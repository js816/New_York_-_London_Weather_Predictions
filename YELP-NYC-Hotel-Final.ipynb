# %% [markdown]
# NYC HOTELS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nych_params1 = {"term":"hotel","location":"New York","limit":50,"offset":0}
nych_response1 = requests.get(search_api_url, headers=headers, params=nych_params1)
nych1 = nych_response1.json()
display(nych1)
#print(nych_response1.url)
#print(nych_response1.status_code)
# Out:
# {'businesses': [{'id': 'GYO8lvStXGZAfFDRlOxQ1Q',
#    'alias': 'hotel-50-bowery-nyc-new-york',
#    'name': 'Hotel 50 Bowery NYC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/opMnr9cWOkbfwrbeIApppg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-50-bowery-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 200,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71599, 'longitude': -73.99683},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '50 Bowery',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['50 Bowery', 'New York, NY 10013']},
#    'phone': '+12125088000',
#    'display_phone': '(212) 508-8000',
#    'distance': 1202.705246954195},
#   {'id': 'cUXl19vPkfd9vdqc0OT7_g',
#    'alias': 'the-ludlow-new-york-city-new-york',
#    'name': 'The Ludlow New York City',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WZ2hDqKCTBlgDXtQIi4xXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ludlow-new-york-city-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 141,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.721839, 'longitude': -73.987355},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '180 Ludlow St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['180 Ludlow St', 'New York, NY 10002']},
#    'phone': '+12124321818',
#    'display_phone': '(212) 432-1818',
#    'distance': 1914.4405497032183},
#   {'id': '6H427bZqS7bqAR-tU8GKDw',
#    'alias': '1-hotel-brooklyn-bridge-brooklyn',
#    'name': '1 Hotel Brooklyn Bridge',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kl2Eu-x0BzadD31gNwBVhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/1-hotel-brooklyn-bridge-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 264,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.701729, 'longitude': -73.995882},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '60 Furman St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Furman St', 'Brooklyn, NY 11201']},
#    'phone': '+18778031111',
#    'display_phone': '(877) 803-1111',
#    'distance': 434.34840074928104},
#   {'id': 'SoSQhqqOaS10aUuxDr1YtA',
#    'alias': 'citizenm-new-york-times-square-hotel-new-york',
#    'name': 'citizenM New York Times Square Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EgR49nnvKbIMY3RU3VgV0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/citizenm-new-york-times-square-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 212,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.761561, 'longitude': -73.984968},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '218 W 50th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['218 W 50th St', 'New York, NY 10019']},
#    'phone': '+12124613638',
#    'display_phone': '(212) 461-3638',
#    'distance': 6289.097804581585},
#   {'id': 'dQFgUq-bSGmfiSYtMo7mnQ',
#    'alias': 'hampton-inn-brooklyn-downtown-brooklyn-2',
#    'name': 'Hampton Inn Brooklyn/Downtown',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xypqA1DNkpfJ8nG8AQfepQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hampton-inn-brooklyn-downtown-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 102,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6957059, 'longitude': -73.9840267},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '125 Flatbush Ave Ext',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['125 Flatbush Ave Ext', 'Brooklyn, NY 11201']},
#    'phone': '+17188758800',
#    'display_phone': '(718) 875-8800',
#    'distance': 1386.272501456994},
#   {'id': 'EL5j67uhlTWSFcrsEX9l_Q',
#    'alias': 'the-frederick-hotel-new-york',
#    'name': 'The Frederick Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/M9MMwr2beg_0UhfirKL3eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-frederick-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71566, 'longitude': -74.0089},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '95 W Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['95 W Broadway', 'New York, NY 10007']},
#    'phone': '+12125661900',
#    'display_phone': '(212) 566-1900',
#    'distance': 1676.296592136316},
#   {'id': 'LSO3Ql7e_Y9nFJmnWdbTPg',
#    'alias': 'the-broome-nyc-new-york',
#    'name': 'The Broome Hotel New York',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3uWqwx4LcAQMXqdMBdn01w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-broome-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.721297, 'longitude': -73.9993957},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '431 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['431 Broome St', 'New York, NY 10013']},
#    'phone': '+12124312929',
#    'display_phone': '(212) 431-2929',
#    'distance': 1814.3792224584138},
#   {'id': 'DxBjx1Bug34P6_kCdkg2Zg',
#    'alias': 'new-york-marriott-at-the-brooklyn-bridge-brooklyn',
#    'name': 'New York Marriott at the Brooklyn Bridge',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VdxNjwrvplA7wEBOZjGcJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-york-marriott-at-the-brooklyn-bridge-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 247,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6937442558137,
#     'longitude': -73.9885747432708},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '333 Adams St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['333 Adams St', 'Brooklyn, NY 11201']},
#    'phone': '+17182467000',
#    'display_phone': '(718) 246-7000',
#    'distance': 1387.4861007527138},
#   {'id': '0xp3lHJWVIH-dSxg-uMCUg',
#    'alias': 'crosby-street-hotel-new-york',
#    'name': 'Crosby Street Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tOR8CrUdvY6P64lsvYTqfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crosby-street-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 145,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72302838, 'longitude': -73.99744294},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '79 Crosby St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79 Crosby St', 'New York, NY 10012']},
#    'phone': '+12122266400',
#    'display_phone': '(212) 226-6400',
#    'distance': 1973.1351815887697},
#   {'id': 'dpZwxj2fgG3pnRbZzXx6GA',
#    'alias': 'the-brooklyn-brooklyn',
#    'name': 'The Brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U2R4guIPD-zLy7AAQyQDeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-brooklyn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.678658, 'longitude': -73.951218},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1199 Atlantic Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1199 Atlantic Ave', 'Brooklyn, NY 11216']},
#    'phone': '+17187891500',
#    'display_phone': '(718) 789-1500',
#    'distance': 4696.920327525606},
#   {'id': 'GXqlI0p_NQejvDEgq0xQ9w',
#    'alias': 'conrad-new-york-downtown-new-york',
#    'name': 'Conrad New York Downtown',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Amdty5l_IJyrW2IJ0bdXww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/conrad-new-york-downtown-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 317,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71503, 'longitude': -74.0158397},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '102 N End Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10282',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 N End Ave', 'New York, NY 10282']},
#    'phone': '+12129450100',
#    'display_phone': '(212) 945-0100',
#    'distance': 2105.7528244827286},
#   {'id': 'jq9WOcjuFe595Rf8I87Y0Q',
#    'alias': 'casablanca-hotel-new-york-2',
#    'name': 'Casablanca Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XWFa88YzofbKVztqbT0dUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casablanca-hotel-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 88,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75641, 'longitude': -73.98547},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '147 W 43rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['147 W 43rd St', 'New York, NY 10036']},
#    'phone': '+12128691212',
#    'display_phone': '(212) 869-1212',
#    'distance': 5724.255233853066},
#   {'id': 'VMGinfrQm6JQfGMUsDFBfg',
#    'alias': 'the-standard-east-village-new-york',
#    'name': 'The Standard, East Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aOEmCElDrEfk8fMx_BkT9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-standard-east-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 209,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7278523436442,
#     'longitude': -73.9907492250947},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '25 Cooper Sq',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 Cooper Sq', 'New York, NY 10003']},
#    'phone': '+12124755700',
#    'display_phone': '(212) 475-5700',
#    'distance': 2509.4341874268853},
#   {'id': 'xsrzs3lSD2-xG889sLqAXA',
#    'alias': 'the-williamsburg-hotel-brooklyn-2',
#    'name': 'The Williamsburg Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5UWMhjtl36uErCSThHsOaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-williamsburg-hotel-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 321,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7215137888895,
#     'longitude': -73.9587011987419},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '96 Wythe Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['96 Wythe Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17183628100',
#    'display_phone': '(718) 362-8100',
#    'distance': 3491.6344065379108},
#   {'id': '4J0EXzWaF-N5B-kltP0pMg',
#    'alias': 'walker-hotel-greenwich-village-new-york-2',
#    'name': 'Walker Hotel Greenwich Village',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eEV50LPMjrW3xZ4dNkAXog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/walker-hotel-greenwich-village-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 123,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73618, 'longitude': -73.9966},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '52 W 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['52 W 13th St', 'New York, NY 10011']},
#    'phone': '+12123751300',
#    'display_phone': '(212) 375-1300',
#    'distance': 3423.1119972449787},
#   {'id': 'MLpKVYcHlYXXIJHt7zAbLA',
#    'alias': 'liberty-inn-new-york-2',
#    'name': 'Liberty Inn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/00hCDj7QWPNiaMwg1BV1uA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/liberty-inn-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74192, 'longitude': -74.0086},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '51 10th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['51 10th Ave', 'New York, NY 10014']},
#    'phone': '+12127412333',
#    'display_phone': '(212) 741-2333',
#    'distance': 4241.513737098739},
#   {'id': 'QxobzmaLiP_Tx6cnmpWQPg',
#    'alias': 'arlo-nomad-new-york',
#    'name': 'Arlo NoMad',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/631xqxLYK8OgVoYP_H9xEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arlo-nomad-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 268,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.746212, 'longitude': -73.9850458},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '11 E 31st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 E 31st St', 'New York, NY 10016']},
#    'phone': '+12128067000',
#    'display_phone': '(212) 806-7000',
#    'distance': 4599.585195853302},
#   {'id': 'lGM-mjoG5ivxJqmEedFukA',
#    'alias': 'nomo-soho-new-york-3',
#    'name': 'NOMO SOHO',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y7zvBlgaO6YPcl3bRK3TSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nomo-soho-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 248,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.719896, 'longitude': -74.000078},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '9 Crosby St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Crosby St', 'New York, NY 10013']},
#    'phone': '+16462186400',
#    'display_phone': '(646) 218-6400',
#    'distance': 1679.2325744941052},
#   {'id': 'TSWhn9EMtv8hYra-Xd2QUw',
#    'alias': 'even-hotel-brooklyn-brooklyn',
#    'name': 'EVEN Hotel Brooklyn',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_X396ZDHOrjHAhL9zZ78wg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/even-hotel-brooklyn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.687842, 'longitude': -73.98187},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '46 Nevins St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['46 Nevins St', 'Brooklyn, NY 11217']},
#    'phone': '+17185523800',
#    'display_phone': '(718) 552-3800',
#    'distance': 2219.9374637074534},
#   {'id': 'jVAAy1KrvskicNnLcn8ylw',
#    'alias': 'nobleden-new-york',
#    'name': 'NobleDEN',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/itI1r5CTf_xKE_Nq1vELkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nobleden-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 106,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71929, 'longitude': -73.99686},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '196 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['196 Grand St', 'New York, NY 10013']},
#    'phone': '+12123908988',
#    'display_phone': '(212) 390-8988',
#    'distance': 1559.7020419479775},
#   {'id': 'vEGyBSEqvWrU_uz0yuRydQ',
#    'alias': 'the-mercer-hotel-new-york',
#    'name': 'The Mercer Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GtgrgBuvW3cGvOAsvmmIjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mercer-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7245521, 'longitude': -73.9988299},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '147 Mercer St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['147 Mercer St', 'New York, NY 10012']},
#    'phone': '+12129666060',
#    'display_phone': '(212) 966-6060',
#    'distance': 2200.077129494172},
#   {'id': '0LdrjL5Yt3vliH0OiglSHg',
#    'alias': 'the-hoxton-brooklyn-2',
#    'name': 'The Hoxton',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DY9ZN1Y8VbwsBpaReRvncA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hoxton-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 75,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72077, 'longitude': -73.95873},
#    'transactions': [],
#    'location': {'address1': '97 Wythe Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['97 Wythe Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17182157100',
#    'display_phone': '(718) 215-7100',
#    'distance': 3447.9472542524304},
#   {'id': 'ks299naLzw8CYdVlLnqPXQ',
#    'alias': 'the-bowery-hotel-new-york-3',
#    'name': 'The Bowery Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JAYvtTVmypIkZ74Fb-ARoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bowery-hotel-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 307,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7260093149249,
#     'longitude': -73.9915595677216},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '335 Bowery',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['335 Bowery', 'New York, NY 10003']},
#    'phone': '+12125059100',
#    'display_phone': '(212) 505-9100',
#    'distance': 2298.237420730232},
#   {'id': 'g8-qHshfhb1Tx3VMYVDZgg',
#    'alias': 'hotel-delmano-brooklyn',
#    'name': 'Hotel Delmano',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-_oMa2V0L9K8138q8D5fZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-delmano-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 383,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.719787, 'longitude': -73.958137},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '82 Berry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['82 Berry St', 'Brooklyn, NY 11211']},
#    'phone': '+17183871945',
#    'display_phone': '(718) 387-1945',
#    'distance': 3441.7067969412697},
#   {'id': 'OmgYgPGvf0a8Gz_jWEpLFQ',
#    'alias': 'the-standard-high-line-new-york',
#    'name': 'The Standard, High Line',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TJludBZmMfB3RZhlAvII6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-standard-high-line-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 691,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.740829, 'longitude': -74.008071},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '848 Washington Street',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['848 Washington Street', 'New York, NY 10014']},
#    'phone': '+12126454646',
#    'display_phone': '(212) 645-4646',
#    'distance': 4099.042539416837},
#   {'id': '_3zTT9xeMFwvkqtMPJeLPg',
#    'alias': 'courtyard-new-york-manhattan-soho-new-york',
#    'name': 'Courtyard by Marriott New York Manhattan/SoHo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GpnJoSYo4dTy1endvBrQkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/courtyard-new-york-manhattan-soho-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 85,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7275586084056,
#     'longitude': -74.0057217632294},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '181 Varick St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['181 Varick St', 'New York, NY 10014']},
#    'phone': '+12124148282',
#    'display_phone': '(212) 414-8282',
#    'distance': 2640.8517448412313},
#   {'id': 'NVsI5DRm1CszltskWJvvZQ',
#    'alias': 'hotel-giraffe-new-york',
#    'name': 'Hotel Giraffe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BdNLCxZSH642yNUqfcZSXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-giraffe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 196,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7421, 'longitude': -73.98461},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '365 Park Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['365 Park Ave S', 'New York, NY 10016']},
#    'phone': '+12126857700',
#    'display_phone': '(212) 685-7700',
#    'distance': 4158.315095576667},
#   {'id': 'V12xO69xVoHWSXBpb3zQ4w',
#    'alias': 'the-greenwich-hotel-new-york',
#    'name': 'The Greenwich Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/C-kU3NpirWRVvoCgNdm1hg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-greenwich-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.719848, 'longitude': -74.009864},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '377 Greenwich St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['377 Greenwich St', 'New York, NY 10013']},
#    'phone': '+12129418900',
#    'display_phone': '(212) 941-8900',
#    'distance': 2071.595369191694},
#   {'id': 'oaxaN-kZuIeZmz7mndoXwA',
#    'alias': 'the-william-new-york',
#    'name': 'The William',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aAVMkexsDbrqhFAFN-DpmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-william-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.750477, 'longitude': -73.980263},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '24 E 39th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 E 39th St', 'New York, NY 10016']},
#    'phone': '+16469228600',
#    'display_phone': '(646) 922-8600',
#    'distance': 5145.572903449319},
#   {'id': 'J0bkcxkGKZuaghjiPUc4MA',
#    'alias': 'hilton-garden-inn-new-york-tribeca-new-york-2',
#    'name': 'Hilton Garden Inn New York/Tribeca',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kcBqYTWIUdZfY17IePWNMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hilton-garden-inn-new-york-tribeca-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 135,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7209583, 'longitude': -74.00544071475811},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '39 Ave Of The Americas',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39 Ave Of The Americas', 'New York, NY 10013']},
#    'phone': '+12129664091',
#    'display_phone': '(212) 966-4091',
#    'distance': 1964.289822438691},
#   {'id': 'EeQnc16aQ2-H8WN9reGGZg',
#    'alias': 'wythe-hotel-brooklyn',
#    'name': 'Wythe Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cR74uoGjsGvNEknzOzmewg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wythe-hotel-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 298,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.72188667, 'longitude': -73.958105},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '80 Wythe Ave N',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Wythe Ave N', 'Brooklyn, NY 11249']},
#    'phone': '+17184608000',
#    'display_phone': '(718) 460-8000',
#    'distance': 3557.709618756631},
#   {'id': 'byrfRqI_R_ZWTgVDBkB57g',
#    'alias': 'hotel-le-jolie-brooklyn',
#    'name': 'Hotel Le Jolie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PR8aMDPM0gET5lcU6xtQFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-le-jolie-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 98,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71653, 'longitude': -73.9508},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '235 Meeker Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['235 Meeker Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17186252100',
#    'display_phone': '(718) 625-2100',
#    'distance': 3870.3949993953806},
#   {'id': '9LqjNHKYyDAE8wwe5sBJWw',
#    'alias': 'the-marlton-hotel-new-york',
#    'name': 'The Marlton Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/N3KDG8kv3ABwFXf2QDdUGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-marlton-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 143,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7324317842722,
#     'longitude': -73.9966548979282},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '5 W 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 W 8th St', 'New York, NY 10011']},
#    'phone': '+12123210100',
#    'display_phone': '(212) 321-0100',
#    'distance': 3031.268950568642},
#   {'id': 'QnNDwDZDVAatr1Q_UBBl-w',
#    'alias': 'arlo-soho-new-york',
#    'name': 'Arlo SoHo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ivc5yl2-QKxThrarfscnvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arlo-soho-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 291,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.724495, 'longitude': -74.007965},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '231 Hudson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 Hudson St', 'New York, NY 10013']},
#    'phone': '+12123427000',
#    'display_phone': '(212) 342-7000',
#    'distance': 2411.3988669470828},
#   {'id': '_BwrVzhkCh8oYMQW4P3ebQ',
#    'alias': 'crown-motor-inn-flushing',
#    'name': 'Crown Motor Inn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/igyZ59jWeyaFA1sekk9d0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crown-motor-inn-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.7394117, 'longitude': -73.8896648},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '7401 Queens Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7401 Queens Blvd', 'Flushing, NY 11373']},
#    'phone': '+17184461414',
#    'display_phone': '(718) 446-1414',
#    'distance': 9588.214918275515},
#   {'id': 'q9-LIXLiXaACuBLKyO5tJg',
#    'alias': 'the-william-vale-brooklyn-4',
#    'name': 'The William Vale',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BZbMMnuLTapW9vRhrFfXrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-william-vale-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 258,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7222796349227,
#     'longitude': -73.9571206358786},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '111 N 12th St',
#     'address2': None,
#     'address3': 'Williamsburg',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 N 12th St',
#      'Williamsburg',
#      'Brooklyn, NY 11249']},
#    'phone': '+17186318400',
#    'display_phone': '(718) 631-8400',
#    'distance': 3649.651858510434},
#   {'id': 'sDrRAoS8yhs091NMn52_QA',
#    'alias': 'the-jane-hotel-new-york-2',
#    'name': 'The Jane Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QM6pjyvJ5oKQgdY8T9DWSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-jane-hotel-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 896,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.738362, 'longitude': -74.009413},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '113 Jane St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['113 Jane St', 'New York, NY 10014']},
#    'phone': '+12129246700',
#    'display_phone': '(212) 924-6700',
#    'distance': 3875.6579046286793},
#   {'id': 'fVUuJd-ZR5DUhzjdI6mGRQ',
#    'alias': 'bowery-lodge-new-york',
#    'name': 'Bowery Lodge',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/h6gIL_xtxBWrcQU2NKtBzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bowery-lodge-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.716723, 'longitude': -73.9953761},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '81 Bowery',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81 Bowery', 'New York, NY 10002']},
#    'phone': '+12129668821',
#    'display_phone': '(212) 966-8821',
#    'distance': 1257.3871553327806},
#   {'id': 'K5rgmQy_4WiOXY_9A-QorA',
#    'alias': 'sanctuary-hotel-new-york-new-york',
#    'name': 'Sanctuary Hotel New York',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fW4G7Uaq8xH7U_Q3dskgRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sanctuary-hotel-new-york-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 177,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75837, 'longitude': -73.9832957},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '132 W 47th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['132 W 47th St', 'New York, NY 10036']},
#    'phone': '+12122347000',
#    'display_phone': '(212) 234-7000',
#    'distance': 5957.508746951999},
#   {'id': 'VqMuuey8_bH3sZ5qHL9tPQ',
#    'alias': 'ace-hotel-new-york-new-york-2',
#    'name': 'Ace Hotel New York',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/63EoSbWNR-tD6rlzGX-x7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ace-hotel-new-york-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 729,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.745777, 'longitude': -73.988286},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '20 W 29th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['20 W 29th St', 'New York, NY 10001']},
#    'phone': '+12126792222',
#    'display_phone': '(212) 679-2222',
#    'distance': 4513.203273243912},
#   {'id': 't6efAU5wYjIMd6T6eGbeWg',
#    'alias': 'public-hotel-new-york',
#    'name': 'PUBLIC Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rHoWLQ_eED6xkuLalb9WdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/public-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 328,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.72307, 'longitude': -73.99203},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '215 Chrystie St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['215 Chrystie St', 'New York, NY 10002']},
#    'phone': '+12127356000',
#    'display_phone': '(212) 735-6000',
#    'distance': 1969.0844053104643},
#   {'id': 'nwvo49wYOrSfg3AhafhZvA',
#    'alias': 'the-beekman-a-thompson-hotel-new-york',
#    'name': 'The Beekman, A Thompson Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LvgeGQppQcWaDva-9jYpUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-beekman-a-thompson-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 150,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7111443, 'longitude': -74.0066413},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '123 Nassau St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['123 Nassau St', 'New York, NY 10038']},
#    'phone': '+12122332300',
#    'display_phone': '(212) 233-2300',
#    'distance': 1218.5833722897614},
#   {'id': 'WQZCwbYZ5XLnmENzOv2xCQ',
#    'alias': 'the-inn-at-irving-place-new-york',
#    'name': 'The Inn At Irving Place',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tHwLyfgScKqv9m_y7EzwyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-inn-at-irving-place-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.735958, 'longitude': -73.986961},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '56 Irving Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['56 Irving Pl', 'New York, NY 10003']},
#    'phone': '+12125334600',
#    'display_phone': '(212) 533-4600',
#    'distance': 3444.0768258597886},
#   {'id': 'SZTBP6Xj7ER4d3NSbgOA-A',
#    'alias': 'four-seasons-hotel-new-york-4',
#    'name': 'Four Seasons Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9aFIPCHXvZnn6Iu7bMVtDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/four-seasons-hotel-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71264339026144,
#     'longitude': -74.0091883883457},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '27 Barclay St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27 Barclay St', 'New York, NY 10007']},
#    'phone': '+16468801999',
#    'display_phone': '(646) 880-1999',
#    'distance': 1488.954857600927},
#   {'id': 'zuMUWAduEq4COEcbnZ3XCA',
#    'alias': 'park-hyatt-new-york-new-york-city',
#    'name': 'Park Hyatt New York',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tG7ih1ELi95Oco2DAaZmsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/park-hyatt-new-york-new-york-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 145,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76538, 'longitude': -73.97895},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '153 West 57th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York City',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['153 West 57th St', 'New York City, NY 10019']},
#    'phone': '+16467741234',
#    'display_phone': '(646) 774-1234',
#    'distance': 6803.977690887442},
#   {'id': 'uK3Wug7R0YylT_u0QWZjUg',
#    'alias': 'gansevoort-meatpacking-nyc-new-york',
#    'name': 'Gansevoort Meatpacking NYC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QW3TiF74rmBCiGQx3Y_yKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gansevoort-meatpacking-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 588,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.73991259707736,
#     'longitude': -74.0058626235944},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '18 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18 9th Ave', 'New York, NY 10014']},
#    'phone': '+12122066700',
#    'display_phone': '(212) 206-6700',
#    'distance': 3954.700006188329},
#   {'id': '0SrF_WcRetbGWlps7ZhJNw',
#    'alias': 'east-village-hotel-new-york',
#    'name': 'East Village Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XQOgohYYeTATmm_3G6yFog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/east-village-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72836, 'longitude': -73.98497},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '147 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['147 1st Ave', 'New York, NY 10003']},
#    'phone': '+19176357757',
#    'display_phone': '(917) 635-7757',
#    'distance': 2668.237156616943},
#   {'id': 'HsfNLFKADPZUNXsRVx9_dA',
#    'alias': 'citizenm-new-york-bowery-hotel-new-york-2',
#    'name': 'citizenM New York Bowery Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xY3xFcKaVr1YGMcnDKWx9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/citizenm-new-york-bowery-hotel-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 128,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72069, 'longitude': -73.99366},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '189 Bowery',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['189 Bowery', 'New York, NY 10002']},
#    'phone': '+12123727274',
#    'display_phone': '(212) 372-7274',
#    'distance': 1696.0197677157246},
#   {'id': 'htWCcFI5R5Cuwod5PNSpow',
#    'alias': '1-hotel-central-park-new-york',
#    'name': '1 Hotel Central Park',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hWyFWROAi_ogTGNmEBR6iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/1-hotel-central-park-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 129,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.764812, 'longitude': -73.976463},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1414 Ave Of The Americas',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1414 Ave Of The Americas', 'New York, NY 10019']},
#    'phone': '+12127032001',
#    'display_phone': '(212) 703-2001',
#    'distance': 6770.1037127699055},
#   {'id': 'svW0v_j18STsq5Ua-8waZg',
#    'alias': 'the-dominick-new-york',
#    'name': 'The Dominick',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oN1o_pBVqbhg0ikCZAkADA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dominick-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 345,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72546541976049,
#     'longitude': -74.00532992757799},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '246 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['246 Spring St', 'New York, NY 10013']},
#    'phone': '+12128425500',
#    'display_phone': '(212) 842-5500',
#    'distance': 2412.7019106955836}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nych1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Hotel": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                                   Hotel    Type Price Rating  \
# 0                   Hotel 50 Bowery NYC  Hotels    $$    4.5
# 1              The Ludlow New York City  Hotels   $$$      4
# 2               1 Hotel Brooklyn Bridge  Hotels   $$$    3.5
# 3  citizenM New York Times Square Hotel  Hotels    $$    4.5
# 4         Hampton Inn Brooklyn/Downtown  Hotels    $$      4
#
#                 Address        Lat        Lng  \
# 0             50 Bowery  40.715990 -73.996830
# 1         180 Ludlow St  40.721839 -73.987355
# 2          60 Furman St  40.701729 -73.995882
# 3         218 W 50th St  40.761561 -73.984968
# 4  125 Flatbush Ave Ext  40.695706 -73.984027
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/hotel-50-bowery-nyc-n...  GYO8lvStXGZAfFDRlOxQ1Q
# 1  https://www.yelp.com/biz/the-ludlow-new-york-c...  cUXl19vPkfd9vdqc0OT7_g
# 2  https://www.yelp.com/biz/1-hotel-brooklyn-brid...  6H427bZqS7bqAR-tU8GKDw
# 3  https://www.yelp.com/biz/citizenm-new-york-tim...  SoSQhqqOaS10aUuxDr1YtA
# 4  https://www.yelp.com/biz/hampton-inn-brooklyn-...  dQFgUq-bSGmfiSYtMo7mnQ

# %%
#2nd set of 50 records 51-100 
nych_params2 = {"term":"hotel","location":"New York","limit":50,"offset":51}
nych_response2 = requests.get(search_api_url, headers=headers, params=nych_params2)
nych2 = nych_response2.json()
display(nych2)
#print(nych_response2.url)
#print(nych_response2.status_code)
# Out:
# {'businesses': [{'id': 'wxKyslbI99ESDbQnns-RSg',
#    'alias': 'sixty-les-new-york-2',
#    'name': 'SIXTY LES',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/R0xfxRTZTAjBACG5B84KWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sixty-les-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 200,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.7221165, 'longitude': -73.9886525},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '190 Allen St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['190 Allen St', 'New York, NY 10002']},
#    'phone': '+12124605300',
#    'display_phone': '(212) 460-5300',
#    'distance': 1913.7902204502134},
#   {'id': 'EPt4kS2XVMhvyoxdyzNeLQ',
#    'alias': 'moxy-nyc-east-village-new-york',
#    'name': 'Moxy NYC East Village',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kTriJGmfGKRUtYgOKFoslg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moxy-nyc-east-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.731601, 'longitude': -73.989509},
#    'transactions': [],
#    'location': {'address1': '112 E 11th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['112 E 11th St', 'New York, NY 10003']},
#    'phone': '+12122886699',
#    'display_phone': '(212) 288-6699',
#    'distance': 2936.2414624766216},
#   {'id': '2_ehPnf8YEaDGAzenLYnrQ',
#    'alias': 'the-high-line-hotel-new-york-4',
#    'name': 'The High Line Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/h15InAktDf0_gmn-C1C_gA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-high-line-hotel-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 136,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.745962, 'longitude': -74.0049928},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '180 10th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['180 10th Ave', 'New York, NY 10011']},
#    'phone': '+12129293888',
#    'display_phone': '(212) 929-3888',
#    'distance': 4594.630028215432},
#   {'id': 'FqRul4l8Vea_b1x6ggRrJw',
#    'alias': 'soho-house-new-york-new-york-2',
#    'name': 'Soho House New York',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6hHFeRK-xjtYH_x_bGv42A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soho-house-new-york-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 255,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74063741, 'longitude': -74.0059231},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '29-35 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['29-35 9th Ave', 'New York, NY 10014']},
#    'phone': '+12126279800',
#    'display_phone': '(212) 627-9800',
#    'distance': 4034.0905417327035},
#   {'id': 'JLoLYfqWvcOPIUfxu48qbQ',
#    'alias': 'fairfield-inn-and-suites-new-york-midtown-manhattan-penn-station-new-york-2',
#    'name': 'Fairfield Inn & Suites New York Midtown Manhattan/Penn Station',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nn9KCtEct9Lj2Z4K-kyQcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fairfield-inn-and-suites-new-york-midtown-manhattan-penn-station-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 119,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7521723402439,
#     'longitude': -73.9951658490235},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '325 W 33rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['325 W 33rd St', 'New York, NY 10001']},
#    'phone': '+12125630900',
#    'display_phone': '(212) 563-0900',
#    'distance': 5196.372768194703},
#   {'id': 'bCilcCWpBrJEFid7TQiDWA',
#    'alias': 'the-new-york-edition-new-york',
#    'name': 'The New York EDITION',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ONJoIHHwfkAsIK8pa9FdiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-new-york-edition-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 138,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.741367, 'longitude': -73.9873577288361},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '5 Madison Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 Madison Ave', 'New York, NY 10010']},
#    'phone': '+12124134200',
#    'display_phone': '(212) 413-4200',
#    'distance': 4036.8878694894433},
#   {'id': 'BnqsLvT7IaPZIibgj35t_Q',
#    'alias': 'the-harlem-flop-house-new-york',
#    'name': 'The Harlem Flop House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qygqQwoZoWkGpH8jzbKiVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-harlem-flop-house-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.80815, 'longitude': -73.9509999},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '242 West 123rd',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['242 West 123rd', 'New York, NY 10027']},
#    'phone': '+12126620678',
#    'display_phone': '(212) 662-0678',
#    'distance': 11990.732870924128},
#   {'id': '11sSXZAiqPA3UrNurkR8Hg',
#    'alias': 'hotel-indigo-lower-east-side-new-york-new-york',
#    'name': 'Hotel Indigo Lower East Side New York',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y64HZMmR56SgkzyZZECC9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-indigo-lower-east-side-new-york-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 194,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.72171, 'longitude': -73.987518},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '171 Ludlow St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 Ludlow St', 'New York, NY 10002']},
#    'phone': '+12122371776',
#    'display_phone': '(212) 237-1776',
#    'distance': 1896.6056994007447},
#   {'id': '9TK6ea3GR2B6H6jErPRlTw',
#    'alias': 'the-nolitan-hotel-new-york',
#    'name': 'The Nolitan Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xGCMCBqD3OsmvJmdrUhklg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-nolitan-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 95,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7205772, 'longitude': -73.9953391},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '30 Kenmare St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30 Kenmare St', 'New York, NY 10012']},
#    'phone': '+12129252555',
#    'display_phone': '(212) 925-2555',
#    'distance': 1684.9445830237828},
#   {'id': 'fA7iFSxoIQXcCcxSwL5oHw',
#    'alias': 'mandarin-oriental-new-york-new-york-5',
#    'name': 'Mandarin Oriental - New York',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8FqDzGj3e9Dk9TrVzBPQrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mandarin-oriental-new-york-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 181,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76847, 'longitude': -73.98309},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '80 Columbus Cir',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Columbus Cir', 'New York, NY 10023']},
#    'phone': '+12128058800',
#    'display_phone': '(212) 805-8800',
#    'distance': 7113.050817604821},
#   {'id': 'pY-DMHCPIRifZo9Cay1Low',
#    'alias': 'the-mckittrick-hotel-new-york',
#    'name': 'The McKittrick Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mBuKzTT4j48RcWVSfn0yWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mckittrick-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 98,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'jazzandblues', 'title': 'Jazz & Blues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.750611, 'longitude': -74.003868},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '530 W 27th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['530 W 27th St', 'New York, NY 10001']},
#    'phone': '+12129041880',
#    'display_phone': '(212) 904-1880',
#    'distance': 5086.634398899394},
#   {'id': 'M-DhhgGu2Gp12Qc-_PhzuQ',
#    'alias': 'sixty-soho-new-york-4',
#    'name': 'SIXTY SoHo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GDMOZ0MrANwEn12Xwep8hg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sixty-soho-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7239965362906,
#     'longitude': -74.003159954002},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '60 Thompson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Thompson St', 'New York, NY 10012']},
#    'phone': '+12124310400',
#    'display_phone': '(212) 431-0400',
#    'distance': 2194.0407623434216},
#   {'id': 'qLV7zNf9CE6C1Nsb3i20PQ',
#    'alias': 'cambria-hotel-new-york-chelsea-new-york',
#    'name': 'Cambria Hotel New York - Chelsea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bCjhn4ySUH8NWNeUYrOdHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cambria-hotel-new-york-chelsea-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 114,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.746727, 'longitude': -73.991567},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '123 W 28th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['123 W 28th St', 'New York, NY 10001']},
#    'phone': '+12122444477',
#    'display_phone': '(212) 244-4477',
#    'distance': 4594.2398412562125},
#   {'id': '5DkFAVEU_gAkC3wAUqdAZg',
#    'alias': 'residence-inn-by-marriott-new-york-downtown-manhattan-new-york-3',
#    'name': 'Residence Inn by Marriott New York Downtown Manhattan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bs1ZtvD5T3Ml6HbGACrI9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/residence-inn-by-marriott-new-york-downtown-manhattan-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.709564, 'longitude': -74.0099212},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '170 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['170 Broadway', 'New York, NY 10007']},
#    'phone': '+12126008900',
#    'display_phone': '(212) 600-8900',
#    'distance': 1394.6569976704864},
#   {'id': 'NJR4lyaLF4-3kJ3eNK9cpA',
#    'alias': 'mccarren-hotel-and-pool-brooklyn',
#    'name': 'McCarren Hotel & Pool',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gqX-n59jw4t4kIoNI2enYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mccarren-hotel-and-pool-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 300,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7209524, 'longitude': -73.9553668},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '160 N 12th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['160 N 12th St', 'Brooklyn, NY 11249']},
#    'phone': '+17182187500',
#    'display_phone': '(718) 218-7500',
#    'distance': 3706.4151606977625},
#   {'id': '1Jyg_gj0yNGR8TqvOEQ4iQ',
#    'alias': 'the-box-house-hotel-brooklyn',
#    'name': 'The Box House Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xU1rEqsU_0okYXaEnUcJCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-box-house-hotel-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 152,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73782, 'longitude': -73.95354},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '77 Box St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['77 Box St', 'Brooklyn, NY 11222']},
#    'phone': '+17183833800',
#    'display_phone': '(718) 383-3800',
#    'distance': 4959.493223607861},
#   {'id': 'de3c201K0cfWbvy-3XAqig',
#    'alias': 'hilton-garden-inn-new-york-midtown-park-ave-new-york-2',
#    'name': 'Hilton Garden Inn New York/Midtown Park Ave',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mIj-OzTjTNBSsNJ8YjGb_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hilton-garden-inn-new-york-midtown-park-ave-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 99,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.746849, 'longitude': -73.9822311},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '45 E 33rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 E 33rd St', 'New York, NY 10016']},
#    'phone': '+12127551108',
#    'display_phone': '(212) 755-1108',
#    'distance': 4714.793864109132},
#   {'id': '7X5dByOWa-nXY_2eBnVcHw',
#    'alias': 'the-roxy-hotel-tribeca-new-york',
#    'name': 'The Roxy Hotel Tribeca',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2MdfjRpQrl84Xgb87tJdWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-roxy-hotel-tribeca-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 432,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71936, 'longitude': -74.00483},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '2 6th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2 6th Ave', 'New York, NY 10013']},
#    'phone': '+12125196600',
#    'display_phone': '(212) 519-6600',
#    'distance': 1792.4626459015908},
#   {'id': '8gWw3lMOqi3xe8d0nKUiKw',
#    'alias': 'hyatt-union-square-new-york-new-york',
#    'name': 'Hyatt Union Square New York',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FOx1hG5p4dnXB9Cvo5L-pw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hyatt-union-square-new-york-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 113,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7334389395744,
#     'longitude': -73.9900782372587},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '134 Fourth Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['134 Fourth Ave', 'New York, NY 10003']},
#    'phone': '+12122531234',
#    'display_phone': '(212) 253-1234',
#    'distance': 3132.998412742251},
#   {'id': 'fEqSedl1uUUfpmfs3mMiwQ',
#    'alias': 'hilton-garden-inn-times-square-new-york',
#    'name': 'Hilton Garden Inn Times Square',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PnVUGB0c1aK7Z6zTU1jAfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hilton-garden-inn-times-square-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 326,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7612053955474,
#     'longitude': -73.9865067601204},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '790 8th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['790 8th Ave', 'New York, NY 10019']},
#    'phone': '+12125817000',
#    'display_phone': '(212) 581-7000',
#    'distance': 6234.895445226294},
#   {'id': 'P2-YUkcDcgyYW46hSPYBMw',
#    'alias': 'holiday-inn-nyc-lower-east-side-new-york',
#    'name': 'Holiday Inn NYC - Lower East Side',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SZn6I6VMAMWD6iTcND6pag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holiday-inn-nyc-lower-east-side-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.718292, 'longitude': -73.98624},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '150 Delancey',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 Delancey', 'New York, NY 10002']},
#    'phone': '+12124752500',
#    'display_phone': '(212) 475-2500',
#    'distance': 1581.5940407008243},
#   {'id': 'nnAkMNV9Zh6G9BZLLOhfog',
#    'alias': 'baccarat-hotel-new-york-3',
#    'name': 'Baccarat Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6_araIFcTl4XLSoQoK4k9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baccarat-hotel-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 244,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76091, 'longitude': -73.97732},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '28 W 53rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 W 53rd St', 'New York, NY 10019']},
#    'phone': '+18669575139',
#    'display_phone': '(866) 957-5139',
#    'distance': 6329.086554250289},
#   {'id': 'm-8qqfAKP5Hw2JZVCx5wQA',
#    'alias': 'lex-hotel-nyc-new-york',
#    'name': 'Lex Hotel NYC',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NjwX-qbH8iFEWxt3L0kAdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lex-hotel-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.740934, 'longitude': -73.9833419},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '67 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['67 Lexington Ave', 'New York, NY 10010']},
#    'phone': '+18774540395',
#    'display_phone': '(877) 454-0395',
#    'distance': 4052.6857809647577},
#   {'id': 'dOTi0TD49S2xqul_71ohUQ',
#    'alias': 'concrete-jungle-at-the-tillary-hotel-brooklyn',
#    'name': 'Concrete Jungle at The Tillary Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Zi2H55rQRJdNAkT0I0cpRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/concrete-jungle-at-the-tillary-hotel-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.69661265607699,
#     'longitude': -73.98453705042085},
#    'transactions': [],
#    'location': {'address1': '85 Flatbush Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 Flatbush Ave', 'Brooklyn, NY 11217']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1280.9822652548642},
#   {'id': 'IAs7wYWuQqs-UAGNjaUufg',
#    'alias': 'sun-bright-hotel-manhattan',
#    'name': 'Sun Bright Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yCz08q9Pdjk6rycbVfoHag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sun-bright-hotel-manhattan?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 40.71727, 'longitude': -73.99583},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '140 Hester St',
#     'address2': '',
#     'address3': '',
#     'city': 'Manhattan',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['140 Hester St', 'Manhattan, NY 10013']},
#    'phone': '+18668440460',
#    'display_phone': '(866) 844-0460',
#    'distance': 1323.9212152035375},
#   {'id': 'rD48w_Iyo-VU-Hvu_e0NeQ',
#    'alias': 'days-inn-by-wyndham-hotel-new-york-city-broadway-new-york',
#    'name': 'Days Inn by Wyndham Hotel New York City-Broadway',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QSqumwz-g2GME9iYhm1z3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/days-inn-by-wyndham-hotel-new-york-city-broadway-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 208,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.7931131923646,
#     'longitude': -73.971762077771},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '215 West 94th Street',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['215 West 94th Street', 'New York, NY 10025']},
#    'phone': '+18003291073',
#    'display_phone': '(800) 329-1073',
#    'distance': 9931.311897960266},
#   {'id': '-Hneo47XIw4irjQBdPMecA',
#    'alias': 'doubletree-by-hilton-new-york-downtown-new-york',
#    'name': 'DoubleTree by Hilton New York Downtown',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/02Z1k117ULrxlgKaqcYl0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doubletree-by-hilton-new-york-downtown-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 264,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.703921, 'longitude': -74.0123519},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8 Stone St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8 Stone St', 'New York, NY 10004']},
#    'phone': '+12124809100',
#    'display_phone': '(212) 480-9100',
#    'distance': 1531.6527961342165},
#   {'id': 'WiXCUJExPRxcrjeX7Awthg',
#    'alias': 'urban-cowboy-b-and-b-brooklyn',
#    'name': 'Urban Cowboy B&B',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i7wTgL1-o1C8W3TUCPwirw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/urban-cowboy-b-and-b-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7123299, 'longitude': -73.9465103},
#    'transactions': [],
#    'location': {'address1': '111 Powers St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 Powers St', 'Brooklyn, NY 11211']},
#    'phone': '+13478400525',
#    'display_phone': '(347) 840-0525',
#    'distance': 4103.974045461183},
#   {'id': 'mM4Q4mnSK5cFLv2gXPu49Q',
#    'alias': 'w-new-york-union-square-new-york-2',
#    'name': 'W New York - Union Square',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LbAZY26Ai2p2WcM9IDMd9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/w-new-york-union-square-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 284,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73665, 'longitude': -73.98869},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '201 Park Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['201 Park Ave S', 'New York, NY 10003']},
#    'phone': '+12122539119',
#    'display_phone': '(212) 253-9119',
#    'distance': 3499.274089603533},
#   {'id': 'VeNu9ATM2HI2NL4Q-ZsTsg',
#    'alias': 'nu-hotel-brooklyn-brooklyn-3',
#    'name': 'NU Hotel - Brooklyn',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LMQT4VaAfFwiWqRXE7Q6TQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nu-hotel-brooklyn-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 193,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.68879, 'longitude': -73.98885},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '85 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17188528585',
#    'display_phone': '(718) 852-8585',
#    'distance': 1900.8340455161504},
#   {'id': 'KKhFd2VBfIj5n4t0rYVMYQ',
#    'alias': 'pod-brooklyn-hotel-brooklyn-2',
#    'name': 'Pod Brooklyn Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Z7gETH1dKvHIziSr2Zkg_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pod-brooklyn-hotel-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71502, 'longitude': -73.95903},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '247 Metropolitan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['247 Metropolitan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+18447637666',
#    'display_phone': '(844) 763-7666',
#    'distance': 3160.644482141769},
#   {'id': 'icE34yZpi0lCBTDaQs914w',
#    'alias': 'the-tillary-hotel-brooklyn-brooklyn',
#    'name': 'The Tillary Hotel Brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fKirUQodV8bONbLBL2-5ZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-tillary-hotel-brooklyn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 105,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.6964453, 'longitude': -73.9843605},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '85 Flatbush Ave Ext',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 Flatbush Ave Ext', 'Brooklyn, NY 11201']},
#    'phone': '+17183299537',
#    'display_phone': '(718) 329-9537',
#    'distance': 1304.8056632794219},
#   {'id': 'Q6n8-lbd-ozt5J13xGnAwQ',
#    'alias': 'hilton-garden-inn-nyc-financial-center-manhattan-downtown-new-york',
#    'name': 'Hilton Garden Inn NYC Financial Center/Manhattan Downtown',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2-pv5gDIPbpLxjGdJMeU4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hilton-garden-inn-nyc-financial-center-manhattan-downtown-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70297, 'longitude': -74.012281},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '6 Water St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6 Water St', 'New York, NY 10004']},
#    'phone': '+12122481100',
#    'display_phone': '(212) 248-1100',
#    'distance': 1541.055541435502},
#   {'id': 'ItnW4u1nVYvde1NT4Lgd3g',
#    'alias': 'maritime-hotel-new-york',
#    'name': 'Maritime Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CfZkHG3hBHVzBlLR_5xKIQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maritime-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 145,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7419282, 'longitude': -74.0032432},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '363 W 16th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['363 W 16th St', 'New York, NY 10011']},
#    'phone': '+12122424300',
#    'display_phone': '(212) 242-4300',
#    'distance': 4193.962795074887},
#   {'id': '7fN4Ygy-q3uRcE3wESTIRw',
#    'alias': 'new-world-hotel-new-york',
#    'name': 'New World Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vtxPva7fm92TF8BfTefWQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-world-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 40.71751, 'longitude': -73.99511},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '101 Bowery',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['101 Bowery', 'New York, NY 10002']},
#    'phone': '+12122265522',
#    'display_phone': '(212) 226-5522',
#    'distance': 1339.5572198387208},
#   {'id': 'qZewWn4-pdd4JfoJSBV1QA',
#    'alias': 'library-hotel-by-library-hotel-collection-new-york',
#    'name': 'Library Hotel by Library Hotel Collection',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EF7HDCezh_OrafkuQ000ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/library-hotel-by-library-hotel-collection-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 138,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75218, 'longitude': -73.97954},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '299 Madison Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['299 Madison Ave', 'New York, NY 10017']},
#    'phone': '+12129834500',
#    'display_phone': '(212) 983-4500',
#    'distance': 5342.446887919652},
#   {'id': 'adpehB-xkZzcmH4iYMMPNA',
#    'alias': 'wyndham-garden-chinatown-new-york-2',
#    'name': 'Wyndham Garden Chinatown',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6CdgAxbp7kfbTpF54PhT7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wyndham-garden-chinatown-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 101,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7171, 'longitude': -73.99533},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '93 Bowery',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['93 Bowery', 'New York, NY 10002']},
#    'phone': '+18885959874',
#    'display_phone': '(888) 595-9874',
#    'distance': 1290.075458386998},
#   {'id': 'qkztosV5nQmw6snsSq7Xrg',
#    'alias': 'washington-square-hotel-new-york',
#    'name': 'Washington Square Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/P20j5mTVqpD3b6P64s6SSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/washington-square-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 118,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.732509, 'longitude': -73.998657},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '103 Waverly Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 Waverly Pl', 'New York, NY 10011']},
#    'phone': '+12127779515',
#    'display_phone': '(212) 777-9515',
#    'distance': 3027.456937976985},
#   {'id': 'w_uKKMkIywOKuis4JfDqkw',
#    'alias': 'sago-hotel-new-york',
#    'name': 'Sago Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/f4Y9NsRKY19eEDjlYF4mFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sago-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7193609, 'longitude': -73.9899591},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '120 Allen St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['120 Allen St', 'New York, NY 10002']},
#    'phone': '+12129511112',
#    'display_phone': '(212) 951-1112',
#    'distance': 1601.4481588265116},
#   {'id': 'DmjSuTCPS-d9HFwmTO9jrA',
#    'alias': 'opera-house-hotel-bronx-2',
#    'name': 'Opera House Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dcuVqCK3hO6DseJYSzvVsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/opera-house-hotel-bronx-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 95,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.815111, 'longitude': -73.915468},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '436 E 149th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10455',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['436 E 149th St', 'Bronx, NY 10455']},
#    'phone': '+17184072800',
#    'display_phone': '(718) 407-2800',
#    'distance': 13884.425752916903},
#   {'id': 'kZuF9vhtHkDBBX8nnKeKZg',
#    'alias': 'the-7-days-hotel-the-bronx',
#    'name': 'The 7 Days Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Q2x8vUbG_OgSmGIVul6qCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-7-days-hotel-the-bronx?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 40.82729, 'longitude': -73.84533},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2338 Bruckner Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'The Bronx',
#     'zip_code': '10473',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2338 Bruckner Blvd', 'The Bronx, NY 10473']},
#    'phone': '+17188222434',
#    'display_phone': '(718) 822-2434',
#    'distance': 18464.265704551},
#   {'id': '2nEXbS33ksBOe6JViJdyog',
#    'alias': 'soho-grand-hotel-new-york',
#    'name': 'Soho Grand Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eQYvR9aXjeZoYr5gkrN9NQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soho-grand-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 368,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7220519, 'longitude': -74.0045064},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '310 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['310 W Broadway', 'New York, NY 10013']},
#    'phone': '+12129653000',
#    'display_phone': '(212) 965-3000',
#    'distance': 2037.39234551383},
#   {'id': 'VzVdwfFwY1dgWKNqlen8lw',
#    'alias': 'hotel-hugo-new-york',
#    'name': 'Hotel Hugo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KKrC9Qw7A4QBDUAjwaUPmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-hugo-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 137,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.726427, 'longitude': -74.008857},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '525 Greenwich St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['525 Greenwich St', 'New York, NY 10013']},
#    'phone': '+12126084848',
#    'display_phone': '(212) 608-4848',
#    'distance': 2636.283486207854},
#   {'id': 'dz1E1AOUQE1f3Ga1sM6pZA',
#    'alias': 'chelsea-pods-new-york',
#    'name': 'Chelsea Pods',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YHIZY0xQkQ7v6fmUYoZyBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chelsea-pods-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.748534590305,
#     'longitude': -73.9958837628365},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '370 8th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['370 8th Ave', 'New York, NY 10001']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4793.227855293936},
#   {'id': 'bIwfyB1MiTrMEZBTAqu0tg',
#    'alias': 'twa-hotel-new-york',
#    'name': 'TWA Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3T2Z0nyi0CrTFNWLC5OT-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/twa-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 303,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.645806489104,
#     'longitude': -73.7779250028912},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'JFK Airport',
#     'address2': 'Terminal 5',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11430',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['JFK Airport', 'Terminal 5', 'New York, NY 11430']},
#    'phone': '+12128069000',
#    'display_phone': '(212) 806-9000',
#    'distance': 19414.3291904214},
#   {'id': 'I95JZecBIM6fhvc-VpAE6w',
#    'alias': 'fairfield-inn-and-suites-new-york-manhattan-downtown-east-new-york',
#    'name': 'Fairfield Inn & Suites New York Manhattan/Downtown East',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lfCe0_J0AZ3UgdlPCnaR_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fairfield-inn-and-suites-new-york-manhattan-downtown-east-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7134506117767,
#     'longitude': -73.9929011464119},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '95 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['95 Henry St', 'New York, NY 10002']},
#    'phone': '+12122270709',
#    'display_phone': '(212) 227-0709',
#    'distance': 897.8970891545117},
#   {'id': 'AfhgLmyOTHTM44PIiYKTHQ',
#    'alias': 'kleinfeld-hotel-blocks-new-york',
#    'name': 'Kleinfeld Hotel Blocks',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/a1fe1_bOJyKcQL_cgVdWZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kleinfeld-hotel-blocks-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 125,
#    'categories': [{'alias': 'travelservices', 'title': 'Travel Services'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74127, 'longitude': -73.99499},
#    'transactions': [],
#    'location': {'address1': '110 W 20th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['110 W 20th St', 'New York, NY 10011']},
#    'phone': '+19088990211',
#    'display_phone': '(908) 899-0211',
#    'distance': 3971.5708483577405},
#   {'id': 'REM4TB-l7gTMRs7uv9QEWQ',
#    'alias': 'the-local-hostel-long-island-city-3',
#    'name': 'The Local Hostel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/l1rhE9RfIneCex5xdjENyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-local-hostel-long-island-city-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'hostels', 'title': 'Hostels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7495386, 'longitude': -73.9479673},
#    'transactions': [],
#    'location': {'address1': '1302 44th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1302 44th Ave', 'Long Island City, NY 11101']},
#    'phone': '+13477385251',
#    'display_phone': '(347) 738-5251',
#    'distance': 6267.227873067181},
#   {'id': 'wVVpqD__PLyaep7ND4GA8g',
#    'alias': 'oasis-motel-bronx',
#    'name': 'Oasis Motel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EOlrDdlmgSOCGuKIeZQQKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oasis-motel-bronx?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.88164, 'longitude': -73.83856},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '3801 Boston Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10466',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3801 Boston Rd', 'Bronx, NY 10466']},
#    'phone': '+17182313300',
#    'display_phone': '(718) 231-3300',
#    'distance': 23560.430901934826},
#   {'id': 'tpxMTuzDG42JuXK5phmxMQ',
#    'alias': 'the-langham-new-york-fifth-avenue-new-york',
#    'name': 'The Langham, New York, Fifth Avenue',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7Rat2rTLUnSuVZxSTR_LCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-langham-new-york-fifth-avenue-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 111,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7501, 'longitude': -73.98381},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '400 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['400 5th Ave', 'New York, NY 10018']},
#    'phone': '+12126954005',
#    'display_phone': '(212) 695-4005',
#    'distance': 5041.061936453574}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nych2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Hotel": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                                                Hotel    Type Price Rating  \
# 0                                          SIXTY LES  Hotels   $$$    2.5
# 1                              Moxy NYC East Village  Hotels
# 2                                The High Line Hotel  Hotels   $$$    3.5
# 3                                Soho House New York  Hotels   $$$    3.5
# 4  Fairfield Inn & Suites New York Midtown Manhat...  Hotels    $$      4
#
#          Address        Lat        Lng  \
# 0   190 Allen St  40.722116 -73.988653
# 1  112 E 11th St  40.731601 -73.989509
# 2   180 10th Ave  40.745962 -74.004993
# 3  29-35 9th Ave  40.740637 -74.005923
# 4  325 W 33rd St  40.752172 -73.995166
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/sixty-les-new-york-2?...  wxKyslbI99ESDbQnns-RSg
# 1
# 2  https://www.yelp.com/biz/the-high-line-hotel-n...  2_ehPnf8YEaDGAzenLYnrQ
# 3  https://www.yelp.com/biz/soho-house-new-york-n...  FqRul4l8Vea_b1x6ggRrJw
# 4  https://www.yelp.com/biz/fairfield-inn-and-sui...  JLoLYfqWvcOPIUfxu48qbQ

# %%
#3rd set of 50 records 101-150
nych_params3 = {"term":"hotel","location":"New York","limit":50,"offset":101}
nych_response3 = requests.get(search_api_url, headers=headers, params=nych_params3)
nych3 = nych_response3.json()
display(nych3)
#print(nych_response3.url)
#print(nych_response3.status_code)
# Out:
# {'businesses': [{'id': '7OFXPjl-7kI2d4Tji6QjMw',
#    'alias': 'freehand-new-york-new-york-3',
#    'name': 'Freehand New York',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7lXqjmDojYXsDadUB278uA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/freehand-new-york-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 170,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7395562, 'longitude': -73.9845026},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '23 Lexington Avenue',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23 Lexington Avenue', 'New York, NY 10010']},
#    'phone': '+12124751920',
#    'display_phone': '(212) 475-1920',
#    'distance': 3909.1744484207916},
#   {'id': 'AWOfrU0MdDMZzIWL3uGTYQ',
#    'alias': 'moderhaus-soho-new-york',
#    'name': 'Moderhaus SoHo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/odlJYaW0_IpTMQGxWJ0NQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moderhaus-soho-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 151,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.72268, 'longitude': -74.0048},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '27 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27 Grand St', 'New York, NY 10013']},
#    'phone': '+12124652000',
#    'display_phone': '(212) 465-2000',
#    'distance': 2116.031928606745},
#   {'id': 'H55p2gOiiwOiz2jQ8Syj9g',
#    'alias': 'haven-motel-rego-park-3',
#    'name': 'Haven Motel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/62nqdN0yI4saZ2ikeRGPaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/haven-motel-rego-park-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 40.715418, 'longitude': -73.860051},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '6805 Woodhaven Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6805 Woodhaven Blvd', 'Rego Park, NY 11374']},
#    'phone': '+17184591313',
#    'display_phone': '(718) 459-1313',
#    'distance': 11369.139374172304},
#   {'id': '1RB0izXOTPJs17dTE9Uwtg',
#    'alias': 'ramada-by-wyndham-bronx-bronx',
#    'name': 'Ramada by Wyndham Bronx',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iUeSIi1Xp_U981G9kl1DLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramada-by-wyndham-bronx-bronx?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.879948, 'longitude': -73.831483},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1000 Baychester Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10475',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1000 Baychester Ave', 'Bronx, NY 10475']},
#    'phone': '+18002521709',
#    'display_phone': '(800) 252-1709',
#    'distance': 23756.256628872983},
#   {'id': 'wr4yApe97nqETNqJJMrHsg',
#    'alias': 'the-pierre-new-york-5',
#    'name': 'The Pierre',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eJak5Q9SIa6z9OAZ069idw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pierre-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 153,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.765242, 'longitude': -73.972014},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '2 E 61st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2 E 61st St', 'New York, NY 10065']},
#    'phone': '+12128388000',
#    'display_phone': '(212) 838-8000',
#    'distance': 6909.026408576066},
#   {'id': 'm2eKA1AJTc47YpErc-ikhA',
#    'alias': 'courtyard-new-york-manhattan-midtown-east-new-york-6',
#    'name': 'Courtyard by Marriott New York Manhattan/Midtown East',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_VxAzYseqkUw7amBVltnfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/courtyard-new-york-manhattan-midtown-east-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 158,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7574547612934,
#     'longitude': -73.9699241362457},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '866 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['866 3rd Ave', 'New York, NY 10022']},
#    'phone': '+12126441300',
#    'display_phone': '(212) 644-1300',
#    'distance': 6136.9396514916225},
#   {'id': 'NIpWK8ncyIz-ZhT_swINtQ',
#    'alias': 'the-artezen-new-york',
#    'name': 'The Artezen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nJIJTwkotASRZqnslRUYtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-artezen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70964, 'longitude': -74.00869},
#    'transactions': [],
#    'location': {'address1': '24 John St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 John St', 'New York, NY 10038']},
#    'phone': '+12125665511',
#    'display_phone': '(212) 566-5511',
#    'distance': 1301.1804348159587},
#   {'id': '6QV90tGuU3go2NtUMQJ4kg',
#    'alias': 'hotel-onyx-new-york',
#    'name': 'Hotel Onyx',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/abJDOImwmjY3Ny38QA72tA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-onyx-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.76097, 'longitude': -73.99906},
#    'transactions': [],
#    'location': {'address1': '610 42nd',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['610 42nd', 'New York, NY 10036']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6170.6115594181465},
#   {'id': 'JkG2GeXceILNzz2FvTZopQ',
#    'alias': 'residence-inn-by-marriot-weehawken-port-imperial-weehawken',
#    'name': 'Residence Inn By Marriot Weehawken Port Imperial',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6DESoid6El7qarANSwwz2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/residence-inn-by-marriot-weehawken-port-imperial-weehawken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7777164892959,
#     'longitude': -74.0113274353321},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '100 Ferry Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Weehawken',
#     'zip_code': '07086',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['100 Ferry Blvd', 'Weehawken, NJ 07086']},
#    'phone': '+12017587922',
#    'display_phone': '(201) 758-7922',
#    'distance': 8163.362348422211},
#   {'id': 'NUPSfXetWw2TaQSOfSqOWw',
#    'alias': 'arthouse-hotel-new-york-city-new-york-2',
#    'name': 'ArtHouse Hotel New York City',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UJ4adefbUeyEkTcAySRwwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arthouse-hotel-new-york-city-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 275,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7822024522958,
#     'longitude': -73.9802998214264},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2178 Broadway W 77th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2178 Broadway W 77th St', 'New York, NY 10024']},
#    'phone': '+18005097598',
#    'display_phone': '(800) 509-7598',
#    'distance': 8616.074303872261},
#   {'id': '02vF5JJNEsx0Z0Ala3EGHw',
#    'alias': 'hilton-brooklyn-new-york-brooklyn',
#    'name': 'Hilton Brooklyn New York',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ixfxUYB1ZMya_DCaDQ-u7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hilton-brooklyn-new-york-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.6896167, 'longitude': -73.9879725},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '140 Schermerhorn St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['140 Schermerhorn St', 'Brooklyn, NY 11201']},
#    'phone': '+17188348800',
#    'display_phone': '(718) 834-8800',
#    'distance': 1838.9054586347079},
#   {'id': 'OxjMJ0ij4QpPEbB8HkEnng',
#    'alias': 'equinox-hotel-new-york-new-york',
#    'name': 'Equinox Hotel New York',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JcAZ8tEbrJ_i2ZXlJDlMZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/equinox-hotel-new-york-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7546506, 'longitude': -74.0022128},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '33 Hudson Yards',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33 Hudson Yards', 'New York, NY 10001']},
#    'phone': '+12128129200',
#    'display_phone': '(212) 812-9200',
#    'distance': 5511.96714456897},
#   {'id': '3gHIMcUaeQHesJhYPbXjfg',
#    'alias': 'the-allen-hotel-new-york',
#    'name': 'The Allen Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/c6SsPCMqQ1E1HkPR8E3_Jw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-allen-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71806, 'longitude': -73.99069},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '88 Allen St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['88 Allen St', 'New York, NY 10002']},
#    'phone': '+12129658898',
#    'display_phone': '(212) 965-8898',
#    'distance': 1439.75184779136},
#   {'id': 'TC1JC87pTCiySadVkU__rw',
#    'alias': 'redford-hotel-new-york',
#    'name': 'Redford Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xprGUx6-Bcvl8I8nnJk2WA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/redford-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.720291, 'longitude': -73.987979},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '136 Ludlow St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136 Ludlow St', 'New York, NY 10002']},
#    'phone': '+12122604141',
#    'display_phone': '(212) 260-4141',
#    'distance': 1734.476631318223},
#   {'id': 'lot1WtUC2qYsCuL7QMgq0A',
#    'alias': 'kimpton-hotel-eventi-new-york',
#    'name': 'Kimpton Hotel Eventi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jsl9iYz-g4dwXRqtP-TBSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kimpton-hotel-eventi-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 428,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'wedding_planning', 'title': 'Wedding Planning'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74703, 'longitude': -73.99003},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '851 Avenue Of The Americas',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['851 Avenue Of The Americas', 'New York, NY 10001']},
#    'phone': '+12125644567',
#    'display_phone': '(212) 564-4567',
#    'distance': 4658.722885570373},
#   {'id': 'ZvjXuv2Utn0hvLp39JkcHw',
#    'alias': 'park-south-hotel-new-york-2',
#    'name': 'Park South Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/khchf11_loXMkiFTKsI-pw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/park-south-hotel-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 128,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74279, 'longitude': -73.98306},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '124 E 28th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['124 E 28th St', 'New York, NY 10016']},
#    'phone': '+12124480888',
#    'display_phone': '(212) 448-0888',
#    'distance': 4259.211427572513},
#   {'id': 'yVEvEPSjZps0lgLskPbKgA',
#    'alias': 'loop-inn-motel-avenel',
#    'name': 'Loop Inn Motel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NF2IPU3LI8C0U-fL1sgxyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/loop-inn-motel-avenel?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.588406, 'longitude': -74.2792816},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1 Rodgers St',
#     'address2': '',
#     'address3': '',
#     'city': 'Avenel',
#     'zip_code': '07001',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1 Rodgers St', 'Avenel, NJ 07001']},
#    'phone': '+17323963500',
#    'display_phone': '(732) 396-3500',
#    'distance': 27339.923903391416},
#   {'id': 'eCrXqqroKfurPmxUVDXQOw',
#    'alias': 'carlton-arms-hotel-new-york-2',
#    'name': 'Carlton Arms Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7TPukps6uMjIlEzZ-8DwHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carlton-arms-hotel-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 67,
#    'categories': [{'alias': 'hostels', 'title': 'Hostels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7402, 'longitude': -73.98268},
#    'transactions': [],
#    'location': {'address1': '160 E 25th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['160 E 25th St', 'New York, NY 10010']},
#    'phone': '+12126790680',
#    'display_phone': '(212) 679-0680',
#    'distance': 3967.001637482176},
#   {'id': 'O4S2ZhhQ674R1aCVpP7bHw',
#    'alias': 'ravel-hotel-long-island-city-2',
#    'name': 'Ravel Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Nc2P-TEre7BTCbweKx40BA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ravel-hotel-long-island-city-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 336,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.753908, 'longitude': -73.949414},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8-08 Queens Plz S',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8-08 Queens Plz S', 'Long Island City, NY 11101']},
#    'phone': '+17182896101',
#    'display_phone': '(718) 289-6101',
#    'distance': 6583.360045675447},
#   {'id': 'uztSHCtNQi_d_5rkN2J7hQ',
#    'alias': 'hotel-17-new-york',
#    'name': 'Hotel 17',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vWo9Gvoi2WngGLo85ZiYfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-17-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 99,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73481, 'longitude': -73.98463},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '225 E 17th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['225 E 17th St', 'New York, NY 10003']},
#    'phone': '+12124752845',
#    'display_phone': '(212) 475-2845',
#    'distance': 3384.852178322063},
#   {'id': 'qd1r5XSyC4TZSYqywfjZAw',
#    'alias': 'madison-les-hotel-new-york',
#    'name': 'Madison Les Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bCwDtyZq1i9jhFRO9fJn6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/madison-les-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71223, 'longitude': -73.99269},
#    'transactions': [],
#    'location': {'address1': '154 Madison St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['154 Madison St', 'New York, NY 10002']},
#    'phone': '+12123901533',
#    'display_phone': '(212) 390-1533',
#    'distance': 764.6675450491147},
#   {'id': 'PkJjSD067n6o9nnmyWNtQQ',
#    'alias': 'aloft-new-york-brooklyn-brooklyn',
#    'name': 'Aloft New York Brooklyn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CvNpGqsf-2851GdupuL4fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aloft-new-york-brooklyn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 200,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.69171, 'longitude': -73.98453},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '216 Duffield St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['216 Duffield St', 'Brooklyn, NY 11201']},
#    'phone': '+17182563833',
#    'display_phone': '(718) 256-3833',
#    'distance': 1740.2376557793812},
#   {'id': 'suTjDG7xDpA2-t64SbldXw',
#    'alias': 'the-williamsburg-hotel-restaurant-brooklyn',
#    'name': 'The Williamsburg Hotel Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yHRnE3ma9B_Jt28wBZuiqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-williamsburg-hotel-restaurant-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72161, 'longitude': -73.95884},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '96 Wythe Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['96 Wythe Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17183628100',
#    'display_phone': '(718) 362-8100',
#    'distance': 3482.3114127242716},
#   {'id': 'b1zHJAiukUDnCkyeil7hOQ',
#    'alias': 'hotel-mulberry-new-york',
#    'name': 'Hotel Mulberry',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/inefg45lfQn2zfK9LXwK8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-mulberry-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 80,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7152699, 'longitude': -73.9995},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '52 Mulberry St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['52 Mulberry St', 'New York, NY 10013']},
#    'phone': '+12123854633',
#    'display_phone': '(212) 385-4633',
#    'distance': 1166.2886853804832},
#   {'id': '5E_rrcPGRBf8LZ8ukFH_jw',
#    'alias': 'surrey-hotels-corporation-new-york',
#    'name': 'Surrey Hotels Corporation',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mrj_Wv4KkDnX55yzHAlx5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/surrey-hotels-corporation-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.73459, 'longitude': -73.9909799},
#    'transactions': [],
#    'location': {'address1': '853 Broadway',
#     'address2': 'Ste 1208',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['853 Broadway', 'Ste 1208', 'New York, NY 10003']},
#    'phone': '+12126149159',
#    'display_phone': '(212) 614-9159',
#    'distance': 3258.191094610409},
#   {'id': 'sY7loHhOtarkEVk_TKb55A',
#    'alias': 'hotel-bliss-new-york',
#    'name': 'Hotel Bliss',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LXHGs6Bz-YfosoMHzlMOWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-bliss-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6640522181988,
#     'longitude': -73.8773133605719},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2330 Linden Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11208',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2330 Linden Blvd', 'New York, NY 11208']},
#    'phone': '+17182725564',
#    'display_phone': '(718) 272-5564',
#    'distance': 10891.216239318535},
#   {'id': '3w99VRJHB0vIHbD6jz1kMg',
#    'alias': 'walker-hotel-tribeca-new-york',
#    'name': 'Walker Hotel Tribeca',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sdN1Z6EpEkY0_XZe8xFtkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/walker-hotel-tribeca-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7184170724422,
#     'longitude': -74.0022848660658},
#    'transactions': [],
#    'location': {'address1': '77 Walker St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['77 Walker St', 'New York, NY 10013']},
#    'phone': '+12127358000',
#    'display_phone': '(212) 735-8000',
#    'distance': 1591.9641624453168},
#   {'id': '55Ofcjm1DPf4LVr73-4-1g',
#    'alias': 'new-york-marriott-marquis-new-york-3',
#    'name': 'New York Marriott Marquis',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3Demjprdbvrk0YGMpbvSUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-york-marriott-marquis-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1004,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7585862119401,
#     'longitude': -73.9858202037049},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1535 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1535 Broadway', 'New York, NY 10036']},
#    'phone': '+12123981900',
#    'display_phone': '(212) 398-1900',
#    'distance': 5952.014665411043},
#   {'id': '4AFrLwxm4J_P7TRuCnOzIQ',
#    'alias': 'fairfield-inn-and-suites-by-marriott-new-york-brooklyn-brooklyn-2',
#    'name': 'Fairfield Inn & Suites By Marriott New York Brooklyn',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6-BAXaugleqyT1LhShTm6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fairfield-inn-and-suites-by-marriott-new-york-brooklyn-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 89,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.680546, 'longitude': -73.9833963141064},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '181 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['181 3rd Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17185224000',
#    'display_phone': '(718) 522-4000',
#    'distance': 2917.0724725936857},
#   {'id': 'Nk71FN4OCa_yVpI0cFuVyg',
#    'alias': 'hotel-lyn-brooklyn',
#    'name': 'Hotel Lyn',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/42DF_oveRfScgYN88yOIGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-lyn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'homelessshelters', 'title': 'Homeless Shelters'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67333, 'longitude': -73.98908},
#    'transactions': [],
#    'location': {'address1': '399 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['399 3rd Ave', 'Brooklyn, NY 11215']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3597.9504842463293},
#   {'id': 'AmmZlCjViVXTg3HN2VgVhA',
#    'alias': 'ny-moore-hostel-brooklyn',
#    'name': 'NY Moore Hostel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/G5TgPC48Kh-r-_wHYnpnMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ny-moore-hostel-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'hostels', 'title': 'Hostels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.704157948494,
#     'longitude': -73.9376416057348},
#    'transactions': [],
#    'location': {'address1': '179 Moore St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['179 Moore St', 'Brooklyn, NY 11206']},
#    'phone': '+13472278634',
#    'display_phone': '(347) 227-8634',
#    'distance': 4777.563582028344},
#   {'id': 'nzv7QCUPH-QKzNHfUnsN8w',
#    'alias': 'henry-norman-hotel-greenpoint',
#    'name': 'Henry Norman Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/50xrXJUKY4guuK4FjS5r0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/henry-norman-hotel-greenpoint?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7280006, 'longitude': -73.9442368},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '251 N Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Greenpoint',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['251 N Henry St', 'Greenpoint, NY 11222']},
#    'phone': '+17186632100',
#    'display_phone': '(718) 663-2100',
#    'distance': 4916.802453853238},
#   {'id': 'i-xQaCux-7E4JKXBa6RRyA',
#    'alias': 'the-mark-hotel-bar-new-york',
#    'name': 'The Mark Hotel Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/21bpKhfoC9Dyp8YANHuc5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mark-hotel-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7752785362952,
#     'longitude': -73.9633958441275},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '25 E 77th',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 E 77th', 'New York, NY 10075']},
#    'phone': '+12127444300',
#    'display_phone': '(212) 744-4300',
#    'distance': 8189.84031944342},
#   {'id': 'h4D1mJ_Jk1w9cozXT2ERMQ',
#    'alias': 'hotel-indigo-williamsburg-brooklyn-brooklyn',
#    'name': 'Hotel Indigo Williamsburg - Brooklyn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tXPhbL97OY_XU-M_m0Nzug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-indigo-williamsburg-brooklyn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.7138775705954,
#     'longitude': -73.9522615169777},
#    'transactions': [],
#    'location': {'address1': '500 Metropolitan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['500 Metropolitan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17185772525',
#    'display_phone': '(718) 577-2525',
#    'distance': 3664.770532800147},
#   {'id': 'ZDp1ysOVW3xQJc4SuQGSCg',
#    'alias': 'archer-hotel-new-york-new-york',
#    'name': 'Archer Hotel New York',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DHoRp4eZBJMu8WH5y2GuJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/archer-hotel-new-york-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 198,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.752053, 'longitude': -73.9847066},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '45 W 38th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 W 38th St', 'New York, NY 10018']},
#    'phone': '+12127194100',
#    'display_phone': '(212) 719-4100',
#    'distance': 5245.161119608879},
#   {'id': 'M_maGjSpjGUv_zO_ySIMGw',
#    'alias': 'holiday-inn-brooklyn-downtown-brooklyn-3',
#    'name': 'Holiday Inn Brooklyn Downtown',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/caAgtLZ4GhVAVXRCmSf_gA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holiday-inn-brooklyn-downtown-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.68749404547364,
#     'longitude': -73.98267891987635},
#    'transactions': [],
#    'location': {'address1': '300 Schermerhorn St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['300 Schermerhorn St', 'Brooklyn, NY 11217']},
#    'phone': '+17186242211',
#    'display_phone': '(718) 624-2211',
#    'distance': 2223.260956544443},
#   {'id': 'wiskeP0gLzntDeBHLyk1mw',
#    'alias': 'americana-inn-new-york-4',
#    'name': 'Americana Inn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wgWJRnNsPsrQZu6YDEapeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/americana-inn-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 52,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.75223, 'longitude': -73.98551},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '69 W 38th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['69 W 38th St', 'New York, NY 10018']},
#    'phone': '+12128406700',
#    'display_phone': '(212) 840-6700',
#    'distance': 5261.089092186237},
#   {'id': '29qq6ZOCfxXb7TZ7W5UslQ',
#    'alias': 'kimpton-ink48-hotel-new-york',
#    'name': 'Kimpton Ink48 Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JfcMu3XQYgXy0SFjhoMYmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kimpton-ink48-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 499,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'wedding_planning', 'title': 'Wedding Planning'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76452, 'longitude': -73.99586},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '653 11th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['653 11th Ave', 'New York, NY 10036']},
#    'phone': '+12127570088',
#    'display_phone': '(212) 757-0088',
#    'distance': 6576.534446741705},
#   {'id': 'rEA0QUAZex8fVh_UhMx83Q',
#    'alias': 'holiday-inn-express-new-york-brooklyn-brooklyn-7',
#    'name': 'Holiday Inn Express New York-Brooklyn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8vI-B2pPadZ4pvQ6LSaY0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holiday-inn-express-new-york-brooklyn-brooklyn-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 89,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.687546, 'longitude': -73.982412},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '625 Union St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['625 Union St', 'Brooklyn, NY 11215']},
#    'phone': '+17186242211',
#    'display_phone': '(718) 624-2211',
#    'distance': 2228.100644397193},
#   {'id': '2v7nK-2QnwwlDBwA_s3Bxw',
#    'alias': 'franklin-guesthouse-brooklyn',
#    'name': 'Franklin Guesthouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vJ6wQJkhbX8A3BwzJsYnBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/franklin-guesthouse-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.733066, 'longitude': -73.957824},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '214 Franklin St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['214 Franklin St', 'Brooklyn, NY 11222']},
#    'phone': '+17183833900',
#    'display_phone': '(718) 383-3900',
#    'distance': 4342.138145575628},
#   {'id': 'NYKUI__MUh0Gh4QYmrt98w',
#    'alias': 'phoenix-hotel-brooklyn',
#    'name': 'Phoenix Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Q6vhZtIVVTP5iO64n-phQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/phoenix-hotel-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 40.6510124, 'longitude': -74.0032181},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '517 39th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11232',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['517 39th St', 'Brooklyn, NY 11232']},
#    'phone': '+19293878270',
#    'display_phone': '(929) 387-8270',
#    'distance': 6099.220371082526},
#   {'id': 'C56chiGa56B-hwM4JYS4BA',
#    'alias': 'the-ritz-carlton-new-york-central-park-new-york-2',
#    'name': 'The Ritz-Carlton New York, Central Park',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/E_VJ2qygkWFR_M8hxWDHZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ritz-carlton-new-york-central-park-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 159,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76525, 'longitude': -73.97604},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '50 Central Park S',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['50 Central Park S', 'New York, NY 10019']},
#    'phone': '+12123089100',
#    'display_phone': '(212) 308-9100',
#    'distance': 6832.839223907516},
#   {'id': 'j3wayJ0tNwVHVwgyAx6NdQ',
#    'alias': 'bowery-grand-hotel-new-york',
#    'name': 'Bowery Grand Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WiaF10-MkYb4F7x7ySUoOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bowery-grand-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.7191331533521,
#     'longitude': -73.9945376754561},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '143 Bowery',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['143 Bowery', 'New York, NY 10002']},
#    'phone': '+12122266655',
#    'display_phone': '(212) 226-6655',
#    'distance': 1522.2060502694671},
#   {'id': '5YpMlQZEsCYcz5gAtrZOmQ',
#    'alias': 'hotel-indigo-brooklyn-brooklyn',
#    'name': 'Hotel Indigo Brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jvpUmhITd5xVH07jOpIn0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-indigo-brooklyn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 171,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.691251, 'longitude': -73.984102},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '229 Duffield St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['229 Duffield St', 'Brooklyn, NY 11201']},
#    'phone': '+17182547800',
#    'display_phone': '(718) 254-7800',
#    'distance': 1796.9733532502842},
#   {'id': 'SbuI8AUmVYQg9AZCg8G9AA',
#    'alias': 'allegria-hotel-long-beach',
#    'name': 'Allegria Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KEz_rGlAU7zG6qHnFrW1_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/allegria-hotel-long-beach?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 496,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.584327, 'longitude': -73.666413},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '80 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Beach',
#     'zip_code': '11561',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 W Broadway', 'Long Beach, NY 11561']},
#    'phone': '+15168891300',
#    'display_phone': '(516) 889-1300',
#    'distance': 30767.47822371708},
#   {'id': '03EFU3OR6j085vqGAXwVbA',
#    'alias': 'gild-hall-a-thompson-hotel-new-york-4',
#    'name': 'Gild Hall, A Thompson Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cVdthjZkG95IPlchph7ziQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gild-hall-a-thompson-hotel-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 235,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7078, 'longitude': -74.00694},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '15 Gold St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Gold St', 'New York, NY 10038']},
#    'phone': '+12122327700',
#    'display_phone': '(212) 232-7700',
#    'distance': 1115.3484069613505},
#   {'id': 'eVBVn6bjwl_mMLxN-35_6w',
#    'alias': 'hotel-chantelle-new-york',
#    'name': 'Hotel Chantelle',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AsKzBSxeqcb7MDFHuH6zjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-chantelle-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1422,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71843, 'longitude': -73.98909},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '92 Ludlow St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['92 Ludlow St', 'New York, NY 10002']},
#    'phone': '+12122549100',
#    'display_phone': '(212) 254-9100',
#    'distance': 1507.1993260477182},
#   {'id': 'LjHUOXB3Iw_l7NXW_nClqA',
#    'alias': 'fairfield-inn-by-marriott-new-york-manhattan-financial-district-new-york',
#    'name': 'Fairfield Inn by Marriott New York Manhattan/Financial District',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZsDrkqDzS1wehH8zY3uE7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fairfield-inn-by-marriott-new-york-manhattan-financial-district-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 76,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.705911, 'longitude': -74.004993},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '161 Front St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['161 Front St', 'New York, NY 10038']},
#    'phone': '+12128260001',
#    'display_phone': '(212) 826-0001',
#    'distance': 903.4096814918291},
#   {'id': 'hLwqr_sSzSAMIppEHcz4cQ',
#    'alias': 'four-points-by-sheraton-new-york-downtown-new-york',
#    'name': 'Four Points by Sheraton New York Downtown',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yN1ZiTIHtnn6WZy11GlxYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/four-points-by-sheraton-new-york-downtown-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 82,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.70747657865638,
#     'longitude': -74.00640093846745},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '6 Platt St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6 Platt St', 'New York, NY 10038']},
#    'phone': '+12122739388',
#    'display_phone': '(212) 273-9388',
#    'distance': 1045.2947002494336},
#   {'id': 'ndFfq-ZjPbR-X8YCpQOS1g',
#    'alias': 'the-one-boutique-hotel-flushing',
#    'name': 'The One Boutique Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZGGMQBWOb3WNbsdTa-ORGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-one-boutique-hotel-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.7635219, 'longitude': -73.8283762},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '137-72 Northern Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['137-72 Northern Blvd', 'Flushing, NY 11354']},
#    'phone': '+17188863555',
#    'display_phone': '(718) 886-3555',
#    'distance': 15399.181958868565}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nych3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        try:
            title3.append(i["categories"][0]["title"])
        except(KeyError,IndexError):
            title3.append("")
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        #title3.append("")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Hotel": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                      Hotel    Type Price Rating              Address  \
# 0        Freehand New York  Hotels    $$    3.5  23 Lexington Avenue
# 1           Moderhaus SoHo  Hotels   $$$      3          27 Grand St
# 2              Haven Motel  Hotels     $    1.5  6805 Woodhaven Blvd
# 3  Ramada by Wyndham Bronx  Hotels     $      3  1000 Baychester Ave
# 4               The Pierre  Hotels  $$$$      4          2 E 61st St
#
#          Lat        Lng                                                url  \
# 0  40.739556 -73.984503  https://www.yelp.com/biz/freehand-new-york-new...
# 1  40.722680 -74.004800  https://www.yelp.com/biz/moderhaus-soho-new-yo...
# 2  40.715418 -73.860051  https://www.yelp.com/biz/haven-motel-rego-park...
# 3  40.879948 -73.831483  https://www.yelp.com/biz/ramada-by-wyndham-bro...
# 4  40.765242 -73.972014  https://www.yelp.com/biz/the-pierre-new-york-5...
#
#                        ID
# 0  7OFXPjl-7kI2d4Tji6QjMw
# 1  AWOfrU0MdDMZzIWL3uGTYQ
# 2  H55p2gOiiwOiz2jQ8Syj9g
# 3  1RB0izXOTPJs17dTE9Uwtg
# 4  wr4yApe97nqETNqJJMrHsg

# %%
#4th set of 50 records 151-200
nych_params4 = {"term":"hotel","location":"New York","limit":50,"offset":151}
nych_response4 = requests.get(search_api_url, headers=headers, params=nych_params4)
nych4 = nych_response4.json()
display(nych4)
#print(nych_response4.url)
#print(nych_response4.status_code)
# Out:
# {'businesses': [{'id': 'PmmTXis1gCL34mg2bZ9gtw',
#    'alias': 'pod-51-new-york',
#    'name': 'Pod 51',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6WijQIUhk4j2qlKlcVn4EQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pod-51-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 479,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7558617771518,
#     'longitude': -73.9691277840614},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '230 E 51st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['230 E 51st St', 'New York, NY 10022']},
#    'phone': '+18447637666',
#    'display_phone': '(844) 763-7666',
#    'distance': 5993.729613144301},
#   {'id': 'zofvKgVX3j4fdypKB5dCqg',
#    'alias': 'bronx-park-motel-bronx',
#    'name': 'Bronx Park Motel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5N1H4nvVMfkvO1vxlRb_tA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bronx-park-motel-bronx?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 40.856629, 'longitude': -73.881874},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2500 Crotona Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10458',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2500 Crotona Ave', 'Bronx, NY 10458']},
#    'phone': '+17189332000',
#    'display_phone': '(718) 933-2000',
#    'distance': 19286.60181142682},
#   {'id': 'S552XBLEOFsT-efRQuNXDg',
#    'alias': 'made-new-york-3',
#    'name': 'MADE',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dKTW7UEzuyyhs9EkI2UriQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/made-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.746296, 'longitude': -73.989638},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '42 W 29th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 W 29th St', 'New York, NY 10001']},
#    'phone': '+12122134429',
#    'display_phone': '(212) 213-4429',
#    'distance': 4559.341380087598},
#   {'id': 'onKBo1qul0Pq27E5pVMAxA',
#    'alias': 'the-mark-hotel-new-york',
#    'name': 'The Mark Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mjABBDfLMO9zmIYqxDmJUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mark-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77526, 'longitude': -73.96347},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '25 E 77th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 E 77th St', 'New York, NY 10075']},
#    'phone': '+12127444300',
#    'display_phone': '(212) 744-4300',
#    'distance': 8197.803125927974},
#   {'id': 'T8hRtRz3Q50VC8DX9NRfDg',
#    'alias': 'the-st-regis-new-york-new-york',
#    'name': 'The St. Regis New York',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ExT6hk0d3j44KO-rogWfog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-st-regis-new-york-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 212,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76136, 'longitude': -73.97443},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': 'Two East 55th Street At Fifth Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Two East 55th Street At Fifth Ave',
#      'New York, NY 10022']},
#    'phone': '+12127534500',
#    'display_phone': '(212) 753-4500',
#    'distance': 6438.877125929483},
#   {'id': 'FA5giJYhqdTkjsT695TqVg',
#    'alias': 'the-plaza-new-york-2',
#    'name': 'The Plaza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5YypIR3HEHooUaBcrd8QRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-plaza-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 496,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7644638970122,
#     'longitude': -73.97448837025816},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '768 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['768 5th Ave', 'New York, NY 10019']},
#    'phone': '+12127593000',
#    'display_phone': '(212) 759-3000',
#    'distance': 6771.436387625446},
#   {'id': 'LtVO-82pFdwjq-hwMITAPg',
#    'alias': 'yotel-new-york-new-york',
#    'name': 'YOTEL New York',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qx8ug0ZZ0is89GJf96-ofQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yotel-new-york-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1269,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7591568, 'longitude': -73.9954561},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '570 Tenth Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['570 Tenth Ave', 'New York, NY 10036']},
#    'phone': '+16464497700',
#    'display_phone': '(646) 449-7700',
#    'distance': 5973.29182163646},
#   {'id': 'JgJAG4E-r0ZQ-pp_oHBTCg',
#    'alias': 'w-hoboken-hoboken',
#    'name': 'W Hoboken',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6IaIy-mZsdHKdTlHX5goPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/w-hoboken-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 277,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.739509, 'longitude': -74.02771},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '225 River St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['225 River St', 'Hoboken, NJ 07030']},
#    'phone': '+12012532400',
#    'display_phone': '(201) 253-2400',
#    'distance': 4719.907822667599},
#   {'id': 'yZXN-Qj3x81ivd3Lr6Cjbw',
#    'alias': 'orchard-street-hotel-new-york',
#    'name': 'Orchard Street Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MPurA3TJ_-YXmmI8odEwKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/orchard-street-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.72114, 'longitude': -73.98881},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '163 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['163 Orchard St', 'New York, NY 10002']},
#    'phone': '+12128048088',
#    'display_phone': '(212) 804-8088',
#    'distance': 1807.0687175875091},
#   {'id': 'XRt4mVzNQbXkC6mxFl7-Sg',
#    'alias': 'chelsea-pines-inn-new-york',
#    'name': 'Chelsea Pines Inn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mT2SpjDvGk-BWY_woeAxlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chelsea-pines-inn-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.740295, 'longitude': -74.003415},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '317 W 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['317 W 14th St', 'New York, NY 10014']},
#    'phone': '+12129291023',
#    'display_phone': '(212) 929-1023',
#    'distance': 3950.662004359314},
#   {'id': 'o2Hs9Ar8qKBevOXgVJ-tsg',
#    'alias': 'mr-c-seaport-new-york',
#    'name': 'Mr. C Seaport',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/txKUH3IqQGw2Ep9REyPG2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-c-seaport-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70798, 'longitude': -74.00144},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '33 Peck Slip',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33 Peck Slip', 'New York, NY 10038']},
#    'phone': '+18775284249',
#    'display_phone': '(877) 528-4249',
#    'distance': 667.9388505312614},
#   {'id': 'C88DklKzQjYTRic2FqBBBA',
#    'alias': 'condor-hotel-brooklyn',
#    'name': 'Condor Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/priL6RsYxXxOvQ97aIKDig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/condor-hotel-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6975225, 'longitude': -73.9587573},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '56 Franklin Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['56 Franklin Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17185266367',
#    'display_phone': '(718) 526-6367',
#    'distance': 3122.4735510289483},
#   {'id': 'DJyd2GApggTIxCmkjYC8EQ',
#    'alias': 'four-points-by-sheraton-manhattan-soho-village-new-york',
#    'name': 'Four Points by Sheraton Manhattan SoHo Village',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/c-etM_1gtcBBwxDJmd24qA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/four-points-by-sheraton-manhattan-soho-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 160,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72697, 'longitude': -74.00611},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '66 Charlton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['66 Charlton St', 'New York, NY 10014']},
#    'phone': '+12122299988',
#    'display_phone': '(212) 229-9988',
#    'distance': 2588.8002704043392},
#   {'id': '4erImwfLkNUDipUSF4Ocpw',
#    'alias': 'hampton-inn-manhattan-seaport-financial-district-new-york-2',
#    'name': 'Hampton Inn Manhattan-Seaport-Financial District',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hRFpKRnNIUsWnFKChNqL4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hampton-inn-manhattan-seaport-financial-district-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 67,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7092877829272,
#     'longitude': -74.0018302202225},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '320 Pearl St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['320 Pearl St', 'New York, NY 10038']},
#    'phone': '+12125714400',
#    'display_phone': '(212) 571-4400',
#    'distance': 765.6416584594335},
#   {'id': 'vgCV1vNhlbUvj9O1baFNHw',
#    'alias': 'the-times-square-edition-new-york',
#    'name': 'The Times Square EDITION',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JWbba_zsng6Ar3EeDP1oWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-times-square-edition-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.759241, 'longitude': -73.984119},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '701 7th Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['701 7th Ave', 'New York, NY 10036']},
#    'phone': '+12123987017',
#    'display_phone': '(212) 398-7017',
#    'distance': 6045.324952763068},
#   {'id': '1wdNxsW1jqieYmYi0CHlbQ',
#    'alias': 'the-benjamin-new-york-2',
#    'name': 'The Benjamin',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3d0ti5NDoEcXP_5pmyMr_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-benjamin-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 202,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75648, 'longitude': -73.97206},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '125 E 50th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['125 E 50th St', 'New York, NY 10022']},
#    'phone': '+12127152500',
#    'display_phone': '(212) 715-2500',
#    'distance': 5995.184899942683},
#   {'id': 'U11SNuUoE0yay-78CRSRSA',
#    'alias': 'northern-lights-mansion-new-york',
#    'name': 'Northern Lights Mansion',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7QqbsPKu8JH1ZvXVwmtAGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/northern-lights-mansion-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.80717, 'longitude': -73.95064},
#    'transactions': [],
#    'location': {'address1': '210 W 122nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['210 W 122nd St', 'New York, NY 10027']},
#    'phone': '+19176588648',
#    'display_phone': '(917) 658-8648',
#    'distance': 11898.228619921545},
#   {'id': 'wj8fcwbXM2ozE9mmneEwvA',
#    'alias': 'bushwick-hotel-brooklyn',
#    'name': 'Bushwick Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sjjDkBmILUf7xQvCmVMpog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bushwick-hotel-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.709616, 'longitude': -73.939909},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '171 Bushwick Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 Bushwick Ave', 'Brooklyn, NY 11206']},
#    'phone': '+17183661204',
#    'display_phone': '(718) 366-1204',
#    'distance': 4611.261893812134},
#   {'id': 'qOm89V0J44e1j_bCTINWAg',
#    'alias': 'umbrella-hotel-brooklyn-brooklyn',
#    'name': 'Umbrella Hotel Brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hv0ZqSImdDTeIRvBTEy7-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/umbrella-hotel-brooklyn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.631096, 'longitude': -74.002785},
#    'transactions': [],
#    'location': {'address1': '1108 60th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11219',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1108 60th St', 'Brooklyn, NY 11219']},
#    'phone': '+17184352060',
#    'display_phone': '(718) 435-2060',
#    'distance': 8298.56666578474},
#   {'id': 'W3K4-SbrRu54VoyNDCe6SA',
#    'alias': 'the-ridge-new-york',
#    'name': 'The Ridge',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Tegaj4J_HKvIzkQNoGPE_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ridge-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 91,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72287, 'longitude': -73.9894},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '151 E Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['151 E Houston St', 'New York, NY 10002']},
#    'phone': '+12127770012',
#    'display_phone': '(212) 777-0012',
#    'distance': 1982.177237439904},
#   {'id': 'jLW5W45YbQ8nmnymJnUQaA',
#    'alias': 'akwaaba-mansion-bed-and-breakfast-brooklyn',
#    'name': 'Akwaaba Mansion Bed & Breakfast',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YYDnz9w2NTEGiU6nFwaLAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/akwaaba-mansion-bed-and-breakfast-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6825, 'longitude': -73.93267},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '347 MacDonough St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['347 MacDonough St', 'Brooklyn, NY 11233']},
#    'phone': '+17184555958',
#    'display_phone': '(718) 455-5958',
#    'distance': 5789.2012341103455},
#   {'id': 'Dp4d88NqIL_mOYzYmAhY6w',
#    'alias': 'the-mansion-at-glen-cove-glen-cove-3',
#    'name': 'The Mansion at Glen Cove',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CRiGHW7EcWUYwy089_0XBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mansion-at-glen-cove-glen-cove-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 209,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.8855994360105,
#     'longitude': -73.6289216277928},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '200 Dosoris Ln',
#     'address2': None,
#     'address3': '',
#     'city': 'Glen Cove',
#     'zip_code': '11542',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 Dosoris Ln', 'Glen Cove, NY 11542']},
#    'phone': '+15167515622',
#    'display_phone': '(516) 751-5622',
#    'distance': 36705.17596601443},
#   {'id': 'BFmhsIJwAj56zRqDxDJCcw',
#    'alias': 'sheridan-hotel-bronx',
#    'name': 'Sheridan Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/g8y6BIrKddQyOfqWUVwvDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sheridan-hotel-bronx?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 40.8306249489031,
#     'longitude': -73.8844637246357},
#    'transactions': [],
#    'location': {'address1': '1440 Sheridan Expy',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10459',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1440 Sheridan Expy', 'Bronx, NY 10459']},
#    'phone': '+17188616500',
#    'display_phone': '(718) 861-6500',
#    'distance': 16712.184371848358},
#   {'id': 'pi2sOXrCKVpKdPMaSwJ-_Q',
#    'alias': 'the-leon-hotel-new-york-2',
#    'name': 'The Leon Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WIVhPFr-dLvsjr3XtK6ANg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-leon-hotel-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.716076, 'longitude': -73.9952133},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '125 Canal St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['125 Canal St', 'New York, NY 10002']},
#    'phone': '+12123908833',
#    'display_phone': '(212) 390-8833',
#    'distance': 1184.6681061474735},
#   {'id': 'FfdQVbXd9zyMcaOYAqmWZA',
#    'alias': 'the-james-new-york-nomad-new-york',
#    'name': 'The James New York - NoMad',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QzOWLC9_H02gDfjmQ_W7QA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-james-new-york-nomad-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 99,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7446399, 'longitude': -73.98551},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '22 E 29th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 E 29th St', 'New York, NY 10016']},
#    'phone': '+12125324100',
#    'display_phone': '(212) 532-4100',
#    'distance': 4411.720446373483},
#   {'id': '7kktzX2yS2CJhSprfNL3FQ',
#    'alias': 'hotel-mimosa-new-york',
#    'name': 'Hotel Mimosa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oEZ0RlHWlY7K716_up0Urg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-mimosa-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.714145, 'longitude': -73.993789},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '79 Division St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79 Division St', 'New York, NY 10002']},
#    'phone': '+12123434243',
#    'display_phone': '(212) 343-4243',
#    'distance': 967.0938466648173},
#   {'id': 'I59qIIR-1mBYpAhH1-4ESg',
#    'alias': 'sheraton-brooklyn-new-york-brooklyn',
#    'name': 'Sheraton Brooklyn New York',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-MQ1BeD_UWE9qesxUH8hJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sheraton-brooklyn-new-york-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 230,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.69149, 'longitude': -73.98476},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '228 Duffield St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 Duffield St', 'Brooklyn, NY 11201']},
#    'phone': '+17188551900',
#    'display_phone': '(718) 855-1900',
#    'distance': 1750.0176878484292},
#   {'id': 'ZhvXODjL9GeCZ9xAiyZoQQ',
#    'alias': 'inn-at-great-neck-bw-premier-collection-great-neck-2',
#    'name': 'Inn at Great Neck, BW Premier Collection',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aMDr6iXyRb8xxwzR19uDlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/inn-at-great-neck-bw-premier-collection-great-neck-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7863295697179,
#     'longitude': -73.7291890382767},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '30 Cuttermill Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'Great Neck',
#     'zip_code': '11021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30 Cuttermill Rd', 'Great Neck, NY 11021']},
#    'phone': '+15167732000',
#    'display_phone': '(516) 773-2000',
#    'distance': 24076.03057854944},
#   {'id': 'hObG_aqfJDWSBD0IOJwy2g',
#    'alias': 'long-beach-hotel-long-beach',
#    'name': 'Long Beach Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pC53F0x_JqXEBADScP3lZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/long-beach-hotel-long-beach?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 148,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.585109, 'longitude': -73.652076},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '405 E Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Beach',
#     'zip_code': '11561',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['405 E Broadway', 'Long Beach, NY 11561']},
#    'phone': '+15165444444',
#    'display_phone': '(516) 544-4444',
#    'distance': 31830.443185490203},
#   {'id': 'gZFGyZzA1ufuKCbXq5Y12A',
#    'alias': 'hotel-rl-brooklyn-brooklyn',
#    'name': 'Hotel RL Brooklyn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/A3p1Qpjrux0OWSXS_MtFCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-rl-brooklyn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.694313, 'longitude': -73.931017},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1080 Broadway',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1080 Broadway', 'Brooklyn, NY 11221']},
#    'phone': '+17187154850',
#    'display_phone': '(718) 715-4850',
#    'distance': 5476.659431712935},
#   {'id': 'RBHSPpLaalwkAPfF2uJaTw',
#    'alias': 'millennium-hilton-new-york-downtown-new-york-2',
#    'name': 'Millennium Hilton New York Downtown',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8K_8Bt-dRd5_EavEnFsU-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/millennium-hilton-new-york-downtown-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 412,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.711114, 'longitude': -74.010333},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '55 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Church St', 'New York, NY 10007']},
#    'phone': '+12126932001',
#    'display_phone': '(212) 693-2001',
#    'distance': 1491.7335434856168},
#   {'id': 'kGX54tkc0zfT5ZquEPtwuQ',
#    'alias': 'doubletree-by-hilton-hotel-and-suites-jersey-city-jersey-city',
#    'name': 'DoubleTree by Hilton Hotel & Suites Jersey City',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fsr0MSnF27jp2t3pmXOoOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doubletree-by-hilton-hotel-and-suites-jersey-city-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.723598, 'longitude': -74.0365603},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '455 Washington Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07310',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['455 Washington Blvd', 'Jersey City, NJ 07310']},
#    'phone': '+12014992400',
#    'display_phone': '(201) 499-2400',
#    'distance': 4094.4983292789275},
#   {'id': 'KaJGgcBqhU-Oqf0TE9LUeA',
#    'alias': 'aloft-long-island-city-manhattan-view-long-island-city',
#    'name': 'Aloft Long Island City Manhattan View',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/STSqEt7xpEFGcTXbPCZGLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aloft-long-island-city-manhattan-view-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 62,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74838, 'longitude': -73.93983},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '27-45 Jackson Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27-45 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+17184339305',
#    'display_phone': '(718) 433-9305',
#    'distance': 6615.332758762323},
#   {'id': 'yMUedbxLLt7H3gElBxBoEQ',
#    'alias': 'harbor-motor-inn-brooklyn',
#    'name': 'Harbor Motor Inn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t6O4jLu7Z_buu58doIEn8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harbor-motor-inn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.593643, 'longitude': -73.997314},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1730 Shore Pkwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1730 Shore Pkwy', 'Brooklyn, NY 11214']},
#    'phone': '+17189469200',
#    'display_phone': '(718) 946-9200',
#    'distance': 12434.398184076425},
#   {'id': '5U3Kk45q34GBCGcL828ZCw',
#    'alias': 'loews-regency-new-york-hotel-new-york-3',
#    'name': 'Loews Regency New York Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RE_clPbO9OM-BLljo-9bIQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/loews-regency-new-york-hotel-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 95,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.764573, 'longitude': -73.968998},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '540 Park Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['540 Park Ave', 'New York, NY 10065']},
#    'phone': '+12127594100',
#    'display_phone': '(212) 759-4100',
#    'distance': 6911.55407036076},
#   {'id': 'Z4t_Wsmjgi8I5n1xPSQWTA',
#    'alias': 'hotel-on-rivington-new-york-2',
#    'name': 'Hotel on Rivington',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WiQyicuV-qhfuH7lIq-DbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-on-rivington-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 287,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7199, 'longitude': -73.98803},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '107 Rivington St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['107 Rivington St', 'New York, NY 10002']},
#    'phone': '+12124752600',
#    'display_phone': '(212) 475-2600',
#    'distance': 1691.7553670515451},
#   {'id': 'aCruJ1jAhr6iluwWLqP_vw',
#    'alias': 'hampton-inn-manhattan-chelsea-new-york-2',
#    'name': 'Hampton Inn Manhattan-Chelsea',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oZ-4wnQupPl9F3sg1t03Kw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hampton-inn-manhattan-chelsea-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 124,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7436548, 'longitude': -73.9930707},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '108 W 24th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['108 W 24th St', 'New York, NY 10011']},
#    'phone': '+12124141000',
#    'display_phone': '(212) 414-1000',
#    'distance': 4249.995069865843},
#   {'id': 'CBqL0djx1GM69gN0gD2yJw',
#    'alias': 'wyndham-garden-brooklyn-sunset-park-brooklyn',
#    'name': 'Wyndham Garden Brooklyn Sunset Park',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cP5HVR26lLUO_21QZBxxwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wyndham-garden-brooklyn-sunset-park-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.65189, 'longitude': -74.004477},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '457 39th Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11232',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['457 39th Street', 'Brooklyn, NY 11232']},
#    'phone': '+18885959874',
#    'display_phone': '(888) 595-9874',
#    'distance': 6027.980435976473},
#   {'id': 'tsqlRfje_qAX5_nVESC-PQ',
#    'alias': 'renaissance-new-york-midtown-hotel-new-york',
#    'name': 'Renaissance New York Midtown Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YaVzOIBaJcs3UiJgTbJ4ag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/renaissance-new-york-midtown-hotel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 170,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7517557767437,
#     'longitude': -73.9910885742397},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '218 W 35th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['218 W 35th St', 'New York, NY 10001']},
#    'phone': '+12122390014',
#    'display_phone': '(212) 239-0014',
#    'distance': 5156.608170988152},
#   {'id': 'tAPYgQY3GnMFuGAuKkwUfg',
#    'alias': 'hyatt-house-jersey-city-jersey-city',
#    'name': 'Hyatt House Jersey City',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sEtxrN29UFTDaWPehBEpmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hyatt-house-jersey-city-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.7159065309252,
#     'longitude': -74.0339133588955},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'One Exchange Pl',
#     'address2': None,
#     'address3': None,
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['One Exchange Pl', 'Jersey City, NJ 07302']},
#    'phone': '+12013950500',
#    'display_phone': '(201) 395-0500',
#    'distance': 3536.278350626372},
#   {'id': 'SdHhR80AAU_Xr2ZQk-6_rQ',
#    'alias': 'selina-chelsea-new-york-city-new-york',
#    'name': 'Selina Chelsea New York City',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1vQ3wctGJYWe8ZTHvRhlhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/selina-chelsea-new-york-city-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.750424, 'longitude': -74.003409},
#    'transactions': [],
#    'location': {'address1': '518 W 27th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['518 W 27th St', 'New York, NY 10001']},
#    'phone': '+13473427805',
#    'display_phone': '(347) 342-7805',
#    'distance': 5059.03667669132},
#   {'id': 'UReqUKgLehSHPkuWfFMoig',
#    'alias': 'the-carlyle-a-rosewood-hotel-new-york-2',
#    'name': 'The Carlyle, A Rosewood Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eEM6JfNrNFBrwJt_tnwiQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-carlyle-a-rosewood-hotel-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 122,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.77419, 'longitude': -73.96284},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': 'A Rosewood Hotel',
#     'address2': '35 E 76th St',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['A Rosewood Hotel',
#      '35 E 76th St',
#      'New York, NY 10021']},
#    'phone': '+12127441600',
#    'display_phone': '(212) 744-1600',
#    'distance': 8105.487169590931},
#   {'id': 'WsWW63fz5yqWFpAdagb9KQ',
#    'alias': 'hilton-garden-inn-new-york-west-35th-st-new-york',
#    'name': 'Hilton Garden Inn New York West 35th St',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7zqAQT_wlBEEC-2bSV9pqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hilton-garden-inn-new-york-west-35th-st-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 235,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7503679301835,
#     'longitude': -73.9865054190159},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '63 W 35th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63 W 35th St', 'New York, NY 10001']},
#    'phone': '+12125943310',
#    'display_phone': '(212) 594-3310',
#    'distance': 5038.133496896897},
#   {'id': 'a3qXia8QjzuoFFVCje20_g',
#    'alias': 'courtyard-by-marriott-jersey-city-newport-jersey-city',
#    'name': 'Courtyard by Marriott Jersey City Newport',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/A-pSE4H_J6JxsDpiv8nwzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/courtyard-by-marriott-jersey-city-newport-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72770042447187,
#     'longitude': -74.03408214110493},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '540 Washington Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07310',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['540 Washington Blvd', 'Jersey City, NJ 07310']},
#    'phone': '+12016266600',
#    'display_phone': '(201) 626-6600',
#    'distance': 4167.6631204412615},
#   {'id': 'yfCAuHtdlxw-DWK77hIw_A',
#    'alias': 'pelham-garden-motel-bronx-2',
#    'name': 'Pelham Garden Motel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6QLPnhSOHI7zVu_X8mETyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pelham-garden-motel-bronx-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.8618, 'longitude': -73.83059},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1990 E Gun Hill Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10469',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1990 E Gun Hill Rd', 'Bronx, NY 10469']},
#    'phone': '+17183792300',
#    'display_phone': '(718) 379-2300',
#    'distance': 22186.432053998433},
#   {'id': 'qwAUa1tcAJMrn2K7Ynbp8w',
#    'alias': 'courtyard-by-marriott-new-york-manhattan-midtown-west-new-york',
#    'name': 'Courtyard by Marriott New York Manhattan/Midtown West',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Kkr1ghHWxaLJuFGpaB4ESA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/courtyard-by-marriott-new-york-manhattan-midtown-west-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.754698, 'longitude': -73.99865},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '461 West 34th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['461 West 34th St', 'New York, NY 10001']},
#    'phone': '+12125533000',
#    'display_phone': '(212) 553-3000',
#    'distance': 5488.983125324918},
#   {'id': 'kumbWukbwNktxWQB4_FvDQ',
#    'alias': 'courtyard-by-marriott-new-york-manhattan-times-square-west-new-york-2',
#    'name': 'Courtyard by Marriott New York Manhattan/Times Square West',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/03f1QLSPe15o3k9FhYUVnQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/courtyard-by-marriott-new-york-manhattan-times-square-west-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 95,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7544948680992,
#     'longitude': -73.9925694912836},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '307 West 37th Street (West 37th Street & 8th Avenue)',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['307 West 37th Street (West 37th Street & 8th Avenue)',
#      'New York, NY 10018']},
#    'phone': '+12129120009',
#    'display_phone': '(212) 912-0009',
#    'distance': 5456.039141628698},
#   {'id': 'giPwSjP4T0ZkXoygdbNfIA',
#    'alias': 'club-quarters-manhattan',
#    'name': 'Club Quarters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PhDDeDniexUSz2EVdldymw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/club-quarters-manhattan?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 177,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.709846496582,
#     'longitude': -74.0139694213867},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '140 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'Manhattan',
#     'zip_code': '10006',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['140 Washington St', 'Manhattan, NY 10006']},
#    'phone': '+12125771133',
#    'display_phone': '(212) 577-1133',
#    'distance': 1726.6254267281815},
#   {'id': 'Mmvru5hXeRGwBi5f6NC8pA',
#    'alias': 'hyatt-regency-jersey-city-on-the-hudson-jersey-city-3',
#    'name': 'Hyatt Regency Jersey City on the Hudson',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jyFjY3kLXh3PT0TdmHoq7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hyatt-regency-jersey-city-on-the-hudson-jersey-city-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 235,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.717103, 'longitude': -74.031894},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '2 Exchange Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['2 Exchange Pl', 'Jersey City, NJ 07302']},
#    'phone': '+12014691234',
#    'display_phone': '(201) 469-1234',
#    'distance': 3424.1041718039564},
#   {'id': 'tdWg-eGacW6d3XOtbxBX5Q',
#    'alias': 'intercontinental-new-york-barclay-new-york-3',
#    'name': 'InterContinental New York Barclay',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XI4MX8xTqQzI9D0lslr3Xw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/intercontinental-new-york-barclay-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 159,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.755745, 'longitude': -73.973492},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '111 E 48th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 E 48th St', 'New York, NY 10017']},
#    'phone': '+18007828021',
#    'display_phone': '(800) 782-8021',
#    'distance': 5849.690917121183}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nych4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Hotel": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#                     Hotel    Type Price Rating  \
# 0                  Pod 51  Hotels    $$    3.5
# 1        Bronx Park Motel  Hotels     $    1.5
# 2                    MADE  Hotels   $$$      4
# 3          The Mark Hotel  Hotels  $$$$      4
# 4  The St. Regis New York  Hotels  $$$$      4
#
#                              Address        Lat        Lng  \
# 0                      230 E 51st St  40.755862 -73.969128
# 1                   2500 Crotona Ave  40.856629 -73.881874
# 2                       42 W 29th St  40.746296 -73.989638
# 3                       25 E 77th St  40.775260 -73.963470
# 4  Two East 55th Street At Fifth Ave  40.761360 -73.974430
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/pod-51-new-york?adjus...  PmmTXis1gCL34mg2bZ9gtw
# 1  https://www.yelp.com/biz/bronx-park-motel-bron...  zofvKgVX3j4fdypKB5dCqg
# 2  https://www.yelp.com/biz/made-new-york-3?adjus...  S552XBLEOFsT-efRQuNXDg
# 3  https://www.yelp.com/biz/the-mark-hotel-new-yo...  onKBo1qul0Pq27E5pVMAxA
# 4  https://www.yelp.com/biz/the-st-regis-new-york...  T8hRtRz3Q50VC8DX9NRfDg

# %%
nyc_hotels_df = pd.concat([df1,df2,df4], sort=True)
nyc_hotels_df.shape
# Out:
# (150, 9)

# %%
column_order = ["Hotel","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_hotels_df = nyc_hotels_df[column_order]
nyc_hotels_df = nyc_hotels_df.sort_values(["Type"], ascending=True)
nyc_hotels_df = nyc_hotels_df.reset_index(drop=True)
nyc_hotels_df
# Out:
#                                                  Hotel                   Type  \
# 0                 Concrete Jungle at The Tillary Hotel         American (New)
# 1                                     Urban Cowboy B&B        Bed & Breakfast
# 2                              Northern Lights Mansion        Bed & Breakfast
# 3                                     The Local Hostel                Hostels
# 4    Fairfield Inn & Suites New York Manhattan/Down...                 Hotels
# 5                                          Oasis Motel                 Hotels
# 6                  The Langham, New York, Fifth Avenue                 Hotels
# 7                                               Pod 51                 Hotels
# 8                                     Bronx Park Motel                 Hotels
# 9                                       The Mark Hotel                 Hotels
# 10                                           TWA Hotel                 Hotels
# 11                              The St. Regis New York                 Hotels
# 12                                      YOTEL New York                 Hotels
# 13                                           W Hoboken                 Hotels
# 14                                Orchard Street Hotel                 Hotels
# 15                                   Chelsea Pines Inn                 Hotels
# 16                                                MADE                 Hotels
# 17                                        Chelsea Pods                 Hotels
# 18                                          Hotel Hugo                 Hotels
# 19                                    Soho Grand Hotel                 Hotels
# 20    Days Inn by Wyndham Hotel New York City-Broadway                 Hotels
# 21              DoubleTree by Hilton New York Downtown                 Hotels
# 22                           W New York - Union Square                 Hotels
# 23                                 NU Hotel - Brooklyn                 Hotels
# 24                                  Pod Brooklyn Hotel                 Hotels
# 25                          The Tillary Hotel Brooklyn                 Hotels
# 26   Hilton Garden Inn NYC Financial Center/Manhatt...                 Hotels
# 27                                      Maritime Hotel                 Hotels
# 28                                     New World Hotel                 Hotels
# 29           Library Hotel by Library Hotel Collection                 Hotels
# ..                                                 ...                    ...
# 120  Residence Inn by Marriott New York Downtown Ma...                 Hotels
# 121                              McCarren Hotel & Pool                 Hotels
# 122                                The Box House Hotel                 Hotels
# 123        Hilton Garden Inn New York/Midtown Park Ave                 Hotels
# 124                             The Roxy Hotel Tribeca                 Hotels
# 125                        Hyatt Union Square New York                 Hotels
# 126                     Hilton Garden Inn Times Square                 Hotels
# 127                  Holiday Inn NYC - Lower East Side                 Hotels
# 128                               The New York EDITION                 Hotels
# 129  Fairfield Inn & Suites New York Midtown Manhat...                 Hotels
# 130                                Soho House New York                 Hotels
# 131                                The High Line Hotel                 Hotels
# 132                                 Ace Hotel New York                 Hotels
# 133                                       PUBLIC Hotel                 Hotels
# 134                      The Beekman, A Thompson Hotel                 Hotels
# 135                            The Inn At Irving Place                 Hotels
# 136                                 Four Seasons Hotel                 Hotels
# 137                                Park Hyatt New York                 Hotels
# 138                                       Bowery Lodge                 Hotels
# 139                         Gansevoort Meatpacking NYC                 Hotels
# 140                     citizenM New York Bowery Hotel                 Hotels
# 141                               1 Hotel Central Park                 Hotels
# 142                                       The Dominick                 Hotels
# 143                                          SIXTY LES                 Hotels
# 144                              Moxy NYC East Village                 Hotels
# 145                                 East Village Hotel                 Hotels
# 146                  InterContinental New York Barclay                 Hotels
# 147                                      Hotel Delmano                Lounges
# 148                             Kleinfeld Hotel Blocks        Travel Services
# 149                                          The Plaza  Venues & Event Spaces
#
#     Rating Price                            Address        Lat        Lng  \
# 0                                   85 Flatbush Ave  40.696613 -73.984537
# 1                                     111 Powers St  40.712330 -73.946510
# 2                                    210 W 122nd St  40.807170 -73.950640
# 3                                     1302 44th Ave  40.749539 -73.947967
# 4        4    $$                        95 Henry St  40.713451 -73.992901
# 5      3.5     $                     3801 Boston Rd  40.881640 -73.838560
# 6      4.5  $$$$                        400 5th Ave  40.750100 -73.983810
# 7      3.5    $$                      230 E 51st St  40.755862 -73.969128
# 8      1.5     $                   2500 Crotona Ave  40.856629 -73.881874
# 9        4  $$$$                       25 E 77th St  40.775260 -73.963470
# 10       3   $$$                        JFK Airport  40.645806 -73.777925
# 11       4  $$$$  Two East 55th Street At Fifth Ave  40.761360 -73.974430
# 12       3   $$$                      570 Tenth Ave  40.759157 -73.995456
# 13     3.5   $$$                       225 River St  40.739509 -74.027710
# 14       3    $$                     163 Orchard St  40.721140 -73.988810
# 15       4    $$                      317 W 14th St  40.740295 -74.003415
# 16       4   $$$                       42 W 29th St  40.746296 -73.989638
# 17     2.5     $                        370 8th Ave  40.748535 -73.995884
# 18       3   $$$                   525 Greenwich St  40.726427 -74.008857
# 19     3.5   $$$                     310 W Broadway  40.722052 -74.004506
# 20       2    $$               215 West 94th Street  40.793113 -73.971762
# 21       3    $$                         8 Stone St  40.703921 -74.012352
# 22     3.5   $$$                     201 Park Ave S  40.736650 -73.988690
# 23     3.5    $$                        85 Smith St  40.688790 -73.988850
# 24     3.5    $$               247 Metropolitan Ave  40.715020 -73.959030
# 25     2.5    $$                85 Flatbush Ave Ext  40.696445 -73.984360
# 26       4   $$$                         6 Water St  40.702970 -74.012281
# 27       4   $$$                      363 W 16th St  40.741928 -74.003243
# 28     1.5     $                         101 Bowery  40.717510 -73.995110
# 29     4.5   $$$                    299 Madison Ave  40.752180 -73.979540
# ..     ...   ...                                ...        ...        ...
# 120      4    $$                       170 Broadway  40.709564 -74.009921
# 121      3   $$$                      160 N 12th St  40.720952 -73.955367
# 122    3.5    $$                          77 Box St  40.737820 -73.953540
# 123    3.5    $$                       45 E 33rd St  40.746849 -73.982231
# 124    3.5   $$$                          2 6th Ave  40.719360 -74.004830
# 125    3.5   $$$                     134 Fourth Ave  40.733439 -73.990078
# 126    3.5    $$                        790 8th Ave  40.761205 -73.986507
# 127      4    $$                       150 Delancey  40.718292 -73.986240
# 128      4   $$$                      5 Madison Ave  40.741367 -73.987358
# 129      4    $$                      325 W 33rd St  40.752172 -73.995166
# 130    3.5   $$$                      29-35 9th Ave  40.740637 -74.005923
# 131    3.5   $$$                       180 10th Ave  40.745962 -74.004993
# 132      4    $$                       20 W 29th St  40.745777 -73.988286
# 133    2.5   $$$                    215 Chrystie St  40.723070 -73.992030
# 134      4   $$$                      123 Nassau St  40.711144 -74.006641
# 135    4.5    $$                       56 Irving Pl  40.735958 -73.986961
# 136    4.5  $$$$                      27 Barclay St  40.712643 -74.009188
# 137    4.5   $$$                   153 West 57th St  40.765380 -73.978950
# 138    2.5     $                          81 Bowery  40.716723 -73.995376
# 139      3   $$$                         18 9th Ave  40.739913 -74.005863
# 140      4     $                         189 Bowery  40.720690 -73.993660
# 141    4.5   $$$           1414 Ave Of The Americas  40.764812 -73.976463
# 142      4  $$$$                      246 Spring St  40.725465 -74.005330
# 143    2.5   $$$                       190 Allen St  40.722116 -73.988653
# 144                                   112 E 11th St  40.731601 -73.989509
# 145      4   $$$                        147 1st Ave  40.728360 -73.984970
# 146    3.5   $$$                      111 E 48th St  40.755745 -73.973492
# 147      4   $$$                        82 Berry St  40.719787 -73.958137
# 148                                   110 W 20th St  40.741270 -73.994990
# 149    3.5  $$$$                        768 5th Ave  40.764464 -73.974488
#
#                                                    url                      ID
# 0
# 1
# 2
# 3
# 4    https://www.yelp.com/biz/fairfield-inn-and-sui...  I95JZecBIM6fhvc-VpAE6w
# 5    https://www.yelp.com/biz/oasis-motel-bronx?adj...  wVVpqD__PLyaep7ND4GA8g
# 6    https://www.yelp.com/biz/the-langham-new-york-...  tpxMTuzDG42JuXK5phmxMQ
# 7    https://www.yelp.com/biz/pod-51-new-york?adjus...  PmmTXis1gCL34mg2bZ9gtw
# 8    https://www.yelp.com/biz/bronx-park-motel-bron...  zofvKgVX3j4fdypKB5dCqg
# 9    https://www.yelp.com/biz/the-mark-hotel-new-yo...  onKBo1qul0Pq27E5pVMAxA
# 10   https://www.yelp.com/biz/twa-hotel-new-york?ad...  bIwfyB1MiTrMEZBTAqu0tg
# 11   https://www.yelp.com/biz/the-st-regis-new-york...  T8hRtRz3Q50VC8DX9NRfDg
# 12   https://www.yelp.com/biz/yotel-new-york-new-yo...  LtVO-82pFdwjq-hwMITAPg
# 13   https://www.yelp.com/biz/w-hoboken-hoboken?adj...  JgJAG4E-r0ZQ-pp_oHBTCg
# 14   https://www.yelp.com/biz/orchard-street-hotel-...  yZXN-Qj3x81ivd3Lr6Cjbw
# 15   https://www.yelp.com/biz/chelsea-pines-inn-new...  XRt4mVzNQbXkC6mxFl7-Sg
# 16   https://www.yelp.com/biz/made-new-york-3?adjus...  S552XBLEOFsT-efRQuNXDg
# 17   https://www.yelp.com/biz/chelsea-pods-new-york...  dz1E1AOUQE1f3Ga1sM6pZA
# 18   https://www.yelp.com/biz/hotel-hugo-new-york?a...  VzVdwfFwY1dgWKNqlen8lw
# 19   https://www.yelp.com/biz/soho-grand-hotel-new-...  2nEXbS33ksBOe6JViJdyog
# 20   https://www.yelp.com/biz/days-inn-by-wyndham-h...  rD48w_Iyo-VU-Hvu_e0NeQ
# 21   https://www.yelp.com/biz/doubletree-by-hilton-...  -Hneo47XIw4irjQBdPMecA
# 22   https://www.yelp.com/biz/w-new-york-union-squa...  mM4Q4mnSK5cFLv2gXPu49Q
# 23   https://www.yelp.com/biz/nu-hotel-brooklyn-bro...  VeNu9ATM2HI2NL4Q-ZsTsg
# 24   https://www.yelp.com/biz/pod-brooklyn-hotel-br...  KKhFd2VBfIj5n4t0rYVMYQ
# 25   https://www.yelp.com/biz/the-tillary-hotel-bro...  icE34yZpi0lCBTDaQs914w
# 26   https://www.yelp.com/biz/hilton-garden-inn-nyc...  Q6n8-lbd-ozt5J13xGnAwQ
# 27   https://www.yelp.com/biz/maritime-hotel-new-yo...  ItnW4u1nVYvde1NT4Lgd3g
# 28   https://www.yelp.com/biz/new-world-hotel-new-y...  7fN4Ygy-q3uRcE3wESTIRw
# 29   https://www.yelp.com/biz/library-hotel-by-libr...  qZewWn4-pdd4JfoJSBV1QA
# ..                                                 ...                     ...
# 120  https://www.yelp.com/biz/residence-inn-by-marr...  5DkFAVEU_gAkC3wAUqdAZg
# 121  https://www.yelp.com/biz/mccarren-hotel-and-po...  NJR4lyaLF4-3kJ3eNK9cpA
# 122  https://www.yelp.com/biz/the-box-house-hotel-b...  1Jyg_gj0yNGR8TqvOEQ4iQ
# 123  https://www.yelp.com/biz/hilton-garden-inn-new...  de3c201K0cfWbvy-3XAqig
# 124  https://www.yelp.com/biz/the-roxy-hotel-tribec...  7X5dByOWa-nXY_2eBnVcHw
# 125  https://www.yelp.com/biz/hyatt-union-square-ne...  8gWw3lMOqi3xe8d0nKUiKw
# 126  https://www.yelp.com/biz/hilton-garden-inn-tim...  fEqSedl1uUUfpmfs3mMiwQ
# 127  https://www.yelp.com/biz/holiday-inn-nyc-lower...  P2-YUkcDcgyYW46hSPYBMw
# 128  https://www.yelp.com/biz/the-new-york-edition-...  bCilcCWpBrJEFid7TQiDWA
# 129  https://www.yelp.com/biz/fairfield-inn-and-sui...  JLoLYfqWvcOPIUfxu48qbQ
# 130  https://www.yelp.com/biz/soho-house-new-york-n...  FqRul4l8Vea_b1x6ggRrJw
# 131  https://www.yelp.com/biz/the-high-line-hotel-n...  2_ehPnf8YEaDGAzenLYnrQ
# 132  https://www.yelp.com/biz/ace-hotel-new-york-ne...  VqMuuey8_bH3sZ5qHL9tPQ
# 133  https://www.yelp.com/biz/public-hotel-new-york...  t6efAU5wYjIMd6T6eGbeWg
# 134  https://www.yelp.com/biz/the-beekman-a-thompso...  nwvo49wYOrSfg3AhafhZvA
# 135  https://www.yelp.com/biz/the-inn-at-irving-pla...  WQZCwbYZ5XLnmENzOv2xCQ
# 136  https://www.yelp.com/biz/four-seasons-hotel-ne...  SZTBP6Xj7ER4d3NSbgOA-A
# 137  https://www.yelp.com/biz/park-hyatt-new-york-n...  zuMUWAduEq4COEcbnZ3XCA
# 138  https://www.yelp.com/biz/bowery-lodge-new-york...  fVUuJd-ZR5DUhzjdI6mGRQ
# 139  https://www.yelp.com/biz/gansevoort-meatpackin...  uK3Wug7R0YylT_u0QWZjUg
# 140  https://www.yelp.com/biz/citizenm-new-york-bow...  HsfNLFKADPZUNXsRVx9_dA
# 141  https://www.yelp.com/biz/1-hotel-central-park-...  htWCcFI5R5Cuwod5PNSpow
# 142  https://www.yelp.com/biz/the-dominick-new-york...  svW0v_j18STsq5Ua-8waZg
# 143  https://www.yelp.com/biz/sixty-les-new-york-2?...  wxKyslbI99ESDbQnns-RSg
# 144
# 145  https://www.yelp.com/biz/east-village-hotel-ne...  0SrF_WcRetbGWlps7ZhJNw
# 146  https://www.yelp.com/biz/intercontinental-new-...  tdWg-eGacW6d3XOtbxBX5Q
# 147  https://www.yelp.com/biz/hotel-delmano-brookly...  g8-qHshfhb1Tx3VMYVDZgg
# 148
# 149  https://www.yelp.com/biz/the-plaza-new-york-2?...  FA5giJYhqdTkjsT695TqVg
#
# [150 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_hotels_df.to_csv('Resources/NYC_Hotels.csv')
