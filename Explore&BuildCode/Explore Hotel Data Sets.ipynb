# %%
## Dependencies and Setup
import pandas as pd

# %%
## Files to Load
london_hotel_data = "Resources/London_hotel_reviews.csv"
nyc_hotel_data = "Resources/new_york_hotels.csv"

## Read the data and store into a Pandas DataFrame
london_hotel_df = pd.read_csv(london_hotel_data, encoding="ISO-8859-1") 
nyc_hotel_df = pd.read_csv(nyc_hotel_data, encoding="ISO-8859-1")

# %%
london_hotel_data = "Resources/London_hotel_reviews.csv"
london_hotel_df = pd.read_csv(london_hotel_data, encoding="ISO-8859-1") 
london_hotel_df.head()
# Out:
#             Property Name  Review Rating  \
# 0  Apex London Wall Hotel              5
# 1  Corinthia Hotel London              5
# 2               The Savoy              5
# 3            Rhodes Hotel              4
# 4               The Savoy              5
#
#                                    Review Title  \
# 0                         Ottima qualità prezzo
# 1            By far, my best hotel in the world
# 2  First visit to the American Bar at the Savoy
# 3                                     Nice stay
# 4                                    Perfection
#
#                                          Review Text  \
# 0  Siamo stati a Londra per un week end ed abbiam...
# 1  I had a pleasure of staying in this hotel for ...
# 2  A very lovely first visit to this iconic hotel...
# 3  3 of us stayed at the Rhodes Hotel for 4 night...
# 4  Form the moment we arrived until we left we ex...
#
#    Location Of The Reviewer Date Of Review
# 0  Casale Monferrato, Italy     10/20/2012
# ...

# %%
ny_hotel_data = "Resources/new_york_hotels.csv"
ny_hotel_df = pd.read_csv(ny_hotel_data, encoding="ISO-8859-1")
nyc_hotel_df = ny_hotel_df[ny_hotel_df["city"] == "New York"]
nyc_hotel_df.head()
# Out:
#      ean_hotel_id                             name  \
# 787        219370      Dumont NYC-an Affinia hotel
# 788        109277            Park Central New York
# 789        116103                 Blakely New York
# 790        415836                           Pod 39
# 791        351449  Sheraton Tribeca New York Hotel
#
#                                    address1      city state_province  \
# 787  150 E. 34th Street at Lexington Avenue  New York             NY
# 788                             870 7th Ave  New York             NY
# 789                           136 W 55th St  New York             NY
# 790                    145 East 39th Street  New York             NY
# 791                        370 Canal Street  New York             NY
#
#     postal_code  latitude  longitude  star_rating  high_rate  low_rate
# 787       10016  40.74624  -73.97929          4.0   349.7400  299.2400
# 788       10019  40.76452  -73.98078          4.0   191.0000  190.0000
# ...
