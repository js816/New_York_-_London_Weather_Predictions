# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# credit: https://www.justintodata.com/python-api-call-to-request-data/

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search
# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
nyc_params = {'term': 'restuarant', 'location': 'New York', 'limit': 50}
london_params = {'term': 'museum', 'location': 'London', 'limit': 50}

# %%
# timeout of 5 seconds: https://requests.readthedocs.io/en/master/user/quickstart/#timeouts
nyc_response = requests.get(search_api_url, headers=headers, params=nyc_params, timeout=5)

# %%
print(nyc_response.url)
print(nyc_response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=restuarant&location=New+York&limit=50
# 200

# %%
print(nyc_response.headers)
# Out:
# {'Connection': 'keep-alive', 'content-type': 'application/json', 'x-zipkin-id': '2e151d6d1260f229', 'ratelimit-remaining': '5000', 'ratelimit-resettime': '2021-09-25T00:00:00+00:00', 'x-routing-service': 'routing-main--useast1-7bbf457c88-g8ddl; site=public_api_v3', 'x-b3-sampled': '0', 'server': 'envoy', 'ratelimit-dailylimit': '5000', 'x-cloudmap': 'routing_useast1', 'content-encoding': 'gzip', 'x-proxied': '10-65-164-1-useast1bprod', 'x-extlb': '10-65-164-1-useast1bprod', 'cache-control': 'max-age=0, no-store, private, no-transform', 'Accept-Ranges': 'bytes', 'Date': 'Fri, 24 Sep 2021 21:26:48 GMT', 'Via': '1.1 varnish', 'X-Served-By': 'cache-mci5927-MCI', 'X-Cache': 'MISS', 'X-Cache-Hits': '0', 'Vary': 'Accept-Encoding', 'transfer-encoding': 'chunked'}

# %%
nyc = nyc_response.json()
nyc
# Out:
# {'businesses': [{'id': 'hdiuRS9sVZSMReZm4oV5SA',
#    'alias': 'da-andrea-new-york',
#    'name': 'Da Andrea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dYaaHrqfyAn8C6x2odES-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-andrea-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 948,
#    'categories': [{'alias': 'tuscan', 'title': 'Tuscan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.736218, 'longitude': -73.99597},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '35 W 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35 W 13th St', 'New York, NY 10011']},
#    'phone': '+12123671979',
#    'display_phone': '(212) 367-1979',
#    'distance': 3424.7293369303584},
#   {'id': 'M-odQWSEfsR2mVEw7nKG-g',
#    'alias': 'nyonya-new-york',
#    'name': 'Nyonya',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YuWC1Gwo7ku4PvD-7mDQnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nyonya-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2149,
#    'categories': [{'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7190148, 'longitude': -73.9968228},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '199 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['199 Grand St', 'New York, NY 10013']},
#    'phone': '+12123343669',
#    'display_phone': '(212) 334-3669',
#    'distance': 1524.9858332338151},
#   {'id': 'V7lXZKBDzScDeGB8JmnzSA',
#    'alias': 'katzs-delicatessen-new-york',
#    'name': "Katz's Delicatessen",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qr7eSU6CFwRGZ7Rc-QEoTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/katzs-delicatessen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12917,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722237, 'longitude': -73.9875259},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '205 E Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['205 E Houston St', 'New York, NY 10002']},
#    'phone': '+12122542246',
#    'display_phone': '(212) 254-2246',
#    'distance': 1952.3706239726876},
#   {'id': 'SaYTVG7wHCMDBofHCgXPaA',
#    'alias': 'dutch-freds-new-york-2',
#    'name': 'Dutch Freds',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/F5fSQkZSmWf_JEkcFUpcyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dutch-freds-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1645,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.760835, 'longitude': -73.987823},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '307 W 47th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['307 W 47th St', 'New York, NY 10036']},
#    'phone': '+16469186923',
#    'display_phone': '(646) 918-6923',
#    'distance': 6182.299430087978},
#   {'id': 'StF9WWWbrRzEOmNAcEINcA',
#    'alias': 'balzem-new-york',
#    'name': 'Balzem',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FHbj0Hqn0btPLBS7pwPfew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/balzem-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 455,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.721408, 'longitude': -73.995415},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '202 Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['202 Mott St', 'New York, NY 10012']},
#    'phone': '+16468377033',
#    'display_phone': '(646) 837-7033',
#    'distance': 1777.534042874945},
#   {'id': 'HiNUBUR1hFwScd_OvVLQAg',
#    'alias': 'la-pecora-bianca-new-york',
#    'name': 'La Pecora Bianca',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pXoM8IbmiWix_LZSNqYGqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-pecora-bianca-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 732,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74358, 'longitude': -73.9892},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1133 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1133 Broadway', 'New York, NY 10010']},
#    'phone': '+12124989696',
#    'display_phone': '(212) 498-9696',
#    'distance': 4283.308393922253},
#   {'id': 'FiRB9Ek3Xo9JHwXgBYITYg',
#    'alias': 'la-sirène-soho-new-york',
#    'name': 'La Sirène-Soho',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L7cSgPVmrKJosZatGJKvBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-sir%C3%A8ne-soho-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1636,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7243642217227,
#     'longitude': -74.005708694458},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '558 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['558 Broome St', 'New York, NY 10013']},
#    'phone': '+12129253061',
#    'display_phone': '(212) 925-3061',
#    'distance': 2313.301948098778},
#   {'id': '59oP8zLjQLPY0Dyh004HSQ',
#    'alias': 'omai-new-york-2',
#    'name': 'Omai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2WrZA4eVQn3m3cobP1eMHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/omai-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 273,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.744289, 'longitude': -74.002563},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '158 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['158 9th Ave', 'New York, NY 10011']},
#    'phone': '+12126330550',
#    'display_phone': '(212) 633-0550',
#    'distance': 4378.469523810043},
#   {'id': '0CjK3esfpFcxIopebzjFxA',
#    'alias': 'joes-shanghai-new-york-2',
#    'name': "Joe's Shanghai",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KRvabBPGaQikcpSD6vO2bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-shanghai-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6429,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7156608, 'longitude': -73.9967012},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '46 Bowery St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['46 Bowery St', 'New York, NY 10013']},
#    'phone': '+12122338888',
#    'display_phone': '(212) 233-8888',
#    'distance': 1153.9482385806896},
#   {'id': 'yZJbealagfujEkgesAl2hA',
#    'alias': 'lupa-new-york',
#    'name': 'Lupa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OdUK7zgusaMmPzToZuq3tA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lupa-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1598,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7276, 'longitude': -74.000045},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '170 Thompson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['170 Thompson St', 'New York, NY 10012']},
#    'phone': '+12129825089',
#    'display_phone': '(212) 982-5089',
#    'distance': 2517.265489271021},
#   {'id': '22nKUyCIbpnzR6R3_g1ptQ',
#    'alias': 'carmines-italian-restaurant-times-square-new-york-5',
#    'name': "Carmine's Italian Restaurant - Times Square",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ABC0jQ9tmZ58dDgztabrVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carmines-italian-restaurant-times-square-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3776,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'catering', 'title': 'Caterers'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75749, 'longitude': -73.98662},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '200 W 44th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 W 44th St', 'New York, NY 10036']},
#    'phone': '+12122213800',
#    'display_phone': '(212) 221-3800',
#    'distance': 5821.554586323717},
#   {'id': 'a0IET3_yCFcO36OqGSsisg',
#    'alias': 'eataly-flatiron-new-york',
#    'name': 'Eataly Flatiron',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/n9MMv47vKQiiUyeRSJkTDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eataly-flatiron-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5710,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74195877796, 'longitude': -73.989716662832},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '200 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 5th Ave', 'New York, NY 10010']},
#    'phone': '+12122292560',
#    'display_phone': '(212) 229-2560',
#    'distance': 4078.4333537925154},
#   {'id': '_LJFf9YqpYxvExTvVxb7Rw',
#    'alias': 'the-modern-new-york-3',
#    'name': 'The Modern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/__is97xsPSkTBpivq7IWMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-modern-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1021,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7610699, 'longitude': -73.97709},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '9 W 53rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 W 53rd St', 'New York, NY 10019']},
#    'phone': '+12123331220',
#    'display_phone': '(212) 333-1220',
#    'distance': 6344.5527611230855},
#   {'id': 's3jou_L_LVYGkNHiuhjlew',
#    'alias': 'boucherie-west-village-new-york-3',
#    'name': 'Boucherie West Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gGTUB2AHF7sK5u-wdjO8DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boucherie-west-village-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1765,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.733063, 'longitude': -74.0028772},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '99 7th Ave S',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['99 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12128371616',
#    'display_phone': '(212) 837-1616',
#    'distance': 3155.0505772747442},
#   {'id': 'l9b8NbDyhKhnjLKtUwlPwQ',
#    'alias': 'olea-brooklyn-2',
#    'name': 'Olea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DnRMsVyIBgFA-CsLDU5AYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olea-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 926,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6877844, 'longitude': -73.9706046},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '171 Lafayette Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 Lafayette Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17186437003',
#    'display_phone': '(718) 643-7003',
#    'distance': 2797.8774095098875},
#   {'id': '7VqMGK9uwi0vKqOjdKyIUA',
#    'alias': 'catch-nyc-new-york',
#    'name': 'Catch NYC',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/C9wl_QZLzt4grdvS2IKpTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/catch-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2424,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.740234, 'longitude': -74.006342},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '21 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21 9th Ave', 'New York, NY 10014']},
#    'phone': '+12123925978',
#    'display_phone': '(212) 392-5978',
#    'distance': 3999.4092418284154},
#   {'id': 'XsElXaLxUPKquI78poB8yw',
#    'alias': 'maison-pickle-new-york',
#    'name': 'Maison Pickle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zZw_u_oeO9it_GYSinWkMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maison-pickle-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1221,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7870473, 'longitude': -73.9781361},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2315 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2315 Broadway', 'New York, NY 10024']},
#    'phone': '+12124969100',
#    'display_phone': '(212) 496-9100',
#    'distance': 9175.285173753695},
#   {'id': 'jjJc_CrkB2HodEinB6cWww',
#    'alias': 'lovemama-new-york',
#    'name': 'LoveMama',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bLlFKTlVuLfmF-lIDGIjZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lovemama-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5557,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.730408722512074,
#     'longitude': -73.98612673033213},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '174 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['174 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12122545370',
#    'display_phone': '(212) 254-5370',
#    'distance': 2859.902795118878},
#   {'id': 'CVxz9B5ncpMwVK1bk_c1YA',
#    'alias': 'veselka-new-york',
#    'name': 'Veselka',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/f1RdxZKOM07-lytOMAHuSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/veselka-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2702,
#    'categories': [{'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'ukrainian', 'title': 'Ukrainian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729036, 'longitude': -73.98712},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '144 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['144 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12122289682',
#    'display_phone': '(212) 228-9682',
#    'distance': 2691.9732008042556},
#   {'id': 'B55Ocx5RBWxo6AGSucYSIA',
#    'alias': 'ilili-new-york-2',
#    'name': 'ilili',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uDoD1yzG5naCvmFYmklyAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ilili-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2478,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'lebanese', 'title': 'Lebanese'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74435, 'longitude': -73.98778},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '236 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['236 5th Ave', 'New York, NY 10001']},
#    'phone': '+12126832929',
#    'display_phone': '(212) 683-2929',
#    'distance': 4365.7542899009195},
#   {'id': '77EedCTJY1biWIYSzAulCQ',
#    'alias': 'j-g-melon-new-york-4',
#    'name': 'J.G. Melon',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TXfqMXlF2VfghYzVvO2Lxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/j-g-melon-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1351,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.77105, 'longitude': -73.95931},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1291 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1291 3rd Ave', 'New York, NY 10021']},
#    'phone': '+12127440585',
#    'display_phone': '(212) 744-0585',
#    'distance': 7866.869294997786},
#   {'id': '9_CEU7Wmvmwlyvqr-PJD6w',
#    'alias': 'ofrenda-new-york',
#    'name': 'Ofrenda',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C2PxC5KF6dL5twB2BM42Aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ofrenda-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1010,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73391, 'longitude': -74.00242},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '113 7th Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['113 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12129242305',
#    'display_phone': '(212) 924-2305',
#    'distance': 3239.692567061365},
#   {'id': 'O1XrvIq-6IlLunLYEjOiFQ',
#    'alias': 'kushi-kushi-yaki-new-york',
#    'name': 'Kushi Kushi Yaki',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kRpgDisV4cZbA0-fEqthSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kushi-kushi-yaki-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.747266, 'longitude': -73.9861784},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '2 W 32nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2 W 32nd St', 'New York, NY 10001']},
#    'phone': '+12122793075',
#    'display_phone': '(212) 279-3075',
#    'distance': 4700.300458259518},
#   {'id': 'xt4sa64WOrpJvZBDPNPNYg',
#    'alias': 'jacobs-pickles-new-york',
#    'name': "Jacob's Pickles",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yU9q4U1WSk6diDF0dcA9ag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jacobs-pickles-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4562,
#    'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7866504411994,
#     'longitude': -73.9755284786224},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '509 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['509 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12124705566',
#    'display_phone': '(212) 470-5566',
#    'distance': 9166.964737863183},
#   {'id': 'nRO136GRieGtxz18uD61DA',
#    'alias': 'eleven-madison-park-new-york',
#    'name': 'Eleven Madison Park',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/s_H7gm_Hwmz--O6bo1iU-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eleven-madison-park-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2210,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7416907417333,
#     'longitude': -73.9872074872255},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '11 Madison Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 Madison Ave', 'New York, NY 10010']},
#    'phone': '+12128890905',
#    'display_phone': '(212) 889-0905',
#    'distance': 4074.3463982775174},
#   {'id': 'WG639VkTjmK5dzydd1BBJA',
#    'alias': 'rubirosa-new-york-2',
#    'name': 'Rubirosa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LuSzR8cpVQRofXOT_bMi1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2439,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.722766, 'longitude': -73.996233},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '235 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#    'phone': '+12129650500',
#    'display_phone': '(212) 965-0500',
#    'distance': 1932.9467701334759},
#   {'id': 'tbg4gR3jUUllR28cySo2kg',
#    'alias': 'awash-ethiopian-restaurant-new-york-2',
#    'name': 'Awash Ethiopian Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2nCt7VjXNZWQcilnBALqEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/awash-ethiopian-restaurant-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 491,
#    'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'},
#     {'alias': 'african', 'title': 'African'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.800641, 'longitude': -73.965098},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '947 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['947 Amsterdam Ave', 'New York, NY 10025']},
#    'phone': '+12129611416',
#    'display_phone': '(212) 961-1416',
#    'distance': 10867.227337057393},
#   {'id': 'pfmAcS-g6SiNG0KlLvrqnA',
#    'alias': 'beauty-and-essex-new-york-2',
#    'name': 'Beauty & Essex',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/T0KCvQyqHSClgUQhO02slQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beauty-and-essex-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3539,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720434786101286,
#     'longitude': -73.98686057623863},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '146 Essex St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['146 Essex St', 'New York, NY 10002']},
#    'phone': '+12126140146',
#    'display_phone': '(212) 614-0146',
#    'distance': 1780.637937184024},
#   {'id': '44SY464xDHbvOcjDzRbKkQ',
#    'alias': 'ippudo-ny-new-york-7',
#    'name': 'Ippudo NY',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zF3EgqHCk7zBUwD2B3WTEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ippudo-ny-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10084,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73092, 'longitude': -73.99015},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '65 4th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['65 4th Ave', 'New York, NY 10003']},
#    'phone': '+12123880088',
#    'display_phone': '(212) 388-0088',
#    'distance': 2854.3012674083675},
#   {'id': 'M-AcAh1C_eQfhzGk6ZmOSQ',
#    'alias': 'emmas-torch-brooklyn-2',
#    'name': "Emma's Torch",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/R_6_3bI5qYxjTG2KQ5Vafg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/emmas-torch-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.67996, 'longitude': -73.99478},
#    'transactions': ['delivery'],
#    'location': {'address1': '345 Smith St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['345 Smith St', 'Brooklyn, NY 11231']},
#    'phone': '+17182431222',
#    'display_phone': '(718) 243-1222',
#    'distance': 2831.794565774135},
#   {'id': 'axqp3pGJXnTLgq2QrPyDyQ',
#    'alias': 'benemon-new-york',
#    'name': 'Benemon',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qYGlL-jKKWmMthi05ae_iA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/benemon-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 617,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72551, 'longitude': -73.98838},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '108 E 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['108 E 4th St', 'New York, NY 10003']},
#    'phone': '+12126143006',
#    'display_phone': '(212) 614-3006',
#    'distance': 2289.2038585586733},
#   {'id': 'ZqIFN8MctXVR1Y30Bsohtg',
#    'alias': 'epistrophy-new-york',
#    'name': 'Epistrophy',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CykM9x7ELf-TsX1RMBsG8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/epistrophy-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 470,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.721202, 'longitude': -73.995401},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '200 Mott St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 Mott St', 'New York, NY 10012']},
#    'phone': '+12129660904',
#    'display_phone': '(212) 966-0904',
#    'distance': 1754.5975846241327},
#   {'id': '8PhwiTru5teSaZ8C6hrIww',
#    'alias': 'casa-mono-new-york',
#    'name': 'Casa Mono',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Qm7W93CkBJ3qMb83HzHy5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-mono-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1277,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7359281440206,
#     'longitude': -73.9871550967319},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '52 Irving Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['52 Irving Pl', 'New York, NY 10003']},
#    'phone': '+12122532773',
#    'display_phone': '(212) 253-2773',
#    'distance': 3442.5489220619515},
#   {'id': 'dh5r9-SbN8xJ76XvnayWLQ',
#    'alias': 'giano-restaurant-new-york',
#    'name': 'Giano Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0PrOZ5stl86k6V1SzHcjNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giano-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 635,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7262256596862,
#     'longitude': -73.9840574049125},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '126 E 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['126 E 7th St', 'New York, NY 10009']},
#    'phone': '+12126737200',
#    'display_phone': '(212) 673-7200',
#    'distance': 2466.5008597028605},
#   {'id': '4XX-zF8h5Lvrr22_tqU6-Q',
#    'alias': 'the-river-café-brooklyn-3',
#    'name': 'The River Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/X5pxv0ydhNP7kPBDArEHsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-river-caf%C3%A9-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1166,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70318, 'longitude': -73.9946499},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '1 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+17185225200',
#    'display_phone': '(718) 522-5200',
#    'distance': 252.24127844020637},
#   {'id': 'lkDtUR6P0Y2gYkylHc6SoQ',
#    'alias': 'wild-new-york',
#    'name': 'WILD',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WqjSxZ74sYbZBWzrYLOd5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wild-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 441,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73474, 'longitude': -74.00632},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '535 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['535 Hudson St', 'New York, NY 10014']},
#    'phone': '+12129292920',
#    'display_phone': '(212) 929-2920',
#    'distance': 3399.317954164052},
#   {'id': 'F89nDDlYZ7wbRe8EpLCqBw',
#    'alias': 'avra-estiatorio-new-york-3',
#    'name': 'Avra Estiatorio',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KOWgG7f1MsuxwS3YvajWfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/avra-estiatorio-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 900,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75503581588927,
#     'longitude': -73.97244109270292},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '141 E 48th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['141 E 48th St', 'New York, NY 10017']},
#    'phone': '+12127598550',
#    'display_phone': '(212) 759-8550',
#    'distance': 5813.556832137099},
#   {'id': 'mPHPVJ2-8mOR-lFHafrc6w',
#    'alias': 'evelina-brooklyn-2',
#    'name': 'Evelina',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hG3aShzVvdnbAFm02sQgZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/evelina-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 234,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.689722, 'longitude': -73.971003},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '211 Dekalb Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['211 Dekalb Ave', 'Brooklyn, NY 11205']},
#    'phone': '+19292980209',
#    'display_phone': '(929) 298-0209',
#    'distance': 2628.710848301728},
#   {'id': 'LpVbI-E9C-CSp7WhU5h2Iw',
#    'alias': 'fishmarket-restaurant-new-york',
#    'name': 'Fishmarket Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zIPbObERXHKehqV-yU7Wgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fishmarket-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 578,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'divebars', 'title': 'Dive Bars'},
#     {'alias': 'malaysian', 'title': 'Malaysian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70717, 'longitude': -74.00192},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '111 South St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 South St', 'New York, NY 10038']},
#    'phone': '+19173638101',
#    'display_phone': '(917) 363-8101',
#    'distance': 667.9406968270184},
#   {'id': 'Dr_eezrA2Cc_azMYnwhRkA',
#    'alias': 'sup-crab-new-york',
#    'name': 'Sup Crab',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Mm3E6skVDm2hw-G9hQe_hw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sup-crab-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 370,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71733, 'longitude': -73.99502},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '97 Bowery',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['97 Bowery', 'New York, NY 10002']},
#    'phone': '+12129258083',
#    'display_phone': '(212) 925-8083',
#    'distance': 1327.6547690924829},
#   {'id': 'XHhRAKq6DArQXYhkgvwaow',
#    'alias': 'spaghetti-incident-new-york-2',
#    'name': 'Spaghetti Incident',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/p5gt4VvPJnobk0HpF53Ong/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spaghetti-incident-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 613,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7223153441439,
#     'longitude': -73.9899454318763},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '231 Eldridge St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 Eldridge St', 'New York, NY 10002']},
#    'phone': '+16468961446',
#    'display_phone': '(646) 896-1446',
#    'distance': 1911.3655890506484},
#   {'id': 'Uut2fBy53XdIgx1rLWdQeg',
#    'alias': 'empanada-mama-l-e-s-new-york-10',
#    'name': 'Empanada Mama L.E.S',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jVEXnJv1Qg5orvbDo7Lq2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/empanada-mama-l-e-s-new-york-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 793,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71873, 'longitude': -73.9909},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '95 Allen St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['95 Allen St', 'New York, NY 10002']},
#    'phone': '+12126730300',
#    'display_phone': '(212) 673-0300',
#    'distance': 1506.9503543427306},
#   {'id': 'i8ejDDR4COtukAAA1Ls5fw',
#    'alias': 'soba-ya-new-york',
#    'name': 'Soba-ya',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xGWd2_qlV4fejCuJkJIAVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soba-ya-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1480,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72965, 'longitude': -73.9878899},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '229 E 9th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['229 E 9th St', 'New York, NY 10003']},
#    'phone': '+12125336966',
#    'display_phone': '(212) 533-6966',
#    'distance': 2744.4836849113926},
#   {'id': '2ggi1luerd3Mf_C82JvCYg',
#    'alias': 'grimaldis-pizzeria-brooklyn-4',
#    'name': "Grimaldi's Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KnocNRTl04953MdDXH9y7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grimaldis-pizzeria-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4684,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.702583, 'longitude': -73.9932413},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17188584300',
#    'display_phone': '(718) 858-4300',
#    'distance': 330.34746206527655},
#   {'id': 'NOh24SMS6k4pzNv8Ds7KDg',
#    'alias': 'cafe-habana-new-york-4',
#    'name': 'Cafe Habana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cUHxmLdN0XyZi6AgvaMb3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-habana-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3187,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722998, 'longitude': -73.994171},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '17 Prince St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 Prince St', 'New York, NY 10012']},
#    'phone': '+12126252001',
#    'display_phone': '(212) 625-2001',
#    'distance': 1951.844634788307},
#   {'id': 'OAqsZMbjv66nOMqlimnYuQ',
#    'alias': 'uva-new-york',
#    'name': 'Uva',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Dv_IaSo7QTUrRRtclijk2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uva-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2481,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7722, 'longitude': -73.95566},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1486 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1486 2nd Ave', 'New York, NY 10075']},
#    'phone': '+12124724552',
#    'display_phone': '(212) 472-4552',
#    'distance': 8104.693377840111},
#   {'id': '8XHbZIKDQbXhyKIGiukVeQ',
#    'alias': 'boucherie-union-square-new-york-city',
#    'name': 'Boucherie Union Square',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1IVgirEX8ILPSKVfylIR2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boucherie-union-square-new-york-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 971,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73725824850519,
#     'longitude': -73.9882252705524},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '225 Park Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'New York City',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['225 Park Ave S', 'New York City, NY 10003']},
#    'phone': '+12123530200',
#    'display_phone': '(212) 353-0200',
#    'distance': 3574.2526799067864},
#   {'id': '20LSOx_4K2wghTsUx4gSsg',
#    'alias': 'oceanic-boil-jackson-heights',
#    'name': 'Oceanic Boil',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aF45SWZgZoZsVsBXgEgDig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oceanic-boil-jackson-heights?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 644,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7498297, 'longitude': -73.8821356},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '84-20 37th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['84-20 37th Ave', 'Jackson Heights, NY 11372']},
#    'phone': '+19292966338',
#    'display_phone': '(929) 296-6338',
#    'distance': 10675.873540539471},
#   {'id': 'lnTPfdaqDqWjywWewsE2Lw',
#    'alias': 'miriam-brooklyn-2',
#    'name': 'Miriam',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tONRUqmVXTshXUq6dePMSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/miriam-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1061,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6801719843659,
#     'longitude': -73.9777555239717},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '79 5th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17186222250',
#    'display_phone': '(718) 622-2250',
#    'distance': 3137.090123467059},
#   {'id': 'fSQ3CCtFSJ2S8VXDi02-3Q',
#    'alias': 'cafe-luxembourg-new-york',
#    'name': 'Cafe Luxembourg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Wh-4j7J-Wh8cUh2CHq5L-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-luxembourg-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 532,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77741, 'longitude': -73.98312},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '200 W 70th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 W 70th St', 'New York, NY 10023']},
#    'phone': '+12128737411',
#    'display_phone': '(212) 873-7411',
#    'distance': 8053.065658829433}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#nyc["businesses"][0]

# %%
# timeout of 5 seconds: https://requests.readthedocs.io/en/master/user/quickstart/#timeouts
london_response = requests.get(search_api_url, headers=headers, params=london_params, timeout=5)

# %%
print(london_response.url)
print(london_response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=museum&location=London&limit=50
# 200

# %%
print(london_response.headers)
# Out:
# {'Connection': 'keep-alive', 'content-type': 'application/json', 'x-routing-service': 'routing-main--useast1-7bbf457c88-6dlqh; site=public_api_v3', 'ratelimit-dailylimit': '5000', 'x-b3-sampled': '0', 'ratelimit-remaining': '4999', 'server': 'envoy', 'ratelimit-resettime': '2021-09-25T00:00:00+00:00', 'x-zipkin-id': '0f759e878250033f', 'x-cloudmap': 'routing_useast1', 'content-encoding': 'gzip', 'x-proxied': '10-65-118-75-useast1aprod', 'x-extlb': '10-65-118-75-useast1aprod', 'cache-control': 'max-age=0, no-store, private, no-transform', 'Accept-Ranges': 'bytes', 'Date': 'Fri, 24 Sep 2021 21:37:50 GMT', 'Via': '1.1 varnish', 'X-Served-By': 'cache-mci5927-MCI', 'X-Cache': 'MISS', 'X-Cache-Hits': '0', 'Vary': 'Accept-Encoding', 'transfer-encoding': 'chunked'}

# %%
london_dict = london_response.json()
type(london_dict)
# Out:
# dict

# %%
london_dict.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
type(london_dict['businesses'])
# Out:
# list

# %%
len(london_dict['businesses'])
# Out:
# 50

# %%
type(london_dict['businesses'][0])
# Out:
# dict

# %%
london_dict['businesses'][0].keys()
# Out:
# dict_keys(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count', 'categories', 'rating', 'coordinates', 'transactions', 'location', 'phone', 'display_phone', 'distance'])

# %%
#First Business in the list
london_dict['businesses'][0]
# Out:
# {'id': 'ElxBJGffVB-jV1kMCG9PbQ',
#  'alias': 'the-national-gallery-london-2',
#  'name': 'The National Gallery',
#  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Y2mDtEARDc8m4RLXstgorA/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/the-national-gallery-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#  'review_count': 463,
#  'categories': [{'alias': 'artmuseums', 'title': 'Art Museums'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 51.508929, 'longitude': -0.128302},
#  'transactions': [],
#  'location': {'address1': 'Trafalgar Square',
#   'address2': '',
#   'address3': '',
#   'city': 'London',
#   'zip_code': 'WC2N 5DN',
#   'country': 'GB',
#   'state': 'XGL',
#   'display_address': ['Trafalgar Square',
#    'London WC2N 5DN',
#    'United Kingdom']},
#  'phone': '+4420077472885',
#  'display_phone': '+44 20077472885',
#  'distance': 685.0138399344412}

# %%
london_dict['businesses'][1].keys()
# Out:
# dict_keys(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count', 'categories', 'rating', 'coordinates', 'transactions', 'location', 'phone', 'display_phone', 'distance'])

# %%
london_dict['businesses'][1]
# Out:
# {'id': 'YRA2VnhFLChIh1ZD31cXjg',
#  'alias': 'the-british-museum-london',
#  'name': 'The British Museum',
#  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TH9r0NXidmIvPXiA9F1_DQ/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/the-british-museum-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#  'review_count': 1001,
#  'categories': [{'alias': 'museums', 'title': 'Museums'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 51.518298, 'longitude': -0.126026},
#  'transactions': [],
#  'location': {'address1': 'Great Russell Street',
#   'address2': '',
#   'address3': '',
#   'city': 'London',
#   'zip_code': 'WC1B 3DG',
#   'country': 'GB',
#   'state': 'XGL',
#   'display_address': ['Great Russell Street',
#    'London WC1B 3DG',
#    'United Kingdom']},
#  'phone': '+442073238299',
#  'display_phone': '+44 20 7323 8299',
#  'distance': 917.0904070806522}

# %%
#yelp1_df = pd.read_json(yelp_data_1, lines=True)
#print(yelp1_df.to_string())

#yelp_data_1 = "Resources/yelp_academic_dataset_review.json"
#yelp1_df = pd.read_json(yelp_data_1, lines=True)
#yelp1_df = yelp1_df[yelp1_df["state"] == "NY"]
#yelp1_df.head()
