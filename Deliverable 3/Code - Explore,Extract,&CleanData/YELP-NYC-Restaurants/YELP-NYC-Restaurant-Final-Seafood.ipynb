# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"seafood","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': 'YvWQMlMjtYmVmheH97tTlQ',
#    'alias': 'crab-house-all-you-can-eat-seafood-new-york',
#    'name': 'Crab House All You Can Eat Seafood',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1J0qtJbyF3aYyTobEOzjgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crab-house-all-you-can-eat-seafood-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 204,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.759664, 'longitude': -73.969776},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '135 E 55th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['135 E 55th St', 'New York, NY 10022']},
#    'phone': '+12129330264',
#    'display_phone': '(212) 933-0264',
#    'distance': 6382.194727371187},
#   {'id': 'ehUuSk5gPTCQmwS_ubgKRA',
#    'alias': 'upstate-craft-beer-and-oyster-bar-new-york-4',
#    'name': 'Upstate Craft Beer & Oyster Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BhBkw2RWNB7rnlEhES1pPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/upstate-craft-beer-and-oyster-bar-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1926,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.726373, 'longitude': -73.986557},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '95 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['95 1st Ave', 'New York, NY 10003']},
#    'phone': '+16467915400',
#    'display_phone': '(646) 791-5400',
#    'distance': 2416.715359115974},
#   {'id': 'ryvBsB9FrBBZDak87iGS1w',
#    'alias': 'sea-fire-grill-new-york',
#    'name': 'Sea Fire Grill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/exMqPoCEi2btoGtAd8kcIQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sea-fire-grill-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1330,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7547012104496,
#     'longitude': -73.972255513072},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '158 E 48th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['158 E 48th St', 'New York, NY 10017']},
#    'phone': '+12129353785',
#    'display_phone': '(212) 935-3785',
#    'distance': 5783.28147646515},
#   {'id': '6jPju63RQy3P3ov9-ejP7g',
#    'alias': 'sea-wolf-williamsburg-waterfront-brooklyn',
#    'name': 'Sea Wolf - Williamsburg Waterfront',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oTb3rG98tjxLpnfBoxFqcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sea-wolf-williamsburg-waterfront-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 158,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.709946, 'longitude': -73.968608},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '420 Kent Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['420 Kent Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17182332792',
#    'display_phone': '(718) 233-2792',
#    'distance': 2222.127845327241},
#   {'id': 'Roj5hZ0Tq22ruarnGnLiVQ',
#    'alias': 'seaport-house-new-york',
#    'name': 'Seaport House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yrVgba-cz5J4BLdZNCtS1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seaport-house-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.707503, 'longitude': -74.001945},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '229 Front St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['229 Front St', 'New York, NY 10038']},
#    'phone': '+12124335800',
#    'display_phone': '(212) 433-5800',
#    'distance': 678.4354371939112},
#   {'id': 'hfMtSdxRsC3JQP3yrm6nag',
#    'alias': 'claw-daddys-new-york',
#    'name': "Claw Daddy's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RCru71cTtO-TtqRw50rc2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/claw-daddys-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1769,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722071, 'longitude': -73.98847},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '185 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['185 Orchard St', 'New York, NY 10002']},
#    'phone': '+16465906816',
#    'display_phone': '(646) 590-6816',
#    'distance': 1912.7787900899964},
#   {'id': 'wRHUJ69-f4CiV5BRY72mUg',
#    'alias': 'aqua-boil-new-york-2',
#    'name': 'Aqua Boil',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wREsz4nOI5oGdYrRiOG1uA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aqua-boil-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 415,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.763702, 'longitude': -73.988386},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '750 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['750 9th Ave', 'New York, NY 10019']},
#    'phone': '+12124647428',
#    'display_phone': '(212) 464-7428',
#    'distance': 6497.896610888184},
#   {'id': 'WJS06XxRdc6DD1s4LWE9HA',
#    'alias': 'fish-cheeks-new-york',
#    'name': 'Fish Cheeks',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pqupe3fe52869QQ23KkiBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fish-cheeks-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 864,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7258, 'longitude': -73.9927},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '55 Bond St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Bond St', 'New York, NY 10012']},
#    'phone': '+12126772223',
#    'display_phone': '(212) 677-2223',
#    'distance': 2258.7720584764224},
#   {'id': 'LpVbI-E9C-CSp7WhU5h2Iw',
#    'alias': 'fishmarket-restaurant-new-york',
#    'name': 'Fishmarket Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zIPbObERXHKehqV-yU7Wgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fishmarket-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 579,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'divebars', 'title': 'Dive Bars'},
#     {'alias': 'malaysian', 'title': 'Malaysian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70717, 'longitude': -74.00192},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '111 South St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 South St', 'New York, NY 10038']},
#    'phone': '+19173638101',
#    'display_phone': '(917) 363-8101',
#    'distance': 667.9406968270184},
#   {'id': '3xTQT7qjZJIxc-eBiFMerQ',
#    'alias': '1803-new-york',
#    'name': '1803',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/f6_ZYxoZGbyGsCn6m_auog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/1803-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 554,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.715498, 'longitude': -74.007178},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '82 Reade St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['82 Reade St', 'New York, NY 10007']},
#    'phone': '+12122673000',
#    'display_phone': '(212) 267-3000',
#    'distance': 1558.541688391669},
#   {'id': '20LSOx_4K2wghTsUx4gSsg',
#    'alias': 'oceanic-boil-jackson-heights',
#    'name': 'Oceanic Boil',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aF45SWZgZoZsVsBXgEgDig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oceanic-boil-jackson-heights?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 645,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7498297, 'longitude': -73.8821356},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '84-20 37th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['84-20 37th Ave', 'Jackson Heights, NY 11372']},
#    'phone': '+19292966338',
#    'display_phone': '(929) 296-6338',
#    'distance': 10675.873540539471},
#   {'id': 'tiSw-6DIm3-mMORyEIOVyg',
#    'alias': 'the-boil-new-york-3',
#    'name': 'The Boil',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oWCJBXN8cM-nGi83pNqc5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-boil-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1972,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71974, 'longitude': -73.99339},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '139 Chrystie St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['139 Chrystie St', 'New York, NY 10002']},
#    'phone': '+12129258815',
#    'display_phone': '(212) 925-8815',
#    'distance': 1594.3621278980172},
#   {'id': '_eC8r8yMhcmDL7PWmaNK9w',
#    'alias': 'brooklyn-crab-brooklyn',
#    'name': 'Brooklyn Crab',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kt1XVSO400u6pavXnCJQCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-crab-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1071,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.6752649, 'longitude': -74.016568},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '24 Reed St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 Reed St', 'Brooklyn, NY 11231']},
#    'phone': '+17186432722',
#    'display_phone': '(718) 643-2722',
#    'distance': 3845.6254067839172},
#   {'id': 'd7_W8J8T0PESBsILMsGKGQ',
#    'alias': 'sea-wolf-bushwick-brooklyn',
#    'name': 'Sea Wolf - Bushwick',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CaWrPP7G4fuhLPBPulhUcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sea-wolf-bushwick-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 567,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70683, 'longitude': -73.9228},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '19 Wyckoff Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Wyckoff Ave', 'Brooklyn, NY 11237']},
#    'phone': '+18335240925',
#    'display_phone': '(833) 524-0925',
#    'distance': 6029.7881830578535},
#   {'id': 'UA2M9QFZghe-9th2KwLoWQ',
#    'alias': 'burger-and-lobster-flatiron-nyc-new-york',
#    'name': 'Burger & Lobster - Flatiron NYC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y1NYFEnpLG2KuyYDg8IcSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burger-and-lobster-flatiron-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5518,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74007, 'longitude': -73.99344},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '39 W 19th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39 W 19th St', 'New York, NY 10011']},
#    'phone': '+16468337532',
#    'display_phone': '(646) 833-7532',
#    'distance': 3849.54386751767},
#   {'id': 'zZrPKwLnkrRcspqqpUTq5w',
#    'alias': 'royal-and-company-seafood-bar-brooklyn',
#    'name': 'Royal And Company Seafood Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lm-FaJ8FE5H2NTczyoMARg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/royal-and-company-seafood-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71140731134931,
#     'longitude': -73.95795946647044},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '160 Havemeyer St',
#     'address2': 'Ste 5',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['160 Havemeyer St', 'Ste 5', 'Brooklyn, NY 11211']},
#    'phone': '+13478896889',
#    'display_phone': '(347) 889-6889',
#    'distance': 3133.510668932601},
#   {'id': 'CqtT8rPaSmrRClUBbqsCFA',
#    'alias': 'seamore-s-dumbo-brooklyn-3',
#    'name': 'Seamore’s Dumbo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XXwEV9O_w7dgfHi7_1YXqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seamore-s-dumbo-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 136,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'fishnchips', 'title': 'Fish & Chips'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7032, 'longitude': -73.99145},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '66 Water St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['66 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+17186636550',
#    'display_phone': '(718) 663-6550',
#    'distance': 361.28143291784545},
#   {'id': '1x2hn3e9sCCZca1cnRTpEg',
#    'alias': 'claw-daddys-brooklyn',
#    'name': "Claw Daddy's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ABHo2xn4dcpVspJkaQ_g-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/claw-daddys-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 542,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68561, 'longitude': -73.98035},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '31 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31 3rd Ave', 'Brooklyn, NY 11217']},
#    'phone': '+13473188893',
#    'display_phone': '(347) 318-8893',
#    'distance': 2500.3200581143838},
#   {'id': 'Onsn-u5PPx4HG9UVr6hgAA',
#    'alias': 'sup-crab-greenpoint-brooklyn',
#    'name': 'Sup Crab Greenpoint',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vCocClfoYvQcIWQz0jbPqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sup-crab-greenpoint-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72467, 'longitude': -73.95117},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '664 Manhattan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['664 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17188740022',
#    'display_phone': '(718) 874-0022',
#    'distance': 4230.354713894376},
#   {'id': 'DIqsYe-HJS8etyDyXNovBg',
#    'alias': 'seamores-nolita-new-york-2',
#    'name': "Seamore's - Nolita",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ejr8UUJuHkKr9J3y1T3rgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seamores-nolita-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 728,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720673, 'longitude': -73.996911},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '390 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['390 Broome St', 'New York, NY 10013']},
#    'phone': '+12127306005',
#    'display_phone': '(212) 730-6005',
#    'distance': 1707.6037230949792},
#   {'id': '4M3jBdELCcCKJl1mEnTxzQ',
#    'alias': 'lamias-fish-market-new-york-2',
#    'name': "Lamia's Fish Market",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ItJosvmrWmSoci0MHvjzrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lamias-fish-market-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 388,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722979, 'longitude': -73.9825102},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '47 Ave B',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 Ave B', 'New York, NY 10009']},
#    'phone': '+12127773650',
#    'display_phone': '(212) 777-3650',
#    'distance': 2188.0590330253954},
#   {'id': 'TfJb2hS3Fem2nkIyz13KUA',
#    'alias': 'ama-raw-bar-new-york',
#    'name': 'Ama Raw Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XYm9cqJ5EQ0XOC_mZAM4oA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ama-raw-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.727996, 'longitude': -73.979324},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '190 Avenue B',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['190 Avenue B', 'New York, NY 10009']},
#    'phone': '+12128459896',
#    'display_phone': '(212) 845-9896',
#    'distance': 2808.2117690400446},
#   {'id': 'nOjGNqPcu5jHRRElOndQqQ',
#    'alias': 'red-hook-lobster-pound-brooklyn',
#    'name': 'Red Hook Lobster Pound',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xI2_dAdb-PbiKCLsscJcrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/red-hook-lobster-pound-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1186,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6797687107191,
#     'longitude': -74.0103686973453},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '284 Van Brunt St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['284 Van Brunt St', 'Brooklyn, NY 11231']},
#    'phone': '+17188587650',
#    'display_phone': '(718) 858-7650',
#    'distance': 3160.4176259685423},
#   {'id': '82wA_Vfg_eDckx23d3dA_g',
#    'alias': 'sel-rrose-new-york-4',
#    'name': 'Sel Rrose',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W5htr0pnmEEAclCduLyyKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sel-rrose-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 543,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7200099, 'longitude': -73.993839},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1 Delancey St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Delancey St', 'New York, NY 10002']},
#    'phone': '+16464502557',
#    'display_phone': '(646) 450-2557',
#    'distance': 1620.0086688769934},
#   {'id': 'O4rYM6YBj90W2u7RhG3Mvg',
#    'alias': 'maison-premiere-brooklyn',
#    'name': 'Maison Premiere',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sYBR9fpPCOcYF6mE6eQ2MA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maison-premiere-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1150,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7142634, 'longitude': -73.96166459999999},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '298 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['298 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+13478895710',
#    'display_phone': '(347) 889-5710',
#    'distance': 2919.7865394988276},
#   {'id': 'aSFBv64GBpMOFPqIleeQFQ',
#    'alias': 'lure-fishbar-new-york-2',
#    'name': 'Lure Fishbar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zh47yiTYJdmzLGJ70oT92w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lure-fishbar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1733,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.724612166991, 'longitude': -73.998574708004},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '142 Mercer St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['142 Mercer St', 'New York, NY 10012']},
#    'phone': '+12124317676',
#    'display_phone': '(212) 431-7676',
#    'distance': 2161.6364530898604},
#   {'id': 'FLH_mRRrTRUjRURDAxX27Q',
#    'alias': 'juicy-king-crab-express-new-york-2',
#    'name': 'Juicy King Crab Express',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6PW244AzUEJJf4kl-CUyAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/juicy-king-crab-express-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.714043, 'longitude': -73.987546},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '213 East Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['213 East Broadway', 'New York, NY 10002']},
#    'phone': '+19176393088',
#    'display_phone': '(917) 639-3088',
#    'distance': 1107.8362585055293},
#   {'id': 'vQcK7BH6maW9dAZWJOuW3Q',
#    'alias': 'the-mermaid-inn-new-york-2',
#    'name': 'The Mermaid Inn',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/clu1t11N921Td56I55DZCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mermaid-inn-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1182,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7887398925594,
#     'longitude': -73.9744491607132},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '570 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['570 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12127997400',
#    'display_phone': '(212) 799-7400',
#    'distance': 9411.62511601298},
#   {'id': 'kxykwx5qTWBhlMh18MQ82Q',
#    'alias': 'lukes-lobster-fidi-new-york',
#    'name': "Luke's Lobster FiDi",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C5NV5lfsLo2nJDkx3Or9ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lukes-lobster-fidi-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1177,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7046213003984,
#     'longitude': -74.0107793876969},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '26 S William St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 S William St', 'New York, NY 10004']},
#    'phone': '+12127471700',
#    'display_phone': '(212) 747-1700',
#    'distance': 1392.7033987694713},
#   {'id': 'zfiXI8AwYBRfWjPyv6oh3w',
#    'alias': 'the-lobster-place-new-york-2',
#    'name': 'The Lobster Place',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zgCitW9dNXpxlehrZuGBTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lobster-place-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1371,
#    'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7427413905213,
#     'longitude': -74.0060118057704},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '75 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 9th Ave', 'New York, NY 10011']},
#    'phone': '+12122555672',
#    'display_phone': '(212) 255-5672',
#    'distance': 4263.133873590816},
#   {'id': 'RrNe_0PReWHXAnjTEXBikQ',
#    'alias': 'lukes-lobster-brooklyn-bridge-park-brooklyn-2',
#    'name': "Luke's Lobster Brooklyn Bridge Park",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hjZVNfkTCmWKE1lTo1G2Vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lukes-lobster-brooklyn-bridge-park-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 364,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70359, 'longitude': -73.99411},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '11 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+19178827516',
#    'display_phone': '(917) 882-7516',
#    'distance': 219.32290848983465},
#   {'id': 'LOeDR4X-YRToeo3hy_plew',
#    'alias': 'the-fulton-new-york-2',
#    'name': 'The Fulton',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kP38Nn_d68EI3odmAo74Pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-fulton-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 269,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7053694327276, 'longitude': -74.00123},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '89 S St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['89 S St', 'New York, NY 10038']},
#    'phone': '+12128381200',
#    'display_phone': '(212) 838-1200',
#    'distance': 584.7879883568789},
#   {'id': 'bjDS88i1DNc0tcean2LXjA',
#    'alias': 'hook-and-reel-cajun-seafood-and-bar-brooklyn-5',
#    'name': 'Hook & Reel Cajun Seafood & Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4sYUKbBs2BA0p-wVJmmiVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hook-and-reel-cajun-seafood-and-bar-brooklyn-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 75,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69088, 'longitude': -73.98378},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '430 Albee Square W',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['430 Albee Square W', 'Brooklyn, NY 11201']},
#    'phone': '+19293970031',
#    'display_phone': '(929) 397-0031',
#    'distance': 1847.135174020232},
#   {'id': 'ns-qepGEEcDpTiEr2FBEXA',
#    'alias': 'dame-new-york-2',
#    'name': 'Dame',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5PIjs0hhwBzM_3Y5MyaL5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dame-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7289445, 'longitude': -74.0015073},
#    'transactions': ['delivery'],
#    'location': {'address1': '87 MacDougal St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['87 MacDougal St', 'New York, NY 10012']},
#    'phone': '+19293677370',
#    'display_phone': '(929) 367-7370',
#    'distance': 2682.8384096049986},
#   {'id': 'afbl_jCNpomzJiDBdomb6g',
#    'alias': 'oceans-new-york-new-york',
#    'name': 'Oceans New York',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y38Y96GsQPkEdbXuVeA2LA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oceans-new-york-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 103,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.737408, 'longitude': -73.987887},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '233 Park Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['233 Park Ave S', 'New York, NY 10003']},
#    'phone': '+12122091055',
#    'display_phone': '(212) 209-1055',
#    'distance': 3601.010994120371},
#   {'id': 'MYh3iKpuo1HQUoHUyzA0BQ',
#    'alias': 'bar-crudo-brooklyn-2',
#    'name': 'Bar Crudo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cgPPQ_01TaMNKdPxTJaItQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-crudo-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 154,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.670226, 'longitude': -73.985768},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '412 Fifth Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['412 Fifth Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187011894',
#    'display_phone': '(718) 701-1894',
#    'distance': 3981.5773244219467},
#   {'id': '8DV1myPrW7SePZOK46IjLQ',
#    'alias': 'lady-chows-kitchen-new-york',
#    'name': "Lady Chow's Kitchen",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VbBM-DpFJ9TkGo4yRre52w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lady-chows-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71785, 'longitude': -73.9968},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '171 Hester St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 Hester St', 'New York, NY 10013']},
#    'phone': '+12123439496',
#    'display_phone': '(212) 343-9496',
#    'distance': 1399.7906969149235},
#   {'id': '0LKC_M1bumyOcgWgbH9OdQ',
#    'alias': 'crave-fishbar-new-york-2',
#    'name': 'Crave Fishbar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ad4JKXDQfhsNl3IckwCvRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crave-fishbar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 301,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78428, 'longitude': -73.97772},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '428 Amsterdam Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['428 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+16464942750',
#    'display_phone': '(646) 494-2750',
#    'distance': 8875.49035877127},
#   {'id': 'mPOa5FLgjWrK3k6yxBGQnw',
#    'alias': 'the-clam-new-york',
#    'name': 'The Clam',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HdOqIHjBYK8pqySr2R3u2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-clam-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 401,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7303076612002,
#     'longitude': -74.0068030357639},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '420 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['420 Hudson St', 'New York, NY 10014']},
#    'phone': '+12122427420',
#    'display_phone': '(212) 242-7420',
#    'distance': 2958.8246183685505},
#   {'id': 'dYm7DXMy1r8kCmKiz1MO8w',
#    'alias': 'crave-fishbar-new-york',
#    'name': 'Crave Fishbar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/95W_wJ1gX-oZtd1WaYoX4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crave-fishbar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 749,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.755136, 'longitude': -73.968683},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '945 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['945 2nd Ave', 'New York, NY 10022']},
#    'phone': '+16468959585',
#    'display_phone': '(646) 895-9585',
#    'distance': 5931.850746703516},
#   {'id': 'H_KyiRhwho8rdlw_R93_0Q',
#    'alias': 'marea-new-york',
#    'name': 'Marea',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-7_hUV0_zqVzsbqNOJ_iMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marea-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2157,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7674213694566,
#     'longitude': -73.9810554368179},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '240 Central Park S',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['240 Central Park S', 'New York, NY 10019']},
#    'phone': '+12125825100',
#    'display_phone': '(212) 582-5100',
#    'distance': 6981.13750343581},
#   {'id': 'E9NMNWvV70HV5gB369N0EA',
#    'alias': 'nerai-new-york',
#    'name': 'Nerai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WXgS2EwgJLkTLWD2PS3bmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nerai-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 566,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76028044523875,
#     'longitude': -73.97306024442727},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '55 E 54th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 E 54th St', 'New York, NY 10022']},
#    'phone': '+12127595554',
#    'display_phone': '(212) 759-5554',
#    'distance': 6354.481726623936},
#   {'id': 'UvQr8V1dD_d6yRsMJi04wA',
#    'alias': 'shaking-crab-brooklyn-brooklyn-2',
#    'name': 'Shaking Crab- Brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cvhgQU_UDdG-MYe9MZCwag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shaking-crab-brooklyn-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 355,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.675783, 'longitude': -73.981205},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '230 5th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['230 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+19293376140',
#    'display_phone': '(929) 337-6140',
#    'distance': 3479.335561241081},
#   {'id': 'C3tP0fNNAoxOAC3O406CXQ',
#    'alias': 'le-sia-new-york-4',
#    'name': 'Le Sia',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Hqr4G8WYzkjqHOr_VOQyKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-sia-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 71,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76072, 'longitude': -73.99119},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '651 9th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['651 9th Ave', 'New York, NY 10036']},
#    'phone': '+16465595220',
#    'display_phone': '(646) 559-5220',
#    'distance': 6155.955879295095},
#   {'id': 'z5EpI39omxW6aK_X2uHi8A',
#    'alias': 'lobster-joint-brooklyn',
#    'name': 'Lobster Joint',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mqStg2ixrTyqOPTQWnqaFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lobster-joint-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 673,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7354, 'longitude': -73.95528},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1073 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1073 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183898990',
#    'display_phone': '(718) 389-8990',
#    'distance': 4676.725389301891},
#   {'id': 'CcxreLJbZsO6Z775-hMWpw',
#    'alias': 'st-tropez-west-village-new-york-3',
#    'name': 'St Tropez West Village',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/T4TolJBuIlUIoEWaWm091g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-tropez-west-village-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 202,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73704, 'longitude': -74.00386},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '304 W 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['304 W 4th St', 'New York, NY 10014']},
#    'phone': '+19173883893',
#    'display_phone': '(917) 388-3893',
#    'distance': 3606.8808422406223},
#   {'id': 'F89nDDlYZ7wbRe8EpLCqBw',
#    'alias': 'avra-estiatorio-new-york-3',
#    'name': 'Avra Estiatorio',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KOWgG7f1MsuxwS3YvajWfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/avra-estiatorio-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 901,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75503581588927,
#     'longitude': -73.97244109270292},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '141 E 48th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['141 E 48th St', 'New York, NY 10017']},
#    'phone': '+12127598550',
#    'display_phone': '(212) 759-8550',
#    'distance': 5813.556832137099},
#   {'id': 'S-BwjmHOZ--bC4nUR4-cmA',
#    'alias': 'oceana-new-york-2',
#    'name': 'Oceana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8MXXNdJbQzOYsdd0dgvefg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oceana-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 540,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7597971248568,
#     'longitude': -73.9825657859833},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '120 W 49th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10020',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['120 W 49th St', 'New York, NY 10020']},
#    'phone': '+12127595941',
#    'display_phone': '(212) 759-5941',
#    'distance': 6123.93709198735},
#   {'id': 'T-RXDLq_VEv7s1_SooYIYQ',
#    'alias': 'osteria-57-new-york',
#    'name': 'Osteria 57',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KD1qrK51WILJwl4mwp6g1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osteria-57-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 207,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73467, 'longitude': -73.99786},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '57 W 10th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['57 W 10th St', 'New York, NY 10011']},
#    'phone': '+12127770057',
#    'display_phone': '(212) 777-0057',
#    'distance': 3264.8135124375995},
#   {'id': '3Gz07E5YJjDTJPSuzsAStQ',
#    'alias': 'ocean-prime-new-york',
#    'name': 'Ocean Prime',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BvJyC5c1n3ZZ0LKD14-BVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ocean-prime-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 634,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7617438, 'longitude': -73.9805565},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '123 W 52nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['123 W 52nd St', 'New York, NY 10019']},
#    'phone': '+12129561404',
#    'display_phone': '(212) 956-1404',
#    'distance': 6366.247532326245}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                            Restaurant     Type Price Rating        Address  \
# 0  Crab House All You Can Eat Seafood  Buffets  $$$$    4.5  135 E 55th St
# 1     Upstate Craft Beer & Oyster Bar  Seafood    $$    4.5     95 1st Ave
# 2                      Sea Fire Grill  Seafood   $$$    4.5  158 E 48th St
# 3  Sea Wolf - Williamsburg Waterfront  Seafood   $$$      4   420 Kent Ave
# 4                       Seaport House  Seafood    $$      4   229 Front St
#
#          Lat        Lng                                                url  \
# 0  40.759664 -73.969776  https://www.yelp.com/biz/crab-house-all-you-ca...
# 1  40.726373 -73.986557  https://www.yelp.com/biz/upstate-craft-beer-an...
# 2  40.754701 -73.972256  https://www.yelp.com/biz/sea-fire-grill-new-yo...
# 3  40.709946 -73.968608  https://www.yelp.com/biz/sea-wolf-williamsburg...
# 4  40.707503 -74.001945  https://www.yelp.com/biz/seaport-house-new-yor...
#
#                        ID
# 0  YvWQMlMjtYmVmheH97tTlQ
# 1  ehUuSk5gPTCQmwS_ubgKRA
# 2  ryvBsB9FrBBZDak87iGS1w
# 3  6jPju63RQy3P3ov9-ejP7g
# 4  Roj5hZ0Tq22ruarnGnLiVQ

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"seafood","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': 'FG3toTBOTyfVTePW5RuWSw',
#    'alias': 'jeffreys-grocery-new-york',
#    'name': "Jeffrey's Grocery",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AR1PjdV_LAG8e2eBbpdmhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jeffreys-grocery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 462,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73399, 'longitude': -74.00137},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '172 Waverly Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['172 Waverly Pl', 'New York, NY 10014']},
#    'phone': '+16463987630',
#    'display_phone': '(646) 398-7630',
#    'distance': 3233.6475500898846},
#   {'id': 'sEuLm5fQgWkkiYBt6OphWQ',
#    'alias': 'greenpoint-fish-and-lobster-brooklyn',
#    'name': 'Greenpoint Fish & Lobster',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/46ATFZXJgEkEGZXDmksiUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greenpoint-fish-and-lobster-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 352,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'seafoodmarkets', 'title': 'Seafood Markets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.724128, 'longitude': -73.9491199},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '114 Nassau Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['114 Nassau Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183131913',
#    'display_phone': '(718) 313-1913',
#    'distance': 4337.204417405035},
#   {'id': '2LcsDUTlvovnFz-SEcSJTQ',
#    'alias': 'astoria-seafood-long-island-city',
#    'name': 'Astoria Seafood',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1JpV37tvXerudsIowCpMMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/astoria-seafood-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 776,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.754, 'longitude': -73.9298699},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '37-10 33rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37-10 33rd St', 'Long Island City, NY 11101']},
#    'phone': '+17183922680',
#    'display_phone': '(718) 392-2680',
#    'distance': 7657.624763799523},
#   {'id': 'Dr_eezrA2Cc_azMYnwhRkA',
#    'alias': 'sup-crab-new-york',
#    'name': 'Sup Crab',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Mm3E6skVDm2hw-G9hQe_hw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sup-crab-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 374,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71733, 'longitude': -73.99502},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '97 Bowery',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['97 Bowery', 'New York, NY 10002']},
#    'phone': '+12129258083',
#    'display_phone': '(212) 925-8083',
#    'distance': 1327.6547690924829},
#   {'id': '5CuYWr0-cE01HxlBu5Ka6g',
#    'alias': 'carne-mare-new-york-5',
#    'name': 'Carne Mare',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tFR0OcGHVFVpHIKr9fee6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carne-mare-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70634, 'longitude': -74.00383},
#    'transactions': ['delivery'],
#    'location': {'address1': '89 South St',
#     'address2': '',
#     'address3': 'Pier 17',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['89 South St', 'Pier 17', 'New York, NY 10038']},
#    'phone': '+12122804600',
#    'display_phone': '(212) 280-4600',
#    'distance': 633.1849803021449},
#   {'id': '91x-8L9T5dfGJHFK79bEQA',
#    'alias': 'naughty-crab-new-york-2',
#    'name': 'Naughty Crab',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6WK6plhvOiFpyUrJKGeLGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/naughty-crab-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 134,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78979, 'longitude': -73.94789},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'location': {'address1': '1621 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1621 Lexington Ave', 'New York, NY 10029']},
#    'phone': '+16467264446',
#    'display_phone': '(646) 726-4446',
#    'distance': 10156.235066463374},
#   {'id': 'rHmeJVffuj96M7jbB-wWgw',
#    'alias': 'flex-mussels-new-york-2',
#    'name': 'Flex Mussels',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/R0Cg3ZkLRl9Ki3IepW0-7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flex-mussels-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 918,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.737437, 'longitude': -73.999661},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '154 W 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['154 W 13th St', 'New York, NY 10011']},
#    'phone': '+12122290222',
#    'display_phone': '(212) 229-0222',
#    'distance': 3586.005573163622},
#   {'id': 'C7s1ohdoF8UtToowLsdIsQ',
#    'alias': 'cobble-fish-new-york-2',
#    'name': 'Cobble Fish',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/btDfqqmCTDsd43Udnreuaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cobble-fish-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70530194592761,
#     'longitude': -74.00257774322735},
#    'transactions': [],
#    'location': {'address1': '89 South St',
#     'address2': 'Pier 16',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['89 South St', 'Pier 16', 'New York, NY 10038']},
#    'phone': '+12122102997',
#    'display_phone': '(212) 210-2997',
#    'distance': 698.5153237996998},
#   {'id': 'apykLG7DTZ-7xnOcZGDZZA',
#    'alias': 'taverna-kyclades-east-village-new-york-2',
#    'name': 'Taverna Kyclades - East Village',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bs7AH0uB2FzHtQu4kSfuCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taverna-kyclades-east-village-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 870,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.731019969685164,
#     'longitude': -73.98260448877211},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '228 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 1st Ave', 'New York, NY 10009']},
#    'phone': '+12124320011',
#    'display_phone': '(212) 432-0011',
#    'distance': 3009.6047537923587},
#   {'id': 'FCms-eFFxnpMLm09AJridQ',
#    'alias': 'peaches-shrimp-and-crab-brooklyn-4',
#    'name': 'Peaches Shrimp and Crab',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/p2LRJdgHfH3BtN8tjUUZ9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peaches-shrimp-and-crab-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 345,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'southern', 'title': 'Southern'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6879838, 'longitude': -73.9625478},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '285 Grand Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['285 Grand Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17186389500',
#    'display_phone': '(718) 638-9500',
#    'distance': 3299.556430300149},
#   {'id': '6dSiCqC9x51PZRMOvdQTpA',
#    'alias': 'pearl-oyster-bar-new-york',
#    'name': 'Pearl Oyster Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lswnCz8yidaaIGZdnpPKmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pearl-oyster-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 834,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7314099, 'longitude': -74.00197},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '18 Cornelia St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18 Cornelia St', 'New York, NY 10014']},
#    'phone': '+12126918211',
#    'display_phone': '(212) 691-8211',
#    'distance': 2949.5670912279784},
#   {'id': 'q11TljTQd33XCWlVoPyRqg',
#    'alias': 'the-osprey-brooklyn',
#    'name': 'The Osprey',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/38J6wCRITFIWiRtWhE_sJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-osprey-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 240,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.702241, 'longitude': -73.995539},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '60 Furman St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Furman St', 'Brooklyn, NY 11201']},
#    'phone': '+13476962505',
#    'display_phone': '(347) 696-2505',
#    'distance': 367.7475436977597},
#   {'id': 'ur73cho5J-1IrhPYVZrNew',
#    'alias': 'jibs-new-york',
#    'name': 'Jibs',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qlFC61wrL9pQaZrssC1eBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jibs-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.754070046953146, 'longitude': -74.0026987},
#    'transactions': [],
#    'location': {'address1': '350 11th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['350 11th Ave', 'New York, NY 10001']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5453.060145151431},
#   {'id': '-bdxB20YveudeyL63chscg',
#    'alias': 'cull-and-pistol-oyster-bar-new-york',
#    'name': 'Cull & Pistol Oyster Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Uvh5Uzb5LusBB2yQjAmYVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cull-and-pistol-oyster-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 636,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7426589397899,
#     'longitude': -74.0059285394953},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '75 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 9th Ave', 'New York, NY 10011']},
#    'phone': '+16465681223',
#    'display_phone': '(646) 568-1223',
#    'distance': 4252.592476927422},
#   {'id': '7OMGEtFWT6sdd9TVuoGqJQ',
#    'alias': 'okonomi-brooklyn',
#    'name': 'Okonomi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RMSBnhoB5aHc-3CUSwULgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/okonomi-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 466,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.712622, 'longitude': -73.9487843},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '150 Ainslie St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 Ainslie St', 'Brooklyn, NY 11211']},
#    'phone': '+19292950480',
#    'display_phone': '(929) 295-0480',
#    'distance': 3918.0469578683437},
#   {'id': 'nGyffNA23K4sO08rKB2E5g',
#    'alias': 'goodnight-sonny-new-york-3',
#    'name': 'Goodnight Sonny',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MFiw5153Ysrlsjf9fNf9dA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/goodnight-sonny-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 282,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72768, 'longitude': -73.98502},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '134 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['134 1st Ave', 'New York, NY 10009']},
#    'phone': '+16466923254',
#    'display_phone': '(646) 692-3254',
#    'distance': 2595.0475117274095},
#   {'id': 'wwYJlPAg4_DV_DihANcuOw',
#    'alias': 'estuary-new-york-2',
#    'name': 'Estuary',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vwQ2qdgycjJqtW84R0W_9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/estuary-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6932355, 'longitude': -74.0007940774},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '159 Bridge Park Dr',
#     'address2': '',
#     'address3': 'Brooklyn Bridge Park',
#     'city': 'New York',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['159 Bridge Park Dr',
#      'Brooklyn Bridge Park',
#      'New York, NY 11201']},
#    'phone': '+17185216744',
#    'display_phone': '(718) 521-6744',
#    'distance': 1464.057918260259},
#   {'id': 'L3REPLCvQpMapYPd_fkS-A',
#    'alias': 'los-mariscos-new-york',
#    'name': 'Los Mariscos',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/miAqlvuZ-SEdViMIAbHkeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-mariscos-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 659,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74207, 'longitude': -74.00565},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '409 W 15th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['409 W 15th St', 'New York, NY 10011']},
#    'phone': '+12129204986',
#    'display_phone': '(212) 920-4986',
#    'distance': 4183.62631647822},
#   {'id': 'enT7NJ7tLMvUMCWQcsUonw',
#    'alias': 'mémé-mediterranean-new-york-4',
#    'name': 'Mémé Mediterranean',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TCo41uZ7WhL5MwMMjZ-RKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/m%C3%A9m%C3%A9-mediterranean-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 635,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.736412, 'longitude': -74.00616},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '581 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['581 Hudson St', 'New York, NY 10014']},
#    'phone': '+16466928450',
#    'display_phone': '(646) 692-8450',
#    'distance': 3585.669092216312},
#   {'id': 'uAy3zyNCmDPO0RpdGjEAdg',
#    'alias': 'the-crabby-shack-brooklyn',
#    'name': 'The Crabby Shack',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gsEB4ju8jGv65sLS8WKcZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-crabby-shack-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 738,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6772748759876,
#     'longitude': -73.9554135086263},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '613 Franklin Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['613 Franklin Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17184841507',
#    'display_phone': '(718) 484-1507',
#    'distance': 4533.981468504624},
#   {'id': 'FRp1NwIyp6tkDU986cJkXQ',
#    'alias': 'piccola-cucina-estiatorio-new-york',
#    'name': 'Piccola Cucina Estiatorio',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3ToLESKv0zNdwXOIYfqqcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piccola-cucina-estiatorio-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 150,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7246, 'longitude': -74.0029799},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '75 Thompson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 Thompson St', 'New York, NY 10012']},
#    'phone': '+16467819183',
#    'display_phone': '(646) 781-9183',
#    'distance': 2254.742845482553},
#   {'id': 'diz6_4TVSP6EdWEZCZ0Acg',
#    'alias': 'kaoru-new-york',
#    'name': 'Kaoru',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2N5uZFepOyyo0-BycQHPLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaoru-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 405,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75202, 'longitude': -73.96977},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '306 E 46th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['306 E 46th St', 'New York, NY 10017']},
#    'phone': '+12128670874',
#    'display_phone': '(212) 867-0874',
#    'distance': 5572.160826301359},
#   {'id': '-P7qAIG1wr_gXW3nzIq5TA',
#    'alias': 'flex-mussels-new-york',
#    'name': 'Flex Mussels',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fn3WR4CEnzShLCFoST_SaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flex-mussels-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1041,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77637, 'longitude': -73.95646},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '174 East 82nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['174 East 82nd St', 'New York, NY 10028']},
#    'phone': '+12127177772',
#    'display_phone': '(212) 717-7772',
#    'distance': 8499.598661615579},
#   {'id': 'ZEhxsE-6Xi18cSVwp4trnA',
#    'alias': 'surf-city-jersey-city',
#    'name': 'Surf City',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/t70B1bvGWYXr3fd64jPi_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/surf-city-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 672,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7115267158165, 'longitude': -74.04279719803},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1 Marin Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1 Marin Blvd', 'Jersey City, NJ 07302']},
#    'phone': '+12015169000',
#    'display_phone': '(201) 516-9000',
#    'distance': 4143.948215881573},
#   {'id': 'nC4HwtW5_nDICBAVPqN9pw',
#    'alias': 'sagaponack-new-york-4',
#    'name': 'Sagaponack',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xBbcndDJx5iPdLNy2nkJ1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sagaponack-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 382,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.740922, 'longitude': -73.990789},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '4 W 22nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4 W 22nd St', 'New York, NY 10010']},
#    'phone': '+12122292226',
#    'display_phone': '(212) 229-2226',
#    'distance': 3957.5096807378354},
#   {'id': 'wTQYOTh9_JPI2I8s6Xc-Cw',
#    'alias': 'pineapple-club-new-york',
#    'name': 'Pineapple Club',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9zSCg2vxqRdZmaNoSsrDig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pineapple-club-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 127,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72529189450972,
#     'longitude': -73.98324323292351},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '509 E 6th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['509 E 6th St', 'New York, NY 10009']},
#    'phone': '+12126978600',
#    'display_phone': '(212) 697-8600',
#    'distance': 2395.3449467702417},
#   {'id': 'wx9mXol6jOrUoAK4vaFS9Q',
#    'alias': 'mission-ceviche-new-york-3',
#    'name': 'Mission Ceviche',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/e7KmYUqKcBIxGQXbbP85BQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mission-ceviche-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 413,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7692325, 'longitude': -73.9578759},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '1400 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1400 2nd Ave', 'New York, NY 10021']},
#    'phone': '+12126500014',
#    'display_phone': '(212) 650-0014',
#    'distance': 7715.020998303233},
#   {'id': '0087AC_NnFRtC0c9FsB9pw',
#    'alias': 'the-boil-new-york-5',
#    'name': 'The Boil',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lzFeR6PJ2JH9LzdHVYUILQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-boil-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 840,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.730316162745154,
#     'longitude': -73.99429517055144},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '17 Waverly Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 Waverly Pl', 'New York, NY 10003']},
#    'phone': '+16468337110',
#    'display_phone': '(646) 833-7110',
#    'distance': 2765.559127548041},
#   {'id': 'lOSerKI9Xh4tR5I4YUw9kw',
#    'alias': 'saint-julivert-brooklyn',
#    'name': 'Saint Julivert',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iy4Wm0esQWKgV435qDgNVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saint-julivert-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68787, 'longitude': -73.99565},
#    'transactions': ['delivery'],
#    'location': {'address1': '264 Clinton St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['264 Clinton St', 'Brooklyn, NY 11201']},
#    'phone': '+13479873710',
#    'display_phone': '(347) 987-3710',
#    'distance': 1956.454530601177},
#   {'id': 'XpAZBiSrLNi0t332tWxYcQ',
#    'alias': 'acme-smoked-fish-brooklyn',
#    'name': 'Acme Smoked Fish',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MzabtjAsxeDPxDFnlf9kCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/acme-smoked-fish-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 144,
#    'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72542, 'longitude': -73.95662},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '30 Gem St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30 Gem St', 'Brooklyn, NY 11222']},
#    'phone': '+17183838585',
#    'display_phone': '(718) 383-8585',
#    'distance': 3888.530763674833},
#   {'id': 'wVzUbIffBw0oJRZ-Eiz59Q',
#    'alias': 'nicks-lobster-house-brooklyn',
#    'name': "Nick's Lobster House",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oP46KSfs-AVi5XEj1rYMLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nicks-lobster-house-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 478,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6035857241758,
#     'longitude': -73.9152159388703},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '2777 Flatbush Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11234',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2777 Flatbush Ave', 'Brooklyn, NY 11234']},
#    'phone': '+17182537117',
#    'display_phone': '(718) 253-7117',
#    'distance': 13144.681413955972},
#   {'id': 'cdoYC58vXUvaTkp3Cl-wnQ',
#    'alias': 'just-beclaws-jersey-city',
#    'name': 'Just BeClaws',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Zl22B1lIJEOHSPBJV72zcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/just-beclaws-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 806,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7221345, 'longitude': -74.0465332},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '280 1st St',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['280 1st St', 'Jersey City, NJ 07302']},
#    'phone': '+12014599100',
#    'display_phone': '(201) 459-9100',
#    'distance': 4778.071525138939},
#   {'id': 'IQhtCTvorekeqbJr4Zf0Lg',
#    'alias': 'cervos-new-york',
#    'name': "Cervo's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/znFYfqwqYyDpb0Ql_z_dpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cervos-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 79,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7149, 'longitude': -73.99132},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '43 Canal St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43 Canal St', 'New York, NY 10002']},
#    'phone': '+12122262545',
#    'display_phone': '(212) 226-2545',
#    'distance': 1080.816804171965},
#   {'id': 'K7gNRpP7FdEITs0GgrKfUw',
#    'alias': 'the-boil-jersey-city',
#    'name': 'The Boil',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_hlGB2efauSnB0D40n1omA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-boil-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 158,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72128, 'longitude': -74.04407},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '8 Erie St',
#     'address2': '',
#     'address3': None,
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['8 Erie St', 'Jersey City, NJ 07302']},
#    'phone': '+12014790808',
#    'display_phone': '(201) 479-0808',
#    'distance': 4563.428224893734},
#   {'id': '3QHorfZEArlrlCbVE1myjQ',
#    'alias': 'juicy-king-crab-express-brooklyn-2',
#    'name': 'Juicy King Crab Express',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Idz1E4OJiWoXPabHW3Y4DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/juicy-king-crab-express-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.693554, 'longitude': -73.929594},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1126 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1126 Broadway', 'Brooklyn, NY 11221']},
#    'phone': '+17184847568',
#    'display_phone': '(718) 484-7568',
#    'distance': 5611.992422736418},
#   {'id': 'vYGi3439teYg1wPzqVcHUA',
#    'alias': 'grand-banks-new-york',
#    'name': 'Grand Banks',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9hy6CbL20ngCm4QHCMvwVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grand-banks-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 671,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.716745, 'longitude': -74.009397},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Pier 25',
#     'address2': '',
#     'address3': 'Hudson River Park',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Pier 25', 'Hudson River Park', 'New York, NY 10013']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2364.049400241822},
#   {'id': '1vAMfzO6i89lDayBT1zlLA',
#    'alias': 'the-folly-new-york',
#    'name': 'The Folly',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KoOcXLKLBiWkjuOuOk_rPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-folly-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 228,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72721, 'longitude': -74.00004},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '92 W Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['92 W Houston St', 'New York, NY 10012']},
#    'phone': '+16467264740',
#    'display_phone': '(646) 726-4740',
#    'distance': 2472.2681869528856},
#   {'id': 'e1d40LtcHu8WU4iaJxLdVw',
#    'alias': 'hooked-jc-jersey-city',
#    'name': 'Hooked JC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/948GofYVYRj9PJj5l_kU8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hooked-jc-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 562,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7146930849064,
#     'longitude': -74.0670708676607},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '467 Communipaw Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Jersey City',
#     'zip_code': '07304',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['467 Communipaw Ave', 'Jersey City, NJ 07304']},
#    'phone': '+12019464177',
#    'display_phone': '(201) 946-4177',
#    'distance': 6219.871958057928},
#   {'id': 'Oq1mej1BYfjcdPKkM_5o8g',
#    'alias': 'high-street-on-hudson-new-york',
#    'name': 'High Street On Hudson',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FvKsbK7g79UVFYyyzqNeYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/high-street-on-hudson-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 427,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73888, 'longitude': -74.00574},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '637 Hudson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['637 Hudson St', 'New York, NY 10014']},
#    'phone': '+19173883944',
#    'display_phone': '(917) 388-3944',
#    'distance': 3843.1955727088894},
#   {'id': 'e5qXalUNGVoee2NsaDy-cQ',
#    'alias': 'seamores-brookfield-new-york',
#    'name': "Seamore's Brookfield",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eDcohavX0HUMqLgxHZ41Tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seamores-brookfield-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 152,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7141804777842,
#     'longitude': -74.0155678242445},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '250 Vesey St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10281',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['250 Vesey St', 'New York, NY 10281']},
#    'phone': '+16465857380',
#    'display_phone': '(646) 585-7380',
#    'distance': 2039.3847303746452},
#   {'id': 'VmgvCsAP6vZ3DL1mw8ugWQ',
#    'alias': 'osteria-del-porto-new-york',
#    'name': 'Osteria Del Porto',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YoBFIx8Zzk5y1IBFaVmGnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osteria-del-porto-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70737443140159,
#     'longitude': -74.00270427364536},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '212 Front St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['212 Front St', 'New York, NY 10038']},
#    'phone': '+16465906053',
#    'display_phone': '(646) 590-6053',
#    'distance': 740.7433933770113},
#   {'id': 'FiRB9Ek3Xo9JHwXgBYITYg',
#    'alias': 'la-sirène-soho-new-york',
#    'name': 'La Sirène-Soho',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L7cSgPVmrKJosZatGJKvBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-sir%C3%A8ne-soho-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1636,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7243642217227,
#     'longitude': -74.005708694458},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '558 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['558 Broome St', 'New York, NY 10013']},
#    'phone': '+12129253061',
#    'display_phone': '(212) 925-3061',
#    'distance': 2313.301948098778},
#   {'id': 'JNQd6YR1hCAM1nqCTBwvGw',
#    'alias': 'essex-pearl-new-york',
#    'name': 'Essex Pearl',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gwx7hJ6GvAm4SqGM5zxQFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/essex-pearl-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'seafoodmarkets', 'title': 'Seafood Markets'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.717871, 'longitude': -73.988199},
#    'transactions': ['delivery'],
#    'location': {'address1': '115 Delancey St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['115 Delancey St', 'New York, NY 10002']},
#    'phone': '+13478994998',
#    'display_phone': '(347) 899-4998',
#    'distance': 1474.1089526259302},
#   {'id': 'pREotiEdCIV1GKSp_pLgNA',
#    'alias': 'somtum-der-redhook-new-york',
#    'name': 'Somtum Der Redhook',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7mfP_Ys2VkbVf-7wrIyhWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/somtum-der-redhook-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67707, 'longitude': -74.01343},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'location': {'address1': '380 Van Brunt St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['380 Van Brunt St', 'New York, NY 11231']},
#    'phone': '+13472277889',
#    'display_phone': '(347) 227-7889',
#    'distance': 3544.596057643579},
#   {'id': 'lRbJGqIFwA6uTEkKb52diw',
#    'alias': 'goodas-bar-and-lounge-brooklyn',
#    'name': 'Goodas Bar & Lounge',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fTgAFDzyAlSoFXhUyxc8uw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/goodas-bar-and-lounge-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.66381, 'longitude': -73.93062},
#    'transactions': [],
#    'location': {'address1': '971 E New York Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11212',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['971 E New York Ave', 'Brooklyn, NY 11212']},
#    'phone': '+13475734313',
#    'display_phone': '(347) 573-4313',
#    'distance': 7088.776091975859},
#   {'id': 'fqPqPFYaRzl-wRfYlKQo5A',
#    'alias': 'fai-bene-brooklyn',
#    'name': 'Fai Bene',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YILNwlB7UTNsnqccj_n6Iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fai-bene-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.678095000027035,
#     'longitude': -73.98545250941578},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '255 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['255 3rd Ave', 'Brooklyn, NY 11215']},
#    'phone': '+19292958425',
#    'display_phone': '(929) 295-8425',
#    'distance': 3131.173191949572},
#   {'id': 'WqjqHMozyW42XLTtLnKGag',
#    'alias': 'la-pulperia-hells-kitchen-new-york',
#    'name': "La Pulperia Hell's Kitchen",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fyNGpzJ4aB_ehHO-nb4IpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-pulperia-hells-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 803,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7599217, 'longitude': -73.991841},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '623 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['623 9th Ave', 'New York, NY 10036']},
#    'phone': '+16466698984',
#    'display_phone': '(646) 669-8984',
#    'distance': 6061.063900139357},
#   {'id': 'XOnspIaW6mYVmrvgqOaYSQ',
#    'alias': 'lolos-seafood-shack-new-york',
#    'name': "LoLo's Seafood Shack",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NX8_UH66Og_HuhFAtAMsLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lolos-seafood-shack-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 775,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'caribbean', 'title': 'Caribbean'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.80486, 'longitude': -73.95567},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '303 W 116th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10026',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['303 W 116th St', 'New York, NY 10026']},
#    'phone': '+16466493356',
#    'display_phone': '(646) 649-3356',
#    'distance': 11517.963784774058},
#   {'id': 'lsJf1_nv6Lymv0HFaGJU4Q',
#    'alias': 'dorians-seafood-market-new-york-2',
#    'name': "Dorian's Seafood Market",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0TxEEfPQGEFG1vC4Vl76KA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dorians-seafood-market-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'seafoodmarkets', 'title': 'Seafood Markets'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.774028, 'longitude': -73.948158},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1580 York Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1580 York Ave', 'New York, NY 10028']},
#    'phone': '+12125352256',
#    'display_phone': '(212) 535-2256',
#    'distance': 8561.005799712771},
#   {'id': '2Fpw5OH9TCEIrBuHmN3rGA',
#    'alias': 'dorlans-tavern-and-oyster-bar-new-york',
#    'name': "Dorlan's Tavern & Oyster Bar",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rToff8T6DtT5mdZe6d4DLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dorlans-tavern-and-oyster-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 224,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70726, 'longitude': -74.00227},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '213 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['213 Front St', 'New York, NY 10038']},
#    'phone': '+12127792222',
#    'display_phone': '(212) 779-2222',
#    'distance': 704.4045501701534}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                   Restaurant         Type Price Rating         Address  \
# 0          Jeffrey's Grocery      Seafood    $$      4  172 Waverly Pl
# 1  Greenpoint Fish & Lobster      Seafood    $$      4  114 Nassau Ave
# 2            Astoria Seafood      Seafood    $$      4   37-10 33rd St
# 3                   Sup Crab      Seafood   $$$      4       97 Bowery
# 4                 Carne Mare  Steakhouses                  89 South St
#
#          Lat       Lng                                                url  \
# 0  40.733990 -74.00137  https://www.yelp.com/biz/jeffreys-grocery-new-...
# 1  40.724128 -73.94912  https://www.yelp.com/biz/greenpoint-fish-and-l...
# 2  40.754000 -73.92987  https://www.yelp.com/biz/astoria-seafood-long-...
# 3  40.717330 -73.99502  https://www.yelp.com/biz/sup-crab-new-york?adj...
# 4  40.706340 -74.00383
#
#                        ID
# 0  FG3toTBOTyfVTePW5RuWSw
# 1  sEuLm5fQgWkkiYBt6OphWQ
# 2  2LcsDUTlvovnFz-SEcSJTQ
# 3  Dr_eezrA2Cc_azMYnwhRkA
# 4

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"seafood","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': 'nHMDOIX32dGbfpuNUwsLNQ',
#    'alias': 'almar-brooklyn-2',
#    'name': 'AlMar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_EoXWmBYT1-X--xHq0oUTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/almar-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 460,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.702662, 'longitude': -73.989177},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '111 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17188555288',
#    'display_phone': '(718) 855-5288',
#    'distance': 530.8013177444826},
#   {'id': 'L8WCsGiujmGt3kodY9tctA',
#    'alias': 'mighty-catch-new-york',
#    'name': 'Mighty Catch',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/brhoKbSofMyqvuLacbe8gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mighty-catch-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7995, 'longitude': -73.963082},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '940 Columbus Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['940 Columbus Ave', 'New York, NY 10025']},
#    'phone': '+19173883668',
#    'display_phone': '(917) 388-3668',
#    'distance': 10786.563496802595},
#   {'id': 'rXd3H1LiMXAvBsqCENMxCg',
#    'alias': 'morgan-fish-market-and-restaurant-jersey-city',
#    'name': 'Morgan Fish Market & Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ro9tAyTxxFcj5VRjke4-xg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/morgan-fish-market-and-restaurant-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 149,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73174, 'longitude': -74.06816},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2801 John F Kennedy Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07306',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['2801 John F Kennedy Blvd', 'Jersey City, NJ 07306']},
#    'phone': '+12017922400',
#    'display_phone': '(201) 792-2400',
#    'distance': 6862.37546663152},
#   {'id': 'Q2dKbHvXwmJuoaf1Yahfxw',
#    'alias': 'miramar-new-york-2',
#    'name': 'Miramar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MEi4esv99gwMApHihsx--g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/miramar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 215,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70814, 'longitude': -74.01779},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '21 S End Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10280',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21 S End Ave', 'New York, NY 10280']},
#    'phone': '+12129643000',
#    'display_phone': '(212) 964-3000',
#    'distance': 2003.6846472755587},
#   {'id': 'U8C69ISrhGTTubjqoVgZYg',
#    'alias': 'maiden-lane-new-york',
#    'name': 'Maiden Lane',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jdxs8u7DlGJFR_ZKqwTWdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maiden-lane-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7270061842058,
#     'longitude': -73.9799581110408},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '162 Ave B',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 Ave B', 'New York, NY 10009']},
#    'phone': '+16467558911',
#    'display_phone': '(646) 755-8911',
#    'distance': 2684.715408536419},
#   {'id': 'edLi09LmjWXgL1NOCJ4qjA',
#    'alias': 'bungalow-bar-rockaway-beach',
#    'name': 'Bungalow Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/toGUJbus_gtZTtxkvERO9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bungalow-bar-rockaway-beach?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 553,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.5890639, 'longitude': -73.817172},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '377 Beach 92nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Rockaway Beach',
#     'zip_code': '11693',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['377 Beach 92nd St', 'Rockaway Beach, NY 11693']},
#    'phone': '+17189452100',
#    'display_phone': '(718) 945-2100',
#    'distance': 19767.866246483234},
#   {'id': 'OYxhY0-BZijAW4RB16z7Pg',
#    'alias': 'puerto-plata-fish-market-brooklyn-2',
#    'name': 'Puerto Plata Fish Market',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UmQgGyJBSd8TbUizAuy5aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/puerto-plata-fish-market-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 126,
#    'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68165, 'longitude': -73.87985},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '391 Arlington Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11208',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['391 Arlington Ave', 'Brooklyn, NY 11208']},
#    'phone': '+17187596732',
#    'display_phone': '(718) 759-6732',
#    'distance': 10001.14332034516},
#   {'id': 'Ssi8ht_p9rXY03Rwld6EKw',
#    'alias': 'vestry-new-york',
#    'name': 'Vestry',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IAcs4Y1zU3O3hUHIMYLmkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vestry-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.725315, 'longitude': -74.005515},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '246 Spring St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['246 Spring St', 'New York, NY 10013']},
#    'phone': '+12127841350',
#    'display_phone': '(212) 784-1350',
#    'distance': 2402.2822871777744},
#   {'id': 'TXEl8kyZ4de8CoW7nT_i3A',
#    'alias': 'roys-fish-market-new-york',
#    'name': "Roy's Fish Market",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Md8Qf9OrSMl0pIRlTGeYiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roys-fish-market-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 207,
#    'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7617347309091,
#     'longitude': -73.9604171678531},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1138 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1138 1st Ave', 'New York, NY 10065']},
#    'phone': '+12128383587',
#    'display_phone': '(212) 838-3587',
#    'distance': 6879.247115734278},
#   {'id': 'X83qWL5WPR-QWGXGQ8WP-Q',
#    'alias': 'nr-new-york-4',
#    'name': 'NR',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4PYM3jLMvsok4ZUzuMM2rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nr-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 154,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.770153, 'longitude': -73.954956},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '339 E 75th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['339 E 75th St', 'New York, NY 10021']},
#    'phone': '+16462264874',
#    'display_phone': '(646) 226-4874',
#    'distance': 7917.800794183593},
#   {'id': 'mEi57As_Gwyt1F73V2x__A',
#    'alias': '1392-seafood-bbq-flushing',
#    'name': '1392 Seafood BBQ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vqom0nf9Q3a2HR2mXUfuBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/1392-seafood-bbq-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.759217, 'longitude': -73.832547},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '39-16 Prince St',
#     'address2': '',
#     'address3': None,
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39-16 Prince St', 'Flushing, NY 11354']},
#    'phone': '+17189391392',
#    'display_phone': '(718) 939-1392',
#    'distance': 14900.419396964291},
#   {'id': 'Z2sNzskjS8Ck0plppRBJIg',
#    'alias': 'eds-lobster-bar-new-york-3',
#    'name': "Ed's Lobster Bar",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QGFhA3yG2QdGnW_sOB8s9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eds-lobster-bar-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1023,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71993072968719,
#     'longitude': -73.99901129999999},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '155 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['155 Grand St', 'New York, NY 10013']},
#    'phone': '+12123433236',
#    'display_phone': '(212) 343-3236',
#    'distance': 1659.1141991299744},
#   {'id': '-Gc5sTFxoXM3Tiv_dkSJZg',
#    'alias': 'cecconis-dumbo-brooklyn',
#    'name': "Cecconi's Dumbo",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/39iIx_iSeCTk3PIwaKFBAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cecconis-dumbo-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 864,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7033063330116,
#     'longitude': -73.9916549604523},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '55 Water St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+17186503900',
#    'display_phone': '(718) 650-3900',
#    'distance': 325.5822990331506},
#   {'id': 'DlDIBBcongaBW2FyNRqeiw',
#    'alias': 'marys-fish-camp-new-york',
#    'name': "Mary's Fish Camp",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Gm-x4NY9liy60bpCEKnTIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marys-fish-camp-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 609,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7348192, 'longitude': -74.0032416},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '64 Charles St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64 Charles St', 'New York, NY 10014']},
#    'phone': '+16464862185',
#    'display_phone': '(646) 486-2185',
#    'distance': 3352.200600357071},
#   {'id': 'qhyll2gPT-gGDRP6JGn1aQ',
#    'alias': 'bice-cucina-midtown-new-york',
#    'name': 'Bice Cucina - Midtown',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SAFRTZGN7vUs5P4fdHCT4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bice-cucina-midtown-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 92,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7624702435463,
#     'longitude': -73.9768997892404},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '62 W 55th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['62 W 55th St', 'New York, NY 10019']},
#    'phone': '+12127572600',
#    'display_phone': '(212) 757-2600',
#    'distance': 6496.076605702763},
#   {'id': '_WsfOuvObbp1tH4cBE-jNw',
#    'alias': 'chart-house-weehawken',
#    'name': 'Chart House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NPJgTi58ozoENm9a6tPwzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chart-house-weehawken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1605,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7607, 'longitude': -74.018038},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '1700 Harbor Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Weehawken',
#     'zip_code': '07086',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1700 Harbor Blvd', 'Weehawken, NJ 07086']},
#    'phone': '+12013486628',
#    'display_phone': '(201) 348-6628',
#    'distance': 6461.624349559966},
#   {'id': 'thUk6cIQKtW9YXbDbsZ81A',
#    'alias': 'littleneck-brooklyn',
#    'name': 'Littleneck',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/d5xuuoHe4haeXstd6sXbkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/littleneck-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 303,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6773052, 'longitude': -73.9863991},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '288 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['288 3rd Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17185221921',
#    'display_phone': '(718) 522-1921',
#    'distance': 3198.9873267774637},
#   {'id': 'PSLAZjy7tPoQdQCFF53LQg',
#    'alias': 'the-high-seafood-jersey-city',
#    'name': 'The High Seafood',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mKNJK1xouXsSPm3_NGQvWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-high-seafood-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72902476303974,
#     'longitude': -74.06948522550644},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '2716 John F Kennedy Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Jersey City',
#     'zip_code': '07087',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['2716 John F Kennedy Blvd', 'Jersey City, NJ 07087']},
#    'phone': '+12015479355',
#    'display_phone': '(201) 547-9355',
#    'distance': 6858.0906986166865},
#   {'id': 'AfiSqDmx7Q3qLLgAvhHSRQ',
#    'alias': 'blue-seafood-bar-new-york',
#    'name': 'Blue Seafood Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ph6rwlLJ6pyYEq2Ol67b7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-seafood-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 167,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76685, 'longitude': -73.98615},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '856 Ninth Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['856 Ninth Ave', 'New York, NY 10019']},
#    'phone': '+12127577511',
#    'display_phone': '(212) 757-7511',
#    'distance': 6864.891317848399},
#   {'id': 'kDJbzzmCEjFbyDQ-lSygvw',
#    'alias': 'fresh-salt-new-york',
#    'name': 'Fresh Salt',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Rmf9kAAubededQTq1rzLIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fresh-salt-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 407,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70707, 'longitude': -74.00244},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '146 Beekman St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['146 Beekman St', 'New York, NY 10038']},
#    'phone': '+12129620053',
#    'display_phone': '(212) 962-0053',
#    'distance': 710.677389267444},
#   {'id': 'wb06aCfVIf8I8ufPJ5zflg',
#    'alias': 'sidneys-five-new-york',
#    'name': "Sidney's Five",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ASkG8xci15jBmupqk_EvDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sidneys-five-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7267, 'longitude': -73.98621},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '103 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 1st Ave', 'New York, NY 10003']},
#    'phone': '+19174093368',
#    'display_phone': '(917) 409-3368',
#    'distance': 2459.119722713088},
#   {'id': 'md90Fu_96gYw1AXJ103mHQ',
#    'alias': 'pips-brooklyn-3',
#    'name': 'Pips',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VBJDGt1y9iKW6ZPp4IUEPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pips-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.690902, 'longitude': -73.995738},
#    'transactions': ['delivery'],
#    'location': {'address1': '129 Atlantic Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['129 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17188588989',
#    'display_phone': '(718) 858-8989',
#    'distance': 1621.671460868158},
#   {'id': 'k2sHdf6WeY22pK3hs6mtqA',
#    'alias': 'legasea-seafood-brasserie-new-york-3',
#    'name': 'Legasea Seafood Brasserie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lZ28v3swlq2a5fhGeZXI_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/legasea-seafood-brasserie-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 318,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75238, 'longitude': -73.98939},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '485 7th Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['485 7th Ave', 'New York, NY 10018']},
#    'phone': '+12122681888',
#    'display_phone': '(212) 268-1888',
#    'distance': 5229.886949527016},
#   {'id': '8TfhQaCxux6Eq8SK8iqyoQ',
#    'alias': 'abuqir-seafood-astoria',
#    'name': 'Abuqir Seafood',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gL_xhfdC31xYMGGvnavkOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/abuqir-seafood-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 181,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7683, 'longitude': -73.9110794},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '24-19 Steinway St',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24-19 Steinway St', 'Astoria, NY 11103']},
#    'phone': '+17182743474',
#    'display_phone': '(718) 274-3474',
#    'distance': 9899.685807181475},
#   {'id': 'H-KmD1i8froVpcRMC7oNOA',
#    'alias': 'rayons-jamaican-and-international-restaurant-brooklyn',
#    'name': "Rayon's Jamaican & International Restaurant",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/li9cu4c2a4BjUL_UqrkO3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rayons-jamaican-and-international-restaurant-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71169574331532,
#     'longitude': -73.95781015582},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '160 Havemeyer St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['160 Havemeyer St', 'Brooklyn, NY 11211']},
#    'phone': '+19293970097',
#    'display_phone': '(929) 397-0097',
#    'distance': 3152.720982442237},
#   {'id': 'ovlug57K-IC_Z5QkcFuYpA',
#    'alias': 'hook-and-reel-cajun-seafood-and-bar-new-york',
#    'name': 'Hook & Reel Cajun Seafood & Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oO4Jv5ePLcc5A8tte15d_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hook-and-reel-cajun-seafood-and-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.57584, 'longitude': -73.98029},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1217 Surf Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '11224',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1217 Surf Ave', 'New York, NY 11224']},
#    'phone': '+17186845533',
#    'display_phone': '(718) 684-5533',
#    'distance': 14456.872307015446},
#   {'id': 'kSI-wgcYYfpcHcgDrbKIfg',
#    'alias': 'sugar-freak-astoria',
#    'name': 'Sugar Freak',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/urVAX5bVPQxTSzgT2b96LQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sugar-freak-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1806,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7646298318085,
#     'longitude': -73.9159499108791},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '37-11 30th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37-11 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17186061900',
#    'display_phone': '(718) 606-1900',
#    'distance': 9321.072231105036},
#   {'id': 'bnsC31tMVSEeKix6E2nlfg',
#    'alias': 'king-of-the-sea-brooklyn-3',
#    'name': 'King Of The Sea',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/X-x0nAwXEPCHyd5wx7FtGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/king-of-the-sea-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 144,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.687, 'longitude': -73.95479},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1102 Bedford Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1102 Bedford Ave', 'Brooklyn, NY 11216']},
#    'phone': '+17187838000',
#    'display_phone': '(718) 783-8000',
#    'distance': 3902.0559516897924},
#   {'id': '03RL_VcRGXuICl2R6Luu_Q',
#    'alias': 'the-waterfront-nyc-bronx',
#    'name': 'The Waterfront NYC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zV8E_UsFpcPXpxetIvlfcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-waterfront-nyc-bronx?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8112556, 'longitude': -73.8352813},
#    'transactions': ['delivery'],
#    'location': {'address1': '500 Hutchinson River Pkwy',
#     'address2': '',
#     'address3': 'Trump Golf Links',
#     'city': 'Bronx',
#     'zip_code': '10465',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['500 Hutchinson River Pkwy',
#      'Trump Golf Links',
#      'Bronx, NY 10465']},
#    'phone': '+17184141577',
#    'display_phone': '(718) 414-1577',
#    'distance': 17907.114878788812},
#   {'id': 'yNePYXpvL3BR2Iu0mqy7GQ',
#    'alias': 'crab-du-jour-xpress-cajun-seafood-new-york-3',
#    'name': 'Crab Du Jour Xpress Cajun Seafood',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FkAZK6CZENHXR-L_WM3FhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crab-du-jour-xpress-cajun-seafood-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.80718, 'longitude': -73.94559},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '284 Malcolm X Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['284 Malcolm X Blvd', 'New York, NY 10027']},
#    'phone': '+16465969766',
#    'display_phone': '(646) 596-9766',
#    'distance': 12032.656779968365},
#   {'id': 'FC2uST9JpPCFmjDcMDVZMA',
#    'alias': 'naked-crab-flushing',
#    'name': 'Naked Crab',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0UR7FIShLBAoMASKTOSA_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/naked-crab-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 604,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7585, 'longitude': -73.83467},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '39-16 College Point Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39-16 College Point Blvd', 'Flushing, NY 11354']},
#    'phone': '+17188868777',
#    'display_phone': '(718) 886-8777',
#    'distance': 14682.428622174932},
#   {'id': 'HEQ04JVgYl1QkLDym_Ji9A',
#    'alias': 'holy-crab-boiling-brooklyn-2',
#    'name': 'Holy Crab Boiling',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pHN1NeISNt_Mgchd4D3V2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holy-crab-boiling-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 208,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.63698, 'longitude': -74.01139},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '5915 7th Ave',
#     'address2': 'Fl 1',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11220',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5915 7th Ave', 'Fl 1', 'Brooklyn, NY 11220']},
#    'phone': '+13478896663',
#    'display_phone': '(347) 889-6663',
#    'distance': 7748.289673639649},
#   {'id': 'hmdm-dO72hLsMQwQRcGEUQ',
#    'alias': 'atrium-dumbo-brooklyn',
#    'name': 'Atrium Dumbo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VUzaLCgAu6qYRSsVGZTDVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/atrium-dumbo-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 669,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7033899, 'longitude': -73.9904923},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '15 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Main St', 'Brooklyn, NY 11201']},
#    'phone': '+17188581095',
#    'display_phone': '(718) 858-1095',
#    'distance': 391.3077959872246},
#   {'id': 'wOq-Jt26jnFf_rhF4r5D6w',
#    'alias': 'scampi-new-york-2',
#    'name': 'Scampi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Rwo2L4OlG87DYsEynrJP_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scampi-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 275,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73902, 'longitude': -73.99358},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '30 W 18th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30 W 18th St', 'New York, NY 10011']},
#    'phone': '+12128882171',
#    'display_phone': '(212) 888-2171',
#    'distance': 3737.290321969826},
#   {'id': 'vW7sMAxt4YcUS8tWONaX2g',
#    'alias': 'the-gumbo-bros-brooklyn',
#    'name': 'The Gumbo Bros',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DXxrsbyS44zRuvatUCzYKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-gumbo-bros-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 381,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68934, 'longitude': -73.99178},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '224 Atlantic Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['224 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+19179091471',
#    'display_phone': '(917) 909-1471',
#    'distance': 1801.2820227976542},
#   {'id': 'Tjc-TchvxYkiEdf3vA1pQA',
#    'alias': 'sirenetta-seafood-and-raw-bar-hoboken',
#    'name': 'Sirenetta Seafood & Raw Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ktASxKdIY8Tm1BP3wq4-RA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sirenetta-seafood-and-raw-bar-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 88,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.749696, 'longitude': -74.026912},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '1039 Washington St',
#     'address2': None,
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1039 Washington St', 'Hoboken, NJ 07030']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5631.406695381987},
#   {'id': 'VpEy7E9fij06n7BRrzvEaw',
#    'alias': 'le-crocodile-brooklyn',
#    'name': 'Le Crocodile',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/36S2BKbamLSZoCiv0ZYggQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-crocodile-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 111,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72191, 'longitude': -73.957873},
#    'transactions': ['delivery'],
#    'location': {'address1': '80 Wythe Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Wythe Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17184608004',
#    'display_phone': '(718) 460-8004',
#    'distance': 3574.1437285922625},
#   {'id': '86StyWnuGaTuY6X2e3irOg',
#    'alias': 'alice-restaurant-new-york',
#    'name': 'Alice Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ncY0qKcrRcjzG6EletGH6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alice-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73710696813969,
#     'longitude': -73.99863114881475},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '126 W 13th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['126 W 13th St', 'New York, NY 10011']},
#    'phone': '+12126914886',
#    'display_phone': '(212) 691-4886',
#    'distance': 3539.5904864797512},
#   {'id': 'EDucGBSfQ0YIbxdHS-KnCg',
#    'alias': 'sagaponack-new-york-5',
#    'name': 'Sagaponack',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FMOmqnjNNN2y5iOfEWJ1mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sagaponack-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 89,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.740937, 'longitude': -73.99081},
#    'transactions': [],
#    'location': {'address1': '4 W 22nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4 W 22nd St', 'New York, NY 10010']},
#    'phone': '+12122292226',
#    'display_phone': '(212) 229-2226',
#    'distance': 3957.5096807378354},
#   {'id': 'J0c8ZtHPf08TMVeojPkNkQ',
#    'alias': 'verde-on-smith-brooklyn-4',
#    'name': 'Verde on Smith',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uiVrcv4FztMvXCt6MW8VNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/verde-on-smith-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 716,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.684437, 'longitude': -73.992234},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '216 Smith St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['216 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17182221525',
#    'display_phone': '(718) 222-1525',
#    'distance': 2342.407565853325},
#   {'id': 'z0lX40tXQxOHlU26VhLATA',
#    'alias': 'american-brass-on-the-water-long-island-city',
#    'name': 'American Brass On The Water',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tHieRTzF8ZXYS6a0WaTe5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/american-brass-on-the-water-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 178,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7441416, 'longitude': -73.9583929},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': 'Corner Of Center Blvd And 49th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11109',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Corner Of Center Blvd And 49th Ave',
#      'Long Island City, NY 11109']},
#    'phone': '+17188061106',
#    'display_phone': '(718) 806-1106',
#    'distance': 5259.954965419117},
#   {'id': 'zv29TbzPs9-rD5ql0qWw5A',
#    'alias': 'the-shadmoor-new-york',
#    'name': 'The Shadmoor',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/e70IUTFr5bK6JffORQXgPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-shadmoor-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 346,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75866, 'longitude': -73.9655499},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1066 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1066 2nd Ave', 'New York, NY 10022']},
#    'phone': '+12123859195',
#    'display_phone': '(212) 385-9195',
#    'distance': 6391.825817122482},
#   {'id': 'JEQ00qBAepe0oSiUBdfIew',
#    'alias': 'taverna-kyclades-astoria',
#    'name': 'Taverna Kyclades',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8q5YKJ9csnX0ZdA-0-IeDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taverna-kyclades-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2422,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7753227, 'longitude': -73.909217},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3307 Ditmars Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3307 Ditmars Blvd', 'Astoria, NY 11105']},
#    'phone': '+17185458666',
#    'display_phone': '(718) 545-8666',
#    'distance': 10571.118527927096},
#   {'id': 'YtXl15Nv7TZvV3yIqbZc8A',
#    'alias': 'burger-and-lobster-bryant-park-new-york-2',
#    'name': 'Burger & Lobster - Bryant Park',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rjPGn5twQEUloEKScGYo-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burger-and-lobster-bryant-park-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1048,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75596, 'longitude': -73.98532},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '132 W 43rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['132 W 43rd St', 'New York, NY 10036']},
#    'phone': '+19175659044',
#    'display_phone': '(917) 565-9044',
#    'distance': 5668.129747084554},
#   {'id': 'KpBfFpjzsGvvqAzCasVW0g',
#    'alias': 'extra-virgin-new-york',
#    'name': 'Extra Virgin',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Idyk61NTgFmF2XYzdGyqxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/extra-virgin-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1292,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7353962496717,
#     'longitude': -74.0031888223197},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '259 W 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['259 W 4th St', 'New York, NY 10014']},
#    'phone': '+12126919359',
#    'display_phone': '(212) 691-9359',
#    'distance': 3413.7710556560824},
#   {'id': 'oMT2qhqYgpLZFZ7gcPZnwQ',
#    'alias': 'seamores-chelsea-new-york',
#    'name': "Seamore's - Chelsea",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dBXa1OBrVq9TLosx1gk-_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seamores-chelsea-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 244,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74247, 'longitude': -74.0009},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '161 8th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['161 8th Ave', 'New York, NY 10011']},
#    'phone': '+12125979222',
#    'display_phone': '(212) 597-9222',
#    'distance': 4155.083247576617},
#   {'id': 'yUfLfVqhCfFsACnMX73YEQ',
#    'alias': 'oceanic-boil-rego-park',
#    'name': 'Oceanic Boil',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4NsBbzng9woxOsjvEz-wxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oceanic-boil-rego-park?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 74,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.729405, 'longitude': -73.861621},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '96-18 Queens Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['96-18 Queens Blvd', 'Rego Park, NY 11374']},
#    'phone': '+13478320123',
#    'display_phone': '(347) 832-0123',
#    'distance': 11494.447732538365},
#   {'id': 'f-WkzzSaAA_mdDmsKlJ4sw',
#    'alias': '21-greenpoint-brooklyn-2',
#    'name': '21 Greenpoint',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Jj5leTKQjdOH7AF1qGRSlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/21-greenpoint-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72978, 'longitude': -73.95992},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '21 Greenpoint Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21 Greenpoint Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183838833',
#    'display_phone': '(718) 383-8833',
#    'distance': 3966.853940669762},
#   {'id': 'm0fvt59Gf-m-TABjyM4YGw',
#    'alias': 'brooklyn-bay-seafood-brooklyn',
#    'name': 'Brooklyn Bay Seafood',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8Ade0BqvCaoctv5jY6j6-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-bay-seafood-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 79,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6341653608713,
#     'longitude': -74.026490981364},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '7026 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7026 3rd Ave', 'Brooklyn, NY 11209']},
#    'phone': '+17183335835',
#    'display_phone': '(718) 333-5835',
#    'distance': 8378.192363129505},
#   {'id': 'D8z7FS2SB48zTjvch4bc0g',
#    'alias': 'johnnys-reef-restaurant-bronx',
#    'name': "Johnny's Reef Restaurant",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lFSAGyz6mHWOxw8Z5IjdUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/johnnys-reef-restaurant-bronx?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 569,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8377099599469,
#     'longitude': -73.7826705251312},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2 City Island Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10464',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2 City Island Ave', 'Bronx, NY 10464']},
#    'phone': '+17188852086',
#    'display_phone': '(718) 885-2086',
#    'distance': 23105.832300314407}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                         Restaurant          Type Price Rating  \
# 0                            AlMar       Italian    $$      4
# 1                     Mighty Catch  Cajun/Creole    $$      4
# 2  Morgan Fish Market & Restaurant       Seafood    $$    4.5
# 3                          Miramar       Seafood    $$    3.5
# 4                      Maiden Lane       Seafood    $$      4
#
#                     Address        Lat        Lng  \
# 0              111 Front St  40.702662 -73.989177
# 1          940 Columbus Ave  40.799500 -73.963082
# 2  2801 John F Kennedy Blvd  40.731740 -74.068160
# 3              21 S End Ave  40.708140 -74.017790
# 4                 162 Ave B  40.727006 -73.979958
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/almar-brooklyn-2?adju...  nHMDOIX32dGbfpuNUwsLNQ
# 1  https://www.yelp.com/biz/mighty-catch-new-york...  L8WCsGiujmGt3kodY9tctA
# 2  https://www.yelp.com/biz/morgan-fish-market-an...  rXd3H1LiMXAvBsqCENMxCg
# 3  https://www.yelp.com/biz/miramar-new-york-2?ad...  Q2dKbHvXwmJuoaf1Yahfxw
# 4  https://www.yelp.com/biz/maiden-lane-new-york?...  U8C69ISrhGTTubjqoVgZYg

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"seafood","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [{'id': 'D8z7FS2SB48zTjvch4bc0g',
#    'alias': 'johnnys-reef-restaurant-bronx',
#    'name': "Johnny's Reef Restaurant",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lFSAGyz6mHWOxw8Z5IjdUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/johnnys-reef-restaurant-bronx?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 569,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8377099599469,
#     'longitude': -73.7826705251312},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2 City Island Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10464',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2 City Island Ave', 'Bronx, NY 10464']},
#    'phone': '+17188852086',
#    'display_phone': '(718) 885-2086',
#    'distance': 23105.832300314407},
#   {'id': 'mhhTORjUdXj-UIDjyGmhBg',
#    'alias': 'estiatorio-milos-midtown-new-york-new-york',
#    'name': 'Estiatorio Milos - Midtown New York',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/i5t24z6LSQuuhEqBLf481Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/estiatorio-milos-midtown-new-york-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 936,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76355879708378,
#     'longitude': -73.97902981165667},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '125 W 55th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['125 W 55th St', 'New York, NY 10019']},
#    'phone': '+12122457400',
#    'display_phone': '(212) 245-7400',
#    'distance': 6588.697775846128},
#   {'id': 'MIsxw3cb4ByYyH2G1KzrZQ',
#    'alias': 'steak-n-lobster-new-york-2',
#    'name': "Steak 'N Lobster",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tp0iKAbXmmsaMQBTM-Ckuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/steak-n-lobster-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7472, 'longitude': -73.990979},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '129 W 29th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['129 W 29th St', 'New York, NY 10001']},
#    'phone': '+12125642929',
#    'display_phone': '(212) 564-2929',
#    'distance': 4651.34601783737},
#   {'id': '4XX-zF8h5Lvrr22_tqU6-Q',
#    'alias': 'the-river-café-brooklyn-3',
#    'name': 'The River Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/X5pxv0ydhNP7kPBDArEHsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-river-caf%C3%A9-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1166,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70318, 'longitude': -73.9946499},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '1 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+17185225200',
#    'display_phone': '(718) 522-5200',
#    'distance': 252.24127844020637},
#   {'id': '8K_1pRyl_Ei1EkVmBYZMGg',
#    'alias': 'red-crab-juicy-seafood-brooklyn',
#    'name': 'Red Crab - Juicy Seafood',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EzANmb_iNeUAy7nZ78H4Ow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/red-crab-juicy-seafood-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.58536, 'longitude': -73.95164},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1724 Sheepshead Bay Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11235',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1724 Sheepshead Bay Rd', 'Brooklyn, NY 11235']},
#    'phone': '+17186481927',
#    'display_phone': '(718) 648-1927',
#    'distance': 13824.47007616702},
#   {'id': 'zyxI5ko5Dpkqi9q5oSGa9w',
#    'alias': 'pilot-brooklyn',
#    'name': 'Pilot',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hNSXtVezk05tsj_Y8GxHmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pilot-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 258,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.696432423661,
#     'longitude': -73.9890010861378},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Pier 6 Brooklyn Bridge Park',
#     'address2': '',
#     'address3': 'Brooklyn Bridge Park',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Pier 6 Brooklyn Bridge Park',
#      'Brooklyn Bridge Park',
#      'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1495.270613516155},
#   {'id': 'DhBhEWMVLDxYF14a1znUvA',
#    'alias': 'lighthouse-brooklyn-2',
#    'name': 'Lighthouse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y3zbJj3MQK-MUXnymqwBpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lighthouse-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 270,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7104080536563,
#     'longitude': -73.9539040490168},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '145 Borinquen Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['145 Borinquen Pl', 'Brooklyn, NY 11211']},
#    'phone': '+13477897742',
#    'display_phone': '(347) 789-7742',
#    'distance': 3448.867236343932},
#   {'id': 'bO7oI7V8MYbRxenHQcWOqQ',
#    'alias': 'surf-bar-brooklyn',
#    'name': 'Surf Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/k5mY_hhvmhJSmlj_JRlw-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/surf-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 616,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'tikibars', 'title': 'Tiki Bars'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7177048496671,
#     'longitude': -73.9586651666596},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '139 N 6th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['139 N 6th St', 'Brooklyn, NY 11249']},
#    'phone': '+17183024441',
#    'display_phone': '(718) 302-4441',
#    'distance': 3297.895058312254},
#   {'id': 'BiVoGBgMPrPIhAdYgIcaGg',
#    'alias': 'shipwreck-gourmet-fish-boutique-brooklyn-4',
#    'name': 'Shipwreck Gourmet Fish Boutique',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yaemKFpSwE_tCFS3j-fSZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shipwreck-gourmet-fish-boutique-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 115,
#    'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6881156, 'longitude': -73.9546684},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1049 Bedford Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1049 Bedford Ave', 'Brooklyn, NY 11216']},
#    'phone': '+17184847611',
#    'display_phone': '(718) 484-7611',
#    'distance': 3868.892019829258},
#   {'id': 'Wu4JKVR3GeoN3IQyGdkouQ',
#    'alias': 'juicy-king-crab-express-brooklyn-10',
#    'name': 'Juicy King Crab Express',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4i0fnHur-Lags_qqfzNszw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/juicy-king-crab-express-brooklyn-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.669613, 'longitude': -73.958176},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '837 Franklin Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11225',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['837 Franklin Ave', 'Brooklyn, NY 11225']},
#    'phone': '+17186846008',
#    'display_phone': '(718) 684-6008',
#    'distance': 5016.027759730588},
#   {'id': 'FwygEW3PBBh9g4ELNLpS8w',
#    'alias': 'docks-oyster-bar-and-seafood-grill-new-york',
#    'name': 'Docks Oyster Bar and Seafood Grill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/F25hYt0tIClmS6CQRUZMEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/docks-oyster-bar-and-seafood-grill-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 631,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7495410989218,
#     'longitude': -73.9751169755325},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '633 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['633 3rd Ave', 'New York, NY 10017']},
#    'phone': '+12129868080',
#    'display_phone': '(212) 986-8080',
#    'distance': 5162.6749602546615},
#   {'id': 'TCJrcryBkI6eg2HYThoiKg',
#    'alias': 'petite-crevette-brooklyn',
#    'name': 'Petite Crevette',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HhnCUa1fzQ2o4c4c9rnGHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/petite-crevette-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 326,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68396, 'longitude': -74.0018},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '144 Union St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['144 Union St', 'Brooklyn, NY 11231']},
#    'phone': '+17188552632',
#    'display_phone': '(718) 855-2632',
#    'distance': 2477.863579971962},
#   {'id': 'lQ87D3INFtCoGAuo715_jw',
#    'alias': 'mama-capri-brooklyn',
#    'name': 'Mama Capri',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mNYvbIbElCNcadlKr03Vwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mama-capri-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68332, 'longitude': -73.99264},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '247 Smith St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['247 Smith St', 'Brooklyn, NY 11231']},
#    'phone': '+19179090237',
#    'display_phone': '(917) 909-0237',
#    'distance': 2466.335131122872},
#   {'id': 'MGd6HFEq1ALD58XWNviSXw',
#    'alias': 'time-out-market-new-york-brooklyn',
#    'name': 'Time Out Market New York',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/I5ybhy4J7GWCel1wZ4NJng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/time-out-market-new-york-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 290,
#    'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7037211399782,
#     'longitude': -73.9918105285751},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '55 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+19178104855',
#    'display_phone': '(917) 810-4855',
#    'distance': 283.7853104247956},
#   {'id': '2Lnmwq2xg_atspvTtjTecg',
#    'alias': 'bk-lobster-brooklyn-8',
#    'name': 'BK Lobster',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0qMGKCFj1ZbDi8YY4jm5rQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bk-lobster-brooklyn-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.712792, 'longitude': -73.962541},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '340 Bedford Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['340 Bedford Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13478895485',
#    'display_phone': '(347) 889-5485',
#    'distance': 2792.6719423988116},
#   {'id': 'IXqVZN2ox9yrEhi_o3dVqA',
#    'alias': 'sea-breeze-fish-market-new-york',
#    'name': 'Sea Breeze Fish Market',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QmWwo9QDKmBM3y_nPjnKag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sea-breeze-fish-market-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 62,
#    'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75731, 'longitude': -73.99367},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '541 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['541 9th Ave', 'New York, NY 10018']},
#    'phone': '+12125637537',
#    'display_phone': '(212) 563-7537',
#    'distance': 5771.02082866334},
#   {'id': 'rlp1_EyRynmIDlJClhRNlQ',
#    'alias': 'randazzos-clam-bar-brooklyn',
#    'name': "Randazzo's Clam Bar",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2TY0CaqKnbNTjKy9ya9SZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/randazzos-clam-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 668,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.5838863, 'longitude': -73.9478455},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '2017 Emmons Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11235',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2017 Emmons Ave', 'Brooklyn, NY 11235']},
#    'phone': '+17186150010',
#    'display_phone': '(718) 615-0010',
#    'distance': 14067.6890917838},
#   {'id': 'lzS4xZdl9Yk1ULtbzi9ejQ',
#    'alias': 'hamido-seafood-astoria',
#    'name': 'Hamido Seafood',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_NVtp9tBPxzFDVG9o3XgiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hamido-seafood-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 192,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7750008, 'longitude': -73.9095623},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '3308 Ditmars Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3308 Ditmars Blvd', 'Astoria, NY 11105']},
#    'phone': '+17185452200',
#    'display_phone': '(718) 545-2200',
#    'distance': 10525.096357777624},
#   {'id': 'gvMYV5E3HyzhN_MYFIMGzg',
#    'alias': 'el-born-brooklyn',
#    'name': 'El Born',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cRJdg0UISKlStMI7vkp6Tw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-born-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 344,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7243479163883,
#     'longitude': -73.9512226101037},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '651 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['651 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+13478449295',
#    'display_phone': '(347) 844-9295',
#    'distance': 4194.692764168617},
#   {'id': 'txSykTj5nbwmpiVNoK_Dyg',
#    'alias': 'blue-ribbon-brasserie-soho-new-york',
#    'name': 'Blue Ribbon Brasserie - SoHo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZAxYITiJ5k1H_zZ2Ph59sg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-ribbon-brasserie-soho-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 949,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.725456, 'longitude': -74.003027},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '97 Sullivan St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['97 Sullivan St', 'New York, NY 10012']},
#    'phone': '+12122740404',
#    'display_phone': '(212) 274-0404',
#    'distance': 2343.726730880165},
#   {'id': 'hudzJdIGMoXmxBO0KsJiFQ',
#    'alias': 'fish-tales-brooklyn',
#    'name': 'Fish Tales',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AezNF_uW7JoJfBJV5d-CAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fish-tales-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 101,
#    'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.687473, 'longitude': -73.993148},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '191A Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['191A Court St', 'Brooklyn, NY 11201']},
#    'phone': '+17182461346',
#    'display_phone': '(718) 246-1346',
#    'distance': 1993.125827638169},
#   {'id': 'xDIBaJfpmAkUjt0vsTgRHQ',
#    'alias': 'jordan-lobster-farms-island-park',
#    'name': 'Jordan Lobster Farms',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Kkvi0-_XPvcVros29XdL6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jordan-lobster-farms-island-park?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 904,
#    'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.596329, 'longitude': -73.654675},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1 Pettit Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'Island Park',
#     'zip_code': '11558',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Pettit Pl', 'Island Park, NY 11558']},
#    'phone': '+15168893314',
#    'display_phone': '(516) 889-3314',
#    'distance': 31125.69930785104},
#   {'id': '764DpGvaDqQqYL-oa1JOJA',
#    'alias': 'twist-seafood-restaurant-and-bar-brooklyn-2',
#    'name': 'Twist Seafood Restaurant & Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0OYD-S_0FGu0UM03aiBc4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/twist-seafood-restaurant-and-bar-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.652309, 'longitude': -74.010406},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '4202 3rd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11232',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4202 3rd Ave', 'Brooklyn, NY 11232']},
#    'phone': '+16468384938',
#    'display_phone': '(646) 838-4938',
#    'distance': 6063.664418703564},
#   {'id': 'n-59KQvfQhURg6WBqxXEQw',
#    'alias': 'grand-army-brooklyn',
#    'name': 'Grand Army',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EFpXQ_BiVGXDtZO7Ky8MCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grand-army-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 206,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.688182, 'longitude': -73.986572},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '336 State St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['336 State St', 'Brooklyn, NY 11201']},
#    'phone': '+17186431503',
#    'display_phone': '(718) 643-1503',
#    'distance': 2024.7830232766212},
#   {'id': 'ySIIdmS4oh-QL2dny7GscA',
#    'alias': 'riko-peruvian-cuisine-new-york-2',
#    'name': 'Riko Peruvian Cuisine',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8aZbZF1sHXLddJ4TPIHcZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/riko-peruvian-cuisine-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 728,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75000088731887,
#     'longitude': -73.99528014341121},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '409 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['409 8th Ave', 'New York, NY 10001']},
#    'phone': '+12126437556',
#    'display_phone': '(212) 643-7556',
#    'distance': 4955.09614504118},
#   {'id': 'hIp46qrh40LYHpzeLZowHw',
#    'alias': 'nola-seafood-flushing',
#    'name': 'Nola Seafood',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/72k4kzSzOywSsYPKDFetDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nola-seafood-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75974, 'longitude': -73.83253},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '38-18 Prince St',
#     'address2': None,
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38-18 Prince St', 'Flushing, NY 11354']},
#    'phone': '+19179080868',
#    'display_phone': '(917) 908-0868',
#    'distance': 14908.00905180552},
#   {'id': '4KzqwQus39gXgrwrDXAjWA',
#    'alias': 'eléa-new-york',
#    'name': 'Eléa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cFF7gz4D1OQn-kdWh6qZdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el%C3%A9a-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 154,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78754, 'longitude': -73.9765199},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '217 W 85th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['217 W 85th St', 'New York, NY 10024']},
#    'phone': '+12123699800',
#    'display_phone': '(212) 369-9800',
#    'distance': 9255.428335342775},
#   {'id': 'oOsJn3leUnWDfErRWMf81g',
#    'alias': 'soco-brooklyn',
#    'name': 'Soco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MQqWdJcIgIgtSI3UiVHS6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soco-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2219,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'soulfood', 'title': 'Soul Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.693866, 'longitude': -73.964535},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '509 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['509 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17187831936',
#    'display_phone': '(718) 783-1936',
#    'distance': 2819.7510824567576},
#   {'id': 'CY2ju2Ez7j9W2TPiO3tPcA',
#    'alias': 'bk-lobster-park-slope-brooklyn-2',
#    'name': 'BK Lobster Park Slope',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nLNfENSuRU-y81LgCibymA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bk-lobster-park-slope-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.66875324366394,
#     'longitude': -73.99035059406613},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '494 4th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['494 4th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+13472278212',
#    'display_phone': '(347) 227-8212',
#    'distance': 4093.4382392046514},
#   {'id': 'EG8MnctXEOXkm7b_yge7Pw',
#    'alias': 'osakana-brooklyn',
#    'name': 'Osakana',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/shWR3yKyQpGlAyzlwHoAwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osakana-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'},
#     {'alias': 'cookingschools', 'title': 'Cooking Schools'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71224, 'longitude': -73.94376},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '290 Graham Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['290 Graham Ave', 'Brooklyn, NY 11211']},
#    'phone': '+16466534633',
#    'display_phone': '(646) 653-4633',
#    'distance': 4322.022118388071},
#   {'id': 'pL7MK_PsDtrKdBm1xLPzkg',
#    'alias': 'off-the-hook-raw-bar-and-grill-astoria',
#    'name': 'Off The Hook Raw Bar & Grill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RZnXcbciuvgOsARWFNGuTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/off-the-hook-raw-bar-and-grill-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 460,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.767167, 'longitude': -73.918014},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '28-08 34th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28-08 34th St', 'Astoria, NY 11103']},
#    'phone': '+17187212112',
#    'display_phone': '(718) 721-2112',
#    'distance': 9402.55205705003},
#   {'id': '5jfJyABI5zAUk79IZXHtrw',
#    'alias': 'el-puerto-seafood-new-york',
#    'name': 'El Puerto Seafood',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/izfQhLfhYPuDp2oUBY2vRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-puerto-seafood-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 102,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8140258789062,
#     'longitude': -73.956413269043},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '511 W 125th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['511 W 125th St', 'New York, NY 10027']},
#    'phone': '+12128657676',
#    'display_phone': '(212) 865-7676',
#    'distance': 12489.051109839502},
#   {'id': 'RrPIJvmje1qb9iaYd6jH0g',
#    'alias': 'pinto-brooklyn-3',
#    'name': 'Pinto',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QzRfSeXdqIx4y7Vbov9vHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pinto-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 231,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69467724943562,
#     'longitude': -73.99423425339312},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '128 Montague St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['128 Montague St', 'Brooklyn, NY 11201']},
#    'phone': '+19293377732',
#    'display_phone': '(929) 337-7732',
#    'distance': 1197.3131497975153},
#   {'id': '63xEppObiNqq_lVE5HGFvw',
#    'alias': 'the-poni-room-new-york',
#    'name': 'The Poni Room',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/U7Gft_MmiDjkJxJxjefSqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-poni-room-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72521, 'longitude': -73.99247},
#    'transactions': ['delivery'],
#    'location': {'address1': '316 Bowery',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['316 Bowery', 'New York, NY 10012']},
#    'phone': '+12122540350',
#    'display_phone': '(212) 254-0350',
#    'distance': 2203.261757078007},
#   {'id': 'vcmkfwTT4FA5Y90EOsmBLg',
#    'alias': 'bk-lobster-new-york',
#    'name': 'BK Lobster',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oMsNFq_UHz3emisntpd5Eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bk-lobster-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.693795, 'longitude': -73.9616288},
#    'transactions': [],
#    'location': {'address1': '572 Myrtle Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['572 Myrtle Ave', 'New York, NY 11205']},
#    'phone': '+13478339393',
#    'display_phone': '(347) 833-9393',
#    'distance': 3043.12907926042},
#   {'id': '0gPXct_l_82phIEoKdtWZw',
#    'alias': 'ryujin-brooklyn-8',
#    'name': 'RYUJIN',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qok9QqxbVYHMHETgZ2gs9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ryujin-brooklyn-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 307,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.711178187852,
#     'longitude': -73.9506256676857},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '513 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['513 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17187099888',
#    'display_phone': '(718) 709-9888',
#    'distance': 3735.5426813558047},
#   {'id': 'be7zagjfrCYN9EQ5ijld5w',
#    'alias': 'pollo-d-oro-brooklyn',
#    'name': "Pollo D' Oro",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BLQJpaPxsQ84B3EvfXeglQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pollo-d-oro-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 288,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69506, 'longitude': -73.98339},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '306 Gold St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['306 Gold St', 'Brooklyn, NY 11201']},
#    'phone': '+17188558088',
#    'display_phone': '(718) 855-8088',
#    'distance': 1466.8027635841881},
#   {'id': 'hMWo5pJqSYTcc9dNmR1QMg',
#    'alias': 'tacoway-beach-rockaway-beach',
#    'name': 'Tacoway Beach',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dzL6waP8iu0_aY3ghPn4fQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacoway-beach-rockaway-beach?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 283,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.58886, 'longitude': -73.812093},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '302 Beach 87th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Rockaway Beach',
#     'zip_code': '11693',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['302 Beach 87th St', 'Rockaway Beach, NY 11693']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 20096.050270891003},
#   {'id': 'moaPtBNbQ5VNu2Z0ilCVGQ',
#    'alias': 'walters-brooklyn',
#    'name': "Walter's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-IVziQ52oaC5C0YS7pztDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/walters-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 549,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6894111633301,
#     'longitude': -73.973258972168},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '166 DeKalb Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['166 DeKalb Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17184887800',
#    'display_phone': '(718) 488-7800',
#    'distance': 2519.304453943392},
#   {'id': '_DBhCb0k5CM_nEE7FO7QTg',
#    'alias': 'pheasant-brooklyn',
#    'name': 'Pheasant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PKuPXpcQgGFFoDMif6R8sQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pheasant-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7185, 'longitude': -73.9452},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '445 Graham Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['445 Graham Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17186755588',
#    'display_phone': '(718) 675-5588',
#    'distance': 4378.147379249452},
#   {'id': 'PGpCaNkB1meojnbgRmb2gQ',
#    'alias': 'buena-vista-restaurant-and-bar-new-york',
#    'name': 'Buena Vista Restaurant & Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cpPCEqAx6O_ytHY1ovajeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/buena-vista-restaurant-and-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 225,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75686, 'longitude': -73.99356},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '536 9th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['536 9th Ave', 'New York, NY 10018']},
#    'phone': '+12123885040',
#    'display_phone': '(212) 388-5040',
#    'distance': 5715.3799368850405},
#   {'id': 'IPh4H0AfWk5LVplgYV9OGQ',
#    'alias': 'black-nile-brooklyn-2',
#    'name': 'Black Nile',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8SBUmPCdnAk9ymSs1TP46g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-nile-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 262,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'soulfood', 'title': 'Soul Food'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67823, 'longitude': -73.94998},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '592 Nostrand Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['592 Nostrand Ave', 'Brooklyn, NY 11216']},
#    'phone': '+13478798911',
#    'display_phone': '(347) 879-8911',
#    'distance': 4810.86442095612},
#   {'id': 'hsnTsIFnQ9Lv4TDJHrIEEQ',
#    'alias': 'surf-and-turf-brooklyn',
#    'name': 'Surf & Turf',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6BdUysMNJTrUT6NGeLD30Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/surf-and-turf-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'russian', 'title': 'Russian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.60045, 'longitude': -73.94066},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2954 Avenue U',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11229',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2954 Avenue U', 'Brooklyn, NY 11229']},
#    'phone': '+17183329730',
#    'display_phone': '(718) 332-9730',
#    'distance': 12529.179474325627},
#   {'id': '5DYXk15LwSfsuc89MeU6Pw',
#    'alias': 'the-simpson-restaurant-and-bar-brooklyn',
#    'name': 'The Simpson Restaurant & Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RvLDDbko4yleLDs3IqEtJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-simpson-restaurant-and-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.683251, 'longitude': -73.973347},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '673 Atlantic Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['673 Atlantic Ave', 'Brooklyn, NY 11217']},
#    'phone': '+13477632711',
#    'display_phone': '(347) 763-2711',
#    'distance': 3033.814356306328},
#   {'id': '8c3UnmA-8Qg3WYVRQDi2Wg',
#    'alias': 'lighthouse-fish-market-and-restaurant-new-york-6',
#    'name': 'Lighthouse Fish Market & Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5WRuWa_EaoDTSAozsbUEAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lighthouse-fish-market-and-restaurant-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 269,
#    'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'soulfood', 'title': 'Soul Food'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.81434, 'longitude': -73.94854},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2451 Frederick Douglass Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2451 Frederick Douglass Blvd', 'New York, NY 10027']},
#    'phone': '+12122032241',
#    'display_phone': '(212) 203-2241',
#    'distance': 12680.065132653921},
#   {'id': 'm1cJLpDN4B-_0hGgPfe5OA',
#    'alias': 'salt-charcoal-brooklyn',
#    'name': 'Salt + Charcoal',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/stPcp8twyzWq4LjF5jaRNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salt-charcoal-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 586,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71453, 'longitude': -73.9613511},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '171 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 Grand St', 'Brooklyn, NY 11249']},
#    'phone': '+17187822087',
#    'display_phone': '(718) 782-2087',
#    'distance': 2954.688075109069},
#   {'id': '80jmHsdVmeYxaoAHaegKyQ',
#    'alias': 'pier-66-maritime-new-york',
#    'name': 'Pier 66 Maritime',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/h9yn5B0bD8lSUY6tv8JrMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pier-66-maritime-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'tradamerican',
#      'title': 'American (Traditional)'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.752197, 'longitude': -74.009167},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'W 26th St',
#     'address2': '',
#     'address3': 'Hudson River Park',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['W 26th St',
#      'Hudson River Park',
#      'New York, NY 10010']},
#    'phone': '+12129896363',
#    'display_phone': '(212) 989-6363',
#    'distance': 5347.542609677337},
#   {'id': 'OhUwfEt_scdr6tiptSI8NQ',
#    'alias': 'liman-restaurant-brooklyn',
#    'name': 'Liman Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4txR-yNjUumWhMZ3HwYNaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/liman-restaurant-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 367,
#    'categories': [{'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.58356, 'longitude': -73.94114},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '2710 Emmons Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11235',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2710 Emmons Ave', 'Brooklyn, NY 11235']},
#    'phone': '+17187693322',
#    'display_phone': '(718) 769-3322',
#    'distance': 14277.90536840932},
#   {'id': 'OCTiJwvjoK81WoDwsTkFvA',
#    'alias': 'paesano-of-mulberry-street-new-york',
#    'name': 'Paesano of Mulberry Street',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yN9ARCE3LF6u9E0yN5WpIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paesano-of-mulberry-street-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1060,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.718554, 'longitude': -73.997447},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '136 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136 Mulberry St', 'New York, NY 10013']},
#    'phone': '+12129651188',
#    'display_phone': '(212) 965-1188',
#    'distance': 1481.7066528289554},
#   {'id': '_z52AlCKEU2Lc-CB1j6Kaw',
#    'alias': 'city-island-lobster-house-bronx-2',
#    'name': 'City Island Lobster House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Ysu9YhKwCt0dvySMPY-qnQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/city-island-lobster-house-bronx-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 651,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.8567604777185,
#     'longitude': -73.791118271164},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '691 Bridge St',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10464',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['691 Bridge St', 'Bronx, NY 10464']},
#    'phone': '+17188851459',
#    'display_phone': '(718) 885-1459',
#    'distance': 23994.64681873053}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#                             Restaurant            Type Price Rating  \
# 0             Johnny's Reef Restaurant         Seafood    $$      4
# 1  Estiatorio Milos - Midtown New York         Seafood  $$$$      4
# 2                     Steak 'N Lobster            Bars    $$      4
# 3                       The River Café  American (New)  $$$$      4
# 4             Red Crab - Juicy Seafood         Seafood
#
#                   Address        Lat        Lng  \
# 0       2 City Island Ave  40.837710 -73.782671
# 1           125 W 55th St  40.763559 -73.979030
# 2           129 W 29th St  40.747200 -73.990979
# 3              1 Water St  40.703180 -73.994650
# 4  1724 Sheepshead Bay Rd  40.585360 -73.951640
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/johnnys-reef-restaura...  D8z7FS2SB48zTjvch4bc0g
# 1  https://www.yelp.com/biz/estiatorio-milos-midt...  mhhTORjUdXj-UIDjyGmhBg
# 2  https://www.yelp.com/biz/steak-n-lobster-new-y...  MIsxw3cb4ByYyH2G1KzrZQ
# 3  https://www.yelp.com/biz/the-river-caf%C3%A9-b...  4XX-zF8h5Lvrr22_tqU6-Q
# 4

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                              Restaurant                    Type Rating Price  \
# 0                    The Waterfront NYC          American (New)
# 1                           Essex Pearl          American (New)
# 2                         21 Greenpoint          American (New)      4   $$$
# 3                              Walter's          American (New)      4    $$
# 4                 High Street On Hudson          American (New)      4    $$
# 5                            The Osprey          American (New)      4    $$
# 6                                  Jibs          American (New)
# 7                          Atrium Dumbo          American (New)      4    $$
# 8                        The River Café          American (New)      4  $$$$
# 9          Blue Ribbon Brasserie - SoHo  American (Traditional)    4.5   $$$
# 10                     Pier 66 Maritime  American (Traditional)      3    $$
# 11                         Bungalow Bar  American (Traditional)      4    $$
# 12                               Le Sia            Asian Fusion    4.5   $$$
# 13                     Steak 'N Lobster                    Bars      4    $$
# 14                            Surf City                    Bars      3    $$
# 15                           Sagaponack                    Bars      4    $$
# 16                           Fresh Salt                    Bars      4    $$
# 17                          Grand Banks                    Bars      4   $$$
# 18                        Sidney's Five                    Bars
# 19                           Sagaponack                    Bars
# 20   Crab House All You Can Eat Seafood                 Buffets    4.5  $$$$
# 21    Crab Du Jour Xpress Cajun Seafood            Cajun/Creole
# 22                             The Boil            Cajun/Creole      4   $$$
# 23                         Mighty Catch            Cajun/Creole      4    $$
# 24                       The Gumbo Bros            Cajun/Creole    4.5    $$
# 25                          Sugar Freak            Cajun/Creole      4    $$
# 26                         Oceanic Boil            Cajun/Creole
# 27                    Holy Crab Boiling            Cajun/Creole      4    $$
# 28                  Sup Crab Greenpoint            Cajun/Creole
# 29                                 Soco            Cajun/Creole      4    $$
# ..                                  ...                     ...    ...   ...
# 170                        Flex Mussels                 Seafood      4    $$
# 171           City Island Lobster House                 Seafood    3.5   $$$
# 172                         Cobble Fish                 Seafood
# 173                     Astoria Seafood                 Seafood      4    $$
# 174                    The Crabby Shack                 Seafood      4    $$
# 175                            Sup Crab                 Seafood      4   $$$
# 176                        Los Mariscos                 Seafood    4.5     $
# 177                             Estuary                 Seafood
# 178            Cull & Pistol Oyster Bar                 Seafood      4    $$
# 179                    Pearl Oyster Bar                 Seafood      4   $$$
# 180                        Naughty Crab                 Seafood
# 181             Peaches Shrimp and Crab                 Seafood      4    $$
# 182                        Flex Mussels                 Seafood      4    $$
# 183                   Roy's Fish Market         Seafood Markets    4.5    $$
# 184            Puerto Plata Fish Market         Seafood Markets    4.5    $$
# 185     Shipwreck Gourmet Fish Boutique         Seafood Markets    4.5    $$
# 186                          Fish Tales         Seafood Markets    4.5   $$$
# 187                             Osakana         Seafood Markets      4    $$
# 188              Sea Breeze Fish Market         Seafood Markets      4    $$
# 189                   The Lobster Place         Seafood Markets      4    $$
# 190                Jordan Lobster Farms         Seafood Markets      4    $$
# 191                    Acme Smoked Fish         Seafood Markets      5    $$
# 192                             El Born                 Spanish    4.5    $$
# 193                          Carne Mare             Steakhouses
# 194                  Somtum Der Redhook                    Thai
# 195                               Pinto                    Thai      4    $$
# 196                    Liman Restaurant                 Turkish      4  $$$$
# 197                       The Poni Room               Wine Bars
# 198                          Lighthouse               Wine Bars      4    $$
# 199              St Tropez West Village               Wine Bars    4.5    $$
#
#                        Address        Lat        Lng  \
# 0    500 Hutchinson River Pkwy  40.811256 -73.835281
# 1              115 Delancey St  40.717871 -73.988199
# 2            21 Greenpoint Ave  40.729780 -73.959920
# 3               166 DeKalb Ave  40.689411 -73.973259
# 4                637 Hudson St  40.738880 -74.005740
# 5                 60 Furman St  40.702241 -73.995539
# 6                 350 11th Ave  40.754070 -74.002699
# 7                   15 Main St  40.703390 -73.990492
# 8                   1 Water St  40.703180 -73.994650
# 9               97 Sullivan St  40.725456 -74.003027
# 10                   W 26th St  40.752197 -74.009167
# 11           377 Beach 92nd St  40.589064 -73.817172
# 12                 651 9th Ave  40.760720 -73.991190
# 13               129 W 29th St  40.747200 -73.990979
# 14                1 Marin Blvd  40.711527 -74.042797
# 15                 4 W 22nd St  40.740922 -73.990789
# 16              146 Beekman St  40.707070 -74.002440
# 17                     Pier 25  40.716745 -74.009397
# 18                 103 1st Ave  40.726700 -73.986210
# 19                 4 W 22nd St  40.740937 -73.990810
# 20               135 E 55th St  40.759664 -73.969776
# 21          284 Malcolm X Blvd  40.807180 -73.945590
# 22               17 Waverly Pl  40.730316 -73.994295
# 23            940 Columbus Ave  40.799500 -73.963082
# 24            224 Atlantic Ave  40.689340 -73.991780
# 25              37-11 30th Ave  40.764630 -73.915950
# 26           96-18 Queens Blvd  40.729405 -73.861621
# 27                5915 7th Ave  40.636980 -74.011390
# 28           664 Manhattan Ave  40.724670 -73.951170
# 29              509 Myrtle Ave  40.693866 -73.964535
# ..                         ...        ...        ...
# 170           174 East 82nd St  40.776370 -73.956460
# 171              691 Bridge St  40.856760 -73.791118
# 172                89 South St  40.705302 -74.002578
# 173              37-10 33rd St  40.754000 -73.929870
# 174           613 Franklin Ave  40.677275 -73.955414
# 175                  97 Bowery  40.717330 -73.995020
# 176              409 W 15th St  40.742070 -74.005650
# 177         159 Bridge Park Dr  40.693236 -74.000794
# 178                 75 9th Ave  40.742659 -74.005929
# 179             18 Cornelia St  40.731410 -74.001970
# 180         1621 Lexington Ave  40.789790 -73.947890
# 181              285 Grand Ave  40.687984 -73.962548
# 182              154 W 13th St  40.737437 -73.999661
# 183               1138 1st Ave  40.761735 -73.960417
# 184          391 Arlington Ave  40.681650 -73.879850
# 185           1049 Bedford Ave  40.688116 -73.954668
# 186              191A Court St  40.687473 -73.993148
# 187             290 Graham Ave  40.712240 -73.943760
# 188                541 9th Ave  40.757310 -73.993670
# 189                 75 9th Ave  40.742741 -74.006012
# 190                1 Pettit Pl  40.596329 -73.654675
# 191                  30 Gem St  40.725420 -73.956620
# 192          651 Manhattan Ave  40.724348 -73.951223
# 193                89 South St  40.706340 -74.003830
# 194           380 Van Brunt St  40.677070 -74.013430
# 195            128 Montague St  40.694677 -73.994234
# 196            2710 Emmons Ave  40.583560 -73.941140
# 197                 316 Bowery  40.725210 -73.992470
# 198           145 Borinquen Pl  40.710408 -73.953904
# 199               304 W 4th St  40.737040 -74.003860
#
#                                                    url                      ID
# 0
# 1
# 2    https://www.yelp.com/biz/21-greenpoint-brookly...  f-WkzzSaAA_mdDmsKlJ4sw
# 3    https://www.yelp.com/biz/walters-brooklyn?adju...  moaPtBNbQ5VNu2Z0ilCVGQ
# 4    https://www.yelp.com/biz/high-street-on-hudson...  Oq1mej1BYfjcdPKkM_5o8g
# 5    https://www.yelp.com/biz/the-osprey-brooklyn?a...  q11TljTQd33XCWlVoPyRqg
# 6
# 7    https://www.yelp.com/biz/atrium-dumbo-brooklyn...  hmdm-dO72hLsMQwQRcGEUQ
# 8    https://www.yelp.com/biz/the-river-caf%C3%A9-b...  4XX-zF8h5Lvrr22_tqU6-Q
# 9    https://www.yelp.com/biz/blue-ribbon-brasserie...  txSykTj5nbwmpiVNoK_Dyg
# 10   https://www.yelp.com/biz/pier-66-maritime-new-...  80jmHsdVmeYxaoAHaegKyQ
# 11   https://www.yelp.com/biz/bungalow-bar-rockaway...  edLi09LmjWXgL1NOCJ4qjA
# 12   https://www.yelp.com/biz/le-sia-new-york-4?adj...  C3tP0fNNAoxOAC3O406CXQ
# 13   https://www.yelp.com/biz/steak-n-lobster-new-y...  MIsxw3cb4ByYyH2G1KzrZQ
# 14   https://www.yelp.com/biz/surf-city-jersey-city...  ZEhxsE-6Xi18cSVwp4trnA
# 15   https://www.yelp.com/biz/sagaponack-new-york-4...  nC4HwtW5_nDICBAVPqN9pw
# 16   https://www.yelp.com/biz/fresh-salt-new-york?a...  kDJbzzmCEjFbyDQ-lSygvw
# 17   https://www.yelp.com/biz/grand-banks-new-york?...  vYGi3439teYg1wPzqVcHUA
# 18
# 19
# 20   https://www.yelp.com/biz/crab-house-all-you-ca...  YvWQMlMjtYmVmheH97tTlQ
# 21
# 22   https://www.yelp.com/biz/the-boil-new-york-5?a...  0087AC_NnFRtC0c9FsB9pw
# 23   https://www.yelp.com/biz/mighty-catch-new-york...  L8WCsGiujmGt3kodY9tctA
# 24   https://www.yelp.com/biz/the-gumbo-bros-brookl...  vW7sMAxt4YcUS8tWONaX2g
# 25   https://www.yelp.com/biz/sugar-freak-astoria?a...  kSI-wgcYYfpcHcgDrbKIfg
# 26
# 27   https://www.yelp.com/biz/holy-crab-boiling-bro...  HEQ04JVgYl1QkLDym_Ji9A
# 28
# 29   https://www.yelp.com/biz/soco-brooklyn?adjust_...  oOsJn3leUnWDfErRWMf81g
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/flex-mussels-new-york...  -P7qAIG1wr_gXW3nzIq5TA
# 171  https://www.yelp.com/biz/city-island-lobster-h...  _z52AlCKEU2Lc-CB1j6Kaw
# 172
# 173  https://www.yelp.com/biz/astoria-seafood-long-...  2LcsDUTlvovnFz-SEcSJTQ
# 174  https://www.yelp.com/biz/the-crabby-shack-broo...  uAy3zyNCmDPO0RpdGjEAdg
# 175  https://www.yelp.com/biz/sup-crab-new-york?adj...  Dr_eezrA2Cc_azMYnwhRkA
# 176  https://www.yelp.com/biz/los-mariscos-new-york...  L3REPLCvQpMapYPd_fkS-A
# 177
# 178  https://www.yelp.com/biz/cull-and-pistol-oyste...  -bdxB20YveudeyL63chscg
# 179  https://www.yelp.com/biz/pearl-oyster-bar-new-...  6dSiCqC9x51PZRMOvdQTpA
# 180
# 181  https://www.yelp.com/biz/peaches-shrimp-and-cr...  FCms-eFFxnpMLm09AJridQ
# 182  https://www.yelp.com/biz/flex-mussels-new-york...  rHmeJVffuj96M7jbB-wWgw
# 183  https://www.yelp.com/biz/roys-fish-market-new-...  TXEl8kyZ4de8CoW7nT_i3A
# 184  https://www.yelp.com/biz/puerto-plata-fish-mar...  OYxhY0-BZijAW4RB16z7Pg
# 185  https://www.yelp.com/biz/shipwreck-gourmet-fis...  BiVoGBgMPrPIhAdYgIcaGg
# 186  https://www.yelp.com/biz/fish-tales-brooklyn?a...  hudzJdIGMoXmxBO0KsJiFQ
# 187  https://www.yelp.com/biz/osakana-brooklyn?adju...  EG8MnctXEOXkm7b_yge7Pw
# 188  https://www.yelp.com/biz/sea-breeze-fish-marke...  IXqVZN2ox9yrEhi_o3dVqA
# 189  https://www.yelp.com/biz/the-lobster-place-new...  zfiXI8AwYBRfWjPyv6oh3w
# 190  https://www.yelp.com/biz/jordan-lobster-farms-...  xDIBaJfpmAkUjt0vsTgRHQ
# 191  https://www.yelp.com/biz/acme-smoked-fish-broo...  XpAZBiSrLNi0t332tWxYcQ
# 192  https://www.yelp.com/biz/el-born-brooklyn?adju...  gvMYV5E3HyzhN_MYFIMGzg
# 193
# 194
# 195  https://www.yelp.com/biz/pinto-brooklyn-3?adju...  RrPIJvmje1qb9iaYd6jH0g
# 196  https://www.yelp.com/biz/liman-restaurant-broo...  OhUwfEt_scdr6tiptSI8NQ
# 197
# 198  https://www.yelp.com/biz/lighthouse-brooklyn-2...  DhBhEWMVLDxYF14a1znUvA
# 199  https://www.yelp.com/biz/st-tropez-west-villag...  CcxreLJbZsO6Z775-hMWpw
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_Seafood.csv')
