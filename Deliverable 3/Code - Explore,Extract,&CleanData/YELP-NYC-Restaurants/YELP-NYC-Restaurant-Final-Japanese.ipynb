# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"japanese","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': 'FlZ1zdVEKWv7dwqm8Uw8-w',
#    'alias': 'raku-new-york-7',
#    'name': 'Raku',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GEbZnH1jR4n7D5WOJ3urPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raku-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1199,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7264988089246,
#     'longitude': -73.9866526052356},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '342 E 6th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['342 E 6th St', 'New York, NY 10003']},
#    'phone': '+12122281324',
#    'display_phone': '(212) 228-1324',
#    'distance': 2428.0392489129867},
#   {'id': '7OMGEtFWT6sdd9TVuoGqJQ',
#    'alias': 'okonomi-brooklyn',
#    'name': 'Okonomi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RMSBnhoB5aHc-3CUSwULgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/okonomi-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 466,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.712622, 'longitude': -73.9487843},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '150 Ainslie St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 Ainslie St', 'Brooklyn, NY 11211']},
#    'phone': '+19292950480',
#    'display_phone': '(929) 295-0480',
#    'distance': 3918.0469578683437},
#   {'id': 'axqp3pGJXnTLgq2QrPyDyQ',
#    'alias': 'benemon-new-york',
#    'name': 'Benemon',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qYGlL-jKKWmMthi05ae_iA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/benemon-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 619,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72551, 'longitude': -73.98838},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '108 E 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['108 E 4th St', 'New York, NY 10003']},
#    'phone': '+12126143006',
#    'display_phone': '(212) 614-3006',
#    'distance': 2289.2038585586733},
#   {'id': 'klAhw3xLQi9GF1tf_HnS7w',
#    'alias': 'izakaya-mew-new-york-3',
#    'name': 'Izakaya MEW',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OHIgiBgK1CA9C3ElqoDTZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-mew-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2447,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.750148, 'longitude': -73.9863203465939},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '53 W 35th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['53 W 35th St', 'New York, NY 10001']},
#    'phone': '+16463689384',
#    'display_phone': '(646) 368-9384',
#    'distance': 5015.952903788343},
#   {'id': 'eQ4QUGvuHGBzsOrphsVc6A',
#    'alias': 'kimura-new-york',
#    'name': 'Kimura',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yLXykLYsF63C1EWLXb2foA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kimura-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 124,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.728995, 'longitude': -73.988279},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '31 St Marks Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31 St Marks Pl', 'New York, NY 10003']},
#    'phone': '+12125981188',
#    'display_phone': '(212) 598-1188',
#    'distance': 2672.2971587321304},
#   {'id': 'BPZfuPvSxCfoppU4lPFm0Q',
#    'alias': 'domodomo-new-york-new-york-4',
#    'name': 'DOMODOMO - New York',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YX89PDM_-aBCL2USyNyhuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/domodomo-new-york-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1252,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7280299, 'longitude': -74.00167},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '140 W Houston St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['140 W Houston St', 'New York, NY 10012']},
#    'phone': '+16467070301',
#    'display_phone': '(646) 707-0301',
#    'distance': 2584.2825548983697},
#   {'id': 'f48yzy50jQDH7X5xFAluOw',
#    'alias': 'tsukimi-new-york',
#    'name': 'Tsukimi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kett5B5aHu9aMaiHWuJJog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tsukimi-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72908, 'longitude': -73.98541},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '228 East 10th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 East 10th St', 'New York, NY 10003']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2726.004489701829},
#   {'id': 'qm1J_dPA5IHij1oAnoZwHw',
#    'alias': 'nonono-new-york-6',
#    'name': 'nonono',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uj6OfjZrgmqGYyHtmn3AAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nonono-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 886,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74545, 'longitude': -73.98499},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '118 Madison Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['118 Madison Ave', 'New York, NY 10016']},
#    'phone': '+16467073227',
#    'display_phone': '(646) 707-3227',
#    'distance': 4515.897681612123},
#   {'id': 'VzstANC68PM1BbyOcDXEtw',
#    'alias': 'donburiya-new-york-2',
#    'name': 'Donburiya',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9GPQ-zsjkgvgJDSjS5j6hw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/donburiya-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 364,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76528, 'longitude': -73.98326},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '253 W 55th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253 W 55th St', 'New York, NY 10019']},
#    'phone': '+12129807909',
#    'display_phone': '(212) 980-7909',
#    'distance': 6724.521667610174},
#   {'id': '9QK3vhI04Q8ylqk49C3JcQ',
#    'alias': 'rule-of-thirds-brooklyn',
#    'name': 'Rule of Thirds',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/z3wcWXhTpcFm-yTiQgwekQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rule-of-thirds-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 110,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7246328, 'longitude': -73.9551096},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '171 Banker St',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 Banker St', 'Brooklyn, NY 11222']},
#    'phone': '+13473346684',
#    'display_phone': '(347) 334-6684',
#    'distance': 3944.454297372159},
#   {'id': 'YC-wGlO0oOkEIaCEDZv-ag',
#    'alias': 'yakitori-totto-new-york',
#    'name': 'Yakitori Totto',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pahS2pdvpTdXRka6CaBFBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yakitori-totto-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1349,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.765375, 'longitude': -73.983114},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '251 W 55th St',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['251 W 55th St', 'Fl 2', 'New York, NY 10019']},
#    'phone': '+12122454555',
#    'display_phone': '(212) 245-4555',
#    'distance': 6730.15788085088},
#   {'id': 'qEe7nIhPfEL6L0-VYhWRrA',
#    'alias': 'raku-new-york-6',
#    'name': 'Raku',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EQsQlLlKQjziOrGsEblCbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raku-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 534,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72728, 'longitude': -74.00252},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '48 Macdougal St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['48 Macdougal St', 'New York, NY 10012']},
#    'phone': '+12129894797',
#    'display_phone': '(212) 989-4797',
#    'distance': 2522.2670460297},
#   {'id': '-J8VuX3wGrYSOBu2G0hMsw',
#    'alias': 'katsu-hama-new-york',
#    'name': 'Katsu-Hama',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pOcVelVViCscikDfwsRcUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/katsu-hama-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1377,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75638, 'longitude': -73.97759},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '11 E 47th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 E 47th St', 'New York, NY 10017']},
#    'phone': '+12127585909',
#    'display_phone': '(212) 758-5909',
#    'distance': 5841.3064284782295},
#   {'id': 'uXsYr76zioJq7jjOKRwQog',
#    'alias': 'shinbashi-72-new-york',
#    'name': 'Shinbashi 72',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TEgqCbhdqBLXCT-ZuP5KSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shinbashi-72-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'intlgrocery', 'title': 'International Grocery'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.778775, 'longitude': -73.982884},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '218 W 72nd St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['218 W 72nd St', 'New York, NY 10023']},
#    'phone': '+12125107799',
#    'display_phone': '(212) 510-7799',
#    'distance': 8215.225681735958},
#   {'id': 'OLSSJIp8pu5UlugTF7tuHA',
#    'alias': 'ootoya-chelsea-new-york',
#    'name': 'Ootoya Chelsea',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bBYOWD2DUwWaML3ADlcZ9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ootoya-chelsea-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1427,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'japacurry', 'title': 'Japanese Curry'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.738721, 'longitude': -73.99279},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '8 W 18th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8 W 18th St', 'New York, NY 10011']},
#    'phone': '+12122550018',
#    'display_phone': '(212) 255-0018',
#    'distance': 3705.421593464517},
#   {'id': 'pNe8ZCkGTe4cXfKdOF7kYQ',
#    'alias': 'ise-restaurant-new-york-3',
#    'name': 'Ise Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/S5SGXwZfHG8Esw2x9-CF4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ise-restaurant-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 511,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7291024, 'longitude': -73.9900618},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '63 Cooper Sq',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63 Cooper Sq', 'New York, NY 10003']},
#    'phone': '+12122284152',
#    'display_phone': '(212) 228-4152',
#    'distance': 2654.657529899308},
#   {'id': 'FYWwW5lcxKzaA98Xgw8bqA',
#    'alias': 'hanon-brooklyn',
#    'name': 'hanon',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dsL1BEJmicoRiQfRHNJcHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hanon-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 202,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7134488, 'longitude': -73.9513445},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '436 Union Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['436 Union Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13477991433',
#    'display_phone': '(347) 799-1433',
#    'distance': 3727.886088653943},
#   {'id': 'kesYSgOJW5krU6L8n9qQ4Q',
#    'alias': 'ichibantei-new-york',
#    'name': 'Ichibantei',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/syVfmMRovMpJiPXLs4EUyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ichibantei-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 234,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73063, 'longitude': -73.98275},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '401 E 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['401 E 13th St', 'New York, NY 10009']},
#    'phone': '+16463689755',
#    'display_phone': '(646) 368-9755',
#    'distance': 2962.9231415353574},
#   {'id': '6lUsFj0KCao678o9L7QwUw',
#    'alias': 'hatsuhana-sushi-restaurant-new-york',
#    'name': 'Hatsuhana Sushi Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yqxu_IyzeCxuKgN9M5ayFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hatsuhana-sushi-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1388,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75703, 'longitude': -73.97692},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '17 E 48th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 E 48th St', 'New York, NY 10017']},
#    'phone': '+12123553345',
#    'display_phone': '(212) 355-3345',
#    'distance': 5920.049431134322},
#   {'id': 'J9UA6rzI5WW_cDGjwDnF5g',
#    'alias': 'tsurutontan-udon-noodle-brasserie-new-york',
#    'name': 'Tsurutontan Udon Noodle Brasserie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/S1XMhxctHZBhMu-qJegLdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tsurutontan-udon-noodle-brasserie-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2009,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73678, 'longitude': -73.9910699},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '21 E 16th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21 E 16th St', 'New York, NY 10003']},
#    'phone': '+12129891000',
#    'display_phone': '(212) 989-1000',
#    'distance': 3503.1155131500914},
#   {'id': 'HFn1sPqKSzvxaMk2n2ZtJw',
#    'alias': 'kotobuki-manhattan-new-york',
#    'name': 'Kotobuki Manhattan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lUQa7hPYeNnhb4qq7jI8fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kotobuki-manhattan-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 648,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.731107, 'longitude': -73.98912},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '56 3rd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['56 3rd Ave', 'New York, NY 10003']},
#    'phone': '+12123535088',
#    'display_phone': '(212) 353-5088',
#    'distance': 2886.611027992669},
#   {'id': 'VdAVjghEq_Zl-DDte0mjrw',
#    'alias': 'acre-brooklyn',
#    'name': 'ACRE',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7KYC_xb8ZZCOrf-SVR1Nbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/acre-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72633, 'longitude': -73.95471},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '64 Meserole Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64 Meserole Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17189549074',
#    'display_phone': '(718) 954-9074',
#    'distance': 4062.4881140396897},
#   {'id': 'aRnqeB3ANO_HKETtyL7rlA',
#    'alias': 'yakitori-tatsu-brooklyn',
#    'name': 'Yakitori Tatsu',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hXkASsnkTSFi9irRNP1oHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yakitori-tatsu-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7205331761803,
#     'longitude': -73.9618723466992},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '90 Kent Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90 Kent Ave', 'Brooklyn, NY 11249']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3206.5138777673296},
#   {'id': 'diz6_4TVSP6EdWEZCZ0Acg',
#    'alias': 'kaoru-new-york',
#    'name': 'Kaoru',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2N5uZFepOyyo0-BycQHPLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaoru-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 405,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75202, 'longitude': -73.96977},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '306 E 46th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['306 E 46th St', 'New York, NY 10017']},
#    'phone': '+12128670874',
#    'display_phone': '(212) 867-0874',
#    'distance': 5572.160826301359},
#   {'id': 'KrJ6m_TkxBAPPSNH-G7rvQ',
#    'alias': 'u-gu-brooklyn-4',
#    'name': 'U-gu',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RItjMW2Bdyhj7JuymhpMPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/u-gu-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 148,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69393, 'longitude': -73.96284},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '541 Myrtle Ave',
#     'address2': 'Ste B',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['541 Myrtle Ave', 'Ste B', 'Brooklyn, NY 11205']},
#    'phone': '+17188570222',
#    'display_phone': '(718) 857-0222',
#    'distance': 2946.825651568673},
#   {'id': 'i8ejDDR4COtukAAA1Ls5fw',
#    'alias': 'soba-ya-new-york',
#    'name': 'Soba-ya',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xGWd2_qlV4fejCuJkJIAVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soba-ya-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1482,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72965, 'longitude': -73.9878899},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '229 E 9th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['229 E 9th St', 'New York, NY 10003']},
#    'phone': '+12125336966',
#    'display_phone': '(212) 533-6966',
#    'distance': 2744.4836849113926},
#   {'id': 'mlm40NxsVJUPnh3LTayaaw',
#    'alias': 'kimika-new-york',
#    'name': 'Kimika',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/N4SCrlJHAWFWw7tUcgV-8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kimika-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 180,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720572, 'longitude': -73.995206},
#    'transactions': ['delivery'],
#    'location': {'address1': '40 Kenmare St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40 Kenmare St', 'New York, NY 10012']},
#    'phone': '+12122569280',
#    'display_phone': '(212) 256-9280',
#    'distance': 1681.2655168704623},
#   {'id': 'bokNBgAa9rmMMO8dkZVR1w',
#    'alias': 'rice-and-miso-brooklyn',
#    'name': 'Rice & Miso',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tVIA3LJJJRVJxFIcQYOljQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rice-and-miso-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6845436245203,
#     'longitude': -73.9837776124477},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '134 Nevins St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['134 Nevins St', 'Brooklyn, NY 11217']},
#    'phone': '+19292793488',
#    'display_phone': '(929) 279-3488',
#    'distance': 2487.455225969594},
#   {'id': 'B8wHwGZCddRZ_T953FApxQ',
#    'alias': 'maki-kosaka-new-york-2',
#    'name': 'Maki Kosaka',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/K3cUEAhuzi77FxntiNHEww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maki-kosaka-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.740322, 'longitude': -73.99379},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '55 W 19th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 W 19th St', 'New York, NY 10011']},
#    'phone': '+19172615538',
#    'display_phone': '(917) 261-5538',
#    'distance': 3875.03890653589},
#   {'id': 'pGYovGGnxm0tMmkiQJPygA',
#    'alias': 'ume-williamsburg-brooklyn',
#    'name': 'Ume Williamsburg',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Xf4YxwWndOMp-5Ho_iJ6tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ume-williamsburg-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 259,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71657, 'longitude': -73.96559},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '237 Kent Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['237 Kent Ave', 'Brooklyn, NY 11249']},
#    'phone': '+19294203253',
#    'display_phone': '(929) 420-3253',
#    'distance': 2724.4228536190876},
#   {'id': 'ax4INkzwL__-d_kGJfcA-w',
#    'alias': 'kaikagetsu-nyc-new-york-2',
#    'name': 'Kaikagetsu NYC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vtl3gL8XoiPNV-MwPvEuVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaikagetsu-nyc-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 104,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72104, 'longitude': -73.98848},
#    'transactions': ['restaurant_reservation', 'delivery'],
#    'price': '$$$$',
#    'location': {'address1': '162 Orchard St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 Orchard St', 'New York, NY 10002']},
#    'phone': '+16465903900',
#    'display_phone': '(646) 590-3900',
#    'distance': 1800.6650070425846},
#   {'id': 'Lz_9RXFKmOaSA4IpgV6NlA',
#    'alias': 'karazishi-botan-brooklyn',
#    'name': 'Karazishi Botan',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6LmRjLlvex87GKomJ2DVCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/karazishi-botan-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 61,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68312, 'longitude': -73.99278},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '255 Smith St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['255 Smith St', 'Brooklyn, NY 11231']},
#    'phone': '+13477631155',
#    'display_phone': '(347) 763-1155',
#    'distance': 2484.443222181057},
#   {'id': '6FZf17rNThWKoF4EU18wnw',
#    'alias': 'yakiniku-futago-new-york',
#    'name': 'Yakiniku Futago',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LcZBEtzW6oGEucJuAUOsuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yakiniku-futago-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 391,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.738851870947,
#     'longitude': -73.9941236398979},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '37 W 17th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37 W 17th St', 'New York, NY 10011']},
#    'phone': '+12126200225',
#    'display_phone': '(212) 620-0225',
#    'distance': 3714.713004612417},
#   {'id': 'pqqhHTz_ZpApsaWGa_zMTA',
#    'alias': 'douska-new-york',
#    'name': 'Douska',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mVPExHYYyAIM4ts62LwRlg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/douska-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 126,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7191369, 'longitude': -73.9908998},
#    'transactions': [],
#    'location': {'address1': '63 Delancey St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63 Delancey St', 'New York, NY 10002']},
#    'phone': '+16466570908',
#    'display_phone': '(646) 657-0908',
#    'distance': 1544.6963982812902},
#   {'id': 'xrZWbxETIF8qj6h4uvhJrQ',
#    'alias': 'j-spec-new-york',
#    'name': 'J-Spec',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/T-2fxrDhJlqT9lGSm9n-Fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/j-spec-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72699, 'longitude': -73.98922},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '239 E 5th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['239 E 5th St', 'New York, NY 10003']},
#    'phone': '+12122870107',
#    'display_phone': '(212) 287-0107',
#    'distance': 2438.0326883939874},
#   {'id': 'kN3rkbjvqkY62CDRYUVz4g',
#    'alias': 'yopparai-new-york',
#    'name': 'Yopparai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8DN014rsW2ZbQ01SOTCU8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yopparai-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 235,
#    'categories': [{'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71976194368783,
#     'longitude': -73.98497117259807},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '49 Clinton St',
#     'address2': 'Ground Floor',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['49 Clinton St',
#      'Ground Floor',
#      'New York, NY 10002']},
#    'phone': '+12127777253',
#    'display_phone': '(212) 777-7253',
#    'distance': 1775.3162440008136},
#   {'id': 'P_UREWCQxEYVbBa-KW_Wew',
#    'alias': 'en-japanese-brasserie-new-york',
#    'name': 'EN Japanese Brasserie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/59UYR8bkVNviIfD6GQDLLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/en-japanese-brasserie-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1280,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7306, 'longitude': -74.00698},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '435 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['435 Hudson St', 'New York, NY 10014']},
#    'phone': '+12126479196',
#    'display_phone': '(212) 647-9196',
#    'distance': 3003.352598143026},
#   {'id': 'n1xpGOPa7XRq4or7QLjzHw',
#    'alias': 'dokodemo-new-york',
#    'name': 'DokoDemo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/X5MbSP7oN9DGK7bdGeJ6OA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dokodemo-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 337,
#    'categories': [{'alias': 'teppanyaki', 'title': 'Teppanyaki'},
#     {'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72638, 'longitude': -73.98964},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '89 E 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['89 E 4th St', 'New York, NY 10003']},
#    'phone': '+19172615228',
#    'display_phone': '(917) 261-5228',
#    'distance': 2361.837949856619},
#   {'id': 'BlzlywklvYdek5uk_NCX9g',
#    'alias': 'suzume-brooklyn',
#    'name': 'Suzume',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1ti7szssQZHXebWPrUNwqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/suzume-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 326,
#    'categories': [{'alias': 'filipino', 'title': 'Filipino'},
#     {'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'hawaiian', 'title': 'Hawaiian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7131652, 'longitude': -73.9494479},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '545 Lorimer St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['545 Lorimer St', 'Brooklyn, NY 11211']},
#    'phone': '+17184860200',
#    'display_phone': '(718) 486-0200',
#    'distance': 3876.21491035216},
#   {'id': '7iY35991NhQ1AShJZCNZgA',
#    'alias': 'sakagura-new-york',
#    'name': 'Sakagura',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UTNso2U3VAiTXdDV98Jbzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sakagura-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1783,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7516467024541,
#     'longitude': -73.9729489318165},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '211 E 43rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['211 E 43rd St', 'New York, NY 10017']},
#    'phone': '+12129537253',
#    'display_phone': '(212) 953-7253',
#    'distance': 5443.138436306642},
#   {'id': '7rxg-tWPc1jK7Cikn5R86g',
#    'alias': 'hi-collar-new-york-2',
#    'name': 'Hi-Collar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6DAtn_pu8hX79LB3sSlFtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hi-collar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 641,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729564, 'longitude': -73.98786},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '231 E 9th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 E 9th St', 'New York, NY 10003']},
#    'phone': '+12127777018',
#    'display_phone': '(212) 777-7018',
#    'distance': 2736.177785571269},
#   {'id': 'ocnHpILS80DHL--34L8xpw',
#    'alias': 'sushi-noz-new-york',
#    'name': 'Sushi Noz',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QGvPobBslCxRVe8n0NfpCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-noz-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 139,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77385, 'longitude': -73.95813},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '181 E 78th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['181 E 78th St', 'New York, NY 10075']},
#    'phone': '+19173381792',
#    'display_phone': '(917) 338-1792',
#    'distance': 8197.706767509848},
#   {'id': 'Ww3aAPf0sA5ygAXu2qV1ZQ',
#    'alias': 'taiki-brooklyn',
#    'name': 'Taiki',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VYFTgiaT2aPwweuoadt6-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taiki-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6845433545275,
#     'longitude': -73.9837775425761},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '134 Nevins St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['134 Nevins St', 'Brooklyn, NY 11217']},
#    'phone': '+19293564826',
#    'display_phone': '(929) 356-4826',
#    'distance': 2481.156681334874},
#   {'id': 'RYKGs45OjF-vlb2Ds2Jb_g',
#    'alias': 'izakaya-juraku-new-york-2',
#    'name': 'Izakaya Juraku',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xlRw20ojLF480_VF8GNrZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-juraku-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 139,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7196796287355,
#     'longitude': -73.9887088537216},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '121 Ludlow St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['121 Ludlow St', 'New York, NY 10002']},
#    'phone': '+12124770100',
#    'display_phone': '(212) 477-0100',
#    'distance': 1651.3305168112172},
#   {'id': 'ZaJS8EKQNSaQpwpmgN-vVw',
#    'alias': 'samurai-mama-brooklyn',
#    'name': 'Samurai Mama',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iU4mCy9pszj-Kx3WzcAXQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/samurai-mama-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 612,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7140208838114,
#     'longitude': -73.960325717926},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '205 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['205 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17185996161',
#    'display_phone': '(718) 599-6161',
#    'distance': 3017.69647092549},
#   {'id': 'icZcEK39HXuL2q08i4EkkQ',
#    'alias': 'bessou-new-york',
#    'name': 'Bessou',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PD7tgyIwu8gNU56oKn2Oxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bessou-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 315,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.725502, 'longitude': -73.992675},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '5 Bleecker St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 Bleecker St', 'New York, NY 10012']},
#    'phone': '+12122288502',
#    'display_phone': '(212) 228-8502',
#    'distance': 2237.328414577862},
#   {'id': '22CRLIEfJWIO-8RjEiecAg',
#    'alias': 'akino-elmhurst',
#    'name': 'Akino',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7OaFodhkcMGYurUhJs7Ifw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/akino-elmhurst?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 914,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.741236, 'longitude': -73.881306},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '82-80 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['82-80 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+17187798280',
#    'display_phone': '(718) 779-8280',
#    'distance': 10319.817555373415},
#   {'id': 'lxQ-tzFmL1tmUqZUN-CSRQ',
#    'alias': 'bozu-brooklyn',
#    'name': 'Bozu',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/N-BH6kfb9LAYAANMVVSkcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bozu-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 844,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7129, 'longitude': -73.95749},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '296 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['296 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17183847770',
#    'display_phone': '(718) 384-7770',
#    'distance': 3200.7565834137804},
#   {'id': 'itblJyiTY2h2ACidLk66oA',
#    'alias': 'takahachi-new-york',
#    'name': 'Takahachi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hEeWHgKSHySg1i9RUQTzUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/takahachi-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 574,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.725315, 'longitude': -73.984436},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '85 Ave A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 Ave A', 'New York, NY 10009']},
#    'phone': '+12125056524',
#    'display_phone': '(212) 505-6524',
#    'distance': 2353.3280141568616},
#   {'id': '4eAgPj7eKonKAtk64kgUfQ',
#    'alias': 'matsuri-woodside',
#    'name': 'Matsuri',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GnhraiRr1D8QhdK5CRsSnQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/matsuri-woodside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 165,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7458357, 'longitude': -73.9035436},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '39-56 61st St',
#     'address2': '',
#     'address3': None,
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39-56 61st St', 'Woodside, NY 11377']},
#    'phone': '+17184241688',
#    'display_phone': '(718) 424-1688',
#    'distance': 8868.626626545061}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#     Restaurant        Type Price Rating         Address        Lat        Lng  \
# 0         Raku    Japanese    $$    4.5    342 E 6th St  40.726499 -73.986653
# 1      Okonomi    Japanese    $$    4.5  150 Ainslie St  40.712622 -73.948784
# 2      Benemon    Japanese    $$    4.5    108 E 4th St  40.725510 -73.988380
# 3  Izakaya MEW  Tapas Bars    $$      4    53 W 35th St  40.750148 -73.986320
# 4       Kimura    Japanese    $$    4.5  31 St Marks Pl  40.728995 -73.988279
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/raku-new-york-7?adjus...  FlZ1zdVEKWv7dwqm8Uw8-w
# 1  https://www.yelp.com/biz/okonomi-brooklyn?adju...  7OMGEtFWT6sdd9TVuoGqJQ
# 2  https://www.yelp.com/biz/benemon-new-york?adju...  axqp3pGJXnTLgq2QrPyDyQ
# 3  https://www.yelp.com/biz/izakaya-mew-new-york-...  klAhw3xLQi9GF1tf_HnS7w
# 4  https://www.yelp.com/biz/kimura-new-york?adjus...  eQ4QUGvuHGBzsOrphsVc6A

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"japanese","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': 'wcwftlB-61XG4ymGTR61aw',
#    'alias': 'sakamai-new-york',
#    'name': 'SakaMai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KW_Q6i-ru5fe9DQICeqB_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sakamai-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 711,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7209536656701,
#     'longitude': -73.9881407239426},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '157 Ludlow St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['157 Ludlow St', 'New York, NY 10002']},
#    'phone': '+16465900684',
#    'display_phone': '(646) 590-0684',
#    'distance': 1800.7758678600844},
#   {'id': 'T2fE7hGS83Ba-QNCOqbK4A',
#    'alias': 'ako-brooklyn-5',
#    'name': 'Ako',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XG4n3k-9-S6MMIlrec9qKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ako-brooklyn-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 436,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7168599, 'longitude': -73.95845},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '205 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['205 Bedford Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17183022035',
#    'display_phone': '(718) 302-2035',
#    'distance': 3275.340512544691},
#   {'id': 'i8F0fnempD5fTb2CxbwKDw',
#    'alias': 'izakaya-new-york-2',
#    'name': 'Izakaya',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FHCms4PlmtuQJc4jo1wccw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 263,
#    'categories': [{'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72667, 'longitude': -73.98738},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '326 E 6th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['326 E 6th St', 'New York, NY 10003']},
#    'phone': '+19176977162',
#    'display_phone': '(917) 697-7162',
#    'distance': 2437.9568274699823},
#   {'id': 'sCx8tslal3pMurNyGFVjMQ',
#    'alias': 'evil-katsu-new-york',
#    'name': 'Evil Katsu',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UxSxT7zH-d8ijrja_ukIbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/evil-katsu-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72768479788727,
#     'longitude': -73.98324300000446},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '435 East 9th',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['435 East 9th', 'New York, NY 10009']},
#    'phone': '+16463703435',
#    'display_phone': '(646) 370-3435',
#    'distance': 2642.515908320115},
#   {'id': 'wjIyCBEpCG_HRp8veiI0YQ',
#    'alias': 'ootoya-times-square-new-york-2',
#    'name': 'Ootoya Times Square',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mBXdPvxAeYXAunyWau1XpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ootoya-times-square-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 968,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'japacurry', 'title': 'Japanese Curry'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75487, 'longitude': -73.98599},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '141 W 41st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['141 W 41st St', 'New York, NY 10036']},
#    'phone': '+12127040833',
#    'display_phone': '(212) 704-0833',
#    'distance': 5546.460552208884},
#   {'id': 'aTzxrI2o3vH_HQkqeFszzg',
#    'alias': 'juban-new-york',
#    'name': 'Juban',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/z4wGR1TUQzI36YN-mGuUKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/juban-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 202,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74731, 'longitude': -74.00467},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '207 10th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['207 10th Ave', 'New York, NY 10011']},
#    'phone': '+16463989770',
#    'display_phone': '(646) 398-9770',
#    'distance': 4738.369461773232},
#   {'id': 'OFfZUS-nu6NDnsWe1B2bUQ',
#    'alias': 'tonchin-new-york-new-york',
#    'name': 'TONCHIN NEW YORK',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4OvK45jvFYpAoU8e2QfJfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tonchin-new-york-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1407,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7502727, 'longitude': -73.9844951},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '13 W 36th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['13 W 36th St', 'New York, NY 10018']},
#    'phone': '+16466929912',
#    'display_phone': '(646) 692-9912',
#    'distance': 5052.538311265594},
#   {'id': 'NRJq2BNcbjqAyxUB_bw7gw',
#    'alias': 'momoya-new-york',
#    'name': 'Momoya',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QZg0n_Fz1kjkl5pX1RShnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/momoya-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 709,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7426255196333,
#     'longitude': -73.9966481924057},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '185 7th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['185 7th Ave', 'New York, NY 10011']},
#    'phone': '+12129894466',
#    'display_phone': '(212) 989-4466',
#    'distance': 4137.730524078914},
#   {'id': 'm1cJLpDN4B-_0hGgPfe5OA',
#    'alias': 'salt-charcoal-brooklyn',
#    'name': 'Salt + Charcoal',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/stPcp8twyzWq4LjF5jaRNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salt-charcoal-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 586,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71453, 'longitude': -73.9613511},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '171 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 Grand St', 'Brooklyn, NY 11249']},
#    'phone': '+17187822087',
#    'display_phone': '(718) 782-2087',
#    'distance': 2954.688075109069},
#   {'id': 'flHcoaHEWxACgc-Vk9MsOQ',
#    'alias': 'jukai-new-york',
#    'name': 'Jukai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TNSgo4eje9hr__xUC5J_uA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jukai-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 164,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7572093705873,
#     'longitude': -73.9678837692742},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '237 E 53rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['237 E 53rd St', 'New York, NY 10022']},
#    'phone': '+12125889788',
#    'display_phone': '(212) 588-9788',
#    'distance': 6171.1248926595545},
#   {'id': 'aK2ipD9K8-usBw_gkvvJuw',
#    'alias': 'nare-sushi-new-york',
#    'name': 'Nare Sushi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UoX_jxCtd440sxMK3WehOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nare-sushi-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 369,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76143, 'longitude': -73.96992},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '115 E 57th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['115 E 57th St', 'New York, NY 10022']},
#    'phone': '+16466660061',
#    'display_phone': '(646) 666-0061',
#    'distance': 6563.24869140818},
#   {'id': '_FhKGcCbiYgtkXcCiwTAiA',
#    'alias': 'aburiya-kinnosuke-new-york',
#    'name': 'Aburiya Kinnosuke',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/R-OczJWhCtsCQhWc7Ff-EQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aburiya-kinnosuke-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 761,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.752583, 'longitude': -73.972274},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '213 E 45th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['213 E 45th St', 'New York, NY 10017']},
#    'phone': '+12128675454',
#    'display_phone': '(212) 867-5454',
#    'distance': 5560.223450920015},
#   {'id': 'kwq1W0opBnOYKoUXWYyQ5g',
#    'alias': 'momokawa-new-york-2',
#    'name': 'Momokawa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rb4YDl2LkDrYKfsAoiwYvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/momokawa-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 186,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77047, 'longitude': -73.9537},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '1466 1st Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1466 1st Ave', 'New York, NY 10075']},
#    'phone': '+12122560403',
#    'display_phone': '(212) 256-0403',
#    'distance': 7998.858190736131},
#   {'id': 'PTYUAAJbEmvIv4EsyRrcnA',
#    'alias': 'momoya-new-york-2',
#    'name': 'Momoya',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VuuQaicuoIhdPAOXDfd1OQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/momoya-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 478,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.784043, 'longitude': -73.977391},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '427 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['427 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12125800007',
#    'display_phone': '(212) 580-0007',
#    'distance': 8854.939080659266},
#   {'id': 'zJcxZQbTSAP3q4Fy-6WAyw',
#    'alias': 'shalom-japan-brooklyn',
#    'name': 'Shalom Japan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/F0f37eyiRrEpmzLiwcAMZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shalom-japan-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 305,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7091679, 'longitude': -73.9558028},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '310 S 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['310 S 4th St', 'Brooklyn, NY 11211']},
#    'phone': '+17183884012',
#    'display_phone': '(718) 388-4012',
#    'distance': 3270.7140308075363},
#   {'id': 'YvRTy-6_akPsz25BSSuC_w',
#    'alias': 'sushi-teru-new-york',
#    'name': 'Sushi Teru',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-zU4g60H1VZy5cau-i0V3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-teru-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.737832, 'longitude': -74.00594},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '615 1/2 Hudson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['615 1/2 Hudson St', 'New York, NY 10014']},
#    'phone': '+16469228677',
#    'display_phone': '(646) 922-8677',
#    'distance': 3741.051371342627},
#   {'id': 'LOZ0SaAh2uAMkRD47j6bhQ',
#    'alias': 'wakuwaku-brooklyn',
#    'name': 'Wakuwaku',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bUXJuABpVc8U9xRq9aA6tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wakuwaku-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6559047, 'longitude': -74.0067754},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '269 36th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11232',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['269 36th St', 'Brooklyn, NY 11232']},
#    'phone': '+13475844577',
#    'display_phone': '(347) 584-4577',
#    'distance': 5595.600080226466},
#   {'id': 'DNSFvZtdsqkaidmFSpm-Jw',
#    'alias': 'soba-noodle-azuma-new-york-3',
#    'name': 'Soba Noodle Azuma',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NYDhgDn4a2Bb3dUNvA3fng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soba-noodle-azuma-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 317,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76526, 'longitude': -73.9832},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '251 W 55th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['251 W 55th St', 'New York, NY 10019']},
#    'phone': '+19172620540',
#    'display_phone': '(917) 262-0540',
#    'distance': 6721.596374906867},
#   {'id': 'GrYs4dj4mseJ4ctu4KhR9Q',
#    'alias': 'ikebana-zen-new-york',
#    'name': 'Ikebana Zen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Loj8DvokEWUMjG7RD-MLcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ikebana-zen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 74,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.765644, 'longitude': -73.9879068},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '401 W 53rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['401 W 53rd St', 'New York, NY 10019']},
#    'phone': '+19173882268',
#    'display_phone': '(917) 388-2268',
#    'distance': 6715.423728315272},
#   {'id': 'I70GNfUnPUzJU77QHW_F_A',
#    'alias': 'rice-and-miso-new-york',
#    'name': 'Rice & Miso',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NdVjbBOAjC6fCa9thdJiAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rice-and-miso-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71701835206153, 'longitude': -73.9932757},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '70 Forsyth St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70 Forsyth St', 'New York, NY 10002']},
#    'phone': '+16464550069',
#    'display_phone': '(646) 455-0069',
#    'distance': 1289.7662086048342},
#   {'id': 'o5EIqc4LekAoeLHiYjzLqQ',
#    'alias': 'bar-goto-new-york',
#    'name': 'Bar Goto',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xU2OQQL91BtqE300D_mNMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-goto-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 239,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72277, 'longitude': -73.98989},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '245 Eldridge St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['245 Eldridge St', 'New York, NY 10002']},
#    'phone': '+12124754411',
#    'display_phone': '(212) 475-4411',
#    'distance': 1962.8019893509165},
#   {'id': 'vHs2lZOqcyuv5uO-OOs_Sg',
#    'alias': 'to-date-japanese-food-brooklyn-2',
#    'name': 'To Date Japanese Food',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tfqK20tAHhqR58mrTFZQ1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/to-date-japanese-food-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.637337, 'longitude': -74.008481},
#    'transactions': ['delivery'],
#    'location': {'address1': '768 57th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11220',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['768 57th St', 'Brooklyn, NY 11220']},
#    'phone': '+17185670888',
#    'display_phone': '(718) 567-0888',
#    'distance': 7667.686961226783},
#   {'id': '6t5xWjPLWAjJV3YFMX_oaw',
#    'alias': 'hirohisa-new-york',
#    'name': 'Hirohisa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7tIm34cRt60wF4MjSX8aqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hirohisa-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 167,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.724597, 'longitude': -74.003174},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '73 Thompson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['73 Thompson St', 'New York, NY 10012']},
#    'phone': '+12129251613',
#    'display_phone': '(212) 925-1613',
#    'distance': 2257.322551527954},
#   {'id': 'XAEwG1bfAiWUewpzZnB2uw',
#    'alias': 'chikarashi-isso-new-york',
#    'name': 'Chikarashi Isso',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vOw1SQWjuRds8k3LFtK7Rg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chikarashi-isso-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'whiskeybars', 'title': 'Whiskey Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.708376, 'longitude': -74.0144832},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '38 Rector St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10006',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38 Rector St', 'New York, NY 10006']},
#    'phone': '+16465968298',
#    'display_phone': '(646) 596-8298',
#    'distance': 1732.7800360377412},
#   {'id': 'B-lJd1eBLcLk1StNbgAe9w',
#    'alias': 'sushi-katsuei-brooklyn',
#    'name': 'Sushi Katsuei',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CIwbXKZxPiMa0bjChkhbIQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-katsuei-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 472,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6707147, 'longitude': -73.9785903},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '210 7th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['210 7th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187885338',
#    'display_phone': '(718) 788-5338',
#    'distance': 4082.473083842233},
#   {'id': 'HC18oDJ2svQoXIddP-wuyw',
#    'alias': 'wasan-brooklyn-brooklyn',
#    'name': 'Wasan Brooklyn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bgILfWQw8maKR-o9a4uc_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wasan-brooklyn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 238,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6812605, 'longitude': -73.9768418},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '440 Bergen St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['440 Bergen St', 'Brooklyn, NY 11217']},
#    'phone': '+17188643549',
#    'display_phone': '(718) 864-3549',
#    'distance': 3060.334668618367},
#   {'id': 'MM5P9cKlzovYLcf5qf2SwQ',
#    'alias': '1-or-8-brooklyn',
#    'name': '1 OR 8',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8o_5LakeGf7rLAFpAdb5hQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/1-or-8-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 417,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6896859, 'longitude': -73.9703551},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '229 Dekalb Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['229 Dekalb Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17183842152',
#    'display_phone': '(718) 384-2152',
#    'distance': 2672.6799518701496},
#   {'id': 'eyjeP9CJZ_gYgeJFP_vtpQ',
#    'alias': 'karasu-brooklyn-2',
#    'name': 'Karasu',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yWwgYzajAiQE9w7r6jw73Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/karasu-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 102,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.689411, 'longitude': -73.973256},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '166 Dekalb Ave',
#     'address2': None,
#     'address3': "Walter's",
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['166 Dekalb Ave', "Walter's", 'Brooklyn, NY 11217']},
#    'phone': '+13472234811',
#    'display_phone': '(347) 223-4811',
#    'distance': 2519.304453943392},
#   {'id': 'L7_siqDfU4-ZA17YtA-SBg',
#    'alias': 'silver-factory-brooklyn',
#    'name': 'Silver Factory',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jIK4cIYx8mer_6MBxDR_iQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/silver-factory-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 233,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.709227, 'longitude': -73.958598},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '270 South 5th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['270 South 5th St', 'Brooklyn, NY 11211']},
#    'phone': '+13477253017',
#    'display_phone': '(347) 725-3017',
#    'distance': 3039.9237511522865},
#   {'id': 'PwrYnl3j3YCGzILX_5UHpw',
#    'alias': 'davelle-new-york-2',
#    'name': 'Davelle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jzTgx708l_9ewrlozC6p-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/davelle-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 184,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71852, 'longitude': -73.98605},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '102 Suffolk St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 Suffolk St', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1612.1924185402318},
#   {'id': 'cyOaoc0U6Trc0FZu6l14VQ',
#    'alias': 'sarashina-horii-new-york-2',
#    'name': 'Sarashina Horii',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5p7KW5JSokbR5mgIZ9t6TQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sarashina-horii-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73871, 'longitude': -73.98838},
#    'transactions': ['delivery'],
#    'location': {'address1': '45 E 20th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 E 20th St', 'New York, NY 10003']},
#    'phone': '+19174090546',
#    'display_phone': '(917) 409-0546',
#    'distance': 3740.796633573266},
#   {'id': 'FLKABU82NNDnCvZSZD75Bg',
#    'alias': 'naruto-ramen-new-york-3',
#    'name': 'Naruto Ramen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NsEs73Nd3sEaPasKKL8gEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/naruto-ramen-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 270,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7968567, 'longitude': -73.9698717},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2634 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2634 Broadway', 'New York, NY 10025']},
#    'phone': '+12122220229',
#    'display_phone': '(212) 222-0229',
#    'distance': 10384.799098874411},
#   {'id': 'xtxcAUvrD4dWHJd0cwvW1A',
#    'alias': 'jeju-noodle-bar-new-york',
#    'name': 'JeJu Noodle Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/grYU8HjlM-6dSTgW27rhAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jeju-noodle-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 678,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73304, 'longitude': -74.00734},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '679 Greenwich St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['679 Greenwich St', 'New York, NY 10014']},
#    'phone': '+16466660947',
#    'display_phone': '(646) 666-0947',
#    'distance': 3256.137406146092},
#   {'id': '8NVN6Nldm7AGoGaABBZMRw',
#    'alias': 'izakaya-nomad-new-york',
#    'name': 'Izakaya NoMad',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/s3qyS_ZDM3WXeqXjLNFPCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-nomad-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 686,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74409, 'longitude': -73.98945},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '13 W 26th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['13 W 26th St', 'New York, NY 10010']},
#    'phone': '+12122136258',
#    'display_phone': '(212) 213-6258',
#    'distance': 4324.0303176280795},
#   {'id': 'tT6teP3ZfCAfvdPdDoqG4A',
#    'alias': 'ki-sushi-brooklyn',
#    'name': 'Ki Sushi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Mbkxqjg7HBvrez77WmwHrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ki-sushi-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 721,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68764, 'longitude': -73.9901},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '122 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['122 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17189350575',
#    'display_phone': '(718) 935-0575',
#    'distance': 2009.758329718251},
#   {'id': 'K84FS4X-Hj2Xt_uUCjwNIA',
#    'alias': 'kissaki-sushi-new-york',
#    'name': 'Kissaki Sushi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AYaUlJoMlO58i55eg28d0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kissaki-sushi-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.778571, 'longitude': -73.978209},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '286 Columbus Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['286 Columbus Ave', 'New York, NY 10023']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8239.494885798758},
#   {'id': 'hUf1EpnxbxFU4gf2nL7H-Q',
#    'alias': 'raku-its-japanese-new-york-2',
#    'name': "Raku it's Japanese",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/X4lJ52VZeEJ5WSTT1WCqWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raku-its-japanese-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 122,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.756591, 'longitude': -73.969306},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '212 East 52nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['212 East 52nd St', 'New York, NY 10022']},
#    'phone': '+12123553272',
#    'display_phone': '(212) 355-3272',
#    'distance': 6065.787252588288},
#   {'id': 'TBp9gdS6xEbSQqffVZ7iag',
#    'alias': 'kazunori-the-original-hand-roll-bar-new-york-2',
#    'name': 'KazuNori  | The Original Hand Roll Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FjKC8ZesjXfRoIJEp8IeqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kazunori-the-original-hand-roll-bar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1080,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74519, 'longitude': -73.98824},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '15 W 28th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 W 28th St', 'New York, NY 10001']},
#    'phone': '+13475945940',
#    'display_phone': '(347) 594-5940',
#    'distance': 4460.538165218128},
#   {'id': 'nrxSzq-VxLqD7aFkE4SH3Q',
#    'alias': 'cocoron-new-york-2',
#    'name': 'Cocoron',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1bYemlNsVqys2QiOezAT4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cocoron-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 675,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7207236, 'longitude': -73.9953191},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '37 Kenmare St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37 Kenmare St', 'New York, NY 10012']},
#    'phone': '+12129660800',
#    'display_phone': '(212) 966-0800',
#    'distance': 1701.114902248387},
#   {'id': 'aE7hRzK1t80iFyi4Do77lw',
#    'alias': 'sushi-uesugi-brooklyn',
#    'name': 'Sushi Uesugi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0xy_mbJXN1HZGkQFvADuHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-uesugi-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6560432255486,
#     'longitude': -74.0064066279496},
#    'transactions': [],
#    'location': {'address1': '934 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11232',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['934 3rd Ave', 'Brooklyn, NY 11232']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5587.369139785564},
#   {'id': '0Lnp_fi3gI2bfJ8RcMDfjg',
#    'alias': 'gen-brooklyn',
#    'name': 'Gen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-ix14U1b4usZgFcGPvzoOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gen-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 282,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.677639, 'longitude': -73.963485},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '659 Washington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['659 Washington Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17183983550',
#    'display_phone': '(718) 398-3550',
#    'distance': 4037.7232033486},
#   {'id': 'Nbqzy3ea5_x2zXWkdWlUIQ',
#    'alias': 'sake-bar-hagi-46-new-york-3',
#    'name': 'Sake Bar Hagi 46',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bROx6Lt8lEJ_JeUdWZw01Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sake-bar-hagi-46-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 341,
#    'categories': [{'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76057, 'longitude': -73.99008},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '358 W 46th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['358 W 46th St', 'New York, NY 10036']},
#    'phone': '+12129562429',
#    'display_phone': '(212) 956-2429',
#    'distance': 6134.20006568508},
#   {'id': '0gPXct_l_82phIEoKdtWZw',
#    'alias': 'ryujin-brooklyn-8',
#    'name': 'RYUJIN',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qok9QqxbVYHMHETgZ2gs9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ryujin-brooklyn-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 307,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.711178187852,
#     'longitude': -73.9506256676857},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '513 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['513 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17187099888',
#    'display_phone': '(718) 709-9888',
#    'distance': 3735.5426813558047},
#   {'id': 'a8Lj13uc3Hhyjm0eYL90sw',
#    'alias': 'sushi-on-me-jackson-heights',
#    'name': 'Sushi On Me',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fBOFC0jM6xj_sJmFRPH9CQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-on-me-jackson-heights?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 91,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.746444, 'longitude': -73.893947},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '71-26 Roosevelt Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['71-26 Roosevelt Ave', 'Jackson Heights, NY 11372']},
#    'phone': '+19292685691',
#    'display_phone': '(929) 268-5691',
#    'distance': 9606.338880318372},
#   {'id': 'l_RAv09V67j-Hm9dyZxWhw',
#    'alias': 'tomi-jazz-new-york',
#    'name': 'Tomi Jazz',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/plM_uVAWQiUotmroZ5jtgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tomi-jazz-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 521,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'jazzandblues', 'title': 'Jazz & Blues'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75725, 'longitude': -73.96774},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '239 E 53rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['239 E 53rd St', 'New York, NY 10022']},
#    'phone': '+16464971254',
#    'display_phone': '(646) 497-1254',
#    'distance': 6173.258261096518},
#   {'id': 'MWx4HB9p7pCzse9CInLuDw',
#    'alias': 'sushi-seki-new-york-9',
#    'name': 'Sushi Seki',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UoKFtYGAt5dqKQS1jJpByA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-seki-new-york-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 513,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.761918, 'longitude': -73.960536},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '1143 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1143 1st Ave', 'New York, NY 10065']},
#    'phone': '+12123710238',
#    'display_phone': '(212) 371-0238',
#    'distance': 6893.65508708051},
#   {'id': 'ULDVJYTT-47RqbLtlR_FUA',
#    'alias': 'ootoya-union-square-new-york-2',
#    'name': 'Ootoya Union Square',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MBG4mkEcgUt30NG5QVK1mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ootoya-union-square-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 341,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'japacurry', 'title': 'Japanese Curry'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73316, 'longitude': -73.99273},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '41 E 11th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41 E 11th St', 'New York, NY 10003']},
#    'phone': '+12124734300',
#    'display_phone': '(212) 473-4300',
#    'distance': 3086.8860063806446},
#   {'id': 'LKNhVc1VIt87NQL2wn9rnw',
#    'alias': 'suki-new-york-5',
#    'name': 'Suki',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/80D4gESJg3O-arQpLPV2SQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/suki-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 174,
#    'categories': [{'alias': 'japacurry', 'title': 'Japanese Curry'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.726943, 'longitude': -73.986107},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '111 1st Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 1st Ave', 'New York, NY 10003']},
#    'phone': '+19179996672',
#    'display_phone': '(917) 999-6672',
#    'distance': 2490.1548669275567},
#   {'id': '479rycCXZojMT9S0cl8Oxg',
#    'alias': 'yakiniku-gen-new-york',
#    'name': 'Yakiniku Gen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XDPwXNfvbwenB-jR02moSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yakiniku-gen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 147,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75611, 'longitude': -73.96815},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '250 E 52nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['250 E 52nd St', 'New York, NY 10022']},
#    'phone': '+12126021129',
#    'display_phone': '(212) 602-1129',
#    'distance': 6052.305245221978},
#   {'id': '1wawnv6mzqatgA17pukdZw',
#    'alias': 'nakaji-new-york',
#    'name': 'Nakaji',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/juAICvzNLMXG7H7y11Ghpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nakaji-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7157, 'longitude': -73.99663},
#    'transactions': ['delivery'],
#    'location': {'address1': '48 Bowery',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['48 Bowery', 'New York, NY 10013']},
#    'phone': '+16464788282',
#    'display_phone': '(646) 478-8282',
#    'distance': 1165.9015274200265}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#             Restaurant        Type Price Rating          Address        Lat  \
# 0              SakaMai    Japanese   $$$      4    157 Ludlow St  40.720954
# 1                  Ako  Sushi Bars    $$      4  205 Bedford Ave  40.716860
# 2              Izakaya     Izakaya    $$      4     326 E 6th St  40.726670
# 3           Evil Katsu    Japanese                  435 East 9th  40.727685
# 4  Ootoya Times Square  Sushi Bars    $$      4    141 W 41st St  40.754870
#
#          Lng                                                url  \
# 0 -73.988141  https://www.yelp.com/biz/sakamai-new-york?adju...
# 1 -73.958450  https://www.yelp.com/biz/ako-brooklyn-5?adjust...
# 2 -73.987380  https://www.yelp.com/biz/izakaya-new-york-2?ad...
# 3 -73.983243
# 4 -73.985990  https://www.yelp.com/biz/ootoya-times-square-n...
#
#                        ID
# 0  wcwftlB-61XG4ymGTR61aw
# 1  T2fE7hGS83Ba-QNCOqbK4A
# 2  i8F0fnempD5fTb2CxbwKDw
# 3
# 4  wjIyCBEpCG_HRp8veiI0YQ

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"japanese","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': 'y_ylOQzCP-9D_4DcUIJ3jA',
#    'alias': 'shabu-tatsu-east-village-new-york',
#    'name': 'Shabu-Tatsu East Village',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UZp2FRvjaKpfQ7A1-apoSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shabu-tatsu-east-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 645,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729147, 'longitude': -73.985906},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '216 E 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['216 E 10th St', 'New York, NY 10003']},
#    'phone': '+12124772972',
#    'display_phone': '(212) 477-2972',
#    'distance': 2730.9836122916126},
#   {'id': 'X73hpslpgeJNhVohYIUzfQ',
#    'alias': 'dashi-brooklyn-brooklyn-3',
#    'name': 'Dashi - Brooklyn',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m0W88G9NHouSFhBp_GB_fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dashi-brooklyn-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.707885, 'longitude': -73.929212},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '119 Ingraham St',
#     'address2': 'Fl 1',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['119 Ingraham St', 'Fl 1', 'Brooklyn, NY 11237']},
#    'phone': '+19292763310',
#    'display_phone': '(929) 276-3310',
#    'distance': 5490.910023270714},
#   {'id': 'zGAQqDu0Ak2khVYs9WdQxw',
#    'alias': 'sushi-nakazawa-new-york',
#    'name': 'Sushi Nakazawa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tNBLvnE6kfwTu_m9BO837g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-nakazawa-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1487,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7317465228689,
#     'longitude': -74.0045493828034},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '23 Commerce St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23 Commerce St', 'New York, NY 10014']},
#    'phone': '+12129242212',
#    'display_phone': '(212) 924-2212',
#    'distance': 3049.663639600052},
#   {'id': 'kIzVGUWS2b5H_b-G0Q0-0g',
#    'alias': 'katana-kitten-new-york-2',
#    'name': 'Katana Kitten',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T8_WgDni-INC7arpAEKI7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/katana-kitten-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73425, 'longitude': -74.00639},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '531 Hudson St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['531 Hudson St', 'New York, NY 10014']},
#    'phone': '+12122433007',
#    'display_phone': '(212) 243-3007',
#    'distance': 3363.180571362766},
#   {'id': '8fr5FYU1ip0phERt1mrekg',
#    'alias': 'bohemian-restaurant-new-york',
#    'name': 'Bohemian Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/17TfKWPEXcDbUvY8gCB-uQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bohemian-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 798,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72639, 'longitude': -73.99236},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '57 Great Jones St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['57 Great Jones St', 'New York, NY 10012']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2336.6703092553835},
#   {'id': 'mESab-FqL5QqSVsnX72asQ',
#    'alias': 'zen-ramen-and-sushi-new-york',
#    'name': 'Zen Ramen & Sushi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-W7fV5FcFuq-KGw_IT_fow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zen-ramen-and-sushi-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1967,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75177475474212,
#     'longitude': -73.98897630211589},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '150 W 36th street',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 W 36th street', 'New York, NY 10018']},
#    'phone': '+16468707509',
#    'display_phone': '(646) 870-7509',
#    'distance': 5171.088225928683},
#   {'id': 'r6r-XK_wL02FQdAgaauTxg',
#    'alias': 'kame-new-york-2',
#    'name': 'Kame',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QCLDn4f32FljiXS9EwxM3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kame-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 510,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7474881059799,
#     'longitude': -73.996648862958},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '330 8th Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['330 8th Ave', 'New York, NY 10001']},
#    'phone': '+19173918587',
#    'display_phone': '(917) 391-8587',
#    'distance': 4679.202389062086},
#   {'id': 'TaDgnJXD6m_7BM9kGFtkWw',
#    'alias': 'bbf-new-york-2',
#    'name': 'BBF',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PeJcHLrpK_mrwdf7ZXZo1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bbf-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72193, 'longitude': -73.98753},
#    'transactions': [],
#    'location': {'address1': '177 Ludlow St New York Ny',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['177 Ludlow St New York Ny', 'New York, NY 10002']},
#    'phone': '+16464765088',
#    'display_phone': '(646) 476-5088',
#    'distance': 1920.028474125032},
#   {'id': 'ur679FKjXosJ1VnddICDiw',
#    'alias': 'don-wagyu-new-york',
#    'name': 'Don Wagyu',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/k22cZkEtg-vVtmtm36HSQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/don-wagyu-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76234, 'longitude': -73.996759},
#    'transactions': ['delivery'],
#    'location': {'address1': '600 11th Ave',
#     'address2': '',
#     'address3': 'Gotham West Market',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['600 11th Ave',
#      'Gotham West Market',
#      'New York, NY 10036']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6329.853950308873},
#   {'id': 'D6ZEcG1FCZ18nekMWrhgMg',
#    'alias': 'wokuni-new-york',
#    'name': 'Wokuni',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kEPV6xdjymPjpHb2S4pwBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wokuni-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 278,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7492189, 'longitude': -73.9773529},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '327 Lexington Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['327 Lexington Ave', 'New York, NY 10016']},
#    'phone': '+12124471212',
#    'display_phone': '(212) 447-1212',
#    'distance': 5072.450857640573},
#   {'id': 'NGDLKVh3x5Hch24XWb6M9w',
#    'alias': 'sushi-nonaka-new-york',
#    'name': 'Sushi Nonaka',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lmQHuRgo2qvXgKjI3g8NrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-nonaka-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 108,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.783672, 'longitude': -73.978343},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '410 Amsterdam Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['410 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+16464540226',
#    'display_phone': '(646) 454-0226',
#    'distance': 8801.592809300435},
#   {'id': 'SxKvgnkMMZdhBJcxxKQnww',
#    'alias': 'nobu-fifty-seven-new-york-2',
#    'name': 'Nobu Fifty Seven',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/INqGC_ky4oZ_rPMcSjNlQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nobu-fifty-seven-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1279,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7636210840864,
#     'longitude': -73.9765048613641},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '40 W 57th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40 W 57th St', 'New York, NY 10019']},
#    'phone': '+12127573000',
#    'display_phone': '(212) 757-3000',
#    'distance': 6640.252584385714},
#   {'id': 'wpT1QU7PSQgQQ1DkzI00JA',
#    'alias': 'izakaya-toribar-new-york',
#    'name': 'Izakaya Toribar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lZig3aa5S2etRjst2WP4qw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-toribar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 87,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.759641, 'longitude': -73.9685558},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '164 E 56th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['164 E 56th St', 'New York, NY 10022']},
#    'phone': '+16467670029',
#    'display_phone': '(646) 767-0029',
#    'distance': 6404.650179251868},
#   {'id': 'LOFl1w5bXrAdDRAQ-vi3_A',
#    'alias': 'koyo-astoria-5',
#    'name': 'Koyo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dMWNDAyPk4PyoKNQihtgHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/koyo-astoria-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76164, 'longitude': -73.91838},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '3712 31st Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3712 31st Ave', 'Astoria, NY 11103']},
#    'phone': '+19293282890',
#    'display_phone': '(929) 328-2890',
#    'distance': 8942.145766307416},
#   {'id': 'Qli775QfVY4oFPNu7Cy5Tw',
#    'alias': 'yakitori-sun-chan-new-york',
#    'name': 'Yakitori Sun-Chan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RMtHY6jQg-_I69AnNBCP5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yakitori-sun-chan-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 225,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7995, 'longitude': -73.9686399},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2707 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2707 Broadway', 'New York, NY 10025']},
#    'phone': '+12127495008',
#    'display_phone': '(212) 749-5008',
#    'distance': 10678.447898210801},
#   {'id': 'lEH8EUPX3Zn_trHauIycYw',
#    'alias': 'aoi-kitchen-new-york',
#    'name': 'Aoi Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xxBXbfDGdGGhnzxAOgcMtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aoi-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 118,
#    'categories': [{'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'japacurry', 'title': 'Japanese Curry'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72683167, 'longitude': -73.98754333},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '320 E 6th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['320 E 6th St', 'New York, NY 10003']},
#    'phone': '+16464540084',
#    'display_phone': '(646) 454-0084',
#    'distance': 2442.622359813582},
#   {'id': 'raelHbSJ_gTo701c-KyXWg',
#    'alias': 'minca-new-york',
#    'name': 'Minca',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/568nXQT_kAatscSBaIcdBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/minca-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1679,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72412, 'longitude': -73.98288},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '536 E 5th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['536 E 5th St', 'New York, NY 10009']},
#    'phone': '+12125058001',
#    'display_phone': '(212) 505-8001',
#    'distance': 2273.800952319139},
#   {'id': 'QR1YIRzFjd2bi5iBzT9zXg',
#    'alias': 'blue-ribbon-sushi-new-york',
#    'name': 'Blue Ribbon Sushi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-qPhorWlki-abAmlr-8akQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-ribbon-sushi-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1125,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72612, 'longitude': -74.0025299},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '119 Sullivan St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['119 Sullivan St', 'New York, NY 10012']},
#    'phone': '+12123430404',
#    'display_phone': '(212) 343-0404',
#    'distance': 2399.5278900084168},
#   {'id': 'd8qCvlsG3jwxQPZc_OGogQ',
#    'alias': 'hibino-brooklyn',
#    'name': 'Hibino',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/P07pVNA8NFL2KT-myQyh0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hibino-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 405,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69017, 'longitude': -73.99637},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '333 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['333 Henry St', 'Brooklyn, NY 11201']},
#    'phone': '+17182608052',
#    'display_phone': '(718) 260-8052',
#    'distance': 1709.5238050413357},
#   {'id': 'Ms1p17KsYteDlkvHnllC2g',
#    'alias': 'soba-totto-new-york',
#    'name': 'Soba Totto',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/q_geDg94B0RPedwaEJIlpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soba-totto-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 900,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75122, 'longitude': -73.97317},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '211 E 43rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['211 E 43rd St', 'New York, NY 10017']},
#    'phone': '+12125578200',
#    'display_phone': '(212) 557-8200',
#    'distance': 5406.2297478569635},
#   {'id': 'GlPJPpKvPR4d8dmcSEYpdA',
#    'alias': 'takahachi-bakery-new-york',
#    'name': 'Takahachi Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oP2xYZjbAa8akp-9CLmiVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/takahachi-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 947,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71393, 'longitude': -74.00822},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '25 Murray St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 Murray St', 'New York, NY 10007']},
#    'phone': '+12127915550',
#    'display_phone': '(212) 791-5550',
#    'distance': 1511.7020935512141},
#   {'id': 'mm8gYHxaLLRyv3CslY40TA',
#    'alias': 'suzuki-shokudo-long-island-city',
#    'name': 'Suzuki Shokudo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OfPh3mF6kBoYsUjrHU-iQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/suzuki-shokudo-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 165,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75353, 'longitude': -73.93184},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '38-01 31st St',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38-01 31st St', 'Long Island City, NY 11101']},
#    'phone': '+17184723778',
#    'display_phone': '(718) 472-3778',
#    'distance': 7500.271425044698},
#   {'id': 'lY_gb_hNbit6GHBiOn3VeQ',
#    'alias': 'nami-nori-new-york',
#    'name': 'Nami Nori',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pSSz6RskJeMBhGErxORmLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nami-nori-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 353,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.730284, 'longitude': -74.003212},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '33 Carmine St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33 Carmine St', 'New York, NY 10014']},
#    'phone': '+16469984588',
#    'display_phone': '(646) 998-4588',
#    'distance': 2864.063123533261},
#   {'id': 'mdAt1D1XUG-HwTYmPSi9fA',
#    'alias': 'izakaya-mew-flushing-flushing',
#    'name': 'Izakaya Mew Flushing',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BUry_zLfojXgP4BCXA5lZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-mew-flushing-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 249,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76536, 'longitude': -73.82022},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '146-13 Northern Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['146-13 Northern Blvd', 'Flushing, NY 11354']},
#    'phone': '+13475060044',
#    'display_phone': '(347) 506-0044',
#    'distance': 16110.076034930906},
#   {'id': 'Pe4cQ65ZJ9qS8JQZVkJz4g',
#    'alias': 'shabushabu-mayumon-new-york',
#    'name': 'shabushabu Mayumon',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OyFOxUCiy2cAM5D4wz16jw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shabushabu-mayumon-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71434, 'longitude': -73.99205},
#    'transactions': ['restaurant_reservation'],
#    'location': {'address1': '115 Division St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['115 Division St', 'New York, NY 10002']},
#    'phone': '+16464767717',
#    'display_phone': '(646) 476-7717',
#    'distance': 995.7191551606902},
#   {'id': '8Oo2AtQEPDfxIOnA8wfXoQ',
#    'alias': '886-new-york',
#    'name': '886',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/N-V-Dl4nrmMhN1TcVt6a8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/886-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 456,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72877, 'longitude': -73.98873},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '26 Saint Marks Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 Saint Marks Pl', 'New York, NY 10003']},
#    'phone': '+16468820231',
#    'display_phone': '(646) 882-0231',
#    'distance': 2638.0802791580863},
#   {'id': '1yqrirjDVm40roP-NcU-Ig',
#    'alias': 'komorebi-full-house-brooklyn',
#    'name': 'Komorebi Full House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gow9AoBwtJllLgYfAM8VjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/komorebi-full-house-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.630169, 'longitude': -74.004041},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '6201 11th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11219',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6201 11th Ave', 'Brooklyn, NY 11219']},
#    'phone': '+17188772828',
#    'display_phone': '(718) 877-2828',
#    'distance': 8410.563952753604},
#   {'id': 'HZWHBfeuP4Fb6y8b8uqnbA',
#    'alias': 'sushi-yasaka-new-york',
#    'name': 'Sushi Yasaka',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kBzfFxtiN2eLH_XOPXIdsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-yasaka-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1830,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.779583, 'longitude': -73.983482},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '251 W 72nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['251 W 72nd St', 'New York, NY 10023']},
#    'phone': '+12124968460',
#    'display_phone': '(212) 496-8460',
#    'distance': 8293.93796491287},
#   {'id': 'ynR4-QgEOsE7VhNfIWo73w',
#    'alias': 'secchu-yokota-new-york',
#    'name': 'Secchu Yokota',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/04gFGWjmYlXY6RgDOAQ6wg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/secchu-yokota-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 121,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.722841651410874, 'longitude': -73.9831015},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '199 E 3rd St',
#     'address2': 'Fl 1',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['199 E 3rd St', 'Fl 1', 'New York, NY 10009']},
#    'phone': '+12127771124',
#    'display_phone': '(212) 777-1124',
#    'distance': 2152.15760594798},
#   {'id': 'xYDays-olVw50rdusxW5Rw',
#    'alias': 'wanpaku-brooklyn',
#    'name': 'Wanpaku',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fKWkpsQn7txEg_220UUZ3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wanpaku-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 103,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'japacurry', 'title': 'Japanese Curry'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72355, 'longitude': -73.95092},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '621 Manhattan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['621 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183833139',
#    'display_phone': '(718) 383-3139',
#    'distance': 4173.285722388106},
#   {'id': 'Nnc2RVv5TPNAy70gOJrc-Q',
#    'alias': 'moonrise-izakaya-new-york',
#    'name': 'Moonrise Izakaya',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/toD_Mwb4skZ9QtHzAyWP6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moonrise-izakaya-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 126,
#    'categories': [{'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.795399, 'longitude': -73.969762},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '774 Amsterdam Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['774 Amsterdam Ave', 'New York, NY 10025']},
#    'phone': '+16465412506',
#    'display_phone': '(646) 541-2506',
#    'distance': 10211.406967168303},
#   {'id': 'dOxHYQmBR14Fa2C1X8oMMQ',
#    'alias': 'sushi-lab-new-york-5',
#    'name': 'Sushi Lab',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Fu8bDLVzqQ3ckzjvmiSGxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-lab-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 361,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.758417, 'longitude': -73.983301},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '132 W 47th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['132 W 47th St', 'New York, NY 10036']},
#    'phone': '+12124320000',
#    'display_phone': '(212) 432-0000',
#    'distance': 5961.292620383107},
#   {'id': '-pab00ajP_NS1KGfILveYA',
#    'alias': 'marumi-new-york',
#    'name': 'Marumi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8ZjEJx0E43hzI0r3XpDgBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marumi-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 429,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7289699, 'longitude': -73.99837},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '546 Laguardia Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['546 Laguardia Pl', 'New York, NY 10012']},
#    'phone': '+12129797055',
#    'display_phone': '(212) 979-7055',
#    'distance': 2642.735845018405},
#   {'id': '9xRIcn0jTyvWNH9aBO3oAA',
#    'alias': 'kenka-new-york',
#    'name': 'Kenka',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sl7IDIHrcRhGcVjtVRl2OA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kenka-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1563,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72913, 'longitude': -73.988465},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '25 St Marks Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 St Marks Pl', 'New York, NY 10003']},
#    'phone': '+12122546363',
#    'display_phone': '(212) 254-6363',
#    'distance': 2679.077796839849},
#   {'id': 'xFp3xSQ43J-i7nmJfNBsZA',
#    'alias': 'norikoh-new-york-8',
#    'name': 'Norikoh',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2hbqIpmNbq36S5YscP06aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/norikoh-new-york-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 569,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7433, 'longitude': -73.99137},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '43 W 24th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43 W 24th St', 'New York, NY 10010']},
#    'phone': '+16462308191',
#    'display_phone': '(646) 230-8191',
#    'distance': 4222.427147776418},
#   {'id': '_FAh31lob7Dnn4iGiLIwng',
#    'alias': 'mui-new-york',
#    'name': 'MUI',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5HG0MHhXmZMOsynCEmgpsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mui-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 281,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74732, 'longitude': -73.98646},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '10 W 32nd St',
#     'address2': 'Fl 5',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10 W 32nd St', 'Fl 5', 'New York, NY 10001']},
#    'phone': '+12122441900',
#    'display_phone': '(212) 244-1900',
#    'distance': 4701.718021195483},
#   {'id': 'pil3w2-2REoXBwEToYZ_tQ',
#    'alias': 'bar-moga-new-york-2',
#    'name': 'Bar Moga',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OJKHiJyjvqo6Z-vk2kWwUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-moga-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 210,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72787, 'longitude': -74.00107},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '128 W Houston St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['128 W Houston St', 'New York, NY 10012']},
#    'phone': '+19293995853',
#    'display_phone': '(929) 399-5853',
#    'distance': 2558.132132254008},
#   {'id': '4Jp0wdJXLpmgCwWv6o6YEQ',
#    'alias': 'torishin-new-york-3',
#    'name': 'Torishin',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WJj52YFgXK_3Mmf0jmmGiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/torishin-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 314,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76496, 'longitude': -73.98721},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '362 W 53rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['362 W 53rd St', 'New York, NY 10019']},
#    'phone': '+12127570108',
#    'display_phone': '(212) 757-0108',
#    'distance': 6648.041071854937},
#   {'id': 'HWPh33x1lrHvBu-DstSPLA',
#    'alias': 'daigo-sushi-roll-bar-brooklyn',
#    'name': 'Daigo Sushi Roll Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UMqwQjseg80uU-WbOVviVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daigo-sushi-roll-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.676541, 'longitude': -73.98445},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '527 Carroll St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['527 Carroll St', 'Brooklyn, NY 11215']},
#    'phone': '+19179091504',
#    'display_phone': '(917) 909-1504',
#    'distance': 3319.378151378764},
#   {'id': 'wQU3LMmOPNzxL-ptOi_F5w',
#    'alias': 'kobeyaki-new-york-2',
#    'name': 'Kobeyaki',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TPhos7dF8UEafEAUWLy4hQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kobeyaki-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 555,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7462138, 'longitude': -73.99388},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '293 7th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['293 7th Ave', 'New York, NY 10001']},
#    'phone': '+12122425500',
#    'display_phone': '(212) 242-5500',
#    'distance': 4537.743181126505},
#   {'id': 'qVlDLz8Ri-ThAFJgYHuQ9A',
#    'alias': 'omusubi-gonbei-new-york-3',
#    'name': 'Omusubi Gonbei',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2MxgyQGfhCqM2vGhyz7Rrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/omusubi-gonbei-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 62,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7507224, 'longitude': -73.9768828},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '370 Lexington Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['370 Lexington Ave', 'New York, NY 10017']},
#    'phone': '+19174727168',
#    'display_phone': '(917) 472-7168',
#    'distance': 5244.026712567999},
#   {'id': 'FXimZKjpMjbDR20M2ruhvg',
#    'alias': 'sapps-long-island-city',
#    'name': 'Sapps',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QTSq-a0y0FYbFELwsp_dsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sapps-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 221,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74762, 'longitude': -73.94008},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '27-26 Jackson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27-26 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+17187845555',
#    'display_phone': '(718) 784-5555',
#    'distance': 6547.2197589056095},
#   {'id': '7qvsMuRypQYg1Ux8kghybg',
#    'alias': 'kissaki-new-york-5',
#    'name': 'Kissaki',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qgNnlHJl9VTShrohO-g5TA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kissaki-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 154,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72535, 'longitude': -73.99193},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '319 Bowery',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['319 Bowery', 'New York, NY 10003']},
#    'phone': '+12125771150',
#    'display_phone': '(212) 577-1150',
#    'distance': 2221.0806344750044},
#   {'id': 'ieXKc6S3WlEiVkyxgaF9Ig',
#    'alias': 'tempura-matsui-new-york',
#    'name': 'Tempura Matsui',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Hcb9QIJMZKds9183FKLA-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tempura-matsui-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 152,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74819, 'longitude': -73.97467},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '222 E 39th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['222 E 39th St', 'New York, NY 10016']},
#    'phone': '+12129868885',
#    'display_phone': '(212) 986-8885',
#    'distance': 5018.736312293281},
#   {'id': 'NCnOkzbyfzDltnBnJySfzw',
#    'alias': 'amami-bar-and-restaurant-brooklyn',
#    'name': 'Amami Bar and Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MzSSNiTIcoEWoRm3fQphtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amami-bar-and-restaurant-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 185,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.723548, 'longitude': -73.952194},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '57 Nassau Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['57 Nassau Ave', 'Brooklyn, NY 11222']},
#    'phone': '+19179091568',
#    'display_phone': '(917) 909-1568',
#    'distance': 4077.199270781559},
#   {'id': 'MTtqSunPEZwdCJFMHsiHzg',
#    'alias': 'ai-ki-ya-new-york-3',
#    'name': 'Ai Ki Ya',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aTAJp9AEYJ3B-MGFDsHrQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ai-ki-ya-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74873, 'longitude': -73.98705},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '41 W 33rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41 W 33rd St', 'New York, NY 10001']},
#    'phone': '+12125486188',
#    'display_phone': '(212) 548-6188',
#    'distance': 4860.7090979919885},
#   {'id': '7EaiwMVaNdQibSs0yYkE5Q',
#    'alias': 'sushi-yasuda-new-york',
#    'name': 'Sushi Yasuda',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/z6GvhobHxGaKtpfXBFd5Lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-yasuda-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2154,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75113, 'longitude': -73.97347},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '204 E 43rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['204 E 43rd St', 'New York, NY 10017']},
#    'phone': '+12129721001',
#    'display_phone': '(212) 972-1001',
#    'distance': 5372.33616036102},
#   {'id': '5QgBCrAbXbM1ORiqZDrBPQ',
#    'alias': 'cha-an-new-york',
#    'name': 'Cha-An',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/geK7mCEMe-dQAIiQYKcn8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cha-an-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1799,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72947, 'longitude': -73.98813},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '230 E 9th St',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['230 E 9th St', 'Fl 2', 'New York, NY 10003']},
#    'phone': '+12122288030',
#    'display_phone': '(212) 228-8030',
#    'distance': 2714.053979232952},
#   {'id': 'IPhWpqIuAiEerKlLS82RpQ',
#    'alias': 'noda-new-york',
#    'name': 'noda',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/p0Hm1ZV6925Ynj5DqMrpLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noda-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74478, 'longitude': -73.9881},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '6 West 28th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6 West 28th St', 'New York, NY 10001']},
#    'phone': '+12124812432',
#    'display_phone': '(212) 481-2432',
#    'distance': 4403.122082300617},
#   {'id': 'nEkVibaTuIFEcTNtltFgJg',
#    'alias': 'kura-new-york',
#    'name': 'Kura',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/X62zaKQxDii-NuggImIT2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kura-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 495,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.726709, 'longitude': -73.9835794},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '130 St Marks Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['130 St Marks Pl', 'New York, NY 10009']},
#    'phone': '+12122281010',
#    'display_phone': '(212) 228-1010',
#    'distance': 2531.01153602343}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                  Restaurant           Type Price Rating            Address  \
# 0  Shabu-Tatsu East Village       Japanese    $$      4      216 E 10th St
# 1          Dashi - Brooklyn       Japanese    $$    4.5    119 Ingraham St
# 2            Sushi Nakazawa       Japanese  $$$$    4.5     23 Commerce St
# 3             Katana Kitten  Cocktail Bars    $$      4      531 Hudson St
# 4       Bohemian Restaurant       Japanese   $$$    4.5  57 Great Jones St
#
#          Lat        Lng                                                url  \
# 0  40.729147 -73.985906  https://www.yelp.com/biz/shabu-tatsu-east-vill...
# 1  40.707885 -73.929212  https://www.yelp.com/biz/dashi-brooklyn-brookl...
# 2  40.731747 -74.004549  https://www.yelp.com/biz/sushi-nakazawa-new-yo...
# 3  40.734250 -74.006390  https://www.yelp.com/biz/katana-kitten-new-yor...
# 4  40.726390 -73.992360  https://www.yelp.com/biz/bohemian-restaurant-n...
#
#                        ID
# 0  y_ylOQzCP-9D_4DcUIJ3jA
# 1  X73hpslpgeJNhVohYIUzfQ
# 2  zGAQqDu0Ak2khVYs9WdQxw
# 3  kIzVGUWS2b5H_b-G0Q0-0g
# 4  8fr5FYU1ip0phERt1mrekg

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"japanese","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [{'id': 'eS9mTLlWwu_Ap2ROMQWPxg',
#    'alias': 'chuko-brooklyn-2',
#    'name': 'Chuko',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MD7Q6u1eUGzEDBtr6Qyimw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chuko-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1076,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.680784, 'longitude': -73.967455},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '565 Vanderbilt Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['565 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#    'phone': '+13474259570',
#    'display_phone': '(347) 425-9570',
#    'distance': 3555.179777356736},
#   {'id': 'SoBdWOxymmY5yKANn63UWw',
#    'alias': 'ozu-brooklyn',
#    'name': 'Ozu',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/T1SdmmthTZtiIae1y5QnNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ozu-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 266,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6974732130766,
#     'longitude': -73.9932652562857},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '78 Clark St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['78 Clark St', 'Brooklyn, NY 11201']},
#    'phone': '+17187973288',
#    'display_phone': '(718) 797-3288',
#    'distance': 896.1026683646718},
#   {'id': 'XOUhjDQ4nRn8-u-79MHFww',
#    'alias': 'kohoku-ku-ramen-new-york-2',
#    'name': 'Kohoku-Ku Ramen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VAG81N2jwPGj36akIb8jeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kohoku-ku-ramen-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.76265, 'longitude': -73.9899},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '709 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['709 9th Ave', 'New York, NY 10019']},
#    'phone': '+16464787886',
#    'display_phone': '(646) 478-7886',
#    'distance': 6376.941769165579},
#   {'id': 'bu7k1pBrfbhGzYao3YoHsg',
#    'alias': 'nara-sushi-new-york',
#    'name': 'Nara Sushi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GB2wrQG3ToSqwbe6a-GqUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nara-sushi-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70377, 'longitude': -74.01041},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '76 Pearl St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['76 Pearl St', 'New York, NY 10004']},
#    'phone': '+16467200202',
#    'display_phone': '(646) 720-0202',
#    'distance': 1369.8053604263123},
#   {'id': '3n6i8TwGEIL9KnCCHUyiqA',
#    'alias': 'sai-rego-park',
#    'name': 'Sai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mF2-_AY6UAX9N1-Gmhc2Tw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sai-rego-park?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 243,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73012, 'longitude': -73.8636},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '95-34 Queens Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['95-34 Queens Blvd', 'Rego Park, NY 11374']},
#    'phone': '+17188970429',
#    'display_phone': '(718) 897-0429',
#    'distance': 11356.078993771007},
#   {'id': 'CicbZtEYbmJCGEpo8Y7Iwg',
#    'alias': 'boxed-to-go-new-york',
#    'name': 'Boxed To-Go',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ut0gyaJiy0xMlU48vWUmOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boxed-to-go-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72926317673329,
#     'longitude': -73.98888386785984},
#    'transactions': [],
#    'location': {'address1': '15 St Marks Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 St Marks Pl', 'New York, NY 10003']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2687.423401379356},
#   {'id': 'O1XrvIq-6IlLunLYEjOiFQ',
#    'alias': 'kushi-kushi-yaki-new-york',
#    'name': 'Kushi Kushi Yaki',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kRpgDisV4cZbA0-fEqthSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kushi-kushi-yaki-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.747266, 'longitude': -73.9861784},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2 W 32nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2 W 32nd St', 'New York, NY 10001']},
#    'phone': '+12122793075',
#    'display_phone': '(212) 279-3075',
#    'distance': 4700.300458259518},
#   {'id': '42j0S2yFg4B6jO95I4Lfog',
#    'alias': 'bentos-new-york',
#    'name': 'Bentos',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OTBkyAr3qQ9EE8GtPgYtYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bentos-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.746897, 'longitude': -73.985172},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '315 Fifth Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['315 Fifth Ave', 'New York, NY 10016']},
#    'phone': '+16466844006',
#    'display_phone': '(646) 684-4006',
#    'distance': 4669.505145373706},
#   {'id': 'WLl0nKeWBksVM5SkKKuLpg',
#    'alias': 'tabetomo-new-york',
#    'name': 'TabeTomo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KuqXkkx0w4J9PX-j0iFmrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tabetomo-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 417,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72688, 'longitude': -73.98311},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '131 Avenue A',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['131 Avenue A', 'New York, NY 10009']},
#    'phone': '+16468506414',
#    'display_phone': '(646) 850-6414',
#    'distance': 2569.588273134286},
#   {'id': 'EXsorzjQ3y3Oh5-m82lgtg',
#    'alias': 'bushniwa-brooklyn',
#    'name': 'Bushniwa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WIXs0Q1WubEJY9uL2rY3gA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bushniwa-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 211,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70397, 'longitude': -73.93344},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'location': {'address1': '250 Varet St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['250 Varet St', 'Brooklyn, NY 11206']},
#    'phone': '+17183868886',
#    'display_phone': '(718) 386-8886',
#    'distance': 5132.889414467697},
#   {'id': 'yj4culC4vfNKWXdj5ZxJ4Q',
#    'alias': 'kosaka-new-york-2',
#    'name': 'Kosaka',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xsrQwOsrcCwMtXk88xSi0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kosaka-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 167,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7381972955808,
#     'longitude': -74.0014449879527},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '220 W 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['220 W 13th St', 'New York, NY 10011']},
#    'phone': '+12127271709',
#    'display_phone': '(212) 727-1709',
#    'distance': 3691.434075196936},
#   {'id': 'FU3_u6uZ5d5Zli_XffQnlg',
#    'alias': 'dr-clark-new-york',
#    'name': 'Dr. Clark',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1hmv8tehzG8-Mx8ODdbcJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dr-clark-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 95,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.71618, 'longitude': -73.99981},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '104 Bayard St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['104 Bayard St', 'New York, NY 10013']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1281.8771562896181},
#   {'id': 'LjAt-SP7BwIpp56TZHVsWA',
#    'alias': 'uotora-brooklyn',
#    'name': 'Uotora',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8smZeo-lKGo0JqBGhBG0Tw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uotora-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 106,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.676369, 'longitude': -73.950486},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '1075 Bergen St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1075 Bergen St', 'Brooklyn, NY 11216']},
#    'phone': '+17185130724',
#    'display_phone': '(718) 513-0724',
#    'distance': 4909.823079918401},
#   {'id': 'AFt1Qcec4_JNr6PWpkRYyw',
#    'alias': 'sushi-lin-brooklyn-2',
#    'name': 'Sushi Lin',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2zPxmKj8fumQqJ1S94UcEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-lin-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 286,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.677786, 'longitude': -73.972591},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '335 Flatbush Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['335 Flatbush Ave', 'Brooklyn, NY 11217']},
#    'phone': '+13476276027',
#    'display_phone': '(347) 627-6027',
#    'distance': 3577.679843014624},
#   {'id': 'PjjpgjY_sdawJU1JHbyNTQ',
#    'alias': 'temakase-new-york',
#    'name': 'Temakase',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jyJJer_Ds4M0trt9IwYB3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/temakase-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 120,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729711, 'longitude': -73.987127},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '157 Second Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['157 Second Ave', 'New York, NY 10003']},
#    'phone': '+12123811456',
#    'display_phone': '(212) 381-1456',
#    'distance': 2766.79175516524},
#   {'id': 'ONQRhDuWv0e9R5xOiI7YAA',
#    'alias': 'gyu-kaku-japanese-bbq-new-york-3',
#    'name': 'Gyu-Kaku Japanese BBQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ONxhOlpk4f0ZuWxCyDtCuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gyu-kaku-japanese-bbq-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1262,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75908, 'longitude': -73.98989},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '321 W 44th St',
#     'address2': 'Unit 103',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['321 W 44th St', 'Unit 103', 'New York, NY 10036']},
#    'phone': '+16466929115',
#    'display_phone': '(646) 692-9115',
#    'distance': 5987.473305453897},
#   {'id': '56PeolgNURAG4x6q7nanmw',
#    'alias': 'odo-new-york',
#    'name': 'Odo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9--uXKY9O55jXmEVApwFtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/odo-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74032, 'longitude': -73.99223},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '17 W 20th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 W 20th St', 'New York, NY 10011']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3890.775166416719},
#   {'id': 'pTMnHb_W3sKqS8oCzjHdVA',
#    'alias': 'senya-new-york',
#    'name': 'SenYa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XBOLS0Kl5d9AU0Bq1Y56Ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/senya-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 283,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7269015463545,
#     'longitude': -73.986101118587},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '109 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['109 1st Ave', 'New York, NY 10003']},
#    'phone': '+12129955278',
#    'display_phone': '(212) 995-5278',
#    'distance': 2483.7627774992},
#   {'id': 'CqQ2Og9kf-LhlUWtODalCQ',
#    'alias': 'blue-ribbon-sushi-bar-and-grill-new-york-new-york',
#    'name': 'Blue Ribbon Sushi Bar & Grill - New York',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eWPICkTWKj_vPF9CU1HfJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-ribbon-sushi-bar-and-grill-new-york-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 770,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7674948014194,
#     'longitude': -73.9831978922043},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '308 W 58th St',
#     'address2': '6 Columbus Hotel',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['308 W 58th St',
#      '6 Columbus Hotel',
#      'New York, NY 10019']},
#    'phone': '+12123970404',
#    'display_phone': '(212) 397-0404',
#    'distance': 6962.67249012649},
#   {'id': 'VVlHJ6_sJbRAodV5lCzBnA',
#    'alias': 'kanoyama-new-york',
#    'name': 'Kanoyama',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/huH4eiAzFa8N-4nUt8e44Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kanoyama-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 676,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.730545186039, 'longitude': -73.986544028849},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '175 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['175 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12127775266',
#    'display_phone': '(212) 777-5266',
#    'distance': 2866.4161405823147},
#   {'id': 'uCXsqMEfD12Rlmp1H09_Nw',
#    'alias': 'omakase-sushi-dairo-new-york',
#    'name': 'Omakase Sushi Dairo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qrK8k3iPNsvFzkmTzbRbng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/omakase-sushi-dairo-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.73601, 'longitude': -73.98542},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'location': {'address1': '208 3rd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['208 3rd Ave', 'New York, NY 10003']},
#    'phone': '+12125294193',
#    'display_phone': '(212) 529-4193',
#    'distance': 3481.3648542296855},
#   {'id': 'ptWTdgSzSpH-0LD24QIH-w',
#    'alias': 'wild-ink-new-york',
#    'name': 'Wild Ink',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tZEeTncctkFhV8pDrERORA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wild-ink-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 173,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.753754, 'longitude': -74.001388},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '500 W 33rd St',
#     'address2': 'Fl 5',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['500 W 33rd St', 'Fl 5', 'New York, NY 10001']},
#    'phone': '+16469747305',
#    'display_phone': '(646) 974-7305',
#    'distance': 5404.889175576828},
#   {'id': 'vec8jeVbbSGzVlStl0Xp_Q',
#    'alias': 'chikarashi-new-york',
#    'name': 'Chikarashi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dXGsF2g2RWKL1cObKBv4pw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chikarashi-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 500,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'hawaiian', 'title': 'Hawaiian'},
#     {'alias': 'poke', 'title': 'Poke'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71792477072888,
#     'longitude': -73.99945752883555},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '227 Canal St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['227 Canal St', 'New York, NY 10013']},
#    'phone': '+16466495965',
#    'display_phone': '(646) 649-5965',
#    'distance': 1454.3660861474511},
#   {'id': 'j-a8HUcsBJXHV2IfF786jw',
#    'alias': 'kogane-ramen-brooklyn-heights-brooklyn',
#    'name': 'Kogane Ramen-Brooklyn Heights',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/74ZZvdyaMobPUx45KcZ7_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kogane-ramen-brooklyn-heights-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 378,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69859, 'longitude': -73.99263},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '76 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['76 Henry St', 'Brooklyn, NY 11201']},
#    'phone': '+17188752828',
#    'display_phone': '(718) 875-2828',
#    'distance': 775.0129178074509},
#   {'id': 'Uoic12Je-GLfRp3D3Klp5g',
#    'alias': 'umi-no-ie-new-york-2',
#    'name': 'Umi No Ie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LZdAkdEz-67ACbROnqq-bA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/umi-no-ie-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 156,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.724637, 'longitude': -73.988227},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '86 E 3rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['86 E 3rd St', 'New York, NY 10003']},
#    'phone': '+16466541122',
#    'display_phone': '(646) 654-1122',
#    'distance': 2194.4551640026725},
#   {'id': 'wcnfhQ7Q_us38Q1uEARagw',
#    'alias': 'sushi-jin-new-york',
#    'name': 'Sushi Jin',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/02Wrectj3WQP-LGrcNAfrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-jin-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.776032, 'longitude': -73.951988},
#    'transactions': ['delivery'],
#    'location': {'address1': '316 E 84th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['316 E 84th St', 'New York, NY 10028']},
#    'phone': '+16466096770',
#    'display_phone': '(646) 609-6770',
#    'distance': 8623.814631349434},
#   {'id': 'ZfuZ2byArGq-5j8zX8Afeg',
#    'alias': 'zest-sushi-new-york-3',
#    'name': 'Zest Sushi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W0-g2DqPNGEih80-h92b8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zest-sushi-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 867,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7178344726563,
#     'longitude': -73.9899597167969},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '249 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['249 Broome St', 'New York, NY 10002']},
#    'phone': '+12126773158',
#    'display_phone': '(212) 677-3158',
#    'distance': 1425.2566698018184},
#   {'id': 'fVbUVAiLiGgLA_nxBFxyww',
#    'alias': 'thursday-kitchen-new-york',
#    'name': 'Thursday Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nXO8M-d-XTamNmc0BpXWtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thursday-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1451,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7275, 'longitude': -73.9838},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '424 E 9th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['424 E 9th St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2613.42601480514},
#   {'id': 'FsuJ7VC5vxX3wcLhFrb97Q',
#    'alias': 'oiji-new-york',
#    'name': 'Oiji',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/O-qvq-slwy8jyt-g-5Nfyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oiji-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 560,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72727, 'longitude': -73.98585},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '119 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['119 1st Ave', 'New York, NY 10003']},
#    'phone': '+16467679050',
#    'display_phone': '(646) 767-9050',
#    'distance': 2528.519369329009},
#   {'id': 'OjL4yNu-EpUOeUMC64DWJw',
#    'alias': 'izakaya-nyc-on-east-4th-new-york',
#    'name': 'IZAKAYA NYC on East 4th',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/y8XpzDJpcTkn1iP_DvMlwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-nyc-on-east-4th-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.723881, 'longitude': -73.983428},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '215 East 4th St',
#     'address2': 'Ground floor',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['215 East 4th St',
#      'Ground floor',
#      'New York, NY 10009']},
#    'phone': '+16465245251',
#    'display_phone': '(646) 524-5251',
#    'distance': 2252.606940866488},
#   {'id': 'QmelPAXgkVLZfUb27diAEw',
#    'alias': 'shigure-new-york',
#    'name': 'Shigure',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x-S2Mzh9WuW1zXk0eMKAOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shigure-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 133,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71853, 'longitude': -74.00477},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '277 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['277 Church St', 'New York, NY 10013']},
#    'phone': '+12129650200',
#    'display_phone': '(212) 965-0200',
#    'distance': 1705.3825679970175},
#   {'id': 'skL_mmJRGkLTrdYhy3rnlg',
#    'alias': 'sushi-hatsune-new-york-3',
#    'name': 'Sushi Hatsune',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1CfLrgIJL2PNJHlOpcvCpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-hatsune-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.715995320569505,
#     'longitude': -73.9927898728603},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '50 Eldridge St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['50 Eldridge St', 'New York, NY 10002']},
#    'phone': '+12123010723',
#    'display_phone': '(212) 301-0723',
#    'distance': 1179.9791092469895},
#   {'id': 'Pr-q47vsmM4aoc2t_Sfk8w',
#    'alias': 'momofuku-noodle-bar-uptown-new-york',
#    'name': 'Momofuku Noodle Bar - Uptown',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/h08ukV9YwJXhQBT2kvCCIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/momofuku-noodle-bar-uptown-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 351,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76847, 'longitude': -73.983092},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10 Columbus Cir',
#     'address2': 'Third Floor',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10 Columbus Cir',
#      'Third Floor',
#      'New York, NY 10019']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 7079.371546056122},
#   {'id': '2txI-FAVf7q0SHNPcnjm7Q',
#    'alias': 'longevousjoy-brooklyn',
#    'name': 'Longevousjoy',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/I6cRKmP1i1Wu7LFKarNs5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/longevousjoy-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 320,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.61312, 'longitude': -73.98246},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '6610 Bay Pkwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11204',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6610 Bay Pkwy', 'Brooklyn, NY 11204']},
#    'phone': '+13473742645',
#    'display_phone': '(347) 374-2645',
#    'distance': 10313.750465669133},
#   {'id': 'V58g7E1AHkuTchTVyLQuYQ',
#    'alias': 'saigon-grill-and-bar-brooklyn-3',
#    'name': 'Saigon Grill & Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/n0P0wybogAiDPrhsXoF0Fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saigon-grill-and-bar-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 248,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.61883, 'longitude': -73.93099},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '4521 Ave N',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11234',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4521 Ave N', 'Brooklyn, NY 11234']},
#    'phone': '+17183388886',
#    'display_phone': '(718) 338-8886',
#    'distance': 11007.438427911506},
#   {'id': 'm6sYBuozGY1JhnHlBf1Bzg',
#    'alias': 'bondst-new-york-2',
#    'name': 'BondST',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GDuifrd0gzrorxRPg08zTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bondst-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1009,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.726934, 'longitude': -73.994404},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '6 Bond St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6 Bond St', 'New York, NY 10012']},
#    'phone': '+12127772500',
#    'display_phone': '(212) 777-2500',
#    'distance': 2389.49844427343},
#   {'id': 'YoR6ouUwehLFnBQ7RAjPlw',
#    'alias': 'zawa-japanese-new-york',
#    'name': 'Zawa Japanese',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ASEBSqGh2YUFI4eF3zoaDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zawa-japanese-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 118,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76397, 'longitude': -73.9592},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '354 E 66th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['354 E 66th St', 'New York, NY 10065']},
#    'phone': '+16466827999',
#    'display_phone': '(646) 682-7999',
#    'distance': 7155.647046787966},
#   {'id': 'oMDKIzPJWkh99UuUP_4ikg',
#    'alias': 'mi-ne-deli-new-york',
#    'name': 'MI-NE Deli',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-6KaJLtCTK6T3BUsTApIaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mi-ne-deli-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73623, 'longitude': -73.99723},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '496 6th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['496 6th Ave', 'New York, NY 10011']},
#    'phone': '+19176756942',
#    'display_phone': '(917) 675-6942',
#    'distance': 3437.026494424644},
#   {'id': 'RYoc4EBUNOtgbg7c32OG9A',
#    'alias': 'atoboy-new-york',
#    'name': 'Atoboy',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/c6SEZBVmzZeqKsyH3TtmEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/atoboy-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 431,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74364, 'longitude': -73.98456},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '43 E 28th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43 E 28th St', 'New York, NY 10016']},
#    'phone': '+16464767217',
#    'display_phone': '(646) 476-7217',
#    'distance': 4328.417879979509},
#   {'id': 'IVDk7BYFWwFsYPRbHLd49w',
#    'alias': 'takeda-new-york',
#    'name': 'Takeda',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vDHGLsj4EIRoVX4DgL63cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/takeda-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.788749, 'longitude': -73.974599},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '566 Amsterdam Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['566 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+16463706965',
#    'display_phone': '(646) 370-6965',
#    'distance': 9411.937172965341},
#   {'id': '1TEsPWu212B918MtgiSu3g',
#    'alias': 'jintan-new-york',
#    'name': 'Jintan',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NyLZ5PjVSRD8MXfx-QGWow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jintan-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7288289984002,
#     'longitude': -73.9841578558473},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10th St & 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10th St & 1st Ave', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2736.9073638618825},
#   {'id': 'M9ocxj9j91I1Av32UKSeYA',
#    'alias': 'yakiniku-tohbay-new-york',
#    'name': 'Yakiniku Tohbay',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wN8f4WwjTQC8kBAuugg8OA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yakiniku-tohbay-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.765354, 'longitude': -73.983214},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '253 West 55th St',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253 West 55th St', 'Fl 2', 'New York, NY 10019']},
#    'phone': '+19172612165',
#    'display_phone': '(917) 261-2165',
#    'distance': 6724.521667610174},
#   {'id': '7Q68kpPS6okcC8Kkw7g42A',
#    'alias': 'sushi-lab-rooftop-nyc-new-york-2',
#    'name': 'Sushi Lab Rooftop NYC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EZdrheKY7NxhnnZltFD4hQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-lab-rooftop-nyc-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 244,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.758417, 'longitude': -73.983301},
#    'transactions': [],
#    'location': {'address1': '132 West 47th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['132 West 47th St', 'New York, NY 10036']},
#    'phone': '+12124320000',
#    'display_phone': '(212) 432-0000',
#    'distance': 5961.292620383107},
#   {'id': 'EXEDl7BOLZksz3Uy_RVFhw',
#    'alias': 'yamato-restaurant-brooklyn',
#    'name': 'Yamato Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EQyy136EEI7FpLnHvcAz5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yamato-restaurant-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 274,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67192, 'longitude': -73.97758},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '168 7th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['168 7th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17188400099',
#    'display_phone': '(718) 840-0099',
#    'distance': 3978.8858940259456},
#   {'id': '4TQMO6AaKSXHMbKvGAf-gg',
#    'alias': 'llama-san-new-york-4',
#    'name': 'Llama San',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MF2IOO0B_o9pzEbes0O0Zw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/llama-san-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 176,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73225, 'longitude': -74.00078},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '359 6th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['359 6th Ave', 'New York, NY 10014']},
#    'phone': '+16464904422',
#    'display_phone': '(646) 490-4422',
#    'distance': 3033.7111008352945},
#   {'id': 'ipAsHykRvgJzpx5hD8vTJw',
#    'alias': 'tokuyama-salon-café-new-york',
#    'name': 'Tokuyama Salon Café',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1wtAhlzaf5Mltj2Elz2YIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tokuyama-salon-caf%C3%A9-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72399, 'longitude': -73.9802},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '627 E 6th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['627 E 6th St', 'New York, NY 10009']},
#    'phone': '+12123881276',
#    'display_phone': '(212) 388-1276',
#    'distance': 2383.746233733969},
#   {'id': '3eBV6HwWcdHzJW3sUH-2hw',
#    'alias': 'ichiran-times-square-new-york-4',
#    'name': 'ICHIRAN - Times Square',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yAxyPzJbSlp6kj6bgv2Efw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ichiran-times-square-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 449,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76004, 'longitude': -73.9833},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '152 W 49th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['152 W 49th St', 'New York, NY 10019']},
#    'phone': '+16469644294',
#    'display_phone': '(646) 964-4294',
#    'distance': 6151.332705321428},
#   {'id': 'X83qWL5WPR-QWGXGQ8WP-Q',
#    'alias': 'nr-new-york-4',
#    'name': 'NR',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4PYM3jLMvsok4ZUzuMM2rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nr-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 154,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.770153, 'longitude': -73.954956},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '339 E 75th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['339 E 75th St', 'New York, NY 10021']},
#    'phone': '+16462264874',
#    'display_phone': '(646) 226-4874',
#    'distance': 7917.800794183593},
#   {'id': '0ePn6TQSJQky4ueKeGQvpQ',
#    'alias': 'sugarfish-by-sushi-nozawa-new-york',
#    'name': 'SUGARFISH by sushi nozawa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/282Jybl2ud5_AT5SekPUKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sugarfish-by-sushi-nozawa-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 892,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73901, 'longitude': -73.98882},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '33 E 20th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33 E 20th St', 'New York, NY 10003']},
#    'phone': '+13477058100',
#    'display_phone': '(347) 705-8100',
#    'distance': 3763.481038786802},
#   {'id': 'R7EGjHWw0tNheY6-ahH8fQ',
#    'alias': 'tuome-new-york-2',
#    'name': 'Tuome',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/J5agtut4uApn4gpvnPmv1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tuome-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 560,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72412482724, 'longitude': -73.9828906263924},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '536 E 5th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['536 E 5th St', 'New York, NY 10009']},
#    'phone': '+16468337811',
#    'display_phone': '(646) 833-7811',
#    'distance': 2288.6649662214686}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#         Restaurant          Type Price Rating             Address        Lat  \
# 0            Chuko  Asian Fusion    $$      4  565 Vanderbilt Ave  40.680784
# 1              Ozu      Japanese    $$      4         78 Clark St  40.697473
# 2  Kohoku-Ku Ramen         Ramen                      709 9th Ave  40.762650
# 3       Nara Sushi    Sushi Bars                      76 Pearl St  40.703770
# 4              Sai  Asian Fusion    $$    4.5   95-34 Queens Blvd  40.730120
#
#          Lng                                                url  \
# 0 -73.967455  https://www.yelp.com/biz/chuko-brooklyn-2?adju...
# 1 -73.993265  https://www.yelp.com/biz/ozu-brooklyn?adjust_c...
# 2 -73.989900
# 3 -74.010410
# 4 -73.863600  https://www.yelp.com/biz/sai-rego-park?adjust_...
#
#                        ID
# 0  eS9mTLlWwu_Ap2ROMQWPxg
# 1  SoBdWOxymmY5yKANn63UWw
# 2
# 3
# 4  3n6i8TwGEIL9KnCCHUyiqA

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                        Restaurant                Type Rating Price  \
# 0                           Tuome      American (New)    4.5   $$$
# 1    Momofuku Noodle Bar - Uptown      American (New)      4    $$
# 2                           Chuko        Asian Fusion      4    $$
# 3                             Sai        Asian Fusion    4.5    $$
# 4                        Wild Ink        Asian Fusion      4   $$$
# 5                Takahachi Bakery            Bakeries      4    $$
# 6                  Izakaya Juraku                Bars    4.5    $$
# 7                  Rule of Thirds  Breakfast & Brunch
# 8                            ACRE  Breakfast & Brunch
# 9                        Bar Moga       Cocktail Bars      4    $$
# 10                       Bar Goto       Cocktail Bars    4.5    $$
# 11                  Katana Kitten       Cocktail Bars      4    $$
# 12            Tokuyama Salon Café        Coffee & Tea
# 13                         Suzume            Filipino      4    $$
# 14                  Izakaya NoMad          Gastropubs      4    $$
# 15               Sake Bar Hagi 46             Izakaya      4    $$
# 16                       Yopparai             Izakaya    4.5   $$$
# 17        IZAKAYA NYC on East 4th             Izakaya
# 18               Moonrise Izakaya             Izakaya      4    $$
# 19                       Wakuwaku             Izakaya
# 20                        Izakaya             Izakaya      4    $$
# 21                    Aoi Kitchen             Izakaya      4    $$
# 22                   Sushi Yasaka            Japanese      4    $$
# 23             shabushabu Mayumon            Japanese
# 24                  Secchu Yokota            Japanese      5  $$$$
# 25                Sarashina Horii            Japanese
# 26                     Soba Totto            Japanese      4    $$
# 27                         Wokuni            Japanese      4   $$$
# 28              Yakitori Sun-Chan            Japanese    3.5    $$
# 29                            Gen            Japanese      4    $$
# ..                            ...                 ...    ...   ...
# 170                 Kissaki Sushi          Sushi Bars
# 171                      Ki Sushi          Sushi Bars      4    $$
# 172                 Sushi Katsuei          Sushi Bars      4   $$$
# 173                          Koyo          Sushi Bars    4.5  $$$$
# 174           Ootoya Times Square          Sushi Bars      4    $$
# 175                        Nakaji          Sushi Bars
# 176                           Ako          Sushi Bars      4    $$
# 177                         Taiki          Sushi Bars    4.5   $$$
# 178                       Norikoh          Sushi Bars      4    $$
# 179                         Kenka          Sushi Bars    3.5    $$
# 180                        Marumi          Sushi Bars      4    $$
# 181             Blue Ribbon Sushi          Sushi Bars      4    $$
# 182                     Sushi Lab          Sushi Bars
# 183                         Akino          Sushi Bars    4.5   $$$
# 184                       Kissaki          Sushi Bars      4  $$$$
# 185                          noda          Sushi Bars    4.5  $$$$
# 186                     Takahachi          Sushi Bars      4    $$
# 187           Komorebi Full House          Sushi Bars    4.5    $$
# 188                     Nami Nori          Sushi Bars    4.5   $$$
# 189                Suzuki Shokudo          Sushi Bars    4.5    $$
# 190                     Sushi Noz          Sushi Bars    4.5  $$$$
# 191                           886           Taiwanese      4    $$
# 192                   Izakaya MEW          Tapas Bars      4    $$
# 193              Kushi Kushi Yaki  Tapas/Small Plates
# 194                        nonono  Tapas/Small Plates      4   $$$
# 195             Aburiya Kinnosuke  Tapas/Small Plates      4   $$$
# 196          Izakaya Mew Flushing  Tapas/Small Plates      4    $$
# 197               Izakaya Toribar  Tapas/Small Plates    4.5    $$
# 198                      DokoDemo          Teppanyaki    4.5     $
# 199            Saigon Grill & Bar          Vietnamese    4.5    $$
#
#                   Address        Lat        Lng  \
# 0            536 E 5th St  40.724125 -73.982891
# 1         10 Columbus Cir  40.768470 -73.983092
# 2      565 Vanderbilt Ave  40.680784 -73.967455
# 3       95-34 Queens Blvd  40.730120 -73.863600
# 4           500 W 33rd St  40.753754 -74.001388
# 5            25 Murray St  40.713930 -74.008220
# 6           121 Ludlow St  40.719680 -73.988709
# 7           171 Banker St  40.724633 -73.955110
# 8         64 Meserole Ave  40.726330 -73.954710
# 9        128 W Houston St  40.727870 -74.001070
# 10        245 Eldridge St  40.722770 -73.989890
# 11          531 Hudson St  40.734250 -74.006390
# 12           627 E 6th St  40.723990 -73.980200
# 13         545 Lorimer St  40.713165 -73.949448
# 14           13 W 26th St  40.744090 -73.989450
# 15          358 W 46th St  40.760570 -73.990080
# 16          49 Clinton St  40.719762 -73.984971
# 17        215 East 4th St  40.723881 -73.983428
# 18      774 Amsterdam Ave  40.795399 -73.969762
# 19            269 36th St  40.655905 -74.006775
# 20           326 E 6th St  40.726670 -73.987380
# 21           320 E 6th St  40.726832 -73.987543
# 22          251 W 72nd St  40.779583 -73.983482
# 23        115 Division St  40.714340 -73.992050
# 24           199 E 3rd St  40.722842 -73.983102
# 25           45 E 20th St  40.738710 -73.988380
# 26          211 E 43rd St  40.751220 -73.973170
# 27      327 Lexington Ave  40.749219 -73.977353
# 28          2707 Broadway  40.799500 -73.968640
# 29     659 Washington Ave  40.677639 -73.963485
# ..                    ...        ...        ...
# 170      286 Columbus Ave  40.778571 -73.978209
# 171          122 Smith St  40.687640 -73.990100
# 172           210 7th Ave  40.670715 -73.978590
# 173         3712 31st Ave  40.761640 -73.918380
# 174         141 W 41st St  40.754870 -73.985990
# 175             48 Bowery  40.715700 -73.996630
# 176       205 Bedford Ave  40.716860 -73.958450
# 177         134 Nevins St  40.684543 -73.983778
# 178          43 W 24th St  40.743300 -73.991370
# 179        25 St Marks Pl  40.729130 -73.988465
# 180      546 Laguardia Pl  40.728970 -73.998370
# 181       119 Sullivan St  40.726120 -74.002530
# 182         132 W 47th St  40.758417 -73.983301
# 183        82-80 Broadway  40.741236 -73.881306
# 184            319 Bowery  40.725350 -73.991930
# 185        6 West 28th St  40.744780 -73.988100
# 186              85 Ave A  40.725315 -73.984436
# 187         6201 11th Ave  40.630169 -74.004041
# 188         33 Carmine St  40.730284 -74.003212
# 189         38-01 31st St  40.753530 -73.931840
# 190         181 E 78th St  40.773850 -73.958130
# 191     26 Saint Marks Pl  40.728770 -73.988730
# 192          53 W 35th St  40.750148 -73.986320
# 193           2 W 32nd St  40.747266 -73.986178
# 194       118 Madison Ave  40.745450 -73.984990
# 195         213 E 45th St  40.752583 -73.972274
# 196  146-13 Northern Blvd  40.765360 -73.820220
# 197         164 E 56th St  40.759641 -73.968556
# 198           89 E 4th St  40.726380 -73.989640
# 199            4521 Ave N  40.618830 -73.930990
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/tuome-new-york-2?adju...  R7EGjHWw0tNheY6-ahH8fQ
# 1    https://www.yelp.com/biz/momofuku-noodle-bar-u...  Pr-q47vsmM4aoc2t_Sfk8w
# 2    https://www.yelp.com/biz/chuko-brooklyn-2?adju...  eS9mTLlWwu_Ap2ROMQWPxg
# 3    https://www.yelp.com/biz/sai-rego-park?adjust_...  3n6i8TwGEIL9KnCCHUyiqA
# 4    https://www.yelp.com/biz/wild-ink-new-york?adj...  ptWTdgSzSpH-0LD24QIH-w
# 5    https://www.yelp.com/biz/takahachi-bakery-new-...  GlPJPpKvPR4d8dmcSEYpdA
# 6    https://www.yelp.com/biz/izakaya-juraku-new-yo...  RYKGs45OjF-vlb2Ds2Jb_g
# 7
# 8
# 9    https://www.yelp.com/biz/bar-moga-new-york-2?a...  pil3w2-2REoXBwEToYZ_tQ
# 10   https://www.yelp.com/biz/bar-goto-new-york?adj...  o5EIqc4LekAoeLHiYjzLqQ
# 11   https://www.yelp.com/biz/katana-kitten-new-yor...  kIzVGUWS2b5H_b-G0Q0-0g
# 12
# 13   https://www.yelp.com/biz/suzume-brooklyn?adjus...  BlzlywklvYdek5uk_NCX9g
# 14   https://www.yelp.com/biz/izakaya-nomad-new-yor...  8NVN6Nldm7AGoGaABBZMRw
# 15   https://www.yelp.com/biz/sake-bar-hagi-46-new-...  Nbqzy3ea5_x2zXWkdWlUIQ
# 16   https://www.yelp.com/biz/yopparai-new-york?adj...  kN3rkbjvqkY62CDRYUVz4g
# 17
# 18   https://www.yelp.com/biz/moonrise-izakaya-new-...  Nnc2RVv5TPNAy70gOJrc-Q
# 19
# 20   https://www.yelp.com/biz/izakaya-new-york-2?ad...  i8F0fnempD5fTb2CxbwKDw
# 21   https://www.yelp.com/biz/aoi-kitchen-new-york?...  lEH8EUPX3Zn_trHauIycYw
# 22   https://www.yelp.com/biz/sushi-yasaka-new-york...  HZWHBfeuP4Fb6y8b8uqnbA
# 23
# 24   https://www.yelp.com/biz/secchu-yokota-new-yor...  ynR4-QgEOsE7VhNfIWo73w
# 25
# 26   https://www.yelp.com/biz/soba-totto-new-york?a...  Ms1p17KsYteDlkvHnllC2g
# 27   https://www.yelp.com/biz/wokuni-new-york?adjus...  D6ZEcG1FCZ18nekMWrhgMg
# 28   https://www.yelp.com/biz/yakitori-sun-chan-new...  Qli775QfVY4oFPNu7Cy5Tw
# 29   https://www.yelp.com/biz/gen-brooklyn?adjust_c...  0Lnp_fi3gI2bfJ8RcMDfjg
# ..                                                 ...                     ...
# 170
# 171  https://www.yelp.com/biz/ki-sushi-brooklyn?adj...  tT6teP3ZfCAfvdPdDoqG4A
# 172  https://www.yelp.com/biz/sushi-katsuei-brookly...  B-lJd1eBLcLk1StNbgAe9w
# 173  https://www.yelp.com/biz/koyo-astoria-5?adjust...  LOFl1w5bXrAdDRAQ-vi3_A
# 174  https://www.yelp.com/biz/ootoya-times-square-n...  wjIyCBEpCG_HRp8veiI0YQ
# 175
# 176  https://www.yelp.com/biz/ako-brooklyn-5?adjust...  T2fE7hGS83Ba-QNCOqbK4A
# 177  https://www.yelp.com/biz/taiki-brooklyn?adjust...  Ww3aAPf0sA5ygAXu2qV1ZQ
# 178  https://www.yelp.com/biz/norikoh-new-york-8?ad...  xFp3xSQ43J-i7nmJfNBsZA
# 179  https://www.yelp.com/biz/kenka-new-york?adjust...  9xRIcn0jTyvWNH9aBO3oAA
# 180  https://www.yelp.com/biz/marumi-new-york?adjus...  -pab00ajP_NS1KGfILveYA
# 181  https://www.yelp.com/biz/blue-ribbon-sushi-new...  QR1YIRzFjd2bi5iBzT9zXg
# 182
# 183  https://www.yelp.com/biz/akino-elmhurst?adjust...  22CRLIEfJWIO-8RjEiecAg
# 184  https://www.yelp.com/biz/kissaki-new-york-5?ad...  7qvsMuRypQYg1Ux8kghybg
# 185  https://www.yelp.com/biz/noda-new-york?adjust_...  IPhWpqIuAiEerKlLS82RpQ
# 186  https://www.yelp.com/biz/takahachi-new-york?ad...  itblJyiTY2h2ACidLk66oA
# 187  https://www.yelp.com/biz/komorebi-full-house-b...  1yqrirjDVm40roP-NcU-Ig
# 188  https://www.yelp.com/biz/nami-nori-new-york?ad...  lY_gb_hNbit6GHBiOn3VeQ
# 189  https://www.yelp.com/biz/suzuki-shokudo-long-i...  mm8gYHxaLLRyv3CslY40TA
# 190  https://www.yelp.com/biz/sushi-noz-new-york?ad...  ocnHpILS80DHL--34L8xpw
# 191  https://www.yelp.com/biz/886-new-york?adjust_c...  8Oo2AtQEPDfxIOnA8wfXoQ
# 192  https://www.yelp.com/biz/izakaya-mew-new-york-...  klAhw3xLQi9GF1tf_HnS7w
# 193
# 194  https://www.yelp.com/biz/nonono-new-york-6?adj...  qm1J_dPA5IHij1oAnoZwHw
# 195  https://www.yelp.com/biz/aburiya-kinnosuke-new...  _FhKGcCbiYgtkXcCiwTAiA
# 196  https://www.yelp.com/biz/izakaya-mew-flushing-...  mdAt1D1XUG-HwTYmPSi9fA
# 197  https://www.yelp.com/biz/izakaya-toribar-new-y...  wpT1QU7PSQgQQ1DkzI00JA
# 198  https://www.yelp.com/biz/dokodemo-new-york?adj...  n1xpGOPa7XRq4or7QLjzHw
# 199  https://www.yelp.com/biz/saigon-grill-and-bar-...  V58g7E1AHkuTchTVyLQuYQ
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_Japanese.csv')
