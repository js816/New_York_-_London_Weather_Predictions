# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"german","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': 'BxNs9d8rEW3Tls-nVdmIgA',
#    'alias': 'reichenbach-hall-new-york',
#    'name': 'Reichenbach Hall',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/luuVq3iQZWeQW1gMZYHXhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/reichenbach-hall-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 772,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'german', 'title': 'German'},
#     {'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7508, 'longitude': -73.98401},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '5 W 37th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 W 37th St', 'New York, NY 10018']},
#    'phone': '+12123027744',
#    'display_phone': '(212) 302-7744',
#    'distance': 5125.789193272705},
#   {'id': 'zo4mcEfVKaktdj_gnSFhGQ',
#    'alias': 'cafe-katja-new-york',
#    'name': 'Cafe Katja',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aOQeKl7wYPmmSthza1Jj7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-katja-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 799,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'austrian', 'title': 'Austrian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7177673, 'longitude': -73.990589},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '79 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79 Orchard St', 'New York, NY 10002']},
#    'phone': '+12122199545',
#    'display_phone': '(212) 219-9545',
#    'distance': 1400.4825475532655},
#   {'id': 'PJeuLlvja4ZKv_tHq_pE1A',
#    'alias': 'heidelberg-restaurant-new-york',
#    'name': 'Heidelberg Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BnKnxH81g71-iKadtkOD-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heidelberg-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 707,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77742, 'longitude': -73.95172},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1648 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1648 2nd Ave', 'New York, NY 10028']},
#    'phone': '+12126282332',
#    'display_phone': '(212) 628-2332',
#    'distance': 8772.369147841455},
#   {'id': 'TOaQzGPAIQWQUIXi4CPnbA',
#    'alias': 'radegast-hall-and-biergarten-brooklyn',
#    'name': 'Radegast Hall and Biergarten',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UZRCvkeV1EEsH45807P93Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/radegast-hall-and-biergarten-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1352,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'german', 'title': 'German'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.716641, 'longitude': -73.961498},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '113 N 3rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['113 N 3rd St', 'Brooklyn, NY 11249']},
#    'phone': '+17189633973',
#    'display_phone': '(718) 963-3973',
#    'distance': 3031.61581674316},
#   {'id': 'Q6quwwLiwx_47SRd3tItvA',
#    'alias': 'schallers-stube-sausage-bar-new-york',
#    'name': "Schaller's Stube Sausage Bar",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pKZ6bv7V1Oz8K8q0Yp5AXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/schallers-stube-sausage-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 226,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.777544, 'longitude': -73.951607},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1652 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1652 2nd Ave', 'New York, NY 10028']},
#    'phone': '+16467264355',
#    'display_phone': '(646) 726-4355',
#    'distance': 8786.691519919546},
#   {'id': '5WD82Wg_s4bh5K0f3ZwnxQ',
#    'alias': 'black-forest-brooklyn-brooklyn-2',
#    'name': 'Black Forest Brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/s0_CJfWE_S66sziuhlnWsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-forest-brooklyn-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 94,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'german', 'title': 'German'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68563, 'longitude': -73.990823},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '181 Smith St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['181 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17185221806',
#    'display_phone': '(718) 522-1806',
#    'distance': 2221.076565579013},
#   {'id': '-2aMphgYYnoxncuZ7xI3Gw',
#    'alias': 'bierhaus-nyc-new-york-4',
#    'name': 'Bierhaus NYC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/150yhnGbxKhRi5iDur4hqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bierhaus-nyc-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 889,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'karaoke', 'title': 'Karaoke'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.75261, 'longitude': -73.97342},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '712 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['712 3rd Ave', 'New York, NY 10017']},
#    'phone': '+12128672337',
#    'display_phone': '(212) 867-2337',
#    'distance': 5531.595364231468},
#   {'id': 'ZgyvDF_hOWas3SXe0Hj7hA',
#    'alias': 'schilling-new-york',
#    'name': 'Schilling',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HCce24K-JLgFm4L5KzV28Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/schilling-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 165,
#    'categories': [{'alias': 'austrian', 'title': 'Austrian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70857, 'longitude': -74.014},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '109 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10006',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['109 Washington St', 'New York, NY 10006']},
#    'phone': '+12124061200',
#    'display_phone': '(212) 406-1200',
#    'distance': 1694.618934732702},
#   {'id': 'K_e7_aNgghFLZ2zvjFSNkQ',
#    'alias': 'loreley-beer-garden-new-york-2',
#    'name': 'Loreley Beer Garden',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OnN4ZY1nvIwRuST8Y96UZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/loreley-beer-garden-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 768,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7212291, 'longitude': -73.992872},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '7 Rivington St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 Rivington St', 'New York, NY 10002']},
#    'phone': '+12122537077',
#    'display_phone': '(212) 253-7077',
#    'distance': 1759.2078116057417},
#   {'id': 'NirY5TkWZBNuuAgbjdG0AA',
#    'alias': 'bohemian-spirit-restaurant-new-york',
#    'name': 'Bohemian Spirit Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rgXO8MNYTvqVbuM1WJBpqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bohemian-spirit-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 102,
#    'categories': [{'alias': 'czech', 'title': 'Czech'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76898, 'longitude': -73.95643},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '321 E 73rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['321 E 73rd St', 'New York, NY 10021']},
#    'phone': '+12128611038',
#    'display_phone': '(212) 861-1038',
#    'distance': 7761.458282641513},
#   {'id': 'FXBrt0VpeBRengdd4fBOZw',
#    'alias': 'werkstatt-brooklyn-2',
#    'name': 'Werkstatt',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YQWncyNpx6m0P4pa6wIn4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/werkstatt-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 270,
#    'categories': [{'alias': 'austrian', 'title': 'Austrian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.645298, 'longitude': -73.970234},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '509 Coney Island Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11218',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['509 Coney Island Ave', 'Brooklyn, NY 11218']},
#    'phone': '+17182845800',
#    'display_phone': '(718) 284-5800',
#    'distance': 6989.009595803364},
#   {'id': 'osY94UfXtrynDL2nMs_bdw',
#    'alias': 'max-bratwurst-und-bier-astoria',
#    'name': 'Max Bratwurst und Bier',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WeahMxEWu0rH3UKD2FTDKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/max-bratwurst-und-bier-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 404,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7612453874006,
#     'longitude': -73.9094611979998},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '4702 30th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4702 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17187771635',
#    'display_phone': '(718) 777-1635',
#    'distance': 9465.188938384523},
#   {'id': '19o6iblcJvz2hdPouYhXgg',
#    'alias': 'zum-stammtisch-glendale',
#    'name': 'Zum Stammtisch',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OAI9b7m-P32jNr_hsCE9yQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zum-stammtisch-glendale?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 484,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7017618, 'longitude': -73.8813408},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '6946 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Glendale',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6946 Myrtle Ave', 'Glendale, NY 11385']},
#    'phone': '+17183863014',
#    'display_phone': '(718) 386-3014',
#    'distance': 9550.09692986248},
#   {'id': 'F622poZMX_mk1eoSoUOyaw',
#    'alias': 'the-biergarten-at-the-standard-high-line-new-york',
#    'name': 'The Biergarten at The Standard, High Line',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oE3_rXk3WFK3OyP33sDvjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-biergarten-at-the-standard-high-line-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 886,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'german', 'title': 'German'},
#     {'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.740799, 'longitude': -74.007907},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '848 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['848 Washington St', 'New York, NY 10014']},
#    'phone': '+12126454100',
#    'display_phone': '(212) 645-4100',
#    'distance': 4099.042539416837},
#   {'id': 'VRXwdcYLqYhuF-tzIdvINw',
#    'alias': 'dsk-brooklyn-brooklyn',
#    'name': 'DSK Brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JhOgZuF6_3cy_Kivugq53g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dsk-brooklyn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 246,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6857666, 'longitude': -73.9735353},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '710 Fulton St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['710 Fulton St', 'Brooklyn, NY 11217']},
#    'phone': '+13478414495',
#    'display_phone': '(347) 841-4495',
#    'distance': 2801.864016748146},
#   {'id': 'tV2IY8q92bOEwVC4McgPjw',
#    'alias': 'wallse-new-york-8',
#    'name': 'Wallse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iL8ad7NiGhoPqlLg71g0eQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wallse-new-york-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 314,
#    'categories': [{'alias': 'austrian', 'title': 'Austrian'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7354552762594,
#     'longitude': -74.0082208400924},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '344 W 11th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['344 W 11th St', 'New York, NY 10014']},
#    'phone': '+12123522300',
#    'display_phone': '(212) 352-2300',
#    'distance': 3537.409034260649},
#   {'id': 'BqPCyiV0N8dwZ69KOUqO2w',
#    'alias': 'spritzenhaus-33-brooklyn',
#    'name': 'Spritzenhaus 33',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ni9xmpc8qegyd2ErrxooiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spritzenhaus-33-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 549,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7232908725574,
#     'longitude': -73.9527179893456},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '33 Nassau Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33 Nassau Ave', 'Brooklyn, NY 11222']},
#    'phone': '+13479874632',
#    'display_phone': '(347) 987-4632',
#    'distance': 4026.936093172967},
#   {'id': '0iCISI2oP9bkS54hy68Xsw',
#    'alias': 'rolfs-bar-and-restaurant-new-york',
#    'name': "Rolf's Bar & Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6hzjg8gf2B7Ob4A1_1nahw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rolfs-bar-and-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 985,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.73803, 'longitude': -73.98353},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '281 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['281 3rd Ave', 'New York, NY 10010']},
#    'phone': '+12124774750',
#    'display_phone': '(212) 477-4750',
#    'distance': 3735.107034518671},
#   {'id': '2BRJP7YeiNuWSwyn2TdAoA',
#    'alias': 'kafana-new-york',
#    'name': 'Kafana',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B-nIvpYSddOHsatr70-fkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kafana-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 415,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72432, 'longitude': -73.97851},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '116 Ave C',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['116 Ave C', 'New York, NY 10009']},
#    'phone': '+12123538000',
#    'display_phone': '(212) 353-8000',
#    'distance': 2491.373576619052},
#   {'id': 'CkKTdw-lxGX8H3L0ppr6Zg',
#    'alias': 'black-forest-brooklyn-brooklyn',
#    'name': 'Black Forest Brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OyqXY8ydqNNx-AzZWhordA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-forest-brooklyn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 411,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6867553, 'longitude': -73.9750998},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '733 Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['733 Fulton St', 'Brooklyn, NY 11217']},
#    'phone': '+17189350300',
#    'display_phone': '(718) 935-0300',
#    'distance': 2633.8422732759072},
#   {'id': '3K8Z8S7bsVI1w9QjUelbag',
#    'alias': 'hasenstüble-brooklyn-2',
#    'name': 'HasenStüble',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kVLn4TrBdxqetmf8SedaFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hasenst%C3%BCble-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.658609, 'longitude': -73.950605},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1184 Nostrand Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11225',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1184 Nostrand Ave', 'Brooklyn, NY 11225']},
#    'phone': '+13472405191',
#    'display_phone': '(347) 240-5191',
#    'distance': 6379.15775332685},
#   {'id': 'XA7phnS0fBfLR8xdsngiUQ',
#    'alias': 'gottscheer-hall-ridgewood',
#    'name': 'Gottscheer Hall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gOLNWBRYfJfwA_m5_WhgZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gottscheer-hall-ridgewood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'catering', 'title': 'Caterers'},
#     {'alias': 'german', 'title': 'German'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.706891, 'longitude': -73.905479},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '657 Fairview Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['657 Fairview Ave', 'Ridgewood, NY 11385']},
#    'phone': '+17183663030',
#    'display_phone': '(718) 366-3030',
#    'distance': 7493.100665139834},
#   {'id': '66T7rXIZvcVg7XicY6QObg',
#    'alias': 'oscars-place-new-york-2',
#    'name': "Oscar's Place",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FETfiRPwBgR91DFXMbEwiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oscars-place-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 219,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7318649, 'longitude': -74.0064011},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '466 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['466 Hudson St', 'New York, NY 10014']},
#    'phone': '+12127416479',
#    'display_phone': '(212) 741-6479',
#    'distance': 3102.120244740204},
#   {'id': 'I3boMDez9rUejzf7EyT2Dg',
#    'alias': 'jagerhaus-german-restaurant-and-biergarten-whitestone-3',
#    'name': 'Jagerhaus German Restaurant & Biergarten',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PiJ4cN9RhWJ0_QZs-M2O6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jagerhaus-german-restaurant-and-biergarten-whitestone-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 282,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78663, 'longitude': -73.81654},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1516 149th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Whitestone',
#     'zip_code': '11357',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1516 149th St', 'Whitestone, NY 11357']},
#    'phone': '+17187673486',
#    'display_phone': '(718) 767-3486',
#    'distance': 17491.46255774265},
#   {'id': 'nm5rcWNmfevNXLNQAITi5w',
#    'alias': 'clinton-hall-new-york',
#    'name': 'Clinton Hall',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jkOeBmGbclLyY3zbOa7COw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clinton-hall-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 700,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70803, 'longitude': -74.014869},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '90 Washington St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10006',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90 Washington St', 'New York, NY 10006']},
#    'phone': '+12123636000',
#    'display_phone': '(212) 363-6000',
#    'distance': 1758.0354661858244},
#   {'id': 'rEw0U5tN2gTwoFrd-Yfsog',
#    'alias': 'schnitzel-haus-brooklyn',
#    'name': 'Schnitzel Haus',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VhIwOq4phguge0ZAbhbkYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/schnitzel-haus-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 313,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.630358, 'longitude': -74.021959},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '7319 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7319 5th Ave', 'Brooklyn, NY 11209']},
#    'phone': '+17188365600',
#    'display_phone': '(718) 836-5600',
#    'distance': 8669.191928039076},
#   {'id': '61Tl42ENbjLAAIkZjN7qfw',
#    'alias': 'berlin-currywurst-new-york-3',
#    'name': 'Berlin Currywurst',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eJz2pS0DtYxs52iHxJkfsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/berlin-currywurst-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74222, 'longitude': -74.00466},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '75 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 9th Ave', 'New York, NY 10011']},
#    'phone': '+16468273689',
#    'display_phone': '(646) 827-3689',
#    'distance': 4160.424215067582},
#   {'id': 'QRbD99HVMffeto7_Hq67CQ',
#    'alias': 'korzo-brooklyn',
#    'name': 'Korzo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bbYZaDUGT7vQmMyvtWHm4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/korzo-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 463,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.66199, 'longitude': -73.99238},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '667 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['667 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17184991199',
#    'display_phone': '(718) 499-1199',
#    'distance': 4830.562014282927},
#   {'id': '_NS1hEZ0LPwaTG4R6jxgnw',
#    'alias': 'cafe-sabarsky-new-york-4',
#    'name': 'Cafe Sabarsky',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8dk88iFlkJH7R720j_igQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-sabarsky-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 505,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'austrian', 'title': 'Austrian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78122494966741,
#     'longitude': -73.9602662713214},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1048 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1048 5th Ave', 'New York, NY 10028']},
#    'phone': '+12122880665',
#    'display_phone': '(212) 288-0665',
#    'distance': 8900.614315463365},
#   {'id': 'Fm1mE5Hf2k-yuzmFz98ufw',
#    'alias': 'manor-oktoberfest-forest-hills-46',
#    'name': 'Manor Oktoberfest',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HA4UyTO0j9w2WHuTTdXVrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/manor-oktoberfest-forest-hills-46?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 284,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7174275, 'longitude': -73.8569518},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '73-11 Yellowstone Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['73-11 Yellowstone Blvd', 'Forest Hills, NY 11375']},
#    'phone': '+17185442400',
#    'display_phone': '(718) 544-2400',
#    'distance': 11658.718614399377},
#   {'id': 'a6SzfZ2F-uELmymusQVMBg',
#    'alias': 'karczma-brooklyn',
#    'name': 'Karczma',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AhFpaHm5pi8BNSbyX901Pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/karczma-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 606,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.729977, 'longitude': -73.955128},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '136 Greenpoint Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136 Greenpoint Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183491744',
#    'display_phone': '(718) 349-1744',
#    'distance': 4282.0841465205085},
#   {'id': 'u5pK1oszIUvrnDRLKwifqA',
#    'alias': 'pilsener-haus-and-biergarten-hoboken',
#    'name': 'Pilsener Haus & Biergarten',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5T0SiDIQ5yhS1K6HB9qBnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pilsener-haus-and-biergarten-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 810,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7552077, 'longitude': -74.0314563558197},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1422 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1422 Grand St', 'Hoboken, NJ 07030']},
#    'phone': '+12016835465',
#    'display_phone': '(201) 683-5465',
#    'distance': 6357.997848641078},
#   {'id': 'SvNoFlsMTcBzDv9OirfGZw',
#    'alias': 'little-poland-new-york',
#    'name': 'Little Poland',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-BOCjznTmhemc_ktoZUvEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-poland-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 320,
#    'categories': [{'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73119, 'longitude': -73.9855199},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '200 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12127779728',
#    'display_phone': '(212) 777-9728',
#    'distance': 2955.7616383214972},
#   {'id': '-wkcI5M7902hJyhkN1zS3A',
#    'alias': '124-old-rabbit-club-new-york',
#    'name': '124 Old Rabbit Club',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eCjkZJi7EfFRd-UoVNaVGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/124-old-rabbit-club-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 347,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729926, 'longitude': -74.000219},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '124 MacDougal St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['124 MacDougal St', 'New York, NY 10012']},
#    'phone': '+16467819646',
#    'display_phone': '(646) 781-9646',
#    'distance': 2767.607648492549},
#   {'id': 'Utao0K7U6eny2tZTNDqziA',
#    'alias': 'wiener-bar-queens',
#    'name': 'Wiener Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EP-px64cRdviq3CQ_bw-3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wiener-bar-queens?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.695, 'longitude': -73.90433},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1539 Covert St',
#     'address2': None,
#     'address3': '',
#     'city': 'Queens',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1539 Covert St', 'Queens, NY 11385']},
#    'phone': '+13617398400',
#    'display_phone': '(361) 739-8400',
#    'distance': 7704.193501996933},
#   {'id': '-BmS1FH3DSK6fSifIt8GgQ',
#    'alias': 'nurnberger-bierhaus-staten-island',
#    'name': 'Nurnberger Bierhaus',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UmPYeEbm4w6GQTLXiRAE2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nurnberger-bierhaus-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 224,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.63482, 'longitude': -74.10961},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '817 Castleton Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10310',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['817 Castleton Ave', 'Staten Island, NY 10310']},
#    'phone': '+17188167461',
#    'display_phone': '(718) 816-7461',
#    'distance': 12494.497421319058},
#   {'id': 'eIbKiQuExi12NcGeqMzQAw',
#    'alias': 'babas-pierogies-brooklyn',
#    'name': "Baba's Pierogies",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LpSQQDCxYapJWk065wJjCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/babas-pierogies-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 426,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'slovakian', 'title': 'Slovakian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67687, 'longitude': -73.98633},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '295 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['295 3rd Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17182220777',
#    'display_phone': '(718) 222-0777',
#    'distance': 3253.379374229705},
#   {'id': 'qbEuBOWUXO2s-C28xJ0tOQ',
#    'alias': 'koliba-astoria',
#    'name': 'Koliba',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/10FkBU-S9Q_nHr22aEH3_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/koliba-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'czech', 'title': 'Czech'},
#     {'alias': 'slovakian', 'title': 'Slovakian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7743701, 'longitude': -73.9126345},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '3111 23rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3111 23rd Ave', 'Astoria, NY 11105']},
#    'phone': '+17186260430',
#    'display_phone': '(718) 626-0430',
#    'distance': 10308.457895022935},
#   {'id': 'wLvcBF3tbvu5h6XDYfm7DA',
#    'alias': 'burp-castle-new-york',
#    'name': 'Burp Castle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3aqHNbGm3mRGIjclVq0CaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burp-castle-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 554,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7283252192663,
#     'longitude': -73.9886448736218},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '41 E 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41 E 7th St', 'New York, NY 10003']},
#    'phone': '+12129824576',
#    'display_phone': '(212) 982-4576',
#    'distance': 2588.328840089062},
#   {'id': 'GlSWzWVmQsKLGxySYSGRbQ',
#    'alias': 'smithfield-hall-new-york-5',
#    'name': 'Smithfield Hall',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/b_11vLu_Gkc-Ph51zuB18A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/smithfield-hall-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 487,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7447532620452,
#     'longitude': -73.9934939850447},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '138 W 25th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['138 W 25th St', 'New York, NY 10001']},
#    'phone': '+12129299677',
#    'display_phone': '(212) 929-9677',
#    'distance': 4371.408398892504},
#   {'id': 'JJluK3s0SKFv02LKZbl_kw',
#    'alias': 'old-traditional-polish-cuisine-new-york',
#    'name': 'Old Traditional Polish Cuisine',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FoS9SWMNkmAzxKNrqnL3yQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/old-traditional-polish-cuisine-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7647053435302,
#     'longitude': -73.9821391124684},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '55TH St Broadway Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10020',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55TH St Broadway Ave', 'New York, NY 10020']},
#    'phone': '+13474698867',
#    'display_phone': '(347) 469-8867',
#    'distance': 6668.5562679728255},
#   {'id': 'u-1o6fSvTnqLBtqFuLFqNw',
#    'alias': 'budapest-cafe-and-restaurant-new-york',
#    'name': 'Budapest Cafe and Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/N0ERt-8Soh4FJnw2RTSsEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/budapest-cafe-and-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 274,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'hungarian', 'title': 'Hungarian'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.77715, 'longitude': -73.95264},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1631 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1631 2nd Ave', 'New York, NY 10028']},
#    'phone': '+12123271105',
#    'display_phone': '(212) 327-1105',
#    'distance': 8712.039630535364},
#   {'id': '0Q3xCYWK2N-wJfXjLa9dFg',
#    'alias': 'bâtard-new-york',
#    'name': 'Bâtard',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pg_CyIMJxC47x_ZOi7uxXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b%C3%A2tard-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 423,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71958, 'longitude': -74.00581},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '239 West Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['239 West Broadway', 'New York, NY 10013']},
#    'phone': '+12122192777',
#    'display_phone': '(212) 219-2777',
#    'distance': 1835.005105739778},
#   {'id': 'NA_p2AH5RSBV314bklZn_g',
#    'alias': 'stone-street-tavern-new-york',
#    'name': 'Stone Street Tavern',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rNoIlPTFMYjlNLGazrv6fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stone-street-tavern-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 442,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7043685019016,
#     'longitude': -74.0102007240057},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '52 Stone St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['52 Stone St', 'New York, NY 10004']},
#    'phone': '+12127855658',
#    'display_phone': '(212) 785-5658',
#    'distance': 1346.2447255271536},
#   {'id': 'Rpw8mQPKJb8esVjosT4Sog',
#    'alias': 'valhalla-new-york',
#    'name': 'Valhalla',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FSH0c0iAImX1M2wyqu8vJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/valhalla-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 504,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76596, 'longitude': -73.98737},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '815 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['815 9th Ave', 'New York, NY 10019']},
#    'phone': '+12127572747',
#    'display_phone': '(212) 757-2747',
#    'distance': 6755.312521837086},
#   {'id': 'ptgu17Y_jD60815rPTEN1w',
#    'alias': 'kotti-berliner-döner-kebab-brooklyn-3',
#    'name': 'Kotti Berliner Döner Kebab',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AQYa3uRrWSd2oPxd11fkpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kotti-berliner-d%C3%B6ner-kebab-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 88,
#    'categories': [{'alias': 'kebab', 'title': 'Kebab'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6907009, 'longitude': -73.9834976},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '445 Albee Square W',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['445 Albee Square W', 'Brooklyn, NY 11201']},
#    'phone': '+13476141779',
#    'display_phone': '(347) 614-1779',
#    'distance': 1875.1242563460148},
#   {'id': '03b_GOyFKAtc4eebtNf2iQ',
#    'alias': 'plattduetsche-park-restaurant-franklin-square',
#    'name': 'Plattduetsche Park Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VTNS0gsGNcgDW1mNA7MWcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/plattduetsche-park-restaurant-franklin-square?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 332,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7082, 'longitude': -73.68282},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1132 Hempstead Tpke',
#     'address2': '',
#     'address3': '',
#     'city': 'Franklin Square',
#     'zip_code': '11010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1132 Hempstead Tpke', 'Franklin Square, NY 11010']},
#    'phone': '+15163543131',
#    'display_phone': '(516) 354-3131',
#    'distance': 26256.46233917509},
#   {'id': 'qN6O25vth1A7H3uN4wO3BA',
#    'alias': 'the-sefton-new-york',
#    'name': 'The Sefton',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2f-QT8Nb8I7HaxiOqVp0vA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-sefton-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7690147430034,
#     'longitude': -73.9553448732022},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1373 1st Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1373 1st Ave', 'New York, NY 10021']},
#    'phone': '+12128128942',
#    'display_phone': '(212) 812-8942',
#    'distance': 7793.21023371617},
#   {'id': 'F-AfJgFrxNbn49Mp4l7aXg',
#    'alias': 'hollow-nickel-brooklyn-2',
#    'name': 'Hollow Nickel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B3ivo-BYPD6rO8v9cehkiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hollow-nickel-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 221,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68562, 'longitude': -73.9819},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '494 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['494 Atlantic Ave', 'Brooklyn, NY 11217']},
#    'phone': '+13472363417',
#    'display_phone': '(347) 236-3417',
#    'distance': 2439.495000581029},
#   {'id': 'cuVyM_ZxtREqpO1SXgZmRA',
#    'alias': 'bohemian-hall-and-beer-garden-astoria',
#    'name': 'Bohemian Hall & Beer Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/L5ZB9pLN3_Hl7lGBO138QQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bohemian-hall-and-beer-garden-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1160,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77273, 'longitude': -73.915772},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2919 24th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2919 24th Ave', 'Astoria, NY 11102']},
#    'phone': '+17182744925',
#    'display_phone': '(718) 274-4925',
#    'distance': 9987.067072302658}],
#  'total': 181,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                      Restaurant    Type Price Rating        Address  \
# 0              Reichenbach Hall    Bars    $$      4    5 W 37th St
# 1                    Cafe Katja  German    $$    4.5  79 Orchard St
# 2         Heidelberg Restaurant  German    $$      4   1648 2nd Ave
# 3  Radegast Hall and Biergarten    Pubs    $$      4   113 N 3rd St
# 4  Schaller's Stube Sausage Bar  German    $$      4   1652 2nd Ave
#
#          Lat        Lng                                                url  \
# 0  40.750800 -73.984010  https://www.yelp.com/biz/reichenbach-hall-new-...
# 1  40.717767 -73.990589  https://www.yelp.com/biz/cafe-katja-new-york?a...
# 2  40.777420 -73.951720  https://www.yelp.com/biz/heidelberg-restaurant...
# 3  40.716641 -73.961498  https://www.yelp.com/biz/radegast-hall-and-bie...
# 4  40.777544 -73.951607  https://www.yelp.com/biz/schallers-stube-sausa...
#
#                        ID
# 0  BxNs9d8rEW3Tls-nVdmIgA
# 1  zo4mcEfVKaktdj_gnSFhGQ
# 2  PJeuLlvja4ZKv_tHq_pE1A
# 3  TOaQzGPAIQWQUIXi4CPnbA
# 4  Q6quwwLiwx_47SRd3tItvA

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"german","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': 'uVimnyjMcc7MOGzd2NRX-w',
#    'alias': 'north-pole-pub-brooklyn',
#    'name': 'North Pole Pub',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dzqZcwY-Sv-89hxS2CYgAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/north-pole-pub-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.68154, 'longitude': -73.9774},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '428 Bergen St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['428 Bergen St', 'Brooklyn, NY 11217']},
#    'phone': '+17188570049',
#    'display_phone': '(718) 857-0049',
#    'distance': 3018.6812276285787},
#   {'id': 'PMp7WlHIXQUnej-Ds1jRfw',
#    'alias': 'blind-tiger-ale-house-new-york',
#    'name': 'Blind Tiger Ale House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/em6l-CtzWbuca3-Y9lRMsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blind-tiger-ale-house-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 902,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.731926, 'longitude': -74.003223},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '281 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['281 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12124624682',
#    'display_phone': '(212) 462-4682',
#    'distance': 3039.2154288142483},
#   {'id': 'PbxDOYOjYobnHFEH6I8PuQ',
#    'alias': 'kotti-berliner-döner-kebab-brooklyn-2',
#    'name': 'Kotti Berliner Döner Kebab',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/g8W4bH2a-jFdHx8ihKMw0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kotti-berliner-d%C3%B6ner-kebab-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 81,
#    'categories': [{'alias': 'kebab', 'title': 'Kebab'},
#     {'alias': 'wraps', 'title': 'Wraps'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.65629, 'longitude': -74.00807},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '220 36th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11232',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['220 36th St', 'Brooklyn, NY 11232']},
#    'phone': '+13476141779',
#    'display_phone': '(347) 614-1779',
#    'distance': 5587.861561038924},
#   {'id': 'w7G1r4v1YIN-ggIB9p7z9w',
#    'alias': 'café-fledermaus-new-york-2',
#    'name': 'Café Fledermaus',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nAE19XTmob1FNLhshW2Jig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-fledermaus-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'austrian', 'title': 'Austrian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.781242, 'longitude': -73.96025},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1048 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1048 5th Ave', 'New York, NY 10028']},
#    'phone': '+12122880665',
#    'display_phone': '(212) 288-0665',
#    'distance': 8903.270326810989},
#   {'id': '5grFfuYswh8K9GoEnOy81A',
#    'alias': 'bierocracy-long-island-city-2',
#    'name': 'Bierocracy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mybTXtdDICBftt497mJiBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bierocracy-long-island-city-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 316,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74402, 'longitude': -73.95028},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '12-23 Jackson Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['12-23 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+17183619333',
#    'display_phone': '(718) 361-9333',
#    'distance': 5665.738793712728},
#   {'id': 'ozyAYd8hardDsx2_l57khA',
#    'alias': 'andres-hungarian-forest-hills',
#    'name': "Andre's Hungarian",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FHq0FzmzNWC30HvBk8wJvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/andres-hungarian-forest-hills?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 98,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'hungarian', 'title': 'Hungarian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7265535, 'longitude': -73.8535516},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '100-28 Queens Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100-28 Queens Blvd', 'Forest Hills, NY 11375']},
#    'phone': '+17188300266',
#    'display_phone': '(718) 830-0266',
#    'distance': 12118.63994480084},
#   {'id': 'b2naaHiaR57Hm6JZG0njPg',
#    'alias': 'draught-55-new-york',
#    'name': 'Draught 55',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wmAGSj_SseLCRvIkC4BmGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/draught-55-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 372,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.758377, 'longitude': -73.966515},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '245 E 55th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['245 E 55th St', 'New York, NY 10022']},
#    'phone': '+12123004096',
#    'display_phone': '(212) 300-4096',
#    'distance': 6329.379548010229},
#   {'id': 'veku2cg2qaV-7MxwhOMBmg',
#    'alias': 'judge-roy-bean-public-house-new-york',
#    'name': 'Judge Roy Bean Public House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uyOBbYOb-lCGQBu6OmRNcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/judge-roy-bean-public-house-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 769,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7629158108786,
#     'longitude': -73.9761248066812},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '38 W 56th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38 W 56th St', 'New York, NY 10019']},
#    'phone': '+12122628300',
#    'display_phone': '(212) 262-8300',
#    'distance': 6571.265299457194},
#   {'id': 'P5X8K61nDAlo8QrgCn-agQ',
#    'alias': 'zeppelin-hall-jersey-city',
#    'name': 'Zeppelin Hall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VHbV8hfLEumrAjPkDlF-Ww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zeppelin-hall-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 874,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.715132087537, 'longitude': -74.04667189924},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '88 Liberty View Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['88 Liberty View Dr', 'Jersey City, NJ 07302']},
#    'phone': '+12017218888',
#    'display_phone': '(201) 721-8888',
#    'distance': 4544.380217519045},
#   {'id': 'zsgDZati0aRKaPf0Um16XQ',
#    'alias': 'stammtisch-pork-store-glendale',
#    'name': 'Stammtisch Pork Store',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/my23ZMIdcTMdnFCsmcHgDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stammtisch-pork-store-glendale?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7017618, 'longitude': -73.8813408},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '69-46 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Glendale',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['69-46 Myrtle Ave', 'Glendale, NY 11385']},
#    'phone': '+17183867200',
#    'display_phone': '(718) 386-7200',
#    'distance': 9550.09692986248},
#   {'id': 'NQmucLdr50HUN5trUSzjng',
#    'alias': 'celtic-gasthaus-glendale',
#    'name': 'Celtic Gasthaus',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fKo92gbZ4aKO8s8hQBRwaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/celtic-gasthaus-glendale?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'german', 'title': 'German'},
#     {'alias': 'irish', 'title': 'Irish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.700901, 'longitude': -73.892246},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '6404 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Glendale',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6404 Myrtle Ave', 'Glendale, NY 11385']},
#    'phone': '+17184568341',
#    'display_phone': '(718) 456-8341',
#    'distance': 8617.056177203618},
#   {'id': 'U3TwPnfQ1aJuilUB-JnUNw',
#    'alias': 'houston-hall-new-york',
#    'name': 'Houston Hall',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qo5D3yG5gOhehjbAU08ZNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/houston-hall-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 548,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'brewpubs', 'title': 'Brewpubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72866, 'longitude': -74.00472},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '222 W Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['222 W Houston St', 'New York, NY 10014']},
#    'phone': '+12126759323',
#    'display_phone': '(212) 675-9323',
#    'distance': 2741.6431434361994},
#   {'id': 'I8U2B8O3uXhhXYhRrOH_Xg',
#    'alias': 'the-ox-tavern-brooklyn',
#    'name': 'The OX Tavern',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LSOAZl6ncdAKYoNM17xACA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ox-tavern-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 537,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.63489, 'longitude': -73.96497},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1301 Newkirk Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11230',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1301 Newkirk Ave', 'Brooklyn, NY 11230']},
#    'phone': '+17182840005',
#    'display_phone': '(718) 284-0005',
#    'distance': 8216.062091137772},
#   {'id': '7sQYI_Ym9RzlxHIhJpj6hg',
#    'alias': 'arts-and-crafts-beer-parlor-new-york',
#    'name': 'Arts and Crafts Beer Parlor',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2eEnARbsZqc_5CzMDadSxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arts-and-crafts-beer-parlor-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 252,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7327283010334,
#     'longitude': -73.9977158235951},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '26 W 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 W 8th St', 'New York, NY 10011']},
#    'phone': '+16466785263',
#    'display_phone': '(646) 678-5263',
#    'distance': 3047.4579245318782},
#   {'id': 'LDwxXfapMw6xNbTF0YDFaQ',
#    'alias': 'brooklyn-public-house-brooklyn',
#    'name': 'Brooklyn Public House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0zx7-jZ0bb4mMu5mTP1Tbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-public-house-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 325,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.68958, 'longitude': -73.96939},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '247 Dekalb Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['247 Dekalb Ave', 'Brooklyn, NY 11205']},
#    'phone': '+13472278976',
#    'display_phone': '(347) 227-8976',
#    'distance': 2738.4094534097794},
#   {'id': 'xd7ioU33jkwx0hQ3kUNIOg',
#    'alias': 'the-double-windsor-brooklyn',
#    'name': 'The Double Windsor',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eR8BDoxAHu73JZI-r7qLGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-double-windsor-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 427,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.66063, 'longitude': -73.98056},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '210 Prospect Park W',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['210 Prospect Park W', 'Brooklyn, NY 11215']},
#    'phone': '+13477253479',
#    'display_phone': '(347) 725-3479',
#    'distance': 5115.8390326932185},
#   {'id': '_edG68ufw52-v_xRL4jsyw',
#    'alias': 'prost-garden-city',
#    'name': 'Prost',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XEYE6gIBAcujaaio_LDbfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prost-garden-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 159,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72456, 'longitude': -73.63403},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '652 Franklin Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Garden City',
#     'zip_code': '11530',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['652 Franklin Ave', 'Garden City, NY 11530']},
#    'phone': '+15164275215',
#    'display_phone': '(516) 427-5215',
#    'distance': 30427.097404977365},
#   {'id': 'K5j_HFzkS5QAgX7cgIO8Gg',
#    'alias': 'dziupla-brooklyn',
#    'name': 'Dziupla',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TZ3_BFZUFCw8JU7XLRHw6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dziupla-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 228,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7174732, 'longitude': -73.9581543},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '194 Bedford Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['194 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17183886194',
#    'display_phone': '(718) 388-6194',
#    'distance': 3326.715912490438},
#   {'id': 'n9vGLAZhWiRGm-hWX6z7-A',
#    'alias': 'bunny-brooklyn',
#    'name': 'Bunny',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6jVnj_y6dD4aMXiwXf0aPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bunny-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68202, 'longitude': -73.94977},
#    'transactions': ['delivery'],
#    'location': {'address1': '449 Nostrand Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['449 Nostrand Ave', 'Brooklyn, NY 11216']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4563.554718231664},
#   {'id': '8o3j29PwIO1lzBLEbhvJlA',
#    'alias': 'carpe-diem-pub-and-restaurant-hoboken-2',
#    'name': 'Carpe Diem Pub & Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_9ZCWgV0ZscNbSXNNlonAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carpe-diem-pub-and-restaurant-hoboken-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 231,
#    'categories': [{'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7544589, 'longitude': -74.0312859},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1405 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1405 Grand St', 'Hoboken, NJ 07030']},
#    'phone': '+12017920050',
#    'display_phone': '(201) 792-0050',
#    'distance': 6278.251690314217},
#   {'id': 'lMy1BYJ5HX8TccXTBwdRNg',
#    'alias': 'covenhoven-brooklyn',
#    'name': 'Covenhoven',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QL24a3HEKWq_5MHt_m-i-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/covenhoven-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 139,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.675246, 'longitude': -73.960244},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '730 Classon Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['730 Classon Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17184839950',
#    'display_phone': '(718) 483-9950',
#    'distance': 4417.8365326838175},
#   {'id': 'qtFJ6T6-bO7IhOpgWb7XLg',
#    'alias': 'spuyten-duyvil-brooklyn',
#    'name': 'Spuyten Duyvil',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oriikyQNwB2Ij8R2FbiO3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spuyten-duyvil-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 374,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.714355, 'longitude': -73.955955},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '359 Metropolitan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['359 Metropolitan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17189634140',
#    'display_phone': '(718) 963-4140',
#    'distance': 3375.5807577253195},
#   {'id': '2lOF2K5CoZ1QqmfRNF_mcA',
#    'alias': 'ryans-daughter-new-york',
#    'name': "Ryan's Daughter",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4qIaZIp6ix0TF5Efdaks9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ryans-daughter-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 237,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77628, 'longitude': -73.95048},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '350 E 85th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['350 E 85th St', 'New York, NY 10028']},
#    'phone': '+12126282613',
#    'display_phone': '(212) 628-2613',
#    'distance': 8699.084655883518},
#   {'id': 'U30jm7WO7kK0l722lsmSQA',
#    'alias': 'deutscher-club-of-clark-clark',
#    'name': 'Deutscher Club of Clark',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/W7oQ8JWJjNPUB2UP0qX47A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/deutscher-club-of-clark-clark?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'social_clubs', 'title': 'Social Clubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.623, 'longitude': -74.32252},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '787 Featherbed Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'Clark',
#     'zip_code': '07066',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['787 Featherbed Ln', 'Clark, NJ 07066']},
#    'phone': '+17325748600',
#    'display_phone': '(732) 574-8600',
#    'distance': 29175.929648709338},
#   {'id': 'niXT7o9AcG18zC7KlaAEEA',
#    'alias': 'park-slope-ale-house-brooklyn-2',
#    'name': 'Park Slope Ale House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EMvksBw9fwqGZSvLpEApvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/park-slope-ale-house-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67061, 'longitude': -73.9819799},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '356 6th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['356 6th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187881756',
#    'display_phone': '(718) 788-1756',
#    'distance': 4007.505360732709},
#   {'id': 'Hc2KkfFWYnWYtL11_F40Ew',
#    'alias': 'brooklyn-ice-house-brooklyn',
#    'name': 'Brooklyn Ice House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZPgZWmntl0aSpqjyENwIIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-ice-house-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 230,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67919, 'longitude': -74.011099},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '318 Van Brunt St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['318 Van Brunt St', 'Brooklyn, NY 11231']},
#    'phone': '+17182221865',
#    'display_phone': '(718) 222-1865',
#    'distance': 3245.078076133803},
#   {'id': 'zWem2SAbFc7lIYR2y9DE0g',
#    'alias': 'harlem-public-new-york',
#    'name': 'Harlem Public',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7LGb-GvBPiqrN2uCY-6sew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harlem-public-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1038,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.828717774457,
#     'longitude': -73.9484412254424},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3612 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10031',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3612 Broadway', 'New York, NY 10031']},
#    'phone': '+12129399404',
#    'display_phone': '(212) 939-9404',
#    'distance': 14240.824372288782},
#   {'id': 'apFNQyii29KahceFL1znOw',
#    'alias': 'das-biergarten-long-beach',
#    'name': 'Das Biergarten',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DWdTnJ6a2wB80w11S6QpFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/das-biergarten-long-beach?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 71,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.5858084002527,
#     'longitude': -73.7034325955231},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1148 West Beech St',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Beach',
#     'zip_code': '11561',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1148 West Beech St', 'Long Beach, NY 11561']},
#    'phone': '+15168972437',
#    'display_phone': '(516) 897-2437',
#    'distance': 27913.536887019764},
#   {'id': '8vwANffgp9s9RDCSn3mD5w',
#    'alias': 'keg-and-lantern-brewing-company-brooklyn',
#    'name': 'Keg & Lantern Brewing Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MjkTGWY5zxD5d9gtCk0G_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/keg-and-lantern-brewing-company-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 273,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'brewpubs', 'title': 'Brewpubs'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.724054, 'longitude': -73.950341},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '97 Nassau Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['97 Nassau Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183895050',
#    'display_phone': '(718) 389-5050',
#    'distance': 4243.131078510608},
#   {'id': 'eaV_aUOFJPsG7wRbzr6M9Q',
#    'alias': 'hudson-hall-jersey-city',
#    'name': 'Hudson Hall',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/q57QbZW0JIbCmjjVrug1YA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hudson-hall-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 241,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'smokehouse', 'title': 'Smokehouse'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72127, 'longitude': -74.04082},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '364 Marin Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['364 Marin Blvd', 'Jersey City, NJ 07302']},
#    'phone': '+12016596565',
#    'display_phone': '(201) 659-6565',
#    'distance': 4298.163920408219},
#   {'id': 'coqbYAvtuzw0-wc5egBpJA',
#    'alias': 'consulate-general-of-germany-new-york',
#    'name': 'Consulate General of Germany',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fuot22smzB0XM-Y0_JCJGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/consulate-general-of-germany-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.753192, 'longitude': -73.967063},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '871 United Nations Plz',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['871 United Nations Plz', 'New York, NY 10017']},
#    'phone': '+12126109700',
#    'display_phone': '(212) 610-9700',
#    'distance': 5799.5701445526065},
#   {'id': 'hPJ7x8rfSsJ4ObgHeAK5kg',
#    'alias': 'greenwood-park-brooklyn',
#    'name': 'Greenwood Park',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lIoaKrYcy3_76AAiyiM2CA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greenwood-park-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 452,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.659353, 'longitude': -73.987894},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '555 7th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['555 7th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17184997999',
#    'display_phone': '(718) 499-7999',
#    'distance': 5153.5031869986915},
#   {'id': 'UQGwXsOt9u0uZX0bY6j1kw',
#    'alias': 'kirsh-bakery-and-kitchen-new-york',
#    'name': 'Kirsh Bakery & Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/l6LN1i5ncLb9liE2wAP1uw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kirsh-bakery-and-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 284,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7879297, 'longitude': -73.9746239},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '551 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['551 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12129511123',
#    'display_phone': '(212) 951-1123',
#    'distance': 9342.111502897553},
#   {'id': 'uCsyRxfIfiRqQQuK_JlfZA',
#    'alias': 'harlem-tavern-new-york-2',
#    'name': 'Harlem Tavern',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/H6XLSHrP5LtyjFgz6mPGRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harlem-tavern-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1300,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.8046999, 'longitude': -73.95558},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2153 Frederick Douglass Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10026',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2153 Frederick Douglass Blvd', 'New York, NY 10026']},
#    'phone': '+12128664500',
#    'display_phone': '(212) 866-4500',
#    'distance': 11509.484743328916},
#   {'id': 'i34wlziIjT8lHgUN1o0ToQ',
#    'alias': 'the-shakespeare-new-york',
#    'name': 'The Shakespeare',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/01zB53rsuOTzFqu4FbfPog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-shakespeare-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 361,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7506062, 'longitude': -73.9801755},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '24 E 39th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 E 39th St', 'New York, NY 10016']},
#    'phone': '+16468376779',
#    'display_phone': '(646) 837-6779',
#    'distance': 5160.692836404028},
#   {'id': 'x41gFmTksra32RdYFjOPHQ',
#    'alias': 'uncle-barrys-brooklyn',
#    'name': "Uncle Barry's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/F16jy6gS-McMjbn9KGGp0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uncle-barrys-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 124,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6812759, 'longitude': -73.9773854},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '58 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['58 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17186224980',
#    'display_phone': '(718) 622-4980',
#    'distance': 3042.1134321055815},
#   {'id': 'TikAlBfPzWZQ9h5yk8Mmdg',
#    'alias': 'cronin-and-phelans-astoria',
#    'name': "Cronin & Phelan's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/l5BnaiT8QoeldCldNkTQWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cronin-and-phelans-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 211,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'irish', 'title': 'Irish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7589, 'longitude': -73.91941},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '38-14 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38-14 Broadway', 'Astoria, NY 11103']},
#    'phone': '+17185458999',
#    'display_phone': '(718) 545-8999',
#    'distance': 8675.497009363213},
#   {'id': '-7PnG_cD9VY-IfHGWzynmQ',
#    'alias': 'ainslie-brooklyn-2',
#    'name': 'Ainslie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x4PdlWcrz3lzNg1WTWEhHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ainslie-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 322,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.712343, 'longitude': -73.952121},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '76 Ainslie St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['76 Ainslie St', 'Brooklyn, NY 11211']},
#    'phone': '+13477253400',
#    'display_phone': '(347) 725-3400',
#    'distance': 3636.4832270704437},
#   {'id': 'J6WUjE6i1vAJFVKEdUtupQ',
#    'alias': 'cork-city-hoboken',
#    'name': 'Cork City',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rzij6DM_GDFLJ_AKvUD5kA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cork-city-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 118,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74, 'longitude': -74.03077},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '239 Bloomfield St',
#     'address2': 'Ste A',
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['239 Bloomfield St', 'Ste A', 'Hoboken, NJ 07030']},
#    'phone': '+12019635512',
#    'display_phone': '(201) 963-5512',
#    'distance': 4921.432539009519},
#   {'id': '9cCqoVpwU1x53m2GMMv6-g',
#    'alias': 'brussels-beer-cafe-kuala-lumpur-2',
#    'name': 'Brussels Beer Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jIvm8lPrBdhAiCbDNL0L-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brussels-beer-cafe-kuala-lumpur-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 3.17488, 'longitude': 101.6595383},
#    'transactions': [],
#    'location': {'address1': "Lot K-OG 13 & 14, SoHo No. Mon't Kiara, 2, Jalan Solaris 3",
#     'address2': 'Mont Kiara',
#     'address3': '',
#     'city': 'Kuala Lumpur',
#     'zip_code': '50480',
#     'country': 'MY',
#     'state': '14',
#     'display_address': ["Lot K-OG 13 & 14, SoHo No. Mon't Kiara, 2, Jalan Solaris 3",
#      'Mont Kiara',
#      '50480 Kuala Lumpur',
#      'Malaysia']},
#    'phone': '+60362052999',
#    'display_phone': '+60 3-6205 2999',
#    'distance': 2116.437229910425},
#   {'id': '3004g82RXwKoqaenSqBVEg',
#    'alias': 'george-keeley-new-york',
#    'name': 'George Keeley',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/--FTdpuZUUJib2nAkhbx4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/george-keeley-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 326,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7858376, 'longitude': -73.975986},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '485 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['485 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12128730251',
#    'display_phone': '(212) 873-0251',
#    'distance': 9071.317801871306},
#   {'id': 'IvcoTrvUdlhtpp2_pn_rAA',
#    'alias': 'omonia-cafe-brooklyn-3',
#    'name': 'Omonia Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DptaFN8glAnB_LOn7Uu83g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/omonia-cafe-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 356,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.63045, 'longitude': -74.0284999},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '7612 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7612 3rd Ave', 'Brooklyn, NY 11209']},
#    'phone': '+17184911435',
#    'display_phone': '(718) 491-1435',
#    'distance': 8823.098078991618},
#   {'id': 'NTwOc9yQ1xl5deeVzZqxfw',
#    'alias': 'tavern29-new-york',
#    'name': 'Tavern29',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/i4-L6ynQSj3awI_DDngaDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tavern29-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 948,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74431, 'longitude': -73.98394},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '47 E 29th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 E 29th St', 'New York, NY 10016']},
#    'phone': '+12126854422',
#    'display_phone': '(212) 685-4422',
#    'distance': 4405.322562505105},
#   {'id': 'Z65cd3Z7JvwK8TnSVg-cfA',
#    'alias': 'district-tap-house-new-york',
#    'name': 'District Tap House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aF7gvHMB9zlruGZf7cP2Ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/district-tap-house-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 824,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75409, 'longitude': -73.99039},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '246 W 38th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['246 W 38th St', 'New York, NY 10018']},
#    'phone': '+12122211822',
#    'display_phone': '(212) 221-1822',
#    'distance': 5412.960609159312},
#   {'id': '4NjA3ySK_nxw2N2k7LIGeg',
#    'alias': 'killmeyers-staten-island',
#    'name': "Killmeyer's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9cwpeWT3bYA90n45MVARzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/killmeyers-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 136,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.5384699, 'longitude': -74.23721},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4254 Arthur Kill Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10309',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4254 Arthur Kill Rd', 'Staten Island, NY 10309']},
#    'phone': '+17189841202',
#    'display_phone': '(718) 984-1202',
#    'distance': 27658.90671141389},
#   {'id': 'VFaHfWhyNb66yQAuiB1S-A',
#    'alias': 'manor-oktoberfest-atlas-park-glendale',
#    'name': 'Manor Oktoberfest Atlas Park',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UuWYAaNNiSP5t1rhIGIhvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/manor-oktoberfest-atlas-park-glendale?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 99,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.708147, 'longitude': -73.868222},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '8028 Cooper Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Glendale',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8028 Cooper Ave', 'Glendale, NY 11385']},
#    'phone': '+17183262201',
#    'display_phone': '(718) 326-2201',
#    'distance': 10631.04024568511},
#   {'id': 'hK14kghcSPkljAqzEHNemA',
#    'alias': 'sugarburg-brooklyn',
#    'name': 'Sugarburg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/c971aXTMDOz38jN_IuLZOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sugarburg-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 324,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7141182158499,
#     'longitude': -73.9516061916947},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '519 Metropolitan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['519 Metropolitan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+19176183029',
#    'display_phone': '(917) 618-3029',
#    'distance': 3725.026878059134},
#   {'id': 'BDM5u5RodeZbElVo_iRdXQ',
#    'alias': 'the-red-lion-new-york',
#    'name': 'The Red Lion',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Dw8R21V5NdxQ_osa4TcPhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-red-lion-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 345,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72843, 'longitude': -73.99945},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '151 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['151 Bleecker St', 'New York, NY 10012']},
#    'phone': '+12122609797',
#    'display_phone': '(212) 260-9797',
#    'distance': 2605.6037849793493},
#   {'id': 'IFQ1CXX3QTiuOjeXYvtWLw',
#    'alias': 'frankie-and-johnnies-steakhouse-new-york-4',
#    'name': "Frankie & Johnnie's Steakhouse",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2rvtdAHspvjegcGk70pKdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frankie-and-johnnies-steakhouse-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 265,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.759956, 'longitude': -73.988926},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '320 W 46th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['320 W 46th St', 'New York, NY 10036']},
#    'phone': '+12129979494',
#    'display_phone': '(212) 997-9494',
#    'distance': 6078.202259885694},
#   {'id': '96zQLCoZ66Nbu-w1ddetqQ',
#    'alias': 'duffys-tavern-staten-island',
#    'name': "Duffy's Tavern",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CPwEtIWtOzV_rHcYfVerzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duffys-tavern-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 135,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'irish', 'title': 'Irish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.62966, 'longitude': -74.11079},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '650 Forest Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10314',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['650 Forest Ave', 'Staten Island, NY 10314']},
#    'phone': '+17184479276',
#    'display_phone': '(718) 447-9276',
#    'distance': 12949.664847854274}],
#  'total': 181,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                    Restaurant                    Type Price Rating  \
# 0              North Pole Pub                    Pubs    $$      5
# 1       Blind Tiger Ale House  American (Traditional)    $$      4
# 2  Kotti Berliner Döner Kebab                   Kebab    $$    4.5
# 3             Café Fledermaus            Coffee & Tea    $$    3.5
# 4                  Bierocracy            Beer Gardens    $$      4
#
#              Address        Lat        Lng  \
# 0      428 Bergen St  40.681540 -73.977400
# 1    281 Bleecker St  40.731926 -74.003223
# 2        220 36th St  40.656290 -74.008070
# 3       1048 5th Ave  40.781242 -73.960250
# 4  12-23 Jackson Ave  40.744020 -73.950280
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/north-pole-pub-brookl...  uVimnyjMcc7MOGzd2NRX-w
# 1  https://www.yelp.com/biz/blind-tiger-ale-house...  PMp7WlHIXQUnej-Ds1jRfw
# 2  https://www.yelp.com/biz/kotti-berliner-d%C3%B...  PbxDOYOjYobnHFEH6I8PuQ
# 3  https://www.yelp.com/biz/caf%C3%A9-fledermaus-...  w7G1r4v1YIN-ggIB9p7z9w
# 4  https://www.yelp.com/biz/bierocracy-long-islan...  5grFfuYswh8K9GoEnOy81A

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"german","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': 'Xkz2uUnAM2ckYIUqxI0NPw',
#    'alias': 'cobblestones-pub-and-biergarten-forest-hills',
#    'name': 'Cobblestones Pub and Biergarten',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JniJfFIuswOFMRDhvQO1dQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cobblestones-pub-and-biergarten-forest-hills?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 272,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7150622, 'longitude': -73.8327231},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '11718 Queens Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11718 Queens Blvd', 'Forest Hills, NY 11375']},
#    'phone': '+17182639754',
#    'display_phone': '(718) 263-9754',
#    'distance': 13657.887813158739},
#   {'id': '2O5w-15_AVnnVJEtlWWE_A',
#    'alias': 'clinton-hall-bronx-4',
#    'name': 'Clinton Hall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lneg4MLQMpq4UJ-jCVWSPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clinton-hall-bronx-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 183,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.85735, 'longitude': -73.88574},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '601 E 189th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10458',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['601 E 189th St', 'Bronx, NY 10458']},
#    'phone': '+17182206400',
#    'display_phone': '(718) 220-6400',
#    'distance': 19211.098766323194},
#   {'id': 'ibTjqHbbBqctjzJLtyUmRw',
#    'alias': 'draft-barn-brooklyn-3',
#    'name': 'Draft Barn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1sawHdaCzu92ZlyGAcLOkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/draft-barn-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.59056, 'longitude': -73.97133},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '317 Ave X',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11223',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['317 Ave X', 'Brooklyn, NY 11223']},
#    'phone': '+17182852356',
#    'display_phone': '(718) 285-2356',
#    'distance': 12912.437646493303},
#   {'id': '2LRg0V0K1iG6JqIvCND5kg',
#    'alias': 'peculier-pub-new-york',
#    'name': 'Peculier Pub',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6RMkfSwLnLfcHza01_7ChQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peculier-pub-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 411,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72837, 'longitude': -73.99906},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '145 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['145 Bleecker St', 'New York, NY 10012']},
#    'phone': '+12123531327',
#    'display_phone': '(212) 353-1327',
#    'distance': 2577.784748794897},
#   {'id': 'qao8HE4BD8qW5A6aAgHodQ',
#    'alias': 'christkindl-markt-franklin-square',
#    'name': 'Christkindl Markt',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y5eNXMHlDeDp1OEXrDHJyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/christkindl-markt-franklin-square?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7085337815478,
#     'longitude': -73.6821346027437},
#    'transactions': [],
#    'location': {'address1': '1132 Hempstead Tpke',
#     'address2': '',
#     'address3': 'Plattdeutsche Park',
#     'city': 'Franklin Square',
#     'zip_code': '11010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1132 Hempstead Tpke',
#      'Plattdeutsche Park',
#      'Franklin Square, NY 11010']},
#    'phone': '+15163543131',
#    'display_phone': '(516) 354-3131',
#    'distance': 26314.624138551248},
#   {'id': 'pQuZDnefX038xurT1BhDXA',
#    'alias': 'keens-steakhouse-new-york',
#    'name': 'Keens Steakhouse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4aZmVaA2EUXrgWkA5xq-NA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/keens-steakhouse-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2672,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75071, 'longitude': -73.98652},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '72 W 36th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['72 W 36th St', 'New York, NY 10018']},
#    'phone': '+12129473636',
#    'display_phone': '(212) 947-3636',
#    'distance': 5071.689036489537},
#   {'id': '2R6owNuekbOaLudU5U8y7w',
#    'alias': 'sean-og-tavern-woodside',
#    'name': 'Sean Og Tavern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Z2C3My5nKG7fnXNE-sUiYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sean-og-tavern-woodside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 144,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74481, 'longitude': -73.90424},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '6002 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6002 Woodside Ave', 'Woodside, NY 11377']},
#    'phone': '+17188993499',
#    'display_phone': '(718) 899-3499',
#    'distance': 8759.915735176446},
#   {'id': 'bfswNnIxzJrSr06MjsXJ3g',
#    'alias': 'schallers-stube-brooklyn',
#    'name': "Schaller's Stube",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gKbky2wqsXMfuOVAqykyQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/schallers-stube-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.691005, 'longitude': -73.982934},
#    'transactions': [],
#    'location': {'address1': '445 Albee Square W',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['445 Albee Square W', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1868.4980548111632},
#   {'id': 'uo6cbaGSBlmmZIXhBjRa9w',
#    'alias': 'bahrs-landing-restaurant-highlands-3',
#    'name': 'Bahrs Landing Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/u8ilVDF_oOYJoiyIEuahCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bahrs-landing-restaurant-highlands-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 515,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.39739, 'longitude': -73.981339},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2 Bay Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Highlands',
#     'zip_code': '07732',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['2 Bay Ave', 'Highlands, NJ 07732']},
#    'phone': '+17328721245',
#    'display_phone': '(732) 872-1245',
#    'distance': 34271.5807717496},
#   {'id': 'ciHt5n5rmpby1YcC_6JVrg',
#    'alias': 'bronx-alehouse-bronx-2',
#    'name': 'Bronx Alehouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6FQ3Ej0DroZKwmAYclZkeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bronx-alehouse-bronx-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 846,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8846317, 'longitude': -73.899705},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '216 W 238th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10463',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['216 W 238th St', 'Bronx, NY 10463']},
#    'phone': '+17186010204',
#    'display_phone': '(718) 601-0204',
#    'distance': 21456.747169575447},
#   {'id': '8QVodl0JGDNyJmtBa8hChA',
#    'alias': 'redds-restaurant-and-biergarten-carlstadt-2',
#    'name': 'Redds Restaurant & Biergarten',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/U3LjyrrkIKx9YEgA8NLupw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/redds-restaurant-and-biergarten-carlstadt-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 143,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.817331, 'longitude': -74.065861},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '317 Washington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Carlstadt',
#     'zip_code': '07072',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['317 Washington Ave', 'Carlstadt, NJ 07072']},
#    'phone': '+12019330015',
#    'display_phone': '(201) 933-0015',
#    'distance': 13824.428885718326},
#   {'id': 'QRf4pu36mJYUKFRVfdGOEg',
#    'alias': 'andaz-kitchen-and-bar-new-york-2',
#    'name': 'Andaz Kitchen & Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AyPOlN0ZzOBRI1MeEfXejw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/andaz-kitchen-and-bar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.7050399, 'longitude': -74.00812},
#    'transactions': [],
#    'location': {'address1': '75 Wall St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 Wall St', 'New York, NY 10005']},
#    'phone': '+12125901234',
#    'display_phone': '(212) 590-1234',
#    'distance': 1157.8274591113147},
#   {'id': 'ydoGxUTN9adaJ90lviuE3A',
#    'alias': 'cooper-beer-garden-glendale',
#    'name': 'Cooper Beer Garden',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FxjAQpOTYttYl6RngTGFuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cooper-beer-garden-glendale?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7090866, 'longitude': -73.8684157},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '8000 Cooper Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Glendale',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8000 Cooper Ave', 'Glendale, NY 11385']},
#    'phone': '+17183262199',
#    'display_phone': '(718) 326-2199',
#    'distance': 10618.11564083391},
#   {'id': 'TK1rbgBEPQWyxF4pu973oQ',
#    'alias': 'chriss-restaurant-brooklyn',
#    'name': "Chris's Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TW4PhHyRkFhHTufB_D4fgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chriss-restaurant-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 76,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.60617, 'longitude': -74.00116},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1866 86th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1866 86th St', 'Brooklyn, NY 11214']},
#    'phone': '+13474623755',
#    'display_phone': '(347) 462-3755',
#    'distance': 11060.54691640379},
#   {'id': 'cO7x8sT6qq9TkVeqU3VXSw',
#    'alias': 'morschers-pork-store-ridgewood',
#    'name': "Morscher's Pork Store",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/df_uOA1hP5BIf38fBKjVWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/morschers-pork-store-ridgewood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'},
#     {'alias': 'butcher', 'title': 'Butcher'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7020797729492,
#     'longitude': -73.9014205932617},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '5844 Catalpa Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5844 Catalpa Ave', 'Ridgewood, NY 11385']},
#    'phone': '+17188211040',
#    'display_phone': '(718) 821-1040',
#    'distance': 7834.351109990516},
#   {'id': 'jJfCbhEnI5PMPW_vS-Pp6g',
#    'alias': 'black-rabbit-brooklyn',
#    'name': 'Black Rabbit',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y4buPzv_EkfFxZN4GZwr5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-rabbit-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 178,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7301408235242,
#     'longitude': -73.9563193070954},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '91 Greenpoint Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['91 Greenpoint Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183491595',
#    'display_phone': '(718) 349-1595',
#    'distance': 4217.014499488315},
#   {'id': 'Hp1ZDTeJOP1NrY2aFtROgQ',
#    'alias': 'woodbines-long-island-city',
#    'name': 'Woodbines',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qKT9T0L4ojYVi269vYSlVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/woodbines-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 326,
#    'categories': [{'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.745216, 'longitude': -73.95357},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '47-10 Vernon Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47-10 Vernon Blvd', 'Long Island City, NY 11101']},
#    'phone': '+17183618488',
#    'display_phone': '(718) 361-8488',
#    'distance': 5597.641114477878},
#   {'id': 'zEHzdRjEa23tcH585_SqHw',
#    'alias': 'the-bronx-beer-hall-bronx',
#    'name': 'The Bronx Beer Hall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/s22XuH25877NGrsPNfQhAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bronx-beer-hall-bronx?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 151,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.854118, 'longitude': -73.888175},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2344 Arthur Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10458',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2344 Arthur Ave', 'Bronx, NY 10458']},
#    'phone': '+13473960555',
#    'display_phone': '(347) 396-0555',
#    'distance': 18796.552253349215},
#   {'id': 'CslkgF_rqwHlx8vneUSO_g',
#    'alias': 'kabaret-restaurant-spotswood',
#    'name': 'Kabaret Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FLqR_e7YeE8HJ7WD0mz_-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kabaret-restaurant-spotswood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.397203, 'longitude': -74.385118},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '100 Summerhill Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Spotswood',
#     'zip_code': '08884',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['100 Summerhill Rd', 'Spotswood, NJ 08884']},
#    'phone': '+17327230200',
#    'display_phone': '(732) 723-0200',
#    'distance': 47570.52993951495},
#   {'id': 'KAWZ2Msx0fbRhN1W4_cggw',
#    'alias': 'o-haras-downtown-jersey-city',
#    'name': "O'Hara's Downtown",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MW6WjsC8-ZL1nsxblcQ54A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/o-haras-downtown-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 257,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7215259224176,
#     'longitude': -74.0408027172089},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '172 1st St',
#     'address2': None,
#     'address3': None,
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['172 1st St', 'Jersey City, NJ 07302']},
#    'phone': '+12012397373',
#    'display_phone': '(201) 239-7373',
#    'distance': 4319.795144621022},
#   {'id': 'Xy5zmV2va1RTgnqyakfMnQ',
#    'alias': 'gruit-brooklyn',
#    'name': 'Gruit',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zmHRicaJtSvTrx885IXQ9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gruit-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'kosher', 'title': 'Kosher'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.663465879123,
#     'longitude': -73.9536466271922},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '252 Empire Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11225',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['252 Empire Blvd', 'Brooklyn, NY 11225']},
#    'phone': '+13478460622',
#    'display_phone': '(347) 846-0622',
#    'distance': 5790.973395592829},
#   {'id': 'gJmJDwrDUHy--3qS9qQFYA',
#    'alias': 'blackbirds-bar-and-restaurant-astoria-2',
#    'name': "Blackbird's Bar & Restaurant",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/x8HZmkbyhNQqL8q8V1Ivzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blackbirds-bar-and-restaurant-astoria-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 266,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76341, 'longitude': -73.91335},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '41-19 30th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41-19 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17189436899',
#    'display_phone': '(718) 943-6899',
#    'distance': 9383.214166404543},
#   {'id': 'pffG9Ciyks5Xik7opl2bEw',
#    'alias': 'phebes-new-york',
#    'name': "Phebe's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_oizhlXL8e_8ldLtFNn9ug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/phebes-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 583,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72681, 'longitude': -73.9912901},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '359 Bowery',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['359 Bowery', 'New York, NY 10003']},
#    'phone': '+12123581902',
#    'display_phone': '(212) 358-1902',
#    'distance': 2389.136617549521},
#   {'id': 'Ayx5XNT7i79TUjbHTTC5YQ',
#    'alias': 'waterfront-ale-house-new-york',
#    'name': 'Waterfront Ale House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7ahyxROwE3d_oaptrKseBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/waterfront-ale-house-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 281,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74204, 'longitude': -73.9775},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '540 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['540 2nd Ave', 'New York, NY 10016']},
#    'phone': '+12126964104',
#    'display_phone': '(212) 696-4104',
#    'distance': 4308.868304635837},
#   {'id': 'RBkz0yuQfs_5ExPhL-6jpg',
#    'alias': 'slainte-bar-and-lounge-new-york',
#    'name': 'Slainte Bar & Lounge',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cvI6vjPFy5ENIY3Zt5ZFKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/slainte-bar-and-lounge-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 240,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'irish', 'title': 'Irish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.724811, 'longitude': -73.992832},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '304 Bowery',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['304 Bowery', 'New York, NY 10012']},
#    'phone': '+12122537030',
#    'display_phone': '(212) 253-7030',
#    'distance': 2156.9323064841687},
#   {'id': 'qRyQ-wXLjEVUhkbHGGQ7hQ',
#    'alias': 'langos-bar-new-york',
#    'name': 'Langos Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-kvzTcrqyXse9nqPdxqveg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/langos-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'hungarian', 'title': 'Hungarian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71943592077994,
#     'longitude': -73.98645678677418},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '137 Rivington St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['137 Rivington St', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1690.1343478275614},
#   {'id': 'j_cpaoMtVJ26i6YPUB04EA',
#    'alias': 'clinton-hall-and-rooftop-beer-garden-brooklyn',
#    'name': 'Clinton Hall & Rooftop Beer Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hj3LLggDVjP_XoFqL3ht2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clinton-hall-and-rooftop-beer-garden-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 152,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71502, 'longitude': -73.95903},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '247 Metropolitan Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['247 Metropolitan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+19294196988',
#    'display_phone': '(929) 419-6988',
#    'distance': 3159.860915550328},
#   {'id': '8jurzw-RyloFCYpuGXdzFA',
#    'alias': 'east-river-bar-brooklyn',
#    'name': 'East River Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VKx0FhRjiJWYfuvPABKdig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/east-river-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 85,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7109413146973,
#     'longitude': -73.9646453857422},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '97 S 6th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['97 S 6th St', 'Brooklyn, NY 11211']},
#    'phone': '+17183020511',
#    'display_phone': '(718) 302-0511',
#    'distance': 2572.2987457275603},
#   {'id': '28q-EaDlKgYNeaF7-LXXqg',
#    'alias': 'lavender-lake-brooklyn',
#    'name': 'Lavender Lake',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xc720iC989jRcGHjWhMaqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lavender-lake-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 279,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6786075, 'longitude': -73.9901923},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '383 Carroll St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['383 Carroll St', 'Brooklyn, NY 11231']},
#    'phone': '+13477992154',
#    'display_phone': '(347) 799-2154',
#    'distance': 3004.138276609909},
#   {'id': 'Sz2_SDk8ttk1FT6UHqUtrA',
#    'alias': 'abigails-restaurant-linden-3',
#    'name': 'Abigails Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RVyJQqe4MYjjqG8HZpHtfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/abigails-restaurant-linden-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 296,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.625845, 'longitude': -74.25772247323548},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '804 W Elizabeth Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Linden',
#     'zip_code': '07036',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['804 W Elizabeth Ave', 'Linden, NJ 07036']},
#    'phone': '+19085230777',
#    'display_phone': '(908) 523-0777',
#    'distance': 23916.76265987107},
#   {'id': 'ULF7NqOo2VWrxMs_hkYgCQ',
#    'alias': 'tracks-raw-bar-and-grill-new-york-2',
#    'name': 'Tracks Raw Bar & Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FTSb4NtIoUJxvHr2SbPDxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tracks-raw-bar-and-grill-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 283,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7505086580734,
#     'longitude': -73.9935086600351},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '220 West 31st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['220 West 31st St', 'New York, NY 10001']},
#    'phone': '+12122446736',
#    'display_phone': '(212) 244-6736',
#    'distance': 5011.295762583591},
#   {'id': 'StN5iogEjup2MWAzwaGDig',
#    'alias': 'royal-warsaw-restaurant-elmwood-park',
#    'name': 'Royal Warsaw Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LJyfS5gdpkjk4EsTE6M4wg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/royal-warsaw-restaurant-elmwood-park?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 248,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.89127, 'longitude': -74.12705},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '871 River Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmwood Park',
#     'zip_code': '07407',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['871 River Dr', 'Elmwood Park, NJ 07407']},
#    'phone': '+12017949277',
#    'display_phone': '(201) 794-9277',
#    'distance': 23497.043326163577},
#   {'id': 'hN3fiSltPQ8G6YJQLSz5xw',
#    'alias': 'katch-astoria-astoria-2',
#    'name': 'Katch Astoria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/emAFOpmwXCFjC8Fpjh4LKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/katch-astoria-astoria-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 454,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7671716, 'longitude': -73.9202752},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '31-19 Newtown Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31-19 Newtown Ave', 'Astoria, NY 11102']},
#    'phone': '+17187772230',
#    'display_phone': '(718) 777-2230',
#    'distance': 9278.41039489296},
#   {'id': 'FsnUZsbsFuxOKJUPOubS5Q',
#    'alias': 'croxleys-ale-franklin-square-franklin-square',
#    'name': "Croxley's Ale - Franklin Square",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m3bvDxGfdnsSXL8n_HH4bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/croxleys-ale-franklin-square-franklin-square?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 305,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7109012, 'longitude': -73.67648877054795},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '129 New Hyde Park Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Franklin Square',
#     'zip_code': '11010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['129 New Hyde Park Rd', 'Franklin Square, NY 11010']},
#    'phone': '+15163269542',
#    'display_phone': '(516) 326-9542',
#    'distance': 26794.67247947233},
#   {'id': 'eXnKDfRkhsPx7iXCy-3GzQ',
#    'alias': 'cloverleaf-tavern-caldwell',
#    'name': 'Cloverleaf Tavern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FEGCjBbUlwOkVOJETuz8jQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cloverleaf-tavern-caldwell?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 766,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.84131, 'longitude': -74.27851},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '395 Bloomfield Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Caldwell',
#     'zip_code': '07006',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['395 Bloomfield Ave', 'Caldwell, NJ 07006']},
#    'phone': '+19732269812',
#    'display_phone': '(973) 226-9812',
#    'distance': 28279.669929690433},
#   {'id': 'yoFyoSRA49aczkp4tHOn1A',
#    'alias': 'blue-ribbon-kanpai-garden-new-york-3',
#    'name': 'Blue Ribbon Kanpai Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/D6XUdZFuVxoQZr3UcKyv6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-ribbon-kanpai-garden-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7221598180322,
#     'longitude': -73.9885377783264},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '190 Allen St',
#     'address2': '2nd Floor, Sixty LES Hotel',
#     'address3': 'Fl 2 Ter',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['190 Allen St',
#      '2nd Floor, Sixty LES Hotel',
#      'Fl 2 Ter',
#      'New York, NY 10002']},
#    'phone': '+12124660404',
#    'display_phone': '(212) 466-0404',
#    'distance': 1920.8752693494423},
#   {'id': 'bUD3Y-uo8RSBlHMR8tN3wQ',
#    'alias': 'alex-and-terrys-deli-bayonne',
#    'name': "Alex & Terry's Deli",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EBW24w87qja755qmIXDarg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alex-and-terrys-deli-bayonne?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67437, 'longitude': -74.1091299},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '798 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Bayonne',
#     'zip_code': '07002',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['798 Broadway', 'Bayonne, NJ 07002']},
#    'phone': '+12014363525',
#    'display_phone': '(201) 436-3525',
#    'distance': 10278.886485765523},
#   {'id': 'AxpsI4_tOI0sM6-KfOY9ig',
#    'alias': 'auntie-annes-pretzels-rego-park-2',
#    'name': "Auntie Anne's Pretzels",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/x28Pq_9QKeByj6sbTZvosw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auntie-annes-pretzels-rego-park-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.733178, 'longitude': -73.862651},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '61-35 Junction Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['61-35 Junction Blvd', 'Rego Park, NY 11374']},
#    'phone': '+17186991643',
#    'display_phone': '(718) 699-1643',
#    'distance': 11514.90997946917},
#   {'id': 'BmOvutFlEYKlfyJRXphqLA',
#    'alias': 'the-front-porch-hawthorne',
#    'name': 'The Front Porch',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jnuS3N3uLAs-AcTHptdfqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-front-porch-hawthorne?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 248,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.94103, 'longitude': -74.15691},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '217 Wagaraw Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Hawthorne',
#     'zip_code': '07506',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['217 Wagaraw Rd', 'Hawthorne, NJ 07506']},
#    'phone': '+19733103828',
#    'display_phone': '(973) 310-3828',
#    'distance': 29492.757733914048},
#   {'id': 'mZV4nRj9XfNIAJc4RPLOzg',
#    'alias': 'kirvens-bronx',
#    'name': 'Kirvens',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9TVKraU_nzX6E6WD0qBggg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kirvens-bronx?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.85439, 'longitude': -73.8663897},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '736 Lydig Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Bronx',
#     'zip_code': '10462',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['736 Lydig Ave', 'Bronx, NY 10462']},
#    'phone': '+13473980792',
#    'display_phone': '(347) 398-0792',
#    'distance': 19755.43026022187},
#   {'id': 'SBLoGGk936tFHg0gYSZ-ow',
#    'alias': 'kent-ale-house-brooklyn',
#    'name': 'Kent Ale House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/if-xMQCIGEVmXBSbUJIvXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kent-ale-house-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 179,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7223281860352,
#     'longitude': -73.9592514038086},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '51 Kent Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['51 Kent Ave', 'Brooklyn, NY 11249']},
#    'phone': '+13472278624',
#    'display_phone': '(347) 227-8624',
#    'distance': 3497.2903432486546},
#   {'id': 'EkQAH2HOwl7NAW0YJD2bHQ',
#    'alias': 'the-wicked-wolf-bronx',
#    'name': 'The Wicked Wolf',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eT56VDJQNoLFrYLkNCmkbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wicked-wolf-bronx?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 100,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'german', 'title': 'German'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.81967, 'longitude': -73.81739},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '4029 E Tremont Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10465',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4029 E Tremont Ave', 'Bronx, NY 10465']},
#    'phone': '+17188294400',
#    'display_phone': '(718) 829-4400',
#    'distance': 19587.80438499678},
#   {'id': '_OzfOh1aJM4PFCG-qpVknQ',
#    'alias': 'omonia-cafe-astoria-astoria',
#    'name': 'Omonia Cafe - Astoria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wfLsR5V-v2OMMYkelhW0sQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/omonia-cafe-astoria-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 663,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7611121, 'longitude': -73.9240205},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '32-20 Broadway',
#     'address2': None,
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32-20 Broadway', 'Astoria, NY 11106']},
#    'phone': '+17182746650',
#    'display_phone': '(718) 274-6650',
#    'distance': 8565.863990585687},
#   {'id': 'fzmFfXyQiCVgz4uSgz8yzw',
#    'alias': 'maloneys-pub-and-grill-matawan',
#    'name': "Maloney's Pub & Grill",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DZScKJjDptS1AQ-E9p9o6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maloneys-pub-and-grill-matawan?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 333,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.4153497796215,
#     'longitude': -74.2289780866008},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '119 Main St',
#     'address2': None,
#     'address3': None,
#     'city': 'Matawan',
#     'zip_code': '07747',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['119 Main St', 'Matawan, NJ 07747']},
#    'phone': '+17325834040',
#    'display_phone': '(732) 583-4040',
#    'distance': 37862.44835527153},
#   {'id': 'YFaL6GRCX-0rcjii4rG76Q',
#    'alias': 'craft-kitchen-and-taphouse-lynbrook',
#    'name': 'Craft Kitchen & Taphouse',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vdmY_jjqNFb0T4ZIwDijqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/craft-kitchen-and-taphouse-lynbrook?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 172,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.655737, 'longitude': -73.672153},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '44 Stauderman Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Lynbrook',
#     'zip_code': '11563',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['44 Stauderman Ave', 'Lynbrook, NY 11563']},
#    'phone': '+15163410547',
#    'display_phone': '(516) 341-0547',
#    'distance': 27721.12809276512},
#   {'id': 'umDSO3r5_E9HfGR5QQij3g',
#    'alias': 'mcquades-neighborhood-grill-lynbrook',
#    'name': 'McQuades Neighborhood Grill',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JFAx04yuWGMjk0gzO3yuiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mcquades-neighborhood-grill-lynbrook?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 123,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.65756, 'longitude': -73.67012},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '275 Merrick Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Lynbrook',
#     'zip_code': '11563',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['275 Merrick Rd', 'Lynbrook, NY 11563']},
#    'phone': '+15162562820',
#    'display_phone': '(516) 256-2820',
#    'distance': 27848.436903390666},
#   {'id': 'ChN0Bi-RGzq97jld3Y05Vg',
#    'alias': 'andys-corner-bar-bogota',
#    'name': "Andy's Corner Bar",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-qUFv2xojHF6U1QzQiMDWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/andys-corner-bar-bogota?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.872783, 'longitude': -74.021224},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '257 Queen Anne Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bogota',
#     'zip_code': '07603',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['257 Queen Anne Rd', 'Bogota, NJ 07603']},
#    'phone': '+12013429887',
#    'display_phone': '(201) 342-9887',
#    'distance': 18749.01587971454},
#   {'id': '3ahcwkc4fTd_4M05j1kKiQ',
#    'alias': 'petes-candy-store-brooklyn',
#    'name': "Pete's Candy Store",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/A-h3wgueYwDOjxLHTTpGwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/petes-candy-store-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 259,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'divebars', 'title': 'Dive Bars'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71809, 'longitude': -73.950325},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '709 Lorimer St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['709 Lorimer St', 'Brooklyn, NY 11211']},
#    'phone': '+17183023770',
#    'display_phone': '(718) 302-3770',
#    'distance': 3970.4825370059557},
#   {'id': 'kuUQ4vHtVDhmcwMO_zmW4A',
#    'alias': 'chefskis-polish-home-made-cooking-wallington',
#    'name': "Chefski's Polish Home Made Cooking",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1prKGoj7LKKhTC0kNWaTAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chefskis-polish-home-made-cooking-wallington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'creperies', 'title': 'Creperies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8593740378521,
#     'longitude': -74.104877887882},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '360 Main Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Wallington',
#     'zip_code': '07057',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['360 Main Ave', 'Wallington, NJ 07057']},
#    'phone': '+19734714193',
#    'display_phone': '(973) 471-4193',
#    'distance': 19478.629243106046},
#   {'id': 'AHq0ROhYmVEsgnrg73r6aQ',
#    'alias': 'broken-bow-brewery-tuckahoe',
#    'name': 'Broken Bow Brewery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DWgLR9zmxrpz7yys2FmsHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/broken-bow-brewery-tuckahoe?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.95504, 'longitude': -73.818983},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '173 Marbledale Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Tuckahoe',
#     'zip_code': '10707',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['173 Marbledale Rd', 'Tuckahoe, NY 10707']},
#    'phone': '+19142680900',
#    'display_phone': '(914) 268-0900',
#    'distance': 31429.650389877395}],
#  'total': 181,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                         Restaurant                    Type Price Rating  \
# 0  Cobblestones Pub and Biergarten  American (Traditional)    $$    3.5
# 1                     Clinton Hall            Beer Gardens    $$      4
# 2                       Draft Barn                    Pubs    $$    3.5
# 3                     Peculier Pub                    Pubs     $      4
# 4                Christkindl Markt                  German
#
#                Address        Lat        Lng  \
# 0    11718 Queens Blvd  40.715062 -73.832723
# 1       601 E 189th St  40.857350 -73.885740
# 2            317 Ave X  40.590560 -73.971330
# 3      145 Bleecker St  40.728370 -73.999060
# 4  1132 Hempstead Tpke  40.708534 -73.682135
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/cobblestones-pub-and-...  Xkz2uUnAM2ckYIUqxI0NPw
# 1  https://www.yelp.com/biz/clinton-hall-bronx-4?...  2O5w-15_AVnnVJEtlWWE_A
# 2  https://www.yelp.com/biz/draft-barn-brooklyn-3...  ibTjqHbbBqctjzJLtyUmRw
# 3  https://www.yelp.com/biz/peculier-pub-new-york...  2LRg0V0K1iG6JqIvCND5kg
# 4

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"german","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [{'id': 'ZcwkYG95JHKKiLzJ8nrVYA',
#    'alias': 'cafe-select-new-york',
#    'name': 'Cafe Select',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HIeFn5s_O_qdmp1y6eb1ow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-select-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 485,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.721816, 'longitude': -73.997927},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '212 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['212 Lafayette St', 'New York, NY 10012']},
#    'phone': '+12129259322',
#    'display_phone': '(212) 925-9322',
#    'distance': 1845.9691746450146},
#   {'id': 'tuIH3ALOciWJRRmVzcOoJQ',
#    'alias': 'polski-smak-butler',
#    'name': 'Polski Smak',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/piPl7SzC8u1ryGMZkR9K1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/polski-smak-butler?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 94,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.9910810589688,
#     'longitude': -74.3459410929136},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1295 Route 23 S',
#     'address2': None,
#     'address3': None,
#     'city': 'Butler',
#     'zip_code': '07405',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1295 Route 23 S', 'Butler, NJ 07405']},
#    'phone': '+19734927625',
#    'display_phone': '(973) 492-7625',
#    'distance': 43400.82351749719},
#   {'id': 'O3uSmOvvrM_Z8SJa2IFveg',
#    'alias': 'yonkers-brewing-co-yonkers',
#    'name': 'Yonkers Brewing Co.',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/95A43a1WvInellNN15P9_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yonkers-brewing-co-yonkers?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 325,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.934378, 'longitude': -73.9028219},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '92 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Yonkers',
#     'zip_code': '10701',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['92 Main St', 'Yonkers, NY 10701']},
#    'phone': '+19142268327',
#    'display_phone': '(914) 226-8327',
#    'distance': 26594.422263135428},
#   {'id': 'G6Kc58Oc42uXY2alGCoDBA',
#    'alias': 'the-churchill-tavern-new-york',
#    'name': 'The Churchill Tavern',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cmDOvXC3Bp5kUPVlqxfusg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-churchill-tavern-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 245,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7435888, 'longitude': -73.9844841},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '45 E 28th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 E 28th St', 'New York, NY 10016']},
#    'phone': '+16469227744',
#    'display_phone': '(646) 922-7744',
#    'distance': 4321.205883326993},
#   {'id': 'OP8-qZGuwYaUb1DoFeJqiA',
#    'alias': 'twin-door-tavern-maywood',
#    'name': 'Twin Door Tavern',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/agLmAqbQQfoxjrJ2bnrTXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/twin-door-tavern-maywood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 109,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.9057253, 'longitude': -74.0646445},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '122 W Pleasant Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Maywood',
#     'zip_code': '07607',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['122 W Pleasant Ave', 'Maywood, NJ 07607']},
#    'phone': '+12018438022',
#    'display_phone': '(201) 843-8022',
#    'distance': 23043.878220959108},
#   {'id': 'sAy-yFDnl4dJ97K5SI9x-A',
#    'alias': 'blarney-station-east-rutherford',
#    'name': 'Blarney Station',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Rqs86bQ55AMk7qzVKHXEdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blarney-station-east-rutherford?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 129,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'irish', 'title': 'Irish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.829008406004, 'longitude': -74.100459446656},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '258 Park Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'East Rutherford',
#     'zip_code': '07073',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['258 Park Ave', 'East Rutherford, NJ 07073']},
#    'phone': '+12015310001',
#    'display_phone': '(201) 531-0001',
#    'distance': 16392.551431822063},
#   {'id': 'n8sDrOo5oOlhTS7eYkiZpA',
#    'alias': 'christinas-brooklyn',
#    'name': "Christina's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xhhoOIxaaTCn0AjCBfjzww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/christinas-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 154,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7291, 'longitude': -73.95406},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '853 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['853 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183834382',
#    'display_phone': '(718) 383-4382',
#    'distance': 4295.679422083844},
#   {'id': 'XsDOVt5A-r2YDnDTDmbqyQ',
#    'alias': 'st-jamess-gate-publick-house-maplewood',
#    'name': "St James's Gate Publick House",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-QRMeblQwBix796R47BmjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-jamess-gate-publick-house-maplewood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 148,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.73116, 'longitude': -74.2778699},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '167 Maplewood Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Maplewood',
#     'zip_code': '07040',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['167 Maplewood Ave', 'Maplewood, NJ 07040']},
#    'phone': '+19733782222',
#    'display_phone': '(973) 378-2222',
#    'distance': 24067.46140236501},
#   {'id': 'mbk7p9edD8Cw1GQItw27mg',
#    'alias': 'bklyn-beer-garden-jamaica',
#    'name': 'BKLYN Beer Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Hu_blILOGpgD3bBOAV4wEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bklyn-beer-garden-jamaica?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 270,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 40.6407785162622,
#     'longitude': -73.7894916067987},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': "Jfk Int'l Airport Terminal 2",
#     'address2': '',
#     'address3': '',
#     'city': 'Jamaica',
#     'zip_code': '11430',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ["Jfk Int'l Airport Terminal 2", 'Jamaica, NY 11430']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 18708.85528750905},
#   {'id': 'iqFZCAkpH74lx6UtbZphJg',
#    'alias': 'oxford-bake-shop-ozone-park',
#    'name': 'Oxford Bake Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/v-Yj3F2tyTeAYuWuhxjUsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oxford-bake-shop-ozone-park?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'german', 'title': 'German'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68229, 'longitude': -73.8369699},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '10401 Liberty Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Ozone Park',
#     'zip_code': '11417',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10401 Liberty Ave', 'Ozone Park, NY 11417']},
#    'phone': '+17188434039',
#    'display_phone': '(718) 843-4039',
#    'distance': 13511.414287737023},
#   {'id': 'o1_Hx7RPW9xBxwdpO81dXA',
#    'alias': 'doyles-corner-astoria',
#    'name': "Doyle's Corner",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XoSYsbgEptZIlRpmUgf_ZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doyles-corner-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 81,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.757959, 'longitude': -73.917423},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4202 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4202 Broadway', 'Astoria, NY 11103']},
#    'phone': '+17186062777',
#    'display_phone': '(718) 606-2777',
#    'distance': 8720.692796721285},
#   {'id': 'mJeOqC0_arMr5LWq1eANqg',
#    'alias': 'darby-road-pub-scotch-plains',
#    'name': 'Darby Road Pub',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/esJ_5v2_h2RStoPrzVvKpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/darby-road-pub-scotch-plains?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 233,
#    'categories': [{'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6497131626796,
#     'longitude': -74.3970154719498},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '450 Park Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Scotch Plains',
#     'zip_code': '07076',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['450 Park Ave', 'Scotch Plains, NJ 07076']},
#    'phone': '+19082887667',
#    'display_phone': '(908) 288-7667',
#    'distance': 34521.89559559936},
#   {'id': 'DMOwfdP0Va1QI_KNefD8kg',
#    'alias': 'berry-park-brooklyn',
#    'name': 'Berry Park',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IsaOmF8XRx5PRKQm2sA36w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/berry-park-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 690,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7224719, 'longitude': -73.9552526},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4 Berry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4 Berry St', 'Brooklyn, NY 11211']},
#    'phone': '+17187822829',
#    'display_phone': '(718) 782-2829',
#    'distance': 3796.282557902373},
#   {'id': '7yJ3fOQp3oj2xuDaUGD3_A',
#    'alias': 'the-bowery-beer-garden-new-york-6',
#    'name': 'The Bowery Beer Garden',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GBXwsKAlOlFddcRjrZjdpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bowery-beer-garden-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7171, 'longitude': -73.99533},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '93 Bowery',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['93 Bowery', 'New York, NY 10002']},
#    'phone': '+12123438111',
#    'display_phone': '(212) 343-8111',
#    'distance': 1290.044947830648},
#   {'id': 'kQnCxOZREPxogXF5k6ga9A',
#    'alias': 'homemade-pirogi-clifton',
#    'name': 'Homemade Pirogi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XGjHH44gr4snlD5LElFJgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/homemade-pirogi-clifton?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.879287, 'longitude': -74.144187},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1295 Main Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Clifton',
#     'zip_code': '07011',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1295 Main Ave', 'Clifton, NJ 07011']},
#    'phone': '+19733400340',
#    'display_phone': '(973) 340-0340',
#    'distance': 23077.830362544075},
#   {'id': 'Ym_PCIvKFA5QUu7dDh20Fw',
#    'alias': 'monas-new-york',
#    'name': "Mona's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bdahOPS0Si7hGFThCHUDTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/monas-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 102,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.729198, 'longitude': -73.978523},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '224 Avenue B',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['224 Avenue B', 'New York, NY 10009']},
#    'phone': '+12123533780',
#    'display_phone': '(212) 353-3780',
#    'distance': 2957.662695312289},
#   {'id': 'zjoHov9SWVHHUk_2zSNzPA',
#    'alias': 'o-donnells-pub-harrison-2',
#    'name': "O'Donnell's Pub",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UALdwfkKtS4RdsAYCt6GPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/o-donnells-pub-harrison-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74585, 'longitude': -74.15875},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '233 Harrison Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Harrison',
#     'zip_code': '07029',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['233 Harrison Ave', 'Harrison, NJ 07029']},
#    'phone': '+19734829800',
#    'display_phone': '(973) 482-9800',
#    'distance': 14574.180719247894},
#   {'id': 'xokJMmYZ53dWMgKBiiPGGg',
#    'alias': 'tap-beer-brooklyn-4',
#    'name': 'Tap Beer',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/p1ABPSh8aoJzOYSEJDFZNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tap-beer-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.584169, 'longitude': -73.950576},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1781 Sheepshead Bay Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11235',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1781 Sheepshead Bay Rd', 'Brooklyn, NY 11235']},
#    'phone': '+17188726700',
#    'display_phone': '(718) 872-6700',
#    'distance': 13980.573064231136},
#   {'id': 'RsLs863308rBCJqwuGfNeA',
#    'alias': 'custom-house-brooklyn',
#    'name': 'Custom House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lzHBmTUfS85FbdH-Zd6ACg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/custom-house-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 180,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.694862, 'longitude': -73.993713},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '139 Montague St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['139 Montague St', 'Brooklyn, NY 11201']},
#    'phone': '+17186436000',
#    'display_phone': '(718) 643-6000',
#    'distance': 1177.6284266634227},
#   {'id': 'EY5ot4Z1tgbDC-TZXIcRjQ',
#    'alias': 'putnams-pub-and-cooker-brooklyn',
#    'name': "Putnam's Pub & Cooker",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/W2mNO8Md_PfbQIvtz02Gbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/putnams-pub-and-cooker-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 459,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.693321, 'longitude': -73.969045},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '419 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['419 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+13477992382',
#    'display_phone': '(347) 799-2382',
#    'distance': 2519.4723419181505},
#   {'id': 'QzZlCAp7Qp7nBP7kRuGuNg',
#    'alias': 'harlem-hops-new-york-2',
#    'name': 'Harlem Hops',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6AmF33DK3pNEc-Wl4K6roA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harlem-hops-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 125,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.81444, 'longitude': -73.9448},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2268 Adam Clayton Powell Jr Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10030',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2268 Adam Clayton Powell Jr Blvd',
#      'New York, NY 10030']},
#    'phone': '+16469983444',
#    'display_phone': '(646) 998-3444',
#    'distance': 12821.080616066774},
#   {'id': 'CW80-xqH6Gm9Npl-QaJ6zg',
#    'alias': 'philly-pretzel-factory-livingston',
#    'name': 'Philly Pretzel Factory',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2RLuVk3Xb6Q9Ra1pUcMgRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/philly-pretzel-factory-livingston?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7956801, 'longitude': -74.3163602},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '21 W Mt Pleasant Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Livingston',
#     'zip_code': '07039',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['21 W Mt Pleasant Ave', 'Livingston, NJ 07039']},
#    'phone': '+19739941004',
#    'display_phone': '(973) 994-1004',
#    'distance': 28925.780280956482},
#   {'id': 'aZyHdGVuC90hznqq5UFHnw',
#    'alias': 'thatcher-mcghees-irish-pub-pompton-lakes',
#    'name': "Thatcher McGhee's Irish Pub",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-DvZ12r9sUytkHs8m0K_Lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thatcher-mcghees-irish-pub-pompton-lakes?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 222,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'irish', 'title': 'Irish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 41.007684, 'longitude': -74.295147},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '6 Wanaque Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Pompton Lakes',
#     'zip_code': '07442',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['6 Wanaque Ave', 'Pompton Lakes, NJ 07442']},
#    'phone': '+19738393377',
#    'display_phone': '(973) 839-3377',
#    'distance': 42067.41309596694},
#   {'id': 'L0g4PLqpgWz0OkpGFbUTZA',
#    'alias': 'mudville9-new-york-3',
#    'name': 'Mudville9',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TeYa8l1cE-kfkVYaECva9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mudville9-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 399,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71520852817451, 'longitude': -74.0089192},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '126 Chambers St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['126 Chambers St', 'New York, NY 10007']},
#    'phone': '+12129649464',
#    'display_phone': '(212) 964-9464',
#    'distance': 1642.693957058314},
#   {'id': 'WCCY222sLsRfiNh6TQgfrw',
#    'alias': 'grande-saloon-clifton',
#    'name': 'Grande Saloon',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JyI-iDgTqjj7aBC9d4evOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grande-saloon-clifton?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'karaoke', 'title': 'Karaoke'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.8648356, 'longitude': -74.1597348},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '940 Van Houten Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Clifton',
#     'zip_code': '07013',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['940 Van Houten Ave', 'Clifton, NJ 07013']},
#    'phone': '+19734725207',
#    'display_phone': '(973) 472-5207',
#    'distance': 22497.98654375726},
#   {'id': 'YvL7_ZXp-VAhrOCy1mb-cQ',
#    'alias': 'bb-q-chicken-ny-ktown-new-york',
#    'name': 'bb.q Chicken - NY KTOWN',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4OT3CELCJzZP7VkT9-dPHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bb-q-chicken-ny-ktown-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 788,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74783, 'longitude': -73.98685},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '25 W 32nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 W 32nd St', 'New York, NY 10001']},
#    'phone': '+12129678093',
#    'display_phone': '(212) 967-8093',
#    'distance': 4760.540557167318},
#   {'id': '8UcUkOgoIls-HEwy-ABzUA',
#    'alias': 'joes-pub-at-the-public-new-york',
#    'name': "Joe's Pub at The Public",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8ZyOYOA3iGXa8Xo3QBLilA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pub-at-the-public-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 269,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72921, 'longitude': -73.99177},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '425 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['425 Lafayette St', 'New York, NY 10003']},
#    'phone': '+12125398778',
#    'display_phone': '(212) 539-8778',
#    'distance': 2629.940877469231},
#   {'id': 'JAnCJOrKl5u5-SohkHTUvg',
#    'alias': 'wurst-sausage-and-more-queens',
#    'name': 'Wurst - Sausage And More',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wurst-sausage-and-more-queens?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.6445, 'longitude': -73.79883},
#    'transactions': [],
#    'location': {'address1': '500 Terminal Dr',
#     'address2': '',
#     'address3': None,
#     'city': 'Queens',
#     'zip_code': '11430',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['500 Terminal Dr', 'Queens, NY 11430']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 18505.905467664667},
#   {'id': 'UTZTj-YYgBu9rThLKYuReQ',
#    'alias': 'the-refinery-tavern-bayonne',
#    'name': 'The Refinery Tavern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DnEeCMZ5Jo3qcFzmM5KB1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-refinery-tavern-bayonne?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.674769, 'longitude': -74.1087808},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '812 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Bayonne',
#     'zip_code': '07002',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['812 Broadway', 'Bayonne, NJ 07002']},
#    'phone': '+12018580060',
#    'display_phone': '(201) 858-0060',
#    'distance': 10237.75020932482},
#   {'id': '33SyxCFwGOK_ws-05W_-lA',
#    'alias': 'pj-leahys-long-island-city',
#    'name': "PJ Leahy's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EfjEHDKmhIsohBCRNmPJcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pj-leahys-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'irish', 'title': 'Irish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.742645, 'longitude': -73.954452},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '5002 Vernon Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5002 Vernon Blvd', 'Long Island City, NY 11101']},
#    'phone': '+17184725131',
#    'display_phone': '(718) 472-5131',
#    'distance': 5333.564607993464}],
#  'total': 181,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#              Restaurant                    Type Price Rating  \
# 0           Cafe Select                    Bars    $$    3.5
# 1           Polski Smak                   Delis     $    4.5
# 2   Yonkers Brewing Co.              Gastropubs    $$    3.5
# 3  The Churchill Tavern                    Pubs    $$    3.5
# 4      Twin Door Tavern  American (Traditional)    $$    3.5
#
#               Address        Lat        Lng  \
# 0    212 Lafayette St  40.721816 -73.997927
# 1     1295 Route 23 S  40.991081 -74.345941
# 2          92 Main St  40.934378 -73.902822
# 3        45 E 28th St  40.743589 -73.984484
# 4  122 W Pleasant Ave  40.905725 -74.064644
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/cafe-select-new-york?...  ZcwkYG95JHKKiLzJ8nrVYA
# 1  https://www.yelp.com/biz/polski-smak-butler?ad...  tuIH3ALOciWJRRmVzcOoJQ
# 2  https://www.yelp.com/biz/yonkers-brewing-co-yo...  O3uSmOvvrM_Z8SJa2IFveg
# 3  https://www.yelp.com/biz/the-churchill-tavern-...  G6Kc58Oc42uXY2alGCoDBA
# 4  https://www.yelp.com/biz/twin-door-tavern-mayw...  OP8-qZGuwYaUb1DoFeJqiA

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (180, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                                     Restaurant                    Type Rating  \
# 0                          The Bronx Beer Hall          American (New)    3.5
# 1                                The OX Tavern          American (New)      4
# 2                                   Berry Park          American (New)    3.5
# 3                             Twin Door Tavern  American (Traditional)    3.5
# 4                Redds Restaurant & Biergarten  American (Traditional)    3.5
# 5                               Kent Ale House  American (Traditional)      4
# 6                  McQuades Neighborhood Grill  American (Traditional)    3.5
# 7                               Bronx Alehouse  American (Traditional)      4
# 8              Cobblestones Pub and Biergarten  American (Traditional)    3.5
# 9                        Blind Tiger Ale House  American (Traditional)      4
# 10                                     Phebe's  American (Traditional)    3.5
# 11                               Grande Saloon  American (Traditional)    3.5
# 12                                   Mudville9  American (Traditional)    3.5
# 13                               Zeppelin Hall  American (Traditional)    3.5
# 14                                      Wallse                Austrian      4
# 15                                   Werkstatt                Austrian    4.5
# 16                                   Schilling                Austrian      4
# 17                           Andre's Hungarian                Bakeries    3.5
# 18                       Omonia Cafe - Astoria                Bakeries      3
# 19                Budapest Cafe and Restaurant                Bakeries    3.5
# 20                                 Omonia Cafe                Bakeries      3
# 21                      Kirsh Bakery & Kitchen                Bakeries      4
# 22                            Oxford Bake Shop                Bakeries      4
# 23                          Brooklyn Ice House                Barbeque    4.5
# 24                                       Gruit                    Bars
# 25                                Clinton Hall                    Bars    3.5
# 26                    Craft Kitchen & Taphouse                    Bars      4
# 27   The Biergarten at The Standard, High Line                    Bars    3.5
# 28                                  Draught 55                    Bars      4
# 29                               Katch Astoria                    Bars      3
# ..                                         ...                     ...    ...
# 150                         The Double Windsor                    Pubs      4
# 151              Keg & Lantern Brewing Company                    Pubs      4
# 152                     Tracks Raw Bar & Grill                    Pubs      4
# 153                                   Tavern29                    Pubs      4
# 154                             Sean Og Tavern                    Pubs    3.5
# 155                        124 Old Rabbit Club                    Pubs      4
# 156                       Slainte Bar & Lounge                    Pubs      4
# 157               Blackbird's Bar & Restaurant                    Pubs      4
# 158                          O'Hara's Downtown                    Pubs    3.5
# 159                               Black Rabbit                    Pubs      4
# 160                                Burp Castle                    Pubs      4
# 161                            Smithfield Hall                    Pubs      4
# 162                                 The Sefton                    Pubs
# 163                        Stone Street Tavern                    Pubs    3.5
# 164                                 PJ Leahy's                    Pubs    3.5
# 165                               Peculier Pub                    Pubs      4
# 166                                 Draft Barn                    Pubs    3.5
# 167                                   Valhalla                    Pubs      4
# 168                             Duffy's Tavern                    Pubs      4
# 169                               The Red Lion                    Pubs    3.5
# 170                                  Sugarburg                    Pubs    4.5
# 171                         Kabaret Restaurant                 Russian      4
# 172                   Bahrs Landing Restaurant                 Seafood    3.5
# 173            Croxley's Ale - Franklin Square             Sports Bars    3.5
# 174                     The Bowery Beer Garden             Sports Bars      3
# 175                         District Tap House             Sports Bars      4
# 176                           Keens Steakhouse             Steakhouses      4
# 177             Frankie & Johnnie's Steakhouse             Steakhouses    3.5
# 178                                      Bunny                 Turkish
# 179                Bohemian Hall & Beer Garden   Venues & Event Spaces      4
#
#     Price               Address        Lat        Lng  \
# 0      $$       2344 Arthur Ave  40.854118 -73.888175
# 1      $$      1301 Newkirk Ave  40.634890 -73.964970
# 2      $$            4 Berry St  40.722472 -73.955253
# 3      $$    122 W Pleasant Ave  40.905725 -74.064644
# 4      $$    317 Washington Ave  40.817331 -74.065861
# 5      $$           51 Kent Ave  40.722328 -73.959251
# 6      $$        275 Merrick Rd  40.657560 -73.670120
# 7      $$        216 W 238th St  40.884632 -73.899705
# 8      $$     11718 Queens Blvd  40.715062 -73.832723
# 9      $$       281 Bleecker St  40.731926 -74.003223
# 10     $$            359 Bowery  40.726810 -73.991290
# 11     $$    940 Van Houten Ave  40.864836 -74.159735
# 12     $$       126 Chambers St  40.715209 -74.008919
# 13     $$    88 Liberty View Dr  40.715132 -74.046672
# 14    $$$         344 W 11th St  40.735455 -74.008221
# 15     $$  509 Coney Island Ave  40.645298 -73.970234
# 16     $$     109 Washington St  40.708570 -74.014000
# 17     $$    100-28 Queens Blvd  40.726554 -73.853552
# 18     $$        32-20 Broadway  40.761112 -73.924020
# 19     $$          1631 2nd Ave  40.777150 -73.952640
# 20     $$          7612 3rd Ave  40.630450 -74.028500
# 21     $$     551 Amsterdam Ave  40.787930 -73.974624
# 22      $     10401 Liberty Ave  40.682290 -73.836970
# 23      $      318 Van Brunt St  40.679190 -74.011099
# 24              252 Empire Blvd  40.663466 -73.953647
# 25     $$      90 Washington St  40.708030 -74.014869
# 26     $$     44 Stauderman Ave  40.655737 -73.672153
# 27     $$     848 Washington St  40.740799 -74.007907
# 28     $$         245 E 55th St  40.758377 -73.966515
# 29     $$     31-19 Newtown Ave  40.767172 -73.920275
# ..    ...                   ...        ...        ...
# 150    $$   210 Prospect Park W  40.660630 -73.980560
# 151    $$         97 Nassau Ave  40.724054 -73.950341
# 152    $$      220 West 31st St  40.750509 -73.993509
# 153    $$          47 E 29th St  40.744310 -73.983940
# 154    $$     6002 Woodside Ave  40.744810 -73.904240
# 155    $$      124 MacDougal St  40.729926 -74.000219
# 156    $$            304 Bowery  40.724811 -73.992832
# 157    $$        41-19 30th Ave  40.763410 -73.913350
# 158    $$            172 1st St  40.721526 -74.040803
# 159    $$     91 Greenpoint Ave  40.730141 -73.956319
# 160    $$           41 E 7th St  40.728325 -73.988645
# 161    $$         138 W 25th St  40.744753 -73.993494
# 162                1373 1st Ave  40.769015 -73.955345
# 163    $$           52 Stone St  40.704369 -74.010201
# 164    $$      5002 Vernon Blvd  40.742645 -73.954452
# 165     $       145 Bleecker St  40.728370 -73.999060
# 166    $$             317 Ave X  40.590560 -73.971330
# 167    $$           815 9th Ave  40.765960 -73.987370
# 168    $$        650 Forest Ave  40.629660 -74.110790
# 169    $$       151 Bleecker St  40.728430 -73.999450
# 170    $$  519 Metropolitan Ave  40.714118 -73.951606
# 171   $$$     100 Summerhill Rd  40.397203 -74.385118
# 172    $$             2 Bay Ave  40.397390 -73.981339
# 173    $$  129 New Hyde Park Rd  40.710901 -73.676489
# 174    $$             93 Bowery  40.717100 -73.995330
# 175    $$         246 W 38th St  40.754090 -73.990390
# 176  $$$$          72 W 36th St  40.750710 -73.986520
# 177   $$$         320 W 46th St  40.759956 -73.988926
# 178            449 Nostrand Ave  40.682020 -73.949770
# 179    $$         2919 24th Ave  40.772730 -73.915772
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/the-bronx-beer-hall-b...  zEHzdRjEa23tcH585_SqHw
# 1    https://www.yelp.com/biz/the-ox-tavern-brookly...  I8U2B8O3uXhhXYhRrOH_Xg
# 2    https://www.yelp.com/biz/berry-park-brooklyn?a...  DMOwfdP0Va1QI_KNefD8kg
# 3    https://www.yelp.com/biz/twin-door-tavern-mayw...  OP8-qZGuwYaUb1DoFeJqiA
# 4    https://www.yelp.com/biz/redds-restaurant-and-...  8QVodl0JGDNyJmtBa8hChA
# 5    https://www.yelp.com/biz/kent-ale-house-brookl...  SBLoGGk936tFHg0gYSZ-ow
# 6    https://www.yelp.com/biz/mcquades-neighborhood...  umDSO3r5_E9HfGR5QQij3g
# 7    https://www.yelp.com/biz/bronx-alehouse-bronx-...  ciHt5n5rmpby1YcC_6JVrg
# 8    https://www.yelp.com/biz/cobblestones-pub-and-...  Xkz2uUnAM2ckYIUqxI0NPw
# 9    https://www.yelp.com/biz/blind-tiger-ale-house...  PMp7WlHIXQUnej-Ds1jRfw
# 10   https://www.yelp.com/biz/phebes-new-york?adjus...  pffG9Ciyks5Xik7opl2bEw
# 11   https://www.yelp.com/biz/grande-saloon-clifton...  WCCY222sLsRfiNh6TQgfrw
# 12   https://www.yelp.com/biz/mudville9-new-york-3?...  L0g4PLqpgWz0OkpGFbUTZA
# 13   https://www.yelp.com/biz/zeppelin-hall-jersey-...  P5X8K61nDAlo8QrgCn-agQ
# 14   https://www.yelp.com/biz/wallse-new-york-8?adj...  tV2IY8q92bOEwVC4McgPjw
# 15   https://www.yelp.com/biz/werkstatt-brooklyn-2?...  FXBrt0VpeBRengdd4fBOZw
# 16   https://www.yelp.com/biz/schilling-new-york?ad...  ZgyvDF_hOWas3SXe0Hj7hA
# 17   https://www.yelp.com/biz/andres-hungarian-fore...  ozyAYd8hardDsx2_l57khA
# 18   https://www.yelp.com/biz/omonia-cafe-astoria-a...  _OzfOh1aJM4PFCG-qpVknQ
# 19   https://www.yelp.com/biz/budapest-cafe-and-res...  u-1o6fSvTnqLBtqFuLFqNw
# 20   https://www.yelp.com/biz/omonia-cafe-brooklyn-...  IvcoTrvUdlhtpp2_pn_rAA
# 21   https://www.yelp.com/biz/kirsh-bakery-and-kitc...  UQGwXsOt9u0uZX0bY6j1kw
# 22   https://www.yelp.com/biz/oxford-bake-shop-ozon...  iqFZCAkpH74lx6UtbZphJg
# 23   https://www.yelp.com/biz/brooklyn-ice-house-br...  Hc2KkfFWYnWYtL11_F40Ew
# 24
# 25   https://www.yelp.com/biz/clinton-hall-new-york...  nm5rcWNmfevNXLNQAITi5w
# 26   https://www.yelp.com/biz/craft-kitchen-and-tap...  YFaL6GRCX-0rcjii4rG76Q
# 27   https://www.yelp.com/biz/the-biergarten-at-the...  F622poZMX_mk1eoSoUOyaw
# 28   https://www.yelp.com/biz/draught-55-new-york?a...  b2naaHiaR57Hm6JZG0njPg
# 29   https://www.yelp.com/biz/katch-astoria-astoria...  hN3fiSltPQ8G6YJQLSz5xw
# ..                                                 ...                     ...
# 150  https://www.yelp.com/biz/the-double-windsor-br...  xd7ioU33jkwx0hQ3kUNIOg
# 151  https://www.yelp.com/biz/keg-and-lantern-brewi...  8vwANffgp9s9RDCSn3mD5w
# 152  https://www.yelp.com/biz/tracks-raw-bar-and-gr...  ULF7NqOo2VWrxMs_hkYgCQ
# 153  https://www.yelp.com/biz/tavern29-new-york?adj...  NTwOc9yQ1xl5deeVzZqxfw
# 154  https://www.yelp.com/biz/sean-og-tavern-woodsi...  2R6owNuekbOaLudU5U8y7w
# 155  https://www.yelp.com/biz/124-old-rabbit-club-n...  -wkcI5M7902hJyhkN1zS3A
# 156  https://www.yelp.com/biz/slainte-bar-and-loung...  RBkz0yuQfs_5ExPhL-6jpg
# 157  https://www.yelp.com/biz/blackbirds-bar-and-re...  gJmJDwrDUHy--3qS9qQFYA
# 158  https://www.yelp.com/biz/o-haras-downtown-jers...  KAWZ2Msx0fbRhN1W4_cggw
# 159  https://www.yelp.com/biz/black-rabbit-brooklyn...  jJfCbhEnI5PMPW_vS-Pp6g
# 160  https://www.yelp.com/biz/burp-castle-new-york?...  wLvcBF3tbvu5h6XDYfm7DA
# 161  https://www.yelp.com/biz/smithfield-hall-new-y...  GlSWzWVmQsKLGxySYSGRbQ
# 162
# 163  https://www.yelp.com/biz/stone-street-tavern-n...  NA_p2AH5RSBV314bklZn_g
# 164  https://www.yelp.com/biz/pj-leahys-long-island...  33SyxCFwGOK_ws-05W_-lA
# 165  https://www.yelp.com/biz/peculier-pub-new-york...  2LRg0V0K1iG6JqIvCND5kg
# 166  https://www.yelp.com/biz/draft-barn-brooklyn-3...  ibTjqHbbBqctjzJLtyUmRw
# 167  https://www.yelp.com/biz/valhalla-new-york?adj...  Rpw8mQPKJb8esVjosT4Sog
# 168  https://www.yelp.com/biz/duffys-tavern-staten-...  96zQLCoZ66Nbu-w1ddetqQ
# 169  https://www.yelp.com/biz/the-red-lion-new-york...  BDM5u5RodeZbElVo_iRdXQ
# 170  https://www.yelp.com/biz/sugarburg-brooklyn?ad...  hK14kghcSPkljAqzEHNemA
# 171  https://www.yelp.com/biz/kabaret-restaurant-sp...  CslkgF_rqwHlx8vneUSO_g
# 172  https://www.yelp.com/biz/bahrs-landing-restaur...  uo6cbaGSBlmmZIXhBjRa9w
# 173  https://www.yelp.com/biz/croxleys-ale-franklin...  FsnUZsbsFuxOKJUPOubS5Q
# 174  https://www.yelp.com/biz/the-bowery-beer-garde...  7yJ3fOQp3oj2xuDaUGD3_A
# 175  https://www.yelp.com/biz/district-tap-house-ne...  Z65cd3Z7JvwK8TnSVg-cfA
# 176  https://www.yelp.com/biz/keens-steakhouse-new-...  pQuZDnefX038xurT1BhDXA
# 177  https://www.yelp.com/biz/frankie-and-johnnies-...  IFQ1CXX3QTiuOjeXYvtWLw
# 178
# 179  https://www.yelp.com/biz/bohemian-hall-and-bee...  cuVyM_ZxtREqpO1SXgZmRA
#
# [180 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_German.csv')
