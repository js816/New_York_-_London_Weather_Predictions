# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"cafe","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': 'vijwGDNrPBJHEG7_DsjZNw',
#    'alias': 'usagi-ny-dumbo-7',
#    'name': 'Usagi NY',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6yNqnkPDJAZXpMemwCYN3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/usagi-ny-dumbo-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'bookstores', 'title': 'Bookstores'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'homedecor', 'title': 'Home Decor'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70383, 'longitude': -73.98691},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '163 Plymouth St',
#     'address2': '',
#     'address3': '',
#     'city': 'Dumbo',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['163 Plymouth St', 'Dumbo, NY 11201']},
#    'phone': '+17188018037',
#    'display_phone': '(718) 801-8037',
#    'distance': 635.7818631527628},
#   {'id': 'ED7A7vDdg8yLNKJTSVHHmg',
#    'alias': 'arabica-brooklyn',
#    'name': '% Arabica',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_3VSEFG3iUT-M66JYc7U4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arabica-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 62,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70247143757704,
#     'longitude': -73.9942601520649},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '20 Old Fulton St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['20 Old Fulton St', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 330.64136101613974},
#   {'id': 'pimuUR-TEHIjUla3S3jemQ',
#    'alias': 'coffee-project-new-york-east-village-new-york',
#    'name': 'Coffee Project New York | East Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/oTalWA2QqsoRD4RprV0tOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffee-project-new-york-east-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 692,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72699, 'longitude': -73.98922},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '239 E 5th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['239 E 5th St', 'New York, NY 10003']},
#    'phone': '+12122287888',
#    'display_phone': '(212) 228-7888',
#    'distance': 2438.0326883939874},
#   {'id': 'KWC_KYP336tSFhAihd8plg',
#    'alias': 'bluestone-lane-dumbo-café-brooklyn',
#    'name': 'Bluestone Lane DUMBO Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AjXvAC5Y5Blhi2a5XxpmIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bluestone-lane-dumbo-caf%C3%A9-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 196,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70077577888819,
#     'longitude': -73.98836356287899},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '55 Prospect St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Prospect St', 'Brooklyn, NY 11201']},
#    'phone': '+17183746858',
#    'display_phone': '(718) 374-6858',
#    'distance': 720.6910385584724},
#   {'id': 'kpxXi23lUQkeJQH-2BtzDw',
#    'alias': 'qahwah-house-brooklyn',
#    'name': 'Qahwah House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hGHi0N9J4Q-2lzp6b3EPkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/qahwah-house-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 114,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7185628184474,
#     'longitude': -73.9571302649415},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '162 Bedford Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3455.274392319802},
#   {'id': 'WHRHK3S1mQc3PmhwsGRvbw',
#    'alias': 'bibble-and-sip-new-york-2',
#    'name': 'Bibble & Sip',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gX847-f2s1X65RkzsFAWBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bibble-and-sip-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5020,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7628355, 'longitude': -73.98518009478293},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '253 W 51st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253 W 51st St', 'New York, NY 10019']},
#    'phone': '+16466495116',
#    'display_phone': '(646) 649-5116',
#    'distance': 6427.569355387715},
#   {'id': '-2UtjTxrt1Xzd-HPsLJ7mA',
#    'alias': 'butler-brooklyn-2',
#    'name': 'Butler',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CU_zfWiYItMJkR6iJsnk0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/butler-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 131,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7032670673495,
#     'longitude': -73.9922419276899},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '40 Water St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40 Water St', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 299.48141504845114},
#   {'id': 'vZevXSC1w27dEvXc2EHCEg',
#    'alias': 'good-thanks-cafe-new-york',
#    'name': 'Good Thanks Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bwiCKLNSXLFdUQXgd_iPXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/good-thanks-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 251,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71972, 'longitude': -73.98952},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '131A Orchard St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['131A Orchard St', 'New York, NY 10002']},
#    'phone': '+16463704426',
#    'display_phone': '(646) 370-4426',
#    'distance': 1640.2291870611812},
#   {'id': 'U3Ueh2bHtp3DLjrdc5w5fQ',
#    'alias': 'remi-flower-and-coffee-new-york-2',
#    'name': 'Remi Flower & Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OdnTsyBHpPngkS3aL3D4ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/remi-flower-and-coffee-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 396,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'florists', 'title': 'Florists'},
#     {'alias': 'floraldesigners', 'title': 'Floral Designers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.753781, 'longitude': -73.9689989},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '906 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['906 2nd Ave', 'New York, NY 10017']},
#    'phone': '+16465591233',
#    'display_phone': '(646) 559-1233',
#    'distance': 5781.90802079335},
#   {'id': 'HUlbrPvAr6sXuBfp5z1MWA',
#    'alias': 'urban-backyard-new-york',
#    'name': 'Urban Backyard',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bB8vr7pVnZmY5x1Snh2WoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/urban-backyard-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 210,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72077, 'longitude': -73.99646},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '180 Mulberry St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['180 Mulberry St', 'New York, NY 10012']},
#    'phone': '+16466929957',
#    'display_phone': '(646) 692-9957',
#    'distance': 1716.018342303412},
#   {'id': 'jZZMmT7Mk3S-fNjXcq3Ksg',
#    'alias': 'devocion-brooklyn-4',
#    'name': 'Devocion',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/33rJ0M41qXFWuQOIF382Ow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/devocion-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 496,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.716054, 'longitude': -73.964684},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '69 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['69 Grand St', 'Brooklyn, NY 11249']},
#    'phone': '+17182856180',
#    'display_phone': '(718) 285-6180',
#    'distance': 2762.7656443327546},
#   {'id': 'Zc7Jbuwe3XO-EaVXIh_TYQ',
#    'alias': 'banter-new-york',
#    'name': 'Banter',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XCjCFrs7nalnaMHB4NZ2pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/banter-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 505,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72787, 'longitude': -74.0010999},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '169 Sullivan St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['169 Sullivan St', 'New York, NY 10012']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2560.3873077474886},
#   {'id': 'UZViRVpxNZvOM5KarmbT1g',
#    'alias': 'sweet-moment-new-york',
#    'name': 'Sweet Moment',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AZThElUcNEcDoZkG-1w3KQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweet-moment-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 921,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'waffles', 'title': 'Waffles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71763, 'longitude': -73.99714},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '106 Mott St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['106 Mott St', 'New York, NY 10013']},
#    'phone': '+12122268724',
#    'display_phone': '(212) 226-8724',
#    'distance': 1378.1148895862755},
#   {'id': 'xTnivXEdEtXrnhp-z4JGvg',
#    'alias': 'la-parisienne-new-york-5',
#    'name': 'La Parisienne',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ywbWsBIM-z7OHvhMoHUg5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-parisienne-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 606,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70961, 'longitude': -74.0093799},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '9 Maiden Ln',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Maiden Ln', 'New York, NY 10038']},
#    'phone': '+16467564911',
#    'display_phone': '(646) 756-4911',
#    'distance': 1350.1089630689858},
#   {'id': 'JYbrQqYd-8iGBWIAAHKBRA',
#    'alias': 'citizens-of-soho-new-york',
#    'name': 'Citizens of Soho',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mJPQikRerSQkEtLGCr_B1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/citizens-of-soho-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'australian', 'title': 'Australian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72134, 'longitude': -73.99777},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '201 Lafayette St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['201 Lafayette St', 'New York, NY 10012']},
#    'phone': '+13475351245',
#    'display_phone': '(347) 535-1245',
#    'distance': 1788.5286937017102},
#   {'id': 'yCfjoS6XfnP8hd9zWjME7Q',
#    'alias': 'citizens-of-gramercy-new-york-2',
#    'name': 'Citizens Of Gramercy',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rHcWueF867fE2ODxkFYZfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/citizens-of-gramercy-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 168,
#    'categories': [{'alias': 'australian', 'title': 'Australian'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73674, 'longitude': -73.98152},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '362 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['362 2nd Ave', 'New York, NY 10010']},
#    'phone': '+13473969678',
#    'display_phone': '(347) 396-9678',
#    'distance': 3630.059092255233},
#   {'id': 'x8slUOJxMX2EJ0YUU0rrSg',
#    'alias': 'banter-new-york-3',
#    'name': 'Banter',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tSOcfx0AMvlvr_QdlO-MWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/banter-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 75,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'acaibowls', 'title': 'Acai Bowls'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.739135, 'longitude': -74.005738},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '643 Hudson St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['643 Hudson St', 'New York, NY 10014']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3868.441709635647},
#   {'id': 'DE0ROwygh-86i4s-WLp8wQ',
#    'alias': 'maman-soho-new-york',
#    'name': 'Maman Soho',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nUj5B96Xh73Y2aGmuvDr6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maman-soho-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 577,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72028, 'longitude': -73.9984},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '239 Centre St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['239 Centre St', 'New York, NY 10013']},
#    'phone': '+12122260700',
#    'display_phone': '(212) 226-0700',
#    'distance': 1685.4911071554986},
#   {'id': 'egkF3jmTAJzbb6uYT-TJrQ',
#    'alias': 'hvrminn-new-york-5',
#    'name': 'HVRMINN',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5GWGY6MArQ8TLEHdw9ubJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hvrminn-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.70308, 'longitude': -73.98392},
#    'transactions': [],
#    'location': {'address1': '247 Water St',
#     'address2': 'Ste 104',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['247 Water St', 'Ste 104', 'New York, NY 11201']},
#    'phone': '+17182608989',
#    'display_phone': '(718) 260-8989',
#    'distance': 903.5833614074085},
#   {'id': 'o9Ipm--aunOX5BbcKY4ENw',
#    'alias': 'feed-shop-and-cafe-brooklyn-2',
#    'name': 'FEED Shop & Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/j0hg_LPCsnAywwrwtP1AAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/feed-shop-and-cafe-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'accessories', 'title': 'Accessories'},
#     {'alias': 'jewelry', 'title': 'Jewelry'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.703402, 'longitude': -73.99141},
#    'transactions': ['delivery'],
#    'location': {'address1': '55 Water St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+19293972716',
#    'display_phone': '(929) 397-2716',
#    'distance': 332.66869202732244},
#   {'id': 'YpGxtJy9ErnjfGG6DXy5uA',
#    'alias': 'sweatshop-cafe-brooklyn',
#    'name': 'Sweatshop Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cx_7Aqq55YRL4rs-Hj3yeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweatshop-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 365,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'australian', 'title': 'Australian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7149542040034, 'longitude': -73.959786},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '232 Metropolitan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['232 Metropolitan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+19179607232',
#    'display_phone': '(917) 960-7232',
#    'distance': 3094.7757917745057},
#   {'id': 'Smj-UqUvNFneHKkuZ0BN7A',
#    'alias': 'kona-coffee-and-company-new-york',
#    'name': 'Kona Coffee and Company',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jpxWssXEd3OEcFn0JJjXpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kona-coffee-and-company-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 156,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72587, 'longitude': -73.98988},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '57 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['57 2nd Ave', 'New York, NY 10003']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2308.140222153645},
#   {'id': 'FaR-Kv-0ZzgcqFW1sCnacw',
#    'alias': 'citizens-of-chelsea-new-york',
#    'name': 'Citizens of Chelsea',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kaKqbs2c0ZYK32iuTmlijw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/citizens-of-chelsea-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 804,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'australian', 'title': 'Australian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.748123, 'longitude': -74.000569},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '401 W 25th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['401 W 25th St', 'New York, NY 10001']},
#    'phone': '+16466493079',
#    'display_phone': '(646) 649-3079',
#    'distance': 4774.962454336896},
#   {'id': 'XEdGYktN7VVuyjkN5ukr4A',
#    'alias': 'bright-side-brooklyn-3',
#    'name': 'Bright Side',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cSx5LjCIO0G3XipfmnXqUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bright-side-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7187096995697,
#     'longitude': -73.9640169072708},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '184 Kent Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['184 Kent Ave', 'Brooklyn, NY 11249']},
#    'phone': '+19292763577',
#    'display_phone': '(929) 276-3577',
#    'distance': 2947.45577986316},
#   {'id': 'GlPJPpKvPR4d8dmcSEYpdA',
#    'alias': 'takahachi-bakery-new-york',
#    'name': 'Takahachi Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oP2xYZjbAa8akp-9CLmiVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/takahachi-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 947,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71393, 'longitude': -74.00822},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '25 Murray St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 Murray St', 'New York, NY 10007']},
#    'phone': '+12127915550',
#    'display_phone': '(212) 791-5550',
#    'distance': 1511.7020935512141},
#   {'id': 'AY9gM46aAW_N_JF7ixTbUw',
#    'alias': 'americano-cafe-staten-island',
#    'name': 'AMERICANO CAFE',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FQBhc8wAyUV231tCvh1fHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/americano-cafe-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.6296235, 'longitude': -74.0738894},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '7 Navy Pier Ct',
#     'address2': None,
#     'address3': None,
#     'city': 'STATEN ISLAND',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 Navy Pier Ct', 'STATEN ISLAND, NY 10304']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 10777.23626008455},
#   {'id': 'nyxmTe-It-tzfagvjkge1g',
#    'alias': 'burrow-brooklyn',
#    'name': 'Burrow',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oAg_RiYyeMnUO5bY_eIOQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burrow-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 81,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7027217, 'longitude': -73.9868878},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '68 Jay St',
#     'address2': 'Ste 119',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['68 Jay St', 'Ste 119', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 693.8065652395189},
#   {'id': 'S9T8kG8xTPaQ1PxLE_VdYg',
#    'alias': 'devocion-new-york',
#    'name': 'Devocion',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NBOv88J8YqPZGU_1dfs0YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/devocion-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 124,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73904, 'longitude': -73.98916},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '25 E 20th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 E 20th St', 'New York, NY 10003']},
#    'phone': '+17182856180',
#    'display_phone': '(718) 285-6180',
#    'distance': 3771.239062934359},
#   {'id': 'ALChdXIVE0712hrwMgPPCA',
#    'alias': 'pueblo-querido-coffee-roasters-brooklyn',
#    'name': 'Pueblo Querido Coffee Roasters',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RwLG2PgaLiqNwZdovuUVmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pueblo-querido-coffee-roasters-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 66,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'colombian', 'title': 'Colombian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7305599, 'longitude': -73.9518},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '195 Greenpoint Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['195 Greenpoint Ave', 'Brooklyn, NY 11222']},
#    'phone': '+19293462986',
#    'display_phone': '(929) 346-2986',
#    'distance': 4541.5037761726035},
#   {'id': 'sgCkRCvUg9P-Z7YV_WE_uQ',
#    'alias': 'meno-coffee-and-tea-new-york-2',
#    'name': 'MENO Coffee & Tea',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OB1BUuqx85difXoIl6pfDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meno-coffee-and-tea-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.729003, 'longitude': -73.99905333},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '218 Thompson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['218 Thompson St', 'New York, NY 10012']},
#    'phone': '+16467679797',
#    'display_phone': '(646) 767-9797',
#    'distance': 2649.956037524944},
#   {'id': 'k9BgEr9WYlraO1DDTKA6hg',
#    'alias': 'rosecrans-new-york',
#    'name': 'Rosecrans',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XWTSM0OJfeftiOQiK990GA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rosecrans-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'giftshops', 'title': 'Gift Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.734217, 'longitude': -73.9998476},
#    'transactions': ['delivery'],
#    'location': {'address1': '7 Greenwich Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 Greenwich Ave', 'New York, NY 10014']},
#    'phone': '+16465046864',
#    'display_phone': '(646) 504-6864',
#    'distance': 3233.374922041918},
#   {'id': 'NG-KlDcSjBk3pfdzjXmMVw',
#    'alias': 'devocion-brooklyn-3',
#    'name': 'Devocion',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ewiPhrKdYcZSgY9TZZrz9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/devocion-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 111,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68857, 'longitude': -73.98334},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '276 Livingston St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['276 Livingston St', 'Brooklyn, NY 11201']},
#    'phone': '+17182856180',
#    'display_phone': '(718) 285-6180',
#    'distance': 2087.8169485341946},
#   {'id': 'zi_TJRxi0WzADbbI6Jcz3A',
#    'alias': 'koneko-new-york-3',
#    'name': 'Koneko',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WZcJF6gmjNHO6TYv9KOfNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/koneko-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 300,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'themedcafes', 'title': 'Themed Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72044, 'longitude': -73.98412},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '26 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 Clinton St', 'New York, NY 10002']},
#    'phone': '+16463705699',
#    'display_phone': '(646) 370-5699',
#    'distance': 1874.6275271483207},
#   {'id': 'VLMxyAe_l9vvyFd5vEPZ4g',
#    'alias': 'bee-cafe-woodside',
#    'name': 'Bee Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IAOxF8RoFpRQjA5k5zqwOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bee-cafe-woodside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 56,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7475304, 'longitude': -73.9030796},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '60-11 39th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60-11 39th Ave', 'Woodside, NY 11377']},
#    'phone': '+13473219098',
#    'display_phone': '(347) 321-9098',
#    'distance': 8998.820844142487},
#   {'id': 'hyEyUk9GOwxlco3w-WU9gA',
#    'alias': 'butler-brooklyn-3',
#    'name': 'Butler',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8LDIfPOfSn01dM3CdiKgew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/butler-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7197884, 'longitude': -73.9591445},
#    'transactions': [],
#    'location': {'address1': '101 N 8th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['101 N 8th St', 'Brooklyn, NY 11249']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3364.546721608744},
#   {'id': 'RDxA8WL7wdHiM5YimUQ_XQ',
#    'alias': 'now-or-never-coffee-new-york',
#    'name': 'Now or Never Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aK0EhNd6MG8nwZqk8Fgt1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/now-or-never-coffee-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72295, 'longitude': -74.00456},
#    'transactions': ['delivery'],
#    'location': {'address1': '30 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30 Grand St', 'New York, NY 10013']},
#    'phone': '+13475568312',
#    'display_phone': '(347) 556-8312',
#    'distance': 2126.280926559841},
#   {'id': 'QgJE4Jfzk7nzmRF_W_6ASA',
#    'alias': 'espresso-bar-brooklyn',
#    'name': 'Espresso Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LeLZYKiktrHtuyZs02uMzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/espresso-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.653054, 'longitude': -73.975948},
#    'transactions': [],
#    'location': {'address1': '1233 Prospect Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11218',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1233 Prospect Ave', 'Brooklyn, NY 11218']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6021.998284698845},
#   {'id': '1fDtQij01Mk92ZTGn6WHjg',
#    'alias': 'the-little-sweet-cafe-boerum-hill-2',
#    'name': 'The Little Sweet Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PxtbjoctqGuEpyZER5HfkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-little-sweet-cafe-boerum-hill-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 154,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6881418, 'longitude': -73.9867324},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '77B Hoyt St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boerum Hill',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['77B Hoyt St', 'Boerum Hill, NY 11201']},
#    'phone': '+17188588998',
#    'display_phone': '(718) 858-8998',
#    'distance': 2026.8476632601842},
#   {'id': '9Ri8et0HTPwzQDg8nUZTBw',
#    'alias': 'book-club-new-york',
#    'name': 'Book Club',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iRrx6GssdaxFyCLezl0lRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/book-club-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'bookstores', 'title': 'Bookstores'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.723015, 'longitude': -73.983207},
#    'transactions': [],
#    'location': {'address1': '197 E 3rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['197 E 3rd St', 'New York, NY 10009']},
#    'phone': '+16466784160',
#    'display_phone': '(646) 678-4160',
#    'distance': 2164.5807746904625},
#   {'id': 'xxiV3-0t_gO1Ojo3xo73TQ',
#    'alias': 'vineapple-cafe-brooklyn',
#    'name': 'Vineapple Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3CTXWh2vzVj7lz0s6MFhKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vineapple-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.698296727787, 'longitude': -73.99307556416},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '71 Pineapple St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['71 Pineapple St', 'Brooklyn, NY 11201']},
#    'phone': '+13477991035',
#    'display_phone': '(347) 799-1035',
#    'distance': 801.4361087691583},
#   {'id': 'sR60I9PI_63noBQcGoIrbw',
#    'alias': 'pause-cafe-new-york',
#    'name': 'Pause Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/T8poA0a4leJLMEeF4DxeSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pause-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 437,
#    'categories': [{'alias': 'moroccan', 'title': 'Moroccan'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72123, 'longitude': -73.98408},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '3 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3 Clinton St', 'New York, NY 10002']},
#    'phone': '+12126775415',
#    'display_phone': '(212) 677-5415',
#    'distance': 1950.7097014911349},
#   {'id': 'CBmrwh7jHn88M4v8Q9Qyyg',
#    'alias': 'white-noise-coffee-co-brooklyn',
#    'name': 'White Noise Coffee Co',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DlrPHdex1kosN3KiL391_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/white-noise-coffee-co-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 98,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6896242, 'longitude': -73.9882489},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '57 Smith St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['57 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17188580258',
#    'display_phone': '(718) 858-0258',
#    'distance': 1823.3291615878086},
#   {'id': 'MKYhiSeXjahxh9O4Gqnimw',
#    'alias': 'grace-street-new-york',
#    'name': 'Grace Street',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sGpzBlU62QQfT9H1Z-yzvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grace-street-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2742,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'shavedice', 'title': 'Shaved Ice'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7478576793883,
#     'longitude': -73.9865590631962},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '17 W 32nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 W 32nd St', 'New York, NY 10001']},
#    'phone': '+19177452125',
#    'display_phone': '(917) 745-2125',
#    'distance': 4760.904253854418},
#   {'id': 'JEuIdK9hzci9g_TuwfnZ_w',
#    'alias': 'society-cafe-new-york-2',
#    'name': 'Society Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NCMXf0M2Ey0ss6sHamg-lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/society-cafe-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 191,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73618, 'longitude': -73.9965962},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '52 W 13th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['52 W 13th St', 'New York, NY 10011']},
#    'phone': '+12123004525',
#    'display_phone': '(212) 300-4525',
#    'distance': 3423.0938252294222},
#   {'id': 'szyoiJXuX8shNnsm8-Bffg',
#    'alias': 'cafe-atelier-new-york',
#    'name': 'Cafe Atelier',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RFNTHrINyRDIl-KKLzVMKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-atelier-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.719573, 'longitude': -74.008365},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '112 Hudson St',
#     'address2': 'Unit 1',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['112 Hudson St', 'Unit 1', 'New York, NY 10013']},
#    'phone': '+16463987807',
#    'display_phone': '(646) 398-7807',
#    'distance': 1968.0566006562863},
#   {'id': 'iV3sxI7FFtaolxY68Mv14g',
#    'alias': 'maman-king-new-york',
#    'name': 'Maman King',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9iH37tF7CZJDKolMQYTp_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maman-king-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.728534, 'longitude': -74.007779},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '375 Hudson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['375 Hudson St', 'New York, NY 10014']},
#    'phone': '+16469706913',
#    'display_phone': '(646) 970-6913',
#    'distance': 2796.2068190243026},
#   {'id': 'o6mE4IK7U2wruJmBF3zWnA',
#    'alias': 'bluestone-lane-new-york-3',
#    'name': 'Bluestone Lane',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EMiMLVwnH58EeFm3vOCAVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bluestone-lane-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 537,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7358109, 'longitude': -74.0009087},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '55 Greenwich Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Greenwich Ave', 'New York, NY 10014']},
#    'phone': '+13473491957',
#    'display_phone': '(347) 349-1957',
#    'distance': 3422.2629136986075},
#   {'id': 'U1exuSaIwTwpjxvlrKeftg',
#    'alias': 'ppl-brooklyn',
#    'name': 'PPL',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Pyr46puhltD1-0wCu2mqhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ppl-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.712885, 'longitude': -73.958529},
#    'transactions': [],
#    'location': {'address1': '189 Roebling St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['189 Roebling St', 'Brooklyn, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3125.9913159270504},
#   {'id': 'KEyhIMAUpj7cceOvG9C1sA',
#    'alias': 'kabisera-new-york-4',
#    'name': 'Kabisera',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eZtLR5F-zklfBWEJyycuTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kabisera-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 101,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'filipino', 'title': 'Filipino'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.720907, 'longitude': -73.989913},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '151 Allen St',
#     'address2': '',
#     'address3': 'Store South',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['151 Allen St', 'Store South', 'New York, NY 10002']},
#    'phone': '+19292073729',
#    'display_phone': '(929) 207-3729',
#    'distance': 1759.6506732063558},
#   {'id': 'u0bYCPlbJ85_lDjnZQ_e3w',
#    'alias': 'kaigo-coffee-room-new-york-4',
#    'name': 'Kaigo Coffee Room',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fpRbgKDuP7UAc00wsfS2qw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaigo-coffee-room-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 157,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7187029822397,
#     'longitude': -74.0004725370878},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '120C Lafayette St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['120C Lafayette St', 'New York, NY 10013']},
#    'phone': '+16465045353',
#    'display_phone': '(646) 504-5353',
#    'distance': 1563.5297646007357}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                                Restaurant          Type Price Rating  \
# 0                                Usagi NY    Bookstores    $$    4.5
# 1                               % Arabica  Coffee & Tea    $$      4
# 2  Coffee Project New York | East Village  Coffee & Tea     $    4.5
# 3               Bluestone Lane DUMBO Café  Coffee & Tea     $      4
# 4                            Qahwah House         Cafes     $      5
#
#             Address        Lat        Lng  \
# 0   163 Plymouth St  40.703830 -73.986910
# 1  20 Old Fulton St  40.702471 -73.994260
# 2      239 E 5th St  40.726990 -73.989220
# 3    55 Prospect St  40.700776 -73.988364
# 4   162 Bedford Ave  40.718563 -73.957130
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/usagi-ny-dumbo-7?adju...  vijwGDNrPBJHEG7_DsjZNw
# 1  https://www.yelp.com/biz/arabica-brooklyn?adju...  ED7A7vDdg8yLNKJTSVHHmg
# 2  https://www.yelp.com/biz/coffee-project-new-yo...  pimuUR-TEHIjUla3S3jemQ
# 3  https://www.yelp.com/biz/bluestone-lane-dumbo-...  KWC_KYP336tSFhAihd8plg
# 4  https://www.yelp.com/biz/qahwah-house-brooklyn...  kpxXi23lUQkeJQH-2BtzDw

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"cafe","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': 'jniZaiTDALOVQfNkg_S9gg',
#    'alias': '787-coffee-new-york-5',
#    'name': '787 Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RA6g4b8dg4_t8f75CML6Ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/787-coffee-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'empanadas', 'title': 'Empanadas'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.703485, 'longitude': -74.01083},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '66 Pearl St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['66 Pearl St', 'New York, NY 10004']},
#    'phone': '+16464499200',
#    'display_phone': '(646) 449-9200',
#    'distance': 1410.8996195780276},
#   {'id': '7gbWC5D0y0ZTUF-WDLwuYw',
#    'alias': 'bluestone-lane-upper-east-side-café-new-york',
#    'name': 'Bluestone Lane Upper East Side Café',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/e94sjlMcyyHlMDoAQJ6BjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bluestone-lane-upper-east-side-caf%C3%A9-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 562,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7837603758071,
#     'longitude': -73.9585503779793},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1085 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1085 5th Ave', 'New York, NY 10128']},
#    'phone': '+17183746858',
#    'display_phone': '(718) 374-6858',
#    'distance': 9214.172029677738},
#   {'id': 'WF_RB9-e0a1s2ulaPZdrqQ',
#    'alias': 'cafe-volkan-new-york',
#    'name': 'Cafe Volkan',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SnF7tepq1P52j6suMjL7Hw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-volkan-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68669, 'longitude': -73.99003},
#    'transactions': ['delivery'],
#    'location': {'address1': '85 Bergen St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 Bergen St', 'New York, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2114.893718529735},
#   {'id': 'gA0VbcoBLCiD2EpSC6vWeg',
#    'alias': 'partners-coffee-long-island-city',
#    'name': 'Partners Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_e06-YI5h2zMRfO4DourEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/partners-coffee-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 174,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74769, 'longitude': -73.9416},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '26-25 Jackson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26-25 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+13475310477',
#    'display_phone': '(347) 531-0477',
#    'distance': 6460.204326416233},
#   {'id': 'ATQDTQu3SsCetuG-byzOFg',
#    'alias': 'cafe-gitane-brooklyn',
#    'name': 'Cafe Gitane',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OveEa94egfLWCN5HgIFrRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-gitane-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'moroccan', 'title': 'Moroccan'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7028272982236,
#     'longitude': -73.9812811999999},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '70 Hudson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70 Hudson Ave', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1134.8131488276106},
#   {'id': 'aNCF4-9nH3hbLJXqIW3EgA',
#    'alias': 'semicolon-cafe-jersey-city',
#    'name': 'Semicolon Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YM4ntNW9Bgj2OxpJ4KASyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/semicolon-cafe-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 149,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.714351, 'longitude': -74.034801},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '77 Hudson St',
#     'address2': None,
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['77 Hudson St', 'Jersey City, NJ 07302']},
#    'phone': '+12013328148',
#    'display_phone': '(201) 332-8148',
#    'distance': 3555.0427034458235},
#   {'id': 'CaYvCcWDITsD0J_4NL2TFg',
#    'alias': 'porcelain-ridgewood',
#    'name': 'Porcelain',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6fUB0L_4I6Dq4RcavrfdNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/porcelain-ridgewood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'panasian', 'title': 'Pan Asian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.702315, 'longitude': -73.901679},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '880 Woodward Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['880 Woodward Ave', 'Ridgewood, NY 11385']},
#    'phone': '+13474645267',
#    'display_phone': '(347) 464-5267',
#    'distance': 7820.925057565874},
#   {'id': 'blX8Y6O0J4p6fXVcTRmANg',
#    'alias': 'the-elk-new-york',
#    'name': 'The Elk',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Dv6TT43vrnM7QymxmicjOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-elk-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 165,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7341962235334,
#     'longitude': -74.007479016899},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '128 Charles St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['128 Charles St', 'New York, NY 10014']},
#    'phone': '+12129334780',
#    'display_phone': '(212) 933-4780',
#    'distance': 3384.6233215025222},
#   {'id': '-HpCsFpk8PwFpbmEELmg6g',
#    'alias': 'semicolon-cafe-new-york',
#    'name': 'Semicolon Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XeV_1Qahm20B_Hs4lrt_hw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/semicolon-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.834633, 'longitude': -73.94522},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '9 Edward M Morgan Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10032',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Edward M Morgan Pl', 'New York, NY 10032']},
#    'phone': '+16467915518',
#    'display_phone': '(646) 791-5518',
#    'distance': 14946.678731643246},
#   {'id': 'zV1_EFMN4VY7Rxpv7P-ajg',
#    'alias': 'sunflower-gramercy-new-york-3',
#    'name': 'Sunflower - Gramercy',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MBjaUlDYeC2t4M6834Gqsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sunflower-gramercy-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 179,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7399, 'longitude': -73.98219},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '335 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['335 3rd Ave', 'New York, NY 10010']},
#    'phone': '+19172620804',
#    'display_phone': '(917) 262-0804',
#    'distance': 3966.0144034235027},
#   {'id': '8g2tBl5vvmin96nrRxAThw',
#    'alias': 'felix-roasting-new-york-3',
#    'name': 'Felix Roasting',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xpo3NK8Kv7cKlSwoYCTn1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/felix-roasting-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 74,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'wholesalers', 'title': 'Wholesalers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72437, 'longitude': -73.99941},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '104 Greene St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['104 Greene St', 'New York, NY 10012']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2154.575292805991},
#   {'id': 'Qmv4SPta2zx7MhKit8ywag',
#    'alias': 'absolute-coffee-brooklyn',
#    'name': 'Absolute Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WrEZlU_pGNek1-Bpb5vdtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/absolute-coffee-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 196,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68827, 'longitude': -73.987569},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '327 Atlantic Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['327 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17185220969',
#    'display_phone': '(718) 522-0969',
#    'distance': 1995.2838490428082},
#   {'id': 'ykqXbitAmPGq1xXZoOLCxw',
#    'alias': 'suited-new-york',
#    'name': 'Suited',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tlJlwZUGYGPWgpHvDM0q2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/suited-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7092991, 'longitude': -74.0079162},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '45 John St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 John St', 'New York, NY 10038']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1225.6685273482528},
#   {'id': 'NJay-xUEFsvWzdeohs9EEA',
#    'alias': 'the-coppola-cafe-new-york',
#    'name': 'The Coppola Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gX4aHYhZYzgzbW4azQ9uQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-coppola-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.732190162973,
#     'longitude': -74.0016116022391},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '171 West 4th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 West 4th St', 'New York, NY 10014']},
#    'phone': '+19176393970',
#    'display_phone': '(917) 639-3970',
#    'distance': 3037.221433563653},
#   {'id': 'wWhZvkaFrntlSf1CWvD1Zw',
#    'alias': 'cafe-patoro-new-york',
#    'name': 'Cafe Patoro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Nnlsd9Wl7KFVVqZxtDRWpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-patoro-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 182,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7072720974983,
#     'longitude': -74.0023160353303},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '223 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['223 Front St', 'New York, NY 10038']},
#    'phone': '+19172620031',
#    'display_phone': '(917) 262-0031',
#    'distance': 706.1266596183273},
#   {'id': '77Q8n_SSXjhN8m2ypqs0ew',
#    'alias': 'maman-nomad-new-york',
#    'name': 'Maman Nomad',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jlNU7kZC-FG87K7qDEU8Mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maman-nomad-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 309,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74325, 'longitude': -73.99023},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '22 W 25th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 W 25th St', 'New York, NY 10010']},
#    'phone': '+16464767660',
#    'display_phone': '(646) 476-7660',
#    'distance': 4220.228339466349},
#   {'id': '4VEgZ7aVUt6oKw8KmXj-jQ',
#    'alias': 'brooklyn-kolache-brooklyn',
#    'name': 'Brooklyn Kolache',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QqQV6MtAiG4i2vqCwFQhCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-kolache-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 337,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6907913077698,
#     'longitude': -73.9556479454041},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '520 Dekalb Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['520 Dekalb Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17183981111',
#    'display_phone': '(718) 398-1111',
#    'distance': 3642.653889043858},
#   {'id': 'Xn_UheApVz6K9heX4vY8PA',
#    'alias': 'terms-of-endearment-brooklyn-2',
#    'name': 'Terms of Endearment',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TBK0GCkD-YY4QxfbA98zOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/terms-of-endearment-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.716367, 'longitude': -73.962207},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '135 Metropolitan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['135 Metropolitan Ave', 'Brooklyn, NY 11249']},
#    'phone': '+13477631420',
#    'display_phone': '(347) 763-1420',
#    'distance': 2964.3329491322866},
#   {'id': 'rQpO1Eie_zmeAOQ9s-T0sQ',
#    'alias': 'hole-in-the-wall-new-york-12',
#    'name': 'Hole In The Wall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NSQmNZzpk69EeGYDQNaThQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hole-in-the-wall-new-york-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 623,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'australian', 'title': 'Australian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70837, 'longitude': -74.00563},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '15 Cliff St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Cliff St', 'New York, NY 10038']},
#    'phone': '+12126029991',
#    'display_phone': '(212) 602-9991',
#    'distance': 1009.2543696243514},
#   {'id': '1aD88qNRb08LGBkl84GQTA',
#    'alias': 'little-collins-new-york-3',
#    'name': 'Little Collins',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JIaDv0kxB4z8bIjItcGMHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-collins-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 868,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75233, 'longitude': -73.97353},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '708 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['708 3rd Ave', 'New York, NY 10017']},
#    'phone': '+12123081969',
#    'display_phone': '(212) 308-1969',
#    'distance': 5507.334764233976},
#   {'id': '-7GUru8FEYMtBmit_hi4cw',
#    'alias': 'ixv-coffee-brooklyn',
#    'name': 'IXV Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/e8twmB6Uq9OmSzoogzLdnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ixv-coffee-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.684921, 'longitude': -73.98126},
#    'transactions': ['delivery'],
#    'location': {'address1': '497C Pacific St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['497C Pacific St', 'Brooklyn, NY 11217']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2532.600061850505},
#   {'id': 'OiCXI-fkb5nyYyfH3AxAOg',
#    'alias': 'kaigo-coffee-room-brooklyn-4',
#    'name': 'Kaigo Coffee Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/q8Xp5g8eoOyInc15pIApSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaigo-coffee-room-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 61,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6936075465661,
#     'longitude': -74.0010171957826},
#    'transactions': ['delivery'],
#    'location': {'address1': '139 Bridge Park Dr',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['139 Bridge Park Dr', 'Brooklyn, NY 11201']},
#    'phone': '+13475296180',
#    'display_phone': '(347) 529-6180',
#    'distance': 1433.1143646260844},
#   {'id': 'IiLLntICUim7YREkIBU7lA',
#    'alias': 'outro-new-york',
#    'name': 'Outro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QuGJCO9M5O2eEVmLtLI52g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/outro-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 340,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'waffles', 'title': 'Waffles'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7327799573693,
#     'longitude': -73.9910601451993},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '816 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['816 Broadway', 'New York, NY 10003']},
#    'phone': '+12129946771',
#    'display_phone': '(212) 994-6771',
#    'distance': 3051.7084001127732},
#   {'id': 'iyKEtW9KM7rIyycAR0o3ew',
#    'alias': 'black-star-bakery-and-cafe-new-york-3',
#    'name': 'Black Star Bakery & Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6pfbDH57Vyv0DVL0b8IuQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-star-bakery-and-cafe-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.738951, 'longitude': -73.980784},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '241 E 24th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['241 E 24th St', 'New York, NY 10010']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3890.344620331399},
#   {'id': 'DxeD4Jw3gsImI-olCOB0bA',
#    'alias': 'little-canal-new-york-2',
#    'name': 'Little Canal',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/35ZbxM9Zh8ex3U4-GPWknA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-canal-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 128,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.714309, 'longitude': -73.990417},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '26 Canal St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 Canal St', 'New York, NY 10002']},
#    'phone': '+19174727479',
#    'display_phone': '(917) 472-7479',
#    'distance': 1035.3030353262682},
#   {'id': 'Mkx7wE0Jlb0bFYGhEpulSg',
#    'alias': 'blackstone-coffee-roasters-new-york',
#    'name': 'Blackstone Coffee Roasters',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3uosI_M3K2cZvAyK_dE0pA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blackstone-coffee-roasters-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7332899, 'longitude': -74.00619},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '502 Hudson St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['502 Hudson St', 'New York, NY 10014']},
#    'phone': '+12129896131',
#    'display_phone': '(212) 989-6131',
#    'distance': 3251.3728402820225},
#   {'id': 'w40v1nDCS_LIeD6Nq14k-Q',
#    'alias': 'capo-capo-cafe-new-york',
#    'name': 'capo capo cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ABmIjKwM4kJLQk0AFoDEDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/capo-capo-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'creperies', 'title': 'Creperies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70714, 'longitude': -74.00367},
#    'transactions': [],
#    'location': {'address1': '21 Fulton St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21 Fulton St', 'New York, NY 10028']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 811.5767035990772},
#   {'id': '4gQTmzAK3VNZfYxwgPXZqw',
#    'alias': 'dream-vista-jersey-city',
#    'name': 'Dream Vista',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bHaJHXlsMIyx595aMc-Iyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dream-vista-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.716568782984325,
#     'longitude': -74.0421270174643},
#    'transactions': ['delivery'],
#    'location': {'address1': '177 York St',
#     'address2': '',
#     'address3': None,
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['177 York St', 'Jersey City, NJ 07302']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4217.226489823962},
#   {'id': 'nI9a2XEe0kM6sEBZr-gxXg',
#    'alias': 'three-owls-market-new-york',
#    'name': 'Three Owls Market',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lkgnYExKwr-bWTdS1de0cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/three-owls-market-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73887, 'longitude': -74.0082},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '800 Washington St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['800 Washington St', 'New York, NY 10014']},
#    'phone': '+19178104891',
#    'display_phone': '(917) 810-4891',
#    'distance': 3900.2817703920573},
#   {'id': 'S-WdvEU1X7J33whXWk1zmw',
#    'alias': 'mud-new-york-3',
#    'name': 'MUD',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HIHld1tjcnr6nkZ8y06cKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mud-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1222,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72905, 'longitude': -73.98668},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '307 E 9th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['307 E 9th St', 'New York, NY 10003']},
#    'phone': '+12122289074',
#    'display_phone': '(212) 228-9074',
#    'distance': 2708.034763713728},
#   {'id': 'M-1k30Dgcc1OxZ8buddE4Q',
#    'alias': 'harbs-soho-new-york-3',
#    'name': 'HARBS SoHo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DE8GF-q9Skq_iRkh_oiRVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harbs-soho-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 147,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.726366, 'longitude': -74.000015},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '465 W Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['465 W Broadway', 'New York, NY 10012']},
#    'phone': '+12124731981',
#    'display_phone': '(212) 473-1981',
#    'distance': 2375.550309555605},
#   {'id': '43WQ7zr54WL3yfT5KTlNBQ',
#    'alias': 'three-jewels-cafe-new-york-2',
#    'name': 'Three Jewels Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ovPmOS5x9AJaK0V2S69Ekg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/three-jewels-cafe-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72624, 'longitude': -73.99119},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '5 E 3rd St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 E 3rd St', 'New York, NY 10003']},
#    'phone': '+16469645736',
#    'display_phone': '(646) 964-5736',
#    'distance': 2340.185523882893},
#   {'id': 'bmW4pD_san3xZrZQdHI4Lw',
#    'alias': 'blank-street-brooklyn-2',
#    'name': 'Blank Street',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/riFcxoDYt079l4p6vHLvDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blank-street-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68416, 'longitude': -73.98357},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '253 Bergen St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253 Bergen St', 'Brooklyn, NY 11217']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2534.1737092218304},
#   {'id': 'k17DEW9TqRZf6EFSc49OsA',
#    'alias': 'bakeri-brooklyn',
#    'name': 'Bakeri',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gfXzPEGq7pudg-fVhYalrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bakeri-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 382,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72004, 'longitude': -73.96013},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '150 Wythe Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 Wythe Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17183888037',
#    'display_phone': '(718) 388-8037',
#    'distance': 3306.011559281162},
#   {'id': 'PwrYnl3j3YCGzILX_5UHpw',
#    'alias': 'davelle-new-york-2',
#    'name': 'Davelle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jzTgx708l_9ewrlozC6p-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/davelle-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 184,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71852, 'longitude': -73.98605},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '102 Suffolk St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 Suffolk St', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1612.1924185402318},
#   {'id': 'RszJexNjHiS1As9cJ7eWpQ',
#    'alias': 'weekends-brooklyn',
#    'name': 'Weekends',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fM3DjFftXU86xI5LYgVZvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/weekends-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71162, 'longitude': -73.96184},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '155 S 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['155 S 4th St', 'Brooklyn, NY 11211']},
#    'phone': '+13479873558',
#    'display_phone': '(347) 987-3558',
#    'distance': 2813.8971237218802},
#   {'id': 'ScGOQn5vliD6TngiKNLRMg',
#    'alias': 'neighbors-brooklyn',
#    'name': 'Neighbors',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lXGSp8EqOYdtPrLx0K17dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/neighbors-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.702241, 'longitude': -73.995539},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '60 Furman St',
#     'address2': 'Fl 1',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Furman St', 'Fl 1', 'Brooklyn, NY 11201']},
#    'phone': '+13476962505',
#    'display_phone': '(347) 696-2505',
#    'distance': 367.7475436977597},
#   {'id': 'v9bbNVQUA0OJzJKAcn_r4w',
#    'alias': 'hole-in-the-wall-williamsburg-brooklyn',
#    'name': 'Hole In The Wall - Williamsburg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HwDCNK3x4w5DARYdNJE5NQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hole-in-the-wall-williamsburg-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'australian', 'title': 'Australian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.714391, 'longitude': -73.961513},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '292 Bedford Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['292 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2931.190959679197},
#   {'id': '1Ik8VQxUa0aDbc1KzrxLRg',
#    'alias': 'caffe-aronne-new-york-3',
#    'name': 'Caffe Aronne',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/06P9LeNq7jaIUaxG5gJzpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-aronne-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.738394, 'longitude': -74.002048},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '112 Greenwich Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['112 Greenwich Ave', 'New York, NY 10011']},
#    'phone': '+16462343555',
#    'display_phone': '(646) 234-3555',
#    'distance': 3725.4558414715802},
#   {'id': 'SZXOfQbLyF3C5GwYBj6VvA',
#    'alias': 'saltwater-coffee-new-york',
#    'name': 'Saltwater Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cdBBTyVhiBft09uTwGStcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saltwater-coffee-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 234,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7304578, 'longitude': -73.9839175},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '345 E 12th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['345 E 12th St', 'New York, NY 10003']},
#    'phone': '+19178812245',
#    'display_phone': '(917) 881-2245',
#    'distance': 2915.5320769059854},
#   {'id': 'P4HX6tjQQK4gbdn_d0cGTw',
#    'alias': 'ground-support-new-york',
#    'name': 'Ground Support',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FbOFOfl469WOxA236dRqIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ground-support-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 522,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7241968559678,
#     'longitude': -74.0020576327145},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '399 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['399 W Broadway', 'New York, NY 10012']},
#    'phone': '+12122198733',
#    'display_phone': '(212) 219-8733',
#    'distance': 2185.4017789063764},
#   {'id': 'ByIhI19_bVFl5koNk0ylpw',
#    'alias': 'tartinery-new-york-14',
#    'name': 'Tartinery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BV0-uCiXGobB0EvmkomWjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tartinery-new-york-14?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.768494, 'longitude': -73.983072},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '10 Columbus Cir',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10 Columbus Cir', 'New York, NY 10019']},
#    'phone': '+19174091991',
#    'display_phone': '(917) 409-1991',
#    'distance': 7079.371546056122},
#   {'id': 't4M1VX4n34eEgUWMJ7cgKw',
#    'alias': 'daily-provisions-new-york',
#    'name': 'Daily Provisions',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KOSmplXpEbiCLdRnRBkcTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daily-provisions-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 471,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73768, 'longitude': -73.9876685},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '103 E 19th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 E 19th St', 'New York, NY 10003']},
#    'phone': '+12124881505',
#    'display_phone': '(212) 488-1505',
#    'distance': 3624.11900652027},
#   {'id': '-8nEZ20KDfr4PPH47MrAOA',
#    'alias': 'la-colombe-coffee-new-york-2',
#    'name': 'La Colombe Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6j27l5rIkTs8KOZOtc9t_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-colombe-coffee-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 685,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72396, 'longitude': -73.99643},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '270 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['270 Lafayette St', 'New York, NY 10012']},
#    'phone': '+12126251717',
#    'display_phone': '(212) 625-1717',
#    'distance': 2069.5745999716323},
#   {'id': '7rxg-tWPc1jK7Cikn5R86g',
#    'alias': 'hi-collar-new-york-2',
#    'name': 'Hi-Collar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6DAtn_pu8hX79LB3sSlFtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hi-collar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 641,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729564, 'longitude': -73.98786},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '231 E 9th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 E 9th St', 'New York, NY 10003']},
#    'phone': '+12127777018',
#    'display_phone': '(212) 777-7018',
#    'distance': 2736.177785571269},
#   {'id': 'GLf8_rOnkszkGmPAiMzO9Q',
#    'alias': 'bread-and-spread-dumbo',
#    'name': 'Bread & Spread',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SMT03iEizZOtc_Cwe5wQbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bread-and-spread-dumbo?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 166,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7025945, 'longitude': -73.9869119},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '151 Front St',
#     'address2': None,
#     'address3': '',
#     'city': 'Dumbo',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['151 Front St', 'Dumbo, NY 11201']},
#    'phone': '+17186252220',
#    'display_phone': '(718) 625-2220',
#    'distance': 698.2848912388458},
#   {'id': '7-yC49tlWreX6TQtMNFSFg',
#    'alias': 'kitsby-brooklyn',
#    'name': 'Kitsby',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2Yss10njvmZ7qcshlj35gA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kitsby-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 220,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71411, 'longitude': -73.960977},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '186 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['186 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+19175305006',
#    'display_phone': '(917) 530-5006',
#    'distance': 2969.509868206952},
#   {'id': '56xmEk-5aTHwBiPyQTzMKA',
#    'alias': 'dreamers-coffee-house-new-york',
#    'name': 'Dreamers Coffee House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RG4YVhDc9YN_4G04tlGBXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dreamers-coffee-house-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.712736, 'longitude': -73.995257},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '54W Henry St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['54W Henry St', 'New York, NY 10002']},
#    'phone': '+12029052088',
#    'display_phone': '(202) 905-2088',
#    'distance': 808.9978527280191},
#   {'id': 'opA6T-cCCdBmixRs_3Q3Lw',
#    'alias': 'calyer-brooklyn-2',
#    'name': 'Calyer',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/p2hphuVOQOqGoSeqr0Upfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/calyer-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.6938, 'longitude': -73.96394},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '519 Myrtle Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['519 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17185763086',
#    'display_phone': '(718) 576-3086',
#    'distance': 2861.1651848905776},
#   {'id': 'bmSYtYRPf6ycx-4xWhbHFg',
#    'alias': 'sey-coffee-brooklyn',
#    'name': 'Sey Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GOcXLMUY2bQcrNtmyNMl-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sey-coffee-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 121,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70532, 'longitude': -73.9324},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '18 Grattan St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18 Grattan St', 'Brooklyn, NY 11206']},
#    'phone': '+13478711611',
#    'display_phone': '(347) 871-1611',
#    'distance': 5215.052044394275}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                             Restaurant          Type Price Rating  \
# 0                           787 Coffee  Coffee & Tea
# 1  Bluestone Lane Upper East Side Café  Coffee & Tea    $$      4
# 2                          Cafe Volkan  Coffee & Tea
# 3                      Partners Coffee  Coffee & Tea    $$      4
# 4                          Cafe Gitane      Moroccan
#
#              Address        Lat        Lng  \
# 0        66 Pearl St  40.703485 -74.010830
# 1       1085 5th Ave  40.783760 -73.958550
# 2       85 Bergen St  40.686690 -73.990030
# 3  26-25 Jackson Ave  40.747690 -73.941600
# 4      70 Hudson Ave  40.702827 -73.981281
#
#                                                  url                      ID
# 0
# 1  https://www.yelp.com/biz/bluestone-lane-upper-...  7gbWC5D0y0ZTUF-WDLwuYw
# 2
# 3  https://www.yelp.com/biz/partners-coffee-long-...  gA0VbcoBLCiD2EpSC6vWeg
# 4

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"cafe","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': 'vk6L5A4OaBmdvgpB_bWDhw',
#    'alias': 'oxa-house-coffee-and-tea-new-york-3',
#    'name': 'OXA House Coffee & Tea ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tm3AbhsX-toc1FL160QZzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oxa-house-coffee-and-tea-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7103, 'longitude': -73.96513},
#    'transactions': [],
#    'location': {'address1': '102 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 Broadway', 'New York, NY 11249']},
#    'phone': '+13478013646',
#    'display_phone': '(347) 801-3646',
#    'distance': 2514.56603882948},
#   {'id': 'NBXYrCQeoz305A3DUAl2GQ',
#    'alias': 'madame-bonté-café-new-york-7',
#    'name': 'Madame Bonté Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/k-Vg0a9H7yjVuwpAF80Rxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/madame-bont%C3%A9-caf%C3%A9-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 71,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78331, 'longitude': -73.94756},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1834 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1834 2nd Ave', 'New York, NY 10128']},
#    'phone': '+12127221122',
#    'display_phone': '(212) 722-1122',
#    'distance': 9511.603190182914},
#   {'id': 'Dntkg2mLT0Tyc_AdKQMogw',
#    'alias': 'saltwater-coffee-new-york-2',
#    'name': 'Saltwater Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/C223_wTf78AuZ6rreYoWoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saltwater-coffee-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73281548761552,
#     'longitude': -73.99985005997831},
#    'transactions': ['delivery'],
#    'location': {'address1': '126 Waverly Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['126 Waverly Pl', 'New York, NY 10011']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3079.290705889451},
#   {'id': 'DiMjV0XcRGybywKE0JTfZQ',
#    'alias': 'two-hands-new-york-3',
#    'name': 'Two Hands',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nNQEfLlBqxroLpTXtyTnwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/two-hands-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 654,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7196877016852,
#     'longitude': -73.9961054743265},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '164 Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['164 Mott St', 'New York, NY 10013']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1591.0783741102405},
#   {'id': 'a8d18n8gAQpQHcr6KwCCeA',
#    'alias': 'saturdays-nyc-new-york-2',
#    'name': 'Saturdays NYC',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WFdNcX1-ABHBty3wgBMhAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saturdays-nyc-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72079, 'longitude': -73.99944},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '31 Crosby St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31 Crosby St', 'New York, NY 10013']},
#    'phone': '+12129667875',
#    'display_phone': '(212) 966-7875',
#    'distance': 1756.2595873324844},
#   {'id': 'sCNZGN2Zh1T5hht728hV5Q',
#    'alias': 'ursula-bk-brooklyn-2',
#    'name': 'Ursula BK',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5h1Jl1ea5L8aAgOu_nx92A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ursula-bk-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 69,
#    'categories': [{'alias': 'newmexican', 'title': 'New Mexican Cuisine'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.672656, 'longitude': -73.954677},
#    'transactions': [],
#    'location': {'address1': '724 Sterling Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['724 Sterling Pl', 'Brooklyn, NY 11216']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4934.048773964252},
#   {'id': 'tq7dDT6edTInhkNdDrYv_w',
#    'alias': 'black-brick-brooklyn',
#    'name': 'Black Brick',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KMA7EDvWqQnCa9T6SICejQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-brick-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 325,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7142079238412,
#     'longitude': -73.9617848396301},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '300 Bedford Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['300 Bedford Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17183840075',
#    'display_phone': '(718) 384-0075',
#    'distance': 2908.1707973176744},
#   {'id': 'xEySCBWaNz84ciNugiaVeA',
#    'alias': 'blank-street-brooklyn',
#    'name': 'Blank Street',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5LHSSvE3zkmchXOe4Vdlxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blank-street-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.717065, 'longitude': -73.962863},
#    'transactions': ['delivery'],
#    'location': {'address1': '225 Wythe Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['225 Wythe Ave', 'Brooklyn, NY 11249']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2949.403899423184},
#   {'id': 'A8jRnZGiMJiMpfHt8qKV3w',
#    'alias': 'fiction-bar-cafe-brooklyn',
#    'name': 'Fiction Bar/Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GdhN-_6OZFkK2cjiN449rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fiction-bar-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 95,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.707248, 'longitude': -73.95375},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '308 Hooper St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['308 Hooper St', 'Brooklyn, NY 11211']},
#    'phone': '+17185995151',
#    'display_phone': '(718) 599-5151',
#    'distance': 3425.4795376581733},
#   {'id': '18-qEPtsL2lbZH4ianmicg',
#    'alias': 'the-granddaddy-new-york-2',
#    'name': 'The Granddaddy',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PG3P3t_9u4VL3j9WZkrghA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-granddaddy-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 129,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71782, 'longitude': -73.992},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '290 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['290 Grand St', 'New York, NY 10002']},
#    'phone': '+19173882233',
#    'display_phone': '(917) 388-2233',
#    'distance': 1384.5579490355208},
#   {'id': 'wXiIxbnFRaFBS9RI4wJrdw',
#    'alias': 'baba-cool-brooklyn',
#    'name': 'Baba Cool',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/n_CzesswTxIUNxHX1XuUkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baba-cool-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 214,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68701, 'longitude': -73.97537},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '64 Lafayette Ave',
#     'address2': 'Ste B',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64 Lafayette Ave', 'Ste B', 'Brooklyn, NY 11217']},
#    'phone': '+13476892344',
#    'display_phone': '(347) 689-2344',
#    'distance': 2600.435369431958},
#   {'id': 'UpPXAjKc-CyuCg72chwd3A',
#    'alias': 'lella-alimentari-brooklyn',
#    'name': 'Lella Alimentari',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/q2epR6g0xR0tMj89o6BR8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lella-alimentari-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 222,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71516, 'longitude': -73.946451},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '325 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['325 Manhattan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17185992625',
#    'display_phone': '(718) 599-2625',
#    'distance': 4169.424717999264},
#   {'id': 'ipygjHXH9PqQS6aqU54RcQ',
#    'alias': 'partners-coffee-brooklyn',
#    'name': 'Partners Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T7330j7npQypa1fl_hqz5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/partners-coffee-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 485,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71796, 'longitude': -73.95921},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '125 N 6th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['125 N 6th St', 'Brooklyn, NY 11249']},
#    'phone': '+13475860063',
#    'display_phone': '(347) 586-0063',
#    'distance': 3278.5492003498985},
#   {'id': 'oLxreLHPGrKFoz7bVzTYUw',
#    'alias': 'cafe-flor-new-york-2',
#    'name': 'Cafe-Flor',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cAx2mieI8ma364zd3-1O-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-flor-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74407, 'longitude': -73.99912},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '218 8th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['218 8th Ave', 'New York, NY 10011']},
#    'phone': '+13479902100',
#    'display_phone': '(347) 990-2100',
#    'distance': 4310.159859133146},
#   {'id': 'gNAMYO9-DQqWiipCDlCqVg',
#    'alias': 'head-hi-brooklyn',
#    'name': 'Head Hi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_-CH0mU3NrpxBG6bJ799fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/head-hi-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bookstores', 'title': 'Bookstores'},
#     {'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.69742, 'longitude': -73.97187},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '14 Clermont Avenue 1L',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 Clermont Avenue 1L', 'Brooklyn, NY 11205']},
#    'phone': '+19179090005',
#    'display_phone': '(917) 909-0005',
#    'distance': 2086.6795378215356},
#   {'id': 'QMwF3MpXNaHJzavVOLRWfA',
#    'alias': 'sugar-miss-tea-cafe-brooklyn-2',
#    'name': 'Sugar Miss Tea Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PJrTtYuoVXlJytssuYM1Pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sugar-miss-tea-cafe-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.640396, 'longitude': -74.007718},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '5309 7th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11220',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5309 7th Ave', 'Brooklyn, NY 11220']},
#    'phone': '+17187992901',
#    'display_phone': '(718) 799-2901',
#    'distance': 7321.1678542179325},
#   {'id': '7IBtDe9DBKEj6-v0MD-aWg',
#    'alias': 'poetica-coffee-brooklyn',
#    'name': 'Poetica Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jutmGI21JN27_YOLsJLSUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/poetica-coffee-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.683249, 'longitude': -73.992623},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '251 Smith St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['251 Smith St', 'Brooklyn, NY 11231']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2477.3704600413084},
#   {'id': 'vrcfSmyE8orhd0yHSrqvgQ',
#    'alias': 'bkg-coffee-roasters-brooklyn-3',
#    'name': 'BKG Coffee Roasters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AGUiBgh2vXViSHT5h2lz-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bkg-coffee-roasters-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 78,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69404, 'longitude': -73.96193},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '557 Myrtle Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['557 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3009.1887231281867},
#   {'id': 'hOJshFD7wCSPeKxOzXTJCg',
#    'alias': 'house-of-saturn-flushing',
#    'name': 'House of Saturn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4azDqCm6BeKNBmoNTZS4WQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/house-of-saturn-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.78263, 'longitude': -73.84616},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '18-18 College Point Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11356',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18-18 College Point Blvd', 'Flushing, NY 11356']},
#    'phone': '+19295108566',
#    'display_phone': '(929) 510-8566',
#    'distance': 15149.539010805027},
#   {'id': 'H2_mpDKae_hILgi0AG_9_A',
#    'alias': 'tap-nyc-new-york',
#    'name': 'Tap NYC',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/es1-S_QT7ENpocaucRbUPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tap-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 207,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'creperies', 'title': 'Creperies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7776844415719,
#     'longitude': -73.9784569824644},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '267 Columbus Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['267 Columbus Ave', 'New York, NY 10023']},
#    'phone': '+19172612094',
#    'display_phone': '(917) 261-2094',
#    'distance': 8142.709984476428},
#   {'id': 'FQ_9HzcX6_vLFnNIJ30jiA',
#    'alias': 'sant-ambroeus-brookfield-new-york',
#    'name': 'Sant Ambroeus Brookfield',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-cWR_qEmfmYRUfgG_DTKqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sant-ambroeus-brookfield-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.713713, 'longitude': -74.014797},
#    'transactions': ['delivery'],
#    'location': {'address1': '200 Vesey St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10281',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 Vesey St', 'New York, NY 10281']},
#    'phone': '+12127320907',
#    'display_phone': '(212) 732-0907',
#    'distance': 1957.5589602092746},
#   {'id': 'VqgqLjiOYAydLXOemivxWw',
#    'alias': 'in-common-nyc-new-york',
#    'name': 'In Common NYC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8JB6PsY_6zSjpj1vaD7y4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/in-common-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.75382, 'longitude': -73.99622},
#    'transactions': [],
#    'location': {'address1': '441 9th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['441 9th Ave', 'New York, NY 10001']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5386.169180327322},
#   {'id': 'I_f_KhuRonsQiQ1llhqVHQ',
#    'alias': 'kodawari-coffee-new-york',
#    'name': 'Kodawari Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qRzbpqixE6mDK70aYOyKmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kodawari-coffee-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7183018824249,
#     'longitude': -73.9927714749158},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '100 Forsyth St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100 Forsyth St', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1435.3755459130114},
#   {'id': 'MYYWU9rEIRZw43lACKXzTQ',
#    'alias': 'yours-truly-new-york-4',
#    'name': 'Yours Truly',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/smCKk0S2k6_bM2akfLm1pQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yours-truly-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 94,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7210275432472,
#     'longitude': -73.9944903889549},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '8 Spring St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8 Spring St', 'New York, NY 10012']},
#    'phone': '+19173882641',
#    'display_phone': '(917) 388-2641',
#    'distance': 1732.792599342473},
#   {'id': '_03n3VP-tujID_SJbeEDeA',
#    'alias': 'two-hands-new-york-5',
#    'name': 'Two Hands',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KT3xWwLRGnWuDPnIS7dh-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/two-hands-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.726277, 'longitude': -73.9956844},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '74 Bleecker St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['74 Bleecker St', 'New York, NY 10012']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2319.39072517498},
#   {'id': '6uPzZapAHWEalyJdkjBqKw',
#    'alias': 'blank-slate-coffee-kitchen-midtown-new-york-2',
#    'name': 'Blank Slate Coffee + Kitchen Midtown',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/j-HTfV6_ztGOmo0DmMp23A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blank-slate-coffee-kitchen-midtown-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 125,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75485, 'longitude': -73.96878},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '941 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['941 2nd Ave', 'New York, NY 10022']},
#    'phone': '+19179701188',
#    'display_phone': '(917) 970-1188',
#    'distance': 5902.40203781674},
#   {'id': 'grhrKtesdFepWhNoeu0z7g',
#    'alias': 'round-k-by-sol-new-york-2',
#    'name': 'Round K by Sol',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NWfXiPhUoAn1AVi5tkQvVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/round-k-by-sol-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7151464197634,
#     'longitude': -73.99313382804394},
#    'transactions': [],
#    'location': {'address1': '78 Canal St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['78 Canal St', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1083.1796452583976},
#   {'id': '4taegd-dJm0xGJOmqG5DtQ',
#    'alias': 'cafe-alula-brooklyn',
#    'name': 'Cafe Alula',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/X-XFFORqq5WL2rJ41zVfZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-alula-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 66,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'lebanese', 'title': 'Lebanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73461, 'longitude': -73.95822},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '252 Franklin St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['252 Franklin St', 'Brooklyn, NY 11222']},
#    'phone': '+17183166161',
#    'display_phone': '(718) 316-6161',
#    'distance': 4446.829557256303},
#   {'id': 'CHBDkg9U4xx6uDanE6tGvA',
#    'alias': 'coffee-project-new-york-fort-greene-brooklyn',
#    'name': 'Coffee Project New York | Fort Greene',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vdbv81x3BFTR0pskJAj1HA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffee-project-new-york-fort-greene-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 78,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6875927899466,
#     'longitude': -73.9792491098683},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '78 Rockwell Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['78 Rockwell Pl', 'Brooklyn, NY 11217']},
#    'phone': '+15858883153',
#    'display_phone': '(585) 888-3153',
#    'distance': 2357.913680206829},
#   {'id': 'jDLKMWhHACb5w1DDtnW9ag',
#    'alias': 'happy-bones-nyc-new-york',
#    'name': 'Happy Bones NYC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8F3z3Mvf2Lk-BRGthuqdPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/happy-bones-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 276,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720726, 'longitude': -73.9970474},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '394 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['394 Broome St', 'New York, NY 10013']},
#    'phone': '+12126733754',
#    'display_phone': '(212) 673-3754',
#    'distance': 1718.756434115631},
#   {'id': 'vROhrixoUwnGr3rgAqGNyw',
#    'alias': 'tb-coffee-house-brooklyn-2',
#    'name': 'TB Coffee House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qz7pKjvSRzVPCLz8I9xdsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tb-coffee-house-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.693829, 'longitude': -73.961411},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '578 Myrtle Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['578 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+19173972719',
#    'display_phone': '(917) 397-2719',
#    'distance': 3058.153908809779},
#   {'id': '0S4MwamlsiHD8g2KZNPtIA',
#    'alias': 'parlor-coffee-brooklyn-2',
#    'name': 'Parlor Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CUhToqzD2isB2JwD1quRMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/parlor-coffee-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69748, 'longitude': -73.97041},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '11 Vanderbilt Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 Vanderbilt Ave', 'Brooklyn, NY 11205']},
#    'phone': '+19179666070',
#    'display_phone': '(917) 966-6070',
#    'distance': 2203.5234679492887},
#   {'id': '7XglHMuiV6q7BWkpjP2HWg',
#    'alias': 'ito-en-brooklyn',
#    'name': 'ITO En',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4XQvCU4Up4FZhtWhu8gZsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ito-en-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7040351, 'longitude': -73.9867238},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '20 Jay St',
#     'address2': 'Ste 530',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['20 Jay St', 'Ste 530', 'Brooklyn, NY 11201']},
#    'phone': '+17182504000',
#    'display_phone': '(718) 250-4000',
#    'distance': 657.0346914837561},
#   {'id': '_l40VhhS3pNm55yZTLgLuw',
#    'alias': 'velvet-brooklyn-brooklyn-2',
#    'name': 'Velvet Brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Kxs0OpGO0SIRpMxHrlpt9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/velvet-brooklyn-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7100847891067,
#     'longitude': -73.9625787734985},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '174 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['174 Broadway', 'Brooklyn, NY 11211']},
#    'phone': '+17183024427',
#    'display_phone': '(718) 302-4427',
#    'distance': 2722.5672262380717},
#   {'id': 'DA1hijID0q6D6Ouch17v7w',
#    'alias': 'pecks-new-york',
#    'name': "Peck's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/H_hr9SJgmj0fOZZIdYCDQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pecks-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 150,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.693489, 'longitude': -73.967376},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '455A Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['455A Myrtle Ave', 'New York, NY 11205']},
#    'phone': '+13476894969',
#    'display_phone': '(347) 689-4969',
#    'distance': 2638.841789597834},
#   {'id': '_NS1hEZ0LPwaTG4R6jxgnw',
#    'alias': 'cafe-sabarsky-new-york-4',
#    'name': 'Cafe Sabarsky',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8dk88iFlkJH7R720j_igQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-sabarsky-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 505,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'austrian', 'title': 'Austrian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78122494966741,
#     'longitude': -73.9602662713214},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1048 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1048 5th Ave', 'New York, NY 10028']},
#    'phone': '+12122880665',
#    'display_phone': '(212) 288-0665',
#    'distance': 8900.614315463365},
#   {'id': 'mU23NlQfn1R9OhA6WMe_xg',
#    'alias': 'breads-bakery-new-york',
#    'name': 'Breads Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mDaSWYX8hEV0eNGXJSDhVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/breads-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1080,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73661, 'longitude': -73.99181},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '18 E 16th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18 E 16th St', 'New York, NY 10003']},
#    'phone': '+12126332253',
#    'display_phone': '(212) 633-2253',
#    'distance': 3470.824425100059},
#   {'id': 'qauE0RX0J519WJw1zjI3VQ',
#    'alias': 'ost-cafe-new-york-3',
#    'name': 'Ost Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6dMbqJ1aW42NEqIrXZlowg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ost-cafe-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71445, 'longitude': -73.98214},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '511 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['511 Grand St', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1433.654815832446},
#   {'id': 'VdAVjghEq_Zl-DDte0mjrw',
#    'alias': 'acre-brooklyn',
#    'name': 'ACRE',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7KYC_xb8ZZCOrf-SVR1Nbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/acre-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72633, 'longitude': -73.95471},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '64 Meserole Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64 Meserole Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17189549074',
#    'display_phone': '(718) 954-9074',
#    'distance': 4062.4881140396897},
#   {'id': 'ml5hBBDsEILy9WsTQyyV-Q',
#    'alias': 'b-cup-café-new-york-5',
#    'name': 'B Cup Café',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-Ow6irDxjC5gOazKhJ2rAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b-cup-caf%C3%A9-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 384,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.728708, 'longitude': -73.978827},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '212 Ave B',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['212 Ave B', 'New York, NY 10009']},
#    'phone': '+12122284808',
#    'display_phone': '(212) 228-4808',
#    'distance': 2896.9287307264567},
#   {'id': 'fi8ATHFkHnZgFGJWZUl_BA',
#    'alias': 'aunts-et-uncles-brooklyn',
#    'name': 'Aunts et Uncles',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Yy4I3wYHY-6i4O4lanwpUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aunts-et-uncles-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.65207, 'longitude': -73.94954},
#    'transactions': [],
#    'location': {'address1': '1407 Nostrand Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11226',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1407 Nostrand Ave', 'Brooklyn, NY 11226']},
#    'phone': '+13472950001',
#    'display_phone': '(347) 295-0001',
#    'distance': 7033.431647286674},
#   {'id': 'Bw9b6vDTKXAOg7c3bcR9PA',
#    'alias': 'salento-colombian-coffee-and-kitchen-new-york',
#    'name': 'Salento Colombian Coffee & Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/r5RZwPT1_Q_gzFk3RjSzwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salento-colombian-coffee-and-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'colombian', 'title': 'Colombian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.83786, 'longitude': -73.9386},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '2112 Amsterdam Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10032',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2112 Amsterdam Ave', 'New York, NY 10032']},
#    'phone': '+16467670680',
#    'display_phone': '(646) 767-0680',
#    'distance': 15452.150604207354},
#   {'id': 'yBBKdMVbGjSPAgxhDT8zMg',
#    'alias': 'early-brooklyn',
#    'name': 'Early',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EJbftTxGbXfB04TMsz0gsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/early-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 105,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.732151, 'longitude': -73.9548187},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '967 Manhattan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['967 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183836963',
#    'display_phone': '(718) 383-6963',
#    'distance': 4459.102478766493},
#   {'id': 'mv4A3Yl90ZLONO03ksqRrg',
#    'alias': 'ix-restaurant-brooklyn-3',
#    'name': 'Ix Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gbpNfFJfJhWVXtbb6iWotA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ix-restaurant-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 167,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6609148441096,
#     'longitude': -73.9613892462263},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '43 Lincoln Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11225',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43 Lincoln Rd', 'Brooklyn, NY 11225']},
#    'phone': '+13475336920',
#    'display_phone': '(347) 533-6920',
#    'distance': 5675.861543925705},
#   {'id': 'A7b42aJOIP-idMY_f2gZBg',
#    'alias': 'matchaful-new-york-7',
#    'name': 'Matchaful',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/awQ2Mq6j_VH8p9BUpqg19Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/matchaful-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72224, 'longitude': -73.9962999},
#    'transactions': [],
#    'location': {'address1': '217 Mulberry St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['217 Mulberry St', 'New York, NY 10012']},
#    'phone': '+16468469077',
#    'display_phone': '(646) 846-9077',
#    'distance': 1875.1746267785463},
#   {'id': 'jNg1sTtGW_Vn3rl6mDubdA',
#    'alias': 'irving-farm-new-york-new-york-20',
#    'name': 'Irving Farm New York',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9VnHlqma2Q5ARnpF9OQtkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/irving-farm-new-york-new-york-20?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.742466, 'longitude': -73.9834918},
#    'transactions': ['delivery'],
#    'location': {'address1': '121 E 27th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['121 E 27th St', 'New York, NY 10016']},
#    'phone': '+12122060707',
#    'display_phone': '(212) 206-0707',
#    'distance': 4215.991225072418},
#   {'id': 'MN17Htz75s1aZvO5nltzPA',
#    'alias': 'haven-cafe-new-york',
#    'name': 'Haven Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gnfsKwbuUOQduwFOOKGnhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/haven-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71885, 'longitude': -73.99668},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '147 Mott St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['147 Mott St', 'New York, NY 10013']},
#    'phone': '+16462076574',
#    'display_phone': '(646) 207-6574',
#    'distance': 1503.0474404150254},
#   {'id': 'IkyRp47Jpbk_AQ35qlr-eg',
#    'alias': 'bird-and-branch-new-york',
#    'name': 'Bird & Branch',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bfE4s07iwI9J55azu9UkNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bird-and-branch-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 318,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7603099, 'longitude': -73.99087},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '359 West 45th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['359 West 45th St', 'New York, NY 10036']},
#    'phone': '+19172658444',
#    'display_phone': '(917) 265-8444',
#    'distance': 6107.008532343116},
#   {'id': 'Usmh6aAwaf6YRQEucPt-jw',
#    'alias': 'café-kitsuné-new-york-new-york',
#    'name': 'Café Kitsuné New York',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PUUYY1NmOt3iiCLXft_i6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-kitsun%C3%A9-new-york-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73505, 'longitude': -74.0059},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '550 Hudson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['550 Hudson St', 'New York, NY 10014']},
#    'phone': '+16467558158',
#    'display_phone': '(646) 755-8158',
#    'distance': 3434.244750123242},
#   {'id': 'hcGcjMrRcVSLzmBIsMIcwQ',
#    'alias': 'chez-les-frenchies-new-york-2',
#    'name': 'Chez Les Frenchies',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rpEgkpfwBllk80V74IoGug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chez-les-frenchies-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'creperies', 'title': 'Creperies'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7687, 'longitude': -73.95182},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '501 E 75th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['501 E 75th St', 'New York, NY 10021']},
#    'phone': '+13474625346',
#    'display_phone': '(347) 462-5346',
#    'distance': 7894.600368564261}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                 Restaurant          Type Price Rating         Address  \
# 0  OXA House Coffee & Tea   Coffee & Tea                 102 Broadway
# 1        Madame Bonté Café         Cafes                 1834 2nd Ave
# 2         Saltwater Coffee  Coffee & Tea               126 Waverly Pl
# 3                Two Hands         Cafes    $$    3.5     164 Mott St
# 4            Saturdays NYC  Coffee & Tea    $$      4    31 Crosby St
#
#          Lat        Lng                                                url  \
# 0  40.710300 -73.965130
# 1  40.783310 -73.947560
# 2  40.732815 -73.999850
# 3  40.719688 -73.996105  https://www.yelp.com/biz/two-hands-new-york-3?...
# 4  40.720790 -73.999440  https://www.yelp.com/biz/saturdays-nyc-new-yor...
#
#                        ID
# 0
# 1
# 2
# 3  DiMjV0XcRGybywKE0JTfZQ
# 4  a8d18n8gAQpQHcr6KwCCeA

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"cafe","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [{'id': 'VHORZQg5A3YNBptRN92QGg',
#    'alias': 'the-lazy-llama-coffee-bar-new-york-2',
#    'name': 'The Lazy Llama Coffee Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/S_ZtGbbfVEIFbrUcGofUJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lazy-llama-coffee-bar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 100,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.723505897000265,
#     'longitude': -73.98873335337309},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '72 E 1st Street',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['72 E 1st Street', 'New York, NY 10003']},
#    'phone': '+16464101938',
#    'display_phone': '(646) 410-1938',
#    'distance': 2062.2377032766435},
#   {'id': 'z5IMh69DbE7TJ5LFhw_qvQ',
#    'alias': 'cafe-ubani-new-york',
#    'name': 'Cafe Ubani',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bTVIdN6s0dRFmcOFMkiNUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-ubani-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.73005, 'longitude': -74.00417},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '37A Bedford St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37A Bedford St', 'New York, NY 10014']},
#    'phone': '+16466785595',
#    'display_phone': '(646) 678-5595',
#    'distance': 2811.9960172923793},
#   {'id': 'mv8dMMzzrzalso3sYCP_QA',
#    'alias': 'café-luluc-brooklyn-2',
#    'name': 'CAFÉ LULUc',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-DzDbYF-Qf3jxYy7pr8Q4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-luluc-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1479,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68451, 'longitude': -73.99225},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '214 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['214 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17186253815',
#    'display_phone': '(718) 625-3815',
#    'distance': 2334.479697543251},
#   {'id': 'unjpqbSvkaldY4iQkVAn6Q',
#    'alias': 'maman-university-place-new-york',
#    'name': 'Maman University Place',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4aB_xL7sr1SOJfa3xIw-Cg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maman-university-place-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.732863, 'longitude': -73.993403},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '67 University Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['67 University Pl', 'New York, NY 10003']},
#    'phone': '+16467670097',
#    'display_phone': '(646) 767-0097',
#    'distance': 3048.598466571789},
#   {'id': 'oBcuOhubYwHV_bY35lu5hA',
#    'alias': 'petees-cafe-brooklyn-4',
#    'name': "Petee's Cafe",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xExFxShGqOg7KuKQqQlBDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/petees-cafe-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 111,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.693794, 'longitude': -73.964702},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '505 Myrtle Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['505 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+16464943630',
#    'display_phone': '(646) 494-3630',
#    'distance': 2811.0519873458315},
#   {'id': 'xHBpwGzxxbC3vTahHWdABg',
#    'alias': 'perk-kafe-new-york',
#    'name': 'Perk Kafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Vdc89zdAqvqORqgVsWvkqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/perk-kafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 406,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.747764735907,
#     'longitude': -73.9770407671092},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '162 E 37th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 E 37th St', 'New York, NY 10016']},
#    'phone': '+12126867375',
#    'display_phone': '(212) 686-7375',
#    'distance': 4925.2051311799305},
#   {'id': 'gectwf0ELo4uBpgBFCnRCQ',
#    'alias': 'blend-coffee-cowork-brooklyn',
#    'name': 'Blend: Coffee + CoWork',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KMjILWWznsVISZanrzLzVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blend-coffee-cowork-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 74,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.63513, 'longitude': -74.02352},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '6808 4th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11220',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6808 4th Ave', 'Brooklyn, NY 11220']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8196.38603001257},
#   {'id': 'ziIb68Res3eMw7fz83yFxw',
#    'alias': 'two-hands-brooklyn',
#    'name': 'Two Hands',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YXZu5menvcoJkP3p-m8Luw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/two-hands-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71614308047852,
#     'longitude': -73.96630579723887},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '262 Kent Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['262 Kent Ave', 'Brooklyn, NY 11249']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2641.944538375531},
#   {'id': 'yMxGI1kcqv6a-aGH-VXg8A',
#    'alias': 'little-skips-east-brooklyn-2',
#    'name': 'Little Skips East',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XC_z6chuyn8ivjNGRhzhsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-skips-east-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 75,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6849363759513,
#     'longitude': -73.9137830212712},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1643 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11207',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1643 Broadway', 'Brooklyn, NY 11207']},
#    'phone': '+17184841555',
#    'display_phone': '(718) 484-1555',
#    'distance': 7160.390241526564},
#   {'id': 'ipAsHykRvgJzpx5hD8vTJw',
#    'alias': 'tokuyama-salon-café-new-york',
#    'name': 'Tokuyama Salon Café',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1wtAhlzaf5Mltj2Elz2YIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tokuyama-salon-caf%C3%A9-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72399, 'longitude': -73.9802},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '627 E 6th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['627 E 6th St', 'New York, NY 10009']},
#    'phone': '+12123881276',
#    'display_phone': '(212) 388-1276',
#    'distance': 2383.746233733969},
#   {'id': 'VLC2DROxvGX-ka_aBmJN9w',
#    'alias': 'social-house-cafe-brooklyn',
#    'name': 'Social House Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XHkG8Rw-KLF4-FCKP_kTkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/social-house-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7102965207822, 'longitude': -73.966014},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '60 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Broadway', 'Brooklyn, NY 11249']},
#    'phone': '+19292950397',
#    'display_phone': '(929) 295-0397',
#    'distance': 2443.9586408622786},
#   {'id': 'XbUg52y01_fcIzz7MEUHxQ',
#    'alias': 'café-leon-dore-new-york',
#    'name': 'Café Leon Dore',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/59UUjkjAtModG2gy7LW2Lw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-leon-dore-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7221012731031,
#     'longitude': -73.9961103853269},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '214 Mulberry St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['214 Mulberry St', 'New York, NY 10012']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1858.4278378870495},
#   {'id': 'fPQ2eE9lm8tc87O5-GLjyA',
#    'alias': 'mille-feuille-bakery-new-york-3',
#    'name': 'Mille-Feuille Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8u453wcp-jdwfV9kpimDQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mille-feuille-bakery-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 355,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.782425, 'longitude': -73.9811603},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2175 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2175 Broadway', 'New York, NY 10024']},
#    'phone': '+12123626261',
#    'display_phone': '(212) 362-6261',
#    'distance': 8630.99662794525},
#   {'id': '3blPn5WuFEPnDppFgkPoMQ',
#    'alias': 'coffee-project-new-york-chelsea-new-york-3',
#    'name': 'Coffee Project New York | Chelsea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OkEic3RQEw_eQ83ZEK-Emg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffee-project-new-york-chelsea-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.741816, 'longitude': -73.997095},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '155 7th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['155 7th Ave', 'New York, NY 10011']},
#    'phone': '+19173883399',
#    'display_phone': '(917) 388-3399',
#    'distance': 4040.5584861596785},
#   {'id': 'WDLly49QF8sSSMJ6BhaXRA',
#    'alias': 'black-star-bakery-long-island-city',
#    'name': 'Black Star Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7OUmugd20cxpnx4sKTfDdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-star-bakery-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.742804948206555,
#     'longitude': -73.95383134315261},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '10-01 50th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10-01 50th Ave', 'Long Island City, NY 11101']},
#    'phone': '+13475271636',
#    'display_phone': '(347) 527-1636',
#    'distance': 5374.382478407519},
#   {'id': 'x_YWFkTcxEu1lo8Nlrog5A',
#    'alias': 'milk-and-honey-cafe-brooklyn-2',
#    'name': 'Milk & Honey Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-txlFHdTzFzCxCnAqaujTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/milk-and-honey-cafe-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1157,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.634356735221,
#     'longitude': -73.9661046515558},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1119 Newkirk Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11230',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1119 Newkirk Ave', 'Brooklyn, NY 11230']},
#    'phone': '+17185130441',
#    'display_phone': '(718) 513-0441',
#    'distance': 8254.401610805717},
#   {'id': 'jWC4mD-yy-IzuZxU5ctAKw',
#    'alias': 'mias-bakery-brooklyn',
#    'name': "Mia's Bakery",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-_RVN3QbCDs6ScFwP_0hqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mias-bakery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 852,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6870199, 'longitude': -73.9901299},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '139 Smith St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['139 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+13479873194',
#    'display_phone': '(347) 987-3194',
#    'distance': 2081.025885948994},
#   {'id': 'Rs196agFk9VEW2mHrOwpvw',
#    'alias': '12-corners-new-york-4',
#    'name': '12 Corners',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yEkNTNvbElGSUKV62a-dlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/12-corners-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 157,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7180405, 'longitude': -73.9972076},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '121 Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['121 Mott St', 'New York, NY 10013']},
#    'phone': '+12126258888',
#    'display_phone': '(212) 625-8888',
#    'distance': 1419.795430699577},
#   {'id': 'S3qnPndTrNlgJnf_5oOrag',
#    'alias': 'secret-garden-brooklyn-4',
#    'name': 'Secret Garden',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/b2kGwU9zDc7ST-oj5MIaxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/secret-garden-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.683746, 'longitude': -73.935023},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '347 Lewis Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['347 Lewis Ave', 'Brooklyn, NY 11233']},
#    'phone': '+13472210719',
#    'display_phone': '(347) 221-0719',
#    'distance': 5547.65490461958},
#   {'id': '3IHtxjuE25_phqDyn6TZRw',
#    'alias': 'partners-coffee-new-york-3',
#    'name': 'Partners Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/o07-cSMKNvVR4ZqibV0ncg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/partners-coffee-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 140,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'internetcafe', 'title': 'Internet Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7349, 'longitude': -74.00228},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '44 Charles St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['44 Charles St', 'New York, NY 10014']},
#    'phone': '+16465901924',
#    'display_phone': '(646) 590-1924',
#    'distance': 3346.33577299331},
#   {'id': '81x1nBpEIpiz1Bo4-j6jpw',
#    'alias': 'cafe-sandra-new-york-2',
#    'name': 'Cafe Sandra',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/S--prpLma8izqGiNko3HcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-sandra-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72978, 'longitude': -73.9835},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '194 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['194 1st Ave', 'New York, NY 10009']},
#    'phone': '+16469645606',
#    'display_phone': '(646) 964-5606',
#    'distance': 2852.98439989339},
#   {'id': 'bMepacmKDTwCdHJAU860bQ',
#    'alias': 'le-café-coffee-new-york-2',
#    'name': 'Le Café Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ROZ9xDQ127FSxhuve3E8mA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-caf%C3%A9-coffee-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 174,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7357460797343,
#     'longitude': -73.9928742229649},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '7 E 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 E 14th St', 'New York, NY 10003']},
#    'phone': '+12123651060',
#    'display_phone': '(212) 365-1060',
#    'distance': 3371.45915952521},
#   {'id': 'IoH3Ge5pRjo4pWRI9T_EIA',
#    'alias': 'waypoint-cafe-new-york',
#    'name': 'Waypoint Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B8dqMqkmrZkWAT8xjIgT2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/waypoint-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'internetcafe', 'title': 'Internet Cafes'},
#     {'alias': 'lancenters', 'title': 'LAN Centers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71728, 'longitude': -73.98991},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '65 Ludlow St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['65 Ludlow St', 'New York, NY 10002']},
#    'phone': '+16466827165',
#    'display_phone': '(646) 682-7165',
#    'distance': 1367.566279061341},
#   {'id': 't6TzNUUY2ez6s-GYOLs4VA',
#    'alias': 'bluestone-lane-manhattan-west-new-york',
#    'name': 'Bluestone Lane - Manhattan West',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zyr9ZwU191rnm0nLB-FDfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bluestone-lane-manhattan-west-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 112,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7520681, 'longitude': -73.9988477},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '435 W 31st St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['435 W 31st St', 'New York, NY 10001']},
#    'phone': '+17183746858',
#    'display_phone': '(718) 374-6858',
#    'distance': 5198.4473246440475},
#   {'id': 'V4kHBho4ZiNdbuztgn0LWQ',
#    'alias': 'cafe-grumpy-new-york-6',
#    'name': 'Cafe Grumpy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5kGH5XqF475f8J208MrJBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-grumpy-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 122,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71512, 'longitude': -73.99015},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '13 Essex St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['13 Essex St', 'New York, NY 10002']},
#    'phone': '+12127777515',
#    'display_phone': '(212) 777-7515',
#    'distance': 1133.8186439848807},
#   {'id': 'gfgbbPRqVqSj_rxlSwhJhg',
#    'alias': 'black-star-bakery-and-cafe-long-island-city',
#    'name': 'Black Star Bakery & Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VW3TAoB9FGh57CMRUSBpCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-star-bakery-and-cafe-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 135,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7433494, 'longitude': -73.9580353},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2-10 50th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2-10 50th Ave', 'Long Island City, NY 11101']},
#    'phone': '+17184339189',
#    'display_phone': '(718) 433-9189',
#    'distance': 5212.243615213465},
#   {'id': '1uj4-rdYAQF6Amc0LVaeXg',
#    'alias': 'the-black-flamingo-brooklyn',
#    'name': 'The Black Flamingo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YX1FHLG5Dr4ObepyXOgVCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-black-flamingo-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 61,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6790846825271,
#     'longitude': -74.0106727985259},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '281 Van Brunt St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['281 Van Brunt St', 'Brooklyn, NY 11231']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3240.1407985733035},
#   {'id': 'mR8MfMcFNgEukDG08I2aDQ',
#    'alias': 'ludlow-coffee-supply-new-york',
#    'name': 'Ludlow Coffee Supply',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zfDWcTSyLBIsMx1PKHzazQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ludlow-coffee-supply-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 250,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.721668, 'longitude': -73.987274},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '176 Ludlow St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['176 Ludlow St', 'New York, NY 10002']},
#    'phone': '+19174727632',
#    'display_phone': '(917) 472-7632',
#    'distance': 1895.3083101128234},
#   {'id': '3t4VJC1vyUGk0aaem3b5ng',
#    'alias': 'ceremonia-bakeshop-brooklyn',
#    'name': 'Ceremonia Bakeshop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4QcEFcXoB6EHY8-zsj_hLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ceremonia-bakeshop-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 98,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7125, 'longitude': -73.96056},
#    'transactions': ['delivery'],
#    'location': {'address1': '743 Driggs Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['743 Driggs Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13473842212',
#    'display_phone': '(347) 384-2212',
#    'distance': 2952.0083122815354},
#   {'id': 'FkxRk1CUEhgBWRzFadkAaQ',
#    'alias': 'paper-coffee-new-york',
#    'name': 'Paper Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/f9d1K8FZGwJuj0h9oqsbug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paper-coffee-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 116,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7463281632382,
#     'longitude': -73.9896308128189},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '44 W 29th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['44 W 29th St', 'New York, NY 10001']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4562.9566139806},
#   {'id': 'JWLRT0dkdaC7AHtYapWbGw',
#    'alias': 'pasticceria-rocco-new-york',
#    'name': 'Pasticceria Rocco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_OAdfVr9GOg2ihEzcKXeiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pasticceria-rocco-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1052,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73083, 'longitude': -74.00265},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '243 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['243 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12122426031',
#    'display_phone': '(212) 242-6031',
#    'distance': 2909.8673181164463},
#   {'id': 'yicBRA8X7urJyKn6aF2wzw',
#    'alias': 'sullivan-street-bakery-new-york-4',
#    'name': 'Sullivan Street Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/C5EOOhqnVAhEA9ay3zwXUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sullivan-street-bakery-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 282,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7474103457198,
#     'longitude': -74.0005904621599},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '236 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['236 9th Ave', 'New York, NY 10001']},
#    'phone': '+12129295900',
#    'display_phone': '(212) 929-5900',
#    'distance': 4684.439691978602},
#   {'id': 'sVkwEFET38Myz3dM1uZpiw',
#    'alias': 'reunion-brooklyn-2',
#    'name': 'Reunion',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RnyH19nHvM-zJRUGOPm6mA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/reunion-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 486,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7171, 'longitude': -73.95164},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '544 Union Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['544 Union Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17185993670',
#    'display_phone': '(718) 599-3670',
#    'distance': 3807.329952370319},
#   {'id': 'neqjsm1AbaGcLDRNshEA7A',
#    'alias': 'gregorys-coffee-brooklyn-2',
#    'name': 'Gregorys Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-AF41sXXGof2rUS1vaT0CA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gregorys-coffee-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.693613, 'longitude': -73.990789},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '16 Court St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['16 Court St', 'Brooklyn, NY 11201']},
#    'phone': '+19293376368',
#    'display_phone': '(929) 337-6368',
#    'distance': 1346.179208376056},
#   {'id': 'a0IET3_yCFcO36OqGSsisg',
#    'alias': 'eataly-flatiron-new-york',
#    'name': 'Eataly Flatiron',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/n9MMv47vKQiiUyeRSJkTDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eataly-flatiron-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5710,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74195877796, 'longitude': -73.989716662832},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '200 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 5th Ave', 'New York, NY 10010']},
#    'phone': '+12122292560',
#    'display_phone': '(212) 229-2560',
#    'distance': 4078.4333537925154},
#   {'id': 'aI1yals6ghSQuXS_vMIbPw',
#    'alias': 'cafe-one-new-york',
#    'name': 'Cafe One',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PAqCCRbre8n86eNw9Bk07w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-one-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 203,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.822166, 'longitude': -73.949569},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1619 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10031',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1619 Amsterdam Ave', 'New York, NY 10031']},
#    'phone': '+12126900060',
#    'display_phone': '(212) 690-0060',
#    'distance': 13507.243654542051},
#   {'id': 'h6qbszNgXgjj9Lrb62m-9w',
#    'alias': 'the-uncommons-new-york',
#    'name': 'The Uncommons',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/23Mnb_KXYfPD2SAzEvB6YA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-uncommons-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 385,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tabletopgames', 'title': 'Tabletop Games'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72933, 'longitude': -73.99865},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '230 Thompson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['230 Thompson St', 'New York, NY 10012']},
#    'phone': '+16465439215',
#    'display_phone': '(646) 543-9215',
#    'distance': 2683.826935437106},
#   {'id': '8RhQa17pxUA9GukTX37PQw',
#    'alias': 'desert-rose-cafe-new-york',
#    'name': 'Desert Rose Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NxsaTpYW5C3snKKNophdIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/desert-rose-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72828, 'longitude': -73.98532},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '350 E 9th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['350 E 9th St', 'New York, NY 10003']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2648.956593413775},
#   {'id': 'rd0VGG_d_qNp_aBW_HJM4w',
#    'alias': 'third-rail-coffee-new-york',
#    'name': 'Third Rail Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vxOIeyZiQSVsB-h8-j1UWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/third-rail-coffee-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 474,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72994, 'longitude': -73.99959},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '240 Sullivan St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['240 Sullivan St', 'New York, NY 10012']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2765.2849385347295},
#   {'id': 'JylIStPfFLOctHdlglvALA',
#    'alias': 'ut47-new-york-3',
#    'name': 'UT47',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/X3kei7Z_5H5dvGMsUm6h4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ut47-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 280,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76135, 'longitude': -73.98995},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '358 W 47th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['358 W 47th St', 'New York, NY 10036']},
#    'phone': '+19172658629',
#    'display_phone': '(917) 265-8629',
#    'distance': 6224.258326293521},
#   {'id': 'O0RxMO7AYZCMnOis7a08EA',
#    'alias': 'espresso-me-brooklyn-3',
#    'name': 'Espresso Me',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xNXkh83BipO-q4tRL175VQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/espresso-me-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.690892864574636,
#     'longitude': -73.99723224490806},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '88 Atlantic Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['88 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+19175195538',
#    'display_phone': '(917) 519-5538',
#    'distance': 1636.9663891136083},
#   {'id': 'v4d2TBqxMmNzWNvShkvRrA',
#    'alias': 'freehold-brooklyn',
#    'name': 'FREEHOLD',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LwilMjSn476ceZrasR1cJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/freehold-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 535,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7136054, 'longitude': -73.965905},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '45 S 3rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 S 3rd St', 'Brooklyn, NY 11249']},
#    'phone': '+17183887591',
#    'display_phone': '(718) 388-7591',
#    'distance': 2559.0795946097583},
#   {'id': 'NfuHyyXieKyq0vScjHWATg',
#    'alias': 'east-one-coffee-roasters-brooklyn',
#    'name': 'East One Coffee Roasters',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AVGtInJbOaazEKB5P_AyJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/east-one-coffee-roasters-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 175,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6812982171111,
#     'longitude': -73.9966663404755},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '384 Court St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['384 Court St', 'Brooklyn, NY 11231']},
#    'phone': '+13479874919',
#    'display_phone': '(347) 987-4919',
#    'distance': 2692.425882403761},
#   {'id': 'OiqGAhC5EQXb1CaNxxvfBQ',
#    'alias': 'harney-and-sons-soho-new-york',
#    'name': 'Harney & Sons SoHo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MuWnp_KUOvoso5KPqtTryA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harney-and-sons-soho-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 743,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7214398332376,
#     'longitude': -73.9994008558221},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '433 Broome St',
#     'address2': '',
#     'address3': 'Ground Fl',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['433 Broome St', 'Ground Fl', 'New York, NY 10013']},
#    'phone': '+12129334853',
#    'display_phone': '(212) 933-4853',
#    'distance': 1829.9148841424953},
#   {'id': 'DNQm5Z2fV06DwfmwH2WpsQ',
#    'alias': 'kava-social-brooklyn',
#    'name': 'Kava Social',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4uQXhZUiku0I7OdrOnFLKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kava-social-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71983, 'longitude': -73.955945},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '120 Bedford Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['120 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17185995282',
#    'display_phone': '(718) 599-5282',
#    'distance': 3607.8250492231664},
#   {'id': 'uk34HIU-ILX2A-FRs1Or3g',
#    'alias': 'kaffe-1668-south-new-york',
#    'name': 'Kaffe 1668 South',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qprmeh1KnhY5JfPWBwkVeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaffe-1668-south-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 693,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.715171, 'longitude': -74.010925},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '275 Greenwich St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['275 Greenwich St', 'New York, NY 10007']},
#    'phone': '+12126933750',
#    'display_phone': '(212) 693-3750',
#    'distance': 1772.5932159246897},
#   {'id': 'VUYIIMfDa-6UD8seDmYLaA',
#    'alias': 'daughter-brooklyn',
#    'name': 'Daughter',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_bh4TcSsFHbRi5tUL6svww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daughter-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.67105, 'longitude': -73.94237},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1090 St Johns Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11213',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1090 St Johns Pl', 'Brooklyn, NY 11213']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5812.717339892859},
#   {'id': '0zcgBHXbaJn0ZxgpcTJ1aQ',
#    'alias': 'nostrand-cafe-brooklyn',
#    'name': 'Nostrand Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KhJnkmsbPJAld9kjLqrIfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nostrand-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.689746, 'longitude': -73.951286},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '261 Nostrand Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['261 Nostrand Ave', 'Brooklyn, NY 11216']},
#    'phone': '+17189758588',
#    'display_phone': '(718) 975-8588',
#    'distance': 4028.5716941023393},
#   {'id': '0wSOGZrj4ILpZSgE7SaYuw',
#    'alias': 'the-bean-new-york-3',
#    'name': 'The Bean',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lwVfPk-FD2JzCMvjNVtLSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bean-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 495,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.725594193655574,
#     'longitude': -73.98954849979374},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '54 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['54 2nd Ave', 'New York, NY 10003']},
#    'phone': '+19172620929',
#    'display_phone': '(917) 262-0929',
#    'distance': 2275.907411691058},
#   {'id': 'RvRvU-xl5PYFrZ0KSU6CUQ',
#    'alias': 'café-beit-brooklyn-3',
#    'name': 'Café Beit',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OMGQdfcqhc1PBUV0x_DDrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-beit-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 102,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.718678, 'longitude': -73.9571094},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '158 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['158 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+19179091430',
#    'display_phone': '(917) 909-1430',
#    'distance': 3462.2899599027282}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#                   Restaurant      Type Price Rating           Address  \
# 0  The Lazy Llama Coffee Bar  Bakeries    $$    4.5   72 E 1st Street
# 1                 Cafe Ubani     Cafes                 37A Bedford St
# 2                 CAFÉ LULUc    French    $$      4      214 Smith St
# 3     Maman University Place     Cafes               67 University Pl
# 4               Petee's Cafe     Cafes    $$      4    505 Myrtle Ave
#
#          Lat        Lng                                                url  \
# 0  40.723506 -73.988733  https://www.yelp.com/biz/the-lazy-llama-coffee...
# 1  40.730050 -74.004170
# 2  40.684510 -73.992250  https://www.yelp.com/biz/caf%C3%A9-luluc-brook...
# 3  40.732863 -73.993403
# 4  40.693794 -73.964702  https://www.yelp.com/biz/petees-cafe-brooklyn-...
#
#                        ID
# 0  VHORZQg5A3YNBptRN92QGg
# 1
# 2  mv8dMMzzrzalso3sYCP_QA
# 3
# 4  oBcuOhubYwHV_bY35lu5hA

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                           Restaurant                 Type Rating Price  \
# 0                       Society Cafe       American (New)      4    $$
# 1               Citizens Of Gramercy           Australian      4    $$
# 2    Hole In The Wall - Williamsburg           Australian    4.5    $$
# 3          The Lazy Llama Coffee Bar             Bakeries    4.5    $$
# 4                         HARBS SoHo             Bakeries      4    $$
# 5                             Butler             Bakeries
# 6           Black Star Bakery & Cafe             Bakeries      4     $
# 7                      Breads Bakery             Bakeries    4.5    $$
# 8                       Mia's Bakery             Bakeries    4.5     $
# 9                 Ceremonia Bakeshop             Bakeries
# 10                 Pasticceria Rocco             Bakeries      4     $
# 11                       Cafe Patoro             Bakeries    4.5     $
# 12            Sullivan Street Bakery             Bakeries    3.5    $$
# 13                  Takahachi Bakery             Bakeries      4    $$
# 14                            Peck's             Bakeries      4    $$
# 15                         Book Club           Bookstores
# 16                          Usagi NY           Bookstores    4.5    $$
# 17                  Hole In The Wall   Breakfast & Brunch    4.5    $$
# 18                          Weekends   Breakfast & Brunch    4.5     $
# 19              Sunflower - Gramercy   Breakfast & Brunch    4.5    $$
# 20                            Koneko   Breakfast & Brunch    4.5    $$
# 21                           Reunion   Breakfast & Brunch      4    $$
# 22                            Banter   Breakfast & Brunch    4.5    $$
# 23                            Suited   Breakfast & Brunch      5    $$
# 24                            Banter   Breakfast & Brunch    4.5    $$
# 25                              ACRE   Breakfast & Brunch
# 26                          Bee Cafe           Bubble Tea    4.5     $
# 27                     Secret Garden                Cafes
# 28                      Petee's Cafe                Cafes      4    $$
# 29                         Two Hands                Cafes
# ..                               ...                  ...    ...   ...
# 170                           Bakeri         Coffee & Tea      4     $
# 171                     Blank Street         Coffee & Tea
# 172                              MUD         Coffee & Tea      4    $$
# 173                 Lella Alimentari         Coffee & Tea    4.5    $$
# 174                   capo capo cafe         Coffee & Tea
# 175                  Partners Coffee         Coffee & Tea      4     $
# 176       Blackstone Coffee Roasters         Coffee & Tea      5    $$
# 177                     Little Canal         Coffee & Tea      4     $
# 178         Black Star Bakery & Cafe         Coffee & Tea
# 179                        Cafe-Flor         Coffee & Tea
# 180                Kaigo Coffee Room         Coffee & Tea
# 181                     Caffe Aronne         Coffee & Tea
# 182         East One Coffee Roasters    Coffee Roasteries      4    $$
# 183                  Kodawari Coffee    Coffee Roasteries      4    $$
# 184                       Sey Coffee    Coffee Roasteries    4.5     $
# 185               Chez Les Frenchies            Creperies
# 186                           Kitsby             Desserts    4.5    $$
# 187                           Burrow             Desserts    4.5     $
# 188              Sugar Miss Tea Cafe             Desserts      4    $$
# 189                       CAFÉ LULUc               French      4    $$
# 190                    Cafe Sabarsky               German      4    $$
# 191                  Eataly Flatiron              Italian      4    $$
# 192                        Hi-Collar             Japanese      4    $$
# 193                          Davelle             Japanese    4.5    $$
# 194                    Nostrand Cafe               Korean    4.5    $$
# 195                      Dream Vista        Mediterranean
# 196                       Pause Cafe             Moroccan    4.5     $
# 197                      Cafe Gitane             Moroccan
# 198                        Ursula BK  New Mexican Cuisine
# 199                        Baba Cool           Sandwiches      4    $$
#
#                 Address        Lat        Lng  \
# 0          52 W 13th St  40.736180 -73.996596
# 1           362 2nd Ave  40.736740 -73.981520
# 2       292 Bedford Ave  40.714391 -73.961513
# 3       72 E 1st Street  40.723506 -73.988733
# 4        465 W Broadway  40.726366 -74.000015
# 5           40 Water St  40.703267 -73.992242
# 6         2-10 50th Ave  40.743349 -73.958035
# 7          18 E 16th St  40.736610 -73.991810
# 8          139 Smith St  40.687020 -73.990130
# 9        743 Driggs Ave  40.712500 -73.960560
# 10      243 Bleecker St  40.730830 -74.002650
# 11         223 Front St  40.707272 -74.002316
# 12          236 9th Ave  40.747410 -74.000590
# 13         25 Murray St  40.713930 -74.008220
# 14      455A Myrtle Ave  40.693489 -73.967376
# 15         197 E 3rd St  40.723015 -73.983207
# 16      163 Plymouth St  40.703830 -73.986910
# 17          15 Cliff St  40.708370 -74.005630
# 18         155 S 4th St  40.711620 -73.961840
# 19          335 3rd Ave  40.739900 -73.982190
# 20        26 Clinton St  40.720440 -73.984120
# 21        544 Union Ave  40.717100 -73.951640
# 22        643 Hudson St  40.739135 -74.005738
# 23           45 John St  40.709299 -74.007916
# 24      169 Sullivan St  40.727870 -74.001100
# 25      64 Meserole Ave  40.726330 -73.954710
# 26       60-11 39th Ave  40.747530 -73.903080
# 27        347 Lewis Ave  40.683746 -73.935023
# 28       505 Myrtle Ave  40.693794 -73.964702
# 29         262 Kent Ave  40.716143 -73.966306
# ..                  ...        ...        ...
# 170       150 Wythe Ave  40.720040 -73.960130
# 171       253 Bergen St  40.684160 -73.983570
# 172        307 E 9th St  40.729050 -73.986680
# 173   325 Manhattan Ave  40.715160 -73.946451
# 174        21 Fulton St  40.707140 -74.003670
# 175        125 N 6th St  40.717960 -73.959210
# 176       502 Hudson St  40.733290 -74.006190
# 177         26 Canal St  40.714309 -73.990417
# 178       241 E 24th St  40.738951 -73.980784
# 179         218 8th Ave  40.744070 -73.999120
# 180  139 Bridge Park Dr  40.693608 -74.001017
# 181   112 Greenwich Ave  40.738394 -74.002048
# 182        384 Court St  40.681298 -73.996666
# 183      100 Forsyth St  40.718302 -73.992771
# 184       18 Grattan St  40.705320 -73.932400
# 185       501 E 75th St  40.768700 -73.951820
# 186        186 Grand St  40.714110 -73.960977
# 187           68 Jay St  40.702722 -73.986888
# 188        5309 7th Ave  40.640396 -74.007718
# 189        214 Smith St  40.684510 -73.992250
# 190        1048 5th Ave  40.781225 -73.960266
# 191         200 5th Ave  40.741959 -73.989717
# 192        231 E 9th St  40.729564 -73.987860
# 193      102 Suffolk St  40.718520 -73.986050
# 194    261 Nostrand Ave  40.689746 -73.951286
# 195         177 York St  40.716569 -74.042127
# 196        3 Clinton St  40.721230 -73.984080
# 197       70 Hudson Ave  40.702827 -73.981281
# 198     724 Sterling Pl  40.672656 -73.954677
# 199    64 Lafayette Ave  40.687010 -73.975370
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/society-cafe-new-york...  JEuIdK9hzci9g_TuwfnZ_w
# 1    https://www.yelp.com/biz/citizens-of-gramercy-...  yCfjoS6XfnP8hd9zWjME7Q
# 2    https://www.yelp.com/biz/hole-in-the-wall-will...  v9bbNVQUA0OJzJKAcn_r4w
# 3    https://www.yelp.com/biz/the-lazy-llama-coffee...  VHORZQg5A3YNBptRN92QGg
# 4    https://www.yelp.com/biz/harbs-soho-new-york-3...  M-1k30Dgcc1OxZ8buddE4Q
# 5
# 6    https://www.yelp.com/biz/black-star-bakery-and...  gfgbbPRqVqSj_rxlSwhJhg
# 7    https://www.yelp.com/biz/breads-bakery-new-yor...  mU23NlQfn1R9OhA6WMe_xg
# 8    https://www.yelp.com/biz/mias-bakery-brooklyn?...  jWC4mD-yy-IzuZxU5ctAKw
# 9
# 10   https://www.yelp.com/biz/pasticceria-rocco-new...  JWLRT0dkdaC7AHtYapWbGw
# 11   https://www.yelp.com/biz/cafe-patoro-new-york?...  wWhZvkaFrntlSf1CWvD1Zw
# 12   https://www.yelp.com/biz/sullivan-street-baker...  yicBRA8X7urJyKn6aF2wzw
# 13   https://www.yelp.com/biz/takahachi-bakery-new-...  GlPJPpKvPR4d8dmcSEYpdA
# 14   https://www.yelp.com/biz/pecks-new-york?adjust...  DA1hijID0q6D6Ouch17v7w
# 15
# 16   https://www.yelp.com/biz/usagi-ny-dumbo-7?adju...  vijwGDNrPBJHEG7_DsjZNw
# 17   https://www.yelp.com/biz/hole-in-the-wall-new-...  rQpO1Eie_zmeAOQ9s-T0sQ
# 18   https://www.yelp.com/biz/weekends-brooklyn?adj...  RszJexNjHiS1As9cJ7eWpQ
# 19   https://www.yelp.com/biz/sunflower-gramercy-ne...  zV1_EFMN4VY7Rxpv7P-ajg
# 20   https://www.yelp.com/biz/koneko-new-york-3?adj...  zi_TJRxi0WzADbbI6Jcz3A
# 21   https://www.yelp.com/biz/reunion-brooklyn-2?ad...  sVkwEFET38Myz3dM1uZpiw
# 22   https://www.yelp.com/biz/banter-new-york-3?adj...  x8slUOJxMX2EJ0YUU0rrSg
# 23   https://www.yelp.com/biz/suited-new-york?adjus...  ykqXbitAmPGq1xXZoOLCxw
# 24   https://www.yelp.com/biz/banter-new-york?adjus...  Zc7Jbuwe3XO-EaVXIh_TYQ
# 25
# 26   https://www.yelp.com/biz/bee-cafe-woodside?adj...  VLMxyAe_l9vvyFd5vEPZ4g
# 27
# 28   https://www.yelp.com/biz/petees-cafe-brooklyn-...  oBcuOhubYwHV_bY35lu5hA
# 29
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/bakeri-brooklyn?adjus...  k17DEW9TqRZf6EFSc49OsA
# 171
# 172  https://www.yelp.com/biz/mud-new-york-3?adjust...  S-WdvEU1X7J33whXWk1zmw
# 173  https://www.yelp.com/biz/lella-alimentari-broo...  UpPXAjKc-CyuCg72chwd3A
# 174
# 175  https://www.yelp.com/biz/partners-coffee-brook...  ipygjHXH9PqQS6aqU54RcQ
# 176  https://www.yelp.com/biz/blackstone-coffee-roa...  Mkx7wE0Jlb0bFYGhEpulSg
# 177  https://www.yelp.com/biz/little-canal-new-york...  DxeD4Jw3gsImI-olCOB0bA
# 178
# 179
# 180
# 181
# 182  https://www.yelp.com/biz/east-one-coffee-roast...  NfuHyyXieKyq0vScjHWATg
# 183  https://www.yelp.com/biz/kodawari-coffee-new-y...  I_f_KhuRonsQiQ1llhqVHQ
# 184  https://www.yelp.com/biz/sey-coffee-brooklyn?a...  bmSYtYRPf6ycx-4xWhbHFg
# 185
# 186  https://www.yelp.com/biz/kitsby-brooklyn?adjus...  7-yC49tlWreX6TQtMNFSFg
# 187  https://www.yelp.com/biz/burrow-brooklyn?adjus...  nyxmTe-It-tzfagvjkge1g
# 188  https://www.yelp.com/biz/sugar-miss-tea-cafe-b...  QMwF3MpXNaHJzavVOLRWfA
# 189  https://www.yelp.com/biz/caf%C3%A9-luluc-brook...  mv8dMMzzrzalso3sYCP_QA
# 190  https://www.yelp.com/biz/cafe-sabarsky-new-yor...  _NS1hEZ0LPwaTG4R6jxgnw
# 191  https://www.yelp.com/biz/eataly-flatiron-new-y...  a0IET3_yCFcO36OqGSsisg
# 192  https://www.yelp.com/biz/hi-collar-new-york-2?...  7rxg-tWPc1jK7Cikn5R86g
# 193  https://www.yelp.com/biz/davelle-new-york-2?ad...  PwrYnl3j3YCGzILX_5UHpw
# 194  https://www.yelp.com/biz/nostrand-cafe-brookly...  0zcgBHXbaJn0ZxgpcTJ1aQ
# 195
# 196  https://www.yelp.com/biz/pause-cafe-new-york?a...  sR60I9PI_63noBQcGoIrbw
# 197
# 198
# 199  https://www.yelp.com/biz/baba-cool-brooklyn?ad...  wXiIxbnFRaFBS9RI4wJrdw
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_Cafe.csv')
