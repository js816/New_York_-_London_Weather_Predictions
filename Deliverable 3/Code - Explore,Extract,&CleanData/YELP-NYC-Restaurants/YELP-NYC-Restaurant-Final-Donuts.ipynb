# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"donuts","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': 'lWOkeS-wV4no8qqA9OwwEg',
#    'alias': 'doughnut-plant-new-york-6',
#    'name': 'Doughnut Plant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hLWKXsLv6hyltNSilBy8-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doughnut-plant-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3274,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.716334, 'longitude': -73.988652},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '379 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['379 Grand St', 'New York, NY 10002']},
#    'phone': '+12125053700',
#    'display_phone': '(212) 505-3700',
#    'distance': 1300.8284914110848},
#   {'id': 'oDRZt37ROqadlK3-VI0PfQ',
#    'alias': 'alimama-new-york-3',
#    'name': 'Alimama',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5XwgumtgBN2Wzm20dprDqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alimama-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1388,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7158626896215,
#     'longitude': -73.9992850858479},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '89A Bayard St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['89A Bayard St', 'New York, NY 10013']},
#    'phone': '+12122357288',
#    'display_phone': '(212) 235-7288',
#    'distance': 1227.5817807830615},
#   {'id': 'c6UUcUTbwbk0kOpF6jVOJQ',
#    'alias': 'the-doughnut-project-new-york',
#    'name': 'The Doughnut Project',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TsRkIkazmTpT_HZ6zaia0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-doughnut-project-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 520,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.731151, 'longitude': -74.003547},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '10 Morton St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10 Morton St', 'New York, NY 10014']},
#    'phone': '+12126915000',
#    'display_phone': '(212) 691-5000',
#    'distance': 2964.428663792995},
#   {'id': 'tJY11BoV6Epe2MmV6o7L9w',
#    'alias': 'the-dough-club-new-york',
#    'name': 'The Dough Club',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0Pz682B5ENshaANmNKmKbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dough-club-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 352,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.717937, 'longitude': -73.99891233660313},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '119 Baxter St',
#     'address2': 'Ste A',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['119 Baxter St', 'Ste A', 'New York, NY 10013']},
#    'phone': '+16469186090',
#    'display_phone': '(646) 918-6090',
#    'distance': 1442.5894716160906},
#   {'id': 'HcgAK_DDdUfBqxcPh4pRsQ',
#    'alias': 'fan-fan-doughnuts-brooklyn',
#    'name': 'Fan Fan Doughnuts',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mc93eITX970Bvb3Bz07-dA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fan-fan-doughnuts-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 105,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6891715804644,
#     'longitude': -73.9571072833309},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '448 Lafayette Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['448 Lafayette Ave', 'Brooklyn, NY 11205']},
#    'phone': '+13475337544',
#    'display_phone': '(347) 533-7544',
#    'distance': 3628.0414347050646},
#   {'id': 'ZMQzXIiqdBIuicFySTWGKg',
#    'alias': 'dough-new-york-2',
#    'name': 'Dough',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Mg3YZ1U-UpkFCCiaL5Remw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dough-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1572,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73931, 'longitude': -73.99243},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '14 W 19th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 W 19th St', 'New York, NY 10011']},
#    'phone': '+12122436844',
#    'display_phone': '(212) 243-6844',
#    'distance': 3771.936848199482},
#   {'id': 'Z_jHSj127fqMDpsKe3NLjg',
#    'alias': 'the-donut-pub-new-york-7',
#    'name': 'The Donut Pub',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JHJRiMwvLM5WCOhpdychtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-donut-pub-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 148,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729845, 'longitude': -73.992809},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '740 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['740 Broadway', 'New York, NY 10003']},
#    'phone': '+16469741221',
#    'display_phone': '(646) 974-1221',
#    'distance': 2711.3092319922707},
#   {'id': 'BJL3JbPPX97a58GTURvTxA',
#    'alias': 'the-donut-pub-new-york',
#    'name': 'The Donut Pub',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/l3O-18zhlv9in84VzLuDSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-donut-pub-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 995,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.738867, 'longitude': -73.999811},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '203 W 14th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['203 W 14th St', 'New York, NY 10011']},
#    'phone': '+16463987007',
#    'display_phone': '(646) 398-7007',
#    'distance': 3745.34546764287},
#   {'id': 'vFdyNlTjIPwOijgm0MJD4A',
#    'alias': 'brandons-donuts-new-york',
#    'name': "Brandon's Donuts",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MEm-1kt_uvXDSY3ssPkoSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brandons-donuts-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.677615, 'longitude': -73.99787},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '449 Court St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['449 Court St', 'New York, NY 11231']},
#    'phone': '+19293376354',
#    'display_phone': '(929) 337-6354',
#    'distance': 3106.2366071760916},
#   {'id': 'IfmcuGIr9kthp9dNjrtlmw',
#    'alias': 'doughnut-plant-brooklyn',
#    'name': 'Doughnut Plant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wocR9_KkyzW7lZ4S9UkDqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doughnut-plant-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 626,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.680653, 'longitude': -73.9747427},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '245 Flatbush Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['245 Flatbush Ave', 'Brooklyn, NY 11217']},
#    'phone': '+12125053700',
#    'display_phone': '(212) 505-3700',
#    'distance': 3211.916407190127},
#   {'id': 'jgaDo7PElSG6BKXrqVz-kg',
#    'alias': 'doughnut-plant-brooklyn-2',
#    'name': 'Doughnut Plant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tbMvcHx-K6T6R6jPMRPsBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doughnut-plant-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7174797, 'longitude': -73.9583136},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '198 Bedford Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['198 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+13159045100',
#    'display_phone': '(315) 904-5100',
#    'distance': 3311.332190135505},
#   {'id': 'O0xFECgTDf1rbZzW9qUULQ',
#    'alias': 'peter-pan-donut-and-pastry-shop-brooklyn-2',
#    'name': 'Peter Pan Donut & Pastry Shop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HDnInssfBVBX6cOke14p9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peter-pan-donut-and-pastry-shop-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1406,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.726086, 'longitude': -73.952308},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '727 Manhattan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['727 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183893676',
#    'display_phone': '(718) 389-3676',
#    'distance': 4217.718983924479},
#   {'id': 'aUgI5v2SUJWlCBymlREmzQ',
#    'alias': 'mochinut-new-york',
#    'name': 'Mochinut',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7nuR8E-VNnV_004fwAYWLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mochinut-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72821, 'longitude': -73.98774},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '124 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['124 2nd Ave', 'New York, NY 10003']},
#    'phone': '+19172617080',
#    'display_phone': '(917) 261-7080',
#    'distance': 2586.1186316666776},
#   {'id': 'Yeyu5eTxwQLwAzixJpQ05Q',
#    'alias': 'petit-chou-new-york',
#    'name': 'Petit Chou',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Qo5UqrfMrAGEMu2PFZZS2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/petit-chou-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.731112, 'longitude': -73.983104},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '229 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['229 1st Ave', 'New York, NY 10003']},
#    'phone': '+19174751620',
#    'display_phone': '(917) 475-1620',
#    'distance': 3005.982591646828},
#   {'id': 'HHN8P3LYoFkiSyF9jgyVrQ',
#    'alias': 'fat-doughnut-brooklyn-2',
#    'name': 'Fat Doughnut',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vKX7OwhAC6tNRohPZNfSLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fat-doughnut-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 142,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6924050190985,
#     'longitude': -73.9311097345756},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '50 Malcolm X Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['50 Malcolm X Blvd', 'Brooklyn, NY 11221']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5520.316792978962},
#   {'id': '4lBQFduDuS_kkMvfrp3sxQ',
#    'alias': 'mikes-donuts-brooklyn',
#    'name': "Mike's Donuts",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DLNdI0umh5BEvHw0_y42vQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mikes-donuts-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 163,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.633755, 'longitude': -74.021219},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '6822 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11220',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6822 5th Ave', 'Brooklyn, NY 11220']},
#    'phone': '+17187456980',
#    'display_phone': '(718) 745-6980',
#    'distance': 8290.57952370429},
#   {'id': 'ga6sRtE0l85iftw_5-W84Q',
#    'alias': 'dominique-ansel-bakery-new-york',
#    'name': 'Dominique Ansel Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ae6sDhEfUXTE5EKfWSOrCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dominique-ansel-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4791,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72522, 'longitude': -74.00291},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '189 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['189 Spring St', 'New York, NY 10012']},
#    'phone': '+12122192773',
#    'display_phone': '(212) 219-2773',
#    'distance': 2316.930739426023},
#   {'id': 'FjI6SFjwhdTWQvZ6jWgkeA',
#    'alias': 'the-dough-club-williamsburg-new-york-4',
#    'name': 'The Dough Club - Williamsburg',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/u2edFxMddEh8h3ROMfni3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dough-club-williamsburg-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71438418201451,
#     'longitude': -73.96152183446654},
#    'transactions': ['delivery'],
#    'location': {'address1': '294 Bedford Ave',
#     'address2': '',
#     'address3': 'Taiyaki NYC',
#     'city': 'New York',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['294 Bedford Ave',
#      'Taiyaki NYC',
#      'New York, NY 11249']},
#    'phone': '+19179091856',
#    'display_phone': '(917) 909-1856',
#    'distance': 2935.6417556500833},
#   {'id': 'gcdtcIOgLbeTpKUVAJB-vg',
#    'alias': 'supex-mochi-donut-flushing',
#    'name': 'Supex Mochi Donut',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dMiB0EOFaMXpBDxVmyt0Cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/supex-mochi-donut-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76361832860424,
#     'longitude': -73.8088889938653},
#    'transactions': ['delivery'],
#    'location': {'address1': '156-16 Northern Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156-16 Northern Blvd', 'Flushing, NY 11354']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 16907.875805007727},
#   {'id': 'nmIhMbsg3vgjFTAG0bRiZw',
#    'alias': 'doughnut-plant-new-york-5',
#    'name': 'Doughnut Plant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gvYWkJKVPPEreQdX7DQCuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doughnut-plant-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 163,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7527277, 'longitude': -73.9772353},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '89 E 42nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['89 E 42nd St', 'New York, NY 10017']},
#    'phone': '+12125053700',
#    'display_phone': '(212) 505-3700',
#    'distance': 5450.544197273203},
#   {'id': 'AfZPx4piTmg9dqZpYgYTgg',
#    'alias': 'moes-doughs-donut-shop-brooklyn',
#    'name': "Moe's Doughs Donut Shop",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/w8akgvIsLDtYXxwXj-rzrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moes-doughs-donut-shop-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 331,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7243431, 'longitude': -73.9484718},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '126 Nassau Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['126 Nassau Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183491216',
#    'display_phone': '(718) 349-1216',
#    'distance': 4396.607727799913},
#   {'id': '0tJEDmeNMLueSGLNTF0JFg',
#    'alias': 'angelina-bakery-new-york',
#    'name': 'Angelina Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8040_-AxajTbQjzk4cySRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/angelina-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 257,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75498, 'longitude': -73.99166},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '575 8th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['575 8th Ave', 'New York, NY 10018']},
#    'phone': '+12126877100',
#    'display_phone': '(212) 687-7100',
#    'distance': 5517.513781375333},
#   {'id': 'WHRHK3S1mQc3PmhwsGRvbw',
#    'alias': 'bibble-and-sip-new-york-2',
#    'name': 'Bibble & Sip',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gX847-f2s1X65RkzsFAWBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bibble-and-sip-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5022,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7628355, 'longitude': -73.98518009478293},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '253 W 51st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253 W 51st St', 'New York, NY 10019']},
#    'phone': '+16466495116',
#    'display_phone': '(646) 649-5116',
#    'distance': 6427.569355387715},
#   {'id': 'FGyIoiGxHytkd6B4qfoIPA',
#    'alias': 'dough-brooklyn-4',
#    'name': 'Dough',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5w8NB3ki2NOhNtKFZrC4Rg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dough-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67703, 'longitude': -73.9693},
#    'transactions': [],
#    'location': {'address1': '646 Vanderbilt Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['646 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3801.1410695306186},
#   {'id': 'yOc5CZ5VxHGqj96RUuZCMA',
#    'alias': 'dun-well-doughnuts-brooklyn',
#    'name': 'Dun-Well Doughnuts',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vepoKVhbv5oMxz9MAo6oDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dun-well-doughnuts-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 882,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.707743, 'longitude': -73.940202},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '222 Montrose Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['222 Montrose Ave', 'Brooklyn, NY 11206']},
#    'phone': '+13472940871',
#    'display_phone': '(347) 294-0871',
#    'distance': 4566.625549679913},
#   {'id': 'owvn3TwI2oweLWh4D7strA',
#    'alias': 'comfortland-astoria-2',
#    'name': 'Comfortland',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bkJWAQqtxPo2opixFJm4AQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/comfortland-astoria-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 243,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.763865, 'longitude': -73.914546},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '40-09 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40-09 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+13476429932',
#    'display_phone': '(347) 642-9932',
#    'distance': 9345.928253464723},
#   {'id': 't4M1VX4n34eEgUWMJ7cgKw',
#    'alias': 'daily-provisions-new-york',
#    'name': 'Daily Provisions',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KOSmplXpEbiCLdRnRBkcTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daily-provisions-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 471,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73768, 'longitude': -73.9876685},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '103 E 19th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 E 19th St', 'New York, NY 10003']},
#    'phone': '+12124881505',
#    'display_phone': '(212) 488-1505',
#    'distance': 3624.11900652027},
#   {'id': 'jWC4mD-yy-IzuZxU5ctAKw',
#    'alias': 'mias-bakery-brooklyn',
#    'name': "Mia's Bakery",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-_RVN3QbCDs6ScFwP_0hqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mias-bakery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 854,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6870199, 'longitude': -73.9901299},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '139 Smith St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['139 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+13479873194',
#    'display_phone': '(347) 987-3194',
#    'distance': 2081.025885948994},
#   {'id': 'hOjbYoXkyy7Z8SKwpx5IvA',
#    'alias': 'dus-donuts-and-coffee-brooklyn',
#    'name': "Du's Donuts & Coffee",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LhNwzcpJ-xc16gR28-JIcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dus-donuts-and-coffee-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 156,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7221862, 'longitude': -73.95697061396419},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '107 N 12th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['107 N 12th St', 'Brooklyn, NY 11249']},
#    'phone': '+17182158770',
#    'display_phone': '(718) 215-8770',
#    'distance': 3655.211776629283},
#   {'id': 'uKxYiV2xoO1AUGUAakAfDQ',
#    'alias': 'from-kora-queens',
#    'name': 'From Kora',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FpmgVa0MRIhOve5_J6BiAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/from-kora-queens?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'filipino', 'title': 'Filipino'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.751208638548974,
#     'longitude': -73.95004514604808},
#    'transactions': ['delivery'],
#    'location': {'address1': '43-46 10th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Queens',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43-46 10th St', 'Queens, NY 11101']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6308.478521708126},
#   {'id': 'M2CSxMwbkwJr_G_Bzp7Y5Q',
#    'alias': 'mah-ze-dahr-bakery-new-york',
#    'name': 'Mah-Ze-Dahr Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FUdkQklLHJeembS3oqXuZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mah-ze-dahr-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 368,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73503, 'longitude': -74.00002},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '28 Greenwich Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 Greenwich Ave', 'New York, NY 10011']},
#    'phone': '+12124989810',
#    'display_phone': '(212) 498-9810',
#    'distance': 3329.046042624273},
#   {'id': '0Zfcsxbos9Y6FE56MbjJtw',
#    'alias': 'mochi-mochi-donut-new-york',
#    'name': 'Mochi Mochi Donut',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YMZp60PwHmF48aWWocCx2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mochi-mochi-donut-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74832675043636,
#     'longitude': -73.98686625525188},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '33 W 32nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33 W 32nd St', 'New York, NY 10001']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4809.1393258512635},
#   {'id': 'Sgh7Uar8wv6WKA-UZ7hcXA',
#    'alias': 'balthazar-boulangerie-new-york',
#    'name': 'Balthazar Boulangerie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XorcA_Z0wQneLiV5SrzUEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/balthazar-boulangerie-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 377,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72276, 'longitude': -73.99842},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '80 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Spring St', 'New York, NY 10012']},
#    'phone': '+12129651785',
#    'display_phone': '(212) 965-1785',
#    'distance': 1943.5604048732139},
#   {'id': 'IGGn_SbhdVFIesmCTSv-Tw',
#    'alias': 'cuzins-duzin-brooklyn-3',
#    'name': "Cuzin's Duzin",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3VdNgQBHFsv7vjxJeUZWsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cuzins-duzin-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6907009, 'longitude': -73.9834976},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '445 Albee Square W',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['445 Albee Square W', 'Brooklyn, NY 11201']},
#    'phone': '+19292973972',
#    'display_phone': '(929) 297-3972',
#    'distance': 1875.1242563460148},
#   {'id': 'WtDBGpcQqctbBaSlXpU2gA',
#    'alias': 'knead-some-love-ny-weehawken-3',
#    'name': 'Knead Some Love NY',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0Tkpb1zVu6xDjpZRFjTFPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/knead-some-love-ny-weehawken-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'chocolate', 'title': 'Chocolatiers & Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7663711, 'longitude': -74.02537149999999},
#    'transactions': [],
#    'location': {'address1': None,
#     'address2': None,
#     'address3': None,
#     'city': 'Weehawken',
#     'zip_code': '07086',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['Weehawken, NJ 07086']},
#    'phone': '+17188442153',
#    'display_phone': '(718) 844-2153',
#    'distance': 7263.116963837967},
#   {'id': '0uyNyorc1m-W0R4zd-wvhQ',
#    'alias': 'beard-papas-new-york-2',
#    'name': "Beard Papa's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gvSbjdOYwgW92312czEESw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beard-papas-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 135,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75714, 'longitude': -73.96782},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '239 E 53rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['239 E 53rd St', 'New York, NY 10022']},
#    'phone': '+12129356308',
#    'display_phone': '(212) 935-6308',
#    'distance': 6173.258261096518},
#   {'id': 'BFsKXS1XKe4eXoAEnYgwkA',
#    'alias': 'doughnut-plant-long-island-city',
#    'name': 'Doughnut Plant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rkaTT6rCo3RGpJCxzGqdAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doughnut-plant-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 274,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.742026, 'longitude': -73.935436},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '31-00 47th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31-00 47th Ave', 'Long Island City, NY 11101']},
#    'phone': '+12125053700',
#    'display_phone': '(212) 505-3700',
#    'distance': 6414.556284925142},
#   {'id': 'ceLen35mSAL5jZoqMQhEpA',
#    'alias': 'mochinut-fort-lee-2',
#    'name': 'Mochinut',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/r1Qp8RzEiJHwcUiTQa7r6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mochinut-fort-lee-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 119,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8454919369321,
#     'longitude': -73.9797824621201},
#    'transactions': [],
#    'location': {'address1': '1369 16th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Fort Lee',
#     'zip_code': '07024',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1369 16th St', 'Fort Lee, NJ 07024']},
#    'phone': '+12012246200',
#    'display_phone': '(201) 224-6200',
#    'distance': 15620.36964340777},
#   {'id': 'uP1cU9wwudXlLCYmJ17PRA',
#    'alias': 'gonuts-doughnuts-elmhurst',
#    'name': 'Gonuts Doughnuts',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rhp4v8piA_C6Cz0wmnoZWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gonuts-doughnuts-elmhurst?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7415553, 'longitude': -73.8746495},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '90-18 Corona Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90-18 Corona Ave', 'Elmhurst, NY 11373']},
#    'phone': '+19296667217',
#    'display_phone': '(929) 666-7217',
#    'distance': 10849.735440719547},
#   {'id': '_kwVdjdWvq2HaTlrykitNw',
#    'alias': 'sullivan-street-bakery-new-york-5',
#    'name': 'Sullivan Street Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vrzbT0sLityw4yJtfmFonA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sullivan-street-bakery-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72759724358166,
#     'longitude': -73.98319280396632},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '437 E 9th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['437 E 9th St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2634.906533756502},
#   {'id': 'hwJGxxJ_FBOOANcnI-QOUA',
#    'alias': 'krispy-kreme-new-york-11',
#    'name': 'Krispy Kreme',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GrhrRg0J7n9oLC0MVrodsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/krispy-kreme-new-york-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.710445, 'longitude': -74.008946},
#    'transactions': ['delivery'],
#    'location': {'address1': '200 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 Broadway', 'New York, NY 10038']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1361.907855546657},
#   {'id': '262gwR-4f6rDo0eU-8Uszg',
#    'alias': 'the-social-brooklyn',
#    'name': 'The Social',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CkqmxjKY66gcwIeS1NJhRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-social-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.67346, 'longitude': -73.96323},
#    'transactions': [],
#    'location': {'address1': '816 Washington Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['816 Washington Ave', 'Brooklyn, NY 11238']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4420.4032396697685},
#   {'id': 'XSwagBljEsxG2i1rq4GEAQ',
#    'alias': 'almondine-bakery-brooklyn',
#    'name': 'Almondine Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/E3wP_njOCmZ2IW6hrWCK6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/almondine-bakery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 372,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7033174, 'longitude': -73.9912506},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '85 Water St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+17187975026',
#    'display_phone': '(718) 797-5026',
#    'distance': 348.91633855519586},
#   {'id': 'b5x-Fw7I7Y88TdFIzvbsnw',
#    'alias': 'supermoon-bakehouse-new-york',
#    'name': 'Supermoon Bakehouse',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SrQiuKi4go9Bjl8XPn-7IA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/supermoon-bakehouse-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 807,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71991, 'longitude': -73.9872},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '120 Rivington St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['120 Rivington St', 'New York, NY 10002']},
#    'phone': '+13476541211',
#    'display_phone': '(347) 654-1211',
#    'distance': 1714.9424016310745},
#   {'id': 'f99NgqbUHN6-bRZRvChg7w',
#    'alias': 'croffle-house-flushing',
#    'name': 'Croffle House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/g3-QYGhC8PO8UUhK3boU5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/croffle-house-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 172,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.762998, 'longitude': -73.814836},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '40-17 149th Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40-17 149th Pl', 'Flushing, NY 11354']},
#    'phone': '+19179080405',
#    'display_phone': '(917) 908-0405',
#    'distance': 16419.897640028856},
#   {'id': 'EZCOwqdPJnTBiDLuZ3IjNQ',
#    'alias': 'doughnuttery-new-york-5',
#    'name': 'Doughnuttery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/s17q7k2tt5RLUKE8Zo0rHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doughnuttery-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'food_court', 'title': 'Food Court'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7642484299927,
#     'longitude': -73.9733619040796},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': 'One W 58th St',
#     'address2': '',
#     'address3': 'Plaza Hotel',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['One W 58th St', 'Plaza Hotel', 'New York, NY 10019']},
#    'phone': '+12126334359',
#    'display_phone': '(212) 633-4359',
#    'distance': 6772.3138083258855},
#   {'id': 'WEC8O6GskyWJVpri_gW3QQ',
#    'alias': 'rays-candy-store-new-york-2',
#    'name': "Ray's Candy Store",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4fuISz8jPj6m8dSZ-fx9bQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rays-candy-store-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 426,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7262776243945,
#     'longitude': -73.9835707495258},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '113 Avenue A',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['113 Avenue A', 'New York, NY 10009']},
#    'phone': '+12125057609',
#    'display_phone': '(212) 505-7609',
#    'distance': 2486.526034967461},
#   {'id': 'HClWutmlwYU1tNipqS1wPg',
#    'alias': 'glaze-donuts-fort-lee-2',
#    'name': 'Glaze Donuts',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/b7rj3J4Te7nzipEi8kyQdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/glaze-donuts-fort-lee-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 71,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.856372, 'longitude': -73.967966},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '2151 Lemoine Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Fort Lee',
#     'zip_code': '07024',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['2151 Lemoine Ave', 'Fort Lee, NJ 07024']},
#    'phone': '+12015856085',
#    'display_phone': '(201) 585-6085',
#    'distance': 16928.077054444944},
#   {'id': 'PyEGUBVt5HhW7FXih1BNgw',
#    'alias': 'doughnuttery-new-york',
#    'name': 'Doughnuttery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/k_n7zydFLW5WOGRpYPz74g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doughnuttery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 491,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74241, 'longitude': -74.006375},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '425 W 15th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['425 W 15th St', 'New York, NY 10011']},
#    'phone': '+12126334359',
#    'display_phone': '(212) 633-4359',
#    'distance': 4234.5509124123255},
#   {'id': 'VVzxp06ZM7WGPPbpQTpoJQ',
#    'alias': 'glazed-and-confused-mini-donuts-jersey-city',
#    'name': 'Glazed & Confused Mini Donuts',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eDz1HV0ssAJp6W069Gg4sw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/glazed-and-confused-mini-donuts-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71748, 'longitude': -74.04385},
#    'transactions': [],
#    'location': {'address1': None,
#     'address2': None,
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['Jersey City, NJ 07030']},
#    'phone': '+12019513864',
#    'display_phone': '(201) 951-3864',
#    'distance': 5104.92488943443}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#              Restaurant      Type Price Rating            Address        Lat  \
# 0        Doughnut Plant    Donuts    $$    4.5       379 Grand St  40.716334
# 1               Alimama  Desserts    $$    4.5      89A Bayard St  40.715863
# 2  The Doughnut Project    Donuts     $    4.5       10 Morton St  40.731151
# 3        The Dough Club    Donuts                   119 Baxter St  40.717937
# 4     Fan Fan Doughnuts    Donuts               448 Lafayette Ave  40.689172
#
#          Lng                                                url  \
# 0 -73.988652  https://www.yelp.com/biz/doughnut-plant-new-yo...
# 1 -73.999285  https://www.yelp.com/biz/alimama-new-york-3?ad...
# 2 -74.003547  https://www.yelp.com/biz/the-doughnut-project-...
# 3 -73.998912
# 4 -73.957107
#
#                        ID
# 0  lWOkeS-wV4no8qqA9OwwEg
# 1  oDRZt37ROqadlK3-VI0PfQ
# 2  c6UUcUTbwbk0kOpF6jVOJQ
# 3
# 4

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"donuts","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': '0kH1mGuqIb5rOrvCKGsWtA',
#    'alias': 'stuffed-ice-cream-new-york-3',
#    'name': 'Stuffed Ice Cream',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WDE5HAX0v06acC0Lus03lw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stuffed-ice-cream-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 712,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72805, 'longitude': -73.98538},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '139 1st Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['139 1st Ave', 'New York, NY 10003']},
#    'phone': '+19179856166',
#    'display_phone': '(917) 985-6166',
#    'distance': 2624.4780970762404},
#   {'id': 'H4jJ7XB3CetIr1pg56CczQ',
#    'alias': 'levain-bakery-new-york',
#    'name': 'Levain Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ElQFlcl5wBXfn1qbfweYsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/levain-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8484,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.779961, 'longitude': -73.980299},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '167 W 74th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['167 W 74th St', 'New York, NY 10023']},
#    'phone': '+19174643769',
#    'display_phone': '(917) 464-3769',
#    'distance': 8369.262424680568},
#   {'id': 'gfgbbPRqVqSj_rxlSwhJhg',
#    'alias': 'black-star-bakery-and-cafe-long-island-city',
#    'name': 'Black Star Bakery & Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VW3TAoB9FGh57CMRUSBpCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-star-bakery-and-cafe-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 136,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7433494, 'longitude': -73.9580353},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '2-10 50th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2-10 50th Ave', 'Long Island City, NY 11101']},
#    'phone': '+17184339189',
#    'display_phone': '(718) 433-9189',
#    'distance': 5212.243615213465},
#   {'id': 'XDggieek96LsnfQ7zzdPTg',
#    'alias': 'duck-donuts-paramus-6',
#    'name': 'Duck Donuts',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/X8WNOxQfSFDO8YSZsoq41w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duck-donuts-paramus-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.95848301317053,
#     'longitude': -74.07384989680645},
#    'transactions': ['delivery'],
#    'location': {'address1': '556 NJ-17',
#     'address2': '',
#     'address3': None,
#     'city': 'Paramus',
#     'zip_code': '07652',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['556 NJ-17', 'Paramus, NJ 07652']},
#    'phone': '+12014833973',
#    'display_phone': '(201) 483-3973',
#    'distance': 28921.707246100068},
#   {'id': 'GlPJPpKvPR4d8dmcSEYpdA',
#    'alias': 'takahachi-bakery-new-york',
#    'name': 'Takahachi Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oP2xYZjbAa8akp-9CLmiVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/takahachi-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 949,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71393, 'longitude': -74.00822},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '25 Murray St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 Murray St', 'New York, NY 10007']},
#    'phone': '+12127915550',
#    'display_phone': '(212) 791-5550',
#    'distance': 1511.7020935512141},
#   {'id': 'AI680OnsLsoCro-0hYF1aQ',
#    'alias': 'michaeli-bakery-new-york-2',
#    'name': 'Michaeli Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-e5YrXebJLxor7-nWdUJtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/michaeli-bakery-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 114,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.714349, 'longitude': -73.992054},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '115A Division St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['115A Division St', 'New York, NY 10002']},
#    'phone': '+16463602284',
#    'display_phone': '(646) 360-2284',
#    'distance': 1007.9224803527684},
#   {'id': 'T5kcIHgs0fBq0GfKjGPG0g',
#    'alias': 'super-nice-coffee-and-bakery-new-york-3',
#    'name': 'Super Nice Coffee and Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fOcUsvU5qSeUQMTxEcE_aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/super-nice-coffee-and-bakery-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 94,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.79914, 'longitude': -73.94098},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '156 E 117th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10035',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156 E 117th St', 'New York, NY 10035']},
#    'phone': '+19172615069',
#    'display_phone': '(917) 261-5069',
#    'distance': 11331.527648543539},
#   {'id': '2P-nqWuFUARtzjde8NzQVg',
#    'alias': 'johns-coffee-donut-shop-brooklyn',
#    'name': "John's Coffee Donut Shop",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TrRFeUX0XpQ6JFkQPlrGnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/johns-coffee-donut-shop-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 76,
#    'categories': [{'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.693641, 'longitude': -73.966094},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '481 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['481 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17186380412',
#    'display_phone': '(718) 638-0412',
#    'distance': 2715.7221185805606},
#   {'id': 'M7abfb2eiDJ_d82-HnmQ9A',
#    'alias': 'the-lodg-jersey-city-2',
#    'name': 'The LoDG',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3th93INPhIhEExAZMvxVzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lodg-jersey-city-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.749857, 'longitude': -74.047168},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '7 Bleecker St',
#     'address2': None,
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07307',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['7 Bleecker St', 'Jersey City, NJ 07307']},
#    'phone': '+12013015465',
#    'display_phone': '(201) 301-5465',
#    'distance': 6651.276899509434},
#   {'id': 'WQUfcgKZZe3siRXkkkwMHg',
#    'alias': 'purple-dough-woodside',
#    'name': 'Purple Dough',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nEcw6UQ76lUS5J-wBLlfcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/purple-dough-woodside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 162,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'filipino', 'title': 'Filipino'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7468627, 'longitude': -73.896251},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '38-05 69th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38-05 69th St', 'Woodside, NY 11377']},
#    'phone': '+16467262187',
#    'display_phone': '(646) 726-2187',
#    'distance': 9460.284813112552},
#   {'id': 'Pf1gdUngOSo75T0qdf-fMg',
#    'alias': 'oh-mochi-new-york',
#    'name': 'Oh Mochi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sYHK4lSOn9g_If7CFovI4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oh-mochi-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7662428236374,
#     'longitude': -73.9812435954809},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '225 W 57th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['225 W 57th St', 'New York, NY 10019']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6849.24345445789},
#   {'id': 't8PW3eOqurv2CU94eSFkkg',
#    'alias': 'ugly-donuts-and-corn-dogs-flushing',
#    'name': 'Ugly Donuts & Corn Dogs',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QQ__x6WRKXo-u27-E1rapw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ugly-donuts-and-corn-dogs-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 56,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7601753, 'longitude': -73.8271219},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '136-84 Roosevelt Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136-84 Roosevelt Ave', 'Flushing, NY 11354']},
#    'phone': '+13475060425',
#    'display_phone': '(347) 506-0425',
#    'distance': 15347.601409022858},
#   {'id': 'qVSOes5JoWc5_umv4nd4Hg',
#    'alias': 'sugar-sweet-sunshine-bakery-new-york',
#    'name': 'Sugar Sweet Sunshine Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mK4J_NrzxZmmbP-ND6w0gg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sugar-sweet-sunshine-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2086,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.719851, 'longitude': -73.987011},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '126 Rivington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['126 Rivington St', 'New York, NY 10002']},
#    'phone': '+12129951960',
#    'display_phone': '(212) 995-1960',
#    'distance': 1715.4495332037206},
#   {'id': '6xaL2MvIgzkC67h8yu1-rw',
#    'alias': 'old-german-bakery-hoboken',
#    'name': 'Old German Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tzI7vd7WhzdeN0eTIAja4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/old-german-bakery-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 264,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7411506480459,
#     'longitude': -74.0299641027722},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '332 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['332 Washington St', 'Hoboken, NJ 07030']},
#    'phone': '+12016838644',
#    'display_phone': '(201) 683-8644',
#    'distance': 4979.904664878206},
#   {'id': 'E2pLus5pOMwr-w9FK5_ZbQ',
#    'alias': 'mochinut-norwood',
#    'name': 'Mochinut',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bnIBhOD4-T1L4jW05PZFGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mochinut-norwood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.99738656449265, 'longitude': -73.9548561},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '450 Livingston Str',
#     'address2': None,
#     'address3': None,
#     'city': 'Norwood',
#     'zip_code': '07648',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['450 Livingston Str', 'Norwood, NJ 07648']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 32631.424176390155},
#   {'id': 'pYjMy5ixIeeG1YLEt4bGDg',
#    'alias': 'win-son-bakery-brooklyn-9',
#    'name': 'Win Son Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JR0-WsKhNSBwbEkAjuP3rg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/win-son-bakery-brooklyn-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 191,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70721, 'longitude': -73.94302},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '164 Graham Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['164 Graham Ave', 'Brooklyn, NY 11206']},
#    'phone': '+19179091725',
#    'display_phone': '(917) 909-1725',
#    'distance': 4331.127070832499},
#   {'id': 'qMr-lz0G0vyz2r4mJJQxmA',
#    'alias': 'butter-lane-new-york',
#    'name': 'Butter Lane',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qwdSGuda8Q89zZljsllVWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/butter-lane-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1233,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'},
#     {'alias': 'cookingclasses', 'title': 'Cooking Classes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7264944895101,
#     'longitude': -73.9841490983963},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '123 E 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['123 E 7th St', 'New York, NY 10009']},
#    'phone': '+12126772880',
#    'display_phone': '(212) 677-2880',
#    'distance': 2491.864637411364},
#   {'id': 'U1exuSaIwTwpjxvlrKeftg',
#    'alias': 'ppl-brooklyn',
#    'name': 'PPL',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Pyr46puhltD1-0wCu2mqhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ppl-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.712885, 'longitude': -73.958529},
#    'transactions': [],
#    'location': {'address1': '189 Roebling St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['189 Roebling St', 'Brooklyn, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3125.9913159270504},
#   {'id': 'RHz7OAoy5yMNWBcLArgLrQ',
#    'alias': 'sweets-bakery-new-york',
#    'name': 'Sweets Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/V3-BCTHX5M452uLqN9rX_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweets-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 82,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.717286, 'longitude': -73.9996625},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '135 Walker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['135 Walker St', 'New York, NY 10013']},
#    'phone': '+12122192012',
#    'display_phone': '(212) 219-2012',
#    'distance': 1392.2768502710003},
#   {'id': 'jz_FnuRpCNzfwwHHQ6Nbeg',
#    'alias': 'schmackarys-new-york',
#    'name': "Schmackary's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_BA179tvEazDc85G6jzR0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/schmackarys-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2054,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.760153883881, 'longitude': -73.990944257291},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '362 W 45th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['362 W 45th St', 'New York, NY 10036']},
#    'phone': '+16468019866',
#    'display_phone': '(646) 801-9866',
#    'distance': 6089.899671870699},
#   {'id': 'aSDGr4NIfm1C6IspWSNaQw',
#    'alias': 'orwashers-new-york',
#    'name': 'Orwashers',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/F6VeUHed2qVjpTUIaT3WgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/orwashers-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 462,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.772191, 'longitude': -73.95505},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '308 E 78th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['308 E 78th St', 'New York, NY 10075']},
#    'phone': '+12122886569',
#    'display_phone': '(212) 288-6569',
#    'distance': 8124.619987999245},
#   {'id': 'jDLKMWhHACb5w1DDtnW9ag',
#    'alias': 'happy-bones-nyc-new-york',
#    'name': 'Happy Bones NYC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8F3z3Mvf2Lk-BRGthuqdPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/happy-bones-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 276,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720726, 'longitude': -73.9970474},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '394 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['394 Broome St', 'New York, NY 10013']},
#    'phone': '+12126733754',
#    'display_phone': '(212) 673-3754',
#    'distance': 1718.756434115631},
#   {'id': 'qXuUBEaib4caLC6WCPhBjA',
#    'alias': 'patisserie-tomoko-brooklyn-2',
#    'name': 'Patisserie Tomoko',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lfFS5x973jlpmFuq5vRf9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-tomoko-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 347,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'macarons', 'title': 'Macarons'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7176114, 'longitude': -73.9519192},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '568 Union Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['568 Union Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17183887121',
#    'display_phone': '(718) 388-7121',
#    'distance': 3819.1739527873074},
#   {'id': '0adywHMtQz9YSg7gON3gAA',
#    'alias': 'holey-cream-new-york',
#    'name': 'Holey Cream',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/f_2Xcqz1fJFmc6N9EefpoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holey-cream-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1021,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.76522, 'longitude': -73.98791},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '791 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['791 9th Ave', 'New York, NY 10019']},
#    'phone': '+12122478400',
#    'display_phone': '(212) 247-8400',
#    'distance': 6675.229676826283},
#   {'id': 'giL47kf_ln3aqJNWhGuNCA',
#    'alias': 'pinkys-space-new-york',
#    'name': "Pinky's Space",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TyBtG-Ojhb4ZeYo3pXmzhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pinkys-space-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'southern', 'title': 'Southern'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72355, 'longitude': -73.98879},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '70 E 1st St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70 E 1st St', 'New York, NY 10003']},
#    'phone': '+19179609699',
#    'display_phone': '(917) 960-9699',
#    'distance': 2065.7694270996762},
#   {'id': 'j9TdOBSQ1LRw8v3hW5fObQ',
#    'alias': 'pies-n-thighs-brooklyn',
#    'name': 'Pies-n-Thighs',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZEox6v_ipIvcrzeRv9mFIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pies-n-thighs-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3007,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.711191, 'longitude': -73.961424},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '166 S 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['166 S 4th St', 'Brooklyn, NY 11211']},
#    'phone': '+13475296090',
#    'display_phone': '(347) 529-6090',
#    'distance': 2843.269690474491},
#   {'id': 'PwjbH9rSjNwDLQsudlF3LA',
#    'alias': 'krispy-kreme-new-york-18',
#    'name': 'Krispy Kreme',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Mpu8ZMvt0L7fhRH3pmhm7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/krispy-kreme-new-york-18?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74043617932742,
#     'longitude': -73.98748373157231},
#    'transactions': [],
#    'location': {'address1': '36 E 23rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['36 E 23rd St', 'New York, NY 10010']},
#    'phone': '+18004574779',
#    'display_phone': '(800) 457-4779',
#    'distance': 3932.9417697008726},
#   {'id': 'kCRNgd0gE1jqdxH6iKRjRw',
#    'alias': 'hidden-grounds-coffee-jersey-city-4',
#    'name': 'Hidden Grounds Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HNPavradlGCiWz6k0EG9Dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hidden-grounds-coffee-jersey-city-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72221, 'longitude': -74.04624},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '276 1st St',
#     'address2': None,
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['276 1st St', 'Jersey City, NJ 07302']},
#    'phone': '+12016100090',
#    'display_phone': '(201) 610-0090',
#    'distance': 4754.477119889276},
#   {'id': 'djQCSwY5ElZYxFqTZYoDww',
#    'alias': 'alfalfa-hoboken',
#    'name': 'Alfalfa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6Z9YRbMGHSj5ag-VGS5mjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alfalfa-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 128,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75048, 'longitude': -74.02725},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1110 Washington St',
#     'address2': None,
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1110 Washington St', 'Hoboken, NJ 07030']},
#    'phone': '+12017900491',
#    'display_phone': '(201) 790-0491',
#    'distance': 5726.802627820289},
#   {'id': 'MCgYN8r2pPEpAVQKpGd9Kw',
#    'alias': 'santos-bakery-yonkers',
#    'name': 'Santos Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PfKGSyVzdoFEGUb1ty0W-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/santos-bakery-yonkers?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.929481, 'longitude': -73.891914},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '171 Willow St',
#     'address2': '',
#     'address3': '',
#     'city': 'Yonkers',
#     'zip_code': '10701',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 Willow St', 'Yonkers, NY 10701']},
#    'phone': '+19149636778',
#    'display_phone': '(914) 963-6778',
#    'distance': 26358.510558995098},
#   {'id': 'Am3m06BI0IBh1T1o403_ow',
#    'alias': 'blissbomb-new-york-2',
#    'name': 'BlissBomb',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-DyPeydvBE-hwWjF9No5Nw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blissbomb-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.75558154309362,
#     'longitude': -73.99317993187233},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '335 W 38th St',
#     'address2': 'Fl 11',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['335 W 38th St', 'Fl 11', 'New York, NY 10018']},
#    'phone': '+19179366251',
#    'display_phone': '(917) 936-6251',
#    'distance': 5575.727293765613},
#   {'id': 'lqbj9LGZq7MnyAlxGxvsfA',
#    'alias': 'holey-cream-new-york-2',
#    'name': 'Holey Cream',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6-P5xlLsH4JacL2oSzw8lw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holey-cream-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74634, 'longitude': -73.9779},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '522 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['522 3rd Ave', 'New York, NY 10016']},
#    'phone': '+12124478400',
#    'display_phone': '(212) 447-8400',
#    'distance': 4757.791214886229},
#   {'id': 'mU23NlQfn1R9OhA6WMe_xg',
#    'alias': 'breads-bakery-new-york',
#    'name': 'Breads Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mDaSWYX8hEV0eNGXJSDhVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/breads-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1080,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73661, 'longitude': -73.99181},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '18 E 16th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18 E 16th St', 'New York, NY 10003']},
#    'phone': '+12126332253',
#    'display_phone': '(212) 633-2253',
#    'distance': 3470.824425100059},
#   {'id': '6LJj6bh_sa0BTllNfNvwsw',
#    'alias': 'dough-brooklyn-3',
#    'name': 'Dough',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ozchKtsanH9_S9e_jTpHLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dough-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.67703, 'longitude': -73.9693},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '646 Vanderbilt Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['646 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#    'phone': '+16467470806',
#    'display_phone': '(646) 747-0806',
#    'distance': 3801.1410695306186},
#   {'id': 'NAKyofVbdyf5msnrLVchYg',
#    'alias': 'bittersweet-brooklyn',
#    'name': 'Bittersweet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gDZ53Vyw2ZCqgnn6GbBWnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bittersweet-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 136,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.689498, 'longitude': -73.9725219},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '180 Dekalb Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['180 Dekalb Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17188522556',
#    'display_phone': '(718) 852-2556',
#    'distance': 2552.0535545128237},
#   {'id': 'ZTlbDn7S3ZZfCDMlpVrAQg',
#    'alias': 'milk-bar-upper-west-side-new-york-3',
#    'name': 'Milk Bar Upper West Side',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/odDDAJX4KGTSmT7_mb70fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/milk-bar-upper-west-side-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 547,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7872421245758,
#     'longitude': -73.9713722245369},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '561 Columbus Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['561 Columbus Ave', 'New York, NY 10024']},
#    'phone': '+12122560586',
#    'display_phone': '(212) 256-0586',
#    'distance': 9298.131828193516},
#   {'id': 'iSGQWoJ1D2o0rbOsjd6OIQ',
#    'alias': 'the-sweet-shop-nyc-new-york',
#    'name': 'The Sweet Shop NYC',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/thpbNLZICt7eZe4WhrLi1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-sweet-shop-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 456,
#    'categories': [{'alias': 'candy', 'title': 'Candy Stores'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'chocolate', 'title': 'Chocolatiers & Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.768054, 'longitude': -73.955091},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '404 E 73rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['404 E 73rd St', 'New York, NY 10021']},
#    'phone': '+12129608685',
#    'display_phone': '(212) 960-8685',
#    'distance': 7705.598938745693},
#   {'id': 'tw9BPuTEyF0TxjTYJcIavg',
#    'alias': 'krispy-kreme-new-york-4',
#    'name': 'Krispy Kreme',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kaRfSNtYrNxZkoX4sjJ4dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/krispy-kreme-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 296,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7499255997679,
#     'longitude': -73.992213328836},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '2 Penn Plz',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2 Penn Plz', 'New York, NY 10001']},
#    'phone': '+12126950428',
#    'display_phone': '(212) 695-0428',
#    'distance': 4949.130857828275},
#   {'id': '5UR2nOXYZAakXAoHHoBqNg',
#    'alias': '7th-avenue-donuts-brooklyn-36',
#    'name': '7th Avenue Donuts',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LZUDb5c-u5uGzq1p1FYLSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/7th-avenue-donuts-brooklyn-36?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 257,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.667279, 'longitude': -73.981574},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '324 7th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['324 7th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187680748',
#    'display_phone': '(718) 768-0748',
#    'distance': 4374.315551523456},
#   {'id': 'fJN6oV2U2Rat4_JQv7OybA',
#    'alias': 'ugly-donuts-and-corn-dogs-new-york',
#    'name': 'Ugly Donuts & Corn Dogs',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZdDekFyRl7pER5l94lxviA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ugly-donuts-and-corn-dogs-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7498157, 'longitude': -73.8822535},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '84-06 37th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['84-06 37th Ave', 'New York, NY 11372']},
#    'phone': '+13475060425',
#    'display_phone': '(347) 506-0425',
#    'distance': 10662.18286405609},
#   {'id': '4VEgZ7aVUt6oKw8KmXj-jQ',
#    'alias': 'brooklyn-kolache-brooklyn',
#    'name': 'Brooklyn Kolache',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QqQV6MtAiG4i2vqCwFQhCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-kolache-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 337,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6907913077698,
#     'longitude': -73.9556479454041},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '520 Dekalb Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['520 Dekalb Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17183981111',
#    'display_phone': '(718) 398-1111',
#    'distance': 3642.653889043858},
#   {'id': 'yicBRA8X7urJyKn6aF2wzw',
#    'alias': 'sullivan-street-bakery-new-york-4',
#    'name': 'Sullivan Street Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/C5EOOhqnVAhEA9ay3zwXUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sullivan-street-bakery-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 283,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7474103457198,
#     'longitude': -74.0005904621599},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '236 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['236 9th Ave', 'New York, NY 10001']},
#    'phone': '+12129295900',
#    'display_phone': '(212) 929-5900',
#    'distance': 4684.439691978602},
#   {'id': 'wWhZvkaFrntlSf1CWvD1Zw',
#    'alias': 'cafe-patoro-new-york',
#    'name': 'Cafe Patoro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Nnlsd9Wl7KFVVqZxtDRWpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-patoro-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 182,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7072720974983,
#     'longitude': -74.0023160353303},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '223 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['223 Front St', 'New York, NY 10038']},
#    'phone': '+19172620031',
#    'display_phone': '(917) 262-0031',
#    'distance': 706.1266596183273},
#   {'id': '9rCpZ15AD8E5Ev18BEiAGQ',
#    'alias': 'top-that-donuts-rutherford',
#    'name': 'Top That! Donuts',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YC5fKXWnPkdzYJXDtRUV7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/top-that-donuts-rutherford?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.8251, 'longitude': -74.1088},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '8 Highland Cross',
#     'address2': None,
#     'address3': '',
#     'city': 'Rutherford',
#     'zip_code': '07070',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['8 Highland Cross', 'Rutherford, NJ 07070']},
#    'phone': '+12015595485',
#    'display_phone': '(201) 559-5485',
#    'distance': 16440.051875642},
#   {'id': 'A7IV4pAQOL5M8X7StKS-4Q',
#    'alias': 'gossip-coffee-astoria-2',
#    'name': 'Gossip Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qxIdTTIMJ6zp8LL0Ryn9jQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gossip-coffee-astoria-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 393,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76436, 'longitude': -73.9166},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '37-04 30th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37-04 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17184408792',
#    'display_phone': '(718) 440-8792',
#    'distance': 9265.923443284166},
#   {'id': 'RcqZmRj3mWiimohFnNA4Nw',
#    'alias': 'milk-bar-east-village-new-york-2',
#    'name': 'Milk Bar East Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2xYDsaWyFxdCNyY1z5pVRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/milk-bar-east-village-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3364,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7318893900159,
#     'longitude': -73.9857388595245},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '251 E 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['251 E 13th St', 'New York, NY 10003']},
#    'phone': '+16466924154',
#    'display_phone': '(646) 692-4154',
#    'distance': 3027.581728184138},
#   {'id': 'MjkCDpn7zYYXj2bBP3Oadw',
#    'alias': 'black-star-bakery-and-cafe-new-york-2',
#    'name': 'Black Star Bakery & Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/E69KtTPdSizifodPSq79iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-star-bakery-and-cafe-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 85,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7749269639842,
#     'longitude': -73.948163241148},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1597 York Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1597 York Ave', 'New York, NY 10028']},
#    'phone': '+16467264546',
#    'display_phone': '(646) 726-4546',
#    'distance': 8648.480322772428},
#   {'id': '4GBqDgTYsV7owGzNMyAFKA',
#    'alias': 'sullivan-street-bakery-new-york-3',
#    'name': 'Sullivan Street Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9IqTUcD62P3ziCRpCel3dA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sullivan-street-bakery-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 522,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76366, 'longitude': -73.994716},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '533 W 47th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['533 W 47th St', 'New York, NY 10036']},
#    'phone': '+12122655580',
#    'display_phone': '(212) 265-5580',
#    'distance': 6473.318564773586},
#   {'id': 'Hs1TH_4FpyzbX6_J5r1XXg',
#    'alias': 'mollys-cupcakes-new-york',
#    'name': "Molly's Cupcakes",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UPAzgAsBqOlHdi00SfCwnQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mollys-cupcakes-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1717,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73014, 'longitude': -74.00248},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '228 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12124142253',
#    'display_phone': '(212) 414-2253',
#    'distance': 2828.812386861157},
#   {'id': 'UpTEFSKKgMTHtzf8N4_kog',
#    'alias': 'kai-sweets-mitsuwa-edgewater',
#    'name': 'Kai Sweets Mitsuwa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/z4-vLezojcV-dcTtAJlehw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kai-sweets-mitsuwa-edgewater?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.81620773938682,
#     'longitude': -73.98024009324925},
#    'transactions': [],
#    'location': {'address1': '595 River Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Edgewater',
#     'zip_code': '07020',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['595 River Rd', 'Edgewater, NJ 07020']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 12372.998062916728}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                  Restaurant                       Type Price Rating  \
# 0         Stuffed Ice Cream  Ice Cream & Frozen Yogurt     $    4.5
# 1             Levain Bakery                   Bakeries    $$    4.5
# 2  Black Star Bakery & Cafe                   Bakeries     $      4
# 3               Duck Donuts                   Desserts
# 4          Takahachi Bakery                   Bakeries    $$      4
#
#          Address        Lat        Lng  \
# 0    139 1st Ave  40.728050 -73.985380
# 1  167 W 74th St  40.779961 -73.980299
# 2  2-10 50th Ave  40.743349 -73.958035
# 3      556 NJ-17  40.958483 -74.073850
# 4   25 Murray St  40.713930 -74.008220
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/stuffed-ice-cream-new...  0kH1mGuqIb5rOrvCKGsWtA
# 1  https://www.yelp.com/biz/levain-bakery-new-yor...  H4jJ7XB3CetIr1pg56CczQ
# 2  https://www.yelp.com/biz/black-star-bakery-and...  gfgbbPRqVqSj_rxlSwhJhg
# 3
# 4  https://www.yelp.com/biz/takahachi-bakery-new-...  GlPJPpKvPR4d8dmcSEYpdA

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"donuts","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': 'nU4XBdvxDABXqZ6CnB8Dig',
#    'alias': 'clinton-street-baking-company-new-york-5',
#    'name': 'Clinton Street Baking Company',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DWHdizJ9bKbXN4yq6nbwAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clinton-street-baking-company-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5277,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.721128, 'longitude': -73.983933},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4 Clinton St', 'New York, NY 10002']},
#    'phone': '+16466026263',
#    'display_phone': '(646) 602-6263',
#    'distance': 1950.282829638887},
#   {'id': 'S-M4rqJM7fwLJ2rSMYS35g',
#    'alias': 'madman-bakery-new-york',
#    'name': 'Madman Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mJe3nsD6Kiye3Fc3Des_PQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/madman-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.73242, 'longitude': -73.99426},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '42 University Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 University Pl', 'New York, NY 10003']},
#    'phone': '+13477811121',
#    'display_phone': '(347) 781-1121',
#    'distance': 2999.863061685295},
#   {'id': 'yaBrQbt7kMrbXAo6qrzpYw',
#    'alias': 'by-the-way-bakery-new-york',
#    'name': 'By the Way Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iioE0AdgUvuhNdogk04M6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/by-the-way-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 244,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7910023, 'longitude': -73.9742942},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '2442 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2442 Broadway', 'New York, NY 10024']},
#    'phone': '+12128770806',
#    'display_phone': '(212) 877-0806',
#    'distance': 9661.559070639432},
#   {'id': 'lj7MllVyDdJY98xZ2xipBw',
#    'alias': 'holey-slopes-brooklyn-4',
#    'name': 'Holey Slopes',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ehBmfNGcRFXMERgnj2DMtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holey-slopes-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'foodtours', 'title': 'Food Tours'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.6688919067383,
#     'longitude': -73.9819030761719},
#    'transactions': [],
#    'location': {'address1': None,
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Brooklyn, NY 11215']},
#    'phone': '+19293246215',
#    'display_phone': '(929) 324-6215',
#    'distance': 4315.243874272614},
#   {'id': 'Oz99IhUQvWiQjszYIhhPqw',
#    'alias': 'donut-world-staten-island',
#    'name': 'Donut World',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c3l5JZktQ8HYZapTRy8d3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/donut-world-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 102,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6047066246297,
#     'longitude': -74.1210346891034},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '11 Holden Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10314',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 Holden Blvd', 'Staten Island, NY 10314']},
#    'phone': '+17184772777',
#    'display_phone': '(718) 477-2777',
#    'distance': 15484.993098760388},
#   {'id': 'iks1xNyp-uZnaeunOM2UPg',
#    'alias': 'magnolia-bakery-rockefeller-center-new-york',
#    'name': 'Magnolia Bakery Rockefeller Center',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fSq3zjaIlaxP6nRZ85liKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/magnolia-bakery-rockefeller-center-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2589,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7592651914885,
#     'longitude': -73.980564548757},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1240 Ave of the Americas',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10020',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1240 Ave of the Americas', 'New York, NY 10020']},
#    'phone': '+12127671123',
#    'display_phone': '(212) 767-1123',
#    'distance': 6095.313685956134},
#   {'id': 'I41VRmgmiQ4kITgFZtJlvQ',
#    'alias': 'old-poland-bakery-brooklyn-2',
#    'name': 'Old Poland Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/siXMguqT0CH7vYT1ouoRDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/old-poland-bakery-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.731071, 'longitude': -73.9542397},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '926 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['926 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4416.609623364894},
#   {'id': 'cft7y3jbgc8iR55q5aKlOg',
#    'alias': 'le-pain-quotidien-new-york-191',
#    'name': 'Le Pain Quotidien',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4X52Z5zeoYCi42lyaF-nLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-pain-quotidien-new-york-191?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76722, 'longitude': -73.98154},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1800 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1800 Broadway', 'New York, NY 10019']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6965.3755800457675},
#   {'id': 'w8eAlTI-8pbVecPsWMrEMw',
#    'alias': 'baked-in-brooklyn-bakery-store-brooklyn',
#    'name': 'Baked In Brooklyn Bakery Store',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6FIArb2bNa931A807Kxl4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baked-in-brooklyn-bakery-store-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 259,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6589279174805,
#     'longitude': -73.9963531494141},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '755 5th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11232',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['755 5th Ave', 'Brooklyn, NY 11232']},
#    'phone': '+17187883164',
#    'display_phone': '(718) 788-3164',
#    'distance': 5176.155801775199},
#   {'id': 'R-ve5GRzP0WlbQvDVI3HKg',
#    'alias': 'pane-pasta-new-york',
#    'name': 'Pane Pasta',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PoKPQWzg6bWQsBARUS0wZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pane-pasta-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.73328, 'longitude': -73.99905},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '58 West 8th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['58 West 8th St', 'New York, NY 10011']},
#    'phone': '+16468910006',
#    'display_phone': '(646) 891-0006',
#    'distance': 3119.6227757097427},
#   {'id': 'xHBpwGzxxbC3vTahHWdABg',
#    'alias': 'perk-kafe-new-york',
#    'name': 'Perk Kafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Vdc89zdAqvqORqgVsWvkqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/perk-kafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 406,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.747764735907,
#     'longitude': -73.9770407671092},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '162 E 37th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 E 37th St', 'New York, NY 10016']},
#    'phone': '+12126867375',
#    'display_phone': '(212) 686-7375',
#    'distance': 4925.2051311799305},
#   {'id': 'XP9d5FQWYs_90qJ2a9jQUQ',
#    'alias': 'doughnuttery-new-york-3',
#    'name': 'Doughnuttery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PTc_E2htj3UfE_-ySRWKcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doughnuttery-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7669606, 'longitude': -73.98292057259813},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1000 S Eighth Ave',
#     'address2': '',
#     'address3': 'TurnStyle Underground Market',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1000 S Eighth Ave',
#      'TurnStyle Underground Market',
#      'New York, NY 10019']},
#    'phone': '+12126334359',
#    'display_phone': '(212) 633-4359',
#    'distance': 6907.017688543341},
#   {'id': 'bvc5P9vmRiNhyVWjd5bVcg',
#    'alias': 'eclair-bakery-new-york',
#    'name': 'Eclair Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qjM8dIvuUOCIGnnet6R_5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eclair-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 649,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'macarons', 'title': 'Macarons'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.756689, 'longitude': -73.966617},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '305 E 53rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['305 E 53rd St', 'New York, NY 10022']},
#    'phone': '+16464298555',
#    'display_phone': '(646) 429-8555',
#    'distance': 6156.82625750047},
#   {'id': 'vRpUrmIJSC6EpoOVOaYHvw',
#    'alias': 'donut-connection-brooklyn-6',
#    'name': 'Donut Connection',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/23p8ZSakAAgBuzSy4dUI4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/donut-connection-brooklyn-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.63606, 'longitude': -74.02625},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '6830 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11220',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6830 3rd Ave', 'Brooklyn, NY 11220']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8171.933094165659},
#   {'id': 'MKYhiSeXjahxh9O4Gqnimw',
#    'alias': 'grace-street-new-york',
#    'name': 'Grace Street',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sGpzBlU62QQfT9H1Z-yzvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grace-street-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2744,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'shavedice', 'title': 'Shaved Ice'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7478576793883,
#     'longitude': -73.9865590631962},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '17 W 32nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 W 32nd St', 'New York, NY 10001']},
#    'phone': '+19177452125',
#    'display_phone': '(917) 745-2125',
#    'distance': 4760.904253854418},
#   {'id': 'vC5ULFjT5F8fAIF3oRBoFg',
#    'alias': 'la-snackeria-nyc-brooklyn-3',
#    'name': 'La Snackeria NYC',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9AuncgmG1pbY7eTLDLc2Zg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-snackeria-nyc-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.64012, 'longitude': -74.01531},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '5823 5th Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11220',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5823 5th Ave', 'Brooklyn, NY 11220']},
#    'phone': '+13477992953',
#    'display_phone': '(347) 799-2953',
#    'distance': 7476.534083692314},
#   {'id': 'Qyluj1pQN3QAwaslpJSQ3g',
#    'alias': 'the-grind-shop-jersey-city',
#    'name': 'The Grind Shop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Im2WLrYOJz61zrORIk9HFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grind-shop-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 148,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7117091, 'longitude': -74.062755},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '360 Communipaw Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07304',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['360 Communipaw Ave', 'Jersey City, NJ 07304']},
#    'phone': '+12015478377',
#    'display_phone': '(201) 547-8377',
#    'distance': 5809.033564480759},
#   {'id': 'wQ0JmNOhtH5s2V3MjcRnfQ',
#    'alias': 'krispy-kreme-new-york-6',
#    'name': 'Krispy Kreme',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/B9Un9zl3QsW-awszxfukmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/krispy-kreme-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.751491, 'longitude': -73.986199},
#    'transactions': ['delivery'],
#    'location': {'address1': '994 6th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['994 6th Ave', 'New York, NY 10018']},
#    'phone': '+18004574779',
#    'display_phone': '(800) 457-4779',
#    'distance': 5165.3200339136},
#   {'id': '1pqoG5XDSpbxCzOLEWifOg',
#    'alias': 'doughology-lynbrook-lynbrook',
#    'name': 'Doughology - Lynbrook',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4LisOvwRR1cEfv07Wdtg-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doughology-lynbrook-lynbrook?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 428,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.65574062362305,
#     'longitude': -73.67189693724923},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '45 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Lynbrook',
#     'zip_code': '11563',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 Atlantic Ave', 'Lynbrook, NY 11563']},
#    'phone': '+15163410882',
#    'display_phone': '(516) 341-0882',
#    'distance': 27742.206358103693},
#   {'id': 'drE9p2p_a9TptqyOFnnJVg',
#    'alias': 'fabrique-new-york',
#    'name': 'Fabrique',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/efMAA30lwKD48lKGbNtavQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fabrique-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 165,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7405, 'longitude': -74.00471},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '348 W 14th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['348 W 14th St', 'New York, NY 10014']},
#    'phone': '+19172612476',
#    'display_phone': '(917) 261-2476',
#    'distance': 3991.028597552693},
#   {'id': 'Q_7J5E-cYCQfHNCkCyMdLA',
#    'alias': 'baked-brooklyn',
#    'name': 'Baked',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IVtF0KBB15w5ya_lMD_oAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baked-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 509,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.676789, 'longitude': -74.013211},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '359 Van Brunt St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['359 Van Brunt St', 'Brooklyn, NY 11231']},
#    'phone': '+17182220345',
#    'display_phone': '(718) 222-0345',
#    'distance': 3563.290868654911},
#   {'id': 'fPQ2eE9lm8tc87O5-GLjyA',
#    'alias': 'mille-feuille-bakery-new-york-3',
#    'name': 'Mille-Feuille Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8u453wcp-jdwfV9kpimDQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mille-feuille-bakery-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 356,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.782425, 'longitude': -73.9811603},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2175 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2175 Broadway', 'New York, NY 10024']},
#    'phone': '+12123626261',
#    'display_phone': '(212) 362-6261',
#    'distance': 8630.99662794525},
#   {'id': 'd1dYHmgFkJ3XuywHUNorYg',
#    'alias': 'northside-bakery-brooklyn',
#    'name': 'Northside Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rJwh6pH0xTGfFVoq25z0kA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/northside-bakery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7186567889571,
#     'longitude': -73.9573605286252},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '149 N 8th St',
#     'address2': '',
#     'address3': 'Division Of Old Poland Foods',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['149 N 8th St',
#      'Division Of Old Poland Foods',
#      'Brooklyn, NY 11249']},
#    'phone': '+17187825551',
#    'display_phone': '(718) 782-5551',
#    'distance': 3442.135082638887},
#   {'id': 'xdR5JXRZZG9hYNTNGiEOKA',
#    'alias': 'carnivale-donut-bar-hoboken',
#    'name': 'Carnivale Donut Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oGBIL1mCWNPSu1rj2P8Tyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carnivale-donut-bar-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7441329956055,
#     'longitude': -74.0326919555664},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': '',
#     'address3': None,
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['Hoboken, NJ 07030']},
#    'phone': '+18887551611',
#    'display_phone': '(888) 755-1611',
#    'distance': 5104.92488943443},
#   {'id': 'kA98xP8HiJ_-fVaM7RECLw',
#    'alias': 'laughing-man-coffee-company-new-york',
#    'name': 'Laughing Man Coffee Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/G9aR228M0F9tibtPUQnMOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laughing-man-coffee-company-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 255,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71731, 'longitude': -74.01016},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '184 Duane St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['184 Duane St', 'New York, NY 10013']},
#    'phone': '+12126801111',
#    'display_phone': '(212) 680-1111',
#    'distance': 1872.338686956493},
#   {'id': '6v5qi9oYI69GeHxGFXo3HQ',
#    'alias': 'the-dough-club-flushing-flushing',
#    'name': 'The Dough Club - Flushing',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tmfXSb1_Yf3tT2lRaPCahA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dough-club-flushing-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76057693679254,
#     'longitude': -73.82981219999999},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '136-17 39th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136-17 39th Ave', 'Flushing, NY 11354']},
#    'phone': '+19178267821',
#    'display_phone': '(917) 826-7821',
#    'distance': 15154.301753275311},
#   {'id': 'vAFLi68I-s3wZEkoVy44kg',
#    'alias': 'dough-astoria-astoria',
#    'name': 'Dough - Astoria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/g0iMlel7wSQxuGjXKT1dyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dough-astoria-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77669, 'longitude': -73.91068},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2170 31st St',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2170 31st St', 'Astoria, NY 11105']},
#    'phone': '+17185409170',
#    'display_phone': '(718) 540-9170',
#    'distance': 10600.617239777102},
#   {'id': 'Q0JWPHcXTDKNP4c8QNU4pw',
#    'alias': 'taiyaki-nyc-williamsburg-brooklyn-6',
#    'name': 'Taiyaki NYC - Williamsburg',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/e7TVPVj_dpWDO13RqEtCIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taiyaki-nyc-williamsburg-brooklyn-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 243,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'waffles', 'title': 'Waffles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7143691, 'longitude': -73.9615536},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '294 Bedford Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['294 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+19179091856',
#    'display_phone': '(917) 909-1856',
#    'distance': 2931.7598355412497},
#   {'id': 'uXIh-aQ1jpJ6Q_VpXVTAqA',
#    'alias': 'donut-shoppe-shaikhs-place-brooklyn-3',
#    'name': "Donut Shoppe Shaikh's Place",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YAZFGmF5L6Y2y6XxV55YxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/donut-shoppe-shaikhs-place-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 199,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.598978079871436, 'longitude': -73.9562222},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1503 Ave U',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11229',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1503 Ave U', 'Brooklyn, NY 11229']},
#    'phone': '+17183752572',
#    'display_phone': '(718) 375-2572',
#    'distance': 12266.475285370228},
#   {'id': '0dzgN-zWU5VTAdEmqfrMxw',
#    'alias': 'afternoon-new-york',
#    'name': 'Afternoon',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/l9BKygCC1Y1R900qY1AL-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/afternoon-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76469, 'longitude': -73.77124},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '39-21 Bell Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39-21 Bell Blvd', 'New York, NY 11361']},
#    'phone': '+17188854248',
#    'display_phone': '(718) 885-4248',
#    'distance': 19918.327938851617},
#   {'id': 'gXz2MvC4637r2rg5YVO2tw',
#    'alias': 'big-booty-bread-new-york',
#    'name': 'Big Booty Bread',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Av4z17ymFhVgE8YCGRynkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/big-booty-bread-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 327,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.745115, 'longitude': -73.9977148},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '261 W 23rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['261 W 23rd St', 'New York, NY 10011']},
#    'phone': '+12124143056',
#    'display_phone': '(212) 414-3056',
#    'distance': 4419.038186328543},
#   {'id': 'jZZMmT7Mk3S-fNjXcq3Ksg',
#    'alias': 'devocion-brooklyn-4',
#    'name': 'Devocion',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/33rJ0M41qXFWuQOIF382Ow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/devocion-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 496,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.716054, 'longitude': -73.964684},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '69 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['69 Grand St', 'Brooklyn, NY 11249']},
#    'phone': '+17182856180',
#    'display_phone': '(718) 285-6180',
#    'distance': 2762.7656443327546},
#   {'id': 'vOJkqLM8Kv4GyQe16UUPjg',
#    'alias': 'brooklyn-farmacy-and-soda-fountain-brooklyn',
#    'name': 'Brooklyn Farmacy & Soda Fountain',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9CL2VjLdrDQTybdEOU3CNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-farmacy-and-soda-fountain-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 714,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68398, 'longitude': -73.99923},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '513 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['513 Henry St', 'Brooklyn, NY 11231']},
#    'phone': '+17185226260',
#    'display_phone': '(718) 522-6260',
#    'distance': 2422.913083885877},
#   {'id': 'YhbVnNXWa8DXCGDCEGey2g',
#    'alias': 'krispy-kreme-new-york-19',
#    'name': 'krispy kreme',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UvJ9XlvTR9yRpXTJxD6VAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/krispy-kreme-new-york-19?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.79024, 'longitude': -73.94587},
#    'transactions': [],
#    'location': {'address1': '1882 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1882 3rd Ave', 'New York, NY 10029']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 10274.333705110499},
#   {'id': 'tq7dDT6edTInhkNdDrYv_w',
#    'alias': 'black-brick-brooklyn',
#    'name': 'Black Brick',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KMA7EDvWqQnCa9T6SICejQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-brick-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 325,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7142079238412,
#     'longitude': -73.9617848396301},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '300 Bedford Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['300 Bedford Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17183840075',
#    'display_phone': '(718) 384-0075',
#    'distance': 2908.1707973176744},
#   {'id': 'cO9E0n9ulzJ6eZ4TKrFx1A',
#    'alias': 'mille-feuille-bakery-new-york-2',
#    'name': 'Mille-Feuille Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tF46aDSEYYoEcbXAl3WHIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mille-feuille-bakery-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 529,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72933, 'longitude': -73.99808},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '552 Laguardia Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['552 Laguardia Pl', 'New York, NY 10012']},
#    'phone': '+12125334698',
#    'display_phone': '(212) 533-4698',
#    'distance': 2657.8473641828227},
#   {'id': 'WyUyyLZhZ03MXFYeXn3ekw',
#    'alias': 'glaze-donuts-new-milford',
#    'name': 'Glaze Donuts',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/24wckRAbo77astIzQRFuqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/glaze-donuts-new-milford?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 518,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.94091, 'longitude': -74.0213747},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '358 River Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'New Milford',
#     'zip_code': '07646',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['358 River Rd', 'New Milford, NJ 07646']},
#    'phone': '+12014838634',
#    'display_phone': '(201) 483-8634',
#    'distance': 26288.30392448021},
#   {'id': 'HUlbrPvAr6sXuBfp5z1MWA',
#    'alias': 'urban-backyard-new-york',
#    'name': 'Urban Backyard',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bB8vr7pVnZmY5x1Snh2WoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/urban-backyard-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 210,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72077, 'longitude': -73.99646},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '180 Mulberry St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['180 Mulberry St', 'New York, NY 10012']},
#    'phone': '+16466929957',
#    'display_phone': '(646) 692-9957',
#    'distance': 1716.018342303412},
#   {'id': 'ltmkkP4QMslSvQ1ZUvaqFQ',
#    'alias': 'krispy-kreme-new-york-13',
#    'name': 'Krispy Kreme',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kQIs7qQZkQp_cDsBbmVLLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/krispy-kreme-new-york-13?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.76037, 'longitude': -73.98519},
#    'transactions': [],
#    'location': {'address1': '1601 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1601 Broadway', 'New York, NY 10019']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6155.916119196422},
#   {'id': 'sM1mrw5y2ttH6GHNTRNieg',
#    'alias': 'mia-s-bakery-new-york',
#    'name': 'Mia’s Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Q9QxOcO2NBap09aV72WEyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mia-s-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 208,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7596408145034,
#     'longitude': -73.984548577331},
#    'transactions': ['delivery'],
#    'location': {'address1': '716 7th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['716 7th Ave', 'New York, NY 10036']},
#    'phone': '+19172614437',
#    'display_phone': '(917) 261-4437',
#    'distance': 6081.986166081543},
#   {'id': 'KWC_KYP336tSFhAihd8plg',
#    'alias': 'bluestone-lane-dumbo-café-brooklyn',
#    'name': 'Bluestone Lane DUMBO Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AjXvAC5Y5Blhi2a5XxpmIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bluestone-lane-dumbo-caf%C3%A9-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 196,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70077577888819,
#     'longitude': -73.98836356287899},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '55 Prospect St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Prospect St', 'Brooklyn, NY 11201']},
#    'phone': '+17183746858',
#    'display_phone': '(718) 374-6858',
#    'distance': 720.6910385584724},
#   {'id': 'b6M79bDjjUyG6x1YaDLSQA',
#    'alias': 'gabys-bakery-shop-brooklyn',
#    'name': "Gaby's Bakery Shop",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8iWO0XPvpQLIlvrdpZHdGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gabys-bakery-shop-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7027192, 'longitude': -73.9256314},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '238 Knickerbocker Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['238 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17184188821',
#    'display_phone': '(718) 418-8821',
#    'distance': 5795.806933940896},
#   {'id': '7PPk1YeN9IGIHXsEQNat1w',
#    'alias': 'darn-donuts-bay-ridge',
#    'name': 'Darn Donuts',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Nz_AKkFcM6Odv3lJf7NgfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/darn-donuts-bay-ridge?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 216,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.62128, 'longitude': -74.02864},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '8723 4th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bay Ridge',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8723 4th Ave', 'Bay Ridge, NY 11209']},
#    'phone': '+17188336300',
#    'display_phone': '(718) 833-6300',
#    'distance': 9797.991323795917},
#   {'id': 'RgXT9Pkui7IuWua2K9yuHA',
#    'alias': 'rossys-bakery-new-york',
#    'name': "Rossy's Bakery",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/f7Hiukfc-aeo4C8Ij64Cwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rossys-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'dominican', 'title': 'Dominican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72184, 'longitude': -73.98159},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '242 E 3rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['242 E 3rd St', 'New York, NY 10009']},
#    'phone': '+12122532424',
#    'display_phone': '(212) 253-2424',
#    'distance': 2112.399853679275},
#   {'id': 'Qmv4SPta2zx7MhKit8ywag',
#    'alias': 'absolute-coffee-brooklyn',
#    'name': 'Absolute Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WrEZlU_pGNek1-Bpb5vdtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/absolute-coffee-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 197,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68827, 'longitude': -73.987569},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '327 Atlantic Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['327 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17185220969',
#    'display_phone': '(718) 522-0969',
#    'distance': 1995.2838490428082},
#   {'id': 'BtPQRHhzavsP6wpZlQh-sA',
#    'alias': 'caputos-bake-shop-brooklyn',
#    'name': "Caputo's Bake Shop",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DlNTjIcDnkQWGy4fuBzEAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caputos-bake-shop-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 128,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.682819, 'longitude': -73.995391},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '329 Court St',
#     'address2': 'Ste 1',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['329 Court St', 'Ste 1', 'Brooklyn, NY 11231']},
#    'phone': '+17188756871',
#    'display_phone': '(718) 875-6871',
#    'distance': 2518.0146194257604},
#   {'id': 'sCNZGN2Zh1T5hht728hV5Q',
#    'alias': 'ursula-bk-brooklyn-2',
#    'name': 'Ursula BK',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5h1Jl1ea5L8aAgOu_nx92A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ursula-bk-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 69,
#    'categories': [{'alias': 'newmexican', 'title': 'New Mexican Cuisine'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.672656, 'longitude': -73.954677},
#    'transactions': [],
#    'location': {'address1': '724 Sterling Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['724 Sterling Pl', 'Brooklyn, NY 11216']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4934.048773964252},
#   {'id': 'CXYKLf3DgDB4eQ8rrJdfQA',
#    'alias': 'kith-treats-new-york',
#    'name': 'KITH Treats',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xwWJV4j0azB1kPYJIyP4Fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kith-treats-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 249,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72598, 'longitude': -73.99442},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '337 Lafayette St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['337 Lafayette St', 'New York, NY 10012']},
#    'phone': '+16466486285',
#    'display_phone': '(646) 648-6285',
#    'distance': 2284.2977523475392},
#   {'id': 'Q1ErIlQqHXqtb-13UXXjVQ',
#    'alias': 'four-and-twenty-blackbirds-brooklyn',
#    'name': 'Four & Twenty Blackbirds',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mieHuyQEc3E8RVJ5qU2LgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/four-and-twenty-blackbirds-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 728,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67206, 'longitude': -73.99015},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '439 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['439 3rd Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17184992917',
#    'display_phone': '(718) 499-2917',
#    'distance': 3727.5234855350877},
#   {'id': 'C_GM5FUpruYtIvIESpxrog',
#    'alias': 'guadalupana-bakery-brooklyn',
#    'name': 'Guadalupana Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cG9XvLU6S4qywxLuhC1p_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/guadalupana-bakery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.699218, 'longitude': -73.939908},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '308 Ellery St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['308 Ellery St', 'Brooklyn, NY 11206']},
#    'phone': '+17183842011',
#    'display_phone': '(718) 384-2011',
#    'distance': 4631.795565535603}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                       Restaurant        Type Price Rating           Address  \
# 0  Clinton Street Baking Company    Bakeries    $$      4      4 Clinton St
# 1                  Madman Bakery  Sandwiches               42 University Pl
# 2              By the Way Bakery    Bakeries     $    4.5     2442 Broadway
# 3                   Holey Slopes  Food Tours                           None
# 4                    Donut World      Donuts                 11 Holden Blvd
#
#          Lat        Lng                                                url  \
# 0  40.721128 -73.983933  https://www.yelp.com/biz/clinton-street-baking...
# 1  40.732420 -73.994260
# 2  40.791002 -73.974294  https://www.yelp.com/biz/by-the-way-bakery-new...
# 3  40.668892 -73.981903
# 4  40.604707 -74.121035
#
#                        ID
# 0  nU4XBdvxDABXqZ6CnB8Dig
# 1
# 2  yaBrQbt7kMrbXAo6qrzpYw
# 3
# 4

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"donuts","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [{'id': 'MYYWU9rEIRZw43lACKXzTQ',
#    'alias': 'yours-truly-new-york-4',
#    'name': 'Yours Truly',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/smCKk0S2k6_bM2akfLm1pQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yours-truly-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 94,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7210275432472,
#     'longitude': -73.9944903889549},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '8 Spring St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8 Spring St', 'New York, NY 10012']},
#    'phone': '+19173882641',
#    'display_phone': '(917) 388-2641',
#    'distance': 1732.792599342473},
#   {'id': 'fvDZVAvv_g4L-WWkbDpCXg',
#    'alias': 'patisserie-claude-new-york',
#    'name': 'Patisserie Claude',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pbL_trMOpVtW_rzGn0qPeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-claude-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 257,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7327402, 'longitude': -74.0018208},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '187 W 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['187 W 4th St', 'New York, NY 10014']},
#    'phone': '+12122555911',
#    'display_phone': '(212) 255-5911',
#    'distance': 3094.0515887033007},
#   {'id': 'VrCCr45dhN-RRM107iptdg',
#    'alias': 'russ-and-daughters-new-york',
#    'name': 'Russ & Daughters',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Fnsvde3LPl_ZdECuUf71sg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/russ-and-daughters-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2376,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'smokehouse', 'title': 'Smokehouse'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.722589, 'longitude': -73.9882828294139},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '179 E Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['179 E Houston St', 'New York, NY 10002']},
#    'phone': '+12124754880',
#    'display_phone': '(212) 475-4880',
#    'distance': 1972.4966482145887},
#   {'id': '8F81LrdFm6P5kkFpsw0n0w',
#    'alias': 'sweet-chick-new-york',
#    'name': 'Sweet Chick',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/e7M1L-t2C2wivXMx1qd-KQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweet-chick-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1731,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7217399, 'longitude': -73.98739},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '178 Ludlow St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['178 Ludlow St', 'New York, NY 10002']},
#    'phone': '+16466570233',
#    'display_phone': '(646) 657-0233',
#    'distance': 1901.1018520082853},
#   {'id': 'MauzeeZM7S-wUk_G98Ybrg',
#    'alias': 'mei-lai-wah-bakery-new-york',
#    'name': 'Mei Lai Wah Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rDd0B0a8-5CV3KItant2GA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mei-lai-wah-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1189,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7155758, 'longitude': -73.9979585},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '64 Bayard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64 Bayard St', 'New York, NY 10013']},
#    'phone': '+12129667866',
#    'display_phone': '(212) 966-7866',
#    'distance': 1167.8722852194924},
#   {'id': 'gJD6DsPQUYHVVCTHLB_nJw',
#    'alias': 'homecoming-brooklyn',
#    'name': 'Homecoming',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mo5lPrh84-DzKVBtCMJk0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/homecoming-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 65,
#    'categories': [{'alias': 'florists', 'title': 'Florists'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'homedecor', 'title': 'Home Decor'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729579, 'longitude': -73.957801},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '107 Franklin St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['107 Franklin St', 'Brooklyn, NY 11222']},
#    'phone': '+13474575385',
#    'display_phone': '(347) 457-5385',
#    'distance': 4081.7150044483446},
#   {'id': 'dcKktiP0nHEo4BSYk_WDag',
#    'alias': 'butterfield-market-new-york-2',
#    'name': 'Butterfield Market',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jBRbQiWj8ytA8N-qs-2UwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/butterfield-market-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'markets', 'title': 'Fruits & Veggies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78069, 'longitude': -73.95955},
#    'transactions': [],
#    'location': {'address1': '1150 Madison Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1150 Madison Ave', 'New York, NY 10028']},
#    'phone': '+12127582800',
#    'display_phone': '(212) 758-2800',
#    'distance': 8833.72738033817},
#   {'id': 'UeSxAEpzdytnCY6E8zvwRA',
#    'alias': 'ovenly-brooklyn-8',
#    'name': 'Ovenly',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zlTMBs1cxyo4cfOtXYdO4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ovenly-brooklyn-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 72,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68119, 'longitude': -73.97573},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '210 Flatbush Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['210 Flatbush Ave', 'Brooklyn, NY 11217']},
#    'phone': '+18888992213',
#    'display_phone': '(888) 899-2213',
#    'distance': 3118.2144010271345},
#   {'id': 'HxC2ZN010NxAFwjTqUVpzw',
#    'alias': 'rice-to-riches-new-york',
#    'name': 'Rice To Riches',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YcJMOVwMfrqTqX1Eo5XFoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rice-to-riches-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3074,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.721845, 'longitude': -73.995802},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '37 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37 Spring St', 'New York, NY 10012']},
#    'phone': '+12122740008',
#    'display_phone': '(212) 274-0008',
#    'distance': 1828.0382830472183},
#   {'id': 'YI49ybEJNLBbzwl5Qx2AMg',
#    'alias': 'cafe-boulis-astoria',
#    'name': 'Cafe Boulis',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fN9p9X4dXWJqKlitmDmehw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-boulis-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 209,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7646102445833,
#     'longitude': -73.9236790957008},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '30-15 31st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30-15 31st Ave', 'Astoria, NY 11106']},
#    'phone': '+17188061014',
#    'display_phone': '(718) 806-1014',
#    'distance': 8870.196776181758},
#   {'id': 'LJtq4TugycFgNN5AoJvc5Q',
#    'alias': 'posh-pop-bakeshop-new-york-2',
#    'name': 'Posh Pop Bakeshop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/pfvfrXB9sWtH5Yq--6ob9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/posh-pop-bakeshop-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 363,
#    'categories': [{'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7291965397419,
#     'longitude': -74.0015334018494},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '192 Bleecker St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['192 Bleecker St', 'New York, NY 10012']},
#    'phone': '+12126747674',
#    'display_phone': '(212) 674-7674',
#    'distance': 2710.6363038329896},
#   {'id': 'c3eMI4_o4dPDDhPV_ibBYQ',
#    'alias': 'ess-a-bagel-new-york',
#    'name': 'Ess-a-Bagel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KJliJ0mJDcTGVi36f30L7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ess-a-bagel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3788,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.756300559255,
#     'longitude': -73.9703701025162},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '831 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['831 3rd Ave', 'New York, NY 10022']},
#    'phone': '+12129801010',
#    'display_phone': '(212) 980-1010',
#    'distance': 6003.433036669106},
#   {'id': 'TS0VkHQC4IrY-8I8tQ30mw',
#    'alias': 'pop-pasta-brooklyn-2',
#    'name': 'Pop Pasta',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hRb9FRMSPiOPXYG3wML0zA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pop-pasta-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'pastashops', 'title': 'Pasta Shops'},
#     {'alias': 'popupshops', 'title': 'Pop-up Shops'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.64577, 'longitude': -74.0237},
#    'transactions': [],
#    'location': {'address1': '80 58th St',
#     'address2': 'Ste 302',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11220',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 58th St', 'Ste 302', 'Brooklyn, NY 11220']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 7078.2522089642225},
#   {'id': '_OHOUoZT5y7jczKEEND0Bw',
#    'alias': 'dipped-doughnuts-cliffside-park',
#    'name': 'Dipped Doughnuts',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7_t6I_BfINmGBjdmVCTZQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dipped-doughnuts-cliffside-park?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.827524, 'longitude': -73.986982},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '677 Anderson Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Cliffside Park',
#     'zip_code': '07010',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['677 Anderson Ave', 'Cliffside Park, NJ 07010']},
#    'phone': '+12014020677',
#    'display_phone': '(201) 402-0677',
#    'distance': 13588.522482866876},
#   {'id': '3zIjs0nyhAUOGR_D-BaQPg',
#    'alias': 'misfits-nutrition-forest-hills',
#    'name': 'MisFits Nutrition',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m1lF99H7GNKna0tlb1jsFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/misfits-nutrition-forest-hills?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'healthmarkets', 'title': 'Health Markets'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.716129, 'longitude': -73.834105},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '11514 Queens Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11514 Queens Blvd', 'Forest Hills, NY 11375']},
#    'phone': '+12038060609',
#    'display_phone': '(203) 806-0609',
#    'distance': 13553.939408272063},
#   {'id': 'FS4SNRnCHNnfZDux-Jgyww',
#    'alias': 'papa-donuts-restaurant-jersey-city',
#    'name': 'Papa Donuts Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KI4_FzIuRJfdOvYVVJJ6ww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/papa-donuts-restaurant-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7297481295302,
#     'longitude': -74.065274399316},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '896 Bergen Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07306',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['896 Bergen Ave', 'Jersey City, NJ 07306']},
#    'phone': '+12016534030',
#    'display_phone': '(201) 653-4030',
#    'distance': 6564.249288412683},
#   {'id': 'CjIBoGl2gdvojZvVlyPIgg',
#    'alias': 'huascar-and-co-bakeshop-new-york',
#    'name': 'Huascar & Co Bakeshop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gdYQDDmT8lMlyDMphFwFHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/huascar-and-co-bakeshop-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 255,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7671574, 'longitude': -73.9895795},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '453 W 54th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['453 W 54th St', 'New York, NY 10019']},
#    'phone': '+12129331041',
#    'display_phone': '(212) 933-1041',
#    'distance': 6873.596446573447},
#   {'id': '32yiaPVXSlYquRxI6_jnAg',
#    'alias': 'colson-patisserie-brooklyn',
#    'name': 'Colson Patisserie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xus9KxZWI_0OrCOupM_zgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/colson-patisserie-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 236,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.667755, 'longitude': -73.98397},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '374 9th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['374 9th St', 'Brooklyn, NY 11215']},
#    'phone': '+17189656400',
#    'display_phone': '(718) 965-6400',
#    'distance': 4277.417202929265},
#   {'id': 'Hk6yiiuk9lMFV1QilkYKYA',
#    'alias': 'sullivan-street-bakery-new-york-6',
#    'name': 'Sullivan Street Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FYsBKTxNSRvmv1iwsOoVGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sullivan-street-bakery-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72562430385372,
#     'longitude': -74.00281930212823},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '103 Sullivan St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 Sullivan St', 'New York, NY 10012']},
#    'phone': '+19173882900',
#    'display_phone': '(917) 388-2900',
#    'distance': 2356.103639581212},
#   {'id': 'gHdejB1Mx2P5UjAgZ6BT2w',
#    'alias': 'cheeky-sandwiches-new-york',
#    'name': 'Cheeky Sandwiches',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XGGQOLhQIL-Y8Y-CdHeOPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cheeky-sandwiches-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1263,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7158, 'longitude': -73.99169},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '35 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35 Orchard St', 'New York, NY 10002']},
#    'phone': '+16465048132',
#    'display_phone': '(646) 504-8132',
#    'distance': 1165.1002553885921},
#   {'id': 'DA1hijID0q6D6Ouch17v7w',
#    'alias': 'pecks-new-york',
#    'name': "Peck's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/H_hr9SJgmj0fOZZIdYCDQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pecks-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 150,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.693489, 'longitude': -73.967376},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '455A Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['455A Myrtle Ave', 'New York, NY 11205']},
#    'phone': '+13476894969',
#    'display_phone': '(347) 689-4969',
#    'distance': 2638.841789597834},
#   {'id': 'XxDsM2Q_tD8iP6T58785uw',
#    'alias': 'georgetown-cupcake-new-york',
#    'name': 'Georgetown Cupcake',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-HY6urroeSjVXy8PW5nNcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/georgetown-cupcake-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 916,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7238244169484,
#     'longitude': -73.9994524607132},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '111 Mercer St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 Mercer St', 'New York, NY 10012']},
#    'phone': '+12124314504',
#    'display_phone': '(212) 431-4504',
#    'distance': 2089.4574630570405},
#   {'id': 'SG9Az18z_UJDm4A61uswoA',
#    'alias': 'lily-bloom-bakery-brooklyn-4',
#    'name': 'Lily Bloom Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/npAzoprWGfLX8BCnjMKPOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lily-bloom-bakery-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 66,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.621261, 'longitude': -74.026771},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '8614 5th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8614 5th Ave', 'Brooklyn, NY 11209']},
#    'phone': '+17182333888',
#    'display_phone': '(718) 233-3888',
#    'distance': 9753.412388254492},
#   {'id': 'PDLYcA21uXCAlqRAkQLNNw',
#    'alias': 'ovenly-brooklyn',
#    'name': 'Ovenly',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/92S_XV7GShkVWM72gvx-Bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ovenly-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 211,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729904, 'longitude': -73.959579},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '31 Greenpoint Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31 Greenpoint Ave', 'Brooklyn, NY 11222']},
#    'phone': '+18888992213',
#    'display_phone': '(888) 899-2213',
#    'distance': 3991.6091247453433},
#   {'id': 'DOSNJk1qfKITbox4defOBw',
#    'alias': 'carlos-bakery-hoboken-9',
#    'name': "Carlo's Bakery",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LPOXChQ4qoub9fGR0kHvUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carlos-bakery-hoboken-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1408,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7372037883636,
#     'longitude': -74.031268176657},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '95 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['95 Washington St', 'Hoboken, NJ 07030']},
#    'phone': '+12016593671',
#    'display_phone': '(201) 659-3671',
#    'distance': 4709.619739464844},
#   {'id': 'Wqf1hvoa25jVBU31oULkfA',
#    'alias': 'babka-bakers-maspeth',
#    'name': 'Babka Bakers',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ebp5b3nuDJYqbHtqAWIyuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/babka-bakers-maspeth?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72316, 'longitude': -73.90465},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '60-45 Maspeth Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Maspeth',
#     'zip_code': '11378',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60-45 Maspeth Ave', 'Maspeth, NY 11378']},
#    'phone': '+17188948877',
#    'display_phone': '(718) 894-8877',
#    'distance': 7811.539311239653},
#   {'id': 'VzHdgvEv9bx9RVrNbhsmQw',
#    'alias': 'little-pie-company-new-york',
#    'name': 'Little Pie Company',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZXbM-XeC2OOI53WqJZ0hhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-pie-company-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 730,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75949, 'longitude': -73.99332},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '424 W 43rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['424 W 43rd St', 'New York, NY 10036']},
#    'phone': '+18778727437',
#    'display_phone': '(877) 872-7437',
#    'distance': 6006.524799250135},
#   {'id': 'V5Vn2O88f8Dbk9UifrZ1jg',
#    'alias': 'choco-love-nuts-new-york-2',
#    'name': 'Choco Love Nuts',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DcKRpWwSna3ka5p3wNhhsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/choco-love-nuts-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'turkish', 'title': 'Turkish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.737319, 'longitude': -73.997499},
#    'transactions': [],
#    'location': {'address1': '104 W14th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['104 W14th St', 'New York, NY 10011']},
#    'phone': '+12127551218',
#    'display_phone': '(212) 755-1218',
#    'distance': 3555.8467297282814},
#   {'id': 'vk7W3_sQwr7eZbRFsXv6rw',
#    'alias': 'taiyaki-nyc-new-york',
#    'name': 'Taiyaki NYC',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/F3Vyd-otu36oE8B8M1XXug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taiyaki-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3036,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71789, 'longitude': -73.9988},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '119 Baxter St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['119 Baxter St', 'New York, NY 10013']},
#    'phone': '+12129662882',
#    'display_phone': '(212) 966-2882',
#    'distance': 1439.7258094631309},
#   {'id': 'Vp73cDdHIRutwalNhjbksA',
#    'alias': 'daily-provisions-new-york-5',
#    'name': 'Daily Provisions',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Q4-fVgcKJjqFQdXboKWlUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daily-provisions-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 109,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78229, 'longitude': -73.97873},
#    'transactions': ['delivery'],
#    'location': {'address1': '375 Amsterdam Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['375 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+16467478612',
#    'display_phone': '(646) 747-8612',
#    'distance': 8640.199173948451},
#   {'id': 'okwe_8q4jBmqECTnpq19VA',
#    'alias': 'crema-jersey-city',
#    'name': 'Crema',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VcoIN8ogCM1eskTzJkFh2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crema-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 91,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7238920057973,
#     'longitude': -74.0703685447746},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '695 Bergen Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07304',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['695 Bergen Ave', 'Jersey City, NJ 07304']},
#    'phone': '+15516895229',
#    'display_phone': '(551) 689-5229',
#    'distance': 6731.901216319342},
#   {'id': '2buX7P8YIqcrHSKtqwm92g',
#    'alias': 'kossars-new-york',
#    'name': "Kossar's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/U9sFtQ8ThrcfSlKCYQcCuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kossars-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 566,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71641, 'longitude': -73.98879},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '367 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['367 Grand St', 'New York, NY 10002']},
#    'phone': '+12124734810',
#    'display_phone': '(212) 473-4810',
#    'distance': 1303.8580395433075},
#   {'id': 'ihm55hLorNuL8NkpDImCFA',
#    'alias': 'alpha-donuts-sunnyside',
#    'name': 'Alpha Donuts',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CKmAhelhcWLBwQmz95sZKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alpha-donuts-sunnyside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 157,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7429102207474,
#     'longitude': -73.9191103766829},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '45-16 Queens Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45-16 Queens Blvd', 'Sunnyside, NY 11104']},
#    'phone': '+17184724725',
#    'display_phone': '(718) 472-4725',
#    'distance': 7582.592410117244},
#   {'id': 'O0RxMO7AYZCMnOis7a08EA',
#    'alias': 'espresso-me-brooklyn-3',
#    'name': 'Espresso Me',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xNXkh83BipO-q4tRL175VQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/espresso-me-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.690892864574636,
#     'longitude': -73.99723224490806},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '88 Atlantic Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['88 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+19175195538',
#    'display_phone': '(917) 519-5538',
#    'distance': 1636.9663891136083},
#   {'id': '9L5D2DHqZNDzIbZuVJWGTQ',
#    'alias': 'duck-donuts-clark',
#    'name': 'Duck Donuts',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-FQ18UV2gDAvgxhokbHBTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duck-donuts-clark?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 194,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.62621259, 'longitude': -74.30676492},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '77 Central Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Clark',
#     'zip_code': '07066',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['77 Central Ave', 'Clark, NJ 07066']},
#    'phone': '+17325408711',
#    'display_phone': '(732) 540-8711',
#    'distance': 27788.631313652226},
#   {'id': 'HmbSkSwJz1JTyLbb5kGEGQ',
#    'alias': 'gombos-heimishe-bakery-brooklyn',
#    'name': "Gombo's Heimishe Bakery",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ywgUCO7V5IsaQL4n-Nfs7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gombos-heimishe-bakery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.667839, 'longitude': -73.942551},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '328 Kingston Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11213',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['328 Kingston Ave', 'Brooklyn, NY 11213']},
#    'phone': '+17187717701',
#    'display_phone': '(718) 771-7701',
#    'distance': 6038.9131745971745},
#   {'id': 'nVIAmfM55P6zoKzaUKdGgw',
#    'alias': 'jacques-torres-chocolate-brooklyn',
#    'name': 'Jacques Torres Chocolate',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-RuZ7qk_3H9u8QETOY-0tQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jacques-torres-chocolate-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 565,
#    'categories': [{'alias': 'chocolate', 'title': 'Chocolatiers & Shops'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7032212028374,
#     'longitude': -73.9914379239426},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '66 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['66 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+17188751269',
#    'display_phone': '(718) 875-1269',
#    'distance': 345.06159656995317},
#   {'id': 'JWLRT0dkdaC7AHtYapWbGw',
#    'alias': 'pasticceria-rocco-new-york',
#    'name': 'Pasticceria Rocco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_OAdfVr9GOg2ihEzcKXeiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pasticceria-rocco-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1051,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73083, 'longitude': -74.00265},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '243 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['243 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12122426031',
#    'display_phone': '(212) 242-6031',
#    'distance': 2909.8673181164463},
#   {'id': 'i6COBjxehtVwsbMIafi0dw',
#    'alias': 'caffe-marchio-new-york-2',
#    'name': 'Caffe Marchio',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/O8k0ZEaoopf-TuXjWtnNYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-marchio-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.744939, 'longitude': -73.984215},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '30 E 30th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30 E 30th St', 'New York, NY 10016']},
#    'phone': '+16467478625',
#    'display_phone': '(646) 747-8625',
#    'distance': 4472.909536884285},
#   {'id': 'Oq1mej1BYfjcdPKkM_5o8g',
#    'alias': 'high-street-on-hudson-new-york',
#    'name': 'High Street On Hudson',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FvKsbK7g79UVFYyyzqNeYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/high-street-on-hudson-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 427,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73888, 'longitude': -74.00574},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '637 Hudson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['637 Hudson St', 'New York, NY 10014']},
#    'phone': '+19173883944',
#    'display_phone': '(917) 388-3944',
#    'distance': 3843.1955727088894},
#   {'id': 'GHqCPN9ubtgP5b_nbrJ0NQ',
#    'alias': 'judickes-bakery-bayonne',
#    'name': "Judicke's Bakery",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/k2RcOzk8Qg9sfMqzHIjK_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/judickes-bakery-bayonne?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 88,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6731512837238,
#     'longitude': -74.1107050119628},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '763 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Bayonne',
#     'zip_code': '07002',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['763 Broadway', 'Bayonne, NJ 07002']},
#    'phone': '+12013394664',
#    'display_phone': '(201) 339-4664',
#    'distance': 10451.400219431076},
#   {'id': 'QnHoxbzAXWlXzr50FDQ0zw',
#    'alias': 'queens-bake-house-astoria',
#    'name': 'Queens Bake House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/W8FGhocrupAncp6mAHOQ2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/queens-bake-house-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 127,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7609, 'longitude': -73.92375},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '33-04 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-04 Broadway', 'Astoria, NY 11106']},
#    'phone': '+13478433994',
#    'display_phone': '(347) 843-3994',
#    'distance': 8569.59241529136},
#   {'id': 'U5hCNNyJmb7f3dmC1HTzSQ',
#    'alias': 'juniors-restaurant-and-bakery-45th-st-new-york',
#    'name': "Junior's Restaurant & Bakery - 45th St",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RwLK04cnu1y4t8xPRY3mwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/juniors-restaurant-and-bakery-45th-st-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4735,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75754564001459,
#     'longitude': -73.98608001118411},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1515 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1515 Broadway', 'New York, NY 10036']},
#    'phone': '+12123022000',
#    'display_phone': '(212) 302-2000',
#    'distance': 5834.523948198199},
#   {'id': 'Wv6jzavopKvQT7RqeXttKA',
#    'alias': 'le-petit-monstre-brooklyn',
#    'name': 'Le Petit Monstre',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NtqFfVROVxVmJN8k-hVcYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-petit-monstre-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'gardening', 'title': 'Nurseries & Gardening'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.696311154904876,
#     'longitude': -73.96770130204715},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '82 Washington Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['82 Washington Ave', 'Brooklyn, NY 11205']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2461.0231986129706},
#   {'id': 'ISh5Jac-G1eSlyVfGzpejA',
#    'alias': 'dough-hut-long-beach',
#    'name': 'Dough Hut',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Q15VccfjcNjWX-piBjm0WQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dough-hut-long-beach?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 193,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.5861009460176,
#     'longitude': -73.6911606788635},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '891 W Beech St',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Beach',
#     'zip_code': '11561',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['891 W Beech St', 'Long Beach, NY 11561']},
#    'phone': '+15164321400',
#    'display_phone': '(516) 432-1400',
#    'distance': 28812.94300650908},
#   {'id': 'YnTXLyVkKFZd_1VdgMfj3w',
#    'alias': 'doughology-atlantic-highlands',
#    'name': 'Doughology',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JBJ0cD7vUTduafkmoSdfhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doughology-atlantic-highlands?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.409871, 'longitude': -74.04015},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '183 First Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Atlantic Highlands',
#     'zip_code': '07716',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['183 First Ave', 'Atlantic Highlands, NJ 07716']},
#    'phone': '+17328723330',
#    'display_phone': '(732) 872-3330',
#    'distance': 33093.669682650776},
#   {'id': 'WifA1usQV51B-ri_zFVGIw',
#    'alias': 'duck-donuts-middletown-2',
#    'name': 'Duck Donuts',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/G2KLnWwM8gUYsErsIqvWkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duck-donuts-middletown-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 221,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.40029778, 'longitude': -74.11712536},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1275 Rte 35',
#     'address2': None,
#     'address3': '',
#     'city': 'Middletown',
#     'zip_code': '07748',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1275 Rte 35', 'Middletown, NJ 07748']},
#    'phone': '+17326713825',
#    'display_phone': '(732) 671-3825',
#    'distance': 35482.27948554918},
#   {'id': '4KHjnRNvrkKHchEznhlnSA',
#    'alias': 'sweet-chick-brooklyn',
#    'name': 'Sweet Chick',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PVVNNTV42TTRzGU6-GwJew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweet-chick-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2085,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.718371, 'longitude': -73.95733},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '164 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['164 Bedford Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13477254793',
#    'display_phone': '(347) 725-4793',
#    'distance': 3431.034977329924},
#   {'id': 'TV40WN9C9MPPId8r1F1bcA',
#    'alias': 'magnolia-bakery-grand-central-terminal-new-york',
#    'name': 'Magnolia Bakery Grand Central Terminal',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cs3LkP2xq9WoNLlZaP_1bw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/magnolia-bakery-grand-central-terminal-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 660,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.752574, 'longitude': -73.97678},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '89 E 42nd St',
#     'address2': '',
#     'address3': 'Grand Central Terminal',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['89 E 42nd St',
#      'Grand Central Terminal',
#      'New York, NY 10017']},
#    'phone': '+12126823588',
#    'display_phone': '(212) 682-3588',
#    'distance': 5444.334592206149},
#   {'id': 'luGkJZkiUNVZxbrCt4g3VA',
#    'alias': 'yayas-bakery-astoria',
#    'name': "Yaya's Bakery",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/w3YtCnQD5oYVYD1MuwTsWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yayas-bakery-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 101,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76749, 'longitude': -73.92129},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '28-46 31st St',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28-46 31st St', 'Astoria, NY 11102']},
#    'phone': '+17189323113',
#    'display_phone': '(718) 932-3113',
#    'distance': 9243.46967805549}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#            Restaurant          Type Price Rating           Address        Lat  \
# 0         Yours Truly  Coffee & Tea    $$      4       8 Spring St  40.721028
# 1   Patisserie Claude      Bakeries     $      4      187 W 4th St  40.732740
# 2    Russ & Daughters        Bagels    $$    4.5  179 E Houston St  40.722589
# 3         Sweet Chick      Southern    $$      4     178 Ludlow St  40.721740
# 4  Mei Lai Wah Bakery      Bakeries     $      4      64 Bayard St  40.715576
#
#          Lng                                                url  \
# 0 -73.994490  https://www.yelp.com/biz/yours-truly-new-york-...
# 1 -74.001821  https://www.yelp.com/biz/patisserie-claude-new...
# 2 -73.988283  https://www.yelp.com/biz/russ-and-daughters-ne...
# 3 -73.987390  https://www.yelp.com/biz/sweet-chick-new-york?...
# 4 -73.997958  https://www.yelp.com/biz/mei-lai-wah-bakery-ne...
#
#                        ID
# 0  MYYWU9rEIRZw43lACKXzTQ
# 1  fvDZVAvv_g4L-WWkbDpCXg
# 2  VrCCr45dhN-RRM107iptdg
# 3  8F81LrdFm6P5kkFpsw0n0w
# 4  MauzeeZM7S-wUk_G98Ybrg

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                            Restaurant                       Type Rating Price  \
# 0               High Street On Hudson             American (New)      4    $$
# 1                    Russ & Daughters                     Bagels    4.5    $$
# 2                       Yaya's Bakery                   Bakeries      4     $
# 3                       Breads Bakery                   Bakeries    4.5    $$
# 4                   Patisserie Claude                   Bakeries      4     $
# 5                       Santos Bakery                   Bakeries      5     $
# 6                  Mei Lai Wah Bakery                   Bakeries      4     $
# 7                  Butterfield Market                   Bakeries
# 8                              Ovenly                   Bakeries      4    $$
# 9                           Orwashers                   Bakeries      4    $$
# 10                        Butter Lane                   Bakeries      4     $
# 11                     Win Son Bakery                   Bakeries      4    $$
# 12                    Big Booty Bread                   Bakeries      4     $
# 13                  Old German Bakery                   Bakeries      4    $$
# 14        Sugar Sweet Sunshine Bakery                   Bakeries      4     $
# 15                        Ess-a-Bagel                   Bakeries      4     $
# 16                       Purple Dough                   Bakeries      4     $
# 17                    Michaeli Bakery                   Bakeries      5    $$
# 18                   Takahachi Bakery                   Bakeries      4    $$
# 19           Black Star Bakery & Cafe                   Bakeries      4     $
# 20                      Levain Bakery                   Bakeries    4.5    $$
# 21                 Guadalupana Bakery                   Bakeries      5     $
# 22           Four & Twenty Blackbirds                   Bakeries      4    $$
# 23                 Caputo's Bake Shop                   Bakeries    4.5     $
# 24             Sullivan Street Bakery                   Bakeries    3.5    $$
# 25               Mille-Feuille Bakery                   Bakeries      4    $$
# 26                   Northside Bakery                   Bakeries      4     $
# 27                              Baked                   Bakeries      4    $$
# 28                           Fabrique                   Bakeries    4.5    $$
# 29                   Donut Connection                   Bakeries      4     $
# ..                                ...                        ...    ...   ...
# 170                    Doughnut Plant                     Donuts      4    $$
# 171                 7th Avenue Donuts                     Donuts    3.5     $
# 172                      Krispy Kreme                     Donuts      4     $
# 173                             Dough                     Donuts
# 174                       Holey Cream                     Donuts
# 175                         BlissBomb                     Donuts
# 176                    Doughnut Plant                     Donuts
# 177           Ugly Donuts & Corn Dogs                     Donuts
# 178                         From Kora                   Filipino
# 179                        Homecoming                   Florists      4    $$
# 180                      Holey Slopes                 Food Tours
# 181     Glazed & Confused Mini Donuts                Food Trucks
# 182                     Pinky's Space                     French
# 183                 Posh Pop Bakeshop                Gluten-Free
# 184        Taiyaki NYC - Williamsburg  Ice Cream & Frozen Yogurt    4.5     $
# 185                       KITH Treats  Ice Cream & Frozen Yogurt      4    $$
# 186  Brooklyn Farmacy & Soda Fountain  Ice Cream & Frozen Yogurt      4    $$
# 187                 Stuffed Ice Cream  Ice Cream & Frozen Yogurt    4.5     $
# 188                        Pane Pasta                    Italian
# 189                 MisFits Nutrition     Juice Bars & Smoothies      5    $$
# 190                         Ursula BK        New Mexican Cuisine
# 191                         Pop Pasta                Pasta Shops
# 192                  Le Petit Monstre       Patisserie/Cake Shop
# 193                           Alfalfa                      Salad
# 194                     Madman Bakery                 Sandwiches
# 195                 Cheeky Sandwiches                 Sandwiches    4.5     $
# 196                     Pies-n-Thighs                   Southern      4    $$
# 197                       Sweet Chick                   Southern      4    $$
# 198                       Sweet Chick                   Southern      4    $$
# 199                  La Snackeria NYC                      Tacos
#
#                 Address        Lat        Lng  \
# 0         637 Hudson St  40.738880 -74.005740
# 1      179 E Houston St  40.722589 -73.988283
# 2         28-46 31st St  40.767490 -73.921290
# 3          18 E 16th St  40.736610 -73.991810
# 4          187 W 4th St  40.732740 -74.001821
# 5         171 Willow St  40.929481 -73.891914
# 6          64 Bayard St  40.715576 -73.997958
# 7      1150 Madison Ave  40.780690 -73.959550
# 8      210 Flatbush Ave  40.681190 -73.975730
# 9         308 E 78th St  40.772191 -73.955050
# 10         123 E 7th St  40.726494 -73.984149
# 11       164 Graham Ave  40.707210 -73.943020
# 12        261 W 23rd St  40.745115 -73.997715
# 13    332 Washington St  40.741151 -74.029964
# 14     126 Rivington St  40.719851 -73.987011
# 15          831 3rd Ave  40.756301 -73.970370
# 16        38-05 69th St  40.746863 -73.896251
# 17     115A Division St  40.714349 -73.992054
# 18         25 Murray St  40.713930 -74.008220
# 19        2-10 50th Ave  40.743349 -73.958035
# 20        167 W 74th St  40.779961 -73.980299
# 21        308 Ellery St  40.699218 -73.939908
# 22          439 3rd Ave  40.672060 -73.990150
# 23         329 Court St  40.682819 -73.995391
# 24          236 9th Ave  40.747410 -74.000590
# 25     552 Laguardia Pl  40.729330 -73.998080
# 26         149 N 8th St  40.718657 -73.957361
# 27     359 Van Brunt St  40.676789 -74.013211
# 28        348 W 14th St  40.740500 -74.004710
# 29         6830 3rd Ave  40.636060 -74.026250
# ..                  ...        ...        ...
# 170    245 Flatbush Ave  40.680653 -73.974743
# 171         324 7th Ave  40.667279 -73.981574
# 172          2 Penn Plz  40.749926 -73.992213
# 173  646 Vanderbilt Ave  40.677030 -73.969300
# 174         522 3rd Ave  40.746340 -73.977900
# 175       335 W 38th St  40.755582 -73.993180
# 176     198 Bedford Ave  40.717480 -73.958314
# 177      84-06 37th Ave  40.749816 -73.882254
# 178       43-46 10th St  40.751209 -73.950045
# 179     107 Franklin St  40.729579 -73.957801
# 180                None  40.668892 -73.981903
# 181                None  40.717480 -74.043850
# 182         70 E 1st St  40.723550 -73.988790
# 183     192 Bleecker St  40.729197 -74.001533
# 184     294 Bedford Ave  40.714369 -73.961554
# 185    337 Lafayette St  40.725980 -73.994420
# 186        513 Henry St  40.683980 -73.999230
# 187         139 1st Ave  40.728050 -73.985380
# 188      58 West 8th St  40.733280 -73.999050
# 189   11514 Queens Blvd  40.716129 -73.834105
# 190     724 Sterling Pl  40.672656 -73.954677
# 191          80 58th St  40.645770 -74.023700
# 192   82 Washington Ave  40.696311 -73.967701
# 193  1110 Washington St  40.750480 -74.027250
# 194    42 University Pl  40.732420 -73.994260
# 195       35 Orchard St  40.715800 -73.991690
# 196        166 S 4th St  40.711191 -73.961424
# 197       178 Ludlow St  40.721740 -73.987390
# 198     164 Bedford Ave  40.718371 -73.957330
# 199        5823 5th Ave  40.640120 -74.015310
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/high-street-on-hudson...  Oq1mej1BYfjcdPKkM_5o8g
# 1    https://www.yelp.com/biz/russ-and-daughters-ne...  VrCCr45dhN-RRM107iptdg
# 2    https://www.yelp.com/biz/yayas-bakery-astoria?...  luGkJZkiUNVZxbrCt4g3VA
# 3    https://www.yelp.com/biz/breads-bakery-new-yor...  mU23NlQfn1R9OhA6WMe_xg
# 4    https://www.yelp.com/biz/patisserie-claude-new...  fvDZVAvv_g4L-WWkbDpCXg
# 5    https://www.yelp.com/biz/santos-bakery-yonkers...  MCgYN8r2pPEpAVQKpGd9Kw
# 6    https://www.yelp.com/biz/mei-lai-wah-bakery-ne...  MauzeeZM7S-wUk_G98Ybrg
# 7
# 8    https://www.yelp.com/biz/ovenly-brooklyn-8?adj...  UeSxAEpzdytnCY6E8zvwRA
# 9    https://www.yelp.com/biz/orwashers-new-york?ad...  aSDGr4NIfm1C6IspWSNaQw
# 10   https://www.yelp.com/biz/butter-lane-new-york?...  qMr-lz0G0vyz2r4mJJQxmA
# 11   https://www.yelp.com/biz/win-son-bakery-brookl...  pYjMy5ixIeeG1YLEt4bGDg
# 12   https://www.yelp.com/biz/big-booty-bread-new-y...  gXz2MvC4637r2rg5YVO2tw
# 13   https://www.yelp.com/biz/old-german-bakery-hob...  6xaL2MvIgzkC67h8yu1-rw
# 14   https://www.yelp.com/biz/sugar-sweet-sunshine-...  qVSOes5JoWc5_umv4nd4Hg
# 15   https://www.yelp.com/biz/ess-a-bagel-new-york?...  c3eMI4_o4dPDDhPV_ibBYQ
# 16   https://www.yelp.com/biz/purple-dough-woodside...  WQUfcgKZZe3siRXkkkwMHg
# 17   https://www.yelp.com/biz/michaeli-bakery-new-y...  AI680OnsLsoCro-0hYF1aQ
# 18   https://www.yelp.com/biz/takahachi-bakery-new-...  GlPJPpKvPR4d8dmcSEYpdA
# 19   https://www.yelp.com/biz/black-star-bakery-and...  gfgbbPRqVqSj_rxlSwhJhg
# 20   https://www.yelp.com/biz/levain-bakery-new-yor...  H4jJ7XB3CetIr1pg56CczQ
# 21   https://www.yelp.com/biz/guadalupana-bakery-br...  C_GM5FUpruYtIvIESpxrog
# 22   https://www.yelp.com/biz/four-and-twenty-black...  Q1ErIlQqHXqtb-13UXXjVQ
# 23   https://www.yelp.com/biz/caputos-bake-shop-bro...  BtPQRHhzavsP6wpZlQh-sA
# 24   https://www.yelp.com/biz/sullivan-street-baker...  yicBRA8X7urJyKn6aF2wzw
# 25   https://www.yelp.com/biz/mille-feuille-bakery-...  cO9E0n9ulzJ6eZ4TKrFx1A
# 26   https://www.yelp.com/biz/northside-bakery-broo...  d1dYHmgFkJ3XuywHUNorYg
# 27   https://www.yelp.com/biz/baked-brooklyn?adjust...  Q_7J5E-cYCQfHNCkCyMdLA
# 28   https://www.yelp.com/biz/fabrique-new-york?adj...  drE9p2p_a9TptqyOFnnJVg
# 29   https://www.yelp.com/biz/donut-connection-broo...  vRpUrmIJSC6EpoOVOaYHvw
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/doughnut-plant-brookl...  IfmcuGIr9kthp9dNjrtlmw
# 171  https://www.yelp.com/biz/7th-avenue-donuts-bro...  5UR2nOXYZAakXAoHHoBqNg
# 172  https://www.yelp.com/biz/krispy-kreme-new-york...  tw9BPuTEyF0TxjTYJcIavg
# 173
# 174
# 175
# 176
# 177
# 178
# 179  https://www.yelp.com/biz/homecoming-brooklyn?a...  gJD6DsPQUYHVVCTHLB_nJw
# 180
# 181
# 182
# 183
# 184  https://www.yelp.com/biz/taiyaki-nyc-williamsb...  Q0JWPHcXTDKNP4c8QNU4pw
# 185  https://www.yelp.com/biz/kith-treats-new-york?...  CXYKLf3DgDB4eQ8rrJdfQA
# 186  https://www.yelp.com/biz/brooklyn-farmacy-and-...  vOJkqLM8Kv4GyQe16UUPjg
# 187  https://www.yelp.com/biz/stuffed-ice-cream-new...  0kH1mGuqIb5rOrvCKGsWtA
# 188
# 189  https://www.yelp.com/biz/misfits-nutrition-for...  3zIjs0nyhAUOGR_D-BaQPg
# 190
# 191
# 192
# 193
# 194
# 195  https://www.yelp.com/biz/cheeky-sandwiches-new...  gHdejB1Mx2P5UjAgZ6BT2w
# 196  https://www.yelp.com/biz/pies-n-thighs-brookly...  j9TdOBSQ1LRw8v3hW5fObQ
# 197  https://www.yelp.com/biz/sweet-chick-new-york?...  8F81LrdFm6P5kkFpsw0n0w
# 198  https://www.yelp.com/biz/sweet-chick-brooklyn?...  4KHjnRNvrkKHchEznhlnSA
# 199
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_Donuts.csv')
