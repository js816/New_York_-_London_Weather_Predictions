# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"polish","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': 'a6SzfZ2F-uELmymusQVMBg',
#    'alias': 'karczma-brooklyn',
#    'name': 'Karczma',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AhFpaHm5pi8BNSbyX901Pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/karczma-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 606,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.729977, 'longitude': -73.955128},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '136 Greenpoint Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136 Greenpoint Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183491744',
#    'display_phone': '(718) 349-1744',
#    'distance': 4282.0841465205085},
#   {'id': 'SvNoFlsMTcBzDv9OirfGZw',
#    'alias': 'little-poland-new-york',
#    'name': 'Little Poland',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-BOCjznTmhemc_ktoZUvEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-poland-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 320,
#    'categories': [{'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73119, 'longitude': -73.9855199},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '200 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12127779728',
#    'display_phone': '(212) 777-9728',
#    'distance': 2955.7616383214972},
#   {'id': 'CVxz9B5ncpMwVK1bk_c1YA',
#    'alias': 'veselka-new-york',
#    'name': 'Veselka',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/f1RdxZKOM07-lytOMAHuSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/veselka-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2703,
#    'categories': [{'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'ukrainian', 'title': 'Ukrainian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729036, 'longitude': -73.98712},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '144 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['144 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12122289682',
#    'display_phone': '(212) 228-9682',
#    'distance': 2691.9732008042556},
#   {'id': 'CGnvt7JZfJDiNGhXsMUHeQ',
#    'alias': 'pierozek-brooklyn',
#    'name': 'Pierozek',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Xcc6ywR7mY4s5P4IQfClqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pierozek-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 89,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.723062, 'longitude': -73.95007},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '592 Manhattan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['592 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17185763866',
#    'display_phone': '(718) 576-3866',
#    'distance': 4204.063510014776},
#   {'id': 'K5j_HFzkS5QAgX7cgIO8Gg',
#    'alias': 'dziupla-brooklyn',
#    'name': 'Dziupla',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TZ3_BFZUFCw8JU7XLRHw6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dziupla-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 228,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7174732, 'longitude': -73.9581543},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '194 Bedford Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['194 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17183886194',
#    'display_phone': '(718) 388-6194',
#    'distance': 3326.715912490438},
#   {'id': 'rA1lLU5n84bCWLVBo3daDA',
#    'alias': 'pyza-brooklyn',
#    'name': 'Pyza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nC1tBO3Ze06gXykw5ZQPgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pyza-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 92,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.724237, 'longitude': -73.94878},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '118 Nassau Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['118 Nassau Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183498829',
#    'display_phone': '(718) 349-8829',
#    'distance': 4365.609068715044},
#   {'id': 'IvaqBqN274GeNxMl8sz3Pg',
#    'alias': 'streecha-new-york',
#    'name': 'Streecha',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VbyG6gfsI8T3hcQZC5IVCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/streecha-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 145,
#    'categories': [{'alias': 'ukrainian', 'title': 'Ukrainian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.728496, 'longitude': -73.9889284},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '33 E 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33 E 7th St', 'New York, NY 10003']},
#    'phone': '+12126777160',
#    'display_phone': '(212) 677-7160',
#    'distance': 2602.739812627713},
#   {'id': '1KxB3LsGd54hHPkaIy5h4A',
#    'alias': 'pierogi-boys-new-york-2',
#    'name': 'Pierogi Boys',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vI3wiWLepoZo4D4LdSYbnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pierogi-boys-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7530915, 'longitude': -73.9836137},
#    'transactions': [],
#    'location': {'address1': '41 W 40th St',
#     'address2': '',
#     'address3': 'Bryant Park',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41 W 40th St', 'Bryant Park', 'New York, NY 10018']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5443.611967007821},
#   {'id': 'eIbKiQuExi12NcGeqMzQAw',
#    'alias': 'babas-pierogies-brooklyn',
#    'name': "Baba's Pierogies",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LpSQQDCxYapJWk065wJjCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/babas-pierogies-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 426,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'slovakian', 'title': 'Slovakian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67687, 'longitude': -73.98633},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '295 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['295 3rd Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17182220777',
#    'display_phone': '(718) 222-0777',
#    'distance': 3253.379374229705},
#   {'id': '_lk_uxURy7g-R7TbrG6hww',
#    'alias': 'ukrainian-east-village-restaurant-new-york-2',
#    'name': 'Ukrainian East Village Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Qu_KTMWye9kJozAriVMkjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ukrainian-east-village-restaurant-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 297,
#    'categories': [{'alias': 'ukrainian', 'title': 'Ukrainian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.728847, 'longitude': -73.987045},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '140 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['140 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12126143283',
#    'display_phone': '(212) 614-3283',
#    'distance': 2673.09675064403},
#   {'id': 'JJluK3s0SKFv02LKZbl_kw',
#    'alias': 'old-traditional-polish-cuisine-new-york',
#    'name': 'Old Traditional Polish Cuisine',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FoS9SWMNkmAzxKNrqnL3yQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/old-traditional-polish-cuisine-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7647053435302,
#     'longitude': -73.9821391124684},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '55TH St Broadway Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10020',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55TH St Broadway Ave', 'New York, NY 10020']},
#    'phone': '+13474698867',
#    'display_phone': '(347) 469-8867',
#    'distance': 6668.5562679728255},
#   {'id': 'qbEuBOWUXO2s-C28xJ0tOQ',
#    'alias': 'koliba-astoria',
#    'name': 'Koliba',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/10FkBU-S9Q_nHr22aEH3_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/koliba-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'czech', 'title': 'Czech'},
#     {'alias': 'slovakian', 'title': 'Slovakian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7743701, 'longitude': -73.9126345},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '3111 23rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3111 23rd Ave', 'Astoria, NY 11105']},
#    'phone': '+17186260430',
#    'display_phone': '(718) 626-0430',
#    'distance': 10308.457895022935},
#   {'id': 'QRbD99HVMffeto7_Hq67CQ',
#    'alias': 'korzo-brooklyn',
#    'name': 'Korzo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bbYZaDUGT7vQmMyvtWHm4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/korzo-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 463,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.66199, 'longitude': -73.99238},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '667 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['667 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17184991199',
#    'display_phone': '(718) 499-1199',
#    'distance': 4830.562014282927},
#   {'id': 'SSX7w6j1ftoY80kM4te85w',
#    'alias': 'stanleys-pierogi-ridgewood',
#    'name': "Stanley's Pierogi",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Y9lwL1noN33Lntw7cyUIdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stanleys-pierogi-ridgewood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'gourmet', 'title': 'Specialty Food'},
#     {'alias': 'intlgrocery', 'title': 'International Grocery'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71334, 'longitude': -73.910362},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '5401 Metropolitan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5401 Metropolitan Ave', 'Ridgewood, NY 11385']},
#    'phone': '+17188213147',
#    'display_phone': '(718) 821-3147',
#    'distance': 7124.324354145143},
#   {'id': '2BRJP7YeiNuWSwyn2TdAoA',
#    'alias': 'kafana-new-york',
#    'name': 'Kafana',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B-nIvpYSddOHsatr70-fkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kafana-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 415,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72432, 'longitude': -73.97851},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '116 Ave C',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['116 Ave C', 'New York, NY 10009']},
#    'phone': '+12123538000',
#    'display_phone': '(212) 353-8000',
#    'distance': 2491.373576619052},
#   {'id': 'btLgjl8CEgW2wvB0ZI-Aqg',
#    'alias': 'mari-vanna-new-york-2',
#    'name': 'Mari Vanna',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/O8lAdW8Fdxpg08t-lk-CWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mari-vanna-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 681,
#    'categories': [{'alias': 'russian', 'title': 'Russian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73888, 'longitude': -73.98851},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '41 E 20th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41 E 20th St', 'New York, NY 10003']},
#    'phone': '+12127771955',
#    'display_phone': '(212) 777-1955',
#    'distance': 3745.880062113082},
#   {'id': 'scJdeBOpASetPOl82NkJFQ',
#    'alias': 'polka-dot-brooklyn',
#    'name': 'Polka Dot',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ScX02KbjvavgxOYiT1KHmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/polka-dot-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7261728595935,
#     'longitude': -73.9519984757585},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '726 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['726 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183492884',
#    'display_phone': '(718) 349-2884',
#    'distance': 4244.86338385448},
#   {'id': 'sHRFCUDuvekILW4ZueTXMg',
#    'alias': 'polish-and-slavic-center-cafeteria-brooklyn',
#    'name': 'Polish & Slavic Center Cafeteria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/y16bhjhaHNOd_5OWMcO_Jg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/polish-and-slavic-center-cafeteria-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'nonprofit', 'title': 'Community Service/Non-Profit'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.731197, 'longitude': -73.953589},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '177 Kent St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['177 Kent St', 'Brooklyn, NY 11222']},
#    'phone': '+17183491033',
#    'display_phone': '(718) 349-1033',
#    'distance': 4474.804943810499},
#   {'id': 'TOaQzGPAIQWQUIXi4CPnbA',
#    'alias': 'radegast-hall-and-biergarten-brooklyn',
#    'name': 'Radegast Hall and Biergarten',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UZRCvkeV1EEsH45807P93Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/radegast-hall-and-biergarten-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1352,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'german', 'title': 'German'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.716641, 'longitude': -73.961498},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '113 N 3rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['113 N 3rd St', 'Brooklyn, NY 11249']},
#    'phone': '+17189633973',
#    'display_phone': '(718) 963-3973',
#    'distance': 3031.61581674316},
#   {'id': 'KY9HMKk4kl6uFz_6fiG1Gg',
#    'alias': 'polonica-restaurant-brooklyn',
#    'name': 'Polonica Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/C8Ef7vAuU-_KJrn8ps5Ecg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/polonica-restaurant-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 195,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.62546, 'longitude': -74.02995},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '8303 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8303 3rd Ave', 'Brooklyn, NY 11209']},
#    'phone': '+17186305805',
#    'display_phone': '(718) 630-5805',
#    'distance': 9387.005953809661},
#   {'id': 'FXBrt0VpeBRengdd4fBOZw',
#    'alias': 'werkstatt-brooklyn-2',
#    'name': 'Werkstatt',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YQWncyNpx6m0P4pa6wIn4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/werkstatt-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 270,
#    'categories': [{'alias': 'austrian', 'title': 'Austrian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.645298, 'longitude': -73.970234},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '509 Coney Island Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11218',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['509 Coney Island Ave', 'Brooklyn, NY 11218']},
#    'phone': '+17182845800',
#    'display_phone': '(718) 284-5800',
#    'distance': 6989.009595803364},
#   {'id': 'zo4mcEfVKaktdj_gnSFhGQ',
#    'alias': 'cafe-katja-new-york',
#    'name': 'Cafe Katja',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aOQeKl7wYPmmSthza1Jj7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-katja-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 799,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'austrian', 'title': 'Austrian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7177673, 'longitude': -73.990589},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '79 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79 Orchard St', 'New York, NY 10002']},
#    'phone': '+12122199545',
#    'display_phone': '(212) 219-9545',
#    'distance': 1400.4825475532655},
#   {'id': 'tG-QM-6Cm2RoLucyj8Kg8g',
#    'alias': 'relax-brooklyn-3',
#    'name': 'Relax',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WcHj0QbVVjIPXGLOpX8NUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/relax-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72473, 'longitude': -73.94721},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '68 Newell St',
#     'address2': 'Ste A',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['68 Newell St', 'Ste A', 'Brooklyn, NY 11222']},
#    'phone': '+17183891665',
#    'display_phone': '(718) 389-1665',
#    'distance': 4510.5919210392085},
#   {'id': '9QWngQn7WeoYaMFKhJ5dFA',
#    'alias': 'terminal-1-staten-island',
#    'name': 'Terminal 1',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/z6Rc1M1pt8Cc9ylrPxFK9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/terminal-1-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.5921058654785,
#     'longitude': -74.067626953125},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '323 Sand Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['323 Sand Ln', 'Staten Island, NY 10305']},
#    'phone': '+17184478376',
#    'display_phone': '(718) 447-8376',
#    'distance': 14043.0804240608},
#   {'id': 'tXZOJhUUknjTRRo9j4ckZg',
#    'alias': 'farida-central-asian-cuisine-and-grill-new-york-2',
#    'name': 'Farida Central Asian Cuisine & Grill',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8PDT9gGzXRW5OyAK6j8chA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/farida-central-asian-cuisine-and-grill-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 391,
#    'categories': [{'alias': 'uzbek', 'title': 'Uzbek'},
#     {'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75568, 'longitude': -73.99441},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '498 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['498 9th Ave', 'New York, NY 10018']},
#    'phone': '+16468632020',
#    'display_phone': '(646) 863-2020',
#    'distance': 5576.668196085386},
#   {'id': 'BqPCyiV0N8dwZ69KOUqO2w',
#    'alias': 'spritzenhaus-33-brooklyn',
#    'name': 'Spritzenhaus 33',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ni9xmpc8qegyd2ErrxooiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spritzenhaus-33-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 549,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7232908725574,
#     'longitude': -73.9527179893456},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '33 Nassau Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33 Nassau Ave', 'Brooklyn, NY 11222']},
#    'phone': '+13479874632',
#    'display_phone': '(347) 987-4632',
#    'distance': 4026.936093172967},
#   {'id': '_NS1hEZ0LPwaTG4R6jxgnw',
#    'alias': 'cafe-sabarsky-new-york-4',
#    'name': 'Cafe Sabarsky',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8dk88iFlkJH7R720j_igQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-sabarsky-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 505,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'austrian', 'title': 'Austrian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78122494966741,
#     'longitude': -73.9602662713214},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1048 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1048 5th Ave', 'New York, NY 10028']},
#    'phone': '+12122880665',
#    'display_phone': '(212) 288-0665',
#    'distance': 8900.614315463365},
#   {'id': 'Q6quwwLiwx_47SRd3tItvA',
#    'alias': 'schallers-stube-sausage-bar-new-york',
#    'name': "Schaller's Stube Sausage Bar",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pKZ6bv7V1Oz8K8q0Yp5AXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/schallers-stube-sausage-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 226,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.777544, 'longitude': -73.951607},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1652 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1652 2nd Ave', 'New York, NY 10028']},
#    'phone': '+16467264355',
#    'display_phone': '(646) 726-4355',
#    'distance': 8786.691519919546},
#   {'id': 'n8sDrOo5oOlhTS7eYkiZpA',
#    'alias': 'christinas-brooklyn',
#    'name': "Christina's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xhhoOIxaaTCn0AjCBfjzww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/christinas-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 154,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7291, 'longitude': -73.95406},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '853 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['853 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183834382',
#    'display_phone': '(718) 383-4382',
#    'distance': 4295.679422083844},
#   {'id': 'PJeuLlvja4ZKv_tHq_pE1A',
#    'alias': 'heidelberg-restaurant-new-york',
#    'name': 'Heidelberg Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BnKnxH81g71-iKadtkOD-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heidelberg-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 707,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77742, 'longitude': -73.95172},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1648 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1648 2nd Ave', 'New York, NY 10028']},
#    'phone': '+12126282332',
#    'display_phone': '(212) 628-2332',
#    'distance': 8772.369147841455},
#   {'id': 'u-1o6fSvTnqLBtqFuLFqNw',
#    'alias': 'budapest-cafe-and-restaurant-new-york',
#    'name': 'Budapest Cafe and Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/N0ERt-8Soh4FJnw2RTSsEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/budapest-cafe-and-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 274,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'hungarian', 'title': 'Hungarian'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.77715, 'longitude': -73.95264},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1631 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1631 2nd Ave', 'New York, NY 10028']},
#    'phone': '+12123271105',
#    'display_phone': '(212) 327-1105',
#    'distance': 8712.039630535364},
#   {'id': 'BxNs9d8rEW3Tls-nVdmIgA',
#    'alias': 'reichenbach-hall-new-york',
#    'name': 'Reichenbach Hall',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/luuVq3iQZWeQW1gMZYHXhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/reichenbach-hall-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 772,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'german', 'title': 'German'},
#     {'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7508, 'longitude': -73.98401},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '5 W 37th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 W 37th St', 'New York, NY 10018']},
#    'phone': '+12123027744',
#    'display_phone': '(212) 302-7744',
#    'distance': 5125.789193272705},
#   {'id': '_L_zrbTjKf3KjWvp8gnb5Q',
#    'alias': 'pierogi-boys-brooklyn-2',
#    'name': 'Pierogi Boys',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7MNJdck-qCL2ORgJRcQDxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pierogi-boys-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 106,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.691077, 'longitude': -73.982954},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '445 Albee Square W',
#     'address2': None,
#     'address3': 'DeKalb Market Hall',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['445 Albee Square W',
#      'DeKalb Market Hall',
#      'Brooklyn, NY 11201']},
#    'phone': '+19293682768',
#    'display_phone': '(929) 368-2768',
#    'distance': 1861.7799863596827},
#   {'id': 'Ck2P4p1VCkmApBSkN-Aj3A',
#    'alias': 'podkarpacie-brooklyn',
#    'name': 'Podkarpacie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ftncTDnunrlUb8l9HYhXpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/podkarpacie-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.63545, 'longitude': -73.99549},
#    'transactions': [],
#    'location': {'address1': '5020 12th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11219',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5020 12th Ave', 'Brooklyn, NY 11219']},
#    'phone': '+17188718894',
#    'display_phone': '(718) 871-8894',
#    'distance': 7784.7859298855055},
#   {'id': 'IC-BoHY-n_THgtJ-COwRHg',
#    'alias': 'jw-real-polish-delicatessen-brooklyn',
#    'name': 'JW Real Polish Delicatessen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gInTsmKJogL-b8h37cJdXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jw-real-polish-delicatessen-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.64396, 'longitude': -73.97701},
#    'transactions': ['delivery'],
#    'location': {'address1': '321 Church Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11218',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['321 Church Ave', 'Brooklyn, NY 11218']},
#    'phone': '+17185596686',
#    'display_phone': '(718) 559-6686',
#    'distance': 6986.234711592618},
#   {'id': 'T6XZnxzx4SYRhaaJ366fHg',
#    'alias': 'heart-of-europe-east-brunswick',
#    'name': 'Heart of Europe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KJTz-w1cGwHdWYDZlAt02Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heart-of-europe-east-brunswick?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.41737802346254,
#     'longitude': -74.37009858575503},
#    'transactions': ['delivery'],
#    'location': {'address1': '1020 State Rte',
#     'address2': None,
#     'address3': '',
#     'city': 'East Brunswick',
#     'zip_code': '08816',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1020 State Rte', 'East Brunswick, NJ 08816']},
#    'phone': '+17329556513',
#    'display_phone': '(732) 955-6513',
#    'distance': 45098.195520485846},
#   {'id': 'THvj8ivYzVh0fAOePxdclA',
#    'alias': 'kaskade-new-york',
#    'name': 'Kaskade',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7qsvisACsEaaUICzIZlrIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaskade-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73023, 'longitude': -73.95518},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '123 Greenpoint Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['123 Greenpoint Ave', 'New York, NY 11222']},
#    'phone': '+13475990039',
#    'display_phone': '(347) 599-0039',
#    'distance': 4301.93423781247},
#   {'id': 'TK1rbgBEPQWyxF4pu973oQ',
#    'alias': 'chriss-restaurant-brooklyn',
#    'name': "Chris's Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TW4PhHyRkFhHTufB_D4fgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chriss-restaurant-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 76,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.60617, 'longitude': -74.00116},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1866 86th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1866 86th St', 'Brooklyn, NY 11214']},
#    'phone': '+13474623755',
#    'display_phone': '(347) 462-3755',
#    'distance': 11060.54691640379},
#   {'id': 'lSJD2Gcf9LjJqpLE7pUlWQ',
#    'alias': 'russian-samovar-restaurant-and-piano-bar-new-york-2',
#    'name': 'Russian Samovar Restaurant and Piano Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QVZx0AYRn8ci4ksTiqubKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/russian-samovar-restaurant-and-piano-bar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 464,
#    'categories': [{'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'pianobars', 'title': 'Piano Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7632, 'longitude': -73.98469},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '256 W 52nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['256 W 52nd St', 'New York, NY 10019']},
#    'phone': '+12127570168',
#    'display_phone': '(212) 757-0168',
#    'distance': 6468.13746056094},
#   {'id': '2KjB4ZptVsDLYFuGN5PoOQ',
#    'alias': 'krajan-polskie-deli-brooklyn',
#    'name': 'Krajan Polskie Deli',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uPzKYd4pWxtMrIHo2n_PdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/krajan-polskie-deli-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72493, 'longitude': -73.94671},
#    'transactions': [],
#    'location': {'address1': '160 Nassau Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['160 Nassau Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183894289',
#    'display_phone': '(718) 389-4289',
#    'distance': 4559.442453061208},
#   {'id': 'yk-urU0Zz41LiTS2ZBZf1Q',
#    'alias': 'romanian-garden-sunnyside-4',
#    'name': 'Romanian Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/n08S7WGxiR4mYbYiAYRyGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/romanian-garden-sunnyside-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 136,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7449088452058,
#     'longitude': -73.921469294812},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '43-06 43rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43-06 43rd Ave', 'Sunnyside, NY 11104']},
#    'phone': '+17187867894',
#    'display_phone': '(718) 786-7894',
#    'distance': 7544.286357609566},
#   {'id': 'wJ9VnRlrJJP5QnVohBDjoA',
#    'alias': 'russian-vodka-room-new-york',
#    'name': 'Russian Vodka Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PKlderfFSqWRqDgPlgoHbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/russian-vodka-room-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 549,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'jazzandblues', 'title': 'Jazz & Blues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76349, 'longitude': -73.9848},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '265 W 52nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['265 W 52nd St', 'New York, NY 10019']},
#    'phone': '+12123075835',
#    'display_phone': '(212) 307-5835',
#    'distance': 6503.7308715178715},
#   {'id': 'XA7phnS0fBfLR8xdsngiUQ',
#    'alias': 'gottscheer-hall-ridgewood',
#    'name': 'Gottscheer Hall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gOLNWBRYfJfwA_m5_WhgZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gottscheer-hall-ridgewood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'catering', 'title': 'Caterers'},
#     {'alias': 'german', 'title': 'German'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.706891, 'longitude': -73.905479},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '657 Fairview Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['657 Fairview Ave', 'Ridgewood, NY 11385']},
#    'phone': '+17183663030',
#    'display_phone': '(718) 366-3030',
#    'distance': 7493.100665139834},
#   {'id': 'hLm1vXfAKuSOgAtBA-vO7w',
#    'alias': 'çka-ka-qëllu-bronx',
#    'name': 'ÇKA KA QËLLU',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8C1r1BYao-mzvGM0qaersg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%C3%A7ka-ka-q%C3%ABllu-bronx?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 96,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.8538017786913,
#     'longitude': -73.8882422081079},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2321 Hughes Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Bronx',
#     'zip_code': '10458',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2321 Hughes Ave', 'Bronx, NY 10458']},
#    'phone': '+17189336194',
#    'display_phone': '(718) 933-6194',
#    'distance': 18758.207561251835},
#   {'id': 'yKOTFgZmTFeas8Pvt077vA',
#    'alias': 'the-russian-tea-room-new-york',
#    'name': 'The Russian Tea Room',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VUds2Rxn6py9LlWfcgktFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-russian-tea-room-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1031,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.764958, 'longitude': -73.9794337},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '150 W 57th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 W 57th St', 'New York, NY 10019']},
#    'phone': '+12125817100',
#    'display_phone': '(212) 581-7100',
#    'distance': 6734.946115153841},
#   {'id': '-RPe5PyA3Za3_iv7strJ_g',
#    'alias': 'bakestone-bakery-brooklyn-2',
#    'name': 'Bakestone Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SAMCiW_fgM0uSxc-kRrYyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bakestone-bakery-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.725303, 'longitude': -73.945541},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '190 Nassau Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['190 Nassau Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183497775',
#    'display_phone': '(718) 349-7775',
#    'distance': 4667.421365962235},
#   {'id': 'HWbZPqMLaUZn6yoRRylO6w',
#    'alias': 'luk-and-bart-homemade-food-staten-island',
#    'name': 'Luk & Bart Homemade Food',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GZepC4JQrNOxPnRAkvxdCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luk-and-bart-homemade-food-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.636708, 'longitude': -74.158927},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2960 Richmond Ter',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10303',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2960 Richmond Ter', 'Staten Island, NY 10303']},
#    'phone': '+17185106196',
#    'display_phone': '(718) 510-6196',
#    'distance': 15849.42961454983},
#   {'id': '19o6iblcJvz2hdPouYhXgg',
#    'alias': 'zum-stammtisch-glendale',
#    'name': 'Zum Stammtisch',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OAI9b7m-P32jNr_hsCE9yQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zum-stammtisch-glendale?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 484,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7017618, 'longitude': -73.8813408},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '6946 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Glendale',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6946 Myrtle Ave', 'Glendale, NY 11385']},
#    'phone': '+17183863014',
#    'display_phone': '(718) 386-3014',
#    'distance': 9550.09692986248},
#   {'id': 'osY94UfXtrynDL2nMs_bdw',
#    'alias': 'max-bratwurst-und-bier-astoria',
#    'name': 'Max Bratwurst und Bier',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WeahMxEWu0rH3UKD2FTDKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/max-bratwurst-und-bier-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 404,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7612453874006,
#     'longitude': -73.9094611979998},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '4702 30th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4702 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17187771635',
#    'display_phone': '(718) 777-1635',
#    'distance': 9465.188938384523},
#   {'id': 'Npf8xdD81WnSS7KDWxjGYA',
#    'alias': 'skovorodka-brooklyn',
#    'name': 'Skovorodka',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7WhWhcPInA3NxZyzy5QpTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/skovorodka-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 219,
#    'categories': [{'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'ukrainian', 'title': 'Ukrainian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.578002, 'longitude': -73.961013},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '615 Brighton Beach Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11235',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['615 Brighton Beach Ave', 'Brooklyn, NY 11235']},
#    'phone': '+17186153096',
#    'display_phone': '(718) 615-3096',
#    'distance': 14446.508891166537}],
#  'total': 115,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#       Restaurant    Type Price Rating             Address        Lat  \
# 0        Karczma  Polish    $$    4.5  136 Greenpoint Ave  40.729977
# 1  Little Poland  Diners    $$      4         200 2nd Ave  40.731190
# 2        Veselka  Diners    $$      4         144 2nd Ave  40.729036
# 3       Pierozek  Polish    $$      5   592 Manhattan Ave  40.723062
# 4        Dziupla  Polish    $$      4     194 Bedford Ave  40.717473
#
#          Lng                                                url  \
# 0 -73.955128  https://www.yelp.com/biz/karczma-brooklyn?adju...
# 1 -73.985520  https://www.yelp.com/biz/little-poland-new-yor...
# 2 -73.987120  https://www.yelp.com/biz/veselka-new-york?adju...
# 3 -73.950070  https://www.yelp.com/biz/pierozek-brooklyn?adj...
# 4 -73.958154  https://www.yelp.com/biz/dziupla-brooklyn?adju...
#
#                        ID
# 0  a6SzfZ2F-uELmymusQVMBg
# 1  SvNoFlsMTcBzDv9OirfGZw
# 2  CVxz9B5ncpMwVK1bk_c1YA
# 3  CGnvt7JZfJDiNGhXsMUHeQ
# 4  K5j_HFzkS5QAgX7cgIO8Gg

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"polish","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': 'SYTBg4SzYuZxrxK3YDU2xg',
#    'alias': 'cheburechnaya-rego-park',
#    'name': 'Cheburechnaya',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uKaseeZA0i_j80QG9YRwew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cheburechnaya-rego-park?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 268,
#    'categories': [{'alias': 'kosher', 'title': 'Kosher'},
#     {'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'uzbek', 'title': 'Uzbek'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7275992341691,
#     'longitude': -73.8640816882253},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '9209 63rd Dr',
#     'address2': 'Ste A',
#     'address3': '',
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9209 63rd Dr', 'Ste A', 'Rego Park, NY 11374']},
#    'phone': '+17188979080',
#    'display_phone': '(718) 897-9080',
#    'distance': 11247.280969990064},
#   {'id': '4AzT2sb1Yu8abfQf5nWrvw',
#    'alias': 'r-and-b-polish-american-deli-brooklyn',
#    'name': 'R&B Polish American Deli',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ivztAtHPfR91jWSDY7fO7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/r-and-b-polish-american-deli-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6205458819837,
#     'longitude': -74.0249262571025},
#    'transactions': [],
#    'location': {'address1': '544 86th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['544 86th St', 'Brooklyn, NY 11209']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9787.535946592436},
#   {'id': 'DJ6uRwmvcIvIqDuZa_0ZzQ',
#    'alias': 'pierogi-cafe-waldwick-2',
#    'name': 'Pierogi Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wkD2UA4FoHEA5rCXSvR8FQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pierogi-cafe-waldwick-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.0107317, 'longitude': -74.1183117},
#    'transactions': ['delivery'],
#    'location': {'address1': '18 E Prospect St',
#     'address2': '',
#     'address3': None,
#     'city': 'Waldwick',
#     'zip_code': '07463',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['18 E Prospect St', 'Waldwick, NJ 07463']},
#    'phone': '+12012904166',
#    'display_phone': '(201) 290-4166',
#    'distance': 35509.799062593236},
#   {'id': 'CPtao9WHPnVJGUS0H4Txww',
#    'alias': 'taam-tov-new-york',
#    'name': 'Taam Tov',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/s6Sr9t6mx0yZp156up75WA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taam-tov-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 134,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'kosher', 'title': 'Kosher'},
#     {'alias': 'uzbek', 'title': 'Uzbek'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.757703, 'longitude': -73.980522},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '41 W 47th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41 W 47th St', 'New York, NY 10036']},
#    'phone': '+12127688001',
#    'display_phone': '(212) 768-8001',
#    'distance': 5925.558371992039},
#   {'id': 'yjir1wtwTAN_0g5Lg1mXPg',
#    'alias': 'zabka-deli-queens',
#    'name': 'Zabka Deli',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZZDk11ywgw0LZzhrKeCcJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zabka-deli-queens?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7073850619833,
#     'longitude': -73.8972490881706},
#    'transactions': [],
#    'location': {'address1': '66-51 Fresh Pond Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Queens',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['66-51 Fresh Pond Rd', 'Queens, NY 11385']},
#    'phone': '+17183663911',
#    'display_phone': '(718) 366-3911',
#    'distance': 8182.933919810482},
#   {'id': 'geSr15H5wurRsaeIreKmRA',
#    'alias': 'varenichnaya-brooklyn',
#    'name': 'Varenichnaya',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4BRW1S22BsgDKjpKq0egQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/varenichnaya-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 96,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'russian', 'title': 'Russian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.57654, 'longitude': -73.96516},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3086 Brighton 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11235',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3086 Brighton 2nd St', 'Brooklyn, NY 11235']},
#    'phone': '+17183329797',
#    'display_phone': '(718) 332-9797',
#    'distance': 14555.35369044821},
#   {'id': 'qVGhJLtH04v4qFQ-t-8fKw',
#    'alias': 'sawa-provision-bayonne-2',
#    'name': 'Sawa Provision',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Tf29bZ7TOEFAXurBuPVklQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sawa-provision-bayonne-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.66728, 'longitude': -74.11829},
#    'transactions': [],
#    'location': {'address1': '588 Avenue C',
#     'address2': '',
#     'address3': None,
#     'city': 'Bayonne',
#     'zip_code': '07002',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['588 Avenue C', 'Bayonne, NJ 07002']},
#    'phone': '+12014373884',
#    'display_phone': '(201) 437-3884',
#    'distance': 11283.584067721062},
#   {'id': 'Fm1mE5Hf2k-yuzmFz98ufw',
#    'alias': 'manor-oktoberfest-forest-hills-46',
#    'name': 'Manor Oktoberfest',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HA4UyTO0j9w2WHuTTdXVrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/manor-oktoberfest-forest-hills-46?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 284,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7174275, 'longitude': -73.8569518},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '73-11 Yellowstone Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['73-11 Yellowstone Blvd', 'Forest Hills, NY 11375']},
#    'phone': '+17185442400',
#    'display_phone': '(718) 544-2400',
#    'distance': 11658.718614399377},
#   {'id': 'IxZzAD2r6hYu7fGH_EDovA',
#    'alias': 'polish-specialties-staten-island',
#    'name': 'Polish Specialties',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BDgWXsq3rarJrOzH2KR_qA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/polish-specialties-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.60054, 'longitude': -74.16262},
#    'transactions': ['delivery'],
#    'location': {'address1': '1949 Richmond Ave',
#     'address2': 'Store  5',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10314',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1949 Richmond Ave',
#      'Store  5',
#      'Staten Island, NY 10314']},
#    'phone': '+17184774474',
#    'display_phone': '(718) 477-4474',
#    'distance': 18364.25176029065},
#   {'id': '8jpRs5cfL8_h3uIUUdgMRg',
#    'alias': 'hetman-polish-deli-and-foods-flushing',
#    'name': 'Hetman Polish Deli and Foods',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T1z_IYHuHht4_rpN1gU0GA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hetman-polish-deli-and-foods-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7057626650355,
#     'longitude': -73.9025192466696},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '6665 Forest Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6665 Forest Ave', 'Flushing, NY 11385']},
#    'phone': '+13478811682',
#    'display_phone': '(347) 881-1682',
#    'distance': 7736.029752138834},
#   {'id': 'aTiVlP1PxzgrcRXFy7WnDQ',
#    'alias': 'tatra-haus-wallington',
#    'name': 'Tatra Haus',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cMKUqfruvxNIBRMbHJdv_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tatra-haus-wallington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.85513, 'longitude': -74.11315},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '115 Main Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Wallington',
#     'zip_code': '07057',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['115 Main Ave', 'Wallington, NJ 07057']},
#    'phone': '+12013932400',
#    'display_phone': '(201) 393-2400',
#    'distance': 19417.078435691914},
#   {'id': 'bUD3Y-uo8RSBlHMR8tN3wQ',
#    'alias': 'alex-and-terrys-deli-bayonne',
#    'name': "Alex & Terry's Deli",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EBW24w87qja755qmIXDarg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alex-and-terrys-deli-bayonne?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67437, 'longitude': -74.1091299},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '798 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Bayonne',
#     'zip_code': '07002',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['798 Broadway', 'Bayonne, NJ 07002']},
#    'phone': '+12014363525',
#    'display_phone': '(201) 436-3525',
#    'distance': 10278.886485765523},
#   {'id': 'StN5iogEjup2MWAzwaGDig',
#    'alias': 'royal-warsaw-restaurant-elmwood-park',
#    'name': 'Royal Warsaw Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LJyfS5gdpkjk4EsTE6M4wg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/royal-warsaw-restaurant-elmwood-park?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 248,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.89127, 'longitude': -74.12705},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '871 River Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmwood Park',
#     'zip_code': '07407',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['871 River Dr', 'Elmwood Park, NJ 07407']},
#    'phone': '+12017949277',
#    'display_phone': '(201) 794-9277',
#    'distance': 23497.043326163577},
#   {'id': '_OzfOh1aJM4PFCG-qpVknQ',
#    'alias': 'omonia-cafe-astoria-astoria',
#    'name': 'Omonia Cafe - Astoria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wfLsR5V-v2OMMYkelhW0sQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/omonia-cafe-astoria-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 663,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7611121, 'longitude': -73.9240205},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '32-20 Broadway',
#     'address2': None,
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32-20 Broadway', 'Astoria, NY 11106']},
#    'phone': '+17182746650',
#    'display_phone': '(718) 274-6650',
#    'distance': 8565.863990585687},
#   {'id': 'ZWfHsuqlxxyWEMBGS1dENQ',
#    'alias': 'syrena-polish-deli-linden',
#    'name': 'Syrena Polish Deli',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ui9-nKR-kAYg62wMa-enVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/syrena-polish-deli-linden?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.626555, 'longitude': -74.272012},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1117 W Saint Georges Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Linden',
#     'zip_code': '07036',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1117 W Saint Georges Ave', 'Linden, NJ 07036']},
#    'phone': '+19084860677',
#    'display_phone': '(908) 486-0677',
#    'distance': 25012.485406410367},
#   {'id': 'cO7x8sT6qq9TkVeqU3VXSw',
#    'alias': 'morschers-pork-store-ridgewood',
#    'name': "Morscher's Pork Store",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/df_uOA1hP5BIf38fBKjVWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/morschers-pork-store-ridgewood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'},
#     {'alias': 'butcher', 'title': 'Butcher'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7020797729492,
#     'longitude': -73.9014205932617},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '5844 Catalpa Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5844 Catalpa Ave', 'Ridgewood, NY 11385']},
#    'phone': '+17188211040',
#    'display_phone': '(718) 821-1040',
#    'distance': 7834.351109990516},
#   {'id': 'qj4gZjx1ujn3BbxcANVyZg',
#    'alias': 'dulcinea-churros-brooklyn-2',
#    'name': 'Dulcinea Churros',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/We6eqbcCi7dOL6INyDhP6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dulcinea-churros-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 62,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.690810819864,
#     'longitude': -73.9830908055573},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '445 Albee Square W Brooklyn Ny 11201',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['445 Albee Square W Brooklyn Ny 11201',
#      'Brooklyn, NY 11201']},
#    'phone': '+17186224050',
#    'display_phone': '(718) 622-4050',
#    'distance': 1881.4251671543386},
#   {'id': 'P5X8K61nDAlo8QrgCn-agQ',
#    'alias': 'zeppelin-hall-jersey-city',
#    'name': 'Zeppelin Hall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VHbV8hfLEumrAjPkDlF-Ww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zeppelin-hall-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 874,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.715132087537, 'longitude': -74.04667189924},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '88 Liberty View Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['88 Liberty View Dr', 'Jersey City, NJ 07302']},
#    'phone': '+12017218888',
#    'display_phone': '(201) 721-8888',
#    'distance': 4544.380217519045},
#   {'id': 'Sz2_SDk8ttk1FT6UHqUtrA',
#    'alias': 'abigails-restaurant-linden-3',
#    'name': 'Abigails Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RVyJQqe4MYjjqG8HZpHtfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/abigails-restaurant-linden-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 296,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.625845, 'longitude': -74.25772247323548},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '804 W Elizabeth Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Linden',
#     'zip_code': '07036',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['804 W Elizabeth Ave', 'Linden, NJ 07036']},
#    'phone': '+19085230777',
#    'display_phone': '(908) 523-0777',
#    'distance': 23916.76265987107},
#   {'id': '09n8pdSWk1NrrprhLYUtUQ',
#    'alias': 'wheelie-good-pierogi-rahway',
#    'name': 'Wheelie Good Pierogi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zgCd9cbxNCWcogvsgL1mpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wheelie-good-pierogi-rahway?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.61014, 'longitude': -74.27711},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1580 Irving St',
#     'address2': '',
#     'address3': None,
#     'city': 'Rahway',
#     'zip_code': '07065',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1580 Irving St', 'Rahway, NJ 07065']},
#    'phone': '+17325357750',
#    'display_phone': '(732) 535-7750',
#    'distance': 26096.555499254493},
#   {'id': 'kuUQ4vHtVDhmcwMO_zmW4A',
#    'alias': 'chefskis-polish-home-made-cooking-wallington',
#    'name': "Chefski's Polish Home Made Cooking",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1prKGoj7LKKhTC0kNWaTAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chefskis-polish-home-made-cooking-wallington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'creperies', 'title': 'Creperies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8593740378521,
#     'longitude': -74.104877887882},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '360 Main Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Wallington',
#     'zip_code': '07057',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['360 Main Ave', 'Wallington, NJ 07057']},
#    'phone': '+19734714193',
#    'display_phone': '(973) 471-4193',
#    'distance': 19478.629243106046},
#   {'id': 'PQFhHgws5BEbwjsTFJ4okA',
#    'alias': 'pierogi-palace-rahway',
#    'name': 'Pierogi Palace',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CFqZjMSkBkmrotB2RboUag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pierogi-palace-rahway?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.615951, 'longitude': -74.283233},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '713 W Grand Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Rahway',
#     'zip_code': '07065',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['713 W Grand Ave', 'Rahway, NJ 07065']},
#    'phone': '+17324998411',
#    'display_phone': '(732) 499-8411',
#    'distance': 26332.438528664938},
#   {'id': 'AO0N9_tCA7_bTf_JF5_XCQ',
#    'alias': 'polska-chata-sayreville',
#    'name': 'Polska Chata',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0Geek05XNChcZIMejWWjjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/polska-chata-sayreville?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.47016333, 'longitude': -74.303025},
#    'transactions': ['delivery'],
#    'location': {'address1': '3294 Washington Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Sayreville',
#     'zip_code': '08859',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['3294 Washington Rd', 'Sayreville, NJ 08859']},
#    'phone': '+17327212352',
#    'display_phone': '(732) 721-2352',
#    'distance': 36935.195469167666},
#   {'id': 'tv_bPt2qM9Z71oj5VweoVw',
#    'alias': 'vanka-cafe-brooklyn',
#    'name': 'Vanka Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bIJ7FN_vjHTu3HcWc86F5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vanka-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.5909668, 'longitude': -73.9401486},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '3810 Nostrand Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11235',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3810 Nostrand Ave', 'Brooklyn, NY 11235']},
#    'phone': '+13477024023',
#    'display_phone': '(347) 702-4023',
#    'distance': 13524.166747907415},
#   {'id': '25W4D5DYfU4n0vFkM1erWQ',
#    'alias': 'psc-cafeteria-greenpoint',
#    'name': 'psc cafeteria',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/psc-cafeteria-greenpoint?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.73122, 'longitude': -73.953323},
#    'transactions': [],
#    'location': {'address1': '187 Kent St',
#     'address2': '',
#     'address3': '',
#     'city': 'Greenpoint',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['187 Kent St', 'Greenpoint, NY 11222']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4486.9821096798405},
#   {'id': 'MHwPnF03-uIuYnVMNb_yBQ',
#    'alias': 'as-warehouse-brooklyn',
#    'name': 'AS Warehouse',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5osgqgbHAraYwvOrgRNLZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/as-warehouse-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.731656, 'longitude': -73.95153},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '276 McGuinness Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['276 McGuinness Blvd', 'Brooklyn, NY 11222']},
#    'phone': '+13474575923',
#    'display_phone': '(347) 457-5923',
#    'distance': 4634.984841989957},
#   {'id': 'jNXFOOaOrQMDcLtJGo5MJA',
#    'alias': 'belka-european-delicatessen-brooklyn-7',
#    'name': 'Belka European Delicatessen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/b-n9TFA-KhGpv9FiXI6FGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/belka-european-delicatessen-brooklyn-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'importedfood', 'title': 'Imported Food'},
#     {'alias': 'russian', 'title': 'Russian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.605794, 'longitude': -73.996603},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '8319 20th Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8319 20th Ave', 'Brooklyn, NY 11214']},
#    'phone': '+17183330535',
#    'display_phone': '(718) 333-0535',
#    'distance': 11079.454380059864},
#   {'id': 'Juc1aLN4W-nlJdpnZGblEw',
#    'alias': 'amsterdam-alley-bar-and-lounge-linden',
#    'name': 'Amsterdam Alley Bar & Lounge',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zc-dlJbZTsgrpytGbeeFlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amsterdam-alley-bar-and-lounge-linden?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6309405, 'longitude': -74.2535903},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '9 West Price St',
#     'address2': '',
#     'address3': '',
#     'city': 'Linden',
#     'zip_code': '07036',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['9 West Price St', 'Linden, NJ 07036']},
#    'phone': '+19089254166',
#    'display_phone': '(908) 925-4166',
#    'distance': 23393.522985067313},
#   {'id': 'tuIH3ALOciWJRRmVzcOoJQ',
#    'alias': 'polski-smak-butler',
#    'name': 'Polski Smak',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/piPl7SzC8u1ryGMZkR9K1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/polski-smak-butler?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 94,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.9910810589688,
#     'longitude': -74.3459410929136},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1295 Route 23 S',
#     'address2': None,
#     'address3': None,
#     'city': 'Butler',
#     'zip_code': '07405',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1295 Route 23 S', 'Butler, NJ 07405']},
#    'phone': '+19734927625',
#    'display_phone': '(973) 492-7625',
#    'distance': 43400.82351749719},
#   {'id': 'u5pK1oszIUvrnDRLKwifqA',
#    'alias': 'pilsener-haus-and-biergarten-hoboken',
#    'name': 'Pilsener Haus & Biergarten',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5T0SiDIQ5yhS1K6HB9qBnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pilsener-haus-and-biergarten-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 810,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7552077, 'longitude': -74.0314563558197},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1422 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1422 Grand St', 'Hoboken, NJ 07030']},
#    'phone': '+12016835465',
#    'display_phone': '(201) 683-5465',
#    'distance': 6357.997848641078},
#   {'id': 'Z0TxOufkowjm-lNX5lNCjg',
#    'alias': 'krakus-restaurant-wallington',
#    'name': 'Krakus Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JX7J8T1C1-Luipqvy2y8Gg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/krakus-restaurant-wallington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.85475, 'longitude': -74.10867},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '208 Main Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Wallington',
#     'zip_code': '07057',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['208 Main Ave', 'Wallington, NJ 07057']},
#    'phone': '+19737791922',
#    'display_phone': '(973) 779-1922',
#    'distance': 19190.880179833897},
#   {'id': 'VZBuV56yUnyf8ZKyvTnfDQ',
#    'alias': 'ryans-bbq-lyndhurst',
#    'name': "Ryan's BBQ",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/v9ZlWVjCXTTyH5G2UnJ9TA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ryans-bbq-lyndhurst?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 79,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.81539, 'longitude': -74.12566},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '239 Stuyvesant Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Lyndhurst',
#     'zip_code': '07071',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['239 Stuyvesant Ave', 'Lyndhurst, NJ 07071']},
#    'phone': '+12019394400',
#    'display_phone': '(201) 939-4400',
#    'distance': 16488.66528288335},
#   {'id': '03b_GOyFKAtc4eebtNf2iQ',
#    'alias': 'plattduetsche-park-restaurant-franklin-square',
#    'name': 'Plattduetsche Park Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VTNS0gsGNcgDW1mNA7MWcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/plattduetsche-park-restaurant-franklin-square?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 332,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7082, 'longitude': -73.68282},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1132 Hempstead Tpke',
#     'address2': '',
#     'address3': '',
#     'city': 'Franklin Square',
#     'zip_code': '11010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1132 Hempstead Tpke', 'Franklin Square, NY 11010']},
#    'phone': '+15163543131',
#    'display_phone': '(516) 354-3131',
#    'distance': 26256.46233917509},
#   {'id': '0qaqUSscW-iYRY2oXO7e6g',
#    'alias': 'comfi-old-bridge-township',
#    'name': 'Comfi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IeBdw4ATCyRt58sh96yB6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/comfi-old-bridge-township?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 676,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.4038638, 'longitude': -74.3218678},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2638 Hwy 516',
#     'address2': '',
#     'address3': '',
#     'city': 'Old Bridge Township',
#     'zip_code': '08857',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['2638 Hwy 516', 'Old Bridge Township, NJ 08857']},
#    'phone': '+17325885385',
#    'display_phone': '(732) 588-5385',
#    'distance': 43450.9885574635},
#   {'id': 'Eu0yHABc9MeJJMUx700a5w',
#    'alias': 'umas-rockaway-beach',
#    'name': "Uma's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Qrarr42zpDYF8TuqwjpyAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/umas-rockaway-beach?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 217,
#    'categories': [{'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'uzbek', 'title': 'Uzbek'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.5861159, 'longitude': -73.815624},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '92-07 Rockaway Beach Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Rockaway Beach',
#     'zip_code': '11693',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['92-07 Rockaway Beach Blvd',
#      'Rockaway Beach, NY 11693']},
#    'phone': '+17183189100',
#    'display_phone': '(718) 318-9100',
#    'distance': 20082.091723361023},
#   {'id': '5RCrpBnI_3UdabG1lieknA',
#    'alias': 'tandoori-food-and-bakery-rego-park',
#    'name': 'Tandoori Food & Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/emp0N3ex8fT4MEmeCmE15w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tandoori-food-and-bakery-rego-park?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 66,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'uzbek', 'title': 'Uzbek'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7325468388103,
#     'longitude': -73.8561887462805},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '9904 63rd Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9904 63rd Rd', 'Rego Park, NY 11374']},
#    'phone': '+17188971071',
#    'display_phone': '(718) 897-1071',
#    'distance': 12022.78375161657},
#   {'id': 'BLFJ4-JDT8XNmL_sIR1OJg',
#    'alias': 'polonia-bakery-passaic',
#    'name': 'Polonia Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tuRepkOA3CbDnx5ISPZokA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/polonia-bakery-passaic?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.866672, 'longitude': -74.122622},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '204 Monroe St',
#     'address2': '',
#     'address3': '',
#     'city': 'Passaic',
#     'zip_code': '07055',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['204 Monroe St', 'Passaic, NJ 07055']},
#    'phone': '+19734713485',
#    'display_phone': '(973) 471-3485',
#    'distance': 20931.55804435246},
#   {'id': 'RuudrmiLICPhDkllOqhvkg',
#    'alias': 'rosa-ly-pierogi-fairfield',
#    'name': 'Rosa-Ly Pierogi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Supkf4y-GpPg7Wl77u2L9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rosa-ly-pierogi-fairfield?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 56,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.868099, 'longitude': -74.312545},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '69 Rt 46 W',
#     'address2': None,
#     'address3': '',
#     'city': 'Fairfield',
#     'zip_code': '07004',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['69 Rt 46 W', 'Fairfield, NJ 07004']},
#    'phone': '+19732270505',
#    'display_phone': '(973) 227-0505',
#    'distance': 32323.010839152612},
#   {'id': 'lKDaUFL491hetaqMOOUZIQ',
#    'alias': 'polish-kitchen-and-deli-sea-cliff',
#    'name': 'Polish Kitchen and Deli',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ENLV-wBBg93n0WYhpTNS5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/polish-kitchen-and-deli-sea-cliff?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.837689, 'longitude': -73.63304},
#    'transactions': ['delivery'],
#    'location': {'address1': '602 Glen Cove Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Sea Cliff',
#     'zip_code': '11579',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['602 Glen Cove Ave', 'Sea Cliff, NY 11579']},
#    'phone': '+15162771957',
#    'display_phone': '(516) 277-1957',
#    'distance': 33788.67848395051},
#   {'id': 'kQnCxOZREPxogXF5k6ga9A',
#    'alias': 'homemade-pirogi-clifton',
#    'name': 'Homemade Pirogi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XGjHH44gr4snlD5LElFJgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/homemade-pirogi-clifton?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.879287, 'longitude': -74.144187},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1295 Main Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Clifton',
#     'zip_code': '07011',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1295 Main Ave', 'Clifton, NJ 07011']},
#    'phone': '+19733400340',
#    'display_phone': '(973) 340-0340',
#    'distance': 23077.830362544075},
#   {'id': '6Xi12JDapuQ1CFr2NHjHfQ',
#    'alias': 'wisla-deli-wallington',
#    'name': 'Wisla Deli',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Yj_kXelSKweyCcYJa399jw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wisla-deli-wallington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'gourmet', 'title': 'Specialty Food'},
#     {'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.8534552457, 'longitude': -74.11081233},
#    'transactions': [],
#    'location': {'address1': '109 Locust Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Wallington',
#     'zip_code': '07057',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['109 Locust Ave', 'Wallington, NJ 07057']},
#    'phone': '+19733650055',
#    'display_phone': '(973) 365-0055',
#    'distance': 19160.348936892493},
#   {'id': '2uHca0X0oqy4J1P0CdHZaQ',
#    'alias': 'polish-delicious-staten-island',
#    'name': 'Polish Delicious',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0Rn8CBmMFR3ZUZm71pmBCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/polish-delicious-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.591662, 'longitude': -74.067399},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '337 Sand Ln',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['337 Sand Ln', 'Staten Island, NY 10305']},
#    'phone': '+17185240101',
#    'display_phone': '(718) 524-0101',
#    'distance': 14078.49763246741},
#   {'id': '0iCISI2oP9bkS54hy68Xsw',
#    'alias': 'rolfs-bar-and-restaurant-new-york',
#    'name': "Rolf's Bar & Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6hzjg8gf2B7Ob4A1_1nahw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rolfs-bar-and-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 985,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.73803, 'longitude': -73.98353},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '281 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['281 3rd Ave', 'New York, NY 10010']},
#    'phone': '+12124774750',
#    'display_phone': '(212) 477-4750',
#    'distance': 3735.107034518671},
#   {'id': 'Gvf470mVe1uRvi_FzR_rUQ',
#    'alias': 'johnnys-cafe-maspeth-17',
#    'name': "Johnny's Cafe",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XCZJuAONdrXgJlHRNDNRwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/johnnys-cafe-maspeth-17?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7160355, 'longitude': -73.9013176},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '6039 Fresh Pond Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'Maspeth',
#     'zip_code': '11378',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6039 Fresh Pond Rd', 'Maspeth, NY 11378']},
#    'phone': '+17188210001',
#    'display_phone': '(718) 821-0001',
#    'distance': 7924.6232630690665},
#   {'id': 'h-tcOdUykJdtmMwyUuHU2g',
#    'alias': 'taste-of-home-fair-lawn',
#    'name': 'Taste of Home',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YUyi7lvx0kW23l4GO7EN-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taste-of-home-fair-lawn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.9351555599011,
#     'longitude': -74.1338890803481},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '13-34 River Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'Fair Lawn',
#     'zip_code': '07410',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['13-34 River Rd', 'Fair Lawn, NY 07410']},
#    'phone': '+12013981990',
#    'display_phone': '(201) 398-1990',
#    'distance': 28114.256618216972},
#   {'id': 'TemMTqYoDJ53doNF-PCKZA',
#    'alias': 'cafe-kashkar-brooklyn',
#    'name': 'Cafe Kashkar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-E3o8WKupd9_w_YN_aqQ9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-kashkar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 266,
#    'categories': [{'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'halal', 'title': 'Halal'},
#     {'alias': 'uzbek', 'title': 'Uzbek'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.5778011, 'longitude': -73.9557381},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1141 Brighton Beach Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11235',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1141 Brighton Beach Ave', 'Brooklyn, NY 11235']},
#    'phone': '+17187433832',
#    'display_phone': '(718) 743-3832',
#    'distance': 14567.549742362226},
#   {'id': 'h8NEvpWO6HvoCdJOM_WNTg',
#    'alias': 'polish-community-center-yonkers',
#    'name': 'Polish Community Center',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/polish-community-center-yonkers?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.932743, 'longitude': -73.893135},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '92 Waverly St',
#     'address2': '',
#     'address3': '',
#     'city': 'Yonkers',
#     'zip_code': '10701',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['92 Waverly St', 'Yonkers, NY 10701']},
#    'phone': '+19149699277',
#    'display_phone': '(914) 969-9277',
#    'distance': 26669.510321139824},
#   {'id': '5Xe9pJnfwad4hXmr8CYSEw',
#    'alias': 'roadhouse-deli-boonton-2',
#    'name': 'Roadhouse Deli',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rGtAD4E7MvzyYHQdCmjsmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roadhouse-deli-boonton-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.9106286, 'longitude': -74.39274235275},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '710 Myrtle Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Boonton',
#     'zip_code': '07005',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['710 Myrtle Ave', 'Boonton, NJ 07005']},
#    'phone': '+19732634900',
#    'display_phone': '(973) 263-4900',
#    'distance': 40560.187807491166},
#   {'id': 'ftSOgoUpnQ7ZjycbEU5tGQ',
#    'alias': 'henrys-deli-bayonne',
#    'name': "Henry's Deli",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Te8FaLBPVvGu4x1yQ0ojNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/henrys-deli-bayonne?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.66389, 'longitude': -74.12115},
#    'transactions': [],
#    'location': {'address1': '488 Avenue C',
#     'address2': '',
#     'address3': '',
#     'city': 'Bayonne',
#     'zip_code': '07002',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['488 Avenue C', 'Bayonne, NJ 07002']},
#    'phone': '+12018581588',
#    'display_phone': '(201) 858-1588',
#    'distance': 11655.832322675185},
#   {'id': 'VFaHfWhyNb66yQAuiB1S-A',
#    'alias': 'manor-oktoberfest-atlas-park-glendale',
#    'name': 'Manor Oktoberfest Atlas Park',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UuWYAaNNiSP5t1rhIGIhvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/manor-oktoberfest-atlas-park-glendale?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 99,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.708147, 'longitude': -73.868222},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '8028 Cooper Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Glendale',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8028 Cooper Ave', 'Glendale, NY 11385']},
#    'phone': '+17183262201',
#    'display_phone': '(718) 326-2201',
#    'distance': 10631.04024568511}],
#  'total': 115,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                  Restaurant            Type Price Rating              Address  \
# 0             Cheburechnaya          Kosher    $$      4         9209 63rd Dr
# 1  R&B Polish American Deli          Polish                       544 86th St
# 2              Pierogi Cafe          Polish                  18 E Prospect St
# 3                  Taam Tov  Middle Eastern    $$    3.5         41 W 47th St
# 4                Zabka Deli          Polish               66-51 Fresh Pond Rd
#
#          Lat        Lng                                                url  \
# 0  40.727599 -73.864082  https://www.yelp.com/biz/cheburechnaya-rego-pa...
# 1  40.620546 -74.024926
# 2  41.010732 -74.118312
# 3  40.757703 -73.980522  https://www.yelp.com/biz/taam-tov-new-york?adj...
# 4  40.707385 -73.897249
#
#                        ID
# 0  SYTBg4SzYuZxrxK3YDU2xg
# 1
# 2
# 3  CPtao9WHPnVJGUS0H4Txww
# 4

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"polish","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': 'hFG8vJ1eOxBB4gTCOMbYSQ',
#    'alias': 'joes-meat-market-perth-amboy',
#    'name': "Joe's Meat Market",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rJpx45ZmOwTLAux5F8b_Ag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-meat-market-perth-amboy?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'},
#     {'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'smokehouse', 'title': 'Smokehouse'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.5121899, 'longitude': -74.28177},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '437 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Perth Amboy',
#     'zip_code': '08861',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['437 Smith St', 'Perth Amboy, NJ 08861']},
#    'phone': '+17324424660',
#    'display_phone': '(732) 442-4660',
#    'distance': 32431.132405965192},
#   {'id': 'PpaV1oQ6idf5kBLDc8lIXA',
#    'alias': 'vernissage-restaurant-hawthorne',
#    'name': 'Vernissage Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/slHP6S_FhFRRUlHy3UtNlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vernissage-restaurant-hawthorne?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.940259, 'longitude': -74.161787},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '111 Wagaraw Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Hawthorne',
#     'zip_code': '07506',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['111 Wagaraw Rd', 'Hawthorne, NJ 07506']},
#    'phone': '+19734235808',
#    'display_phone': '(973) 423-5808',
#    'distance': 29671.043899002783},
#   {'id': 'dza0nBPjGz9829GQtOHAEQ',
#    'alias': 'wallington-exchange-wallington',
#    'name': 'Wallington Exchange',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wKlUJ7EVEZ2LDtEzikz21w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wallington-exchange-wallington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8526420593262,
#     'longitude': -74.1083450317383},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'Wallington',
#     'zip_code': '07057',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['Wallington, NJ 07057']},
#    'phone': '+19734725457',
#    'display_phone': '(973) 472-5457',
#    'distance': 18862.900411792452},
#   {'id': '4y-UVK2Rxxq_tQlDNQmKTg',
#    'alias': 'golden-eagle-deli-garfield',
#    'name': 'Golden Eagle Deli',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ktFmK9BiAPusaiqDk5H4LQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/golden-eagle-deli-garfield?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8898811340332,
#     'longitude': -74.1068572998047},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '452 Lanza Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Garfield',
#     'zip_code': '07026',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['452 Lanza Ave', 'Garfield, NJ 07026']},
#    'phone': '+19735462040',
#    'display_phone': '(973) 546-2040',
#    'distance': 22591.448368092035},
#   {'id': '-JAEpGalOG4VJi5ExSXedA',
#    'alias': 'chinar-restaurant-and-special-events-brooklyn-2',
#    'name': 'Chinar Restaurant & Special Events',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-j5E2eYuk0cBfT5YENo1Kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chinar-restaurant-and-special-events-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'russian', 'title': 'Russian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.5888325, 'longitude': -73.960316},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$$',
#    'location': {'address1': '2775 Coney Island Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11229',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2775 Coney Island Ave', 'Brooklyn, NY 11229']},
#    'phone': '+17183682955',
#    'display_phone': '(718) 368-2955',
#    'distance': 13279.768176540909},
#   {'id': 'qRyQ-wXLjEVUhkbHGGQ7hQ',
#    'alias': 'langos-bar-new-york',
#    'name': 'Langos Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-kvzTcrqyXse9nqPdxqveg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/langos-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'hungarian', 'title': 'Hungarian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71943592077994,
#     'longitude': -73.98645678677418},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '137 Rivington St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['137 Rivington St', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1690.1343478275614},
#   {'id': 'CZg05roVBkzu1QzxTHfkPw',
#    'alias': 'fino-french-bistro-bayside',
#    'name': 'FINO French Bistro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0LT8x1_O0mYlh9sczmrqVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fino-french-bistro-bayside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 420,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76492513125973,
#     'longitude': -73.77149154087756},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '39 13 Bell Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39 13 Bell Blvd', 'Bayside, NY 11361']},
#    'phone': '+17182291330',
#    'display_phone': '(718) 229-1330',
#    'distance': 19903.415708425804},
#   {'id': '2JYL4KmJoxfCSbfBwA7YLw',
#    'alias': 'b-and-b-international-deli-fair-lawn',
#    'name': 'B& B International Deli',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HJVI94TnisUWwaL3hq8K7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b-and-b-international-deli-fair-lawn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'russian', 'title': 'Russian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.9316039085388,
#     'longitude': -74.1319931298494},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '12-17 River Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Fair Lawn',
#     'zip_code': '07410',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['12-17 River Rd', 'Fair Lawn, NJ 07410']},
#    'phone': '+12017940115',
#    'display_phone': '(201) 794-0115',
#    'distance': 27689.722945333866},
#   {'id': 'C9khKyGgZY8S-JjK9FowKg',
#    'alias': 'cappadocia-restaurant-little-falls',
#    'name': 'Cappadocia Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-W7eyGY13WZ82hJtcz34Vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cappadocia-restaurant-little-falls?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 138,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'turkish', 'title': 'Turkish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.88375, 'longitude': -74.24461},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '117 Newark Pompton Tpke',
#     'address2': None,
#     'address3': '',
#     'city': 'Little Falls',
#     'zip_code': '07424',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['117 Newark Pompton Tpke', 'Little Falls, NJ 07424']},
#    'phone': '+19738378737',
#    'display_phone': '(973) 837-8737',
#    'distance': 28924.2664409963},
#   {'id': 'g7c1P9DCUAn1_LBrKVCljg',
#    'alias': 'polish-european-american-deli-m-e-staten-island',
#    'name': 'Polish-European American Deli M.E',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/polish-european-american-deli-m-e-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.62618, 'longitude': -74.13031},
#    'transactions': [],
#    'location': {'address1': '1214 Forest Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10310',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1214 Forest Ave', 'Staten Island, NY 10310']},
#    'phone': '+13478617181',
#    'display_phone': '(347) 861-7181',
#    'distance': 14472.615682876376},
#   {'id': 'vegSCksJy6SI8WUGttLH-w',
#    'alias': 'fradei-bistro-brooklyn-4',
#    'name': 'Fradei Bistro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ukys9pga2bQNptMn0ySLOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fradei-bistro-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.686579, 'longitude': -73.974191},
#    'transactions': [],
#    'location': {'address1': '99 South Portland Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['99 South Portland Ave', 'Brooklyn, NY 11217']},
#    'phone': '+13477253275',
#    'display_phone': '(347) 725-3275',
#    'distance': 2694.3213368567067},
#   {'id': 'AVKRF3v3nvV1NtRc_apQ6g',
#    'alias': 'hot-potato-house-brooklyn',
#    'name': 'Hot Potato House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1zsLxN5LDap0IxF_v1RI1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hot-potato-house-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 166,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'russian', 'title': 'Russian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.5770903848785,
#     'longitude': -73.9526605958191},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '109 Oriental Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11235',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['109 Oriental Blvd', 'Brooklyn, NY 11235']},
#    'phone': '+17189757990',
#    'display_phone': '(718) 975-7990',
#    'distance': 14698.278199137254},
#   {'id': 'yW2oXWI5_gsLWobyKLjG3Q',
#    'alias': 'oceanview-cafe-brooklyn',
#    'name': 'Oceanview Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bOxa-gtDTFvADksgLS2_oQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oceanview-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 140,
#    'categories': [{'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.57672, 'longitude': -73.96427},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '290 Brighton Beach Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11235',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['290 Brighton Beach Ave', 'Brooklyn, NY 11235']},
#    'phone': '+17183321900',
#    'display_phone': '(718) 332-1900',
#    'distance': 14538.749159829922},
#   {'id': '5y3lsh4QeLCM3uNn36wXSw',
#    'alias': 'cafe-restaurant-volna-brooklyn',
#    'name': 'Cafe Restaurant Volna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WJkzCfWqDifKk1vO24SR7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-restaurant-volna-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 104,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'russian', 'title': 'Russian'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.5754013061523,
#     'longitude': -73.9626770019531},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '3145 Brighton 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11235',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3145 Brighton 4th St', 'Brooklyn, NY 11235']},
#    'phone': '+17183320341',
#    'display_phone': '(718) 332-0341',
#    'distance': 14704.244254462243}],
#  'total': 115,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                            Restaurant                   Type Price Rating  \
# 0                   Joe's Meat Market             Meat Shops     $    4.5
# 1               Vernissage Restaurant                Russian  $$$$    3.5
# 2                 Wallington Exchange                 Polish
# 3                   Golden Eagle Deli                  Delis     $      4
# 4  Chinar Restaurant & Special Events  Venues & Event Spaces  $$$$    4.5
#
#                  Address        Lat        Lng  \
# 0           437 Smith St  40.512190 -74.281770
# 1         111 Wagaraw Rd  40.940259 -74.161787
# 2                         40.852642 -74.108345
# 3          452 Lanza Ave  40.889881 -74.106857
# 4  2775 Coney Island Ave  40.588833 -73.960316
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/joes-meat-market-pert...  hFG8vJ1eOxBB4gTCOMbYSQ
# 1  https://www.yelp.com/biz/vernissage-restaurant...  PpaV1oQ6idf5kBLDc8lIXA
# 2
# 3  https://www.yelp.com/biz/golden-eagle-deli-gar...  4y-UVK2Rxxq_tQlDNQmKTg
# 4  https://www.yelp.com/biz/chinar-restaurant-and...  -JAEpGalOG4VJi5ExSXedA

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"polish","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [],
#  'total': 115,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
# Empty DataFrame
# Columns: [Restaurant, Type, Price, Rating, Address, Lat, Lng, url, ID]
# Index: []

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (114, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                                    Restaurant                    Type Rating  \
# 0                            Hot Potato House          American (New)    4.5
# 1                       Cafe Restaurant Volna  American (Traditional)      2
# 2                               Zeppelin Hall  American (Traditional)    3.5
# 3                                       Comfi  American (Traditional)    4.5
# 4                                   Werkstatt                Austrian    4.5
# 5                       Omonia Cafe - Astoria                Bakeries      3
# 6                      Tandoori Food & Bakery                Bakeries      4
# 7                Budapest Cafe and Restaurant                Bakeries    3.5
# 8                              Polonia Bakery                Bakeries      4
# 9                                  Ryan's BBQ                Barbeque    4.5
# 10                           Reichenbach Hall                    Bars      4
# 11                            Gottscheer Hall                Caterers    4.5
# 12                             Roadhouse Deli                   Delis      5
# 13                                Podkarpacie                   Delis
# 14                JW Real Polish Delicatessen                   Delis
# 15          Polish-European American Deli M.E                   Delis
# 16                        Krajan Polskie Deli                   Delis
# 17                    B& B International Deli                   Delis    3.5
# 18                         Syrena Polish Deli                   Delis      4
# 19                          Golden Eagle Deli                   Delis      4
# 20                               Polska Chata                   Delis
# 21                                Polski Smak                   Delis    4.5
# 22                               Henry's Deli                   Delis
# 23                         Polish Specialties                   Delis
# 24                Belka European Delicatessen                   Delis      4
# 25                             Sawa Provision                   Delis
# 26                           Dulcinea Churros                Desserts    3.5
# 27                              Little Poland                  Diners      4
# 28                                    Veselka                  Diners      4
# 29                                      Relax                  Diners      4
# ..                                        ...                     ...    ...
# 84                                 Tatra Haus                  Polish    4.5
# 85               Hetman Polish Deli and Foods                  Polish      4
# 86                               Pierogi Boys                  Polish    4.5
# 87                        Alex & Terry's Deli                  Polish    4.5
# 88                    Royal Warsaw Restaurant                  Polish      4
# 89                                  Polka Dot                  Polish      4
# 90                                 Terminal 1                  Polish    4.5
# 91         Chefski's Polish Home Made Cooking                  Polish      4
# 92                             Pierogi Palace                  Polish      4
# 93                                Christina's                  Polish    3.5
# 94                            Heart of Europe                  Polish
# 95                           Bakestone Bakery                  Polish      4
# 96               Radegast Hall and Biergarten                    Pubs      4
# 97   Russian Samovar Restaurant and Piano Bar                 Russian      4
# 98                      Vernissage Restaurant                 Russian    3.5
# 99                                 Vanka Cafe                 Russian      4
# 100                                Skovorodka                 Russian      4
# 101                            Oceanview Cafe                 Russian    4.5
# 102                                     Uma's                 Russian      4
# 103                                Mari Vanna                 Russian      4
# 104                             Taste of Home                 Russian    4.5
# 105                                Wisla Deli          Specialty Food
# 106                         Stanley's Pierogi          Specialty Food      5
# 107                      The Russian Tea Room               Tea Rooms      3
# 108                              Cafe Kashkar                 Turkish      4
# 109                                  Streecha               Ukrainian    4.5
# 110         Ukrainian East Village Restaurant               Ukrainian      4
# 111      Farida Central Asian Cuisine & Grill                   Uzbek      4
# 112        Chinar Restaurant & Special Events   Venues & Event Spaces    4.5
# 113                             Fradei Bistro               Wine Bars
#
#     Price                               Address        Lat        Lng  \
# 0      $$                     109 Oriental Blvd  40.577090 -73.952661
# 1      $$                  3145 Brighton 4th St  40.575401 -73.962677
# 2      $$                    88 Liberty View Dr  40.715132 -74.046672
# 3      $$                          2638 Hwy 516  40.403864 -74.321868
# 4      $$                  509 Coney Island Ave  40.645298 -73.970234
# 5      $$                        32-20 Broadway  40.761112 -73.924020
# 6      $$                          9904 63rd Rd  40.732547 -73.856189
# 7      $$                          1631 2nd Ave  40.777150 -73.952640
# 8       $                         204 Monroe St  40.866672 -74.122622
# 9      $$                    239 Stuyvesant Ave  40.815390 -74.125660
# 10     $$                           5 W 37th St  40.750800 -73.984010
# 11      $                      657 Fairview Ave  40.706891 -73.905479
# 12     $$                        710 Myrtle Ave  40.910629 -74.392742
# 13                                5020 12th Ave  40.635450 -73.995490
# 14                               321 Church Ave  40.643960 -73.977010
# 15                              1214 Forest Ave  40.626180 -74.130310
# 16                               160 Nassau Ave  40.724930 -73.946710
# 17     $$                        12-17 River Rd  40.931604 -74.131993
# 18     $$              1117 W Saint Georges Ave  40.626555 -74.272012
# 19      $                         452 Lanza Ave  40.889881 -74.106857
# 20                           3294 Washington Rd  40.470163 -74.303025
# 21      $                       1295 Route 23 S  40.991081 -74.345941
# 22                                 488 Avenue C  40.663890 -74.121150
# 23                            1949 Richmond Ave  40.600540 -74.162620
# 24      $                         8319 20th Ave  40.605794 -73.996603
# 25                                 588 Avenue C  40.667280 -74.118290
# 26      $  445 Albee Square W Brooklyn Ny 11201  40.690811 -73.983091
# 27     $$                           200 2nd Ave  40.731190 -73.985520
# 28     $$                           144 2nd Ave  40.729036 -73.987120
# 29      $                          68 Newell St  40.724730 -73.947210
# ..    ...                                   ...        ...        ...
# 84     $$                          115 Main Ave  40.855130 -74.113150
# 85      $                       6665 Forest Ave  40.705763 -73.902519
# 86     $$                    445 Albee Square W  40.691077 -73.982954
# 87     $$                          798 Broadway  40.674370 -74.109130
# 88     $$                          871 River Dr  40.891270 -74.127050
# 89      $                     726 Manhattan Ave  40.726173 -73.951998
# 90     $$                           323 Sand Ln  40.592106 -74.067627
# 91      $                          360 Main Ave  40.859374 -74.104878
# 92      $                       713 W Grand Ave  40.615951 -74.283233
# 93     $$                     853 Manhattan Ave  40.729100 -73.954060
# 94                               1020 State Rte  40.417378 -74.370099
# 95      $                        190 Nassau Ave  40.725303 -73.945541
# 96     $$                          113 N 3rd St  40.716641 -73.961498
# 97     $$                         256 W 52nd St  40.763200 -73.984690
# 98   $$$$                        111 Wagaraw Rd  40.940259 -74.161787
# 99     $$                     3810 Nostrand Ave  40.590967 -73.940149
# 100    $$                615 Brighton Beach Ave  40.578002 -73.961013
# 101    $$                290 Brighton Beach Ave  40.576720 -73.964270
# 102    $$             92-07 Rockaway Beach Blvd  40.586116 -73.815624
# 103   $$$                          41 E 20th St  40.738880 -73.988510
# 104     $                        13-34 River Rd  40.935156 -74.133889
# 105                              109 Locust Ave  40.853455 -74.110812
# 106     $                 5401 Metropolitan Ave  40.713340 -73.910362
# 107  $$$$                         150 W 57th St  40.764958 -73.979434
# 108    $$               1141 Brighton Beach Ave  40.577801 -73.955738
# 109     $                           33 E 7th St  40.728496 -73.988928
# 110    $$                           140 2nd Ave  40.728847 -73.987045
# 111    $$                           498 9th Ave  40.755680 -73.994410
# 112  $$$$                 2775 Coney Island Ave  40.588833 -73.960316
# 113                       99 South Portland Ave  40.686579 -73.974191
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/hot-potato-house-broo...  AVKRF3v3nvV1NtRc_apQ6g
# 1    https://www.yelp.com/biz/cafe-restaurant-volna...  5y3lsh4QeLCM3uNn36wXSw
# 2    https://www.yelp.com/biz/zeppelin-hall-jersey-...  P5X8K61nDAlo8QrgCn-agQ
# 3    https://www.yelp.com/biz/comfi-old-bridge-town...  0qaqUSscW-iYRY2oXO7e6g
# 4    https://www.yelp.com/biz/werkstatt-brooklyn-2?...  FXBrt0VpeBRengdd4fBOZw
# 5    https://www.yelp.com/biz/omonia-cafe-astoria-a...  _OzfOh1aJM4PFCG-qpVknQ
# 6    https://www.yelp.com/biz/tandoori-food-and-bak...  5RCrpBnI_3UdabG1lieknA
# 7    https://www.yelp.com/biz/budapest-cafe-and-res...  u-1o6fSvTnqLBtqFuLFqNw
# 8    https://www.yelp.com/biz/polonia-bakery-passai...  BLFJ4-JDT8XNmL_sIR1OJg
# 9    https://www.yelp.com/biz/ryans-bbq-lyndhurst?a...  VZBuV56yUnyf8ZKyvTnfDQ
# 10   https://www.yelp.com/biz/reichenbach-hall-new-...  BxNs9d8rEW3Tls-nVdmIgA
# 11   https://www.yelp.com/biz/gottscheer-hall-ridge...  XA7phnS0fBfLR8xdsngiUQ
# 12   https://www.yelp.com/biz/roadhouse-deli-boonto...  5Xe9pJnfwad4hXmr8CYSEw
# 13
# 14
# 15
# 16
# 17   https://www.yelp.com/biz/b-and-b-international...  2JYL4KmJoxfCSbfBwA7YLw
# 18   https://www.yelp.com/biz/syrena-polish-deli-li...  ZWfHsuqlxxyWEMBGS1dENQ
# 19   https://www.yelp.com/biz/golden-eagle-deli-gar...  4y-UVK2Rxxq_tQlDNQmKTg
# 20
# 21   https://www.yelp.com/biz/polski-smak-butler?ad...  tuIH3ALOciWJRRmVzcOoJQ
# 22
# 23
# 24   https://www.yelp.com/biz/belka-european-delica...  jNXFOOaOrQMDcLtJGo5MJA
# 25
# 26   https://www.yelp.com/biz/dulcinea-churros-broo...  qj4gZjx1ujn3BbxcANVyZg
# 27   https://www.yelp.com/biz/little-poland-new-yor...  SvNoFlsMTcBzDv9OirfGZw
# 28   https://www.yelp.com/biz/veselka-new-york?adju...  CVxz9B5ncpMwVK1bk_c1YA
# 29   https://www.yelp.com/biz/relax-brooklyn-3?adju...  tG-QM-6Cm2RoLucyj8Kg8g
# ..                                                 ...                     ...
# 84   https://www.yelp.com/biz/tatra-haus-wallington...  aTiVlP1PxzgrcRXFy7WnDQ
# 85   https://www.yelp.com/biz/hetman-polish-deli-an...  8jpRs5cfL8_h3uIUUdgMRg
# 86   https://www.yelp.com/biz/pierogi-boys-brooklyn...  _L_zrbTjKf3KjWvp8gnb5Q
# 87   https://www.yelp.com/biz/alex-and-terrys-deli-...  bUD3Y-uo8RSBlHMR8tN3wQ
# 88   https://www.yelp.com/biz/royal-warsaw-restaura...  StN5iogEjup2MWAzwaGDig
# 89   https://www.yelp.com/biz/polka-dot-brooklyn?ad...  scJdeBOpASetPOl82NkJFQ
# 90   https://www.yelp.com/biz/terminal-1-staten-isl...  9QWngQn7WeoYaMFKhJ5dFA
# 91   https://www.yelp.com/biz/chefskis-polish-home-...  kuUQ4vHtVDhmcwMO_zmW4A
# 92   https://www.yelp.com/biz/pierogi-palace-rahway...  PQFhHgws5BEbwjsTFJ4okA
# 93   https://www.yelp.com/biz/christinas-brooklyn?a...  n8sDrOo5oOlhTS7eYkiZpA
# 94
# 95   https://www.yelp.com/biz/bakestone-bakery-broo...  -RPe5PyA3Za3_iv7strJ_g
# 96   https://www.yelp.com/biz/radegast-hall-and-bie...  TOaQzGPAIQWQUIXi4CPnbA
# 97   https://www.yelp.com/biz/russian-samovar-resta...  lSJD2Gcf9LjJqpLE7pUlWQ
# 98   https://www.yelp.com/biz/vernissage-restaurant...  PpaV1oQ6idf5kBLDc8lIXA
# 99   https://www.yelp.com/biz/vanka-cafe-brooklyn?a...  tv_bPt2qM9Z71oj5VweoVw
# 100  https://www.yelp.com/biz/skovorodka-brooklyn?a...  Npf8xdD81WnSS7KDWxjGYA
# 101  https://www.yelp.com/biz/oceanview-cafe-brookl...  yW2oXWI5_gsLWobyKLjG3Q
# 102  https://www.yelp.com/biz/umas-rockaway-beach?a...  Eu0yHABc9MeJJMUx700a5w
# 103  https://www.yelp.com/biz/mari-vanna-new-york-2...  btLgjl8CEgW2wvB0ZI-Aqg
# 104  https://www.yelp.com/biz/taste-of-home-fair-la...  h-tcOdUykJdtmMwyUuHU2g
# 105
# 106  https://www.yelp.com/biz/stanleys-pierogi-ridg...  SSX7w6j1ftoY80kM4te85w
# 107  https://www.yelp.com/biz/the-russian-tea-room-...  yKOTFgZmTFeas8Pvt077vA
# 108  https://www.yelp.com/biz/cafe-kashkar-brooklyn...  TemMTqYoDJ53doNF-PCKZA
# 109  https://www.yelp.com/biz/streecha-new-york?adj...  IvaqBqN274GeNxMl8sz3Pg
# 110  https://www.yelp.com/biz/ukrainian-east-villag...  _lk_uxURy7g-R7TbrG6hww
# 111  https://www.yelp.com/biz/farida-central-asian-...  tXZOJhUUknjTRRo9j4ckZg
# 112  https://www.yelp.com/biz/chinar-restaurant-and...  -JAEpGalOG4VJi5ExSXedA
# 113
#
# [114 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_Polish.csv')
