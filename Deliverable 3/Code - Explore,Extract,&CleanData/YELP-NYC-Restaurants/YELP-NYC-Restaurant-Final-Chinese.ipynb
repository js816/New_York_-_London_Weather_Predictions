# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"chinese","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': '0CjK3esfpFcxIopebzjFxA',
#    'alias': 'joes-shanghai-new-york-2',
#    'name': "Joe's Shanghai",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KRvabBPGaQikcpSD6vO2bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-shanghai-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6437,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7156608, 'longitude': -73.9967012},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '46 Bowery St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['46 Bowery St', 'New York, NY 10013']},
#    'phone': '+12122338888',
#    'display_phone': '(212) 233-8888',
#    'distance': 1153.9482385806896},
#   {'id': 'lynQoI3w_pzYfHGeuUU-Qg',
#    'alias': 'shu-jiao-fu-zhou-cuisine-restaurant-new-york',
#    'name': 'Shu Jiao Fu Zhou Cuisine Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EV10p_mweh7C1qjrLUJePw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shu-jiao-fu-zhou-cuisine-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 912,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7174109, 'longitude': -73.9920876},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '295 Grand St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['295 Grand St', 'New York, NY 10002']},
#    'phone': '+12126252532',
#    'display_phone': '(212) 625-2532',
#    'distance': 1343.4851190479994},
#   {'id': 'xq0cX_DgxiJMXwhmEl9kUA',
#    'alias': 'café-china-new-york-2',
#    'name': 'Café China',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UhHqxEX2epOvrBFI2pgRzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-china-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1693,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75157, 'longitude': -73.98584},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '59 West 37th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['59 West 37th St', 'New York, NY 10018']},
#    'phone': '+12122132810',
#    'display_phone': '(212) 213-2810',
#    'distance': 5186.281753515895},
#   {'id': '0dDCDQz7DrKkSvu9h2hcQw',
#    'alias': 'chow-house-new-york',
#    'name': 'Chow House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kzeClsI9_2tkHqKScotx1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chow-house-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 456,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72915, 'longitude': -74.00072},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '181 Bleecker St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['181 Bleecker St', 'New York, NY 10012']},
#    'phone': '+12128371021',
#    'display_phone': '(212) 837-1021',
#    'distance': 2692.4401801037266},
#   {'id': 'X8ZS-dgiMIJvhwf9SaDnjw',
#    'alias': 'wah-fung-no-1-new-york-2',
#    'name': 'Wah Fung No 1',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oMriteKj4yYHMmb8myOgJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wah-fung-no-1-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1626,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71735, 'longitude': -73.99457},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '79 Chrystie St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79 Chrystie St', 'New York, NY 10002']},
#    'phone': '+12129255175',
#    'display_phone': '(212) 925-5175',
#    'distance': 1323.2851807067286},
#   {'id': 'wfhMIiMh2A2psCGONOVSlg',
#    'alias': 'han-dynasty-new-york',
#    'name': 'Han Dynasty',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/G5jm9G3m_tquqwDm_qHoVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/han-dynasty-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1274,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.732072, 'longitude': -73.988074},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '90 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90 3rd Ave', 'New York, NY 10003']},
#    'phone': '+12123908685',
#    'display_phone': '(212) 390-8685',
#    'distance': 3006.833804957513},
#   {'id': 'XsXLVWr1UZWVhKThNvNiaA',
#    'alias': 'blue-willow-夜来湘-new-york-2',
#    'name': 'Blue Willow 夜来湘',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1E59vOqmXZHBlJe0lLBHtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-willow-%E5%A4%9C%E6%9D%A5%E6%B9%98-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 274,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76292, 'longitude': -73.976546},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '40 W 56th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40 W 56th St', 'New York, NY 10019']},
#    'phone': '+12122132299',
#    'display_phone': '(212) 213-2299',
#    'distance': 6563.688733717886},
#   {'id': 'BNaveJmi-OUGKG9sRfrIhA',
#    'alias': 'mr-sun-new-york',
#    'name': 'Mr. Sun',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dv2__yunhW9ahqK9BexKRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-sun-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75809, 'longitude': -73.98026},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '48 W 48th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['48 W 48th St', 'New York, NY 10036']},
#    'phone': '+17183169811',
#    'display_phone': '(718) 316-9811',
#    'distance': 5959.214395061453},
#   {'id': 'Q1TpfbuPwKPFrNFyu-u2_g',
#    'alias': 'han-dynasty-brooklyn-2',
#    'name': 'Han Dynasty',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vxbMumdu8Q1e3iCxJ2qZfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/han-dynasty-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 323,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6911319610036,
#     'longitude': -73.9825977757573},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1 Dekalb Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Dekalb Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17188580588',
#    'display_phone': '(718) 858-0588',
#    'distance': 1872.1778710541835},
#   {'id': '4FD0TAxe70nb3ngk3sXF9Q',
#    'alias': 'uluh-new-york',
#    'name': 'Uluh',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZPv7XlXR5ZnD3S_AAV3jXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uluh-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 519,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7293403, 'longitude': -73.9866071},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '152 2nd Ave',
#     'address2': 'Ste A',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['152 2nd Ave', 'Ste A', 'New York, NY 10003']},
#    'phone': '+19172615963',
#    'display_phone': '(917) 261-5963',
#    'distance': 2734.8706531999514},
#   {'id': 'R26zweQ8-xoZS7iHkXQOvw',
#    'alias': 'shanghai-21-new-york-2',
#    'name': 'Shanghai 21',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1rNQzY87fKHPOEexZIGHGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shanghai-21-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1768,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71441, 'longitude': -73.99902},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '21 Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21 Mott St', 'New York, NY 10013']},
#    'phone': '+12127666311',
#    'display_phone': '(212) 766-6311',
#    'distance': 1073.6754859131381},
#   {'id': 'rPTX2J5KGDkN1QhPD-QOvg',
#    'alias': 'bites-of-xian-brooklyn',
#    'name': "Bites of Xi'an",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SiWrJqq1wyIbUWFbhjgoXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bites-of-xian-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 163,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68807, 'longitude': -73.98199},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '318 Livingston St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['318 Livingston St', 'Brooklyn, NY 11217']},
#    'phone': '+13478896725',
#    'display_phone': '(347) 889-6725',
#    'distance': 2192.812317778102},
#   {'id': 'scTDvJ2M2jDbb1ntVeIyxA',
#    'alias': 'hao-noodle-west-village-new-york-2',
#    'name': 'Hao Noodle - West Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/X-hE8s5vsTYtJ-w2k7p86w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hao-noodle-west-village-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 778,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7334863190479,
#     'longitude': -73.9998929006093},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '401 6th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['401 6th Ave', 'New York, NY 10014']},
#    'phone': '+12126338900',
#    'display_phone': '(212) 633-8900',
#    'distance': 3153.574300459982},
#   {'id': 'iSjPBJRiWqrgxW7ZM3CGig',
#    'alias': 'birds-of-a-feather-brooklyn',
#    'name': 'Birds of a Feather',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LCpWi2oB64WZJNaTjgmKyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/birds-of-a-feather-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 422,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71442, 'longitude': -73.960441},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '191 Grand St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['191 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17189696800',
#    'display_phone': '(718) 969-6800',
#    'distance': 3012.406485249949},
#   {'id': 'ojbH3wnRu050hRhkmoxRiA',
#    'alias': 'han-dynasty-new-york-4',
#    'name': 'Han Dynasty',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-aIQqghSAjISvaYL-9w5oA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/han-dynasty-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 629,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78752, 'longitude': -73.97647},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '215 W 85th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['215 W 85th St', 'New York, NY 10024']},
#    'phone': '+12128589060',
#    'display_phone': '(212) 858-9060',
#    'distance': 9254.42805459871},
#   {'id': 'bnDfFdiCcPzhuNWUJORvLQ',
#    'alias': 'noodle-village-new-york-7',
#    'name': 'Noodle Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TwBJ_7nfanDH2CNQ-NQxQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noodle-village-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1192,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.714167, 'longitude': -73.998803},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '13 Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['13 Mott St', 'New York, NY 10013']},
#    'phone': '+12122330788',
#    'display_phone': '(212) 233-0788',
#    'distance': 1041.687819907976},
#   {'id': 'C3tP0fNNAoxOAC3O406CXQ',
#    'alias': 'le-sia-new-york-4',
#    'name': 'Le Sia',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Hqr4G8WYzkjqHOr_VOQyKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-sia-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 71,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76072, 'longitude': -73.99119},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '651 9th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['651 9th Ave', 'New York, NY 10036']},
#    'phone': '+16465595220',
#    'display_phone': '(646) 559-5220',
#    'distance': 6155.955879295095},
#   {'id': 'SNhDVaf_n7VDZcfry8mYdA',
#    'alias': 'the-bao-new-york',
#    'name': 'The Bao',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mxfoOB6li2czAr87PhH3aQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bao-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1275,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72939, 'longitude': -73.9889199},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '13 St Marks Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['13 St Marks Pl', 'New York, NY 10003']},
#    'phone': '+12123889238',
#    'display_phone': '(212) 388-9238',
#    'distance': 2697.5233343657724},
#   {'id': 'xVduej7-JiPrZzsFXIkIDw',
#    'alias': 'lazy-sius-brooklyn',
#    'name': "Lazy Siu's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0s0ZcA2sk__SsM_xNhwHbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lazy-sius-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71261, 'longitude': -73.96077},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '742 Driggs Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['742 Driggs Ave', 'Brooklyn, NY 11211']},
#    'phone': '+19293376352',
#    'display_phone': '(929) 337-6352',
#    'distance': 2933.585593999067},
#   {'id': '8Oo2AtQEPDfxIOnA8wfXoQ',
#    'alias': '886-new-york',
#    'name': '886',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/N-V-Dl4nrmMhN1TcVt6a8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/886-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 456,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72877, 'longitude': -73.98873},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '26 Saint Marks Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 Saint Marks Pl', 'New York, NY 10003']},
#    'phone': '+16468820231',
#    'display_phone': '(646) 882-0231',
#    'distance': 2638.0802791580863},
#   {'id': 'M-odQWSEfsR2mVEw7nKG-g',
#    'alias': 'nyonya-new-york',
#    'name': 'Nyonya',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YuWC1Gwo7ku4PvD-7mDQnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nyonya-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2151,
#    'categories': [{'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7190148, 'longitude': -73.9968228},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '199 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['199 Grand St', 'New York, NY 10013']},
#    'phone': '+12123343669',
#    'display_phone': '(212) 334-3669',
#    'distance': 1524.9858332338151},
#   {'id': 'vZgJyMZlpSSS_Y-duxd4_A',
#    'alias': 'kings-co-imperial-brooklyn',
#    'name': 'Kings Co Imperial',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4DtrNVOVRo1Zj0Ye10EkOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kings-co-imperial-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 342,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71512, 'longitude': -73.95097},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '20 Skillman Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['20 Skillman Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17186102000',
#    'display_phone': '(718) 610-2000',
#    'distance': 3807.7319449460683},
#   {'id': 'wqdFd3DZD_uTXRW784mFkg',
#    'alias': 'a-pous-taste-brooklyn-2',
#    'name': "A-Pou's Taste",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xl5eqyVYo9bVVRwOMGVBgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/a-pous-taste-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 78,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71326, 'longitude': -73.93616},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '963 Grand St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['963 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17183883038',
#    'display_phone': '(718) 388-3038',
#    'distance': 4977.457105832991},
#   {'id': 'olRNNJCJ2TJvPRmjBiOcGA',
#    'alias': 'silky-kitchen-new-york-3',
#    'name': 'Silky Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YFkv6-Z4Ax0mtwMkIjUDPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/silky-kitchen-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 244,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73297, 'longitude': -73.98829},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '137 E 13th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['137 E 13th St', 'New York, NY 10003']},
#    'phone': '+16468500635',
#    'display_phone': '(646) 850-0635',
#    'distance': 3099.0828505233635},
#   {'id': 'jc7lVTvmYMIK5RNpENtS6w',
#    'alias': 'szechuan-mountain-house-new-york-2',
#    'name': 'Szechuan Mountain House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DkO-lKVPNYyvJMRl8es3WQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/szechuan-mountain-house-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 433,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72911, 'longitude': -73.98858},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '23 St Marks Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23 St Marks Pl', 'New York, NY 10003']},
#    'phone': '+19173883866',
#    'display_phone': '(917) 388-3866',
#    'distance': 2686.6341472633094},
#   {'id': '3gqKLANaXNsHZnPDjKrcTg',
#    'alias': 'win-son-brooklyn-4',
#    'name': 'Win Son',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EXCnl7qaa1wEQMWMI6ZqRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/win-son-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 556,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70747, 'longitude': -73.94339},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '159 Graham Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['159 Graham Ave', 'Brooklyn, NY 11206']},
#    'phone': '+13474576010',
#    'display_phone': '(347) 457-6010',
#    'distance': 4288.123697814991},
#   {'id': 'sQw7aEos_0FmO0UFtrJokg',
#    'alias': 'clay-pot-west-village-new-york-2',
#    'name': 'Clay Pot - West Village',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/whFu6V5xMjIeK4ZhoKJdDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clay-pot-west-village-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 107,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73138, 'longitude': -74.00319},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '270 Bleeker St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['270 Bleeker St', 'New York, NY 10014']},
#    'phone': '+19177756159',
#    'display_phone': '(917) 775-6159',
#    'distance': 2977.5019905000745},
#   {'id': 'bVkjBJlAIwKAj9Aw1KVWjA',
#    'alias': 'dim-sum-palace-new-york-8',
#    'name': 'Dim Sum Palace',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NqnWxno1sa9nbrb1YlvbkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dim-sum-palace-new-york-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1363,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76015, 'longitude': -73.9893699},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '334 W 46th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['334 W 46th St', 'New York, NY 10036']},
#    'phone': '+16468611910',
#    'display_phone': '(646) 861-1910',
#    'distance': 6102.3266274330845},
#   {'id': 'wDuf4Qz9qsC62amLZgWNJQ',
#    'alias': 'little-alley-new-york',
#    'name': 'Little Alley',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TUEvUL0vFghtB1byZRw7cg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-alley-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 396,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74744, 'longitude': -73.97728},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '550 3rd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['550 3rd Ave', 'New York, NY 10016']},
#    'phone': '+16469983976',
#    'display_phone': '(646) 998-3976',
#    'distance': 4884.401375532534},
#   {'id': 'xCHApgtkLpEyh0lz-uhZvg',
#    'alias': 'szechuan-garden-new-york',
#    'name': 'Szechuan Garden',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/g0szneLpAM3H6Ur6qyv_Ag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/szechuan-garden-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 333,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.80053, 'longitude': -73.967586},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '239 W 105th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['239 W 105th St', 'New York, NY 10025']},
#    'phone': '+12128658808',
#    'display_phone': '(212) 865-8808',
#    'distance': 10812.066604467627},
#   {'id': 'cOtB9fWWLrbaBebZDjJquQ',
#    'alias': 'dunhuang-miss-noodles-brooklyn',
#    'name': 'DunHuang Miss Noodles',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RrlOuwLfm1pi5oqXk6CN4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dunhuang-miss-noodles-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.693868137768895,
#     'longitude': -73.9634565145772},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '531 Myrtle Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['531 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17187893530',
#    'display_phone': '(718) 789-3530',
#    'distance': 2900.8291200464364},
#   {'id': '8DV1myPrW7SePZOK46IjLQ',
#    'alias': 'lady-chows-kitchen-new-york',
#    'name': "Lady Chow's Kitchen",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VbBM-DpFJ9TkGo4yRre52w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lady-chows-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71785, 'longitude': -73.9968},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '171 Hester St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 Hester St', 'New York, NY 10013']},
#    'phone': '+12123439496',
#    'display_phone': '(212) 343-9496',
#    'distance': 1399.7906969149235},
#   {'id': 'RoPrfBqmRTqw_cBqcWAfYA',
#    'alias': 'dim-sum-bar-brooklyn',
#    'name': 'Dim Sum Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vel_JJTV9Y6bONllGiNFNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dim-sum-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 215,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.714735, 'longitude': -73.961346},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '167 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['167 Grand St', 'Brooklyn, NY 11249']},
#    'phone': '+17183888988',
#    'display_phone': '(718) 388-8988',
#    'distance': 2962.8795231121862},
#   {'id': 'Kqb7MjTPNkjPMoFRd-rWpw',
#    'alias': 'málà-project-new-york',
#    'name': 'MáLà Project',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PFR2C4TiLBTUcMUpznUXlg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/m%C3%A1l%C3%A0-project-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 736,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72713, 'longitude': -73.98542},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '122 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['122 1st Ave', 'New York, NY 10009']},
#    'phone': '+12123538880',
#    'display_phone': '(212) 353-8880',
#    'distance': 2523.2680723643457},
#   {'id': 'IhSVn0TaX8xXb3wcQ-fgcA',
#    'alias': 'vanessas-dumpling-house-new-york-2',
#    'name': "Vanessa's Dumpling House",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5RDbR4H-D7BL6WaeleY_sg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vanessas-dumpling-house-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2706,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71839, 'longitude': -73.9917399},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '118A Eldridge St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['118A Eldridge St', 'New York, NY 10002']},
#    'phone': '+12126258008',
#    'display_phone': '(212) 625-8008',
#    'distance': 1449.9327962540722},
#   {'id': '97q5nUQTuBo_h00XCxna2A',
#    'alias': 'tasty-hand-pulled-noodles-new-york',
#    'name': 'Tasty Hand-Pulled Noodles',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/S4YfmBNkmDl7l2aiYJwBuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tasty-hand-pulled-noodles-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1658,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7142, 'longitude': -73.99787},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1 Doyers St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Doyers St', 'New York, NY 10013']},
#    'phone': '+12127911817',
#    'display_phone': '(212) 791-1817',
#    'distance': 1017.7282412658462},
#   {'id': 'xLJnT-pB4VECJzmUf1Whpg',
#    'alias': '3-times-new-york-5',
#    'name': '3 Times',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uBC9JN_S03qqWTCF_eNnwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/3-times-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 145,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.718271, 'longitude': -73.985209},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '90 Clinton St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90 Clinton St', 'New York, NY 10002']},
#    'phone': '+16466096324',
#    'display_phone': '(646) 609-6324',
#    'distance': 1616.388397109797},
#   {'id': 'rYw5rQbWRX9buZHZbxqWdA',
#    'alias': 'congee-village-new-york',
#    'name': 'Congee Village',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Nccuu7yqWhOiEtuqozq9DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/congee-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1632,
#    'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7187, 'longitude': -73.99031},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '100 Allen St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100 Allen St', 'New York, NY 10002']},
#    'phone': '+12129411818',
#    'display_phone': '(212) 941-1818',
#    'distance': 1506.9093475842137},
#   {'id': 'FcHVRbMcYY-D1Glzwo3ofA',
#    'alias': 'mr-bao-brooklyn',
#    'name': 'Mr. Bao',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DOtT38IBRaEdOMnNDrFlTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-bao-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 101,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.677216, 'longitude': -73.979754},
#    'transactions': [],
#    'location': {'address1': '179 5th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['179 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3369.4425765065284},
#   {'id': 'A_fZL0ir_actclrL-ePTOw',
#    'alias': 'jj-kitchen-brooklyn',
#    'name': 'JJ Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/folvsIJywU5yshKGhyBVsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jj-kitchen-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69354, 'longitude': -73.96627},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '475 B Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['475 B Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17186360468',
#    'display_phone': '(718) 636-0468',
#    'distance': 2704.135502473467},
#   {'id': '2wVirrAVg3ltAFHoHeXHMQ',
#    'alias': 'dim-sum-palace-new-york-9',
#    'name': 'Dim Sum Palace',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eSaOLayWbkTQ9r3fq1evzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dim-sum-palace-new-york-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 224,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7259, 'longitude': -73.98986},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '59 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['59 2nd Ave', 'New York, NY 10003']},
#    'phone': '+16464768846',
#    'display_phone': '(646) 476-8846',
#    'distance': 2309.8668756613047},
#   {'id': 'DpfE0gPBXj-aj2pnEh4E2Q',
#    'alias': 'wei-williamsburg-brooklyn',
#    'name': 'Wei Williamsburg',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LNgR4BdMlEr-i1XXUJbO6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wei-williamsburg-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 180,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7107868, 'longitude': -73.9542168},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '145 Borinquen Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['145 Borinquen Pl', 'Brooklyn, NY 11211']},
#    'phone': '+17183601908',
#    'display_phone': '(718) 360-1908',
#    'distance': 3461.341384289627},
#   {'id': 'Bb0h5Rs8ugSM2CjulRhfBw',
#    'alias': 'spicy-moon-east-village-new-york',
#    'name': 'Spicy Moon East Village',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5xj4ZyYiECeK7Z3sFmOwCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spicy-moon-east-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 437,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72674, 'longitude': -73.98722},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '328 E 6th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['328 E 6th St', 'New York, NY 10003']},
#    'phone': '+16464298471',
#    'display_phone': '(646) 429-8471',
#    'distance': 2437.632855284239},
#   {'id': 'FXhSEZfIqjMZh4hR0_8jMQ',
#    'alias': 'china-xiang-中国湘-new-york-2',
#    'name': 'China Xiang 中国湘',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MC6-poc5wb7mP-jO7qfHHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/china-xiang-%E4%B8%AD%E5%9B%BD%E6%B9%98-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 500,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7582902125633,
#     'longitude': -73.9925113993899},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '360 W 42nd Street',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['360 W 42nd Street', 'New York, NY 10036']},
#    'phone': '+12129676088',
#    'display_phone': '(212) 967-6088',
#    'distance': 5878.045777624759},
#   {'id': '2J3--ZI6CcoYLWSYYVdt7Q',
#    'alias': 'milu-new-york-2',
#    'name': 'Milu',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ePJzEAtHWzvQaNbTZIl4LQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/milu-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 114,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.741084, 'longitude': -73.985324},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '333 Park Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['333 Park Ave S', 'New York, NY 10010']},
#    'phone': '+12123776403',
#    'display_phone': '(212) 377-6403',
#    'distance': 4036.8412391510096},
#   {'id': 'BkXb82Y2OIsQ5RpNNQOYmQ',
#    'alias': 'china-express-brooklyn-4',
#    'name': 'China Express',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6oTE-vhUO0flYTIQoeXjgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/china-express-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 119,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7061859, 'longitude': -73.9501435},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '192 Union Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['192 Union Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17182187919',
#    'display_phone': '(718) 218-7919',
#    'distance': 3734.901068347167},
#   {'id': 'nI1UYDCYUTt23TpGxqnLKg',
#    'alias': 'buddakan-new-york',
#    'name': 'Buddakan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JJ6WiHxZmX3gKyllSteBmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/buddakan-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4134,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7422762672197,
#     'longitude': -74.0048000961542},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$$',
#    'location': {'address1': '75 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 9th Ave', 'New York, NY 10011']},
#    'phone': '+12129896699',
#    'display_phone': '(212) 989-6699',
#    'distance': 4190.079294335545},
#   {'id': 'L9N9O2u_M9Daby9_myK4Yg',
#    'alias': 'mao-s-bao-new-york',
#    'name': 'Mao’s Bao',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QJXJAvPqmlOik1PDeauwoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mao-s-bao-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7480714928872,
#     'longitude': -74.004706248683},
#    'transactions': [],
#    'location': {'address1': '4059 High Line',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4059 High Line', 'New York, NY 10011']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4820.396918707139},
#   {'id': 'oowNI_aUmGEFa_VW8BFgRg',
#    'alias': 'tri-dim-shanghai-new-york-2',
#    'name': 'Tri Dim Shanghai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-HycyO1XNiKGN8q28RYATg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tri-dim-shanghai-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 433,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.773951, 'longitude': -73.957927},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1378 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1378 3rd Ave', 'New York, NY 10075']},
#    'phone': '+12125853388',
#    'display_phone': '(212) 585-3388',
#    'distance': 8209.867326951198},
#   {'id': 'UK1oGbr8GU2rufpnJR4-HQ',
#    'alias': 'joes-home-of-soup-dumplings-new-york',
#    'name': "Joe's Home of Soup Dumplings",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GY04xwX3RMnbSLmPizy1eA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-home-of-soup-dumplings-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 75,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75723, 'longitude': -73.97702},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '7 E 48th St',
#     'address2': 'between Fifth and Madison avenues',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 E 48th St',
#      'between Fifth and Madison avenues',
#      'New York, NY 10017']},
#    'phone': '+12123333868',
#    'display_phone': '(212) 333-3868',
#    'distance': 5921.106571357405}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                             Restaurant          Type Price Rating  \
# 0                       Joe's Shanghai  Shanghainese    $$      4
# 1  Shu Jiao Fu Zhou Cuisine Restaurant       Chinese     $    4.5
# 2                           Café China      Szechuan    $$      4
# 3                           Chow House      Szechuan    $$    4.5
# 4                        Wah Fung No 1     Fast Food     $    4.5
#
#            Address        Lat        Lng  \
# 0     46 Bowery St  40.715661 -73.996701
# 1     295 Grand St  40.717411 -73.992088
# 2  59 West 37th St  40.751570 -73.985840
# 3  181 Bleecker St  40.729150 -74.000720
# 4   79 Chrystie St  40.717350 -73.994570
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/joes-shanghai-new-yor...  0CjK3esfpFcxIopebzjFxA
# 1  https://www.yelp.com/biz/shu-jiao-fu-zhou-cuis...  lynQoI3w_pzYfHGeuUU-Qg
# 2  https://www.yelp.com/biz/caf%C3%A9-china-new-y...  xq0cX_DgxiJMXwhmEl9kUA
# 3  https://www.yelp.com/biz/chow-house-new-york?a...  0dDCDQz7DrKkSvu9h2hcQw
# 4  https://www.yelp.com/biz/wah-fung-no-1-new-yor...  X8ZS-dgiMIJvhwf9SaDnjw

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"chinese","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': '3oB2_2vpeIyxJt1GvlcZBA',
#    'alias': 'baodega-new-york',
#    'name': 'Baodega',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/obYuCbmayKFOVyVscUGJ1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baodega-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 205,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74014, 'longitude': -73.99178},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '7 W 20th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 W 20th St', 'New York, NY 10011']},
#    'phone': '+16463706034',
#    'display_phone': '(646) 370-6034',
#    'distance': 3868.878237136064},
#   {'id': '62Kedrco374IuZ_OFb0BxA',
#    'alias': '3-times-new-york-6',
#    'name': '3 Times',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/I-kKW1dlEk444vgCEhTPTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/3-times-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 163,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73285, 'longitude': -73.99104},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '818 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['818 Broadway', 'New York, NY 10003']},
#    'phone': '+16466093040',
#    'display_phone': '(646) 609-3040',
#    'distance': 3060.977452329732},
#   {'id': 'lQ8Fzgji9qmgRXkFcvAsVQ',
#    'alias': 'chong-qing-xiao-mian-new-york-2',
#    'name': 'Chong Qing Xiao Mian',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/z1UDqQoreZSEEVEgtlI8pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chong-qing-xiao-mian-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 318,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76513, 'longitude': -73.98753},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '796 9th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['796 9th Ave', 'New York, NY 10019']},
#    'phone': '+12125828866',
#    'display_phone': '(212) 582-8866',
#    'distance': 6661.428754177582},
#   {'id': 'AfF4zVbVI27zwgkzOLYDFg',
#    'alias': 'xian-famous-foods-brooklyn-9',
#    'name': "Xi'an Famous Foods",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yrsp6lqTre5pFqrCMFcQEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/xian-famous-foods-brooklyn-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 230,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7243301734731,
#     'longitude': -73.9509299397469},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '648 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['648 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+12127862068',
#    'display_phone': '(212) 786-2068',
#    'distance': 4215.074542407371},
#   {'id': '1KoKR9fug8VXZr5tqqtimQ',
#    'alias': 'rim-nam-thai-brooklyn',
#    'name': 'Rim Nam Thai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/C45gqQ7OAHtanVuhSmSjxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rim-nam-thai-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7033674860089, 'longitude': -73.9868891},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '52 Jay St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['52 Jay St', 'Brooklyn, NY 11201']},
#    'phone': '+19292980337',
#    'display_phone': '(929) 298-0337',
#    'distance': 665.5044429640708},
#   {'id': 'w3wKbjuNCZnYoPOr-FCk5w',
#    'alias': 'new-moon-new-york',
#    'name': 'New Moon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kE6lAgB1pe-FWe1NUzdeaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-moon-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 169,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.742569, 'longitude': -73.977856},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '547 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['547 2nd Ave', 'New York, NY 10016']},
#    'phone': '+12127792828',
#    'display_phone': '(212) 779-2828',
#    'distance': 4355.435031227419},
#   {'id': 'sfsjk1h50ooC2ioY7m48gw',
#    'alias': 'pig-heaven-new-york-3',
#    'name': 'Pig Heaven',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YzHJPPxM5m6qp_vwfrC6SA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pig-heaven-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 429,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77544, 'longitude': -73.95686},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1420 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1420 3rd Ave', 'New York, NY 10028']},
#    'phone': '+12127444333',
#    'display_phone': '(212) 744-4333',
#    'distance': 8399.490329439157},
#   {'id': '--SoNTeCXFUx56no0OgibQ',
#    'alias': 'bites-of-xian-new-york',
#    'name': "Bites of Xi'an",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7Dpg33hicEbKBVr3wH4aQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bites-of-xian-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.730861, 'longitude': -73.989941},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '84 E 10th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['84 E 10th St', 'New York, NY 10003']},
#    'phone': '+19174095535',
#    'display_phone': '(917) 409-5535',
#    'distance': 2850.3734620688583},
#   {'id': 'EmJ7rfmv2y6lQZxgA8U__g',
#    'alias': 'red-peony-chinese-cuisine-new-york-4',
#    'name': 'Red Peony Chinese Cuisine',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bD0jgTj0uJdBsd2vrN-JLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/red-peony-chinese-cuisine-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 426,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76278, 'longitude': -73.97589},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '24 W 56th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 W 56th St', 'New York, NY 10019']},
#    'phone': '+12123808883',
#    'display_phone': '(212) 380-8883',
#    'distance': 6558.352315651386},
#   {'id': 'jLhKLKuNPMTzAMJgEY5DsQ',
#    'alias': 'monarch-restaurant-brooklyn',
#    'name': 'Monarch Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/g7ZBrOXFk1T_eIzEeEfK-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/monarch-restaurant-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'panasian', 'title': 'Pan Asian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71595, 'longitude': -73.96222},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '146 Metropolitan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['146 Metropolitan Ave', 'Brooklyn, NY 11249']},
#    'phone': '+19179091596',
#    'display_phone': '(917) 909-1596',
#    'distance': 2940.0641704453333},
#   {'id': 'UaQF4mv6hVjiegkwUvQeMQ',
#    'alias': 'dim-sum-chelsea-new-york-4',
#    'name': 'Dim Sum Chelsea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/REgdCdh222y92X3liXd2AQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dim-sum-chelsea-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 99,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.744624, 'longitude': -73.998649},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '236 8th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['236 8th Ave', 'New York, NY 10011']},
#    'phone': '+12126450100',
#    'display_phone': '(212) 645-0100',
#    'distance': 4371.952100040229},
#   {'id': 'shwaY4v3fx9tjalvHVIBxQ',
#    'alias': 'tengri-tagh-uyghur-cuisine-new-york',
#    'name': 'Tengri Tagh Uyghur Cuisine',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TXDN9HHZdXjCnHRytt33ug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tengri-tagh-uyghur-cuisine-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'halal', 'title': 'Halal'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'kebab', 'title': 'Kebab'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75246221952214,
#     'longitude': -73.98871967056284},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '144 W 37th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['144 W 37th St', 'New York, NY 10018']},
#    'phone': '+16469645418',
#    'display_phone': '(646) 964-5418',
#    'distance': 5249.137867555698},
#   {'id': 'v2dtG37r1ThqtfEfiFsAUg',
#    'alias': 'shanghai-mong-new-york',
#    'name': 'Shanghai Mong',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6gBvfvj0TH44dvmvLAjUdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shanghai-mong-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 571,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7476119995117,
#     'longitude': -73.9871597290039},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '30 W 32nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30 W 32nd St', 'New York, NY 10001']},
#    'phone': '+12126296450',
#    'display_phone': '(212) 629-6450',
#    'distance': 4726.86415341011},
#   {'id': 'U2aUFZARLeSMf4RQIxjuTw',
#    'alias': 'lucky-house-kitchen-brooklyn',
#    'name': 'Lucky House Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W1gxn2t0DSWFyx972XNWpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lucky-house-kitchen-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 106,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6838402152061,
#     'longitude': -73.9351565390825},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '343 Lewis Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['343 Lewis Ave', 'Brooklyn, NY 11233']},
#    'phone': '+17184432298',
#    'display_phone': '(718) 443-2298',
#    'distance': 5544.456640284258},
#   {'id': '_XLLSXPIjgoZQtwU3RCcQA',
#    'alias': 'hunan-delight-brooklyn',
#    'name': 'Hunan Delight',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GydoNAcyZqMpdKwULzMmmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hunan-delight-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 319,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6755282563532,
#     'longitude': -73.9780712127686},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '752 Union St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['752 Union St', 'Brooklyn, NY 11215']},
#    'phone': '+17187891400',
#    'display_phone': '(718) 789-1400',
#    'distance': 3596.7671237234936},
#   {'id': 'xH7mEjh4Rn6KdHjXYNoOjw',
#    'alias': 'yaso-tangbao-brooklyn-4',
#    'name': 'Yaso Tangbao',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/To9YIXVJLVhpeRhlO0oxQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yaso-tangbao-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 775,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6918206366101,
#     'longitude': -73.9863992364001},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '148 Lawrence St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['148 Lawrence St', 'Brooklyn, NY 11201']},
#    'phone': '+19293377599',
#    'display_phone': '(929) 337-7599',
#    'distance': 1654.6654435111413},
#   {'id': 'IoAUbSudW1Mds5_XY_01Rg',
#    'alias': 'mission-brooklyn-brooklyn',
#    'name': 'Mission - Brooklyn',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nF15Ipri4P1KEJnmVT96OA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mission-brooklyn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.709382, 'longitude': -73.923229},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '599 Johnson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['599 Johnson Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17186283731',
#    'display_phone': '(718) 628-3731',
#    'distance': 6004.297870197819},
#   {'id': '6tASYtO9zOrXr8-LPnAToQ',
#    'alias': 'zest-szechuan-new-york',
#    'name': 'Zest Szechuan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gRwi2bF4FXIZKHgFObryqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zest-szechuan-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 609,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75274, 'longitude': -73.98445},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '45 W 39th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 W 39th St', 'New York, NY 10018']},
#    'phone': '+16468700521',
#    'display_phone': '(646) 870-0521',
#    'distance': 5323.221187222823},
#   {'id': 'Puyzn1gagH9TsJz7EBJs3g',
#    'alias': 'baji-baji-new-york',
#    'name': 'Baji Baji',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/x6skz4gZQVq5ei9kUwPUJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baji-baji-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72821421354205,
#     'longitude': -73.98516918819301},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '145 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['145 1st Ave', 'New York, NY 10003']},
#    'phone': '+12127773888',
#    'display_phone': '(212) 777-3888',
#    'distance': 2646.032709702592},
#   {'id': 'zrV2yUsz1SxymeH51iRBRw',
#    'alias': 'chuan-tian-xia-川天下-brooklyn',
#    'name': 'Chuan Tian Xia 川天下',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jBfIr6J9zzmNsyHezJe_yA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chuan-tian-xia-%E5%B7%9D%E5%A4%A9%E4%B8%8B-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 209,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6397, 'longitude': -74.009131},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '5502 7th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11220',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5502 7th Ave', 'Brooklyn, NY 11220']},
#    'phone': '+19292950128',
#    'display_phone': '(929) 295-0128',
#    'distance': 7416.811879225012},
#   {'id': 'kueEZRLEaNVo6Cow3hf56Q',
#    'alias': 'nice-day-chinese-new-york-3',
#    'name': 'Nice Day Chinese',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NZf4Ef9maIUr1vMBlHXZ9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nice-day-chinese-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72867, 'longitude': -74.0007},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '170 Bleecker St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['170 Bleecker St', 'New York, NY 10012']},
#    'phone': '+19292601030',
#    'display_phone': '(929) 260-1030',
#    'distance': 2640.420280567424},
#   {'id': 'R7EGjHWw0tNheY6-ahH8fQ',
#    'alias': 'tuome-new-york-2',
#    'name': 'Tuome',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/J5agtut4uApn4gpvnPmv1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tuome-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 560,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72412482724, 'longitude': -73.9828906263924},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '536 E 5th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['536 E 5th St', 'New York, NY 10009']},
#    'phone': '+16468337811',
#    'display_phone': '(646) 833-7811',
#    'distance': 2288.6649662214686},
#   {'id': 'lJsNGj70bmuBrcAubvfTAQ',
#    'alias': 'first-wok-brooklyn',
#    'name': 'First Wok',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VKXiyb-ft6uC7bb9lT7__A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/first-wok-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.70154, 'longitude': -73.98456},
#    'transactions': ['delivery'],
#    'location': {'address1': '155 York St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['155 York St', 'Brooklyn, NY 11201']},
#    'phone': '+17188524383',
#    'display_phone': '(718) 852-4383',
#    'distance': 927.6030065527393},
#   {'id': 'pPqEu60FMffpiWqk2MCrVA',
#    'alias': 'hutaoli-music-restaurant-and-bar-new-york',
#    'name': 'Hutaoli Music Restaurant & Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/c9MR2ubOcC-Iq4_AI5lYqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hutaoli-music-restaurant-and-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.748413, 'longitude': -73.9871229},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '42 W 33rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 W 33rd St', 'New York, NY 10001']},
#    'phone': '+19172616989',
#    'display_phone': '(917) 261-6989',
#    'distance': 4813.399872651659},
#   {'id': 'rBUTVjRs5CcEMe3dfVRZJQ',
#    'alias': 'ho-foods-new-york-3',
#    'name': 'Ho Foods',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-yKeU-JwcZ_CaO5-cok-Cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ho-foods-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 333,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72634, 'longitude': -73.98478},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '110 E 7th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['110 E 7th St', 'New York, NY 10009']},
#    'phone': '+13477880682',
#    'display_phone': '(347) 788-0682',
#    'distance': 2459.1073897868705},
#   {'id': 'rJ4N10Nbh-GM49qOSGFoAw',
#    'alias': 'old-xian-new-york-4',
#    'name': "Old Xi'an",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/m31vYiHavX7fyVir148bHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/old-xian-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 230,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70591, 'longitude': -74.00747},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '164 Pearl St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['164 Pearl St', 'New York, NY 10005']},
#    'phone': '+12127975509',
#    'display_phone': '(212) 797-5509',
#    'distance': 1106.144449489715},
#   {'id': 'S-aX_Pz8F7nDL6kRThKcHw',
#    'alias': 'vanessas-dumpling-house-brooklyn',
#    'name': "Vanessa's Dumpling House",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GxKqLQja61STkJ_pAiKp-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vanessas-dumpling-house-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 549,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.713795, 'longitude': -73.961983},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '310 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['310 Bedford Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17182188809',
#    'display_phone': '(718) 218-8809',
#    'distance': 2877.910787616412},
#   {'id': 'pCfGgX0WxGASGM4-Yhr2Pw',
#    'alias': 'hao-noodle-chelsea-new-york-7',
#    'name': 'Hao Noodle Chelsea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WbBI5Kd8FAegVcV1g-BkyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hao-noodle-chelsea-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 460,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7406999, 'longitude': -74.00436},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '343 W 14th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['343 W 14th St', 'New York, NY 10014']},
#    'phone': '+16468820059',
#    'display_phone': '(646) 882-0059',
#    'distance': 4014.0194931947067},
#   {'id': '9-vKFnUby_6-pR6UJxjzMw',
#    'alias': 'sun-hing-lung-co-new-york-3',
#    'name': 'Sun Hing Lung Co',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qVbsbpdJUS0X0cVl8eNWsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sun-hing-lung-co-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 190,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7127362, 'longitude': -73.9950764600962},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '58 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['58 Henry St', 'New York, NY 10002']},
#    'phone': '+12129627032',
#    'display_phone': '(212) 962-7032',
#    'distance': 813.4421176666204},
#   {'id': 'X4hEgOBOLTYFhlWO-gAFxQ',
#    'alias': 'tipsy-shanghai-new-york-2',
#    'name': 'Tipsy Shanghai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eug9X4MJcWws0LkoTC7J5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tipsy-shanghai-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 246,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72929, 'longitude': -73.99882},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '228 Thompson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 Thompson St', 'New York, NY 10012']},
#    'phone': '+12127630877',
#    'display_phone': '(212) 763-0877',
#    'distance': 2673.946404708324},
#   {'id': 'qNMPfDIoPFGHmEHnJBnl1A',
#    'alias': 'public-village-new-york',
#    'name': 'Public Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1anaXYftqtazX6H88z8Jtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/public-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.715441, 'longitude': -73.99006},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '23 Essex St N',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23 Essex St N', 'New York, NY 10002']},
#    'phone': '+16464767501',
#    'display_phone': '(646) 476-7501',
#    'distance': 1169.3031086170454},
#   {'id': '8ig0yf0003DAp4YOGTlbVg',
#    'alias': 'spicy-village-new-york',
#    'name': 'Spicy Village',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-2Lutxll4CVMAEzHvDAqxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spicy-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 710,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71695, 'longitude': -73.99327},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '68 Forsyth St',
#     'address2': 'Ste B',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['68 Forsyth St', 'Ste B', 'New York, NY 10002']},
#    'phone': '+12126258299',
#    'display_phone': '(212) 625-8299',
#    'distance': 1290.0560443478676},
#   {'id': '7ZQSMqWzvXMSetXnii2fBg',
#    'alias': 'excellent-dumpling-house-new-york-3',
#    'name': 'Excellent Dumpling House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZnK3r6Knbjjqv3wfQUIExQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/excellent-dumpling-house-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 676,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'shanghainese', 'title': 'Shanghainese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7440494396358,
#     'longitude': -73.995028194335},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '165 W 23rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['165 W 23rd St', 'New York, NY 10011']},
#    'phone': '+12129898885',
#    'display_phone': '(212) 989-8885',
#    'distance': 4293.074947610118},
#   {'id': 'qrncvjkiKN5Z-JC06ygy6A',
#    'alias': 'hutong-new-york',
#    'name': 'Hutong',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/E7M1H_1eb8g6UUuQWOSBDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hutong-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 336,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.761551, 'longitude': -73.967443},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '731 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['731 Lexington Ave', 'New York, NY 10022']},
#    'phone': '+12127584800',
#    'display_phone': '(212) 758-4800',
#    'distance': 6636.244354302038},
#   {'id': 'hNFe8WhCibrqT4sFcZmAgw',
#    'alias': 'kong-sihk-tong-港食堂-new-york',
#    'name': 'Kong Sihk Tong 港食堂',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lzxHYCybNvsZPtHcgGuNSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kong-sihk-tong-%E6%B8%AF%E9%A3%9F%E5%A0%82-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 364,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71542, 'longitude': -73.99813},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '65 Bayard St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['65 Bayard St', 'New York, NY 10013']},
#    'phone': '+16468506140',
#    'display_phone': '(646) 850-6140',
#    'distance': 1153.870812287678},
#   {'id': 's5JNxy0eAFgxS2Poi73ODw',
#    'alias': 'mala-project-new-york-4',
#    'name': 'Mala Project',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/s_0ndQTeEAmhygnLrdFy4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mala-project-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 394,
#    'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.756899, 'longitude': -73.980586},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '41 W 46th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41 W 46th St', 'New York, NY 10036']},
#    'phone': '+19172617520',
#    'display_phone': '(917) 261-7520',
#    'distance': 5840.2672450495475},
#   {'id': 'QQfwlKFD6X8-ZXf7gfQZqg',
#    'alias': 'hardee-new-york-4',
#    'name': 'Hardee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/w2rSwrMnLYsmVnlRcrZvrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hardee-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6933441162109,
#     'longitude': -73.9722290039062},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '351 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['351 Myrtle Ave', 'New York, NY 11205']},
#    'phone': '+13478897210',
#    'display_phone': '(347) 889-7210',
#    'distance': 2295.6999778208606},
#   {'id': 'v0opDMezc6pKgdfR22KUnQ',
#    'alias': 'da-tang-szechuan-new-york-2',
#    'name': 'Da Tang Szechuan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ByzWS78I4dlPB3U1HXVLDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-tang-szechuan-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 282,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75128, 'longitude': -73.98376},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '18 W 38th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18 W 38th St', 'New York, NY 10018']},
#    'phone': '+16464788345',
#    'display_phone': '(646) 478-8345',
#    'distance': 5165.776956800986},
#   {'id': 'ZCAkVl5SeCDeBWg_xjfYeg',
#    'alias': 'clay-pot-east-village-new-york-2',
#    'name': 'Clay Pot - East Village',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3sfoNZ7LD5w7X9EyWLZVyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clay-pot-east-village-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 317,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7279880270274,
#     'longitude': -73.9865907985248},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': "58 St Mark's Pl",
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ["58 St Mark's Pl", 'New York, NY 10003']},
#    'phone': '+16464346449',
#    'display_phone': '(646) 434-6449',
#    'distance': 2589.374386720123},
#   {'id': 'kBZggrnSP1kcUMnsnfkTaQ',
#    'alias': 'nan-xiang-xiao-long-bao-flushing',
#    'name': 'Nan Xiang Xiao Long Bao',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_swf0c4gtBCd1Yu9ExJABA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nan-xiang-xiao-long-bao-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3878,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'gourmet', 'title': 'Specialty Food'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75924, 'longitude': -73.8326},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '39-16 Prince St',
#     'address2': 'Ste 104',
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39-16 Prince St', 'Ste 104', 'Flushing, NY 11354']},
#    'phone': '+17183213838',
#    'display_phone': '(718) 321-3838',
#    'distance': 14900.419396964291},
#   {'id': 'mUl0wtO7tPkBocuJqZ-7Dw',
#    'alias': 'dun-huang-grand-central-new-york-4',
#    'name': 'Dun Huang -  Grand Central',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VLB4BQCJLUtSuf_SWYMXYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dun-huang-grand-central-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 221,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74922, 'longitude': -73.97785},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '320 Lexington Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['320 Lexington Ave', 'New York, NY 10016']},
#    'phone': '+16469644007',
#    'display_phone': '(646) 964-4007',
#    'distance': 5063.101360266531},
#   {'id': 'SyvC0s3y0ZrtnLbwnvw7tw',
#    'alias': 'tim-ho-wan-new-york-2',
#    'name': 'Tim Ho Wan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cH82hYN0kyGYThJc1ZWjzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tim-ho-wan-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1755,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.731338, 'longitude': -73.990145},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '85 4th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 4th Ave', 'New York, NY 10003']},
#    'phone': '+12122282800',
#    'display_phone': '(212) 228-2800',
#    'distance': 2900.3292896415205},
#   {'id': 'Dqp5Itsj9dN0Ewz8Gm853g',
#    'alias': 'philippe-downtown-new-york',
#    'name': 'Philippe Downtown',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/e6atiNKiK3fKUJMzziV7aQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/philippe-downtown-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 112,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74213, 'longitude': -74.0038},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '355 W 16th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['355 W 16th St', 'New York, NY 10011']},
#    'phone': '+12128859400',
#    'display_phone': '(212) 885-9400',
#    'distance': 4173.967332771831},
#   {'id': 'qFmyAqm0MQbdu_MHX1mhpQ',
#    'alias': 'oh-dumplings-brooklyn',
#    'name': 'Oh Dumplings',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7AE1zYl7xMKLQzzA8wFlhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oh-dumplings-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 100,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6875754, 'longitude': -73.9929996},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '6 Bergen St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6 Bergen St', 'Brooklyn, NY 11201']},
#    'phone': '+13477991237',
#    'display_phone': '(347) 799-1237',
#    'distance': 1985.4525357185491},
#   {'id': '0GftSP2dRwEzujkv2VKIgA',
#    'alias': 'wok-wok-southeast-asian-kitchen-new-york',
#    'name': 'Wok Wok Southeast Asian Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XOc7n_rq6kYGXySwasouRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wok-wok-southeast-asian-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1069,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7140555, 'longitude': -73.9988387116394},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '11 Mott St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 Mott St', 'New York, NY 10013']},
#    'phone': '+19173883627',
#    'display_phone': '(917) 388-3627',
#    'distance': 1031.2690925773445},
#   {'id': 'U74_3F7r3tMhd6dmTmDBxQ',
#    'alias': 'macao-trading-company-new-york',
#    'name': 'Macao Trading Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EY5hMnXAFZpZcISNvOEymQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/macao-trading-company-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 766,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'portuguese', 'title': 'Portuguese'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.719623, 'longitude': -74.003904},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '311 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['311 Church St', 'New York, NY 10013']},
#    'phone': '+12124318750',
#    'display_phone': '(212) 431-8750',
#    'distance': 1774.0795207044496},
#   {'id': 'QO4Xm2VrG2PEHXVMPrf7Sw',
#    'alias': 'sanshi-rice-noodle-new-york',
#    'name': 'Sanshi Rice Noodle',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tx6Ok9ci2nLOxcv-_9MKyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sanshi-rice-noodle-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.727979, 'longitude': -73.987761},
#    'transactions': ['delivery'],
#    'location': {'address1': '118 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['118 2nd Ave', 'New York, NY 10003']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2564.7034581200182},
#   {'id': 'dDXtga5Kgo5B1twdezcZJA',
#    'alias': 'auntie-guans-kitchen-108-new-york',
#    'name': "Auntie Guan's Kitchen 108",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FBxjWFECyQ89qtExjlzdvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auntie-guans-kitchen-108-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 353,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7377213477598,
#     'longitude': -73.9974148512518},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '108 W 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['108 W 14th St', 'New York, NY 10011']},
#    'phone': '+12122068388',
#    'display_phone': '(212) 206-8388',
#    'distance': 3598.605789455146},
#   {'id': 'ye-TSU-mu1Gd5TAJOpI5Mg',
#    'alias': 'lichee-nut-brooklyn-2',
#    'name': 'Lichee Nut',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/K_3mRRBRwFrdL8hfhDlYXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lichee-nut-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 272,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.694149, 'longitude': -73.9928131},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '162 Montague St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 Montague St', 'Brooklyn, NY 11201']},
#    'phone': '+17185225565',
#    'display_phone': '(718) 522-5565',
#    'distance': 1257.7122862074825},
#   {'id': '9HD5HQiTkURkx5i7hL92EA',
#    'alias': 'spicy-moon-west-village-new-york-2',
#    'name': 'Spicy Moon West Village',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/O38BGgFpTJ-1e7_lwjgDEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spicy-moon-west-village-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 145,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.729318, 'longitude': -73.99832},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '68 W 3rd St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['68 W 3rd St', 'New York, NY 10012']},
#    'phone': '+16465901390',
#    'display_phone': '(646) 590-1390',
#    'distance': 2680.4189944043897}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#              Restaurant          Type Price Rating            Address  \
# 0               Baodega  Shanghainese    $$      4        7 W 20th St
# 1               3 Times       Dim Sum    $$      4       818 Broadway
# 2  Chong Qing Xiao Mian       Chinese    $$      4        796 9th Ave
# 3    Xi'an Famous Foods       Chinese    $$      4  648 Manhattan Ave
# 4          Rim Nam Thai          Thai                       52 Jay St
#
#          Lat        Lng                                                url  \
# 0  40.740140 -73.991780  https://www.yelp.com/biz/baodega-new-york?adju...
# 1  40.732850 -73.991040  https://www.yelp.com/biz/3-times-new-york-6?ad...
# 2  40.765130 -73.987530  https://www.yelp.com/biz/chong-qing-xiao-mian-...
# 3  40.724330 -73.950930  https://www.yelp.com/biz/xian-famous-foods-bro...
# 4  40.703367 -73.986889
#
#                        ID
# 0  3oB2_2vpeIyxJt1GvlcZBA
# 1  62Kedrco374IuZ_OFb0BxA
# 2  lQ8Fzgji9qmgRXkFcvAsVQ
# 3  AfF4zVbVI27zwgkzOLYDFg
# 4

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"chinese","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': 'pBNMZp_tKCAfRNx7-ybcHQ',
#    'alias': 'calle-dao-chelsea-new-york',
#    'name': 'Calle Dao - Chelsea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/135HuozBP6evKZQGjH3wpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/calle-dao-chelsea-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 796,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74769301, 'longitude': -74.00350737},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '461 W 23rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['461 W 23rd St', 'New York, NY 10011']},
#    'phone': '+12124144104',
#    'display_phone': '(212) 414-4104',
#    'distance': 4761.507725279524},
#   {'id': '9b_FvTUgkkUUMyL0nGhFtg',
#    'alias': 'three-roosters-new-york',
#    'name': 'Three Roosters',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RZJDNAXD9ATfNk5ErLSLVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/three-roosters-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 79,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.764957, 'longitude': -73.987485},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '792 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['792 9th Ave', 'New York, NY 10019']},
#    'phone': '+19172614055',
#    'display_phone': '(917) 261-4055',
#    'distance': 6640.475059154251},
#   {'id': 'QFOYvQK9y2jM7ue-DXkw2g',
#    'alias': 'family-garden-brooklyn-2',
#    'name': 'Family Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QM2At-gzb1NDyTzhcihxKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/family-garden-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.635335, 'longitude': -73.960987},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1709 Foster Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11230',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1709 Foster Ave', 'Brooklyn, NY 11230']},
#    'phone': '+17188592738',
#    'display_phone': '(718) 859-2738',
#    'distance': 8290.183822402385},
#   {'id': 'LT0yyLNM84EiJj9DL0rfHA',
#    'alias': 'hui-restaurant-and-bar-new-york',
#    'name': 'Hui Restaurant & Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/G1q-ohhwhrJwx8z5k7JQXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hui-restaurant-and-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 197,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76701, 'longitude': -73.95846},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '314 E 70th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['314 E 70th St', 'New York, NY 10021']},
#    'phone': '+16468690339',
#    'display_phone': '(646) 869-0339',
#    'distance': 7471.247192255624},
#   {'id': 'PGeL1b4xNJggpZsHEGoxjg',
#    'alias': 'mr-chow-new-york-2',
#    'name': 'Mr Chow',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/I7_r8g13tqyGJJDF2klsMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-chow-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 403,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7201045, 'longitude': -74.0087721},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '121 Hudson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['121 Hudson St', 'New York, NY 10013']},
#    'phone': '+12129659500',
#    'display_phone': '(212) 965-9500',
#    'distance': 2050.4302622394007},
#   {'id': 'a93NwZxjkPQydJxR42oPyg',
#    'alias': 'grain-house-new-york-2',
#    'name': 'Grain House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-_OQR9v9ucrb0KooLELC_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grain-house-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 103,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.800127673827,
#     'longitude': -73.9657538384199},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '929 Amsterdam Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['929 Amsterdam Ave', 'New York, NY 10025']},
#    'phone': '+12125311130',
#    'display_phone': '(212) 531-1130',
#    'distance': 10799.206952977489},
#   {'id': 'TzhAlljC_843JO7UDDUIaQ',
#    'alias': 'the-tang-upper-west-side-new-york',
#    'name': 'The Tang - Upper West Side',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/e1b-BU1Dz6rXbmMg5D1sFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-tang-upper-west-side-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 233,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.80006, 'longitude': -73.96639},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '920 Amsterdam Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['920 Amsterdam Ave', 'New York, NY 10025']},
#    'phone': '+16465967970',
#    'display_phone': '(646) 596-7970',
#    'distance': 10771.864416955908},
#   {'id': '5TnBfeoBpxPPwIXMGBMasg',
#    'alias': 'new-double-dragon-new-york-3',
#    'name': 'New Double Dragon',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/azgyfv7_Fk_MnjXnHnFYYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-double-dragon-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 101,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7242, 'longitude': -73.98801},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '37 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37 1st Ave', 'New York, NY 10003']},
#    'phone': '+12125980730',
#    'display_phone': '(212) 598-0730',
#    'distance': 2152.468623745747},
#   {'id': '5rX_7IkvFx5MKqS3ikQe3Q',
#    'alias': 'fortune-house-brooklyn',
#    'name': 'Fortune House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8rr_B4pmTOyeoyALO6u4Fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fortune-house-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 125,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.698455, 'longitude': -73.992805},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '82 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['82 Henry St', 'Brooklyn, NY 11201']},
#    'phone': '+17188557055',
#    'display_phone': '(718) 855-7055',
#    'distance': 784.6717442285465},
#   {'id': 'q2bIyvU8CQwiB6xe_iVs0g',
#    'alias': 'fan-fried-rice-bar-brooklyn-2',
#    'name': 'Fan Fried Rice Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HGcN7WIU9tIVmsCIbnoNmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fan-fried-rice-bar-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 88,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69099, 'longitude': -73.95587},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '525 Dekalb Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['525 Dekalb Ave', 'Brooklyn, NY 11205']},
#    'phone': '+19292902197',
#    'display_phone': '(929) 290-2197',
#    'distance': 3612.2739701769797},
#   {'id': 'Xf6e3HaP0AgMBxY7dEDkOA',
#    'alias': '99-favor-taste-new-york-12',
#    'name': '99 Favor Taste',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9gFktkHItuyectWnoi1Mbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/99-favor-taste-new-york-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1935,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7176199, 'longitude': -73.99249},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '285 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['285 Grand St', 'New York, NY 10002']},
#    'phone': '+16466829162',
#    'display_phone': '(646) 682-9162',
#    'distance': 1348.6324758108813},
#   {'id': '-KfM32STVYND4v_9l1YRug',
#    'alias': 'xian-famous-foods-brooklyn-10',
#    'name': "Xi'an Famous Foods",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Djkd5Zs5o1COjR0_TYLocw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/xian-famous-foods-brooklyn-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 61,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69212, 'longitude': -73.9867},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '54 Willoughby St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['54 Willoughby St', 'Brooklyn, NY 11201']},
#    'phone': '+12127862068',
#    'display_phone': '(212) 786-2068',
#    'distance': 1617.9575068235206},
#   {'id': 'WIj12zDqIbBucW1hXYhrew',
#    'alias': 'kings-kitchen-new-york-4',
#    'name': "King's Kitchen",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nX62xRkvxQspFRnAGkTgEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kings-kitchen-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 287,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71399, 'longitude': -73.99367},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '92 E Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['92 E Broadway', 'New York, NY 10002']},
#    'phone': '+12129667288',
#    'display_phone': '(212) 966-7288',
#    'distance': 951.0543163804169},
#   {'id': 'E7q1Qf6380N_aMqz28EgNw',
#    'alias': 'duckedup-new-york',
#    'name': 'Duckedup',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/E7w7vUuZllu0DGF0rLApcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duckedup-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7205, 'longitude': -73.98826},
#    'transactions': [],
#    'location': {'address1': '139 Ludlow St',
#     'address2': 'Ludlow House',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['139 Ludlow St',
#      'Ludlow House',
#      'New York, NY 10002']},
#    'phone': '+16462536100',
#    'display_phone': '(646) 253-6100',
#    'distance': 1750.6418728303915},
#   {'id': 'Dqu-5RxNbbpBsL1Ssht9Ng',
#    'alias': 'hunan-slurp-new-york-2',
#    'name': 'Hunan Slurp',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IGmf-AwM7x5VLX-EL1C0lA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hunan-slurp-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 230,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72669, 'longitude': -73.98563},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '112 1st Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['112 1st Ave', 'New York, NY 10009']},
#    'phone': '+16465859585',
#    'display_phone': '(646) 585-9585',
#    'distance': 2472.6807344111503},
#   {'id': 'fa5a7jksUak7yleWLWMigg',
#    'alias': 'joe-s-steam-rice-roll-new-york-2',
#    'name': 'Joe’s Steam Rice Roll',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kSXgXjEUBHH0rWIQ9awkRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joe-s-steam-rice-roll-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 343,
#    'categories': [{'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'},
#     {'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7190194496717,
#     'longitude': -74.0008207038045},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '261 Canal St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['261 Canal St', 'New York, NY 10013']},
#    'phone': '+17188780828',
#    'display_phone': '(718) 878-0828',
#    'distance': 1606.563472066166},
#   {'id': 'MdDj13LgIs0WdbIdiyqB7Q',
#    'alias': 'pinch-chinese-new-york-2',
#    'name': 'Pinch Chinese',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5YkuAzXSx9HrzNmuvfxAxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pinch-chinese-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 386,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72645222833495,
#     'longitude': -74.0017973317552},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '177 Prince St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['177 Prince St', 'New York, NY 10012']},
#    'phone': '+12123287880',
#    'display_phone': '(212) 328-7880',
#    'distance': 2420.013921886496},
#   {'id': 'KSleHGTG1yL1E7OEFFPoNQ',
#    'alias': 'laoma-spicy-new-york-2',
#    'name': 'LaoMa Spicy',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OyQ08hJ1585APtxfmRMdkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laoma-spicy-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 199,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73089, 'longitude': -73.99343},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '58 E 8th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['58 E 8th St', 'New York, NY 10003']},
#    'phone': '+12127771661',
#    'display_phone': '(212) 777-1661',
#    'distance': 2831.035668524085},
#   {'id': 'DmTz35KvxO20mH-pJxLNpg',
#    'alias': 'xian-famous-foods-new-york-40',
#    'name': "Xi'an Famous Foods",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dlzBo-oN-BUBVQGOKyMHmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/xian-famous-foods-new-york-40?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.740203, 'longitude': -74.001963},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '96 8th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['96 8th Ave', 'New York, NY 10011']},
#    'phone': '+12127862068',
#    'display_phone': '(212) 786-2068',
#    'distance': 3913.4432507006936},
#   {'id': 'zPK48x2wvTmJTQ_13bbeRQ',
#    'alias': 'hong-kong-cafe-brooklyn',
#    'name': 'Hong Kong Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GjkOZg5a-dFnv3FdnoMuOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hong-kong-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.687267, 'longitude': -73.95667},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '357 Franklin Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['357 Franklin Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17187833838',
#    'display_phone': '(718) 783-3838',
#    'distance': 3761.1318153897237},
#   {'id': 'i4cyV13lYIS4mcJKZW75cA',
#    'alias': 'food-sing-brooklyn',
#    'name': 'Food Sing',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iVESWhgI3gshlu05WYofvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/food-sing-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.714324, 'longitude': -73.961257},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '172 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['172 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17187827596',
#    'display_phone': '(718) 782-7596',
#    'distance': 2953.0516148547445},
#   {'id': 'oJjMYhA6z1_BVaQpSdyl8g',
#    'alias': 'golden-forest-new-york',
#    'name': 'Golden Forest',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EXILCcE6E7_w0wKUzq0N_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/golden-forest-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 193,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7167, 'longitude': -73.98945},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '353 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['353 Grand St', 'New York, NY 10002']},
#    'phone': '+12125059513',
#    'display_phone': '(212) 505-9513',
#    'distance': 1315.4876609371609},
#   {'id': 'l7G5tDA96xbA_bx1ZgkOeg',
#    'alias': 'ichiran-midtown-new-york',
#    'name': 'ICHIRAN Midtown',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MaYsFXRKL4Zy5wY9R6GfMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ichiran-midtown-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 938,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74839, 'longitude': -73.99062},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '132 W 31st St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['132 W 31st St', 'New York, NY 10001']},
#    'phone': '+12124650701',
#    'display_phone': '(212) 465-0701',
#    'distance': 4785.297070086241},
#   {'id': '53lgp8fFEuK3Yo7yeXc89A',
#    'alias': 'tim-ho-wan-hells-kitchen-new-york-2',
#    'name': "Tim Ho Wan - Hell's Kitchen",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TcanxIts0R1DwmSYWa2Y3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tim-ho-wan-hells-kitchen-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 444,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.75935, 'longitude': -73.99175},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '610 9th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['610 9th Ave', 'New York, NY 10036']},
#    'phone': '+12122282802',
#    'display_phone': '(212) 228-2802',
#    'distance': 5990.725578704439},
#   {'id': 'ynIx549QFj29o84y1RSGyw',
#    'alias': 'bao-bao-cafe-new-york-2',
#    'name': 'Bao Bao Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iEEU_Xu1duVjO7Le9jVhPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bao-bao-cafe-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 482,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.740829, 'longitude': -73.983474},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '61 Lexington Ave',
#     'address2': 'Unit B',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['61 Lexington Ave', 'Unit B', 'New York, NY 10010']},
#    'phone': '+19173882479',
#    'display_phone': '(917) 388-2479',
#    'distance': 4040.2833194223813},
#   {'id': '3fQ9IExhN9KMqGHVm_9AEQ',
#    'alias': 'wing-cheong-restaurant-brooklyn',
#    'name': 'Wing Cheong Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ltk3VNIJea8LPme6-uMA7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wing-cheong-restaurant-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.680375, 'longitude': -73.945514},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1389 Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1389 Fulton St', 'Brooklyn, NY 11216']},
#    'phone': '+17186224720',
#    'display_phone': '(718) 622-4720',
#    'distance': 4966.27877977335},
#   {'id': 'jXL7zCeuhZnQVei5rfq7qw',
#    'alias': 'the-braised-shop-new-york',
#    'name': 'The Braised Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RzBMa6fPhG37-uvfKlUToQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-braised-shop-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 93,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7289533, 'longitude': -73.9845},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '241 E 10th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['241 E 10th St', 'New York, NY 10003']},
#    'phone': '+16468633200',
#    'display_phone': '(646) 863-3200',
#    'distance': 2742.5457992585307},
#   {'id': 'oD0mN9vXuc1gFRyw1CG-Pw',
#    'alias': 'new-china-wok-chinese-kitchen-brooklyn-2',
#    'name': 'New China Wok Chinese Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/d8R-FChyFg8_2OwvB9lK5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-china-wok-chinese-kitchen-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68257, 'longitude': -73.97927},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '57 4th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['57 4th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17186381898',
#    'display_phone': '(718) 638-1898',
#    'distance': 2835.3013451118027},
#   {'id': 'qEe7nIhPfEL6L0-VYhWRrA',
#    'alias': 'raku-new-york-6',
#    'name': 'Raku',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EQsQlLlKQjziOrGsEblCbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raku-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 534,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72728, 'longitude': -74.00252},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '48 Macdougal St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['48 Macdougal St', 'New York, NY 10012']},
#    'phone': '+12129894797',
#    'display_phone': '(212) 989-4797',
#    'distance': 2522.2670460297},
#   {'id': '7erFgHiQmw7ZJfVPmOjeeA',
#    'alias': 'm-shanghai-bistro-and-garden-brooklyn',
#    'name': 'M Shanghai Bistro & Garden',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rqEPIt72fMdH1lDCVkf9Jg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/m-shanghai-bistro-and-garden-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 435,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71293, 'longitude': -73.95757},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '292 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['292 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17183849300',
#    'display_phone': '(718) 384-9300',
#    'distance': 3199.4191821443387},
#   {'id': 'lKxmH-hQ6ezKbq4URKrd-Q',
#    'alias': 'may-wah-fast-food-new-york-3',
#    'name': 'May Wah Fast Food',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-yXFJdbLspki2pqG-eeKgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/may-wah-fast-food-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 368,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'taiwanese', 'title': 'Taiwanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71825, 'longitude': -73.99842},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '190 Hester St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['190 Hester St', 'New York, NY 10013']},
#    'phone': '+12129256428',
#    'display_phone': '(212) 925-6428',
#    'distance': 1461.001694287333},
#   {'id': 'YzyHW3w0HUyaG8EvplNT1A',
#    'alias': 'lius-shanghai-brooklyn-2',
#    'name': "Liu's Shanghai",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9mrTfDfCFSytiutwOt7AAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lius-shanghai-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 404,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6026411895768,
#     'longitude': -74.0038766549142},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1869 Bath Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1869 Bath Ave', 'Brooklyn, NY 11214']},
#    'phone': '+17182566868',
#    'display_phone': '(718) 256-6868',
#    'distance': 11459.78647653601},
#   {'id': '6wJOojpF2c4lLeBNbTBB0A',
#    'alias': 'baoburg-brooklyn-2',
#    'name': 'Baoburg',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dKj992_3gxwfLizCVFBCUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baoburg-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 270,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7234929271998,
#     'longitude': -73.9503321851175},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '614 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['614 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183490011',
#    'display_phone': '(718) 349-0011',
#    'distance': 4213.725334102182},
#   {'id': 'tfMPbnQqJ1P1RIab-o6gtg',
#    'alias': 'kum-kau-brooklyn',
#    'name': 'Kum Kau',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xnlCeIGQnJgDsq1wJDJwcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kum-kau-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 268,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.693573, 'longitude': -73.966702},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '465 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['465 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17186381850',
#    'display_phone': '(718) 638-1850',
#    'distance': 2674.4693830954993},
#   {'id': '54om5q7V4anmIXw2PdNJbA',
#    'alias': 'chens-buffet-bar-new-york',
#    'name': "Chen's Buffet Bar",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AvG4SNaldEDw8iayYc_wbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chens-buffet-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70712, 'longitude': -74.00845},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '32 Cedar St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 Cedar St', 'New York, NY 10038']},
#    'phone': '+12127979477',
#    'display_phone': '(212) 797-9477',
#    'distance': 1203.02167456842},
#   {'id': 'GIHPA9UylksLNx-5jQVVVA',
#    'alias': 'season-taste-new-york',
#    'name': 'Season Taste',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4rjqzTQ3SFUyBuovnbSbxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/season-taste-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74304, 'longitude': -73.99619},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '197 7th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['197 7th Ave', 'New York, NY 10011']},
#    'phone': '+16466784474',
#    'display_phone': '(646) 678-4474',
#    'distance': 4184.200617396369},
#   {'id': 'VW2Epq3C8jqysu6Edpu-RA',
#    'alias': 'atlas-kitchen-new-york',
#    'name': 'Atlas Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uRbFq0fflOohLJT82KgR4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/atlas-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 124,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.80332, 'longitude': -73.9668},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '258 W 109th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['258 W 109th St', 'New York, NY 10025']},
#    'phone': '+16469280522',
#    'display_phone': '(646) 928-0522',
#    'distance': 11115.116547961194},
#   {'id': 'UiBQ8Uyu4wfOtEM1Rr8ycA',
#    'alias': 'shanghai-asian-cuisine-new-york-2',
#    'name': 'Shanghai Asian Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GTWDjv0-tTtQawd_ghvrSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shanghai-asian-cuisine-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 532,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7159077, 'longitude': -73.997383},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '14A Elizabeth St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14A Elizabeth St', 'New York, NY 10013']},
#    'phone': '+12129645640',
#    'display_phone': '(212) 964-5640',
#    'distance': 1192.205105933742},
#   {'id': 'DNSFvZtdsqkaidmFSpm-Jw',
#    'alias': 'soba-noodle-azuma-new-york-3',
#    'name': 'Soba Noodle Azuma',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NYDhgDn4a2Bb3dUNvA3fng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soba-noodle-azuma-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 317,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76526, 'longitude': -73.9832},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '251 W 55th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['251 W 55th St', 'New York, NY 10019']},
#    'phone': '+19172620540',
#    'display_phone': '(917) 262-0540',
#    'distance': 6721.596374906867},
#   {'id': 'Pr-q47vsmM4aoc2t_Sfk8w',
#    'alias': 'momofuku-noodle-bar-uptown-new-york',
#    'name': 'Momofuku Noodle Bar - Uptown',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/h08ukV9YwJXhQBT2kvCCIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/momofuku-noodle-bar-uptown-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 351,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76847, 'longitude': -73.983092},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10 Columbus Cir',
#     'address2': 'Third Floor',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10 Columbus Cir',
#      'Third Floor',
#      'New York, NY 10019']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 7079.371546056122},
#   {'id': '1jAB_uaI8-P_wSqOo2S3KQ',
#    'alias': 'mazu-szechuan-new-york',
#    'name': 'Mazu Szechuan',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8cFEkh35jpLEJ7YNM1uOkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mazu-szechuan-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.745234, 'longitude': -73.97812},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'location': {'address1': '495 3rd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['495 3rd Ave', 'New York, NY 10016']},
#    'phone': '+16466093388',
#    'display_phone': '(646) 609-3388',
#    'distance': 4631.441786014258},
#   {'id': '95bPhynOQ4bHoUqJJv6UEQ',
#    'alias': 'crop-circle-new-york',
#    'name': 'Crop Circle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IG0TKWisoqzOy2Z3hwE9tQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crop-circle-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 85,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73003, 'longitude': -74.00034},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '126 MacDougal St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['126 MacDougal St', 'New York, NY 10012']},
#    'phone': '+19174091666',
#    'display_phone': '(917) 409-1666',
#    'distance': 2769.9026618528856},
#   {'id': 'Lp8vAE5nHSt5zbu-lSGK8A',
#    'alias': 'hop-lee-restaurant-new-york',
#    'name': 'Hop Lee Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZUXrOpU1LhYOsToo8mk5fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hop-lee-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 329,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71426, 'longitude': -73.99849},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '16 Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['16 Mott St', 'New York, NY 10013']},
#    'phone': '+12129626475',
#    'display_phone': '(212) 962-6475',
#    'distance': 1039.1711856890965},
#   {'id': 'LztkKM-lvRraBbS9TVXzcg',
#    'alias': 'yiwanmen-new-york-2',
#    'name': 'Yiwanmen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/34rPXHr5Pkj3nb-h6qRgXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yiwanmen-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 164,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7193132739237,
#     'longitude': -73.9962630421457},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '150 Mott St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 Mott St', 'New York, NY 10013']},
#    'phone': '+12129668998',
#    'display_phone': '(212) 966-8998',
#    'distance': 1551.0068101721004},
#   {'id': 'zYoL-o9YJpGTwJ-Gmj8AFA',
#    'alias': 'jue-lan-club-new-york-3',
#    'name': 'Jue Lan Club',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VtozXw_ViGEYV3x26QXRjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jue-lan-club-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 589,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7409694, 'longitude': -73.9934031},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '49 W 20th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['49 W 20th St', 'New York, NY 10011']},
#    'phone': '+16465247409',
#    'display_phone': '(646) 524-7409',
#    'distance': 3950.85588600907},
#   {'id': 'NgY0RmhbpgAYb5t1jWT3OA',
#    'alias': 'yaso-new-york',
#    'name': 'Yaso',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sLA8VwIjGEuRD8O6ahA55w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yaso-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.730208, 'longitude': -73.994044},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '289 Mercer St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['289 Mercer St', 'New York, NY 10003']},
#    'phone': '+19175221600',
#    'display_phone': '(917) 522-1600',
#    'distance': 2756.0275354048777},
#   {'id': 'pb_cHcy8D8UC-jQ-Q524ug',
#    'alias': 'som-bo-new-york-2',
#    'name': 'Som Bo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/usAdZvJQKR90DnlJszwM5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/som-bo-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 243,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74192, 'longitude': -74.00136},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '143 8th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['143 8th Ave', 'New York, NY 10011']},
#    'phone': '+19172617947',
#    'display_phone': '(917) 261-7947',
#    'distance': 4094.9410633565935},
#   {'id': 'ZaJS8EKQNSaQpwpmgN-vVw',
#    'alias': 'samurai-mama-brooklyn',
#    'name': 'Samurai Mama',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iU4mCy9pszj-Kx3WzcAXQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/samurai-mama-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 612,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7140208838114,
#     'longitude': -73.960325717926},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '205 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['205 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17185996161',
#    'display_phone': '(718) 599-6161',
#    'distance': 3017.69647092549},
#   {'id': 'k34VgKhpuIRPEr8vKSMwjA',
#    'alias': 'chung-chun-kitchen-brooklyn-2',
#    'name': 'Chung Chun Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vbWEXTRI7BLcps8IyqdCCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chung-chun-kitchen-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.69314, 'longitude': -73.973},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '338 Myrtle Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['338 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17188552119',
#    'display_phone': '(718) 855-2119',
#    'distance': 2257.2892324389704},
#   {'id': 'qH8PVeddtVs9cKN2pwgdkQ',
#    'alias': 'hwa-yuan-new-york-2',
#    'name': 'Hwa Yuan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FUlrT0L-7WXks3aqekdAhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hwa-yuan-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 344,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7137, 'longitude': -73.99598},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '42 E Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 E Broadway', 'New York, NY 10002']},
#    'phone': '+12129666002',
#    'display_phone': '(212) 966-6002',
#    'distance': 936.1140589682508}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#              Restaurant     Type Price Rating          Address        Lat  \
# 0   Calle Dao - Chelsea    Cuban    $$    4.5    461 W 23rd St  40.747693
# 1        Three Roosters     Thai    $$      5      792 9th Ave  40.764957
# 2         Family Garden  Chinese     $      4  1709 Foster Ave  40.635335
# 3  Hui Restaurant & Bar     Bars    $$    4.5    314 E 70th St  40.767010
# 4               Mr Chow  Chinese  $$$$      3    121 Hudson St  40.720104
#
#          Lng                                                url  \
# 0 -74.003507  https://www.yelp.com/biz/calle-dao-chelsea-new...
# 1 -73.987485  https://www.yelp.com/biz/three-roosters-new-yo...
# 2 -73.960987  https://www.yelp.com/biz/family-garden-brookly...
# 3 -73.958460  https://www.yelp.com/biz/hui-restaurant-and-ba...
# 4 -74.008772  https://www.yelp.com/biz/mr-chow-new-york-2?ad...
#
#                        ID
# 0  pBNMZp_tKCAfRNx7-ybcHQ
# 1  9b_FvTUgkkUUMyL0nGhFtg
# 2  QFOYvQK9y2jM7ue-DXkw2g
# 3  LT0yyLNM84EiJj9DL0rfHA
# 4  PGeL1b4xNJggpZsHEGoxjg

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"chinese","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [{'id': 'H1jops1lmuhrq9lP7lEGJQ',
#    'alias': 'flor-de-mayo-new-york-2',
#    'name': 'Flor De Mayo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/upMdi6U9mtbpAxkbl5ikdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flor-de-mayo-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1229,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78609, 'longitude': -73.97658},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '484 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['484 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12127873388',
#    'display_phone': '(212) 787-3388',
#    'distance': 9088.843494696126},
#   {'id': 'h0pRCiJDrCN7tm3VX5tILQ',
#    'alias': 'chili-new-york',
#    'name': 'CHILI',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_ZzHcUnvrG-ezxyfeRtFXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chili-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.75002, 'longitude': -73.98215},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '13 E 37th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['13 E 37th St', 'New York, NY 10016']},
#    'phone': '+16468820666',
#    'display_phone': '(646) 882-0666',
#    'distance': 5073.982572446933},
#   {'id': '6KWuxjK1ey72cW8LVuoV5A',
#    'alias': 'mr-bao-new-york',
#    'name': 'Mr Bao',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dAiE_zyIBI5YbdgmMFycjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-bao-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.717057, 'longitude': -73.958764},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '208 Bedford Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['208 Bedford Ave', 'New York, NY 11249']},
#    'phone': '+17183888898',
#    'display_phone': '(718) 388-8898',
#    'distance': 3260.675009361085},
#   {'id': 'tDYk6DmmU3buWBs9G0NBXQ',
#    'alias': 'china-restaurant-brooklyn',
#    'name': 'China Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C6gLjRwYJEIVJQOVtFBkYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/china-restaurant-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 71,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.650260925293, 'longitude': -73.929931640625},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '937 Utica Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11203',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['937 Utica Ave', 'Brooklyn, NY 11203']},
#    'phone': '+17184985108',
#    'display_phone': '(718) 498-5108',
#    'distance': 8193.117582448549},
#   {'id': 'XaEFFUabnbH8ZF7ccmSAlQ',
#    'alias': 'south-of-the-clouds-new-york',
#    'name': 'South Of The Clouds',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jWhMlWF_alK1D0hd9OBAVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/south-of-the-clouds-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 229,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73264, 'longitude': -73.99752},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '16 W 8th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['16 W 8th St', 'New York, NY 10011']},
#    'phone': '+12128889653',
#    'display_phone': '(212) 888-9653',
#    'distance': 3029.5752880920404},
#   {'id': 'GGRMY-twaqZf_NIAprBJkg',
#    'alias': 'junzi-kitchen-new-york-11',
#    'name': 'Junzi Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ADyIaKqdicH_HfvxqcWOiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/junzi-kitchen-new-york-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 139,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.754886, 'longitude': -73.985688},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '135 W 41st St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['135 W 41st St', 'New York, NY 10036']},
#    'phone': '+16466698228',
#    'display_phone': '(646) 669-8228',
#    'distance': 5547.8034432908335},
#   {'id': 'BPErPpKSNluwcjbKRgze3w',
#    'alias': 'xian-famous-foods-new-york-38',
#    'name': "Xi'an Famous Foods",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AoVpH7TNbgptZZUc1e6K_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/xian-famous-foods-new-york-38?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 572,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77197, 'longitude': -73.95452},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '328 E 78th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['328 E 78th St', 'New York, NY 10075']},
#    'phone': '+12127862068',
#    'display_phone': '(212) 786-2068',
#    'distance': 8122.343683975649},
#   {'id': 'a52GUjv7jYD3Baa0Ltbytw',
#    'alias': 'golden-dragon-kitchen-brooklyn',
#    'name': 'Golden Dragon Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/faLEtaklj6Xp5ZmIL2xaAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/golden-dragon-kitchen-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7139499, 'longitude': -73.95519},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '394 Metropolitan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['394 Metropolitan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17187828024',
#    'display_phone': '(718) 782-8024',
#    'distance': 3426.9479367417493},
#   {'id': 'aZMVSzm1ypJOkRsLVaMUVA',
#    'alias': 'new-chin-chin-wu-restaurant-brooklyn',
#    'name': 'New Chin Chin Wu Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3kemehA5bf2936Ehp2YgoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-chin-chin-wu-restaurant-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.64904, 'longitude': -73.96446},
#    'transactions': [],
#    'location': {'address1': '1615 Church Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11226',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1615 Church Ave', 'Brooklyn, NY 11226']},
#    'phone': '+17188568656',
#    'display_phone': '(718) 856-8656',
#    'distance': 6754.291450378761},
#   {'id': 'WRPJeH3goSpj5ke3Pkrnfw',
#    'alias': 'burp-bowl-cafe-new-york-6',
#    'name': 'Burp Bowl Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T2CkeYLqyTAdWoZog30qkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burp-bowl-cafe-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 244,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74183, 'longitude': -73.98271},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '134 E 27th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['134 E 27th St', 'New York, NY 10010']},
#    'phone': '+19292616643',
#    'display_phone': '(929) 261-6643',
#    'distance': 4158.653651946488},
#   {'id': 'UNyGz06_7RendbswIyNYtA',
#    'alias': 'shu-han-ju-new-york-2',
#    'name': 'Shu Han Ju',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r3BEZ4IRvdFyrgZ2RnQS4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shu-han-ju-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 178,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73558, 'longitude': -73.99843},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '465 6th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['465 6th Ave', 'New York, NY 10011']},
#    'phone': '+12124288800',
#    'display_phone': '(212) 428-8800',
#    'distance': 3371.4257513533744},
#   {'id': 'wo7-TKh4B37RTBjPNtkp7w',
#    'alias': 'chengdu1-jersey-city',
#    'name': 'Chengdu1',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vvA1eDVpEx2r-JMCCoQscQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chengdu1-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 103,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7323552298113,
#     'longitude': -74.039612951068},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '166 15th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Jersey City',
#     'zip_code': '07310',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['166 15th St', 'Jersey City, NJ 07310']},
#    'phone': '+12014599988',
#    'display_phone': '(201) 459-9988',
#    'distance': 4851.9694160989975},
#   {'id': '1YGpTYD8xIuUpK_beMhzSw',
#    'alias': 'the-rice-noodle-new-york',
#    'name': 'The Rice Noodle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/C_msLHZwf3LL38codvU52w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-rice-noodle-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 141,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729087, 'longitude': -74.001525},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '190 Bleecker St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['190 Bleecker St', 'New York, NY 10012']},
#    'phone': '+16468959908',
#    'display_phone': '(646) 895-9908',
#    'distance': 2693.437152882534},
#   {'id': 'Bwj7nzWphGV6FaZ_ygTSOg',
#    'alias': 'happy-hot-hunan-new-york',
#    'name': 'Happy Hot Hunan',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KdNwH8eZBvsTgAWK37YTeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/happy-hot-hunan-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 169,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.80133, 'longitude': -73.96466},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '969 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['969 Amsterdam Ave', 'New York, NY 10025']},
#    'phone': '+12125311788',
#    'display_phone': '(212) 531-1788',
#    'distance': 10952.109906500982},
#   {'id': '-2FAuHbWsc_rxuSaeYAhCw',
#    'alias': 'green-garden-village-new-york-3',
#    'name': 'Green Garden Village',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/h07C-1IJWqb9jcPxx_5xlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/green-garden-village-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 71,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7190136, 'longitude': -73.9959638},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '216 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['216 Grand St', 'New York, NY 10013']},
#    'phone': '+16469129136',
#    'display_phone': '(646) 912-9136',
#    'distance': 1519.8190680790055},
#   {'id': 'NN3mOWF5e_pnR1ArqM2bHQ',
#    'alias': 'obao-new-york-3',
#    'name': 'OBAO',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CpVI2XJLrvg09Fm83bfPog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/obao-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2751,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7606544, 'longitude': -73.991332},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '647 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['647 9th Ave', 'New York, NY 10036']},
#    'phone': '+12122458880',
#    'display_phone': '(212) 245-8880',
#    'distance': 6144.081737145313},
#   {'id': 'PQSrlPW8BGZr8AsgCxVcWQ',
#    'alias': 'weng-garden-brooklyn',
#    'name': 'Weng Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y_L7X5jTur23kDL9t6mVaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/weng-garden-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.685707, 'longitude': -73.920722},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '872 Hancock St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['872 Hancock St', 'Brooklyn, NY 11233']},
#    'phone': '+17185748979',
#    'display_phone': '(718) 574-8979',
#    'distance': 6582.915975321236},
#   {'id': 'F2KRHRtnIAZJezs9UC2u6w',
#    'alias': 'chelsea-golden-wok-new-york',
#    'name': 'Chelsea Golden Wok',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UWZTCWEXvOx1fQAHzKSMdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chelsea-golden-wok-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 62,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.74401, 'longitude': -73.999824},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '209 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['209 8th Ave', 'New York, NY 10011']},
#    'phone': '+12126200712',
#    'display_phone': '(212) 620-0712',
#    'distance': 4306.190364035247},
#   {'id': 'uaFHoq-a5XqxF-bsOK9_Qg',
#    'alias': 'real-kung-fu-little-steamed-buns-ramen-new-york-2',
#    'name': 'Real Kung Fu Little Steamed Buns Ramen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZbiTrlc8trJdycYJ2yOQfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/real-kung-fu-little-steamed-buns-ramen-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1041,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7616286634162, 'longitude': -73.98688},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '811 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['811 8th Ave', 'New York, NY 10019']},
#    'phone': '+19173882555',
#    'display_phone': '(917) 388-2555',
#    'distance': 6278.494442426036},
#   {'id': 'Jn_p5WaprUY3Ql_539gsWw',
#    'alias': 'm-and-j-asian-cuisine-new-york',
#    'name': 'M&J Asian Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C-y8rlSEA0PqKs0ITKZrkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/m-and-j-asian-cuisine-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7292851717997,
#     'longitude': -73.9780369922164},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '600 E 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['600 E 14th St', 'New York, NY 10009']},
#    'phone': '+12125336888',
#    'display_phone': '(212) 533-6888',
#    'distance': 2984.0257474494792},
#   {'id': 'wzmeaMTm5cZ1JCjep7iQeA',
#    'alias': 'zls-bbq-new-york',
#    'name': 'ZLS BBQ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9zfg3VKbXszlB4VRJcm4Ag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zls-bbq-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73852, 'longitude': -73.98201},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '219 E 23rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['219 E 23rd St', 'New York, NY 10010']},
#    'phone': '+16467819595',
#    'display_phone': '(646) 781-9595',
#    'distance': 3824.596937136006},
#   {'id': 'd_TC6Om2EBTzHVm_lCgNtg',
#    'alias': 'great-ny-noodle-town-new-york',
#    'name': 'Great NY Noodle Town',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eF2UmKlaqNAZHw7FtKxHiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/great-ny-noodle-town-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1364,
#    'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7150363828814,
#     'longitude': -73.9971172437072},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '28 Bowery',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 Bowery', 'New York, NY 10013']},
#    'phone': '+12123490923',
#    'display_phone': '(212) 349-0923',
#    'distance': 1092.7664691368493},
#   {'id': 'CgYWuNH0UHd5vp2vGgKflw',
#    'alias': 'wagamama-murray-hill-new-york',
#    'name': 'wagamama - murray hill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HcZkYIcoPPv7b4A1wygwBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wagamama-murray-hill-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 342,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74909, 'longitude': -73.9754},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '605 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10158',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['605 3rd Ave', 'New York, NY 10158']},
#    'phone': '+16468133396',
#    'display_phone': '(646) 813-3396',
#    'distance': 5105.44415174977},
#   {'id': 'iKW9zBGWfE9CM6MfK0UtjA',
#    'alias': 'fong-on-new-york',
#    'name': 'Fong On',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ntf79V6z2KirNjU-JCkfYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fong-on-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 180,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71417, 'longitude': -73.9937},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '81 Division St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81 Division St', 'New York, NY 10002']},
#    'phone': '+19172617222',
#    'display_phone': '(917) 261-7222',
#    'distance': 971.2591913381516},
#   {'id': 'wyjtGsW5NeVDknGQWnIPAQ',
#    'alias': 'wagamama-midtown-new-york',
#    'name': 'wagamama - midtown',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xCufQewC6rJ5iFqGZXiS8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wagamama-midtown-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 105,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7629, 'longitude': -73.9781574},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '100 W 55th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100 W 55th St', 'New York, NY 10019']},
#    'phone': '+13329006111',
#    'display_phone': '(332) 900-6111',
#    'distance': 6530.759592323944},
#   {'id': 'NXg-oNpx0GYNiErdHb8L5A',
#    'alias': 'awesum-dimsum-new-york-2',
#    'name': 'Awesum Dimsum',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W2zSkq4XV8UJK52NQAmF0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/awesum-dimsum-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 225,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7388534, 'longitude': -73.98367370212858},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '160 E 23rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['160 E 23rd St', 'New York, NY 10010']},
#    'phone': '+16469983313',
#    'display_phone': '(646) 998-3313',
#    'distance': 3821.132993478452},
#   {'id': 'L9SuMN3UsGipopWOe3pr9w',
#    'alias': 'chiko-brooklyn-2',
#    'name': 'Chiko',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xc9NyGXCUSpv2HsDVPX1qw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chiko-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7319, 'longitude': -73.95422},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '954 Manhattan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['954 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+19179090580',
#    'display_phone': '(917) 909-0580',
#    'distance': 4474.591209981534},
#   {'id': 'wobICp6lQP7Y6dfnJ_4Ujw',
#    'alias': 'shun-lee-west-and-cafe-new-york-2',
#    'name': 'Shun Lee West & Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XGdC4HnIEgn9Acmy7qJ9dg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shun-lee-west-and-cafe-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 481,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.77269583, 'longitude': -73.98150783},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '43 W 65th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43 W 65th St', 'New York, NY 10023']},
#    'phone': '+12125958895',
#    'display_phone': '(212) 595-8895',
#    'distance': 7572.368103237685},
#   {'id': 'MYPes7EWP5aLiVG1Z_9eFQ',
#    'alias': 'jing-fong-new-york-6',
#    'name': 'Jing Fong',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UluObpM4s-pTjarY4QwKmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jing-fong-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 233,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7827096147799,
#     'longitude': -73.9789128775797},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '380 Amsterdam Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['380 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+16466785511',
#    'display_phone': '(646) 678-5511',
#    'distance': 8688.595454201595},
#   {'id': 'lgS9lE0Y9FhzT68zCj5QCw',
#    'alias': 'hunan-bistro-new-york',
#    'name': 'Hunan Bistro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Uqmypotc4RZna7VQcW-tpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hunan-bistro-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 222,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73234, 'longitude': -73.9881},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '96 3rd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['96 3rd Ave', 'New York, NY 10003']},
#    'phone': '+12123889855',
#    'display_phone': '(212) 388-9855',
#    'distance': 3036.478308217195},
#   {'id': 'JaKLZrh1Y_2qB_0Gc3bk3A',
#    'alias': 'ollies-sichuan-new-york-2',
#    'name': "Ollie's Sichuan",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/E3vVq8chZE2rkLSLmi7UDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ollies-sichuan-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 527,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.75884, 'longitude': -73.99319},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '411 W 42nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['411 W 42nd St', 'New York, NY 10036']},
#    'phone': '+12128686588',
#    'display_phone': '(212) 868-6588',
#    'distance': 5950.726580341693},
#   {'id': 'A-ert0jDRBfku9ogyW_mEg',
#    'alias': 'spice-symphony-new-york-3',
#    'name': 'Spice Symphony',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/b9t8C8ktnsAypQ0vpFSF5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spice-symphony-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 544,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7558937072754,
#     'longitude': -73.9715347290039},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '150 E 50th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 E 50th St', 'New York, NY 10022']},
#    'phone': '+12123004869',
#    'display_phone': '(212) 300-4869',
#    'distance': 5928.628074161979},
#   {'id': 'wxUTM-FkpCvnoTGJfSXkWg',
#    'alias': 'china-king-new-york-3',
#    'name': 'China King',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2v-oehujs-6mQZpoQm3lIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/china-king-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.738249, 'longitude': -73.983329},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '285 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['285 3rd Ave', 'New York, NY 10010']},
#    'phone': '+12127259888',
#    'display_phone': '(212) 725-9888',
#    'distance': 3762.8575749566317},
#   {'id': 'gcEMZjjqy5Ucnv_5Pv-q1g',
#    'alias': 'tasty-hand-pulled-noodles-ii-new-york',
#    'name': 'Tasty Hand Pulled Noodles II',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JpPFt3sYaf9ow9lX4gl_hA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tasty-hand-pulled-noodles-ii-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 328,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.760537, 'longitude': -73.990782},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '648 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['648 9th Ave', 'New York, NY 10036']},
#    'phone': '+19173882351',
#    'display_phone': '(917) 388-2351',
#    'distance': 6133.099009266688},
#   {'id': 'FYWwW5lcxKzaA98Xgw8bqA',
#    'alias': 'hanon-brooklyn',
#    'name': 'hanon',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dsL1BEJmicoRiQfRHNJcHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hanon-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 202,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7134488, 'longitude': -73.9513445},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '436 Union Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['436 Union Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13477991433',
#    'display_phone': '(347) 799-1433',
#    'distance': 3727.886088653943},
#   {'id': 'QhE50zhSMnQaudpHW1jp7g',
#    'alias': 'the-tyger-new-york-2',
#    'name': 'The Tyger',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xdyC5Z_denJ-lBlR1dlqhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-tyger-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 215,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'panasian', 'title': 'Pan Asian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71888, 'longitude': -73.99951},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1 Howard St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Howard St', 'New York, NY 10013']},
#    'phone': '+16464767566',
#    'display_phone': '(646) 476-7566',
#    'distance': 1558.0214279215886},
#   {'id': 'kxv4jD_qXRPVrV0oPR7isQ',
#    'alias': 'yu-kitchen-new-york-5',
#    'name': 'Yu Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oKCotV7o1FmLHT_v0ffOJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yu-kitchen-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 123,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.79759, 'longitude': -73.9693099},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2656 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2656 Broadway', 'New York, NY 10025']},
#    'phone': '+12126788784',
#    'display_phone': '(212) 678-8784',
#    'distance': 10461.865293000406},
#   {'id': '8ZBbl3VN-cu6PFOL0D7-8A',
#    'alias': 'hunan-village-new-york',
#    'name': 'Hunan Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dXcsEQjpYb7kYGqDYiI_mQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hunan-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.749688, 'longitude': -73.977171},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '339 Lexington Ave New York Ny',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['339 Lexington Ave New York Ny',
#      'New York, NY 10016']},
#    'phone': '+16466924888',
#    'display_phone': '(646) 692-4888',
#    'distance': 5126.81638712685},
#   {'id': 'xtxcAUvrD4dWHJd0cwvW1A',
#    'alias': 'jeju-noodle-bar-new-york',
#    'name': 'JeJu Noodle Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/grYU8HjlM-6dSTgW27rhAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jeju-noodle-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 678,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73304, 'longitude': -74.00734},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '679 Greenwich St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['679 Greenwich St', 'New York, NY 10014']},
#    'phone': '+16466660947',
#    'display_phone': '(646) 666-0947',
#    'distance': 3256.137406146092},
#   {'id': 'RYoc4EBUNOtgbg7c32OG9A',
#    'alias': 'atoboy-new-york',
#    'name': 'Atoboy',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/c6SEZBVmzZeqKsyH3TtmEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/atoboy-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 431,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74364, 'longitude': -73.98456},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '43 E 28th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43 E 28th St', 'New York, NY 10016']},
#    'phone': '+16464767217',
#    'display_phone': '(646) 476-7217',
#    'distance': 4328.417879979509},
#   {'id': 'QBhHq4eN7rtFzmDUciVL-Q',
#    'alias': 'king-wok-new-york',
#    'name': 'King Wok',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kaAPqMS63Bgh1XBRyq1ucQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/king-wok-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 147,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72904, 'longitude': -74.0050399},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '222 Varick St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['222 Varick St', 'New York, NY 10014']},
#    'phone': '+12126758989',
#    'display_phone': '(212) 675-8989',
#    'distance': 2772.2638419637096},
#   {'id': 'SVJNB9LqI13jtVyKMZVqeg',
#    'alias': 'uncle-teds-modern-chinese-cuisine-new-york',
#    'name': "Uncle Ted's Modern Chinese Cuisine",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AWT1te7IPgnB_EJTMezE5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uncle-teds-modern-chinese-cuisine-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 489,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.728806, 'longitude': -73.999947},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '163 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['163 Bleecker St', 'New York, NY 10012']},
#    'phone': '+12127771395',
#    'display_phone': '(212) 777-1395',
#    'distance': 2636.7132059217056},
#   {'id': 'qVBvZIgDcwSFsENWD1nWKQ',
#    'alias': '3-times-new-york-4',
#    'name': '3 Times',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cTNI6cB--23Aha-2nTd0zw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/3-times-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70332, 'longitude': -74.01065},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '38 Water St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38 Water St', 'New York, NY 10004']},
#    'phone': '+16468959297',
#    'display_phone': '(646) 895-9297',
#    'distance': 1398.5656273213121},
#   {'id': 'TU_BU9HLflYI2xlyqVQdRA',
#    'alias': 'tao-uptown-new-york-2',
#    'name': 'TAO Uptown',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Hlkr0IJaok7ORA1TSurTnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tao-uptown-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2635,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.762639, 'longitude': -73.971447},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '42 E 58th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 E 58th St', 'New York, NY 10022']},
#    'phone': '+12128882288',
#    'display_phone': '(212) 888-2288',
#    'distance': 6640.771012137894},
#   {'id': 'cCHkQ5oISNafWnLoBpsagg',
#    'alias': 'yue-wong-restaurant-new-york',
#    'name': 'Yue Wong Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jfPvZXnlA6k4652d__YU9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yue-wong-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.715546, 'longitude': -73.99774},
#    'transactions': ['delivery'],
#    'location': {'address1': '60 Bayard St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Bayard St', 'New York, NY 10013']},
#    'phone': '+16466092331',
#    'display_phone': '(646) 609-2331',
#    'distance': 1160.894689975341},
#   {'id': 'oe8GEFE4QLFAKt87y7zcgA',
#    'alias': 'very-fresh-noodles-new-york',
#    'name': 'Very Fresh Noodles',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Q9II-vHW4IQAfnwECSiOTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/very-fresh-noodles-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1106,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74207, 'longitude': -74.00565},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '409 W 15th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['409 W 15th St', 'New York, NY 10011']},
#    'phone': '+13129655213',
#    'display_phone': '(312) 965-5213',
#    'distance': 4183.62631647822},
#   {'id': 'f7jZvRH-h76F4emzvKytaQ',
#    'alias': 'tuk-tuk-long-island-city',
#    'name': 'Tuk Tuk',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8Q8ojT6I_SyUYLTGSoFdyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tuk-tuk-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 717,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.743232, 'longitude': -73.954254},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '4906 Vernon Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4906 Vernon Blvd', 'Long Island City, NY 11101']},
#    'phone': '+17184725598',
#    'display_phone': '(718) 472-5598',
#    'distance': 5389.827078491865},
#   {'id': 'B7bxdtvLYR7Nmex4AIFd4w',
#    'alias': 'redfarm-new-york-2',
#    'name': 'RedFarm',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/91FP1Kb_-CPfZlcAOy8rDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/redfarm-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 643,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.782051, 'longitude': -73.980415},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '2170 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2170 Broadway', 'New York, NY 10024']},
#    'phone': '+12127249700',
#    'display_phone': '(212) 724-9700',
#    'distance': 8601.638115921005},
#   {'id': 'P2bxlKAmRWZIpHdJ_JT3fg',
#    'alias': 'east-harbor-seafood-palace-brooklyn',
#    'name': 'East Harbor Seafood Palace',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8vLNECyXNwu_JOKg0tl4bQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/east-harbor-seafood-palace-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 709,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.633425, 'longitude': -74.014425},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '714 65th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11220',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['714 65th St', 'Brooklyn, NY 11220']},
#    'phone': '+17187650098',
#    'display_phone': '(718) 765-0098',
#    'distance': 8191.334745352622},
#   {'id': 'R3UNnA8EbjhNWBHS0wJ0VA',
#    'alias': 'grand-sichuan-eastern-new-york',
#    'name': 'Grand Sichuan Eastern',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BouWgLx5vNMgt72M1XkkPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grand-sichuan-eastern-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 256,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.75831, 'longitude': -73.96636},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1049 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1049 2nd Ave', 'New York, NY 10022']},
#    'phone': '+12123555855',
#    'display_phone': '(212) 355-5855',
#    'distance': 6332.070564413123}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#             Restaurant          Type Price Rating            Address  \
# 0         Flor De Mayo       Chinese    $$      4  484 Amsterdam Ave
# 1                CHILI      Szechuan    $$      5       13 E 37th St
# 2               Mr Bao  Shanghainese                 208 Bedford Ave
# 3     China Restaurant       Chinese     $      4      937 Utica Ave
# 4  South Of The Clouds       Chinese    $$      4        16 W 8th St
#
#          Lat        Lng                                                url  \
# 0  40.786090 -73.976580  https://www.yelp.com/biz/flor-de-mayo-new-york...
# 1  40.750020 -73.982150  https://www.yelp.com/biz/chili-new-york?adjust...
# 2  40.717057 -73.958764
# 3  40.650261 -73.929932  https://www.yelp.com/biz/china-restaurant-broo...
# 4  40.732640 -73.997520  https://www.yelp.com/biz/south-of-the-clouds-n...
#
#                        ID
# 0  H1jops1lmuhrq9lP7lEGJQ
# 1  h0pRCiJDrCN7tm3VX5tILQ
# 2
# 3  tDYk6DmmU3buWBs9G0NBXQ
# 4  XaEFFUabnbH8ZF7ccmSAlQ

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                          Restaurant            Type Rating Price  \
# 0                             Tuome  American (New)    4.5   $$$
# 1      Momofuku Noodle Bar - Uptown  American (New)      4    $$
# 2                           Baoburg    Asian Fusion      4    $$
# 3             Macao Trading Company    Asian Fusion      4   $$$
# 4                wagamama - midtown    Asian Fusion      4    $$
# 5                        TAO Uptown    Asian Fusion    3.5   $$$
# 6                            Som Bo    Asian Fusion      4    $$
# 7                 M&J Asian Cuisine    Asian Fusion      4     $
# 8                            Le Sia    Asian Fusion    4.5   $$$
# 9                        Pig Heaven        Barbeque      4    $$
# 10                          ZLS BBQ        Barbeque
# 11             Hui Restaurant & Bar            Bars    4.5    $$
# 12                   Bites of Xi'an         Burgers
# 13                   Congee Village       Cantonese    3.5    $$
# 14             Great NY Noodle Town       Cantonese    3.5     $
# 15                        Old Xi'an         Chinese      4    $$
# 16               Xi'an Famous Foods         Chinese    4.5    $$
# 17   Hutaoli Music Restaurant & Bar         Chinese      4   $$$
# 18                        First Wok         Chinese
# 19              Yue Wong Restaurant         Chinese
# 20                 Nice Day Chinese         Chinese    4.5    $$
# 21         Vanessa's Dumpling House         Chinese    3.5     $
# 22                     Hunan Bistro         Chinese    3.5    $$
# 23                   Hong Kong Cafe         Chinese      4     $
# 24               Mission - Brooklyn         Chinese    3.5    $$
# 25                        Food Sing         Chinese    3.5     $
# 26                    Hunan Delight         Chinese      4    $$
# 27              Lucky House Kitchen         Chinese    4.5     $
# 28                    Golden Forest         Chinese      4     $
# 29           Wing Cheong Restaurant         Chinese    4.5     $
# ..                              ...             ...    ...   ...
# 170                      Chow House        Szechuan    4.5    $$
# 171                     Han Dynasty        Szechuan      4    $$
# 172                 Blue Willow 夜来湘        Szechuan
# 173              Birds of a Feather        Szechuan      4    $$
# 174                     Han Dynasty        Szechuan      4    $$
# 175         Szechuan Mountain House        Szechuan    4.5    $$
# 176                 Szechuan Garden        Szechuan      4    $$
# 177         Spicy Moon East Village        Szechuan    4.5    $$
# 178                   Zest Szechuan        Szechuan      4    $$
# 179                    MáLà Project        Szechuan      4    $$
# 180           Grand Sichuan Eastern        Szechuan    3.5    $$
# 181                           CHILI        Szechuan      5    $$
# 182                  Public Village        Szechuan
# 183                Da Tang Szechuan        Szechuan    4.5    $$
# 184                        Hwa Yuan        Szechuan      4   $$$
# 185                   Mazu Szechuan        Szechuan
# 186                     LaoMa Spicy        Szechuan      4    $$
# 187              Chuan Tian Xia 川天下        Szechuan    4.5    $$
# 188              Very Fresh Noodles       Taiwanese    4.5    $$
# 189                The Braised Shop       Taiwanese      4    $$
# 190                        Ho Foods       Taiwanese      4    $$
# 191                   A-Pou's Taste       Taiwanese    4.5     $
# 192                         Win Son       Taiwanese      4    $$
# 193                             886       Taiwanese      4    $$
# 194              Fan Fried Rice Bar       Taiwanese    4.5     $
# 195                            Uluh       Tea Rooms    4.5   $$$
# 196                  Three Roosters            Thai      5    $$
# 197                         Tuk Tuk            Thai      4    $$
# 198                    Rim Nam Thai            Thai
# 199                            OBAO      Vietnamese      4    $$
#
#                Address        Lat        Lng  \
# 0         536 E 5th St  40.724125 -73.982891
# 1      10 Columbus Cir  40.768470 -73.983092
# 2    614 Manhattan Ave  40.723493 -73.950332
# 3        311 Church St  40.719623 -74.003904
# 4        100 W 55th St  40.762900 -73.978157
# 5         42 E 58th St  40.762639 -73.971447
# 6          143 8th Ave  40.741920 -74.001360
# 7        600 E 14th St  40.729285 -73.978037
# 8          651 9th Ave  40.760720 -73.991190
# 9         1420 3rd Ave  40.775440 -73.956860
# 10       219 E 23rd St  40.738520 -73.982010
# 11       314 E 70th St  40.767010 -73.958460
# 12        84 E 10th St  40.730861 -73.989941
# 13        100 Allen St  40.718700 -73.990310
# 14           28 Bowery  40.715036 -73.997117
# 15        164 Pearl St  40.705910 -74.007470
# 16          96 8th Ave  40.740203 -74.001963
# 17        42 W 33rd St  40.748413 -73.987123
# 18         155 York St  40.701540 -73.984560
# 19        60 Bayard St  40.715546 -73.997740
# 20     170 Bleecker St  40.728670 -74.000700
# 21     310 Bedford Ave  40.713795 -73.961983
# 22          96 3rd Ave  40.732340 -73.988100
# 23    357 Franklin Ave  40.687267 -73.956670
# 24     599 Johnson Ave  40.709382 -73.923229
# 25        172 Grand St  40.714324 -73.961257
# 26        752 Union St  40.675528 -73.978071
# 27       343 Lewis Ave  40.683840 -73.935157
# 28        353 Grand St  40.716700 -73.989450
# 29      1389 Fulton St  40.680375 -73.945514
# ..                 ...        ...        ...
# 170    181 Bleecker St  40.729150 -74.000720
# 171         90 3rd Ave  40.732072 -73.988074
# 172       40 W 56th St  40.762920 -73.976546
# 173       191 Grand St  40.714420 -73.960441
# 174      215 W 85th St  40.787520 -73.976470
# 175     23 St Marks Pl  40.729110 -73.988580
# 176     239 W 105th St  40.800530 -73.967586
# 177       328 E 6th St  40.726740 -73.987220
# 178       45 W 39th St  40.752740 -73.984450
# 179        122 1st Ave  40.727130 -73.985420
# 180       1049 2nd Ave  40.758310 -73.966360
# 181       13 E 37th St  40.750020 -73.982150
# 182      23 Essex St N  40.715441 -73.990060
# 183       18 W 38th St  40.751280 -73.983760
# 184      42 E Broadway  40.713700 -73.995980
# 185        495 3rd Ave  40.745234 -73.978120
# 186        58 E 8th St  40.730890 -73.993430
# 187       5502 7th Ave  40.639700 -74.009131
# 188      409 W 15th St  40.742070 -74.005650
# 189      241 E 10th St  40.728953 -73.984500
# 190       110 E 7th St  40.726340 -73.984780
# 191       963 Grand St  40.713260 -73.936160
# 192     159 Graham Ave  40.707470 -73.943390
# 193  26 Saint Marks Pl  40.728770 -73.988730
# 194     525 Dekalb Ave  40.690990 -73.955870
# 195        152 2nd Ave  40.729340 -73.986607
# 196        792 9th Ave  40.764957 -73.987485
# 197   4906 Vernon Blvd  40.743232 -73.954254
# 198          52 Jay St  40.703367 -73.986889
# 199        647 9th Ave  40.760654 -73.991332
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/tuome-new-york-2?adju...  R7EGjHWw0tNheY6-ahH8fQ
# 1    https://www.yelp.com/biz/momofuku-noodle-bar-u...  Pr-q47vsmM4aoc2t_Sfk8w
# 2    https://www.yelp.com/biz/baoburg-brooklyn-2?ad...  6wJOojpF2c4lLeBNbTBB0A
# 3    https://www.yelp.com/biz/macao-trading-company...  U74_3F7r3tMhd6dmTmDBxQ
# 4    https://www.yelp.com/biz/wagamama-midtown-new-...  wyjtGsW5NeVDknGQWnIPAQ
# 5    https://www.yelp.com/biz/tao-uptown-new-york-2...  TU_BU9HLflYI2xlyqVQdRA
# 6    https://www.yelp.com/biz/som-bo-new-york-2?adj...  pb_cHcy8D8UC-jQ-Q524ug
# 7    https://www.yelp.com/biz/m-and-j-asian-cuisine...  Jn_p5WaprUY3Ql_539gsWw
# 8    https://www.yelp.com/biz/le-sia-new-york-4?adj...  C3tP0fNNAoxOAC3O406CXQ
# 9    https://www.yelp.com/biz/pig-heaven-new-york-3...  sfsjk1h50ooC2ioY7m48gw
# 10
# 11   https://www.yelp.com/biz/hui-restaurant-and-ba...  LT0yyLNM84EiJj9DL0rfHA
# 12
# 13   https://www.yelp.com/biz/congee-village-new-yo...  rYw5rQbWRX9buZHZbxqWdA
# 14   https://www.yelp.com/biz/great-ny-noodle-town-...  d_TC6Om2EBTzHVm_lCgNtg
# 15   https://www.yelp.com/biz/old-xian-new-york-4?a...  rJ4N10Nbh-GM49qOSGFoAw
# 16   https://www.yelp.com/biz/xian-famous-foods-new...  DmTz35KvxO20mH-pJxLNpg
# 17   https://www.yelp.com/biz/hutaoli-music-restaur...  pPqEu60FMffpiWqk2MCrVA
# 18
# 19
# 20   https://www.yelp.com/biz/nice-day-chinese-new-...  kueEZRLEaNVo6Cow3hf56Q
# 21   https://www.yelp.com/biz/vanessas-dumpling-hou...  S-aX_Pz8F7nDL6kRThKcHw
# 22   https://www.yelp.com/biz/hunan-bistro-new-york...  lgS9lE0Y9FhzT68zCj5QCw
# 23   https://www.yelp.com/biz/hong-kong-cafe-brookl...  zPK48x2wvTmJTQ_13bbeRQ
# 24   https://www.yelp.com/biz/mission-brooklyn-broo...  IoAUbSudW1Mds5_XY_01Rg
# 25   https://www.yelp.com/biz/food-sing-brooklyn?ad...  i4cyV13lYIS4mcJKZW75cA
# 26   https://www.yelp.com/biz/hunan-delight-brookly...  _XLLSXPIjgoZQtwU3RCcQA
# 27   https://www.yelp.com/biz/lucky-house-kitchen-b...  U2aUFZARLeSMf4RQIxjuTw
# 28   https://www.yelp.com/biz/golden-forest-new-yor...  oJjMYhA6z1_BVaQpSdyl8g
# 29   https://www.yelp.com/biz/wing-cheong-restauran...  3fQ9IExhN9KMqGHVm_9AEQ
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/chow-house-new-york?a...  0dDCDQz7DrKkSvu9h2hcQw
# 171  https://www.yelp.com/biz/han-dynasty-new-york?...  wfhMIiMh2A2psCGONOVSlg
# 172
# 173  https://www.yelp.com/biz/birds-of-a-feather-br...  iSjPBJRiWqrgxW7ZM3CGig
# 174  https://www.yelp.com/biz/han-dynasty-new-york-...  ojbH3wnRu050hRhkmoxRiA
# 175  https://www.yelp.com/biz/szechuan-mountain-hou...  jc7lVTvmYMIK5RNpENtS6w
# 176  https://www.yelp.com/biz/szechuan-garden-new-y...  xCHApgtkLpEyh0lz-uhZvg
# 177  https://www.yelp.com/biz/spicy-moon-east-villa...  Bb0h5Rs8ugSM2CjulRhfBw
# 178  https://www.yelp.com/biz/zest-szechuan-new-yor...  6tASYtO9zOrXr8-LPnAToQ
# 179  https://www.yelp.com/biz/m%C3%A1l%C3%A0-projec...  Kqb7MjTPNkjPMoFRd-rWpw
# 180  https://www.yelp.com/biz/grand-sichuan-eastern...  R3UNnA8EbjhNWBHS0wJ0VA
# 181  https://www.yelp.com/biz/chili-new-york?adjust...  h0pRCiJDrCN7tm3VX5tILQ
# 182
# 183  https://www.yelp.com/biz/da-tang-szechuan-new-...  v0opDMezc6pKgdfR22KUnQ
# 184  https://www.yelp.com/biz/hwa-yuan-new-york-2?a...  qH8PVeddtVs9cKN2pwgdkQ
# 185
# 186  https://www.yelp.com/biz/laoma-spicy-new-york-...  KSleHGTG1yL1E7OEFFPoNQ
# 187  https://www.yelp.com/biz/chuan-tian-xia-%E5%B7...  zrV2yUsz1SxymeH51iRBRw
# 188  https://www.yelp.com/biz/very-fresh-noodles-ne...  oe8GEFE4QLFAKt87y7zcgA
# 189  https://www.yelp.com/biz/the-braised-shop-new-...  jXL7zCeuhZnQVei5rfq7qw
# 190  https://www.yelp.com/biz/ho-foods-new-york-3?a...  rBUTVjRs5CcEMe3dfVRZJQ
# 191  https://www.yelp.com/biz/a-pous-taste-brooklyn...  wqdFd3DZD_uTXRW784mFkg
# 192  https://www.yelp.com/biz/win-son-brooklyn-4?ad...  3gqKLANaXNsHZnPDjKrcTg
# 193  https://www.yelp.com/biz/886-new-york?adjust_c...  8Oo2AtQEPDfxIOnA8wfXoQ
# 194  https://www.yelp.com/biz/fan-fried-rice-bar-br...  q2bIyvU8CQwiB6xe_iVs0g
# 195  https://www.yelp.com/biz/uluh-new-york?adjust_...  4FD0TAxe70nb3ngk3sXF9Q
# 196  https://www.yelp.com/biz/three-roosters-new-yo...  9b_FvTUgkkUUMyL0nGhFtg
# 197  https://www.yelp.com/biz/tuk-tuk-long-island-c...  f7jZvRH-h76F4emzvKytaQ
# 198
# 199  https://www.yelp.com/biz/obao-new-york-3?adjus...  NN3mOWF5e_pnR1ArqM2bHQ
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_Chinese.csv')
