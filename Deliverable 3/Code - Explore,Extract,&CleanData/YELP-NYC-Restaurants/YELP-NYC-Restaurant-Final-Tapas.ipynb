# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"tapas","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': 'iTj5T_jPYvznd1QTgs7NZw',
#    'alias': 'nai-tapas-new-york-5',
#    'name': 'Nai Tapas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NbwhwWIPwmz27ZlsJoNb4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nai-tapas-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 989,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7267949, 'longitude': -73.9892815},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '85 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12126771030',
#    'display_phone': '(212) 677-1030',
#    'distance': 2411.2962234343086},
#   {'id': '5S8ZK9XLdl4l645twbNYZQ',
#    'alias': 'boqueria-new-york-16',
#    'name': 'Boqueria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fbSDh3qEKXs_EUdW63DlFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boqueria-new-york-16?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 790,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.771522, 'longitude': -73.956073},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '1460 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1460 2nd Ave', 'New York, NY 10075']},
#    'phone': '+12123432227',
#    'display_phone': '(212) 343-2227',
#    'distance': 8022.0936685931465},
#   {'id': 'XEugUtbw4rRmGr9S1XA-aQ',
#    'alias': 'alta-new-york',
#    'name': 'Alta',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aUWGUNBLw-mbQZOzJ9-Pdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alta-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1937,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7345163811398,
#     'longitude': -73.9983369619683},
#    'transactions': ['restaurant_reservation', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '64 W 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64 W 10th St', 'New York, NY 10011']},
#    'phone': '+12125057777',
#    'display_phone': '(212) 505-7777',
#    'distance': 3250.5152771255803},
#   {'id': 'XghOzJn16M-nvaKMOdC5og',
#    'alias': 'verlaine-new-york-2',
#    'name': 'Verlaine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/F2ou7G6rM1TcQW9G0V31Hg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/verlaine-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1452,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720079, 'longitude': -73.987785},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '110 Rivington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['110 Rivington St', 'New York, NY 10002']},
#    'phone': '+12126142493',
#    'display_phone': '(212) 614-2493',
#    'distance': 1717.209013709613},
#   {'id': 'cUyfnb3E7HvzNfbTgTjl_Q',
#    'alias': 'despaña-fine-foods-and-tapas-cafe-new-york-2',
#    'name': 'Despaña Fine Foods & Tapas Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/P_ElQd-AkKJOWHPps-f-Mg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/despa%C3%B1a-fine-foods-and-tapas-cafe-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 581,
#    'categories': [{'alias': 'gourmet', 'title': 'Specialty Food'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'importedfood', 'title': 'Imported Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.721094, 'longitude': -73.9978255},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '408 Broome St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['408 Broome St', 'New York, NY 10013']},
#    'phone': '+12122195050',
#    'display_phone': '(212) 219-5050',
#    'distance': 1765.3868869898827},
#   {'id': 'AIKjw2QLvVNdha3TciJYzg',
#    'alias': 'boqueria-soho-new-york-2',
#    'name': 'Boqueria Soho',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dsTgn4Xekc3pgB5s1JuhrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boqueria-soho-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1099,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.724912, 'longitude': -74.0021299},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '171 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 Spring St', 'New York, NY 10012']},
#    'phone': '+12123434255',
#    'display_phone': '(212) 343-4255',
#    'distance': 2263.1676600663327},
#   {'id': 'fVbUVAiLiGgLA_nxBFxyww',
#    'alias': 'thursday-kitchen-new-york',
#    'name': 'Thursday Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nXO8M-d-XTamNmc0BpXWtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thursday-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1451,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7275, 'longitude': -73.9838},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '424 E 9th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['424 E 9th St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2613.42601480514},
#   {'id': 'qIOAlXCCYrwN0VxEEH-Tmw',
#    'alias': 'boqueria-flatiron-new-york-4',
#    'name': 'Boqueria Flatiron',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZjtnIVgp6ChKy55T1A0ghg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boqueria-flatiron-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1299,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7402927726298,
#     'longitude': -73.9940709810079},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '53 W 19th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['53 W 19th St', 'New York, NY 10011']},
#    'phone': '+12122554160',
#    'display_phone': '(212) 255-4160',
#    'distance': 3874.95155313543},
#   {'id': 'iexl39DYyy_76Xq3ExaJkQ',
#    'alias': 'excuse-my-french-new-york',
#    'name': 'Excuse My French',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZIhKH5H06vFbrLn7OJFM_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/excuse-my-french-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 312,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71844, 'longitude': -73.98981},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '96 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['96 Orchard St', 'New York, NY 10002']},
#    'phone': '+12127809600',
#    'display_phone': '(212) 780-9600',
#    'distance': 1494.339354725842},
#   {'id': 'gvMYV5E3HyzhN_MYFIMGzg',
#    'alias': 'el-born-brooklyn',
#    'name': 'El Born',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cRJdg0UISKlStMI7vkp6Tw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-born-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 344,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7243479163883,
#     'longitude': -73.9512226101037},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '651 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['651 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+13478449295',
#    'display_phone': '(347) 844-9295',
#    'distance': 4194.692764168617},
#   {'id': '9yc2V6zNpLG58uPV_ykBog',
#    'alias': 'boqueria-west-40th-st-new-york',
#    'name': 'Boqueria West 40th St',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uyd-5SYJ0j7s8s6OyjUhRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boqueria-west-40th-st-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 483,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75558, 'longitude': -73.99012},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '260 W 40th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['260 W 40th St', 'New York, NY 10018']},
#    'phone': '+12122556047',
#    'display_phone': '(212) 255-6047',
#    'distance': 5573.02130762801},
#   {'id': 'EHINHIbLklEUShuANKjGgw',
#    'alias': 'tomiño-taberna-gallega-new-york',
#    'name': 'Tomiño Taberna Gallega',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4D8QyvL2sJTNj9Q6nKVSOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tomi%C3%B1o-taberna-gallega-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 308,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7192978908919,
#     'longitude': -73.9969160361937},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '192 Grand St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['192 Grand St', 'New York, NY 10013']},
#    'phone': '+12129334763',
#    'display_phone': '(212) 933-4763',
#    'distance': 1556.166469060262},
#   {'id': '4axlhxyN2bKuRWfnY2IhuQ',
#    'alias': 'tabaré-brooklyn-2',
#    'name': 'Tabaré',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/seC6-UXedR23zcn6Q-Raew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tabar%C3%A9-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 668,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.713046, 'longitude': -73.958968},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '221 S 1st St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['221 S 1st St', 'Brooklyn, NY 11211']},
#    'phone': '+13473350187',
#    'display_phone': '(347) 335-0187',
#    'distance': 3095.160559528829},
#   {'id': 'NqwwyMMXIS-JnwdDQBQT9A',
#    'alias': 'bazar-tapas-bar-and-restaurant-new-york-5',
#    'name': 'Bazar Tapas Bar and Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5t-5TV7sfrLhD9fUnjwN6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bazar-tapas-bar-and-restaurant-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 528,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74437, 'longitude': -73.99014},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '31 W 26th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31 W 26th St', 'New York, NY 10010']},
#    'phone': '+12125108155',
#    'display_phone': '(212) 510-8155',
#    'distance': 4349.191918940027},
#   {'id': 'AgAkUVLN_axMY-bzbNCfCw',
#    'alias': 'yuca-bar-new-york',
#    'name': 'Yuca Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jP2eHFr9p6EOzDOFh7es3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yuca-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1874,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7262, 'longitude': -73.9836},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '111 Avenue A',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 Avenue A', 'New York, NY 10009']},
#    'phone': '+12129829533',
#    'display_phone': '(212) 982-9533',
#    'distance': 2486.707075449049},
#   {'id': 'MNNpsRXe7Wt5m3Jla9Wk0w',
#    'alias': 'the-alcove-sunnyside',
#    'name': 'The Alcove',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/peNqHPI1kUUKbvTse-xIxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-alcove-sunnyside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 953,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7459065, 'longitude': -73.915103},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '41-11 49th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41-11 49th St', 'Sunnyside, NY 11104']},
#    'phone': '+13478134159',
#    'display_phone': '(347) 813-4159',
#    'distance': 8045.510107980188},
#   {'id': 'tXWA5kUJnZY_NbED1-ST0g',
#    'alias': 'la-ñapa-brooklyn-2',
#    'name': 'La Ñapa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-9J9kuTIq6fY1_3aO2pJWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-%C3%B1apa-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67596, 'longitude': -73.95007},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '656 Nostrand Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['656 Nostrand Ave', 'Brooklyn, NY 11216']},
#    'phone': '+13474350920',
#    'display_phone': '(347) 435-0920',
#    'distance': 4968.60053393084},
#   {'id': '3UmRGpZsMdJx4fWCT1NxZg',
#    'alias': 'bar-dalia-astoria',
#    'name': 'Bar Dalia',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/L3-0A-t9KdP9BxY_mYiLeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-dalia-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.76347, 'longitude': -73.9212253},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '33-17 31st Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-17 31st Ave', 'Astoria, NY 11106']},
#    'phone': '+13475071218',
#    'display_phone': '(347) 507-1218',
#    'distance': 8918.05816100453},
#   {'id': 'DiHm4iIAQhqMKfjsrBPvZw',
#    'alias': 'socarrat-paella-bar-chelsea-new-york-3',
#    'name': 'Socarrat Paella Bar - Chelsea',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1lhp74JM_bux_us9r97piA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/socarrat-paella-bar-chelsea-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1194,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7426956, 'longitude': -73.9995488},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '259 W 19th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['259 W 19th St', 'New York, NY 10011']},
#    'phone': '+12124621000',
#    'display_phone': '(212) 462-1000',
#    'distance': 4165.698670744235},
#   {'id': 'EuYs8uV6WgCzeYqNi6y84g',
#    'alias': 'tasca-new-york-2',
#    'name': 'Tasca',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CJHmxsose8mdTh57z7n1vQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tasca-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'caribbean', 'title': 'Caribbean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78533, 'longitude': -73.9728},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '505 Columbus Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['505 Columbus Ave', 'New York, NY 10024']},
#    'phone': '+12123622211',
#    'display_phone': '(212) 362-2211',
#    'distance': 9064.451141808939},
#   {'id': 'yZx1kHlBHXwEBZLkX0PRhA',
#    'alias': 'plado-tasting-bar-new-york',
#    'name': 'Plado Tasting Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/l7Y6q9f26VYA89_kkCZp9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/plado-tasting-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72242, 'longitude': -73.98397},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '192 E 2nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['192 E 2nd St', 'New York, NY 10009']},
#    'phone': '+16468505151',
#    'display_phone': '(646) 850-5151',
#    'distance': 2094.6592783330693},
#   {'id': 'HRl7_BMSznkfYSlXWQ89Ig',
#    'alias': 'lamano-west-village-new-york',
#    'name': 'Lamano West Village',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/N03iAkty8KFL3CqUuHgKNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lamano-west-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73388, 'longitude': -74.00158},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '39 Christopher St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39 Christopher St', 'New York, NY 10014']},
#    'phone': '+12122433200',
#    'display_phone': '(212) 243-3200',
#    'distance': 3222.9520140895565},
#   {'id': 'SaYTVG7wHCMDBofHCgXPaA',
#    'alias': 'dutch-freds-new-york-2',
#    'name': 'Dutch Freds',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/F5fSQkZSmWf_JEkcFUpcyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dutch-freds-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1648,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.760835, 'longitude': -73.987823},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '307 W 47th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['307 W 47th St', 'New York, NY 10036']},
#    'phone': '+16469186923',
#    'display_phone': '(646) 918-6923',
#    'distance': 6182.299430087978},
#   {'id': 'StF9WWWbrRzEOmNAcEINcA',
#    'alias': 'balzem-new-york',
#    'name': 'Balzem',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FHbj0Hqn0btPLBS7pwPfew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/balzem-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 456,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.721408, 'longitude': -73.995415},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '202 Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['202 Mott St', 'New York, NY 10012']},
#    'phone': '+16468377033',
#    'display_phone': '(646) 837-7033',
#    'distance': 1777.534042874945},
#   {'id': '6zH2Ih2Hw2wwf9ssIbZYRw',
#    'alias': 'vinotapa-new-york',
#    'name': 'VinoTapa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/l7MDCcS8vM5NgC4V-eK8fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vinotapa-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 423,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7436868467235,
#     'longitude': -73.9790102422585},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '201 E 31st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['201 E 31st St', 'New York, NY 10016']},
#    'phone': '+12127258466',
#    'display_phone': '(212) 725-8466',
#    'distance': 4443.061319106825},
#   {'id': 'XLT7aNLJEhIdoieNjPw8Gg',
#    'alias': 'blueprint-brooklyn-2',
#    'name': 'Blueprint',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xJSV7SP2iMg3yq72yzvXwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blueprint-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 342,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6769, 'longitude': -73.980411},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '196 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['196 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17186226644',
#    'display_phone': '(718) 622-6644',
#    'distance': 3382.876266993298},
#   {'id': 'wx9mXol6jOrUoAK4vaFS9Q',
#    'alias': 'mission-ceviche-new-york-3',
#    'name': 'Mission Ceviche',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/e7KmYUqKcBIxGQXbbP85BQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mission-ceviche-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 413,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7692325, 'longitude': -73.9578759},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '1400 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1400 2nd Ave', 'New York, NY 10021']},
#    'phone': '+12126500014',
#    'display_phone': '(212) 650-0014',
#    'distance': 7715.020998303233},
#   {'id': 'XAHfErhn_JujythNCmGl1w',
#    'alias': 'salinas-new-york',
#    'name': 'Salinas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VfGS-hNkRTimDNiNuUoajA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salinas-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 941,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7436999, 'longitude': -74.00314},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$$',
#    'location': {'address1': '136 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136 9th Ave', 'New York, NY 10011']},
#    'phone': '+12127761990',
#    'display_phone': '(212) 776-1990',
#    'distance': 4315.934483120549},
#   {'id': '1cJsIcgLMQ_XsrKZYFhkzA',
#    'alias': 'haizea-new-york-3',
#    'name': 'Haizea',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SvrDwieaHhhNGQLckR0rew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/haizea-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'basque', 'title': 'Basque'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72705166724979,
#     'longitude': -74.0020627560054},
#    'transactions': ['delivery'],
#    'location': {'address1': '142 Sullivan St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['142 Sullivan St', 'New York, NY 10012']},
#    'phone': '+16464762261',
#    'display_phone': '(646) 476-2261',
#    'distance': 2490.200878510082},
#   {'id': 'CcxreLJbZsO6Z775-hMWpw',
#    'alias': 'st-tropez-west-village-new-york-3',
#    'name': 'St Tropez West Village',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/T4TolJBuIlUIoEWaWm091g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-tropez-west-village-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 202,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73704, 'longitude': -74.00386},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '304 W 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['304 W 4th St', 'New York, NY 10014']},
#    'phone': '+19173883893',
#    'display_phone': '(917) 388-3893',
#    'distance': 3606.8808422406223},
#   {'id': 'qm1J_dPA5IHij1oAnoZwHw',
#    'alias': 'nonono-new-york-6',
#    'name': 'nonono',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uj6OfjZrgmqGYyHtmn3AAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nonono-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 886,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74545, 'longitude': -73.98499},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '118 Madison Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['118 Madison Ave', 'New York, NY 10016']},
#    'phone': '+16467073227',
#    'display_phone': '(646) 707-3227',
#    'distance': 4515.897681612123},
#   {'id': 'GSaBi8jPsuQFa7YwYlihjA',
#    'alias': 'la-vara-brooklyn',
#    'name': 'La Vara',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7NBLDJW5VN6-XaS69z6URQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-vara-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 378,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68781, 'longitude': -73.99576},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '268 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['268 Clinton St', 'Brooklyn, NY 11201']},
#    'phone': '+17184220065',
#    'display_phone': '(718) 422-0065',
#    'distance': 1965.312119898106},
#   {'id': 'l9b8NbDyhKhnjLKtUwlPwQ',
#    'alias': 'olea-brooklyn-2',
#    'name': 'Olea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DnRMsVyIBgFA-CsLDU5AYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olea-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 928,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6877844, 'longitude': -73.9706046},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '171 Lafayette Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 Lafayette Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17186437003',
#    'display_phone': '(718) 643-7003',
#    'distance': 2797.8774095098875},
#   {'id': 'wYmb7YpPwlchsYEPHzgcdQ',
#    'alias': 'the-rusty-face-brooklyn-3',
#    'name': 'The Rusty Face',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/P1u-Zn5SeVsVSGPZ6vz_ww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-rusty-face-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71418787933165,
#     'longitude': -73.96078337251589},
#    'transactions': ['delivery'],
#    'location': {'address1': '188 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['188 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+13473350006',
#    'display_phone': '(347) 335-0006',
#    'distance': 2987.1115256735393},
#   {'id': 'nF-EOBd_H1fX50iT1EIVZA',
#    'alias': 'pil-pil-new-york',
#    'name': 'Pil Pil',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gDJzny2a3Ur6vfFVttO3hQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pil-pil-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 684,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7728412, 'longitude': -73.9558687},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '265 E 78th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['265 E 78th St', 'New York, NY 10075']},
#    'phone': '+12129883788',
#    'display_phone': '(212) 988-3788',
#    'distance': 8163.455753834157},
#   {'id': 'IavC9CRFtosOC7UN5ndXpg',
#    'alias': 'fandi-mata-brooklyn-3',
#    'name': 'Fandi Mata',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Hzvkcryw6MyBRhttOd4sww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fandi-mata-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 106,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.719022672809004,
#     'longitude': -73.94928253665668},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '74 Bayard St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['74 Bayard St', 'Brooklyn, NY 11211']},
#    'phone': '+17183888877',
#    'display_phone': '(718) 388-8877',
#    'distance': 4083.1149321169146},
#   {'id': '-OplSkpDk33uikS5fO-JQw',
#    'alias': 'addictive-wine-and-tapas-bar-jackson-heights-4',
#    'name': 'Addictive Wine and Tapas Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BK7PatYxq7tPsRA3zBVRxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/addictive-wine-and-tapas-bar-jackson-heights-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 218,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75632, 'longitude': -73.8806},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '87-01 Northern Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['87-01 Northern Blvd', 'Jackson Heights, NY 11372']},
#    'phone': '+13478320951',
#    'display_phone': '(347) 832-0951',
#    'distance': 11120.974115785602},
#   {'id': 'fUxRTikmfHnURZ26lD2y4Q',
#    'alias': 'tia-pol-new-york',
#    'name': 'Tia Pol',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jJ641tPiJ5y05O_9cHwwpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tia-pol-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 709,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7473, 'longitude': -74.00481},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '205 10th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['205 10th Ave', 'New York, NY 10011']},
#    'phone': '+12126758805',
#    'display_phone': '(212) 675-8805',
#    'distance': 4737.556701669699},
#   {'id': 'qLLxS7RwNEjP_jq_KQrPfA',
#    'alias': 'traif-brooklyn',
#    'name': 'Traif',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PpkVfUXlooPy9uejl3zptg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/traif-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1908,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.710658, 'longitude': -73.958872},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$$',
#    'location': {'address1': '229 S 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['229 S 4th St', 'Brooklyn, NY 11211']},
#    'phone': '+13478449578',
#    'display_phone': '(347) 844-9578',
#    'distance': 3041.420337735676},
#   {'id': 'p5g5P-t-iAvHAxJvI6KUPg',
#    'alias': 'la-nacional-restaurant-new-york-4',
#    'name': 'La Nacional Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yw7DuJ_lq0dmjY5tMGP6rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-nacional-restaurant-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 94,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.739475, 'longitude': -74.001143},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '239 W 14th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['239 W 14th St', 'New York, NY 10011']},
#    'phone': '+19173882888',
#    'display_phone': '(917) 388-2888',
#    'distance': 3829.6269534727307},
#   {'id': 'uVfOB37NyYEGRs5FITM-nQ',
#    'alias': 'leyenda-brooklyn',
#    'name': 'Leyenda',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xmzICvK5W37OzD61Bpv1uQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/leyenda-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 261,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68431, 'longitude': -73.99197},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '221 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['221 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+13479873260',
#    'display_phone': '(347) 987-3260',
#    'distance': 2361.4337938854646},
#   {'id': 'avBY-xnfy4_pXCNc6EFHpg',
#    'alias': 'my-moon-brooklyn-2',
#    'name': 'My Moon',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nMvvkb4mhn3lRFuucVPiCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-moon-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 360,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7188586, 'longitude': -73.9552174},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '184 N 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['184 N 10th St', 'Brooklyn, NY 11211']},
#    'phone': '+17185997007',
#    'display_phone': '(718) 599-7007',
#    'distance': 3618.3378162316935},
#   {'id': '8PhwiTru5teSaZ8C6hrIww',
#    'alias': 'casa-mono-new-york',
#    'name': 'Casa Mono',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Qm7W93CkBJ3qMb83HzHy5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-mono-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1278,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7359281440206,
#     'longitude': -73.9871550967319},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '52 Irving Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['52 Irving Pl', 'New York, NY 10003']},
#    'phone': '+12122532773',
#    'display_phone': '(212) 253-2773',
#    'distance': 3442.5489220619515},
#   {'id': 'fVslDZ8dGsVmcRhS0R0kFg',
#    'alias': 'huertas-new-york',
#    'name': 'Huertas',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hxKr2CnJNMFkbkTX1fsxlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/huertas-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 321,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.726856, 'longitude': -73.986251},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '107 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['107 1st Ave', 'New York, NY 10003']},
#    'phone': '+12122284490',
#    'display_phone': '(212) 228-4490',
#    'distance': 2475.0281411802994},
#   {'id': 'VLGmFHE4s0Sfu0piMVQa1Q',
#    'alias': 'hold-fast-kitchen-and-spirits-new-york',
#    'name': 'Hold Fast Kitchen & Spirits',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2a8BP3w4_pgEn8Y0E6TBow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hold-fast-kitchen-and-spirits-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 420,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.76064, 'longitude': -73.99023},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '364 W 46th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['364 W 46th St', 'New York, NY 10036']},
#    'phone': '+19172616691',
#    'display_phone': '(917) 261-6691',
#    'distance': 6140.252693485879},
#   {'id': '5MpWHGQ6Qc-M4q1KL_nioA',
#    'alias': 'bar-b-new-york',
#    'name': 'Bar B',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rP6Gfe33cpkYe549tj_2BQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-b-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 187,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7395804, 'longitude': -73.999118},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '84 7th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['84 7th Ave', 'New York, NY 10011']},
#    'phone': '+12122291888',
#    'display_phone': '(212) 229-1888',
#    'distance': 3817.3548091487633},
#   {'id': 'BEYmqrP1_TC0nhnTGKkkJg',
#    'alias': 'ella-social-new-york',
#    'name': 'Ella Social',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QZBwj2Qv88av6s6SpsNrVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ella-social-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 552,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7769826, 'longitude': -73.9788067},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '249 Columbus Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['249 Columbus Ave', 'New York, NY 10023']},
#    'phone': '+12125799929',
#    'display_phone': '(212) 579-9929',
#    'distance': 8060.913620478771},
#   {'id': 'P4AqEW0Bs-6bkA_fHpcBlA',
#    'alias': 'bar-jamón-new-york-2',
#    'name': 'Bar Jamón',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6zcHOU0rO7_HVF-XZPZY4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-jam%C3%B3n-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 287,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7358627319336,
#     'longitude': -73.9870300292969},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '125 E 17th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['125 E 17th St', 'New York, NY 10003']},
#    'phone': '+12122532773',
#    'display_phone': '(212) 253-2773',
#    'distance': 3435.6300197859855},
#   {'id': 'jilTxChA2GqtAE21V--ckw',
#    'alias': 'debajo-new-york-2',
#    'name': 'Debajo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/84bau3LqytStuhWF8CBggQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/debajo-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.746214, 'longitude': -73.98945},
#    'transactions': ['delivery'],
#    'location': {'address1': '44 West 29th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['44 West 29th St', 'New York, NY 10001']},
#    'phone': '+12122134429',
#    'display_phone': '(212) 213-4429',
#    'distance': 4549.362274529624},
#   {'id': 'ddFY9PpygYagv7-jVduB2Q',
#    'alias': 'counter-and-bodega-new-york',
#    'name': 'Counter & Bodega',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bntOKIdBYIuTnibuAQQjfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/counter-and-bodega-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 138,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'puertorican', 'title': 'Puerto Rican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74382731329241, 'longitude': -73.996272},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '216 7th Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['216 7th Ave', 'New York, NY 10011']},
#    'phone': '+16468700785',
#    'display_phone': '(646) 870-0785',
#    'distance': 4271.185156375448}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                         Restaurant                Type Price Rating  \
# 0                        Nai Tapas          Tapas Bars   $$$    4.5
# 1                         Boqueria  Tapas/Small Plates   $$$      4
# 2                             Alta          Tapas Bars   $$$      4
# 3                         Verlaine  Tapas/Small Plates    $$      4
# 4  Despaña Fine Foods & Tapas Cafe      Specialty Food    $$    4.5
#
#             Address        Lat        Lng  \
# 0        85 2nd Ave  40.726795 -73.989282
# 1      1460 2nd Ave  40.771522 -73.956073
# 2      64 W 10th St  40.734516 -73.998337
# 3  110 Rivington St  40.720079 -73.987785
# 4     408 Broome St  40.721094 -73.997826
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/nai-tapas-new-york-5?...  iTj5T_jPYvznd1QTgs7NZw
# 1  https://www.yelp.com/biz/boqueria-new-york-16?...  5S8ZK9XLdl4l645twbNYZQ
# 2  https://www.yelp.com/biz/alta-new-york?adjust_...  XEugUtbw4rRmGr9S1XA-aQ
# 3  https://www.yelp.com/biz/verlaine-new-york-2?a...  XghOzJn16M-nvaKMOdC5og
# 4  https://www.yelp.com/biz/despa%C3%B1a-fine-foo...  cUyfnb3E7HvzNfbTgTjl_Q

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"tapas","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': 'ETgJqJHV7BW6pIr9Ox74sA',
#    'alias': 'amélie-new-york',
#    'name': 'Amélie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cSDgVuPMnJgMLTrTNSEXug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/am%C3%A9lie-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2751,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7327, 'longitude': -73.99766},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '22 W 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 W 8th St', 'New York, NY 10011']},
#    'phone': '+12125332962',
#    'display_phone': '(212) 533-2962',
#    'distance': 3038.8699032940094},
#   {'id': 'fFkqEyupjc5x2iJQIPcpLw',
#    'alias': 'ruffian-new-york-4',
#    'name': 'Ruffian',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0UFfPVtjZ2PAEJd0gx7rtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ruffian-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 230,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7264, 'longitude': -73.98411},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '125 E 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['125 E 7th St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2487.011426980985},
#   {'id': 'Swjm9no7DRqhThLlf0EHng',
#    'alias': 'sama-street-brooklyn-2',
#    'name': 'Sama Street',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4-AGIzhwZZs3ev8TmZ4X6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sama-street-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 120,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'panasian', 'title': 'Pan Asian'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7328843, 'longitude': -73.9545232327229},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '988 Manhattan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['988 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+19292763140',
#    'display_phone': '(929) 276-3140',
#    'distance': 4532.441879818043},
#   {'id': 'Du4yrt8aWlBhOeEjhEH3ww',
#    'alias': 'st-tropez-soho-new-york-2',
#    'name': 'St Tropez - Soho',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zAlqB-hcZgrKvs5I-3Iblw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-tropez-soho-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 115,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72498, 'longitude': -74.00328},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '194 Spring St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['194 Spring St', 'New York, NY 10012']},
#    'phone': '+19172614441',
#    'display_phone': '(917) 261-4441',
#    'distance': 2298.546347742118},
#   {'id': '3xTQT7qjZJIxc-eBiFMerQ',
#    'alias': '1803-new-york',
#    'name': '1803',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/f6_ZYxoZGbyGsCn6m_auog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/1803-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 554,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.715498, 'longitude': -74.007178},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '82 Reade St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['82 Reade St', 'New York, NY 10007']},
#    'phone': '+12122673000',
#    'display_phone': '(212) 267-3000',
#    'distance': 1558.541688391669},
#   {'id': 'cRmRAl5HHJcysKBSrHivHA',
#    'alias': 'lamano-chelsea-new-york-2',
#    'name': 'Lamano Chelsea',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/akq7tIefyXPAutAc7VD4MA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lamano-chelsea-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 112,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7433797337789,
#     'longitude': -73.9994259551167},
#    'transactions': ['pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '265 W 20th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['265 W 20th St', 'New York, NY 10011']},
#    'phone': '+12127412398',
#    'display_phone': '(212) 741-2398',
#    'distance': 4240.2786215267115},
#   {'id': '6tGW6KMFB1rLGInE6sB3KA',
#    'alias': 'kaia-wine-bar-new-york',
#    'name': 'Kaia Wine Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DUD5Pnxc49W4tjxAKMn5Tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaia-wine-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 466,
#    'categories': [{'alias': 'southafrican', 'title': 'South African'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7819, 'longitude': -73.95197},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1614 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1614 3rd Ave', 'New York, NY 10128']},
#    'phone': '+12127220490',
#    'display_phone': '(212) 722-0490',
#    'distance': 9210.214016739925},
#   {'id': 'TOlIQbDBIHq_or6JcXx4ZQ',
#    'alias': 'sauced-brooklyn',
#    'name': 'Sauced',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9fTKY6-18pBciiTp_xoKlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sauced-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7126701394003,
#     'longitude': -73.9623194526208},
#    'transactions': ['delivery'],
#    'location': {'address1': '331 Bedford Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['331 Bedford Ave', 'Brooklyn, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2812.2439705902975},
#   {'id': '76B7-T4f1EdsQsoI0NM9Wg',
#    'alias': 'beso-staten-island',
#    'name': 'Beso',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nvCek_FFzl3l2uoWwgkf8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beso-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 561,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6433825472408,
#     'longitude': -74.0769100798997},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '11 Schuyler St',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10301',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 Schuyler St', 'Staten Island, NY 10301']},
#    'phone': '+17188168162',
#    'display_phone': '(718) 816-8162',
#    'distance': 9806.5034407657},
#   {'id': 'PnnU4YcwH6qOO97i5CzKgA',
#    'alias': 'los-dos-hermanos-brooklyn',
#    'name': 'Los Dos Hermanos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/w-UmwD0fgzw6BxVQ_w3QLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-dos-hermanos-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6897589190199,
#     'longitude': -73.97237462897537},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '266 Carlton Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['266 Carlton Ave', 'Brooklyn, NY 11205']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2540.9925600214},
#   {'id': '16ZnHpuaaBt92XWeJHCC5A',
#    'alias': 'olio-e-piú-new-york-city',
#    'name': 'Olio e Piú',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/W_kyLvXj7ustj-XHWYU6tQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olio-e-pi%C3%BA-new-york-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2773,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.733798036104304,
#     'longitude': -73.99977392649927},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3 Greenwich Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York City',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3 Greenwich Ave', 'New York City, NY 10014']},
#    'phone': '+12122436546',
#    'display_phone': '(212) 243-6546',
#    'distance': 3186.3804982206075},
#   {'id': 'Ck09FempamAKGSPsV_bX-A',
#    'alias': 'xixa-brooklyn',
#    'name': 'Xixa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gP0Mr0TzIptA5-C2ryCNrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/xixa-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 614,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.710505, 'longitude': -73.958466},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '241 S 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['241 S 4th St', 'Brooklyn, NY 11211']},
#    'phone': '+17183888860',
#    'display_phone': '(718) 388-8860',
#    'distance': 3068.0963514710497},
#   {'id': 'Om6KGbN524K6pu9IkPT0Rg',
#    'alias': 'maite-brooklyn',
#    'name': 'Maite',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Rl9D83fjlkZTZxiifuqfrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maite-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 200,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'colombian', 'title': 'Colombian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69924, 'longitude': -73.926797},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '159 Central Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['159 Central Ave', 'Brooklyn, NY 11221']},
#    'phone': '+17183663090',
#    'display_phone': '(718) 366-3090',
#    'distance': 5731.450254368031},
#   {'id': 'xZ96vaoL-cQjfotmUKtjJQ',
#    'alias': 'barn-joo-35-new-york',
#    'name': 'Barn Joo 35',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/h4zKOxpPuJ958w8S43Wu4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barn-joo-35-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2106,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74964, 'longitude': -73.98582},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '34 W 35th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['34 W 35th St', 'New York, NY 10001']},
#    'phone': '+12125644430',
#    'display_phone': '(212) 564-4430',
#    'distance': 4968.473297353009},
#   {'id': 'OsA5iRphHwPlYNhdddvBng',
#    'alias': 'june-brooklyn-3',
#    'name': 'June',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1dZlWIzH26L-BAd0yF7tJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/june-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 189,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68606512542637,
#     'longitude': -73.99388911165558},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '231 Court St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 Court St', 'Brooklyn, NY 11201']},
#    'phone': '+19179090434',
#    'display_phone': '(917) 909-0434',
#    'distance': 2155.1955507472085},
#   {'id': 'q11TljTQd33XCWlVoPyRqg',
#    'alias': 'the-osprey-brooklyn',
#    'name': 'The Osprey',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/38J6wCRITFIWiRtWhE_sJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-osprey-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 240,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.702241, 'longitude': -73.995539},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '60 Furman St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Furman St', 'Brooklyn, NY 11201']},
#    'phone': '+13476962505',
#    'display_phone': '(347) 696-2505',
#    'distance': 367.7475436977597},
#   {'id': 'YxLazl79hS4O_ygHWqM3mg',
#    'alias': 'lo-res-bar-brooklyn',
#    'name': 'Lo-Res Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RDZWAITlYB03MKYk-lfpVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lo-res-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.715984, 'longitude': -73.962577},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '136 Metropolitan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136 Metropolitan Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17187828370',
#    'display_phone': '(718) 782-8370',
#    'distance': 2917.1834942237756},
#   {'id': 'RemvTpxalDjSew5HwmNzUQ',
#    'alias': 'the-dead-rabbit-new-york',
#    'name': 'The Dead Rabbit',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_4T5R0HHhASROheby-TXDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dead-rabbit-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1615,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70329, 'longitude': -74.01102},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '30 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30 Water St', 'New York, NY 10004']},
#    'phone': '+16464227906',
#    'display_phone': '(646) 422-7906',
#    'distance': 1431.0399855447463},
#   {'id': '71HLFDV5yIX8l7WqP7Km5g',
#    'alias': 'westlight-brooklyn',
#    'name': 'Westlight',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TjVEapZucfdPEvCnN46cOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/westlight-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 615,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.722299, 'longitude': -73.956691},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '111 N 12th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 N 12th St', 'Brooklyn, NY 11249']},
#    'phone': '+17183077100',
#    'display_phone': '(718) 307-7100',
#    'distance': 3681.878990715751},
#   {'id': '9z2lUyfzZV8b2rkkiwSM4g',
#    'alias': 'abc-cocina-new-york',
#    'name': 'ABC Cocina',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pQl-_7f3IXULP8fWP4Wtew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/abc-cocina-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 927,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.738005, 'longitude': -73.989251},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '38 E 19th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38 E 19th St', 'New York, NY 10003']},
#    'phone': '+12124755829',
#    'display_phone': '(212) 475-5829',
#    'distance': 3643.1150740886005},
#   {'id': 'KWIPsr4kQBLIpPTSwKTlig',
#    'alias': 'brookvin-brooklyn',
#    'name': 'Brookvin',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/v1GdV2UDnO3PwgamyZj5GQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brookvin-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 309,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6652526855469,
#     'longitude': -73.9825668334961},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '381 7th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['381 7th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187689463',
#    'display_phone': '(718) 768-9463',
#    'distance': 4572.193140180949},
#   {'id': 'P9x0uX9nmPCph1mWM3k4vg',
#    'alias': 'barely-disfigured-brooklyn-3',
#    'name': 'Barely Disfigured',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y_dgfZIDct0Mbk-AQOFz9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barely-disfigured-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 105,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68309, 'longitude': -73.9928},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '257 Smith St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['257 Smith St', 'Brooklyn, NY 11231']},
#    'phone': '+17188585646',
#    'display_phone': '(718) 858-5646',
#    'distance': 2488.952828636363},
#   {'id': '7SekluUz__l0ZtPOaLBUeQ',
#    'alias': 'socarrat-paella-bar-nolita-new-york-3',
#    'name': 'Socarrat Paella Bar - Nolita',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TmUuC0SrDDpLOa4UfsSs4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/socarrat-paella-bar-nolita-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 520,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.724483, 'longitude': -73.99504},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '284 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['284 Mulberry St', 'New York, NY 10012']},
#    'phone': '+12122190101',
#    'display_phone': '(212) 219-0101',
#    'distance': 2117.8771977811966},
#   {'id': '9BzRiWO6PSdR-l3dzCm3VA',
#    'alias': 'buceo-95-new-york',
#    'name': 'Buceo 95',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SlU7lZHBfmr431YR3kbWlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/buceo-95-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 446,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.793613, 'longitude': -73.971112},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '201 W 95th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['201 W 95th St', 'New York, NY 10025']},
#    'phone': '+12126627010',
#    'display_phone': '(212) 662-7010',
#    'distance': 9996.42066278644},
#   {'id': '8MwqN3ZZCzYVKwzYgcCZdg',
#    'alias': 'local-and-vine-new-york',
#    'name': 'Local & Vine',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2wtGzJ4o5wZKxufdLz25ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/local-and-vine-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72528, 'longitude': -74.0074},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '282 Hudson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['282 Hudson St', 'New York, NY 10013']},
#    'phone': '+12123373414',
#    'display_phone': '(212) 337-3414',
#    'distance': 2465.7105145010964},
#   {'id': 'VvsZAnEwU4c8Xkyrzx05Nw',
#    'alias': 'anytime-new-york',
#    'name': 'Anytime',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZCynTTqe0O1JtxKRozmWHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anytime-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1632,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74776270790539,
#     'longitude': -73.9867793576711},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '23 W 32nd St',
#     'address2': 'Fl 3',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23 W 32nd St', 'Fl 3', 'New York, NY 10001']},
#    'phone': '+16466697733',
#    'display_phone': '(646) 669-7733',
#    'distance': 4747.932417457403},
#   {'id': 'dblEevwbNXl56I4L6TULGg',
#    'alias': 'lolas-hoboken',
#    'name': "Lola's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6U7a0UdGlihkSHhPlDtCvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lolas-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 204,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.753263, 'longitude': -74.027242},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '153 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['153 14th St', 'Hoboken, NJ 07030']},
#    'phone': '+12014206062',
#    'display_phone': '(201) 420-6062',
#    'distance': 5998.343598311225},
#   {'id': 'SysAthrDghPL62a6OElOCQ',
#    'alias': 'local-92-new-york-32',
#    'name': 'Local 92',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MOXM-fj5G3im3S99EHa5tw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/local-92-new-york-32?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 454,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.726957, 'longitude': -73.9885354},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '92 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['92 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12124322232',
#    'display_phone': '(212) 432-2232',
#    'distance': 2440.7642790284935},
#   {'id': 'axqp3pGJXnTLgq2QrPyDyQ',
#    'alias': 'benemon-new-york',
#    'name': 'Benemon',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qYGlL-jKKWmMthi05ae_iA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/benemon-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 619,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72551, 'longitude': -73.98838},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '108 E 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['108 E 4th St', 'New York, NY 10003']},
#    'phone': '+12126143006',
#    'display_phone': '(212) 614-3006',
#    'distance': 2289.2038585586733},
#   {'id': 'F5YKnCOtmaDWLjL3Hu2tgQ',
#    'alias': 'la-sala-by-tu-casa-kew-gardens-2',
#    'name': 'La Sala by Tu Casa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/R5Ss5cQy5sw4tYB2MEuwvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-sala-by-tu-casa-kew-gardens-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.707369, 'longitude': -73.835057},
#    'transactions': [],
#    'location': {'address1': '11635 Metropolitan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Kew Gardens',
#     'zip_code': '11418',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11635 Metropolitan Ave', 'Kew Gardens, NY 11418']},
#    'phone': '+17184873990',
#    'display_phone': '(718) 487-3990',
#    'distance': 13419.627486099838},
#   {'id': 'wpT1QU7PSQgQQ1DkzI00JA',
#    'alias': 'izakaya-toribar-new-york',
#    'name': 'Izakaya Toribar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lZig3aa5S2etRjst2WP4qw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-toribar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 87,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.759641, 'longitude': -73.9685558},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '164 E 56th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['164 E 56th St', 'New York, NY 10022']},
#    'phone': '+16467670029',
#    'display_phone': '(646) 767-0029',
#    'distance': 6404.650179251868},
#   {'id': 'MYh3iKpuo1HQUoHUyzA0BQ',
#    'alias': 'bar-crudo-brooklyn-2',
#    'name': 'Bar Crudo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cgPPQ_01TaMNKdPxTJaItQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-crudo-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 154,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.670226, 'longitude': -73.985768},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '412 Fifth Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['412 Fifth Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187011894',
#    'display_phone': '(718) 701-1894',
#    'distance': 3981.5773244219467},
#   {'id': 'UF9F0A4e7AJHzNPG5zrHUQ',
#    'alias': 'the-beast-next-door-long-island-city-2',
#    'name': 'The Beast Next Door',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yWORhJMU72LW5-zM8ynQGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-beast-next-door-long-island-city-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 200,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74881, 'longitude': -73.94073},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '42-51 27th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42-51 27th St', 'Long Island City, NY 11101']},
#    'phone': '+17182551612',
#    'display_phone': '(718) 255-1612',
#    'distance': 6606.958104550268},
#   {'id': 'wA_KKu3X36JcaUPgFjyIHg',
#    'alias': 'glasserie-brooklyn-2',
#    'name': 'Glasserie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3o1blwUZTs_1PRUB3JYn4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/glasserie-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 380,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7376154, 'longitude': -73.9560697},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '95 Commercial St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['95 Commercial St', 'Brooklyn, NY 11222']},
#    'phone': '+17183890640',
#    'display_phone': '(718) 389-0640',
#    'distance': 4813.793970929616},
#   {'id': 'g-q-kRxdn2zh2oWOY-jKTQ',
#    'alias': 'anfora-new-york',
#    'name': 'Anfora',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7FvTcXeMoqDY3JmO-pk-MQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anfora-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 186,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73789, 'longitude': -74.00408},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '34 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['34 8th Ave', 'New York, NY 10014']},
#    'phone': '+12125182722',
#    'display_phone': '(212) 518-2722',
#    'distance': 3705.476685402482},
#   {'id': 'RfxOtJ4SQmEeVX_XjFLWUQ',
#    'alias': 'otis-brooklyn-2',
#    'name': 'Otis',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aViDtyaJ5YRmsqC4ot5L2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/otis-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 374,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.706011, 'longitude': -73.932598},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '18 Harrison Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18 Harrison Pl', 'Brooklyn, NY 11206']},
#    'phone': '+16468860601',
#    'display_phone': '(646) 886-0601',
#    'distance': 5200.877004016517},
#   {'id': 'StpOKezaW-AyN2xA1EJKvw',
#    'alias': 'victors-cafe-new-york-6',
#    'name': "Victor's Cafe",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Ts6hioUXawlKSHUZ3SksUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/victors-cafe-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1504,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7629499, 'longitude': -73.98403},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '236 W 52nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['236 W 52nd St', 'New York, NY 10019']},
#    'phone': '+12125867714',
#    'display_phone': '(212) 586-7714',
#    'distance': 6443.557003174376},
#   {'id': 'Rj2ACaJcbroJLPDhRhzvBw',
#    'alias': 'shuka-new-york-3',
#    'name': 'Shuka',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RqYdXhgbPMwX6XriUdAYHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shuka-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 603,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72707, 'longitude': -74.00283},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '38 MacDougal St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38 MacDougal St', 'New York, NY 10012']},
#    'phone': '+12124757500',
#    'display_phone': '(212) 475-7500',
#    'distance': 2508.1446558186562},
#   {'id': 'J5y7oRfiGtxFDkYGKxFZkw',
#    'alias': 'anella-brooklyn',
#    'name': 'Anella',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wtCx7mZt-ajOQOupF9GvjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anella-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 422,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73327, 'longitude': -73.95786},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '222 Franklin St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['222 Franklin St', 'Brooklyn, NY 11222']},
#    'phone': '+17183898100',
#    'display_phone': '(718) 389-8100',
#    'distance': 4354.831102659747},
#   {'id': 'XO3yD87rTPz9o6Dy9qRaJg',
#    'alias': 'the-spaniard-new-york',
#    'name': 'The Spaniard',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C7TTSwl8qtsN3YJbKvAS9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-spaniard-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 288,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'whiskeybars', 'title': 'Whiskey Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7327497, 'longitude': -74.0021829},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '190 W 4th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['190 W 4th St', 'New York, NY 10014']},
#    'phone': '+12129181986',
#    'display_phone': '(212) 918-1986',
#    'distance': 3108.1109361713225},
#   {'id': 'TGP5gbAgml0IDRLGCpFnCw',
#    'alias': 'pmf-pardon-my-french-new-york',
#    'name': 'PMF Pardon My French',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/X8eWP2AqEiktrGTr3th8JA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pmf-pardon-my-french-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1034,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72473, 'longitude': -73.98115},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '103 Ave B',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 Ave B', 'New York, NY 10009']},
#    'phone': '+12123589683',
#    'display_phone': '(212) 358-9683',
#    'distance': 2414.8553623569283},
#   {'id': 'XVMzBs7wGeU5BWgyBL3xyQ',
#    'alias': 'ardesia-new-york',
#    'name': 'Ardesia Wine Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jH_TiigJ7gzTz28O5KnoJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ardesia-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 385,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7660831005947,
#     'longitude': -73.9914581179619},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '510 W 52nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['510 W 52nd St', 'New York, NY 10019']},
#    'phone': '+12122479191',
#    'display_phone': '(212) 247-9191',
#    'distance': 6746.886665552301},
#   {'id': 'f12cJ70sc75C2ON50-fYqw',
#    'alias': 'anytime-billiards-new-york',
#    'name': 'Anytime Billiards',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tmlxULSSx36mBgFAfNK63A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anytime-billiards-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'poolhalls', 'title': 'Pool Halls'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74747, 'longitude': -73.99033},
#    'transactions': [],
#    'location': {'address1': '112 W 30th 1FL',
#     'address2': 'Fl 1',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['112 W 30th 1FL', 'Fl 1', 'New York, NY 10001']},
#    'phone': '+16466660144',
#    'display_phone': '(646) 666-0144',
#    'distance': 4673.73322715939},
#   {'id': 'tmbW6_dJs5-UXhvROO093Q',
#    'alias': 'casa-d-paco-newark',
#    'name': "Casa d'Paco",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zd84XX26_6SPwp4VXPATmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-d-paco-newark?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 764,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72529, 'longitude': -74.16309},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '73 Warwick St',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07105',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['73 Warwick St', 'Newark, NJ 07105']},
#    'phone': '+18623436300',
#    'display_phone': '(862) 343-6300',
#    'distance': 14401.95610844707},
#   {'id': 'e5wK3I_THzF4Ce_OgoSCQw',
#    'alias': 'mokyo-new-york-2',
#    'name': 'MOKYO',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5iR0_udC0Z_D1nBye5JQXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mokyo-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 152,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.727223, 'longitude': -73.983878},
#    'transactions': [],
#    'location': {'address1': '109 St Marks Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['109 St Marks Pl', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2574.1694660765133},
#   {'id': '0vdgqmIt6e0suBu2g-M1UQ',
#    'alias': 'the-ten-bells-new-york',
#    'name': 'The Ten Bells',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/u31yuvibU1GtkqrfrxFgVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ten-bells-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 458,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.717801, 'longitude': -73.98985},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '247 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['247 Broome St', 'New York, NY 10002']},
#    'phone': '+12122284450',
#    'display_phone': '(212) 228-4450',
#    'distance': 1424.0632550041787},
#   {'id': 'klAhw3xLQi9GF1tf_HnS7w',
#    'alias': 'izakaya-mew-new-york-3',
#    'name': 'Izakaya MEW',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OHIgiBgK1CA9C3ElqoDTZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-mew-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2447,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.750148, 'longitude': -73.9863203465939},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '53 W 35th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['53 W 35th St', 'New York, NY 10001']},
#    'phone': '+16463689384',
#    'display_phone': '(646) 368-9384',
#    'distance': 5015.952903788343},
#   {'id': 'f-WkzzSaAA_mdDmsKlJ4sw',
#    'alias': '21-greenpoint-brooklyn-2',
#    'name': '21 Greenpoint',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Jj5leTKQjdOH7AF1qGRSlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/21-greenpoint-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72978, 'longitude': -73.95992},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '21 Greenpoint Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21 Greenpoint Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183838833',
#    'display_phone': '(718) 383-8833',
#    'distance': 3966.853940669762},
#   {'id': 'G_zDrPTmfNCL2R1tHpEouw',
#    'alias': 'the-archer-jersey-city-2',
#    'name': 'The Archer',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1-IURtQT4CQR-UbPl8IabA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-archer-jersey-city-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 313,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.721315204191, 'longitude': -74.045283556493},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '176 Newark Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['176 Newark Ave', 'Jersey City, NJ 07302']},
#    'phone': '+12013091090',
#    'display_phone': '(201) 309-1090',
#    'distance': 4645.856603438639},
#   {'id': 'MOwB9YYd-Ko6nVgSB-ltQw',
#    'alias': 'briciola-new-york',
#    'name': 'Briciola',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eO9jNBCXTg5yxxnbpLrkeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/briciola-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 867,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7637997047278,
#     'longitude': -73.9880919456482},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '370 W 51st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['370 W 51st St', 'New York, NY 10019']},
#    'phone': '+16466785763',
#    'display_phone': '(646) 678-5763',
#    'distance': 6509.757763438482}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#          Restaurant           Type Price Rating            Address        Lat  \
# 0            Amélie         French   $$$    4.5        22 W 8th St  40.732700
# 1           Ruffian      Wine Bars    $$    4.5       125 E 7th St  40.726400
# 2       Sama Street  Cocktail Bars    $$      5  988 Manhattan Ave  40.732884
# 3  St Tropez - Soho         French    $$      4      194 Spring St  40.724980
# 4              1803   Cajun/Creole    $$    4.5        82 Reade St  40.715498
#
#          Lng                                                url  \
# 0 -73.997660  https://www.yelp.com/biz/am%C3%A9lie-new-york?...
# 1 -73.984110  https://www.yelp.com/biz/ruffian-new-york-4?ad...
# 2 -73.954523  https://www.yelp.com/biz/sama-street-brooklyn-...
# 3 -74.003280  https://www.yelp.com/biz/st-tropez-soho-new-yo...
# 4 -74.007178  https://www.yelp.com/biz/1803-new-york?adjust_...
#
#                        ID
# 0  ETgJqJHV7BW6pIr9Ox74sA
# 1  fFkqEyupjc5x2iJQIPcpLw
# 2  Swjm9no7DRqhThLlf0EHng
# 3  Du4yrt8aWlBhOeEjhEH3ww
# 4  3xTQT7qjZJIxc-eBiFMerQ

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"tapas","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': 'R8Vfaytsa1yQ9L5HNmA49g',
#    'alias': 'l-wren-brooklyn-3',
#    'name': "L'Wren",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-gLOametGHO55uBt1fGZQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-wren-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.650743, 'longitude': -74.004913},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '4004 5th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11232',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4004 5th Ave', 'Brooklyn, NY 11232']},
#    'phone': '+19179091894',
#    'display_phone': '(917) 909-1894',
#    'distance': 6150.3611487013195},
#   {'id': 'twHJyFgUSd7wzioKQjE7Jw',
#    'alias': 'galli-new-york-5',
#    'name': 'Galli',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NriJMGzJm4mZn-Pj2oRm3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/galli-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 974,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72161, 'longitude': -74.00127},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '45 Mercer St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 Mercer St', 'New York, NY 10013']},
#    'phone': '+12129669288',
#    'display_phone': '(212) 966-9288',
#    'distance': 1898.5732904580973},
#   {'id': 'rFhI8Gedy7XQksVD-ixOHw',
#    'alias': 'oppa-bistro-new-york',
#    'name': 'Oppa Bistro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FxzgzXmz9MoV0O5j5G5eSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oppa-bistro-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 147,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.731826, 'longitude': -74.0013903},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '162 West 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 West 4th St', 'New York, NY 10014']},
#    'phone': '+16464100503',
#    'display_phone': '(646) 410-0503',
#    'distance': 2993.80187503631},
#   {'id': 'vlepW-Y_RDQaDMLtEwHWmg',
#    'alias': 'bubo-new-york',
#    'name': 'Bubo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4Zz4bxIVKuy_KWkd47xI2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bubo-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 201,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74598, 'longitude': -73.97753},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '515 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['515 3rd Ave', 'New York, NY 10016']},
#    'phone': '+12125323300',
#    'display_phone': '(212) 532-3300',
#    'distance': 4725.590762206177},
#   {'id': 'ePqKbqXFBCbwBaWiN2Jo9w',
#    'alias': 'ampersand-new-york-2',
#    'name': 'Ampersand',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VonOfbx-KisgqaxG0zhltw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ampersand-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 229,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7386178790617,
#     'longitude': -73.9834206895483},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '294 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['294 3rd Ave', 'New York, NY 10010']},
#    'phone': '+12124778100',
#    'display_phone': '(212) 477-8100',
#    'distance': 3800.7617476958712},
#   {'id': 'kB-lmHs7yNwLIlQyp0kMmQ',
#    'alias': 'quality-meats-new-york',
#    'name': 'Quality Meats',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/X7eFAr1jZCbF1OpOay0PQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/quality-meats-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2016,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.764958, 'longitude': -73.976206},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '57 W 58th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['57 W 58th St', 'New York, NY 10019']},
#    'phone': '+12123717777',
#    'display_phone': '(212) 371-7777',
#    'distance': 6790.760655173766},
#   {'id': 'jAaVnUKLITkuhzwXIe0vLQ',
#    'alias': 'cafe-mogador-brooklyn',
#    'name': 'Cafe Mogador',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/79mu5Jkhl1UelPQvNjtk7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-mogador-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1228,
#    'categories': [{'alias': 'moroccan', 'title': 'Moroccan'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.719747, 'longitude': -73.959993},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '133 Wythe Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['133 Wythe Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17184869222',
#    'display_phone': '(718) 486-9222',
#    'distance': 3299.5306167935732},
#   {'id': 'PAQDvkvVselqlhOc0Mh92g',
#    'alias': 'doma-new-york-4',
#    'name': 'Doma',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vqfcvJPHcnxGI-cXZLXhsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doma-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72703, 'longitude': -73.985392},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '120 1st Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['120 1st Ave', 'New York, NY 10009']},
#    'phone': '+16466783092',
#    'display_phone': '(646) 678-3092',
#    'distance': 2512.863769062223},
#   {'id': '63xEppObiNqq_lVE5HGFvw',
#    'alias': 'the-poni-room-new-york',
#    'name': 'The Poni Room',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/U7Gft_MmiDjkJxJxjefSqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-poni-room-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72521, 'longitude': -73.99247},
#    'transactions': ['delivery'],
#    'location': {'address1': '316 Bowery',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['316 Bowery', 'New York, NY 10012']},
#    'phone': '+12122540350',
#    'display_phone': '(212) 254-0350',
#    'distance': 2203.261757078007},
#   {'id': 'xR2Yeb_Nh0MOAiUIaqaVOg',
#    'alias': 'tavern-157-flushing-2',
#    'name': 'Tavern 157',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DzgKsJaswv3HgvcZcOImOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tavern-157-flushing-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 439,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7634836392041,
#     'longitude': -73.807817278102},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '157-12 Northern Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['157-12 Northern Blvd', 'Flushing, NY 11354']},
#    'phone': '+17188867488',
#    'display_phone': '(718) 886-7488',
#    'distance': 16985.65931887605},
#   {'id': 'MH08_pIRKsUSwfkVYxUE7w',
#    'alias': 'vinatería-new-york-4',
#    'name': 'VINATERÍA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qDZdWOELDVu3OQs5qaAC0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vinater%C3%ADa-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 520,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8064392068585,
#     'longitude': -73.9540110111145},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2211 Frederick Douglass Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10026',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2211 Frederick Douglass Blvd', 'New York, NY 10026']},
#    'phone': '+12126628462',
#    'display_phone': '(212) 662-8462',
#    'distance': 11731.415238483045},
#   {'id': 'WoAvunLY0_L0ix8Vgit8gQ',
#    'alias': 'the-tuck-room-new-york',
#    'name': 'The Tuck Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gH9DAaCG0aBpaZjwL4nnig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-tuck-room-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 275,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7066254, 'longitude': -74.00314050061166},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '11 Fulton St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 Fulton St', 'New York, NY 10038']},
#    'phone': '+12127768273',
#    'display_phone': '(212) 776-8273',
#    'distance': 757.2289687487001},
#   {'id': 'mdAt1D1XUG-HwTYmPSi9fA',
#    'alias': 'izakaya-mew-flushing-flushing',
#    'name': 'Izakaya Mew Flushing',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BUry_zLfojXgP4BCXA5lZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-mew-flushing-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 249,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76536, 'longitude': -73.82022},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '146-13 Northern Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['146-13 Northern Blvd', 'Flushing, NY 11354']},
#    'phone': '+13475060044',
#    'display_phone': '(347) 506-0044',
#    'distance': 16110.076034930906},
#   {'id': 'Orbsfc3nI21mQ8cwSPahhg',
#    'alias': 'the-four-horsemen-brooklyn',
#    'name': 'The Four Horsemen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_HpgmmeSN9qK2hdPa8S-7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-four-horsemen-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 212,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71305, 'longitude': -73.95732},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '295 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['295 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17185994900',
#    'display_phone': '(718) 599-4900',
#    'distance': 3234.4709420444497},
#   {'id': 'h_qGWauoScc3tMBDBb-few',
#    'alias': 'gaudir-new-york-2',
#    'name': 'GAUDir',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LS8WTvGz_qpJTzMuFvGIZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gaudir-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.79349, 'longitude': -73.941},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '251 E 110th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['251 E 110th St', 'New York, NY 10029']},
#    'phone': '+12127444422',
#    'display_phone': '(212) 744-4422',
#    'distance': 10769.60213643748},
#   {'id': 'aJqjC4uAo6vhOpsVNCiMDA',
#    'alias': 'samba-kitchen-new-york-5',
#    'name': 'Samba Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7f-Wh7i58MUnrLkqVuP8Xg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/samba-kitchen-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 460,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.764666, 'longitude': -73.9912643},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '457 W 50th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['457 W 50th St', 'New York, NY 10019']},
#    'phone': '+16469890532',
#    'display_phone': '(646) 989-0532',
#    'distance': 6590.02589083191},
#   {'id': 'r2aGrOQe0yoY7FD9LI44Zg',
#    'alias': 'tapas-de-españa-north-bergen-3',
#    'name': 'Tapas De España',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/b6wrgIfCvhd0SRAdFkDiGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tapas-de-espa%C3%B1a-north-bergen-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 351,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.80206, 'longitude': -74.00664},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '7909 Bergenline Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'North Bergen',
#     'zip_code': '07047',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['7909 Bergenline Ave', 'North Bergen, NJ 07047']},
#    'phone': '+12014531690',
#    'display_phone': '(201) 453-1690',
#    'distance': 10796.140205660135},
#   {'id': '7m4GnzK5pv7qGn-Ar1zabQ',
#    'alias': 'lena-new-york-12',
#    'name': 'Lena',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YDGiHCiuRcIBvMZEdCaM7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lena-new-york-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.732552, 'longitude': -73.996704},
#    'transactions': [],
#    'location': {'address1': '1B West 8th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1B West 8th St', 'New York, NY 10011']},
#    'phone': '+12129792315',
#    'display_phone': '(212) 979-2315',
#    'distance': 3021.012362493374},
#   {'id': 'Lir90KKfKjrI6VMvNqgVlA',
#    'alias': 'tapas-bar-and-lounge-queens-2',
#    'name': 'Tapas Bar & Lounge',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sWl__nvEYyuDWKCCfq79VA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tapas-bar-and-lounge-queens-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.737148606160375,
#     'longitude': -73.70991623635895},
#    'transactions': [],
#    'location': {'address1': '258-03 Hillside Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Queens',
#     'zip_code': '11004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['258-03 Hillside Ave', 'Queens, NY 11004']},
#    'phone': '+15167441111',
#    'display_phone': '(516) 744-1111',
#    'distance': 24223.367087581155},
#   {'id': 'SF2G4QfcSV03sMCSsv5s2g',
#    'alias': 'the-cellar-new-york',
#    'name': 'The Cellar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_q5G-1Be50eOTr25jI3OKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cellar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 668,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73889, 'longitude': -73.9897},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '900 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['900 Broadway', 'New York, NY 10003']},
#    'phone': '+12124663340',
#    'display_phone': '(212) 466-3340',
#    'distance': 3736.81886629639},
#   {'id': 'ZOfk6Ao0db5icjc0WEq7zg',
#    'alias': 'bacchus-bistro-and-wine-bar-brooklyn-2',
#    'name': 'Bacchus Bistro & Wine Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_m46oBmSGKhdddta9WoejA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bacchus-bistro-and-wine-bar-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 504,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68692, 'longitude': -73.98437},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '409-411 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['409-411 Atlantic Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17188521572',
#    'display_phone': '(718) 852-1572',
#    'distance': 2219.7594386413657},
#   {'id': 'HbCyzokiA19bEWUp6mga_g',
#    'alias': 'bibi-new-york',
#    'name': 'bibi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V2qvFO0ohemmEdb0Nm4ROg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bibi-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 196,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.723937, 'longitude': -73.983519},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '211 E 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['211 E 4th St', 'New York, NY 10009']},
#    'phone': '+12126732424',
#    'display_phone': '(212) 673-2424',
#    'distance': 2247.8154805576246},
#   {'id': 'vyyJNMgVo5b3Lyex5GawHg',
#    'alias': 'district-local-new-york-2',
#    'name': 'District Local',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9Vs8AzvCwwSxBR63pweD_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/district-local-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73917, 'longitude': -73.99946},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '72 7th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['72 7th Ave', 'New York, NY 10011']},
#    'phone': '+12129306677',
#    'display_phone': '(212) 930-6677',
#    'distance': 3773.6284900511323},
#   {'id': '_hvgCRW8Vw1n3Usr9RPoUg',
#    'alias': 'cellar-335-jersey-city',
#    'name': 'Cellar 335',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LrRgK-iWmQeGL-VAO-v6KA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cellar-335-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 571,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tikibars', 'title': 'Tiki Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7249692, 'longitude': -74.0515195},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '335 Newark Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['335 Newark Ave', 'Jersey City, NJ 07302']},
#    'phone': '+12012221422',
#    'display_phone': '(201) 222-1422',
#    'distance': 5284.81191870707},
#   {'id': 'X8yEmEDD9ZTkHoIRFqzcRw',
#    'alias': 'osamil-new-york',
#    'name': 'Osamil',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DqYrPS7e-6VsgjVAihJBrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osamil-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 473,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74697, 'longitude': -73.9864},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '5 West 31st St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 West 31st St', 'New York, NY 10001']},
#    'phone': '+12123004713',
#    'display_phone': '(212) 300-4713',
#    'distance': 4663.679425010974},
#   {'id': 'goKn7tKTIqpNPM_jR2yRCg',
#    'alias': 'leyla-new-york-4',
#    'name': 'Leyla',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EgHo8Wpadbh0azN-FyUAZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/leyla-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 148,
#    'categories': [{'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77882, 'longitude': -73.97834},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '108 W 74th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['108 W 74th St', 'New York, NY 10023']},
#    'phone': '+13473347939',
#    'display_phone': '(347) 334-7939',
#    'distance': 8261.702549744094},
#   {'id': 'WyFvM4kmgNm19jip0tDBqA',
#    'alias': 'lunàtico-brooklyn',
#    'name': 'LunÀtico',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BHlEMMAd6hpPLpbOcWSX0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lun%C3%A0tico-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 114,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6834345006833,
#     'longitude': -73.9346118563989},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '486 Halsey St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['486 Halsey St', 'Brooklyn, NY 11233']},
#    'phone': '+17185130339',
#    'display_phone': '(718) 513-0339',
#    'distance': 5595.255971110654},
#   {'id': 'FiRB9Ek3Xo9JHwXgBYITYg',
#    'alias': 'la-sirène-soho-new-york',
#    'name': 'La Sirène-Soho',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L7cSgPVmrKJosZatGJKvBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-sir%C3%A8ne-soho-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1636,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7243642217227,
#     'longitude': -74.005708694458},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '558 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['558 Broome St', 'New York, NY 10013']},
#    'phone': '+12129253061',
#    'display_phone': '(212) 925-3061',
#    'distance': 2313.301948098778},
#   {'id': '4wfFugovobVrqSQ77ppjaQ',
#    'alias': 'uncle-chop-chop-new-york',
#    'name': 'Uncle Chop Chop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/s0NZ3snI0WzuVNtit8VCcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uncle-chop-chop-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 71,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7316883151894,
#     'longitude': -74.0016427455464},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '7 Cornelia St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 Cornelia St', 'New York, NY 10014']},
#    'phone': '+19172615346',
#    'display_phone': '(917) 261-5346',
#    'distance': 2983.1471387428537},
#   {'id': 'QrfNvP4RSrQKxZ9d2NDefg',
#    'alias': 'firefly-flushing',
#    'name': 'Firefly',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Q1VWWskgH9n8v9zowd-WzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/firefly-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.758145, 'longitude': -73.787137},
#    'transactions': [],
#    'location': {'address1': '194-17 Northern Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11358',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['194-17 Northern Blvd', 'Flushing, NY 11358']},
#    'phone': '+17183140888',
#    'display_phone': '(718) 314-0888',
#    'distance': 18414.654935868428},
#   {'id': 'k5fd-RSdG4IuXnnGSQ5oOw',
#    'alias': 'san-marzano-pasta-fresca-new-york',
#    'name': 'San Marzano Pasta Fresca',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zdM-ivewN83FqN36dZHChw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/san-marzano-pasta-fresca-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1270,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.727966, 'longitude': -73.988382},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '117 Second Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['117 Second Ave', 'New York, NY 10003']},
#    'phone': '+12127773600',
#    'display_phone': '(212) 777-3600',
#    'distance': 2557.918277420454},
#   {'id': 'Xjswj531-FkRZPpcccU6kQ',
#    'alias': 'vida-verde-new-york',
#    'name': 'Vida Verde',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4VtXhki9jwY7yDXXA1p2eA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vida-verde-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1253,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7649503286729,
#     'longitude': -73.9828372257363},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '248 W 55th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['248 W 55th St', 'New York, NY 10019']},
#    'phone': '+16466570565',
#    'display_phone': '(646) 657-0565',
#    'distance': 6686.786631887716},
#   {'id': 'kDJbzzmCEjFbyDQ-lSygvw',
#    'alias': 'fresh-salt-new-york',
#    'name': 'Fresh Salt',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Rmf9kAAubededQTq1rzLIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fresh-salt-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 407,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70707, 'longitude': -74.00244},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '146 Beekman St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['146 Beekman St', 'New York, NY 10038']},
#    'phone': '+12129620053',
#    'display_phone': '(212) 962-0053',
#    'distance': 710.677389267444},
#   {'id': 'DhBhEWMVLDxYF14a1znUvA',
#    'alias': 'lighthouse-brooklyn-2',
#    'name': 'Lighthouse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y3zbJj3MQK-MUXnymqwBpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lighthouse-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 270,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7104080536563,
#     'longitude': -73.9539040490168},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '145 Borinquen Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['145 Borinquen Pl', 'Brooklyn, NY 11211']},
#    'phone': '+13477897742',
#    'display_phone': '(347) 789-7742',
#    'distance': 3448.867236343932},
#   {'id': 'trOfIBnEr_CxZuLRyGj9FQ',
#    'alias': 'miti-miti-brooklyn-2',
#    'name': 'Miti Miti',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bD1NjFE32z2ShYIX2FDSHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/miti-miti-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1232,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6786672454389,
#     'longitude': -73.9791200818081},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '138 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['138 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17182303760',
#    'display_phone': '(718) 230-3760',
#    'distance': 3240.7089537904526},
#   {'id': 'enT7NJ7tLMvUMCWQcsUonw',
#    'alias': 'mémé-mediterranean-new-york-4',
#    'name': 'Mémé Mediterranean',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TCo41uZ7WhL5MwMMjZ-RKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/m%C3%A9m%C3%A9-mediterranean-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 635,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.736412, 'longitude': -74.00616},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '581 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['581 Hudson St', 'New York, NY 10014']},
#    'phone': '+16466928450',
#    'display_phone': '(646) 692-8450',
#    'distance': 3585.669092216312},
#   {'id': '1raNn0l3I4H9PcAJce69Sw',
#    'alias': 'sojourn-new-york',
#    'name': 'Sojourn',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dk_4o5s8-m8LhF817w2OHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sojourn-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 659,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77343, 'longitude': -73.95568},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '244 E 79th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['244 E 79th St', 'New York, NY 10075']},
#    'phone': '+12125377745',
#    'display_phone': '(212) 537-7745',
#    'distance': 8220.461494566476},
#   {'id': 'TS2mqGtNhOzMKcSqJvrBPg',
#    'alias': 'ringolevio-brooklyn',
#    'name': 'Ringolevio',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2W63o7hWYZGduWRZ88kaJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ringolevio-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 286,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71907, 'longitude': -73.94337},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '490 Humboldt St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['490 Humboldt St', 'Brooklyn, NY 11222']},
#    'phone': '+13473350056',
#    'display_phone': '(347) 335-0056',
#    'distance': 4556.6594003186865},
#   {'id': 'FizBsTIAJwNrImIG1mPDcg',
#    'alias': 'barn-joo-new-york-3',
#    'name': 'Barn Joo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i7ReKaGzUGGXuisJFIV-RA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barn-joo-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1680,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73684, 'longitude': -73.99069},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '35 Union Sq W',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35 Union Sq W', 'New York, NY 10003']},
#    'phone': '+16463989663',
#    'display_phone': '(646) 398-9663',
#    'distance': 3509.0010091108297},
#   {'id': 'YDHUVTkQ5ioHaPOMVwQjWQ',
#    'alias': 'dagon-new-york',
#    'name': 'Dagon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IRK7QU8mjrkiUpW1ZpS9Yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dagon-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 85,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.791129, 'longitude': -73.973913},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '2454 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2454 Broadway', 'New York, NY 10024']},
#    'phone': '+12128732466',
#    'display_phone': '(212) 873-2466',
#    'distance': 9683.596155745181},
#   {'id': 'g7qtHQ_121mYWUdu3VWlrA',
#    'alias': 'tong-brooklyn',
#    'name': 'Tong',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yLdDN-6mdb07KblZKp1qhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tong-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 66,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.708053, 'longitude': -73.920502},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '321 Starr St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['321 Starr St', 'Brooklyn, NY 11237']},
#    'phone': '+17183660586',
#    'display_phone': '(718) 366-0586',
#    'distance': 6226.370732963361},
#   {'id': 'i8F0fnempD5fTb2CxbwKDw',
#    'alias': 'izakaya-new-york-2',
#    'name': 'Izakaya',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FHCms4PlmtuQJc4jo1wccw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 263,
#    'categories': [{'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72667, 'longitude': -73.98738},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '326 E 6th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['326 E 6th St', 'New York, NY 10003']},
#    'phone': '+19176977162',
#    'display_phone': '(917) 697-7162',
#    'distance': 2437.9568274699823},
#   {'id': 'By01mUaEhcjmQlmTHPz8Og',
#    'alias': 'circulo-espanol-astoria-3',
#    'name': 'Circulo Espanol',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/p7-Somt2_1GoOKVynlOrew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/circulo-espanol-astoria-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75871, 'longitude': -73.91785},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '41-01 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41-01 Broadway', 'Astoria, NY 11103']},
#    'phone': '+17186260872',
#    'display_phone': '(718) 626-0872',
#    'distance': 8754.130694123603},
#   {'id': 'ED2I3t5rOf81cddCsLA4tw',
#    'alias': 'terroir-tribeca-new-york',
#    'name': 'Terroir Tribeca',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Vuwfta5iVpV3VM6RKb6Xwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/terroir-tribeca-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 291,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.718804998517,
#     'longitude': -74.0099987815497},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '24 Harrison St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 Harrison St', 'New York, NY 10013']},
#    'phone': '+12126259463',
#    'display_phone': '(212) 625-9463',
#    'distance': 1989.7860911421576},
#   {'id': 'FXgSgiLg6xgOO8zrG51mzg',
#    'alias': 'claro-brooklyn',
#    'name': 'Claro',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2_n3ndzp6cJ367V_VI-qmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/claro-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 241,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'newmexican', 'title': 'New Mexican Cuisine'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6773587963142,
#     'longitude': -73.9861984489446},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '284 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['284 3rd Ave', 'Brooklyn, NY 11215']},
#    'phone': '+13477213126',
#    'display_phone': '(347) 721-3126',
#    'distance': 3196.727237508255},
#   {'id': '3qIISjUYn1tbqHXi7nCLXg',
#    'alias': 'sofia-wine-bar-new-york',
#    'name': 'Sofia Wine Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IDk9ljhlAmH_GFqgyglo-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sofia-wine-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 671,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75502, 'longitude': -73.96913},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '242 E 50th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['242 E 50th St', 'New York, NY 10022']},
#    'phone': '+12128888660',
#    'display_phone': '(212) 888-8660',
#    'distance': 5903.573820140736},
#   {'id': '5IGFJRN06HiclnivxaFThQ',
#    'alias': 'el-pote-español-restaurant-new-york-2',
#    'name': 'El Pote Español Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8YLnS41Rz-x10x0q2WMTCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-pote-espa%C3%B1ol-restaurant-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 191,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74754, 'longitude': -73.9735},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '718 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['718 2nd Ave', 'New York, NY 10016']},
#    'phone': '+12128896680',
#    'display_phone': '(212) 889-6680',
#    'distance': 4995.033517226137},
#   {'id': 'RYoc4EBUNOtgbg7c32OG9A',
#    'alias': 'atoboy-new-york',
#    'name': 'Atoboy',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/c6SEZBVmzZeqKsyH3TtmEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/atoboy-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 431,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74364, 'longitude': -73.98456},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '43 E 28th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43 E 28th St', 'New York, NY 10016']},
#    'phone': '+16464767217',
#    'display_phone': '(646) 476-7217',
#    'distance': 4328.417879979509},
#   {'id': 'MTtqSunPEZwdCJFMHsiHzg',
#    'alias': 'ai-ki-ya-new-york-3',
#    'name': 'Ai Ki Ya',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aTAJp9AEYJ3B-MGFDsHrQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ai-ki-ya-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74873, 'longitude': -73.98705},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '41 W 33rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41 W 33rd St', 'New York, NY 10001']},
#    'phone': '+12125486188',
#    'display_phone': '(212) 548-6188',
#    'distance': 4860.7090979919885},
#   {'id': 'hmdm-dO72hLsMQwQRcGEUQ',
#    'alias': 'atrium-dumbo-brooklyn',
#    'name': 'Atrium Dumbo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VUzaLCgAu6qYRSsVGZTDVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/atrium-dumbo-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 669,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7033899, 'longitude': -73.9904923},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '15 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Main St', 'Brooklyn, NY 11201']},
#    'phone': '+17188581095',
#    'display_phone': '(718) 858-1095',
#    'distance': 391.3077959872246}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#     Restaurant           Type Price Rating          Address        Lat  \
# 0       L'Wren  Cocktail Bars                  4004 5th Ave  40.650743
# 1        Galli        Italian    $$      4     45 Mercer St  40.721610
# 2  Oppa Bistro  Cocktail Bars    $$      4  162 West 4th St  40.731826
# 3         Bubo  Cocktail Bars    $$    4.5      515 3rd Ave  40.745980
# 4    Ampersand  Cocktail Bars    $$    4.5      294 3rd Ave  40.738618
#
#          Lng                                                url  \
# 0 -74.004913
# 1 -74.001270  https://www.yelp.com/biz/galli-new-york-5?adju...
# 2 -74.001390  https://www.yelp.com/biz/oppa-bistro-new-york?...
# 3 -73.977530  https://www.yelp.com/biz/bubo-new-york?adjust_...
# 4 -73.983421  https://www.yelp.com/biz/ampersand-new-york-2?...
#
#                        ID
# 0
# 1  twHJyFgUSd7wzioKQjE7Jw
# 2  rFhI8Gedy7XQksVD-ixOHw
# 3  vlepW-Y_RDQaDMLtEwHWmg
# 4  ePqKbqXFBCbwBaWiN2Jo9w

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"tapas","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [{'id': 'tW8a8-MX_lVoshmKRLUuHQ',
#    'alias': 'caracas-arepa-bar-brooklyn',
#    'name': 'Caracas Arepa Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nuuP2qg5hIq0AvfkWejIYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caracas-arepa-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 836,
#    'categories': [{'alias': 'venezuelan', 'title': 'Venezuelan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.713214, 'longitude': -73.957397},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '291 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['291 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17182186050',
#    'display_phone': '(718) 218-6050',
#    'distance': 3224.3077213254223},
#   {'id': '4KzqwQus39gXgrwrDXAjWA',
#    'alias': 'eléa-new-york',
#    'name': 'Eléa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cFF7gz4D1OQn-kdWh6qZdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el%C3%A9a-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 154,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78754, 'longitude': -73.9765199},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '217 W 85th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['217 W 85th St', 'New York, NY 10024']},
#    'phone': '+12123699800',
#    'display_phone': '(212) 369-9800',
#    'distance': 9255.428335342775},
#   {'id': '_FhKGcCbiYgtkXcCiwTAiA',
#    'alias': 'aburiya-kinnosuke-new-york',
#    'name': 'Aburiya Kinnosuke',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/R-OczJWhCtsCQhWc7Ff-EQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aburiya-kinnosuke-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 761,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.752583, 'longitude': -73.972274},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '213 E 45th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['213 E 45th St', 'New York, NY 10017']},
#    'phone': '+12128675454',
#    'display_phone': '(212) 867-5454',
#    'distance': 5560.223450920015},
#   {'id': 'lnTPfdaqDqWjywWewsE2Lw',
#    'alias': 'miriam-brooklyn-2',
#    'name': 'Miriam',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tONRUqmVXTshXUq6dePMSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/miriam-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1064,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6801719843659,
#     'longitude': -73.9777555239717},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '79 5th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17186222250',
#    'display_phone': '(718) 622-2250',
#    'distance': 3137.090123467059},
#   {'id': '9QK3vhI04Q8ylqk49C3JcQ',
#    'alias': 'rule-of-thirds-brooklyn',
#    'name': 'Rule of Thirds',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/z3wcWXhTpcFm-yTiQgwekQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rule-of-thirds-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 110,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7246328, 'longitude': -73.9551096},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '171 Banker St',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 Banker St', 'Brooklyn, NY 11222']},
#    'phone': '+13473346684',
#    'display_phone': '(347) 334-6684',
#    'distance': 3944.454297372159},
#   {'id': '_em8dL1HhMPFGkG_i-M0rA',
#    'alias': 'don-tapas-long-island-city',
#    'name': 'Don Tapas',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7JTFkp_OI3F56iJUdP7Xrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/don-tapas-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.742807, 'longitude': -73.935556},
#    'transactions': ['pickup'],
#    'price': '$',
#    'location': {'address1': '3100 47th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3100 47th Ave', 'Long Island City, NY 11101']},
#    'phone': '+13478502575',
#    'display_phone': '(347) 850-2575',
#    'distance': 6462.202905490942},
#   {'id': 'xkvv0n7jbl4Ra3Vm_jfxaA',
#    'alias': 'upland-new-york',
#    'name': 'Upland',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aaHIBePLehwF_llzTIdg1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/upland-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1078,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7418912, 'longitude': -73.9846396},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '345 Park Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['345 Park Ave S', 'New York, NY 10010']},
#    'phone': '+12126861006',
#    'display_phone': '(212) 686-1006',
#    'distance': 4133.488189568971},
#   {'id': '9DPI1WLAOfpiMXxHeQ0swg',
#    'alias': 'tailfeather-new-york',
#    'name': 'Tailfeather',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BU9K-kSLRnJ4GN5AvjEKLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tailfeather-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.69415, 'longitude': -73.96089},
#    'transactions': ['delivery'],
#    'location': {'address1': '581 Myrtle Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['581 Myrtle Ave', 'New York, NY 11205']},
#    'phone': '+13472405915',
#    'display_phone': '(347) 240-5915',
#    'distance': 3078.046336577469},
#   {'id': 'yGQT6OZ-nNIhTKj32wRlmA',
#    'alias': 'bar-bolinas-clinton-hill',
#    'name': 'Bar Bolinas',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1q0ybwr2AmnYiznbEnYDWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-bolinas-clinton-hill?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 127,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.693499, 'longitude': -73.967389},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '455 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Clinton Hill',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['455 Myrtle Ave', 'Clinton Hill, NY 11205']},
#    'phone': '+17189359331',
#    'display_phone': '(718) 935-9331',
#    'distance': 2630.3859320936035},
#   {'id': 'khM6CxlYEY7otMW5ba0CCw',
#    'alias': 'manchego-koko-brooklyn-5',
#    'name': 'Manchego Koko',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/al9rhAAOzpLAIGMSAOACYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/manchego-koko-brooklyn-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 153,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.641022, 'longitude': -73.96426},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1502 Cortelyou Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11226',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1502 Cortelyou Rd', 'Brooklyn, NY 11226']},
#    'phone': '+13474258511',
#    'display_phone': '(347) 425-8511',
#    'distance': 7597.209798920746},
#   {'id': 'IHLGmtOkqm8Qm3Ny8yjfVA',
#    'alias': 'pata-paplean-elmhurst',
#    'name': 'Pata Paplean',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ectHd2wXvXG5Mh23FXgU1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pata-paplean-elmhurst?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7435901462143,
#     'longitude': -73.8880684963577},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '76-21 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['76-21 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17186512076',
#    'display_phone': '(718) 651-2076',
#    'distance': 9905.57046768824},
#   {'id': 'SXWnyFNLCehVlJPRxk7gAg',
#    'alias': 'anejo-tribeca-new-york-3',
#    'name': 'Anejo Tribeca',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_fuWOS5dG8GL2oyWkn1L5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anejo-tribeca-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 536,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7193829, 'longitude': -74.004417},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '301 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['301 Church St', 'New York, NY 10013']},
#    'phone': '+12129206270',
#    'display_phone': '(212) 920-6270',
#    'distance': 1769.2048160174595},
#   {'id': 'g6R8iwi__IDy8plQy0v9WQ',
#    'alias': 'café-gitane-new-york-3',
#    'name': 'Café Gitane',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IZYz7cLHVGrGMMNKwaEsug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-gitane-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 715,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'moroccan', 'title': 'Moroccan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7231802723335,
#     'longitude': -73.9946175625656},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '242 Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['242 Mott St', 'New York, NY 10012']},
#    'phone': '+12123349552',
#    'display_phone': '(212) 334-9552',
#    'distance': 1972.2746550749027},
#   {'id': 'Pf3tk5fYN-GVxXWRokjIWg',
#    'alias': 'colonia-verde-brooklyn',
#    'name': 'Colonia Verde',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4Z-XMHBCr4p0SfiYdE10Ug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/colonia-verde-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 190,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6897354125977, 'longitude': -73.970703125},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '219 Dekalb Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['219 Dekalb Ave', 'Brooklyn, NY 11205']},
#    'phone': '+13476894287',
#    'display_phone': '(347) 689-4287',
#    'distance': 2648.9809339145722},
#   {'id': 'WIe7Qi3uOoMKU2ZbHfTGew',
#    'alias': 'mazzat-brooklyn',
#    'name': 'Mazzat',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wOhfsGxpNien558xtOy_Lw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mazzat-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 205,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68495, 'longitude': -74.00289},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '208 Columbia St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['208 Columbia St', 'Brooklyn, NY 11231']},
#    'phone': '+17188521652',
#    'display_phone': '(718) 852-1652',
#    'distance': 2390.3721001219833},
#   {'id': 'OAqsZMbjv66nOMqlimnYuQ',
#    'alias': 'uva-new-york',
#    'name': 'Uva',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Dv_IaSo7QTUrRRtclijk2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uva-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2482,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7722, 'longitude': -73.95566},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1486 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1486 2nd Ave', 'New York, NY 10075']},
#    'phone': '+12124724552',
#    'display_phone': '(212) 472-4552',
#    'distance': 8104.693377840111},
#   {'id': 'pBNMZp_tKCAfRNx7-ybcHQ',
#    'alias': 'calle-dao-chelsea-new-york',
#    'name': 'Calle Dao - Chelsea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/135HuozBP6evKZQGjH3wpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/calle-dao-chelsea-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 796,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74769301, 'longitude': -74.00350737},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '461 W 23rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['461 W 23rd St', 'New York, NY 10011']},
#    'phone': '+12124144104',
#    'display_phone': '(212) 414-4104',
#    'distance': 4761.507725279524},
#   {'id': 'IOHaEgK1zDvUvB3SfKuGCw',
#    'alias': 'parker-and-quinn-new-york',
#    'name': 'Parker & Quinn',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6xuN0yyAi9PaxSAVVAgfrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/parker-and-quinn-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1387,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7525862175813,
#     'longitude': -73.9850713153442},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '64 W 39th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64 W 39th St', 'New York, NY 10018']},
#    'phone': '+12127290277',
#    'display_phone': '(212) 729-0277',
#    'distance': 5299.158389411888},
#   {'id': 'TAANt0fPbfHqVP5LyMBioA',
#    'alias': 'kashkaval-garden-new-york',
#    'name': 'Kashkaval Garden',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ouDsPeDuZmtubfCmJcjP0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kashkaval-garden-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 593,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'fondue', 'title': 'Fondue'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76680229936593,
#     'longitude': -73.986219866559},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '852 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['852 9th Ave', 'New York, NY 10019']},
#    'phone': '+12122451758',
#    'display_phone': '(212) 245-1758',
#    'distance': 6856.453086343799},
#   {'id': '1ozuYD1HTa4u2F_NR9uUJg',
#    'alias': 'gomi-korean-wine-bar-new-york-2',
#    'name': 'Gomi Korean Wine Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xKv7_kBtdIM4OrggPdcZCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gomi-korean-wine-bar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 142,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72886, 'longitude': -73.9813},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '186 Ave A',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['186 Ave A', 'New York, NY 10009']},
#    'phone': '+16467070707',
#    'display_phone': '(646) 707-0707',
#    'distance': 2823.8442206479995},
#   {'id': 'E9NMNWvV70HV5gB369N0EA',
#    'alias': 'nerai-new-york',
#    'name': 'Nerai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WXgS2EwgJLkTLWD2PS3bmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nerai-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 566,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76028044523875,
#     'longitude': -73.97306024442727},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '55 E 54th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 E 54th St', 'New York, NY 10022']},
#    'phone': '+12127595554',
#    'display_phone': '(212) 759-5554',
#    'distance': 6354.481726623936},
#   {'id': '1p4dUaLyzIhN5n1lJnHSgA',
#    'alias': 'bustan-new-york',
#    'name': 'Bustan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4i6dByvhq6WZWYJhCZZpyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bustan-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 520,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7859082, 'longitude': -73.9759551},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '487 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['487 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12125955050',
#    'display_phone': '(212) 595-5050',
#    'distance': 9079.496374280274},
#   {'id': 'LpVbI-E9C-CSp7WhU5h2Iw',
#    'alias': 'fishmarket-restaurant-new-york',
#    'name': 'Fishmarket Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zIPbObERXHKehqV-yU7Wgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fishmarket-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 579,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'divebars', 'title': 'Dive Bars'},
#     {'alias': 'malaysian', 'title': 'Malaysian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70717, 'longitude': -74.00192},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '111 South St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 South St', 'New York, NY 10038']},
#    'phone': '+19173638101',
#    'display_phone': '(917) 363-8101',
#    'distance': 667.9406968270184},
#   {'id': 'IbHTKBJmodymKD4MpKwuAQ',
#    'alias': 'cravings-tapas-bistro-ridgewood',
#    'name': 'Cravings Tapas Bistro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7aHRMJXCiyyAbxCGuPbYLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cravings-tapas-bistro-ridgewood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 295,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.9798881861691, 'longitude': -74.121748},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '8 Wilsey Sq',
#     'address2': '',
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '07450',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['8 Wilsey Sq', 'Ridgewood, NJ 07450']},
#    'phone': '+12018578533',
#    'display_phone': '(201) 857-8533',
#    'distance': 32345.26854911709},
#   {'id': 'N_iUh4REefckkA0zLm9TeA',
#    'alias': 'plancha-tapas-and-wine-bar-garden-city',
#    'name': 'Plancha Tapas and Wine Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U2kaycGsxqcpc-V7FllNCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/plancha-tapas-and-wine-bar-garden-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 458,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7287204, 'longitude': -73.6350924},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '931 Franklin Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Garden City',
#     'zip_code': '11530',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['931 Franklin Ave', 'Garden City, NY 11530']},
#    'phone': '+15162469459',
#    'display_phone': '(516) 246-9459',
#    'distance': 30383.485826878787},
#   {'id': 'UKDOoYu_g1HYBvs5TpdG6w',
#    'alias': 'amor-cubano-new-york',
#    'name': 'Amor Cubano',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/k9tUealxbpvgWedq2HHBJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amor-cubano-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 525,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.794776, 'longitude': -73.942703},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2018 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2018 3rd Ave', 'New York, NY 10029']},
#    'phone': '+12129961220',
#    'display_phone': '(212) 996-1220',
#    'distance': 10840.610500337569},
#   {'id': 'pfmAcS-g6SiNG0KlLvrqnA',
#    'alias': 'beauty-and-essex-new-york-2',
#    'name': 'Beauty & Essex',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/T0KCvQyqHSClgUQhO02slQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beauty-and-essex-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3548,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720434786101286,
#     'longitude': -73.98686057623863},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '146 Essex St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['146 Essex St', 'New York, NY 10002']},
#    'phone': '+12126140146',
#    'display_phone': '(212) 614-0146',
#    'distance': 1780.637937184024},
#   {'id': 'ZgyvDF_hOWas3SXe0Hj7hA',
#    'alias': 'schilling-new-york',
#    'name': 'Schilling',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HCce24K-JLgFm4L5KzV28Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/schilling-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 165,
#    'categories': [{'alias': 'austrian', 'title': 'Austrian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70857, 'longitude': -74.014},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '109 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10006',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['109 Washington St', 'New York, NY 10006']},
#    'phone': '+12124061200',
#    'display_phone': '(212) 406-1200',
#    'distance': 1694.618934732702},
#   {'id': 'c_Kellz-oODKoNpcRbV24w',
#    'alias': 'mono-mono-new-york-9',
#    'name': 'MONO+MONO',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vcJFs8sLfHBUozLtrpJ__g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mono-mono-new-york-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 538,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72549, 'longitude': -73.98803},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '116 E 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['116 E 4th St', 'New York, NY 10003']},
#    'phone': '+13476202431',
#    'display_phone': '(347) 620-2431',
#    'distance': 2282.2109157307914},
#   {'id': 'zwOAiVT4pAmpNGXzj-t5MA',
#    'alias': 'lilia-brooklyn',
#    'name': 'Lilia',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CVDfrE84IWv9v-Y86jqlRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lilia-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 921,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71757, 'longitude': -73.95236},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '567 Union Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['567 Union Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17185763095',
#    'display_phone': '(718) 576-3095',
#    'distance': 3776.4789584058713},
#   {'id': 'J3NT61-AH5d5Gu5tFJhYSw',
#    'alias': 'the-cabin-nyc-new-york-2',
#    'name': 'The Cabin NYC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XEdD6R1D3DtTVKkc5U48Cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cabin-nyc-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 333,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72393, 'longitude': -73.98383},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '205 E 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['205 E 4th St', 'New York, NY 10009']},
#    'phone': '+12127770454',
#    'display_phone': '(212) 777-0454',
#    'distance': 2240.673403602855},
#   {'id': 'OkiPb6gNNRmcbB4zIIMx0g',
#    'alias': 'big-tiny-brooklyn-4',
#    'name': 'Big Tiny',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HVKFUDb7zcv4Hytu7qWcTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/big-tiny-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6834507, 'longitude': -73.992855},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '244 Smith St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['244 Smith St', 'Brooklyn, NY 11231']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2448.640731099753},
#   {'id': 'vgg1dvDP-9tFWSacN4q0nA',
#    'alias': 'coppelia-new-york',
#    'name': 'Coppelia',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sXzxZcMCd5ZH2RzZ26QJZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coppelia-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1390,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7389111700125,
#     'longitude': -73.9999985153443},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '207 W 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['207 W 14th St', 'New York, NY 10011']},
#    'phone': '+12128585001',
#    'display_phone': '(212) 858-5001',
#    'distance': 3752.211111171991},
#   {'id': 'MxE0X8ayNGii9zA2i2ZERA',
#    'alias': 'snack-taverna-new-york',
#    'name': 'Snack Taverna',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/as3cDn9pWQbNoQJZEbmVTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/snack-taverna-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 346,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.731033, 'longitude': -74.004814},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '63 Bedford St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63 Bedford St', 'New York, NY 10014']},
#    'phone': '+12129293499',
#    'display_phone': '(212) 929-3499',
#    'distance': 2980.3515196916433},
#   {'id': 'LpIpG7klTOl_btqxNkp-Vw',
#    'alias': 'ernesto-s-new-york',
#    'name': 'Ernesto’s',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ySKuRBP_-klyNQtbhsjADg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ernesto-s-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71429, 'longitude': -73.9854371},
#    'transactions': ['delivery'],
#    'location': {'address1': '259 E Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['259 E Broadway', 'New York, NY 10002']},
#    'phone': '+16466928300',
#    'display_phone': '(646) 692-8300',
#    'distance': 1234.7256324045454},
#   {'id': 'bQraKjILxZGN1GNKt5XUKA',
#    'alias': 'ramona-brooklyn',
#    'name': 'Ramona',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eLOcco_GhCv6qHr2HdpDvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramona-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 138,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7302444236037,
#     'longitude': -73.9578210900354},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '113 Franklin St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['113 Franklin St', 'Brooklyn, NY 11222']},
#    'phone': '+13472278164',
#    'display_phone': '(347) 227-8164',
#    'distance': 4129.46636585005},
#   {'id': 'mXLrVoEi80WZaZ3agBP5Jw',
#    'alias': 'bijans-brooklyn-2',
#    'name': "Bijan's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VJmLtQJ2tXq9qjlhGGMVxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bijans-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 608,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68803, 'longitude': -73.98671},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '81 Hoyt St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81 Hoyt St', 'Brooklyn, NY 11211']},
#    'phone': '+17188555574',
#    'display_phone': '(718) 855-5574',
#    'distance': 2045.4454607339076},
#   {'id': 'WqjqHMozyW42XLTtLnKGag',
#    'alias': 'la-pulperia-hells-kitchen-new-york',
#    'name': "La Pulperia Hell's Kitchen",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fyNGpzJ4aB_ehHO-nb4IpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-pulperia-hells-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 803,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7599217, 'longitude': -73.991841},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '623 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['623 9th Ave', 'New York, NY 10036']},
#    'phone': '+16466698984',
#    'display_phone': '(646) 669-8984',
#    'distance': 6061.063900139357},
#   {'id': 'nrwOQSXoRXfAYhkdjiUk8g',
#    'alias': 'toro-loco-new-york',
#    'name': 'Toro Loco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uBhe_gNq53jqkdtPmBM_Lw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/toro-loco-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 333,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70421, 'longitude': -74.01208},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '15 Stone St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Stone St', 'New York, NY 10004']},
#    'phone': '+19172620444',
#    'display_phone': '(917) 262-0444',
#    'distance': 1509.416353803401},
#   {'id': 'Ulr_Nyp2nvt82EPH_BiftA',
#    'alias': 'olmsted-brooklyn',
#    'name': 'Olmsted',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SfKomS2m7FzsYcuVXjcEjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olmsted-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 418,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67713, 'longitude': -73.96869},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '659 Vanderbilt Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['659 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17185522610',
#    'display_phone': '(718) 552-2610',
#    'distance': 3821.0655417471244},
#   {'id': '2zWDqKAq8B3rC5ydFFrN1g',
#    'alias': 'sangria-71-williston-park',
#    'name': 'Sangria 71',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Jd3r9LjeaTa-e8JZMv7ckw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sangria-71-williston-park?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 458,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7573097, 'longitude': -73.6420024},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '71 Hillside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Williston Park',
#     'zip_code': '11596',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['71 Hillside Ave', 'Williston Park, NY 11596']},
#    'phone': '+15162469778',
#    'display_phone': '(516) 246-9778',
#    'distance': 30239.339906158937},
#   {'id': 'upaVTWhLsxcu1HXqN8iHVQ',
#    'alias': 'ladybird-new-york',
#    'name': 'Ladybird',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i-DTQD4m9DkmN8kFtst07A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ladybird-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 343,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.726769311104,
#     'longitude': -73.9847712789363},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '111 East 7th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 East 7th St', 'New York, NY 10009']},
#    'phone': '+18333284588',
#    'display_phone': '(833) 328-4588',
#    'distance': 2503.289690803383},
#   {'id': 'xTWpl9DgIkkr5B8h8_xUpA',
#    'alias': 'lokal-83-mediterranean-kitchen-new-york-2',
#    'name': 'Lokal 83 Mediterranean Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GcrWkRztvAX2S-Eb1PtkzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lokal-83-mediterranean-kitchen-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 389,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7842696, 'longitude': -73.9734941},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '473 Columbus Ave',
#     'address2': '83rd street',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['473 Columbus Ave',
#      '83rd street',
#      'New York, NY 10024']},
#    'phone': '+12125955554',
#    'display_phone': '(212) 595-5554',
#    'distance': 8938.326441181493},
#   {'id': 'Nnc2RVv5TPNAy70gOJrc-Q',
#    'alias': 'moonrise-izakaya-new-york',
#    'name': 'Moonrise Izakaya',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/toD_Mwb4skZ9QtHzAyWP6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moonrise-izakaya-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 126,
#    'categories': [{'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.795399, 'longitude': -73.969762},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '774 Amsterdam Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['774 Amsterdam Ave', 'New York, NY 10025']},
#    'phone': '+16465412506',
#    'display_phone': '(646) 541-2506',
#    'distance': 10211.406967168303},
#   {'id': 'Gfo-8z_CMOpHZVhX-HKD0g',
#    'alias': 'vanguard-wine-bar-new-york-2',
#    'name': 'Vanguard Wine Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/As7Q3Re3FDsAKvOvwN7gPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vanguard-wine-bar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 172,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77643, 'longitude': -73.983},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '189 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['189 Amsterdam Ave', 'New York, NY 10023']},
#    'phone': '+12127999463',
#    'display_phone': '(212) 799-9463',
#    'distance': 7936.817088572986},
#   {'id': 'Rc1lxc5lSKJYd162JHNMfQ',
#    'alias': 'bea-new-york',
#    'name': 'Bea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m2d14AiiBqqly1gpMyU2RQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bea-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2517,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7591968, 'longitude': -73.9923361},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '403 W 43rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['403 W 43rd St', 'New York, NY 10036']},
#    'phone': '+12126021910',
#    'display_phone': '(212) 602-1910',
#    'distance': 5979.210371091945},
#   {'id': 'iPc-zPgcpgeSo76xl5Jbpw',
#    'alias': 'the-maze-new-york-3',
#    'name': 'The Maze',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hPYHRfgxCwzPF5HVpXqyQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-maze-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 513,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.747846, 'longitude': -73.9872499},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '32 W 32nd St',
#     'address2': 'Fl 3',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 W 32nd St', 'Fl 3', 'New York, NY 10001']},
#    'phone': '+16469187519',
#    'display_phone': '(646) 918-7519',
#    'distance': 4751.996403737684},
#   {'id': 'Sj3JYCbaEFrAqUzRrenQbg',
#    'alias': 'jora-restaurant-and-bar-long-island-city',
#    'name': 'Jora Restaurant & Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CwblGUtXfY8noC1JrQUZ2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jora-restaurant-and-bar-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 756,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7438054, 'longitude': -73.9515007},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '47-46 11th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47-46 11th St', 'Long Island City, NY 11101']},
#    'phone': '+17183922033',
#    'display_phone': '(718) 392-2033',
#    'distance': 5585.551264105366},
#   {'id': '7DnZWIn1Dcsvq-_pIXXFZQ',
#    'alias': 'hortus-nyc-new-york',
#    'name': 'Hortus NYC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BFyIS0Y1BlwL_t9QHuzBJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hortus-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 277,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.745481, 'longitude': -73.986518},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '271 5th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['271 5th Ave', 'New York, NY 10016']},
#    'phone': '+16468583784',
#    'display_phone': '(646) 858-3784',
#    'distance': 4499.76744743394},
#   {'id': 'H9GD7km7riFooM0FkdwOPg',
#    'alias': 'calle-ocho-new-york',
#    'name': 'Calle Ocho',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nl43-8g5SiafOJlKlc51Pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/calle-ocho-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2554,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.801264, 'longitude': -73.967663},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2756 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2756 Broadway', 'New York, NY 10025']},
#    'phone': '+12128735025',
#    'display_phone': '(212) 873-5025',
#    'distance': 10888.157641559588}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#           Restaurant                Type Price Rating        Address  \
# 0  Caracas Arepa Bar          Venezuelan    $$      4   291 Grand St
# 1               Eléa       Mediterranean               217 W 85th St
# 2  Aburiya Kinnosuke  Tapas/Small Plates   $$$      4  213 E 45th St
# 3             Miriam           Wine Bars    $$      4     79 5th Ave
# 4     Rule of Thirds  Breakfast & Brunch               171 Banker St
#
#          Lat        Lng                                                url  \
# 0  40.713214 -73.957397  https://www.yelp.com/biz/caracas-arepa-bar-bro...
# 1  40.787540 -73.976520
# 2  40.752583 -73.972274  https://www.yelp.com/biz/aburiya-kinnosuke-new...
# 3  40.680172 -73.977756  https://www.yelp.com/biz/miriam-brooklyn-2?adj...
# 4  40.724633 -73.955110
#
#                        ID
# 0  tW8a8-MX_lVoshmKRLUuHQ
# 1
# 2  _FhKGcCbiYgtkXcCiwTAiA
# 3  lnTPfdaqDqWjywWewsE2Lw
# 4

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                        Restaurant                   Type Rating Price  \
# 0                      Cellar 335         American (New)    4.5    $$
# 1                          Upland         American (New)      4   $$$
# 2     Hold Fast Kitchen & Spirits         American (New)      5    $$
# 3                    Atrium Dumbo         American (New)      4    $$
# 4                  Parker & Quinn         American (New)      4    $$
# 5                         Sojourn         American (New)      4    $$
# 6                   21 Greenpoint         American (New)      4   $$$
# 7                    The Spaniard         American (New)      4    $$
# 8                  Beauty & Essex         American (New)      4   $$$
# 9                   The Cabin NYC         American (New)      4    $$
# 10                         Anella         American (New)      4    $$
# 11            The Beast Next Door         American (New)    4.5    $$
# 12                          Traif         American (New)    4.5  $$$$
# 13                        Bijan's         American (New)      4    $$
# 14                     The Osprey         American (New)      4    $$
# 15                        Olmsted         American (New)      4   $$$
# 16                            Bea         American (New)      4    $$
# 17                           Otis         American (New)      5    $$
# 18                    Bar Bolinas         American (New)      4    $$
# 19                        Firefly           Asian Fusion
# 20                     Hortus NYC           Asian Fusion    4.5   $$$
# 21                      Schilling               Austrian      4    $$
# 22                     Lo-Res Bar                   Bars    4.5    $$
# 23                          Dagon                   Bars    4.5   $$$
# 24                     Fresh Salt                   Bars      4    $$
# 25               Excuse My French                   Bars    4.5    $$
# 26                   Pata Paplean                   Bars      4    $$
# 27                         Haizea                 Basque
# 28                      Ernesto’s                 Basque
# 29                  Samba Kitchen              Brazilian    4.5    $$
# ..                            ...                    ...    ...   ...
# 170                         Leyla                Turkish
# 171                      Ladybird                  Vegan      4    $$
# 172             Caracas Arepa Bar             Venezuelan      4    $$
# 173                       My Moon  Venues & Event Spaces      4   $$$
# 174                        Anfora              Wine Bars      4    $$
# 175                      Brookvin              Wine Bars      4    $$
# 176            La Sala by Tu Casa              Wine Bars
# 177             Vanguard Wine Bar              Wine Bars      4    $$
# 178                  Local & Vine              Wine Bars    4.5    $$
# 179              Ardesia Wine Bar              Wine Bars      4   $$$
# 180                 The Ten Bells              Wine Bars    3.5    $$
# 181                          June              Wine Bars      4    $$
# 182        St Tropez West Village              Wine Bars    4.5    $$
# 183                      Big Tiny              Wine Bars    4.5    $$
# 184                    Lighthouse              Wine Bars      4    $$
# 185                        Miriam              Wine Bars      4    $$
# 186  Addictive Wine and Tapas Bar              Wine Bars    4.5    $$
# 187                   Tailfeather              Wine Bars
# 188                          bibi              Wine Bars    4.5    $$
# 189                    The Cellar              Wine Bars      4    $$
# 190                        Sauced              Wine Bars
# 191                          Lena              Wine Bars
# 192          Gomi Korean Wine Bar              Wine Bars    4.5    $$
# 193               Terroir Tribeca              Wine Bars      4    $$
# 194                 The Poni Room              Wine Bars
# 195                       Ruffian              Wine Bars    4.5    $$
# 196                Lamano Chelsea              Wine Bars      4    $$
# 197        Tomiño Taberna Gallega              Wine Bars    4.5   $$$
# 198             The Four Horsemen              Wine Bars    4.5    $$
# 199                    Tavern 157              Wine Bars    4.5    $$
#
#                     Address        Lat        Lng  \
# 0            335 Newark Ave  40.724969 -74.051519
# 1            345 Park Ave S  40.741891 -73.984640
# 2             364 W 46th St  40.760640 -73.990230
# 3                15 Main St  40.703390 -73.990492
# 4              64 W 39th St  40.752586 -73.985071
# 5             244 E 79th St  40.773430 -73.955680
# 6         21 Greenpoint Ave  40.729780 -73.959920
# 7              190 W 4th St  40.732750 -74.002183
# 8              146 Essex St  40.720435 -73.986861
# 9              205 E 4th St  40.723930 -73.983830
# 10          222 Franklin St  40.733270 -73.957860
# 11            42-51 27th St  40.748810 -73.940730
# 12             229 S 4th St  40.710658 -73.958872
# 13               81 Hoyt St  40.688030 -73.986710
# 14             60 Furman St  40.702241 -73.995539
# 15       659 Vanderbilt Ave  40.677130 -73.968690
# 16            403 W 43rd St  40.759197 -73.992336
# 17           18 Harrison Pl  40.706011 -73.932598
# 18           455 Myrtle Ave  40.693499 -73.967389
# 19     194-17 Northern Blvd  40.758145 -73.787137
# 20              271 5th Ave  40.745481 -73.986518
# 21        109 Washington St  40.708570 -74.014000
# 22     136 Metropolitan Ave  40.715984 -73.962577
# 23            2454 Broadway  40.791129 -73.973913
# 24           146 Beekman St  40.707070 -74.002440
# 25            96 Orchard St  40.718440 -73.989810
# 26       76-21 Woodside Ave  40.743590 -73.888068
# 27          142 Sullivan St  40.727052 -74.002063
# 28           259 E Broadway  40.714290 -73.985437
# 29            457 W 50th St  40.764666 -73.991264
# ..                      ...        ...        ...
# 170           108 W 74th St  40.778820 -73.978340
# 171         111 East 7th St  40.726769 -73.984771
# 172            291 Grand St  40.713214 -73.957397
# 173           184 N 10th St  40.718859 -73.955217
# 174              34 8th Ave  40.737890 -74.004080
# 175             381 7th Ave  40.665253 -73.982567
# 176  11635 Metropolitan Ave  40.707369 -73.835057
# 177       189 Amsterdam Ave  40.776430 -73.983000
# 178           282 Hudson St  40.725280 -74.007400
# 179           510 W 52nd St  40.766083 -73.991458
# 180           247 Broome St  40.717801 -73.989850
# 181            231 Court St  40.686065 -73.993889
# 182            304 W 4th St  40.737040 -74.003860
# 183            244 Smith St  40.683451 -73.992855
# 184        145 Borinquen Pl  40.710408 -73.953904
# 185              79 5th Ave  40.680172 -73.977756
# 186     87-01 Northern Blvd  40.756320 -73.880600
# 187          581 Myrtle Ave  40.694150 -73.960890
# 188            211 E 4th St  40.723937 -73.983519
# 189            900 Broadway  40.738890 -73.989700
# 190         331 Bedford Ave  40.712670 -73.962319
# 191          1B West 8th St  40.732552 -73.996704
# 192               186 Ave A  40.728860 -73.981300
# 193          24 Harrison St  40.718805 -74.009999
# 194              316 Bowery  40.725210 -73.992470
# 195            125 E 7th St  40.726400 -73.984110
# 196           265 W 20th St  40.743380 -73.999426
# 197            192 Grand St  40.719298 -73.996916
# 198            295 Grand St  40.713050 -73.957320
# 199    157-12 Northern Blvd  40.763484 -73.807817
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/cellar-335-jersey-cit...  _hvgCRW8Vw1n3Usr9RPoUg
# 1    https://www.yelp.com/biz/upland-new-york?adjus...  xkvv0n7jbl4Ra3Vm_jfxaA
# 2    https://www.yelp.com/biz/hold-fast-kitchen-and...  VLGmFHE4s0Sfu0piMVQa1Q
# 3    https://www.yelp.com/biz/atrium-dumbo-brooklyn...  hmdm-dO72hLsMQwQRcGEUQ
# 4    https://www.yelp.com/biz/parker-and-quinn-new-...  IOHaEgK1zDvUvB3SfKuGCw
# 5    https://www.yelp.com/biz/sojourn-new-york?adju...  1raNn0l3I4H9PcAJce69Sw
# 6    https://www.yelp.com/biz/21-greenpoint-brookly...  f-WkzzSaAA_mdDmsKlJ4sw
# 7    https://www.yelp.com/biz/the-spaniard-new-york...  XO3yD87rTPz9o6Dy9qRaJg
# 8    https://www.yelp.com/biz/beauty-and-essex-new-...  pfmAcS-g6SiNG0KlLvrqnA
# 9    https://www.yelp.com/biz/the-cabin-nyc-new-yor...  J3NT61-AH5d5Gu5tFJhYSw
# 10   https://www.yelp.com/biz/anella-brooklyn?adjus...  J5y7oRfiGtxFDkYGKxFZkw
# 11   https://www.yelp.com/biz/the-beast-next-door-l...  UF9F0A4e7AJHzNPG5zrHUQ
# 12   https://www.yelp.com/biz/traif-brooklyn?adjust...  qLLxS7RwNEjP_jq_KQrPfA
# 13   https://www.yelp.com/biz/bijans-brooklyn-2?adj...  mXLrVoEi80WZaZ3agBP5Jw
# 14   https://www.yelp.com/biz/the-osprey-brooklyn?a...  q11TljTQd33XCWlVoPyRqg
# 15   https://www.yelp.com/biz/olmsted-brooklyn?adju...  Ulr_Nyp2nvt82EPH_BiftA
# 16   https://www.yelp.com/biz/bea-new-york?adjust_c...  Rc1lxc5lSKJYd162JHNMfQ
# 17   https://www.yelp.com/biz/otis-brooklyn-2?adjus...  RfxOtJ4SQmEeVX_XjFLWUQ
# 18   https://www.yelp.com/biz/bar-bolinas-clinton-h...  yGQT6OZ-nNIhTKj32wRlmA
# 19
# 20   https://www.yelp.com/biz/hortus-nyc-new-york?a...  7DnZWIn1Dcsvq-_pIXXFZQ
# 21   https://www.yelp.com/biz/schilling-new-york?ad...  ZgyvDF_hOWas3SXe0Hj7hA
# 22   https://www.yelp.com/biz/lo-res-bar-brooklyn?a...  YxLazl79hS4O_ygHWqM3mg
# 23   https://www.yelp.com/biz/dagon-new-york?adjust...  YDHUVTkQ5ioHaPOMVwQjWQ
# 24   https://www.yelp.com/biz/fresh-salt-new-york?a...  kDJbzzmCEjFbyDQ-lSygvw
# 25   https://www.yelp.com/biz/excuse-my-french-new-...  iexl39DYyy_76Xq3ExaJkQ
# 26   https://www.yelp.com/biz/pata-paplean-elmhurst...  IHLGmtOkqm8Qm3Ny8yjfVA
# 27
# 28
# 29   https://www.yelp.com/biz/samba-kitchen-new-yor...  aJqjC4uAo6vhOpsVNCiMDA
# ..                                                 ...                     ...
# 170
# 171  https://www.yelp.com/biz/ladybird-new-york?adj...  upaVTWhLsxcu1HXqN8iHVQ
# 172  https://www.yelp.com/biz/caracas-arepa-bar-bro...  tW8a8-MX_lVoshmKRLUuHQ
# 173  https://www.yelp.com/biz/my-moon-brooklyn-2?ad...  avBY-xnfy4_pXCNc6EFHpg
# 174  https://www.yelp.com/biz/anfora-new-york?adjus...  g-q-kRxdn2zh2oWOY-jKTQ
# 175  https://www.yelp.com/biz/brookvin-brooklyn?adj...  KWIPsr4kQBLIpPTSwKTlig
# 176
# 177  https://www.yelp.com/biz/vanguard-wine-bar-new...  Gfo-8z_CMOpHZVhX-HKD0g
# 178  https://www.yelp.com/biz/local-and-vine-new-yo...  8MwqN3ZZCzYVKwzYgcCZdg
# 179  https://www.yelp.com/biz/ardesia-new-york?adju...  XVMzBs7wGeU5BWgyBL3xyQ
# 180  https://www.yelp.com/biz/the-ten-bells-new-yor...  0vdgqmIt6e0suBu2g-M1UQ
# 181  https://www.yelp.com/biz/june-brooklyn-3?adjus...  OsA5iRphHwPlYNhdddvBng
# 182  https://www.yelp.com/biz/st-tropez-west-villag...  CcxreLJbZsO6Z775-hMWpw
# 183  https://www.yelp.com/biz/big-tiny-brooklyn-4?a...  OkiPb6gNNRmcbB4zIIMx0g
# 184  https://www.yelp.com/biz/lighthouse-brooklyn-2...  DhBhEWMVLDxYF14a1znUvA
# 185  https://www.yelp.com/biz/miriam-brooklyn-2?adj...  lnTPfdaqDqWjywWewsE2Lw
# 186  https://www.yelp.com/biz/addictive-wine-and-ta...  -OplSkpDk33uikS5fO-JQw
# 187
# 188  https://www.yelp.com/biz/bibi-new-york?adjust_...  HbCyzokiA19bEWUp6mga_g
# 189  https://www.yelp.com/biz/the-cellar-new-york?a...  SF2G4QfcSV03sMCSsv5s2g
# 190
# 191
# 192  https://www.yelp.com/biz/gomi-korean-wine-bar-...  1ozuYD1HTa4u2F_NR9uUJg
# 193  https://www.yelp.com/biz/terroir-tribeca-new-y...  ED2I3t5rOf81cddCsLA4tw
# 194
# 195  https://www.yelp.com/biz/ruffian-new-york-4?ad...  fFkqEyupjc5x2iJQIPcpLw
# 196  https://www.yelp.com/biz/lamano-chelsea-new-yo...  cRmRAl5HHJcysKBSrHivHA
# 197  https://www.yelp.com/biz/tomi%C3%B1o-taberna-g...  EHINHIbLklEUShuANKjGgw
# 198  https://www.yelp.com/biz/the-four-horsemen-bro...  Orbsfc3nI21mQ8cwSPahhg
# 199  https://www.yelp.com/biz/tavern-157-flushing-2...  xR2Yeb_Nh0MOAiUIaqaVOg
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_Tapas.csv')
