# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"pizza","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': 'zj8Lq1T8KIC5zwFief15jg',
#    'alias': 'prince-street-pizza-new-york-2',
#    'name': 'Prince Street Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZAukOyv530w4KjOHC5YY1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3994,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72308755605564,
#     'longitude': -73.99453001177575},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '27 Prince St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27 Prince St', 'New York, NY 10012']},
#    'phone': '+12129664100',
#    'display_phone': '(212) 966-4100',
#    'distance': 1961.8771417367063},
#   {'id': 'ysqgdbSrezXgVwER2kQWKA',
#    'alias': 'julianas-brooklyn-3',
#    'name': "Juliana's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/clscwgOF9_Ecq-Rwsq7jyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/julianas-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2354,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70274718768062,
#     'longitude': -73.99343490196397},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '19 Old Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#    'phone': '+17185966700',
#    'display_phone': '(718) 596-6700',
#    'distance': 308.56984360837544},
#   {'id': 'WG639VkTjmK5dzydd1BBJA',
#    'alias': 'rubirosa-new-york-2',
#    'name': 'Rubirosa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LuSzR8cpVQRofXOT_bMi1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2448,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.722766, 'longitude': -73.996233},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '235 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#    'phone': '+12129650500',
#    'display_phone': '(212) 965-0500',
#    'distance': 1932.9467701334759},
#   {'id': 'WIhm0W9197f_rRtDziq5qQ',
#    'alias': 'lombardis-pizza-new-york-4',
#    'name': "Lombardi's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UZ6V_hobp1KpYDPOHNoCKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6193,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7215934960083,
#     'longitude': -73.9955956044561},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '32 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 Spring St', 'New York, NY 10012']},
#    'phone': '+12129417994',
#    'display_phone': '(212) 941-7994',
#    'distance': 1798.9959778083735},
#   {'id': 'Q9F2ocrmYuGt1yn3M7MOBw',
#    'alias': 'lucali-brooklyn-3',
#    'name': 'Lucali',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Yl_eZ_DW_iaumnU-pfSoaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lucali-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1714,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6818, 'longitude': -74.00024},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '575 Henry St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['575 Henry St', 'Brooklyn, NY 11231']},
#    'phone': '+17188584086',
#    'display_phone': '(718) 858-4086',
#    'distance': 2674.849860473569},
#   {'id': 'FhXjAc6nKLf414KxYujUHw',
#    'alias': 'robertas-brooklyn-2',
#    'name': "Roberta's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8fY9fA5TtCF0ebdTNph9mQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/robertas-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3005,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70493, 'longitude': -73.93399},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '261 Moore St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['261 Moore St', 'Brooklyn, NY 11206']},
#    'phone': '+17184171118',
#    'display_phone': '(718) 417-1118',
#    'distance': 5083.5233118395545},
#   {'id': 'uc5qQMzs96rzjK27epDCug',
#    'alias': 'joes-pizza-new-york-4',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1TvTRG9HFmEGaTSBMcUBhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2675,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73060076, 'longitude': -74.00215997},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '7 Carmine St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 Carmine St', 'New York, NY 10014']},
#    'phone': '+12123661182',
#    'display_phone': '(212) 366-1182',
#    'distance': 2874.702513677348},
#   {'id': '0UdC0VYX6aAvLiOcpR4MVQ',
#    'alias': 'joes-pizza-new-york-7',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BTCcvlqxlp2MOeK_rHa8lQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 946,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73331, 'longitude': -73.98763},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '150 E 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 E 14th St', 'New York, NY 10003']},
#    'phone': '+12123889474',
#    'display_phone': '(212) 388-9474',
#    'distance': 3152.5373085823726},
#   {'id': '2ggi1luerd3Mf_C82JvCYg',
#    'alias': 'grimaldis-pizzeria-brooklyn-4',
#    'name': "Grimaldi's Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KnocNRTl04953MdDXH9y7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grimaldis-pizzeria-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4689,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.702583, 'longitude': -73.9932413},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17188584300',
#    'display_phone': '(718) 858-4300',
#    'distance': 330.34746206527655},
#   {'id': 'LF1QAuvpfX7KGQlg2zMg6Q',
#    'alias': 'johns-of-bleecker-street-new-york-2',
#    'name': "John's of Bleecker Street",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9_3Eim0f4ttMZFxdNp-lVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/johns-of-bleecker-street-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2157,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73158, 'longitude': -74.00332},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '278 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['278 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12122431680',
#    'display_phone': '(212) 243-1680',
#    'distance': 3010.899021476809},
#   {'id': 'qoBcWhGwlcUsKIQ2nB22vA',
#    'alias': 'lombardos-of-bay-ridge-brooklyn-2',
#    'name': "Lombardo's of Bay Ridge",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dApR-oBFGa2kQIpmEeasfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lombardos-of-bay-ridge-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 154,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.634741, 'longitude': -74.0284259},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '279 71st St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['279 71st St', 'Brooklyn, NY 11209']},
#    'phone': '+17182387100',
#    'display_phone': '(718) 238-7100',
#    'distance': 8367.095256061873},
#   {'id': 'C8j0q4Ma_S5hBGuAI-aaww',
#    'alias': 'di-fara-pizza-brooklyn',
#    'name': 'Di Fara Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4dfe9qpe20P-vi3qFjWd4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/di-fara-pizza-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3656,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.625093, 'longitude': -73.961531},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1424 Ave J',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11230',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1424 Ave J', 'Brooklyn, NY 11230']},
#    'phone': '+17182581367',
#    'display_phone': '(718) 258-1367',
#    'distance': 9352.269072867253},
#   {'id': 'v1DHGRNCH9247WLYoaoA9A',
#    'alias': 'l-industrie-pizzeria-brooklyn',
#    'name': "L'industrie Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_tHRJGBaVtQD4L-hFK9jjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 600,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71162, 'longitude': -73.95783},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '254 S 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211']},
#    'phone': '+17185990002',
#    'display_phone': '(718) 599-0002',
#    'distance': 3145.016041338447},
#   {'id': 'pGr5QuQU7Ur5GHLvXbT8bw',
#    'alias': 'paulie-gees-brooklyn',
#    'name': "Paulie Gee's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1j39J4NABK_RBtO-l90QNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paulie-gees-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1287,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.729546, 'longitude': -73.958568},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '60 Greenpoint Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Greenpoint Ave', 'Brooklyn, NY 11222']},
#    'phone': '+13479873747',
#    'display_phone': '(347) 987-3747',
#    'distance': 4027.308250680752},
#   {'id': 'oOr6Ta5gZyDl6PyZ1cq7pg',
#    'alias': 'east-village-pizza-new-york',
#    'name': 'East Village Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JiV117pdeH3hG6J91KfPeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/east-village-pizza-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 384,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.728199, 'longitude': -73.985182},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '145 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['145 1st Ave', 'New York, NY 10003']},
#    'phone': '+12125294545',
#    'display_phone': '(212) 529-4545',
#    'distance': 2643.8575043591286},
#   {'id': 'oJ_XSPZFpvIt6rvheSQl7A',
#    'alias': 'bleecker-street-pizza-new-york',
#    'name': 'Bleecker Street Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Kyi2tP43S_a6s-zXD38NUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bleecker-street-pizza-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2463,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7320627016512,
#     'longitude': -74.0036552270137},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '69 7th Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['69 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12129244466',
#    'display_phone': '(212) 924-4466',
#    'distance': 3073.5742196084057},
#   {'id': 'hGksyTiHBBdrhbiVjXzWVw',
#    'alias': 'scarrs-pizza-new-york',
#    'name': "Scarr's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xonxGJK91P_Ow3iY7olsxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scarrs-pizza-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 502,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71534, 'longitude': -73.9914},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '22 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 Orchard St', 'New York, NY 10002']},
#    'phone': '+12123343481',
#    'display_phone': '(212) 334-3481',
#    'distance': 1125.7843300426755},
#   {'id': 'TWH4MjLtN1fKlF-7n6YXHg',
#    'alias': 'lil-frankies-new-york',
#    'name': "Lil Frankie's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/b0nsA2W4oswnmH3fr-BOig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lil-frankies-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1230,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.723625, 'longitude': -73.988555},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '19 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 1st Ave', 'New York, NY 10003']},
#    'phone': '+12124204900',
#    'display_phone': '(212) 420-4900',
#    'distance': 2079.0350425992006},
#   {'id': 'EXQ0x2W9RTydIlHAU9MU1A',
#    'alias': 'mimis-pizza-new-york',
#    'name': "Mimi's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/btcWJW_uNq7JEwk2wFMtiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mimis-pizza-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.778638, 'longitude': -73.952895},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '217 E 86th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['217 E 86th St', 'New York, NY 10028']},
#    'phone': '+16468612518',
#    'display_phone': '(646) 861-2518',
#    'distance': 8852.345604022003},
#   {'id': 'GRXvvB1OKMuW4XDWEaVAlg',
#    'alias': 'joes-pizza-brooklyn-8',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7RQebflR3JvTcMWRbVC86g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-brooklyn-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 365,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71691, 'longitude': -73.958987},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '216 Bedford Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['216 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17183882216',
#    'display_phone': '(718) 388-2216',
#    'distance': 3239.2966565668607},
#   {'id': 'vyoA8dxwScuMV_AsTcjQcg',
#    'alias': 'l-and-b-spumoni-gardens-brooklyn',
#    'name': 'L & B Spumoni Gardens',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BrTci9PjIwi7V1vkbgkdqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-and-b-spumoni-gardens-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4048,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.594715, 'longitude': -73.981316},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '2725 86th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11223',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2725 86th St', 'Brooklyn, NY 11223']},
#    'phone': '+17184491230',
#    'display_phone': '(718) 449-1230',
#    'distance': 12361.163422806636},
#   {'id': 'G77Q6kU-7qRefColCRTS0w',
#    'alias': 'robertas-brooklyn-5',
#    'name': "Roberta's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LL2pMBF8nGtob11nKudndA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/robertas-brooklyn-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71618788546057,
#     'longitude': -73.96651754323669},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '6 Grand St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6 Grand St', 'Brooklyn, NY 11249']},
#    'phone': '+17182782400',
#    'display_phone': '(718) 278-2400',
#    'distance': 2628.2809301068355},
#   {'id': 'n_0FM-6aEyjTMDcz5PKEfQ',
#    'alias': 'koronet-pizza-new-york-6',
#    'name': 'Koronet Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8njY9y5TpJUDgMyJRrJJ7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/koronet-pizza-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77408, 'longitude': -73.95969},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1110 Lexington Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1110 Lexington Ave', 'New York, NY 10075']},
#    'phone': '+16467670424',
#    'display_phone': '(646) 767-0424',
#    'distance': 8161.807257257894},
#   {'id': 'rZ9OFoSqy8u4WECfh--ylg',
#    'alias': 'marta-new-york-7',
#    'name': 'Marta',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wVdnsTQRlks4TUXt0QQiFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marta-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 908,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7445882, 'longitude': -73.9847936},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '29 E 29th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['29 E 29th St', 'New York, NY 10016']},
#    'phone': '+12126513800',
#    'display_phone': '(212) 651-3800',
#    'distance': 4444.4428187583135},
#   {'id': '4h4Tuuc56YPO6lWfZ1bdSQ',
#    'alias': 'joes-pizza-new-york-152',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yo5oXK2HmxMnvH_PqeABiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-new-york-152?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 266,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7101297729083,
#     'longitude': -74.0077206864953},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '124 Fulton St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['124 Fulton St', 'New York, NY 10038']},
#    'phone': '+12122670860',
#    'display_phone': '(212) 267-0860',
#    'distance': 1245.9428626945232},
#   {'id': '-9NO2IDCJMyNGZMAQ1-VQw',
#    'alias': 'ny-pizza-suprema-new-york',
#    'name': 'NY Pizza Suprema',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EqbDXneMuQP6pw6GemVdQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ny-pizza-suprema-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2107,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7502059936523,
#     'longitude': -73.9953231811523},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '413 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['413 8th Ave', 'New York, NY 10001']},
#    'phone': '+12125948939',
#    'display_phone': '(212) 594-8939',
#    'distance': 4977.847939164096},
#   {'id': '16ZnHpuaaBt92XWeJHCC5A',
#    'alias': 'olio-e-piú-new-york-city',
#    'name': 'Olio e Piú',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/W_kyLvXj7ustj-XHWYU6tQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olio-e-pi%C3%BA-new-york-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2773,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.733798036104304,
#     'longitude': -73.99977392649927},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3 Greenwich Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York City',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3 Greenwich Ave', 'New York City, NY 10014']},
#    'phone': '+12122436546',
#    'display_phone': '(212) 243-6546',
#    'distance': 3186.3804982206075},
#   {'id': 'xrgzB0pvsxeGEIboE6I2gg',
#    'alias': 'patsys-pizzeria-brooklyn-2',
#    'name': "Patsy's Pizzeria",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1n5xL5ojLR-_zseirQKaMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patsys-pizzeria-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 563,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6818695, 'longitude': -73.976181},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '450 Dean St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['450 Dean St', 'Brooklyn, NY 11217']},
#    'phone': '+17186222268',
#    'display_phone': '(718) 622-2268',
#    'distance': 3034.9893998767334},
#   {'id': 'FogLdooqSzKbmkwMGSwDiQ',
#    'alias': 'razza-pizza-artigianale-jersey-city-2',
#    'name': 'Razza Pizza Artigianale',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4FDidtkNYP694tNVP1XJOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/razza-pizza-artigianale-jersey-city-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 969,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7177490485075,
#     'longitude': -74.0441924355125},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '275 Grove St',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['275 Grove St', 'Jersey City, NJ 07302']},
#    'phone': '+12013569348',
#    'display_phone': '(201) 356-9348',
#    'distance': 4422.740592466265},
#   {'id': 'vfYhEpp0x-DrNjC6GSJjPQ',
#    'alias': 'artichoke-basilles-pizza-new-york-2',
#    'name': "Artichoke Basille's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4krjwPml7pLVDnn56sf6AQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/artichoke-basilles-pizza-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4009,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7321124557704,
#     'longitude': -73.9839056828882},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '321 E 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['321 E 14th St', 'New York, NY 10003']},
#    'phone': '+12122282004',
#    'display_phone': '(212) 228-2004',
#    'distance': 3091.822113723405},
#   {'id': 'vTn3ww550Rnhz9naIxtjww',
#    'alias': 'brunetti-pizza-new-york',
#    'name': 'Brunetti Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GFEmMtaYhoxsMcZZf3CjkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brunetti-pizza-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 310,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73829, 'longitude': -74.0054},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '626 Hudson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['626 Hudson St', 'New York, NY 10014']},
#    'phone': '+12122555699',
#    'display_phone': '(212) 255-5699',
#    'distance': 3767.335383357533},
#   {'id': '-CCfu19Uuy_kD2t4ZwsQfA',
#    'alias': 'village-square-pizza-new-york-3',
#    'name': 'Village Square Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rc1se5XkYcc6ABo8g7u4Zw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/village-square-pizza-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 195,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72748, 'longitude': -73.98268},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '147 Ave A',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['147 Ave A', 'New York, NY 10009']},
#    'phone': '+19176757709',
#    'display_phone': '(917) 675-7709',
#    'distance': 2640.263835248777},
#   {'id': 'KEEXuHCYhsQJ-zpJhu98bA',
#    'alias': 'joes-pizza-new-york-148',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-ORP9v5yOaKdqvmRXN_zkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-new-york-148?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1278,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7547, 'longitude': -73.98696},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1435 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1435 Broadway', 'New York, NY 10018']},
#    'phone': '+16465594878',
#    'display_phone': '(646) 559-4878',
#    'distance': 5508.746902433722},
#   {'id': 'o-kfxonPwQOWQNBvfkBkWw',
#    'alias': 'nyc-pizza-kitchen-new-york',
#    'name': 'NYC Pizza Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/abnuTWaCehMrA47h9I_Z8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nyc-pizza-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.741947306680636,
#     'longitude': -73.98095156997442},
#    'transactions': [],
#    'location': {'address1': '390 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['390 3rd Ave', 'New York, NY 10016']},
#    'phone': '+12127299497',
#    'display_phone': '(212) 729-9497',
#    'distance': 4211.720687746522},
#   {'id': '6ECcDYsRgmfv0eKXk-c11Q',
#    'alias': 'la-nonna-krispy-krust-pizza-brooklyn',
#    'name': 'La Nonna Krispy Krust Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/snKP9CUQHOth_2vox3Z79g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-nonna-krispy-krust-pizza-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.717953, 'longitude': -73.9637027},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '175 Kent Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['175 Kent Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13473842100',
#    'display_phone': '(347) 384-2100',
#    'distance': 2929.5564145017947},
#   {'id': 'ZLPYcgEeRllSoeWyr7y4Ig',
#    'alias': 'totonnos-brooklyn',
#    'name': "Totonno's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sRcdY5SLS9RCZqd9BqNccQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/totonnos-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 810,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.578913225666966,
#     'longitude': -73.98383392883555},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '1524 Neptune Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11224',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1524 Neptune Ave', 'Brooklyn, NY 11224']},
#    'phone': '+17183728606',
#    'display_phone': '(718) 372-8606',
#    'distance': 14097.30957825896},
#   {'id': 'MphfKkYFEe0BDQ6hZ0A5fA',
#    'alias': 'gelso-and-grand-new-york',
#    'name': 'Gelso & Grand',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hkiNG-bPWX459H2KIBrsvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gelso-and-grand-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1085,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7194089547259,
#     'longitude': -73.9973777877722},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '186 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['186 Grand St', 'New York, NY 10013']},
#    'phone': '+12122261600',
#    'display_phone': '(212) 226-1600',
#    'distance': 1574.3490321455226},
#   {'id': 'fH8DkdRerw5LJ7fZZHRfeA',
#    'alias': 'leuca-brooklyn',
#    'name': 'Leuca',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vwsD0CIQCXcerVESUWsJNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/leuca-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 347,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722121, 'longitude': -73.956678},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '111 N 12th St',
#     'address2': '',
#     'address3': 'The William Vale Hotel',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 N 12th St',
#      'The William Vale Hotel',
#      'Brooklyn, NY 11249']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3672.793357584282},
#   {'id': '7jbInJHwOm4W_kesEe19mA',
#    'alias': 'my-pie-new-york-5',
#    'name': 'My Pie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/p3_mXtue214X53EL_M0-Zw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-pie-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 168,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77823, 'longitude': -73.98117},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '166 West 72nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['166 West 72nd St', 'New York, NY 10023']},
#    'phone': '+12127877200',
#    'display_phone': '(212) 787-7200',
#    'distance': 8163.87808658151},
#   {'id': 'aTmNnrx0XE_nTSFFzXnt8w',
#    'alias': 'roebling-pizza-brooklyn',
#    'name': 'Roebling Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MKB7xNl91tiGK-8icZ2psA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roebling-pizza-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 120,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7084890714263,
#     'longitude': -73.9610940711639},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '326 Roebling St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['326 Roebling St', 'Brooklyn, NY 11211']},
#    'phone': '+17187825042',
#    'display_phone': '(718) 782-5042',
#    'distance': 2818.8131221054136},
#   {'id': 'xxgcU_oFIox_pAmroo9WwA',
#    'alias': 'front-street-pizza-brooklyn',
#    'name': 'Front Street Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ybrfmg0lGdBoJRM7X1_s3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/front-street-pizza-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 390,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70244, 'longitude': -73.98943},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '80 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17188753700',
#    'display_phone': '(718) 875-3700',
#    'distance': 550.4392264831844},
#   {'id': 'S4uozcDEieoaXxIJ6TsUoQ',
#    'alias': 'dellaroccos-brooklyn-3',
#    'name': "Dellarocco's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RGsip2vQXryVUbOrXfYBkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dellaroccos-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 301,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6950309, 'longitude': -73.9961252},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '214 Hicks St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['214 Hicks St', 'Brooklyn, NY 11201']},
#    'phone': '+17188581010',
#    'display_phone': '(718) 858-1010',
#    'distance': 1170.2700329972115},
#   {'id': 'xeC9vn3dxVVzAMR_aFwfXg',
#    'alias': 'il-brigante-new-york',
#    'name': 'IL Brigante',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0G1IhFFYvIhkvG85SiSAgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-brigante-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 427,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.707492, 'longitude': -74.002571},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '214 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['214 Front St', 'New York, NY 10038']},
#    'phone': '+12122850222',
#    'display_phone': '(212) 285-0222',
#    'distance': 738.248263617683},
#   {'id': '2xQmBB6w-W6lxiex80fA9A',
#    'alias': 'luigis-pizzeria-brooklyn-4',
#    'name': "Luigi's Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B3eNfBS1DTkTZ6fasVL01A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luigis-pizzeria-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 255,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6897, 'longitude': -73.965369},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '326 Dekalb Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['326 Dekalb Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17187832430',
#    'display_phone': '(718) 783-2430',
#    'distance': 3001.8318150390764},
#   {'id': 'uEKiv6WEPg9dWj10HCur5A',
#    'alias': 'table-87-brooklyn-heights-brooklyn-2',
#    'name': 'Table 87 - Brooklyn Heights',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CX-0-ASjoOQ1jfazjjaD_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/table-87-brooklyn-heights-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 301,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.691219329834,
#     'longitude': -73.9973449707031},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '87 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['87 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17187979300',
#    'display_phone': '(718) 797-9300',
#    'distance': 1602.5908124268826},
#   {'id': '1ocm2YeYQJ3KveEBDcXAqg',
#    'alias': 'nonnas-pizza-new-york-6',
#    'name': "Nonna's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/piSyq2J3P5ZUxtHofubYUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nonnas-pizza-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73891, 'longitude': -73.99298},
#    'transactions': ['delivery'],
#    'location': {'address1': '12 W 18th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['12 W 18th St', 'New York, NY 10011']},
#    'phone': '+12122060500',
#    'display_phone': '(212) 206-0500',
#    'distance': 3718.62334949911},
#   {'id': 'WE_dce2JKcv-VoFNaqiJ4w',
#    'alias': 'carmines-pizzeria-brooklyn',
#    'name': "Carmine's Pizzeria",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/V6LFN2p5zVHu78FvXnVZ7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carmines-pizzeria-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 473,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.714987, 'longitude': -73.94414},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '358 Graham Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['358 Graham Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17187829659',
#    'display_phone': '(718) 782-9659',
#    'distance': 4355.864983059872},
#   {'id': 'Aazjxg21VH2cncWYBAv68Q',
#    'alias': 'sottocasa-pizzeria-brooklyn-3',
#    'name': 'Sottocasa Pizzeria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MbBAMb3kb1VXtF9M5ptazA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sottocasa-pizzeria-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 657,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.688285, 'longitude': -73.989006},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '298 Atlantic Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['298 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17188528758',
#    'display_phone': '(718) 852-8758',
#    'distance': 1955.3105885559205},
#   {'id': 'vpkTNjq9dRh9rT3Nh0pe-A',
#    'alias': 'nolita-pizza-new-york-2',
#    'name': 'Nolita Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2h3k8ApjZGZ8aUNPZp8--g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nolita-pizza-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 92,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7208883, 'longitude': -73.9962404},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '68 Kenmare St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['68 Kenmare St', 'New York, NY 10012']},
#    'phone': '+16468959131',
#    'display_phone': '(646) 895-9131',
#    'distance': 1725.0543086810944},
#   {'id': 'MEz44tgJJ6GNg-RN2H84zg',
#    'alias': 'bellucci-pizza-astoria',
#    'name': 'Bellucci Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6PV0Fga7W2xABKbW8VfXQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bellucci-pizza-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 119,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76772937223715,
#     'longitude': -73.9234633428848},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '29-04 30th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['29-04 30th Ave', 'Astoria, NY 11102']},
#    'phone': '+17189711074',
#    'display_phone': '(718) 971-1074',
#    'distance': 9142.164567616306}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#             Restaurant     Type Price Rating           Address        Lat  \
# 0  Prince Street Pizza    Pizza     $    4.5      27 Prince St  40.723088
# 1            Juliana's    Pizza    $$    4.5  19 Old Fulton St  40.702747
# 2             Rubirosa  Italian    $$    4.5   235 Mulberry St  40.722766
# 3     Lombardi's Pizza    Pizza    $$      4      32 Spring St  40.721593
# 4               Lucali    Pizza    $$      4      575 Henry St  40.681800
#
#          Lng                                                url  \
# 0 -73.994530  https://www.yelp.com/biz/prince-street-pizza-n...
# 1 -73.993435  https://www.yelp.com/biz/julianas-brooklyn-3?a...
# 2 -73.996233  https://www.yelp.com/biz/rubirosa-new-york-2?a...
# 3 -73.995596  https://www.yelp.com/biz/lombardis-pizza-new-y...
# 4 -74.000240  https://www.yelp.com/biz/lucali-brooklyn-3?adj...
#
#                        ID
# 0  zj8Lq1T8KIC5zwFief15jg
# 1  ysqgdbSrezXgVwER2kQWKA
# 2  WG639VkTjmK5dzydd1BBJA
# 3  WIhm0W9197f_rRtDziq5qQ
# 4  Q9F2ocrmYuGt1yn3M7MOBw

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"pizza","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': 'yH6t1JWcwkdWG4CS5KPvow',
#    'alias': 'adriennes-pizzabar-new-york',
#    'name': "Adrienne's Pizzabar",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MOG8wpqkeYQxDslq7ospLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/adriennes-pizzabar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1711,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7043362, 'longitude': -74.0101733},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '54 Stone St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['54 Stone St', 'New York, NY 10004']},
#    'phone': '+12122483838',
#    'display_phone': '(212) 248-3838',
#    'distance': 1344.2671600758972},
#   {'id': 'UuY1QCxWybMF0IMxAYG06w',
#    'alias': 'emmy-squared-brooklyn-brooklyn-2',
#    'name': 'Emmy Squared - Brooklyn',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QhvUiC2hXUJaHayNwPIO0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/emmy-squared-brooklyn-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 673,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.712168, 'longitude': -73.955707},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '364 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['364 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17183604535',
#    'display_phone': '(718) 360-4535',
#    'distance': 3337.371448778803},
#   {'id': 'vVVmHacu2YAxKfpIjhfd1g',
#    'alias': 'norma-new-york-5',
#    'name': 'Norma',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qJKt5l2xSBUKOFRA6UOqVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/norma-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 477,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.743553, 'longitude': -73.980026},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '438 3rd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['438 3rd Ave', 'New York, NY 10016']},
#    'phone': '+12128890600',
#    'display_phone': '(212) 889-0600',
#    'distance': 4409.483534452521},
#   {'id': '9Qcxauog2gOTKt-L4Ljxxw',
#    'alias': 'burrata-pizza-new-york',
#    'name': 'Burrata Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jBENbh42upX4TVYzc2p5Zg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burrata-pizza-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7302, 'longitude': -73.98069},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '221 Ave A',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['221 Ave A', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2981.056338871247},
#   {'id': '3VJwpmmeoPlCN3J5p5miEQ',
#    'alias': 'brooklyns-homeslice-pizzeria-brooklyn',
#    'name': "Brooklyn's Homeslice Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PFbKEyhlyJIuGZxhqSYlKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyns-homeslice-pizzeria-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 152,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.680702, 'longitude': -73.967455},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '567 Vanderbilt Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['567 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17183999000',
#    'display_phone': '(718) 399-9000',
#    'distance': 3562.2182094944847},
#   {'id': 'hFmz7HH2og9hn7xNNv20yw',
#    'alias': 'il-porto-ristorante-brooklyn',
#    'name': 'Il Porto Ristorante',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ka4_bkUB_I5JAZyRjAnbLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-porto-ristorante-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 344,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6974427, 'longitude': -73.9675197},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '37 Washington Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37 Washington Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17186240954',
#    'display_phone': '(718) 624-0954',
#    'distance': 2433.138320005117},
#   {'id': 'd8USIZvTTqee35l34anRBg',
#    'alias': 'sauce-pizzeria-new-york-4',
#    'name': 'Sauce Pizzeria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VoSXYh3NdJuHhD68i1IQIQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sauce-pizzeria-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 212,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73033, 'longitude': -73.98403},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '345 E 12th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['345 E 12th St', 'New York, NY 10003']},
#    'phone': '+16469834007',
#    'display_phone': '(646) 983-4007',
#    'distance': 2911.8661493024188},
#   {'id': 'FXYsBqMu2q1dhJYQg_FfAA',
#    'alias': 'rosemary-s-new-york',
#    'name': 'Rosemary’s',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t6JhLAL6hx4KbG04keW1RA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rosemary-s-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 65,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73512, 'longitude': -73.97965},
#    'transactions': [],
#    'location': {'address1': '350 1st Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['350 1st Ave', 'New York, NY 10010']},
#    'phone': '+16468685335',
#    'display_phone': '(646) 868-5335',
#    'distance': 3520.4220508659423},
#   {'id': 'yc4vsT-Q4Ej1_9hr94DxkQ',
#    'alias': 'sotto-13-new-york-7',
#    'name': 'Sotto 13',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mCE2TARhbLRvR1eqSn9DsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sotto-13-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 938,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7372, 'longitude': -73.99919},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '140 W 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['140 W 13th St', 'New York, NY 10011']},
#    'phone': '+12126471001',
#    'display_phone': '(212) 647-1001',
#    'distance': 3557.7665642618012},
#   {'id': '15k7iqFbhf4h8L01yggLqg',
#    'alias': 'song-e-napule-new-york',
#    'name': 'Song E Napule',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y9G-nheTrxSrx4Cqg0HzHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/song-e-napule-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 560,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72813, 'longitude': -74.00188},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '146 W Houston St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['146 W Houston St', 'New York, NY 10012']},
#    'phone': '+12125331242',
#    'display_phone': '(212) 533-1242',
#    'distance': 2607.168270554507},
#   {'id': 'oRdM7n-AfBPBGAlH4Q0Sag',
#    'alias': 'my-pie-pizzeria-romana-new-york-2',
#    'name': 'My Pie Pizzeria Romana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/C0xEYVnbJNDnyMYv_VVZ9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-pie-pizzeria-romana-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 798,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7608512, 'longitude': -73.9694809},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '690 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['690 Lexington Ave', 'New York, NY 10022']},
#    'phone': '+12123171850',
#    'display_phone': '(212) 317-1850',
#    'distance': 6505.9564779774955},
#   {'id': 'AHDlsNh8fODK9miC3zv3Zg',
#    'alias': 'unregular-pizza-new-york-2',
#    'name': 'Unregular Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t3_T8Ex7-mrCxnAwW9uH6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/unregular-pizza-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73398, 'longitude': -73.98961},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '135 4th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['135 4th Ave', 'New York, NY 10003']},
#    'phone': '+16466094699',
#    'display_phone': '(646) 609-4699',
#    'distance': 3163.0182107738174},
#   {'id': 'IZ9-5z45wc3Oh_jlnX_Kcg',
#    'alias': 'giuseppinas-brooklyn',
#    'name': "Giuseppina's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/38q6KTMRVd0NiwlQ7GiBKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giuseppinas-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 326,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6603430973463,
#     'longitude': -73.9907741546631},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '691 6th Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['691 6th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17184995052',
#    'display_phone': '(718) 499-5052',
#    'distance': 5023.85312943866},
#   {'id': 'm3PS0tIaa0ChcP8Y5S-DrQ',
#    'alias': 'mamas-too-new-york',
#    'name': "MAMA'S TOO!",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NTpvPQSoxumdAuc6szUSyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mamas-too-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 462,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.80084, 'longitude': -73.96766},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2750 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2750 Broadway', 'New York, NY 10025']},
#    'phone': '+12125107256',
#    'display_phone': '(212) 510-7256',
#    'distance': 10840.163726815497},
#   {'id': 'OVrHAnfna46SdaFnTNqhhQ',
#    'alias': 'artichoke-basilles-pizza-brooklyn-9',
#    'name': "Artichoke Basille's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UscKgJncYqWdLuwFSOb3_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/artichoke-basilles-pizza-brooklyn-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 392,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6810107667113,
#     'longitude': -73.9771813899279},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '59 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['59 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+13477631975',
#    'display_phone': '(347) 763-1975',
#    'distance': 3076.219141950709},
#   {'id': 'i_rg-OLXQbpRUN7O3MeCeA',
#    'alias': 'piz-zetta-brooklyn-2',
#    'name': 'Piz-zetta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9L4viDwAGx3obgYLnXMA6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piz-zetta-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 303,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6912834070746,
#     'longitude': -73.9906029201042},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '90 Livingston St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90 Livingston St', 'Brooklyn, NY 11201']},
#    'phone': '+17184227878',
#    'display_phone': '(718) 422-7878',
#    'distance': 1605.1176697811002},
#   {'id': 'rJfGgBleDYCVq2rkBr_w-Q',
#    'alias': 'barano-brooklyn',
#    'name': 'Barano',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zp2q4o3QGrUsLtnQIwplrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barano-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 283,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.710372, 'longitude': -73.96794},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '26 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 Broadway', 'Brooklyn, NY 11249']},
#    'phone': '+13479874500',
#    'display_phone': '(347) 987-4500',
#    'distance': 2294.1417665733024},
#   {'id': 'kIm0oeOaVfC9-2flLPVklA',
#    'alias': 'patrizias-pizza-and-pasta-new-york',
#    'name': "Patrizia's Pizza and Pasta",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HG4eRBBgLSG0RrzLZv1mLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patrizias-pizza-and-pasta-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 665,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7398415, 'longitude': -73.9792862},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '462-466 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['462-466 2nd Ave', 'New York, NY 10016']},
#    'phone': '+12125979999',
#    'display_phone': '(212) 597-9999',
#    'distance': 4040.895814674829},
#   {'id': '2FgUndzCT_jJATbmrBDVBg',
#    'alias': 'paulie-gees-slice-shop-brooklyn',
#    'name': "Paulie Gee's Slice Shop",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/So5FTaF3_Sf0fWYLhQ-Ofw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paulie-gees-slice-shop-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 241,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72836, 'longitude': -73.9572},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '110 Franklin St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['110 Franklin St', 'Brooklyn, NY 11222']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4034.987858819694},
#   {'id': 'AtPlNbHfiDrJrY_nUVoByA',
#    'alias': 'zazzys-pizza-new-york-2',
#    'name': "Zazzy's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gklYGWUa78h9HHJYliFraw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zazzys-pizza-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.721617, 'longitude': -73.98862},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '173 Orchard St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['173 Orchard St', 'New York, NY 10002']},
#    'phone': '+12125420177',
#    'display_phone': '(212) 542-0177',
#    'distance': 1860.606327830235},
#   {'id': 'AoezuAP-QOH6JZZOmyzJLg',
#    'alias': 'marinara-pizza-new-york-11',
#    'name': 'Marinara Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3pb0XoJkF5Zx6ZPwjfpdfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marinara-pizza-new-york-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 288,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7826, 'longitude': -73.95351},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1376 Lexington Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1376 Lexington Ave', 'New York, NY 10128']},
#    'phone': '+16465595100',
#    'display_phone': '(646) 559-5100',
#    'distance': 9241.472431640696},
#   {'id': '7iwVStyeovgqLUltsWN0bA',
#    'alias': 'mario-s-pizza-brooklyn',
#    'name': 'Mario’s Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Eunbp4MNC-4IB0xPjjfGGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mario-s-pizza-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.731392, 'longitude': -73.954136},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '940 Manhattan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['940 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183492700',
#    'display_phone': '(718) 349-2700',
#    'distance': 4448.600746743508},
#   {'id': 'CFR-HzVHKWRMpMAR3LAhzg',
#    'alias': 'montesacro-pinseria-brooklyn-brooklyn',
#    'name': 'Montesacro Pinseria Brooklyn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pXeNs5eU9r6Ks1fO2DX6eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/montesacro-pinseria-brooklyn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 155,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71338, 'longitude': -73.95136},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '432 Union Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['432 Union Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13479161062',
#    'display_phone': '(347) 916-1062',
#    'distance': 3734.036336252337},
#   {'id': 'vmUNPvduTeWu24d--TbHAg',
#    'alias': 'ops-brooklyn',
#    'name': 'Ops',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_lBY7QytGHebiQvAxtNrug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ops-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 155,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70276, 'longitude': -73.9171},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '346 Himrod St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['346 Himrod St', 'Brooklyn, NY 11237']},
#    'phone': '+17183864009',
#    'display_phone': '(718) 386-4009',
#    'distance': 6508.236049695104},
#   {'id': 'Ajvcvk6tvlKbRF8Zkf0M5Q',
#    'alias': 'marinara-pizza-new-york-8',
#    'name': 'Marinara Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mcHv3zx8R6C0NBbCl_CIWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marinara-pizza-new-york-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74241, 'longitude': -73.98452},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '379 Park Ave S',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['379 Park Ave S', 'New York, NY 10016']},
#    'phone': '+16466495282',
#    'display_phone': '(646) 649-5282',
#    'distance': 4191.659530141325},
#   {'id': 'xzN2k19JXDYjOWAhNw62aw',
#    'alias': 'adoro-lei-new-york',
#    'name': 'Adoro Lei',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WXAccpo_S4j8Ypik6PXZZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/adoro-lei-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 317,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.725612, 'longitude': -74.007916},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '287 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['287 Hudson St', 'New York, NY 10013']},
#    'phone': '+16466665096',
#    'display_phone': '(646) 666-5096',
#    'distance': 2519.3150013593554},
#   {'id': 'aPn2_EtjfHduXEmEBNxuFA',
#    'alias': 'rosas-pizza-brooklyn',
#    'name': "Rosa's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_Bb9Q9WAh23q7bK3Bnuf3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rosas-pizza-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 136,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7139499, 'longitude': -73.95563},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '374 Metropolitan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['374 Metropolitan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17189632378',
#    'display_phone': '(718) 963-2378',
#    'distance': 3387.06021599364},
#   {'id': 'Tm0VqPlt8uJIIq9A7Os09Q',
#    'alias': 'zazzys-pizza-new-york-3',
#    'name': "Zazzy's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iYjYqjjdcngJ-kD5gQukeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zazzys-pizza-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.736699, 'longitude': -74.001447},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '75 Greenwich Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 Greenwich Ave', 'New York, NY 10014']},
#    'phone': '+12125420226',
#    'display_phone': '(212) 542-0226',
#    'distance': 3527.8251354671547},
#   {'id': 'cS2dquz8jSagXqeVKBwSsg',
#    'alias': 'fascati-pizza-brooklyn',
#    'name': 'Fascati Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_u0bhgV51bK-Xbo_5SQNqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fascati-pizza-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 247,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6985, 'longitude': -73.99273},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '80 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Henry St', 'Brooklyn, NY 11201']},
#    'phone': '+17182371278',
#    'display_phone': '(718) 237-1278',
#    'distance': 783.4896373292174},
#   {'id': 'M4pCWzdBCkp2g_d834a7Hw',
#    'alias': 'sauce-new-york-3',
#    'name': 'Sauce',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EtQuNDHcbVhXUplq7s9MFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sauce-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 844,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7204716, 'longitude': -73.9893263},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '78 Rivington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['78 Rivington St', 'New York, NY 10002']},
#    'phone': '+12124207700',
#    'display_phone': '(212) 420-7700',
#    'distance': 1722.539622700155},
#   {'id': 'H8qcX7MNNnC1bqE0LnIhKg',
#    'alias': 'simò-pizza-new-york-4',
#    'name': 'SIMÒ PIZZA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qaSQsBdO9e1gz5OH9ROckw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sim%C3%B2-pizza-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 188,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7392597584612,
#     'longitude': -74.0088130692187},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '90-92 Gansevoort St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90-92 Gansevoort St', 'New York, NY 10014']},
#    'phone': '+12124622703',
#    'display_phone': '(212) 462-2703',
#    'distance': 3954.1313238707344},
#   {'id': 'zHtCLIChaKxqFXfMZQHkMQ',
#    'alias': 'speedy-romeo-brooklyn',
#    'name': 'Speedy Romeo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/s2f-lienaUxWvW9MuxasdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/speedy-romeo-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 619,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6875154792236,
#     'longitude': -73.959874469611},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '376 Classon Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['376 Classon Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17182300061',
#    'display_phone': '(718) 230-0061',
#    'distance': 3520.563818418619},
#   {'id': '7vq2CNM69sdrXrtbT2-qEQ',
#    'alias': 'campania-coal-fired-pizza-brooklyn',
#    'name': 'Campania Coal Fired Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3MT3LUTSVA_KfBHdyQrdhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/campania-coal-fired-pizza-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 563,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6136093139648,
#     'longitude': -74.033332824707},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '9824 4th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9824 4th Ave', 'Brooklyn, NY 11209']},
#    'phone': '+13475174868',
#    'display_phone': '(347) 517-4868',
#    'distance': 10727.945423258845},
#   {'id': 'ZTsN8TdMXl8SW_AKd_ablw',
#    'alias': 'forno-rosso-brooklyn',
#    'name': 'Forno Rosso',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9aKNymymd9out1HSpkLuiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/forno-rosso-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 727,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.694467, 'longitude': -73.98293},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '327 Gold St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['327 Gold St', 'Brooklyn, NY 11201']},
#    'phone': '+17184513800',
#    'display_phone': '(718) 451-3800',
#    'distance': 1546.804489135146},
#   {'id': 'd7Asc4q2ImoPlA_BhfroTQ',
#    'alias': 'kesté-pizza-and-vino-new-york-5',
#    'name': 'Kesté Pizza & Vino',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Dd5EOBOvbRs5ttjQwuJedQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kest%C3%A9-pizza-and-vino-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1448,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7093947, 'longitude': -74.0048977},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '66 Gold S',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['66 Gold S', 'New York, NY 10038']},
#    'phone': '+12122431500',
#    'display_phone': '(212) 243-1500',
#    'distance': 992.7345723339745},
#   {'id': 'aaA4UHm25lbUIOlwwjWLyw',
#    'alias': 'roeys-new-york',
#    'name': "Roey's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MPIHxubSegSnZ31CEVP1mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roeys-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 112,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73596, 'longitude': -74.00093},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1 Perry St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Perry St', 'New York, NY 10014']},
#    'phone': '+16468641200',
#    'display_phone': '(646) 864-1200',
#    'distance': 3442.7663655504134},
#   {'id': 'nfZUADLfijRalf1kknJJCw',
#    'alias': 'emmy-squared-east-village-new-york',
#    'name': 'Emmy Squared - East Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SWxzJs2-EXwfU72BDtdsUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/emmy-squared-east-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 270,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72598, 'longitude': -73.98672},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '83 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['83 1st Ave', 'New York, NY 10003']},
#    'phone': '+19174633737',
#    'display_phone': '(917) 463-3737',
#    'distance': 2370.804700369215},
#   {'id': 'fU22eRTnKLT2C-OFJ6eUGQ',
#    'alias': 'saraghina-brooklyn',
#    'name': 'Saraghina',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eRPby_hSC_z4Zv9b_GTqkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saraghina-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 908,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6837407, 'longitude': -73.9353473},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '350 Lewis Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['350 Lewis Ave', 'Brooklyn, NY 11233']},
#    'phone': '+17185740010',
#    'display_phone': '(718) 574-0010',
#    'distance': 5524.596550882466},
#   {'id': 'aP1Nwq1-7j0Y7hr7oavY2A',
#    'alias': 'upside-pizza-new-york-2',
#    'name': 'Upside Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RWcIDIl-IyRIJy7nTaNUfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/upside-pizza-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722115, 'longitude': -73.996407},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '51 Spring St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['51 Spring St', 'New York, NY 10012']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1862.1844834674346},
#   {'id': 'MvkkAVNCFVmCWo8rXaTwBQ',
#    'alias': 'uncle-frankie-s-brick-oven-pizza-brooklyn',
#    'name': 'Uncle Frankie’s Brick Oven Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6IaYyLomX_Dwvl3jFaUUwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uncle-frankie-s-brick-oven-pizza-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.64852, 'longitude': -73.9787},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '3007 Fort Hamilton Pkwy',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11218',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3007 Fort Hamilton Pkwy', 'Brooklyn, NY 11218']},
#    'phone': '+17188543462',
#    'display_phone': '(718) 854-3462',
#    'distance': 6453.680782322662},
#   {'id': 'k3vbv0tbV83IrfaH2Z5t5Q',
#    'alias': 'maneros-pizza-new-york',
#    'name': "Manero's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4C4o_uuLbnIxEe0GftP-lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maneros-pizza-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.717593, 'longitude': -73.998396},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '113 Mulberry St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['113 Mulberry St', 'New York, NY 10013']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1398.553837392163},
#   {'id': 'xbrQ2dHuQoFJmNxAuOky4A',
#    'alias': 'vics-new-york',
#    'name': "Vic's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-AKKhSlRxqudkdani2Ut0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vics-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 509,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72693, 'longitude': -73.99319},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '31 Great Jones St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31 Great Jones St', 'New York, NY 10012']},
#    'phone': '+12122535700',
#    'display_phone': '(212) 253-5700',
#    'distance': 2387.4482277722477},
#   {'id': 'KEgdfVEVVgJFnGFiLNPDzQ',
#    'alias': 'sofia-pizza-shoppe-new-york',
#    'name': 'Sofia Pizza Shoppe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SWm7XJ-oycXJo6UGo07p-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sofia-pizza-shoppe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 227,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75674, 'longitude': -73.96431},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '989 1st Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['989 1st Ave', 'New York, NY 10022']},
#    'phone': '+12128888816',
#    'display_phone': '(212) 888-8816',
#    'distance': 6230.3284266620085},
#   {'id': 'ON7ihGoWgZaBFDaLCYpk2Q',
#    'alias': 'rome-to-brooklyn-pizza-new-york',
#    'name': 'Rome To Brooklyn Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rGm_g8V5xl8DB5zOsHKHYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rome-to-brooklyn-pizza-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71187, 'longitude': -73.94283},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '755 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['755 Grand St', 'New York, NY 11211']},
#    'phone': '+17182693239',
#    'display_phone': '(718) 269-3239',
#    'distance': 4390.505472386779},
#   {'id': 'm86CNmYThtzzWB3nPnrhbg',
#    'alias': 'emily-west-village-new-york',
#    'name': 'Emily - West Village',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6zPD8MFRcJLJiJoo-vXD9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/emily-west-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 770,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729330068469,
#     'longitude': -74.0038400073579},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '35 Downing St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35 Downing St', 'New York, NY 10014']},
#    'phone': '+19179356434',
#    'display_phone': '(917) 935-6434',
#    'distance': 2779.5434255898854},
#   {'id': 'iW11zKNq2gDylgAkKAfqCg',
#    'alias': 'salsa-pizzeria-brooklyn',
#    'name': 'Salsa Pizzeria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ssjYUXaAYEZuw2fYqA12zg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salsa-pizzeria-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7269007, 'longitude': -73.9554019},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '40 Clifford Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40 Clifford Pl', 'Brooklyn, NY 11222']},
#    'phone': '+13475424680',
#    'display_phone': '(347) 542-4680',
#    'distance': 4036.6704650732077},
#   {'id': '58YvTYsyxNyGixTAZiMHcg',
#    'alias': 'williamsburg-pizza-new-york-3',
#    'name': 'Williamsburg Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uMXAMUisv9ehDKRBKDU9DQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/williamsburg-pizza-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 244,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71822, 'longitude': -73.99123},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '277 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['277 Broome St', 'New York, NY 10002']},
#    'phone': '+12122264455',
#    'display_phone': '(212) 226-4455',
#    'distance': 1447.5435085978659},
#   {'id': '78TCGIG1eHMYdyvMpFdDbQ',
#    'alias': 'follia-nyc-new-york',
#    'name': 'Follia NYC',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wpf_6eIsOO219K91kn4LhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/follia-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 216,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7349243164062,
#     'longitude': -73.9855880737305},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '179 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['179 3rd Ave', 'New York, NY 10003']},
#    'phone': '+12124774100',
#    'display_phone': '(212) 477-4100',
#    'distance': 3359.1268163984287},
#   {'id': 'atbANdSznV29GI066I2Ijw',
#    'alias': 'champion-pizza-new-york-6',
#    'name': 'Champion Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SBZL50PVgk_0mYbo9_RsBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/champion-pizza-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 367,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7215270996094,
#     'longitude': -73.9970855712891},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '17 Cleveland Pl',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 Cleveland Pl', 'New York, NY 10012']},
#    'phone': '+12122263777',
#    'display_phone': '(212) 226-3777',
#    'distance': 1801.4764439408825},
#   {'id': 'c3D2ckzacnPtdGIM8tb-_w',
#    'alias': 'b-side-pizza-and-wine-bar-new-york',
#    'name': 'B Side Pizza & Wine Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0oC3VssQ0t1gSEEf9HWlmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b-side-pizza-and-wine-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1164,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76394, 'longitude': -73.9883399},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '370 W 51st St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['370 W 51st St', 'New York, NY 10019']},
#    'phone': '+16466797225',
#    'display_phone': '(646) 679-7225',
#    'distance': 6519.850090048231}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                       Restaurant     Type Price Rating             Address  \
# 0            Adrienne's Pizzabar    Pizza    $$      4         54 Stone St
# 1        Emmy Squared - Brooklyn    Pizza    $$      4        364 Grand St
# 2                          Norma  Italian    $$    4.5         438 3rd Ave
# 3                  Burrata Pizza  Italian                        221 Ave A
# 4  Brooklyn's Homeslice Pizzeria    Pizza     $    4.5  567 Vanderbilt Ave
#
#          Lat        Lng                                                url  \
# 0  40.704336 -74.010173  https://www.yelp.com/biz/adriennes-pizzabar-ne...
# 1  40.712168 -73.955707  https://www.yelp.com/biz/emmy-squared-brooklyn...
# 2  40.743553 -73.980026  https://www.yelp.com/biz/norma-new-york-5?adju...
# 3  40.730200 -73.980690
# 4  40.680702 -73.967455  https://www.yelp.com/biz/brooklyns-homeslice-p...
#
#                        ID
# 0  yH6t1JWcwkdWG4CS5KPvow
# 1  UuY1QCxWybMF0IMxAYG06w
# 2  vVVmHacu2YAxKfpIjhfd1g
# 3
# 4  3VJwpmmeoPlCN3J5p5miEQ

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"pizza","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': 'DJSLGbSqCJ1W8ma3LFlMuw',
#    'alias': 'patzeria-perfect-pizza-new-york',
#    'name': 'Patzeria Perfect Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/w62on7rHWF6ZNTVy6M6RuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patzeria-perfect-pizza-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1642,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.759494511551836,
#     'longitude': -73.98673451962638},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '231 W 46th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 W 46th St', 'New York, NY 10036']},
#    'phone': '+12125757646',
#    'display_phone': '(212) 575-7646',
#    'distance': 6043.69177290215},
#   {'id': 'MwcRbM6lS6_8N67LmyBELA',
#    'alias': '99-cent-fresh-pizza-new-york-5',
#    'name': '99 Cent Fresh Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yy7ZIhBQiVIsoBINay-MIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/99-cent-fresh-pizza-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 565,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76458, 'longitude': -73.98247},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1723 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1723 Broadway', 'New York, NY 10019']},
#    'phone': '+12122452155',
#    'display_phone': '(212) 245-2155',
#    'distance': 6652.683137648691},
#   {'id': 'rJ9V5bMbP_e9ABaTkPjAbA',
#    'alias': 'coco-pazzeria-new-york',
#    'name': 'Coco Pazzeria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ilUQcGz0ArOB9WovRQLxUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coco-pazzeria-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.726166, 'longitude': -74.008441},
#    'transactions': ['delivery'],
#    'location': {'address1': '307 Spring St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['307 Spring St', 'New York, NY 10013']},
#    'phone': '+16468501003',
#    'display_phone': '(646) 850-1003',
#    'distance': 2593.022397313367},
#   {'id': 'St8a2de1vfyCxwIySBUWbA',
#    'alias': 'graziellas-brooklyn-11',
#    'name': "Graziella's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GV0d871fK5Ys0lQRdaHBaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/graziellas-brooklyn-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 449,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6904563903809,
#     'longitude': -73.9696273803711},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '232 Vanderbilt Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['232 Vanderbilt Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17187895663',
#    'display_phone': '(718) 789-5663',
#    'distance': 2668.0909755132543},
#   {'id': 'lxPVSGnZ7YTiO5OGrqBS8Q',
#    'alias': 'vinnies-pizzeria-brooklyn',
#    'name': "Vinnie's Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Pw4iESsgzab7NXR_VTkVPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vinnies-pizzeria-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 701,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7189, 'longitude': -73.956843},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '148 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['148 Bedford Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17187827078',
#    'display_phone': '(718) 782-7078',
#    'distance': 3489.0079917146263},
#   {'id': 'xRiLLXjeM2wOvVTYJH2__A',
#    'alias': 'barboncino-pizza-and-bar-brooklyn-2',
#    'name': 'Barboncino Pizza & Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/48doX4sxCRLxOl8a6AD35Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barboncino-pizza-and-bar-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1012,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67206, 'longitude': -73.95717},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '781 Franklin Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['781 Franklin Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17184838834',
#    'display_phone': '(718) 483-8834',
#    'distance': 4850.790371389969},
#   {'id': 'kgvMqeMTgPz4ZGz7oj6cFg',
#    'alias': 'lazzaro-new-york',
#    'name': 'Lazzaro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/teuUbKwZ1MEwQQh-sfHQHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lazzaro-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70948, 'longitude': -74.012},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '110 Trinity Place',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10006',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['110 Trinity Place', 'New York, NY 10006']},
#    'phone': '+12127964499',
#    'display_phone': '(212) 796-4499',
#    'distance': 1562.5877759370537},
#   {'id': 'kcBTJsftfhKMc2UjGW48Tw',
#    'alias': 'jets-pizza-new-york',
#    'name': "Jet's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YFNG0aJq_xVdT6s5JThqgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jets-pizza-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74318, 'longitude': -74.00357},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '120 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['120 9th Ave', 'New York, NY 10011']},
#    'phone': '+13322095387',
#    'display_phone': '(332) 209-5387',
#    'distance': 4259.506390847472},
#   {'id': 'kVrTff8uDMSBAaceBwQ7dg',
#    'alias': 'saluggis-new-york',
#    'name': "Saluggi's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/P_NI4AhmWBAi4c33PViGMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saluggis-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 567,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720104, 'longitude': -74.003578},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '325 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['325 Church St', 'New York, NY 10013']},
#    'phone': '+12122267900',
#    'display_phone': '(212) 226-7900',
#    'distance': 1808.5885826304711},
#   {'id': 'rJJiGJx3kfMAxtD7P7okHQ',
#    'alias': 'celeste-restaurant-new-york-4',
#    'name': 'Celeste Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EA5ECJCF3AQBoc5kOuh92g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/celeste-restaurant-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 919,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.78666, 'longitude': -73.97599},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '502 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['502 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12128744559',
#    'display_phone': '(212) 874-4559',
#    'distance': 9164.23028791989},
#   {'id': 'OkyVxeVOO9DKLTqJS9R4Zw',
#    'alias': 'village-square-pizza-west-village-new-york',
#    'name': 'Village Square Pizza - West Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/M8M2g-fB3heAgjVmd0lk_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/village-square-pizza-west-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.733052, 'longitude': -74.005461},
#    'transactions': ['delivery'],
#    'location': {'address1': '118 Christopher St W',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['118 Christopher St W', 'New York, NY 10014']},
#    'phone': '+16466924028',
#    'display_phone': '(646) 692-4028',
#    'distance': 3212.6823963309116},
#   {'id': 'QfCbV1_VIjfCkowro_WGNA',
#    'alias': 'luigis-pizza-brooklyn',
#    'name': "Luigi's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WsGK3FQqwN79wtbczYR3ZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luigis-pizza-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 361,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.66163, 'longitude': -73.99334},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '686 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['686 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17184993857',
#    'display_phone': '(718) 499-3857',
#    'distance': 4871.041578229889},
#   {'id': 'ZzBCKPzIvaRr5k8319VpTg',
#    'alias': 'uncle-sams-pizza-new-york',
#    'name': "Uncle Sam's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VKhVgdisRq75c7hlWAYZVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uncle-sams-pizza-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.720827, 'longitude': -73.984367},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '17 Clinton St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 Clinton St', 'New York, NY 10002']},
#    'phone': '+16468761111',
#    'display_phone': '(646) 876-1111',
#    'distance': 1905.9448930852805},
#   {'id': 'CiRj1B-gK5tRfbMkq3SBog',
#    'alias': 'robertas-new-york-3',
#    'name': "Roberta's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ykSv069jx3mrHnmT3Le2cQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/robertas-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71995520720623,
#     'longitude': -73.98304455197378},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '196 Stanton St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['196 Stanton St', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1871.4089704068806},
#   {'id': 'cE7xZRpa8HLtGNtVhomysQ',
#    'alias': 'hoek-pizza-brooklyn-2',
#    'name': 'Hoek Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AQtq3MnweQgjmwLo96RaLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hoek-pizza-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 62,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6779064, 'longitude': -74.0169529},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '117 Ferris St',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['117 Ferris St', 'Brooklyn, NY 11231']},
#    'phone': '+17188558111',
#    'display_phone': '(718) 855-8111',
#    'distance': 3600.3861129864295},
#   {'id': 'GXq2Qsm--A7QQt9rTXldig',
#    'alias': 'deninos-pizzeria-and-tavern-staten-island-4',
#    'name': 'Deninos Pizzeria & Tavern',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/F62xvRp4vBIK8pzV3UhtTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/deninos-pizzeria-and-tavern-staten-island-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 783,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6302266718896,
#     'longitude': -74.1402754933448},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '524 Port Richmond Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10302',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['524 Port Richmond Ave', 'Staten Island, NY 10302']},
#    'phone': '+17184429401',
#    'display_phone': '(718) 442-9401',
#    'distance': 14884.48244182446},
#   {'id': '0-hM-ARw7sLpkyyow_qf6w',
#    'alias': 'artichoke-basilles-pizza-new-york-9',
#    'name': "Artichoke Basille's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qclxfo7Xy1Qmu464us9yCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/artichoke-basilles-pizza-new-york-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1612,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74406421842744,
#     'longitude': -74.00655890429283},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '114 10th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['114 10th Ave', 'New York, NY 10011']},
#    'phone': '+12127929200',
#    'display_phone': '(212) 792-9200',
#    'distance': 4416.915125626123},
#   {'id': '6BC5LQI4Cg3KChkgigo9sA',
#    'alias': 'lo-duca-pizza-brooklyn',
#    'name': 'Lo Duca Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TzsRRoCbP1MdWug79I7lRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lo-duca-pizza-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 123,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6349400235262,
#     'longitude': -73.9625812061059},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '14 Newkirk Plz',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11226',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 Newkirk Plz', 'Brooklyn, NY 11226']},
#    'phone': '+17188591501',
#    'display_phone': '(718) 859-1501',
#    'distance': 8283.427380652798},
#   {'id': 'bB5b8cj0yWNJvmmLiQeWGA',
#    'alias': 'piccolo-trattoria-new-york-2',
#    'name': 'Piccolo Trattoria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/02qKviMffBC0kBb9E81Z9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piccolo-trattoria-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 96,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7591676767848,
#     'longitude': -73.9525466887989},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '455 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10044',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['455 Main St', 'New York, NY 10044']},
#    'phone': '+12127532300',
#    'display_phone': '(212) 753-2300',
#    'distance': 6932.403227218253},
#   {'id': 'DLsqhCGZmEo48zsgduCbpQ',
#    'alias': 'lombardis-pizza-new-york-3',
#    'name': "Lombardi's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-8Id7zSey3eX2z7dsinGGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 152,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74623, 'longitude': -73.9974},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '290 8th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['290 8th Ave', 'New York, NY 10001']},
#    'phone': '+12122561973',
#    'display_phone': '(212) 256-1973',
#    'distance': 4544.250019376753},
#   {'id': 'an8TuHRg0e3cgiAE705ZDA',
#    'alias': 'fornino-brooklyn-5',
#    'name': 'Fornino',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TabOPQaFAlHNRYynVIs1AQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fornino-brooklyn-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 265,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6928735340776,
#     'longitude': -74.0016932280972},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Pier 6 Brooklyn Bridge Park',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Pier 6 Brooklyn Bridge Park', 'Brooklyn, NY 11201']},
#    'phone': '+17184221107',
#    'display_phone': '(718) 422-1107',
#    'distance': 1530.751249738525},
#   {'id': 'LRgB2kEKtBxqIxNksTO_PQ',
#    'alias': 'patrizias-williamsburg-brooklyn',
#    'name': "Patrizia's - Williamsburg",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OsItAhnu1KLVGxPfVAqFkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patrizias-williamsburg-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 702,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7109154314181,
#     'longitude': -73.9673637711639},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '35 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35 Broadway', 'Brooklyn, NY 11249']},
#    'phone': '+17182189272',
#    'display_phone': '(718) 218-9272',
#    'distance': 2349.983905012418},
#   {'id': 'yl5BoFbgHfrY62cLXwnCxQ',
#    'alias': 'pizza-moto-brooklyn-2',
#    'name': 'Pizza Moto',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kPnbudY20wUq67T7u1FVsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizza-moto-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 209,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6746224, 'longitude': -74.0007999},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '338 Hamilton Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['338 Hamilton Ave', 'Brooklyn, NY 11231']},
#    'phone': '+17188346686',
#    'display_phone': '(718) 834-6686',
#    'distance': 3470.9267183040233},
#   {'id': 'S9S-uR_AvwZnUM3lfBTIwQ',
#    'alias': 'village-pizza-new-york',
#    'name': 'Village Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/61Zo8f4GGJp232shQM7jKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/village-pizza-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 134,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73927, 'longitude': -74.00321},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '65 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['65 8th Ave', 'New York, NY 10014']},
#    'phone': '+12122434367',
#    'display_phone': '(212) 243-4367',
#    'distance': 3834.020053523422},
#   {'id': 'kVVjtVwlKwxKp4E345sdIw',
#    'alias': 'goodfellas-pizzeria-of-lic-long-island-city-2',
#    'name': 'Goodfellas Pizzeria of LIC',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Si0Vyw5DZ9XxYzEWKbmMUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/goodfellas-pizzeria-of-lic-long-island-city-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75334, 'longitude': -73.93716},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '25-19 40th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25-19 40th Ave', 'Long Island City, NY 11101']},
#    'phone': '+17184721932',
#    'display_phone': '(718) 472-1932',
#    'distance': 7185.71761100428},
#   {'id': 'fdaS1XvbEwWNIcLqv2C6Vw',
#    'alias': 'upside-pizza-new-york',
#    'name': 'Upside Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XTl4wZRuIElqDloExFqyEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/upside-pizza-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 168,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7550912, 'longitude': -73.9911494},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '598 8th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['598 8th Ave', 'New York, NY 10018']},
#    'phone': '+16464845244',
#    'display_phone': '(646) 484-5244',
#    'distance': 5530.918363742025},
#   {'id': 'k5fd-RSdG4IuXnnGSQ5oOw',
#    'alias': 'san-marzano-pasta-fresca-new-york',
#    'name': 'San Marzano Pasta Fresca',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zdM-ivewN83FqN36dZHChw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/san-marzano-pasta-fresca-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1270,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.727966, 'longitude': -73.988382},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '117 Second Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['117 Second Ave', 'New York, NY 10003']},
#    'phone': '+12127773600',
#    'display_phone': '(212) 777-3600',
#    'distance': 2557.918277420454},
#   {'id': 'LTi4_wcCVmqQeJ_jgTEbOQ',
#    'alias': 'emporio-new-york',
#    'name': 'Emporio',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CbrzzbxrkoucdhNfahv_rQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/emporio-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 801,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722647, 'longitude': -73.995246},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '231 Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 Mott St', 'New York, NY 10012']},
#    'phone': '+12129661234',
#    'display_phone': '(212) 966-1234',
#    'distance': 1908.6732685916875},
#   {'id': '75s8ErSnvhVTFx1Z4PRGqw',
#    'alias': 'sicilys-best-pizzeria-brooklyn',
#    'name': "Sicily's Best Pizzeria",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7gQdbwfbPYtsJG9oC8F36Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sicilys-best-pizzeria-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 80,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70517, 'longitude': -73.915155},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '190 Cypress Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['190 Cypress Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17184561833',
#    'display_phone': '(718) 456-1833',
#    'distance': 6671.9557271305885},
#   {'id': 'VrP6mI9Ihf2qt8dH6XwnYg',
#    'alias': 'protos-pizza-new-york-9',
#    'name': "Proto's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AdbSxI5lZGb6EBFJfvQAOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/protos-pizza-new-york-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 105,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.725353, 'longitude': -73.989746},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '50 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['50 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12124324044',
#    'display_phone': '(212) 432-4044',
#    'distance': 2243.224436697979},
#   {'id': 'H_Q1dEqnrz7GzQiArdsrNw',
#    'alias': 'sauce-pizzeria-new-york-5',
#    'name': 'Sauce Pizzeria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LigrJ0_aWj_XZ3oMMfkX9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sauce-pizzeria-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7204894, 'longitude': -73.98927},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '84 Rivington St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['84 Rivington St', 'New York, NY 10002']},
#    'phone': '+19176757240',
#    'display_phone': '(917) 675-7240',
#    'distance': 1725.6176928991938},
#   {'id': 'tRIHhPKryUZ56SfIz6mLiA',
#    'alias': 'angelos-coal-oven-pizzeria-new-york',
#    'name': "Angelo's Coal Oven Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LX6yLXzik0UVep_1JGG3aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/angelos-coal-oven-pizzeria-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 933,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76492, 'longitude': -73.97794},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '117 W 57th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['117 W 57th St', 'New York, NY 10019']},
#    'phone': '+12123334333',
#    'display_phone': '(212) 333-4333',
#    'distance': 6753.601098536139},
#   {'id': 'FpgzHQMSNTTjagrKXxOw5A',
#    'alias': 'san-matteo-pizzeria-e-cucina-new-york',
#    'name': 'San Matteo Pizzeria e Cucina',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SPsfsT6IwH7sOZNJMs0lGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/san-matteo-pizzeria-e-cucina-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 333,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7746799, 'longitude': -73.95443},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1559 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1559 2nd Ave', 'New York, NY 10028']},
#    'phone': '+12128612434',
#    'display_phone': '(212) 861-2434',
#    'distance': 8398.163391038213},
#   {'id': 'FKzpfWUpyupl4q74Jt8fTA',
#    'alias': 'don-antonio-new-york-5',
#    'name': 'Don Antonio',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Kwv16TeExWDWWLLbCNq7Cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/don-antonio-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1464,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.762711, 'longitude': -73.986708},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '309 W 50th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['309 W 50th St', 'New York, NY 10019']},
#    'phone': '+16467191043',
#    'display_phone': '(646) 719-1043',
#    'distance': 6399.689323736132},
#   {'id': '9DPI1WLAOfpiMXxHeQ0swg',
#    'alias': 'tailfeather-new-york',
#    'name': 'Tailfeather',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BU9K-kSLRnJ4GN5AvjEKLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tailfeather-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.69415, 'longitude': -73.96089},
#    'transactions': ['delivery'],
#    'location': {'address1': '581 Myrtle Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['581 Myrtle Ave', 'New York, NY 11205']},
#    'phone': '+13472405915',
#    'display_phone': '(347) 240-5915',
#    'distance': 3078.046336577469},
#   {'id': '9AP2VYXrBiea6KtOwb5xjQ',
#    'alias': 'philomenas-sunnyside',
#    'name': "Philomena's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2lC1aq14OGflT92nF2YFSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/philomenas-sunnyside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 128,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7432, 'longitude': -73.92275},
#    'transactions': ['delivery'],
#    'location': {'address1': '41-16 Queens Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41-16 Queens Blvd', 'Sunnyside, NY 11104']},
#    'phone': '+17182551778',
#    'display_phone': '(718) 255-1778',
#    'distance': 7337.076510867615},
#   {'id': 'MpF9j5-fBH0H6L9AzzyArA',
#    'alias': 'little-italy-pizza-new-york-25',
#    'name': 'Little Italy Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PVDO55__StArkCjy2mb_gA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-italy-pizza-new-york-25?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 134,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7081041823001,
#     'longitude': -74.0046897976739},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '50 Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['50 Fulton St', 'New York, NY 10038']},
#    'phone': '+12125717700',
#    'display_phone': '(212) 571-7700',
#    'distance': 924.8933702256317},
#   {'id': 'MHbxF-ZS918-ZoXKQPBEyg',
#    'alias': 'sotto-le-stelle-sunnyside',
#    'name': 'Sotto Le Stelle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XXa_1w-s3LEml0UyNRu8nw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sotto-le-stelle-sunnyside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 290,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.743656, 'longitude': -73.9201782},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '4407 Queens Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4407 Queens Blvd', 'Sunnyside, NY 11104']},
#    'phone': '+17186852086',
#    'display_phone': '(718) 685-2086',
#    'distance': 7553.869795682012},
#   {'id': 'X8Hl9OezX-Yr9Jir3fsF7g',
#    'alias': 'posto-new-york-4',
#    'name': 'Posto',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GNK1zpfkMKebOq7U5ljZqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/posto-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 621,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73483, 'longitude': -73.98282},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '310 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['310 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12127161200',
#    'display_phone': '(212) 716-1200',
#    'distance': 3407.292340600204},
#   {'id': 'vLaaNR3rTeSFEZe_nn43BA',
#    'alias': 'motorino-pizzeria-napoletana-brooklyn',
#    'name': 'Motorino Pizzeria Napoletana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AkVsxlXh7UuILkKEPGvPjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/motorino-pizzeria-napoletana-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 252,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.710559, 'longitude': -73.963462},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '139 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['139 Broadway', 'Brooklyn, NY 11211']},
#    'phone': '+17185998899',
#    'display_phone': '(718) 599-8899',
#    'distance': 2669.2827029041264},
#   {'id': 'EBK0OkVMBg_n_KxAU_4DZg',
#    'alias': 'double-zero-new-york',
#    'name': 'Double Zero',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XWqnsi72CwRQXpDZ3C7h4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/double-zero-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 562,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7261288, 'longitude': -73.9896645},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '65 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['65 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12127771608',
#    'display_phone': '(212) 777-1608',
#    'distance': 2326.9458661850313},
#   {'id': 'hFeGYPt9M5dd_KXG9a_ePQ',
#    'alias': 'patsy-s-pizzeria-new-york',
#    'name': 'Patsy’s Pizzeria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LUKTAs0KzLQ-wnnf8QoluA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patsy-s-pizzeria-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 418,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.76177, 'longitude': -73.96575},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '206 E 60th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['206 E 60th St', 'New York, NY 10022']},
#    'phone': '+12126889707',
#    'display_phone': '(212) 688-9707',
#    'distance': 6715.014923079241},
#   {'id': 'gu1gF8uZ_KvTzrL67hwH3g',
#    'alias': 'enzo-bruni-pizza-gourmet-new-york',
#    'name': 'Enzo Bruni Pizza Gourmet',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p9_-Y2mHat53L5XCZUTtUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/enzo-bruni-pizza-gourmet-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.783433, 'longitude': -73.947932},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1827 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1827 2nd Ave', 'New York, NY 10128']},
#    'phone': '+19176756867',
#    'display_phone': '(917) 675-6867',
#    'distance': 9510.074845435325},
#   {'id': 'uQBlitra7XJTFJPXUGWBJw',
#    'alias': 'alphonsos-pizzeria-and-trattoria-new-york',
#    'name': "Alphonso's Pizzeria & Trattoria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vYeAclQZHFTa2YC47hsrdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alphonsos-pizzeria-and-trattoria-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 133,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7143, 'longitude': -73.98172},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '525 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['525 Grand St', 'New York, NY 10002']},
#    'phone': '+12124773367',
#    'display_phone': '(212) 477-3367',
#    'distance': 1445.4936632430633},
#   {'id': 'g8Ai7LiusDgN_fpsdD8_fQ',
#    'alias': 'joe-and-sals-pizza-of-fort-greene-brooklyn',
#    'name': "Joe & Sal's Pizza Of Fort Greene",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-QksY22lcNbiboI7tUC6Pw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joe-and-sals-pizza-of-fort-greene-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69335, 'longitude': -73.97214},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '353 Myrtle Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['353 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+19179091420',
#    'display_phone': '(917) 909-1420',
#    'distance': 2299.366488836825},
#   {'id': 'BgGz5IdV53bGb4o7opR5zg',
#    'alias': 'arturos-new-york',
#    'name': "Arturo's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hUTu5vlfU4JYSNp-Qt0t4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arturos-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 705,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7273563342024,
#     'longitude': -74.0004944801331},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '106 W Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['106 W Houston St', 'New York, NY 10012']},
#    'phone': '+12126773820',
#    'display_phone': '(212) 677-3820',
#    'distance': 2491.867165709998},
#   {'id': '3RKrKV8eearo2zJPr3OO1g',
#    'alias': '99-cent-fresh-pizza-new-york-17',
#    'name': '99 Cent Fresh Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8ywIJ748F0ChRUYL7sNYDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/99-cent-fresh-pizza-new-york-17?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7216890942271,
#     'longitude': -74.0046280995011},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '383 Canal St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['383 Canal St', 'New York, NY 10013']},
#    'phone': '+12129661110',
#    'display_phone': '(212) 966-1110',
#    'distance': 2005.3354925503795},
#   {'id': 'V-FCEicobl5Su-R7EVJQNA',
#    'alias': 'la-lanterna-di-vittorio-new-york',
#    'name': 'La Lanterna Di Vittorio',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fniemSih6k-Gy103nmNVxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-lanterna-di-vittorio-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1501,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73069, 'longitude': -74.00015},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '129 MacDougal St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['129 MacDougal St', 'New York, NY 10012']},
#    'phone': '+19176393236',
#    'display_phone': '(917) 639-3236',
#    'distance': 2852.210394135104},
#   {'id': 'UB1mGugr1pvgUUP1eTNXrg',
#    'alias': 'stone-bridge-pizza-and-salad-new-york',
#    'name': 'Stone Bridge Pizza & Salad',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yfY3OA1Zd1GWBnbeZoWB8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stone-bridge-pizza-and-salad-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 289,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75225, 'longitude': -73.98061},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '16 E 41st St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['16 E 41st St', 'New York, NY 10017']},
#    'phone': '+16467915690',
#    'display_phone': '(646) 791-5690',
#    'distance': 5333.518247518763},
#   {'id': '1OZPOWZwJr-hpvMt6TD4ug',
#    'alias': 'milkflower-astoria',
#    'name': 'Milkflower',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SQG1kIYmNDRRoP35Xo6jPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/milkflower-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 689,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7628961, 'longitude': -73.9207081},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3412 31st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3412 31st Ave', 'Astoria, NY 11106']},
#    'phone': '+17182041300',
#    'display_phone': '(718) 204-1300',
#    'distance': 8902.311957108725}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                Restaurant     Type Price Rating             Address  \
# 0  Patzeria Perfect Pizza    Pizza     $      4       231 W 46th St
# 1     99 Cent Fresh Pizza    Pizza     $      4       1723 Broadway
# 2           Coco Pazzeria    Pizza                    307 Spring St
# 3             Graziella's  Italian    $$      4  232 Vanderbilt Ave
# 4       Vinnie's Pizzeria    Pizza     $      4     148 Bedford Ave
#
#          Lat        Lng                                                url  \
# 0  40.759495 -73.986735  https://www.yelp.com/biz/patzeria-perfect-pizz...
# 1  40.764580 -73.982470  https://www.yelp.com/biz/99-cent-fresh-pizza-n...
# 2  40.726166 -74.008441
# 3  40.690456 -73.969627  https://www.yelp.com/biz/graziellas-brooklyn-1...
# 4  40.718900 -73.956843  https://www.yelp.com/biz/vinnies-pizzeria-broo...
#
#                        ID
# 0  DJSLGbSqCJ1W8ma3LFlMuw
# 1  MwcRbM6lS6_8N67LmyBELA
# 2
# 3  St8a2de1vfyCxwIySBUWbA
# 4  lxPVSGnZ7YTiO5OGrqBS8Q

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"pizza","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [{'id': 'wTNUUoYUl3gox-gUAZ9bAA',
#    'alias': 'peppinos-brick-oven-pizza-and-restaurant-brooklyn-2',
#    'name': "Peppino's Brick Oven Pizza & Restaurant",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Mz8N4ggsttTNdvXBxJgr5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peppinos-brick-oven-pizza-and-restaurant-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 454,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.668221, 'longitude': -73.986936},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '469 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['469 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187687244',
#    'display_phone': '(718) 768-7244',
#    'distance': 4185.328288702886},
#   {'id': 'SxevJa1nDYO4KXKSO1Mosw',
#    'alias': 'luna-pizza-new-york',
#    'name': 'Luna Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KWyRhSGVVX_dogpCmCrAcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luna-pizza-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 93,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.713245675315, 'longitude': -73.998651104496},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '225 Park Row',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['225 Park Row', 'New York, NY 10038']},
#    'phone': '+12123858118',
#    'display_phone': '(212) 385-8118',
#    'distance': 941.9789923730051},
#   {'id': 'RqRCx09k0PZ4sZJgOxbAIA',
#    'alias': 'dough-vale-new-york',
#    'name': 'Dough Vale',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hvCluHOyqN6DyNQKs70_SQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dough-vale-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70933, 'longitude': -73.95407},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '330 S 3rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['330 S 3rd St', 'New York, NY 11211']},
#    'phone': '+13478897400',
#    'display_phone': '(347) 889-7400',
#    'distance': 3411.3706362931734},
#   {'id': 'xsQTIeq-WLkp4ParkTQpMQ',
#    'alias': 'pizzarte-new-york',
#    'name': 'PizzArte',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aoQCNBXCrUL1y-w7F7qTGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizzarte-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1144,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7629335072372,
#     'longitude': -73.9776668697596},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '69 W 55th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['69 W 55th St', 'New York, NY 10019']},
#    'phone': '+12122473936',
#    'display_phone': '(212) 247-3936',
#    'distance': 6544.13958857817},
#   {'id': '_gUAvmiTD5pPukKshL0NKg',
#    'alias': '1-pizza-new-york',
#    'name': '$1 Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TgX7rb23Tpxq0vOrpNRZkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/1-pizza-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7464708159905,
#     'longitude': -73.9899855852127},
#    'transactions': [],
#    'location': {'address1': '832 6th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['832 6th Ave', 'New York, NY 10001']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4576.291773404978},
#   {'id': '79bTSZd0QArz9xmninDdtQ',
#    'alias': 'trenta-tre-pizzeria-new-york-2',
#    'name': 'Trenta Tre Pizzeria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MiUjCfG0ktNCucxRtEfc5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trenta-tre-pizzeria-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 124,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74706, 'longitude': -73.98311},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '29 East 33rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['29 East 33rd St', 'New York, NY 10016']},
#    'phone': '+12126855300',
#    'display_phone': '(212) 685-5300',
#    'distance': 4721.400910671767},
#   {'id': 'orvnuNWLuoE3-iEx4Aj8eA',
#    'alias': 'bakers-pizza-new-york',
#    'name': "Baker's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xvJ_IVOxtTBd2YOFK_y7Rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bakers-pizza-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 238,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72942181645356,
#     'longitude': -73.98127671518847},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '201 Avenue A',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['201 Avenue A', 'New York, NY 10009']},
#    'phone': '+12127777477',
#    'display_phone': '(212) 777-7477',
#    'distance': 2882.982732419474},
#   {'id': 'WGG16MQeM96TAf7a39dQuw',
#    'alias': 'maspeth-pizza-maspeth',
#    'name': 'Maspeth Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ISrL0I8Dl5SvRjGYnPp8zQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maspeth-pizza-maspeth?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72815, 'longitude': -73.89206},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '7109 Grand Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Maspeth',
#     'zip_code': '11378',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7109 Grand Ave', 'Maspeth, NY 11378']},
#    'phone': '+17186395050',
#    'display_phone': '(718) 639-5050',
#    'distance': 8978.033083698081},
#   {'id': 'uGjj55HUdt99spaFLuY99w',
#    'alias': 'madison-street-pizza-new-york-2',
#    'name': 'Madison Street Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T283oz2NYXvM54LxUK_55g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/madison-street-pizza-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7129255709055,
#     'longitude': -73.9887648448348},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '223 Madison St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['223 Madison St', 'New York, NY 10002']},
#    'phone': '+19173882238',
#    'display_phone': '(917) 388-2238',
#    'distance': 953.4438237547969},
#   {'id': '4x04BopjwdGw_gwSgneCnQ',
#    'alias': 'corner-pizza-and-wine-brooklyn',
#    'name': 'Corner Pizza And Wine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sXN5yyDm7yneoBoTxHrhqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/corner-pizza-and-wine-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7148695, 'longitude': -73.9625803},
#    'transactions': ['delivery'],
#    'location': {'address1': '130 Grand St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['130 Grand St', 'Brooklyn, NY 11249']},
#    'phone': '+17188662828',
#    'display_phone': '(718) 866-2828',
#    'distance': 2864.027629035049},
#   {'id': '5C0vGV5YVjvsuvZuKvo6-w',
#    'alias': 'tony-boloneys-hoboken-hoboken',
#    'name': "Tony Boloney's - Hoboken",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DS06Uf-A3cfrfQgz1iESRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tony-boloneys-hoboken-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 617,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7378974, 'longitude': -74.0343764},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '263 1st St',
#     'address2': None,
#     'address3': None,
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['263 1st St', 'Hoboken, NJ 07030']},
#    'phone': '+12012228669',
#    'display_phone': '(201) 222-8669',
#    'distance': 4942.885283035966},
#   {'id': 'eTneVbjPKdo4gD9HfkDGdA',
#    'alias': 'santa-panza-brooklyn',
#    'name': 'Santa Panza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/i2mhjGgXUCS1YDWt2urv6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/santa-panza-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 183,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6947, 'longitude': -73.93068},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1079 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1079 Broadway', 'Brooklyn, NY 11221']},
#    'phone': '+13474139695',
#    'display_phone': '(347) 413-9695',
#    'distance': 5491.707809648726},
#   {'id': 'a0IET3_yCFcO36OqGSsisg',
#    'alias': 'eataly-flatiron-new-york',
#    'name': 'Eataly Flatiron',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/n9MMv47vKQiiUyeRSJkTDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eataly-flatiron-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5710,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74195877796, 'longitude': -73.989716662832},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '200 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 5th Ave', 'New York, NY 10010']},
#    'phone': '+12122292560',
#    'display_phone': '(212) 229-2560',
#    'distance': 4078.4333537925154},
#   {'id': 'J38XGzriEkMsDfCMt6et_g',
#    'alias': 'vezzo-new-york-2',
#    'name': 'Vezzo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UaxaZPmEk5diurSZpu2mzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vezzo-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1313,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.744435447210506, 'longitude': -73.9814189},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '178 Lexington Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['178 Lexington Ave', 'New York, NY 10016']},
#    'phone': '+12128398300',
#    'display_phone': '(212) 839-8300',
#    'distance': 4469.229898925912},
#   {'id': 'MeQU-nGaQvX12VXYOyzavQ',
#    'alias': 'gruppo-new-york-4',
#    'name': 'Gruppo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zZ9mk9zksLb9mv0yFLXC_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gruppo-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 261,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72474, 'longitude': -73.98161},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '98 Ave  B',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['98 Ave  B', 'New York, NY 10009']},
#    'phone': '+12129952100',
#    'display_phone': '(212) 995-2100',
#    'distance': 2395.292393079335},
#   {'id': 'mYQMjrtHp8vsEKKNsRz1XA',
#    'alias': 'union-pizza-works-brooklyn',
#    'name': 'Union Pizza Works',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/quZGt_v-07dUXFkUXYmJRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/union-pizza-works-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 261,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7073067, 'longitude': -73.922154},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '423 Troutman St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['423 Troutman St', 'Brooklyn, NY 11237']},
#    'phone': '+17186281927',
#    'display_phone': '(718) 628-1927',
#    'distance': 6084.319713624871},
#   {'id': 'dvUsg9UFFuUb2rE7RA5tnA',
#    'alias': 'brado-brooklyn-3',
#    'name': 'Brado',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7AEpx0ZjK4Cr2iwA67fkaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brado-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 150,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6905570310882,
#     'longitude': -73.9954792872909},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '155 Atlantic Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['155 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+19292981531',
#    'display_phone': '(929) 298-1531',
#    'distance': 1658.4666630544123},
#   {'id': 'EDYTUNp4bFO4dAwJMGuwCQ',
#    'alias': 'pizza-collective-new-york',
#    'name': 'Pizza Collective',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qlzlpnND0bzfNjw1zGvK5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizza-collective-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 65,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77795, 'longitude': -73.98155},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2060 Broadway',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2060 Broadway', 'New York, NY 10023']},
#    'phone': '+16466930949',
#    'display_phone': '(646) 693-0949',
#    'distance': 8090.0170924113745},
#   {'id': 'HV8xairb2qct7wSHqNwqXw',
#    'alias': 'levante-long-island-city',
#    'name': 'Levante',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/684bF9EC12x0Yy9JjmGXqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/levante-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 270,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74764, 'longitude': -73.94173},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '26-21 Jackson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26-21 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+17183923885',
#    'display_phone': '(718) 392-3885',
#    'distance': 6448.886397575788},
#   {'id': 'uPWyvfh5qSrVbujhjsDiiw',
#    'alias': 'oregano-brooklyn',
#    'name': 'Oregano',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UfCQWozhn4MTnupaktM9vQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oregano-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 438,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7190165, 'longitude': -73.9586248},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '102 Berry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 Berry St', 'Brooklyn, NY 11249']},
#    'phone': '+17185995988',
#    'display_phone': '(718) 599-5988',
#    'distance': 3363.8232350677754},
#   {'id': '_AqeaDQnMaErG19LobuU8Q',
#    'alias': 'wheated-brooklyn',
#    'name': 'Wheated',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nGlPNpQjGMDP7ZSi4LtReg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wheated-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 340,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'whiskeybars', 'title': 'Whiskey Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6465968960541,
#     'longitude': -73.9704950265688},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '905 Church Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11218',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['905 Church Ave', 'Brooklyn, NY 11218']},
#    'phone': '+13472402813',
#    'display_phone': '(347) 240-2813',
#    'distance': 6844.434796463964},
#   {'id': 'ynQ8NJB7SEAIkuUxopHPvA',
#    'alias': 'ignazios-brooklyn',
#    'name': "Ignazio's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8X6uFKW7BksKs7H8GYsQxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ignazios-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 550,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.703137, 'longitude': -73.993608},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '4 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+17185222100',
#    'display_phone': '(718) 522-2100',
#    'distance': 263.0425018849065},
#   {'id': 'PZFOk9BXEcCbl48Z8bnUFQ',
#    'alias': 'old-fashioned-pizza-new-york-2',
#    'name': 'Old Fashioned Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IzAffiKyCIt9j7_lO_ta-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/old-fashioned-pizza-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73182, 'longitude': -73.98607},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '244 E 13th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['244 E 13th St', 'New York, NY 10003']},
#    'phone': '+12125051781',
#    'display_phone': '(212) 505-1781',
#    'distance': 3002.2660678405273},
#   {'id': 'JiFG6HWsjIIbzOVPu2QljA',
#    'alias': 'death-by-pizza-new-york-2',
#    'name': 'Death By Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4eCcYVLwHwtgGFTxS0mbTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/death-by-pizza-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.739176881019205,
#     'longitude': -74.00178874784991},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '240 W 14th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['240 W 14th St', 'New York, NY 10011']},
#    'phone': '+12127319924',
#    'display_phone': '(212) 731-9924',
#    'distance': 3803.641701325306},
#   {'id': 'EsHcyOLHaK76bQuU7bwiTw',
#    'alias': 'tonys-pizzeria-and-restaurant-brooklyn-3',
#    'name': "Tony's Pizzeria & Restaurant",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wEPzpmEQ2Hd-WkeKUGe1Kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tonys-pizzeria-and-restaurant-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 324,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.699286, 'longitude': -73.918724},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '443 Knickerbocker Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['443 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17184559664',
#    'display_phone': '(718) 455-9664',
#    'distance': 6407.0089037876505},
#   {'id': 'he4wG_xmKaPW77p3re_7Lg',
#    'alias': 'norms-pizza-brooklyn',
#    'name': "Norm's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VTLezF4-4EAIAlQn-RMEww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/norms-pizza-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 71,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6926244183216,
#     'longitude': -73.9884449855341},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '345 Adams St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['345 Adams St', 'Brooklyn, NY 11201']},
#    'phone': '+13479161310',
#    'display_phone': '(347) 916-1310',
#    'distance': 1508.4118170772797},
#   {'id': 'FvlsWbL9vRrxF_z4QR2UuQ',
#    'alias': 'ginos-new-york-2',
#    'name': "Gino's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/T-70DSQbBKTLfJpgtlWGRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginos-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.710783, 'longitude': -73.9963431},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '81 Catherine St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81 Catherine St', 'New York, NY 10038']},
#    'phone': '+12129644533',
#    'display_phone': '(212) 964-4533',
#    'distance': 618.2100861958658},
#   {'id': 'HUY6yj38FXqAQvWUdgL0xA',
#    'alias': 'sirenetta-new-york-2',
#    'name': 'Sirenetta',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/joE3nu3NZ_5VIVTGpCn2lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sirenetta-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 292,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78881, 'longitude': -73.97459},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '568 Amsterdam Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['568 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12127997401',
#    'display_phone': '(212) 799-7401',
#    'distance': 9416.060899375447},
#   {'id': 'LO2kgBEQZJ-ceFbj6-UaEA',
#    'alias': 'mos-general-brooklyn',
#    'name': "Mo's General",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hCAZA0LzKXDw5cAFeZZlvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mos-general-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71562045514015, 'longitude': -73.9494481},
#    'transactions': [],
#    'location': {'address1': '620 Lorimer St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['620 Lorimer St', 'Brooklyn, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3945.5877654838296},
#   {'id': 'fyC2cBsQ0FsMJmv0jSworg',
#    'alias': 'donna-margherita-new-york',
#    'name': 'Donna Margherita',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4chLqGmT-geUbtlsjf5wzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/donna-margherita-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 96,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76652, 'longitude': -73.9598},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1304 2nd Ave',
#     'address2': 'Ste A',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1304 2nd Ave', 'Ste A', 'New York, NY 10065']},
#    'phone': '+12127721169',
#    'display_phone': '(212) 772-1169',
#    'distance': 7381.263054780704},
#   {'id': 'uSOnbiYkOgrcIF6IyBxgHg',
#    'alias': 'slice-joint-new-york',
#    'name': 'Slice Joint',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/J7g0XXShiiTaK6ro1r5ItQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/slice-joint-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71827, 'longitude': -73.98806},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '115 Delancey St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['115 Delancey St', 'New York, NY 10002']},
#    'phone': '+13324560129',
#    'display_phone': '(332) 456-0129',
#    'distance': 1517.088677269159},
#   {'id': 'Z67mgMkN3RfdPEX5mXsyYA',
#    'alias': 'piacere-new-york',
#    'name': 'Piacere',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nP5_rJ7tlw_ZamiMN1zxOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piacere-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 677,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7196979, 'longitude': -73.9951175},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '351 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['351 Broome St', 'New York, NY 10013']},
#    'phone': '+12122194080',
#    'display_phone': '(212) 219-4080',
#    'distance': 1586.3855179286054},
#   {'id': 'G4KNXsc7F49OzkW7I28JCg',
#    'alias': 'best-pizza-brooklyn',
#    'name': 'Best Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ciSOpSIk6VIYaxl3IdVqvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/best-pizza-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 634,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7156, 'longitude': -73.95352},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '33 Havemeyer St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33 Havemeyer St', 'Brooklyn, NY 11211']},
#    'phone': '+17185992210',
#    'display_phone': '(718) 599-2210',
#    'distance': 3621.3461980147513},
#   {'id': 'MGd6HFEq1ALD58XWNviSXw',
#    'alias': 'time-out-market-new-york-brooklyn',
#    'name': 'Time Out Market New York',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/I5ybhy4J7GWCel1wZ4NJng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/time-out-market-new-york-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 290,
#    'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7037211399782,
#     'longitude': -73.9918105285751},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '55 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+19178104855',
#    'display_phone': '(917) 810-4855',
#    'distance': 283.7853104247956},
#   {'id': 'Qab4GBAxxjacF4KsXLFETA',
#    'alias': 'sal-and-carmines-pizza-new-york',
#    'name': "Sal & Carmine's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mfPyry6ctCZ_7uV0tlzjHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sal-and-carmines-pizza-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 363,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7983115, 'longitude': -73.9694405},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '2671 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2671 Broadway', 'New York, NY 10025']},
#    'phone': '+12126637651',
#    'display_phone': '(212) 663-7651',
#    'distance': 10544.162382174953},
#   {'id': 'eVk4F9ixl89zyUHJ1G2Aiw',
#    'alias': 'luzzos-la-pizza-napoletana-new-york-10',
#    'name': 'Luzzos La Pizza Napoletana',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/siQq0MnFSCXmAd8rg28EwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luzzos-la-pizza-napoletana-new-york-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1051,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.730616, 'longitude': -73.9834846},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '211 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['211 1st Ave', 'New York, NY 10003']},
#    'phone': '+12124737447',
#    'display_phone': '(212) 473-7447',
#    'distance': 2943.403489083045},
#   {'id': 'zo4JHfD2nWPUiqgsgDOaHQ',
#    'alias': 'raos-new-york',
#    'name': "Rao's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/B7RWu3d1c8KM9SF1OoCnZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raos-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 186,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.79392, 'longitude': -73.93427},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '455 E 114th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['455 E 114th St', 'New York, NY 10029']},
#    'phone': '+12127226709',
#    'display_phone': '(212) 722-6709',
#    'distance': 11067.267086274775},
#   {'id': 'JnFV_qz7uWbLTY80K89J7Q',
#    'alias': 'emmetts-new-york-2',
#    'name': "Emmett's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HYRCZvifmipKhOh7_4-Pog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/emmetts-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 531,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.727303, 'longitude': -74.00243},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '50 Macdougal St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['50 Macdougal St', 'New York, NY 10012']},
#    'phone': '+19176393571',
#    'display_phone': '(917) 639-3571',
#    'distance': 2525.403139418779},
#   {'id': 'asxQ9Kf3RjigsftsTVk53A',
#    'alias': 'two-boots-east-village-new-york',
#    'name': 'Two Boots East Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NYuHQ29xJinOQhXptuGRAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/two-boots-east-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 386,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72369, 'longitude': -73.98489},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '42 Ave A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 Ave A', 'New York, NY 10009']},
#    'phone': '+12122541919',
#    'display_phone': '(212) 254-1919',
#    'distance': 2177.537270004616},
#   {'id': '02sAHm3_CsRKE2IeT5iaPA',
#    'alias': 'table-87-gowanus-brooklyn-2',
#    'name': 'Table 87 - Gowanus',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OSV-qVJS7BQKFJWMWuYcbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/table-87-gowanus-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 365,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.670664, 'longitude': -73.991371},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '473 3rd Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['473 3rd Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17189658400',
#    'display_phone': '(718) 965-8400',
#    'distance': 3876.0599051509726},
#   {'id': 'zTHxVxp0gxcwdFDRFRN4cw',
#    'alias': 'triangolo-pizza-brooklyn',
#    'name': 'Triangolo Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2NMAU9cHwEDvXA6jEh5vug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/triangolo-pizza-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 118,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73357, 'longitude': -73.955116},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1017 Manhattan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1017 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183895885',
#    'display_phone': '(718) 389-5885',
#    'distance': 4547.3523862290285},
#   {'id': 'P7w6ZqD1qkAaBgKu11sO5w',
#    'alias': 'rivington-pizza-new-york-2',
#    'name': 'Rivington Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x488HeoLFr0dIGz2otrI6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rivington-pizza-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.719146, 'longitude': -73.984627},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '170 Rivington St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['170 Rivington St', 'New York, NY 10002']},
#    'phone': '+16463603343',
#    'display_phone': '(646) 360-3343',
#    'distance': 1736.0400721664853},
#   {'id': 'lXzK0i9VnocLzPFwmEQ8Aw',
#    'alias': 'garlic-new-york-pizza-bar-new-york',
#    'name': 'Garlic New York Pizza Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KUDk37COz8J68fLEimn6Bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/garlic-new-york-pizza-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 448,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74514, 'longitude': -73.97584},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '629 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['629 2nd Ave', 'New York, NY 10016']},
#    'phone': '+16465599500',
#    'display_phone': '(646) 559-9500',
#    'distance': 4680.073877625548},
#   {'id': 'PQd4M3cuSgdweWgLgZIslQ',
#    'alias': 'inatteso-pizzabar-new-york',
#    'name': 'Inatteso Pizzabar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0ZZULDJXEGL35JUGQyHnCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/inatteso-pizzabar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 327,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7056571, 'longitude': -74.0172056},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '28 West St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 West St', 'New York, NY 10004']},
#    'phone': '+12122678000',
#    'display_phone': '(212) 267-8000',
#    'distance': 1919.3110107593948},
#   {'id': 'MTQpqHo-cCAPK7c9fd6zHw',
#    'alias': 'il-mattone-new-york-3',
#    'name': 'Il Mattone',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BLxg8yKubvwvlaD2VDbGeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-mattone-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 92,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.720799, 'longitude': -74.0091255},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '49 Beach St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['49 Beach St', 'New York, NY 10013']},
#    'phone': '+16469644623',
#    'display_phone': '(646) 964-4623',
#    'distance': 2116.053968418348},
#   {'id': 'Kh0-HmlgmVUkRxR55_Vn1g',
#    'alias': 'patsys-pizzeria-new-york-7',
#    'name': "Patsy's Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gXl9HrfT338PuJpwPjlUkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patsys-pizzeria-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 873,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.797157, 'longitude': -73.93488},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2287 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10035',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2287 1st Ave', 'New York, NY 10035']},
#    'phone': '+12125349783',
#    'display_phone': '(212) 534-9783',
#    'distance': 11359.776930320333},
#   {'id': 'M-2aF4N8jIewBt3UoYEYJg',
#    'alias': 'fornino-greenpoint-brooklyn-3',
#    'name': 'Fornino- Greenpoint',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RyfcMp49ZGy7aVVa7xGW2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fornino-greenpoint-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 237,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.728949, 'longitude': -73.953999},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '849 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['849 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183895300',
#    'display_phone': '(718) 389-5300',
#    'distance': 4285.2128881723675},
#   {'id': 'VP3-iMnKK_TaHDuy6mxTzA',
#    'alias': 'scotts-pizza-tours-new-york',
#    'name': "Scott's Pizza Tours",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nhfA9SXPjeX9H4KfjTcn9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scotts-pizza-tours-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 323,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'foodtours', 'title': 'Food Tours'},
#     {'alias': 'walkingtours', 'title': 'Walking Tours'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.750244140625,
#     'longitude': -73.9970245361328},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['New York, NY 10001']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5379.773739687928},
#   {'id': 'AYBRN8pKB8_ZfcCks17OmQ',
#    'alias': 'beebes-long-island-city-4',
#    'name': "Beebe's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iEToVluuxHpqfU-PXUN0UA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beebes-long-island-city-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 144,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.754827, 'longitude': -73.935918},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '38-28 27th St',
#     'address2': '',
#     'address3': 'Boro Hotel',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38-28 27th St',
#      'Boro Hotel',
#      'Long Island City, NY 11101']},
#    'phone': '+17182082895',
#    'display_phone': '(718) 208-2895',
#    'distance': 7374.530538532513},
#   {'id': 'Zjj8JkJm0yRyrUFffr7Eww',
#    'alias': 'midici-neapolitan-pizza-brooklyn',
#    'name': 'MidiCi Neapolitan Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bwoLy3pM9l5Avr6xlve0Aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/midici-neapolitan-pizza-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 82,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71529, 'longitude': -73.95858},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '174 N 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['174 N 4th St', 'Brooklyn, NY 11211']},
#    'phone': '+17187822020',
#    'display_phone': '(718) 782-2020',
#    'distance': 3203.565774800785}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#                                 Restaurant   Type Price Rating       Address  \
# 0  Peppino's Brick Oven Pizza & Restaurant  Pizza    $$    4.5   469 5th Ave
# 1                               Luna Pizza  Pizza    $$      4  225 Park Row
# 2                               Dough Vale  Pizza    $$    4.5  330 S 3rd St
# 3                                 PizzArte  Pizza    $$      4  69 W 55th St
# 4                                 $1 Pizza  Pizza                832 6th Ave
#
#          Lat        Lng                                                url  \
# 0  40.668221 -73.986936  https://www.yelp.com/biz/peppinos-brick-oven-p...
# 1  40.713246 -73.998651  https://www.yelp.com/biz/luna-pizza-new-york?a...
# 2  40.709330 -73.954070  https://www.yelp.com/biz/dough-vale-new-york?a...
# 3  40.762934 -73.977667  https://www.yelp.com/biz/pizzarte-new-york?adj...
# 4  40.746471 -73.989986
#
#                        ID
# 0  wTNUUoYUl3gox-gUAZ9bAA
# 1  SxevJa1nDYO4KXKSO1Mosw
# 2  RqRCx09k0PZ4sZJgOxbAIA
# 3  xsQTIeq-WLkp4ParkTQpMQ
# 4

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                         Restaurant                    Type Rating Price  \
# 0                         Emmett's  American (Traditional)      4    $$
# 1                      Santa Panza                    Bars    4.5    $$
# 2                       Hoek Pizza                    Bars
# 3         Time Out Market New York              Food Court    3.5    $$
# 4                          Oregano                 Italian      4    $$
# 5                         Arturo's                 Italian      4    $$
# 6                Union Pizza Works                 Italian      4    $$
# 7                    Gelso & Grand                 Italian    4.5    $$
# 8                            Leuca                 Italian      4   $$$
# 9                            Sauce                 Italian      4    $$
# 10                 Eataly Flatiron                 Italian      4    $$
# 11                     IL Brigante                 Italian      4    $$
# 12                   Burrata Pizza                 Italian
# 13                       Adoro Lei                 Italian    4.5    $$
# 14    Montesacro Pinseria Brooklyn                 Italian    4.5    $$
# 15                           Norma                 Italian    4.5    $$
# 16      Patrizia's Pizza and Pasta                 Italian      4    $$
# 17                Patsy’s Pizzeria                 Italian    3.5    $$
# 18         La Lanterna Di Vittorio                 Italian      4    $$
# 19                      Rosemary’s                 Italian
# 20                        Sotto 13                 Italian      4    $$
# 21                       Piz-zetta                 Italian    4.5     $
# 22          My Pie Pizzeria Romana                 Italian    4.5     $
# 23                         Emporio                 Italian      4    $$
# 24        San Marzano Pasta Fresca                 Italian      4    $$
# 25                     Forno Rosso                 Italian      4    $$
# 26       Garlic New York Pizza Bar                 Italian    3.5     $
# 27              Celeste Restaurant                 Italian    3.5    $$
# 28                        Rubirosa                 Italian    4.5    $$
# 29                     Graziella's                 Italian      4    $$
# ..                             ...                     ...    ...   ...
# 170         Patzeria Perfect Pizza                   Pizza      4     $
# 171            99 Cent Fresh Pizza                   Pizza      4     $
# 172                  Coco Pazzeria                   Pizza
# 173              Vinnie's Pizzeria                   Pizza      4     $
# 174                   Speedy Romeo                   Pizza      4    $$
# 175                 Bellucci Pizza                   Pizza
# 176                     SIMÒ PIZZA                   Pizza    4.5     $
# 177                  Zazzy's Pizza                   Pizza
# 178        Emmy Squared - Brooklyn                   Pizza      4    $$
# 179  Brooklyn's Homeslice Pizzeria                   Pizza    4.5     $
# 180            Il Porto Ristorante                   Pizza      4    $$
# 181                 Sauce Pizzeria                   Pizza    4.5     $
# 182                  Song E Napule                   Pizza    4.5    $$
# 183                Unregular Pizza                   Pizza    4.5    $$
# 184                   Giuseppina's                   Pizza    4.5    $$
# 185                  Fascati Pizza                   Pizza      4     $
# 186      Artichoke Basille's Pizza                   Pizza    3.5     $
# 187                    MAMA'S TOO!                   Pizza    3.5    $$
# 188        Paulie Gee's Slice Shop                   Pizza      4     $
# 189                  Zazzy's Pizza                   Pizza
# 190                 Marinara Pizza                   Pizza      4     $
# 191                  Mario’s Pizza                   Pizza
# 192                            Ops                   Pizza    4.5    $$
# 193                 Marinara Pizza                   Pizza
# 194                   Rosa's Pizza                   Pizza    4.5     $
# 195                         Barano                   Pizza    4.5   $$$
# 196        MidiCi Neapolitan Pizza                   Pizza    4.5    $$
# 197       Tony Boloney's - Hoboken                   Salad    3.5    $$
# 198                     Follia NYC               Wine Bars      4    $$
# 199                    Tailfeather               Wine Bars
#
#                   Address        Lat        Lng  \
# 0         50 Macdougal St  40.727303 -74.002430
# 1           1079 Broadway  40.694700 -73.930680
# 2           117 Ferris St  40.677906 -74.016953
# 3             55 Water St  40.703721 -73.991811
# 4            102 Berry St  40.719017 -73.958625
# 5        106 W Houston St  40.727356 -74.000494
# 6         423 Troutman St  40.707307 -73.922154
# 7            186 Grand St  40.719409 -73.997378
# 8           111 N 12th St  40.722121 -73.956678
# 9         78 Rivington St  40.720472 -73.989326
# 10            200 5th Ave  40.741959 -73.989717
# 11           214 Front St  40.707492 -74.002571
# 12              221 Ave A  40.730200 -73.980690
# 13          287 Hudson St  40.725612 -74.007916
# 14          432 Union Ave  40.713380 -73.951360
# 15            438 3rd Ave  40.743553 -73.980026
# 16        462-466 2nd Ave  40.739841 -73.979286
# 17          206 E 60th St  40.761770 -73.965750
# 18       129 MacDougal St  40.730690 -74.000150
# 19            350 1st Ave  40.735120 -73.979650
# 20          140 W 13th St  40.737200 -73.999190
# 21       90 Livingston St  40.691283 -73.990603
# 22      690 Lexington Ave  40.760851 -73.969481
# 23            231 Mott St  40.722647 -73.995246
# 24         117 Second Ave  40.727966 -73.988382
# 25            327 Gold St  40.694467 -73.982930
# 26            629 2nd Ave  40.745140 -73.975840
# 27      502 Amsterdam Ave  40.786660 -73.975990
# 28        235 Mulberry St  40.722766 -73.996233
# 29     232 Vanderbilt Ave  40.690456 -73.969627
# ..                    ...        ...        ...
# 170         231 W 46th St  40.759495 -73.986735
# 171         1723 Broadway  40.764580 -73.982470
# 172         307 Spring St  40.726166 -74.008441
# 173       148 Bedford Ave  40.718900 -73.956843
# 174       376 Classon Ave  40.687515 -73.959874
# 175        29-04 30th Ave  40.767729 -73.923463
# 176   90-92 Gansevoort St  40.739260 -74.008813
# 177      75 Greenwich Ave  40.736699 -74.001447
# 178          364 Grand St  40.712168 -73.955707
# 179    567 Vanderbilt Ave  40.680702 -73.967455
# 180     37 Washington Ave  40.697443 -73.967520
# 181         345 E 12th St  40.730330 -73.984030
# 182      146 W Houston St  40.728130 -74.001880
# 183           135 4th Ave  40.733980 -73.989610
# 184           691 6th Ave  40.660343 -73.990774
# 185           80 Henry St  40.698500 -73.992730
# 186            59 5th Ave  40.681011 -73.977181
# 187         2750 Broadway  40.800840 -73.967660
# 188       110 Franklin St  40.728360 -73.957200
# 189        173 Orchard St  40.721617 -73.988620
# 190    1376 Lexington Ave  40.782600 -73.953510
# 191     940 Manhattan Ave  40.731392 -73.954136
# 192         346 Himrod St  40.702760 -73.917100
# 193        379 Park Ave S  40.742410 -73.984520
# 194  374 Metropolitan Ave  40.713950 -73.955630
# 195           26 Broadway  40.710372 -73.967940
# 196          174 N 4th St  40.715290 -73.958580
# 197            263 1st St  40.737897 -74.034376
# 198           179 3rd Ave  40.734924 -73.985588
# 199        581 Myrtle Ave  40.694150 -73.960890
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/emmetts-new-york-2?ad...  JnFV_qz7uWbLTY80K89J7Q
# 1    https://www.yelp.com/biz/santa-panza-brooklyn?...  eTneVbjPKdo4gD9HfkDGdA
# 2
# 3    https://www.yelp.com/biz/time-out-market-new-y...  MGd6HFEq1ALD58XWNviSXw
# 4    https://www.yelp.com/biz/oregano-brooklyn?adju...  uPWyvfh5qSrVbujhjsDiiw
# 5    https://www.yelp.com/biz/arturos-new-york?adju...  BgGz5IdV53bGb4o7opR5zg
# 6    https://www.yelp.com/biz/union-pizza-works-bro...  mYQMjrtHp8vsEKKNsRz1XA
# 7    https://www.yelp.com/biz/gelso-and-grand-new-y...  MphfKkYFEe0BDQ6hZ0A5fA
# 8    https://www.yelp.com/biz/leuca-brooklyn?adjust...  fH8DkdRerw5LJ7fZZHRfeA
# 9    https://www.yelp.com/biz/sauce-new-york-3?adju...  M4pCWzdBCkp2g_d834a7Hw
# 10   https://www.yelp.com/biz/eataly-flatiron-new-y...  a0IET3_yCFcO36OqGSsisg
# 11   https://www.yelp.com/biz/il-brigante-new-york?...  xeC9vn3dxVVzAMR_aFwfXg
# 12
# 13   https://www.yelp.com/biz/adoro-lei-new-york?ad...  xzN2k19JXDYjOWAhNw62aw
# 14   https://www.yelp.com/biz/montesacro-pinseria-b...  CFR-HzVHKWRMpMAR3LAhzg
# 15   https://www.yelp.com/biz/norma-new-york-5?adju...  vVVmHacu2YAxKfpIjhfd1g
# 16   https://www.yelp.com/biz/patrizias-pizza-and-p...  kIm0oeOaVfC9-2flLPVklA
# 17   https://www.yelp.com/biz/patsy-s-pizzeria-new-...  hFeGYPt9M5dd_KXG9a_ePQ
# 18   https://www.yelp.com/biz/la-lanterna-di-vittor...  V-FCEicobl5Su-R7EVJQNA
# 19
# 20   https://www.yelp.com/biz/sotto-13-new-york-7?a...  yc4vsT-Q4Ej1_9hr94DxkQ
# 21   https://www.yelp.com/biz/piz-zetta-brooklyn-2?...  i_rg-OLXQbpRUN7O3MeCeA
# 22   https://www.yelp.com/biz/my-pie-pizzeria-roman...  oRdM7n-AfBPBGAlH4Q0Sag
# 23   https://www.yelp.com/biz/emporio-new-york?adju...  LTi4_wcCVmqQeJ_jgTEbOQ
# 24   https://www.yelp.com/biz/san-marzano-pasta-fre...  k5fd-RSdG4IuXnnGSQ5oOw
# 25   https://www.yelp.com/biz/forno-rosso-brooklyn?...  ZTsN8TdMXl8SW_AKd_ablw
# 26   https://www.yelp.com/biz/garlic-new-york-pizza...  lXzK0i9VnocLzPFwmEQ8Aw
# 27   https://www.yelp.com/biz/celeste-restaurant-ne...  rJJiGJx3kfMAxtD7P7okHQ
# 28   https://www.yelp.com/biz/rubirosa-new-york-2?a...  WG639VkTjmK5dzydd1BBJA
# 29   https://www.yelp.com/biz/graziellas-brooklyn-1...  St8a2de1vfyCxwIySBUWbA
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/patzeria-perfect-pizz...  DJSLGbSqCJ1W8ma3LFlMuw
# 171  https://www.yelp.com/biz/99-cent-fresh-pizza-n...  MwcRbM6lS6_8N67LmyBELA
# 172
# 173  https://www.yelp.com/biz/vinnies-pizzeria-broo...  lxPVSGnZ7YTiO5OGrqBS8Q
# 174  https://www.yelp.com/biz/speedy-romeo-brooklyn...  zHtCLIChaKxqFXfMZQHkMQ
# 175
# 176  https://www.yelp.com/biz/sim%C3%B2-pizza-new-y...  H8qcX7MNNnC1bqE0LnIhKg
# 177
# 178  https://www.yelp.com/biz/emmy-squared-brooklyn...  UuY1QCxWybMF0IMxAYG06w
# 179  https://www.yelp.com/biz/brooklyns-homeslice-p...  3VJwpmmeoPlCN3J5p5miEQ
# 180  https://www.yelp.com/biz/il-porto-ristorante-b...  hFmz7HH2og9hn7xNNv20yw
# 181  https://www.yelp.com/biz/sauce-pizzeria-new-yo...  d8USIZvTTqee35l34anRBg
# 182  https://www.yelp.com/biz/song-e-napule-new-yor...  15k7iqFbhf4h8L01yggLqg
# 183  https://www.yelp.com/biz/unregular-pizza-new-y...  AHDlsNh8fODK9miC3zv3Zg
# 184  https://www.yelp.com/biz/giuseppinas-brooklyn?...  IZ9-5z45wc3Oh_jlnX_Kcg
# 185  https://www.yelp.com/biz/fascati-pizza-brookly...  cS2dquz8jSagXqeVKBwSsg
# 186  https://www.yelp.com/biz/artichoke-basilles-pi...  OVrHAnfna46SdaFnTNqhhQ
# 187  https://www.yelp.com/biz/mamas-too-new-york?ad...  m3PS0tIaa0ChcP8Y5S-DrQ
# 188  https://www.yelp.com/biz/paulie-gees-slice-sho...  2FgUndzCT_jJATbmrBDVBg
# 189
# 190  https://www.yelp.com/biz/marinara-pizza-new-yo...  AoezuAP-QOH6JZZOmyzJLg
# 191
# 192  https://www.yelp.com/biz/ops-brooklyn?adjust_c...  vmUNPvduTeWu24d--TbHAg
# 193
# 194  https://www.yelp.com/biz/rosas-pizza-brooklyn?...  aPn2_EtjfHduXEmEBNxuFA
# 195  https://www.yelp.com/biz/barano-brooklyn?adjus...  rJfGgBleDYCVq2rkBr_w-Q
# 196  https://www.yelp.com/biz/midici-neapolitan-piz...  Zjj8JkJm0yRyrUFffr7Eww
# 197  https://www.yelp.com/biz/tony-boloneys-hoboken...  5C0vGV5YVjvsuvZuKvo6-w
# 198  https://www.yelp.com/biz/follia-nyc-new-york?a...  78TCGIG1eHMYdyvMpFdDbQ
# 199
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_Pizza.csv')
