# %% [markdown]
# LONDON RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
lndr_params1 = {"term":"Polish","location":"London","limit":50,"offset":0}
lndr_response1 = requests.get(search_api_url, headers=headers, params=lndr_params1)
lndr1 = lndr_response1.json()
display(lndr1)
#print(lndr_response1.url)
#print(lndr_response1.status_code)
# Out:
# {'businesses': [{'id': '1xbPH2-s_uNu2YicJFNdgQ',
#    'alias': 'pyrlandia-london',
#    'name': 'Pyrlandia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/U8GA9XEPo41PhRKcEx90qg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pyrlandia-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'},
#     {'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.512115761958,
#     'longitude': -0.133606195449829},
#    'transactions': [],
#    'location': {'address1': 'Rupert Street Market',
#     'address2': 'Rupert Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W4 1LU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Rupert Street Market',
#      'Rupert Street',
#      'London W4 1LU',
#      'United Kingdom']},
#    'phone': '+447590373160',
#    'display_phone': '+44 7590 373160',
#    'distance': 181.22655260521063},
#   {'id': 'wTuLet6gV2Vj-wH_LoSB0A',
#    'alias': 'mamuska-polish-kitchen-and-bar-london',
#    'name': 'Mamuska - Polish Kitchen & Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/II7T4z3P4ECD0kgD4IvGOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mamuska-polish-kitchen-and-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.501304, 'longitude': -0.116066},
#    'transactions': [],
#    'location': {'address1': '9 Addington Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7RY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Addington Street',
#      'London SE1 7RY',
#      'United Kingdom']},
#    'phone': '+442036021898',
#    'display_phone': '+44 20 3602 1898',
#    'distance': 1938.8804644561535},
#   {'id': '0SfwQrzLJ_vOEDEJ5Im_5g',
#    'alias': 'bar-polski-london',
#    'name': 'Bar Polski',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hoq4vBhPxnzrihai9GPqPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-polski-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5174144, 'longitude': -0.1190414},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Little Turnstile',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1V 7DX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Little Turnstile',
#      'London WC1V 7DX',
#      'United Kingdom']},
#    'phone': '+442078319679',
#    'display_phone': '+44 20 7831 9679',
#    'distance': 1276.379984129975},
#   {'id': 'fDul4h-8jhWtVB4tDhV9QQ',
#    'alias': 'lowiczanka-polish-centre-restaurant-london',
#    'name': 'Lowiczanka Polish Centre Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4cbBH821imYkUsYmmbwgug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lowiczanka-polish-centre-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4933573, 'longitude': -0.2371255},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '238-246 King Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W6 0QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['238-246 King Street',
#      'London W6 0QL',
#      'United Kingdom']},
#    'phone': '+442087413225',
#    'display_phone': '+44 20 8741 3225',
#    'distance': 7337.990622814627},
#   {'id': 'FEy2mxjof_2WvBCRCn3X-w',
#    'alias': 'sowa-restaurant-ealing-broadway',
#    'name': 'Sowa Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qEVC1v8QyKa77MvNzcAWvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sowa-restaurant-ealing-broadway?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5121721, 'longitude': -0.3050028},
#    'transactions': [],
#    'location': {'address1': '33 High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Ealing Broadway',
#     'zip_code': 'W5 5DB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['33 High Street',
#      'Ealing Broadway W5 5DB',
#      'United Kingdom']},
#    'phone': '+442085677707',
#    'display_phone': '+44 20 8567 7707',
#    'distance': 11688.795334535953},
#   {'id': '2TJvSFxtzO2w-ZxipJOtwQ',
#    'alias': 'smoke-and-salt-london-2',
#    'name': 'Smoke & Salt',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vV4Eqb9cP0x8Oupy20wQJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/smoke-and-salt-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4635098, 'longitude': -0.1123464},
#    'transactions': [],
#    'location': {'address1': 'Pop Brixton',
#     'address2': '49 Brixton Station Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 8PQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Pop Brixton',
#      '49 Brixton Station Road',
#      'London SW9 8PQ',
#      'United Kingdom']},
#    'phone': '+447421327556',
#    'display_phone': '+44 7421 327556',
#    'distance': 5723.181085796268},
#   {'id': 'IIMtF_7RpIGBBPN9qN0CRA',
#    'alias': 'daquise-london-2',
#    'name': 'Daquise',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EBYm0vNE2edUR1BUXvi9zQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daquise-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 76,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4943231, 'longitude': -0.1736183},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '20 Thurloe Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 2LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Thurloe Street',
#      'London SW7 2LT',
#      'United Kingdom']},
#    'phone': '+442075896117',
#    'display_phone': '+44 20 7589 6117',
#    'distance': 3302.7034521636515},
#   {'id': 'fdwAAs9cm_uLkgxXedYh3w',
#    'alias': 'baltic-bar-and-restaurant-london',
#    'name': 'Baltic Bar and Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Th3235Hk9AlSXVsMlC9XSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baltic-bar-and-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.503466, 'longitude': -0.104866},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '74 Blackfriars Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['74 Blackfriars Road',
#      'London SE1 8HA',
#      'United Kingdom']},
#    'phone': '+442079281111',
#    'display_phone': '+44 20 7928 1111',
#    'distance': 2390.6260048944155},
#   {'id': 'YEmBywnYiaA78eih0K1LCw',
#    'alias': 'autograf-london',
#    'name': 'Autograf',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tuzF74veYHLvt_zOn9lgQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/autograf-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5877471, 'longitude': -0.0991417},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '488 West Green Road',
#     'address2': 'Tottenham',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N15 3DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['488 West Green Road',
#      'Tottenham',
#      'London N15 3DA',
#      'United Kingdom']},
#    'phone': '+442088892999',
#    'display_phone': '+44 20 8889 2999',
#    'distance': 8710.03097592059},
#   {'id': 'vJqzSbmNvK9TpJq_D1m73g',
#    'alias': 'topolski-london-2',
#    'name': 'Topolski',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cIUNluyrU_9dKtCjlde8fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/topolski-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5049009709524,
#     'longitude': -0.11573825037897},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '150-152 Hungerford Arches',
#     'address2': 'Concert Hall',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8XU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['150-152 Hungerford Arches',
#      'Concert Hall',
#      'London SE1 8XU',
#      'United Kingdom']},
#    'phone': '+442076200627',
#    'display_phone': '+44 20 7620 0627',
#    'distance': 1654.136112235537},
#   {'id': 'CGcK4c86Mwu1dpTCHoUSFg',
#    'alias': 'pierogi-co-mitcham',
#    'name': 'Pierogi Co',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/toxijehP_TnUyQnaVyGWXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pierogi-co-mitcham?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.416354, 'longitude': -0.167952},
#    'transactions': [],
#    'location': {'address1': 'Taylor Road',
#     'address2': 'Positive Network Centre',
#     'address3': '',
#     'city': 'Mitcham',
#     'zip_code': 'CR4 3JR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Taylor Road',
#      'Positive Network Centre',
#      'Mitcham CR4 3JR',
#      'United Kingdom']},
#    'phone': '+442079981005',
#    'display_phone': '+44 20 7998 1005',
#    'distance': 10954.821750423285},
#   {'id': '6pjFbloUrfJEaZuJaOkiiA',
#    'alias': 'cafe-wanda-london-3',
#    'name': 'Cafe Wanda',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UuSIHHslZwFdNLA9Cqt22Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-wanda-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.462169, 'longitude': -0.13634},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '153 Clapham High Street',
#     'address2': 'Clapham',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW4 7SS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['153 Clapham High Street',
#      'Clapham',
#      'London SW4 7SS',
#      'United Kingdom']},
#    'phone': '+442077388760',
#    'display_phone': '+44 20 7738 8760',
#    'distance': 5624.099026452727},
#   {'id': 'h6FfK4Wewq3-H023vTIcag',
#    'alias': 'zorya-shisha-london',
#    'name': 'Zorya Shisha',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NpOegp99yN_tPJEO_OXHNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zorya-shisha-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5429849, 'longitude': -0.1486984},
#    'transactions': [],
#    'location': {'address1': '48 Chalk Farm Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['48 Chalk Farm Rd',
#      'London NW1 8AJ',
#      'United Kingdom']},
#    'phone': '+442074248550',
#    'display_phone': '+44 20 7424 8550',
#    'distance': 3473.907343579959},
#   {'id': 'a8FtrgeFoHZ3N8KPVK2lGQ',
#    'alias': 'bob-bob-ricard-soho',
#    'name': 'Bob Bob Ricard',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1LnW9-0h7nLQupMlkAhetw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bob-bob-ricard-soho?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 157,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5123099662701,
#     'longitude': -0.137234320867947},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '1 Upper James Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Soho',
#     'zip_code': 'W1F 9DF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Upper James Street',
#      'Soho W1F 9DF',
#      'United Kingdom']},
#    'phone': '+442031451000',
#    'display_phone': '+44 20 3145 1000',
#    'distance': 106.03236951148304},
#   {'id': 'ldduTLJGykX1jtid-GoI7g',
#    'alias': 'ognisko-london',
#    'name': 'Ognisko',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T8qa93hILOKAw4-8hYKx7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ognisko-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4990393817465,
#     'longitude': -0.174058199926435},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '55 Princes Gate',
#     'address2': 'Exhibition Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 2PG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55 Princes Gate',
#      'Exhibition Road',
#      'London SW7 2PG',
#      'United Kingdom']},
#    'phone': '+442075890101',
#    'display_phone': '+44 20 7589 0101',
#    'distance': 3050.8575697725305},
#   {'id': 'zJNI06Y2zZQFh9OBSFCdgQ',
#    'alias': 'sketch-london-2',
#    'name': 'Sketch',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pAEJmqSJX1lh_pLuvjbFww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sketch-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 831,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5127614699071,
#     'longitude': -0.14159163911048},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '9 Conduit Street',
#     'address2': 'Mayfair',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 2XG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Conduit Street',
#      'Mayfair',
#      'London W1S 2XG',
#      'United Kingdom']},
#    'phone': '+442076594500',
#    'display_phone': '+44 20 7659 4500',
#    'distance': 390.09161644125044},
#   {'id': 'C_R6SlaMeZcMOo4VNo9CpQ',
#    'alias': 'l-autre-restaurant-london',
#    'name': "L'Autre Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/a7_x66LX-AAjw_nJOxouWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-autre-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.50606, 'longitude': -0.146524},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5B Shepherd Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 7HP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5B Shepherd Street',
#      'London W1J 7HP',
#      'United Kingdom']},
#    'phone': '+442074994680',
#    'display_phone': '+44 20 7499 4680',
#    'distance': 1040.6827613628982},
#   {'id': 'J399Q96eASKdXbAmSlHwTg',
#    'alias': 'kredens-polish-bar-and-restaurant-london',
#    'name': 'Kredens Polish Bar & Restaurant',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kredens-polish-bar-and-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.461426273365,
#     'longitude': -0.111316703259945},
#    'transactions': [],
#    'location': {'address1': '63 Atlantic Road',
#     'address2': '',
#     'address3': 'Brixton',
#     'city': 'London',
#     'zip_code': 'SW9 8PU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63 Atlantic Road',
#      'Brixton',
#      'London SW9 8PU',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5965.582096004114},
#   {'id': 'lvG81RiIwLURb38TUBMo6Q',
#    'alias': 'light-bite-london',
#    'name': 'Light Bite',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wBIC7jY2OVVOMij7gcDGfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/light-bite-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5820989, 'longitude': -0.0688994},
#    'transactions': [],
#    'location': {'address1': '31 Bernard Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N15 4NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['31 Bernard Road',
#      'London N15 4NE',
#      'United Kingdom']},
#    'phone': '+447973966966',
#    'display_phone': '+44 7973 966966',
#    'distance': 8989.818352189403},
#   {'id': 'Quhmsx-9Lz0Q3CoBiMshoA',
#    'alias': 'cafe-the-polish-canteen-london',
#    'name': 'Cafe The Polish Canteen',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-the-polish-canteen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.50037, 'longitude': -0.3062515},
#    'transactions': [],
#    'location': {'address1': 'Wickes Car Park',
#     'address2': '89 South Ealing Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W5 4QS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Wickes Car Park',
#      '89 South Ealing Road',
#      'London W5 4QS',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 11858.298285508281},
#   {'id': '75-HeBBB391Np6T7GdJ5xQ',
#    'alias': 'the-ivy-london',
#    'name': 'The Ivy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rVk4F439o22SXXzGGHKGRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ivy-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 171,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512814, 'longitude': -0.128013},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1 - 5 West Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9NQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 - 5 West Street',
#      'London WC2H 9NQ',
#      'United Kingdom']},
#    'phone': '+442078364751',
#    'display_phone': '+44 20 7836 4751',
#    'distance': 549.6549455465449},
#   {'id': 'sqqCpeU4AEkjwa_SGwTCRw',
#    'alias': 'the-fable-london',
#    'name': 'The Fable',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2xOrogCWBB9qjF7x64ajlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-fable-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.516865, 'longitude': -0.1037447},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '52 Holborn Viaduct',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1A 2FD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['52 Holborn Viaduct',
#      'London EC1A 2FD',
#      'United Kingdom']},
#    'phone': '+448450680105',
#    'display_phone': '+44 845 068 0105',
#    'distance': 2273.526930008717},
#   {'id': 'fdu-BnegfJrCfDMiQdjC3w',
#    'alias': 'the-knaypa-london',
#    'name': 'The Knaypa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/s_WCDb4svWxE5nvhtM-o8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-knaypa-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.493682, 'longitude': -0.239597},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Flat',
#     'address2': '268 King Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W6 0SP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Flat',
#      '268 King Street',
#      'London W6 0SP',
#      'United Kingdom']},
#    'phone': '+442085632887',
#    'display_phone': '+44 20 8563 2887',
#    'distance': 7490.6902491237515},
#   {'id': 'tlS84ZzQuHftC8fSjybECQ',
#    'alias': 'londek-cafe-london',
#    'name': 'Londek Cafe',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/londek-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5452987221191,
#     'longitude': 0.00439359082260513},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '196 The Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E15 1NS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['196 The Grove', 'London E15 1NS', 'United Kingdom']},
#    'phone': '+442082700063',
#    'display_phone': '+44 20 8270 0063',
#    'distance': 10358.17611113869},
#   {'id': 'Woxg5w-1Of4ID1C6LYRNag',
#    'alias': 'paleta-kitchen-hounslow',
#    'name': 'Paleta Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-fd9Ap5_nIik7aroJQ9qeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paleta-kitchen-hounslow?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4676351561211, 'longitude': -0.3865934},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '175 Martindale Road',
#     'address2': '',
#     'address3': None,
#     'city': 'Hounslow',
#     'zip_code': 'TW4 7EZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['175 Martindale Road',
#      'Hounslow TW4 7EZ',
#      'United Kingdom']},
#    'phone': '+447854715284',
#    'display_phone': '+44 7854 715284',
#    'distance': 18066.145101423535},
#   {'id': '4P-JlxSkcA--xPKJxDUOng',
#    'alias': 'polish-white-eagle-club-london',
#    'name': 'Polish White Eagle Club',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/K3NTfTp9R_Pe90nWZM_Hww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/polish-white-eagle-club-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.4397548910323,
#     'longitude': -0.155207219662862},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '211 Balham High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW17 7BQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['211 Balham High Road',
#      'London SW17 7BQ',
#      'United Kingdom']},
#    'phone': '+442086721723',
#    'display_phone': '+44 20 8672 1723',
#    'distance': 8234.837347694414},
#   {'id': '43THdJ2u8iVT8k5OdAvq4A',
#    'alias': 'pasibrzuch-polish-restaurant-and-cafe-london',
#    'name': 'Pasibrzuch Polish Restaurant and Cafe',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pasibrzuch-polish-restaurant-and-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 51.54763, 'longitude': -0.226584},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18-20 Wilsden High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW10 2QD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18-20 Wilsden High Road',
#      'London NW10 2QD',
#      'United Kingdom']},
#    'phone': '+442087297319',
#    'display_phone': '+44 20 8729 7319',
#    'distance': 7357.295957320781},
#   {'id': '8yHUhLCiNlX-1bpZBTO0wQ',
#    'alias': 'mis-bar-mleczny-london-2',
#    'name': 'Mis Bar Mleczny',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mis-bar-mleczny-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 51.4236129118999,
#     'longitude': -0.162079882025417},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '178 Mitcham Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW17 9NJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['178 Mitcham Road',
#      'London SW17 9NJ',
#      'United Kingdom']},
#    'phone': '+442086820263',
#    'display_phone': '+44 20 8682 0263',
#    'distance': 10084.771135108662},
#   {'id': '9P77lZQNRMtq9m2Y82dH7A',
#    'alias': 'the-spitfire-london',
#    'name': 'The Spitfire',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-spitfire-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4888805, 'longitude': -0.2227522},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '93 Fulham Palace Road',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W6 8JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['93 Fulham Palace Road',
#      'London W6 8JA',
#      'United Kingdom']},
#    'phone': '+442087487272',
#    'display_phone': '+44 20 8748 7272',
#    'distance': 6571.97224689054},
#   {'id': 'zJNuog1I1f6aJbMzwingqg',
#    'alias': 'gospoda-vita-london',
#    'name': 'Gospoda Vita',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gospoda-vita-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5113084, 'longitude': -0.3174954},
#    'transactions': [],
#    'location': {'address1': '146 Uxbridge Road',
#     'address2': 'West Ealing',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W13 8SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['146 Uxbridge Road',
#      'West Ealing',
#      'London W13 8SB',
#      'United Kingdom']},
#    'phone': '+442085791489',
#    'display_phone': '+44 20 8579 1489',
#    'distance': 12564.05715977165},
#   {'id': 'C2oJNq6iCz99exi5C5fQrg',
#    'alias': 'aqua-nueva-london-3',
#    'name': 'aqua nueva',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3505YxeVLg6Qu-WS2gl_fA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aqua-nueva-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5144175, 'longitude': -0.1406601},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '5th Floor 240 Regent Street',
#     'address2': 'Entrance 30 Argyll St',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 3BR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5th Floor 240 Regent Street',
#      'Entrance 30 Argyll St',
#      'London W1B 3BR',
#      'United Kingdom']},
#    'phone': '+442074780540',
#    'display_phone': '+44 20 7478 0540',
#    'distance': 370.02277506846934},
#   {'id': 'W527BOr-eQYQc8SluoJueA',
#    'alias': 'antonys-london',
#    'name': "Antony's",
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/antonys-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5182352, 'longitude': -0.1888339},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '54 Porchester Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 6ET',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54 Porchester Road',
#      'London W2 6ET',
#      'United Kingdom']},
#    'phone': '+442072438743',
#    'display_phone': '+44 20 7243 8743',
#    'distance': 3706.77887931426},
#   {'id': '-tocMG5z1cqHIc0nq_96eQ',
#    'alias': 'folvark-hounslow',
#    'name': 'Folvark',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/folvark-hounslow?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'polish', 'title': 'Polish'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4704739, 'longitude': -0.3672207},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '36 Lampton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Hounslow',
#     'zip_code': 'TW3 1JH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['36 Lampton Road',
#      'Hounslow TW3 1JH',
#      'United Kingdom']},
#    'phone': '+442085777760',
#    'display_phone': '+44 20 8577 7760',
#    'distance': 16689.677062358198},
#   {'id': 'QKxeBSnqUOBSOkzCQ3bQ6w',
#    'alias': 'cafe-maya-london-2',
#    'name': 'Cafe Maya',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/k5L_ZCHC1GJBgVh3UrgDKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-maya-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4933573, 'longitude': -0.2371255},
#    'transactions': [],
#    'location': {'address1': '238-246 King Street',
#     'address2': 'Hammersmith',
#     'address3': 'Hammersmith And Fulham',
#     'city': 'London',
#     'zip_code': 'W6',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['238-246 King Street',
#      'Hammersmith',
#      'Hammersmith And Fulham',
#      'London W6',
#      'United Kingdom']},
#    'phone': '+442085638550',
#    'display_phone': '+44 20 8563 8550',
#    'distance': 7337.990622814627},
#   {'id': 'TziEl_RR-t6tRUMOigk0tg',
#    'alias': 'the-golden-empire-gt-lon',
#    'name': 'The Golden Empire',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-golden-empire-gt-lon?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5311666218182,
#     'longitude': -0.292561839097021},
#    'transactions': [],
#    'location': {'address1': 'N Circular Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Gt Lon',
#     'zip_code': 'E17',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['N Circular Road', 'Gt Lon E17', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 11025.154652843845},
#   {'id': '-zh6KAMi7jHNV7m5iortDA',
#    'alias': 'café-grove-london-2',
#    'name': 'Café Grove',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-grove-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5109666, 'longitude': -0.3013244},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '65 The Grove',
#     'address2': 'Ealing',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W5 5LL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['65 The Grove',
#      'Ealing',
#      'London W5 5LL',
#      'United Kingdom']},
#    'phone': '+442088100364',
#    'display_phone': '+44 20 8810 0364',
#    'distance': 11445.77360673497},
#   {'id': 'acufU3MV5_e5lIlYRi-C0w',
#    'alias': 'the-centre-for-polish-arts-and-culture-london',
#    'name': 'The Centre for Polish Arts and Culture',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xCxXAkArGSzgv7XZY_DhGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-centre-for-polish-arts-and-culture-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'culturalcenter', 'title': 'Cultural Center'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4933971, 'longitude': -0.2381482},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '238-246 King Street',
#     'address2': 'Hammersmith',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W6 0RA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['238-246 King Street',
#      'Hammersmith',
#      'London W6 0RA',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 7396.190026316793}],
#  'total': 37,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                             Restaurant            Type Price Rating  \
# 0                            Pyrlandia  Farmers Market
# 1       Mamuska - Polish Kitchen & Bar          Polish
# 2                           Bar Polski          Polish    ££      4
# 3  Lowiczanka Polish Centre Restaurant          Polish    ££      5
# 4                      Sowa Restaurant          Polish
#
#                 Address        Lat       Lng  \
# 0  Rupert Street Market  51.512116 -0.133606
# 1    9 Addington Street  51.501304 -0.116066
# 2   11 Little Turnstile  51.517414 -0.119041
# 3   238-246 King Street  51.493357 -0.237125
# 4        33 High Street  51.512172 -0.305003
#
#                                                  url                      ID
# 0
# 1
# 2  https://www.yelp.com/biz/bar-polski-london?adj...  0SfwQrzLJ_vOEDEJ5Im_5g
# 3  https://www.yelp.com/biz/lowiczanka-polish-cen...  fDul4h-8jhWtVB4tDhV9QQ
# 4

# %%
#2nd set of 50 records 51-100 
lndr_params2 = {"term":"Polish","location":"London","limit":50,"offset":51}
lndr_response2 = requests.get(search_api_url, headers=headers, params=lndr_params2)
lndr2 = lndr_response2.json()
display(lndr2)
#print(lndr_response2.url)
#print(lndr_response2.status_code)
# Out:
# {'businesses': [],
#  'total': 37,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
# Empty DataFrame
# Columns: [Restaurant, Type, Price, Rating, Address, Lat, Lng, url, ID]
# Index: []

# %%
#3rd set of 50 records 101-150
lndr_params3 = {"term":"Polish","location":"London","limit":50,"offset":101}
lndr_response3 = requests.get(search_api_url, headers=headers, params=lndr_params3)
lndr3 = lndr_response3.json()
display(lndr3)
#print(lndr_response3.url)
#print(lndr_response3.status_code)
# Out:
# {'businesses': [],
#  'total': 37,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
# Empty DataFrame
# Columns: [Restaurant, Type, Price, Rating, Address, Lat, Lng, url, ID]
# Index: []

# %%
#4th set of 50 records 151-200
lndr_params4 = {"term":"Polish","location":"London","limit":50,"offset":151}
lndr_response4 = requests.get(search_api_url, headers=headers, params=lndr_params4)
lndr4 = lndr_response4.json()
display(lndr4)
#print(lndr_response4.url)
#print(lndr_response4.status_code)
# Out:
# {'businesses': [],
#  'total': 37,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
# Empty DataFrame
# Columns: [Restaurant, Type, Price, Rating, Address, Lat, Lng, url, ID]
# Index: []

# %%
london_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
london_restaurants_df.shape
# Out:
# (37, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_restaurants_df = london_restaurants_df[column_order]
london_restaurants_df = london_restaurants_df.sort_values(["Type"], ascending=True)
london_restaurants_df = london_restaurants_df.reset_index(drop=True)
london_restaurants_df
# Out:
#                