# %% [markdown]
# LONDON RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
lndr_params1 = {"term":"Italian","location":"London","limit":50,"offset":0}
lndr_response1 = requests.get(search_api_url, headers=headers, params=lndr_params1)
lndr1 = lndr_response1.json()
display(lndr1)
#print(lndr_response1.url)
#print(lndr_response1.status_code)
# Out:
# {'businesses': [{'id': 'KzYd2EaFvmu63wqTIektSA',
#    'alias': 'padella-london-3',
#    'name': 'Padella',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Z6ujE4hSjT6DrejptE9PQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/padella-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 211,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5051451, 'longitude': -0.0899515},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 Southwark Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1TQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Southwark Street',
#      'London SE1 1TQ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3297.287249700157},
#   {'id': '1bR581OwoAOLMLG9sS_tow',
#    'alias': 'circolo-popolare-london',
#    'name': 'Circolo Popolare',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fcMZ6vZgHsstTAupJ69ocg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/circolo-popolare-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5173110961914,
#     'longitude': -0.133615002036095},
#    'transactions': [],
#    'location': {'address1': '40-41 Rathbone Place',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1T 1HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40-41 Rathbone Place',
#      'London W1T 1HX',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 508.1354888154036},
#   {'id': 'ZfM-yM1OWk41l8RJNRMnvw',
#    'alias': 'da-mario-restaurant-london',
#    'name': 'Da Mario Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GgmhWL3ae9RuS9ChDOmcIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-mario-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 140,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4987228161749,
#     'longitude': -0.183567237647306},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '15 Gloucester Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 4PP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Gloucester Road',
#      'London SW7 4PP',
#      'United Kingdom']},
#    'phone': '+442075849078',
#    'display_phone': '+44 20 7584 9078',
#    'distance': 3649.840780107747},
#   {'id': 'eRsWcoSBWYkfhfXoHxnIEg',
#    'alias': 'bocca-di-lupo-london',
#    'name': 'Bocca Di Lupo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hFJdlRuh6cw5DxSGh6TqFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bocca-di-lupo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 166,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5116836912991,
#     'longitude': -0.133953506589517},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '12 Archer Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 7BB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Archer Street',
#      'London W1D 7BB',
#      'United Kingdom']},
#    'phone': '+442077342223',
#    'display_phone': '+44 20 7734 2223',
#    'distance': 188.68901579545133},
#   {'id': 'jcWobjpfGS5AaJuh13UbUw',
#    'alias': 'il-portico-london',
#    'name': 'Il Portico',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_ZqoDWADKy3AwvfBrrn4dA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-portico-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4985799, 'longitude': -0.2000019},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '277 Kensington High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 6NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['277 Kensington High Street',
#      'London W8 6NA',
#      'United Kingdom']},
#    'phone': '+442076026262',
#    'display_phone': '+44 20 7602 6262',
#    'distance': 4703.757817126668},
#   {'id': 'oxCMByNo12dgtYWzHretMg',
#    'alias': 'la-rocchetta-london',
#    'name': 'La Rocchetta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Jth2EaMdBYlvJOR9pVRrcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-rocchetta-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5229682922363,
#     'longitude': -0.105994999408722},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '40 Clerkenwell Green',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 0DU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 Clerkenwell Green',
#      'London EC1R 0DU',
#      'United Kingdom']},
#    'phone': '+442072538676',
#    'display_phone': '+44 20 7253 8676',
#    'distance': 2359.48246285179},
#   {'id': 'RRBZpT_Ljv-Mol53nAjvGg',
#    'alias': 'piccolino-london-2',
#    'name': 'Piccolino',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VKED7Ch68XN_hZeMMXl1Yw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piccolino-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.510953, 'longitude': -0.139739},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '21 Heddon Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 4BG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21 Heddon Street',
#      'London W1B 4BG',
#      'United Kingdom']},
#    'phone': '+442072874029',
#    'display_phone': '+44 20 7287 4029',
#    'distance': 329.056979623144},
#   {'id': 'Gqs6N5V7PcIF_DbTceEFiQ',
#    'alias': 'cecconis-mayfair-london-2',
#    'name': "Cecconi's Mayfair",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KqJA_5YZv4VoTcDSCG1Wiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cecconis-mayfair-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 96,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51004817, 'longitude': -0.14055809},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '5A Burlington Gardens',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 3EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5A Burlington Gardens',
#      'London W1S 3EP',
#      'United Kingdom']},
#    'phone': '+442074341500',
#    'display_phone': '+44 20 7434 1500',
#    'distance': 444.40866950399754},
#   {'id': 'B3G1IoAyqTKWBMNUiB2SLA',
#    'alias': 'morso-restaurant-london',
#    'name': 'Morso Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DoaJfv63NvwxCXtKJu5DNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/morso-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5370894, 'longitude': -0.1858321},
#    'transactions': [],
#    'location': {'address1': '130 Boundary Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 0RH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['130 Boundary Road',
#      'London NW8 0RH',
#      'United Kingdom']},
#    'phone': '+442076247412',
#    'display_phone': '+44 20 7624 7412',
#    'distance': 4375.5197725399},
#   {'id': 'ofk57INQHCumktjqs0EjhQ',
#    'alias': 'san-carlo-cicchetti-london-2',
#    'name': 'San Carlo Cicchetti',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8blt2grhJcB35GAyYuJWvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/san-carlo-cicchetti-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 120,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5095021385658,
#     'longitude': -0.135087305946757},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '215 Piccadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 9HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['215 Piccadilly', 'London W1J 9HL', 'United Kingdom']},
#    'phone': '+442074949435',
#    'display_phone': '+44 20 7494 9435',
#    'distance': 375.49624382101644},
#   {'id': 'nUAkhKSEKG3NZl4vinNMjQ',
#    'alias': 'il-bordello-london',
#    'name': 'Il Bordello',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kMlAYUVXLZvbu4o5-FDvrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-bordello-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5065452882856,
#     'longitude': -0.0527607017206719},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit G01 Metropolitan Wharf',
#     'address2': '70 Wapping Wall',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E1W 3SS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit G01 Metropolitan Wharf',
#      '70 Wapping Wall',
#      'London E1W 3SS',
#      'United Kingdom']},
#    'phone': '+442074819950',
#    'display_phone': '+44 20 7481 9950',
#    'distance': 5799.9023617318035},
#   {'id': 'natxYvht_q9dVUpVCtJlYw',
#    'alias': 'giovannis-of-covent-garden-london',
#    'name': "Giovanni's of Covent Garden",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8InP1Oxrmk4HK9P1G-Ptsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giovannis-of-covent-garden-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5109872, 'longitude': -0.1261001},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '10 Goodwins Court',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4LL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Goodwins Court',
#      'London WC2N 4LL',
#      'United Kingdom']},
#    'phone': '+442072403303',
#    'display_phone': '+44 20 7240 3303',
#    'distance': 711.4416983772318},
#   {'id': 'dbgwLM4DAgIa26fVA9xMZg',
#    'alias': 'anacapri-restaurant-london',
#    'name': 'Anacapri Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9Ysg-oM-CpZFPRBLMuQgQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anacapri-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.519641656007, 'longitude': -0.1558836672686},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '10 Dorset Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 6QR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Dorset Street',
#      'London W1U 6QR',
#      'United Kingdom']},
#    'phone': '+442079356441',
#    'display_phone': '+44 20 7935 6441',
#    'distance': 1572.9538640242754},
#   {'id': 'FXSGVcfBDYytOHHyLsoCCg',
#    'alias': 'albertini-restaurant-london',
#    'name': 'Albertini Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ifwjbx18T7ZmecmJN2rLIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/albertini-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 52,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5290298461914,
#     'longitude': -0.129214003682137},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '16-20 Chalton Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 1JH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16-20 Chalton Street',
#      'London NW1 1JH',
#      'United Kingdom']},
#    'phone': '+442073874723',
#    'display_phone': '+44 20 7387 4723',
#    'distance': 1844.1187278999082},
#   {'id': 'T6HqvhytfyhMBVooUgl9rg',
#    'alias': 'franco-manca-london',
#    'name': 'Franco Manca',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Oj3RI_R7vs1cKW4sTQ6YWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/franco-manca-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 169,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4617348041813,
#     'longitude': -0.11336088180542},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '4 Market Row',
#     'address2': 'Electric Lane',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 8LD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Market Row',
#      'Electric Lane',
#      'London SW9 8LD',
#      'United Kingdom']},
#    'phone': '+442077383021',
#    'display_phone': '+44 20 7738 3021',
#    'distance': 5893.572953642648},
#   {'id': 'NoJ_9VDZ4GyTGywmsvkH9A',
#    'alias': 'canto-corvino-london',
#    'name': 'Canto Corvino',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eDvD6NETBQUR1S1jJJR1Gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/canto-corvino-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5184731521465,
#     'longitude': -0.0783929228782654},
#    'transactions': [],
#    'location': {'address1': '21 Artillery Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 7HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21 Artillery Lane',
#      'London E1 7HA',
#      'United Kingdom']},
#    'phone': '+442076550390',
#    'display_phone': '+44 20 7655 0390',
#    'distance': 4032.1843577028762},
#   {'id': 'MMQdqF-q-d__b1Z8_4Hs2Q',
#    'alias': 'astoria-london',
#    'name': 'Astoria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YdfWUKJqfciWrZS-_II4cg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/astoria-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.511549, 'longitude': -0.13251},
#    'transactions': [],
#    'location': {'address1': '45 Wardour Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6PZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Wardour Street',
#      'London W1D 6PZ',
#      'United Kingdom']},
#    'phone': '+442074376523',
#    'display_phone': '+44 20 7437 6523',
#    'distance': 279.3894500795922},
#   {'id': 'nKdgPrFZgxFciMOPNdmfaA',
#    'alias': 'conchiglia-london',
#    'name': 'Conchiglia',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/y43Qk8mNNSZd6-yB6d3iiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/conchiglia-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5207595, 'longitude': -0.1417802},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '125 Great Titchfield St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 6RZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['125 Great Titchfield St',
#      'London W1W 6RZ',
#      'United Kingdom']},
#    'phone': '+442076361995',
#    'display_phone': '+44 20 7636 1995',
#    'distance': 986.5907480423153},
#   {'id': 'I0CdzZuM1lNe6YENxl1hLQ',
#    'alias': 'domo-94-london',
#    'name': 'Domo 94',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RiPc715rlpTAsyc-yCh-OQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/domo-94-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5412931, 'longitude': -0.1385957},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '94 Camden Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 9EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['94 Camden Road', 'London NW1 9EA', 'United Kingdom']},
#    'phone': '+442074824366',
#    'display_phone': '+44 20 7482 4366',
#    'distance': 3169.600503668651},
#   {'id': 'cxRk4T-Z3q_mekEWj6l2Dw',
#    'alias': 'mamma-mia-london-9',
#    'name': 'Mamma Mia ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/s7Nc0VR_mBNGamMKyuGB1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mamma-mia-london-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5115510342144,
#     'longitude': -0.187024012207985},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '36 Queensway',
#     'address2': '',
#     'address3': 'Bayswater',
#     'city': 'London',
#     'zip_code': 'W2 3RX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['36 Queensway',
#      'Bayswater',
#      'London W2 3RX',
#      'United Kingdom']},
#    'phone': '+442072438992',
#    'display_phone': '+44 20 7243 8992',
#    'distance': 3536.9001095278263},
#   {'id': 'N061zlyo0MTNDQiG96hUHQ',
#    'alias': 'il-giardino-restaurant-london',
#    'name': 'Il Giardino Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fGaV7pdIrPca2yE8V0-n4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-giardino-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.488548, 'longitude': -0.169777},
#    'transactions': [],
#    'location': {'address1': '119 Sydney St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 6NR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['119 Sydney St', 'London SW3 6NR', 'United Kingdom']},
#    'phone': '+442073522718',
#    'display_phone': '+44 20 7352 2718',
#    'distance': 3571.3705712870756},
#   {'id': 'EKM6VmUANUVy5wqXT7gEXQ',
#    'alias': 'bon-gusto-london',
#    'name': 'Bon Gusto',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9vVpPXCeNEEK2r6ri3rfBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bon-gusto-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 88,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4992042, 'longitude': -0.1378462},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '75-77 Buckingham Gate',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1E 6PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['75-77 Buckingham Gate',
#      'London SW1E 6PD',
#      'United Kingdom']},
#    'phone': '+442072227185',
#    'display_phone': '+44 20 7222 7185',
#    'distance': 1521.3684126347684},
#   {'id': '-ATEXu2q4Oe4wPQeyrsILw',
#    'alias': 'princi-london',
#    'name': 'Princi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QLFgoDIBiLx2F0tpUIw7gQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/princi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 304,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5138629586873,
#     'longitude': -0.134387051472991},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '135 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0UT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['135 Wardour Street',
#      'London W1F 0UT',
#      'United Kingdom']},
#    'phone': '+442074788888',
#    'display_phone': '+44 20 7478 8888',
#    'distance': 157.59755401297926},
#   {'id': 'E7uTFoTXygHYo_KAaHRjpw',
#    'alias': 'oliveto-london',
#    'name': 'Oliveto',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/s8PlF6v38HiJ7jJXiXOF3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oliveto-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.493495, 'longitude': -0.150923},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '49 Elizabeth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 9PP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Elizabeth Street',
#      'London SW1W 9PP',
#      'United Kingdom']},
#    'phone': '+442077300074',
#    'display_phone': '+44 20 7730 0074',
#    'distance': 2387.8696912342853},
#   {'id': 'Uc7upMXqlizTDoqbmyoMxg',
#    'alias': 'la-tua-pasta-london-6',
#    'name': 'La Tua Pasta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vdYvRyJhonOVgk_YViZcxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-tua-pasta-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'food', 'title': 'Food'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5050824, 'longitude': -0.0900808},
#    'transactions': [],
#    'location': {'address1': 'Borough Market',
#     'address2': 'Borough High Street',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 1TL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Borough Market',
#      'Borough High Street',
#      'London SE1 1TL',
#      'United Kingdom']},
#    'phone': '+442089618024',
#    'display_phone': '+44 20 8961 8024',
#    'distance': 3289.8292155823306},
#   {'id': 'OiRMxtQCo0MdfZkejv2xUg',
#    'alias': 'polpetto-london-2',
#    'name': 'Polpetto',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9TwLb2vvMtaCJzleKxnU5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/polpetto-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.513356, 'longitude': -0.134634},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Berwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0PL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Berwick Street',
#      'London W1F 0PL',
#      'United Kingdom']},
#    'phone': '+442074398627',
#    'display_phone': '+44 20 7439 8627',
#    'distance': 108.24146336197532},
#   {'id': 'Z4OljJ0T71xATMvYMXkgiQ',
#    'alias': 'cassio-restaurant-and-pizzeria-london',
#    'name': 'Cassio Restaurant and Pizzeria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pzb0t0f8MWmXQiesX77qZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cassio-restaurant-and-pizzeria-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4350586, 'longitude': -0.1575961},
#    'transactions': [],
#    'location': {'address1': '32 Tooting Bec Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW17 8BD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['32 Tooting Bec Road',
#      'London SW17 8BD',
#      'United Kingdom']},
#    'phone': '+442087679395',
#    'display_phone': '+44 20 8767 9395',
#    'distance': 8770.256154024562},
#   {'id': 'wK1jADUhsD0102bIlp-PaA',
#    'alias': 'pesantissimo-london',
#    'name': 'Pesantissimo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WOtdloIeUUNAyu7I4FUm0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pesantissimo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5408413853259,
#     'longitude': -0.157658620866755},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '57 Regents Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8XD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57 Regents Park Road',
#      'London NW1 8XD',
#      'United Kingdom']},
#    'phone': '+442074838733',
#    'display_phone': '+44 20 7483 8733',
#    'distance': 3457.143033930679},
#   {'id': 'hfmhrnn-ZxQlhI7tTMCWAg',
#    'alias': 'brizzis-london',
#    'name': "Brizzi's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EWdNW_JhPVrOHIR5cVe0ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brizzis-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.527082, 'longitude': -0.136661},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '131 Drummond Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 2HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['131 Drummond Street',
#      'London NW1 2HL',
#      'United Kingdom']},
#    'phone': '+442073800857',
#    'display_phone': '+44 20 7380 0857',
#    'distance': 1578.1096625813698},
#   {'id': '-147sXWJVzjQ6xed3kdtxQ',
#    'alias': 'la-porchetta-pollo-bar-london',
#    'name': 'La Porchetta Pollo Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7dR3wrkUu2n3IY-GXYNadg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-porchetta-pollo-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5136346213443,
#     'longitude': -0.130298037090699},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '20 Old Compton Street',
#     'address2': '',
#     'address3': 'Soho',
#     'city': 'London',
#     'zip_code': 'W1D 4TW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Old Compton Street',
#      'Soho',
#      'London W1D 4TW',
#      'United Kingdom']},
#    'phone': '+442074949368',
#    'display_phone': '+44 20 7494 9368',
#    'distance': 401.4759210697374},
#   {'id': '99Q0vNBvnM5Rnw1atnr2xA',
#    'alias': 'osteria-basilico-london',
#    'name': 'Osteria Basilico',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4GbVaxV4AxqJykqU3mVGDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osteria-basilico-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515359633283, 'longitude': -0.2058905197699},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '29 Kensington Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['29 Kensington Park Road',
#      'London W11 2EU',
#      'United Kingdom']},
#    'phone': '+442077279957',
#    'display_phone': '+44 20 7727 9957',
#    'distance': 4847.542307422941},
#   {'id': 'PsqVVwSoKcyPkq747CQ8yg',
#    'alias': 'misto-london-2',
#    'name': 'Misto',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/79zbePZnNPRv84r1uA1wfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/misto-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5063972, 'longitude': -0.1465176},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '7 Shepherd Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 7PE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Shepherd Market',
#      'London W1J 7PE',
#      'United Kingdom']},
#    'phone': '+442076293317',
#    'display_phone': '+44 20 7629 3317',
#    'distance': 1052.8569949037374},
#   {'id': 'bcazIJMmqKyjsylS4FEngQ',
#    'alias': 'vapiano-no-title',
#    'name': 'Vapiano',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RisaPH3GdKsswjgBdreglA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vapiano-no-title?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cafeteria', 'title': 'Cafeteria'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5056058011705,
#     'longitude': -0.0975875964032075},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '90 B Southwark street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0FD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['90 B Southwark street',
#      'London SE1 0FD',
#      'United Kingdom']},
#    'phone': '+442075932010',
#    'display_phone': '+44 20 7593 2010',
#    'distance': 2774.3504002877035},
#   {'id': 'zDjiF9j6dWiWxhJqstqKOg',
#    'alias': 'alla-salute-trattoria-pizzeria-social-london',
#    'name': 'Alla Salute! Trattoria Pizzeria Social',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/akQom-oQdzubWQHr4Jm4xA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alla-salute-trattoria-pizzeria-social-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4729053641485,
#     'longitude': -0.0215501981475654},
#    'transactions': [],
#    'location': {'address1': 'Unit 2 Indiana Building',
#     'address2': '1 Deals Gateway',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE13 7SE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 2 Indiana Building',
#      '1 Deals Gateway',
#      'London SE13 7SE',
#      'United Kingdom']},
#    'phone': '+442086919516',
#    'display_phone': '+44 20 8691 9516',
#    'distance': 9080.042725749156},
#   {'id': 'gmOauwdLtEInyMeb_q9eeg',
#    'alias': 'villa-rosa-restaurant-london',
#    'name': 'Villa Rosa Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wcr7WdNQ4-EPHccwvEyn3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/villa-rosa-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5148623, 'longitude': -0.1766336},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9 Craven Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3BP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Craven Road', 'London W2 3BP', 'United Kingdom']},
#    'phone': '+442074022995',
#    'display_phone': '+44 20 7402 2995',
#    'distance': 2813.174306693585},
#   {'id': 'X6-yef_wmPo-w_QMmYP5ag',
#    'alias': 'the-gold-of-naples-londra',
#    'name': 'The Gold of Naples',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BypbXhiJi1ZHPkl3zwVKvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-gold-of-naples-londra?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafeteria', 'title': 'Cafeteria'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4532861794787,
#     'longitude': -0.00787020519954051},
#    'transactions': [],
#    'location': {'address1': '134 Hither Green Lane',
#     'address2': '',
#     'address3': None,
#     'city': 'Londra',
#     'zip_code': 'SE13 6QA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['134 Hither Green Lane',
#      'Londra SE13 6QA',
#      'United Kingdom']},
#    'phone': '+447455001218',
#    'display_phone': '+44 7455 001218',
#    'distance': 11068.515207824981},
#   {'id': 'lrkhrEmcffCWIBLsqU0nRw',
#    'alias': 'bizzarro-london',
#    'name': 'Bizzarro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KO1LnuEZTe8ZfgAetqCuyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bizzarro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 150,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514853, 'longitude': -0.1772311},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18-22 Craven Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18-22 Craven Road',
#      'London W2 3PX',
#      'United Kingdom']},
#    'phone': '+442077236029',
#    'display_phone': '+44 20 7723 6029',
#    'distance': 2857.153283484032},
#   {'id': 'WXKXQ4Vnkfv5Yfw2jbnFjg',
#    'alias': 'caldesi-london-2',
#    'name': 'Caldesi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3bAjBZk8MZvBaUl_Pb37_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caldesi-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5182114, 'longitude': -0.15081},
#    'transactions': [],
#    'location': {'address1': '118 Marylebone Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 2NF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['118 Marylebone Lane',
#      'London W1U 2NF',
#      'United Kingdom']},
#    'phone': '+442079359227',
#    'display_phone': '+44 20 7935 9227',
#    'distance': 1189.0459051143018},
#   {'id': '5h1YHYWjrCuq69mbbjgvMw',
#    'alias': 'emilias-crafted-pasta-london-2',
#    'name': "Emilia's Crafted Pasta",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WCZf0eFisKX-OaJIpjXd_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/emilias-crafted-pasta-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5072531, 'longitude': -0.0716082},
#    'transactions': [],
#    'location': {'address1': 'Unit C3 Ivory House',
#     'address2': 'St Katharine Docks',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1W 1AT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit C3 Ivory House',
#      'St Katharine Docks',
#      'London E1W 1AT',
#      'United Kingdom']},
#    'phone': '+442074812004',
#    'display_phone': '+44 20 7481 2004',
#    'distance': 4496.23953893699},
#   {'id': 'mnLM9jFngaaL8EdH0qHnWw',
#    'alias': 'orsini-london',
#    'name': 'Orsini',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FpcnzKFZx3Zaw4u5rTpoFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/orsini-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 66,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.496176, 'longitude': -0.169932},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8A Thurloe Place',
#     'address2': 'South Kensington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 2RX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8A Thurloe Place',
#      'South Kensington',
#      'London SW7 2RX',
#      'United Kingdom']},
#    'phone': '+442075815553',
#    'display_phone': '+44 20 7581 5553',
#    'distance': 2996.4733331679718},
#   {'id': 'xlqv2nIEOukr7uV5OuAYYw',
#    'alias': 'capriccio-restaurant-london',
#    'name': 'Capriccio Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/i8p26vn0nmBwRfPveZLY_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/capriccio-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.583002, 'longitude': -0.199846},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '20 Temple Fortune Parade',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW11 0QS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Temple Fortune Parade',
#      'London NW11 0QS',
#      'United Kingdom']},
#    'phone': '+442084554432',
#    'display_phone': '+44 20 8455 4432',
#    'distance': 8923.619579317472},
#   {'id': 'fADN0KuYkKuXsXm1XQQx6w',
#    'alias': 'la-vita-e-bella-london',
#    'name': 'La Vita E Bella',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UBCkmGYr7Iu4LXzVZ4eGoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-vita-e-bella-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5375644, 'longitude': -0.103468},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '16 Theberton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 0QX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Theberton Street',
#      'London N1 0QX',
#      'United Kingdom']},
#    'phone': '+442073597984',
#    'display_phone': '+44 20 7359 7984',
#    'distance': 3551.4180170833292},
#   {'id': '8O9OVXHScu7lXQNO7q8sBg',
#    'alias': 'scarpetta-london',
#    'name': 'Scarpetta',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CIUnHbhujug-AGgoTpuhWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scarpetta-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5109736667965,
#     'longitude': -0.0879026067459563},
#    'transactions': [],
#    'location': {'address1': '110 Cannon Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4N 6EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['110 Cannon Street',
#      'London EC4N 6EU',
#      'United Kingdom']},
#    'phone': '+442079296901',
#    'display_phone': '+44 20 7929 6901',
#    'distance': 3331.8308944828423},
#   {'id': '3yo4_D0J7lWRfX_kl_F3IA',
#    'alias': 'stuzzico-london',
#    'name': 'Stuzzico',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Gy8SXueE_2Rclf5QftI9ag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stuzzico-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5146428, 'longitude': -0.1665175},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '24 Kendal Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 2AW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Kendal Street',
#      'London W2 2AW',
#      'United Kingdom']},
#    'phone': '+442072629122',
#    'display_phone': '+44 20 7262 9122',
#    'distance': 2124.380790491326},
#   {'id': 'KRS7yBZBFT80iA86ahtQ-g',
#    'alias': 'santore-london',
#    'name': 'Santore',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/u2jAwxLGG_v0oFedWNxouA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/santore-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5262783740002,
#     'longitude': -0.108517492582082},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '59-61 Exmouth Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 4QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['59-61 Exmouth Market',
#      'London EC1R 4QL',
#      'United Kingdom']},
#    'phone': '+442078121488',
#    'display_phone': '+44 20 7812 1488',
#    'distance': 2416.312163723102},
#   {'id': 'RU96clkbYyObbxCX27smKA',
#    'alias': 'teca-del-duca-london',
#    'name': 'Teca del Duca',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DMvox72Frj4YoDiwtcG9Ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/teca-del-duca-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5150206, 'longitude': -0.1940216},
#    'transactions': [],
#    'location': {'address1': '115 Westbourne Grove',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 4UP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['115 Westbourne Grove',
#      'London W2 4UP',
#      'United Kingdom']},
#    'phone': '+442077275000',
#    'display_phone': '+44 20 7727 5000',
#    'distance': 4034.737928121747},
#   {'id': '5r2Gi_vRprwHTiBLpwNz1w',
#    'alias': 'casa-becci-restaurant-london',
#    'name': 'Casa Becci Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nqukK-LHifay3REuxOSg9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-becci-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5205076849027,
#     'longitude': -0.156044418217071},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '32 Paddington Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 4HE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['32 Paddington Street',
#      'London W1U 4HE',
#      'United Kingdom']},
#    'phone': '+442079357031',
#    'display_phone': '+44 20 7935 7031',
#    'distance': 1630.9439736592458},
#   {'id': 'Xty2MtDQTnd2grIlrIST1w',
#    'alias': 'scalini-restaurant-london',
#    'name': 'Scalini Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hkrUiffjKA-CgHoGo30GrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scalini-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4958648681641,
#     'longitude': -0.164902999997139},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1-3 Walton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 2JD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1-3 Walton Street',
#      'London SW3 2JD',
#      'United Kingdom']},
#    'phone': '+442072252301',
#    'display_phone': '+44 20 7225 2301',
#    'distance': 2742.367296468606},
#   {'id': 'rLZFBf47RG75DYy02p57DA',
#    'alias': 'trattoria-da-luigi-london',
#    'name': 'Trattoria Da Luigi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pujUMXXQHE9vhXQrZunoPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trattoria-da-luigi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.562435, 'longitude': -0.078356},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 98-100',
#     'address2': 'Stoke Newington Church Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 0AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 98-100',
#      'Stoke Newington Church Street',
#      'London N16 0AP',
#      'United Kingdom']},
#    'phone': '+442072496553',
#    'display_phone': '+44 20 7249 6553',
#    'distance': 6803.104260939589},
#   {'id': '5iTca54jLb1EOmQHWU-Lhg',
#    'alias': 'bernardis-restaurant-and-bar-london',
#    'name': "Bernardi's Restaurant and Bar",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UVFJ19RWj6uJ08VW73b6XA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bernardis-restaurant-and-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.514406, 'longitude': -0.161159},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '62 Seymour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 5BN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['62 Seymour Street',
#      'London W1H 5BN',
#      'United Kingdom']},
#    'phone': '+442038267940',
#    'display_phone': '+44 20 3826 7940',
#    'distance': 1752.7740725784627}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#             Restaurant     Type Price Rating                     Address  \
# 0              Padella  Italian    ££    4.5          6 Southwark Street
# 1     Circolo Popolare  Italian                     40-41 Rathbone Place
# 2  Da Mario Restaurant  Italian    ££    4.5          15 Gloucester Road
# 3        Bocca Di Lupo  Italian   £££      4            12 Archer Street
# 4           Il Portico  Italian   £££      5  277 Kensington High Street
#
#          Lat       Lng                                                url  \
# 0  51.505145 -0.089952  https://www.yelp.com/biz/padella-london-3?adju...
# 1  51.517311 -0.133615
# 2  51.498723 -0.183567  https://www.yelp.com/biz/da-mario-restaurant-l...
# 3  51.511684 -0.133954  https://www.yelp.com/biz/bocca-di-lupo-london?...
# 4  51.498580 -0.200002  https://www.yelp.com/biz/il-portico-london?adj...
#
#                        ID
# 0  KzYd2EaFvmu63wqTIektSA
# 1
# 2  ZfM-yM1OWk41l8RJNRMnvw
# 3  eRsWcoSBWYkfhfXoHxnIEg
# 4  jcWobjpfGS5AaJuh13UbUw

# %%
#2nd set of 50 records 51-100 
lndr_params2 = {"term":"Italian","location":"London","limit":50,"offset":51}
lndr_response2 = requests.get(search_api_url, headers=headers, params=lndr_params2)
lndr2 = lndr_response2.json()
display(lndr2)
#print(lndr_response2.url)
#print(lndr_response2.status_code)
# Out:
# {'businesses': [{'id': 'TIfha7KOWgLRhN8935g6Iw',
#    'alias': 'la-pappardella-london',
#    'name': 'La Pappardella',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/oiAA4WSdjuZLQRZsUcUQkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-pappardella-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 79,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.489143, 'longitude': -0.190697},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '253 Old Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 9HP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['253 Old Brompton Road',
#      'London SW5 9HP',
#      'United Kingdom']},
#    'phone': '+442073737777',
#    'display_phone': '+44 20 7373 7777',
#    'distance': 4632.497746602916},
#   {'id': 'ZUGNQVHJy8FXxF5dsv2JFg',
#    'alias': 'cacio-and-pepe-london',
#    'name': 'Cacio & Pepe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Nh9NJhcGS20Gguof2WvYjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cacio-and-pepe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4912538, 'longitude': -0.1392584},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '46 Churton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 2LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['46 Churton Street',
#      'London SW1V 2LP',
#      'United Kingdom']},
#    'phone': '+442076307588',
#    'display_phone': '+44 20 7630 7588',
#    'distance': 2414.975180420146},
#   {'id': 'iSu_sC16-fUeo9qPFODGOw',
#    'alias': 'vasco-and-pieros-pavilion-restaurant-london',
#    'name': "Vasco & Piero's Pavilion Restaurant",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NroEbQwW83zIkD8132ZAFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vasco-and-pieros-pavilion-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.514775, 'longitude': -0.136932},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '15 Poland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8QE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Poland Street',
#      'London W1F 8QE',
#      'United Kingdom']},
#    'phone': '+442074378774',
#    'display_phone': '+44 20 7437 8774',
#    'distance': 226.31044489010904},
#   {'id': '4EvNL5HWc5B6C3FkXWhilA',
#    'alias': 'tarantella-london-2',
#    'name': 'Tarantella',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IWAW37kynlm_4YHNsv9_4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tarantella-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4930311699351,
#     'longitude': -0.25615431368351},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 Elliott Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W4 1PE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Elliott Road', 'London W4 1PE', 'United Kingdom']},
#    'phone': '+442089878877',
#    'display_phone': '+44 20 8987 8877',
#    'distance': 8606.161484953787},
#   {'id': 'DL5lptAIN3Jbe4EwdA0U8w',
#    'alias': 'flour-and-grape-london-2',
#    'name': 'Flour & Grape',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tqzIKWy__zuX-u6503NDeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flour-and-grape-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4980458434566,
#     'longitude': -0.0815150294296529},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '214 Bermondsey St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 3TQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['214 Bermondsey St',
#      'London SE1 3TQ',
#      'United Kingdom']},
#    'phone': '+442074074682',
#    'display_phone': '+44 20 7407 4682',
#    'distance': 4111.208532124347},
#   {'id': 'GzDBa_4-SuPDF-ftrPgnzA',
#    'alias': 'eataly-london-3',
#    'name': 'Eataly',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/shdkGbh4rN3U7mZPpn6BCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eataly-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51939, 'longitude': -0.108925},
#    'transactions': [],
#    'location': {'address1': '41 Greville St Corner Leather Lane',
#     'address2': 'Clerkenwell',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1N 8PJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41 Greville St Corner Leather Lane',
#      'Clerkenwell',
#      'London EC1N 8PJ',
#      'United Kingdom']},
#    'phone': '+447966544965',
#    'display_phone': '+44 7966 544965',
#    'distance': 2002.3025320925756},
#   {'id': 'XKcfgRIaisqdzdRmot8BMA',
#    'alias': 'villa-bianca-london',
#    'name': 'Villa Bianca',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sJrsJiU2Otj0exJ_YFmFJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/villa-bianca-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5556017, 'longitude': -0.1774188},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1 Perrins Court',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 1QS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Perrins Court',
#      'London NW3 1QS',
#      'United Kingdom']},
#    'phone': '+442074353131',
#    'display_phone': '+44 20 7435 3131',
#    'distance': 5561.0958649559425},
#   {'id': '3JAZzpV_cfNtQDmkwjOvKw',
#    'alias': 'arancina-london-2',
#    'name': 'Arancina',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7r96Dg_OrVYrUnsefcnJag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arancina-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 94,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5099935255636,
#     'longitude': -0.197430819704437},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '19 Pembridge Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 3HG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Pembridge Road',
#      'London W11 3HG',
#      'United Kingdom']},
#    'phone': '+442072217776',
#    'display_phone': '+44 20 7221 7776',
#    'distance': 4265.979272522798},
#   {'id': 'UaKN9OHMOz0J0gcbeI4k7Q',
#    'alias': 'franco-manca-london-10',
#    'name': 'Franco Manca',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YlSL38TpMQnv5pCgBE2vEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/franco-manca-london-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 93,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4924644, 'longitude': -0.177208},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '91 Old Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3LD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['91 Old Brompton Road',
#      'London SW7 3LD',
#      'United Kingdom']},
#    'phone': '+442075849713',
#    'display_phone': '+44 20 7584 9713',
#    'distance': 3635.2957125478642},
#   {'id': 'kwLvscNdOfBJTpm5qtD-iA',
#    'alias': 'polpo-london-16',
#    'name': 'POLPO',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ojOtcPkBbNZFayzg7mpF4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/polpo-london-16?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 87,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5107491, 'longitude': -0.1226443},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 Maiden Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 7NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Maiden Lane', 'London WC2E 7NA', 'United Kingdom']},
#    'phone': '+442078368448',
#    'display_phone': '+44 20 7836 8448',
#    'distance': 949.9546375999565},
#   {'id': 'yWVjEGPELKLygMmio6yOHQ',
#    'alias': 'gloria-london-2',
#    'name': 'Gloria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/89lVlnVdKvTzxGCKJSJYGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gloria-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5250382, 'longitude': -0.0812426},
#    'transactions': [],
#    'location': {'address1': '54-56 Great Eastern Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 3QR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54-56 Great Eastern Street',
#      'London EC2A 3QR',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4016.9720589894027},
#   {'id': 'wqZucWHydm2qx-iUCUyJpQ',
#    'alias': 'e-pellicci-london',
#    'name': 'E Pellicci',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wtUxdaKR9UoXTT3eYcjMGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/e-pellicci-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5265159984371,
#     'longitude': -0.0635611602914123},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '332 Bethnal Green Road',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E2 0AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['332 Bethnal Green Road',
#      'London E2 0AG',
#      'United Kingdom']},
#    'phone': '+442077394873',
#    'display_phone': '+44 20 7739 4873',
#    'distance': 5234.916021601817},
#   {'id': '_Q3CiOo0gWTD8nD_US_9CA',
#    'alias': 'coppa-club-london',
#    'name': 'Coppa Club',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/e23LTwnwqFHyHrgbFgbCrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coppa-club-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5134464, 'longitude': -0.1002132},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "4 St Paul's Churchyard",
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4M 8AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["4 St Paul's Churchyard",
#      'London EC4M 8AY',
#      'United Kingdom']},
#    'phone': '+442072487178',
#    'display_phone': '+44 20 7248 7178',
#    'distance': 2490.0197269563882},
#   {'id': 'CnxqwrH8M7QDzR2G2_taLw',
#    'alias': 'il-blandfords-london',
#    'name': "Il Blandford's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aZFihChTOy_i_1vxSIqwxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-blandfords-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 75,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.520315, 'longitude': -0.155747},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '65 Chiltern Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1U 6NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['65 Chiltern Street',
#      'London W1U 6NH',
#      'United Kingdom']},
#    'phone': '+442074864117',
#    'display_phone': '+44 20 7486 4117',
#    'distance': 1602.2168651410186},
#   {'id': 'b_-oPc8EICNR3beyKH_dfA',
#    'alias': 'lamezia-london-5',
#    'name': 'Lamezia',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HBWhq2f5TonVKHQ0c-wZqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lamezia-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.549781, 'longitude': -0.108798},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '165 Holloway Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N7 8LX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['165 Holloway Road',
#      'London N7 8LX',
#      'United Kingdom']},
#    'phone': '+442076096620',
#    'display_phone': '+44 20 7609 6620',
#    'distance': 4517.2922588714},
#   {'id': '5yHgv-_48HVwkF90fzRHvA',
#    'alias': 'diciannove-london',
#    'name': 'Diciannove',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/klV9rbA54HRvXnK1Vkj6kA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/diciannove-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5125084, 'longitude': -0.1041498},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '19 New Bridge Street',
#     'address2': 'Blackfriars',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4V 6DB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 New Bridge Street',
#      'Blackfriars',
#      'London EC4V 6DB',
#      'United Kingdom']},
#    'phone': '+442074388029',
#    'display_phone': '+44 20 7438 8029',
#    'distance': 2201.3128547736983},
#   {'id': 'hllMc-Ycqra77V1M4CoJng',
#    'alias': 'franzina-trattoria-london',
#    'name': 'Franzina Trattoria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1JKYkMy11RQN2s8qh0NBUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/franzina-trattoria-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4634398, 'longitude': -0.1107476},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '49 Brixton Station Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW9 8PQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Brixton Station Road',
#      'London SW9 8PQ',
#      'United Kingdom']},
#    'phone': '+447847415955',
#    'display_phone': '+44 7847 415955',
#    'distance': 5739.665567173421},
#   {'id': 'gXQSA3xudtrtN1lYOzrmoQ',
#    'alias': 'cacciaris-london-3',
#    'name': "Cacciari's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wvobI_qMaV0rrTdg2pN5Tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cacciaris-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.494095623609,
#     'longitude': -0.201894407860292},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '82 Pembroke Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 6NX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['82 Pembroke Road',
#      'London W8 6NX',
#      'United Kingdom']},
#    'phone': '+442076034448',
#    'display_phone': '+44 20 7603 4448',
#    'distance': 5017.146539157406},
#   {'id': 'q6KDb7nOXgQa5GTWBaCoCQ',
#    'alias': 'ciao-bella-london',
#    'name': 'Ciao Bella',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DDU7AnXNVg-B10Ogp1sXPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ciao-bella-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 124,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5232425139546,
#     'longitude': -0.119118084823987},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '86-90 Lambs Conduit Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 3LZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['86-90 Lambs Conduit Street',
#      'London WC1N 3LZ',
#      'United Kingdom']},
#    'phone': '+442072424119',
#    'display_phone': '+44 20 7242 4119',
#    'distance': 1642.092422047072},
#   {'id': 'w-kpar4Y81AR4L53xeHtjw',
#    'alias': 'pizza-pilgrims-london-2',
#    'name': 'Pizza Pilgrims',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xf7LGXn2YCEQpunAeQjWMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizza-pilgrims-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 111,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5149474, 'longitude': -0.13324},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Dean Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 3RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Dean Street',
#      'Soho',
#      'London W1D 3RP',
#      'United Kingdom']},
#    'phone': '+442072878964',
#    'display_phone': '+44 20 7287 8964',
#    'distance': 300.77168176768566},
#   {'id': 'r5Ni17dep-Kn4RHDyckLTg',
#    'alias': 'de-amicis-london',
#    'name': 'De Amicis',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IBnYbZobjBz5w5KGisEj4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/de-amicis-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5097908, 'longitude': -0.1933323},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 Notting Hill Gate',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 3JE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Notting Hill Gate',
#      'London W11 3JE',
#      'United Kingdom']},
#    'phone': '+442072298205',
#    'display_phone': '+44 20 7229 8205',
#    'distance': 3995.3664798217887},
#   {'id': 'Xol6-_M--EE6HkU4n80SCA',
#    'alias': 'prezzo-london-34',
#    'name': 'Prezzo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/l7vxjQG2yZrnXXPrTDzbKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prezzo-london-34?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.505513195797, 'longitude': -0.1487418235955},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '17 Hertford Street',
#     'address2': 'Mayfair',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 7RS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17 Hertford Street',
#      'Mayfair',
#      'London W1J 7RS',
#      'United Kingdom']},
#    'phone': '+442074994690',
#    'display_phone': '+44 20 7499 4690',
#    'distance': 1202.4692052965086},
#   {'id': '40kbFr-OwMCECFxth1hqPQ',
#    'alias': 'tuscanic-london',
#    'name': 'Tuscanic',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2MsPW9uC_SYbCVNZjGqezQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tuscanic-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5126836, 'longitude': -0.1329437},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '72 Old Compton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 4UN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['72 Old Compton Street',
#      'London W1D 4UN',
#      'United Kingdom']},
#    'phone': '+442036599243',
#    'display_phone': '+44 20 3659 9243',
#    'distance': 210.46461309411598},
#   {'id': 'uFYQ6YGR9hL2_zIRwK32IQ',
#    'alias': 'da-daniela-london-3',
#    'name': 'Da Daniela',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xLxs62NBJxtGlwKtcogSrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-daniela-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.52420440697, 'longitude': -0.18850507887835},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '49 Shirland Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W9 2JD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Shirland Road',
#      'London W9 2JD',
#      'United Kingdom']},
#    'phone': '+442072890008',
#    'display_phone': '+44 20 7289 0008',
#    'distance': 3849.495762609077},
#   {'id': 'dgzA0kVLiTmaKH0UBUrCcg',
#    'alias': 'la-tavernetta-london',
#    'name': 'La Tavernetta',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-tavernetta-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.478119, 'longitude': -0.103468},
#    'transactions': [],
#    'location': {'address1': '148 Camberwell New Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE5 0RR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['148 Camberwell New Road',
#      'London SE5 0RR',
#      'United Kingdom']},
#    'phone': '+442070910447',
#    'display_phone': '+44 20 7091 0447',
#    'distance': 4467.670603550576},
#   {'id': '4CivKEbm_pJEaJa3kDC6KQ',
#    'alias': 'tavolino-london',
#    'name': 'Tavolino',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/00plmmiNrJv0bc2aAPtQxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tavolino-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.50527, 'longitude': -0.080495},
#    'transactions': [],
#    'location': {'address1': 'Unit 1',
#     'address2': '2 More London Place',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 2JP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 1',
#      '2 More London Place',
#      'London SE1 2JP',
#      'United Kingdom']},
#    'phone': '+442081941037',
#    'display_phone': '+44 20 8194 1037',
#    'distance': 3929.364812187934},
#   {'id': 'aAbTKIzcnemZc9k2hfNRZg',
#    'alias': 'obicà-london-5',
#    'name': 'Obicà',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kEAWD-zjzOghdazlGys8EQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/obic%C3%A0-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.502859, 'longitude': -0.020183},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 1',
#     'address2': 'West Wintergarden',
#     'address3': '35 Bank Street',
#     'city': 'London',
#     'zip_code': 'E14 5NW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 1',
#      'West Wintergarden',
#      '35 Bank Street',
#      'London E14 5NW',
#      'United Kingdom']},
#    'phone': '+442077191532',
#    'display_phone': '+44 20 7719 1532',
#    'distance': 8088.888785719964},
#   {'id': 'PRrEe5QrXVgwrQeIaKv-CQ',
#    'alias': 'sarracino-restaurant-london',
#    'name': 'Sarracino Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xyqi-BxJhrSg8h7lcnIDOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sarracino-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.546569, 'longitude': -0.190136},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '186 Broadhurst Gardens',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 3AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['186 Broadhurst Gardens',
#      'London NW6 3AY',
#      'United Kingdom']},
#    'phone': '+442073725889',
#    'display_phone': '+44 20 7372 5889',
#    'distance': 5292.6294644622285},
#   {'id': 'r130n2T4Yu8RuDANIz-c9w',
#    'alias': 'prima-sapori-italia-london',
#    'name': 'Prima Sapori Italia',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/s4z92F_c4acMWHVRV506ZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prima-sapori-italia-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.511382579241,
#     'longitude': -0.122399630007294},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Tavistock Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2E 8BE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Tavistock Street',
#      'London WC2E 8BE',
#      'United Kingdom']},
#    'phone': '+442078365448',
#    'display_phone': '+44 20 7836 5448',
#    'distance': 951.9248275479093},
#   {'id': 'mWouVx2APIzSeneEK5W0wQ',
#    'alias': 'santo-mare-london',
#    'name': 'Santo Mare',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mGtPjoYYPGmzyjmOfEoN8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/santo-mare-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.51704, 'longitude': -0.15717},
#    'transactions': [],
#    'location': {'address1': '87-89 George Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1U 8AQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['87-89 George Street',
#      'London W1U 8AQ',
#      'United Kingdom']},
#    'phone': '+442074860377',
#    'display_phone': '+44 20 7486 0377',
#    'distance': 1542.6783090444737},
#   {'id': 'Orx87C7tgxPlYG4qNCC4MQ',
#    'alias': 'locanda-locatelli-london-2',
#    'name': 'Locanda Locatelli',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bbNSUeKGHQax_nUDsMKx-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/locanda-locatelli-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5150156, 'longitude': -0.1576491},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '8 Seymour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7JZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Seymour Street',
#      'London W1H 7JZ',
#      'United Kingdom']},
#    'phone': '+442079359088',
#    'display_phone': '+44 20 7935 9088',
#    'distance': 1496.875905294034},
#   {'id': 'qtHjaPduuF253zcPub1vVw',
#    'alias': 'sale-e-pepe-london',
#    'name': 'Sale E Pepe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-CxO1x0ZfmAXgpkE1A4DMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sale-e-pepe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5005529, 'longitude': -0.1606957},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '9-15 Pavilion Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 0HD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9-15 Pavilion Road',
#      'London SW1X 0HD',
#      'United Kingdom']},
#    'phone': '+442072350098',
#    'display_phone': '+44 20 7235 0098',
#    'distance': 2190.233240307527},
#   {'id': '7Pc6VXiWEqc4JbgrH4U3tA',
#    'alias': 'rocca-london',
#    'name': 'Rocca',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/unoBe3JOZnztSZwT3CppAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rocca-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4928759536943,
#     'longitude': -0.176558382809162},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '73 Old Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3LD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['73 Old Brompton Road',
#      'London SW7 3LD',
#      'United Kingdom']},
#    'phone': '+442072253413',
#    'display_phone': '+44 20 7225 3413',
#    'distance': 3581.0337831711167},
#   {'id': 'kfC0Om5BlL3wTi_YTUKvvA',
#    'alias': 'burro-e-salvia-pastificio-london-2',
#    'name': 'Burro E Salvia Pastificio',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qUAITjYVeWM3L1MR5qD4-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burro-e-salvia-pastificio-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'gourmet', 'title': 'Specialty Food'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5242958, 'longitude': -0.0746875},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '52 Redchurch Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['52 Redchurch Street',
#      'London E2 7DP',
#      'United Kingdom']},
#    'phone': '+442077394429',
#    'display_phone': '+44 20 7739 4429',
#    'distance': 4428.6653914603885},
#   {'id': '1Ctqa323bzNIFGvvkM_zTQ',
#    'alias': 'lardo-london',
#    'name': 'Lardo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2xiuc0ViUMmhBK1_j48QQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lardo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.54357762742,
#     'longitude': -0.057247297606362},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '197-201 Richmond Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 3NJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['197-201 Richmond Road',
#      'London E8 3NJ',
#      'United Kingdom']},
#    'phone': '+442089852683',
#    'display_phone': '+44 20 8985 2683',
#    'distance': 6428.97445428336},
#   {'id': 'pbWzxl-N7sF3liuUCWL3Wg',
#    'alias': 'da-pietro-london',
#    'name': 'Da Pietro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7tWUotlq_RBb7pQqpGHdFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-pietro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4340257, 'longitude': -0.1284156},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '122 Streatham High Road',
#     'address2': 'Streatham',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW16 1BW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['122 Streatham High Road',
#      'Streatham',
#      'London SW16 1BW',
#      'United Kingdom']},
#    'phone': '+442086646033',
#    'display_phone': '+44 20 8664 6033',
#    'distance': 8778.790077426216},
#   {'id': 'p563ZSNeT_SOP6WHEnuRhQ',
#    'alias': 'bellaria-restaurant-london',
#    'name': 'Bellaria Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0yQiniqcX6ruP53HBUMDfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bellaria-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5185707907351,
#     'longitude': -0.140762329101562},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '71 Great Titchfield Street',
#     'address2': 'Fittzrovia',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 6RB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['71 Great Titchfield Street',
#      'Fittzrovia',
#      'London W1W 6RB',
#      'United Kingdom']},
#    'phone': '+442075808075',
#    'display_phone': '+44 20 7580 8075',
#    'distance': 719.2505747980833},
#   {'id': 'Cz_fMo-u-R70IHNryBX-bQ',
#    'alias': 'pizzeria-pappagone-london',
#    'name': 'Pizzeria Pappagone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Y0cTtl8IzjfdSMbkf0JWJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizzeria-pappagone-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5694126, 'longitude': -0.1126623},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '131 Stroud Green Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N4 3PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['131 Stroud Green Road',
#      'London N4 3PX',
#      'United Kingdom']},
#    'phone': '+442072632114',
#    'display_phone': '+44 20 7263 2114',
#    'distance': 6499.2632802361295},
#   {'id': 'GZmIMGiJqJ2mt-XdhBgHGg',
#    'alias': 'villa-di-geggiano-london',
#    'name': 'Villa di Geggiano',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_PGi-hF2vazXngheYep8Gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/villa-di-geggiano-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.493426, 'longitude': -0.249519},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '66-68 Chiswick High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W4 1SY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66-68 Chiswick High Road',
#      'London W4 1SY',
#      'United Kingdom']},
#    'phone': '+442033849442',
#    'display_phone': '+44 20 3384 9442',
#    'distance': 8148.627809718357},
#   {'id': '94NES3AsE1pfsuqTHqh5Lg',
#    'alias': 'cotto-london',
#    'name': 'Cotto',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SpmuCzwhwtcqSCanMxdaCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cotto-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 112,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4988819, 'longitude': -0.1127175},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '89 Westminster Bridge Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7HR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['89 Westminster Bridge Road',
#      'London SE1 7HR',
#      'United Kingdom']},
#    'phone': '+442079285535',
#    'display_phone': '+44 20 7928 5535',
#    'distance': 2238.766107941911},
#   {'id': 'ASpm0fr5A5fp0G_E1hFwzA',
#    'alias': 'artigiano-london',
#    'name': 'Artigiano',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Aduu6MvXM_tUbS05RLNbmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/artigiano-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5489128, 'longitude': -0.1710916},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '12a Belsize Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 4AX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12a Belsize Terrace',
#      'London NW3 4AX',
#      'United Kingdom']},
#    'phone': '+442077944288',
#    'display_phone': '+44 20 7794 4288',
#    'distance': 4690.430883777782},
#   {'id': 'VpXOD3pTsTMGy7cqtpNuNA',
#    'alias': 'sartori-restaurant-london-2',
#    'name': 'Sartori Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4zu2Y-9soaYtKj1rPnoWaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sartori-restaurant-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511791229248,
#     'longitude': -0.128003999590874},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '15 Great Newport Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 7JE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Great Newport Street',
#      'London WC2H 7JE',
#      'United Kingdom']},
#    'phone': '+442078366308',
#    'display_phone': '+44 20 7836 6308',
#    'distance': 561.3031039602805},
#   {'id': 'BzX-KhL4VDjOidEKXPhBNQ',
#    'alias': 'zafferano-london',
#    'name': 'Zafferano',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ID3-4Q82AA6xmCMfsqvSRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zafferano-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.499097748922,
#     'longitude': -0.157740090217924},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '15 Lowndes Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 9EY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Lowndes Street',
#      'London SW1X 9EY',
#      'United Kingdom']},
#    'phone': '+442072355800',
#    'display_phone': '+44 20 7235 5800',
#    'distance': 2146.3185005024943},
#   {'id': 'bKkZm6z3nZz97Z0L8pPNsA',
#    'alias': 'bocconcino-restaurant-london-2',
#    'name': 'Bocconcino Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OGbAXLFl5eiuHuXBsmYV-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bocconcino-restaurant-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5088519, 'longitude': -0.1436403},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '19 Berkeley Street',
#     'address2': 'Mayfair',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 8ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Berkeley Street',
#      'Mayfair',
#      'London W1J 8ED',
#      'United Kingdom']},
#    'phone': '+442074994510',
#    'display_phone': '+44 20 7499 4510',
#    'distance': 692.1124252216309},
#   {'id': 'vnC7idK5GtzenRZiFdkAew',
#    'alias': 'olivelli-london-6',
#    'name': 'Olivelli',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KRaJu7T90Up2KaBWwsDB2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olivelli-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51986, 'longitude': -0.1311722},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '35 Store Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1E 7BS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35 Store Street',
#      'London WC1E 7BS',
#      'United Kingdom']},
#    'phone': '+442072552554',
#    'display_phone': '+44 20 7255 2554',
#    'distance': 861.4650824810792},
#   {'id': '344WUr6UgCqVWjlKh_20tg',
#    'alias': 'anima-d-italia-london',
#    'name': "Anima D'italia",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4qyeR3U72_Cn_2H26U1V7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anima-d-italia-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5204355, 'longitude': -0.0519754},
#    'transactions': [],
#    'location': {'address1': '114 Mile End Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 4UN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['114 Mile End Road',
#      'London E1 4UN',
#      'United Kingdom']},
#    'phone': '+442033182217',
#    'display_phone': '+44 20 3318 2217',
#    'distance': 5872.16138132601},
#   {'id': 'gpQUlJ0dQyZexifTOoMF1Q',
#    'alias': 'spaghetti-house-london-15',
#    'name': 'Spaghetti House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BOUkkLqjUANg7cYMAsLTyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spaghetti-house-london-15?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.502248, 'longitude': -0.187966},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9 Kensington High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 5NP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Kensington High Street',
#      'London W8 5NP',
#      'United Kingdom']},
#    'phone': '+442079378961',
#    'display_phone': '+44 20 7937 8961',
#    'distance': 3787.200148914702},
#   {'id': 'JKwMHA_plYwrKVxkkh6bAg',
#    'alias': 'san-carlo-cicchetti-london-3',
#    'name': 'San Carlo Cicchetti',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JyWPJirtxHKGUvSZM7PoIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/san-carlo-cicchetti-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5123138, 'longitude': -0.12058},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '30 Wellington Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 7BD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Wellington Street',
#      'London WC2E 7BD',
#      'United Kingdom']},
#    'phone': '+442072406339',
#    'display_phone': '+44 20 7240 6339',
#    'distance': 1064.0472140449294},
#   {'id': 'eHECpyAZ7Hm0bFjqh1eloA',
#    'alias': 'spaghetti-house-london-11',
#    'name': 'Spaghetti House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uYjIRAO-C7Vc0bjSIFb52A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spaghetti-house-london-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51977, 'longitude': -0.134364},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '15 Goodge Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 2PQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Goodge Street',
#      'London W1T 2PQ',
#      'United Kingdom']},
#    'phone': '+442076366582',
#    'display_phone': '+44 20 7636 6582',
#    'distance': 778.9029558731622},
#   {'id': 'DGReEvlnkBiZ4nVY3qfcGg',
#    'alias': 'l-antipasto-city-london',
#    'name': "L'Antipasto City",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mRmA689M592AyaKqTWy8Iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-antipasto-city-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5118607745811,
#     'longitude': -0.106365156250035},
#    'transactions': [],
#    'location': {'address1': '2/4 Botolph Alley',
#     'address2': 'Monument Station',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3R 8DR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2/4 Botolph Alley',
#      'Monument Station',
#      'London EC3R 8DR',
#      'United Kingdom']},
#    'phone': '+442072837000',
#    'display_phone': '+44 20 7283 7000',
#    'distance': 2050.5881560530606}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                             Restaurant     Type Price Rating  \
# 0                       La Pappardella    Pizza    ££      4
# 1                         Cacio & Pepe  Italian   £££      5
# 2  Vasco & Piero's Pavilion Restaurant  Italian   £££    4.5
# 3                           Tarantella  Italian    ££      4
# 4                        Flour & Grape  Italian    ££    4.5
#
#                  Address        Lat       Lng  \
# 0  253 Old Brompton Road  51.489143 -0.190697
# 1      46 Churton Street  51.491254 -0.139258
# 2       15 Poland Street  51.514775 -0.136932
# 3         4 Elliott Road  51.493031 -0.256154
# 4      214 Bermondsey St  51.498046 -0.081515
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/la-pappardella-london...  TIfha7KOWgLRhN8935g6Iw
# 1  https://www.yelp.com/biz/cacio-and-pepe-london...  ZUGNQVHJy8FXxF5dsv2JFg
# 2  https://www.yelp.com/biz/vasco-and-pieros-pavi...  iSu_sC16-fUeo9qPFODGOw
# 3  https://www.yelp.com/biz/tarantella-london-2?a...  4EvNL5HWc5B6C3FkXWhilA
# 4  https://www.yelp.com/biz/flour-and-grape-londo...  DL5lptAIN3Jbe4EwdA0U8w

# %%
#3rd set of 50 records 101-150
lndr_params3 = {"term":"Italian","location":"London","limit":50,"offset":101}
lndr_response3 = requests.get(search_api_url, headers=headers, params=lndr_params3)
lndr3 = lndr_response3.json()
display(lndr3)
#print(lndr_response3.url)
#print(lndr_response3.status_code)
# Out:
# {'businesses': [{'id': 'NSFaY9UeEUqie5Vh0RpKpA',
#    'alias': 'spaghetti-house-london-13',
#    'name': 'Spaghetti House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2-WgBuEdKxA5cZm3d43OyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spaghetti-house-london-13?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5134004, 'longitude': -0.1512049},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '74 Duke Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 6JZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['74 Duke Street', 'London W1K 6JZ', 'United Kingdom']},
#    'phone': '+442076296097',
#    'display_phone': '+44 20 7629 6097',
#    'distance': 1056.0435670866354},
#   {'id': 'UOMGToX1X1XqxcoqcLf8Pw',
#    'alias': 'la-pastaia-london',
#    'name': 'La Pastaia',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4aop_ly4sKK-zuulY_P1dQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-pastaia-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.512463, 'longitude': -0.13289},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '63 Old Compton Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1D 6HT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63 Old Compton Street',
#      'London W1D 6HT',
#      'United Kingdom']},
#    'phone': '+442074941271',
#    'display_phone': '+44 20 7494 1271',
#    'distance': 213.2988387816787},
#   {'id': '6swPe7Trae-ifxoSRAEFNg',
#    'alias': 'dapaolo-italian-restaurant-london',
#    'name': "Da'Paolo Italian Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6RTQQx2nHBVQpHquIaizWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dapaolo-italian-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5189107, 'longitude': -0.1362067},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '3 Charlotte Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 1SD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Charlotte Place',
#      'London W1T 1SD',
#      'United Kingdom']},
#    'phone': '+442075800021',
#    'display_phone': '+44 20 7580 0021',
#    'distance': 677.073959637964},
#   {'id': 'pSyUFW1a9bs9LJshoS7rzw',
#    'alias': 'spaghetti-house-london-4',
#    'name': 'Spaghetti House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BmeV7sL9guq8thIWWNgunA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spaghetti-house-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5140113830566,
#     'longitude': -0.159620001912117},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '47 Bryanston Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7DN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Bryanston Street',
#      'London W1H 7DN',
#      'United Kingdom']},
#    'phone': '+442077249615',
#    'display_phone': '+44 20 7724 9615',
#    'distance': 1642.7736101194946},
#   {'id': '4Ff4jkboKDzTsiGRVv6Qzw',
#    'alias': 'forza-win-london',
#    'name': 'Forza Win',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lBz_1OmDNTCmSG_bAuARlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/forza-win-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'soulfood', 'title': 'Soul Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.469862024911,
#     'longitude': -0.0656424011192485},
#    'transactions': [],
#    'location': {'address1': 'Unit 4 1',
#     'address2': '133 Copeland Road',
#     'address3': 'Copeland Park',
#     'city': 'London',
#     'zip_code': 'SE15 3SN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 4 1',
#      '133 Copeland Road',
#      'Copeland Park',
#      'London SE15 3SN',
#      'United Kingdom']},
#    'phone': '+442077329012',
#    'display_phone': '+44 20 7732 9012',
#    'distance': 6821.381703556315},
#   {'id': 'uc05lbneCFd3NaEMSO6bTA',
#    'alias': 'trattoria-raffaele-london',
#    'name': 'Trattoria Raffaele',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lFx9LSuDoSZPHRm-RwxHnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trattoria-raffaele-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.425607, 'longitude': -0.04863},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '94 Sydenham Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE26 5JX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['94 Sydenham Road',
#      'London SE26 5JX',
#      'United Kingdom']},
#    'phone': '+442087786262',
#    'display_phone': '+44 20 8778 6262',
#    'distance': 11421.443032375793},
#   {'id': 'BBQgwswtNr6B1ExB9haAnA',
#    'alias': 'franco-manca-soho',
#    'name': 'Franco Manca',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KnqwiNw1T3hgAcbBpdvDKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/franco-manca-soho?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5155642, 'longitude': -0.1363627},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '51 Berwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Soho',
#     'zip_code': 'W1F 8SJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Berwick Street',
#      'Soho W1F 8SJ',
#      'United Kingdom']},
#    'phone': '+442077349330',
#    'display_phone': '+44 20 7734 9330',
#    'distance': 295.59768604724957},
#   {'id': 'wvJVJRmgJYpWNFt5GZmtzA',
#    'alias': 'bravi-ragazzi-london',
#    'name': 'Bravi Ragazzi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xT_fQloelsDcqjzJyoMSkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bravi-ragazzi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.430542, 'longitude': -0.1292379},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '2A Sunnyhill Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW16 2UH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2A Sunnyhill Rd',
#      'London SW16 2UH',
#      'United Kingdom']},
#    'phone': '+442087694966',
#    'display_phone': '+44 20 8769 4966',
#    'distance': 9157.20843654917},
#   {'id': 'O64cGnCu-TQvVVyGOfoLrA',
#    'alias': 'il-posto-london-2',
#    'name': 'Il Posto',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/H3XAzgMHk9OVgUygo3k_Hw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-posto-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4956817626953,
#     'longitude': -0.141846001148224},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '314-316 Vauxhall Bridge Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['314-316 Vauxhall Bridge Rd',
#      'London SW1V 1AA',
#      'United Kingdom']},
#    'phone': '+442078345270',
#    'display_phone': '+44 20 7834 5270',
#    'distance': 1950.4906881628187},
#   {'id': 'FV59IBaaeHKbJSSM9WLK7g',
#    'alias': 'la-cucina-london-3',
#    'name': 'La Cucina',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1pPC7szBc9YbfzqjHye_fA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-cucina-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51953, 'longitude': -0.071673},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '96 Brick Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['96 Brick Lane', 'London E1 6RL', 'United Kingdom']},
#    'phone': '+442072477772',
#    'display_phone': '+44 20 7247 7772',
#    'distance': 4512.556328860799},
#   {'id': '8jNOl4h8Z6iibXxY6Tx3vQ',
#    'alias': 'icco-london-2',
#    'name': 'ICCo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eTHebCvj5Ar06SVpAtxuXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/icco-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 142,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.519545, 'longitude': -0.136045},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '46 Goodge Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 4LU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['46 Goodge Street',
#      'London W1T 4LU',
#      'United Kingdom']},
#    'phone': '+442075809688',
#    'display_phone': '+44 20 7580 9688',
#    'distance': 746.0847029581461},
#   {'id': 'uNmwBDJk2fKlpLii-vVjyQ',
#    'alias': 'via-emilia-by-food-roots-london',
#    'name': 'Via Emilia by FOOD ROOTS',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vtEKbYG0WCSyU3L63L-ROA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/via-emilia-by-food-roots-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.527428, 'longitude': -0.08069},
#    'transactions': [],
#    'location': {'address1': '37a Hoxton Square',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 6NN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['37a Hoxton Square',
#      'London N1 6NN',
#      'United Kingdom']},
#    'phone': '+442076130508',
#    'display_phone': '+44 20 7613 0508',
#    'distance': 4153.858292255892},
#   {'id': 'vsKa-KYWNeGo2rREfXrwow',
#    'alias': 'cecconis-london-4',
#    'name': "Cecconi's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1FmKSkToPqTlgCSt2imgpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cecconis-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'wineries', 'title': 'Wineries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.513682, 'longitude': -0.089911},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '27 Poultry',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2R 8AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['27 Poultry', 'London EC2R 8AJ', 'United Kingdom']},
#    'phone': '+442038282000',
#    'display_phone': '+44 20 3828 2000',
#    'distance': 3187.7024039302673},
#   {'id': 'lEhxP1w5bD92h3iYSUp5mw',
#    'alias': 'pepenero-london',
#    'name': 'Pepenero',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/L-MtdjkBxJWpTBBl7iJIUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pepenero-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5123836376572,
#     'longitude': 0.0108546975252147},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'The Sphere Unit 3',
#     'address2': '114 Silvertown Way',
#     'address3': 'Royal Docks',
#     'city': 'London',
#     'zip_code': 'E16 1EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Sphere Unit 3',
#      '114 Silvertown Way',
#      'Royal Docks',
#      'London E16 1EA',
#      'United Kingdom']},
#    'phone': '+442074769354',
#    'display_phone': '+44 20 7476 9354',
#    'distance': 10159.591643825212},
#   {'id': 'ush325wnI4b0YSWzBtyLnw',
#    'alias': 'quirinale-london',
#    'name': 'Quirinale',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZernE7ss9AB6j8ha3RzLMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/quirinale-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.496888, 'longitude': -0.126712},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1 Great Peter Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 3LL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Great Peter Street',
#      'London SW1P 3LL',
#      'United Kingdom']},
#    'phone': '+442072227080',
#    'display_phone': '+44 20 7222 7080',
#    'distance': 1884.0505108295326},
#   {'id': 'hmL97HDiAB7YLfCggbKyBA',
#    'alias': 'cecconis-london-7',
#    'name': "Cecconi's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TWwDKs6QTDB_rtS8sf-JRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cecconis-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.52442225, 'longitude': -0.074357},
#    'transactions': [],
#    'location': {'address1': '58-60 Redchurch st',
#     'address2': None,
#     'address3': 'Shoreditch',
#     'city': 'London',
#     'zip_code': 'E2 7DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['58-60 Redchurch st',
#      'Shoreditch',
#      'London E2 7DP',
#      'United Kingdom']},
#    'phone': '+442038417755',
#    'display_phone': '+44 20 3841 7755',
#    'distance': 4452.624059498336},
#   {'id': 'xAzcGEDsUmrXpJgdnLF2wQ',
#    'alias': 'the-bite-london-3',
#    'name': 'The Bite',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jcgyLNIWd8DxRers8dd80Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bite-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5457168352045,
#     'longitude': -0.0758428126573563},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '533 Kingsland Road',
#     'address2': 'Dalston',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 4AR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['533 Kingsland Road',
#      'Dalston',
#      'London E8 4AR',
#      'United Kingdom']},
#    'phone': '+44442072544770',
#    'display_phone': '+44 442072544770',
#    'distance': 5537.154459399103},
#   {'id': 'XNj3z-EVv6o58E19C2spZg',
#    'alias': 'locale-london-6',
#    'name': 'Locale',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pszZCaR0g_j_XPCedUJDpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/locale-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 69,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.501479, 'longitude': -0.118008},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'County Hall',
#     'address2': '3B Belvedere Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7GP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['County Hall',
#      '3B Belvedere Road',
#      'London SE1 7GP',
#      'United Kingdom']},
#    'phone': '+442074016734',
#    'display_phone': '+44 20 7401 6734',
#    'distance': 1760.5081016764732},
#   {'id': 'fAdMI0n38kDXspqTKCuZyQ',
#    'alias': 'bocconi-ristorante-london',
#    'name': 'Bocconi Ristorante',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qEAEvKl8j1S4dUnKhvNs9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bocconi-ristorante-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.503017939329,
#     'longitude': -0.223435671985158},
#    'transactions': [],
#    'location': {'address1': '5 Goldhawk Road',
#     'address2': "Shepherd's Bush",
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W12 8QQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Goldhawk Road',
#      "Shepherd's Bush",
#      'London W12 8QQ',
#      'United Kingdom']},
#    'phone': '+442034170590',
#    'display_phone': '+44 20 3417 0590',
#    'distance': 6151.969059830755},
#   {'id': 'CQsUI0K8XOAwSR4gN6l55Q',
#    'alias': 'pizza-union-london-7',
#    'name': 'Pizza Union',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/v0sNgoZ5-bGnhmxoC3CFGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizza-union-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 67,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.531051655444,
#     'longitude': -0.11983242244974},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '246 - 250 Pentonville Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9JY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['246 - 250 Pentonville Road',
#      'London N1 9JY',
#      'United Kingdom']},
#    'phone': '+442072789425',
#    'display_phone': '+44 20 7278 9425',
#    'distance': 2312.4049845213176},
#   {'id': 'AEYp6nEtzJ7tPhPPi0LgAQ',
#    'alias': 'la-bottega-london-5',
#    'name': 'La Bottega',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-bottega-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.50723, 'longitude': -0.138595},
#    'transactions': [],
#    'location': {'address1': '20 Ryder Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 6QB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Ryder Street',
#      'London SW1Y 6QB',
#      'United Kingdom']},
#    'phone': '+442078395789',
#    'display_phone': '+44 20 7839 5789',
#    'distance': 577.8672211780736},
#   {'id': 'SBf115mUfL4ryjpJcZOiUg',
#    'alias': 'bancone-london',
#    'name': 'Bancone',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hONlJAwb9F0NsozPkpKYPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bancone-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5095699, 'longitude': -0.12642},
#    'transactions': [],
#    'location': {'address1': '39 William IV St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2N 4DD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39 William IV St',
#      'London WC2N 4DD',
#      'United Kingdom']},
#    'phone': '+442072408786',
#    'display_phone': '+44 20 7240 8786',
#    'distance': 753.6083686419305},
#   {'id': 'JcpYVXTIMNFo7vl1De1W0g',
#    'alias': 'la-luna-london-2',
#    'name': 'La Luna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/k5J6_7ScergYQWjmuc3oQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-luna-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.484635, 'longitude': -0.094058},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '380 Walworth Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE17 2NG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['380 Walworth Road',
#      'London SE17 2NG',
#      'United Kingdom']},
#    'phone': '+442072771991',
#    'display_phone': '+44 20 7277 1991',
#    'distance': 4275.448112303117},
#   {'id': 'IBGiXhPZsnHB0Uls03DiPA',
#    'alias': 'murano-london',
#    'name': 'Murano',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SoKoYzsaapm0O2BAzH3HpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/murano-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.507034, 'longitude': -0.147277},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '20 Queen Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 5PP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Queen Street',
#      'London W1J 5PP',
#      'United Kingdom']},
#    'phone': '+442074951127',
#    'display_phone': '+44 20 7495 1127',
#    'distance': 1002.0239734128802},
#   {'id': 'q1Qwp2Fbe9ltzc217cqgLg',
#    'alias': 'trattoria-verdi-london',
#    'name': 'Trattoria Verdi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6APlfN29mel_nxShgaDN3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trattoria-verdi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.520417, 'longitude': -0.122489},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '110 Southampton Row',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 4BL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['110 Southampton Row',
#      'London WC1B 4BL',
#      'United Kingdom']},
#    'phone': '+442074058001',
#    'display_phone': '+44 20 7405 8001',
#    'distance': 1257.3399103674162},
#   {'id': 'mg9geWDj8biDftBv6w64VA',
#    'alias': 'terra-rossa-london',
#    'name': 'Terra Rossa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qyiglVbufiKC9tVd9OqCRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/terra-rossa-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5394972, 'longitude': -0.1026884},
#    'transactions': [],
#    'location': {'address1': '139 Upper Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 1QP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['139 Upper Street',
#      'London N1 1QP',
#      'United Kingdom']},
#    'phone': '+442072262244',
#    'display_phone': '+44 20 7226 2244',
#    'distance': 3754.2229748632817},
#   {'id': 'x0_g9TDFgLJCyAZNPqz5pw',
#    'alias': 'harrys-bar-pizzeria-london',
#    'name': "Harry's Bar Pizzeria",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-YlamssAcDD0zrMfEEdG7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harrys-bar-pizzeria-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5129345, 'longitude': -0.103464},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '15 Black Friars Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4V 6ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Black Friars Lane',
#      'London EC4V 6ER',
#      'United Kingdom']},
#    'phone': '+442073290240',
#    'display_phone': '+44 20 7329 0240',
#    'distance': 2258.335966964332},
#   {'id': 'aAzCPzQkOcBUBnqd3-qIuw',
#    'alias': 'obicà-london-4',
#    'name': 'Obicà',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SCY-3PHSATY47GxeYdHSQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/obic%C3%A0-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5149383967259,
#     'longitude': -0.13713073307934},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Poland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8QF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Poland Street',
#      'London W1F 8QF',
#      'United Kingdom']},
#    'phone': '+442033277070',
#    'display_phone': '+44 20 3327 7070',
#    'distance': 247.5605647506309},
#   {'id': 'W5qDRErkfwRcRNj6bX_WMg',
#    'alias': 'l-antica-pizzeria-london',
#    'name': "L'antica Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yKC3RLIvQm7LpSiCaA7P1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-antica-pizzeria-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5573775, 'longitude': -0.1781694},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '66 Heath Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 1DN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Heath Street',
#      'London NW3 1DN',
#      'United Kingdom']},
#    'phone': '+442074318516',
#    'display_phone': '+44 20 7431 8516',
#    'distance': 5749.4138934897355},
#   {'id': 'ptFeATOHchBNz-oAFw13xw',
#    'alias': 'purezza-london',
#    'name': 'Purezza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/U8uV0LUpMonHe8EgSJJxfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/purezza-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5381126, 'longitude': -0.1443048},
#    'transactions': [],
#    'location': {'address1': '43 Parkway',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW1 7PN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['43 Parkway', 'London NW1 7PN', 'United Kingdom']},
#    'phone': '+442038840078',
#    'display_phone': '+44 20 3884 0078',
#    'distance': 2869.527686600775},
#   {'id': 'Xl1CntJIpfJTrAMJmQbzsg',
#    'alias': 'scarpetta-london-2',
#    'name': 'Scarpetta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SGsblx_Rr1Wg-pblxW7aGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scarpetta-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5043826410815,
#     'longitude': -0.0169062843583561},
#    'transactions': [],
#    'location': {'address1': '20 Canada Square',
#     'address2': 'Canary Wharf',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E14 5NN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Canada Square',
#      'Canary Wharf',
#      'London E14 5NN',
#      'United Kingdom']},
#    'phone': '+442077191661',
#    'display_phone': '+44 20 7719 1661',
#    'distance': 8292.536775212224},
#   {'id': '2pDU7LE3gTpDWGsoKuGwMA',
#    'alias': 'apulia-london',
#    'name': 'Apulia',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gJiKoXC-5tcdKFSOn5Ze5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/apulia-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5190086, 'longitude': -0.1003585},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '50 Long Lane',
#     'address2': 'Barbican',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1A 9EJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50 Long Lane',
#      'Barbican',
#      'London EC1A 9EJ',
#      'United Kingdom']},
#    'phone': '+442076008107',
#    'display_phone': '+44 20 7600 8107',
#    'distance': 2551.8401317155112},
#   {'id': 'TrBQ0Q2IMrMPDlzIeMjUJQ',
#    'alias': 'la-bella-vita-london',
#    'name': 'La Bella Vita',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-bella-vita-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5697, 'longitude': 0.01305},
#    'transactions': [],
#    'location': {'address1': '853 High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E11 3AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['853 High Road', 'London E11 3AJ', 'United Kingdom']},
#    'phone': '+442034413465',
#    'display_phone': '+44 20 3441 3465',
#    'distance': 11488.023670777351},
#   {'id': 'jc3pYQz8TpkhlPcDEFqrlQ',
#    'alias': 'rossodisera-london',
#    'name': 'Rossodisera',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pnFLDXnf7on4-Czmjak6Ug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rossodisera-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5149, 'longitude': -0.126723},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '5 Monmouth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Monmouth Street',
#      'London WC2H 9DA',
#      'United Kingdom']},
#    'phone': '+442072403683',
#    'display_phone': '+44 20 7240 3683',
#    'distance': 677.8606968622349},
#   {'id': '-B8tZu-ysXG8fBkcRKzQyg',
#    'alias': 'guiseppes-london-2',
#    'name': 'Guiseppes',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PkWKn3x7cRpldRaDXpfebA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/guiseppes-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5048012364929,
#     'longitude': -0.0897637296226026},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '47-49 Borough High Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 1NB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47-49 Borough High Street',
#      'London SE1 1NB',
#      'United Kingdom']},
#    'phone': '+442074073451',
#    'display_phone': '+44 20 7407 3451',
#    'distance': 3319.2979090534636},
#   {'id': 'ZgFDci1CibiNsG7TXV5jlQ',
#    'alias': 'caraffini-restaurant-london',
#    'name': 'Caraffini Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FqqFAzYTuao7XPFq4zGU1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caraffini-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4903601471077,
#     'longitude': -0.156774507743243},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61-63 Lower Sloane Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 8DH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61-63 Lower Sloane Street',
#      'London SW1W 8DH',
#      'United Kingdom']},
#    'phone': '+442072590235',
#    'display_phone': '+44 20 7259 0235',
#    'distance': 2884.8372369221934},
#   {'id': '-fs2TmSWOGbreFNugeHmIA',
#    'alias': 'da-mario-italian-restaurant-london-3',
#    'name': 'Da Mario Italian Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/roJgVHev0yFF1vo2sySKlg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-mario-italian-restaurant-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515028, 'longitude': -0.125723},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '63 Endell Street',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63 Endell Street',
#      'Covent Garden',
#      'London WC2H 9AJ',
#      'United Kingdom']},
#    'phone': '+442072403632',
#    'display_phone': '+44 20 7240 3632',
#    'distance': 751.5015057500469},
#   {'id': 'Mh0jzKBDYqcNcYXC2fuzXg',
#    'alias': 'artusi-london',
#    'name': 'Artusi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jfpuZLKNoB7JiFDagfS3lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/artusi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4668722, 'longitude': -0.0724561},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '161 Bellenden Road',
#     'address2': 'Peckham',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE15 4DH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['161 Bellenden Road',
#      'Peckham',
#      'London SE15 4DH',
#      'United Kingdom']},
#    'phone': '+442033028200',
#    'display_phone': '+44 20 3302 8200',
#    'distance': 6741.655177752617},
#   {'id': 'NJ2hs8ln1lx0bMYkXmOqkA',
#    'alias': 'la-figa-london-2',
#    'name': 'La Figa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/E3NFAFSUCc-ZPB2i4mKZeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-figa-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.510135253223,
#     'longitude': -0.039447864202734},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '45 Narrow Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E14 8DW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Narrow Street',
#      'London E14 8DW',
#      'United Kingdom']},
#    'phone': '+442077900077',
#    'display_phone': '+44 20 7790 0077',
#    'distance': 6685.379796505414},
#   {'id': '_f4VU_D--cPFbS8cSp_xZA',
#    'alias': 'the-river-cafe-london-2',
#    'name': 'The River Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_QcVQ9hqQMlR5bMsJEDSzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-river-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 85,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4840302245571,
#     'longitude': -0.224279266409326},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'Thames Wharf Studio',
#     'address2': 'Rainville Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W6 9HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Thames Wharf Studio',
#      'Rainville Road',
#      'London W6 9HA',
#      'United Kingdom']},
#    'phone': '+442073864200',
#    'display_phone': '+44 20 7386 4200',
#    'distance': 6902.1825765671765},
#   {'id': 'DkPg-aeC3zxvhzqAtncTyQ',
#    'alias': 'amalfi-london',
#    'name': 'Amalfi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rRo6DYohpQFGWQxe7hPNJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amalfi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512989, 'longitude': -0.13147},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '29-31 Old Compton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 5JS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['29-31 Old Compton Street',
#      'London W1D 5JS',
#      'United Kingdom']},
#    'phone': '+442074377284',
#    'display_phone': '+44 20 7437 7284',
#    'distance': 311.80507278212116},
#   {'id': 'Nur6y3eP4Kq3tyrNMydWtA',
#    'alias': 'sartoria-london',
#    'name': 'Sartoria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FCjzu0cs43yTVMgkUHt3NA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sartoria-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511550208721,
#     'longitude': -0.14072940208433},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '20 Savile Row',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 3PR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Savile Row', 'London W1S 3PR', 'United Kingdom']},
#    'phone': '+442075347000',
#    'display_phone': '+44 20 7534 7000',
#    'distance': 359.9328177590157},
#   {'id': 'deV4Jb89QAgkyJqvu3aD_g',
#    'alias': 'mister-lasagna-soho',
#    'name': 'Mister Lasagna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KMamkYxXibea36bCPvQ5RA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mister-lasagna-soho?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.511999, 'longitude': -0.133687},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '53 Rupert Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Soho',
#     'zip_code': 'W1D 7PG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['53 Rupert Street', 'Soho W1D 7PG', 'United Kingdom']},
#    'phone': '+442077340064',
#    'display_phone': '+44 20 7734 0064',
#    'distance': 182.1731598880933},
#   {'id': 'AWE2pkiuC0dsr7OzmMPqZQ',
#    'alias': 'carluccios-marylebone-marylebone',
#    'name': "Carluccio's Marylebone",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qsFTaM6027NGdvy0U1siJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carluccios-marylebone-marylebone?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.520736, 'longitude': -0.1525937},
#    'transactions': [],
#    'location': {'address1': '7-9 Paddington Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Marylebone',
#     'zip_code': 'W1U',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7-9 Paddington Street',
#      'Marylebone W1U',
#      'United Kingdom']},
#    'phone': '+442074864150',
#    'display_phone': '+44 20 7486 4150',
#    'distance': 1448.1509662760536},
#   {'id': 'fDI1GsQUp6wg-SN6q3YVsw',
#    'alias': 'trullo-london',
#    'name': 'Trullo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/H2q53AjEFc27tZwWsW96aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trullo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5462962, 'longitude': -0.1012203},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "300 St Paul's Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 2LH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["300 St Paul's Road",
#      'London N1 2LH',
#      'United Kingdom']},
#    'phone': '+442072262733',
#    'display_phone': '+44 20 7226 2733',
#    'distance': 4429.100236027409},
#   {'id': 'RqAZPVvX8HtwlznZeEDqIQ',
#    'alias': 'santi-restaurant-pizzeria-london',
#    'name': 'Santi Restaurant Pizzeria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9OgoD9S3F_5daKM3uzM3Sg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/santi-restaurant-pizzeria-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.540903, 'longitude': -0.001207},
#    'transactions': [],
#    'location': {'address1': '42-45 Victory Parade',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E15 2ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42-45 Victory Parade',
#      'London E15 2ER',
#      'United Kingdom']},
#    'phone': '+442085552013',
#    'display_phone': '+44 20 8555 2013',
#    'distance': 9640.089602792246},
#   {'id': '_TZIH7rF_uoRT5roOHtYBw',
#    'alias': 'il-baretto-london',
#    'name': 'Il Baretto',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3gvaEAcvseTtGCPXIWexnQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-baretto-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5182326, 'longitude': -0.1543056},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '43 Blandford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 7HF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['43 Blandford Street',
#      'London W1U 7HF',
#      'United Kingdom']},
#    'phone': '+442074867340',
#    'display_phone': '+44 20 7486 7340',
#    'distance': 1404.4248264636958},
#   {'id': 'EULk_3fHxc_PlCLEK8SNDw',
#    'alias': 'rosso-london',
#    'name': 'Rosso',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QLXYsIj38WAqLlYFtBVeIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rosso-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wineries', 'title': 'Wineries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4985482071032,
#     'longitude': -0.201135836541653},
#    'transactions': [],
#    'location': {'address1': '280 Kensington High Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W8 6ND',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['280 Kensington High Street',
#      'London W8 6ND',
#      'United Kingdom']},
#    'phone': '+447384595191',
#    'display_phone': '+44 7384 595191',
#    'distance': 4782.784119377115},
#   {'id': 'hfvXCRJR_-5-oPrX_cAJ1A',
#    'alias': 'bottega-prelibato-london',
#    'name': 'Bottega Prelibato',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TCiJJQ6y48_hmNd1mw_qig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bottega-prelibato-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.52612, 'longitude': -0.081457},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '45 Rivington Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 3QB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Rivington Street',
#      'London EC2A 3QB',
#      'United Kingdom']},
#    'phone': '+442077394995',
#    'display_phone': '+44 20 7739 4995',
#    'distance': 4051.921125300116},
#   {'id': 'YX0-5x8jJNKQlxtRGX66rA',
#    'alias': 'little-sardegna-london',
#    'name': 'Little Sardegna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V_zp6MG2iWDTnvn3KrCawg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-sardegna-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5602062, 'longitude': -0.0987249},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '170 Blackstock Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N5 1HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['170 Blackstock Road',
#      'London N5 1HA',
#      'United Kingdom']},
#    'phone': '+442073544500',
#    'display_phone': '+44 20 7354 4500',
#    'distance': 5857.51892837245}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                     Restaurant     Type Price Rating                Address  \
# 0              Spaghetti House  Italian    ££      4         74 Duke Street
# 1                   La Pastaia  Italian    ££    3.5  63 Old Compton Street
# 2  Da'Paolo Italian Restaurant  Italian   £££      4      3 Charlotte Place
# 3              Spaghetti House  Italian    ££      4    47 Bryanston Street
# 4                    Forza Win  Italian                            Unit 4 1
#
#          Lat       Lng                                                url  \
# 0  51.513400 -0.151205  https://www.yelp.com/biz/spaghetti-house-londo...
# 1  51.512463 -0.132890  https://www.yelp.com/biz/la-pastaia-london?adj...
# 2  51.518911 -0.136207  https://www.yelp.com/biz/dapaolo-italian-resta...
# 3  51.514011 -0.159620  https://www.yelp.com/biz/spaghetti-house-londo...
# 4  51.469862 -0.065642
#
#                        ID
# 0  NSFaY9UeEUqie5Vh0RpKpA
# 1  UOMGToX1X1XqxcoqcLf8Pw
# 2  6swPe7Trae-ifxoSRAEFNg
# 3  pSyUFW1a9bs9LJshoS7rzw
# 4

# %%
#4th set of 50 records 151-200
lndr_params4 = {"term":"Italian","location":"London","limit":50,"offset":151}
lndr_response4 = requests.get(search_api_url, headers=headers, params=lndr_params4)
lndr4 = lndr_response4.json()
display(lndr4)
#print(lndr_response4.url)
#print(lndr_response4.status_code)
# Out:
# {'businesses': [{'id': 'Mc68-14kLxXdNKUBXEU5YA',
#    'alias': 'bellini-london-3',
#    'name': 'Bellini',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/axz1D7VpI_9NQUYoijpdjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bellini-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.377991, 'longitude': -0.2401327},
#    'transactions': [],
#    'location': {'address1': '70 Central Road',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'KT4 8HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['70 Central Road',
#      'London KT4 8HX',
#      'United Kingdom']},
#    'phone': '+442083350888',
#    'display_phone': '+44 20 8335 0888',
#    'distance': 16641.685209546366},
#   {'id': '8cQ-_O9O77--IwkleM0IeA',
#    'alias': 'caravaggio-london-2',
#    'name': 'Caravaggio',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/v-KhP9yA2LhKvMc-rlHqfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caravaggio-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4739748, 'longitude': -0.0896303},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '47 Camberwell Church Street',
#     'address2': 'Camberwell',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE5 8TR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Camberwell Church Street',
#      'Camberwell',
#      'London SE5 8TR',
#      'United Kingdom']},
#    'phone': '+442072071612',
#    'display_phone': '+44 20 7207 1612',
#    'distance': 5398.027219094823},
#   {'id': 'a69Vxx4dyAv0ZfXWv40mMw',
#    'alias': 'san-marco-london',
#    'name': 'San Marco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5VOYe4QaMXpw-H7fai1vYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/san-marco-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.595617, 'longitude': -0.0713621},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Bruce Grove',
#     'address2': 'Tottenham',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N17 6QY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Bruce Grove',
#      'Tottenham',
#      'London N17 6QY',
#      'United Kingdom']},
#    'phone': '+442088089494',
#    'display_phone': '+44 20 8808 9494',
#    'distance': 10231.016563583753},
#   {'id': 'j5N5Foo455q3yYL62TMQ7A',
#    'alias': '2-veneti-london',
#    'name': '2 Veneti',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7cuh-F0NTlYVFxcKMJovIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/2-veneti-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.516872, 'longitude': -0.146676},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '8-10 Wigmore Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 2RD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8-10 Wigmore Street',
#      'London W1U 2RD',
#      'United Kingdom']},
#    'phone': '+442076370789',
#    'display_phone': '+44 20 7637 0789',
#    'distance': 869.0706560948065},
#   {'id': '4wQBd6YfN5kJR8XESFu7Zg',
#    'alias': 'margot-london-4',
#    'name': 'Margot',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nlacoo-JUmaE4HdJJBDQJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/margot-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5147099025643,
#     'longitude': -0.121719541257562},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '45 Great Queen Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Great Queen Street',
#      'London WC2B 5AA',
#      'United Kingdom']},
#    'phone': '+442034094777',
#    'display_phone': '+44 20 3409 4777',
#    'distance': 1006.9483109551111},
#   {'id': '8bw0q8dfnQHdgLuncrdNgg',
#    'alias': 'fucina-london',
#    'name': 'Fucina',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GUdUk0pBd8LcQHVFlcRAUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fucina-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5206317540388,
#     'longitude': -0.15546926141886},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '26 Paddington Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1U 5QY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Paddington Street',
#      'London W1U 5QY',
#      'United Kingdom']},
#    'phone': '+442070584444',
#    'display_phone': '+44 20 7058 4444',
#    'distance': 1604.5700401773151},
#   {'id': 'UuC2D19b8ZElkzBHaccgSQ',
#    'alias': 'la-piadina-london',
#    'name': 'La Piadina',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ibyoJ2rtl7ETOeD2EWcsJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-piadina-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.520237, 'longitude': -0.073113},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "The Old Truman Brewery Ely's Yard",
#     'address2': 'Hanbury Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6QR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["The Old Truman Brewery Ely's Yard",
#      'Hanbury Street',
#      'London E1 6QR',
#      'United Kingdom']},
#    'phone': '+447943985066',
#    'display_phone': '+44 7943 985066',
#    'distance': 4429.574249063799},
#   {'id': 'YLJJBPFIUcHqmSTcVR3ioQ',
#    'alias': 'dante-london',
#    'name': 'Dante',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hAVAENLMnrVZRzHrx-MX8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dante-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.510229, 'longitude': -0.2870656},
#    'transactions': [],
#    'location': {'address1': 'Uxbridge Road',
#     'address2': 'Station Parade',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W5 3LD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Uxbridge Road',
#      'Station Parade',
#      'London W5 3LD',
#      'United Kingdom']},
#    'phone': '+442089922727',
#    'display_phone': '+44 20 8992 2727',
#    'distance': 10461.24582497963},
#   {'id': 'NRoSewv4zWHGib-XAvFcTA',
#    'alias': 'alforno-restaurant-london',
#    'name': 'Alforno Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/H0Kh_NtqL9gcD1YTppZkvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alforno-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4197771, 'longitude': -0.2021152},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2a Kings Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW19 8QN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2a Kings Road', 'London SW19 8QN', 'United Kingdom']},
#    'phone': '+442085405710',
#    'display_phone': '+44 20 8540 5710',
#    'distance': 11299.976357410667},
#   {'id': 'vCrWrTFWlL0U9EaDR_6bzQ',
#    'alias': 'sweet-basil-london-2',
#    'name': 'Sweet Basil',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Zc-G7dbSxGBHvgFkMf091g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweet-basil-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.519186, 'longitude': -0.075939},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '65 Brushfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['65 Brushfield Street',
#      'London E1 6AA',
#      'United Kingdom']},
#    'phone': '+442073753484',
#    'display_phone': '+44 20 7375 3484',
#    'distance': 4235.6959067141615},
#   {'id': 'LMKwOJL1JSP-aP6hC_B8zw',
#    'alias': 'mediterraneo-london',
#    'name': 'Mediterraneo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Uf3G3F1rqjGDmYTJ9-d19w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mediterraneo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51557644707, 'longitude': -0.20600306515706},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '37 Kensington Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['37 Kensington Park Road',
#      'London W11 2EU',
#      'United Kingdom']},
#    'phone': '+442077923131',
#    'display_phone': '+44 20 7792 3131',
#    'distance': 4856.7590401169255},
#   {'id': 'OeDB8VlMwdxHFYTaaub8ww',
#    'alias': 'zzetta-soul-fired-pizza-london-2',
#    'name': 'Zzetta Soul Fired Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EBOAPZQOlhQz581XIe991Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zzetta-soul-fired-pizza-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5170268476288,
#     'longitude': 0.0112434602713165},
#    'transactions': [],
#    'location': {'address1': '110 Barking Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E16 1EN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['110 Barking Road',
#      'London E16 1EN',
#      'United Kingdom']},
#    'phone': '+442039047074',
#    'display_phone': '+44 20 3904 7074',
#    'distance': 10196.507658171702},
#   {'id': 'vyI7OOJ9O0g4n-1a2K76fw',
#    'alias': 'osteria-ambrosia-london',
#    'name': 'Osteria Ambrosia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C3XjBegNSwWjiqAgLnWlog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osteria-ambrosia-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5148440635957,
#     'longitude': -0.150470774015474},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '48-50 St Johns',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW11 1PR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['48-50 St Johns',
#      'London SW11 1PR',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1028.9571314781385},
#   {'id': 'ZBpAqLA9KrAgzrIxS8DpIg',
#    'alias': 'six-soho-london',
#    'name': 'SIX Soho',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/six-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5142365, 'longitude': -0.1310147},
#    'transactions': [],
#    'location': {'address1': '6 Greek Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 4NX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Greek Street', 'London W1D 4NX', 'United Kingdom']},
#    'phone': '+442077343888',
#    'display_phone': '+44 20 7734 3888',
#    'distance': 375.7391788189564},
#   {'id': 'dJPmL1Y20ltLWrDIVxP6VA',
#    'alias': 'figli-del-vesuvio-london',
#    'name': 'Figli del Vesuvio',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/noZvEpZVsVUys6stub7R9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/figli-del-vesuvio-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4335656, 'longitude': -0.1849861},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '658 Garratt Lane',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW17 0NP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['658 Garratt Lane',
#      'London SW17 0NP',
#      'United Kingdom']},
#    'phone': '+442036091118',
#    'display_phone': '+44 20 3609 1118',
#    'distance': 9445.939425976489},
#   {'id': 'AWxLccDtMO8XAk92Ei3_iQ',
#    'alias': 'o-ver-london',
#    'name': 'O Ver',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0LbAC1rgjF16kSq6nnlVzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/o-ver-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.504995, 'longitude': -0.094621},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '44-46 Southwark Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 1UN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['44-46 Southwark Street',
#      'London SE1 1UN',
#      'United Kingdom']},
#    'phone': '+442073789933',
#    'display_phone': '+44 20 7378 9933',
#    'distance': 3016.5229280619005},
#   {'id': '2rFS1v5qN_9ShfBeTbFcJA',
#    'alias': 'bar-remo-london-2',
#    'name': 'Bar Remo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/P3WDXV2vB5DVYM0oWOyqLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-remo-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5146635, 'longitude': -0.1425439},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Princes Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 2LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Princes Street',
#      'London W1B 2LB',
#      'United Kingdom']},
#    'phone': '+442076291715',
#    'display_phone': '+44 20 7629 1715',
#    'distance': 494.3602710557327},
#   {'id': 'iASQRKQiElbXx_6PjHzpZg',
#    'alias': 'limoncello-london-2',
#    'name': 'limoncello',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LKe5IL2H_fT7jOUsf4M3xQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/limoncello-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.430663, 'longitude': 0.083451},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '8-9 Marechal Niel Parade',
#     'address2': 'Main Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'DA14 6QF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8-9 Marechal Niel Parade',
#      'Main Road',
#      'London DA14 6QF',
#      'United Kingdom']},
#    'phone': '+442083080333',
#    'display_phone': '+44 20 8308 0333',
#    'distance': 17756.831747353357},
#   {'id': '0BDuohnoATEnz1c_5jxIdg',
#    'alias': 'gastronomica-london-4',
#    'name': 'Gastronomica',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gA6un8X7AD89G4vkmq7cTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gastronomica-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'foodstands', 'title': 'Food Stands'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.505428, 'longitude': -0.090252},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Borough Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9AL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Borough Market', 'London SE1 9AL', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3233.288662828306},
#   {'id': 'VomGBPMQALZLfKHCI8_jTg',
#    'alias': 'the-swan-london-6',
#    'name': 'The Swan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CjuYlM6M82fHy8xsBDw0Ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-swan-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 115,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511656071976,
#     'longitude': -0.17697194507093},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '66 Bayswater Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Bayswater Road',
#      'London W2 3PH',
#      'United Kingdom']},
#    'phone': '+442072625204',
#    'display_phone': '+44 20 7262 5204',
#    'distance': 2841.418230660763},
#   {'id': 'FGLai69prYJwDfH6NHUrdQ',
#    'alias': 'in-parma-by-food-roots-london',
#    'name': 'In Parma by Food Roots',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6M2dKPxwrdZP8RFVL8y_oA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/in-parma-by-food-roots-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.518877, 'longitude': -0.135842},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10 Charlotte Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 1SH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Charlotte Place',
#      'London W1T 1SH',
#      'United Kingdom']},
#    'phone': '+442081274277',
#    'display_phone': '+44 20 8127 4277',
#    'distance': 670.6919753074222},
#   {'id': 'hJX3rWU4-h3GmHZCK7NLkw',
#    'alias': 'il-sugo-london',
#    'name': 'Il Sugo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ijfMRVXHUeNlLkIg5DlbCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-sugo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5375442, 'longitude': -0.1403737},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '1-3 Pratt Street',
#     'address2': 'Camden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 0AE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1-3 Pratt Street',
#      'Camden',
#      'London NW1 0AE',
#      'United Kingdom']},
#    'phone': '+442072673575',
#    'display_phone': '+44 20 7267 3575',
#    'distance': 2764.424587055545},
#   {'id': '0OpfzXpQYQuc94ZG-Ep52A',
#    'alias': 'il-piccolo-diavolo-london',
#    'name': 'Il Piccolo Diavolo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/r7rFgq05UTNmFRZdz3AXNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-piccolo-diavolo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5707641931904,
#     'longitude': -0.116558184680198},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Crouch Hill',
#     'address2': 'Crouch Hill',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N4 4AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Crouch Hill',
#      'Crouch Hill',
#      'London N4 4AP',
#      'United Kingdom']},
#    'phone': '+442072723302',
#    'display_phone': '+44 20 7272 3302',
#    'distance': 6579.572839308078},
#   {'id': 'uubqxLWVSXC_zOnrI2yHoQ',
#    'alias': 'tettos-london',
#    'name': "Tetto's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VpNl_uj2zcFgpqCFCp3jfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tettos-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.559997, 'longitude': -0.092056},
#    'transactions': [],
#    'location': {'address1': '313 Highbury New Park',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N5 2LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['313 Highbury New Park',
#      'London N5 2LB',
#      'United Kingdom']},
#    'phone': '+442075027812',
#    'display_phone': '+44 20 7502 7812',
#    'distance': 6059.704723326016},
#   {'id': '3AqrHgpIbcMXj0q-p_oPzg',
#    'alias': 'homeslice-neals-yard-london',
#    'name': "Homeslice Neal's Yard",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2Fv58EUzsVHVhAjM00K69g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/homeslice-neals-yard-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 228,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5144380966574,
#     'longitude': -0.126426543278564},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "13 Neal's Yard",
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["13 Neal's Yard",
#      'Covent Garden',
#      'London WC2H 9DP',
#      'United Kingdom']},
#    'phone': '+442031517488',
#    'display_phone': '+44 20 3151 7488',
#    'distance': 683.0755682796743},
#   {'id': 'bpPc86UDVamkaZRmzkz_LQ',
#    'alias': 'luna-nuova-london',
#    'name': 'Luna Nuova',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/n1sfQLINahSHmtwLEZrsMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luna-nuova-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4764709472656,
#     'longitude': -0.203929007053375},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '773 Fulham Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 5HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['773 Fulham Road',
#      'London SW6 5HA',
#      'United Kingdom']},
#    'phone': '+442073719774',
#    'display_phone': '+44 20 7371 9774',
#    'distance': 6204.333934451122},
#   {'id': 'UaRbaw8qy8WR6AUTogv8lg',
#    'alias': 'cacciaris-london',
#    'name': "Cacciari's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/empo_c-ty5v4fvg_-yc3Sw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cacciaris-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4926107238041,
#     'longitude': -0.177413503541668},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '82 Old Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3LQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['82 Old Brompton Road',
#      'London SW7 3LQ',
#      'United Kingdom']},
#    'phone': '+442070529046',
#    'display_phone': '+44 20 7052 9046',
#    'distance': 3645.793771136073},
#   {'id': 'TMM6S0k2TBiPJcLiQziQ0Q',
#    'alias': 'carousel-london-4',
#    'name': 'Carousel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YVqJ9JSV0gBa0vnQ5zMwgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carousel-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5180645568365,
#     'longitude': -0.156335396272258},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '71 Blandford St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 8AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['71 Blandford St',
#      'London W1U 8AB',
#      'United Kingdom']},
#    'phone': '+442074875564',
#    'display_phone': '+44 20 7487 5564',
#    'distance': 1525.3692853051132},
#   {'id': 'YDiA-oB2_8aTULrZTIW18w',
#    'alias': 'osteria-tufo-london',
#    'name': 'Osteria Tufo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-36ufj8lLXfD6vzWbXNTkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osteria-tufo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5662404, 'longitude': -0.1106195},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '67 Fonthill Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N4 3HZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['67 Fonthill Road',
#      'London N4 3HZ',
#      'United Kingdom']},
#    'phone': '+442072722911',
#    'display_phone': '+44 20 7272 2911',
#    'distance': 6191.476502681193},
#   {'id': 'Mw9p4SiJ5ZY1HV0sp3CMFg',
#    'alias': 'enoteca-da-luca-london-4',
#    'name': 'Enoteca Da Luca',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7S4mGCnSlH4Hnn2oD7BBUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/enoteca-da-luca-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.508743, 'longitude': -0.1446645},
#    'transactions': [],
#    'location': {'address1': '11-12 Lansdowne Row',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 6DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11-12 Lansdowne Row',
#      'London W1J 6DY',
#      'United Kingdom']},
#    'phone': '+442074999986',
#    'display_phone': '+44 20 7499 9986',
#    'distance': 755.185166248098},
#   {'id': 'w1TqrVGd_NzAwQzNVWslEw',
#    'alias': 'il-girasole-london-3',
#    'name': 'Il Girasole',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BfZHWS_CUPqawdcPVjwhRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-girasole-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4504059832827,
#     'longitude': -0.189856372855288},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '189 Garratt Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW18 4DR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['189 Garratt Lane',
#      'London SW18 4DR',
#      'United Kingdom']},
#    'phone': '+442088700931',
#    'display_phone': '+44 20 8870 0931',
#    'distance': 7881.678816924638},
#   {'id': 'V0TYCiwGmDTd2gYrtZctdw',
#    'alias': 'mio-restaurant-westminster',
#    'name': 'Mio Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Dqya3B0DcP1ZbgEc8luHgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mio-restaurant-westminster?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4966379350656,
#     'longitude': -0.133318678504111},
#    'transactions': [],
#    'location': {'address1': '58 Great Peter Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Westminster',
#     'zip_code': 'SW1P 2HD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['58 Great Peter Street',
#      'Westminster SW1P 2HD',
#      'United Kingdom']},
#    'phone': '+442072220058',
#    'display_phone': '+44 20 7222 0058',
#    'distance': 1810.3123946353346},
#   {'id': 'M0ZyBZWpw1ildLjs9VykHQ',
#    'alias': 'mangiabene-london',
#    'name': 'Mangiabene',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ipsacbRv0dW_5VMXVbmxaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mangiabene-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5335655, 'longitude': -0.1097374},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18 Chapel Market',
#     'address2': 'Islington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9EZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Chapel Market',
#      'Islington',
#      'London N1 9EZ',
#      'United Kingdom']},
#    'phone': '+442072782825',
#    'display_phone': '+44 20 7278 2825',
#    'distance': 2939.4537737404344},
#   {'id': 'K-K5Nj1TmLGx5JA0LR36Qg',
#    'alias': 'little-italy-soho',
#    'name': 'Little Italy',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Qanf9tQEnaJiv_0ScpomFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-italy-soho?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5134932, 'longitude': -0.1312247},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '21 Frith Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Soho',
#     'zip_code': 'W1D 4RN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21 Frith Street', 'Soho W1D 4RN', 'United Kingdom']},
#    'phone': '+442077344737',
#    'display_phone': '+44 20 7734 4737',
#    'distance': 333.80969232638284},
#   {'id': 'e44iE44q9KwTjdvNpg5iMw',
#    'alias': 'thats-amore-london',
#    'name': "That's Amore",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5mB_V75mWvjOyZMJxmvr_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thats-amore-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5795262, 'longitude': -0.1982346},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1031 Finchley Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW11 7ES',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1031 Finchley Rd',
#      'London NW11 7ES',
#      'United Kingdom']},
#    'phone': '+442083814636',
#    'display_phone': '+44 20 8381 4636',
#    'distance': 8575.470487666083},
#   {'id': '4nlC6KIWaNzQsUtiSmHiqw',
#    'alias': 'la-barca-ristorante-london',
#    'name': 'La Barca Ristorante',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ld8oeAVSzZJvnE8_u-dWPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-barca-ristorante-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5017621, 'longitude': -0.1109925},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '81 Lower Marsh',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['81 Lower Marsh', 'London SE1 7AB', 'United Kingdom']},
#    'phone': '+442072619221',
#    'display_phone': '+44 20 7261 9221',
#    'distance': 2122.8455537699774},
#   {'id': 'yHfKmtOcekcyWE9eyNmNmw',
#    'alias': 'bucci-restaurant-london',
#    'name': 'Bucci Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FXKsE8h7DhW9jPOiSZG_-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bucci-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4413043, 'longitude': -0.1544355},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '195 Balham High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW12 9BE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['195 Balham High Road',
#      'London SW12 9BE',
#      'United Kingdom']},
#    'phone': '+442086735459',
#    'display_phone': '+44 20 8673 5459',
#    'distance': 8030.270025637166},
#   {'id': 'liycbH19E5BKElTc-QkVeQ',
#    'alias': 'cafe-murano-london',
#    'name': 'Cafe Murano',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Xs9vQatMJNW2Vc7WIbTldw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-murano-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.507255, 'longitude': -0.139588},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '33 St James St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1A 1HD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['33 St James St',
#      'London SW1A 1HD',
#      'United Kingdom']},
#    'phone': '+442033715559',
#    'display_phone': '+44 20 3371 5559',
#    'distance': 676.4104940422342},
#   {'id': '7y-6yaVTFhXTbqIfnbvRQg',
#    'alias': 'enoteca-da-luca-london',
#    'name': 'Enoteca Da Luca',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ma4EzP5SrpXzQArVA5hFWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/enoteca-da-luca-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5155402, 'longitude': -0.090803},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '10 - 12 Basinghall Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2V 5BQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 - 12 Basinghall Street',
#      'London EC2V 5BQ',
#      'United Kingdom']},
#    'phone': '+442076002161',
#    'display_phone': '+44 20 7600 2161',
#    'distance': 3138.9627067624374},
#   {'id': 'W3bdBJQ_N1DEzA2R-WhYYQ',
#    'alias': 'pentolina-london',
#    'name': 'Pentolina',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9wsFXZ3BXzZLPCs2usDruw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pentolina-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4975128, 'longitude': -0.2174403},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '71 Blythe Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W14 0HP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['71 Blythe Road', 'London W14 0HP', 'United Kingdom']},
#    'phone': '+442030100091',
#    'display_phone': '+44 20 3010 0091',
#    'distance': 5889.425488297484},
#   {'id': 'QKuw4hAQvtFgrMl86msXaw',
#    'alias': 'la-fortuna-kensington-london',
#    'name': 'La Fortuna Kensington',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9Akb0lVwzKMswRog4qXzOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-fortuna-kensington-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.50392, 'longitude': -0.19189},
#    'transactions': [],
#    'location': {'address1': '32 Kensington Church Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['32 Kensington Church Street',
#      'London W8 4HA',
#      'United Kingdom']},
#    'phone': '+442079378752',
#    'display_phone': '+44 20 7937 8752',
#    'distance': 3996.307654268249},
#   {'id': 'NmFWljc8-TfLlW62zRZ2MA',
#    'alias': 'il-vicolo-london',
#    'name': 'Il Vicolo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OKorcaVjo1GSLPyPs7Fa5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-vicolo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5058047, 'longitude': -0.1375438},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '4 Crown Passage',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 6PP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Crown Passage',
#      'London SW1Y 6PP',
#      'United Kingdom']},
#    'phone': '+442078393960',
#    'display_phone': '+44 20 7839 3960',
#    'distance': 794.6739184290293},
#   {'id': 'drQAddUq7OjZJ4IlnnKCIQ',
#    'alias': 'rossella-london',
#    'name': 'Rossella',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iZhaIU1xy7iuu2-a6puefQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rossella-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.555179, 'longitude': -0.145481},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '103 Highgate Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW5 1TR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['103 Highgate Road',
#      'London NW5 1TR',
#      'United Kingdom']},
#    'phone': '+442072679797',
#    'display_phone': '+44 20 7267 9797',
#    'distance': 4733.9361224704535},
#   {'id': 'JnFwWjHzQAD72XBtudW9gw',
#    'alias': 'la-piazzetta-london',
#    'name': 'La Piazzetta',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/f7EWVuF8krAAkrqrSp2nKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-piazzetta-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5124246984168, 'longitude': -0.1263641},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "13 Neal's Yard",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["13 Neal's Yard",
#      'London WC2H 9DP',
#      'United Kingdom']},
#    'phone': '+442072401168',
#    'display_phone': '+44 20 7240 1168',
#    'distance': 665.3280478367622},
#   {'id': 'hf_Jnbwab8jJ96XyPWwbMw',
#    'alias': 'the-ivy-chelsea-garden-london',
#    'name': 'The Ivy Chelsea Garden',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/P_jrMo87FJNimNla8tTcbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ivy-chelsea-garden-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 72,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4871107, 'longitude': -0.1693342},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '195-197 Kings Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 5EQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['195-197 Kings Road',
#      'London SW3 5EQ',
#      'United Kingdom']},
#    'phone': '+442033010300',
#    'display_phone': '+44 20 3301 0300',
#    'distance': 3677.026440039353},
#   {'id': '0TXydyOD0MXkB6XbNKg1gw',
#    'alias': 'jamies-italian-piccadilly-london-2',
#    'name': "Jamie's Italian - Piccadilly",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UUC05hsqzl30xKJ4zhr4EQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jamies-italian-piccadilly-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 79,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5106598, 'longitude': -0.1353948},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '17-19 Denman Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 7HW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17-19 Denman Street',
#      'London W1D 7HW',
#      'United Kingdom']},
#    'phone': '+442033763391',
#    'display_phone': '+44 20 3376 3391',
#    'distance': 245.02416333594277},
#   {'id': '8yhxUKM8ONpr4yuQ1fW1UQ',
#    'alias': 'festa-sul-prato-london',
#    'name': 'Festa sul prato',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Bw58EIeAE6f5rjyilN-sNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/festa-sul-prato-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4826882176606,
#     'longitude': -0.0399787864415121},
#    'transactions': [],
#    'location': {'address1': '222 Trundleys Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE8 5JE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['222 Trundleys Road',
#      'London SE8 5JE',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 7441.687408536539},
#   {'id': 'HnKh1SD89JPH5aJu5Rwiqw',
#    'alias': 'melanzana-london',
#    'name': 'Melanzana',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DnpFD9wPMqCg956AkDmGBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/melanzana-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4753048743646,
#     'longitude': -0.174966304893474},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '140 Westbridge Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW11 3PF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['140 Westbridge Road',
#      'London SW11 3PF',
#      'United Kingdom']},
#    'phone': '+442072285420',
#    'display_phone': '+44 20 7228 5420',
#    'distance': 4970.84893567195},
#   {'id': '1IHOIVVkiHj1mEba43HYBQ',
#    'alias': 'da-corradi-london',
#    'name': 'Da Corradi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rNemidpFGVqkXRxs0IyRug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-corradi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.506741, 'longitude': -0.146323},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20-22 Shepherd Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 7QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20-22 Shepherd Market',
#      'London W1J 7QJ',
#      'United Kingdom']},
#    'phone': '+442074991742',
#    'display_phone': '+44 20 7499 1742',
#    'distance': 987.1192169466364},
#   {'id': 'r-40hpB7G8QmMbb6dxKIWQ',
#    'alias': 'fumo-london',
#    'name': 'Fumo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FUXHbfY-yuDKKty-JkjWQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fumo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 52,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5099474, 'longitude': -0.1269062},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "N37 St Martin's Lane",
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2N 4ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["N37 St Martin's Lane",
#      'London WC2N 4ER',
#      'United Kingdom']},
#    'phone': '+442037780430',
#    'display_phone': '+44 20 3778 0430',
#    'distance': 703.8013663465491}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#    Restaurant          Type Price Rating                      Address  \
# 0     Bellini       Italian                           70 Central Road
# 1  Caravaggio  Coffee & Tea    ££    4.5  47 Camberwell Church Street
# 2   San Marco       Italian    ££    4.5                  Bruce Grove
# 3    2 Veneti       Italian   £££    4.5          8-10 Wigmore Street
# 4      Margot       Italian   £££    4.5        45 Great Queen Street
#
#          Lat       Lng                                                url  \
# 0  51.377991 -0.240133
# 1  51.473975 -0.089630  https://www.yelp.com/biz/caravaggio-london-2?a...
# 2  51.595617 -0.071362  https://www.yelp.com/biz/san-marco-london?adju...
# 3  51.516872 -0.146676  https://www.yelp.com/biz/2-veneti-london?adjus...
# 4  51.514710 -0.121720  https://www.yelp.com/biz/margot-london-4?adjus...
#
#                        ID
# 0
# 1  8cQ-_O9O77--IwkleM0IeA
# 2  a69Vxx4dyAv0ZfXWv40mMw
# 3  j5N5Foo455q3yYL62TMQ7A
# 4  4wQBd6YfN5kJR8XESFu7Zg

# %%
london_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
london_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_restaurants_df = london_restaurants_df[column_order]
london_restaurants_df = london_restaurants_df.sort_values(["Type"], ascending=True)
london_restaurants_df = london_restaurants_df.reset_index(drop=True)
london_restaurants_df
# Out:
#                                  Restaurant                   Type Rating  \
# 0                                Coppa Club                   Bars    3.5
# 1                    The Ivy Chelsea Garden                British      4
# 2                                 Scarpetta                  Cafes
# 3                        The Gold of Naples              Cafeteria
# 4                              La Piazzetta           Coffee & Tea      5
# 5                         Bottega Prelibato           Coffee & Tea      4
# 6                                Caravaggio           Coffee & Tea    4.5
# 7                              Gastronomica            Food Stands    4.5
# 8                                La Bottega                Italian
# 9                                   Bancone                Italian
# 10                                  La Luna                Italian    4.5
# 11                                   Murano                Italian      4
# 12                              Terra Rossa                Italian
# 13                                    Obicà                Italian    3.5
# 14                                  Padella                Italian    4.5
# 15                       Bocconi Ristorante                Italian
# 16                              Rossodisera                Italian      4
# 17                                Guiseppes                Italian      3
# 18                     Caraffini Restaurant                Italian    4.5
# 19              Da Mario Italian Restaurant                Italian      4
# 20                                   Artusi                Italian    4.5
# 21                                  La Figa                Italian      4
# 22                           The River Cafe                Italian      4
# 23                                   Apulia                Italian      4
# 24                            La Bella Vita                Italian
# 25                                   Locale                Italian      4
# 26                                 The Bite                Italian    4.5
# 27                                 Olivelli                Italian      4
# 28                           Anima D'italia                Italian
# 29                          Spaghetti House                Italian      4
# ..                                      ...                    ...    ...
# 170                    Albertini Restaurant                  Pizza    4.5
# 171                       L'antica Pizzeria                  Pizza    3.5
# 172                             Pizza Union                  Pizza    4.5
# 173                             Il Bordello                  Pizza    4.5
# 174                          Mio Restaurant                  Pizza
# 175                            Franco Manca                  Pizza    4.5
# 176                                Arancina                  Pizza      4
# 177                          La Pappardella                  Pizza      4
# 178                                 Purezza                  Pizza
# 179                      Sartori Restaurant                  Pizza      4
# 180               Santi Restaurant Pizzeria                  Pizza
# 181                           Bravi Ragazzi                  Pizza    4.5
# 182                          Pizza Pilgrims                  Pizza      4
# 183                              Mamma Mia                   Pizza    4.5
# 184                 Zzetta Soul Fired Pizza                  Pizza
# 185                   Homeslice Neal's Yard                  Pizza    4.5
# 186                                    ICCo                  Pizza      4
# 187                           La Tavernetta                  Pizza
# 188                            Franco Manca                  Pizza    4.5
# 189          Cassio Restaurant and Pizzeria                  Pizza
# 190                                   O Ver                  Pizza    4.5
# 191                       Figli del Vesuvio                  Pizza      5
# 192  Alla Salute! Trattoria Pizzeria Social                  Pizza
# 193                                The Swan                   Pubs      4
# 194               Burro E Salvia Pastificio         Specialty Food    4.5
# 195                                 Tetto's            Steakhouses
# 196                        Morso Restaurant     Tapas/Small Plates
# 197                                Carousel  Venues & Event Spaces    4.5
# 198                         Trattoria Verdi  Venues & Event Spaces      4
# 199                         Enoteca Da Luca              Wine Bars
#
#     Price                      Address        Lat       Lng  \
# 0      ££       4 St Paul's Churchyard  51.513446 -0.100213
# 1     £££           195-197 Kings Road  51.487111 -0.169334
# 2                     20 Canada Square  51.504383 -0.016906
# 3                134 Hither Green Lane  51.453286 -0.007870
# 4      ££               13 Neal's Yard  51.512425 -0.126364
# 5      ££          45 Rivington Street  51.526120 -0.081457
# 6      ££  47 Camberwell Church Street  51.473975 -0.089630
# 7       £               Borough Market  51.505428 -0.090252
# 8                      20 Ryder Street  51.507230 -0.138595
# 9                     39 William IV St  51.509570 -0.126420
# 10     ££            380 Walworth Road  51.484635 -0.094058
# 11   ££££              20 Queen Street  51.507034 -0.147277
# 12                    139 Upper Street  51.539497 -0.102688
# 13     ££             20 Poland Street  51.514938 -0.137131
# 14     ££           6 Southwark Street  51.505145 -0.089952
# 15                     5 Goldhawk Road  51.503018 -0.223436
# 16      £            5 Monmouth Street  51.514900 -0.126723
# 17      £    47-49 Borough High Street  51.504801 -0.089764
# 18     ££    61-63 Lower Sloane Street  51.490360 -0.156775
# 19     ££             63 Endell Street  51.515028 -0.125723
# 20    £££           161 Bellenden Road  51.466872 -0.072456
# 21     ££             45 Narrow Street  51.510135 -0.039448
# 22   ££££          Thames Wharf Studio  51.484030 -0.224279
# 23     ££                 50 Long Lane  51.519009 -0.100359
# 24                       853 High Road  51.569700  0.013050
# 25     ££                  County Hall  51.501479 -0.118008
# 26     ££           533 Kingsland Road  51.545717 -0.075843
# 27     ££              35 Store Street  51.519860 -0.131172
# 28                   114 Mile End Road  51.520435 -0.051975
# 29     ££     9 Kensington High Street  51.502248 -0.187966
# ..    ...                          ...        ...       ...
# 170     £         16-20 Chalton Street  51.529030 -0.129214
# 171    ££              66 Heath Street  51.557378 -0.178169
# 172     £   246 - 250 Pentonville Road  51.531052 -0.119832
# 173    ££  Unit G01 Metropolitan Wharf  51.506545 -0.052761
# 174              58 Great Peter Street  51.496638 -0.133319
# 175    ££         91 Old Brompton Road  51.492464 -0.177208
# 176    ££            19 Pembridge Road  51.509994 -0.197431
# 177    ££        253 Old Brompton Road  51.489143 -0.190697
# 178                         43 Parkway  51.538113 -0.144305
# 179    ££      15 Great Newport Street  51.511791 -0.128004
# 180               42-45 Victory Parade  51.540903 -0.001207
# 181     £              2A Sunnyhill Rd  51.430542 -0.129238
# 182    ££               11 Dean Street  51.514947 -0.133240
# 183    ££                 36 Queensway  51.511551 -0.187024
# 184                   110 Barking Road  51.517027  0.011243
# 185    ££               13 Neal's Yard  51.514438 -0.126427
# 186     £             46 Goodge Street  51.519545 -0.136045
# 187            148 Camberwell New Road  51.478119 -0.103468
# 188    ££            51 Berwick Street  51.515564 -0.136363
# 189                32 Tooting Bec Road  51.435059 -0.157596
# 190    ££       44-46 Southwark Street  51.504995 -0.094621
# 191    ££             658 Garratt Lane  51.433566 -0.184986
# 192            Unit 2 Indiana Building  51.472905 -0.021550
# 193    ££            66 Bayswater Road  51.511656 -0.176972
# 194    ££          52 Redchurch Street  51.524296 -0.074688
# 195              313 Highbury New Park  51.559997 -0.092056
# 196                  130 Boundary Road  51.537089 -0.185832
# 197    ££              71 Blandford St  51.518065 -0.156335
# 198    ££          110 Southampton Row  51.520417 -0.122489
# 199                11-12 Lansdowne Row  51.508743 -0.144665
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/coppa-club-london?adj...  _Q3CiOo0gWTD8nD_US_9CA
# 1    https://www.yelp.com/biz/the-ivy-chelsea-garde...  hf_Jnbwab8jJ96XyPWwbMw
# 2
# 3
# 4    https://www.yelp.com/biz/la-piazzetta-london?a...  JnFwWjHzQAD72XBtudW9gw
# 5    https://www.yelp.com/biz/bottega-prelibato-lon...  hfvXCRJR_-5-oPrX_cAJ1A
# 6    https://www.yelp.com/biz/caravaggio-london-2?a...  8cQ-_O9O77--IwkleM0IeA
# 7    https://www.yelp.com/biz/gastronomica-london-4...  0BDuohnoATEnz1c_5jxIdg
# 8
# 9
# 10   https://www.yelp.com/biz/la-luna-london-2?adju...  JcpYVXTIMNFo7vl1De1W0g
# 11   https://www.yelp.com/biz/murano-london?adjust_...  IBGiXhPZsnHB0Uls03DiPA
# 12
# 13   https://www.yelp.com/biz/obic%C3%A0-london-4?a...  aAzCPzQkOcBUBnqd3-qIuw
# 14   https://www.yelp.com/biz/padella-london-3?adju...  KzYd2EaFvmu63wqTIektSA
# 15
# 16   https://www.yelp.com/biz/rossodisera-london?ad...  jc3pYQz8TpkhlPcDEFqrlQ
# 17   https://www.yelp.com/biz/guiseppes-london-2?ad...  -B8tZu-ysXG8fBkcRKzQyg
# 18   https://www.yelp.com/biz/caraffini-restaurant-...  ZgFDci1CibiNsG7TXV5jlQ
# 19   https://www.yelp.com/biz/da-mario-italian-rest...  -fs2TmSWOGbreFNugeHmIA
# 20   https://www.yelp.com/biz/artusi-london?adjust_...  Mh0jzKBDYqcNcYXC2fuzXg
# 21   https://www.yelp.com/biz/la-figa-london-2?adju...  NJ2hs8ln1lx0bMYkXmOqkA
# 22   https://www.yelp.com/biz/the-river-cafe-london...  _f4VU_D--cPFbS8cSp_xZA
# 23   https://www.yelp.com/biz/apulia-london?adjust_...  2pDU7LE3gTpDWGsoKuGwMA
# 24
# 25   https://www.yelp.com/biz/locale-london-6?adjus...  XNj3z-EVv6o58E19C2spZg
# 26   https://www.yelp.com/biz/the-bite-london-3?adj...  xAzcGEDsUmrXpJgdnLF2wQ
# 27   https://www.yelp.com/biz/olivelli-london-6?adj...  vnC7idK5GtzenRZiFdkAew
# 28
# 29   https://www.yelp.com/biz/spaghetti-house-londo...  gpQUlJ0dQyZexifTOoMF1Q
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/albertini-restaurant-...  FXSGVcfBDYytOHHyLsoCCg
# 171  https://www.yelp.com/biz/l-antica-pizzeria-lon...  W5qDRErkfwRcRNj6bX_WMg
# 172  https://www.yelp.com/biz/pizza-union-london-7?...  CQsUI0K8XOAwSR4gN6l55Q
# 173  https://www.yelp.com/biz/il-bordello-london?ad...  nUAkhKSEKG3NZl4vinNMjQ
# 174
# 175  https://www.yelp.com/biz/franco-manca-london-1...  UaKN9OHMOz0J0gcbeI4k7Q
# 176  https://www.yelp.com/biz/arancina-london-2?adj...  3JAZzpV_cfNtQDmkwjOvKw
# 177  https://www.yelp.com/biz/la-pappardella-london...  TIfha7KOWgLRhN8935g6Iw
# 178
# 179  https://www.yelp.com/biz/sartori-restaurant-lo...  VpXOD3pTsTMGy7cqtpNuNA
# 180
# 181  https://www.yelp.com/biz/bravi-ragazzi-london?...  wvJVJRmgJYpWNFt5GZmtzA
# 182  https://www.yelp.com/biz/pizza-pilgrims-london...  w-kpar4Y81AR4L53xeHtjw
# 183  https://www.yelp.com/biz/mamma-mia-london-9?ad...  cxRk4T-Z3q_mekEWj6l2Dw
# 184
# 185  https://www.yelp.com/biz/homeslice-neals-yard-...  3AqrHgpIbcMXj0q-p_oPzg
# 186  https://www.yelp.com/biz/icco-london-2?adjust_...  8jNOl4h8Z6iibXxY6Tx3vQ
# 187
# 188  https://www.yelp.com/biz/franco-manca-soho?adj...  BBQgwswtNr6B1ExB9haAnA
# 189
# 190  https://www.yelp.com/biz/o-ver-london?adjust_c...  AWxLccDtMO8XAk92Ei3_iQ
# 191  https://www.yelp.com/biz/figli-del-vesuvio-lon...  dJPmL1Y20ltLWrDIVxP6VA
# 192
# 193  https://www.yelp.com/biz/the-swan-london-6?adj...  VomGBPMQALZLfKHCI8_jTg
# 194  https://www.yelp.com/biz/burro-e-salvia-pastif...  kfC0Om5BlL3wTi_YTUKvvA
# 195
# 196
# 197  https://www.yelp.com/biz/carousel-london-4?adj...  TMM6S0k2TBiPJcLiQziQ0Q
# 198  https://www.yelp.com/biz/trattoria-verdi-londo...  q1Qwp2Fbe9ltzc217cqgLg
# 199
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
london_restaurants_df.to_csv('Resources/London_Restaurants_Italian.csv')
