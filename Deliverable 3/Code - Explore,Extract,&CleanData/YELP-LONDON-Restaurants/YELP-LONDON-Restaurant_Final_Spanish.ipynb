# %% [markdown]
# LONDON RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
term = "Spanish"

# %%
#First set of 50 records 0-50
lndr_params1 = {"term":term,"location":"London","limit":50,"offset":0}
lndr_response1 = requests.get(search_api_url, headers=headers, params=lndr_params1)
lndr1 = lndr_response1.json()
display(lndr1)
#print(lndr_response1.url)
#print(lndr_response1.status_code)
# Out:
# {'businesses': [{'id': 'LVtracBONt-BsZ4Vr8_z_g',
#    'alias': 'barrafina-london-5',
#    'name': 'Barrafina',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0kA5JH9_U-9S9jC0WOt5hQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barrafina-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5143394, 'longitude': -0.1219044},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '43 Drury Lane',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5RT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['43 Drury Lane',
#      'Covent Garden',
#      'London WC2B 5RT',
#      'United Kingdom']},
#    'phone': '+442074401456',
#    'display_phone': '+44 20 7440 1456',
#    'distance': 987.2181531651347},
#   {'id': 'oHChMAEdji2RzwQXHdMvoA',
#    'alias': 'carmen-bar-de-tapas-london',
#    'name': 'Carmen Bar De Tapas',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5nDyjwBu3yU4T6Z83l7ocQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carmen-bar-de-tapas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.461562, 'longitude': -0.137833},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 Clapham Common South Side',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW4 7AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Clapham Common South Side',
#      'London SW4 7AA',
#      'United Kingdom']},
#    'phone': '+442076226848',
#    'display_phone': '+44 20 7622 6848',
#    'distance': 5691.107885369147},
#   {'id': 'rkcEjJ3uvbL40Wd-Xufsdg',
#    'alias': 'don-pepe-london',
#    'name': 'Don Pepe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Pp_T_y9XHGGYYpz3yf6ztA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/don-pepe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5236, 'longitude': -0.174362},
#    'transactions': [],
#    'location': {'address1': '99 Framton Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW8 8NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['99 Framton Street',
#      'London NW8 8NA',
#      'United Kingdom']},
#    'phone': '+442072623834',
#    'display_phone': '+44 20 7262 3834',
#    'distance': 2914.554190493479},
#   {'id': 'GtjaGgiKiMPxjPcPtxgUiQ',
#    'alias': 'josé-london-2',
#    'name': 'José',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2uk2nHSKkyOgABWB3JivcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jos%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 82,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5004996, 'longitude': -0.0819549},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '104 Bermondsey Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 3UB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['104 Bermondsey Street',
#      'London SE1 3UB',
#      'United Kingdom']},
#    'phone': '+442074034902',
#    'display_phone': '+44 20 7403 4902',
#    'distance': 3976.1955339893666},
#   {'id': '5iqZAyTXND6zA9dFii_4UQ',
#    'alias': 'centro-galego-de-londres-london',
#    'name': 'Centro Galego de Londres',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/s0Kk5vq7mGDU10nf9eULGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/centro-galego-de-londres-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.53212819224, 'longitude': -0.23686324793784},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '869 Harrow Road',
#     'address2': 'Kensal Green',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW10 5NG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['869 Harrow Road',
#      'Kensal Green',
#      'London NW10 5NG',
#      'United Kingdom']},
#    'phone': '+442089644873',
#    'display_phone': '+44 20 8964 4873',
#    'distance': 7303.567547513148},
#   {'id': 'VUH8CQe3GazQKtDIxCNixQ',
#    'alias': 'cambio-de-tercio-london',
#    'name': 'Cambio De Tercio',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/T5Llbgy4N2vBKUDMIRKyXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cambio-de-tercio-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.490747737127, 'longitude': -0.1836244573671},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '163 Old Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 0LJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['163 Old Brompton Road',
#      'London SW5 0LJ',
#      'United Kingdom']},
#    'phone': '+442072448970',
#    'display_phone': '+44 20 7244 8970',
#    'distance': 4113.265005675445},
#   {'id': 'oERtgNeSaDE0XRPmGEP4uQ',
#    'alias': 'donostia-london',
#    'name': 'Donostia',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IL59HrjhZzvzWMeHbdepPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/donostia-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.514732, 'longitude': -0.160959},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '10 Seymour Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7ND',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Seymour Place',
#      'London W1H 7ND',
#      'United Kingdom']},
#    'phone': '+442036201845',
#    'display_phone': '+44 20 3620 1845',
#    'distance': 1745.9272851654525},
#   {'id': 'mPco-JtqwgjMxvghVyKlzg',
#    'alias': 'el-parador-london',
#    'name': 'El Parador',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NOMi4m-JmsuD_PxIIQMxog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-parador-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5335736, 'longitude': -0.1377578},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '245 Eversholt Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 1BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['245 Eversholt Street',
#      'London NW1 1BA',
#      'United Kingdom']},
#    'phone': '+442073872789',
#    'display_phone': '+44 20 7387 2789',
#    'distance': 2313.0649324231913},
#   {'id': 'NtAndbH_o7DQLLDz-wuGlA',
#    'alias': 'condesa-london',
#    'name': 'Condesa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m27d3sgV7Z5cPti--ZVG5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/condesa-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5106, 'longitude': -0.123181},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '15 Maiden Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 7NG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Maiden Lane',
#      'London WC2E 7NG',
#      'United Kingdom']},
#    'phone': '+442036015752',
#    'display_phone': '+44 20 3601 5752',
#    'distance': 915.4460650530785},
#   {'id': 'iJPlkSdTPp1I3vHf00rk5Q',
#    'alias': 'iberica-marylebone-2',
#    'name': 'Iberica',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kDPF89nbh0yv1TIYm4VT7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/iberica-marylebone-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 76,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.522476, 'longitude': -0.143939},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '195 Great Portland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Marylebone',
#     'zip_code': 'W1W 5PS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['195 Great Portland Street',
#      'Marylebone W1W 5PS',
#      'United Kingdom']},
#    'phone': '+442030265118',
#    'display_phone': '+44 20 3026 5118',
#    'distance': 1205.923616612702},
#   {'id': 'xvr5aSeoJg5ZAJM4FG99xg',
#    'alias': 'barrafina-london-4',
#    'name': 'Barrafina',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HplQzy1vFSfXkqV7SKn9Vw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barrafina-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 65,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5093806, 'longitude': -0.1258185},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '10 Adelaide Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4HZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Adelaide Street',
#      'London WC2N 4HZ',
#      'United Kingdom']},
#    'phone': '+442074401456',
#    'display_phone': '+44 20 7440 1456',
#    'distance': 799.8381109808604},
#   {'id': 't_O2xY53TW3z8X6eyQp2bQ',
#    'alias': 'tapas-brindisa-london-4',
#    'name': 'Tapas Brindisa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TE48ZUyEYOrT8eRdRxOUIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tapas-brindisa-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.513468865838,
#     'longitude': -0.13664590618241},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '46 Broadwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['46 Broadwick Street',
#      'London W1F 7AF',
#      'United Kingdom']},
#    'phone': '+442075341690',
#    'display_phone': '+44 20 7534 1690',
#    'distance': 85.0891297565369},
#   {'id': 'J14GGm_I6Y0zjIFPApaVWw',
#    'alias': 'sabor-london-2',
#    'name': 'Sabor',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5xxNeg5jkxmsKqTzmASfZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sabor-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.511538, 'longitude': -0.139764},
#    'transactions': [],
#    'location': {'address1': '35-37 Heddon Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1B 4BR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35-37 Heddon Street',
#      'London W1B 4BR',
#      'United Kingdom']},
#    'phone': '+442033198130',
#    'display_phone': '+44 20 3319 8130',
#    'distance': 300.4432275585517},
#   {'id': 'WH-BJYaU8RWtzpHZ5xoogg',
#    'alias': 'alquimia-spanish-restaurant-london',
#    'name': 'Alquimia Spanish Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WSmW1420PIgsU26qMybr8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alquimia-spanish-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4650262770793,
#     'longitude': -0.213009018602193},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '30 Brewhouse Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW15 2JX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Brewhouse Lane',
#      'London SW15 2JX',
#      'United Kingdom']},
#    'phone': '+442087850508',
#    'display_phone': '+44 20 8785 0508',
#    'distance': 7531.467578861926},
#   {'id': 'YdnTx95kgD9WLygV3FTxSA',
#    'alias': 'the-port-house-london',
#    'name': 'The Port House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Tfnd4sV2gurl_SavuD8auQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-port-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.509936, 'longitude': -0.123138},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '417 Strand',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2R 0PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['417 Strand',
#      'Covent Garden',
#      'London WC2R 0PD',
#      'United Kingdom']},
#    'phone': '+442078367764',
#    'display_phone': '+44 20 7836 7764',
#    'distance': 943.808997103807},
#   {'id': 'MI3DDKL7YO38tEF-K-qs_w',
#    'alias': 'bravas-tapas-london',
#    'name': 'Bravas Tapas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gBXCg5l_S-rrzERNRM4meg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bravas-tapas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.507436, 'longitude': -0.071242},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'St Katharine Docks',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1W 1AT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['St Katharine Docks',
#      'London E1W 1AT',
#      'United Kingdom']},
#    'phone': '+442074811464',
#    'display_phone': '+44 20 7481 1464',
#    'distance': 4518.584986283189},
#   {'id': 'IjezoTAhQT2yV1UchKLtgA',
#    'alias': 'eneko-basque-kitchen-and-bar-london',
#    'name': 'Eneko Basque Kitchen & Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rGshakkj08Tujq1aX6vByw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eneko-basque-kitchen-and-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5117832, 'longitude': -0.1194172},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1 Aldwych',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2B 4BZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Aldwych', 'London WC2B 4BZ', 'United Kingdom']},
#    'phone': '+442073000300',
#    'display_phone': '+44 20 7300 0300',
#    'distance': 1150.4659692206558},
#   {'id': 'qe6oTrrhUCxxG0fGRo8_6w',
#    'alias': 'titos-london-4',
#    'name': "Tito's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SFKnuO9lO32WAWfUii0PWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/titos-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4709636, 'longitude': -0.1234425},
#    'transactions': [],
#    'location': {'address1': '273A Clapham Road',
#     'address2': 'Stockwell',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 9BQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['273A Clapham Road',
#      'Stockwell',
#      'London SW9 9BQ',
#      'United Kingdom']},
#    'phone': '+442037300659',
#    'display_phone': '+44 20 3730 0659',
#    'distance': 4735.853197138724},
#   {'id': 'c-cEnOLF6sCJaTLxFaX1SQ',
#    'alias': 'el-rincon-quiteño-london-2',
#    'name': 'El Rincon Quiteño',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8RDzs3zhKk43rVS8p4mRMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-rincon-quite%C3%B1o-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.551448, 'longitude': -0.111144},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '235 Holloway Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N7 8HG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['235 Holloway Road',
#      'London N7 8HG',
#      'United Kingdom']},
#    'phone': '+442077003670',
#    'display_phone': '+44 20 7700 3670',
#    'distance': 4629.787763032948},
#   {'id': 'dGkVk041v8tevLofLY8GTg',
#    'alias': 'enrique-tomas-london',
#    'name': 'Enrique Tomas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6Q_S9TF9uudbCXWilI_MqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/enrique-tomas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5144489879813,
#     'longitude': -0.134711450693457},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '132 Wardour Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0TY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['132 Wardour Street',
#      'Soho',
#      'London W1F 0TY',
#      'United Kingdom']},
#    'phone': '+442072872303',
#    'display_phone': '+44 20 7287 2303',
#    'distance': 199.00362720340348},
#   {'id': 'XkAwS7fh17t2NByUzM-VPg',
#    'alias': 'cambio-de-tercio-london-2',
#    'name': 'Cambio De Tercio',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dnbxdqu7cjrbKcdGXM1d5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cambio-de-tercio-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.49071555011, 'longitude': -0.18367075607669},
#    'transactions': [],
#    'location': {'address1': '157 Old Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 0LJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['157 Old Brompton Road',
#      'London SW5 0LJ',
#      'United Kingdom']},
#    'phone': '+442073730567',
#    'display_phone': '+44 20 7373 0567',
#    'distance': 4117.973789897908},
#   {'id': 'ylrlHx0eyaBDA9qSICY1HQ',
#    'alias': 'hispania-london',
#    'name': 'Hispania',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GztmoVs1frKU-YZ4TERP9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hispania-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51297, 'longitude': -0.0877973},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '72-74 Lombard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3V 9AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['72-74 Lombard Street',
#      'London EC3V 9AY',
#      'United Kingdom']},
#    'phone': '+442076210338',
#    'display_phone': '+44 20 7621 0338',
#    'distance': 3353.2707516390033},
#   {'id': 'wS__WuvZNx23gdDQG7c7iQ',
#    'alias': 'mar-i-terra-london-2',
#    'name': 'Mar I Terra',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tENkxDqL4M-faaWwMvq5Pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mar-i-terra-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.504343, 'longitude': -0.102645},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 Gambia Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0XH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Gambia Street',
#      'London SE1 0XH',
#      'United Kingdom']},
#    'phone': '+442079287628',
#    'display_phone': '+44 20 7928 7628',
#    'distance': 2483.814561468635},
#   {'id': '3c3ykVq81dFQLAeFwoRZmQ',
#    'alias': 'jamon-jamon-camden-london',
#    'name': 'Jamon Jamon Camden',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aH_UfISsf5VNCia77mOKxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jamon-jamon-camden-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5383545583328,
#     'longitude': -0.144474506378174},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '38 Parkway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 7AH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38 Parkway', 'London NW1 7AH', 'United Kingdom']},
#    'phone': '+442072840606',
#    'display_phone': '+44 20 7284 0606',
#    'distance': 2898.137667537523},
#   {'id': 'q_tusdGaa20AEQNfpJoW4A',
#    'alias': 'tendido-cero-london',
#    'name': 'Tendido Cero',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LYsauGte4tdlI_JbUoOv7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tendido-cero-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4909847, 'longitude': -0.1839378},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '174 Old Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 0LJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['174 Old Brompton Road',
#      'London SW5 0LJ',
#      'United Kingdom']},
#    'phone': '+442073703685',
#    'display_phone': '+44 20 7370 3685',
#    'distance': 4115.246826374932},
#   {'id': 'bibItX92d7LSCVThLeXb8Q',
#    'alias': 'tapas-brindisa-london-2',
#    'name': 'Tapas Brindisa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vU-8O_rQswlRyb1t-T9ZYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tapas-brindisa-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 133,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.504908, 'longitude': -0.0905255},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18-20 Southwark Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1TJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18-20 Southwark Street',
#      'London SE1 1TJ',
#      'United Kingdom']},
#    'phone': '+442073578880',
#    'display_phone': '+44 20 7357 8880',
#    'distance': 3266.5497816662755},
#   {'id': 'cpju7YCiMFY4kyloKxcNeA',
#    'alias': 'pinchos-london',
#    'name': 'Pinchos',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6SxbmqBF6RV4ZNsO6z3kaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pinchos-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.421059, 'longitude': -0.206346},
#    'transactions': [],
#    'location': {'address1': 'The Concourse',
#     'address2': 'Wimbledon Station',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW19 7NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Concourse',
#      'Wimbledon Station',
#      'London SW19 7NH',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 11317.056612278888},
#   {'id': '-YaDerXncRbSx9uSo9UcKg',
#    'alias': 'iberica-london-16',
#    'name': 'Iberica',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ySACET2arBcFRaBBD8tmIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/iberica-london-16?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4974346, 'longitude': -0.138477},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Unit 5- 6 Zig Zag Building',
#     'address2': '68 Victoria Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1E 6SQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 5- 6 Zig Zag Building',
#      '68 Victoria Street',
#      'London SW1E 6SQ',
#      'United Kingdom']},
#    'phone': '+442030265118',
#    'display_phone': '+44 20 3026 5118',
#    'distance': 1721.3698174281649},
#   {'id': '_hiTEsg7MgrFNfZRl8mksA',
#    'alias': 'señor-ceviche-london-2',
#    'name': 'Señor Ceviche',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/A1nUMTQCNwoW1mSJBxb5qA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/se%C3%B1or-ceviche-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51241, 'longitude': -0.13858},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Kingly Court',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5PW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Kingly Court', 'London W1B 5PW', 'United Kingdom']},
#    'phone': '+442078428540',
#    'display_phone': '+44 20 7842 8540',
#    'distance': 194.43889273685113},
#   {'id': 'nBZxw8KselF6esBLUH24Ww',
#    'alias': 'lobos-meat-and-tapas-london',
#    'name': 'Lobos Meat and Tapas',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sgeV-HnKqFpj7_92l0052g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lobos-meat-and-tapas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5056258, 'longitude': -0.0891513},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '14 Borough High Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9QG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Borough High Street',
#      'London SE1 9QG',
#      'United Kingdom']},
#    'phone': '+442074075361',
#    'display_phone': '+44 20 7407 5361',
#    'distance': 3336.9028620120794},
#   {'id': 'S_WKkcAjy6mL-cysYNcP5A',
#    'alias': 'dehesa-london',
#    'name': 'Dehesa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jVMQimHcdCVrV6lkfG570A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dehesa-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 61,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512781, 'longitude': -0.139333},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '25 Ganton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9BP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['25 Ganton Street',
#      'London W1F 9BP',
#      'United Kingdom']},
#    'phone': '+442074944170',
#    'display_phone': '+44 20 7494 4170',
#    'distance': 235.73618211523822},
#   {'id': 'qvO0hYRegZI5bCEk1cNoOQ',
#    'alias': 'barrafina-london-6',
#    'name': 'Barrafina',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/N8X17KIIbkWHZXnQL57deg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barrafina-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514227, 'longitude': -0.132764},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '26 Dean Street',
#     'address2': 'Soho',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1D 3LL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Dean Street',
#      'Soho',
#      'London W1D 3LL',
#      'United Kingdom']},
#    'phone': '+442074401456',
#    'display_phone': '+44 20 7440 1456',
#    'distance': 269.6751284969637},
#   {'id': 'uLJp1QsowWjJ9qNXHZIIpw',
#    'alias': 'ametsa-london-2',
#    'name': 'Ametsa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VlgMInKB1bVICUe0Cu-jWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ametsa-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5008477, 'longitude': -0.1518671},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '5-6 Halkin Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7DJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5-6 Halkin Street',
#      'London SW1X 7DJ',
#      'United Kingdom']},
#    'phone': '+442073331234',
#    'display_phone': '+44 20 7333 1234',
#    'distance': 1729.026038110191},
#   {'id': 'Vh-VIkTQ8cylRT2XL-MO9g',
#    'alias': 'lurra-london',
#    'name': 'Lurra',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cWn0QQ2QO83DNdUTa5OmRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lurra-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5145415, 'longitude': -0.1612505},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '9 Seymour Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 5BB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Seymour Place',
#      'London W1H 5BB',
#      'United Kingdom']},
#    'phone': '+442077244545',
#    'display_phone': '+44 20 7724 4545',
#    'distance': 1764.2076058473324},
#   {'id': 'fGxj4hAdOocY8bcXiNY1gA',
#    'alias': 'donde-carlos-restaurant-london',
#    'name': 'Donde Carlos Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i0l6ZlM9I2FQ7nNN58_1kw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/donde-carlos-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.50132, 'longitude': -0.231422},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '143 Goldhawk Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W12 8EN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['143 Goldhawk Road',
#      'London W12 8EN',
#      'United Kingdom']},
#    'phone': '+442087499575',
#    'display_phone': '+44 20 8749 9575',
#    'distance': 6734.03875397288},
#   {'id': 'n60s6dzDICjP96wtIYCg-Q',
#    'alias': 'estella-restaurant-london',
#    'name': 'Estella Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KAIj517UXYKGi6RxHiG89A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/estella-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4349668, 'longitude': -0.1983968},
#    'transactions': [],
#    'location': {'address1': '169 Arthur Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW19 8AD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['169 Arthur Road',
#      'London SW19 8AD',
#      'United Kingdom']},
#    'phone': '+442089466518',
#    'display_phone': '+44 20 8946 6518',
#    'distance': 9674.788317103856},
#   {'id': 'cQrWlVTX_0LMrI53m-Ah-A',
#    'alias': 'jose-pizarro-broadgate-london',
#    'name': 'Jose Pizarro Broadgate',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XsX41pCOkEmNl65zdUUZ6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jose-pizarro-broadgate-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.518924, 'longitude': -0.08359},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '36 Broadgate Circle',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2M 2BN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['36 Broadgate Circle',
#      'London EC2M 2BN',
#      'United Kingdom']},
#    'phone': '+442072565333',
#    'display_phone': '+44 20 7256 5333',
#    'distance': 3715.8386422868225},
#   {'id': '5WR5vlucQqcSkVjsxdMWpA',
#    'alias': 'salvador-and-amanda-london',
#    'name': 'Salvador & Amanda',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9q2K8PJMqYHGzaJgDp0YZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salvador-and-amanda-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511995, 'longitude': -0.127822},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8 Great Newport Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 7JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Great Newport Street',
#      'London WC2H 7JA',
#      'United Kingdom']},
#    'phone': '+442072401551',
#    'display_phone': '+44 20 7240 1551',
#    'distance': 574.0565751822019},
#   {'id': 'HuHxB3T8hf3WsTa7YkijdQ',
#    'alias': 'llerena-london',
#    'name': 'Llerena',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/snW6Lr3ZIUougEJxtA8fWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/llerena-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5409955, 'longitude': -0.1030298},
#    'transactions': [],
#    'location': {'address1': '167 Upper Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N1 1US',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['167 Upper Street',
#      'London N1 1US',
#      'United Kingdom']},
#    'phone': '+442077049977',
#    'display_phone': '+44 20 7704 9977',
#    'distance': 3874.9683232693064},
#   {'id': 'fpIx8nCBRqtImTkGJ-ujuQ',
#    'alias': 'morito-london',
#    'name': 'Morito',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CbbO-prB-P2VpTKpu-jvBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/morito-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5258712768555,
#     'longitude': -0.108857996761799},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '32 Exmouth Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 4QE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['32 Exmouth Market',
#      'London EC1R 4QE',
#      'United Kingdom']},
#    'phone': '+442072787007',
#    'display_phone': '+44 20 7278 7007',
#    'distance': 2369.898036502475},
#   {'id': 'Yfwp3WxxxAELuZmom1pS-g',
#    'alias': 'laxeiro-tapas-bar-london',
#    'name': 'Laxeiro Tapas Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XYhrEehDKX7FPsFrzgrgrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laxeiro-tapas-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.529856051392,
#     'longitude': -0.068823875337898},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '93 Columbia Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7RG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['93 Columbia Road',
#      'London E2 7RG',
#      'United Kingdom']},
#    'phone': '+442077291147',
#    'display_phone': '+44 20 7729 1147',
#    'distance': 5015.511473373969},
#   {'id': '-gSV0LVi6K8pMMbqO66PvQ',
#    'alias': 'bar-tozino-london',
#    'name': 'Bar Tozino',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5v8jiQurw6DNmeiSdEqgBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-tozino-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.499291248657,
#     'longitude': -0.0755051194567521},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Ropewalk off Maltby Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 3PA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Ropewalk off Maltby Street',
#      'London SE1 3PA',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4446.674037567032},
#   {'id': 'Q2hLgPzvmxbqwgPqVRY_Ew',
#    'alias': 'el-rocio-tapas-bar-and-restaurant-london',
#    'name': 'El Rocio Tapas Bar & Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EvQ38_ngQTQlndb8oz3e6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-rocio-tapas-bar-and-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': None, 'longitude': None},
#    'transactions': [],
#    'location': {'address1': '268 West End Lane',
#     'address2': 'West Hampstead',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 1LJ',
#     'country': 'IE',
#     'state': 'XGL',
#     'display_address': ['268 West End Lane',
#      'West Hampstead',
#      'London, NW6 1LJ',
#      'Republic of Ireland']},
#    'phone': '+3532074358164',
#    'display_phone': '+353 2074358164',
#    'distance': 5800.154408860505},
#   {'id': 'isPxXiqXRypEw8k45Gjjsw',
#    'alias': 'elche-restaurante-de-tapas-london',
#    'name': 'Elche Restaurante de Tapas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_9vJKn560dNf7d7wXL1APw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elche-restaurante-de-tapas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.633869, 'longitude': 0.009803},
#    'transactions': [],
#    'location': {'address1': '166 Station Road',
#     'address2': 'Chingford',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E4 6AN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['166 Station Road',
#      'Chingford',
#      'London E4 6AN',
#      'United Kingdom']},
#    'phone': '+442085248666',
#    'display_phone': '+44 20 8524 8666',
#    'distance': 16832.756792117587},
#   {'id': 'nMDC_0s833y6uWDzEEIWRA',
#    'alias': 'mi-cocina-es-tuya-london',
#    'name': 'Mi Cocina Es Tuya',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yNj8Y9hOKhmCR7ZaBeJ3HA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mi-cocina-es-tuya-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4177748, 'longitude': -0.0820176},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61 Westow St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE19 3RW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Westow St', 'London SE19 3RW', 'United Kingdom']},
#    'phone': '+442087714078',
#    'display_phone': '+44 20 8771 4078',
#    'distance': 11211.222740392666},
#   {'id': 'tUXG0M3VnTG40Gobw5zp4Q',
#    'alias': 'san-miguels-london',
#    'name': "San Miguel's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ch-5rCTYXiVB7dCNkjcWkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/san-miguels-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.51938, 'longitude': -0.168564},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '256 Edgware Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1DS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['256 Edgware Road',
#      'London W2 1DS',
#      'United Kingdom']},
#    'phone': '+442072621709',
#    'display_phone': '+44 20 7262 1709',
#    'distance': 2370.8009855817654},
#   {'id': 'OyLrjCVSSp5UUAYe9Vm0Hg',
#    'alias': 'camino-london',
#    'name': 'Camino',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TDU4TPZeSeQkrj7WyEY_Dg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camino-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 107,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5312937277784,
#     'longitude': -0.121793746948242},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3 Varnishers Yard',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Varnishers Yard',
#      'London N1 9AF',
#      'United Kingdom']},
#    'phone': '+442078417331',
#    'display_phone': '+44 20 7841 7331',
#    'distance': 2274.344517625361},
#   {'id': 'uChfhfkKwlU5Fu5x2RedXA',
#    'alias': 'arros-qd-london',
#    'name': 'Arros QD',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bDjukSIBB46KPPgjUsBuAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arros-qd-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516741, 'longitude': -0.136918},
#    'transactions': [],
#    'location': {'address1': '64 Eastcastle Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 8NQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['64 Eastcastle Street',
#      'London W1W 8NQ',
#      'United Kingdom']},
#    'phone': '+442038833525',
#    'display_phone': '+44 20 3883 3525',
#    'distance': 439.3433947154889},
#   {'id': 'MCx1FDljaGB7wGdFtPHPtA',
#    'alias': 'moro-restaurant-london',
#    'name': 'Moro Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T87mAPP6kaENLAibDUU_TQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moro-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 76,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.525859880105,
#     'longitude': -0.10906549497442},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '34-36 Exmouth Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 4QE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['34-36 Exmouth Market',
#      'London EC1R 4QE',
#      'United Kingdom']},
#    'phone': '+442078338336',
#    'display_phone': '+44 20 7833 8336',
#    'distance': 2357.7775297856156},
#   {'id': 'BVlzDuPtmnupkLA41HaH5A',
#    'alias': 'twist-london-2',
#    'name': 'Twist',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CRPc40A541zsYAK94rJxig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/twist-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5193012900495,
#     'longitude': -0.16238228962316},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '42 Crawford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 1JW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 Crawford Street',
#      'London W1H 1JW',
#      'United Kingdom']},
#    'phone': '+442077233377',
#    'display_phone': '+44 20 7723 3377',
#    'distance': 1964.8674457885131}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                  Restaurant     Type Price Rating  \
# 0                 Barrafina  Spanish    ££    4.5
# 1       Carmen Bar De Tapas  Spanish    ££      4
# 2                  Don Pepe  Spanish
# 3                      José  Spanish    ££    4.5
# 4  Centro Galego de Londres  Spanish    ££    4.5
#
#                        Address        Lat       Lng  \
# 0                43 Drury Lane  51.514339 -0.121904
# 1  6 Clapham Common South Side  51.461562 -0.137833
# 2            99 Framton Street  51.523600 -0.174362
# 3        104 Bermondsey Street  51.500500 -0.081955
# 4              869 Harrow Road  51.532128 -0.236863
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/barrafina-london-5?ad...  LVtracBONt-BsZ4Vr8_z_g
# 1  https://www.yelp.com/biz/carmen-bar-de-tapas-l...  oHChMAEdji2RzwQXHdMvoA
# 2
# 3  https://www.yelp.com/biz/jos%C3%A9-london-2?ad...  GtjaGgiKiMPxjPcPtxgUiQ
# 4  https://www.yelp.com/biz/centro-galego-de-lond...  5iqZAyTXND6zA9dFii_4UQ

# %%
#2nd set of 50 records 51-100 
lndr_params2 = {"term":term,"location":"London","limit":50,"offset":51}
lndr_response2 = requests.get(search_api_url, headers=headers, params=lndr_params2)
lndr2 = lndr_response2.json()
display(lndr2)
#print(lndr_response2.url)
#print(lndr_response2.status_code)
# Out:
# {'businesses': [{'id': 'XUGUEQ0-f8I9ethzxN-ZUA',
#    'alias': 'la-tasca-london-18',
#    'name': 'La Tasca',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dwSjTkF8yECBJN05ocgbaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-tasca-london-18?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5074264778162,
#     'longitude': -0.0233688980964009},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'West India Quay',
#     'address2': 'Canary Wharf',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E14 4AE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['West India Quay',
#      'Canary Wharf',
#      'London E14 4AE',
#      'United Kingdom']},
#    'phone': '+442075319990',
#    'display_phone': '+44 20 7531 9990',
#    'distance': 7814.756744617628},
#   {'id': 'KhC_K54c93Ej3yoPTAl_gg',
#    'alias': 'bodegade-tapas-london',
#    'name': 'Bodegade Tapas',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NTs-NfwnqPCtNEqIO45xjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bodegade-tapas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5409693, 'longitude': -0.1439009},
#    'transactions': [],
#    'location': {'address1': '30 Hawley Crescent',
#     'address2': 'Camden',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW1 8NP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Hawley Crescent',
#      'Camden',
#      'London NW1 8NP',
#      'United Kingdom']},
#    'phone': '+442074825937',
#    'display_phone': '+44 20 7482 5937',
#    'distance': 3176.2477807160617},
#   {'id': '02fYko-o-LDt6g0agcNZsg',
#    'alias': 'boqueria-london',
#    'name': 'Boqueria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/b4du7u9Ja5tirLua4rGvWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boqueria-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.459870028924,
#     'longitude': -0.12713936531653},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '192 Acre Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW2 5UL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['192 Acre Lane', 'London SW2 5UL', 'United Kingdom']},
#    'phone': '+442077334408',
#    'display_phone': '+44 20 7733 4408',
#    'distance': 5921.040858643929},
#   {'id': 'PWJiVG6QUm8P2aLJke1Ndw',
#    'alias': 'las-tapas-london',
#    'name': 'Las Tapas',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VEIKQJJlYYvItclSoUiaDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/las-tapas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5067595, 'longitude': -0.2072507},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '108 Holland Park Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 4UA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['108 Holland Park Avenue',
#      'London W11 4UA',
#      'United Kingdom']},
#    'phone': '+442072213598',
#    'display_phone': '+44 20 7221 3598',
#    'distance': 4980.041326069025},
#   {'id': 'RXi1QlJsQcFvoBR5oR7x3w',
#    'alias': 'la-lluna-london',
#    'name': 'La Lluna',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/q2e8setlNhZ_epnKtzx2Tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-lluna-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5926970055022,
#     'longitude': -0.143234954958407},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9462 Muswell Hill Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N10 1BS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9462 Muswell Hill Broadway',
#      'London N10 1BS',
#      'United Kingdom']},
#    'phone': '+442084422662',
#    'display_phone': '+44 20 8442 2662',
#    'distance': 8894.432262669847},
#   {'id': 'K9EJ3OCwtk5qDLRZqm_4SQ',
#    'alias': 'toro-gordo-london',
#    'name': 'Toro Gordo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zUfMRO_chVUPob1aNKQ8SA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/toro-gordo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4924524517799,
#     'longitude': -0.230151628799284},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '121 King Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W6 9JG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['121 King Street', 'London W6 9JG', 'United Kingdom']},
#    'phone': '+442088347434',
#    'display_phone': '+44 20 8834 7434',
#    'distance': 6902.606952583127},
#   {'id': 'vCF8ut7OZcfA4hEmhngfSQ',
#    'alias': 'andina-london',
#    'name': 'Andina',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sgBZI-KCVdW5u838gGQW6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/andina-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 142,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5243208695971,
#     'longitude': -0.077134990126122},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Redchurch Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7DJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Redchurch Street',
#      'London E2 7DJ',
#      'United Kingdom']},
#    'phone': '+442079206499',
#    'display_phone': '+44 20 7920 6499',
#    'distance': 4265.6096504626785},
#   {'id': 'alC9ZQUlGSZ4SYfKVBl65A',
#    'alias': 'l-oculto-london',
#    'name': "L'Oculto",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yIHUk2d3u4naqtfJXhyG0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-oculto-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4673161, 'longitude': -0.0229169},
#    'transactions': [],
#    'location': {'address1': '57 Loampit Hill',
#     'address2': 'Lewisham - Brockley',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE13 7SZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57 Loampit Hill',
#      'Lewisham - Brockley',
#      'London SE13 7SZ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9320.406659645661},
#   {'id': 'TX9hjk1xl2xKwG1_Wuw0UQ',
#    'alias': 'camino-london-5',
#    'name': 'Camino',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/M0-jrnPJZnFddIT6c9GqMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camino-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5058899, 'longitude': -0.09945},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5 Canvey Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Canvey Street',
#      'London SE1 9NA',
#      'United Kingdom']},
#    'phone': '+442036173169',
#    'display_phone': '+44 20 3617 3169',
#    'distance': 2601.204580420548},
#   {'id': 'hY6qUgNek-18AGTVtQt_4Q',
#    'alias': 'levante-bar-london',
#    'name': 'Levante Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EDAWI0lIWrKsCwYYizV4wQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/levante-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.507445200665,
#     'longitude': -0.0229300370483543},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 Hertsmere Road',
#     'address2': 'W India Quay',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E14 4AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Hertsmere Road',
#      'W India Quay',
#      'London E14 4AF',
#      'United Kingdom']},
#    'phone': '+442030698981',
#    'display_phone': '+44 20 3069 8981',
#    'distance': 7844.877438271125},
#   {'id': 'D1pGai_OlTkiMMXfWaqBCA',
#    'alias': 'salt-yard-london',
#    'name': 'Salt Yard',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-YdNVmqVax6Z_LexluyIUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salt-yard-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5191758, 'longitude': -0.1365711},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '54 Goodge Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 4NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54 Goodge Street',
#      'London W1T 4NA',
#      'United Kingdom']},
#    'phone': '+442076370657',
#    'display_phone': '+44 20 7637 0657',
#    'distance': 706.4575147278808},
#   {'id': '_-elas7RMSmqgfXN2MbSSQ',
#    'alias': 'taperia-deptford-london',
#    'name': 'Taperia Deptford',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xrTTo5Ypo56nphwbNqetOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taperia-deptford-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.472943, 'longitude': -0.021699},
#    'transactions': [],
#    'location': {'address1': '1 Deal Gateway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE13 7QD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Deal Gateway',
#      'London SE13 7QD',
#      'United Kingdom']},
#    'phone': '+442086940115',
#    'display_phone': '+44 20 8694 0115',
#    'distance': 9053.809090807728},
#   {'id': 'ZWF3QlnudKACeJRsSYWZLA',
#    'alias': 'el-barco-latino-london',
#    'name': 'El Barco Latino',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lg3iISw5HVbwW2QHk3D7Vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-barco-latino-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5105167, 'longitude': -0.1155195},
#    'transactions': [],
#    'location': {'address1': 'Victoria Embankment',
#     'address2': 'Charing Cross',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2R 2PP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Victoria Embankment',
#      'Charing Cross',
#      'London WC2R 2PP',
#      'United Kingdom']},
#    'phone': '+442073795496',
#    'display_phone': '+44 20 7379 5496',
#    'distance': 1437.5592013542089},
#   {'id': 'fWtrmqyjwI2urelGvGP1rw',
#    'alias': 'la-bodega-tapas-bar-london',
#    'name': 'La Bodega Tapas Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/49eooHOBIIUyoTdUJ8TueQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-bodega-tapas-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.518248374611,
#     'longitude': -0.20661031224103},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '78 Tavistock Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 1AN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['78 Tavistock Road',
#      'London W11 1AN',
#      'United Kingdom']},
#    'phone': '+442077275660',
#    'display_phone': '+44 20 7727 5660',
#    'distance': 4925.97290600177},
#   {'id': '1BzTEwJ89j_nBSi7Sf3ylQ',
#    'alias': 'black-pig-with-white-pearls-london',
#    'name': 'Black Pig With White Pearls',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wNKN_xInvn_b82zTgQ7WRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-pig-with-white-pearls-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.55896, 'longitude': -0.0744295},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61 Stoke Newington High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 8EL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Stoke Newington High Street',
#      'London N16 8EL',
#      'United Kingdom']},
#    'phone': '+442072491772',
#    'display_phone': '+44 20 7249 1772',
#    'distance': 6649.972106415342},
#   {'id': 'GQLfQGeX0VuCUUCOzMiNdQ',
#    'alias': 'casa-manalo-london',
#    'name': 'Casa Manalo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vsrCQTXpfiW8kpCVkFuWMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-manalo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5349925833602,
#     'longitude': -0.104803964495659},
#    'transactions': [],
#    'location': {'address1': '43 Upper Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N1 0PN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['43 Upper Street', 'London N1 0PN', 'United Kingdom']},
#    'phone': '+442073543302',
#    'display_phone': '+44 20 7354 3302',
#    'distance': 3273.3775350503383},
#   {'id': 'vBEQW6eX3DFYlDgrzr8VCQ',
#    'alias': 'el-vergel-london',
#    'name': 'El Vergel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HMpP7JOOK9BZy5cSKuOAwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-vergel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.500707, 'longitude': -0.099151},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '132 Webber Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['132 Webber Street',
#      'London SE1 0QL',
#      'United Kingdom']},
#    'phone': '+442074012308',
#    'display_phone': '+44 20 7401 2308',
#    'distance': 2881.1132049899998},
#   {'id': 'ZiDGOLqa9ATyjMQ265ijFQ',
#    'alias': 'goya-london-3',
#    'name': 'Goya',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oOzNTdnAzX6H-NcjEx890Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/goya-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4884216, 'longitude': -0.1375914},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '34 Lupus Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 3EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['34 Lupus Street',
#      'London SW1V 3EB',
#      'United Kingdom']},
#    'phone': '+442079765309',
#    'display_phone': '+44 20 7976 5309',
#    'distance': 2716.734433413352},
#   {'id': 'ofwMyWQN3MMfpqxa3y3l_w',
#    'alias': 'opera-tavern-london',
#    'name': 'Opera Tavern',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qwgQQue8iNTto7QvOZbHQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/opera-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5124698, 'longitude': -0.1204465},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '23 Catherine Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5JS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23 Catherine Street',
#      'London WC2B 5JS',
#      'United Kingdom']},
#    'phone': '+442078363680',
#    'display_phone': '+44 20 7836 3680',
#    'distance': 1077.0170548099657},
#   {'id': '8zRK64DiSEh2FIvtcUs08A',
#    'alias': 'canaletes-tapas-and-wine-london',
#    'name': 'Canaletes Tapas & Wine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Zy9TdfdbkuTE2R9pCSVAgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/canaletes-tapas-and-wine-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5408663364831,
#     'longitude': -0.201840586960316},
#    'transactions': [],
#    'location': {'address1': '51 Willesden Lane',
#     'address2': 'North Maida Vale London NW6 7RL',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW6 7RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Willesden Lane',
#      'North Maida Vale London NW6 7RL',
#      'London NW6 7RL',
#      'United Kingdom']},
#    'phone': '+442076247004',
#    'display_phone': '+44 20 7624 7004',
#    'distance': 5521.70607622616},
#   {'id': '5bx0l0I3qbPzVLpdP3o2Ew',
#    'alias': 'el-pirata-of-mayfair-mayfair',
#    'name': 'El Pirata of Mayfair',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lyR6Mfrke0YmvzXZKgC-Dg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-pirata-of-mayfair-mayfair?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 61,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.505142, 'longitude': -0.148132},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '5-6 Down Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Mayfair',
#     'zip_code': 'W1J 7AQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5-6 Down Street',
#      'Mayfair W1J 7AQ',
#      'United Kingdom']},
#    'phone': '+442074913810',
#    'display_phone': '+44 20 7491 3810',
#    'distance': 1201.0174523191545},
#   {'id': 'jgx_WCV_5zBEeGHQvimLHQ',
#    'alias': 'cafe-españa-london-2',
#    'name': 'Cafe España',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0MXTmVg2C_USHLhor7GSsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-espa%C3%B1a-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.512463, 'longitude': -0.13289},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '63 Old Compton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6HT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63 Old Compton Street',
#      'London W1D 6HT',
#      'United Kingdom']},
#    'phone': '+442072875336',
#    'display_phone': '+44 20 7287 5336',
#    'distance': 213.2988387816787},
#   {'id': 'VTMZPFQ-cyPuKLnqAOxXwQ',
#    'alias': 'la-tasca-restaurant-london',
#    'name': 'La Tasca Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/36T5Dq_ClwgqieuglqDg_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-tasca-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5114047, 'longitude': -0.126852},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "63-66 St. Martin's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4JS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["63-66 St. Martin's Lane",
#      'London WC2N 4JS',
#      'United Kingdom']},
#    'phone': '+442072402011',
#    'display_phone': '+44 20 7240 2011',
#    'distance': 649.7807048551338},
#   {'id': '89qpxd9qtTI4plPxHPZf0g',
#    'alias': 'fernandez-and-wells-london-3',
#    'name': 'Fernandez & Wells',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yRtKahoPJZewTOA5E00kxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fernandez-and-wells-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5120811, 'longitude': -0.11688},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'East Wing Somerset House',
#     'address2': 'Strand',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2R 1LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['East Wing Somerset House',
#      'Strand',
#      'London WC2R 1LA',
#      'United Kingdom']},
#    'phone': '+442074209408',
#    'display_phone': '+44 20 7420 9408',
#    'distance': 1285.7715860031617},
#   {'id': 'r4yImLpeIpcjMFD7qSz_ng',
#    'alias': 'meson-don-felipe-london',
#    'name': 'Meson Don Felipe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yl8p5RbithuAa2sp1pXTFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meson-don-felipe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5029673, 'longitude': -0.1072009},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '53 The Cut',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8LF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['53 The Cut', 'London SE1 8LF', 'United Kingdom']},
#    'phone': '+442079283237',
#    'display_phone': '+44 20 7928 3237',
#    'distance': 2270.849488911948},
#   {'id': 'jTnrRxJp82iYjJVt8PPITQ',
#    'alias': 'barcelona-tapas-london-2',
#    'name': 'Barcelona Tapas',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZKQsBHXpmTxrGGvm4pVsdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barcelona-tapas-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5118330704957,
#     'longitude': -0.0835872701958973},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '24 Lime Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3M 7HS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Lime Street',
#      'London EC3M 7HS',
#      'United Kingdom']},
#    'phone': '+442079292389',
#    'display_phone': '+44 20 7929 2389',
#    'distance': 3625.703570941595},
#   {'id': '1saSQJuhKzjWbhWSAcfpNg',
#    'alias': 'miss-tapas-london',
#    'name': 'Miss Tapas',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZeDSMURAXwHoUVeLlT8VGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/miss-tapas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4681856176917,
#     'longitude': -0.0691786000000216},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '46 Choumert Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE15 4SE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['46 Choumert Road',
#      'London SE15 4SE',
#      'United Kingdom']},
#    'phone': '+442036895050',
#    'display_phone': '+44 20 3689 5050',
#    'distance': 6784.141045113692},
#   {'id': 'H54RI_SY2N5srvP3qpgAmg',
#    'alias': 'brindisa-london-2',
#    'name': 'Brindisa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4AAQ6vubtbly__QMz7d3IA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brindisa-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4624005417607,
#     'longitude': -0.112283045097797},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '41-43 Atlantic Road',
#     'address2': 'Brixton',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 8JL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41-43 Atlantic Road',
#      'Brixton',
#      'London SW9 8JL',
#      'United Kingdom']},
#    'phone': '+442077330634',
#    'display_phone': '+44 20 7733 0634',
#    'distance': 5842.727444569834},
#   {'id': '9EJjiBc0n7weYPzrwmMbdw',
#    'alias': 'los-parrales-london',
#    'name': 'Los Parrales',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VIwPf4MeaWrw1uNTOYi5IA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-parrales-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4449155, 'longitude': 0.1023555},
#    'transactions': [],
#    'location': {'address1': '21 The Oval',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'DA15 9ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21 The Oval', 'London DA15 9ER', 'United Kingdom']},
#    'phone': '+442083004773',
#    'display_phone': '+44 20 8300 4773',
#    'distance': 18149.600439771053},
#   {'id': '1qNEj896lQeb4iX0pFdbOQ',
#    'alias': 'casa-manolo-london-2',
#    'name': 'Casa Manolo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/raoJjajIm780n-hUEpL0jw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-manolo-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5104451, 'longitude': -0.1205752},
#    'transactions': [],
#    'location': {'address1': '99 Strand',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2R 0EW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['99 Strand', 'London WC2R 0EW', 'United Kingdom']},
#    'phone': '+442072409872',
#    'display_phone': '+44 20 7240 9872',
#    'distance': 1097.0668207008844},
#   {'id': 'nLgRYqDWBryUZ46F-0ZEAA',
#    'alias': 'albertine-london',
#    'name': 'Albertine',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/r3IZCDY-E_4kTSFA359yHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/albertine-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.505570737177,
#     'longitude': -0.22483055106729},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Wood Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W12 7DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Wood Lane', 'London W12 7DP', 'United Kingdom']},
#    'phone': '+442087439593',
#    'display_phone': '+44 20 8743 9593',
#    'distance': 6203.5217337173435},
#   {'id': 'uVPz6AznuCZRUPLR3S0TKw',
#    'alias': 'el-metro-restaurant-london',
#    'name': 'El Metro Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hlTAEgyKm4BrWZkTBc-_YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-metro-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.479411, 'longitude': -0.195849},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10-12 Effie Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 1TB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10-12 Effie Road',
#      'London SW6 1TB',
#      'United Kingdom']},
#    'phone': '+442073841264',
#    'display_phone': '+44 20 7384 1264',
#    'distance': 5567.536326511399},
#   {'id': 'XB2S_jYmKVyxDxR5silCPQ',
#    'alias': 'jamon-jamon-london-5',
#    'name': 'Jamon Jamon',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AsWBsRxjPu5p0Zsy1JFvfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jamon-jamon-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5501828521338,
#     'longitude': -0.164836167734323},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '177 Haverstock Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 4QS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['177 Haverstock Hill',
#      'London NW3 4QS',
#      'United Kingdom']},
#    'phone': '+442074834242',
#    'display_phone': '+44 20 7483 4242',
#    'distance': 4608.351435650079},
#   {'id': 'vN5XHJMX7A5EpXGGnIj_Ag',
#    'alias': 'jamon-jamon-soho-london-3',
#    'name': 'Jamon Jamon Soho',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XLjryAeMK2SUt58A9KpKWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jamon-jamon-soho-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5139202738536,
#     'longitude': -0.12920486284338},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3-5 Caxton Walk',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 8PW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3-5 Caxton Walk',
#      'London WC2H 8PW',
#      'United Kingdom']},
#    'phone': '+442078366969',
#    'display_phone': '+44 20 7836 6969',
#    'distance': 482.4863147941423},
#   {'id': 'MuB1SAHJkKGauEA2_2QuMw',
#    'alias': 'donostia-social-club-london-2',
#    'name': 'Donostia Social Club',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZB4R5KKbrJ-BZA5ENcjrig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/donostia-social-club-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'basque', 'title': 'Basque'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4634215902681,
#     'longitude': -0.112375015123689},
#    'transactions': [],
#    'location': {'address1': '49 Brixton Station Road',
#     'address2': 'Pop Brixton',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 8PQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Brixton Station Road',
#      'Pop Brixton',
#      'London SW9 8PQ',
#      'United Kingdom']},
#    'phone': '+447961844464',
#    'display_phone': '+44 7961 844464',
#    'distance': 5732.017427688565},
#   {'id': 'DguKdtdKKRg5U0OBiZa_sw',
#    'alias': 'tendido-cuatro-london',
#    'name': 'Tendido Cuatro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hIYXJGNs2_VYEZXRmoLdGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tendido-cuatro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.4721336364746,
#     'longitude': -0.204386994242668},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '108 New Kings Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 4LY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['108 New Kings Rd',
#      'London SW6 4LY',
#      'United Kingdom']},
#    'phone': '+442073715147',
#    'display_phone': '+44 20 7371 5147',
#    'distance': 6551.961082434741},
#   {'id': 'aywIyiNMxy4nbBabMGK1Vw',
#    'alias': 'bedales-of-borough-market-london',
#    'name': 'Bedales of Borough Market',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/W7ZhXwSWsVzhAiQYNcrODA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bedales-of-borough-market-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.505406, 'longitude': -0.0898341},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5 Bedale Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9AL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Bedale Street',
#      'London SE1 9AL',
#      'United Kingdom']},
#    'phone': '+442074038853',
#    'display_phone': '+44 20 7403 8853',
#    'distance': 3297.098607334311},
#   {'id': 'ZZWYsbwD8kkHUyiAKnVnAQ',
#    'alias': 'ibérica-london-7',
#    'name': 'Ibérica',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uVi23WMSL3azDdnTs3zUsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ib%C3%A9rica-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5210778192986,
#     'longitude': -0.105176791548729},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '89 Turnmill Street',
#     'address2': 'Farringdon',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1M 5QU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['89 Turnmill Street',
#      'Farringdon',
#      'London EC1M 5QU',
#      'United Kingdom']},
#    'phone': '+442030265118',
#    'display_phone': '+44 20 3026 5118',
#    'distance': 2318.5725550698658},
#   {'id': '08ITFw37j1rJTTkOROWJWQ',
#    'alias': 'la-plaza-tapas-bar-london',
#    'name': 'La Plaza Tapas Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Lz5GFJovX-9JJgeYgLOHdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-plaza-tapas-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.518317132243,
#     'longitude': -0.20521943982827},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '74 Tavistock Road',
#     'address2': 'Notting Hill',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 1AN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['74 Tavistock Road',
#      'Notting Hill',
#      'London W11 1AN',
#      'United Kingdom']},
#    'phone': '+442072295995',
#    'display_phone': '+44 20 7229 5995',
#    'distance': 4831.419461087176},
#   {'id': 'UlWuQCehRHfyxz8AZj42tg',
#    'alias': 'casa-brindisa-london',
#    'name': 'Casa Brindisa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TJOimddfv7uJSrAEhiLMrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-brindisa-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4948622943727,
#     'longitude': -0.173562906002465},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '7-9 Exhibition Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 2HE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7-9 Exhibition Road',
#      'London SW7 2HE',
#      'United Kingdom']},
#    'phone': '+442075900008',
#    'display_phone': '+44 20 7590 0008',
#    'distance': 3281.6931678912774},
#   {'id': 'CtPiMwCfJ0MTkeHEWdsy1g',
#    'alias': 'enrique-tomas-london-3',
#    'name': 'Enrique Tomas',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OQ1XRJcYUdd_g7LP6cxtoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/enrique-tomas-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5438078695376,
#     'longitude': -0.00900228687170422},
#    'transactions': [],
#    'location': {'address1': '14 Westfield Stratford City',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E20 1GP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Westfield Stratford City',
#      'London E20 1GP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9433.442657886459},
#   {'id': '7MUA0ebmkyyQG5YrR4WJpA',
#    'alias': 'norfolk-arms-london',
#    'name': 'Norfolk Arms',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yqrP4ZsPhxI8gu2veze6ZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/norfolk-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.526648, 'longitude': -0.12526},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '28 Leigh Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 9EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28 Leigh Street',
#      'London WC1H 9EP',
#      'United Kingdom']},
#    'phone': '+442073883937',
#    'display_phone': '+44 20 7388 3937',
#    'distance': 1704.1327478563194},
#   {'id': 'QBW7NfRURYLOVSAYp4mMpw',
#    'alias': 'jamon-jamon-paella-stall-london',
#    'name': 'Jamon Jamon - Paella Stall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/N-1aGH759fwd1Kls0mYQgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jamon-jamon-paella-stall-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5165946117105,
#     'longitude': -0.205446481704712},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Portobello Road Market',
#     'address2': 'Stall 90 Portobello Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 1LU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Portobello Road Market',
#      'Stall 90 Portobello Road',
#      'London W11 1LU',
#      'United Kingdom']},
#    'phone': '+447887984899',
#    'display_phone': '+44 7887 984899',
#    'distance': 4826.750965548269},
#   {'id': 'hAquCqR6pbCOZKJc_RuOaw',
#    'alias': 'mas-q-menos-london',
#    'name': 'Mas Q Menos',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pNWr9CyBOgx3RQs0-s-JaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mas-q-menos-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.517910248824,
#     'longitude': -0.116228820717674},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '272 High Holborn',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1V 7EY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['272 High Holborn',
#      'London WC1V 7EY',
#      'United Kingdom']},
#    'phone': '+442078313940',
#    'display_phone': '+44 20 7831 3940',
#    'distance': 1477.083394042611},
#   {'id': 'ao6l60DSpTlssR60XEjOnw',
#    'alias': 'barrica-london',
#    'name': 'Barrica',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pI74VqbPxn32ebIwauTslQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barrica-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.519099, 'longitude': -0.136827},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '62 Goodge Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 4NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['62 Goodge Street',
#      'London W1T 4NE',
#      'United Kingdom']},
#    'phone': '+442074369448',
#    'display_phone': '+44 20 7436 9448',
#    'distance': 696.3818191543485},
#   {'id': 'Wp9G9XQLWsaxfbNdGwcacw',
#    'alias': 'casa-manolo-london',
#    'name': 'Casa Manolo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yXVOan6CUZIOwSbhe8hsLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-manolo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4871328668651,
#     'longitude': -0.16912266464558},
#    'transactions': [],
#    'location': {'address1': "187 King's Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 5EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["187 King's Road",
#      'London SW3 5EB',
#      'United Kingdom']},
#    'phone': '+442073521215',
#    'display_phone': '+44 20 7352 1215',
#    'distance': 3665.921146091279},
#   {'id': 'YB4lnrHR8KM23ruC2M-_Dg',
#    'alias': 'the-lounge-balham',
#    'name': 'The Lounge',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZzyepaxwQ_roMA5eaETl-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lounge-balham?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4423226, 'longitude': -0.1495673},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '76 Bedford Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'Balham',
#     'zip_code': 'SW12 9HR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['76 Bedford Hill',
#      'Balham SW12 9HR',
#      'United Kingdom']},
#    'phone': '+442086738787',
#    'display_phone': '+44 20 8673 8787',
#    'distance': 7915.777628880449},
#   {'id': 'WreNoNYNkQ7b5OI_ZCsSnQ',
#    'alias': 'cubana-london',
#    'name': 'Cubana',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NHE0xGyJgoUkvlKptgLGlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cubana-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 106,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'cuban', 'title': 'Cuban'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5015189520748,
#     'longitude': -0.110859948883456},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '48 Lower Marsh',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7RG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['48 Lower Marsh', 'London SE1 7RG', 'United Kingdom']},
#    'phone': '+447474968275',
#    'display_phone': '+44 7474 968275',
#    'distance': 2144.7965923605707},
#   {'id': 'HO_YLnFUpea_S6UfC_4XSw',
#    'alias': 'lobos-london',
#    'name': 'Lobos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Y-IXdsGGbAk4Rau4C0xbBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lobos-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5135427, 'longitude': -0.131473},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '48 Frith Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 4SF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['48 Frith Street',
#      'London W1D 4SF',
#      'United Kingdom']},
#    'phone': '+442030195082',
#    'display_phone': '+44 20 3019 5082',
#    'distance': 320.0233551913448},
#   {'id': 'xzui1-XqO7N5VzDnEeYWrw',
#    'alias': 'terroirs-london',
#    'name': 'Terroirs',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UST1MxNd0WWdCD9laoJNUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/terroirs-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 88,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5093551, 'longitude': -0.1252067},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '5 William IV Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4DW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 William IV Street',
#      'London WC2N 4DW',
#      'United Kingdom']},
#    'phone': '+442070360660',
#    'display_phone': '+44 20 7036 0660',
#    'distance': 837.1697744535918}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#        Restaurant                Type Price Rating  \
# 0        La Tasca             Spanish    ££      3
# 1  Bodegade Tapas             Spanish
# 2        Boqueria          Tapas Bars    ££      4
# 3       Las Tapas  Tapas/Small Plates   £££    3.5
# 4        La Lluna             Spanish    ££      5
#
#                       Address        Lat       Lng  \
# 0             West India Quay  51.507426 -0.023369
# 1          30 Hawley Crescent  51.540969 -0.143901
# 2               192 Acre Lane  51.459870 -0.127139
# 3     108 Holland Park Avenue  51.506760 -0.207251
# 4  9462 Muswell Hill Broadway  51.592697 -0.143235
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/la-tasca-london-18?ad...  XUGUEQ0-f8I9ethzxN-ZUA
# 1
# 2  https://www.yelp.com/biz/boqueria-london?adjus...  02fYko-o-LDt6g0agcNZsg
# 3  https://www.yelp.com/biz/las-tapas-london?adju...  PWJiVG6QUm8P2aLJke1Ndw
# 4  https://www.yelp.com/biz/la-lluna-london?adjus...  RXi1QlJsQcFvoBR5oR7x3w

# %%
#3rd set of 50 records 101-150
lndr_params3 = {"term":term,"location":"London","limit":50,"offset":101}
lndr_response3 = requests.get(search_api_url, headers=headers, params=lndr_params3)
lndr3 = lndr_response3.json()
display(lndr3)
#print(lndr_response3.url)
#print(lndr_response3.status_code)
# Out:
# {'businesses': [{'id': '5oeBHVtncsgfV5bLSMVVeA',
#    'alias': 'las-barilles-london',
#    'name': 'Las Barilles',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/las-barilles-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.524381, 'longitude': -0.099478},
#    'transactions': [],
#    'location': {'address1': '55-63 Goswell Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 7EN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55-63 Goswell Road',
#      'London EC1V 7EN',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2831.9738345911146},
#   {'id': 'lpggeARkCtGqQ7X5_OZOEQ',
#    'alias': 'house-of-tippler-london',
#    'name': 'House of Tippler',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VQ7JzgtYiPK5loSNNDZtjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/house-of-tippler-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4571528, 'longitude': -0.0752982},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '123 Lordship Lane',
#     'address2': 'East Dulwich',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE22 8HU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['123 Lordship Lane',
#      'East Dulwich',
#      'London SE22 8HU',
#      'United Kingdom']},
#    'phone': '+442079984878',
#    'display_phone': '+44 20 7998 4878',
#    'distance': 7481.799340332362},
#   {'id': 'EazZp7bn_8HkTqUscy7Erg',
#    'alias': 'orford-saloon-tapas-bar-london',
#    'name': 'Orford Saloon Tapas Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HnMgqC0ih6uoPZViWXq1vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/orford-saloon-tapas-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.582562, 'longitude': -0.013116},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '32 Orford Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E17 9NJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['32 Orford Road', 'London E17 9NJ', 'United Kingdom']},
#    'phone': '+442085036542',
#    'display_phone': '+44 20 8503 6542',
#    'distance': 11496.05715442962},
#   {'id': 'EA9cSKJg-Xox0n3u-tmX4A',
#    'alias': 'los-molinos-london',
#    'name': 'Los Molinos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/x3tSC57QWCi5aYRvo63fFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-molinos-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4972652, 'longitude': -0.2225333},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '127 Shepherds Bush Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W6 7LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['127 Shepherds Bush Road',
#      'London W6 7LP',
#      'United Kingdom']},
#    'phone': '+442076032229',
#    'display_phone': '+44 20 7603 2229',
#    'distance': 6228.453134414655},
#   {'id': 'dTSM3PhntgDOZlBayZ9LEQ',
#    'alias': 'la-fabrica-london',
#    'name': 'La Fabrica',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iid4fI2sw1NCdd-Tp_07tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-fabrica-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5675496, 'longitude': -0.1090879},
#    'transactions': [],
#    'location': {'address1': '45 Stroud Green Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N4 3EF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Stroud Green Road',
#      'London N4 3EF',
#      'United Kingdom']},
#    'phone': '+442072720020',
#    'display_phone': '+44 20 7272 0020',
#    'distance': 6369.509728197906},
#   {'id': 'zm8F0kYTZXZ7jxGXw-gVMw',
#    'alias': 'boqueria-london-2',
#    'name': 'Boqueria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/S8GwCWRVXR_adNgEfE6lQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boqueria-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4766182969515,
#     'longitude': -0.148112449341489},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '278 Queenstown Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW8 4LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['278 Queenstown Road',
#      'London SW8 4LT',
#      'United Kingdom']},
#    'phone': '+442074988427',
#    'display_phone': '+44 20 7498 8427',
#    'distance': 4114.1633012793955},
#   {'id': 'tHhljazL4CJ8E8GNXZ3xNQ',
#    'alias': 'ibérica-la-terraza-london-7',
#    'name': 'Ibérica La Terraza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fforc6b-alNIRdtaUoTU6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ib%C3%A9rica-la-terraza-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5055353323496,
#     'longitude': -0.0222644797711382},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '12 Cabot Square',
#     'address2': 'Canary Wharf',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E14 4QQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Cabot Square',
#      'Canary Wharf',
#      'London E14 4QQ',
#      'United Kingdom']},
#    'phone': '+442030265118',
#    'display_phone': '+44 20 3026 5118',
#    'distance': 7909.933618140434},
#   {'id': 'UhnSZ8ESjZYEwkdzJ4Jx_A',
#    'alias': 'hola-paella-london-2',
#    'name': 'Hola Paella',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O9njgyiIbaLCH6eLBWYGgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hola-paella-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4816271, 'longitude': -0.0088386},
#    'transactions': [],
#    'location': {'address1': '7 Greenwich Market',
#     'address2': 'Greenwich',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE10 9HZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Greenwich Market',
#      'Greenwich',
#      'London SE10 9HZ',
#      'United Kingdom']},
#    'phone': '+442088580695',
#    'display_phone': '+44 20 8858 0695',
#    'distance': 9459.174442337338},
#   {'id': 'vz-VINQOFosCDVtATsghUg',
#    'alias': 'el-ganso-london',
#    'name': 'El Ganso',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JUn32Qq6Yk3dnMMNy-skxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-ganso-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.53719735, 'longitude': -0.06140592},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '59 Broadway Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 4PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['59 Broadway Market',
#      'London E8 4PH',
#      'United Kingdom']},
#    'phone': '+442072411793',
#    'display_phone': '+44 20 7241 1793',
#    'distance': 5825.667107135062},
#   {'id': 'xlynfBbbLmx6WjO8U_nOJw',
#    'alias': 'trangallán-london-3',
#    'name': 'Trangallán',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/n9BGk3k_3v6TzVfjy-2Ebw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trangall%C3%A1n-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.551188313598,
#     'longitude': -0.086327063756242},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '61 Newington Green',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 9PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Newington Green',
#      'London N16 9PX',
#      'United Kingdom']},
#    'phone': '+442073594988',
#    'display_phone': '+44 20 7359 4988',
#    'distance': 5474.662780961663},
#   {'id': 'ON2WTORm81nZw2L9UXeh5g',
#    'alias': 'carbon-london-4',
#    'name': 'Carbon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/96EcgdunHPkK3lRtAW46JA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carbon-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5108463, 'longitude': -0.1370224},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '78 Brewer Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9TY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['78 Brewer Street',
#      'London W1F 9TY',
#      'United Kingdom']},
#    'phone': '+442077349101',
#    'display_phone': '+44 20 7734 9101',
#    'distance': 233.1812227035964},
#   {'id': 'il6Inhzrqu6VG9JB2yR12g',
#    'alias': 'rosita-and-the-sherry-bar-london',
#    'name': 'Rosita and The Sherry Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xjSVKXt1Tff93biaM7SdmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rosita-and-the-sherry-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4561273, 'longitude': -0.165453999999976},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '124 Northcote Road',
#     'address2': 'London',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW11 6QU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['124 Northcote Road',
#      'London',
#      'London SW11 6QU',
#      'United Kingdom']},
#    'phone': '+442079989093',
#    'display_phone': '+44 20 7998 9093',
#    'distance': 6628.230371791463},
#   {'id': 'LVk2zxRgMun7JuKr-38bzQ',
#    'alias': 'tapas-brindisa-shoreditch-london',
#    'name': 'Tapas Brindisa Shoreditch',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GFY-6RbFrMv4Hg4tzL34Tw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tapas-brindisa-shoreditch-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5268939, 'longitude': -0.0801531},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '152 Curtain Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 3AT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['152 Curtain Road',
#      'London EC2A 3AT',
#      'United Kingdom']},
#    'phone': '+442077499961',
#    'display_phone': '+44 20 7749 9961',
#    'distance': 4165.451407243913},
#   {'id': 'ylcWE2NFp3ybM87CAtpY7g',
#    'alias': 'pix-london-3',
#    'name': 'Pix',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/m8x0qcjaLVwNWOIi39L-Lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pix-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5139808654785,
#     'longitude': -0.132193997502327},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '16 Bateman Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 3AH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Bateman Street',
#      'London W1D 3AH',
#      'United Kingdom']},
#    'phone': '+442074370377',
#    'display_phone': '+44 20 7437 0377',
#    'distance': 289.80142874184395},
#   {'id': 'ytIFY2JvU-zcd1FsonES5w',
#    'alias': 'about-thyme-london',
#    'name': 'About Thyme',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Mh4BT2kuTfm_NFGpOQRFXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/about-thyme-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4924969, 'longitude': -0.1399836},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '82 Wilton Road',
#     'address2': 'Pimlico',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['82 Wilton Road',
#      'Pimlico',
#      'London SW1V 1DL',
#      'United Kingdom']},
#    'phone': '+442078217504',
#    'display_phone': '+44 20 7821 7504',
#    'distance': 2281.829545906066},
#   {'id': 'rQENamiSDknaUFfzHfW6Cw',
#    'alias': 'santa-maria-del-sur-london',
#    'name': 'Santa Maria del Sur',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/StCzT0kvX8pEB1ICYadb2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/santa-maria-del-sur-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'argentine', 'title': 'Argentine'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4701274, 'longitude': -0.1497402},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '129 Queenstown Road',
#     'address2': 'Battersea',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW8 3RH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['129 Queenstown Road',
#      'Battersea',
#      'London SW8 3RH',
#      'United Kingdom']},
#    'phone': '+442076222088',
#    'display_phone': '+44 20 7622 2088',
#    'distance': 4835.108029067291},
#   {'id': 'tdFlULhmRAF5j_tmmP2Ylg',
#    'alias': 'bar-gansa-london',
#    'name': 'Bar Gansa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VqRy8shMqaPEZ9WPnpGLyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-gansa-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5398048, 'longitude': -0.1436027},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Inverness Street',
#     'address2': 'Camden Town',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 7HJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Inverness Street',
#      'Camden Town',
#      'London NW1 7HJ',
#      'United Kingdom']},
#    'phone': '+442072678909',
#    'display_phone': '+44 20 7267 8909',
#    'distance': 3042.044448404408},
#   {'id': '2s0ot8hVF6RO55zxVI04gA',
#    'alias': 'bar-esteban-london',
#    'name': 'Bar Esteban',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5j5FobOWZ6r1VAab7xWdPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-esteban-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.580689, 'longitude': -0.125},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '29 Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N8 8TE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['29 Park Road', 'London N8 8TE', 'United Kingdom']},
#    'phone': '+442083403090',
#    'display_phone': '+44 20 8340 3090',
#    'distance': 7592.5451992033995},
#   {'id': 'kTU1W-EWDtF1Bo3O8bk04Q',
#    'alias': 'la-rueda-london-2',
#    'name': 'La Rueda',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CCxrjp9bA6m6eRerPjI70w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-rueda-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4635887, 'longitude': -0.1334029},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '66 Clapham High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW4 7UL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Clapham High Street',
#      'London SW4 7UL',
#      'United Kingdom']},
#    'phone': '+442076272173',
#    'display_phone': '+44 20 7627 2173',
#    'distance': 5462.901171031538},
#   {'id': 'Xsn3HfVP5_VDjfj91QDMrg',
#    'alias': 'andalucia-london-5',
#    'name': 'Andalucia',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IOaDfXMEertE1g-47cgFlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/andalucia-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.509282, 'longitude': -0.131954},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 Panton St',
#     'address2': 'Haymarket',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 4DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Panton St',
#      'Haymarket',
#      'London SW1Y 4DL',
#      'United Kingdom']},
#    'phone': '+442079309950',
#    'display_phone': '+44 20 7930 9950',
#    'distance': 487.10875105739115},
#   {'id': '9K-A7wHxB-z3n5h-P_mYFA',
#    'alias': 'vinoteca-kings-cross-london',
#    'name': 'Vinoteca Kings Cross',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7EEdDIkdCr9_lZulQOEI6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vinoteca-kings-cross-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5327386594665,
#     'longitude': -0.124989295739738},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'One Pancras Square',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['One Pancras Square',
#      'London N1C 4AG',
#      'United Kingdom']},
#    'phone': '+442037937210',
#    'display_phone': '+44 20 3793 7210',
#    'distance': 2339.5707067138264},
#   {'id': 'JLnG7C_TiDVTpEUEGXIuUg',
#    'alias': 'cigala-restaurant-london',
#    'name': 'Cigala Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2wteyzZ4y4nn2L5ZQvx77g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cigala-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5220678, 'longitude': -0.1183506},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '54 Lambs Conduit Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 3LW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54 Lambs Conduit Street',
#      'London WC1N 3LW',
#      'United Kingdom']},
#    'phone': '+442074051717',
#    'display_phone': '+44 20 7405 1717',
#    'distance': 1588.7018640739159},
#   {'id': 'Wu0K50eeMtE0Cfdky8B_1A',
#    'alias': 'pix-london-2',
#    'name': 'Pix',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1ks_xZg5OZcumlOrO4mT2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pix-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5146598815918,
#     'longitude': -0.126387000083923},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '63 Neal Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9PJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63 Neal Street',
#      'London WC2H 9PJ',
#      'United Kingdom']},
#    'phone': '+442078369779',
#    'display_phone': '+44 20 7836 9779',
#    'distance': 692.53434890955},
#   {'id': 'zWrlXb7JkHWq6t2_W1pYxw',
#    'alias': 'la-farola-london',
#    'name': 'La Farola',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rgeVj9aMVQE-_OJMx3CtKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-farola-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5376652, 'longitude': -0.1029422},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '101 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 1QN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['101 Upper Street',
#      'London N1 1QN',
#      'United Kingdom']},
#    'phone': '+442073597707',
#    'display_phone': '+44 20 7359 7707',
#    'distance': 3583.1777489273027},
#   {'id': 'xI1xAcfE03LoGvV4NvRL-w',
#    'alias': 'pizarro-london',
#    'name': 'Pizarro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uE-s3qUBeLcDuoi_HtTTAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizarro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4984322, 'longitude': -0.081331},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '194 Bermondsey Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 3TQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['194 Bermondsey Street',
#      'London SE1 3TQ',
#      'United Kingdom']},
#    'phone': '+442073789455',
#    'display_phone': '+44 20 7378 9455',
#    'distance': 4111.463567116186},
#   {'id': 'zsLT_xm0wic25gugtfm1sw',
#    'alias': 'la-tasca-london-19',
#    'name': 'La Tasca',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/k9oGS_oFANSsZCYr8w--Cg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-tasca-london-19?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5181950543948,
#     'longitude': -0.0843746697076508},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '16 Eldon Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2M 7',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Eldon Street', 'London EC2M 7', 'United Kingdom']},
#    'phone': '+442072562381',
#    'display_phone': '+44 20 7256 2381',
#    'distance': 3618.6616994224505},
#   {'id': '4j-ZIblF7qeDX9QMvPbtMQ',
#    'alias': 'copita-london',
#    'name': 'Copita',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YYPQcEJ9oII0cHkMw4LLrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/copita-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.514562, 'longitude': -0.135975},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "26-27 D'arblay Street",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["26-27 D'arblay Street",
#      'London W1F 8EP',
#      'United Kingdom']},
#    'phone': '+442072877797',
#    'display_phone': '+44 20 7287 7797',
#    'distance': 188.79060319193078},
#   {'id': 'dyAE0ROgElNHbRa-y3CfFw',
#    'alias': 'sacred-london',
#    'name': 'Sacred',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gbnky4zCMMrFXmkPjO3zlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sacred-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 69,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512954, 'longitude': -0.138923},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '13 Ganton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9BL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Ganton Street',
#      'London W1F 9BL',
#      'United Kingdom']},
#    'phone': '+447595733057',
#    'display_phone': '+44 7595 733057',
#    'distance': 201.35274674274652},
#   {'id': 'C2oJNq6iCz99exi5C5fQrg',
#    'alias': 'aqua-nueva-london-3',
#    'name': 'aqua nueva',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3505YxeVLg6Qu-WS2gl_fA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aqua-nueva-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5144175, 'longitude': -0.1406601},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '5th Floor 240 Regent Street',
#     'address2': 'Entrance 30 Argyll St',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 3BR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5th Floor 240 Regent Street',
#      'Entrance 30 Argyll St',
#      'London W1B 3BR',
#      'United Kingdom']},
#    'phone': '+442074780540',
#    'display_phone': '+44 20 7478 0540',
#    'distance': 370.02277506846934},
#   {'id': 'QJ3F_ZdcvAfyUnLkEoGQng',
#    'alias': 'meson-los-barriles-london',
#    'name': 'Meson Los Barriles',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meson-los-barriles-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5243876, 'longitude': -0.0993866},
#    'transactions': [],
#    'location': {'address1': '55-63 Goswell Road',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EC1V 7EN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55-63 Goswell Road',
#      'London EC1V 7EN',
#      'United Kingdom']},
#    'phone': '+442073360324',
#    'display_phone': '+44 20 7336 0324',
#    'distance': 2837.682928355733},
#   {'id': 'kqv_sWIerU3W4mfUcaVPGw',
#    'alias': 'la-paella-london-2',
#    'name': 'La Paella',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-paella-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.6326696, 'longitude': -0.1269391},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9 The Broadway',
#     'address2': 'Southgate',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N14 6PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 The Broadway',
#      'Southgate',
#      'London N14 6PH',
#      'United Kingdom']},
#    'phone': '+442088827868',
#    'display_phone': '+44 20 8882 7868',
#    'distance': 13339.489562289169},
#   {'id': '5ocwwJ87gbxxL4OksSnr0w',
#    'alias': 'eyre-brothers-london',
#    'name': 'Eyre Brothers',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/01CMPmHnL9DAC-aUjDVJFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eyre-brothers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'portuguese', 'title': 'Portuguese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.524571530634,
#     'longitude': -0.083271497961901},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '70 Leonard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 4QX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['70 Leonard Street',
#      'London EC2A 4QX',
#      'United Kingdom']},
#    'phone': '+442076135346',
#    'display_phone': '+44 20 7613 5346',
#    'distance': 3871.8762602623938},
#   {'id': 'ZRAwGetiZCbOpRuR71kpKg',
#    'alias': 'el-botellon-london',
#    'name': 'El Botellon',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kBjf7ujTMHEGVbn_6tb7Qw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-botellon-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.585665, 'longitude': -0.071372},
#    'transactions': [],
#    'location': {'address1': '260-262 High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N15 4AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['260-262 High Road',
#      'London N15 4AJ',
#      'United Kingdom']},
#    'phone': '+442036455659',
#    'display_phone': '+44 20 3645 5659',
#    'distance': 9236.405344011491},
#   {'id': 'b1-vmsTG-seLeGeRgEipdg',
#    'alias': 'casa-pastor-london-2',
#    'name': 'Casa Pastor',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Wt2gareh10_sFipd_fpmnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-pastor-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5365463, 'longitude': -0.1256003},
#    'transactions': [],
#    'location': {'address1': 'Coal Drops Yard',
#     'address2': 'Stable Street',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N1C 4AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Coal Drops Yard',
#      'Stable Street',
#      'London N1C 4AB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2644.996542723459},
#   {'id': 'QbWOuyyqmNQ5h3nExHS3kg',
#    'alias': 'toresano-ruislip',
#    'name': 'Toresano',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/toresano-ruislip?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.575902, 'longitude': -0.42653},
#    'transactions': [],
#    'location': {'address1': '36 High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Ruislip',
#     'zip_code': 'HA4 7AN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['36 High Street',
#      'Ruislip HA4 7AN',
#      'United Kingdom']},
#    'phone': '+441895633128',
#    'display_phone': '+44 1895 633128',
#    'distance': 21273.029836467154},
#   {'id': 'ewzF05bcn1vhVwSeoEmdcw',
#    'alias': 'jose-pizzaro-london-2',
#    'name': 'Jose Pizzaro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/H4GM9UqTKY7umhPcPlJoqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jose-pizzaro-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.4984688570913,
#     'longitude': -0.0812804527868449},
#    'transactions': [],
#    'location': {'address1': '194-204 Bermondsey Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 3TQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['194-204 Bermondsey Street',
#      'London SE1 3TQ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4107.556555695591},
#   {'id': 'neYFoUgK4PBYFebC17YH6Q',
#    'alias': 'rioja-london',
#    'name': 'Rioja',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rioja-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.6535987, 'longitude': -0.2015337},
#    'transactions': [],
#    'location': {'address1': '1b Church Passage',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EN5 4QS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1b Church Passage',
#      'London EN5 4QS',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 16294.769284018783},
#   {'id': 'CYVTIvc9ef_wqwM_Ep5abQ',
#    'alias': 'buenos-aires-argentine-steakhouse-chiswick-london',
#    'name': 'Buenos Aires Argentine Steakhouse - Chiswick',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EDhnCtD-CPSIO9RD3IAonQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/buenos-aires-argentine-steakhouse-chiswick-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'argentine', 'title': 'Argentine'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4934578712133,
#     'longitude': -0.2550816125879},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '32 Turnham Green Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W4 1QP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['32 Turnham Green Terrace',
#      'London W4 1QP',
#      'United Kingdom']},
#    'phone': '+442087478772',
#    'display_phone': '+44 20 8747 8772',
#    'distance': 8522.249621948045},
#   {'id': 'bAbFz2Q16S7r8eDrEk4TuQ',
#    'alias': 'padron-london-4',
#    'name': 'Padron',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/padron-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.516096, 'longitude': -0.077266},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '13 Harrow Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 7DB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Harrow Place', 'London E1 7DB', 'United Kingdom']},
#    'phone': '+442073778586',
#    'display_phone': '+44 20 7377 8586',
#    'distance': 4088.9292887775014},
#   {'id': '5mHXqAle2fDABAsnekegUg',
#    'alias': 'donde-tapas-london',
#    'name': 'Donde Tapas',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WjBvTkJ3MLgsg_Yca3h-ZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/donde-tapas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.4490063, 'longitude': -0.0433022},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '37-39 Honor Oak Park',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE23 1DZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['37-39 Honor Oak Park',
#      'London SE23 1DZ',
#      'United Kingdom']},
#    'phone': '+442082912822',
#    'display_phone': '+44 20 8291 2822',
#    'distance': 9567.749542265083},
#   {'id': 'cQzR9_RVVPdwWYE7fXL14w',
#    'alias': 'la-rueda-de-tapas-london',
#    'name': 'La Rueda de Tapas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yxEwqDRinOWHgSyKDRa4uQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-rueda-de-tapas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.512287, 'longitude': -0.306182},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '12 Bond Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W5 5AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Bond Street', 'London W5 5AA', 'United Kingdom']},
#    'phone': '+442085674219',
#    'display_phone': '+44 20 8567 4219',
#    'distance': 11778.707877068508},
#   {'id': 'phNAsy-XGDEFAhnkHNodBg',
#    'alias': 'streetxo-london-2',
#    'name': 'StreetXO',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XBgc27ODx6RBDYaMO_nNtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/streetxo-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5113219, 'longitude': -0.1413446},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '15 Old Burlington Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 2JR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Old Burlington Street',
#      'London W1S 2JR',
#      'United Kingdom']},
#    'phone': '+442030967555',
#    'display_phone': '+44 20 3096 7555',
#    'distance': 409.136858066705},
#   {'id': 'PcbpnAstLLgJlG79NWauJg',
#    'alias': 'pix-london-6',
#    'name': 'Pix',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/q3TkEA3oQ7TowWKZLs7RuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pix-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5129536, 'longitude': -0.1392527},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '24 Ganton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7QY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Ganton Street',
#      'London W1F 7QY',
#      'United Kingdom']},
#    'phone': '+442072873031',
#    'display_phone': '+44 20 7287 3031',
#    'distance': 228.52490094199717},
#   {'id': 'LCDyEhT5pYBV43UG7fso4Q',
#    'alias': 'barcelona-tapas-bar-london',
#    'name': 'Barcelona Tapas Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/I5z6DlPCFS1-UPRjebFutA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barcelona-tapas-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.444423988575,
#     'longitude': -0.068610528862175},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '481 Lordship Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE22 8JY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['481 Lordship Lane',
#      'London SE22 8JY',
#      'United Kingdom']},
#    'phone': '+442086935111',
#    'display_phone': '+44 20 8693 5111',
#    'distance': 8922.895090969574},
#   {'id': '3lrsL7fllHtEJ22SWGDzUg',
#    'alias': 'sager-wilde-hackney-road-london',
#    'name': 'Sager + Wilde - Hackney Road',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HngKOdza-CJT_1UecXgBow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sager-wilde-hackney-road-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5309900314205,
#     'longitude': -0.0721368747608334},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '193 Hackney Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 8JL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['193 Hackney Rd', 'London E2 8JL', 'United Kingdom']},
#    'phone': '+442081277330',
#    'display_phone': '+44 20 8127 7330',
#    'distance': 4855.025458634655},
#   {'id': 'flhOrex26o579VSEPjyB6Q',
#    'alias': 'the-queens-head-and-artichoke-london',
#    'name': 'The Queens Head & Artichoke',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QG-7CiFzNqxBurCBo6IMew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-queens-head-and-artichoke-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.525804714038,
#     'longitude': -0.14406230554315},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '32 Albany Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 4EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['32 Albany Street',
#      'London NW1 4EA',
#      'United Kingdom']},
#    'phone': '+442079166206',
#    'display_phone': '+44 20 7916 6206',
#    'distance': 1547.345288351882},
#   {'id': 'szD7qqAsYvCDrVdzvNsWaw',
#    'alias': 'dama-de-elche-london',
#    'name': 'Dama De Elche',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JoRKeUBp3PV9oaVK60ZROA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dama-de-elche-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5752529691535,
#     'longitude': 0.0269579745256365},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '7 Cambridge Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E11 2UA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Cambridge Park Road',
#      'London E11 2UA',
#      'United Kingdom']},
#    'phone': '+442085188111',
#    'display_phone': '+44 20 8518 8111',
#    'distance': 13232.322008410385},
#   {'id': 'Lp5AgT02FlvuS4RKUyE9og',
#    'alias': 'las-iguanas-london',
#    'name': 'Las Iguanas',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tNHwHi66khMmYfcDQt2Ahg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/las-iguanas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 87,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5055947841907,
#     'longitude': -0.117650182564496},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Royal Festival Hall Festival Terrace',
#     'address2': 'Southbank Centre',
#     'address3': 'Belvedere Road',
#     'city': 'London',
#     'zip_code': 'SE1 8XX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Royal Festival Hall Festival Terrace',
#      'Southbank Centre',
#      'Belvedere Road',
#      'London SE1 8XX',
#      'United Kingdom']},
#    'phone': '+442076201328',
#    'display_phone': '+44 20 7620 1328',
#    'distance': 1501.0625729181472},
#   {'id': 'feiMH0ySO0vY-BNPVM14yA',
#    'alias': 'el-molino-beckenham',
#    'name': 'El Molino',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EXAwFy-OHsIUVA0fiCuDAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-molino-beckenham?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.409903, 'longitude': -0.045775},
#    'transactions': [],
#    'location': {'address1': '251 Beckenham Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Beckenham',
#     'zip_code': 'BR3 4RP',
#     'country': 'GB',
#     'state': 'KEN',
#     'display_address': ['251 Beckenham Road',
#      'Beckenham BR3 4RP',
#      'United Kingdom']},
#    'phone': '+442086592622',
#    'display_phone': '+44 20 8659 2622',
#    'distance': 13053.008136816785},
#   {'id': '_7KLULhotVoBPBB_7P-HHA',
#    'alias': 'canas-y-tapas-islington',
#    'name': 'Canas y Tapas',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hArZGKItwYvwjY0HOxUu1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/canas-y-tapas-islington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.5359579780293,
#     'longitude': -0.103617176448103},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '72 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Islington',
#     'zip_code': 'N1 0NY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['72 Upper Street',
#      'Islington N1 0NY',
#      'United Kingdom']},
#    'phone': '+442077046688',
#    'display_phone': '+44 20 7704 6688',
#    'distance': 3408.229162967609}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                 Restaurant                Type Price Rating  \
# 0             Las Barilles  Tapas/Small Plates
# 1         House of Tippler             Spanish   £££    4.5
# 2  Orford Saloon Tapas Bar           Wine Bars  ££££    4.5
# 3              Los Molinos             Spanish    ££      4
# 4               La Fabrica  Tapas/Small Plates
#
#                    Address        Lat       Lng  \
# 0       55-63 Goswell Road  51.524381 -0.099478
# 1        123 Lordship Lane  51.457153 -0.075298
# 2           32 Orford Road  51.582562 -0.013116
# 3  127 Shepherds Bush Road  51.497265 -0.222533
# 4     45 Stroud Green Road  51.567550 -0.109088
#
#                                                  url                      ID
# 0
# 1  https://www.yelp.com/biz/house-of-tippler-lond...  lpggeARkCtGqQ7X5_OZOEQ
# 2  https://www.yelp.com/biz/orford-saloon-tapas-b...  EazZp7bn_8HkTqUscy7Erg
# 3  https://www.yelp.com/biz/los-molinos-london?ad...  EA9cSKJg-Xox0n3u-tmX4A
# 4

# %%
#4th set of 50 records 151-200
lndr_params4 = {"term":term,"location":"London","limit":50,"offset":151}
lndr_response4 = requests.get(search_api_url, headers=headers, params=lndr_params4)
lndr4 = lndr_response4.json()
display(lndr4)
#print(lndr_response4.url)
#print(lndr_response4.status_code)
# Out:
# {'businesses': [{'id': 'utRALTc6JCTWQ2HTPnmH7w',
#    'alias': 'camino-london-6',
#    'name': 'Camino',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yC5eiIWq6HEFficfKkBj0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camino-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.510981239674,
#     'longitude': -0.0816555045794029},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '15 Mincing Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3R 7BD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Mincing Lane',
#      'London EC3R 7BD',
#      'United Kingdom']},
#    'phone': '+442078417335',
#    'display_phone': '+44 20 7841 7335',
#    'distance': 3763.358721084851},
#   {'id': 'uRARkDJS52wlpedM2e9IYg',
#    'alias': 'barsito-london',
#    'name': 'Barsito',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/a4io1oqHpPVxHVKEIlt65g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barsito-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4627495, 'longitude': -0.1379308},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '57 Venn Street',
#     'address2': 'Clapham',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW4 0BD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57 Venn Street',
#      'Clapham',
#      'London SW4 0BD',
#      'United Kingdom']},
#    'phone': '+442076274000',
#    'display_phone': '+44 20 7627 4000',
#    'distance': 5568.43450702354},
#   {'id': '51Nq0e6afkefxTSepcE9Gw',
#    'alias': 'mas-q-menos-london-3',
#    'name': 'Mas Q Menos',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7ZmvHGcJMJSGQk2fLMhs9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mas-q-menos-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5112038, 'longitude': -0.0799059},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '70 Mark Lane',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3R',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['70 Mark Lane', 'London EC3R', 'United Kingdom']},
#    'phone': '+442037780108',
#    'display_phone': '+44 20 3778 0108',
#    'distance': 3876.3211310405036},
#   {'id': 'xWh3to0cBuBvPJBNOK7ckg',
#    'alias': 'seven-at-brixton-london',
#    'name': 'Seven at Brixton',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hsiAynz2wV9z63UlZSd-OA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seven-at-brixton-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4618541743817,
#     'longitude': -0.113437605782599},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 7',
#     'address2': 'Market Row',
#     'address3': 'Brixton',
#     'city': 'London',
#     'zip_code': 'SW9 8LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 7',
#      'Market Row',
#      'Brixton',
#      'London SW9 8LB',
#      'United Kingdom']},
#    'phone': '+442079983309',
#    'display_phone': '+44 20 7998 3309',
#    'distance': 5879.3653037557315},
#   {'id': '7lLl21fX9KOYn0FFxgt4Ow',
#    'alias': 'la-bodeguita-london',
#    'name': 'La Bodeguita',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LH3q0yLTPAKJDNNGAs8wFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-bodeguita-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.493544, 'longitude': -0.09934},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Elephant & Castle Shopping Centre',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 6TE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Elephant & Castle Shopping Centre',
#      'London SE1 6TE',
#      'United Kingdom']},
#    'phone': '+442077019166',
#    'display_phone': '+44 20 7701 9166',
#    'distance': 3320.3351023710875},
#   {'id': '8Sk6aaTxj3OBwJm2txGnfQ',
#    'alias': 'tonteria-london',
#    'name': 'TONTERIA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pwB2xc1lvjQB3-PhbZkJ4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tonteria-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'danceclubs', 'title': 'Dance Clubs'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.49294, 'longitude': -0.1571057},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '7-12 Sloane Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 8EG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7-12 Sloane Square',
#      'London SW1W 8EG',
#      'United Kingdom']},
#    'phone': '+442078815991',
#    'display_phone': '+44 20 7881 5991',
#    'distance': 2652.7742822273945},
#   {'id': 'vWpmjbLkh2KYpajAR-axCQ',
#    'alias': 'e-bar-london',
#    'name': 'E Bar',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/e-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.524174964082,
#     'longitude': -0.18452750044131},
#    'transactions': [],
#    'location': {'address1': '2 Warrington Cresent',
#     'address2': 'Little Venice',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W9 1ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Warrington Cresent',
#      'Little Venice',
#      'London W9 1ER',
#      'United Kingdom']},
#    'phone': '+442074328455',
#    'display_phone': '+44 20 7432 8455',
#    'distance': 3589.5290717619823},
#   {'id': 'e31kDuKb3oyyWwb07stCRg',
#    'alias': 'escocesa-london',
#    'name': 'Escocesa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0jWb3TMPLuke5TUxjUITNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/escocesa-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5621830286786,
#     'longitude': -0.0768258422613144},
#    'transactions': [],
#    'location': {'address1': '67 Stoke Newington Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 0AR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['67 Stoke Newington Church Street',
#      'London N16 0AR',
#      'United Kingdom']},
#    'phone': '+442078129189',
#    'display_phone': '+44 20 7812 9189',
#    'distance': 6843.557709068918},
#   {'id': 'ZvJdA_qzt2sh2EiU3OJhbw',
#    'alias': 'casa-manolo-london-3',
#    'name': 'Casa Manolo',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-manolo-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 51.4625162, 'longitude': -0.2165089},
#    'transactions': [],
#    'location': {'address1': '124 Putney High Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW15 1RG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['124 Putney High Street',
#      'London SW15 1RG',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 7893.143102966074},
#   {'id': 'kuWmJZCAIX_bx7JCBfo_ag',
#    'alias': 'mas-q-menos-london-2',
#    'name': 'Mas Q Menos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/X7NItvVzmrWE4mvuXPTYGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mas-q-menos-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.512912, 'longitude': -0.133448},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '68-70 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0TB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['68-70 Wardour Street',
#      'London W1F 0TB',
#      'United Kingdom']},
#    'phone': '+442072873773',
#    'display_phone': '+44 20 7287 3773',
#    'distance': 173.78105352455785},
#   {'id': '9KmxgynxkZbhXY_KNos3tw',
#    'alias': 'barrio-shoreditch-london',
#    'name': 'Barrio Shoreditch',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LjeSbnnCTjFwCOPllgif2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barrio-shoreditch-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5261481076847,
#     'longitude': -0.0781682810583805},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '141-143 Shoreditch High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6JE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['141-143 Shoreditch High Street',
#      'London E1 6JE',
#      'United Kingdom']},
#    'phone': '+442077493940',
#    'display_phone': '+44 20 7749 3940',
#    'distance': 4263.587338022185},
#   {'id': 'q7t4xq80Is_ND8x68vc5wA',
#    'alias': 'l-entrepot-london',
#    'name': "L'Entrepot",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/U7kx2j_PEjoSJ099BtMUPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-entrepot-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5485053, 'longitude': -0.0610472},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '230 Dalston Lane',
#     'address2': 'Hackney Downs',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 1LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['230 Dalston Lane',
#      'Hackney Downs',
#      'London E8 1LA',
#      'United Kingdom']},
#    'phone': '+442072491176',
#    'display_phone': '+44 20 7249 1176',
#    'distance': 6525.4603747860065},
#   {'id': '6JUS1dP5YeIAp3gqApvwdw',
#    'alias': 'barcelona-tapas-bar-london-3',
#    'name': 'Barcelona Tapas Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HOWkpwkXMpfGzsxVw8z30g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barcelona-tapas-bar-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.515076, 'longitude': -0.075911},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Beaufort House',
#     'address2': '15 St Botolph Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3A 7DT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Beaufort House',
#      '15 St Botolph Street',
#      'London EC3A 7DT',
#      'United Kingdom']},
#    'phone': '+442073775111',
#    'display_phone': '+44 20 7377 5111',
#    'distance': 4175.912568305643},
#   {'id': 'KUD0vbVDakF90njewzcEAg',
#    'alias': 'la-terraza-tapas-bar-and-restaurant-walton-on-thames',
#    'name': 'La Terraza Tapas Bar & Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pp67PfRiLzhJqVm8Vjeelg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-terraza-tapas-bar-and-restaurant-walton-on-thames?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.3763084, 'longitude': -0.4096701},
#    'transactions': [],
#    'location': {'address1': '40 Hersham Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Walton-on-Thames',
#     'zip_code': 'KT12 1JH',
#     'country': 'GB',
#     'state': 'SRY',
#     'display_address': ['40 Hersham Road',
#      'Walton-on-Thames KT12 1JH',
#      'United Kingdom']},
#    'phone': '+441932240867',
#    'display_phone': '+44 1932 240867',
#    'distance': 24319.805307162093},
#   {'id': 'OZKWjttS7iaZgCvFVW_TOg',
#    'alias': 'el-rincon-spanish-tapas-restaurant-epsom',
#    'name': 'El Rincon Spanish Tapas Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9xR5HZUlt_0lp9oj-TZs6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-rincon-spanish-tapas-restaurant-epsom?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.3097858, 'longitude': -0.2411062},
#    'transactions': [],
#    'location': {'address1': '16 Tattenham Crescent',
#     'address2': '',
#     'address3': '',
#     'city': 'Epsom',
#     'zip_code': 'KT18 5QJ',
#     'country': 'GB',
#     'state': 'SRY',
#     'display_address': ['16 Tattenham Crescent',
#      'Epsom KT18 5QJ',
#      'United Kingdom']},
#    'phone': '+441737373647',
#    'display_phone': '+44 1737 373647',
#    'distance': 23726.094277601183},
#   {'id': 'hyfTBdIJr7ulsCbHlyIxGA',
#    'alias': 'ember-yard-london',
#    'name': 'Ember Yard',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TY6QMjbuTPRZNmg3los70w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ember-yard-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5154159, 'longitude': -0.1366013},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '60-61 Berwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8SU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['60-61 Berwick Street',
#      'London W1F 8SU',
#      'United Kingdom']},
#    'phone': '+442074398057',
#    'display_phone': '+44 20 7439 8057',
#    'distance': 290.3806972617578},
#   {'id': 'PWyrmKw-w70lBIR9a9qHZw',
#    'alias': 'gremio-de-brixton-london',
#    'name': 'Gremio de Brixton',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/95s91k-SxMBK1kwDjt2gew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gremio-de-brixton-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4598375615174,
#     'longitude': -0.115986530074246},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'The Crypt Brixton Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW2 1JF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Crypt Brixton Hill',
#      'London SW2 1JF',
#      'United Kingdom']},
#    'phone': '+442079240660',
#    'display_phone': '+44 20 7924 0660',
#    'distance': 6053.13533710378},
#   {'id': 'HhNdh5ubnqryHEyt_-61Cw',
#    'alias': 'spanish-tapas-bar-london',
#    'name': 'Spanish Tapas Bar',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spanish-tapas-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 51.4893303, 'longitude': -0.22299},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Fulham Palace road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W6 9PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Fulham Palace road',
#      'London W6 9PH',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6581.3993017186785},
#   {'id': 'WP6o9WXBRyt3b3MJhNxOIg',
#    'alias': 'escudo-de-cuba-london',
#    'name': 'Escudo de Cuba',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vJbTyrzWyxbQPudQOwVeMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/escudo-de-cuba-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5511021971743,
#     'longitude': -0.0750197097659111},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Stoke Newington Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 7XN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Stoke Newington Road',
#      'London N16 7XN',
#      'United Kingdom']},
#    'phone': '+442072499794',
#    'display_phone': '+44 20 7249 9794',
#    'distance': 5989.343477666841},
#   {'id': '3851C1ulFmiDKJAykfG10w',
#    'alias': 'wc-wine-and-charcuterie-london',
#    'name': 'WC Wine & Charcuterie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/POgXmTTnHOQOiAIm_sndxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wc-wine-and-charcuterie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.461802, 'longitude': -0.137783},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Clapham Common',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW4 7AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Clapham Common', 'London SW4 7AA', 'United Kingdom']},
#    'phone': '+442076225502',
#    'display_phone': '+44 20 7622 5502',
#    'distance': 5676.072459889173},
#   {'id': 'OcXVh5CsOJlpGEE4xEPlmQ',
#    'alias': 'blues-tapas-bar-harrow',
#    'name': 'Blues Tapas Bar',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blues-tapas-bar-harrow?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5706618659331,
#     'longitude': -0.339819100239505},
#    'transactions': [],
#    'location': {'address1': '86 High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Harrow',
#     'zip_code': 'HA1 3LW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['86 High Street', 'Harrow HA1 3LW', 'United Kingdom']},
#    'phone': '+442084233888',
#    'display_phone': '+44 20 8423 3888',
#    'distance': 15495.615838787186},
#   {'id': 'aNe-csvGyoEkw62ysRbqpA',
#    'alias': 'the-distillery-london-3',
#    'name': 'The Distillery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6qYa5K11h32iF0-vGRvAyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-distillery-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'distilleries', 'title': 'Distilleries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5160106198114,
#     'longitude': -0.204917461249907},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '186 Portobello Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W11 2DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['186 Portobello Road',
#      'London W11 2DY',
#      'United Kingdom']},
#    'phone': '+442030342233',
#    'display_phone': '+44 20 3034 2233',
#    'distance': 4785.083885315025},
#   {'id': 'Ne9TlgOa8bMjaKbVZhlDTQ',
#    'alias': 'la-tasca-watford',
#    'name': 'La Tasca',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-tasca-watford?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.6578635, 'longitude': -0.3992325},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '63 The Parade',
#     'address2': 'High Street',
#     'address3': None,
#     'city': 'Watford',
#     'zip_code': 'WD17 1LJ',
#     'country': 'GB',
#     'state': 'HRT',
#     'display_address': ['63 The Parade',
#      'High Street',
#      'Watford WD17 1LJ',
#      'United Kingdom']},
#    'phone': '+441923223545',
#    'display_phone': '+44 1923 223545',
#    'distance': 24309.112032460715},
#   {'id': '5Z7s-dok_OPzGB6VHlvmGQ',
#    'alias': 'el-meson-de-los-hermanos-weybridge',
#    'name': 'El Meson De Los Hermanos',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vlyWLYSaLr6vHhLuC8iTWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-meson-de-los-hermanos-weybridge?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.372337, 'longitude': -0.457783},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'El Mason De Los Hermanos',
#     'address2': '20 Baker Street',
#     'address3': '',
#     'city': 'Weybridge',
#     'zip_code': 'KT13 8AU',
#     'country': 'GB',
#     'state': 'SRY',
#     'display_address': ['El Mason De Los Hermanos',
#      '20 Baker Street',
#      'Weybridge KT13 8AU',
#      'United Kingdom']},
#    'phone': '+441932851333',
#    'display_phone': '+44 1932 851333',
#    'distance': 27223.122813817936},
#   {'id': 'VnQRdomGigExJ62ssOMEqw',
#    'alias': 'galicia-tapas-bar-croydon',
#    'name': 'Galicia Tapas Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8snMFwUXgvtvDHPWqxV7Bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/galicia-tapas-bar-croydon?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.3684044, 'longitude': -0.0990967},
#    'transactions': [],
#    'location': {'address1': '269-275 High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Croydon',
#     'zip_code': 'CR0 1QH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['269-275 High Street',
#      'Croydon CR0 1QH',
#      'United Kingdom']},
#    'phone': '+442086860043',
#    'display_phone': '+44 20 8686 0043',
#    'distance': 16252.960090252696},
#   {'id': 'A_FDLFIIzyReg7k7VhxBlQ',
#    'alias': 'the-little-taperia-london',
#    'name': 'The Little Taperia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Gl7W37mDDe5VrBTKSfPQhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-little-taperia-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4254684, 'longitude': -0.1701196},
#    'transactions': [],
#    'location': {'address1': '143 Tooting High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW17 0SY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['143 Tooting High Street',
#      'London SW17 0SY',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9999.894086664091},
#   {'id': 'QVnFjlRLno_xU2nminAx-g',
#    'alias': 'tapas-revolution-london',
#    'name': 'Tapas Revolution',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3RoAwrngCclTDRLvL82LFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tapas-revolution-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.507247, 'longitude': -0.22233},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Kiosk K2024 The Balcony',
#     'address2': "Shepherd's Bush",
#     'address3': 'Westfield',
#     'city': 'London',
#     'zip_code': 'W12 7SL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Kiosk K2024 The Balcony',
#      "Shepherd's Bush",
#      'Westfield',
#      'London W12 7SL',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6009.751358920538},
#   {'id': 'gATRnvLwTDttFrqpqlzO7g',
#    'alias': 'the-place-london-8',
#    'name': 'The Place',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4x4gYpCs9myJxhU5xmcHhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-place-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5248790933708,
#     'longitude': -0.143438838422298},
#    'transactions': [],
#    'location': {'address1': 'Albany Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW1 3UP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Albany Street', 'London NW1 3UP', 'United Kingdom']},
#    'phone': '+442073913000',
#    'display_phone': '+44 20 7391 3000',
#    'distance': 1435.7887970669576},
#   {'id': 'mM13I6b3emWA8KthSxmXYg',
#    'alias': '28-50-wine-workshop-and-kitchen-london',
#    'name': '28-50 Wine Workshop and Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rR9H0qF7ljt7EiBrC3uh-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/28-50-wine-workshop-and-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516357, 'longitude': -0.150488},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '15-17 Marylebone Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 2NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15-17 Marylebone Lane',
#      'London W1U 2NE',
#      'United Kingdom']},
#    'phone': '+442074867922',
#    'display_phone': '+44 20 7486 7922',
#    'distance': 1075.8878616539794},
#   {'id': 'nqm8ums0ScLCYNM3LqLpUQ',
#    'alias': 'spit-jack-london',
#    'name': 'Spit Jack',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RdZeq8ztmHvm_5pMzSeruA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spit-jack-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5377471515622,
#     'longitude': -0.0446883256715291},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '87 Lauriston Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E9 7HJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['87 Lauriston Road',
#      'London E9 7HJ',
#      'United Kingdom']},
#    'phone': '+442089857773',
#    'display_phone': '+44 20 8985 7773',
#    'distance': 6894.965311819471},
#   {'id': '2x69VoFtdCoCygZYn4D5Lg',
#    'alias': 'del-parc-london',
#    'name': 'Del Parc',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/70f-z08tlf57yvMyXCLupA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/del-parc-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5605902, 'longitude': -0.1370335},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '167 Junction Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N19 5PZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['167 Junction Road',
#      'London N19 5PZ',
#      'United Kingdom']},
#    'phone': '+442072815684',
#    'display_phone': '+44 20 7281 5684',
#    'distance': 5316.539879030537},
#   {'id': 'N0HEQOApGTVm1XAIAyknlw',
#    'alias': 'the-almond-london',
#    'name': 'The Almond',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-almond-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4434433, 'longitude': -0.1673876},
#    'transactions': [],
#    'location': {'address1': '216 Trinity Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW17 7HP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['216 Trinity Road',
#      'London SW17 7HP',
#      'United Kingdom']},
#    'phone': '+442086722651',
#    'display_phone': '+44 20 8672 2651',
#    'distance': 8016.215779579686},
#   {'id': 'M3jV-lr-8IQ2dKabeMidnw',
#    'alias': 'donostia-social-club-london',
#    'name': 'Donostia Social Club',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gf6HC-ZnLFbrFp9CEbptiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/donostia-social-club-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'streetvendors', 'title': 'Street Vendors'},
#     {'alias': 'basque', 'title': 'Basque'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.505776, 'longitude': -0.116837},
#    'transactions': [],
#    'location': {'address1': 'Southbank Centre',
#     'address2': 'Belvedere Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8XX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Southbank Centre',
#      'Belvedere Road',
#      'London SE1 8XX',
#      'United Kingdom']},
#    'phone': '+447961844464',
#    'display_phone': '+44 7961 844464',
#    'distance': 1615.058549721907},
#   {'id': 'BOLG1b3ajFUjoeWJ2gL2hw',
#    'alias': 'el-molino-london-2',
#    'name': 'El Molino',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/25EnyREgIHO4BoED1N9krQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-molino-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.557019542423,
#     'longitude': -0.11867876519908},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '379 Holloway Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N7 0RN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['379 Holloway Road',
#      'London N7 0RN',
#      'United Kingdom']},
#    'phone': '+442077004312',
#    'display_phone': '+44 20 7700 4312',
#    'distance': 5056.277313603139},
#   {'id': 'YYnDf_8y6E4DJ1cPSlTqhQ',
#    'alias': 'r-s-hispaniola-london',
#    'name': 'R.S. Hispaniola',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xAONJuT8F8Eh_qL3SQuk2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/r-s-hispaniola-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.506299, 'longitude': -0.121931},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Victoria Embankment',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 5DJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Victoria Embankment',
#      'London WC2N 5DJ',
#      'United Kingdom']},
#    'phone': '+442078393011',
#    'display_phone': '+44 20 7839 3011',
#    'distance': 1194.193088782509},
#   {'id': 'q6KDb7nOXgQa5GTWBaCoCQ',
#    'alias': 'ciao-bella-london',
#    'name': 'Ciao Bella',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DDU7AnXNVg-B10Ogp1sXPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ciao-bella-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 124,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5232425139546,
#     'longitude': -0.119118084823987},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '86-90 Lambs Conduit Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 3LZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['86-90 Lambs Conduit Street',
#      'London WC1N 3LZ',
#      'United Kingdom']},
#    'phone': '+442072424119',
#    'display_phone': '+44 20 7242 4119',
#    'distance': 1642.092422047072},
#   {'id': 'm44y9fYDtQyZjGa2DzBaxw',
#    'alias': 'la-movida-london',
#    'name': 'La Movida',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-movida-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4714871, 'longitude': -0.168309},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '300 Battersea Park Road',
#     'address2': 'Battersea',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW11 3BU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['300 Battersea Park Road',
#      'Battersea',
#      'London SW11 3BU',
#      'United Kingdom']},
#    'phone': '+442079242595',
#    'display_phone': '+44 20 7924 2595',
#    'distance': 5114.313585616344},
#   {'id': 'mrG0vi01CXLqvyOglUiEnw',
#    'alias': 'bar-61-restaurant-london',
#    'name': 'Bar 61 Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cV04Wb7PxJagkNUyT0UvoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-61-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.439928, 'longitude': -0.125533},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61a Streatham Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW2 4TX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61a Streatham Hill',
#      'London SW2 4TX',
#      'United Kingdom']},
#    'phone': '+442086710444',
#    'display_phone': '+44 20 8671 0444',
#    'distance': 8125.590686941383},
#   {'id': 'GIYuIKAtv99pIYvgwPODGA',
#    'alias': 'la-tasca-london-16',
#    'name': 'La Tasca',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YJ3oUszTTC2AP2YtXisgyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-tasca-london-16?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5762, 'longitude': 0.17825},
#    'transactions': [],
#    'location': {'address1': 'The Brewery',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'RM1 1AU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Brewery', 'London RM1 1AU', 'United Kingdom']},
#    'phone': '+441708734662',
#    'display_phone': '+44 1708 734662',
#    'distance': 22841.998604382905},
#   {'id': '3jUuBgt_V3GuCXf2PP-mbg',
#    'alias': 'wine-rooms-london',
#    'name': 'Wine Rooms',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2lGvX6fzPKDDAMNCY8O16g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wine-rooms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5072869094514,
#     'longitude': -0.194856309601584},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '127-129 Kensington Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 7LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['127-129 Kensington Church Street',
#      'London W8 7LP',
#      'United Kingdom']},
#    'phone': '+442077278142',
#    'display_phone': '+44 20 7727 8142',
#    'distance': 4122.643871096528},
#   {'id': 'EEh6PB9ePIIi775y9Ku2-w',
#    'alias': 'la-sala-woodford',
#    'name': 'La Sala',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-sala-woodford?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.6061603, 'longitude': 0.0545526},
#    'transactions': [],
#    'location': {'address1': '692-694 Chigwell Road',
#     'address2': 'Woodford Green',
#     'address3': '',
#     'city': 'Woodford',
#     'zip_code': 'IG8 8AL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['692-694 Chigwell Road',
#      'Woodford Green',
#      'Woodford IG8 8AL',
#      'United Kingdom']},
#    'phone': '+443330063008',
#    'display_phone': '+44 333 006 3008',
#    'distance': 16771.006299150868},
#   {'id': 'clo4E_IPi_VXFV-IckDiPw',
#    'alias': 'may-fair-kitchen-mayfair',
#    'name': 'May Fair Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LnzPq39FcTP29elt38WnLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/may-fair-kitchen-mayfair?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5078956507983,
#     'longitude': -0.143862962722778},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'Stratton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Mayfair',
#     'zip_code': 'W1J 8LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Stratton Street',
#      'Mayfair W1J 8LT',
#      'United Kingdom']},
#    'phone': '+442079153892',
#    'display_phone': '+44 20 7915 3892',
#    'distance': 775.3436910023726},
#   {'id': 'byZ5PAOeIHFkhAjuu2DQPg',
#    'alias': 'pisqu-london-2',
#    'name': 'Pisqu',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XwObFZB6-w1q8fgt9-ldjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pisqu-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5176582336426,
#     'longitude': -0.13391800224781},
#    'transactions': [],
#    'location': {'address1': '23 Rathbone Place',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 1HZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23 Rathbone Place',
#      'London W1T 1HZ',
#      'United Kingdom']},
#    'phone': '+442074366123',
#    'display_phone': '+44 20 7436 6123',
#    'distance': 554.7961616719069},
#   {'id': 'MBBzQuIyJq_ZNAnjW61azQ',
#    'alias': 'mezzet-dar-tapas-restaurant-east-molesey',
#    'name': 'Mezzet Dar Tapas Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ufhii2RXh6GgXfjpaCqSTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mezzet-dar-tapas-restaurant-east-molesey?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'lebanese', 'title': 'Lebanese'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4018123, 'longitude': -0.3456016},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '39 Bridge Road',
#     'address2': 'Hampton Court',
#     'address3': 'London',
#     'city': 'East Molesey',
#     'zip_code': 'KT8 9ER',
#     'country': 'GB',
#     'state': 'SRY',
#     'display_address': ['39 Bridge Road',
#      'Hampton Court',
#      'London',
#      'East Molesey KT8 9ER',
#      'United Kingdom']},
#    'phone': '+442087830149',
#    'display_phone': '+44 20 8783 0149',
#    'distance': 19062.773126914373},
#   {'id': 'kcL2FigiqepZjr732Mdtig',
#    'alias': 'salvador-and-amanda-london-3',
#    'name': 'Salvador and Amanda',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JReYGHu7lpOuNTMhqxdWXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salvador-and-amanda-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.518858, 'longitude': -0.1216333},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Vernon Place',
#     'address2': 'Bloomsbury',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1A 2EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Vernon Place',
#      'Bloomsbury',
#      'London WC1A 2EP',
#      'United Kingdom']},
#    'phone': '+442076372960',
#    'display_phone': '+44 20 7637 2960',
#    'distance': 1196.104348089743},
#   {'id': 'ez94fqWsdoVPiFAZc8BNMg',
#    'alias': 'las-fuentes-purley',
#    'name': 'Las Fuentes',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/p_FGSmvv5iVqHA4WfHjm6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/las-fuentes-purley?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.3386666, 'longitude': -0.1152227},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '38-40 High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Purley',
#     'zip_code': 'CR8 2AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38-40 High Street',
#      'Purley CR8 2AA',
#      'United Kingdom']},
#    'phone': '+442087631983',
#    'display_phone': '+44 20 8763 1983',
#    'distance': 19437.18978538581},
#   {'id': '3A72QNxsBegPsBG9QLFzEA',
#    'alias': 'el-nido-london',
#    'name': 'El Nido',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-nido-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.3617395, 'longitude': -0.1503624},
#    'transactions': [],
#    'location': {'address1': '79 Manor Road',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SM6 0DE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['79 Manor Road', 'London SM6 0DE', 'United Kingdom']},
#    'phone': '+442086470940',
#    'display_phone': '+44 20 8647 0940',
#    'distance': 16830.7428785417},
#   {'id': 'aYogX-UglExoiBAY8FCi9A',
#    'alias': 'café-kick-london-3',
#    'name': 'Café Kick',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KcrOAPXYXKJIkQIP2ZS8Yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-kick-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5261213, 'longitude': -0.1089813},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '43 Exmouth Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 4QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['43 Exmouth Market',
#      'London EC1R 4QL',
#      'United Kingdom']},
#    'phone': '+442078378077',
#    'display_phone': '+44 20 7837 8077',
#    'distance': 2371.741549935536},
#   {'id': '1xOGuRkmfEd-j8Avs4-MuQ',
#    'alias': '3b-london',
#    'name': '3B',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DtaXM5_QzixASCZdZz8NQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/3b-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 51.5170479, 'longitude': -0.188208},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '43 Porchester Road',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 5DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['43 Porchester Road',
#      'London W2 5DP',
#      'United Kingdom']},
#    'phone': '+442077925885',
#    'display_phone': '+44 20 7792 5885',
#    'distance': 3645.9435898206416},
#   {'id': '7XmKJcAcVdUx74sH7NFA_g',
#    'alias': 'hide-london',
#    'name': 'Hide',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eKTpFUfYIlbJaw9f5CCStQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hide-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5061568370745,
#     'longitude': -0.144324263574846},
#    'transactions': [],
#    'location': {'address1': '85 Piccadilly',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1J 7NB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['85 Piccadilly', 'London W1J 7NB', 'United Kingdom']},
#    'phone': '+442031468666',
#    'display_phone': '+44 20 3146 8666',
#    'distance': 941.7631440041313}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#          Restaurant                Type Price Rating  \
# 0            Camino             Spanish    ££    3.5
# 1           Barsito  Tapas/Small Plates    ££    3.5
# 2       Mas Q Menos           Wine Bars    ££      3
# 3  Seven at Brixton             Spanish    ££      4
# 4      La Bodeguita             Grocery    ££      3
#
#                              Address        Lat       Lng  \
# 0                    15 Mincing Lane  51.510981 -0.081656
# 1                     57 Venn Street  51.462750 -0.137931
# 2                       70 Mark Lane  51.511204 -0.079906
# 3                             Unit 7  51.461854 -0.113438
# 4  Elephant & Castle Shopping Centre  51.493544 -0.099340
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/camino-london-6?adjus...  utRALTc6JCTWQ2HTPnmH7w
# 1  https://www.yelp.com/biz/barsito-london?adjust...  uRARkDJS52wlpedM2e9IYg
# 2  https://www.yelp.com/biz/mas-q-menos-london-3?...  51Nq0e6afkefxTSepcE9Gw
# 3  https://www.yelp.com/biz/seven-at-brixton-lond...  xWh3to0cBuBvPJBNOK7ckg
# 4  https://www.yelp.com/biz/la-bodeguita-london?a...  7lLl21fX9KOYn0FFxgt4Ow

# %%
london_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
london_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_restaurants_df = london_restaurants_df[column_order]
london_restaurants_df = london_restaurants_df.sort_values(["Type"], ascending=True)
london_restaurants_df = london_restaurants_df.reset_index(drop=True)
london_restaurants_df
# Out:
#                                        Restaurant                  Type  \
# 0    Buenos Aires Argentine Steakhouse - Chiswick             Argentine
# 1                                          Carbon              Barbeque
# 2                                         La Sala                  Bars
# 3                                          Camino                  Bars
# 4                                          Ametsa                Basque
# 5                      Eneko Basque Kitchen & Bar                Basque
# 6                            Donostia Social Club                Basque
# 7                       Bedales of Borough Market  Beer, Wine & Spirits
# 8                                          Andina    Breakfast & Brunch
# 9                     The Queens Head & Artichoke               British
# 10                                    Casa Manalo                 Cafes
# 11                              Barrio Shoreditch         Cocktail Bars
# 12                                    Casa Pastor         Cocktail Bars
# 13                                  Señor Ceviche         Cocktail Bars
# 14                                 The Distillery         Cocktail Bars
# 15                                         Sacred          Coffee & Tea
# 16                                 Escudo de Cuba                 Cuban
# 17                                           Hide                French
# 18                                      La Movida                 Greek
# 19                                   La Bodeguita               Grocery
# 20                               May Fair Kitchen               Italian
# 21                                     Ciao Bella               Italian
# 22                                    Las Iguanas        Latin American
# 23                        Donde Carlos Restaurant        Latin American
# 24                                      El Vergel        Latin American
# 25                                         Cubana        Latin American
# 26                              Mi Cocina Es Tuya        Latin American
# 27                              El Rincon Quiteño        Latin American
# 28                                         Tito's        Latin American
# 29                    Mezzet Dar Tapas Restaurant              Lebanese
# ..                                            ...                   ...
# 170                                      El Ganso    Tapas/Small Plates
# 171                                    Miss Tapas    Tapas/Small Plates
# 172                                       Barsito    Tapas/Small Plates
# 173                                           Pix    Tapas/Small Plates
# 174                                    La Fabrica    Tapas/Small Plates
# 175                                      Escocesa    Tapas/Small Plates
# 176                                   Casa Manolo    Tapas/Small Plates
# 177                                      StreetXO    Tapas/Small Plates
# 178                                        Morito    Tapas/Small Plates
# 179                                         Twist    Tapas/Small Plates
# 180                                       Condesa    Tapas/Small Plates
# 181                                     Barrafina    Tapas/Small Plates
# 182                                     Las Tapas    Tapas/Small Plates
# 183                                  Las Barilles    Tapas/Small Plates
# 184                          Lobos Meat and Tapas    Tapas/Small Plates
# 185                                       Iberica    Tapas/Small Plates
# 186                                        Camino    Tapas/Small Plates
# 187                                       Iberica             Wine Bars
# 188                  Sager + Wilde - Hackney Road             Wine Bars
# 189                         WC Wine & Charcuterie             Wine Bars
# 190                                    L'Entrepot             Wine Bars
# 191                                   Mas Q Menos             Wine Bars
# 192                                   Levante Bar             Wine Bars
# 193                          Vinoteca Kings Cross             Wine Bars
# 194                              Meson Don Felipe             Wine Bars
# 195                                   Casa Manolo             Wine Bars
# 196                       Orford Saloon Tapas Bar             Wine Bars
# 197                                     Albertine             Wine Bars
# 198               28-50 Wine Workshop and Kitchen             Wine Bars
# 199                                      Terroirs             Wine Bars
#
#     Rating Price                               Address        Lat       Lng  \
# 0        4   £££              32 Turnham Green Terrace  51.493458 -0.255082
# 1      3.5     £                      78 Brewer Street  51.510846 -0.137022
# 2                                692-694 Chigwell Road  51.606160  0.054553
# 3      3.5    ££                     3 Varnishers Yard  51.531294 -0.121794
# 4        4  ££££                     5-6 Halkin Street  51.500848 -0.151867
# 5      4.5   £££                             1 Aldwych  51.511783 -0.119417
# 6                              49 Brixton Station Road  51.463422 -0.112375
# 7        4    ££                       5 Bedale Street  51.505406 -0.089834
# 8        4    ££                    1 Redchurch Street  51.524321 -0.077135
# 9      3.5    ££                      32 Albany Street  51.525805 -0.144062
# 10                                     43 Upper Street  51.534993 -0.104804
# 11       3    ££        141-143 Shoreditch High Street  51.526148 -0.078168
# 12                                     Coal Drops Yard  51.536546 -0.125600
# 13       4    ££                          Kingly Court  51.512410 -0.138580
# 14     4.5    ££                   186 Portobello Road  51.516011 -0.204917
# 15       4     £                      13 Ganton Street  51.512954 -0.138923
# 16       4    ££               20 Stoke Newington Road  51.551102 -0.075020
# 17                                       85 Piccadilly  51.506157 -0.144324
# 18       4     £               300 Battersea Park Road  51.471487 -0.168309
# 19       3    ££     Elephant & Castle Shopping Centre  51.493544 -0.099340
# 20       4  ££££                       Stratton Street  51.507896 -0.143863
# 21       4    ££            86-90 Lambs Conduit Street  51.523243 -0.119118
# 22       3    ££  Royal Festival Hall Festival Terrace  51.505595 -0.117650
# 23     4.5    ££                     143 Goldhawk Road  51.501320 -0.231422
# 24     3.5     £                     132 Webber Street  51.500707 -0.099151
# 25     3.5    ££                        48 Lower Marsh  51.501519 -0.110860
# 26       4    ££                          61 Westow St  51.417775 -0.082018
# 27       4     £                     235 Holloway Road  51.551448 -0.111144
# 28                                   273A Clapham Road  51.470964 -0.123442
# 29       4    ££                        39 Bridge Road  51.401812 -0.345602
# ..     ...   ...                                   ...        ...       ...
# 170      4    ££                    59 Broadway Market  51.537197 -0.061406
# 171    4.5    ££                      46 Choumert Road  51.468186 -0.069179
# 172    3.5    ££                        57 Venn Street  51.462750 -0.137931
# 173    3.5    ££                      24 Ganton Street  51.512954 -0.139253
# 174                               45 Stroud Green Road  51.567550 -0.109088
# 175                   67 Stoke Newington Church Street  51.562183 -0.076826
# 176                             124 Putney High Street  51.462516 -0.216509
# 177      4  ££££              15 Old Burlington Street  51.511322 -0.141345
# 178      4    ££                     32 Exmouth Market  51.525871 -0.108858
# 179    4.5   £££                    42 Crawford Street  51.519301 -0.162382
# 180    4.5    ££                        15 Maiden Lane  51.510600 -0.123181
# 181      4   £££                        26 Dean Street  51.514227 -0.132764
# 182    3.5   £££               108 Holland Park Avenue  51.506760 -0.207251
# 183                                 55-63 Goswell Road  51.524381 -0.099478
# 184    4.5   £££                14 Borough High Street  51.505626 -0.089151
# 185      4   £££            Unit 5- 6 Zig Zag Building  51.497435 -0.138477
# 186      4    ££                       5 Canvey Street  51.505890 -0.099450
# 187      4   £££             195 Great Portland Street  51.522476 -0.143939
# 188    4.5   £££                        193 Hackney Rd  51.530990 -0.072137
# 189    4.5    ££                        Clapham Common  51.461802 -0.137783
# 190      4    ££                      230 Dalston Lane  51.548505 -0.061047
# 191      3    ££                          70 Mark Lane  51.511204 -0.079906
# 192    3.5    ££                     14 Hertsmere Road  51.507445 -0.022930
# 193      4    ££                    One Pancras Square  51.532739 -0.124989
# 194      4    ££                            53 The Cut  51.502967 -0.107201
# 195                                          99 Strand  51.510445 -0.120575
# 196    4.5  ££££                        32 Orford Road  51.582562 -0.013116
# 197    4.5    ££                           1 Wood Lane  51.505571 -0.224831
# 198      4   £££                 15-17 Marylebone Lane  51.516357 -0.150488
# 199    4.5   £££                   5 William IV Street  51.509355 -0.125207
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/buenos-aires-argentin...  CYVTIvc9ef_wqwM_Ep5abQ
# 1    https://www.yelp.com/biz/carbon-london-4?adjus...  ON2WTORm81nZw2L9UXeh5g
# 2
# 3    https://www.yelp.com/biz/camino-london?adjust_...  OyLrjCVSSp5UUAYe9Vm0Hg
# 4    https://www.yelp.com/biz/ametsa-london-2?adjus...  uLJp1QsowWjJ9qNXHZIIpw
# 5    https://www.yelp.com/biz/eneko-basque-kitchen-...  IjezoTAhQT2yV1UchKLtgA
# 6
# 7    https://www.yelp.com/biz/bedales-of-borough-ma...  aywIyiNMxy4nbBabMGK1Vw
# 8    https://www.yelp.com/biz/andina-london?adjust_...  vCF8ut7OZcfA4hEmhngfSQ
# 9    https://www.yelp.com/biz/the-queens-head-and-a...  flhOrex26o579VSEPjyB6Q
# 10
# 11   https://www.yelp.com/biz/barrio-shoreditch-lon...  9KmxgynxkZbhXY_KNos3tw
# 12
# 13   https://www.yelp.com/biz/se%C3%B1or-ceviche-lo...  _hiTEsg7MgrFNfZRl8mksA
# 14   https://www.yelp.com/biz/the-distillery-london...  aNe-csvGyoEkw62ysRbqpA
# 15   https://www.yelp.com/biz/sacred-london?adjust_...  dyAE0ROgElNHbRa-y3CfFw
# 16   https://www.yelp.com/biz/escudo-de-cuba-london...  WP6o9WXBRyt3b3MJhNxOIg
# 17
# 18   https://www.yelp.com/biz/la-movida-london?adju...  m44y9fYDtQyZjGa2DzBaxw
# 19   https://www.yelp.com/biz/la-bodeguita-london?a...  7lLl21fX9KOYn0FFxgt4Ow
# 20   https://www.yelp.com/biz/may-fair-kitchen-mayf...  clo4E_IPi_VXFV-IckDiPw
# 21   https://www.yelp.com/biz/ciao-bella-london?adj...  q6KDb7nOXgQa5GTWBaCoCQ
# 22   https://www.yelp.com/biz/las-iguanas-london?ad...  Lp5AgT02FlvuS4RKUyE9og
# 23   https://www.yelp.com/biz/donde-carlos-restaura...  fGxj4hAdOocY8bcXiNY1gA
# 24   https://www.yelp.com/biz/el-vergel-london?adju...  vBEQW6eX3DFYlDgrzr8VCQ
# 25   https://www.yelp.com/biz/cubana-london?adjust_...  WreNoNYNkQ7b5OI_ZCsSnQ
# 26   https://www.yelp.com/biz/mi-cocina-es-tuya-lon...  nMDC_0s833y6uWDzEEIWRA
# 27   https://www.yelp.com/biz/el-rincon-quite%C3%B1...  c-cEnOLF6sCJaTLxFaX1SQ
# 28
# 29   https://www.yelp.com/biz/mezzet-dar-tapas-rest...  MBBzQuIyJq_ZNAnjW61azQ
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/el-ganso-london?adjus...  vz-VINQOFosCDVtATsghUg
# 171  https://www.yelp.com/biz/miss-tapas-london?adj...  1saSQJuhKzjWbhWSAcfpNg
# 172  https://www.yelp.com/biz/barsito-london?adjust...  uRARkDJS52wlpedM2e9IYg
# 173  https://www.yelp.com/biz/pix-london-6?adjust_c...  PcbpnAstLLgJlG79NWauJg
# 174
# 175
# 176
# 177  https://www.yelp.com/biz/streetxo-london-2?adj...  phNAsy-XGDEFAhnkHNodBg
# 178  https://www.yelp.com/biz/morito-london?adjust_...  fpIx8nCBRqtImTkGJ-ujuQ
# 179  https://www.yelp.com/biz/twist-london-2?adjust...  BVlzDuPtmnupkLA41HaH5A
# 180  https://www.yelp.com/biz/condesa-london?adjust...  NtAndbH_o7DQLLDz-wuGlA
# 181  https://www.yelp.com/biz/barrafina-london-6?ad...  qvO0hYRegZI5bCEk1cNoOQ
# 182  https://www.yelp.com/biz/las-tapas-london?adju...  PWJiVG6QUm8P2aLJke1Ndw
# 183
# 184  https://www.yelp.com/biz/lobos-meat-and-tapas-...  nBZxw8KselF6esBLUH24Ww
# 185  https://www.yelp.com/biz/iberica-london-16?adj...  -YaDerXncRbSx9uSo9UcKg
# 186  https://www.yelp.com/biz/camino-london-5?adjus...  TX9hjk1xl2xKwG1_Wuw0UQ
# 187  https://www.yelp.com/biz/iberica-marylebone-2?...  iJPlkSdTPp1I3vHf00rk5Q
# 188  https://www.yelp.com/biz/sager-wilde-hackney-r...  3lrsL7fllHtEJ22SWGDzUg
# 189  https://www.yelp.com/biz/wc-wine-and-charcuter...  3851C1ulFmiDKJAykfG10w
# 190  https://www.yelp.com/biz/l-entrepot-london?adj...  q7t4xq80Is_ND8x68vc5wA
# 191  https://www.yelp.com/biz/mas-q-menos-london-3?...  51Nq0e6afkefxTSepcE9Gw
# 192  https://www.yelp.com/biz/levante-bar-london?ad...  hY6qUgNek-18AGTVtQt_4Q
# 193  https://www.yelp.com/biz/vinoteca-kings-cross-...  9K-A7wHxB-z3n5h-P_mYFA
# 194  https://www.yelp.com/biz/meson-don-felipe-lond...  r4yImLpeIpcjMFD7qSz_ng
# 195
# 196  https://www.yelp.com/biz/orford-saloon-tapas-b...  EazZp7bn_8HkTqUscy7Erg
# 197  https://www.yelp.com/biz/albertine-london?adju...  nLgRYqDWBryUZ46F-0ZEAA
# 198  https://www.yelp.com/biz/28-50-wine-workshop-a...  mM13I6b3emWA8KthSxmXYg
# 199  https://www.yelp.com/biz/terroirs-london?adjus...  xzui1-XqO7N5VzDnEeYWrw
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
london_restaurants_df.to_csv('Resources/London_Restaurants_Spanish.csv')
