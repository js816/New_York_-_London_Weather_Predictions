# %% [markdown]
# LONDON RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
lndr_params1 = {"term":"bistro","location":"London","limit":50,"offset":0}
lndr_response1 = requests.get(search_api_url, headers=headers, params=lndr_params1)
lndr1 = lndr_response1.json()
display(lndr1)
#print(lndr_response1.url)
#print(lndr_response1.status_code)
# Out:
# {'businesses': [{'id': 'sSjQl1wulo6X8-yWosTWxA',
#    'alias': 'bistro-51-santa-eulalia',
#    'name': 'Bistro 51',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qzKEbRcDL78znSPctx7Xkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistro-51-santa-eulalia?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4984817504883,
#     'longitude': -0.13748200237751},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '51 Buckingham Gate',
#     'address2': '',
#     'address3': '',
#     'city': 'Santa Eulalia',
#     'zip_code': 'SW1E 6AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Buckingham Gate',
#      'Santa Eulalia SW1E 6AF',
#      'United Kingdom']},
#    'phone': '+4434971336709',
#    'display_phone': '+44 34971336709',
#    'distance': 1599.5562992304415},
#   {'id': '4ibHPLYd299_m1LOdcqxXw',
#    'alias': 'savoir-faire-london',
#    'name': 'Savoir Faire',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kn-I1Rc8bpafCu5zweqS_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/savoir-faire-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 191,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5171949, 'longitude': -0.1260125},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '42 New Oxford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1A 1EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 New Oxford Street',
#      'London WC1A 1EP',
#      'United Kingdom']},
#    'phone': '+442074360707',
#    'display_phone': '+44 20 7436 0707',
#    'distance': 852.4529863641968},
#   {'id': 'umLQuVzI5h0HbPqipD360w',
#    'alias': 'andrew-edmunds-london',
#    'name': 'Andrew Edmunds',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/A33YIvgc6Ftchke6rzcgTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/andrew-edmunds-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.513155, 'longitude': -0.13614583403546},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '46 Lexington Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['46 Lexington Street',
#      'London W1F 0LP',
#      'United Kingdom']},
#    'phone': '+442074375708',
#    'display_phone': '+44 20 7437 5708',
#    'distance': 37.88004466546301},
#   {'id': 'T-fowSffgbxpSKSdrDez1A',
#    'alias': 'la-petite-maison-london',
#    'name': 'La Petite Maison',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/toLPlC7ry0SX252ZecEfFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-petite-maison-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512638, 'longitude': -0.146243},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '53 - 54 Brooks Mews',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 4EG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['53 - 54 Brooks Mews',
#      'London W1K 4EG',
#      'United Kingdom']},
#    'phone': '+442074954774',
#    'display_phone': '+44 20 7495 4774',
#    'distance': 711.4286207345583},
#   {'id': 'XUwGo_3lgdxjuL7E5s3FKA',
#    'alias': 'pierre-victoire-london',
#    'name': 'Pierre Victoire',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GTWqvdhr1GEB6AY7vvMOWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pierre-victoire-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 94,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515441, 'longitude': -0.133575},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5 Dean Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 3RQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Dean Street', 'London W1D 3RQ', 'United Kingdom']},
#    'phone': '+442072874582',
#    'display_phone': '+44 20 7287 4582',
#    'distance': 332.42940152360893},
#   {'id': 'hQEdwFG8kCTCO6fwvLuWBQ',
#    'alias': 'the-artisan-bistro-london',
#    'name': 'The Artisan Bistro',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/POdjWe9TNhTCqmmeXgz7Og/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-artisan-bistro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'bistros', 'title': 'Bistros'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.486104, 'longitude': -0.1846975},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '14 Hollywood Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW10 9HY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Hollywood Road',
#      'London SW10 9HY',
#      'United Kingdom']},
#    'phone': '+442074600875',
#    'display_phone': '+44 20 7460 0875',
#    'distance': 4492.908583450809},
#   {'id': 'jxN3X5vgEfPfHsZxEeJtuQ',
#    'alias': 'le-boudin-blanc-london',
#    'name': 'Le Boudin Blanc',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EJNWJcZM79ubSLoCCXVfig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-boudin-blanc-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 52,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.506485, 'longitude': -0.147213},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '5 Trebeck Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 7LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Trebeck Street',
#      'London W1J 7LT',
#      'United Kingdom']},
#    'phone': '+442074993292',
#    'display_phone': '+44 20 7499 3292',
#    'distance': 1050.7934925275044},
#   {'id': 'jRvh4MyRkjlIl2Llnwzd9Q',
#    'alias': 'côte-london-18',
#    'name': 'Côte',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8pf9lguJ-jUr9VZrV4aTEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/c%C3%B4te-london-18?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 98,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514231, 'longitude': -0.134374},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '124-126 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0TY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['124-126 Wardour Street',
#      'London W1F 0TY',
#      'United Kingdom']},
#    'phone': '+442072879280',
#    'display_phone': '+44 20 7287 9280',
#    'distance': 185.24876029046393},
#   {'id': 'qM6lDKglcVhUkH-0fJTn4g',
#    'alias': 'le-garrick-london',
#    'name': 'Le Garrick',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sQoN0zEsbMV-aFX0fO9EiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-garrick-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5115661621094,
#     'longitude': -0.126066997647285},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10-12 Garrick Street',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 9BH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10-12 Garrick Street',
#      'Covent Garden',
#      'London WC2E 9BH',
#      'United Kingdom']},
#    'phone': '+442072407649',
#    'display_phone': '+44 20 7240 7649',
#    'distance': 698.7287779983149},
#   {'id': 'Ii_CsiiPkg0MzsZrVWSMwQ',
#    'alias': 'the-bird-in-hand-london-3',
#    'name': 'The Bird In Hand',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CMHN1DAX3ao2hSoFoTFbzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bird-in-hand-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.499761921973,
#     'longitude': -0.21544145627873},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '88 Masbro Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W14 0LR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['88 Masbro Road', 'London W14 0LR', 'United Kingdom']},
#    'phone': '+442073712721',
#    'display_phone': '+44 20 7371 2721',
#    'distance': 5690.099093804208},
#   {'id': 'BjK1E7MvoR-Sm5yLY87KmQ',
#    'alias': 'l-absinthe-london',
#    'name': "L'Absinthe",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hqu-me6TfHK5-aCOlKiWFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-absinthe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.54019711634, 'longitude': -0.15427274630793},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '40 Chalcot Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8LS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 Chalcot Road',
#      'London NW1 8LS',
#      'United Kingdom']},
#    'phone': '+442074834848',
#    'display_phone': '+44 20 7483 4848',
#    'distance': 3295.8034394923893},
#   {'id': 'AVtK43VhZGCUSBc-XeOz6g',
#    'alias': 'soif-london',
#    'name': 'Soif',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mti-yA2Fp3jzK2JlHxGesw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soif-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.460771, 'longitude': -0.163489},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '27 Battersea Rise',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW11 1HG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['27 Battersea Rise',
#      'London SW11 1HG',
#      'United Kingdom']},
#    'phone': '+442072231112',
#    'display_phone': '+44 20 7223 1112',
#    'distance': 6089.39484152026},
#   {'id': 'E43MdoA7zkZ6SnPjAJaTvA',
#    'alias': 'brasserie-zédel-london',
#    'name': 'Brasserie Zédel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IeIn5kaFWw3q14DUoWZvyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brasserie-z%C3%A9del-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 163,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'jazzandblues', 'title': 'Jazz & Blues'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5106025898049,
#     'longitude': -0.135575861793962},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Sherwood Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Sherwood Street',
#      'London W1F 7ED',
#      'United Kingdom']},
#    'phone': '+442077344888',
#    'display_phone': '+44 20 7734 4888',
#    'distance': 249.67869451004725},
#   {'id': 'GuVx0eqzAfVWrZSJsiLESA',
#    'alias': 'champagne-fromage-london-2',
#    'name': 'Champagne+Fromage',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LYkp6MAdFhEuHJQURWsi9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/champagne-fromage-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4626205, 'longitude': -0.1118072},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 10-11',
#     'address2': 'Brixton Market',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 8PS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 10-11',
#      'Brixton Market',
#      'London SW9 8PS',
#      'United Kingdom']},
#    'phone': '+442070958504',
#    'display_phone': '+44 20 7095 8504',
#    'distance': 5828.620059090527},
#   {'id': 'UWiKhfMbCrxigWfc05jrWA',
#    'alias': 'chez-elles-london',
#    'name': 'Chez Elles',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Dnhm1DKnMp5Np7m3oQZi_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chez-elles-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5181672, 'longitude': -0.0712837},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '45 Brick Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6PU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Brick Lane', 'London E1 6PU', 'United Kingdom']},
#    'phone': '+442072479699',
#    'display_phone': '+44 20 7247 9699',
#    'distance': 4514.205375590505},
#   {'id': 'eKV3GGH9gU5h028CU839kQ',
#    'alias': 'bibendum-london',
#    'name': 'Bibendum',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/K6XTZoBk_WNsmgXHQkx3zg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bibendum-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.49331458816, 'longitude': -0.16883345515649},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'MIchelin House',
#     'address2': '81 Fulham Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 6RD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['MIchelin House',
#      '81 Fulham Road',
#      'London SW3 6RD',
#      'United Kingdom']},
#    'phone': '+442075815817',
#    'display_phone': '+44 20 7581 5817',
#    'distance': 3144.8689494402993},
#   {'id': '5sEiM_Xw5jXbMhloNqSgYQ',
#    'alias': 'grumbles-london',
#    'name': 'Grumbles',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/D6YLzHz7ilRcYpLsaG92Gg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grumbles-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4911292, 'longitude': -0.1388531},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '35 Churton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 2LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35 Churton Street',
#      'London SW1V 2LT',
#      'United Kingdom']},
#    'phone': '+442078340149',
#    'display_phone': '+44 20 7834 0149',
#    'distance': 2417.0516096383467},
#   {'id': 'MSqfyXS2fdm6H-ywHAV75w',
#    'alias': 'blanchette-london',
#    'name': 'Blanchette',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ow_wpCyVlEGztsuelh3x6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blanchette-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5146869918666,
#     'longitude': -0.136290080845356},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "9 D'Arblay Street",
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8DR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["9 D'Arblay Street",
#      'Soho',
#      'London W1F 8DR',
#      'United Kingdom']},
#    'phone': '+442074398100',
#    'display_phone': '+44 20 7439 8100',
#    'distance': 207.1693242672839},
#   {'id': 'QGz9cQb7nMMALbDh51m5pA',
#    'alias': 'shampers-london',
#    'name': 'Shampers',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dFOjSVQU0DGRa2Sgr20IrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shampers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5122603, 'longitude': -0.138605},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 Kingly Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5PE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Kingly Street',
#      'London W1B 5PE',
#      'United Kingdom']},
#    'phone': '+442074371692',
#    'display_phone': '+44 20 7437 1692',
#    'distance': 203.88093480395113},
#   {'id': 'Vm3mW0sCvB13QOmZRaSwrQ',
#    'alias': 'la-poule-au-pot-london',
#    'name': 'La Poule Au Pot',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tMb01dgQKWSFRE4WgWiFwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-poule-au-pot-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.49098422311, 'longitude': -0.15276253933283},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '231 Ebury Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 8UT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['231 Ebury Street',
#      'London SW1W 8UT',
#      'United Kingdom']},
#    'phone': '+442077307763',
#    'display_phone': '+44 20 7730 7763',
#    'distance': 2693.8822038196363},
#   {'id': '0r2-fwgLvuOLef0epiFkFQ',
#    'alias': 'granger-and-co-london',
#    'name': 'Granger & Co',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4pSTSM2JgsADC_cPoLBQJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/granger-and-co-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 183,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514646148453,
#     'longitude': -0.19779915622354},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '175 Westbourne Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['175 Westbourne Grove',
#      'London W11 2SB',
#      'United Kingdom']},
#    'phone': '+442072299111',
#    'display_phone': '+44 20 7229 9111',
#    'distance': 4284.263019990538},
#   {'id': 'PXD_6dSxdUUAgZwpYfWyYQ',
#    'alias': 'petit-pois-bistro-hackney',
#    'name': 'Petit Pois Bistro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4nSJoFy1r2b84ZqY5T_15A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/petit-pois-bistro-hackney?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5278505274307,
#     'longitude': -0.0815508028999212},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9 Hoxton Square',
#     'address2': '',
#     'address3': None,
#     'city': 'Hackney',
#     'zip_code': 'N1 6NU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Hoxton Square',
#      'Hackney N1 6NU',
#      'United Kingdom']},
#    'phone': '+442076133689',
#    'display_phone': '+44 20 7613 3689',
#    'distance': 4117.9055244516},
#   {'id': 'pMZ4XI-RsAxY6YK3xHVFJA',
#    'alias': 'boro-bistro-london',
#    'name': 'Boro Bistro',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AOkUzon0EnQK-hJpxOi1_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boro-bistro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5061193239226,
#     'longitude': -0.0887993531057241},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6-10 Borough High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9QQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6-10 Borough High Street',
#      'London SE1 9QQ',
#      'United Kingdom']},
#    'phone': '+442073780788',
#    'display_phone': '+44 20 7378 0788',
#    'distance': 3347.8671427058275},
#   {'id': 'zzjuqjPE7KTFFWIZvY6Uew',
#    'alias': 'bar-boulud-london',
#    'name': 'Bar Boulud',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-2vu7UtZ3wtN87i0I7d9fA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-boulud-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 109,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.502029603588, 'longitude': -0.1602532520838},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '66 Knightsbridge',
#     'address2': 'Mandarin Oriental Hyde Park',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Knightsbridge',
#      'Mandarin Oriental Hyde Park',
#      'London SW1X 7LA',
#      'United Kingdom']},
#    'phone': '+442072013899',
#    'display_phone': '+44 20 7201 3899',
#    'distance': 2066.7712422076224},
#   {'id': 'PsixhUTw6H2_KMBnBE5Q8A',
#    'alias': 'prix-fixe-london-2',
#    'name': 'Prix Fixe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HMEIP1b3J05RhQStSAl03w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prix-fixe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51344, 'longitude': -0.132173},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '39 Dean Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 4PU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39 Dean Street', 'London W1D 4PU', 'United Kingdom']},
#    'phone': '+442077345976',
#    'display_phone': '+44 20 7734 5976',
#    'distance': 271.2274844580187},
#   {'id': 'HyMWx0hCF0FLxAy3RwbL7w',
#    'alias': 'le-sacre-coeur-london',
#    'name': 'Le Sacre Coeur',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_kjFvLE-eNc0P41ErqnQrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-sacre-coeur-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5376815795898,
#     'longitude': -0.10402800142765},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18 Theberton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 0QX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Theberton Street',
#      'London N1 0QX',
#      'United Kingdom']},
#    'phone': '+442073542618',
#    'display_phone': '+44 20 7354 2618',
#    'distance': 3537.192826008922},
#   {'id': 'ofk57INQHCumktjqs0EjhQ',
#    'alias': 'san-carlo-cicchetti-london-2',
#    'name': 'San Carlo Cicchetti',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8blt2grhJcB35GAyYuJWvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/san-carlo-cicchetti-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 120,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5095021385658,
#     'longitude': -0.135087305946757},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '215 Piccadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 9HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['215 Piccadilly', 'London W1J 9HL', 'United Kingdom']},
#    'phone': '+442074949435',
#    'display_phone': '+44 20 7494 9435',
#    'distance': 375.49624382101644},
#   {'id': 'd6ZfhVFHTjwlB33BLUECmg',
#    'alias': 'cafe-boheme-london-4',
#    'name': 'CAFE BOHEME',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BcfspfUaozoX673Pw3H-Zw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-boheme-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5133171081543,
#     'longitude': -0.130649998784065},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '13 Old Compton st',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 5JQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Old Compton st',
#      'London W1D 5JQ',
#      'United Kingdom']},
#    'phone': '+442077340623',
#    'display_phone': '+44 20 7734 0623',
#    'distance': 374.5539523398065},
#   {'id': 'bw--h7Ow9sWB03kbLbN6Lw',
#    'alias': 'the-bleeding-heart-bistro-london',
#    'name': 'Bleeding Heart Bistro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/I33asV3cC5nDL6FYOV_rgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bleeding-heart-bistro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5192804154901,
#     'longitude': -0.106960255819672},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'Bleeding Heart Yard',
#     'address2': 'Off Greville Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1N 8SJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Bleeding Heart Yard',
#      'Off Greville Street',
#      'London EC1N 8SJ',
#      'United Kingdom']},
#    'phone': '+442072428238',
#    'display_phone': '+44 20 7242 8238',
#    'distance': 2130.5204500839573},
#   {'id': 'AyDH3j6yrUkZiPHSOOojHg',
#    'alias': 'comptoir-gascon-london',
#    'name': 'Comptoir Gascon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CNQOYsbLwOR3mN_ePmUOKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/comptoir-gascon-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5192574, 'longitude': -0.103499},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61-63 Charterhouse Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1M 6HJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61-63 Charterhouse Street',
#      'London EC1M 6HJ',
#      'United Kingdom']},
#    'phone': '+442076080851',
#    'display_phone': '+44 20 7608 0851',
#    'distance': 2358.9440446038375},
#   {'id': 'By1sfLsT1HnYjQmtrGa0iA',
#    'alias': 'hyde-perk-bistro-london',
#    'name': 'Hyde Perk Bistro',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YWjq4K6hj79d_OiVjPeL0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hyde-perk-bistro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.501545, 'longitude': -0.1842622},
#    'transactions': [],
#    'location': {'address1': '1 Palace Gate',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 5LS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Palace Gate', 'London W8 5LS', 'United Kingdom']},
#    'phone': '+442072250129',
#    'display_phone': '+44 20 7225 0129',
#    'distance': 3572.3894306656875},
#   {'id': 'RjWPLLjUmauU3mU7cp2emA',
#    'alias': 'bistro-benito-london',
#    'name': 'Bistro Benito',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/anr5TLyPXvRqB8BXI5OYzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistro-benito-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.493654, 'longitude': -0.195157},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '166 Earls Court Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 9QQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['166 Earls Court Road',
#      'London SW5 9QQ',
#      'United Kingdom']},
#    'phone': '+442073704857',
#    'display_phone': '+44 20 7370 4857',
#    'distance': 4614.557921109791},
#   {'id': 'CWYCCZkND7MEsOZH6C3jAg',
#    'alias': 'social-eating-house-london-2',
#    'name': 'Social Eating House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hIyL1b22NC8KsGz-82kDdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/social-eating-house-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 93,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5136727, 'longitude': -0.1363879},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '58 Poland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7NS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['58 Poland Street',
#      'London W1F 7NS',
#      'United Kingdom']},
#    'phone': '+442079933251',
#    'display_phone': '+44 20 7993 3251',
#    'distance': 97.77416732581322},
#   {'id': 'ytIFY2JvU-zcd1FsonES5w',
#    'alias': 'about-thyme-london',
#    'name': 'About Thyme',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Mh4BT2kuTfm_NFGpOQRFXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/about-thyme-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4924969, 'longitude': -0.1399836},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '82 Wilton Road',
#     'address2': 'Pimlico',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['82 Wilton Road',
#      'Pimlico',
#      'London SW1V 1DL',
#      'United Kingdom']},
#    'phone': '+442078217504',
#    'display_phone': '+44 20 7821 7504',
#    'distance': 2281.829545906066},
#   {'id': 'KhGIb4IwUxrc7xEm504V-A',
#    'alias': 'little-social-london',
#    'name': 'Little Social',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pKZGpYa3gSDO6LD5D1l-3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-social-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5135356, 'longitude': -0.1421587},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '5 Pollen Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 1NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Pollen Street',
#      'London W1S 1NE',
#      'United Kingdom']},
#    'phone': '+442078703730',
#    'display_phone': '+44 20 7870 3730',
#    'distance': 436.2438974859768},
#   {'id': 'WHrXrCaBE3Uf3d-B5Wyh0g',
#    'alias': 'heddon-street-kitchen-london',
#    'name': 'Heddon Street Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T5ZDviNFEe04BXyeJvfpig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heddon-street-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 91,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5107288, 'longitude': -0.1393024},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '3-9 Heddon St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 4BE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3-9 Heddon St', 'London W1B 4BE', 'United Kingdom']},
#    'phone': '+442075921212',
#    'display_phone': '+44 20 7592 1212',
#    'distance': 329.41022584098886},
#   {'id': 'xzui1-XqO7N5VzDnEeYWrw',
#    'alias': 'terroirs-london',
#    'name': 'Terroirs',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UST1MxNd0WWdCD9laoJNUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/terroirs-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 88,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5093551, 'longitude': -0.1252067},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '5 William IV Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4DW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 William IV Street',
#      'London WC2N 4DW',
#      'United Kingdom']},
#    'phone': '+442070360660',
#    'display_phone': '+44 20 7036 0660',
#    'distance': 837.1697744535918},
#   {'id': 'fSdxlY9uaMYDmiU3jjm5dA',
#    'alias': 'ducksoup-london',
#    'name': 'Ducksoup',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PFAIuC0eFNd2JXYLONuZQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ducksoup-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.51335, 'longitude': -0.132105},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '41 Dean Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 4PY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41 Dean Street', 'London W1D 4PY', 'United Kingdom']},
#    'phone': '+442072874599',
#    'display_phone': '+44 20 7287 4599',
#    'distance': 265.47860326758996},
#   {'id': 's39KOOGNRxO9ja5Tb5wifA',
#    'alias': 'truc-vert-london',
#    'name': 'Truc Vert',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-G1F09E3JCk-eXAEIg35xA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/truc-vert-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.51241, 'longitude': -0.1534},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '42 N Audley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 6ZR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 N Audley Street',
#      'London W1K 6ZR',
#      'United Kingdom']},
#    'phone': '+442074919988',
#    'display_phone': '+44 20 7491 9988',
#    'distance': 1203.1208603388206},
#   {'id': '-IW3FGRMhAXl-aRM1JmY8g',
#    'alias': 'langans-brasserie-london',
#    'name': "Langan's Brasserie",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i-rLUAT3sgnwDoRpXwb1MQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/langans-brasserie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.507003, 'longitude': -0.143575},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Stratton House',
#     'address2': 'Stratton Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 8LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Stratton House',
#      'Stratton Street',
#      'London W1J 8LB',
#      'United Kingdom']},
#    'phone': '+442074918822',
#    'display_phone': '+44 20 7491 8822',
#    'distance': 827.9995243311132},
#   {'id': 'FRMgD2uZKd-69ZWIPMoHqA',
#    'alias': 'le-relais-de-venise-london-4',
#    'name': 'Le Relais de Venise',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FLolF6QFYdiH44lrawxGcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-relais-de-venise-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514705, 'longitude': -0.086231},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '5 Throgmorton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2N 2AD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Throgmorton Street',
#      'London EC2N 2AD',
#      'United Kingdom']},
#    'phone': '+442076386325',
#    'display_phone': '+44 20 7638 6325',
#    'distance': 3430.5938860441515},
#   {'id': '3fug-QaxGXZf58gBEqBe4w',
#    'alias': 'bistrotheque-london-2',
#    'name': 'Bistrotheque',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9I-W8Q8CNonaVgPGj7sT1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistrotheque-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 93,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5341223088385,
#     'longitude': -0.0560837915559814},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '23-27 Wadeson Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 9DR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23-27 Wadeson Street',
#      'London E2 9DR',
#      'United Kingdom']},
#    'phone': '+442089837900',
#    'display_phone': '+44 20 8983 7900',
#    'distance': 6011.524250056963},
#   {'id': '1NOMO_ZuYy1u57lKSp1tSw',
#    'alias': '108-brasserie-london',
#    'name': '108 Brasserie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NDLaqScJukvyr9ekVNgIAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/108-brasserie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5179613, 'longitude': -0.1505703},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '108 Marylebone Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 2QE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['108 Marylebone Lane',
#      'London W1U 2QE',
#      'United Kingdom']},
#    'phone': '+442079693900',
#    'display_phone': '+44 20 7969 3900',
#    'distance': 1162.5013377145387},
#   {'id': 'M2tEYs-5EWdl91_eASOktA',
#    'alias': 'casa-tua-london',
#    'name': 'Casa Tua',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Z6vl6OQxfWAhlKj46VoE_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-tua-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5416508, 'longitude': -0.1380299},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '176 Royal College Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 0SP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['176 Royal College Street',
#      'London NW1 0SP',
#      'United Kingdom']},
#    'phone': '+442081270460',
#    'display_phone': '+44 20 8127 0460',
#    'distance': 3207.320322540477},
#   {'id': 'fdwAAs9cm_uLkgxXedYh3w',
#    'alias': 'baltic-bar-and-restaurant-london',
#    'name': 'Baltic Bar and Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Th3235Hk9AlSXVsMlC9XSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baltic-bar-and-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.503466, 'longitude': -0.104866},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '74 Blackfriars Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['74 Blackfriars Road',
#      'London SE1 8HA',
#      'United Kingdom']},
#    'phone': '+442079281111',
#    'display_phone': '+44 20 7928 1111',
#    'distance': 2390.6260048944155},
#   {'id': 'mB89HRKJEAvpGXFDxAuz6g',
#    'alias': 'the-bleeding-heart-restaurant-london',
#    'name': 'Bleeding Heart Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Pj924q_lsHvSupzfiLV-dA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bleeding-heart-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.519165, 'longitude': -0.1067},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Bleeding Heart Yard',
#     'address2': 'Off Greville Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1N 8SJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Bleeding Heart Yard',
#      'Off Greville Street',
#      'London EC1N 8SJ',
#      'United Kingdom']},
#    'phone': '+442072428238',
#    'display_phone': '+44 20 7242 8238',
#    'distance': 2149.9250095948228},
#   {'id': '3YhbdDmRCr_0XcWLwmUa1w',
#    'alias': 'bistro-vadouvan-london',
#    'name': 'Bistro Vadouvan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L2RIWGSHMoKLGSzv6StQ4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistro-vadouvan-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bistros', 'title': 'Bistros'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.46518, 'longitude': -0.212421},
#    'transactions': [],
#    'location': {'address1': '30 Brewhouse Lane',
#     'address2': 'Putney',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW15 2JX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Brewhouse Lane',
#      'Putney',
#      'London SW15 2JX',
#      'United Kingdom']},
#    'phone': '+442034753776',
#    'display_phone': '+44 20 3475 3776',
#    'distance': 7490.575332410896},
#   {'id': '75-HeBBB391Np6T7GdJ5xQ',
#    'alias': 'the-ivy-london',
#    'name': 'The Ivy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rVk4F439o22SXXzGGHKGRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ivy-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 171,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512814, 'longitude': -0.128013},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1 - 5 West Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9NQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 - 5 West Street',
#      'London WC2H 9NQ',
#      'United Kingdom']},
#    'phone': '+442078364751',
#    'display_phone': '+44 20 7836 4751',
#    'distance': 549.6549455465449},
#   {'id': 'T0BfGyQX2ZrQN_muEnUFsQ',
#    'alias': 'les-gourmets-des-ternes-london',
#    'name': 'Les Gourmets des Ternes',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wmJYjdCL93ejorkFwoYeWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/les-gourmets-des-ternes-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5245538458094,
#     'longitude': -0.185106483467052},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '18 Formosa Street',
#     'address2': 'Little Venice',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W9 1EE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Formosa Street',
#      'Little Venice',
#      'London W9 1EE',
#      'United Kingdom']},
#    'phone': '+442072863742',
#    'display_phone': '+44 20 7286 3742',
#    'distance': 3641.9113128680083},
#   {'id': 'VtLgCcLSEwFBiKPFV6_Mug',
#    'alias': 'balthazar-london',
#    'name': 'Balthazar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jjUdrn07VkCmksfsd6RuPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/balthazar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 176,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512493, 'longitude': -0.1212219},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '4-6 Russell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5HZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4-6 Russell Street',
#      'London WC2B 5HZ',
#      'United Kingdom']},
#    'phone': '+442033011155',
#    'display_phone': '+44 20 3301 1155',
#    'distance': 1017.1328446810884}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#          Restaurant             Type Price Rating               Address  \
# 0         Bistro 51  Modern European    ££    4.5    51 Buckingham Gate
# 1      Savoir Faire           French    ££    4.5  42 New Oxford Street
# 2    Andrew Edmunds        Wine Bars   £££    4.5   46 Lexington Street
# 3  La Petite Maison           French  ££££    4.5   53 - 54 Brooks Mews
# 4   Pierre Victoire           French    ££      4         5 Dean Street
#
#          Lat       Lng                                                url  \
# 0  51.498482 -0.137482  https://www.yelp.com/biz/bistro-51-santa-eulal...
# 1  51.517195 -0.126012  https://www.yelp.com/biz/savoir-faire-london?a...
# 2  51.513155 -0.136146  https://www.yelp.com/biz/andrew-edmunds-london...
# 3  51.512638 -0.146243  https://www.yelp.com/biz/la-petite-maison-lond...
# 4  51.515441 -0.133575  https://www.yelp.com/biz/pierre-victoire-londo...
#
#                        ID
# 0  sSjQl1wulo6X8-yWosTWxA
# 1  4ibHPLYd299_m1LOdcqxXw
# 2  umLQuVzI5h0HbPqipD360w
# 3  T-fowSffgbxpSKSdrDez1A
# 4  XUwGo_3lgdxjuL7E5s3FKA

# %%
#2nd set of 50 records 51-100 
lndr_params2 = {"term":"bistro","location":"London","limit":50,"offset":51}
lndr_response2 = requests.get(search_api_url, headers=headers, params=lndr_params2)
lndr2 = lndr_response2.json()
display(lndr2)
#print(lndr_response2.url)
#print(lndr_response2.status_code)
# Out:
# {'businesses': [{'id': 'lrA0Xss9u0lwd4sfEyktmw',
#    'alias': 'cafe-rouge-london-54',
#    'name': 'Cafe Rouge',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FSy-57O3Vno27PGd9qx4cQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-rouge-london-54?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5132288926225,
#     'longitude': -0.0992694879514433},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 5',
#     'address2': "St Paul's Church Yard",
#     'address3': 'Condor House',
#     'city': 'London',
#     'zip_code': 'EC4M 8AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 5',
#      "St Paul's Church Yard",
#      'Condor House',
#      'London EC4M 8AY',
#      'United Kingdom']},
#    'phone': '+442074897812',
#    'display_phone': '+44 20 7489 7812',
#    'distance': 2539.092195972151},
#   {'id': 'XoIWi1dNRrXNv459LFiUkg',
#    'alias': 'gazette-brasserie-london-2',
#    'name': 'Gazette Brasserie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OFVG_ctvpvId-hTVqm6LFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gazette-brasserie-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.465745, 'longitude': -0.182282},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '79 Sherwood Court',
#     'address2': 'Chatfield Road',
#     'address3': 'Battersea',
#     'city': 'London',
#     'zip_code': 'SW11 3UY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['79 Sherwood Court',
#      'Chatfield Road',
#      'Battersea',
#      'London SW11 3UY',
#      'United Kingdom']},
#    'phone': '+442072230999',
#    'display_phone': '+44 20 7223 0999',
#    'distance': 6140.511079680508},
#   {'id': '9NJ6EoGXVbAs17w1jMvQeg',
#    'alias': 'le-bistro-london',
#    'name': 'Le Bistro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/P6uHEu0neln8odgs3fSNvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-bistro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5872859, 'longitude': -0.120097},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '36 High Street',
#     'address2': 'Hornsey',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N8 7NX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['36 High Street',
#      'Hornsey',
#      'London N8 7NX',
#      'United Kingdom']},
#    'phone': '+442083402116',
#    'display_phone': '+44 20 8340 2116',
#    'distance': 8358.217102359911},
#   {'id': '6WsuX-QP8DQtejctGK6qVg',
#    'alias': 'cepages-wine-bistro-london',
#    'name': 'Cepages Wine Bistro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kEo8wvY-ePJePUTfiCkjqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cepages-wine-bistro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5188439371901,
#     'longitude': -0.194726504754008},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '69 Westbourne Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 5QH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['69 Westbourne Park Road',
#      'London W2 5QH',
#      'United Kingdom']},
#    'phone': '+442036028890',
#    'display_phone': '+44 20 3602 8890',
#    'distance': 4121.231099993012},
#   {'id': '3u6E18F9ZBOtitBsXn-Iag',
#    'alias': 'côte-brasserie-london-17',
#    'name': 'Côte Brasserie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/s5iCxqCFTqvJEHoFRNdouw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/c%C3%B4te-brasserie-london-17?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5082135345565,
#     'longitude': -0.0734716141694121},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'International House',
#     'address2': "1 St Katharine's Way",
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E1W 1UN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['International House',
#      "1 St Katharine's Way",
#      'London E1W 1UN',
#      'United Kingdom']},
#    'phone': '+442074883668',
#    'display_phone': '+44 20 7488 3668',
#    'distance': 4354.616134362743},
#   {'id': 'mH_sQ_v8BUx-EHuZcTO2ig',
#    'alias': 'mill-lane-bistro-london',
#    'name': 'Mill Lane Bistro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/65B1JvXmfNKUXcKmI6zDmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mill-lane-bistro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5520510958439,
#     'longitude': -0.196220014292067},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '77 Mill Lane',
#     'address2': 'West Hampstead',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 1NB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['77 Mill Lane',
#      'West Hampstead',
#      'London NW6 1NB',
#      'United Kingdom']},
#    'phone': '+442077945577',
#    'display_phone': '+44 20 7794 5577',
#    'distance': 6032.519260409729},
#   {'id': 'm3A_7od2v91zWbXbllasHA',
#    'alias': 'bank-restaurants-london-2',
#    'name': 'Bank Restaurants',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3q4stnrBSHfpi8js8n24Uw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bank-restaurants-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4986583, 'longitude': -0.1373148},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '45 Buckingham Gate',
#     'address2': 'Westminster',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1E 6BS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Buckingham Gate',
#      'Westminster',
#      'London SW1E 6BS',
#      'United Kingdom']},
#    'phone': '+442076306644',
#    'display_phone': '+44 20 7630 6644',
#    'distance': 1579.2368119166258},
#   {'id': 'PD3t6N3c8aLODudwd2SbqQ',
#    'alias': 'le-bistro-de-la-gare-london',
#    'name': 'Le Bistro de la Gare',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iSEyl1oejDW4ABj_ryi4mQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-bistro-de-la-gare-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5314537, 'longitude': -0.1169393},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '180-186 Pentonville Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9JP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['180-186 Pentonville Road',
#      'London N1 9JP',
#      'United Kingdom']},
#    'phone': '+442078372292',
#    'display_phone': '+44 20 7837 2292',
#    'distance': 2452.948224364074},
#   {'id': '5-YH5TS_PEjNezuZgbhfhw',
#    'alias': 'le-rendezvous-de-cafe-london-2',
#    'name': 'Le Rendezvous De Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3WSsc3i3z2yitbjAWimT4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-rendezvous-de-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5202437, 'longitude': -0.0998749},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '121 Charterhouse Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1M 6AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['121 Charterhouse Street',
#      'London EC1M 6AA',
#      'United Kingdom']},
#    'phone': '+442073368836',
#    'display_phone': '+44 20 7336 8836',
#    'distance': 2629.014727511597},
#   {'id': 'XkUO7tQD-tfXoTzuHMbnMg',
#    'alias': 'portobello-house-london',
#    'name': 'Portobello House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yK9BFXWr70ydWDyodXHSEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/portobello-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.519389, 'longitude': -0.21148},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '225 Ladbroke Grove',
#     'address2': 'London',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W10 6HQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['225 Ladbroke Grove',
#      'London',
#      'London W10 6HQ',
#      'United Kingdom']},
#    'phone': '+442031810920',
#    'display_phone': '+44 20 3181 0920',
#    'distance': 5275.550116017336},
#   {'id': 'wm6Hwzan5qYhTzCDmO3oDQ',
#    'alias': 'muriels-kitchen-london',
#    'name': "Muriel's Kitchen",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9un8EzHME-wGnd7zVoev2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/muriels-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 134,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.494117, 'longitude': -0.174468},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 1',
#     'address2': '3 Pelham Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 2ND',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 1',
#      '3 Pelham Street',
#      'London SW7 2ND',
#      'United Kingdom']},
#    'phone': '+442075893511',
#    'display_phone': '+44 20 7589 3511',
#    'distance': 3381.980840047671},
#   {'id': 'SsA4xyF60DUXdOaCspIe1w',
#    'alias': 'bistrò-by-shot-london',
#    'name': 'Bistrò by Shot',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WHINRY_CDwPiuEDOG8CXGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistr%C3%B2-by-shot-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4761126249543,
#     'longitude': -0.201063260185887},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '28 Parsons Green Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 4HS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28 Parsons Green Lane',
#      'London SW6 4HS',
#      'United Kingdom']},
#    'phone': '+442073717533',
#    'display_phone': '+44 20 7371 7533',
#    'distance': 6081.936487270801},
#   {'id': '3X0LSwIvvcqJ6xjB_07M0A',
#    'alias': 'south-place-grill-london',
#    'name': 'South Place Grill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0A0k-WMwYek2OyJ-oFbaHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/south-place-grill-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.519045, 'longitude': -0.086526},
#    'transactions': [],
#    'location': {'address1': '3 S Place',
#     'address2': 'London',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2M 2AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 S Place',
#      'London',
#      'London EC2M 2AF',
#      'United Kingdom']},
#    'phone': '+442035030777',
#    'display_phone': '+44 20 3503 0777',
#    'distance': 3482.512359320897},
#   {'id': '5qHpg2z69QMbQGh0KIor6Q',
#    'alias': 'aix-london-2',
#    'name': 'Aix',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zLtgofgI88N-G8xSsXP5gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aix-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5816532516394,
#     'longitude': -0.121383368968964},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '54 Topsfield Parade',
#     'address2': 'Tottenham Lane',
#     'address3': 'Crouch End',
#     'city': 'London',
#     'zip_code': 'N8 8PT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54 Topsfield Parade',
#      'Tottenham Lane',
#      'Crouch End',
#      'London N8 8PT',
#      'United Kingdom']},
#    'phone': '+442083406346',
#    'display_phone': '+44 20 8340 6346',
#    'distance': 7718.2351129770295},
#   {'id': 'ls_OnpyYxsJU6KtPODfxbg',
#    'alias': 'pique-nique-london',
#    'name': 'Pique-Nique',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HgdkmNJuRC9vMxYnBPX-3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pique-nique-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.50018, 'longitude': -0.07929},
#    'transactions': [],
#    'location': {'address1': 'Tanner St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 3LD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Tanner St', 'London SE1 3LD', 'United Kingdom']},
#    'phone': '+442074039549',
#    'display_phone': '+44 20 7403 9549',
#    'distance': 4169.910705065413},
#   {'id': 'FacPh7aiSijdmRVUGPSPeg',
#    'alias': 'bellamys-bruton-place-london',
#    'name': "Bellamy's Bruton Place",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dha4OxRW-3jiR41llppOMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bellamys-bruton-place-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511288373554,
#     'longitude': -0.14455779936198},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '18 Bruton Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 6LY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Bruton Place',
#      'London W1J 6LY',
#      'United Kingdom']},
#    'phone': '+442074912727',
#    'display_phone': '+44 20 7491 2727',
#    'distance': 619.6360345962997},
#   {'id': 'nVMVXywZjvDBkPPR_uqhUA',
#    'alias': 'the-garrison-london',
#    'name': 'The Garrison',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/z8a68zJmqJXkFn7wjll03g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-garrison-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 104,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.500646, 'longitude': -0.08159},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '99 Bermondsey Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 3XB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['99 Bermondsey Street',
#      'London SE1 3XB',
#      'United Kingdom']},
#    'phone': '+442070899355',
#    'display_phone': '+44 20 7089 9355',
#    'distance': 3989.2901215567895},
#   {'id': 'QxbG6OZDNezypwH5RdSZUA',
#    'alias': 'chabrot-london-2',
#    'name': 'Chabrot',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cjL2tASm0cUnYFktqbOCDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chabrot-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5014900338738,
#     'longitude': -0.162574052810669},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '9 Knightsbridge Green',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Knightsbridge Green',
#      'London SW1X 7QL',
#      'United Kingdom']},
#    'phone': '+442072252238',
#    'display_phone': '+44 20 7225 2238',
#    'distance': 2232.792767783279},
#   {'id': '8pafyRKpDRt0pd5KXh-Hzg',
#    'alias': 'côte-london-20',
#    'name': 'Côte',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KmQ_t0Mxp5XWvQFV37eevA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/c%C3%B4te-london-20?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5019768764095,
#     'longitude': -0.188927866187417},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '47 Kensington Court',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 5DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Kensington Court',
#      'London W8 5DA',
#      'United Kingdom']},
#    'phone': '+442079384147',
#    'display_phone': '+44 20 7938 4147',
#    'distance': 3859.8619347128256},
#   {'id': 'cV9dn2Db9xzd4YnnEmMLnQ',
#    'alias': 'le-relais-de-venise-l-entrecôte-london-4',
#    'name': "Le Relais de Venise L'Entrecôte",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bt0wAGQDUDFrAOxSB9vfWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-relais-de-venise-l-entrec%C3%B4te-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 187,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.518264, 'longitude': -0.151117},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '120 Marylebone Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 2QG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['120 Marylebone Lane',
#      'London W1U 2QG',
#      'United Kingdom']},
#    'phone': '+442074860878',
#    'display_phone': '+44 20 7486 0878',
#    'distance': 1201.4970512340358},
#   {'id': 'Zosh5-bHe3MSV_Mk9upzVA',
#    'alias': 'les-petits-gourmets-london',
#    'name': 'Les Petits Gourmets',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4Pdm8l_OYBKoGyx9uPSE7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/les-petits-gourmets-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5236597, 'longitude': -0.185095009903178},
#    'transactions': [],
#    'location': {'address1': '18 Formosa Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W9 1EE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Formosa Street',
#      'London W9 1EE',
#      'United Kingdom']},
#    'phone': '+442072863742',
#    'display_phone': '+44 20 7286 3742',
#    'distance': 3606.816864569485},
#   {'id': 'VaeuHtY3U-8-1VfmEDJaXg',
#    'alias': 'li-veli-winery-and-bistro-london',
#    'name': 'Li Veli Winery & Bistro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YEAJNLO6PAIj7WPnrJzjqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/li-veli-winery-and-bistro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bistros', 'title': 'Bistros'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5142616249142,
#     'longitude': -0.122286090968714},
#    'transactions': [],
#    'location': {'address1': '69 Covent Garden',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 9NQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['69 Covent Garden',
#      'London WC2E 9NQ',
#      'United Kingdom']},
#    'phone': '+442072408163',
#    'display_phone': '+44 20 7240 8163',
#    'distance': 959.141525455023},
#   {'id': 'RNCwHorv4bGFY25NaZZpDQ',
#    'alias': 'ellory-london',
#    'name': 'Ellory',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-1ywzddv_huZMzQcv4laQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ellory-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5376554, 'longitude': -0.0580662},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1 Westgate Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 3RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Westgate Street',
#      'London E8 3RL',
#      'United Kingdom']},
#    'phone': '+442030959455',
#    'display_phone': '+44 20 3095 9455',
#    'distance': 6071.345125843228},
#   {'id': 'lkkcuczHUWf-kXAsKkM_FQ',
#    'alias': 'neo-bistro-mayfair',
#    'name': 'Neo Bistro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DQKTzmpjU7DSZxIb4gOjwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/neo-bistro-mayfair?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5143236568531,
#     'longitude': -0.147719592931629},
#    'transactions': [],
#    'location': {'address1': '11 Woodstock St',
#     'address2': '',
#     'address3': None,
#     'city': 'Mayfair',
#     'zip_code': 'W1C 2AE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Woodstock St',
#      'Mayfair W1C 2AE',
#      'United Kingdom']},
#    'phone': '+442074999427',
#    'display_phone': '+44 20 7499 9427',
#    'distance': 830.6986831687411},
#   {'id': 'JcGMQaoEfPt_uSfjwPYixw',
#    'alias': 'toulouse-lautrec-london',
#    'name': 'Toulouse Lautrec',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EwnHrMQ_DbQ826tWwA3_LQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/toulouse-lautrec-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'jazzandblues', 'title': 'Jazz & Blues'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'pianobars', 'title': 'Piano Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4910865673158,
#     'longitude': -0.103391147617971},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '140 Newington Butts',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE11 4RN',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ['140 Newington Butts',
#      'London SE11 4RN',
#      'United Kingdom']},
#    'phone': '+442075826800',
#    'display_phone': '+44 20 7582 6800',
#    'distance': 3305.9371443546547},
#   {'id': '4yj9yyOSLFeITrqqD7t3yw',
#    'alias': 'bon-vivant-london-2',
#    'name': 'Bon Vivant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CzPyy6g_c7SKufTCrJfxvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bon-vivant-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5255314, 'longitude': -0.1256143},
#    'transactions': [],
#    'location': {'address1': '75-77 Marchmont Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 1AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['75-77 Marchmont Street',
#      'London WC1N 1AP',
#      'United Kingdom']},
#    'phone': '+442077136111',
#    'display_phone': '+44 20 7713 6111',
#    'distance': 1586.1069965032252},
#   {'id': 'CQL8mLR6rcNOtD7s3GrYCg',
#    'alias': 'casse-croute-london',
#    'name': 'Casse-Croute',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Uc_S6h0Q97ArmGNQzVZbUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casse-croute-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5005074, 'longitude': -0.0815315},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '109 Bermondsey Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 3XB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['109 Bermondsey Street',
#      'London SE1 3XB',
#      'United Kingdom']},
#    'phone': '+442074072140',
#    'display_phone': '+44 20 7407 2140',
#    'distance': 4000.153654024596},
#   {'id': 'eIHXc3RkRhpQBJS5M2tjjg',
#    'alias': 'l-aventure-london',
#    'name': "L'Aventure",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yXJwVfhm8AtoSqv2HMOBUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-aventure-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.535148, 'longitude': -0.1814524},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '3 Blenheim Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 0EH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Blenheim Terrace',
#      'London NW8 0EH',
#      'United Kingdom']},
#    'phone': '+442076246232',
#    'display_phone': '+44 20 7624 6232',
#    'distance': 4005.7695363048124},
#   {'id': 'YjM4oKNwo8MuzHkAdmwiaA',
#    'alias': 'plateau-restaurant-london',
#    'name': 'Plateau Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ziwDXINvPjoX4ojZ8HgOIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/plateau-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5044556493532,
#     'longitude': -0.0166596716095782},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Canada Place',
#     'address2': '4th Floor',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E14 5ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Canada Place',
#      '4th Floor',
#      'London E14 5ER',
#      'United Kingdom']},
#    'phone': '+442077157100',
#    'display_phone': '+44 20 7715 7100',
#    'distance': 8308.57348500271},
#   {'id': 'aAzCPzQkOcBUBnqd3-qIuw',
#    'alias': 'obicà-london-4',
#    'name': 'Obicà',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SCY-3PHSATY47GxeYdHSQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/obic%C3%A0-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5149383967259,
#     'longitude': -0.13713073307934},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Poland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8QF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Poland Street',
#      'London W1F 8QF',
#      'United Kingdom']},
#    'phone': '+442033277070',
#    'display_phone': '+44 20 3327 7070',
#    'distance': 247.5605647506309},
#   {'id': '8haIlB3gghjV8ZUOwsqBUA',
#    'alias': 'bar-du-marché-london-2',
#    'name': 'Bar Du Marché',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fSPed0qZGBaPIkg5duxMdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-du-march%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.513735, 'longitude': -0.134856},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '19 Berwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Berwick Street',
#      'London W1F 0PX',
#      'United Kingdom']},
#    'phone': '+442077344606',
#    'display_phone': '+44 20 7734 4606',
#    'distance': 119.25747461729352},
#   {'id': 'UDcjE8YbIE4mtMZBg4sIzQ',
#    'alias': 'aubaine-london-11',
#    'name': 'Aubaine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iiVF75iKlle9jjaOlUCyEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aubaine-london-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5103765333673,
#     'longitude': -0.187597811045066},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Hilton London Hyde Park',
#     'address2': '129 Bayswater Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 4RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Hilton London Hyde Park',
#      '129 Bayswater Road',
#      'London W2 4RJ',
#      'United Kingdom']},
#    'phone': '+442037733930',
#    'display_phone': '+44 20 3773 3930',
#    'distance': 3584.2136643996305},
#   {'id': 'wAk5BqaL_NJM1WrJOzmRgA',
#    'alias': 'st-paul-london',
#    'name': 'St Paul',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/squPWo1aR0F3tPHwROJAPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-paul-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5464835, 'longitude': -0.1002818},
#    'transactions': [],
#    'location': {'address1': '274b St Pauls Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 2LJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['274b St Pauls Road',
#      'London N1 2LJ',
#      'United Kingdom']},
#    'phone': '+442076839993',
#    'display_phone': '+44 20 7683 9993',
#    'distance': 4465.791643396503},
#   {'id': 'ZVNN8a2gBhj2OYgELQ-qgw',
#    'alias': 'coopers-restaurant-london',
#    'name': 'Coopers Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Mq5iBoyJFL2g4tIRb-56mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coopers-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5150146, 'longitude': -0.1174239},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '49a Lincolns Inn Fields',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2A 3PF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49a Lincolns Inn Fields',
#      'London WC2A 3PF',
#      'United Kingdom']},
#    'phone': '+442078316211',
#    'display_phone': '+44 20 7831 6211',
#    'distance': 1305.0843271987064},
#   {'id': 'IC1tBuRq1BZpOdCDeI_umg',
#    'alias': 'henrietta-bistro-london',
#    'name': 'Henrietta Bistro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GKm82AslhFV2KZUnMyC0gg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/henrietta-bistro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5109, 'longitude': -0.12394},
#    'transactions': [],
#    'location': {'address1': '14-15 henrietta street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 8QG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14-15 henrietta street',
#      'London WC2E 8QG',
#      'United Kingdom']},
#    'phone': '+442037945314',
#    'display_phone': '+44 20 3794 5314',
#    'distance': 862.7093262873091},
#   {'id': 'c7urOor7CgoJAvuPezrDEQ',
#    'alias': 'bread-street-kitchen-london',
#    'name': 'Bread Street Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZFmQpAHtCYEAd-bSA529yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bread-street-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 144,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5134808, 'longitude': -0.0947269},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '10 Bread Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4M 9AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Bread Street',
#      'London EC4M 9AJ',
#      'United Kingdom']},
#    'phone': '+442030304050',
#    'display_phone': '+44 20 3030 4050',
#    'distance': 2853.9594061626294},
#   {'id': 'vjTdO3gRdUiTW2cUFjZhUg',
#    'alias': 'cote-brasserie-london-4',
#    'name': 'Cote Brasserie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gOhiwgCJAW5nZBSAjKNjBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cote-brasserie-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4752083, 'longitude': -0.2006151},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '45-47 Parsons Green Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 4HH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45-47 Parsons Green Lane',
#      'London SW6 4HH',
#      'United Kingdom']},
#    'phone': '+442077368444',
#    'display_phone': '+44 20 7736 8444',
#    'distance': 6117.030770597906},
#   {'id': 'xL8dHOFSVTKD9adYjgxxCw',
#    'alias': 'bellevue-rendezvous-london',
#    'name': 'Bellevue Rendezvous',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TfQ6b4whF7yQQeJnLLltAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bellevue-rendezvous-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4435064, 'longitude': -0.1674472},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '218 Trinity Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW17 7HP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['218 Trinity Road',
#      'London SW17 7HP',
#      'United Kingdom']},
#    'phone': '+442087675810',
#    'display_phone': '+44 20 8767 5810',
#    'distance': 8016.813869306589},
#   {'id': '5oLV6eWx4RLjgPlEKLczOQ',
#    'alias': 'little-bay-west-hampstead-london',
#    'name': 'Little Bay West Hampstead',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GuLK-bfgyH6AjOHIFswYXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-bay-west-hampstead-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5387914, 'longitude': -0.190351},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '228 Belsize Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 4BT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['228 Belsize Road',
#      'London NW6 4BT',
#      'United Kingdom']},
#    'phone': '+442073724699',
#    'display_phone': '+44 20 7372 4699',
#    'distance': 4742.840050006223},
#   {'id': '0gHA2RVAV7Prsp1FqNSK-g',
#    'alias': 'bite-bistro-london',
#    'name': 'Bite Bistro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OUvFXPe_i75I6VVAsY2_Qg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bite-bistro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.463607, 'longitude': -0.133678},
#    'transactions': [],
#    'location': {'address1': '127 Clapham High Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW4 7',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['127 Clapham High Street',
#      'London SW4 7',
#      'United Kingdom']},
#    'phone': '+442076278005',
#    'display_phone': '+44 20 7627 8005',
#    'distance': 5476.227196558816},
#   {'id': 'MorS393f7A-tho09UoRvPw',
#    'alias': 'fish-and-wine-restaurant-and-bar-london',
#    'name': 'Fish & Wine Restaurant & Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QUF8XafSFmCdi8Gzw_geKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fish-and-wine-restaurant-and-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4528106584757,
#     'longitude': -0.102353718285705},
#    'transactions': [],
#    'location': {'address1': '222 Railton Road',
#     'address2': 'Herne Hill',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE24 0JT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['222 Railton Road',
#      'Herne Hill',
#      'London SE24 0JT',
#      'United Kingdom']},
#    'phone': '+442072740555',
#    'display_phone': '+44 20 7274 0555',
#    'distance': 7068.411353286208},
#   {'id': 'xpqyvIaX-q1-mqPVHdpbqw',
#    'alias': 'cafe-monte-london',
#    'name': 'Cafe Monte',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-_YICzcdvYQGmgVBNaYTHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-monte-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4794986500945,
#     'longitude': -0.211679935455322},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '228 Munster Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 6AZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['228 Munster Road',
#      'London SW6 6AZ',
#      'United Kingdom']},
#    'phone': '+442076100037',
#    'display_phone': '+44 20 7610 0037',
#    'distance': 6420.32378221114},
#   {'id': 'Sf1u7eCFmf9E9B0agS1yXw',
#    'alias': 'cafe-du-marche-london',
#    'name': 'Cafe Du Marche',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7ZvtP_4AVxxWsQlpyr3TRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-du-marche-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5206234, 'longitude': -0.1007171},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Charterhouse Mews',
#     'address2': '22 Charterhouse Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1M 6AH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Charterhouse Mews',
#      '22 Charterhouse Square',
#      'London EC1M 6AH',
#      'United Kingdom']},
#    'phone': '+442076081609',
#    'display_phone': '+44 20 7608 1609',
#    'distance': 2587.550564157516},
#   {'id': 'iu4h-vGKGXmFMhJwdpfexQ',
#    'alias': 'cellar-gascon-london',
#    'name': 'Cellar Gascon',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/A2IO4ndgvfCumU60lQZc3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cellar-gascon-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51927, 'longitude': -0.10374},
#    'transactions': [],
#    'location': {'address1': '57-59 Charterhouse Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1M 6HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57-59 Charterhouse Street',
#      'London EC1M 6HA',
#      'United Kingdom']},
#    'phone': '+442076007561',
#    'display_phone': '+44 20 7600 7561',
#    'distance': 2352.733680502668},
#   {'id': 'TtkhkYxbzkL_F6ZajO3veQ',
#    'alias': 'côte-brasserie-london-22',
#    'name': 'Côte Brasserie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bKbHrE2KbFieAFUg1wzPww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/c%C3%B4te-brasserie-london-22?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5123642, 'longitude': -0.1202975},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '17-21 Tavistock Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 7PA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17-21 Tavistock Street',
#      'London WC2E 7PA',
#      'United Kingdom']},
#    'phone': '+442073799991',
#    'display_phone': '+44 20 7379 9991',
#    'distance': 1092.1770027055795},
#   {'id': 'DLrzXYzAIwyTMXtOv52M1Q',
#    'alias': 'la-trompette-london',
#    'name': 'La Trompette',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Cby03Jtt5sRy86XrSFZP3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-trompette-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.491874, 'longitude': -0.256036},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '3-7 Devonshire Road',
#     'address2': 'Chiswick',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W4 2EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3-7 Devonshire Road',
#      'Chiswick',
#      'London W4 2EU',
#      'United Kingdom']},
#    'phone': '+442087471836',
#    'display_phone': '+44 20 8747 1836',
#    'distance': 8632.197562939984},
#   {'id': 'lD9uGmjLDFjxrHFCZe5kPQ',
#    'alias': 'towpath-café-london-2',
#    'name': 'Towpath Café',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cZ7gaRlHUeD5EMcpG_e0hg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/towpath-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5371934005833,
#     'longitude': -0.0812172889709473},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '42 De Beauvoir Crescent',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 5SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 De Beauvoir Crescent',
#      'London N1 5SB',
#      'United Kingdom']},
#    'phone': '+442072547606',
#    'display_phone': '+44 20 7254 7606',
#    'distance': 4655.828065708086},
#   {'id': 'Eiyg9PK7AE10p_B0Y9Aasg',
#    'alias': 'giuseppes-ristorante-italiano-london',
#    'name': "Giuseppe's Ristorante Italiano",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2Gv0zTYK3pTjQppiigbGHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giuseppes-ristorante-italiano-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5048012364929,
#     'longitude': -0.0897637296226026},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '47/49 Borough High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1NB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47/49 Borough High Street',
#      'London SE1 1NB',
#      'United Kingdom']},
#    'phone': '+442074073451',
#    'display_phone': '+44 20 7407 3451',
#    'distance': 3319.2979090534636},
#   {'id': 'M2Vlk_yEDYwdeNTDb2cHXg',
#    'alias': 'cafe-rouge-hays-galleria-london',
#    'name': 'Cafe Rouge - Hays Galleria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/b-UNdktyERe2krn71RKtTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-rouge-hays-galleria-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5059571359642,
#     'longitude': -0.0832561576154376},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "Hay's Galleria",
#     'address2': 'Tooley Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 2HD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["Hay's Galleria",
#      'Tooley Street',
#      'London SE1 2HD',
#      'United Kingdom']},
#    'phone': '+442073780097',
#    'display_phone': '+44 20 7378 0097',
#    'distance': 3726.4728651063506},
#   {'id': 'ab5UXMk4YZVKROpyjXHmQg',
#    'alias': 'hugos-london',
#    'name': "Hugo's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Dzis5g9vK_ft12fCo74cZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hugos-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.53713, 'longitude': -0.203419},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '21-25 Lonsdale Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 6RA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21-25 Lonsdale Road',
#      'London NW6 6RA',
#      'United Kingdom']},
#    'phone': '+442073721232',
#    'display_phone': '+44 20 7372 1232',
#    'distance': 5392.685570466436}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#             Restaurant                Type Price Rating  \
# 0           Cafe Rouge              French    ££    3.5
# 1    Gazette Brasserie              French    ££      4
# 2            Le Bistro              French   £££      3
# 3  Cepages Wine Bistro  Tapas/Small Plates   £££    3.5
# 4       Côte Brasserie              French    ££    3.5
#
#                    Address        Lat       Lng  \
# 0                   Unit 5  51.513229 -0.099269
# 1        79 Sherwood Court  51.465745 -0.182282
# 2           36 High Street  51.587286 -0.120097
# 3  69 Westbourne Park Road  51.518844 -0.194727
# 4      International House  51.508214 -0.073472
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/cafe-rouge-london-54?...  lrA0Xss9u0lwd4sfEyktmw
# 1  https://www.yelp.com/biz/gazette-brasserie-lon...  XoIWi1dNRrXNv459LFiUkg
# 2  https://www.yelp.com/biz/le-bistro-london?adju...  9NJ6EoGXVbAs17w1jMvQeg
# 3  https://www.yelp.com/biz/cepages-wine-bistro-l...  6WsuX-QP8DQtejctGK6qVg
# 4  https://www.yelp.com/biz/c%C3%B4te-brasserie-l...  3u6E18F9ZBOtitBsXn-Iag

# %%
#3rd set of 50 records 101-150
lndr_params3 = {"term":"bistro","location":"London","limit":50,"offset":101}
lndr_response3 = requests.get(search_api_url, headers=headers, params=lndr_params3)
lndr3 = lndr_response3.json()
display(lndr3)
#print(lndr_response3.url)
#print(lndr_response3.status_code)
# Out:
# {'businesses': [{'id': 'p5kYUF3fVIOoWWcDUqbBfg',
#    'alias': 'numidie-wine-bar-and-bistro-london',
#    'name': 'Numidie Wine Bar and Bistro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yk9q8wDOH2z62RYewibEgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/numidie-wine-bar-and-bistro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4195731, 'longitude': -0.0808072},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '48 Westow Hill',
#     'address2': 'Crystal Palace',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE19 1RX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['48 Westow Hill',
#      'Crystal Palace',
#      'London SE19 1RX',
#      'United Kingdom']},
#    'phone': '+442087666166',
#    'display_phone': '+44 20 8766 6166',
#    'distance': 11041.340404291816},
#   {'id': 'NmFWljc8-TfLlW62zRZ2MA',
#    'alias': 'il-vicolo-london',
#    'name': 'Il Vicolo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OKorcaVjo1GSLPyPs7Fa5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-vicolo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5058047, 'longitude': -0.1375438},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '4 Crown Passage',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 6PP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Crown Passage',
#      'London SW1Y 6PP',
#      'United Kingdom']},
#    'phone': '+442078393960',
#    'display_phone': '+44 20 7839 3960',
#    'distance': 794.6739184290293},
#   {'id': 'MJ23VrNqVO_RE2yHKO2QPw',
#    'alias': 'roast-london',
#    'name': 'Roast',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2Hiovmoq8W4xOIYXPftq2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roast-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 144,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5056071178748,
#     'longitude': -0.0910057691819765},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Stoney Street',
#     'address2': 'Borough Market',
#     'address3': 'The Floral Hall',
#     'city': 'London',
#     'zip_code': 'SE1 1TL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Stoney Street',
#      'Borough Market',
#      'The Floral Hall',
#      'London SE1 1TL',
#      'United Kingdom']},
#    'phone': '+442030066111',
#    'display_phone': '+44 20 3006 6111',
#    'distance': 3212.9883251551605},
#   {'id': 'aukShSND1N8a0a1wmlz8Yg',
#    'alias': 'the-folly-london',
#    'name': 'The Folly',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Vd3GXuBk5wHhOtDvBusftA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-folly-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 99,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.511221522485,
#     'longitude': -0.085984423465873},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '41 Gracechurch Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3V 0BT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41 Gracechurch Street',
#      'London EC3V 0BT',
#      'United Kingdom']},
#    'phone': '+448454680102',
#    'display_phone': '+44 845 468 0102',
#    'distance': 3462.779802865497},
#   {'id': 'UJPGEf1_YiIYQ9NmBmULlA',
#    'alias': 'blueprint-café-london-2',
#    'name': 'Blueprint Café',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dJ523uhUYhR6qAg5-dMhJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blueprint-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5027981, 'longitude': -0.0718366},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Butlers Wharf',
#     'address2': '28 Shad Thames',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 2YD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Butlers Wharf',
#      '28 Shad Thames',
#      'London SE1 2YD',
#      'United Kingdom']},
#    'phone': '+442073787031',
#    'display_phone': '+44 20 7378 7031',
#    'distance': 4578.727848206278},
#   {'id': 'D3fDXB68Mu2MnZefMnDQtA',
#    'alias': 'theos-pizzeria-london',
#    'name': "Theo's Pizzeria",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0iYo7a8v3OvaH1EyKCWpvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/theos-pizzeria-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4736554134774,
#     'longitude': -0.0905126171260563},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Grove Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE5 8SY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Grove Lane', 'London SE5 8SY', 'United Kingdom']},
#    'phone': '+442030264224',
#    'display_phone': '+44 20 3026 4224',
#    'distance': 5373.814160473861},
#   {'id': '-OTXUjtJ0_Mer7PnBir18Q',
#    'alias': 'bistro-190-london',
#    'name': 'Bistro 190',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6kRcu-8_gSTC6X9j3b4_TQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistro-190-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.500257, 'longitude': -0.179609},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'The Gore',
#     'address2': "190 Queen's Gate",
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 5EX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Gore',
#      "190 Queen's Gate",
#      'London SW7 5EX',
#      'United Kingdom']},
#    'phone': '+442075906705',
#    'display_phone': '+44 20 7590 6705',
#    'distance': 3329.1919657473654},
#   {'id': 'pnAxtTzYAyNbgkMbOzNqMw',
#    'alias': 'pidgin-london',
#    'name': 'Pidgin',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IqjZo35neQfGYGOxxlYIdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pidgin-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5454733, 'longitude': -0.061314},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '52 Wilton Way',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 1BG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['52 Wilton Way', 'London E8 1BG', 'United Kingdom']},
#    'phone': '+442072548311',
#    'display_phone': '+44 20 7254 8311',
#    'distance': 6328.408862747327},
#   {'id': 'P3YeWO3ODeWmQVi-IilkAQ',
#    'alias': 'st-john-bar-and-restaurant-london',
#    'name': 'St John Bar and Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8m6whIPf2zLcm6KAhVCsNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-john-bar-and-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 293,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.520481, 'longitude': -0.101486},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '26 St John Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1M 4AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 St John Street',
#      'London EC1M 4AY',
#      'United Kingdom']},
#    'phone': '+442072510848',
#    'display_phone': '+44 20 7251 0848',
#    'distance': 2532.1204734464523},
#   {'id': 'wq0HZVl_n9e6P6tSNSrY8g',
#    'alias': 'les-associes-london',
#    'name': 'Les Associes',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/les-associes-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.5836966, 'longitude': -0.1294846},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '172 Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N8 8JT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['172 Park Road', 'London N8 8JT', 'United Kingdom']},
#    'phone': '+442083488944',
#    'display_phone': '+44 20 8348 8944',
#    'distance': 7891.0550030106915},
#   {'id': 'Dklia9nQPJTU4Vb8gEUQvQ',
#    'alias': 'the-10-cases-london-2',
#    'name': 'The 10 Cases',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/k6jz4FiALRokNi_27XSwqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-10-cases-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5145378112793,
#     'longitude': -0.124330997467041},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '16 Endell Street',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9BD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Endell Street',
#      'Covent Garden',
#      'London WC2H 9BD',
#      'United Kingdom']},
#    'phone': '+442078366801',
#    'display_phone': '+44 20 7836 6801',
#    'distance': 826.402253407595},
#   {'id': 'mZIsVL_tBAx_Tiojwd-n-w',
#    'alias': 'bar-190-london',
#    'name': 'Bar 190',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZNnRo1Wmk-Wh6CMlJi76_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-190-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.500257, 'longitude': -0.179609},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Gore Hotel',
#     'address2': "190 Queen's Gate",
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 5EX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Gore Hotel',
#      "190 Queen's Gate",
#      'London SW7 5EX',
#      'United Kingdom']},
#    'phone': '+442075846601',
#    'display_phone': '+44 20 7584 6601',
#    'distance': 3329.1919657473654},
#   {'id': 'k7DpLR2q_4CSNWjWSh3CeA',
#    'alias': 'mosaic-clapton-london',
#    'name': 'Mosaic Clapton',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eMYwa1JFHgjIa_ZsXSmJHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mosaic-clapton-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.563061, 'longitude': -0.057943},
#    'transactions': [],
#    'location': {'address1': '118 Upper Clapton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E5 9JY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['118 Upper Clapton Road',
#      'London E5 9JY',
#      'United Kingdom']},
#    'phone': '+442088808448',
#    'display_phone': '+44 20 8880 8448',
#    'distance': 7766.572182102159},
#   {'id': 'kKgmD8eX-4WVY2_oZH3xQA',
#    'alias': 'côte-richmond-2',
#    'name': 'Côte',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xDQLBxLgl_o7Nnw8Q_5N1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/c%C3%B4te-richmond-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4590314, 'longitude': -0.3058683},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '24 Hill Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': 'TW9 1TW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Hill Street',
#      'Richmond TW9 1TW',
#      'United Kingdom']},
#    'phone': '+442089485971',
#    'display_phone': '+44 20 8948 5971',
#    'distance': 13203.18931497913},
#   {'id': '9jY-_VLBs4XVXgiGApNe7Q',
#    'alias': 'colbert-chelsea',
#    'name': 'Colbert',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4_6HwpF9QVUOxw4ktCqWUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/colbert-chelsea?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4928527, 'longitude': -0.1566231},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '50-52 Sloane Square',
#     'address2': '',
#     'address3': '',
#     'city': 'Chelsea',
#     'zip_code': 'SW1W 8AX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50-52 Sloane Square',
#      'Chelsea SW1W 8AX',
#      'United Kingdom']},
#    'phone': '+442077302804',
#    'display_phone': '+44 20 7730 2804',
#    'distance': 2642.645637785076},
#   {'id': 'JjtiuWxSz02AHLhwWkDKGw',
#    'alias': 'ma-cuisine-richmond',
#    'name': 'Ma Cuisine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OxSeEYbBLpe20lLvNC2ahw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ma-cuisine-richmond?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4776529044901,
#     'longitude': -0.285841634215271},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '9 Station Approach',
#     'address2': '',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': 'TW9 3QB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Station Approach',
#      'Richmond TW9 3QB',
#      'United Kingdom']},
#    'phone': '+442083321923',
#    'display_phone': '+44 20 8332 1923',
#    'distance': 11089.227968593194},
#   {'id': 'j5xjbDDO3erW3wdBeDyzeg',
#    'alias': 'chez-antoinette-london-2',
#    'name': 'Chez Antoinette',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WQiGj5B9kq6BqHm2jLxsNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chez-antoinette-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.49827, 'longitude': -0.13541},
#    'transactions': [],
#    'location': {'address1': '22 Palmer Street',
#     'address2': '',
#     'address3': 'Victoria',
#     'city': 'London',
#     'zip_code': 'SW1H 0PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Palmer Street',
#      'Victoria',
#      'London SW1H 0PH',
#      'United Kingdom']},
#    'phone': '+442039905377',
#    'display_phone': '+44 20 3990 5377',
#    'distance': 1620.0507638628308},
#   {'id': 'yY5Ng5ujlAZSToWRmLTzQw',
#    'alias': 'steak-and-lobster-bloomsbury-london-4',
#    'name': 'Steak & Lobster',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tr7rTLMdrhyaX7X78kpu7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/steak-and-lobster-bloomsbury-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5173945928254,
#     'longitude': -0.127506986952353},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9-13 Bloomsbury Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3QD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9-13 Bloomsbury Street',
#      'London WC1B 3QD',
#      'United Kingdom']},
#    'phone': '+442088170944',
#    'display_phone': '+44 20 8817 0944',
#    'distance': 773.8175616267521},
#   {'id': '6UNIlCN-8Hs9faqwXAW3Jg',
#    'alias': '86-bistro-bar-london',
#    'name': '86 Bistro Bar',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/86-bistro-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.585114, 'longitude': -0.219755},
#    'transactions': [],
#    'location': {'address1': '86 Brent Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW4 2EF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['86 Brent Street',
#      'London NW4 2EF',
#      'United Kingdom']},
#    'phone': '+442082025575',
#    'display_phone': '+44 20 8202 5575',
#    'distance': 9903.144674508563},
#   {'id': 'bUSpzLnvC70PBrnjlUJ-UA',
#    'alias': 'the-premises-cafe-london-2',
#    'name': 'The Premises Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HBOIWM_um4Vai-xpN1ti_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-premises-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5310580220194,
#     'longitude': -0.0715311831245662},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '209 Hackney Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 8JL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['209 Hackney Road',
#      'London E2 8JL',
#      'United Kingdom']},
#    'phone': '+442076842230',
#    'display_phone': '+44 20 7684 2230',
#    'distance': 4896.289109394247},
#   {'id': 'N05ni488O0XQg3jBC_I70Q',
#    'alias': 'patron-cave-à-manger-london',
#    'name': 'Patron Cave à Manger',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tgp0F-9luVM5TmETlrMxfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patron-cave-%C3%A0-manger-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'},
#     {'alias': 'wineries', 'title': 'Wineries'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5526877, 'longitude': -0.1407776},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '26 Fortess Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW5 2HB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Fortess Road',
#      'London NW5 2HB',
#      'United Kingdom']},
#    'phone': '+442078132540',
#    'display_phone': '+44 20 7813 2540',
#    'distance': 4443.888889614833},
#   {'id': 'w1TqrVGd_NzAwQzNVWslEw',
#    'alias': 'il-girasole-london-3',
#    'name': 'Il Girasole',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BfZHWS_CUPqawdcPVjwhRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-girasole-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4504059832827,
#     'longitude': -0.189856372855288},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '189 Garratt Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW18 4DR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['189 Garratt Lane',
#      'London SW18 4DR',
#      'United Kingdom']},
#    'phone': '+442088700931',
#    'display_phone': '+44 20 8870 0931',
#    'distance': 7881.678816924638},
#   {'id': 'f1S9DYmRFzU7VrYq4TKFGQ',
#    'alias': 'meat-people-london',
#    'name': 'Meat People',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6QpfZ1LGx3zVUqAVMHLJSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meat-people-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.536386, 'longitude': -0.101694},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4-6 Essex Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8LN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4-6 Essex Road', 'London N1 8LN', 'United Kingdom']},
#    'phone': '+442073595361',
#    'display_phone': '+44 20 7359 5361',
#    'distance': 3532.142357201449},
#   {'id': '6hYgYyILbzIiSnim8ulcXg',
#    'alias': 'cafe-rouge-victoria-london',
#    'name': 'Cafe Rouge - Victoria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HmEzddjeenuQhzO8pntNPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-rouge-victoria-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4944773020436,
#     'longitude': -0.145459243377677},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Victoria Place Shopping Centre',
#     'address2': 'Buckingham Palace Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 9SJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Victoria Place Shopping Centre',
#      'Buckingham Palace Road',
#      'London SW1W 9SJ',
#      'United Kingdom']},
#    'phone': '+442079319300',
#    'display_phone': '+44 20 7931 9300',
#    'distance': 2144.699459841088},
#   {'id': 'mQ9xQov8ZSfXfmkSRd95Vg',
#    'alias': 'le-pain-quotidien-london-18',
#    'name': 'Le Pain Quotidien',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TAbUKKxwL4-EOdAq6edePA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-pain-quotidien-london-18?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4941248, 'longitude': -0.1423182},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '128 Wilton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1JZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['128 Wilton Road',
#      'London SW1V 1JZ',
#      'United Kingdom']},
#    'phone': '+442036576945',
#    'display_phone': '+44 20 3657 6945',
#    'distance': 2131.1889217821545},
#   {'id': 'gbZKs7QD7X9ZHNGACy2B9g',
#    'alias': 'brawn-london-2',
#    'name': 'Brawn',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gdMBMbPsKe6lu_mYnhhqxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brawn-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5289277153112,
#     'longitude': -0.0702632793320869},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '49 Columbia Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7RG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Columbia Road',
#      'London E2 7RG',
#      'United Kingdom']},
#    'phone': '+442077295692',
#    'display_phone': '+44 20 7729 5692',
#    'distance': 4884.719992328003},
#   {'id': 'DkKOKkZ0l1qm07cAG_CKgg',
#    'alias': 'the-waterway-london',
#    'name': 'The Waterway',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/abNrsJwGZ5JioeuDw1juJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-waterway-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.522673179187,
#     'longitude': -0.18780904971049},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '54 Formosa Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W9 2JU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54 Formosa Street',
#      'London W9 2JU',
#      'United Kingdom']},
#    'phone': '+442072663557',
#    'display_phone': '+44 20 7266 3557',
#    'distance': 3750.9542355647377},
#   {'id': 'rb3DTjC5mhEnjy-ay0AYUw',
#    'alias': 'the-dovetail-london-2',
#    'name': 'The Dovetail',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8pCWYHYQUY_nA_ufbWM4tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dovetail-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 69,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'belgian', 'title': 'Belgian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5232408423047,
#     'longitude': -0.103924836781924},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9-10 Jerusalem Passage',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 4JP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9-10 Jerusalem Passage',
#      'London EC1V 4JP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2500.151841017729},
#   {'id': 'uTm94f_-FlwM7v7T2ycXaQ',
#    'alias': 'dominique-ansel-treehouse-london',
#    'name': 'Dominique Ansel Treehouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Amyw6Q1tbkeeiPYFPnwBUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dominique-ansel-treehouse-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5119045680643,
#     'longitude': -0.12540479881136},
#    'transactions': [],
#    'location': {'address1': '24 Floral Street',
#     'address2': '',
#     'address3': 'Covent Garden',
#     'city': 'London',
#     'zip_code': 'WC2E 9DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Floral Street',
#      'Covent Garden',
#      'London WC2E 9DP',
#      'United Kingdom']},
#    'phone': '+442038834710',
#    'display_phone': '+44 20 3883 4710',
#    'distance': 737.4485292911053},
#   {'id': 'HHX4T0ofksCdF-MAbWJqJA',
#    'alias': 'i-mattoni-italian-bistro-london',
#    'name': 'I Mattoni Italian Bistro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cB-t-uUNrsHXjN2iIujLBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/i-mattoni-italian-bistro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5246712, 'longitude': -0.07146},
#    'transactions': [],
#    'location': {'address1': '224 Brick Lane',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6SA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['224 Brick Lane', 'London E1 6SA', 'United Kingdom']},
#    'phone': '+442032220031',
#    'display_phone': '+44 20 3222 0031',
#    'distance': 4653.745072645295},
#   {'id': 'o23aihPccXrnfs99k7GvrQ',
#    'alias': 'bel-canto-london',
#    'name': 'Bel Canto',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4Rzfm9mrD_tWue7luYN4Wg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bel-canto-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'opera', 'title': 'Opera & Ballet'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.511827, 'longitude': -0.177283},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'Corus Hotel Hyde Park',
#     'address2': '1 Lancaster Gate',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3LG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Corus Hotel Hyde Park',
#      '1 Lancaster Gate',
#      'London W2 3LG',
#      'United Kingdom']},
#    'phone': '+442072621678',
#    'display_phone': '+44 20 7262 1678',
#    'distance': 2862.1079667918084},
#   {'id': 'GPH3kE8QkDwg-onqjvON8g',
#    'alias': 'côte-london-25',
#    'name': 'Côte',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/c%C3%B4te-london-25?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.475345, 'longitude': -0.2005651},
#    'transactions': [],
#    'location': {'address1': '45-47 Parsons Green Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 4HH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45-47 Parsons Green Lane',
#      'London SW6 4HH',
#      'United Kingdom']},
#    'phone': '+442077368444',
#    'display_phone': '+44 20 7736 8444',
#    'distance': 6117.030770597906},
#   {'id': 'Oir2IPE1gDK8Wn08QjC8tQ',
#    'alias': 'high-road-brasserie-london',
#    'name': 'High Road Brasserie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OqO6NgCY0lHN_Ogiwi_HLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/high-road-brasserie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.492899, 'longitude': -0.25468},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '162-170 Chiswick High Road',
#     'address2': 'Chiswick',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W4 1PR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['162-170 Chiswick High Road',
#      'Chiswick',
#      'London W4 1PR',
#      'United Kingdom']},
#    'phone': '+442087427474',
#    'display_phone': '+44 20 8742 7474',
#    'distance': 8511.380326534038},
#   {'id': '35B3UJMEaI1sQj4vaKK0RQ',
#    'alias': 'percy-and-founders-london',
#    'name': 'Percy & Founders',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/H_OABaaEO2qHgs_Zx-yG_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/percy-and-founders-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5187944346049,
#     'longitude': -0.137987967211919},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1 Pearson Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 3BF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Pearson Square',
#      'London W1T 3BF',
#      'United Kingdom']},
#    'phone': '+442037610200',
#    'display_phone': '+44 20 3761 0200',
#    'distance': 677.3569343118869},
#   {'id': 'zZQdJRJ1hqFuNWmCuOictg',
#    'alias': 'dalloway-terrace-london',
#    'name': 'Dalloway Terrace',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9ANzc_AlRXqIjZVrsq51JQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dalloway-terrace-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5172302719223,
#     'longitude': -0.12909671319926},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '16-22 Great Russell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3NN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16-22 Great Russell Street',
#      'London WC1B 3NN',
#      'United Kingdom']},
#    'phone': '+442073471221',
#    'display_phone': '+44 20 7347 1221',
#    'distance': 681.2327177861348},
#   {'id': 'OJ2yeF6g2V9cLB43t_tsUg',
#    'alias': 'antidote-london',
#    'name': 'Antidote',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kMIqtclGgZxXFuoa042vCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/antidote-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.513656, 'longitude': -0.138937},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '12a Newburgh Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7RR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12a Newburgh Street',
#      'London W1F 7RR',
#      'United Kingdom']},
#    'phone': '+442072878488',
#    'display_phone': '+44 20 7287 8488',
#    'distance': 219.9272136017088},
#   {'id': 'q_NslqBpXfOJPA5IhZcamw',
#    'alias': 'café-rouge-canary-wharf-2',
#    'name': 'Café Rouge',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HC4I0SR6fa3AXtuTTeW8BA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-rouge-canary-wharf-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5042167008322,
#     'longitude': -0.0219336899683067},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10 Cabot Square',
#     'address2': '29-35 Mackenzie Walk',
#     'address3': '',
#     'city': 'Canary Wharf',
#     'zip_code': 'E14 4PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Cabot Square',
#      '29-35 Mackenzie Walk',
#      'Canary Wharf E14 4PH',
#      'United Kingdom']},
#    'phone': '+442075379696',
#    'display_phone': '+44 20 7537 9696',
#    'distance': 7949.161406124531},
#   {'id': 'FypPh_46MQ6nqunRXkPOAw',
#    'alias': 'laville-café-london-2',
#    'name': 'Laville Café',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2OCmV1azDb0CbWAgV-tveQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laville-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5245752, 'longitude': -0.176988},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '453 Edgware Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1TH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['453 Edgware Road',
#      'London W2 1TH',
#      'United Kingdom']},
#    'phone': '+442077062620',
#    'display_phone': '+44 20 7706 2620',
#    'distance': 3120.80672373354},
#   {'id': 'p4RDP4LpUQ2s2FiVs4mGhQ',
#    'alias': 'balans-soho-society-london-2',
#    'name': 'Balans Soho Society',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jR3NeGD5-44qMGf1q6jOZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/balans-soho-society-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 113,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5127825041885,
#     'longitude': -0.132572578634624},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '60 - 62 Old Compton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 4UG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['60 - 62 Old Compton Street',
#      'London W1D 4UG',
#      'United Kingdom']},
#    'phone': '+442074392183',
#    'display_phone': '+44 20 7439 2183',
#    'distance': 234.19702494574196},
#   {'id': 'xEl4Oi1lfAa5g17Z5UsHNQ',
#    'alias': 'gymkhana-london',
#    'name': 'Gymkhana',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NujCGIGT3q4KG0SLlWpCeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gymkhana-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 135,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.50842, 'longitude': -0.1416607},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '42 Albemarle Street',
#     'address2': 'Mayfair',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 4JH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 Albemarle Street',
#      'Mayfair',
#      'London W1S 4JH',
#      'United Kingdom']},
#    'phone': '+442030115900',
#    'display_phone': '+44 20 3011 5900',
#    'distance': 630.0265103387487},
#   {'id': 'QFOUxTcxG3tB9HyxvfU1FA',
#    'alias': 'vinoteca-london',
#    'name': 'Vinoteca',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Js05toclN6pen1N2jlfWYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vinoteca-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.520121, 'longitude': -0.101915},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '7 St John Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1M 4AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 St John Street',
#      'London EC1M 4AA',
#      'United Kingdom']},
#    'phone': '+442072538786',
#    'display_phone': '+44 20 7253 8786',
#    'distance': 2490.8823586808176},
#   {'id': 'BYX50yHA19PVF1blGIwe7A',
#    'alias': 'rossopomodoro-covent-garden-london-2',
#    'name': 'Rossopomodoro Covent Garden',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/M7-6tZEILmmq2SSd-V5gNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rossopomodoro-covent-garden-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 93,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5130126011976,
#     'longitude': -0.127266748729596},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '50-52 Monmouth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50-52 Monmouth Street',
#      'London WC2H 9EP',
#      'United Kingdom']},
#    'phone': '+442072409095',
#    'display_phone': '+44 20 7240 9095',
#    'distance': 601.6120072406837},
#   {'id': 'fYQXciEc6YVzUtla0zwY1A',
#    'alias': 'capricci-london',
#    'name': 'Capricci',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/capricci-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5066039673511,
#     'longitude': -0.10060931288611},
#    'transactions': [],
#    'location': {'address1': 'Unit C South 72 Holland Street',
#     'address2': '',
#     'address3': 'Neo Bankside',
#     'city': 'London',
#     'zip_code': 'SE1 9NX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit C South 72 Holland Street',
#      'Neo Bankside',
#      'London SE1 9NX',
#      'United Kingdom']},
#    'phone': '+442070210703',
#    'display_phone': '+44 20 7021 0703',
#    'distance': 2542.422658653255},
#   {'id': 'g0meBQ4_XzfKh8AzsTDV7Q',
#    'alias': 'la-muse-london',
#    'name': 'La Muse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QX3AemHqNR7F3VFkLeQE3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-muse-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.548152923584,
#     'longitude': -0.106881998479366},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '119 Holloway Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N7 8LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['119 Holloway Road',
#      'London N7 8LT',
#      'United Kingdom']},
#    'phone': '+442076095397',
#    'display_phone': '+44 20 7609 5397',
#    'distance': 4412.136059154432},
#   {'id': 'qsX8IzkDl1MdvzgUgyqgPA',
#    'alias': 'chez-tonton-london',
#    'name': 'Chez Tonton',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3tHopOl6t-Ggu7T7XpFtYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chez-tonton-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.64746, 'longitude': -0.1679394},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '182 East Barnet Road',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EN4 8QZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['182 East Barnet Road',
#      'London EN4 8QZ',
#      'United Kingdom']},
#    'phone': '+442084402696',
#    'display_phone': '+44 20 8440 2696',
#    'distance': 15131.800327775265},
#   {'id': 'DEi9vdDupeUWP7xjn7viug',
#    'alias': 'le-marmiton-london',
#    'name': 'Le Marmiton',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m4fDgvMKD0M1SyrhJfnb7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-marmiton-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5767097473145,
#     'longitude': 0.0276740007102489},
#    'transactions': [],
#    'location': {'address1': '147 High St',
#     'address2': '',
#     'address3': 'Wanstead',
#     'city': 'London',
#     'zip_code': 'E11 2RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['147 High St',
#      'Wanstead',
#      'London E11 2RL',
#      'United Kingdom']},
#    'phone': '+442089898343',
#    'display_phone': '+44 20 8989 8343',
#    'distance': 13366.3269846087},
#   {'id': 'aCAF8K9MRhiHWri1CqxyAw',
#    'alias': 'le-mercury-deuxième-london',
#    'name': 'Le Mercury Deuxième',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PT0JQL9nha9wwotqrlr57A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-mercury-deuxi%C3%A8me-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5402908, 'longitude': -0.1028201},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '154 - 155 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 1RA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['154 - 155 Upper Street',
#      'London N1 1RA',
#      'United Kingdom']},
#    'phone': '+442073544088',
#    'display_phone': '+44 20 7354 4088',
#    'distance': 3827.6364867576485},
#   {'id': 'dlvKn_WhoRRaDYvpD9xqwA',
#    'alias': 'aubaine-london-10',
#    'name': 'Aubaine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cermR1IRFSVI7BPImTB9_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aubaine-london-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5197551050192,
#     'longitude': -0.152480434975379},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '7 Moxon Street',
#     'address2': 'Marylebone',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 4EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Moxon Street',
#      'Marylebone',
#      'London W1U 4EP',
#      'United Kingdom']},
#    'phone': '+442033936330',
#    'display_phone': '+44 20 3393 6330',
#    'distance': 1378.204083313898},
#   {'id': 'j5N5Foo455q3yYL62TMQ7A',
#    'alias': '2-veneti-london',
#    'name': '2 Veneti',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7cuh-F0NTlYVFxcKMJovIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/2-veneti-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.516872, 'longitude': -0.146676},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '8-10 Wigmore Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 2RD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8-10 Wigmore Street',
#      'London W1U 2RD',
#      'United Kingdom']},
#    'phone': '+442076370789',
#    'display_phone': '+44 20 7637 0789',
#    'distance': 869.0706560948065},
#   {'id': 'rWUDw95a8l8TZDarLzZWGQ',
#    'alias': 'the-somers-town-coffee-house-london',
#    'name': 'The Somers Town Coffee House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xAii6LZjUJ4GmWcDQCBTvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-somers-town-coffee-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.529882, 'longitude': -0.130116},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '60 Chalton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 1HS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['60 Chalton Street',
#      'London NW1 1HS',
#      'United Kingdom']},
#    'phone': '+442073877377',
#    'display_phone': '+44 20 7387 7377',
#    'distance': 1944.8628397700331}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                     Restaurant           Type Price Rating  \
# 0  Numidie Wine Bar and Bistro  Mediterranean   £££      4
# 1                    Il Vicolo        Italian   £££      4
# 2                        Roast        British   £££    3.5
# 3                    The Folly      Wine Bars    ££      3
# 4               Blueprint Café        British   £££    3.5
#
#                  Address        Lat       Lng  \
# 0         48 Westow Hill  51.419573 -0.080807
# 1        4 Crown Passage  51.505805 -0.137544
# 2          Stoney Street  51.505607 -0.091006
# 3  41 Gracechurch Street  51.511222 -0.085984
# 4          Butlers Wharf  51.502798 -0.071837
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/numidie-wine-bar-and-...  p5kYUF3fVIOoWWcDUqbBfg
# 1  https://www.yelp.com/biz/il-vicolo-london?adju...  NmFWljc8-TfLlW62zRZ2MA
# 2  https://www.yelp.com/biz/roast-london?adjust_c...  MJ23VrNqVO_RE2yHKO2QPw
# 3  https://www.yelp.com/biz/the-folly-london?adju...  aukShSND1N8a0a1wmlz8Yg
# 4  https://www.yelp.com/biz/blueprint-caf%C3%A9-l...  UJPGEf1_YiIYQ9NmBmULlA

# %%
#4th set of 50 records 151-200
lndr_params4 = {"term":"bistro","location":"London","limit":50,"offset":151}
lndr_response4 = requests.get(search_api_url, headers=headers, params=lndr_params4)
lndr4 = lndr_response4.json()
display(lndr4)
#print(lndr_response4.url)
#print(lndr_response4.status_code)
# Out:
# {'businesses': [{'id': 'NDo0J9G78sNzB0ygRnyd9Q',
#    'alias': 'la-cage-imaginaire-london',
#    'name': 'La Cage Imaginaire',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MSWQZ9WStCM9WGEvqQzCeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-cage-imaginaire-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.556657355356, 'longitude': -0.177122449176},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '16 Flask Walk',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 1HE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Flask Walk', 'London NW3 1HE', 'United Kingdom']},
#    'phone': '+442077946674',
#    'display_phone': '+44 20 7794 6674',
#    'distance': 5643.710155639079},
#   {'id': '0PevNLQx8HyuKHBzg8Fy6w',
#    'alias': 'goode-and-wright-london-2',
#    'name': 'Goode & Wright',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Iz_5kE8SXbNVj7pkSmbPFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/goode-and-wright-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.517861, 'longitude': -0.206798},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '271 Portobello Road',
#     'address2': 'Notting Hill',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 1LR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['271 Portobello Road',
#      'Notting Hill',
#      'London W11 1LR',
#      'United Kingdom']},
#    'phone': '+442077275552',
#    'display_phone': '+44 20 7727 5552',
#    'distance': 4929.528334980876},
#   {'id': 'JTJJxemAOT7ZYyec8xRo2A',
#    'alias': 'vinoteca-london-2',
#    'name': 'Vinoteca',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JSQ0xXBPOxRiK1t-RBzzaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vinoteca-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5148735046387,
#     'longitude': -0.16143000125885},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '15 Seymour Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 5BD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Seymour Place',
#      'London W1H 5BD',
#      'United Kingdom']},
#    'phone': '+442077247288',
#    'display_phone': '+44 20 7724 7288',
#    'distance': 1777.3036126501836},
#   {'id': 'NeQ8axi9Lo_c3lvDCHMPHA',
#    'alias': 'on-the-hoof-bistro-london',
#    'name': 'On the Hoof Bistro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/K3XqClR_FulEkg8p1cdBKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/on-the-hoof-bistro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4271367682652,
#     'longitude': -0.0543293632657697},
#    'transactions': [],
#    'location': {'address1': '23 Sydenham Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE26 5EX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23 Sydenham Road',
#      'London SE26 5EX',
#      'United Kingdom']},
#    'phone': '+442086597333',
#    'display_phone': '+44 20 8659 7333',
#    'distance': 11080.327717646642},
#   {'id': 'Mca0on6b9pNIqGL58y8ybA',
#    'alias': 'champagne-fromage-greenwich',
#    'name': 'Champagne + Fromage',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ycsUITknG0JnJfKVfjHbdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/champagne-fromage-greenwich?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4813385219267,
#     'longitude': -0.00981522017236669},
#    'transactions': [],
#    'location': {'address1': '34 Church Street',
#     'address2': None,
#     'address3': None,
#     'city': 'Greenwich',
#     'zip_code': 'SE10 9BL',
#     'country': 'GB',
#     'state': 'BPL',
#     'display_address': ['34 Church Street',
#      'Greenwich SE10 9BL',
#      'United Kingdom']},
#    'phone': '+442088533106',
#    'display_phone': '+44 20 8853 3106',
#    'distance': 9408.238557713998},
#   {'id': 'UL75qDGkw5E4osQBUa51Hw',
#    'alias': 'the-little-french-restaurant-london',
#    'name': 'The Little French Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/B6caAENKFuO-TSooZGq2Wg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-little-french-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.493280025088,
#     'longitude': -0.19252729950596},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18 Hogarth Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 0QY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Hogarth Place',
#      'London SW5 0QY',
#      'United Kingdom']},
#    'phone': '+442073700366',
#    'display_phone': '+44 20 7370 0366',
#    'distance': 4478.899043924287},
#   {'id': 'B3KOxvXOZ5Kzfi8qe7sVuw',
#    'alias': 'marlborough-head-london',
#    'name': 'Marlborough Head',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GGFYIOu9pNvKp-b6BsJoAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marlborough-head-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5133685, 'longitude': -0.1537988},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '24 North Audley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 6WD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 North Audley Street',
#      'London W1K 6WD',
#      'United Kingdom']},
#    'phone': '+442076295981',
#    'display_phone': '+44 20 7629 5981',
#    'distance': 1238.0514083314017},
#   {'id': 'wj39WtyNO1sbwW7KemxvMg',
#    'alias': 'petit-bistro-london',
#    'name': 'Petit Bistro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cS5BCYenVpYhTjgBpOI88A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/petit-bistro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 51.511125, 'longitude': -0.129728},
#    'transactions': [],
#    'location': {'address1': '14 Leicester Place',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 7BZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Leicester Place',
#      'London WC2H 7BZ',
#      'United Kingdom']},
#    'phone': '+442039094099',
#    'display_phone': '+44 20 3909 4099',
#    'distance': 471.0823929894413},
#   {'id': 'n7vXgfapPy4uGLgqsUTDyg',
#    'alias': 'the-barge-house-london',
#    'name': 'The Barge House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qyRLwAeCfi9ydDeemsMTwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-barge-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5372997, 'longitude': -0.0808728},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '46 De Beauvoir Crescent',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 5RY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['46 De Beauvoir Crescent',
#      'London N1 5RY',
#      'United Kingdom']},
#    'phone': '+442072490765',
#    'display_phone': '+44 20 7249 0765',
#    'distance': 4682.087331063891},
#   {'id': 'tjb7FqjU3KZy_DJ8YI76QQ',
#    'alias': 'la-petite-auberge-islington',
#    'name': 'La Petite Auberge',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4WxSwWlQrkVrvCgoBovEsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-petite-auberge-islington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.540003, 'longitude': -0.102363},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '283 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Islington',
#     'zip_code': 'N1 2TZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['283 Upper Street',
#      'Islington N1 2TZ',
#      'United Kingdom']},
#    'phone': '+442073591046',
#    'display_phone': '+44 20 7359 1046',
#    'distance': 3811.3668401295213},
#   {'id': 'U3Pha6qoX5MraAp5oa7oXA',
#    'alias': 'les-deux-salons-london',
#    'name': 'Les Deux Salons',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TBoImaahar84wFkOSl__hw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/les-deux-salons-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5096092224121,
#     'longitude': -0.126536995172501},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '40 - 42 William IV Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4DD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 - 42 William IV Street',
#      'London WC2N 4DD',
#      'United Kingdom']},
#    'phone': '+442074202050',
#    'display_phone': '+44 20 7420 2050',
#    'distance': 744.0166506668805},
#   {'id': 'rKwkCvsSfp8z7w1CmNnMMQ',
#    'alias': 'the-table-london-8',
#    'name': 'The Table',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/T-rwpQYiLxDyUXGNAwEYSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-table-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 268,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.505604, 'longitude': -0.099671},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '83 Southwark Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Southwark Street',
#      'London SE1 0HX',
#      'United Kingdom']},
#    'phone': '+442074012760',
#    'display_phone': '+44 20 7401 2760',
#    'distance': 2636.7435245046486},
#   {'id': 'pW_F-spe0hHOC83OM1Yqdw',
#    'alias': 'browns-mayfair-london',
#    'name': 'Browns Mayfair',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KMi_n7cP3ssnAzZT5PPLZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/browns-mayfair-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5123936, 'longitude': -0.1443771},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '47 Maddox Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 2PG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Maddox Street',
#      'London W1S 2PG',
#      'United Kingdom']},
#    'phone': '+442074914565',
#    'display_phone': '+44 20 7491 4565',
#    'distance': 584.8316770474845},
#   {'id': 'AKhm8Oc4qVGobeQ555DuxQ',
#    'alias': 'richoux-london-2',
#    'name': 'Richoux',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mRmYWUBhUgMGgdnadY7Iqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/richoux-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.50799, 'longitude': -0.139541},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '172 Piccadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 9EJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['172 Piccadilly', 'London W1J 9EJ', 'United Kingdom']},
#    'phone': '+442074932204',
#    'display_phone': '+44 20 7493 2204',
#    'distance': 593.1789691622027},
#   {'id': 'jEvDRYIW2ySE0nrtFZIIgQ',
#    'alias': 'palm-court-brasserie-london',
#    'name': 'Palm Court Brasserie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0qlAaCheTterq-D2WBwSEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/palm-court-brasserie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5118843, 'longitude': -0.1242749},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Covent Garden',
#     'address2': '39 King Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 8JS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Covent Garden',
#      '39 King Street',
#      'London WC2E 8JS',
#      'United Kingdom']},
#    'phone': '+442072402939',
#    'display_phone': '+44 20 7240 2939',
#    'distance': 818.0638495250915},
#   {'id': 'ZKfiQaOMDu7rfVhmMmQ0bQ',
#    'alias': 'berners-tavern-london-5',
#    'name': 'Berners Tavern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tnfzvqS02pyFcaF6b2f8xw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/berners-tavern-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 121,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5167515074354,
#     'longitude': -0.135977268218994},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '10 Berners Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 3NP',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ['10 Berners Street',
#      'London W1T 3NP',
#      'United Kingdom']},
#    'phone': '+442077810000',
#    'display_phone': '+44 20 7781 0000',
#    'distance': 435.43985267437006},
#   {'id': 'xqpUr61KFa1Xx721-E6l_A',
#    'alias': 'kipferl-london-6',
#    'name': 'Kipferl',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CUoYGTlW1CYS-nJ5vAUGPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kipferl-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'austrian', 'title': 'Austrian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.535247538411,
#     'longitude': -0.10339315152949},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Camden Passage',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Camden Passage',
#      'London N1 8ED',
#      'United Kingdom']},
#    'phone': '+442077041555',
#    'display_phone': '+44 20 7704 1555',
#    'distance': 3359.4222431551457},
#   {'id': 'gAvhYy-7tpNGwpxo7qWtzw',
#    'alias': 'côte-brasserie-islington-london-2',
#    'name': 'Côte Brasserie - Islington',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RRJpz66K2V9pA8aZEevTQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/c%C3%B4te-brasserie-islington-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5365193816325,
#     'longitude': -0.102964639663696},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4-6 Islington Green',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 2XA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4-6 Islington Green',
#      'London N1 2XA',
#      'United Kingdom']},
#    'phone': '+442073544666',
#    'display_phone': '+44 20 7354 4666',
#    'distance': 3484.953778688318},
#   {'id': 'AueQllfNne75UQ7Ilv7zkw',
#    'alias': 'small-and-beautiful-london-2',
#    'name': 'Small & Beautiful',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RBasn2CqPSNcUXixNq_j9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/small-and-beautiful-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.545139, 'longitude': -0.2019203},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '351 Kilburn High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 7QB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['351 Kilburn High Road',
#      'London NW6 7QB',
#      'United Kingdom']},
#    'phone': '+442073282637',
#    'display_phone': '+44 20 7328 2637',
#    'distance': 5807.318511396982},
#   {'id': 'IIMtF_7RpIGBBPN9qN0CRA',
#    'alias': 'daquise-london-2',
#    'name': 'Daquise',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EBYm0vNE2edUR1BUXvi9zQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daquise-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 76,
#    'categories': [{'alias': 'polish', 'title': 'Polish'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4943231, 'longitude': -0.1736183},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '20 Thurloe Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 2LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Thurloe Street',
#      'London SW7 2LT',
#      'United Kingdom']},
#    'phone': '+442075896117',
#    'display_phone': '+44 20 7589 6117',
#    'distance': 3302.7034521636515},
#   {'id': 'vyI7OOJ9O0g4n-1a2K76fw',
#    'alias': 'osteria-ambrosia-london',
#    'name': 'Osteria Ambrosia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C3XjBegNSwWjiqAgLnWlog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osteria-ambrosia-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5148440635957,
#     'longitude': -0.150470774015474},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '48-50 St Johns',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW11 1PR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['48-50 St Johns',
#      'London SW11 1PR',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1028.9571314781385},
#   {'id': 'wP8WFnsso_3SSHzrtYzVeQ',
#    'alias': 'troy-cafe-bistro-london',
#    'name': 'Troy Cafe Bistro',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6_fH70--nEUR8vcS60A5Ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/troy-cafe-bistro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5304613, 'longitude': -0.0770172},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '124 Kingsland Road',
#     'address2': 'Shoreditch',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 8DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['124 Kingsland Road',
#      'Shoreditch',
#      'London E2 8DP',
#      'United Kingdom']},
#    'phone': '+442070339514',
#    'display_phone': '+44 20 7033 9514',
#    'distance': 4530.976616099971},
#   {'id': '0Z-sI1cddyYJ7Sj3LLvu9g',
#    'alias': 'le-caprice-london',
#    'name': 'Le Caprice',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xFeldNgDxQXit-PANvpoFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-caprice-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5067509, 'longitude': -0.1406103},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '20 Arlington Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1A 1RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Arlington Street',
#      'London SW1A 1RJ',
#      'United Kingdom']},
#    'phone': '+442076292239',
#    'display_phone': '+44 20 7629 2239',
#    'distance': 749.3444329594134},
#   {'id': 'g79KR-kAcJS9OH_f-ZrG0g',
#    'alias': 'york-and-albany-london',
#    'name': 'York & Albany',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/55UXVEuayVfeNcdXrn1oYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/york-and-albany-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 92,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5359792, 'longitude': -0.1466359},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '127-129 Parkway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 7PS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['127-129 Parkway',
#      'London NW1 7PS',
#      'United Kingdom']},
#    'phone': '+442075921227',
#    'display_phone': '+44 20 7592 1227',
#    'distance': 2686.89262750153},
#   {'id': 'WAzWfY8YK8LVv9T-mlqY6A',
#    'alias': 'côte-london-19',
#    'name': 'Côte',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cC596zVHbvJ6U1upIpEC_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/c%C3%B4te-london-19?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.424379, 'longitude': -0.216106},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8 High Street',
#     'address2': 'Wimbledon Village',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW19 5DX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 High Street',
#      'Wimbledon Village',
#      'London SW19 5DX',
#      'United Kingdom']},
#    'phone': '+442089477100',
#    'display_phone': '+44 20 8947 7100',
#    'distance': 11294.60127269989},
#   {'id': 'csVPVnXRUxb9pmCqe-kFJQ',
#    'alias': 'made-in-camden-london',
#    'name': 'Made In Camden',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PklaOIKUIHO1_eI6HABcGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/made-in-camden-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5434890275839,
#     'longitude': -0.152038804296912},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'The Roundhouse',
#     'address2': 'Chalk Farm Rd',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8EH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Roundhouse',
#      'Chalk Farm Rd',
#      'London NW1 8EH',
#      'United Kingdom']},
#    'phone': '+442074248495',
#    'display_phone': '+44 20 7424 8495',
#    'distance': 3585.496556137051},
#   {'id': 'PYcG5ExM9vLXkbCXV59OoA',
#    'alias': 'the-brackenbury-wine-rooms-london',
#    'name': 'The Brackenbury Wine Rooms',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5DGdCg9qzty8ohtzu6L-lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-brackenbury-wine-rooms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'winetastingroom', 'title': 'Wine Tasting Room'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4979728, 'longitude': -0.2276862},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '111 - 115 Hammersmith Grove',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W6 0NQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['111 - 115 Hammersmith Grove',
#      'London W6 0NQ',
#      'United Kingdom']},
#    'phone': '+442036968240',
#    'display_phone': '+44 20 3696 8240',
#    'distance': 6559.441188890449},
#   {'id': '2A4uietlmgr6MTvcv5InVQ',
#    'alias': 'l-etoile-london',
#    'name': "L'Etoile",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TgidMWJx8s6eBO2scUmimw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-etoile-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.519007, 'longitude': -0.135029},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '30 Charlotte Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 2NG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Charlotte Street',
#      'London W1T 2NG',
#      'United Kingdom']},
#    'phone': '+442076367189',
#    'display_phone': '+44 20 7636 7189',
#    'distance': 694.7505138816381},
#   {'id': '99Q0vNBvnM5Rnw1atnr2xA',
#    'alias': 'osteria-basilico-london',
#    'name': 'Osteria Basilico',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4GbVaxV4AxqJykqU3mVGDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osteria-basilico-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515359633283, 'longitude': -0.2058905197699},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '29 Kensington Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['29 Kensington Park Road',
#      'London W11 2EU',
#      'United Kingdom']},
#    'phone': '+442077279957',
#    'display_phone': '+44 20 7727 9957',
#    'distance': 4847.542307422941},
#   {'id': 'MMqkie041Dt3lwGXjk_c9A',
#    'alias': 'istanbul-cafe-bistro-london',
#    'name': 'Istanbul Cafe Bistro',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZxkXuvYA9QjafVtRbekZnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/istanbul-cafe-bistro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.523857, 'longitude': -0.144014},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Great Portland Street Station',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 5PW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Great Portland Street Station',
#      'London W1W 5PW',
#      'United Kingdom']},
#    'phone': '+442075809142',
#    'display_phone': '+44 20 7580 9142',
#    'distance': 1346.4052174842375},
#   {'id': 'fDI1GsQUp6wg-SN6q3YVsw',
#    'alias': 'trullo-london',
#    'name': 'Trullo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/H2q53AjEFc27tZwWsW96aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trullo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5462962, 'longitude': -0.1012203},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "300 St Paul's Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 2LH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["300 St Paul's Road",
#      'London N1 2LH',
#      'United Kingdom']},
#    'phone': '+442072262733',
#    'display_phone': '+44 20 7226 2733',
#    'distance': 4429.100236027409},
#   {'id': 'vb2aK8EUXgSwvC87-xj7-A',
#    'alias': 'joannas-london-2',
#    'name': "Joanna's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vUKYouaC_esJKpFoO3A3uQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joannas-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4195930842822,
#     'longitude': -0.0805375669064267},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Crystal Palace',
#     'address2': '56 Westow Hill',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE19 1RX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Crystal Palace',
#      '56 Westow Hill',
#      'London SE19 1RX',
#      'United Kingdom']},
#    'phone': '+442086704052',
#    'display_phone': '+44 20 8670 4052',
#    'distance': 11055.958646319146},
#   {'id': '92dm-ARIoQb1DC_XTWOMVw',
#    'alias': 'the-clerkenwell-kitchen-london',
#    'name': 'The Clerkenwell Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LU3xk9AEKhE4x8Jj5C-F8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-clerkenwell-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.524127972354,
#     'longitude': -0.10651934447895},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '31 Clerkenwell Close',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 0AT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['31 Clerkenwell Close',
#      'London EC1R 0AT',
#      'United Kingdom']},
#    'phone': '+442071019959',
#    'display_phone': '+44 20 7101 9959',
#    'distance': 2392.728267314209},
#   {'id': 'Bn2BPzznOhRQho5EbgbEgw',
#    'alias': 'le-deuxième-london-2',
#    'name': 'Le Deuxième',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tM5kTjUuKAl773nNjqc3HA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-deuxi%C3%A8me-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5139573, 'longitude': -0.1227302},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '65a Long Acre',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 9JH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['65a Long Acre', 'London WC2E 9JH', 'United Kingdom']},
#    'phone': '+442073790033',
#    'display_phone': '+44 20 7379 0033',
#    'distance': 923.6739616560646},
#   {'id': 'JtK4x9GV4VoVntXPJ8J6SA',
#    'alias': 'cafe-rouge-kingsway-holborn',
#    'name': 'Cafe Rouge - Kingsway',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fSNPg1depT3Yw46kjMkCHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-rouge-kingsway-holborn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bistros', 'title': 'Bistros'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5160483631117,
#     'longitude': -0.119625063823719},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '77 Kingsway',
#     'address2': '',
#     'address3': '',
#     'city': 'Holborn',
#     'zip_code': 'WC2B 6SR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['77 Kingsway', 'Holborn WC2B 6SR', 'United Kingdom']},
#    'phone': '+442074301416',
#    'display_phone': '+44 20 7430 1416',
#    'distance': 1185.1876017401473},
#   {'id': 'vKwYO2uh7oypiDPbvFIU4w',
#    'alias': 'the-walmer-castle-london',
#    'name': 'The Walmer Castle',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uJxw5BZJMwg9h5jb1Nogkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-walmer-castle-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5151779, 'longitude': -0.1991706},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '58 Ledbury Road',
#     'address2': 'Notting Hill',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['58 Ledbury Road',
#      'Notting Hill',
#      'London W11 2AJ',
#      'United Kingdom']},
#    'phone': '+442072294620',
#    'display_phone': '+44 20 7229 4620',
#    'distance': 4382.154750483272},
#   {'id': 'm8yb3xuPPNBCgbR8LQ716A',
#    'alias': 'cafe-rouge-highgate-highgate',
#    'name': 'Cafe Rouge - Highgate',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/76Ci4or9EFpytk34xEja3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-rouge-highgate-highgate?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5705076656549,
#     'longitude': -0.148125288021907},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6-7 South Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'Highgate,',
#     'zip_code': 'N6 6BP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6-7 South Grove',
#      'Highgate, N6 6BP',
#      'United Kingdom']},
#    'phone': '+442083429797',
#    'display_phone': '+44 20 8342 9797',
#    'distance': 6467.832083072687},
#   {'id': 'DU6lNNb2x-S4BmnAkCfWtQ',
#    'alias': 'burger-and-lobster-london-17',
#    'name': 'Burger & Lobster',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6ie2-zxP4SZQWjpBrkUYIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burger-and-lobster-london-17?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5138886, 'longitude': -0.1503485},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '26 Binney Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 5BN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Binney Street',
#      'London W1K 5BN',
#      'United Kingdom']},
#    'phone': '+442074958514',
#    'display_phone': '+44 20 7495 8514',
#    'distance': 1026.321663572871},
#   {'id': 'qbyl_BgZSz49FHcLUtsG5A',
#    'alias': 'ma-cuisine-london',
#    'name': 'Ma Cuisine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PcGYfiCpqWI2n8kUc6-GTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ma-cuisine-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.450948, 'longitude': -0.3322632},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '6 Whitton Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'TW1 1BJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Whitton Street',
#      'London TW1 1BJ',
#      'United Kingdom']},
#    'phone': '+442086079849',
#    'display_phone': '+44 20 8607 9849',
#    'distance': 15236.442636768026},
#   {'id': 'D8bGs6Vqx89uzcQrgneAnw',
#    'alias': 'ye-olde-rose-and-crown-theatre-pub-london',
#    'name': 'Ye Olde Rose & Crown Theatre Pub',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2AMCUqyOO6Qf3d_SeN8WUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ye-olde-rose-and-crown-theatre-pub-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'theater', 'title': 'Performing Arts'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.587843, 'longitude': -0.020732},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '53 Hoe Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E17 4SA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['53 Hoe Street', 'London E17 4SA', 'United Kingdom']},
#    'phone': '+442085093880',
#    'display_phone': '+44 20 8509 3880',
#    'distance': 11534.14011721445},
#   {'id': 'IVw-oF1KzV9H6X25aQezpQ',
#    'alias': 'gallipoli-bistro-and-cafe-london',
#    'name': 'Gallipoli Bistro & Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Uss1MzfIaKvQKZJamNamsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gallipoli-bistro-and-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'bistros', 'title': 'Bistros'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5377136, 'longitude': -0.1029622},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '102 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 1QN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['102 Upper Street',
#      'London N1 1QN',
#      'United Kingdom']},
#    'phone': '+442073590630',
#    'display_phone': '+44 20 7359 0630',
#    'distance': 3584.7046947895806},
#   {'id': 'jhXl6t-narNJ36B4SYKU4w',
#    'alias': 'côte-london-26',
#    'name': 'Côte',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fvvlWZ1DfF3vMs1G9mjGyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/c%C3%B4te-london-26?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.513879857643,
#     'longitude': -0.101035305766373},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '26 Ludgate Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4M 7DR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Ludgate Hill',
#      'London EC4M 7DR',
#      'United Kingdom']},
#    'phone': '+442072364399',
#    'display_phone': '+44 20 7236 4399',
#    'distance': 2419.291070435097},
#   {'id': 'XAJf3kcKTqimNiuvseuYPg',
#    'alias': 'the-frenchie-bistro-london',
#    'name': 'The Frenchie Bistro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Q_dcnE7EtaGVLAAfbw4uWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-frenchie-bistro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4933788421539,
#     'longitude': -0.0979965087707342},
#    'transactions': [],
#    'location': {'address1': 'Unit 8 The Artworks Elephant',
#     'address2': 'Elephant Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE17 1LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 8 The Artworks Elephant',
#      'Elephant Road',
#      'London SE17 1LB',
#      'United Kingdom']},
#    'phone': '+442077034453',
#    'display_phone': '+44 20 7703 4453',
#    'distance': 3403.4938729549663},
#   {'id': 'zOLPCLptUE2UKRXYWCEHvg',
#    'alias': 'the-modern-pantry-london',
#    'name': 'The Modern Pantry',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xCCsKLYTjFB2it91U1ntmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-modern-pantry-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 145,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5230301121618,
#     'longitude': -0.103575187145258},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "47-48 St John's Square",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 4JJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["47-48 St John's Square",
#      'London EC1V 4JJ',
#      'United Kingdom']},
#    'phone': '+442075539210',
#    'display_phone': '+44 20 7553 9210',
#    'distance': 2510.962821457009},
#   {'id': '_aBvIYw6nfKc7ttyrZJGdw',
#    'alias': 'cote-brasserie-london-20',
#    'name': 'Cote Brasserie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/T6c17SIGiUTXbQLupriTQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cote-brasserie-london-20?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5181696057953,
#     'longitude': -0.134567342907612},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '5 Charlotte Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 1SF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Charlotte Street',
#      'London W1T 1SF',
#      'United Kingdom']},
#    'phone': '+442074361087',
#    'display_phone': '+44 20 7436 1087',
#    'distance': 600.8537163926007},
#   {'id': '0icedHIXu3meMxP5ICBx9g',
#    'alias': 'l-artiste-muscle-london',
#    'name': "L'Artiste Muscle",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yg1GH7-uxUzJB2IYiWfCMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-artiste-muscle-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.506430643424,
#     'longitude': -0.14640741333688},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Shepherd Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 7PA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Shepherd Market',
#      'London W1J 7PA',
#      'United Kingdom']},
#    'phone': '+442074936150',
#    'display_phone': '+44 20 7493 6150',
#    'distance': 1015.0824208104713},
#   {'id': 'lO0rGjjIVuLdF_unJhhnmg',
#    'alias': 'cafe-rouge-euston-london',
#    'name': 'Cafe Rouge Euston',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tbmp7wph5lOl29RZFemNlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-rouge-euston-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.527737, 'longitude': -0.132642},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 4',
#     'address2': 'The Piazza Euston Station',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 2RT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 4',
#      'The Piazza Euston Station',
#      'London NW1 2RT',
#      'United Kingdom']},
#    'phone': '+442073889100',
#    'display_phone': '+44 20 7388 9100',
#    'distance': 1672.75506384534},
#   {'id': 'x4M9Udkyd7Cr9-dQRRVk0g',
#    'alias': 'bobs-cafe-mill-hill-london',
#    'name': "Bob's Cafe Mill Hill",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VXFzT5YU8h8GIl8LnjABxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bobs-cafe-mill-hill-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.6156484, 'longitude': -0.2445645},
#    'transactions': [],
#    'location': {'address1': '88 The Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW7 3TB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['88 The Broadway',
#      'London NW7 3TB',
#      'United Kingdom']},
#    'phone': '+442089590330',
#    'display_phone': '+44 20 8959 0330',
#    'distance': 13676.859621534548},
#   {'id': 'FTUpttvt3pP8eBCO2FNpCA',
#    'alias': 'bistro-fifteen-london',
#    'name': 'Bistro Fifteen',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistro-fifteen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.4945147, 'longitude': -0.1748967},
#    'transactions': [],
#    'location': {'address1': '15 Cromwell Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 2LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Cromwell Place',
#      'London SW7 2LA',
#      'United Kingdom']},
#    'phone': '+44442036417565',
#    'display_phone': '+44 442036417565',
#    'distance': 3378.56040988553},
#   {'id': '3_8E7PvPHo1BJ7VwWzTUsA',
#    'alias': 'côte-london-41',
#    'name': 'Côte',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_sbhuaVbNYPoG1wnpdeEZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/c%C3%B4te-london-41?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5921065006675,
#     'longitude': -0.143202818598953},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '323 Muswell Hill Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N10 1DF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['323 Muswell Hill Broadway',
#      'London N10 1DF',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8828.750979835359}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#             Restaurant       Type Price Rating              Address  \
# 0   La Cage Imaginaire     French    ££      4        16 Flask Walk
# 1       Goode & Wright    British    ££    3.5  271 Portobello Road
# 2             Vinoteca  Wine Bars   £££      4     15 Seymour Place
# 3   On the Hoof Bistro    Bistros                  23 Sydenham Road
# 4  Champagne + Fromage      Delis                  34 Church Street
#
#          Lat       Lng                                                url  \
# 0  51.556657 -0.177122  https://www.yelp.com/biz/la-cage-imaginaire-lo...
# 1  51.517861 -0.206798  https://www.yelp.com/biz/goode-and-wright-lond...
# 2  51.514874 -0.161430  https://www.yelp.com/biz/vinoteca-london-2?adj...
# 3  51.427137 -0.054329
# 4  51.481339 -0.009815
#
#                        ID
# 0  NDo0J9G78sNzB0ygRnyd9Q
# 1  0PevNLQx8HyuKHBzg8Fy6w
# 2  JTJJxemAOT7ZYyec8xRo2A
# 3
# 4

# %%
london_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
london_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_restaurants_df = london_restaurants_df[column_order]
london_restaurants_df = london_restaurants_df.sort_values(["Type"], ascending=True)
london_restaurants_df = london_restaurants_df.reset_index(drop=True)
london_restaurants_df
# Out:
#                            Restaurant                    Type Rating Price  \
# 0                    Portobello House  American (Traditional)      3    ££
# 1           Dominique Ansel Treehouse                Bakeries
# 2                              Hugo's                    Bars      4    ££
# 3                  Plateau Restaurant                    Bars    4.5   £££
# 4                            Bibendum                    Bars      4   £££
# 5                        The Waterway                    Bars    3.5   £££
# 6                       86 Bistro Bar                    Bars
# 7                       York & Albany                    Bars      4   £££
# 8                      Made In Camden                    Bars    3.5    ££
# 9           Baltic Bar and Restaurant                    Bars      4   £££
# 10                       Petit Bistro                 Bistros
# 11                   Troy Cafe Bistro                 Bistros      4   £££
# 12               Patron Cave à Manger                 Bistros    3.5    ££
# 13                   Bank Restaurants                 Bistros    3.5   £££
# 14                         Bistro 190                 Bistros    3.5    ££
# 15                     Bistro Fifteen                 Bistros
# 16                        Bite Bistro                 Bistros
# 17                         Blanchette                 Bistros      4   £££
# 18                  South Place Grill                 Bistros
# 19                The Frenchie Bistro                 Bistros
# 20                 On the Hoof Bistro                 Bistros
# 21                     Côte Brasserie              Brasseries      4    ££
# 22                               Côte              Brasseries      4    ££
# 23                    Brasserie Zédel              Brasseries      4    ££
# 24                               Côte      Breakfast & Brunch    3.5    ££
# 25                               Côte      Breakfast & Brunch      4   £££
# 26                   Percy & Founders      Breakfast & Brunch      4   £££
# 27                     Bistrò by Shot      Breakfast & Brunch      5    ££
# 28                  The Premises Cafe      Breakfast & Brunch      4    ££
# 29                  The Modern Pantry      Breakfast & Brunch      4    ££
# ..                                ...                     ...    ...   ...
# 170       Rossopomodoro Covent Garden                   Pizza    3.5    ££
# 171                   Theo's Pizzeria                   Pizza    4.5    ££
# 172                           Daquise                  Polish    4.5   £££
# 173  Ye Olde Rose & Crown Theatre Pub                    Pubs      4    ££
# 174                      The Garrison                    Pubs      4    ££
# 175                       Boro Bistro                    Pubs    4.5    ££
# 176                  The Bird In Hand                    Pubs      4    ££
# 177                      The Dovetail                    Pubs      4    ££
# 178                  Marlborough Head                    Pubs      3    ££
# 179                 The Walmer Castle                    Pubs    3.5    ££
# 180                       About Thyme                 Spanish    4.5   £££
# 181                   Steak & Lobster             Steakhouses      4    ££
# 182                       Meat People             Steakhouses      4    ££
# 183               Cepages Wine Bistro      Tapas/Small Plates    3.5   £££
# 184           Gallipoli Bistro & Cafe                 Turkish      4    ££
# 185              Istanbul Cafe Bistro                 Turkish      4    ££
# 186                     Cellar Gascon               Wine Bars
# 187                     Bar Du Marché               Wine Bars      4    ££
# 188                            Ellory               Wine Bars    4.5   £££
# 189                         The Folly               Wine Bars      3    ££
# 190        The Brackenbury Wine Rooms               Wine Bars      4   £££
# 191                    Andrew Edmunds               Wine Bars    4.5   £££
# 192                              Soif               Wine Bars      4   £££
# 193                        Le Garrick               Wine Bars      4    ££
# 194                          Terroirs               Wine Bars    4.5   £££
# 195                  L'Artiste Muscle               Wine Bars    3.5    ££
# 196                          Vinoteca               Wine Bars      4    ££
# 197                          Vinoteca               Wine Bars      4   £££
# 198      Fish & Wine Restaurant & Bar               Wine Bars
# 199                The Artisan Bistro               Wine Bars      5   £££
#
#                            Address        Lat       Lng  \
# 0               225 Ladbroke Grove  51.519389 -0.211480
# 1                 24 Floral Street  51.511905 -0.125405
# 2              21-25 Lonsdale Road  51.537130 -0.203419
# 3                     Canada Place  51.504456 -0.016660
# 4                   MIchelin House  51.493315 -0.168833
# 5                54 Formosa Street  51.522673 -0.187809
# 6                  86 Brent Street  51.585114 -0.219755
# 7                  127-129 Parkway  51.535979 -0.146636
# 8                   The Roundhouse  51.543489 -0.152039
# 9              74 Blackfriars Road  51.503466 -0.104866
# 10              14 Leicester Place  51.511125 -0.129728
# 11              124 Kingsland Road  51.530461 -0.077017
# 12                 26 Fortess Road  51.552688 -0.140778
# 13              45 Buckingham Gate  51.498658 -0.137315
# 14                        The Gore  51.500257 -0.179609
# 15               15 Cromwell Place  51.494515 -0.174897
# 16         127 Clapham High Street  51.463607 -0.133678
# 17               9 D'Arblay Street  51.514687 -0.136290
# 18                       3 S Place  51.519045 -0.086526
# 19    Unit 8 The Artworks Elephant  51.493379 -0.097997
# 20                23 Sydenham Road  51.427137 -0.054329
# 21          17-21 Tavistock Street  51.512364 -0.120298
# 22       323 Muswell Hill Broadway  51.592107 -0.143203
# 23              20 Sherwood Street  51.510603 -0.135576
# 24             47 Kensington Court  51.501977 -0.188928
# 25                 26 Ludgate Hill  51.513880 -0.101035
# 26                1 Pearson Square  51.518794 -0.137988
# 27           28 Parsons Green Lane  51.476113 -0.201063
# 28                209 Hackney Road  51.531058 -0.071531
# 29          47-48 St John's Square  51.523030 -0.103575
# ..                             ...        ...       ...
# 170          50-52 Monmouth Street  51.513013 -0.127267
# 171                   2 Grove Lane  51.473655 -0.090513
# 172              20 Thurloe Street  51.494323 -0.173618
# 173                  53 Hoe Street  51.587843 -0.020732
# 174           99 Bermondsey Street  51.500646 -0.081590
# 175       6-10 Borough High Street  51.506119 -0.088799
# 176                 88 Masbro Road  51.499762 -0.215441
# 177         9-10 Jerusalem Passage  51.523241 -0.103925
# 178         24 North Audley Street  51.513368 -0.153799
# 179                58 Ledbury Road  51.515178 -0.199171
# 180                 82 Wilton Road  51.492497 -0.139984
# 181         9-13 Bloomsbury Street  51.517395 -0.127507
# 182                 4-6 Essex Road  51.536386 -0.101694
# 183        69 Westbourne Park Road  51.518844 -0.194727
# 184               102 Upper Street  51.537714 -0.102962
# 185  Great Portland Street Station  51.523857 -0.144014
# 186      57-59 Charterhouse Street  51.519270 -0.103740
# 187              19 Berwick Street  51.513735 -0.134856
# 188              1 Westgate Street  51.537655 -0.058066
# 189          41 Gracechurch Street  51.511222 -0.085984
# 190    111 - 115 Hammersmith Grove  51.497973 -0.227686
# 191            46 Lexington Street  51.513155 -0.136146
# 192              27 Battersea Rise  51.460771 -0.163489
# 193           10-12 Garrick Street  51.511566 -0.126067
# 194            5 William IV Street  51.509355 -0.125207
# 195              1 Shepherd Market  51.506431 -0.146407
# 196               7 St John Street  51.520121 -0.101915
# 197               15 Seymour Place  51.514874 -0.161430
# 198               222 Railton Road  51.452811 -0.102354
# 199              14 Hollywood Road  51.486104 -0.184697
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/portobello-house-lond...  XkUO7tQD-tfXoTzuHMbnMg
# 1
# 2    https://www.yelp.com/biz/hugos-london?adjust_c...  ab5UXMk4YZVKROpyjXHmQg
# 3    https://www.yelp.com/biz/plateau-restaurant-lo...  YjM4oKNwo8MuzHkAdmwiaA
# 4    https://www.yelp.com/biz/bibendum-london?adjus...  eKV3GGH9gU5h028CU839kQ
# 5    https://www.yelp.com/biz/the-waterway-london?a...  DkKOKkZ0l1qm07cAG_CKgg
# 6
# 7    https://www.yelp.com/biz/york-and-albany-londo...  g79KR-kAcJS9OH_f-ZrG0g
# 8    https://www.yelp.com/biz/made-in-camden-london...  csVPVnXRUxb9pmCqe-kFJQ
# 9    https://www.yelp.com/biz/baltic-bar-and-restau...  fdwAAs9cm_uLkgxXedYh3w
# 10
# 11   https://www.yelp.com/biz/troy-cafe-bistro-lond...  wP8WFnsso_3SSHzrtYzVeQ
# 12   https://www.yelp.com/biz/patron-cave-%C3%A0-ma...  N05ni488O0XQg3jBC_I70Q
# 13   https://www.yelp.com/biz/bank-restaurants-lond...  m3A_7od2v91zWbXbllasHA
# 14   https://www.yelp.com/biz/bistro-190-london?adj...  -OTXUjtJ0_Mer7PnBir18Q
# 15
# 16
# 17   https://www.yelp.com/biz/blanchette-london?adj...  MSqfyXS2fdm6H-ywHAV75w
# 18
# 19
# 20
# 21   https://www.yelp.com/biz/c%C3%B4te-brasserie-l...  TtkhkYxbzkL_F6ZajO3veQ
# 22   https://www.yelp.com/biz/c%C3%B4te-london-41?a...  3_8E7PvPHo1BJ7VwWzTUsA
# 23   https://www.yelp.com/biz/brasserie-z%C3%A9del-...  E43MdoA7zkZ6SnPjAJaTvA
# 24   https://www.yelp.com/biz/c%C3%B4te-london-20?a...  8pafyRKpDRt0pd5KXh-Hzg
# 25   https://www.yelp.com/biz/c%C3%B4te-london-26?a...  jhXl6t-narNJ36B4SYKU4w
# 26   https://www.yelp.com/biz/percy-and-founders-lo...  35B3UJMEaI1sQj4vaKK0RQ
# 27   https://www.yelp.com/biz/bistr%C3%B2-by-shot-l...  SsA4xyF60DUXdOaCspIe1w
# 28   https://www.yelp.com/biz/the-premises-cafe-lon...  bUSpzLnvC70PBrnjlUJ-UA
# 29   https://www.yelp.com/biz/the-modern-pantry-lon...  zOLPCLptUE2UKRXYWCEHvg
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/rossopomodoro-covent-...  BYX50yHA19PVF1blGIwe7A
# 171  https://www.yelp.com/biz/theos-pizzeria-london...  D3fDXB68Mu2MnZefMnDQtA
# 172  https://www.yelp.com/biz/daquise-london-2?adju...  IIMtF_7RpIGBBPN9qN0CRA
# 173  https://www.yelp.com/biz/ye-olde-rose-and-crow...  D8bGs6Vqx89uzcQrgneAnw
# 174  https://www.yelp.com/biz/the-garrison-london?a...  nVMVXywZjvDBkPPR_uqhUA
# 175  https://www.yelp.com/biz/boro-bistro-london?ad...  pMZ4XI-RsAxY6YK3xHVFJA
# 176  https://www.yelp.com/biz/the-bird-in-hand-lond...  Ii_CsiiPkg0MzsZrVWSMwQ
# 177  https://www.yelp.com/biz/the-dovetail-london-2...  rb3DTjC5mhEnjy-ay0AYUw
# 178  https://www.yelp.com/biz/marlborough-head-lond...  B3KOxvXOZ5Kzfi8qe7sVuw
# 179  https://www.yelp.com/biz/the-walmer-castle-lon...  vKwYO2uh7oypiDPbvFIU4w
# 180  https://www.yelp.com/biz/about-thyme-london?ad...  ytIFY2JvU-zcd1FsonES5w
# 181  https://www.yelp.com/biz/steak-and-lobster-blo...  yY5Ng5ujlAZSToWRmLTzQw
# 182  https://www.yelp.com/biz/meat-people-london?ad...  f1S9DYmRFzU7VrYq4TKFGQ
# 183  https://www.yelp.com/biz/cepages-wine-bistro-l...  6WsuX-QP8DQtejctGK6qVg
# 184  https://www.yelp.com/biz/gallipoli-bistro-and-...  IVw-oF1KzV9H6X25aQezpQ
# 185  https://www.yelp.com/biz/istanbul-cafe-bistro-...  MMqkie041Dt3lwGXjk_c9A
# 186
# 187  https://www.yelp.com/biz/bar-du-march%C3%A9-lo...  8haIlB3gghjV8ZUOwsqBUA
# 188  https://www.yelp.com/biz/ellory-london?adjust_...  RNCwHorv4bGFY25NaZZpDQ
# 189  https://www.yelp.com/biz/the-folly-london?adju...  aukShSND1N8a0a1wmlz8Yg
# 190  https://www.yelp.com/biz/the-brackenbury-wine-...  PYcG5ExM9vLXkbCXV59OoA
# 191  https://www.yelp.com/biz/andrew-edmunds-london...  umLQuVzI5h0HbPqipD360w
# 192  https://www.yelp.com/biz/soif-london?adjust_cr...  AVtK43VhZGCUSBc-XeOz6g
# 193  https://www.yelp.com/biz/le-garrick-london?adj...  qM6lDKglcVhUkH-0fJTn4g
# 194  https://www.yelp.com/biz/terroirs-london?adjus...  xzui1-XqO7N5VzDnEeYWrw
# 195  https://www.yelp.com/biz/l-artiste-muscle-lond...  0icedHIXu3meMxP5ICBx9g
# 196  https://www.yelp.com/biz/vinoteca-london?adjus...  QFOUxTcxG3tB9HyxvfU1FA
# 197  https://www.yelp.com/biz/vinoteca-london-2?adj...  JTJJxemAOT7ZYyec8xRo2A
# 198
# 199  https://www.yelp.com/biz/the-artisan-bistro-lo...  hQEdwFG8kCTCO6fwvLuWBQ
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
london_restaurants_df.to_csv('Resources/London_Restaurants_Bistro.csv')
