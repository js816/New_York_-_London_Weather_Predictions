# %% [markdown]
# LONDON RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
lndr_params1 = {"term":"pastry","location":"London","limit":50,"offset":0}
lndr_response1 = requests.get(search_api_url, headers=headers, params=lndr_params1)
lndr1 = lndr_response1.json()
display(lndr1)
#print(lndr_response1.url)
#print(lndr_response1.status_code)
# Out:
# {'businesses': [{'id': '0tJs57Xoq75-RDWKVco0nw',
#    'alias': 'bageriet-london',
#    'name': 'Bageriet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2yfTj7nJkUd_snGs1WP2aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bageriet-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'scandinavian', 'title': 'Scandinavian'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5119236, 'longitude': -0.1261821},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '24 Rose Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 9EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Rose Street',
#      'London WC2E 9EA',
#      'United Kingdom']},
#    'phone': '+442072400000',
#    'display_phone': '+44 20 7240 0000',
#    'distance': 683.9151857905819},
#   {'id': 'KZd0pTzAhKbIs9Lg94Delg',
#    'alias': 'bread-ahead-london-3',
#    'name': 'Bread Ahead',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0zFLqdD1WpHNDsv_5YeVGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bread-ahead-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 79,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5061427, 'longitude': -0.090258},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Borough Market',
#     'address2': 'Cathedral Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9DE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Borough Market',
#      'Cathedral Street',
#      'London SE1 9DE',
#      'United Kingdom']},
#    'phone': '+442074035444',
#    'display_phone': '+44 20 7403 5444',
#    'distance': 3248.944489817099},
#   {'id': '9gqKbR6JK79zTc5RDLP_4A',
#    'alias': 'dominique-ansel-bakery-victoria',
#    'name': 'Dominique Ansel Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_NbEwfiF5IbRjDso83WZpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dominique-ansel-bakery-victoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4926912521198,
#     'longitude': -0.149131484387577},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '17-21 Elizabeth Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Victoria',
#     'zip_code': 'SW1W 9RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17-21 Elizabeth Street',
#      'Victoria SW1W 9RP',
#      'United Kingdom']},
#    'phone': '+442073247705',
#    'display_phone': '+44 20 7324 7705',
#    'distance': 2418.4730027147466},
#   {'id': 'EbT5viLW9ujk9iQ73CJcmQ',
#    'alias': 'the-pasty-shop-london',
#    'name': 'The Pasty Shop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RAszscwdnd_rGyu7XSkCBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pasty-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4962890220788,
#     'longitude': -0.143927823389436},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Victoria Street Station',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1JU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Victoria Street Station',
#      'London SW1V 1JU',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1920.8400662572742},
#   {'id': 'in1fuQDAfRBIb7cGnOEviA',
#    'alias': 'gails-bakery-soho-london',
#    'name': "GAIL's Bakery Soho",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/n8-P1vDMEKq2CyDsOzjfRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5143112170147,
#     'longitude': -0.134518146514893},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '128 Wardour Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8ZL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['128 Wardour Street',
#      'Soho',
#      'London W1F 8ZL',
#      'United Kingdom']},
#    'phone': '+442072871324',
#    'display_phone': '+44 20 7287 1324',
#    'distance': 191.89294382102497},
#   {'id': 'QyYFRNphu0fICXNfZjD_AA',
#    'alias': 'the-hummingbird-bakery-london-2',
#    'name': 'The Hummingbird Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iNrM97UAuo0a-o3XgX-WqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hummingbird-bakery-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 131,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5140019, 'longitude': -0.2038738},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '133 Portobello Road',
#     'address2': 'Notting Hill',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['133 Portobello Road',
#      'Notting Hill',
#      'London W11 2DY',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4701.254789485355},
#   {'id': '5or4AzNouZq8RClNeTdqiA',
#    'alias': 'ole-and-steen-london-2',
#    'name': 'Ole and Steen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HhmDFvGw42MnOJErQE9vkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ole-and-steen-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.509238, 'longitude': -0.1326965},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '56 Haymarket',
#     'address2': '',
#     'address3': "No 2 St James's Market",
#     'city': 'London',
#     'zip_code': 'SW1Y 4RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['56 Haymarket',
#      "No 2 St James's Market",
#      'London SW1Y 4RP',
#      'United Kingdom']},
#    'phone': '+442038288242',
#    'display_phone': '+44 20 3828 8242',
#    'distance': 459.23424350084883},
#   {'id': 'LgKc7xGArsmxAw6xUQ2mYA',
#    'alias': 'gails-bakery-seymour-place-london-4',
#    'name': "GAIL's Bakery Seymour Place",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FWiORe3Zw8vEUmD0tANYvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-seymour-place-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.514595, 'longitude': -0.160964},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4-6 Seymour Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4-6 Seymour Place',
#      'London W1H 7NA',
#      'United Kingdom']},
#    'phone': '+442077243590',
#    'display_phone': '+44 20 7724 3590',
#    'distance': 1741.5797182376227},
#   {'id': 'OLXnVhh19HtAnbywQzD3zw',
#    'alias': 'rinkoff-bakeries-london-2',
#    'name': 'Rinkoff Bakeries',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U0sRZgXWXgBxJhqCMQAESA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rinkoff-bakeries-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5198880062398,
#     'longitude': -0.0530246183202313},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '224 Jubilee Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 3BS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['224 Jubilee Street',
#      'London E1 3BS',
#      'United Kingdom']},
#    'phone': '+442077914909',
#    'display_phone': '+44 20 7791 4909',
#    'distance': 5791.8034174832765},
#   {'id': 'rQKDeNCx8LkUR12YH9LpVg',
#    'alias': 'bäkehaus-london-2',
#    'name': 'Bäkehaus',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t8nwOKGUsvFhyuNdJFTrvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b%C3%A4kehaus-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4926600176647,
#     'longitude': -0.227837562561035},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '71 King Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W6 9HW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['71 King Street', 'London W6 9HW', 'United Kingdom']},
#    'phone': '+442034903231',
#    'display_phone': '+44 20 3490 3231',
#    'distance': 6743.794563736779},
#   {'id': 'mDyJw5PstVTN2RQi5HO-sw',
#    'alias': 'st-john-bakery-london-3',
#    'name': 'St. John Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/37zJgBXE1CGwCulKzfCGCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-john-bakery-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5143596884016,
#     'longitude': -0.126515915278274},
#    'transactions': [],
#    'location': {'address1': "3 Neal's Yard",
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2H 9DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["3 Neal's Yard", 'London WC2H 9DP', 'United Kingdom']},
#    'phone': '+442072510848',
#    'display_phone': '+44 20 7251 0848',
#    'distance': 674.8655754823199},
#   {'id': 'x3xVIhjTy6jZ8PhKVqYjIw',
#    'alias': 'the-hummingbird-bakery-london-4',
#    'name': 'The Hummingbird Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4cvpY3Z_fsXDeftdmySptQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hummingbird-bakery-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 106,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5144372642472,
#     'longitude': -0.134845145998042},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '155a Wardour Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8WG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['155a Wardour Street',
#      'Soho',
#      'London W1F 8WG',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 193.9810977468779},
#   {'id': 'Sh_PrXavTAk2d5jTs_onuQ',
#    'alias': 'nordic-bakery-london',
#    'name': 'Nordic Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y1r_R3BokRhDYZIaF0XB6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nordic-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 118,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'scandinavian', 'title': 'Scandinavian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5114297969411,
#     'longitude': -0.13674108684063},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 Golden Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9JG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Golden Square',
#      'London W1F 9JG',
#      'United Kingdom']},
#    'phone': '+442032301077',
#    'display_phone': '+44 20 3230 1077',
#    'distance': 165.48625457765309},
#   {'id': '3ZWC6EkdLcUe80Vq097Bfg',
#    'alias': 'patisserie-sainte-anne-london',
#    'name': 'Patisserie Sainte Anne',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nxFsUg1NYt-UJHi6uTxd_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-sainte-anne-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4930805319587,
#     'longitude': -0.236022540998695},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '204 King Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W6 0RA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['204 King Street', 'London W6 0RA', 'United Kingdom']},
#    'phone': '+442085632046',
#    'display_phone': '+44 20 8563 2046',
#    'distance': 7266.198358582235},
#   {'id': 'BZ96WsFu82jq65zs4Y2MsQ',
#    'alias': 'aux-merveilleux-de-fred-london',
#    'name': 'Aux Merveilleux de Fred',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DXEeU-Kc1KA0V6mm3yRPXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aux-merveilleux-de-fred-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4924431, 'longitude': -0.1778994},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '88 Old Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3LQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['88 Old Brompton Road',
#      'London SW7 3LQ',
#      'United Kingdom']},
#    'phone': '+442075844249',
#    'display_phone': '+44 20 7584 4249',
#    'distance': 3661.0849280759267},
#   {'id': '1epk2D1-2-g08GAntFlySg',
#    'alias': 'konditor-london',
#    'name': 'Konditor',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QbRhycT_YxKWL-AX_fwlWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/konditor-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5042899533514,
#     'longitude': -0.110367141112856},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Cornwall Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8TW',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ['22 Cornwall Rd', 'London SE1 8TW', 'United Kingdom']},
#    'phone': '+442076333333',
#    'display_phone': '+44 20 7633 3333',
#    'distance': 2009.750808419612},
#   {'id': 'BjPq77aiaKZAVUHIu2S3gA',
#    'alias': 'the-english-rose-cafe-and-tea-shop-london',
#    'name': 'The English Rose Cafe and Tea Shop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B_v1cOkgPEcbr8e2rtfaog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-english-rose-cafe-and-tea-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 213,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4980558, 'longitude': -0.1444512},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 Lower Grosvenor Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 0EJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Lower Grosvenor Place',
#      'London SW1W 0EJ',
#      'United Kingdom']},
#    'phone': '+442079766280',
#    'display_phone': '+44 20 7976 6280',
#    'distance': 1745.2072668809335},
#   {'id': 'kAgxFPCeNiZeiKc9POkiOg',
#    'alias': 'ottolenghi-london-2',
#    'name': 'Ottolenghi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/h7J52IR5gmXdlef7pJxfSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ottolenghi-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4995017, 'longitude': -0.1566887},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '13 Motcomb Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 8LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Motcomb Street',
#      'London SW1X 8LB',
#      'United Kingdom']},
#    'phone': '+442078232707',
#    'display_phone': '+44 20 7823 2707',
#    'distance': 2068.4293878068443},
#   {'id': '271U0h4hish4lq_mESjGRw',
#    'alias': 'maitre-choux-london-2',
#    'name': 'Maitre Choux',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/veVV5ArN0vnhOMfPv3i9cA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maitre-choux-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5127143859863,
#     'longitude': -0.132231995463371},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '60 Dean St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1D 6AW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['60 Dean St', 'London W1D 6AW', 'United Kingdom']},
#    'phone': '+442077343132',
#    'display_phone': '+44 20 7734 3132',
#    'distance': 271.62844826358406},
#   {'id': 'riWepzZEIHj82UiDk_WVLQ',
#    'alias': 'montparnasse-cafe-london-2',
#    'name': 'Montparnasse Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/90P9GQECkOj3aZIrJfpO8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/montparnasse-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5005205, 'longitude': -0.1885342},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '22 Thackeray Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 5ET',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Thackeray Street',
#      'London W8 5ET',
#      'United Kingdom']},
#    'phone': '+442073762212',
#    'display_phone': '+44 20 7376 2212',
#    'distance': 3888.086719460034},
#   {'id': 'wh4R2zTxcjZw4JcQFNBtog',
#    'alias': 'aux-pains-de-papy-london',
#    'name': 'Aux Pains de Papy',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Kqbb4D3ddlwupyZ2hxiYVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aux-pains-de-papy-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5273865, 'longitude': -0.1184675},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '279 Grays Inn Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1X 8EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['279 Grays Inn Rd',
#      'London WC1X 8EB',
#      'United Kingdom']},
#    'phone': '+447771613779',
#    'display_phone': '+44 7771 613779',
#    'distance': 2020.4045688598862},
#   {'id': 'FM2fOny0zttmwnSeHCHzyA',
#    'alias': 'fabrique-bakery-london-5',
#    'name': 'Fabrique Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1-A9bxyUwournvQ4hL3sMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fabrique-bakery-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516469, 'longitude': -0.205223},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '212 Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 1LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['212 Portobello Road',
#      'London W11 1LA',
#      'United Kingdom']},
#    'phone': '+442072213721',
#    'display_phone': '+44 20 7221 3721',
#    'distance': 4813.9954429630825},
#   {'id': 'c3m_OXrRNdJpWmTqhEgdeQ',
#    'alias': 'lanka-london-2',
#    'name': 'Lanka',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1pANCLbvBZdO9tptjqOjmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lanka-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5457719, 'longitude': -0.1793938},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9 Goldhurst Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 3HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Goldhurst Terrace',
#      'London NW6 3HX',
#      'United Kingdom']},
#    'phone': '+442076253366',
#    'display_phone': '+44 20 7625 3366',
#    'distance': 4737.301543897287},
#   {'id': 'Fo77yYBP65cK52-9-sjXNQ',
#    'alias': 'crosstown-mayfair',
#    'name': 'Crosstown',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/__vlEdNIgLnc2ingtRMlJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crosstown-mayfair?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5092357, 'longitude': -0.1371423},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '35 Piccadilly',
#     'address2': '',
#     'address3': None,
#     'city': 'Mayfair',
#     'zip_code': 'W1J 0DW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35 Piccadilly', 'Mayfair W1J 0DW', 'United Kingdom']},
#    'phone': '+442072877671',
#    'display_phone': '+44 20 7287 7671',
#    'distance': 408.61614726988506},
#   {'id': 'OGW03dLcEui-6CWZIucVMw',
#    'alias': 'laduree-london-14',
#    'name': 'Laduree',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gnAH2qu0IqhJq3NQA1h8Jg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laduree-london-14?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'macarons', 'title': 'Macarons'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5083572494815,
#     'longitude': -0.139577354757421},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '71-72 Burlington Arcade',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 0QX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['71-72 Burlington Arcade',
#      'London W1J 0QX',
#      'United Kingdom']},
#    'phone': '+442074919155',
#    'display_phone': '+44 20 7491 9155',
#    'distance': 557.4749357668763},
#   {'id': '4DDzcfgbnVAKWomCQoZilg',
#    'alias': 'fortitude-bakehouse-london',
#    'name': 'Fortitude Bakehouse',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1XuacJvRQ1iMGuttnQKQSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fortitude-bakehouse-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5229210884015,
#     'longitude': -0.124047992374525},
#    'transactions': [],
#    'location': {'address1': '35 Colonnade',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC1N 1DD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35 Colonnade', 'London WC1N 1DD', 'United Kingdom']},
#    'phone': '+442078375456',
#    'display_phone': '+44 20 7837 5456',
#    'distance': 1391.6020920227202},
#   {'id': 'BVD84PXIYOiIr5Rc-s8JQw',
#    'alias': 'crosstown-doughnuts-and-coffee-london-2',
#    'name': 'Crosstown Doughnuts & Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eJQiXqEJVqVd0uwQPU0qYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crosstown-doughnuts-and-coffee-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 81,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514167, 'longitude': -0.1346751},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 Broadwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8HJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Broadwick Street',
#      'London W1F 8HJ',
#      'United Kingdom']},
#    'phone': '+442077348873',
#    'display_phone': '+44 20 7734 8873',
#    'distance': 167.30030991784423},
#   {'id': '6Hc37w-thLXw4_pD3mZdJA',
#    'alias': 'fabrique-bakery-london',
#    'name': 'Fabrique Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6mXU2_cjtNe66mpd_w8AdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fabrique-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5321125496558,
#     'longitude': -0.0760506578224951},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Arch 385',
#     'address2': 'Gaffrye Street',
#     'address3': 'Shoreditch',
#     'city': 'London',
#     'zip_code': 'E2 8HZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Arch 385',
#      'Gaffrye Street',
#      'Shoreditch',
#      'London E2 8HZ',
#      'United Kingdom']},
#    'phone': '+442070330268',
#    'display_phone': '+44 20 7033 0268',
#    'distance': 4666.093756363539},
#   {'id': 'pa2j9BlCHH8mRIk-TtD6UQ',
#    'alias': 'camden-bakery-london',
#    'name': 'Camden Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/V1BIQXnDxmTz0NyfTs6BiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camden-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5370833, 'longitude': -0.1407642},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '94 Camden High Street',
#     'address2': 'Camden Town',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 0LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['94 Camden High Street',
#      'Camden Town',
#      'London NW1 0LT',
#      'United Kingdom']},
#    'phone': '+442073874947',
#    'display_phone': '+44 20 7387 4947',
#    'distance': 2712.007403533704},
#   {'id': 'mvds37L7mCurGn3rGPM8ag',
#    'alias': 'kaffeine-london',
#    'name': 'Kaffeine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QWk5UJ1ELO0n7VrE3aLUWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaffeine-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 173,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51848, 'longitude': -0.14037},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '66 Great Titchfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 7QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Great Titchfield Street',
#      'London W1W 7QJ',
#      'United Kingdom']},
#    'phone': '+442075806755',
#    'display_phone': '+44 20 7580 6755',
#    'distance': 697.5687539772275},
#   {'id': '-ATEXu2q4Oe4wPQeyrsILw',
#    'alias': 'princi-london',
#    'name': 'Princi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QLFgoDIBiLx2F0tpUIw7gQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/princi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 304,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5138629586873,
#     'longitude': -0.134387051472991},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '135 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0UT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['135 Wardour Street',
#      'London W1F 0UT',
#      'United Kingdom']},
#    'phone': '+442074788888',
#    'display_phone': '+44 20 7478 8888',
#    'distance': 157.59755401297926},
#   {'id': 'e5jPAqpCcIAsTtasUN5h2g',
#    'alias': 'the-wolseley-london',
#    'name': 'The Wolseley',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T9xpXsz-az88-l0Ko_KLpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wolseley-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 553,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.507617, 'longitude': -0.141012},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '160 Picadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 9EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['160 Picadilly', 'London W1J 9EB', 'United Kingdom']},
#    'phone': '+442074996996',
#    'display_phone': '+44 20 7499 6996',
#    'distance': 677.6098617325135},
#   {'id': 'y3A99Bk8moGq70QMupAvcg',
#    'alias': 'minamoto-kitchoan-london',
#    'name': 'Minamoto Kitchoan',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ym2YQZptqJ0gbpRmt9jcHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/minamoto-kitchoan-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'candy', 'title': 'Candy Stores'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.508814, 'longitude': -0.138055},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '44 Piccadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 0DS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['44 Piccadilly', 'London W1J 0DS', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 472.5051820978047},
#   {'id': '9klx0ol5iCCf7vG-IjcYFQ',
#    'alias': 'patisserie-valerie-london-12',
#    'name': 'Patisserie Valerie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/u6ECUWzSeBE8a5BOTiE2OA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-valerie-london-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5157113693673,
#     'longitude': -0.188256121731851},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '174-176 Queensway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 6LY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['174-176 Queensway',
#      'London W2 6LY',
#      'United Kingdom']},
#    'phone': '+442072439069',
#    'display_phone': '+44 20 7243 9069',
#    'distance': 3633.214213959659},
#   {'id': 'U-Sz3hVjbZ8eaNeKGpZU_A',
#    'alias': 'borough-market-london-3',
#    'name': 'Borough Market',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EjVltsQ_qhUKdgdTMndkIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/borough-market-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1657,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5051427191678,
#     'longitude': -0.0909365332063361},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8 Southwark Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 1TL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Southwark Street',
#      'London SE1 1TL',
#      'United Kingdom']},
#    'phone': '+442030262283',
#    'display_phone': '+44 20 3026 2283',
#    'distance': 3230.9293288880117},
#   {'id': '3fDLrrmStQBZFMBHUvMbrQ',
#    'alias': 'fix-126-london',
#    'name': 'Fix 126',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UaNwPc1DUW418DLihHCXJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fix-126-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5261251, 'longitude': -0.0802153},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '126 Curtain Road',
#     'address2': 'Shoreditch',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 3PJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['126 Curtain Road',
#      'Shoreditch',
#      'London EC2A 3PJ',
#      'United Kingdom']},
#    'phone': '+442070339555',
#    'display_phone': '+44 20 7033 9555',
#    'distance': 4130.140674765295},
#   {'id': 'C3Dp2ONw3fntVgUTwCjHLg',
#    'alias': 'st-john-bakery-london-2',
#    'name': 'St John Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/b7CV9uGCdrYYoQAH2x0PsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-john-bakery-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.499488, 'longitude': -0.075961},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '72 Druid St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['72 Druid St', 'London SE1', 'United Kingdom']},
#    'phone': '+442072375999',
#    'display_phone': '+44 20 7237 5999',
#    'distance': 4409.5796775486},
#   {'id': '83KeM6uScA4ONx97xMHvXw',
#    'alias': 'golden-gate-cake-shop-london',
#    'name': 'Golden Gate Cake Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/t6bnv4bccgmpFEL0qVpmag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/golden-gate-cake-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511968, 'longitude': -0.131181},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '13 Macclesfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 5BR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Macclesfield Street',
#      'London W1D 5BR',
#      'United Kingdom']},
#    'phone': '+442072879862',
#    'display_phone': '+44 20 7287 9862',
#    'distance': 345.0054953908694},
#   {'id': 'M1gUkd17zi9ZYjBcSkSpIA',
#    'alias': 'le-gavroche-london',
#    'name': 'Le Gavroche',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dAz5UoYBrv5cZZzwO1db_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-gavroche-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.511300562631,
#     'longitude': -0.15507069144529},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '43 Upper Brook Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 7QR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['43 Upper Brook Street',
#      'London W1K 7QR',
#      'United Kingdom']},
#    'phone': '+442074080881',
#    'display_phone': '+44 20 7408 0881',
#    'distance': 1333.7550905711703},
#   {'id': 'YNduANMPzIVE8CzBH7YjEQ',
#    'alias': 'regency-café-london-2',
#    'name': 'Regency Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pz5q5e8LBG7C1ozSuhvuKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/regency-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 393,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4940143171, 'longitude': -0.13222007974201},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '17-19 Regency Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 4BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17-19 Regency Street',
#      'London SW1P 4BY',
#      'United Kingdom']},
#    'phone': '+442078216596',
#    'display_phone': '+44 20 7821 6596',
#    'distance': 2108.732795587357},
#   {'id': 'nBHgQH6Fo7VZ5ipeV9FZmA',
#    'alias': 'bonne-bouche-london',
#    'name': 'Bonne Bouche',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qrnNxCG7Iflid-AiSnSzew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bonne-bouche-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5181053211288,
#     'longitude': -0.151716128809521},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '2-3 Thayer Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 3JB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2-3 Thayer Street',
#      'London W1U 3JB',
#      'United Kingdom']},
#    'phone': '+442074869584',
#    'display_phone': '+44 20 7486 9584',
#    'distance': 1238.0218508033952},
#   {'id': 'XLZZ1MsocZiXavD39zfHgg',
#    'alias': 'paul-london-28',
#    'name': 'Paul',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6CvfTBsiRuSIMwp-7laC1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-london-28?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.508135, 'longitude': -0.139246},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '173 Piccadilly Arcade',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 6NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['173 Piccadilly Arcade',
#      'London SW1Y 6NH',
#      'United Kingdom']},
#    'phone': '+442074998708',
#    'display_phone': '+44 20 7499 8708',
#    'distance': 570.1166518695289},
#   {'id': 'Opa8XUwUghxbGFafvubV6A',
#    'alias': 'monmouth-coffee-london-3',
#    'name': 'Monmouth Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bwLj-cK2l4ws5hpEefgdqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/monmouth-coffee-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 306,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5143539, 'longitude': -0.1269168},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '27 Monmouth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['27 Monmouth Street',
#      'London WC2H 9EU',
#      'United Kingdom']},
#    'phone': '+442072323010',
#    'display_phone': '+44 20 7232 3010',
#    'distance': 647.8829298163467},
#   {'id': '5_0GHVzaA2tgzHSvFt5idw',
#    'alias': 'ladurée-london-12',
#    'name': 'Ladurée',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GkoHmWAPtVH8e9cQqztaJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ladur%C3%A9e-london-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 92,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51184286271,
#     'longitude': -0.123133037598674},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1 The Market',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 8RA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 The Market',
#      'Covent Garden',
#      'London WC2E 8RA',
#      'United Kingdom']},
#    'phone': '+442072400706',
#    'display_phone': '+44 20 7240 0706',
#    'distance': 894.1956882105256},
#   {'id': 'uTm94f_-FlwM7v7T2ycXaQ',
#    'alias': 'dominique-ansel-treehouse-london',
#    'name': 'Dominique Ansel Treehouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Amyw6Q1tbkeeiPYFPnwBUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dominique-ansel-treehouse-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5119045680643,
#     'longitude': -0.12540479881136},
#    'transactions': [],
#    'location': {'address1': '24 Floral Street',
#     'address2': '',
#     'address3': 'Covent Garden',
#     'city': 'London',
#     'zip_code': 'WC2E 9DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Floral Street',
#      'Covent Garden',
#      'London WC2E 9DP',
#      'United Kingdom']},
#    'phone': '+442038834710',
#    'display_phone': '+44 20 3883 4710',
#    'distance': 737.4485292911053},
#   {'id': 'jIuiv7VJkAAM5bRCuKNozg',
#    'alias': 'baker-and-spice-london',
#    'name': 'Baker & Spice',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qhKK__pVmzQmzhkDlOTx8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baker-and-spice-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4936, 'longitude': -0.150758},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '54-56 Elizabeth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 9PB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54-56 Elizabeth Street',
#      'London SW1W 9PB',
#      'United Kingdom']},
#    'phone': '+442077305524',
#    'display_phone': '+44 20 7730 5524',
#    'distance': 2371.6101398591395},
#   {'id': 'uCmXqPY3cOIHxda-HDxB0Q',
#    'alias': 'chinatown-bakery-london',
#    'name': 'Chinatown Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/M53Wp0eRJs57iDxXfqoLyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chinatown-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512026, 'longitude': -0.129721},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '7 Newport Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 7JR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Newport Place',
#      'London WC2H 7JR',
#      'United Kingdom']},
#    'phone': '+442072877995',
#    'display_phone': '+44 20 7287 7995',
#    'distance': 440.74810491522373},
#   {'id': 'Da8ClETsPknyD-XIam-jbg',
#    'alias': 'maroush-bakehouse-london-6',
#    'name': 'Maroush Bakehouse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hYjyJ-w7yL5JNQ_7sUFl9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maroush-bakehouse-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'lebanese', 'title': 'Lebanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.49332, 'longitude': -0.194478},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '131 Earls Court Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 9RH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['131 Earls Court Road',
#      'London SW5 9RH',
#      'United Kingdom']},
#    'phone': '+442073704324',
#    'display_phone': '+44 20 7370 4324',
#    'distance': 4595.303422118365},
#   {'id': 'U_XeFWW1Lttdq22txTABMw',
#    'alias': 'gails-bakery-neo-bankside-london',
#    'name': "GAIL's Bakery Neo Bankside",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CEfkaYA0zFoAlNcdiNt_aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-neo-bankside-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5066352772979,
#     'longitude': -0.100412668500134},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit C Neo Bankside',
#     'address2': '70 Holland Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9NX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit C Neo Bankside',
#      '70 Holland Road',
#      'London SE1 9NX',
#      'United Kingdom']},
#    'phone': '+442079280621',
#    'display_phone': '+44 20 7928 0621',
#    'distance': 2554.576460738087},
#   {'id': 'zJNI06Y2zZQFh9OBSFCdgQ',
#    'alias': 'sketch-london-2',
#    'name': 'Sketch',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pAEJmqSJX1lh_pLuvjbFww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sketch-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 831,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5127614699071,
#     'longitude': -0.14159163911048},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '9 Conduit Street',
#     'address2': 'Mayfair',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 2XG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Conduit Street',
#      'Mayfair',
#      'London W1S 2XG',
#      'United Kingdom']},
#    'phone': '+442076594500',
#    'display_phone': '+44 20 7659 4500',
#    'distance': 390.09161644125044}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                Restaurant          Type Price Rating                  Address  \
# 0                Bageriet  Scandinavian     £    4.5           24 Rose Street
# 1             Bread Ahead      Bakeries     £    4.5           Borough Market
# 2  Dominique Ansel Bakery      Bakeries    ££      4   17-21 Elizabeth Street
# 3          The Pasty Shop      Bakeries     £    4.5  Victoria Street Station
# 4      GAIL's Bakery Soho      Bakeries    ££      4       128 Wardour Street
#
#          Lat       Lng                                                url  \
# 0  51.511924 -0.126182  https://www.yelp.com/biz/bageriet-london?adjus...
# 1  51.506143 -0.090258  https://www.yelp.com/biz/bread-ahead-london-3?...
# 2  51.492691 -0.149131  https://www.yelp.com/biz/dominique-ansel-baker...
# 3  51.496289 -0.143928  https://www.yelp.com/biz/the-pasty-shop-london...
# 4  51.514311 -0.134518  https://www.yelp.com/biz/gails-bakery-soho-lon...
#
#                        ID
# 0  0tJs57Xoq75-RDWKVco0nw
# 1  KZd0pTzAhKbIs9Lg94Delg
# 2  9gqKbR6JK79zTc5RDLP_4A
# 3  EbT5viLW9ujk9iQ73CJcmQ
# 4  in1fuQDAfRBIb7cGnOEviA

# %%
#2nd set of 50 records 51-100 
lndr_params2 = {"term":"pastry","location":"London","limit":50,"offset":51}
lndr_response2 = requests.get(search_api_url, headers=headers, params=lndr_params2)
lndr2 = lndr_response2.json()
display(lndr2)
#print(lndr_response2.url)
#print(lndr_response2.status_code)
# Out:
# {'businesses': [{'id': 'J38s3iokvd30sRGi5uB9lA',
#    'alias': 'l-eto-caffe-london',
#    'name': "L'Eto Caffe",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/glLwggFfv-PFoCGgzDIynA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-eto-caffe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 124,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514301, 'longitude': -0.134786},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '155 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8WG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['155 Wardour Street',
#      'London W1F 8WG',
#      'United Kingdom']},
#    'phone': '+442074944991',
#    'display_phone': '+44 20 7494 4991',
#    'distance': 181.95299001691527},
#   {'id': 'Z3dr4as9zDncGnaCtqnntQ',
#    'alias': 'patisserie-valerie-london-7',
#    'name': 'Patisserie Valerie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GeZus7r-mVclADzIcGbopg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-valerie-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5191096196678,
#     'longitude': -0.15177361600921},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '105 Marylebone High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 4RS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['105 Marylebone High Road',
#      'London W1U 4RS',
#      'United Kingdom']},
#    'phone': '+442079356240',
#    'display_phone': '+44 20 7935 6240',
#    'distance': 1297.9635922946884},
#   {'id': '7Nme-QeQ65gtQEyoB0KyEw',
#    'alias': 'the-coffee-jar-london',
#    'name': 'The Coffee Jar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/26Cm2OUJsOTPR_xpptHdhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-coffee-jar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5373402066451,
#     'longitude': -0.145319216450743},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '83 Parkway',
#     'address2': 'Camden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 7PP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Parkway',
#      'Camden',
#      'London NW1 7PP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2800.7359403054115},
#   {'id': 'r-USboJFp1ifbtFWtbTGhQ',
#    'alias': 'paper-and-cup-london-2',
#    'name': 'Paper and Cup',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XkBLH87FtSkzIaMMSnmN3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paper-and-cup-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5262201, 'longitude': -0.076815},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '18 Calvert Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7JP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Calvert Avenue',
#      'London E2 7JP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4354.245310616501},
#   {'id': 'WotOpvaXPZW2Yx-dzoK73w',
#    'alias': 'seoul-bakery-london-3',
#    'name': 'Seoul Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bLb2f4il2hodPvDWaefrhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seoul-bakery-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.517237, 'longitude': -0.129569},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '14 Great Russell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Great Russell Street',
#      'London WC1B 3NH',
#      'United Kingdom']},
#    'phone': '+442072400877',
#    'display_phone': '+44 20 7240 0877',
#    'distance': 659.4351702613345},
#   {'id': 'f4bEfbf1_VyZpLsvlonhMw',
#    'alias': 'paul-gloucester-road-london',
#    'name': 'PAUL - Gloucester Road',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4LmyxBx2ijOg34FW_YfI9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-gloucester-road-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 56,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4949745, 'longitude': -0.1825811},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '73 Gloucester Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 4SS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['73 Gloucester Road',
#      'London SW7 4SS',
#      'United Kingdom']},
#    'phone': '+442073731232',
#    'display_phone': '+44 20 7373 1232',
#    'distance': 3789.8998601376957},
#   {'id': 'VQCzUGBY63yVE-FxLg6vqg',
#    'alias': 'paul-london-46',
#    'name': 'Paul',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Bpjml-e7uByqnhRG9TS7Dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-london-46?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4922526690858,
#     'longitude': -0.192893868972578},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '185 Earls Court Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW5 9RB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['185 Earls Court Road',
#      'London SW5 9RB',
#      'United Kingdom']},
#    'phone': '+442072441046',
#    'display_phone': '+44 20 7244 1046',
#    'distance': 4557.42106632384},
#   {'id': 'ehdbdRbOyPobXgxt8NybGA',
#    'alias': 'redemption-roasters-kings-cross',
#    'name': 'Redemption Roasters',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aclDa8emYhznIGZ3Sng7yQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/redemption-roasters-kings-cross?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5358826742158,
#     'longitude': -0.126157242991667},
#    'transactions': [],
#    'location': {'address1': 'Unit 109',
#     'address2': 'Lower Stable Street',
#     'address3': None,
#     'city': 'Kings Cross',
#     'zip_code': 'N1C 4AQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 109',
#      'Lower Stable Street',
#      'Kings Cross N1C 4AQ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2650.8674644551675},
#   {'id': '7TETeEdYvewlhdjmMSwLdg',
#    'alias': 'pâtisserie-deux-amis-london-2',
#    'name': 'Pâtisserie Deux Amis',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QOrh6QeP-vvD3r_lviR-CA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/p%C3%A2tisserie-deux-amis-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.526409002227,
#     'longitude': -0.12406009445317},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '63 Judd Street',
#     'address2': 'Bloomsbury',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 9QT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63 Judd Street',
#      'Bloomsbury',
#      'London WC1H 9QT',
#      'United Kingdom']},
#    'phone': '+442073837029',
#    'display_phone': '+44 20 7383 7029',
#    'distance': 1719.1378500956116},
#   {'id': 'Sxe2lUli3t_XA5aKYUqqkQ',
#    'alias': 'the-butter-bakery-london',
#    'name': 'The Butter Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PpA6jruR-OIILmj4vmjXhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-butter-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5177900934312,
#     'longitude': -0.201469101011753},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '219 Westbourne Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['219 Westbourne Park Road',
#      'London W11',
#      'United Kingdom']},
#    'phone': '+442072439223',
#    'display_phone': '+44 20 7243 9223',
#    'distance': 4566.685019734055},
#   {'id': '47dDRqywcdaMNI8QtiHV8g',
#    'alias': 'cafe-de-nata-london-3',
#    'name': 'Cafe de Nata',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MBb0UCS4rod1IUpDKh8JSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-de-nata-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5130772, 'longitude': -0.1312998},
#    'transactions': [],
#    'location': {'address1': '25 Old Compton Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1D 5JN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['25 Old Compton Street',
#      'London W1D 5JN',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 323.7052542402405},
#   {'id': 'XD89DGPLbNTjVhesu5wyIA',
#    'alias': 'kooky-bakes-london',
#    'name': 'Kooky Bakes',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/C99Maf_9qZ_AdJzCqz8hhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kooky-bakes-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'streetvendors', 'title': 'Street Vendors'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5210655305934,
#     'longitude': -0.0729759455077783},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Sunday Up Market',
#     'address2': 'Brick Lane',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Sunday Up Market',
#      'Brick Lane',
#      'London E1 6QL',
#      'United Kingdom']},
#    'phone': '+442030868350',
#    'display_phone': '+44 20 3086 8350',
#    'distance': 4452.919827953376},
#   {'id': 'gEpuqc4xVZtbEG7jOuhlJQ',
#    'alias': 'vegan-sweet-tooth-london-london-6',
#    'name': 'VEGAN SWEET TOOTH London',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/l8vacFCZLyzv-6l4B_e8-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vegan-sweet-tooth-london-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.3977916, 'longitude': -0.094092},
#    'transactions': [],
#    'location': {'address1': '2',
#     'address2': 'gilsland road',
#     'address3': 'Thornton Heath',
#     'city': 'London',
#     'zip_code': 'CR7 8RQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2',
#      'gilsland road',
#      'Thornton Heath',
#      'London CR7 8RQ',
#      'United Kingdom']},
#    'phone': '+447702499689',
#    'display_phone': '+44 7702 499689',
#    'distance': 13117.029201151905},
#   {'id': 'HAi7bThXmEtooc5ZQq9hdw',
#    'alias': 'laurents-london',
#    'name': 'Laurents',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IjF-yyo_-fqEs5nTO5MMpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laurents-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.513468, 'longitude': -0.179164},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '39 Craven Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 3BX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39 Craven Road', 'London W2 3BX', 'United Kingdom']},
#    'phone': '+442035819232',
#    'display_phone': '+44 20 3581 9232',
#    'distance': 2990.8516064262462},
#   {'id': 'DAE3fIusVTUGt9PDwPlelg',
#    'alias': 'exmouth-coffee-company-london',
#    'name': 'Exmouth Coffee Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0yrsGXNRm5roKhOo_8VUiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/exmouth-coffee-company-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 81,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.515994, 'longitude': -0.070496},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '83 Whitechapel High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 7QX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Whitechapel High Street',
#      'London E1 7QX',
#      'United Kingdom']},
#    'phone': '+442073771010',
#    'display_phone': '+44 20 7377 1010',
#    'distance': 4553.663911477298},
#   {'id': 'chCmoqD2AjX04TE1R0qZOA',
#    'alias': 'popina-london-4',
#    'name': 'Popina',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/75GQwQFxZTxsXs9CpcPviw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/popina-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5130134404197,
#     'longitude': -0.150612695002224},
#    'transactions': [],
#    'location': {'address1': '82 Duke Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1K 6JG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['82 Duke Street', 'London W1K 6JG', 'United Kingdom']},
#    'phone': '+442076298883',
#    'display_phone': '+44 20 7629 8883',
#    'distance': 1014.460480632947},
#   {'id': 'IWl1Y0eQOZSnYeIDw94svg',
#    'alias': 'monmouth-coffee-london',
#    'name': 'Monmouth Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-eZOw_Lts2a7dWXNYekA_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/monmouth-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 306,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5055383383613,
#     'longitude': -0.0914615294783139},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Park Street',
#     'address2': 'The Borough',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Park Street',
#      'The Borough',
#      'London SE1 9AB',
#      'United Kingdom']},
#    'phone': '+442072323010',
#    'display_phone': '+44 20 7232 3010',
#    'distance': 3184.4018654070014},
#   {'id': '0T5fEkTQAry6pRmI056nTA',
#    'alias': 'maitre-choux-london',
#    'name': 'Maitre Choux',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Fl6oLvKyCIxXAp71W_X52w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maitre-choux-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4939411, 'longitude': -0.1755375},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '15 Harrington Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3ES',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Harrington Road',
#      'London SW7 3ES',
#      'United Kingdom']},
#    'phone': '+442035834561',
#    'display_phone': '+44 20 3583 4561',
#    'distance': 3452.4998941819867},
#   {'id': 'MIKUeHBDQs46i6YOVeNKyw',
#    'alias': 'h-r-higgins-london',
#    'name': 'H R Higgins',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eAfRQlbtrCwZ8MP0k8Uisw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/h-r-higgins-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5129642, 'longitude': -0.1508551},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '79 Duke Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1K 5AS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['79 Duke Street', 'London W1K 5AS', 'United Kingdom']},
#    'phone': '+442074918819',
#    'display_phone': '+44 20 7491 8819',
#    'distance': 1031.1420005559974},
#   {'id': 'CrQcYS4nWWdXmSD1pxf_KA',
#    'alias': 'beigel-bake-london',
#    'name': 'Beigel Bake',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1Q9nDZsnX30-yv55INHp7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beigel-bake-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 477,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.524391, 'longitude': -0.071726},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '159 Brick Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['159 Brick Lane', 'London E1 6SB', 'United Kingdom']},
#    'phone': '+442077290616',
#    'display_phone': '+44 20 7729 0616',
#    'distance': 4626.215959115099},
#   {'id': 'S_1iMSbWOa4I7pa8BxWZag',
#    'alias': 'hart-and-lova-london',
#    'name': 'Hart & Lova',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9VIDKCRKfqFstQt53jVA-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hart-and-lova-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5384383, 'longitude': -0.190891},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '213 Belsize Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 4AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['213 Belsize Road',
#      'London NW6 4AA',
#      'United Kingdom']},
#    'phone': '+447882806540',
#    'display_phone': '+44 7882 806540',
#    'distance': 4748.534923920667},
#   {'id': 'lkethHYEgAT3gE-09fLWag',
#    'alias': 'yumchaa-soho-london',
#    'name': 'Yumchaa Soho',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Si6ohuBWReqcfiWiaPMNYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yumchaa-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 161,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515164726519,
#     'longitude': -0.13609727051977},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '45 Berwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8SF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Berwick Street',
#      'London W1F 8SF',
#      'United Kingdom']},
#    'phone': '+442072099641',
#    'display_phone': '+44 20 7209 9641',
#    'distance': 259.1804522380711},
#   {'id': 'W7DpFG8AbfLi516fIvgdDg',
#    'alias': 'abbey-cafe-london',
#    'name': 'Abbey Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UedDW_RDdKobWFYeQBagGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/abbey-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.531848626266,
#     'longitude': -0.18065861355395},
#    'transactions': [],
#    'location': {'address1': '3 Nugent Terrace',
#     'address2': "St. John's Wood",
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 9QB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Nugent Terrace',
#      "St. John's Wood",
#      'London NW8 9QB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3746.3652871577324},
#   {'id': 'Xll3M26qDVQFPVF9rmERZw',
#    'alias': 'ole-and-steen-london-4',
#    'name': 'Ole & Steen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/S_657Xvx5eEDhBLcndKO9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ole-and-steen-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.517686, 'longitude': -0.13121},
#    'transactions': [],
#    'location': {'address1': '1 Bedford Avenue',
#     'address2': 'Unit 4',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC1B 3AU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Bedford Avenue',
#      'Unit 4',
#      'London WC1B 3AU',
#      'United Kingdom']},
#    'phone': '+442039484888',
#    'display_phone': '+44 20 3948 4888',
#    'distance': 631.4592636929035},
#   {'id': 'mdy8N4wPOlOSiatLWKjLGg',
#    'alias': 'the-borough-barista-london',
#    'name': 'The Borough Barista',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5BOQF57dPe1EaVvhzb0wtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-borough-barista-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.514461025878,
#     'longitude': -0.16090849657059},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '60A Seymour Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7JN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['60A Seymour Street',
#      'London W1H 7JN',
#      'United Kingdom']},
#    'phone': '+442075637222',
#    'display_phone': '+44 20 7563 7222',
#    'distance': 1736.1517070034572},
#   {'id': 'IDH_axJK2uI99N5-_PHl5A',
#    'alias': 'phoenicia-mediterranean-food-hall-london',
#    'name': 'Phoenicia - Mediterranean Food Hall',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jVQwCWM78Aneh-MwhCtMdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/phoenicia-mediterranean-food-hall-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'intlgrocery', 'title': 'International Grocery'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'},
#     {'alias': 'butcher', 'title': 'Butcher'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.547598, 'longitude': -0.141266},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '186 -192 Kentish Town Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW5 2AE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['186 -192 Kentish Town Road',
#      'London NW5 2AE',
#      'United Kingdom']},
#    'phone': '+442072671267',
#    'display_phone': '+44 20 7267 1267',
#    'distance': 3882.8214327231235},
#   {'id': '2DPvfVF6vSEaZ5JqDFnXTw',
#    'alias': 'sweetheart-london-2',
#    'name': 'Sweetheart',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_Th_C_WBYuE-upP5DJ8oNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweetheart-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'cupcakes', 'title': 'Cupcakes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5118923302027,
#     'longitude': -0.122435174762825},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 34',
#     'address2': 'The Market',
#     'address3': 'Covent Garden',
#     'city': 'London',
#     'zip_code': 'WC2E 8RE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 34',
#      'The Market',
#      'Covent Garden',
#      'London WC2E 8RE',
#      'United Kingdom']},
#    'phone': '+442072405039',
#    'display_phone': '+44 20 7240 5039',
#    'distance': 941.5093845598345},
#   {'id': 'mpgdKEzO5eDllOEZpKyL3A',
#    'alias': 'maison-ruget-london',
#    'name': 'Maison Ruget',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Np0PMp2TkajFyfzhmq7uEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maison-ruget-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5148914, 'longitude': -0.2042632},
#    'transactions': [],
#    'location': {'address1': '148 Portobello Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W11 2DZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['148 Portobello Road',
#      'London W11 2DZ',
#      'United Kingdom']},
#    'phone': '+442072211000',
#    'display_phone': '+44 20 7221 1000',
#    'distance': 4733.123950874524},
#   {'id': 'Gyxs4y3aofIAjAWGaPNmrQ',
#    'alias': 'milk-bar-london',
#    'name': 'Milk Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5onhkWkXKrnHmKGOHDxEtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/milk-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 82,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514162886575,
#     'longitude': -0.13126851745979},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3 Bateman Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 4AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Bateman Street',
#      'London W1D 4AG',
#      'United Kingdom']},
#    'phone': '+442072874796',
#    'display_phone': '+44 20 7287 4796',
#    'distance': 356.36235664390273},
#   {'id': 'Q-f511k1hYDIKfKIpC_HIw',
#    'alias': 'fabrique-bakery-london-4',
#    'name': 'Fabrique Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5Qq5T9LiFK91ag7ftRlFWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fabrique-bakery-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5134638236347,
#     'longitude': -0.12840236007971},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8 Earlham Street',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9RY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Earlham Street',
#      'Covent Garden',
#      'London WC2H 9RY',
#      'United Kingdom']},
#    'phone': '+442072401392',
#    'display_phone': '+44 20 7240 1392',
#    'distance': 527.3502509023187},
#   {'id': 'cyBJaUTrwdJvarTY-C3SUw',
#    'alias': 'ec1-coffee-house-london-2',
#    'name': 'EC1 Coffee House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_qnl3K8n35Rv2m0kuMx9Mg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ec1-coffee-house-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.522513424384,
#     'longitude': -0.103959729293153},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '45-47 Clerkenwell Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1M 5RS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45-47 Clerkenwell Road',
#      'London EC1M 5RS',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2461.607807048883},
#   {'id': '4ibHPLYd299_m1LOdcqxXw',
#    'alias': 'savoir-faire-london',
#    'name': 'Savoir Faire',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kn-I1Rc8bpafCu5zweqS_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/savoir-faire-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 191,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5171949, 'longitude': -0.1260125},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '42 New Oxford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1A 1EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 New Oxford Street',
#      'London WC1A 1EP',
#      'United Kingdom']},
#    'phone': '+442074360707',
#    'display_phone': '+44 20 7436 0707',
#    'distance': 852.4529863641968},
#   {'id': 'f5lYXTuVpY6iMLyCPMXWsA',
#    'alias': 'louis-hungarian-patisserie-london',
#    'name': 'Louis Hungarian Patisserie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RnGDj2dq7ztSS0CfaqSY9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/louis-hungarian-patisserie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5560567, 'longitude': -0.1785851},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '32 Heath Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 6TE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['32 Heath Street',
#      'London NW3 6TE',
#      'United Kingdom']},
#    'phone': '+442074359908',
#    'display_phone': '+44 20 7435 9908',
#    'distance': 5636.660617752017},
#   {'id': 'xJvPDma1C7F7hvEp0OfjWg',
#    'alias': 'patisserie-valerie-london-11',
#    'name': 'Patisserie Valerie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lcoP_bGFWqLxUVWqFEuszA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-valerie-london-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5142705778633,
#     'longitude': -0.159455789441691},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'York House',
#     'address2': '15 Great Cumberland Place',
#     'address3': 'London',
#     'city': 'London',
#     'zip_code': 'W1H 7AS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['York House',
#      '15 Great Cumberland Place',
#      'London',
#      'London W1H 7AS',
#      'United Kingdom']},
#    'phone': '+442077248542',
#    'display_phone': '+44 20 7724 8542',
#    'distance': 1634.0041903497304},
#   {'id': 'iXVq9PcCT-a34FzaXbUagA',
#    'alias': 'scooter-caffè-london-2',
#    'name': 'Scooter Caffè',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/x9HNw_Kud2pJil8Zv5_8oA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scooter-caff%C3%A8-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.500341224864,
#     'longitude': -0.11381534473676},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '132 Lower Marsh',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7AE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['132 Lower Marsh',
#      'London SE1 7AE',
#      'United Kingdom']},
#    'phone': '+442076201421',
#    'display_phone': '+44 20 7620 1421',
#    'distance': 2068.3940056684514},
#   {'id': 'PBFvhVyBi0lEJyTbyuxf5w',
#    'alias': 'the-orangery-london-7',
#    'name': 'The Orangery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L_0d22xNmfCC_d-tArBo3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-orangery-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 238,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5066360577041,
#     'longitude': -0.187725349125042},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Kensington Palace',
#     'address2': 'Palace Green',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Kensington Palace',
#      'Palace Green',
#      'London W8 4PX',
#      'United Kingdom']},
#    'phone': '+442031666113',
#    'display_phone': '+44 20 3166 6113',
#    'distance': 3648.4574890404074},
#   {'id': 'uwQVCV7lXyHM2uvwKei-Dw',
#    'alias': 'konditor-and-cook-london-2',
#    'name': 'Konditor & Cook',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ebMM9yTvaxjR-k9wx_dwdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/konditor-and-cook-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5130832, 'longitude': -0.0936692},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9 Bow Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4M 9EB',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ['9 Bow Lane', 'London EC4M 9EB', 'United Kingdom']},
#    'phone': '+442076333333',
#    'display_phone': '+44 20 7633 3333',
#    'distance': 2925.4952035964807},
#   {'id': '-EPJuMu8Qbr5azjHu_QOtg',
#    'alias': 'the-watch-house-london-5',
#    'name': 'The Watch House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/v6IlbI-P0BgzdTxXQcQn2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-watch-house-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4980461313304,
#     'longitude': -0.0810502413027092},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '199 Bermondsey Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 3UW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['199 Bermondsey Street',
#      'London SE1 3UW',
#      'United Kingdom']},
#    'phone': '+442074075431',
#    'display_phone': '+44 20 7407 5431',
#    'distance': 4140.698976372922},
#   {'id': 'PYwzVOvFIjwCMNYV5upPwg',
#    'alias': 'the-attendant-london-2',
#    'name': 'The Attendant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W4pc8bJ_lVWg801nKejVOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-attendant-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 74,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5192470995905,
#     'longitude': -0.140738025145255},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Downstairs 27A',
#     'address2': 'Foley Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 6DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Downstairs 27A',
#      'Foley Street',
#      'London W1W 6DY',
#      'United Kingdom']},
#    'phone': '+442076373794',
#    'display_phone': '+44 20 7637 3794',
#    'distance': 785.9877629261662},
#   {'id': 'ztuEuIDjVTJMklB2OP3rpg',
#    'alias': 'ty-seven-dials-timberyard-london-2',
#    'name': 'TY Seven Dials - Timberyard',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Gr5lHKB84DjJGw8ESo5I6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ty-seven-dials-timberyard-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 138,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5128577362728,
#     'longitude': -0.127308054907987},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "7 Upper St Martin's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["7 Upper St Martin's Lane",
#      'London WC2H 9DL',
#      'United Kingdom']},
#    'phone': '+442032172009',
#    'display_phone': '+44 20 3217 2009',
#    'distance': 598.4373905869091},
#   {'id': 'BhIXdzdJfPsFX0ZpdkfvzA',
#    'alias': 'le-deli-robuchon-london',
#    'name': 'Le Deli Robuchon',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VXWiC1qNJylOEBUxn8OYPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-deli-robuchon-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5064442712487,
#     'longitude': -0.14376774430275},
#    'transactions': [],
#    'location': {'address1': '82 Piccadilly',
#     'address2': 'Mayfair',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1J 8JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['82 Piccadilly',
#      'Mayfair',
#      'London W1J 8JA',
#      'United Kingdom']},
#    'phone': '+442080760564',
#    'display_phone': '+44 20 8076 0564',
#    'distance': 892.938302891522},
#   {'id': '1iZkMMh1PZnCjQhJLivG3Q',
#    'alias': 'carmelli-london',
#    'name': 'Carmelli',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/M7o8leBNP8ttnhOP8rHOcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carmelli-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5739863, 'longitude': -0.2007461},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '126-128 Golders Green Road',
#     'address2': '',
#     'address3': 'London',
#     'city': 'London',
#     'zip_code': 'NW11 8HB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['126-128 Golders Green Road',
#      'London',
#      'London NW11 8HB',
#      'United Kingdom']},
#    'phone': '+442084552074',
#    'display_phone': '+44 20 8455 2074',
#    'distance': 8150.379306826664},
#   {'id': '39nGPmVcnpp3RaenmlfZCQ',
#    'alias': 'long-shot-coffee-london',
#    'name': 'Long Shot Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yCoFPInejXdzoZXOHfMfFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/long-shot-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5117874, 'longitude': -0.0687977},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '127 Leman Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 8EY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['127 Leman Street',
#      'London E1 8EY',
#      'United Kingdom']},
#    'phone': '+442074811100',
#    'display_phone': '+44 20 7481 1100',
#    'distance': 4650.305158888016},
#   {'id': 'CYYAMBaNJ2dxgUXLk3XvYA',
#    'alias': 'grace-cafe-london',
#    'name': 'Grace Cafe',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grace-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5131714, 'longitude': -0.1012047},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '8 Creed Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4V 5DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Creed Lane', 'London EC4V 5DY', 'United Kingdom']},
#    'phone': '+447910821659',
#    'display_phone': '+44 7910 821659',
#    'distance': 2405.0890996547323},
#   {'id': 'VZ_1ATiJ5j4uTHvGHr7JNw',
#    'alias': 'wonderful-patisserie-london',
#    'name': 'Wonderful Patisserie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_L6bhJQIUIF0rscqPJHuIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wonderful-patisserie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.511969, 'longitude': -0.130143},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '45 Gerrard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 5QQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Gerrard Street',
#      'London W1D 5QQ',
#      'United Kingdom']},
#    'phone': '+442077347629',
#    'display_phone': '+44 20 7734 7629',
#    'distance': 415.7925288481275},
#   {'id': 'L-ZNTln24SoU_jYia4M19Q',
#    'alias': 'ottolenghi-london-3',
#    'name': 'Ottolenghi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/M0v7lVN-ZkBDz0BuJQhzwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ottolenghi-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 96,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514890823172,
#     'longitude': -0.19941762827537},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '63 Ledbury Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2AD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63 Ledbury Road',
#      'London W11 2AD',
#      'United Kingdom']},
#    'phone': '+442077271121',
#    'display_phone': '+44 20 7727 1121',
#    'distance': 4397.458116121883},
#   {'id': 'HXjHL0L7lqtQQ1KJ0ZKAug',
#    'alias': 'kastner-and-ovens-london',
#    'name': 'Kastner and Ovens',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/n6adQfuqx24tKJlv0wMiew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kastner-and-ovens-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5135034, 'longitude': -0.1227604},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '52 Floral Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 9DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['52 Floral Street',
#      'London WC2E 9DA',
#      'United Kingdom']},
#    'phone': '+442078362700',
#    'display_phone': '+44 20 7836 2700',
#    'distance': 918.5834049759383},
#   {'id': 'v3MQtzWZhRCknVhl9OoZzw',
#    'alias': 'the-balcon-london-2',
#    'name': 'The Balcon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-Hgrzf9TfWuUL-dEEw5Bdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-balcon-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.507687, 'longitude': -0.132279},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '8 Pall Mall',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 5NG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Pall Mall', 'London SW1Y 5NG', 'United Kingdom']},
#    'phone': '+442079682900',
#    'display_phone': '+44 20 7968 2900',
#    'distance': 627.834435994637},
#   {'id': 'GSbQscE52ZfK43ykA6vLbg',
#    'alias': 'fortnum-and-mason-diamond-jubilee-tea-salon-london',
#    'name': 'Fortnum and Mason: Diamond Jubilee Tea Salon',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BnvHO-ZpEwnHqhsLLXzr0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fortnum-and-mason-diamond-jubilee-tea-salon-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 262,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5087069889729,
#     'longitude': -0.138279327972609},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '4th Floor',
#     'address2': '181 Piccadilly',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1A 1ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4th Floor',
#      '181 Piccadilly',
#      'London W1A 1ER',
#      'United Kingdom']},
#    'phone': '+448453001707',
#    'display_phone': '+44 845 300 1707',
#    'distance': 486.41760431695195},
#   {'id': 'FATOg3vQpgbrl_20WySbqQ',
#    'alias': 'sunflour-bakery-london',
#    'name': 'Sunflour Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/E_YSpYIlnlq9XSV4uQFxZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sunflour-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.539747, 'longitude': -0.11718},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '263 Caledonian Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 1EE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['263 Caledonian Road',
#      'London N1 1EE',
#      'United Kingdom']},
#    'phone': '+442076970003',
#    'display_phone': '+44 20 7697 0003',
#    'distance': 3259.713725625197}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#            Restaurant                  Type Price Rating  \
# 0         L'Eto Caffe                 Cafes    ££      4
# 1  Patisserie Valerie  Patisserie/Cake Shop    ££      4
# 2      The Coffee Jar          Coffee & Tea    ££    4.5
# 3       Paper and Cup          Coffee & Tea     £    4.5
# 4        Seoul Bakery                 Cafes     £    4.5
#
#                     Address        Lat       Lng  \
# 0        155 Wardour Street  51.514301 -0.134786
# 1  105 Marylebone High Road  51.519110 -0.151774
# 2                83 Parkway  51.537340 -0.145319
# 3         18 Calvert Avenue  51.526220 -0.076815
# 4   14 Great Russell Street  51.517237 -0.129569
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/l-eto-caffe-london?ad...  J38s3iokvd30sRGi5uB9lA
# 1  https://www.yelp.com/biz/patisserie-valerie-lo...  Z3dr4as9zDncGnaCtqnntQ
# 2  https://www.yelp.com/biz/the-coffee-jar-london...  7Nme-QeQ65gtQEyoB0KyEw
# 3  https://www.yelp.com/biz/paper-and-cup-london-...  r-USboJFp1ifbtFWtbTGhQ
# 4  https://www.yelp.com/biz/seoul-bakery-london-3...  WotOpvaXPZW2Yx-dzoK73w

# %%
#3rd set of 50 records 101-150
lndr_params3 = {"term":"pastry","location":"London","limit":50,"offset":101}
lndr_response3 = requests.get(search_api_url, headers=headers, params=lndr_params3)
lndr3 = lndr_response3.json()
display(lndr3)
#print(lndr_response3.url)
#print(lndr_response3.status_code)
# Out:
# {'businesses': [{'id': 'fp5po-wno5RLU4Rz0q0h-w',
#    'alias': 'my-place-soho-london',
#    'name': 'My Place Soho',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gnMfIijyZhFXOyvJPP88ZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-place-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5138405, 'longitude': -0.1346902},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '21 Berwick Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1F 0PZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21 Berwick Street',
#      'London W1F 0PZ',
#      'United Kingdom']},
#    'phone': '+442034172829',
#    'display_phone': '+44 20 3417 2829',
#    'distance': 141.97901027026617},
#   {'id': 'PwLaIu3Gb7tsAvTfBryABw',
#    'alias': 'santa-nata-london-2',
#    'name': 'Santa Nata',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9uIJyXcYvhhI93c7vZqrIQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/santa-nata-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512495, 'longitude': -0.1218693},
#    'transactions': [],
#    'location': {'address1': '17 Russell St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2B 5HP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17 Russell St', 'London WC2B 5HP', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 993.0445297032087},
#   {'id': 'x5vg6DMQQjiuZ2SQVKhIAg',
#    'alias': 'ladurée-london-8',
#    'name': 'Ladurée',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/h8Pp-zN6jYrCJ5nbwRx96Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ladur%C3%A9e-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 127,
#    'categories': [{'alias': 'delicatessen', 'title': 'Delicatessen'},
#     {'alias': 'macarons', 'title': 'Macarons'},
#     {'alias': 'chocolate', 'title': 'Chocolatiers & Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4984851733343,
#     'longitude': -0.162618309259415},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '87 Brompton Road',
#     'address2': 'Harrods',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7XL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['87 Brompton Road',
#      'Harrods',
#      'London SW1X 7XL',
#      'United Kingdom']},
#    'phone': '+442031550111',
#    'display_phone': '+44 20 3155 0111',
#    'distance': 2439.5817151439915},
#   {'id': 'F1TUcNYeB2oogqpO5Pdkzg',
#    'alias': 'the-pastry-parlour-london-2',
#    'name': 'The Pastry Parlour',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ek1VkyS-6E-hzFegQm3DIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pastry-parlour-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.513737, 'longitude': -0.067745},
#    'transactions': [],
#    'location': {'address1': "47 Gower's Walk",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 8BS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["47 Gower's Walk", 'London E1 8BS', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4721.266573083818},
#   {'id': 'mnRiHkVxRxL70m5IL1ReMw',
#    'alias': 'the-breadstall-london-2',
#    'name': 'The Breadstall',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dSjbR4cJ33UqK96UgqDxag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-breadstall-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'marketstalls', 'title': 'Market Stalls'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.456328, 'longitude': -0.165136},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Northcote Road',
#     'address2': 'Battersea',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW11 6PS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Northcote Road',
#      'Battersea',
#      'London SW11 6PS',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6606.050122707436},
#   {'id': 'DUS7Nz3429d2iv0q-Jky9A',
#    'alias': 'paul-london-3',
#    'name': 'Paul',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_deqF7vT-EKCTReCgaMVqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4990676958953,
#     'longitude': -0.165139898919551},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '122 Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 1JD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['122 Brompton Road',
#      'London SW3 1JD',
#      'United Kingdom']},
#    'phone': '+442075846117',
#    'display_phone': '+44 20 7584 6117',
#    'distance': 2534.4748856906567},
#   {'id': 'UhXQ3C0ixl8BukWDAR-cqg',
#    'alias': 'lisboa-patisserie-london',
#    'name': 'Lisboa Patisserie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MHk4pcW6eU8Gm_oU-pSeGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lisboa-patisserie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5224017, 'longitude': -0.2074916},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '57 Golborne Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W10 5NR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57 Golborne Road',
#      'London W10 5NR',
#      'United Kingdom']},
#    'phone': '+442089685242',
#    'display_phone': '+44 20 8968 5242',
#    'distance': 5062.825558024065},
#   {'id': 'Z9nUxF6zHfzluOG0Ga5bxQ',
#    'alias': 'maroush-bakehouse-london-2',
#    'name': 'Maroush Bakehouse',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ghurusucKQnE8OEdUqC1fQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maroush-bakehouse-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'delicatessen', 'title': 'Delicatessen'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5151314, 'longitude': -0.1633217},
#    'transactions': [],
#    'location': {'address1': '45-49 Edgware Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 2HZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45-49 Edgware Road',
#      'London W2 2HZ',
#      'United Kingdom']},
#    'phone': '+442072621915',
#    'display_phone': '+44 20 7262 1915',
#    'distance': 1910.8267043883154},
#   {'id': 'rn70OOQObZ5TxvIahNSl7w',
#    'alias': 'chanteroy-london',
#    'name': 'Chanteroy',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aK36AUi8VjIHMADgKKBzoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chanteroy-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cheese', 'title': 'Cheese Shops'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4450952518046,
#     'longitude': -0.205981699624434},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '233a Wimbledon Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW18 5RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['233a Wimbledon Park Road',
#      'London SW18 5RJ',
#      'United Kingdom']},
#    'phone': '+442088741446',
#    'display_phone': '+44 20 8874 1446',
#    'distance': 8958.445522157237},
#   {'id': 'UjMwZ6-PgXs3BXN7LLOSAw',
#    'alias': 'gails-bakery-pimlico-london',
#    'name': "GAIL's Bakery - Pimlico",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zobkG9NdbclJN7D9O6w5yw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-pimlico-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4917627846861,
#     'longitude': -0.139058523838447},
#    'transactions': [],
#    'location': {'address1': '26 Churton Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1V 2LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Churton Street',
#      'London SW1V 2LP',
#      'United Kingdom']},
#    'phone': '+442079320734',
#    'display_phone': '+44 20 7932 0734',
#    'distance': 2352.9999537192894},
#   {'id': 't9-_U2-WmaIee3XDB0Tz0w',
#    'alias': 'hotel-café-royal-london',
#    'name': 'Hotel Café Royal',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Jnx6mmFqDAEbaSkqyvdMKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-caf%C3%A9-royal-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 65,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.510171, 'longitude': -0.135962},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '68 Regent Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 4DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['68 Regent Street',
#      'London W1B 4DY',
#      'United Kingdom']},
#    'phone': '+442074063333',
#    'display_phone': '+44 20 7406 3333',
#    'distance': 296.2812185491074},
#   {'id': 'qVpaMQ1s6wqRe2A3K2Ptew',
#    'alias': 'workshop-coffee-london-2',
#    'name': 'Workshop Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2y7vlJhzrionUwEFte2rZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/workshop-coffee-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.517581, 'longitude': -0.142626},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '80 A Mortimer Street',
#     'address2': 'Fitzrovia',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 7FE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['80 A Mortimer Street',
#      'Fitzrovia',
#      'London W1W 7FE',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 691.8581768473714},
#   {'id': '-22PaX8rQyh0ZQrdCiDz4A',
#    'alias': 'fuckoffee-london-3',
#    'name': 'Fuckoffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MQ7RV7bMOSjdLX1DfhzQ_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fuckoffee-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 87,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4993814, 'longitude': -0.0812485},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '163-167 Bermondsey Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 3UW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['163-167 Bermondsey Street',
#      'London SE1 3UW',
#      'United Kingdom']},
#    'phone': '+442074037655',
#    'display_phone': '+44 20 7403 7655',
#    'distance': 4071.1885164771065},
#   {'id': 'euPJ7RVjrni8E_HcM85dUw',
#    'alias': 'etna-coffee-london',
#    'name': 'Etna Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uzLHyZn7-mMxtWGxejV8ag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/etna-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5188887, 'longitude': -0.1558085},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '54 Baker Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1U 7WH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54 Baker Street',
#      'London W1U 7WH',
#      'United Kingdom']},
#    'phone': '+442079351600',
#    'display_phone': '+44 20 7935 1600',
#    'distance': 1529.7649188479352},
#   {'id': 'G9fziI6-xivwIobgudOtaQ',
#    'alias': 'momento-london-2',
#    'name': 'Momento',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/x5fAer3cjkyJ6c0PCteY2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/momento-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5164189, 'longitude': -0.1738711},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '159 Praed Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['159 Praed Street',
#      'London W2 1RL',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2653.752571351006},
#   {'id': 'dpJpZsb1zuTcEDUPoI4C4Q',
#    'alias': 'sun-luen-london-2',
#    'name': 'Sun Luen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RJyQDfVM4JtZBqbYE1ysBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sun-luen-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511843, 'longitude': -0.12901},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '14 Little Newport Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 7JJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Little Newport Street',
#      'London WC2H 7JJ',
#      'United Kingdom']},
#    'phone': '+442074377468',
#    'display_phone': '+44 20 7437 7468',
#    'distance': 509.0161741672901},
#   {'id': 'WTXaI3zLo-2VTsfjvAOgHA',
#    'alias': 'slice-street-bakery-london-2',
#    'name': 'Slice Street Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tHfYum52NJKjc-XwGl3KJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/slice-street-bakery-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.462387579162,
#     'longitude': -0.167677961289883},
#    'transactions': [],
#    'location': {'address1': "St John's Road",
#     'address2': 'Battersea',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW11',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["St John's Road",
#      'Battersea',
#      'London SW11',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6024.224738575077},
#   {'id': 'WXdvvDADvJTpDUkU4rkp5Q',
#    'alias': 'le-montmartre-london',
#    'name': 'Le Montmartre',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OA-yqi3jg-0GEF64DmmFag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-montmartre-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5133389, 'longitude': -0.0843126},
#    'transactions': [],
#    'location': {'address1': '59-60 Cornhill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3V 3PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['59-60 Cornhill',
#      'London EC3V 3PD',
#      'United Kingdom']},
#    'phone': '+442079364108',
#    'display_phone': '+44 20 7936 4108',
#    'distance': 3570.584518799582},
#   {'id': '1OcBgrUzPgp82BfZBUKRow',
#    'alias': 'gails-bakery-hampstead-london',
#    'name': "GAIL's Bakery Hampstead",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UOf253iDTU_yHsHrbwwV2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-hampstead-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5561216, 'longitude': -0.1779628},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '64 Hampstead High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 1QH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['64 Hampstead High Street',
#      'London NW3 1QH',
#      'United Kingdom']},
#    'phone': '+442077940926',
#    'display_phone': '+44 20 7794 0926',
#    'distance': 5621.242336165493},
#   {'id': 'Z_KQWTzlUVWjVoFd0b77aw',
#    'alias': 'said-london',
#    'name': 'Said',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/r7ojZUtSeE9UPXJ2Flijfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/said-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'chocolate', 'title': 'Chocolatiers & Shops'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5132248, 'longitude': -0.136738},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '41 Broadwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41 Broadwick Street',
#      'London W1F 9QL',
#      'United Kingdom']},
#    'phone': '+442074371584',
#    'display_phone': '+44 20 7437 1584',
#    'distance': 69.30726559279131},
#   {'id': 'Y3YV7FSwxJm--wj2DNAoEA',
#    'alias': 'kahaila-cafe-london',
#    'name': 'Kahaila Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/C-AjTvTLMqiUsPUyOEV7YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kahaila-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'nonprofit',
#      'title': 'Community Service/Non-Profit'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.523786, 'longitude': -0.071577},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '135 Brick Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['135 Brick Lane', 'London E1 6SB', 'United Kingdom']},
#    'phone': '+442079981388',
#    'display_phone': '+44 20 7998 1388',
#    'distance': 4617.9569747350515},
#   {'id': '-PAvIOieAnJH9ZZwZCR2iQ',
#    'alias': 'konditor-and-cook-london',
#    'name': 'Konditor',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hXutxCBTqx-pGZuCpo7cYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/konditor-and-cook-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51969, 'longitude': -0.111929},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "46 Gray's Inn Rd",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1X 8LR',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ["46 Gray's Inn Rd",
#      'London WC1X 8LR',
#      'United Kingdom']},
#    'phone': '+442076333333',
#    'display_phone': '+44 20 7633 3333',
#    'distance': 1828.934181489293},
#   {'id': 'OfVWxtafTQQ0am4JC8aOLQ',
#    'alias': 'élan-cafe-london',
#    'name': 'Élan Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cVnWWiIPbOhQWqrXlJ6aFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%C3%A9lan-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.4966404103307,
#     'longitude': -0.168716306698447},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '239 Brompton Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW3 2EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['239 Brompton Road',
#      'London SW3 2EP',
#      'United Kingdom']},
#    'phone': '+442074918880',
#    'display_phone': '+44 20 7491 8880',
#    'distance': 2895.564348908017},
#   {'id': 'ttROKeMmaM1k39JogTAFSA',
#    'alias': 'paul-london-32',
#    'name': 'Paul',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JVQ8KzP7TMypYooagV1lfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-london-32?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51468, 'longitude': -0.09843},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Paternoster Lodge',
#     'address2': 'Paternoster Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4M 7DX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Paternoster Lodge',
#      'Paternoster Square',
#      'London EC4M 7DX',
#      'United Kingdom']},
#    'phone': '+442073294705',
#    'display_phone': '+44 20 7329 4705',
#    'distance': 2578.3611394881545},
#   {'id': 'GWeEuO9SvFKldRJBVJFBcw',
#    'alias': 'le-cordon-bleu-london-3',
#    'name': 'Le Cordon Bleu',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4F6VrTrPduCVRwiTQUWVmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-cordon-bleu-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5189056, 'longitude': -0.1237716},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '15 Bloomsbury Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1A 2LS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Bloomsbury Square',
#      'London WC1A 2LS',
#      'United Kingdom']},
#    'phone': '+442074003900',
#    'display_phone': '+44 20 7400 3900',
#    'distance': 1096.4929426913645},
#   {'id': 'uUW5p5Y1eyp3fQ5_fXV8Hw',
#    'alias': 'arif-bakery-london',
#    'name': 'Arif Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/d6TYjBmM-7hqoOeqx2hw2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arif-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4890362, 'longitude': -0.0964018},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '212 Walworth Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE17 1JE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['212 Walworth Road',
#      'London SE17 1JE',
#      'United Kingdom']},
#    'phone': '+442077082540',
#    'display_phone': '+44 20 7708 2540',
#    'distance': 3796.3619303625246},
#   {'id': 'IfyCqU5noJALqrXTGKnQsQ',
#    'alias': 'the-little-one-london',
#    'name': 'The Little One',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qqYE8rW0C02TamnqgZCEDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-little-one-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5426041, 'longitude': -0.1555134},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "115 Regent's Park Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8UR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["115 Regent's Park Road",
#      'London NW1 8UR',
#      'United Kingdom']},
#    'phone': '+447510843093',
#    'display_phone': '+44 7510 843093',
#    'distance': 3575.938807492533},
#   {'id': '-u5a56uMO4bAHlDXgCQ2tQ',
#    'alias': 'rochelle-canteen-london',
#    'name': 'Rochelle Canteen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kF64eCZmlLQmBR8taRxf1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rochelle-canteen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5256247386258,
#     'longitude': -0.0741839616935067},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '16 Playground Gardens',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7FA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Playground Gardens',
#      'London E2 7FA',
#      'United Kingdom']},
#    'phone': '+442077295677',
#    'display_phone': '+44 20 7729 5677',
#    'distance': 4504.4424539457705},
#   {'id': 'XN7K4g1Wq-93WYvg85EgMg',
#    'alias': 'the-gentlemen-baristas-london',
#    'name': 'The Gentlemen Baristas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/weXGI3HolMjieVD466xwyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-gentlemen-baristas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.503841999477,
#     'longitude': -0.0947035655992168},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '63 Union Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1SG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63 Union Street',
#      'London SE1 1SG',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3025.052485481412},
#   {'id': 'ugfrj4j6BmZfNfGvzHCY6g',
#    'alias': 'doughnut-time-london',
#    'name': 'Doughnut Time',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XtxpTY6BGVyMTHgkzO510A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doughnut-time-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512214, 'longitude': -0.1312078},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '96 Shaftesbury Avenue',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1D 5ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['96 Shaftesbury Avenue',
#      'London W1D 5ED',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 337.4097588890315},
#   {'id': '8il2IaM8wmi2MUPMbk5SRA',
#    'alias': 'bagel-delight-bakery-london',
#    'name': 'Bagel Delight Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/goJ93R7n2WzDZoM57OdVOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagel-delight-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.556003, 'longitude': -0.214833},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '155 Cricklewood Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW2 3HY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['155 Cricklewood Broadway',
#      'London NW2 3HY',
#      'United Kingdom']},
#    'phone': '+442084504080',
#    'display_phone': '+44 20 8450 4080',
#    'distance': 7275.080336624443},
#   {'id': '3PeQF-J_j89dcLcC0P5o4A',
#    'alias': 'gails-bakery-bloomsbury-london-3',
#    'name': "GAIL's Bakery - Bloomsbury",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/POqVbFU_O0cRoPrHezyypA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-bloomsbury-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5188693, 'longitude': -0.131913},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '11-13 Bayley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3HD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11-13 Bayley Street',
#      'London WC1B 3HD',
#      'United Kingdom']},
#    'phone': '+442073232356',
#    'display_phone': '+44 20 7323 2356',
#    'distance': 725.3824302360697},
#   {'id': 'vJdVqeNAQ4i9Gvh6fDwXrw',
#    'alias': 'dum-dum-donutterie-london',
#    'name': 'Dum Dum Donutterie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PMPS24XnRnCPK6j3iYatzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dum-dum-donutterie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.523523, 'longitude': -0.075889},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 31 Box Park',
#     'address2': '2-4 Bethnal Green Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6HT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 31 Box Park',
#      '2-4 Bethnal Green Road',
#      'London E1 6HT',
#      'United Kingdom']},
#    'phone': '+447525115233',
#    'display_phone': '+44 7525 115233',
#    'distance': 4322.7520901072585},
#   {'id': '3e0w6LF8-QVlGziAAbpljA',
#    'alias': 'pavilion-cafe-hackney',
#    'name': 'Pavilion Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OhY9hBblvGOejv0d5DMN3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pavilion-cafe-hackney?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5364813172579,
#     'longitude': -0.0618335538444681},
#    'transactions': [],
#    'location': {'address1': '18 Broadway Market',
#     'address2': '',
#     'address3': '',
#     'city': 'Hackney',
#     'zip_code': 'E8 4QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Broadway Market',
#      'Hackney E8 4QJ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5762.7679725969},
#   {'id': '-X11ta8_G08LraoZJoHFaA',
#    'alias': 'the-pastry-parlour-london',
#    'name': 'The Pastry Parlour',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AlKluhP8OxWhHgj9gioi2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pastry-parlour-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.513553, 'longitude': -0.069471},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8 Piazza Walk',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 8FU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Piazza Walk', 'London E1 8FU', 'United Kingdom']},
#    'phone': '+442077024113',
#    'display_phone': '+44 20 7702 4113',
#    'distance': 4601.463732493841},
#   {'id': '9suEi8Hch0YjqnDNtBxhdQ',
#    'alias': 'bread-ahead-london-6',
#    'name': 'Bread Ahead',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ix7tDKo9I9nsz2kT4x6uQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bread-ahead-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5121612401552,
#     'longitude': -0.138188934487744},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '21 Beak Street',
#     'address2': '',
#     'address3': 'Soho',
#     'city': 'London',
#     'zip_code': 'W1F 9RR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21 Beak Street',
#      'Soho',
#      'London W1F 9RR',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 171.76334887977825},
#   {'id': 'ZDDEKWdrpjJHqX2d0InVMg',
#    'alias': 'urban-baristas-london-2',
#    'name': 'Urban Baristas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/f5NsZ4qiBlgvwVMbwh54Qg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/urban-baristas-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5108318662288,
#     'longitude': -0.187354646623135},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Queensway',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 4QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Queensway', 'London W2 4QJ', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3563.8944950081736},
#   {'id': 'DY2qHkTlkWB8UVxnaCWj-w',
#    'alias': 'euphorium-bakery-london-6',
#    'name': 'Euphorium Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cz8zy9HMtV9RRobzyZk4HA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/euphorium-bakery-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5365826, 'longitude': -0.1035965},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '79 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 0NU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['79 Upper Street', 'London N1 0NU', 'United Kingdom']},
#    'phone': '+442072888788',
#    'display_phone': '+44 20 7288 8788',
#    'distance': 3460.115806670105},
#   {'id': 'm3vdBGC0X94sG_5pglDcjQ',
#    'alias': 'st-john-bread-and-wine-london',
#    'name': 'St. John Bread & Wine',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/pp8TqPWzX151RfxV3HbzXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-john-bread-and-wine-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 128,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5196695, 'longitude': -0.074299},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '94-96 Commercial Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6LZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['94-96 Commercial Street',
#      'London E1 6LZ',
#      'United Kingdom']},
#    'phone': '+442072510848',
#    'display_phone': '+44 20 7251 0848',
#    'distance': 4337.705786972397},
#   {'id': 'MY5vPpDxJFPzj-wR4_pUsg',
#    'alias': 'crumpets-london',
#    'name': 'Crumpets',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2GXRSS7bftG4X6Z-0Q4VxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crumpets-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4991936, 'longitude': -0.1382647},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '82 Buckingham Gate',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1E 6PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['82 Buckingham Gate',
#      'London SW1E 6PD',
#      'United Kingdom']},
#    'phone': '+442072331479',
#    'display_phone': '+44 20 7233 1479',
#    'distance': 1525.3047584226708},
#   {'id': '9Rt2XZouSHgIyrYRmypVXA',
#    'alias': 'hagen-london',
#    'name': 'Hagen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jGC4_HvZFEIXeNejpzXs5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hagen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4878836, 'longitude': -0.1671998},
#    'transactions': [],
#    'location': {'address1': "151 King's Road",
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW3 5TX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["151 King's Road",
#      'London SW3 5TX',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3517.85048149},
#   {'id': '4rpkLLSPzVRqdHlM9_-9Cw',
#    'alias': 'four-corners-cafe-london-2',
#    'name': 'Four Corners Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rq5jjv5YtDdYt9HJQ8OyEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/four-corners-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5003689, 'longitude': -0.1135442},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '12 Lower Marsh',
#     'address2': 'Waterloo',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Lower Marsh',
#      'Waterloo',
#      'London SE1 7RJ',
#      'United Kingdom']},
#    'phone': '+442086179591',
#    'display_phone': '+44 20 8617 9591',
#    'distance': 2080.282557645936},
#   {'id': 'QF8HaEPzqS4OJBY3SYrCGw',
#    'alias': 'chatica-cafe-deli-and-bakery-london',
#    'name': 'Chatica Cafe Deli & Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pkX4PFKzkNWKEjpVHfvTNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chatica-cafe-deli-and-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.50505, 'longitude': -0.08752},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '2 Elephant Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE17 1LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Elephant Road',
#      'London SE17 1LA',
#      'United Kingdom']},
#    'phone': '+442072774485',
#    'display_phone': '+44 20 7277 4485',
#    'distance': 3462.0724628619355},
#   {'id': 'zOcwqHpSKnEMonZxrJiM4g',
#    'alias': 'pierre-herme-london-3',
#    'name': 'Pierre Herme',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Nc09C3ZpQuv-nhhCRquS-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pierre-herme-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5134164873925,
#     'longitude': -0.127191884385164},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '38 Monmouth Street',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38 Monmouth Street',
#      'Covent Garden',
#      'London WC2H 9EP',
#      'United Kingdom']},
#    'phone': '+442072408653',
#    'display_phone': '+44 20 7240 8653',
#    'distance': 609.8985619204582},
#   {'id': 'UxuxEoIWnQQNPMdNzBJPJQ',
#    'alias': 'mariage-freres-london',
#    'name': 'Mariage Freres',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Efdu-Oz-hL1XJC_SygBoNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mariage-freres-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5118571, 'longitude': -0.1243388},
#    'transactions': [],
#    'location': {'address1': '38 King Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2E 8JS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38 King Street',
#      'London WC2E 8JS',
#      'United Kingdom']},
#    'phone': '+442078361854',
#    'display_phone': '+44 20 7836 1854',
#    'distance': 815.2586931885163},
#   {'id': 'E_3NekwxctQ3BzN7tLKk2A',
#    'alias': 'casa-tua-london-2',
#    'name': 'Casa Tua',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m7FJ2XmVjJQ-Sx0umK6pmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-tua-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5276449011142,
#     'longitude': -0.123588235886524},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '106 Cromer Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 8BZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['106 Cromer Street',
#      'London WC1H 8BZ',
#      'United Kingdom']},
#    'phone': '+442078331483',
#    'display_phone': '+44 20 7833 1483',
#    'distance': 1855.7864052166005},
#   {'id': 'IFx29LvkxdZx8pTp-JrvnA',
#    'alias': 'l-eto-caffe-london-3',
#    'name': "L'eto Caffe",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/102DdjCIFtBYllWCYwlo2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-eto-caffe-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4987685, 'longitude': -0.1570349},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10 W Halkin Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 8JL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 W Halkin Street',
#      'London SW1X 8JL',
#      'United Kingdom']},
#    'phone': '+442072356415',
#    'display_phone': '+44 20 7235 6415',
#    'distance': 2138.947633367185},
#   {'id': 'Kfs_IcuEG0XgeAokAOIxsg',
#    'alias': 'pophams-bakery-london',
#    'name': 'Pophams Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OmiEGvQpplSHwBqNDBjADw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pophams-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5365399339192,
#     'longitude': -0.096091953563201},
#    'transactions': [],
#    'location': {'address1': '19 Prebend Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N1 8PF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Prebend Street',
#      'London N1 8PF',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3814.901749335446},
#   {'id': 'eekflLQwzpeZ9sNg89F38A',
#    'alias': 'jakobs-london',
#    'name': 'Jakobs',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/m797XQr64brTgRK7TdrqPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jakobs-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.49905885109, 'longitude': -0.18382193239086},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Gloucester Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 4RB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Gloucester Road',
#      'London SW7 4RB',
#      'United Kingdom']},
#    'phone': '+442075819292',
#    'display_phone': '+44 20 7581 9292',
#    'distance': 3649.913506628403},
#   {'id': 'OqcvGls-xA8gIxSGANbNCg',
#    'alias': 'paul-london-40',
#    'name': 'Paul',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y8Ddm2leQcu_ISW1aaUh_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-london-40?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5063536827166,
#     'longitude': -0.10055633116723},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 4 Blue Fin Building',
#     'address2': '16 Sumner Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9JZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 4 Blue Fin Building',
#      '16 Sumner Street',
#      'London SE1 9JZ',
#      'United Kingdom']},
#    'phone': '+442079283946',
#    'display_phone': '+44 20 7928 3946',
#    'distance': 2553.6719822766536}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#            Restaurant          Type Price Rating            Address  \
# 0       My Place Soho         Cafes    ££    4.5  21 Berwick Street
# 1          Santa Nata      Desserts                   17 Russell St
# 2             Ladurée  Delicatessen   £££      4   87 Brompton Road
# 3  The Pastry Parlour  Coffee & Tea                 47 Gower's Walk
# 4      The Breadstall      Bakeries    ££      5     Northcote Road
#
#          Lat       Lng                                                url  \
# 0  51.513841 -0.134690  https://www.yelp.com/biz/my-place-soho-london?...
# 1  51.512495 -0.121869
# 2  51.498485 -0.162618  https://www.yelp.com/biz/ladur%C3%A9e-london-8...
# 3  51.513737 -0.067745
# 4  51.456328 -0.165136  https://www.yelp.com/biz/the-breadstall-london...
#
#                        ID
# 0  fp5po-wno5RLU4Rz0q0h-w
# 1
# 2  x5vg6DMQQjiuZ2SQVKhIAg
# 3
# 4  mnRiHkVxRxL70m5IL1ReMw

# %%
#4th set of 50 records 151-200
lndr_params4 = {"term":"pastry","location":"London","limit":50,"offset":151}
lndr_response4 = requests.get(search_api_url, headers=headers, params=lndr_params4)
lndr4 = lndr_response4.json()
display(lndr4)
#print(lndr_response4.url)
#print(lndr_response4.status_code)
# Out:
# {'businesses': [{'id': 'eekflLQwzpeZ9sNg89F38A',
#    'alias': 'jakobs-london',
#    'name': 'Jakobs',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/m797XQr64brTgRK7TdrqPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jakobs-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.49905885109, 'longitude': -0.18382193239086},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Gloucester Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 4RB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Gloucester Road',
#      'London SW7 4RB',
#      'United Kingdom']},
#    'phone': '+442075819292',
#    'display_phone': '+44 20 7581 9292',
#    'distance': 3649.913506628403},
#   {'id': '5sastzP0XG9cG5b38ndZFQ',
#    'alias': 'brownie-box-london',
#    'name': 'Brownie Box',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZkA-tlRlR0dINMpiljb3PQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brownie-box-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.489143371582,
#     'longitude': -0.190696999430656},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '247 Old Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 9HP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['247 Old Brompton Road',
#      'London SW5 9HP',
#      'United Kingdom']},
#    'phone': '+442073739111',
#    'display_phone': '+44 20 7373 9111',
#    'distance': 4614.687955887362},
#   {'id': 'bCkjiJ6wM3vFBebsu9PtgA',
#    'alias': 'paul-london-15',
#    'name': 'Paul',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zy_E0CLCix71BtVP4AYr0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-london-15?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.519155, 'longitude': -0.156502},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '55 Baker Street',
#     'address2': 'Unit 65',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 8EW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55 Baker Street',
#      'Unit 65',
#      'London W1U 8EW',
#      'United Kingdom']},
#    'phone': '+442074860626',
#    'display_phone': '+44 20 7486 0626',
#    'distance': 1585.892296168721},
#   {'id': 'a_sNW8UVd7O_-rjJQaov4g',
#    'alias': 'west-cornwall-pasty-london-5',
#    'name': 'West Cornwall Pasty',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/n2iiqUCy2dZVHh4KQxvk2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/west-cornwall-pasty-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4801748, 'longitude': -0.1949885},
#    'transactions': [],
#    'location': {'address1': 'Fulham Broadway Station',
#     'address2': '470 Fulham Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 1BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Fulham Broadway Station',
#      '470 Fulham Road',
#      'London SW6 1BY',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5455.152943090924},
#   {'id': '6DwwLF424xP7VTPNznVTYQ',
#    'alias': 'gails-bakery-st-johns-wood-london-3',
#    'name': "GAIL's Bakery St John's Wood",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5a-7-59lbasf11p0XdO5ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-st-johns-wood-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5336595, 'longitude': -0.171694},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5 Circus Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 6NX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Circus Road', 'London NW8 6NX', 'United Kingdom']},
#    'phone': '+442077220983',
#    'display_phone': '+44 20 7722 0983',
#    'distance': 3390.2048284682287},
#   {'id': 'X0Bw6wgjhmAZraXvPdLELQ',
#    'alias': 'notes-london-4',
#    'name': 'Notes',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2n4_s5u-BgN4-zKSUhwamw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/notes-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 101,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5095536, 'longitude': -0.1267229},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "31 St Martin's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["31 St Martin's Lane",
#      'London WC2N 4ER',
#      'United Kingdom']},
#    'phone': '+442072400424',
#    'display_phone': '+44 20 7240 0424',
#    'distance': 730.1254826123966},
#   {'id': 'X8UxGRF_ju6cfIB2fZizqQ',
#    'alias': 'old-post-office-bakery-london',
#    'name': 'Old Post Office Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VvgStDUrKexM7fTdbDSPeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/old-post-office-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.465915224149,
#     'longitude': -0.12510033116717},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '76 Landor Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 9PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['76 Landor Road', 'London SW9 9PH', 'United Kingdom']},
#    'phone': '+442073264408',
#    'display_phone': '+44 20 7326 4408',
#    'distance': 5271.15208095644},
#   {'id': '68gc1BAE1IT_zZghFafw0Q',
#    'alias': 'ozone-coffee-london-2',
#    'name': 'Ozone Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FMKfpA6gKHlDAKDuPVVdTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ozone-coffee-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 188,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.524683689256,
#     'longitude': -0.086674106560876},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Leonard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 4AQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Leonard Street',
#      'London EC2A 4AQ',
#      'United Kingdom']},
#    'phone': '+442074901039',
#    'display_phone': '+44 20 7490 1039',
#    'distance': 3655.552919913525},
#   {'id': 'jrRKp4dsl9uTQjBb0uBbfw',
#    'alias': 'pimlico-fresh-london',
#    'name': 'Pimlico Fresh',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pxjxkpfArqkdyAaBJwaWZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pimlico-fresh-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 154,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.492391374275,
#     'longitude': -0.14021524722041},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '85 Wilton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1DE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['85 Wilton Road',
#      'London SW1V 1DE',
#      'United Kingdom']},
#    'phone': '+442079320030',
#    'display_phone': '+44 20 7932 0030',
#    'distance': 2292.321028443847},
#   {'id': 'yemHrQ_ihk3trlQN3gKGoQ',
#    'alias': 'brick-house-east-dulwich',
#    'name': 'Brick House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rUJaJI7xb3hmgyQ_1g11Vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brick-house-east-dulwich?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4602410231235,
#     'longitude': -0.0757133133748053},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '1 Zenoria Street',
#     'address2': '',
#     'address3': '',
#     'city': 'East Dulwich',
#     'zip_code': 'SE22 8HP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Zenoria Street',
#      'East Dulwich SE22 8HP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 7183.390129362812},
#   {'id': 'muxCRMUqHY63jE0wavLG7w',
#    'alias': 'violet-cakes-london',
#    'name': 'Violet Cakes',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/S9OZXaf_jMG4rEiNxuA-5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/violet-cakes-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.545469478641,
#     'longitude': -0.064133277339768},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '47 Wilton Way',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 3ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Wilton Way', 'London E8 3ED', 'United Kingdom']},
#    'phone': '+442072758360',
#    'display_phone': '+44 20 7275 8360',
#    'distance': 6152.4531923363975},
#   {'id': 'VoN5pEsu3kre_EJ0ARro7g',
#    'alias': 'benugo-london-20',
#    'name': 'Benugo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6-wglJFFeSKfbIBxQUtn4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/benugo-london-20?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5149431, 'longitude': -0.0681656},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '33 Commercial Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 1LD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['33 Commercial Road',
#      'London E1 1LD',
#      'United Kingdom']},
#    'phone': '+442076554857',
#    'display_phone': '+44 20 7655 4857',
#    'distance': 4696.884775271177},
#   {'id': 'O-a4dCQH0ylxYt8pnA4byQ',
#    'alias': 'patisserie-valerie-london-48',
#    'name': 'Patisserie Valerie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/x4I-J-10Q0AYl4QRWLbuMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-valerie-london-48?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5105155, 'longitude': -0.1244745},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '15 Bedford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2 9HE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Bedford Street',
#      'London WC2 9HE',
#      'United Kingdom']},
#    'phone': '+442073796428',
#    'display_phone': '+44 20 7379 6428',
#    'distance': 828.5788819219546},
#   {'id': 'bdUsmRcJUe29Ssa-osjjDA',
#    'alias': 'paul-covent-garden-le-restaurant-de-paul-london',
#    'name': 'PAUL Covent Garden Le Restaurant de Paul',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8MxPbMCH5oHXQhMaReQpAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-covent-garden-le-restaurant-de-paul-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511152, 'longitude': -0.124783},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '29 Bedford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 9ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['29 Bedford Street',
#      'London WC2E 9ED',
#      'United Kingdom']},
#    'phone': '+442078363304',
#    'display_phone': '+44 20 7836 3304',
#    'distance': 795.521850531159},
#   {'id': 'L5bYiNsHg-hKJraeFXBSYA',
#    'alias': 'baker-and-spice-london-2',
#    'name': 'Baker & Spice',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nnqOqLOXyhgiq2lOvBhPqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baker-and-spice-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4939913, 'longitude': -0.164682},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '47 Denyer Street',
#     'address2': '',
#     'address3': 'Chelsea',
#     'city': 'London',
#     'zip_code': 'SW3 2LX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Denyer Street',
#      'Chelsea',
#      'London SW3 2LX',
#      'United Kingdom']},
#    'phone': '+442075894734',
#    'display_phone': '+44 20 7589 4734',
#    'distance': 2883.911010904249},
#   {'id': 'c9fsJoggr23sL-VcEHbo7g',
#    'alias': 'paul-tregeser-london-2',
#    'name': 'Paul Tregeser',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-tregeser-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.527797, 'longitude': -0.196849},
#    'transactions': [],
#    'location': {'address1': '203 Shirland Road W',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W9 2EX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['203 Shirland Road W',
#      'London W9 2EX',
#      'United Kingdom']},
#    'phone': '+442073289838',
#    'display_phone': '+44 20 7328 9838',
#    'distance': 4536.228521842293},
#   {'id': 'LyXXTUzll212_JKMkzC3DQ',
#    'alias': '49-cafe-london',
#    'name': '49 Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PWsAaKgpDIo7aF9k5n6qjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/49-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5249587, 'longitude': -0.1251605},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '49 Marchmont Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 1AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Marchmont Street',
#      'London WC1N 1AP',
#      'United Kingdom']},
#    'phone': '+442035383474',
#    'display_phone': '+44 20 3538 3474',
#    'distance': 1541.1440285471679},
#   {'id': 'MOZ3X-asf3FZEOE39966-A',
#    'alias': 'fork-deli-patisserie-london',
#    'name': 'Fork Deli Patisserie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XxhA1i9wZc8qLnP6JA8L0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fork-deli-patisserie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5258331, 'longitude': -0.1258274},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '85 Marchmont Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 1AL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['85 Marchmont Street',
#      'London WC1N 1AL',
#      'United Kingdom']},
#    'phone': '+442073872860',
#    'display_phone': '+44 20 7387 2860',
#    'distance': 1609.3072196936705},
#   {'id': 'mOD60RafvMIEv0PR0QqV-g',
#    'alias': 'the-rosebery-lounge-london',
#    'name': 'The Rosebery Lounge',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/s_HF9blFPjxAvkRh1lVC2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-rosebery-lounge-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.502405, 'longitude': -0.159971},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '66 Knightsbridge',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Knightsbridge',
#      'London SW1X 7LA',
#      'United Kingdom']},
#    'phone': '+442072013828',
#    'display_phone': '+44 20 7201 3828',
#    'distance': 2037.494114265099},
#   {'id': 'D21Iu0qiqjvFWVHgs3JyhQ',
#    'alias': 'gails-bakery-belsize-park-london-3',
#    'name': "GAIL's Bakery Belsize Park",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jqcgg0pmWxxIVr0scFJk5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-belsize-park-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5498302, 'longitude': -0.1646677},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '167 Haverstock Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 4QT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['167 Haverstock Hill',
#      'London NW3 4QT',
#      'United Kingdom']},
#    'phone': '+442075864399',
#    'display_phone': '+44 20 7586 4399',
#    'distance': 4567.9706806328195},
#   {'id': '1kTiW_C-WQbebTCqkV6xYg',
#    'alias': 'camden-coffee-shop-london',
#    'name': 'Camden Coffee Shop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5rRQALuKN9v6BPrXOqHwfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camden-coffee-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.536842323903,
#     'longitude': -0.14207936959551},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '11 Delancey Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 7NL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Delancey Street',
#      'London NW1 7NL',
#      'United Kingdom']},
#    'phone': '+442073874080',
#    'display_phone': '+44 20 7387 4080',
#    'distance': 2702.839238520007},
#   {'id': 'x58LDkXGU7vC8-KRDlS9Mw',
#    'alias': 'raison-d-etre-london',
#    'name': "Raison D'Etre",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GNL9SAtkBRabO34z0GOmqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raison-d-etre-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.493706018346,
#     'longitude': -0.17628170716244},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '18 Bute Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3EX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Bute Street', 'London SW7 3EX', 'United Kingdom']},
#    'phone': '+442075845008',
#    'display_phone': '+44 20 7584 5008',
#    'distance': 3509.3036349562817},
#   {'id': 'S3h8uhI3wK2Fn4e9gw9bfA',
#    'alias': 'shoreditch-grind-london',
#    'name': 'Shoreditch Grind',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wcWCxMuAey7jvjK6_m5TIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shoreditch-grind-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 116,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5258391235513,
#     'longitude': -0.0879659656067133},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '213 Old Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 9NR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['213 Old Street',
#      'London EC1V 9NR',
#      'United Kingdom']},
#    'phone': '+442074907490',
#    'display_phone': '+44 20 7490 7490',
#    'distance': 3621.631922482148},
#   {'id': '3ViNQObKHR6l02hkvBFClw',
#    'alias': 'mimos-cafe-london',
#    'name': 'Mimos Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/k6WfcS61Er3U5TxjAdvcNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mimos-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 85,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5150959, 'longitude': -0.174005},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '19 London Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 London Street',
#      'London W2 1HL',
#      'United Kingdom']},
#    'phone': '+442077067175',
#    'display_phone': '+44 20 7706 7175',
#    'distance': 2647.9526940777378},
#   {'id': '5H4EEA8Sdqy1L_xFY9xSUw',
#    'alias': 'white-mulberries-london',
#    'name': 'White Mulberries',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IMvRHPQJRmhhvlkLW5uJVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/white-mulberries-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.507252, 'longitude': -0.071157},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit D3',
#     'address2': 'Ivory House',
#     'address3': 'St Katharine Docks',
#     'city': 'London',
#     'zip_code': 'E1W 1AT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit D3',
#      'Ivory House',
#      'St Katharine Docks',
#      'London E1W 1AT',
#      'United Kingdom']},
#    'phone': '+447507572600',
#    'display_phone': '+44 7507 572600',
#    'distance': 4527.184767844278},
#   {'id': 'YZIsogwDym4uAgoAH3bQUw',
#    'alias': 'beehive-london-4',
#    'name': 'Beehive',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XonTWExprcY09ipinpTZTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beehive-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.491655, 'longitude': -0.2556941},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '28 Devonshire Road',
#     'address2': 'Chiswick',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W4 2HD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28 Devonshire Road',
#      'Chiswick',
#      'London W4 2HD',
#      'United Kingdom']},
#    'phone': '+442089948628',
#    'display_phone': '+44 20 8994 8628',
#    'distance': 8616.05744964085},
#   {'id': 'DI3mIVje3_Ntw_Dke96Odw',
#    'alias': 'cockney-pie-and-mash-shop-london',
#    'name': 'Cockney Pie & Mash Shop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6zYaOys3i3j593VcWI4kKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cockney-pie-and-mash-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5212598, 'longitude': -0.209793},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '314 Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W10 5RU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['314 Portobello Road',
#      'London W10 5RU',
#      'United Kingdom']},
#    'phone': '+442089609409',
#    'display_phone': '+44 20 8960 9409',
#    'distance': 5191.350460440984},
#   {'id': '2Ffr8Fs_OlGQqxT7TN_nJg',
#    'alias': 'lundenwic-london-2',
#    'name': 'Lundenwic',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UxlKEsPg6r_m9lpmyS95nQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lundenwic-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5129, 'longitude': -0.118617},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '45 Aldwych',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 4DW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Aldwych', 'London WC2B 4DW', 'United Kingdom']},
#    'phone': '+447921911068',
#    'display_phone': '+44 7921 911068',
#    'distance': 1199.8817944620134},
#   {'id': 'nHMn6sJQEj1c2cnGThyvvg',
#    'alias': 'harrods-food-hall-london',
#    'name': 'Harrods Food Hall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lTez1h3O4WyMt5kA4i8FBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harrods-food-hall-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 325,
#    'categories': [{'alias': 'cheese', 'title': 'Cheese Shops'},
#     {'alias': 'wineries', 'title': 'Wineries'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4990917420527,
#     'longitude': -0.162348972665107},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '87-135 Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7XL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['87-135 Brompton Road',
#      'London SW1X 7XL',
#      'United Kingdom']},
#    'phone': '+442077301234',
#    'display_phone': '+44 20 7730 1234',
#    'distance': 2381.6721756016004},
#   {'id': 'IEGYMW3nc-dTtOicVJ0AWw',
#    'alias': 'caffe-concerto-london-20',
#    'name': 'Caffe Concerto',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tVlEmmD6ad_7JNGOlFPGhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-concerto-london-20?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5070957, 'longitude': -0.1265794},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4-5 Northumberland Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 5BW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4-5 Northumberland Avenue',
#      'London WC2N 5BW',
#      'United Kingdom']},
#    'phone': '+442074949750',
#    'display_phone': '+44 20 7494 9750',
#    'distance': 892.5834488549697},
#   {'id': 'kpNbaGRBwC3I7OPqQNqimg',
#    'alias': 'chapter-coffee-roasters-london',
#    'name': 'Chapter Coffee Roasters',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UVLvJzPYoo_SGts9nPsfEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chapter-coffee-roasters-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4919847, 'longitude': -0.2071349},
#    'transactions': [],
#    'location': {'address1': '137 North End Road',
#     'address2': 'West Kensington',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W14 8XU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['137 North End Road',
#      'West Kensington',
#      'London W14 8XU',
#      'United Kingdom']},
#    'phone': '+442038753655',
#    'display_phone': '+44 20 3875 3655',
#    'distance': 5445.057639939854},
#   {'id': 'klqP4NUFEl9kA6DIyRHpjA',
#    'alias': 'little-bread-pedlar-london',
#    'name': 'Little Bread Pedlar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/c8tHh4TWUFb98oD65Gfing/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-bread-pedlar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4955192, 'longitude': -0.0692471},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 5',
#     'address2': 'Dockley Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE16 3SF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 5',
#      'Dockley Road',
#      'London SE16 3SF',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5002.583314102826},
#   {'id': 'k7qmLDOGfESN8fDBQZZL7w',
#    'alias': '106-baker-st-london',
#    'name': '106 Baker St',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9CXBPhU2Ib_gv7QmtYAMCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/106-baker-st-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5207977, 'longitude': -0.1566825},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '106 Baker Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 6TW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['106 Baker Street',
#      'London W1U 6TW',
#      'United Kingdom']},
#    'phone': '+442074873372',
#    'display_phone': '+44 20 7487 3372',
#    'distance': 1689.8849777286025},
#   {'id': 'btmD6I6XuFIngdLZtWAjTg',
#    'alias': 'fait-maison-london-4',
#    'name': 'Fait Maison',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7rXjacFCZl5eGwgJdhgQNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fait-maison-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4937304, 'longitude': -0.1823091},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '144 Gloucester Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 4QT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['144 Gloucester Road',
#      'London SW7 4QT',
#      'United Kingdom']},
#    'phone': '+442034905585',
#    'display_phone': '+44 20 3490 5585',
#    'distance': 3850.3388919213453},
#   {'id': '4SG-pRroQ3Wyo-qlgMDZxA',
#    'alias': 'thames-foyer-london',
#    'name': 'Thames Foyer',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kzar0GTepLkuB6zZruLMqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thames-foyer-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.510397, 'longitude': -0.120741},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'Strand The Savoy',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2R 0EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Strand The Savoy',
#      'London WC2R 0EU',
#      'United Kingdom']},
#    'phone': '+442074202111',
#    'display_phone': '+44 20 7420 2111',
#    'distance': 1087.2604659388765},
#   {'id': 'fM99pmX2-ipWvG33tILdZQ',
#    'alias': 'franze-and-evans-cafe-shoreditch-london-2',
#    'name': 'Franze & Evans Cafe Shoreditch',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GXigHW3dfzZ42TB_8cvOvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/franze-and-evans-cafe-shoreditch-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5248675, 'longitude': -0.0726335},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '101 Redchurch St',
#     'address2': 'Shoreditch',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['101 Redchurch St',
#      'Shoreditch',
#      'London E2 7DL',
#      'United Kingdom']},
#    'phone': '+442070331910',
#    'display_phone': '+44 20 7033 1910',
#    'distance': 4581.098657661117},
#   {'id': 'REhb-qBL9hkXyoec71arhA',
#    'alias': 'cafe-de-nata-fulham',
#    'name': 'Cafe de Nata',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eSdt5vR9DJKjaOvyepPg9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-de-nata-fulham?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'portuguese', 'title': 'Portuguese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.492014, 'longitude': -0.224198},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '25b Broadway Shopping Centre W',
#     'address2': 'Hammersmith Broadway',
#     'address3': None,
#     'city': 'Fulham',
#     'zip_code': 'W6 9YD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['25b Broadway Shopping Centre W',
#      'Hammersmith Broadway',
#      'Fulham W6 9YD',
#      'United Kingdom']},
#    'phone': '+442088347555',
#    'display_phone': '+44 20 8834 7555',
#    'distance': 6531.920748923603},
#   {'id': 'WviWKTmXpSZWv7Pdt_7RyQ',
#    'alias': 'pompidou-cafe-london',
#    'name': 'Pompidou Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZvIwYIvwIJxnuX9XCIW8CQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pompidou-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5310148, 'longitude': -0.1213579},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '284 Pentonville Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9NR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['284 Pentonville Road',
#      'London N1 9NR',
#      'United Kingdom']},
#    'phone': '+442072787677',
#    'display_phone': '+44 20 7278 7677',
#    'distance': 2252.1800220171363},
#   {'id': 'tcVWoHSko9PIy_Ec95_j1A',
#    'alias': 'candella-tea-room-london',
#    'name': 'Candella Tea Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VU1iZ4XuPbqFlUuaTFe6cg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/candella-tea-room-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5040735504425,
#     'longitude': -0.192011632025242},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '34 Kensington Church Street',
#     'address2': 'High Street',
#     'address3': 'Kensington',
#     'city': 'London',
#     'zip_code': 'W8 4HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['34 Kensington Church Street',
#      'High Street',
#      'Kensington',
#      'London W8 4HA',
#      'United Kingdom']},
#    'phone': '+442079374161',
#    'display_phone': '+44 20 7937 4161',
#    'distance': 3999.955512224944},
#   {'id': 'TB31gU2v3mFZphYYN-xecg',
#    'alias': 'boxcar-baker-and-deli-london',
#    'name': 'Boxcar Baker & Deli',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uZ_uXO8zbbKVRM61J0D9lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boxcar-baker-and-deli-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5195266, 'longitude': -0.161565},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '7A Wyndham Place',
#     'address2': 'Marylebone',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 1PN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7A Wyndham Place',
#      'Marylebone',
#      'London W1H 1PN',
#      'United Kingdom']},
#    'phone': '+442030067000',
#    'display_phone': '+44 20 3006 7000',
#    'distance': 1920.25121063196},
#   {'id': 'DXMoezQ1WxA-lzvSNPg6Og',
#    'alias': 'd1-coffee-little-venice',
#    'name': 'D1 Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mOMm9erE16oTv2gxuM4sjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/d1-coffee-little-venice?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5248684, 'longitude': -0.1763357},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Aberdeen Place',
#     'address2': '',
#     'address3': '',
#     'city': 'Little Venice',
#     'zip_code': 'NW8 8JN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Aberdeen Place',
#      'Little Venice NW8 8JN',
#      'United Kingdom']},
#    'phone': '+442077233337',
#    'display_phone': '+44 20 7723 3337',
#    'distance': 3097.807873394816},
#   {'id': 'sseI7FWOxOMOCZgmLC-_mg',
#    'alias': 'the-kennington-coffee-shop-london',
#    'name': 'The Kennington Coffee Shop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AwQj9ZEAX8hm6b0Q-N2NJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-kennington-coffee-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4927224, 'longitude': -0.1104432},
#    'transactions': [],
#    'location': {'address1': '173 Kennington Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE11 6QR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['173 Kennington Road',
#      'London SE11 6QR',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2849.5910012475033},
#   {'id': 'cFCAYrs6LX17ucDFEWMXLg',
#    'alias': 'mihbaj-café-and-kitchen-london',
#    'name': 'Mihbaj Café & Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5g5DVb2Q7z4gmXG3AtDbOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mihbaj-caf%C3%A9-and-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.516163, 'longitude': -0.1744713},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '153 Praed Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['153 Praed Street',
#      'London W2 1RL',
#      'United Kingdom']},
#    'phone': '+442077063063',
#    'display_phone': '+44 20 7706 3063',
#    'distance': 2690.7690001080196},
#   {'id': 'zDNPxXhBZ5PHxOFEDNBvBw',
#    'alias': 'borneo-cafe-and-bakery-london',
#    'name': 'Borneo Cafe & Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SUKAjhyo3DhiACmt3RHXVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/borneo-cafe-and-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.6091035627186,
#     'longitude': -0.11024683713913},
#    'transactions': [],
#    'location': {'address1': '29A Green Lanes',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N13 4TN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['29A Green Lanes',
#      'London N13 4TN',
#      'United Kingdom']},
#    'phone': '+447588051351',
#    'display_phone': '+44 7588 051351',
#    'distance': 10851.032005427694},
#   {'id': 'P4rFlCsevSiJuwshO6wF7g',
#    'alias': 'simit-sarayi-london-4',
#    'name': 'Simit Sarayi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BAUChxLMzEtvN5I5MF8dgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/simit-sarayi-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5104, 'longitude': -0.1339005},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '1 Piccadilly Circus',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 0DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Piccadilly Circus',
#      'London W1J 0DA',
#      'United Kingdom']},
#    'phone': '+442076364636',
#    'display_phone': '+44 20 7636 4636',
#    'distance': 305.8958542761565},
#   {'id': 'Q2x1Tq3GF9ZHFwA4a8LR4w',
#    'alias': 'the-paprika-store-london',
#    'name': 'The Paprika Store',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/unDNN74YDS1ShA8oXbkSCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-paprika-store-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'importedfood', 'title': 'Imported Food'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.579104, 'longitude': -0.098913},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '50 Grand Parade',
#     'address2': 'Green Lanes',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N4 1AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50 Grand Parade',
#      'Green Lanes',
#      'London N4 1AG',
#      'United Kingdom']},
#    'phone': '+442036459092',
#    'display_phone': '+44 20 3645 9092',
#    'distance': 7801.2389630233},
#   {'id': '0mPYAPkojho-XLcIIPiY8Q',
#    'alias': 'barista-and-baker-london',
#    'name': 'Barista & Baker',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9QvxPAmcdqAA-xA73tqxwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barista-and-baker-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4983696638885,
#     'longitude': -0.104033751512027},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '6 St Georges Circus',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 6LF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 St Georges Circus',
#      'London SE1 6LF',
#      'United Kingdom']},
#    'phone': '+447815703342',
#    'display_phone': '+44 7815 703342',
#    'distance': 2732.9010728233598},
#   {'id': 'Qk9CwHdpFgYo1Za77yfPtQ',
#    'alias': 'l-eto-caffe-london-6',
#    'name': "L'eto Caffe",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1FQ30FQP3kvrI5A8NXId9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-eto-caffe-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.48794, 'longitude': -0.167225},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "149 King's Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 5TX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["149 King's Road",
#      'London SW3 5TX',
#      'United Kingdom']},
#    'phone': '+442073517656',
#    'display_phone': '+44 20 7351 7656',
#    'distance': 3513.9797015942327},
#   {'id': 'qnzpTVsWxTnxRoOG_sh-pQ',
#    'alias': 'le-pain-quotidien-london',
#    'name': 'Le Pain Quotidien',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QZfiA9_-F6zisPqE11Xqpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-pain-quotidien-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.521258, 'longitude': -0.152221},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '72-75 Marylebone High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 5JW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['72-75 Marylebone High Street',
#      'London W1U 5JW',
#      'United Kingdom']},
#    'phone': '+442036576949',
#    'display_phone': '+44 20 3657 6949',
#    'distance': 1455.6081489902765},
#   {'id': 'WiM-U0SxQS8w4Js4QTpsgw',
#    'alias': 'manna-dew-london',
#    'name': 'Manna Dew',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mJ-aw-qOvTXtw0afRPxiFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/manna-dew-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.470635, 'longitude': -0.172092},
#    'transactions': [],
#    'location': {'address1': '169 Battersea High Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW11 3JS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['169 Battersea High Street',
#      'London SW11 3JS',
#      'United Kingdom']},
#    'phone': '+447503200020',
#    'display_phone': '+44 7503 200020',
#    'distance': 5310.551397551676}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#                      Restaurant           Type Price Rating  \
# 0                        Jakobs  Mediterranean    ££      5
# 1                   Brownie Box       Desserts     £    4.5
# 2                          Paul       Bakeries     £      4
# 3           West Cornwall Pasty       Bakeries
# 4  GAIL's Bakery St John's Wood       Bakeries    ££      4
#
#                    Address        Lat       Lng  \
# 0       20 Gloucester Road  51.499059 -0.183822
# 1    247 Old Brompton Road  51.489143 -0.190697
# 2          55 Baker Street  51.519155 -0.156502
# 3  Fulham Broadway Station  51.480175 -0.194989
# 4            5 Circus Road  51.533659 -0.171694
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/jakobs-london?adjust_...  eekflLQwzpeZ9sNg89F38A
# 1  https://www.yelp.com/biz/brownie-box-london?ad...  5sastzP0XG9cG5b38ndZFQ
# 2  https://www.yelp.com/biz/paul-london-15?adjust...  bCkjiJ6wM3vFBebsu9PtgA
# 3
# 4  https://www.yelp.com/biz/gails-bakery-st-johns...  6DwwLF424xP7VTPNznVTYQ

# %%
london_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
london_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_restaurants_df = london_restaurants_df[column_order]
london_restaurants_df = london_restaurants_df.sort_values(["Type"], ascending=True)
london_restaurants_df = london_restaurants_df.reset_index(drop=True)
london_restaurants_df
# Out:
#                                    Restaurant                   Type Rating  \
# 0                                    Carmelli                 Bagels      4
# 1                             Sunflour Bakery               Bakeries    4.5
# 2                              The Breadstall               Bakeries      5
# 3                           Kastner and Ovens               Bakeries    4.5
# 4                                  Ottolenghi               Bakeries      4
# 5                            Le Deli Robuchon               Bakeries
# 6                             Konditor & Cook               Bakeries    4.5
# 7                                Maison Ruget               Bakeries
# 8                                 Beigel Bake               Bakeries      4
# 9                                      Popina               Bakeries
# 10                                   Laurents               Bakeries    4.5
# 11                          The Butter Bakery               Bakeries    4.5
# 12                       Pâtisserie Deux Amis               Bakeries      4
# 13                                       Paul               Bakeries    4.5
# 14                     PAUL - Gloucester Road               Bakeries    4.5
# 15                          Maroush Bakehouse               Bakeries    4.5
# 16                           Chinatown Bakery               Bakeries      4
# 17                              Baker & Spice               Bakeries      4
# 18                                       Paul               Bakeries      4
# 19                  Dominique Ansel Treehouse               Bakeries
# 20                    GAIL's Bakery - Pimlico               Bakeries
# 21                    GAIL's Bakery Hampstead               Bakeries    4.5
# 22                       Borneo Cafe & Bakery               Bakeries
# 23                        Boxcar Baker & Deli               Bakeries      4
# 24                        Little Bread Pedlar               Bakeries      4
# 25                 GAIL's Bakery Belsize Park               Bakeries    3.5
# 26                              Paul Tregeser               Bakeries
# 27                              Baker & Spice               Bakeries      4
# 28                     Old Post Office Bakery               Bakeries    4.5
# 29               GAIL's Bakery St John's Wood               Bakeries      4
# ..                                        ...                    ...    ...
# 170                                      Paul                 French      4
# 171                          Hotel Café Royal                 Hotels    4.5
# 172                         The Paprika Store          Imported Food      5
# 173       Phoenicia - Mediterranean Food Hall  International Grocery      4
# 174                                    Princi                Italian      4
# 175                            Caffe Concerto                Italian      3
# 176                                   Laduree               Macarons    4.5
# 177                                    Jakobs          Mediterranean      5
# 178                                    Jakobs          Mediterranean      5
# 179                                   49 Cafe        Modern European    4.5
# 180                        Patisserie Valerie   Patisserie/Cake Shop      4
# 181                        Patisserie Valerie   Patisserie/Cake Shop      4
# 182                     Golden Gate Cake Shop   Patisserie/Cake Shop      4
# 183            Franze & Evans Cafe Shoreditch   Patisserie/Cake Shop      4
# 184                        Patisserie Valerie   Patisserie/Cake Shop      4
# 185                           Fabrique Bakery   Patisserie/Cake Shop      4
# 186                Louis Hungarian Patisserie   Patisserie/Cake Shop      4
# 187                      Wonderful Patisserie   Patisserie/Cake Shop    3.5
# 188                      Fork Deli Patisserie   Patisserie/Cake Shop    4.5
# 189                             Ole and Steen   Patisserie/Cake Shop    4.5
# 190  PAUL Covent Garden Le Restaurant de Paul   Patisserie/Cake Shop      4
# 191                                     Lanka   Patisserie/Cake Shop    4.5
# 192                         Lisboa Patisserie   Patisserie/Cake Shop      4
# 193                              Maitre Choux   Patisserie/Cake Shop    4.5
# 194                  VEGAN SWEET TOOTH London   Patisserie/Cake Shop
# 195                              Cafe de Nata             Portuguese    4.5
# 196                                  Bageriet           Scandinavian    4.5
# 197                         Candella Tea Room              Tea Rooms    4.5
# 198                       The Rosebery Lounge              Tea Rooms    4.5
# 199                              Simit Sarayi                Turkish      3
#
#     Price                         Address        Lat       Lng  \
# 0       £      126-128 Golders Green Road  51.573986 -0.200746
# 1       £             263 Caledonian Road  51.539747 -0.117180
# 2      ££                  Northcote Road  51.456328 -0.165136
# 3       £                52 Floral Street  51.513503 -0.122760
# 4      ££                 63 Ledbury Road  51.514891 -0.199418
# 5                           82 Piccadilly  51.506444 -0.143768
# 6      ££                      9 Bow Lane  51.513083 -0.093669
# 7                     148 Portobello Road  51.514891 -0.204263
# 8       £                  159 Brick Lane  51.524391 -0.071726
# 9                          82 Duke Street  51.513013 -0.150613
# 10      £                  39 Craven Road  51.513468 -0.179164
# 11     ££        219 Westbourne Park Road  51.517790 -0.201469
# 12     ££                  63 Judd Street  51.526409 -0.124060
# 13     ££            185 Earls Court Road  51.492253 -0.192894
# 14      £              73 Gloucester Road  51.494974 -0.182581
# 15     ££            131 Earls Court Road  51.493320 -0.194478
# 16      £                 7 Newport Place  51.512026 -0.129721
# 17     ££          54-56 Elizabeth Street  51.493600 -0.150758
# 18      £               122 Brompton Road  51.499068 -0.165140
# 19                       24 Floral Street  51.511905 -0.125405
# 20                      26 Churton Street  51.491763 -0.139059
# 21     ££        64 Hampstead High Street  51.556122 -0.177963
# 22                        29A Green Lanes  51.609104 -0.110247
# 23     ££                7A Wyndham Place  51.519527 -0.161565
# 24      £                          Unit 5  51.495519 -0.069247
# 25      £             167 Haverstock Hill  51.549830 -0.164668
# 26                    203 Shirland Road W  51.527797 -0.196849
# 27     ££                47 Denyer Street  51.493991 -0.164682
# 28     ££                  76 Landor Road  51.465915 -0.125100
# 29     ££                   5 Circus Road  51.533659 -0.171694
# ..    ...                             ...        ...       ...
# 170     £        Unit 4 Blue Fin Building  51.506354 -0.100556
# 171   £££                68 Regent Street  51.510171 -0.135962
# 172     £                 50 Grand Parade  51.579104 -0.098913
# 173     £      186 -192 Kentish Town Road  51.547598 -0.141266
# 174    ££              135 Wardour Street  51.513863 -0.134387
# 175    ££       4-5 Northumberland Avenue  51.507096 -0.126579
# 176   £££         71-72 Burlington Arcade  51.508357 -0.139577
# 177    ££              20 Gloucester Road  51.499059 -0.183822
# 178    ££              20 Gloucester Road  51.499059 -0.183822
# 179     £             49 Marchmont Street  51.524959 -0.125161
# 180    ££               174-176 Queensway  51.515711 -0.188256
# 181    ££        105 Marylebone High Road  51.519110 -0.151774
# 182     £          13 Macclesfield Street  51.511968 -0.131181
# 183    ££                101 Redchurch St  51.524867 -0.072634
# 184    ££                      York House  51.514271 -0.159456
# 185    ££                8 Earlham Street  51.513464 -0.128402
# 186    ££                 32 Heath Street  51.556057 -0.178585
# 187    ££               45 Gerrard Street  51.511969 -0.130143
# 188     £             85 Marchmont Street  51.525833 -0.125827
# 189    ££                    56 Haymarket  51.509238 -0.132696
# 190    ££               29 Bedford Street  51.511152 -0.124783
# 191    ££             9 Goldhurst Terrace  51.545772 -0.179394
# 192     £                57 Golborne Road  51.522402 -0.207492
# 193   £££                      60 Dean St  51.512714 -0.132232
# 194                                     2  51.397792 -0.094092
# 195     £  25b Broadway Shopping Centre W  51.492014 -0.224198
# 196     £                  24 Rose Street  51.511924 -0.126182
# 197    ££     34 Kensington Church Street  51.504074 -0.192012
# 198   £££                66 Knightsbridge  51.502405 -0.159971
# 199     £             1 Piccadilly Circus  51.510400 -0.133901
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/carmelli-london?adjus...  1iZkMMh1PZnCjQhJLivG3Q
# 1    https://www.yelp.com/biz/sunflour-bakery-londo...  FATOg3vQpgbrl_20WySbqQ
# 2    https://www.yelp.com/biz/the-breadstall-london...  mnRiHkVxRxL70m5IL1ReMw
# 3    https://www.yelp.com/biz/kastner-and-ovens-lon...  HXjHL0L7lqtQQ1KJ0ZKAug
# 4    https://www.yelp.com/biz/ottolenghi-london-3?a...  L-ZNTln24SoU_jYia4M19Q
# 5
# 6    https://www.yelp.com/biz/konditor-and-cook-lon...  uwQVCV7lXyHM2uvwKei-Dw
# 7
# 8    https://www.yelp.com/biz/beigel-bake-london?ad...  CrQcYS4nWWdXmSD1pxf_KA
# 9
# 10   https://www.yelp.com/biz/laurents-london?adjus...  HAi7bThXmEtooc5ZQq9hdw
# 11   https://www.yelp.com/biz/the-butter-bakery-lon...  Sxe2lUli3t_XA5aKYUqqkQ
# 12   https://www.yelp.com/biz/p%C3%A2tisserie-deux-...  7TETeEdYvewlhdjmMSwLdg
# 13   https://www.yelp.com/biz/paul-london-46?adjust...  VQCzUGBY63yVE-FxLg6vqg
# 14   https://www.yelp.com/biz/paul-gloucester-road-...  f4bEfbf1_VyZpLsvlonhMw
# 15   https://www.yelp.com/biz/maroush-bakehouse-lon...  Da8ClETsPknyD-XIam-jbg
# 16   https://www.yelp.com/biz/chinatown-bakery-lond...  uCmXqPY3cOIHxda-HDxB0Q
# 17   https://www.yelp.com/biz/baker-and-spice-londo...  jIuiv7VJkAAM5bRCuKNozg
# 18   https://www.yelp.com/biz/paul-london-3?adjust_...  DUS7Nz3429d2iv0q-Jky9A
# 19
# 20
# 21   https://www.yelp.com/biz/gails-bakery-hampstea...  1OcBgrUzPgp82BfZBUKRow
# 22
# 23   https://www.yelp.com/biz/boxcar-baker-and-deli...  TB31gU2v3mFZphYYN-xecg
# 24   https://www.yelp.com/biz/little-bread-pedlar-l...  klqP4NUFEl9kA6DIyRHpjA
# 25   https://www.yelp.com/biz/gails-bakery-belsize-...  D21Iu0qiqjvFWVHgs3JyhQ
# 26
# 27   https://www.yelp.com/biz/baker-and-spice-londo...  L5bYiNsHg-hKJraeFXBSYA
# 28   https://www.yelp.com/biz/old-post-office-baker...  X8UxGRF_ju6cfIB2fZizqQ
# 29   https://www.yelp.com/biz/gails-bakery-st-johns...  6DwwLF424xP7VTPNznVTYQ
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/paul-london-40?adjust...  OqcvGls-xA8gIxSGANbNCg
# 171  https://www.yelp.com/biz/hotel-caf%C3%A9-royal...  t9-_U2-WmaIee3XDB0Tz0w
# 172  https://www.yelp.com/biz/the-paprika-store-lon...  Q2x1Tq3GF9ZHFwA4a8LR4w
# 173  https://www.yelp.com/biz/phoenicia-mediterrane...  IDH_axJK2uI99N5-_PHl5A
# 174  https://www.yelp.com/biz/princi-london?adjust_...  -ATEXu2q4Oe4wPQeyrsILw
# 175  https://www.yelp.com/biz/caffe-concerto-london...  IEGYMW3nc-dTtOicVJ0AWw
# 176  https://www.yelp.com/biz/laduree-london-14?adj...  OGW03dLcEui-6CWZIucVMw
# 177  https://www.yelp.com/biz/jakobs-london?adjust_...  eekflLQwzpeZ9sNg89F38A
# 178  https://www.yelp.com/biz/jakobs-london?adjust_...  eekflLQwzpeZ9sNg89F38A
# 179  https://www.yelp.com/biz/49-cafe-london?adjust...  LyXXTUzll212_JKMkzC3DQ
# 180  https://www.yelp.com/biz/patisserie-valerie-lo...  9klx0ol5iCCf7vG-IjcYFQ
# 181  https://www.yelp.com/biz/patisserie-valerie-lo...  Z3dr4as9zDncGnaCtqnntQ
# 182  https://www.yelp.com/biz/golden-gate-cake-shop...  83KeM6uScA4ONx97xMHvXw
# 183  https://www.yelp.com/biz/franze-and-evans-cafe...  fM99pmX2-ipWvG33tILdZQ
# 184  https://www.yelp.com/biz/patisserie-valerie-lo...  xJvPDma1C7F7hvEp0OfjWg
# 185  https://www.yelp.com/biz/fabrique-bakery-londo...  Q-f511k1hYDIKfKIpC_HIw
# 186  https://www.yelp.com/biz/louis-hungarian-patis...  f5lYXTuVpY6iMLyCPMXWsA
# 187  https://www.yelp.com/biz/wonderful-patisserie-...  VZ_1ATiJ5j4uTHvGHr7JNw
# 188  https://www.yelp.com/biz/fork-deli-patisserie-...  MOZ3X-asf3FZEOE39966-A
# 189  https://www.yelp.com/biz/ole-and-steen-london-...  5or4AzNouZq8RClNeTdqiA
# 190  https://www.yelp.com/biz/paul-covent-garden-le...  bdUsmRcJUe29Ssa-osjjDA
# 191  https://www.yelp.com/biz/lanka-london-2?adjust...  c3m_OXrRNdJpWmTqhEgdeQ
# 192  https://www.yelp.com/biz/lisboa-patisserie-lon...  UhXQ3C0ixl8BukWDAR-cqg
# 193  https://www.yelp.com/biz/maitre-choux-london-2...  271U0h4hish4lq_mESjGRw
# 194
# 195  https://www.yelp.com/biz/cafe-de-nata-fulham?a...  REhb-qBL9hkXyoec71arhA
# 196  https://www.yelp.com/biz/bageriet-london?adjus...  0tJs57Xoq75-RDWKVco0nw
# 197  https://www.yelp.com/biz/candella-tea-room-lon...  tcVWoHSko9PIy_Ec95_j1A
# 198  https://www.yelp.com/biz/the-rosebery-lounge-l...  mOD60RafvMIEv0PR0QqV-g
# 199  https://www.yelp.com/biz/simit-sarayi-london-4...  P4rFlCsevSiJuwshO6wF7g
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
london_restaurants_df.to_csv('Resources/London_Restaurants_Pastry.csv')
