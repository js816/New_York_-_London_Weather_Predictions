# %% [markdown]
# LONDON RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
lndr_params1 = {"term":"cafe","location":"London","limit":50,"offset":0}
lndr_response1 = requests.get(search_api_url, headers=headers, params=lndr_params1)
lndr1 = lndr_response1.json()
display(lndr1)
#print(lndr_response1.url)
#print(lndr_response1.status_code)
# Out:
# {'businesses': [{'id': 'EeTAE4kabQnQw1flRCcjvA',
#    'alias': 'the-arts-cafe-london-4',
#    'name': 'The Arts Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EMgvPJ16kW_inKgx3XvdBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-arts-cafe-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5119065, 'longitude': -0.1276458},
#    'transactions': [],
#    'location': {'address1': 'The Arts Theatre',
#     'address2': '6 - 7 Great Newport Street',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2H 7JB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Arts Theatre',
#      '6 - 7 Great Newport Street',
#      'London WC2H 7JB',
#      'United Kingdom']},
#    'phone': '+442070648100',
#    'display_phone': '+44 20 7064 8100',
#    'distance': 584.270759371596},
#   {'id': '-22PaX8rQyh0ZQrdCiDz4A',
#    'alias': 'fuckoffee-london-3',
#    'name': 'Fuckoffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MQ7RV7bMOSjdLX1DfhzQ_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fuckoffee-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 87,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4993814, 'longitude': -0.0812485},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '163-167 Bermondsey Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 3UW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['163-167 Bermondsey Street',
#      'London SE1 3UW',
#      'United Kingdom']},
#    'phone': '+442074037655',
#    'display_phone': '+44 20 7403 7655',
#    'distance': 4071.1885164771065},
#   {'id': 'BjPq77aiaKZAVUHIu2S3gA',
#    'alias': 'the-english-rose-cafe-and-tea-shop-london',
#    'name': 'The English Rose Cafe and Tea Shop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B_v1cOkgPEcbr8e2rtfaog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-english-rose-cafe-and-tea-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 213,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4980558, 'longitude': -0.1444512},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 Lower Grosvenor Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 0EJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Lower Grosvenor Place',
#      'London SW1W 0EJ',
#      'United Kingdom']},
#    'phone': '+442079766280',
#    'display_phone': '+44 20 7976 6280',
#    'distance': 1745.2072668809335},
#   {'id': 'r-USboJFp1ifbtFWtbTGhQ',
#    'alias': 'paper-and-cup-london-2',
#    'name': 'Paper and Cup',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XkBLH87FtSkzIaMMSnmN3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paper-and-cup-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5262201, 'longitude': -0.076815},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '18 Calvert Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7JP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Calvert Avenue',
#      'London E2 7JP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4354.245310616501},
#   {'id': 'IWl1Y0eQOZSnYeIDw94svg',
#    'alias': 'monmouth-coffee-london',
#    'name': 'Monmouth Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-eZOw_Lts2a7dWXNYekA_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/monmouth-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 306,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5055383383613,
#     'longitude': -0.0914615294783139},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Park Street',
#     'address2': 'The Borough',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Park Street',
#      'The Borough',
#      'London SE1 9AB',
#      'United Kingdom']},
#    'phone': '+442072323010',
#    'display_phone': '+44 20 7232 3010',
#    'distance': 3184.4018654070014},
#   {'id': 'UMJxTGTSShg2u1FFwZBWAQ',
#    'alias': 'the-book-club-london',
#    'name': 'The Book Club',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8HCdjBRKyg074ero0uqGAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-book-club-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.524537, 'longitude': -0.081494},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '100 Leonard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 4RH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['100 Leonard Street',
#      'London EC2A 4RH',
#      'United Kingdom']},
#    'phone': '+442076848618',
#    'display_phone': '+44 20 7684 8618',
#    'distance': 3994.972382925784},
#   {'id': 'PBFvhVyBi0lEJyTbyuxf5w',
#    'alias': 'the-orangery-london-7',
#    'name': 'The Orangery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L_0d22xNmfCC_d-tArBo3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-orangery-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 238,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5066360577041,
#     'longitude': -0.187725349125042},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Kensington Palace',
#     'address2': 'Palace Green',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Kensington Palace',
#      'Palace Green',
#      'London W8 4PX',
#      'United Kingdom']},
#    'phone': '+442031666113',
#    'display_phone': '+44 20 3166 6113',
#    'distance': 3648.4574890404074},
#   {'id': '68gc1BAE1IT_zZghFafw0Q',
#    'alias': 'ozone-coffee-london-2',
#    'name': 'Ozone Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FMKfpA6gKHlDAKDuPVVdTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ozone-coffee-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 188,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.524683689256,
#     'longitude': -0.086674106560876},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Leonard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 4AQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Leonard Street',
#      'London EC2A 4AQ',
#      'United Kingdom']},
#    'phone': '+442074901039',
#    'display_phone': '+44 20 7490 1039',
#    'distance': 3655.552919913525},
#   {'id': 'j0PAetkQTQxUt-9CFhsySA',
#    'alias': 'black-sheep-coffee-london-42',
#    'name': 'Black Sheep Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6z3JfgTbHbR3FVspGb9Iwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-sheep-coffee-london-42?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.514694, 'longitude': -0.086011},
#    'transactions': [],
#    'location': {'address1': '125 Old Broad Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2N 1AR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['125 Old Broad Street',
#      'London EC2N 1AR',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3462.3277442739386},
#   {'id': 'p77CnjTGOIZA1hEpLfCC6Q',
#    'alias': 'kennington-lane-cafe-london',
#    'name': 'Kennington Lane Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4pjtT4PSUYl_0_BqOTx6Cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kennington-lane-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4860611, 'longitude': -0.1208514},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '383 Kennington Lane',
#     'address2': 'Vauxhall',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE11 5QY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['383 Kennington Lane',
#      'Vauxhall',
#      'London SE11 5QY',
#      'United Kingdom']},
#    'phone': '+442077355853',
#    'display_phone': '+44 20 7735 5853',
#    'distance': 3147.932368103276},
#   {'id': 'riWepzZEIHj82UiDk_WVLQ',
#    'alias': 'montparnasse-cafe-london-2',
#    'name': 'Montparnasse Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/90P9GQECkOj3aZIrJfpO8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/montparnasse-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5005205, 'longitude': -0.1885342},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '22 Thackeray Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 5ET',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Thackeray Street',
#      'London W8 5ET',
#      'United Kingdom']},
#    'phone': '+442073762212',
#    'display_phone': '+44 20 7376 2212',
#    'distance': 3888.086719460034},
#   {'id': 'tYynO1nOy1GKxMV3jkxbmw',
#    'alias': 'the-breakfast-club-london-2',
#    'name': 'The Breakfast Club',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TElKM303HWt3LAkvgBuTWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-breakfast-club-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 497,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514733, 'longitude': -0.135406},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "33 D'Arblay Street",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["33 D'Arblay Street",
#      'London W1F 8EU',
#      'United Kingdom']},
#    'phone': '+442074342571',
#    'display_phone': '+44 20 7434 2571',
#    'distance': 215.73161782407266},
#   {'id': 'mvds37L7mCurGn3rGPM8ag',
#    'alias': 'kaffeine-london',
#    'name': 'Kaffeine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QWk5UJ1ELO0n7VrE3aLUWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaffeine-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 173,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51848, 'longitude': -0.14037},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '66 Great Titchfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 7QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Great Titchfield Street',
#      'London W1W 7QJ',
#      'United Kingdom']},
#    'phone': '+442075806755',
#    'display_phone': '+44 20 7580 6755',
#    'distance': 697.5687539772275},
#   {'id': 'lkethHYEgAT3gE-09fLWag',
#    'alias': 'yumchaa-soho-london',
#    'name': 'Yumchaa Soho',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Si6ohuBWReqcfiWiaPMNYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yumchaa-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 161,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515164726519,
#     'longitude': -0.13609727051977},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '45 Berwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8SF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Berwick Street',
#      'London W1F 8SF',
#      'United Kingdom']},
#    'phone': '+442072099641',
#    'display_phone': '+44 20 7209 9641',
#    'distance': 259.1804522380711},
#   {'id': 'mK87F1KiR7Ph-iOwI45Thw',
#    'alias': 'milk-london-2',
#    'name': 'Milk',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mkSDunrDVhCd2ba-ISglrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/milk-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.444649, 'longitude': -0.1510286},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18-20 Bedford Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW12 9RG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18-20 Bedford Hill',
#      'London SW12 9RG',
#      'United Kingdom']},
#    'phone': '+44442087729085',
#    'display_phone': '+44 442087729085',
#    'distance': 7653.50288388963},
#   {'id': 'Opa8XUwUghxbGFafvubV6A',
#    'alias': 'monmouth-coffee-london-3',
#    'name': 'Monmouth Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bwLj-cK2l4ws5hpEefgdqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/monmouth-coffee-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 306,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5143539, 'longitude': -0.1269168},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '27 Monmouth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['27 Monmouth Street',
#      'London WC2H 9EU',
#      'United Kingdom']},
#    'phone': '+442072323010',
#    'display_phone': '+44 20 7232 3010',
#    'distance': 647.8829298163467},
#   {'id': 'YNduANMPzIVE8CzBH7YjEQ',
#    'alias': 'regency-café-london-2',
#    'name': 'Regency Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pz5q5e8LBG7C1ozSuhvuKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/regency-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 393,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4940143171, 'longitude': -0.13222007974201},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '17-19 Regency Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 4BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17-19 Regency Street',
#      'London SW1P 4BY',
#      'United Kingdom']},
#    'phone': '+442078216596',
#    'display_phone': '+44 20 7821 6596',
#    'distance': 2108.732795587357},
#   {'id': '3fDLrrmStQBZFMBHUvMbrQ',
#    'alias': 'fix-126-london',
#    'name': 'Fix 126',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UaNwPc1DUW418DLihHCXJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fix-126-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5261251, 'longitude': -0.0802153},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '126 Curtain Road',
#     'address2': 'Shoreditch',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 3PJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['126 Curtain Road',
#      'Shoreditch',
#      'London EC2A 3PJ',
#      'United Kingdom']},
#    'phone': '+442070339555',
#    'display_phone': '+44 20 7033 9555',
#    'distance': 4130.140674765295},
#   {'id': 'DAE3fIusVTUGt9PDwPlelg',
#    'alias': 'exmouth-coffee-company-london',
#    'name': 'Exmouth Coffee Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0yrsGXNRm5roKhOo_8VUiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/exmouth-coffee-company-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 81,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.515994, 'longitude': -0.070496},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '83 Whitechapel High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 7QX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Whitechapel High Street',
#      'London E1 7QX',
#      'United Kingdom']},
#    'phone': '+442073771010',
#    'display_phone': '+44 20 7377 1010',
#    'distance': 4553.663911477298},
#   {'id': 'pOQwGM-8Qrwb8PGzLDGyeg',
#    'alias': 'queen-elizabeth-roof-garden-bar-and-café-southbank-centre-2',
#    'name': 'Queen Elizabeth Roof Garden Bar & Café',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8KH-8QITcveXy9JjR8GTGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/queen-elizabeth-roof-garden-bar-and-caf%C3%A9-southbank-centre-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.50571, 'longitude': -0.116686820983887},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Queen Elizabeth Hall',
#     'address2': 'Southbank Centre',
#     'address3': '',
#     'city': 'Southbank Centre',
#     'zip_code': 'SE1 8XX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Queen Elizabeth Hall',
#      'Southbank Centre',
#      'Southbank Centre SE1 8XX',
#      'United Kingdom']},
#    'phone': '+442079210758',
#    'display_phone': '+44 20 7921 0758',
#    'distance': 1551.1575341559812},
#   {'id': 'mdy8N4wPOlOSiatLWKjLGg',
#    'alias': 'the-borough-barista-london',
#    'name': 'The Borough Barista',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5BOQF57dPe1EaVvhzb0wtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-borough-barista-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.514461025878,
#     'longitude': -0.16090849657059},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '60A Seymour Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7JN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['60A Seymour Street',
#      'London W1H 7JN',
#      'United Kingdom']},
#    'phone': '+442075637222',
#    'display_phone': '+44 20 7563 7222',
#    'distance': 1736.1517070034572},
#   {'id': 'KcTG8dVnattBQaWXdIzMrg',
#    'alias': 'feya-london',
#    'name': 'Feya',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/29bCWknB8eqsYuHmY2ii3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/feya-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51509, 'longitude': -0.1508},
#    'transactions': [],
#    'location': {'address1': '23 James St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1U 1DT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23 James St', 'London W1U 1DT', 'United Kingdom']},
#    'phone': '+442078580858',
#    'display_phone': '+44 20 7858 0858',
#    'distance': 1056.5656492391608},
#   {'id': 'PHTcl--LbBwA1N6EHZV_sg',
#    'alias': 'new-london-cafe-london',
#    'name': 'New London Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JCkupf-AWh-_sjg8myef1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-london-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.546910711, 'longitude': -0.0983781045074466},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "216 St Paul's Road",
#     'address2': 'Islington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 2LL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["216 St Paul's Road",
#      'Islington',
#      'London N1 2LL',
#      'United Kingdom']},
#    'phone': '+442073547321',
#    'display_phone': '+44 20 7354 7321',
#    'distance': 4594.940461650296},
#   {'id': '7Nme-QeQ65gtQEyoB0KyEw',
#    'alias': 'the-coffee-jar-london',
#    'name': 'The Coffee Jar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/26Cm2OUJsOTPR_xpptHdhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-coffee-jar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5373402066451,
#     'longitude': -0.145319216450743},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '83 Parkway',
#     'address2': 'Camden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 7PP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Parkway',
#      'Camden',
#      'London NW1 7PP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2800.7359403054115},
#   {'id': '4LrPlD9U-E0oxyAFBCjChw',
#    'alias': 'tap-coffee-no-114-london',
#    'name': 'Tap Coffee No.114',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/M97PW0Ttz9OwyUKZHgqIkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tap-coffee-no-114-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.523831, 'longitude': -0.137085},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '114 Tottenham Court Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 5AQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['114 Tottenham Court Road',
#      'London W1T 5AQ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1225.1340149771556},
#   {'id': 'UjsIWFM9xcD9PCO0nJoMCQ',
#    'alias': 'caffe-in-london',
#    'name': 'Caffe In',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O4NH7q62sJXw765I_8fEvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-in-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.506194, 'longitude': -0.146446},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3 Shepherd Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 7HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Shepherd Street',
#      'London W1J 7HL',
#      'United Kingdom']},
#    'phone': '+442074936400',
#    'display_phone': '+44 20 7493 6400',
#    'distance': 1032.7212314091926},
#   {'id': 'y8xX3BDj1bf7-wc4Q9Atvg',
#    'alias': 'the-monocle-cafe-london',
#    'name': 'The Monocle Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WVPzYgrKif_v7M9hkSshJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-monocle-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 69,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5188109085709,
#     'longitude': -0.154666668198166},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '18 Chiltern Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 7QA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Chiltern Street',
#      'London W1U 7QA',
#      'United Kingdom']},
#    'phone': '+442071352040',
#    'display_phone': '+44 20 7135 2040',
#    'distance': 1455.2587544542089},
#   {'id': 'dIWOqYszVKk-oswXDzUH6A',
#    'alias': 'primrose-bakery-london',
#    'name': 'Primrose Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ng53dTpGBxCLSpY5sotd_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/primrose-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5402263, 'longitude': -0.1511222},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '69 Gloucester Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8LD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['69 Gloucester Avenue',
#      'London NW1 8LD',
#      'United Kingdom']},
#    'phone': '+442074834222',
#    'display_phone': '+44 20 7483 4222',
#    'distance': 3221.367607689674},
#   {'id': 'za-KLljMB6yelgi2idCQPg',
#    'alias': 'beany-green-london',
#    'name': 'Beany Green',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UMPucP-qTkGpe2o5ix3woA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beany-green-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.519873314712,
#     'longitude': -0.180045690126235},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 6C',
#     'address2': '4 Sheldon Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 6EZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 6C',
#      '4 Sheldon Square',
#      'London W2 6EZ',
#      'United Kingdom']},
#    'phone': '+442072893344',
#    'display_phone': '+44 20 7289 3344',
#    'distance': 3149.5925485320417},
#   {'id': 'W7DpFG8AbfLi516fIvgdDg',
#    'alias': 'abbey-cafe-london',
#    'name': 'Abbey Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UedDW_RDdKobWFYeQBagGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/abbey-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.531848626266,
#     'longitude': -0.18065861355395},
#    'transactions': [],
#    'location': {'address1': '3 Nugent Terrace',
#     'address2': "St. John's Wood",
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 9QB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Nugent Terrace',
#      "St. John's Wood",
#      'London NW8 9QB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3746.3652871577324},
#   {'id': 'EanCLBAeSJNU9MA0pVlHVg',
#    'alias': 'cafe-twelve-london',
#    'name': 'Cafe Twelve',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uAIN5SbTugPIgyu7ljHtjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-twelve-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.528322, 'longitude': -0.075946},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '57 Hackney Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7NX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57 Hackney Rd', 'London E2 7NX', 'United Kingdom']},
#    'phone': '+442077299319',
#    'display_phone': '+44 20 7729 9319',
#    'distance': 4494.95978931185},
#   {'id': '-6GHU4qI0DKsIrBpv57qTg',
#    'alias': 'e5-bakehouse-london',
#    'name': 'E5 Bakehouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5fOMHTqW0WvJz3o4ojfxXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/e5-bakehouse-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5412038403948,
#     'longitude': -0.0576161965996107},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '395 Mentmore Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 3PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['395 Mentmore Terrace',
#      'London E8 3PH',
#      'United Kingdom']},
#    'phone': '+442085252890',
#    'display_phone': '+44 20 8525 2890',
#    'distance': 6270.653368630909},
#   {'id': '1TgYqfxkXv6-IB4cvuuy3w',
#    'alias': 'tea-and-tattle-london',
#    'name': 'Tea and Tattle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zm3bEijY0rcDGz-5Nw9sKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tea-and-tattle-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5178680419922,
#     'longitude': -0.126817002892494},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '41 Great Russell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3PE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41 Great Russell Street',
#      'London WC1B 3PE',
#      'United Kingdom']},
#    'phone': '+447722192703',
#    'display_phone': '+44 7722 192703',
#    'distance': 841.826045500197},
#   {'id': 'aGqt0g9_WU2UGituR7yn-w',
#    'alias': 'farm-girl-cafe-london',
#    'name': 'Farm Girl Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Qxj7RtZyROODLKeUzWbarw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/farm-girl-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 78,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5120686916922,
#     'longitude': -0.200769876546774},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '59A Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 3DB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['59A Portobello Road',
#      'London W11 3DB',
#      'United Kingdom']},
#    'phone': '+442072294678',
#    'display_phone': '+44 20 7229 4678',
#    'distance': 4486.039469290095},
#   {'id': 'H-Ke1qRMqKd7rvlMBmcQ6A',
#    'alias': 'birdhouse-london',
#    'name': 'Birdhouse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hViZ8arhFswqbmXr-CKs3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/birdhouse-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4608992385793,
#     'longitude': -0.175180435180664},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "123 St John's Hill",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW11 1SZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["123 St John's Hill",
#      'London SW11 1SZ',
#      'United Kingdom']},
#    'phone': '+442072286663',
#    'display_phone': '+44 20 7228 6663',
#    'distance': 6381.8017672318065},
#   {'id': 'SeDzq2X1sP3g7BteNJkxxg',
#    'alias': 'urban-pantry-london',
#    'name': 'Urban Pantry',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6Gl6fC0Xd5nhOQZh41dTlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/urban-pantry-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4916802381695,
#     'longitude': -0.255905280028632},
#    'transactions': [],
#    'location': {'address1': '15 Devonshire Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W4 2HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Devonshire Road',
#      'London W4 2HA',
#      'United Kingdom']},
#    'phone': '+442089941444',
#    'display_phone': '+44 20 8994 1444',
#    'distance': 8629.35128354945},
#   {'id': 'd7MRSjcGM9nq8m4wRLOFwg',
#    'alias': 'kanella-and-co-london',
#    'name': 'Kanella & Co',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VfMunw3LNh0pMybncCglEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kanella-and-co-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'greek', 'title': 'Greek'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4572122, 'longitude': -0.0757312},
#    'transactions': [],
#    'location': {'address1': '106 Lordship Lane',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE22 8HF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['106 Lordship Lane',
#      'London SE22 8HF',
#      'United Kingdom']},
#    'phone': '+447983308870',
#    'display_phone': '+44 7983 308870',
#    'distance': 7459.5302479964785},
#   {'id': 'tg8989Huoygge1GGqR1_8A',
#    'alias': 'beatles-coffee-shop-london',
#    'name': 'Beatles Coffee Shop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/i_44Ov7Fn5271P2TO4zupw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beatles-coffee-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5346523696246,
#     'longitude': -0.174049176031857},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "St John's Wood Underground Station",
#     'address2': 'Finchley Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 6HY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["St John's Wood Underground Station",
#      'Finchley Road',
#      'London NW3 6HY',
#      'United Kingdom']},
#    'phone': '+442075865404',
#    'display_phone': '+44 20 7586 5404',
#    'distance': 3582.004625493745},
#   {'id': 'IfyCqU5noJALqrXTGKnQsQ',
#    'alias': 'the-little-one-london',
#    'name': 'The Little One',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qqYE8rW0C02TamnqgZCEDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-little-one-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5426041, 'longitude': -0.1555134},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "115 Regent's Park Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8UR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["115 Regent's Park Road",
#      'London NW1 8UR',
#      'United Kingdom']},
#    'phone': '+447510843093',
#    'display_phone': '+44 7510 843093',
#    'distance': 3575.938807492533},
#   {'id': '99cI70VVcGEw_PlBslo9QA',
#    'alias': 'caffe-concerto-london-30',
#    'name': 'Caffe Concerto',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vrqQlTMpLyM-TNnnStxHVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-concerto-london-30?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5080342, 'longitude': -0.1404697},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61 Piccadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 0DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Piccadilly', 'London W1J 0DY', 'United Kingdom']},
#    'phone': '+442074946844',
#    'display_phone': '+44 20 7494 6844',
#    'distance': 620.2445721336735},
#   {'id': '6NIJqOFjLUPXnGaJbxW3lA',
#    'alias': 'l-eto-london-2',
#    'name': "L'ETO",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wPsMI8cgIW_5JjqdEcUhgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-eto-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.496624, 'longitude': -0.1688603},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '243 Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['243 Brompton Road', 'London SW3', 'United Kingdom']},
#    'phone': '+442078542860',
#    'display_phone': '+44 20 7854 2860',
#    'distance': 2898.9080858295915},
#   {'id': 'XL7cx1Sb3dFPak2gkPOzKw',
#    'alias': 'soho-grind-london-2',
#    'name': 'Soho Grind',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Vl36Az1so-DbXZ25ImcqjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soho-grind-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512154, 'longitude': -0.138379},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '19 Beak Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Beak Street',
#      'Soho',
#      'London W1F 9RP',
#      'United Kingdom']},
#    'phone': '+442072877073',
#    'display_phone': '+44 20 7287 7073',
#    'distance': 181.13696795054122},
#   {'id': 'e5jPAqpCcIAsTtasUN5h2g',
#    'alias': 'the-wolseley-london',
#    'name': 'The Wolseley',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T9xpXsz-az88-l0Ko_KLpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wolseley-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 553,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.507617, 'longitude': -0.141012},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '160 Picadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 9EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['160 Picadilly', 'London W1J 9EB', 'United Kingdom']},
#    'phone': '+442074996996',
#    'display_phone': '+44 20 7499 6996',
#    'distance': 677.6098617325135},
#   {'id': '7csCri69UQ2hsEdkPbSegw',
#    'alias': 'piggys-cafe-london-2',
#    'name': "Piggy's Cafe",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UwWKmKwx0WIZ0dE9NiSAOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piggys-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5062603, 'longitude': -0.0148893},
#    'transactions': [],
#    'location': {'address1': 'Billingsgate Market',
#     'address2': 'Trafalgar Way',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E14 5ST',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Billingsgate Market',
#      'Trafalgar Way',
#      'London E14 5ST',
#      'United Kingdom']},
#    'phone': '+442079871068',
#    'display_phone': '+44 20 7987 1068',
#    'distance': 8410.354287845837},
#   {'id': 'xqpUr61KFa1Xx721-E6l_A',
#    'alias': 'kipferl-london-6',
#    'name': 'Kipferl',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CUoYGTlW1CYS-nJ5vAUGPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kipferl-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'austrian', 'title': 'Austrian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.535247538411,
#     'longitude': -0.10339315152949},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Camden Passage',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Camden Passage',
#      'London N1 8ED',
#      'United Kingdom']},
#    'phone': '+442077041555',
#    'display_phone': '+44 20 7704 1555',
#    'distance': 3359.4222431551457},
#   {'id': '5or4AzNouZq8RClNeTdqiA',
#    'alias': 'ole-and-steen-london-2',
#    'name': 'Ole and Steen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HhmDFvGw42MnOJErQE9vkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ole-and-steen-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.509238, 'longitude': -0.1326965},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '56 Haymarket',
#     'address2': '',
#     'address3': "No 2 St James's Market",
#     'city': 'London',
#     'zip_code': 'SW1Y 4RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['56 Haymarket',
#      "No 2 St James's Market",
#      'London SW1Y 4RP',
#      'United Kingdom']},
#    'phone': '+442038288242',
#    'display_phone': '+44 20 3828 8242',
#    'distance': 459.23424350084883},
#   {'id': 'XqYhhs7WWgOnP_e5x3Wg8g',
#    'alias': 'garden-shack-hideaway-london',
#    'name': 'Garden Shack Hideaway',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iGtACYivM-UcH1iQyS19Zg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/garden-shack-hideaway-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5027676843354,
#     'longitude': -0.115942216752501},
#    'transactions': [],
#    'location': {'address1': '55 York Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 7NJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55 York Rd', 'London SE1 7NJ', 'United Kingdom']},
#    'phone': '+447912106692',
#    'display_phone': '+44 7912 106692',
#    'distance': 1780.9533069366198},
#   {'id': 'vAiqG2dTHlG0kKOCMYEBsg',
#    'alias': 'cafe-van-gogh-camberwell',
#    'name': 'Cafe Van Gogh',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gcV6XzjrlV6R2pcp7beldQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-van-gogh-camberwell?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4777129, 'longitude': -0.112505},
#    'transactions': [],
#    'location': {'address1': '88-96 Brixton Road',
#     'address2': '',
#     'address3': None,
#     'city': 'Camberwell',
#     'zip_code': 'SW9 6BH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['88-96 Brixton Road',
#      'Camberwell SW9 6BH',
#      'United Kingdom']},
#    'phone': '+447546966554',
#    'display_phone': '+44 7546 966554',
#    'distance': 4229.435925758568},
#   {'id': 'rQKDeNCx8LkUR12YH9LpVg',
#    'alias': 'bäkehaus-london-2',
#    'name': 'Bäkehaus',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t8nwOKGUsvFhyuNdJFTrvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b%C3%A4kehaus-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4926600176647,
#     'longitude': -0.227837562561035},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '71 King Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W6 9HW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['71 King Street', 'London W6 9HW', 'United Kingdom']},
#    'phone': '+442034903231',
#    'display_phone': '+44 20 3490 3231',
#    'distance': 6743.794563736779},
#   {'id': 'ZDDEKWdrpjJHqX2d0InVMg',
#    'alias': 'urban-baristas-london-2',
#    'name': 'Urban Baristas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/f5NsZ4qiBlgvwVMbwh54Qg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/urban-baristas-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5108318662288,
#     'longitude': -0.187354646623135},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Queensway',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 4QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Queensway', 'London W2 4QJ', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3563.8944950081736}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                            Restaurant          Type Price Rating  \
# 0                       The Arts Cafe         Cafes
# 1                           Fuckoffee  Coffee & Tea     £      4
# 2  The English Rose Cafe and Tea Shop  Coffee & Tea    ££    4.5
# 3                       Paper and Cup  Coffee & Tea     £    4.5
# 4                     Monmouth Coffee  Coffee & Tea    ££    4.5
#
#                      Address        Lat       Lng  \
# 0           The Arts Theatre  51.511907 -0.127646
# 1  163-167 Bermondsey Street  51.499381 -0.081249
# 2    4 Lower Grosvenor Place  51.498056 -0.144451
# 3          18 Calvert Avenue  51.526220 -0.076815
# 4              2 Park Street  51.505538 -0.091462
#
#                                                  url                      ID
# 0
# 1  https://www.yelp.com/biz/fuckoffee-london-3?ad...  -22PaX8rQyh0ZQrdCiDz4A
# 2  https://www.yelp.com/biz/the-english-rose-cafe...  BjPq77aiaKZAVUHIu2S3gA
# 3  https://www.yelp.com/biz/paper-and-cup-london-...  r-USboJFp1ifbtFWtbTGhQ
# 4  https://www.yelp.com/biz/monmouth-coffee-londo...  IWl1Y0eQOZSnYeIDw94svg

# %%
#2nd set of 50 records 51-100 
lndr_params2 = {"term":"cafe","location":"London","limit":50,"offset":51}
lndr_response2 = requests.get(search_api_url, headers=headers, params=lndr_params2)
lndr2 = lndr_response2.json()
display(lndr2)
#print(lndr_response2.url)
#print(lndr_response2.status_code)
# Out:
# {'businesses': [{'id': 'PYwzVOvFIjwCMNYV5upPwg',
#    'alias': 'the-attendant-london-2',
#    'name': 'The Attendant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W4pc8bJ_lVWg801nKejVOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-attendant-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 74,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5192470995905,
#     'longitude': -0.140738025145255},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Downstairs 27A',
#     'address2': 'Foley Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 6DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Downstairs 27A',
#      'Foley Street',
#      'London W1W 6DY',
#      'United Kingdom']},
#    'phone': '+442076373794',
#    'display_phone': '+44 20 7637 3794',
#    'distance': 785.9877629261662},
#   {'id': 'Xll3M26qDVQFPVF9rmERZw',
#    'alias': 'ole-and-steen-london-4',
#    'name': 'Ole & Steen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/S_657Xvx5eEDhBLcndKO9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ole-and-steen-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.517686, 'longitude': -0.13121},
#    'transactions': [],
#    'location': {'address1': '1 Bedford Avenue',
#     'address2': 'Unit 4',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC1B 3AU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Bedford Avenue',
#      'Unit 4',
#      'London WC1B 3AU',
#      'United Kingdom']},
#    'phone': '+442039484888',
#    'display_phone': '+44 20 3948 4888',
#    'distance': 631.4592636929035},
#   {'id': 'nQ79oxa3bLcT6yKV-kGidQ',
#    'alias': 'cafe-babka-london',
#    'name': 'Cafe Babka',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RajRV5SNJaZz8tBb_OryHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-babka-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5180054019877,
#     'longitude': -0.126519799232483},
#    'transactions': [],
#    'location': {'address1': '44 Great Russell Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC1B 3PA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['44 Great Russell Street',
#      'London WC1B 3PA',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 869.9445615390207},
#   {'id': 'RdVuh5xQAkzULoKtjXsE1Q',
#    'alias': 'mill-and-brew-london-3',
#    'name': 'Mill & Brew',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AYy71B2VX1cGjehIm5Jarg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mill-and-brew-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.6144307, 'longitude': -0.2483771},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '23 The Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW7 3DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23 The Broadway',
#      'London NW7 3DA',
#      'United Kingdom']},
#    'phone': '+442089596964',
#    'display_phone': '+44 20 8959 6964',
#    'distance': 13711.561379122157},
#   {'id': 'qtW1fg8pyGOXKJnAIk7Wmg',
#    'alias': 'flat-white-london',
#    'name': 'Flat White',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xhvTDNtJzpaPpECSawt5OA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flat-white-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 151,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.513644, 'longitude': -0.134773},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '17 Berwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0PT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17 Berwick Street',
#      'London W1F 0PT',
#      'United Kingdom']},
#    'phone': '+442077340370',
#    'display_phone': '+44 20 7734 0370',
#    'distance': 121.5192430888984},
#   {'id': 'MF6Xwxep-fx_WfjpR-hmRQ',
#    'alias': 'the-quince-tree-london',
#    'name': 'The Quince Tree',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RvTdclXJQCaKu3xrr_QntQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-quince-tree-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.522522, 'longitude': -0.1849087},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Clifton Nurseries',
#     'address2': '5a Clifton Villas',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W9 2PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Clifton Nurseries',
#      '5a Clifton Villas',
#      'London W9 2PH',
#      'United Kingdom']},
#    'phone': '+442074321867',
#    'display_phone': '+44 20 7432 1867',
#    'distance': 3554.3491487276037},
#   {'id': 'WotOpvaXPZW2Yx-dzoK73w',
#    'alias': 'seoul-bakery-london-3',
#    'name': 'Seoul Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bLb2f4il2hodPvDWaefrhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seoul-bakery-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.517237, 'longitude': -0.129569},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '14 Great Russell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Great Russell Street',
#      'London WC1B 3NH',
#      'United Kingdom']},
#    'phone': '+442072400877',
#    'display_phone': '+44 20 7240 0877',
#    'distance': 659.4351702613345},
#   {'id': 'RJd6_J2dekhZT3g7S2sFKQ',
#    'alias': 'ripe-kitchen-london',
#    'name': 'Ripe Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eWdcUDw5jrPd2z1GjchEdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ripe-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'healthmarkets', 'title': 'Health Markets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5406973, 'longitude': -0.1572616},
#    'transactions': [],
#    'location': {'address1': '136 Regents Park Road',
#     'address2': 'Primrose Hill',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8XL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['136 Regents Park Road',
#      'Primrose Hill',
#      'London NW1 8XL',
#      'United Kingdom']},
#    'phone': '+447572480102',
#    'display_phone': '+44 7572 480102',
#    'distance': 3430.830308059021},
#   {'id': 'o1gFln8kSV4Y36Zo420dyQ',
#    'alias': 'vanilla-black-coffee-and-books-london',
#    'name': 'Vanilla Black Coffee and Books',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rm-Ghsek7uCOp2p5p3fxBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vanilla-black-coffee-and-books-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'usedbooks', 'title': 'Used Bookstore'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4874737983978,
#     'longitude': -0.11141661554575},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '306-308 Kennington Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE11 4LD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['306-308 Kennington Road',
#      'London SE11 4LD',
#      'United Kingdom']},
#    'phone': '+442077355505',
#    'display_phone': '+44 20 7735 5505',
#    'distance': 3292.1395618571432},
#   {'id': 'Qk9CwHdpFgYo1Za77yfPtQ',
#    'alias': 'l-eto-caffe-london-6',
#    'name': "L'eto Caffe",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1FQ30FQP3kvrI5A8NXId9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-eto-caffe-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.48794, 'longitude': -0.167225},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "149 King's Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 5TX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["149 King's Road",
#      'London SW3 5TX',
#      'United Kingdom']},
#    'phone': '+442073517656',
#    'display_phone': '+44 20 7351 7656',
#    'distance': 3513.9797015942327},
#   {'id': '2W5-ITjCbbdRO6_VSn3Jng',
#    'alias': 'the-ivy-café-london-2',
#    'name': 'The Ivy Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/V9gVs01upMjVTQCukknMtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ivy-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5335598, 'longitude': -0.1705403},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "120 Saint John's Wood High Street",
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW8 7SG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["120 Saint John's Wood High Street",
#      'London NW8 7SG',
#      'United Kingdom']},
#    'phone': '+442030969444',
#    'display_phone': '+44 20 3096 9444',
#    'distance': 3314.7521456346053},
#   {'id': '3txeypXuJ-MqNt8LGopsOQ',
#    'alias': 'truly-scrumptious-london',
#    'name': 'Truly Scrumptious',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/P1SyoGp8-RIQyrZeeQRyeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/truly-scrumptious-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.543384, 'longitude': -0.150603},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '67 Chalk Farm Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8AN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['67 Chalk Farm Road',
#      'London NW1 8AN',
#      'United Kingdom']},
#    'phone': '+442079160616',
#    'display_phone': '+44 20 7916 0616',
#    'distance': 3544.7371416891046},
#   {'id': 'OLXnVhh19HtAnbywQzD3zw',
#    'alias': 'rinkoff-bakeries-london-2',
#    'name': 'Rinkoff Bakeries',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U0sRZgXWXgBxJhqCMQAESA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rinkoff-bakeries-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5198880062398,
#     'longitude': -0.0530246183202313},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '224 Jubilee Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 3BS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['224 Jubilee Street',
#      'London E1 3BS',
#      'United Kingdom']},
#    'phone': '+442077914909',
#    'display_phone': '+44 20 7791 4909',
#    'distance': 5791.8034174832765},
#   {'id': 'I0uedC7kST8RRKLmJ6os-w',
#    'alias': 'cowshed-london-2',
#    'name': 'Cowshed',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/15avBS143wYRw0GTHw6UtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cowshed-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5425758, 'longitude': -0.1556083},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': "115 Regent's Park Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8UR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["115 Regent's Park Road",
#      'London NW1 8UR',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3575.938807492533},
#   {'id': '-ATEXu2q4Oe4wPQeyrsILw',
#    'alias': 'princi-london',
#    'name': 'Princi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QLFgoDIBiLx2F0tpUIw7gQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/princi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 304,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5138629586873,
#     'longitude': -0.134387051472991},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '135 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0UT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['135 Wardour Street',
#      'London W1F 0UT',
#      'United Kingdom']},
#    'phone': '+442074788888',
#    'display_phone': '+44 20 7478 8888',
#    'distance': 157.59755401297926},
#   {'id': 'AH_Hk4-QQ7KbkIs4H6lfTQ',
#    'alias': 'black-sheep-coffee-london-14',
#    'name': 'Black Sheep Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3gIhZPoxINQqdA9KKSt9cg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-sheep-coffee-london-14?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5199084, 'longitude': -0.1340499},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5-7 Goodge Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1T 2PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5-7 Goodge Street',
#      'London W1T 2PD',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 797.4480439481582},
#   {'id': 'k-qIxL_IHDlXxlgDpNkN7Q',
#    'alias': 'ez-and-moss-london',
#    'name': 'EZ & Moss',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ItZEzaXsRlQSbo3-dg0ztg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ez-and-moss-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5501848, 'longitude': -0.1092206},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '183 Holloway Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N7 8LX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['183 Holloway Road',
#      'London N7 8LX',
#      'United Kingdom']},
#    'phone': '+442076199523',
#    'display_phone': '+44 20 7619 9523',
#    'distance': 4546.191125147666},
#   {'id': 'BNAddFkvoUGR1l6AL32p8w',
#    'alias': 'over-under-coffee-london-3',
#    'name': 'Over Under Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nlSAXEZwQAl5HFBHSWTpvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/over-under-coffee-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4923794, 'longitude': -0.1930041},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "181A Earl's Court Road",
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW5 9RD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["181A Earl's Court Road",
#      'London SW5 9RD',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4556.96556200919},
#   {'id': 'illIEFnTN27Skw0M6ntz1Q',
#    'alias': 'the-ra-grand-cafe-london',
#    'name': 'The RA Grand Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5DgRVNqB3l6LNMlC1PZPsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ra-grand-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5093544, 'longitude': -0.1399078},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Burlington House',
#     'address2': '',
#     'address3': 'Piccadilly',
#     'city': 'London',
#     'zip_code': 'W1J 0BD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Burlington House',
#      'Piccadilly',
#      'London W1J 0BD',
#      'United Kingdom']},
#    'phone': '+44442073008090',
#    'display_phone': '+44 442073008090',
#    'distance': 473.9521241627192},
#   {'id': '-EPJuMu8Qbr5azjHu_QOtg',
#    'alias': 'the-watch-house-london-5',
#    'name': 'The Watch House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/v6IlbI-P0BgzdTxXQcQn2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-watch-house-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4980461313304,
#     'longitude': -0.0810502413027092},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '199 Bermondsey Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 3UW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['199 Bermondsey Street',
#      'London SE1 3UW',
#      'United Kingdom']},
#    'phone': '+442074075431',
#    'display_phone': '+44 20 7407 5431',
#    'distance': 4140.698976372922},
#   {'id': '-ylzTrYtRJUJa2BuAInoyQ',
#    'alias': 'friends-of-ours-london',
#    'name': 'Friends of Ours',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/q5Fg1_UQtNmvOoIzrLzhAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/friends-of-ours-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 96,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5291189, 'longitude': -0.0836995},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61 Pitfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 6BU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Pitfield Street',
#      'London N1 6BU',
#      'United Kingdom']},
#    'phone': '+442076865525',
#    'display_phone': '+44 20 7686 5525',
#    'distance': 4041.3053965414406},
#   {'id': 'k7qmLDOGfESN8fDBQZZL7w',
#    'alias': '106-baker-st-london',
#    'name': '106 Baker St',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9CXBPhU2Ib_gv7QmtYAMCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/106-baker-st-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5207977, 'longitude': -0.1566825},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '106 Baker Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 6TW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['106 Baker Street',
#      'London W1U 6TW',
#      'United Kingdom']},
#    'phone': '+442074873372',
#    'display_phone': '+44 20 7487 3372',
#    'distance': 1689.8849777286025},
#   {'id': '-fLxQOd0pjTkQl4ttwR4XA',
#    'alias': 'books-for-cooks-london',
#    'name': 'Books for Cooks',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/REu7-q4WSa6QKKI6sYCNtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/books-for-cooks-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'bookstores', 'title': 'Bookstores'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cookingschools', 'title': 'Cooking Schools'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5159431, 'longitude': -0.2053744},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 Blenheim Cresent',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 1NN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Blenheim Cresent',
#      'London W11 1NN',
#      'United Kingdom']},
#    'phone': '+442072211992',
#    'display_phone': '+44 20 7221 1992',
#    'distance': 4820.047305934839},
#   {'id': '6ugop_2_fnetqRX6DbRNmA',
#    'alias': 'the-ivy-cafe-marylebone-london',
#    'name': 'The Ivy Cafe - Marylebone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/b-QqY82b4G-8fYxsCXn6Xg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ivy-cafe-marylebone-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5174429568542,
#     'longitude': -0.150753520220344},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '96 Marylebone Lane',
#     'address2': 'Marylebone',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['96 Marylebone Lane',
#      'Marylebone',
#      'London W1U',
#      'United Kingdom']},
#    'phone': '+442033010400',
#    'display_phone': '+44 20 3301 0400',
#    'distance': 1144.9781390024443},
#   {'id': 'JaveZcrYNz-Pq0UIjgWJCA',
#    'alias': 'egg-break-london',
#    'name': 'Egg Break',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FcjERvhFTXfYHIPi6uvQbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/egg-break-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 80,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.50832, 'longitude': -0.198022},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '30 Uxbridge Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 7TA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Uxbridge Street',
#      'London W8 7TA',
#      'United Kingdom']},
#    'phone': '+442035358300',
#    'display_phone': '+44 20 3535 8300',
#    'distance': 4312.433159863853},
#   {'id': 'cFCAYrs6LX17ucDFEWMXLg',
#    'alias': 'mihbaj-café-and-kitchen-london',
#    'name': 'Mihbaj Café & Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5g5DVb2Q7z4gmXG3AtDbOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mihbaj-caf%C3%A9-and-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.516163, 'longitude': -0.1744713},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '153 Praed Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['153 Praed Street',
#      'London W2 1RL',
#      'United Kingdom']},
#    'phone': '+442077063063',
#    'display_phone': '+44 20 7706 3063',
#    'distance': 2690.7690001080196},
#   {'id': 'ltNrgT5KBga_-G09KPKUGA',
#    'alias': 'ginger-and-white-london',
#    'name': 'Ginger & White',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7QXlwpFegZ2gwdzLskNX8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginger-and-white-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5554778031252, 'longitude': -0.178065},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "4 Perrin's Court",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 1QS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["4 Perrin's Court",
#      'London NW3 1QS',
#      'United Kingdom']},
#    'phone': '+442074319098',
#    'display_phone': '+44 20 7431 9098',
#    'distance': 5564.726459557364},
#   {'id': 'uN9nxbQlUmXUMv1kt8Ye1w',
#    'alias': 'saint-espresso-london-2',
#    'name': 'Saint Espresso',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6wpKqcs2qZXaLHdioBj9pQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saint-espresso-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5233293750657,
#     'longitude': -0.158073306083679},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '214 Baker Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW1',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['214 Baker Street', 'London NW1', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1924.4771101888414},
#   {'id': '4rpkLLSPzVRqdHlM9_-9Cw',
#    'alias': 'four-corners-cafe-london-2',
#    'name': 'Four Corners Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rq5jjv5YtDdYt9HJQ8OyEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/four-corners-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5003689, 'longitude': -0.1135442},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '12 Lower Marsh',
#     'address2': 'Waterloo',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Lower Marsh',
#      'Waterloo',
#      'London SE1 7RJ',
#      'United Kingdom']},
#    'phone': '+442086179591',
#    'display_phone': '+44 20 8617 9591',
#    'distance': 2080.282557645936},
#   {'id': 'JqVOEsAUuhoAu-uRtzMtFQ',
#    'alias': 'olivers-village-cafe-london',
#    'name': "Oliver's Village Cafe",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/oLC9A3lIJ-OnbFB-6qHhOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olivers-village-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5484962463379,
#     'longitude': -0.172924995422363},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '92 Belsize Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 5BE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['92 Belsize Lane',
#      'London NW3 5BE',
#      'United Kingdom']},
#    'phone': '+442078130048',
#    'display_phone': '+44 20 7813 0048',
#    'distance': 4721.389652496097},
#   {'id': 'rRSStigtOHSi7K8J0kEvsA',
#    'alias': 'the-buttery-café-london-2',
#    'name': 'The Buttery Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SVKu-DFYa9UjGQe_qt-l2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-buttery-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.558188, 'longitude': -0.175104},
#    'transactions': [],
#    'location': {'address1': 'Burgh House',
#     'address2': 'New End Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 1LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Burgh House',
#      'New End Square',
#      'London NW3 1LT',
#      'United Kingdom']},
#    'phone': '+442077942905',
#    'display_phone': '+44 20 7794 2905',
#    'distance': 5722.964667148881},
#   {'id': '7TJEcpp8t3OBkDYbCaPZYw',
#    'alias': 'green-and-fortune-london',
#    'name': 'Green & Fortune',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AShVyzU5mmBpU096qGgHsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/green-and-fortune-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'marketing', 'title': 'Marketing'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.534765, 'longitude': -0.1221951},
#    'transactions': [],
#    'location': {'address1': 'Kings Place',
#     'address2': '90 York Way',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Kings Place',
#      '90 York Way',
#      'London N1 9AG',
#      'United Kingdom']},
#    'phone': '+442070142847',
#    'display_phone': '+44 20 7014 2847',
#    'distance': 2634.9441713782553},
#   {'id': 'FM2fOny0zttmwnSeHCHzyA',
#    'alias': 'fabrique-bakery-london-5',
#    'name': 'Fabrique Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1-A9bxyUwournvQ4hL3sMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fabrique-bakery-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516469, 'longitude': -0.205223},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '212 Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 1LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['212 Portobello Road',
#      'London W11 1LA',
#      'United Kingdom']},
#    'phone': '+442072213721',
#    'display_phone': '+44 20 7221 3721',
#    'distance': 4813.9954429630825},
#   {'id': 'f8s8dT9Rm4359xUVHtiqRA',
#    'alias': 'black-cat-london',
#    'name': 'Black Cat',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RZHJY2Tw6cAtF7ZrT7vQTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-cat-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5513968, 'longitude': -0.055691},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '76 Clarence Road',
#     'address2': 'Hackney',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E5 8HB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['76 Clarence Road',
#      'Hackney',
#      'London E5 8HB',
#      'United Kingdom']},
#    'phone': '+442089857091',
#    'display_phone': '+44 20 8985 7091',
#    'distance': 7015.023023552639},
#   {'id': 'BJPoMcoKJxrs_QT4_PcL8A',
#    'alias': 'bloomsbury-cafe-london',
#    'name': 'Bloomsbury Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lGKxROCBx-YKn806nO8xWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bloomsbury-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5175164253045,
#     'longitude': -0.127287250243864},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '16 Bloomsbury Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3QA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Bloomsbury Street',
#      'London WC1B 3QA',
#      'United Kingdom']},
#    'phone': '+442076378400',
#    'display_phone': '+44 20 7637 8400',
#    'distance': 794.1799236505923},
#   {'id': 'iXVq9PcCT-a34FzaXbUagA',
#    'alias': 'scooter-caffè-london-2',
#    'name': 'Scooter Caffè',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/x9HNw_Kud2pJil8Zv5_8oA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scooter-caff%C3%A8-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.500341224864,
#     'longitude': -0.11381534473676},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '132 Lower Marsh',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7AE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['132 Lower Marsh',
#      'London SE1 7AE',
#      'United Kingdom']},
#    'phone': '+442076201421',
#    'display_phone': '+44 20 7620 1421',
#    'distance': 2068.3940056684514},
#   {'id': 'RYus9YxVxD-R8jm6xkDX8g',
#    'alias': 'red-door-london',
#    'name': 'Red Door',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Wpge_vSiPdmdj5nk00vX0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/red-door-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'galleries', 'title': 'Art Galleries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.481164, 'longitude': -0.009072},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10 Turnpin Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE10 9JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Turnpin Lane',
#      'London SE10 9JA',
#      'United Kingdom']},
#    'phone': '+442088582131',
#    'display_phone': '+44 20 8858 2131',
#    'distance': 9456.14762342682},
#   {'id': 'b04et4coHh_QwC9752mfSg',
#    'alias': 'cafe-soho-london',
#    'name': 'Cafe Soho',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CuI5mkRxStuL7Oh88QAlXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.513148, 'longitude': -0.135845},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '13 Ingestre Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0JG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Ingestre Place',
#      'London W1F 0JG',
#      'United Kingdom']},
#    'phone': '+442072878572',
#    'display_phone': '+44 20 7287 8572',
#    'distance': 38.33498879517009},
#   {'id': '1epk2D1-2-g08GAntFlySg',
#    'alias': 'konditor-london',
#    'name': 'Konditor',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QbRhycT_YxKWL-AX_fwlWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/konditor-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5042899533514,
#     'longitude': -0.110367141112856},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Cornwall Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8TW',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ['22 Cornwall Rd', 'London SE1 8TW', 'United Kingdom']},
#    'phone': '+442076333333',
#    'display_phone': '+44 20 7633 3333',
#    'distance': 2009.750808419612},
#   {'id': 'ZdifV49GCHMlBbERGZlZpw',
#    'alias': 'feya-london-2',
#    'name': 'Feya',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-gccV-HlbRORML4de4MBVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/feya-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4985063616543,
#     'longitude': -0.166267723613714},
#    'transactions': [],
#    'location': {'address1': '146 Brompton Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW3 1HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['146 Brompton Road',
#      'London SW3 1HX',
#      'United Kingdom']},
#    'phone': '+442078580858',
#    'display_phone': '+44 20 7858 0858',
#    'distance': 2634.397922050065},
#   {'id': 'ZT8M0TcLZXXcdPaMbk18Cg',
#    'alias': 'portobello-garden-caffe-london',
#    'name': "Portobello Garden Caffe'",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YEszzg8iWcZkmfE5vUkfxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/portobello-garden-caffe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5180217, 'longitude': -0.2069201},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '269b Portobello Road',
#     'address2': 'Notting Hill',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 1LR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['269b Portobello Road',
#      'Notting Hill',
#      'London W11 1LR',
#      'United Kingdom']},
#    'phone': '+442077928419',
#    'display_phone': '+44 20 7792 8419',
#    'distance': 4944.258290109093},
#   {'id': 'alG0_K6eXYLGTfnDhrEmzA',
#    'alias': 'mouse-tail-coffee-stories-london-4',
#    'name': 'Mouse Tail Coffee Stories',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CtUTWkIMYMmt8gEbQN9QLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mouse-tail-coffee-stories-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4978022252176,
#     'longitude': -0.0478901037367684},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Deal Porters Way',
#     'address2': 'Canada Water Plaza',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE16 7AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Deal Porters Way',
#      'Canada Water Plaza',
#      'London SE16 7AP',
#      'United Kingdom']},
#    'phone': '+447552961118',
#    'display_phone': '+44 7552 961118',
#    'distance': 6320.298054379184},
#   {'id': 'JV97uhTY3WFQPtm80YI5YA',
#    'alias': 'the-hive-sw6-london',
#    'name': 'The Hive SW6',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KIwR3sbDH4fF5X5Z71kXKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hive-sw6-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4754906, 'longitude': -0.2062352},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '670 Fulham Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 5RX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['670 Fulham Road',
#      'London SW6 5RX',
#      'United Kingdom']},
#    'phone': '+442077361118',
#    'display_phone': '+44 20 7736 1118',
#    'distance': 6399.945422268729},
#   {'id': 'C0WXN7VeBUNg4tg7Fu-N3A',
#    'alias': 'taylor-st-baristas-london-11',
#    'name': 'Taylor St Baristas',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Jox53dWlyjxJJZ03kqk7Pw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taylor-st-baristas-london-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4987165702106,
#     'longitude': -0.0149627110749048},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Exchange Tower',
#     'address2': '1 Harbour Exchange Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E14 9GB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Exchange Tower',
#      '1 Harbour Exchange Square',
#      'London E14 9GB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8520.021316952803},
#   {'id': 'mWIaThf7jXEFk-IzPfxRrQ',
#    'alias': 'garden-breakfast-cafe-london',
#    'name': 'Garden Breakfast Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QlmAbh_5E8hFLOM7DjwC9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/garden-breakfast-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.545783996582,
#     'longitude': -0.179408997297287},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3 Goldhurst Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 3HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Goldhurst Terrace',
#      'London NW6 3HX',
#      'United Kingdom']},
#    'phone': '+442073282295',
#    'display_phone': '+44 20 7328 2295',
#    'distance': 4739.603460462908},
#   {'id': 'lcrWCN-pZ9cdNOfk4Wq31g',
#    'alias': 'caffe-pascucci-london',
#    'name': 'Caffe Pascucci',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1GHeeTQD7BSfibLKzpgwgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-pascucci-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5086403, 'longitude': -0.1376713},
#    'transactions': [],
#    'location': {'address1': '189 Piccadilly',
#     'address2': 'Piccadilly',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 9EH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['189 Piccadilly',
#      'Piccadilly',
#      'London W1J 9EH',
#      'United Kingdom']},
#    'phone': '+442074329930',
#    'display_phone': '+44 20 7432 9930',
#    'distance': 498.341833425507},
#   {'id': '12y5F7hEoYAgur9eslpqCg',
#    'alias': 'kaffeine-london-2',
#    'name': 'Kaffeine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m1YMTCBNVuvdcmVaiu8wZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaffeine-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5168726, 'longitude': -0.137167},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '15 Eastcastle Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 3AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Eastcastle Street',
#      'London W1T 3AY',
#      'United Kingdom']},
#    'phone': '+442075806755',
#    'display_phone': '+44 20 7580 6755',
#    'distance': 456.6591394087493},
#   {'id': 'ETxJqTNvE3qc8iZfuwG4LA',
#    'alias': 'omotesando-koffee-london',
#    'name': 'Omotesando Koffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sMF1KusCmRg3OGnetIyLCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/omotesando-koffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5165656647651,
#     'longitude': -0.134790412002872},
#    'transactions': [],
#    'location': {'address1': '8 Newman Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1T 1PB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Newman Street',
#      'London W1T 1PB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 422.5395129497864},
#   {'id': '7fnq7-pePPEM2WaZ4CLg0g',
#    'alias': 'department-of-coffee-and-social-affairs-london',
#    'name': 'Department of Coffee and Social Affairs',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/W_xUKBTvCBaAlWlj7UjbUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/department-of-coffee-and-social-affairs-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5194646, 'longitude': -0.1089855},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14-16 Leather Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1N 7SU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14-16 Leather Lane',
#      'London EC1N 7SU',
#      'United Kingdom']},
#    'phone': '+442074196906',
#    'display_phone': '+44 20 7419 6906',
#    'distance': 2005.7501145358774},
#   {'id': 'Xqj98iIyqB3BDjkICbs8Eg',
#    'alias': 'lanark-coffee-london',
#    'name': 'Lanark Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/j8152h-IVPDUdEzAymvs4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lanark-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5309641, 'longitude': -0.0687264},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '262 Hackney Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7SJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['262 Hackney Road',
#      'London E2 7SJ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5069.425430530156}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#       Restaurant          Type Price Rating                  Address  \
# 0  The Attendant  Coffee & Tea     £    4.5           Downstairs 27A
# 1    Ole & Steen         Cafes                      1 Bedford Avenue
# 2     Cafe Babka         Cafes               44 Great Russell Street
# 3    Mill & Brew         Cafes     £      5          23 The Broadway
# 4     Flat White  Coffee & Tea    ££      4        17 Berwick Street
#
#          Lat       Lng                                                url  \
# 0  51.519247 -0.140738  https://www.yelp.com/biz/the-attendant-london-...
# 1  51.517686 -0.131210
# 2  51.518005 -0.126520
# 3  51.614431 -0.248377  https://www.yelp.com/biz/mill-and-brew-london-...
# 4  51.513644 -0.134773  https://www.yelp.com/biz/flat-white-london?adj...
#
#                        ID
# 0  PYwzVOvFIjwCMNYV5upPwg
# 1
# 2
# 3  RdVuh5xQAkzULoKtjXsE1Q
# 4  qtW1fg8pyGOXKJnAIk7Wmg

# %%
#3rd set of 50 records 101-150
lndr_params3 = {"term":"cafe","location":"London","limit":50,"offset":101}
lndr_response3 = requests.get(search_api_url, headers=headers, params=lndr_params3)
lndr3 = lndr_response3.json()
display(lndr3)
#print(lndr_response3.url)
#print(lndr_response3.status_code)
# Out:
# {'businesses': [{'id': '62YhaqIfyixjj4Z_W57D4w',
#    'alias': 'freud-café-london',
#    'name': 'Freud Café',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EIhBLf3vmtKipXrf9ZB0UA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/freud-caf%C3%A9-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 148,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5151658342822,
#     'longitude': -0.126793384552002},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '198 Shaftesbury Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 8JL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['198 Shaftesbury Avenue',
#      'London WC2H 8JL',
#      'United Kingdom']},
#    'phone': '+442072409933',
#    'display_phone': '+44 20 7240 9933',
#    'distance': 684.9371626235788},
#   {'id': 'pb1lTQ-SdGHT2wDkKzQRqA',
#    'alias': 'tiffins-london',
#    'name': 'Tiffins',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ACSLt7tXDXL-ZKvjVJO1Fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tiffins-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5196881, 'longitude': -0.1090228},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '24-26 Leather Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1N 7SU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24-26 Leather Lane',
#      'London EC1N 7SU',
#      'United Kingdom']},
#    'phone': '+442074045894',
#    'display_phone': '+44 20 7404 5894',
#    'distance': 2005.6322105383317},
#   {'id': '91TQLypsN7trt-EyX8TgBQ',
#    'alias': 'daisy-green-london-2',
#    'name': 'Daisy Green',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ythY0ZkbjY3cYODreg4hLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daisy-green-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5148104, 'longitude': -0.1579352},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Seymour Street',
#     'address2': 'Marble Arch',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Seymour Street',
#      'Marble Arch',
#      'London W1H 7HX',
#      'United Kingdom']},
#    'phone': '+442077233301',
#    'display_phone': '+44 20 7723 3301',
#    'distance': 1536.7313570216975},
#   {'id': 'bhfWGN9enSLFEa-LYiJfBA',
#    'alias': 'saint-aymes-london-2',
#    'name': 'Saint Aymes',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HMJK1sq0K1S8A1TM_I-8Iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saint-aymes-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'chocolate', 'title': 'Chocolatiers & Shops'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5142499, 'longitude': -0.16675},
#    'transactions': [],
#    'location': {'address1': '59 Connaught Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 2BB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['59 Connaught Street',
#      'London W2 2BB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2136.82605143008},
#   {'id': 'wzDJaIeVV89GVycKwMMeyw',
#    'alias': 'kioskafé-london-2',
#    'name': 'Kioskafé',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4jNvSE6Jqv2aCu7YTZcQng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kioskaf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'mags', 'title': 'Newspapers & Magazines'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.516821580645,
#     'longitude': -0.172688003330827},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '31 Norfolk Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1QH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['31 Norfolk Place',
#      'London W2 1QH',
#      'United Kingdom']},
#    'phone': '+442031114242',
#    'display_phone': '+44 20 3111 4242',
#    'distance': 2580.144462242365},
#   {'id': 'ypsFAFBmx2cUq1DZ5esZRA',
#    'alias': 'silverberry-deli-and-kitchen-london',
#    'name': 'Silverberry Deli & Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uAEsyPmbhweFlgcQqlkEMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/silverberry-deli-and-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5540823038372,
#     'longitude': -0.165075874311875},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 Pond Street',
#     'address2': 'Hampstead',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 2PS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Pond Street',
#      'Hampstead',
#      'London NW3 2PS',
#      'United Kingdom']},
#    'phone': '+442077945461',
#    'display_phone': '+44 20 7794 5461',
#    'distance': 5009.2325017215735},
#   {'id': 'MIKUeHBDQs46i6YOVeNKyw',
#    'alias': 'h-r-higgins-london',
#    'name': 'H R Higgins',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eAfRQlbtrCwZ8MP0k8Uisw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/h-r-higgins-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5129642, 'longitude': -0.1508551},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '79 Duke Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1K 5AS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['79 Duke Street', 'London W1K 5AS', 'United Kingdom']},
#    'phone': '+442074918819',
#    'display_phone': '+44 20 7491 8819',
#    'distance': 1031.1420005559974},
#   {'id': 'Sh_PrXavTAk2d5jTs_onuQ',
#    'alias': 'nordic-bakery-london',
#    'name': 'Nordic Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y1r_R3BokRhDYZIaF0XB6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nordic-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 118,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'scandinavian', 'title': 'Scandinavian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5114297969411,
#     'longitude': -0.13674108684063},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 Golden Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9JG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Golden Square',
#      'London W1F 9JG',
#      'United Kingdom']},
#    'phone': '+442032301077',
#    'display_phone': '+44 20 3230 1077',
#    'distance': 165.48625457765309},
#   {'id': 't9-_U2-WmaIee3XDB0Tz0w',
#    'alias': 'hotel-café-royal-london',
#    'name': 'Hotel Café Royal',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Jnx6mmFqDAEbaSkqyvdMKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-caf%C3%A9-royal-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 65,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.510171, 'longitude': -0.135962},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '68 Regent Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 4DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['68 Regent Street',
#      'London W1B 4DY',
#      'United Kingdom']},
#    'phone': '+442074063333',
#    'display_phone': '+44 20 7406 3333',
#    'distance': 296.2812185491074},
#   {'id': 'nBHgQH6Fo7VZ5ipeV9FZmA',
#    'alias': 'bonne-bouche-london',
#    'name': 'Bonne Bouche',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qrnNxCG7Iflid-AiSnSzew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bonne-bouche-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5181053211288,
#     'longitude': -0.151716128809521},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '2-3 Thayer Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 3JB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2-3 Thayer Street',
#      'London W1U 3JB',
#      'United Kingdom']},
#    'phone': '+442074869584',
#    'display_phone': '+44 20 7486 9584',
#    'distance': 1238.0218508033952},
#   {'id': '1TBmcRK1gywVVRHYYr7R0Q',
#    'alias': 'el-and-n-london-2',
#    'name': 'EL&N',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eV5QcWA8peOvw15Ns6A5Aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-and-n-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4998051, 'longitude': -0.1620998},
#    'transactions': [],
#    'location': {'address1': '42 Hans Cres',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1X 0LZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 Hans Cres', 'London SW1X 0LZ', 'United Kingdom']},
#    'phone': '+442070520130',
#    'display_phone': '+44 20 7052 0130',
#    'distance': 2322.608342949373},
#   {'id': '3ykZ2dHZfz5rVN0YC3uM9w',
#    'alias': 'black-sheep-coffee-london-28',
#    'name': 'Black Sheep Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/33UiIHjiHULW7iGc5HQ3Ug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-sheep-coffee-london-28?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.524656, 'longitude': -0.141609},
#    'transactions': [],
#    'location': {'address1': '338 Euston Road',
#     'address2': 'Ground floor',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 3BT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['338 Euston Road',
#      'Ground floor',
#      'London NW1 3BT',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1371.344607870066},
#   {'id': 'MzF9nlCdHZOaL5ocfY7QqQ',
#    'alias': 'bar-italia-london',
#    'name': 'Bar Italia',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oh5WxAHehBTJD15XgVui2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-italia-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 109,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.513425, 'longitude': -0.131236},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '22 Frith Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 4RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Frith Street',
#      'London W1D 4RP',
#      'United Kingdom']},
#    'phone': '+442074374520',
#    'display_phone': '+44 20 7437 4520',
#    'distance': 331.76147365439056},
#   {'id': '6cv-z48HnGcMZMF2jdeYzw',
#    'alias': 'the-marylebone-kitchen-marylebone',
#    'name': 'The Marylebone Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lhpXtUuhqYXPix0dWkZM2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-marylebone-kitchen-marylebone?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5197623, 'longitude': -0.1639772},
#    'transactions': [],
#    'location': {'address1': '106 York Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Marylebone',
#     'zip_code': 'W1H 4QN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['106 York Street',
#      'Marylebone W1H 4QN',
#      'United Kingdom']},
#    'phone': '+442077247552',
#    'display_phone': '+44 20 7724 7552',
#    'distance': 2086.3362670400315},
#   {'id': 'O3WaROs_7OFbYv4B-7m02Q',
#    'alias': 'polo-24-hour-bar-london-2',
#    'name': 'Polo 24 Hour Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4GzyD8FBMGDA8CHyN_fX-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/polo-24-hour-bar-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 100,
#    'categories': [{'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.517821, 'longitude': -0.080269},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '176 Bishopsgate',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2M 4NQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['176 Bishopsgate',
#      'London EC2M 4NQ',
#      'United Kingdom']},
#    'phone': '+442072834889',
#    'display_phone': '+44 20 7283 4889',
#    'distance': 3893.038073822518},
#   {'id': 'ztuEuIDjVTJMklB2OP3rpg',
#    'alias': 'ty-seven-dials-timberyard-london-2',
#    'name': 'TY Seven Dials - Timberyard',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Gr5lHKB84DjJGw8ESo5I6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ty-seven-dials-timberyard-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 138,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5128577362728,
#     'longitude': -0.127308054907987},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "7 Upper St Martin's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["7 Upper St Martin's Lane",
#      'London WC2H 9DL',
#      'United Kingdom']},
#    'phone': '+442032172009',
#    'display_phone': '+44 20 3217 2009',
#    'distance': 598.4373905869091},
#   {'id': 'BNdzjiLoibX1uSH4kAQy5w',
#    'alias': 'the-bike-shed-london',
#    'name': 'The Bike Shed',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_zYjKPcPg4BE91Bl7tVPUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bike-shed-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'accessories', 'title': 'Accessories'},
#     {'alias': 'themedcafes', 'title': 'Themed Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5270903, 'longitude': -0.0782151},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '384 Old Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 9LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['384 Old Street',
#      'London EC1V 9LT',
#      'United Kingdom']},
#    'phone': '+442077298114',
#    'display_phone': '+44 20 7729 8114',
#    'distance': 4257.350530218552},
#   {'id': '9kYUIi9guLcWh3iFOJ_vWg',
#    'alias': 'knockbox-coffee-london',
#    'name': 'Knockbox Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IrDnvf2dRXzDwYW9xz__yA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/knockbox-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5211323, 'longitude': -0.1180363},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '29 Lambs Conduit Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 3NG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['29 Lambs Conduit Street',
#      'London WC1N 3NG',
#      'United Kingdom']},
#    'phone': '+442034897325',
#    'display_phone': '+44 20 3489 7325',
#    'distance': 1545.4931234557102},
#   {'id': 'fp5po-wno5RLU4Rz0q0h-w',
#    'alias': 'my-place-soho-london',
#    'name': 'My Place Soho',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gnMfIijyZhFXOyvJPP88ZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-place-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5138405, 'longitude': -0.1346902},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '21 Berwick Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1F 0PZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21 Berwick Street',
#      'London W1F 0PZ',
#      'United Kingdom']},
#    'phone': '+442034172829',
#    'display_phone': '+44 20 3417 2829',
#    'distance': 141.97901027026617},
#   {'id': 'KBTZHuvXVCwEskNtj0Q1SA',
#    'alias': 'italian-gardens-cafe-london',
#    'name': 'Italian Gardens Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Egmi4aUdIR97Yhl9KT3v8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/italian-gardens-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5115726564169,
#     'longitude': -0.175203145592036},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '61 Bayswater Road',
#     'address2': 'Hyde Park - Marlborough Gate',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 3PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Bayswater Road',
#      'Hyde Park - Marlborough Gate',
#      'London W2 3PH',
#      'United Kingdom']},
#    'phone': '+443000612000',
#    'display_phone': '+44 300 061 2000',
#    'distance': 2719.616092978104},
#   {'id': 'aYd2mlWPlQmJdKHbiWq0PA',
#    'alias': 'pattern-coffee-london',
#    'name': 'Pattern Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZXSktRmEi6hPrSVc-we4JQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pattern-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.532962, 'longitude': -0.119133},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '82 Caledonian Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9DN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['82 Caledonian Rd',
#      'London N1 9DN',
#      'United Kingdom']},
#    'phone': '+442078371981',
#    'display_phone': '+44 20 7837 1981',
#    'distance': 2523.2727710781455},
#   {'id': 'ghg0SAC1cuKkk46ji-M9Kw',
#    'alias': 'the-black-lab-coffee-house-london',
#    'name': "'The Black Lab' Coffee House",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/e_hPHnpzTNA0ezHfxHGFiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-black-lab-coffee-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4610903556983,
#     'longitude': -0.138673064112254},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18 Clapham Common South Side',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW4 7AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Clapham Common South Side',
#      'London SW4 7AB',
#      'United Kingdom']},
#    'phone': '+442077388441',
#    'display_phone': '+44 20 7738 8441',
#    'distance': 5756.8687201302955},
#   {'id': 'Nb7nzRoJdGi74Q1TOTcwUw',
#    'alias': 'sally-white-london',
#    'name': 'Sally White',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/i17osVd1Ku5gIk0J833JOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sally-white-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4872522, 'longitude': -0.1111273},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '353 Kennington Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE11 4QE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['353 Kennington Road',
#      'London SE11 4QE',
#      'United Kingdom']},
#    'phone': '+442075820066',
#    'display_phone': '+44 20 7582 0066',
#    'distance': 3338.909143450355},
#   {'id': 'x58LDkXGU7vC8-KRDlS9Mw',
#    'alias': 'raison-d-etre-london',
#    'name': "Raison D'Etre",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GNL9SAtkBRabO34z0GOmqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raison-d-etre-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.493706018346,
#     'longitude': -0.17628170716244},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '18 Bute Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3EX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Bute Street', 'London SW7 3EX', 'United Kingdom']},
#    'phone': '+442075845008',
#    'display_phone': '+44 20 7584 5008',
#    'distance': 3509.3036349562817},
#   {'id': 'wnUHPVeubkSIEAF0nqNxBg',
#    'alias': 'i-will-kill-again-london',
#    'name': 'I Will Kill Again',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/p9E9cW9_P8hEKLI6DTDpWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/i-will-kill-again-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5472640626661,
#     'longitude': -0.0468713453717017},
#    'transactions': [],
#    'location': {'address1': 'Arch 216 Dark Arts Coffee',
#     'address2': '217A Ponsford Street',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E9 6JU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Arch 216 Dark Arts Coffee',
#      '217A Ponsford Street',
#      'London E9 6JU',
#      'United Kingdom']},
#    'phone': '+442037740131',
#    'display_phone': '+44 20 3774 0131',
#    'distance': 7254.708071911209},
#   {'id': 'Lrfm0sdK45KHT373xrAgkA',
#    'alias': 'cafe-olive-london-2',
#    'name': 'Cafe Olive',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tcwJYPLaCf1wrwtQvTQ_MQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-olive-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5456429, 'longitude': -0.0834334},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '192 Southgate Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 3HU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['192 Southgate Road',
#      'London N1 3HU',
#      'United Kingdom']},
#    'phone': '+442079237900',
#    'display_phone': '+44 20 7923 7900',
#    'distance': 5155.139656532509},
#   {'id': 'cTNNBcdxUH-hMCwKcqonzg',
#    'alias': 'cinq-london',
#    'name': 'Cinq',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cinq-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5087032, 'longitude': -0.1376422},
#    'transactions': [],
#    'location': {'address1': '193 Piccadilly',
#     'address2': "St James's",
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1J 9EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['193 Piccadilly',
#      "St James's",
#      'London W1J 9EU',
#      'United Kingdom']},
#    'phone': '+442072870627',
#    'display_phone': '+44 20 7287 0627',
#    'distance': 474.0817794901813},
#   {'id': '-MMUfvKPJXeo5ONoHSw7Zw',
#    'alias': 'double-six-cafe-london',
#    'name': 'Double Six Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Eevd-YQNFeUZFgBz6cpc2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/double-six-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5295715, 'longitude': -0.1330154},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '66 Eversholt Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 1DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Eversholt Street',
#      'London NW1 1DA',
#      'United Kingdom']},
#    'phone': '+442073870262',
#    'display_phone': '+44 20 7387 0262',
#    'distance': 1868.62168679472},
#   {'id': 'lMxu8jhSIb_liUki8cy2Wg',
#    'alias': 'chamomile-london',
#    'name': 'Chamomile',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/L1XvSQmXkGbyxSqLdzqEWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chamomile-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5456005, 'longitude': -0.1623197},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "45 England's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 4YD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["45 England's Lane",
#      'London NW3 4YD',
#      'United Kingdom']},
#    'phone': '+442075864580',
#    'display_phone': '+44 20 7586 4580',
#    'distance': 4074.0720076605753},
#   {'id': 'Z_KQWTzlUVWjVoFd0b77aw',
#    'alias': 'said-london',
#    'name': 'Said',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/r7ojZUtSeE9UPXJ2Flijfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/said-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'chocolate', 'title': 'Chocolatiers & Shops'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5132248, 'longitude': -0.136738},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '41 Broadwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41 Broadwick Street',
#      'London W1F 9QL',
#      'United Kingdom']},
#    'phone': '+442074371584',
#    'display_phone': '+44 20 7437 1584',
#    'distance': 69.30726559279131},
#   {'id': 'NokujITOpBd_VLAtAYJrTg',
#    'alias': 'the-old-dairy-cafe-london',
#    'name': 'The Old Dairy Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IOGiWDuUTjE3CqHwfWG-BQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-old-dairy-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5234260559082,
#     'longitude': -0.141537994146347},
#    'transactions': [],
#    'location': {'address1': '35 Conway Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 6BW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35 Conway Street',
#      'London W1T 6BW',
#      'United Kingdom']},
#    'phone': '+442073832900',
#    'display_phone': '+44 20 7383 2900',
#    'distance': 1239.3376956541763},
#   {'id': 'sTjZJB20joSHE8oVPHs1Cw',
#    'alias': 'covent-garden-grind-london',
#    'name': 'Covent Garden Grind',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c7YW3mmPah5JplPL-fFPbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/covent-garden-grind-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5110479046224,
#     'longitude': -0.122459969000028},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '42 Maiden Lane',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 7LJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 Maiden Lane',
#      'Covent Garden',
#      'London WC2E 7LJ',
#      'United Kingdom']},
#    'phone': '+442030191801',
#    'display_phone': '+44 20 3019 1801',
#    'distance': 954.8611659358846},
#   {'id': 'NlmOy2zX4J34y_tLpVjVog',
#    'alias': 'ginger-jules-london',
#    'name': 'Ginger Jules',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3OYaH6MGYkodWttLlc_rbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginger-jules-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.524925, 'longitude': -0.131659},
#    'transactions': [],
#    'location': {'address1': 'Gordon Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 0PY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Gordon Square', 'London WC1H 0PY', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1363.076113082657},
#   {'id': 'wqZucWHydm2qx-iUCUyJpQ',
#    'alias': 'e-pellicci-london',
#    'name': 'E Pellicci',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wtUxdaKR9UoXTT3eYcjMGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/e-pellicci-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5265159984371,
#     'longitude': -0.0635611602914123},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '332 Bethnal Green Road',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E2 0AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['332 Bethnal Green Road',
#      'London E2 0AG',
#      'United Kingdom']},
#    'phone': '+442077394873',
#    'display_phone': '+44 20 7739 4873',
#    'distance': 5234.916021601817},
#   {'id': 'Lr5_1a2rIyzA7W-6UPKS-A',
#    'alias': '26-grains-london',
#    'name': '26 Grains',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ci9nQvD05RdQ7k56unmJwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/26-grains-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5143765, 'longitude': -0.126556},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "1 Neal's Yard",
#     'address2': 'Covent Garden',
#     'address3': 'Seven Dials',
#     'city': 'London',
#     'zip_code': 'WC2H 9DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["1 Neal's Yard",
#      'Covent Garden',
#      'Seven Dials',
#      'London WC2H 9DP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 672.6546229251097},
#   {'id': 'CIpC-cP7x5NyYPtOXLpuTg',
#    'alias': 'chloes-espresso-london',
#    'name': "Chloe's Espresso",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MhtCD9J_H9Z2-y0YAA2cGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chloes-espresso-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5432794, 'longitude': -0.1550517},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "123 Regent's Park Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8BE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["123 Regent's Park Road",
#      'London NW1 8BE',
#      'United Kingdom']},
#    'phone': '+442077223999',
#    'display_phone': '+44 20 7722 3999',
#    'distance': 3633.821205235555},
#   {'id': 'exjNWU4T_uzKOtH3uHIutQ',
#    'alias': 'camden-coffee-house-london',
#    'name': 'Camden Coffee House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bN0xUYpHqvIrvOD59TcF0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camden-coffee-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'restaurants', 'title': 'Restaurants'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5399813, 'longitude': -0.1407954},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '30 Camden Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 9DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Camden Road', 'London NW1 9DP', 'United Kingdom']},
#    'phone': '+442074289477',
#    'display_phone': '+44 20 7428 9477',
#    'distance': 3029.1577816380923},
#   {'id': 'JufEVrCH41pMNDuS9_N-gw',
#    'alias': 'the-fields-beneath-london',
#    'name': 'The Fields Beneath',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/L4ougAp44U0FZHCIJjsQwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-fields-beneath-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5466077925974,
#     'longitude': -0.146729706191089},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '52a Prince of Wales Road',
#     'address2': 'Kentish Town West Station',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW5 3LN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['52a Prince of Wales Road',
#      'Kentish Town West Station',
#      'London NW5 3LN',
#      'United Kingdom']},
#    'phone': '+442074248838',
#    'display_phone': '+44 20 7424 8838',
#    'distance': 3828.5426145620913},
#   {'id': 'tHKiDGayBq4RD0oL-DutCg',
#    'alias': 'bloomsbury-coffee-house-london',
#    'name': 'Bloomsbury Coffee House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CAUiQ6-F7FTloOIkmSnTyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bloomsbury-coffee-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.525250540481,
#     'longitude': -0.126389201213277},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '20 Tavistock Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 9RE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Tavistock Place',
#      'London WC1H 9RE',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1530.9764438322995},
#   {'id': 'kOmkk63gMmsKk0Wve5aJRA',
#    'alias': 'the-garden-café-london-4',
#    'name': 'The Garden Café',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LG14Vavn8I5mnEQd6g6ANA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-garden-caf%C3%A9-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5268751462841,
#     'longitude': -0.154452323913574},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Inner Circle',
#     'address2': "Regent's Park",
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 4NU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Inner Circle',
#      "Regent's Park",
#      'London NW1 4NU',
#      'United Kingdom']},
#    'phone': '+442079355729',
#    'display_phone': '+44 20 7935 5729',
#    'distance': 2018.6552787350033},
#   {'id': 'J38s3iokvd30sRGi5uB9lA',
#    'alias': 'l-eto-caffe-london',
#    'name': "L'Eto Caffe",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/glLwggFfv-PFoCGgzDIynA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-eto-caffe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 124,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514301, 'longitude': -0.134786},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '155 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8WG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['155 Wardour Street',
#      'London W1F 8WG',
#      'United Kingdom']},
#    'phone': '+442074944991',
#    'display_phone': '+44 20 7494 4991',
#    'distance': 181.95299001691527},
#   {'id': 'U_XeFWW1Lttdq22txTABMw',
#    'alias': 'gails-bakery-neo-bankside-london',
#    'name': "GAIL's Bakery Neo Bankside",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CEfkaYA0zFoAlNcdiNt_aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-neo-bankside-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5066352772979,
#     'longitude': -0.100412668500134},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit C Neo Bankside',
#     'address2': '70 Holland Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9NX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit C Neo Bankside',
#      '70 Holland Road',
#      'London SE1 9NX',
#      'United Kingdom']},
#    'phone': '+442079280621',
#    'display_phone': '+44 20 7928 0621',
#    'distance': 2554.576460738087},
#   {'id': 'E_3NekwxctQ3BzN7tLKk2A',
#    'alias': 'casa-tua-london-2',
#    'name': 'Casa Tua',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m7FJ2XmVjJQ-Sx0umK6pmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-tua-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5276449011142,
#     'longitude': -0.123588235886524},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '106 Cromer Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 8BZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['106 Cromer Street',
#      'London WC1H 8BZ',
#      'United Kingdom']},
#    'phone': '+442078331483',
#    'display_phone': '+44 20 7833 1483',
#    'distance': 1855.7864052166005},
#   {'id': 'FDTx9-86N50Xa2Ojv65YcQ',
#    'alias': 'fabrique-bakery-fitzrovia',
#    'name': 'Fabrique Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qnnW-uG8iKNCwRHaw-JIIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fabrique-bakery-fitzrovia?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5191208284928,
#     'longitude': -0.136215056815711},
#    'transactions': [],
#    'location': {'address1': '53 Goodge Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Fitzrovia',
#     'zip_code': 'W1T 1TG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['53 Goodge Street',
#      'Fitzrovia W1T 1TG',
#      'United Kingdom']},
#    'phone': '+442075804227',
#    'display_phone': '+44 20 7580 4227',
#    'distance': 699.1236945245441},
#   {'id': 'rSIq7KI098VKIhgo4SBSuQ',
#    'alias': 'photographers-gallery-café-london',
#    'name': "Photographer's Gallery Café",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xgE-LIENQ_ODO4CMhRI3bQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/photographers-gallery-caf%C3%A9-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514787, 'longitude': -0.138822},
#    'transactions': [],
#    'location': {'address1': 'Ramillies Street 16-18',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1F 7LW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Ramillies Street 16-18',
#      'London W1F 7LW',
#      'United Kingdom']},
#    'phone': '+448452621618',
#    'display_phone': '+44 845 262 1618',
#    'distance': 293.980849183896},
#   {'id': 'uCNH9aBdcJdRP6D6JiW1lg',
#    'alias': 'love-walk-café-london-2',
#    'name': 'Love Walk Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zB9imIm6YA_djRExqxDriA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/love-walk-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4717102050781,
#     'longitude': -0.092739999294281},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '81 Denmark Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE5 8RS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['81 Denmark Hill',
#      'London SE5 8RS',
#      'United Kingdom']},
#    'phone': '+442077039898',
#    'display_phone': '+44 20 7703 9898',
#    'distance': 5464.724029224635},
#   {'id': 'wCjU2KuTntCZDCZSIS1Uxw',
#    'alias': 'the-ivy-kensington-brasserie-london',
#    'name': 'The Ivy Kensington Brasserie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/O2iBlelJiZe11wXmi9NsIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ivy-kensington-brasserie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5015677, 'longitude': -0.1921797},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '96 Kensington High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4SG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['96 Kensington High Street',
#      'London W8 4SG',
#      'United Kingdom']},
#    'phone': '+442033010500',
#    'display_phone': '+44 20 3301 0500',
#    'distance': 4091.0923076045005},
#   {'id': '8fOwzD6Ksk7fFinUzozVvg',
#    'alias': 'artisan-london-3',
#    'name': 'Artisan',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NVdCCZcVwtt7CUihU2T53w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/artisan-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.513316, 'longitude': -0.306361},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '32 New Broadway Ealing',
#     'address2': 'Ealing London',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W5 2XA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['32 New Broadway Ealing',
#      'Ealing London',
#      'London W5 2XA',
#      'United Kingdom']},
#    'phone': '+442079983450',
#    'display_phone': '+44 20 7998 3450',
#    'distance': 11815.45890187267},
#   {'id': 'N0kfB-iYOb3Fs9RkOfwBlA',
#    'alias': 'ginos-coffee-bar-london',
#    'name': "Gino's Coffee Bar",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/opzj7LhMMQGw3VYx6vp03g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginos-coffee-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5222244262695,
#     'longitude': -0.162099003791809},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Great Central St',
#     'address2': 'London',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 6JH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Great Central St',
#      'London',
#      'London NW1 6JH',
#      'United Kingdom']},
#    'phone': '+442072628105',
#    'display_phone': '+44 20 7262 8105',
#    'distance': 2088.591889208201},
#   {'id': 'khnhd6DnBb-zIfZEC1y9zg',
#    'alias': 'the-waiting-room-london-2',
#    'name': 'The Waiting Room',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/29nNTUak9XjUXqkiRvn-Kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-waiting-room-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4792366027832,
#     'longitude': -0.0259060002863407},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '142 Deptford High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE8 3PQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['142 Deptford High Street',
#      'London SE8 3PQ',
#      'United Kingdom']},
#    'phone': '+44442078120105',
#    'display_phone': '+44 442078120105',
#    'distance': 8487.784849357136}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#     Restaurant                   Type Price Rating                 Address  \
# 0   Freud Café                Lounges    ££      4  198 Shaftesbury Avenue
# 1      Tiffins           Coffee & Tea     £      4      24-26 Leather Lane
# 2  Daisy Green                  Cafes    ££      4       20 Seymour Street
# 3  Saint Aymes  Venues & Event Spaces                  59 Connaught Street
# 4     Kioskafé           Coffee & Tea    ££    4.5        31 Norfolk Place
#
#          Lat       Lng                                                url  \
# 0  51.515166 -0.126793  https://www.yelp.com/biz/freud-caf%C3%A9-londo...
# 1  51.519688 -0.109023  https://www.yelp.com/biz/tiffins-london?adjust...
# 2  51.514810 -0.157935  https://www.yelp.com/biz/daisy-green-london-2?...
# 3  51.514250 -0.166750
# 4  51.516822 -0.172688  https://www.yelp.com/biz/kioskaf%C3%A9-london-...
#
#                        ID
# 0  62YhaqIfyixjj4Z_W57D4w
# 1  pb1lTQ-SdGHT2wDkKzQRqA
# 2  91TQLypsN7trt-EyX8TgBQ
# 3
# 4  wzDJaIeVV89GVycKwMMeyw

# %%
#4th set of 50 records 151-200
lndr_params4 = {"term":"cafe","location":"London","limit":50,"offset":151}
lndr_response4 = requests.get(search_api_url, headers=headers, params=lndr_params4)
lndr4 = lndr_response4.json()
display(lndr4)
#print(lndr_response4.url)
#print(lndr_response4.status_code)
# Out:
# {'businesses': [{'id': 'vLX78mD-aZPd-3AyGcryWA',
#    'alias': 'tap-coffee-london',
#    'name': 'Tap Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7dcT0teObKHsFJj_lkgIFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tap-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515468, 'longitude': -0.135823},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '193 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8ZF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['193 Wardour Street',
#      'London W1F 8ZF',
#      'United Kingdom']},
#    'phone': '+442075802163',
#    'display_phone': '+44 20 7580 2163',
#    'distance': 291.8006048606978},
#   {'id': 'ylB8-VeLxJq7ZZabJvut5Q',
#    'alias': 'peggy-porschen-london-2',
#    'name': 'Peggy Porschen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5jdkgNK9PWg591kCrQlU1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peggy-porschen-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.48651, 'longitude': -0.17089},
#    'transactions': [],
#    'location': {'address1': "219 King's Road",
#     'address2': '',
#     'address3': 'Chelsea',
#     'city': 'London',
#     'zip_code': 'SW3 5EJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["219 King's Road",
#      'Chelsea',
#      'London SW3 5EJ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3794.5778230405813},
#   {'id': 'NNqPxJdhQRziK8UJpjw2_A',
#    'alias': 'the-pie-man-london',
#    'name': 'The Pie Man',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1pGLGf7QXGsiYQH6ViYeEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pie-man-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'catering', 'title': 'Caterers'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4906543605701,
#     'longitude': -0.166865786906551},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '16 Cale Street',
#     'address2': 'Chelsea Green',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 3QU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Cale Street',
#      'Chelsea Green',
#      'London SW3 3QU',
#      'United Kingdom']},
#    'phone': '+442072250587',
#    'display_phone': '+44 20 7225 0587',
#    'distance': 3265.0905230511},
#   {'id': 'XN7K4g1Wq-93WYvg85EgMg',
#    'alias': 'the-gentlemen-baristas-london',
#    'name': 'The Gentlemen Baristas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/weXGI3HolMjieVD466xwyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-gentlemen-baristas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.503841999477,
#     'longitude': -0.0947035655992168},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '63 Union Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1SG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63 Union Street',
#      'London SE1 1SG',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3025.052485481412},
#   {'id': 'gmQu79rLOaaKmdiXODvH0Q',
#    'alias': 'café-par-london',
#    'name': 'Café Par',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3-57NwGvPiS5fJ6wJ1bjJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-par-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.522873, 'longitude': -0.102466},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '115 St John Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 4JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['115 St John Street',
#      'London EC1V 4JA',
#      'United Kingdom']},
#    'phone': '+442074907928',
#    'display_phone': '+44 20 7490 7928',
#    'distance': 2580.056596229638},
#   {'id': 'P_maLzj1XGKe19PqsZNG5g',
#    'alias': 'the-coffee-room-london',
#    'name': 'The Coffee Room',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jLALpDgQGARTjnXgUlmZHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-coffee-room-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5264645, 'longitude': -0.0354996},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '6A Grove Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E3 5AX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6A Grove Road', 'London E3 5AX', 'United Kingdom']},
#    'phone': '+447760108896',
#    'display_phone': '+44 7760 108896',
#    'distance': 7113.913218650372},
#   {'id': 'A-IeaZPEGOcqMvVc4vw8Kw',
#    'alias': 'cafe-dylan-dog-london',
#    'name': 'Cafe Dylan Dog',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RL2FuEjpPpTBxSrxijIHRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-dylan-dog-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5148811, 'longitude': -0.1765969},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '7 Craven Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3BP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Craven Road', 'London W2 3BP', 'United Kingdom']},
#    'phone': '+442077238027',
#    'display_phone': '+44 20 7723 8027',
#    'distance': 2814.277784990465},
#   {'id': 'xV9SoZfU4ZyiM7zbpgkJVQ',
#    'alias': 'wellcome-kitchen-london-2',
#    'name': 'Wellcome Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6E_OaJGcYeCT0RuZiq7_7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wellcome-kitchen-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5259056091309,
#     'longitude': -0.133955001831055},
#    'transactions': [],
#    'location': {'address1': '183 Euston Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW1 2BE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['183 Euston Road',
#      'London NW1 2BE',
#      'United Kingdom']},
#    'phone': '+442076112222',
#    'display_phone': '+44 20 7611 2222',
#    'distance': 1460.3153301566247},
#   {'id': 'uA_H2UI3nPL7-L11G61-wA',
#    'alias': 'hackney-coffee-company-london',
#    'name': 'Hackney Coffee Company',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xliZ9Rmj6VT4o_mBM0i7Hw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hackney-coffee-company-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5325459, 'longitude': -0.0584213},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '503 Hackney Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 9ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['503 Hackney Road',
#      'London E2 9ED',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5794.75520452962},
#   {'id': 'MliUZtEV91sjiNN-OgLq_A',
#    'alias': 'prufrock-coffee-london-2',
#    'name': 'Prufrock Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JdIpUpy8TrYo42xBatSwgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prufrock-coffee-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51997, 'longitude': -0.10958},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '23-25 Leather Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1N 7TE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23-25 Leather Lane',
#      'London EC1N 7TE',
#      'United Kingdom']},
#    'phone': '+442072420467',
#    'display_phone': '+44 20 7242 0467',
#    'distance': 1995.269333811344},
#   {'id': 'YXLHj8H0V-6NlczR2DuZqA',
#    'alias': 'wesleys-cafe-london',
#    'name': 'Wesleys Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EeiJFdrP60uCNlVPahjYmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wesleys-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'restaurants', 'title': 'Restaurants'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.500258, 'longitude': -0.129931},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Central Hall Westminster',
#     'address2': "Storey's Gate",
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1H 9NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Central Hall Westminster',
#      "Storey's Gate",
#      'London SW1H 9NH',
#      'United Kingdom']},
#    'phone': '+442076543834',
#    'display_phone': '+44 20 7654 3834',
#    'distance': 1460.69015765681},
#   {'id': 'kEI6mZ6EBzYFJ9veQ-vD3A',
#    'alias': 'chatime-london-3',
#    'name': 'Chatime',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qVtesbo9iNyufTQSjaO6gA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chatime-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.524453914796,
#     'longitude': -0.124379430363801},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 34',
#     'address2': 'The Brunswick',
#     'address3': 'Russell Square',
#     'city': 'London',
#     'zip_code': 'WC1N 1AE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 34',
#      'The Brunswick',
#      'Russell Square',
#      'London WC1N 1AE',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1520.0688911604277},
#   {'id': 'DXMoezQ1WxA-lzvSNPg6Og',
#    'alias': 'd1-coffee-little-venice',
#    'name': 'D1 Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mOMm9erE16oTv2gxuM4sjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/d1-coffee-little-venice?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5248684, 'longitude': -0.1763357},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Aberdeen Place',
#     'address2': '',
#     'address3': '',
#     'city': 'Little Venice',
#     'zip_code': 'NW8 8JN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Aberdeen Place',
#      'Little Venice NW8 8JN',
#      'United Kingdom']},
#    'phone': '+442077233337',
#    'display_phone': '+44 20 7723 3337',
#    'distance': 3097.807873394816},
#   {'id': 'Vc_Pw4jlrak_LlCk8DHBJA',
#    'alias': 'karma-bread-london',
#    'name': 'Karma Bread',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/P7X4DYtbYD1rdiZLlk6R8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/karma-bread-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5544616396241,
#     'longitude': -0.165723802891784},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '13 S End Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 2PT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 S End Road', 'London NW3 2PT', 'United Kingdom']},
#    'phone': '+442074316050',
#    'display_phone': '+44 20 7431 6050',
#    'distance': 5065.927131951486},
#   {'id': 'izDKJQTY1TuSrnt4l7reqA',
#    'alias': 'granger-and-co-london-5',
#    'name': 'Granger & Co',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sngypUSJ_Z7F4DL1VuRftA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/granger-and-co-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4937584582247,
#     'longitude': -0.158635840925337},
#    'transactions': [],
#    'location': {'address1': '237 Pavilion Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1X 0BP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['237 Pavilion Road',
#      'London SW1X 0BP',
#      'United Kingdom']},
#    'phone': '+442038481060',
#    'display_phone': '+44 20 3848 1060',
#    'distance': 2638.954622882282},
#   {'id': 'YSH7Np4HykZbK0IpmAMJhQ',
#    'alias': 'palm-vaults-hackney',
#    'name': 'Palm Vaults',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jgwOvStrtKJtrzBWo87wNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/palm-vaults-hackney?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5492266, 'longitude': -0.0552513},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '411 Mare Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hackney',
#     'zip_code': 'E8 1HY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['411 Mare Street',
#      'Hackney E8 1HY',
#      'United Kingdom']},
#    'phone': '+447391139805',
#    'display_phone': '+44 7391 139805',
#    'distance': 6895.584976421945},
#   {'id': '3ViNQObKHR6l02hkvBFClw',
#    'alias': 'mimos-cafe-london',
#    'name': 'Mimos Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/k6WfcS61Er3U5TxjAdvcNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mimos-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 85,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5150959, 'longitude': -0.174005},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '19 London Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 London Street',
#      'London W2 1HL',
#      'United Kingdom']},
#    'phone': '+442077067175',
#    'display_phone': '+44 20 7706 7175',
#    'distance': 2647.9526940777378},
#   {'id': '-y26Nl2xSJrbGygr3pMaGQ',
#    'alias': 'arro-coffee-the-temple-of-coffee-london-2',
#    'name': 'ArrO Coffee- The Temple of Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-_Mg-eahxnVIzet7uUvF_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arro-coffee-the-temple-of-coffee-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.520333, 'longitude': -0.1557873},
#    'transactions': [],
#    'location': {'address1': '67 Chiltern St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1U 6NJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['67 Chiltern St', 'London W1U 6NJ', 'United Kingdom']},
#    'phone': '+442079351053',
#    'display_phone': '+44 20 7935 1053',
#    'distance': 1605.6390568972956},
#   {'id': 'dyAE0ROgElNHbRa-y3CfFw',
#    'alias': 'sacred-london',
#    'name': 'Sacred',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gbnky4zCMMrFXmkPjO3zlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sacred-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 69,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512954, 'longitude': -0.138923},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '13 Ganton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9BL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Ganton Street',
#      'London W1F 9BL',
#      'United Kingdom']},
#    'phone': '+447595733057',
#    'display_phone': '+44 7595 733057',
#    'distance': 201.35274674274652},
#   {'id': 'S3h8uhI3wK2Fn4e9gw9bfA',
#    'alias': 'shoreditch-grind-london',
#    'name': 'Shoreditch Grind',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wcWCxMuAey7jvjK6_m5TIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shoreditch-grind-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 116,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5258391235513,
#     'longitude': -0.0879659656067133},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '213 Old Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 9NR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['213 Old Street',
#      'London EC1V 9NR',
#      'United Kingdom']},
#    'phone': '+442074907490',
#    'display_phone': '+44 20 7490 7490',
#    'distance': 3621.631922482148},
#   {'id': 'IFx29LvkxdZx8pTp-JrvnA',
#    'alias': 'l-eto-caffe-london-3',
#    'name': "L'eto Caffe",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/102DdjCIFtBYllWCYwlo2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-eto-caffe-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4987685, 'longitude': -0.1570349},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10 W Halkin Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 8JL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 W Halkin Street',
#      'London SW1X 8JL',
#      'United Kingdom']},
#    'phone': '+442072356415',
#    'display_phone': '+44 20 7235 6415',
#    'distance': 2138.947633367185},
#   {'id': 'MXYj38qKszh9Z7YATzmrrA',
#    'alias': 'store-street-espresso-london',
#    'name': 'Store Street Espresso',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/A-FYmm4F48gSZWZBFrTG8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/store-street-espresso-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 62,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5200997, 'longitude': -0.1306308},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '40 Store Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1E 7DB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 Store Street',
#      'London WC1E 7DB',
#      'United Kingdom']},
#    'phone': '+442076372623',
#    'display_phone': '+44 20 7637 2623',
#    'distance': 899.7744295076758},
#   {'id': 'TnnXpysgEQAqgweb62rXQQ',
#    'alias': 'westminster-abbey-coffee-club-london',
#    'name': 'Westminster Abbey Coffee Club',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/i064fRM1rCH24FDDnJlIUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/westminster-abbey-coffee-club-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.49891, 'longitude': -0.128286},
#    'transactions': [],
#    'location': {'address1': 'In front of Westminster Abbey',
#     'address2': 'Broad Sanctuary',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 3PA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['In front of Westminster Abbey',
#      'Broad Sanctuary',
#      'London SW1P 3PA',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1612.7661588279934},
#   {'id': '-HkQk8DoHwNvzuLKmsWwOA',
#    'alias': 'host-cafe-london-2',
#    'name': 'Host Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/so4TLurpNtPvYfZy-Z_c0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/host-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5126908219997,
#     'longitude': -0.0935071706771851},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Saint Mary Aldermary',
#     'address2': 'Watling Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4M 9BW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Saint Mary Aldermary',
#      'Watling Street',
#      'London EC4M 9BW',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2937.5326021021433},
#   {'id': 'SNRC7L3NbjgObjwKwOmNZQ',
#    'alias': 'lils-cafe-soho-london',
#    'name': "Lil's Cafe SoHo",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VenCKl4BFbzd_gVyqjwAww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lils-cafe-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.511999, 'longitude': -0.133687},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '53 Rupert Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 7PG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['53 Rupert Street',
#      'London W1D 7PG',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 182.36025531010344},
#   {'id': 'e0SC4WLre7mVu1c2ad0x-A',
#    'alias': 'byzantium-cafe-london',
#    'name': 'Byzantium Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qzDE1s78lIZRrUVM3arMNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/byzantium-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512401, 'longitude': -0.189185},
#    'transactions': [],
#    'location': {'address1': '31 Moscow Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 4AH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['31 Moscow Road', 'London W2 4AH', 'United Kingdom']},
#    'phone': '+442072299367',
#    'display_phone': '+44 20 7229 9367',
#    'distance': 3668.101602585959},
#   {'id': 'xyGoZSV_Gqh11iusdToF1Q',
#    'alias': 'candid-café-london-2',
#    'name': 'Candid Café',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6n6Kw90m4r56IQzkNpX27Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/candid-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.532232, 'longitude': -0.105091},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3 Torrens Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 1NQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Torrens Street',
#      'London EC1V 1NQ',
#      'United Kingdom']},
#    'phone': '+442078374237',
#    'display_phone': '+44 20 7837 4237',
#    'distance': 3023.9373760219646},
#   {'id': '39nGPmVcnpp3RaenmlfZCQ',
#    'alias': 'long-shot-coffee-london',
#    'name': 'Long Shot Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yCoFPInejXdzoZXOHfMfFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/long-shot-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5117874, 'longitude': -0.0687977},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '127 Leman Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 8EY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['127 Leman Street',
#      'London E1 8EY',
#      'United Kingdom']},
#    'phone': '+442074811100',
#    'display_phone': '+44 20 7481 1100',
#    'distance': 4650.305158888016},
#   {'id': 'nmkSaHYYp6ntKv1kBNB0ug',
#    'alias': 'caffè-nero-london-174',
#    'name': 'Caffè Nero',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vXHgTMZH40KITnMkHhIO1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caff%C3%A8-nero-london-174?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514874793045,
#     'longitude': -0.176135101189141},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 38',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1RH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 38', 'London W2 1RH', 'United Kingdom']},
#    'phone': '+447717367763',
#    'display_phone': '+44 7717 367763',
#    'distance': 2789.611979804231},
#   {'id': '4DDzcfgbnVAKWomCQoZilg',
#    'alias': 'fortitude-bakehouse-london',
#    'name': 'Fortitude Bakehouse',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1XuacJvRQ1iMGuttnQKQSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fortitude-bakehouse-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5229210884015,
#     'longitude': -0.124047992374525},
#    'transactions': [],
#    'location': {'address1': '35 Colonnade',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC1N 1DD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35 Colonnade', 'London WC1N 1DD', 'United Kingdom']},
#    'phone': '+442078375456',
#    'display_phone': '+44 20 7837 5456',
#    'distance': 1391.6020920227202},
#   {'id': 'AZ22wY3_3ygZY8aid46EdQ',
#    'alias': 'l-eto-caffe-mayfair-2',
#    'name': "L'ETO Caffe",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xVtDQYQj_fOqMgSg6UAllw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-eto-caffe-mayfair-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5065040588379,
#     'longitude': -0.14690899848938},
#    'transactions': [],
#    'location': {'address1': '46-48 Shepherd Market',
#     'address2': '',
#     'address3': '',
#     'city': 'Mayfair',
#     'zip_code': 'W1J 7QS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['46-48 Shepherd Market',
#      'Mayfair W1J 7QS',
#      'United Kingdom']},
#    'phone': '+442076293985',
#    'display_phone': '+44 20 7629 3985',
#    'distance': 1034.5294608894424},
#   {'id': 'Mq1YF89fLYk4DeMZcds48Q',
#    'alias': 'pedros-cafe-london',
#    'name': "Pedro's Cafe",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9vBbwVxlNcRKJKk2UQ2Euw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pedros-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5458423, 'longitude': -0.1418939},
#    'transactions': [],
#    'location': {'address1': '165 Kentish Town Road',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW1 8PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['165 Kentish Town Road',
#      'London NW1 8PD',
#      'United Kingdom']},
#    'phone': '+442074859599',
#    'display_phone': '+44 20 7485 9599',
#    'distance': 3693.0978530908137},
#   {'id': '1v9EkpH0JlBhgz3JDAJMdw',
#    'alias': 'ginos-cafe-london',
#    'name': "Gino's Cafe",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ot1Feo_jsRPAUYAZbd8oJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginos-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.516, 'longitude': -0.149106},
#    'transactions': [],
#    'location': {'address1': '69 Welbeck Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1G 0AT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['69 Welbeck Street',
#      'London W1G 0AT',
#      'United Kingdom']},
#    'phone': '+442074867490',
#    'display_phone': '+44 20 7486 7490',
#    'distance': 975.6364108952755},
#   {'id': 'fIg1VEHmj9H7p1l3-GEUuQ',
#    'alias': 'caffe-nero-london-278',
#    'name': 'Caffe Nero',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_5U0ACsYPDLEIdT4iIQgWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-nero-london-278?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5132621, 'longitude': -0.1314045},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '43 Frith Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1V 5TE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['43 Frith Street',
#      'London W1V 5TE',
#      'United Kingdom']},
#    'phone': '+442074343887',
#    'display_phone': '+44 20 7434 3887',
#    'distance': 318.5051009276574},
#   {'id': 'o95C9QEq-bKJx1wTn7RBnQ',
#    'alias': 'bonjour-brioche-london-3',
#    'name': 'Bonjour Brioche',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UWqIpJ1pZ3SE1v9OFGgMMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bonjour-brioche-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4900052, 'longitude': -0.20631690489347},
#    'transactions': [],
#    'location': {'address1': '187 North End Road',
#     'address2': 'West Kensington',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W14 9NL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['187 North End Road',
#      'West Kensington',
#      'London W14 9NL',
#      'United Kingdom']},
#    'phone': '+442030927735',
#    'display_phone': '+44 20 3092 7735',
#    'distance': 5492.184466817846},
#   {'id': 'jrRKp4dsl9uTQjBb0uBbfw',
#    'alias': 'pimlico-fresh-london',
#    'name': 'Pimlico Fresh',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pxjxkpfArqkdyAaBJwaWZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pimlico-fresh-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 154,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.492391374275,
#     'longitude': -0.14021524722041},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '85 Wilton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1DE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['85 Wilton Road',
#      'London SW1V 1DE',
#      'United Kingdom']},
#    'phone': '+442079320030',
#    'display_phone': '+44 20 7932 0030',
#    'distance': 2292.321028443847},
#   {'id': 'pQS5srLHVMsb4EU9uep9Gw',
#    'alias': 'cereal-killer-cafe-london',
#    'name': 'Cereal Killer Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nukLebpj9h77i_3DBr_YIQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cereal-killer-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 121,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5237499257239,
#     'longitude': -0.071338377892971},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '192 Brick Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['192 Brick Lane', 'London E1 6SB', 'United Kingdom']},
#    'phone': '+442036019100',
#    'display_phone': '+44 20 3601 9100',
#    'distance': 4632.834898564713},
#   {'id': 'nAwpCaUpBIneyj1Vg0Zlcw',
#    'alias': 'candy-café-london-2',
#    'name': 'Candy Café',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ALRE1FXqVDY8Q2WmIJye4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/candy-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511873, 'longitude': -0.131473},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '3 Macclesfield Street',
#     'address2': 'Chinatown',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6AU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Macclesfield Street',
#      'Chinatown',
#      'London W1D 6AU',
#      'United Kingdom']},
#    'phone': '+442074344581',
#    'display_phone': '+44 20 7434 4581',
#    'distance': 337.4774111722012},
#   {'id': 'RlX1FLa740WcSP5QMLZ-mQ',
#    'alias': 'the-wren-coffee-london',
#    'name': 'The Wren Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oP9f5_pTKmfPk9bb1NOfBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wren-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5121468, 'longitude': -0.0975965},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'St Nicholas Cole Abbey',
#     'address2': '114 Queen Victoria St',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4V 4BJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['St Nicholas Cole Abbey',
#      '114 Queen Victoria St',
#      'London EC4V 4BJ',
#      'United Kingdom']},
#    'phone': '+442072361014',
#    'display_phone': '+44 20 7236 1014',
#    'distance': 2655.6231551175424},
#   {'id': 'bfq0rN8T48pJAsujwrp_qw',
#    'alias': 'streets-coffee-london',
#    'name': 'Streets Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DnwVFZEfaX3TyVlQUfRKsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/streets-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5493402, 'longitude': -0.181955},
#    'transactions': [],
#    'location': {'address1': '289 Finchley Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 6ND',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['289 Finchley Road',
#      'London NW3 6ND',
#      'United Kingdom']},
#    'phone': '+442074357604',
#    'display_phone': '+44 20 7435 7604',
#    'distance': 5157.62417550774},
#   {'id': '0KXlMLUy4ZKEs3gADeEvsg',
#    'alias': 'crescent-coffee-london',
#    'name': 'Crescent Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2zlkBhvLKD-b58uj42ya9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crescent-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.534163, 'longitude': -0.138892},
#    'transactions': [],
#    'location': {'address1': '1 Hurdwick Place',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 2JE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Hurdwick Place',
#      'London NW1 2JE',
#      'United Kingdom']},
#    'phone': '+447875767573',
#    'display_phone': '+44 7875 767573',
#    'distance': 2380.189210337391},
#   {'id': 'nJA-5mA9yvHF55M-cwWVRg',
#    'alias': 'the-wild-goose-bakery-london',
#    'name': 'The Wild Goose Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/E4LTIQEXIQ3N9BWm3iN9VA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wild-goose-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.56867, 'longitude': 0.01134},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '654 High Road',
#     'address2': 'Leytonstone',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E11 3AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['654 High Road',
#      'Leytonstone',
#      'London E11 3AA',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 11903.838612909321},
#   {'id': 'AJ7i8Xqyx70wpcTTcK4GFA',
#    'alias': 'somerset-house-strand',
#    'name': 'Somerset House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/85dQ4lnXBBi6Xi4C4w3DpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/somerset-house-strand?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 67,
#    'categories': [{'alias': 'museums', 'title': 'Museums'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5110614108427,
#     'longitude': -0.117102253177384},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'South Building',
#     'address2': 'Somerset House',
#     'address3': '',
#     'city': 'Strand',
#     'zip_code': 'WC2R 1LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['South Building',
#      'Somerset House',
#      'Strand WC2R 1LA',
#      'United Kingdom']},
#    'phone': '+442078454600',
#    'display_phone': '+44 20 7845 4600',
#    'distance': 1319.5379341546704},
#   {'id': 'I1FOTVrKirQfWT1yv25yxA',
#    'alias': 'doppio-cafe-london',
#    'name': 'Doppio Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pICCYeiUmRxQ7Bm6645QcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doppio-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5461019420634,
#     'longitude': -0.141918025910854},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '177 Kentish Town Road',
#     'address2': 'Camden Town',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['177 Kentish Town Road',
#      'Camden Town',
#      'London NW1 8PD',
#      'United Kingdom']},
#    'phone': '+442072675993',
#    'display_phone': '+44 20 7267 5993',
#    'distance': 3721.975381913747},
#   {'id': 'kk3nbq6MrB_S36Gj_vqIFw',
#    'alias': 'royal-exchange-london-2',
#    'name': 'Royal Exchange',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/34LEtTIfh93Zj3afaTRy4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/royal-exchange-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5135777175252,
#     'longitude': -0.087540410301783},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Threadneedle',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EC3V 3LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Threadneedle', 'London EC3V 3LP', 'United Kingdom']},
#    'phone': '+442076182480',
#    'display_phone': '+44 20 7618 2480',
#    'distance': 3351.3780160400474},
#   {'id': 'sR_XQYWwLiF5Lkj8-Cu-RA',
#    'alias': 'persepolis-london',
#    'name': 'Persepolis',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r8wkxaqNDWk9lgCZRaTPww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/persepolis-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'persian', 'title': 'Persian/Iranian'},
#     {'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4733916, 'longitude': -0.0722307},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '28-30 Peckham High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE15 5DT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28-30 Peckham High Street',
#      'London SE15 5DT',
#      'United Kingdom']},
#    'phone': '+442076398007',
#    'display_phone': '+44 20 7639 8007',
#    'distance': 6246.625984287883},
#   {'id': 'o3KrewdcT9foq1PK2lsngg',
#    'alias': 'affogato-london',
#    'name': 'Affogato',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NUh3i7zwVFFq3ADg14pivA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/affogato-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4098587, 'longitude': -0.1225811},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1457 London Road',
#     'address2': 'Norbury',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW16 4AQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1457 London Road',
#      'Norbury',
#      'London SW16 4AQ',
#      'United Kingdom']},
#    'phone': '+442036209815',
#    'display_phone': '+44 20 3620 9815',
#    'distance': 11472.066104884861},
#   {'id': 'nGx7Mtw5ERsMUO9OHyzFvA',
#    'alias': 'the-pigeon-hole-cafe-london',
#    'name': 'The Pigeon Hole Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VuX7i0JuekcfcFXnc5Iq4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pigeon-hole-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4739723205566,
#     'longitude': -0.0887290015816689},
#    'transactions': [],
#    'location': {'address1': '2 Datchelor Place',
#     'address2': 'Camberwell',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE5 7AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Datchelor Place',
#      'Camberwell',
#      'London SE5 7AP',
#      'United Kingdom']},
#    'phone': '+447814669278',
#    'display_phone': '+44 7814 669278',
#    'distance': 5420.322763096938},
#   {'id': 'MPMPIoIeMe1P4faS-ldqsw',
#    'alias': 'wa-cafe-london-2',
#    'name': 'WA Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OzPcPG0BZSqvFwG2-iw_dQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wa-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.51103, 'longitude': -0.12648},
#    'transactions': [],
#    'location': {'address1': '5 New Row',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2N 4LH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 New Row', 'London WC2N 4LH', 'United Kingdom']},
#    'phone': '+442072405567',
#    'display_phone': '+44 20 7240 5567',
#    'distance': 687.9705803323653},
#   {'id': 'LYPuCoeoYpRpMcvFfwK3wQ',
#    'alias': 'farmstand-london-3',
#    'name': 'Farmstand',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IC8LsiHvAb5kgNsIVteqjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/farmstand-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5143394470215,
#     'longitude': -0.122018814086914},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '42 Drury Lane',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 Drury Lane',
#      'Covent Garden',
#      'London WC2B 5AJ',
#      'United Kingdom']},
#    'phone': '+442072403866',
#    'display_phone': '+44 20 7240 3866',
#    'distance': 986.9717381016312}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#                Restaurant          Type Price Rating             Address  \
# 0              Tap Coffee  Coffee & Tea     £      4  193 Wardour Street
# 1          Peggy Porschen         Cafes                  219 King's Road
# 2             The Pie Man         Delis    ££      4      16 Cale Street
# 3  The Gentlemen Baristas  Coffee & Tea     £    4.5     63 Union Street
# 4                Café Par    Sandwiches     £      5  115 St John Street
#
#          Lat       Lng                                                url  \
# 0  51.515468 -0.135823  https://www.yelp.com/biz/tap-coffee-london?adj...
# 1  51.486510 -0.170890
# 2  51.490654 -0.166866  https://www.yelp.com/biz/the-pie-man-london?ad...
# 3  51.503842 -0.094704  https://www.yelp.com/biz/the-gentlemen-barista...
# 4  51.522873 -0.102466  https://www.yelp.com/biz/caf%C3%A9-par-london?...
#
#                        ID
# 0  vLX78mD-aZPd-3AyGcryWA
# 1
# 2  NNqPxJdhQRziK8UJpjw2_A
# 3  XN7K4g1Wq-93WYvg85EgMg
# 4  gmQu79rLOaaKmdiXODvH0Q

# %%
london_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
london_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_restaurants_df = london_restaurants_df[column_order]
london_restaurants_df = london_restaurants_df.sort_values(["Type"], ascending=True)
london_restaurants_df = london_restaurants_df.reset_index(drop=True)
london_restaurants_df
# Out:
#                                  Restaurant                    Type Rating  \
# 0                             The Bike Shed             Accessories    4.5
# 1                                  Red Door           Art Galleries    4.5
# 2                           Primrose Bakery                Bakeries      4
# 3                                  Konditor                Bakeries    4.5
# 4                          Rinkoff Bakeries                Bakeries    4.5
# 5                             Nordic Bakery                Bakeries    3.5
# 6                              E5 Bakehouse                Bakeries    4.5
# 7                     The Wild Goose Bakery                Bakeries    4.5
# 8    Queen Elizabeth Roof Garden Bar & Café                    Bars    3.5
# 9                           Books for Cooks              Bookstores      5
# 10             The Ivy Kensington Brasserie              Brasseries      4
# 11               GAIL's Bakery Neo Bankside      Breakfast & Brunch    4.5
# 12                              L'ETO Caffe      Breakfast & Brunch
# 13                          The Garden Café                 British    3.5
# 14                        Gino's Coffee Bar                 British    4.5
# 15                           Tea and Tattle                 British    4.5
# 16                    Garden Breakfast Cafe                 British    4.5
# 17                             The Orangery                 British      4
# 18                          New London Cafe                 British    4.5
# 19                           Peggy Porschen                   Cafes
# 20                             Seoul Bakery                   Cafes    4.5
# 21                          Fabrique Bakery                   Cafes
# 22                             Ripe Kitchen                   Cafes
# 23                              L'eto Caffe                   Cafes    4.5
# 24                    Mihbaj Café & Kitchen                   Cafes    4.5
# 25                             The Ivy Café                   Cafes      4
# 26                The Ivy Cafe - Marylebone                   Cafes      4
# 27                          Friends of Ours                   Cafes    4.5
# 28                        The RA Grand Cafe                   Cafes      4
# 29                                EZ & Moss                   Cafes    4.5
# ..                                      ...                     ...    ...
# 170                                 Fix 126            Coffee & Tea      4
# 171                         Fabrique Bakery            Coffee & Tea      4
# 172                      Black Sheep Coffee            Coffee & Tea
# 173                         Bloomsbury Cafe            Coffee & Tea      4
# 174                            Ozone Coffee            Coffee & Tea    4.5
# 175                       Montparnasse Cafe            Coffee & Tea    4.5
# 176       ArrO Coffee- The Temple of Coffee       Coffee Roasteries
# 177                                 Cowshed                Day Spas    4.5
# 178                             The Pie Man                   Delis      4
# 179                          Love Walk Café                   Delis      4
# 180                         Lil's Cafe SoHo                Desserts    3.5
# 181                                Affogato                Desserts      4
# 182                        Polo 24 Hour Bar                  Diners      4
# 183                               Farmstand             Gluten-Free      4
# 184                        Hotel Café Royal                  Hotels    4.5
# 185                                  Princi                 Italian      4
# 186                              E Pellicci                 Italian    4.5
# 187                     Covent Garden Grind  Juice Bars & Smoothies    4.5
# 188                            Granger & Co  Juice Bars & Smoothies
# 189                              Freud Café                 Lounges      4
# 190                         Green & Fortune               Marketing
# 191                          Somerset House                 Museums    4.5
# 192                           Ole and Steen    Patisserie/Cake Shop    4.5
# 193                              Persepolis         Persian/Iranian    4.5
# 194                     Camden Coffee House             Restaurants      4
# 195                            Wesleys Cafe             Restaurants      4
# 196                                Café Par              Sandwiches      5
# 197                               Black Cat                   Vegan    4.5
# 198                           The Book Club   Venues & Event Spaces      4
# 199                             Saint Aymes   Venues & Event Spaces
#
#     Price                            Address        Lat       Lng  \
# 0      ££                     384 Old Street  51.527090 -0.078215
# 1      ££                    10 Turnpin Lane  51.481164 -0.009072
# 2      ££               69 Gloucester Avenue  51.540226 -0.151122
# 3      ££                     22 Cornwall Rd  51.504290 -0.110367
# 4       £                 224 Jubilee Street  51.519888 -0.053025
# 5      ££                   14 Golden Square  51.511430 -0.136741
# 6      ££               395 Mentmore Terrace  51.541204 -0.057616
# 7    ££££                      654 High Road  51.568670  0.011340
# 8      ££               Queen Elizabeth Hall  51.505710 -0.116687
# 9      ££                 4 Blenheim Cresent  51.515943 -0.205374
# 10    £££          96 Kensington High Street  51.501568 -0.192180
# 11     ££                Unit C Neo Bankside  51.506635 -0.100413
# 12                     46-48 Shepherd Market  51.506504 -0.146909
# 13     ££                       Inner Circle  51.526875 -0.154452
# 14      £                   Great Central St  51.522224 -0.162099
# 15     ££            41 Great Russell Street  51.517868 -0.126817
# 16     ££                3 Goldhurst Terrace  51.545784 -0.179409
# 17    £££                  Kensington Palace  51.506636 -0.187725
# 18      £                 216 St Paul's Road  51.546911 -0.098378
# 19                           219 King's Road  51.486510 -0.170890
# 20      £            14 Great Russell Street  51.517237 -0.129569
# 21                          53 Goodge Street  51.519121 -0.136215
# 22                     136 Regents Park Road  51.540697 -0.157262
# 23    £££                    149 King's Road  51.487940 -0.167225
# 24     ££                   153 Praed Street  51.516163 -0.174471
# 25     ££  120 Saint John's Wood High Street  51.533560 -0.170540
# 26     ££                 96 Marylebone Lane  51.517443 -0.150754
# 27     ££                 61 Pitfield Street  51.529119 -0.083699
# 28     ££                   Burlington House  51.509354 -0.139908
# 29      £                  183 Holloway Road  51.550185 -0.109221
# ..    ...                                ...        ...       ...
# 170    ££                   126 Curtain Road  51.526125 -0.080215
# 171    ££                212 Portobello Road  51.516469 -0.205223
# 172                     125 Old Broad Street  51.514694 -0.086011
# 173     £               16 Bloomsbury Street  51.517516 -0.127287
# 174    ££                  11 Leonard Street  51.524684 -0.086674
# 175     £                22 Thackeray Street  51.500521 -0.188534
# 176                           67 Chiltern St  51.520333 -0.155787
# 177  ££££             115 Regent's Park Road  51.542576 -0.155608
# 178    ££                     16 Cale Street  51.490654 -0.166866
# 179    ££                    81 Denmark Hill  51.471710 -0.092740
# 180     £                   53 Rupert Street  51.511999 -0.133687
# 181   £££                   1457 London Road  51.409859 -0.122581
# 182     £                    176 Bishopsgate  51.517821 -0.080269
# 183     £                      42 Drury Lane  51.514339 -0.122019
# 184   £££                   68 Regent Street  51.510171 -0.135962
# 185    ££                 135 Wardour Street  51.513863 -0.134387
# 186     £             332 Bethnal Green Road  51.526516 -0.063561
# 187     £                     42 Maiden Lane  51.511048 -0.122460
# 188                        237 Pavilion Road  51.493758 -0.158636
# 189    ££             198 Shaftesbury Avenue  51.515166 -0.126793
# 190                              Kings Place  51.534765 -0.122195
# 191    ££                     South Building  51.511061 -0.117102
# 192    ££                       56 Haymarket  51.509238 -0.132696
# 193     £          28-30 Peckham High Street  51.473392 -0.072231
# 194     £                     30 Camden Road  51.539981 -0.140795
# 195     £           Central Hall Westminster  51.500258 -0.129931
# 196     £                 115 St John Street  51.522873 -0.102466
# 197     £                   76 Clarence Road  51.551397 -0.055691
# 198    ££                 100 Leonard Street  51.524537 -0.081494
# 199                      59 Connaught Street  51.514250 -0.166750
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/the-bike-shed-london?...  BNdzjiLoibX1uSH4kAQy5w
# 1    https://www.yelp.com/biz/red-door-london?adjus...  RYus9YxVxD-R8jm6xkDX8g
# 2    https://www.yelp.com/biz/primrose-bakery-londo...  dIWOqYszVKk-oswXDzUH6A
# 3    https://www.yelp.com/biz/konditor-london?adjus...  1epk2D1-2-g08GAntFlySg
# 4    https://www.yelp.com/biz/rinkoff-bakeries-lond...  OLXnVhh19HtAnbywQzD3zw
# 5    https://www.yelp.com/biz/nordic-bakery-london?...  Sh_PrXavTAk2d5jTs_onuQ
# 6    https://www.yelp.com/biz/e5-bakehouse-london?a...  -6GHU4qI0DKsIrBpv57qTg
# 7    https://www.yelp.com/biz/the-wild-goose-bakery...  nJA-5mA9yvHF55M-cwWVRg
# 8    https://www.yelp.com/biz/queen-elizabeth-roof-...  pOQwGM-8Qrwb8PGzLDGyeg
# 9    https://www.yelp.com/biz/books-for-cooks-londo...  -fLxQOd0pjTkQl4ttwR4XA
# 10   https://www.yelp.com/biz/the-ivy-kensington-br...  wCjU2KuTntCZDCZSIS1Uxw
# 11   https://www.yelp.com/biz/gails-bakery-neo-bank...  U_XeFWW1Lttdq22txTABMw
# 12
# 13   https://www.yelp.com/biz/the-garden-caf%C3%A9-...  kOmkk63gMmsKk0Wve5aJRA
# 14   https://www.yelp.com/biz/ginos-coffee-bar-lond...  N0kfB-iYOb3Fs9RkOfwBlA
# 15   https://www.yelp.com/biz/tea-and-tattle-london...  1TgYqfxkXv6-IB4cvuuy3w
# 16   https://www.yelp.com/biz/garden-breakfast-cafe...  mWIaThf7jXEFk-IzPfxRrQ
# 17   https://www.yelp.com/biz/the-orangery-london-7...  PBFvhVyBi0lEJyTbyuxf5w
# 18   https://www.yelp.com/biz/new-london-cafe-londo...  PHTcl--LbBwA1N6EHZV_sg
# 19
# 20   https://www.yelp.com/biz/seoul-bakery-london-3...  WotOpvaXPZW2Yx-dzoK73w
# 21
# 22
# 23   https://www.yelp.com/biz/l-eto-caffe-london-6?...  Qk9CwHdpFgYo1Za77yfPtQ
# 24   https://www.yelp.com/biz/mihbaj-caf%C3%A9-and-...  cFCAYrs6LX17ucDFEWMXLg
# 25   https://www.yelp.com/biz/the-ivy-caf%C3%A9-lon...  2W5-ITjCbbdRO6_VSn3Jng
# 26   https://www.yelp.com/biz/the-ivy-cafe-marylebo...  6ugop_2_fnetqRX6DbRNmA
# 27   https://www.yelp.com/biz/friends-of-ours-londo...  -ylzTrYtRJUJa2BuAInoyQ
# 28   https://www.yelp.com/biz/the-ra-grand-cafe-lon...  illIEFnTN27Skw0M6ntz1Q
# 29   https://www.yelp.com/biz/ez-and-moss-london?ad...  k-qIxL_IHDlXxlgDpNkN7Q
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/fix-126-london?adjust...  3fDLrrmStQBZFMBHUvMbrQ
# 171  https://www.yelp.com/biz/fabrique-bakery-londo...  FM2fOny0zttmwnSeHCHzyA
# 172
# 173  https://www.yelp.com/biz/bloomsbury-cafe-londo...  BJPoMcoKJxrs_QT4_PcL8A
# 174  https://www.yelp.com/biz/ozone-coffee-london-2...  68gc1BAE1IT_zZghFafw0Q
# 175  https://www.yelp.com/biz/montparnasse-cafe-lon...  riWepzZEIHj82UiDk_WVLQ
# 176
# 177  https://www.yelp.com/biz/cowshed-london-2?adju...  I0uedC7kST8RRKLmJ6os-w
# 178  https://www.yelp.com/biz/the-pie-man-london?ad...  NNqPxJdhQRziK8UJpjw2_A
# 179  https://www.yelp.com/biz/love-walk-caf%C3%A9-l...  uCNH9aBdcJdRP6D6JiW1lg
# 180  https://www.yelp.com/biz/lils-cafe-soho-london...  SNRC7L3NbjgObjwKwOmNZQ
# 181  https://www.yelp.com/biz/affogato-london?adjus...  o3KrewdcT9foq1PK2lsngg
# 182  https://www.yelp.com/biz/polo-24-hour-bar-lond...  O3WaROs_7OFbYv4B-7m02Q
# 183  https://www.yelp.com/biz/farmstand-london-3?ad...  LYPuCoeoYpRpMcvFfwK3wQ
# 184  https://www.yelp.com/biz/hotel-caf%C3%A9-royal...  t9-_U2-WmaIee3XDB0Tz0w
# 185  https://www.yelp.com/biz/princi-london?adjust_...  -ATEXu2q4Oe4wPQeyrsILw
# 186  https://www.yelp.com/biz/e-pellicci-london?adj...  wqZucWHydm2qx-iUCUyJpQ
# 187  https://www.yelp.com/biz/covent-garden-grind-l...  sTjZJB20joSHE8oVPHs1Cw
# 188
# 189  https://www.yelp.com/biz/freud-caf%C3%A9-londo...  62YhaqIfyixjj4Z_W57D4w
# 190
# 191  https://www.yelp.com/biz/somerset-house-strand...  AJ7i8Xqyx70wpcTTcK4GFA
# 192  https://www.yelp.com/biz/ole-and-steen-london-...  5or4AzNouZq8RClNeTdqiA
# 193  https://www.yelp.com/biz/persepolis-london?adj...  sR_XQYWwLiF5Lkj8-Cu-RA
# 194  https://www.yelp.com/biz/camden-coffee-house-l...  exjNWU4T_uzKOtH3uHIutQ
# 195  https://www.yelp.com/biz/wesleys-cafe-london?a...  YXLHj8H0V-6NlczR2DuZqA
# 196  https://www.yelp.com/biz/caf%C3%A9-par-london?...  gmQu79rLOaaKmdiXODvH0Q
# 197  https://www.yelp.com/biz/black-cat-london?adju...  f8s8dT9Rm4359xUVHtiqRA
# 198  https://www.yelp.com/biz/the-book-club-london?...  UMJxTGTSShg2u1FFwZBWAQ
# 199
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
london_restaurants_df.to_csv('Resources/London_Restaurants_Cafe.csv')
