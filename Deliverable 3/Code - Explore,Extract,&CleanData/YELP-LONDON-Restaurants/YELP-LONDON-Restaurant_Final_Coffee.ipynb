# %% [markdown]
# LONDON RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
lndr_params1 = {"term":"coffee","location":"London","limit":50,"offset":0}
lndr_response1 = requests.get(search_api_url, headers=headers, params=lndr_params1)
lndr1 = lndr_response1.json()
display(lndr1)
#print(lndr_response1.url)
#print(lndr_response1.status_code)
# Out:
# {'businesses': [{'id': '-22PaX8rQyh0ZQrdCiDz4A',
#    'alias': 'fuckoffee-london-3',
#    'name': 'Fuckoffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MQ7RV7bMOSjdLX1DfhzQ_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fuckoffee-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 87,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4993814, 'longitude': -0.0812485},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '163-167 Bermondsey Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 3UW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['163-167 Bermondsey Street',
#      'London SE1 3UW',
#      'United Kingdom']},
#    'phone': '+442074037655',
#    'display_phone': '+44 20 7403 7655',
#    'distance': 4071.1885164771065},
#   {'id': '3fDLrrmStQBZFMBHUvMbrQ',
#    'alias': 'fix-126-london',
#    'name': 'Fix 126',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UaNwPc1DUW418DLihHCXJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fix-126-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5261251, 'longitude': -0.0802153},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '126 Curtain Road',
#     'address2': 'Shoreditch',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 3PJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['126 Curtain Road',
#      'Shoreditch',
#      'London EC2A 3PJ',
#      'United Kingdom']},
#    'phone': '+442070339555',
#    'display_phone': '+44 20 7033 9555',
#    'distance': 4130.140674765295},
#   {'id': 'Opa8XUwUghxbGFafvubV6A',
#    'alias': 'monmouth-coffee-london-3',
#    'name': 'Monmouth Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bwLj-cK2l4ws5hpEefgdqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/monmouth-coffee-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 306,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5143539, 'longitude': -0.1269168},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '27 Monmouth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['27 Monmouth Street',
#      'London WC2H 9EU',
#      'United Kingdom']},
#    'phone': '+442072323010',
#    'display_phone': '+44 20 7232 3010',
#    'distance': 647.8829298163467},
#   {'id': 'ETxJqTNvE3qc8iZfuwG4LA',
#    'alias': 'omotesando-koffee-london',
#    'name': 'Omotesando Koffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sMF1KusCmRg3OGnetIyLCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/omotesando-koffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5165656647651,
#     'longitude': -0.134790412002872},
#    'transactions': [],
#    'location': {'address1': '8 Newman Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1T 1PB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Newman Street',
#      'London W1T 1PB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 422.5395129497864},
#   {'id': 'mvds37L7mCurGn3rGPM8ag',
#    'alias': 'kaffeine-london',
#    'name': 'Kaffeine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QWk5UJ1ELO0n7VrE3aLUWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaffeine-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 173,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51848, 'longitude': -0.14037},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '66 Great Titchfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 7QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Great Titchfield Street',
#      'London W1W 7QJ',
#      'United Kingdom']},
#    'phone': '+442075806755',
#    'display_phone': '+44 20 7580 6755',
#    'distance': 697.5687539772275},
#   {'id': 'IWl1Y0eQOZSnYeIDw94svg',
#    'alias': 'monmouth-coffee-london',
#    'name': 'Monmouth Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-eZOw_Lts2a7dWXNYekA_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/monmouth-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 306,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5055383383613,
#     'longitude': -0.0914615294783139},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Park Street',
#     'address2': 'The Borough',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Park Street',
#      'The Borough',
#      'London SE1 9AB',
#      'United Kingdom']},
#    'phone': '+442072323010',
#    'display_phone': '+44 20 7232 3010',
#    'distance': 3184.4018654070014},
#   {'id': 'qtW1fg8pyGOXKJnAIk7Wmg',
#    'alias': 'flat-white-london',
#    'name': 'Flat White',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xhvTDNtJzpaPpECSawt5OA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flat-white-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 151,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.513644, 'longitude': -0.134773},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '17 Berwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0PT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17 Berwick Street',
#      'London W1F 0PT',
#      'United Kingdom']},
#    'phone': '+442077340370',
#    'display_phone': '+44 20 7734 0370',
#    'distance': 121.5192430888984},
#   {'id': 'r-USboJFp1ifbtFWtbTGhQ',
#    'alias': 'paper-and-cup-london-2',
#    'name': 'Paper and Cup',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XkBLH87FtSkzIaMMSnmN3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paper-and-cup-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5262201, 'longitude': -0.076815},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '18 Calvert Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7JP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Calvert Avenue',
#      'London E2 7JP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4354.245310616501},
#   {'id': 'mdy8N4wPOlOSiatLWKjLGg',
#    'alias': 'the-borough-barista-london',
#    'name': 'The Borough Barista',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5BOQF57dPe1EaVvhzb0wtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-borough-barista-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.514461025878,
#     'longitude': -0.16090849657059},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '60A Seymour Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7JN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['60A Seymour Street',
#      'London W1H 7JN',
#      'United Kingdom']},
#    'phone': '+442075637222',
#    'display_phone': '+44 20 7563 7222',
#    'distance': 1736.1517070034572},
#   {'id': '7KvU4eIzUhG2Uj2ZRktK2Q',
#    'alias': 'southpaw-coffee-london',
#    'name': 'Southpaw Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dJKexWhB-HcwlfR3SVVY2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/southpaw-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5434843188304,
#     'longitude': -0.113267339766026},
#    'transactions': [],
#    'location': {'address1': '2 Roman Way',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N7 8XG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Roman Way', 'London N7 8XG', 'United Kingdom']},
#    'phone': '+447785732875',
#    'display_phone': '+44 7785 732875',
#    'distance': 3752.041188221996},
#   {'id': 'vLX78mD-aZPd-3AyGcryWA',
#    'alias': 'tap-coffee-london',
#    'name': 'Tap Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7dcT0teObKHsFJj_lkgIFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tap-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515468, 'longitude': -0.135823},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '193 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8ZF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['193 Wardour Street',
#      'London W1F 8ZF',
#      'United Kingdom']},
#    'phone': '+442075802163',
#    'display_phone': '+44 20 7580 2163',
#    'distance': 291.8006048606978},
#   {'id': '39nGPmVcnpp3RaenmlfZCQ',
#    'alias': 'long-shot-coffee-london',
#    'name': 'Long Shot Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yCoFPInejXdzoZXOHfMfFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/long-shot-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5117874, 'longitude': -0.0687977},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '127 Leman Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 8EY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['127 Leman Street',
#      'London E1 8EY',
#      'United Kingdom']},
#    'phone': '+442074811100',
#    'display_phone': '+44 20 7481 1100',
#    'distance': 4650.305158888016},
#   {'id': 'XL7cx1Sb3dFPak2gkPOzKw',
#    'alias': 'soho-grind-london-2',
#    'name': 'Soho Grind',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Vl36Az1so-DbXZ25ImcqjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soho-grind-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512154, 'longitude': -0.138379},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '19 Beak Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Beak Street',
#      'Soho',
#      'London W1F 9RP',
#      'United Kingdom']},
#    'phone': '+442072877073',
#    'display_phone': '+44 20 7287 7073',
#    'distance': 181.13696795054122},
#   {'id': 'tg8989Huoygge1GGqR1_8A',
#    'alias': 'beatles-coffee-shop-london',
#    'name': 'Beatles Coffee Shop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/i_44Ov7Fn5271P2TO4zupw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beatles-coffee-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5346523696246,
#     'longitude': -0.174049176031857},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "St John's Wood Underground Station",
#     'address2': 'Finchley Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 6HY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["St John's Wood Underground Station",
#      'Finchley Road',
#      'London NW3 6HY',
#      'United Kingdom']},
#    'phone': '+442075865404',
#    'display_phone': '+44 20 7586 5404',
#    'distance': 3582.004625493745},
#   {'id': 'DAE3fIusVTUGt9PDwPlelg',
#    'alias': 'exmouth-coffee-company-london',
#    'name': 'Exmouth Coffee Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0yrsGXNRm5roKhOo_8VUiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/exmouth-coffee-company-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 81,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.515994, 'longitude': -0.070496},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '83 Whitechapel High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 7QX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Whitechapel High Street',
#      'London E1 7QX',
#      'United Kingdom']},
#    'phone': '+442073771010',
#    'display_phone': '+44 20 7377 1010',
#    'distance': 4553.663911477298},
#   {'id': 'qVpaMQ1s6wqRe2A3K2Ptew',
#    'alias': 'workshop-coffee-london-2',
#    'name': 'Workshop Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2y7vlJhzrionUwEFte2rZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/workshop-coffee-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.517581, 'longitude': -0.142626},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '80 A Mortimer Street',
#     'address2': 'Fitzrovia',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 7FE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['80 A Mortimer Street',
#      'Fitzrovia',
#      'London W1W 7FE',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 691.8581768473714},
#   {'id': 'rQKDeNCx8LkUR12YH9LpVg',
#    'alias': 'bäkehaus-london-2',
#    'name': 'Bäkehaus',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t8nwOKGUsvFhyuNdJFTrvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b%C3%A4kehaus-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4926600176647,
#     'longitude': -0.227837562561035},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '71 King Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W6 9HW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['71 King Street', 'London W6 9HW', 'United Kingdom']},
#    'phone': '+442034903231',
#    'display_phone': '+44 20 3490 3231',
#    'distance': 6743.794563736779},
#   {'id': '7Nme-QeQ65gtQEyoB0KyEw',
#    'alias': 'the-coffee-jar-london',
#    'name': 'The Coffee Jar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/26Cm2OUJsOTPR_xpptHdhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-coffee-jar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5373402066451,
#     'longitude': -0.145319216450743},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '83 Parkway',
#     'address2': 'Camden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 7PP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Parkway',
#      'Camden',
#      'London NW1 7PP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2800.7359403054115},
#   {'id': 'ZDDEKWdrpjJHqX2d0InVMg',
#    'alias': 'urban-baristas-london-2',
#    'name': 'Urban Baristas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/f5NsZ4qiBlgvwVMbwh54Qg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/urban-baristas-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5108318662288,
#     'longitude': -0.187354646623135},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Queensway',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 4QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Queensway', 'London W2 4QJ', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3563.8944950081736},
#   {'id': '4LrPlD9U-E0oxyAFBCjChw',
#    'alias': 'tap-coffee-no-114-london',
#    'name': 'Tap Coffee No.114',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/M97PW0Ttz9OwyUKZHgqIkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tap-coffee-no-114-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.523831, 'longitude': -0.137085},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '114 Tottenham Court Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 5AQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['114 Tottenham Court Road',
#      'London W1T 5AQ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1225.1340149771556},
#   {'id': '5BKcsFbleeE0vk7vVF0Mxg',
#    'alias': 'flocafe-espresso-room-london',
#    'name': 'Flocafe Espresso Room',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/teLAYxpNGhjJCUkUv-Lwug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flocafe-espresso-room-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.514113, 'longitude': -0.148489},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '40 South Molton Str',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1K 5RW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 South Molton Str',
#      'London W1K 5RW',
#      'United Kingdom']},
#    'phone': '+447949502551',
#    'display_phone': '+44 7949 502551',
#    'distance': 876.7118021751821},
#   {'id': 'riWepzZEIHj82UiDk_WVLQ',
#    'alias': 'montparnasse-cafe-london-2',
#    'name': 'Montparnasse Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/90P9GQECkOj3aZIrJfpO8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/montparnasse-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5005205, 'longitude': -0.1885342},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '22 Thackeray Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 5ET',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Thackeray Street',
#      'London W8 5ET',
#      'United Kingdom']},
#    'phone': '+442073762212',
#    'display_phone': '+44 20 7376 2212',
#    'distance': 3888.086719460034},
#   {'id': '5or4AzNouZq8RClNeTdqiA',
#    'alias': 'ole-and-steen-london-2',
#    'name': 'Ole and Steen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HhmDFvGw42MnOJErQE9vkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ole-and-steen-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.509238, 'longitude': -0.1326965},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '56 Haymarket',
#     'address2': '',
#     'address3': "No 2 St James's Market",
#     'city': 'London',
#     'zip_code': 'SW1Y 4RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['56 Haymarket',
#      "No 2 St James's Market",
#      'London SW1Y 4RP',
#      'United Kingdom']},
#    'phone': '+442038288242',
#    'display_phone': '+44 20 3828 8242',
#    'distance': 459.23424350084883},
#   {'id': '5sKkrr9Hae1FDNpLN_S-PA',
#    'alias': 'origin-coffee-roasters-london-2',
#    'name': 'Origin Coffee Roasters',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mS-zdmjSfnJoJoRBPz527g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/origin-coffee-roasters-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5291835916195,
#     'longitude': -0.126726078698084},
#    'transactions': [],
#    'location': {'address1': 'The British Library',
#     'address2': '96 Euston Road',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW1 2DB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The British Library',
#      '96 Euston Road',
#      'London NW1 2DB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1926.7251654970423},
#   {'id': 'uN9nxbQlUmXUMv1kt8Ye1w',
#    'alias': 'saint-espresso-london-2',
#    'name': 'Saint Espresso',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6wpKqcs2qZXaLHdioBj9pQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saint-espresso-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5233293750657,
#     'longitude': -0.158073306083679},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '214 Baker Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW1',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['214 Baker Street', 'London NW1', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1924.4771101888414},
#   {'id': 'SZKnyELeuleFThFU5-1h0Q',
#    'alias': 'harrisons-coffee-paddington',
#    'name': "Harrison's Coffee",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LDtQXhUkPNHzYBSHxy4vpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harrisons-coffee-paddington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5143226926966,
#     'longitude': -0.175418145954609},
#    'transactions': [],
#    'location': {'address1': '3 Spring Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Paddington',
#     'zip_code': 'W2 3RA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Spring Street',
#      'Paddington W2 3RA',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2735.7867325594743},
#   {'id': '12y5F7hEoYAgur9eslpqCg',
#    'alias': 'kaffeine-london-2',
#    'name': 'Kaffeine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m1YMTCBNVuvdcmVaiu8wZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaffeine-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5168726, 'longitude': -0.137167},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '15 Eastcastle Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 3AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Eastcastle Street',
#      'London W1T 3AY',
#      'United Kingdom']},
#    'phone': '+442075806755',
#    'display_phone': '+44 20 7580 6755',
#    'distance': 456.6591394087493},
#   {'id': 'PYwzVOvFIjwCMNYV5upPwg',
#    'alias': 'the-attendant-london-2',
#    'name': 'The Attendant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W4pc8bJ_lVWg801nKejVOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-attendant-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 74,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5192470995905,
#     'longitude': -0.140738025145255},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Downstairs 27A',
#     'address2': 'Foley Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 6DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Downstairs 27A',
#      'Foley Street',
#      'London W1W 6DY',
#      'United Kingdom']},
#    'phone': '+442076373794',
#    'display_phone': '+44 20 7637 3794',
#    'distance': 785.9877629261662},
#   {'id': 'aiJJB8O0l_0bXFVhZrZyKw',
#    'alias': 'sista-barista-london',
#    'name': 'Sista Barista',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/S8yGnLX12eMVREwW401ojA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sista-barista-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.499619, 'longitude': -0.1142224},
#    'transactions': [],
#    'location': {'address1': 'Sista Barista',
#     'address2': '141 Westminster Bridge Road',
#     'address3': 'Waterloo',
#     'city': 'London',
#     'zip_code': 'SE1 7HR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Sista Barista',
#      '141 Westminster Bridge Road',
#      'Waterloo',
#      'London SE1 7HR',
#      'United Kingdom']},
#    'phone': '+442079280990',
#    'display_phone': '+44 20 7928 0990',
#    'distance': 2102.934967860448},
#   {'id': '68gc1BAE1IT_zZghFafw0Q',
#    'alias': 'ozone-coffee-london-2',
#    'name': 'Ozone Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FMKfpA6gKHlDAKDuPVVdTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ozone-coffee-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 188,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.524683689256,
#     'longitude': -0.086674106560876},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Leonard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 4AQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Leonard Street',
#      'London EC2A 4AQ',
#      'United Kingdom']},
#    'phone': '+442074901039',
#    'display_phone': '+44 20 7490 1039',
#    'distance': 3655.552919913525},
#   {'id': 'AH_Hk4-QQ7KbkIs4H6lfTQ',
#    'alias': 'black-sheep-coffee-london-14',
#    'name': 'Black Sheep Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3gIhZPoxINQqdA9KKSt9cg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-sheep-coffee-london-14?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5199084, 'longitude': -0.1340499},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5-7 Goodge Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1T 2PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5-7 Goodge Street',
#      'London W1T 2PD',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 797.4480439481582},
#   {'id': 'S_1iMSbWOa4I7pa8BxWZag',
#    'alias': 'hart-and-lova-london',
#    'name': 'Hart & Lova',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9VIDKCRKfqFstQt53jVA-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hart-and-lova-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5384383, 'longitude': -0.190891},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '213 Belsize Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 4AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['213 Belsize Road',
#      'London NW6 4AA',
#      'United Kingdom']},
#    'phone': '+447882806540',
#    'display_phone': '+44 7882 806540',
#    'distance': 4748.534923920667},
#   {'id': '-EPJuMu8Qbr5azjHu_QOtg',
#    'alias': 'the-watch-house-london-5',
#    'name': 'The Watch House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/v6IlbI-P0BgzdTxXQcQn2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-watch-house-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4980461313304,
#     'longitude': -0.0810502413027092},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '199 Bermondsey Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 3UW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['199 Bermondsey Street',
#      'London SE1 3UW',
#      'United Kingdom']},
#    'phone': '+442074075431',
#    'display_phone': '+44 20 7407 5431',
#    'distance': 4140.698976372922},
#   {'id': 'mK87F1KiR7Ph-iOwI45Thw',
#    'alias': 'milk-london-2',
#    'name': 'Milk',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mkSDunrDVhCd2ba-ISglrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/milk-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.444649, 'longitude': -0.1510286},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18-20 Bedford Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW12 9RG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18-20 Bedford Hill',
#      'London SW12 9RG',
#      'United Kingdom']},
#    'phone': '+44442087729085',
#    'display_phone': '+44 442087729085',
#    'distance': 7653.50288388963},
#   {'id': 'xqpUr61KFa1Xx721-E6l_A',
#    'alias': 'kipferl-london-6',
#    'name': 'Kipferl',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CUoYGTlW1CYS-nJ5vAUGPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kipferl-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'austrian', 'title': 'Austrian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.535247538411,
#     'longitude': -0.10339315152949},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Camden Passage',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Camden Passage',
#      'London N1 8ED',
#      'United Kingdom']},
#    'phone': '+442077041555',
#    'display_phone': '+44 20 7704 1555',
#    'distance': 3359.4222431551457},
#   {'id': 'ztuEuIDjVTJMklB2OP3rpg',
#    'alias': 'ty-seven-dials-timberyard-london-2',
#    'name': 'TY Seven Dials - Timberyard',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Gr5lHKB84DjJGw8ESo5I6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ty-seven-dials-timberyard-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 138,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5128577362728,
#     'longitude': -0.127308054907987},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "7 Upper St Martin's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["7 Upper St Martin's Lane",
#      'London WC2H 9DL',
#      'United Kingdom']},
#    'phone': '+442032172009',
#    'display_phone': '+44 20 3217 2009',
#    'distance': 598.4373905869091},
#   {'id': 'IfyCqU5noJALqrXTGKnQsQ',
#    'alias': 'the-little-one-london',
#    'name': 'The Little One',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qqYE8rW0C02TamnqgZCEDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-little-one-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5426041, 'longitude': -0.1555134},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "115 Regent's Park Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8UR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["115 Regent's Park Road",
#      'London NW1 8UR',
#      'United Kingdom']},
#    'phone': '+447510843093',
#    'display_phone': '+44 7510 843093',
#    'distance': 3575.938807492533},
#   {'id': 'y8xX3BDj1bf7-wc4Q9Atvg',
#    'alias': 'the-monocle-cafe-london',
#    'name': 'The Monocle Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WVPzYgrKif_v7M9hkSshJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-monocle-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 69,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5188109085709,
#     'longitude': -0.154666668198166},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '18 Chiltern Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 7QA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Chiltern Street',
#      'London W1U 7QA',
#      'United Kingdom']},
#    'phone': '+442071352040',
#    'display_phone': '+44 20 7135 2040',
#    'distance': 1455.2587544542089},
#   {'id': 'exjNWU4T_uzKOtH3uHIutQ',
#    'alias': 'camden-coffee-house-london',
#    'name': 'Camden Coffee House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bN0xUYpHqvIrvOD59TcF0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camden-coffee-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'restaurants', 'title': 'Restaurants'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5399813, 'longitude': -0.1407954},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '30 Camden Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 9DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Camden Road', 'London NW1 9DP', 'United Kingdom']},
#    'phone': '+442074289477',
#    'display_phone': '+44 20 7428 9477',
#    'distance': 3029.1577816380923},
#   {'id': '7fnq7-pePPEM2WaZ4CLg0g',
#    'alias': 'department-of-coffee-and-social-affairs-london',
#    'name': 'Department of Coffee and Social Affairs',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/W_xUKBTvCBaAlWlj7UjbUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/department-of-coffee-and-social-affairs-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5194646, 'longitude': -0.1089855},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14-16 Leather Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1N 7SU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14-16 Leather Lane',
#      'London EC1N 7SU',
#      'United Kingdom']},
#    'phone': '+442074196906',
#    'display_phone': '+44 20 7419 6906',
#    'distance': 2005.7501145358774},
#   {'id': 'lkethHYEgAT3gE-09fLWag',
#    'alias': 'yumchaa-soho-london',
#    'name': 'Yumchaa Soho',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Si6ohuBWReqcfiWiaPMNYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yumchaa-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 161,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515164726519,
#     'longitude': -0.13609727051977},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '45 Berwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8SF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Berwick Street',
#      'London W1F 8SF',
#      'United Kingdom']},
#    'phone': '+442072099641',
#    'display_phone': '+44 20 7209 9641',
#    'distance': 259.1804522380711},
#   {'id': 'EanCLBAeSJNU9MA0pVlHVg',
#    'alias': 'cafe-twelve-london',
#    'name': 'Cafe Twelve',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uAIN5SbTugPIgyu7ljHtjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-twelve-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.528322, 'longitude': -0.075946},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '57 Hackney Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7NX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57 Hackney Rd', 'London E2 7NX', 'United Kingdom']},
#    'phone': '+442077299319',
#    'display_phone': '+44 20 7729 9319',
#    'distance': 4494.95978931185},
#   {'id': 'PBFvhVyBi0lEJyTbyuxf5w',
#    'alias': 'the-orangery-london-7',
#    'name': 'The Orangery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L_0d22xNmfCC_d-tArBo3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-orangery-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 238,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5066360577041,
#     'longitude': -0.187725349125042},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Kensington Palace',
#     'address2': 'Palace Green',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Kensington Palace',
#      'Palace Green',
#      'London W8 4PX',
#      'United Kingdom']},
#    'phone': '+442031666113',
#    'display_phone': '+44 20 3166 6113',
#    'distance': 3648.4574890404074},
#   {'id': 'RJd6_J2dekhZT3g7S2sFKQ',
#    'alias': 'ripe-kitchen-london',
#    'name': 'Ripe Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eWdcUDw5jrPd2z1GjchEdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ripe-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'healthmarkets', 'title': 'Health Markets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5406973, 'longitude': -0.1572616},
#    'transactions': [],
#    'location': {'address1': '136 Regents Park Road',
#     'address2': 'Primrose Hill',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8XL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['136 Regents Park Road',
#      'Primrose Hill',
#      'London NW1 8XL',
#      'United Kingdom']},
#    'phone': '+447572480102',
#    'display_phone': '+44 7572 480102',
#    'distance': 3430.830308059021},
#   {'id': 'BjPq77aiaKZAVUHIu2S3gA',
#    'alias': 'the-english-rose-cafe-and-tea-shop-london',
#    'name': 'The English Rose Cafe and Tea Shop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B_v1cOkgPEcbr8e2rtfaog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-english-rose-cafe-and-tea-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 213,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4980558, 'longitude': -0.1444512},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 Lower Grosvenor Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 0EJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Lower Grosvenor Place',
#      'London SW1W 0EJ',
#      'United Kingdom']},
#    'phone': '+442079766280',
#    'display_phone': '+44 20 7976 6280',
#    'distance': 1745.2072668809335},
#   {'id': 'XraXeaxvh09W1szdtUAhtA',
#    'alias': 'wired-london-2',
#    'name': 'Wired',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nI7InjY0IM3xYKoEPDTZWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wired-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5464769286194,
#     'longitude': -0.190354272016259},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '194 Broadhurst Gardens',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 3AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['194 Broadhurst Gardens',
#      'London NW6 3AY',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5305.998105158604},
#   {'id': 'p77CnjTGOIZA1hEpLfCC6Q',
#    'alias': 'kennington-lane-cafe-london',
#    'name': 'Kennington Lane Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4pjtT4PSUYl_0_BqOTx6Cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kennington-lane-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4860611, 'longitude': -0.1208514},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '383 Kennington Lane',
#     'address2': 'Vauxhall',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE11 5QY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['383 Kennington Lane',
#      'Vauxhall',
#      'London SE11 5QY',
#      'United Kingdom']},
#    'phone': '+442077355853',
#    'display_phone': '+44 20 7735 5853',
#    'distance': 3147.932368103276},
#   {'id': '9kYUIi9guLcWh3iFOJ_vWg',
#    'alias': 'knockbox-coffee-london',
#    'name': 'Knockbox Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IrDnvf2dRXzDwYW9xz__yA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/knockbox-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5211323, 'longitude': -0.1180363},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '29 Lambs Conduit Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 3NG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['29 Lambs Conduit Street',
#      'London WC1N 3NG',
#      'United Kingdom']},
#    'phone': '+442034897325',
#    'display_phone': '+44 20 3489 7325',
#    'distance': 1545.4931234557102},
#   {'id': 'UjsIWFM9xcD9PCO0nJoMCQ',
#    'alias': 'caffe-in-london',
#    'name': 'Caffe In',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O4NH7q62sJXw765I_8fEvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-in-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.506194, 'longitude': -0.146446},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3 Shepherd Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 7HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Shepherd Street',
#      'London W1J 7HL',
#      'United Kingdom']},
#    'phone': '+442074936400',
#    'display_phone': '+44 20 7493 6400',
#    'distance': 1032.7212314091926},
#   {'id': '371SNZXi292Y2tPYV-EEmQ',
#    'alias': 'the-roasting-london',
#    'name': 'The Roasting',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lZSW6AQ00PGIzgrwKV912g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-roasting-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4912614, 'longitude': -0.1388321},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '31 Churton Street',
#     'address2': '23 Elizabeth Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 2LY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['31 Churton Street',
#      '23 Elizabeth Street',
#      'London SW1V 2LY',
#      'United Kingdom']},
#    'phone': '+442078346091',
#    'display_phone': '+44 20 7834 6091',
#    'distance': 2394.8792765738704}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#           Restaurant          Type Price Rating                     Address  \
# 0          Fuckoffee  Coffee & Tea     £      4   163-167 Bermondsey Street
# 1            Fix 126  Coffee & Tea    ££      4            126 Curtain Road
# 2    Monmouth Coffee  Coffee & Tea    ££    4.5          27 Monmouth Street
# 3  Omotesando Koffee  Coffee & Tea                          8 Newman Street
# 4           Kaffeine  Coffee & Tea    ££    4.5  66 Great Titchfield Street
#
#          Lat       Lng                                                url  \
# 0  51.499381 -0.081249  https://www.yelp.com/biz/fuckoffee-london-3?ad...
# 1  51.526125 -0.080215  https://www.yelp.com/biz/fix-126-london?adjust...
# 2  51.514354 -0.126917  https://www.yelp.com/biz/monmouth-coffee-londo...
# 3  51.516566 -0.134790
# 4  51.518480 -0.140370  https://www.yelp.com/biz/kaffeine-london?adjus...
#
#                        ID
# 0  -22PaX8rQyh0ZQrdCiDz4A
# 1  3fDLrrmStQBZFMBHUvMbrQ
# 2  Opa8XUwUghxbGFafvubV6A
# 3
# 4  mvds37L7mCurGn3rGPM8ag

# %%
#2nd set of 50 records 51-100 
lndr_params2 = {"term":"coffee","location":"London","limit":50,"offset":51}
lndr_response2 = requests.get(search_api_url, headers=headers, params=lndr_params2)
lndr2 = lndr_response2.json()
display(lndr2)
#print(lndr_response2.url)
#print(lndr_response2.status_code)
# Out:
# {'businesses': [{'id': 'ltNrgT5KBga_-G09KPKUGA',
#    'alias': 'ginger-and-white-london',
#    'name': 'Ginger & White',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7QXlwpFegZ2gwdzLskNX8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginger-and-white-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5554778031252, 'longitude': -0.178065},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "4 Perrin's Court",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 1QS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["4 Perrin's Court",
#      'London NW3 1QS',
#      'United Kingdom']},
#    'phone': '+442074319098',
#    'display_phone': '+44 20 7431 9098',
#    'distance': 5564.726459557364},
#   {'id': 'C0WXN7VeBUNg4tg7Fu-N3A',
#    'alias': 'taylor-st-baristas-london-11',
#    'name': 'Taylor St Baristas',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Jox53dWlyjxJJZ03kqk7Pw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taylor-st-baristas-london-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4987165702106,
#     'longitude': -0.0149627110749048},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Exchange Tower',
#     'address2': '1 Harbour Exchange Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E14 9GB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Exchange Tower',
#      '1 Harbour Exchange Square',
#      'London E14 9GB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8520.021316952803},
#   {'id': '6bC5rzsmpnF8amwsgfsG9Q',
#    'alias': 'noble-espresso-london',
#    'name': 'Noble Espresso',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3OgqnI6OOfcP3klQcUVDSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noble-espresso-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5321090042632,
#     'longitude': -0.12496336150654},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Battle Bridge Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4TB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Battle Bridge Place',
#      'London N1C 4TB',
#      'United Kingdom']},
#    'phone': '+447854895078',
#    'display_phone': '+44 7854 895078',
#    'distance': 2274.0549261321103},
#   {'id': 'kpNbaGRBwC3I7OPqQNqimg',
#    'alias': 'chapter-coffee-roasters-london',
#    'name': 'Chapter Coffee Roasters',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UVLvJzPYoo_SGts9nPsfEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chapter-coffee-roasters-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4919847, 'longitude': -0.2071349},
#    'transactions': [],
#    'location': {'address1': '137 North End Road',
#     'address2': 'West Kensington',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W14 8XU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['137 North End Road',
#      'West Kensington',
#      'London W14 8XU',
#      'United Kingdom']},
#    'phone': '+442038753655',
#    'display_phone': '+44 20 3875 3655',
#    'distance': 5445.057639939854},
#   {'id': 'IZsschY-x-Asv1daf43FJQ',
#    'alias': 'workshop-coffee-london-3',
#    'name': 'Workshop Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tU9SC1Kp9_QYqXmr5lXjKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/workshop-coffee-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5151520463904,
#     'longitude': -0.150024120371164},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Barrett Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 1AX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Barrett Street',
#      'London W1U 1AX',
#      'United Kingdom']},
#    'phone': '+442072516501',
#    'display_phone': '+44 20 7251 6501',
#    'distance': 1007.0161685658328},
#   {'id': 'sTjZJB20joSHE8oVPHs1Cw',
#    'alias': 'covent-garden-grind-london',
#    'name': 'Covent Garden Grind',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c7YW3mmPah5JplPL-fFPbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/covent-garden-grind-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5110479046224,
#     'longitude': -0.122459969000028},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '42 Maiden Lane',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 7LJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 Maiden Lane',
#      'Covent Garden',
#      'London WC2E 7LJ',
#      'United Kingdom']},
#    'phone': '+442030191801',
#    'display_phone': '+44 20 3019 1801',
#    'distance': 954.8611659358846},
#   {'id': 'mQAB6Tv7FW298r5aFTczeA',
#    'alias': 'jacob-the-angel-london',
#    'name': 'Jacob the Angel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r8mmBUT46aVErLmtcVxcAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jacob-the-angel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5146, 'longitude': -0.12651},
#    'transactions': [],
#    'location': {'address1': "16 1/2 Neal's yard",
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["16 1/2 Neal's yard",
#      'Covent Garden',
#      'London WC2H 9',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 682.4571321654374},
#   {'id': 'XN7K4g1Wq-93WYvg85EgMg',
#    'alias': 'the-gentlemen-baristas-london',
#    'name': 'The Gentlemen Baristas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/weXGI3HolMjieVD466xwyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-gentlemen-baristas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.503841999477,
#     'longitude': -0.0947035655992168},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '63 Union Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1SG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63 Union Street',
#      'London SE1 1SG',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3025.052485481412},
#   {'id': 'aYd2mlWPlQmJdKHbiWq0PA',
#    'alias': 'pattern-coffee-london',
#    'name': 'Pattern Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZXSktRmEi6hPrSVc-we4JQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pattern-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.532962, 'longitude': -0.119133},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '82 Caledonian Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9DN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['82 Caledonian Rd',
#      'London N1 9DN',
#      'United Kingdom']},
#    'phone': '+442078371981',
#    'display_phone': '+44 20 7837 1981',
#    'distance': 2523.2727710781455},
#   {'id': 'uA_H2UI3nPL7-L11G61-wA',
#    'alias': 'hackney-coffee-company-london',
#    'name': 'Hackney Coffee Company',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xliZ9Rmj6VT4o_mBM0i7Hw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hackney-coffee-company-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5325459, 'longitude': -0.0584213},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '503 Hackney Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 9ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['503 Hackney Road',
#      'London E2 9ED',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5794.75520452962},
#   {'id': 'UMJxTGTSShg2u1FFwZBWAQ',
#    'alias': 'the-book-club-london',
#    'name': 'The Book Club',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8HCdjBRKyg074ero0uqGAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-book-club-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.524537, 'longitude': -0.081494},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '100 Leonard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 4RH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['100 Leonard Street',
#      'London EC2A 4RH',
#      'United Kingdom']},
#    'phone': '+442076848618',
#    'display_phone': '+44 20 7684 8618',
#    'distance': 3994.972382925784},
#   {'id': 'guy3VKpOBfK0E4OTmLJNlg',
#    'alias': 'oak-caffe-london',
#    'name': 'Oak Caffe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MCUzUS3S-peJXNp6gIEmjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oak-caffe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.6299, 'longitude': -0.174439},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '1 Oakleigh Road North',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N20 9HE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Oakleigh Road North',
#      'London N20 9HE',
#      'United Kingdom']},
#    'phone': '+442084455217',
#    'display_phone': '+44 20 8445 5217',
#    'distance': 13285.894971055752},
#   {'id': 'X3Bf648lnr4QNO8JQr3PAw',
#    'alias': 'workshop-coffee-london-5',
#    'name': 'Workshop Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kiqygcsGXthASIGhpWF7YA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/workshop-coffee-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5170786, 'longitude': -0.1041372},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '60a Holborn Viaduct',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1A 2FD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['60a Holborn Viaduct',
#      'London EC1A 2FD',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2251.757295623384},
#   {'id': 'f8s8dT9Rm4359xUVHtiqRA',
#    'alias': 'black-cat-london',
#    'name': 'Black Cat',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RZHJY2Tw6cAtF7ZrT7vQTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-cat-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5513968, 'longitude': -0.055691},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '76 Clarence Road',
#     'address2': 'Hackney',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E5 8HB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['76 Clarence Road',
#      'Hackney',
#      'London E5 8HB',
#      'United Kingdom']},
#    'phone': '+442089857091',
#    'display_phone': '+44 20 8985 7091',
#    'distance': 7015.023023552639},
#   {'id': 'o1gFln8kSV4Y36Zo420dyQ',
#    'alias': 'vanilla-black-coffee-and-books-london',
#    'name': 'Vanilla Black Coffee and Books',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rm-Ghsek7uCOp2p5p3fxBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vanilla-black-coffee-and-books-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'usedbooks', 'title': 'Used Bookstore'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4874737983978,
#     'longitude': -0.11141661554575},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '306-308 Kennington Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE11 4LD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['306-308 Kennington Road',
#      'London SE11 4LD',
#      'United Kingdom']},
#    'phone': '+442077355505',
#    'display_phone': '+44 20 7735 5505',
#    'distance': 3292.1395618571432},
#   {'id': '9Rt2XZouSHgIyrYRmypVXA',
#    'alias': 'hagen-london',
#    'name': 'Hagen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jGC4_HvZFEIXeNejpzXs5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hagen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4878836, 'longitude': -0.1671998},
#    'transactions': [],
#    'location': {'address1': "151 King's Road",
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW3 5TX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["151 King's Road",
#      'London SW3 5TX',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3517.85048149},
#   {'id': 'alG0_K6eXYLGTfnDhrEmzA',
#    'alias': 'mouse-tail-coffee-stories-london-4',
#    'name': 'Mouse Tail Coffee Stories',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CtUTWkIMYMmt8gEbQN9QLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mouse-tail-coffee-stories-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4978022252176,
#     'longitude': -0.0478901037367684},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Deal Porters Way',
#     'address2': 'Canada Water Plaza',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE16 7AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Deal Porters Way',
#      'Canada Water Plaza',
#      'London SE16 7AP',
#      'United Kingdom']},
#    'phone': '+447552961118',
#    'display_phone': '+44 7552 961118',
#    'distance': 6320.298054379184},
#   {'id': '38ESTPT2Ri_Yz58oCwCIXw',
#    'alias': 'black-sheep-coffee-london-34',
#    'name': 'Black Sheep Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XCl7TLc02XAEhKXc7ClX4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-sheep-coffee-london-34?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.496363, 'longitude': -0.143891},
#    'transactions': [],
#    'location': {'address1': '189 Victoria Street',
#     'address2': 'Ground Floor & Basement',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1E 5NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['189 Victoria Street',
#      'Ground Floor & Basement',
#      'London SW1E 5NE',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1912.228550160135},
#   {'id': 'BNAddFkvoUGR1l6AL32p8w',
#    'alias': 'over-under-coffee-london-3',
#    'name': 'Over Under Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nlSAXEZwQAl5HFBHSWTpvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/over-under-coffee-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4923794, 'longitude': -0.1930041},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "181A Earl's Court Road",
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW5 9RD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["181A Earl's Court Road",
#      'London SW5 9RD',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4556.96556200919},
#   {'id': 'FM2fOny0zttmwnSeHCHzyA',
#    'alias': 'fabrique-bakery-london-5',
#    'name': 'Fabrique Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1-A9bxyUwournvQ4hL3sMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fabrique-bakery-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516469, 'longitude': -0.205223},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '212 Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 1LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['212 Portobello Road',
#      'London W11 1LA',
#      'United Kingdom']},
#    'phone': '+442072213721',
#    'display_phone': '+44 20 7221 3721',
#    'distance': 4813.9954429630825},
#   {'id': 'W7DpFG8AbfLi516fIvgdDg',
#    'alias': 'abbey-cafe-london',
#    'name': 'Abbey Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UedDW_RDdKobWFYeQBagGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/abbey-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.531848626266,
#     'longitude': -0.18065861355395},
#    'transactions': [],
#    'location': {'address1': '3 Nugent Terrace',
#     'address2': "St. John's Wood",
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 9QB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Nugent Terrace',
#      "St. John's Wood",
#      'London NW8 9QB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3746.3652871577324},
#   {'id': 'wajEwOovLij1W_GC_z7FaQ',
#    'alias': 'toms-roasting-co-london',
#    'name': 'Toms Roasting Co.',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PiRLAbEcHyFgXpy3hOWqYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/toms-roasting-co-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5133923620049,
#     'longitude': -0.139904894435634},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '5-7 Fouberts Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7PY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5-7 Fouberts Place',
#      'London W1F 7PY',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 280.2051722764215},
#   {'id': 'lCRkNZaofaiUn-CEOQNr3g',
#    'alias': 'coffee-island-london',
#    'name': 'Coffee Island',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KuqkbDTzA7csmM6vdmZ7eA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffee-island-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51224, 'longitude': -0.127379},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "5 Upper St Martin's Lane",
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9NY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["5 Upper St Martin's Lane",
#      'London WC2H 9NY',
#      'United Kingdom']},
#    'phone': '+442078363007',
#    'display_phone': '+44 20 7836 3007',
#    'distance': 608.4664698472292},
#   {'id': 'MliUZtEV91sjiNN-OgLq_A',
#    'alias': 'prufrock-coffee-london-2',
#    'name': 'Prufrock Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JdIpUpy8TrYo42xBatSwgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prufrock-coffee-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51997, 'longitude': -0.10958},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '23-25 Leather Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1N 7TE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23-25 Leather Lane',
#      'London EC1N 7TE',
#      'United Kingdom']},
#    'phone': '+442072420467',
#    'display_phone': '+44 20 7242 0467',
#    'distance': 1995.269333811344},
#   {'id': 'MIKUeHBDQs46i6YOVeNKyw',
#    'alias': 'h-r-higgins-london',
#    'name': 'H R Higgins',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eAfRQlbtrCwZ8MP0k8Uisw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/h-r-higgins-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5129642, 'longitude': -0.1508551},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '79 Duke Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1K 5AS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['79 Duke Street', 'London W1K 5AS', 'United Kingdom']},
#    'phone': '+442074918819',
#    'display_phone': '+44 20 7491 8819',
#    'distance': 1031.1420005559974},
#   {'id': 'I1FOTVrKirQfWT1yv25yxA',
#    'alias': 'doppio-cafe-london',
#    'name': 'Doppio Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pICCYeiUmRxQ7Bm6645QcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doppio-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5461019420634,
#     'longitude': -0.141918025910854},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '177 Kentish Town Road',
#     'address2': 'Camden Town',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['177 Kentish Town Road',
#      'Camden Town',
#      'London NW1 8PD',
#      'United Kingdom']},
#    'phone': '+442072675993',
#    'display_phone': '+44 20 7267 5993',
#    'distance': 3721.975381913747},
#   {'id': 'dyAE0ROgElNHbRa-y3CfFw',
#    'alias': 'sacred-london',
#    'name': 'Sacred',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gbnky4zCMMrFXmkPjO3zlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sacred-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 69,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512954, 'longitude': -0.138923},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '13 Ganton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9BL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Ganton Street',
#      'London W1F 9BL',
#      'United Kingdom']},
#    'phone': '+447595733057',
#    'display_phone': '+44 7595 733057',
#    'distance': 201.35274674274652},
#   {'id': 'i4jQhsURQ50QwP2c0qJOnQ',
#    'alias': 'black-sheep-coffee-london-30',
#    'name': 'Black Sheep Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m8dhiVXpDGYiKgSVWvNceQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-sheep-coffee-london-30?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5220047128414,
#     'longitude': -0.0799236232787734},
#    'transactions': [],
#    'location': {'address1': '115 Worship Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 2BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['115 Worship Street',
#      'London EC2A 2BA',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4008.905204960933},
#   {'id': 'DXMoezQ1WxA-lzvSNPg6Og',
#    'alias': 'd1-coffee-little-venice',
#    'name': 'D1 Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mOMm9erE16oTv2gxuM4sjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/d1-coffee-little-venice?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5248684, 'longitude': -0.1763357},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Aberdeen Place',
#     'address2': '',
#     'address3': '',
#     'city': 'Little Venice',
#     'zip_code': 'NW8 8JN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Aberdeen Place',
#      'Little Venice NW8 8JN',
#      'United Kingdom']},
#    'phone': '+442077233337',
#    'display_phone': '+44 20 7723 3337',
#    'distance': 3097.807873394816},
#   {'id': 'ghg0SAC1cuKkk46ji-M9Kw',
#    'alias': 'the-black-lab-coffee-house-london',
#    'name': "'The Black Lab' Coffee House",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/e_hPHnpzTNA0ezHfxHGFiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-black-lab-coffee-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4610903556983,
#     'longitude': -0.138673064112254},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18 Clapham Common South Side',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW4 7AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Clapham Common South Side',
#      'London SW4 7AB',
#      'United Kingdom']},
#    'phone': '+442077388441',
#    'display_phone': '+44 20 7738 8441',
#    'distance': 5756.8687201302955},
#   {'id': 'Xqj98iIyqB3BDjkICbs8Eg',
#    'alias': 'lanark-coffee-london',
#    'name': 'Lanark Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/j8152h-IVPDUdEzAymvs4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lanark-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5309641, 'longitude': -0.0687264},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '262 Hackney Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7SJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['262 Hackney Road',
#      'London E2 7SJ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5069.425430530156},
#   {'id': '-6GHU4qI0DKsIrBpv57qTg',
#    'alias': 'e5-bakehouse-london',
#    'name': 'E5 Bakehouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5fOMHTqW0WvJz3o4ojfxXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/e5-bakehouse-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5412038403948,
#     'longitude': -0.0576161965996107},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '395 Mentmore Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 3PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['395 Mentmore Terrace',
#      'London E8 3PH',
#      'United Kingdom']},
#    'phone': '+442085252890',
#    'display_phone': '+44 20 8525 2890',
#    'distance': 6270.653368630909},
#   {'id': '1kTiW_C-WQbebTCqkV6xYg',
#    'alias': 'camden-coffee-shop-london',
#    'name': 'Camden Coffee Shop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5rRQALuKN9v6BPrXOqHwfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camden-coffee-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.536842323903,
#     'longitude': -0.14207936959551},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '11 Delancey Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 7NL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Delancey Street',
#      'London NW1 7NL',
#      'United Kingdom']},
#    'phone': '+442073874080',
#    'display_phone': '+44 20 7387 4080',
#    'distance': 2702.839238520007},
#   {'id': 'Nb7nzRoJdGi74Q1TOTcwUw',
#    'alias': 'sally-white-london',
#    'name': 'Sally White',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/i17osVd1Ku5gIk0J833JOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sally-white-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4872522, 'longitude': -0.1111273},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '353 Kennington Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE11 4QE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['353 Kennington Road',
#      'London SE11 4QE',
#      'United Kingdom']},
#    'phone': '+442075820066',
#    'display_phone': '+44 20 7582 0066',
#    'distance': 3338.909143450355},
#   {'id': 'u4fN4OgdtAzT4xeiZut3qw',
#    'alias': 'flat-cap-coffee-co-london',
#    'name': 'Flat Cap Coffee Co',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/27yODSTSPf8tydUNauKbLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flat-cap-coffee-co-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4972694, 'longitude': -0.1340628},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '4 Strutton Ground',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 2HR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Strutton Ground',
#      'London SW1P 2HR',
#      'United Kingdom']},
#    'phone': '+447861425172',
#    'display_phone': '+44 7861 425172',
#    'distance': 1719.2728006151283},
#   {'id': '1TgYqfxkXv6-IB4cvuuy3w',
#    'alias': 'tea-and-tattle-london',
#    'name': 'Tea and Tattle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zm3bEijY0rcDGz-5Nw9sKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tea-and-tattle-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5178680419922,
#     'longitude': -0.126817002892494},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '41 Great Russell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3PE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41 Great Russell Street',
#      'London WC1B 3PE',
#      'United Kingdom']},
#    'phone': '+447722192703',
#    'display_phone': '+44 7722 192703',
#    'distance': 841.826045500197},
#   {'id': 'MXYj38qKszh9Z7YATzmrrA',
#    'alias': 'store-street-espresso-london',
#    'name': 'Store Street Espresso',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/A-FYmm4F48gSZWZBFrTG8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/store-street-espresso-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 62,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5200997, 'longitude': -0.1306308},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '40 Store Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1E 7DB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 Store Street',
#      'London WC1E 7DB',
#      'United Kingdom']},
#    'phone': '+442076372623',
#    'display_phone': '+44 20 7637 2623',
#    'distance': 899.7744295076758},
#   {'id': 'GsH186S8zYC3ANyn0AE9Ug',
#    'alias': 'black-sheep-coffee-london-38',
#    'name': 'Black Sheep Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/q1OxTbTnWFy6RLFHBTpOXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-sheep-coffee-london-38?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5054958565293,
#     'longitude': -0.0994014978095711},
#    'transactions': [],
#    'location': {'address1': '81 Southwark Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 0HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['81 Southwark Street',
#      'London SE1 0HX',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2658.1826096918026},
#   {'id': 'k7qmLDOGfESN8fDBQZZL7w',
#    'alias': '106-baker-st-london',
#    'name': '106 Baker St',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9CXBPhU2Ib_gv7QmtYAMCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/106-baker-st-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5207977, 'longitude': -0.1566825},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '106 Baker Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 6TW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['106 Baker Street',
#      'London W1U 6TW',
#      'United Kingdom']},
#    'phone': '+442074873372',
#    'display_phone': '+44 20 7487 3372',
#    'distance': 1689.8849777286025},
#   {'id': 'HAi7bThXmEtooc5ZQq9hdw',
#    'alias': 'laurents-london',
#    'name': 'Laurents',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IjF-yyo_-fqEs5nTO5MMpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laurents-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.513468, 'longitude': -0.179164},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '39 Craven Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 3BX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39 Craven Road', 'London W2 3BX', 'United Kingdom']},
#    'phone': '+442035819232',
#    'display_phone': '+44 20 3581 9232',
#    'distance': 2990.8516064262462},
#   {'id': 'XqYhhs7WWgOnP_e5x3Wg8g',
#    'alias': 'garden-shack-hideaway-london',
#    'name': 'Garden Shack Hideaway',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iGtACYivM-UcH1iQyS19Zg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/garden-shack-hideaway-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5027676843354,
#     'longitude': -0.115942216752501},
#    'transactions': [],
#    'location': {'address1': '55 York Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 7NJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55 York Rd', 'London SE1 7NJ', 'United Kingdom']},
#    'phone': '+447912106692',
#    'display_phone': '+44 7912 106692',
#    'distance': 1780.9533069366198},
#   {'id': 'x58LDkXGU7vC8-KRDlS9Mw',
#    'alias': 'raison-d-etre-london',
#    'name': "Raison D'Etre",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GNL9SAtkBRabO34z0GOmqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raison-d-etre-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.493706018346,
#     'longitude': -0.17628170716244},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '18 Bute Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3EX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Bute Street', 'London SW7 3EX', 'United Kingdom']},
#    'phone': '+442075845008',
#    'display_phone': '+44 20 7584 5008',
#    'distance': 3509.3036349562817},
#   {'id': '7XmHitS2QW-MAzhFaCdz6w',
#    'alias': 'arro-coffee-the-temple-of-coffee-london',
#    'name': 'Arro Coffee - The Temple of Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dkIZRvD-fEWapLASMB7MPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arro-coffee-the-temple-of-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51586, 'longitude': -0.18773},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "77 Bishop's Bridge Road",
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 6BG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["77 Bishop's Bridge Road",
#      'London W2 6BG',
#      'United Kingdom']},
#    'phone': '+442072214600',
#    'display_phone': '+44 20 7221 4600',
#    'distance': 3600.8360260651657},
#   {'id': 'YfKn2fkIyXC2jmE1qmgxQw',
#    'alias': 'outsider-tart-london',
#    'name': 'Outsider Tart',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CCbq7o_xmLzRkBXvNOh9TQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/outsider-tart-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4927, 'longitude': -0.252125},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '83 Chiswick High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W4 2EF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Chiswick High Road',
#      'London W4 2EF',
#      'United Kingdom']},
#    'phone': '+442070961609',
#    'display_phone': '+44 20 7096 1609',
#    'distance': 8339.382278059751},
#   {'id': 'mHKOLIto9vuj0fnW-MDQbA',
#    'alias': 'long-and-short-coffee-roasters-london',
#    'name': 'Long & Short Coffee Roasters',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NziRx9LS_5JE8mgj9HNDwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/long-and-short-coffee-roasters-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'coffeeteasupplies', 'title': 'Coffee & Tea Supplies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.52108, 'longitude': -0.07122},
#    'transactions': [],
#    'location': {'address1': 'The Tea Rooms',
#     'address2': '146 Brick Lane',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E1 6QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Tea Rooms',
#      '146 Brick Lane',
#      'London E1 6QL',
#      'United Kingdom']},
#    'phone': '+447903821203',
#    'display_phone': '+44 7903 821203',
#    'distance': 4543.1495647980155},
#   {'id': 'Uk-I7FyRJQoSrT_nAjnbAA',
#    'alias': 'craft-coffee-london',
#    'name': 'Craft Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jQuvU9VskJYLamDWQs63XQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/craft-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4993012, 'longitude': -0.0756092},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '39 Maltby Street',
#     'address2': 'Ropewalk',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 3PA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39 Maltby Street',
#      'Ropewalk',
#      'London SE1 3PA',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4439.521265026938},
#   {'id': 'wsvg4dplxVl9G2Yl6eG6SA',
#    'alias': 'lift-574-london',
#    'name': 'Lift 574',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UhKGx3guRD1hjwwbB6fSVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lift-574-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5453210939865,
#     'longitude': -0.0758013558852211},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '574 Kingsland Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 4AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['574 Kingsland Road',
#      'London E8 4AP',
#      'United Kingdom']},
#    'phone': '+442079239518',
#    'display_phone': '+44 20 7923 9518',
#    'distance': 5510.376144346487},
#   {'id': 'E8Jy84AW-SOyKBL99zQ3hQ',
#    'alias': 'soho-coffee-co-london-3',
#    'name': 'Soho Coffee Co',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LhLRLrIVd-5rwz2KEB5Vyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soho-coffee-co-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5175159490869,
#     'longitude': -0.155770964920521},
#    'transactions': [],
#    'location': {'address1': '19 Baker Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1U 8EQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Baker Street',
#      'London W1U 8EQ',
#      'United Kingdom']},
#    'phone': '+442074867888',
#    'display_phone': '+44 20 7486 7888',
#    'distance': 1466.603478666473},
#   {'id': 'GzC3ChZAzbHcoz1pYwp7dg',
#    'alias': 'the-coffeeworks-project-london-2',
#    'name': 'The CoffeeWorks Project',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5TWR9vFiDoF_W88uVoha4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-coffeeworks-project-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5065012, 'longitude': -0.1042137},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '235 Blackfriars Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8BF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['235 Blackfriars Rd',
#      'London SE1 8BF',
#      'United Kingdom']},
#    'phone': '+442079288456',
#    'display_phone': '+44 20 7928 8456',
#    'distance': 2323.7373700319176},
#   {'id': 'euPJ7RVjrni8E_HcM85dUw',
#    'alias': 'etna-coffee-london',
#    'name': 'Etna Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uzLHyZn7-mMxtWGxejV8ag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/etna-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5188887, 'longitude': -0.1558085},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '54 Baker Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1U 7WH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54 Baker Street',
#      'London W1U 7WH',
#      'United Kingdom']},
#    'phone': '+442079351600',
#    'display_phone': '+44 20 7935 1600',
#    'distance': 1529.7649188479352}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                 Restaurant               Type Price Rating  \
# 0           Ginger & White       Coffee & Tea    ££      4
# 1       Taylor St Baristas       Coffee & Tea     £      5
# 2           Noble Espresso       Coffee & Tea     £      5
# 3  Chapter Coffee Roasters  Coffee Roasteries
# 4          Workshop Coffee       Coffee & Tea    ££    3.5
#
#                Address        Lat       Lng  \
# 0     4 Perrin's Court  51.555478 -0.178065
# 1       Exchange Tower  51.498717 -0.014963
# 2  Battle Bridge Place  51.532109 -0.124963
# 3   137 North End Road  51.491985 -0.207135
# 4     1 Barrett Street  51.515152 -0.150024
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/ginger-and-white-lond...  ltNrgT5KBga_-G09KPKUGA
# 1  https://www.yelp.com/biz/taylor-st-baristas-lo...  C0WXN7VeBUNg4tg7Fu-N3A
# 2  https://www.yelp.com/biz/noble-espresso-london...  6bC5rzsmpnF8amwsgfsG9Q
# 3
# 4  https://www.yelp.com/biz/workshop-coffee-londo...  IZsschY-x-Asv1daf43FJQ

# %%
#3rd set of 50 records 101-150
lndr_params3 = {"term":"coffee","location":"London","limit":50,"offset":101}
lndr_response3 = requests.get(search_api_url, headers=headers, params=lndr_params3)
lndr3 = lndr_response3.json()
display(lndr3)
#print(lndr_response3.url)
#print(lndr_response3.status_code)
# Out:
# {'businesses': [{'id': 'S3h8uhI3wK2Fn4e9gw9bfA',
#    'alias': 'shoreditch-grind-london',
#    'name': 'Shoreditch Grind',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wcWCxMuAey7jvjK6_m5TIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shoreditch-grind-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 116,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5258391235513,
#     'longitude': -0.0879659656067133},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '213 Old Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 9NR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['213 Old Street',
#      'London EC1V 9NR',
#      'United Kingdom']},
#    'phone': '+442074907490',
#    'display_phone': '+44 20 7490 7490',
#    'distance': 3621.631922482148},
#   {'id': 'X0Bw6wgjhmAZraXvPdLELQ',
#    'alias': 'notes-london-4',
#    'name': 'Notes',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2n4_s5u-BgN4-zKSUhwamw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/notes-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 101,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5095536, 'longitude': -0.1267229},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "31 St Martin's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["31 St Martin's Lane",
#      'London WC2N 4ER',
#      'United Kingdom']},
#    'phone': '+442072400424',
#    'display_phone': '+44 20 7240 0424',
#    'distance': 730.1254826123966},
#   {'id': 'UjMwZ6-PgXs3BXN7LLOSAw',
#    'alias': 'gails-bakery-pimlico-london',
#    'name': "GAIL's Bakery - Pimlico",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zobkG9NdbclJN7D9O6w5yw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-pimlico-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4917627846861,
#     'longitude': -0.139058523838447},
#    'transactions': [],
#    'location': {'address1': '26 Churton Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1V 2LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Churton Street',
#      'London SW1V 2LP',
#      'United Kingdom']},
#    'phone': '+442079320734',
#    'display_phone': '+44 20 7932 0734',
#    'distance': 2352.9999537192894},
#   {'id': 'S96e3O7F0EL-ohMVyCRvzw',
#    'alias': 'soho-coffee-london',
#    'name': 'Soho Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6HGHKvsYW2Ma6ok7XFJnLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soho-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5132095, 'longitude': -0.0994357},
#    'transactions': [],
#    'location': {'address1': "10 Saint Paul's Churchyard",
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EC4M 8AL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["10 Saint Paul's Churchyard",
#      'London EC4M 8AL',
#      'United Kingdom']},
#    'phone': '+442080901304',
#    'display_phone': '+44 20 8090 1304',
#    'distance': 2512.4962072063668},
#   {'id': 'FdvJtM_P3V-LqgHAZaTP2A',
#    'alias': 'roasting-plant-coffee-london-2',
#    'name': 'Roasting Plant Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nkAaJQcf6hiDiAb-4Ftn7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roasting-plant-coffee-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5063383556296,
#     'longitude': -0.0885824944037584},
#    'transactions': [],
#    'location': {'address1': '4 Borough High Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 9QQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Borough High Street',
#      'London SE1 9QQ',
#      'United Kingdom']},
#    'phone': '+442073570405',
#    'display_phone': '+44 20 7357 0405',
#    'distance': 3357.1656095130393},
#   {'id': 'rH-b73mF8SB3cSCvNyL-sg',
#    'alias': 'frequency-coffee-london',
#    'name': 'Frequency Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_GLrYMKinoVMfEIEv-TmpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frequency-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5290936188276,
#     'longitude': -0.115869944973013},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "121 King's Cross Road",
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC1X 9NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["121 King's Cross Road",
#      'London WC1X 9NH',
#      'United Kingdom']},
#    'phone': '+447772309231',
#    'display_phone': '+44 7772 309231',
#    'distance': 2280.2406686622753},
#   {'id': 'W8e8gTL6JrY5WQC_6CfJAQ',
#    'alias': 'caffettino-london',
#    'name': 'Caffettino',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8256CLC6rRmCiw3Mf-xHZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffettino-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4737627, 'longitude': -0.1604785},
#    'transactions': [],
#    'location': {'address1': '230-232 Battersea Park Road',
#     'address2': 'Battersea',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW11 4ND',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['230-232 Battersea Park Road',
#      'Battersea',
#      'London SW11 4ND',
#      'United Kingdom']},
#    'phone': '+442077203833',
#    'display_phone': '+44 20 7720 3833',
#    'distance': 4664.613966227975},
#   {'id': '4rpkLLSPzVRqdHlM9_-9Cw',
#    'alias': 'four-corners-cafe-london-2',
#    'name': 'Four Corners Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rq5jjv5YtDdYt9HJQ8OyEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/four-corners-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5003689, 'longitude': -0.1135442},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '12 Lower Marsh',
#     'address2': 'Waterloo',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Lower Marsh',
#      'Waterloo',
#      'London SE1 7RJ',
#      'United Kingdom']},
#    'phone': '+442086179591',
#    'display_phone': '+44 20 8617 9591',
#    'distance': 2080.282557645936},
#   {'id': '8hEXXEyjhbW3349LW4TX0g',
#    'alias': 'tonic-coffee-bar-london',
#    'name': 'Tonic Coffee Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fF24gMaCA7ZhnwrsFeWLAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tonic-coffee-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5111422, 'longitude': -0.1361376},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '15 Sherwood Street',
#     'address2': 'Regent Street Quadrant',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Sherwood Street',
#      'Regent Street Quadrant',
#      'London W1F 7ED',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 188.70831287232065},
#   {'id': '9gqKbR6JK79zTc5RDLP_4A',
#    'alias': 'dominique-ansel-bakery-victoria',
#    'name': 'Dominique Ansel Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_NbEwfiF5IbRjDso83WZpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dominique-ansel-bakery-victoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4926912521198,
#     'longitude': -0.149131484387577},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '17-21 Elizabeth Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Victoria',
#     'zip_code': 'SW1W 9RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17-21 Elizabeth Street',
#      'Victoria SW1W 9RP',
#      'United Kingdom']},
#    'phone': '+442073247705',
#    'display_phone': '+44 20 7324 7705',
#    'distance': 2418.4730027147466},
#   {'id': 'lMxu8jhSIb_liUki8cy2Wg',
#    'alias': 'chamomile-london',
#    'name': 'Chamomile',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/L1XvSQmXkGbyxSqLdzqEWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chamomile-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5456005, 'longitude': -0.1623197},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "45 England's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 4YD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["45 England's Lane",
#      'London NW3 4YD',
#      'United Kingdom']},
#    'phone': '+442075864580',
#    'display_phone': '+44 20 7586 4580',
#    'distance': 4074.0720076605753},
#   {'id': 'fp5po-wno5RLU4Rz0q0h-w',
#    'alias': 'my-place-soho-london',
#    'name': 'My Place Soho',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gnMfIijyZhFXOyvJPP88ZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-place-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5138405, 'longitude': -0.1346902},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '21 Berwick Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1F 0PZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21 Berwick Street',
#      'London W1F 0PZ',
#      'United Kingdom']},
#    'phone': '+442034172829',
#    'display_phone': '+44 20 3417 2829',
#    'distance': 141.97901027026617},
#   {'id': 'Wv1Zlca4NTkgFVjKgEJyog',
#    'alias': 'poilane-london',
#    'name': 'Poilane',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MxEA4XTmPnw2OAaRPCqi7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/poilane-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.492054852899, 'longitude': -0.1597783672174},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '39 Cadogan Gardens',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 2TB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39 Cadogan Gardens',
#      'London SW3 2TB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2838.7103460697786},
#   {'id': 'OLXnVhh19HtAnbywQzD3zw',
#    'alias': 'rinkoff-bakeries-london-2',
#    'name': 'Rinkoff Bakeries',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U0sRZgXWXgBxJhqCMQAESA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rinkoff-bakeries-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5198880062398,
#     'longitude': -0.0530246183202313},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '224 Jubilee Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 3BS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['224 Jubilee Street',
#      'London E1 3BS',
#      'United Kingdom']},
#    'phone': '+442077914909',
#    'display_phone': '+44 20 7791 4909',
#    'distance': 5791.8034174832765},
#   {'id': '1TBmcRK1gywVVRHYYr7R0Q',
#    'alias': 'el-and-n-london-2',
#    'name': 'EL&N',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eV5QcWA8peOvw15Ns6A5Aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-and-n-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4998051, 'longitude': -0.1620998},
#    'transactions': [],
#    'location': {'address1': '42 Hans Cres',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1X 0LZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 Hans Cres', 'London SW1X 0LZ', 'United Kingdom']},
#    'phone': '+442070520130',
#    'display_phone': '+44 20 7052 0130',
#    'distance': 2322.608342949373},
#   {'id': 'OCnlcGe28goVWSpDkhkBMg',
#    'alias': 'free-state-coffee-london',
#    'name': 'Free State Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6GN6RNmiWi3TQOm9rKZg5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/free-state-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5182752731116,
#     'longitude': -0.120940864750357},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '23 Southampton Row',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 5HJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23 Southampton Row',
#      'London WC1B 5HJ',
#      'United Kingdom']},
#    'phone': '+442079981017',
#    'display_phone': '+44 20 7998 1017',
#    'distance': 1202.2318883638918},
#   {'id': '4xPHAFb8u_wzfjcWYHVKnw',
#    'alias': 'abuelo-london',
#    'name': 'Abuelo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/T2JtRvcsRVB6iEpIr9KQPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/abuelo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5112, 'longitude': -0.12261},
#    'transactions': [],
#    'location': {'address1': '26 Southampton Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2E 7RS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Southampton Street',
#      'London WC2E 7RS',
#      'United Kingdom']},
#    'phone': '+442078368476',
#    'display_phone': '+44 20 7836 8476',
#    'distance': 945.0913708751297},
#   {'id': '5zFiOz2Y1FMCE6nCDFQaYg',
#    'alias': 'tapped-and-packed-london-2',
#    'name': 'Tapped & Packed',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uGsyBXLkXqwgkkUADNxKSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tapped-and-packed-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.523323059082,
#     'longitude': -0.137232005596161},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '114 Tottenham Court Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 5AH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['114 Tottenham Court Road',
#      'London W1T 5AH',
#      'United Kingdom']},
#    'phone': '+442075802163',
#    'display_phone': '+44 20 7580 2163',
#    'distance': 1167.6137484032245},
#   {'id': '6zT5qW1I_jcwSnIHo3OsBA',
#    'alias': 'nineteen-london-3',
#    'name': 'Nineteen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jV2bxZIx17VtnQbRBzqy7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nineteen-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'giftshops', 'title': 'Gift Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5371819, 'longitude': -0.2031378},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '19 Lonsdale Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 6RA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Lonsdale Road',
#      'London NW6 6RA',
#      'United Kingdom']},
#    'phone': '+442076254119',
#    'display_phone': '+44 20 7625 4119',
#    'distance': 5379.799052035305},
#   {'id': '-ylzTrYtRJUJa2BuAInoyQ',
#    'alias': 'friends-of-ours-london',
#    'name': 'Friends of Ours',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/q5Fg1_UQtNmvOoIzrLzhAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/friends-of-ours-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 96,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5291189, 'longitude': -0.0836995},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61 Pitfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 6BU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Pitfield Street',
#      'London N1 6BU',
#      'United Kingdom']},
#    'phone': '+442076865525',
#    'display_phone': '+44 20 7686 5525',
#    'distance': 4041.3053965414406},
#   {'id': 'KBTZHuvXVCwEskNtj0Q1SA',
#    'alias': 'italian-gardens-cafe-london',
#    'name': 'Italian Gardens Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Egmi4aUdIR97Yhl9KT3v8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/italian-gardens-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5115726564169,
#     'longitude': -0.175203145592036},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '61 Bayswater Road',
#     'address2': 'Hyde Park - Marlborough Gate',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 3PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Bayswater Road',
#      'Hyde Park - Marlborough Gate',
#      'London W2 3PH',
#      'United Kingdom']},
#    'phone': '+443000612000',
#    'display_phone': '+44 300 061 2000',
#    'distance': 2719.616092978104},
#   {'id': 'za-KLljMB6yelgi2idCQPg',
#    'alias': 'beany-green-london',
#    'name': 'Beany Green',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UMPucP-qTkGpe2o5ix3woA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beany-green-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.519873314712,
#     'longitude': -0.180045690126235},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 6C',
#     'address2': '4 Sheldon Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 6EZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 6C',
#      '4 Sheldon Square',
#      'London W2 6EZ',
#      'United Kingdom']},
#    'phone': '+442072893344',
#    'display_phone': '+44 20 7289 3344',
#    'distance': 3149.5925485320417},
#   {'id': 'EeTAE4kabQnQw1flRCcjvA',
#    'alias': 'the-arts-cafe-london-4',
#    'name': 'The Arts Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EMgvPJ16kW_inKgx3XvdBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-arts-cafe-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5119065, 'longitude': -0.1276458},
#    'transactions': [],
#    'location': {'address1': 'The Arts Theatre',
#     'address2': '6 - 7 Great Newport Street',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2H 7JB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Arts Theatre',
#      '6 - 7 Great Newport Street',
#      'London WC2H 7JB',
#      'United Kingdom']},
#    'phone': '+442070648100',
#    'display_phone': '+44 20 7064 8100',
#    'distance': 584.270759371596},
#   {'id': 'bv5I4riA1pJvbNFefeHXWw',
#    'alias': 'esters-london-2',
#    'name': 'Esters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Y1mIi5vQ5SYh7sUZalxHsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/esters-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5600418, 'longitude': -0.0783293},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '55 Kynaston Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 0EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55 Kynaston Road',
#      'London N16 0EB',
#      'United Kingdom']},
#    'phone': '+442072540253',
#    'display_phone': '+44 20 7254 0253',
#    'distance': 6590.8338161308875},
#   {'id': 'MF6Xwxep-fx_WfjpR-hmRQ',
#    'alias': 'the-quince-tree-london',
#    'name': 'The Quince Tree',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RvTdclXJQCaKu3xrr_QntQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-quince-tree-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.522522, 'longitude': -0.1849087},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Clifton Nurseries',
#     'address2': '5a Clifton Villas',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W9 2PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Clifton Nurseries',
#      '5a Clifton Villas',
#      'London W9 2PH',
#      'United Kingdom']},
#    'phone': '+442074321867',
#    'display_phone': '+44 20 7432 1867',
#    'distance': 3554.3491487276037},
#   {'id': 'NPAGfkgk_yAIB2oK-vJf9g',
#    'alias': 'briki-london-2',
#    'name': 'Briki',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XGqqAb7ftRXcLil8jA8zIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/briki-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5264182332052,
#     'longitude': -0.108153232644337},
#    'transactions': [],
#    'location': {'address1': '67 Exmouth Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 4QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['67 Exmouth Market',
#      'London EC1R 4QL',
#      'United Kingdom']},
#    'phone': '+442072788745',
#    'display_phone': '+44 20 7278 8745',
#    'distance': 2445.7347758340943},
#   {'id': '4Vz-12sq9q5It5Jr9RW2OQ',
#    'alias': 'tapped-and-packed-london-3',
#    'name': 'Tapped & Packed',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/D7BGh3QEIqNgUg_mQ58ayA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tapped-and-packed-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5156898498535,
#     'longitude': -0.135758996009827},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '193 Wardour Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8ZF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['193 Wardour Street',
#      'Soho',
#      'London W1F 8ZF',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 317.67858867750186},
#   {'id': 'WotOpvaXPZW2Yx-dzoK73w',
#    'alias': 'seoul-bakery-london-3',
#    'name': 'Seoul Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bLb2f4il2hodPvDWaefrhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seoul-bakery-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.517237, 'longitude': -0.129569},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '14 Great Russell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Great Russell Street',
#      'London WC1B 3NH',
#      'United Kingdom']},
#    'phone': '+442072400877',
#    'display_phone': '+44 20 7240 0877',
#    'distance': 659.4351702613345},
#   {'id': 'PFiKoG5xJBFVZkjEwhi-4Q',
#    'alias': 'harris-hoole-london-10',
#    'name': 'Harris + Hoole',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/82zl-Fn6GPS3TN-gN-fB0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harris-hoole-london-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5204306945297,
#     'longitude': -0.140559270897825},
#    'transactions': [],
#    'location': {'address1': '136 New Cavendish Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1W 6YD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['136 New Cavendish Street',
#      'London W1W 6YD',
#      'United Kingdom']},
#    'phone': '+442076368137',
#    'display_phone': '+44 20 7636 8137',
#    'distance': 902.6184550438455},
#   {'id': 'WI6ZlfN6EFuExc21VnmVrQ',
#    'alias': 'a-wanted-man-london',
#    'name': 'A Wanted Man',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/r4MenIFqF40hvRwn67Fv1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/a-wanted-man-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4854399, 'longitude': -0.1742},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "330 King's Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 5UR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["330 King's Road",
#      'London SW3 5UR',
#      'United Kingdom']},
#    'phone': '+442073515166',
#    'display_phone': '+44 20 7351 5166',
#    'distance': 4039.144607784619},
#   {'id': 'wzDJaIeVV89GVycKwMMeyw',
#    'alias': 'kioskafé-london-2',
#    'name': 'Kioskafé',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4jNvSE6Jqv2aCu7YTZcQng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kioskaf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'mags', 'title': 'Newspapers & Magazines'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.516821580645,
#     'longitude': -0.172688003330827},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '31 Norfolk Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1QH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['31 Norfolk Place',
#      'London W2 1QH',
#      'United Kingdom']},
#    'phone': '+442031114242',
#    'display_phone': '+44 20 3111 4242',
#    'distance': 2580.144462242365},
#   {'id': 'ghiSwp2ieTqsNDcjqY_EWw',
#    'alias': 'yumchaa-london-11',
#    'name': 'Yumchaa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6jUTbHacoLhwd2GfQUisFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yumchaa-london-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.536513, 'longitude': -0.124696},
#    'transactions': [],
#    'location': {'address1': '1 Granary Square',
#     'address2': "King's Cross",
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Granary Square',
#      "King's Cross",
#      'London N1C 4AA',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2733.9090361207564},
#   {'id': 'MmVt08teZMbWVrrp4vpAUg',
#    'alias': 'department-of-coffee-and-social-affairs-london-2',
#    'name': 'Department of Coffee and Social Affairs',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ryGnCysaCv-Xptoxx9FxmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/department-of-coffee-and-social-affairs-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5114847733567,
#     'longitude': -0.138275921344757},
#    'transactions': [],
#    'location': {'address1': '30 Warwick Street',
#     'address2': '5th floor',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Warwick Street',
#      '5th floor',
#      'London W1B 5NH',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 219.85711235350539},
#   {'id': 'D9UiyBpAWhVaQtcu9gr55w',
#    'alias': 'curators-coffee-london',
#    'name': 'Curators Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2AoCsIXKHObqcxvbkLDSfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/curators-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.512119, 'longitude': -0.082593},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9a Cullum Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3M 7JJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9a Cullum Street',
#      'London EC3M 7JJ',
#      'United Kingdom']},
#    'phone': '+442072834642',
#    'display_phone': '+44 20 7283 4642',
#    'distance': 3689.873760833793},
#   {'id': '3--7NIylo-0lDc3c4jdROg',
#    'alias': 'second-shot-coffee-london',
#    'name': 'Second Shot Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KTsEG6fYXBJ3ESz_y7PvJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/second-shot-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5275409, 'longitude': -0.0565548},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '475 Bethnal Green Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 9QH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['475 Bethnal Green Road',
#      'London E2 9QH',
#      'United Kingdom']},
#    'phone': '+442077391628',
#    'display_phone': '+44 20 7739 1628',
#    'distance': 5726.727355212552},
#   {'id': 'GGG-14QFlozKOOSDAlDZ3g',
#    'alias': 'saint-espresso-london',
#    'name': 'Saint Espresso',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TRBUoKWFRJHTc6XHBR2-ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saint-espresso-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5320215750491,
#     'longitude': -0.107608515753707},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Angel House',
#     'address2': '26 Pentonville Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9HJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Angel House',
#      '26 Pentonville Road',
#      'London N1 9HJ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2897.9014287817117},
#   {'id': 'RYus9YxVxD-R8jm6xkDX8g',
#    'alias': 'red-door-london',
#    'name': 'Red Door',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Wpge_vSiPdmdj5nk00vX0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/red-door-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'galleries', 'title': 'Art Galleries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.481164, 'longitude': -0.009072},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10 Turnpin Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE10 9JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Turnpin Lane',
#      'London SE10 9JA',
#      'United Kingdom']},
#    'phone': '+442088582131',
#    'display_phone': '+44 20 8858 2131',
#    'distance': 9456.14762342682},
#   {'id': '4DDzcfgbnVAKWomCQoZilg',
#    'alias': 'fortitude-bakehouse-london',
#    'name': 'Fortitude Bakehouse',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1XuacJvRQ1iMGuttnQKQSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fortitude-bakehouse-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5229210884015,
#     'longitude': -0.124047992374525},
#    'transactions': [],
#    'location': {'address1': '35 Colonnade',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC1N 1DD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35 Colonnade', 'London WC1N 1DD', 'United Kingdom']},
#    'phone': '+442078375456',
#    'display_phone': '+44 20 7837 5456',
#    'distance': 1391.6020920227202},
#   {'id': 'U_XeFWW1Lttdq22txTABMw',
#    'alias': 'gails-bakery-neo-bankside-london',
#    'name': "GAIL's Bakery Neo Bankside",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CEfkaYA0zFoAlNcdiNt_aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-neo-bankside-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5066352772979,
#     'longitude': -0.100412668500134},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit C Neo Bankside',
#     'address2': '70 Holland Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9NX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit C Neo Bankside',
#      '70 Holland Road',
#      'London SE1 9NX',
#      'United Kingdom']},
#    'phone': '+442079280621',
#    'display_phone': '+44 20 7928 0621',
#    'distance': 2554.576460738087},
#   {'id': '-HkQk8DoHwNvzuLKmsWwOA',
#    'alias': 'host-cafe-london-2',
#    'name': 'Host Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/so4TLurpNtPvYfZy-Z_c0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/host-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5126908219997,
#     'longitude': -0.0935071706771851},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Saint Mary Aldermary',
#     'address2': 'Watling Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4M 9BW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Saint Mary Aldermary',
#      'Watling Street',
#      'London EC4M 9BW',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2937.5326021021433},
#   {'id': 'e5jPAqpCcIAsTtasUN5h2g',
#    'alias': 'the-wolseley-london',
#    'name': 'The Wolseley',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T9xpXsz-az88-l0Ko_KLpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wolseley-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 553,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.507617, 'longitude': -0.141012},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '160 Picadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 9EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['160 Picadilly', 'London W1J 9EB', 'United Kingdom']},
#    'phone': '+442074996996',
#    'display_phone': '+44 20 7499 6996',
#    'distance': 677.6098617325135},
#   {'id': 'kAgxFPCeNiZeiKc9POkiOg',
#    'alias': 'ottolenghi-london-2',
#    'name': 'Ottolenghi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/h7J52IR5gmXdlef7pJxfSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ottolenghi-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4995017, 'longitude': -0.1566887},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '13 Motcomb Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 8LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Motcomb Street',
#      'London SW1X 8LB',
#      'United Kingdom']},
#    'phone': '+442078232707',
#    'display_phone': '+44 20 7823 2707',
#    'distance': 2068.4293878068443},
#   {'id': 'pda-judhXA46ukcyknEimg',
#    'alias': 'blighty-coffee-london',
#    'name': 'Blighty Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yU3WsVG82ePp0O03oTniXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blighty-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5639223, 'longitude': -0.102986},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '35-37 Blackstock Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N4 2JF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35-37 Blackstock Road',
#      'London N4 2JF',
#      'United Kingdom']},
#    'phone': '+442075027759',
#    'display_phone': '+44 20 7502 7759',
#    'distance': 6121.162135172724},
#   {'id': '_zQGr1XLpDPyUxkMAdiJUw',
#    'alias': 'orrery-epicerie-london',
#    'name': 'Orrery Epicerie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BMwN-OMCWhOqzuKJUdJnCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/orrery-epicerie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.522249, 'longitude': -0.1512119},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '55-57 Marylebone High Street',
#     'address2': 'Marylebone',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 5HS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55-57 Marylebone High Street',
#      'Marylebone',
#      'London W1U 5HS',
#      'United Kingdom']},
#    'phone': '+442076168036',
#    'display_phone': '+44 20 7616 8036',
#    'distance': 1489.7859807332125},
#   {'id': 'YNduANMPzIVE8CzBH7YjEQ',
#    'alias': 'regency-café-london-2',
#    'name': 'Regency Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pz5q5e8LBG7C1ozSuhvuKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/regency-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 393,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4940143171, 'longitude': -0.13222007974201},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '17-19 Regency Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 4BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17-19 Regency Street',
#      'London SW1P 4BY',
#      'United Kingdom']},
#    'phone': '+442078216596',
#    'display_phone': '+44 20 7821 6596',
#    'distance': 2108.732795587357},
#   {'id': 'PymJ3yWM5SaZC8QH89ZEBw',
#    'alias': 'dirty-bones-soho-london',
#    'name': 'Dirty Bones Soho',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/o3YH-aF3ffVn0EgZol8PrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dirty-bones-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.510811, 'longitude': -0.135314},
#    'transactions': [],
#    'location': {'address1': '14 Denman Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1D 7HJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Denman Street',
#      'London W1D 7HJ',
#      'United Kingdom']},
#    'phone': '+442030199064',
#    'display_phone': '+44 20 3019 9064',
#    'distance': 229.45587427086852},
#   {'id': 'Tp5yDvTTI0nBlfbeR9sAxw',
#    'alias': 'espresso-room-london',
#    'name': 'Espresso Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nvKoAYwQ1s3fWViHpQvgOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/espresso-room-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5218919, 'longitude': -0.1197139},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '31-35 Great Ormond Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 3HZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['31-35 Great Ormond Street',
#      'London WC1N 3HZ',
#      'United Kingdom']},
#    'phone': '+447760714883',
#    'display_phone': '+44 7760 714883',
#    'distance': 1507.2054646748222},
#   {'id': 'MY5vPpDxJFPzj-wR4_pUsg',
#    'alias': 'crumpets-london',
#    'name': 'Crumpets',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2GXRSS7bftG4X6Z-0Q4VxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crumpets-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4991936, 'longitude': -0.1382647},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '82 Buckingham Gate',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1E 6PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['82 Buckingham Gate',
#      'London SW1E 6PD',
#      'United Kingdom']},
#    'phone': '+442072331479',
#    'display_phone': '+44 20 7233 1479',
#    'distance': 1525.3047584226708},
#   {'id': '6ArSyJogmDUyXngLVvsilg',
#    'alias': 'mayfair-brew-house-london',
#    'name': 'Mayfair Brew House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PmL0Nxp0Q96CXElQy_eRuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mayfair-brew-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5121043617013,
#     'longitude': -0.144905888878195},
#    'transactions': [],
#    'location': {'address1': '81 Grosvenor Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['81 Grosvenor Street',
#      'London W1K',
#      'United Kingdom']},
#    'phone': '+442074931275',
#    'display_phone': '+44 20 7493 1275',
#    'distance': 624.6716852428667},
#   {'id': 'khnhd6DnBb-zIfZEC1y9zg',
#    'alias': 'the-waiting-room-london-2',
#    'name': 'The Waiting Room',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/29nNTUak9XjUXqkiRvn-Kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-waiting-room-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4792366027832,
#     'longitude': -0.0259060002863407},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '142 Deptford High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE8 3PQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['142 Deptford High Street',
#      'London SE8 3PQ',
#      'United Kingdom']},
#    'phone': '+44442078120105',
#    'display_phone': '+44 442078120105',
#    'distance': 8487.784849357136}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                 Restaurant               Type Price Rating  \
# 0         Shoreditch Grind       Coffee & Tea    ££      4
# 1                    Notes       Coffee & Tea    ££      4
# 2  GAIL's Bakery - Pimlico           Bakeries
# 3              Soho Coffee       Coffee & Tea
# 4    Roasting Plant Coffee  Coffee Roasteries
#
#                       Address        Lat       Lng  \
# 0              213 Old Street  51.525839 -0.087966
# 1         31 St Martin's Lane  51.509554 -0.126723
# 2           26 Churton Street  51.491763 -0.139059
# 3  10 Saint Paul's Churchyard  51.513210 -0.099436
# 4       4 Borough High Street  51.506338 -0.088582
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/shoreditch-grind-lond...  S3h8uhI3wK2Fn4e9gw9bfA
# 1  https://www.yelp.com/biz/notes-london-4?adjust...  X0Bw6wgjhmAZraXvPdLELQ
# 2
# 3
# 4

# %%
#4th set of 50 records 151-200
lndr_params4 = {"term":"coffee","location":"London","limit":50,"offset":151}
lndr_response4 = requests.get(search_api_url, headers=headers, params=lndr_params4)
lndr4 = lndr_response4.json()
display(lndr4)
#print(lndr_response4.url)
#print(lndr_response4.status_code)
# Out:
# {'businesses': [{'id': '7Qv3QwusgyryqFr0oWRWUw',
#    'alias': 'illy-cafe-london',
#    'name': 'Illy Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vLO6uUF9X_HqjFPrFp8kew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/illy-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5008451510021,
#     'longitude': -0.116752333821362},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '200 Westminster Bridge Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7UT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['200 Westminster Bridge Rd',
#      'London SE1 7UT',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1882.560661136731},
#   {'id': 'xAcdtqUqjggUyAMS4zOIfQ',
#    'alias': 'mouse-tail-coffee-stories-london-2',
#    'name': 'Mouse Tail Coffee Stories',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/niqY7F5rzoRoS7Wax24W5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mouse-tail-coffee-stories-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5195122, 'longitude': -0.058621},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '307 Whitechapel Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 1BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['307 Whitechapel Road',
#      'London E1 1BY',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5397.915879553458},
#   {'id': 'Qk9CwHdpFgYo1Za77yfPtQ',
#    'alias': 'l-eto-caffe-london-6',
#    'name': "L'eto Caffe",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1FQ30FQP3kvrI5A8NXId9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-eto-caffe-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.48794, 'longitude': -0.167225},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "149 King's Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 5TX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["149 King's Road",
#      'London SW3 5TX',
#      'United Kingdom']},
#    'phone': '+442073517656',
#    'display_phone': '+44 20 7351 7656',
#    'distance': 3513.9797015942327},
#   {'id': 'w6q63c5K-dHrL9mWfpl3dg',
#    'alias': 'brixton-blend-london',
#    'name': 'Brixton Blend',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wYqhDpm6pRJ_z-FbgPiUdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brixton-blend-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4627675421235,
#     'longitude': -0.115651488304138},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8 Tunstall Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW9 8BN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Tunstall Road',
#      'London SW9 8BN',
#      'United Kingdom']},
#    'phone': '+442077330775',
#    'display_phone': '+44 20 7733 0775',
#    'distance': 5742.058048860259},
#   {'id': 'tHKiDGayBq4RD0oL-DutCg',
#    'alias': 'bloomsbury-coffee-house-london',
#    'name': 'Bloomsbury Coffee House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CAUiQ6-F7FTloOIkmSnTyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bloomsbury-coffee-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.525250540481,
#     'longitude': -0.126389201213277},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '20 Tavistock Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 9RE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Tavistock Place',
#      'London WC1H 9RE',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1530.9764438322995},
#   {'id': '1epk2D1-2-g08GAntFlySg',
#    'alias': 'konditor-london',
#    'name': 'Konditor',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QbRhycT_YxKWL-AX_fwlWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/konditor-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5042899533514,
#     'longitude': -0.110367141112856},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Cornwall Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8TW',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ['22 Cornwall Rd', 'London SE1 8TW', 'United Kingdom']},
#    'phone': '+442076333333',
#    'display_phone': '+44 20 7633 3333',
#    'distance': 2009.750808419612},
#   {'id': '2Ffr8Fs_OlGQqxT7TN_nJg',
#    'alias': 'lundenwic-london-2',
#    'name': 'Lundenwic',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UxlKEsPg6r_m9lpmyS95nQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lundenwic-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5129, 'longitude': -0.118617},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '45 Aldwych',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 4DW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Aldwych', 'London WC2B 4DW', 'United Kingdom']},
#    'phone': '+447921911068',
#    'display_phone': '+44 7921 911068',
#    'distance': 1199.8817944620134},
#   {'id': 'H-9BJnVZspH4bjQ_ba1bmg',
#    'alias': '52a-coffee-house-london',
#    'name': '52A Coffee House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nO0sLxiimK7OaBbkOjW2XQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/52a-coffee-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5395951375695,
#     'longitude': -0.0855829194188118},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '52A Southgate Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 3JF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['52A Southgate Road',
#      'London N1 3JF',
#      'United Kingdom']},
#    'phone': '+442072549909',
#    'display_phone': '+44 20 7254 9909',
#    'distance': 4582.3341063444095},
#   {'id': 'G9fziI6-xivwIobgudOtaQ',
#    'alias': 'momento-london-2',
#    'name': 'Momento',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/x5fAer3cjkyJ6c0PCteY2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/momento-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5164189, 'longitude': -0.1738711},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '159 Praed Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['159 Praed Street',
#      'London W2 1RL',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2653.752571351006},
#   {'id': 'EzgJdGH5k0psD5ZuvCCqiA',
#    'alias': 'department-of-coffee-and-social-affairs-carnaby',
#    'name': 'Department of Coffee and Social Affairs',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vxod0lhDEdivwTs_vrelNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/department-of-coffee-and-social-affairs-carnaby?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5132511252588,
#     'longitude': -0.138569476072683},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3 Lowndes Court',
#     'address2': '',
#     'address3': '',
#     'city': 'Carnaby',
#     'zip_code': 'W1F 7HD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Lowndes Court',
#      'Carnaby W1F 7HD',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 186.67773358478217},
#   {'id': 'Sc-BG-xWJ0gAuwcERfopNQ',
#    'alias': 'allpress-espresso-london-4',
#    'name': 'Allpress Espresso',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ea1CyE4fIyT14NwXH0d3Bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/allpress-espresso-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5464423964129,
#     'longitude': -0.070580542351081},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '55 Dalston Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 1PQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55 Dalston Lane', 'London E8 1PQ', 'United Kingdom']},
#    'phone': '+442077491780',
#    'display_phone': '+44 20 7749 1780',
#    'distance': 5866.533405685033},
#   {'id': 'V4jFUaN3iMGG2rUF3NFTlw',
#    'alias': 'notes-moorgate-london',
#    'name': 'Notes Moorgate',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TqjjEgzpDHC7EvESvSgFyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/notes-moorgate-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.519732, 'longitude': -0.089178},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Ground Floor Citypoint',
#     'address2': '1 Ropemaker Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2Y 9AL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Ground Floor Citypoint',
#      '1 Ropemaker Street',
#      'London EC2Y 9AL',
#      'United Kingdom']},
#    'phone': '+442076285175',
#    'display_phone': '+44 20 7628 5175',
#    'distance': 3326.4207559889337},
#   {'id': 'VNu9h_i48B8idkQLic2tdw',
#    'alias': 'coleman-coffee-roasters-london',
#    'name': 'Coleman Coffee Roasters',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cFZTTc9xEkI0hGVwfqUUrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coleman-coffee-roasters-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5005772, 'longitude': -0.1129936},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Lower Marsh',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 7RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Lower Marsh', 'London SE1 7RJ', 'United Kingdom']},
#    'phone': '+442032671139',
#    'display_phone': '+44 20 3267 1139',
#    'distance': 2089.4714550177555},
#   {'id': '56Ln51izPdpwn9RKJ6XfjA',
#    'alias': 'association-coffee-london',
#    'name': 'Association Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4BktG_4u001Ge85zZ-BV5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/association-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5136852664621,
#     'longitude': -0.0791895389556885},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10-12 Creechurch Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3A 5AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10-12 Creechurch Lane',
#      'London EC3A 5AY',
#      'United Kingdom']},
#    'phone': '+442072831155',
#    'display_phone': '+44 20 7283 1155',
#    'distance': 3929.3763224184904},
#   {'id': 'hWl7B5EhxOAZhVc0lj7BNQ',
#    'alias': 'origin-coffee-roasters-london',
#    'name': 'Origin Coffee Roasters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ddDDPsq9ult3b-K4BjRBjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/origin-coffee-roasters-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5264854431152,
#     'longitude': -0.0811539962887764},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '65 Charlotte Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 3PE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['65 Charlotte Road',
#      'London EC2A 3PE',
#      'United Kingdom']},
#    'phone': '+442077296252',
#    'display_phone': '+44 20 7729 6252',
#    'distance': 4083.048487051365},
#   {'id': '0tJs57Xoq75-RDWKVco0nw',
#    'alias': 'bageriet-london',
#    'name': 'Bageriet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2yfTj7nJkUd_snGs1WP2aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bageriet-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'scandinavian', 'title': 'Scandinavian'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5119236, 'longitude': -0.1261821},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '24 Rose Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 9EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Rose Street',
#      'London WC2E 9EA',
#      'United Kingdom']},
#    'phone': '+442072400000',
#    'display_phone': '+44 20 7240 0000',
#    'distance': 683.9151857905819},
#   {'id': 'vTsxCk6WbL4ui3NmSNfJSw',
#    'alias': 'federation-coffee-london-2',
#    'name': 'Federation Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zSC89NEsgSxJL1DZIE0cvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/federation-coffee-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.462631, 'longitude': -0.111819},
#    'transactions': [],
#    'location': {'address1': '46 Granville Arcade',
#     'address2': 'Brixton',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 8PR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['46 Granville Arcade',
#      'Brixton',
#      'London SW9 8PR',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5842.068140761639},
#   {'id': 'UHukpq9Wwq7r5QIQUmDl6A',
#    'alias': 'out-of-the-brew-london',
#    'name': 'Out of the Brew',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/B0quEYsbQncXC6lZZX4IhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/out-of-the-brew-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.475585208295,
#     'longitude': -0.0375217571854591},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '306 New Cross Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE14 6AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['306 New Cross Road',
#      'London SE14 6AF',
#      'United Kingdom']},
#    'phone': '+442082656740',
#    'display_phone': '+44 20 8265 6740',
#    'distance': 7974.586307601109},
#   {'id': 'iXVq9PcCT-a34FzaXbUagA',
#    'alias': 'scooter-caffè-london-2',
#    'name': 'Scooter Caffè',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/x9HNw_Kud2pJil8Zv5_8oA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scooter-caff%C3%A8-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.500341224864,
#     'longitude': -0.11381534473676},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '132 Lower Marsh',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7AE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['132 Lower Marsh',
#      'London SE1 7AE',
#      'United Kingdom']},
#    'phone': '+442076201421',
#    'display_phone': '+44 20 7620 1421',
#    'distance': 2068.3940056684514},
#   {'id': 'P86MKCSwKlgwFSsNS-sHmQ',
#    'alias': 'barista-cafe-london',
#    'name': 'Barista Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ln8sXxo_rHI9_9LIH3ehXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barista-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.547105, 'longitude': -0.180062},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '219b Finchley Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 6LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['219b Finchley Road',
#      'London NW3 6LP',
#      'United Kingdom']},
#    'phone': '+442073285055',
#    'display_phone': '+44 20 7328 5055',
#    'distance': 4854.678137908755},
#   {'id': '0KXlMLUy4ZKEs3gADeEvsg',
#    'alias': 'crescent-coffee-london',
#    'name': 'Crescent Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2zlkBhvLKD-b58uj42ya9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crescent-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.534163, 'longitude': -0.138892},
#    'transactions': [],
#    'location': {'address1': '1 Hurdwick Place',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 2JE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Hurdwick Place',
#      'London NW1 2JE',
#      'United Kingdom']},
#    'phone': '+447875767573',
#    'display_phone': '+44 7875 767573',
#    'distance': 2380.189210337391},
#   {'id': 'ehdbdRbOyPobXgxt8NybGA',
#    'alias': 'redemption-roasters-kings-cross',
#    'name': 'Redemption Roasters',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aclDa8emYhznIGZ3Sng7yQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/redemption-roasters-kings-cross?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5358826742158,
#     'longitude': -0.126157242991667},
#    'transactions': [],
#    'location': {'address1': 'Unit 109',
#     'address2': 'Lower Stable Street',
#     'address3': None,
#     'city': 'Kings Cross',
#     'zip_code': 'N1C 4AQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 109',
#      'Lower Stable Street',
#      'Kings Cross N1C 4AQ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2650.8674644551675},
#   {'id': 'RYao1HkkY3BbyC62knoI8w',
#    'alias': 'goswell-road-coffee-london-3',
#    'name': 'Goswell Road Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6VlZrX3Z_F5wDU61Mtw3PA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/goswell-road-coffee-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5256799, 'longitude': -0.0995047},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '160 - 164 Goswell Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 7DU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['160 - 164 Goswell Road',
#      'London EC1V 7DU',
#      'United Kingdom']},
#    'phone': '+442074907444',
#    'display_phone': '+44 20 7490 7444',
#    'distance': 2896.078797780542},
#   {'id': 'tJ9btKiYYgAe1SST_foP_Q',
#    'alias': 'caffè-fratelli-london-7',
#    'name': 'Caffè Fratelli',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T7svPpqg5djvu3LjOUBkWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caff%C3%A8-fratelli-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.492956, 'longitude': -0.149779},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '21 Elizabeth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 9RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21 Elizabeth Street',
#      'London SW1W 9RP',
#      'United Kingdom']},
#    'phone': '+442077303950',
#    'display_phone': '+44 20 7730 3950',
#    'distance': 2409.348485866322},
#   {'id': 'aivGgBZ83bZjE95nrB1jvA',
#    'alias': 'peyton-and-byrne-london-11',
#    'name': 'Peyton and Byrne',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/G61GtUBwTiGpiZmjnU5Z9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peyton-and-byrne-london-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5228863, 'longitude': -0.143831277057965},
#    'transactions': [],
#    'location': {'address1': '226 Great Portland Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1W 5QP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['226 Great Portland Street',
#      'London W1W 5QP',
#      'United Kingdom']},
#    'phone': '+442034221453',
#    'display_phone': '+44 20 3422 1453',
#    'distance': 1243.3684205844672},
#   {'id': '335bAiGx1OzbnmgV-6dE4g',
#    'alias': 'le-peche-mignon-london',
#    'name': 'Le Peche Mignon',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/W68FEGHxYOJkqtZnIhgpZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-peche-mignon-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5500471393663,
#     'longitude': -0.107909992126366},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '6 Ronalds Road',
#     'address2': 'Highbury',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N5 1XH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Ronalds Road',
#      'Highbury',
#      'London N5 1XH',
#      'United Kingdom']},
#    'phone': '+442076071826',
#    'display_phone': '+44 20 7607 1826',
#    'distance': 4569.955270762261},
#   {'id': 'x-RBcrzy5cV01RFJYhV6KQ',
#    'alias': 'brunswick-east-london',
#    'name': 'Brunswick East',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eW4FdNxHSmTUX-J38MnGTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brunswick-east-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'organic_stores', 'title': 'Organic Stores'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5491454882416,
#     'longitude': -0.0767732220901962},
#    'transactions': [],
#    'location': {'address1': 'Unit 3D Stamford Works',
#     'address2': 'Gillett Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 8JH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 3D Stamford Works',
#      'Gillett Street',
#      'London N16 8JH',
#      'United Kingdom']},
#    'phone': '+447570119708',
#    'display_phone': '+44 7570 119708',
#    'distance': 5749.860223975882},
#   {'id': '2Xz4uXtE95S5yrGZeBehkQ',
#    'alias': 'highstone-brew-london',
#    'name': 'Highstone Brew',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ixDEQ6EsnYk4PogCiGo7gg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/highstone-brew-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5412739, 'longitude': -0.1388721},
#    'transactions': [],
#    'location': {'address1': '90 Camden Road',
#     'address2': "King's Cross",
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW1 9EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['90 Camden Road',
#      "King's Cross",
#      'London NW1 9EA',
#      'United Kingdom']},
#    'phone': '+442074824076',
#    'display_phone': '+44 20 7482 4076',
#    'distance': 3168.629078929951},
#   {'id': 'in1fuQDAfRBIb7cGnOEviA',
#    'alias': 'gails-bakery-soho-london',
#    'name': "GAIL's Bakery Soho",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/n8-P1vDMEKq2CyDsOzjfRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5143112170147,
#     'longitude': -0.134518146514893},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '128 Wardour Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8ZL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['128 Wardour Street',
#      'Soho',
#      'London W1F 8ZL',
#      'United Kingdom']},
#    'phone': '+442072871324',
#    'display_phone': '+44 20 7287 1324',
#    'distance': 191.89294382102497},
#   {'id': 'IFx29LvkxdZx8pTp-JrvnA',
#    'alias': 'l-eto-caffe-london-3',
#    'name': "L'eto Caffe",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/102DdjCIFtBYllWCYwlo2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-eto-caffe-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4987685, 'longitude': -0.1570349},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10 W Halkin Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 8JL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 W Halkin Street',
#      'London SW1X 8JL',
#      'United Kingdom']},
#    'phone': '+442072356415',
#    'display_phone': '+44 20 7235 6415',
#    'distance': 2138.947633367185},
#   {'id': 'mmVaCz8guvUYaxvWhzHFGA',
#    'alias': 'coffee-corner-london-2',
#    'name': 'Coffee Corner',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QbV6s6ptAxk_Tkkx64qhBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffee-corner-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5462706, 'longitude': -0.1024184},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '314 St Pauls Rd',
#     'address2': 'Highbury Corner',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 2LF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['314 St Pauls Rd',
#      'Highbury Corner',
#      'London N1 2LF',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4382.275115299902},
#   {'id': '6Hc37w-thLXw4_pD3mZdJA',
#    'alias': 'fabrique-bakery-london',
#    'name': 'Fabrique Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6mXU2_cjtNe66mpd_w8AdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fabrique-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5321125496558,
#     'longitude': -0.0760506578224951},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Arch 385',
#     'address2': 'Gaffrye Street',
#     'address3': 'Shoreditch',
#     'city': 'London',
#     'zip_code': 'E2 8HZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Arch 385',
#      'Gaffrye Street',
#      'Shoreditch',
#      'London E2 8HZ',
#      'United Kingdom']},
#    'phone': '+442070330268',
#    'display_phone': '+44 20 7033 0268',
#    'distance': 4666.093756363539},
#   {'id': 'NVcWeFYg78eLEGnoha7AvQ',
#    'alias': 'la-tarte-parisienne-holloway',
#    'name': 'La Tarte Parisienne',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tjmj0SobcrTtJugA9nmvMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-tarte-parisienne-holloway?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5562273938451,
#     'longitude': -0.117813348770142},
#    'transactions': [],
#    'location': {'address1': '345 Holloway Road',
#     'address2': '',
#     'address3': None,
#     'city': 'Holloway',
#     'zip_code': 'N7 0RN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['345 Holloway Road',
#      'Holloway N7 0RN',
#      'United Kingdom']},
#    'phone': '+442076978700',
#    'display_phone': '+44 20 7697 8700',
#    'distance': 4985.465323614743},
#   {'id': 'bAPWN3IeQb4AQL4jiBJYmg',
#    'alias': 'elephant-shack-london',
#    'name': 'Elephant Shack',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Szq5QH45snW_wCJ4B82xUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elephant-shack-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4936105090291,
#     'longitude': -0.0994708347876871},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 18',
#     'address2': 'The Artworks',
#     'address3': 'Elephant Road',
#     'city': 'London',
#     'zip_code': 'SE17 1LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 18',
#      'The Artworks',
#      'Elephant Road',
#      'London SE17 1LB',
#      'United Kingdom']},
#    'phone': '+447772233121',
#    'display_phone': '+44 7772 233121',
#    'distance': 3308.6436193901413},
#   {'id': 'Eqzli9-CdBXqW6oK6zSn6w',
#    'alias': 'lumberjack-london',
#    'name': 'Lumberjack',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_eYZLoVTSLa3xHI1W2GYBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lumberjack-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.47347, 'longitude': -0.08826},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '70 Camberwell Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE5 8QZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['70 Camberwell Church Street',
#      'London SE5 8QZ',
#      'United Kingdom']},
#    'phone': '+442073584475',
#    'display_phone': '+44 20 7358 4475',
#    'distance': 5483.10183388823},
#   {'id': 'Vc_Pw4jlrak_LlCk8DHBJA',
#    'alias': 'karma-bread-london',
#    'name': 'Karma Bread',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/P7X4DYtbYD1rdiZLlk6R8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/karma-bread-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5544616396241,
#     'longitude': -0.165723802891784},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '13 S End Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 2PT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 S End Road', 'London NW3 2PT', 'United Kingdom']},
#    'phone': '+442074316050',
#    'display_phone': '+44 20 7431 6050',
#    'distance': 5065.927131951486},
#   {'id': 'aGqt0g9_WU2UGituR7yn-w',
#    'alias': 'farm-girl-cafe-london',
#    'name': 'Farm Girl Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Qxj7RtZyROODLKeUzWbarw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/farm-girl-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 78,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5120686916922,
#     'longitude': -0.200769876546774},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '59A Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 3DB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['59A Portobello Road',
#      'London W11 3DB',
#      'United Kingdom']},
#    'phone': '+442072294678',
#    'display_phone': '+44 20 7229 4678',
#    'distance': 4486.039469290095},
#   {'id': 'yQy0O4maalqIZX3txcxCXg',
#    'alias': 'grounded-coffee-london-2',
#    'name': 'Grounded Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/InuECK964Pm_rRX4-V7Rfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grounded-coffee-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5164248587188,
#     'longitude': -0.0693253754631087},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9 Whitechapel Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 1DU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Whitechapel Road',
#      'London E1 1DU',
#      'United Kingdom']},
#    'phone': '+442073771703',
#    'display_phone': '+44 20 7377 1703',
#    'distance': 4627.946047616965},
#   {'id': 'cFCAYrs6LX17ucDFEWMXLg',
#    'alias': 'mihbaj-café-and-kitchen-london',
#    'name': 'Mihbaj Café & Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5g5DVb2Q7z4gmXG3AtDbOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mihbaj-caf%C3%A9-and-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.516163, 'longitude': -0.1744713},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '153 Praed Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['153 Praed Street',
#      'London W2 1RL',
#      'United Kingdom']},
#    'phone': '+442077063063',
#    'display_phone': '+44 20 7706 3063',
#    'distance': 2690.7690001080196},
#   {'id': 'UIw466Jqo0p9hvor6RxlIw',
#    'alias': 'bellboi-london',
#    'name': 'Bellboi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/S05G71MwiM9BZYbFpDSaaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bellboi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'luggage', 'title': 'Luggage'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5232, 'longitude': -0.071455},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '104 Sclater Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6HR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['104 Sclater Street',
#      'London E1 6HR',
#      'United Kingdom']},
#    'phone': '+447584484672',
#    'display_phone': '+44 7584 484672',
#    'distance': 4609.405944461003},
#   {'id': '6NIJqOFjLUPXnGaJbxW3lA',
#    'alias': 'l-eto-london-2',
#    'name': "L'ETO",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wPsMI8cgIW_5JjqdEcUhgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-eto-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.496624, 'longitude': -0.1688603},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '243 Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['243 Brompton Road', 'London SW3', 'United Kingdom']},
#    'phone': '+442078542860',
#    'display_phone': '+44 20 7854 2860',
#    'distance': 2898.9080858295915},
#   {'id': 'dlCynaTvL-pRghEH_z0ayA',
#    'alias': 'double-shot-coffee-company-london',
#    'name': 'Double Shot Coffee Company',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_acUN-9-limPjj4HYsLF5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/double-shot-coffee-company-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51216, 'longitude': -0.120119},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '38a Tavistock St',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 7PB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38a Tavistock St',
#      'Covent Garden',
#      'London WC2E 7PB',
#      'United Kingdom']},
#    'phone': '+442072409742',
#    'display_phone': '+44 20 7240 9742',
#    'distance': 1109.0089176207814},
#   {'id': 'MUdU2bubmklL1jt5-luYEw',
#    'alias': 'vagabond-n7-london',
#    'name': 'Vagabond N7',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QHVIp3KL_1ib5sRJyWiCEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vagabond-n7-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5481370008645,
#     'longitude': -0.10683057587731},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '105 Holloway Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N7 8LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['105 Holloway Road',
#      'London N7 8LT',
#      'United Kingdom']},
#    'phone': '+447453630308',
#    'display_phone': '+44 7453 630308',
#    'distance': 4412.18353138647},
#   {'id': 'UMUDGb5nywMsFcPhdIGVaw',
#    'alias': 'natural-coffee-lounge-london',
#    'name': 'Natural Coffee lounge',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZbuKSj_TyPLKEGVoW7KZZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/natural-coffee-lounge-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5461710780613,
#     'longitude': -0.141588347924144},
#    'transactions': [],
#    'location': {'address1': '136-138 Kentish Town Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW1 9QB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['136-138 Kentish Town Road',
#      'London NW1 9QB',
#      'United Kingdom']},
#    'phone': '+442078131179',
#    'display_phone': '+44 20 7813 1179',
#    'distance': 3727.162617519861},
#   {'id': 'hoa8tvJCMbHpIX1BLN6K8w',
#    'alias': 'freds-london-3',
#    'name': "Fred's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ic-iufV99mNor2Xtyi-png/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/freds-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4549681, 'longitude': -0.0373296},
#    'transactions': [],
#    'location': {'address1': '358 Brockley Road',
#     'address2': 'Crofton Park',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE4 2BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['358 Brockley Road',
#      'Crofton Park',
#      'London SE4 2BY',
#      'United Kingdom']},
#    'phone': '+442038023166',
#    'display_phone': '+44 20 3802 3166',
#    'distance': 9384.49446887678},
#   {'id': '26SJ12JyH4cN7yRjs-97Xg',
#    'alias': 'assembly-coffee-london',
#    'name': 'Assembly Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pbgtnOvDKmEbsafM1xvJNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/assembly-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4640043, 'longitude': -0.11498},
#    'transactions': [],
#    'location': {'address1': '244 Ferndale Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 8FR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['244 Ferndale Road',
#      'London SW9 8FR',
#      'United Kingdom']},
#    'phone': '+442031051787',
#    'display_phone': '+44 20 3105 1787',
#    'distance': 5593.9810870822475},
#   {'id': '6gV-0CW_Gl4lhwsql5_f-g',
#    'alias': 'algerian-coffee-stores-london-2',
#    'name': 'Algerian Coffee Stores',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/D1UkI00lFiruzhU97V-1dA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/algerian-coffee-stores-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'gourmet', 'title': 'Specialty Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5128974359911,
#     'longitude': -0.1322330868332},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '52 Old Compton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 4PB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['52 Old Compton Street',
#      'London W1D 4PB',
#      'United Kingdom']},
#    'phone': '+442074372480',
#    'display_phone': '+44 20 7437 2480',
#    'distance': 257.7076182645044},
#   {'id': 'Qf3_iFsezqMRfyZzyVuxig',
#    'alias': 'by-the-bridge-london',
#    'name': 'By the Bridge',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oB_mc9FoU9upg9ZW1rXGRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/by-the-bridge-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5364132310822,
#     'longitude': -0.0769763812422752},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '283A Kingsland Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 8AS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['283A Kingsland Road',
#      'London E2 8AS',
#      'United Kingdom']},
#    'phone': '+447738456991',
#    'display_phone': '+44 7738 456991',
#    'distance': 4850.036233845017},
#   {'id': 'l9Z9_UdByjJRgTTQgnJsSA',
#    'alias': 'department-of-coffee-and-social-affairs-london-4',
#    'name': 'Department of Coffee and Social Affairs',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/n2BlUbkG30tJ_t8oQU_a6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/department-of-coffee-and-social-affairs-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.520082, 'longitude': -0.075224},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '6 Lamb Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Lamb Street', 'London E1 6EA', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4238.654752021698},
#   {'id': 'QyYFRNphu0fICXNfZjD_AA',
#    'alias': 'the-hummingbird-bakery-london-2',
#    'name': 'The Hummingbird Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iNrM97UAuo0a-o3XgX-WqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hummingbird-bakery-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 131,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5140019, 'longitude': -0.2038738},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '133 Portobello Road',
#     'address2': 'Notting Hill',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['133 Portobello Road',
#      'Notting Hill',
#      'London W11 2DY',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4701.254789485355}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#                   Restaurant          Type Price Rating  \
# 0                  Illy Cafe         Cafes     £      5
# 1  Mouse Tail Coffee Stories  Coffee & Tea    ££    4.5
# 2                L'eto Caffe         Cafes   £££    4.5
# 3              Brixton Blend  Coffee & Tea    ££      5
# 4    Bloomsbury Coffee House  Coffee & Tea     £      4
#
#                      Address        Lat       Lng  \
# 0  200 Westminster Bridge Rd  51.500845 -0.116752
# 1       307 Whitechapel Road  51.519512 -0.058621
# 2            149 King's Road  51.487940 -0.167225
# 3            8 Tunstall Road  51.462768 -0.115651
# 4         20 Tavistock Place  51.525251 -0.126389
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/illy-cafe-london?adju...  7Qv3QwusgyryqFr0oWRWUw
# 1  https://www.yelp.com/biz/mouse-tail-coffee-sto...  xAcdtqUqjggUyAMS4zOIfQ
# 2  https://www.yelp.com/biz/l-eto-caffe-london-6?...  Qk9CwHdpFgYo1Za77yfPtQ
# 3  https://www.yelp.com/biz/brixton-blend-london?...  w6q63c5K-dHrL9mWfpl3dg
# 4  https://www.yelp.com/biz/bloomsbury-coffee-hou...  tHKiDGayBq4RD0oL-DutCg

# %%
london_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
london_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_restaurants_df = london_restaurants_df[column_order]
london_restaurants_df = london_restaurants_df.sort_values(["Type"], ascending=True)
london_restaurants_df = london_restaurants_df.reset_index(drop=True)
london_restaurants_df
# Out:
#                                   Restaurant                    Type Rating  \
# 0                                   Red Door           Art Galleries    4.5
# 1                     The Hummingbird Bakery                Bakeries      4
# 2                                   Konditor                Bakeries    4.5
# 3                                 Ottolenghi                Bakeries      4
# 4                               E5 Bakehouse                Bakeries    4.5
# 5                            Fabrique Bakery                Bakeries    4.5
# 6                                   Laurents                Bakeries    4.5
# 7                         GAIL's Bakery Soho                Bakeries      4
# 8                     Dominique Ansel Bakery                Bakeries      4
# 9                                    Poilane                Bakeries    4.5
# 10                   GAIL's Bakery - Pimlico                Bakeries
# 11                          Rinkoff Bakeries                Bakeries    4.5
# 12                           Grounded Coffee      Breakfast & Brunch    4.5
# 13                GAIL's Bakery Neo Bankside      Breakfast & Brunch    4.5
# 14                              The Orangery                 British      4
# 15                            Tea and Tattle                 British    4.5
# 16                       Fortitude Bakehouse                   Cafes
# 17                              The Wolseley                   Cafes      4
# 18                        Mayfair Brew House                   Cafes
# 19                             My Place Soho                   Cafes    4.5
# 20                          Frequency Coffee                   Cafes      5
# 21                               L'eto Caffe                   Cafes    4.5
# 22                      Kennington Lane Cafe                   Cafes      5
# 23                                     Wired                   Cafes    4.5
# 24                              Regency Café                   Cafes    4.5
# 25                                   Yumchaa                   Cafes
# 26                                      EL&N                   Cafes
# 27                              Seoul Bakery                   Cafes    4.5
# 28                                  Lift 574                   Cafes    4.5
# 29                                 D1 Coffee                   Cafes      5
# ..                                       ...                     ...    ...
# 170                   The Gentlemen Baristas            Coffee & Tea    4.5
# 171                           Pattern Coffee            Coffee & Tea      4
# 172                              Soho Coffee            Coffee & Tea
# 173                   Hackney Coffee Company            Coffee & Tea      4
# 174                                    Notes            Coffee & Tea      4
# 175                       Black Sheep Coffee            Coffee & Tea
# 176                                Oak Caffe            Coffee & Tea      5
# 177                         Shoreditch Grind            Coffee & Tea      4
# 178           Vanilla Black Coffee and Books            Coffee & Tea    4.5
# 179  Department of Coffee and Social Affairs            Coffee & Tea    4.5
# 180                                    Hagen            Coffee & Tea
# 181                Mouse Tail Coffee Stories            Coffee & Tea    4.5
# 182                          Workshop Coffee            Coffee & Tea    4.5
# 183                       Black Sheep Coffee            Coffee & Tea
# 184                          Assembly Coffee       Coffee Roasteries
# 185                  Chapter Coffee Roasters       Coffee Roasteries
# 186                            Coffee Island       Coffee Roasteries      4
# 187                      Redemption Roasters       Coffee Roasteries
# 188                  Coleman Coffee Roasters       Coffee Roasteries    4.5
# 189                       Camden Coffee Shop       Coffee Roasteries      5
# 190                    Roasting Plant Coffee       Coffee Roasteries
# 191                            Outsider Tart                Desserts    4.5
# 192                              Hart & Lova                Desserts    4.5
# 193                      Covent Garden Grind  Juice Bars & Smoothies    4.5
# 194                             The Roasting  Juice Bars & Smoothies    4.5
# 195                            Ole and Steen    Patisserie/Cake Shop    4.5
# 196                      Camden Coffee House             Restaurants      4
# 197                                 Bageriet            Scandinavian    4.5
# 198                                Black Cat                   Vegan    4.5
# 199                            The Book Club   Venues & Event Spaces      4
#
#     Price                     Address        Lat       Lng  \
# 0      ££             10 Turnpin Lane  51.481164 -0.009072
# 1      ££         133 Portobello Road  51.514002 -0.203874
# 2      ££              22 Cornwall Rd  51.504290 -0.110367
# 3      ££           13 Motcomb Street  51.499502 -0.156689
# 4      ££        395 Mentmore Terrace  51.541204 -0.057616
# 5      ££                    Arch 385  51.532113 -0.076051
# 6       £              39 Craven Road  51.513468 -0.179164
# 7      ££          128 Wardour Street  51.514311 -0.134518
# 8      ££      17-21 Elizabeth Street  51.492691 -0.149131
# 9     £££          39 Cadogan Gardens  51.492055 -0.159778
# 10                  26 Churton Street  51.491763 -0.139059
# 11      £          224 Jubilee Street  51.519888 -0.053025
# 12     ££          9 Whitechapel Road  51.516425 -0.069325
# 13     ££         Unit C Neo Bankside  51.506635 -0.100413
# 14    £££           Kensington Palace  51.506636 -0.187725
# 15     ££     41 Great Russell Street  51.517868 -0.126817
# 16                       35 Colonnade  51.522921 -0.124048
# 17    £££               160 Picadilly  51.507617 -0.141012
# 18                81 Grosvenor Street  51.512104 -0.144906
# 19     ££           21 Berwick Street  51.513841 -0.134690
# 20      £       121 King's Cross Road  51.529094 -0.115870
# 21    £££             149 King's Road  51.487940 -0.167225
# 22      £         383 Kennington Lane  51.486061 -0.120851
# 23      £      194 Broadhurst Gardens  51.546477 -0.190354
# 24      £        17-19 Regency Street  51.494014 -0.132220
# 25                   1 Granary Square  51.536513 -0.124696
# 26                       42 Hans Cres  51.499805 -0.162100
# 27      £     14 Great Russell Street  51.517237 -0.129569
# 28     ££          574 Kingsland Road  51.545321 -0.075801
# 29     ££            1 Aberdeen Place  51.524868 -0.176336
# ..    ...                         ...        ...       ...
# 170     £             63 Union Street  51.503842 -0.094704
# 171    ££            82 Caledonian Rd  51.532962 -0.119133
# 172        10 Saint Paul's Churchyard  51.513210 -0.099436
# 173    ££            503 Hackney Road  51.532546 -0.058421
# 174    ££         31 St Martin's Lane  51.509554 -0.126723
# 175               189 Victoria Street  51.496363 -0.143891
# 176     £       1 Oakleigh Road North  51.629900 -0.174439
# 177    ££              213 Old Street  51.525839 -0.087966
# 178     £     306-308 Kennington Road  51.487474 -0.111417
# 179     £               6 Lamb Street  51.520082 -0.075224
# 180                   151 King's Road  51.487884 -0.167200
# 181     £            Deal Porters Way  51.497802 -0.047890
# 182   £££         60a Holborn Viaduct  51.517079 -0.104137
# 183               81 Southwark Street  51.505496 -0.099401
# 184                 244 Ferndale Road  51.464004 -0.114980
# 185                137 North End Road  51.491985 -0.207135
# 186    ££    5 Upper St Martin's Lane  51.512240 -0.127379
# 187                          Unit 109  51.535883 -0.126157
# 188    ££              20 Lower Marsh  51.500577 -0.112994
# 189     £          11 Delancey Street  51.536842 -0.142079
# 190             4 Borough High Street  51.506338 -0.088582
# 191     £       83 Chiswick High Road  51.492700 -0.252125
# 192    ££            213 Belsize Road  51.538438 -0.190891
# 193     £              42 Maiden Lane  51.511048 -0.122460
# 194    ££           31 Churton Street  51.491261 -0.138832
# 195    ££                56 Haymarket  51.509238 -0.132696
# 196     £              30 Camden Road  51.539981 -0.140795
# 197     £              24 Rose Street  51.511924 -0.126182
# 198     £            76 Clarence Road  51.551397 -0.055691
# 199    ££          100 Leonard Street  51.524537 -0.081494
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/red-door-london?adjus...  RYus9YxVxD-R8jm6xkDX8g
# 1    https://www.yelp.com/biz/the-hummingbird-baker...  QyYFRNphu0fICXNfZjD_AA
# 2    https://www.yelp.com/biz/konditor-london?adjus...  1epk2D1-2-g08GAntFlySg
# 3    https://www.yelp.com/biz/ottolenghi-london-2?a...  kAgxFPCeNiZeiKc9POkiOg
# 4    https://www.yelp.com/biz/e5-bakehouse-london?a...  -6GHU4qI0DKsIrBpv57qTg
# 5    https://www.yelp.com/biz/fabrique-bakery-londo...  6Hc37w-thLXw4_pD3mZdJA
# 6    https://www.yelp.com/biz/laurents-london?adjus...  HAi7bThXmEtooc5ZQq9hdw
# 7    https://www.yelp.com/biz/gails-bakery-soho-lon...  in1fuQDAfRBIb7cGnOEviA
# 8    https://www.yelp.com/biz/dominique-ansel-baker...  9gqKbR6JK79zTc5RDLP_4A
# 9    https://www.yelp.com/biz/poilane-london?adjust...  Wv1Zlca4NTkgFVjKgEJyog
# 10
# 11   https://www.yelp.com/biz/rinkoff-bakeries-lond...  OLXnVhh19HtAnbywQzD3zw
# 12   https://www.yelp.com/biz/grounded-coffee-londo...  yQy0O4maalqIZX3txcxCXg
# 13   https://www.yelp.com/biz/gails-bakery-neo-bank...  U_XeFWW1Lttdq22txTABMw
# 14   https://www.yelp.com/biz/the-orangery-london-7...  PBFvhVyBi0lEJyTbyuxf5w
# 15   https://www.yelp.com/biz/tea-and-tattle-london...  1TgYqfxkXv6-IB4cvuuy3w
# 16
# 17   https://www.yelp.com/biz/the-wolseley-london?a...  e5jPAqpCcIAsTtasUN5h2g
# 18
# 19   https://www.yelp.com/biz/my-place-soho-london?...  fp5po-wno5RLU4Rz0q0h-w
# 20   https://www.yelp.com/biz/frequency-coffee-lond...  rH-b73mF8SB3cSCvNyL-sg
# 21   https://www.yelp.com/biz/l-eto-caffe-london-6?...  Qk9CwHdpFgYo1Za77yfPtQ
# 22   https://www.yelp.com/biz/kennington-lane-cafe-...  p77CnjTGOIZA1hEpLfCC6Q
# 23   https://www.yelp.com/biz/wired-london-2?adjust...  XraXeaxvh09W1szdtUAhtA
# 24   https://www.yelp.com/biz/regency-caf%C3%A9-lon...  YNduANMPzIVE8CzBH7YjEQ
# 25
# 26
# 27   https://www.yelp.com/biz/seoul-bakery-london-3...  WotOpvaXPZW2Yx-dzoK73w
# 28   https://www.yelp.com/biz/lift-574-london?adjus...  wsvg4dplxVl9G2Yl6eG6SA
# 29   https://www.yelp.com/biz/d1-coffee-little-veni...  DXMoezQ1WxA-lzvSNPg6Og
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/the-gentlemen-barista...  XN7K4g1Wq-93WYvg85EgMg
# 171  https://www.yelp.com/biz/pattern-coffee-london...  aYd2mlWPlQmJdKHbiWq0PA
# 172
# 173  https://www.yelp.com/biz/hackney-coffee-compan...  uA_H2UI3nPL7-L11G61-wA
# 174  https://www.yelp.com/biz/notes-london-4?adjust...  X0Bw6wgjhmAZraXvPdLELQ
# 175
# 176  https://www.yelp.com/biz/oak-caffe-london?adju...  guy3VKpOBfK0E4OTmLJNlg
# 177  https://www.yelp.com/biz/shoreditch-grind-lond...  S3h8uhI3wK2Fn4e9gw9bfA
# 178  https://www.yelp.com/biz/vanilla-black-coffee-...  o1gFln8kSV4Y36Zo420dyQ
# 179  https://www.yelp.com/biz/department-of-coffee-...  l9Z9_UdByjJRgTTQgnJsSA
# 180
# 181  https://www.yelp.com/biz/mouse-tail-coffee-sto...  alG0_K6eXYLGTfnDhrEmzA
# 182  https://www.yelp.com/biz/workshop-coffee-londo...  X3Bf648lnr4QNO8JQr3PAw
# 183
# 184
# 185
# 186  https://www.yelp.com/biz/coffee-island-london?...  lCRkNZaofaiUn-CEOQNr3g
# 187
# 188  https://www.yelp.com/biz/coleman-coffee-roaste...  VNu9h_i48B8idkQLic2tdw
# 189  https://www.yelp.com/biz/camden-coffee-shop-lo...  1kTiW_C-WQbebTCqkV6xYg
# 190
# 191  https://www.yelp.com/biz/outsider-tart-london?...  YfKn2fkIyXC2jmE1qmgxQw
# 192  https://www.yelp.com/biz/hart-and-lova-london?...  S_1iMSbWOa4I7pa8BxWZag
# 193  https://www.yelp.com/biz/covent-garden-grind-l...  sTjZJB20joSHE8oVPHs1Cw
# 194  https://www.yelp.com/biz/the-roasting-london?a...  371SNZXi292Y2tPYV-EEmQ
# 195  https://www.yelp.com/biz/ole-and-steen-london-...  5or4AzNouZq8RClNeTdqiA
# 196  https://www.yelp.com/biz/camden-coffee-house-l...  exjNWU4T_uzKOtH3uHIutQ
# 197  https://www.yelp.com/biz/bageriet-london?adjus...  0tJs57Xoq75-RDWKVco0nw
# 198  https://www.yelp.com/biz/black-cat-london?adju...  f8s8dT9Rm4359xUVHtiqRA
# 199  https://www.yelp.com/biz/the-book-club-london?...  UMJxTGTSShg2u1FFwZBWAQ
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
london_restaurants_df.to_csv('Resources/London_Restaurants_Coffee.csv')
