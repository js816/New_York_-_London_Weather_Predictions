# %% [markdown]
# LONDON RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
lndr_params1 = {"term":"bakery","location":"London","limit":50,"offset":0}
lndr_response1 = requests.get(search_api_url, headers=headers, params=lndr_params1)
lndr1 = lndr_response1.json()
display(lndr1)
#print(lndr_response1.url)
#print(lndr_response1.status_code)
# Out:
# {'businesses': [{'id': '0tJs57Xoq75-RDWKVco0nw',
#    'alias': 'bageriet-london',
#    'name': 'Bageriet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2yfTj7nJkUd_snGs1WP2aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bageriet-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'scandinavian', 'title': 'Scandinavian'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5119236, 'longitude': -0.1261821},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '24 Rose Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 9EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Rose Street',
#      'London WC2E 9EA',
#      'United Kingdom']},
#    'phone': '+442072400000',
#    'display_phone': '+44 20 7240 0000',
#    'distance': 683.9151857905819},
#   {'id': 'KZd0pTzAhKbIs9Lg94Delg',
#    'alias': 'bread-ahead-london-3',
#    'name': 'Bread Ahead',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0zFLqdD1WpHNDsv_5YeVGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bread-ahead-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 79,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5061427, 'longitude': -0.090258},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Borough Market',
#     'address2': 'Cathedral Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9DE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Borough Market',
#      'Cathedral Street',
#      'London SE1 9DE',
#      'United Kingdom']},
#    'phone': '+442074035444',
#    'display_phone': '+44 20 7403 5444',
#    'distance': 3248.944489817099},
#   {'id': 'LgKc7xGArsmxAw6xUQ2mYA',
#    'alias': 'gails-bakery-seymour-place-london-4',
#    'name': "GAIL's Bakery Seymour Place",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FWiORe3Zw8vEUmD0tANYvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-seymour-place-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.514595, 'longitude': -0.160964},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4-6 Seymour Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4-6 Seymour Place',
#      'London W1H 7NA',
#      'United Kingdom']},
#    'phone': '+442077243590',
#    'display_phone': '+44 20 7724 3590',
#    'distance': 1741.5797182376227},
#   {'id': '3ZWC6EkdLcUe80Vq097Bfg',
#    'alias': 'patisserie-sainte-anne-london',
#    'name': 'Patisserie Sainte Anne',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nxFsUg1NYt-UJHi6uTxd_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-sainte-anne-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4930805319587,
#     'longitude': -0.236022540998695},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '204 King Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W6 0RA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['204 King Street', 'London W6 0RA', 'United Kingdom']},
#    'phone': '+442085632046',
#    'display_phone': '+44 20 8563 2046',
#    'distance': 7266.198358582235},
#   {'id': 'wh4R2zTxcjZw4JcQFNBtog',
#    'alias': 'aux-pains-de-papy-london',
#    'name': 'Aux Pains de Papy',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Kqbb4D3ddlwupyZ2hxiYVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aux-pains-de-papy-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5273865, 'longitude': -0.1184675},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '279 Grays Inn Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1X 8EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['279 Grays Inn Rd',
#      'London WC1X 8EB',
#      'United Kingdom']},
#    'phone': '+447771613779',
#    'display_phone': '+44 7771 613779',
#    'distance': 2020.4045688598862},
#   {'id': 'QyYFRNphu0fICXNfZjD_AA',
#    'alias': 'the-hummingbird-bakery-london-2',
#    'name': 'The Hummingbird Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iNrM97UAuo0a-o3XgX-WqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hummingbird-bakery-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 131,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5140019, 'longitude': -0.2038738},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '133 Portobello Road',
#     'address2': 'Notting Hill',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['133 Portobello Road',
#      'Notting Hill',
#      'London W11 2DY',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4701.254789485355},
#   {'id': 'x3xVIhjTy6jZ8PhKVqYjIw',
#    'alias': 'the-hummingbird-bakery-london-4',
#    'name': 'The Hummingbird Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4cvpY3Z_fsXDeftdmySptQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hummingbird-bakery-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 106,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5144372642472,
#     'longitude': -0.134845145998042},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '155a Wardour Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8WG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['155a Wardour Street',
#      'Soho',
#      'London W1F 8WG',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 193.9810977468779},
#   {'id': 'mDyJw5PstVTN2RQi5HO-sw',
#    'alias': 'st-john-bakery-london-3',
#    'name': 'St. John Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/37zJgBXE1CGwCulKzfCGCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-john-bakery-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5143596884016,
#     'longitude': -0.126515915278274},
#    'transactions': [],
#    'location': {'address1': "3 Neal's Yard",
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2H 9DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["3 Neal's Yard", 'London WC2H 9DP', 'United Kingdom']},
#    'phone': '+442072510848',
#    'display_phone': '+44 20 7251 0848',
#    'distance': 674.8655754823199},
#   {'id': '9gqKbR6JK79zTc5RDLP_4A',
#    'alias': 'dominique-ansel-bakery-victoria',
#    'name': 'Dominique Ansel Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_NbEwfiF5IbRjDso83WZpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dominique-ansel-bakery-victoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4926912521198,
#     'longitude': -0.149131484387577},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '17-21 Elizabeth Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Victoria',
#     'zip_code': 'SW1W 9RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17-21 Elizabeth Street',
#      'Victoria SW1W 9RP',
#      'United Kingdom']},
#    'phone': '+442073247705',
#    'display_phone': '+44 20 7324 7705',
#    'distance': 2418.4730027147466},
#   {'id': 'FATOg3vQpgbrl_20WySbqQ',
#    'alias': 'sunflour-bakery-london',
#    'name': 'Sunflour Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/E_YSpYIlnlq9XSV4uQFxZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sunflour-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.539747, 'longitude': -0.11718},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '263 Caledonian Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 1EE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['263 Caledonian Road',
#      'London N1 1EE',
#      'United Kingdom']},
#    'phone': '+442076970003',
#    'display_phone': '+44 20 7697 0003',
#    'distance': 3259.713725625197},
#   {'id': 'EbT5viLW9ujk9iQ73CJcmQ',
#    'alias': 'the-pasty-shop-london',
#    'name': 'The Pasty Shop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RAszscwdnd_rGyu7XSkCBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pasty-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4962890220788,
#     'longitude': -0.143927823389436},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Victoria Street Station',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1JU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Victoria Street Station',
#      'London SW1V 1JU',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1920.8400662572742},
#   {'id': 'kAgxFPCeNiZeiKc9POkiOg',
#    'alias': 'ottolenghi-london-2',
#    'name': 'Ottolenghi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/h7J52IR5gmXdlef7pJxfSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ottolenghi-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4995017, 'longitude': -0.1566887},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '13 Motcomb Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 8LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Motcomb Street',
#      'London SW1X 8LB',
#      'United Kingdom']},
#    'phone': '+442078232707',
#    'display_phone': '+44 20 7823 2707',
#    'distance': 2068.4293878068443},
#   {'id': '5or4AzNouZq8RClNeTdqiA',
#    'alias': 'ole-and-steen-london-2',
#    'name': 'Ole and Steen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HhmDFvGw42MnOJErQE9vkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ole-and-steen-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.509238, 'longitude': -0.1326965},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '56 Haymarket',
#     'address2': '',
#     'address3': "No 2 St James's Market",
#     'city': 'London',
#     'zip_code': 'SW1Y 4RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['56 Haymarket',
#      "No 2 St James's Market",
#      'London SW1Y 4RP',
#      'United Kingdom']},
#    'phone': '+442038288242',
#    'display_phone': '+44 20 3828 8242',
#    'distance': 459.23424350084883},
#   {'id': 'rQKDeNCx8LkUR12YH9LpVg',
#    'alias': 'bäkehaus-london-2',
#    'name': 'Bäkehaus',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t8nwOKGUsvFhyuNdJFTrvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b%C3%A4kehaus-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4926600176647,
#     'longitude': -0.227837562561035},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '71 King Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W6 9HW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['71 King Street', 'London W6 9HW', 'United Kingdom']},
#    'phone': '+442034903231',
#    'display_phone': '+44 20 3490 3231',
#    'distance': 6743.794563736779},
#   {'id': 'C3Dp2ONw3fntVgUTwCjHLg',
#    'alias': 'st-john-bakery-london-2',
#    'name': 'St John Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/b7CV9uGCdrYYoQAH2x0PsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-john-bakery-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.499488, 'longitude': -0.075961},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '72 Druid St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['72 Druid St', 'London SE1', 'United Kingdom']},
#    'phone': '+442072375999',
#    'display_phone': '+44 20 7237 5999',
#    'distance': 4409.5796775486},
#   {'id': 'n2bhQ85Vk9pT77jb4th38A',
#    'alias': 'crumbs-and-doilies-london',
#    'name': 'Crumbs and Doilies',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vZzB_zJMf0NKTG4TaSZwTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crumbs-and-doilies-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512258, 'longitude': -0.138374},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '1 Kingly Court',
#     'address2': 'Carnaby Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5PW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Kingly Court',
#      'Carnaby Street',
#      'London W1B 5PW',
#      'United Kingdom']},
#    'phone': '+442088748885',
#    'display_phone': '+44 20 8874 8885',
#    'distance': 179.24059999393177},
#   {'id': '-ATEXu2q4Oe4wPQeyrsILw',
#    'alias': 'princi-london',
#    'name': 'Princi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QLFgoDIBiLx2F0tpUIw7gQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/princi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 304,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5138629586873,
#     'longitude': -0.134387051472991},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '135 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0UT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['135 Wardour Street',
#      'London W1F 0UT',
#      'United Kingdom']},
#    'phone': '+442074788888',
#    'display_phone': '+44 20 7478 8888',
#    'distance': 157.59755401297926},
#   {'id': 'OLXnVhh19HtAnbywQzD3zw',
#    'alias': 'rinkoff-bakeries-london-2',
#    'name': 'Rinkoff Bakeries',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U0sRZgXWXgBxJhqCMQAESA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rinkoff-bakeries-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5198880062398,
#     'longitude': -0.0530246183202313},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '224 Jubilee Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 3BS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['224 Jubilee Street',
#      'London E1 3BS',
#      'United Kingdom']},
#    'phone': '+442077914909',
#    'display_phone': '+44 20 7791 4909',
#    'distance': 5791.8034174832765},
#   {'id': 'uCmXqPY3cOIHxda-HDxB0Q',
#    'alias': 'chinatown-bakery-london',
#    'name': 'Chinatown Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/M53Wp0eRJs57iDxXfqoLyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chinatown-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512026, 'longitude': -0.129721},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '7 Newport Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 7JR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Newport Place',
#      'London WC2H 7JR',
#      'United Kingdom']},
#    'phone': '+442072877995',
#    'display_phone': '+44 20 7287 7995',
#    'distance': 440.74810491522373},
#   {'id': 'WotOpvaXPZW2Yx-dzoK73w',
#    'alias': 'seoul-bakery-london-3',
#    'name': 'Seoul Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bLb2f4il2hodPvDWaefrhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seoul-bakery-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.517237, 'longitude': -0.129569},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '14 Great Russell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Great Russell Street',
#      'London WC1B 3NH',
#      'United Kingdom']},
#    'phone': '+442072400877',
#    'display_phone': '+44 20 7240 0877',
#    'distance': 659.4351702613345},
#   {'id': 'dIWOqYszVKk-oswXDzUH6A',
#    'alias': 'primrose-bakery-london',
#    'name': 'Primrose Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ng53dTpGBxCLSpY5sotd_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/primrose-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5402263, 'longitude': -0.1511222},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '69 Gloucester Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8LD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['69 Gloucester Avenue',
#      'London NW1 8LD',
#      'United Kingdom']},
#    'phone': '+442074834222',
#    'display_phone': '+44 20 7483 4222',
#    'distance': 3221.367607689674},
#   {'id': 'pa2j9BlCHH8mRIk-TtD6UQ',
#    'alias': 'camden-bakery-london',
#    'name': 'Camden Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/V1BIQXnDxmTz0NyfTs6BiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camden-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5370833, 'longitude': -0.1407642},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '94 Camden High Street',
#     'address2': 'Camden Town',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 0LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['94 Camden High Street',
#      'Camden Town',
#      'London NW1 0LT',
#      'United Kingdom']},
#    'phone': '+442073874947',
#    'display_phone': '+44 20 7387 4947',
#    'distance': 2712.007403533704},
#   {'id': 'in1fuQDAfRBIb7cGnOEviA',
#    'alias': 'gails-bakery-soho-london',
#    'name': "GAIL's Bakery Soho",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/n8-P1vDMEKq2CyDsOzjfRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5143112170147,
#     'longitude': -0.134518146514893},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '128 Wardour Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8ZL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['128 Wardour Street',
#      'Soho',
#      'London W1F 8ZL',
#      'United Kingdom']},
#    'phone': '+442072871324',
#    'display_phone': '+44 20 7287 1324',
#    'distance': 191.89294382102497},
#   {'id': '1epk2D1-2-g08GAntFlySg',
#    'alias': 'konditor-london',
#    'name': 'Konditor',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QbRhycT_YxKWL-AX_fwlWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/konditor-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5042899533514,
#     'longitude': -0.110367141112856},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Cornwall Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8TW',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ['22 Cornwall Rd', 'London SE1 8TW', 'United Kingdom']},
#    'phone': '+442076333333',
#    'display_phone': '+44 20 7633 3333',
#    'distance': 2009.750808419612},
#   {'id': '4DDzcfgbnVAKWomCQoZilg',
#    'alias': 'fortitude-bakehouse-london',
#    'name': 'Fortitude Bakehouse',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1XuacJvRQ1iMGuttnQKQSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fortitude-bakehouse-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5229210884015,
#     'longitude': -0.124047992374525},
#    'transactions': [],
#    'location': {'address1': '35 Colonnade',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC1N 1DD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35 Colonnade', 'London WC1N 1DD', 'United Kingdom']},
#    'phone': '+442078375456',
#    'display_phone': '+44 20 7837 5456',
#    'distance': 1391.6020920227202},
#   {'id': 'mso0KFMpL7C3OaCHnQiReg',
#    'alias': 'bachmanns-patisserie-thames-ditton',
#    'name': "Bachmann's Patisserie",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rqxm5mfg112oNQTdlI4ydg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bachmanns-patisserie-thames-ditton?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.389394, 'longitude': -0.325959},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 Criterion Buildings',
#     'address2': 'Portsmouth Rd',
#     'address3': '',
#     'city': 'Thames Ditton',
#     'zip_code': 'KT7 0SS',
#     'country': 'GB',
#     'state': 'SRY',
#     'display_address': ['6 Criterion Buildings',
#      'Portsmouth Rd',
#      'Thames Ditton KT7 0SS',
#      'United Kingdom']},
#    'phone': '+442083981988',
#    'display_phone': '+44 20 8398 1988',
#    'distance': 19026.255787147777},
#   {'id': 'FDTx9-86N50Xa2Ojv65YcQ',
#    'alias': 'fabrique-bakery-fitzrovia',
#    'name': 'Fabrique Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qnnW-uG8iKNCwRHaw-JIIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fabrique-bakery-fitzrovia?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5191208284928,
#     'longitude': -0.136215056815711},
#    'transactions': [],
#    'location': {'address1': '53 Goodge Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Fitzrovia',
#     'zip_code': 'W1T 1TG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['53 Goodge Street',
#      'Fitzrovia W1T 1TG',
#      'United Kingdom']},
#    'phone': '+442075804227',
#    'display_phone': '+44 20 7580 4227',
#    'distance': 699.1236945245441},
#   {'id': '8LRg_LUNa8yLCpVOo5sw7g',
#    'alias': 'maison-souss-london',
#    'name': 'Maison Souss',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_72TGaUzEmm43MHbcKAMLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maison-souss-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5046831344375,
#     'longitude': -0.221322855151522},
#    'transactions': [],
#    'location': {'address1': '104 Uxbridge Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W12 8LR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['104 Uxbridge Road',
#      'London W12 8LR',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5977.144918921935},
#   {'id': '6Hc37w-thLXw4_pD3mZdJA',
#    'alias': 'fabrique-bakery-london',
#    'name': 'Fabrique Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6mXU2_cjtNe66mpd_w8AdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fabrique-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5321125496558,
#     'longitude': -0.0760506578224951},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Arch 385',
#     'address2': 'Gaffrye Street',
#     'address3': 'Shoreditch',
#     'city': 'London',
#     'zip_code': 'E2 8HZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Arch 385',
#      'Gaffrye Street',
#      'Shoreditch',
#      'London E2 8HZ',
#      'United Kingdom']},
#    'phone': '+442070330268',
#    'display_phone': '+44 20 7033 0268',
#    'distance': 4666.093756363539},
#   {'id': 'UWp5pMuqwuNxECSq5XMVew',
#    'alias': 'dunns-bakery-london',
#    'name': "Dunn's Bakery",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WacjG6oYfAILqs6z8-JIsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dunns-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5784633, 'longitude': -0.1237851},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 The Broadway',
#     'address2': 'Crouch End',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N8 9SN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 The Broadway',
#      'Crouch End',
#      'London N8 9SN',
#      'United Kingdom']},
#    'phone': '+442083401614',
#    'display_phone': '+44 20 8340 1614',
#    'distance': 7345.839486334228},
#   {'id': 'YfKn2fkIyXC2jmE1qmgxQw',
#    'alias': 'outsider-tart-london',
#    'name': 'Outsider Tart',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CCbq7o_xmLzRkBXvNOh9TQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/outsider-tart-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4927, 'longitude': -0.252125},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '83 Chiswick High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W4 2EF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Chiswick High Road',
#      'London W4 2EF',
#      'United Kingdom']},
#    'phone': '+442070961609',
#    'display_phone': '+44 20 7096 1609',
#    'distance': 8339.382278059751},
#   {'id': 'UjMwZ6-PgXs3BXN7LLOSAw',
#    'alias': 'gails-bakery-pimlico-london',
#    'name': "GAIL's Bakery - Pimlico",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zobkG9NdbclJN7D9O6w5yw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-pimlico-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4917627846861,
#     'longitude': -0.139058523838447},
#    'transactions': [],
#    'location': {'address1': '26 Churton Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1V 2LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Churton Street',
#      'London SW1V 2LP',
#      'United Kingdom']},
#    'phone': '+442079320734',
#    'display_phone': '+44 20 7932 0734',
#    'distance': 2352.9999537192894},
#   {'id': 'S_1iMSbWOa4I7pa8BxWZag',
#    'alias': 'hart-and-lova-london',
#    'name': 'Hart & Lova',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9VIDKCRKfqFstQt53jVA-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hart-and-lova-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5384383, 'longitude': -0.190891},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '213 Belsize Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 4AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['213 Belsize Road',
#      'London NW6 4AA',
#      'United Kingdom']},
#    'phone': '+447882806540',
#    'display_phone': '+44 7882 806540',
#    'distance': 4748.534923920667},
#   {'id': 'FM2fOny0zttmwnSeHCHzyA',
#    'alias': 'fabrique-bakery-london-5',
#    'name': 'Fabrique Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1-A9bxyUwournvQ4hL3sMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fabrique-bakery-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516469, 'longitude': -0.205223},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '212 Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 1LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['212 Portobello Road',
#      'London W11 1LA',
#      'United Kingdom']},
#    'phone': '+442072213721',
#    'display_phone': '+44 20 7221 3721',
#    'distance': 4813.9954429630825},
#   {'id': 'y89iGnu2dRref9ZXgCCytA',
#    'alias': 'yeast-bakery-london',
#    'name': 'Yeast Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0qcv_V0NwodsQjCOhQU6oA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yeast-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5377001594943,
#     'longitude': -0.0583132356405258},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Arch 356',
#     'address2': 'Westgate Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 3RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Arch 356',
#      'Westgate Street',
#      'London E8 3RL',
#      'United Kingdom']},
#    'phone': '+447973878801',
#    'display_phone': '+44 7973 878801',
#    'distance': 6041.2663110246895},
#   {'id': '83KeM6uScA4ONx97xMHvXw',
#    'alias': 'golden-gate-cake-shop-london',
#    'name': 'Golden Gate Cake Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/t6bnv4bccgmpFEL0qVpmag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/golden-gate-cake-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511968, 'longitude': -0.131181},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '13 Macclesfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 5BR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Macclesfield Street',
#      'London W1D 5BR',
#      'United Kingdom']},
#    'phone': '+442072879862',
#    'display_phone': '+44 20 7287 9862',
#    'distance': 345.0054953908694},
#   {'id': 'u2mLhuhJpEUkKTLXx-TPyw',
#    'alias': 'assal-patisserie-london',
#    'name': 'Assal Patisserie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lVRGr9ZuFGMrPebp3qqtOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/assal-patisserie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5147298, 'longitude': -0.1653632},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '14 Connaught Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 2AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Connaught Street',
#      'London W2 2AF',
#      'United Kingdom']},
#    'phone': '+442077062905',
#    'display_phone': '+44 20 7706 2905',
#    'distance': 2046.8622428463266},
#   {'id': 'BZ96WsFu82jq65zs4Y2MsQ',
#    'alias': 'aux-merveilleux-de-fred-london',
#    'name': 'Aux Merveilleux de Fred',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DXEeU-Kc1KA0V6mm3yRPXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aux-merveilleux-de-fred-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4924431, 'longitude': -0.1778994},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '88 Old Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3LQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['88 Old Brompton Road',
#      'London SW7 3LQ',
#      'United Kingdom']},
#    'phone': '+442075844249',
#    'display_phone': '+44 20 7584 4249',
#    'distance': 3661.0849280759267},
#   {'id': 'CrQcYS4nWWdXmSD1pxf_KA',
#    'alias': 'beigel-bake-london',
#    'name': 'Beigel Bake',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1Q9nDZsnX30-yv55INHp7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beigel-bake-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 477,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.524391, 'longitude': -0.071726},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '159 Brick Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['159 Brick Lane', 'London E1 6SB', 'United Kingdom']},
#    'phone': '+442077290616',
#    'display_phone': '+44 20 7729 0616',
#    'distance': 4626.215959115099},
#   {'id': 'kwFb99k3auydqT6AW3xdWg',
#    'alias': 'gails-bakery-london-37',
#    'name': "GAIL's Bakery",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_9ABUB6ZOlM9Yk6PItBVlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-london-37?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.49891, 'longitude': -0.2001699},
#    'transactions': [],
#    'location': {'address1': '240-242 Kensington High Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 5SA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['240-242 Kensington High Street',
#      'London W8 5SA',
#      'United Kingdom']},
#    'phone': '+442073483924',
#    'display_phone': '+44 20 7348 3924',
#    'distance': 4685.080648578934},
#   {'id': 'riWepzZEIHj82UiDk_WVLQ',
#    'alias': 'montparnasse-cafe-london-2',
#    'name': 'Montparnasse Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/90P9GQECkOj3aZIrJfpO8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/montparnasse-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5005205, 'longitude': -0.1885342},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '22 Thackeray Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 5ET',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Thackeray Street',
#      'London W8 5ET',
#      'United Kingdom']},
#    'phone': '+442073762212',
#    'display_phone': '+44 20 7376 2212',
#    'distance': 3888.086719460034},
#   {'id': 'Nb7nzRoJdGi74Q1TOTcwUw',
#    'alias': 'sally-white-london',
#    'name': 'Sally White',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/i17osVd1Ku5gIk0J833JOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sally-white-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4872522, 'longitude': -0.1111273},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '353 Kennington Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE11 4QE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['353 Kennington Road',
#      'London SE11 4QE',
#      'United Kingdom']},
#    'phone': '+442075820066',
#    'display_phone': '+44 20 7582 0066',
#    'distance': 3338.909143450355},
#   {'id': '9suEi8Hch0YjqnDNtBxhdQ',
#    'alias': 'bread-ahead-london-6',
#    'name': 'Bread Ahead',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ix7tDKo9I9nsz2kT4x6uQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bread-ahead-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5121612401552,
#     'longitude': -0.138188934487744},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '21 Beak Street',
#     'address2': '',
#     'address3': 'Soho',
#     'city': 'London',
#     'zip_code': 'W1F 9RR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21 Beak Street',
#      'Soho',
#      'London W1F 9RR',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 171.76334887977825},
#   {'id': 'HAi7bThXmEtooc5ZQq9hdw',
#    'alias': 'laurents-london',
#    'name': 'Laurents',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IjF-yyo_-fqEs5nTO5MMpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laurents-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.513468, 'longitude': -0.179164},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '39 Craven Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 3BX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39 Craven Road', 'London W2 3BX', 'United Kingdom']},
#    'phone': '+442035819232',
#    'display_phone': '+44 20 3581 9232',
#    'distance': 2990.8516064262462},
#   {'id': 'bPbHHWSUbEQ82X2-ZUcVYQ',
#    'alias': 'peggy-porschen-cakes-london',
#    'name': 'Peggy Porschen Cakes',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c_IC2X6VwcQEK8REEtmceQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peggy-porschen-cakes-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 102,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.493261207677,
#     'longitude': -0.150525569915771},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '116 Ebury Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 9QQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['116 Ebury Street',
#      'London SW1W 9QQ',
#      'United Kingdom']},
#    'phone': '+442077301316',
#    'display_phone': '+44 20 7730 1316',
#    'distance': 2398.834581982357},
#   {'id': 'BVD84PXIYOiIr5Rc-s8JQw',
#    'alias': 'crosstown-doughnuts-and-coffee-london-2',
#    'name': 'Crosstown Doughnuts & Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eJQiXqEJVqVd0uwQPU0qYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crosstown-doughnuts-and-coffee-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 81,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514167, 'longitude': -0.1346751},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 Broadwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8HJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Broadwick Street',
#      'London W1F 8HJ',
#      'United Kingdom']},
#    'phone': '+442077348873',
#    'display_phone': '+44 20 7734 8873',
#    'distance': 167.30030991784423},
#   {'id': '526yWZIgx7PQKJcBY8PWRg',
#    'alias': 'grodzinski-bakers-shops-london',
#    'name': "Grodzinski Bakers' Shops",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dUAPsxXkw8eX4rj-PXR6wQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grodzinski-bakers-shops-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5732238, 'longitude': -0.0714056},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '170 Clapton Common',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E5 9AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['170 Clapton Common',
#      'London E5 9AG',
#      'United Kingdom']},
#    'phone': '+442082118108',
#    'display_phone': '+44 20 8211 8108',
#    'distance': 8075.487268555366},
#   {'id': 'Sxe2lUli3t_XA5aKYUqqkQ',
#    'alias': 'the-butter-bakery-london',
#    'name': 'The Butter Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PpA6jruR-OIILmj4vmjXhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-butter-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5177900934312,
#     'longitude': -0.201469101011753},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '219 Westbourne Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['219 Westbourne Park Road',
#      'London W11',
#      'United Kingdom']},
#    'phone': '+442072439223',
#    'display_phone': '+44 20 7243 9223',
#    'distance': 4566.685019734055},
#   {'id': 'Sh_PrXavTAk2d5jTs_onuQ',
#    'alias': 'nordic-bakery-london',
#    'name': 'Nordic Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y1r_R3BokRhDYZIaF0XB6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nordic-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 118,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'scandinavian', 'title': 'Scandinavian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5114297969411,
#     'longitude': -0.13674108684063},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 Golden Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9JG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Golden Square',
#      'London W1F 9JG',
#      'United Kingdom']},
#    'phone': '+442032301077',
#    'display_phone': '+44 20 3230 1077',
#    'distance': 165.48625457765309},
#   {'id': 'OOJTf27dRVOTrokw1ZnOZA',
#    'alias': 'sophocles-bakery-london-2',
#    'name': 'Sophocles Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3ZkjQcFDfMkm4LErYKEiWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sophocles-bakery-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.473763328735,
#     'longitude': -0.089810647607304},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '24 Camberwell Church Street',
#     'address2': 'Camberwell',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE5 8QU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Camberwell Church Street',
#      'Camberwell',
#      'London SE5 8QU',
#      'United Kingdom']},
#    'phone': '+442072526316',
#    'display_phone': '+44 20 7252 6316',
#    'distance': 5392.734733691988}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                     Restaurant          Type Price Rating            Address  \
# 0                     Bageriet  Scandinavian     £    4.5     24 Rose Street
# 1                  Bread Ahead      Bakeries     £    4.5     Borough Market
# 2  GAIL's Bakery Seymour Place      Bakeries    ££    4.5  4-6 Seymour Place
# 3       Patisserie Sainte Anne      Bakeries     £      5    204 King Street
# 4            Aux Pains de Papy      Bakeries     £      5   279 Grays Inn Rd
#
#          Lat       Lng                                                url  \
# 0  51.511924 -0.126182  https://www.yelp.com/biz/bageriet-london?adjus...
# 1  51.506143 -0.090258  https://www.yelp.com/biz/bread-ahead-london-3?...
# 2  51.514595 -0.160964  https://www.yelp.com/biz/gails-bakery-seymour-...
# 3  51.493081 -0.236023  https://www.yelp.com/biz/patisserie-sainte-ann...
# 4  51.527386 -0.118468  https://www.yelp.com/biz/aux-pains-de-papy-lon...
#
#                        ID
# 0  0tJs57Xoq75-RDWKVco0nw
# 1  KZd0pTzAhKbIs9Lg94Delg
# 2  LgKc7xGArsmxAw6xUQ2mYA
# 3  3ZWC6EkdLcUe80Vq097Bfg
# 4  wh4R2zTxcjZw4JcQFNBtog

# %%
#2nd set of 50 records 51-100 
lndr_params2 = {"term":"bakery","location":"London","limit":50,"offset":51}
lndr_response2 = requests.get(search_api_url, headers=headers, params=lndr_params2)
lndr2 = lndr_response2.json()
display(lndr2)
#print(lndr_response2.url)
#print(lndr_response2.status_code)
# Out:
# {'businesses': [{'id': 'OGW03dLcEui-6CWZIucVMw',
#    'alias': 'laduree-london-14',
#    'name': 'Laduree',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gnAH2qu0IqhJq3NQA1h8Jg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laduree-london-14?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'macarons', 'title': 'Macarons'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5083572494815,
#     'longitude': -0.139577354757421},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '71-72 Burlington Arcade',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 0QX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['71-72 Burlington Arcade',
#      'London W1J 0QX',
#      'United Kingdom']},
#    'phone': '+442074919155',
#    'display_phone': '+44 20 7491 9155',
#    'distance': 557.4749357668763},
#   {'id': '7TETeEdYvewlhdjmMSwLdg',
#    'alias': 'pâtisserie-deux-amis-london-2',
#    'name': 'Pâtisserie Deux Amis',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QOrh6QeP-vvD3r_lviR-CA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/p%C3%A2tisserie-deux-amis-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.526409002227,
#     'longitude': -0.12406009445317},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '63 Judd Street',
#     'address2': 'Bloomsbury',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 9QT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63 Judd Street',
#      'Bloomsbury',
#      'London WC1H 9QT',
#      'United Kingdom']},
#    'phone': '+442073837029',
#    'display_phone': '+44 20 7383 7029',
#    'distance': 1719.1378500956116},
#   {'id': 'muxCRMUqHY63jE0wavLG7w',
#    'alias': 'violet-cakes-london',
#    'name': 'Violet Cakes',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/S9OZXaf_jMG4rEiNxuA-5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/violet-cakes-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.545469478641,
#     'longitude': -0.064133277339768},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '47 Wilton Way',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 3ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Wilton Way', 'London E8 3ED', 'United Kingdom']},
#    'phone': '+442072758360',
#    'display_phone': '+44 20 7275 8360',
#    'distance': 6152.4531923363975},
#   {'id': 'mvds37L7mCurGn3rGPM8ag',
#    'alias': 'kaffeine-london',
#    'name': 'Kaffeine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QWk5UJ1ELO0n7VrE3aLUWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaffeine-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 173,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51848, 'longitude': -0.14037},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '66 Great Titchfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 7QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Great Titchfield Street',
#      'London W1W 7QJ',
#      'United Kingdom']},
#    'phone': '+442075806755',
#    'display_phone': '+44 20 7580 6755',
#    'distance': 697.5687539772275},
#   {'id': 'Rw0EzoWhElWgfbb84hMuhQ',
#    'alias': 'the-cakehouse-london',
#    'name': 'The Cakehouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yQl2G5YIdYgq5m5I0Z-0bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cakehouse-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5460129, 'longitude': -0.147699},
#    'transactions': [],
#    'location': {'address1': '73 Prince of Wales Road',
#     'address2': 'Kentish Town',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW5 3LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['73 Prince of Wales Road',
#      'Kentish Town',
#      'London NW5 3LT',
#      'United Kingdom']},
#    'phone': '+447913233777',
#    'display_phone': '+44 7913 233777',
#    'distance': 3779.91205310475},
#   {'id': 'c3m_OXrRNdJpWmTqhEgdeQ',
#    'alias': 'lanka-london-2',
#    'name': 'Lanka',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1pANCLbvBZdO9tptjqOjmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lanka-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5457719, 'longitude': -0.1793938},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9 Goldhurst Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 3HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Goldhurst Terrace',
#      'London NW6 3HX',
#      'United Kingdom']},
#    'phone': '+442076253366',
#    'display_phone': '+44 20 7625 3366',
#    'distance': 4737.301543897287},
#   {'id': '0_D-cBDrhU6Cx0hHeHVO3w',
#    'alias': 'rubys-of-london-london',
#    'name': 'Rubys of London',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4tSGCTag0QTRdwhjVne_sw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rubys-of-london-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4816271, 'longitude': -0.0088386},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5B Greenwich market',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE10 9HZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5B Greenwich market',
#      'London SE10 9HZ',
#      'United Kingdom']},
#    'phone': '+447947271487',
#    'display_phone': '+44 7947 271487',
#    'distance': 9459.174442337338},
#   {'id': '-6GHU4qI0DKsIrBpv57qTg',
#    'alias': 'e5-bakehouse-london',
#    'name': 'E5 Bakehouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5fOMHTqW0WvJz3o4ojfxXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/e5-bakehouse-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5412038403948,
#     'longitude': -0.0576161965996107},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '395 Mentmore Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 3PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['395 Mentmore Terrace',
#      'London E8 3PH',
#      'United Kingdom']},
#    'phone': '+442085252890',
#    'display_phone': '+44 20 8525 2890',
#    'distance': 6270.653368630909},
#   {'id': '9klx0ol5iCCf7vG-IjcYFQ',
#    'alias': 'patisserie-valerie-london-12',
#    'name': 'Patisserie Valerie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/u6ECUWzSeBE8a5BOTiE2OA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-valerie-london-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5157113693673,
#     'longitude': -0.188256121731851},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '174-176 Queensway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 6LY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['174-176 Queensway',
#      'London W2 6LY',
#      'United Kingdom']},
#    'phone': '+442072439069',
#    'display_phone': '+44 20 7243 9069',
#    'distance': 3633.214213959659},
#   {'id': 'HL5WLBu_thiEf8ix4BZvGg',
#    'alias': 'belle-epoque-london-5',
#    'name': 'Belle Epoque',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/I7v76Z129jZQ-rmxG8l3wA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/belle-epoque-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5427478375484,
#     'longitude': -0.103128254413605},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '262 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 2UQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['262 Upper Street',
#      'London N1 2UQ',
#      'United Kingdom']},
#    'phone': '+442080018295',
#    'display_phone': '+44 20 8001 8295',
#    'distance': 4027.4206501396397},
#   {'id': 'X8UxGRF_ju6cfIB2fZizqQ',
#    'alias': 'old-post-office-bakery-london',
#    'name': 'Old Post Office Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VvgStDUrKexM7fTdbDSPeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/old-post-office-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.465915224149,
#     'longitude': -0.12510033116717},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '76 Landor Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 9PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['76 Landor Road', 'London SW9 9PH', 'United Kingdom']},
#    'phone': '+442073264408',
#    'display_phone': '+44 20 7326 4408',
#    'distance': 5271.15208095644},
#   {'id': 'J38s3iokvd30sRGi5uB9lA',
#    'alias': 'l-eto-caffe-london',
#    'name': "L'Eto Caffe",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/glLwggFfv-PFoCGgzDIynA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-eto-caffe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 124,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514301, 'longitude': -0.134786},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '155 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8WG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['155 Wardour Street',
#      'London W1F 8WG',
#      'United Kingdom']},
#    'phone': '+442074944991',
#    'display_phone': '+44 20 7494 4991',
#    'distance': 181.95299001691527},
#   {'id': 'Da8ClETsPknyD-XIam-jbg',
#    'alias': 'maroush-bakehouse-london-6',
#    'name': 'Maroush Bakehouse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hYjyJ-w7yL5JNQ_7sUFl9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maroush-bakehouse-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'lebanese', 'title': 'Lebanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.49332, 'longitude': -0.194478},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '131 Earls Court Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 9RH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['131 Earls Court Road',
#      'London SW5 9RH',
#      'United Kingdom']},
#    'phone': '+442073704324',
#    'display_phone': '+44 20 7370 4324',
#    'distance': 4595.303422118365},
#   {'id': 'lINVn-iVcLcFQkq1DXZo_Q',
#    'alias': 'upper-fleet-bakery-london',
#    'name': 'Upper Fleet Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/av4PNLmZzYf0tuHKp3Y-6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/upper-fleet-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5263319313231,
#     'longitude': -0.129384561430401},
#    'transactions': [],
#    'location': {'address1': '7 - 11 Upper Woburn place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 0JW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 - 11 Upper Woburn place',
#      'London WC1H 0JW',
#      'United Kingdom']},
#    'phone': '+442073875544',
#    'display_phone': '+44 20 7387 5544',
#    'distance': 1568.0932386529987},
#   {'id': '7g5S5zrRb0IrYu0ZM5O5Yg',
#    'alias': 'fabrique-london-2',
#    'name': 'Fabrique',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Gq6IsAbB1wdj6uRNp_u7QA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fabrique-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5176073307184,
#     'longitude': -0.119026713073254},
#    'transactions': [],
#    'location': {'address1': '239 High Holborn',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC1V 7EW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['239 High Holborn',
#      'London WC1V 7EW',
#      'United Kingdom']},
#    'phone': '+442078310925',
#    'display_phone': '+44 20 7831 0925',
#    'distance': 1286.0115485327688},
#   {'id': 'bNkcbScID14JJvtPZBuxLA',
#    'alias': 'luminary-bakery-london',
#    'name': 'Luminary Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vEdYGIJZWlwfT2eN1jEvIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luminary-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.543002, 'longitude': -0.148795},
#    'transactions': [],
#    'location': {'address1': '47 Chalk Farm Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW1 8AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Chalk Farm Road',
#      'London NW1 8AJ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3469.9541741640596},
#   {'id': '5aKBzS_J3DF2cxhzC5IGGw',
#    'alias': 'delice-de-france-london-4',
#    'name': 'Delice de France',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BQfMllecVKsseihBeY_zLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/delice-de-france-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.5156898498535,
#     'longitude': -0.176127001643181},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Paddington Station',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1HB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Paddington Station',
#      'London W2 1HB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2797.85561633946},
#   {'id': '1OcBgrUzPgp82BfZBUKRow',
#    'alias': 'gails-bakery-hampstead-london',
#    'name': "GAIL's Bakery Hampstead",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UOf253iDTU_yHsHrbwwV2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-hampstead-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5561216, 'longitude': -0.1779628},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '64 Hampstead High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 1QH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['64 Hampstead High Street',
#      'London NW3 1QH',
#      'United Kingdom']},
#    'phone': '+442077940926',
#    'display_phone': '+44 20 7794 0926',
#    'distance': 5621.242336165493},
#   {'id': 'FEfzDsEOSdtHvf3aTrb6lQ',
#    'alias': 'akdeniz-bakery-london',
#    'name': 'Akdeniz Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NaPeDifVtu9GLQVpbW0VVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/akdeniz-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.558398, 'longitude': -0.0740563},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '60 Stoke Newington High Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N16 7PB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['60 Stoke Newington High Street',
#      'London N16 7PB',
#      'United Kingdom']},
#    'phone': '+442072758554',
#    'display_phone': '+44 20 7275 8554',
#    'distance': 6633.063774275486},
#   {'id': 'MY5vPpDxJFPzj-wR4_pUsg',
#    'alias': 'crumpets-london',
#    'name': 'Crumpets',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2GXRSS7bftG4X6Z-0Q4VxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crumpets-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4991936, 'longitude': -0.1382647},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '82 Buckingham Gate',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1E 6PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['82 Buckingham Gate',
#      'London SW1E 6PD',
#      'United Kingdom']},
#    'phone': '+442072331479',
#    'display_phone': '+44 20 7233 1479',
#    'distance': 1525.3047584226708},
#   {'id': 'L7Vvywx0FVe6StgC09kzrw',
#    'alias': 'rainbow-bakery-london',
#    'name': 'Rainbow Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kubgh_WQaeCqJSjHbAHFRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rainbow-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5459727, 'longitude': -0.0754968},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '596 Kingsland Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 4AH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['596 Kingsland Road',
#      'London E8 4AH',
#      'United Kingdom']},
#    'phone': '+442079231706',
#    'display_phone': '+44 20 7923 1706',
#    'distance': 5572.99748276904},
#   {'id': 'amwXVuFLQbmANNjDKjbXrw',
#    'alias': 'the-hummingbird-bakery-london',
#    'name': 'The Hummingbird Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HuMCbJNVTn0C4JtmMNm9qQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hummingbird-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 87,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4933421535998,
#     'longitude': -0.175513593691228},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '47 Old Brompton Road',
#     'address2': 'South Kensington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3JP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Old Brompton Road',
#      'South Kensington',
#      'London SW7 3JP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3492.1444261249017},
#   {'id': 'HXjHL0L7lqtQQ1KJ0ZKAug',
#    'alias': 'kastner-and-ovens-london',
#    'name': 'Kastner and Ovens',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/n6adQfuqx24tKJlv0wMiew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kastner-and-ovens-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5135034, 'longitude': -0.1227604},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '52 Floral Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 9DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['52 Floral Street',
#      'London WC2E 9DA',
#      'United Kingdom']},
#    'phone': '+442078362700',
#    'display_phone': '+44 20 7836 2700',
#    'distance': 918.5834049759383},
#   {'id': 'u10_rYKhp-7Xk4W1axZVHg',
#    'alias': 'benita-bakery-london',
#    'name': 'Benita Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gOG8hcvVymDBqczlaU7UEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/benita-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5449553690602,
#     'longitude': -0.103480964899063},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '239 Upper Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N1 1RU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['239 Upper Street',
#      'London N1 1RU',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4219.334748128452},
#   {'id': 'vt3Klo2UTjlvQD4AvU7d2A',
#    'alias': 'bens-cookies-london-3',
#    'name': "Ben's Cookies",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ovcS7_oO-BaMNdHx4_NPzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bens-cookies-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 156,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5122, 'longitude': -0.122449},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '13A The Piazza',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 8HD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13A The Piazza',
#      'London WC2E 8HD',
#      'United Kingdom']},
#    'phone': '+442072406599',
#    'display_phone': '+44 20 7240 6599',
#    'distance': 937.3574582695936},
#   {'id': 'nJA-5mA9yvHF55M-cwWVRg',
#    'alias': 'the-wild-goose-bakery-london',
#    'name': 'The Wild Goose Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/E4LTIQEXIQ3N9BWm3iN9VA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wild-goose-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.56867, 'longitude': 0.01134},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '654 High Road',
#     'address2': 'Leytonstone',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E11 3AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['654 High Road',
#      'Leytonstone',
#      'London E11 3AA',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 11903.838612909321},
#   {'id': 'P1iHRy8VwEYpgZ9jtdiz7g',
#    'alias': 'le-coq-epicier-london',
#    'name': 'Le Coq Epicier',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WuZ27yJumjNqtYC-gX-WXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-coq-epicier-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5345405, 'longitude': -0.1043652},
#    'transactions': [],
#    'location': {'address1': '1 Islington High Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N1 8EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Islington High Street',
#      'London N1 8EA',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3256.0158730619855},
#   {'id': 'chCmoqD2AjX04TE1R0qZOA',
#    'alias': 'popina-london-4',
#    'name': 'Popina',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/75GQwQFxZTxsXs9CpcPviw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/popina-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5130134404197,
#     'longitude': -0.150612695002224},
#    'transactions': [],
#    'location': {'address1': '82 Duke Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1K 6JG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['82 Duke Street', 'London W1K 6JG', 'United Kingdom']},
#    'phone': '+442076298883',
#    'display_phone': '+44 20 7629 8883',
#    'distance': 1014.460480632947},
#   {'id': 'XD89DGPLbNTjVhesu5wyIA',
#    'alias': 'kooky-bakes-london',
#    'name': 'Kooky Bakes',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/C99Maf_9qZ_AdJzCqz8hhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kooky-bakes-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'streetvendors', 'title': 'Street Vendors'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5210655305934,
#     'longitude': -0.0729759455077783},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Sunday Up Market',
#     'address2': 'Brick Lane',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Sunday Up Market',
#      'Brick Lane',
#      'London E1 6QL',
#      'United Kingdom']},
#    'phone': '+442030868350',
#    'display_phone': '+44 20 3086 8350',
#    'distance': 4452.919827953376},
#   {'id': '5tIA8ET05tlWsD7IcQuofQ',
#    'alias': 'cake-boy-london',
#    'name': 'Cake Boy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/j5Cxg6_7Lu500ylQ5IJUvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cake-boy-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4647477201238,
#     'longitude': -0.184028157672174},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Unite 2 Kingfisher House / Battersea Reach',
#     'address2': 'Jupiner Drive',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW18 1TX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unite 2 Kingfisher House / Battersea Reach',
#      'Jupiner Drive',
#      'London SW18 1TX',
#      'United Kingdom']},
#    'phone': '+442079785555',
#    'display_phone': '+44 20 7978 5555',
#    'distance': 6298.404528588159},
#   {'id': 'mdy8N4wPOlOSiatLWKjLGg',
#    'alias': 'the-borough-barista-london',
#    'name': 'The Borough Barista',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5BOQF57dPe1EaVvhzb0wtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-borough-barista-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.514461025878,
#     'longitude': -0.16090849657059},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '60A Seymour Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7JN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['60A Seymour Street',
#      'London W1H 7JN',
#      'United Kingdom']},
#    'phone': '+442075637222',
#    'display_phone': '+44 20 7563 7222',
#    'distance': 1736.1517070034572},
#   {'id': 'DARE_WvgMZINvslycDPJFQ',
#    'alias': 'raabs-bakery-london',
#    'name': "Raab's Bakery",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Q_qgt_LRqOi-YUrl4rNWCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raabs-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5393189, 'longitude': -0.0977451},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '136 Essex Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8LX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['136 Essex Road', 'London N1 8LX', 'United Kingdom']},
#    'phone': '+442072262830',
#    'display_phone': '+44 20 7226 2830',
#    'distance': 3968.321016159277},
#   {'id': 'Q4sKgCkCPOD4CkSO9wXhOg',
#    'alias': 'brioche-dorée-london-2',
#    'name': 'Brioche Dorée',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brioche-dor%C3%A9e-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5151408, 'longitude': -0.150699},
#    'transactions': [],
#    'location': {'address1': '21 James Street',
#     'address2': 'Mayfair',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1U 1DS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21 James Street',
#      'Mayfair',
#      'London W1U 1DS',
#      'United Kingdom']},
#    'phone': '+442074862420',
#    'display_phone': '+44 20 7486 2420',
#    'distance': 1051.9261103618692},
#   {'id': 'KsKHtI7sgXfY2ppxi7QKig',
#    'alias': 'honey-and-spice-london',
#    'name': 'Honey & Spice',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IBTN0uzIN6WzZYo0fVAuLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/honey-and-spice-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'herbsandspices', 'title': 'Herbs & Spices'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.524137, 'longitude': -0.140204},
#    'transactions': [],
#    'location': {'address1': '52 Warren Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1T 5NJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['52 Warren Street',
#      'London W1T 5NJ',
#      'United Kingdom']},
#    'phone': '+442073886175',
#    'display_phone': '+44 20 7388 6175',
#    'distance': 1290.5853879704657},
#   {'id': 'jIuiv7VJkAAM5bRCuKNozg',
#    'alias': 'baker-and-spice-london',
#    'name': 'Baker & Spice',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qhKK__pVmzQmzhkDlOTx8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baker-and-spice-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4936, 'longitude': -0.150758},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '54-56 Elizabeth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 9PB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54-56 Elizabeth Street',
#      'London SW1W 9PB',
#      'United Kingdom']},
#    'phone': '+442077305524',
#    'display_phone': '+44 20 7730 5524',
#    'distance': 2371.6101398591395},
#   {'id': '78P_MEpAuokAM7gxss829A',
#    'alias': 'dum-dum-donutterie-brick-lane-london-2',
#    'name': 'Dum Dum Donutterie - Brick Lane',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-Oyd3MOC4wr0xkrYpMxRCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dum-dum-donutterie-brick-lane-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5184915, 'longitude': -0.071576},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '43 Brick Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6PU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['43 Brick Lane', 'London E1 6PU', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4498.671570100571},
#   {'id': '3AXQMV-Yirhfq4oQHry6tA',
#    'alias': 'poilane-london-2',
#    'name': 'Poilane',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Q6ebWSVX6ww2ytOCd96_Aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/poilane-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.493827, 'longitude': -0.150838},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '46 Elizabeth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 9PA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['46 Elizabeth Street',
#      'London SW1W 9PA',
#      'United Kingdom']},
#    'phone': '+442078084910',
#    'display_phone': '+44 20 7808 4910',
#    'distance': 2353.221354752839},
#   {'id': 'Q4btnsnZT8LzB8pr5ctUAQ',
#    'alias': 'la-gauloise-london',
#    'name': 'La Gauloise',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SeVfPHRr2YrwvDuKgzX2pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-gauloise-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5228807, 'longitude': -0.1582018},
#    'transactions': [],
#    'location': {'address1': '3a Melcombe Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 6AE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3a Melcombe Street',
#      'London NW1 6AE',
#      'United Kingdom']},
#    'phone': '+442079352179',
#    'display_phone': '+44 20 7935 2179',
#    'distance': 1914.5356145615076},
#   {'id': 'MtJQNJVJsICx_YZ1LDOqBw',
#    'alias': 'cutter-and-squidge-soho',
#    'name': 'Cutter and Squidge',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DxlkybPUIWgZ_4IFmA1wQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cutter-and-squidge-soho?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5123136, 'longitude': -0.1343362},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Brewer Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Soho',
#     'zip_code': 'W1F 0SJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Brewer Street', 'Soho W1F 0SJ', 'United Kingdom']},
#    'phone': '+442077342540',
#    'display_phone': '+44 20 7734 2540',
#    'distance': 128.09860619009447},
#   {'id': 'XmUWjHm8Uh_UCyDsr6LFVw',
#    'alias': 'hummingbird-bakery-london-2',
#    'name': 'Hummingbird Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VKOgrjpfhFRtNgfYS1isEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hummingbird-bakery-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5312670306865,
#     'longitude': -0.106344223022461},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'The Angel Building',
#     'address2': '405 St John Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 4AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Angel Building',
#      '405 St John Street',
#      'London EC1V 4AB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2897.880490415323},
#   {'id': 'xJvPDma1C7F7hvEp0OfjWg',
#    'alias': 'patisserie-valerie-london-11',
#    'name': 'Patisserie Valerie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lcoP_bGFWqLxUVWqFEuszA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-valerie-london-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5142705778633,
#     'longitude': -0.159455789441691},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'York House',
#     'address2': '15 Great Cumberland Place',
#     'address3': 'London',
#     'city': 'London',
#     'zip_code': 'W1H 7AS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['York House',
#      '15 Great Cumberland Place',
#      'London',
#      'London W1H 7AS',
#      'United Kingdom']},
#    'phone': '+442077248542',
#    'display_phone': '+44 20 7724 8542',
#    'distance': 1634.0041903497304},
#   {'id': 'UjsIWFM9xcD9PCO0nJoMCQ',
#    'alias': 'caffe-in-london',
#    'name': 'Caffe In',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O4NH7q62sJXw765I_8fEvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-in-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.506194, 'longitude': -0.146446},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3 Shepherd Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 7HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Shepherd Street',
#      'London W1J 7HL',
#      'United Kingdom']},
#    'phone': '+442074936400',
#    'display_phone': '+44 20 7493 6400',
#    'distance': 1032.7212314091926},
#   {'id': 'U_XeFWW1Lttdq22txTABMw',
#    'alias': 'gails-bakery-neo-bankside-london',
#    'name': "GAIL's Bakery Neo Bankside",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CEfkaYA0zFoAlNcdiNt_aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-neo-bankside-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5066352772979,
#     'longitude': -0.100412668500134},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit C Neo Bankside',
#     'address2': '70 Holland Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9NX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit C Neo Bankside',
#      '70 Holland Road',
#      'London SE1 9NX',
#      'United Kingdom']},
#    'phone': '+442079280621',
#    'display_phone': '+44 20 7928 0621',
#    'distance': 2554.576460738087},
#   {'id': 'UDcjE8YbIE4mtMZBg4sIzQ',
#    'alias': 'aubaine-london-11',
#    'name': 'Aubaine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iiVF75iKlle9jjaOlUCyEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aubaine-london-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5103765333673,
#     'longitude': -0.187597811045066},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Hilton London Hyde Park',
#     'address2': '129 Bayswater Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 4RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Hilton London Hyde Park',
#      '129 Bayswater Road',
#      'London W2 4RJ',
#      'United Kingdom']},
#    'phone': '+442037733930',
#    'display_phone': '+44 20 3773 3930',
#    'distance': 3584.2136643996305},
#   {'id': 'nBHgQH6Fo7VZ5ipeV9FZmA',
#    'alias': 'bonne-bouche-london',
#    'name': 'Bonne Bouche',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qrnNxCG7Iflid-AiSnSzew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bonne-bouche-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5181053211288,
#     'longitude': -0.151716128809521},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '2-3 Thayer Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 3JB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2-3 Thayer Street',
#      'London W1U 3JB',
#      'United Kingdom']},
#    'phone': '+442074869584',
#    'display_phone': '+44 20 7486 9584',
#    'distance': 1238.0218508033952},
#   {'id': '271U0h4hish4lq_mESjGRw',
#    'alias': 'maitre-choux-london-2',
#    'name': 'Maitre Choux',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/veVV5ArN0vnhOMfPv3i9cA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maitre-choux-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5127143859863,
#     'longitude': -0.132231995463371},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '60 Dean St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1D 6AW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['60 Dean St', 'London W1D 6AW', 'United Kingdom']},
#    'phone': '+442077343132',
#    'display_phone': '+44 20 7734 3132',
#    'distance': 271.62844826358406},
#   {'id': 'NyokgJ-rDE5Zp8Ao3CJEQg',
#    'alias': 'sweet-things-london',
#    'name': 'Sweet Things',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UoJpTVPP7p4smoLKNp-_2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweet-things-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5409262, 'longitude': -0.1572602},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '138 Regents Park Road',
#     'address2': 'Primrose Hill',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW1 8XL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['138 Regents Park Road',
#      'Primrose Hill',
#      'London NW1 8XL',
#      'United Kingdom']},
#    'phone': '+442077222107',
#    'display_phone': '+44 20 7722 2107',
#    'distance': 3453.788640184007},
#   {'id': 'L-ZNTln24SoU_jYia4M19Q',
#    'alias': 'ottolenghi-london-3',
#    'name': 'Ottolenghi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/M0v7lVN-ZkBDz0BuJQhzwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ottolenghi-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 96,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514890823172,
#     'longitude': -0.19941762827537},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '63 Ledbury Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2AD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63 Ledbury Road',
#      'London W11 2AD',
#      'United Kingdom']},
#    'phone': '+442077271121',
#    'display_phone': '+44 20 7727 1121',
#    'distance': 4397.458116121883},
#   {'id': 'f4bEfbf1_VyZpLsvlonhMw',
#    'alias': 'paul-gloucester-road-london',
#    'name': 'PAUL - Gloucester Road',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4LmyxBx2ijOg34FW_YfI9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-gloucester-road-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 56,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4949745, 'longitude': -0.1825811},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '73 Gloucester Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 4SS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['73 Gloucester Road',
#      'London SW7 4SS',
#      'United Kingdom']},
#    'phone': '+442073731232',
#    'display_phone': '+44 20 7373 1232',
#    'distance': 3789.8998601376957},
#   {'id': 'aivGgBZ83bZjE95nrB1jvA',
#    'alias': 'peyton-and-byrne-london-11',
#    'name': 'Peyton and Byrne',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/G61GtUBwTiGpiZmjnU5Z9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peyton-and-byrne-london-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5228863, 'longitude': -0.143831277057965},
#    'transactions': [],
#    'location': {'address1': '226 Great Portland Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1W 5QP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['226 Great Portland Street',
#      'London W1W 5QP',
#      'United Kingdom']},
#    'phone': '+442034221453',
#    'display_phone': '+44 20 3422 1453',
#    'distance': 1243.3684205844672}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#              Restaurant          Type Price Rating  \
# 0               Laduree      Macarons   £££    4.5
# 1  Pâtisserie Deux Amis      Bakeries    ££      4
# 2          Violet Cakes  Coffee & Tea   £££      4
# 3              Kaffeine  Coffee & Tea    ££    4.5
# 4         The Cakehouse         Cafes
#
#                       Address        Lat       Lng  \
# 0     71-72 Burlington Arcade  51.508357 -0.139577
# 1              63 Judd Street  51.526409 -0.124060
# 2               47 Wilton Way  51.545469 -0.064133
# 3  66 Great Titchfield Street  51.518480 -0.140370
# 4     73 Prince of Wales Road  51.546013 -0.147699
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/laduree-london-14?adj...  OGW03dLcEui-6CWZIucVMw
# 1  https://www.yelp.com/biz/p%C3%A2tisserie-deux-...  7TETeEdYvewlhdjmMSwLdg
# 2  https://www.yelp.com/biz/violet-cakes-london?a...  muxCRMUqHY63jE0wavLG7w
# 3  https://www.yelp.com/biz/kaffeine-london?adjus...  mvds37L7mCurGn3rGPM8ag
# 4

# %%
#3rd set of 50 records 101-150
lndr_params3 = {"term":"bakery","location":"London","limit":50,"offset":101}
lndr_response3 = requests.get(search_api_url, headers=headers, params=lndr_params3)
lndr3 = lndr_response3.json()
display(lndr3)
#print(lndr_response3.url)
#print(lndr_response3.status_code)
# Out:
# {'businesses': [{'id': 'VQCzUGBY63yVE-FxLg6vqg',
#    'alias': 'paul-london-46',
#    'name': 'Paul',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Bpjml-e7uByqnhRG9TS7Dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-london-46?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4922526690858,
#     'longitude': -0.192893868972578},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '185 Earls Court Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW5 9RB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['185 Earls Court Road',
#      'London SW5 9RB',
#      'United Kingdom']},
#    'phone': '+442072441046',
#    'display_phone': '+44 20 7244 1046',
#    'distance': 4557.42106632384},
#   {'id': 'VZ_1ATiJ5j4uTHvGHr7JNw',
#    'alias': 'wonderful-patisserie-london',
#    'name': 'Wonderful Patisserie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_L6bhJQIUIF0rscqPJHuIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wonderful-patisserie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.511969, 'longitude': -0.130143},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '45 Gerrard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 5QQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Gerrard Street',
#      'London W1D 5QQ',
#      'United Kingdom']},
#    'phone': '+442077347629',
#    'display_phone': '+44 20 7734 7629',
#    'distance': 415.7925288481275},
#   {'id': 'tH_2560cbjme-hFBFVj8cQ',
#    'alias': 'brigits-bakery-london',
#    'name': "Brigit's Bakery",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mdh8u6FH2qeo4BRzNVNBHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brigits-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5100888407083,
#     'longitude': -0.124539992630842},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6-7 Chandos Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4HU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6-7 Chandos Place',
#      'London WC2N 4HU',
#      'United Kingdom']},
#    'phone': '+442030261188',
#    'display_phone': '+44 20 3026 1188',
#    'distance': 846.9905268424552},
#   {'id': 'GSbQscE52ZfK43ykA6vLbg',
#    'alias': 'fortnum-and-mason-diamond-jubilee-tea-salon-london',
#    'name': 'Fortnum and Mason: Diamond Jubilee Tea Salon',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BnvHO-ZpEwnHqhsLLXzr0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fortnum-and-mason-diamond-jubilee-tea-salon-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 262,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5087069889729,
#     'longitude': -0.138279327972609},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '4th Floor',
#     'address2': '181 Piccadilly',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1A 1ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4th Floor',
#      '181 Piccadilly',
#      'London W1A 1ER',
#      'United Kingdom']},
#    'phone': '+448453001707',
#    'display_phone': '+44 845 300 1707',
#    'distance': 486.41760431695195},
#   {'id': '-EPJuMu8Qbr5azjHu_QOtg',
#    'alias': 'the-watch-house-london-5',
#    'name': 'The Watch House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/v6IlbI-P0BgzdTxXQcQn2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-watch-house-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4980461313304,
#     'longitude': -0.0810502413027092},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '199 Bermondsey Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 3UW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['199 Bermondsey Street',
#      'London SE1 3UW',
#      'United Kingdom']},
#    'phone': '+442074075431',
#    'display_phone': '+44 20 7407 5431',
#    'distance': 4140.698976372922},
#   {'id': 'k7qmLDOGfESN8fDBQZZL7w',
#    'alias': '106-baker-st-london',
#    'name': '106 Baker St',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9CXBPhU2Ib_gv7QmtYAMCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/106-baker-st-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5207977, 'longitude': -0.1566825},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '106 Baker Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 6TW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['106 Baker Street',
#      'London W1U 6TW',
#      'United Kingdom']},
#    'phone': '+442074873372',
#    'display_phone': '+44 20 7487 3372',
#    'distance': 1689.8849777286025},
#   {'id': 'XLZZ1MsocZiXavD39zfHgg',
#    'alias': 'paul-london-28',
#    'name': 'Paul',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6CvfTBsiRuSIMwp-7laC1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-london-28?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.508135, 'longitude': -0.139246},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '173 Piccadilly Arcade',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 6NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['173 Piccadilly Arcade',
#      'London SW1Y 6NH',
#      'United Kingdom']},
#    'phone': '+442074998708',
#    'display_phone': '+44 20 7499 8708',
#    'distance': 570.1166518695289},
#   {'id': 'uTm94f_-FlwM7v7T2ycXaQ',
#    'alias': 'dominique-ansel-treehouse-london',
#    'name': 'Dominique Ansel Treehouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Amyw6Q1tbkeeiPYFPnwBUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dominique-ansel-treehouse-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5119045680643,
#     'longitude': -0.12540479881136},
#    'transactions': [],
#    'location': {'address1': '24 Floral Street',
#     'address2': '',
#     'address3': 'Covent Garden',
#     'city': 'London',
#     'zip_code': 'WC2E 9DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Floral Street',
#      'Covent Garden',
#      'London WC2E 9DP',
#      'United Kingdom']},
#    'phone': '+442038834710',
#    'display_phone': '+44 20 3883 4710',
#    'distance': 737.4485292911053},
#   {'id': 'SOMKtZ5eZyI0ernb4YT14g',
#    'alias': 'yildiz-bakery-london',
#    'name': 'Yildiz Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GJBgVrALjutW7DqvPQvzZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yildiz-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5641588, 'longitude': -0.1350042},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '45 Junction Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N19 5QU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Junction Road',
#      'London N19 5QU',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5712.870058178992},
#   {'id': 'Xll3M26qDVQFPVF9rmERZw',
#    'alias': 'ole-and-steen-london-4',
#    'name': 'Ole & Steen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/S_657Xvx5eEDhBLcndKO9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ole-and-steen-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.517686, 'longitude': -0.13121},
#    'transactions': [],
#    'location': {'address1': '1 Bedford Avenue',
#     'address2': 'Unit 4',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC1B 3AU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Bedford Avenue',
#      'Unit 4',
#      'London WC1B 3AU',
#      'United Kingdom']},
#    'phone': '+442039484888',
#    'display_phone': '+44 20 3948 4888',
#    'distance': 631.4592636929035},
#   {'id': 'zJNI06Y2zZQFh9OBSFCdgQ',
#    'alias': 'sketch-london-2',
#    'name': 'Sketch',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pAEJmqSJX1lh_pLuvjbFww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sketch-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 831,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5127614699071,
#     'longitude': -0.14159163911048},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '9 Conduit Street',
#     'address2': 'Mayfair',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 2XG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Conduit Street',
#      'Mayfair',
#      'London W1S 2XG',
#      'United Kingdom']},
#    'phone': '+442076594500',
#    'display_phone': '+44 20 7659 4500',
#    'distance': 390.09161644125044},
#   {'id': 'Wv1Zlca4NTkgFVjKgEJyog',
#    'alias': 'poilane-london',
#    'name': 'Poilane',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MxEA4XTmPnw2OAaRPCqi7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/poilane-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.492054852899, 'longitude': -0.1597783672174},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '39 Cadogan Gardens',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 2TB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39 Cadogan Gardens',
#      'London SW3 2TB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2838.7103460697786},
#   {'id': '3jsAS_hDfDu7XKTQx5e8OA',
#    'alias': 'manuels-bakery-london-3',
#    'name': "Manuel's Bakery",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0Zlnw-O8sjPIyVei1IkjRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/manuels-bakery-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.442787, 'longitude': -0.188584},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '491 Garratt Lane',
#     'address2': 'Wandsworth',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW18 4SW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['491 Garratt Lane',
#      'Wandsworth',
#      'London SW18 4SW',
#      'United Kingdom']},
#    'phone': '+442089446846',
#    'display_phone': '+44 20 8944 6846',
#    'distance': 8601.218956116843},
#   {'id': 'e5jPAqpCcIAsTtasUN5h2g',
#    'alias': 'the-wolseley-london',
#    'name': 'The Wolseley',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T9xpXsz-az88-l0Ko_KLpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wolseley-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 553,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.507617, 'longitude': -0.141012},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '160 Picadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 9EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['160 Picadilly', 'London W1J 9EB', 'United Kingdom']},
#    'phone': '+442074996996',
#    'display_phone': '+44 20 7499 6996',
#    'distance': 677.6098617325135},
#   {'id': '_S-eQiUsS9ye2ZedB8JqcA',
#    'alias': 'blackbird-bakery-london-7',
#    'name': 'Blackbird Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ETBl3Fo_Ij-sL7FMQNIWWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blackbird-bakery-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4735603549998, 'longitude': -0.057451},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "134 Queen's Rd",
#     'address2': 'Peckham',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE15 2ND',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["134 Queen's Rd",
#      'Peckham',
#      'London SE15 2ND',
#      'United Kingdom']},
#    'phone': '+442077327711',
#    'display_phone': '+44 20 7732 7711',
#    'distance': 6972.159088348238},
#   {'id': 'Q-f511k1hYDIKfKIpC_HIw',
#    'alias': 'fabrique-bakery-london-4',
#    'name': 'Fabrique Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5Qq5T9LiFK91ag7ftRlFWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fabrique-bakery-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5134638236347,
#     'longitude': -0.12840236007971},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8 Earlham Street',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9RY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Earlham Street',
#      'Covent Garden',
#      'London WC2H 9RY',
#      'United Kingdom']},
#    'phone': '+442072401392',
#    'display_phone': '+44 20 7240 1392',
#    'distance': 527.3502509023187},
#   {'id': '6NIJqOFjLUPXnGaJbxW3lA',
#    'alias': 'l-eto-london-2',
#    'name': "L'ETO",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wPsMI8cgIW_5JjqdEcUhgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-eto-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.496624, 'longitude': -0.1688603},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '243 Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['243 Brompton Road', 'London SW3', 'United Kingdom']},
#    'phone': '+442078542860',
#    'display_phone': '+44 20 7854 2860',
#    'distance': 2898.9080858295915},
#   {'id': 'VtLgCcLSEwFBiKPFV6_Mug',
#    'alias': 'balthazar-london',
#    'name': 'Balthazar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jjUdrn07VkCmksfsd6RuPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/balthazar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 176,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512493, 'longitude': -0.1212219},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '4-6 Russell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5HZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4-6 Russell Street',
#      'London WC2B 5HZ',
#      'United Kingdom']},
#    'phone': '+442033011155',
#    'display_phone': '+44 20 3301 1155',
#    'distance': 1017.1328446810884},
#   {'id': 'hTHHVsW9UqQYlSnl3_vzwA',
#    'alias': 'ole-and-steen-london-3',
#    'name': 'Ole & Steen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NMTm0bFEaq_IAVrcV81f2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ole-and-steen-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51594, 'longitude': -0.15067},
#    'transactions': [],
#    'location': {'address1': 'Unit 1',
#     'address2': '71-73 Wigmore Street',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1U 1QA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 1',
#      '71-73 Wigmore Street',
#      'London W1U 1QA',
#      'United Kingdom']},
#    'phone': '+442039484000',
#    'display_phone': '+44 20 3948 4000',
#    'distance': 1071.5354835474461},
#   {'id': 'iXVq9PcCT-a34FzaXbUagA',
#    'alias': 'scooter-caffè-london-2',
#    'name': 'Scooter Caffè',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/x9HNw_Kud2pJil8Zv5_8oA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scooter-caff%C3%A8-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.500341224864,
#     'longitude': -0.11381534473676},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '132 Lower Marsh',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7AE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['132 Lower Marsh',
#      'London SE1 7AE',
#      'United Kingdom']},
#    'phone': '+442076201421',
#    'display_phone': '+44 20 7620 1421',
#    'distance': 2068.3940056684514},
#   {'id': 'NepoH95B72aOjj02r48ZWg',
#    'alias': 'beverly-hills-bakery-london',
#    'name': 'Beverly Hills Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qwZcvVgKkMVkBVzmqa-j5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beverly-hills-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.542276, 'longitude': -0.160988},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '77e King Henrys Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 3QU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['77e King Henrys Road',
#      'London NW3 3QU',
#      'United Kingdom']},
#    'phone': '+442075860070',
#    'display_phone': '+44 20 7586 0070',
#    'distance': 3663.095421068915},
#   {'id': 'DzfBbOXoqpZcl07lIPH83g',
#    'alias': 'sprinkalicious-bakery-london',
#    'name': 'Sprinkalicious Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2tE9KkcHRv5oCI11XXQw1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sprinkalicious-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'organic_stores', 'title': 'Organic Stores'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5417218, 'longitude': -0.2236863},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': None,
#     'address2': 'Brent',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW10 3EH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Brent', 'London NW10 3EH', 'United Kingdom']},
#    'phone': '+447562982334',
#    'display_phone': '+44 7562 982334',
#    'distance': 6866.6569699072},
#   {'id': 'C3u5fCnxUb7TpFMr6ctqcQ',
#    'alias': 'stolle-london',
#    'name': 'Stolle',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DgEdS8gvEIy-yACXGdfxIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stolle-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.538119, 'longitude': -0.144256},
#    'transactions': [],
#    'location': {'address1': '47 Parkway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 7PN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Parkway', 'London NW1 7PN', 'United Kingdom']},
#    'phone': '+442074822299',
#    'display_phone': '+44 20 7482 2299',
#    'distance': 2860.6608671966596},
#   {'id': 'mpgdKEzO5eDllOEZpKyL3A',
#    'alias': 'maison-ruget-london',
#    'name': 'Maison Ruget',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Np0PMp2TkajFyfzhmq7uEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maison-ruget-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5148914, 'longitude': -0.2042632},
#    'transactions': [],
#    'location': {'address1': '148 Portobello Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W11 2DZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['148 Portobello Road',
#      'London W11 2DZ',
#      'United Kingdom']},
#    'phone': '+442072211000',
#    'display_phone': '+44 20 7221 1000',
#    'distance': 4733.123950874524},
#   {'id': 'UhXQ3C0ixl8BukWDAR-cqg',
#    'alias': 'lisboa-patisserie-london',
#    'name': 'Lisboa Patisserie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MHk4pcW6eU8Gm_oU-pSeGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lisboa-patisserie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5224017, 'longitude': -0.2074916},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '57 Golborne Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W10 5NR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57 Golborne Road',
#      'London W10 5NR',
#      'United Kingdom']},
#    'phone': '+442089685242',
#    'display_phone': '+44 20 8968 5242',
#    'distance': 5062.825558024065},
#   {'id': 'G1aPOo0NS5srqfY5p2zIuw',
#    'alias': 'kowloon-london',
#    'name': 'Kowloon',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rlZ3lqboigiYfrjPCEcIOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kowloon-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5116324, 'longitude': -0.1318569},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '21-22 Gerrard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6JH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21-22 Gerrard Street',
#      'London W1D 6JH',
#      'United Kingdom']},
#    'phone': '+442074371694',
#    'display_phone': '+44 20 7437 1694',
#    'distance': 314.5818341403556},
#   {'id': 'GWeEuO9SvFKldRJBVJFBcw',
#    'alias': 'le-cordon-bleu-london-3',
#    'name': 'Le Cordon Bleu',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4F6VrTrPduCVRwiTQUWVmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-cordon-bleu-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5189056, 'longitude': -0.1237716},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '15 Bloomsbury Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1A 2LS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Bloomsbury Square',
#      'London WC1A 2LS',
#      'United Kingdom']},
#    'phone': '+442074003900',
#    'display_phone': '+44 20 7400 3900',
#    'distance': 1096.4929426913645},
#   {'id': 'sw6_GGspr2RbgAsaOnSz_g',
#    'alias': 'better-health-bakery-london',
#    'name': 'Better Health Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Iy1YAwLP10fy-nDVJVMHjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/better-health-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5372843256428,
#     'longitude': -0.0752527266740799},
#    'transactions': [],
#    'location': {'address1': '13 Stean St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 4ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Stean St', 'London E8 4ED', 'United Kingdom']},
#    'phone': '+442072549103',
#    'display_phone': '+44 20 7254 9103',
#    'distance': 5002.714322284882},
#   {'id': 'pSUwN4KXpsnpifV8Rh8xIQ',
#    'alias': 'ms-cupcake-london',
#    'name': 'Ms. Cupcake',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wM6Bw94Ctzg66GC_cOlfRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ms-cupcake-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 56,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4617347, 'longitude': -0.1132291},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '408 Coldharbour Lane',
#     'address2': 'Brixton',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 8LF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['408 Coldharbour Lane',
#      'Brixton',
#      'London SW9 8LF',
#      'United Kingdom']},
#    'phone': '+442030868933',
#    'display_phone': '+44 20 3086 8933',
#    'distance': 5896.01281424632},
#   {'id': 'BD2h6G18Tb8CoK6SmLfJfg',
#    'alias': 'bake-london',
#    'name': 'Bake',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vUTHUQLU00fwUOJM6pm_qg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bake-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.51081, 'longitude': -0.1319},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '9 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6PF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Wardour Street',
#      'London W1D 6PF',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 361.6930212250562},
#   {'id': 'BTDkYiXZs78lDkTPcv8NAA',
#    'alias': 'jane-asher-party-cakes-and-sugarcraft-london',
#    'name': 'Jane Asher Party Cakes & Sugarcraft',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/R8f35tWsI4YadgQiSztXGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jane-asher-party-cakes-and-sugarcraft-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.490707, 'longitude': -0.166896},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '22-24 Cale Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 3QU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22-24 Cale Street',
#      'London SW3 3QU',
#      'United Kingdom']},
#    'phone': '+442075846177',
#    'display_phone': '+44 20 7584 6177',
#    'distance': 3262.3460186013963},
#   {'id': 'DAE3fIusVTUGt9PDwPlelg',
#    'alias': 'exmouth-coffee-company-london',
#    'name': 'Exmouth Coffee Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0yrsGXNRm5roKhOo_8VUiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/exmouth-coffee-company-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 81,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.515994, 'longitude': -0.070496},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '83 Whitechapel High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 7QX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Whitechapel High Street',
#      'London E1 7QX',
#      'United Kingdom']},
#    'phone': '+442073771010',
#    'display_phone': '+44 20 7377 1010',
#    'distance': 4553.663911477298},
#   {'id': 'qcOvjwgr06iWxfuqwiln1w',
#    'alias': 'the-lebanese-bakery-london-2',
#    'name': 'The lebanese bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SCacrcOqmGhnE_iAX48VeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lebanese-bakery-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5135968, 'longitude': -0.1203767},
#    'transactions': [],
#    'location': {'address1': '34-43 Russell Street',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['34-43 Russell Street',
#      'Covent Garden',
#      'London WC2B 5HA',
#      'United Kingdom']},
#    'phone': '+442038839033',
#    'display_phone': '+44 20 3883 9033',
#    'distance': 1081.3976391155386},
#   {'id': '5_0GHVzaA2tgzHSvFt5idw',
#    'alias': 'ladurée-london-12',
#    'name': 'Ladurée',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GkoHmWAPtVH8e9cQqztaJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ladur%C3%A9e-london-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 92,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51184286271,
#     'longitude': -0.123133037598674},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1 The Market',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 8RA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 The Market',
#      'Covent Garden',
#      'London WC2E 8RA',
#      'United Kingdom']},
#    'phone': '+442072400706',
#    'display_phone': '+44 20 7240 0706',
#    'distance': 894.1956882105256},
#   {'id': 'W7DpFG8AbfLi516fIvgdDg',
#    'alias': 'abbey-cafe-london',
#    'name': 'Abbey Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UedDW_RDdKobWFYeQBagGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/abbey-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.531848626266,
#     'longitude': -0.18065861355395},
#    'transactions': [],
#    'location': {'address1': '3 Nugent Terrace',
#     'address2': "St. John's Wood",
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 9QB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Nugent Terrace',
#      "St. John's Wood",
#      'London NW8 9QB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3746.3652871577324},
#   {'id': 'qx3hMD0wjT_HIcaSLRg7DA',
#    'alias': 'damascene-bakery-london',
#    'name': 'Damascene bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nAtKlkDKLMalxyRnJ01JJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/damascene-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5061034536275,
#     'longitude': -0.229608815215123},
#    'transactions': [],
#    'location': {'address1': '264 Uxbridge Road',
#     'address2': 'Shepherds Bush',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W12 7JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['264 Uxbridge Road',
#      'Shepherds Bush',
#      'London W12 7JA',
#      'United Kingdom']},
#    'phone': '+442087432069',
#    'display_phone': '+44 20 8743 2069',
#    'distance': 6524.435557983179},
#   {'id': 'qQjPCOxuYvS3FF1-nuRU1g',
#    'alias': 'oree-london-2',
#    'name': 'Oree',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FUy-bW1-xAsnEDoVEjN9PQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oree-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.500555223517,
#     'longitude': -0.194074250757694},
#    'transactions': [],
#    'location': {'address1': '147 Kensington High Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W8 6SU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['147 Kensington High Street',
#      'London W8 6SU',
#      'United Kingdom']},
#    'phone': '+442038837568',
#    'display_phone': '+44 20 3883 7568',
#    'distance': 4247.849629759562},
#   {'id': 'klqP4NUFEl9kA6DIyRHpjA',
#    'alias': 'little-bread-pedlar-london',
#    'name': 'Little Bread Pedlar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/c8tHh4TWUFb98oD65Gfing/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-bread-pedlar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4955192, 'longitude': -0.0692471},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 5',
#     'address2': 'Dockley Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE16 3SF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 5',
#      'Dockley Road',
#      'London SE16 3SF',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5002.583314102826},
#   {'id': 'SKs3Iv0rVUelPACz1jkXnw',
#    'alias': 'sally-clarke-shop-london',
#    'name': 'Sally Clarke Shop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/t9BaIpjcdWZGypCM40FxhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sally-clarke-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5068135, 'longitude': -0.1960083},
#    'transactions': [],
#    'location': {'address1': '1 Campden Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 7EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Campden Street',
#      'London W8 7EP',
#      'United Kingdom']},
#    'phone': '+442072292190',
#    'display_phone': '+44 20 7229 2190',
#    'distance': 4209.560102081266},
#   {'id': 'I0sKyehdq3iKZ6GI5K5Gag',
#    'alias': 'caffé-concerto-london-8',
#    'name': 'Caffé Concerto',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/p8x4ybyEIPwQUQT8ep8X5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caff%C3%A9-concerto-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.509699, 'longitude': -0.136678},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '79-81 Regent Street',
#     'address2': 'Piccadilly',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 4EG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['79-81 Regent Street',
#      'Piccadilly',
#      'London W1B 4EG',
#      'United Kingdom']},
#    'phone': '+442074390090',
#    'display_phone': '+44 20 7439 0090',
#    'distance': 345.7304354390102},
#   {'id': 'JqjoGvzDcn-d4RKIw8m47g',
#    'alias': 'patisserie-patchi-london',
#    'name': 'Patisserie Patchi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vQ43Vj4EZbwuXhBmoZOq2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-patchi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5254057143973,
#     'longitude': -0.259115990182637},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '28 Abbey Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW10 7SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28 Abbey Rd', 'London NW10 7SB', 'United Kingdom']},
#    'phone': '+442089613443',
#    'display_phone': '+44 20 8961 3443',
#    'distance': 8635.487622040082},
#   {'id': '4X7LLU3cNixJNUUlfBZXew',
#    'alias': 'sweet-joy-london',
#    'name': 'Sweet Joy',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sw27LM8NTyZ7dYtTxMwHUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweet-joy-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.50643, 'longitude': -0.12721},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': '',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['London', 'United Kingdom']},
#    'phone': '+442277343888',
#    'display_phone': '+44 22 7734 3888',
#    'distance': 3382.5119233941423},
#   {'id': 'ztuEuIDjVTJMklB2OP3rpg',
#    'alias': 'ty-seven-dials-timberyard-london-2',
#    'name': 'TY Seven Dials - Timberyard',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Gr5lHKB84DjJGw8ESo5I6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ty-seven-dials-timberyard-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 138,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5128577362728,
#     'longitude': -0.127308054907987},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "7 Upper St Martin's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["7 Upper St Martin's Lane",
#      'London WC2H 9DL',
#      'United Kingdom']},
#    'phone': '+442032172009',
#    'display_phone': '+44 20 3217 2009',
#    'distance': 598.4373905869091},
#   {'id': 'uwQVCV7lXyHM2uvwKei-Dw',
#    'alias': 'konditor-and-cook-london-2',
#    'name': 'Konditor & Cook',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ebMM9yTvaxjR-k9wx_dwdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/konditor-and-cook-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5130832, 'longitude': -0.0936692},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9 Bow Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4M 9EB',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ['9 Bow Lane', 'London EC4M 9EB', 'United Kingdom']},
#    'phone': '+442076333333',
#    'display_phone': '+44 20 7633 3333',
#    'distance': 2925.4952035964807},
#   {'id': 'v15QYkGuOjhdqDV60r08QQ',
#    'alias': 'bonne-bouche-catering-london-4',
#    'name': 'Bonne Bouche Catering',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0w3EM9tKAIWkM6CBFQd33Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bonne-bouche-catering-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5166095, 'longitude': -0.1734508},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '129 Praed Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['129 Praed Street',
#      'London W2 1RL',
#      'United Kingdom']},
#    'phone': '+442077245784',
#    'display_phone': '+44 20 7724 5784',
#    'distance': 2632.8242264652868},
#   {'id': '1iZkMMh1PZnCjQhJLivG3Q',
#    'alias': 'carmelli-london',
#    'name': 'Carmelli',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/M7o8leBNP8ttnhOP8rHOcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carmelli-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5739863, 'longitude': -0.2007461},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '126-128 Golders Green Road',
#     'address2': '',
#     'address3': 'London',
#     'city': 'London',
#     'zip_code': 'NW11 8HB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['126-128 Golders Green Road',
#      'London',
#      'London NW11 8HB',
#      'United Kingdom']},
#    'phone': '+442084552074',
#    'display_phone': '+44 20 8455 2074',
#    'distance': 8150.379306826664},
#   {'id': 'O-a4dCQH0ylxYt8pnA4byQ',
#    'alias': 'patisserie-valerie-london-48',
#    'name': 'Patisserie Valerie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/x4I-J-10Q0AYl4QRWLbuMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-valerie-london-48?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5105155, 'longitude': -0.1244745},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '15 Bedford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2 9HE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Bedford Street',
#      'London WC2 9HE',
#      'United Kingdom']},
#    'phone': '+442073796428',
#    'display_phone': '+44 20 7379 6428',
#    'distance': 828.5788819219546},
#   {'id': 'xQ_xwD6gH9A-RmtUCpIviQ',
#    'alias': 'el-and-n-london-4',
#    'name': 'EL&N',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ugzEeY0dkcIrM4TimBgYxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-and-n-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5067884273363,
#     'longitude': -0.151887824614013},
#    'transactions': [],
#    'location': {'address1': '48 Park Lane',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1K 1PR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['48 Park Lane', 'London W1K 1PR', 'United Kingdom']},
#    'phone': '+442074918880',
#    'display_phone': '+44 20 7491 8880',
#    'distance': 1291.4402456225503},
#   {'id': 'Lfn3XlKavDgKUKb19OaClw',
#    'alias': 'luminary-bakery-london-2',
#    'name': 'Luminary Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Chhp3eF21k_Kya9WmJ-3Vw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luminary-bakery-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5555542, 'longitude': -0.0824096018524187},
#    'transactions': [],
#    'location': {'address1': '71 Allen Road',
#     'address2': '',
#     'address3': 'Stoke Newington',
#     'city': 'London',
#     'zip_code': 'N16 8RY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['71 Allen Road',
#      'Stoke Newington',
#      'London N16 8RY',
#      'United Kingdom']},
#    'phone': '+442076869779',
#    'display_phone': '+44 20 7686 9779',
#    'distance': 6023.3588423532},
#   {'id': '1C0u7SMTRLQePx_o-Ic0cw',
#    'alias': 'pret-a-manger-london-39',
#    'name': 'Pret A Manger',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oLbjjolP-1FTqYEoiQapag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pret-a-manger-london-39?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5115768, 'longitude': -0.127285},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "77-78 St Martin's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["77-78 St Martin's Lane",
#      'London WC2N 4AA',
#      'United Kingdom']},
#    'phone': '+442079325213',
#    'display_phone': '+44 20 7932 5213',
#    'distance': 616.1437265710483}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                                      Restaurant                  Type Price  \
# 0                                          Paul              Bakeries    ££
# 1                          Wonderful Patisserie  Patisserie/Cake Shop    ££
# 2                               Brigit's Bakery              Bakeries    ££
# 3  Fortnum and Mason: Diamond Jubilee Tea Salon              Desserts  ££££
# 4                               The Watch House          Coffee & Tea    ££
#
#   Rating                Address        Lat       Lng  \
# 0    4.5   185 Earls Court Road  51.492253 -0.192894
# 1    3.5      45 Gerrard Street  51.511969 -0.130143
# 2      4      6-7 Chandos Place  51.510089 -0.124540
# 3      4              4th Floor  51.508707 -0.138279
# 4    4.5  199 Bermondsey Street  51.498046 -0.081050
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/paul-london-46?adjust...  VQCzUGBY63yVE-FxLg6vqg
# 1  https://www.yelp.com/biz/wonderful-patisserie-...  VZ_1ATiJ5j4uTHvGHr7JNw
# 2  https://www.yelp.com/biz/brigits-bakery-london...  tH_2560cbjme-hFBFVj8cQ
# 3  https://www.yelp.com/biz/fortnum-and-mason-dia...  GSbQscE52ZfK43ykA6vLbg
# 4  https://www.yelp.com/biz/the-watch-house-londo...  -EPJuMu8Qbr5azjHu_QOtg

# %%
#4th set of 50 records 151-200
lndr_params4 = {"term":"bakery","location":"London","limit":50,"offset":151}
lndr_response4 = requests.get(search_api_url, headers=headers, params=lndr_params4)
lndr4 = lndr_response4.json()
display(lndr4)
#print(lndr_response4.url)
#print(lndr_response4.status_code)
# Out:
# {'businesses': [{'id': 'zn20kanWz2YApVHfgereMg',
#    'alias': 'di-lieto-bakery-london',
#    'name': 'Di Lieto Bakery',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/di-lieto-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4773216, 'longitude': -0.1231037},
#    'transactions': [],
#    'location': {'address1': 'South Lambeth Road',
#     'address2': '175 South Lambeth road',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW8 1XW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['South Lambeth Road',
#      '175 South Lambeth road',
#      'London SW8 1XW',
#      'United Kingdom']},
#    'phone': '+442077351997',
#    'display_phone': '+44 20 7735 1997',
#    'distance': 4047.952764181566},
#   {'id': '3PeQF-J_j89dcLcC0P5o4A',
#    'alias': 'gails-bakery-bloomsbury-london-3',
#    'name': "GAIL's Bakery - Bloomsbury",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/POqVbFU_O0cRoPrHezyypA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-bloomsbury-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5188693, 'longitude': -0.131913},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '11-13 Bayley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3HD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11-13 Bayley Street',
#      'London WC1B 3HD',
#      'United Kingdom']},
#    'phone': '+442073232356',
#    'display_phone': '+44 20 7323 2356',
#    'distance': 725.3824302360697},
#   {'id': 'TZfwIvVAFC0vXxGJ37srjQ',
#    'alias': 'p-j-bakers-london',
#    'name': 'P J Bakers',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1aGB9fnU2XdIcPoBd8av-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/p-j-bakers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.505391, 'longitude': -0.057917},
#    'transactions': [],
#    'location': {'address1': '93 Wapping Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1W 2RW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['93 Wapping Lane',
#      'London E1W 2RW',
#      'United Kingdom']},
#    'phone': '+442074811501',
#    'display_phone': '+44 20 7481 1501',
#    'distance': 5472.203930996104},
#   {'id': '-3USXGHx6Xcpwq-ueoED7g',
#    'alias': 'melissa-london',
#    'name': 'Melissa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rrB0GD2x4OscmixeP5Flzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/melissa-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5367341, 'longitude': -0.1403202},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '88 Camden High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 0LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['88 Camden High Street',
#      'London NW1 0LT',
#      'United Kingdom']},
#    'phone': '+442073830559',
#    'display_phone': '+44 20 7383 0559',
#    'distance': 2674.4963881658255},
#   {'id': 'y8xX3BDj1bf7-wc4Q9Atvg',
#    'alias': 'the-monocle-cafe-london',
#    'name': 'The Monocle Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WVPzYgrKif_v7M9hkSshJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-monocle-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 69,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5188109085709,
#     'longitude': -0.154666668198166},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '18 Chiltern Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 7QA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Chiltern Street',
#      'London W1U 7QA',
#      'United Kingdom']},
#    'phone': '+442071352040',
#    'display_phone': '+44 20 7135 2040',
#    'distance': 1455.2587544542089},
#   {'id': '02ybxBpQiX0wrR8sez3Z5A',
#    'alias': 'miss-poppy-cakes-london',
#    'name': 'Miss Poppy Cakes',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uo1USWcj76PO1kUwMOFHug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/miss-poppy-cakes-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.541263, 'longitude': -0.149738},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '4 Chalk Farm Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Chalk Farm Road',
#      'London NW1 8AA',
#      'United Kingdom']},
#    'phone': '+447564135416',
#    'display_phone': '+44 7564 135416',
#    'distance': 3309.6957536840155},
#   {'id': 'Qm8ZjdS4Cne9g4-FFFF0FA',
#    'alias': 'oliviers-bakery-london',
#    'name': "Olivier's Bakery",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HPJX8w_twJWtQYJc7t3AoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oliviers-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5052993, 'longitude': -0.0910801},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8 Stoney Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Stoney Street', 'London SE1', 'United Kingdom']},
#    'phone': '+442072371140',
#    'display_phone': '+44 20 7237 1140',
#    'distance': 3216.764481924927},
#   {'id': 'xqpUr61KFa1Xx721-E6l_A',
#    'alias': 'kipferl-london-6',
#    'name': 'Kipferl',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CUoYGTlW1CYS-nJ5vAUGPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kipferl-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'austrian', 'title': 'Austrian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.535247538411,
#     'longitude': -0.10339315152949},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Camden Passage',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Camden Passage',
#      'London N1 8ED',
#      'United Kingdom']},
#    'phone': '+442077041555',
#    'display_phone': '+44 20 7704 1555',
#    'distance': 3359.4222431551457},
#   {'id': 'zOcwqHpSKnEMonZxrJiM4g',
#    'alias': 'pierre-herme-london-3',
#    'name': 'Pierre Herme',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Nc09C3ZpQuv-nhhCRquS-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pierre-herme-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5134164873925,
#     'longitude': -0.127191884385164},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '38 Monmouth Street',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38 Monmouth Street',
#      'Covent Garden',
#      'London WC2H 9EP',
#      'United Kingdom']},
#    'phone': '+442072408653',
#    'display_phone': '+44 20 7240 8653',
#    'distance': 609.8985619204582},
#   {'id': 'xwWEborkGEjAc2qrvO_TRw',
#    'alias': 'flavourtown-bakery-london-2',
#    'name': 'Flavourtown Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9wlrP4taUpFjcvaWXy1H9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flavourtown-bakery-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4765205080051,
#     'longitude': -0.204111858341822},
#    'transactions': [],
#    'location': {'address1': '777 Fulham Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW6 5HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['777 Fulham Road',
#      'London SW6 5HA',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6210.353673785226},
#   {'id': '--5Snf9tWcJN3LnISWxW8Q',
#    'alias': 'artisan-foods-london',
#    'name': 'Artisan Foods',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OkymFbmep7O70GaI2gmaRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/artisan-foods-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'streetvendors', 'title': 'Street Vendors'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5901742154993,
#     'longitude': -0.0413796441803242},
#    'transactions': [],
#    'location': {'address1': 'Unit 9 Forest Trading Estate',
#     'address2': 'Priestley Way',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E17 6AL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 9 Forest Trading Estate',
#      'Priestley Way',
#      'London E17 6AL',
#      'United Kingdom']},
#    'phone': '+442089858001',
#    'display_phone': '+44 20 8985 8001',
#    'distance': 10803.48274127623},
#   {'id': 'rn70OOQObZ5TxvIahNSl7w',
#    'alias': 'chanteroy-london',
#    'name': 'Chanteroy',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aK36AUi8VjIHMADgKKBzoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chanteroy-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cheese', 'title': 'Cheese Shops'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4450952518046,
#     'longitude': -0.205981699624434},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '233a Wimbledon Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW18 5RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['233a Wimbledon Park Road',
#      'London SW18 5RJ',
#      'United Kingdom']},
#    'phone': '+442088741446',
#    'display_phone': '+44 20 8874 1446',
#    'distance': 8958.445522157237},
#   {'id': 'Lxhbq_b8tbCdji7N4g3hGw',
#    'alias': 'gails-bakery-notting-hill-london-3',
#    'name': "GAIL's Bakery Notting Hill",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6Ka2-zed5l1-eA8_Z0834A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-notting-hill-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.514255658517,
#     'longitude': -0.20344594848854},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '138 Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2DZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['138 Portobello Road',
#      'London W11 2DZ',
#      'United Kingdom']},
#    'phone': '+442077928715',
#    'display_phone': '+44 20 7792 8715',
#    'distance': 4672.97393974897},
#   {'id': 'iztb-Ro3RuGjwqj0LUncow',
#    'alias': 'soderberg-soho-london',
#    'name': 'Soderberg Soho',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5mXIaUYrDa2kpNlQ_C0wZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soderberg-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5146, 'longitude': -0.13565},
#    'transactions': [],
#    'location': {'address1': '36 Berwick Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1F 8RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['36 Berwick Street',
#      'London W1F 8RJ',
#      'United Kingdom']},
#    'phone': '+442072872111',
#    'display_phone': '+44 20 7287 2111',
#    'distance': 197.59127945276856},
#   {'id': '_CNqbC-MnNLwsk48BL-r5A',
#    'alias': 'candy-cakes-london-9',
#    'name': 'Candy Cakes',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/candy-cakes-london-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5052578, 'longitude': -0.0222966},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Tesco Metro',
#     'address2': '15 Cabot Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E14 4QT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Tesco Metro',
#      '15 Cabot Square',
#      'London E14 4QT',
#      'United Kingdom']},
#    'phone': '+442037012780',
#    'display_phone': '+44 20 3701 2780',
#    'distance': 7910.973663710431},
#   {'id': '-PAvIOieAnJH9ZZwZCR2iQ',
#    'alias': 'konditor-and-cook-london',
#    'name': 'Konditor',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hXutxCBTqx-pGZuCpo7cYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/konditor-and-cook-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51969, 'longitude': -0.111929},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "46 Gray's Inn Rd",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1X 8LR',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ["46 Gray's Inn Rd",
#      'London WC1X 8LR',
#      'United Kingdom']},
#    'phone': '+442076333333',
#    'display_phone': '+44 20 7633 3333',
#    'distance': 1828.934181489293},
#   {'id': 'WXdvvDADvJTpDUkU4rkp5Q',
#    'alias': 'le-montmartre-london',
#    'name': 'Le Montmartre',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OA-yqi3jg-0GEF64DmmFag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-montmartre-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5133389, 'longitude': -0.0843126},
#    'transactions': [],
#    'location': {'address1': '59-60 Cornhill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3V 3PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['59-60 Cornhill',
#      'London EC3V 3PD',
#      'United Kingdom']},
#    'phone': '+442079364108',
#    'display_phone': '+44 20 7936 4108',
#    'distance': 3570.584518799582},
#   {'id': 'nAwpCaUpBIneyj1Vg0Zlcw',
#    'alias': 'candy-café-london-2',
#    'name': 'Candy Café',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ALRE1FXqVDY8Q2WmIJye4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/candy-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511873, 'longitude': -0.131473},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '3 Macclesfield Street',
#     'address2': 'Chinatown',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6AU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Macclesfield Street',
#      'Chinatown',
#      'London W1D 6AU',
#      'United Kingdom']},
#    'phone': '+442074344581',
#    'display_phone': '+44 20 7434 4581',
#    'distance': 337.4774111722012},
#   {'id': 'I-WKA8ZUxSE_US2zPjMohA',
#    'alias': 'blackbird-bakery-london',
#    'name': 'Blackbird Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RgeqVA4ZJGl2baE1wCMNoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blackbird-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4526883047826,
#     'longitude': -0.102220709221585},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '208 Railton Road',
#     'address2': 'Herne Hill',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE24 0JT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['208 Railton Road',
#      'Herne Hill',
#      'London SE24 0JT',
#      'United Kingdom']},
#    'phone': '+442070958800',
#    'display_phone': '+44 20 7095 8800',
#    'distance': 7084.292397366785},
#   {'id': 'D21Iu0qiqjvFWVHgs3JyhQ',
#    'alias': 'gails-bakery-belsize-park-london-3',
#    'name': "GAIL's Bakery Belsize Park",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jqcgg0pmWxxIVr0scFJk5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-belsize-park-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5498302, 'longitude': -0.1646677},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '167 Haverstock Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 4QT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['167 Haverstock Hill',
#      'London NW3 4QT',
#      'United Kingdom']},
#    'phone': '+442075864399',
#    'display_phone': '+44 20 7586 4399',
#    'distance': 4567.9706806328195},
#   {'id': '9aTpHJSdyPWwESQ_6pjiaA',
#    'alias': 'comptoir-gourmand-london',
#    'name': 'Comptoir Gourmand',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wmqpJAnX4AHoj5wazcaO-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/comptoir-gourmand-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4988488, 'longitude': -0.0736399},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '98 Druid Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 2HQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['98 Druid Street',
#      'London SE1 2HQ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4584.821643190302},
#   {'id': '__2zhkr5e3ume9h-KfE3EQ',
#    'alias': 'flavourtown-bakery-london',
#    'name': 'Flavourtown Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ahIp1jKvMV7_sWzfXhrHjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flavourtown-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'streetvendors', 'title': 'Street Vendors'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.519156, 'longitude': -0.0768451},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Old Spitalfields Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Old Spitalfields Market',
#      'London E1 6AA',
#      'United Kingdom']},
#    'phone': '+447412590790',
#    'display_phone': '+44 7412 590790',
#    'distance': 4150.170764270031},
#   {'id': 'ZmPuLx41P8x2aYX3_nk7Fg',
#    'alias': 'artisan-gluten-free-bakery-london',
#    'name': 'Artisan Gluten Free Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MLm_ymCb4xALJe0O0rMVvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/artisan-gluten-free-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5410032, 'longitude': -0.1029761},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '167 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 1XU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['167 Upper Street',
#      'London N1 1XU',
#      'United Kingdom']},
#    'phone': '+442073548945',
#    'display_phone': '+44 20 7354 8945',
#    'distance': 3874.9683232693064},
#   {'id': '3kidFQspGuPQN-Ycf1QRRw',
#    'alias': 'tugra-london',
#    'name': 'Tugra',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/32UE18kqTAzRCfCtOLN_Mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tugra-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'turkish', 'title': 'Turkish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.591733, 'longitude': -0.104363},
#    'transactions': [],
#    'location': {'address1': '10 High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N22 6BX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 High Road', 'London N22 6BX', 'United Kingdom']},
#    'phone': '+442083658029',
#    'display_phone': '+44 20 8365 8029',
#    'distance': 9039.955847482328},
#   {'id': '2DPvfVF6vSEaZ5JqDFnXTw',
#    'alias': 'sweetheart-london-2',
#    'name': 'Sweetheart',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_Th_C_WBYuE-upP5DJ8oNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweetheart-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'cupcakes', 'title': 'Cupcakes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5118923302027,
#     'longitude': -0.122435174762825},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 34',
#     'address2': 'The Market',
#     'address3': 'Covent Garden',
#     'city': 'London',
#     'zip_code': 'WC2E 8RE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 34',
#      'The Market',
#      'Covent Garden',
#      'London WC2E 8RE',
#      'United Kingdom']},
#    'phone': '+442072405039',
#    'display_phone': '+44 20 7240 5039',
#    'distance': 941.5093845598345},
#   {'id': '7JupvZDbjjRosgkaqBLKhA',
#    'alias': 'the-pantry-dalston-london',
#    'name': 'The Pantry Dalston',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/U0YZI5d_FVhP2F8c4RhDGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pantry-dalston-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.5492767, 'longitude': -0.0749752},
#    'transactions': [],
#    'location': {'address1': '112 Kingsland High Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E8 2NS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['112 Kingsland High Street',
#      'London E8 2NS',
#      'United Kingdom']},
#    'phone': '+442072545777',
#    'display_phone': '+44 20 7254 5777',
#    'distance': 5849.1610520362465},
#   {'id': 'EwfP3qXpnWP23zvEgwmhoQ',
#    'alias': 'yasar-halim-london',
#    'name': 'Yasar Halim',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-LIE_5IGeKSVvcCpY17faw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yasar-halim-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'importedfood', 'title': 'Imported Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5804495317793,
#     'longitude': -0.0997724885879259},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '386-390 Green Lanes',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N13 5XQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['386-390 Green Lanes',
#      'London N13 5XQ',
#      'United Kingdom']},
#    'phone': '+442083408090',
#    'display_phone': '+44 20 8340 8090',
#    'distance': 7923.732272693916},
#   {'id': 'YTHYs1ISSZwGXrXyFJj7Wg',
#    'alias': 'tesoro-london',
#    'name': 'Tesoro',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/U1HPgGfCs5r0YMU7XwxW2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tesoro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.519399, 'longitude': -0.135317},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '39 Goodge Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 2PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39 Goodge Street',
#      'London W1T 2PX',
#      'United Kingdom']},
#    'phone': '+442076375311',
#    'display_phone': '+44 20 7637 5311',
#    'distance': 730.0940002632292},
#   {'id': 'DY2qHkTlkWB8UVxnaCWj-w',
#    'alias': 'euphorium-bakery-london-6',
#    'name': 'Euphorium Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cz8zy9HMtV9RRobzyZk4HA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/euphorium-bakery-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5365826, 'longitude': -0.1035965},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '79 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 0NU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['79 Upper Street', 'London N1 0NU', 'United Kingdom']},
#    'phone': '+442072888788',
#    'display_phone': '+44 20 7288 8788',
#    'distance': 3460.115806670105},
#   {'id': 'Vc_Pw4jlrak_LlCk8DHBJA',
#    'alias': 'karma-bread-london',
#    'name': 'Karma Bread',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/P7X4DYtbYD1rdiZLlk6R8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/karma-bread-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5544616396241,
#     'longitude': -0.165723802891784},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '13 S End Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 2PT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 S End Road', 'London NW3 2PT', 'United Kingdom']},
#    'phone': '+442074316050',
#    'display_phone': '+44 20 7431 6050',
#    'distance': 5065.927131951486},
#   {'id': 'IWl1Y0eQOZSnYeIDw94svg',
#    'alias': 'monmouth-coffee-london',
#    'name': 'Monmouth Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-eZOw_Lts2a7dWXNYekA_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/monmouth-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 306,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5055383383613,
#     'longitude': -0.0914615294783139},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Park Street',
#     'address2': 'The Borough',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Park Street',
#      'The Borough',
#      'London SE1 9AB',
#      'United Kingdom']},
#    'phone': '+442072323010',
#    'display_phone': '+44 20 7232 3010',
#    'distance': 3184.4018654070014},
#   {'id': 'xNFhS1xibcXnZh6ZRAgeYQ',
#    'alias': 'charbonnel-et-walker-london',
#    'name': 'Charbonnel Et Walker',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qxwR-8deECMXA_M2fpI0Dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/charbonnel-et-walker-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.509162, 'longitude': -0.141354},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'One The Royal Arcade',
#     'address2': '28 Old Bond Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 4BT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['One The Royal Arcade',
#      '28 Old Bond Street',
#      'London W1S 4BT',
#      'United Kingdom']},
#    'phone': '+442074910939',
#    'display_phone': '+44 20 7491 0939',
#    'distance': 554.0406323801665},
#   {'id': 'bCkjiJ6wM3vFBebsu9PtgA',
#    'alias': 'paul-london-15',
#    'name': 'Paul',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zy_E0CLCix71BtVP4AYr0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-london-15?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.519155, 'longitude': -0.156502},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '55 Baker Street',
#     'address2': 'Unit 65',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 8EW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55 Baker Street',
#      'Unit 65',
#      'London W1U 8EW',
#      'United Kingdom']},
#    'phone': '+442074860626',
#    'display_phone': '+44 20 7486 0626',
#    'distance': 1585.892296168721},
#   {'id': 'SjrvHuI--7zJOnkZQur5Ew',
#    'alias': 'ole-and-steen-london-7',
#    'name': 'Ole & Steen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yY2IHeTi7k9ISQ7Di0g1ow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ole-and-steen-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5095617217612,
#     'longitude': -0.221816666730774},
#    'transactions': [],
#    'location': {'address1': 'Unit SU1203',
#     'address2': 'Ariel Way',
#     'address3': 'Shepherds Bush',
#     'city': 'London',
#     'zip_code': 'W12 7HT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit SU1203',
#      'Ariel Way',
#      'Shepherds Bush',
#      'London W12 7HT',
#      'United Kingdom']},
#    'phone': '+442039557450',
#    'display_phone': '+44 20 3955 7450',
#    'distance': 5953.002063630901},
#   {'id': '0T5fEkTQAry6pRmI056nTA',
#    'alias': 'maitre-choux-london',
#    'name': 'Maitre Choux',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Fl6oLvKyCIxXAp71W_X52w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maitre-choux-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4939411, 'longitude': -0.1755375},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '15 Harrington Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3ES',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Harrington Road',
#      'London SW7 3ES',
#      'United Kingdom']},
#    'phone': '+442035834561',
#    'display_phone': '+44 20 3583 4561',
#    'distance': 3452.4998941819867},
#   {'id': 'rqZ9nXfcS1fAs0DY1BrAAA',
#    'alias': 'bad-ass-cakes-london-2',
#    'name': 'Bad Ass Cakes',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hMt_nx6fX9RYzKsWyGUQ6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bad-ass-cakes-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'customcakes', 'title': 'Custom Cakes'},
#     {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'},
#     {'alias': 'cookingclasses', 'title': 'Cooking Classes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4851756, 'longitude': -0.1990207},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 1RB',
#     'country': 'GB',
#     'state': 'XWY',
#     'display_address': ['London SW6 1RB', 'United Kingdom']},
#    'phone': '+447854400459',
#    'display_phone': '+44 7854 400459',
#    'distance': 5340.121514899093},
#   {'id': 'ZStgRS5r_7Dk18JFoIjiRw',
#    'alias': 'gails-bakery-exmouth-market-london',
#    'name': "GAIL's Bakery Exmouth Market",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QLLvChwHnGfaEW7qQrCmWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-exmouth-market-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5259196414871,
#     'longitude': -0.109331067055787},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '33-35 Exmouth Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 4QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['33-35 Exmouth Market',
#      'London EC1R 4QL',
#      'United Kingdom']},
#    'phone': '+442077136550',
#    'display_phone': '+44 20 7713 6550',
#    'distance': 2347.4162813851194},
#   {'id': 'oZFmFK_7utppr5Dqtn7oEw',
#    'alias': 'paul-rhodes-bakery-london',
#    'name': 'Paul Rhodes Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OBSgblMYY_7WlKajiiOsBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-rhodes-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5096498950531,
#     'longitude': -0.194281597508819},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '26 Notting Hill Gate',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 3HY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Notting Hill Gate',
#      'London W11 3HY',
#      'United Kingdom']},
#    'phone': '+442072211440',
#    'display_phone': '+44 20 7221 1440',
#    'distance': 4051.8511445572512},
#   {'id': 'MCiYvaVOu-GkfHj5oRodQw',
#    'alias': 'le-petit-village-london-2',
#    'name': 'Le Petit Village',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Tag25rC5mLkO6l59Uor3Dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-petit-village-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cheese', 'title': 'Cheese Shops'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5392898322453,
#     'longitude': -0.106626814379176},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '142 Liverpool Road',
#     'address2': 'Islington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 1LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['142 Liverpool Road',
#      'Islington',
#      'London N1 1LA',
#      'United Kingdom']},
#    'phone': '+442077005957',
#    'display_phone': '+44 20 7700 5957',
#    'distance': 3573.479910281426},
#   {'id': 'l0aYVluJfwiKmlfbskThzw',
#    'alias': 'whipped-london-london',
#    'name': 'Whipped London',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LxJtzNg4cI96wY7CyKo5yw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/whipped-london-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5149763, 'longitude': -0.122387},
#    'transactions': [],
#    'location': {'address1': '160 Drury Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['160 Drury Lane', 'London WC2H', 'United Kingdom']},
#    'phone': '+442070185525',
#    'display_phone': '+44 20 7018 5525',
#    'distance': 967.1645134663564},
#   {'id': '6DwwLF424xP7VTPNznVTYQ',
#    'alias': 'gails-bakery-st-johns-wood-london-3',
#    'name': "GAIL's Bakery St John's Wood",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5a-7-59lbasf11p0XdO5ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-st-johns-wood-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5336595, 'longitude': -0.171694},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5 Circus Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 6NX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Circus Road', 'London NW8 6NX', 'United Kingdom']},
#    'phone': '+442077220983',
#    'display_phone': '+44 20 7722 0983',
#    'distance': 3390.2048284682287},
#   {'id': 'eDqcRJKUdRt46nld92YyTA',
#    'alias': 'biscuiteers-london-2',
#    'name': 'Biscuiteers',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_kSvmhQwojvsCUR1OLCivg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/biscuiteers-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5155496, 'longitude': -0.2058177},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '194 Kensington Park Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2ES',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['194 Kensington Park Rd',
#      'London W11 2ES',
#      'United Kingdom']},
#    'phone': '+442077278096',
#    'display_phone': '+44 20 7727 8096',
#    'distance': 4843.771849571174},
#   {'id': '91TQLypsN7trt-EyX8TgBQ',
#    'alias': 'daisy-green-london-2',
#    'name': 'Daisy Green',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ythY0ZkbjY3cYODreg4hLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daisy-green-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5148104, 'longitude': -0.1579352},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Seymour Street',
#     'address2': 'Marble Arch',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Seymour Street',
#      'Marble Arch',
#      'London W1H 7HX',
#      'United Kingdom']},
#    'phone': '+442077233301',
#    'display_phone': '+44 20 7723 3301',
#    'distance': 1536.7313570216975},
#   {'id': 'cEqChFjsQajetqse5yRDNw',
#    'alias': 'the-hummingbird-bakery-london-5',
#    'name': 'The Hummingbird Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/n4KkBbTgSJAJAUUWEcpKPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hummingbird-bakery-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5178570645, 'longitude': -0.0767323002219},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Frying Pan Alley',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 7HS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Frying Pan Alley',
#      'London E1 7HS',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4135.958259680674},
#   {'id': '8tsGkeT6Z9EhT8UvBzVtWw',
#    'alias': 'rinkoff-bakeries-london',
#    'name': 'Rinkoff Bakeries',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2xa-EAj9vCWoIrLWUFOXeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rinkoff-bakeries-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5220242, 'longitude': -0.0644858},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '79 Vallance Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 5BS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['79 Vallance Road',
#      'London E1 5BS',
#      'United Kingdom']},
#    'phone': '+442072476228',
#    'display_phone': '+44 20 7247 6228',
#    'distance': 5049.735578986961},
#   {'id': 'Z3dr4as9zDncGnaCtqnntQ',
#    'alias': 'patisserie-valerie-london-7',
#    'name': 'Patisserie Valerie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GeZus7r-mVclADzIcGbopg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-valerie-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5191096196678,
#     'longitude': -0.15177361600921},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '105 Marylebone High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 4RS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['105 Marylebone High Road',
#      'London W1U 4RS',
#      'United Kingdom']},
#    'phone': '+442079356240',
#    'display_phone': '+44 20 7935 6240',
#    'distance': 1297.9635922946884},
#   {'id': '94cWQZLiw7AXUPGFwHe2lA',
#    'alias': 'diwan-damas-london-2',
#    'name': 'Diwan Damas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hem3G3HZYAImM-NvXdNvVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/diwan-damas-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'chocolate', 'title': 'Chocolatiers & Shops'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.516528, 'longitude': -0.165439},
#    'transactions': [],
#    'location': {'address1': '121b Edgware Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 2HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['121b Edgware Road',
#      'London W2 2HX',
#      'United Kingdom']},
#    'phone': '+442071801972',
#    'display_phone': '+44 20 7180 1972',
#    'distance': 2081.085233285256},
#   {'id': 'ZUIJ8U6GU6TLx29lcwIyvg',
#    'alias': 'urban-tea-rooms-london',
#    'name': 'Urban Tea Rooms',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XMrZyD4PVAmkdBbkb6Evlg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/urban-tea-rooms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512947, 'longitude': -0.139558},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '19 Kingly Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5PY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Kingly Street',
#      'London W1B 5PY',
#      'United Kingdom']},
#    'phone': '+442074343767',
#    'display_phone': '+44 20 7434 3767',
#    'distance': 248.67741461823445},
#   {'id': 'pCuFgwtpg_7nXv94r9DObg',
#    'alias': 'granier-bakery-london-2',
#    'name': 'Granier Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VJFNf1_0A14dunC4v4Kgrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/granier-bakery-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5907485426882,
#     'longitude': -0.103420352592472},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '4 High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N22 6BX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 High Road', 'London N22 6BX', 'United Kingdom']},
#    'phone': '+442088885889',
#    'display_phone': '+44 20 8888 5889',
#    'distance': 8950.817522466883},
#   {'id': 'FeRP9CIb0TLDkDv9fbLe7g',
#    'alias': 'quartiers-london',
#    'name': 'Quartiers',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XJFOVCtrSQSKsa9IUFJFRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/quartiers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4920492171925,
#     'longitude': -0.140656046569347},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '47 Warwick Way',
#     'address2': 'Pimlico',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1QS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Warwick Way',
#      'Pimlico',
#      'London SW1V 1QS',
#      'United Kingdom']},
#    'phone': '+442036026165',
#    'display_phone': '+44 20 3602 6165',
#    'distance': 2334.1131855610943}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#                    Restaurant      Type Price Rating                Address  \
# 0             Di Lieto Bakery  Bakeries                  South Lambeth Road
# 1  GAIL's Bakery - Bloomsbury  Bakeries     £    4.5    11-13 Bayley Street
# 2                  P J Bakers  Bakeries                     93 Wapping Lane
# 3                     Melissa  Bakeries     £      4  88 Camden High Street
# 4            The Monocle Cafe     Cafes     £      4     18 Chiltern Street
#
#          Lat       Lng                                                url  \
# 0  51.477322 -0.123104
# 1  51.518869 -0.131913  https://www.yelp.com/biz/gails-bakery-bloomsbu...
# 2  51.505391 -0.057917
# 3  51.536734 -0.140320  https://www.yelp.com/biz/melissa-london?adjust...
# 4  51.518811 -0.154667  https://www.yelp.com/biz/the-monocle-cafe-lond...
#
#                        ID
# 0
# 1  3PeQF-J_j89dcLcC0P5o4A
# 2
# 3  -3USXGHx6Xcpwq-ueoED7g
# 4  y8xX3BDj1bf7-wc4Q9Atvg

# %%
london_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
london_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_restaurants_df = london_restaurants_df[column_order]
london_restaurants_df = london_restaurants_df.sort_values(["Type"], ascending=True)
london_restaurants_df = london_restaurants_df.reset_index(drop=True)
london_restaurants_df
# Out:
#                        Restaurant                  Type Rating Price  \
# 0                        Carmelli                Bagels      4     £
# 1                       Quartiers              Bakeries      4    ££
# 2           Bonne Bouche Catering              Bakeries    3.5     £
# 3                   Baker & Spice              Bakeries      4    ££
# 4                   Raab's Bakery              Bakeries      5     £
# 5                        Cake Boy              Bakeries    4.5   £££
# 6                          Popina              Bakeries
# 7                 Di Lieto Bakery              Bakeries
# 8           The Wild Goose Bakery              Bakeries    4.5  ££££
# 9                   Ben's Cookies              Bakeries    4.5     £
# 10     GAIL's Bakery - Bloomsbury              Bakeries    4.5     £
# 11              Kastner and Ovens              Bakeries    4.5     £
# 12                        Poilane              Bakeries      4    ££
# 13         The Hummingbird Bakery              Bakeries    3.5    ££
# 14                     P J Bakers              Bakeries
# 15                 Akdeniz Bakery              Bakeries    4.5    ££
# 16        GAIL's Bakery Hampstead              Bakeries    4.5    ££
# 17               Delice de France              Bakeries    2.5    ££
# 18                Luminary Bakery              Bakeries
# 19                       Fabrique              Bakeries
# 20             Upper Fleet Bakery              Bakeries
# 21              Maroush Bakehouse              Bakeries    4.5    ££
# 22                        Melissa              Bakeries      4     £
# 23         Old Post Office Bakery              Bakeries    4.5    ££
# 24                   E5 Bakehouse              Bakeries    4.5    ££
# 25                 Rainbow Bakery              Bakeries      5     £
# 26                Rubys of London              Bakeries      5    ££
# 27                Konditor & Cook              Bakeries    4.5    ££
# 28             Hummingbird Bakery              Bakeries      4    ££
# 29           Beverly Hills Bakery              Bakeries    4.5    ££
# ..                            ...                   ...    ...   ...
# 170                   Ms. Cupcake              Desserts    4.5     £
# 171  Crosstown Doughnuts & Coffee                Donuts      4    ££
# 172                   Kooky Bakes        Farmers Market    4.5    ££
# 173                   La Gauloise             Fast Food
# 174                        Sketch                French      4   £££
# 175                Le Coq Epicier                French
# 176                     Balthazar                French      4   £££
# 177                       Aubaine                French    3.5    ££
# 178                 Brioche Dorée                French
# 179    Artisan Gluten Free Bakery           Gluten-Free      4     £
# 180                   Yasar Halim               Grocery      4     £
# 181                 Honey & Spice               Grocery
# 182                        Princi               Italian      4    ££
# 183                       Laduree              Macarons    4.5   £££
# 184                   Biscuiteers  Patisserie/Cake Shop      4    ££
# 185             Lisboa Patisserie  Patisserie/Cake Shop      4     £
# 186            Patisserie Valerie  Patisserie/Cake Shop      4    ££
# 187               Fabrique Bakery  Patisserie/Cake Shop      4    ££
# 188                 Ole and Steen  Patisserie/Cake Shop    4.5    ££
# 189            Patisserie Valerie  Patisserie/Cake Shop      4    ££
# 190          Wonderful Patisserie  Patisserie/Cake Shop    3.5    ££
# 191         Golden Gate Cake Shop  Patisserie/Cake Shop      4     £
# 192              Assal Patisserie  Patisserie/Cake Shop      5     £
# 193                  Belle Epoque  Patisserie/Cake Shop    4.5    ££
# 194                  Maitre Choux  Patisserie/Cake Shop    4.5   £££
# 195            Patisserie Valerie  Patisserie/Cake Shop      4    ££
# 196          Peggy Porschen Cakes  Patisserie/Cake Shop      4    ££
# 197                         Lanka  Patisserie/Cake Shop    4.5    ££
# 198         Bachmann's Patisserie  Patisserie/Cake Shop      5    ££
# 199                      Bageriet          Scandinavian    4.5     £
#
#                                         Address        Lat       Lng  \
# 0                    126-128 Golders Green Road  51.573986 -0.200746
# 1                                47 Warwick Way  51.492049 -0.140656
# 2                              129 Praed Street  51.516610 -0.173451
# 3                        54-56 Elizabeth Street  51.493600 -0.150758
# 4                                136 Essex Road  51.539319 -0.097745
# 5    Unite 2 Kingfisher House / Battersea Reach  51.464748 -0.184028
# 6                                82 Duke Street  51.513013 -0.150613
# 7                            South Lambeth Road  51.477322 -0.123104
# 8                                 654 High Road  51.568670  0.011340
# 9                                13A The Piazza  51.512200 -0.122449
# 10                          11-13 Bayley Street  51.518869 -0.131913
# 11                             52 Floral Street  51.513503 -0.122760
# 12                          46 Elizabeth Street  51.493827 -0.150838
# 13                         47 Old Brompton Road  51.493342 -0.175514
# 14                              93 Wapping Lane  51.505391 -0.057917
# 15               60 Stoke Newington High Street  51.558398 -0.074056
# 16                     64 Hampstead High Street  51.556122 -0.177963
# 17                           Paddington Station  51.515690 -0.176127
# 18                           47 Chalk Farm Road  51.543002 -0.148795
# 19                             239 High Holborn  51.517607 -0.119027
# 20                    7 - 11 Upper Woburn place  51.526332 -0.129385
# 21                         131 Earls Court Road  51.493320 -0.194478
# 22                        88 Camden High Street  51.536734 -0.140320
# 23                               76 Landor Road  51.465915 -0.125100
# 24                         395 Mentmore Terrace  51.541204 -0.057616
# 25                           596 Kingsland Road  51.545973 -0.075497
# 26                          5B Greenwich market  51.481627 -0.008839
# 27                                   9 Bow Lane  51.513083 -0.093669
# 28                           The Angel Building  51.531267 -0.106344
# 29                         77e King Henrys Road  51.542276 -0.160988
# ..                                          ...        ...       ...
# 170                        408 Coldharbour Lane  51.461735 -0.113229
# 171                          4 Broadwick Street  51.514167 -0.134675
# 172                            Sunday Up Market  51.521066 -0.072976
# 173                          3a Melcombe Street  51.522881 -0.158202
# 174                            9 Conduit Street  51.512761 -0.141592
# 175                     1 Islington High Street  51.534540 -0.104365
# 176                          4-6 Russell Street  51.512493 -0.121222
# 177                     Hilton London Hyde Park  51.510377 -0.187598
# 178                             21 James Street  51.515141 -0.150699
# 179                            167 Upper Street  51.541003 -0.102976
# 180                         386-390 Green Lanes  51.580450 -0.099772
# 181                            52 Warren Street  51.524137 -0.140204
# 182                          135 Wardour Street  51.513863 -0.134387
# 183                     71-72 Burlington Arcade  51.508357 -0.139577
# 184                      194 Kensington Park Rd  51.515550 -0.205818
# 185                            57 Golborne Road  51.522402 -0.207492
# 186                    105 Marylebone High Road  51.519110 -0.151774
# 187                            8 Earlham Street  51.513464 -0.128402
# 188                                56 Haymarket  51.509238 -0.132696
# 189                                  York House  51.514271 -0.159456
# 190                           45 Gerrard Street  51.511969 -0.130143
# 191                      13 Macclesfield Street  51.511968 -0.131181
# 192                         14 Connaught Street  51.514730 -0.165363
# 193                            262 Upper Street  51.542748 -0.103128
# 194                                  60 Dean St  51.512714 -0.132232
# 195                           174-176 Queensway  51.515711 -0.188256
# 196                            116 Ebury Street  51.493261 -0.150526
# 197                         9 Goldhurst Terrace  51.545772 -0.179394
# 198                       6 Criterion Buildings  51.389394 -0.325959
# 199                              24 Rose Street  51.511924 -0.126182
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/carmelli-london?adjus...  1iZkMMh1PZnCjQhJLivG3Q
# 1    https://www.yelp.com/biz/quartiers-london?adju...  FeRP9CIb0TLDkDv9fbLe7g
# 2    https://www.yelp.com/biz/bonne-bouche-catering...  v15QYkGuOjhdqDV60r08QQ
# 3    https://www.yelp.com/biz/baker-and-spice-londo...  jIuiv7VJkAAM5bRCuKNozg
# 4    https://www.yelp.com/biz/raabs-bakery-london?a...  DARE_WvgMZINvslycDPJFQ
# 5    https://www.yelp.com/biz/cake-boy-london?adjus...  5tIA8ET05tlWsD7IcQuofQ
# 6
# 7
# 8    https://www.yelp.com/biz/the-wild-goose-bakery...  nJA-5mA9yvHF55M-cwWVRg
# 9    https://www.yelp.com/biz/bens-cookies-london-3...  vt3Klo2UTjlvQD4AvU7d2A
# 10   https://www.yelp.com/biz/gails-bakery-bloomsbu...  3PeQF-J_j89dcLcC0P5o4A
# 11   https://www.yelp.com/biz/kastner-and-ovens-lon...  HXjHL0L7lqtQQ1KJ0ZKAug
# 12   https://www.yelp.com/biz/poilane-london-2?adju...  3AXQMV-Yirhfq4oQHry6tA
# 13   https://www.yelp.com/biz/the-hummingbird-baker...  amwXVuFLQbmANNjDKjbXrw
# 14
# 15   https://www.yelp.com/biz/akdeniz-bakery-london...  FEfzDsEOSdtHvf3aTrb6lQ
# 16   https://www.yelp.com/biz/gails-bakery-hampstea...  1OcBgrUzPgp82BfZBUKRow
# 17   https://www.yelp.com/biz/delice-de-france-lond...  5aKBzS_J3DF2cxhzC5IGGw
# 18
# 19
# 20
# 21   https://www.yelp.com/biz/maroush-bakehouse-lon...  Da8ClETsPknyD-XIam-jbg
# 22   https://www.yelp.com/biz/melissa-london?adjust...  -3USXGHx6Xcpwq-ueoED7g
# 23   https://www.yelp.com/biz/old-post-office-baker...  X8UxGRF_ju6cfIB2fZizqQ
# 24   https://www.yelp.com/biz/e5-bakehouse-london?a...  -6GHU4qI0DKsIrBpv57qTg
# 25   https://www.yelp.com/biz/rainbow-bakery-london...  L7Vvywx0FVe6StgC09kzrw
# 26   https://www.yelp.com/biz/rubys-of-london-londo...  0_D-cBDrhU6Cx0hHeHVO3w
# 27   https://www.yelp.com/biz/konditor-and-cook-lon...  uwQVCV7lXyHM2uvwKei-Dw
# 28   https://www.yelp.com/biz/hummingbird-bakery-lo...  XmUWjHm8Uh_UCyDsr6LFVw
# 29   https://www.yelp.com/biz/beverly-hills-bakery-...  NepoH95B72aOjj02r48ZWg
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/ms-cupcake-london?adj...  pSUwN4KXpsnpifV8Rh8xIQ
# 171  https://www.yelp.com/biz/crosstown-doughnuts-a...  BVD84PXIYOiIr5Rc-s8JQw
# 172  https://www.yelp.com/biz/kooky-bakes-london?ad...  XD89DGPLbNTjVhesu5wyIA
# 173
# 174  https://www.yelp.com/biz/sketch-london-2?adjus...  zJNI06Y2zZQFh9OBSFCdgQ
# 175
# 176  https://www.yelp.com/biz/balthazar-london?adju...  VtLgCcLSEwFBiKPFV6_Mug
# 177  https://www.yelp.com/biz/aubaine-london-11?adj...  UDcjE8YbIE4mtMZBg4sIzQ
# 178
# 179  https://www.yelp.com/biz/artisan-gluten-free-b...  ZmPuLx41P8x2aYX3_nk7Fg
# 180  https://www.yelp.com/biz/yasar-halim-london?ad...  EwfP3qXpnWP23zvEgwmhoQ
# 181
# 182  https://www.yelp.com/biz/princi-london?adjust_...  -ATEXu2q4Oe4wPQeyrsILw
# 183  https://www.yelp.com/biz/laduree-london-14?adj...  OGW03dLcEui-6CWZIucVMw
# 184  https://www.yelp.com/biz/biscuiteers-london-2?...  eDqcRJKUdRt46nld92YyTA
# 185  https://www.yelp.com/biz/lisboa-patisserie-lon...  UhXQ3C0ixl8BukWDAR-cqg
# 186  https://www.yelp.com/biz/patisserie-valerie-lo...  Z3dr4as9zDncGnaCtqnntQ
# 187  https://www.yelp.com/biz/fabrique-bakery-londo...  Q-f511k1hYDIKfKIpC_HIw
# 188  https://www.yelp.com/biz/ole-and-steen-london-...  5or4AzNouZq8RClNeTdqiA
# 189  https://www.yelp.com/biz/patisserie-valerie-lo...  xJvPDma1C7F7hvEp0OfjWg
# 190  https://www.yelp.com/biz/wonderful-patisserie-...  VZ_1ATiJ5j4uTHvGHr7JNw
# 191  https://www.yelp.com/biz/golden-gate-cake-shop...  83KeM6uScA4ONx97xMHvXw
# 192  https://www.yelp.com/biz/assal-patisserie-lond...  u2mLhuhJpEUkKTLXx-TPyw
# 193  https://www.yelp.com/biz/belle-epoque-london-5...  HL5WLBu_thiEf8ix4BZvGg
# 194  https://www.yelp.com/biz/maitre-choux-london-2...  271U0h4hish4lq_mESjGRw
# 195  https://www.yelp.com/biz/patisserie-valerie-lo...  9klx0ol5iCCf7vG-IjcYFQ
# 196  https://www.yelp.com/biz/peggy-porschen-cakes-...  bPbHHWSUbEQ82X2-ZUcVYQ
# 197  https://www.yelp.com/biz/lanka-london-2?adjust...  c3m_OXrRNdJpWmTqhEgdeQ
# 198  https://www.yelp.com/biz/bachmanns-patisserie-...  mso0KFMpL7C3OaCHnQiReg
# 199  https://www.yelp.com/biz/bageriet-london?adjus...  0tJs57Xoq75-RDWKVco0nw
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
london_restaurants_df.to_csv('Resources/London_Restaurants_Bakery.csv')
