# %% [markdown]
# LONDON RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
lndr_params1 = {"term":"pub","location":"London","limit":50,"offset":0}
lndr_response1 = requests.get(search_api_url, headers=headers, params=lndr_params1)
lndr1 = lndr_response1.json()
display(lndr1)
#print(lndr_response1.url)
#print(lndr_response1.status_code)
# Out:
# {'businesses': [{'id': '1i-iUdP2GKs10_lduricuQ',
#    'alias': 'the-harp-london-2',
#    'name': 'The Harp',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/e6yc3MwHRj7fhhZEBkNGSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-harp-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 135,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5096642, 'longitude': -0.1259343},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '47 Chandos Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4HS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Chandos Place',
#      'London WC2N 4HS',
#      'United Kingdom']},
#    'phone': '+442078360291',
#    'display_phone': '+44 20 7836 0291',
#    'distance': 778.0252696186084},
#   {'id': 'Wjgxl0lSp_FRtzecbJ4FZQ',
#    'alias': 'the-queens-arms-london',
#    'name': 'The Queens Arms',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-QF0e-bRLjskiUjWPD7Ihg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-queens-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 120,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4925789, 'longitude': -0.1392194},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Warwick Way',
#     'address2': 'Pimlico',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1QT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Warwick Way',
#      'Pimlico',
#      'London SW1V 1QT',
#      'United Kingdom']},
#    'phone': '+442078343313',
#    'display_phone': '+44 20 7834 3313',
#    'distance': 2259.97766392161},
#   {'id': 'Z0r83lDOA1mI8RpNccXtHw',
#    'alias': 'the-fat-bear-london',
#    'name': 'The Fat Bear',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-U3vVDIo1UItF64Gf1yAZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-fat-bear-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 123,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'soulfood', 'title': 'Soul Food'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5131833881734,
#     'longitude': -0.10138103121642},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61 Carter Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4V 5DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Carter Lane',
#      'London EC4V 5DY',
#      'United Kingdom']},
#    'phone': '+442072362498',
#    'display_phone': '+44 20 7236 2498',
#    'distance': 2392.909207748214},
#   {'id': 'teXPunKtpwj0NuttvPYhyQ',
#    'alias': 'the-victoria-paddington',
#    'name': 'The Victoria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IscE584D-z4Snf71FJ1bcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-victoria-paddington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 218,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51350403679, 'longitude': -0.17119959969309},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10a Strathearn Place',
#     'address2': '',
#     'address3': '',
#     'city': 'Paddington',
#     'zip_code': 'W2 2NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10a Strathearn Place',
#      'Paddington W2 2NH',
#      'United Kingdom']},
#    'phone': '+442077241191',
#    'display_phone': '+44 20 7724 1191',
#    'distance': 2440.016451414865},
#   {'id': 'IBV7BsXnv2gX68nWUARhjw',
#    'alias': 'mother-mash-london',
#    'name': 'Mother Mash',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YRdJ5N93Jc3qOIxx_itIRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mother-mash-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 469,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512935, 'longitude': -0.139414},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '26 Ganton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7QZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Ganton Street',
#      'London W1F 7QZ',
#      'United Kingdom']},
#    'phone': '+442074949644',
#    'display_phone': '+44 20 7494 9644',
#    'distance': 235.11523624102102},
#   {'id': 'Nv63I1hKZpqtKUwJgV2FYw',
#    'alias': 'the-monkey-puzzle-london',
#    'name': 'The Monkey Puzzle',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-Wz6mShH7W9n3rOOl_NxeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-monkey-puzzle-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5164243625465,
#     'longitude': -0.169808305799961},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '30 Southwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1JQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Southwick Street',
#      'London W2 1JQ',
#      'United Kingdom']},
#    'phone': '+442077230143',
#    'display_phone': '+44 20 7723 0143',
#    'distance': 2376.2784719424735},
#   {'id': 'NEAPxGZfFuGZf8pjC2yhWQ',
#    'alias': 'the-blackfriar-london',
#    'name': 'The Blackfriar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VTMbqMAyxEH3GYg8VPY-Wg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-blackfriar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 150,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51213429293, 'longitude': -0.10372875314406},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '174 Queen Victoria Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4V 4EG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['174 Queen Victoria Street',
#      'London EC4V 4EG',
#      'United Kingdom']},
#    'phone': '+442072365474',
#    'display_phone': '+44 20 7236 5474',
#    'distance': 2231.521060343169},
#   {'id': 'a-GLT-ji4T3QAQ5b2Vqdng',
#    'alias': 'the-kings-head-london-7',
#    'name': 'The Kings Head',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kM6upGnci_uk6c0wioj6vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-kings-head-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5196816, 'longitude': -0.1501257},
#    'transactions': [],
#    'location': {'address1': '13 Westmoreland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1G 8PJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Westmoreland Street',
#      'London W1G 8PJ',
#      'United Kingdom']},
#    'phone': '+442079352201',
#    'display_phone': '+44 20 7935 2201',
#    'distance': 1241.3179503907002},
#   {'id': 'az6hEPLFn0PVVhYZk1gpVQ',
#    'alias': 'the-red-lion-london-10',
#    'name': 'The Red Lion',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZZyZl8GzZs65sA5FVJljhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-red-lion-london-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5021048352022,
#     'longitude': -0.125728284603611},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '48 Parliament Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1A 2NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['48 Parliament Street',
#      'London SW1A 2NH',
#      'United Kingdom']},
#    'phone': '+442079305826',
#    'display_phone': '+44 20 7930 5826',
#    'distance': 1387.3541666513256},
#   {'id': 'Gyus9t3spoc1Ymc-BChRFw',
#    'alias': 'cahoots-bar-soho',
#    'name': 'Cahoots Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/E3N3tDHi8cWqTTp87jX3Vw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cahoots-bar-soho?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 106,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512542, 'longitude': -0.1391},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '13 Kingly Court',
#     'address2': 'Carnaby Street',
#     'address3': '',
#     'city': 'Soho',
#     'zip_code': 'W1B 5PW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Kingly Court',
#      'Carnaby Street',
#      'Soho W1B 5PW',
#      'United Kingdom']},
#    'phone': '+442073526200',
#    'display_phone': '+44 20 7352 6200',
#    'distance': 220.0157243666825},
#   {'id': '4bzGqKQMrTUAhB84SKy83w',
#    'alias': 'the-ordnance-london',
#    'name': 'The Ordnance',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wOglfHDVn5_GPDqe9lrlHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ordnance-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5357005, 'longitude': -0.1713083},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '29 Ordnance Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 6PS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['29 Ordnance Hill',
#      'London NW8 6PS',
#      'United Kingdom']},
#    'phone': '+442077220278',
#    'display_phone': '+44 20 7722 0278',
#    'distance': 3545.873700919653},
#   {'id': 'kV0BkdO197Ftj4KIYqAdNg',
#    'alias': 'carpenters-arms-london-4',
#    'name': 'Carpenters Arms',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_UmSc-HpNJ7v92BXDT39Rg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carpenters-arms-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5147650067045,
#     'longitude': -0.16106785416687},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '12 Seymour Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Seymour Place',
#      'London W1H 7NE',
#      'United Kingdom']},
#    'phone': '+442077231050',
#    'display_phone': '+44 20 7723 1050',
#    'distance': 1750.9335728812569},
#   {'id': 'nxxCu3Svrmp2cNvfufrdFw',
#    'alias': 'the-harwood-arms-london',
#    'name': 'The Harwood Arms',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hte754uy10BMdVg3P0hbxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-harwood-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 125,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4829113087309,
#     'longitude': -0.196470990454087},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '27 Walham Grove',
#     'address2': 'Fulham',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 1QP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['27 Walham Grove',
#      'Fulham',
#      'London SW6 1QP',
#      'United Kingdom']},
#    'phone': '+442073861847',
#    'display_phone': '+44 20 7386 1847',
#    'distance': 5349.774856506561},
#   {'id': 'epH0utRAynKdkkK2BB56bg',
#    'alias': 'the-windsor-castle-london-3',
#    'name': 'The Windsor Castle',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QAmXLWSemSjgCQgDAbfEDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-windsor-castle-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.495204944444,
#     'longitude': -0.13796251468522},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '23 Francis Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 1DN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23 Francis Street',
#      'London SW1P 1DN',
#      'United Kingdom']},
#    'phone': '+442078347260',
#    'display_phone': '+44 20 7834 7260',
#    'distance': 1965.3424908619384},
#   {'id': 'FJs1PrhFMFVL_iMcH69VuQ',
#    'alias': 'the-grenadier-london',
#    'name': 'The Grenadier',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yvn70RKEt4QFqJp6MfeluA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grenadier-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 188,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.501462, 'longitude': -0.155004},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18 Wilton Row',
#     'address2': '',
#     'address3': 'Belgravia',
#     'city': 'London',
#     'zip_code': 'SW1X 7NR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Wilton Row',
#      'Belgravia',
#      'London SW1X 7NR',
#      'United Kingdom']},
#    'phone': '+442072353074',
#    'display_phone': '+44 20 7235 3074',
#    'distance': 1826.8454804863936},
#   {'id': 'hGiblm0l67sLGTtsMvx51A',
#    'alias': 'the-churchill-arms-london',
#    'name': 'The Churchill Arms',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6gBKxDzV9D3Ehmavvg7mYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-churchill-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 358,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5068261, 'longitude': -0.194781},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '119 Kensington Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 7LN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['119 Kensington Church Street',
#      'London W8 7LN',
#      'United Kingdom']},
#    'phone': '+442077274242',
#    'display_phone': '+44 20 7727 4242',
#    'distance': 4125.33167965603},
#   {'id': 'bJiVADMSTEKj0MjqiLrOPA',
#    'alias': 'the-grazing-goat-marylebone-london',
#    'name': 'The Grazing Goat Marylebone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/h73f5PAFit9wdm8w_zm3lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grazing-goat-marylebone-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 240,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515378341447,
#     'longitude': -0.15823586449841},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 New Quebec Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7RQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 New Quebec Street',
#      'London W1H 7RQ',
#      'United Kingdom']},
#    'phone': '+442077247243',
#    'display_phone': '+44 20 7724 7243',
#    'distance': 1567.469377589238},
#   {'id': 'Nm0YZA4SGLDCw35DHRe6Fg',
#    'alias': 'coach-and-horses-london-24',
#    'name': 'Coach and Horses',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cTRQ9w_-KmgOM7jXQqHlpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coach-and-horses-london-24?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5108378505636,
#     'longitude': -0.143784536805356},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5 Bruton Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1J 6PT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Bruton Street',
#      'London W1J 6PT',
#      'United Kingdom']},
#    'phone': '+442076294123',
#    'display_phone': '+44 20 7629 4123',
#    'distance': 585.5366862982436},
#   {'id': 'FzrRg1-nCAW2R0KJBdDCFA',
#    'alias': 'the-cock-and-bottle-london-2',
#    'name': 'The Cock & Bottle',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iJiLzuIlFbAx821qQ5mWzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cock-and-bottle-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.515413, 'longitude': -0.197582},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '17 Needham Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17 Needham Road',
#      'London W11 2RP',
#      'United Kingdom']},
#    'phone': '+442072291550',
#    'display_phone': '+44 20 7229 1550',
#    'distance': 4274.086747984158},
#   {'id': 'pQSVwo98sKLUgE8tV4hcLw',
#    'alias': 'brewdog-soho',
#    'name': 'BrewDog',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mpaAqJND_FkPHbRq0dg5IQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brewdog-soho?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5150421077263,
#     'longitude': -0.137205049395561},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '21 Poland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Soho',
#     'zip_code': 'W1F 8QG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21 Poland Street', 'Soho W1F 8QG', 'United Kingdom']},
#    'phone': '+442072878029',
#    'display_phone': '+44 20 7287 8029',
#    'distance': 260.14413531437225},
#   {'id': '-Ve2_hHfPczRX159xt0BCg',
#    'alias': 'ye-olde-cheshire-cheese-london',
#    'name': 'Ye Olde Cheshire Cheese',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4B0TZgcIebNCJgwtZcc3gQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ye-olde-cheshire-cheese-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 354,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5143449, 'longitude': -0.107315},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '145 Fleet Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4A 2BU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['145 Fleet Street',
#      'London EC4A 2BU',
#      'United Kingdom']},
#    'phone': '+442073536170',
#    'display_phone': '+44 20 7353 6170',
#    'distance': 1999.1587381312402},
#   {'id': 'mRv4aBJvsOrTyK0FzM5O-A',
#    'alias': 'the-queens-head-london-4',
#    'name': "The Queen's Head",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/axPeuWOJwP9D1M5XBBynVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-queens-head-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5108549, 'longitude': -0.1353599},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '15 Denman Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 7HN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Denman Street',
#      'London W1D 7HN',
#      'United Kingdom']},
#    'phone': '+442074371540',
#    'display_phone': '+44 20 7437 1540',
#    'distance': 230.364555692782},
#   {'id': 'VT3Y1okIjvdC31BU_9IApA',
#    'alias': 'the-kings-head-london',
#    'name': "The King's Head",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8DuUBz8gYqNj5L94KaiqWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-kings-head-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.508718, 'longitude': -0.141171},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10 Stafford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 4RX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Stafford Street',
#      'London W1S 4RX',
#      'United Kingdom']},
#    'phone': '+442074930337',
#    'display_phone': '+44 20 7493 0337',
#    'distance': 592.4973978422088},
#   {'id': 'VomGBPMQALZLfKHCI8_jTg',
#    'alias': 'the-swan-london-6',
#    'name': 'The Swan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CjuYlM6M82fHy8xsBDw0Ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-swan-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 115,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511656071976,
#     'longitude': -0.17697194507093},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '66 Bayswater Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Bayswater Road',
#      'London W2 3PH',
#      'United Kingdom']},
#    'phone': '+442072625204',
#    'display_phone': '+44 20 7262 5204',
#    'distance': 2841.418230660763},
#   {'id': 'JcO8N2mrooxEoFZTRiLRqw',
#    'alias': 'the-queens-arms-london-3',
#    'name': "The Queen's Arms",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V56aN41Oywr5Br_j-EWYjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-queens-arms-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 128,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4992491095565,
#     'longitude': -0.180797918037262},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "30 Queen's Gate Mews",
#     'address2': 'Kensington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 5QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["30 Queen's Gate Mews",
#      'Kensington',
#      'London SW7 5QL',
#      'United Kingdom']},
#    'phone': '+442078239293',
#    'display_phone': '+44 20 7823 9293',
#    'distance': 3451.741366066539},
#   {'id': 'By_GidVlsMQa_Ri2hLkP9Q',
#    'alias': 'waxy-o-connors-london',
#    'name': "Waxy O'Connor's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2VBGvltFPGmBdVnJMAHi3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/waxy-o-connors-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 168,
#    'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'},
#     {'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5107349, 'longitude': -0.1322637},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14-16 Rupert Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6DD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14-16 Rupert Street',
#      'London W1D 6DD',
#      'United Kingdom']},
#    'phone': '+442072870255',
#    'display_phone': '+44 20 7287 0255',
#    'distance': 343.497932226086},
#   {'id': '3R0Klq1B1ESNTwqPfcsY-w',
#    'alias': 'the-pig-and-butcher-london',
#    'name': 'The Pig and Butcher',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zpEzs1qPf3ijMGJdGEcM8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pig-and-butcher-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 109,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.537442542029,
#     'longitude': -0.10682789450616},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '80 Liverpool Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 0QD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['80 Liverpool Road',
#      'London N1 0QD',
#      'United Kingdom']},
#    'phone': '+442072268304',
#    'display_phone': '+44 20 7226 8304',
#    'distance': 3398.14716948262},
#   {'id': 'AIssXkThJSw4Y2gSGUwbSQ',
#    'alias': 'the-shaftesbury-london-3',
#    'name': 'The Shaftesbury',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vvjMAfAY0TdqiFvUDaKIhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-shaftesbury-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5118239, 'longitude': -0.132904},
#    'transactions': [],
#    'location': {'address1': '39-45 Shaftesbury Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39-45 Shaftesbury Avenue',
#      'London W1D 6LA',
#      'United Kingdom']},
#    'phone': '+442072878064',
#    'display_phone': '+44 20 7287 8064',
#    'distance': 239.27954648471407},
#   {'id': '0B-ag3J18TatG9H9EQohGg',
#    'alias': 'hawksmoor-seven-dials-london-4',
#    'name': 'Hawksmoor Seven Dials',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yYxu0Q9uw-StO5TXszf8IQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hawksmoor-seven-dials-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 344,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5134998914001,
#     'longitude': -0.12567396291297},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '11 Langley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9JG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Langley Street',
#      'London WC2H 9JG',
#      'United Kingdom']},
#    'phone': '+442074209390',
#    'display_phone': '+44 20 7420 9390',
#    'distance': 715.3327247350239},
#   {'id': 'gpOVjr6Q1PjeUMl8HTMqrQ',
#    'alias': 'cleveland-arms-london',
#    'name': 'Cleveland Arms',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xHIP02sE1Kz3n54sPpy3Mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cleveland-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5148637, 'longitude': -0.1809331},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '28 Chilworth Street',
#     'address2': 'Paddington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 6DT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28 Chilworth Street',
#      'Paddington',
#      'London W2 6DT',
#      'United Kingdom']},
#    'phone': '+442077061759',
#    'display_phone': '+44 20 7706 1759',
#    'distance': 3120.5434071423074},
#   {'id': 'ij6JgRnQmdXND4uokTFIdQ',
#    'alias': 'pieminister-london-3',
#    'name': 'Pieminister',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sxICWzn-wHe0H1z5qUzI3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pieminister-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 88,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.507826, 'longitude': -0.110065},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "Gabriel's Wharf",
#     'address2': '56 Upper Ground',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9PP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["Gabriel's Wharf",
#      '56 Upper Ground',
#      'London SE1 9PP',
#      'United Kingdom']},
#    'phone': '+442079285755',
#    'display_phone': '+44 20 7928 5755',
#    'distance': 1876.3555341238437},
#   {'id': 'WRg2C5xK3v4RH0_SedqHLg',
#    'alias': 'market-tavern-london',
#    'name': 'Market Tavern',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IYCRv7pKkzOLZcR_Uo_GzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/market-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.506150543269, 'longitude': -0.1468604094879},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '7 Shepherd Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 7HR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Shepherd Street',
#      'London W1J 7HR',
#      'United Kingdom']},
#    'phone': '+442074910910',
#    'display_phone': '+44 20 7491 0910',
#    'distance': 1059.274964613101},
#   {'id': 'z6s18W6UWk73QyintC4hsQ',
#    'alias': 'hereford-arms-london',
#    'name': 'Hereford Arms',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/stGKFOLxnF2PaxYrbaQaTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hereford-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 103,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4928650556698,
#     'longitude': -0.181306525714939},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '127 Gloucester Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 4TE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['127 Gloucester Road',
#      'London SW7 4TE',
#      'United Kingdom']},
#    'phone': '+442073704988',
#    'display_phone': '+44 20 7370 4988',
#    'distance': 3845.052015495539},
#   {'id': '5tAAwu7ZDhulLsyt09bXnw',
#    'alias': 'maggie-joness-london-2',
#    'name': "Maggie Jones's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6THUfVyJ2jNScpV6BAY6rg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maggie-joness-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 119,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.502856014927, 'longitude': -0.1909916674772},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '6 Old Court Place',
#     'address2': 'Kensington Church Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4PL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Old Court Place',
#      'Kensington Church Street',
#      'London W8 4PL',
#      'United Kingdom']},
#    'phone': '+442079376462',
#    'display_phone': '+44 20 7937 6462',
#    'distance': 3967.2973141903262},
#   {'id': 'miaBUi97a2kSIBUNv_VQVw',
#    'alias': 'the-mitre-london-2',
#    'name': 'The Mitre',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7EwIuV7tWGYWMTjMF8C0Bw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mitre-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5123634074761,
#     'longitude': -0.17837760220187},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '24 Craven Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3QH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Craven Terrace',
#      'London W2 3QH',
#      'United Kingdom']},
#    'phone': '+442072625240',
#    'display_phone': '+44 20 7262 5240',
#    'distance': 2936.1105110844214},
#   {'id': 'B_8Yj3zaEP1-e1YeGrgI1Q',
#    'alias': 'hung-drawn-and-quartered-london',
#    'name': 'Hung Drawn & Quartered',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4FPkcbrt8H60btuna3rbOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hung-drawn-and-quartered-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.509547, 'longitude': -0.080753},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '26-27 Great Tower Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3R 5AQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26-27 Great Tower Street',
#      'London EC3R 5AQ',
#      'United Kingdom']},
#    'phone': '+442076266123',
#    'display_phone': '+44 20 7626 6123',
#    'distance': 3837.6823886602388},
#   {'id': 'pe5DCbQaVZB5BZ60q4g-Ag',
#    'alias': 'the-punchbowl-mayfair',
#    'name': 'The Punchbowl',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Q6o6wII3g9d0Jt1zlj5C7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-punchbowl-mayfair?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 79,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5090688, 'longitude': -0.1494544},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '41 Farm Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Mayfair',
#     'zip_code': 'W1J 5RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41 Farm Street',
#      'Mayfair W1J 5RP',
#      'United Kingdom']},
#    'phone': '+442074936841',
#    'display_phone': '+44 20 7493 6841',
#    'distance': 1023.0200079472846},
#   {'id': 'lJ_hk4cn88vv6_XqAlbYHw',
#    'alias': 'the-beehive-london-7',
#    'name': 'The Beehive',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4FHnwe7jE7cdfBeIYjWknQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-beehive-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.520052, 'longitude': -0.157343},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '126 Crawford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 6BF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['126 Crawford Street',
#      'London W1U 6BF',
#      'United Kingdom']},
#    'phone': '+442074868037',
#    'display_phone': '+44 20 7486 8037',
#    'distance': 1682.3349010000493},
#   {'id': 'CexMDiWtQh7BNpq3nSN30g',
#    'alias': 'prospect-of-whitby-london',
#    'name': 'Prospect Of Whitby',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BKeENWGbj3-GSGe0IKUgbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prospect-of-whitby-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 56,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5071151879516,
#     'longitude': -0.0511241777638486},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '57 Wapping Wall',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1W 3SH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57 Wapping Wall',
#      'London E1W 3SH',
#      'United Kingdom']},
#    'phone': '+442074811095',
#    'display_phone': '+44 20 7481 1095',
#    'distance': 5905.15028374947},
#   {'id': '3xexIL9jt0lRBaqwUqGEFQ',
#    'alias': 'philomenas-bar-and-cafe-london-2',
#    'name': "Philomena's Bar and Cafe",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6lJNclgsJxEvUXeUOCYIFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/philomenas-bar-and-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.515147, 'longitude': -0.121914},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '40 Great Queen Street',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 Great Queen Street',
#      'Covent Garden',
#      'London WC2B 5AA',
#      'United Kingdom']},
#    'phone': '+442072425560',
#    'display_phone': '+44 20 7242 5560',
#    'distance': 1005.6707950743768},
#   {'id': 'WHSJsMnrsAQEN4TKo0n7XA',
#    'alias': 'lord-nelson-london-2',
#    'name': 'Lord Nelson',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4heSWuWOQKVc3uJr4YpRvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lord-nelson-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.503489520908,
#     'longitude': -0.10225512172207},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '243 Union Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0LR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['243 Union Street',
#      'London SE1 0LR',
#      'United Kingdom']},
#    'phone': '+442072072701',
#    'display_phone': '+44 20 7207 2701',
#    'distance': 2553.4058565853998},
#   {'id': 'Pz43R3x69i6rNd5KNSXZxA',
#    'alias': 'the-marylebone-london',
#    'name': 'The Marylebone',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jWPHEJzZ--ZWFh6NMr14MQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-marylebone-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51988692678,
#     'longitude': -0.151906623278819},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '93 Marylebone High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 4RE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['93 Marylebone High Street',
#      'London W1U 4RE',
#      'United Kingdom']},
#    'phone': '+442079354373',
#    'display_phone': '+44 20 7935 4373',
#    'distance': 1353.879608689905},
#   {'id': 'gCV4iy5W1YBlVEeMCRD6ag',
#    'alias': 'callaghans-london',
#    'name': 'Callaghans',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x3f_S4xChjYlm6fFUmth6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/callaghans-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'irish', 'title': 'Irish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5241263, 'longitude': -0.1258014},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Coram Street',
#     'address2': 'Bloomsbury',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC1N 1HT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Coram Street',
#      'Bloomsbury',
#      'London WC1N 1HT',
#      'United Kingdom']},
#    'phone': '+448704009222',
#    'display_phone': '+44 870 400 9222',
#    'distance': 1438.7066097194534},
#   {'id': '70Q-Ll18zb4aglXXbUG7lw',
#    'alias': 'ffionas-restaurant-london',
#    'name': "Ffiona's Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/seykrl3tugRsE8UL6-phKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ffionas-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 265,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.50405773515,
#     'longitude': -0.192783395566043},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '51 Kensington Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Kensington Church Street',
#      'London W8 4BA',
#      'United Kingdom']},
#    'phone': '+442079374152',
#    'display_phone': '+44 20 7937 4152',
#    'distance': 4052.2035032181666},
#   {'id': 'QI8guDlv3zxMYo_2l5SJJQ',
#    'alias': 'the-nags-head-london-3',
#    'name': "The Nag's Head",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kUmhr57ThOPBq3NB3eO6Zg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-nags-head-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.501344, 'longitude': -0.157104},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '53 Kinnerton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 8ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['53 Kinnerton Street',
#      'London SW1X 8ED',
#      'United Kingdom']},
#    'phone': '+442072351135',
#    'display_phone': '+44 20 7235 1135',
#    'distance': 1950.5697647772065},
#   {'id': 'dXEPhJmyV9BiA77wdAfEmg',
#    'alias': 'the-blackbird-london',
#    'name': 'The Blackbird',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/l-vFQ5dw4QEJDAkWvI5Neg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-blackbird-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 157,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.49178, 'longitude': -0.19211},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '209 Earls Ct Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 9AN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['209 Earls Ct Road',
#      'London SW5 9AN',
#      'United Kingdom']},
#    'phone': '+442078351855',
#    'display_phone': '+44 20 7835 1855',
#    'distance': 4538.901972736327},
#   {'id': 'xouHUGexW5aBcrC60rx9kw',
#    'alias': 'the-mayflower-london',
#    'name': 'The Mayflower',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ffLVdxFg79iT9hgdtE0iow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mayflower-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.501782997115,
#     'longitude': -0.053587722326993},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '117 Rotherhithe Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE16 4NF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['117 Rotherhithe Street',
#      'London SE16 4NF',
#      'United Kingdom']},
#    'phone': '+442072374088',
#    'display_phone': '+44 20 7237 4088',
#    'distance': 5831.608478843023},
#   {'id': 't-LjuFbYp76ARX7QEp0gnA',
#    'alias': 'the-windmill-london-2',
#    'name': 'The Windmill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EoyTiwabaEmXue8EXs4nKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-windmill-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 94,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512565, 'longitude': -0.142204},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6-8 Mill Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 2AZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6-8 Mill Street',
#      'London W1S 2AZ',
#      'United Kingdom']},
#    'phone': '+442074918050',
#    'display_phone': '+44 20 7491 8050',
#    'distance': 433.4266729223569},
#   {'id': 'GD4LetX9pdn3fvDigFPjiA',
#    'alias': 'the-crown-and-sceptre-london-2',
#    'name': 'The Crown and Sceptre',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yO1NuEvD5fIVco-JkWHFpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-crown-and-sceptre-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4979662, 'longitude': -0.20744},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '34 Holland Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W14 8BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['34 Holland Road',
#      'London W14 8BA',
#      'United Kingdom']},
#    'phone': '+442076032007',
#    'display_phone': '+44 20 7603 2007',
#    'distance': 5217.735026982817},
#   {'id': '6zdVc_noXqjJLIohpSyIbw',
#    'alias': 'crockers-folly-london',
#    'name': "Crocker's Folly",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qYWCrn-kcozO0ionPWdI8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crockers-folly-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'lebanese', 'title': 'Lebanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.525735598316,
#     'longitude': -0.174713730812073},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '24 Aberdeen Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 8JR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Aberdeen Place',
#      'London NW8 8JR',
#      'United Kingdom']},
#    'phone': '+442072899898',
#    'display_phone': '+44 20 7289 9898',
#    'distance': 3041.2326413608102}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#         Restaurant                    Type Price Rating               Address  \
# 0         The Harp                    Pubs     £    4.5      47 Chandos Place
# 1  The Queens Arms                 British    ££    4.5        11 Warwick Way
# 2     The Fat Bear  American (Traditional)    ££    4.5        61 Carter Lane
# 3     The Victoria                    Pubs    ££    4.5  10a Strathearn Place
# 4      Mother Mash                 British    ££      4      26 Ganton Street
#
#          Lat       Lng                                                url  \
# 0  51.509664 -0.125934  https://www.yelp.com/biz/the-harp-london-2?adj...
# 1  51.492579 -0.139219  https://www.yelp.com/biz/the-queens-arms-londo...
# 2  51.513183 -0.101381  https://www.yelp.com/biz/the-fat-bear-london?a...
# 3  51.513504 -0.171200  https://www.yelp.com/biz/the-victoria-paddingt...
# 4  51.512935 -0.139414  https://www.yelp.com/biz/mother-mash-london?ad...
#
#                        ID
# 0  1i-iUdP2GKs10_lduricuQ
# 1  Wjgxl0lSp_FRtzecbJ4FZQ
# 2  Z0r83lDOA1mI8RpNccXtHw
# 3  teXPunKtpwj0NuttvPYhyQ
# 4  IBV7BsXnv2gX68nWUARhjw

# %%
#2nd set of 50 records 51-100 
lndr_params2 = {"term":"pub","location":"London","limit":50,"offset":51}
lndr_response2 = requests.get(search_api_url, headers=headers, params=lndr_params2)
lndr2 = lndr_response2.json()
display(lndr2)
#print(lndr_response2.url)
#print(lndr_response2.status_code)
# Out:
# {'businesses': [{'id': 'TYCrKfYC7Zo14xmi8CIGtw',
#    'alias': 'the-craft-beer-co-london-5',
#    'name': 'The Craft Beer Co',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0YGfQ_V89OJPca-dZ3weQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-craft-beer-co-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51575, 'longitude': -0.125786},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '168 High Holborn',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1V 7AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['168 High Holborn',
#      'London WC1V 7AA',
#      'United Kingdom']},
#    'phone': '+442078349988',
#    'display_phone': '+44 20 7834 9988',
#    'distance': 774.7715742064693},
#   {'id': 'wuuCbT901SC0N-LvzkG8jA',
#    'alias': 'the-cock-and-lion-london',
#    'name': 'The Cock and Lion',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/29hUE5V7b1mmS110vCvaVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cock-and-lion-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5163060196746,
#     'longitude': -0.149841032648468},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '66 Wigmore St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1U 2SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Wigmore St', 'London W1U 2SB', 'United Kingdom']},
#    'phone': '+442079358727',
#    'display_phone': '+44 20 7935 8727',
#    'distance': 1035.4324405613872},
#   {'id': 'GD4LetX9pdn3fvDigFPjiA',
#    'alias': 'the-crown-and-sceptre-london-2',
#    'name': 'The Crown and Sceptre',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yO1NuEvD5fIVco-JkWHFpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-crown-and-sceptre-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4979662, 'longitude': -0.20744},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '34 Holland Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W14 8BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['34 Holland Road',
#      'London W14 8BA',
#      'United Kingdom']},
#    'phone': '+442076032007',
#    'display_phone': '+44 20 7603 2007',
#    'distance': 5217.735026982817},
#   {'id': '1c60bGFaWOhq_ra06w9daQ',
#    'alias': 'the-alfred-tennyson-belgravia-london',
#    'name': 'The Alfred Tennyson Belgravia',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3p5hdST5T_V7r-sGK34LIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-alfred-tennyson-belgravia-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.499631, 'longitude': -0.156411},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10 Motcomb Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 8LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Motcomb Street',
#      'London SW1X 8LA',
#      'United Kingdom']},
#    'phone': '+442077306074',
#    'display_phone': '+44 20 7730 6074',
#    'distance': 2039.6321494418455},
#   {'id': 'ztxaksJUXyy7jm85Q1xiSw',
#    'alias': 'queens-head-london-6',
#    'name': 'Queens Head',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QIT9k-_WHCFZK6oC73RI8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/queens-head-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.528421358155,
#     'longitude': -0.118502992464336},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '66 Acton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1X 9NB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Acton Street',
#      'London WC1X 9NB',
#      'United Kingdom']},
#    'phone': '+442077135772',
#    'display_phone': '+44 20 7713 5772',
#    'distance': 2112.2674112780774},
#   {'id': '70Q-Ll18zb4aglXXbUG7lw',
#    'alias': 'ffionas-restaurant-london',
#    'name': "Ffiona's Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/seykrl3tugRsE8UL6-phKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ffionas-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 265,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.50405773515,
#     'longitude': -0.192783395566043},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '51 Kensington Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Kensington Church Street',
#      'London W8 4BA',
#      'United Kingdom']},
#    'phone': '+442079374152',
#    'display_phone': '+44 20 7937 4152',
#    'distance': 4052.2035032181666},
#   {'id': 'gnkQ-UbIX-vYWR-Rf_IcEQ',
#    'alias': 'ye-olde-mitre-inn-london',
#    'name': 'Ye Olde Mitre Inn',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m18NvR4Seq_waGnMGndRew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ye-olde-mitre-inn-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5184387, 'longitude': -0.1074239},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Ely Court',
#     'address2': 'Ely Place',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1N 6SJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Ely Court',
#      'Ely Place',
#      'London EC1N 6SJ',
#      'United Kingdom']},
#    'phone': '+442074054751',
#    'display_phone': '+44 20 7405 4751',
#    'distance': 2070.288252318426},
#   {'id': '2gkmpJtfRi7q1saeDRtzBQ',
#    'alias': 'goat-tavern-london',
#    'name': 'Goat Tavern',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xmFIQmno8p2RuGEQ1s5K7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/goat-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5022327, 'longitude': -0.1876348},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3A Kensington High Street',
#     'address2': 'Kensington',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W8 5NP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3A Kensington High Street',
#      'Kensington',
#      'London W8 5NP',
#      'United Kingdom']},
#    'phone': '+442079371213',
#    'display_phone': '+44 20 7937 1213',
#    'distance': 3765.953354027003},
#   {'id': 'WMiCQUNJfg14w0jUScoFTA',
#    'alias': 'the-knights-templar-london',
#    'name': 'The Knights Templar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SeysrE-iyh5FGqD6_6WSAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-knights-templar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5153665, 'longitude': -0.1119648},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '95 Chancery Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2A 1DT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['95 Chancery Lane',
#      'London WC2A 1DT',
#      'United Kingdom']},
#    'phone': '+442078312660',
#    'display_phone': '+44 20 7831 2660',
#    'distance': 1683.2989459962719},
#   {'id': 'GaScDG5loFxXHlePsIDBcQ',
#    'alias': 'dog-and-duck-london-2',
#    'name': 'Dog & Duck',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PGH_eQYSi1LekPqgtO2yPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dog-and-duck-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514029972765,
#     'longitude': -0.13189415773159},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18 Bateman Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 3AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Bateman Street',
#      'London W1D 3AJ',
#      'United Kingdom']},
#    'phone': '+442074940697',
#    'display_phone': '+44 20 7494 0697',
#    'distance': 310.867473406407},
#   {'id': 'e8FKAwHFo1iPEKRzDFiaGw',
#    'alias': 'red-lion-london-8',
#    'name': 'Red Lion',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GR5KGJnCl2cyLLjCVgDGUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/red-lion-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.512625, 'longitude': -0.139124},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 Kingly Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5PP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Kingly Street',
#      'London W1B 5PP',
#      'United Kingdom']},
#    'phone': '+442077344985',
#    'display_phone': '+44 20 7734 4985',
#    'distance': 224.43928866268942},
#   {'id': '6zdVc_noXqjJLIohpSyIbw',
#    'alias': 'crockers-folly-london',
#    'name': "Crocker's Folly",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qYWCrn-kcozO0ionPWdI8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crockers-folly-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'lebanese', 'title': 'Lebanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.525735598316,
#     'longitude': -0.174713730812073},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '24 Aberdeen Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 8JR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Aberdeen Place',
#      'London NW8 8JR',
#      'United Kingdom']},
#    'phone': '+442072899898',
#    'display_phone': '+44 20 7289 9898',
#    'distance': 3041.2326413608102},
#   {'id': 'taD2YeoUpeR9lhQK_0Nonw',
#    'alias': 'anchor-tap-london',
#    'name': 'Anchor Tap',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1QniLRHutrl4BjTpFi4O-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anchor-tap-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5035540297327,
#     'longitude': -0.0760193780666896},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '28 Horselydown Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 2LN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28 Horselydown Lane',
#      'London SE1 2LN',
#      'United Kingdom']},
#    'phone': '+442074034637',
#    'display_phone': '+44 20 7403 4637',
#    'distance': 4274.538478830492},
#   {'id': '5o8lm4tCTGgZfH0N4QAgMg',
#    'alias': 'cask-pub-and-kitchen-london-2',
#    'name': 'CASK Pub and Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ntmuMfLZr0WOVoqNXUqW6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cask-pub-and-kitchen-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 139,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.49135039773, 'longitude': -0.13753688795203},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 Charlwood Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 2EE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Charlwood Street',
#      'London SW1V 2EE',
#      'United Kingdom']},
#    'phone': '+442076307225',
#    'display_phone': '+44 20 7630 7225',
#    'distance': 2391.5393462801244},
#   {'id': '1ukNMECwNpEuUdAhj2jGTQ',
#    'alias': 'the-kings-head-london-8',
#    'name': "The King's Head",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gR3ynUdiutmGXBZpTU6GHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-kings-head-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4933785714065,
#     'longitude': -0.192608185150107},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '17 Hogarth Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 0QT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17 Hogarth Place',
#      'London SW5 0QT',
#      'United Kingdom']},
#    'phone': '+442073735239',
#    'display_phone': '+44 20 7373 5239',
#    'distance': 4478.486765996878},
#   {'id': 'b7RW2pHBLX1gpSKCrIm4AQ',
#    'alias': 'builders-arms-london',
#    'name': 'Builders Arms',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1haAluRxsAMs8uNoEbFMLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/builders-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4994295095615,
#     'longitude': -0.188299279589993},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Kensington Court Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 5BJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Kensington Court Place',
#      'London W8 5BJ',
#      'United Kingdom']},
#    'phone': '+442079376213',
#    'display_phone': '+44 20 7937 6213',
#    'distance': 3917.4513323577366},
#   {'id': '3OIaUlgZWnyAhxoWqrB61Q',
#    'alias': 'princess-of-wales-london-5',
#    'name': 'Princess of Wales',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7nubr7jl80pBKbsaXEpF8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/princess-of-wales-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.540283, 'longitude': -0.153757},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Chalcot Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8LL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Chalcot Road',
#      'London NW1 8LL',
#      'United Kingdom']},
#    'phone': '+442077220354',
#    'display_phone': '+44 20 7722 0354',
#    'distance': 3306.604443158016},
#   {'id': 'Rugom03-YkWplCoxMGdkzw',
#    'alias': 'leinster-arms-london',
#    'name': 'Leinster Arms',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DjUrSZvmbzFOQBEuGR37lw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/leinster-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5116842, 'longitude': -0.1828815},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '17 Leinster Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17 Leinster Terrace',
#      'London W2 3EU',
#      'United Kingdom']},
#    'phone': '+442074024670',
#    'display_phone': '+44 20 7402 4670',
#    'distance': 3248.6833737676093},
#   {'id': 'FcTq1tFrMwXnQJ3hE3IGJQ',
#    'alias': 'morpeth-arms-london',
#    'name': 'Morpeth Arms',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XgoR4-yJAPxLbd1PkrjjeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/morpeth-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.489373240701,
#     'longitude': -0.12863043011762},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '58 Millbank',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 4RW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['58 Millbank', 'London SW1P 4RW', 'United Kingdom']},
#    'phone': '+442078346442',
#    'display_phone': '+44 20 7834 6442',
#    'distance': 2657.701473480263},
#   {'id': 'ZKfiQaOMDu7rfVhmMmQ0bQ',
#    'alias': 'berners-tavern-london-5',
#    'name': 'Berners Tavern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tnfzvqS02pyFcaF6b2f8xw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/berners-tavern-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 121,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5167515074354,
#     'longitude': -0.135977268218994},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '10 Berners Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 3NP',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ['10 Berners Street',
#      'London W1T 3NP',
#      'United Kingdom']},
#    'phone': '+442077810000',
#    'display_phone': '+44 20 7781 0000',
#    'distance': 435.43985267437006},
#   {'id': 'G3cavZnRpyHjFWIOIfuozA',
#    'alias': 'the-cock-tavern-london-5',
#    'name': 'The Cock Tavern',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yyp0qAbfru1muje7baAiCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cock-tavern-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5167171, 'longitude': -0.1414124},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '27 Great Portland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 8QE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['27 Great Portland Street',
#      'London W1W 8QE',
#      'United Kingdom']},
#    'phone': '+442076315002',
#    'display_phone': '+44 20 7631 5002',
#    'distance': 575.4596396210071},
#   {'id': 'jGLj2JsYF8to11i934Aisw',
#    'alias': 'the-princess-victoria-london',
#    'name': 'The Princess Victoria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HAz99AqXfJRcIGgm2LgWyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-princess-victoria-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.506488400078,
#     'longitude': -0.24090795450115},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '217 Uxbridge Road',
#     'address2': 'Shepherds Bush',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W12 9DH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['217 Uxbridge Road',
#      'Shepherds Bush',
#      'London W12 9DH',
#      'United Kingdom']},
#    'phone': '+442087494466',
#    'display_phone': '+44 20 8749 4466',
#    'distance': 7297.496506772882},
#   {'id': 'eN_knU-P9rwnID4_2YA0Ng',
#    'alias': 'iron-duke-london',
#    'name': 'Iron Duke',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TzCWGDjbqKWl4P72Y_-uSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/iron-duke-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512679, 'longitude': -0.145981},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Avery Row',
#     'address2': 'Mayfair',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 4AN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Avery Row',
#      'Mayfair',
#      'London W1K 4AN',
#      'United Kingdom']},
#    'phone': '+442076291643',
#    'display_phone': '+44 20 7629 1643',
#    'distance': 693.0331286567847},
#   {'id': 'j0XQt-btOBlQVaUmd8oRqg',
#    'alias': 'kings-arms-london-2',
#    'name': 'Kings Arms',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wAxDS3MRattvlHMdsMhFXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kings-arms-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gaybars', 'title': 'Gay Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515364536904,
#     'longitude': -0.13738286424908},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '23 Poland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23 Poland Street',
#      'London W1F 8QJ',
#      'United Kingdom']},
#    'phone': '+442077345907',
#    'display_phone': '+44 20 7734 5907',
#    'distance': 298.04810195734046},
#   {'id': 'gkLoTapECbuQ4ekyEmAg2g',
#    'alias': 'the-masons-arms-london',
#    'name': "The Mason's Arms",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-ftVTxrJ6N4A_SONOyxFkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-masons-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514749847562,
#     'longitude': -0.16103720744705},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '51 Upper Berkeley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7QW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Upper Berkeley Street',
#      'London W1H 7QW',
#      'United Kingdom']},
#    'phone': '+442077232131',
#    'display_phone': '+44 20 7723 2131',
#    'distance': 1748.6231307481023},
#   {'id': 'U_71ZadYKpRQH3a3brJldg',
#    'alias': 'the-footman-london',
#    'name': 'The Footman',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wHVZ3ZnSg1UYK8X6WiQtBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-footman-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.508493408063,
#     'longitude': -0.14612577314659},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5 Charles Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 5DF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Charles Street',
#      'London W1J 5DF',
#      'United Kingdom']},
#    'phone': '+442074992988',
#    'display_phone': '+44 20 7499 2988',
#    'distance': 853.4961697235703},
#   {'id': 'n_oGHFO88muDRn6vgQLjqw',
#    'alias': 'princess-louise-london-2',
#    'name': 'Princess Louise',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QE9E6yLWz7vbB9IZ2Q_Flw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/princess-louise-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 131,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.517294236118,
#     'longitude': -0.12157103373648},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '208 High Holborn',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1V 7BW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['208 High Holborn',
#      'London WC1V 7BW',
#      'United Kingdom']},
#    'phone': '+442074058816',
#    'display_phone': '+44 20 7405 8816',
#    'distance': 1112.028049897214},
#   {'id': 'cVnVLLqgJkOf75I7wJ6kMg',
#    'alias': 'the-crown-london-9',
#    'name': 'The Crown',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0pD8Za7zjwWJMkMoywqYNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-crown-london-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511215, 'longitude': -0.136329},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '64 Brewer Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9TP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['64 Brewer Street',
#      'London W1F 9TP',
#      'United Kingdom']},
#    'phone': '+442074329711',
#    'display_phone': '+44 20 7432 9711',
#    'distance': 182.0347945951368},
#   {'id': 'Lfhb267w4FGa3kiaT8SoEA',
#    'alias': 'the-lamb-london',
#    'name': 'The Lamb',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XZS5Naon39Pd7UaKMgm1Nw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lamb-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5233037072011,
#     'longitude': -0.119153724223369},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '92-94 Lambs Conduit Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 3LZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['92-94 Lambs Conduit Street',
#      'London WC1N 3LZ',
#      'United Kingdom']},
#    'phone': '+442074050713',
#    'display_phone': '+44 20 7405 0713',
#    'distance': 1645.1504914517332},
#   {'id': '1LuM8aJI8qDOlJC1JFTyYw',
#    'alias': 'stags-head-london',
#    'name': 'Stags Head',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uz_5DoTyMYIyV-RBZQXj5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stags-head-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5362615, 'longitude': -0.0802206},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '55 Orsman Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 5RA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55 Orsman Road', 'London N1 5RA', 'United Kingdom']},
#    'phone': '+442077395186',
#    'display_phone': '+44 20 7739 5186',
#    'distance': 4631.529023920304},
#   {'id': 'GwUpy8KMGxBNoQKlqnLJ3A',
#    'alias': 'the-dragon-bar-london-3',
#    'name': 'The Dragon Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/K-AkGHBE7nn7A4hfBzE4pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dragon-bar-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.52627, 'longitude': -0.0781649},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '138-139 Shoreditch High Street',
#     'address2': 'Shoreditch',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6JE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['138-139 Shoreditch High Street',
#      'Shoreditch',
#      'London E1 6JE',
#      'United Kingdom']},
#    'phone': '+442070330325',
#    'display_phone': '+44 20 7033 0325',
#    'distance': 4262.334200280141},
#   {'id': 'euBJIN5rPU9o41LK58uMzg',
#    'alias': 'the-walrus-bar-and-hostel-london-2',
#    'name': 'The Walrus Bar and Hostel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9mRJ7xT3OFzF5-5eq6i2WQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-walrus-bar-and-hostel-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.499962539179,
#     'longitude': -0.11444486609041},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '172 Westminster Bridge Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7RW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['172 Westminster Bridge Road',
#      'London SE1 7RW',
#      'United Kingdom']},
#    'phone': '+442079284368',
#    'display_phone': '+44 20 7928 4368',
#    'distance': 2065.28869051317},
#   {'id': 'sFSu1BXSCYegYehJt2wa8Q',
#    'alias': 'heist-bank-london',
#    'name': 'Heist Bank',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sv2Io4zA3BAPLJwftDjgbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heist-bank-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5187950094017, 'longitude': -0.176081},
#    'transactions': [],
#    'location': {'address1': '5 North Wharf Road',
#     'address2': 'Paddington',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 1LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 North Wharf Road',
#      'Paddington',
#      'London W2 1LA',
#      'United Kingdom']},
#    'phone': '+442077238080',
#    'display_phone': '+44 20 7723 8080',
#    'distance': 2854.5004035371967},
#   {'id': 'DWPtpdsU6mIMzRUouGklBQ',
#    'alias': 'the-worlds-end-london-2',
#    'name': "The World's End",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r0tYqO0UL3b7gP3cT4KNrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-worlds-end-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 115,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.539470248288,
#     'longitude': -0.14222360058202},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '174 Camden High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 0NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['174 Camden High Street',
#      'London NW1 0NE',
#      'United Kingdom']},
#    'phone': '+442074821932',
#    'display_phone': '+44 20 7482 1932',
#    'distance': 2993.2170312903895},
#   {'id': 'Knha-8wa2_RPavK_o9qfQQ',
#    'alias': 'simpsons-tavern-london-2',
#    'name': 'Simpsons Tavern',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FOeBcE7ikfpDv23RWwyxkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/simpsons-tavern-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5131443111499,
#     'longitude': -0.0860142708131661},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Ballcourt 38 1/2 Cornhill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3V 9DR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Ballcourt 38 1/2 Cornhill',
#      'London EC3V 9DR',
#      'United Kingdom']},
#    'phone': '+442076269985',
#    'display_phone': '+44 20 7626 9985',
#    'distance': 3456.1580791156907},
#   {'id': 'P33NBF3mTAgFYLmtMljuzg',
#    'alias': 'flight-club-london',
#    'name': 'Flight Club',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5qK6wUWCZdtriKr8AYLaqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flight-club-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.522064813494,
#     'longitude': -0.0865259200196924},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Alphabeta Building',
#     'address2': '2A Worship Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 2AH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Alphabeta Building',
#      '2A Worship Street',
#      'London EC2A 2AH',
#      'United Kingdom']},
#    'phone': '+442030193093',
#    'display_phone': '+44 20 3019 3093',
#    'distance': 3570.8922087004435},
#   {'id': 'TsMWNMU27qcU_MtMdKMmzQ',
#    'alias': 'the-coach-makers-arms-marylebone-london',
#    'name': 'The Coach Makers Arms Marylebone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/30SbQNU7ppNsDjsg05v3Lw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-coach-makers-arms-marylebone-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5172137, 'longitude': -0.1505589},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '88 Marylebone Lane',
#     'address2': 'Marylebone',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 2PY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['88 Marylebone Lane',
#      'Marylebone',
#      'London W1U 2PY',
#      'United Kingdom']},
#    'phone': '+442072244022',
#    'display_phone': '+44 20 7224 4022',
#    'distance': 1124.1354677013858},
#   {'id': 'JbZXAQ3EimZ4K6Ny-apVlg',
#    'alias': 'the-duke-of-york-london-5',
#    'name': 'THE DUKE OF YORK',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Y7jwk9ergS5pkOHweqapxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-duke-of-york-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5175398, 'longitude': -0.16401636},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '45 Harrowby st',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 5HT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Harrowby st', 'London W1H 5HT', 'United Kingdom']},
#    'phone': '+442077231966',
#    'display_phone': '+44 20 7723 1966',
#    'distance': 2010.9403921409748},
#   {'id': 'ix9s2bJUR8LMz_73dJY3AA',
#    'alias': 'mr-foggs-society-of-exploration-london',
#    'name': "Mr Fogg's Society of Exploration",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8rzIbVqny4RyNumcxZd15Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-foggs-society-of-exploration-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5098205986884,
#     'longitude': -0.123694593570477},
#    'transactions': [],
#    'location': {'address1': '1A Bedford St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2E 9HH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1A Bedford St', 'London WC2E 9HH', 'United Kingdom']},
#    'phone': '+442075905255',
#    'display_phone': '+44 20 7590 5255',
#    'distance': 912.3412315070655},
#   {'id': 'IxcsElXRIDvLWoD-jUUTbA',
#    'alias': 'the-globe-london-4',
#    'name': 'The Globe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TO3AcCSfSN3PNHnrG8LQIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-globe-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5225831154429,
#     'longitude': -0.165593952402464},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '47 Lisson Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 6UB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Lisson Grove',
#      'London NW1 6UB',
#      'United Kingdom']},
#    'phone': '+442077232680',
#    'display_phone': '+44 20 7723 2680',
#    'distance': 2319.578208679152},
#   {'id': 'aPfg25ZHYizYDfUMjELX6A',
#    'alias': 'the-black-dog-london',
#    'name': 'The Black Dog',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qABc2C8Wvy7hKjzrq4ySfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-black-dog-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.488721108267,
#     'longitude': -0.12091580684024},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '112 Vauxhall Walk',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE11 5ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['112 Vauxhall Walk',
#      'London SE11 5ER',
#      'United Kingdom']},
#    'phone': '+442077354440',
#    'display_phone': '+44 20 7735 4440',
#    'distance': 2876.4026116593195},
#   {'id': 'iV1g7WoK2E23r4CC8RpdoQ',
#    'alias': 'the-barley-mow-london-5',
#    'name': 'The Barley Mow',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/smdKK3dju29qOCb699saSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-barley-mow-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5127484, 'longitude': -0.1510221},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '82 Duke Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 6JF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['82 Duke Street', 'London W1K 6JF', 'United Kingdom']},
#    'phone': '+442076295604',
#    'display_phone': '+44 20 7629 5604',
#    'distance': 1042.6467295323362},
#   {'id': 'j8UOiyiEvwdnrva3kXmcyg',
#    'alias': 'the-grosvenor-london-2',
#    'name': 'The Grosvenor',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fk2s3JZQxmQyfECcAmuIXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grosvenor-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4865902888953,
#     'longitude': -0.131570059362001},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '79 Grosvenor Road',
#     'address2': 'Pimlico',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1V 3LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['79 Grosvenor Road',
#      'Pimlico',
#      'London SW1V 3LA',
#      'United Kingdom']},
#    'phone': '+442078218786',
#    'display_phone': '+44 20 7821 8786',
#    'distance': 2934.0814788659195},
#   {'id': 'hXWtuKNmbVzAYtoZhNLLPw',
#    'alias': 'connaught-bar-london',
#    'name': 'Connaught Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ITro8OzOKISsn64bw2Xxqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/connaught-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 66,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5101556, 'longitude': -0.1496314},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'The Connaught',
#     'address2': 'Carlos Place',
#     'address3': 'Mayfair',
#     'city': 'London',
#     'zip_code': 'W1K 2AL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Connaught',
#      'Carlos Place',
#      'Mayfair',
#      'London W1K 2AL',
#      'United Kingdom']},
#    'phone': '+442073143419',
#    'display_phone': '+44 20 7314 3419',
#    'distance': 992.1974132195033},
#   {'id': 'y__iD3k2p4Xm0Xl_tSSNZg',
#    'alias': 'holly-bush-london',
#    'name': 'Holly Bush',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/A1ESayCy7xj7xcE0p_1Pew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holly-bush-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5579124, 'longitude': -0.1793261},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Holly Mount',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 6SG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Holly Mount', 'London NW3 6SG', 'United Kingdom']},
#    'phone': '+442074352892',
#    'display_phone': '+44 20 7435 2892',
#    'distance': 5836.476390811221},
#   {'id': 'JBXyL6t5OmxJN7GEZD3c7Q',
#    'alias': 'ye-olde-cock-tavern-london',
#    'name': 'Ye Olde Cock Tavern',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/37bMxtEOybKfkTfBt25D6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ye-olde-cock-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.513687, 'longitude': -0.110501},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Fleet Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4Y 1AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Fleet Street',
#      'London EC4Y 1AA',
#      'United Kingdom']},
#    'phone': '+442073538570',
#    'display_phone': '+44 20 7353 8570',
#    'distance': 1764.9385826237367},
#   {'id': 'NyGG3SHQGrjmP1zoBLhubQ',
#    'alias': 'the-cow-london',
#    'name': 'The Cow',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DXu5ms-0aoG_Y68nxaMraw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cow-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.519244332609,
#     'longitude': -0.19526811734486},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '89 Westbourne Park Road',
#     'address2': 'Westbourne Grove',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 5QH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['89 Westbourne Park Road',
#      'Westbourne Grove',
#      'London W2 5QH',
#      'United Kingdom']},
#    'phone': '+442072210021',
#    'display_phone': '+44 20 7221 0021',
#    'distance': 4165.584782674144},
#   {'id': 'lJ5q7EkXvKtku0aUgsTrAw',
#    'alias': 'the-harrison-london',
#    'name': 'The Harrison',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y6ZdflLpGSwRiGuycPdzjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-harrison-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.527533751588, 'longitude': -0.1206015435123},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '28 Harrison Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 8JF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28 Harrison Street',
#      'London WC1H 8JF',
#      'United Kingdom']},
#    'phone': '+442072783966',
#    'display_phone': '+44 20 7278 3966',
#    'distance': 1949.296955926065},
#   {'id': '-clnu6vMMIc4616znY_fbA',
#    'alias': 'the-gloucester-london',
#    'name': 'The Gloucester',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/e1sbiG4q6tLvKnA7AKFGWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-gloucester-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4999756, 'longitude': -0.1595376},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '187 Sloane Street',
#     'address2': 'Knightsbridge',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 9QR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['187 Sloane Street',
#      'Knightsbridge',
#      'London SW1X 9QR',
#      'United Kingdom']},
#    'phone': '+442072350298',
#    'display_phone': '+44 20 7235 0298',
#    'distance': 2174.240830263591},
#   {'id': 'owHIUnK6hxEdiISX2DnIdg',
#    'alias': 'founders-arms-london',
#    'name': 'Founders Arms',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-bWELxqv2DUyxDAcrulnXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/founders-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 101,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.508561647029,
#     'longitude': -0.10155056446805},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '52 Hopton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9JH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['52 Hopton Street',
#      'London SE1 9JH',
#      'United Kingdom']},
#    'phone': '+442079281899',
#    'display_phone': '+44 20 7928 1899',
#    'distance': 2427.949349807966}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                       Restaurant        Type Price Rating            Address  \
# 0              The Craft Beer Co        Pubs    ££    4.5   168 High Holborn
# 1              The Cock and Lion        Pubs     £    3.5      66 Wigmore St
# 2          The Crown and Sceptre  Gastropubs    ££    4.5    34 Holland Road
# 3  The Alfred Tennyson Belgravia     British    ££      4  10 Motcomb Street
# 4                    Queens Head        Pubs    ££    4.5    66 Acton Street
#
#          Lat       Lng                                                url  \
# 0  51.515750 -0.125786  https://www.yelp.com/biz/the-craft-beer-co-lon...
# 1  51.516306 -0.149841  https://www.yelp.com/biz/the-cock-and-lion-lon...
# 2  51.497966 -0.207440  https://www.yelp.com/biz/the-crown-and-sceptre...
# 3  51.499631 -0.156411  https://www.yelp.com/biz/the-alfred-tennyson-b...
# 4  51.528421 -0.118503  https://www.yelp.com/biz/queens-head-london-6?...
#
#                        ID
# 0  TYCrKfYC7Zo14xmi8CIGtw
# 1  wuuCbT901SC0N-LvzkG8jA
# 2  GD4LetX9pdn3fvDigFPjiA
# 3  1c60bGFaWOhq_ra06w9daQ
# 4  ztxaksJUXyy7jm85Q1xiSw

# %%
#3rd set of 50 records 101-150
lndr_params3 = {"term":"pub","location":"London","limit":50,"offset":101}
lndr_response3 = requests.get(search_api_url, headers=headers, params=lndr_params3)
lndr3 = lndr_response3.json()
display(lndr3)
#print(lndr_response3.url)
#print(lndr_response3.status_code)
# Out:
# {'businesses': [{'id': '-uzz2p0W3eDAOqSBHgw-fQ',
#    'alias': 'lamb-and-flag-london-2',
#    'name': 'Lamb & Flag',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Hn89mPLKJtttNXdxqg0yiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lamb-and-flag-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 139,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511695614013,
#     'longitude': -0.12572690505399},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '33 Rose Street',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 9EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['33 Rose Street',
#      'Covent Garden',
#      'London WC2E 9EB',
#      'United Kingdom']},
#    'phone': '+442074979504',
#    'display_phone': '+44 20 7497 9504',
#    'distance': 719.1170647692165},
#   {'id': '6xmMCZKl6Zr2_iE1Qw-ilw',
#    'alias': 'paxtons-head-london',
#    'name': 'Paxtons Head',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x4bT89bzDMJjOhyStZEAkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paxtons-head-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5016, 'longitude': -0.16254},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '153 Knightsbridge',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7PA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['153 Knightsbridge',
#      'London SW1X 7PA',
#      'United Kingdom']},
#    'phone': '+442075896627',
#    'display_phone': '+44 20 7589 6627',
#    'distance': 2210.86164633511},
#   {'id': 'YKdPgX4jRyz5tfsF04eUYw',
#    'alias': 'the-churchill-bar-and-terrace-london',
#    'name': 'The Churchill Bar & Terrace',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/oN-UaVyWg6AoyR5RqB1paw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-churchill-bar-and-terrace-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5154357, 'longitude': -0.1569583},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '30 Portman Square',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1H 7BH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Portman Square',
#      'London W1H 7BH',
#      'United Kingdom']},
#    'phone': '+442072992035',
#    'display_phone': '+44 20 7299 2035',
#    'distance': 1497.0881132274078},
#   {'id': '75-HeBBB391Np6T7GdJ5xQ',
#    'alias': 'the-ivy-london',
#    'name': 'The Ivy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rVk4F439o22SXXzGGHKGRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ivy-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 171,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512814, 'longitude': -0.128013},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1 - 5 West Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9NQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 - 5 West Street',
#      'London WC2H 9NQ',
#      'United Kingdom']},
#    'phone': '+442078364751',
#    'display_phone': '+44 20 7836 4751',
#    'distance': 549.6549455465449},
#   {'id': '9qTCHY5yzNo7Vqbv4W0a6Q',
#    'alias': 'star-tavern-london',
#    'name': 'Star Tavern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Mkk2SGn8CPAtg3Tlevr7ww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/star-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4983045, 'longitude': -0.1557526},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 Belgrave Mews West',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 8HT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Belgrave Mews West',
#      'London SW1X 8HT',
#      'United Kingdom']},
#    'phone': '+442072353019',
#    'display_phone': '+44 20 7235 3019',
#    'distance': 2113.363716472156},
#   {'id': 'TKrgGHkG3zZQyHbXLWVGiA',
#    'alias': 'the-grapes-london',
#    'name': 'The Grapes',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/38B4N_cfX-XvOEr_tmb_iQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grapes-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 52,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.508878565194,
#     'longitude': -0.033953656209499},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '76 Narrow Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E14 8BP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['76 Narrow Street',
#      'London E14 8BP',
#      'United Kingdom']},
#    'phone': '+442079874396',
#    'display_phone': '+44 20 7987 4396',
#    'distance': 7072.645818652105},
#   {'id': 'Fbt8YC8OQmBF2J4_vDdHhw',
#    'alias': 'simpsons-in-the-strand-london',
#    'name': "Simpson's in the Strand",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PIrsQTdry-qV7gTEoWYhwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/simpsons-in-the-strand-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 79,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5105687, 'longitude': -0.1206719},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '100 Strand',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2R 0EW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['100 Strand', 'London WC2R 0EW', 'United Kingdom']},
#    'phone': '+442074202111',
#    'display_phone': '+44 20 7420 2111',
#    'distance': 1087.3061141000965},
#   {'id': 'lOXgPapia7GItOVQQlIHMg',
#    'alias': 'the-white-hart-london',
#    'name': 'The White Hart',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yZT9xfNFISXdbWzsbfz90A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-white-hart-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.520242, 'longitude': -0.056246},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Mile End Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 4TP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Mile End Road', 'London E1 4TP', 'United Kingdom']},
#    'phone': '+442077902894',
#    'display_phone': '+44 20 7790 2894',
#    'distance': 5576.688385429917},
#   {'id': 'SjK7ZPrjx6YVczuu4EQ9Zg',
#    'alias': 'royal-oak-london',
#    'name': 'Royal Oak',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AmKrn6SzUyT2P-TidicFcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/royal-oak-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5295433651224,
#     'longitude': -0.0692570344313651},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '73 Columbia Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7RG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['73 Columbia Road',
#      'London E2 7RG',
#      'United Kingdom']},
#    'phone': '+442077292220',
#    'display_phone': '+44 20 7729 2220',
#    'distance': 4974.696179797314},
#   {'id': 'D2rZgP8lFv1zwnQwQHm5cw',
#    'alias': 'the-sands-end-london',
#    'name': 'The Sands End',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/edihFJRSuS_KrigBJ2Pjug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-sands-end-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4712001, 'longitude': -0.1871549},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '135-137 Stephendale Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 2PR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['135-137 Stephendale Road',
#      'London SW6 2PR',
#      'United Kingdom']},
#    'phone': '+442077317823',
#    'display_phone': '+44 20 7731 7823',
#    'distance': 5842.820744861494},
#   {'id': 'mxFv2t92_sTjxeCPqnHK0A',
#    'alias': 'sussex-arms-london',
#    'name': 'Sussex Arms',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PN8Z0dgs8Q2osw7CDfp_1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sussex-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5150909, 'longitude': -0.1739967},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '21 London Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21 London Street',
#      'London W2 1HL',
#      'United Kingdom']},
#    'phone': '+442077231026',
#    'display_phone': '+44 20 7723 1026',
#    'distance': 2634.162879183608},
#   {'id': 'erZKvShXshTiKVzYCS-uLQ',
#    'alias': 'king-charles-i-london',
#    'name': 'King Charles I',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Xvd7_aNQIjY6nc4L1APOOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/king-charles-i-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5324330139593,
#     'longitude': -0.119722939541498},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '55-57 Northdown Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9BL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55-57 Northdown Street',
#      'London N1 9BL',
#      'United Kingdom']},
#    'phone': '+442078377758',
#    'display_phone': '+44 20 7837 7758',
#    'distance': 2451.524820864812},
#   {'id': '9ACXZe3N9ATCGnpTErRnGA',
#    'alias': 'the-cavendish-marylebone',
#    'name': 'The Cavendish',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GXgExhYEb37L7d8-BVQPvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cavendish-marylebone?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5190291, 'longitude': -0.1498081},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '35 New Cavendish Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Marylebone',
#     'zip_code': 'W1G 9TR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35 New Cavendish Street',
#      'Marylebone W1G 9TR',
#      'United Kingdom']},
#    'phone': '+442074873030',
#    'display_phone': '+44 20 7487 3030',
#    'distance': 1178.6712335900593},
#   {'id': '5_M0-o3mU88yRpsLB3Rcqw',
#    'alias': 'ye-olde-swiss-cottage-london',
#    'name': 'Ye Olde Swiss Cottage',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HOkf2auzPxdC2CCPuh67DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ye-olde-swiss-cottage-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.542696, 'longitude': -0.1748242},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '98 Finchley Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 5EL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['98 Finchley Road',
#      'London NW3 5EL',
#      'United Kingdom']},
#    'phone': '+442077223487',
#    'display_phone': '+44 20 7722 3487',
#    'distance': 4281.279893576327},
#   {'id': 'GQkVrn-BXPh-VSZ_fy60Bg',
#    'alias': 'the-crown-and-anchor-london-4',
#    'name': 'The Crown & Anchor',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ITHJwohhHXIbOg16WDob6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-crown-and-anchor-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.526862625298,
#     'longitude': -0.13713131689699},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '137 Drummond Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 2HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['137 Drummond Street',
#      'London NW1 2HL',
#      'United Kingdom']},
#    'phone': '+442073832681',
#    'display_phone': '+44 20 7383 2681',
#    'distance': 1561.860235589365},
#   {'id': 'jkHCQ0X_oiMLxvI16XWUjQ',
#    'alias': 'o-neills-london-8',
#    'name': "O'Neill's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Nv7j1CBNdXw8mSMbBq2HOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/o-neills-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5289389, 'longitude': -0.1262226},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '73-77 Euston Road',
#     'address2': '',
#     'address3': 'Marylebone',
#     'city': 'London',
#     'zip_code': 'NW1 2QS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['73-77 Euston Road',
#      'Marylebone',
#      'London NW1 2QS',
#      'United Kingdom']},
#    'phone': '+442073800464',
#    'display_phone': '+44 20 7380 0464',
#    'distance': 1913.9171909299064},
#   {'id': 'T3-MDiueFueqiNv7o_RzCg',
#    'alias': 'the-toucan-london',
#    'name': 'The Toucan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/u2ojdqyW-Ralc6z6QsnjgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-toucan-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'irish', 'title': 'Irish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5151013043723,
#     'longitude': -0.133124215362068},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '19 Carlisle Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 3BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Carlisle Street',
#      'London W1D 3BY',
#      'United Kingdom']},
#    'phone': '+442074374123',
#    'display_phone': '+44 20 7437 4123',
#    'distance': 319.1700260155866},
#   {'id': 'kkJFhs9Tp8ASLXJCV_kqnA',
#    'alias': 'the-cockpit-london',
#    'name': 'The Cockpit',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GGnF8gj8feeMIysMR8Klog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cockpit-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5129302, 'longitude': -0.1013312},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "7 St Andrew's Hill",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4V 5BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["7 St Andrew's Hill",
#      'London EC4V 5BY',
#      'United Kingdom']},
#    'phone': '+442072487315',
#    'display_phone': '+44 20 7248 7315',
#    'distance': 2387.965504455212},
#   {'id': '_abTj0y321OwKVLx5X1LUw',
#    'alias': 'elephants-head-london',
#    'name': 'Elephants Head',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/95x3kCsvpu82zlZNck4IFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elephants-head-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5407487, 'longitude': -0.1439448},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '224 Camden High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8QR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['224 Camden High Street',
#      'London NW1 8QR',
#      'United Kingdom']},
#    'phone': '+442074853130',
#    'display_phone': '+44 20 7485 3130',
#    'distance': 3152.6223438930274},
#   {'id': 'fNvaEe2gZ4TwJzHJDUM7ZA',
#    'alias': 'fullers-london',
#    'name': 'Fullers',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yqvVJfqrolnO23FnvvlSGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fullers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4997260189768,
#     'longitude': -0.132075380273069},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '45 Tothill Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1H',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Tothill Street', 'London SW1H', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1482.2425026507717},
#   {'id': '3yvDAVKLDtsXZEHrskuobA',
#    'alias': 'the-lyric-london',
#    'name': 'The Lyric',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6b6WZXvrlCYJdqksILAuPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lyric-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.511283, 'longitude': -0.134466},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '37 Great Windmill Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 7LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['37 Great Windmill Street',
#      'Soho',
#      'London W1D 7LT',
#      'United Kingdom']},
#    'phone': '+442074340604',
#    'display_phone': '+44 20 7434 0604',
#    'distance': 200.29114916089154},
#   {'id': 'AJw--QOr-isUzLor7Er6iA',
#    'alias': 'spread-eagle-london',
#    'name': 'Spread Eagle',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/68hCWv3seE7QMUz4fBFv8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spread-eagle-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.537645455254,
#     'longitude': -0.14489810718948},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '141 Albert Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 7NB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['141 Albert Street',
#      'London NW1 7NB',
#      'United Kingdom']},
#    'phone': '+442072671410',
#    'display_phone': '+44 20 7267 1410',
#    'distance': 2827.2506487104674},
#   {'id': 'ipV5A82oNd0X4xyC1u02MA',
#    'alias': 'the-bull-london-5',
#    'name': 'The Bull',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rtbm3ZA0wsK6I-eHpRrFOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bull-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.537467622288,
#     'longitude': -0.10305190851333},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '100 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 0NP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['100 Upper Street',
#      'London N1 0NP',
#      'United Kingdom']},
#    'phone': '+442073549174',
#    'display_phone': '+44 20 7354 9174',
#    'distance': 3561.424245946536},
#   {'id': 'AuRbCdbDEetUNlF6mIJpng',
#    'alias': 'the-george-tavern-london',
#    'name': 'The George Tavern',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BjrZ5ZSRLJVT7DUeUw1mIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-george-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514333, 'longitude': -0.053114},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '373 Commercial Road',
#     'address2': 'Stepney',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 0LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['373 Commercial Road',
#      'Stepney',
#      'London E1 0LA',
#      'United Kingdom']},
#    'phone': '+442077907335',
#    'display_phone': '+44 20 7790 7335',
#    'distance': 5735.050752699368},
#   {'id': '-nLG7F_nYvKp9u_OxVZqcw',
#    'alias': 'red-lion-london-2',
#    'name': 'Red Lion',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Xc2mVaSNPKLISqe8PnSFrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/red-lion-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.508239, 'longitude': -0.136492},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Duke of York Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 6JP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Duke of York Street',
#      'London SW1Y 6JP',
#      'United Kingdom']},
#    'phone': '+442073210782',
#    'display_phone': '+44 20 7321 0782',
#    'distance': 505.4152937782669},
#   {'id': '0VDHiSAtbs3HItL8e3sL6Q',
#    'alias': 'portobello-star-london',
#    'name': 'Portobello Star',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pBHFdNacXeiNl7BkWW_hjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/portobello-star-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5147664, 'longitude': -0.2045765},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '171 Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['171 Portobello Road',
#      'London W11 2DY',
#      'United Kingdom']},
#    'phone': '+442072298220',
#    'display_phone': '+44 20 7229 8220',
#    'distance': 4748.423513054586},
#   {'id': '3OM4EiPjyk4Xn6ACoAEqiw',
#    'alias': 'the-speaker-london',
#    'name': 'The Speaker',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NhIMkVtpECeISzHb8sjOMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-speaker-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.496763151387,
#     'longitude': -0.13323024067782},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '46 Great Peter Street',
#     'address2': 'Westminster',
#     'address3': 'London',
#     'city': 'London',
#     'zip_code': 'SW1P 2HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['46 Great Peter Street',
#      'Westminster',
#      'London',
#      'London SW1P 2HA',
#      'United Kingdom']},
#    'phone': '+442072221749',
#    'display_phone': '+44 20 7222 1749',
#    'distance': 1797.092693119931},
#   {'id': 'sfSLpV-gKIpHbYrcqTDJPQ',
#    'alias': 'the-black-heart-london',
#    'name': 'The Black Heart',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sIDT0c1cNCg4x6F4Fdb9nw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-black-heart-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.538782, 'longitude': -0.141835},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2-3 Greenland Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 0AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2-3 Greenland Place',
#      'London NW1 0AP',
#      'United Kingdom']},
#    'phone': '+442074289730',
#    'display_phone': '+44 20 7428 9730',
#    'distance': 2914.7765394864196},
#   {'id': '9ad4tZB0Mp-tNnXLZwYvUA',
#    'alias': 'the-anchor-and-hope-london',
#    'name': 'The Anchor and Hope',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IfWn4BAl8A0ZUtccQ_OyeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-anchor-and-hope-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 114,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.503472834404,
#     'longitude': -0.10658608333864},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '36 The Cut',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['36 The Cut', 'London SE1 8LP', 'United Kingdom']},
#    'phone': '+442079289898',
#    'display_phone': '+44 20 7928 9898',
#    'distance': 2283.7243941691772},
#   {'id': 'pWztU2_yJtspXikeS3XJUQ',
#    'alias': 'the-clifton-london',
#    'name': 'The Clifton',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/r9qcaY10yId2kx4ySE52dA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-clifton-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5358935277519,
#     'longitude': -0.185162946581841},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '96 Clifton Hill',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW8 0JT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['96 Clifton Hill',
#      'London NW8 0JT',
#      'United Kingdom']},
#    'phone': '+442076255010',
#    'display_phone': '+44 20 7625 5010',
#    'distance': 4261.819564891763},
#   {'id': 'fsM7gx4iZvKZXdjC8kMhkQ',
#    'alias': 'fountains-abbey-london',
#    'name': 'Fountains Abbey',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i8m7uKlprki5G-PtSq9pHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fountains-abbey-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5169984026106,
#     'longitude': -0.172877321583189},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '109 Praed Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['109 Praed Street',
#      'London W2 1RL',
#      'United Kingdom']},
#    'phone': '+442077232364',
#    'display_phone': '+44 20 7723 2364',
#    'distance': 2596.479266709719},
#   {'id': 'KibX1drMsr4bmfFYj5BkMw',
#    'alias': 'the-crobar-london',
#    'name': 'The Crobar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Qg-WAbZNXeHWd16ZuxELjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-crobar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'danceclubs', 'title': 'Dance Clubs'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514867642482,
#     'longitude': -0.13033772564174},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '17 Manette Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 4AS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17 Manette Street',
#      'London W1D 4AS',
#      'United Kingdom']},
#    'phone': '+442074390831',
#    'display_phone': '+44 20 7439 0831',
#    'distance': 449.665379262671},
#   {'id': 'uLzw0JetLd_Gnogh2ThxaQ',
#    'alias': 'the-mad-bishop-and-bear-london',
#    'name': 'The Mad Bishop & Bear',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UXfNIxc1i_zCa8exq_r_LA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mad-bishop-and-bear-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5158626309597,
#     'longitude': -0.176841472348542},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1st Floor',
#     'address2': 'Paddington Station',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1HB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1st Floor',
#      'Paddington Station',
#      'London W2 1HB',
#      'United Kingdom']},
#    'phone': '+442074022441',
#    'display_phone': '+44 20 7402 2441',
#    'distance': 2849.182931431834},
#   {'id': 'nu0-8B3sQn-DeY3vKqe7Zg',
#    'alias': 'back-room-london',
#    'name': 'Back Room',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vgdUOtdMwaalANPX-V3zfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/back-room-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.504073, 'longitude': -0.149328},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '148B Old Park Lane',
#     'address2': 'London',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 1QY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['148B Old Park Lane',
#      'London',
#      'London W1K 1QY',
#      'United Kingdom']},
#    'phone': '+442075141700',
#    'display_phone': '+44 20 7514 1700',
#    'distance': 1344.0821029332615},
#   {'id': 'jWv5TAis6tiZTpMoiPnJUg',
#    'alias': 'the-culpeper-london',
#    'name': 'The Culpeper',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-sLgVp5Spw03RDlveDdZsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-culpeper-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5169119, 'longitude': -0.0730395},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '40 Commercial Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 Commercial Street',
#      'London E1 6LP',
#      'United Kingdom']},
#    'phone': '+442072475371',
#    'display_phone': '+44 20 7247 5371',
#    'distance': 4377.202205411278},
#   {'id': 'ySM7A1ljKIthN6ckAYdN5g',
#    'alias': 'the-marquis-of-westminster-london',
#    'name': 'The Marquis of Westminster',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JQVTZHnF8TRJ-UJQVWfpzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-marquis-of-westminster-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 121,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.491901, 'longitude': -0.140515},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '50 Warwick Way',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1RY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50 Warwick Way',
#      'London SW1V 1RY',
#      'United Kingdom']},
#    'phone': '+442078281700',
#    'display_phone': '+44 20 7828 1700',
#    'distance': 2360.251869923125},
#   {'id': 'Av34TC4A3CsJaS99F73mog',
#    'alias': 'the-horse-and-stables-london',
#    'name': 'The Horse and Stables',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ByjfjohbyQMmzAMuFp5KqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-horse-and-stables-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4991741615558,
#     'longitude': -0.112677261993705},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '122-124 Westminster Bridge Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7RW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['122-124 Westminster Bridge Road',
#      'London SE1 7RW',
#      'United Kingdom']},
#    'phone': '+442079286277',
#    'display_phone': '+44 20 7928 6277',
#    'distance': 2214.349961929356},
#   {'id': 'WKCjgA-yUXyG23A-lbphug',
#    'alias': 'the-dove-london-2',
#    'name': 'The Dove',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Svq8GxoJSUyAZzYS6absHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dove-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.490546348798,
#     'longitude': -0.23483216570651},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '19 Upper Mall',
#     'address2': 'Hammersmith',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W6 9TA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Upper Mall',
#      'Hammersmith',
#      'London W6 9TA',
#      'United Kingdom']},
#    'phone': '+442087489474',
#    'display_phone': '+44 20 8748 9474',
#    'distance': 7278.947425795405},
#   {'id': '-E5pZ_XXmQM9BCprahxnaw',
#    'alias': 'the-scarsdale-tavern-london',
#    'name': 'The Scarsdale Tavern',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KVaPS7Ar1d4fHs03VJxJiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-scarsdale-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.496972727492,
#     'longitude': -0.19898382361723},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '23a Edwardes Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 6HE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23a Edwardes Square',
#      'London W8 6HE',
#      'United Kingdom']},
#    'phone': '+442079371811',
#    'display_phone': '+44 20 7937 1811',
#    'distance': 4705.458140823339},
#   {'id': 'V8vti60yD3T18f6bd4i4uw',
#    'alias': 'sherlock-holmes-london',
#    'name': 'Sherlock Holmes',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3e21ivK6ajot9zedfZJMjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sherlock-holmes-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 196,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.507376, 'longitude': -0.125215},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10-11 Northumberland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 5DB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10-11 Northumberland Street',
#      'London WC2N 5DB',
#      'United Kingdom']},
#    'phone': '+442079302644',
#    'display_phone': '+44 20 7930 2644',
#    'distance': 962.5654421675805},
#   {'id': 'DSiQy7UTS-bY3ob_rtG5wQ',
#    'alias': 'the-swan-london-9',
#    'name': 'The Swan',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vw8FkYln1x1zxC_TRhUcZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-swan-london-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5211944580078,
#     'longitude': -0.122731000185013},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '7 Cosmo Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 3AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Cosmo Place', 'London WC1N 3AP', 'United Kingdom']},
#    'phone': '+44442078376223',
#    'display_phone': '+44 442078376223',
#    'distance': 1290.2871565330336},
#   {'id': 'TflE31sa_pWpCypgkhEh5w',
#    'alias': 'prince-albert-london-6',
#    'name': 'Prince Albert',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LfK1VfD0M54uwjOdGE0Khw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prince-albert-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.479641685779,
#     'longitude': -0.16578261514069},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '85 Albert Bridge Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW11 4PF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['85 Albert Bridge Road',
#      'London SW11 4PF',
#      'United Kingdom']},
#    'phone': '+442072280923',
#    'display_phone': '+44 20 7228 0923',
#    'distance': 4229.269397774381},
#   {'id': 'Ii_CsiiPkg0MzsZrVWSMwQ',
#    'alias': 'the-bird-in-hand-london-3',
#    'name': 'The Bird In Hand',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CMHN1DAX3ao2hSoFoTFbzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bird-in-hand-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.499761921973,
#     'longitude': -0.21544145627873},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '88 Masbro Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W14 0LR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['88 Masbro Road', 'London W14 0LR', 'United Kingdom']},
#    'phone': '+442073712721',
#    'display_phone': '+44 20 7371 2721',
#    'distance': 5690.099093804208},
#   {'id': '6DQ7aS2GW0lNYnAZrGgF_g',
#    'alias': 'duke-of-wellington-london-5',
#    'name': 'Duke Of Wellington',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1cp-jX57WQbL2DbVUbCuTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duke-of-wellington-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gaybars', 'title': 'Gay Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512306097343, 'longitude': -0.1330333719202},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '77 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6QA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['77 Wardour Street',
#      'London W1D 6QA',
#      'United Kingdom']},
#    'phone': '+442074391274',
#    'display_phone': '+44 20 7439 1274',
#    'distance': 210.6304848027643},
#   {'id': 'wlVpTY2Z_4fcI4iAGsQMpA',
#    'alias': 'the-elgin-london-2',
#    'name': 'The Elgin',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CGQH2TDmMe5tKwk76EQOWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-elgin-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5302529, 'longitude': -0.1858404},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '255 Elgin Avenue',
#     'address2': 'Maida Vale',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W9 1NJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['255 Elgin Avenue',
#      'Maida Vale',
#      'London W9 1NJ',
#      'United Kingdom']},
#    'phone': '+442076255511',
#    'display_phone': '+44 20 7625 5511',
#    'distance': 3957.656055541361},
#   {'id': 'gaiqW6X2V0IvvF5YRhDKGw',
#    'alias': 'the-ship-london',
#    'name': 'The Ship',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rJPCX3g4Iw76-lH3nhB5mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ship-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514035555048,
#     'longitude': -0.13426389935721},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '116 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0TT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['116 Wardour Street',
#      'London W1F 0TT',
#      'United Kingdom']},
#    'phone': '+442074378446',
#    'display_phone': '+44 20 7437 8446',
#    'distance': 177.5200104381783},
#   {'id': 'NsW-FrgdMkt41DfhtZlYtA',
#    'alias': 'the-carpenters-arms-london-2',
#    'name': 'The Carpenters Arms',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fhSgS4MXs_wvoFwquPGDcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-carpenters-arms-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.523959386643,
#     'longitude': -0.067309584978472},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '73 Cheshire Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 6EG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['73 Cheshire Street',
#      'London E2 6EG',
#      'United Kingdom']},
#    'phone': '+442077396342',
#    'display_phone': '+44 20 7739 6342',
#    'distance': 4908.213735114037},
#   {'id': 'A2TWupbkBAjXpXH-5ISPQA',
#    'alias': 'white-mustache-london',
#    'name': 'White Mustache',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bwo5uiS4TnqfrkfzA2KGAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/white-mustache-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.530285649474,
#     'longitude': -0.141171581404857},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '7A Stanhope Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 3RD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7A Stanhope Street',
#      'London NW1 3RD',
#      'United Kingdom']},
#    'phone': '+442073880944',
#    'display_phone': '+44 20 7388 0944',
#    'distance': 1973.6351576150394},
#   {'id': 'yyy49BegNOIij7uw7rEP6A',
#    'alias': 'royal-exchange-london',
#    'name': 'Royal Exchange',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4tZRq8avxyFfXAMtZM9owA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/royal-exchange-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5181759, 'longitude': -0.1697782},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '26 Sale Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1PU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Sale Place', 'London W2 1PU', 'United Kingdom']},
#    'phone': '+442077233781',
#    'display_phone': '+44 20 7723 3781',
#    'distance': 2420.0567544326564},
#   {'id': 'cgY_UsLFdcBRkMkR7HdIJw',
#    'alias': 'the-havelock-tavern-london',
#    'name': 'The Havelock Tavern',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WnPuwqs-98bhVvrPmPmfSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-havelock-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4989090272368,
#     'longitude': -0.216338917481596},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '57 Masbro Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W14 0LS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57 Masbro Road', 'London W14 0LS', 'United Kingdom']},
#    'phone': '+442076035374',
#    'display_phone': '+44 20 7603 5374',
#    'distance': 5774.928949726518}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                     Restaurant             Type Price  Rating  \
# 0                  Lamb & Flag             Pubs    ££     4.0
# 1                 Paxtons Head             Pubs    ££     3.5
# 2  The Churchill Bar & Terrace  Modern European  ££££     4.5
# 3                      The Ivy          British   £££     4.0
# 4                  Star Tavern             Pubs    ££     4.0
#
#                 Address        Lat       Lng  \
# 0        33 Rose Street  51.511696 -0.125727
# 1     153 Knightsbridge  51.501600 -0.162540
# 2     30 Portman Square  51.515436 -0.156958
# 3     1 - 5 West Street  51.512814 -0.128013
# 4  6 Belgrave Mews West  51.498305 -0.155753
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/lamb-and-flag-london-...  -uzz2p0W3eDAOqSBHgw-fQ
# 1  https://www.yelp.com/biz/paxtons-head-london?a...  6xmMCZKl6Zr2_iE1Qw-ilw
# 2  https://www.yelp.com/biz/the-churchill-bar-and...  YKdPgX4jRyz5tfsF04eUYw
# 3  https://www.yelp.com/biz/the-ivy-london?adjust...  75-HeBBB391Np6T7GdJ5xQ
# 4  https://www.yelp.com/biz/star-tavern-london?ad...  9qTCHY5yzNo7Vqbv4W0a6Q

# %%
#4th set of 50 records 151-200
lndr_params4 = {"term":"pub","location":"London","limit":50,"offset":151}
lndr_response4 = requests.get(search_api_url, headers=headers, params=lndr_params4)
lndr4 = lndr_response4.json()
display(lndr4)
#print(lndr_response4.url)
#print(lndr_response4.status_code)
# Out:
# {'businesses': [{'id': 'LcPnzwVLvDTYjjKsOHxyxQ',
#    'alias': 'golden-eagle-london-3',
#    'name': 'Golden Eagle',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/luG95Slvqcyccyt5-64wtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/golden-eagle-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5176461, 'longitude': -0.1508037},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '59 Marylebone Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 2NY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['59 Marylebone Lane',
#      'London W1U 2NY',
#      'United Kingdom']},
#    'phone': '+442079353228',
#    'display_phone': '+44 20 7935 3228',
#    'distance': 1158.338781706465},
#   {'id': 'b721gjWkPpG-Bcn17k41mg',
#    'alias': 'duke-of-edinburgh-london-2',
#    'name': 'Duke of Edinburgh',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/p98yPZZU8Ffm1HPOlu7u-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duke-of-edinburgh-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.463043717091,
#     'longitude': -0.12071344451921},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '204 Ferndale Road',
#     'address2': 'Brixton',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 8AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['204 Ferndale Road',
#      'Brixton',
#      'London SW9 8AG',
#      'United Kingdom']},
#    'phone': '+442073260301',
#    'display_phone': '+44 20 7326 0301',
#    'distance': 5636.276723656076},
#   {'id': 'vDYVC5x9dSwCOZ78iDsRsg',
#    'alias': 'royal-vauxhall-tavern-london',
#    'name': 'Royal Vauxhall Tavern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8eebszCiNa-LbXw6ETanWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/royal-vauxhall-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'theater', 'title': 'Performing Arts'},
#     {'alias': 'gaybars', 'title': 'Gay Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4860659, 'longitude': -0.121945},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '372 Kennington Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE11 5HY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['372 Kennington Lane',
#      'London SE11 5HY',
#      'United Kingdom']},
#    'phone': '+442078201222',
#    'display_phone': '+44 20 7820 1222',
#    'distance': 3102.9384693114534},
#   {'id': 'cUoWCiqRC1aGoRpfv1Co9A',
#    'alias': 'the-ship-london-11',
#    'name': 'The Ship',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vrSBGq3_vNtPphucXkCiyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ship-london-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.520411265955,
#     'longitude': -0.14078684872805},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '134 New Cavendish Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 6YB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['134 New Cavendish Street',
#      'London W1W 6YB',
#      'United Kingdom']},
#    'phone': '+442076366301',
#    'display_phone': '+44 20 7636 6301',
#    'distance': 906.286884354713},
#   {'id': 'wEJKOJ9Hc2FEEGq2UbaMQQ',
#    'alias': 'duke-of-kendal-london',
#    'name': 'Duke Of Kendal',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rAfIZgm1pGCQq4TL0y6N3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duke-of-kendal-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514587763527,
#     'longitude': -0.16622892139991},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '38 Connaught Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 2AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38 Connaught Street',
#      'London W2 2AF',
#      'United Kingdom']},
#    'phone': '+442077238478',
#    'display_phone': '+44 20 7723 8478',
#    'distance': 2103.927386637284},
#   {'id': 'aAGDecm8DlOTVADNjxyXMg',
#    'alias': 'the-horse-and-groom-london-2',
#    'name': 'The Horse & Groom',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gg2vIaqHiAv1hM-Ai_T4NQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-horse-and-groom-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.519887, 'longitude': -0.1424087},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '128 Great Portland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 6PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['128 Great Portland Street',
#      'London W1W 6PX',
#      'United Kingdom']},
#    'phone': '+442075804726',
#    'display_phone': '+44 20 7580 4726',
#    'distance': 900.877125116509},
#   {'id': 'EV8xkxnI7lIYP3IjoWs6Ig',
#    'alias': 'fox-and-pheasant-london',
#    'name': 'Fox & Pheasant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4LjKuAN1hIglqwg9NqEGFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fox-and-pheasant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4818809, 'longitude': -0.1875077},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '1 Billing Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW10 9UJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Billing Road',
#      'London SW10 9UJ',
#      'United Kingdom']},
#    'phone': '+442073522943',
#    'display_phone': '+44 20 7352 2943',
#    'distance': 4961.154962492819},
#   {'id': '65JkA2ikIjsbBHtrUJcH2w',
#    'alias': 'lowlander-london',
#    'name': 'Lowlander',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tp9v_dWpnXTNkdf-7vxljQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lowlander-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'belgian', 'title': 'Belgian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514624, 'longitude': -0.12241},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '36 Drury Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5RR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['36 Drury Lane', 'London WC2B 5RR', 'United Kingdom']},
#    'phone': '+442073797446',
#    'display_phone': '+44 20 7379 7446',
#    'distance': 963.9661830841728},
#   {'id': '1ZxrMRMv3cF1LTR8OBlOow',
#    'alias': 'the-red-lion-london-2',
#    'name': 'The Red Lion',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZlgTjz3x3dtpEexBUTB-Kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-red-lion-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.505868, 'longitude': -0.137771},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '23 Crown Passage',
#     'address2': "St James's",
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 6PP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23 Crown Passage',
#      "St James's",
#      'London SW1Y 6PP',
#      'United Kingdom']},
#    'phone': '+442079304141',
#    'display_phone': '+44 20 7930 4141',
#    'distance': 800.9351268073277},
#   {'id': 'z20bn5sdhmL0BDTPF1JAYQ',
#    'alias': 'exmouth-arms-london',
#    'name': 'Exmouth Arms',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ST8RTRTFyXpTMNshA8LM1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/exmouth-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.527876025712,
#     'longitude': -0.13665294408621},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Starcross Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 2HR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Starcross Street',
#      'London NW1 2HR',
#      'United Kingdom']},
#    'phone': '+442073875440',
#    'display_phone': '+44 20 7387 5440',
#    'distance': 1673.121359035123},
#   {'id': 'Zoaj-Cyl2GSYS1eH5u9Nzw',
#    'alias': 'the-thomas-cubitt-belgravia-london',
#    'name': 'The Thomas Cubitt Belgravia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zWOdVoav207nci84qI0Q0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-thomas-cubitt-belgravia-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 92,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.493738247163,
#     'longitude': -0.15080451196477},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '44 Elizabeth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 9PA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['44 Elizabeth Street',
#      'London SW1W 9PA',
#      'United Kingdom']},
#    'phone': '+442077306060',
#    'display_phone': '+44 20 7730 6060',
#    'distance': 2359.155619213274},
#   {'id': 'oMHEzgfHoufuS8xruS3GHg',
#    'alias': 'skinners-arms-london',
#    'name': 'Skinners Arms',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Q0NEX67xATYBAzEzf5Dlew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/skinners-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5282238, 'longitude': -0.1251041},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '114 Judd Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 9NT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['114 Judd Street',
#      'London WC1H 9NT',
#      'United Kingdom']},
#    'phone': '+442078376521',
#    'display_phone': '+44 20 7837 6521',
#    'distance': 1871.129388985023},
#   {'id': 'y-Vk_cyPRwgzTmAFpaGoVQ',
#    'alias': 'the-old-kings-head-london-2',
#    'name': 'The Old Kings Head',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tiDqzLkUk4zwiqE4SVg15g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-old-kings-head-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5046789008311,
#     'longitude': -0.0894797562057192},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "King's Head Yard",
#     'address2': '45-49 Borough High Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["King's Head Yard",
#      '45-49 Borough High Street',
#      'London SE1 1NA',
#      'United Kingdom']},
#    'phone': '+442074071550',
#    'display_phone': '+44 20 7407 1550',
#    'distance': 3341.9001404673522},
#   {'id': 'HwVbQ7vTj_oQvBG2K0RYNQ',
#    'alias': 'kings-head-pub-and-theatre-london',
#    'name': "King's Head Pub and Theatre",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hYJpryhb-LbNP0b_zYoPqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kings-head-pub-and-theatre-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'theater', 'title': 'Performing Arts'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.538436085252,
#     'longitude': -0.10255137447907},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '115 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 1QN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['115 Upper Street',
#      'London N1 1QN',
#      'United Kingdom']},
#    'phone': '+442072264443',
#    'display_phone': '+44 20 7226 4443',
#    'distance': 3666.6038408959844},
#   {'id': 'EpsYd4_AZ6bYCHroNgsmnw',
#    'alias': 'the-jugged-hare-london',
#    'name': 'The Jugged Hare',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8WBaipZderVELejKdHOaqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-jugged-hare-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4930096, 'longitude': -0.1382199},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '172 Vauxhall Bridge Rd',
#     'address2': 'Victoria',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1DX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['172 Vauxhall Bridge Rd',
#      'Victoria',
#      'London SW1V 1DX',
#      'United Kingdom']},
#    'phone': '+442078281543',
#    'display_phone': '+44 20 7828 1543',
#    'distance': 2205.30459748741},
#   {'id': 'rUdls6ffDxyT4QJgjr-odQ',
#    'alias': 'the-running-horse-london',
#    'name': 'The Running Horse',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KHCFdCS0-P7LlAVEBs_Iqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-running-horse-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.513183837502,
#     'longitude': -0.14848386115582},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '50 Davies Street',
#     'address2': 'Mayfair',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 5JE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50 Davies Street',
#      'Mayfair',
#      'London W1K 5JE',
#      'United Kingdom']},
#    'phone': '+442074931275',
#    'display_phone': '+44 20 7493 1275',
#    'distance': 867.8137338670542},
#   {'id': '2d2OJZyG9-ZnKA33SttYVA',
#    'alias': 'ship-tavern-london',
#    'name': 'Ship Tavern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9yKnehF7OEk5GEe3GDZihw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ship-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 93,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5172487, 'longitude': -0.119072165950775},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '12 Gate Street',
#     'address2': '',
#     'address3': 'Holborn',
#     'city': 'London',
#     'zip_code': 'WC2A 3HP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Gate Street',
#      'Holborn',
#      'London WC2A 3HP',
#      'United Kingdom']},
#    'phone': '+442074051992',
#    'display_phone': '+44 20 7405 1992',
#    'distance': 1267.1816159304317},
#   {'id': 'UMJxTGTSShg2u1FFwZBWAQ',
#    'alias': 'the-book-club-london',
#    'name': 'The Book Club',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8HCdjBRKyg074ero0uqGAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-book-club-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.524537, 'longitude': -0.081494},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '100 Leonard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 4RH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['100 Leonard Street',
#      'London EC2A 4RH',
#      'United Kingdom']},
#    'phone': '+442076848618',
#    'display_phone': '+44 20 7684 8618',
#    'distance': 3994.972382925784},
#   {'id': 'csGhqk_FmQPQVqh1ilZXpw',
#    'alias': 'the-hemingway-london-2',
#    'name': 'The Hemingway',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dnIbIsKO1NEyvzcIZEOaog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hemingway-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.537232212707,
#     'longitude': -0.048917991861221},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '84 Victoria Park Road',
#     'address2': 'Hackney',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E9 7JL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['84 Victoria Park Road',
#      'Hackney',
#      'London E9 7JL',
#      'United Kingdom']},
#    'phone': '+442085100215',
#    'display_phone': '+44 20 8510 0215',
#    'distance': 6604.350302753733},
#   {'id': '4ZpdUX7oxzykVWLf5_4cVA',
#    'alias': 'southampton-arms-london',
#    'name': 'Southampton Arms',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YdcFhpAs8s_t6IbLzSF3DQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/southampton-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.556086855106,
#     'longitude': -0.14620782791074},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '139 Highgate Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW5 1LE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['139 Highgate Road',
#      'London NW5 1LE',
#      'United Kingdom']},
#    'phone': '+447958780073',
#    'display_phone': '+44 7958 780073',
#    'distance': 4861.320067691116},
#   {'id': 'Iw5EUoxrmS18E4kPX3ce4Q',
#    'alias': 'duke-of-york-london-7',
#    'name': 'Duke Of York',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ntGWJD5h0CUReb4I0Ai1XQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duke-of-york-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51873308047, 'longitude': -0.13588693494383},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '47 Rathbone Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 1NW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Rathbone Street',
#      'London W1T 1NW',
#      'United Kingdom']},
#    'phone': '+442076367065',
#    'display_phone': '+44 20 7636 7065',
#    'distance': 655.7952632307087},
#   {'id': 'hgthAJ-rYFb-PKsvEmoH9w',
#    'alias': 'duke-of-argyll-london',
#    'name': 'Duke of Argyll',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lQ-JQFioIf2b-U0wZoqCag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duke-of-argyll-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5118095, 'longitude': -0.1347355},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '37 Brewer Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 7LQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['37 Brewer Street',
#      'London W1D 7LQ',
#      'United Kingdom']},
#    'phone': '+442074376819',
#    'display_phone': '+44 20 7437 6819',
#    'distance': 133.5185018519253},
#   {'id': 'qzaiyKhXNRy-J1-7p0-7CQ',
#    'alias': 'the-st-georges-tavern-london',
#    'name': "The St George's Tavern",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Y4RUamPiG7JeXZf1BIoAuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-st-georges-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 80,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.493255, 'longitude': -0.144796},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 Belgrave Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1QD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Belgrave Road',
#      'London SW1V 1QD',
#      'United Kingdom']},
#    'phone': '+442076301116',
#    'display_phone': '+44 20 7630 1116',
#    'distance': 2261.598698968142},
#   {'id': 'mfUfKa3Y_yzvROmFU59VuA',
#    'alias': 'the-library-bar-london-2',
#    'name': 'The Library Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OXxoTyZ88pbO130zfkVcpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-library-bar-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5023849627287,
#     'longitude': -0.152542591094971},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'The Lanesborough',
#     'address2': 'Lanesborough Place',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7TA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Lanesborough',
#      'Lanesborough Place',
#      'London SW1X 7TA',
#      'United Kingdom']},
#    'phone': '+442072595599',
#    'display_phone': '+44 20 7259 5599',
#    'distance': 1633.4467306096801},
#   {'id': 'LBR5rmnaOHnfPjxxalH44A',
#    'alias': 'three-tuns-marylebone',
#    'name': 'Three Tuns',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/na7tKFVChTnzpBuc7dAQOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/three-tuns-marylebone?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'fishnchips', 'title': 'Fish & Chips'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.514561, 'longitude': -0.15585},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Portman Mews S',
#     'address2': '',
#     'address3': '',
#     'city': 'Marylebone',
#     'zip_code': 'W1H 6HR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Portman Mews S',
#      'Marylebone W1H 6HR',
#      'United Kingdom']},
#    'phone': '+442074080330',
#    'display_phone': '+44 20 7408 0330',
#    'distance': 1397.9068717438174},
#   {'id': 'hXJvKG-LetjLlXrZZsmxhg',
#    'alias': 'carlsberg-sports-bar-london',
#    'name': 'Carlsberg Sports Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7KjGF5u71LUVYNH-0HZ_Mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carlsberg-sports-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.510943, 'longitude': -0.130501},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5-6 Leicester Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 7NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5-6 Leicester Square',
#      'London WC2H 7NA',
#      'United Kingdom']},
#    'phone': '+442035042490',
#    'display_phone': '+44 20 3504 2490',
#    'distance': 432.1802436049965},
#   {'id': 'h7dhAr5UCjhMj0pUV8qsbA',
#    'alias': 'the-understudy-london',
#    'name': 'The Understudy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Tu24DfHabcyYvE-awXNn3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-understudy-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5071789665883,
#     'longitude': -0.113651822090105},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'The National Theatre Southbank',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The National Theatre Southbank',
#      'London SE1 9PX',
#      'United Kingdom']},
#    'phone': '+442074523000',
#    'display_phone': '+44 20 7452 3000',
#    'distance': 1666.7835324430105},
#   {'id': 'mjxQdINZtNcUBNAFUVFVXQ',
#    'alias': 'mr-foggs-tavern-london',
#    'name': "Mr Fogg's Tavern",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Xow4yMY0cS8fjpERQetQHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-foggs-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 52,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5110196, 'longitude': -0.1268381},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "58 St Martin's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["58 St Martin's Lane",
#      'London WC2N 4EA',
#      'United Kingdom']},
#    'phone': '+442075813992',
#    'display_phone': '+44 20 7581 3992',
#    'distance': 659.936907710134},
#   {'id': '7X3kpSaP_PJFsPaRVXBzEA',
#    'alias': 'windsor-castle-london-3',
#    'name': 'Windsor Castle',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/74qRVgjdwcvARr2-qvQW_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/windsor-castle-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.526398, 'longitude': -0.162271},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '98 Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 4SH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['98 Park Road', 'London NW1 4SH', 'United Kingdom']},
#    'phone': '+442077239262',
#    'display_phone': '+44 20 7723 9262',
#    'distance': 2364.207410060371},
#   {'id': 'ND_WTQ3CdP2R6z90aUnRBQ',
#    'alias': 'jack-horner-london',
#    'name': 'Jack Horner',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MU5b3UBgINJzVxXGx-2ArA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jack-horner-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5186863972325,
#     'longitude': -0.1322340085036},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '234-236 Tottenham Court Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 7QN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['234-236 Tottenham Court Road',
#      'London W1T 7QN',
#      'United Kingdom']},
#    'phone': '+442076362868',
#    'display_phone': '+44 20 7636 2868',
#    'distance': 699.7056459335643},
#   {'id': 'd4G2m7XoqTPFhFzbPkWi_Q',
#    'alias': 'the-mall-tavern-london',
#    'name': 'The Mall Tavern',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ztuG6IaUQI8ancO7TDr-fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mall-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5083618, 'longitude': -0.1939162},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '71-73 Palace Gardens Ter',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4RU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['71-73 Palace Gardens Ter',
#      'London W8 4RU',
#      'United Kingdom']},
#    'phone': '+442072293374',
#    'display_phone': '+44 20 7229 3374',
#    'distance': 4040.6773612805346},
#   {'id': 'hOLFwKg4-0FsCleJ4yoCXw',
#    'alias': 'duck-and-waffle-london',
#    'name': 'Duck & Waffle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WrS5I1dN-nGXePaADwE0cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duck-and-waffle-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 707,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516178, 'longitude': -0.08094},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '110 Bishopsgate',
#     'address2': '40th Floor',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2N 4AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['110 Bishopsgate',
#      '40th Floor',
#      'London EC2N 4AY',
#      'United Kingdom']},
#    'phone': '+442036407310',
#    'display_phone': '+44 20 3640 7310',
#    'distance': 3825.102922188434},
#   {'id': 'Snps6MdfS78ye8fiSDyphQ',
#    'alias': 'brewdog-camden-london',
#    'name': 'BrewDog Camden',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/I0bFtVdoeFe7FueIbojCNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brewdog-camden-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 67,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.538411115006,
#     'longitude': -0.14083902579638},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '113 Bayham Street',
#     'address2': 'Camden Town',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 0AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['113 Bayham Street',
#      'Camden Town',
#      'London NW1 0AG',
#      'United Kingdom']},
#    'phone': '+442072844626',
#    'display_phone': '+44 20 7284 4626',
#    'distance': 2863.8683800128697},
#   {'id': 'u4a1B85w6MlKein09Z63gA',
#    'alias': 'the-old-kings-head-london-3',
#    'name': 'The Old Kings Head',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Lwfe6B7egnXh5MnwqqtqEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-old-kings-head-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5231677630073,
#     'longitude': -0.082225530112523},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '28 Holywell Row',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 4JB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28 Holywell Row',
#      'London EC2A 4JB',
#      'United Kingdom']},
#    'phone': '+442074260658',
#    'display_phone': '+44 20 7426 0658',
#    'distance': 3891.234300261876},
#   {'id': 'Gj5tCvJ_XoDnqrqSaCH0cw',
#    'alias': 'the-horse-and-groom-london-3',
#    'name': 'The Horse and Groom',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hp9cbLxo7E75r9RsgKbaxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-horse-and-groom-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.499484, 'longitude': -0.150883},
#    'transactions': [],
#    'location': {'address1': '7 Groom Place',
#     'address2': 'Belgravia',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Groom Place',
#      'Belgravia',
#      'London SW1X 7BA',
#      'United Kingdom']},
#    'phone': '+442072356980',
#    'display_phone': '+44 20 7235 6980',
#    'distance': 1831.7555349277027},
#   {'id': '9Gvhaa2UV3OP542ewoyL9g',
#    'alias': 'the-wigmore-london-2',
#    'name': 'The Wigmore',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MKu1pH7by2VmJxSeUx3C4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wigmore-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.517502, 'longitude': -0.143281},
#    'transactions': [],
#    'location': {'address1': '15 Langham Place',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1B 3DE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Langham Place',
#      'London W1B 3DE',
#      'United Kingdom']},
#    'phone': '+442079650198',
#    'display_phone': '+44 20 7965 0198',
#    'distance': 725.3799364630263},
#   {'id': 'Fa9718rkbQuMh3DYgvsSYw',
#    'alias': 'bodeans-london',
#    'name': "Bodean's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/awG2RJXZPrElj_1OEIhwyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bodeans-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 260,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514481362499,
#     'longitude': -0.13676105637839},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "D'Arblay House",
#     'address2': '10a Poland Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8PZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["D'Arblay House",
#      '10a Poland Street',
#      'London W1F 8PZ',
#      'United Kingdom']},
#    'phone': '+442072877575',
#    'display_phone': '+44 20 7287 7575',
#    'distance': 191.30425196477682},
#   {'id': 'V34NIC6ssALi5xevWpSsTg',
#    'alias': 'the-clarence-london-2',
#    'name': 'The Clarence',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2XCWeEoPVyPmh239ubmrlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-clarence-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.507876, 'longitude': -0.1412687},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 Dover Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 4LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Dover Street', 'London W1S 4LB', 'United Kingdom']},
#    'phone': '+442074913607',
#    'display_phone': '+44 20 7491 3607',
#    'distance': 666.5114333042667},
#   {'id': 'KGfryNuNH5mqYddLll9QCw',
#    'alias': 'gordons-wine-bar-london-4',
#    'name': "Gordon's Wine Bar",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bfARR-wEQXTyAWC9TCZwXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gordons-wine-bar-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 407,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5079411426091,
#     'longitude': -0.123381614685059},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '47 Villiers Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 6NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Villiers Street',
#      'London WC2N 6NE',
#      'United Kingdom']},
#    'phone': '+442079301408',
#    'display_phone': '+44 20 7930 1408',
#    'distance': 1026.362730294806},
#   {'id': 'ZEoJSP5I1H16ekbiJjM2Cw',
#    'alias': 'the-blind-pig-london',
#    'name': 'The Blind Pig',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/R2KhZVvOR6yvGJcwNjwsIQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-blind-pig-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5138271, 'longitude': -0.1367278},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '58 Poland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7NR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['58 Poland Street',
#      'London W1F 7NR',
#      'United Kingdom']},
#    'phone': '+442079933251',
#    'display_phone': '+44 20 7993 3251',
#    'distance': 122.51858604240589},
#   {'id': 'SxpEMzMtdNCrPdU7viJ2fQ',
#    'alias': 'the-surprise-london',
#    'name': 'The Surprise',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1KRywuE_hYl0m3zjaBhohA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-surprise-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.486236715601, 'longitude': -0.1630825103729},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 Christchurch Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 4AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Christchurch Street',
#      'London SW3 4AJ',
#      'United Kingdom']},
#    'phone': '+442073516954',
#    'display_phone': '+44 20 7351 6954',
#    'distance': 3503.3689727404876},
#   {'id': 'Lpdz1Yn0WbJjL5IH0tVb4A',
#    'alias': 'the-george-london-12',
#    'name': 'The George',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eQ-veReY9q7tZHcn915SSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-george-london-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5523661, 'longitude': -0.16724},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '250 Haverstock Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 2AE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['250 Haverstock Hill',
#      'London NW3 2AE',
#      'United Kingdom']},
#    'phone': '+442074310889',
#    'display_phone': '+44 20 7431 0889',
#    'distance': 4901.118321994842},
#   {'id': 'Bd6eDslPaMteCcmkNGFKbA',
#    'alias': 'clarette-london',
#    'name': 'Clarette',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LO55iGtKrbRaTqgT0MvUzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clarette-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5185699, 'longitude': -0.1537631},
#    'transactions': [],
#    'location': {'address1': '44 Blandford Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1U 7HS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['44 Blandford Street',
#      'London W1U 7HS',
#      'United Kingdom']},
#    'phone': '+442030197750',
#    'display_phone': '+44 20 3019 7750',
#    'distance': 1387.4075776067978},
#   {'id': 'pOnkBNgFreS7QzKZXXV3jA',
#    'alias': 'the-portman-london',
#    'name': 'The Portman',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zEMYATE1Ul51acGAA3QLnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-portman-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5152469791282,
#     'longitude': -0.161370500226781},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '51 Upper Berkeley Street',
#     'address2': 'Marylebone',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7QW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Upper Berkeley Street',
#      'Marylebone',
#      'London W1H 7QW',
#      'United Kingdom']},
#    'phone': '+442077238996',
#    'display_phone': '+44 20 7723 8996',
#    'distance': 1778.9968273370253},
#   {'id': 'UkqTqV8tNon_kRjBtMWfvg',
#    'alias': 'the-coach-and-horses-london-5',
#    'name': 'The Coach & Horses',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fOlbhs4sf9YpyZt3SPG2jg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-coach-and-horses-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.513274, 'longitude': -0.130205},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '29 Greek Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 5DH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['29 Greek Street',
#      'London W1D 5DH',
#      'United Kingdom']},
#    'phone': '+442074375920',
#    'display_phone': '+44 20 7437 5920',
#    'distance': 405.01183031988586},
#   {'id': 'SCdYgnZUaaQiCAUnfRxlsg',
#    'alias': 'happiness-forgets-london',
#    'name': 'Happiness Forgets',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZqXB2yjEVx_qCXpaB-FdRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/happiness-forgets-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 106,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.52770282863,
#     'longitude': -0.0816464424133301},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8-9 Hoxton Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 6NU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8-9 Hoxton Square',
#      'London N1 6NU',
#      'United Kingdom']},
#    'phone': '+442076130325',
#    'display_phone': '+44 20 7613 0325',
#    'distance': 4105.2218818060555},
#   {'id': '2FcSDOaOs4booPldINMMFg',
#    'alias': 'the-globe-london-7',
#    'name': 'The Globe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/X8GEEpXKq9waVquEapyWuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-globe-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.521927, 'longitude': -0.157037},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '43-47 Marylebone Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 5JY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['43-47 Marylebone Road',
#      'London NW1 5JY',
#      'United Kingdom']},
#    'phone': '+448721484429',
#    'display_phone': '+44 872 148 4429',
#    'distance': 1770.8808787013102},
#   {'id': '_KHr_QRAn5-czkDkonAdhA',
#    'alias': 'the-social-london',
#    'name': 'The Social',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TyHo4eoK8A6tPB67kBR7Dg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-social-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 61,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'danceclubs', 'title': 'Dance Clubs'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5174, 'longitude': -0.140846},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5 Little Portland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 7JD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Little Portland Street',
#      'London W1W 7JD',
#      'United Kingdom']},
#    'phone': '+442076364992',
#    'display_phone': '+44 20 7636 4992',
#    'distance': 607.2857045494891},
#   {'id': '1oShlXeGjTrfD-A1I_iHBw',
#    'alias': 'the-spread-eagle-london-6',
#    'name': 'The Spread Eagle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QEZKnaoWDOvsAs2a5hTrkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-spread-eagle-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5486131491202,
#     'longitude': -0.0408179463767122},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '224 Homerton High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E9 6AS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['224 Homerton High Street',
#      'London E9 6AS',
#      'United Kingdom']},
#    'phone': '+442089850400',
#    'display_phone': '+44 20 8985 0400',
#    'distance': 7690.047611557957},
#   {'id': '7Q6JpFSFv997rhv7w1izNA',
#    'alias': 'the-colonel-fawcett-london',
#    'name': 'The Colonel Fawcett',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5sI0DzmCXQB1JkmxqaLbtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-colonel-fawcett-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5418041646628,
#     'longitude': -0.136007736926076},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Randolph Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 0SS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Randolph Street',
#      'London NW1 0SS',
#      'United Kingdom']},
#    'phone': '+442072679829',
#    'display_phone': '+44 20 7267 9829',
#    'distance': 3221.1646170751255}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#               Restaurant             Type Price Rating  \
# 0           Golden Eagle             Pubs    ££      4
# 1      Duke of Edinburgh             Pubs    ££    4.5
# 2  Royal Vauxhall Tavern  Performing Arts    ££      4
# 3               The Ship             Pubs     £    4.5
# 4         Duke Of Kendal             Pubs    ££      4
#
#                     Address        Lat       Lng  \
# 0        59 Marylebone Lane  51.517646 -0.150804
# 1         204 Ferndale Road  51.463044 -0.120713
# 2       372 Kennington Lane  51.486066 -0.121945
# 3  134 New Cavendish Street  51.520411 -0.140787
# 4       38 Connaught Street  51.514588 -0.166229
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/golden-eagle-london-3...  LcPnzwVLvDTYjjKsOHxyxQ
# 1  https://www.yelp.com/biz/duke-of-edinburgh-lon...  b721gjWkPpG-Bcn17k41mg
# 2  https://www.yelp.com/biz/royal-vauxhall-tavern...  vDYVC5x9dSwCOZ78iDsRsg
# 3  https://www.yelp.com/biz/the-ship-london-11?ad...  cUoWCiqRC1aGoRpfv1Co9A
# 4  https://www.yelp.com/biz/duke-of-kendal-london...  wEJKOJ9Hc2FEEGq2UbaMQQ

# %%
london_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
london_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_restaurants_df = london_restaurants_df[column_order]
london_restaurants_df = london_restaurants_df.sort_values(["Type"], ascending=True)
london_restaurants_df = london_restaurants_df.reset_index(drop=True)
london_restaurants_df
# Out:
#                         Restaurant                    Type Rating Price  \
# 0                     The Fat Bear  American (Traditional)    4.5    ££
# 1                         Bodean's  American (Traditional)      4    ££
# 2                    Connaught Bar                    Bars    4.5  ££££
# 3                   BrewDog Camden                    Bars      4    ££
# 4                       The Social                    Bars      4    ££
# 5                   The Dragon Bar                    Bars      4    ££
# 6                  Simpsons Tavern                    Bars      4    ££
# 7                   The Kings Head                    Bars
# 8                  Crocker's Folly                    Bars    4.5   £££
# 9                      Cahoots Bar                    Bars    4.5    ££
# 10                         BrewDog                    Bars    4.5    ££
# 11                      Heist Bank                    Bars
# 12                 Crocker's Folly                    Bars    4.5   £££
# 13                       The Lyric                    Bars    4.5    ££
# 14         Simpson's in the Strand                 British      4   £££
# 15                     Pieminister                 British      4     £
# 16                         The Ivy                 British      4   £££
# 17                  Maggie Jones's                 British    4.5   £££
# 18           Hawksmoor Seven Dials                 British    4.5   £££
# 19                         The Cow                 British      4    ££
# 20                  Berners Tavern                 British    4.5   £££
# 21             The Anchor and Hope                 British      4    ££
# 22                  The Gloucester                 British    3.5    ££
# 23      The Marquis of Westminster                 British      4    ££
# 24             The Pig and Butcher                 British    4.5    ££
# 25                Mr Fogg's Tavern                 British      4    ££
# 26             Ffiona's Restaurant                 British    4.5    ££
# 27   The Alfred Tennyson Belgravia                 British      4    ££
# 28                 The Queens Arms                 British    4.5    ££
# 29             Ffiona's Restaurant                 British    4.5    ££
# ..                             ...                     ...    ...   ...
# 170                      Royal Oak                    Pubs      4    ££
# 171                  The Sands End                    Pubs      4    ££
# 172                 King Charles I                    Pubs    4.5    ££
# 173          Ye Olde Swiss Cottage                    Pubs    3.5     £
# 174                     Dog & Duck                    Pubs      4    ££
# 175                The World's End                    Pubs    3.5    ££
# 176                    Flight Club                    Pubs    4.5    ££
# 177      The Walrus Bar and Hostel                    Pubs      4     £
# 178                     Anchor Tap                    Pubs      4     £
# 179           CASK Pub and Kitchen                    Pubs    4.5    ££
# 180                  Builders Arms                    Pubs      4    ££
# 181              Princess of Wales                    Pubs      4    ££
# 182                  Leinster Arms                    Pubs      4    ££
# 183                   Morpeth Arms                    Pubs      4    ££
# 184                The Cock Tavern                    Pubs      4    ££
# 185                      Iron Duke                    Pubs      4    ££
# 186                  Founders Arms                    Pubs      4    ££
# 187               The Mason's Arms                    Pubs      4   £££
# 188                    The Footman                    Pubs      4    ££
# 189                Princess Louise                    Pubs    4.5    ££
# 190                      The Crown                    Pubs      4    ££
# 191                       The Lamb                    Pubs      4    ££
# 192                     Stags Head                    Pubs      4    ££
# 193                     Kings Arms                    Pubs      4     £
# 194           Carlsberg Sports Bar             Sports Bars      3    ££
# 195                    Sussex Arms             Sports Bars    3.5    ££
# 196                  The Book Club   Venues & Event Spaces      4    ££
# 197                       Clarette               Wine Bars
# 198                The Library Bar               Wine Bars      5   £££
# 199              Gordon's Wine Bar               Wine Bars    4.5    ££
#
#                             Address        Lat       Lng  \
# 0                    61 Carter Lane  51.513183 -0.101381
# 1                    D'Arblay House  51.514481 -0.136761
# 2                     The Connaught  51.510156 -0.149631
# 3                 113 Bayham Street  51.538411 -0.140839
# 4          5 Little Portland Street  51.517400 -0.140846
# 5    138-139 Shoreditch High Street  51.526270 -0.078165
# 6         Ballcourt 38 1/2 Cornhill  51.513144 -0.086014
# 7            13 Westmoreland Street  51.519682 -0.150126
# 8                 24 Aberdeen Place  51.525736 -0.174714
# 9                   13 Kingly Court  51.512542 -0.139100
# 10                 21 Poland Street  51.515042 -0.137205
# 11               5 North Wharf Road  51.518795 -0.176081
# 12                24 Aberdeen Place  51.525736 -0.174714
# 13         37 Great Windmill Street  51.511283 -0.134466
# 14                       100 Strand  51.510569 -0.120672
# 15                  Gabriel's Wharf  51.507826 -0.110065
# 16                1 - 5 West Street  51.512814 -0.128013
# 17                6 Old Court Place  51.502856 -0.190992
# 18                11 Langley Street  51.513500 -0.125674
# 19          89 Westbourne Park Road  51.519244 -0.195268
# 20                10 Berners Street  51.516752 -0.135977
# 21                       36 The Cut  51.503473 -0.106586
# 22                187 Sloane Street  51.499976 -0.159538
# 23                   50 Warwick Way  51.491901 -0.140515
# 24                80 Liverpool Road  51.537443 -0.106828
# 25              58 St Martin's Lane  51.511020 -0.126838
# 26      51 Kensington Church Street  51.504058 -0.192783
# 27                10 Motcomb Street  51.499631 -0.156411
# 28                   11 Warwick Way  51.492579 -0.139219
# 29      51 Kensington Church Street  51.504058 -0.192783
# ..                              ...        ...       ...
# 170                73 Columbia Road  51.529543 -0.069257
# 171        135-137 Stephendale Road  51.471200 -0.187155
# 172          55-57 Northdown Street  51.532433 -0.119723
# 173                98 Finchley Road  51.542696 -0.174824
# 174               18 Bateman Street  51.514030 -0.131894
# 175          174 Camden High Street  51.539470 -0.142224
# 176              Alphabeta Building  51.522065 -0.086526
# 177     172 Westminster Bridge Road  51.499963 -0.114445
# 178             28 Horselydown Lane  51.503554 -0.076019
# 179              6 Charlwood Street  51.491350 -0.137537
# 180        1 Kensington Court Place  51.499430 -0.188299
# 181                 22 Chalcot Road  51.540283 -0.153757
# 182             17 Leinster Terrace  51.511684 -0.182882
# 183                     58 Millbank  51.489373 -0.128630
# 184        27 Great Portland Street  51.516717 -0.141412
# 185                    11 Avery Row  51.512679 -0.145981
# 186                52 Hopton Street  51.508562 -0.101551
# 187        51 Upper Berkeley Street  51.514750 -0.161037
# 188                5 Charles Street  51.508493 -0.146126
# 189                208 High Holborn  51.517294 -0.121571
# 190                64 Brewer Street  51.511215 -0.136329
# 191      92-94 Lambs Conduit Street  51.523304 -0.119154
# 192                  55 Orsman Road  51.536262 -0.080221
# 193                23 Poland Street  51.515365 -0.137383
# 194            5-6 Leicester Square  51.510943 -0.130501
# 195                21 London Street  51.515091 -0.173997
# 196              100 Leonard Street  51.524537 -0.081494
# 197             44 Blandford Street  51.518570 -0.153763
# 198                The Lanesborough  51.502385 -0.152543
# 199              47 Villiers Street  51.507941 -0.123382
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/the-fat-bear-london?a...  Z0r83lDOA1mI8RpNccXtHw
# 1    https://www.yelp.com/biz/bodeans-london?adjust...  Fa9718rkbQuMh3DYgvsSYw
# 2    https://www.yelp.com/biz/connaught-bar-london?...  hXWtuKNmbVzAYtoZhNLLPw
# 3    https://www.yelp.com/biz/brewdog-camden-london...  Snps6MdfS78ye8fiSDyphQ
# 4    https://www.yelp.com/biz/the-social-london?adj...  _KHr_QRAn5-czkDkonAdhA
# 5    https://www.yelp.com/biz/the-dragon-bar-london...  GwUpy8KMGxBNoQKlqnLJ3A
# 6    https://www.yelp.com/biz/simpsons-tavern-londo...  Knha-8wa2_RPavK_o9qfQQ
# 7
# 8    https://www.yelp.com/biz/crockers-folly-london...  6zdVc_noXqjJLIohpSyIbw
# 9    https://www.yelp.com/biz/cahoots-bar-soho?adju...  Gyus9t3spoc1Ymc-BChRFw
# 10   https://www.yelp.com/biz/brewdog-soho?adjust_c...  pQSVwo98sKLUgE8tV4hcLw
# 11
# 12   https://www.yelp.com/biz/crockers-folly-london...  6zdVc_noXqjJLIohpSyIbw
# 13   https://www.yelp.com/biz/the-lyric-london?adju...  3yvDAVKLDtsXZEHrskuobA
# 14   https://www.yelp.com/biz/simpsons-in-the-stran...  Fbt8YC8OQmBF2J4_vDdHhw
# 15   https://www.yelp.com/biz/pieminister-london-3?...  ij6JgRnQmdXND4uokTFIdQ
# 16   https://www.yelp.com/biz/the-ivy-london?adjust...  75-HeBBB391Np6T7GdJ5xQ
# 17   https://www.yelp.com/biz/maggie-joness-london-...  5tAAwu7ZDhulLsyt09bXnw
# 18   https://www.yelp.com/biz/hawksmoor-seven-dials...  0B-ag3J18TatG9H9EQohGg
# 19   https://www.yelp.com/biz/the-cow-london?adjust...  NyGG3SHQGrjmP1zoBLhubQ
# 20   https://www.yelp.com/biz/berners-tavern-london...  ZKfiQaOMDu7rfVhmMmQ0bQ
# 21   https://www.yelp.com/biz/the-anchor-and-hope-l...  9ad4tZB0Mp-tNnXLZwYvUA
# 22   https://www.yelp.com/biz/the-gloucester-london...  -clnu6vMMIc4616znY_fbA
# 23   https://www.yelp.com/biz/the-marquis-of-westmi...  ySM7A1ljKIthN6ckAYdN5g
# 24   https://www.yelp.com/biz/the-pig-and-butcher-l...  3R0Klq1B1ESNTwqPfcsY-w
# 25   https://www.yelp.com/biz/mr-foggs-tavern-londo...  mjxQdINZtNcUBNAFUVFVXQ
# 26   https://www.yelp.com/biz/ffionas-restaurant-lo...  70Q-Ll18zb4aglXXbUG7lw
# 27   https://www.yelp.com/biz/the-alfred-tennyson-b...  1c60bGFaWOhq_ra06w9daQ
# 28   https://www.yelp.com/biz/the-queens-arms-londo...  Wjgxl0lSp_FRtzecbJ4FZQ
# 29   https://www.yelp.com/biz/ffionas-restaurant-lo...  70Q-Ll18zb4aglXXbUG7lw
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/royal-oak-london?adju...  SjK7ZPrjx6YVczuu4EQ9Zg
# 171  https://www.yelp.com/biz/the-sands-end-london?...  D2rZgP8lFv1zwnQwQHm5cw
# 172  https://www.yelp.com/biz/king-charles-i-london...  erZKvShXshTiKVzYCS-uLQ
# 173  https://www.yelp.com/biz/ye-olde-swiss-cottage...  5_M0-o3mU88yRpsLB3Rcqw
# 174  https://www.yelp.com/biz/dog-and-duck-london-2...  GaScDG5loFxXHlePsIDBcQ
# 175  https://www.yelp.com/biz/the-worlds-end-london...  DWPtpdsU6mIMzRUouGklBQ
# 176  https://www.yelp.com/biz/flight-club-london?ad...  P33NBF3mTAgFYLmtMljuzg
# 177  https://www.yelp.com/biz/the-walrus-bar-and-ho...  euBJIN5rPU9o41LK58uMzg
# 178  https://www.yelp.com/biz/anchor-tap-london?adj...  taD2YeoUpeR9lhQK_0Nonw
# 179  https://www.yelp.com/biz/cask-pub-and-kitchen-...  5o8lm4tCTGgZfH0N4QAgMg
# 180  https://www.yelp.com/biz/builders-arms-london?...  b7RW2pHBLX1gpSKCrIm4AQ
# 181  https://www.yelp.com/biz/princess-of-wales-lon...  3OIaUlgZWnyAhxoWqrB61Q
# 182  https://www.yelp.com/biz/leinster-arms-london?...  Rugom03-YkWplCoxMGdkzw
# 183  https://www.yelp.com/biz/morpeth-arms-london?a...  FcTq1tFrMwXnQJ3hE3IGJQ
# 184  https://www.yelp.com/biz/the-cock-tavern-londo...  G3cavZnRpyHjFWIOIfuozA
# 185  https://www.yelp.com/biz/iron-duke-london?adju...  eN_knU-P9rwnID4_2YA0Ng
# 186  https://www.yelp.com/biz/founders-arms-london?...  owHIUnK6hxEdiISX2DnIdg
# 187  https://www.yelp.com/biz/the-masons-arms-londo...  gkLoTapECbuQ4ekyEmAg2g
# 188  https://www.yelp.com/biz/the-footman-london?ad...  U_71ZadYKpRQH3a3brJldg
# 189  https://www.yelp.com/biz/princess-louise-londo...  n_oGHFO88muDRn6vgQLjqw
# 190  https://www.yelp.com/biz/the-crown-london-9?ad...  cVnVLLqgJkOf75I7wJ6kMg
# 191  https://www.yelp.com/biz/the-lamb-london?adjus...  Lfhb267w4FGa3kiaT8SoEA
# 192  https://www.yelp.com/biz/stags-head-london?adj...  1LuM8aJI8qDOlJC1JFTyYw
# 193  https://www.yelp.com/biz/kings-arms-london-2?a...  j0XQt-btOBlQVaUmd8oRqg
# 194  https://www.yelp.com/biz/carlsberg-sports-bar-...  hXJvKG-LetjLlXrZZsmxhg
# 195  https://www.yelp.com/biz/sussex-arms-london?ad...  mxFv2t92_sTjxeCPqnHK0A
# 196  https://www.yelp.com/biz/the-book-club-london?...  UMJxTGTSShg2u1FFwZBWAQ
# 197
# 198  https://www.yelp.com/biz/the-library-bar-londo...  mfUfKa3Y_yzvROmFU59VuA
# 199  https://www.yelp.com/biz/gordons-wine-bar-lond...  KGfryNuNH5mqYddLll9QCw
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
london_restaurants_df.to_csv('Resources/London_Restaurants_Pub.csv')
