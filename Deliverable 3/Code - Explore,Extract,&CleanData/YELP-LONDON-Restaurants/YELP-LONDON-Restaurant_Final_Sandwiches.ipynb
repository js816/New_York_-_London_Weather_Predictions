# %% [markdown]
# LONDON RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
term = "sandwich"

# %%
#First set of 50 records 0-50
lndr_params1 = {"term":term,"location":"London","limit":50,"offset":0}
lndr_response1 = requests.get(search_api_url, headers=headers, params=lndr_params1)
lndr1 = lndr_response1.json()
display(lndr1)
#print(lndr_response1.url)
#print(lndr_response1.status_code)
# Out:
# {'businesses': [{'id': 'c897jdNz40fc0AzNhmf4xg',
#    'alias': 'sandwich-shop-london',
#    'name': 'Sandwich Shop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jdtX44jC222EoD6n6eVGxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sandwich-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4980207, 'longitude': -0.1839306},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '54 Gloucester Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 4QT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54 Gloucester Road',
#      'London SW7 4QT',
#      'United Kingdom']},
#    'phone': '+442075892849',
#    'display_phone': '+44 20 7589 2849',
#    'distance': 3709.425872911642},
#   {'id': 'DqYZGmadZod5zqdhgsBoJw',
#    'alias': 'kappacasein-london',
#    'name': 'Kappacasein',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sCOe8MwEkVrLzlMOq0taOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kappacasein-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 136,
#    'categories': [{'alias': 'cheese', 'title': 'Cheese Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.505052, 'longitude': -0.090898},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '1 Stoney Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Stoney Street',
#      'London SE1 9AA',
#      'United Kingdom']},
#    'phone': '+442073945520',
#    'display_phone': '+44 20 7394 5520',
#    'distance': 3236.1871921002435},
#   {'id': 'Ou34hZJiM8QabVqotVZSQw',
#    'alias': 'the-sandwich-shop-london',
#    'name': 'The Sandwich Shop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nwT0Pry3eFm2zVfq5O8rYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-sandwich-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4990071, 'longitude': -0.13245},
#    'transactions': [],
#    'location': {'address1': '19 Dacre Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1H 0DJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Dacre Street',
#      'London SW1H 0DJ',
#      'United Kingdom']},
#    'phone': '+442072330363',
#    'display_phone': '+44 20 7233 0363',
#    'distance': 1573.4903191538697},
#   {'id': '0sjH44nfLe0nr1uBZPNWAQ',
#    'alias': 'maxs-sandwich-shop-london',
#    'name': "Max's Sandwich Shop",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-fI7nMa0DTTOSwL3EPTssw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maxs-sandwich-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5706090486317,
#     'longitude': -0.11618759483099},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '19 Crouch Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N4 4AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Crouch Hill', 'London N4 4AP', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6567.972072323076},
#   {'id': 'vhepCL_kywNXIWuTF9VwUg',
#    'alias': 'mayfair-sandwich-shop-london',
#    'name': 'Mayfair Sandwich Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/elpL6Sek-kQIznaOwlhX3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mayfair-sandwich-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.508407, 'longitude': -0.141947},
#    'transactions': [],
#    'location': {'address1': '7 Stafford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 4RT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Stafford Street',
#      'London W1S 4RT',
#      'United Kingdom']},
#    'phone': '+442076292063',
#    'display_phone': '+44 20 7629 2063',
#    'distance': 633.7967614202664},
#   {'id': 'CrQcYS4nWWdXmSD1pxf_KA',
#    'alias': 'beigel-bake-london',
#    'name': 'Beigel Bake',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1Q9nDZsnX30-yv55INHp7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beigel-bake-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 477,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.524391, 'longitude': -0.071726},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '159 Brick Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['159 Brick Lane', 'London E1 6SB', 'United Kingdom']},
#    'phone': '+442077290616',
#    'display_phone': '+44 20 7729 0616',
#    'distance': 4626.215959115099},
#   {'id': '6xXfpMnpujSY_XuxeVvESQ',
#    'alias': 'pickle-and-rye-london',
#    'name': 'Pickle & Rye',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dWPINkZ7mmq7yezm_BF2GA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pickle-and-rye-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4683030502269,
#     'longitude': -0.266688129485996},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '31 Sheen Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW14 8AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['31 Sheen Lane', 'London SW14 8AB', 'United Kingdom']},
#    'phone': '+442088788982',
#    'display_phone': '+44 20 8878 8982',
#    'distance': 10317.197483082797},
#   {'id': 'pa2j9BlCHH8mRIk-TtD6UQ',
#    'alias': 'camden-bakery-london',
#    'name': 'Camden Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/V1BIQXnDxmTz0NyfTs6BiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camden-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5370833, 'longitude': -0.1407642},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '94 Camden High Street',
#     'address2': 'Camden Town',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 0LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['94 Camden High Street',
#      'Camden Town',
#      'London NW1 0LT',
#      'United Kingdom']},
#    'phone': '+442073874947',
#    'display_phone': '+44 20 7387 4947',
#    'distance': 2712.007403533704},
#   {'id': '9huadp8OwppgqBtzL5brCA',
#    'alias': 'sub-cult-london-3',
#    'name': 'Sub Cult',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BqunTd-iOxyOahYF0g6J_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sub-cult-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5141611, 'longitude': -0.1356765},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Berwick St Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8TW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Berwick St Market',
#      'London W1F 8TW',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 148.65933357566928},
#   {'id': 'DARE_WvgMZINvslycDPJFQ',
#    'alias': 'raabs-bakery-london',
#    'name': "Raab's Bakery",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Q_qgt_LRqOi-YUrl4rNWCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raabs-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5393189, 'longitude': -0.0977451},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '136 Essex Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8LX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['136 Essex Road', 'London N1 8LX', 'United Kingdom']},
#    'phone': '+442072262830',
#    'display_phone': '+44 20 7226 2830',
#    'distance': 3968.321016159277},
#   {'id': 'x58LDkXGU7vC8-KRDlS9Mw',
#    'alias': 'raison-d-etre-london',
#    'name': "Raison D'Etre",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GNL9SAtkBRabO34z0GOmqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raison-d-etre-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.493706018346,
#     'longitude': -0.17628170716244},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '18 Bute Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3EX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Bute Street', 'London SW7 3EX', 'United Kingdom']},
#    'phone': '+442075845008',
#    'display_phone': '+44 20 7584 5008',
#    'distance': 3509.3036349562817},
#   {'id': 'Yhh7ooveAeWmbHUsxm0bdQ',
#    'alias': 'taza-sandwich-london',
#    'name': 'Taza Sandwich',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KyjdTAccm9-bJqoBnhMLqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taza-sandwich-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 72,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5112347, 'longitude': -0.1874585},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '35a Queensway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 4QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35a Queensway', 'London W2 4QJ', 'United Kingdom']},
#    'phone': '+442077277420',
#    'display_phone': '+44 20 7727 7420',
#    'distance': 3575.019002403701},
#   {'id': 'LgKc7xGArsmxAw6xUQ2mYA',
#    'alias': 'gails-bakery-seymour-place-london-4',
#    'name': "GAIL's Bakery Seymour Place",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FWiORe3Zw8vEUmD0tANYvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-seymour-place-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.514595, 'longitude': -0.160964},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4-6 Seymour Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4-6 Seymour Place',
#      'London W1H 7NA',
#      'United Kingdom']},
#    'phone': '+442077243590',
#    'display_phone': '+44 20 7724 3590',
#    'distance': 1741.5797182376227},
#   {'id': 'RTBkp7ewp3ZDFTJeIdLIMA',
#    'alias': 'hanks-po-boys-london',
#    'name': "Hank's Po' Boys",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Z_noSQPmhYpSLVuf3qZ9KQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hanks-po-boys-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5053216, 'longitude': -0.1160542},
#    'transactions': [],
#    'location': {'address1': 'Southbank Centre Market',
#     'address2': 'Belvedere Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8XX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Southbank Centre Market',
#      'Belvedere Road',
#      'London SE1 8XX',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1610.9293914129462},
#   {'id': 'BNdzjiLoibX1uSH4kAQy5w',
#    'alias': 'the-bike-shed-london',
#    'name': 'The Bike Shed',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_zYjKPcPg4BE91Bl7tVPUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bike-shed-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'accessories', 'title': 'Accessories'},
#     {'alias': 'themedcafes', 'title': 'Themed Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5270903, 'longitude': -0.0782151},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '384 Old Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 9LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['384 Old Street',
#      'London EC1V 9LT',
#      'United Kingdom']},
#    'phone': '+442077298114',
#    'display_phone': '+44 20 7729 8114',
#    'distance': 4257.350530218552},
#   {'id': 'QFtIXzRf8XLmmhYtpUxjxA',
#    'alias': 'mayfair-pasta-and-sandwich-bar-london',
#    'name': 'Mayfair Pasta & Sandwich Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AeDfjO-Ev_9kg7Y77jk0bQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mayfair-pasta-and-sandwich-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.513195, 'longitude': -0.1487149},
#    'transactions': [],
#    'location': {'address1': '61 Davies Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 5SQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Davies Street',
#      'London W1K 5SQ',
#      'United Kingdom']},
#    'phone': '+442076294095',
#    'display_phone': '+44 20 7629 4095',
#    'distance': 885.7464206738513},
#   {'id': '3CDSWnNiIg36sESmr0m8cw',
#    'alias': 'tongue-and-brisket-london-2',
#    'name': 'Tongue & Brisket',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uswTNYq4a4nSF67RNpfv9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tongue-and-brisket-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515596, 'longitude': -0.135961},
#    'transactions': [],
#    'location': {'address1': '199 Wardour Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1F 8JP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['199 Wardour Street',
#      'London W1F 8JP',
#      'United Kingdom']},
#    'phone': '+442037842273',
#    'display_phone': '+44 20 3784 2273',
#    'distance': 309.066632381074},
#   {'id': 'lINVn-iVcLcFQkq1DXZo_Q',
#    'alias': 'upper-fleet-bakery-london',
#    'name': 'Upper Fleet Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/av4PNLmZzYf0tuHKp3Y-6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/upper-fleet-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5263319313231,
#     'longitude': -0.129384561430401},
#    'transactions': [],
#    'location': {'address1': '7 - 11 Upper Woburn place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 0JW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 - 11 Upper Woburn place',
#      'London WC1H 0JW',
#      'United Kingdom']},
#    'phone': '+442073875544',
#    'display_phone': '+44 20 7387 5544',
#    'distance': 1568.0932386529987},
#   {'id': 'ZT8M0TcLZXXcdPaMbk18Cg',
#    'alias': 'portobello-garden-caffe-london',
#    'name': "Portobello Garden Caffe'",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YEszzg8iWcZkmfE5vUkfxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/portobello-garden-caffe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5180217, 'longitude': -0.2069201},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '269b Portobello Road',
#     'address2': 'Notting Hill',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 1LR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['269b Portobello Road',
#      'Notting Hill',
#      'London W11 1LR',
#      'United Kingdom']},
#    'phone': '+442077928419',
#    'display_phone': '+44 20 7792 8419',
#    'distance': 4944.258290109093},
#   {'id': '2BoGHL6GSyn30i4yU2VKtQ',
#    'alias': 'camisa-and-son-london',
#    'name': 'Camisa & Son',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x6ZCJBiIPaxeOv3tVmXiXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camisa-and-son-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512482, 'longitude': -0.132848},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61 Old Compton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6HS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Old Compton Street',
#      'London W1D 6HS',
#      'United Kingdom']},
#    'phone': '+442074377610',
#    'display_phone': '+44 20 7437 7610',
#    'distance': 218.62713673273046},
#   {'id': 'SgkpvCD6vRHKi20oer-sWA',
#    'alias': 'chequers-london-2',
#    'name': 'Chequers',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PNMZH9jFI89y2yQj9DLkAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chequers-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.510113, 'longitude': -0.12372},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '47 Bedford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 9HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Bedford Street',
#      'London WC2E 9HA',
#      'United Kingdom']},
#    'phone': '+442078366000',
#    'display_phone': '+44 20 7836 6000',
#    'distance': 904.9171070327363},
#   {'id': '4OqhYt1IdxpmcN7TZrXkZA',
#    'alias': 'sub-cult-london-4',
#    'name': 'Sub Cult',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/K808TVDZqcJkpidcCOWeLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sub-cult-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5235079426847,
#     'longitude': -0.0764473155140877},
#    'transactions': [],
#    'location': {'address1': '2-10 Bethnal Green Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E1 6GY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2-10 Bethnal Green Rd',
#      'London E1 6GY',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4285.159061181271},
#   {'id': 'k7qmLDOGfESN8fDBQZZL7w',
#    'alias': '106-baker-st-london',
#    'name': '106 Baker St',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9CXBPhU2Ib_gv7QmtYAMCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/106-baker-st-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5207977, 'longitude': -0.1566825},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '106 Baker Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 6TW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['106 Baker Street',
#      'London W1U 6TW',
#      'United Kingdom']},
#    'phone': '+442074873372',
#    'display_phone': '+44 20 7487 3372',
#    'distance': 1689.8849777286025},
#   {'id': 'U-Sz3hVjbZ8eaNeKGpZU_A',
#    'alias': 'borough-market-london-3',
#    'name': 'Borough Market',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EjVltsQ_qhUKdgdTMndkIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/borough-market-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1657,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5051427191678,
#     'longitude': -0.0909365332063361},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8 Southwark Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 1TL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Southwark Street',
#      'London SE1 1TL',
#      'United Kingdom']},
#    'phone': '+442030262283',
#    'display_phone': '+44 20 3026 2283',
#    'distance': 3230.9293288880117},
#   {'id': '-22PaX8rQyh0ZQrdCiDz4A',
#    'alias': 'fuckoffee-london-3',
#    'name': 'Fuckoffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MQ7RV7bMOSjdLX1DfhzQ_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fuckoffee-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 87,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4993814, 'longitude': -0.0812485},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '163-167 Bermondsey Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 3UW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['163-167 Bermondsey Street',
#      'London SE1 3UW',
#      'United Kingdom']},
#    'phone': '+442074037655',
#    'display_phone': '+44 20 7403 7655',
#    'distance': 4071.1885164771065},
#   {'id': 'BJPoMcoKJxrs_QT4_PcL8A',
#    'alias': 'bloomsbury-cafe-london',
#    'name': 'Bloomsbury Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lGKxROCBx-YKn806nO8xWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bloomsbury-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5175164253045,
#     'longitude': -0.127287250243864},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '16 Bloomsbury Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3QA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Bloomsbury Street',
#      'London WC1B 3QA',
#      'United Kingdom']},
#    'phone': '+442076378400',
#    'display_phone': '+44 20 7637 8400',
#    'distance': 794.1799236505923},
#   {'id': 'flkj8L8l2OZ2SZts7G9THQ',
#    'alias': 'basils-sandwiches-london',
#    'name': 'Basils Sandwiches',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/te73mvLzErxn31aV5aIfNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/basils-sandwiches-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51118, 'longitude': -0.0793951},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '15 New London Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3R 7NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 New London Street',
#      'London EC3R 7NA',
#      'United Kingdom']},
#    'phone': '+442074805995',
#    'display_phone': '+44 20 7480 5995',
#    'distance': 3910.9103819839283},
#   {'id': 'rn70OOQObZ5TxvIahNSl7w',
#    'alias': 'chanteroy-london',
#    'name': 'Chanteroy',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aK36AUi8VjIHMADgKKBzoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chanteroy-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cheese', 'title': 'Cheese Shops'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4450952518046,
#     'longitude': -0.205981699624434},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '233a Wimbledon Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW18 5RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['233a Wimbledon Park Road',
#      'London SW18 5RJ',
#      'United Kingdom']},
#    'phone': '+442088741446',
#    'display_phone': '+44 20 8874 1446',
#    'distance': 8958.445522157237},
#   {'id': 'riWepzZEIHj82UiDk_WVLQ',
#    'alias': 'montparnasse-cafe-london-2',
#    'name': 'Montparnasse Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/90P9GQECkOj3aZIrJfpO8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/montparnasse-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5005205, 'longitude': -0.1885342},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '22 Thackeray Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 5ET',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Thackeray Street',
#      'London W8 5ET',
#      'United Kingdom']},
#    'phone': '+442073762212',
#    'display_phone': '+44 20 7376 2212',
#    'distance': 3888.086719460034},
#   {'id': 'EEquXLKz0cz4wTFTRcKgmQ',
#    'alias': 'paul-rothe-and-sons-london-3',
#    'name': 'Paul Rothe & Sons',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Rj0lR22wIH-rejrbJlunig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-rothe-and-sons-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'gourmet', 'title': 'Specialty Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.516839, 'longitude': -0.150843},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '35 Marylebone Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 2NN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35 Marylebone Lane',
#      'London W1U 2NN',
#      'United Kingdom']},
#    'phone': '+442079356783',
#    'display_phone': '+44 20 7935 6783',
#    'distance': 1121.035787893208},
#   {'id': 'Ts-q6d50M1ph0QcunvdHZg',
#    'alias': 'panino-d-oro-london-4',
#    'name': "Panino D' Oro",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZCrxK4OcWg3OIXLU2--mug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/panino-d-oro-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4510807, 'longitude': -0.0857394},
#    'transactions': [],
#    'location': {'address1': '37 Dulwich Village',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE21 7BN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['37 Dulwich Village',
#      'London SE21 7BN',
#      'United Kingdom']},
#    'phone': '+442086932614',
#    'display_phone': '+44 20 8693 2614',
#    'distance': 7692.675056827686},
#   {'id': '6Yp6zR3CJpckXO6IVxmM3w',
#    'alias': 'the-deli-downstairs-london',
#    'name': 'The Deli Downstairs',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-ru8ET4tO0oRc1g7dF4Fog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-deli-downstairs-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.538265474899,
#     'longitude': -0.0451950425471481},
#    'transactions': [],
#    'location': {'address1': '211 Victoria Park Road',
#     'address2': 'Victoria Park Village',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E9 7JN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['211 Victoria Park Road',
#      'Victoria Park Village',
#      'London E9 7JN',
#      'United Kingdom']},
#    'phone': '+442085335006',
#    'display_phone': '+44 20 8533 5006',
#    'distance': 6886.309835412619},
#   {'id': 'zYUCY6y7RqC7GB0xPAZZNg',
#    'alias': 'the-sandwich-centre-london',
#    'name': 'The Sandwich Centre',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AFsOo7vJvSqGsVvA1cV1Bw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-sandwich-centre-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5071972354505,
#     'longitude': -0.131873477246131},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '15-16 Royal Opera Arcade',
#     'address2': 'Pall Mall',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 4UY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15-16 Royal Opera Arcade',
#      'Pall Mall',
#      'London SW1Y 4UY',
#      'United Kingdom']},
#    'phone': '+442078397838',
#    'display_phone': '+44 20 7839 7838',
#    'distance': 687.6631791429497},
#   {'id': 'hnQ_HGysnRv8IMMtDYhLCA',
#    'alias': 'yolk-breaker-london',
#    'name': 'Yolk Breaker',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RjbGkiMgFJ8vTJWXtGdJOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yolk-breaker-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5419998168945,
#     'longitude': -0.147372007369995},
#    'transactions': [],
#    'location': {'address1': 'Unit 701 Stables Market',
#     'address2': 'Chalk Farm Road Camden Town London',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8AH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 701 Stables Market',
#      'Chalk Farm Road Camden Town London',
#      'London NW1 8AH',
#      'United Kingdom']},
#    'phone': '+447736066662',
#    'display_phone': '+44 7736 066662',
#    'distance': 3336.1545652666314},
#   {'id': 'JufEVrCH41pMNDuS9_N-gw',
#    'alias': 'the-fields-beneath-london',
#    'name': 'The Fields Beneath',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/L4ougAp44U0FZHCIJjsQwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-fields-beneath-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5466077925974,
#     'longitude': -0.146729706191089},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '52a Prince of Wales Road',
#     'address2': 'Kentish Town West Station',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW5 3LN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['52a Prince of Wales Road',
#      'Kentish Town West Station',
#      'London NW5 3LN',
#      'United Kingdom']},
#    'phone': '+442074248838',
#    'display_phone': '+44 20 7424 8838',
#    'distance': 3828.5426145620913},
#   {'id': 'FdfIx7h5tRd4AAMcXHrljw',
#    'alias': 'birley-sandwiches-london-6',
#    'name': 'Birley Sandwiches',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JV8io1KHFrmdrKfaBDEgdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/birley-sandwiches-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5051509130517,
#     'longitude': -0.0213405953842312},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 23A',
#     'address2': '1 Canada Square',
#     'address3': 'Canary Wharf',
#     'city': 'London',
#     'zip_code': 'E14 5AX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 23A',
#      '1 Canada Square',
#      'Canary Wharf',
#      'London E14 5AX',
#      'United Kingdom']},
#    'phone': '+442077191163',
#    'display_phone': '+44 20 7719 1163',
#    'distance': 7978.035748799018},
#   {'id': '7-YZnDoXzUgy9Lbstyf4Ag',
#    'alias': 'the-bathurst-deli-london',
#    'name': 'The Bathurst Deli',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r07psgJ1H0s6-RqSRuz9uA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bathurst-deli-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5129138, 'longitude': -0.1747844},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '3 Bathurst Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 2SD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Bathurst Street',
#      'London W2 2SD',
#      'United Kingdom']},
#    'phone': '+442072621888',
#    'display_phone': '+44 20 7262 1888',
#    'distance': 2683.70881653556},
#   {'id': 'OOsowaqAUF_O7wN3JbEVFw',
#    'alias': 'project-sandwich-london',
#    'name': 'Project Sandwich',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5Rm6aXP7F4kVBa2M5qTwhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/project-sandwich-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'streetvendors', 'title': 'Street Vendors'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.53349, 'longitude': -0.1246},
#    'transactions': [],
#    'location': {'address1': 'Kings Boulevard',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N1C',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Kings Boulevard', 'London N1C', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2413.729712695603},
#   {'id': 'xUgb5NTJl_T9DgIf7EOkwg',
#    'alias': 'la-bottega-london',
#    'name': 'La Bottega',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jDnpwYUFmQgOQf5iQe4mHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-bottega-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.490429, 'longitude': -0.156665},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '65 Lower Sloane Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 8DH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['65 Lower Sloane Street',
#      'London SW1W 8DH',
#      'United Kingdom']},
#    'phone': '+442077308844',
#    'display_phone': '+44 20 7730 8844',
#    'distance': 2881.443777320836},
#   {'id': 'mNrNR1_e3nBw52uKhVvqjg',
#    'alias': 'anthonys-delicatessen-london',
#    'name': "Anthony's Delicatessen",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/r-VBmr7gD9Isz4--Q54hig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anthonys-delicatessen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'food', 'title': 'Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5410864, 'longitude': -0.1571539},
#    'transactions': [],
#    'location': {'address1': '146 Regents Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8XN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['146 Regents Park Road',
#      'London NW1 8XN',
#      'United Kingdom']},
#    'phone': '+442077229246',
#    'display_phone': '+44 20 7722 9246',
#    'distance': 3479.9911983932693},
#   {'id': 'SUwNHvDR-oUN424viI7krQ',
#    'alias': 'monty-s-deli-london',
#    'name': 'Monty’s Deli',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jlJV8gznue2rnm6DEnmnKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/monty-s-deli-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.513894, 'longitude': -0.126301},
#    'transactions': [],
#    'location': {'address1': 'Kerb Seven Dials Market',
#     'address2': 'Earlham Street',
#     'address3': 'Covent Garden',
#     'city': 'London',
#     'zip_code': 'WC2H 9LX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Kerb Seven Dials Market',
#      'Earlham Street',
#      'Covent Garden',
#      'London WC2H 9LX',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 678.4015661755786},
#   {'id': '1vBxuy7xZfJ1is3FRR3ecA',
#    'alias': 'souli-london',
#    'name': 'Souli',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qIu3RWUIeY6V77JflTaCLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/souli-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5177106042592,
#     'longitude': -0.153749920427799},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '17 George Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 3QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17 George Street',
#      'London W1U 3QL',
#      'United Kingdom']},
#    'phone': '+442074860483',
#    'display_phone': '+44 20 7486 0483',
#    'distance': 1345.3477942845568},
#   {'id': 'C6V1QzVasY85J1W7niwEjg',
#    'alias': 'crust-london',
#    'name': 'Crust',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Dkx5zXNNOAUx7uHBzTAfzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crust-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafeteria', 'title': 'Cafeteria'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4932660088153,
#     'longitude': -0.141164995729923},
#    'transactions': [],
#    'location': {'address1': '56-62 Wilton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1DE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['56-62 Wilton Road',
#      'London SW1V 1DE',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2205.697180417537},
#   {'id': 'T5ifm1dzc33tvnDyY-l3Ig',
#    'alias': 'grill-my-cheese-london',
#    'name': 'Grill My Cheese',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pnsNqM1d0JNIxgsYl2bMRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grill-my-cheese-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'streetvendors', 'title': 'Street Vendors'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5199901, 'longitude': -0.1093684},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Leather Lane Market',
#     'address2': 'Leather Lane',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1N 7RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Leather Lane Market',
#      'Leather Lane',
#      'London EC1N 7RJ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2004.3708616469376},
#   {'id': 'jfMtjw59rQNEQctWOwLGZA',
#    'alias': 'paxton-and-whitfield-london',
#    'name': 'Paxton & Whitfield',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HNpY2NLtlonXW5NyWHOqWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paxton-and-whitfield-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'cheese', 'title': 'Cheese Shops'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.508234, 'longitude': -0.136709},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '93 Jermyn Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 6JE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['93 Jermyn Street',
#      'London SW1Y 6JE',
#      'United Kingdom']},
#    'phone': '+442079300259',
#    'display_phone': '+44 20 7930 0259',
#    'distance': 510.2778902615807},
#   {'id': 'oOABLDZgNb6mloCJ9kuCQQ',
#    'alias': 'doorsteps-london-2',
#    'name': 'Doorsteps',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uhBc-4hz1KId4qB2rauy0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doorsteps-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4938053, 'longitude': -0.2263275},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '3a Hammersmith Grove',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W6 0ND',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3a Hammersmith Grove',
#      'London W6 0ND',
#      'United Kingdom']},
#    'phone': '+442087414066',
#    'display_phone': '+44 20 8741 4066',
#    'distance': 6603.339072585866},
#   {'id': 'SDuYp1_7GMqahGY1Be0Gkw',
#    'alias': 'rosetta-london-3',
#    'name': 'Rosetta',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9JmzKE87t3cPn0aIpC2vGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rosetta-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5095309021108,
#     'longitude': -0.12663403261004},
#    'transactions': [],
#    'location': {'address1': '38 William IV Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2N 4DD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38 William IV Street',
#      'London WC2N 4DD',
#      'United Kingdom']},
#    'phone': '+447502572371',
#    'display_phone': '+44 7502 572371',
#    'distance': 742.4127520523106},
#   {'id': 'OLSP9V0V7xjDrkksBlbJHA',
#    'alias': 'reubens-london',
#    'name': 'Reubens',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nbiZGxpQ7Dtsb2_4T1bX4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/reubens-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'kosher', 'title': 'Kosher'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5197718, 'longitude': -0.1566207},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '79 Baker Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 6AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['79 Baker Street',
#      'London W1U 6AG',
#      'United Kingdom']},
#    'phone': '+442074860035',
#    'display_phone': '+44 20 7486 0035',
#    'distance': 1632.9555012851665},
#   {'id': 'L_K05ZLnvWYSWUWjgpSiqA',
#    'alias': 'h-t-harris-london',
#    'name': 'H T Harris',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cJIa4L6kqM8KharufW0wBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/h-t-harris-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5183508, 'longitude': -0.1407232},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '41 Great Titchfield Street',
#     'address2': 'Marylebone',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1W 7PG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41 Great Titchfield Street',
#      'Marylebone',
#      'London W1W 7PG',
#      'United Kingdom']},
#    'phone': '+442076364228',
#    'display_phone': '+44 20 7636 4228',
#    'distance': 696.3665523247838},
#   {'id': 'hZUr4JjPSMpVZrCzU8kIww',
#    'alias': 'pacific-social-club-london',
#    'name': 'Pacific Social Club',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/T-hSF5fZlnSvFuNHzRL90A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pacific-social-club-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.549910508815,
#     'longitude': -0.0549815967679024},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '8 Clarence Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E5 8HB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Clarence Road', 'London E5 8HB', 'United Kingdom']},
#    'phone': '+447816963127',
#    'display_phone': '+44 7816 963127',
#    'distance': 6954.775507366697}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#               Restaurant          Type Price Rating             Address  \
# 0          Sandwich Shop    Sandwiches     £    4.5  54 Gloucester Road
# 1            Kappacasein  Cheese Shops     £    4.5     1 Stoney Street
# 2      The Sandwich Shop    Sandwiches                  19 Dacre Street
# 3    Max's Sandwich Shop    Sandwiches     £    4.5      19 Crouch Hill
# 4  Mayfair Sandwich Shop     Fast Food                7 Stafford Street
#
#          Lat       Lng                                                url  \
# 0  51.498021 -0.183931  https://www.yelp.com/biz/sandwich-shop-london?...
# 1  51.505052 -0.090898  https://www.yelp.com/biz/kappacasein-london?ad...
# 2  51.499007 -0.132450
# 3  51.570609 -0.116188  https://www.yelp.com/biz/maxs-sandwich-shop-lo...
# 4  51.508407 -0.141947
#
#                        ID
# 0  c897jdNz40fc0AzNhmf4xg
# 1  DqYZGmadZod5zqdhgsBoJw
# 2
# 3  0sjH44nfLe0nr1uBZPNWAQ
# 4

# %%
#2nd set of 50 records 51-100 
lndr_params2 = {"term":term,"location":"London","limit":50,"offset":51}
lndr_response2 = requests.get(search_api_url, headers=headers, params=lndr_params2)
lndr2 = lndr_response2.json()
display(lndr2)
#print(lndr_response2.url)
#print(lndr_response2.status_code)
# Out:
# {'businesses': [{'id': 'bgMJHURGZftfI441orwhMg',
#    'alias': 'm-moen-and-sons-london',
#    'name': 'M Moen & Sons',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/d7FKod0MDPatLcDgm-GZrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/m-moen-and-sons-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4622982, 'longitude': -0.1401057},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '24 The Pavement',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW4 0JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 The Pavement',
#      'London SW4 0JA',
#      'United Kingdom']},
#    'phone': '+442076221624',
#    'display_phone': '+44 20 7622 1624',
#    'distance': 5622.176254665025},
#   {'id': 'biJZD-gqBEN-J1x1legG_A',
#    'alias': 'giacobazzis-delicatessen-london',
#    'name': "Giacobazzi's Delicatessen",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GwV-DC944seLagc_tArDMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giacobazzis-delicatessen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5540721, 'longitude': -0.164456},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '150 Fleet Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 2QX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['150 Fleet Road', 'London NW3 2QX', 'United Kingdom']},
#    'phone': '+442072677222',
#    'display_phone': '+44 20 7267 7222',
#    'distance': 4977.5177359611625},
#   {'id': 'lEpFzAUcPvUhAHdZwL5tbA',
#    'alias': 'bon-appetit-london',
#    'name': 'Bon Appetit',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aMu4b0TWrU-LwUhMwHFvIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bon-appetit-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5272677, 'longitude': -0.190531},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '73 Castellain Road',
#     'address2': 'Maida Vale',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W9 1EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['73 Castellain Road',
#      'Maida Vale',
#      'London W9 1EU',
#      'United Kingdom']},
#    'phone': '+442072664365',
#    'display_phone': '+44 20 7266 4365',
#    'distance': 4102.914828298527},
#   {'id': 'nBHgQH6Fo7VZ5ipeV9FZmA',
#    'alias': 'bonne-bouche-london',
#    'name': 'Bonne Bouche',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qrnNxCG7Iflid-AiSnSzew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bonne-bouche-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5181053211288,
#     'longitude': -0.151716128809521},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '2-3 Thayer Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 3JB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2-3 Thayer Street',
#      'London W1U 3JB',
#      'United Kingdom']},
#    'phone': '+442074869584',
#    'display_phone': '+44 20 7486 9584',
#    'distance': 1238.0218508033952},
#   {'id': 'PhnQPC4OIxieq61FC_BCiA',
#    'alias': 'make-mine-london-2',
#    'name': 'Make Mine',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-aYfxSD5MLmKdEN1QCX6dA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/make-mine-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5172052, 'longitude': -0.1424428},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '314-322 Regent St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 3BB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['314-322 Regent St',
#      'London W1B 3BB',
#      'United Kingdom']},
#    'phone': '+442076361308',
#    'display_phone': '+44 20 7636 1308',
#    'distance': 661.4995051105816},
#   {'id': '6cv-z48HnGcMZMF2jdeYzw',
#    'alias': 'the-marylebone-kitchen-marylebone',
#    'name': 'The Marylebone Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lhpXtUuhqYXPix0dWkZM2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-marylebone-kitchen-marylebone?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5197623, 'longitude': -0.1639772},
#    'transactions': [],
#    'location': {'address1': '106 York Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Marylebone',
#     'zip_code': 'W1H 4QN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['106 York Street',
#      'Marylebone W1H 4QN',
#      'United Kingdom']},
#    'phone': '+442077247552',
#    'display_phone': '+44 20 7724 7552',
#    'distance': 2086.3362670400315},
#   {'id': 'tJ9btKiYYgAe1SST_foP_Q',
#    'alias': 'caffè-fratelli-london-7',
#    'name': 'Caffè Fratelli',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T7svPpqg5djvu3LjOUBkWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caff%C3%A8-fratelli-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.492956, 'longitude': -0.149779},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '21 Elizabeth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 9RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21 Elizabeth Street',
#      'London SW1W 9RP',
#      'United Kingdom']},
#    'phone': '+442077303950',
#    'display_phone': '+44 20 7730 3950',
#    'distance': 2409.348485866322},
#   {'id': 'e5jPAqpCcIAsTtasUN5h2g',
#    'alias': 'the-wolseley-london',
#    'name': 'The Wolseley',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T9xpXsz-az88-l0Ko_KLpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wolseley-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 553,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.507617, 'longitude': -0.141012},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '160 Picadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 9EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['160 Picadilly', 'London W1J 9EB', 'United Kingdom']},
#    'phone': '+442074996996',
#    'display_phone': '+44 20 7499 6996',
#    'distance': 677.6098617325135},
#   {'id': 'f4bEfbf1_VyZpLsvlonhMw',
#    'alias': 'paul-gloucester-road-london',
#    'name': 'PAUL - Gloucester Road',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4LmyxBx2ijOg34FW_YfI9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-gloucester-road-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 56,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4949745, 'longitude': -0.1825811},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '73 Gloucester Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 4SS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['73 Gloucester Road',
#      'London SW7 4SS',
#      'United Kingdom']},
#    'phone': '+442073731232',
#    'display_phone': '+44 20 7373 1232',
#    'distance': 3789.8998601376957},
#   {'id': 'DUS7Nz3429d2iv0q-Jky9A',
#    'alias': 'paul-london-3',
#    'name': 'Paul',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_deqF7vT-EKCTReCgaMVqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4990676958953,
#     'longitude': -0.165139898919551},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '122 Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 1JD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['122 Brompton Road',
#      'London SW3 1JD',
#      'United Kingdom']},
#    'phone': '+442075846117',
#    'display_phone': '+44 20 7584 6117',
#    'distance': 2534.4748856906567},
#   {'id': '1OcBgrUzPgp82BfZBUKRow',
#    'alias': 'gails-bakery-hampstead-london',
#    'name': "GAIL's Bakery Hampstead",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UOf253iDTU_yHsHrbwwV2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-hampstead-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5561216, 'longitude': -0.1779628},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '64 Hampstead High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 1QH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['64 Hampstead High Street',
#      'London NW3 1QH',
#      'United Kingdom']},
#    'phone': '+442077940926',
#    'display_phone': '+44 20 7794 0926',
#    'distance': 5621.242336165493},
#   {'id': '7Yeu8jD6o1JgTWtRaG5CTA',
#    'alias': 'wa-cafe-london',
#    'name': 'WA Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/c50IInTblFehgbYf3JQb8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wa-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5155095, 'longitude': -0.3020439},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '32 Haven Green Ealing',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W5 2NX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['32 Haven Green Ealing',
#      'London W5 2NX',
#      'United Kingdom']},
#    'phone': '+442089917855',
#    'display_phone': '+44 20 8991 7855',
#    'distance': 11496.95023475837},
#   {'id': 'Z05IfjbLhn6flUZOaBPTrw',
#    'alias': 'deeneys-london',
#    'name': "Deeney's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2TOjqwYFv2oD0p1N8adTxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/deeneys-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'scottish', 'title': 'Scottish'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5360641, 'longitude': -0.0618433},
#    'transactions': [],
#    'location': {'address1': '22 Broadway Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 4QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Broadway Market',
#      'London E8 4QJ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5751.531734380497},
#   {'id': 'RJd6_J2dekhZT3g7S2sFKQ',
#    'alias': 'ripe-kitchen-london',
#    'name': 'Ripe Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eWdcUDw5jrPd2z1GjchEdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ripe-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'healthmarkets', 'title': 'Health Markets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5406973, 'longitude': -0.1572616},
#    'transactions': [],
#    'location': {'address1': '136 Regents Park Road',
#     'address2': 'Primrose Hill',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8XL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['136 Regents Park Road',
#      'Primrose Hill',
#      'London NW1 8XL',
#      'United Kingdom']},
#    'phone': '+447572480102',
#    'display_phone': '+44 7572 480102',
#    'distance': 3430.830308059021},
#   {'id': 'ltNrgT5KBga_-G09KPKUGA',
#    'alias': 'ginger-and-white-london',
#    'name': 'Ginger & White',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7QXlwpFegZ2gwdzLskNX8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginger-and-white-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5554778031252, 'longitude': -0.178065},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "4 Perrin's Court",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 1QS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["4 Perrin's Court",
#      'London NW3 1QS',
#      'United Kingdom']},
#    'phone': '+442074319098',
#    'display_phone': '+44 20 7431 9098',
#    'distance': 5564.726459557364},
#   {'id': 'KBTZHuvXVCwEskNtj0Q1SA',
#    'alias': 'italian-gardens-cafe-london',
#    'name': 'Italian Gardens Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Egmi4aUdIR97Yhl9KT3v8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/italian-gardens-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5115726564169,
#     'longitude': -0.175203145592036},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '61 Bayswater Road',
#     'address2': 'Hyde Park - Marlborough Gate',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 3PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Bayswater Road',
#      'Hyde Park - Marlborough Gate',
#      'London W2 3PH',
#      'United Kingdom']},
#    'phone': '+443000612000',
#    'display_phone': '+44 300 061 2000',
#    'distance': 2719.616092978104},
#   {'id': 'SE7wpud8QuVIc8VKUochDA',
#    'alias': 'eggslut-notting-hill',
#    'name': 'Eggslut',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7k5-rAYrz81qHWtgKnbocw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eggslut-notting-hill?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5153442, 'longitude': -0.2048745},
#    'transactions': [],
#    'location': {'address1': '185 Portobello Road',
#     'address2': '',
#     'address3': None,
#     'city': 'Notting Hill',
#     'zip_code': 'W11 2ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['185 Portobello Road',
#      'Notting Hill W11 2ED',
#      'United Kingdom']},
#    'phone': '+442037451920',
#    'display_phone': '+44 20 3745 1920',
#    'distance': 4775.790389917452},
#   {'id': 'iJOxs_39A55S3qNDtMRPWg',
#    'alias': 'roast-to-go-london',
#    'name': 'Roast To Go',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rWWpGMEKkObyTcAgycRS9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roast-to-go-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5056071178748,
#     'longitude': -0.0910057691819765},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Borough Market',
#     'address2': 'Stoney Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1TL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Borough Market',
#      'Stoney Street',
#      'London SE1 1TL',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3212.9883251551605},
#   {'id': '0BDuohnoATEnz1c_5jxIdg',
#    'alias': 'gastronomica-london-4',
#    'name': 'Gastronomica',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gA6un8X7AD89G4vkmq7cTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gastronomica-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'foodstands', 'title': 'Food Stands'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.505428, 'longitude': -0.090252},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Borough Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9AL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Borough Market', 'London SE1 9AL', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3233.288662828306},
#   {'id': 'MBNN96eKz8i54UIVyfI_2g',
#    'alias': 'brompton-food-market-london',
#    'name': 'Brompton Food Market',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JrIap64uj6nZJrd7zugAzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brompton-food-market-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'butcher', 'title': 'Butcher'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4947643464837,
#     'longitude': -0.174170505922529},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '33 Thurloe Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 2HQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['33 Thurloe Place',
#      'London SW7 2HQ',
#      'United Kingdom']},
#    'phone': '+442075844491',
#    'display_phone': '+44 20 7584 4491',
#    'distance': 3321.7283081802034},
#   {'id': 'oJDD01g3TWrT2jFcXI2Kxw',
#    'alias': 'the-sandwich-box-london',
#    'name': 'The Sandwich Box',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6aXIqXh2SLv-MOPdiyVE_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-sandwich-box-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'catering', 'title': 'Caterers'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5601278, 'longitude': -0.1007308},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '4A Gillespie Road',
#     'address2': 'Highbury',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N5 1LN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4A Gillespie Road',
#      'Highbury',
#      'London N5 1LN',
#      'United Kingdom']},
#    'phone': '+442077041988',
#    'display_phone': '+44 20 7704 1988',
#    'distance': 5795.618518012961},
#   {'id': '9j2NnQ-SqTw-3NOoSoRY4g',
#    'alias': 'make-mine-london',
#    'name': 'Make Mine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0oCuJ0AWEjrldCw9gaLINw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/make-mine-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514697552511,
#     'longitude': -0.13331281200855},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '86 Dean Street',
#     'address2': '',
#     'address3': 'Soho',
#     'city': 'London',
#     'zip_code': 'W1D 3SR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['86 Dean Street',
#      'Soho',
#      'London W1D 3SR',
#      'United Kingdom']},
#    'phone': '+442072872385',
#    'display_phone': '+44 20 7287 2385',
#    'distance': 276.2593392346476},
#   {'id': 'sfDSKAKez1MBs1qfiwUb9w',
#    'alias': 'nanis-london',
#    'name': 'Nanis',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ClWYLuVUTeOQ36FlG1mwHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nanis-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.520061, 'longitude': -0.142525},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '134 Great Portland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 6PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['134 Great Portland Street',
#      'London W1W 6PX',
#      'United Kingdom']},
#    'phone': '+442076371060',
#    'display_phone': '+44 20 7637 1060',
#    'distance': 921.1428173321054},
#   {'id': 'VE2kOujaYhEZ8hSKrm1iMw',
#    'alias': 'liberty-cheesesteak-company-london',
#    'name': 'Liberty Cheesesteak Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8_zpp8sQfZOFrSuHJY9UYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/liberty-cheesesteak-company-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'foodstands', 'title': 'Food Stands'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.522045135498,
#     'longitude': -0.140456005930901},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Cleveland St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 6NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Cleveland St', 'London W1T 6NE', 'United Kingdom']},
#    'phone': '+447793269739',
#    'display_phone': '+44 7793 269739',
#    'distance': 1070.224846236651},
#   {'id': 'dGkVk041v8tevLofLY8GTg',
#    'alias': 'enrique-tomas-london',
#    'name': 'Enrique Tomas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6Q_S9TF9uudbCXWilI_MqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/enrique-tomas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5144489879813,
#     'longitude': -0.134711450693457},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '132 Wardour Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0TY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['132 Wardour Street',
#      'Soho',
#      'London W1F 0TY',
#      'United Kingdom']},
#    'phone': '+442072872303',
#    'display_phone': '+44 20 7287 2303',
#    'distance': 199.00362720340348},
#   {'id': 'nHMn6sJQEj1c2cnGThyvvg',
#    'alias': 'harrods-food-hall-london',
#    'name': 'Harrods Food Hall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lTez1h3O4WyMt5kA4i8FBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harrods-food-hall-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 325,
#    'categories': [{'alias': 'cheese', 'title': 'Cheese Shops'},
#     {'alias': 'wineries', 'title': 'Wineries'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4990917420527,
#     'longitude': -0.162348972665107},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '87-135 Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7XL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['87-135 Brompton Road',
#      'London SW1X 7XL',
#      'United Kingdom']},
#    'phone': '+442077301234',
#    'display_phone': '+44 20 7730 1234',
#    'distance': 2381.6721756016004},
#   {'id': 'k9sDFW6lHgdFAmQJ-tLMqw',
#    'alias': 'smack-lobster-roll-london-2',
#    'name': 'Smack Lobster Roll',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vxuZxfVD1YXWx3LYXtZ5lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/smack-lobster-roll-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5126361, 'longitude': -0.132043},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '58 Dean Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6AL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['58 Dean Street', 'London W1D 6AL', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 271.3659975217385},
#   {'id': '0r2-fwgLvuOLef0epiFkFQ',
#    'alias': 'granger-and-co-london',
#    'name': 'Granger & Co',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4pSTSM2JgsADC_cPoLBQJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/granger-and-co-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 183,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514646148453,
#     'longitude': -0.19779915622354},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '175 Westbourne Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['175 Westbourne Grove',
#      'London W11 2SB',
#      'United Kingdom']},
#    'phone': '+442072299111',
#    'display_phone': '+44 20 7229 9111',
#    'distance': 4284.263019990538},
#   {'id': '91TQLypsN7trt-EyX8TgBQ',
#    'alias': 'daisy-green-london-2',
#    'name': 'Daisy Green',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ythY0ZkbjY3cYODreg4hLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daisy-green-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5148104, 'longitude': -0.1579352},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Seymour Street',
#     'address2': 'Marble Arch',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Seymour Street',
#      'Marble Arch',
#      'London W1H 7HX',
#      'United Kingdom']},
#    'phone': '+442077233301',
#    'display_phone': '+44 20 7723 3301',
#    'distance': 1536.7313570216975},
#   {'id': 'OU4wwhyq8ZTN2N7I5V3mTw',
#    'alias': 'ruby-london',
#    'name': 'Ruby',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/awlNZ64lM_A3cWdAmWSPxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ruby-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.525381, 'longitude': -0.081387},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '35 Charlotte Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 3PB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35 Charlotte Road',
#      'London EC2A 3PB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4041.660397872964},
#   {'id': 'KJvWUxpviW95Z6eW2tR8Mg',
#    'alias': 'wendells-deli-cafe-london',
#    'name': 'Wendells Deli Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lqEtpJKgoO0MsgzSzIuv9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wendells-deli-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.499865, 'longitude': -0.084432},
#    'transactions': [],
#    'location': {'address1': '11/13 Weston St',
#     'address2': 'The Leather Market',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 3ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11/13 Weston St',
#      'The Leather Market',
#      'London SE1 3ER',
#      'United Kingdom']},
#    'phone': '+442074077660',
#    'display_phone': '+44 20 7407 7660',
#    'distance': 3810.384585437798},
#   {'id': '5or4AzNouZq8RClNeTdqiA',
#    'alias': 'ole-and-steen-london-2',
#    'name': 'Ole and Steen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HhmDFvGw42MnOJErQE9vkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ole-and-steen-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.509238, 'longitude': -0.1326965},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '56 Haymarket',
#     'address2': '',
#     'address3': "No 2 St James's Market",
#     'city': 'London',
#     'zip_code': 'SW1Y 4RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['56 Haymarket',
#      "No 2 St James's Market",
#      'London SW1Y 4RP',
#      'United Kingdom']},
#    'phone': '+442038288242',
#    'display_phone': '+44 20 3828 8242',
#    'distance': 459.23424350084883},
#   {'id': 'Sh_PrXavTAk2d5jTs_onuQ',
#    'alias': 'nordic-bakery-london',
#    'name': 'Nordic Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y1r_R3BokRhDYZIaF0XB6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nordic-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 118,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'scandinavian', 'title': 'Scandinavian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5114297969411,
#     'longitude': -0.13674108684063},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 Golden Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9JG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Golden Square',
#      'London W1F 9JG',
#      'United Kingdom']},
#    'phone': '+442032301077',
#    'display_phone': '+44 20 3230 1077',
#    'distance': 165.48625457765309},
#   {'id': 'o36QGeErTq7-OKE8DnIF1A',
#    'alias': 'dip-and-flip-wimbledon-wimbledon',
#    'name': 'Dip & Flip- Wimbledon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kcOTf1IhmUo12bQAmNfvtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dip-and-flip-wimbledon-wimbledon?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4197473, 'longitude': -0.2027887},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '62 The Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Wimbledon',
#     'zip_code': 'SW19 1RQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['62 The Broadway',
#      'Wimbledon SW19 1RQ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 11339.092926963276},
#   {'id': 'Ug8nEBDfZyf7JoQ5KoE8Aw',
#    'alias': 'which-wich-london-3',
#    'name': 'Which Wich',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p-OFzbQr6HV7Zk3b2yV3vw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/which-wich-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5160089853739,
#     'longitude': -0.128487481555102},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 8',
#     'address2': 'Central St Giles',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2H 8AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 8',
#      'Central St Giles',
#      'London WC2H 8AG',
#      'United Kingdom']},
#    'phone': '+442038796677',
#    'display_phone': '+44 20 3879 6677',
#    'distance': 625.7782016620733},
#   {'id': 'MMJC81TUIGgx0Hs7wbZ07g',
#    'alias': 'double-js-sandwich-bar-london-2',
#    'name': "Double J's Sandwich Bar",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CwtXwltbkCDPFhYzqjxoMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/double-js-sandwich-bar-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5245879, 'longitude': -0.1398379},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '333 Euston Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 3AD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['333 Euston Road',
#      'London NW1 3AD',
#      'United Kingdom']},
#    'phone': '+442073881212',
#    'display_phone': '+44 20 7388 1212',
#    'distance': 1334.1237856020898},
#   {'id': 'WIYx8bX_UUJrXELmqnq0HA',
#    'alias': 'brunel-sandwich-shop-london',
#    'name': 'Brunel Sandwich Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rs3-2i--REP0iSUH2WsHmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brunel-sandwich-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5130333, 'longitude': -0.1132614},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '211 Strand',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2R 1AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['211 Strand', 'London WC2R 1AP', 'United Kingdom']},
#    'phone': '+442073531972',
#    'display_phone': '+44 20 7353 1972',
#    'distance': 1575.1019917293893},
#   {'id': 'nSdZXe2tbFS9iME-pbjbyw',
#    'alias': 'angel-delicatessen-london',
#    'name': 'Angel Delicatessen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kvP1cfK-Ky0ZH486RYrsOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/angel-delicatessen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5395126342773,
#     'longitude': -0.101572997868061},
#    'transactions': [],
#    'location': {'address1': '48 Cross Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 2BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['48 Cross Street', 'London N1 2BA', 'United Kingdom']},
#    'phone': '+442072261951',
#    'display_phone': '+44 20 7226 1951',
#    'distance': 3802.2525856509615},
#   {'id': '-KMMxUbXF3rlYqnEnacuWA',
#    'alias': 'lincoln-sandwich-shop-london',
#    'name': 'Lincoln Sandwich Shop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LiDhLD_dICFLO0OS2PC9AA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lincoln-sandwich-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.517258, 'longitude': -0.118987},
#    'transactions': [],
#    'location': {'address1': '2 Gate Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2A 3HP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Gate Street', 'London WC2A 3HP', 'United Kingdom']},
#    'phone': '+442074051137',
#    'display_phone': '+44 20 7405 1137',
#    'distance': 1260.3964193143895},
#   {'id': 'BjPq77aiaKZAVUHIu2S3gA',
#    'alias': 'the-english-rose-cafe-and-tea-shop-london',
#    'name': 'The English Rose Cafe and Tea Shop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B_v1cOkgPEcbr8e2rtfaog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-english-rose-cafe-and-tea-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 213,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4980558, 'longitude': -0.1444512},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 Lower Grosvenor Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 0EJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Lower Grosvenor Place',
#      'London SW1W 0EJ',
#      'United Kingdom']},
#    'phone': '+442079766280',
#    'display_phone': '+44 20 7976 6280',
#    'distance': 1745.2072668809335},
#   {'id': 't998_qiX0wX0bmAbLhJy3g',
#    'alias': 'earls-sandwiches-london-2',
#    'name': 'Earls Sandwiches',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jgxVdlm3zMZEANkYYFe8Eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/earls-sandwiches-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512119, 'longitude': -0.082593},
#    'transactions': [],
#    'location': {'address1': '7 Cullum Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3M 7JJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Cullum Street',
#      'London EC3M 7JJ',
#      'United Kingdom']},
#    'phone': '+442076261694',
#    'display_phone': '+44 20 7626 1694',
#    'distance': 3704.966086502596},
#   {'id': 'hWJqgTY0AucCidghJ3Wztg',
#    'alias': 'earls-london',
#    'name': "Earl's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nGgxM_ejqQO-TUlxQ66UxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/earls-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5145133, 'longitude': -0.124282},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '14 Endell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9BD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Endell Street',
#      'London WC2H 9BD',
#      'United Kingdom']},
#    'phone': '+442078364665',
#    'display_phone': '+44 20 7836 4665',
#    'distance': 831.7413127994342},
#   {'id': 'jx2vOqV7m4XRgHdA6PIwpA',
#    'alias': 'eddies-food-bar-london',
#    'name': "Eddie's Food Bar",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/l6aANErGAGFeauqKYljr2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eddies-food-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.519684, 'longitude': -0.163124},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '110 Seymour Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 1NJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['110 Seymour Place',
#      'London W1H 1NJ',
#      'United Kingdom']},
#    'phone': '+447903506527',
#    'display_phone': '+44 7903 506527',
#    'distance': 2029.7610127653165},
#   {'id': 'mpObzFGn9UtUw9CJW-xKUA',
#    'alias': 'the-ginger-pig-london',
#    'name': 'The Ginger Pig',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ef-XLCbFxMO3Tr-JZtW2-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ginger-pig-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5198747699266,
#     'longitude': -0.152393400229603},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '8-10 Moxon Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 4EW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8-10 Moxon Street',
#      'London W1U 4EW',
#      'United Kingdom']},
#    'phone': '+442079357788',
#    'display_phone': '+44 20 7935 7788',
#    'distance': 1380.709955973446},
#   {'id': 'PYwzVOvFIjwCMNYV5upPwg',
#    'alias': 'the-attendant-london-2',
#    'name': 'The Attendant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W4pc8bJ_lVWg801nKejVOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-attendant-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 74,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5192470995905,
#     'longitude': -0.140738025145255},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Downstairs 27A',
#     'address2': 'Foley Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 6DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Downstairs 27A',
#      'Foley Street',
#      'London W1W 6DY',
#      'United Kingdom']},
#    'phone': '+442076373794',
#    'display_phone': '+44 20 7637 3794',
#    'distance': 785.9877629261662},
#   {'id': 'Tk83SHGjBMQ6ntQqTC2Hpw',
#    'alias': 'eat-london-30',
#    'name': 'EAT.',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nipoZZdYAG70KsDD2C2RAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eat-london-30?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.509172, 'longitude': -0.1374798},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '36-38 Piccadilly',
#     'address2': 'Malta House',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 0DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['36-38 Piccadilly',
#      'Malta House',
#      'London W1J 0DP',
#      'United Kingdom']},
#    'phone': '+442074943285',
#    'display_phone': '+44 20 7494 3285',
#    'distance': 420.79550725625694},
#   {'id': 'UdFNcwNbwVJ7qNdDXYd_PA',
#    'alias': 'herman-ze-german-london',
#    'name': 'Herman Ze German',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ihuIc-ESzJtO7NVYqkMg8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/herman-ze-german-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 100,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.508297609923,
#     'longitude': -0.12397418784664},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '19 Villiers Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 6NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Villiers Street',
#      'London WC2N 6NE',
#      'United Kingdom']},
#    'phone': '+442079304827',
#    'display_phone': '+44 20 7930 4827',
#    'distance': 970.6457866246815},
#   {'id': 'teXPunKtpwj0NuttvPYhyQ',
#    'alias': 'the-victoria-paddington',
#    'name': 'The Victoria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IscE584D-z4Snf71FJ1bcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-victoria-paddington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 218,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51350403679, 'longitude': -0.17119959969309},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10a Strathearn Place',
#     'address2': '',
#     'address3': '',
#     'city': 'Paddington',
#     'zip_code': 'W2 2NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10a Strathearn Place',
#      'Paddington W2 2NH',
#      'United Kingdom']},
#    'phone': '+442077241191',
#    'display_phone': '+44 20 7724 1191',
#    'distance': 2440.016451414865},
#   {'id': 'SrBFJM2tr4cbxDq8Np8cuw',
#    'alias': 'street-kitchen-london-5',
#    'name': 'Street Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/g9GP88y2yrX7oUh_C1oPcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/street-kitchen-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5403520119311,
#     'longitude': -0.0577667323465869},
#    'transactions': [],
#    'location': {'address1': '381 Mentmore Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 3PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['381 Mentmore Terrace',
#      'London E8 3PH',
#      'United Kingdom']},
#    'phone': '+447710024616',
#    'display_phone': '+44 7710 024616',
#    'distance': 6214.521733397822},
#   {'id': 'LyXXTUzll212_JKMkzC3DQ',
#    'alias': '49-cafe-london',
#    'name': '49 Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PWsAaKgpDIo7aF9k5n6qjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/49-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5249587, 'longitude': -0.1251605},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '49 Marchmont Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 1AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Marchmont Street',
#      'London WC1N 1AP',
#      'United Kingdom']},
#    'phone': '+442035383474',
#    'display_phone': '+44 20 3538 3474',
#    'distance': 1541.1440285471679}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                   Restaurant          Type Price Rating             Address  \
# 0              M Moen & Sons    Meat Shops   £££    4.5     24 The Pavement
# 1  Giacobazzi's Delicatessen         Delis    ££      5      150 Fleet Road
# 2                Bon Appetit         Delis    ££    4.5  73 Castellain Road
# 3               Bonne Bouche  Coffee & Tea     £      4   2-3 Thayer Street
# 4                  Make Mine         Cafes    ££      4   314-322 Regent St
#
#          Lat       Lng                                                url  \
# 0  51.462298 -0.140106  https://www.yelp.com/biz/m-moen-and-sons-londo...
# 1  51.554072 -0.164456  https://www.yelp.com/biz/giacobazzis-delicates...
# 2  51.527268 -0.190531  https://www.yelp.com/biz/bon-appetit-london?ad...
# 3  51.518105 -0.151716  https://www.yelp.com/biz/bonne-bouche-london?a...
# 4  51.517205 -0.142443  https://www.yelp.com/biz/make-mine-london-2?ad...
#
#                        ID
# 0  bgMJHURGZftfI441orwhMg
# 1  biJZD-gqBEN-J1x1legG_A
# 2  lEpFzAUcPvUhAHdZwL5tbA
# 3  nBHgQH6Fo7VZ5ipeV9FZmA
# 4  PhnQPC4OIxieq61FC_BCiA

# %%
#3rd set of 50 records 101-150
lndr_params3 = {"term":term,"location":"London","limit":50,"offset":101}
lndr_response3 = requests.get(search_api_url, headers=headers, params=lndr_params3)
lndr3 = lndr_response3.json()
display(lndr3)
#print(lndr_response3.url)
#print(lndr_response3.status_code)
# Out:
# {'businesses': [{'id': 'DpoSRkEAUGwZeVs7rq9Ajw',
#    'alias': 'viandas-de-salamanca-london',
#    'name': 'Viandas de Salamanca',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QMEdykH5wBoIqXxDe5uD0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/viandas-de-salamanca-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5106618, 'longitude': -0.120628},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '99 Strand',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2R 0EW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['99 Strand', 'London WC2R 0EW', 'United Kingdom']},
#    'phone': '+442072409864',
#    'display_phone': '+44 20 7240 9864',
#    'distance': 1087.9137992649714},
#   {'id': 'ztuEuIDjVTJMklB2OP3rpg',
#    'alias': 'ty-seven-dials-timberyard-london-2',
#    'name': 'TY Seven Dials - Timberyard',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Gr5lHKB84DjJGw8ESo5I6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ty-seven-dials-timberyard-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 138,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5128577362728,
#     'longitude': -0.127308054907987},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "7 Upper St Martin's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["7 Upper St Martin's Lane",
#      'London WC2H 9DL',
#      'United Kingdom']},
#    'phone': '+442032172009',
#    'display_phone': '+44 20 3217 2009',
#    'distance': 598.4373905869091},
#   {'id': '3sShVU-HYAFlmU_dND68dA',
#    'alias': 'brunos-deli-london',
#    'name': "Bruno's Deli",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qqdaJ3dvOCgv3Uk6a16HPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brunos-deli-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5371396660839,
#     'longitude': -0.183738449570932},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '59A Abbey Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 0AD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['59A Abbey Road', 'London NW8 0AD', 'United Kingdom']},
#    'phone': '+442073288692',
#    'display_phone': '+44 20 7328 8692',
#    'distance': 4269.8074669749585},
#   {'id': 'hfmhrnn-ZxQlhI7tTMCWAg',
#    'alias': 'brizzis-london',
#    'name': "Brizzi's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EWdNW_JhPVrOHIR5cVe0ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brizzis-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.527082, 'longitude': -0.136661},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '131 Drummond Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 2HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['131 Drummond Street',
#      'London NW1 2HL',
#      'United Kingdom']},
#    'phone': '+442073800857',
#    'display_phone': '+44 20 7380 0857',
#    'distance': 1578.1096625813698},
#   {'id': 'QuR7O0yd-W4UOM6SeG8L9w',
#    'alias': 'speedys-cafe-london-2',
#    'name': "Speedy's Cafe",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/F1cTubQIjATP_saAVYDGWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/speedys-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5261655, 'longitude': -0.1368146},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '187 North Gower Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 2NJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['187 North Gower Street',
#      'London NW1 2NJ',
#      'United Kingdom']},
#    'phone': '+442073833485',
#    'display_phone': '+44 20 7383 3485',
#    'distance': 1493.323641164572},
#   {'id': 'rKwkCvsSfp8z7w1CmNnMMQ',
#    'alias': 'the-table-london-8',
#    'name': 'The Table',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/T-rwpQYiLxDyUXGNAwEYSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-table-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 268,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.505604, 'longitude': -0.099671},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '83 Southwark Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Southwark Street',
#      'London SE1 0HX',
#      'United Kingdom']},
#    'phone': '+442074012760',
#    'display_phone': '+44 20 7401 2760',
#    'distance': 2636.7435245046486},
#   {'id': '371SNZXi292Y2tPYV-EEmQ',
#    'alias': 'the-roasting-london',
#    'name': 'The Roasting',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lZSW6AQ00PGIzgrwKV912g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-roasting-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4912614, 'longitude': -0.1388321},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '31 Churton Street',
#     'address2': '23 Elizabeth Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 2LY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['31 Churton Street',
#      '23 Elizabeth Street',
#      'London SW1V 2LY',
#      'United Kingdom']},
#    'phone': '+442078346091',
#    'display_phone': '+44 20 7834 6091',
#    'distance': 2394.8792765738704},
#   {'id': 'HaUEkzqd8ahjouFlhvq1tQ',
#    'alias': 'pickles-london-2',
#    'name': 'Pickles',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rt8BFFy1puq4RDeSw_sVEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pickles-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.501011, 'longitude': -0.130923},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '6 Old Queen Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1H 9HP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Old Queen Street',
#      'London SW1H 9HP',
#      'United Kingdom']},
#    'phone': '+442072228749',
#    'display_phone': '+44 20 7222 8749',
#    'distance': 1380.8110470930878},
#   {'id': 'r-USboJFp1ifbtFWtbTGhQ',
#    'alias': 'paper-and-cup-london-2',
#    'name': 'Paper and Cup',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XkBLH87FtSkzIaMMSnmN3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paper-and-cup-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5262201, 'longitude': -0.076815},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '18 Calvert Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7JP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Calvert Avenue',
#      'London E2 7JP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4354.245310616501},
#   {'id': 'ITcGz_zdMW3EyqNBJx6Fxw',
#    'alias': 'burger-and-lobster-london-7',
#    'name': 'Burger & Lobster',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0WdJ5kteNqVnjbmhlmv2nw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burger-and-lobster-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 93,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.501441, 'longitude': -0.159432},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Fifth Floor Harvey Nichols',
#     'address2': '109 - 125 Knightsbridge',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Fifth Floor Harvey Nichols',
#      '109 - 125 Knightsbridge',
#      'London SW1X 7RJ',
#      'United Kingdom']},
#    'phone': '+442072018676',
#    'display_phone': '+44 20 7201 8676',
#    'distance': 2060.3924138301472},
#   {'id': 'aGqt0g9_WU2UGituR7yn-w',
#    'alias': 'farm-girl-cafe-london',
#    'name': 'Farm Girl Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Qxj7RtZyROODLKeUzWbarw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/farm-girl-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 78,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5120686916922,
#     'longitude': -0.200769876546774},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '59A Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 3DB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['59A Portobello Road',
#      'London W11 3DB',
#      'United Kingdom']},
#    'phone': '+442072294678',
#    'display_phone': '+44 20 7229 4678',
#    'distance': 4486.039469290095},
#   {'id': 'xpi-03hbdYsutfcm4D4tTw',
#    'alias': 'mouse-and-de-lotz-london',
#    'name': 'Mouse & de Lotz',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/f2cf8hVgwuyKzUMjKPsBQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mouse-and-de-lotz-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.552791130543,
#     'longitude': -0.070266286872632},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '103 Shacklewell Lane',
#     'address2': 'Dalston',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 2EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['103 Shacklewell Lane',
#      'Dalston',
#      'London E8 2EB',
#      'United Kingdom']},
#    'phone': '+442034898082',
#    'display_phone': '+44 20 3489 8082',
#    'distance': 6354.9116163335975},
#   {'id': 'HAi7bThXmEtooc5ZQq9hdw',
#    'alias': 'laurents-london',
#    'name': 'Laurents',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IjF-yyo_-fqEs5nTO5MMpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laurents-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.513468, 'longitude': -0.179164},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '39 Craven Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 3BX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39 Craven Road', 'London W2 3BX', 'United Kingdom']},
#    'phone': '+442035819232',
#    'display_phone': '+44 20 3581 9232',
#    'distance': 2990.8516064262462},
#   {'id': 'Da8ClETsPknyD-XIam-jbg',
#    'alias': 'maroush-bakehouse-london-6',
#    'name': 'Maroush Bakehouse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hYjyJ-w7yL5JNQ_7sUFl9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maroush-bakehouse-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'lebanese', 'title': 'Lebanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.49332, 'longitude': -0.194478},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '131 Earls Court Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 9RH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['131 Earls Court Road',
#      'London SW5 9RH',
#      'United Kingdom']},
#    'phone': '+442073704324',
#    'display_phone': '+44 20 7370 4324',
#    'distance': 4595.303422118365},
#   {'id': '5YWoARsV4TqJua-pUhOlLg',
#    'alias': 'butchies-london-2',
#    'name': "Butchie's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t--_QA-cOHT8z9U9KrFB3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/butchies-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'},
#     {'alias': 'butcher', 'title': 'Butcher'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5419891, 'longitude': -0.1473598},
#    'transactions': [],
#    'location': {'address1': 'Butchies Hatch',
#     'address2': 'Unit 314 Stables Market',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW1 8AH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Butchies Hatch',
#      'Unit 314 Stables Market',
#      'London NW1 8AH',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3336.341599222763},
#   {'id': 'p77CnjTGOIZA1hEpLfCC6Q',
#    'alias': 'kennington-lane-cafe-london',
#    'name': 'Kennington Lane Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4pjtT4PSUYl_0_BqOTx6Cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kennington-lane-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4860611, 'longitude': -0.1208514},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '383 Kennington Lane',
#     'address2': 'Vauxhall',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE11 5QY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['383 Kennington Lane',
#      'Vauxhall',
#      'London SE11 5QY',
#      'United Kingdom']},
#    'phone': '+442077355853',
#    'display_phone': '+44 20 7735 5853',
#    'distance': 3147.932368103276},
#   {'id': 'HhLos84nKcJMUzAa9HwzBg',
#    'alias': 'wraps-n-more-london-2',
#    'name': "Wraps 'N More",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AhURBj52gW5V0QD5UUOI-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wraps-n-more-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.517215, 'longitude': -0.129784},
#    'transactions': [],
#    'location': {'address1': '8 Great Russell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Great Russell Street',
#      'London WC1B 3NH',
#      'United Kingdom']},
#    'phone': '+442074360360',
#    'display_phone': '+44 20 7436 0360',
#    'distance': 635.8390542558218},
#   {'id': '4rpkLLSPzVRqdHlM9_-9Cw',
#    'alias': 'four-corners-cafe-london-2',
#    'name': 'Four Corners Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rq5jjv5YtDdYt9HJQ8OyEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/four-corners-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5003689, 'longitude': -0.1135442},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '12 Lower Marsh',
#     'address2': 'Waterloo',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Lower Marsh',
#      'Waterloo',
#      'London SE1 7RJ',
#      'United Kingdom']},
#    'phone': '+442086179591',
#    'display_phone': '+44 20 8617 9591',
#    'distance': 2080.282557645936},
#   {'id': 'UjMwZ6-PgXs3BXN7LLOSAw',
#    'alias': 'gails-bakery-pimlico-london',
#    'name': "GAIL's Bakery - Pimlico",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zobkG9NdbclJN7D9O6w5yw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-pimlico-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4917627846861,
#     'longitude': -0.139058523838447},
#    'transactions': [],
#    'location': {'address1': '26 Churton Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1V 2LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Churton Street',
#      'London SW1V 2LP',
#      'United Kingdom']},
#    'phone': '+442079320734',
#    'display_phone': '+44 20 7932 0734',
#    'distance': 2352.9999537192894},
#   {'id': 'mL1mrZVK6Dy-tTAg5zP0wA',
#    'alias': 'belvedere-traditional-london',
#    'name': 'Belvedere Traditional',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ST4z7AVZ2Rqe5peM74jVfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/belvedere-traditional-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'delicatessen', 'title': 'Delicatessen'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5460758, 'longitude': -0.2025756},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '340 Kilburn High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 2QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['340 Kilburn High Road',
#      'London NW6 2QJ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5907.576483286799},
#   {'id': 'MY5vPpDxJFPzj-wR4_pUsg',
#    'alias': 'crumpets-london',
#    'name': 'Crumpets',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2GXRSS7bftG4X6Z-0Q4VxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crumpets-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4991936, 'longitude': -0.1382647},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '82 Buckingham Gate',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1E 6PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['82 Buckingham Gate',
#      'London SW1E 6PD',
#      'United Kingdom']},
#    'phone': '+442072331479',
#    'display_phone': '+44 20 7233 1479',
#    'distance': 1525.3047584226708},
#   {'id': 'SgrEMAIg6bDW5LYSxYzWwQ',
#    'alias': 'anfa-café-london-2',
#    'name': 'Anfa Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qknw6rgXLFKA4xY7w_dO8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anfa-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.522376029083,
#     'longitude': -0.101923942565918},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '102 St John Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1M 4EH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['102 St John Street',
#      'London EC1M 4EH',
#      'United Kingdom']},
#    'phone': '+442074907662',
#    'display_phone': '+44 20 7490 7662',
#    'distance': 2582.7204323859237},
#   {'id': 'VCZ2CxqBvJtffYWYCL_XHg',
#    'alias': 'francos-take-away-london',
#    'name': "Franco's Take Away",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ddu6Qbd-v9twWLXfgxR6mQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/francos-take-away-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5263072, 'longitude': -0.0801147},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '67 Rivington Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 3AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['67 Rivington Street',
#      'London EC2A 3AY',
#      'United Kingdom']},
#    'phone': '+442077390231',
#    'display_phone': '+44 20 7739 0231',
#    'distance': 4165.293352285584},
#   {'id': 'GWeEuO9SvFKldRJBVJFBcw',
#    'alias': 'le-cordon-bleu-london-3',
#    'name': 'Le Cordon Bleu',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4F6VrTrPduCVRwiTQUWVmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-cordon-bleu-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5189056, 'longitude': -0.1237716},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '15 Bloomsbury Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1A 2LS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Bloomsbury Square',
#      'London WC1A 2LS',
#      'United Kingdom']},
#    'phone': '+442074003900',
#    'display_phone': '+44 20 7400 3900',
#    'distance': 1096.4929426913645},
#   {'id': 'PrIqHQtsQl-DnafTdS326A',
#    'alias': 'whitecross-market-london',
#    'name': 'Whitecross Market',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZRvAMD9ErxXzsvFgjeqieQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/whitecross-market-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'streetvendors', 'title': 'Street Vendors'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5228285836074,
#     'longitude': -0.0927653379297215},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '1 Whitecross Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 9AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Whitecross Street',
#      'London EC1V 9AB',
#      'United Kingdom']},
#    'phone': '+442075273830',
#    'display_phone': '+44 20 7527 3830',
#    'distance': 3188.3843760093823},
#   {'id': '4Dsj_RZLMAlay-UBrbrByQ',
#    'alias': 'sheilas-sandwich-bar-london',
#    'name': "Sheila's Sandwich Bar",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sEOhbZn52qAubdkIuwqRyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sheilas-sandwich-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5122422350936,
#     'longitude': -0.178269320031823},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '24a Craven Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3QH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24a Craven Terrace',
#      'London W2 3QH',
#      'United Kingdom']},
#    'phone': '+442074028065',
#    'display_phone': '+44 20 7402 8065',
#    'distance': 2928.894847201483},
#   {'id': 'mWIaThf7jXEFk-IzPfxRrQ',
#    'alias': 'garden-breakfast-cafe-london',
#    'name': 'Garden Breakfast Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QlmAbh_5E8hFLOM7DjwC9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/garden-breakfast-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.545783996582,
#     'longitude': -0.179408997297287},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3 Goldhurst Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 3HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Goldhurst Terrace',
#      'London NW6 3HX',
#      'United Kingdom']},
#    'phone': '+442073282295',
#    'display_phone': '+44 20 7328 2295',
#    'distance': 4739.603460462908},
#   {'id': 'xFjP08phJ-IeeP4EGgt67g',
#    'alias': 'flour-to-the-people-london',
#    'name': 'Flour To The People',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CeeNyGT0oMKW1fz7iLmYTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flour-to-the-people-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.471184, 'longitude': -0.168629},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '573 Battersea Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW11 3BJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['573 Battersea Park Road',
#      'London SW11 3BJ',
#      'United Kingdom']},
#    'phone': '+442072285672',
#    'display_phone': '+44 20 7228 5672',
#    'distance': 5162.824084700251},
#   {'id': 'vrC5KuiEFQFKYtG8n5_n7A',
#    'alias': 'maltby-street-market-london-2',
#    'name': 'Maltby Street Market',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eWL75dMkvlsQi-6ABeD-kw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maltby-street-market-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 82,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'},
#     {'alias': 'streetvendors', 'title': 'Street Vendors'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4992822180825,
#     'longitude': -0.0755775595650676},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Ropewalk',
#     'address2': 'Maltby Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 2HQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Ropewalk',
#      'Maltby Street',
#      'London SE1 2HQ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4442.297967710116},
#   {'id': 'Ca_X0-7tICyuCX3K8E1jvw',
#    'alias': 'bar-bruno-london',
#    'name': 'Bar Bruno',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wlFOxb4BGJBgq-Jt_nM0ZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-bruno-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5130084, 'longitude': -0.1339024},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '101 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0UG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['101 Wardour Street',
#      'London W1F 0UG',
#      'United Kingdom']},
#    'phone': '+442077343750',
#    'display_phone': '+44 20 7734 3750',
#    'distance': 198.24848678293532},
#   {'id': 'kwFb99k3auydqT6AW3xdWg',
#    'alias': 'gails-bakery-london-37',
#    'name': "GAIL's Bakery",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_9ABUB6ZOlM9Yk6PItBVlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-london-37?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.49891, 'longitude': -0.2001699},
#    'transactions': [],
#    'location': {'address1': '240-242 Kensington High Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 5SA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['240-242 Kensington High Street',
#      'London W8 5SA',
#      'United Kingdom']},
#    'phone': '+442073483924',
#    'display_phone': '+44 20 7348 3924',
#    'distance': 4685.080648578934},
#   {'id': '4q6X9JarhmK_8EH8PjFBIw',
#    'alias': 'kiosk-london-4',
#    'name': 'Kiosk',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sb9BaYxXScTZxv5AKRsjlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kiosk-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5312103381264,
#     'longitude': -0.124819908212316},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "King's Cross Station",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4TB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["King's Cross Station",
#      'London N1C 4TB',
#      'United Kingdom']},
#    'phone': '+442033880816',
#    'display_phone': '+44 20 3388 0816',
#    'distance': 2183.6227975440484},
#   {'id': 'cZrzXYDY9vCqNkLw9ZugzQ',
#    'alias': 'wings-sandwich-bar-london',
#    'name': 'Wings Sandwich Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Yd1ldxAnbuNn3h9rV6kfhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wings-sandwich-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.501262959578,
#     'longitude': -0.117073059082031},
#    'transactions': [],
#    'location': {'address1': '39 Drury Lane',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5JZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39 Drury Lane',
#      'Covent Garden',
#      'London WC2B 5JZ',
#      'United Kingdom']},
#    'phone': '+442073796090',
#    'display_phone': '+44 20 7379 6090',
#    'distance': 1834.0621475214707},
#   {'id': '5kF-JWfal4TAM1wJLxM14g',
#    'alias': 'kêu-london-2',
#    'name': 'Kêu!',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/d_1y__VcSCUGtdoi7I5Htw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/k%C3%AAu-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5266075134277,
#     'longitude': -0.0816240012645721},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '332 Old Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 9DR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['332 Old Street',
#      'London EC1V 9DR',
#      'United Kingdom']},
#    'phone': '+442077391164',
#    'display_phone': '+44 20 7739 1164',
#    'distance': 4059.187358291426},
#   {'id': 'n4IsSnZJyE3y3uEfPrk-Ew',
#    'alias': 'matteos-sandwich-bar-london',
#    'name': "Matteo's Sandwich Bar",
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/matteos-sandwich-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.520339, 'longitude': -0.136215},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '32 Tottenham Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 4RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['32 Tottenham Street',
#      'London W1T 4RL',
#      'United Kingdom']},
#    'phone': '+442074361426',
#    'display_phone': '+44 20 7436 1426',
#    'distance': 829.8637378487681},
#   {'id': '116IL0SPhtdXWvEnBlyk6A',
#    'alias': 'tickle-me-sandwich-bar-london',
#    'name': 'Tickle Me Sandwich Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nA6KlVp1DtsMRGXSw8ezzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tickle-me-sandwich-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4313784, 'longitude': -0.1043615},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '56 Knights Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE27 0JD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['56 Knights Hill',
#      'London SE27 0JD',
#      'United Kingdom']},
#    'phone': '+442087619711',
#    'display_phone': '+44 20 8761 9711',
#    'distance': 9322.441243244304},
#   {'id': 'khB6FXx0K94R4ciYEs_Pog',
#    'alias': 'sandwich-box-london',
#    'name': 'Sandwich Box',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VhuMd0T2iu4uiuEWdiZHlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sandwich-box-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.492816345657,
#     'longitude': -0.26719263308274},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '440 Chiswick High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W4 5TT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['440 Chiswick High Road',
#      'London W4 5TT',
#      'United Kingdom']},
#    'phone': '+442089879008',
#    'display_phone': '+44 20 8987 9008',
#    'distance': 9352.47563193303},
#   {'id': 'EeyF4I5YENHrNQICqxe4nA',
#    'alias': 'bagel-bite-london',
#    'name': 'Bagel Bite',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/saptsY4xt1XECThrfnmCnQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagel-bite-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.50388, 'longitude': -0.219407},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '20 Shepherds Bush Green',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W12 8PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Shepherds Bush Green',
#      'London W12 8PH',
#      'United Kingdom']},
#    'phone': '+442087496411',
#    'display_phone': '+44 20 8749 6411',
#    'distance': 5768.804648204201},
#   {'id': 'g2Jt-w1hZ-ycphZIBgGYoA',
#    'alias': 'harrys-london',
#    'name': 'Harrys',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YCikYumo_8BWyfniwEkvow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harrys-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5447149, 'longitude': -0.1035145},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '236 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 1RU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['236 Upper Street',
#      'London N1 1RU',
#      'United Kingdom']},
#    'phone': '+442072261902',
#    'display_phone': '+44 20 7226 1902',
#    'distance': 4195.629622604146},
#   {'id': 'BCXbj5eIrBzq4GlzfSWEKw',
#    'alias': 'putney-pantry-london',
#    'name': 'Putney Pantry',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/z71rv-toFTqghN943I63oQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/putney-pantry-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4659215, 'longitude': -0.2234785},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "St Mary's Church Putney High Street",
#     'address2': 'Putney',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW15 1SN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["St Mary's Church Putney High Street",
#      'Putney',
#      'London SW15 1SN',
#      'United Kingdom']},
#    'phone': '+442087891137',
#    'display_phone': '+44 20 8789 1137',
#    'distance': 7995.850424895337},
#   {'id': 'DaFNeH61PcTia4U3jst8rg',
#    'alias': 'no-name-italian-deli-london-2',
#    'name': 'No Name Italian Deli',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/khPEXRkZ0dScthbEUOmShA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/no-name-italian-deli-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5256703, 'longitude': -0.0875615},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Old Street Station Unit 8',
#     'address2': 'With a red surround',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1Y 1BE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Old Street Station Unit 8',
#      'With a red surround',
#      'London EC1Y 1BE',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3639.9116750439275},
#   {'id': 'pVHXvpUvCpMKlXKFpVFGEQ',
#    'alias': 'the-luncheonette-london',
#    'name': 'The Luncheonette',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZeMPM3GsYXWIKqXafq8Qlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-luncheonette-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.504754, 'longitude': -0.089747},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '47-49 Borough High Street',
#     'address2': 'Southwark London',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1NB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47-49 Borough High Street',
#      'Southwark London',
#      'London SE1 1NB',
#      'United Kingdom']},
#    'phone': '+442074077663',
#    'display_phone': '+44 20 7407 7663',
#    'distance': 3315.751406656196},
#   {'id': 'SOKfY1_st_Uh5ObwmTCAwQ',
#    'alias': 'brown-and-green-london',
#    'name': 'Brown and Green',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hzJ-lIMAWWa-41jTKdu4fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brown-and-green-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.41818, 'longitude': -0.072619},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Crystal Palace Station',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE19 2AZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Crystal Palace Station',
#      'London SE19 2AZ',
#      'United Kingdom']},
#    'phone': '+442087616409',
#    'display_phone': '+44 20 8761 6409',
#    'distance': 11404.491610067409},
#   {'id': 'dyvWhZ5Zy_kXhWPK02-ICA',
#    'alias': 'cafe-helen-london',
#    'name': 'Cafe Helen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eL4iK07NhkCTw-g_8CfVvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-helen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516103, 'longitude': -0.164712},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '105A Edgware Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 2HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['105A Edgware Road',
#      'London W2 2HX',
#      'United Kingdom']},
#    'phone': '+442074022072',
#    'display_phone': '+44 20 7402 2072',
#    'distance': 2022.7801164213531},
#   {'id': '-ATEXu2q4Oe4wPQeyrsILw',
#    'alias': 'princi-london',
#    'name': 'Princi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QLFgoDIBiLx2F0tpUIw7gQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/princi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 304,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5138629586873,
#     'longitude': -0.134387051472991},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '135 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0UT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['135 Wardour Street',
#      'London W1F 0UT',
#      'United Kingdom']},
#    'phone': '+442074788888',
#    'display_phone': '+44 20 7478 8888',
#    'distance': 157.59755401297926},
#   {'id': 'm3vdBGC0X94sG_5pglDcjQ',
#    'alias': 'st-john-bread-and-wine-london',
#    'name': 'St. John Bread & Wine',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/pp8TqPWzX151RfxV3HbzXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-john-bread-and-wine-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 128,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5196695, 'longitude': -0.074299},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '94-96 Commercial Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6LZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['94-96 Commercial Street',
#      'London E1 6LZ',
#      'United Kingdom']},
#    'phone': '+442072510848',
#    'display_phone': '+44 20 7251 0848',
#    'distance': 4337.705786972397},
#   {'id': '12y5F7hEoYAgur9eslpqCg',
#    'alias': 'kaffeine-london-2',
#    'name': 'Kaffeine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m1YMTCBNVuvdcmVaiu8wZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaffeine-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5168726, 'longitude': -0.137167},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '15 Eastcastle Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 3AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Eastcastle Street',
#      'London W1T 3AY',
#      'United Kingdom']},
#    'phone': '+442075806755',
#    'display_phone': '+44 20 7580 6755',
#    'distance': 456.6591394087493},
#   {'id': 'PdTdmLnhSXu3zGjWXP8KVA',
#    'alias': 'amys-deli-london',
#    'name': 'Amys Deli',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/I3frtEOEc1qPWp5VfRP_tA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amys-deli-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512071, 'longitude': -0.122976},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '28 The Market',
#     'address2': 'Covent Garden',
#     'address3': 'London',
#     'city': 'London',
#     'zip_code': 'WC2E 8RA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28 The Market',
#      'Covent Garden',
#      'London',
#      'London WC2E 8RA',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 921.3389744188174},
#   {'id': 'x5xZDJ0A7aCSUypxUrEZMg',
#    'alias': 'pomme-de-pain-london',
#    'name': 'Pomme De Pain',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TYRbuEXNEudcA6AMmo3K8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pomme-de-pain-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5175624, 'longitude': -0.1310101},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '260 Tottenham Court Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 7RF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['260 Tottenham Court Road',
#      'London W1T 7RF',
#      'United Kingdom']},
#    'phone': '+442076366060',
#    'display_phone': '+44 20 7636 6060',
#    'distance': 615.1793135981187},
#   {'id': 'v3MQtzWZhRCknVhl9OoZzw',
#    'alias': 'the-balcon-london-2',
#    'name': 'The Balcon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-Hgrzf9TfWuUL-dEEw5Bdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-balcon-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.507687, 'longitude': -0.132279},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '8 Pall Mall',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 5NG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Pall Mall', 'London SW1Y 5NG', 'United Kingdom']},
#    'phone': '+442079682900',
#    'display_phone': '+44 20 7968 2900',
#    'distance': 627.834435994637}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                     Restaurant          Type Price Rating  \
# 0         Viandas de Salamanca    Meat Shops   £££    4.5
# 1  TY Seven Dials - Timberyard  Coffee & Tea    ££    4.5
# 2                 Bruno's Deli       Italian     £    4.5
# 3                     Brizzi's       Italian     £      5
# 4                Speedy's Cafe         Cafes     £      4
#
#                     Address        Lat       Lng  \
# 0                 99 Strand  51.510662 -0.120628
# 1  7 Upper St Martin's Lane  51.512858 -0.127308
# 2            59A Abbey Road  51.537140 -0.183738
# 3       131 Drummond Street  51.527082 -0.136661
# 4    187 North Gower Street  51.526165 -0.136815
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/viandas-de-salamanca-...  DpoSRkEAUGwZeVs7rq9Ajw
# 1  https://www.yelp.com/biz/ty-seven-dials-timber...  ztuEuIDjVTJMklB2OP3rpg
# 2  https://www.yelp.com/biz/brunos-deli-london?ad...  3sShVU-HYAFlmU_dND68dA
# 3  https://www.yelp.com/biz/brizzis-london?adjust...  hfmhrnn-ZxQlhI7tTMCWAg
# 4  https://www.yelp.com/biz/speedys-cafe-london-2...  QuR7O0yd-W4UOM6SeG8L9w

# %%
#4th set of 50 records 151-200
lndr_params4 = {"term":term,"location":"London","limit":50,"offset":151}
lndr_response4 = requests.get(search_api_url, headers=headers, params=lndr_params4)
lndr4 = lndr_response4.json()
display(lndr4)
#print(lndr_response4.url)
#print(lndr_response4.status_code)
# Out:
# {'businesses': [{'id': 'wqZucWHydm2qx-iUCUyJpQ',
#    'alias': 'e-pellicci-london',
#    'name': 'E Pellicci',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wtUxdaKR9UoXTT3eYcjMGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/e-pellicci-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5265159984371,
#     'longitude': -0.0635611602914123},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '332 Bethnal Green Road',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E2 0AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['332 Bethnal Green Road',
#      'London E2 0AG',
#      'United Kingdom']},
#    'phone': '+442077394873',
#    'display_phone': '+44 20 7739 4873',
#    'distance': 5234.916021601817},
#   {'id': 'ZbZ17bk6s9_ie9Oobq67CA',
#    'alias': 'bernis-sandwich-bar-london',
#    'name': "Berni's Sandwich Bar",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6tw1UAS7ZllxQQ6AXv983Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bernis-sandwich-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5297089, 'longitude': -0.102614},
#    'transactions': [],
#    'location': {'address1': '249 Goswell Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 1NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['249 Goswell Road',
#      'London EC1V 1NE',
#      'United Kingdom']},
#    'phone': '+442072785694',
#    'display_phone': '+44 20 7278 5694',
#    'distance': 2978.315659546356},
#   {'id': 'in1fuQDAfRBIb7cGnOEviA',
#    'alias': 'gails-bakery-soho-london',
#    'name': "GAIL's Bakery Soho",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/n8-P1vDMEKq2CyDsOzjfRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5143112170147,
#     'longitude': -0.134518146514893},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '128 Wardour Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8ZL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['128 Wardour Street',
#      'Soho',
#      'London W1F 8ZL',
#      'United Kingdom']},
#    'phone': '+442072871324',
#    'display_phone': '+44 20 7287 1324',
#    'distance': 191.89294382102497},
#   {'id': 'Gyxs4y3aofIAjAWGaPNmrQ',
#    'alias': 'milk-bar-london',
#    'name': 'Milk Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5onhkWkXKrnHmKGOHDxEtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/milk-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 82,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514162886575,
#     'longitude': -0.13126851745979},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3 Bateman Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 4AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Bateman Street',
#      'London W1D 4AG',
#      'United Kingdom']},
#    'phone': '+442072874796',
#    'display_phone': '+44 20 7287 4796',
#    'distance': 356.36235664390273},
#   {'id': 'y8xX3BDj1bf7-wc4Q9Atvg',
#    'alias': 'the-monocle-cafe-london',
#    'name': 'The Monocle Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WVPzYgrKif_v7M9hkSshJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-monocle-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 69,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5188109085709,
#     'longitude': -0.154666668198166},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '18 Chiltern Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 7QA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Chiltern Street',
#      'London W1U 7QA',
#      'United Kingdom']},
#    'phone': '+442071352040',
#    'display_phone': '+44 20 7135 2040',
#    'distance': 1455.2587544542089},
#   {'id': 'XLZZ1MsocZiXavD39zfHgg',
#    'alias': 'paul-london-28',
#    'name': 'Paul',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6CvfTBsiRuSIMwp-7laC1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-london-28?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.508135, 'longitude': -0.139246},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '173 Piccadilly Arcade',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 6NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['173 Piccadilly Arcade',
#      'London SW1Y 6NH',
#      'United Kingdom']},
#    'phone': '+442074998708',
#    'display_phone': '+44 20 7499 8708',
#    'distance': 570.1166518695289},
#   {'id': 'NRohWk2myGxmKpzFEjigSw',
#    'alias': 'ships-galley-london',
#    'name': 'Ships Galley',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fUnvCq7qidAUKiYSBhs9Pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ships-galley-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.519425, 'longitude': -0.14036},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '1 Hanson Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 6TA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Hanson Street',
#      'London W1W 6TA',
#      'United Kingdom']},
#    'phone': '+442074363854',
#    'display_phone': '+44 20 7436 3854',
#    'distance': 795.2178989367195},
#   {'id': 'ZXGv6n-kR2_dqo0fTmCBtA',
#    'alias': 'super-deli-sandwich-london',
#    'name': 'Super Deli Sandwich',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WWv3TpeCfJI0ROlwzyjeow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/super-deli-sandwich-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5182495, 'longitude': -0.0778599},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '17 Widegate Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 7HP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17 Widegate Street',
#      'London E1 7HP',
#      'United Kingdom']},
#    'phone': '+442073770868',
#    'display_phone': '+44 20 7377 0868',
#    'distance': 4061.1055592175303},
#   {'id': 'qGmZFoLJnDTMDQsscu9VhA',
#    'alias': 'pret-a-manger-london-204',
#    'name': 'Pret a Manger',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ez5AQqTpz-kQWyXQ3ArxTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pret-a-manger-london-204?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5006744, 'longitude': -0.1621836},
#    'transactions': [],
#    'location': {'address1': 'Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 1HY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Brompton Road', 'London SW3 1HY', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2263.5469735874626},
#   {'id': 'HXjHL0L7lqtQQ1KJ0ZKAug',
#    'alias': 'kastner-and-ovens-london',
#    'name': 'Kastner and Ovens',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/n6adQfuqx24tKJlv0wMiew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kastner-and-ovens-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5135034, 'longitude': -0.1227604},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '52 Floral Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 9DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['52 Floral Street',
#      'London WC2E 9DA',
#      'United Kingdom']},
#    'phone': '+442078362700',
#    'display_phone': '+44 20 7836 2700',
#    'distance': 918.5834049759383},
#   {'id': 'Lxhbq_b8tbCdji7N4g3hGw',
#    'alias': 'gails-bakery-notting-hill-london-3',
#    'name': "GAIL's Bakery Notting Hill",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6Ka2-zed5l1-eA8_Z0834A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-notting-hill-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.514255658517,
#     'longitude': -0.20344594848854},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '138 Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2DZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['138 Portobello Road',
#      'London W11 2DZ',
#      'United Kingdom']},
#    'phone': '+442077928715',
#    'display_phone': '+44 20 7792 8715',
#    'distance': 4672.97393974897},
#   {'id': '7XD_PwmmMgnSqAec370WpQ',
#    'alias': 'brass-rail-salt-beef-bar-london',
#    'name': 'Brass Rail Salt Beef Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bC3-35Bl47BaK04Rcdv_wA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brass-rail-salt-beef-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514518, 'longitude': -0.153764},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Selfridges London',
#     'address2': '400 Oxford Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1A 1AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Selfridges London',
#      '400 Oxford Street',
#      'London W1A 1AB',
#      'United Kingdom']},
#    'phone': '+442073183115',
#    'display_phone': '+44 20 7318 3115',
#    'distance': 1246.439874774706},
#   {'id': 'VIgAskZCKuYwtA30lWjE4A',
#    'alias': 'crussh-london-8',
#    'name': 'Crussh',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/g9pNitFQ14Qt7Gm_3WISJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crussh-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51775, 'longitude': -0.134576},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '30 Rathbone Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 1JQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Rathbone Place',
#      'London W1T 1JQ',
#      'United Kingdom']},
#    'phone': '+442076369808',
#    'display_phone': '+44 20 7636 9808',
#    'distance': 554.2443962262382},
#   {'id': 'lMxu8jhSIb_liUki8cy2Wg',
#    'alias': 'chamomile-london',
#    'name': 'Chamomile',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/L1XvSQmXkGbyxSqLdzqEWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chamomile-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5456005, 'longitude': -0.1623197},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "45 England's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 4YD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["45 England's Lane",
#      'London NW3 4YD',
#      'United Kingdom']},
#    'phone': '+442075864580',
#    'display_phone': '+44 20 7586 4580',
#    'distance': 4074.0720076605753},
#   {'id': 'YfKn2fkIyXC2jmE1qmgxQw',
#    'alias': 'outsider-tart-london',
#    'name': 'Outsider Tart',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CCbq7o_xmLzRkBXvNOh9TQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/outsider-tart-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4927, 'longitude': -0.252125},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '83 Chiswick High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W4 2EF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Chiswick High Road',
#      'London W4 2EF',
#      'United Kingdom']},
#    'phone': '+442070961609',
#    'display_phone': '+44 20 7096 1609',
#    'distance': 8339.382278059751},
#   {'id': 'Mliu9UHo1ci2kMzxqNAfKA',
#    'alias': 'mr-gingham-west-hampstead',
#    'name': 'Mr Gingham',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PgV1rEGRNKaTb3Dy2lU4-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-gingham-west-hampstead?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.546726, 'longitude': -0.190981},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '112 West End Lane',
#     'address2': 'West Hampstead',
#     'address3': '',
#     'city': 'West Hampstead',
#     'zip_code': 'NW6 2LS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['112 West End Lane',
#      'West Hampstead',
#      'West Hampstead NW6 2LS',
#      'United Kingdom']},
#    'phone': '+447939953764',
#    'display_phone': '+44 7939 953764',
#    'distance': 5353.474004206891},
#   {'id': 'No7AhdS-anCLc5u-ie1aMw',
#    'alias': 'canaletto-london',
#    'name': 'Canaletto',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-r4dLWk-ALAht0TjItJ4aA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/canaletto-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512286, 'longitude': -0.137595},
#    'transactions': [],
#    'location': {'address1': '36 Beak Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9RF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['36 Beak Street', 'London W1F 9RF', 'United Kingdom']},
#    'phone': '+442074378597',
#    'display_phone': '+44 20 7437 8597',
#    'distance': 128.696801364655},
#   {'id': 'Ucq1UTEPjOUzLr0dK1v7PA',
#    'alias': 'pret-a-manger-london-28',
#    'name': 'Pret A Manger',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/44GsQGRE-cejqxlgkWbhZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pret-a-manger-london-28?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5135516676829,
#     'longitude': -0.158816958393108},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '556 Oxford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1C 1LZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['556 Oxford Street',
#      'London W1C 1LZ',
#      'United Kingdom']},
#    'phone': '+442079325240',
#    'display_phone': '+44 20 7932 5240',
#    'distance': 1584.0023834943333},
#   {'id': 'CIZyTP2RPqFZxVQgaKG3qw',
#    'alias': 'nivens-london',
#    'name': "Niven's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7XD3dPLyerxzkhe_KgvItg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nivens-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5302925109863,
#     'longitude': -0.116402998566628},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "157 King's Cross Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1X 9DS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["157 King's Cross Road",
#      'London WC1X 9DS',
#      'United Kingdom']},
#    'phone': '+442078373717',
#    'display_phone': '+44 20 7837 3717',
#    'distance': 2366.0250944380605},
#   {'id': 'C7TB4RqD69KIj8NpclF-xA',
#    'alias': 'natural-kitchen-london-3',
#    'name': 'Natural Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/g7nqb8dURJtRbqQumpLB0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/natural-kitchen-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'delis', 'title': 'Delis'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.520971, 'longitude': -0.152275},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '77-78 Marylebone High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 5JX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['77-78 Marylebone High Street',
#      'London W1U 5JX',
#      'United Kingdom']},
#    'phone': '+442074868065',
#    'display_phone': '+44 20 7486 8065',
#    'distance': 1439.2980824498075},
#   {'id': 'g1RTEAXkhEobqDNGNcIIJA',
#    'alias': 'summer-with-monika-london',
#    'name': 'Summer With Monika',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QSjakE4jieyAJcJFjYr1tA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/summer-with-monika-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5294034274596,
#     'longitude': -0.0836718826996208},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '67-69 Pitfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 6BT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['67-69 Pitfield Street',
#      'London N1 6BT',
#      'United Kingdom']},
#    'phone': '+442072538631',
#    'display_phone': '+44 20 7253 8631',
#    'distance': 4059.5304670097607},
#   {'id': 'fM99pmX2-ipWvG33tILdZQ',
#    'alias': 'franze-and-evans-cafe-shoreditch-london-2',
#    'name': 'Franze & Evans Cafe Shoreditch',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GXigHW3dfzZ42TB_8cvOvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/franze-and-evans-cafe-shoreditch-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5248675, 'longitude': -0.0726335},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '101 Redchurch St',
#     'address2': 'Shoreditch',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['101 Redchurch St',
#      'Shoreditch',
#      'London E2 7DL',
#      'United Kingdom']},
#    'phone': '+442070331910',
#    'display_phone': '+44 20 7033 1910',
#    'distance': 4581.098657661117},
#   {'id': 'P5GwJcDkv31LJ_cqPEIO9g',
#    'alias': 'apostrophe-london-11',
#    'name': 'Apostrophe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lpfbGKdv__lfzvoyh2_s9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/apostrophe-london-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5120788122786,
#     'longitude': -0.145699437195727},
#    'transactions': [],
#    'location': {'address1': '10 Grosvenor Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 4QB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Grosvenor Street',
#      'London W1K 4QB',
#      'United Kingdom']},
#    'phone': '+442074996511',
#    'display_phone': '+44 20 7499 6511',
#    'distance': 679.5030299744695},
#   {'id': 'NPAGfkgk_yAIB2oK-vJf9g',
#    'alias': 'briki-london-2',
#    'name': 'Briki',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XGqqAb7ftRXcLil8jA8zIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/briki-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5264182332052,
#     'longitude': -0.108153232644337},
#    'transactions': [],
#    'location': {'address1': '67 Exmouth Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 4QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['67 Exmouth Market',
#      'London EC1R 4QL',
#      'United Kingdom']},
#    'phone': '+442072788745',
#    'display_phone': '+44 20 7278 8745',
#    'distance': 2445.7347758340943},
#   {'id': 'nP98JdIDr9sdzdNSnMKuug',
#    'alias': 'salumeria-dino-london',
#    'name': 'Salumeria Dino',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3c2lrRK6JlpO1U0ubh52Hw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salumeria-dino-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5190815122491,
#     'longitude': -0.136224031448364},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '15 Charlotte Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 1SP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Charlotte Place',
#      'London W1T 1SP',
#      'United Kingdom']},
#    'phone': '+442075803938',
#    'display_phone': '+44 20 7580 3938',
#    'distance': 694.7696932980305},
#   {'id': 'rK1GME2iK1i0rf3OAxhr5w',
#    'alias': 'the-bagel-house-london',
#    'name': 'The Bagel House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Xggckt6yhWnUN59svgA4HQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bagel-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.557398906635,
#     'longitude': -0.074235334232473},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '2 Stoke Newington High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 7PL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Stoke Newington High Street',
#      'London N16 7PL',
#      'United Kingdom']},
#    'phone': '+442072493908',
#    'display_phone': '+44 20 7249 3908',
#    'distance': 6540.544617888131},
#   {'id': 'NkrLJNyzMVz8u0RXPd2EKw',
#    'alias': 'eves-sandwich-bar-london',
#    'name': "Eve's Sandwich Bar",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vJuiJVoc94LzwPE4PJoeIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eves-sandwich-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.517519, 'longitude': -0.129375},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '108 Great Russell Street',
#     'address2': 'Bloomsbury',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC1B 3NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['108 Great Russell Street',
#      'Bloomsbury',
#      'London WC1B 3NA',
#      'United Kingdom']},
#    'phone': '+442076369949',
#    'display_phone': '+44 20 7636 9949',
#    'distance': 691.7920610378039},
#   {'id': 'Q3g_9e7qZEkQBfkoVWJHmw',
#    'alias': 'centro-cafe-london',
#    'name': 'Centro Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hD_gGZIoegneOgm5bQDrpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/centro-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.537766, 'longitude': -0.136786},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '19 Mandela Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 0DU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Mandela Street',
#      'London NW1 0DU',
#      'United Kingdom']},
#    'phone': '+442073830309',
#    'display_phone': '+44 20 7383 0309',
#    'distance': 2764.482820465879},
#   {'id': 'EKM6VmUANUVy5wqXT7gEXQ',
#    'alias': 'bon-gusto-london',
#    'name': 'Bon Gusto',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9vVpPXCeNEEK2r6ri3rfBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bon-gusto-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 88,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4992042, 'longitude': -0.1378462},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '75-77 Buckingham Gate',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1E 6PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['75-77 Buckingham Gate',
#      'London SW1E 6PD',
#      'United Kingdom']},
#    'phone': '+442072227185',
#    'display_phone': '+44 20 7222 7185',
#    'distance': 1521.3684126347684},
#   {'id': '5tCTNDZORPcvD9Ws3IIN5g',
#    'alias': 'waterloo-sandwich-bar-london',
#    'name': 'Waterloo Sandwich Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kOywKgpNlCxufy-IGQ8Xgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/waterloo-sandwich-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.503036, 'longitude': -0.108031},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '82 The Cut',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8LW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['82 The Cut', 'London SE1 8LW', 'United Kingdom']},
#    'phone': '+442079221379',
#    'display_phone': '+44 20 7922 1379',
#    'distance': 2221.7849393539054},
#   {'id': '7IggM6WejoIBLSHXSuWThg',
#    'alias': 'salt-and-pepper-london',
#    'name': 'Salt & Pepper',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/u1Qgd6NgsHmChm2sv6bL4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salt-and-pepper-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5171608653659,
#     'longitude': -0.127189595817122},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '5 Bloomsbury Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC1B 3QE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Bloomsbury Street',
#      'London WC1B 3QE',
#      'United Kingdom']},
#    'phone': '+44442075808448',
#    'display_phone': '+44 442075808448',
#    'distance': 774.1339594859332},
#   {'id': 'bgNNAcV-GYqPXkYcHmZNCg',
#    'alias': 'curious-yellow-kafé-london-2',
#    'name': 'Curious Yellow Kafé',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6vJbw-iS0rh8p0zpzAyZvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/curious-yellow-kaf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'scandinavian', 'title': 'Scandinavian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.52954503532,
#     'longitude': -0.0838136672973633},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '77 Pitfield Street',
#     'address2': 'Hoxton',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 6BT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['77 Pitfield Street',
#      'Hoxton',
#      'London N1 6BT',
#      'United Kingdom']},
#    'phone': '+442072516018',
#    'display_phone': '+44 20 7251 6018',
#    'distance': 4057.971810265291},
#   {'id': 'TL-8ktKuMaE-fTxv7DjbSg',
#    'alias': 'north-street-deli-london',
#    'name': 'North Street Deli',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/StjsEcc7cl0QuHIBLnuHHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/north-street-deli-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'food', 'title': 'Food'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.466699, 'longitude': -0.142461},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '26 North Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW4 0HB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 North Street',
#      'London SW4 0HB',
#      'United Kingdom']},
#    'phone': '+442079781555',
#    'display_phone': '+44 20 7978 1555',
#    'distance': 5154.883944066384},
#   {'id': 'CUGRnBQ6U7JXz0Iri2Ue7A',
#    'alias': 'cafe-nouvelle-london',
#    'name': 'Cafe Nouvelle',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WdtULeolH1aa5uX5UK8T0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-nouvelle-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.49767, 'longitude': -0.19585},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '69 Abingdon Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 6AW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['69 Abingdon Road',
#      'London W8 6AW',
#      'United Kingdom']},
#    'phone': '+442079382523',
#    'display_phone': '+44 20 7938 2523',
#    'distance': 4476.256257065634},
#   {'id': 'S3h8uhI3wK2Fn4e9gw9bfA',
#    'alias': 'shoreditch-grind-london',
#    'name': 'Shoreditch Grind',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wcWCxMuAey7jvjK6_m5TIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shoreditch-grind-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 116,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5258391235513,
#     'longitude': -0.0879659656067133},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '213 Old Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 9NR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['213 Old Street',
#      'London EC1V 9NR',
#      'United Kingdom']},
#    'phone': '+442074907490',
#    'display_phone': '+44 20 7490 7490',
#    'distance': 3621.631922482148},
#   {'id': '6Hc37w-thLXw4_pD3mZdJA',
#    'alias': 'fabrique-bakery-london',
#    'name': 'Fabrique Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6mXU2_cjtNe66mpd_w8AdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fabrique-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5321125496558,
#     'longitude': -0.0760506578224951},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Arch 385',
#     'address2': 'Gaffrye Street',
#     'address3': 'Shoreditch',
#     'city': 'London',
#     'zip_code': 'E2 8HZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Arch 385',
#      'Gaffrye Street',
#      'Shoreditch',
#      'London E2 8HZ',
#      'United Kingdom']},
#    'phone': '+442070330268',
#    'display_phone': '+44 20 7033 0268',
#    'distance': 4666.093756363539},
#   {'id': 'ZerBIV_7L4ewNvIbhpPd4g',
#    'alias': 'shrigleys-moroccan-café-london',
#    'name': 'Shrigleys Moroccan Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/L1muL0isIdT18QCW6IwyLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shrigleys-moroccan-caf%C3%A9-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'moroccan', 'title': 'Moroccan'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5036655, 'longitude': -0.0911155},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '125 Borough High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1NP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['125 Borough High Street',
#      'London SE1 1NP',
#      'United Kingdom']},
#    'phone': '+442073780057',
#    'display_phone': '+44 20 7378 0057',
#    'distance': 3260.1434699885313},
#   {'id': 'tZlkrCUgetak8511rdlIQg',
#    'alias': 'upper-crust-london-19',
#    'name': 'Upper Crust',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/11NLpNzZjrcaJ4hBYE9vSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/upper-crust-london-19?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5147, 'longitude': -0.175508},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Span 3 Paddington Station',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 4PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Span 3 Paddington Station',
#      'London W2 4PX',
#      'United Kingdom']},
#    'phone': '+442077069435',
#    'display_phone': '+44 20 7706 9435',
#    'distance': 2744.8316762540526},
#   {'id': '7sKAUqEagSjsNjHVyMHq-Q',
#    'alias': 'the-london-particular-london-3',
#    'name': 'The London Particular',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XXSiR_OXzNtqxrWyohd4Bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-london-particular-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4759049028314,
#     'longitude': -0.033576499062248},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '399 New Cross Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE14 6LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['399 New Cross Road',
#      'London SE14 6LA',
#      'United Kingdom']},
#    'phone': '+442086926149',
#    'display_phone': '+44 20 8692 6149',
#    'distance': 8191.30650062815},
#   {'id': 'FXSGVcfBDYytOHHyLsoCCg',
#    'alias': 'albertini-restaurant-london',
#    'name': 'Albertini Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ifwjbx18T7ZmecmJN2rLIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/albertini-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 52,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5290298461914,
#     'longitude': -0.129214003682137},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '16-20 Chalton Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 1JH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16-20 Chalton Street',
#      'London NW1 1JH',
#      'United Kingdom']},
#    'phone': '+442073874723',
#    'display_phone': '+44 20 7387 4723',
#    'distance': 1844.1187278999082},
#   {'id': 'mXFFXB4QgzxNF07LxYcJcw',
#    'alias': 'benugo-london-3',
#    'name': 'Benugo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kERrxImX1Qk2VlE4R6CqIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/benugo-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5318677114238,
#     'longitude': -0.126514434814453},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 32-33 St Pancras Station',
#     'address2': 'Euston Road',
#     'address3': 'Kings Cross',
#     'city': 'London',
#     'zip_code': 'NW1 9QP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 32-33 St Pancras Station',
#      'Euston Road',
#      'Kings Cross',
#      'London NW1 9QP',
#      'United Kingdom']},
#    'phone': '+442078330201',
#    'display_phone': '+44 20 7833 0201',
#    'distance': 2214.798822645712},
#   {'id': 'xYYh1dd95idvwCoGZWq58g',
#    'alias': 'bao-soho-london',
#    'name': 'BAO - Soho',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hiS0Ns69m1UsSgMPWaCaHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bao-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 184,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5132221949841,
#     'longitude': -0.136528484994449},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '53 Lexington Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9AS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['53 Lexington Street',
#      'London W1F 9AS',
#      'United Kingdom']},
#    'phone': '+442030192200',
#    'display_phone': '+44 20 3019 2200',
#    'distance': 58.47355609756945},
#   {'id': 'mvds37L7mCurGn3rGPM8ag',
#    'alias': 'kaffeine-london',
#    'name': 'Kaffeine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QWk5UJ1ELO0n7VrE3aLUWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaffeine-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 173,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51848, 'longitude': -0.14037},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '66 Great Titchfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 7QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Great Titchfield Street',
#      'London W1W 7QJ',
#      'United Kingdom']},
#    'phone': '+442075806755',
#    'display_phone': '+44 20 7580 6755',
#    'distance': 697.5687539772275},
#   {'id': 'khnhd6DnBb-zIfZEC1y9zg',
#    'alias': 'the-waiting-room-london-2',
#    'name': 'The Waiting Room',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/29nNTUak9XjUXqkiRvn-Kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-waiting-room-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4792366027832,
#     'longitude': -0.0259060002863407},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '142 Deptford High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE8 3PQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['142 Deptford High Street',
#      'London SE8 3PQ',
#      'United Kingdom']},
#    'phone': '+44442078120105',
#    'display_phone': '+44 442078120105',
#    'distance': 8487.784849357136},
#   {'id': 'cy28kr98GOWJzUqf7Dg_dg',
#    'alias': 'absolutely-starving-london',
#    'name': 'Absolutely Starving',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kwgsDjzjZ9sNiJ7gkPIw7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/absolutely-starving-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5050986007288,
#     'longitude': -0.0849500457449048},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '51 Tooley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 2QN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Tooley Street',
#      'London SE1 2QN',
#      'United Kingdom']},
#    'phone': '+442074077417',
#    'display_phone': '+44 20 7407 7417',
#    'distance': 3633.267376510319},
#   {'id': 'Ck5cgnj3SlLgieo5hMvHQg',
#    'alias': 'giraffe-london-13',
#    'name': 'Giraffe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hl9fHlqnaKbU4Ijp9hLQAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giraffe-london-13?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 62,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tex-mex', 'title': 'Tex-Mex'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.493899, 'longitude': -0.1423036},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '120 Wilton Rd',
#     'address2': '',
#     'address3': 'Victoria',
#     'city': 'London',
#     'zip_code': 'SW1V 1JZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['120 Wilton Rd',
#      'Victoria',
#      'London SW1V 1JZ',
#      'United Kingdom']},
#    'phone': '+442072338303',
#    'display_phone': '+44 20 7233 8303',
#    'distance': 2150.9932845349713},
#   {'id': 'lYNsoSKIs1E9ZVlAyYry1Q',
#    'alias': 'valentinos-london-3',
#    'name': 'Valentinos',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0Q3g-zScL72lVEI-gnFLqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/valentinos-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.51745, 'longitude': -0.119152},
#    'transactions': [],
#    'location': {'address1': '10 Little Turnstile',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1V 7DX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Little Turnstile',
#      'London WC1V 7DX',
#      'United Kingdom']},
#    'phone': '+442072422332',
#    'display_phone': '+44 20 7242 2332',
#    'distance': 1280.6975626871422},
#   {'id': 'Wjgxl0lSp_FRtzecbJ4FZQ',
#    'alias': 'the-queens-arms-london',
#    'name': 'The Queens Arms',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-QF0e-bRLjskiUjWPD7Ihg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-queens-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 120,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4925789, 'longitude': -0.1392194},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Warwick Way',
#     'address2': 'Pimlico',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1QT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Warwick Way',
#      'Pimlico',
#      'London SW1V 1QT',
#      'United Kingdom']},
#    'phone': '+442078343313',
#    'display_phone': '+44 20 7834 3313',
#    'distance': 2259.97766392161},
#   {'id': 'MGmB7GtV9lLUnusONnv3_w',
#    'alias': 'silvas-grill-and-snack-bar-london',
#    'name': "Silva's Grill & Snack Bar",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/m3InlnM4TFsrAO80Ou-VBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/silvas-grill-and-snack-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.516472, 'longitude': -0.126038},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '220 Shaftesbury Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 8EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['220 Shaftesbury Avenue',
#      'London WC2H 8EB',
#      'United Kingdom']},
#    'phone': '+442072400028',
#    'display_phone': '+44 20 7240 0028',
#    'distance': 794.6066134181943},
#   {'id': 'O3WaROs_7OFbYv4B-7m02Q',
#    'alias': 'polo-24-hour-bar-london-2',
#    'name': 'Polo 24 Hour Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4GzyD8FBMGDA8CHyN_fX-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/polo-24-hour-bar-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 100,
#    'categories': [{'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.517821, 'longitude': -0.080269},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '176 Bishopsgate',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2M 4NQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['176 Bishopsgate',
#      'London EC2M 4NQ',
#      'United Kingdom']},
#    'phone': '+442072834889',
#    'display_phone': '+44 20 7283 4889',
#    'distance': 3893.038073822518}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#              Restaurant        Type Price Rating                 Address  \
# 0            E Pellicci     Italian     £    4.5  332 Bethnal Green Road
# 1  Berni's Sandwich Bar  Sandwiches                     249 Goswell Road
# 2    GAIL's Bakery Soho    Bakeries    ££      4      128 Wardour Street
# 3              Milk Bar       Cafes    ££      4        3 Bateman Street
# 4      The Monocle Cafe       Cafes     £      4      18 Chiltern Street
#
#          Lat       Lng                                                url  \
# 0  51.526516 -0.063561  https://www.yelp.com/biz/e-pellicci-london?adj...
# 1  51.529709 -0.102614
# 2  51.514311 -0.134518  https://www.yelp.com/biz/gails-bakery-soho-lon...
# 3  51.514163 -0.131269  https://www.yelp.com/biz/milk-bar-london?adjus...
# 4  51.518811 -0.154667  https://www.yelp.com/biz/the-monocle-cafe-lond...
#
#                        ID
# 0  wqZucWHydm2qx-iUCUyJpQ
# 1
# 2  in1fuQDAfRBIb7cGnOEviA
# 3  Gyxs4y3aofIAjAWGaPNmrQ
# 4  y8xX3BDj1bf7-wc4Q9Atvg

# %%
london_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
london_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_restaurants_df = london_restaurants_df[column_order]
london_restaurants_df = london_restaurants_df.sort_values(["Type"], ascending=True)
london_restaurants_df = london_restaurants_df.reset_index(drop=True)
london_restaurants_df
# Out:
#                       Restaurant                    Type Rating Price  \
# 0                  The Bike Shed             Accessories    4.5    ££
# 1               Burger & Lobster  American (Traditional)    4.5    ££
# 2                The Bagel House                  Bagels      4     £
# 3                Fabrique Bakery                Bakeries    4.5    ££
# 4                  GAIL's Bakery                Bakeries
# 5        GAIL's Bakery Hampstead                Bakeries    4.5    ££
# 6                           Paul                Bakeries      4     £
# 7         PAUL - Gloucester Road                Bakeries    4.5     £
# 8                           Paul                Bakeries      4    ££
# 9             Upper Fleet Bakery                Bakeries
# 10         St. John Bread & Wine                Bakeries    4.5    ££
# 11    GAIL's Bakery Notting Hill                Bakeries    3.5    ££
# 12             Maroush Bakehouse                Bakeries    4.5    ££
# 13             Kastner and Ovens                Bakeries    4.5     £
# 14       GAIL's Bakery - Pimlico                Bakeries
# 15                      Laurents                Bakeries    4.5     £
# 16                 Raab's Bakery                Bakeries      5     £
# 17            GAIL's Bakery Soho                Bakeries      4    ££
# 18                 Camden Bakery                Bakeries    4.5     £
# 19   GAIL's Bakery Seymour Place                Bakeries    4.5    ££
# 20                   Beigel Bake                Bakeries      4     £
# 21                 Nordic Bakery                Bakeries    3.5    ££
# 22            Wings Sandwich Bar      Breakfast & Brunch
# 23                  Yolk Breaker      Breakfast & Brunch
# 24                          EAT.      Breakfast & Brunch      4     £
# 25           Flour To The People      Breakfast & Brunch    4.5    ££
# 26                     The Table                 British      4    ££
# 27                  Granger & Co                 British      4    ££
# 28               The Queens Arms                 British    4.5    ££
# 29         Garden Breakfast Cafe                 British    4.5    ££
# ..                           ...                     ...    ...   ...
# 170                     Sub Cult              Sandwiches
# 171              Hank's Po' Boys              Sandwiches
# 172                     Sub Cult              Sandwiches      4     £
# 173                 Pickle & Rye              Sandwiches      5     £
# 174          Max's Sandwich Shop              Sandwiches    4.5     £
# 175            The Sandwich Shop              Sandwiches
# 176      Shrigleys Moroccan Café              Sandwiches      5     £
# 177                     Deeney's              Sandwiches
# 178                Sandwich Shop              Sandwiches    4.5     £
# 179                  Centro Cafe              Sandwiches    4.5     £
# 180                Pomme De Pain              Sandwiches    4.5     £
# 181                    Amys Deli              Sandwiches      4     £
# 182     Brass Rail Salt Beef Bar              Sandwiches      4    ££
# 183                       Crussh              Sandwiches    4.5    ££
# 184                        Kiosk              Sandwiches    4.5     £
# 185         Berni's Sandwich Bar              Sandwiches
# 186                      Pickles              Sandwiches    3.5     £
# 187                Wraps 'N More              Sandwiches
# 188                       Earl's              Sandwiches      4     £
# 189        Lincoln Sandwich Shop              Sandwiches
# 190                   Which Wich              Sandwiches      4     £
# 191                      Niven's              Sandwiches      5    ££
# 192           Smack Lobster Roll                 Seafood      4    ££
# 193                Enrique Tomas                 Spanish      4    ££
# 194            Paul Rothe & Sons          Specialty Food    4.5     £
# 195            Whitecross Market          Street Vendors    4.5     £
# 196             Project Sandwich          Street Vendors
# 197              Grill My Cheese          Street Vendors      4     £
# 198                   BAO - Soho               Taiwanese      4    ££
# 199                         Kêu!              Vietnamese      4     £
#
#                             Address        Lat       Lng  \
# 0                    384 Old Street  51.527090 -0.078215
# 1        Fifth Floor Harvey Nichols  51.501441 -0.159432
# 2     2 Stoke Newington High Street  51.557399 -0.074235
# 3                          Arch 385  51.532113 -0.076051
# 4    240-242 Kensington High Street  51.498910 -0.200170
# 5          64 Hampstead High Street  51.556122 -0.177963
# 6                 122 Brompton Road  51.499068 -0.165140
# 7                73 Gloucester Road  51.494974 -0.182581
# 8             173 Piccadilly Arcade  51.508135 -0.139246
# 9         7 - 11 Upper Woburn place  51.526332 -0.129385
# 10          94-96 Commercial Street  51.519669 -0.074299
# 11              138 Portobello Road  51.514256 -0.203446
# 12             131 Earls Court Road  51.493320 -0.194478
# 13                 52 Floral Street  51.513503 -0.122760
# 14                26 Churton Street  51.491763 -0.139059
# 15                   39 Craven Road  51.513468 -0.179164
# 16                   136 Essex Road  51.539319 -0.097745
# 17               128 Wardour Street  51.514311 -0.134518
# 18            94 Camden High Street  51.537083 -0.140764
# 19                4-6 Seymour Place  51.514595 -0.160964
# 20                   159 Brick Lane  51.524391 -0.071726
# 21                 14 Golden Square  51.511430 -0.136741
# 22                    39 Drury Lane  51.501263 -0.117073
# 23          Unit 701 Stables Market  51.542000 -0.147372
# 24                 36-38 Piccadilly  51.509172 -0.137480
# 25          573 Battersea Park Road  51.471184 -0.168629
# 26              83 Southwark Street  51.505604 -0.099671
# 27             175 Westbourne Grove  51.514646 -0.197799
# 28                   11 Warwick Way  51.492579 -0.139219
# 29              3 Goldhurst Terrace  51.545784 -0.179409
# ..                              ...        ...       ...
# 170           2-10 Bethnal Green Rd  51.523508 -0.076447
# 171         Southbank Centre Market  51.505322 -0.116054
# 172               Berwick St Market  51.514161 -0.135677
# 173                   31 Sheen Lane  51.468303 -0.266688
# 174                  19 Crouch Hill  51.570609 -0.116188
# 175                 19 Dacre Street  51.499007 -0.132450
# 176         125 Borough High Street  51.503665 -0.091116
# 177              22 Broadway Market  51.536064 -0.061843
# 178              54 Gloucester Road  51.498021 -0.183931
# 179               19 Mandela Street  51.537766 -0.136786
# 180        260 Tottenham Court Road  51.517562 -0.131010
# 181                   28 The Market  51.512071 -0.122976
# 182               Selfridges London  51.514518 -0.153764
# 183               30 Rathbone Place  51.517750 -0.134576
# 184            King's Cross Station  51.531210 -0.124820
# 185                249 Goswell Road  51.529709 -0.102614
# 186              6 Old Queen Street  51.501011 -0.130923
# 187          8 Great Russell Street  51.517215 -0.129784
# 188                14 Endell Street  51.514513 -0.124282
# 189                   2 Gate Street  51.517258 -0.118987
# 190                          Unit 8  51.516009 -0.128487
# 191           157 King's Cross Road  51.530293 -0.116403
# 192                  58 Dean Street  51.512636 -0.132043
# 193              132 Wardour Street  51.514449 -0.134711
# 194              35 Marylebone Lane  51.516839 -0.150843
# 195             1 Whitecross Street  51.522829 -0.092765
# 196                 Kings Boulevard  51.533490 -0.124600
# 197             Leather Lane Market  51.519990 -0.109368
# 198             53 Lexington Street  51.513222 -0.136528
# 199                  332 Old Street  51.526608 -0.081624
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/the-bike-shed-london?...  BNdzjiLoibX1uSH4kAQy5w
# 1    https://www.yelp.com/biz/burger-and-lobster-lo...  ITcGz_zdMW3EyqNBJx6Fxw
# 2    https://www.yelp.com/biz/the-bagel-house-londo...  rK1GME2iK1i0rf3OAxhr5w
# 3    https://www.yelp.com/biz/fabrique-bakery-londo...  6Hc37w-thLXw4_pD3mZdJA
# 4
# 5    https://www.yelp.com/biz/gails-bakery-hampstea...  1OcBgrUzPgp82BfZBUKRow
# 6    https://www.yelp.com/biz/paul-london-3?adjust_...  DUS7Nz3429d2iv0q-Jky9A
# 7    https://www.yelp.com/biz/paul-gloucester-road-...  f4bEfbf1_VyZpLsvlonhMw
# 8    https://www.yelp.com/biz/paul-london-28?adjust...  XLZZ1MsocZiXavD39zfHgg
# 9
# 10   https://www.yelp.com/biz/st-john-bread-and-win...  m3vdBGC0X94sG_5pglDcjQ
# 11   https://www.yelp.com/biz/gails-bakery-notting-...  Lxhbq_b8tbCdji7N4g3hGw
# 12   https://www.yelp.com/biz/maroush-bakehouse-lon...  Da8ClETsPknyD-XIam-jbg
# 13   https://www.yelp.com/biz/kastner-and-ovens-lon...  HXjHL0L7lqtQQ1KJ0ZKAug
# 14
# 15   https://www.yelp.com/biz/laurents-london?adjus...  HAi7bThXmEtooc5ZQq9hdw
# 16   https://www.yelp.com/biz/raabs-bakery-london?a...  DARE_WvgMZINvslycDPJFQ
# 17   https://www.yelp.com/biz/gails-bakery-soho-lon...  in1fuQDAfRBIb7cGnOEviA
# 18   https://www.yelp.com/biz/camden-bakery-london?...  pa2j9BlCHH8mRIk-TtD6UQ
# 19   https://www.yelp.com/biz/gails-bakery-seymour-...  LgKc7xGArsmxAw6xUQ2mYA
# 20   https://www.yelp.com/biz/beigel-bake-london?ad...  CrQcYS4nWWdXmSD1pxf_KA
# 21   https://www.yelp.com/biz/nordic-bakery-london?...  Sh_PrXavTAk2d5jTs_onuQ
# 22
# 23
# 24   https://www.yelp.com/biz/eat-london-30?adjust_...  Tk83SHGjBMQ6ntQqTC2Hpw
# 25   https://www.yelp.com/biz/flour-to-the-people-l...  xFjP08phJ-IeeP4EGgt67g
# 26   https://www.yelp.com/biz/the-table-london-8?ad...  rKwkCvsSfp8z7w1CmNnMMQ
# 27   https://www.yelp.com/biz/granger-and-co-london...  0r2-fwgLvuOLef0epiFkFQ
# 28   https://www.yelp.com/biz/the-queens-arms-londo...  Wjgxl0lSp_FRtzecbJ4FZQ
# 29   https://www.yelp.com/biz/garden-breakfast-cafe...  mWIaThf7jXEFk-IzPfxRrQ
# ..                                                 ...                     ...
# 170
# 171
# 172  https://www.yelp.com/biz/sub-cult-london-3?adj...  9huadp8OwppgqBtzL5brCA
# 173  https://www.yelp.com/biz/pickle-and-rye-london...  6xXfpMnpujSY_XuxeVvESQ
# 174  https://www.yelp.com/biz/maxs-sandwich-shop-lo...  0sjH44nfLe0nr1uBZPNWAQ
# 175
# 176  https://www.yelp.com/biz/shrigleys-moroccan-ca...  ZerBIV_7L4ewNvIbhpPd4g
# 177
# 178  https://www.yelp.com/biz/sandwich-shop-london?...  c897jdNz40fc0AzNhmf4xg
# 179  https://www.yelp.com/biz/centro-cafe-london?ad...  Q3g_9e7qZEkQBfkoVWJHmw
# 180  https://www.yelp.com/biz/pomme-de-pain-london?...  x5xZDJ0A7aCSUypxUrEZMg
# 181  https://www.yelp.com/biz/amys-deli-london?adju...  PdTdmLnhSXu3zGjWXP8KVA
# 182  https://www.yelp.com/biz/brass-rail-salt-beef-...  7XD_PwmmMgnSqAec370WpQ
# 183  https://www.yelp.com/biz/crussh-london-8?adjus...  VIgAskZCKuYwtA30lWjE4A
# 184  https://www.yelp.com/biz/kiosk-london-4?adjust...  4q6X9JarhmK_8EH8PjFBIw
# 185
# 186  https://www.yelp.com/biz/pickles-london-2?adju...  HaUEkzqd8ahjouFlhvq1tQ
# 187
# 188  https://www.yelp.com/biz/earls-london?adjust_c...  hWJqgTY0AucCidghJ3Wztg
# 189
# 190  https://www.yelp.com/biz/which-wich-london-3?a...  Ug8nEBDfZyf7JoQ5KoE8Aw
# 191  https://www.yelp.com/biz/nivens-london?adjust_...  CIZyTP2RPqFZxVQgaKG3qw
# 192  https://www.yelp.com/biz/smack-lobster-roll-lo...  k9sDFW6lHgdFAmQJ-tLMqw
# 193  https://www.yelp.com/biz/enrique-tomas-london?...  dGkVk041v8tevLofLY8GTg
# 194  https://www.yelp.com/biz/paul-rothe-and-sons-l...  EEquXLKz0cz4wTFTRcKgmQ
# 195  https://www.yelp.com/biz/whitecross-market-lon...  PrIqHQtsQl-DnafTdS326A
# 196
# 197  https://www.yelp.com/biz/grill-my-cheese-londo...  T5ifm1dzc33tvnDyY-l3Ig
# 198  https://www.yelp.com/biz/bao-soho-london?adjus...  xYYh1dd95idvwCoGZWq58g
# 199  https://www.yelp.com/biz/k%C3%AAu-london-2?adj...  5kF-JWfal4TAM1wJLxM14g
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
london_restaurants_df.to_csv('Resources/London_Restaurants_Sandwich.csv')
