# %% [markdown]
# LONDON RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
term = "pudding"

# %%
#First set of 50 records 0-50
lndr_params1 = {"term":term,"location":"London","limit":50,"offset":0}
lndr_response1 = requests.get(search_api_url, headers=headers, params=lndr_params1)
lndr1 = lndr_response1.json()
display(lndr1)
#print(lndr_response1.url)
#print(lndr_response1.status_code)
# Out:
# {'businesses': [{'id': '70Q-Ll18zb4aglXXbUG7lw',
#    'alias': 'ffionas-restaurant-london',
#    'name': "Ffiona's Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/seykrl3tugRsE8UL6-phKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ffionas-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 265,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.50405773515,
#     'longitude': -0.192783395566043},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '51 Kensington Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Kensington Church Street',
#      'London W8 4BA',
#      'United Kingdom']},
#    'phone': '+442079374152',
#    'display_phone': '+44 20 7937 4152',
#    'distance': 4052.2035032181666},
#   {'id': 'Wjgxl0lSp_FRtzecbJ4FZQ',
#    'alias': 'the-queens-arms-london',
#    'name': 'The Queens Arms',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-QF0e-bRLjskiUjWPD7Ihg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-queens-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 120,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4925789, 'longitude': -0.1392194},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Warwick Way',
#     'address2': 'Pimlico',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1QT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Warwick Way',
#      'Pimlico',
#      'London SW1V 1QT',
#      'United Kingdom']},
#    'phone': '+442078343313',
#    'display_phone': '+44 20 7834 3313',
#    'distance': 2259.97766392161},
#   {'id': 'YNduANMPzIVE8CzBH7YjEQ',
#    'alias': 'regency-café-london-2',
#    'name': 'Regency Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pz5q5e8LBG7C1ozSuhvuKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/regency-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 393,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4940143171, 'longitude': -0.13222007974201},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '17-19 Regency Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 4BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17-19 Regency Street',
#      'London SW1P 4BY',
#      'United Kingdom']},
#    'phone': '+442078216596',
#    'display_phone': '+44 20 7821 6596',
#    'distance': 2108.732795587357},
#   {'id': 'IBV7BsXnv2gX68nWUARhjw',
#    'alias': 'mother-mash-london',
#    'name': 'Mother Mash',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YRdJ5N93Jc3qOIxx_itIRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mother-mash-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 469,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512935, 'longitude': -0.139414},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '26 Ganton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7QZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Ganton Street',
#      'London W1F 7QZ',
#      'United Kingdom']},
#    'phone': '+442074949644',
#    'display_phone': '+44 20 7494 9644',
#    'distance': 235.11523624102102},
#   {'id': 'e5jPAqpCcIAsTtasUN5h2g',
#    'alias': 'the-wolseley-london',
#    'name': 'The Wolseley',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T9xpXsz-az88-l0Ko_KLpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wolseley-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 553,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.507617, 'longitude': -0.141012},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '160 Picadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 9EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['160 Picadilly', 'London W1J 9EB', 'United Kingdom']},
#    'phone': '+442074996996',
#    'display_phone': '+44 20 7499 6996',
#    'distance': 677.6098617325135},
#   {'id': 'E_x4vtkQek-dJ7j19ON7ZA',
#    'alias': 'basement-sate-london',
#    'name': 'Basement Sate',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U06Bqm38eX6hRe3s2Hl4mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/basement-sate-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514068, 'longitude': -0.134914},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8 Broadwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8HN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Broadwick Street',
#      'London W1F 8HN',
#      'United Kingdom']},
#    'phone': '+442072873412',
#    'display_phone': '+44 20 7287 3412',
#    'distance': 156.93823636393194},
#   {'id': '-Ve2_hHfPczRX159xt0BCg',
#    'alias': 'ye-olde-cheshire-cheese-london',
#    'name': 'Ye Olde Cheshire Cheese',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4B0TZgcIebNCJgwtZcc3gQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ye-olde-cheshire-cheese-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 354,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5143449, 'longitude': -0.107315},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '145 Fleet Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4A 2BU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['145 Fleet Street',
#      'London EC4A 2BU',
#      'United Kingdom']},
#    'phone': '+442073536170',
#    'display_phone': '+44 20 7353 6170',
#    'distance': 1999.1587381312402},
#   {'id': 'ZKfiQaOMDu7rfVhmMmQ0bQ',
#    'alias': 'berners-tavern-london-5',
#    'name': 'Berners Tavern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tnfzvqS02pyFcaF6b2f8xw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/berners-tavern-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 121,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5167515074354,
#     'longitude': -0.135977268218994},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '10 Berners Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 3NP',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ['10 Berners Street',
#      'London W1T 3NP',
#      'United Kingdom']},
#    'phone': '+442077810000',
#    'display_phone': '+44 20 7781 0000',
#    'distance': 435.43985267437006},
#   {'id': '0tJs57Xoq75-RDWKVco0nw',
#    'alias': 'bageriet-london',
#    'name': 'Bageriet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2yfTj7nJkUd_snGs1WP2aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bageriet-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'scandinavian', 'title': 'Scandinavian'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5119236, 'longitude': -0.1261821},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '24 Rose Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 9EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Rose Street',
#      'London WC2E 9EA',
#      'United Kingdom']},
#    'phone': '+442072400000',
#    'display_phone': '+44 20 7240 0000',
#    'distance': 683.9151857905819},
#   {'id': 'MaNE6xr9_bqpIWCLm5VhkA',
#    'alias': 'goddards-at-greenwich-london',
#    'name': 'Goddards at Greenwich',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hGrxtzUFxlDAbt8TyhlZ5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/goddards-at-greenwich-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4812088, 'longitude': -0.0083317},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '22 King William Walk',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE10 9HU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 King William Walk',
#      'London SE10 9HU',
#      'United Kingdom']},
#    'phone': '+442083059612',
#    'display_phone': '+44 20 8305 9612',
#    'distance': 9498.252492833206},
#   {'id': 'iYz6RM1H-W_YB13Z5WA-Hg',
#    'alias': 'cakes-and-bubbles-london',
#    'name': 'Cakes And Bubbles',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/h36Jj6pYTTAnJNLhjjzxBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cakes-and-bubbles-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51009, 'longitude': -0.136},
#    'transactions': [],
#    'location': {'address1': '68 Regent St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1B 5RH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['68 Regent St', 'London W1B 5RH', 'United Kingdom']},
#    'phone': '+442074063333',
#    'display_phone': '+44 20 7406 3333',
#    'distance': 315.40974404815825},
#   {'id': 'b8u_D0Qlp0-nqSC6O2fMNw',
#    'alias': 'restaurant-gordon-ramsay-london-3',
#    'name': 'Restaurant Gordon Ramsay',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OPwMc_lYwLE37jDUsX_dSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/restaurant-gordon-ramsay-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 208,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.485833, 'longitude': -0.161966},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '68 Royal Hospital Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 4HP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['68 Royal Hospital Road',
#      'London SW3 4HP',
#      'United Kingdom']},
#    'phone': '+442073524441',
#    'display_phone': '+44 20 7352 4441',
#    'distance': 3500.98686782132},
#   {'id': 'Da8ClETsPknyD-XIam-jbg',
#    'alias': 'maroush-bakehouse-london-6',
#    'name': 'Maroush Bakehouse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hYjyJ-w7yL5JNQ_7sUFl9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maroush-bakehouse-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'lebanese', 'title': 'Lebanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.49332, 'longitude': -0.194478},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '131 Earls Court Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 9RH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['131 Earls Court Road',
#      'London SW5 9RH',
#      'United Kingdom']},
#    'phone': '+442073704324',
#    'display_phone': '+44 20 7370 4324',
#    'distance': 4595.303422118365},
#   {'id': 'teXPunKtpwj0NuttvPYhyQ',
#    'alias': 'the-victoria-paddington',
#    'name': 'The Victoria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IscE584D-z4Snf71FJ1bcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-victoria-paddington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 218,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51350403679, 'longitude': -0.17119959969309},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10a Strathearn Place',
#     'address2': '',
#     'address3': '',
#     'city': 'Paddington',
#     'zip_code': 'W2 2NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10a Strathearn Place',
#      'Paddington W2 2NH',
#      'United Kingdom']},
#    'phone': '+442077241191',
#    'display_phone': '+44 20 7724 1191',
#    'distance': 2440.016451414865},
#   {'id': 'wdPCcml663tzNsnBWArE0g',
#    'alias': 'the-st-ermins-tea-lounge-westminster',
#    'name': "The St. Ermin's Tea Lounge",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/--zcMqj2NmkMePwZ1fHIvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-st-ermins-tea-lounge-westminster?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4991015229692,
#     'longitude': -0.134610682725906},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Caxton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Westminster',
#     'zip_code': 'SW1H 0QW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Caxton Street',
#      'Westminster SW1H 0QW',
#      'United Kingdom']},
#    'phone': '+442072277777',
#    'display_phone': '+44 20 7227 7777',
#    'distance': 1529.9843214535217},
#   {'id': 'bJiVADMSTEKj0MjqiLrOPA',
#    'alias': 'the-grazing-goat-marylebone-london',
#    'name': 'The Grazing Goat Marylebone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/h73f5PAFit9wdm8w_zm3lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grazing-goat-marylebone-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 240,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515378341447,
#     'longitude': -0.15823586449841},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 New Quebec Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7RQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 New Quebec Street',
#      'London W1H 7RQ',
#      'United Kingdom']},
#    'phone': '+442077247243',
#    'display_phone': '+44 20 7724 7243',
#    'distance': 1567.469377589238},
#   {'id': 'cWY8GI2iu_kGIR8ytqPavQ',
#    'alias': 'restaurant-story-london',
#    'name': 'Restaurant Story',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VxAY4VjOYKGgnq8zkCkhEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/restaurant-story-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5027791351505,
#     'longitude': -0.0777639515951396},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '199 Tooley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 2UE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['199 Tooley Street',
#      'London SE1 2UE',
#      'United Kingdom']},
#    'phone': '+442071832117',
#    'display_phone': '+44 20 7183 2117',
#    'distance': 4179.730302045423},
#   {'id': 'VjHBht-AsSB8iw6bwhmaqA',
#    'alias': 'the-lock-tavern-london',
#    'name': 'The Lock Tavern',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/icTn4Y8v4R1QsKxWRPwvNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lock-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 93,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5427479502402,
#     'longitude': -0.147851002323095},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '35 Chalk Farm Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35 Chalk Farm Road',
#      'London NW1 8AJ',
#      'United Kingdom']},
#    'phone': '+442074827163',
#    'display_phone': '+44 20 7482 7163',
#    'distance': 3426.387242675606},
#   {'id': 'hOLFwKg4-0FsCleJ4yoCXw',
#    'alias': 'duck-and-waffle-london',
#    'name': 'Duck & Waffle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WrS5I1dN-nGXePaADwE0cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duck-and-waffle-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 707,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516178, 'longitude': -0.08094},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '110 Bishopsgate',
#     'address2': '40th Floor',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2N 4AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['110 Bishopsgate',
#      '40th Floor',
#      'London EC2N 4AY',
#      'United Kingdom']},
#    'phone': '+442036407310',
#    'display_phone': '+44 20 3640 7310',
#    'distance': 3825.102922188434},
#   {'id': '9tTwAnp4hUzBkb3AwVPHpw',
#    'alias': 'gu-chocolate-puds-london',
#    'name': 'Gu Chocolate Puds',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/M2onexbKJr7zYBiia6G8tw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gu-chocolate-puds-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'chocolate', 'title': 'Chocolatiers & Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.50215, 'longitude': -0.219777},
#    'transactions': [],
#    'location': {'address1': 'Rockley Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W14 0DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Rockley Road', 'London W14 0DA', 'United Kingdom']},
#    'phone': '+442076031660',
#    'display_phone': '+44 20 7603 1660',
#    'distance': 5928.09022079389},
#   {'id': 'y__iD3k2p4Xm0Xl_tSSNZg',
#    'alias': 'holly-bush-london',
#    'name': 'Holly Bush',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/A1ESayCy7xj7xcE0p_1Pew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holly-bush-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5579124, 'longitude': -0.1793261},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Holly Mount',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 6SG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Holly Mount', 'London NW3 6SG', 'United Kingdom']},
#    'phone': '+442074352892',
#    'display_phone': '+44 20 7435 2892',
#    'distance': 5836.476390811221},
#   {'id': '0B-ag3J18TatG9H9EQohGg',
#    'alias': 'hawksmoor-seven-dials-london-4',
#    'name': 'Hawksmoor Seven Dials',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yYxu0Q9uw-StO5TXszf8IQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hawksmoor-seven-dials-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 344,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5134998914001,
#     'longitude': -0.12567396291297},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '11 Langley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9JG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Langley Street',
#      'London WC2H 9JG',
#      'United Kingdom']},
#    'phone': '+442074209390',
#    'display_phone': '+44 20 7420 9390',
#    'distance': 715.3327247350239},
#   {'id': 'jP8bNCOYyBexIUs-L7xDIA',
#    'alias': 'eat-my-pies-london',
#    'name': 'Eat My Pies',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zkaFQEcw1A1xEvs33PxNxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eat-my-pies-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.521716, 'longitude': -0.072301},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "Ely's Yard",
#     'address2': 'The Old Truman Brewery',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["Ely's Yard",
#      'The Old Truman Brewery',
#      'London E1 6QL',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4488.396328610339},
#   {'id': 'mn9JQh5w5I9YGXqHn0PbfQ',
#    'alias': 'rules-london-2',
#    'name': 'Rules',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OIYCYHl_8EFNVy8UWtM-dA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rules-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 206,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5108207, 'longitude': -0.1232501},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '35 Maiden Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 7LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35 Maiden Lane',
#      'London WC2E 7LB',
#      'United Kingdom']},
#    'phone': '+442078365314',
#    'display_phone': '+44 20 7836 5314',
#    'distance': 913.8201956539808},
#   {'id': 'PBFvhVyBi0lEJyTbyuxf5w',
#    'alias': 'the-orangery-london-7',
#    'name': 'The Orangery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L_0d22xNmfCC_d-tArBo3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-orangery-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 238,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5066360577041,
#     'longitude': -0.187725349125042},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Kensington Palace',
#     'address2': 'Palace Green',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Kensington Palace',
#      'Palace Green',
#      'London W8 4PX',
#      'United Kingdom']},
#    'phone': '+442031666113',
#    'display_phone': '+44 20 3166 6113',
#    'distance': 3648.4574890404074},
#   {'id': 'b7RW2pHBLX1gpSKCrIm4AQ',
#    'alias': 'builders-arms-london',
#    'name': 'Builders Arms',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1haAluRxsAMs8uNoEbFMLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/builders-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4994295095615,
#     'longitude': -0.188299279589993},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Kensington Court Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 5BJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Kensington Court Place',
#      'London W8 5BJ',
#      'United Kingdom']},
#    'phone': '+442079376213',
#    'display_phone': '+44 20 7937 6213',
#    'distance': 3917.4513323577366},
#   {'id': 'nAwpCaUpBIneyj1Vg0Zlcw',
#    'alias': 'candy-café-london-2',
#    'name': 'Candy Café',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ALRE1FXqVDY8Q2WmIJye4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/candy-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511873, 'longitude': -0.131473},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '3 Macclesfield Street',
#     'address2': 'Chinatown',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6AU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Macclesfield Street',
#      'Chinatown',
#      'London W1D 6AU',
#      'United Kingdom']},
#    'phone': '+442074344581',
#    'display_phone': '+44 20 7434 4581',
#    'distance': 337.4774111722012},
#   {'id': '3d-OuoqZet1-6iIiro74HA',
#    'alias': 'scandikitchen-london',
#    'name': 'ScandiKitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3OJht4thoMKvoZUvGWl-KA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scandikitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'intlgrocery', 'title': 'International Grocery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5187327, 'longitude': -0.1408946},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61 Great Titchfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 7PP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Great Titchfield Street',
#      'London W1W 7PP',
#      'United Kingdom']},
#    'phone': '+442075807161',
#    'display_phone': '+44 20 7580 7161',
#    'distance': 739.881249374518},
#   {'id': 'syvgGAUsp2ReOwIOm3lUxQ',
#    'alias': 'sussex-london-2',
#    'name': 'Sussex',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sussex-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'winetastingroom', 'title': 'Wine Tasting Room'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5144213610493,
#     'longitude': -0.132224228836094},
#    'transactions': [],
#    'location': {'address1': '63-64 Frith Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1D 3JW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63-64 Frith Street',
#      'London W1D 3JW',
#      'United Kingdom']},
#    'phone': '+442039237770',
#    'display_phone': '+44 20 3923 7770',
#    'distance': 312.68927363891225},
#   {'id': 'YfKn2fkIyXC2jmE1qmgxQw',
#    'alias': 'outsider-tart-london',
#    'name': 'Outsider Tart',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CCbq7o_xmLzRkBXvNOh9TQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/outsider-tart-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4927, 'longitude': -0.252125},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '83 Chiswick High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W4 2EF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Chiswick High Road',
#      'London W4 2EF',
#      'United Kingdom']},
#    'phone': '+442070961609',
#    'display_phone': '+44 20 7096 1609',
#    'distance': 8339.382278059751},
#   {'id': 'UjMwZ6-PgXs3BXN7LLOSAw',
#    'alias': 'gails-bakery-pimlico-london',
#    'name': "GAIL's Bakery - Pimlico",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zobkG9NdbclJN7D9O6w5yw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-pimlico-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4917627846861,
#     'longitude': -0.139058523838447},
#    'transactions': [],
#    'location': {'address1': '26 Churton Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1V 2LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Churton Street',
#      'London SW1V 2LP',
#      'United Kingdom']},
#    'phone': '+442079320734',
#    'display_phone': '+44 20 7932 0734',
#    'distance': 2352.9999537192894},
#   {'id': 'nxxCu3Svrmp2cNvfufrdFw',
#    'alias': 'the-harwood-arms-london',
#    'name': 'The Harwood Arms',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hte754uy10BMdVg3P0hbxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-harwood-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 125,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4829113087309,
#     'longitude': -0.196470990454087},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '27 Walham Grove',
#     'address2': 'Fulham',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 1QP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['27 Walham Grove',
#      'Fulham',
#      'London SW6 1QP',
#      'United Kingdom']},
#    'phone': '+442073861847',
#    'display_phone': '+44 20 7386 1847',
#    'distance': 5349.774856506561},
#   {'id': 'N7VEVrHgwcm4-Aj4neD79g',
#    'alias': 'hawksmoor-london-13',
#    'name': 'Hawksmoor',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LBPP_7l5bqzeyz93YuPZmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hawksmoor-london-13?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 151,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5097072807539,
#     'longitude': -0.136161326657445},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '5A Air Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 0AD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5A Air Street', 'London W1J 0AD', 'United Kingdom']},
#    'phone': '+442074063980',
#    'display_phone': '+44 20 7406 3980',
#    'distance': 348.1347150240858},
#   {'id': 'a8FtrgeFoHZ3N8KPVK2lGQ',
#    'alias': 'bob-bob-ricard-soho',
#    'name': 'Bob Bob Ricard',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1LnW9-0h7nLQupMlkAhetw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bob-bob-ricard-soho?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 157,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5123099662701,
#     'longitude': -0.137234320867947},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '1 Upper James Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Soho',
#     'zip_code': 'W1F 9DF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Upper James Street',
#      'Soho W1F 9DF',
#      'United Kingdom']},
#    'phone': '+442031451000',
#    'display_phone': '+44 20 3145 1000',
#    'distance': 106.03236951148304},
#   {'id': 'iqzQ-rPbALZWPdhNksIRRw',
#    'alias': 'blacklock-london-6',
#    'name': 'Blacklock',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Xg_bHFdoXSNonKTgWVzkhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blacklock-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 108,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.511687, 'longitude': -0.134762},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'The Basement',
#     'address2': '24 Great Windmill Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 7LG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Basement',
#      '24 Great Windmill Street',
#      'London W1D 7LG',
#      'United Kingdom']},
#    'phone': '+442034416996',
#    'display_phone': '+44 20 3441 6996',
#    'distance': 152.1012121582909},
#   {'id': 'jWv5TAis6tiZTpMoiPnJUg',
#    'alias': 'the-culpeper-london',
#    'name': 'The Culpeper',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-sLgVp5Spw03RDlveDdZsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-culpeper-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5169119, 'longitude': -0.0730395},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '40 Commercial Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 Commercial Street',
#      'London E1 6LP',
#      'United Kingdom']},
#    'phone': '+442072475371',
#    'display_phone': '+44 20 7247 5371',
#    'distance': 4377.202205411278},
#   {'id': 'lJ5q7EkXvKtku0aUgsTrAw',
#    'alias': 'the-harrison-london',
#    'name': 'The Harrison',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y6ZdflLpGSwRiGuycPdzjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-harrison-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.527533751588, 'longitude': -0.1206015435123},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '28 Harrison Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 8JF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28 Harrison Street',
#      'London WC1H 8JF',
#      'United Kingdom']},
#    'phone': '+442072783966',
#    'display_phone': '+44 20 7278 3966',
#    'distance': 1949.296955926065},
#   {'id': 'x5vg6DMQQjiuZ2SQVKhIAg',
#    'alias': 'ladurée-london-8',
#    'name': 'Ladurée',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/h8Pp-zN6jYrCJ5nbwRx96Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ladur%C3%A9e-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 127,
#    'categories': [{'alias': 'delicatessen', 'title': 'Delicatessen'},
#     {'alias': 'macarons', 'title': 'Macarons'},
#     {'alias': 'chocolate', 'title': 'Chocolatiers & Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4984851733343,
#     'longitude': -0.162618309259415},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '87 Brompton Road',
#     'address2': 'Harrods',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7XL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['87 Brompton Road',
#      'Harrods',
#      'London SW1X 7XL',
#      'United Kingdom']},
#    'phone': '+442031550111',
#    'display_phone': '+44 20 3155 0111',
#    'distance': 2439.5817151439915},
#   {'id': 'rKwkCvsSfp8z7w1CmNnMMQ',
#    'alias': 'the-table-london-8',
#    'name': 'The Table',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/T-rwpQYiLxDyUXGNAwEYSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-table-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 268,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.505604, 'longitude': -0.099671},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '83 Southwark Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Southwark Street',
#      'London SE1 0HX',
#      'United Kingdom']},
#    'phone': '+442074012760',
#    'display_phone': '+44 20 7401 2760',
#    'distance': 2636.7435245046486},
#   {'id': 'dXEPhJmyV9BiA77wdAfEmg',
#    'alias': 'the-blackbird-london',
#    'name': 'The Blackbird',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/l-vFQ5dw4QEJDAkWvI5Neg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-blackbird-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 157,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.49178, 'longitude': -0.19211},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '209 Earls Ct Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 9AN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['209 Earls Ct Road',
#      'London SW5 9AN',
#      'United Kingdom']},
#    'phone': '+442078351855',
#    'display_phone': '+44 20 7835 1855',
#    'distance': 4538.901972736327},
#   {'id': 'kHlrLHZqIuoQmRpoNYbshg',
#    'alias': 'kerridges-bar-and-grill-london',
#    'name': 'Kerridges Bar and Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zWBSTtELKacxReAIpcJ4iQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kerridges-bar-and-grill-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.506290435791,
#     'longitude': -0.125318005681038},
#    'transactions': [],
#    'location': {'address1': 'Whitehall Pl',
#     'address2': 'Corinthia Hotel',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1A 2BD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Whitehall Pl',
#      'Corinthia Hotel',
#      'London SW1A 2BD',
#      'United Kingdom']},
#    'phone': '+442073213244',
#    'display_phone': '+44 20 7321 3244',
#    'distance': 1078.2876432650048},
#   {'id': 'wm6Hwzan5qYhTzCDmO3oDQ',
#    'alias': 'muriels-kitchen-london',
#    'name': "Muriel's Kitchen",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9un8EzHME-wGnd7zVoev2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/muriels-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 134,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.494117, 'longitude': -0.174468},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 1',
#     'address2': '3 Pelham Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 2ND',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 1',
#      '3 Pelham Street',
#      'London SW7 2ND',
#      'United Kingdom']},
#    'phone': '+442075893511',
#    'display_phone': '+44 20 7589 3511',
#    'distance': 3381.980840047671},
#   {'id': 'Fbt8YC8OQmBF2J4_vDdHhw',
#    'alias': 'simpsons-in-the-strand-london',
#    'name': "Simpson's in the Strand",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PIrsQTdry-qV7gTEoWYhwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/simpsons-in-the-strand-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 79,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5105687, 'longitude': -0.1206719},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '100 Strand',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2R 0EW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['100 Strand', 'London WC2R 0EW', 'United Kingdom']},
#    'phone': '+442074202111',
#    'display_phone': '+44 20 7420 2111',
#    'distance': 1087.3061141000965},
#   {'id': 'ylp2h2OETDExPwggOpWkMg',
#    'alias': 'hixter-bankside-london',
#    'name': 'Hixter Bankside',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/M8t7g76qjFEoWKnVu5yZqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hixter-bankside-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.504811, 'longitude': -0.097384},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '16 Great Guildford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0HS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Great Guildford Street',
#      'London SE1 0HS',
#      'United Kingdom']},
#    'phone': '+442079219508',
#    'display_phone': '+44 20 7921 9508',
#    'distance': 2814.618381457222},
#   {'id': 'E32UWQyHYlSrBbRbtxPzKQ',
#    'alias': 'the-shed-london-3',
#    'name': 'The Shed',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gBCVVxpxL3D2e3l3S7CFFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-shed-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 78,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5089417, 'longitude': -0.1937266},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '122 Palace Gardens Terrace',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4RT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['122 Palace Gardens Terrace',
#      'London W8 4RT',
#      'United Kingdom']},
#    'phone': '+442072294024',
#    'display_phone': '+44 20 7229 4024',
#    'distance': 4026.135052011636},
#   {'id': 'AOA6008C-ZtN6qZPvNn2Ig',
#    'alias': 'holborn-dining-room-london',
#    'name': 'Holborn Dining Room',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/97yY0Rir98gsASYiFPE0gA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holborn-dining-room-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5177699375185,
#     'longitude': -0.117759815344243},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '252 High Holborn',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1V 7EN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['252 High Holborn',
#      'London WC1V 7EN',
#      'United Kingdom']},
#    'phone': '+442037478633',
#    'display_phone': '+44 20 3747 8633',
#    'distance': 1373.4670610292308},
#   {'id': 'By_GidVlsMQa_Ri2hLkP9Q',
#    'alias': 'waxy-o-connors-london',
#    'name': "Waxy O'Connor's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2VBGvltFPGmBdVnJMAHi3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/waxy-o-connors-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 168,
#    'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'},
#     {'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5107349, 'longitude': -0.1322637},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14-16 Rupert Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6DD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14-16 Rupert Street',
#      'London W1D 6DD',
#      'United Kingdom']},
#    'phone': '+442072870255',
#    'display_phone': '+44 20 7287 0255',
#    'distance': 343.497932226086},
#   {'id': 'Tp9hf6I8QThx19E85zgBrA',
#    'alias': 'searcys-st-pancras-restaurant-and-champagne-bar-london',
#    'name': 'Searcys St Pancras Restaurant and Champagne Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/M9qfvLniEZc4FWfHP4aVkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/searcys-st-pancras-restaurant-and-champagne-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'champagne_bars', 'title': 'Champagne Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.530689710913,
#     'longitude': -0.126725974010085},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Grand Terrace Upper Concourse',
#     'address2': 'St Pancras International Station',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Grand Terrace Upper Concourse',
#      'St Pancras International Station',
#      'London N1C 4QL',
#      'United Kingdom']},
#    'phone': '+442078709900',
#    'display_phone': '+44 20 7870 9900',
#    'distance': 2085.46951369412},
#   {'id': 'c3m_OXrRNdJpWmTqhEgdeQ',
#    'alias': 'lanka-london-2',
#    'name': 'Lanka',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1pANCLbvBZdO9tptjqOjmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lanka-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5457719, 'longitude': -0.1793938},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9 Goldhurst Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 3HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Goldhurst Terrace',
#      'London NW6 3HX',
#      'United Kingdom']},
#    'phone': '+442076253366',
#    'display_phone': '+44 20 7625 3366',
#    'distance': 4737.301543897287},
#   {'id': '3R0Klq1B1ESNTwqPfcsY-w',
#    'alias': 'the-pig-and-butcher-london',
#    'name': 'The Pig and Butcher',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zpEzs1qPf3ijMGJdGEcM8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pig-and-butcher-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 109,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.537442542029,
#     'longitude': -0.10682789450616},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '80 Liverpool Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 0QD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['80 Liverpool Road',
#      'London N1 0QD',
#      'United Kingdom']},
#    'phone': '+442072268304',
#    'display_phone': '+44 20 7226 8304',
#    'distance': 3398.14716948262}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#             Restaurant     Type Price Rating                      Address  \
# 0  Ffiona's Restaurant  British    ££    4.5  51 Kensington Church Street
# 1      The Queens Arms  British    ££    4.5               11 Warwick Way
# 2         Regency Café    Cafes     £    4.5         17-19 Regency Street
# 3          Mother Mash  British    ££      4             26 Ganton Street
# 4         The Wolseley    Cafes   £££      4                160 Picadilly
#
#          Lat       Lng                                                url  \
# 0  51.504058 -0.192783  https://www.yelp.com/biz/ffionas-restaurant-lo...
# 1  51.492579 -0.139219  https://www.yelp.com/biz/the-queens-arms-londo...
# 2  51.494014 -0.132220  https://www.yelp.com/biz/regency-caf%C3%A9-lon...
# 3  51.512935 -0.139414  https://www.yelp.com/biz/mother-mash-london?ad...
# 4  51.507617 -0.141012  https://www.yelp.com/biz/the-wolseley-london?a...
#
#                        ID
# 0  70Q-Ll18zb4aglXXbUG7lw
# 1  Wjgxl0lSp_FRtzecbJ4FZQ
# 2  YNduANMPzIVE8CzBH7YjEQ
# 3  IBV7BsXnv2gX68nWUARhjw
# 4  e5jPAqpCcIAsTtasUN5h2g

# %%
#2nd set of 50 records 51-100 
lndr_params2 = {"term":term,"location":"London","limit":50,"offset":51}
lndr_response2 = requests.get(search_api_url, headers=headers, params=lndr_params2)
lndr2 = lndr_response2.json()
display(lndr2)
#print(lndr_response2.url)
#print(lndr_response2.status_code)
# Out:
# {'businesses': [{'id': 'cr_Y_cjHyvifsCkTmK7VAw',
#    'alias': 'r-chocolate-london-richmond-2',
#    'name': 'R Chocolate London',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IkbtCYVYIg8jOsvnMS-L9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/r-chocolate-london-richmond-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'chocolate', 'title': 'Chocolatiers & Shops'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.460311, 'longitude': -0.306768},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10 Paved Court',
#     'address2': '',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': 'TW9 1LZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Paved Court',
#      'Richmond TW9 1LZ',
#      'United Kingdom']},
#    'phone': '+442083323002',
#    'display_phone': '+44 20 8332 3002',
#    'distance': 13190.391413990053},
#   {'id': '3R0Klq1B1ESNTwqPfcsY-w',
#    'alias': 'the-pig-and-butcher-london',
#    'name': 'The Pig and Butcher',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zpEzs1qPf3ijMGJdGEcM8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pig-and-butcher-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 109,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.537442542029,
#     'longitude': -0.10682789450616},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '80 Liverpool Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 0QD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['80 Liverpool Road',
#      'London N1 0QD',
#      'United Kingdom']},
#    'phone': '+442072268304',
#    'display_phone': '+44 20 7226 8304',
#    'distance': 3398.14716948262},
#   {'id': 'jpGkuJfxzKvNTSWxIxSQ8w',
#    'alias': 'loyal-tavern-london',
#    'name': 'Loyal Tavern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8SsxqSi_piYU0PDFhdAnnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/loyal-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.49908, 'longitude': -0.0809},
#    'transactions': [],
#    'location': {'address1': '171-173 Bermondsey Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 3UW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['171-173 Bermondsey Street',
#      'London SE1 3UW',
#      'United Kingdom']},
#    'phone': '+442072602560',
#    'display_phone': '+44 20 7260 2560',
#    'distance': 4106.008684076347},
#   {'id': 't-LjuFbYp76ARX7QEp0gnA',
#    'alias': 'the-windmill-london-2',
#    'name': 'The Windmill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EoyTiwabaEmXue8EXs4nKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-windmill-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 94,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512565, 'longitude': -0.142204},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6-8 Mill Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 2AZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6-8 Mill Street',
#      'London W1S 2AZ',
#      'United Kingdom']},
#    'phone': '+442074918050',
#    'display_phone': '+44 20 7491 8050',
#    'distance': 433.4266729223569},
#   {'id': 'O-DmIhZUQUdeGjT4UCZdFw',
#    'alias': 'hubbard-and-bell-london',
#    'name': 'Hubbard & Bell',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QiNyRKP-2_Ee8yNrsLamCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hubbard-and-bell-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5171333, 'longitude': -0.1223028},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '199-206 High Holborn',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1V 7BD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['199-206 High Holborn',
#      'London WC1V 7BD',
#      'United Kingdom']},
#    'phone': '+442076613030',
#    'display_phone': '+44 20 7661 3030',
#    'distance': 1058.7461338462558},
#   {'id': 'SjK7ZPrjx6YVczuu4EQ9Zg',
#    'alias': 'royal-oak-london',
#    'name': 'Royal Oak',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AmKrn6SzUyT2P-TidicFcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/royal-oak-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5295433651224,
#     'longitude': -0.0692570344313651},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '73 Columbia Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7RG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['73 Columbia Road',
#      'London E2 7RG',
#      'United Kingdom']},
#    'phone': '+442077292220',
#    'display_phone': '+44 20 7729 2220',
#    'distance': 4974.696179797314},
#   {'id': 'Z_KQWTzlUVWjVoFd0b77aw',
#    'alias': 'said-london',
#    'name': 'Said',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/r7ojZUtSeE9UPXJ2Flijfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/said-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'chocolate', 'title': 'Chocolatiers & Shops'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5132248, 'longitude': -0.136738},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '41 Broadwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41 Broadwick Street',
#      'London W1F 9QL',
#      'United Kingdom']},
#    'phone': '+442074371584',
#    'display_phone': '+44 20 7437 1584',
#    'distance': 69.30726559279131},
#   {'id': '3OIaUlgZWnyAhxoWqrB61Q',
#    'alias': 'princess-of-wales-london-5',
#    'name': 'Princess of Wales',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7nubr7jl80pBKbsaXEpF8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/princess-of-wales-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.540283, 'longitude': -0.153757},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Chalcot Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8LL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Chalcot Road',
#      'London NW1 8LL',
#      'United Kingdom']},
#    'phone': '+442077220354',
#    'display_phone': '+44 20 7722 0354',
#    'distance': 3306.604443158016},
#   {'id': 'YOA3LxQ5Pl5yCF-fs0LYMw',
#    'alias': 'boisdale-of-belgravia-london-2',
#    'name': 'Boisdale of Belgravia',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0NW-cNKfaaAxtaJDJRc8fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boisdale-of-belgravia-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 56,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'jazzandblues', 'title': 'Jazz & Blues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4944286, 'longitude': -0.148144},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '15 Eccleston Street',
#     'address2': 'Belgravia',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 9LX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Eccleston Street',
#      'Belgravia',
#      'London SW1W 9LX',
#      'United Kingdom']},
#    'phone': '+442077306922',
#    'display_phone': '+44 20 7730 6922',
#    'distance': 2212.496025354421},
#   {'id': 'jojO1GLQw0Dy18VfLOMlHA',
#    'alias': 'mac-and-wild-london',
#    'name': 'Mac and Wild',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pZVR97lUFK6mThavc-x30w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mac-and-wild-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.518886, 'longitude': -0.140973},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '65 Great Titchfield Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1W 7PS',
#     'country': 'GB',
#     'state': 'ABE',
#     'display_address': ['65 Great Titchfield Street',
#      'London W1W 7PS',
#      'United Kingdom']},
#    'phone': '+442076370510',
#    'display_phone': '+44 20 7637 0510',
#    'distance': 754.2953041475938},
#   {'id': 'CWYCCZkND7MEsOZH6C3jAg',
#    'alias': 'social-eating-house-london-2',
#    'name': 'Social Eating House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hIyL1b22NC8KsGz-82kDdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/social-eating-house-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 93,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5136727, 'longitude': -0.1363879},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '58 Poland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7NS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['58 Poland Street',
#      'London W1F 7NS',
#      'United Kingdom']},
#    'phone': '+442079933251',
#    'display_phone': '+44 20 7993 3251',
#    'distance': 97.77416732581322},
#   {'id': 'jOGLF2Dg8sTmZSiHq1QveQ',
#    'alias': 'sweet-mile-end-london',
#    'name': 'Sweet Mile End',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/pvl3pGLk7D0V97WbjD3sDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweet-mile-end-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'waffles', 'title': 'Waffles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.521854, 'longitude': -0.047487},
#    'transactions': [],
#    'location': {'address1': '169b Mile End Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 4AQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['169b Mile End Road',
#      'London E1 4AQ',
#      'United Kingdom']},
#    'phone': '+44208120500',
#    'display_phone': '+44 208120500',
#    'distance': 6229.33112122162},
#   {'id': 'Fevh3j1rfrLaMgDX5sQCgA',
#    'alias': 'laughing-gravy-london',
#    'name': 'Laughing Gravy',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/g0eYrj0OJ2HxIoudwwH7Nw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laughing-gravy-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5011315371, 'longitude': -0.104388336058516},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '154 Blackfriars Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8EN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['154 Blackfriars Road',
#      'London SE1 8EN',
#      'United Kingdom']},
#    'phone': '+442079981707',
#    'display_phone': '+44 20 7998 1707',
#    'distance': 2543.0208584436764},
#   {'id': 'HaYOqwNtC6JK2uuGmr1KGg',
#    'alias': 'piebury-corner-london-4',
#    'name': 'Piebury Corner',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3-ozW-aDRq3uEnFudGS0mQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piebury-corner-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.55099, 'longitude': -0.11041},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '209-211 Holloway Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N7 8DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['209-211 Holloway Road',
#      'London N7 8DL',
#      'United Kingdom']},
#    'phone': '+442077005441',
#    'display_phone': '+44 20 7700 5441',
#    'distance': 4601.644340774392},
#   {'id': '96e4OEzbAooftH1qaUxa5g',
#    'alias': 'the-english-restaurant-london',
#    'name': 'The English Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Oi2f7EQTutleGg5kIT7YEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-english-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 72,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5189580049569,
#     'longitude': -0.076603889465332},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '50-52 Brushfield Street',
#     'address2': 'Spitalfields',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50-52 Brushfield Street',
#      'Spitalfields',
#      'London E1 6AG',
#      'United Kingdom']},
#    'phone': '+442072474110',
#    'display_phone': '+44 20 7247 4110',
#    'distance': 4162.973302057391},
#   {'id': 'lVn3qBXylytx6BxrTzCpLQ',
#    'alias': 'the-chandos-london',
#    'name': 'The Chandos',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Clk3rjykKlojgJzv5motqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-chandos-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 151,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.509588, 'longitude': -0.126792},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "29 Saint Martin's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["29 Saint Martin's Lane",
#      'London WC2N 4ER',
#      'United Kingdom']},
#    'phone': '+442078361401',
#    'display_phone': '+44 20 7836 1401',
#    'distance': 729.771036358222},
#   {'id': 'lMhErBByefchffCCf5fUjQ',
#    'alias': 'scotts-london-4',
#    'name': "Scott's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pu4rvKVUPLMc8R7dDF5XIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scotts-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 98,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5098472, 'longitude': -0.150917},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '20 Mount Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 2HE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Mount Street',
#      'London W1K 2HE',
#      'United Kingdom']},
#    'phone': '+442074957309',
#    'display_phone': '+44 20 7495 7309',
#    'distance': 1080.2879178427297},
#   {'id': 'm3vdBGC0X94sG_5pglDcjQ',
#    'alias': 'st-john-bread-and-wine-london',
#    'name': 'St. John Bread & Wine',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/pp8TqPWzX151RfxV3HbzXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-john-bread-and-wine-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 128,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5196695, 'longitude': -0.074299},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '94-96 Commercial Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6LZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['94-96 Commercial Street',
#      'London E1 6LZ',
#      'United Kingdom']},
#    'phone': '+442072510848',
#    'display_phone': '+44 20 7251 0848',
#    'distance': 4337.705786972397},
#   {'id': '6T4edfBlwPy7pSW7f1KhMg',
#    'alias': 'bird-of-smithfield-london-2',
#    'name': 'Bird of Smithfield',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NU8SYOoY5wtLoFEcyfR3Iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bird-of-smithfield-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5183818, 'longitude': -0.1026044},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '26 Smithfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1A 9LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Smithfield Street',
#      'London EC1A 9LB',
#      'United Kingdom']},
#    'phone': '+442075595100',
#    'display_phone': '+44 20 7559 5100',
#    'distance': 2388.789092264097},
#   {'id': 'VomGBPMQALZLfKHCI8_jTg',
#    'alias': 'the-swan-london-6',
#    'name': 'The Swan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CjuYlM6M82fHy8xsBDw0Ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-swan-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 115,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511656071976,
#     'longitude': -0.17697194507093},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '66 Bayswater Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Bayswater Road',
#      'London W2 3PH',
#      'United Kingdom']},
#    'phone': '+442072625204',
#    'display_phone': '+44 20 7262 5204',
#    'distance': 2841.418230660763},
#   {'id': 'wEJKOJ9Hc2FEEGq2UbaMQQ',
#    'alias': 'duke-of-kendal-london',
#    'name': 'Duke Of Kendal',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rAfIZgm1pGCQq4TL0y6N3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duke-of-kendal-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514587763527,
#     'longitude': -0.16622892139991},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '38 Connaught Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 2AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38 Connaught Street',
#      'London W2 2AF',
#      'United Kingdom']},
#    'phone': '+442077238478',
#    'display_phone': '+44 20 7723 8478',
#    'distance': 2103.927386637284},
#   {'id': '94cWQZLiw7AXUPGFwHe2lA',
#    'alias': 'diwan-damas-london-2',
#    'name': 'Diwan Damas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hem3G3HZYAImM-NvXdNvVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/diwan-damas-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'chocolate', 'title': 'Chocolatiers & Shops'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.516528, 'longitude': -0.165439},
#    'transactions': [],
#    'location': {'address1': '121b Edgware Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 2HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['121b Edgware Road',
#      'London W2 2HX',
#      'United Kingdom']},
#    'phone': '+442071801972',
#    'display_phone': '+44 20 7180 1972',
#    'distance': 2081.085233285256},
#   {'id': 'fHIKopvPKVG0IJ7cHy3Zow',
#    'alias': 'piebury-corner-london-5',
#    'name': 'Piebury Corner',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8JSmF1ohb0FZQYiljTB42Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piebury-corner-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5311405, 'longitude': -0.1211956},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '3 Caledonian Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N1 9DX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Caledonian Road',
#      'London N1 9DX',
#      'United Kingdom']},
#    'phone': '+442076882987',
#    'display_phone': '+44 20 7688 2987',
#    'distance': 2277.2368519304696},
#   {'id': 'vmy1NQa3t-UG6c6ORRH2Ig',
#    'alias': 'the-champion-notting-hill-london',
#    'name': 'The Champion- Notting Hill',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MsneYiNY2f3lryCHl5QR1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-champion-notting-hill-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 109,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5100255, 'longitude': -0.1922685},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Wellington Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 4LW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Wellington Terrace',
#      'London W2 4LW',
#      'United Kingdom']},
#    'phone': '+442077924527',
#    'display_phone': '+44 20 7792 4527',
#    'distance': 3909.5150047857796},
#   {'id': 'hM4RCPwAZHWy9woF0UWATA',
#    'alias': 'the-winchester-london',
#    'name': 'The Winchester',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bqDEtqwHTsWGGhaE--Vkog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-winchester-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.536355271762,
#     'longitude': -0.10161073774793},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Essex Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8LN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Essex Road', 'London N1 8LN', 'United Kingdom']},
#    'phone': '+442077048789',
#    'display_phone': '+44 20 7704 8789',
#    'distance': 3533.4814194333685},
#   {'id': 'Nr2nibp1Oya1MPsuAgqB9A',
#    'alias': 'the-white-swan-london',
#    'name': 'The White Swan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uU8TsOXeb3zUnqDJSx_vrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-white-swan-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516278634291,
#     'longitude': -0.10929885783682},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '108 Fetter Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4A 1ES',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['108 Fetter Lane',
#      'London EC4A 1ES',
#      'United Kingdom']},
#    'phone': '+442072429696',
#    'display_phone': '+44 20 7242 9696',
#    'distance': 1883.9279417213795},
#   {'id': 'Z3dr4as9zDncGnaCtqnntQ',
#    'alias': 'patisserie-valerie-london-7',
#    'name': 'Patisserie Valerie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GeZus7r-mVclADzIcGbopg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-valerie-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5191096196678,
#     'longitude': -0.15177361600921},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '105 Marylebone High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 4RS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['105 Marylebone High Road',
#      'London W1U 4RS',
#      'United Kingdom']},
#    'phone': '+442079356240',
#    'display_phone': '+44 20 7935 6240',
#    'distance': 1297.9635922946884},
#   {'id': '9K-A7wHxB-z3n5h-P_mYFA',
#    'alias': 'vinoteca-kings-cross-london',
#    'name': 'Vinoteca Kings Cross',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7EEdDIkdCr9_lZulQOEI6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vinoteca-kings-cross-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5327386594665,
#     'longitude': -0.124989295739738},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'One Pancras Square',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['One Pancras Square',
#      'London N1C 4AG',
#      'United Kingdom']},
#    'phone': '+442037937210',
#    'display_phone': '+44 20 3793 7210',
#    'distance': 2339.5707067138264},
#   {'id': 'QuR7O0yd-W4UOM6SeG8L9w',
#    'alias': 'speedys-cafe-london-2',
#    'name': "Speedy's Cafe",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/F1cTubQIjATP_saAVYDGWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/speedys-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5261655, 'longitude': -0.1368146},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '187 North Gower Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 2NJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['187 North Gower Street',
#      'London NW1 2NJ',
#      'United Kingdom']},
#    'phone': '+442073833485',
#    'display_phone': '+44 20 7383 3485',
#    'distance': 1493.323641164572},
#   {'id': 'XUwGo_3lgdxjuL7E5s3FKA',
#    'alias': 'pierre-victoire-london',
#    'name': 'Pierre Victoire',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GTWqvdhr1GEB6AY7vvMOWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pierre-victoire-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 94,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515441, 'longitude': -0.133575},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5 Dean Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 3RQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Dean Street', 'London W1D 3RQ', 'United Kingdom']},
#    'phone': '+442072874582',
#    'display_phone': '+44 20 7287 4582',
#    'distance': 332.42940152360893},
#   {'id': 'fdy9YViMdCwsTsXYsHwurw',
#    'alias': 'eastway-brasserie-london',
#    'name': 'Eastway Brasserie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4qzCaW2cMasxxPLFV4hSgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eastway-brasserie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.517379, 'longitude': -0.081469},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '40 Liverpool Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2M 7QN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 Liverpool Street',
#      'London EC2M 7QN',
#      'United Kingdom']},
#    'phone': '+442076187010',
#    'display_phone': '+44 20 7618 7010',
#    'distance': 3804.0455168474455},
#   {'id': 'SQqalQPyvPPeMVRZpM4Euw',
#    'alias': 'chez-antoinette-london',
#    'name': 'Chez Antoinette',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zlMs2nYV9CufeYXN9wJHBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chez-antoinette-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512071, 'longitude': -0.122977},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '30 The Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 8RF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 The Market', 'London WC2E 8RF', 'United Kingdom']},
#    'phone': '+442072409072',
#    'display_phone': '+44 20 7240 9072',
#    'distance': 904.8765108749993},
#   {'id': 'OLXUZqx6doQtdeHfyEoyOw',
#    'alias': 'balans-soho-society-london',
#    'name': 'Balans Soho Society',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/x5-9gQeXo60P7Y5uC0nWUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/balans-soho-society-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 92,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4999833, 'longitude': -0.1956639},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '187 Kensington High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 6SH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['187 Kensington High Street',
#      'London W8 6SH',
#      'United Kingdom']},
#    'phone': '+442073760115',
#    'display_phone': '+44 20 7376 0115',
#    'distance': 4362.76195718541},
#   {'id': 'K69_hmLhHHkXnjHxGayQVQ',
#    'alias': 'le-pain-quotidien-london-16',
#    'name': 'Le Pain Quotidien',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ggcjTkzCJUSM_DyCioUqNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-pain-quotidien-london-16?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.506293222721,
#     'longitude': -0.091394940760572},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '15 Winchester Walk',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Winchester Walk',
#      'London SE1 9AG',
#      'United Kingdom']},
#    'phone': '+442036576927',
#    'display_phone': '+44 20 3657 6927',
#    'distance': 3168.5150579455744},
#   {'id': 'xmqDJi8wGKhvl9DCmegThQ',
#    'alias': 'the-winter-garden-restaurant-london-2',
#    'name': 'The Winter Garden Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oyXn2g7nLLQmIuHLLrwBHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-winter-garden-restaurant-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5213155, 'longitude': -0.1626014},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '222 Marylebone Road',
#     'address2': '',
#     'address3': 'The Landmark London',
#     'city': 'London',
#     'zip_code': 'NW1 6JQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['222 Marylebone Road',
#      'The Landmark London',
#      'London NW1 6JQ',
#      'United Kingdom']},
#    'phone': '+442076318000',
#    'display_phone': '+44 20 7631 8000',
#    'distance': 2070.8562242794737},
#   {'id': 'LpIY4AvlAQZqJEZgcFoFPA',
#    'alias': 'the-alchemist-london-3',
#    'name': 'The Alchemist',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NXHurBRaL0gJuLtVnXZAKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-alchemist-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 85,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5150476, 'longitude': -0.0793474},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 Bevis Marks',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3A 7BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Bevis Marks', 'London EC3A 7BA', 'United Kingdom']},
#    'phone': '+442072838800',
#    'display_phone': '+44 20 7283 8800',
#    'distance': 3924.9724248663238},
#   {'id': 'pQS5srLHVMsb4EU9uep9Gw',
#    'alias': 'cereal-killer-cafe-london',
#    'name': 'Cereal Killer Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nukLebpj9h77i_3DBr_YIQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cereal-killer-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 121,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5237499257239,
#     'longitude': -0.071338377892971},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '192 Brick Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['192 Brick Lane', 'London E1 6SB', 'United Kingdom']},
#    'phone': '+442036019100',
#    'display_phone': '+44 20 3601 9100',
#    'distance': 4632.834898564713},
#   {'id': '5sEiM_Xw5jXbMhloNqSgYQ',
#    'alias': 'grumbles-london',
#    'name': 'Grumbles',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/D6YLzHz7ilRcYpLsaG92Gg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grumbles-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4911292, 'longitude': -0.1388531},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '35 Churton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 2LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35 Churton Street',
#      'London SW1V 2LT',
#      'United Kingdom']},
#    'phone': '+442078340149',
#    'display_phone': '+44 20 7834 0149',
#    'distance': 2417.0516096383467},
#   {'id': 'DUS7Nz3429d2iv0q-Jky9A',
#    'alias': 'paul-london-3',
#    'name': 'Paul',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_deqF7vT-EKCTReCgaMVqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4990676958953,
#     'longitude': -0.165139898919551},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '122 Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 1JD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['122 Brompton Road',
#      'London SW3 1JD',
#      'United Kingdom']},
#    'phone': '+442075846117',
#    'display_phone': '+44 20 7584 6117',
#    'distance': 2534.4748856906567},
#   {'id': 'PFfvx35hedesCYwPMtE8dg',
#    'alias': 'skylon-london',
#    'name': 'Skylon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5TVWOiHuO0qgl_Fi8seq8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/skylon-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 88,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.505748, 'longitude': -0.117614},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Southbank Centre',
#     'address2': 'Belvedere Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8XX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Southbank Centre',
#      'Belvedere Road',
#      'London SE1 8XX',
#      'United Kingdom']},
#    'phone': '+442076547800',
#    'display_phone': '+44 20 7654 7800',
#    'distance': 1494.1187451904684},
#   {'id': 'A-IeaZPEGOcqMvVc4vw8Kw',
#    'alias': 'cafe-dylan-dog-london',
#    'name': 'Cafe Dylan Dog',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RL2FuEjpPpTBxSrxijIHRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-dylan-dog-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5148811, 'longitude': -0.1765969},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '7 Craven Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3BP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Craven Road', 'London W2 3BP', 'United Kingdom']},
#    'phone': '+442077238027',
#    'display_phone': '+44 20 7723 8027',
#    'distance': 2814.277784990465},
#   {'id': 'esqcFErh7VLufx6ytt_HGg',
#    'alias': 'flavour-bastard-london',
#    'name': 'Flavour Bastard',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AJOmACQWpIAJUgbLFKuDtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flavour-bastard-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5144030223745,
#     'longitude': -0.132213458418846},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '63-64 Frith Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1D 3JW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63-64 Frith Street',
#      'London W1D 3JW',
#      'United Kingdom']},
#    'phone': '+442077344545',
#    'display_phone': '+44 20 7734 4545',
#    'distance': 312.16193777049284},
#   {'id': '7dtrVGOrT6q7QvMxSyyLgg',
#    'alias': 'chin-chin-labs-london-2',
#    'name': 'Chin Chin Labs',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OhD1NPtsfq-corumKjKkaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chin-chin-labs-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 150,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.541145, 'longitude': -0.14664},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '49-50 Camden Lock Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49-50 Camden Lock Place',
#      'London NW1 8AF',
#      'United Kingdom']},
#    'phone': '+447885604284',
#    'display_phone': '+44 7885 604284',
#    'distance': 3233.4769175786328},
#   {'id': 'mc1KLbA1Sy4kUTKo0ZEeRQ',
#    'alias': 'dishoom-london-7',
#    'name': 'Dishoom',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9ok9Iflq--Oxs2w3dbcF9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dishoom-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 553,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.513087, 'longitude': -0.139767},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Kingly Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5QP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Kingly Street',
#      'London W1B 5QP',
#      'United Kingdom']},
#    'phone': '+442074209322',
#    'display_phone': '+44 20 7420 9322',
#    'distance': 265.21527226714676},
#   {'id': '1TZOMqkGKNENJPMQL9g5qg',
#    'alias': 'henrys-cafe-bar-london-2',
#    'name': "Henry's Cafe Bar",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aicOVl3Fip8T_aB_gT2_JQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/henrys-cafe-bar-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.506747, 'longitude': -0.143297},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '80 Piccadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 8HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['80 Piccadilly', 'London W1J 8HX', 'United Kingdom']},
#    'phone': '+442074912544',
#    'display_phone': '+44 20 7491 2544',
#    'distance': 854.5926455058137},
#   {'id': 'IAO38h8sIn5UQQcIb3770A',
#    'alias': 'the-princess-of-shoreditch-london',
#    'name': 'The Princess of Shoreditch',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ATMA-aDh1tFpK07rckRwmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-princess-of-shoreditch-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5254182, 'longitude': -0.0836493},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '76-78 Paul Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 4NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['76-78 Paul Street',
#      'London EC2A 4NE',
#      'United Kingdom']},
#    'phone': '+442077299270',
#    'display_phone': '+44 20 7729 9270',
#    'distance': 3873.2287400969053},
#   {'id': 'p-mix89L-TLe6qVu1yk03g',
#    'alias': 'scoff-and-banter-london-21',
#    'name': 'Scoff & Banter',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZYhEDoEzXukA5qhJTJ38vA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scoff-and-banter-london-21?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5179725, 'longitude': -0.1280495},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '97 Great Russell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3LD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['97 Great Russell Street',
#      'London WC1B 3LD',
#      'United Kingdom']},
#    'phone': '+442076662068',
#    'display_phone': '+44 20 7666 2068',
#    'distance': 790.940084846832},
#   {'id': '4KgPoTQjWf6yosVVyCyLBg',
#    'alias': 'the-butlers-london',
#    'name': 'The Butlers',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IGXNByl6hp8S4yUDgDMGHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-butlers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'diners', 'title': 'Diners'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5076757098205,
#     'longitude': -0.147087520237733},
#    'transactions': [],
#    'location': {'address1': '35 Charles Street',
#     'address2': '',
#     'address3': 'Mayfair',
#     'city': 'London',
#     'zip_code': 'W1J 5EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35 Charles Street',
#      'Mayfair',
#      'London W1J 5EB',
#      'United Kingdom']},
#    'phone': '+442074912622',
#    'display_phone': '+44 20 7491 2622',
#    'distance': 960.5462674242048},
#   {'id': '0r2-fwgLvuOLef0epiFkFQ',
#    'alias': 'granger-and-co-london',
#    'name': 'Granger & Co',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4pSTSM2JgsADC_cPoLBQJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/granger-and-co-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 183,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514646148453,
#     'longitude': -0.19779915622354},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '175 Westbourne Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['175 Westbourne Grove',
#      'London W11 2SB',
#      'United Kingdom']},
#    'phone': '+442072299111',
#    'display_phone': '+44 20 7229 9111',
#    'distance': 4284.263019990538},
#   {'id': 'wCjU2KuTntCZDCZSIS1Uxw',
#    'alias': 'the-ivy-kensington-brasserie-london',
#    'name': 'The Ivy Kensington Brasserie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/O2iBlelJiZe11wXmi9NsIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ivy-kensington-brasserie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5015677, 'longitude': -0.1921797},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '96 Kensington High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4SG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['96 Kensington High Street',
#      'London W8 4SG',
#      'United Kingdom']},
#    'phone': '+442033010500',
#    'display_phone': '+44 20 3301 0500',
#    'distance': 4091.0923076045005}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#             Restaurant                  Type Price Rating  \
# 0   R Chocolate London  Chocolatiers & Shops    ££      5
# 1  The Pig and Butcher               British    ££    4.5
# 2         Loyal Tavern               British
# 3         The Windmill                  Pubs    ££      4
# 4       Hubbard & Bell                  Bars    ££      4
#
#                      Address        Lat       Lng  \
# 0             10 Paved Court  51.460311 -0.306768
# 1          80 Liverpool Road  51.537443 -0.106828
# 2  171-173 Bermondsey Street  51.499080 -0.080900
# 3            6-8 Mill Street  51.512565 -0.142204
# 4       199-206 High Holborn  51.517133 -0.122303
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/r-chocolate-london-ri...  cr_Y_cjHyvifsCkTmK7VAw
# 1  https://www.yelp.com/biz/the-pig-and-butcher-l...  3R0Klq1B1ESNTwqPfcsY-w
# 2
# 3  https://www.yelp.com/biz/the-windmill-london-2...  t-LjuFbYp76ARX7QEp0gnA
# 4  https://www.yelp.com/biz/hubbard-and-bell-lond...  O-DmIhZUQUdeGjT4UCZdFw

# %%
#3rd set of 50 records 101-150
lndr_params3 = {"term":term,"location":"London","limit":50,"offset":101}
lndr_response3 = requests.get(search_api_url, headers=headers, params=lndr_params3)
lndr3 = lndr_response3.json()
display(lndr3)
#print(lndr_response3.url)
#print(lndr_response3.status_code)
# Out:
# {'businesses': [{'id': 'bEmaFY0A9JwpuxHKJXWx7Q',
#    'alias': 'the-ledbury-london',
#    'name': 'The Ledbury',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/j28_qI46pGjAGK3I6QLB5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ledbury-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 166,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.516819, 'longitude': -0.200107},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '127 Ledbury Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2AQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['127 Ledbury Road',
#      'London W11 2AQ',
#      'United Kingdom']},
#    'phone': '+442077929090',
#    'display_phone': '+44 20 7792 9090',
#    'distance': 4461.169501484266},
#   {'id': 'F_QagoJLYYRaDvgcvzsbiQ',
#    'alias': 'frontline-restaurant-london',
#    'name': 'Frontline Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4DjZCKiNBRBnx4W-P4t1Eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frontline-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5169838, 'longitude': -0.1724763},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '13 Norfolk Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Norfolk Place',
#      'London W2 1QJ',
#      'United Kingdom']},
#    'phone': '+442074798960',
#    'display_phone': '+44 20 7479 8960',
#    'distance': 2568.6402035095152},
#   {'id': 'E43MdoA7zkZ6SnPjAJaTvA',
#    'alias': 'brasserie-zédel-london',
#    'name': 'Brasserie Zédel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IeIn5kaFWw3q14DUoWZvyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brasserie-z%C3%A9del-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 163,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'jazzandblues', 'title': 'Jazz & Blues'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5106025898049,
#     'longitude': -0.135575861793962},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Sherwood Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Sherwood Street',
#      'London W1F 7ED',
#      'United Kingdom']},
#    'phone': '+442077344888',
#    'display_phone': '+44 20 7734 4888',
#    'distance': 249.67869451004725},
#   {'id': 'H8dMsOa3ylJxZjHqkEg9cg',
#    'alias': 'kitty-fishers-mayfair',
#    'name': "Kitty Fisher's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yx1Yp9jx6YB0vE-2ZfG5aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kitty-fishers-mayfair?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5064608599645,
#     'longitude': -0.146486238043086},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '10 Shepherd Market',
#     'address2': '',
#     'address3': '',
#     'city': 'Mayfair',
#     'zip_code': 'W1J 7QF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Shepherd Market',
#      'Mayfair W1J 7QF',
#      'United Kingdom']},
#    'phone': '+442033021661',
#    'display_phone': '+44 20 3302 1661',
#    'distance': 1016.6310635452348},
#   {'id': 'uTm94f_-FlwM7v7T2ycXaQ',
#    'alias': 'dominique-ansel-treehouse-london',
#    'name': 'Dominique Ansel Treehouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Amyw6Q1tbkeeiPYFPnwBUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dominique-ansel-treehouse-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5119045680643,
#     'longitude': -0.12540479881136},
#    'transactions': [],
#    'location': {'address1': '24 Floral Street',
#     'address2': '',
#     'address3': 'Covent Garden',
#     'city': 'London',
#     'zip_code': 'WC2E 9DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Floral Street',
#      'Covent Garden',
#      'London WC2E 9DP',
#      'United Kingdom']},
#    'phone': '+442038834710',
#    'display_phone': '+44 20 3883 4710',
#    'distance': 737.4485292911053},
#   {'id': 'nHMn6sJQEj1c2cnGThyvvg',
#    'alias': 'harrods-food-hall-london',
#    'name': 'Harrods Food Hall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lTez1h3O4WyMt5kA4i8FBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harrods-food-hall-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 325,
#    'categories': [{'alias': 'cheese', 'title': 'Cheese Shops'},
#     {'alias': 'wineries', 'title': 'Wineries'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4990917420527,
#     'longitude': -0.162348972665107},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '87-135 Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7XL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['87-135 Brompton Road',
#      'London SW1X 7XL',
#      'United Kingdom']},
#    'phone': '+442077301234',
#    'display_phone': '+44 20 7730 1234',
#    'distance': 2381.6721756016004},
#   {'id': 'K0lmqEgpNz97FausJUyn1A',
#    'alias': 'swan-bankside',
#    'name': 'Swan',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/N64Augq0xpsMA9lZ9yHnBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/swan-bankside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 240,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.50835, 'longitude': -0.096985},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "Swan Shakespeare's Globe",
#     'address2': '21 New Globe Walk',
#     'address3': '',
#     'city': 'Bankside',
#     'zip_code': 'SE1 9DT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["Swan Shakespeare's Globe",
#      '21 New Globe Walk',
#      'Bankside SE1 9DT',
#      'United Kingdom']},
#    'phone': '+442079289444',
#    'display_phone': '+44 20 7928 9444',
#    'distance': 2742.680311119211},
#   {'id': 'dKkpVibx1M5rrrOovvl-xQ',
#    'alias': 'hix-soho-london',
#    'name': 'Hix - Soho',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8oGnoreq2oV3F7rsd9fI-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hix-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 82,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5111269794589,
#     'longitude': -0.136461530845653},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '66-70 Brewer Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9UP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66-70 Brewer Street',
#      'London W1F 9UP',
#      'United Kingdom']},
#    'phone': '+442072923518',
#    'display_phone': '+44 20 7292 3518',
#    'distance': 193.17751511750475},
#   {'id': 'meHB5zqhVKuOQ3gacMlzBg',
#    'alias': 'dinner-by-heston-blumenthal-london',
#    'name': 'Dinner by Heston Blumenthal',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QN_cg4jL6VvrklJ4iTgpsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dinner-by-heston-blumenthal-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 288,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.502163, 'longitude': -0.159966},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '66 Knightsbridge',
#     'address2': '',
#     'address3': 'Mandarin Oriental at Hyde Park',
#     'city': 'London',
#     'zip_code': 'SW1X 7LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Knightsbridge',
#      'Mandarin Oriental at Hyde Park',
#      'London SW1X 7LA',
#      'United Kingdom']},
#    'phone': '+442072013833',
#    'display_phone': '+44 20 7201 3833',
#    'distance': 2041.9703490995012},
#   {'id': 'lHxwh10PUmcXIzUp5wAiEg',
#    'alias': 'hawksmoor-london-14',
#    'name': 'Hawksmoor',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MvWrjDkcHDuO2eFbMIFCLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hawksmoor-london-14?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 67,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4974592155569,
#     'longitude': -0.166872303554917},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "3 Yeoman's Row",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 2AL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["3 Yeoman's Row", 'London SW3 2AL', 'United Kingdom']},
#    'phone': '+442075909290',
#    'display_phone': '+44 20 7590 9290',
#    'distance': 2738.9932877272277},
#   {'id': '1pUEGW91riUIux0TZWw_4g',
#    'alias': 'palm-court-london',
#    'name': 'Palm Court',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lm0uTmtWFWNdHZ9t_bDGDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/palm-court-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 66,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.517861058645,
#     'longitude': -0.14380458653274},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1C Portland Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 1JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1C Portland Place',
#      'London W1B 1JA',
#      'United Kingdom']},
#    'phone': '+442079650195',
#    'display_phone': '+44 20 7965 0195',
#    'distance': 779.2584555813771},
#   {'id': 'fJ1G0mb0EMQ3qBlx9dRv9g',
#    'alias': 'the-dining-room-at-the-goring-hotel-london',
#    'name': 'The Dining Room at The Goring Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/i7pFuNEZzinIKirZt_CtGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dining-room-at-the-goring-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.497484, 'longitude': -0.145575},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '15 Beeston Place',
#     'address2': 'Grosvenor Gardens',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 0JW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Beeston Place',
#      'Grosvenor Gardens',
#      'London SW1W 0JW',
#      'United Kingdom']},
#    'phone': '+442073969000',
#    'display_phone': '+44 20 7396 9000',
#    'distance': 1823.5531621164491},
#   {'id': '75-HeBBB391Np6T7GdJ5xQ',
#    'alias': 'the-ivy-london',
#    'name': 'The Ivy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rVk4F439o22SXXzGGHKGRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ivy-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 171,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512814, 'longitude': -0.128013},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1 - 5 West Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9NQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 - 5 West Street',
#      'London WC2H 9NQ',
#      'United Kingdom']},
#    'phone': '+442078364751',
#    'display_phone': '+44 20 7836 4751',
#    'distance': 549.6549455465449},
#   {'id': 'ScvTVomXz-WmNjrnjNLH4g',
#    'alias': 'newman-arms-london',
#    'name': 'Newman Arms',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1p5Ym-LvA8e8ossXblR9jg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/newman-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.518156559194,
#     'longitude': -0.13516434068553},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '23 Rathbone Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 1NG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23 Rathbone Street',
#      'London W1T 1NG',
#      'United Kingdom']},
#    'phone': '+442076361127',
#    'display_phone': '+44 20 7636 1127',
#    'distance': 594.2010924388351},
#   {'id': '2QTiP4NN1vmE82sIYo3OBA',
#    'alias': 'pleasant-lady-jian-bing-trading-stall-london',
#    'name': 'Pleasant Lady Jian Bing Trading Stall',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WxI2QBCQJiHkCJB5JmuwmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pleasant-lady-jian-bing-trading-stall-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'streetvendors', 'title': 'Street Vendors'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5136205056365,
#     'longitude': -0.130577597926276},
#    'transactions': [],
#    'location': {'address1': '23 Greek Street',
#     'address2': '',
#     'address3': 'Soho',
#     'city': 'London',
#     'zip_code': 'W1D 4DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23 Greek Street',
#      'Soho',
#      'London W1D 4DY',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 382.2725599567419},
#   {'id': 'lhxbsnG4XURYcUVoZgaO5w',
#    'alias': 'the-prince-arthur-london',
#    'name': 'The Prince Arthur',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_qaRtEqfKEWqrTZ85m1bow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-prince-arthur-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.544152920013,
#     'longitude': -0.06561294346439},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Public House',
#     'address2': '95 Forest Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 3BH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Public House',
#      '95 Forest Road',
#      'London E8 3BH',
#      'United Kingdom']},
#    'phone': '+442072499996',
#    'display_phone': '+44 20 7249 9996',
#    'distance': 5983.787757551523},
#   {'id': 'Hau6XfpZTKv_H07WUgCF2w',
#    'alias': 'the-albert-london-3',
#    'name': 'The Albert',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uYxqRxcY0stjxXW1PlE7eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-albert-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.497704715101,
#     'longitude': -0.13551526516958},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '52 Victoria Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1H 0NP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['52 Victoria Street',
#      'London SW1H 0NP',
#      'United Kingdom']},
#    'phone': '+442072225577',
#    'display_phone': '+44 20 7222 5577',
#    'distance': 1682.7432783061354},
#   {'id': 'UESyhTRQY4CYtGNoYBc52Q',
#    'alias': 'terrys-cafe-london-3',
#    'name': "Terry's Cafe",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YBkG1Yc2dbbemDZCQeKbOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/terrys-cafe-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.50069, 'longitude': -0.0984105},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '158 Great Suffolk Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1PE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['158 Great Suffolk Street',
#      'London SE1 1PE',
#      'United Kingdom']},
#    'phone': '+442074079358',
#    'display_phone': '+44 20 7407 9358',
#    'distance': 2928.512166850289},
#   {'id': 'KoIBxqTLWD35W_NLTf9qUA',
#    'alias': 'canteen-london-11',
#    'name': 'Canteen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kPGhFsgEC08ZAKGOS5bBSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/canteen-london-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.505777, 'longitude': -0.116838},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Royal Festival Hall',
#     'address2': 'Belvedere Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8XX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Royal Festival Hall',
#      'Belvedere Road',
#      'London SE1 8XX',
#      'United Kingdom']},
#    'phone': '+448456861122',
#    'display_phone': '+44 845 686 1122',
#    'distance': 1537.9435840916901},
#   {'id': '68gc1BAE1IT_zZghFafw0Q',
#    'alias': 'ozone-coffee-london-2',
#    'name': 'Ozone Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FMKfpA6gKHlDAKDuPVVdTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ozone-coffee-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 188,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.524683689256,
#     'longitude': -0.086674106560876},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Leonard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 4AQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Leonard Street',
#      'London EC2A 4AQ',
#      'United Kingdom']},
#    'phone': '+442074901039',
#    'display_phone': '+44 20 7490 1039',
#    'distance': 3655.552919913525},
#   {'id': 'GTImh5FbaxKTo8TXyxRT4w',
#    'alias': 'rabot-1745-london-3',
#    'name': 'Rabot 1745',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MZQVMlveAsL3Gh11ocSHZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rabot-1745-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 80,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5053829371106,
#     'longitude': -0.0899640662595528},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2-4 Bedale Street',
#     'address2': 'Borough Market',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9AL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2-4 Bedale Street',
#      'Borough Market',
#      'London SE1 9AL',
#      'United Kingdom']},
#    'phone': '+442073788226',
#    'display_phone': '+44 20 7378 8226',
#    'distance': 3289.037757085594},
#   {'id': 'tH_2560cbjme-hFBFVj8cQ',
#    'alias': 'brigits-bakery-london',
#    'name': "Brigit's Bakery",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mdh8u6FH2qeo4BRzNVNBHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brigits-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5100888407083,
#     'longitude': -0.124539992630842},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6-7 Chandos Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4HU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6-7 Chandos Place',
#      'London WC2N 4HU',
#      'United Kingdom']},
#    'phone': '+442030261188',
#    'display_phone': '+44 20 3026 1188',
#    'distance': 846.9905268424552},
#   {'id': 'ofk57INQHCumktjqs0EjhQ',
#    'alias': 'san-carlo-cicchetti-london-2',
#    'name': 'San Carlo Cicchetti',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8blt2grhJcB35GAyYuJWvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/san-carlo-cicchetti-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 120,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5095021385658,
#     'longitude': -0.135087305946757},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '215 Piccadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 9HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['215 Piccadilly', 'London W1J 9HL', 'United Kingdom']},
#    'phone': '+442074949435',
#    'display_phone': '+44 20 7494 9435',
#    'distance': 375.49624382101644},
#   {'id': 'K8pUeTDTqEPXsu2QwDXAdw',
#    'alias': 'snog-london-13',
#    'name': 'Snog',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xR-j9TNrIj-e3RCpgRH13w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/snog-london-13?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5122694, 'longitude': -0.1338435},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9 Brewer Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0RG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Brewer Street',
#      'Soho',
#      'London W1F 0RG',
#      'United Kingdom']},
#    'phone': '+442030341555',
#    'display_phone': '+44 20 3034 1555',
#    'distance': 159.15309982558432},
#   {'id': 'miaBUi97a2kSIBUNv_VQVw',
#    'alias': 'the-mitre-london-2',
#    'name': 'The Mitre',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7EwIuV7tWGYWMTjMF8C0Bw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mitre-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5123634074761,
#     'longitude': -0.17837760220187},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '24 Craven Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3QH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Craven Terrace',
#      'London W2 3QH',
#      'United Kingdom']},
#    'phone': '+442072625240',
#    'display_phone': '+44 20 7262 5240',
#    'distance': 2936.1105110844214},
#   {'id': 'hq695SY9qohYxX5a324thw',
#    'alias': 'katsute-100-london',
#    'name': 'Katsute 100',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XaQ6_4KnqWBiJUu8Hdus1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/katsute-100-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5344633, 'longitude': -0.104346},
#    'transactions': [],
#    'location': {'address1': 'Camden Passage',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N1 8EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Camden Passage', 'London N1 8EA', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3250.5528023046013},
#   {'id': 'bVSdbV-LXvyxik6F7u4KXQ',
#    'alias': 'the-marquis-cornwallis-london',
#    'name': 'The Marquis Cornwallis',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SqLJnn7h2JwLUj5yAHLpaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-marquis-cornwallis-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 105,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.524567356394,
#     'longitude': -0.12502513122867},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '31 Marchmont Street',
#     'address2': 'Bloomsbury',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 1AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['31 Marchmont Street',
#      'Bloomsbury',
#      'London WC1N 1AP',
#      'United Kingdom']},
#    'phone': '+442072788355',
#    'display_phone': '+44 20 7278 8355',
#    'distance': 1507.9068513918212},
#   {'id': 'x-nXIF0rvxYwRkGuPFYvYg',
#    'alias': 'vq-chelsea-london',
#    'name': 'VQ Chelsea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/usuS1inD6IB7T_INy8gURA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vq-chelsea-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.48637, 'longitude': -0.180185},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '325 Fulham Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW10 9QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['325 Fulham Road',
#      'London SW10 9QL',
#      'United Kingdom']},
#    'phone': '+442073767224',
#    'display_phone': '+44 20 7376 7224',
#    'distance': 4246.594198585887},
#   {'id': 'XiD1SlM1mgi0Tm_dwmmQLQ',
#    'alias': 'emiles-restaurant-london',
#    'name': "Emile's Restaurant",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/97nqnpFbEaHeuzs2bAgO3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/emiles-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4660759, 'longitude': -0.2197662},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '96 Felsham Road',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW15 1DQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['96 Felsham Road',
#      'London SW15 1DQ',
#      'United Kingdom']},
#    'phone': '+442087893323',
#    'display_phone': '+44 20 8789 3323',
#    'distance': 7791.386460343904},
#   {'id': '5pCi06GRXx8l6G5bzmfGcg',
#    'alias': 'the-drayton-arms-london',
#    'name': 'The Drayton Arms',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/e9VdC6x0UDb2MOn9aoo2-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-drayton-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.490670343906,
#     'longitude': -0.18321572156801},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '153 Old Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 0LJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['153 Old Brompton Road',
#      'London SW5 0LJ',
#      'United Kingdom']},
#    'phone': '+442078352301',
#    'display_phone': '+44 20 7835 2301',
#    'distance': 4095.7802540390385},
#   {'id': 'cse6Zq5WyXkOxfVjFd5Ftw',
#    'alias': 'original-maids-of-honour-richmond-2',
#    'name': 'Original Maids Of Honour',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VL6482QwkhFwy9t3zegrSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/original-maids-of-honour-richmond-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.480649607176,
#     'longitude': -0.288493910450711},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '288 Kew Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': 'TW9 3DU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['288 Kew Road', 'Richmond TW9 3DU', 'United Kingdom']},
#    'phone': '+442089402752',
#    'display_phone': '+44 20 8940 2752',
#    'distance': 11149.510856546958},
#   {'id': 'JaveZcrYNz-Pq0UIjgWJCA',
#    'alias': 'egg-break-london',
#    'name': 'Egg Break',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FcjERvhFTXfYHIPi6uvQbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/egg-break-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 80,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.50832, 'longitude': -0.198022},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '30 Uxbridge Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 7TA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Uxbridge Street',
#      'London W8 7TA',
#      'United Kingdom']},
#    'phone': '+442035358300',
#    'display_phone': '+44 20 3535 8300',
#    'distance': 4312.433159863853},
#   {'id': 'qF2RobL-4k6IYnS6hpqEyA',
#    'alias': 'poppies-london-5',
#    'name': 'Poppies',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/n246LLC0nd6XjVjPNtT_YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/poppies-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 342,
#    'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5202629, 'longitude': -0.074075},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6-8 Hanbury Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6QR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6-8 Hanbury Street',
#      'London E1 6QR',
#      'United Kingdom']},
#    'phone': '+442072470892',
#    'display_phone': '+44 20 7247 0892',
#    'distance': 4360.779510525656},
#   {'id': '8ZUHGbZjVqK61KturAB0eg',
#    'alias': 'the-flask-london-3',
#    'name': 'The Flask',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HPgAi-PO5qUA3CvAGRABtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-flask-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.569881303877,
#     'longitude': -0.15093969430275},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '77 Highgate West Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N6 6BU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['77 Highgate West Hill',
#      'London N6 6BU',
#      'United Kingdom']},
#    'phone': '+442083487346',
#    'display_phone': '+44 20 8348 7346',
#    'distance': 6427.280036303667},
#   {'id': 'h5Tqem-_t98gW86CWXExJg',
#    'alias': 'quality-chop-house-london',
#    'name': 'Quality Chop House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c6lpB9XlwEd7l8RT9DujTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/quality-chop-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5247046, 'longitude': -0.1099494},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '88-94 Farringdon Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 3EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['88-94 Farringdon Road',
#      'London EC1R 3EA',
#      'United Kingdom']},
#    'phone': '+442036028115',
#    'display_phone': '+44 20 3602 8115',
#    'distance': 2233.740636341485},
#   {'id': 'I0sKyehdq3iKZ6GI5K5Gag',
#    'alias': 'caffé-concerto-london-8',
#    'name': 'Caffé Concerto',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/p8x4ybyEIPwQUQT8ep8X5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caff%C3%A9-concerto-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.509699, 'longitude': -0.136678},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '79-81 Regent Street',
#     'address2': 'Piccadilly',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 4EG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['79-81 Regent Street',
#      'Piccadilly',
#      'London W1B 4EG',
#      'United Kingdom']},
#    'phone': '+442074390090',
#    'display_phone': '+44 20 7439 0090',
#    'distance': 345.7304354390102},
#   {'id': 'MuB1SAHJkKGauEA2_2QuMw',
#    'alias': 'donostia-social-club-london-2',
#    'name': 'Donostia Social Club',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZB4R5KKbrJ-BZA5ENcjrig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/donostia-social-club-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'basque', 'title': 'Basque'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4634215902681,
#     'longitude': -0.112375015123689},
#    'transactions': [],
#    'location': {'address1': '49 Brixton Station Road',
#     'address2': 'Pop Brixton',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 8PQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Brixton Station Road',
#      'Pop Brixton',
#      'London SW9 8PQ',
#      'United Kingdom']},
#    'phone': '+447961844464',
#    'display_phone': '+44 7961 844464',
#    'distance': 5732.017427688565},
#   {'id': 'ruccgDIBllsprKlP_7HBpg',
#    'alias': 'the-easton-london',
#    'name': 'The Easton',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/00hZ8dwgUCTRmptcXSYfWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-easton-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.526323227476,
#     'longitude': -0.11139933433552},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Easton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1X 0DS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Easton Street',
#      'London WC1X 0DS',
#      'United Kingdom']},
#    'phone': '+442072787608',
#    'display_phone': '+44 20 7278 7608',
#    'distance': 2266.3090043333623},
#   {'id': 'LQSWyUJZg4g4GZHgN6RedA',
#    'alias': 'caffè-vergnano-1882-london-4',
#    'name': 'Caffè Vergnano 1882',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kUMaFHx9TQQf2_c0Kl6Skw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caff%C3%A8-vergnano-1882-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.505776, 'longitude': -0.116837},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Belvedere Road',
#     'address2': 'Southbank Centre Festival Terrace',
#     'address3': 'London',
#     'city': 'London',
#     'zip_code': 'SE1 8XX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Belvedere Road',
#      'Southbank Centre Festival Terrace',
#      'London',
#      'London SE1 8XX',
#      'United Kingdom']},
#    'phone': '+442079219339',
#    'display_phone': '+44 20 7921 9339',
#    'distance': 1574.723397566967},
#   {'id': 'f2ALhozSWXHal8b4uoSAhQ',
#    'alias': 'hipchips-london',
#    'name': 'Hipchips',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t3Suwa3xq6KS8EWUx-DJ5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hipchips-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'gourmet', 'title': 'Specialty Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51266662, 'longitude': -0.13235341},
#    'transactions': [],
#    'location': {'address1': '49 Old Compton st',
#     'address2': '',
#     'address3': 'Soho',
#     'city': 'London',
#     'zip_code': 'W1D 6HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Old Compton st',
#      'Soho',
#      'London W1D 6HL',
#      'United Kingdom']},
#    'phone': '+442072873114',
#    'display_phone': '+44 20 7287 3114',
#    'distance': 249.99626340142058},
#   {'id': 'HFLN8SrGHXT2k7CHpfPi8Q',
#    'alias': 'the-washington-london',
#    'name': 'The Washington',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-PhGvPsHpAv8ggEgR_3oSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-washington-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.545668644739,
#     'longitude': -0.16284509911221},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "50 England's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 4EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["50 England's Lane",
#      'London NW3 4EU',
#      'United Kingdom']},
#    'phone': '+442077228842',
#    'display_phone': '+44 20 7722 8842',
#    'distance': 4097.415532879192},
#   {'id': '71c0m1n_NH3V81qTBdonGw',
#    'alias': 'fire-station-london',
#    'name': 'Fire Station',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Yzyk05mxugd5z5eFXCg8AQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fire-station-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5025569, 'longitude': -0.1105747},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '150 Waterloo Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['150 Waterloo Road',
#      'London SE1 8SB',
#      'United Kingdom']},
#    'phone': '+442076202226',
#    'display_phone': '+44 20 7620 2226',
#    'distance': 2093.2589523236998},
#   {'id': '1Z-uv6_JuONT0QYcf48PlQ',
#    'alias': 'natural-kitchen-london-2',
#    'name': 'Natural Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oTYQK-3cPQ90QcvAjWiF1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/natural-kitchen-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5109071, 'longitude': -0.0782531},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '7 Pepys Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3N 4AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Pepys Street',
#      'London EC3N 4AF',
#      'United Kingdom']},
#    'phone': '+442077024038',
#    'display_phone': '+44 20 7702 4038',
#    'distance': 4013.293436140861},
#   {'id': 'zWCUKosTsfZEwExrle-SYQ',
#    'alias': 'lanes-of-london-london',
#    'name': 'Lanes of London',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ATNkMPy7LuIzETaT0BQ-5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lanes-of-london-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5131069, 'longitude': -0.1578938},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '140 Park Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 7AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['140 Park Lane', 'London W1K 7AA', 'United Kingdom']},
#    'phone': '+442076475664',
#    'display_phone': '+44 20 7647 5664',
#    'distance': 1518.4238743633418},
#   {'id': 'Rugom03-YkWplCoxMGdkzw',
#    'alias': 'leinster-arms-london',
#    'name': 'Leinster Arms',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DjUrSZvmbzFOQBEuGR37lw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/leinster-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5116842, 'longitude': -0.1828815},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '17 Leinster Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17 Leinster Terrace',
#      'London W2 3EU',
#      'United Kingdom']},
#    'phone': '+442074024670',
#    'display_phone': '+44 20 7402 4670',
#    'distance': 3248.6833737676093},
#   {'id': 'rWUDw95a8l8TZDarLzZWGQ',
#    'alias': 'the-somers-town-coffee-house-london',
#    'name': 'The Somers Town Coffee House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xAii6LZjUJ4GmWcDQCBTvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-somers-town-coffee-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.529882, 'longitude': -0.130116},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '60 Chalton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 1HS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['60 Chalton Street',
#      'London NW1 1HS',
#      'United Kingdom']},
#    'phone': '+442073877377',
#    'display_phone': '+44 20 7387 7377',
#    'distance': 1944.8628397700331},
#   {'id': '_Lx4blRGVIdvkEpjfR-6VQ',
#    'alias': 'amorino-london',
#    'name': 'Amorino',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GDLghEi0T3nAX2pYgWkY9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amorino-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.513045, 'longitude': -0.132425},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '41 Old Compton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 4DF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41 Old Compton Street',
#      'London W1D 4DF',
#      'United Kingdom']},
#    'phone': '+442074943300',
#    'display_phone': '+44 20 7494 3300',
#    'distance': 245.4424644130785},
#   {'id': 'XSiTrSnaA3H50zaMWjyGOQ',
#    'alias': 'marias-market-café-london-2',
#    'name': "Maria's Market Café",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/U3jRp--YlLRbpPaRaDOgdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marias-market-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.505117, 'longitude': -0.091086},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Borough Market',
#     'address2': '8 Southwark Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Borough Market',
#      '8 Southwark Street',
#      'London SE1 9AA',
#      'United Kingdom']},
#    'phone': '+442074071002',
#    'display_phone': '+44 20 7407 1002',
#    'distance': 3220.2590376650837},
#   {'id': '3pFgmXQlhDPwMCAYtTJoYg',
#    'alias': 'the-northall-london-2',
#    'name': 'The Northall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MG3hnKzj2TXx-ZkV298YOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-northall-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5066782055573,
#     'longitude': -0.124324303556782},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '10a Northumberland Avenue',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2N 5AE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10a Northumberland Avenue',
#      'London WC2N 5AE',
#      'United Kingdom']},
#    'phone': '+442073213100',
#    'display_phone': '+44 20 7321 3100',
#    'distance': 1056.7545506928168},
#   {'id': 'Snr_3I7dSsx3QMUH-xfcnA',
#    'alias': 'the-breakfast-club-london-12',
#    'name': 'The Breakfast Club',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zwu_aWTV0FdyvKouknk-Pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-breakfast-club-london-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 61,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5058390348173,
#     'longitude': -0.0181783917421963},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit CR30',
#     'address2': 'Level Zero',
#     'address3': '1 Crossrail Place',
#     'city': 'London',
#     'zip_code': 'E14 5AR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit CR30',
#      'Level Zero',
#      '1 Crossrail Place',
#      'London E14 5AR',
#      'United Kingdom']},
#    'phone': '+442078719986',
#    'display_phone': '+44 20 7871 9986',
#    'distance': 8187.970876270602}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                   Restaurant             Type Price Rating  \
# 0                The Ledbury  Modern European  ££££    4.5
# 1       Frontline Restaurant          British   £££      4
# 2            Brasserie Zédel       Brasseries    ££      4
# 3             Kitty Fisher's          British  ££££    4.5
# 4  Dominique Ansel Treehouse         Bakeries
#
#               Address        Lat       Lng  \
# 0    127 Ledbury Road  51.516819 -0.200107
# 1    13 Norfolk Place  51.516984 -0.172476
# 2  20 Sherwood Street  51.510603 -0.135576
# 3  10 Shepherd Market  51.506461 -0.146486
# 4    24 Floral Street  51.511905 -0.125405
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/the-ledbury-london?ad...  bEmaFY0A9JwpuxHKJXWx7Q
# 1  https://www.yelp.com/biz/frontline-restaurant-...  F_QagoJLYYRaDvgcvzsbiQ
# 2  https://www.yelp.com/biz/brasserie-z%C3%A9del-...  E43MdoA7zkZ6SnPjAJaTvA
# 3  https://www.yelp.com/biz/kitty-fishers-mayfair...  H8dMsOa3ylJxZjHqkEg9cg
# 4

# %%
#4th set of 50 records 151-200
lndr_params4 = {"term":term,"location":"London","limit":50,"offset":151}
lndr_response4 = requests.get(search_api_url, headers=headers, params=lndr_params4)
lndr4 = lndr_response4.json()
display(lndr4)
#print(lndr_response4.url)
#print(lndr_response4.status_code)
# Out:
# {'businesses': [{'id': 'Snr_3I7dSsx3QMUH-xfcnA',
#    'alias': 'the-breakfast-club-london-12',
#    'name': 'The Breakfast Club',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zwu_aWTV0FdyvKouknk-Pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-breakfast-club-london-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 61,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5058390348173,
#     'longitude': -0.0181783917421963},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit CR30',
#     'address2': 'Level Zero',
#     'address3': '1 Crossrail Place',
#     'city': 'London',
#     'zip_code': 'E14 5AR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit CR30',
#      'Level Zero',
#      '1 Crossrail Place',
#      'London E14 5AR',
#      'United Kingdom']},
#    'phone': '+442078719986',
#    'display_phone': '+44 20 7871 9986',
#    'distance': 8187.970876270602},
#   {'id': 'ep7Q8nZSqQJztyq_JgUGhg',
#    'alias': 'goodman-london-2',
#    'name': 'Goodman',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4RdQ8SdZQiuuges_SaSxUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/goodman-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 106,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5131345, 'longitude': -0.1422486},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '26 Maddox Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 1QH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Maddox Street',
#      'London W1S 1QH',
#      'United Kingdom']},
#    'phone': '+442074993776',
#    'display_phone': '+44 20 7499 3776',
#    'distance': 436.23218569860506},
#   {'id': 'gbZKs7QD7X9ZHNGACy2B9g',
#    'alias': 'brawn-london-2',
#    'name': 'Brawn',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gdMBMbPsKe6lu_mYnhhqxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brawn-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5289277153112,
#     'longitude': -0.0702632793320869},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '49 Columbia Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7RG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Columbia Road',
#      'London E2 7RG',
#      'United Kingdom']},
#    'phone': '+442077295692',
#    'display_phone': '+44 20 7729 5692',
#    'distance': 4884.719992328003},
#   {'id': 'TjNbQnoUTtZchNLhji-XDQ',
#    'alias': 'cafe-plaka-london',
#    'name': 'Cafe Plaka',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/E_O3PaJJa9fQatDOClUyTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-plaka-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5301852, 'longitude': -0.1209572},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "315 Gray's Inn Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1X 8PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["315 Gray's Inn Road",
#      'London WC1X 8PX',
#      'United Kingdom']},
#    'phone': '+442078335823',
#    'display_phone': '+44 20 7833 5823',
#    'distance': 2194.830846634308},
#   {'id': 'S_1iMSbWOa4I7pa8BxWZag',
#    'alias': 'hart-and-lova-london',
#    'name': 'Hart & Lova',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9VIDKCRKfqFstQt53jVA-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hart-and-lova-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5384383, 'longitude': -0.190891},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '213 Belsize Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 4AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['213 Belsize Road',
#      'London NW6 4AA',
#      'United Kingdom']},
#    'phone': '+447882806540',
#    'display_phone': '+44 7882 806540',
#    'distance': 4748.534923920667},
#   {'id': 'cgkDnzaQvP9q-JHXd-ECcA',
#    'alias': 'cambridge-street-london-2',
#    'name': 'Cambridge Street',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FPLn24WdcutHUe8geTYRYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cambridge-street-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4905412, 'longitude': -0.1449144},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Artist Residence',
#     'address2': '52 Cambridge Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 4QQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Artist Residence',
#      '52 Cambridge Street',
#      'London SW1V 4QQ',
#      'United Kingdom']},
#    'phone': '+442032620501',
#    'display_phone': '+44 20 3262 0501',
#    'distance': 2558.1902736900183},
#   {'id': 'JJpZLwZ5Tw8xJT0QLr3ZKA',
#    'alias': 'raffles-london-5',
#    'name': 'Raffles',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/t_m1784CJbkieCi_7CYWCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raffles-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5147449, 'longitude': -0.1768147},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '13 Craven Road',
#     'address2': 'Paddington',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 3BP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Craven Road',
#      'Paddington',
#      'London W2 3BP',
#      'United Kingdom']},
#    'phone': '+442077233159',
#    'display_phone': '+44 20 7723 3159',
#    'distance': 2835.3726499268837},
#   {'id': 'Vzbse5HBdhn71v8az3D7dw',
#    'alias': 'roux-at-parliament-square-london',
#    'name': 'Roux at Parliament Square',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1f4DeEkksX-TRW9NtxtfVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roux-at-parliament-square-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5010029703473, 'longitude': -0.1281716},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '11 Great George Street',
#     'address2': 'Parliament Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 3AD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Great George Street',
#      'Parliament Square',
#      'London SW1P 3AD',
#      'United Kingdom']},
#    'phone': '+442073343737',
#    'display_phone': '+44 20 7334 3737',
#    'distance': 1421.7453007517574},
#   {'id': '4QK1kQOde5RZ6PNTfo7wug',
#    'alias': 'albion-london-5',
#    'name': 'Albion',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5Cs76CZPdDPELbONN2AJHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/albion-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 101,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.524137, 'longitude': -0.076235},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2-4 Boundary Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7DD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2-4 Boundary Street',
#      'London E2 7DD',
#      'United Kingdom']},
#    'phone': '+442077291051',
#    'display_phone': '+44 20 7729 1051',
#    'distance': 4327.903016108891},
#   {'id': 'GG_lpEApTeNIDNzyQv1I0A',
#    'alias': 'the-rum-kitchen-london-2',
#    'name': 'The Rum Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yWnEbf5wc_8UVQDB62Ee4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-rum-kitchen-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 78,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5123393, 'longitude': -0.1387341},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1st Floor Kingly Court',
#     'address2': 'Carnaby Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5PW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1st Floor Kingly Court',
#      'Carnaby Soho',
#      'London W1B 5PW',
#      'United Kingdom']},
#    'phone': '+442079206479',
#    'display_phone': '+44 20 7920 6479',
#    'distance': 200.02220242637392},
#   {'id': 'y3A99Bk8moGq70QMupAvcg',
#    'alias': 'minamoto-kitchoan-london',
#    'name': 'Minamoto Kitchoan',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ym2YQZptqJ0gbpRmt9jcHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/minamoto-kitchoan-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'candy', 'title': 'Candy Stores'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.508814, 'longitude': -0.138055},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '44 Piccadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 0DS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['44 Piccadilly', 'London W1J 0DS', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 472.5051820978047},
#   {'id': '-ATEXu2q4Oe4wPQeyrsILw',
#    'alias': 'princi-london',
#    'name': 'Princi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QLFgoDIBiLx2F0tpUIw7gQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/princi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 304,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5138629586873,
#     'longitude': -0.134387051472991},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '135 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0UT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['135 Wardour Street',
#      'London W1F 0UT',
#      'United Kingdom']},
#    'phone': '+442074788888',
#    'display_phone': '+44 20 7478 8888',
#    'distance': 157.59755401297926},
#   {'id': 'Q6tw8tw0iZUUq9gumhA0nA',
#    'alias': 'park-room-london',
#    'name': 'Park Room',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6VtyTatZ9j7FjoZxckotnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/park-room-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5097307293668,
#     'longitude': -0.155653953552246},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'J W Marriott Hotel - Grosvenor House',
#     'address2': '86-90 Park Lane',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 7TN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['J W Marriott Hotel - Grosvenor House',
#      '86-90 Park Lane',
#      'London W1K 7TN',
#      'United Kingdom']},
#    'phone': '+442073998452',
#    'display_phone': '+44 20 7399 8452',
#    'distance': 1406.2133857848767},
#   {'id': 'vvXYdvtAPnFzOhqrFviwpQ',
#    'alias': 'the-montagu-london-2',
#    'name': 'The Montagu',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IPEfTJ5gFjtYKne-vzIAqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-montagu-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5154357, 'longitude': -0.1569583},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '30 Portman Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7BH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Portman Square',
#      'London W1H 7BH',
#      'United Kingdom']},
#    'phone': '+442072992037',
#    'display_phone': '+44 20 7299 2037',
#    'distance': 1497.0881132274078},
#   {'id': 'EanCLBAeSJNU9MA0pVlHVg',
#    'alias': 'cafe-twelve-london',
#    'name': 'Cafe Twelve',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uAIN5SbTugPIgyu7ljHtjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-twelve-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.528322, 'longitude': -0.075946},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '57 Hackney Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7NX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57 Hackney Rd', 'London E2 7NX', 'United Kingdom']},
#    'phone': '+442077299319',
#    'display_phone': '+44 20 7729 9319',
#    'distance': 4494.95978931185},
#   {'id': 'r-1QpdD11CdP6V9JGX3smQ',
#    'alias': 'the-game-bird-london',
#    'name': 'The Game Bird',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XKHsCVixsjI6LSkbDGlgjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-game-bird-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.505773, 'longitude': -0.140441},
#    'transactions': [],
#    'location': {'address1': "16-18 St James's Place",
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1A',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["16-18 St James's Place",
#      'London SW1A',
#      'United Kingdom']},
#    'phone': '+442074930111',
#    'display_phone': '+44 20 7493 0111',
#    'distance': 844.4352046433678},
#   {'id': 'XYu4Vp_8iT-E04EPFm_TvQ',
#    'alias': 'battersea-pie-london-2',
#    'name': 'Battersea Pie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m8MCmi3WqTXgMQzq6H2f3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/battersea-pie-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5118037902116,
#     'longitude': -0.122687677730959},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Lower Ground Floor',
#     'address2': '28 The Market',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 8RA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Lower Ground Floor',
#      '28 The Market',
#      'London WC2E 8RA',
#      'United Kingdom']},
#    'phone': '+442072409566',
#    'display_phone': '+44 20 7240 9566',
#    'distance': 925.316452073998},
#   {'id': 'm-49WP-2bBX6INAP8o9VoA',
#    'alias': 'scoff-and-banter-tea-rooms-london-3',
#    'name': 'Scoff & Banter Tea Rooms',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2VenHtdTNeHWypgOp4Nw8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scoff-and-banter-tea-rooms-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5146197, 'longitude': -0.1484107},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '350 Oxford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1C 1BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['350 Oxford Street',
#      'London W1C 1BY',
#      'United Kingdom']},
#    'phone': '+442075143456',
#    'display_phone': '+44 20 7514 3456',
#    'distance': 871.743090665736},
#   {'id': '12c1E7u3QentMVuW9-VWnA',
#    'alias': 'bills-london-17',
#    'name': "Bill's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/k_UzLcqf2SPXkqUbVLZOZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bills-london-17?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5007843694555,
#     'longitude': -0.192435744332796},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Kensington Arcade',
#     'address2': '125 High Street Kensington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 5SF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Kensington Arcade',
#      '125 High Street Kensington',
#      'London W8 5SF',
#      'United Kingdom']},
#    'phone': '+442079371482',
#    'display_phone': '+44 20 7937 1482',
#    'distance': 4132.285545014933},
#   {'id': '6pXa7F32SeWoti3ypLYYxg',
#    'alias': 'no-fifty-cheyne-london',
#    'name': 'No. Fifty Cheyne',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/no-fifty-cheyne-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4833536, 'longitude': -0.1697231},
#    'transactions': [],
#    'location': {'address1': '50 Cheyne Walk',
#     'address2': '',
#     'address3': 'Chelsea',
#     'city': 'London',
#     'zip_code': 'SW3 5TS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50 Cheyne Walk',
#      'Chelsea',
#      'London SW3 5TS',
#      'United Kingdom']},
#    'phone': '+442073768787',
#    'display_phone': '+44 20 7376 8787',
#    'distance': 4013.6889996204977},
#   {'id': 'umLQuVzI5h0HbPqipD360w',
#    'alias': 'andrew-edmunds-london',
#    'name': 'Andrew Edmunds',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/A33YIvgc6Ftchke6rzcgTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/andrew-edmunds-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.513155, 'longitude': -0.13614583403546},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '46 Lexington Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['46 Lexington Street',
#      'London W1F 0LP',
#      'United Kingdom']},
#    'phone': '+442074375708',
#    'display_phone': '+44 20 7437 5708',
#    'distance': 37.88004466546301},
#   {'id': 'UPFlyt-ZliNN1lRN_ZpXeg',
#    'alias': 'eatabout-london',
#    'name': 'EatAbout',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XTR_5eupgX0OUVI8osp8WA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eatabout-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'personalchefs', 'title': 'Personal Chefs'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.514965057373,
#     'longitude': -0.14156536757946},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 3AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['London W1B 3AG', 'United Kingdom']},
#    'phone': '+447475898938',
#    'display_phone': '+44 7475 898938',
#    'distance': 457.9375970285052},
#   {'id': 'tYynO1nOy1GKxMV3jkxbmw',
#    'alias': 'the-breakfast-club-london-2',
#    'name': 'The Breakfast Club',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TElKM303HWt3LAkvgBuTWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-breakfast-club-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 497,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514733, 'longitude': -0.135406},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "33 D'Arblay Street",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["33 D'Arblay Street",
#      'London W1F 8EU',
#      'United Kingdom']},
#    'phone': '+442074342571',
#    'display_phone': '+44 20 7434 2571',
#    'distance': 215.73161782407266},
#   {'id': 'mtCWACvspzFT8weCOlRTOg',
#    'alias': 'tramshed-london',
#    'name': 'Tramshed',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fZAJEs_mPceHKw8icoaEkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tramshed-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 116,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.526005638273,
#     'longitude': -0.081622501460487},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '32 Rivington Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 3LX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['32 Rivington Street',
#      'London EC2A 3LX',
#      'United Kingdom']},
#    'phone': '+442077490478',
#    'display_phone': '+44 20 7749 0478',
#    'distance': 4034.534972363923},
#   {'id': 'aTx78zJXF5i0uEeeTpRL3g',
#    'alias': 'daisy-london',
#    'name': 'daisy',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daisy-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5265205398686,
#     'longitude': -0.0996886566281319},
#    'transactions': [],
#    'location': {'address1': '3a Lever St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EC1V 3QU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3a Lever St', 'London EC1V 3QU', 'United Kingdom']},
#    'phone': '+447948756626',
#    'display_phone': '+44 7948 756626',
#    'distance': 2934.685614088162},
#   {'id': 'b2fSo-AJF7QaAHgRslmvxg',
#    'alias': 'union-tavern-london',
#    'name': 'Union Tavern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/O3dnZJxwajCN0lf5xojgMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/union-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5266946, 'longitude': -0.113319},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '52 Lloyd Baker Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1X 9AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['52 Lloyd Baker Street',
#      'London WC1X 9AA',
#      'United Kingdom']},
#    'phone': '+442072780111',
#    'display_phone': '+44 20 7278 0111',
#    'distance': 2188.8206833964377},
#   {'id': 'EAAypM7nV_q8tATyQxo52g',
#    'alias': 'paul-a-young-fine-chocolates-london-4',
#    'name': 'Paul A Young Fine Chocolates',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gfs50LArTfLgTkDpIYezXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-a-young-fine-chocolates-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 85,
#    'categories': [{'alias': 'chocolate', 'title': 'Chocolatiers & Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.535008894911, 'longitude': -0.1039117},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '33 Camden Passage',
#     'address2': 'Islington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['33 Camden Passage',
#      'Islington',
#      'London N1 8EA',
#      'United Kingdom']},
#    'phone': '+442074245750',
#    'display_phone': '+44 20 7424 5750',
#    'distance': 3315.6951650708916},
#   {'id': 'gwbJQ9zdmahbfrHI657UGg',
#    'alias': 'hush-london',
#    'name': 'Hush',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VXIqWecLcu4mhDnG-77l0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hush-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 74,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51271, 'longitude': -0.145634},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '8 Lancashire Court',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 1EY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Lancashire Court',
#      'London W1S 1EY',
#      'United Kingdom']},
#    'phone': '+442076591500',
#    'display_phone': '+44 20 7659 1500',
#    'distance': 694.5058308715747},
#   {'id': 'P3YeWO3ODeWmQVi-IilkAQ',
#    'alias': 'st-john-bar-and-restaurant-london',
#    'name': 'St John Bar and Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8m6whIPf2zLcm6KAhVCsNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-john-bar-and-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 293,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.520481, 'longitude': -0.101486},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '26 St John Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1M 4AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 St John Street',
#      'London EC1M 4AY',
#      'United Kingdom']},
#    'phone': '+442072510848',
#    'display_phone': '+44 20 7251 0848',
#    'distance': 2532.1204734464523},
#   {'id': 'EkxFVH3PM1j7CFW5P5r5mA',
#    'alias': 'caxton-grill-london-2',
#    'name': 'Caxton Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tBFkf79V40imYES66zj-Iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caxton-grill-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.498905, 'longitude': -0.1339093},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '2 Caxton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1H 0QW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Caxton Street',
#      'London SW1H 0QW',
#      'United Kingdom']},
#    'phone': '+442072277777',
#    'display_phone': '+44 20 7227 7777',
#    'distance': 1555.464015258172},
#   {'id': 'fRqzZFS605IyvyFqJ1JHUw',
#    'alias': 'steak-and-co-london-15',
#    'name': 'Steak & Co',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QRDywq_x25XGWv4xG3E3VA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/steak-and-co-london-15?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 109,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5097794728296,
#     'longitude': -0.128617345486412},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3/5 Charing Cross Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 0HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3/5 Charing Cross Road',
#      'London WC2H 0HA',
#      'United Kingdom']},
#    'phone': '+442078398100',
#    'display_phone': '+44 20 7839 8100',
#    'distance': 611.0501842147607},
#   {'id': 'tyxml_JT5NKQPa_ATrajRA',
#    'alias': 'st-barts-brewery-london-2',
#    'name': 'St Barts Brewery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-msPtILBesWPJmycSf1bRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-barts-brewery-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breweries', 'title': 'Breweries'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5189517, 'longitude': -0.1008049},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '66 W Smithfield',
#     'address2': 'EC1A 9DY',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1A 9DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 W Smithfield',
#      'EC1A 9DY',
#      'London EC1A 9DY',
#      'United Kingdom']},
#    'phone': '+442076002705',
#    'display_phone': '+44 20 7600 2705',
#    'distance': 2530.1470504424938},
#   {'id': 'k52l-CiipKPGF4DgIPxwAw',
#    'alias': 'old-compton-brasserie-soho',
#    'name': 'Old Compton Brasserie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hCgouMb4luc_28kSqtvFwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/old-compton-brasserie-soho?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5133623, 'longitude': -0.1311296},
#    'transactions': [],
#    'location': {'address1': '34 - 36 Old Compton Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Soho',
#     'zip_code': 'W1D 4TT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['34 - 36 Old Compton Street',
#      'Soho W1D 4TT',
#      'United Kingdom']},
#    'phone': '+442074342214',
#    'display_phone': '+44 20 7434 2214',
#    'distance': 340.691050201597},
#   {'id': '1klYYFMFbfg54StXS5S1eQ',
#    'alias': 'reform-social-and-grill-london',
#    'name': 'Reform Social and Grill',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4qmJtBVZ4xsGgz9Q9aHV1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/reform-social-and-grill-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5165165, 'longitude': -0.1509735},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '8-14 Mandeville Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 2BE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8-14 Mandeville Place',
#      'London W1U 2BE',
#      'United Kingdom']},
#    'phone': '+442072241624',
#    'display_phone': '+44 20 7224 1624',
#    'distance': 1116.8968673201898},
#   {'id': 'qhbCUUn1CM27dvTPUwvAUA',
#    'alias': 'flat-iron-london-2',
#    'name': 'Flat Iron',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BawTx5b2LdfMVHfFDJUMzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flat-iron-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 381,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51212, 'longitude': -0.1384008},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '17 Beak Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9RW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17 Beak Street',
#      'Soho',
#      'London W1F 9RW',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 186.04344128459593},
#   {'id': 'YjM4oKNwo8MuzHkAdmwiaA',
#    'alias': 'plateau-restaurant-london',
#    'name': 'Plateau Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ziwDXINvPjoX4ojZ8HgOIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/plateau-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5044556493532,
#     'longitude': -0.0166596716095782},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Canada Place',
#     'address2': '4th Floor',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E14 5ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Canada Place',
#      '4th Floor',
#      'London E14 5ER',
#      'United Kingdom']},
#    'phone': '+442077157100',
#    'display_phone': '+44 20 7715 7100',
#    'distance': 8308.57348500271},
#   {'id': 'IXfqW71UvwKzjSg0HsFiFQ',
#    'alias': 'ottolenghi-london-6',
#    'name': 'Ottolenghi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nSI6P0JGdPmlMOd5NVpPpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ottolenghi-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5181446, 'longitude': -0.0771446},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '50 Artillery Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 7LJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50 Artillery Lane',
#      'London E1 7LJ',
#      'United Kingdom']},
#    'phone': '+442072471999',
#    'display_phone': '+44 20 7247 1999',
#    'distance': 4112.162343972592},
#   {'id': 'zJNI06Y2zZQFh9OBSFCdgQ',
#    'alias': 'sketch-london-2',
#    'name': 'Sketch',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pAEJmqSJX1lh_pLuvjbFww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sketch-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 831,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5127614699071,
#     'longitude': -0.14159163911048},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '9 Conduit Street',
#     'address2': 'Mayfair',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 2XG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Conduit Street',
#      'Mayfair',
#      'London W1S 2XG',
#      'United Kingdom']},
#    'phone': '+442076594500',
#    'display_phone': '+44 20 7659 4500',
#    'distance': 390.09161644125044},
#   {'id': 'L54JoFrYqCIVyVFhguaL6w',
#    'alias': 'the-edinboro-castle-london',
#    'name': 'The Edinboro Castle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PP-Mqec7MeJS_XWsJC1FFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-edinboro-castle-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 69,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.536059, 'longitude': -0.14483},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '57 Mornington Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 7RU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57 Mornington Terrace',
#      'London NW1 7RU',
#      'United Kingdom']},
#    'phone': '+442072559651',
#    'display_phone': '+44 20 7255 9651',
#    'distance': 2659.1334869789507},
#   {'id': 'vlq4D26p_143Tj21OF-iMA',
#    'alias': 'dishoom-london-2',
#    'name': 'Dishoom',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8zeazSGXG59wynFrPFcqMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dishoom-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 496,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5245310066818,
#     'longitude': -0.076594190862934},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '7 Boundary Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7JE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Boundary Street',
#      'London E2 7JE',
#      'United Kingdom']},
#    'phone': '+442074209324',
#    'display_phone': '+44 20 7420 9324',
#    'distance': 4308.313256620144},
#   {'id': 'bjDqOmXi_CBDBvEiTd5T1g',
#    'alias': 'siren-london-2',
#    'name': 'Siren',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/u3PpzXByusT4JTrvIILFTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/siren-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4975421046262,
#     'longitude': -0.145524152510348},
#    'transactions': [],
#    'location': {'address1': '15 Beeston Place',
#     'address2': 'The Goring Hotel',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1W 0JW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Beeston Place',
#      'The Goring Hotel',
#      'London SW1W 0JW',
#      'United Kingdom']},
#    'phone': '+442077694485',
#    'display_phone': '+44 20 7769 4485',
#    'distance': 1824.9489610195271},
#   {'id': '36rz4hKUsK3DvXEy69k-Gg',
#    'alias': 'patara-london',
#    'name': 'Patara',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iMe7vQL3QQbTssSq1Q_6rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patara-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 141,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5141961, 'longitude': -0.1307571},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '15 Greek Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 4DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Greek Street',
#      'London W1D 4DP',
#      'United Kingdom']},
#    'phone': '+442074371071',
#    'display_phone': '+44 20 7437 1071',
#    'distance': 390.327702139416},
#   {'id': 'g8-HDSVwGUe0QUxwV4pAjQ',
#    'alias': 'le-pain-quotidien-london-2',
#    'name': 'Le Pain Quotidien',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YjHqkRJQ99ExTyCK1XU9tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-pain-quotidien-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5144366, 'longitude': -0.13916},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18 Great Marlborough Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7HS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Great Marlborough Street',
#      'London W1F 7HS',
#      'United Kingdom']},
#    'phone': '+4420736576948',
#    'display_phone': '+44 20736576948',
#    'distance': 288.1726834096272},
#   {'id': 'MSqfyXS2fdm6H-ywHAV75w',
#    'alias': 'blanchette-london',
#    'name': 'Blanchette',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ow_wpCyVlEGztsuelh3x6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blanchette-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5146869918666,
#     'longitude': -0.136290080845356},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "9 D'Arblay Street",
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8DR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["9 D'Arblay Street",
#      'Soho',
#      'London W1F 8DR',
#      'United Kingdom']},
#    'phone': '+442074398100',
#    'display_phone': '+44 20 7439 8100',
#    'distance': 207.1693242672839},
#   {'id': 'swRWaoYcnQFS6yQ4RMhuhg',
#    'alias': 'blue-door-bistro-london',
#    'name': 'Blue Door Bistro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y7k9CaR3Wok0MpFtMTLlAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-door-bistro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5202164, 'longitude': -0.1257102},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '15 Montague Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 5BJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Montague Street',
#      'London WC1B 5BJ',
#      'United Kingdom']},
#    'phone': '+442076128416',
#    'display_phone': '+44 20 7612 8416',
#    'distance': 1085.0053178608703},
#   {'id': 'KkcJrYaogWg5VvV3-HC_HQ',
#    'alias': 'the-jones-family-project-london-2',
#    'name': 'The Jones Family Project',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eYbuxe9UjQLbaHhpAhJSeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-jones-family-project-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5258201511173,
#     'longitude': -0.0829150037047839},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '78 Great Eastern Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 3JL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['78 Great Eastern Street',
#      'London EC2A 3JL',
#      'United Kingdom']},
#    'phone': '+442077391740',
#    'display_phone': '+44 20 7739 1740',
#    'distance': 3943.7475803070456},
#   {'id': '67pNmBN6AMm-CUhfCTIUmQ',
#    'alias': 'andrews-london-15',
#    'name': "Andrew's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NLGtub9j9A2s6VL6NNiPAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/andrews-london-15?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'restaurants', 'title': 'Restaurants'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5222553, 'longitude': -0.1136202},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '160 Grays Inn Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1X 8ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['160 Grays Inn Rd',
#      'London WC1X 8ED',
#      'United Kingdom']},
#    'phone': '+442078371630',
#    'display_phone': '+44 20 7837 1630',
#    'distance': 1863.3526477669018},
#   {'id': '2SX4bVbFytVii5Px5PH2xQ',
#    'alias': 'de-vine-restaurant-and-coffee-bar-london',
#    'name': 'De Vine Restaurant and Coffee Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZMljylnBUb095DEiKt8jPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/de-vine-restaurant-and-coffee-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5109241386221,
#     'longitude': -0.0755801994950509},
#    'transactions': [],
#    'location': {'address1': '19 Vine Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3N 2PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Vine Street',
#      'London EC3N 2PX',
#      'United Kingdom']},
#    'phone': '+442074889929',
#    'display_phone': '+44 20 7488 9929',
#    'distance': 4183.53612031524},
#   {'id': 'TF4OCTkOkU7ybcI9nUIAiw',
#    'alias': 'corrigans-mayfair-london',
#    'name': "Corrigan's Mayfair",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wmKf9MxaQbkvI9k8lItm2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/corrigans-mayfair-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.509892, 'longitude': -0.155116},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '28 Upper Grosvenor Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 7EH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28 Upper Grosvenor Street',
#      'London W1K 7EH',
#      'United Kingdom']},
#    'phone': '+442074999943',
#    'display_phone': '+44 20 7499 9943',
#    'distance': 1382.1141238835246},
#   {'id': '3y4Dbz-UCI818N94IkidiA',
#    'alias': 'savoy-grill-london-2',
#    'name': 'Savoy Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XU_MnkC0yd5hjfLoX7dL6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/savoy-grill-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 124,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5102197687511,
#     'longitude': -0.120730476398416},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'The Strand',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2R 0EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Strand', 'London WC2R 0EU', 'United Kingdom']},
#    'phone': '+442075921600',
#    'display_phone': '+44 20 7592 1600',
#    'distance': 1093.0459156164534}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#            Restaurant                Type Price Rating              Address  \
# 0  The Breakfast Club  Breakfast & Brunch    ££      4            Unit CR30
# 1             Goodman         Steakhouses   £££    4.5     26 Maddox Street
# 2               Brawn     Modern European   £££    4.5     49 Columbia Road
# 3          Cafe Plaka        Coffee & Tea     £    3.5  315 Gray's Inn Road
# 4         Hart & Lova            Desserts    ££    4.5     213 Belsize Road
#
#          Lat       Lng                                                url  \
# 0  51.505839 -0.018178  https://www.yelp.com/biz/the-breakfast-club-lo...
# 1  51.513134 -0.142249  https://www.yelp.com/biz/goodman-london-2?adju...
# 2  51.528928 -0.070263  https://www.yelp.com/biz/brawn-london-2?adjust...
# 3  51.530185 -0.120957  https://www.yelp.com/biz/cafe-plaka-london?adj...
# 4  51.538438 -0.190891  https://www.yelp.com/biz/hart-and-lova-london?...
#
#                        ID
# 0  Snr_3I7dSsx3QMUH-xfcnA
# 1  ep7Q8nZSqQJztyq_JgUGhg
# 2  gbZKs7QD7X9ZHNGACy2B9g
# 3  TjNbQnoUTtZchNLhji-XDQ
# 4  S_1iMSbWOa4I7pa8BxWZag

# %%
london_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
london_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_restaurants_df = london_restaurants_df[column_order]
london_restaurants_df = london_restaurants_df.sort_values(["Type"], ascending=True)
london_restaurants_df = london_restaurants_df.reset_index(drop=True)
london_restaurants_df
# Out:
#                                 Restaurant                Type Rating Price  \
# 0                                     Paul            Bakeries      4     £
# 1                    St. John Bread & Wine            Bakeries    4.5    ££
# 2                          Brigit's Bakery            Bakeries      4    ££
# 3                Dominique Ansel Treehouse            Bakeries
# 4                        Le Pain Quotidien            Bakeries    3.5    ££
# 5                  GAIL's Bakery - Pimlico            Bakeries
# 6                        Maroush Bakehouse            Bakeries    4.5    ££
# 7                       Plateau Restaurant                Bars    4.5   £££
# 8                           Hubbard & Bell                Bars      4    ££
# 9                             Caxton Grill                Bars      4   £££
# 10                                    Hush                Bars      4   £££
# 11                        No. Fifty Cheyne                Bars
# 12                    Donostia Social Club              Basque
# 13                              Blanchette             Bistros      4   £££
# 14                         Brasserie Zédel          Brasseries      4    ££
# 15            The Ivy Kensington Brasserie          Brasseries      4   £££
# 16                                  Bill's  Breakfast & Brunch      4    ££
# 17                     Balans Soho Society  Breakfast & Brunch      4    ££
# 18                      The Breakfast Club  Breakfast & Brunch      4    ££
# 19                      The Breakfast Club  Breakfast & Brunch      4    ££
# 20                       Le Pain Quotidien  Breakfast & Brunch      4    ££
# 21                      Bird of Smithfield             British      4   £££
# 22                                    Swan             British      4    ££
# 23                          Piebury Corner             British    4.5     £
# 24                          Kitty Fisher's             British    4.5  ££££
# 25            The Winter Garden Restaurant             British    4.5  ££££
# 26                      Corrigan's Mayfair             British      4   £££
# 27                                Grumbles             British      4    ££
# 28                            Granger & Co             British      4    ££
# 29                          Scoff & Banter             British      3   £££
# ..                                     ...                 ...    ...   ...
# 170                              The Mitre                Pubs      4    ££
# 171                             The Albert                Pubs      3    ££
# 172                             The Easton                Pubs    4.5    ££
# 173                      The Prince Arthur                Pubs    3.5    ££
# 174                         The Washington                Pubs    3.5    ££
# 175                           Fire Station                Pubs    3.5    ££
# 176                          Leinster Arms                Pubs      4    ££
# 177                            Newman Arms                Pubs      4    ££
# 178                          Builders Arms                Pubs      4    ££
# 179                           The Windmill                Pubs      4    ££
# 180                             Holly Bush                Pubs      4    ££
# 181                          The Blackbird                Pubs      4    ££
# 182                               Bageriet        Scandinavian    4.5     £
# 183                              Hawksmoor             Seafood    4.5   £££
# 184                                Scott's             Seafood    4.5  ££££
# 185                                  Siren             Seafood
# 186                               Hipchips      Specialty Food
# 187                             Steak & Co         Steakhouses      4    ££
# 188                              Flat Iron         Steakhouses    4.5    ££
# 189                              Hawksmoor         Steakhouses    4.5   £££
# 190                                Goodman         Steakhouses    4.5   £££
# 191  Pleasant Lady Jian Bing Trading Stall      Street Vendors
# 192                            Katsute 100           Tea Rooms
# 193             The St. Ermin's Tea Lounge           Tea Rooms    4.5    ££
# 194                             Palm Court           Tea Rooms      4   £££
# 195               Scoff & Banter Tea Rooms           Tea Rooms    4.5    ££
# 196                                 Patara                Thai      4   £££
# 197                         Andrew Edmunds           Wine Bars    4.5   £££
# 198                   Vinoteca Kings Cross           Wine Bars      4    ££
# 199                           The Northall           Wine Bars    4.5   £££
#
#                          Address        Lat       Lng  \
# 0              122 Brompton Road  51.499068 -0.165140
# 1        94-96 Commercial Street  51.519669 -0.074299
# 2              6-7 Chandos Place  51.510089 -0.124540
# 3               24 Floral Street  51.511905 -0.125405
# 4    18 Great Marlborough Street  51.514437 -0.139160
# 5              26 Churton Street  51.491763 -0.139059
# 6           131 Earls Court Road  51.493320 -0.194478
# 7                   Canada Place  51.504456 -0.016660
# 8           199-206 High Holborn  51.517133 -0.122303
# 9                2 Caxton Street  51.498905 -0.133909
# 10            8 Lancashire Court  51.512710 -0.145634
# 11                50 Cheyne Walk  51.483354 -0.169723
# 12       49 Brixton Station Road  51.463422 -0.112375
# 13             9 D'Arblay Street  51.514687 -0.136290
# 14            20 Sherwood Street  51.510603 -0.135576
# 15     96 Kensington High Street  51.501568 -0.192180
# 16             Kensington Arcade  51.500784 -0.192436
# 17    187 Kensington High Street  51.499983 -0.195664
# 18                     Unit CR30  51.505839 -0.018178
# 19                     Unit CR30  51.505839 -0.018178
# 20            15 Winchester Walk  51.506293 -0.091395
# 21          26 Smithfield Street  51.518382 -0.102604
# 22      Swan Shakespeare's Globe  51.508350 -0.096985
# 23             3 Caledonian Road  51.531140 -0.121196
# 24            10 Shepherd Market  51.506461 -0.146486
# 25           222 Marylebone Road  51.521316 -0.162601
# 26     28 Upper Grosvenor Street  51.509892 -0.155116
# 27             35 Churton Street  51.491129 -0.138853
# 28          175 Westbourne Grove  51.514646 -0.197799
# 29       97 Great Russell Street  51.517972 -0.128050
# ..                           ...        ...       ...
# 170            24 Craven Terrace  51.512363 -0.178378
# 171           52 Victoria Street  51.497705 -0.135515
# 172             22 Easton Street  51.526323 -0.111399
# 173                 Public House  51.544153 -0.065613
# 174            50 England's Lane  51.545669 -0.162845
# 175            150 Waterloo Road  51.502557 -0.110575
# 176          17 Leinster Terrace  51.511684 -0.182882
# 177           23 Rathbone Street  51.518157 -0.135164
# 178     1 Kensington Court Place  51.499430 -0.188299
# 179              6-8 Mill Street  51.512565 -0.142204
# 180               22 Holly Mount  51.557912 -0.179326
# 181            209 Earls Ct Road  51.491780 -0.192110
# 182               24 Rose Street  51.511924 -0.126182
# 183                5A Air Street  51.509707 -0.136161
# 184              20 Mount Street  51.509847 -0.150917
# 185             15 Beeston Place  51.497542 -0.145524
# 186            49 Old Compton st  51.512667 -0.132353
# 187       3/5 Charing Cross Road  51.509779 -0.128617
# 188               17 Beak Street  51.512120 -0.138401
# 189               3 Yeoman's Row  51.497459 -0.166872
# 190             26 Maddox Street  51.513134 -0.142249
# 191              23 Greek Street  51.513621 -0.130578
# 192               Camden Passage  51.534463 -0.104346
# 193              2 Caxton Street  51.499102 -0.134611
# 194            1C Portland Place  51.517861 -0.143805
# 195            350 Oxford Street  51.514620 -0.148411
# 196              15 Greek Street  51.514196 -0.130757
# 197          46 Lexington Street  51.513155 -0.136146
# 198           One Pancras Square  51.532739 -0.124989
# 199    10a Northumberland Avenue  51.506678 -0.124324
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/paul-london-3?adjust_...  DUS7Nz3429d2iv0q-Jky9A
# 1    https://www.yelp.com/biz/st-john-bread-and-win...  m3vdBGC0X94sG_5pglDcjQ
# 2    https://www.yelp.com/biz/brigits-bakery-london...  tH_2560cbjme-hFBFVj8cQ
# 3
# 4    https://www.yelp.com/biz/le-pain-quotidien-lon...  g8-HDSVwGUe0QUxwV4pAjQ
# 5
# 6    https://www.yelp.com/biz/maroush-bakehouse-lon...  Da8ClETsPknyD-XIam-jbg
# 7    https://www.yelp.com/biz/plateau-restaurant-lo...  YjM4oKNwo8MuzHkAdmwiaA
# 8    https://www.yelp.com/biz/hubbard-and-bell-lond...  O-DmIhZUQUdeGjT4UCZdFw
# 9    https://www.yelp.com/biz/caxton-grill-london-2...  EkxFVH3PM1j7CFW5P5r5mA
# 10   https://www.yelp.com/biz/hush-london?adjust_cr...  gwbJQ9zdmahbfrHI657UGg
# 11
# 12
# 13   https://www.yelp.com/biz/blanchette-london?adj...  MSqfyXS2fdm6H-ywHAV75w
# 14   https://www.yelp.com/biz/brasserie-z%C3%A9del-...  E43MdoA7zkZ6SnPjAJaTvA
# 15   https://www.yelp.com/biz/the-ivy-kensington-br...  wCjU2KuTntCZDCZSIS1Uxw
# 16   https://www.yelp.com/biz/bills-london-17?adjus...  12c1E7u3QentMVuW9-VWnA
# 17   https://www.yelp.com/biz/balans-soho-society-l...  OLXUZqx6doQtdeHfyEoyOw
# 18   https://www.yelp.com/biz/the-breakfast-club-lo...  Snr_3I7dSsx3QMUH-xfcnA
# 19   https://www.yelp.com/biz/the-breakfast-club-lo...  Snr_3I7dSsx3QMUH-xfcnA
# 20   https://www.yelp.com/biz/le-pain-quotidien-lon...  K69_hmLhHHkXnjHxGayQVQ
# 21   https://www.yelp.com/biz/bird-of-smithfield-lo...  6T4edfBlwPy7pSW7f1KhMg
# 22   https://www.yelp.com/biz/swan-bankside?adjust_...  K0lmqEgpNz97FausJUyn1A
# 23   https://www.yelp.com/biz/piebury-corner-london...  fHIKopvPKVG0IJ7cHy3Zow
# 24   https://www.yelp.com/biz/kitty-fishers-mayfair...  H8dMsOa3ylJxZjHqkEg9cg
# 25   https://www.yelp.com/biz/the-winter-garden-res...  xmqDJi8wGKhvl9DCmegThQ
# 26   https://www.yelp.com/biz/corrigans-mayfair-lon...  TF4OCTkOkU7ybcI9nUIAiw
# 27   https://www.yelp.com/biz/grumbles-london?adjus...  5sEiM_Xw5jXbMhloNqSgYQ
# 28   https://www.yelp.com/biz/granger-and-co-london...  0r2-fwgLvuOLef0epiFkFQ
# 29   https://www.yelp.com/biz/scoff-and-banter-lond...  p-mix89L-TLe6qVu1yk03g
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/the-mitre-london-2?ad...  miaBUi97a2kSIBUNv_VQVw
# 171  https://www.yelp.com/biz/the-albert-london-3?a...  Hau6XfpZTKv_H07WUgCF2w
# 172  https://www.yelp.com/biz/the-easton-london?adj...  ruccgDIBllsprKlP_7HBpg
# 173  https://www.yelp.com/biz/the-prince-arthur-lon...  lhxbsnG4XURYcUVoZgaO5w
# 174  https://www.yelp.com/biz/the-washington-london...  HFLN8SrGHXT2k7CHpfPi8Q
# 175  https://www.yelp.com/biz/fire-station-london?a...  71c0m1n_NH3V81qTBdonGw
# 176  https://www.yelp.com/biz/leinster-arms-london?...  Rugom03-YkWplCoxMGdkzw
# 177  https://www.yelp.com/biz/newman-arms-london?ad...  ScvTVomXz-WmNjrnjNLH4g
# 178  https://www.yelp.com/biz/builders-arms-london?...  b7RW2pHBLX1gpSKCrIm4AQ
# 179  https://www.yelp.com/biz/the-windmill-london-2...  t-LjuFbYp76ARX7QEp0gnA
# 180  https://www.yelp.com/biz/holly-bush-london?adj...  y__iD3k2p4Xm0Xl_tSSNZg
# 181  https://www.yelp.com/biz/the-blackbird-london?...  dXEPhJmyV9BiA77wdAfEmg
# 182  https://www.yelp.com/biz/bageriet-london?adjus...  0tJs57Xoq75-RDWKVco0nw
# 183  https://www.yelp.com/biz/hawksmoor-london-13?a...  N7VEVrHgwcm4-Aj4neD79g
# 184  https://www.yelp.com/biz/scotts-london-4?adjus...  lMhErBByefchffCCf5fUjQ
# 185
# 186
# 187  https://www.yelp.com/biz/steak-and-co-london-1...  fRqzZFS605IyvyFqJ1JHUw
# 188  https://www.yelp.com/biz/flat-iron-london-2?ad...  qhbCUUn1CM27dvTPUwvAUA
# 189  https://www.yelp.com/biz/hawksmoor-london-14?a...  lHxwh10PUmcXIzUp5wAiEg
# 190  https://www.yelp.com/biz/goodman-london-2?adju...  ep7Q8nZSqQJztyq_JgUGhg
# 191
# 192
# 193  https://www.yelp.com/biz/the-st-ermins-tea-lou...  wdPCcml663tzNsnBWArE0g
# 194  https://www.yelp.com/biz/palm-court-london?adj...  1pUEGW91riUIux0TZWw_4g
# 195  https://www.yelp.com/biz/scoff-and-banter-tea-...  m-49WP-2bBX6INAP8o9VoA
# 196  https://www.yelp.com/biz/patara-london?adjust_...  36rz4hKUsK3DvXEy69k-Gg
# 197  https://www.yelp.com/biz/andrew-edmunds-london...  umLQuVzI5h0HbPqipD360w
# 198  https://www.yelp.com/biz/vinoteca-kings-cross-...  9K-A7wHxB-z3n5h-P_mYFA
# 199  https://www.yelp.com/biz/the-northall-london-2...  3pFgmXQlhDPwMCAYtTJoYg
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
london_restaurants_df.to_csv('Resources/London_Restaurants_Pudding.csv')
