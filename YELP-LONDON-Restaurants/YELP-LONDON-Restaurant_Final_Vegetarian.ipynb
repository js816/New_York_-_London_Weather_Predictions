# %% [markdown]
# LONDON RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
term = "vegetarian"

# %%
#First set of 50 records 0-50
lndr_params1 = {"term":term,"location":"London","limit":50,"offset":0}
lndr_response1 = requests.get(search_api_url, headers=headers, params=lndr_params1)
lndr1 = lndr_response1.json()
display(lndr1)
#print(lndr_response1.url)
#print(lndr_response1.status_code)
# Out:
# {'businesses': [{'id': '9jlhFqBRxlvdtDqfeCciEA',
#    'alias': 'the-veggie-table-london',
#    'name': 'The Veggie Table',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_QOS6oipwSPX8eFDEEy1kw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-veggie-table-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.505092, 'longitude': -0.090092},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '8 Southwark Street',
#     'address2': 'Borough Market',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1TL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Southwark Street',
#      'Borough Market',
#      'London SE1 1TL',
#      'United Kingdom']},
#    'phone': '+442034174542',
#    'display_phone': '+44 20 3417 4542',
#    'distance': 3220.2590376652647},
#   {'id': 'bXo_3uLhacyeGJ0iF743PQ',
#    'alias': 'mildreds-london',
#    'name': 'Mildreds',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3tO7I9umlO0hbSp29-q7wA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mildreds-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 280,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5130233764648,
#     'longitude': -0.136484995484352},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '45 Lexington Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9AN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Lexington Street',
#      'London W1F 9AN',
#      'United Kingdom']},
#    'phone': '+442074941634',
#    'display_phone': '+44 20 7494 1634',
#    'distance': 37.57987441984523},
#   {'id': 'rLjRU-MRorU36kc2Xq0zSQ',
#    'alias': 'squirrel-london',
#    'name': 'Squirrel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/t3Q9HiQzvEKyL2r41AVk2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/squirrel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4939502, 'longitude': -0.1755847},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '11 Harrington Road',
#     'address2': 'South Kensington',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW7 3ES',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Harrington Road',
#      'South Kensington',
#      'London SW7 3ES',
#      'United Kingdom']},
#    'phone': '+442070950377',
#    'display_phone': '+44 20 7095 0377',
#    'distance': 3470.279936351604},
#   {'id': 'SjFzSPW6nyZ1lD73lFJT6g',
#    'alias': 'the-gate-london-17',
#    'name': 'The Gate',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UW4hbJLJOuLnVbCQB_SPkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-gate-london-17?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5337, 'longitude': -0.16934},
#    'transactions': [],
#    'location': {'address1': '87 Allitsen Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 7AS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['87 Allitsen Road',
#      'London NW8 7AS',
#      'United Kingdom']},
#    'phone': '+442078330401',
#    'display_phone': '+44 20 7833 0401',
#    'distance': 3278.28118880223},
#   {'id': 'DnBY9gukSdy42EoJtBhdaQ',
#    'alias': 'tibits-london-3',
#    'name': 'Tibits',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zP-qObQgPFOzh6GlckF9Yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tibits-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 159,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511302947998,
#     'longitude': -0.139624997973442},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '12-14 Heddon Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 4DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12-14 Heddon Street',
#      'London W1B 4DA',
#      'United Kingdom']},
#    'phone': '+442077456146',
#    'display_phone': '+44 20 7745 6146',
#    'distance': 276.51513726465686},
#   {'id': 'bRACQuON_142mYHqaifaGQ',
#    'alias': 'koshari-street-london',
#    'name': 'Koshari Street',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yL_Fufu1gnpmxTQk-suDvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/koshari-street-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5109410206983,
#     'longitude': -0.126831103538283},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "56 St Martin's Ln",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["56 St Martin's Ln",
#      'London WC2N 4EA',
#      'United Kingdom']},
#    'phone': '+442078361056',
#    'display_phone': '+44 20 7836 1056',
#    'distance': 665.6631678254904},
#   {'id': '1_nby6Ob2JH8kaOvVdk7_Q',
#    'alias': 'wild-food-cafe-london',
#    'name': 'Wild Food Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lniBoSvg2agWhmLnlBqBBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wild-food-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 78,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5144749136901,
#     'longitude': -0.126376003026962},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1st Floor',
#     'address2': '14 Neals Yard',
#     'address3': 'Covent Garden',
#     'city': 'London',
#     'zip_code': 'WC2H 9DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1st Floor',
#      '14 Neals Yard',
#      'Covent Garden',
#      'London WC2H 9DP',
#      'United Kingdom']},
#    'phone': '+442074192014',
#    'display_phone': '+44 20 7419 2014',
#    'distance': 687.526283780164},
#   {'id': 'oK_SLmmAVQg3meguh7LrIA',
#    'alias': 'dishoom-london',
#    'name': 'Dishoom',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4HC2FmxHZYzxqlqiRaeKCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dishoom-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1856,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512447030091, 'longitude': -0.1269579217873},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "12 Upper Saint Martin's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9FB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["12 Upper Saint Martin's Lane",
#      'London WC2H 9FB',
#      'United Kingdom']},
#    'phone': '+442074209320',
#    'display_phone': '+44 20 7420 9320',
#    'distance': 624.1612863605939},
#   {'id': '5u3SgBbNRJAPfzzffLD42w',
#    'alias': 'ethos-london-4',
#    'name': 'Ethos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QNIq0j9wOfzt8QMkdt86bQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ethos-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51638, 'longitude': -0.1390968},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '48 Eastcastle Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 8DX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['48 Eastcastle Street',
#      'London W1W 8DX',
#      'United Kingdom']},
#    'phone': '+442035811538',
#    'display_phone': '+44 20 3581 1538',
#    'distance': 450.0866218060961},
#   {'id': 'sR_XQYWwLiF5Lkj8-Cu-RA',
#    'alias': 'persepolis-london',
#    'name': 'Persepolis',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r8wkxaqNDWk9lgCZRaTPww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/persepolis-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'persian', 'title': 'Persian/Iranian'},
#     {'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4733916, 'longitude': -0.0722307},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '28-30 Peckham High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE15 5DT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28-30 Peckham High Street',
#      'London SE15 5DT',
#      'United Kingdom']},
#    'phone': '+442076398007',
#    'display_phone': '+44 20 7639 8007',
#    'distance': 6246.625984287883},
#   {'id': 'ZTSM33QFv3pwxtSJp8Y02g',
#    'alias': 'farmacy-london',
#    'name': 'Farmacy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/38AZr06tSZ3IU2zDxBb7zQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/farmacy-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 67,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.515446, 'longitude': -0.1926381},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '74 Westbourne Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 5SH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['74 Westbourne Grove',
#      'London W2 5SH',
#      'United Kingdom']},
#    'phone': '+442072210705',
#    'display_phone': '+44 20 7221 0705',
#    'distance': 3938.117967873019},
#   {'id': '2C9EoktEUIMwfzj71n26ag',
#    'alias': 'mildreds-london-2',
#    'name': 'Mildreds',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HIZnoXUywoGsF4mk1r0kPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mildreds-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.54048, 'longitude': -0.144592},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9 Jamestown Road',
#     'address2': 'Camden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 7BW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Jamestown Road',
#      'Camden',
#      'London NW1 7BW',
#      'United Kingdom']},
#    'phone': '+442074824200',
#    'display_phone': '+44 20 7482 4200',
#    'distance': 3124.750543558349},
#   {'id': 'X_ENdT2USAG_X8bs83ijYg',
#    'alias': 'rudys-dirty-vegan-diner-london',
#    'name': "Rudy's Dirty Vegan Diner",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tyRXAIAUGdF78lybwH3TbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rudys-dirty-vegan-diner-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5424003308146,
#     'longitude': -0.14850796110578},
#    'transactions': [],
#    'location': {'address1': 'Chalk Farm Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW1',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Chalk Farm Rd', 'London NW1', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3400.199930263857},
#   {'id': 'pGKetrSI0kyG6yxlII2n6g',
#    'alias': 'wild-food-cafe-islington-london',
#    'name': 'Wild Food Cafe - Islington',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tF-Ji7Gg6a6FvytReVg9Dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wild-food-cafe-islington-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'raw_food', 'title': 'Live/Raw Food'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5426596, 'longitude': -0.102888},
#    'transactions': [],
#    'location': {'address1': '269 - 270 Upper Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N1 2UQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['269 - 270 Upper Street',
#      'London N1 2UQ',
#      'United Kingdom']},
#    'phone': '+442080363990',
#    'display_phone': '+44 20 8036 3990',
#    'distance': 4033.721787573521},
#   {'id': 'R4yaSL1PT2mpt5yNX2U7AA',
#    'alias': '222-veggie-vegan-london',
#    'name': '222 Veggie Vegan',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YZSzXRtKqSrmi7Jw0wTcSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/222-veggie-vegan-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.486007, 'longitude': -0.2030859},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '222 North End Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W14 9NU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['222 North End Road',
#      'London W14 9NU',
#      'United Kingdom']},
#    'phone': '+442073812322',
#    'display_phone': '+44 20 7381 2322',
#    'distance': 5523.137045506117},
#   {'id': '6Qqb-xU4ERH4nsHWKtthLg',
#    'alias': 'wulf-and-lamb-london',
#    'name': 'Wulf and lamb',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QYF2ACiXWDqcVRLQIkfVzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wulf-and-lamb-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4939041, 'longitude': -0.1586825},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '243 Pavilion Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1X 0BP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['243 Pavilion Road',
#      'London SW1X 0BP',
#      'United Kingdom']},
#    'phone': '+442039485999',
#    'display_phone': '+44 20 3948 5999',
#    'distance': 2659.1803841820383},
#   {'id': 'WT5EjZGp4gn9BNnzTlC2Ww',
#    'alias': 'ottolenghi-islington',
#    'name': 'Ottolenghi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y0eBCsgaeswDaLcF0m-iLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ottolenghi-islington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 212,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5397542479056,
#     'longitude': -0.102216303348541},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '287 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 2TZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['287 Upper Street',
#      'London N1 2TZ',
#      'United Kingdom']},
#    'phone': '+442072881454',
#    'display_phone': '+44 20 7288 1454',
#    'distance': 3795.717274260169},
#   {'id': 'KzYd2EaFvmu63wqTIektSA',
#    'alias': 'padella-london-3',
#    'name': 'Padella',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Z6ujE4hSjT6DrejptE9PQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/padella-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 211,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5051451, 'longitude': -0.0899515},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 Southwark Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1TQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Southwark Street',
#      'London SE1 1TQ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3297.287249700157},
#   {'id': 'RsitHVcTNdEx7G-xNJCcag',
#    'alias': 'comptoir-libanais-london-11',
#    'name': 'Comptoir Libanais',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JRUJQqBAyQC_FM1j2mWDIQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/comptoir-libanais-london-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'lebanese', 'title': 'Lebanese'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5140237, 'longitude': -0.1368746},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '52 Poland Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7NQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['52 Poland Street',
#      'London W1F 7NQ',
#      'United Kingdom']},
#    'phone': '+442074344335',
#    'display_phone': '+44 20 7434 4335',
#    'distance': 157.0520039360506},
#   {'id': 'lWIaUMCpSkJHaODE0JgN8g',
#    'alias': 'café-forty-one-london',
#    'name': 'Café Forty One',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/U9ob-SQZTn3iddtp1rpRIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-forty-one-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512652, 'longitude': -0.1867779},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '41-51 Inverness Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3JN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41-51 Inverness Terrace',
#      'London W2 3JN',
#      'United Kingdom']},
#    'phone': '+442073138484',
#    'display_phone': '+44 20 7313 8484',
#    'distance': 3517.0003433800193},
#   {'id': '3KY3-PR4JG-aZe8A7fhuNA',
#    'alias': 'tibits-london-7',
#    'name': 'Tibits',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/auwunf3Uc-VOpsbekyUaYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tibits-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.506317, 'longitude': -0.101547},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '124 Southwark Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 0SW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['124 Southwark Street',
#      'London SE1 0SW',
#      'United Kingdom']},
#    'phone': '+442072028370',
#    'display_phone': '+44 20 7202 8370',
#    'distance': 2489.160174665022},
#   {'id': '5I-8tJ2LdKPpGkGR2y4NMw',
#    'alias': 'the-gate-londres-2',
#    'name': 'The Gate',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YYh9LKAI8HwnBiqI8oQaCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-gate-londres-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5151328683862,
#     'longitude': -0.161105208098888},
#    'transactions': [],
#    'location': {'address1': '22-24 Seymour Place',
#     'address2': '',
#     'address3': None,
#     'city': 'Londres',
#     'zip_code': 'W1H 7NL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22-24 Seymour Place',
#      'Londres W1H 7NL',
#      'United Kingdom']},
#    'phone': '+442078330401',
#    'display_phone': '+44 20 7833 0401',
#    'distance': 1758.965423328204},
#   {'id': 'Pxk-sgmoU8nZLIT-OWDpkA',
#    'alias': 'delhiwala-restaurant-and-sweet-centre-hounslow',
#    'name': 'Delhiwala Restaurant & Sweet Centre',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vnzRi4kDrVOHWIoxKxdIqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/delhiwala-restaurant-and-sweet-centre-hounslow?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4774752, 'longitude': -0.3838098},
#    'transactions': [],
#    'location': {'address1': '72 Vicarage Farm Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Hounslow',
#     'zip_code': 'TW5 0AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['72 Vicarage Farm Road',
#      'Hounslow TW5 0AB',
#      'United Kingdom']},
#    'phone': '+442085729303',
#    'display_phone': '+44 20 8572 9303',
#    'distance': 17605.587127612285},
#   {'id': 'h7I2R6d3x1yVYDj0PVhZaw',
#    'alias': 'the-good-life-eatery-london',
#    'name': 'The Good Life Eatery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bcMuQ58Jmb82smec88_YEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-good-life-eatery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4919548, 'longitude': -0.1653394},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '59 Sloane Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 3DH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['59 Sloane Avenue',
#      'London SW3 3DH',
#      'United Kingdom']},
#    'phone': '+442070529388',
#    'display_phone': '+44 20 7052 9388',
#    'distance': 3086.6446536335807},
#   {'id': 'WS6uwqv5LnVjeSh-7Z6F1A',
#    'alias': 'amitas-vegetarian-london',
#    'name': 'Amitas Vegetarian',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bWRd9LHF90KPZbA_AVg3vA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amitas-vegetarian-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5429446, 'longitude': 0.032271},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '126 Green Street',
#     'address2': 'Forest Gate',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E7 8JQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['126 Green Street',
#      'Forest Gate',
#      'London E7 8JQ',
#      'United Kingdom']},
#    'phone': '+442084721839',
#    'display_phone': '+44 20 8472 1839',
#    'distance': 12109.605401024766},
#   {'id': 'rH505Aa2ptYdU_K1NIkMzA',
#    'alias': 'vantra-london-2',
#    'name': 'Vantra',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Fb_JhaI1vLwFJR0dBb34Qw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vantra-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5107003, 'longitude': -0.1340457},
#    'transactions': [],
#    'location': {'address1': '5 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Wardour Street',
#      'London W1D 6PD',
#      'United Kingdom']},
#    'phone': '+442072875222',
#    'display_phone': '+44 20 7287 5222',
#    'distance': 271.74178744912734},
#   {'id': 'eekflLQwzpeZ9sNg89F38A',
#    'alias': 'jakobs-london',
#    'name': 'Jakobs',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/m797XQr64brTgRK7TdrqPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jakobs-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.49905885109, 'longitude': -0.18382193239086},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Gloucester Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 4RB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Gloucester Road',
#      'London SW7 4RB',
#      'United Kingdom']},
#    'phone': '+442075819292',
#    'display_phone': '+44 20 7581 9292',
#    'distance': 3649.913506628403},
#   {'id': 'AMfqUC9oYC0xc55MaXbvAA',
#    'alias': 'nopi-london',
#    'name': 'NOPI',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Gu5NZ13wiFuOMxMrMJh5Dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nopi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 271,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511617, 'longitude': -0.1385226},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '21-22 Warwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21-22 Warwick Street',
#      'London W1B 5NE',
#      'United Kingdom']},
#    'phone': '+442074949584',
#    'display_phone': '+44 20 7494 9584',
#    'distance': 223.40454126752283},
#   {'id': 'aX0nQBilAGDtVNWQMRUqqg',
#    'alias': 'the-gate-london-8',
#    'name': 'The Gate',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WugrEy4QGNymvuvhSZhmqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-gate-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 66,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.49025, 'longitude': -0.22544},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '51 Queen Caroline Street',
#     'address2': 'Hammersmith',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W6 9QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Queen Caroline Street',
#      'Hammersmith',
#      'London W6 9QL',
#      'United Kingdom']},
#    'phone': '+442078330401',
#    'display_phone': '+44 20 7833 0401',
#    'distance': 6686.635738244803},
#   {'id': 'elEmETsx5rVcCeIg7a2yXw',
#    'alias': 'the-canary-london-2',
#    'name': 'The Canary',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/62Sse6SvHpFsXL2RMh2UYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-canary-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5294906, 'longitude': -0.0609225},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '61-63 Old Bethnal Green Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 6QA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61-63 Old Bethnal Green Road',
#      'London E2 6QA',
#      'United Kingdom']},
#    'phone': '+442082578170',
#    'display_phone': '+44 20 8257 8170',
#    'distance': 5524.301304843762},
#   {'id': 'k-qIxL_IHDlXxlgDpNkN7Q',
#    'alias': 'ez-and-moss-london',
#    'name': 'EZ & Moss',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ItZEzaXsRlQSbo3-dg0ztg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ez-and-moss-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5501848, 'longitude': -0.1092206},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '183 Holloway Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N7 8LX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['183 Holloway Road',
#      'London N7 8LX',
#      'United Kingdom']},
#    'phone': '+442076199523',
#    'display_phone': '+44 20 7619 9523',
#    'distance': 4546.191125147666},
#   {'id': 'ymPZZiFP14gjuqvlsd2Dhg',
#    'alias': 'katakata-london',
#    'name': 'Katakata',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SMZ_Tr78eUJ89pjcsehGxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/katakata-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'creperies', 'title': 'Creperies'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4527259737879,
#     'longitude': -0.121387057006359},
#    'transactions': [],
#    'location': {'address1': '132 Brixton Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW2 1RS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['132 Brixton Hill',
#      'London SW2 1RS',
#      'United Kingdom']},
#    'phone': '+442034901160',
#    'display_phone': '+44 20 3490 1160',
#    'distance': 6759.575280620765},
#   {'id': 'PCP32dk4euUG21mX0kp5aw',
#    'alias': 'govindas-restaurant-london-2',
#    'name': "Govinda's Restaurant",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3DtFy8xYSRPJ7nMU6WYDTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/govindas-restaurant-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 88,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515878, 'longitude': -0.132808},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '10 Soho Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 3DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Soho Street', 'London W1D 3DL', 'United Kingdom']},
#    'phone': '+442036870617',
#    'display_phone': '+44 20 3687 0617',
#    'distance': 398.3851888532987},
#   {'id': 'uHEGftH6JSPt4T9Dv7lKCg',
#    'alias': 'woodlands-london',
#    'name': 'Woodlands',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/f1UgZuRMZyQvgrkU9LlYnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/woodlands-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5180611, 'longitude': -0.151165},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '77 Marylebone Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 2PS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['77 Marylebone Lane',
#      'London W1U 2PS',
#      'United Kingdom']},
#    'phone': '+442074863862',
#    'display_phone': '+44 20 7486 3862',
#    'distance': 1202.1791172554251},
#   {'id': 'EFWXqJKZQMce40TfwPwkag',
#    'alias': 'thakers-hounslow',
#    'name': 'Thakers',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/j4fB8vrEshEWesZAia3uNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thakers-hounslow?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'soulfood', 'title': 'Soul Food'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4695549086117,
#     'longitude': -0.361086806626014},
#    'transactions': [],
#    'location': {'address1': '162a High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Hounslow',
#     'zip_code': 'TW3 1BQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['162a High Street',
#      'Hounslow TW3 1BQ',
#      'United Kingdom']},
#    'phone': '+442085776130',
#    'display_phone': '+44 20 8577 6130',
#    'distance': 16312.719892015875},
#   {'id': 'z3xc2E24kl-kWjEG3Gi_3w',
#    'alias': 'my-village-café-london-2',
#    'name': 'My Village Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DQYfigk2_-_qIBTjw7c84g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-village-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5427549, 'longitude': -0.1476913},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '37 Chalk Farm Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['37 Chalk Farm Road',
#      'London NW1 8AJ',
#      'United Kingdom']},
#    'phone': '+442034892293',
#    'display_phone': '+44 20 3489 2293',
#    'distance': 3447.810731279882},
#   {'id': 'C7TB4RqD69KIj8NpclF-xA',
#    'alias': 'natural-kitchen-london-3',
#    'name': 'Natural Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/g7nqb8dURJtRbqQumpLB0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/natural-kitchen-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'delis', 'title': 'Delis'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.520971, 'longitude': -0.152275},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '77-78 Marylebone High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 5JX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['77-78 Marylebone High Street',
#      'London W1U 5JX',
#      'United Kingdom']},
#    'phone': '+442074868065',
#    'display_phone': '+44 20 7486 8065',
#    'distance': 1439.2980824498075},
#   {'id': 'LqF2CjyQu0__v1ySNWJG8Q',
#    'alias': 'cook-daily-london-2',
#    'name': 'Cook Daily',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fHNDP9KtOhlQleMWA9heqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cook-daily-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5378951454733,
#     'longitude': -0.0584027543663979},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Arch 358',
#     'address2': 'Westgate Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 3RN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Arch 358',
#      'Westgate Street',
#      'London E8 3RN',
#      'United Kingdom']},
#    'phone': '+447498563168',
#    'display_phone': '+44 7498 563168',
#    'distance': 6045.712719012184},
#   {'id': '4ibHPLYd299_m1LOdcqxXw',
#    'alias': 'savoir-faire-london',
#    'name': 'Savoir Faire',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kn-I1Rc8bpafCu5zweqS_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/savoir-faire-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 191,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5171949, 'longitude': -0.1260125},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '42 New Oxford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1A 1EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 New Oxford Street',
#      'London WC1A 1EP',
#      'United Kingdom']},
#    'phone': '+442074360707',
#    'display_phone': '+44 20 7436 0707',
#    'distance': 852.4529863641968},
#   {'id': 'TGOBwzRyz0NOm_Pk8b6F3Q',
#    'alias': 'by-chloe-covent-garden-london',
#    'name': 'by CHLOE. Covent Garden',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rbwa7TDT-XlPczeCKSYRGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/by-chloe-covent-garden-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51353, 'longitude': -0.12051},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Drury House',
#     'address2': '34-43 Russell Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 8BE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Drury House',
#      '34-43 Russell Street',
#      'London WC2E 8BE',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1081.3976391153726},
#   {'id': 'E1i7l8_bh3yiRjNkJpPSwg',
#    'alias': 'vijays-chawalla-london-2',
#    'name': "Vijay's Chawalla",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/k1SRRFGYx7ervdMrYZa-iA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vijays-chawalla-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5387, 'longitude': 0.0332554},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '268-270 Green Street',
#     'address2': 'Forest Gate',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E7 8LF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['268-270 Green Street',
#      'Forest Gate',
#      'London E7 8LF',
#      'United Kingdom']},
#    'phone': '+442084703535',
#    'display_phone': '+44 20 8470 3535',
#    'distance': 12054.351873079491},
#   {'id': '9-77tm8TPVH76HPMgYvhGA',
#    'alias': 'pilpel-london-2',
#    'name': 'Pilpel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yWmlr7GDQsv91vA1E0hUMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pilpel-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5152326005808,
#     'longitude': -0.0989198684692383},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 5',
#     'address2': "Queen's Head Passage",
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4M 7DZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 5',
#      "Queen's Head Passage",
#      'London EC4M 7DZ',
#      'United Kingdom']},
#    'phone': '+442072489281',
#    'display_phone': '+44 20 7248 9281',
#    'distance': 2576.6761766586287},
#   {'id': 'TZtCNJvOJYhijB-bynwprw',
#    'alias': 'gopal-s-corner-london',
#    'name': 'Gopal’s Corner',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vl2Q2zPAv992RnxX-r2RNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gopal-s-corner-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'malaysian', 'title': 'Malaysian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4963598, 'longitude': -0.1443307},
#    'transactions': [],
#    'location': {'address1': 'Market Halls Victoria - 1st Floor',
#     'address2': '191 Victoria Street',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1E 5NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Market Halls Victoria - 1st Floor',
#      '191 Victoria Street',
#      'London SW1E 5NE',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1920.1685901533385},
#   {'id': 'a4FkZ2b7Wn3-AP7q3ptHtQ',
#    'alias': 'duck-and-waffle-local-london',
#    'name': 'Duck & Waffle Local',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zd2VBLt5bwlnlLFVP1VIWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duck-and-waffle-local-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 141,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'waffles', 'title': 'Waffles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5094175706263,
#     'longitude': -0.132749820495633},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '52 Haymarket',
#     'address2': "St James's Market",
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 4RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['52 Haymarket',
#      "St James's Market",
#      'London SW1Y 4RP',
#      'United Kingdom']},
#    'phone': '+442039004444',
#    'display_phone': '+44 20 3900 4444',
#    'distance': 440.07809948825326},
#   {'id': '-DiKePIk80wOVAxVnj_kZw',
#    'alias': 'redemption-london-3',
#    'name': 'Redemption',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8BKXjn1dX_WKjDtYmA6HDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/redemption-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5155772, 'longitude': -0.195027},
#    'transactions': [],
#    'location': {'address1': '6 Chepstow Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 5BH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Chepstow Road', 'London W2 5BH', 'United Kingdom']},
#    'phone': '+442073139041',
#    'display_phone': '+44 20 7313 9041',
#    'distance': 4098.137349896123},
#   {'id': '2Kdbq8L0P0Qhpk8ql1D7IQ',
#    'alias': 'temple-of-seitan-london-2',
#    'name': 'Temple of Seitan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6eWyRRtj83TLeWRLFGH2GQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/temple-of-seitan-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.537883, 'longitude': -0.130586},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '103 Camley St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N1C 4PF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['103 Camley St', 'London N1C 4PF', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2809.8158412988614},
#   {'id': 'p77CnjTGOIZA1hEpLfCC6Q',
#    'alias': 'kennington-lane-cafe-london',
#    'name': 'Kennington Lane Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4pjtT4PSUYl_0_BqOTx6Cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kennington-lane-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4860611, 'longitude': -0.1208514},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '383 Kennington Lane',
#     'address2': 'Vauxhall',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE11 5QY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['383 Kennington Lane',
#      'Vauxhall',
#      'London SE11 5QY',
#      'United Kingdom']},
#    'phone': '+442077355853',
#    'display_phone': '+44 20 7735 5853',
#    'distance': 3147.932368103276},
#   {'id': 'xKhxUFGjQCayQbYaJ9UBfg',
#    'alias': 'the-gate-london-18',
#    'name': 'The Gate',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lYvB7Eid9P4QQWzcpUMhzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-gate-london-18?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 62,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5301667, 'longitude': -0.1051527},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '370 St John Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 4NN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['370 St John Street',
#      'London EC1V 4NN',
#      'United Kingdom']},
#    'phone': '+442078330401',
#    'display_phone': '+44 20 7833 0401',
#    'distance': 2869.219830668549},
#   {'id': '5rGACVUL-kFwJt0LMgHRBA',
#    'alias': 'bonnington-café-london-2',
#    'name': 'Bonnington Café',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iOPQu-EX203NNPJSrTmptQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bonnington-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4846229, 'longitude': -0.1200278},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '11 Vauxhall Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW8 1TD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Vauxhall Grove',
#      'London SW8 1TD',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3319.1729868415487},
#   {'id': 'mPsQju_OFdYtj2wjxzVIGQ',
#    'alias': 'taste-of-cochin-london',
#    'name': 'Taste Of Cochin',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9PeEXQPSvEOV9tRShBz5eQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taste-of-cochin-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.409352, 'longitude': -0.227088},
#    'transactions': [],
#    'location': {'address1': '9 Approach Road',
#     'address2': 'Raynes Park',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW20 8BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Approach Road',
#      'Raynes Park',
#      'London SW20 8BA',
#      'United Kingdom']},
#    'phone': '+442033559111',
#    'display_phone': '+44 20 3355 9111',
#    'distance': 13125.108699271888}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#          Restaurant        Type Price Rating              Address        Lat  \
# 0  The Veggie Table       Vegan     £    4.5   8 Southwark Street  51.505092
# 1          Mildreds       Vegan    ££      4  45 Lexington Street  51.513023
# 2          Squirrel  Vegetarian     £      4   11 Harrington Road  51.493950
# 3          The Gate  Vegetarian                  87 Allitsen Road  51.533700
# 4            Tibits  Vegetarian    ££      4  12-14 Heddon Street  51.511303
#
#         Lng                                                url  \
# 0 -0.090092  https://www.yelp.com/biz/the-veggie-table-lond...
# 1 -0.136485  https://www.yelp.com/biz/mildreds-london?adjus...
# 2 -0.175585  https://www.yelp.com/biz/squirrel-london?adjus...
# 3 -0.169340
# 4 -0.139625  https://www.yelp.com/biz/tibits-london-3?adjus...
#
#                        ID
# 0  9jlhFqBRxlvdtDqfeCciEA
# 1  bXo_3uLhacyeGJ0iF743PQ
# 2  rLjRU-MRorU36kc2Xq0zSQ
# 3
# 4  DnBY9gukSdy42EoJtBhdaQ

# %%
#2nd set of 50 records 51-100 
lndr_params2 = {"term":term,"location":"London","limit":50,"offset":51}
lndr_response2 = requests.get(search_api_url, headers=headers, params=lndr_params2)
lndr2 = lndr_response2.json()
display(lndr2)
#print(lndr_response2.url)
#print(lndr_response2.status_code)
# Out:
# {'businesses': [{'id': 'HzyhCXPooUGWvuPYOfT0WA',
#    'alias': 'vanilla-black-london',
#    'name': 'Vanilla Black',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iFcVNZ-zr5gaYxDg5_J85w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vanilla-black-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 52,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.517175605475,
#     'longitude': -0.11102477345447},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "17-18 Took's Court",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4A 1LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["17-18 Took's Court",
#      'London EC4A 1LB',
#      'United Kingdom']},
#    'phone': '+442072422622',
#    'display_phone': '+44 20 7242 2622',
#    'distance': 1791.3966816793013},
#   {'id': 'w3gHIiTFqUs68ecxO941GA',
#    'alias': 'negril-london',
#    'name': 'Negril',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Mt5P4A71U_5IVa1DrFforQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/negril-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4527575, 'longitude': -0.1213855},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '132 Brixton Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW2 1RS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['132 Brixton Hill',
#      'London SW2 1RS',
#      'United Kingdom']},
#    'phone': '+442086748798',
#    'display_phone': '+44 20 8674 8798',
#    'distance': 6757.086301937479},
#   {'id': '5tAAwu7ZDhulLsyt09bXnw',
#    'alias': 'maggie-joness-london-2',
#    'name': "Maggie Jones's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6THUfVyJ2jNScpV6BAY6rg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maggie-joness-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 119,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.502856014927, 'longitude': -0.1909916674772},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '6 Old Court Place',
#     'address2': 'Kensington Church Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4PL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Old Court Place',
#      'Kensington Church Street',
#      'London W8 4PL',
#      'United Kingdom']},
#    'phone': '+442079376462',
#    'display_phone': '+44 20 7937 6462',
#    'distance': 3967.2973141903262},
#   {'id': 'VovLxnCCWutZhE9NnSD9NA',
#    'alias': 'bunbunbun-vietnamese-food-london-2',
#    'name': 'BunBunBun Vietnamese Food',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/riE1uXKiC3yWckzh-sHHXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bunbunbun-vietnamese-food-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5317879, 'longitude': -0.0768315},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '134B Kingsland Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 8DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['134B Kingsland Road',
#      'London E2 8DY',
#      'United Kingdom']},
#    'phone': '+442077296494',
#    'display_phone': '+44 20 7729 6494',
#    'distance': 4551.352743608464},
#   {'id': 'ak9Ru7VnzKh0jz53kMadOg',
#    'alias': 'wholefood-heaven-london',
#    'name': 'Wholefood Heaven',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6MppNef1fBLFKsCTy5eQ_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wholefood-heaven-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.545258, 'longitude': -0.140778},
#    'transactions': [],
#    'location': {'address1': 'Whitecross Street Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 9JL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Whitecross Street Market',
#      'London NW1 9JL',
#      'United Kingdom']},
#    'phone': '+442072094988',
#    'display_phone': '+44 20 7209 4988',
#    'distance': 3619.4292516189744},
#   {'id': 'Cv0-Mwcp1nXkSE4ZcnaN2Q',
#    'alias': 'leggero-london',
#    'name': 'Leggero',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lLqdn37ZegSkDnms2Q8zUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/leggero-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5126756608556,
#     'longitude': -0.132752752549664},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '64 Old Compton Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 4UQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['64 Old Compton Street',
#      'London W1D 4UQ',
#      'United Kingdom']},
#    'phone': '+442074343617',
#    'display_phone': '+44 20 7434 3617',
#    'distance': 222.36648959142138},
#   {'id': 'kC_nkOqLsECRYImd2G9hNw',
#    'alias': 'vasantha-vilas-london',
#    'name': 'Vasantha Vilas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/coRlgp6Vn6VoySHzFSeScg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vasantha-vilas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5397163935504,
#     'longitude': 0.0511657680534654},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '206 High Street North',
#     'address2': 'East Ham',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E6 2JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['206 High Street North',
#      'East Ham',
#      'London E6 2JA',
#      'United Kingdom']},
#    'phone': '+442084758986',
#    'display_phone': '+44 20 8475 8986',
#    'distance': 13285.754027134835},
#   {'id': 'RFyH1Qiv06LYHrwqzLkVXg',
#    'alias': 'roti-chai-london-2',
#    'name': 'Roti Chai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/W1UTlapyo3or5E0-7Q1Z7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roti-chai-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 295,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'kebab', 'title': 'Kebab'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5146226, 'longitude': -0.1557135},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3 Portman Mews South',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 6AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Portman Mews South',
#      'London W1H 6AY',
#      'United Kingdom']},
#    'phone': '+442074080101',
#    'display_phone': '+44 20 7408 0101',
#    'distance': 1381.5881838127664},
#   {'id': 'tSRsSKlk4cKWD7Pc7aJihQ',
#    'alias': 'grand-bazaar-london',
#    'name': 'Grand Bazaar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/l2MVdp0cA1Muen1cqCKbdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grand-bazaar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5154866, 'longitude': -0.1506015},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '42 James Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 1EX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 James Street',
#      'London W1U 1EX',
#      'United Kingdom']},
#    'phone': '+442072241544',
#    'display_phone': '+44 20 7224 1544',
#    'distance': 1054.1613836254885},
#   {'id': '7-KtpNmkFBSPd4r6MhVzDA',
#    'alias': 'mildreds-london-3',
#    'name': 'Mildreds',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1UrH0BVa0XffEel5EaMyPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mildreds-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5313571869762,
#     'longitude': -0.117220487906411},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '200 Pentonville Road',
#     'address2': 'Kings Cross',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9JP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['200 Pentonville Road',
#      'Kings Cross',
#      'London N1 9JP',
#      'United Kingdom']},
#    'phone': '+442072789422',
#    'display_phone': '+44 20 7278 9422',
#    'distance': 2433.4800942962415},
#   {'id': 'SuOm8qiv8MPAqj71PBI9bg',
#    'alias': 'shoryu-ramen-london',
#    'name': 'Shoryu Ramen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Der98FjcLCUpcfnw0qtbvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shoryu-ramen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 375,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.508494856125,
#     'longitude': -0.13381448629492},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9 Regent Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 4LR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Regent Street',
#      'London SW1Y 4LR',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 504.895989252289},
#   {'id': 'vmi7fEu1vy2Tj2yuYlgR0g',
#    'alias': 'kazan-london',
#    'name': 'Kazan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RFFFQinUIs2XBQOL0ycung/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kazan-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 112,
#    'categories': [{'alias': 'turkish', 'title': 'Turkish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4927, 'longitude': -0.14072},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '93-94 Wilton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1DW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['93-94 Wilton Road',
#      'London SW1V 1DW',
#      'United Kingdom']},
#    'phone': '+442072337100',
#    'display_phone': '+44 20 7233 7100',
#    'distance': 2264.258035381997},
#   {'id': 'zEXaCL6ccmH8NKwSCheeOQ',
#    'alias': 'the-full-nelson-london',
#    'name': 'The Full Nelson',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HsbYBnvp8DH0SdefYUbmpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-full-nelson-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4746705408659,
#     'longitude': -0.025293231010437},
#    'transactions': [],
#    'location': {'address1': '47 Deptford Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE8 4PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Deptford Broadway',
#      'London SE8 4PH',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8758.007622160958},
#   {'id': 'jRi5sU-9m9F_WxeN7ElBxg',
#    'alias': 'dosa-world-london',
#    'name': 'Dosa World',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xCmGr2yOmyoAAm1fseHHcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dosa-world-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5201988220215,
#     'longitude': -0.0706939995288849},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '46 Hanbury Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 5JL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['46 Hanbury Street',
#      'London E1 5JL',
#      'United Kingdom']},
#    'phone': '+442073770344',
#    'display_phone': '+44 20 7377 0344',
#    'distance': 4589.435133742581},
#   {'id': 'y__iD3k2p4Xm0Xl_tSSNZg',
#    'alias': 'holly-bush-london',
#    'name': 'Holly Bush',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/A1ESayCy7xj7xcE0p_1Pew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holly-bush-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5579124, 'longitude': -0.1793261},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Holly Mount',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 6SG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Holly Mount', 'London NW3 6SG', 'United Kingdom']},
#    'phone': '+442074352892',
#    'display_phone': '+44 20 7435 2892',
#    'distance': 5836.476390811221},
#   {'id': 'g7EiFuJHGQ14UlbRbP7mTg',
#    'alias': 'the-vegetarians-paradise-london',
#    'name': 'The Vegetarians Paradise',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/p2n61lSUqFGbg13LhCG1pw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-vegetarians-paradise-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.525005, 'longitude': -0.125415},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '59 Marchmont Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 1AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['59 Marchmont Street',
#      'London WC1N 1AP',
#      'United Kingdom']},
#    'phone': '+442072786881',
#    'display_phone': '+44 20 7278 6881',
#    'distance': 1536.668256508674},
#   {'id': 'X7BOyI5AXb0TnitGaJ7Ysg',
#    'alias': 'mon-plaisir-clevedon',
#    'name': 'Mon Plaisir',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LUSWjtuvlhfkciT8yxRLMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mon-plaisir-clevedon?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.514506, 'longitude': -0.126767},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '32-34 Hill Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Clevedon',
#     'zip_code': 'BS21 7PH',
#     'country': 'GB',
#     'state': 'NSM',
#     'display_address': ['32-34 Hill Road',
#      'Clevedon BS21 7PH',
#      'United Kingdom']},
#    'phone': '+441275872307',
#    'display_phone': '+44 1275 872307',
#    'distance': 662.4374288531014},
#   {'id': 'iLiT7cJhOrQzi6DUoxG6kg',
#    'alias': 'fitz-fine-food-london',
#    'name': 'Fitz Fine Food',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JNPUH9in6Un4OyWrnoqH8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fitz-fine-food-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'herbsandspices', 'title': 'Herbs & Spices'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5050392, 'longitude': -0.09079},
#    'transactions': [],
#    'location': {'address1': 'Borough Market',
#     'address2': 'Stoney Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1TL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Borough Market',
#      'Stoney Street',
#      'London SE1 1TL',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3203.2260884478283},
#   {'id': 'CEPduoos73caV6mfrtxH-A',
#    'alias': 'dou-dou-london',
#    'name': 'Dou Dou',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dou-dou-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5396299521655, 'longitude': -0.1422534},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Camden Town',
#     'address2': '6 Kentish Town Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 9NX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Camden Town',
#      '6 Kentish Town Road',
#      'London NW1 9NX',
#      'United Kingdom']},
#    'phone': '+447850663328',
#    'display_phone': '+44 7850 663328',
#    'distance': 3011.0865309614323},
#   {'id': 'B6ayHXLwfYBuIADficAeMg',
#    'alias': 'caravan-kings-cross-london',
#    'name': 'Caravan Kings Cross',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/N3qh0kXJvNLcjPEP9EEZGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caravan-kings-cross-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 170,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5357788239146,
#     'longitude': -0.125370576153865},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Granary Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Granary Square',
#      'London N1C 4AA',
#      'United Kingdom']},
#    'phone': '+442071017661',
#    'display_phone': '+44 20 7101 7661',
#    'distance': 2654.2035388419845},
#   {'id': 'mc1KLbA1Sy4kUTKo0ZEeRQ',
#    'alias': 'dishoom-london-7',
#    'name': 'Dishoom',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9ok9Iflq--Oxs2w3dbcF9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dishoom-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 553,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.513087, 'longitude': -0.139767},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Kingly Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5QP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Kingly Street',
#      'London W1B 5QP',
#      'United Kingdom']},
#    'phone': '+442074209322',
#    'display_phone': '+44 20 7420 9322',
#    'distance': 265.21527226714676},
#   {'id': 'vCF8ut7OZcfA4hEmhngfSQ',
#    'alias': 'andina-london',
#    'name': 'Andina',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sgBZI-KCVdW5u838gGQW6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/andina-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 142,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5243208695971,
#     'longitude': -0.077134990126122},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Redchurch Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7DJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Redchurch Street',
#      'London E2 7DJ',
#      'United Kingdom']},
#    'phone': '+442079206499',
#    'display_phone': '+44 20 7920 6499',
#    'distance': 4265.6096504626785},
#   {'id': 'IXfqW71UvwKzjSg0HsFiFQ',
#    'alias': 'ottolenghi-london-6',
#    'name': 'Ottolenghi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nSI6P0JGdPmlMOd5NVpPpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ottolenghi-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5181446, 'longitude': -0.0771446},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '50 Artillery Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 7LJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50 Artillery Lane',
#      'London E1 7LJ',
#      'United Kingdom']},
#    'phone': '+442072471999',
#    'display_phone': '+44 20 7247 1999',
#    'distance': 4112.162343972592},
#   {'id': 'Ame6cZG8I-DQ5tkMtdyyeg',
#    'alias': 'good-earth-london-2',
#    'name': 'Good Earth',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cpLh8fy-R13IaCVYaOcS3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/good-earth-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4968451, 'longitude': -0.1684174},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '233 Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 2EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['233 Brompton Road',
#      'London SW3 2EP',
#      'United Kingdom']},
#    'phone': '+442075843658',
#    'display_phone': '+44 20 7584 3658',
#    'distance': 2865.586287158154},
#   {'id': 'D_K05_8gB6Mm8vf8q2VHzQ',
#    'alias': 'love-gift-vegan-london',
#    'name': 'Love Gift Vegan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/K-qXN4Vzf829AFWiI-ev5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/love-gift-vegan-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4569312, 'longitude': 0.0090325},
#    'transactions': [],
#    'location': {'address1': '386 Lee High Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE12 8RW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['386 Lee High Rd',
#      'London SE12 8RW',
#      'United Kingdom']},
#    'phone': '+447958308397',
#    'display_phone': '+44 7958 308397',
#    'distance': 11808.175889949416},
#   {'id': 'u2T6ZhYb_gNCgNvq_1uJtA',
#    'alias': 'itadaki-zen-london',
#    'name': 'Itadaki Zen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FwN9ADXQkJ48Sbysry_UeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/itadaki-zen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5296729, 'longitude': -0.116012},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "139 King's Cross Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1X 9BJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["139 King's Cross Road",
#      'London WC1X 9BJ',
#      'United Kingdom']},
#    'phone': '+442072783573',
#    'display_phone': '+44 20 7278 3573',
#    'distance': 2330.0383450050026},
#   {'id': 'O4ctkL-NSlNSD-m3ikDllQ',
#    'alias': 'taste-of-siam-london',
#    'name': 'Taste Of Siam',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Uh9qOnfoFzL5r0vmE3bH7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taste-of-siam-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5356196, 'longitude': -0.1397889},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '45 Camden High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 7JH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Camden High Street',
#      'London NW1 7JH',
#      'United Kingdom']},
#    'phone': '+442073800665',
#    'display_phone': '+44 20 7380 0665',
#    'distance': 2547.3123506327875},
#   {'id': 'IQpsCaCYOAZkKAJRcA-24Q',
#    'alias': 'jusu-brothers-london',
#    'name': 'Jusu Brothers',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qkifmhPA8so5lXo5-rRXtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jusu-brothers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5147605, 'longitude': -0.1960694},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '147-149 Westbourne Grove',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2RS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['147-149 Westbourne Grove',
#      'London W11 2RS',
#      'United Kingdom']},
#    'phone': '+442038028805',
#    'display_phone': '+44 20 3802 8805',
#    'distance': 4173.611679665257},
#   {'id': 'hQauSZTzq-qhmSN9yIwhhw',
#    'alias': 'jai-shri-krishna-london',
#    'name': 'Jai Shri Krishna',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9ocBIRrmONgV_EPQwpcDbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jai-shri-krishna-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.590213, 'longitude': -0.104382},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '',
#     'address2': '10 Turnpike Lane',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N8 0PT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Turnpike Lane',
#      'London N8 0PT',
#      'United Kingdom']},
#    'phone': '+442088887200',
#    'display_phone': '+44 20 8888 7200',
#    'distance': 8873.323210176004},
#   {'id': 'NCj4ufnnu9iJuJVy_15nxw',
#    'alias': 'niche-london-5',
#    'name': 'Niche',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QiV8fpqNY26Tbd4y-IE8lw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/niche-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5299391920297,
#     'longitude': -0.105478788954883},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '197-199 Rosebery Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 4TJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['197-199 Rosebery Avenue',
#      'London EC1R 4TJ',
#      'United Kingdom']},
#    'phone': '+442078375048',
#    'display_phone': '+44 20 7837 5048',
#    'distance': 2839.605686346751},
#   {'id': 'u7aTmKXmc8trRrpRav6kCg',
#    'alias': 'essential-vegan-cafe-london',
#    'name': 'Essential Vegan Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8TqOEkWe3nzqufoosoVQxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/essential-vegan-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.52629, 'longitude': -0.07746},
#    'transactions': [],
#    'location': {'address1': '6 Calvert Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E2 7JP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Calvert Ave', 'London E2 7JP', 'United Kingdom']},
#    'phone': '+442077393628',
#    'display_phone': '+44 20 7739 3628',
#    'distance': 4316.255473038654},
#   {'id': 'hGiblm0l67sLGTtsMvx51A',
#    'alias': 'the-churchill-arms-london',
#    'name': 'The Churchill Arms',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6gBKxDzV9D3Ehmavvg7mYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-churchill-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 358,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5068261, 'longitude': -0.194781},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '119 Kensington Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 7LN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['119 Kensington Church Street',
#      'London W8 7LN',
#      'United Kingdom']},
#    'phone': '+442077274242',
#    'display_phone': '+44 20 7727 4242',
#    'distance': 4125.33167965603},
#   {'id': 'n_HexdowAUaDBNZ8qWFykg',
#    'alias': 'curled-leaf-london',
#    'name': 'Curled Leaf',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/curled-leaf-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5515376226734,
#     'longitude': -0.19876798784018},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '98 Mill Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 1NF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['98 Mill Lane', 'London NW6 1NF', 'United Kingdom']},
#    'phone': '+442077946296',
#    'display_phone': '+44 20 7794 6296',
#    'distance': 6115.33028657133},
#   {'id': 'LYPuCoeoYpRpMcvFfwK3wQ',
#    'alias': 'farmstand-london-3',
#    'name': 'Farmstand',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IC8LsiHvAb5kgNsIVteqjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/farmstand-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5143394470215,
#     'longitude': -0.122018814086914},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '42 Drury Lane',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 Drury Lane',
#      'Covent Garden',
#      'London WC2B 5AJ',
#      'United Kingdom']},
#    'phone': '+442072403866',
#    'display_phone': '+44 20 7240 3866',
#    'distance': 986.9717381016312},
#   {'id': '6iCxFP7Oc0qG_6ByenO0sw',
#    'alias': 'silk-road-london-2',
#    'name': 'Silk Road',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SnpsB1Bj1F79jzXcctOuRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/silk-road-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4739712, 'longitude': -0.0896081},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '49 Camberwell Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE5 8TR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Camberwell Church Street',
#      'London SE5 8TR',
#      'United Kingdom']},
#    'phone': '+442077034832',
#    'display_phone': '+44 20 7703 4832',
#    'distance': 5400.477008947773},
#   {'id': 'iRGargcTLAdpZwwYv0D90A',
#    'alias': 'rosas-thai-cafe-london-6',
#    'name': "Rosa's Thai Cafe",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/V9REPDyItJF29-Hvl71z7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rosas-thai-cafe-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4936975642565,
#     'longitude': -0.141516400361775},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '25 Gillingham Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1V 1HN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['25 Gillingham Street',
#      'London SW1V 1HN',
#      'United Kingdom']},
#    'phone': '+442038136773',
#    'display_phone': '+44 20 3813 6773',
#    'distance': 2162.565966628508},
#   {'id': 'YNduANMPzIVE8CzBH7YjEQ',
#    'alias': 'regency-café-london-2',
#    'name': 'Regency Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pz5q5e8LBG7C1ozSuhvuKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/regency-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 393,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4940143171, 'longitude': -0.13222007974201},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '17-19 Regency Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 4BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17-19 Regency Street',
#      'London SW1P 4BY',
#      'United Kingdom']},
#    'phone': '+442078216596',
#    'display_phone': '+44 20 7821 6596',
#    'distance': 2108.732795587357},
#   {'id': 'nsiUDhW2nBLaW_JCM4gmxg',
#    'alias': 'afghan-kitchen-london',
#    'name': 'Afghan Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/unatlgG0iPqc1-ySJlaPYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/afghan-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'afghani', 'title': 'Afghan'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5357864609294,
#     'longitude': -0.103037509845308},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '35 Islington Green',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8DU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35 Islington Green',
#      'London N1 8DU',
#      'United Kingdom']},
#    'phone': '+442073598019',
#    'display_phone': '+44 20 7359 8019',
#    'distance': 3420.4374340410614},
#   {'id': '1BzTEwJ89j_nBSi7Sf3ylQ',
#    'alias': 'black-pig-with-white-pearls-london',
#    'name': 'Black Pig With White Pearls',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wNKN_xInvn_b82zTgQ7WRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-pig-with-white-pearls-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.55896, 'longitude': -0.0744295},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61 Stoke Newington High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 8EL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Stoke Newington High Street',
#      'London N16 8EL',
#      'United Kingdom']},
#    'phone': '+442072491772',
#    'display_phone': '+44 20 7249 1772',
#    'distance': 6649.972106415342},
#   {'id': 'Que7HUcGPIdWGme3IjEWXg',
#    'alias': 'tayyabs-london-3',
#    'name': 'Tayyabs',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hj14yk-KNLQYfXlS6pypFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tayyabs-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 684,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'pakistani', 'title': 'Pakistani'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5172233660434,
#     'longitude': -0.0633161000573224},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '83-89 Fieldgate Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 1JU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83-89 Fieldgate Street',
#      'London E1 1JU',
#      'United Kingdom']},
#    'phone': '+442072476400',
#    'display_phone': '+44 20 7247 6400',
#    'distance': 5050.114950484469},
#   {'id': 'omeoQdyPp2akKbKBiM8W2Q',
#    'alias': 'noura-london-5',
#    'name': 'Noura',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RVKha_DFDVT-4RFH0N4_pA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noura-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4981193, 'longitude': -0.147859},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '16 Hobart Place',
#     'address2': 'Belgravia',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 0HH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Hobart Place',
#      'Belgravia',
#      'London SW1W 0HH',
#      'United Kingdom']},
#    'phone': '+442072359444',
#    'display_phone': '+44 20 7235 9444',
#    'distance': 1832.052840033281},
#   {'id': 'f8s8dT9Rm4359xUVHtiqRA',
#    'alias': 'black-cat-london',
#    'name': 'Black Cat',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RZHJY2Tw6cAtF7ZrT7vQTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-cat-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5513968, 'longitude': -0.055691},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '76 Clarence Road',
#     'address2': 'Hackney',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E5 8HB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['76 Clarence Road',
#      'Hackney',
#      'London E5 8HB',
#      'United Kingdom']},
#    'phone': '+442089857091',
#    'display_phone': '+44 20 8985 7091',
#    'distance': 7015.023023552639},
#   {'id': 'khnhd6DnBb-zIfZEC1y9zg',
#    'alias': 'the-waiting-room-london-2',
#    'name': 'The Waiting Room',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/29nNTUak9XjUXqkiRvn-Kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-waiting-room-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4792366027832,
#     'longitude': -0.0259060002863407},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '142 Deptford High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE8 3PQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['142 Deptford High Street',
#      'London SE8 3PQ',
#      'United Kingdom']},
#    'phone': '+44442078120105',
#    'display_phone': '+44 442078120105',
#    'distance': 8487.784849357136},
#   {'id': 'cIqYqd3aRSmfkklAC_ENhw',
#    'alias': 'levant-london',
#    'name': 'Levant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wfOgyx7IPy9EdMJm165Y_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/levant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'lebanese', 'title': 'Lebanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516215, 'longitude': -0.150666},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'Jason Court',
#     'address2': '76 Wigmore Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 2SJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Jason Court',
#      '76 Wigmore Street',
#      'London W1U 2SJ',
#      'United Kingdom']},
#    'phone': '+442072241111',
#    'display_phone': '+44 20 7224 1111',
#    'distance': 1086.13703083026},
#   {'id': 'hFR06IFzwrs6RgM6r3W1VA',
#    'alias': 'the-riverside-vegetaria-kingston-upon-thames',
#    'name': 'The Riverside Vegetaria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/W776loAW4poKvXBO3M-TaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-riverside-vegetaria-kingston-upon-thames?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.407239, 'longitude': -0.308125},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '64 High Street',
#     'address2': 'Kingston',
#     'address3': '',
#     'city': 'Kingston Upon Thames',
#     'zip_code': 'KT1 1HN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['64 High Street',
#      'Kingston',
#      'Kingston Upon Thames KT1 1HN',
#      'United Kingdom']},
#    'phone': '+442085467992',
#    'display_phone': '+44 20 8546 7992',
#    'distance': 16761.310499839445},
#   {'id': 'C8sYZKBuws6SRUUzlgb0fQ',
#    'alias': 'arancini-brothers-london-3',
#    'name': 'Arancini Brothers',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/J96YPpXYqipb58kPk0OdAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arancini-brothers-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'australian', 'title': 'Australian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.54592, 'longitude': -0.0755888},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '592 Kingsland Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 4AH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['592 Kingsland Road',
#      'London E8 4AH',
#      'United Kingdom']},
#    'phone': '+442035837303',
#    'display_phone': '+44 20 3583 7303',
#    'distance': 5565.263134649826},
#   {'id': 'teXPunKtpwj0NuttvPYhyQ',
#    'alias': 'the-victoria-paddington',
#    'name': 'The Victoria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IscE584D-z4Snf71FJ1bcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-victoria-paddington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 218,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51350403679, 'longitude': -0.17119959969309},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10a Strathearn Place',
#     'address2': '',
#     'address3': '',
#     'city': 'Paddington',
#     'zip_code': 'W2 2NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10a Strathearn Place',
#      'Paddington W2 2NH',
#      'United Kingdom']},
#    'phone': '+442077241191',
#    'display_phone': '+44 20 7724 1191',
#    'distance': 2440.016451414865},
#   {'id': 'W8uZ2XRz0mL1h8geJDD5MQ',
#    'alias': 'the-queen-of-sheba-london',
#    'name': 'The Queen of Sheba',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZTyzTlnrWi52oxXePkoTvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-queen-of-sheba-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'ethiopian', 'title': 'Ethiopian'},
#     {'alias': 'african', 'title': 'African'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5522561, 'longitude': -0.1408549},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '12 Fortess Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW5 2EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Fortess Road',
#      'London NW5 2EU',
#      'United Kingdom']},
#    'phone': '+442072843947',
#    'display_phone': '+44 20 7284 3947',
#    'distance': 4397.080990103243},
#   {'id': 'Bh9Jncp_lEBnJdJjzvtrgA',
#    'alias': 'the-begging-bowl-london',
#    'name': 'The Begging Bowl',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fOtf8ehYD1kXROKb8awyUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-begging-bowl-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4672892553912,
#     'longitude': -0.0727415084838867},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '168 Bellenden Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE15 4BW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['168 Bellenden Road',
#      'London SE15 4BW',
#      'United Kingdom']},
#    'phone': '+442076352627',
#    'display_phone': '+44 20 7635 2627',
#    'distance': 6693.616385281309},
#   {'id': 'veUO9bhS7Eqi-BLqwnhK1A',
#    'alias': 'vegan-yes-london',
#    'name': 'Vegan Yes',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mipx3VuUDQhBSm_r032X6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vegan-yes-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5187357113673,
#     'longitude': -0.0714313709148927},
#    'transactions': [],
#    'location': {'address1': '64 Brick Lane',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E1 6RF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['64 Brick Lane', 'London E1 6RF', 'United Kingdom']},
#    'phone': '+447879536269',
#    'display_phone': '+44 7879 536269',
#    'distance': 4512.80408658267}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                   Restaurant        Type Price Rating  \
# 0              Vanilla Black  Vegetarian   £££      4
# 1                     Negril   Caribbean    ££      4
# 2             Maggie Jones's     British   £££    4.5
# 3  BunBunBun Vietnamese Food  Vietnamese    ££    4.5
# 4           Wholefood Heaven       Vegan
#
#                     Address        Lat       Lng  \
# 0        17-18 Took's Court  51.517176 -0.111025
# 1          132 Brixton Hill  51.452757 -0.121385
# 2         6 Old Court Place  51.502856 -0.190992
# 3       134B Kingsland Road  51.531788 -0.076831
# 4  Whitecross Street Market  51.545258 -0.140778
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/vanilla-black-london?...  HzyhCXPooUGWvuPYOfT0WA
# 1  https://www.yelp.com/biz/negril-london?adjust_...  w3gHIiTFqUs68ecxO941GA
# 2  https://www.yelp.com/biz/maggie-joness-london-...  5tAAwu7ZDhulLsyt09bXnw
# 3  https://www.yelp.com/biz/bunbunbun-vietnamese-...  VovLxnCCWutZhE9NnSD9NA
# 4

# %%
#3rd set of 50 records 101-150
lndr_params3 = {"term":term,"location":"London","limit":50,"offset":101}
lndr_response3 = requests.get(search_api_url, headers=headers, params=lndr_params3)
lndr3 = lndr_response3.json()
display(lndr3)
#print(lndr_response3.url)
#print(lndr_response3.status_code)
# Out:
# {'businesses': [{'id': 'FDZivchIliS2K_dpF-DZNw',
#    'alias': 'shayona-london',
#    'name': 'Shayona',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FGrHRWF1Y35SKtcRmFCZYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shayona-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.547863, 'longitude': -0.2624042},
#    'transactions': [],
#    'location': {'address1': '54 - 62 Meadow Garth',
#     'address2': 'Neasden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW10 8HD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54 - 62 Meadow Garth',
#      'Neasden',
#      'London NW10 8HD',
#      'United Kingdom']},
#    'phone': '+442089653365',
#    'display_phone': '+44 20 8965 3365',
#    'distance': 9612.373738563443},
#   {'id': 'cLyL7ABwhjdkQcREkeOCEw',
#    'alias': 'chai-ki-london-2',
#    'name': 'Chai Ki',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/F_G3LEcSuOsydo9EglZXJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chai-ki-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 52,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.506224381971,
#     'longitude': -0.0180665979703719},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Crossrail Place',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E14 5AR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Crossrail Place',
#      'London E14 5AR',
#      'United Kingdom']},
#    'phone': '+442075160444',
#    'display_phone': '+44 20 7516 0444',
#    'distance': 8191.6820260628465},
#   {'id': 'Ukviw0MTBHKqC_hxctkfxA',
#    'alias': 'lemongrass-restaurant-london',
#    'name': 'Lemongrass Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sFb-RmersoKyDTEX7-kJRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lemongrass-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'cambodian', 'title': 'Cambodian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5424947, 'longitude': -0.1391339},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '243 Royal College Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 9LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['243 Royal College Street',
#      'London NW1 9LT',
#      'United Kingdom']},
#    'phone': '+442072841116',
#    'display_phone': '+44 20 7284 1116',
#    'distance': 3305.266662588123},
#   {'id': '2hWE0g0lCJt97WQY4o2Q-g',
#    'alias': 'pilpel-london',
#    'name': 'Pilpel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yLIXTmi5yXiAiiwtK83aPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pilpel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 56,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'falafel', 'title': 'Falafel'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5189556, 'longitude': -0.0772774},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '38 Brushfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6AT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38 Brushfield Street',
#      'London E1 6AT',
#      'United Kingdom']},
#    'phone': '+442072470146',
#    'display_phone': '+44 20 7247 0146',
#    'distance': 4116.959257500344},
#   {'id': 'rlgecmgj4sTj1-BapJBg_Q',
#    'alias': 'cafe-east-london-2',
#    'name': 'Cafe East',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8qyqFa11bymhEEIqi5zj8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-east-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 72,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4962937564236,
#     'longitude': -0.0415420532226562},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '100 Redriff Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE16 7LH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['100 Redriff Road',
#      'London SE16 7LH',
#      'United Kingdom']},
#    'phone': '+442072521212',
#    'display_phone': '+44 20 7252 1212',
#    'distance': 6788.635469185765},
#   {'id': 'sovwL7rq0Kd01fYC3wLbYA',
#    'alias': 'temple-of-seitan-london',
#    'name': 'Temple of Seitan',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/X5W0LzfZ5OkSR_CRHy38-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/temple-of-seitan-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5458702483097,
#     'longitude': -0.054151803576945},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '10 Morning Lane',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E9 6NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Morning Lane', 'London E9 6NA', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6746.534083198448},
#   {'id': '2U4muki2mQXmkefOtL1VYQ',
#    'alias': 'hoppers-soho',
#    'name': 'Hoppers',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MS-OUurffAgQrKul3n96gg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hoppers-soho?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 114,
#    'categories': [{'alias': 'srilankan', 'title': 'Sri Lankan'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5135765075684,
#     'longitude': -0.131750002503395},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '49 Frith Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Soho',
#     'zip_code': 'W1D 4SG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Frith Street', 'Soho W1D 4SG', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 308.04319047033516},
#   {'id': 'PBFvhVyBi0lEJyTbyuxf5w',
#    'alias': 'the-orangery-london-7',
#    'name': 'The Orangery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L_0d22xNmfCC_d-tArBo3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-orangery-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 238,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5066360577041,
#     'longitude': -0.187725349125042},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Kensington Palace',
#     'address2': 'Palace Green',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Kensington Palace',
#      'Palace Green',
#      'London W8 4PX',
#      'United Kingdom']},
#    'phone': '+442031666113',
#    'display_phone': '+44 20 3166 6113',
#    'distance': 3648.4574890404074},
#   {'id': 'dUjqjY7GxJFQ9bzlu4HEgw',
#    'alias': 'loving-hut-archway-london',
#    'name': 'Loving Hut Archway',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T3Uohbsrsv2XDJWEePpUig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/loving-hut-archway-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5649508868981,
#     'longitude': -0.133335962891579},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '669 Holloway Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N19 5SE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['669 Holloway Rd',
#      'London N19 5SE',
#      'United Kingdom']},
#    'phone': '+442072818989',
#    'display_phone': '+44 20 7281 8989',
#    'distance': 5797.789831547512},
#   {'id': 'QkLEg3luaWv4xg2vIAwkPQ',
#    'alias': 'gi-gi-hut-london',
#    'name': 'Gi Gi Hut',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BMZulKA11tzbkXAtcxapCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gi-gi-hut-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5243752, 'longitude': -0.14027},
#    'transactions': [],
#    'location': {'address1': '339 Euston Road',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW1 3AD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['339 Euston Road',
#      'London NW1 3AD',
#      'United Kingdom']},
#    'phone': '+442073833978',
#    'display_phone': '+44 20 7383 3978',
#    'distance': 1317.4167403744134},
#   {'id': 'VTOd4cweIR_5uMHh0KLeBg',
#    'alias': 'kiln-london',
#    'name': 'Kiln',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wx-7MBtCasPF-3zrvoYqfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kiln-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5114108, 'longitude': -0.1360504},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '58 Brewer Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1F 9TL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['58 Brewer Street',
#      'London W1F 9TL',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 159.83190000687998},
#   {'id': 'YMCoy6XiUv1w3Whr6F4fyw',
#    'alias': 'kalifornia-kitchen-london',
#    'name': 'Kalifornia Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jSg4ISOrBzXr_vzCYKqSqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kalifornia-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5185890197754,
#     'longitude': -0.132510006427765},
#    'transactions': [],
#    'location': {'address1': '19 Percy Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1T 1BZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Percy Street',
#      'London W1T 1BZ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 680.0381322141267},
#   {'id': 'HaYOqwNtC6JK2uuGmr1KGg',
#    'alias': 'piebury-corner-london-4',
#    'name': 'Piebury Corner',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3-ozW-aDRq3uEnFudGS0mQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piebury-corner-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.55099, 'longitude': -0.11041},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '209-211 Holloway Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N7 8DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['209-211 Holloway Road',
#      'London N7 8DL',
#      'United Kingdom']},
#    'phone': '+442077005441',
#    'display_phone': '+44 20 7700 5441',
#    'distance': 4601.644340774392},
#   {'id': 'NSrYBenDSYo1irgdWesU4Q',
#    'alias': 'pied-à-terre-london-3',
#    'name': 'Pied à Terre',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pumd02k8GoQl5gFs_HK9KQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pied-%C3%A0-terre-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.519099, 'longitude': -0.13517},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '34 Charlotte Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 2NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['34 Charlotte Street',
#      'London W1T 2NH',
#      'United Kingdom']},
#    'phone': '+442076361178',
#    'display_phone': '+44 20 7636 1178',
#    'distance': 701.7668355108046},
#   {'id': 'BNdzjiLoibX1uSH4kAQy5w',
#    'alias': 'the-bike-shed-london',
#    'name': 'The Bike Shed',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_zYjKPcPg4BE91Bl7tVPUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bike-shed-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'accessories', 'title': 'Accessories'},
#     {'alias': 'themedcafes', 'title': 'Themed Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5270903, 'longitude': -0.0782151},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '384 Old Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 9LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['384 Old Street',
#      'London EC1V 9LT',
#      'United Kingdom']},
#    'phone': '+442077298114',
#    'display_phone': '+44 20 7729 8114',
#    'distance': 4257.350530218552},
#   {'id': 'q-OOWNDtWue-ALqtnL2iDQ',
#    'alias': 'trishna-london',
#    'name': 'Trishna',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JqH5fvDOgbVjoXRw3gHaJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trishna-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.518294, 'longitude': -0.153047},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '15-17 Blandford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 3DG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15-17 Blandford Street',
#      'London W1U 3DG',
#      'United Kingdom']},
#    'phone': '+442079355624',
#    'display_phone': '+44 20 7935 5624',
#    'distance': 1335.226272872303},
#   {'id': 'JV97uhTY3WFQPtm80YI5YA',
#    'alias': 'the-hive-sw6-london',
#    'name': 'The Hive SW6',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KIwR3sbDH4fF5X5Z71kXKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hive-sw6-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4754906, 'longitude': -0.2062352},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '670 Fulham Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 5RX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['670 Fulham Road',
#      'London SW6 5RX',
#      'United Kingdom']},
#    'phone': '+442077361118',
#    'display_phone': '+44 20 7736 1118',
#    'distance': 6399.945422268729},
#   {'id': 'eLy2iu3hByI6XHYfCB2p_g',
#    'alias': 'tortellinicup-london',
#    'name': 'TortelliniCup',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ERxYMQg9FGVOsgtPNAzelg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tortellinicup-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5477120796588,
#     'longitude': -0.181073722758984},
#    'transactions': [],
#    'location': {'address1': 'O2 Centre',
#     'address2': '255 Finchley Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 6LU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['O2 Centre',
#      '255 Finchley Road',
#      'London NW3 6LU',
#      'United Kingdom']},
#    'phone': '+447909594094',
#    'display_phone': '+44 7909 594094',
#    'distance': 4977.9780850849575},
#   {'id': 'qQHJL2i-7WxcFbgRJy4GHw',
#    'alias': 'woody-grill-london',
#    'name': 'Woody Grill',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Hnr5AwDpKX1ugfwxou-k2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/woody-grill-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 76,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'turkish', 'title': 'Turkish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.539693431101,
#     'longitude': -0.14189511136749},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '1A Camden Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 9LG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1A Camden Road', 'London NW1 9LG', 'United Kingdom']},
#    'phone': '+442086169587',
#    'display_phone': '+44 20 8616 9587',
#    'distance': 3014.592650425651},
#   {'id': 'Y51qImK_hOk-AaT5c5yC2w',
#    'alias': 'plum-and-spilt-milk-london',
#    'name': 'Plum & Spilt Milk',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GdWFQ0A3uGHuTwSTmCDzzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/plum-and-spilt-milk-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.532379, 'longitude': -0.1254596},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "King's Cross Street",
#     'address2': 'Pancras Station',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4TB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["King's Cross Street",
#      'Pancras Station',
#      'London N1C 4TB',
#      'United Kingdom']},
#    'phone': '+442033880818',
#    'display_phone': '+44 20 3388 0818',
#    'distance': 2291.2577599195056},
#   {'id': 'QYuGi-HP15ZI4Ss-gAuLKQ',
#    'alias': 'apadana-restaurant-london-3',
#    'name': 'Apadana Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/179plWjivQ0oKlETyvQ5Ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/apadana-restaurant-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'persian', 'title': 'Persian/Iranian'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4973635246985,
#     'longitude': -0.203176802846274},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '351 Kensington High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 6NW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['351 Kensington High Street',
#      'London W8 6NW',
#      'United Kingdom']},
#    'phone': '+442076033696',
#    'display_phone': '+44 20 7603 3696',
#    'distance': 4960.438268416169},
#   {'id': '_uFHdQr2si6J7-NdNp2MWw',
#    'alias': 'by-chloe-tower-bridge-london',
#    'name': 'by CHLOE. Tower Bridge',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/afNOfbSA5to7-RVgKj_0Bw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/by-chloe-tower-bridge-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5035046, 'longitude': -0.0773},
#    'transactions': [],
#    'location': {'address1': 'One Tower Bridge',
#     'address2': 'Tower Bridge Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 2UP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['One Tower Bridge',
#      'Tower Bridge Road',
#      'London SE1 2UP',
#      'United Kingdom']},
#    'phone': '+442122908000',
#    'display_phone': '+44 21 2290 8000',
#    'distance': 4189.945807523757},
#   {'id': '_hoy9y5s47Bx2tCrXv1OVw',
#    'alias': 'maroush-ii-london',
#    'name': 'Maroush II',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jepixSk1QTuxc55gu10mBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maroush-ii-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 100,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.49724, 'longitude': -0.164357},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '38 Beauchamp Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 1NU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38 Beauchamp Place',
#      'London SW3 1NU',
#      'United Kingdom']},
#    'phone': '+442075815434',
#    'display_phone': '+44 20 7581 5434',
#    'distance': 2620.319493596372},
#   {'id': 'pTzAvHQQ-eJqp8fcZ8F_wQ',
#    'alias': 'planet-organic-london-2',
#    'name': 'Planet Organic',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NWj6-btnC-bVbCYfo5gIKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/planet-organic-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'healthmarkets', 'title': 'Health Markets'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.521367, 'longitude': -0.134126},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Torrington Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1E 7HJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Torrington Place',
#      'London WC1E 7HJ',
#      'United Kingdom']},
#    'phone': '+442074361929',
#    'display_phone': '+44 20 7436 1929',
#    'distance': 993.9618175190195},
#   {'id': 'vlq4D26p_143Tj21OF-iMA',
#    'alias': 'dishoom-london-2',
#    'name': 'Dishoom',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8zeazSGXG59wynFrPFcqMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dishoom-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 496,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5245310066818,
#     'longitude': -0.076594190862934},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '7 Boundary Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7JE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Boundary Street',
#      'London E2 7JE',
#      'United Kingdom']},
#    'phone': '+442074209324',
#    'display_phone': '+44 20 7420 9324',
#    'distance': 4308.313256620144},
#   {'id': 'y9MWERu8ULGHhMKaDn8F2Q',
#    'alias': 'firecracker-london',
#    'name': 'Firecracker',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fnJNGRlX_0pB2JRopI-Mzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/firecracker-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'karaoke', 'title': 'Karaoke'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4949849, 'longitude': -0.1271241},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '44 Horseferry Road',
#     'address2': 'Westminster',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 2AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['44 Horseferry Road',
#      'Westminster',
#      'London SW1P 2AF',
#      'United Kingdom']},
#    'phone': '+442072224680',
#    'display_phone': '+44 20 7222 4680',
#    'distance': 2076.323359032682},
#   {'id': 'OLXUZqx6doQtdeHfyEoyOw',
#    'alias': 'balans-soho-society-london',
#    'name': 'Balans Soho Society',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/x5-9gQeXo60P7Y5uC0nWUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/balans-soho-society-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 92,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4999833, 'longitude': -0.1956639},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '187 Kensington High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 6SH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['187 Kensington High Street',
#      'London W8 6SH',
#      'United Kingdom']},
#    'phone': '+442073760115',
#    'display_phone': '+44 20 7376 0115',
#    'distance': 4362.76195718541},
#   {'id': '_eLGYgZ5aqLeyADvCRUT0w',
#    'alias': 'the-detox-kitchen-london-3',
#    'name': 'The Detox Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YgwPSjd7-HVtPsz6NBtiNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-detox-kitchen-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'healthmarkets', 'title': 'Health Markets'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5186046, 'longitude': -0.1380871},
#    'transactions': [],
#    'location': {'address1': '10 Mortimer Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1T 3JJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Mortimer Street',
#      'London W1T 3JJ',
#      'United Kingdom']},
#    'phone': '+442074986417',
#    'display_phone': '+44 20 7498 6417',
#    'distance': 658.445753130219},
#   {'id': 'RaIZ-cnvuSM3wLDuQkl-aw',
#    'alias': 'banana-tree-london-7',
#    'name': 'Banana Tree',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0u4OudFTcqjs9hYro9GZtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/banana-tree-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 56,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.460635, 'longitude': -0.166301},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '75-79 Battersea Rise',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW11 1HN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['75-79 Battersea Rise',
#      'London SW11 1HN',
#      'United Kingdom']},
#    'phone': '+442072282828',
#    'display_phone': '+44 20 7228 2828',
#    'distance': 6177.02185711272},
#   {'id': '-PnReVDp_G_OfuJMQ0TOzg',
#    'alias': 'cafe-pushkar-london',
#    'name': 'Cafe Pushkar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Dda6nWQ-lZVX5FUv9nIeOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-pushkar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.46164, 'longitude': -0.11361},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '424 Coldharbour Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 8LF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['424 Coldharbour Lane',
#      'London SW9 8LF',
#      'United Kingdom']},
#    'phone': '+442077386161',
#    'display_phone': '+44 20 7738 6161',
#    'distance': 5891.06375591332},
#   {'id': 'yM_Soly8tagfja0NNUqb5w',
#    'alias': 'chutneys-london',
#    'name': 'Chutneys',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qFsmUH0lQFsSUgWx6vQm0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chutneys-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.526885742863,
#     'longitude': -0.13758647273438},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '124 Drummond Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 2PA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['124 Drummond Street',
#      'London NW1 2PA',
#      'United Kingdom']},
#    'phone': '+442073880604',
#    'display_phone': '+44 20 7388 0604',
#    'distance': 1566.380326702366},
#   {'id': '7jauLkFeYYJg2VTPxT7KWw',
#    'alias': 'naughty-piglets-london',
#    'name': 'Naughty Piglets',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_3b9EDCeftahK5FUkH9APg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/naughty-piglets-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4551122527474,
#     'longitude': -0.113104695700827},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '28 Brixton Water Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW2 1PE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28 Brixton Water Lane',
#      'London SW2 1PE',
#      'United Kingdom']},
#    'phone': '+442072747796',
#    'display_phone': '+44 20 7274 7796',
#    'distance': 6610.690442641753},
#   {'id': '1oShlXeGjTrfD-A1I_iHBw',
#    'alias': 'the-spread-eagle-london-6',
#    'name': 'The Spread Eagle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QEZKnaoWDOvsAs2a5hTrkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-spread-eagle-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5486131491202,
#     'longitude': -0.0408179463767122},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '224 Homerton High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E9 6AS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['224 Homerton High Street',
#      'London E9 6AS',
#      'United Kingdom']},
#    'phone': '+442089850400',
#    'display_phone': '+44 20 8985 0400',
#    'distance': 7690.047611557957},
#   {'id': 'ccQoTNlwneWz7mC4uy7lhg',
#    'alias': 'wok-to-walk-oxford-st-london',
#    'name': 'Wok to Walk - Oxford St',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/O-3zC_Wqo3yBavWLuaGBOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wok-to-walk-oxford-st-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5151319864592,
#     'longitude': -0.141034647080711},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '15 Argyll Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7TP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Argyll Street',
#      'London W1F 7TP',
#      'United Kingdom']},
#    'phone': '+442072875491',
#    'display_phone': '+44 20 7287 5491',
#    'distance': 434.42388296851465},
#   {'id': '7NdidQzvlnlCTrLGVGkY2w',
#    'alias': 'ganapati-london',
#    'name': 'Ganapati',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/asY4Ql7KN_utoFmnZMUZGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ganapati-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.469647326576,
#     'longitude': -0.073005378271727},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '38 Holly Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE15 5DF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38 Holly Grove',
#      'London SE15 5DF',
#      'United Kingdom']},
#    'phone': '+442072772928',
#    'display_phone': '+44 20 7277 2928',
#    'distance': 6485.121918529254},
#   {'id': '5o8lm4tCTGgZfH0N4QAgMg',
#    'alias': 'cask-pub-and-kitchen-london-2',
#    'name': 'CASK Pub and Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ntmuMfLZr0WOVoqNXUqW6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cask-pub-and-kitchen-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 139,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.49135039773, 'longitude': -0.13753688795203},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 Charlwood Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 2EE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Charlwood Street',
#      'London SW1V 2EE',
#      'United Kingdom']},
#    'phone': '+442076307225',
#    'display_phone': '+44 20 7630 7225',
#    'distance': 2391.5393462801244},
#   {'id': '-1Z1naE04815v0Lxb5-pbA',
#    'alias': 'saravana-bhavan-central-london-london',
#    'name': 'Saravana Bhavan Central London',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bxBIlz-1b6CsOzU9w8y4KQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saravana-bhavan-central-london-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5101805, 'longitude': -0.1286267},
#    'transactions': [],
#    'location': {'address1': '17 Charing Cross Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 0EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17 Charing Cross Road',
#      'London WC2H 0EP',
#      'United Kingdom']},
#    'phone': '+442078398797',
#    'display_phone': '+44 20 7839 8797',
#    'distance': 582.6229211891256},
#   {'id': 'kFuNTfCd50hHjw3xxnCQ1w',
#    'alias': 'makan-café-london-3',
#    'name': 'Makan Café',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QhS3iIzjZi7T9nuCjdvG2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/makan-caf%C3%A9-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'malaysian', 'title': 'Malaysian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.519035, 'longitude': -0.207198},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '270 Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W10 5TY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['270 Portobello Road',
#      'London W10 5TY',
#      'United Kingdom']},
#    'phone': '+442089605169',
#    'display_phone': '+44 20 8960 5169',
#    'distance': 4970.698989235501},
#   {'id': 'Su5jF1qOBmzN1dymQwshJw',
#    'alias': 'gujarati-rasoi-london-2',
#    'name': 'Gujarati Rasoi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TiKA1xiegVWWJbfcbduhmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gujarati-rasoi-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5486677, 'longitude': -0.0762269},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '10 C Bradbury Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 8JN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 C Bradbury Street',
#      'London N16 8JN',
#      'United Kingdom']},
#    'phone': '+442086167914',
#    'display_phone': '+44 20 8616 7914',
#    'distance': 5739.83802356559},
#   {'id': 'mBkMpzhvXflyZsqX0s-FKg',
#    'alias': 'konaki-restaurant-london',
#    'name': 'Konaki Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Nofs72LXaXF9qMVX4YNXqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/konaki-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5174575, 'longitude': -0.1263657},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5 Coptic Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1A 1NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Coptic Street',
#      'London WC1A 1NH',
#      'United Kingdom']},
#    'phone': '+442075809730',
#    'display_phone': '+44 20 7580 9730',
#    'distance': 839.3529311519959},
#   {'id': 'Tzdawv36VsL7N8gTLXTLmg',
#    'alias': 'buffalo-london-2',
#    'name': 'Buffalo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QwP4ndWC0XxtuUGO8rAeGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/buffalo-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5400751, 'longitude': -0.0560769},
#    'transactions': [],
#    'location': {'address1': '171 Mare Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E8 3RH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['171 Mare Street', 'London E8 3RH', 'United Kingdom']},
#    'phone': '+442086179470',
#    'display_phone': '+44 20 8617 9470',
#    'distance': 6301.6932217918165},
#   {'id': 'D7p8_LXEFq3OqLxZIO-dLQ',
#    'alias': 'clos-maggiore-london-2',
#    'name': 'Clos Maggiore',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rpKcQyI2xoRovHYb2pQ9WA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clos-maggiore-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 128,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51166, 'longitude': -0.124695},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '33 King Street',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 8JD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['33 King Street',
#      'Covent Garden',
#      'London WC2E 8JD',
#      'United Kingdom']},
#    'phone': '+442073799696',
#    'display_phone': '+44 20 7379 9696',
#    'distance': 790.1547733860398},
#   {'id': 'a50cdpgVp7afE2-WU3fQ7Q',
#    'alias': 'simplicity-london',
#    'name': 'Simplicity',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NQV8cr1-0pKt2skuS4Ocow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/simplicity-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.501247, 'longitude': -0.053137},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Tunnel Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE16 4JJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Tunnel Road', 'London SE16 4JJ', 'United Kingdom']},
#    'phone': '+442072325174',
#    'display_phone': '+44 20 7232 5174',
#    'distance': 5875.657226484116},
#   {'id': 'zqr54R-hh99HCPaujuLpXQ',
#    'alias': 'carnevale-london',
#    'name': 'Carnevale',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wV5zTZdYZq2oua63FPdl5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carnevale-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5228964, 'longitude': -0.0929861},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '135 Whitecross Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1Y 8JL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['135 Whitecross Street',
#      'London EC1Y 8JL',
#      'United Kingdom']},
#    'phone': '+442072503452',
#    'display_phone': '+44 20 7250 3452',
#    'distance': 3178.2914700668925},
#   {'id': 'bJiVADMSTEKj0MjqiLrOPA',
#    'alias': 'the-grazing-goat-marylebone-london',
#    'name': 'The Grazing Goat Marylebone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/h73f5PAFit9wdm8w_zm3lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grazing-goat-marylebone-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 240,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515378341447,
#     'longitude': -0.15823586449841},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 New Quebec Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7RQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 New Quebec Street',
#      'London W1H 7RQ',
#      'United Kingdom']},
#    'phone': '+442077247243',
#    'display_phone': '+44 20 7724 7243',
#    'distance': 1567.469377589238},
#   {'id': 'bgNNAcV-GYqPXkYcHmZNCg',
#    'alias': 'curious-yellow-kafé-london-2',
#    'name': 'Curious Yellow Kafé',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6vJbw-iS0rh8p0zpzAyZvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/curious-yellow-kaf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'scandinavian', 'title': 'Scandinavian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.52954503532,
#     'longitude': -0.0838136672973633},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '77 Pitfield Street',
#     'address2': 'Hoxton',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 6BT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['77 Pitfield Street',
#      'Hoxton',
#      'London N1 6BT',
#      'United Kingdom']},
#    'phone': '+442072516018',
#    'display_phone': '+44 20 7251 6018',
#    'distance': 4057.971810265291},
#   {'id': 'T-_ewkgY9DiMJ36qHL4UvQ',
#    'alias': 'greenberry-café-london',
#    'name': 'Greenberry Café',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZD7JdkRDA6OEHybFT934Hw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greenberry-caf%C3%A9-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.542194, 'longitude': -0.156334},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '101 Regents Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8UR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['101 Regents Park Road',
#      'London NW1 8UR',
#      'United Kingdom']},
#    'phone': '+442074833765',
#    'display_phone': '+44 20 7483 3765',
#    'distance': 3554.568759488491},
#   {'id': 'RnI5EHQP9esD19epdo8s8Q',
#    'alias': 'vijay-india-restaurant-london',
#    'name': 'Vijay India Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YSWXgnyrwX6u50TKaWTJCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vijay-india-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5407952, 'longitude': -0.201584},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '49 Willesden Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 7RF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Willesden Lane',
#      'London NW6 7RF',
#      'United Kingdom']},
#    'phone': '+442073281087',
#    'display_phone': '+44 20 7328 1087',
#    'distance': 5505.12547225513},
#   {'id': '4fXAbVy4FIx_BVcMWhaVxQ',
#    'alias': 'hummusa-london',
#    'name': 'Hummusa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2zkWmJqc1RAcnrXquyvvYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hummusa-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'lebanese', 'title': 'Lebanese'},
#     {'alias': 'falafel', 'title': 'Falafel'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.461273, 'longitude': -0.00647015869617462},
#    'transactions': [],
#    'location': {'address1': '82 Lee High Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE13 5PT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['82 Lee High Road',
#      'London SE13 5PT',
#      'United Kingdom']},
#    'phone': '+442070185711',
#    'display_phone': '+44 20 7018 5711',
#    'distance': 10642.117102021748},
#   {'id': 'bOEPov-chRVQhggY5k805w',
#    'alias': 'the-blue-legume-london',
#    'name': 'The Blue Legume',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZGvcO144Vdi31dN1q3oatA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-blue-legume-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.541374206543,
#     'longitude': -0.103168003261089},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '177 Upper St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 1RG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['177 Upper St', 'London N1 1RG', 'United Kingdom']},
#    'phone': '+442072265858',
#    'display_phone': '+44 20 7226 5858',
#    'distance': 3900.6488057505812}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#               Restaurant          Type Price Rating                   Address  \
# 0                Shayona        Indian                   54 - 62 Meadow Garth
# 1                Chai Ki  Asian Fusion    ££      4           Crossrail Place
# 2  Lemongrass Restaurant       Chinese    ££      4  243 Royal College Street
# 3                 Pilpel    Vegetarian     £    4.5      38 Brushfield Street
# 4              Cafe East    Vietnamese     £      4          100 Redriff Road
#
#          Lat       Lng                                                url  \
# 0  51.547863 -0.262404
# 1  51.506224 -0.018067  https://www.yelp.com/biz/chai-ki-london-2?adju...
# 2  51.542495 -0.139134  https://www.yelp.com/biz/lemongrass-restaurant...
# 3  51.518956 -0.077277  https://www.yelp.com/biz/pilpel-london?adjust_...
# 4  51.496294 -0.041542  https://www.yelp.com/biz/cafe-east-london-2?ad...
#
#                        ID
# 0
# 1  cLyL7ABwhjdkQcREkeOCEw
# 2  Ukviw0MTBHKqC_hxctkfxA
# 3  2hWE0g0lCJt97WQY4o2Q-g
# 4  rlgecmgj4sTj1-BapJBg_Q

# %%
#4th set of 50 records 151-200
lndr_params4 = {"term":term,"location":"London","limit":50,"offset":151}
lndr_response4 = requests.get(search_api_url, headers=headers, params=lndr_params4)
lndr4 = lndr_response4.json()
display(lndr4)
#print(lndr_response4.url)
#print(lndr_response4.status_code)
# Out:
# {'businesses': [{'id': 'm2XtIGSfOtXqTfR7ij-kzg',
#    'alias': 'sandys-london',
#    'name': "Sandy's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5lnHU2347jMucjblzlBpow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sandys-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5148849487305,
#     'longitude': -0.161039993166924},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 Seymour Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7NF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Seymour Place',
#      'London W1H 7NF',
#      'United Kingdom']},
#    'phone': '+442077238833',
#    'display_phone': '+44 20 7723 8833',
#    'distance': 1750.7039372728864},
#   {'id': 'q7Oz1gTCgoQkFu3VoOQrDQ',
#    'alias': 'mohsen-london',
#    'name': 'Mohsen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BPi7EnRx0cbWPiBbPk4qHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mohsen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'persian', 'title': 'Persian/Iranian'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.495177, 'longitude': -0.20302},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '152 Warwick Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W14 8PS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['152 Warwick Road',
#      'London W14 8PS',
#      'United Kingdom']},
#    'phone': '+442076039888',
#    'display_phone': '+44 20 7603 9888',
#    'distance': 5040.231788053019},
#   {'id': 'rKwkCvsSfp8z7w1CmNnMMQ',
#    'alias': 'the-table-london-8',
#    'name': 'The Table',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/T-rwpQYiLxDyUXGNAwEYSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-table-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 268,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.505604, 'longitude': -0.099671},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '83 Southwark Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Southwark Street',
#      'London SE1 0HX',
#      'United Kingdom']},
#    'phone': '+442074012760',
#    'display_phone': '+44 20 7401 2760',
#    'distance': 2636.7435245046486},
#   {'id': 'MaNE6xr9_bqpIWCLm5VhkA',
#    'alias': 'goddards-at-greenwich-london',
#    'name': 'Goddards at Greenwich',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hGrxtzUFxlDAbt8TyhlZ5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/goddards-at-greenwich-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4812088, 'longitude': -0.0083317},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '22 King William Walk',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE10 9HU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 King William Walk',
#      'London SE10 9HU',
#      'United Kingdom']},
#    'phone': '+442083059612',
#    'display_phone': '+44 20 8305 9612',
#    'distance': 9498.252492833206},
#   {'id': 'M5U_bhEd5J5isIQ5u9UsLQ',
#    'alias': 'arancini-brothers-london-4',
#    'name': 'Arancini Brothers',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8F632AVVzwgfjsIYC8wvUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arancini-brothers-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5189616956944,
#     'longitude': -0.083632884655799},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '115A Kentish Town Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8PB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['115A Kentish Town Road',
#      'London NW1 8PB',
#      'United Kingdom']},
#    'phone': '+442035832242',
#    'display_phone': '+44 20 3583 2242',
#    'distance': 3684.075541564013},
#   {'id': '3AqrHgpIbcMXj0q-p_oPzg',
#    'alias': 'homeslice-neals-yard-london',
#    'name': "Homeslice Neal's Yard",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2Fv58EUzsVHVhAjM00K69g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/homeslice-neals-yard-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 228,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5144380966574,
#     'longitude': -0.126426543278564},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "13 Neal's Yard",
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["13 Neal's Yard",
#      'Covent Garden',
#      'London WC2H 9DP',
#      'United Kingdom']},
#    'phone': '+442031517488',
#    'display_phone': '+44 20 3151 7488',
#    'distance': 683.0755682796743},
#   {'id': 'L-ZNTln24SoU_jYia4M19Q',
#    'alias': 'ottolenghi-london-3',
#    'name': 'Ottolenghi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/M0v7lVN-ZkBDz0BuJQhzwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ottolenghi-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 96,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514890823172,
#     'longitude': -0.19941762827537},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '63 Ledbury Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2AD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63 Ledbury Road',
#      'London W11 2AD',
#      'United Kingdom']},
#    'phone': '+442077271121',
#    'display_phone': '+44 20 7727 1121',
#    'distance': 4397.458116121883},
#   {'id': '2UOyTS-Tj1l5o7gflGJzHQ',
#    'alias': 'kitchen-149-london',
#    'name': 'Kitchen @ 149',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QPJKfQKUo4rsIXvpr3pHDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kitchen-149-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.559506, 'longitude': -0.114575},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '149 Hornsey Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N7 6DU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['149 Hornsey Road',
#      'London N7 6DU',
#      'United Kingdom']},
#    'phone': '+442076979816',
#    'display_phone': '+44 20 7697 9816',
#    'distance': 5396.3521963592375},
#   {'id': 'BmXTlvUhnaMtWhB8WCtejQ',
#    'alias': 'the-hive-london-7',
#    'name': 'The Hive',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/P-qMKZ3mXhsGIEBvmpCX_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hive-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.4988656705546,
#     'longitude': -0.199602283537388},
#    'transactions': [],
#    'location': {'address1': '240-242 Kensington High Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W8 6ND',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['240-242 Kensington High Street',
#      'London W8 6ND',
#      'United Kingdom']},
#    'phone': '+442073716987',
#    'display_phone': '+44 20 7371 6987',
#    'distance': 4670.931155669415},
#   {'id': 'LpIY4AvlAQZqJEZgcFoFPA',
#    'alias': 'the-alchemist-london-3',
#    'name': 'The Alchemist',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NXHurBRaL0gJuLtVnXZAKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-alchemist-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 85,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5150476, 'longitude': -0.0793474},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 Bevis Marks',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3A 7BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Bevis Marks', 'London EC3A 7BA', 'United Kingdom']},
#    'phone': '+442072838800',
#    'display_phone': '+44 20 7283 8800',
#    'distance': 3924.9724248663238},
#   {'id': '7LpeL8dfze0pSaczaeFTuA',
#    'alias': 'cafe-pura-london',
#    'name': 'Cafe Pura',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-A1ObMeAn0HtGL9p1SN70g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-pura-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.494321, 'longitude': 0.013527},
#    'transactions': [],
#    'location': {'address1': '48 Newton Lodge Oval Square',
#     'address2': 'Greenwich Millennium Village',
#     'address3': 'West Parkside',
#     'city': 'London',
#     'zip_code': 'SE10 0BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['48 Newton Lodge Oval Square',
#      'Greenwich Millennium Village',
#      'West Parkside',
#      'London SE10 0BA',
#      'United Kingdom']},
#    'phone': '+442083128383',
#    'display_phone': '+44 20 8312 8383',
#    'distance': 10536.470840121754},
#   {'id': 'xXS34SSivXDzySH9hrAVMw',
#    'alias': 'sagar-london-3',
#    'name': 'Sagar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eMybKvtjl3IWcFoWYRJF4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sagar-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5184954, 'longitude': -0.1327689},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '17a Percy Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 1DU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17a Percy Street',
#      'London W1T 1DU',
#      'United Kingdom']},
#    'phone': '+442076313319',
#    'display_phone': '+44 20 7631 3319',
#    'distance': 666.8664474200509},
#   {'id': 'nMDC_0s833y6uWDzEEIWRA',
#    'alias': 'mi-cocina-es-tuya-london',
#    'name': 'Mi Cocina Es Tuya',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yNj8Y9hOKhmCR7ZaBeJ3HA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mi-cocina-es-tuya-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4177748, 'longitude': -0.0820176},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61 Westow St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE19 3RW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Westow St', 'London SE19 3RW', 'United Kingdom']},
#    'phone': '+442087714078',
#    'display_phone': '+44 20 8771 4078',
#    'distance': 11211.222740392666},
#   {'id': 'iJGo7qT7a8Gu5Em-6KvlLA',
#    'alias': 'maloko-london',
#    'name': 'Maloko',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/csiTsXxDbpwvUlW5Tt6_Nw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maloko-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'african', 'title': 'African'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4736925, 'longitude': -0.0886691},
#    'transactions': [],
#    'location': {'address1': '60 Camberwell Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE5 8TU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['60 Camberwell Church Street',
#      'London SE5 8TU',
#      'United Kingdom']},
#    'phone': '+442033058913',
#    'display_phone': '+44 20 3305 8913',
#    'distance': 5446.218330140674},
#   {'id': 'uSmXcq26qSXpsoLyog_nlA',
#    'alias': 'kin-london-2',
#    'name': 'KIN',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/O4AC6cs6on05YQ1-1xL1oQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kin-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.521448855755,
#     'longitude': -0.10987964543908},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '88 Leather Lane',
#     'address2': 'Clerkenwell',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1N 7TT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['88 Leather Lane',
#      'Clerkenwell',
#      'London EC1N 7TT',
#      'United Kingdom']},
#    'phone': '+442074300886',
#    'display_phone': '+44 20 7430 0886',
#    'distance': 2042.763640692577},
#   {'id': 'gJAFSUO7U70GQJFo3ynRUw',
#    'alias': 'rapsa-london-2',
#    'name': 'Rapsa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fouHC09o9SvAWW-yBPmfbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rapsa-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5310648658011,
#     'longitude': -0.0800106030410461},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '100-104 Hoxton Street',
#     'address2': 'Shoreditch',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 6SG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['100-104 Hoxton Street',
#      'Shoreditch',
#      'London N1 6SG',
#      'United Kingdom']},
#    'phone': '+442077291444',
#    'display_phone': '+44 20 7729 1444',
#    'distance': 4369.319716613212},
#   {'id': 'AwmVZ5X4FicbLUCOlWq3WQ',
#    'alias': 'ravi-shankar-london',
#    'name': 'Ravi Shankar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/w95fi5uiqwEZl21Hq1vWjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ravi-shankar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'pakistani', 'title': 'Pakistani'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.527081, 'longitude': -0.13666},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '133-135 Drummond Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 2HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['133-135 Drummond Street',
#      'London NW1 2HL',
#      'United Kingdom']},
#    'phone': '+442073886458',
#    'display_phone': '+44 20 7388 6458',
#    'distance': 1577.5741864537733},
#   {'id': '8971IC1VEYJyOqsowN99sg',
#    'alias': 'jai-krishna-london',
#    'name': 'Jai Krishna',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DD3_97HUe0GFMVAGwdER0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jai-krishna-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'pakistani', 'title': 'Pakistani'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.570228454423,
#     'longitude': -0.11459932784773},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '161 Stroud Green Road',
#     'address2': 'Finsbury Park',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N4 3PZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['161 Stroud Green Road',
#      'Finsbury Park',
#      'London N4 3PZ',
#      'United Kingdom']},
#    'phone': '+442072721680',
#    'display_phone': '+44 20 7272 1680',
#    'distance': 6550.474704357357},
#   {'id': '-ylzTrYtRJUJa2BuAInoyQ',
#    'alias': 'friends-of-ours-london',
#    'name': 'Friends of Ours',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/q5Fg1_UQtNmvOoIzrLzhAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/friends-of-ours-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 96,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5291189, 'longitude': -0.0836995},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61 Pitfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 6BU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Pitfield Street',
#      'London N1 6BU',
#      'United Kingdom']},
#    'phone': '+442076865525',
#    'display_phone': '+44 20 7686 5525',
#    'distance': 4041.3053965414406},
#   {'id': 'U5KT3ojJN01z9y9Fmf4Bfg',
#    'alias': 'woodlands-restaurant-london',
#    'name': 'Woodlands Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qz0Vt491GiFiUcpFuLabMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/woodlands-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5095919, 'longitude': -0.1315508},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '37 Panton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 4EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['37 Panton Street',
#      'London SW1Y 4EA',
#      'United Kingdom']},
#    'phone': '+442078397258',
#    'display_phone': '+44 20 7839 7258',
#    'distance': 472.2435407967452},
#   {'id': 'gbvQyRDYdS-Deq0e7vLq9w',
#    'alias': 'the-famous-curry-bazaar-london',
#    'name': 'The Famous Curry Bazaar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O2KwXCeqhYYDtDG7HboUYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-famous-curry-bazaar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'bangladeshi', 'title': 'Bangladeshi'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5201642927316,
#     'longitude': -0.0719567060821191},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '77 Brick Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['77 Brick Lane', 'London E1 6QL', 'United Kingdom']},
#    'phone': '+442073751986',
#    'display_phone': '+44 20 7375 1986',
#    'distance': 4502.795608604241},
#   {'id': '2agY-rczZLIERKHB721V2g',
#    'alias': 'veg-london-2',
#    'name': 'Veg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_W4uQKBt7jb3dNNVZXz9Ag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/veg-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.5323647, 'longitude': -0.1064309},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '11 Islington High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9LQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Islington High Street',
#      'London N1 9LQ',
#      'United Kingdom']},
#    'phone': '+442078339399',
#    'display_phone': '+44 20 7833 9399',
#    'distance': 2979.982221249251},
#   {'id': 'zdyKTWY6jDasd6Q8BEJdAw',
#    'alias': 'honest-burgers-meard-st-soho-london',
#    'name': 'Honest Burgers Meard St - Soho',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/z9i_vprbnt7HobB10Z9rDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/honest-burgers-meard-st-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 279,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5134184063764,
#     'longitude': -0.132883885733008},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4a Meard St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0EF',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ['4a Meard St', 'London W1F 0EF', 'United Kingdom']},
#    'phone': '+442036099524',
#    'display_phone': '+44 20 3609 9524',
#    'distance': 222.23970384246957},
#   {'id': 'Y5fRcO7-cjW77hYB5FEwWw',
#    'alias': 'kin-café-london',
#    'name': 'Kin Café',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9LNP7O_W9HIsY7_CuBmVoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kin-caf%C3%A9-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5193586, 'longitude': -0.1404321},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Foley Street',
#     'address2': 'Fitzrovia',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 6DT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Foley Street',
#      'Fitzrovia',
#      'London W1W 6DT',
#      'United Kingdom']},
#    'phone': '+442079984720',
#    'display_phone': '+44 20 7998 4720',
#    'distance': 783.8165958106023},
#   {'id': '7y87XhuSRjPvFC35omEBBA',
#    'alias': 'miranda-cafe-london',
#    'name': 'Miranda Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/M3vcr-cal6gtw9qoaNef6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/miranda-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5811918320925,
#     'longitude': -0.121645116567606},
#    'transactions': [],
#    'location': {'address1': '28 Broadway Parade',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N8 9DB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28 Broadway Parade',
#      'London N8 9DB',
#      'United Kingdom']},
#    'phone': '+442083428989',
#    'display_phone': '+44 20 8342 8989',
#    'distance': 7665.012701357907},
#   {'id': 'E2GbtvuTVKo23qJeyqc82w',
#    'alias': 'ngon-ngon-london',
#    'name': 'Ngon Ngon',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SBpdwMvfefqUnaytAo9epQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ngon-ngon-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5221634, 'longitude': -0.1097323},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '144 Clerkenwell Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 5DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['144 Clerkenwell Road',
#      'London EC1R 5DP',
#      'United Kingdom']},
#    'phone': '+442072784123',
#    'display_phone': '+44 20 7278 4123',
#    'distance': 2089.141888524592},
#   {'id': 'IBV7BsXnv2gX68nWUARhjw',
#    'alias': 'mother-mash-london',
#    'name': 'Mother Mash',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YRdJ5N93Jc3qOIxx_itIRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mother-mash-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 469,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512935, 'longitude': -0.139414},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '26 Ganton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7QZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Ganton Street',
#      'London W1F 7QZ',
#      'United Kingdom']},
#    'phone': '+442074949644',
#    'display_phone': '+44 20 7494 9644',
#    'distance': 235.11523624102102},
#   {'id': '5ctdM8Aiw1K9M6vZ2jUTeA',
#    'alias': 'sen-viet-london',
#    'name': 'Sen Viet',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ABF1MWSeveExGHGD9gDSfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sen-viet-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.529089, 'longitude': -0.1159522},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "119 King's Cross Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1X 9NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["119 King's Cross Road",
#      'London WC1X 9NH',
#      'United Kingdom']},
#    'phone': '+442072782881',
#    'display_phone': '+44 20 7278 2881',
#    'distance': 2278.39375360805},
#   {'id': 'LdHw3LF62o2bUTGvbox_jg',
#    'alias': 'the-feel-good-café-london',
#    'name': 'The Feel Good Café',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5fWoVbzlAXBoMPCjUVWfwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-feel-good-caf%C3%A9-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.63136, 'longitude': 0.0042},
#    'transactions': [],
#    'location': {'address1': 'The Village Arcade',
#     'address2': '49-51 Station Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E4 7DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Village Arcade',
#      '49-51 Station Road',
#      'London E4 7DA',
#      'United Kingdom']},
#    'phone': '+447799965611',
#    'display_phone': '+44 7799 965611',
#    'distance': 16352.22518518916},
#   {'id': 'HRusjUrXGFzMGbA2liIpwQ',
#    'alias': 'foodilic-london',
#    'name': 'Foodilic',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/J4Ao06Ztj3Fulzh-3PE_gQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/foodilic-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.531028014695,
#     'longitude': -0.120225165508865},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '260 Pentonville Road',
#     'address2': 'Kings Cross',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9JY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['260 Pentonville Road',
#      'Kings Cross',
#      'London N1 9JY',
#      'United Kingdom']},
#    'phone': '+442072787887',
#    'display_phone': '+44 20 7278 7887',
#    'distance': 2297.104593983586},
#   {'id': 'lfUDW3AFKicfSZivkYVKBA',
#    'alias': 'ping-pong-london-32',
#    'name': 'Ping Pong',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Iws_eGA6nmKBXnwfjQascg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ping-pong-london-32?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 75,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5153116, 'longitude': -0.150888},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '29 A James Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 1DZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['29 A James Street',
#      'London W1U 1DZ',
#      'United Kingdom']},
#    'phone': '+442070343100',
#    'display_phone': '+44 20 7034 3100',
#    'distance': 1069.3451404139034},
#   {'id': 'e-Tc1FXfJLu0DIWub89EWw',
#    'alias': 'vegan-burgers-by-mooshies-london',
#    'name': 'Vegan Burgers by Mooshies',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fun9Kqqg2Yq3vCOQd4ZVUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vegan-burgers-by-mooshies-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5196543, 'longitude': -0.0715914},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '104 Brick Lane',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['104 Brick Lane', 'London E1 6RL', 'United Kingdom']},
#    'phone': '+447931842458',
#    'display_phone': '+44 7931 842458',
#    'distance': 4509.1968058801385},
#   {'id': 'MI3DDKL7YO38tEF-K-qs_w',
#    'alias': 'bravas-tapas-london',
#    'name': 'Bravas Tapas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gBXCg5l_S-rrzERNRM4meg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bravas-tapas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.507436, 'longitude': -0.071242},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'St Katharine Docks',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1W 1AT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['St Katharine Docks',
#      'London E1W 1AT',
#      'United Kingdom']},
#    'phone': '+442074811464',
#    'display_phone': '+44 20 7481 1464',
#    'distance': 4518.584986283189},
#   {'id': 'NMLg-k71vzunEjY0W79miQ',
#    'alias': 'what-the-pitta-london-2',
#    'name': 'What The Pitta!',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8FZ1iYe3M8oRQgQCqo1Qog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/what-the-pitta-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.53798, 'longitude': -0.14062},
#    'transactions': [],
#    'location': {'address1': '89-91 Bayham Street',
#     'address2': 'Ground Floor Right',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 0AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['89-91 Bayham Street',
#      'Ground Floor Right',
#      'London NW1 0AG',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2805.1135583451523},
#   {'id': 'Ck5cgnj3SlLgieo5hMvHQg',
#    'alias': 'giraffe-london-13',
#    'name': 'Giraffe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hl9fHlqnaKbU4Ijp9hLQAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giraffe-london-13?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 62,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tex-mex', 'title': 'Tex-Mex'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.493899, 'longitude': -0.1423036},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '120 Wilton Rd',
#     'address2': '',
#     'address3': 'Victoria',
#     'city': 'London',
#     'zip_code': 'SW1V 1JZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['120 Wilton Rd',
#      'Victoria',
#      'London SW1V 1JZ',
#      'United Kingdom']},
#    'phone': '+442072338303',
#    'display_phone': '+44 20 7233 8303',
#    'distance': 2150.9932845349713},
#   {'id': '_faDmrUFilwMxk0atkXjNA',
#    'alias': 'the-dove-london-3',
#    'name': 'The Dove',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/e4-NZ4Ue4Fg45Xp3GAABcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dove-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'belgian', 'title': 'Belgian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5363390811417,
#     'longitude': -0.0618530896556768},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '24-26 Broadway Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 4QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24-26 Broadway Market',
#      'London E8 4QJ',
#      'United Kingdom']},
#    'phone': '+442072757617',
#    'display_phone': '+44 20 7275 7617',
#    'distance': 5754.37208734647},
#   {'id': 'pD0FFxeSxvd997eVE81I0g',
#    'alias': 'sourced-market-london-2',
#    'name': 'Sourced Market',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zPTwY9NsUZw6ERkLbS4Jhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sourced-market-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.532036, 'longitude': -0.126343},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'St Pancras International',
#     'address2': 'Pancras Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['St Pancras International',
#      'Pancras Road',
#      'London N1C 4QL',
#      'United Kingdom']},
#    'phone': '+442078339352',
#    'display_phone': '+44 20 7833 9352',
#    'distance': 2236.1846304921187},
#   {'id': 'wRIvr7m40Mjxx-H8BYietw',
#    'alias': 'the-grain-shop-london',
#    'name': 'The Grain Shop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rfDaHhGh8BXGraLbnXKrZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grain-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51786, 'longitude': -0.206798},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '269A Portobello Road',
#     'address2': 'London',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 1LR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['269A Portobello Road',
#      'London',
#      'London W11 1LR',
#      'United Kingdom']},
#    'phone': '+442072295571',
#    'display_phone': '+44 20 7229 5571',
#    'distance': 4939.073370845596},
#   {'id': 'ytIFY2JvU-zcd1FsonES5w',
#    'alias': 'about-thyme-london',
#    'name': 'About Thyme',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Mh4BT2kuTfm_NFGpOQRFXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/about-thyme-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4924969, 'longitude': -0.1399836},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '82 Wilton Road',
#     'address2': 'Pimlico',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['82 Wilton Road',
#      'Pimlico',
#      'London SW1V 1DL',
#      'United Kingdom']},
#    'phone': '+442078217504',
#    'display_phone': '+44 20 7821 7504',
#    'distance': 2281.829545906066},
#   {'id': 'Nis31-vJHsaD9BaUoCrXDw',
#    'alias': 'ev-restaurant-london-2',
#    'name': 'Ev Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_alT4XAOtg6386taM50zLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ev-restaurant-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'turkish', 'title': 'Turkish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5041, 'longitude': -0.106221},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '97-99 Isabella Street',
#     'address2': '',
#     'address3': 'The Arches',
#     'city': 'London',
#     'zip_code': 'SE1 8DD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['97-99 Isabella Street',
#      'The Arches',
#      'London SE1 8DD',
#      'United Kingdom']},
#    'phone': '+442076206191',
#    'display_phone': '+44 20 7620 6191',
#    'distance': 2275.5989720883913},
#   {'id': 'LHgANF39rcuiRaJv1ibi3Q',
#    'alias': 'cafe-silka-london',
#    'name': 'Cafe Silka',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dXKH1RIlHobxnESepI9n8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-silka-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.499434608424,
#     'longitude': -0.053143651424866},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '30 Albion Street',
#     'address2': 'Rotherhithe',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE16 7JQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Albion Street',
#      'Rotherhithe',
#      'London SE16 7JQ',
#      'United Kingdom']},
#    'phone': '+442072372122',
#    'display_phone': '+44 20 7237 2122',
#    'distance': 5922.05480538581},
#   {'id': 'tIfB4hNVr0aQC7BkYZYO7A',
#    'alias': 'sunnys-olive-tree-london-3',
#    'name': "Sunny's Olive Tree",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VrJtwZ7KomSkGjrsWIPHFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sunnys-olive-tree-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.522898, 'longitude': -0.0928},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Whitecross Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 9AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Whitecross Street',
#      'London EC1V 9AB',
#      'United Kingdom']},
#    'phone': '+447956938194',
#    'display_phone': '+44 7956 938194',
#    'distance': 3188.8344806562486},
#   {'id': 'Ldwq1_0iRTUth1q0DoaojQ',
#    'alias': 'jamaica-patty-co-london',
#    'name': 'Jamaica Patty Co.',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UiyXca4f0OqJy7OvhQlc8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jamaica-patty-co-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51113, 'longitude': -0.126663},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '26 New Row',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 New Row', 'London WC2N 4LA', 'United Kingdom']},
#    'phone': '+442078363334',
#    'display_phone': '+44 20 7836 3334',
#    'distance': 670.4631368301312},
#   {'id': 'R1UKQHTz65dQKkdLjzVEBg',
#    'alias': 'dishoom-london-3',
#    'name': 'Dishoom',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Gy-vIVmqUc_fHHnFcdje6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dishoom-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 385,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5363182978271,
#     'longitude': -0.125145272091882},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5 Stable Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Stable Street',
#      'London N1C 4AB',
#      'United Kingdom']},
#    'phone': '+442074209321',
#    'display_phone': '+44 20 7420 9321',
#    'distance': 2716.1616871636725},
#   {'id': 'yHfKmtOcekcyWE9eyNmNmw',
#    'alias': 'bucci-restaurant-london',
#    'name': 'Bucci Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FXKsE8h7DhW9jPOiSZG_-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bucci-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4413043, 'longitude': -0.1544355},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '195 Balham High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW12 9BE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['195 Balham High Road',
#      'London SW12 9BE',
#      'United Kingdom']},
#    'phone': '+442086735459',
#    'display_phone': '+44 20 8673 5459',
#    'distance': 8030.270025637166},
#   {'id': 'GUyS7KWsvqSNPz1mYMD8Bw',
#    'alias': 'river-view-chinese-restaurant-london',
#    'name': 'River View Chinese Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZY5GwePLD-her7xPmsiDgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/river-view-chinese-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.50579, 'longitude': -0.05393},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'New Crane Wharf',
#     'address2': 'New Crane Place',
#     'address3': 'Whapping',
#     'city': 'London',
#     'zip_code': 'E1W 3TU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['New Crane Wharf',
#      'New Crane Place',
#      'Whapping',
#      'London E1W 3TU',
#      'United Kingdom']},
#    'phone': '+442074806026',
#    'display_phone': '+44 20 7480 6026',
#    'distance': 5708.722216073941},
#   {'id': '6kz1DOu387HO_4wKORt3Wg',
#    'alias': 'hawraman-cafe-bar-london',
#    'name': 'Hawraman Cafe Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2zdZUtRHTt5wyF9EMGWZ7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hawraman-cafe-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.542848, 'longitude': -0.1483066},
#    'transactions': [],
#    'location': {'address1': '38 Chalk Farm Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38 Chalk Farm Road',
#      'London NW1 8AJ',
#      'United Kingdom']},
#    'phone': '+447737892812',
#    'display_phone': '+44 7737 892812',
#    'distance': 3444.868877567905},
#   {'id': 'zJNI06Y2zZQFh9OBSFCdgQ',
#    'alias': 'sketch-london-2',
#    'name': 'Sketch',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pAEJmqSJX1lh_pLuvjbFww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sketch-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 831,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5127614699071,
#     'longitude': -0.14159163911048},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '9 Conduit Street',
#     'address2': 'Mayfair',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 2XG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Conduit Street',
#      'Mayfair',
#      'London W1S 2XG',
#      'United Kingdom']},
#    'phone': '+442076594500',
#    'display_phone': '+44 20 7659 4500',
#    'distance': 390.09161644125044},
#   {'id': 'HaUEkzqd8ahjouFlhvq1tQ',
#    'alias': 'pickles-london-2',
#    'name': 'Pickles',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rt8BFFy1puq4RDeSw_sVEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pickles-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.501011, 'longitude': -0.130923},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '6 Old Queen Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1H 9HP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Old Queen Street',
#      'London SW1H 9HP',
#      'United Kingdom']},
#    'phone': '+442072228749',
#    'display_phone': '+44 20 7222 8749',
#    'distance': 1380.8110470930878},
#   {'id': 'XeAaUJWcS9RZsE80a1UxjA',
#    'alias': 'mestizo-london',
#    'name': 'Mestizo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m15vQhfhss5ycfcdVatg7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mestizo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 153,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.52752, 'longitude': -0.1387649},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '103 Hampstead Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 3EL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['103 Hampstead Road',
#      'London NW1 3EL',
#      'United Kingdom']},
#    'phone': '+442073874064',
#    'display_phone': '+44 20 7387 4064',
#    'distance': 1656.1089625620355}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#               Restaurant             Type Price Rating  \
# 0                Sandy's            Pizza    ££      4
# 1                 Mohsen  Persian/Iranian    ££    4.5
# 2              The Table          British    ££      4
# 3  Goddards at Greenwich          British     £    4.5
# 4      Arancini Brothers          Italian     £    4.5
#
#                   Address        Lat       Lng  \
# 0        14 Seymour Place  51.514885 -0.161040
# 1        152 Warwick Road  51.495177 -0.203020
# 2     83 Southwark Street  51.505604 -0.099671
# 3    22 King William Walk  51.481209 -0.008332
# 4  115A Kentish Town Road  51.518962 -0.083633
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/sandys-london?adjust_...  m2XtIGSfOtXqTfR7ij-kzg
# 1  https://www.yelp.com/biz/mohsen-london?adjust_...  q7Oz1gTCgoQkFu3VoOQrDQ
# 2  https://www.yelp.com/biz/the-table-london-8?ad...  rKwkCvsSfp8z7w1CmNnMMQ
# 3  https://www.yelp.com/biz/goddards-at-greenwich...  MaNE6xr9_bqpIWCLm5VhkA
# 4  https://www.yelp.com/biz/arancini-brothers-lon...  M5U_bhEd5J5isIQ5u9UsLQ

# %%
london_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
london_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_restaurants_df = london_restaurants_df[column_order]
london_restaurants_df = london_restaurants_df.sort_values(["Type"], ascending=True)
london_restaurants_df = london_restaurants_df.reset_index(drop=True)
london_restaurants_df
# Out:
#                               Restaurant                Type Rating Price  \
# 0                          The Bike Shed         Accessories    4.5    ££
# 1                         Afghan Kitchen              Afghan      4    ££
# 2                                 Maloko             African
# 3                            Firecracker        Asian Fusion      4    ££
# 4                                Chai Ki        Asian Fusion      4    ££
# 5                            Banana Tree        Asian Fusion      4    ££
# 6                                  Rapsa        Asian Fusion    4.5    ££
# 7                                    KIN        Asian Fusion      4    ££
# 8                             Ottolenghi            Bakeries      4    ££
# 9                    Duck & Waffle Local                Bars    4.5    ££
# 10                            Redemption                Bars
# 11                       Greenberry Café          Brasseries      4    ££
# 12                   Balans Soho Society  Breakfast & Brunch      4    ££
# 13                  The Good Life Eatery  Breakfast & Brunch      4    ££
# 14                                Andina  Breakfast & Brunch      4    ££
# 15                   Caravan Kings Cross  Breakfast & Brunch      4    ££
# 16                            Simplicity  Breakfast & Brunch    3.5    ££
# 17                        Piebury Corner             British      5     £
# 18                          The Orangery             British      4   £££
# 19                                 Niche             British      4    ££
# 20                               Giraffe             British      4    ££
# 21                 Goddards at Greenwich             British    4.5     £
# 22                     Plum & Spilt Milk             British      4   £££
# 23                           Mother Mash             British      4    ££
# 24                        Maggie Jones's             British    4.5   £££
# 25                             The Table             British      4    ££
# 26                       The Blue Legume             British      4    ££
# 27                               Dou Dou             Buffets    4.5     £
# 28        Honest Burgers Meard St - Soho             Burgers    4.5    ££
# 29                       Friends of Ours               Cafes    4.5    ££
# ..                                   ...                 ...    ...   ...
# 170                     222 Veggie Vegan          Vegetarian      4    ££
# 171                       The Grain Shop          Vegetarian      4     £
# 172                                Ethos          Vegetarian      4    ££
# 173                       Wild Food Cafe          Vegetarian      4    ££
# 174                       Koshari Street          Vegetarian    4.5     £
# 175                               Tibits          Vegetarian      4    ££
# 176                             The Gate          Vegetarian
# 177                             Squirrel          Vegetarian      4     £
# 178                         Cafe Pushkar          Vegetarian    3.5    ££
# 179                             The Gate          Vegetarian
# 180  Delhiwala Restaurant & Sweet Centre          Vegetarian
# 181                                Sagar          Vegetarian      4    ££
# 182                             The Gate          Vegetarian    4.5   £££
# 183                               Levant          Vegetarian      4  ££££
# 184                        Vanilla Black          Vegetarian      4   £££
# 185                      Bonnington Café          Vegetarian      4     £
# 186                             The Gate          Vegetarian      4    ££
# 187              The Riverside Vegetaria          Vegetarian      4    ££
# 188                     Vijay's Chawalla          Vegetarian      4    ££
# 189                            Cafe Pura          Vegetarian
# 190                                  Veg          Vegetarian    2.5     £
# 191                            Carnevale          Vegetarian      4    ££
# 192                      My Village Café          Vegetarian      4     £
# 193                 Govinda's Restaurant          Vegetarian      4     £
# 194                           The Canary          Vegetarian      5     £
# 195                               Pilpel          Vegetarian    4.5     £
# 196                            Ngon Ngon          Vietnamese    4.5    ££
# 197                             Sen Viet          Vietnamese      4    ££
# 198            BunBunBun Vietnamese Food          Vietnamese    4.5    ££
# 199                            Cafe East          Vietnamese      4     £
#
#                           Address        Lat       Lng  \
# 0                  384 Old Street  51.527090 -0.078215
# 1              35 Islington Green  51.535786 -0.103038
# 2     60 Camberwell Church Street  51.473692 -0.088669
# 3              44 Horseferry Road  51.494985 -0.127124
# 4                 Crossrail Place  51.506224 -0.018067
# 5            75-79 Battersea Rise  51.460635 -0.166301
# 6           100-104 Hoxton Street  51.531065 -0.080011
# 7                 88 Leather Lane  51.521449 -0.109880
# 8                 63 Ledbury Road  51.514891 -0.199418
# 9                    52 Haymarket  51.509418 -0.132750
# 10                6 Chepstow Road  51.515577 -0.195027
# 11          101 Regents Park Road  51.542194 -0.156334
# 12     187 Kensington High Street  51.499983 -0.195664
# 13               59 Sloane Avenue  51.491955 -0.165339
# 14             1 Redchurch Street  51.524321 -0.077135
# 15               1 Granary Square  51.535779 -0.125371
# 16                  1 Tunnel Road  51.501247 -0.053137
# 17          209-211 Holloway Road  51.550990 -0.110410
# 18              Kensington Palace  51.506636 -0.187725
# 19        197-199 Rosebery Avenue  51.529939 -0.105479
# 20                  120 Wilton Rd  51.493899 -0.142304
# 21           22 King William Walk  51.481209 -0.008332
# 22            King's Cross Street  51.532379 -0.125460
# 23               26 Ganton Street  51.512935 -0.139414
# 24              6 Old Court Place  51.502856 -0.190992
# 25            83 Southwark Street  51.505604 -0.099671
# 26                   177 Upper St  51.541374 -0.103168
# 27                    Camden Town  51.539630 -0.142253
# 28                    4a Meard St  51.513418 -0.132884
# 29             61 Pitfield Street  51.529119 -0.083699
# ..                            ...        ...       ...
# 170            222 North End Road  51.486007 -0.203086
# 171          269A Portobello Road  51.517860 -0.206798
# 172          48 Eastcastle Street  51.516380 -0.139097
# 173                     1st Floor  51.514475 -0.126376
# 174             56 St Martin's Ln  51.510941 -0.126831
# 175           12-14 Heddon Street  51.511303 -0.139625
# 176              87 Allitsen Road  51.533700 -0.169340
# 177            11 Harrington Road  51.493950 -0.175585
# 178          424 Coldharbour Lane  51.461640 -0.113610
# 179           22-24 Seymour Place  51.515133 -0.161105
# 180         72 Vicarage Farm Road  51.477475 -0.383810
# 181              17a Percy Street  51.518495 -0.132769
# 182      51 Queen Caroline Street  51.490250 -0.225440
# 183                   Jason Court  51.516215 -0.150666
# 184            17-18 Took's Court  51.517176 -0.111025
# 185             11 Vauxhall Grove  51.484623 -0.120028
# 186            370 St John Street  51.530167 -0.105153
# 187                64 High Street  51.407239 -0.308125
# 188          268-270 Green Street  51.538700  0.033255
# 189   48 Newton Lodge Oval Square  51.494321  0.013527
# 190      11 Islington High Street  51.532365 -0.106431
# 191         135 Whitecross Street  51.522896 -0.092986
# 192            37 Chalk Farm Road  51.542755 -0.147691
# 193                10 Soho Street  51.515878 -0.132808
# 194  61-63 Old Bethnal Green Road  51.529491 -0.060922
# 195          38 Brushfield Street  51.518956 -0.077277
# 196          144 Clerkenwell Road  51.522163 -0.109732
# 197         119 King's Cross Road  51.529089 -0.115952
# 198           134B Kingsland Road  51.531788 -0.076831
# 199              100 Redriff Road  51.496294 -0.041542
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/the-bike-shed-london?...  BNdzjiLoibX1uSH4kAQy5w
# 1    https://www.yelp.com/biz/afghan-kitchen-london...  nsiUDhW2nBLaW_JCM4gmxg
# 2
# 3    https://www.yelp.com/biz/firecracker-london?ad...  y9MWERu8ULGHhMKaDn8F2Q
# 4    https://www.yelp.com/biz/chai-ki-london-2?adju...  cLyL7ABwhjdkQcREkeOCEw
# 5    https://www.yelp.com/biz/banana-tree-london-7?...  RaIZ-cnvuSM3wLDuQkl-aw
# 6    https://www.yelp.com/biz/rapsa-london-2?adjust...  gJAFSUO7U70GQJFo3ynRUw
# 7    https://www.yelp.com/biz/kin-london-2?adjust_c...  uSmXcq26qSXpsoLyog_nlA
# 8    https://www.yelp.com/biz/ottolenghi-london-3?a...  L-ZNTln24SoU_jYia4M19Q
# 9    https://www.yelp.com/biz/duck-and-waffle-local...  a4FkZ2b7Wn3-AP7q3ptHtQ
# 10
# 11   https://www.yelp.com/biz/greenberry-caf%C3%A9-...  T-_ewkgY9DiMJ36qHL4UvQ
# 12   https://www.yelp.com/biz/balans-soho-society-l...  OLXUZqx6doQtdeHfyEoyOw
# 13   https://www.yelp.com/biz/the-good-life-eatery-...  h7I2R6d3x1yVYDj0PVhZaw
# 14   https://www.yelp.com/biz/andina-london?adjust_...  vCF8ut7OZcfA4hEmhngfSQ
# 15   https://www.yelp.com/biz/caravan-kings-cross-l...  B6ayHXLwfYBuIADficAeMg
# 16   https://www.yelp.com/biz/simplicity-london?adj...  a50cdpgVp7afE2-WU3fQ7Q
# 17   https://www.yelp.com/biz/piebury-corner-london...  HaYOqwNtC6JK2uuGmr1KGg
# 18   https://www.yelp.com/biz/the-orangery-london-7...  PBFvhVyBi0lEJyTbyuxf5w
# 19   https://www.yelp.com/biz/niche-london-5?adjust...  NCj4ufnnu9iJuJVy_15nxw
# 20   https://www.yelp.com/biz/giraffe-london-13?adj...  Ck5cgnj3SlLgieo5hMvHQg
# 21   https://www.yelp.com/biz/goddards-at-greenwich...  MaNE6xr9_bqpIWCLm5VhkA
# 22   https://www.yelp.com/biz/plum-and-spilt-milk-l...  Y51qImK_hOk-AaT5c5yC2w
# 23   https://www.yelp.com/biz/mother-mash-london?ad...  IBV7BsXnv2gX68nWUARhjw
# 24   https://www.yelp.com/biz/maggie-joness-london-...  5tAAwu7ZDhulLsyt09bXnw
# 25   https://www.yelp.com/biz/the-table-london-8?ad...  rKwkCvsSfp8z7w1CmNnMMQ
# 26   https://www.yelp.com/biz/the-blue-legume-londo...  bOEPov-chRVQhggY5k805w
# 27   https://www.yelp.com/biz/dou-dou-london?adjust...  CEPduoos73caV6mfrtxH-A
# 28   https://www.yelp.com/biz/honest-burgers-meard-...  zdyKTWY6jDasd6Q8BEJdAw
# 29   https://www.yelp.com/biz/friends-of-ours-londo...  -ylzTrYtRJUJa2BuAInoyQ
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/222-veggie-vegan-lond...  R4yaSL1PT2mpt5yNX2U7AA
# 171  https://www.yelp.com/biz/the-grain-shop-london...  wRIvr7m40Mjxx-H8BYietw
# 172  https://www.yelp.com/biz/ethos-london-4?adjust...  5u3SgBbNRJAPfzzffLD42w
# 173  https://www.yelp.com/biz/wild-food-cafe-london...  1_nby6Ob2JH8kaOvVdk7_Q
# 174  https://www.yelp.com/biz/koshari-street-london...  bRACQuON_142mYHqaifaGQ
# 175  https://www.yelp.com/biz/tibits-london-3?adjus...  DnBY9gukSdy42EoJtBhdaQ
# 176
# 177  https://www.yelp.com/biz/squirrel-london?adjus...  rLjRU-MRorU36kc2Xq0zSQ
# 178  https://www.yelp.com/biz/cafe-pushkar-london?a...  -PnReVDp_G_OfuJMQ0TOzg
# 179
# 180
# 181  https://www.yelp.com/biz/sagar-london-3?adjust...  xXS34SSivXDzySH9hrAVMw
# 182  https://www.yelp.com/biz/the-gate-london-8?adj...  aX0nQBilAGDtVNWQMRUqqg
# 183  https://www.yelp.com/biz/levant-london?adjust_...  cIqYqd3aRSmfkklAC_ENhw
# 184  https://www.yelp.com/biz/vanilla-black-london?...  HzyhCXPooUGWvuPYOfT0WA
# 185  https://www.yelp.com/biz/bonnington-caf%C3%A9-...  5rGACVUL-kFwJt0LMgHRBA
# 186  https://www.yelp.com/biz/the-gate-london-18?ad...  xKhxUFGjQCayQbYaJ9UBfg
# 187  https://www.yelp.com/biz/the-riverside-vegetar...  hFR06IFzwrs6RgM6r3W1VA
# 188  https://www.yelp.com/biz/vijays-chawalla-londo...  E1i7l8_bh3yiRjNkJpPSwg
# 189
# 190  https://www.yelp.com/biz/veg-london-2?adjust_c...  2agY-rczZLIERKHB721V2g
# 191  https://www.yelp.com/biz/carnevale-london?adju...  zqr54R-hh99HCPaujuLpXQ
# 192  https://www.yelp.com/biz/my-village-caf%C3%A9-...  z3xc2E24kl-kWjEG3Gi_3w
# 193  https://www.yelp.com/biz/govindas-restaurant-l...  PCP32dk4euUG21mX0kp5aw
# 194  https://www.yelp.com/biz/the-canary-london-2?a...  elEmETsx5rVcCeIg7a2yXw
# 195  https://www.yelp.com/biz/pilpel-london?adjust_...  2hWE0g0lCJt97WQY4o2Q-g
# 196  https://www.yelp.com/biz/ngon-ngon-london?adju...  E2GbtvuTVKo23qJeyqc82w
# 197  https://www.yelp.com/biz/sen-viet-london?adjus...  5ctdM8Aiw1K9M6vZ2jUTeA
# 198  https://www.yelp.com/biz/bunbunbun-vietnamese-...  VovLxnCCWutZhE9NnSD9NA
# 199  https://www.yelp.com/biz/cafe-east-london-2?ad...  rlgecmgj4sTj1-BapJBg_Q
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
london_restaurants_df.to_csv('Resources/London_Restaurants_Vegetarian.csv')
