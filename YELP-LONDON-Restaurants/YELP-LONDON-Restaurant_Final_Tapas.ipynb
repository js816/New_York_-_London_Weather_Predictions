# %% [markdown]
# LONDON RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
term = "tapas"

# %%
#First set of 50 records 0-50
lndr_params1 = {"term":term,"location":"London","limit":50,"offset":0}
lndr_response1 = requests.get(search_api_url, headers=headers, params=lndr_params1)
lndr1 = lndr_response1.json()
display(lndr1)
#print(lndr_response1.url)
#print(lndr_response1.status_code)
# Out:
# {'businesses': [{'id': 'LVtracBONt-BsZ4Vr8_z_g',
#    'alias': 'barrafina-london-5',
#    'name': 'Barrafina',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0kA5JH9_U-9S9jC0WOt5hQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barrafina-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5143394, 'longitude': -0.1219044},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '43 Drury Lane',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5RT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['43 Drury Lane',
#      'Covent Garden',
#      'London WC2B 5RT',
#      'United Kingdom']},
#    'phone': '+442074401456',
#    'display_phone': '+44 20 7440 1456',
#    'distance': 987.2181531651347},
#   {'id': 't_O2xY53TW3z8X6eyQp2bQ',
#    'alias': 'tapas-brindisa-london-4',
#    'name': 'Tapas Brindisa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TE48ZUyEYOrT8eRdRxOUIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tapas-brindisa-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.513468865838,
#     'longitude': -0.13664590618241},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '46 Broadwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['46 Broadwick Street',
#      'London W1F 7AF',
#      'United Kingdom']},
#    'phone': '+442075341690',
#    'display_phone': '+44 20 7534 1690',
#    'distance': 85.0891297565369},
#   {'id': 'qvO0hYRegZI5bCEk1cNoOQ',
#    'alias': 'barrafina-london-6',
#    'name': 'Barrafina',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/N8X17KIIbkWHZXnQL57deg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barrafina-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514227, 'longitude': -0.132764},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '26 Dean Street',
#     'address2': 'Soho',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1D 3LL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Dean Street',
#      'Soho',
#      'London W1D 3LL',
#      'United Kingdom']},
#    'phone': '+442074401456',
#    'display_phone': '+44 20 7440 1456',
#    'distance': 269.6751284969637},
#   {'id': 'oERtgNeSaDE0XRPmGEP4uQ',
#    'alias': 'donostia-london',
#    'name': 'Donostia',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IL59HrjhZzvzWMeHbdepPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/donostia-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.514732, 'longitude': -0.160959},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '10 Seymour Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7ND',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Seymour Place',
#      'London W1H 7ND',
#      'United Kingdom']},
#    'phone': '+442036201845',
#    'display_phone': '+44 20 3620 1845',
#    'distance': 1745.9272851654525},
#   {'id': 'MI3DDKL7YO38tEF-K-qs_w',
#    'alias': 'bravas-tapas-london',
#    'name': 'Bravas Tapas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gBXCg5l_S-rrzERNRM4meg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bravas-tapas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.507436, 'longitude': -0.071242},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'St Katharine Docks',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1W 1AT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['St Katharine Docks',
#      'London E1W 1AT',
#      'United Kingdom']},
#    'phone': '+442074811464',
#    'display_phone': '+44 20 7481 1464',
#    'distance': 4518.584986283189},
#   {'id': 'GtjaGgiKiMPxjPcPtxgUiQ',
#    'alias': 'josé-london-2',
#    'name': 'José',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2uk2nHSKkyOgABWB3JivcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jos%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 82,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5004996, 'longitude': -0.0819549},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '104 Bermondsey Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 3UB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['104 Bermondsey Street',
#      'London SE1 3UB',
#      'United Kingdom']},
#    'phone': '+442074034902',
#    'display_phone': '+44 20 7403 4902',
#    'distance': 3976.1955339893666},
#   {'id': 'oHChMAEdji2RzwQXHdMvoA',
#    'alias': 'carmen-bar-de-tapas-london',
#    'name': 'Carmen Bar De Tapas',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5nDyjwBu3yU4T6Z83l7ocQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carmen-bar-de-tapas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.461562, 'longitude': -0.137833},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 Clapham Common South Side',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW4 7AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Clapham Common South Side',
#      'London SW4 7AA',
#      'United Kingdom']},
#    'phone': '+442076226848',
#    'display_phone': '+44 20 7622 6848',
#    'distance': 5691.107885369147},
#   {'id': 'wS__WuvZNx23gdDQG7c7iQ',
#    'alias': 'mar-i-terra-london-2',
#    'name': 'Mar I Terra',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tENkxDqL4M-faaWwMvq5Pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mar-i-terra-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.504343, 'longitude': -0.102645},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 Gambia Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0XH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Gambia Street',
#      'London SE1 0XH',
#      'United Kingdom']},
#    'phone': '+442079287628',
#    'display_phone': '+44 20 7928 7628',
#    'distance': 2483.814561468635},
#   {'id': 'NtAndbH_o7DQLLDz-wuGlA',
#    'alias': 'condesa-london',
#    'name': 'Condesa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m27d3sgV7Z5cPti--ZVG5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/condesa-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5106, 'longitude': -0.123181},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '15 Maiden Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 7NG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Maiden Lane',
#      'London WC2E 7NG',
#      'United Kingdom']},
#    'phone': '+442036015752',
#    'display_phone': '+44 20 3601 5752',
#    'distance': 915.4460650530785},
#   {'id': 'xvr5aSeoJg5ZAJM4FG99xg',
#    'alias': 'barrafina-london-4',
#    'name': 'Barrafina',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HplQzy1vFSfXkqV7SKn9Vw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barrafina-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 65,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5093806, 'longitude': -0.1258185},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '10 Adelaide Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4HZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Adelaide Street',
#      'London WC2N 4HZ',
#      'United Kingdom']},
#    'phone': '+442074401456',
#    'display_phone': '+44 20 7440 1456',
#    'distance': 799.8381109808604},
#   {'id': 'mPco-JtqwgjMxvghVyKlzg',
#    'alias': 'el-parador-london',
#    'name': 'El Parador',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NOMi4m-JmsuD_PxIIQMxog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-parador-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5335736, 'longitude': -0.1377578},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '245 Eversholt Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 1BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['245 Eversholt Street',
#      'London NW1 1BA',
#      'United Kingdom']},
#    'phone': '+442073872789',
#    'display_phone': '+44 20 7387 2789',
#    'distance': 2313.0649324231913},
#   {'id': 'iJPlkSdTPp1I3vHf00rk5Q',
#    'alias': 'iberica-marylebone-2',
#    'name': 'Iberica',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kDPF89nbh0yv1TIYm4VT7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/iberica-marylebone-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 76,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.522476, 'longitude': -0.143939},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '195 Great Portland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Marylebone',
#     'zip_code': 'W1W 5PS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['195 Great Portland Street',
#      'Marylebone W1W 5PS',
#      'United Kingdom']},
#    'phone': '+442030265118',
#    'display_phone': '+44 20 3026 5118',
#    'distance': 1205.923616612702},
#   {'id': '-YaDerXncRbSx9uSo9UcKg',
#    'alias': 'iberica-london-16',
#    'name': 'Iberica',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ySACET2arBcFRaBBD8tmIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/iberica-london-16?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4974346, 'longitude': -0.138477},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Unit 5- 6 Zig Zag Building',
#     'address2': '68 Victoria Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1E 6SQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 5- 6 Zig Zag Building',
#      '68 Victoria Street',
#      'London SW1E 6SQ',
#      'United Kingdom']},
#    'phone': '+442030265118',
#    'display_phone': '+44 20 3026 5118',
#    'distance': 1721.3698174281649},
#   {'id': 'VUH8CQe3GazQKtDIxCNixQ',
#    'alias': 'cambio-de-tercio-london',
#    'name': 'Cambio De Tercio',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/T5Llbgy4N2vBKUDMIRKyXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cambio-de-tercio-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.490747737127, 'longitude': -0.1836244573671},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '163 Old Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 0LJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['163 Old Brompton Road',
#      'London SW5 0LJ',
#      'United Kingdom']},
#    'phone': '+442072448970',
#    'display_phone': '+44 20 7244 8970',
#    'distance': 4113.265005675445},
#   {'id': 'YdnTx95kgD9WLygV3FTxSA',
#    'alias': 'the-port-house-london',
#    'name': 'The Port House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Tfnd4sV2gurl_SavuD8auQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-port-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.509936, 'longitude': -0.123138},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '417 Strand',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2R 0PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['417 Strand',
#      'Covent Garden',
#      'London WC2R 0PD',
#      'United Kingdom']},
#    'phone': '+442078367764',
#    'display_phone': '+44 20 7836 7764',
#    'distance': 943.808997103807},
#   {'id': 'bibItX92d7LSCVThLeXb8Q',
#    'alias': 'tapas-brindisa-london-2',
#    'name': 'Tapas Brindisa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vU-8O_rQswlRyb1t-T9ZYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tapas-brindisa-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 133,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.504908, 'longitude': -0.0905255},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18-20 Southwark Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1TJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18-20 Southwark Street',
#      'London SE1 1TJ',
#      'United Kingdom']},
#    'phone': '+442073578880',
#    'display_phone': '+44 20 7357 8880',
#    'distance': 3266.5497816662755},
#   {'id': '3c3ykVq81dFQLAeFwoRZmQ',
#    'alias': 'jamon-jamon-camden-london',
#    'name': 'Jamon Jamon Camden',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aH_UfISsf5VNCia77mOKxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jamon-jamon-camden-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5383545583328,
#     'longitude': -0.144474506378174},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '38 Parkway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 7AH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38 Parkway', 'London NW1 7AH', 'United Kingdom']},
#    'phone': '+442072840606',
#    'display_phone': '+44 20 7284 0606',
#    'distance': 2898.137667537523},
#   {'id': 'rkcEjJ3uvbL40Wd-Xufsdg',
#    'alias': 'don-pepe-london',
#    'name': 'Don Pepe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Pp_T_y9XHGGYYpz3yf6ztA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/don-pepe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5236, 'longitude': -0.174362},
#    'transactions': [],
#    'location': {'address1': '99 Framton Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW8 8NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['99 Framton Street',
#      'London NW8 8NA',
#      'United Kingdom']},
#    'phone': '+442072623834',
#    'display_phone': '+44 20 7262 3834',
#    'distance': 2914.554190493479},
#   {'id': 'nBZxw8KselF6esBLUH24Ww',
#    'alias': 'lobos-meat-and-tapas-london',
#    'name': 'Lobos Meat and Tapas',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sgeV-HnKqFpj7_92l0052g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lobos-meat-and-tapas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5056258, 'longitude': -0.0891513},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '14 Borough High Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9QG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Borough High Street',
#      'London SE1 9QG',
#      'United Kingdom']},
#    'phone': '+442074075361',
#    'display_phone': '+44 20 7407 5361',
#    'distance': 3336.9028620120794},
#   {'id': 'i3xsDQYHD24T9Z8F56vdGw',
#    'alias': 'tostado-london',
#    'name': 'Tostado',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/R9pkNVuappogNEicQzFqkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tostado-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5143373573821,
#     'longitude': -0.134182901535516},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "16a St Anne's Court",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0BG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["16a St Anne's Court",
#      'London W1F 0BG',
#      'United Kingdom']},
#    'phone': '+442072873000',
#    'display_phone': '+44 20 7287 3000',
#    'distance': 207.21816626116814},
#   {'id': 'BVlzDuPtmnupkLA41HaH5A',
#    'alias': 'twist-london-2',
#    'name': 'Twist',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CRPc40A541zsYAK94rJxig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/twist-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5193012900495,
#     'longitude': -0.16238228962316},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '42 Crawford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 1JW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 Crawford Street',
#      'London W1H 1JW',
#      'United Kingdom']},
#    'phone': '+442077233377',
#    'display_phone': '+44 20 7723 3377',
#    'distance': 1964.8674457885131},
#   {'id': 'ylrlHx0eyaBDA9qSICY1HQ',
#    'alias': 'hispania-london',
#    'name': 'Hispania',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GztmoVs1frKU-YZ4TERP9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hispania-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51297, 'longitude': -0.0877973},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '72-74 Lombard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3V 9AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['72-74 Lombard Street',
#      'London EC3V 9AY',
#      'United Kingdom']},
#    'phone': '+442076210338',
#    'display_phone': '+44 20 7621 0338',
#    'distance': 3353.2707516390033},
#   {'id': '02fYko-o-LDt6g0agcNZsg',
#    'alias': 'boqueria-london',
#    'name': 'Boqueria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/b4du7u9Ja5tirLua4rGvWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boqueria-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.459870028924,
#     'longitude': -0.12713936531653},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '192 Acre Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW2 5UL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['192 Acre Lane', 'London SW2 5UL', 'United Kingdom']},
#    'phone': '+442077334408',
#    'display_phone': '+44 20 7733 4408',
#    'distance': 5921.040858643929},
#   {'id': 'J14GGm_I6Y0zjIFPApaVWw',
#    'alias': 'sabor-london-2',
#    'name': 'Sabor',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5xxNeg5jkxmsKqTzmASfZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sabor-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.511538, 'longitude': -0.139764},
#    'transactions': [],
#    'location': {'address1': '35-37 Heddon Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1B 4BR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35-37 Heddon Street',
#      'London W1B 4BR',
#      'United Kingdom']},
#    'phone': '+442033198130',
#    'display_phone': '+44 20 3319 8130',
#    'distance': 300.4432275585517},
#   {'id': 'q_tusdGaa20AEQNfpJoW4A',
#    'alias': 'tendido-cero-london',
#    'name': 'Tendido Cero',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LYsauGte4tdlI_JbUoOv7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tendido-cero-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4909847, 'longitude': -0.1839378},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '174 Old Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 0LJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['174 Old Brompton Road',
#      'London SW5 0LJ',
#      'United Kingdom']},
#    'phone': '+442073703685',
#    'display_phone': '+44 20 7370 3685',
#    'distance': 4115.246826374932},
#   {'id': '5bx0l0I3qbPzVLpdP3o2Ew',
#    'alias': 'el-pirata-of-mayfair-mayfair',
#    'name': 'El Pirata of Mayfair',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lyR6Mfrke0YmvzXZKgC-Dg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-pirata-of-mayfair-mayfair?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 61,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.505142, 'longitude': -0.148132},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '5-6 Down Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Mayfair',
#     'zip_code': 'W1J 7AQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5-6 Down Street',
#      'Mayfair W1J 7AQ',
#      'United Kingdom']},
#    'phone': '+442074913810',
#    'display_phone': '+44 20 7491 3810',
#    'distance': 1201.0174523191545},
#   {'id': '5S2vNZHbihkMwIrOfeL_JA',
#    'alias': 'zoilo-london',
#    'name': 'ZOILO',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XLJlgCiwHRL6OZMHAi9-vw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zoilo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'argentine', 'title': 'Argentine'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5159341, 'longitude': -0.1520374},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '9 Duke Street',
#     'address2': 'Marylebone',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 3EG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Duke Street',
#      'Marylebone',
#      'London W1U 3EG',
#      'United Kingdom']},
#    'phone': '+442074869699',
#    'display_phone': '+44 20 7486 9699',
#    'distance': 1164.9402876384315},
#   {'id': '-gSV0LVi6K8pMMbqO66PvQ',
#    'alias': 'bar-tozino-london',
#    'name': 'Bar Tozino',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5v8jiQurw6DNmeiSdEqgBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-tozino-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.499291248657,
#     'longitude': -0.0755051194567521},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Ropewalk off Maltby Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 3PA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Ropewalk off Maltby Street',
#      'London SE1 3PA',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4446.674037567032},
#   {'id': '5WR5vlucQqcSkVjsxdMWpA',
#    'alias': 'salvador-and-amanda-london',
#    'name': 'Salvador & Amanda',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9q2K8PJMqYHGzaJgDp0YZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salvador-and-amanda-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511995, 'longitude': -0.127822},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8 Great Newport Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 7JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Great Newport Street',
#      'London WC2H 7JA',
#      'United Kingdom']},
#    'phone': '+442072401551',
#    'display_phone': '+44 20 7240 1551',
#    'distance': 574.0565751822019},
#   {'id': 'S_WKkcAjy6mL-cysYNcP5A',
#    'alias': 'dehesa-london',
#    'name': 'Dehesa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jVMQimHcdCVrV6lkfG570A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dehesa-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 61,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512781, 'longitude': -0.139333},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '25 Ganton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9BP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['25 Ganton Street',
#      'London W1F 9BP',
#      'United Kingdom']},
#    'phone': '+442074944170',
#    'display_phone': '+44 20 7494 4170',
#    'distance': 235.73618211523822},
#   {'id': 'fpIx8nCBRqtImTkGJ-ujuQ',
#    'alias': 'morito-london',
#    'name': 'Morito',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CbbO-prB-P2VpTKpu-jvBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/morito-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5258712768555,
#     'longitude': -0.108857996761799},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '32 Exmouth Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 4QE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['32 Exmouth Market',
#      'London EC1R 4QE',
#      'United Kingdom']},
#    'phone': '+442072787007',
#    'display_phone': '+44 20 7278 7007',
#    'distance': 2369.898036502475},
#   {'id': 'Yfwp3WxxxAELuZmom1pS-g',
#    'alias': 'laxeiro-tapas-bar-london',
#    'name': 'Laxeiro Tapas Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XYhrEehDKX7FPsFrzgrgrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laxeiro-tapas-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.529856051392,
#     'longitude': -0.068823875337898},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '93 Columbia Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7RG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['93 Columbia Road',
#      'London E2 7RG',
#      'United Kingdom']},
#    'phone': '+442077291147',
#    'display_phone': '+44 20 7729 1147',
#    'distance': 5015.511473373969},
#   {'id': 'XkAwS7fh17t2NByUzM-VPg',
#    'alias': 'cambio-de-tercio-london-2',
#    'name': 'Cambio De Tercio',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dnbxdqu7cjrbKcdGXM1d5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cambio-de-tercio-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.49071555011, 'longitude': -0.18367075607669},
#    'transactions': [],
#    'location': {'address1': '157 Old Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 0LJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['157 Old Brompton Road',
#      'London SW5 0LJ',
#      'United Kingdom']},
#    'phone': '+442073730567',
#    'display_phone': '+44 20 7373 0567',
#    'distance': 4117.973789897908},
#   {'id': '-tOj445DkKqE04wTFqYJtA',
#    'alias': 'taberna-do-mercado-london',
#    'name': 'Taberna do Mercado',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Nkh1AvoIOPu8Z_2uw6dPoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taberna-do-mercado-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'portuguese', 'title': 'Portuguese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5197434697765,
#     'longitude': -0.0747024939347884},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '107b Commercial Street',
#     'address2': 'Old Spitalfields Market',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6BG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['107b Commercial Street',
#      'Old Spitalfields Market',
#      'London E1 6BG',
#      'United Kingdom']},
#    'phone': '+442073750649',
#    'display_phone': '+44 20 7375 0649',
#    'distance': 4307.5036841553665},
#   {'id': 'D8T1NJ982wZPiItnxp2AKA',
#    'alias': 'the-palomar-restaurant-london',
#    'name': 'The Palomar Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kiuVlZcWx4CgZTIsPYjp_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-palomar-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 106,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5111632, 'longitude': -0.1327159},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '34 Rupert Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6DN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['34 Rupert Street',
#      'London W1D 6DN',
#      'United Kingdom']},
#    'phone': '+442074398777',
#    'display_phone': '+44 20 7439 8777',
#    'distance': 291.2872720990486},
#   {'id': 'B6ayHXLwfYBuIADficAeMg',
#    'alias': 'caravan-kings-cross-london',
#    'name': 'Caravan Kings Cross',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/N3qh0kXJvNLcjPEP9EEZGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caravan-kings-cross-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 170,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5357788239146,
#     'longitude': -0.125370576153865},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Granary Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Granary Square',
#      'London N1C 4AA',
#      'United Kingdom']},
#    'phone': '+442071017661',
#    'display_phone': '+44 20 7101 7661',
#    'distance': 2654.2035388419845},
#   {'id': 'qnHCFYfRpuU4cyXE5aapoQ',
#    'alias': 'sagardi-basque-country-chefs-london-4',
#    'name': 'Sagardi Basque Country Chefs',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UK1tdzxk_NP9LXMIVUdYYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sagardi-basque-country-chefs-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'basque', 'title': 'Basque'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5252885, 'longitude': -0.080616},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Cordy House 95 Curtain Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 3BS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Cordy House 95 Curtain Rd',
#      'London EC2A 3BS',
#      'United Kingdom']},
#    'phone': '+442038020478',
#    'display_phone': '+44 20 3802 0478',
#    'distance': 4071.727672338526},
#   {'id': '3lrsL7fllHtEJ22SWGDzUg',
#    'alias': 'sager-wilde-hackney-road-london',
#    'name': 'Sager + Wilde - Hackney Road',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HngKOdza-CJT_1UecXgBow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sager-wilde-hackney-road-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5309900314205,
#     'longitude': -0.0721368747608334},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '193 Hackney Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 8JL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['193 Hackney Rd', 'London E2 8JL', 'United Kingdom']},
#    'phone': '+442081277330',
#    'display_phone': '+44 20 8127 7330',
#    'distance': 4855.025458634655},
#   {'id': 'dTSM3PhntgDOZlBayZ9LEQ',
#    'alias': 'la-fabrica-london',
#    'name': 'La Fabrica',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iid4fI2sw1NCdd-Tp_07tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-fabrica-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5675496, 'longitude': -0.1090879},
#    'transactions': [],
#    'location': {'address1': '45 Stroud Green Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N4 3EF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Stroud Green Road',
#      'London N4 3EF',
#      'United Kingdom']},
#    'phone': '+442072720020',
#    'display_phone': '+44 20 7272 0020',
#    'distance': 6369.509728197906},
#   {'id': 'D1pGai_OlTkiMMXfWaqBCA',
#    'alias': 'salt-yard-london',
#    'name': 'Salt Yard',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-YdNVmqVax6Z_LexluyIUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salt-yard-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5191758, 'longitude': -0.1365711},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '54 Goodge Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 4NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54 Goodge Street',
#      'London W1T 4NA',
#      'United Kingdom']},
#    'phone': '+442076370657',
#    'display_phone': '+44 20 7637 0657',
#    'distance': 706.4575147278808},
#   {'id': 'jTnrRxJp82iYjJVt8PPITQ',
#    'alias': 'barcelona-tapas-london-2',
#    'name': 'Barcelona Tapas',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZKQsBHXpmTxrGGvm4pVsdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barcelona-tapas-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5118330704957,
#     'longitude': -0.0835872701958973},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '24 Lime Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3M 7HS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Lime Street',
#      'London EC3M 7HS',
#      'United Kingdom']},
#    'phone': '+442079292389',
#    'display_phone': '+44 20 7929 2389',
#    'distance': 3625.703570941595},
#   {'id': 'AMfqUC9oYC0xc55MaXbvAA',
#    'alias': 'nopi-london',
#    'name': 'NOPI',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Gu5NZ13wiFuOMxMrMJh5Dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nopi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 271,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511617, 'longitude': -0.1385226},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '21-22 Warwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21-22 Warwick Street',
#      'London W1B 5NE',
#      'United Kingdom']},
#    'phone': '+442074949584',
#    'display_phone': '+44 20 7494 9584',
#    'distance': 223.40454126752283},
#   {'id': 'HO_YLnFUpea_S6UfC_4XSw',
#    'alias': 'lobos-london',
#    'name': 'Lobos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Y-IXdsGGbAk4Rau4C0xbBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lobos-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5135427, 'longitude': -0.131473},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '48 Frith Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 4SF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['48 Frith Street',
#      'London W1D 4SF',
#      'United Kingdom']},
#    'phone': '+442030195082',
#    'display_phone': '+44 20 3019 5082',
#    'distance': 320.0233551913448},
#   {'id': 'K9EJ3OCwtk5qDLRZqm_4SQ',
#    'alias': 'toro-gordo-london',
#    'name': 'Toro Gordo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zUfMRO_chVUPob1aNKQ8SA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/toro-gordo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4924524517799,
#     'longitude': -0.230151628799284},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '121 King Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W6 9JG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['121 King Street', 'London W6 9JG', 'United Kingdom']},
#    'phone': '+442088347434',
#    'display_phone': '+44 20 8834 7434',
#    'distance': 6902.606952583127},
#   {'id': 'zm8F0kYTZXZ7jxGXw-gVMw',
#    'alias': 'boqueria-london-2',
#    'name': 'Boqueria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/S8GwCWRVXR_adNgEfE6lQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boqueria-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4766182969515,
#     'longitude': -0.148112449341489},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '278 Queenstown Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW8 4LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['278 Queenstown Road',
#      'London SW8 4LT',
#      'United Kingdom']},
#    'phone': '+442074988427',
#    'display_phone': '+44 20 7498 8427',
#    'distance': 4114.1633012793955},
#   {'id': '1BzTEwJ89j_nBSi7Sf3ylQ',
#    'alias': 'black-pig-with-white-pearls-london',
#    'name': 'Black Pig With White Pearls',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wNKN_xInvn_b82zTgQ7WRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-pig-with-white-pearls-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.55896, 'longitude': -0.0744295},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61 Stoke Newington High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 8EL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Stoke Newington High Street',
#      'London N16 8EL',
#      'United Kingdom']},
#    'phone': '+442072491772',
#    'display_phone': '+44 20 7249 1772',
#    'distance': 6649.972106415342},
#   {'id': 'UlWuQCehRHfyxz8AZj42tg',
#    'alias': 'casa-brindisa-london',
#    'name': 'Casa Brindisa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TJOimddfv7uJSrAEhiLMrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-brindisa-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4948622943727,
#     'longitude': -0.173562906002465},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '7-9 Exhibition Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 2HE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7-9 Exhibition Road',
#      'London SW7 2HE',
#      'United Kingdom']},
#    'phone': '+442075900008',
#    'display_phone': '+44 20 7590 0008',
#    'distance': 3281.6931678912774},
#   {'id': 'OiRMxtQCo0MdfZkejv2xUg',
#    'alias': 'polpetto-london-2',
#    'name': 'Polpetto',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9TwLb2vvMtaCJzleKxnU5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/polpetto-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.513356, 'longitude': -0.134634},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Berwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0PL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Berwick Street',
#      'London W1F 0PL',
#      'United Kingdom']},
#    'phone': '+442074398627',
#    'display_phone': '+44 20 7439 8627',
#    'distance': 108.24146336197532},
#   {'id': 'n60s6dzDICjP96wtIYCg-Q',
#    'alias': 'estella-restaurant-london',
#    'name': 'Estella Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KAIj517UXYKGi6RxHiG89A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/estella-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4349668, 'longitude': -0.1983968},
#    'transactions': [],
#    'location': {'address1': '169 Arthur Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW19 8AD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['169 Arthur Road',
#      'London SW19 8AD',
#      'United Kingdom']},
#    'phone': '+442089466518',
#    'display_phone': '+44 20 8946 6518',
#    'distance': 9674.788317103856},
#   {'id': 'TX9hjk1xl2xKwG1_Wuw0UQ',
#    'alias': 'camino-london-5',
#    'name': 'Camino',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/M0-jrnPJZnFddIT6c9GqMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camino-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5058899, 'longitude': -0.09945},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5 Canvey Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Canvey Street',
#      'London SE1 9NA',
#      'United Kingdom']},
#    'phone': '+442036173169',
#    'display_phone': '+44 20 3617 3169',
#    'distance': 2601.204580420548}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#        Restaurant                Type Price Rating              Address  \
# 0       Barrafina             Spanish    ££    4.5        43 Drury Lane
# 1  Tapas Brindisa             Spanish   £££      4  46 Broadwick Street
# 2       Barrafina  Tapas/Small Plates   £££      4       26 Dean Street
# 3        Donostia  Tapas/Small Plates   £££    4.5     10 Seymour Place
# 4    Bravas Tapas             Spanish    ££    4.5   St Katharine Docks
#
#          Lat       Lng                                                url  \
# 0  51.514339 -0.121904  https://www.yelp.com/biz/barrafina-london-5?ad...
# 1  51.513469 -0.136646  https://www.yelp.com/biz/tapas-brindisa-london...
# 2  51.514227 -0.132764  https://www.yelp.com/biz/barrafina-london-6?ad...
# 3  51.514732 -0.160959  https://www.yelp.com/biz/donostia-london?adjus...
# 4  51.507436 -0.071242  https://www.yelp.com/biz/bravas-tapas-london?a...
#
#                        ID
# 0  LVtracBONt-BsZ4Vr8_z_g
# 1  t_O2xY53TW3z8X6eyQp2bQ
# 2  qvO0hYRegZI5bCEk1cNoOQ
# 3  oERtgNeSaDE0XRPmGEP4uQ
# 4  MI3DDKL7YO38tEF-K-qs_w

# %%
#2nd set of 50 records 51-100 
lndr_params2 = {"term":term,"location":"London","limit":50,"offset":51}
lndr_response2 = requests.get(search_api_url, headers=headers, params=lndr_params2)
lndr2 = lndr_response2.json()
display(lndr2)
#print(lndr_response2.url)
#print(lndr_response2.status_code)
# Out:
# {'businesses': [{'id': 'lpggeARkCtGqQ7X5_OZOEQ',
#    'alias': 'house-of-tippler-london',
#    'name': 'House of Tippler',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VQ7JzgtYiPK5loSNNDZtjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/house-of-tippler-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4571528, 'longitude': -0.0752982},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '123 Lordship Lane',
#     'address2': 'East Dulwich',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE22 8HU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['123 Lordship Lane',
#      'East Dulwich',
#      'London SE22 8HU',
#      'United Kingdom']},
#    'phone': '+442079984878',
#    'display_phone': '+44 20 7998 4878',
#    'distance': 7481.799340332362},
#   {'id': 'Wu0K50eeMtE0Cfdky8B_1A',
#    'alias': 'pix-london-2',
#    'name': 'Pix',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1ks_xZg5OZcumlOrO4mT2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pix-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5146598815918,
#     'longitude': -0.126387000083923},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '63 Neal Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9PJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63 Neal Street',
#      'London WC2H 9PJ',
#      'United Kingdom']},
#    'phone': '+442078369779',
#    'display_phone': '+44 20 7836 9779',
#    'distance': 692.53434890955},
#   {'id': 'XB2S_jYmKVyxDxR5silCPQ',
#    'alias': 'jamon-jamon-london-5',
#    'name': 'Jamon Jamon',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AsWBsRxjPu5p0Zsy1JFvfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jamon-jamon-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5501828521338,
#     'longitude': -0.164836167734323},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '177 Haverstock Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 4QS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['177 Haverstock Hill',
#      'London NW3 4QS',
#      'United Kingdom']},
#    'phone': '+442074834242',
#    'display_phone': '+44 20 7483 4242',
#    'distance': 4608.351435650079},
#   {'id': '08ITFw37j1rJTTkOROWJWQ',
#    'alias': 'la-plaza-tapas-bar-london',
#    'name': 'La Plaza Tapas Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Lz5GFJovX-9JJgeYgLOHdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-plaza-tapas-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.518317132243,
#     'longitude': -0.20521943982827},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '74 Tavistock Road',
#     'address2': 'Notting Hill',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 1AN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['74 Tavistock Road',
#      'Notting Hill',
#      'London W11 1AN',
#      'United Kingdom']},
#    'phone': '+442072295995',
#    'display_phone': '+44 20 7229 5995',
#    'distance': 4831.419461087176},
#   {'id': 'WT5EjZGp4gn9BNnzTlC2Ww',
#    'alias': 'ottolenghi-islington',
#    'name': 'Ottolenghi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y0eBCsgaeswDaLcF0m-iLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ottolenghi-islington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 212,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5397542479056,
#     'longitude': -0.102216303348541},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '287 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 2TZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['287 Upper Street',
#      'London N1 2TZ',
#      'United Kingdom']},
#    'phone': '+442072881454',
#    'display_phone': '+44 20 7288 1454',
#    'distance': 3795.717274260169},
#   {'id': 'RXi1QlJsQcFvoBR5oR7x3w',
#    'alias': 'la-lluna-london',
#    'name': 'La Lluna',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/q2e8setlNhZ_epnKtzx2Tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-lluna-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5926970055022,
#     'longitude': -0.143234954958407},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9462 Muswell Hill Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N10 1BS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9462 Muswell Hill Broadway',
#      'London N10 1BS',
#      'United Kingdom']},
#    'phone': '+442084422662',
#    'display_phone': '+44 20 8442 2662',
#    'distance': 8894.432262669847},
#   {'id': 'cQrWlVTX_0LMrI53m-Ah-A',
#    'alias': 'jose-pizarro-broadgate-london',
#    'name': 'Jose Pizarro Broadgate',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XsX41pCOkEmNl65zdUUZ6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jose-pizarro-broadgate-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.518924, 'longitude': -0.08359},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '36 Broadgate Circle',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2M 2BN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['36 Broadgate Circle',
#      'London EC2M 2BN',
#      'United Kingdom']},
#    'phone': '+442072565333',
#    'display_phone': '+44 20 7256 5333',
#    'distance': 3715.8386422868225},
#   {'id': 'ahDp21uF9jctuvLkHzJGiQ',
#    'alias': 'le-petit-sud-london',
#    'name': 'Le Petit Sud',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/61dByajlmocQrV2x2RdK8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-petit-sud-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5014328025491,
#     'longitude': -0.184245772868543},
#    'transactions': [],
#    'location': {'address1': '1 Palace Gate',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W8 5LS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Palace Gate', 'London W8 5LS', 'United Kingdom']},
#    'phone': '+442075890030',
#    'display_phone': '+44 20 7589 0030',
#    'distance': 3574.5545631922246},
#   {'id': 'WH-BJYaU8RWtzpHZ5xoogg',
#    'alias': 'alquimia-spanish-restaurant-london',
#    'name': 'Alquimia Spanish Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WSmW1420PIgsU26qMybr8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alquimia-spanish-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4650262770793,
#     'longitude': -0.213009018602193},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '30 Brewhouse Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW15 2JX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Brewhouse Lane',
#      'London SW15 2JX',
#      'United Kingdom']},
#    'phone': '+442087850508',
#    'display_phone': '+44 20 8785 0508',
#    'distance': 7531.467578861926},
#   {'id': '5iqZAyTXND6zA9dFii_4UQ',
#    'alias': 'centro-galego-de-londres-london',
#    'name': 'Centro Galego de Londres',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/s0Kk5vq7mGDU10nf9eULGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/centro-galego-de-londres-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.53212819224, 'longitude': -0.23686324793784},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '869 Harrow Road',
#     'address2': 'Kensal Green',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW10 5NG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['869 Harrow Road',
#      'Kensal Green',
#      'London NW10 5NG',
#      'United Kingdom']},
#    'phone': '+442089644873',
#    'display_phone': '+44 20 8964 4873',
#    'distance': 7303.567547513148},
#   {'id': 'AqL0rJQ3K0zpOBdflZ8lig',
#    'alias': 'the-other-naughty-piglet-westminster',
#    'name': 'The Other Naughty Piglet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-ps2LUs6XiBtURd3J1kGYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-other-naughty-piglet-westminster?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4987970730637,
#     'longitude': -0.142227463466019},
#    'transactions': [],
#    'location': {'address1': '12 Palace Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Westminster',
#     'zip_code': 'SW1E 5JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Palace Street',
#      'Westminster SW1E 5JA',
#      'United Kingdom']},
#    'phone': '+442075920322',
#    'display_phone': '+44 20 7592 0322',
#    'distance': 1620.23030806935},
#   {'id': 'ZZWYsbwD8kkHUyiAKnVnAQ',
#    'alias': 'ibérica-london-7',
#    'name': 'Ibérica',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uVi23WMSL3azDdnTs3zUsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ib%C3%A9rica-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5210778192986,
#     'longitude': -0.105176791548729},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '89 Turnmill Street',
#     'address2': 'Farringdon',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1M 5QU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['89 Turnmill Street',
#      'Farringdon',
#      'London EC1M 5QU',
#      'United Kingdom']},
#    'phone': '+442030265118',
#    'display_phone': '+44 20 3026 5118',
#    'distance': 2318.5725550698658},
#   {'id': 'ZiDGOLqa9ATyjMQ265ijFQ',
#    'alias': 'goya-london-3',
#    'name': 'Goya',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oOzNTdnAzX6H-NcjEx890Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/goya-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4884216, 'longitude': -0.1375914},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '34 Lupus Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 3EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['34 Lupus Street',
#      'London SW1V 3EB',
#      'United Kingdom']},
#    'phone': '+442079765309',
#    'display_phone': '+44 20 7976 5309',
#    'distance': 2716.734433413352},
#   {'id': 'zWrlXb7JkHWq6t2_W1pYxw',
#    'alias': 'la-farola-london',
#    'name': 'La Farola',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rgeVj9aMVQE-_OJMx3CtKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-farola-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5376652, 'longitude': -0.1029422},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '101 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 1QN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['101 Upper Street',
#      'London N1 1QN',
#      'United Kingdom']},
#    'phone': '+442073597707',
#    'display_phone': '+44 20 7359 7707',
#    'distance': 3583.1777489273027},
#   {'id': 'ydAy5UC6GhdTOJc-o-tBew',
#    'alias': 'cafe-el-buen-gusto-london',
#    'name': 'Cafe El Buen Gusto',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/78ibOUShf7NsIP1DAnzFbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-el-buen-gusto-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5129578, 'longitude': -0.1312579},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '39 Frith Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 5LL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39 Frith Street',
#      'London W1D 5LL',
#      'United Kingdom']},
#    'phone': '+442071594440',
#    'display_phone': '+44 20 7159 4440',
#    'distance': 325.3833904637707},
#   {'id': 'tSRsSKlk4cKWD7Pc7aJihQ',
#    'alias': 'grand-bazaar-london',
#    'name': 'Grand Bazaar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/l2MVdp0cA1Muen1cqCKbdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grand-bazaar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5154866, 'longitude': -0.1506015},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '42 James Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 1EX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 James Street',
#      'London W1U 1EX',
#      'United Kingdom']},
#    'phone': '+442072241544',
#    'display_phone': '+44 20 7224 1544',
#    'distance': 1054.1613836254885},
#   {'id': '9t-1zwu5yfZUADCd6DIwdQ',
#    'alias': 'bonoo-london',
#    'name': 'Bonoo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CtuU7iHPgshrCG2YN-sJEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bonoo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5614581054399,
#     'longitude': -0.197351574897766},
#    'transactions': [],
#    'location': {'address1': '675 Finchley Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW2 2JP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['675 Finchley Road',
#      'London NW2 2JP',
#      'United Kingdom']},
#    'phone': '+442077948899',
#    'display_phone': '+44 20 7794 8899',
#    'distance': 6874.793013372523},
#   {'id': '1saSQJuhKzjWbhWSAcfpNg',
#    'alias': 'miss-tapas-london',
#    'name': 'Miss Tapas',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZeDSMURAXwHoUVeLlT8VGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/miss-tapas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4681856176917,
#     'longitude': -0.0691786000000216},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '46 Choumert Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE15 4SE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['46 Choumert Road',
#      'London SE15 4SE',
#      'United Kingdom']},
#    'phone': '+442036895050',
#    'display_phone': '+44 20 3689 5050',
#    'distance': 6784.141045113692},
#   {'id': 'H54RI_SY2N5srvP3qpgAmg',
#    'alias': 'brindisa-london-2',
#    'name': 'Brindisa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4AAQ6vubtbly__QMz7d3IA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brindisa-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4624005417607,
#     'longitude': -0.112283045097797},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '41-43 Atlantic Road',
#     'address2': 'Brixton',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 8JL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41-43 Atlantic Road',
#      'Brixton',
#      'London SW9 8JL',
#      'United Kingdom']},
#    'phone': '+442077330634',
#    'display_phone': '+44 20 7733 0634',
#    'distance': 5842.727444569834},
#   {'id': 'ytIFY2JvU-zcd1FsonES5w',
#    'alias': 'about-thyme-london',
#    'name': 'About Thyme',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Mh4BT2kuTfm_NFGpOQRFXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/about-thyme-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4924969, 'longitude': -0.1399836},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '82 Wilton Road',
#     'address2': 'Pimlico',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['82 Wilton Road',
#      'Pimlico',
#      'London SW1V 1DL',
#      'United Kingdom']},
#    'phone': '+442078217504',
#    'display_phone': '+44 20 7821 7504',
#    'distance': 2281.829545906066},
#   {'id': 'OZKWjttS7iaZgCvFVW_TOg',
#    'alias': 'el-rincon-spanish-tapas-restaurant-epsom',
#    'name': 'El Rincon Spanish Tapas Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9xR5HZUlt_0lp9oj-TZs6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-rincon-spanish-tapas-restaurant-epsom?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.3097858, 'longitude': -0.2411062},
#    'transactions': [],
#    'location': {'address1': '16 Tattenham Crescent',
#     'address2': '',
#     'address3': '',
#     'city': 'Epsom',
#     'zip_code': 'KT18 5QJ',
#     'country': 'GB',
#     'state': 'SRY',
#     'display_address': ['16 Tattenham Crescent',
#      'Epsom KT18 5QJ',
#      'United Kingdom']},
#    'phone': '+441737373647',
#    'display_phone': '+44 1737 373647',
#    'distance': 23726.094277601183},
#   {'id': 'vz-VINQOFosCDVtATsghUg',
#    'alias': 'el-ganso-london',
#    'name': 'El Ganso',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JUn32Qq6Yk3dnMMNy-skxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-ganso-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.53719735, 'longitude': -0.06140592},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '59 Broadway Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 4PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['59 Broadway Market',
#      'London E8 4PH',
#      'United Kingdom']},
#    'phone': '+442072411793',
#    'display_phone': '+44 20 7241 1793',
#    'distance': 5825.667107135062},
#   {'id': 'vOpRo1510_CeE_GFHsJGcg',
#    'alias': 'chojo-london',
#    'name': 'Chojo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/22GpBUtLBs_8S9jFst532Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chojo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'taiwanese', 'title': 'Taiwanese'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.51512, 'longitude': -0.19168},
#    'transactions': [],
#    'location': {'address1': '16 Garway Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 4NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Garway Road', 'London W2 4NH', 'United Kingdom']},
#    'phone': '+442032868286',
#    'display_phone': '+44 20 3286 8286',
#    'distance': 3866.0995264535777},
#   {'id': 'uVPz6AznuCZRUPLR3S0TKw',
#    'alias': 'el-metro-restaurant-london',
#    'name': 'El Metro Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hlTAEgyKm4BrWZkTBc-_YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-metro-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.479411, 'longitude': -0.195849},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10-12 Effie Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 1TB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10-12 Effie Road',
#      'London SW6 1TB',
#      'United Kingdom']},
#    'phone': '+442073841264',
#    'display_phone': '+44 20 7384 1264',
#    'distance': 5567.536326511399},
#   {'id': '8zRK64DiSEh2FIvtcUs08A',
#    'alias': 'canaletes-tapas-and-wine-london',
#    'name': 'Canaletes Tapas & Wine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Zy9TdfdbkuTE2R9pCSVAgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/canaletes-tapas-and-wine-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5408663364831,
#     'longitude': -0.201840586960316},
#    'transactions': [],
#    'location': {'address1': '51 Willesden Lane',
#     'address2': 'North Maida Vale London NW6 7RL',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW6 7RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Willesden Lane',
#      'North Maida Vale London NW6 7RL',
#      'London NW6 7RL',
#      'United Kingdom']},
#    'phone': '+442076247004',
#    'display_phone': '+44 20 7624 7004',
#    'distance': 5521.70607622616},
#   {'id': 'tHhljazL4CJ8E8GNXZ3xNQ',
#    'alias': 'ibérica-la-terraza-london-7',
#    'name': 'Ibérica La Terraza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fforc6b-alNIRdtaUoTU6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ib%C3%A9rica-la-terraza-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5055353323496,
#     'longitude': -0.0222644797711382},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '12 Cabot Square',
#     'address2': 'Canary Wharf',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E14 4QQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Cabot Square',
#      'Canary Wharf',
#      'London E14 4QQ',
#      'United Kingdom']},
#    'phone': '+442030265118',
#    'display_phone': '+44 20 3026 5118',
#    'distance': 7909.933618140434},
#   {'id': 'KGfryNuNH5mqYddLll9QCw',
#    'alias': 'gordons-wine-bar-london-4',
#    'name': "Gordon's Wine Bar",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bfARR-wEQXTyAWC9TCZwXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gordons-wine-bar-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 407,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5079411426091,
#     'longitude': -0.123381614685059},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '47 Villiers Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 6NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Villiers Street',
#      'London WC2N 6NE',
#      'United Kingdom']},
#    'phone': '+442079301408',
#    'display_phone': '+44 20 7930 1408',
#    'distance': 1026.362730294806},
#   {'id': 'HuHxB3T8hf3WsTa7YkijdQ',
#    'alias': 'llerena-london',
#    'name': 'Llerena',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/snW6Lr3ZIUougEJxtA8fWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/llerena-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5409955, 'longitude': -0.1030298},
#    'transactions': [],
#    'location': {'address1': '167 Upper Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N1 1US',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['167 Upper Street',
#      'London N1 1US',
#      'United Kingdom']},
#    'phone': '+442077049977',
#    'display_phone': '+44 20 7704 9977',
#    'distance': 3874.9683232693064},
#   {'id': 'qR4hbrreQJ1keROTYqKimw',
#    'alias': 'viva-tapas-bar-london-7',
#    'name': 'Viva Tapas Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4smOqIEHS00ZqJEvO4S4Vw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/viva-tapas-bar-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.55099, 'longitude': -0.074833},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Stoke Newington Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 7XN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Stoke Newington Road',
#      'London N16 7XN',
#      'United Kingdom']},
#    'phone': '+442072411104',
#    'display_phone': '+44 20 7241 1104',
#    'distance': 5989.599930652805},
#   {'id': 'wnjEC2RFvivLUFF7xnLFyw',
#    'alias': 'leicester-square-kitchen-london-2',
#    'name': 'Leicester Square Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0IDJKUS9vn6-i-UhHCq3IQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/leicester-square-kitchen-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5098669, 'longitude': -0.1297669},
#    'transactions': [],
#    'location': {'address1': '31-36 Leicester Square',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2H 7LH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['31-36 Leicester Square',
#      'London WC2H 7LH',
#      'United Kingdom']},
#    'phone': '+442076660902',
#    'display_phone': '+44 20 7666 0902',
#    'distance': 540.7374631917979},
#   {'id': 'Di6gdsDoCA-9tR__IQf4Ag',
#    'alias': 'casita-andina-soho',
#    'name': 'Casita Andina',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/csCxxZU853oWku8tLGq0SA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casita-andina-soho?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51161, 'longitude': -0.13473},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '31 Great Windmill Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Soho',
#     'zip_code': 'W1D 7LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['31 Great Windmill Street',
#      'Soho W1D 7LP',
#      'United Kingdom']},
#    'phone': '+442033279464',
#    'display_phone': '+44 20 3327 9464',
#    'distance': 162.37211488759735},
#   {'id': 'EA9cSKJg-Xox0n3u-tmX4A',
#    'alias': 'los-molinos-london',
#    'name': 'Los Molinos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/x3tSC57QWCi5aYRvo63fFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-molinos-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4972652, 'longitude': -0.2225333},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '127 Shepherds Bush Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W6 7LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['127 Shepherds Bush Road',
#      'London W6 7LP',
#      'United Kingdom']},
#    'phone': '+442076032229',
#    'display_phone': '+44 20 7603 2229',
#    'distance': 6228.453134414655},
#   {'id': 'OyLrjCVSSp5UUAYe9Vm0Hg',
#    'alias': 'camino-london',
#    'name': 'Camino',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TDU4TPZeSeQkrj7WyEY_Dg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camino-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 107,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5312937277784,
#     'longitude': -0.121793746948242},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3 Varnishers Yard',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Varnishers Yard',
#      'London N1 9AF',
#      'United Kingdom']},
#    'phone': '+442078417331',
#    'display_phone': '+44 20 7841 7331',
#    'distance': 2274.344517625361},
#   {'id': '2qk8fjk5VrrxtuefMKl44g',
#    'alias': 'pachamama-london',
#    'name': 'Pachamama',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hRjW1UCg2H2ZJ-w7phSz8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pachamama-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5171822, 'longitude': -0.1515276},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '18 Thayer Street',
#     'address2': 'Marylebone',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 3JY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Thayer Street',
#      'Marylebone',
#      'London W1U 3JY',
#      'United Kingdom']},
#    'phone': '+442079359393',
#    'display_phone': '+44 20 7935 9393',
#    'distance': 1180.9647507202842},
#   {'id': 'szD7qqAsYvCDrVdzvNsWaw',
#    'alias': 'dama-de-elche-london',
#    'name': 'Dama De Elche',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JoRKeUBp3PV9oaVK60ZROA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dama-de-elche-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5752529691535,
#     'longitude': 0.0269579745256365},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '7 Cambridge Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E11 2UA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Cambridge Park Road',
#      'London E11 2UA',
#      'United Kingdom']},
#    'phone': '+442085188111',
#    'display_phone': '+44 20 8518 8111',
#    'distance': 13232.322008410385},
#   {'id': 'nxxCu3Svrmp2cNvfufrdFw',
#    'alias': 'the-harwood-arms-london',
#    'name': 'The Harwood Arms',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hte754uy10BMdVg3P0hbxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-harwood-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 125,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4829113087309,
#     'longitude': -0.196470990454087},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '27 Walham Grove',
#     'address2': 'Fulham',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 1QP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['27 Walham Grove',
#      'Fulham',
#      'London SW6 1QP',
#      'United Kingdom']},
#    'phone': '+442073861847',
#    'display_phone': '+44 20 7386 1847',
#    'distance': 5349.774856506561},
#   {'id': 'XxMKf7GDsE70Xq3NFkneWA',
#    'alias': 'coya-london-2',
#    'name': 'COYA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hPBk9G0c_bnAs5vaNI68bw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coya-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 72,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5044732, 'longitude': -0.147974},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '118 Piccadilly',
#     'address2': 'Mayfair',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 7NW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['118 Piccadilly',
#      'Mayfair',
#      'London W1J 7NW',
#      'United Kingdom']},
#    'phone': '+442070427118',
#    'display_phone': '+44 20 7042 7118',
#    'distance': 1247.563984144171},
#   {'id': 'xlynfBbbLmx6WjO8U_nOJw',
#    'alias': 'trangallán-london-3',
#    'name': 'Trangallán',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/n9BGk3k_3v6TzVfjy-2Ebw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trangall%C3%A1n-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.551188313598,
#     'longitude': -0.086327063756242},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '61 Newington Green',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 9PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Newington Green',
#      'London N16 9PX',
#      'United Kingdom']},
#    'phone': '+442073594988',
#    'display_phone': '+44 20 7359 4988',
#    'distance': 5474.662780961663},
#   {'id': 'e31kDuKb3oyyWwb07stCRg',
#    'alias': 'escocesa-london',
#    'name': 'Escocesa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0jWb3TMPLuke5TUxjUITNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/escocesa-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5621830286786,
#     'longitude': -0.0768258422613144},
#    'transactions': [],
#    'location': {'address1': '67 Stoke Newington Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 0AR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['67 Stoke Newington Church Street',
#      'London N16 0AR',
#      'United Kingdom']},
#    'phone': '+442078129189',
#    'display_phone': '+44 20 7812 9189',
#    'distance': 6843.557709068918},
#   {'id': 'pKebVZTdbgx7kI89vDMERw',
#    'alias': '28-church-row-hampstead',
#    'name': '28 Church Row',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/28-church-row-hampstead?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5554943529702,
#     'longitude': -0.178899871641582},
#    'transactions': [],
#    'location': {'address1': '28 Church Row',
#     'address2': '',
#     'address3': None,
#     'city': 'HAMPSTEAD',
#     'zip_code': 'NW3 6UP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28 Church Row',
#      'HAMPSTEAD NW3 6UP',
#      'United Kingdom']},
#    'phone': '+442079932062',
#    'display_phone': '+44 20 7993 2062',
#    'distance': 5596.72735217849},
#   {'id': '_hiTEsg7MgrFNfZRl8mksA',
#    'alias': 'señor-ceviche-london-2',
#    'name': 'Señor Ceviche',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/A1nUMTQCNwoW1mSJBxb5qA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/se%C3%B1or-ceviche-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51241, 'longitude': -0.13858},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Kingly Court',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5PW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Kingly Court', 'London W1B 5PW', 'United Kingdom']},
#    'phone': '+442078428540',
#    'display_phone': '+44 20 7842 8540',
#    'distance': 194.43889273685113},
#   {'id': 'LVk2zxRgMun7JuKr-38bzQ',
#    'alias': 'tapas-brindisa-shoreditch-london',
#    'name': 'Tapas Brindisa Shoreditch',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GFY-6RbFrMv4Hg4tzL34Tw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tapas-brindisa-shoreditch-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5268939, 'longitude': -0.0801531},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '152 Curtain Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 3AT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['152 Curtain Road',
#      'London EC2A 3AT',
#      'United Kingdom']},
#    'phone': '+442077499961',
#    'display_phone': '+44 20 7749 9961',
#    'distance': 4165.451407243913},
#   {'id': 'BtTR-tuAz7KWL4nccmDdiA',
#    'alias': 'bar-lorca-london-3',
#    'name': 'Bar Lorca',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-lorca-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5566785, 'longitude': -0.1383916},
#    'transactions': [],
#    'location': {'address1': '156-158 Fortess Road',
#     'address2': 'Tufnell Park',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW5 2HP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['156-158 Fortess Road',
#      'Tufnell Park',
#      'London NW5 2HP',
#      'United Kingdom']},
#    'phone': '+442074851314',
#    'display_phone': '+44 20 7485 1314',
#    'distance': 4878.02172480157},
#   {'id': 'ao6l60DSpTlssR60XEjOnw',
#    'alias': 'barrica-london',
#    'name': 'Barrica',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pI74VqbPxn32ebIwauTslQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barrica-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.519099, 'longitude': -0.136827},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '62 Goodge Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 4NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['62 Goodge Street',
#      'London W1T 4NE',
#      'United Kingdom']},
#    'phone': '+442074369448',
#    'display_phone': '+44 20 7436 9448',
#    'distance': 696.3818191543485},
#   {'id': 'USzmydytDQ5ksyX22zURQQ',
#    'alias': 'pix-london',
#    'name': 'Pix',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RC8rMuAxqIjYrLrwEvVMdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pix-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5153442, 'longitude': -0.2048745},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '185 Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['185 Portobello Road',
#      'London W11 2ED',
#      'United Kingdom']},
#    'phone': '+442077276978',
#    'display_phone': '+44 20 7727 6978',
#    'distance': 4775.790389917452},
#   {'id': 'ggwDV5tRXMfQJvH2-yZVug',
#    'alias': 'the-barbary-london',
#    'name': 'The Barbary',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ljHbpFfy8KuswWBzJt2pGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-barbary-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5144480132327,
#     'longitude': -0.126241173962971},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "16 Neal's Yard",
#     'address2': 'Seven Dials',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2H 9DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["16 Neal's Yard",
#      'Seven Dials',
#      'London WC2H 9DP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 695.7502106283067},
#   {'id': 'tdFlULhmRAF5j_tmmP2Ylg',
#    'alias': 'bar-gansa-london',
#    'name': 'Bar Gansa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VqRy8shMqaPEZ9WPnpGLyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-gansa-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5398048, 'longitude': -0.1436027},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Inverness Street',
#     'address2': 'Camden Town',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 7HJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Inverness Street',
#      'Camden Town',
#      'London NW1 7HJ',
#      'United Kingdom']},
#    'phone': '+442072678909',
#    'display_phone': '+44 20 7267 8909',
#    'distance': 3042.044448404408},
#   {'id': 'PWJiVG6QUm8P2aLJke1Ndw',
#    'alias': 'las-tapas-london',
#    'name': 'Las Tapas',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VEIKQJJlYYvItclSoUiaDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/las-tapas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5067595, 'longitude': -0.2072507},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '108 Holland Park Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 4UA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['108 Holland Park Avenue',
#      'London W11 4UA',
#      'United Kingdom']},
#    'phone': '+442072213598',
#    'display_phone': '+44 20 7221 3598',
#    'distance': 4980.041326069025},
#   {'id': 'MuB1SAHJkKGauEA2_2QuMw',
#    'alias': 'donostia-social-club-london-2',
#    'name': 'Donostia Social Club',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZB4R5KKbrJ-BZA5ENcjrig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/donostia-social-club-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'basque', 'title': 'Basque'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4634215902681,
#     'longitude': -0.112375015123689},
#    'transactions': [],
#    'location': {'address1': '49 Brixton Station Road',
#     'address2': 'Pop Brixton',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 8PQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Brixton Station Road',
#      'Pop Brixton',
#      'London SW9 8PQ',
#      'United Kingdom']},
#    'phone': '+447961844464',
#    'display_phone': '+44 7961 844464',
#    'distance': 5732.017427688565},
#   {'id': 'r4yImLpeIpcjMFD7qSz_ng',
#    'alias': 'meson-don-felipe-london',
#    'name': 'Meson Don Felipe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yl8p5RbithuAa2sp1pXTFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meson-don-felipe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5029673, 'longitude': -0.1072009},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '53 The Cut',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8LF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['53 The Cut', 'London SE1 8LF', 'United Kingdom']},
#    'phone': '+442079283237',
#    'display_phone': '+44 20 7928 3237',
#    'distance': 2270.849488911948}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#            Restaurant           Type Price Rating              Address  \
# 0    House of Tippler        Spanish   £££    4.5    123 Lordship Lane
# 1                 Pix     Tapas Bars    ££      4       63 Neal Street
# 2         Jamon Jamon        Spanish    ££      4  177 Haverstock Hill
# 3  La Plaza Tapas Bar        Spanish    ££    3.5    74 Tavistock Road
# 4          Ottolenghi  Mediterranean    ££      4     287 Upper Street
#
#          Lat       Lng                                                url  \
# 0  51.457153 -0.075298  https://www.yelp.com/biz/house-of-tippler-lond...
# 1  51.514660 -0.126387  https://www.yelp.com/biz/pix-london-2?adjust_c...
# 2  51.550183 -0.164836  https://www.yelp.com/biz/jamon-jamon-london-5?...
# 3  51.518317 -0.205219  https://www.yelp.com/biz/la-plaza-tapas-bar-lo...
# 4  51.539754 -0.102216  https://www.yelp.com/biz/ottolenghi-islington?...
#
#                        ID
# 0  lpggeARkCtGqQ7X5_OZOEQ
# 1  Wu0K50eeMtE0Cfdky8B_1A
# 2  XB2S_jYmKVyxDxR5silCPQ
# 3  08ITFw37j1rJTTkOROWJWQ
# 4  WT5EjZGp4gn9BNnzTlC2Ww

# %%
#3rd set of 50 records 101-150
lndr_params3 = {"term":term,"location":"London","limit":50,"offset":101}
lndr_response3 = requests.get(search_api_url, headers=headers, params=lndr_params3)
lndr3 = lndr_response3.json()
display(lndr3)
#print(lndr_response3.url)
#print(lndr_response3.status_code)
# Out:
# {'businesses': [{'id': 'hOLFwKg4-0FsCleJ4yoCXw',
#    'alias': 'duck-and-waffle-london',
#    'name': 'Duck & Waffle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WrS5I1dN-nGXePaADwE0cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duck-and-waffle-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 707,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516178, 'longitude': -0.08094},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '110 Bishopsgate',
#     'address2': '40th Floor',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2N 4AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['110 Bishopsgate',
#      '40th Floor',
#      'London EC2N 4AY',
#      'United Kingdom']},
#    'phone': '+442036407310',
#    'display_phone': '+44 20 3640 7310',
#    'distance': 3825.102922188434},
#   {'id': 'G2EF7KepnKIaaIlr-DxeAQ',
#    'alias': 'el-vino-co-london',
#    'name': 'El Vino Co',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/E5cu7AYsnLNAdJOxI82lQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-vino-co-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.512574, 'longitude': -0.10399},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '30 New Bridge Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4V 6BJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 New Bridge Street',
#      'London EC4V 6BJ',
#      'United Kingdom']},
#    'phone': '+442072364534',
#    'display_phone': '+44 20 7236 4534',
#    'distance': 2215.3520593265985},
#   {'id': 'cQzR9_RVVPdwWYE7fXL14w',
#    'alias': 'la-rueda-de-tapas-london',
#    'name': 'La Rueda de Tapas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yxEwqDRinOWHgSyKDRa4uQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-rueda-de-tapas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.512287, 'longitude': -0.306182},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '12 Bond Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W5 5AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Bond Street', 'London W5 5AA', 'United Kingdom']},
#    'phone': '+442085674219',
#    'display_phone': '+44 20 8567 4219',
#    'distance': 11778.707877068508},
#   {'id': 'kwLvscNdOfBJTpm5qtD-iA',
#    'alias': 'polpo-london-16',
#    'name': 'POLPO',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ojOtcPkBbNZFayzg7mpF4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/polpo-london-16?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 87,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5107491, 'longitude': -0.1226443},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 Maiden Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 7NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Maiden Lane', 'London WC2E 7NA', 'United Kingdom']},
#    'phone': '+442078368448',
#    'display_phone': '+44 20 7836 8448',
#    'distance': 949.9546375999565},
#   {'id': 'hXWtuKNmbVzAYtoZhNLLPw',
#    'alias': 'connaught-bar-london',
#    'name': 'Connaught Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ITro8OzOKISsn64bw2Xxqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/connaught-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 66,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5101556, 'longitude': -0.1496314},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'The Connaught',
#     'address2': 'Carlos Place',
#     'address3': 'Mayfair',
#     'city': 'London',
#     'zip_code': 'W1K 2AL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Connaught',
#      'Carlos Place',
#      'Mayfair',
#      'London W1K 2AL',
#      'United Kingdom']},
#    'phone': '+442073143419',
#    'display_phone': '+44 20 7314 3419',
#    'distance': 992.1974132195033},
#   {'id': 'kuWmJZCAIX_bx7JCBfo_ag',
#    'alias': 'mas-q-menos-london-2',
#    'name': 'Mas Q Menos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/X7NItvVzmrWE4mvuXPTYGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mas-q-menos-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.512912, 'longitude': -0.133448},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '68-70 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0TB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['68-70 Wardour Street',
#      'London W1F 0TB',
#      'United Kingdom']},
#    'phone': '+442072873773',
#    'display_phone': '+44 20 7287 3773',
#    'distance': 173.78105352455785},
#   {'id': 'phNAsy-XGDEFAhnkHNodBg',
#    'alias': 'streetxo-london-2',
#    'name': 'StreetXO',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XBgc27ODx6RBDYaMO_nNtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/streetxo-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5113219, 'longitude': -0.1413446},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '15 Old Burlington Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 2JR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Old Burlington Street',
#      'London W1S 2JR',
#      'United Kingdom']},
#    'phone': '+442030967555',
#    'display_phone': '+44 20 3096 7555',
#    'distance': 409.136858066705},
#   {'id': 'tUXG0M3VnTG40Gobw5zp4Q',
#    'alias': 'san-miguels-london',
#    'name': "San Miguel's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ch-5rCTYXiVB7dCNkjcWkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/san-miguels-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.51938, 'longitude': -0.168564},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '256 Edgware Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1DS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['256 Edgware Road',
#      'London W2 1DS',
#      'United Kingdom']},
#    'phone': '+442072621709',
#    'display_phone': '+44 20 7262 1709',
#    'distance': 2370.8009855817654},
#   {'id': 'pMZ4XI-RsAxY6YK3xHVFJA',
#    'alias': 'boro-bistro-london',
#    'name': 'Boro Bistro',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AOkUzon0EnQK-hJpxOi1_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boro-bistro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5061193239226,
#     'longitude': -0.0887993531057241},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6-10 Borough High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9QQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6-10 Borough High Street',
#      'London SE1 9QQ',
#      'United Kingdom']},
#    'phone': '+442073780788',
#    'display_phone': '+44 20 7378 0788',
#    'distance': 3347.8671427058275},
#   {'id': 'vN5XHJMX7A5EpXGGnIj_Ag',
#    'alias': 'jamon-jamon-soho-london-3',
#    'name': 'Jamon Jamon Soho',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XLjryAeMK2SUt58A9KpKWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jamon-jamon-soho-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5139202738536,
#     'longitude': -0.12920486284338},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3-5 Caxton Walk',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 8PW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3-5 Caxton Walk',
#      'London WC2H 8PW',
#      'United Kingdom']},
#    'phone': '+442078366969',
#    'display_phone': '+44 20 7836 6969',
#    'distance': 482.4863147941423},
#   {'id': 'jVvBLAttH3ir_3FdSJXOCA',
#    'alias': 'merchant-house-london-2',
#    'name': 'Merchant House',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/merchant-house-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5138127, 'longitude': -0.10485},
#    'transactions': [],
#    'location': {'address1': '13 Well Court',
#     'address2': 'Off Bow Lane',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EC4Y 8DT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Well Court',
#      'Off Bow Lane',
#      'London EC4Y 8DT',
#      'United Kingdom']},
#    'phone': '+442038024451',
#    'display_phone': '+44 20 3802 4451',
#    'distance': 2155.2675610527012},
#   {'id': 'BxLOgE8-LkyFvpctaEIf2Q',
#    'alias': 'monmouth-kitchen-london',
#    'name': 'Monmouth Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/g9fkinCsR4TlaNz4LPBR0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/monmouth-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.514233, 'longitude': -0.127168},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '20 Mercer Street',
#     'address2': 'Covent Garden',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2H 9HD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Mercer Street',
#      'Covent Garden',
#      'London WC2H 9HD',
#      'United Kingdom']},
#    'phone': '+442078458607',
#    'display_phone': '+44 20 7845 8607',
#    'distance': 624.2132955812355},
#   {'id': 'PEgAoJeVtVAbmuNKUWa-wg',
#    'alias': '10-greek-street-london',
#    'name': '10 Greek Street',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-88bKhhTr5nVtN6hxERGlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/10-greek-street-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5144981659116,
#     'longitude': -0.131063461303711},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '10 Greek Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 4DH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Greek Street',
#      'London W1D 4DH',
#      'United Kingdom']},
#    'phone': '+442077344677',
#    'display_phone': '+44 20 7734 4677',
#    'distance': 385.73947726767943},
#   {'id': '1qNEj896lQeb4iX0pFdbOQ',
#    'alias': 'casa-manolo-london-2',
#    'name': 'Casa Manolo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/raoJjajIm780n-hUEpL0jw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-manolo-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5104451, 'longitude': -0.1205752},
#    'transactions': [],
#    'location': {'address1': '99 Strand',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2R 0EW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['99 Strand', 'London WC2R 0EW', 'United Kingdom']},
#    'phone': '+442072409872',
#    'display_phone': '+44 20 7240 9872',
#    'distance': 1097.0668207008844},
#   {'id': 'MCx1FDljaGB7wGdFtPHPtA',
#    'alias': 'moro-restaurant-london',
#    'name': 'Moro Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T87mAPP6kaENLAibDUU_TQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moro-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 76,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.525859880105,
#     'longitude': -0.10906549497442},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '34-36 Exmouth Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 4QE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['34-36 Exmouth Market',
#      'London EC1R 4QE',
#      'United Kingdom']},
#    'phone': '+442078338336',
#    'display_phone': '+44 20 7833 8336',
#    'distance': 2357.7775297856156},
#   {'id': 'HMCVjigSFKU4ANVKqF4A-g',
#    'alias': 'bar-191-london',
#    'name': 'Bar 191',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/E9mq6uTrNejaJIsi24A-NA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-191-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4108354, 'longitude': -0.2281119},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '191 Worple Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW20 8RE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['191 Worple Road',
#      'London SW20 8RE',
#      'United Kingdom']},
#    'phone': '+442089445533',
#    'display_phone': '+44 20 8944 5533',
#    'distance': 13017.106617326297},
#   {'id': 'B3G1IoAyqTKWBMNUiB2SLA',
#    'alias': 'morso-restaurant-london',
#    'name': 'Morso Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DoaJfv63NvwxCXtKJu5DNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/morso-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5370894, 'longitude': -0.1858321},
#    'transactions': [],
#    'location': {'address1': '130 Boundary Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 0RH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['130 Boundary Road',
#      'London NW8 0RH',
#      'United Kingdom']},
#    'phone': '+442076247412',
#    'display_phone': '+44 20 7624 7412',
#    'distance': 4375.5197725399},
#   {'id': 'ifVVNQ10aBG8a78oYGbE-g',
#    'alias': 'sabor-iberico-barbican',
#    'name': 'Sabor Iberico',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6mTSsffxlLxF8QsGKsFJjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sabor-iberico-barbican?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5221635, 'longitude': -0.0928426},
#    'transactions': [],
#    'location': {'address1': '105-107 Whitecross street',
#     'address2': '',
#     'address3': '',
#     'city': 'Barbican',
#     'zip_code': 'EC1Y 8JD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['105-107 Whitecross street',
#      'Barbican EC1Y 8JD',
#      'United Kingdom']},
#    'phone': '+442073746713',
#    'display_phone': '+44 20 7374 6713',
#    'distance': 3030.8863267887127},
#   {'id': '7kBtTjr1SdEDESFiyan-Ag',
#    'alias': 'apero-restaurant-and-bar-london',
#    'name': 'Apero Restaurant and Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4itRKhjda2FZNmDd1uWylQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/apero-restaurant-and-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4942818627381,
#     'longitude': -0.175694857095886},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Harrington Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Harrington Road',
#      'London SW7 3ER',
#      'United Kingdom']},
#    'phone': '+442075914410',
#    'display_phone': '+44 20 7591 4410',
#    'distance': 3438.2722475474984},
#   {'id': 'IXfqW71UvwKzjSg0HsFiFQ',
#    'alias': 'ottolenghi-london-6',
#    'name': 'Ottolenghi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nSI6P0JGdPmlMOd5NVpPpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ottolenghi-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5181446, 'longitude': -0.0771446},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '50 Artillery Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 7LJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50 Artillery Lane',
#      'London E1 7LJ',
#      'United Kingdom']},
#    'phone': '+442072471999',
#    'display_phone': '+44 20 7247 1999',
#    'distance': 4112.162343972592},
#   {'id': 'PcbpnAstLLgJlG79NWauJg',
#    'alias': 'pix-london-6',
#    'name': 'Pix',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/q3TkEA3oQ7TowWKZLs7RuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pix-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5129536, 'longitude': -0.1392527},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '24 Ganton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7QY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Ganton Street',
#      'London W1F 7QY',
#      'United Kingdom']},
#    'phone': '+442072873031',
#    'display_phone': '+44 20 7287 3031',
#    'distance': 228.52490094199717},
#   {'id': 'aNe-csvGyoEkw62ysRbqpA',
#    'alias': 'the-distillery-london-3',
#    'name': 'The Distillery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6qYa5K11h32iF0-vGRvAyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-distillery-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'distilleries', 'title': 'Distilleries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5160106198114,
#     'longitude': -0.204917461249907},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '186 Portobello Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W11 2DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['186 Portobello Road',
#      'London W11 2DY',
#      'United Kingdom']},
#    'phone': '+442030342233',
#    'display_phone': '+44 20 3034 2233',
#    'distance': 4785.083885315025},
#   {'id': 'Q3iHRt03xgAmLfT-ykx_Eg',
#    'alias': 'cannick-tapps-london',
#    'name': 'Cannick Tapps',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cannick-tapps-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.51168, 'longitude': -0.08968},
#    'transactions': [],
#    'location': {'address1': '109 Cannon Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EC4A 4AN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['109 Cannon Street',
#      'London EC4A 4AN',
#      'United Kingdom']},
#    'phone': '+442076268246',
#    'display_phone': '+44 20 7626 8246',
#    'distance': 3206.283029767933},
#   {'id': '5ocwwJ87gbxxL4OksSnr0w',
#    'alias': 'eyre-brothers-london',
#    'name': 'Eyre Brothers',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/01CMPmHnL9DAC-aUjDVJFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eyre-brothers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'portuguese', 'title': 'Portuguese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.524571530634,
#     'longitude': -0.083271497961901},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '70 Leonard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 4QX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['70 Leonard Street',
#      'London EC2A 4QX',
#      'United Kingdom']},
#    'phone': '+442076135346',
#    'display_phone': '+44 20 7613 5346',
#    'distance': 3871.8762602623938},
#   {'id': '8P4qwhVKdxoV1bW-_I3s-A',
#    'alias': 'the-dairy-london-2',
#    'name': 'The Dairy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9gI0ORT8RPrbeM1xa1KNhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dairy-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4618724, 'longitude': -0.1395915},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '15 The Pavement',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW4 0HY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 The Pavement',
#      'London SW4 0HY',
#      'United Kingdom']},
#    'phone': '+442076224165',
#    'display_phone': '+44 20 7622 4165',
#    'distance': 5672.422770158091},
#   {'id': 'utRALTc6JCTWQ2HTPnmH7w',
#    'alias': 'camino-london-6',
#    'name': 'Camino',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yC5eiIWq6HEFficfKkBj0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camino-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.510981239674,
#     'longitude': -0.0816555045794029},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '15 Mincing Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3R 7BD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Mincing Lane',
#      'London EC3R 7BD',
#      'United Kingdom']},
#    'phone': '+442078417335',
#    'display_phone': '+44 20 7841 7335',
#    'distance': 3763.358721084851},
#   {'id': 'DsHjEAme_QeR93Q9Wtlxsw',
#    'alias': 'tapa-tapa-london-3',
#    'name': 'Tapa Tapa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TjSN6PQr10qX9XNDxi_R5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tapa-tapa-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5088112676765,
#     'longitude': 0.0255981732161321},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Warehouse K',
#     'address2': 'Western Gateway',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E16 1DR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Warehouse K',
#      'Western Gateway',
#      'London E16 1DR',
#      'United Kingdom']},
#    'phone': '+442074734874',
#    'display_phone': '+44 20 7473 4874',
#    'distance': 11189.123271914284},
#   {'id': 'cz2sDzAszy3YhzFXtaMpWg',
#    'alias': 'la-cabina-dalston',
#    'name': 'La Cabina',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Gcn066NHIYrS0uuzV-yBKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-cabina-dalston?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.535655, 'longitude': -0.076716},
#    'transactions': [],
#    'location': {'address1': '232 Kingsland Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Dalston',
#     'zip_code': 'E2 8AX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['232 Kingsland Road',
#      'Dalston E2 8AX',
#      'United Kingdom']},
#    'phone': '+442034870896',
#    'display_phone': '+44 20 3487 0896',
#    'distance': 4818.288623107317},
#   {'id': 'VTMZPFQ-cyPuKLnqAOxXwQ',
#    'alias': 'la-tasca-restaurant-london',
#    'name': 'La Tasca Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/36T5Dq_ClwgqieuglqDg_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-tasca-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5114047, 'longitude': -0.126852},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "63-66 St. Martin's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4JS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["63-66 St. Martin's Lane",
#      'London WC2N 4JS',
#      'United Kingdom']},
#    'phone': '+442072402011',
#    'display_phone': '+44 20 7240 2011',
#    'distance': 649.7807048551338},
#   {'id': 'fWtrmqyjwI2urelGvGP1rw',
#    'alias': 'la-bodega-tapas-bar-london',
#    'name': 'La Bodega Tapas Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/49eooHOBIIUyoTdUJ8TueQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-bodega-tapas-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.518248374611,
#     'longitude': -0.20661031224103},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '78 Tavistock Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 1AN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['78 Tavistock Road',
#      'London W11 1AN',
#      'United Kingdom']},
#    'phone': '+442077275660',
#    'display_phone': '+44 20 7727 5660',
#    'distance': 4925.97290600177},
#   {'id': 'FzONldsJNcWXH9-jJhQS3A',
#    'alias': 'leños-and-carbón-london-3',
#    'name': 'Leños & Carbón',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5diMp_XxlySUJ7E1bu4KKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le%C3%B1os-and-carb%C3%B3n-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4943619, 'longitude': -0.0980439},
#    'transactions': [],
#    'location': {'address1': '113 Elephant Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE17 1LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['113 Elephant Road',
#      'London SE17 1LB',
#      'United Kingdom']},
#    'phone': '+442074078865',
#    'display_phone': '+44 20 7407 8865',
#    'distance': 3326.561949577643},
#   {'id': 'AEIHz3vzjJ1Ev6Io50JXQw',
#    'alias': 'bar-douro-london',
#    'name': 'Bar Douro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SE5PNG3XOjoi0DP7X8Zl_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-douro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'portuguese', 'title': 'Portuguese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5043699861763,
#     'longitude': -0.0951653841308371},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Arch 35B',
#     'address2': 'Flat Iron Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1TD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Arch 35B',
#      'Flat Iron Square',
#      'London SE1 1TD',
#      'United Kingdom']},
#    'phone': '+442073780524',
#    'display_phone': '+44 20 7378 0524',
#    'distance': 2975.80206293795},
#   {'id': 'vCF8ut7OZcfA4hEmhngfSQ',
#    'alias': 'andina-london',
#    'name': 'Andina',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sgBZI-KCVdW5u838gGQW6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/andina-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 142,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5243208695971,
#     'longitude': -0.077134990126122},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Redchurch Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7DJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Redchurch Street',
#      'London E2 7DJ',
#      'United Kingdom']},
#    'phone': '+442079206499',
#    'display_phone': '+44 20 7920 6499',
#    'distance': 4265.6096504626785},
#   {'id': '_xON7NLorYnqEuFdcfwIxw',
#    'alias': 'sagami-ya-japanese-brasserie-london',
#    'name': 'Sagami-ya Japanese Brasserie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/87hxNfuh8YusGDCGCRCwJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sagami-ya-japanese-brasserie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5012454408064,
#     'longitude': -0.118619217999253},
#    'transactions': [],
#    'location': {'address1': 'County Hall',
#     'address2': 'Belvedere Road',
#     'address3': 'Lambeth',
#     'city': 'London',
#     'zip_code': 'SE1 7PB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['County Hall',
#      'Belvedere Road',
#      'Lambeth',
#      'London SE1 7PB',
#      'United Kingdom']},
#    'phone': '+447507914874',
#    'display_phone': '+44 7507 914874',
#    'distance': 1760.840332007885},
#   {'id': 'A_FDLFIIzyReg7k7VhxBlQ',
#    'alias': 'the-little-taperia-london',
#    'name': 'The Little Taperia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Gl7W37mDDe5VrBTKSfPQhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-little-taperia-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4254684, 'longitude': -0.1701196},
#    'transactions': [],
#    'location': {'address1': '143 Tooting High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW17 0SY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['143 Tooting High Street',
#      'London SW17 0SY',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9999.894086664091},
#   {'id': '3xexIL9jt0lRBaqwUqGEFQ',
#    'alias': 'philomenas-bar-and-cafe-london-2',
#    'name': "Philomena's Bar and Cafe",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6lJNclgsJxEvUXeUOCYIFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/philomenas-bar-and-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.515147, 'longitude': -0.121914},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '40 Great Queen Street',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 Great Queen Street',
#      'Covent Garden',
#      'London WC2B 5AA',
#      'United Kingdom']},
#    'phone': '+442072425560',
#    'display_phone': '+44 20 7242 5560',
#    'distance': 1005.6707950743768},
#   {'id': '1KeK0DqDe93dzHm1LMoiNA',
#    'alias': 'la-tasca-london-17',
#    'name': 'La Tasca',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EUXPuh6Nq78y3YqT66dKGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-tasca-london-17?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51269, 'longitude': -0.083405},
#    'transactions': [],
#    'location': {'address1': '26 - 27 Leadenhall Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3V 1LR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 - 27 Leadenhall Market',
#      'London EC3V 1LR',
#      'United Kingdom']},
#    'phone': '+442076231818',
#    'display_phone': '+44 20 7623 1818',
#    'distance': 3628.000111211402},
#   {'id': 'uRARkDJS52wlpedM2e9IYg',
#    'alias': 'barsito-london',
#    'name': 'Barsito',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/a4io1oqHpPVxHVKEIlt65g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barsito-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4627495, 'longitude': -0.1379308},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '57 Venn Street',
#     'address2': 'Clapham',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW4 0BD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57 Venn Street',
#      'Clapham',
#      'London SW4 0BD',
#      'United Kingdom']},
#    'phone': '+442076274000',
#    'display_phone': '+44 20 7627 4000',
#    'distance': 5568.43450702354},
#   {'id': 'kTU1W-EWDtF1Bo3O8bk04Q',
#    'alias': 'la-rueda-london-2',
#    'name': 'La Rueda',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CCxrjp9bA6m6eRerPjI70w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-rueda-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4635887, 'longitude': -0.1334029},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '66 Clapham High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW4 7UL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Clapham High Street',
#      'London SW4 7UL',
#      'United Kingdom']},
#    'phone': '+442076272173',
#    'display_phone': '+44 20 7627 2173',
#    'distance': 5462.901171031538},
#   {'id': '7MUA0ebmkyyQG5YrR4WJpA',
#    'alias': 'norfolk-arms-london',
#    'name': 'Norfolk Arms',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yqrP4ZsPhxI8gu2veze6ZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/norfolk-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.526648, 'longitude': -0.12526},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '28 Leigh Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 9EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28 Leigh Street',
#      'London WC1H 9EP',
#      'United Kingdom']},
#    'phone': '+442073883937',
#    'display_phone': '+44 20 7388 3937',
#    'distance': 1704.1327478563194},
#   {'id': 'PWyrmKw-w70lBIR9a9qHZw',
#    'alias': 'gremio-de-brixton-london',
#    'name': 'Gremio de Brixton',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/95s91k-SxMBK1kwDjt2gew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gremio-de-brixton-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4598375615174,
#     'longitude': -0.115986530074246},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'The Crypt Brixton Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW2 1JF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Crypt Brixton Hill',
#      'London SW2 1JF',
#      'United Kingdom']},
#    'phone': '+442079240660',
#    'display_phone': '+44 20 7924 0660',
#    'distance': 6053.13533710378},
#   {'id': '2r5UOS3lGbhFY8n46kQqiQ',
#    'alias': 'grays-and-feather-wine-parlour-london-2',
#    'name': 'Grays & Feather Wine Parlour',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VfqjI7h3ATpbBgjQJCnONA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grays-and-feather-wine-parlour-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5121103010877,
#     'longitude': -0.12022589076522},
#    'transactions': [],
#    'location': {'address1': '26 Wellington Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2E 7DD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Wellington Street',
#      'London WC2E 7DD',
#      'United Kingdom']},
#    'phone': '+442039484900',
#    'display_phone': '+44 20 3948 4900',
#    'distance': 1091.516130335049},
#   {'id': 'gfTiXGI9pU3LVgf6piH2bQ',
#    'alias': 'oldroyd-london',
#    'name': 'Oldroyd',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RagzTc9K-w_hqmGNasW8HQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oldroyd-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5348857, 'longitude': -0.1042088},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '344 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 0PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['344 Upper Street',
#      'London N1 0PD',
#      'United Kingdom']},
#    'phone': '+442086179010',
#    'display_phone': '+44 20 8617 9010',
#    'distance': 3309.750610732193},
#   {'id': 'KAsdsmhroFTqsnVjprN30g',
#    'alias': 'pirana-london',
#    'name': 'Pirana',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/F4qPhg_zr0h7h16BF_4ipg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pirana-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4421615, 'longitude': -0.1494917},
#    'transactions': [],
#    'location': {'address1': '76 Bedford Hill',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW12 9HD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['76 Bedford Hill',
#      'London SW12 9HD',
#      'United Kingdom']},
#    'phone': '+442087728428',
#    'display_phone': '+44 20 8772 8428',
#    'distance': 7915.722419073999},
#   {'id': 'shtcu9CrJEHp3IhT0YvU7Q',
#    'alias': 'bar-pepito-london',
#    'name': 'Bar Pepito',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8Y7GLC7ocZPWU294y6Z-iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-pepito-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.531244, 'longitude': -0.121772},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "The Regent's Quarter",
#     'address2': '3 Varnishers Yard',
#     'address3': "King's Cross",
#     'city': 'London',
#     'zip_code': 'N1 9FD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["The Regent's Quarter",
#      '3 Varnishers Yard',
#      "King's Cross",
#      'London N1 9FD',
#      'United Kingdom']},
#    'phone': '+442078417331',
#    'display_phone': '+44 20 7841 7331',
#    'distance': 2270.0060321727015},
#   {'id': 'QVnFjlRLno_xU2nminAx-g',
#    'alias': 'tapas-revolution-london',
#    'name': 'Tapas Revolution',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3RoAwrngCclTDRLvL82LFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tapas-revolution-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.507247, 'longitude': -0.22233},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Kiosk K2024 The Balcony',
#     'address2': "Shepherd's Bush",
#     'address3': 'Westfield',
#     'city': 'London',
#     'zip_code': 'W12 7SL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Kiosk K2024 The Balcony',
#      "Shepherd's Bush",
#      'Westfield',
#      'London W12 7SL',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6009.751358920538},
#   {'id': '_-elas7RMSmqgfXN2MbSSQ',
#    'alias': 'taperia-deptford-london',
#    'name': 'Taperia Deptford',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xrTTo5Ypo56nphwbNqetOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taperia-deptford-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.472943, 'longitude': -0.021699},
#    'transactions': [],
#    'location': {'address1': '1 Deal Gateway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE13 7QD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Deal Gateway',
#      'London SE13 7QD',
#      'United Kingdom']},
#    'phone': '+442086940115',
#    'display_phone': '+44 20 8694 0115',
#    'distance': 9053.809090807728},
#   {'id': '51Nq0e6afkefxTSepcE9Gw',
#    'alias': 'mas-q-menos-london-3',
#    'name': 'Mas Q Menos',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7ZmvHGcJMJSGQk2fLMhs9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mas-q-menos-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5112038, 'longitude': -0.0799059},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '70 Mark Lane',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3R',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['70 Mark Lane', 'London EC3R', 'United Kingdom']},
#    'phone': '+442037780108',
#    'display_phone': '+44 20 3778 0108',
#    'distance': 3876.3211310405036},
#   {'id': 'IjezoTAhQT2yV1UchKLtgA',
#    'alias': 'eneko-basque-kitchen-and-bar-london',
#    'name': 'Eneko Basque Kitchen & Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rGshakkj08Tujq1aX6vByw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eneko-basque-kitchen-and-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5117832, 'longitude': -0.1194172},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1 Aldwych',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2B 4BZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Aldwych', 'London WC2B 4BZ', 'United Kingdom']},
#    'phone': '+442073000300',
#    'display_phone': '+44 20 7300 0300',
#    'distance': 1150.4659692206558},
#   {'id': 'V5DXWH_6VkPKe0eRuBBvIw',
#    'alias': 'don-teodoro-london',
#    'name': 'Don Teodoro',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/don-teodoro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'portuguese', 'title': 'Portuguese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5360424, 'longitude': -0.1395714},
#    'transactions': [],
#    'location': {'address1': '1 Plender Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 0',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Plender Street', 'London NW1 0', 'United Kingdom']},
#    'phone': '+442073833233',
#    'display_phone': '+44 20 7383 3233',
#    'distance': 2596.341513974936}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#           Restaurant             Type Price Rating               Address  \
# 0      Duck & Waffle  Modern European   £££      4       110 Bishopsgate
# 1         El Vino Co        Wine Bars    ££    3.5  30 New Bridge Street
# 2  La Rueda de Tapas          Spanish    ££      3        12 Bond Street
# 3              POLPO          Italian    ££      4         6 Maiden Lane
# 4      Connaught Bar             Bars  ££££    4.5         The Connaught
#
#          Lat       Lng                                                url  \
# 0  51.516178 -0.080940  https://www.yelp.com/biz/duck-and-waffle-londo...
# 1  51.512574 -0.103990  https://www.yelp.com/biz/el-vino-co-london?adj...
# 2  51.512287 -0.306182  https://www.yelp.com/biz/la-rueda-de-tapas-lon...
# 3  51.510749 -0.122644  https://www.yelp.com/biz/polpo-london-16?adjus...
# 4  51.510156 -0.149631  https://www.yelp.com/biz/connaught-bar-london?...
#
#                        ID
# 0  hOLFwKg4-0FsCleJ4yoCXw
# 1  G2EF7KepnKIaaIlr-DxeAQ
# 2  cQzR9_RVVPdwWYE7fXL14w
# 3  kwLvscNdOfBJTpm5qtD-iA
# 4  hXWtuKNmbVzAYtoZhNLLPw

# %%
#4th set of 50 records 151-200
lndr_params4 = {"term":term,"location":"London","limit":50,"offset":151}
lndr_response4 = requests.get(search_api_url, headers=headers, params=lndr_params4)
lndr4 = lndr_response4.json()
display(lndr4)
#print(lndr_response4.url)
#print(lndr_response4.status_code)
# Out:
# {'businesses': [{'id': 'qbao4zL07Kmnto4XGr7ktA',
#    'alias': 'bacino-london',
#    'name': "B'acino",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rIdYEU7_PQBoAVRmpE8GUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bacino-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5234131797006,
#     'longitude': -0.0809871181845665},
#    'transactions': [],
#    'location': {'address1': '54-56 Scrutton Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EC2A 4PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54-56 Scrutton Street',
#      'London EC2A 4PH',
#      'United Kingdom']},
#    'phone': '+442073928855',
#    'display_phone': '+44 20 7392 8855',
#    'distance': 3981.1511349114544},
#   {'id': 'AM2d672O6FjDpL82iVWTlg',
#    'alias': 'momo-london',
#    'name': 'Momo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1wtcMgYTFwevbAopsEL6sQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/momo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 116,
#    'categories': [{'alias': 'moroccan', 'title': 'Moroccan'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5111056, 'longitude': -0.1403264},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '25-27 Heddon Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 4BH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['25-27 Heddon Street',
#      'London W1B 4BH',
#      'United Kingdom']},
#    'phone': '+442074344040',
#    'display_phone': '+44 20 7434 4040',
#    'distance': 358.44161076116546},
#   {'id': 'XeAaUJWcS9RZsE80a1UxjA',
#    'alias': 'mestizo-london',
#    'name': 'Mestizo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m15vQhfhss5ycfcdVatg7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mestizo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 153,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.52752, 'longitude': -0.1387649},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '103 Hampstead Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 3EL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['103 Hampstead Road',
#      'London NW1 3EL',
#      'United Kingdom']},
#    'phone': '+442073874064',
#    'display_phone': '+44 20 7387 4064',
#    'distance': 1656.1089625620355},
#   {'id': 'gJAFSUO7U70GQJFo3ynRUw',
#    'alias': 'rapsa-london-2',
#    'name': 'Rapsa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fouHC09o9SvAWW-yBPmfbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rapsa-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5310648658011,
#     'longitude': -0.0800106030410461},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '100-104 Hoxton Street',
#     'address2': 'Shoreditch',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 6SG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['100-104 Hoxton Street',
#      'Shoreditch',
#      'London N1 6SG',
#      'United Kingdom']},
#    'phone': '+442077291444',
#    'display_phone': '+44 20 7729 1444',
#    'distance': 4369.319716613212},
#   {'id': 'RC9q1pP2Vmjz80NBO_O05g',
#    'alias': '5th-view-bar-and-food-london',
#    'name': '5th View Bar & Food',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/R-5lrvSQcySR1_YtP3TQhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/5th-view-bar-and-food-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5090707, 'longitude': -0.1363054},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "Waterstone's Piccadilly",
#     'address2': '203-206 Piccadilly',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 9LE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["Waterstone's Piccadilly",
#      '203-206 Piccadilly',
#      'London W1J 9LE',
#      'United Kingdom']},
#    'phone': '+442078512433',
#    'display_phone': '+44 20 7851 2433',
#    'distance': 412.6399958027281},
#   {'id': 'aywIyiNMxy4nbBabMGK1Vw',
#    'alias': 'bedales-of-borough-market-london',
#    'name': 'Bedales of Borough Market',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/W7ZhXwSWsVzhAiQYNcrODA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bedales-of-borough-market-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.505406, 'longitude': -0.0898341},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5 Bedale Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9AL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Bedale Street',
#      'London SE1 9AL',
#      'United Kingdom']},
#    'phone': '+442074038853',
#    'display_phone': '+44 20 7403 8853',
#    'distance': 3297.098607334311},
#   {'id': 'vlyegsU6Sobc5zWEwkZkRg',
#    'alias': 'boki-london',
#    'name': 'Boki',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YLnEyagnfe3RoKvMz2n3DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boki-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.513575, 'longitude': -0.127627},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Earlham Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2H 9LG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Earlham Street',
#      'London WC2H 9LG',
#      'United Kingdom']},
#    'phone': '+442078368589',
#    'display_phone': '+44 20 7836 8589',
#    'distance': 582.1923509348951},
#   {'id': 'JLnG7C_TiDVTpEUEGXIuUg',
#    'alias': 'cigala-restaurant-london',
#    'name': 'Cigala Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2wteyzZ4y4nn2L5ZQvx77g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cigala-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5220678, 'longitude': -0.1183506},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '54 Lambs Conduit Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 3LW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54 Lambs Conduit Street',
#      'London WC1N 3LW',
#      'United Kingdom']},
#    'phone': '+442074051717',
#    'display_phone': '+44 20 7405 1717',
#    'distance': 1588.7018640739159},
#   {'id': 'hS7k6pamcC85unubWTiOZQ',
#    'alias': 'ceru-london-6',
#    'name': 'Ceru',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7syjh3SQpOipqm4FLG7Q1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ceru-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4934256, 'longitude': -0.176283},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '7-9 Bute Street',
#     'address2': 'South Kensington',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW7 3EY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7-9 Bute Street',
#      'South Kensington',
#      'London SW7 3EY',
#      'United Kingdom']},
#    'phone': '+442031953001',
#    'display_phone': '+44 20 3195 3001',
#    'distance': 3528.3682194177145},
#   {'id': '9K-A7wHxB-z3n5h-P_mYFA',
#    'alias': 'vinoteca-kings-cross-london',
#    'name': 'Vinoteca Kings Cross',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7EEdDIkdCr9_lZulQOEI6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vinoteca-kings-cross-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5327386594665,
#     'longitude': -0.124989295739738},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'One Pancras Square',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['One Pancras Square',
#      'London N1C 4AG',
#      'United Kingdom']},
#    'phone': '+442037937210',
#    'display_phone': '+44 20 3793 7210',
#    'distance': 2339.5707067138264},
#   {'id': 'ofwMyWQN3MMfpqxa3y3l_w',
#    'alias': 'opera-tavern-london',
#    'name': 'Opera Tavern',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qwgQQue8iNTto7QvOZbHQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/opera-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5124698, 'longitude': -0.1204465},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '23 Catherine Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5JS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23 Catherine Street',
#      'London WC2B 5JS',
#      'United Kingdom']},
#    'phone': '+442078363680',
#    'display_phone': '+44 20 7836 3680',
#    'distance': 1077.0170548099657},
#   {'id': '0et_IK49bQhTjhcKZwV-pQ',
#    'alias': 'highbury-arts-club-london',
#    'name': 'Highbury Arts Club',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pZ6_2NbJvt6sWj5jLi-6pw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/highbury-arts-club-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5561568397679,
#     'longitude': -0.0981608113437638},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '73 Highbury Park',
#     'address2': 'Highbury Barn',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N5 1UA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['73 Highbury Park',
#      'Highbury Barn',
#      'London N5 1UA',
#      'United Kingdom']},
#    'phone': '+447826899499',
#    'display_phone': '+44 7826 899499',
#    'distance': 5480.7450137629585},
#   {'id': 'xdw_P7cZBp8PTG6eM2B2tg',
#    'alias': 'bradleys-spanish-bar-london-2',
#    'name': "Bradley's Spanish Bar",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cP4ymz-wvnMV7MewGGi4fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bradleys-spanish-bar-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516396827163,
#     'longitude': -0.132729090213047},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '42-44 Hanway Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 1UT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42-44 Hanway Street',
#      'London W1T 1UT',
#      'United Kingdom']},
#    'phone': '+442076360359',
#    'display_phone': '+44 20 7636 0359',
#    'distance': 454.61013667159625},
#   {'id': '89qpxd9qtTI4plPxHPZf0g',
#    'alias': 'fernandez-and-wells-london-3',
#    'name': 'Fernandez & Wells',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yRtKahoPJZewTOA5E00kxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fernandez-and-wells-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5120811, 'longitude': -0.11688},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'East Wing Somerset House',
#     'address2': 'Strand',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2R 1LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['East Wing Somerset House',
#      'Strand',
#      'London WC2R 1LA',
#      'United Kingdom']},
#    'phone': '+442074209408',
#    'display_phone': '+44 20 7420 9408',
#    'distance': 1285.7715860031617},
#   {'id': 'WHSJsMnrsAQEN4TKo0n7XA',
#    'alias': 'lord-nelson-london-2',
#    'name': 'Lord Nelson',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4heSWuWOQKVc3uJr4YpRvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lord-nelson-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.503489520908,
#     'longitude': -0.10225512172207},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '243 Union Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0LR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['243 Union Street',
#      'London SE1 0LR',
#      'United Kingdom']},
#    'phone': '+442072072701',
#    'display_phone': '+44 20 7207 2701',
#    'distance': 2553.4058565853998},
#   {'id': '4-CULvL9R1LiEyOn6YHwPA',
#    'alias': 'enoteca-pomaio-london',
#    'name': 'Enoteca Pomaio',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PKCdBgH6FgKgeDp18weYlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/enoteca-pomaio-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5247942, 'longitude': -0.0714714},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '224 Brick Lane',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6SA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['224 Brick Lane', 'London E1 6SA', 'United Kingdom']},
#    'phone': '+442032220031',
#    'display_phone': '+44 20 3222 0031',
#    'distance': 4653.745072645295},
#   {'id': 'JqCq3vd0pHAwc1iRukp7Pg',
#    'alias': 'planet-of-the-grapes-london-2',
#    'name': 'Planet of the Grapes',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-efdTGKeq_RtI0pxmS4khQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/planet-of-the-grapes-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512596, 'longitude': -0.093627},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '74-82 Queen Victoria Street',
#     'address2': 'Bow Lane',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4N 4SJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['74-82 Queen Victoria Street',
#      'Bow Lane',
#      'London EC4N 4SJ',
#      'United Kingdom']},
#    'phone': '+442072481892',
#    'display_phone': '+44 20 7248 1892',
#    'distance': 2922.0300030007793},
#   {'id': 'il6Inhzrqu6VG9JB2yR12g',
#    'alias': 'rosita-and-the-sherry-bar-london',
#    'name': 'Rosita and The Sherry Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xjSVKXt1Tff93biaM7SdmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rosita-and-the-sherry-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4561273, 'longitude': -0.165453999999976},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '124 Northcote Road',
#     'address2': 'London',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW11 6QU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['124 Northcote Road',
#      'London',
#      'London SW11 6QU',
#      'United Kingdom']},
#    'phone': '+442079989093',
#    'display_phone': '+44 20 7998 9093',
#    'distance': 6628.230371791463},
#   {'id': '5oeBHVtncsgfV5bLSMVVeA',
#    'alias': 'las-barilles-london',
#    'name': 'Las Barilles',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/las-barilles-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.524381, 'longitude': -0.099478},
#    'transactions': [],
#    'location': {'address1': '55-63 Goswell Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 7EN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55-63 Goswell Road',
#      'London EC1V 7EN',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2831.9738345911146},
#   {'id': 'Wp9G9XQLWsaxfbNdGwcacw',
#    'alias': 'casa-manolo-london',
#    'name': 'Casa Manolo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yXVOan6CUZIOwSbhe8hsLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-manolo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4871328668651,
#     'longitude': -0.16912266464558},
#    'transactions': [],
#    'location': {'address1': "187 King's Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 5EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["187 King's Road",
#      'London SW3 5EB',
#      'United Kingdom']},
#    'phone': '+442073521215',
#    'display_phone': '+44 20 7352 1215',
#    'distance': 3665.921146091279},
#   {'id': 'DguKdtdKKRg5U0OBiZa_sw',
#    'alias': 'tendido-cuatro-london',
#    'name': 'Tendido Cuatro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hIYXJGNs2_VYEZXRmoLdGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tendido-cuatro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.4721336364746,
#     'longitude': -0.204386994242668},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '108 New Kings Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 4LY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['108 New Kings Rd',
#      'London SW6 4LY',
#      'United Kingdom']},
#    'phone': '+442073715147',
#    'display_phone': '+44 20 7371 5147',
#    'distance': 6551.961082434741},
#   {'id': 'ZRAwGetiZCbOpRuR71kpKg',
#    'alias': 'el-botellon-london',
#    'name': 'El Botellon',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kBjf7ujTMHEGVbn_6tb7Qw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-botellon-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.585665, 'longitude': -0.071372},
#    'transactions': [],
#    'location': {'address1': '260-262 High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N15 4AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['260-262 High Road',
#      'London N15 4AJ',
#      'United Kingdom']},
#    'phone': '+442036455659',
#    'display_phone': '+44 20 3645 5659',
#    'distance': 9236.405344011491},
#   {'id': 'myFgcdEQQTo2qguoATe7AQ',
#    'alias': 'tapeo-cafe-and-tapas-beckenham',
#    'name': 'Tapeo Cafe and Tapas',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oHj3V_fk9gjGfoD1r7VGHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tapeo-cafe-and-tapas-beckenham?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4077210256529,
#     'longitude': -0.0269421190023422},
#    'transactions': [],
#    'location': {'address1': '142 Beckenham High Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Beckenham',
#     'zip_code': 'BR3 1EA',
#     'country': 'GB',
#     'state': 'KEN',
#     'display_address': ['142 Beckenham High Street',
#      'Beckenham BR3 1EA',
#      'United Kingdom']},
#    'phone': '+442034174310',
#    'display_phone': '+44 20 3417 4310',
#    'distance': 13915.980944639432},
#   {'id': 'T-XPkD7xHKJSgPe0xzj5xw',
#    'alias': 'flora-indica-london',
#    'name': 'Flora Indica',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vimIpI5Tv3ZrYbks8OcMXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flora-indica-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.489858, 'longitude': -0.189819},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '242 Old Brompton Road',
#     'address2': "Earl's Court",
#     'address3': 'Kensington & Chelsea',
#     'city': 'London',
#     'zip_code': 'SW5 0DE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['242 Old Brompton Road',
#      "Earl's Court",
#      'Kensington & Chelsea',
#      'London SW5 0DE',
#      'United Kingdom']},
#    'phone': '+442073704450',
#    'display_phone': '+44 20 7370 4450',
#    'distance': 4530.116879654809},
#   {'id': 'isPxXiqXRypEw8k45Gjjsw',
#    'alias': 'elche-restaurante-de-tapas-london',
#    'name': 'Elche Restaurante de Tapas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_9vJKn560dNf7d7wXL1APw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elche-restaurante-de-tapas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.633869, 'longitude': 0.009803},
#    'transactions': [],
#    'location': {'address1': '166 Station Road',
#     'address2': 'Chingford',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E4 6AN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['166 Station Road',
#      'Chingford',
#      'London E4 6AN',
#      'United Kingdom']},
#    'phone': '+442085248666',
#    'display_phone': '+44 20 8524 8666',
#    'distance': 16832.756792117587},
#   {'id': 'Y4K4LCi8UlBSan2oRd2o1g',
#    'alias': 'el-olivo-london-2',
#    'name': 'El Olivo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bIH7oomdHSY8iV2qsmUgsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-olivo-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5621758, 'longitude': -0.0747208},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '24 Stoke Newington Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 0LU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Stoke Newington Church Street',
#      'London N16 0LU',
#      'United Kingdom']},
#    'phone': '+442072547897',
#    'display_phone': '+44 20 7254 7897',
#    'distance': 6932.515059303843},
#   {'id': '53EK6ge7YyfdJmpCxzdA7Q',
#    'alias': 'art-of-tapas-london',
#    'name': 'Art of Tapas',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/art-of-tapas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 51.492009, 'longitude': -0.138797},
#    'transactions': [],
#    'location': {'address1': '16 Churton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 2LL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Churton Street',
#      'London SW1V 2LL',
#      'United Kingdom']},
#    'phone': '+442078282822',
#    'display_phone': '+44 20 7828 2822',
#    'distance': 2325.172712856146},
#   {'id': 'alC9ZQUlGSZ4SYfKVBl65A',
#    'alias': 'l-oculto-london',
#    'name': "L'Oculto",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yIHUk2d3u4naqtfJXhyG0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-oculto-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4673161, 'longitude': -0.0229169},
#    'transactions': [],
#    'location': {'address1': '57 Loampit Hill',
#     'address2': 'Lewisham - Brockley',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE13 7SZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57 Loampit Hill',
#      'Lewisham - Brockley',
#      'London SE13 7SZ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9320.406659645661},
#   {'id': 'auk6Ae1wwEd0430tMQ8hjQ',
#    'alias': 'brumus-london-2',
#    'name': 'Brumus',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WbBfjMFVWOuL_nZfrHrGkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brumus-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5083941472032,
#     'longitude': -0.131208717823029},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1 Suffolk Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 4BP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Suffolk Place',
#      'London SW1Y 4BP',
#      'United Kingdom']},
#    'phone': '+442074704007',
#    'display_phone': '+44 20 7470 4007',
#    'distance': 593.1443516760166},
#   {'id': 'Q1ELAXgpTgu0OOp5xGmbPQ',
#    'alias': 'yuu-kitchen-london',
#    'name': 'YUU Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/boBNmTDLnb7FNzmYWeEutg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yuu-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5163453296298,
#     'longitude': -0.0733002399505267},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '29 Commercial Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E1 6NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['29 Commercial Street',
#      'London E1 6NE',
#      'United Kingdom']},
#    'phone': '+442073770411',
#    'display_phone': '+44 20 7377 0411',
#    'distance': 4353.184139535283},
#   {'id': 'ab7p0APUwPQnmBdyvQBqdw',
#    'alias': 'the-provincial-london',
#    'name': 'The Provincial',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XL1c4eaA9ndjGbiqA37KEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-provincial-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4617538, 'longitude': -0.1132681},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 21',
#     'address2': 'Market Row',
#     'address3': 'Brixton',
#     'city': 'London',
#     'zip_code': 'SW9 8LD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 21',
#      'Market Row',
#      'Brixton',
#      'London SW9 8LD',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5893.245597666611},
#   {'id': 'hAquCqR6pbCOZKJc_RuOaw',
#    'alias': 'mas-q-menos-london',
#    'name': 'Mas Q Menos',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pNWr9CyBOgx3RQs0-s-JaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mas-q-menos-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.517910248824,
#     'longitude': -0.116228820717674},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '272 High Holborn',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1V 7EY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['272 High Holborn',
#      'London WC1V 7EY',
#      'United Kingdom']},
#    'phone': '+442078313940',
#    'display_phone': '+44 20 7831 3940',
#    'distance': 1477.083394042611},
#   {'id': 'uLJp1QsowWjJ9qNXHZIIpw',
#    'alias': 'ametsa-london-2',
#    'name': 'Ametsa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VlgMInKB1bVICUe0Cu-jWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ametsa-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5008477, 'longitude': -0.1518671},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '5-6 Halkin Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7DJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5-6 Halkin Street',
#      'London SW1X 7DJ',
#      'United Kingdom']},
#    'phone': '+442073331234',
#    'display_phone': '+44 20 7333 1234',
#    'distance': 1729.026038110191},
#   {'id': 'EazZp7bn_8HkTqUscy7Erg',
#    'alias': 'orford-saloon-tapas-bar-london',
#    'name': 'Orford Saloon Tapas Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HnMgqC0ih6uoPZViWXq1vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/orford-saloon-tapas-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.582562, 'longitude': -0.013116},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '32 Orford Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E17 9NJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['32 Orford Road', 'London E17 9NJ', 'United Kingdom']},
#    'phone': '+442085036542',
#    'display_phone': '+44 20 8503 6542',
#    'distance': 11496.05715442962},
#   {'id': 'yjwyF_QA5BdEqNvqqlvwdQ',
#    'alias': 'sky-pod-bar-london',
#    'name': 'Sky Pod Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/U91kH5VbT7PITPl1g5kVDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sky-pod-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5113382443007,
#     'longitude': -0.083578996360302},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Fenchurch Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3M 3BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Fenchurch Street',
#      'London EC3M 3BY',
#      'United Kingdom']},
#    'phone': '+443337720020',
#    'display_phone': '+44 333 772 0020',
#    'distance': 3628.403657173922},
#   {'id': '2DscCJkNHiZv63JebpC9HA',
#    'alias': 'trader-vics-london',
#    'name': "Trader Vic's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3KNl5XmvpIHxjbC_CMAm0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trader-vics-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'hawaiian', 'title': 'Hawaiian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5054604652401,
#     'longitude': -0.150574000276853},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Park Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 1BE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Park Lane', 'London W1K 1BE', 'United Kingdom']},
#    'phone': '+442072084113',
#    'display_phone': '+44 20 7208 4113',
#    'distance': 1302.303743376059},
#   {'id': 'Lp5AgT02FlvuS4RKUyE9og',
#    'alias': 'las-iguanas-london',
#    'name': 'Las Iguanas',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tNHwHi66khMmYfcDQt2Ahg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/las-iguanas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 87,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5055947841907,
#     'longitude': -0.117650182564496},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Royal Festival Hall Festival Terrace',
#     'address2': 'Southbank Centre',
#     'address3': 'Belvedere Road',
#     'city': 'London',
#     'zip_code': 'SE1 8XX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Royal Festival Hall Festival Terrace',
#      'Southbank Centre',
#      'Belvedere Road',
#      'London SE1 8XX',
#      'United Kingdom']},
#    'phone': '+442076201328',
#    'display_phone': '+44 20 7620 1328',
#    'distance': 1501.0625729181472},
#   {'id': 'r-40hpB7G8QmMbb6dxKIWQ',
#    'alias': 'fumo-london',
#    'name': 'Fumo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FUXHbfY-yuDKKty-JkjWQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fumo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 52,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5099474, 'longitude': -0.1269062},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "N37 St Martin's Lane",
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2N 4ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["N37 St Martin's Lane",
#      'London WC2N 4ER',
#      'United Kingdom']},
#    'phone': '+442037780430',
#    'display_phone': '+44 20 3778 0430',
#    'distance': 703.8013663465491},
#   {'id': 'Ii_CsiiPkg0MzsZrVWSMwQ',
#    'alias': 'the-bird-in-hand-london-3',
#    'name': 'The Bird In Hand',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CMHN1DAX3ao2hSoFoTFbzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bird-in-hand-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.499761921973,
#     'longitude': -0.21544145627873},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '88 Masbro Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W14 0LR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['88 Masbro Road', 'London W14 0LR', 'United Kingdom']},
#    'phone': '+442073712721',
#    'display_phone': '+44 20 7371 2721',
#    'distance': 5690.099093804208},
#   {'id': 'nbuZsM-j0NnQlD-jeJ64sQ',
#    'alias': 'the-real-greek-soho-london',
#    'name': 'The Real Greek - Soho',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4GipHpOljbtoLoALRzc6uQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-real-greek-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5154839, 'longitude': -0.1362927},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '50 Berwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8SJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50 Berwick Street',
#      'London W1F 8SJ',
#      'United Kingdom']},
#    'phone': '+442072876805',
#    'display_phone': '+44 20 7287 6805',
#    'distance': 293.06178009484626},
#   {'id': 'bAbFz2Q16S7r8eDrEk4TuQ',
#    'alias': 'padron-london-4',
#    'name': 'Padron',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/padron-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.516096, 'longitude': -0.077266},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '13 Harrow Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 7DB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Harrow Place', 'London E1 7DB', 'United Kingdom']},
#    'phone': '+442073778586',
#    'display_phone': '+44 20 7377 8586',
#    'distance': 4088.9292887775014},
#   {'id': '3jUuBgt_V3GuCXf2PP-mbg',
#    'alias': 'wine-rooms-london',
#    'name': 'Wine Rooms',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2lGvX6fzPKDDAMNCY8O16g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wine-rooms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5072869094514,
#     'longitude': -0.194856309601584},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '127-129 Kensington Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 7LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['127-129 Kensington Church Street',
#      'London W8 7LP',
#      'United Kingdom']},
#    'phone': '+442077278142',
#    'display_phone': '+44 20 7727 8142',
#    'distance': 4122.643871096528},
#   {'id': 'b7RW2pHBLX1gpSKCrIm4AQ',
#    'alias': 'builders-arms-london',
#    'name': 'Builders Arms',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1haAluRxsAMs8uNoEbFMLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/builders-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4994295095615,
#     'longitude': -0.188299279589993},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Kensington Court Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 5BJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Kensington Court Place',
#      'London W8 5BJ',
#      'United Kingdom']},
#    'phone': '+442079376213',
#    'display_phone': '+44 20 7937 6213',
#    'distance': 3917.4513323577366},
#   {'id': 'ylcWE2NFp3ybM87CAtpY7g',
#    'alias': 'pix-london-3',
#    'name': 'Pix',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/m8x0qcjaLVwNWOIi39L-Lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pix-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5139808654785,
#     'longitude': -0.132193997502327},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '16 Bateman Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 3AH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Bateman Street',
#      'London W1D 3AH',
#      'United Kingdom']},
#    'phone': '+442074370377',
#    'display_phone': '+44 20 7437 0377',
#    'distance': 289.80142874184395},
#   {'id': 'KW3YTOMZGLqi9MnEWUDKhw',
#    'alias': 'mazi-london',
#    'name': 'Mazi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dfRNpDgwO5BdFRQY-9yIEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mazi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5081215, 'longitude': -0.1977605},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '12-14 Hillgate Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 7SR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12-14 Hillgate Street',
#      'London W8 7SR',
#      'United Kingdom']},
#    'phone': '+442072293794',
#    'display_phone': '+44 20 7229 3794',
#    'distance': 4307.229943617715},
#   {'id': '1Wr3w5xWYEhbv9aXaSYkZg',
#    'alias': 'la-familia-restaurante-epsom',
#    'name': 'La Familia Restaurante',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/h4VCbmGLbYldyU3TEIdRgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-familia-restaurante-epsom?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.3477401712889,
#     'longitude': -0.249717758847958},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '67-69 High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Epsom',
#     'zip_code': 'KT17 1RX',
#     'country': 'GB',
#     'state': 'SRY',
#     'display_address': ['67-69 High Street',
#      'Epsom KT17 1RX',
#      'United Kingdom']},
#    'phone': '+442083938810',
#    'display_phone': '+44 20 8393 8810',
#    'distance': 19980.149097705504},
#   {'id': 'aR7QZC3KQHYFi9py5IhI5g',
#    'alias': 'rumours-london',
#    'name': 'Rumours',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cRbk8oOfCfu1STnSCS7leg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rumours-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5109565, 'longitude': -0.139313},
#    'transactions': [],
#    'location': {'address1': '4 Heddon Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1B 4BS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Heddon Street',
#      'London W1B 4BS',
#      'United Kingdom']},
#    'phone': '+442077349138',
#    'display_phone': '+44 20 7734 9138',
#    'distance': 312.13767588751443},
#   {'id': 'x-9gCp7c0F2dJ3g30Gd2lg',
#    'alias': 'chiringuito-london',
#    'name': 'Chiringuito',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9O6cK_flJjsEWMFHIm8K7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chiringuito-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.528303, 'longitude': -0.054859},
#    'transactions': [],
#    'location': {'address1': 'Museum Gardens',
#     'address2': 'Cambridge Heath Road',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E2 9PA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Museum Gardens',
#      'Cambridge Heath Road',
#      'London E2 9PA',
#      'United Kingdom']},
#    'phone': '+442089813894',
#    'display_phone': '+44 20 8981 3894',
#    'distance': 5868.696524140675},
#   {'id': '4j-ZIblF7qeDX9QMvPbtMQ',
#    'alias': 'copita-london',
#    'name': 'Copita',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YYPQcEJ9oII0cHkMw4LLrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/copita-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.514562, 'longitude': -0.135975},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "26-27 D'arblay Street",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["26-27 D'arblay Street",
#      'London W1F 8EP',
#      'United Kingdom']},
#    'phone': '+442072877797',
#    'display_phone': '+44 20 7287 7797',
#    'distance': 188.79060319193078},
#   {'id': 'vBEQW6eX3DFYlDgrzr8VCQ',
#    'alias': 'el-vergel-london',
#    'name': 'El Vergel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HMpP7JOOK9BZy5cSKuOAwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-vergel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.500707, 'longitude': -0.099151},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '132 Webber Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['132 Webber Street',
#      'London SE1 0QL',
#      'United Kingdom']},
#    'phone': '+442074012308',
#    'display_phone': '+44 20 7401 2308',
#    'distance': 2881.1132049899998}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#             Restaurant          Type Price Rating                  Address  \
# 0              B'acino     Wine Bars                 54-56 Scrutton Street
# 1                 Momo      Moroccan   £££      4      25-27 Heddon Street
# 2              Mestizo       Mexican    ££      4       103 Hampstead Road
# 3                Rapsa  Asian Fusion    ££    4.5    100-104 Hoxton Street
# 4  5th View Bar & Food    Tapas Bars    ££    3.5  Waterstone's Piccadilly
#
#          Lat       Lng                                                url  \
# 0  51.523413 -0.080987
# 1  51.511106 -0.140326  https://www.yelp.com/biz/momo-london?adjust_cr...
# 2  51.527520 -0.138765  https://www.yelp.com/biz/mestizo-london?adjust...
# 3  51.531065 -0.080011  https://www.yelp.com/biz/rapsa-london-2?adjust...
# 4  51.509071 -0.136305  https://www.yelp.com/biz/5th-view-bar-and-food...
#
#                        ID
# 0
# 1  AM2d672O6FjDpL82iVWTlg
# 2  XeAaUJWcS9RZsE80a1UxjA
# 3  gJAFSUO7U70GQJFo3ynRUw
# 4  RC9q1pP2Vmjz80NBO_O05g

# %%
london_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
london_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_restaurants_df = london_restaurants_df[column_order]
london_restaurants_df = london_restaurants_df.sort_values(["Type"], ascending=True)
london_restaurants_df = london_restaurants_df.reset_index(drop=True)
london_restaurants_df
# Out:
#                        Restaurant                   Type Rating Price  \
# 0                           ZOILO              Argentine    4.5   £££
# 1                           Rapsa           Asian Fusion    4.5    ££
# 2                    Flora Indica                   Bars      5    ££
# 3                          Camino                   Bars    3.5    ££
# 4                      Bar Pepito                   Bars      4    ££
# 5                       Bar Douro                   Bars      4    ££
# 6                       The Dairy                   Bars    4.5  ££££
# 7                   Connaught Bar                   Bars    4.5  ££££
# 8                     Sky Pod Bar                   Bars      4    ££
# 9    Sagardi Basque Country Chefs                 Basque      4    ££
# 10                         Ametsa                 Basque      4  ££££
# 11     Eneko Basque Kitchen & Bar                 Basque    4.5   £££
# 12           Donostia Social Club                 Basque
# 13      Bedales of Borough Market   Beer, Wine & Spirits      4    ££
# 14                        Oldroyd             Brasseries    4.5    ££
# 15            Caravan Kings Cross     Breakfast & Brunch      4    ££
# 16                         Andina     Breakfast & Brunch      4    ££
# 17                    YUU Kitchen          Chicken Wings    4.5    ££
# 18                          Chojo                Chinese
# 19                 Merchant House          Cocktail Bars
# 20                 The Distillery          Cocktail Bars    4.5    ££
# 21                  Señor Ceviche          Cocktail Bars      4    ££
# 22                      Bar Lorca          Cocktail Bars
# 23                         Pirana          Cocktail Bars
# 24                           Boki           Coffee & Tea      5    ££
# 25               The Harwood Arms             Gastropubs    4.5   £££
# 26                   Trader Vic's               Hawaiian    3.5    ££
# 27                          Bonoo                 Indian
# 28                          POLPO                Italian      4    ££
# 29                           Fumo                Italian    3.5    ££
# ..                            ...                    ...    ...   ...
# 170                           Pix     Tapas/Small Plates    3.5    ££
# 171                     Tapa Tapa     Tapas/Small Plates    3.5    ££
# 172                     La Farola     Tapas/Small Plates      4   £££
# 173                        Camino     Tapas/Small Plates      4    ££
# 174                         Lobos     Tapas/Small Plates      4   £££
# 175                      El Ganso     Tapas/Small Plates      4    ££
# 176                     Las Tapas     Tapas/Small Plates    3.5   £££
# 177              Tapas Revolution     Tapas/Small Plates    3.5    ££
# 178                 28 Church Row     Tapas/Small Plates
# 179                      Escocesa     Tapas/Small Plates
# 180                       Barsito     Tapas/Small Plates    3.5    ££
# 181              Jamon Jamon Soho     Tapas/Small Plates    3.5    ££
# 182                  Grand Bazaar                Turkish      4    ££
# 183                       Rumours  Venues & Event Spaces
# 184                    El Vino Co              Wine Bars    3.5    ££
# 185             Gordon's Wine Bar              Wine Bars    4.5    ££
# 186                       Bar 191              Wine Bars      4    ££
# 187                   Casa Manolo              Wine Bars
# 188       Orford Saloon Tapas Bar              Wine Bars    4.5  ££££
# 189                       Iberica              Wine Bars      4   £££
# 190          Vinoteca Kings Cross              Wine Bars      4    ££
# 191                  Le Petit Sud              Wine Bars
# 192  Grays & Feather Wine Parlour              Wine Bars
# 193  Sager + Wilde - Hackney Road              Wine Bars    4.5   £££
# 194                   Mas Q Menos              Wine Bars      3    ££
# 195                       B'acino              Wine Bars
# 196          Planet of the Grapes              Wine Bars    4.5   £££
# 197                Enoteca Pomaio              Wine Bars      4     £
# 198      The Other Naughty Piglet              Wine Bars
# 199              Meson Don Felipe              Wine Bars      4    ££
#
#                               Address        Lat       Lng  \
# 0                       9 Duke Street  51.515934 -0.152037
# 1               100-104 Hoxton Street  51.531065 -0.080011
# 2               242 Old Brompton Road  51.489858 -0.189819
# 3                   3 Varnishers Yard  51.531294 -0.121794
# 4                The Regent's Quarter  51.531244 -0.121772
# 5                            Arch 35B  51.504370 -0.095165
# 6                     15 The Pavement  51.461872 -0.139592
# 7                       The Connaught  51.510156 -0.149631
# 8                 20 Fenchurch Street  51.511338 -0.083579
# 9           Cordy House 95 Curtain Rd  51.525289 -0.080616
# 10                  5-6 Halkin Street  51.500848 -0.151867
# 11                          1 Aldwych  51.511783 -0.119417
# 12            49 Brixton Station Road  51.463422 -0.112375
# 13                    5 Bedale Street  51.505406 -0.089834
# 14                   344 Upper Street  51.534886 -0.104209
# 15                   1 Granary Square  51.535779 -0.125371
# 16                 1 Redchurch Street  51.524321 -0.077135
# 17               29 Commercial Street  51.516345 -0.073300
# 18                     16 Garway Road  51.515120 -0.191680
# 19                      13 Well Court  51.513813 -0.104850
# 20                186 Portobello Road  51.516011 -0.204917
# 21                       Kingly Court  51.512410 -0.138580
# 22               156-158 Fortess Road  51.556678 -0.138392
# 23                    76 Bedford Hill  51.442161 -0.149492
# 24                  20 Earlham Street  51.513575 -0.127627
# 25                    27 Walham Grove  51.482911 -0.196471
# 26                       22 Park Lane  51.505460 -0.150574
# 27                  675 Finchley Road  51.561458 -0.197352
# 28                      6 Maiden Lane  51.510749 -0.122644
# 29               N37 St Martin's Lane  51.509947 -0.126906
# ..                                ...        ...       ...
# 170                  24 Ganton Street  51.512954 -0.139253
# 171                       Warehouse K  51.508811  0.025598
# 172                  101 Upper Street  51.537665 -0.102942
# 173                   5 Canvey Street  51.505890 -0.099450
# 174                   48 Frith Street  51.513543 -0.131473
# 175                59 Broadway Market  51.537197 -0.061406
# 176           108 Holland Park Avenue  51.506760 -0.207251
# 177           Kiosk K2024 The Balcony  51.507247 -0.222330
# 178                     28 Church Row  51.555494 -0.178900
# 179  67 Stoke Newington Church Street  51.562183 -0.076826
# 180                    57 Venn Street  51.462750 -0.137931
# 181                   3-5 Caxton Walk  51.513920 -0.129205
# 182                   42 James Street  51.515487 -0.150601
# 183                   4 Heddon Street  51.510956 -0.139313
# 184              30 New Bridge Street  51.512574 -0.103990
# 185                47 Villiers Street  51.507941 -0.123382
# 186                   191 Worple Road  51.410835 -0.228112
# 187                         99 Strand  51.510445 -0.120575
# 188                    32 Orford Road  51.582562 -0.013116
# 189         195 Great Portland Street  51.522476 -0.143939
# 190                One Pancras Square  51.532739 -0.124989
# 191                     1 Palace Gate  51.501433 -0.184246
# 192              26 Wellington Street  51.512110 -0.120226
# 193                    193 Hackney Rd  51.530990 -0.072137
# 194                      70 Mark Lane  51.511204 -0.079906
# 195             54-56 Scrutton Street  51.523413 -0.080987
# 196       74-82 Queen Victoria Street  51.512596 -0.093627
# 197                    224 Brick Lane  51.524794 -0.071471
# 198                  12 Palace Street  51.498797 -0.142227
# 199                        53 The Cut  51.502967 -0.107201
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/zoilo-london?adjust_c...  5S2vNZHbihkMwIrOfeL_JA
# 1    https://www.yelp.com/biz/rapsa-london-2?adjust...  gJAFSUO7U70GQJFo3ynRUw
# 2    https://www.yelp.com/biz/flora-indica-london?a...  T-XPkD7xHKJSgPe0xzj5xw
# 3    https://www.yelp.com/biz/camino-london?adjust_...  OyLrjCVSSp5UUAYe9Vm0Hg
# 4    https://www.yelp.com/biz/bar-pepito-london?adj...  shtcu9CrJEHp3IhT0YvU7Q
# 5    https://www.yelp.com/biz/bar-douro-london?adju...  AEIHz3vzjJ1Ev6Io50JXQw
# 6    https://www.yelp.com/biz/the-dairy-london-2?ad...  8P4qwhVKdxoV1bW-_I3s-A
# 7    https://www.yelp.com/biz/connaught-bar-london?...  hXWtuKNmbVzAYtoZhNLLPw
# 8    https://www.yelp.com/biz/sky-pod-bar-london?ad...  yjwyF_QA5BdEqNvqqlvwdQ
# 9    https://www.yelp.com/biz/sagardi-basque-countr...  qnHCFYfRpuU4cyXE5aapoQ
# 10   https://www.yelp.com/biz/ametsa-london-2?adjus...  uLJp1QsowWjJ9qNXHZIIpw
# 11   https://www.yelp.com/biz/eneko-basque-kitchen-...  IjezoTAhQT2yV1UchKLtgA
# 12
# 13   https://www.yelp.com/biz/bedales-of-borough-ma...  aywIyiNMxy4nbBabMGK1Vw
# 14   https://www.yelp.com/biz/oldroyd-london?adjust...  gfTiXGI9pU3LVgf6piH2bQ
# 15   https://www.yelp.com/biz/caravan-kings-cross-l...  B6ayHXLwfYBuIADficAeMg
# 16   https://www.yelp.com/biz/andina-london?adjust_...  vCF8ut7OZcfA4hEmhngfSQ
# 17   https://www.yelp.com/biz/yuu-kitchen-london?ad...  Q1ELAXgpTgu0OOp5xGmbPQ
# 18
# 19
# 20   https://www.yelp.com/biz/the-distillery-london...  aNe-csvGyoEkw62ysRbqpA
# 21   https://www.yelp.com/biz/se%C3%B1or-ceviche-lo...  _hiTEsg7MgrFNfZRl8mksA
# 22
# 23
# 24   https://www.yelp.com/biz/boki-london?adjust_cr...  vlyegsU6Sobc5zWEwkZkRg
# 25   https://www.yelp.com/biz/the-harwood-arms-lond...  nxxCu3Svrmp2cNvfufrdFw
# 26   https://www.yelp.com/biz/trader-vics-london?ad...  2DscCJkNHiZv63JebpC9HA
# 27
# 28   https://www.yelp.com/biz/polpo-london-16?adjus...  kwLvscNdOfBJTpm5qtD-iA
# 29   https://www.yelp.com/biz/fumo-london?adjust_cr...  r-40hpB7G8QmMbb6dxKIWQ
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/pix-london-6?adjust_c...  PcbpnAstLLgJlG79NWauJg
# 171  https://www.yelp.com/biz/tapa-tapa-london-3?ad...  DsHjEAme_QeR93Q9Wtlxsw
# 172  https://www.yelp.com/biz/la-farola-london?adju...  zWrlXb7JkHWq6t2_W1pYxw
# 173  https://www.yelp.com/biz/camino-london-5?adjus...  TX9hjk1xl2xKwG1_Wuw0UQ
# 174  https://www.yelp.com/biz/lobos-london?adjust_c...  HO_YLnFUpea_S6UfC_4XSw
# 175  https://www.yelp.com/biz/el-ganso-london?adjus...  vz-VINQOFosCDVtATsghUg
# 176  https://www.yelp.com/biz/las-tapas-london?adju...  PWJiVG6QUm8P2aLJke1Ndw
# 177  https://www.yelp.com/biz/tapas-revolution-lond...  QVnFjlRLno_xU2nminAx-g
# 178
# 179
# 180  https://www.yelp.com/biz/barsito-london?adjust...  uRARkDJS52wlpedM2e9IYg
# 181  https://www.yelp.com/biz/jamon-jamon-soho-lond...  vN5XHJMX7A5EpXGGnIj_Ag
# 182  https://www.yelp.com/biz/grand-bazaar-london?a...  tSRsSKlk4cKWD7Pc7aJihQ
# 183
# 184  https://www.yelp.com/biz/el-vino-co-london?adj...  G2EF7KepnKIaaIlr-DxeAQ
# 185  https://www.yelp.com/biz/gordons-wine-bar-lond...  KGfryNuNH5mqYddLll9QCw
# 186  https://www.yelp.com/biz/bar-191-london?adjust...  HMCVjigSFKU4ANVKqF4A-g
# 187
# 188  https://www.yelp.com/biz/orford-saloon-tapas-b...  EazZp7bn_8HkTqUscy7Erg
# 189  https://www.yelp.com/biz/iberica-marylebone-2?...  iJPlkSdTPp1I3vHf00rk5Q
# 190  https://www.yelp.com/biz/vinoteca-kings-cross-...  9K-A7wHxB-z3n5h-P_mYFA
# 191
# 192
# 193  https://www.yelp.com/biz/sager-wilde-hackney-r...  3lrsL7fllHtEJ22SWGDzUg
# 194  https://www.yelp.com/biz/mas-q-menos-london-3?...  51Nq0e6afkefxTSepcE9Gw
# 195
# 196  https://www.yelp.com/biz/planet-of-the-grapes-...  JqCq3vd0pHAwc1iRukp7Pg
# 197  https://www.yelp.com/biz/enoteca-pomaio-london...  4-CULvL9R1LiEyOn6YHwPA
# 198
# 199  https://www.yelp.com/biz/meson-don-felipe-lond...  r4yImLpeIpcjMFD7qSz_ng
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
london_restaurants_df.to_csv('Resources/London_Restaurants_Tapas.csv')
