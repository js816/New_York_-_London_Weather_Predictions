# %% [markdown]
# LONDON RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
term = "sausage"

# %%
#First set of 50 records 0-50
lndr_params1 = {"term":term,"location":"London","limit":50,"offset":0}
lndr_response1 = requests.get(search_api_url, headers=headers, params=lndr_params1)
lndr1 = lndr_response1.json()
display(lndr1)
#print(lndr_response1.url)
#print(lndr_response1.status_code)
# Out:
# {'businesses': [{'id': 'IBV7BsXnv2gX68nWUARhjw',
#    'alias': 'mother-mash-london',
#    'name': 'Mother Mash',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YRdJ5N93Jc3qOIxx_itIRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mother-mash-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 469,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512935, 'longitude': -0.139414},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '26 Ganton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7QZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Ganton Street',
#      'London W1F 7QZ',
#      'United Kingdom']},
#    'phone': '+442074949644',
#    'display_phone': '+44 20 7494 9644',
#    'distance': 235.11523624102102},
#   {'id': 'UdFNcwNbwVJ7qNdDXYd_PA',
#    'alias': 'herman-ze-german-london',
#    'name': 'Herman Ze German',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ihuIc-ESzJtO7NVYqkMg8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/herman-ze-german-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 100,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.508297609923,
#     'longitude': -0.12397418784664},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '19 Villiers Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 6NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Villiers Street',
#      'London WC2N 6NE',
#      'United Kingdom']},
#    'phone': '+442079304827',
#    'display_phone': '+44 20 7930 4827',
#    'distance': 970.6457866246815},
#   {'id': 'mpObzFGn9UtUw9CJW-xKUA',
#    'alias': 'the-ginger-pig-london',
#    'name': 'The Ginger Pig',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ef-XLCbFxMO3Tr-JZtW2-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ginger-pig-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5198747699266,
#     'longitude': -0.152393400229603},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '8-10 Moxon Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 4EW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8-10 Moxon Street',
#      'London W1U 4EW',
#      'United Kingdom']},
#    'phone': '+442079357788',
#    'display_phone': '+44 20 7935 7788',
#    'distance': 1380.709955973446},
#   {'id': '3XTM3AIdCtPhrDfT77-hmw',
#    'alias': 'boston-sausage-boston-2',
#    'name': 'Boston Sausage',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DKKJbaHh0KrHkglzWmOaTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boston-sausage-boston-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'streetvendors', 'title': 'Street Vendors'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5057829, 'longitude': -0.0915919},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Bridge Foot',
#     'address2': '13 High Street',
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': 'PE21 8SH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Bridge Foot',
#      '13 High Street',
#      'Boston PE21 8SH',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3168.8308595444905},
#   {'id': 'wxfGeNQQ0J3j9mzIZG6Wig',
#    'alias': 'the-hampstead-butcher-and-providore-london',
#    'name': 'The Hampstead Butcher & Providore',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XL_QGnlSfwpJW0PtLdGM8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hampstead-butcher-and-providore-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'},
#     {'alias': 'butcher', 'title': 'Butcher'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5551738, 'longitude': -0.1733836},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '56 Rosslyn Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 1ND',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['56 Rosslyn Hill',
#      'London NW3 1ND',
#      'United Kingdom']},
#    'phone': '+442077949210',
#    'display_phone': '+44 20 7794 9210',
#    'distance': 5372.6531638347815},
#   {'id': 'Zf6FbXwsCKxSpBLql9l_9Q',
#    'alias': 'herman-ze-german-london-4',
#    'name': 'Herman Ze German',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GI-9oMbK1c1i8XTftugpOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/herman-ze-german-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5191705290611,
#     'longitude': -0.135596556276787},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '43 Charlotte Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 2NW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['43 Charlotte Street',
#      'London W1T 2NW',
#      'United Kingdom']},
#    'phone': '+442073239207',
#    'display_phone': '+44 20 7323 9207',
#    'distance': 704.858455490402},
#   {'id': 'jlBIhApFiYYLb3GV7XhPwQ',
#    'alias': 'freemans-london',
#    'name': 'Freemans',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DjI0RwOmuVE5X0PwWJGmHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/freemans-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5801765126764,
#     'longitude': -0.123810768127441},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9 Topsfield Parade',
#     'address2': 'Tottenham Lane',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N8 8PR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Topsfield Parade',
#      'Tottenham Lane',
#      'London N8 8PR',
#      'United Kingdom']},
#    'phone': '+442083403100',
#    'display_phone': '+44 20 8340 3100',
#    'distance': 7534.917209845898},
#   {'id': 'XmNUMfan4ZJhmlysp9RIIw',
#    'alias': 'ginger-pig-london-2',
#    'name': 'Ginger Pig',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ISNE2tGccN3WZzKMtTpZ5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginger-pig-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5055784029147,
#     'longitude': -0.0912491308273502},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Southwark St',
#     'address2': 'Borough Market',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1TL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Southwark St',
#      'Borough Market',
#      'London SE1 1TL',
#      'United Kingdom']},
#    'phone': '+442074034721',
#    'display_phone': '+44 20 7403 4721',
#    'distance': 3197.4896872875406},
#   {'id': 'wDco0qMw8raEZxmpAWko4g',
#    'alias': 'banger-bros-london',
#    'name': 'Banger Bros',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qMzn_V-tA2EXUo-TMQEe1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/banger-bros-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.516636, 'longitude': -0.2057331},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '225a Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 1LU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['225a Portobello Road',
#      'London W11 1LU',
#      'United Kingdom']},
#    'phone': '+442072299147',
#    'display_phone': '+44 20 7229 9147',
#    'distance': 4842.521854099548},
#   {'id': '70Q-Ll18zb4aglXXbUG7lw',
#    'alias': 'ffionas-restaurant-london',
#    'name': "Ffiona's Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/seykrl3tugRsE8UL6-phKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ffionas-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 265,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.50405773515,
#     'longitude': -0.192783395566043},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '51 Kensington Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Kensington Church Street',
#      'London W8 4BA',
#      'United Kingdom']},
#    'phone': '+442079374152',
#    'display_phone': '+44 20 7937 4152',
#    'distance': 4052.2035032181666},
#   {'id': 'tYynO1nOy1GKxMV3jkxbmw',
#    'alias': 'the-breakfast-club-london-2',
#    'name': 'The Breakfast Club',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TElKM303HWt3LAkvgBuTWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-breakfast-club-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 497,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514733, 'longitude': -0.135406},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "33 D'Arblay Street",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["33 D'Arblay Street",
#      'London W1F 8EU',
#      'United Kingdom']},
#    'phone': '+442074342571',
#    'display_phone': '+44 20 7434 2571',
#    'distance': 215.73161782407266},
#   {'id': 'iJOxs_39A55S3qNDtMRPWg',
#    'alias': 'roast-to-go-london',
#    'name': 'Roast To Go',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rWWpGMEKkObyTcAgycRS9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roast-to-go-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5056071178748,
#     'longitude': -0.0910057691819765},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Borough Market',
#     'address2': 'Stoney Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1TL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Borough Market',
#      'Stoney Street',
#      'London SE1 1TL',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3212.9883251551605},
#   {'id': 'EFwQyq_qSoL_3A2oQWL6Ig',
#    'alias': 'bierschenke-london',
#    'name': 'Bierschenke',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sGzMdgGIaKXrhgy2AxZMcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bierschenke-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5172964975816,
#     'longitude': -0.0852677978367637},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 London Wall Buildings',
#     'address2': 'Blomfield Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2M 5NT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 London Wall Buildings',
#      'Blomfield Street',
#      'London EC2M 5NT',
#      'United Kingdom']},
#    'phone': '+442071002500',
#    'display_phone': '+44 20 7100 2500',
#    'distance': 3542.385863708519},
#   {'id': 'nxxCu3Svrmp2cNvfufrdFw',
#    'alias': 'the-harwood-arms-london',
#    'name': 'The Harwood Arms',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hte754uy10BMdVg3P0hbxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-harwood-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 125,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4829113087309,
#     'longitude': -0.196470990454087},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '27 Walham Grove',
#     'address2': 'Fulham',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 1QP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['27 Walham Grove',
#      'Fulham',
#      'London SW6 1QP',
#      'United Kingdom']},
#    'phone': '+442073861847',
#    'display_phone': '+44 20 7386 1847',
#    'distance': 5349.774856506561},
#   {'id': 'PX3IwDtLn9SZnBJcPhvP-Q',
#    'alias': 'heaps-sausage-shop-london-2',
#    'name': "Heap's Sausage Shop",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sFB5bZzfSx_4DuYvro_JOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heaps-sausage-shop-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4795609, 'longitude': -0.0073732},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '8 Nevada Street',
#     'address2': 'Greenwich',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE10 9JL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Nevada Street',
#      'Greenwich',
#      'London SE10 9JL',
#      'United Kingdom']},
#    'phone': '+442082939199',
#    'display_phone': '+44 20 8293 9199',
#    'distance': 9639.632515761434},
#   {'id': '4IpNjfnu3VnM8p7_i4or4Q',
#    'alias': 'german-gymnasium-london-2',
#    'name': 'German Gymnasium',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TmJEnHXlhw3juq9561WDQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/german-gymnasium-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 52,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5323975443626,
#     'longitude': -0.125419827905187},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1 Kings Boulevard',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Kings Boulevard',
#      'London N1C 4AG',
#      'United Kingdom']},
#    'phone': '+442072878000',
#    'display_phone': '+44 20 7287 8000',
#    'distance': 2294.086392187214},
#   {'id': 'TSIoa1kBk3MmYthsnzOPmw',
#    'alias': 'bubbledogs-london',
#    'name': 'Bubbledogs',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HqeFKUJ340NeBU47B2sJBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bubbledogs-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 92,
#    'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#     {'alias': 'champagne_bars', 'title': 'Champagne Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5203332564428,
#     'longitude': -0.136556625366211},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '70 Charlotte Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 4QG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['70 Charlotte Street',
#      'London W1T 4QG',
#      'United Kingdom']},
#    'phone': '+442076377770',
#    'display_phone': '+44 20 7637 7770',
#    'distance': 834.745100045042},
#   {'id': 'U-Sz3hVjbZ8eaNeKGpZU_A',
#    'alias': 'borough-market-london-3',
#    'name': 'Borough Market',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EjVltsQ_qhUKdgdTMndkIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/borough-market-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1657,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5051427191678,
#     'longitude': -0.0909365332063361},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8 Southwark Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 1TL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Southwark Street',
#      'London SE1 1TL',
#      'United Kingdom']},
#    'phone': '+442030262283',
#    'display_phone': '+44 20 3026 2283',
#    'distance': 3230.9293288880117},
#   {'id': 'rwIWu1ImYqiiigwXDrO6JA',
#    'alias': 'big-apple-hot-dogs-london',
#    'name': 'Big Apple Hot Dogs',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_h6nklI4bkcnVuapdwlIRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/big-apple-hot-dogs-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5361747741699,
#     'longitude': -0.116492003202438},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Cole & Sons',
#     'address2': '170 Caledonian Rd',
#     'address3': 'Kings Cross',
#     'city': 'London',
#     'zip_code': 'N1 0SQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Cole & Sons',
#      '170 Caledonian Rd',
#      'Kings Cross',
#      'London N1 0SQ',
#      'United Kingdom']},
#    'phone': '+442035925526',
#    'display_phone': '+44 20 3592 5526',
#    'distance': 2923.7521708019267},
#   {'id': 'hilvZ2LeTt6lR6CAH7Tmpg',
#    'alias': 'the-ginger-pig-café-london-2',
#    'name': 'The Ginger Pig Café',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/H_fUBd1prBijzWnzNuhF_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ginger-pig-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5333665, 'longitude': -0.0801603},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '231 Hoxton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 5LG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['231 Hoxton Street',
#      'London N1 5LG',
#      'United Kingdom']},
#    'phone': '+442077490705',
#    'display_phone': '+44 20 7749 0705',
#    'distance': 4484.771370123279},
#   {'id': 'YNduANMPzIVE8CzBH7YjEQ',
#    'alias': 'regency-café-london-2',
#    'name': 'Regency Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pz5q5e8LBG7C1ozSuhvuKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/regency-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 393,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4940143171, 'longitude': -0.13222007974201},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '17-19 Regency Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 4BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17-19 Regency Street',
#      'London SW1P 4BY',
#      'United Kingdom']},
#    'phone': '+442078216596',
#    'display_phone': '+44 20 7821 6596',
#    'distance': 2108.732795587357},
#   {'id': 'qppsFJyx6ollRbZ0TTJXTw',
#    'alias': 'the-naked-sausage-london-2',
#    'name': 'The Naked Sausage',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/x42n_gcuF8Ef936jLS90kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-naked-sausage-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.533441, 'longitude': -0.109657},
#    'transactions': [],
#    'location': {'address1': 'Chapel Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Chapel Market', 'London N1', 'United Kingdom']},
#    'phone': '+447939242048',
#    'display_phone': '+44 7939 242048',
#    'distance': 2941.909566091406},
#   {'id': 'KgihwijlUEYOCfZEB98R-A',
#    'alias': 'meat-n16-london',
#    'name': 'Meat N16',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FpXSMH7V6nw2MV-T-E8psQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meat-n16-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'delicatessen', 'title': 'Delicatessen'},
#     {'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5623045, 'longitude': -0.0790558},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '104 Stoke Newington Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 0LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['104 Stoke Newington Church Street',
#      'London N16 0LA',
#      'United Kingdom']},
#    'phone': '+442072540724',
#    'display_phone': '+44 20 7254 0724',
#    'distance': 6760.659749948554},
#   {'id': 'Wjgxl0lSp_FRtzecbJ4FZQ',
#    'alias': 'the-queens-arms-london',
#    'name': 'The Queens Arms',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-QF0e-bRLjskiUjWPD7Ihg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-queens-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 120,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4925789, 'longitude': -0.1392194},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Warwick Way',
#     'address2': 'Pimlico',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1QT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Warwick Way',
#      'Pimlico',
#      'London SW1V 1QT',
#      'United Kingdom']},
#    'phone': '+442078343313',
#    'display_phone': '+44 20 7834 3313',
#    'distance': 2259.97766392161},
#   {'id': 'apqNvjbaB20wozywrLNPiQ',
#    'alias': 'fischers-london',
#    'name': "Fischer's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/A68yx91bh-81NvBKkMXVCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fischers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'austrian', 'title': 'Austrian'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5216155579831,
#     'longitude': -0.151699820819173},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '50 Marylebone High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 5HN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50 Marylebone High Street',
#      'London W1U 5HN',
#      'United Kingdom']},
#    'phone': '+442074665501',
#    'display_phone': '+44 20 7466 5501',
#    'distance': 1462.850471845834},
#   {'id': 'tMCi65NLHTg5xFBz1xz5lg',
#    'alias': 'ali-ocakbaşı-london',
#    'name': 'Ali Ocakbaşı',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/q1vMdR5HTiTDQ9kCkYa01g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ali-ocakba%C5%9F%C4%B1-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5098350641127,
#     'longitude': -0.129026994109154},
#    'transactions': [],
#    'location': {'address1': '16 Irving Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2H 7AU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Irving Street',
#      'London WC2H 7AU',
#      'United Kingdom']},
#    'phone': '+442078394020',
#    'display_phone': '+44 20 7839 4020',
#    'distance': 584.1480763382478},
#   {'id': '2vgpyvU72DEHiLRYmSE1FQ',
#    'alias': 'herman-ze-german-london-3',
#    'name': 'Herman Ze German',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/y1gCQFgTD2X8RAB5Tc1c_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/herman-ze-german-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.513273, 'longitude': -0.131731},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '33 Old Compton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 5JU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['33 Old Compton Street',
#      'London W1D 5JU',
#      'United Kingdom']},
#    'phone': '+442077340431',
#    'display_phone': '+44 20 7734 0431',
#    'distance': 296.37866942693194},
#   {'id': 'DI9SUiuxlf1WjkTu_jJSbg',
#    'alias': 'hawksmoor-spitalfields-london-6',
#    'name': 'Hawksmoor Spitalfields',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gcRRsddsSBcVDtJA6kIklw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hawksmoor-spitalfields-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 168,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5211502, 'longitude': -0.075657},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '157a Commercial Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6BJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['157a Commercial Street',
#      'London E1 6BJ',
#      'United Kingdom']},
#    'phone': '+442074264850',
#    'display_phone': '+44 20 7426 4850',
#    'distance': 4273.558452074432},
#   {'id': 'wm6Hwzan5qYhTzCDmO3oDQ',
#    'alias': 'muriels-kitchen-london',
#    'name': "Muriel's Kitchen",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9un8EzHME-wGnd7zVoev2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/muriels-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 134,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.494117, 'longitude': -0.174468},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 1',
#     'address2': '3 Pelham Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 2ND',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 1',
#      '3 Pelham Street',
#      'London SW7 2ND',
#      'United Kingdom']},
#    'phone': '+442075893511',
#    'display_phone': '+44 20 7589 3511',
#    'distance': 3381.980840047671},
#   {'id': 'P3YeWO3ODeWmQVi-IilkAQ',
#    'alias': 'st-john-bar-and-restaurant-london',
#    'name': 'St John Bar and Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8m6whIPf2zLcm6KAhVCsNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-john-bar-and-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 293,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.520481, 'longitude': -0.101486},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '26 St John Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1M 4AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 St John Street',
#      'London EC1M 4AY',
#      'United Kingdom']},
#    'phone': '+442072510848',
#    'display_phone': '+44 20 7251 0848',
#    'distance': 2532.1204734464523},
#   {'id': 'xViBKVW8zxlrxLfDam2eqg',
#    'alias': 'byward-kitchen-and-bar-london',
#    'name': 'Byward Kitchen & Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RTf7hDLtp2wy5sMWe7spQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/byward-kitchen-and-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5092887647333,
#     'longitude': -0.0789638981223106},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Byward Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3R 5BJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Byward Street', 'London EC3R 5BJ', 'United Kingdom']},
#    'phone': '+442074813533',
#    'display_phone': '+44 20 7481 3533',
#    'distance': 3963.7136520192603},
#   {'id': 'jcBeMcH_nAaDDJotomqs-g',
#    'alias': 'katzenjammers-london',
#    'name': 'Katzenjammers',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Wam1D3XSLBf1uOjRuXOh_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/katzenjammers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.504827352652,
#     'longitude': -0.0910319201774978},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '24 Southwark Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1TY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Southwark Street',
#      'London SE1 1TY',
#      'United Kingdom']},
#    'phone': '+447771363542',
#    'display_phone': '+44 7771 363542',
#    'distance': 3234.0535001935},
#   {'id': '07iun95qUOuTR7aWShFwUw',
#    'alias': 'chinwag-london',
#    'name': 'Chinwag',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/O4cwWOZWieLKllpbX1tw2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chinwag-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4751791028272,
#     'longitude': -0.0351671713981808},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '21 Lewisham Way',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE4 1US',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21 Lewisham Way',
#      'London SE4 1US',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8137.491299751467},
#   {'id': 'jGLj2JsYF8to11i934Aisw',
#    'alias': 'the-princess-victoria-london',
#    'name': 'The Princess Victoria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HAz99AqXfJRcIGgm2LgWyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-princess-victoria-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.506488400078,
#     'longitude': -0.24090795450115},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '217 Uxbridge Road',
#     'address2': 'Shepherds Bush',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W12 9DH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['217 Uxbridge Road',
#      'Shepherds Bush',
#      'London W12 9DH',
#      'United Kingdom']},
#    'phone': '+442087494466',
#    'display_phone': '+44 20 8749 4466',
#    'distance': 7297.496506772882},
#   {'id': 'Z1oce02uSXZ_6Fbtm0j-_A',
#    'alias': 'the-covent-garden-real-food-market-london',
#    'name': 'The Covent Garden Real Food Market',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/APBf_7ukQtBQ_xvGgAhgdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-covent-garden-real-food-market-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512071, 'longitude': -0.122976},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Covent Garden Piazza',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 8RA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Covent Garden Piazza',
#      'London WC2E 8RA',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 911.6190042090954},
#   {'id': 'Ae9Z7QFj3nftRSmhT8ncKg',
#    'alias': 'the-bolton-london',
#    'name': 'The Bolton',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WawpB8Yk0vRDmMKFzjy77w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bolton-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4895706, 'longitude': -0.1904267},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '326 Earls Court Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 9BQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['326 Earls Court Road',
#      'London SW5 9BQ',
#      'United Kingdom']},
#    'phone': '+442072445921',
#    'display_phone': '+44 20 7244 5921',
#    'distance': 4573.41743320191},
#   {'id': 'X4hZZcge-HgrnwVGqmEUiA',
#    'alias': 'south-kensington-farmers-market-london',
#    'name': 'South Kensington Farmers Market',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ob4DvE5GTyzGOMDmXzYUEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/south-kensington-farmers-market-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.493741, 'longitude': -0.176321},
#    'transactions': [],
#    'location': {'address1': 'Bute St & Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3EX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Bute St & Brompton Road',
#      'London SW7 3EX',
#      'United Kingdom']},
#    'phone': '+442078330338',
#    'display_phone': '+44 20 7833 0338',
#    'distance': 3509.111394638024},
#   {'id': 'teXPunKtpwj0NuttvPYhyQ',
#    'alias': 'the-victoria-paddington',
#    'name': 'The Victoria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IscE584D-z4Snf71FJ1bcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-victoria-paddington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 218,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51350403679, 'longitude': -0.17119959969309},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10a Strathearn Place',
#     'address2': '',
#     'address3': '',
#     'city': 'Paddington',
#     'zip_code': 'W2 2NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10a Strathearn Place',
#      'Paddington W2 2NH',
#      'United Kingdom']},
#    'phone': '+442077241191',
#    'display_phone': '+44 20 7724 1191',
#    'distance': 2440.016451414865},
#   {'id': 'se61yyYAHdJZ_Fq9ygXjVg',
#    'alias': 'bills-london-4',
#    'name': "Bill's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BMTYyZHF72uuASONanBykA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bills-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 207,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511881, 'longitude': -0.135307},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '36-44 Brewer Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9TB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['36-44 Brewer Street',
#      'London W1F 9TB',
#      'United Kingdom']},
#    'phone': '+442072878712',
#    'display_phone': '+44 20 7287 8712',
#    'distance': 121.31404288224127},
#   {'id': 'N0kfB-iYOb3Fs9RkOfwBlA',
#    'alias': 'ginos-coffee-bar-london',
#    'name': "Gino's Coffee Bar",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/opzj7LhMMQGw3VYx6vp03g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginos-coffee-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5222244262695,
#     'longitude': -0.162099003791809},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Great Central St',
#     'address2': 'London',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 6JH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Great Central St',
#      'London',
#      'London NW1 6JH',
#      'United Kingdom']},
#    'phone': '+442072628105',
#    'display_phone': '+44 20 7262 8105',
#    'distance': 2088.591889208201},
#   {'id': 'nHMn6sJQEj1c2cnGThyvvg',
#    'alias': 'harrods-food-hall-london',
#    'name': 'Harrods Food Hall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lTez1h3O4WyMt5kA4i8FBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harrods-food-hall-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 325,
#    'categories': [{'alias': 'cheese', 'title': 'Cheese Shops'},
#     {'alias': 'wineries', 'title': 'Wineries'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4990917420527,
#     'longitude': -0.162348972665107},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '87-135 Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7XL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['87-135 Brompton Road',
#      'London SW1X 7XL',
#      'United Kingdom']},
#    'phone': '+442077301234',
#    'display_phone': '+44 20 7730 1234',
#    'distance': 2381.6721756016004},
#   {'id': 'vmi7fEu1vy2Tj2yuYlgR0g',
#    'alias': 'kazan-london',
#    'name': 'Kazan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RFFFQinUIs2XBQOL0ycung/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kazan-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 112,
#    'categories': [{'alias': 'turkish', 'title': 'Turkish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4927, 'longitude': -0.14072},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '93-94 Wilton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1DW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['93-94 Wilton Road',
#      'London SW1V 1DW',
#      'United Kingdom']},
#    'phone': '+442072337100',
#    'display_phone': '+44 20 7233 7100',
#    'distance': 2264.258035381997},
#   {'id': 'Rb3xF0gkAwnDHML6okB1FA',
#    'alias': 'honey-and-co-london',
#    'name': 'Honey & Co',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GjRuBFxsvAvRsNXS44S23Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/honey-and-co-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 112,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5238287, 'longitude': -0.1407882},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '25a Warren Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 5LZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['25a Warren Street',
#      'London W1T 5LZ',
#      'United Kingdom']},
#    'phone': '+442073886175',
#    'display_phone': '+44 20 7388 6175',
#    'distance': 1267.2898980857588},
#   {'id': '0B-ag3J18TatG9H9EQohGg',
#    'alias': 'hawksmoor-seven-dials-london-4',
#    'name': 'Hawksmoor Seven Dials',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yYxu0Q9uw-StO5TXszf8IQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hawksmoor-seven-dials-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 344,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5134998914001,
#     'longitude': -0.12567396291297},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '11 Langley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9JG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Langley Street',
#      'London WC2H 9JG',
#      'United Kingdom']},
#    'phone': '+442074209390',
#    'display_phone': '+44 20 7420 9390',
#    'distance': 715.3327247350239},
#   {'id': 't4n-Go-jqlFYYuCuyNeBTA',
#    'alias': 'the-kings-arms-london-9',
#    'name': 'The Kings Arms',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fOuFsVxIsk8HM6X02_CmOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-kings-arms-london-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5063486, 'longitude': -0.1461078},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Shepherd Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 7QA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Shepherd Market',
#      'London W1J 7QA',
#      'United Kingdom']},
#    'phone': '+442076290416',
#    'display_phone': '+44 20 7629 0416',
#    'distance': 1010.7956126455001},
#   {'id': '8ig-ZwikctqXwhluOr3OCg',
#    'alias': 'the-sausage-man-dartford',
#    'name': 'The Sausage Man',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WMReuXXiBireN82m7762JA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-sausage-man-dartford?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.457212, 'longitude': -0.0058533},
#    'transactions': [],
#    'location': {'address1': 'Unit 1',
#     'address2': "St Margaret's Farm",
#     'address3': "St Margaret's Road",
#     'city': 'Dartford',
#     'zip_code': 'DA4 9LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 1',
#      "St Margaret's Farm",
#      "St Margaret's Road",
#      'Dartford DA4 9LB',
#      'United Kingdom']},
#    'phone': '+441322867060',
#    'display_phone': '+44 1322 867060',
#    'distance': 10927.558008567297},
#   {'id': 'oSJClu8F3C75_NzTcOatHQ',
#    'alias': 'scotchtails-london-2',
#    'name': 'Scotchtails',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lb3gHk2UDRZngyFQMY_O6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scotchtails-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'streetvendors', 'title': 'Street Vendors'},
#     {'alias': 'scottish', 'title': 'Scottish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5058600512612,
#     'longitude': -0.0900266337073297},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Borough Market',
#     'address2': '8 Southwark Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1TL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Borough Market',
#      '8 Southwark Street',
#      'London SE1 1TL',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3271.8502469761415},
#   {'id': '75-HeBBB391Np6T7GdJ5xQ',
#    'alias': 'the-ivy-london',
#    'name': 'The Ivy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rVk4F439o22SXXzGGHKGRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ivy-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 171,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512814, 'longitude': -0.128013},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1 - 5 West Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9NQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 - 5 West Street',
#      'London WC2H 9NQ',
#      'United Kingdom']},
#    'phone': '+442078364751',
#    'display_phone': '+44 20 7836 4751',
#    'distance': 549.6549455465449},
#   {'id': 'sf6GiPbDGsLrnQ6YfEFQVw',
#    'alias': 'c-lidgate-london-2',
#    'name': 'C Lidgate',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/suiSHDYPlYG4t8AdAkTISA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/c-lidgate-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5068313, 'longitude': -0.2073012},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '110 Holland Park Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 4UA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['110 Holland Park Ave',
#      'London W11 4UA',
#      'United Kingdom']},
#    'phone': '+442077278243',
#    'display_phone': '+44 20 7727 8243',
#    'distance': 4987.358148092097},
#   {'id': 'RTBkp7ewp3ZDFTJeIdLIMA',
#    'alias': 'hanks-po-boys-london',
#    'name': "Hank's Po' Boys",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Z_noSQPmhYpSLVuf3qZ9KQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hanks-po-boys-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5053216, 'longitude': -0.1160542},
#    'transactions': [],
#    'location': {'address1': 'Southbank Centre Market',
#     'address2': 'Belvedere Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8XX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Southbank Centre Market',
#      'Belvedere Road',
#      'London SE1 8XX',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1610.9293914129462}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                           Restaurant            Type Price Rating  \
# 0                        Mother Mash         British    ££      4
# 1                   Herman Ze German          German     £      4
# 2                     The Ginger Pig      Meat Shops   £££    4.5
# 3                     Boston Sausage  Street Vendors     £    4.5
# 4  The Hampstead Butcher & Providore      Meat Shops   £££      5
#
#               Address        Lat       Lng  \
# 0    26 Ganton Street  51.512935 -0.139414
# 1  19 Villiers Street  51.508298 -0.123974
# 2   8-10 Moxon Street  51.519875 -0.152393
# 3         Bridge Foot  51.505783 -0.091592
# 4     56 Rosslyn Hill  51.555174 -0.173384
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/mother-mash-london?ad...  IBV7BsXnv2gX68nWUARhjw
# 1  https://www.yelp.com/biz/herman-ze-german-lond...  UdFNcwNbwVJ7qNdDXYd_PA
# 2  https://www.yelp.com/biz/the-ginger-pig-london...  mpObzFGn9UtUw9CJW-xKUA
# 3  https://www.yelp.com/biz/boston-sausage-boston...  3XTM3AIdCtPhrDfT77-hmw
# 4  https://www.yelp.com/biz/the-hampstead-butcher...  wxfGeNQQ0J3j9mzIZG6Wig

# %%
#2nd set of 50 records 51-100 
lndr_params2 = {"term":term,"location":"London","limit":50,"offset":51}
lndr_response2 = requests.get(search_api_url, headers=headers, params=lndr_params2)
lndr2 = lndr_response2.json()
display(lndr2)
#print(lndr_response2.url)
#print(lndr_response2.status_code)
# Out:
# {'businesses': [{'id': 'mV4UQO_i0RahVnmdVfa9Tw',
#    'alias': 'hunger-dogs-london',
#    'name': 'Hunger Dogs',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mCSqoZAzkjO55gkIUmaUkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hunger-dogs-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5351891843644,
#     'longitude': -0.139317845535043},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '21A Camden High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 7JE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21A Camden High Street',
#      'London NW1 7JE',
#      'United Kingdom']},
#    'phone': '+442035835090',
#    'display_phone': '+44 20 3583 5090',
#    'distance': 2496.470531615445},
#   {'id': 'zr2aKieJp8S5by5VPceKUQ',
#    'alias': 'lao-cafe-london',
#    'name': 'Lao Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1sGRD5rt_tuoBIBJZUs-Hw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lao-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'laotian', 'title': 'Laotian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.510153354616,
#     'longitude': -0.125136251632811},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '60 Chandos Place',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2N 4HG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['60 Chandos Place',
#      'London WC2N 4HG',
#      'United Kingdom']},
#    'phone': '+442037404748',
#    'display_phone': '+44 20 3740 4748',
#    'distance': 805.9579826001464},
#   {'id': 'norkswWvmhtxM2w1AX09tA',
#    'alias': 'the-sausage-man-uk-ltd-dartford-2',
#    'name': 'The Sausage Man UK Ltd',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hR4OG4lQPVXppU_QKH8KOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-sausage-man-uk-ltd-dartford-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#     {'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4117036, 'longitude': 0.2600253},
#    'transactions': [],
#    'location': {'address1': "Unit 1 St Margaret's Farm",
#     'address2': "St Margaret's Road",
#     'address3': '',
#     'city': 'Dartford',
#     'zip_code': 'DA4 9LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["Unit 1 St Margaret's Farm",
#      "St Margaret's Road",
#      'Dartford DA4 9LB',
#      'United Kingdom']},
#    'phone': '+441322867060',
#    'display_phone': '+44 1322 867060',
#    'distance': 29648.023805161076},
#   {'id': '5puz_aDYRkQ-Ur45ceZy9A',
#    'alias': 'world-of-wurst-london',
#    'name': 'World of Wurst',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FXc3SEDHdr3bo23dMN3r-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/world-of-wurst-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4634005, 'longitude': -0.1110494},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '49 Brixton Station Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 8PQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Brixton Station Road',
#      'London SW9 8PQ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5739.665567173421},
#   {'id': 'VBQWqRMbt31fIUGlWUMkeQ',
#    'alias': 'gaucho-london-22',
#    'name': 'Gaucho',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jFMzhWc0PewrMrNGMvH6HA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gaucho-london-22?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 135,
#    'categories': [{'alias': 'argentine', 'title': 'Argentine'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.50968, 'longitude': -0.1379546},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '25 Swallow Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 4QR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['25 Swallow Street',
#      'London W1B 4QR',
#      'United Kingdom']},
#    'phone': '+442077344040',
#    'display_phone': '+44 20 7734 4040',
#    'distance': 366.2962721186836},
#   {'id': '5zAP9qPHcBDut7QGCZCLbg',
#    'alias': 'the-jolly-butchers-london',
#    'name': 'The Jolly Butchers',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3k3DMWnzba7fAQko50zXFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-jolly-butchers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5623655, 'longitude': -0.0733491},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '204 Stoke Newington High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 7HU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['204 Stoke Newington High Street',
#      'London N16 7HU',
#      'United Kingdom']},
#    'phone': '+442072499471',
#    'display_phone': '+44 20 7249 9471',
#    'distance': 7026.981171176548},
#   {'id': 'JJTlY7F3S9tiiO-eIeCL6g',
#    'alias': 'laughing-halibut-london',
#    'name': 'Laughing Halibut',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/iOeDT3vcL2ZiZaw7gCXlpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laughing-halibut-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 241,
#    'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4966544699782,
#     'longitude': -0.133777235475182},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '38 Strutton Ground',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 2HR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38 Strutton Ground',
#      'London SW1P 2HR',
#      'United Kingdom']},
#    'phone': '+442077992844',
#    'display_phone': '+44 20 7799 2844',
#    'distance': 1805.556069505154},
#   {'id': 'WYHgZEH5oeYoCAs__BCNzg',
#    'alias': 'rodizio-rico-london-2',
#    'name': 'Rodizio Rico',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YSXhVAFmaTaMctdl-ZI9Kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rodizio-rico-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5365104675293,
#     'longitude': -0.103692002594471},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '77-78 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 0NU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['77-78 Upper Street',
#      'London N1 0NU',
#      'United Kingdom']},
#    'phone': '+442073541076',
#    'display_phone': '+44 20 7354 1076',
#    'distance': 3448.7688084365764},
#   {'id': '4BxxZPDBbrIg9egm-r8FXg',
#    'alias': 'czechoslovak-national-house-club-and-restaurant-london',
#    'name': 'Czechoslovak National House Club & Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/s9c6X0nCwRaziIUcAHB-Iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/czechoslovak-national-house-club-and-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'czech', 'title': 'Czech'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5445546, 'longitude': -0.1921988},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '74 W End Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 2LX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['74 W End Lane', 'London NW6 2LX', 'United Kingdom']},
#    'phone': '+442073721193',
#    'display_phone': '+44 20 7372 1193',
#    'distance': 5241.810882230616},
#   {'id': '_gTqDZ4G0U0I_EnEcpT7Jw',
#    'alias': 'pether-fine-meat-and-poultry-hounslow',
#    'name': 'Pether Fine Meat & Poultry',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VXzpMKEPIXgGsRsIjuhk1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pether-fine-meat-and-poultry-hounslow?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4783007408949,
#     'longitude': -0.286466553982453},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '16 Station Parade',
#     'address2': 'Richmond',
#     'address3': 'Surrey',
#     'city': 'Hounslow',
#     'zip_code': 'TW9 3PZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Station Parade',
#      'Richmond',
#      'Surrey',
#      'Hounslow TW9 3PZ',
#      'United Kingdom']},
#    'phone': '+442089400163',
#    'display_phone': '+44 20 8940 0163',
#    'distance': 11104.533051972516},
#   {'id': 'XeAaUJWcS9RZsE80a1UxjA',
#    'alias': 'mestizo-london',
#    'name': 'Mestizo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m15vQhfhss5ycfcdVatg7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mestizo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 153,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.52752, 'longitude': -0.1387649},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '103 Hampstead Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 3EL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['103 Hampstead Road',
#      'London NW1 3EL',
#      'United Kingdom']},
#    'phone': '+442073874064',
#    'display_phone': '+44 20 7387 4064',
#    'distance': 1656.1089625620355},
#   {'id': '9vzIix6uttTqfIQH-aH7eg',
#    'alias': 'tollington-the-public-house-london',
#    'name': 'Tollington The Public House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NmIPfRTPGxK3mDGbftlrAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tollington-the-public-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.557264, 'longitude': -0.112692},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '115 Hornsey Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N7 6DN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['115 Hornsey Road',
#      'London N7 6DN',
#      'United Kingdom']},
#    'phone': '+442077006419',
#    'display_phone': '+44 20 7700 6419',
#    'distance': 5222.068586783099},
#   {'id': 'DKYoFYcEe9XQI_d-JuRAsg',
#    'alias': 'the-honest-sausage-london',
#    'name': 'The Honest Sausage',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bo2KYSYk5bpMD9zj4mcHIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-honest-sausage-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5309066184409,
#     'longitude': -0.150675773620605},
#    'transactions': [],
#    'location': {'address1': 'Broad Walk',
#     'address2': 'Kensington Gardens',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 0AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Broad Walk',
#      'Kensington Gardens',
#      'London W8 0AB',
#      'United Kingdom']},
#    'phone': '+442072243872',
#    'display_phone': '+44 20 7224 3872',
#    'distance': 2252.763163594705},
#   {'id': 'jxN3X5vgEfPfHsZxEeJtuQ',
#    'alias': 'le-boudin-blanc-london',
#    'name': 'Le Boudin Blanc',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EJNWJcZM79ubSLoCCXVfig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-boudin-blanc-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 52,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.506485, 'longitude': -0.147213},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '5 Trebeck Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 7LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Trebeck Street',
#      'London W1J 7LT',
#      'United Kingdom']},
#    'phone': '+442074993292',
#    'display_phone': '+44 20 7499 3292',
#    'distance': 1050.7934925275044},
#   {'id': 'xqpUr61KFa1Xx721-E6l_A',
#    'alias': 'kipferl-london-6',
#    'name': 'Kipferl',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CUoYGTlW1CYS-nJ5vAUGPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kipferl-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'austrian', 'title': 'Austrian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.535247538411,
#     'longitude': -0.10339315152949},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Camden Passage',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Camden Passage',
#      'London N1 8ED',
#      'United Kingdom']},
#    'phone': '+442077041555',
#    'display_phone': '+44 20 7704 1555',
#    'distance': 3359.4222431551457},
#   {'id': 'z8xyGXRdLQ3hSeFKZx--rA',
#    'alias': 'macken-brothers-london',
#    'name': 'Macken Brothers',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RnkSW_XWPZGVK0U_tXneNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/macken-brothers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4936575, 'longitude': -0.2551651},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '44 Turnham Green Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W4 1QP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['44 Turnham Green Terrace',
#      'London W4 1QP',
#      'United Kingdom']},
#    'phone': '+442089942646',
#    'display_phone': '+44 20 8994 2646',
#    'distance': 8522.475927700212},
#   {'id': 'vPYD3C9W-m409muDlhEWQw',
#    'alias': 'porterford-butchers-london',
#    'name': 'Porterford Butchers',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_kMXbM-YovX1Kl9-qC1Klg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/porterford-butchers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5131950378418,
#     'longitude': -0.0940200015902519},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '72 Watling St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4M 9BJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['72 Watling St', 'London EC4M 9BJ', 'United Kingdom']},
#    'phone': '+442072481396',
#    'display_phone': '+44 20 7248 1396',
#    'distance': 2902.2593983356232},
#   {'id': '3yvDAVKLDtsXZEHrskuobA',
#    'alias': 'the-lyric-london',
#    'name': 'The Lyric',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6b6WZXvrlCYJdqksILAuPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lyric-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.511283, 'longitude': -0.134466},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '37 Great Windmill Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 7LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['37 Great Windmill Street',
#      'Soho',
#      'London W1D 7LT',
#      'United Kingdom']},
#    'phone': '+442074340604',
#    'display_phone': '+44 20 7434 0604',
#    'distance': 200.29114916089154},
#   {'id': 'ao-yAAnj8D_D9WI7qgLOow',
#    'alias': 'the-breakfast-club-london-3',
#    'name': 'The Breakfast Club',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/e7Zr6Q_07X1_UHb09Pe7lQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-breakfast-club-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 202,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5269878207578,
#     'longitude': -0.0811266326024151},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2-4 Rufus Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 6PE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2-4 Rufus Street',
#      'London N1 6PE',
#      'United Kingdom']},
#    'phone': '+442077295252',
#    'display_phone': '+44 20 7729 5252',
#    'distance': 4107.080123788109},
#   {'id': 'LmS_NsB9gxrq-QGrtM7LsA',
#    'alias': 'the-peasant-london-2',
#    'name': 'The Peasant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DIjycHGsFMjHUyW2l_QXGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-peasant-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5257670339641,
#     'longitude': -0.103859877687725},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '240 St John Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 4PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['240 St John Street',
#      'London EC1V 4PH',
#      'United Kingdom']},
#    'phone': '+442073367726',
#    'display_phone': '+44 20 7336 7726',
#    'distance': 2645.6274912578956},
#   {'id': '3R0Klq1B1ESNTwqPfcsY-w',
#    'alias': 'the-pig-and-butcher-london',
#    'name': 'The Pig and Butcher',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zpEzs1qPf3ijMGJdGEcM8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pig-and-butcher-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 109,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.537442542029,
#     'longitude': -0.10682789450616},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '80 Liverpool Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 0QD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['80 Liverpool Road',
#      'London N1 0QD',
#      'United Kingdom']},
#    'phone': '+442072268304',
#    'display_phone': '+44 20 7226 8304',
#    'distance': 3398.14716948262},
#   {'id': 'Fa9718rkbQuMh3DYgvsSYw',
#    'alias': 'bodeans-london',
#    'name': "Bodean's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/awG2RJXZPrElj_1OEIhwyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bodeans-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 260,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514481362499,
#     'longitude': -0.13676105637839},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "D'Arblay House",
#     'address2': '10a Poland Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8PZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["D'Arblay House",
#      '10a Poland Street',
#      'London W1F 8PZ',
#      'United Kingdom']},
#    'phone': '+442072877575',
#    'display_phone': '+44 20 7287 7575',
#    'distance': 191.30425196477682},
#   {'id': 'NCj4ufnnu9iJuJVy_15nxw',
#    'alias': 'niche-london-5',
#    'name': 'Niche',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QiV8fpqNY26Tbd4y-IE8lw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/niche-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5299391920297,
#     'longitude': -0.105478788954883},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '197-199 Rosebery Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 4TJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['197-199 Rosebery Avenue',
#      'London EC1R 4TJ',
#      'United Kingdom']},
#    'phone': '+442078375048',
#    'display_phone': '+44 20 7837 5048',
#    'distance': 2839.605686346751},
#   {'id': 'Vaq49W0ubGjuIc4h5_qQ0w',
#    'alias': 'the-mayfair-chippy-london-2',
#    'name': 'The Mayfair Chippy',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BDTRkfVSJ8hoAT0amAfwkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mayfair-chippy-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 285,
#    'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5131345, 'longitude': -0.1533961},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 North Audley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 6WE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 North Audley Street',
#      'London W1K 6WE',
#      'United Kingdom']},
#    'phone': '+442077412233',
#    'display_phone': '+44 20 7741 2233',
#    'distance': 1207.337490950252},
#   {'id': 'lJ_hk4cn88vv6_XqAlbYHw',
#    'alias': 'the-beehive-london-7',
#    'name': 'The Beehive',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4FHnwe7jE7cdfBeIYjWknQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-beehive-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.520052, 'longitude': -0.157343},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '126 Crawford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 6BF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['126 Crawford Street',
#      'London W1U 6BF',
#      'United Kingdom']},
#    'phone': '+442074868037',
#    'display_phone': '+44 20 7486 8037',
#    'distance': 1682.3349010000493},
#   {'id': 'tQLHS3esu_vLtkbdPYSY6A',
#    'alias': 'on-the-bab-london',
#    'name': 'On The Bab',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9Fqa3mgW6Lya6jyU35dINw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/on-the-bab-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 92,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5267653903883,
#     'longitude': -0.0815281434501047},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '305 Old Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 9LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['305 Old Street',
#      'London EC1V 9LA',
#      'United Kingdom']},
#    'phone': '+442076830361',
#    'display_phone': '+44 20 7683 0361',
#    'distance': 4071.969764045619},
#   {'id': 'njoyzvQKqEthBysq6mSB-Q',
#    'alias': 'j-elliott-london',
#    'name': 'J Elliott',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3Xtf52_-DWiNRqpbEydBSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/j-elliott-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.538621, 'longitude': -0.098738},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '96 Essex Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8LU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['96 Essex Road', 'London N1 8LU', 'United Kingdom']},
#    'phone': '+442072263658',
#    'display_phone': '+44 20 7226 3658',
#    'distance': 3857.740716081619},
#   {'id': 'p77CnjTGOIZA1hEpLfCC6Q',
#    'alias': 'kennington-lane-cafe-london',
#    'name': 'Kennington Lane Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4pjtT4PSUYl_0_BqOTx6Cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kennington-lane-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4860611, 'longitude': -0.1208514},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '383 Kennington Lane',
#     'address2': 'Vauxhall',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE11 5QY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['383 Kennington Lane',
#      'Vauxhall',
#      'London SE11 5QY',
#      'United Kingdom']},
#    'phone': '+442077355853',
#    'display_phone': '+44 20 7735 5853',
#    'distance': 3147.932368103276},
#   {'id': 'sen5D3KKE0penBC7d5GlUQ',
#    'alias': 'zeitgeist-london-3',
#    'name': 'Zeitgeist',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zuld2QQENVx6CJmJ36AWSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zeitgeist-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.491333, 'longitude': -0.1182021},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '49 - 51 Black Prince Road',
#     'address2': 'Lambeth',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE11 6AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 - 51 Black Prince Road',
#      'Lambeth',
#      'London SE11 6AB',
#      'United Kingdom']},
#    'phone': '+442078400426',
#    'display_phone': '+44 20 7840 0426',
#    'distance': 2684.618353612666},
#   {'id': 'VVghAJA5WjFVMUnnKcpQxQ',
#    'alias': 'cannon-and-cannon-fine-foods-london',
#    'name': 'Cannon & Cannon Fine Foods',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/daKnPyBw0VxfAPeYqETgpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cannon-and-cannon-fine-foods-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'butcher', 'title': 'Butcher'},
#     {'alias': 'cheese', 'title': 'Cheese Shops'},
#     {'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5062980117458,
#     'longitude': -0.0913849306884913},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 4W',
#     'address2': 'Jubilee Place',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 4W',
#      'Jubilee Place',
#      'London SE1 9AG',
#      'United Kingdom']},
#    'phone': '+442074035481',
#    'display_phone': '+44 20 7403 5481',
#    'distance': 3169.066960644892},
#   {'id': 'CmTi8AXcTp7RsS4fdoDZ4g',
#    'alias': 'the-pride-of-paddington-london',
#    'name': 'The Pride Of Paddington',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1iMX4Yg_eDblPRsCMYT7Xg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pride-of-paddington-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5149423, 'longitude': -0.176487},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1-3 Craven Road',
#     'address2': 'Paddington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3BP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1-3 Craven Road',
#      'Paddington',
#      'London W2 3BP',
#      'United Kingdom']},
#    'phone': '+442074022156',
#    'display_phone': '+44 20 7402 2156',
#    'distance': 2805.9335822118273},
#   {'id': 'DHA0dyhobkw-XXUWF4aapw',
#    'alias': 'butcher-at-leadenhall-london',
#    'name': 'Butcher At Leadenhall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1jDTF-mJCSCyowTu3usIAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/butcher-at-leadenhall-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5130264, 'longitude': -0.0837921},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6-7 Leadenhall Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3V 1LR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6-7 Leadenhall Market',
#      'London EC3V 1LR',
#      'United Kingdom']},
#    'phone': '+442072831662',
#    'display_phone': '+44 20 7283 1662',
#    'distance': 3611.9314932765856},
#   {'id': '2BoGHL6GSyn30i4yU2VKtQ',
#    'alias': 'camisa-and-son-london',
#    'name': 'Camisa & Son',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x6ZCJBiIPaxeOv3tVmXiXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camisa-and-son-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512482, 'longitude': -0.132848},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61 Old Compton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6HS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Old Compton Street',
#      'London W1D 6HS',
#      'United Kingdom']},
#    'phone': '+442074377610',
#    'display_phone': '+44 20 7437 7610',
#    'distance': 218.62713673273046},
#   {'id': 'HVfH72v8FqPCOEkQS0e_EA',
#    'alias': 'kent-and-sons-butchers-london',
#    'name': 'Kent & Sons Butchers',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Dj3_kUubYirxYHZddE1Fcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kent-and-sons-butchers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'butcher', 'title': 'Butcher'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.53358857053,
#     'longitude': -0.170991120813964},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '59 St Johns Wood High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 7NL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['59 St Johns Wood High Street',
#      'London NW8 7NL',
#      'United Kingdom']},
#    'phone': '+442077222258',
#    'display_phone': '+44 20 7722 2258',
#    'distance': 3346.7240791311815},
#   {'id': 'XgU_CX_G1zzCXCe1IV7I6g',
#    'alias': 'hawksmoor-guildhall-london-2',
#    'name': 'Hawksmoor Guildhall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uGolmbeomVEuVFkeU92xMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hawksmoor-guildhall-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5155006968868,
#     'longitude': -0.0908641121643541},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '10 Basinghall Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2V 5BQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Basinghall Street',
#      'London EC2V 5BQ',
#      'United Kingdom']},
#    'phone': '+442073978120',
#    'display_phone': '+44 20 7397 8120',
#    'distance': 3134.3362758475205},
#   {'id': 'LSvWWKNJi4-gaaRDU-VVYA',
#    'alias': 'golden-union-fish-bar-london',
#    'name': 'Golden Union Fish Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hfsrEdPKwvba19Qanu-sVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/golden-union-fish-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 298,
#    'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5153383, 'longitude': -0.1376925},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '38 Poland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7LY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38 Poland Street',
#      'London W1F 7LY',
#      'United Kingdom']},
#    'phone': '+442074341933',
#    'display_phone': '+44 20 7434 1933',
#    'distance': 306.2399426483066},
#   {'id': '7kBtTjr1SdEDESFiyan-Ag',
#    'alias': 'apero-restaurant-and-bar-london',
#    'name': 'Apero Restaurant and Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4itRKhjda2FZNmDd1uWylQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/apero-restaurant-and-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4942818627381,
#     'longitude': -0.175694857095886},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Harrington Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Harrington Road',
#      'London SW7 3ER',
#      'United Kingdom']},
#    'phone': '+442075914410',
#    'display_phone': '+44 20 7591 4410',
#    'distance': 3438.2722475474984},
#   {'id': '4QK1kQOde5RZ6PNTfo7wug',
#    'alias': 'albion-london-5',
#    'name': 'Albion',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5Cs76CZPdDPELbONN2AJHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/albion-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 101,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.524137, 'longitude': -0.076235},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2-4 Boundary Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7DD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2-4 Boundary Street',
#      'London E2 7DD',
#      'United Kingdom']},
#    'phone': '+442077291051',
#    'display_phone': '+44 20 7729 1051',
#    'distance': 4327.903016108891},
#   {'id': 'xTno948bD8MVyt37dcUJlw',
#    'alias': 'barbarellas-london-2',
#    'name': 'Barbarellas',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Yqvpdu6fMYBuCASAhZBJpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barbarellas-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5000747, 'longitude': -0.1143629},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '141 Lower Marsh',
#     'address2': 'Waterloo',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7AE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['141 Lower Marsh',
#      'Waterloo',
#      'London SE1 7AE',
#      'United Kingdom']},
#    'phone': '+442074013525',
#    'display_phone': '+44 20 7401 3525',
#    'distance': 2065.0558467482933},
#   {'id': 'DSAV6IYGtFAaoG_hkd_KnA',
#    'alias': 'the-atlas-london',
#    'name': 'The Atlas',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6kfWSSwg4O1yuRkESj94ww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-atlas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4861721, 'longitude': -0.1963213},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '16 Seagrave Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 1RX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Seagrave Road',
#      'London SW6 1RX',
#      'United Kingdom']},
#    'phone': '+442073859129',
#    'display_phone': '+44 20 7385 9129',
#    'distance': 5123.540839643137},
#   {'id': 'bgMJHURGZftfI441orwhMg',
#    'alias': 'm-moen-and-sons-london',
#    'name': 'M Moen & Sons',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/d7FKod0MDPatLcDgm-GZrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/m-moen-and-sons-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4622982, 'longitude': -0.1401057},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '24 The Pavement',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW4 0JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 The Pavement',
#      'London SW4 0JA',
#      'United Kingdom']},
#    'phone': '+442076221624',
#    'display_phone': '+44 20 7622 1624',
#    'distance': 5622.176254665025},
#   {'id': '7Q6JpFSFv997rhv7w1izNA',
#    'alias': 'the-colonel-fawcett-london',
#    'name': 'The Colonel Fawcett',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5sI0DzmCXQB1JkmxqaLbtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-colonel-fawcett-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5418041646628,
#     'longitude': -0.136007736926076},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Randolph Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 0SS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Randolph Street',
#      'London NW1 0SS',
#      'United Kingdom']},
#    'phone': '+442072679829',
#    'display_phone': '+44 20 7267 9829',
#    'distance': 3221.1646170751255},
#   {'id': '3ViNQObKHR6l02hkvBFClw',
#    'alias': 'mimos-cafe-london',
#    'name': 'Mimos Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/k6WfcS61Er3U5TxjAdvcNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mimos-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 85,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5150959, 'longitude': -0.174005},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '19 London Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 London Street',
#      'London W2 1HL',
#      'United Kingdom']},
#    'phone': '+442077067175',
#    'display_phone': '+44 20 7706 7175',
#    'distance': 2647.9526940777378},
#   {'id': '_Ub-9VGBQmfHVW3MD3jhcg',
#    'alias': 'frank-godfrey-london',
#    'name': 'Frank Godfrey',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZUO9AwJZ2skp0acOGli5JA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frank-godfrey-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.553786585289,
#     'longitude': -0.098373824875248},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '7 Highbury Park',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N5 1QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Highbury Park', 'London N5 1QJ', 'United Kingdom']},
#    'phone': '+442072262425',
#    'display_phone': '+44 20 7226 2425',
#    'distance': 5243.316945395645},
#   {'id': '-147sXWJVzjQ6xed3kdtxQ',
#    'alias': 'la-porchetta-pollo-bar-london',
#    'name': 'La Porchetta Pollo Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7dR3wrkUu2n3IY-GXYNadg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-porchetta-pollo-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5136346213443,
#     'longitude': -0.130298037090699},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '20 Old Compton Street',
#     'address2': '',
#     'address3': 'Soho',
#     'city': 'London',
#     'zip_code': 'W1D 4TW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Old Compton Street',
#      'Soho',
#      'London W1D 4TW',
#      'United Kingdom']},
#    'phone': '+442074949368',
#    'display_phone': '+44 20 7494 9368',
#    'distance': 401.4759210697374},
#   {'id': 'RQxZlkXAAiDA6KNmvThi5w',
#    'alias': 'hansel-and-pretzel-london',
#    'name': 'Hansel & Pretzel',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hansel-and-pretzel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'german', 'title': 'German'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4384193, 'longitude': -0.3134942},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '71 Ham Street',
#     'address2': 'Ham',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'TW10 7UD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['71 Ham Street',
#      'Ham',
#      'London TW10 7UD',
#      'United Kingdom']},
#    'phone': '+442083321916',
#    'display_phone': '+44 20 8332 1916',
#    'distance': 14825.29350775577},
#   {'id': 'YuQUXWOJROqOSeo0a19M5w',
#    'alias': 'sticky-fingers-london',
#    'name': 'Sticky Fingers',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NgeckE5OfBX6QfAJ8PVixA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sticky-fingers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.49988, 'longitude': -0.198297},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1a Phillimore Gardens',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 7QB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1a Phillimore Gardens',
#      'London W8 7QB',
#      'United Kingdom']},
#    'phone': '+442079385338',
#    'display_phone': '+44 20 7938 5338',
#    'distance': 4543.4012847763015},
#   {'id': '8n2YcCHAQl7B-ih61evwdQ',
#    'alias': 'kennedys-london-3',
#    'name': "Kennedy's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aGhWfLSlLsHB67c23KQt6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kennedys-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4380761, 'longitude': -0.1265172},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5A Leigham Court Road',
#     'address2': 'Streatham Hill',
#     'address3': 'London',
#     'city': 'London',
#     'zip_code': 'SW16 2ND',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5A Leigham Court Road',
#      'Streatham Hill',
#      'London',
#      'London SW16 2ND',
#      'United Kingdom']},
#    'phone': '+442087691003',
#    'display_phone': '+44 20 8769 1003',
#    'distance': 8341.47716720912},
#   {'id': 'bpPc86UDVamkaZRmzkz_LQ',
#    'alias': 'luna-nuova-london',
#    'name': 'Luna Nuova',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/n1sfQLINahSHmtwLEZrsMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luna-nuova-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4764709472656,
#     'longitude': -0.203929007053375},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '773 Fulham Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 5HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['773 Fulham Road',
#      'London SW6 5HA',
#      'United Kingdom']},
#    'phone': '+442073719774',
#    'display_phone': '+44 20 7371 9774',
#    'distance': 6204.333934451122},
#   {'id': 'uZF_h43c4RfXdzEPKJBbBw',
#    'alias': 'theobalds-mckanna-meats-london',
#    'name': "Theobald's - McKanna Meats",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/thAaclz1z6Xge6N6I7yR-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/theobalds-mckanna-meats-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5203574, 'longitude': -0.1173135},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '21 Theobalds Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1X 8SL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21 Theobalds Road',
#      'London WC1X 8SL',
#      'United Kingdom']},
#    'phone': '+442072427740',
#    'display_phone': '+44 20 7242 7740',
#    'distance': 1532.5883253673787}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                Restaurant                  Type Price Rating  \
# 0             Hunger Dogs              Hot Dogs    ££      3
# 1                Lao Cafe               Laotian    ££      4
# 2  The Sausage Man UK Ltd  Beer, Wine & Spirits
# 3          World of Wurst                German     £    4.5
# 4                  Gaucho             Argentine   £££      4
#
#                      Address        Lat       Lng  \
# 0     21A Camden High Street  51.535189 -0.139318
# 1           60 Chandos Place  51.510153 -0.125136
# 2  Unit 1 St Margaret's Farm  51.411704  0.260025
# 3    49 Brixton Station Road  51.463400 -0.111049
# 4          25 Swallow Street  51.509680 -0.137955
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/hunger-dogs-london?ad...  mV4UQO_i0RahVnmdVfa9Tw
# 1  https://www.yelp.com/biz/lao-cafe-london?adjus...  zr2aKieJp8S5by5VPceKUQ
# 2
# 3  https://www.yelp.com/biz/world-of-wurst-london...  5puz_aDYRkQ-Ur45ceZy9A
# 4  https://www.yelp.com/biz/gaucho-london-22?adju...  VBQWqRMbt31fIUGlWUMkeQ

# %%
#3rd set of 50 records 101-150
lndr_params3 = {"term":term,"location":"London","limit":50,"offset":101}
lndr_response3 = requests.get(search_api_url, headers=headers, params=lndr_params3)
lndr3 = lndr_response3.json()
display(lndr3)
#print(lndr_response3.url)
#print(lndr_response3.status_code)
# Out:
# {'businesses': [{'id': 'BJPoMcoKJxrs_QT4_PcL8A',
#    'alias': 'bloomsbury-cafe-london',
#    'name': 'Bloomsbury Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lGKxROCBx-YKn806nO8xWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bloomsbury-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5175164253045,
#     'longitude': -0.127287250243864},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '16 Bloomsbury Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3QA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Bloomsbury Street',
#      'London WC1B 3QA',
#      'United Kingdom']},
#    'phone': '+442076378400',
#    'display_phone': '+44 20 7637 8400',
#    'distance': 794.1799236505923},
#   {'id': 'PrIqHQtsQl-DnafTdS326A',
#    'alias': 'whitecross-market-london',
#    'name': 'Whitecross Market',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZRvAMD9ErxXzsvFgjeqieQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/whitecross-market-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'streetvendors', 'title': 'Street Vendors'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5228285836074,
#     'longitude': -0.0927653379297215},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '1 Whitecross Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 9AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Whitecross Street',
#      'London EC1V 9AB',
#      'United Kingdom']},
#    'phone': '+442075273830',
#    'display_phone': '+44 20 7527 3830',
#    'distance': 3188.3843760093823},
#   {'id': 'CQsUI0K8XOAwSR4gN6l55Q',
#    'alias': 'pizza-union-london-7',
#    'name': 'Pizza Union',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/v0sNgoZ5-bGnhmxoC3CFGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizza-union-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 67,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.531051655444,
#     'longitude': -0.11983242244974},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '246 - 250 Pentonville Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9JY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['246 - 250 Pentonville Road',
#      'London N1 9JY',
#      'United Kingdom']},
#    'phone': '+442072789425',
#    'display_phone': '+44 20 7278 9425',
#    'distance': 2312.4049845213176},
#   {'id': 'hOLFwKg4-0FsCleJ4yoCXw',
#    'alias': 'duck-and-waffle-london',
#    'name': 'Duck & Waffle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WrS5I1dN-nGXePaADwE0cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duck-and-waffle-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 707,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516178, 'longitude': -0.08094},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '110 Bishopsgate',
#     'address2': '40th Floor',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2N 4AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['110 Bishopsgate',
#      '40th Floor',
#      'London EC2N 4AY',
#      'United Kingdom']},
#    'phone': '+442036407310',
#    'display_phone': '+44 20 3640 7310',
#    'distance': 3825.102922188434},
#   {'id': 'FdfIx7h5tRd4AAMcXHrljw',
#    'alias': 'birley-sandwiches-london-6',
#    'name': 'Birley Sandwiches',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JV8io1KHFrmdrKfaBDEgdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/birley-sandwiches-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5051509130517,
#     'longitude': -0.0213405953842312},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 23A',
#     'address2': '1 Canada Square',
#     'address3': 'Canary Wharf',
#     'city': 'London',
#     'zip_code': 'E14 5AX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 23A',
#      '1 Canada Square',
#      'Canary Wharf',
#      'London E14 5AX',
#      'United Kingdom']},
#    'phone': '+442077191163',
#    'display_phone': '+44 20 7719 1163',
#    'distance': 7978.035748799018},
#   {'id': 'zlAyFg09KhOFncHQ-eKyFA',
#    'alias': 'terrace-grill-and-bar-london',
#    'name': 'Terrace Grill and Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rQfpjMeB1boN2x_c9DZ_5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/terrace-grill-and-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5092748320384,
#     'longitude': -0.136759439958052},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '21 Piccadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 0BH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21 Piccadilly', 'London W1J 0BH', 'United Kingdom']},
#    'phone': '+44442078513085',
#    'display_phone': '+44 442078513085',
#    'distance': 399.8169450987421},
#   {'id': 'ruccgDIBllsprKlP_7HBpg',
#    'alias': 'the-easton-london',
#    'name': 'The Easton',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/00hZ8dwgUCTRmptcXSYfWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-easton-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.526323227476,
#     'longitude': -0.11139933433552},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Easton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1X 0DS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Easton Street',
#      'London WC1X 0DS',
#      'United Kingdom']},
#    'phone': '+442072787608',
#    'display_phone': '+44 20 7278 7608',
#    'distance': 2266.3090043333623},
#   {'id': 'TEFyfQZgUh7YfZPVB7dIAw',
#    'alias': 'greensmiths-london',
#    'name': 'Greensmiths',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VRKw34lJHLNrkPfq6U6b5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greensmiths-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5008808, 'longitude': -0.1122979},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '27 Lower Marsh',
#     'address2': 'Waterloo',
#     'address3': 'London',
#     'city': 'London',
#     'zip_code': 'SE1 7RG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['27 Lower Marsh',
#      'Waterloo',
#      'London',
#      'London SE1 7RG',
#      'United Kingdom']},
#    'phone': '+442079212970',
#    'display_phone': '+44 20 7921 2970',
#    'distance': 2101.2572858349076},
#   {'id': '6oW6305g3-MTy8dBe8QlBQ',
#    'alias': 'german-deli-borough',
#    'name': 'German Deli',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Drbhb5DckwwQF0ODs12K3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/german-deli-borough?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.505241090956,
#     'longitude': -0.091765960314486},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3 Park Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Borough',
#     'zip_code': 'SE1 9AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Park Street', 'Borough SE1 9AB', 'United Kingdom']},
#    'phone': '+442073780000',
#    'display_phone': '+44 20 7378 0000',
#    'distance': 3172.6799463041784},
#   {'id': 'tWqe8jJBRf-TjqwQAn1Xfw',
#    'alias': 'the-jugged-hare-london-2',
#    'name': 'The Jugged Hare',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/G6T9MHt7fRy_urB9o2OdWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-jugged-hare-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.520789, 'longitude': -0.090935},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '49 Chiswell Street',
#     'address2': 'Barbican',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1Y 4SA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Chiswell Street',
#      'Barbican',
#      'London EC1Y 4SA',
#      'United Kingdom']},
#    'phone': '+442076140134',
#    'display_phone': '+44 20 7614 0134',
#    'distance': 3242.861693530846},
#   {'id': '2_uKaqxZJr9VFiN8zQ6UEQ',
#    'alias': 'the-gazzanos-ltd-london',
#    'name': "The Gazzano's Ltd",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZtDw2zSVXgv23ULNPMJgtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-gazzanos-ltd-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5243835449219,
#     'longitude': -0.110131002962589},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '167-169 Farringdon Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 3AL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['167-169 Farringdon Road',
#      'London EC1R 3AL',
#      'United Kingdom']},
#    'phone': '+442078371586',
#    'display_phone': '+44 20 7837 1586',
#    'distance': 2200.4040821483177},
#   {'id': 'QTRkMjYHXAVROidXkkt7Ow',
#    'alias': 'the-delaunay-london-3',
#    'name': 'The Delaunay',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zz7VMc8u_hhSOuIphETZLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-delaunay-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 118,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5131115, 'longitude': -0.1182553},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '55 Aldwych',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 4BB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55 Aldwych', 'London WC2B 4BB', 'United Kingdom']},
#    'phone': '+442074998558',
#    'display_phone': '+44 20 7499 8558',
#    'distance': 1233.9810795843225},
#   {'id': '7m0uht8Rw38lc0Vbvdb-IQ',
#    'alias': 'poem-bar-and-grill-london',
#    'name': 'Poem Bar & Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IuJv8RWDxwdt22cciCweIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/poem-bar-and-grill-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.537843586362,
#     'longitude': -0.18492060586753},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '94 Boundary Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 0RH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['94 Boundary Road',
#      'London NW8 0RH',
#      'United Kingdom']},
#    'phone': '+442073723897',
#    'display_phone': '+44 20 7372 3897',
#    'distance': 4382.655267391364},
#   {'id': 'dF6M7XzivF2qI3c1wp_F9A',
#    'alias': 'mr-christians-london',
#    'name': "Mr Christian's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CyFBKFY2BebZV-kdkLmimg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-christians-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'cheese', 'title': 'Cheese Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5148864, 'longitude': -0.2049839},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '11 Elgin Crescent',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Elgin Crescent',
#      'London W11 2JA',
#      'United Kingdom']},
#    'phone': '+442072290501',
#    'display_phone': '+44 20 7229 0501',
#    'distance': 4782.83880408329},
#   {'id': 'VpXOD3pTsTMGy7cqtpNuNA',
#    'alias': 'sartori-restaurant-london-2',
#    'name': 'Sartori Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4zu2Y-9soaYtKj1rPnoWaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sartori-restaurant-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511791229248,
#     'longitude': -0.128003999590874},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '15 Great Newport Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 7JE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Great Newport Street',
#      'London WC2H 7JE',
#      'United Kingdom']},
#    'phone': '+442078366308',
#    'display_phone': '+44 20 7836 6308',
#    'distance': 561.3031039602805},
#   {'id': 'JETHlrp_LakVWuXq_o6_xQ',
#    'alias': 'apres-food-co-london',
#    'name': 'Apres Food Co.',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yG0ikU6ta19zJqB0-KDceQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/apres-food-co-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.521479, 'longitude': -0.101328},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '72 Saint John Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EC1M 4DT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['72 Saint John Street',
#      'London EC1M 4DT',
#      'United Kingdom']},
#    'phone': '+442076868888',
#    'display_phone': '+44 20 7686 8888',
#    'distance': 2579.004965235833},
#   {'id': 'bF2iD9f6B8j2J98CLqMIRw',
#    'alias': 'crown-fish-and-chips-london',
#    'name': 'Crown Fish & Chips',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9TZTNZdVzNuWkF9Onh5P4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crown-fish-and-chips-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5372921, 'longitude': -0.141114},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '1-3 Pratt St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 0AE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1-3 Pratt St', 'London NW1 0AE', 'United Kingdom']},
#    'phone': '+442074826680',
#    'display_phone': '+44 20 7482 6680',
#    'distance': 2746.0252725489163},
#   {'id': 'zI4Z-LjiIWBubhcLCX8vpw',
#    'alias': 'the-pavilion-cafe-london',
#    'name': 'The Pavilion Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zgj62S140sq4g5Q-Jetmzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pavilion-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.533421, 'longitude': -0.042846},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Victoria Park',
#     'address2': 'Old Ford Rd',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E9 7DE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Victoria Park',
#      'Old Ford Rd',
#      'London E9 7DE',
#      'United Kingdom']},
#    'phone': '+442089800030',
#    'display_phone': '+44 20 8980 0030',
#    'distance': 6836.419536616521},
#   {'id': 'tNqlff6UM01PCRaSg3kdfA',
#    'alias': 'soho-joe-london-2',
#    'name': 'Soho Joe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i5TOWJJ9ixhIO1r2pq0IIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soho-joe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5149162419674,
#     'longitude': -0.135393677274406},
#    'transactions': [],
#    'location': {'address1': "34 D'Arblay St",
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1F 8EY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["34 D'Arblay St", 'London W1F 8EY', 'United Kingdom']},
#    'phone': '+447534134398',
#    'display_phone': '+44 7534 134398',
#    'distance': 234.61259657975114},
#   {'id': 'LYPuCoeoYpRpMcvFfwK3wQ',
#    'alias': 'farmstand-london-3',
#    'name': 'Farmstand',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IC8LsiHvAb5kgNsIVteqjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/farmstand-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5143394470215,
#     'longitude': -0.122018814086914},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '42 Drury Lane',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 Drury Lane',
#      'Covent Garden',
#      'London WC2B 5AJ',
#      'United Kingdom']},
#    'phone': '+442072403866',
#    'display_phone': '+44 20 7240 3866',
#    'distance': 986.9717381016312},
#   {'id': '__zb-nuVLOikaEnrnKoBvA',
#    'alias': 'voodoo-rays-london-2',
#    'name': "Voodoo Ray's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GpS4W15NKdZYTqKLwsMHiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/voodoo-rays-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5235106, 'longitude': -0.0763937},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 1-3 Boxpark',
#     'address2': '2 Bethnal Green Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6GY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 1-3 Boxpark',
#      '2 Bethnal Green Road',
#      'London E1 6GY',
#      'United Kingdom']},
#    'phone': '+442070334100',
#    'display_phone': '+44 20 7033 4100',
#    'distance': 4288.805548528988},
#   {'id': 'ewUiAjDS6CZEZiD-PgcIeQ',
#    'alias': 'villages-fine-sausages-beckenham',
#    'name': 'Villages Fine Sausages',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xe90Shh94y1knpdQfdpD5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/villages-fine-sausages-beckenham?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4074251, 'longitude': -0.0273131},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '91 High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Beckenham',
#     'zip_code': 'BR3 1AG',
#     'country': 'GB',
#     'state': 'KEN',
#     'display_address': ['91 High Street',
#      'Beckenham BR3 1AG',
#      'United Kingdom']},
#    'phone': '+442083255475',
#    'display_phone': '+44 20 8325 5475',
#    'distance': 13937.000076543385},
#   {'id': 'Ua0pmEYc0elDSgUt5OCK3g',
#    'alias': 'the-castle-london-10',
#    'name': 'The Castle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rjhSr6l5VDTtOSWFD0UXZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-castle-london-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5202949, 'longitude': -0.10429},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '34-35 Cowcross Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1M 6DB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['34-35 Cowcross Street',
#      'London EC1M 6DB',
#      'United Kingdom']},
#    'phone': '+442075537621',
#    'display_phone': '+44 20 7553 7621',
#    'distance': 2342.305397808506},
#   {'id': 'XSiTrSnaA3H50zaMWjyGOQ',
#    'alias': 'marias-market-café-london-2',
#    'name': "Maria's Market Café",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/U3jRp--YlLRbpPaRaDOgdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marias-market-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.505117, 'longitude': -0.091086},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Borough Market',
#     'address2': '8 Southwark Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Borough Market',
#      '8 Southwark Street',
#      'London SE1 9AA',
#      'United Kingdom']},
#    'phone': '+442074071002',
#    'display_phone': '+44 20 7407 1002',
#    'distance': 3220.2590376650837},
#   {'id': 'LdVANIJFLBrwsGkijiSSwA',
#    'alias': 'sun-cafe-london',
#    'name': 'Sun Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_R7CQ_Ylfq2K65OkDdQqBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sun-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.524381, 'longitude': -0.099477},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '55-63 Goswell Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 7EN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55-63 Goswell Road',
#      'London EC1V 7EN',
#      'United Kingdom']},
#    'phone': '+442072513806',
#    'display_phone': '+44 20 7251 3806',
#    'distance': 2831.9738345911146},
#   {'id': 'NSrYBenDSYo1irgdWesU4Q',
#    'alias': 'pied-à-terre-london-3',
#    'name': 'Pied à Terre',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pumd02k8GoQl5gFs_HK9KQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pied-%C3%A0-terre-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.519099, 'longitude': -0.13517},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '34 Charlotte Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 2NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['34 Charlotte Street',
#      'London W1T 2NH',
#      'United Kingdom']},
#    'phone': '+442076361178',
#    'display_phone': '+44 20 7636 1178',
#    'distance': 701.7668355108046},
#   {'id': 'E7uTFoTXygHYo_KAaHRjpw',
#    'alias': 'oliveto-london',
#    'name': 'Oliveto',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/s8PlF6v38HiJ7jJXiXOF3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oliveto-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.493495, 'longitude': -0.150923},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '49 Elizabeth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 9PP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Elizabeth Street',
#      'London SW1W 9PP',
#      'United Kingdom']},
#    'phone': '+442077300074',
#    'display_phone': '+44 20 7730 0074',
#    'distance': 2387.8696912342853},
#   {'id': 'X_1Z-RAonaFLaTjkdKBljA',
#    'alias': 'lisas-london-2',
#    'name': "Lisa's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/o7f1ipNVpmcVj689xXBKZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lisas-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'scandinavian', 'title': 'Scandinavian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5193556, 'longitude': -0.2078333},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '305 Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W10 5TD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['305 Portobello Road',
#      'London W10 5TD',
#      'United Kingdom']},
#    'phone': '+447445261778',
#    'display_phone': '+44 7445 261778',
#    'distance': 5026.193752550122},
#   {'id': 'PBFvhVyBi0lEJyTbyuxf5w',
#    'alias': 'the-orangery-london-7',
#    'name': 'The Orangery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L_0d22xNmfCC_d-tArBo3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-orangery-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 238,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5066360577041,
#     'longitude': -0.187725349125042},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Kensington Palace',
#     'address2': 'Palace Green',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Kensington Palace',
#      'Palace Green',
#      'London W8 4PX',
#      'United Kingdom']},
#    'phone': '+442031666113',
#    'display_phone': '+44 20 3166 6113',
#    'distance': 3648.4574890404074},
#   {'id': '7O8blUUjCGAk7V9wZvOEAg',
#    'alias': 'little-jack-horners-london',
#    'name': "Little Jack Horner's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pnAG4GvxvAmZSNNoZq_5vw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-jack-horners-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'streetvendors', 'title': 'Street Vendors'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5589968652238,
#     'longitude': -0.152370929718018},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Parliament Hill Farmers Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW5 1RN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Parliament Hill Farmers Market',
#      'London NW5 1RN',
#      'United Kingdom']},
#    'phone': '+447530107676',
#    'display_phone': '+44 7530 107676',
#    'distance': 5256.96990190976},
#   {'id': 'IDH_axJK2uI99N5-_PHl5A',
#    'alias': 'phoenicia-mediterranean-food-hall-london',
#    'name': 'Phoenicia - Mediterranean Food Hall',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jVQwCWM78Aneh-MwhCtMdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/phoenicia-mediterranean-food-hall-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'intlgrocery', 'title': 'International Grocery'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'},
#     {'alias': 'butcher', 'title': 'Butcher'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.547598, 'longitude': -0.141266},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '186 -192 Kentish Town Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW5 2AE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['186 -192 Kentish Town Road',
#      'London NW5 2AE',
#      'United Kingdom']},
#    'phone': '+442072671267',
#    'display_phone': '+44 20 7267 1267',
#    'distance': 3882.8214327231235},
#   {'id': 'VTOd4cweIR_5uMHh0KLeBg',
#    'alias': 'kiln-london',
#    'name': 'Kiln',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wx-7MBtCasPF-3zrvoYqfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kiln-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5114108, 'longitude': -0.1360504},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '58 Brewer Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1F 9TL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['58 Brewer Street',
#      'London W1F 9TL',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 159.83190000687998},
#   {'id': 'qQrQr-3WddVRFqsBaTe_wg',
#    'alias': 'dirty-bones-london',
#    'name': 'Dirty Bones',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tKbMCUD4eQMPYVK0uPm8yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dirty-bones-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5026391, 'longitude': -0.1911358},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Kensington Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Kensington Church St',
#      'London W8 4EP',
#      'United Kingdom']},
#    'phone': '+442030199061',
#    'display_phone': '+44 20 3019 9061',
#    'distance': 3983.6815465641157},
#   {'id': '-ATEXu2q4Oe4wPQeyrsILw',
#    'alias': 'princi-london',
#    'name': 'Princi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QLFgoDIBiLx2F0tpUIw7gQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/princi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 304,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5138629586873,
#     'longitude': -0.134387051472991},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '135 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0UT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['135 Wardour Street',
#      'London W1F 0UT',
#      'United Kingdom']},
#    'phone': '+442074788888',
#    'display_phone': '+44 20 7478 8888',
#    'distance': 157.59755401297926},
#   {'id': 'ZeRFcWpgERKSFY1Rvuq8VA',
#    'alias': 'hotbox-london',
#    'name': 'HotBox',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Sch3UQO-FqQpKRw22VwiaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotbox-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5170698872586,
#     'longitude': -0.0733181834220886},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '46-48 Commercial Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['46-48 Commercial Street',
#      'London E1 6LT',
#      'United Kingdom']},
#    'phone': '+442072471817',
#    'display_phone': '+44 20 7247 1817',
#    'distance': 4359.876753112907},
#   {'id': 'SE7wpud8QuVIc8VKUochDA',
#    'alias': 'eggslut-notting-hill',
#    'name': 'Eggslut',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7k5-rAYrz81qHWtgKnbocw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eggslut-notting-hill?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5153442, 'longitude': -0.2048745},
#    'transactions': [],
#    'location': {'address1': '185 Portobello Road',
#     'address2': '',
#     'address3': None,
#     'city': 'Notting Hill',
#     'zip_code': 'W11 2ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['185 Portobello Road',
#      'Notting Hill W11 2ED',
#      'United Kingdom']},
#    'phone': '+442037451920',
#    'display_phone': '+44 20 3745 1920',
#    'distance': 4775.790389917452},
#   {'id': 'aTrd4BXTspeQtObc2fcwGQ',
#    'alias': 'britannia-fish-bar-london',
#    'name': 'Britannia Fish Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/StWEf2gfigZSianU-k70-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/britannia-fish-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.528995070764,
#     'longitude': -0.038661651296427},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '101 Grove Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E3 5RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['101 Grove Road', 'London E3 5RP', 'United Kingdom']},
#    'phone': '+442089833414',
#    'display_phone': '+44 20 8983 3414',
#    'distance': 6967.337004566257},
#   {'id': 'B6ayHXLwfYBuIADficAeMg',
#    'alias': 'caravan-kings-cross-london',
#    'name': 'Caravan Kings Cross',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/N3qh0kXJvNLcjPEP9EEZGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caravan-kings-cross-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 170,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5357788239146,
#     'longitude': -0.125370576153865},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Granary Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Granary Square',
#      'London N1C 4AA',
#      'United Kingdom']},
#    'phone': '+442071017661',
#    'display_phone': '+44 20 7101 7661',
#    'distance': 2654.2035388419845},
#   {'id': 'xP96KRwGyy-XIBmQHel9JA',
#    'alias': 'regal-fish-bar-london',
#    'name': 'Regal Fish Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fpCLAnsYFZGdtQwYDorgpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/regal-fish-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.527243510257,
#     'longitude': -0.057239483406799},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '474 Bethnal Green Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 0EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['474 Bethnal Green Road',
#      'London E2 0EA',
#      'United Kingdom']},
#    'phone': '+442077399426',
#    'display_phone': '+44 20 7739 9426',
#    'distance': 5677.124526728306},
#   {'id': '6BRC_x_SsQxv4rBp42yPog',
#    'alias': 'villandry-london',
#    'name': 'Villandry',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bGSrRzS7UURVotaFbeLjqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/villandry-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5214563850873,
#     'longitude': -0.143144858908866},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '170 Great Portland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 5QB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['170 Great Portland Street',
#      'London W1W 5QB',
#      'United Kingdom']},
#    'phone': '+442076313131',
#    'display_phone': '+44 20 7631 3131',
#    'distance': 1079.9782130304109},
#   {'id': 'kTVWoi7hPB6EjK_s0QSjmw',
#    'alias': 'dennis-of-bexley-dartford',
#    'name': 'Dennis Of Bexley',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/H1UROH_awhQ8m5fKFgNbfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dennis-of-bexley-dartford?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.434231, 'longitude': 0.177521},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1 Maplehurst Close',
#     'address2': '',
#     'address3': '',
#     'city': 'Dartford',
#     'zip_code': 'DA2 7WX',
#     'country': 'GB',
#     'state': 'KEN',
#     'display_address': ['1 Maplehurst Close',
#      'Dartford DA2 7WX',
#      'United Kingdom']},
#    'phone': '+441322522126',
#    'display_phone': '+44 1322 522126',
#    'distance': 23406.038701223264},
#   {'id': 'HntBHodgbw-vhW3MaCqbcw',
#    'alias': 'the-windsor-castle-london-2',
#    'name': 'The Windsor Castle',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GumbAd40jaiQ5bjPESs1pA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-windsor-castle-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.505787326816,
#     'longitude': -0.198597460985184},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '114 Campden Hill Road',
#     'address2': 'Kensington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 7AR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['114 Campden Hill Road',
#      'Kensington',
#      'London W8 7AR',
#      'United Kingdom']},
#    'phone': '+442072438797',
#    'display_phone': '+44 20 7243 8797',
#    'distance': 4405.465244691853},
#   {'id': 'cy28kr98GOWJzUqf7Dg_dg',
#    'alias': 'absolutely-starving-london',
#    'name': 'Absolutely Starving',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kwgsDjzjZ9sNiJ7gkPIw7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/absolutely-starving-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5050986007288,
#     'longitude': -0.0849500457449048},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '51 Tooley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 2QN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Tooley Street',
#      'London SE1 2QN',
#      'United Kingdom']},
#    'phone': '+442074077417',
#    'display_phone': '+44 20 7407 7417',
#    'distance': 3633.267376510319},
#   {'id': 'Z53l9X3kK_rgPOmMGT6Lmw',
#    'alias': 'chadwicks-butchers-london',
#    'name': "Chadwick's Butchers",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_nsqBg5B5H9yuJTIcH_H8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chadwicks-butchers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'cheese', 'title': 'Cheese Shops'},
#     {'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.445142, 'longitude': -0.1511436},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '109 Balham High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW12 9AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['109 Balham High Road',
#      'London SW12 9AP',
#      'United Kingdom']},
#    'phone': '+442087721895',
#    'display_phone': '+44 20 8772 1895',
#    'distance': 7586.419318456876},
#   {'id': 'ClnDKm_D0jPgYjV2TrkCbg',
#    'alias': 'players-bar-and-kitchen-london',
#    'name': 'Players Bar and Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MRDAGFUTp4YbhAUNtaMrDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/players-bar-and-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.508101, 'longitude': -0.124093},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'The Arches',
#     'address2': 'Villiers Street',
#     'address3': 'Embankment',
#     'city': 'London',
#     'zip_code': 'WC2N 6NG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Arches',
#      'Villiers Street',
#      'Embankment',
#      'London WC2N 6NG',
#      'United Kingdom']},
#    'phone': '+442079305868',
#    'display_phone': '+44 20 7930 5868',
#    'distance': 975.2583899825801},
#   {'id': 'xl05GXufB5wPlGQL75wiJA',
#    'alias': 'lantana-cafe-london-2',
#    'name': 'Lantana Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kRvWu-oAIbU1rGj-T_fcOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lantana-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 124,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5189676, 'longitude': -0.1359559},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '13 Charlotte Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 1SN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Charlotte Place',
#      'London W1T 1SN',
#      'United Kingdom']},
#    'phone': '+442076373347',
#    'display_phone': '+44 20 7637 3347',
#    'distance': 681.8552979623188},
#   {'id': 'GYgy4JhIyolI0lJIxe1PmQ',
#    'alias': 'exmouth-market-london',
#    'name': 'Exmouth Market',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tjPafMdp6IT3SMbRa5ugXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/exmouth-market-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5254901, 'longitude': -0.1099058},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Exmouth Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 4QD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Exmouth Market',
#      'London EC1R 4QD',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2279.47731821133},
#   {'id': 'GexTNbg_Fa51RRMplLWHdg',
#    'alias': 'toffs-of-muswell-hill-london',
#    'name': "Toff's of Muswell Hill",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C_eDVDrhf7Zk5Mqek61n1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/toffs-of-muswell-hill-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 52,
#    'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.58945970694, 'longitude': -0.14461961705316},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '38 Muswell Hill Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N10 3RT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38 Muswell Hill Broadway',
#      'London N10 3RT',
#      'United Kingdom']},
#    'phone': '+442088838656',
#    'display_phone': '+44 20 8883 8656',
#    'distance': 8541.243889540554},
#   {'id': 'uhtq0kf7Hnxg0ap4B7_8AQ',
#    'alias': 'franco-manca-london-17',
#    'name': 'Franco Manca',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LBbfADTD6DJfpkSuhTinRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/franco-manca-london-17?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.510954, 'longitude': -0.122907},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '39 Maiden Lane',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 7LJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39 Maiden Lane',
#      'Covent Garden',
#      'London WC2E 7LJ',
#      'United Kingdom']},
#    'phone': '+442072408309',
#    'display_phone': '+44 20 7240 8309',
#    'distance': 932.579008650093},
#   {'id': 'Bc4GZfIUJu9363QQVACZVA',
#    'alias': 'caravan-london-3',
#    'name': 'Caravan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/v264jW33G2GVAP44U9OJ1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caravan-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 149,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5254718215956,
#     'longitude': -0.110122750616417},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11-13 Exmouth Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 4QD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11-13 Exmouth Market',
#      'London EC1R 4QD',
#      'United Kingdom']},
#    'phone': '+442078338115',
#    'display_phone': '+44 20 7833 8115',
#    'distance': 2273.5789430194204}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#           Restaurant             Type Price Rating  \
# 0    Bloomsbury Cafe     Coffee & Tea     £      4
# 1  Whitecross Market   Street Vendors     £    4.5
# 2        Pizza Union            Pizza     £    4.5
# 3      Duck & Waffle  Modern European   £££      4
# 4  Birley Sandwiches       Sandwiches     £      4
#
#                       Address        Lat       Lng  \
# 0        16 Bloomsbury Street  51.517516 -0.127287
# 1         1 Whitecross Street  51.522829 -0.092765
# 2  246 - 250 Pentonville Road  51.531052 -0.119832
# 3             110 Bishopsgate  51.516178 -0.080940
# 4                    Unit 23A  51.505151 -0.021341
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/bloomsbury-cafe-londo...  BJPoMcoKJxrs_QT4_PcL8A
# 1  https://www.yelp.com/biz/whitecross-market-lon...  PrIqHQtsQl-DnafTdS326A
# 2  https://www.yelp.com/biz/pizza-union-london-7?...  CQsUI0K8XOAwSR4gN6l55Q
# 3  https://www.yelp.com/biz/duck-and-waffle-londo...  hOLFwKg4-0FsCleJ4yoCXw
# 4  https://www.yelp.com/biz/birley-sandwiches-lon...  FdfIx7h5tRd4AAMcXHrljw

# %%
#4th set of 50 records 151-200
lndr_params4 = {"term":term,"location":"London","limit":50,"offset":151}
lndr_response4 = requests.get(search_api_url, headers=headers, params=lndr_params4)
lndr4 = lndr_response4.json()
display(lndr4)
#print(lndr_response4.url)
#print(lndr_response4.status_code)
# Out:
# {'businesses': [{'id': 'qlRpV22dIDFiY1sVjr9kxQ',
#    'alias': 'the-feathers-london-2',
#    'name': 'The Feathers',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/b8YPNN3t9edMQPTT8SuIoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-feathers-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4992265, 'longitude': -0.1331029},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18-20 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1H 0BH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18-20 Broadway',
#      'London SW1H 0BH',
#      'United Kingdom']},
#    'phone': '+442072270921',
#    'display_phone': '+44 20 7227 0921',
#    'distance': 1526.0802056573025},
#   {'id': 'sMeVGW8YFs0gaRFFNJH8uQ',
#    'alias': 'halepi-london',
#    'name': 'Halepi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sFLa6olrvJUgalKKga407g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/halepi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'kebab', 'title': 'Kebab'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511329946838,
#     'longitude': -0.18310297196364},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18 Leinster Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3ET',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Leinster Terrace',
#      'London W2 3ET',
#      'United Kingdom']},
#    'phone': '+442072621070',
#    'display_phone': '+44 20 7262 1070',
#    'distance': 3266.9719060435264},
#   {'id': 'lINVn-iVcLcFQkq1DXZo_Q',
#    'alias': 'upper-fleet-bakery-london',
#    'name': 'Upper Fleet Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/av4PNLmZzYf0tuHKp3Y-6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/upper-fleet-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5263319313231,
#     'longitude': -0.129384561430401},
#    'transactions': [],
#    'location': {'address1': '7 - 11 Upper Woburn place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 0JW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 - 11 Upper Woburn place',
#      'London WC1H 0JW',
#      'United Kingdom']},
#    'phone': '+442073875544',
#    'display_phone': '+44 20 7387 5544',
#    'distance': 1568.0932386529987},
#   {'id': 'LyXXTUzll212_JKMkzC3DQ',
#    'alias': '49-cafe-london',
#    'name': '49 Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PWsAaKgpDIo7aF9k5n6qjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/49-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5249587, 'longitude': -0.1251605},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '49 Marchmont Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 1AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Marchmont Street',
#      'London WC1N 1AP',
#      'United Kingdom']},
#    'phone': '+442035383474',
#    'display_phone': '+44 20 3538 3474',
#    'distance': 1541.1440285471679},
#   {'id': 'DARE_WvgMZINvslycDPJFQ',
#    'alias': 'raabs-bakery-london',
#    'name': "Raab's Bakery",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Q_qgt_LRqOi-YUrl4rNWCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raabs-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5393189, 'longitude': -0.0977451},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '136 Essex Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8LX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['136 Essex Road', 'London N1 8LX', 'United Kingdom']},
#    'phone': '+442072262830',
#    'display_phone': '+44 20 7226 2830',
#    'distance': 3968.321016159277},
#   {'id': 'xueM-mMFg2p-wweqiITstw',
#    'alias': 'raizes-london',
#    'name': 'Raizes',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CPTZS2lWWkTWiMxjlVo3YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raizes-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.532062, 'longitude': -0.058945},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '460 Hackney Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 9EG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['460 Hackney Road',
#      'London E2 9EG',
#      'United Kingdom']},
#    'phone': '+442077392009',
#    'display_phone': '+44 20 7739 2009',
#    'distance': 5746.750913996319},
#   {'id': 'w2lWBJDb_8uk5oV_uyrGjw',
#    'alias': 'champagne-fromage-london',
#    'name': 'Champagne + Fromage',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VzxJs5WWW58LtZSlF-ctDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/champagne-fromage-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cheese', 'title': 'Cheese Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5119787, 'longitude': -0.1200707},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Wellington Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 7DD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Wellington Street',
#      'London WC2E 7DD',
#      'United Kingdom']},
#    'phone': '+442072401604',
#    'display_phone': '+44 20 7240 1604',
#    'distance': 1103.3951943393763},
#   {'id': 'b_wH2Nueo8TraMtm0qtWGw',
#    'alias': 'snoggys-wandsworth',
#    'name': "Snoggy's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kFmEgey_pvz5oS1EnBNt5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/snoggys-wandsworth?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4644579, 'longitude': -0.2376655},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '367 Upper Richmond Road',
#     'address2': 'Putney',
#     'address3': '',
#     'city': 'Wandsworth',
#     'zip_code': 'SW15 5QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['367 Upper Richmond Road',
#      'Putney',
#      'Wandsworth SW15 5QJ',
#      'United Kingdom']},
#    'phone': '+442088762050',
#    'display_phone': '+44 20 8876 2050',
#    'distance': 8861.658258328429},
#   {'id': 'WqJ5Pp0pB-kZI6qa4tdlsA',
#    'alias': 'greggs-london-3',
#    'name': 'Greggs',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AmjH7ikqtZ77mCsQsIlfpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greggs-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4746146, 'longitude': -0.2068644},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '702c Fulham Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 5SA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['702c Fulham Road',
#      'London SW6 5SA',
#      'United Kingdom']},
#    'phone': '+442077364090',
#    'display_phone': '+44 20 7736 4090',
#    'distance': 6522.51899673772},
#   {'id': 'Px5vTIY3_lb6vJOnerjW8A',
#    'alias': 'the-troubadour-london',
#    'name': 'The Troubadour',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Aae9gdJpU1iewv19NNq4nw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-troubadour-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 95,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'danceclubs', 'title': 'Dance Clubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.488822437999,
#     'longitude': -0.19190476580433},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '263-7 Old Brompton Road',
#     'address2': 'Earls Court',
#     'address3': 'Kensington and Chelsea',
#     'city': 'London',
#     'zip_code': 'SW5 9JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['263-7 Old Brompton Road',
#      'Earls Court',
#      'Kensington and Chelsea',
#      'London SW5 9JA',
#      'United Kingdom']},
#    'phone': '+442073701434',
#    'display_phone': '+44 20 7370 1434',
#    'distance': 4704.008264124056},
#   {'id': 'qF2RobL-4k6IYnS6hpqEyA',
#    'alias': 'poppies-london-5',
#    'name': 'Poppies',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/n246LLC0nd6XjVjPNtT_YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/poppies-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 342,
#    'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5202629, 'longitude': -0.074075},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6-8 Hanbury Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6QR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6-8 Hanbury Street',
#      'London E1 6QR',
#      'United Kingdom']},
#    'phone': '+442072470892',
#    'display_phone': '+44 20 7247 0892',
#    'distance': 4360.779510525656},
#   {'id': 'XHCHzTZOxyXFIaI52rU4CQ',
#    'alias': 'jinjuu-london',
#    'name': 'Jinjuu',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/znStpjZubXnMhw6VOgFtMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jinjuu-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5123954723956,
#     'longitude': -0.138893650736518},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '15 Kingly Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5PS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Kingly Street',
#      'London W1B 5PS',
#      'United Kingdom']},
#    'phone': '+442081818887',
#    'display_phone': '+44 20 8181 8887',
#    'distance': 209.1076820199375},
#   {'id': 'CoOXb3OMOuMnOEatF62LiQ',
#    'alias': 'steins-kingston-upon-thames',
#    'name': "Stein's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VkQ5OpRyhL2auQbsUE6szw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/steins-kingston-upon-thames?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.407239, 'longitude': -0.308125},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '56 High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Kingston Upon Thames',
#     'zip_code': 'KT1 1HN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['56 High Street',
#      'Kingston Upon Thames KT1 1HN',
#      'United Kingdom']},
#    'phone': '+442085462411',
#    'display_phone': '+44 20 8546 2411',
#    'distance': 16740.459370749977},
#   {'id': 'o7PM_2GI50-9mlhQ_0WqyA',
#    'alias': 'the-wurst-club-london',
#    'name': 'The Wurst Club',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YXOcrYMlAk77PQL91S25TQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wurst-club-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.513202, 'longitude': -0.084998},
#    'transactions': [],
#    'location': {'address1': '56-57 Cornhill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3V 3PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['56-57 Cornhill',
#      'London EC3V 3PD',
#      'United Kingdom']},
#    'phone': '+442072838008',
#    'display_phone': '+44 20 7283 8008',
#    'distance': 3527.392606845823},
#   {'id': 'CUBjGkG29s0V7yPnr-5Hwg',
#    'alias': '1920-london-2',
#    'name': '1920',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7hzrA-bpaEZxH9nSKneH-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/1920-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'poolhalls', 'title': 'Pool Halls'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5232200622559,
#     'longitude': -0.100608997046947},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '19-20 Great Sutton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 0DR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19-20 Great Sutton Street',
#      'London EC1V 0DR',
#      'United Kingdom']},
#    'phone': '+442072531920',
#    'display_phone': '+44 20 7253 1920',
#    'distance': 2704.6353982562073},
#   {'id': 'T9BC90kxPsFi7ZHb5vH1nw',
#    'alias': 'made-in-italy-london-4',
#    'name': 'Made in Italy',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hFE5Uc9G7m1SanacFPKSqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/made-in-italy-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 65,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4860996, 'longitude': -0.1720436},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "249 King's Road",
#     'address2': 'Chelsea',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW3 5EL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["249 King's Road",
#      'Chelsea',
#      'London SW3 5EL',
#      'United Kingdom']},
#    'phone': '+442073521880',
#    'display_phone': '+44 20 7352 1880',
#    'distance': 3883.0801418071587},
#   {'id': 'pa2j9BlCHH8mRIk-TtD6UQ',
#    'alias': 'camden-bakery-london',
#    'name': 'Camden Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/V1BIQXnDxmTz0NyfTs6BiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camden-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5370833, 'longitude': -0.1407642},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '94 Camden High Street',
#     'address2': 'Camden Town',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 0LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['94 Camden High Street',
#      'Camden Town',
#      'London NW1 0LT',
#      'United Kingdom']},
#    'phone': '+442073874947',
#    'display_phone': '+44 20 7387 4947',
#    'distance': 2712.007403533704},
#   {'id': 'qORMGjRfN0tVN6vN2YtQYw',
#    'alias': 'o-sheas-butchers-london',
#    'name': "O'shea's Butchers",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ytjS2eO811pOb4I1Qn9cpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/o-sheas-butchers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'butcher', 'title': 'Butcher'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.498826, 'longitude': -0.0737},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '120 Druid Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 2HH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['120 Druid Street',
#      'London SE1 2HH',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4607.005867548632},
#   {'id': 'sgeNa1YWdyfzqDLwu1pUMw',
#    'alias': 'gigs-london',
#    'name': 'Gigs',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tGTX8DPGgyG06UwLULuzOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gigs-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.521001, 'longitude': -0.135294},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '12 Tottenham Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 4RE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Tottenham Street',
#      'London W1T 4RE',
#      'United Kingdom']},
#    'phone': '+442076361424',
#    'display_phone': '+44 20 7636 1424',
#    'distance': 909.1129041918585},
#   {'id': 'wFWiE3iYnAeZAqY_rYUijw',
#    'alias': 'the-breakfast-club-london-5',
#    'name': 'The Breakfast Club',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ngN4FmcyWKpk0oAfMD3VTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-breakfast-club-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5183525085449,
#     'longitude': -0.0783239975571632},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '12-16 Artillery Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 7LS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12-16 Artillery Lane',
#      'London E1 7LS',
#      'United Kingdom']},
#    'phone': '+442070789633',
#    'display_phone': '+44 20 7078 9633',
#    'distance': 4034.839657484001},
#   {'id': 'lrkhrEmcffCWIBLsqU0nRw',
#    'alias': 'bizzarro-london',
#    'name': 'Bizzarro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KO1LnuEZTe8ZfgAetqCuyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bizzarro-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 150,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514853, 'longitude': -0.1772311},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18-22 Craven Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18-22 Craven Road',
#      'London W2 3PX',
#      'United Kingdom']},
#    'phone': '+442077236029',
#    'display_phone': '+44 20 7723 6029',
#    'distance': 2857.153283484032},
#   {'id': 'eBBzulCh4P5un77UtXAxCg',
#    'alias': 'cleavers-london',
#    'name': 'Cleavers',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zC7EgVzYOfcTqUPvaGKaXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cleavers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4598693847656,
#     'longitude': -0.188730999827385},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '537 Old York Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW18 1TG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['537 Old York Road',
#      'London SW18 1TG',
#      'United Kingdom']},
#    'phone': '+4420888745843',
#    'display_phone': '+44 20888745843',
#    'distance': 6931.101958306738},
#   {'id': 'zOLPCLptUE2UKRXYWCEHvg',
#    'alias': 'the-modern-pantry-london',
#    'name': 'The Modern Pantry',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xCCsKLYTjFB2it91U1ntmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-modern-pantry-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 145,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5230301121618,
#     'longitude': -0.103575187145258},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "47-48 St John's Square",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 4JJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["47-48 St John's Square",
#      'London EC1V 4JJ',
#      'United Kingdom']},
#    'phone': '+442075539210',
#    'display_phone': '+44 20 7553 9210',
#    'distance': 2510.962821457009},
#   {'id': 'm1HQUczUwC4-WfGnIfgQkg',
#    'alias': 'meatmarket-london',
#    'name': 'MEATmarket',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iSqGXOMHa2q-57URSll6GQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meatmarket-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 93,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5115639700479,
#     'longitude': -0.121881224701809},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'The Deck Jubilee Market Hall',
#     'address2': 'Tavistock Street',
#     'address3': 'Covent Garden',
#     'city': 'London',
#     'zip_code': 'WC2E 8BE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Deck Jubilee Market Hall',
#      'Tavistock Street',
#      'Covent Garden',
#      'London WC2E 8BE',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 984.1965410983465},
#   {'id': 'ixbPUSOYmbl9koCTsEtr0Q',
#    'alias': 'crown-tavern-london',
#    'name': 'Crown Tavern',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dTmziw0L4CBBqRTlaD0xnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crown-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.523259, 'longitude': -0.105218},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '43 Clerkenwell Green',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 0EG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['43 Clerkenwell Green',
#      'London EC1R 0EG',
#      'United Kingdom']},
#    'phone': '+442072534973',
#    'display_phone': '+44 20 7253 4973',
#    'distance': 2418.71634677864},
#   {'id': 'jgx_WCV_5zBEeGHQvimLHQ',
#    'alias': 'cafe-españa-london-2',
#    'name': 'Cafe España',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0MXTmVg2C_USHLhor7GSsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-espa%C3%B1a-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.512463, 'longitude': -0.13289},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '63 Old Compton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6HT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63 Old Compton Street',
#      'London W1D 6HT',
#      'United Kingdom']},
#    'phone': '+442072875336',
#    'display_phone': '+44 20 7287 5336',
#    'distance': 213.2988387816787},
#   {'id': 'kwFb99k3auydqT6AW3xdWg',
#    'alias': 'gails-bakery-london-37',
#    'name': "GAIL's Bakery",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_9ABUB6ZOlM9Yk6PItBVlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-london-37?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.49891, 'longitude': -0.2001699},
#    'transactions': [],
#    'location': {'address1': '240-242 Kensington High Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 5SA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['240-242 Kensington High Street',
#      'London W8 5SA',
#      'United Kingdom']},
#    'phone': '+442073483924',
#    'display_phone': '+44 20 7348 3924',
#    'distance': 4685.080648578934},
#   {'id': 'wFxsp5CZCnyVs1nEheJADg',
#    'alias': 'gaucho-tower-bridge-london',
#    'name': 'Gaucho - Tower Bridge',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CMny3QhHJee5gx2GRJ1d2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gaucho-tower-bridge-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 72,
#    'categories': [{'alias': 'argentine', 'title': 'Argentine'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5048025184846,
#     'longitude': -0.0801444053649902},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '2 More London Riverside',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 2AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 More London Riverside',
#      'London SE1 2AP',
#      'United Kingdom']},
#    'phone': '+442074075222',
#    'display_phone': '+44 20 7407 5222',
#    'distance': 3964.475894136698},
#   {'id': 'wqZucWHydm2qx-iUCUyJpQ',
#    'alias': 'e-pellicci-london',
#    'name': 'E Pellicci',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wtUxdaKR9UoXTT3eYcjMGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/e-pellicci-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5265159984371,
#     'longitude': -0.0635611602914123},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '332 Bethnal Green Road',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E2 0AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['332 Bethnal Green Road',
#      'London E2 0AG',
#      'United Kingdom']},
#    'phone': '+442077394873',
#    'display_phone': '+44 20 7739 4873',
#    'distance': 5234.916021601817},
#   {'id': '8YdXBeXvOv9Iyt56CvTwUw',
#    'alias': 'smithfield-butchers-london',
#    'name': 'Smithfield Butchers',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/smubBexe5Y05NFY7L_nQsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/smithfield-butchers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5183525085449,
#     'longitude': -0.102554000914097},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '24 Smithfield St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1A 9LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Smithfield St',
#      'London EC1A 9LB',
#      'United Kingdom']},
#    'phone': '+442072362425',
#    'display_phone': '+44 20 7236 2425',
#    'distance': 2391.3215772873327},
#   {'id': 'Knha-8wa2_RPavK_o9qfQQ',
#    'alias': 'simpsons-tavern-london-2',
#    'name': 'Simpsons Tavern',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FOeBcE7ikfpDv23RWwyxkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/simpsons-tavern-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5131443111499,
#     'longitude': -0.0860142708131661},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Ballcourt 38 1/2 Cornhill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3V 9DR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Ballcourt 38 1/2 Cornhill',
#      'London EC3V 9DR',
#      'United Kingdom']},
#    'phone': '+442076269985',
#    'display_phone': '+44 20 7626 9985',
#    'distance': 3456.1580791156907},
#   {'id': '4lCI-05rQo2hQMr9qXKJAQ',
#    'alias': 'pizza-union-london-8',
#    'name': 'Pizza Union',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/u-a-jn1TKJ4wTVKKBRi3eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizza-union-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 80,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5175265894232,
#     'longitude': -0.0773585960268974},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "25 Sandy's Row",
#     'address2': 'Corner of Middlesex Street',
#     'address3': 'Spitalfields',
#     'city': 'London',
#     'zip_code': 'E1 7HW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["25 Sandy's Row",
#      'Corner of Middlesex Street',
#      'Spitalfields',
#      'London E1 7HW',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4088.184992399059},
#   {'id': 'By_GidVlsMQa_Ri2hLkP9Q',
#    'alias': 'waxy-o-connors-london',
#    'name': "Waxy O'Connor's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2VBGvltFPGmBdVnJMAHi3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/waxy-o-connors-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 168,
#    'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'},
#     {'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5107349, 'longitude': -0.1322637},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14-16 Rupert Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6DD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14-16 Rupert Street',
#      'London W1D 6DD',
#      'United Kingdom']},
#    'phone': '+442072870255',
#    'display_phone': '+44 20 7287 0255',
#    'distance': 343.497932226086},
#   {'id': 'LMGXgoqJDLM5ZDD72oigPg',
#    'alias': 'preto-london',
#    'name': 'Preto',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dXUhW2sd1K3laxK5G9TvuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/preto-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4930272155551,
#     'longitude': -0.140680427009754},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '72 Wilton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1DE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['72 Wilton Road',
#      'London SW1V 1DE',
#      'United Kingdom']},
#    'phone': '+442072338668',
#    'display_phone': '+44 20 7233 8668',
#    'distance': 2226.7246760989733},
#   {'id': 't-LjuFbYp76ARX7QEp0gnA',
#    'alias': 'the-windmill-london-2',
#    'name': 'The Windmill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EoyTiwabaEmXue8EXs4nKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-windmill-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 94,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512565, 'longitude': -0.142204},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6-8 Mill Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 2AZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6-8 Mill Street',
#      'London W1S 2AZ',
#      'United Kingdom']},
#    'phone': '+442074918050',
#    'display_phone': '+44 20 7491 8050',
#    'distance': 433.4266729223569},
#   {'id': 'n7vXgfapPy4uGLgqsUTDyg',
#    'alias': 'the-barge-house-london',
#    'name': 'The Barge House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qyRLwAeCfi9ydDeemsMTwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-barge-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5372997, 'longitude': -0.0808728},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '46 De Beauvoir Crescent',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 5RY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['46 De Beauvoir Crescent',
#      'London N1 5RY',
#      'United Kingdom']},
#    'phone': '+442072490765',
#    'display_phone': '+44 20 7249 0765',
#    'distance': 4682.087331063891},
#   {'id': 'vE8n6zPzAMFLa2pUJubz7w',
#    'alias': 'armstrongs-of-richmond-richmond',
#    'name': "Armstrong's Of Richmond",
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/armstrongs-of-richmond-richmond?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4662246704102,
#     'longitude': -0.294010013341904},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '205 Lower Mortlake Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': 'TW9 2LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['205 Lower Mortlake Road',
#      'Richmond TW9 2LP',
#      'United Kingdom']},
#    'phone': '+442089401833',
#    'display_phone': '+44 20 8940 1833',
#    'distance': 12108.40049023612},
#   {'id': 'had_4DZe8LPqKNbX1UVNdQ',
#    'alias': 'w-bunting-london',
#    'name': 'W Bunting',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xe_E0HxAt1_BV6spxc9gFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/w-bunting-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.482735, 'longitude': -0.065318},
#    'transactions': [],
#    'location': {'address1': '13 Peckham Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE15 6TR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Peckham Park Road',
#      'London SE15 6TR',
#      'United Kingdom']},
#    'phone': '+442076393718',
#    'display_phone': '+44 20 7639 3718',
#    'distance': 5928.519689067787},
#   {'id': '2SX4bVbFytVii5Px5PH2xQ',
#    'alias': 'de-vine-restaurant-and-coffee-bar-london',
#    'name': 'De Vine Restaurant and Coffee Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZMljylnBUb095DEiKt8jPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/de-vine-restaurant-and-coffee-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5109241386221,
#     'longitude': -0.0755801994950509},
#    'transactions': [],
#    'location': {'address1': '19 Vine Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3N 2PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Vine Street',
#      'London EC3N 2PX',
#      'United Kingdom']},
#    'phone': '+442074889929',
#    'display_phone': '+44 20 7488 9929',
#    'distance': 4183.53612031524},
#   {'id': 'yLKPHgqm3hCr2qHJbau0nQ',
#    'alias': 'the-brewhouse-london',
#    'name': 'The Brewhouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RtcSjdA9NGcE1ub90jc9Lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-brewhouse-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.571336, 'longitude': -0.167637},
#    'transactions': [],
#    'location': {'address1': 'Hampstead Lane',
#     'address2': 'Kenwood',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 7JR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Hampstead Lane',
#      'Kenwood',
#      'London NW3 7JR',
#      'United Kingdom']},
#    'phone': '+442083415384',
#    'display_phone': '+44 20 8341 5384',
#    'distance': 6879.488419636889},
#   {'id': 'nG9FL_8vpAUsJFy1R4XTYg',
#    'alias': 'comptoir-libanais-kensington',
#    'name': 'Comptoir Libanais',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gQxEwd1r9S6DihIgTKm3_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/comptoir-libanais-kensington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'lebanese', 'title': 'Lebanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4946804479439,
#     'longitude': -0.182466405629542},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '77a Gloucester Road',
#     'address2': '',
#     'address3': None,
#     'city': 'Kensington',
#     'zip_code': 'SW7 4SS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['77a Gloucester Road',
#      'Kensington SW7 4SS',
#      'United Kingdom']},
#    'phone': '+442033550856',
#    'display_phone': '+44 20 3355 0856',
#    'distance': 3799.8292968113137},
#   {'id': 'Z0r83lDOA1mI8RpNccXtHw',
#    'alias': 'the-fat-bear-london',
#    'name': 'The Fat Bear',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-U3vVDIo1UItF64Gf1yAZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-fat-bear-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 123,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'soulfood', 'title': 'Soul Food'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5131833881734,
#     'longitude': -0.10138103121642},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61 Carter Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4V 5DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Carter Lane',
#      'London EC4V 5DY',
#      'United Kingdom']},
#    'phone': '+442072362498',
#    'display_phone': '+44 20 7236 2498',
#    'distance': 2392.909207748214},
#   {'id': 'qM6lDKglcVhUkH-0fJTn4g',
#    'alias': 'le-garrick-london',
#    'name': 'Le Garrick',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sQoN0zEsbMV-aFX0fO9EiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-garrick-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5115661621094,
#     'longitude': -0.126066997647285},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10-12 Garrick Street',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 9BH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10-12 Garrick Street',
#      'Covent Garden',
#      'London WC2E 9BH',
#      'United Kingdom']},
#    'phone': '+442072407649',
#    'display_phone': '+44 20 7240 7649',
#    'distance': 698.7287779983149},
#   {'id': '65JkA2ikIjsbBHtrUJcH2w',
#    'alias': 'lowlander-london',
#    'name': 'Lowlander',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tp9v_dWpnXTNkdf-7vxljQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lowlander-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'belgian', 'title': 'Belgian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514624, 'longitude': -0.12241},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '36 Drury Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5RR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['36 Drury Lane', 'London WC2B 5RR', 'United Kingdom']},
#    'phone': '+442073797446',
#    'display_phone': '+44 20 7379 7446',
#    'distance': 963.9661830841728},
#   {'id': 'pGbGihQeRCZpTcMBBtbExQ',
#    'alias': 'lina-stores-restaurant-london',
#    'name': 'Lina Stores Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yGHiJ7U9wIjfh5MSdBDYjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lina-stores-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5141264, 'longitude': -0.1311127},
#    'transactions': [],
#    'location': {'address1': '51 Greek Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 4EH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Greek Street',
#      'London W1D 4EH',
#      'United Kingdom']},
#    'phone': '+442039290068',
#    'display_phone': '+44 20 3929 0068',
#    'distance': 363.93633807555403},
#   {'id': '8760FhaiXzekz1kOj1uDxg',
#    'alias': 'bloomsbury-farmers-market-london',
#    'name': "Bloomsbury Farmers' Market",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qTC4Jrmk-yDqeULIbMB6mA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bloomsbury-farmers-market-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'},
#     {'alias': 'streetvendors', 'title': 'Street Vendors'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.522696, 'longitude': -0.13116},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Torrington Square',
#     'address2': 'Byng Place',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1E 7HY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Torrington Square',
#      'Byng Place',
#      'London WC1E 7HY',
#      'United Kingdom']},
#    'phone': '+442078330338',
#    'display_phone': '+44 20 7833 0338',
#    'distance': 1179.7754612413335},
#   {'id': 'uq52voow6qazaRAFJ0ceMw',
#    'alias': 'the-greenwich-union-london',
#    'name': 'The Greenwich Union',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/N0-v397Ntye4xRU4u0CuSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-greenwich-union-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.47653480684,
#     'longitude': -0.0095805481062472},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '56 Royal Hill',
#     'address2': 'Greenwich',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE10 8RT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['56 Royal Hill',
#      'Greenwich',
#      'London SE10 8RT',
#      'United Kingdom']},
#    'phone': '+442086926258',
#    'display_phone': '+44 20 8692 6258',
#    'distance': 9635.029679658126},
#   {'id': 'bJiVADMSTEKj0MjqiLrOPA',
#    'alias': 'the-grazing-goat-marylebone-london',
#    'name': 'The Grazing Goat Marylebone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/h73f5PAFit9wdm8w_zm3lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grazing-goat-marylebone-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 240,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515378341447,
#     'longitude': -0.15823586449841},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 New Quebec Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7RQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 New Quebec Street',
#      'London W1H 7RQ',
#      'United Kingdom']},
#    'phone': '+442077247243',
#    'display_phone': '+44 20 7724 7243',
#    'distance': 1567.469377589238},
#   {'id': '9unKQnITNDIu5Z2IP8P1tQ',
#    'alias': 'shanes-on-chatsworth-london-3',
#    'name': "Shane's on Chatsworth",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5pHHIgqCi171vq4GM_ihSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shanes-on-chatsworth-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5542755126953,
#     'longitude': -0.0448880009353161},
#    'transactions': [],
#    'location': {'address1': '62 Chatsworth Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E5 0LS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['62 Chatsworth Road',
#      'London E5 0LS',
#      'United Kingdom']},
#    'phone': '+442089853755',
#    'display_phone': '+44 20 8985 3755',
#    'distance': 7804.587545065096},
#   {'id': 'vmBxOLRJEme7m-wR5CdgcQ',
#    'alias': 'shake-shack-covent-garden-london-4',
#    'name': 'Shake Shack Covent Garden',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-b9pmraTBa4b90ozXDea2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shake-shack-covent-garden-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 235,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.511818, 'longitude': -0.122506},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '24 Market Building',
#     'address2': 'The Piazza',
#     'address3': 'Covent Garden',
#     'city': 'London',
#     'zip_code': 'WC2E 8RD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Market Building',
#      'The Piazza',
#      'Covent Garden',
#      'London WC2E 8RD',
#      'United Kingdom']},
#    'phone': '+441923555129',
#    'display_phone': '+44 1923 555129',
#    'distance': 937.601022291232}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#            Restaurant             Type Price Rating  \
# 0        The Feathers             Pubs    ££    3.5
# 1              Halepi            Greek    ££      4
# 2  Upper Fleet Bakery         Bakeries
# 3             49 Cafe  Modern European     £    4.5
# 4       Raab's Bakery         Bakeries     £      5
#
#                      Address        Lat       Lng  \
# 0             18-20 Broadway  51.499226 -0.133103
# 1        18 Leinster Terrace  51.511330 -0.183103
# 2  7 - 11 Upper Woburn place  51.526332 -0.129385
# 3        49 Marchmont Street  51.524959 -0.125161
# 4             136 Essex Road  51.539319 -0.097745
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/the-feathers-london-2...  qlRpV22dIDFiY1sVjr9kxQ
# 1  https://www.yelp.com/biz/halepi-london?adjust_...  sMeVGW8YFs0gaRFFNJH8uQ
# 2
# 3  https://www.yelp.com/biz/49-cafe-london?adjust...  LyXXTUzll212_JKMkzC3DQ
# 4  https://www.yelp.com/biz/raabs-bakery-london?a...  DARE_WvgMZINvslycDPJFQ

# %%
london_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
london_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_restaurants_df = london_restaurants_df[column_order]
london_restaurants_df = london_restaurants_df.sort_values(["Type"], ascending=True)
london_restaurants_df = london_restaurants_df.reset_index(drop=True)
london_restaurants_df
# Out:
#                       Restaurant                    Type Rating Price  \
# 0                        Chinwag          American (New)    4.5    ££
# 1                       Bodean's  American (Traditional)      4    ££
# 2                   The Fat Bear  American (Traditional)    4.5    ££
# 3                 Sticky Fingers  American (Traditional)    3.5    ££
# 4             The Breakfast Club  American (Traditional)    3.5    ££
# 5                         Gaucho               Argentine      4   £££
# 6          Gaucho - Tower Bridge               Argentine      4   £££
# 7                      Fischer's                Austrian      4   £££
# 8               Hansel & Pretzel                Bakeries      5    ££
# 9                  GAIL's Bakery                Bakeries
# 10          Byward Kitchen & Bar                Bakeries      4    ££
# 11            Upper Fleet Bakery                Bakeries
# 12                 Raab's Bakery                Bakeries      5     £
# 13                 Camden Bakery                Bakeries    4.5     £
# 14                        Greggs                Bakeries      4     £
# 15                        HotBox                Barbeque      4   £££
# 16                     The Lyric                    Bars    4.5    ££
# 17               Simpsons Tavern                    Bars      4    ££
# 18                   Dirty Bones                    Bars      4    ££
# 19        The Sausage Man UK Ltd    Beer, Wine & Spirits
# 20               The Jugged Hare              Brasseries      4   £££
# 21                        Raizes               Brazilian      3    ££
# 22                  Rodizio Rico               Brazilian      4    ££
# 23                         Preto               Brazilian    3.5    ££
# 24            The Breakfast Club      Breakfast & Brunch    3.5    ££
# 25                      Soho Joe      Breakfast & Brunch
# 26             The Modern Pantry      Breakfast & Brunch      4    ££
# 27           Caravan Kings Cross      Breakfast & Brunch      4    ££
# 28                  Lantana Cafe      Breakfast & Brunch      4    ££
# 29                       Caravan      Breakfast & Brunch      4    ££
# ..                           ...                     ...    ...   ...
# 170                  Pizza Union                   Pizza    4.5     £
# 171           Sartori Restaurant                   Pizza      4    ££
# 172                 Franco Manca                   Pizza      4    ££
# 173                 Voodoo Ray's                   Pizza      4     £
# 174                  Pizza Union                   Pizza    4.5     £
# 175                         1920              Pool Halls      4    ££
# 176                 The Windmill                    Pubs      4    ££
# 177                    Lowlander                    Pubs      4    ££
# 178           The Jolly Butchers                    Pubs    4.5    ££
# 179                 Crown Tavern                    Pubs    3.5    ££
# 180                      Stein's                    Pubs    4.5    ££
# 181                 The Feathers                    Pubs    3.5    ££
# 182           The Windsor Castle                    Pubs      4    ££
# 183  Tollington The Public House                    Pubs    4.5    ££
# 184                   The Castle                    Pubs    3.5    ££
# 185                   The Easton                    Pubs    4.5    ££
# 186                 The Victoria                    Pubs    4.5    ££
# 187               The Kings Arms                    Pubs      4    ££
# 188              Hank's Po' Boys              Sandwiches
# 189            Birley Sandwiches              Sandwiches      4     £
# 190                       Lisa's            Scandinavian      4    ££
# 191                  Cafe España                 Spanish    3.5    ££
# 192          Hawksmoor Guildhall             Steakhouses    4.5   £££
# 193       Hawksmoor Spitalfields             Steakhouses    4.5   £££
# 194            Whitecross Market          Street Vendors    4.5     £
# 195               Boston Sausage          Street Vendors    4.5     £
# 196                  Scotchtails          Street Vendors      4     £
# 197         Little Jack Horner's          Street Vendors      5    ££
# 198                        Kazan                 Turkish    4.5    ££
# 199                   Le Garrick               Wine Bars      4    ££
#
#                              Address        Lat       Lng  \
# 0                    21 Lewisham Way  51.475179 -0.035167
# 1                     D'Arblay House  51.514481 -0.136761
# 2                     61 Carter Lane  51.513183 -0.101381
# 3              1a Phillimore Gardens  51.499880 -0.198297
# 4               12-16 Artillery Lane  51.518353 -0.078324
# 5                  25 Swallow Street  51.509680 -0.137955
# 6            2 More London Riverside  51.504803 -0.080144
# 7          50 Marylebone High Street  51.521616 -0.151700
# 8                      71 Ham Street  51.438419 -0.313494
# 9     240-242 Kensington High Street  51.498910 -0.200170
# 10                     Byward Street  51.509289 -0.078964
# 11         7 - 11 Upper Woburn place  51.526332 -0.129385
# 12                    136 Essex Road  51.539319 -0.097745
# 13             94 Camden High Street  51.537083 -0.140764
# 14                  702c Fulham Road  51.474615 -0.206864
# 15           46-48 Commercial Street  51.517070 -0.073318
# 16          37 Great Windmill Street  51.511283 -0.134466
# 17         Ballcourt 38 1/2 Cornhill  51.513144 -0.086014
# 18           20 Kensington Church St  51.502639 -0.191136
# 19         Unit 1 St Margaret's Farm  51.411704  0.260025
# 20                49 Chiswell Street  51.520789 -0.090935
# 21                  460 Hackney Road  51.532062 -0.058945
# 22                77-78 Upper Street  51.536510 -0.103692
# 23                    72 Wilton Road  51.493027 -0.140680
# 24                  2-4 Rufus Street  51.526988 -0.081127
# 25                    34 D'Arblay St  51.514916 -0.135394
# 26            47-48 St John's Square  51.523030 -0.103575
# 27                  1 Granary Square  51.535779 -0.125371
# 28                13 Charlotte Place  51.518968 -0.135956
# 29              11-13 Exmouth Market  51.525472 -0.110123
# ..                               ...        ...       ...
# 170       246 - 250 Pentonville Road  51.531052 -0.119832
# 171          15 Great Newport Street  51.511791 -0.128004
# 172                   39 Maiden Lane  51.510954 -0.122907
# 173                 Unit 1-3 Boxpark  51.523511 -0.076394
# 174                   25 Sandy's Row  51.517527 -0.077359
# 175        19-20 Great Sutton Street  51.523220 -0.100609
# 176                  6-8 Mill Street  51.512565 -0.142204
# 177                    36 Drury Lane  51.514624 -0.122410
# 178  204 Stoke Newington High Street  51.562365 -0.073349
# 179             43 Clerkenwell Green  51.523259 -0.105218
# 180                   56 High Street  51.407239 -0.308125
# 181                   18-20 Broadway  51.499226 -0.133103
# 182            114 Campden Hill Road  51.505787 -0.198597
# 183                 115 Hornsey Road  51.557264 -0.112692
# 184            34-35 Cowcross Street  51.520295 -0.104290
# 185                 22 Easton Street  51.526323 -0.111399
# 186             10a Strathearn Place  51.513504 -0.171200
# 187                2 Shepherd Market  51.506349 -0.146108
# 188          Southbank Centre Market  51.505322 -0.116054
# 189                         Unit 23A  51.505151 -0.021341
# 190              305 Portobello Road  51.519356 -0.207833
# 191            63 Old Compton Street  51.512463 -0.132890
# 192             10 Basinghall Street  51.515501 -0.090864
# 193           157a Commercial Street  51.521150 -0.075657
# 194              1 Whitecross Street  51.522829 -0.092765
# 195                      Bridge Foot  51.505783 -0.091592
# 196                   Borough Market  51.505860 -0.090027
# 197   Parliament Hill Farmers Market  51.558997 -0.152371
# 198                93-94 Wilton Road  51.492700 -0.140720
# 199             10-12 Garrick Street  51.511566 -0.126067
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/chinwag-london?adjust...  07iun95qUOuTR7aWShFwUw
# 1    https://www.yelp.com/biz/bodeans-london?adjust...  Fa9718rkbQuMh3DYgvsSYw
# 2    https://www.yelp.com/biz/the-fat-bear-london?a...  Z0r83lDOA1mI8RpNccXtHw
# 3    https://www.yelp.com/biz/sticky-fingers-london...  YuQUXWOJROqOSeo0a19M5w
# 4    https://www.yelp.com/biz/the-breakfast-club-lo...  wFWiE3iYnAeZAqY_rYUijw
# 5    https://www.yelp.com/biz/gaucho-london-22?adju...  VBQWqRMbt31fIUGlWUMkeQ
# 6    https://www.yelp.com/biz/gaucho-tower-bridge-l...  wFxsp5CZCnyVs1nEheJADg
# 7    https://www.yelp.com/biz/fischers-london?adjus...  apqNvjbaB20wozywrLNPiQ
# 8    https://www.yelp.com/biz/hansel-and-pretzel-lo...  RQxZlkXAAiDA6KNmvThi5w
# 9
# 10   https://www.yelp.com/biz/byward-kitchen-and-ba...  xViBKVW8zxlrxLfDam2eqg
# 11
# 12   https://www.yelp.com/biz/raabs-bakery-london?a...  DARE_WvgMZINvslycDPJFQ
# 13   https://www.yelp.com/biz/camden-bakery-london?...  pa2j9BlCHH8mRIk-TtD6UQ
# 14   https://www.yelp.com/biz/greggs-london-3?adjus...  WqJ5Pp0pB-kZI6qa4tdlsA
# 15   https://www.yelp.com/biz/hotbox-london?adjust_...  ZeRFcWpgERKSFY1Rvuq8VA
# 16   https://www.yelp.com/biz/the-lyric-london?adju...  3yvDAVKLDtsXZEHrskuobA
# 17   https://www.yelp.com/biz/simpsons-tavern-londo...  Knha-8wa2_RPavK_o9qfQQ
# 18   https://www.yelp.com/biz/dirty-bones-london?ad...  qQrQr-3WddVRFqsBaTe_wg
# 19
# 20   https://www.yelp.com/biz/the-jugged-hare-londo...  tWqe8jJBRf-TjqwQAn1Xfw
# 21   https://www.yelp.com/biz/raizes-london?adjust_...  xueM-mMFg2p-wweqiITstw
# 22   https://www.yelp.com/biz/rodizio-rico-london-2...  WYHgZEH5oeYoCAs__BCNzg
# 23   https://www.yelp.com/biz/preto-london?adjust_c...  LMGXgoqJDLM5ZDD72oigPg
# 24   https://www.yelp.com/biz/the-breakfast-club-lo...  ao-yAAnj8D_D9WI7qgLOow
# 25
# 26   https://www.yelp.com/biz/the-modern-pantry-lon...  zOLPCLptUE2UKRXYWCEHvg
# 27   https://www.yelp.com/biz/caravan-kings-cross-l...  B6ayHXLwfYBuIADficAeMg
# 28   https://www.yelp.com/biz/lantana-cafe-london-2...  xl05GXufB5wPlGQL75wiJA
# 29   https://www.yelp.com/biz/caravan-london-3?adju...  Bc4GZfIUJu9363QQVACZVA
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/pizza-union-london-7?...  CQsUI0K8XOAwSR4gN6l55Q
# 171  https://www.yelp.com/biz/sartori-restaurant-lo...  VpXOD3pTsTMGy7cqtpNuNA
# 172  https://www.yelp.com/biz/franco-manca-london-1...  uhtq0kf7Hnxg0ap4B7_8AQ
# 173  https://www.yelp.com/biz/voodoo-rays-london-2?...  __zb-nuVLOikaEnrnKoBvA
# 174  https://www.yelp.com/biz/pizza-union-london-8?...  4lCI-05rQo2hQMr9qXKJAQ
# 175  https://www.yelp.com/biz/1920-london-2?adjust_...  CUBjGkG29s0V7yPnr-5Hwg
# 176  https://www.yelp.com/biz/the-windmill-london-2...  t-LjuFbYp76ARX7QEp0gnA
# 177  https://www.yelp.com/biz/lowlander-london?adju...  65JkA2ikIjsbBHtrUJcH2w
# 178  https://www.yelp.com/biz/the-jolly-butchers-lo...  5zAP9qPHcBDut7QGCZCLbg
# 179  https://www.yelp.com/biz/crown-tavern-london?a...  ixbPUSOYmbl9koCTsEtr0Q
# 180  https://www.yelp.com/biz/steins-kingston-upon-...  CoOXb3OMOuMnOEatF62LiQ
# 181  https://www.yelp.com/biz/the-feathers-london-2...  qlRpV22dIDFiY1sVjr9kxQ
# 182  https://www.yelp.com/biz/the-windsor-castle-lo...  HntBHodgbw-vhW3MaCqbcw
# 183  https://www.yelp.com/biz/tollington-the-public...  9vzIix6uttTqfIQH-aH7eg
# 184  https://www.yelp.com/biz/the-castle-london-10?...  Ua0pmEYc0elDSgUt5OCK3g
# 185  https://www.yelp.com/biz/the-easton-london?adj...  ruccgDIBllsprKlP_7HBpg
# 186  https://www.yelp.com/biz/the-victoria-paddingt...  teXPunKtpwj0NuttvPYhyQ
# 187  https://www.yelp.com/biz/the-kings-arms-london...  t4n-Go-jqlFYYuCuyNeBTA
# 188
# 189  https://www.yelp.com/biz/birley-sandwiches-lon...  FdfIx7h5tRd4AAMcXHrljw
# 190  https://www.yelp.com/biz/lisas-london-2?adjust...  X_1Z-RAonaFLaTjkdKBljA
# 191  https://www.yelp.com/biz/cafe-espa%C3%B1a-lond...  jgx_WCV_5zBEeGHQvimLHQ
# 192  https://www.yelp.com/biz/hawksmoor-guildhall-l...  XgU_CX_G1zzCXCe1IV7I6g
# 193  https://www.yelp.com/biz/hawksmoor-spitalfield...  DI9SUiuxlf1WjkTu_jJSbg
# 194  https://www.yelp.com/biz/whitecross-market-lon...  PrIqHQtsQl-DnafTdS326A
# 195  https://www.yelp.com/biz/boston-sausage-boston...  3XTM3AIdCtPhrDfT77-hmw
# 196  https://www.yelp.com/biz/scotchtails-london-2?...  oSJClu8F3C75_NzTcOatHQ
# 197  https://www.yelp.com/biz/little-jack-horners-l...  7O8blUUjCGAk7V9wZvOEAg
# 198  https://www.yelp.com/biz/kazan-london?adjust_c...  vmi7fEu1vy2Tj2yuYlgR0g
# 199  https://www.yelp.com/biz/le-garrick-london?adj...  qM6lDKglcVhUkH-0fJTn4g
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
london_restaurants_df.to_csv('Resources/London_Restaurants_Sausage.csv')
