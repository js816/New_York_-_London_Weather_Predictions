# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"coffee","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': 'pimuUR-TEHIjUla3S3jemQ',
#    'alias': 'coffee-project-new-york-east-village-new-york',
#    'name': 'Coffee Project New York | East Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/oTalWA2QqsoRD4RprV0tOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffee-project-new-york-east-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 692,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72699, 'longitude': -73.98922},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '239 E 5th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['239 E 5th St', 'New York, NY 10003']},
#    'phone': '+12122287888',
#    'display_phone': '(212) 228-7888',
#    'distance': 2438.0326883939874},
#   {'id': 'WHRHK3S1mQc3PmhwsGRvbw',
#    'alias': 'bibble-and-sip-new-york-2',
#    'name': 'Bibble & Sip',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gX847-f2s1X65RkzsFAWBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bibble-and-sip-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5020,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7628355, 'longitude': -73.98518009478293},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '253 W 51st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253 W 51st St', 'New York, NY 10019']},
#    'phone': '+16466495116',
#    'display_phone': '(646) 649-5116',
#    'distance': 6427.569355387715},
#   {'id': 'Mkx7wE0Jlb0bFYGhEpulSg',
#    'alias': 'blackstone-coffee-roasters-new-york',
#    'name': 'Blackstone Coffee Roasters',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3uosI_M3K2cZvAyK_dE0pA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blackstone-coffee-roasters-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7332899, 'longitude': -74.00619},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '502 Hudson St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['502 Hudson St', 'New York, NY 10014']},
#    'phone': '+12129896131',
#    'display_phone': '(212) 989-6131',
#    'distance': 3251.3728402820225},
#   {'id': 'vijwGDNrPBJHEG7_DsjZNw',
#    'alias': 'usagi-ny-dumbo-7',
#    'name': 'Usagi NY',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6yNqnkPDJAZXpMemwCYN3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/usagi-ny-dumbo-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'bookstores', 'title': 'Bookstores'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'homedecor', 'title': 'Home Decor'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70383, 'longitude': -73.98691},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '163 Plymouth St',
#     'address2': '',
#     'address3': '',
#     'city': 'Dumbo',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['163 Plymouth St', 'Dumbo, NY 11201']},
#    'phone': '+17188018037',
#    'display_phone': '(718) 801-8037',
#    'distance': 635.7818631527628},
#   {'id': 'KWC_KYP336tSFhAihd8plg',
#    'alias': 'bluestone-lane-dumbo-café-brooklyn',
#    'name': 'Bluestone Lane DUMBO Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AjXvAC5Y5Blhi2a5XxpmIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bluestone-lane-dumbo-caf%C3%A9-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 196,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70077577888819,
#     'longitude': -73.98836356287899},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '55 Prospect St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Prospect St', 'Brooklyn, NY 11201']},
#    'phone': '+17183746858',
#    'display_phone': '(718) 374-6858',
#    'distance': 720.6910385584724},
#   {'id': 'RDxA8WL7wdHiM5YimUQ_XQ',
#    'alias': 'now-or-never-coffee-new-york',
#    'name': 'Now or Never Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aK0EhNd6MG8nwZqk8Fgt1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/now-or-never-coffee-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72295, 'longitude': -74.00456},
#    'transactions': ['delivery'],
#    'location': {'address1': '30 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30 Grand St', 'New York, NY 10013']},
#    'phone': '+13475568312',
#    'display_phone': '(347) 556-8312',
#    'distance': 2126.280926559841},
#   {'id': '-ogb8JWn8dvgzZA656EANA',
#    'alias': 'abraço-new-york-4',
#    'name': 'Abraço',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/587s6r-fMqJJhMnOC6ITtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/abra%C3%A7o-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 867,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.727365, 'longitude': -73.986167},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '81 E 7th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81 E 7th St', 'New York, NY 10003']},
#    'phone': '+12123889731',
#    'display_phone': '(212) 388-9731',
#    'distance': 2530.9861428706913},
#   {'id': 'SZXOfQbLyF3C5GwYBj6VvA',
#    'alias': 'saltwater-coffee-new-york',
#    'name': 'Saltwater Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cdBBTyVhiBft09uTwGStcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saltwater-coffee-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 234,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7304578, 'longitude': -73.9839175},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '345 E 12th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['345 E 12th St', 'New York, NY 10003']},
#    'phone': '+19178812245',
#    'display_phone': '(917) 881-2245',
#    'distance': 2915.5320769059854},
#   {'id': 'jniZaiTDALOVQfNkg_S9gg',
#    'alias': '787-coffee-new-york-5',
#    'name': '787 Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RA6g4b8dg4_t8f75CML6Ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/787-coffee-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'empanadas', 'title': 'Empanadas'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.703485, 'longitude': -74.01083},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '66 Pearl St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['66 Pearl St', 'New York, NY 10004']},
#    'phone': '+16464499200',
#    'display_phone': '(646) 449-9200',
#    'distance': 1410.8996195780276},
#   {'id': 'o9Ipm--aunOX5BbcKY4ENw',
#    'alias': 'feed-shop-and-cafe-brooklyn-2',
#    'name': 'FEED Shop & Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/j0hg_LPCsnAywwrwtP1AAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/feed-shop-and-cafe-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'accessories', 'title': 'Accessories'},
#     {'alias': 'jewelry', 'title': 'Jewelry'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.703402, 'longitude': -73.99141},
#    'transactions': ['delivery'],
#    'location': {'address1': '55 Water St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+19293972716',
#    'display_phone': '(929) 397-2716',
#    'distance': 332.66869202732244},
#   {'id': 'vk6L5A4OaBmdvgpB_bWDhw',
#    'alias': 'oxa-house-coffee-and-tea-new-york-3',
#    'name': 'OXA House Coffee & Tea ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tm3AbhsX-toc1FL160QZzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oxa-house-coffee-and-tea-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7103, 'longitude': -73.96513},
#    'transactions': [],
#    'location': {'address1': '102 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 Broadway', 'New York, NY 11249']},
#    'phone': '+13478013646',
#    'display_phone': '(347) 801-3646',
#    'distance': 2514.56603882948},
#   {'id': 'jZZMmT7Mk3S-fNjXcq3Ksg',
#    'alias': 'devocion-brooklyn-4',
#    'name': 'Devocion',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/33rJ0M41qXFWuQOIF382Ow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/devocion-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 496,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.716054, 'longitude': -73.964684},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '69 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['69 Grand St', 'Brooklyn, NY 11249']},
#    'phone': '+17182856180',
#    'display_phone': '(718) 285-6180',
#    'distance': 2762.7656443327546},
#   {'id': 'S9T8kG8xTPaQ1PxLE_VdYg',
#    'alias': 'devocion-new-york',
#    'name': 'Devocion',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NBOv88J8YqPZGU_1dfs0YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/devocion-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 124,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73904, 'longitude': -73.98916},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '25 E 20th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 E 20th St', 'New York, NY 10003']},
#    'phone': '+17182856180',
#    'display_phone': '(718) 285-6180',
#    'distance': 3771.239062934359},
#   {'id': 'ipygjHXH9PqQS6aqU54RcQ',
#    'alias': 'partners-coffee-brooklyn',
#    'name': 'Partners Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T7330j7npQypa1fl_hqz5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/partners-coffee-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 485,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71796, 'longitude': -73.95921},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '125 N 6th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['125 N 6th St', 'Brooklyn, NY 11249']},
#    'phone': '+13475860063',
#    'display_phone': '(347) 586-0063',
#    'distance': 3278.5492003498985},
#   {'id': '-2UtjTxrt1Xzd-HPsLJ7mA',
#    'alias': 'butler-brooklyn-2',
#    'name': 'Butler',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CU_zfWiYItMJkR6iJsnk0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/butler-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 131,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7032670673495,
#     'longitude': -73.9922419276899},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '40 Water St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40 Water St', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 299.48141504845114},
#   {'id': 'u0bYCPlbJ85_lDjnZQ_e3w',
#    'alias': 'kaigo-coffee-room-new-york-4',
#    'name': 'Kaigo Coffee Room',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fpRbgKDuP7UAc00wsfS2qw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaigo-coffee-room-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 157,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7187029822397,
#     'longitude': -74.0004725370878},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '120C Lafayette St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['120C Lafayette St', 'New York, NY 10013']},
#    'phone': '+16465045353',
#    'display_phone': '(646) 504-5353',
#    'distance': 1563.5297646007357},
#   {'id': 'vrcfSmyE8orhd0yHSrqvgQ',
#    'alias': 'bkg-coffee-roasters-brooklyn-3',
#    'name': 'BKG Coffee Roasters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AGUiBgh2vXViSHT5h2lz-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bkg-coffee-roasters-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 78,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69404, 'longitude': -73.96193},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '557 Myrtle Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['557 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3009.1887231281867},
#   {'id': 'OiCXI-fkb5nyYyfH3AxAOg',
#    'alias': 'kaigo-coffee-room-brooklyn-4',
#    'name': 'Kaigo Coffee Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/q8Xp5g8eoOyInc15pIApSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaigo-coffee-room-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 61,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6936075465661,
#     'longitude': -74.0010171957826},
#    'transactions': ['delivery'],
#    'location': {'address1': '139 Bridge Park Dr',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['139 Bridge Park Dr', 'Brooklyn, NY 11201']},
#    'phone': '+13475296180',
#    'display_phone': '(347) 529-6180',
#    'distance': 1433.1143646260844},
#   {'id': 'I_f_KhuRonsQiQ1llhqVHQ',
#    'alias': 'kodawari-coffee-new-york',
#    'name': 'Kodawari Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qRzbpqixE6mDK70aYOyKmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kodawari-coffee-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7183018824249,
#     'longitude': -73.9927714749158},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '100 Forsyth St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100 Forsyth St', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1435.3755459130114},
#   {'id': 'yCfjoS6XfnP8hd9zWjME7Q',
#    'alias': 'citizens-of-gramercy-new-york-2',
#    'name': 'Citizens Of Gramercy',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rHcWueF867fE2ODxkFYZfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/citizens-of-gramercy-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 168,
#    'categories': [{'alias': 'australian', 'title': 'Australian'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73674, 'longitude': -73.98152},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '362 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['362 2nd Ave', 'New York, NY 10010']},
#    'phone': '+13473969678',
#    'display_phone': '(347) 396-9678',
#    'distance': 3630.059092255233},
#   {'id': '-8nEZ20KDfr4PPH47MrAOA',
#    'alias': 'la-colombe-coffee-new-york-2',
#    'name': 'La Colombe Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6j27l5rIkTs8KOZOtc9t_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-colombe-coffee-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 685,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72396, 'longitude': -73.99643},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '270 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['270 Lafayette St', 'New York, NY 10012']},
#    'phone': '+12126251717',
#    'display_phone': '(212) 625-1717',
#    'distance': 2069.5745999716323},
#   {'id': 'CBmrwh7jHn88M4v8Q9Qyyg',
#    'alias': 'white-noise-coffee-co-brooklyn',
#    'name': 'White Noise Coffee Co',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DlrPHdex1kosN3KiL391_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/white-noise-coffee-co-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 98,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6896242, 'longitude': -73.9882489},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '57 Smith St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['57 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17188580258',
#    'display_phone': '(718) 858-0258',
#    'distance': 1823.3291615878086},
#   {'id': '8g2tBl5vvmin96nrRxAThw',
#    'alias': 'felix-roasting-new-york-3',
#    'name': 'Felix Roasting',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xpo3NK8Kv7cKlSwoYCTn1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/felix-roasting-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 74,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'wholesalers', 'title': 'Wholesalers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72437, 'longitude': -73.99941},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '104 Greene St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['104 Greene St', 'New York, NY 10012']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2154.575292805991},
#   {'id': '0S4MwamlsiHD8g2KZNPtIA',
#    'alias': 'parlor-coffee-brooklyn-2',
#    'name': 'Parlor Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CUhToqzD2isB2JwD1quRMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/parlor-coffee-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69748, 'longitude': -73.97041},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '11 Vanderbilt Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 Vanderbilt Ave', 'Brooklyn, NY 11205']},
#    'phone': '+19179666070',
#    'display_phone': '(917) 966-6070',
#    'distance': 2203.5234679492887},
#   {'id': 'MYYWU9rEIRZw43lACKXzTQ',
#    'alias': 'yours-truly-new-york-4',
#    'name': 'Yours Truly',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/smCKk0S2k6_bM2akfLm1pQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yours-truly-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 94,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7210275432472,
#     'longitude': -73.9944903889549},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '8 Spring St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8 Spring St', 'New York, NY 10012']},
#    'phone': '+19173882641',
#    'display_phone': '(917) 388-2641',
#    'distance': 1732.792599342473},
#   {'id': 'Dntkg2mLT0Tyc_AdKQMogw',
#    'alias': 'saltwater-coffee-new-york-2',
#    'name': 'Saltwater Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/C223_wTf78AuZ6rreYoWoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saltwater-coffee-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73281548761552,
#     'longitude': -73.99985005997831},
#    'transactions': ['delivery'],
#    'location': {'address1': '126 Waverly Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['126 Waverly Pl', 'New York, NY 10011']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3079.290705889451},
#   {'id': 'egkF3jmTAJzbb6uYT-TJrQ',
#    'alias': 'hvrminn-new-york-5',
#    'name': 'HVRMINN',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5GWGY6MArQ8TLEHdw9ubJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hvrminn-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.70308, 'longitude': -73.98392},
#    'transactions': [],
#    'location': {'address1': '247 Water St',
#     'address2': 'Ste 104',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['247 Water St', 'Ste 104', 'New York, NY 11201']},
#    'phone': '+17182608989',
#    'display_phone': '(718) 260-8989',
#    'distance': 903.5833614074085},
#   {'id': 'U1exuSaIwTwpjxvlrKeftg',
#    'alias': 'ppl-brooklyn',
#    'name': 'PPL',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Pyr46puhltD1-0wCu2mqhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ppl-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.712885, 'longitude': -73.958529},
#    'transactions': [],
#    'location': {'address1': '189 Roebling St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['189 Roebling St', 'Brooklyn, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3125.9913159270504},
#   {'id': 'XEdGYktN7VVuyjkN5ukr4A',
#    'alias': 'bright-side-brooklyn-3',
#    'name': 'Bright Side',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cSx5LjCIO0G3XipfmnXqUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bright-side-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7187096995697,
#     'longitude': -73.9640169072708},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '184 Kent Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['184 Kent Ave', 'Brooklyn, NY 11249']},
#    'phone': '+19292763577',
#    'display_phone': '(929) 276-3577',
#    'distance': 2947.45577986316},
#   {'id': '3IHtxjuE25_phqDyn6TZRw',
#    'alias': 'partners-coffee-new-york-3',
#    'name': 'Partners Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/o07-cSMKNvVR4ZqibV0ncg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/partners-coffee-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 140,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'internetcafe', 'title': 'Internet Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7349, 'longitude': -74.00228},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '44 Charles St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['44 Charles St', 'New York, NY 10014']},
#    'phone': '+16465901924',
#    'display_phone': '(646) 590-1924',
#    'distance': 3346.33577299331},
#   {'id': 'a8d18n8gAQpQHcr6KwCCeA',
#    'alias': 'saturdays-nyc-new-york-2',
#    'name': 'Saturdays NYC',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WFdNcX1-ABHBty3wgBMhAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saturdays-nyc-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72079, 'longitude': -73.99944},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '31 Crosby St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31 Crosby St', 'New York, NY 10013']},
#    'phone': '+12129667875',
#    'display_phone': '(212) 966-7875',
#    'distance': 1756.2595873324844},
#   {'id': 'HUlbrPvAr6sXuBfp5z1MWA',
#    'alias': 'urban-backyard-new-york',
#    'name': 'Urban Backyard',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bB8vr7pVnZmY5x1Snh2WoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/urban-backyard-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 210,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72077, 'longitude': -73.99646},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '180 Mulberry St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['180 Mulberry St', 'New York, NY 10012']},
#    'phone': '+16466929957',
#    'display_phone': '(646) 692-9957',
#    'distance': 1716.018342303412},
#   {'id': 'F_xfvWtka3ZHXxH94AFNrA',
#    'alias': 'seven-grams-caffe-new-york-7',
#    'name': 'Seven Grams Caffe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Lc_pNN3QlBT8hxGLHSghqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seven-grams-caffe-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 91,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74391, 'longitude': -73.98593},
#    'transactions': ['delivery'],
#    'location': {'address1': '76 Madison Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['76 Madison Ave', 'New York, NY 10016']},
#    'phone': '+12127790777',
#    'display_phone': '(212) 779-0777',
#    'distance': 4339.778311146225},
#   {'id': 'DRorx6DjfsSDQI75Lp84Ng',
#    'alias': 'rebel-coffee-new-york',
#    'name': 'Rebel Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Y3fe-iwAxTPnNzwrTW872Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rebel-coffee-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 148,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73784, 'longitude': -74.00475},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '19 8th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 8th Ave', 'New York, NY 10014']},
#    'phone': '+19172614299',
#    'display_phone': '(917) 261-4299',
#    'distance': 3707.6017890048615},
#   {'id': '56xmEk-5aTHwBiPyQTzMKA',
#    'alias': 'dreamers-coffee-house-new-york',
#    'name': 'Dreamers Coffee House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RG4YVhDc9YN_4G04tlGBXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dreamers-coffee-house-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.712736, 'longitude': -73.995257},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '54W Henry St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['54W Henry St', 'New York, NY 10002']},
#    'phone': '+12029052088',
#    'display_phone': '(202) 905-2088',
#    'distance': 808.9978527280191},
#   {'id': 'qauE0RX0J519WJw1zjI3VQ',
#    'alias': 'ost-cafe-new-york-3',
#    'name': 'Ost Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6dMbqJ1aW42NEqIrXZlowg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ost-cafe-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71445, 'longitude': -73.98214},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '511 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['511 Grand St', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1433.654815832446},
#   {'id': 'jDLKMWhHACb5w1DDtnW9ag',
#    'alias': 'happy-bones-nyc-new-york',
#    'name': 'Happy Bones NYC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8F3z3Mvf2Lk-BRGthuqdPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/happy-bones-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 276,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720726, 'longitude': -73.9970474},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '394 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['394 Broome St', 'New York, NY 10013']},
#    'phone': '+12126733754',
#    'display_phone': '(212) 673-3754',
#    'distance': 1718.756434115631},
#   {'id': 'IKB1DhFCLFY98mTt_l6u2A',
#    'alias': 'stumptown-coffee-roasters-new-york-2',
#    'name': 'Stumptown Coffee Roasters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tPRn3V3n39Km7zF7appOhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stumptown-coffee-roasters-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 441,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7328193931365,
#     'longitude': -73.9979619990999},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '30 W 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30 W 8th St', 'New York, NY 10011']},
#    'phone': '+13474147802',
#    'display_phone': '(347) 414-7802',
#    'distance': 3059.568496199233},
#   {'id': 'gNAMYO9-DQqWiipCDlCqVg',
#    'alias': 'head-hi-brooklyn',
#    'name': 'Head Hi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_-CH0mU3NrpxBG6bJ799fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/head-hi-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bookstores', 'title': 'Bookstores'},
#     {'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.69742, 'longitude': -73.97187},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '14 Clermont Avenue 1L',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 Clermont Avenue 1L', 'Brooklyn, NY 11205']},
#    'phone': '+19179090005',
#    'display_phone': '(917) 909-0005',
#    'distance': 2086.6795378215356},
#   {'id': 'DxeD4Jw3gsImI-olCOB0bA',
#    'alias': 'little-canal-new-york-2',
#    'name': 'Little Canal',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/35ZbxM9Zh8ex3U4-GPWknA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-canal-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 128,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.714309, 'longitude': -73.990417},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '26 Canal St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 Canal St', 'New York, NY 10002']},
#    'phone': '+19174727479',
#    'display_phone': '(917) 472-7479',
#    'distance': 1035.3030353262682},
#   {'id': 'xO2CRFBMObWzMe0GOfO6Sg',
#    'alias': 'hungry-ghost-new-york-6',
#    'name': 'Hungry Ghost',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IH1ePM344IDUoSEiqmfNRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hungry-ghost-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73287, 'longitude': -74.00383},
#    'transactions': [],
#    'location': {'address1': '315 Bleecker St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['315 Bleecker St', 'New York, NY 10014']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3155.9446151948596},
#   {'id': 'mR8MfMcFNgEukDG08I2aDQ',
#    'alias': 'ludlow-coffee-supply-new-york',
#    'name': 'Ludlow Coffee Supply',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zfDWcTSyLBIsMx1PKHzazQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ludlow-coffee-supply-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 250,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.721668, 'longitude': -73.987274},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '176 Ludlow St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['176 Ludlow St', 'New York, NY 10002']},
#    'phone': '+19174727632',
#    'display_phone': '(917) 472-7632',
#    'distance': 1895.3083101128234},
#   {'id': '8IcowtkuaPf3ZoXIGiNvqg',
#    'alias': 'blue-bottle-coffee-new-york-11',
#    'name': 'Blue Bottle Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BfI8eDx7qVx2MwSCXXVGWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-bottle-coffee-new-york-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 119,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.710715, 'longitude': -74.0123300674591},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '150 Greenwich St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 Greenwich St', 'New York, NY 10007']},
#    'phone': '+15106533394',
#    'display_phone': '(510) 653-3394',
#    'distance': 1629.3626579765842},
#   {'id': 'bmSYtYRPf6ycx-4xWhbHFg',
#    'alias': 'sey-coffee-brooklyn',
#    'name': 'Sey Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GOcXLMUY2bQcrNtmyNMl-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sey-coffee-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 121,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70532, 'longitude': -73.9324},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '18 Grattan St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18 Grattan St', 'Brooklyn, NY 11206']},
#    'phone': '+13478711611',
#    'display_phone': '(347) 871-1611',
#    'distance': 5215.052044394275},
#   {'id': 'Smj-UqUvNFneHKkuZ0BN7A',
#    'alias': 'kona-coffee-and-company-new-york',
#    'name': 'Kona Coffee and Company',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jpxWssXEd3OEcFn0JJjXpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kona-coffee-and-company-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 156,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72587, 'longitude': -73.98988},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '57 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['57 2nd Ave', 'New York, NY 10003']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2308.140222153645},
#   {'id': 'kpxXi23lUQkeJQH-2BtzDw',
#    'alias': 'qahwah-house-brooklyn',
#    'name': 'Qahwah House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hGHi0N9J4Q-2lzp6b3EPkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/qahwah-house-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 114,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7185628184474,
#     'longitude': -73.9571302649415},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '162 Bedford Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3455.274392319802},
#   {'id': 'ED7A7vDdg8yLNKJTSVHHmg',
#    'alias': 'arabica-brooklyn',
#    'name': '% Arabica',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_3VSEFG3iUT-M66JYc7U4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arabica-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 62,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70247143757704,
#     'longitude': -73.9942601520649},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '20 Old Fulton St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['20 Old Fulton St', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 330.64136101613974},
#   {'id': 'U3Ueh2bHtp3DLjrdc5w5fQ',
#    'alias': 'remi-flower-and-coffee-new-york-2',
#    'name': 'Remi Flower & Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OdnTsyBHpPngkS3aL3D4ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/remi-flower-and-coffee-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 396,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'florists', 'title': 'Florists'},
#     {'alias': 'floraldesigners', 'title': 'Floral Designers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.753781, 'longitude': -73.9689989},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '906 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['906 2nd Ave', 'New York, NY 10017']},
#    'phone': '+16465591233',
#    'display_phone': '(646) 559-1233',
#    'distance': 5781.90802079335},
#   {'id': 'PJ9iOIDrroVqchn7JsiBNA',
#    'alias': 'daymoves-brooklyn',
#    'name': 'Daymoves',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qePUZqvxAqyvJWsI30KHYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daymoves-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7130584, 'longitude': -73.957308},
#    'transactions': ['delivery'],
#    'location': {'address1': '295 Grand St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['295 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3230.3490118557534},
#   {'id': 'gA0VbcoBLCiD2EpSC6vWeg',
#    'alias': 'partners-coffee-long-island-city',
#    'name': 'Partners Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_e06-YI5h2zMRfO4DourEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/partners-coffee-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 174,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74769, 'longitude': -73.9416},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '26-25 Jackson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26-25 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+13475310477',
#    'display_phone': '(347) 531-0477',
#    'distance': 6460.204326416233}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                                Restaurant          Type Price Rating  \
# 0  Coffee Project New York | East Village  Coffee & Tea     $    4.5
# 1                            Bibble & Sip  Coffee & Tea    $$    4.5
# 2              Blackstone Coffee Roasters  Coffee & Tea    $$      5
# 3                                Usagi NY    Bookstores    $$    4.5
# 4               Bluestone Lane DUMBO Café  Coffee & Tea     $      4
#
#            Address        Lat        Lng  \
# 0     239 E 5th St  40.726990 -73.989220
# 1    253 W 51st St  40.762836 -73.985180
# 2    502 Hudson St  40.733290 -74.006190
# 3  163 Plymouth St  40.703830 -73.986910
# 4   55 Prospect St  40.700776 -73.988364
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/coffee-project-new-yo...  pimuUR-TEHIjUla3S3jemQ
# 1  https://www.yelp.com/biz/bibble-and-sip-new-yo...  WHRHK3S1mQc3PmhwsGRvbw
# 2  https://www.yelp.com/biz/blackstone-coffee-roa...  Mkx7wE0Jlb0bFYGhEpulSg
# 3  https://www.yelp.com/biz/usagi-ny-dumbo-7?adju...  vijwGDNrPBJHEG7_DsjZNw
# 4  https://www.yelp.com/biz/bluestone-lane-dumbo-...  KWC_KYP336tSFhAihd8plg

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"coffee","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': 'Qmv4SPta2zx7MhKit8ywag',
#    'alias': 'absolute-coffee-brooklyn',
#    'name': 'Absolute Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WrEZlU_pGNek1-Bpb5vdtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/absolute-coffee-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 196,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68827, 'longitude': -73.987569},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '327 Atlantic Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['327 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17185220969',
#    'display_phone': '(718) 522-0969',
#    'distance': 1995.2838490428082},
#   {'id': 'Rs196agFk9VEW2mHrOwpvw',
#    'alias': '12-corners-new-york-4',
#    'name': '12 Corners',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yEkNTNvbElGSUKV62a-dlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/12-corners-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 157,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7180405, 'longitude': -73.9972076},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '121 Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['121 Mott St', 'New York, NY 10013']},
#    'phone': '+12126258888',
#    'display_phone': '(212) 625-8888',
#    'distance': 1419.795430699577},
#   {'id': 'SAUBVV-yj9DFQ7NnZr5b1w',
#    'alias': 'prodigy-coffee-new-york-2',
#    'name': 'Prodigy Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i56SP6BHKpis5F23QvCiRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prodigy-coffee-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 209,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7302096, 'longitude': -74.0032381},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '33 Carmine St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33 Carmine St', 'New York, NY 10014']},
#    'phone': '+12124144142',
#    'display_phone': '(212) 414-4142',
#    'distance': 2855.0340278656963},
#   {'id': 'qoUWugiUAMzSgsoLbUME9w',
#    'alias': 'brooklyn-roasting-company-brooklyn-3',
#    'name': 'Brooklyn Roasting Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SK2ELaq8eU6wuTwB1xD-sg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-roasting-company-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 78,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6976059, 'longitude': -73.96798294704632},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '200 Flushing Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 Flushing Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17188585500',
#    'display_phone': '(718) 858-5500',
#    'distance': 2383.0543593885673},
#   {'id': 'NG-KlDcSjBk3pfdzjXmMVw',
#    'alias': 'devocion-brooklyn-3',
#    'name': 'Devocion',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ewiPhrKdYcZSgY9TZZrz9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/devocion-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 111,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68857, 'longitude': -73.98334},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '276 Livingston St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['276 Livingston St', 'Brooklyn, NY 11201']},
#    'phone': '+17182856180',
#    'display_phone': '(718) 285-6180',
#    'distance': 2087.8169485341946},
#   {'id': 'yUTsVnUME9zzrex1qmregw',
#    'alias': 'caffe-vita-lower-east-side-new-york',
#    'name': 'Caffe Vita Lower East Side',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yLgqvaYbICE6NiS7S-zE6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-vita-lower-east-side-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 189,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.719736, 'longitude': -73.988422},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '124 Ludlow St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['124 Ludlow St', 'New York, NY 10002']},
#    'phone': '+12122608482',
#    'display_phone': '(212) 260-8482',
#    'distance': 1664.36730204467},
#   {'id': 'YpGxtJy9ErnjfGG6DXy5uA',
#    'alias': 'sweatshop-cafe-brooklyn',
#    'name': 'Sweatshop Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cx_7Aqq55YRL4rs-Hj3yeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweatshop-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 365,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'australian', 'title': 'Australian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7149542040034, 'longitude': -73.959786},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '232 Metropolitan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['232 Metropolitan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+19179607232',
#    'display_phone': '(917) 960-7232',
#    'distance': 3094.7757917745057},
#   {'id': '7IBtDe9DBKEj6-v0MD-aWg',
#    'alias': 'poetica-coffee-brooklyn',
#    'name': 'Poetica Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jutmGI21JN27_YOLsJLSUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/poetica-coffee-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.683249, 'longitude': -73.992623},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '251 Smith St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['251 Smith St', 'Brooklyn, NY 11231']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2477.3704600413084},
#   {'id': 'bMepacmKDTwCdHJAU860bQ',
#    'alias': 'le-café-coffee-new-york-2',
#    'name': 'Le Café Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ROZ9xDQ127FSxhuve3E8mA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-caf%C3%A9-coffee-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 174,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7357460797343,
#     'longitude': -73.9928742229649},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '7 E 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 E 14th St', 'New York, NY 10003']},
#    'phone': '+12123651060',
#    'display_phone': '(212) 365-1060',
#    'distance': 3371.45915952521},
#   {'id': 'aljEnhQthQwifG971tY1mA',
#    'alias': 'everyman-espresso-new-york',
#    'name': 'Everyman Espresso',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bmLiIic1MytHjqQKhZmM1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/everyman-espresso-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 381,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7327852478612,
#     'longitude': -73.9883291989235},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '136 E 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136 E 13th St', 'New York, NY 10003']},
#    'phone': '+12125330524',
#    'display_phone': '(212) 533-0524',
#    'distance': 3081.3783535300277},
#   {'id': 'VHORZQg5A3YNBptRN92QGg',
#    'alias': 'the-lazy-llama-coffee-bar-new-york-2',
#    'name': 'The Lazy Llama Coffee Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/S_ZtGbbfVEIFbrUcGofUJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lazy-llama-coffee-bar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 100,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.723505897000265,
#     'longitude': -73.98873335337309},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '72 E 1st Street',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['72 E 1st Street', 'New York, NY 10003']},
#    'phone': '+16464101938',
#    'display_phone': '(646) 410-1938',
#    'distance': 2062.2377032766435},
#   {'id': 'JYbrQqYd-8iGBWIAAHKBRA',
#    'alias': 'citizens-of-soho-new-york',
#    'name': 'Citizens of Soho',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mJPQikRerSQkEtLGCr_B1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/citizens-of-soho-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'australian', 'title': 'Australian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72134, 'longitude': -73.99777},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '201 Lafayette St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['201 Lafayette St', 'New York, NY 10012']},
#    'phone': '+13475351245',
#    'display_phone': '(347) 535-1245',
#    'distance': 1788.5286937017102},
#   {'id': 'nyxmTe-It-tzfagvjkge1g',
#    'alias': 'burrow-brooklyn',
#    'name': 'Burrow',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oAg_RiYyeMnUO5bY_eIOQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burrow-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 81,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7027217, 'longitude': -73.9868878},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '68 Jay St',
#     'address2': 'Ste 119',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['68 Jay St', 'Ste 119', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 693.8065652395189},
#   {'id': 'WBQPnEuUm8BfAylBov_MGg',
#    'alias': 'matto-espresso-new-york-20',
#    'name': 'Matto Espresso',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KY_RnmLooWEG68oXuz_X8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/matto-espresso-new-york-20?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73025, 'longitude': -73.99397},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '293 Mercer St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['293 Mercer St', 'New York, NY 10003']},
#    'phone': '+12122444281',
#    'display_phone': '(212) 244-4281',
#    'distance': 2765.1853339440795},
#   {'id': '1fDtQij01Mk92ZTGn6WHjg',
#    'alias': 'the-little-sweet-cafe-boerum-hill-2',
#    'name': 'The Little Sweet Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PxtbjoctqGuEpyZER5HfkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-little-sweet-cafe-boerum-hill-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 154,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6881418, 'longitude': -73.9867324},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '77B Hoyt St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boerum Hill',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['77B Hoyt St', 'Boerum Hill, NY 11201']},
#    'phone': '+17188588998',
#    'display_phone': '(718) 858-8998',
#    'distance': 2026.8476632601842},
#   {'id': 'moo7CuKs4djrUCMHs4G_uQ',
#    'alias': 'café-integral-new-york-2',
#    'name': 'Café Integral',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-TEYXnmJeGl0G_gaoEs5xg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-integral-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 95,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720384, 'longitude': -73.995213},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '149 Elizabeth St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['149 Elizabeth St', 'New York, NY 10012']},
#    'phone': '+16468015747',
#    'display_phone': '(646) 801-5747',
#    'distance': 1662.9622099041658},
#   {'id': 'AY9gM46aAW_N_JF7ixTbUw',
#    'alias': 'americano-cafe-staten-island',
#    'name': 'AMERICANO CAFE',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FQBhc8wAyUV231tCvh1fHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/americano-cafe-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.6296235, 'longitude': -74.0738894},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '7 Navy Pier Ct',
#     'address2': None,
#     'address3': None,
#     'city': 'STATEN ISLAND',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 Navy Pier Ct', 'STATEN ISLAND, NY 10304']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 10777.23626008455},
#   {'id': 'kA98xP8HiJ_-fVaM7RECLw',
#    'alias': 'laughing-man-coffee-company-new-york',
#    'name': 'Laughing Man Coffee Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/G9aR228M0F9tibtPUQnMOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laughing-man-coffee-company-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 255,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71731, 'longitude': -74.01016},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '184 Duane St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['184 Duane St', 'New York, NY 10013']},
#    'phone': '+12126801111',
#    'display_phone': '(212) 680-1111',
#    'distance': 1872.338686956493},
#   {'id': 'sSQ3dtC8nbfeT6srFiiIlA',
#    'alias': 'stumptown-coffee-roasters-new-york',
#    'name': 'Stumptown Coffee Roasters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MjfyS99JsOMjsX51tdcHWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stumptown-coffee-roasters-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1396,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7456663381275,
#     'longitude': -73.9880916348562},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '20 W 29th St',
#     'address2': '',
#     'address3': 'The Ace Hotel',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['20 W 29th St',
#      'The Ace Hotel',
#      'New York, NY 10001']},
#    'phone': '+18557113385',
#    'display_phone': '(855) 711-3385',
#    'distance': 4502.8476637492195},
#   {'id': 'SWRz34fmNEDPcrngJMMo7Q',
#    'alias': 'butler-brooklyn',
#    'name': 'Butler',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_N74apVU_48PvLh6YlukTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/butler-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 123,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7117670177852,
#     'longitude': -73.9646924963509},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '95 S 5th St',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['95 S 5th St', 'Brooklyn, NY 11249']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2592.1803299896737},
#   {'id': 'Zc7Jbuwe3XO-EaVXIh_TYQ',
#    'alias': 'banter-new-york',
#    'name': 'Banter',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XCjCFrs7nalnaMHB4NZ2pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/banter-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 505,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72787, 'longitude': -74.0010999},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '169 Sullivan St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['169 Sullivan St', 'New York, NY 10012']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2560.3873077474886},
#   {'id': 'tq7dDT6edTInhkNdDrYv_w',
#    'alias': 'black-brick-brooklyn',
#    'name': 'Black Brick',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KMA7EDvWqQnCa9T6SICejQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-brick-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 325,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7142079238412,
#     'longitude': -73.9617848396301},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '300 Bedford Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['300 Bedford Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17183840075',
#    'display_phone': '(718) 384-0075',
#    'distance': 2908.1707973176744},
#   {'id': '_0VARjCkDlSPfzCA5nAo0Q',
#    'alias': 'den-social-cafe-new-york',
#    'name': 'Den Social Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bG6iNon5EL6YEzZknpjmOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/den-social-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75093, 'longitude': -73.98624},
#    'transactions': [],
#    'location': {'address1': '65 W 36th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['65 W 36th St', 'New York, NY 10018']},
#    'phone': '+12125643737',
#    'display_phone': '(212) 564-3737',
#    'distance': 5115.005496328242},
#   {'id': 'V4kHBho4ZiNdbuztgn0LWQ',
#    'alias': 'cafe-grumpy-new-york-6',
#    'name': 'Cafe Grumpy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5kGH5XqF475f8J208MrJBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-grumpy-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 122,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71512, 'longitude': -73.99015},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '13 Essex St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['13 Essex St', 'New York, NY 10002']},
#    'phone': '+12127777515',
#    'display_phone': '(212) 777-7515',
#    'distance': 1133.8186439848807},
#   {'id': 'VLC2DROxvGX-ka_aBmJN9w',
#    'alias': 'social-house-cafe-brooklyn',
#    'name': 'Social House Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XHkG8Rw-KLF4-FCKP_kTkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/social-house-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7102965207822, 'longitude': -73.966014},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '60 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Broadway', 'Brooklyn, NY 11249']},
#    'phone': '+19292950397',
#    'display_phone': '(929) 295-0397',
#    'distance': 2443.9586408622786},
#   {'id': 'hyEyUk9GOwxlco3w-WU9gA',
#    'alias': 'butler-brooklyn-3',
#    'name': 'Butler',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8LDIfPOfSn01dM3CdiKgew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/butler-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7197884, 'longitude': -73.9591445},
#    'transactions': [],
#    'location': {'address1': '101 N 8th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['101 N 8th St', 'Brooklyn, NY 11249']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3364.546721608744},
#   {'id': 'oDRZt37ROqadlK3-VI0PfQ',
#    'alias': 'alimama-new-york-3',
#    'name': 'Alimama',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5XwgumtgBN2Wzm20dprDqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alimama-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1386,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7158626896215,
#     'longitude': -73.9992850858479},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '89A Bayard St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['89A Bayard St', 'New York, NY 10013']},
#    'phone': '+12122357288',
#    'display_phone': '(212) 235-7288',
#    'distance': 1227.5817807830615},
#   {'id': 'STBNV2yArITdLJ1k5hfBig',
#    'alias': 'gotham-coffee-roasters-new-york',
#    'name': 'Gotham Coffee Roasters',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wECgtzY3zCfZFp1a4kfU-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gotham-coffee-roasters-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73975, 'longitude': -73.99269},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '23 W 19th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23 W 19th St', 'New York, NY 10011']},
#    'phone': '+12122552972',
#    'display_phone': '(212) 255-2972',
#    'distance': 3832.6476305870124},
#   {'id': 'Q6rOOar8ud4sXoh7pDZUnw',
#    'alias': 'oslo-coffee-roasters-new-york-2',
#    'name': 'Oslo Coffee Roasters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4I4eEMgVCsEx8ESQ6HZozA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oslo-coffee-roasters-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7337720512204, 'longitude': -74.005471},
#    'transactions': ['delivery'],
#    'location': {'address1': '236 W 10th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['236 W 10th St', 'New York, NY 10014']},
#    'phone': '+17187820332',
#    'display_phone': '(718) 782-0332',
#    'distance': 3287.68337964657},
#   {'id': 'rd0VGG_d_qNp_aBW_HJM4w',
#    'alias': 'third-rail-coffee-new-york',
#    'name': 'Third Rail Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vxOIeyZiQSVsB-h8-j1UWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/third-rail-coffee-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 474,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72994, 'longitude': -73.99959},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '240 Sullivan St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['240 Sullivan St', 'New York, NY 10012']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2765.2849385347295},
#   {'id': 'XbUg52y01_fcIzz7MEUHxQ',
#    'alias': 'café-leon-dore-new-york',
#    'name': 'Café Leon Dore',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/59UUjkjAtModG2gy7LW2Lw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-leon-dore-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7221012731031,
#     'longitude': -73.9961103853269},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '214 Mulberry St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['214 Mulberry St', 'New York, NY 10012']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1858.4278378870495},
#   {'id': 'neqjsm1AbaGcLDRNshEA7A',
#    'alias': 'gregorys-coffee-brooklyn-2',
#    'name': 'Gregorys Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-AF41sXXGof2rUS1vaT0CA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gregorys-coffee-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.693613, 'longitude': -73.990789},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '16 Court St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['16 Court St', 'Brooklyn, NY 11201']},
#    'phone': '+19293376368',
#    'display_phone': '(929) 337-6368',
#    'distance': 1346.179208376056},
#   {'id': 'TgQoXIJsTjDtbO-UtpCtlA',
#    'alias': 'kettl-new-york',
#    'name': 'Kettl',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8sCCCtgPOlMgF_1keCh7DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kettl-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72664, 'longitude': -73.99202},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '348 Bowery',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['348 Bowery', 'New York, NY 10012']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2363.440526193271},
#   {'id': 'DA1hijID0q6D6Ouch17v7w',
#    'alias': 'pecks-new-york',
#    'name': "Peck's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/H_hr9SJgmj0fOZZIdYCDQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pecks-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 150,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.693489, 'longitude': -73.967376},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '455A Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['455A Myrtle Ave', 'New York, NY 11205']},
#    'phone': '+13476894969',
#    'display_phone': '(347) 689-4969',
#    'distance': 2638.841789597834},
#   {'id': 'KEyhIMAUpj7cceOvG9C1sA',
#    'alias': 'kabisera-new-york-4',
#    'name': 'Kabisera',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eZtLR5F-zklfBWEJyycuTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kabisera-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 101,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'filipino', 'title': 'Filipino'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.720907, 'longitude': -73.989913},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '151 Allen St',
#     'address2': '',
#     'address3': 'Store South',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['151 Allen St', 'Store South', 'New York, NY 10002']},
#    'phone': '+19292073729',
#    'display_phone': '(929) 207-3729',
#    'distance': 1759.6506732063558},
#   {'id': 'ejZjFbR_Z3He5pi699eJKg',
#    'alias': 'birch-coffee-new-york-10',
#    'name': 'Birch Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SxLAxrUNGUbgsquZqy1DLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/birch-coffee-new-york-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 78,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.710971, 'longitude': -74.005676},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '8 Spruce St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8 Spruce St', 'New York, NY 10038']},
#    'phone': '+12126861444',
#    'display_phone': '(212) 686-1444',
#    'distance': 1144.4381823271774},
#   {'id': 'OiqGAhC5EQXb1CaNxxvfBQ',
#    'alias': 'harney-and-sons-soho-new-york',
#    'name': 'Harney & Sons SoHo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MuWnp_KUOvoso5KPqtTryA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harney-and-sons-soho-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 743,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7214398332376,
#     'longitude': -73.9994008558221},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '433 Broome St',
#     'address2': '',
#     'address3': 'Ground Fl',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['433 Broome St', 'Ground Fl', 'New York, NY 10013']},
#    'phone': '+12129334853',
#    'display_phone': '(212) 933-4853',
#    'distance': 1829.9148841424953},
#   {'id': '-HpCsFpk8PwFpbmEELmg6g',
#    'alias': 'semicolon-cafe-new-york',
#    'name': 'Semicolon Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XeV_1Qahm20B_Hs4lrt_hw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/semicolon-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.834633, 'longitude': -73.94522},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '9 Edward M Morgan Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10032',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Edward M Morgan Pl', 'New York, NY 10032']},
#    'phone': '+16467915518',
#    'display_phone': '(646) 791-5518',
#    'distance': 14946.678731643246},
#   {'id': 'rQpO1Eie_zmeAOQ9s-T0sQ',
#    'alias': 'hole-in-the-wall-new-york-12',
#    'name': 'Hole In The Wall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NSQmNZzpk69EeGYDQNaThQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hole-in-the-wall-new-york-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 623,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'australian', 'title': 'Australian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70837, 'longitude': -74.00563},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '15 Cliff St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Cliff St', 'New York, NY 10038']},
#    'phone': '+12126029991',
#    'display_phone': '(212) 602-9991',
#    'distance': 1009.2543696243514},
#   {'id': '18-qEPtsL2lbZH4ianmicg',
#    'alias': 'the-granddaddy-new-york-2',
#    'name': 'The Granddaddy',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PG3P3t_9u4VL3j9WZkrghA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-granddaddy-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 129,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71782, 'longitude': -73.992},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '290 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['290 Grand St', 'New York, NY 10002']},
#    'phone': '+19173882233',
#    'display_phone': '(917) 388-2233',
#    'distance': 1384.5579490355208},
#   {'id': 'MFB3OOo5ZQxfCAYEDa8ZFA',
#    'alias': 'gasoline-alley-coffee-new-york',
#    'name': 'Gasoline Alley Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SXGhXLxFh74dWrJQsq2JAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gasoline-alley-coffee-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 261,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.725419, 'longitude': -73.994874},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '325 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['325 Lafayette St', 'New York, NY 10012']},
#    'phone': '+12129330113',
#    'display_phone': '(212) 933-0113',
#    'distance': 2221.559409545996},
#   {'id': '-7GUru8FEYMtBmit_hi4cw',
#    'alias': 'ixv-coffee-brooklyn',
#    'name': 'IXV Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/e8twmB6Uq9OmSzoogzLdnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ixv-coffee-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.684921, 'longitude': -73.98126},
#    'transactions': ['delivery'],
#    'location': {'address1': '497C Pacific St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['497C Pacific St', 'Brooklyn, NY 11217']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2532.600061850505},
#   {'id': 'DGhWO1sUWydVeR5j5ZZaMw',
#    'alias': 'la-grande-boucherie-new-york-2',
#    'name': 'La Grande Boucherie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/b9URGcuuhnLq7J-__pHIng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-grande-boucherie-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 519,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7626274, 'longitude': -73.98084109999999},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '145 W 53rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['145 W 53rd St', 'New York, NY 10019']},
#    'phone': '+12125107714',
#    'display_phone': '(212) 510-7714',
#    'distance': 6458.633757596852},
#   {'id': 'P4HX6tjQQK4gbdn_d0cGTw',
#    'alias': 'ground-support-new-york',
#    'name': 'Ground Support',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FbOFOfl469WOxA236dRqIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ground-support-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 522,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7241968559678,
#     'longitude': -74.0020576327145},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '399 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['399 W Broadway', 'New York, NY 10012']},
#    'phone': '+12122198733',
#    'display_phone': '(212) 219-8733',
#    'distance': 2185.4017789063764},
#   {'id': '4VEgZ7aVUt6oKw8KmXj-jQ',
#    'alias': 'brooklyn-kolache-brooklyn',
#    'name': 'Brooklyn Kolache',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QqQV6MtAiG4i2vqCwFQhCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-kolache-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 337,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6907913077698,
#     'longitude': -73.9556479454041},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '520 Dekalb Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['520 Dekalb Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17183981111',
#    'display_phone': '(718) 398-1111',
#    'distance': 3642.653889043858},
#   {'id': 'iyKEtW9KM7rIyycAR0o3ew',
#    'alias': 'black-star-bakery-and-cafe-new-york-3',
#    'name': 'Black Star Bakery & Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6pfbDH57Vyv0DVL0b8IuQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-star-bakery-and-cafe-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.738951, 'longitude': -73.980784},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '241 E 24th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['241 E 24th St', 'New York, NY 10010']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3890.344620331399},
#   {'id': '7EWx7XCZYrcvQxzL41Ne4Q',
#    'alias': 'blank-street-new-york-5',
#    'name': 'Blank Street',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L0XMrE4817VKRdfjOZWx5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blank-street-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72256, 'longitude': -73.99718},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '236 Lafayette St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['236 Lafayette St', 'New York, NY 10012']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1916.243010809115},
#   {'id': 'xxiV3-0t_gO1Ojo3xo73TQ',
#    'alias': 'vineapple-cafe-brooklyn',
#    'name': 'Vineapple Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3CTXWh2vzVj7lz0s6MFhKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vineapple-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.698296727787, 'longitude': -73.99307556416},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '71 Pineapple St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['71 Pineapple St', 'Brooklyn, NY 11201']},
#    'phone': '+13477991035',
#    'display_phone': '(347) 799-1035',
#    'distance': 801.4361087691583},
#   {'id': 'OGO_ykdC27Fc-Q3Yhwjo4w',
#    'alias': 'ground-central-new-york-3',
#    'name': 'Ground Central',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/viu1xdHP2jxSEcDH_hX72Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ground-central-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 120,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75014, 'longitude': -73.97176},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '800 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['800 2nd Ave', 'New York, NY 10017']},
#    'phone': '+16468610015',
#    'display_phone': '(646) 861-0015',
#    'distance': 5296.621262311831},
#   {'id': 'uQ4HZzNarBBNcTKZSIY-vA',
#    'alias': 'black-fox-coffee-new-york',
#    'name': 'Black Fox Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JDMHFi9GJcDX5egiUxvuUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-fox-coffee-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 217,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7063449, 'longitude': -74.0076944},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '70 Pine St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70 Pine St', 'New York, NY 10005']},
#    'phone': '+19177420133',
#    'display_phone': '(917) 742-0133',
#    'distance': 1142.221482327151}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                   Restaurant          Type Price Rating            Address  \
# 0            Absolute Coffee  Coffee & Tea    $$    4.5   327 Atlantic Ave
# 1                 12 Corners  Coffee & Tea     $    4.5        121 Mott St
# 2             Prodigy Coffee  Coffee & Tea    $$      4      33 Carmine St
# 3  Brooklyn Roasting Company  Coffee & Tea    $$    3.5   200 Flushing Ave
# 4                   Devocion  Coffee & Tea     $      4  276 Livingston St
#
#          Lat        Lng                                                url  \
# 0  40.688270 -73.987569  https://www.yelp.com/biz/absolute-coffee-brook...
# 1  40.718041 -73.997208  https://www.yelp.com/biz/12-corners-new-york-4...
# 2  40.730210 -74.003238  https://www.yelp.com/biz/prodigy-coffee-new-yo...
# 3  40.697606 -73.967983  https://www.yelp.com/biz/brooklyn-roasting-com...
# 4  40.688570 -73.983340  https://www.yelp.com/biz/devocion-brooklyn-3?a...
#
#                        ID
# 0  Qmv4SPta2zx7MhKit8ywag
# 1  Rs196agFk9VEW2mHrOwpvw
# 2  SAUBVV-yj9DFQ7NnZr5b1w
# 3  qoUWugiUAMzSgsoLbUME9w
# 4  NG-KlDcSjBk3pfdzjXmMVw

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"coffee","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': 'blX8Y6O0J4p6fXVcTRmANg',
#    'alias': 'the-elk-new-york',
#    'name': 'The Elk',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Dv6TT43vrnM7QymxmicjOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-elk-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 165,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7341962235334,
#     'longitude': -74.007479016899},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '128 Charles St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['128 Charles St', 'New York, NY 10014']},
#    'phone': '+12129334780',
#    'display_phone': '(212) 933-4780',
#    'distance': 3384.6233215025222},
#   {'id': 'wWhZvkaFrntlSf1CWvD1Zw',
#    'alias': 'cafe-patoro-new-york',
#    'name': 'Cafe Patoro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Nnlsd9Wl7KFVVqZxtDRWpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-patoro-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 182,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7072720974983,
#     'longitude': -74.0023160353303},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '223 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['223 Front St', 'New York, NY 10038']},
#    'phone': '+19172620031',
#    'display_phone': '(917) 262-0031',
#    'distance': 706.1266596183273},
#   {'id': 'DE0ROwygh-86i4s-WLp8wQ',
#    'alias': 'maman-soho-new-york',
#    'name': 'Maman Soho',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nUj5B96Xh73Y2aGmuvDr6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maman-soho-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 577,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72028, 'longitude': -73.9984},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '239 Centre St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['239 Centre St', 'New York, NY 10013']},
#    'phone': '+12122260700',
#    'display_phone': '(212) 226-0700',
#    'distance': 1685.4911071554986},
#   {'id': 'iasVVMV9BGZy8LLNPpNVfA',
#    'alias': 'joe-coffee-company-brooklyn-2',
#    'name': 'Joe Coffee Company',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UXtU0A5f7uKojuE4Qxo7Cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joe-coffee-company-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6986734, 'longitude': -73.9943579},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '102 Hicks St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 Hicks St', 'Brooklyn, NY 11201']},
#    'phone': '+13474220304',
#    'display_phone': '(347) 422-0304',
#    'distance': 752.9714027220938},
#   {'id': '9-ornJr0G_IHkl6FpcCNzw',
#    'alias': 'terremoto-coffee-new-york',
#    'name': 'Terremoto Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/86BkMMP3m1JqpUZOumHrNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/terremoto-coffee-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 113,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74079, 'longitude': -74.00337},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '328 W 15th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['328 W 15th St', 'New York, NY 10011']},
#    'phone': '+12122434300',
#    'display_phone': '(212) 243-4300',
#    'distance': 4003.635732369655},
#   {'id': 'O0RxMO7AYZCMnOis7a08EA',
#    'alias': 'espresso-me-brooklyn-3',
#    'name': 'Espresso Me',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xNXkh83BipO-q4tRL175VQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/espresso-me-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.690892864574636,
#     'longitude': -73.99723224490806},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '88 Atlantic Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['88 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+19175195538',
#    'display_phone': '(917) 519-5538',
#    'distance': 1636.9663891136083},
#   {'id': 'A8jRnZGiMJiMpfHt8qKV3w',
#    'alias': 'fiction-bar-cafe-brooklyn',
#    'name': 'Fiction Bar/Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GdhN-_6OZFkK2cjiN449rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fiction-bar-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 95,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.707248, 'longitude': -73.95375},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '308 Hooper St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['308 Hooper St', 'Brooklyn, NY 11211']},
#    'phone': '+17185995151',
#    'display_phone': '(718) 599-5151',
#    'distance': 3425.4795376581733},
#   {'id': 'yMxGI1kcqv6a-aGH-VXg8A',
#    'alias': 'little-skips-east-brooklyn-2',
#    'name': 'Little Skips East',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XC_z6chuyn8ivjNGRhzhsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-skips-east-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 75,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6849363759513,
#     'longitude': -73.9137830212712},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1643 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11207',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1643 Broadway', 'Brooklyn, NY 11207']},
#    'phone': '+17184841555',
#    'display_phone': '(718) 484-1555',
#    'distance': 7160.390241526564},
#   {'id': '-MDpSeMiCsvfz9TueedWwg',
#    'alias': 'la-colombe-coffee-new-york-3',
#    'name': 'La Colombe Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/G6zLlrXHpG6dn3f1ZXmJwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-colombe-coffee-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 164,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7056896627839,
#     'longitude': -74.0083486272612},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '67 Wall St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['67 Wall St', 'New York, NY 10005']},
#    'phone': '+12122200415',
#    'display_phone': '(212) 220-0415',
#    'distance': 1185.0934583830956},
#   {'id': 'rXt5UuxqPKDz9id-th8wnw',
#    'alias': 'drip-coffee-makers-brooklyn-4',
#    'name': 'drip coffee makers',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4-Do_tQObs2VmBqJHxmkGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/drip-coffee-makers-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69841, 'longitude': -73.93703},
#    'transactions': ['delivery'],
#    'location': {'address1': '12 Belvidere St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['12 Belvidere St', 'Brooklyn, NY 11206']},
#    'phone': '+19177046742',
#    'display_phone': '(917) 704-6742',
#    'distance': 4895.666863429298},
#   {'id': 'Bw9b6vDTKXAOg7c3bcR9PA',
#    'alias': 'salento-colombian-coffee-and-kitchen-new-york',
#    'name': 'Salento Colombian Coffee & Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/r5RZwPT1_Q_gzFk3RjSzwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salento-colombian-coffee-and-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'colombian', 'title': 'Colombian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.83786, 'longitude': -73.9386},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2112 Amsterdam Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10032',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2112 Amsterdam Ave', 'New York, NY 10032']},
#    'phone': '+16467670680',
#    'display_phone': '(646) 767-0680',
#    'distance': 15452.150604207354},
#   {'id': '1Ik8VQxUa0aDbc1KzrxLRg',
#    'alias': 'caffe-aronne-new-york-3',
#    'name': 'Caffe Aronne',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/06P9LeNq7jaIUaxG5gJzpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-aronne-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.738394, 'longitude': -74.002048},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '112 Greenwich Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['112 Greenwich Ave', 'New York, NY 10011']},
#    'phone': '+16462343555',
#    'display_phone': '(646) 234-3555',
#    'distance': 3725.4558414715802},
#   {'id': '43WQ7zr54WL3yfT5KTlNBQ',
#    'alias': 'three-jewels-cafe-new-york-2',
#    'name': 'Three Jewels Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ovPmOS5x9AJaK0V2S69Ekg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/three-jewels-cafe-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72624, 'longitude': -73.99119},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '5 E 3rd St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 E 3rd St', 'New York, NY 10003']},
#    'phone': '+16469645736',
#    'display_phone': '(646) 964-5736',
#    'distance': 2340.185523882893},
#   {'id': 'VLMxyAe_l9vvyFd5vEPZ4g',
#    'alias': 'bee-cafe-woodside',
#    'name': 'Bee Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IAOxF8RoFpRQjA5k5zqwOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bee-cafe-woodside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 56,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7475304, 'longitude': -73.9030796},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '60-11 39th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60-11 39th Ave', 'Woodside, NY 11377']},
#    'phone': '+13473219098',
#    'display_phone': '(347) 321-9098',
#    'distance': 8998.820844142487},
#   {'id': 'S-WdvEU1X7J33whXWk1zmw',
#    'alias': 'mud-new-york-3',
#    'name': 'MUD',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HIHld1tjcnr6nkZ8y06cKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mud-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1222,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72905, 'longitude': -73.98668},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '307 E 9th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['307 E 9th St', 'New York, NY 10003']},
#    'phone': '+12122289074',
#    'display_phone': '(212) 228-9074',
#    'distance': 2708.034763713728},
#   {'id': 'YTYxc-Q8A3gRxjBr4nz_Xw',
#    'alias': 'upright-coffee-brooklyn',
#    'name': 'Upright Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/w7u_KTn_HYKHucsSJyGTiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/upright-coffee-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 128,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7292285, 'longitude': -73.9537541},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '860 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['860 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17182159910',
#    'display_phone': '(718) 215-9910',
#    'distance': 4320.535658886764},
#   {'id': 'bxU7CnSO9cFhq_1tQyX40A',
#    'alias': '787-coffee-new-york-2',
#    'name': '787 Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NerXLTb8BzHFxuWBft50YA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/787-coffee-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 89,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'empanadas', 'title': 'Empanadas'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72629, 'longitude': -73.98386},
#    'transactions': ['delivery'],
#    'location': {'address1': '131 E 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['131 E 7th St', 'New York, NY 10009']},
#    'phone': '+16466492774',
#    'display_phone': '(646) 649-2774',
#    'distance': 2483.913539245487},
#   {'id': 'YFaz9CprHpk9mkEmYyvcLA',
#    'alias': 'ralphs-coffee-new-york-5',
#    'name': "Ralph's Coffee",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1j43vKylc9Hj8B5zw100HA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ralphs-coffee-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74016, 'longitude': -73.99083},
#    'transactions': ['delivery'],
#    'location': {'address1': '160 5th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['160 5th Ave', 'New York, NY 10010']},
#    'phone': '+12126272040',
#    'display_phone': '(212) 627-2040',
#    'distance': 3865.210073684448},
#   {'id': 'DANnWXzJGxpYVr_MVLlkpg',
#    'alias': 'sweetleaf-coffee-brooklyn',
#    'name': 'Sweetleaf Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/duCXoOT2zQSwGToflwANKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweetleaf-coffee-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 105,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7345567794736,
#     'longitude': -73.9554053775444},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '159 Freeman St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['159 Freeman St', 'Brooklyn, NY 11222']},
#    'phone': '+13479873732',
#    'display_phone': '(347) 987-3732',
#    'distance': 4606.447667264001},
#   {'id': 'TqXN-wHboqIsTRyLhDobAg',
#    'alias': 'hungry-ghost-coffee-brooklyn',
#    'name': 'Hungry Ghost Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1JJ2d8yOLJreBhdFqzjq9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hungry-ghost-coffee-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6898258557588,
#     'longitude': -73.9800336547528},
#    'transactions': ['delivery'],
#    'location': {'address1': '80 Dekalb Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Dekalb Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17184890998',
#    'display_phone': '(718) 489-0998',
#    'distance': 2112.209931810772},
#   {'id': 'fiZG5Ttjk428MIc9XvMBHQ',
#    'alias': 'office-coffee-new-york-4',
#    'name': 'Office Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IIuUPJYUzxly5xrIpn4xbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/office-coffee-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71893703250802,
#     'longitude': -74.00095218748342},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '265 Canal St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['265 Canal St', 'New York, NY 10013']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1601.805757235283},
#   {'id': 'NJay-xUEFsvWzdeohs9EEA',
#    'alias': 'the-coppola-cafe-new-york',
#    'name': 'The Coppola Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gX4aHYhZYzgzbW4azQ9uQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-coppola-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.732190162973,
#     'longitude': -74.0016116022391},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '171 West 4th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 West 4th St', 'New York, NY 10014']},
#    'phone': '+19176393970',
#    'display_phone': '(917) 639-3970',
#    'distance': 3037.221433563653},
#   {'id': 'v3yGWIwc4Stv3uV3lj20sQ',
#    'alias': 'brooklyn-kava-bushwick',
#    'name': 'Brooklyn Kava',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4q-5f24ep8hnxfjlhkswWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-kava-bushwick?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'gourmet', 'title': 'Specialty Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7003175, 'longitude': -73.9256934},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '191 Suydam St',
#     'address2': '',
#     'address3': '',
#     'city': 'Bushwick',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['191 Suydam St', 'Bushwick, NY 11221']},
#    'phone': '+17184842330',
#    'display_phone': '(718) 484-2330',
#    'distance': 5820.067603840423},
#   {'id': 'CHBDkg9U4xx6uDanE6tGvA',
#    'alias': 'coffee-project-new-york-fort-greene-brooklyn',
#    'name': 'Coffee Project New York | Fort Greene',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vdbv81x3BFTR0pskJAj1HA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffee-project-new-york-fort-greene-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 78,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6875927899466,
#     'longitude': -73.9792491098683},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '78 Rockwell Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['78 Rockwell Pl', 'Brooklyn, NY 11217']},
#    'phone': '+15858883153',
#    'display_phone': '(585) 888-3153',
#    'distance': 2357.913680206829},
#   {'id': 'vbiBlVwjp-mnWqdzIElG9A',
#    'alias': 'beepublic-coffee-brooklyn',
#    'name': 'Beepublic Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yuvxkLGIBrpcGDvNhQG9Aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beepublic-coffee-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70277, 'longitude': -73.9870969},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '147 Front St',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['147 Front St', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 675.609559041376},
#   {'id': 'dXK2R-3ECPqXVgjvGlV8Cw',
#    'alias': 'zibetto-espresso-bar-new-york',
#    'name': 'Zibetto Espresso Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2qqlzP14OqPrVCp_mYPoeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zibetto-espresso-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 452,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7639232809413,
#     'longitude': -73.9776043465576},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1385 6th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1385 6th Ave', 'New York, NY 10019']},
#    'phone': '+16467070505',
#    'display_phone': '(646) 707-0505',
#    'distance': 6652.796996653451},
#   {'id': 'FkxRk1CUEhgBWRzFadkAaQ',
#    'alias': 'paper-coffee-new-york',
#    'name': 'Paper Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/f9d1K8FZGwJuj0h9oqsbug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paper-coffee-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 116,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7463281632382,
#     'longitude': -73.9896308128189},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '44 W 29th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['44 W 29th St', 'New York, NY 10001']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4562.9566139806},
#   {'id': 'gJD6DsPQUYHVVCTHLB_nJw',
#    'alias': 'homecoming-brooklyn',
#    'name': 'Homecoming',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mo5lPrh84-DzKVBtCMJk0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/homecoming-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 65,
#    'categories': [{'alias': 'florists', 'title': 'Florists'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'homedecor', 'title': 'Home Decor'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729579, 'longitude': -73.957801},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '107 Franklin St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['107 Franklin St', 'Brooklyn, NY 11222']},
#    'phone': '+13474575385',
#    'display_phone': '(347) 457-5385',
#    'distance': 4081.7150044483446},
#   {'id': 'UonMt2uU1tbj4L1cgFTOWg',
#    'alias': 'culture-espresso-new-york-3',
#    'name': 'Culture Espresso',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/m8J-PA1Hh0wuKEGVW15QKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/culture-espresso-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75505, 'longitude': -73.99216},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '307 W 38th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['307 W 38th St', 'New York, NY 10018']},
#    'phone': '+16468641963',
#    'display_phone': '(646) 864-1963',
#    'distance': 5527.320131466967},
#   {'id': 'atR9OjUA-kcnjSYMDV9BJw',
#    'alias': 'ellas-cafe-espresso-and-wine-bar-new-york',
#    'name': "Ella's Cafe Espresso & Wine Bar",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WIIcYxwqw1WkHCNcgv_FdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ellas-cafe-espresso-and-wine-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77168, 'longitude': -73.95649},
#    'transactions': [],
#    'location': {'address1': '1465 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1465 2nd Ave', 'New York, NY 10075']},
#    'phone': '+19174090307',
#    'display_phone': '(917) 409-0307',
#    'distance': 8013.114197160785},
#   {'id': '3PAWQuIvJ8DIa5akaF3XYQ',
#    'alias': 'marcy-and-myrtle-cafe-new-york-city',
#    'name': 'Marcy & Myrtle Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qgwA3tUWO1Y4zklDjyBDlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marcy-and-myrtle-cafe-new-york-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72068, 'longitude': -73.95766},
#    'transactions': ['delivery'],
#    'location': {'address1': '101 N 10th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York City',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['101 N 10th St', 'New York City, NY 11249']},
#    'phone': '+19176487800',
#    'display_phone': '(917) 648-7800',
#    'distance': 3525.7414425579113},
#   {'id': 'xTnivXEdEtXrnhp-z4JGvg',
#    'alias': 'la-parisienne-new-york-5',
#    'name': 'La Parisienne',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ywbWsBIM-z7OHvhMoHUg5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-parisienne-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 606,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70961, 'longitude': -74.0093799},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '9 Maiden Ln',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Maiden Ln', 'New York, NY 10038']},
#    'phone': '+16467564911',
#    'display_phone': '(646) 756-4911',
#    'distance': 1350.1089630689858},
#   {'id': '1uj4-rdYAQF6Amc0LVaeXg',
#    'alias': 'the-black-flamingo-brooklyn',
#    'name': 'The Black Flamingo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YX1FHLG5Dr4ObepyXOgVCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-black-flamingo-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 61,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6790846825271,
#     'longitude': -74.0106727985259},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '281 Van Brunt St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['281 Van Brunt St', 'Brooklyn, NY 11231']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3240.1407985733035},
#   {'id': 'sR60I9PI_63noBQcGoIrbw',
#    'alias': 'pause-cafe-new-york',
#    'name': 'Pause Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/T8poA0a4leJLMEeF4DxeSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pause-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 437,
#    'categories': [{'alias': 'moroccan', 'title': 'Moroccan'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72123, 'longitude': -73.98408},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '3 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3 Clinton St', 'New York, NY 10002']},
#    'phone': '+12126775415',
#    'display_phone': '(212) 677-5415',
#    'distance': 1950.7097014911349},
#   {'id': 'h7M1s9arHO5dcMf-XxzOLA',
#    'alias': 'ebb-and-flow-bakery-brooklyn',
#    'name': 'Ebb & Flow Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cp6O1BykYWqCjtlR_Kg2mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ebb-and-flow-bakery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69385416250277,
#     'longitude': -74.00085359915278},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '159 Bridge Dr',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['159 Bridge Dr', 'Brooklyn, NY 11201']},
#    'phone': '+17186189775',
#    'display_phone': '(718) 618-9775',
#    'distance': 1402.4740362013142},
#   {'id': 'YhOmfXTPu_QRNT3azAu6wA',
#    'alias': 'la-colombe-coffee-new-york-4',
#    'name': 'La Colombe Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KkxKxmMrApw1b7DMoQuhkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-colombe-coffee-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 566,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.728221, 'longitude': -73.993165},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '400 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['400 Lafayette St', 'New York, NY 10003']},
#    'phone': '+12126775834',
#    'display_phone': '(212) 677-5834',
#    'distance': 2534.3722481379123},
#   {'id': 'LfPtY7hYpOsNTaxgfny_hw',
#    'alias': 'madman-espresso-new-york-5',
#    'name': 'Madman Espresso',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lu6rhAAfl_prHds2zP5GDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/madman-espresso-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7326190878137,
#     'longitude': -73.9940478909803},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '54 University Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['54 University Pl', 'New York, NY 10003']},
#    'phone': '+13477811121',
#    'display_phone': '(347) 781-1121',
#    'distance': 3021.703153550894},
#   {'id': 'xaC_IRKUsJl2aI7ysWRIFQ',
#    'alias': 'blank-street-new-york-4',
#    'name': 'Blank Street',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LGg5qnxZYNlZPjs4fOVPaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blank-street-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71423, 'longitude': -73.96128},
#    'transactions': ['delivery'],
#    'location': {'address1': '277 Bedford Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['277 Bedford Ave', 'New York, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2947.9406347361078},
#   {'id': 'lUJNrKUCgi3gpXusZRV6jA',
#    'alias': 'claudias-coffee-shop-new-york',
#    'name': "Claudia's Coffee Shop",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vUDeA6lS03CXzmd_4Sr74g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/claudias-coffee-shop-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70235, 'longitude': -74.010508},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '125 Broad St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['125 Broad St', 'New York, NY 10004']},
#    'phone': '+12123445215',
#    'display_phone': '(212) 344-5215',
#    'distance': 1409.492395511651},
#   {'id': 'Qh5zKlMSgaKE7qTklzXFIA',
#    'alias': 'nook-brooklyn',
#    'name': 'Nook',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rb0WUM50zpAtvCJ6V5uCvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nook-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.705189, 'longitude': -73.924549},
#    'transactions': ['delivery'],
#    'location': {'address1': '45 Irving Ave',
#     'address2': 'Unit 1',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 Irving Ave', 'Unit 1', 'Brooklyn, NY 11237']},
#    'phone': '+17187342880',
#    'display_phone': '(718) 734-2880',
#    'distance': 5879.07825062191},
#   {'id': 'DoK89L5b46D8eCB_JufRdg',
#    'alias': 'nguyen-coffee-supply-brooklyn-2',
#    'name': 'Nguyen Coffee Supply',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6_P0vbHzBI-libfpUW_tDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nguyen-coffee-supply-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.6924514770508,
#     'longitude': -73.9903564453125},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Brooklyn, NY']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5201.875663549643},
#   {'id': '2q4mUi0g086UQb9cn_Naug',
#    'alias': 'out-of-office-coffee-new-york',
#    'name': 'Out of Office Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gj6JFUB1fDulOXEuaILucg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/out-of-office-coffee-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.70875, 'longitude': -73.96113},
#    'transactions': [],
#    'location': {'address1': '322 Roebling St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['322 Roebling St', 'New York, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2818.273628829679},
#   {'id': 'a9I5JJgSc2CGpq8j4PKvOg',
#    'alias': 'octavia-coffee-brooklyn',
#    'name': 'Octavia Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Bn1ZedB6fBX_fIk31veVHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/octavia-coffee-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.687138, 'longitude': -73.993819},
#    'transactions': [],
#    'location': {'address1': '198 Court St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['198 Court St', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2031.2509068361992},
#   {'id': 'S1vJPFkIxBwlPIqikvT_gQ',
#    'alias': 'irving-farm-new-york-new-york-9',
#    'name': 'Irving Farm New York',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yLnVKvOr8bv1vv0zxW3Ahg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/irving-farm-new-york-new-york-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 528,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7367161883013,
#     'longitude': -73.9868168809509},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '71 Irving Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['71 Irving Pl', 'New York, NY 10003']},
#    'phone': '+12122060707',
#    'display_phone': '(212) 206-0707',
#    'distance': 3533.830167059943},
#   {'id': 'CaYvCcWDITsD0J_4NL2TFg',
#    'alias': 'porcelain-ridgewood',
#    'name': 'Porcelain',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6fUB0L_4I6Dq4RcavrfdNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/porcelain-ridgewood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'panasian', 'title': 'Pan Asian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.702315, 'longitude': -73.901679},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '880 Woodward Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['880 Woodward Ave', 'Ridgewood, NY 11385']},
#    'phone': '+13474645267',
#    'display_phone': '(347) 464-5267',
#    'distance': 7820.925057565874},
#   {'id': 'VdAVjghEq_Zl-DDte0mjrw',
#    'alias': 'acre-brooklyn',
#    'name': 'ACRE',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7KYC_xb8ZZCOrf-SVR1Nbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/acre-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72633, 'longitude': -73.95471},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '64 Meserole Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64 Meserole Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17189549074',
#    'display_phone': '(718) 954-9074',
#    'distance': 4062.4881140396897},
#   {'id': 'xEySCBWaNz84ciNugiaVeA',
#    'alias': 'blank-street-brooklyn',
#    'name': 'Blank Street',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5LHSSvE3zkmchXOe4Vdlxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blank-street-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.717065, 'longitude': -73.962863},
#    'transactions': ['delivery'],
#    'location': {'address1': '225 Wythe Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['225 Wythe Ave', 'Brooklyn, NY 11249']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2949.403899423184},
#   {'id': 'QgJE4Jfzk7nzmRF_W_6ASA',
#    'alias': 'espresso-bar-brooklyn',
#    'name': 'Espresso Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LeLZYKiktrHtuyZs02uMzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/espresso-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.653054, 'longitude': -73.975948},
#    'transactions': [],
#    'location': {'address1': '1233 Prospect Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11218',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1233 Prospect Ave', 'Brooklyn, NY 11218']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6021.998284698845},
#   {'id': 'mxsbNvFTy6_4nSq-UWcYkw',
#    'alias': '787-coffee-new-york-3',
#    'name': '787 Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BN_v3lBNe1Uf6UmpMTgA6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/787-coffee-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 67,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.77435, 'longitude': -73.95557},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '228 E 80th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 E 80th St', 'New York, NY 10075']},
#    'phone': '+16468500234',
#    'display_phone': '(646) 850-0234',
#    'distance': 8319.242860937948},
#   {'id': 'nOCjslrdcKBQQYgD5qUs9Q',
#    'alias': 'kam-hing-coffee-shop-new-york-2',
#    'name': 'Kam Hing Coffee Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dJMMeLLjl_h03ovSk9aB7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kam-hing-coffee-shop-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 743,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71798, 'longitude': -73.99921},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '118 Baxter St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['118 Baxter St', 'New York, NY 10013']},
#    'phone': '+16465527867',
#    'display_phone': '(646) 552-7867',
#    'distance': 1454.1441795259896}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#            Restaurant          Type Price Rating         Address        Lat  \
# 0             The Elk  Coffee & Tea    $$      4  128 Charles St  40.734196
# 1         Cafe Patoro      Bakeries     $    4.5    223 Front St  40.707272
# 2          Maman Soho         Cafes    $$      4   239 Centre St  40.720280
# 3  Joe Coffee Company  Coffee & Tea     $      4    102 Hicks St  40.698673
# 4    Terremoto Coffee  Coffee & Tea    $$    4.5   328 W 15th St  40.740790
#
#          Lng                                                url  \
# 0 -74.007479  https://www.yelp.com/biz/the-elk-new-york?adju...
# 1 -74.002316  https://www.yelp.com/biz/cafe-patoro-new-york?...
# 2 -73.998400  https://www.yelp.com/biz/maman-soho-new-york?a...
# 3 -73.994358  https://www.yelp.com/biz/joe-coffee-company-br...
# 4 -74.003370  https://www.yelp.com/biz/terremoto-coffee-new-...
#
#                        ID
# 0  blX8Y6O0J4p6fXVcTRmANg
# 1  wWhZvkaFrntlSf1CWvD1Zw
# 2  DE0ROwygh-86i4s-WLp8wQ
# 3  iasVVMV9BGZy8LLNPpNVfA
# 4  9-ornJr0G_IHkl6FpcCNzw

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"coffee","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [{'id': 'vZevXSC1w27dEvXc2EHCEg',
#    'alias': 'good-thanks-cafe-new-york',
#    'name': 'Good Thanks Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bwiCKLNSXLFdUQXgd_iPXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/good-thanks-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 251,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71972, 'longitude': -73.98952},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '131A Orchard St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['131A Orchard St', 'New York, NY 10002']},
#    'phone': '+16463704426',
#    'display_phone': '(646) 370-4426',
#    'distance': 1640.2291870611812},
#   {'id': 'XSwagBljEsxG2i1rq4GEAQ',
#    'alias': 'almondine-bakery-brooklyn',
#    'name': 'Almondine Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/E3wP_njOCmZ2IW6hrWCK6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/almondine-bakery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 372,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7033174, 'longitude': -73.9912506},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '85 Water St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+17187975026',
#    'display_phone': '(718) 797-5026',
#    'distance': 348.91633855519586},
#   {'id': 'N-CTDp0mh0AY4Wn55eJajQ',
#    'alias': 'brooklyn-bean-roastery-new-york',
#    'name': 'Brooklyn Bean Roastery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jPCocQKFuxByAz1-JlxMTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-bean-roastery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7229309, 'longitude': -73.9860106},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '23 Avenue A',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23 Avenue A', 'New York, NY 10009']},
#    'phone': '+19082050018',
#    'display_phone': '(908) 205-0018',
#    'distance': 2065.874563176207},
#   {'id': 'QVFxBLZoKWNohMQYop2V9g',
#    'alias': 'city-of-saints-coffee-roasters-brooklyn',
#    'name': 'City of Saints Coffee Roasters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vQ4np8Uj7PrLWkIMN2Sgpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/city-of-saints-coffee-roasters-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 56,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7087771, 'longitude': -73.9360653},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '297 Meserole St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['297 Meserole St', 'Brooklyn, NY 11206']},
#    'phone': '+19299005282',
#    'display_phone': '(929) 900-5282',
#    'distance': 4922.089937841717},
#   {'id': 'hWjWMY5HtHg1SS7kNAdOHw',
#    'alias': 'stumptown-coffee-roasters-brooklyn-3',
#    'name': 'Stumptown Coffee Roasters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/prNm8znCx1Q7Rdp2csi1og/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stumptown-coffee-roasters-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 52,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68888, 'longitude': -73.99214},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '212B Pacific St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['212B Pacific St', 'Brooklyn, NY 11201']},
#    'phone': '+13474166741',
#    'display_phone': '(347) 416-6741',
#    'distance': 1856.0504182390582},
#   {'id': 'geBcrXRoKB_cla6SdCyVcQ',
#    'alias': '787-coffee-new-york-4',
#    'name': '787 Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/F_CEnerbCafddTK1_GG-RQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/787-coffee-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'empanadas', 'title': 'Empanadas'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72738, 'longitude': -73.98878},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '101 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['101 2nd Ave', 'New York, NY 10003']},
#    'phone': '+16468389890',
#    'display_phone': '(646) 838-9890',
#    'distance': 2484.420655747823},
#   {'id': 'JEuIdK9hzci9g_TuwfnZ_w',
#    'alias': 'society-cafe-new-york-2',
#    'name': 'Society Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NCMXf0M2Ey0ss6sHamg-lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/society-cafe-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 191,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73618, 'longitude': -73.9965962},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '52 W 13th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['52 W 13th St', 'New York, NY 10011']},
#    'phone': '+12123004525',
#    'display_phone': '(212) 300-4525',
#    'distance': 3423.0938252294222},
#   {'id': '5KzeXpVMQQoN4Xjey4nBkg',
#    'alias': 'ralphs-coffee-new-york-3',
#    'name': "Ralph's Coffee",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0_P2A53i8jpUgrdw-bWgqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ralphs-coffee-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7587008886395,
#     'longitude': -73.9781311633061},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '45 Rockefeller Plz',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10111',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 Rockefeller Plz', 'New York, NY 10111']},
#    'phone': '+12123326868',
#    'display_phone': '(212) 332-6868',
#    'distance': 6076.36169942017},
#   {'id': 'zi_TJRxi0WzADbbI6Jcz3A',
#    'alias': 'koneko-new-york-3',
#    'name': 'Koneko',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WZcJF6gmjNHO6TYv9KOfNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/koneko-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 300,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'themedcafes', 'title': 'Themed Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72044, 'longitude': -73.98412},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '26 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 Clinton St', 'New York, NY 10002']},
#    'phone': '+16463705699',
#    'display_phone': '(646) 370-5699',
#    'distance': 1874.6275271483207},
#   {'id': 'I1X2vkOkdjwTL2MiKjvovQ',
#    'alias': 'the-hideout-chai-bar-new-york',
#    'name': 'The Hideout Chai Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gvOtqU4UCoeivoa0Cx5peA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hideout-chai-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 103,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7209790412755,
#     'longitude': -73.9910624415156},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '42 Rivington St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 Rivington St', 'New York, NY 10002']},
#    'phone': '+16466495868',
#    'display_phone': '(646) 649-5868',
#    'distance': 1748.6514279160683},
#   {'id': 'r8PoVfV5vKmrLxSjbcfQLA',
#    'alias': 'squarrel-cafe-brooklyn',
#    'name': 'Squarrel Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t9rmS-Tlo1uGlZH3DbewUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/squarrel-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 69,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tabletopgames', 'title': 'Tabletop Games'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.68444, 'longitude': -73.97889},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '572 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['572 Atlantic Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17182374286',
#    'display_phone': '(718) 237-4286',
#    'distance': 2672.901832728678},
#   {'id': 'ycdDrcQAl7QXxttw9g5_qA',
#    'alias': 'all-the-kings-horses-cafe-new-york',
#    'name': "All the King's Horses Cafe",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dmqirqZtWu2R6tpJcN3LDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/all-the-kings-horses-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.728833, 'longitude': -73.980163},
#    'transactions': ['delivery'],
#    'location': {'address1': '521 E 12th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['521 E 12th St', 'New York, NY 10009']},
#    'phone': '+16316407192',
#    'display_phone': '(631) 640-7192',
#    'distance': 2856.7584304685765},
#   {'id': 'IkyRp47Jpbk_AQ35qlr-eg',
#    'alias': 'bird-and-branch-new-york',
#    'name': 'Bird & Branch',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bfE4s07iwI9J55azu9UkNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bird-and-branch-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 318,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7603099, 'longitude': -73.99087},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '359 West 45th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['359 West 45th St', 'New York, NY 10036']},
#    'phone': '+19172658444',
#    'display_phone': '(917) 265-8444',
#    'distance': 6107.008532343116},
#   {'id': '3erDg5x5OYgJjaPkV_ysLw',
#    'alias': 'birch-coffee-new-york-9',
#    'name': 'Birch Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iZbkysF2Lo3TQKYmPml9cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/birch-coffee-new-york-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 105,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7434044, 'longitude': -73.9799957},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '432 Third Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['432 Third Ave', 'New York, NY 10016']},
#    'phone': '+12126861444',
#    'display_phone': '(212) 686-1444',
#    'distance': 4385.081406686161},
#   {'id': 'sJJ1GcP663RJbVuECHN9Ww',
#    'alias': 'remi-43-new-york-2',
#    'name': 'Remi 43',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NYOIBhg76jqPmW1-61fLsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/remi-43-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'florists', 'title': 'Florists'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.750615, 'longitude': -73.971293},
#    'transactions': [],
#    'location': {'address1': '810 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['810 2nd Ave', 'New York, NY 10017']},
#    'phone': '+12129188122',
#    'display_phone': '(212) 918-8122',
#    'distance': 5383.547047446838},
#   {'id': 't4M1VX4n34eEgUWMJ7cgKw',
#    'alias': 'daily-provisions-new-york',
#    'name': 'Daily Provisions',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KOSmplXpEbiCLdRnRBkcTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daily-provisions-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 471,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73768, 'longitude': -73.9876685},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '103 E 19th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 E 19th St', 'New York, NY 10003']},
#    'phone': '+12124881505',
#    'display_phone': '(212) 488-1505',
#    'distance': 3624.11900652027},
#   {'id': 'KakiWGOfm_h5rEqOyKD7zQ',
#    'alias': 'dominique-ansel-workshop-new-york',
#    'name': 'Dominique Ansel Workshop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LWH8FfCgBGTQFQ0GEKY5yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dominique-ansel-workshop-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74368, 'longitude': -73.98658},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '17 E 27th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 E 27th St', 'New York, NY 10016']},
#    'phone': '+12129011015',
#    'display_phone': '(212) 901-1015',
#    'distance': 4311.226067535746},
#   {'id': 'DNQm5Z2fV06DwfmwH2WpsQ',
#    'alias': 'kava-social-brooklyn',
#    'name': 'Kava Social',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4uQXhZUiku0I7OdrOnFLKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kava-social-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71983, 'longitude': -73.955945},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '120 Bedford Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['120 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17185995282',
#    'display_phone': '(718) 599-5282',
#    'distance': 3607.8250492231664},
#   {'id': 'X2iGIM2ziPwVPVVFGvGR9w',
#    'alias': 'laughing-man-coffee-and-tea-new-york',
#    'name': 'Laughing Man Coffee & Tea',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EeaLlLcWSQHozJ7N_EDf0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laughing-man-coffee-and-tea-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'nonprofit', 'title': 'Community Service/Non-Profit'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.714517, 'longitude': -74.016966},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '300 Vesey St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10282',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['300 Vesey St', 'New York, NY 10282']},
#    'phone': '+12122273240',
#    'display_phone': '(212) 227-3240',
#    'distance': 2162.1043272213556},
#   {'id': 'xGkjOhRnsIQz_maA6tfhbA',
#    'alias': 'winner-brooklyn',
#    'name': 'Winner',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Zeyq20eFxenkESJ3FP9Wwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/winner-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 87,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.665709, 'longitude': -73.982375},
#    'transactions': ['delivery'],
#    'location': {'address1': '376 7th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['376 7th Ave', 'Brooklyn, NY 11215']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4531.261840506078},
#   {'id': 'FaR-Kv-0ZzgcqFW1sCnacw',
#    'alias': 'citizens-of-chelsea-new-york',
#    'name': 'Citizens of Chelsea',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kaKqbs2c0ZYK32iuTmlijw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/citizens-of-chelsea-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 804,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'australian', 'title': 'Australian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.748123, 'longitude': -74.000569},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '401 W 25th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['401 W 25th St', 'New York, NY 10001']},
#    'phone': '+16466493079',
#    'display_phone': '(646) 649-3079',
#    'distance': 4774.962454336896},
#   {'id': '7gbWC5D0y0ZTUF-WDLwuYw',
#    'alias': 'bluestone-lane-upper-east-side-café-new-york',
#    'name': 'Bluestone Lane Upper East Side Café',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/e94sjlMcyyHlMDoAQJ6BjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bluestone-lane-upper-east-side-caf%C3%A9-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 562,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7837603758071,
#     'longitude': -73.9585503779793},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1085 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1085 5th Ave', 'New York, NY 10128']},
#    'phone': '+17183746858',
#    'display_phone': '(718) 374-6858',
#    'distance': 9214.172029677738},
#   {'id': '9Ri8et0HTPwzQDg8nUZTBw',
#    'alias': 'book-club-new-york',
#    'name': 'Book Club',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iRrx6GssdaxFyCLezl0lRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/book-club-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'bookstores', 'title': 'Bookstores'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.723015, 'longitude': -73.983207},
#    'transactions': [],
#    'location': {'address1': '197 E 3rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['197 E 3rd St', 'New York, NY 10009']},
#    'phone': '+16466784160',
#    'display_phone': '(646) 678-4160',
#    'distance': 2164.5807746904625},
#   {'id': 'YGUzlo20oCGAnYnvg1b6Kg',
#    'alias': 'blue-bottle-coffee-new-york-6',
#    'name': 'Blue Bottle Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yUwj_ZsaMsUeiJJ3Cwx-2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-bottle-coffee-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 277,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7530635290641,
#     'longitude': -73.984223271164},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '54 W 40th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['54 W 40th St', 'New York, NY 10018']},
#    'phone': '+15106533394',
#    'display_phone': '(510) 653-3394',
#    'distance': 5362.506547097897},
#   {'id': 'hlrEAnfd96n-usuSwLJhOw',
#    'alias': 'kitten-coffee-brooklyn-4',
#    'name': 'Kitten Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2X8HgxMMjl46MDVuJ0AA8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kitten-coffee-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69253, 'longitude': -73.95659},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '187 Skillman St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['187 Skillman St', 'Brooklyn, NY 11205']},
#    'phone': '+17183608543',
#    'display_phone': '(718) 360-8543',
#    'distance': 3495.7045611745493},
#   {'id': '3t4VJC1vyUGk0aaem3b5ng',
#    'alias': 'ceremonia-bakeshop-brooklyn',
#    'name': 'Ceremonia Bakeshop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4QcEFcXoB6EHY8-zsj_hLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ceremonia-bakeshop-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 98,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7125, 'longitude': -73.96056},
#    'transactions': ['delivery'],
#    'location': {'address1': '743 Driggs Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['743 Driggs Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13473842212',
#    'display_phone': '(347) 384-2212',
#    'distance': 2952.0083122815354},
#   {'id': 'Vl3ticJO_730wIi5L-gcRQ',
#    'alias': 'gregorys-coffee-new-york-9',
#    'name': 'Gregorys Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/g1fQcEe_TjRDKcQ_08ZnuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gregorys-coffee-new-york-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 76,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70525, 'longitude': -74.00675},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '100 Wall St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100 Wall St', 'New York, NY 10005']},
#    'phone': '+16469187274',
#    'display_phone': '(646) 918-7274',
#    'distance': 1049.6123972408345},
#   {'id': 'gfgbbPRqVqSj_rxlSwhJhg',
#    'alias': 'black-star-bakery-and-cafe-long-island-city',
#    'name': 'Black Star Bakery & Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VW3TAoB9FGh57CMRUSBpCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-star-bakery-and-cafe-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 135,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7433494, 'longitude': -73.9580353},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2-10 50th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2-10 50th Ave', 'Long Island City, NY 11101']},
#    'phone': '+17184339189',
#    'display_phone': '(718) 433-9189',
#    'distance': 5212.243615213465},
#   {'id': 'ATQDTQu3SsCetuG-byzOFg',
#    'alias': 'cafe-gitane-brooklyn',
#    'name': 'Cafe Gitane',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OveEa94egfLWCN5HgIFrRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-gitane-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'moroccan', 'title': 'Moroccan'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7028272982236,
#     'longitude': -73.9812811999999},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '70 Hudson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70 Hudson Ave', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1134.8131488276106},
#   {'id': 'GlPJPpKvPR4d8dmcSEYpdA',
#    'alias': 'takahachi-bakery-new-york',
#    'name': 'Takahachi Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oP2xYZjbAa8akp-9CLmiVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/takahachi-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 947,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71393, 'longitude': -74.00822},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '25 Murray St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 Murray St', 'New York, NY 10007']},
#    'phone': '+12127915550',
#    'display_phone': '(212) 791-5550',
#    'distance': 1511.7020935512141},
#   {'id': 'yBBKdMVbGjSPAgxhDT8zMg',
#    'alias': 'early-brooklyn',
#    'name': 'Early',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EJbftTxGbXfB04TMsz0gsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/early-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 105,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.732151, 'longitude': -73.9548187},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '967 Manhattan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['967 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183836963',
#    'display_phone': '(718) 383-6963',
#    'distance': 4459.102478766493},
#   {'id': 'bmW4pD_san3xZrZQdHI4Lw',
#    'alias': 'blank-street-brooklyn-2',
#    'name': 'Blank Street',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/riFcxoDYt079l4p6vHLvDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blank-street-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68416, 'longitude': -73.98357},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '253 Bergen St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253 Bergen St', 'Brooklyn, NY 11217']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2534.1737092218304},
#   {'id': '2l0dBpaoPVQ1JwD7CaQu-w',
#    'alias': 'madman-espresso-new-york-4',
#    'name': 'Madman Espresso',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NBukSq7Yo6RM1KaPxMPZZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/madman-espresso-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 275,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.752132504861095,
#     'longitude': -73.99152656670547},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '234 W 35th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10123',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['234 W 35th St', 'New York, NY 10123']},
#    'phone': '+12125647505',
#    'display_phone': '(212) 564-7505',
#    'distance': 5196.654872525019},
#   {'id': 'nMuagHWRIf7FGwTLouXJWg',
#    'alias': '787-coffee-new-york-8',
#    'name': '787 Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ADxbPD842ifA9nrjwwMUJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/787-coffee-new-york-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.732317383599764,
#     'longitude': -73.98396565978786},
#    'transactions': [],
#    'location': {'address1': '319 E 14th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['319 E 14th St', 'New York, NY 10003']},
#    'phone': '+16465904241',
#    'display_phone': '(646) 590-4241',
#    'distance': 3112.265475775727},
#   {'id': 'NfuHyyXieKyq0vScjHWATg',
#    'alias': 'east-one-coffee-roasters-brooklyn',
#    'name': 'East One Coffee Roasters',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AVGtInJbOaazEKB5P_AyJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/east-one-coffee-roasters-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 175,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6812982171111,
#     'longitude': -73.9966663404755},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '384 Court St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['384 Court St', 'Brooklyn, NY 11231']},
#    'phone': '+13479874919',
#    'display_phone': '(347) 987-4919',
#    'distance': 2692.425882403761},
#   {'id': '3blPn5WuFEPnDppFgkPoMQ',
#    'alias': 'coffee-project-new-york-chelsea-new-york-3',
#    'name': 'Coffee Project New York | Chelsea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OkEic3RQEw_eQ83ZEK-Emg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffee-project-new-york-chelsea-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.741816, 'longitude': -73.997095},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '155 7th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['155 7th Ave', 'New York, NY 10011']},
#    'phone': '+19173883399',
#    'display_phone': '(917) 388-3399',
#    'distance': 4040.5584861596785},
#   {'id': 'ORU3eWuOMu8Qms8VcgrhUw',
#    'alias': 'the-hive-hoboken',
#    'name': 'The Hive',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Hb5t3ur8jH0RWJws7RGeGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hive-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74934171665144,
#     'longitude': -74.03029777771},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1000 Park Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1000 Park Ave', 'Hoboken, NJ 07030']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5747.177898842802},
#   {'id': 'bHY5-dzDzzTw6Xl0duONVQ',
#    'alias': 'interlude-coffee-and-tea-new-york',
#    'name': 'Interlude Coffee & Tea',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rZx1kvYYswddTm4NTweuUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/interlude-coffee-and-tea-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72107, 'longitude': -74.00868},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '145 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['145 Hudson St', 'New York, NY 10013']},
#    'phone': '+12122192067',
#    'display_phone': '(212) 219-2067',
#    'distance': 2121.4748459527},
#   {'id': 'lCyiAsEUv8saCamKEU9KUQ',
#    'alias': 'maman-hudson-new-york-4',
#    'name': 'Maman - Hudson',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8MSxpfW6bQLDAHyFZBGafg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maman-hudson-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72381, 'longitude': -74.00836},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '205 Hudson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['205 Hudson St', 'New York, NY 10013']},
#    'phone': '+12122192436',
#    'display_phone': '(212) 219-2436',
#    'distance': 2351.9767420289218},
#   {'id': 'Toe219x40Dtq71_HOQ1OOg',
#    'alias': 'la-colombe-coffee-new-york',
#    'name': 'La Colombe Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BM9mJkpuaMC_nAmNj9R9pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-colombe-coffee-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 363,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.719941, 'longitude': -74.003781},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '319 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['319 Church St', 'New York, NY 10013']},
#    'phone': '+12123431515',
#    'display_phone': '(212) 343-1515',
#    'distance': 1799.3563645487764},
#   {'id': '9791rZU0PXGcYudSlVwiAA',
#    'alias': 'oslo-coffee-roasters-brooklyn-3',
#    'name': 'Oslo Coffee Roasters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zJzzv82dniVeURSuSq2tCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oslo-coffee-roasters-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 122,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7130749, 'longitude': -73.9621875},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '328 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['328 Bedford Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17187820332',
#    'display_phone': '(718) 782-0332',
#    'distance': 2836.034072955392},
#   {'id': 'OQOr0DE1HtSNfxO5_mwfFg',
#    'alias': 'five-and-dime-new-york',
#    'name': 'Five & Dime',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/au-O0E8ULJ4p-GNk2qwMGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/five-and-dime-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 100,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7126429155284,
#     'longitude': -74.0080474702053},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '8 Park Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8 Park Pl', 'New York, NY 10007']},
#    'phone': '+12124333463',
#    'display_phone': '(212) 433-3463',
#    'distance': 1418.5778626669671},
#   {'id': '1RRD6Ub4QEW9ZeyaBMx5jQ',
#    'alias': 'mountain-province-brooklyn',
#    'name': 'Mountain Province',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DzRd6_P0_a1zc-4lTCjstA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mountain-province-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 269,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'filipino', 'title': 'Filipino'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7075228032172,
#     'longitude': -73.9503787374344},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '9 Meserole St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Meserole St', 'Brooklyn, NY 11206']},
#    'phone': '+17183877030',
#    'display_phone': '(718) 387-7030',
#    'distance': 3708.8603587337498},
#   {'id': '1aD88qNRb08LGBkl84GQTA',
#    'alias': 'little-collins-new-york-3',
#    'name': 'Little Collins',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JIaDv0kxB4z8bIjItcGMHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-collins-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 868,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75233, 'longitude': -73.97353},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '708 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['708 3rd Ave', 'New York, NY 10017']},
#    'phone': '+12123081969',
#    'display_phone': '(212) 308-1969',
#    'distance': 5507.334764233976},
#   {'id': '7rxg-tWPc1jK7Cikn5R86g',
#    'alias': 'hi-collar-new-york-2',
#    'name': 'Hi-Collar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6DAtn_pu8hX79LB3sSlFtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hi-collar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 641,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729564, 'longitude': -73.98786},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '231 E 9th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 E 9th St', 'New York, NY 10003']},
#    'phone': '+12127777018',
#    'display_phone': '(212) 777-7018',
#    'distance': 2736.177785571269},
#   {'id': 'MKYhiSeXjahxh9O4Gqnimw',
#    'alias': 'grace-street-new-york',
#    'name': 'Grace Street',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sGpzBlU62QQfT9H1Z-yzvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grace-street-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2742,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'shavedice', 'title': 'Shaved Ice'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7478576793883,
#     'longitude': -73.9865590631962},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '17 W 32nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 W 32nd St', 'New York, NY 10001']},
#    'phone': '+19177452125',
#    'display_phone': '(917) 745-2125',
#    'distance': 4760.904253854418},
#   {'id': '7a6aiWA3UCEHUKyTRRkESQ',
#    'alias': 'caffe-vita-bushwick-brooklyn',
#    'name': 'Caffe Vita Bushwick',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qeLt0Myqcz0sjJumTvlx2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-vita-bushwick-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70879, 'longitude': -73.92521},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '576 Johnson Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['576 Johnson Ave', 'Brooklyn, NY 11237']},
#    'phone': '+19292959328',
#    'display_phone': '(929) 295-9328',
#    'distance': 5834.546523386762},
#   {'id': 'yicBRA8X7urJyKn6aF2wzw',
#    'alias': 'sullivan-street-bakery-new-york-4',
#    'name': 'Sullivan Street Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/C5EOOhqnVAhEA9ay3zwXUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sullivan-street-bakery-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 282,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7474103457198,
#     'longitude': -74.0005904621599},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '236 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['236 9th Ave', 'New York, NY 10001']},
#    'phone': '+12129295900',
#    'display_phone': '(212) 929-5900',
#    'distance': 4684.439691978602},
#   {'id': '_lrhk3UtwAqHpVvHTTSlCg',
#    'alias': '787-coffee-new-york-6',
#    'name': '787 Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L8aGW184SZAhlINQxL3kQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/787-coffee-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'empanadas', 'title': 'Empanadas'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.742233, 'longitude': -73.983147},
#    'transactions': ['delivery'],
#    'location': {'address1': '100 Lexington Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100 Lexington Ave', 'New York, NY 10016']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4198.895106261386},
#   {'id': 'Wv6jzavopKvQT7RqeXttKA',
#    'alias': 'le-petit-monstre-brooklyn',
#    'name': 'Le Petit Monstre',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NtqFfVROVxVmJN8k-hVcYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-petit-monstre-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'gardening', 'title': 'Nurseries & Gardening'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.696311154904876,
#     'longitude': -73.96770130204715},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '82 Washington Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['82 Washington Ave', 'Brooklyn, NY 11205']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2461.0231986129706}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#                        Restaurant               Type Price Rating  \
# 0                Good Thanks Cafe              Cafes    $$    4.5
# 1                Almondine Bakery           Bakeries    $$      4
# 2          Brooklyn Bean Roastery  Coffee Roasteries
# 3  City of Saints Coffee Roasters       Coffee & Tea     $    4.5
# 4       Stumptown Coffee Roasters  Coffee Roasteries   $$$      4
#
#            Address        Lat        Lng  \
# 0  131A Orchard St  40.719720 -73.989520
# 1      85 Water St  40.703317 -73.991251
# 2      23 Avenue A  40.722931 -73.986011
# 3  297 Meserole St  40.708777 -73.936065
# 4  212B Pacific St  40.688880 -73.992140
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/good-thanks-cafe-new-...  vZevXSC1w27dEvXc2EHCEg
# 1  https://www.yelp.com/biz/almondine-bakery-broo...  XSwagBljEsxG2i1rq4GEAQ
# 2
# 3  https://www.yelp.com/biz/city-of-saints-coffee...  QVFxBLZoKWNohMQYop2V9g
# 4  https://www.yelp.com/biz/stumptown-coffee-roas...  hWjWMY5HtHg1SS7kNAdOHw

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                     Restaurant                  Type Rating Price  \
# 0                 Society Cafe        American (New)      4    $$
# 1         Citizens Of Gramercy            Australian      4    $$
# 2         Kam Hing Coffee Shop              Bakeries    4.5     $
# 3                       Peck's              Bakeries      4    $$
# 4                       Butler              Bakeries    4.5    $$
# 5            Ebb & Flow Bakery              Bakeries
# 6    The Lazy Llama Coffee Bar              Bakeries    4.5    $$
# 7             Almondine Bakery              Bakeries      4    $$
# 8     Dominique Ansel Workshop              Bakeries    4.5    $$
# 9           Ceremonia Bakeshop              Bakeries
# 10    Black Star Bakery & Cafe              Bakeries      4     $
# 11            Takahachi Bakery              Bakeries      4    $$
# 12                      Butler              Bakeries
# 13                 Cafe Patoro              Bakeries    4.5     $
# 14      Sullivan Street Bakery              Bakeries    3.5    $$
# 15           Mountain Province              Bakeries    4.5     $
# 16                    Usagi NY            Bookstores    4.5    $$
# 17                   Book Club            Bookstores
# 18                      Koneko    Breakfast & Brunch    4.5    $$
# 19            Hole In The Wall    Breakfast & Brunch    4.5    $$
# 20                        ACRE    Breakfast & Brunch
# 21                      Banter    Breakfast & Brunch    4.5    $$
# 22                    Bee Cafe            Bubble Tea    4.5     $
# 23                Qahwah House                 Cafes      5     $
# 24            Good Thanks Cafe                 Cafes    4.5    $$
# 25                  Maman Soho                 Cafes      4    $$
# 26                Espresso Bar                 Cafes
# 27                   Porcelain                 Cafes
# 28                        Nook                 Cafes
# 29                    Devocion                 Cafes      4     $
# ..                         ...                   ...    ...   ...
# 170             Vineapple Cafe          Coffee & Tea    4.5    $$
# 171             Poetica Coffee          Coffee & Tea
# 172               Blank Street          Coffee & Tea
# 173             AMERICANO CAFE          Coffee & Tea
# 174   Black Star Bakery & Cafe          Coffee & Tea
# 175          Everyman Espresso          Coffee & Tea      4    $$
# 176           Brooklyn Kolache          Coffee & Tea    4.5     $
# 177             Matto Espresso          Coffee & Tea    4.5     $
# 178      The Little Sweet Cafe          Coffee & Tea    4.5    $$
# 179              Café Integral          Coffee & Tea      4    $$
# 180             Le Café Coffee          Coffee & Tea    4.5    $$
# 181         Harney & Sons SoHo          Coffee & Tea    4.5    $$
# 182                     Abraço     Coffee Roasteries    4.5    $$
# 183   East One Coffee Roasters     Coffee Roasteries      4    $$
# 184     Gotham Coffee Roasters     Coffee Roasteries    4.5    $$
# 185       Oslo Coffee Roasters     Coffee Roasteries
# 186                 Sey Coffee     Coffee Roasteries    4.5     $
# 187       Nguyen Coffee Supply     Coffee Roasteries
# 188  Stumptown Coffee Roasters     Coffee Roasteries      4   $$$
# 189     Brooklyn Bean Roastery     Coffee Roasteries
# 190       Irving Farm New York     Coffee Roasteries    3.5    $$
# 191            Kodawari Coffee     Coffee Roasteries      4    $$
# 192                    Alimama              Desserts    4.5    $$
# 193                     Burrow              Desserts    4.5     $
# 194                 Homecoming              Florists      4    $$
# 195        La Grande Boucherie                French    4.5   $$$
# 196                  Hi-Collar              Japanese      4    $$
# 197                Cafe Gitane              Moroccan
# 198                 Pause Cafe              Moroccan    4.5     $
# 199           Le Petit Monstre  Patisserie/Cake Shop
#
#                Address        Lat        Lng  \
# 0         52 W 13th St  40.736180 -73.996596
# 1          362 2nd Ave  40.736740 -73.981520
# 2        118 Baxter St  40.717980 -73.999210
# 3      455A Myrtle Ave  40.693489 -73.967376
# 4          95 S 5th St  40.711767 -73.964692
# 5        159 Bridge Dr  40.693854 -74.000854
# 6      72 E 1st Street  40.723506 -73.988733
# 7          85 Water St  40.703317 -73.991251
# 8         17 E 27th St  40.743680 -73.986580
# 9       743 Driggs Ave  40.712500 -73.960560
# 10       2-10 50th Ave  40.743349 -73.958035
# 11        25 Murray St  40.713930 -74.008220
# 12         40 Water St  40.703267 -73.992242
# 13        223 Front St  40.707272 -74.002316
# 14         236 9th Ave  40.747410 -74.000590
# 15       9 Meserole St  40.707523 -73.950379
# 16     163 Plymouth St  40.703830 -73.986910
# 17        197 E 3rd St  40.723015 -73.983207
# 18       26 Clinton St  40.720440 -73.984120
# 19         15 Cliff St  40.708370 -74.005630
# 20     64 Meserole Ave  40.726330 -73.954710
# 21     169 Sullivan St  40.727870 -74.001100
# 22      60-11 39th Ave  40.747530 -73.903080
# 23     162 Bedford Ave  40.718563 -73.957130
# 24     131A Orchard St  40.719720 -73.989520
# 25       239 Centre St  40.720280 -73.998400
# 26   1233 Prospect Ave  40.653054 -73.975948
# 27    880 Woodward Ave  40.702315 -73.901679
# 28       45 Irving Ave  40.705189 -73.924549
# 29        25 E 20th St  40.739040 -73.989160
# ..                 ...        ...        ...
# 170    71 Pineapple St  40.698297 -73.993076
# 171       251 Smith St  40.683249 -73.992623
# 172   236 Lafayette St  40.722560 -73.997180
# 173     7 Navy Pier Ct  40.629624 -74.073889
# 174      241 E 24th St  40.738951 -73.980784
# 175      136 E 13th St  40.732785 -73.988329
# 176     520 Dekalb Ave  40.690791 -73.955648
# 177      293 Mercer St  40.730250 -73.993970
# 178        77B Hoyt St  40.688142 -73.986732
# 179   149 Elizabeth St  40.720384 -73.995213
# 180        7 E 14th St  40.735746 -73.992874
# 181      433 Broome St  40.721440 -73.999401
# 182        81 E 7th St  40.727365 -73.986167
# 183       384 Court St  40.681298 -73.996666
# 184       23 W 19th St  40.739750 -73.992690
# 185      236 W 10th St  40.733772 -74.005471
# 186      18 Grattan St  40.705320 -73.932400
# 187                     40.692451 -73.990356
# 188    212B Pacific St  40.688880 -73.992140
# 189        23 Avenue A  40.722931 -73.986011
# 190       71 Irving Pl  40.736716 -73.986817
# 191     100 Forsyth St  40.718302 -73.992771
# 192      89A Bayard St  40.715863 -73.999285
# 193          68 Jay St  40.702722 -73.986888
# 194    107 Franklin St  40.729579 -73.957801
# 195      145 W 53rd St  40.762627 -73.980841
# 196       231 E 9th St  40.729564 -73.987860
# 197      70 Hudson Ave  40.702827 -73.981281
# 198       3 Clinton St  40.721230 -73.984080
# 199  82 Washington Ave  40.696311 -73.967701
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/society-cafe-new-york...  JEuIdK9hzci9g_TuwfnZ_w
# 1    https://www.yelp.com/biz/citizens-of-gramercy-...  yCfjoS6XfnP8hd9zWjME7Q
# 2    https://www.yelp.com/biz/kam-hing-coffee-shop-...  nOCjslrdcKBQQYgD5qUs9Q
# 3    https://www.yelp.com/biz/pecks-new-york?adjust...  DA1hijID0q6D6Ouch17v7w
# 4    https://www.yelp.com/biz/butler-brooklyn?adjus...  SWRz34fmNEDPcrngJMMo7Q
# 5
# 6    https://www.yelp.com/biz/the-lazy-llama-coffee...  VHORZQg5A3YNBptRN92QGg
# 7    https://www.yelp.com/biz/almondine-bakery-broo...  XSwagBljEsxG2i1rq4GEAQ
# 8    https://www.yelp.com/biz/dominique-ansel-works...  KakiWGOfm_h5rEqOyKD7zQ
# 9
# 10   https://www.yelp.com/biz/black-star-bakery-and...  gfgbbPRqVqSj_rxlSwhJhg
# 11   https://www.yelp.com/biz/takahachi-bakery-new-...  GlPJPpKvPR4d8dmcSEYpdA
# 12
# 13   https://www.yelp.com/biz/cafe-patoro-new-york?...  wWhZvkaFrntlSf1CWvD1Zw
# 14   https://www.yelp.com/biz/sullivan-street-baker...  yicBRA8X7urJyKn6aF2wzw
# 15   https://www.yelp.com/biz/mountain-province-bro...  1RRD6Ub4QEW9ZeyaBMx5jQ
# 16   https://www.yelp.com/biz/usagi-ny-dumbo-7?adju...  vijwGDNrPBJHEG7_DsjZNw
# 17
# 18   https://www.yelp.com/biz/koneko-new-york-3?adj...  zi_TJRxi0WzADbbI6Jcz3A
# 19   https://www.yelp.com/biz/hole-in-the-wall-new-...  rQpO1Eie_zmeAOQ9s-T0sQ
# 20
# 21   https://www.yelp.com/biz/banter-new-york?adjus...  Zc7Jbuwe3XO-EaVXIh_TYQ
# 22   https://www.yelp.com/biz/bee-cafe-woodside?adj...  VLMxyAe_l9vvyFd5vEPZ4g
# 23   https://www.yelp.com/biz/qahwah-house-brooklyn...  kpxXi23lUQkeJQH-2BtzDw
# 24   https://www.yelp.com/biz/good-thanks-cafe-new-...  vZevXSC1w27dEvXc2EHCEg
# 25   https://www.yelp.com/biz/maman-soho-new-york?a...  DE0ROwygh-86i4s-WLp8wQ
# 26
# 27
# 28
# 29   https://www.yelp.com/biz/devocion-new-york?adj...  S9T8kG8xTPaQ1PxLE_VdYg
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/vineapple-cafe-brookl...  xxiV3-0t_gO1Ojo3xo73TQ
# 171
# 172
# 173
# 174
# 175  https://www.yelp.com/biz/everyman-espresso-new...  aljEnhQthQwifG971tY1mA
# 176  https://www.yelp.com/biz/brooklyn-kolache-broo...  4VEgZ7aVUt6oKw8KmXj-jQ
# 177  https://www.yelp.com/biz/matto-espresso-new-yo...  WBQPnEuUm8BfAylBov_MGg
# 178  https://www.yelp.com/biz/the-little-sweet-cafe...  1fDtQij01Mk92ZTGn6WHjg
# 179  https://www.yelp.com/biz/caf%C3%A9-integral-ne...  moo7CuKs4djrUCMHs4G_uQ
# 180  https://www.yelp.com/biz/le-caf%C3%A9-coffee-n...  bMepacmKDTwCdHJAU860bQ
# 181  https://www.yelp.com/biz/harney-and-sons-soho-...  OiqGAhC5EQXb1CaNxxvfBQ
# 182  https://www.yelp.com/biz/abra%C3%A7o-new-york-...  -ogb8JWn8dvgzZA656EANA
# 183  https://www.yelp.com/biz/east-one-coffee-roast...  NfuHyyXieKyq0vScjHWATg
# 184  https://www.yelp.com/biz/gotham-coffee-roaster...  STBNV2yArITdLJ1k5hfBig
# 185
# 186  https://www.yelp.com/biz/sey-coffee-brooklyn?a...  bmSYtYRPf6ycx-4xWhbHFg
# 187
# 188  https://www.yelp.com/biz/stumptown-coffee-roas...  hWjWMY5HtHg1SS7kNAdOHw
# 189
# 190  https://www.yelp.com/biz/irving-farm-new-york-...  S1vJPFkIxBwlPIqikvT_gQ
# 191  https://www.yelp.com/biz/kodawari-coffee-new-y...  I_f_KhuRonsQiQ1llhqVHQ
# 192  https://www.yelp.com/biz/alimama-new-york-3?ad...  oDRZt37ROqadlK3-VI0PfQ
# 193  https://www.yelp.com/biz/burrow-brooklyn?adjus...  nyxmTe-It-tzfagvjkge1g
# 194  https://www.yelp.com/biz/homecoming-brooklyn?a...  gJD6DsPQUYHVVCTHLB_nJw
# 195  https://www.yelp.com/biz/la-grande-boucherie-n...  DGhWO1sUWydVeR5j5ZZaMw
# 196  https://www.yelp.com/biz/hi-collar-new-york-2?...  7rxg-tWPc1jK7Cikn5R86g
# 197
# 198  https://www.yelp.com/biz/pause-cafe-new-york?a...  sR60I9PI_63noBQcGoIrbw
# 199
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_Coffee.csv')
