# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"bagel","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': 'VrCCr45dhN-RRM107iptdg',
#    'alias': 'russ-and-daughters-new-york',
#    'name': 'Russ & Daughters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/u1URnR-RrNo06dV3zWISog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/russ-and-daughters-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2373,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'smokehouse', 'title': 'Smokehouse'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.722589, 'longitude': -73.9882828294139},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '179 E Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['179 E Houston St', 'New York, NY 10002']},
#    'phone': '+12124754880',
#    'display_phone': '(212) 475-4880',
#    'distance': 1972.4966482145887},
#   {'id': 'j1S3NUrkB3BVT49n_e76NQ',
#    'alias': 'best-bagel-and-coffee-new-york',
#    'name': 'Best Bagel & Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9-8DVzhwfzFS5GUCq3O6NA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/best-bagel-and-coffee-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3573,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7522683, 'longitude': -73.9910861},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '225 W 35th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['225 W 35th St', 'New York, NY 10001']},
#    'phone': '+12125644409',
#    'display_phone': '(212) 564-4409',
#    'distance': 5213.5315009761325},
#   {'id': 'c3eMI4_o4dPDDhPV_ibBYQ',
#    'alias': 'ess-a-bagel-new-york',
#    'name': 'Ess-a-Bagel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KJliJ0mJDcTGVi36f30L7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ess-a-bagel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3786,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.756300559255,
#     'longitude': -73.9703701025162},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '831 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['831 3rd Ave', 'New York, NY 10022']},
#    'phone': '+12129801010',
#    'display_phone': '(212) 980-1010',
#    'distance': 6003.433036669106},
#   {'id': 'pb_ryc8FYHpUPV56eV2Eyg',
#    'alias': 'brooklyn-bagel-and-coffee-company-new-york-2',
#    'name': 'Brooklyn Bagel & Coffee Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hUTrABJ4rEdz9YvjFTTWFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-bagel-and-coffee-company-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1549,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.746183, 'longitude': -73.997642},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '286 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['286 8th Ave', 'New York, NY 10001']},
#    'phone': '+12129242824',
#    'display_phone': '(212) 924-2824',
#    'distance': 4538.650359115514},
#   {'id': 'oi39VAwo4-KGm_gSkWPCsQ',
#    'alias': 'tompkins-square-bagels-avenue-a-new-york',
#    'name': 'Tompkins Square Bagels - Avenue A',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qCxRtPN2ogXLPv0ly5Xn7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tompkins-square-bagels-avenue-a-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1205,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72823, 'longitude': -73.9823},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '165 Avenue A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['165 Avenue A', 'New York, NY 10009']},
#    'phone': '+16463516520',
#    'display_phone': '(646) 351-6520',
#    'distance': 2727.8478104386327},
#   {'id': 'foO2N-TrdPBO-dFn6M35TA',
#    'alias': 'brooklyn-bagel-and-coffee-company-new-york-8',
#    'name': 'Brooklyn Bagel & Coffee Company',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2ssnQhBvQsZfpM1qZn_Ihg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-bagel-and-coffee-company-new-york-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 150,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73104, 'longitude': -73.9932199},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '63 E 8th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63 E 8th St', 'New York, NY 10003']},
#    'phone': '+12124773070',
#    'display_phone': '(212) 477-3070',
#    'distance': 2846.0313901268783},
#   {'id': 'Gpc2-sPCXlIQUrkfi4bpzw',
#    'alias': 'court-street-bagels-brooklyn',
#    'name': 'Court Street Bagels',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2WYCmVkvsh4hxt0Yx-Js6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/court-street-bagels-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 236,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68804, 'longitude': -73.99301},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '181 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['181 Court St', 'Brooklyn, NY 11201']},
#    'phone': '+17186243972',
#    'display_phone': '(718) 624-3972',
#    'distance': 1939.7400173390035},
#   {'id': 'EhqrXqxMb70I1NrnMAGJMA',
#    'alias': 'the-bagel-store-brooklyn-19',
#    'name': 'The Bagel Store',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GUBQg9wLLQV55xJmAXXnAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bagel-store-brooklyn-19?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.680582, 'longitude': -73.977476},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '69 5th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['69 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+13475294301',
#    'display_phone': '(347) 529-4301',
#    'distance': 3106.996778750043},
#   {'id': 'SCornvTSCMQ2SvWGq8Z_Mw',
#    'alias': 'ess-a-bagel-new-york-5',
#    'name': 'Ess-A-Bagel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sUDmVXOYYUBMMxWBpa6DDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ess-a-bagel-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 893,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7342019611776,
#     'longitude': -73.9801854769702},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '324 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['324 1st Ave', 'New York, NY 10009']},
#    'phone': '+12122602252',
#    'display_phone': '(212) 260-2252',
#    'distance': 3423.385220350828},
#   {'id': 'GLf8_rOnkszkGmPAiMzO9Q',
#    'alias': 'bread-and-spread-dumbo',
#    'name': 'Bread & Spread',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SMT03iEizZOtc_Cwe5wQbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bread-and-spread-dumbo?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 166,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7025945, 'longitude': -73.9869119},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '151 Front St',
#     'address2': None,
#     'address3': '',
#     'city': 'Dumbo',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['151 Front St', 'Dumbo, NY 11201']},
#    'phone': '+17186252220',
#    'display_phone': '(718) 625-2220',
#    'distance': 698.2848912388458},
#   {'id': 'Ys9iYSjuFDpZj7B1X07v5g',
#    'alias': 'liberty-bagels-midtown-new-york-3',
#    'name': 'Liberty Bagels Midtown',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UfpS3nudd0Rwt_9WRqUbZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/liberty-bagels-midtown-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 697,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75255, 'longitude': -73.99249},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '260 W 35th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['260 W 35th St', 'New York, NY 10001']},
#    'phone': '+12122791124',
#    'display_phone': '(212) 279-1124',
#    'distance': 5233.684935669175},
#   {'id': 'lQ7H-COT5duZQQ0XqGFPDg',
#    'alias': 'smith-st-bagels-brooklyn',
#    'name': 'Smith St Bagels',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-k215OjGfCB5wrVIwg2qJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/smith-st-bagels-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 417,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.684805, 'longitude': -73.992051},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '202 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['202 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17188586000',
#    'display_phone': '(718) 858-6000',
#    'distance': 2301.5368040741914},
#   {'id': '7HP9pH30Ha7xJsxsdVJBrg',
#    'alias': 'bagelsmith-brooklyn',
#    'name': 'Bagelsmith',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NxNWiASpH_17AbOwxPeIhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagelsmith-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 524,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.717584, 'longitude': -73.957854},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '189 Bedford Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['189 Bedford Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17182187414',
#    'display_phone': '(718) 218-7414',
#    'distance': 3354.8424626223364},
#   {'id': 'n8AfzNmqZUfXZzHtieea_A',
#    'alias': 'murrays-bagels-new-york',
#    'name': "Murray's Bagels",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/C8xnSQ3GC70JnnV2YmejNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/murrays-bagels-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 884,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.736339, 'longitude': -73.997184},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '500 Ave Of The Americas',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['500 Ave Of The Americas', 'New York, NY 10011']},
#    'phone': '+12124622830',
#    'display_phone': '(212) 462-2830',
#    'distance': 3440.781664896575},
#   {'id': 's-Fg5eHqv4VCAn2ANkHiZA',
#    'alias': 'leos-bagels-new-york',
#    'name': "Leo's Bagels",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zuUz6o6T7ARojYvy-jSvYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/leos-bagels-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 951,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7048928861349,
#     'longitude': -74.0097218048184},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '3 Hanover Sq',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3 Hanover Sq', 'New York, NY 10005']},
#    'phone': '+12127854700',
#    'display_phone': '(212) 785-4700',
#    'distance': 1301.9860989541098},
#   {'id': 'PiAU4BCl5d9P-NWDvkNY4A',
#    'alias': 'bergen-bagels-brooklyn-2',
#    'name': 'Bergen Bagels',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/N7Dt1ABxuFqdsqPgFizVRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bergen-bagels-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 398,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.680987, 'longitude': -73.974796},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '473 Bergen St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['473 Bergen St', 'Brooklyn, NY 11217']},
#    'phone': '+17187897600',
#    'display_phone': '(718) 789-7600',
#    'distance': 3177.7688173562083},
#   {'id': 'BIFbVuIDJFS_2u_8vJxnwA',
#    'alias': 'tompkins-square-bagels-2nd-ave-new-york',
#    'name': 'Tompkins Square Bagels -  2nd Ave',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3oBvfk31EQ5QeJAtgyh3mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tompkins-square-bagels-2nd-ave-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 279,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73064, 'longitude': -73.98578},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '184 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['184 2nd Ave', 'New York, NY 10003']},
#    'phone': '+19174727639',
#    'display_phone': '(917) 472-7639',
#    'distance': 2892.7733862279747},
#   {'id': 'rdgOCFe30sIaAo6tkXkJ-A',
#    'alias': 'shelskys-of-brooklyn-appetizing-and-delicateseen-brooklyn',
#    'name': "Shelsky's of Brooklyn Appetizing & Delicateseen",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/06dxPBihxeiaLe8Ev_wfiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shelskys-of-brooklyn-appetizing-and-delicateseen-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 210,
#    'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.689386, 'longitude': -73.9922942},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '141 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['141 Court St', 'Brooklyn, NY 11201']},
#    'phone': '+17188558817',
#    'display_phone': '(718) 855-8817',
#    'distance': 1793.5970196863084},
#   {'id': '4OTDu-sPa5d88gnF2sfWKQ',
#    'alias': 'bagel-pub-brooklyn-5',
#    'name': 'Bagel Pub',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7_8bSHPTJ_HdyAHPikaAhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagel-pub-brooklyn-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6757549, 'longitude': -73.9743022},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '57 7th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['57 7th Ave', 'Brooklyn, NY 11217']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3706.7405929050105},
#   {'id': 'U43uuWwSyH95gXsUhejd4w',
#    'alias': 'la-bagel-delight-at-dumbo-brooklyn',
#    'name': 'La Bagel Delight at Dumbo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/M-UVf8NcMuQD3q1W4edHeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-bagel-delight-at-dumbo-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 152,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70235, 'longitude': -73.98873},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '104 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['104 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17186252235',
#    'display_phone': '(718) 625-2235',
#    'distance': 582.5113568595275},
#   {'id': 'JV5oa5-KGdiWnqrKPoxSug',
#    'alias': 'absolute-bagels-new-york',
#    'name': 'Absolute Bagels',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GjaYFLA8G7IEFiFLKgL_Ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/absolute-bagels-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1489,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.80251, 'longitude': -73.96745},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '2788 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2788 Broadway', 'New York, NY 10025']},
#    'phone': '+12129322052',
#    'display_phone': '(212) 932-2052',
#    'distance': 11028.952385526974},
#   {'id': '2buX7P8YIqcrHSKtqwm92g',
#    'alias': 'kossars-new-york',
#    'name': "Kossar's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/U9sFtQ8ThrcfSlKCYQcCuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kossars-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 566,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71641, 'longitude': -73.98879},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '367 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['367 Grand St', 'New York, NY 10002']},
#    'phone': '+12124734810',
#    'display_phone': '(212) 473-4810',
#    'distance': 1303.8580395433075},
#   {'id': 'mpCQzQAT4Rken3mFBlwqLw',
#    'alias': 'bagels-on-the-square-new-york',
#    'name': 'Bagels on the Square',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xVap3sMcWZAWVfdv9U9MJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagels-on-the-square-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 458,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.730604, 'longitude': -74.002152},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '7 Carmine St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 Carmine St', 'New York, NY 10014']},
#    'phone': '+12126913041',
#    'display_phone': '(212) 691-3041',
#    'distance': 2874.8982503201637},
#   {'id': 'EfhCZ3CiZeVzFt5E5N0n3w',
#    'alias': 'bergen-bagels-brooklyn-3',
#    'name': 'Bergen Bagels',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IQF5WV-6iNb5XHwRj1fKHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bergen-bagels-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 242,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.69354, 'longitude': -73.96356},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '536 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['536 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17187899300',
#    'display_phone': '(718) 789-9300',
#    'distance': 2927.3216027732283},
#   {'id': 'u9zVZH0liQu9skIz1kGrMA',
#    'alias': 'heavens-hot-bagel-new-york',
#    'name': "Heaven's Hot Bagel",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LO0eln9shgcmyARWzLnb_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heavens-hot-bagel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 212,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72131, 'longitude': -73.98436},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '283 E Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['283 E Houston St', 'New York, NY 10002']},
#    'phone': '+12124207566',
#    'display_phone': '(212) 420-7566',
#    'distance': 1955.496674888556},
#   {'id': 'Fx_zqaXVgc8BzwIfcbEKkw',
#    'alias': 'bos-bagels-new-york',
#    'name': "BO's Bagels",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Xus98i_PNynBvRzBiDvJUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bos-bagels-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 381,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.804197, 'longitude': -73.954091},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '235 W 116th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10026',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['235 W 116th St', 'New York, NY 10026']},
#    'phone': '+19179028345',
#    'display_phone': '(917) 902-8345',
#    'distance': 11491.004663436925},
#   {'id': 'PWDSfW-c8198UegLtaTR1A',
#    'alias': 'russ-and-daughters-brooklyn-brooklyn',
#    'name': 'Russ & Daughters - Brooklyn',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bn6q8egRQ4Lj7FYI4WV61g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/russ-and-daughters-brooklyn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 72,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.69799, 'longitude': -73.97116},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '141 Flushing Ave',
#     'address2': 'Bldg 77',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['141 Flushing Ave', 'Bldg 77', 'Brooklyn, NY 11205']},
#    'phone': '+12124754880',
#    'display_phone': '(212) 475-4880',
#    'distance': 2091.8075832354552},
#   {'id': 'VImctKXnwzT_zrsc1ssvbg',
#    'alias': 'brooklyn-bagel-and-coffee-company-astoria',
#    'name': 'Brooklyn Bagel & Coffee Company',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-kxDsaXYIc7vT-ocIhCfCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-bagel-and-coffee-company-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 725,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76055, 'longitude': -73.92176},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '35-05 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35-05 Broadway', 'Astoria, NY 11106']},
#    'phone': '+17182040141',
#    'display_phone': '(718) 204-0141',
#    'distance': 8652.279576166276},
#   {'id': 'mU23NlQfn1R9OhA6WMe_xg',
#    'alias': 'breads-bakery-new-york',
#    'name': 'Breads Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mDaSWYX8hEV0eNGXJSDhVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/breads-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1080,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73661, 'longitude': -73.99181},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '18 E 16th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18 E 16th St', 'New York, NY 10003']},
#    'phone': '+12126332253',
#    'display_phone': '(212) 633-2253',
#    'distance': 3470.824425100059},
#   {'id': 'S0QgzOvaw5COMRnKWlVGnA',
#    'alias': 'baz-bagel-and-restaurant-new-york-2',
#    'name': 'Baz Bagel and Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/W_4LlAoCDl3vu44fGBkMrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baz-bagel-and-restaurant-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 419,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7193075362767,
#     'longitude': -73.9977402932106},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '181 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['181 Grand St', 'New York, NY 10013']},
#    'phone': '+12123350609',
#    'display_phone': '(212) 335-0609',
#    'distance': 1568.5986108010695},
#   {'id': 'GlTdgd8780RNXLvz8bTmFg',
#    'alias': 'egg-shop-new-york-3',
#    'name': 'Egg Shop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XPOlrRJ_NsT7MfPCeqv5cQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/egg-shop-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1158,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7204574688656,
#     'longitude': -73.9952510689421},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '151 Elizabeth St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['151 Elizabeth St', 'New York, NY 10012']},
#    'phone': '+16466660810',
#    'display_phone': '(646) 666-0810',
#    'distance': 1671.27464679055},
#   {'id': 'P91q647NhgyIf7nLc4wYsQ',
#    'alias': 'frankels-delicatessen-brooklyn',
#    'name': "Frankel's Delicatessen",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/P2ctJ8B6CHUr0S4aBJ4LbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frankels-delicatessen-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 268,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.723826, 'longitude': -73.9509979},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '631 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['631 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183892302',
#    'display_phone': '(718) 389-2302',
#    'distance': 4185.370971697787},
#   {'id': '_kARxrcTt5HjXQIEalDGWg',
#    'alias': 'zabars-new-york',
#    'name': "Zabar's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/V1rQpKGSQrcdINM4fJB39g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zabars-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1056,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.784817, 'longitude': -73.979712},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2245 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2245 Broadway', 'New York, NY 10024']},
#    'phone': '+12127872000',
#    'display_phone': '(212) 787-2000',
#    'distance': 8910.841427056843},
#   {'id': 'MzSsxuBwJBlHmNFgEiOOeA',
#    'alias': 'have-a-bagel-brooklyn',
#    'name': 'Have-A-Bagel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bemxq-x73QX3M4av3APD6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/have-a-bagel-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 102,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7099588960409,
#     'longitude': -73.9585105329752},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '197 Havemeyer St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['197 Havemeyer St', 'Brooklyn, NY 11211']},
#    'phone': '+17187820111',
#    'display_phone': '(718) 782-0111',
#    'distance': 3065.628300138641},
#   {'id': 'FkBFKwF9bDl3BCt3vebHbw',
#    'alias': 'williamsburg-bagel-brooklyn',
#    'name': 'Williamsburg Bagel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/egd08xcCGbI0rmn9vpxHtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/williamsburg-bagel-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.707384, 'longitude': -73.961024},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '343 Roebling St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['343 Roebling St', 'Brooklyn, NY 11211']},
#    'phone': '+17183840904',
#    'display_phone': '(718) 384-0904',
#    'distance': 2812.621651965322},
#   {'id': '64i-2H8rLLs55RP89Ole4A',
#    'alias': 'bagel-pub-brooklyn',
#    'name': 'Bagel Pub',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VbyRN1b-PMfQP4dQFiYLbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagel-pub-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 485,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6696865704743,
#     'longitude': -73.9868907811782},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '287 9th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['287 9th St', 'Brooklyn, NY 11215']},
#    'phone': '+17184994402',
#    'display_phone': '(718) 499-4402',
#    'distance': 4024.8253682733603},
#   {'id': 'fRvMiQFYJTc41KFltinpcA',
#    'alias': 'bagel-world-brooklyn-4',
#    'name': 'Bagel World',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CzB4GO9az4XMg18v1xIjAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagel-world-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.68963, 'longitude': -73.97056},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '223 Dekalb Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['223 Dekalb Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17186432686',
#    'display_phone': '(718) 643-2686',
#    'distance': 2659.1436152946844},
#   {'id': 'tRys0z0O4EE8sivXLFZ3kQ',
#    'alias': 'davids-bagels-new-york',
#    'name': "David's Bagels",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ve8zoSK6O586tBPzSPA6Fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/davids-bagels-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 359,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.732543, 'longitude': -73.982063},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '273 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['273 1st Ave', 'New York, NY 10003']},
#    'phone': '+12127802308',
#    'display_phone': '(212) 780-2308',
#    'distance': 3182.5107540884105},
#   {'id': 'k3Dn19cNxNuLlO0lebtDUg',
#    'alias': 'la-bagel-delight-brooklyn-4',
#    'name': '252 7th ave bagels',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hvpAMKF3iiz_bFtbikTiPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-bagel-delight-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 311,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.668548813868, 'longitude': -73.980512840055},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '284 7th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['284 7th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187686107',
#    'display_phone': '(718) 768-6107',
#    'distance': 4264.010838791061},
#   {'id': 'Mkx7wE0Jlb0bFYGhEpulSg',
#    'alias': 'blackstone-coffee-roasters-new-york',
#    'name': 'Blackstone Coffee Roasters',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3uosI_M3K2cZvAyK_dE0pA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blackstone-coffee-roasters-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7332899, 'longitude': -74.00619},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '502 Hudson St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['502 Hudson St', 'New York, NY 10014']},
#    'phone': '+12129896131',
#    'display_phone': '(212) 989-6131',
#    'distance': 3251.3728402820225},
#   {'id': 'bn-529T1P_7uQvpQEEXHFw',
#    'alias': 'bagel-boss-nolita-new-york-3',
#    'name': 'Bagel Boss - Nolita',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/E00XooZHE1SGx2GzIvYQVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagel-boss-nolita-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72458, 'longitude': -73.99445},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '55 E Houston St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 E Houston St', 'New York, NY 10012']},
#    'phone': '+16463701520',
#    'display_phone': '(646) 370-1520',
#    'distance': 2124.7772656265583},
#   {'id': 'WBNXo3byv64a0hn40c9Zuw',
#    'alias': 'montague-street-bagels-brooklyn',
#    'name': 'Montague Street Bagels',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8RpjvnZNHdyB-JqoQTCGFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/montague-street-bagels-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 220,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.6949, 'longitude': -73.995183},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '108 Montague St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['108 Montague St', 'Brooklyn, NY 11201']},
#    'phone': '+17182372512',
#    'display_phone': '(718) 237-2512',
#    'distance': 1174.930930035015},
#   {'id': '1s95hIhSQhLroVtp-4uOtw',
#    'alias': 'black-seed-bagels-new-york-9',
#    'name': 'Black Seed Bagels',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/X6QIH_mrNvgrqvQSr3LUWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-seed-bagels-new-york-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 720,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.72091485000776,
#     'longitude': -73.9947216981572},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '170 Elizabeth St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['170 Elizabeth St', 'New York, NY 10012']},
#    'phone': '+16469151500',
#    'display_phone': '(646) 915-1500',
#    'distance': 1720.561062726508},
#   {'id': '4VEgZ7aVUt6oKw8KmXj-jQ',
#    'alias': 'brooklyn-kolache-brooklyn',
#    'name': 'Brooklyn Kolache',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QqQV6MtAiG4i2vqCwFQhCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-kolache-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 337,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6907913077698,
#     'longitude': -73.9556479454041},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '520 Dekalb Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['520 Dekalb Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17183981111',
#    'display_phone': '(718) 398-1111',
#    'distance': 3642.653889043858},
#   {'id': 'WHRHK3S1mQc3PmhwsGRvbw',
#    'alias': 'bibble-and-sip-new-york-2',
#    'name': 'Bibble & Sip',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gX847-f2s1X65RkzsFAWBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bibble-and-sip-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5020,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7628355, 'longitude': -73.98518009478293},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '253 W 51st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253 W 51st St', 'New York, NY 10019']},
#    'phone': '+16466495116',
#    'display_phone': '(646) 649-5116',
#    'distance': 6427.569355387715},
#   {'id': 'mOL7TxRDJGutaEtVA8_hUg',
#    'alias': 'sadelles-new-york',
#    'name': "Sadelle's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0xW8lp6uEUuOENV-v4liFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sadelles-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 666,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72624, 'longitude': -74.00013},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '463 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['463 W Broadway', 'New York, NY 10012']},
#    'phone': '+12127764926',
#    'display_phone': '(212) 776-4926',
#    'distance': 2366.64465173586},
#   {'id': '3AgtLUyDGFIsMrg25e8LPQ',
#    'alias': 'brooklyn-bread-cafe-brooklyn',
#    'name': 'Brooklyn Bread Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/a_BXVg1K7s1KChoqzdBF8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-bread-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 170,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6801748923356,
#     'longitude': -73.99714436095344},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '412 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['412 Court St', 'Brooklyn, NY 11231']},
#    'phone': '+19292502715',
#    'display_phone': '(929) 250-2715',
#    'distance': 2820.152781601164},
#   {'id': 'H_V8VZtIv34atqpI-Z86CQ',
#    'alias': 'bagel-pub-brooklyn-2',
#    'name': 'Bagel Pub',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zbT6-uBOrBMdWXIoRZXF8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagel-pub-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 336,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.672237, 'longitude': -73.957107},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '775 Franklin Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['775 Franklin Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17187742243',
#    'display_phone': '(718) 774-2243',
#    'distance': 4838.689155953329},
#   {'id': 'rQpO1Eie_zmeAOQ9s-T0sQ',
#    'alias': 'hole-in-the-wall-new-york-12',
#    'name': 'Hole In The Wall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NSQmNZzpk69EeGYDQNaThQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hole-in-the-wall-new-york-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 623,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'australian', 'title': 'Australian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70837, 'longitude': -74.00563},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '15 Cliff St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Cliff St', 'New York, NY 10038']},
#    'phone': '+12126029991',
#    'display_phone': '(212) 602-9991',
#    'distance': 1009.2543696243514},
#   {'id': 'gwo5ci1qtZZhOURn81ddhg',
#    'alias': 'greenbergs-bagels-brooklyn',
#    'name': "Greenberg's Bagels",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OeD25RIPE3mrO2uzRc9xbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greenbergs-bagels-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7169011403856,
#     'longitude': -73.9619611948728},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '103 N 3rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 N 3rd St', 'Brooklyn, NY 11249']},
#    'phone': '+13478600455',
#    'display_phone': '(347) 860-0455',
#    'distance': 3008.191349123169}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                           Restaurant      Type Price Rating           Address  \
# 0                   Russ & Daughters    Bagels    $$    4.5  179 E Houston St
# 1                Best Bagel & Coffee    Bagels     $    4.5     225 W 35th St
# 2                        Ess-a-Bagel  Bakeries     $      4       831 3rd Ave
# 3    Brooklyn Bagel & Coffee Company    Bagels     $    4.5       286 8th Ave
# 4  Tompkins Square Bagels - Avenue A    Bagels    $$      4      165 Avenue A
#
#          Lat        Lng                                                url  \
# 0  40.722589 -73.988283  https://www.yelp.com/biz/russ-and-daughters-ne...
# 1  40.752268 -73.991086  https://www.yelp.com/biz/best-bagel-and-coffee...
# 2  40.756301 -73.970370  https://www.yelp.com/biz/ess-a-bagel-new-york?...
# 3  40.746183 -73.997642  https://www.yelp.com/biz/brooklyn-bagel-and-co...
# 4  40.728230 -73.982300  https://www.yelp.com/biz/tompkins-square-bagel...
#
#                        ID
# 0  VrCCr45dhN-RRM107iptdg
# 1  j1S3NUrkB3BVT49n_e76NQ
# 2  c3eMI4_o4dPDDhPV_ibBYQ
# 3  pb_ryc8FYHpUPV56eV2Eyg
# 4  oi39VAwo4-KGm_gSkWPCsQ

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"bagel","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': '7eNqRj9iCdxcORVTxexvuw',
#    'alias': 'greenberg-s-bagels-brooklyn',
#    'name': 'Greenberg’s Bagels',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sn8GzxbnXQVnt1ymKIls6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greenberg-s-bagels-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 61,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.68753, 'longitude': -73.95458},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1065 Bedford Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1065 Bedford Ave', 'Brooklyn, NY 11216']},
#    'phone': '+13478600455',
#    'display_phone': '(347) 860-0455',
#    'distance': 3903.2713614556005},
#   {'id': '2D7orDrXzflLL1TRmWGPMw',
#    'alias': 'utopia-bagels-whitestone-2',
#    'name': 'Utopia Bagels',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HdLKN-UjDNmBnE1GmscKAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/utopia-bagels-whitestone-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 723,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7798968356453,
#     'longitude': -73.7930051609874},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1909 Utopia Pkwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Whitestone',
#     'zip_code': '11357',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1909 Utopia Pkwy', 'Whitestone, NY 11357']},
#    'phone': '+17183522586',
#    'display_phone': '(718) 352-2586',
#    'distance': 18870.72100003463},
#   {'id': 'oLYnY3SKNqIwERzZXOc63A',
#    'alias': 'myrtle-bagel-brooklyn',
#    'name': 'Myrtle Bagel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zQTkkFV1oHg-MZFh_L-uKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/myrtle-bagel-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6930314149359,
#     'longitude': -73.9693918107215},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '410 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['410 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17188584916',
#    'display_phone': '(718) 858-4916',
#    'distance': 2512.3719976453854},
#   {'id': 'pWywDImlX0n_XKPNg0Bizg',
#    'alias': 'sunny-and-annies-new-york',
#    'name': "Sunny and Annie's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/R2onHYbQdBM1oVjWRZ900w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sunny-and-annies-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 517,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.724653, 'longitude': -73.981702},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '94 Ave B',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['94 Ave B', 'New York, NY 10003']},
#    'phone': '+12126773131',
#    'display_phone': '(212) 677-3131',
#    'distance': 2382.8415438824572},
#   {'id': 'tq7dDT6edTInhkNdDrYv_w',
#    'alias': 'black-brick-brooklyn',
#    'name': 'Black Brick',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KMA7EDvWqQnCa9T6SICejQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-brick-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 325,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7142079238412,
#     'longitude': -73.9617848396301},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '300 Bedford Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['300 Bedford Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17183840075',
#    'display_phone': '(718) 384-0075',
#    'distance': 2908.1707973176744},
#   {'id': 't4M1VX4n34eEgUWMJ7cgKw',
#    'alias': 'daily-provisions-new-york',
#    'name': 'Daily Provisions',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KOSmplXpEbiCLdRnRBkcTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daily-provisions-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 471,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73768, 'longitude': -73.9876685},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '103 E 19th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 E 19th St', 'New York, NY 10003']},
#    'phone': '+12124881505',
#    'display_phone': '(212) 488-1505',
#    'distance': 3624.11900652027},
#   {'id': 'c6UUcUTbwbk0kOpF6jVOJQ',
#    'alias': 'the-doughnut-project-new-york',
#    'name': 'The Doughnut Project',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TsRkIkazmTpT_HZ6zaia0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-doughnut-project-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 520,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.731151, 'longitude': -74.003547},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '10 Morton St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10 Morton St', 'New York, NY 10014']},
#    'phone': '+12126915000',
#    'display_phone': '(212) 691-5000',
#    'distance': 2964.428663792995},
#   {'id': '0rQz8mkleT62eUkiAVs4UA',
#    'alias': 'russ-and-daughters-cafe-new-york-5',
#    'name': 'Russ & Daughters Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iX8aL6YLwC2V8auRGy5t5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/russ-and-daughters-cafe-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1043,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7196253171697,
#     'longitude': -73.9895758930263},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '127 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['127 Orchard St', 'New York, NY 10002']},
#    'phone': '+12124754881',
#    'display_phone': '(212) 475-4881',
#    'distance': 1626.1485996193103},
#   {'id': 'jewdjZyGcAXIepOeTBae6g',
#    'alias': 'cafe-panino-mucho-giusto-new-york',
#    'name': 'Cafe Panino Mucho Giusto',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_1MBpcFh7BJClhvNVjlLag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-panino-mucho-giusto-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 109,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.735256, 'longitude': -74.006309},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '551 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['551 Hudson St', 'New York, NY 10014']},
#    'phone': '+12122292799',
#    'display_phone': '(212) 229-2799',
#    'distance': 3466.3911255716803},
#   {'id': 'QdmvRfJb86BVvk6A-J5gAg',
#    'alias': 'modern-bread-and-bagel-new-york',
#    'name': 'Modern Bread and Bagel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uWxfRLaUTkre6IDdJj92aQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/modern-bread-and-bagel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 206,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78438, 'longitude': -73.97392},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '472 Columbus Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['472 Columbus Ave', 'New York, NY 10024']},
#    'phone': '+16467752985',
#    'display_phone': '(646) 775-2985',
#    'distance': 8952.103987442379},
#   {'id': '1Jjg8-vQVRQqqtL4sODi5g',
#    'alias': 'mekelburgs-brooklyn',
#    'name': "Mekelburg's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6j8-rSAj6P_HM7upIQQcnQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mekelburgs-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 303,
#    'categories': [{'alias': 'gourmet', 'title': 'Specialty Food'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.687542, 'longitude': -73.962334},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '293 Grand Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['293 Grand Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17183992337',
#    'display_phone': '(718) 399-2337',
#    'distance': 3347.768531764459},
#   {'id': 'iyKEtW9KM7rIyycAR0o3ew',
#    'alias': 'black-star-bakery-and-cafe-new-york-3',
#    'name': 'Black Star Bakery & Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6pfbDH57Vyv0DVL0b8IuQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-star-bakery-and-cafe-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.738951, 'longitude': -73.980784},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '241 E 24th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['241 E 24th St', 'New York, NY 10010']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3890.344620331399},
#   {'id': 'amoGEhgkE4xcNXwYqWeoaw',
#    'alias': 'yonah-schimmels-knish-bakery-new-york',
#    'name': "Yonah Schimmel's Knish Bakery",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lyvUu5EXQGgN37dALcdoLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yonah-schimmels-knish-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 653,
#    'categories': [{'alias': 'kosher', 'title': 'Kosher'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'soulfood', 'title': 'Soul Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.723133, 'longitude': -73.990144},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '137 E Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['137 E Houston St', 'New York, NY 10002']},
#    'phone': '+12124772858',
#    'display_phone': '(212) 477-2858',
#    'distance': 1996.628304874503},
#   {'id': 'MGd6HFEq1ALD58XWNviSXw',
#    'alias': 'time-out-market-new-york-brooklyn',
#    'name': 'Time Out Market New York',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/I5ybhy4J7GWCel1wZ4NJng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/time-out-market-new-york-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 290,
#    'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7037211399782,
#     'longitude': -73.9918105285751},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '55 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+19178104855',
#    'display_phone': '(917) 810-4855',
#    'distance': 283.7853104247956},
#   {'id': 'H4jJ7XB3CetIr1pg56CczQ',
#    'alias': 'levain-bakery-new-york',
#    'name': 'Levain Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ElQFlcl5wBXfn1qbfweYsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/levain-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8481,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.779961, 'longitude': -73.980299},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '167 W 74th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['167 W 74th St', 'New York, NY 10023']},
#    'phone': '+19174643769',
#    'display_phone': '(917) 464-3769',
#    'distance': 8369.262424680568},
#   {'id': 'lLsEzgmXwCoP6OK5ACT1Ig',
#    'alias': 'ess-a-bagel-new-york-6',
#    'name': 'Ess-a-Bagel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rB7-FiN_CTa5TmEyYFGRLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ess-a-bagel-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 176,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74863, 'longitude': -73.9894},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '108 W 32nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['108 W 32nd St', 'New York, NY 10001']},
#    'phone': '+19177814040',
#    'display_phone': '(917) 781-4040',
#    'distance': 4804.7371040716225},
#   {'id': 'bb4TLfMexv3XPy864A09ug',
#    'alias': 'h-and-h-bagels-new-york-6',
#    'name': 'H&H Bagels',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-tY9U0NUrjztwPqK-w8xrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/h-and-h-bagels-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 848,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77444, 'longitude': -73.95447},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1551 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1551 2nd Ave', 'New York, NY 10028']},
#    'phone': '+12127347441',
#    'display_phone': '(212) 734-7441',
#    'distance': 8373.161269346705},
#   {'id': 'x_oV9aGzq-lNmgPXU_tvbw',
#    'alias': 'zuckers-bagels-and-smoked-fish-new-york',
#    'name': "Zucker's Bagels & Smoked Fish",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0ZPkM9tZmtOZYte731zL3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zuckers-bagels-and-smoked-fish-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 692,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.715576, 'longitude': -74.009849},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '146 Chambers St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['146 Chambers St', 'New York, NY 10007']},
#    'phone': '+12126085844',
#    'display_phone': '(212) 608-5844',
#    'distance': 1727.7486753486696},
#   {'id': '2xxX3t7ykIlyoaOXZdRZNw',
#    'alias': 'bagel-world-brooklyn-3',
#    'name': 'Bagel World',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tjWlbRE2F66_VYycydD4eA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagel-world-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 220,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67205, 'longitude': -73.98373},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '339 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['339 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17184991143',
#    'display_phone': '(718) 499-1143',
#    'distance': 3826.839209813229},
#   {'id': '2bpjwQBGoo9KyMYUuPt0Hw',
#    'alias': 'the-bagel-market-brooklyn',
#    'name': 'The Bagel Market',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tgufec69BCLFQA0Fq0k0Vw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bagel-market-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 164,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.67418, 'longitude': -73.97581},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '106 7th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['106 7th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17182304700',
#    'display_phone': '(718) 230-4700',
#    'distance': 3807.420230473229},
#   {'id': '4v5lbiExMocWoG7iKnYWrQ',
#    'alias': 'black-seed-bagels-new-york-11',
#    'name': 'Black Seed Bagels',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DLoFdj28jzWSwubki6NVjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-seed-bagels-new-york-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 250,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.72912, 'longitude': -73.98398},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '176 First Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['176 First Ave', 'New York, NY 10012']},
#    'phone': '+16468592289',
#    'display_phone': '(646) 859-2289',
#    'distance': 2769.647285453586},
#   {'id': '3xTlLfIwh_IFkxoXNU8tYQ',
#    'alias': 'bagel-point-brooklyn-2',
#    'name': 'Bagel Point',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dUMc6I3JKbctiBpYV401jw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagel-point-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 197,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72553, 'longitude': -73.9519495},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '699 Manhattan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['699 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183831600',
#    'display_phone': '(718) 383-1600',
#    'distance': 4209.991629540794},
#   {'id': 'xTnivXEdEtXrnhp-z4JGvg',
#    'alias': 'la-parisienne-new-york-5',
#    'name': 'La Parisienne',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ywbWsBIM-z7OHvhMoHUg5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-parisienne-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 606,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70961, 'longitude': -74.0093799},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '9 Maiden Ln',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Maiden Ln', 'New York, NY 10038']},
#    'phone': '+16467564911',
#    'display_phone': '(646) 756-4911',
#    'distance': 1350.1089630689858},
#   {'id': 'pNAzYa46vVgMIrPbdvSnww',
#    'alias': 'brooklyn-gourmet-deli-brooklyn',
#    'name': 'Brooklyn Gourmet Deli',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/D9wOljeypuJDnZwmvvgD9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-gourmet-deli-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.713143, 'longitude': -73.962035},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '313 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['313 Bedford Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17184868261',
#    'display_phone': '(718) 486-8261',
#    'distance': 2850.565466457004},
#   {'id': 'WkALLrAOqGnMPhWhR4pM8w',
#    'alias': 'thompson-finest-deli-new-york',
#    'name': 'Thompson Finest Deli',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JKn1cdEGwo3A8_cIoX3tfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thompson-finest-deli-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7224357, 'longitude': -74.0044578},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '20 Thompson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['20 Thompson St', 'New York, NY 10013']},
#    'phone': '+12123432337',
#    'display_phone': '(212) 343-2337',
#    'distance': 2078.5718836889714},
#   {'id': 'Oq1mej1BYfjcdPKkM_5o8g',
#    'alias': 'high-street-on-hudson-new-york',
#    'name': 'High Street On Hudson',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FvKsbK7g79UVFYyyzqNeYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/high-street-on-hudson-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 427,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73888, 'longitude': -74.00574},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '637 Hudson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['637 Hudson St', 'New York, NY 10014']},
#    'phone': '+19173883944',
#    'display_phone': '(917) 388-3944',
#    'distance': 3843.1955727088894},
#   {'id': 'VHORZQg5A3YNBptRN92QGg',
#    'alias': 'the-lazy-llama-coffee-bar-new-york-2',
#    'name': 'The Lazy Llama Coffee Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/S_ZtGbbfVEIFbrUcGofUJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lazy-llama-coffee-bar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 100,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.723505897000265,
#     'longitude': -73.98873335337309},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '72 E 1st Street',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['72 E 1st Street', 'New York, NY 10003']},
#    'phone': '+16464101938',
#    'display_phone': '(646) 410-1938',
#    'distance': 2062.2377032766435},
#   {'id': 'UgTfFaQ_NAyne5OwLtTpXQ',
#    'alias': 'bagels-and-schmear-new-york',
#    'name': 'Bagels & Schmear',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/u6-g8ndUeOTtBmiA0AUbmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagels-and-schmear-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 538,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74289899502011,
#     'longitude': -73.98331665413312},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '116 E 28th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['116 E 28th St', 'New York, NY 10016']},
#    'phone': '+12127257873',
#    'display_phone': '(212) 725-7873',
#    'distance': 4266.190340893236},
#   {'id': 'XTa5infpecABoyLZ86EH2w',
#    'alias': 'bagel-bobs-new-york',
#    'name': "Bagel Bob's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2lKoNDBtGr2TwKKCCYoPMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagel-bobs-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 195,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73248, 'longitude': -73.99385},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '51 University Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['51 University Pl', 'New York, NY 10003']},
#    'phone': '+12125332627',
#    'display_phone': '(212) 533-2627',
#    'distance': 2997.927902631181},
#   {'id': 'CYf9FmRmjYa2MAnAv1Z4Cw',
#    'alias': 'blue-spoon-coffee-co-new-york-2',
#    'name': 'Blue Spoon Coffee Company',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/h_fIEP3_YJPNNl1ZyOk53Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-spoon-coffee-co-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 199,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.708068, 'longitude': -74.007469},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '90 William St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90 William St', 'New York, NY 10038']},
#    'phone': '+12128098880',
#    'display_phone': '(212) 809-8880',
#    'distance': 1149.7915132345515},
#   {'id': 'DklpHj1YV2CMR4VEo-TlGQ',
#    'alias': 'casella-bagel-coffee-shop-new-york',
#    'name': 'Casella Bagel Coffee Shop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/obEOIWMHj09f10rwEIfWLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casella-bagel-coffee-shop-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'cuban', 'title': 'Cuban'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.692009, 'longitude': -73.986076},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '66 Willoughby St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['66 Willoughby St', 'New York, NY 11201']},
#    'phone': '+17185225641',
#    'display_phone': '(718) 522-5641',
#    'distance': 1645.124984063014},
#   {'id': 'm6FV9h1mMJ9_LZetNOjNjg',
#    'alias': 'bagelworks-new-york-5',
#    'name': 'Bagelworks',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ITFibwrKaUqIHghqgH0u1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagelworks-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 433,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.764358, 'longitude': -73.958862},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1229 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1229 1st Ave', 'New York, NY 10065']},
#    'phone': '+12127446444',
#    'display_phone': '(212) 744-6444',
#    'distance': 7206.574490626029},
#   {'id': 'cGsQXm4d2NVHW7jljXPF1Q',
#    'alias': 'o-bagel-hoboken',
#    'name': "O'Bagel",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1ugIkqOCCyHjaPM7fUa84g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/o-bagel-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 392,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7436099, 'longitude': -74.0293},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '600 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['600 Washington St', 'Hoboken, NJ 07030']},
#    'phone': '+12016838600',
#    'display_phone': '(201) 683-8600',
#    'distance': 5169.874865840342},
#   {'id': 'moxoKYWdOUZarqPgtMd-5w',
#    'alias': 'vodega-new-york',
#    'name': 'Vodega',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/I8pEHQLD7Eg8Is8aIbhv8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vodega-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.703595, 'longitude': -73.987903},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '140 Plymoth St',
#     'address2': 'Ste 140B',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['140 Plymoth St', 'Ste 140B', 'New York, NY 11201']},
#    'phone': '+13479160098',
#    'display_phone': '(347) 916-0098',
#    'distance': 575.7829169470484},
#   {'id': '3PAWQuIvJ8DIa5akaF3XYQ',
#    'alias': 'marcy-and-myrtle-cafe-new-york-city',
#    'name': 'Marcy & Myrtle Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qgwA3tUWO1Y4zklDjyBDlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marcy-and-myrtle-cafe-new-york-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72068, 'longitude': -73.95766},
#    'transactions': ['delivery'],
#    'location': {'address1': '101 N 10th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York City',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['101 N 10th St', 'New York City, NY 11249']},
#    'phone': '+19176487800',
#    'display_phone': '(917) 648-7800',
#    'distance': 3525.7414425579113},
#   {'id': 'P4HX6tjQQK4gbdn_d0cGTw',
#    'alias': 'ground-support-new-york',
#    'name': 'Ground Support',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FbOFOfl469WOxA236dRqIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ground-support-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 522,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7241968559678,
#     'longitude': -74.0020576327145},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '399 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['399 W Broadway', 'New York, NY 10012']},
#    'phone': '+12122198733',
#    'display_phone': '(212) 219-8733',
#    'distance': 2185.4017789063764},
#   {'id': 'yMxGI1kcqv6a-aGH-VXg8A',
#    'alias': 'little-skips-east-brooklyn-2',
#    'name': 'Little Skips East',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XC_z6chuyn8ivjNGRhzhsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-skips-east-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 75,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6849363759513,
#     'longitude': -73.9137830212712},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1643 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11207',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1643 Broadway', 'Brooklyn, NY 11207']},
#    'phone': '+17184841555',
#    'display_phone': '(718) 484-1555',
#    'distance': 7160.390241526564},
#   {'id': 'I0cCH0mw6WGyClL6OSE3Jg',
#    'alias': 'pick-a-bagel-new-york-3',
#    'name': 'Pick A Bagel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pHTOW6Rmyy-SXFnro5nYZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pick-a-bagel-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 290,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.773664, 'longitude': -73.959566},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1101 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1101 Lexington Ave', 'New York, NY 10075']},
#    'phone': '+12125176590',
#    'display_phone': '(212) 517-6590',
#    'distance': 8130.29821373756},
#   {'id': 'RKAK9AuzKR7K36ABcXPjTA',
#    'alias': 'ccs-cafe-new-york-2',
#    'name': "CC's Cafe",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ReA5ahTHehAxnSaQNWK9XA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ccs-cafe-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 151,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71166, 'longitude': -73.99452},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '41 Monroe St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41 Monroe St', 'New York, NY 10002']},
#    'phone': '+12125711060',
#    'display_phone': '(212) 571-1060',
#    'distance': 695.0211568685693},
#   {'id': 'Fm2XUIqr62M6IznAS-kJBw',
#    'alias': 'broad-nosh-bagels-new-york',
#    'name': 'Broad Nosh Bagels',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fTV9B6EPntSKx3OIxD6N6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/broad-nosh-bagels-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'kosher', 'title': 'Kosher'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78793, 'longitude': -73.97648},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2350 Broadway',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2350 Broadway', 'New York, NY 10024']},
#    'phone': '+12126000933',
#    'display_phone': '(212) 600-0933',
#    'distance': 9285.384212299557},
#   {'id': 'bvIXVgn_Do7K7qnqcJmWhA',
#    'alias': 'tal-bagels-new-york-7',
#    'name': 'Tal Bagels',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XzfvJd_EPE5hgWaUhYrpuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tal-bagels-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 143,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73554, 'longitude': -73.97975},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '357 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['357 1st Ave', 'New York, NY 10010']},
#    'phone': '+12123878100',
#    'display_phone': '(212) 387-8100',
#    'distance': 3563.947633333622},
#   {'id': 'ZE_y6vpKU7QBsMBqU93pyQ',
#    'alias': 'between-the-bagel-queens-2',
#    'name': 'Between the Bagel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BmzrCBALCN4xcy218KeLAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/between-the-bagel-queens-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.766837, 'longitude': -73.920731},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '31-13 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Queens',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31-13 30th Ave', 'Queens, NY 11102']},
#    'phone': '+17189321425',
#    'display_phone': '(718) 932-1425',
#    'distance': 9220.267960066154},
#   {'id': 'vrcfSmyE8orhd0yHSrqvgQ',
#    'alias': 'bkg-coffee-roasters-brooklyn-3',
#    'name': 'BKG Coffee Roasters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AGUiBgh2vXViSHT5h2lz-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bkg-coffee-roasters-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 78,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69404, 'longitude': -73.96193},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '557 Myrtle Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['557 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3009.1887231281867},
#   {'id': 'a7BC1doUjNDqrqTaAMmfZg',
#    'alias': 'bite-new-york',
#    'name': 'Bite',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TwZI7h0HzbdECV7Tv7WQWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bite-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 276,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7257318645125,
#     'longitude': -73.9946338116395},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '335 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['335 Lafayette St', 'New York, NY 10012']},
#    'phone': '+12124310301',
#    'display_phone': '(212) 431-0301',
#    'distance': 2255.9916215713783},
#   {'id': 'BF18SM3lrdxyxCuu73rMhg',
#    'alias': 'grabsteins-bagels-new-york-2',
#    'name': "Grabstein's Bagels",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3dx5QRhM8MHwLioufk1f7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grabsteins-bagels-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.78697239214806,
#     'longitude': -73.95386457480862},
#    'transactions': [],
#    'location': {'address1': '50 E 96th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['50 E 96th St', 'New York, NY 10128']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9684.088766279678},
#   {'id': 'wguf7JbO1Nu9oN_ywXTCCA',
#    'alias': 'sip-and-co-new-york',
#    'name': 'Sip and Co',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/F2nEA9xDlnLsGtm8Vuzvug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sip-and-co-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.76472, 'longitude': -73.97581},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '41 W 58th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41 W 58th St', 'New York, NY 10019']},
#    'phone': '+19177179747',
#    'display_phone': '(917) 717-9747',
#    'distance': 6775.195798237168},
#   {'id': 'SQS9wteNCLoVStkVK0oZNA',
#    'alias': 'zuckers-bagels-and-smoked-fish-new-york-2',
#    'name': "Zucker's Bagels & Smoked Fish",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Ft-IwDksBjzGRt-dGMEy7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zuckers-bagels-and-smoked-fish-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 532,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.75058, 'longitude': -73.97685},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '370 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['370 Lexington Ave', 'New York, NY 10017']},
#    'phone': '+12126611080',
#    'display_phone': '(212) 661-1080',
#    'distance': 5244.026712567999},
#   {'id': 'drSJJWL7lsG8dSRYI--6wQ',
#    'alias': 'ny-bagels-and-cafe-new-york',
#    'name': 'NY Bagels & Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/X1Tpitg2xgAfd10blcmbKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ny-bagels-and-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 228,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.743578, 'longitude': -73.973966},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '587 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['587 1st Ave', 'New York, NY 10016']},
#    'phone': '+12127253777',
#    'display_phone': '(212) 725-3777',
#    'distance': 4573.139148748726},
#   {'id': 'xiwnLiNhSlEN4CDcurqsLQ',
#    'alias': '2nd-ave-deli-new-york',
#    'name': '2nd Ave Deli',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/u9pAnwZlqehOgc1FV572eA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/2nd-ave-deli-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1257,
#    'categories': [{'alias': 'kosher', 'title': 'Kosher'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.745206, 'longitude': -73.9791699},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '162 E 33rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 E 33rd St', 'New York, NY 10016']},
#    'phone': '+12126899000',
#    'display_phone': '(212) 689-9000',
#    'distance': 4601.242671102633},
#   {'id': 'ysqgdbSrezXgVwER2kQWKA',
#    'alias': 'julianas-brooklyn-3',
#    'name': "Juliana's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/clscwgOF9_Ecq-Rwsq7jyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/julianas-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2354,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70274718768062,
#     'longitude': -73.99343490196397},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '19 Old Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#    'phone': '+17185966700',
#    'display_phone': '(718) 596-6700',
#    'distance': 308.56984360837544}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#            Restaurant          Type Price Rating           Address        Lat  \
# 0  Greenberg’s Bagels        Bagels               1065 Bedford Ave  40.687530
# 1       Utopia Bagels      Bakeries     $    4.5  1909 Utopia Pkwy  40.779897
# 2        Myrtle Bagel        Bagels     $    3.5    410 Myrtle Ave  40.693031
# 3   Sunny and Annie's    Sandwiches     $    4.5          94 Ave B  40.724653
# 4         Black Brick  Coffee & Tea     $      4   300 Bedford Ave  40.714208
#
#          Lng                                                url  \
# 0 -73.954580
# 1 -73.793005  https://www.yelp.com/biz/utopia-bagels-whitest...
# 2 -73.969392  https://www.yelp.com/biz/myrtle-bagel-brooklyn...
# 3 -73.981702  https://www.yelp.com/biz/sunny-and-annies-new-...
# 4 -73.961785  https://www.yelp.com/biz/black-brick-brooklyn?...
#
#                        ID
# 0
# 1  2D7orDrXzflLL1TRmWGPMw
# 2  oLYnY3SKNqIwERzZXOc63A
# 3  pWywDImlX0n_XKPNg0Bizg
# 4  tq7dDT6edTInhkNdDrYv_w

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"bagel","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': 'psx14GCq03cuRCWJIs0CuQ',
#    'alias': 'bagel-oasis-fresh-meadows-3',
#    'name': 'Bagel Oasis',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kCPqP_RvRmIGlcDZ0Vnjdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagel-oasis-fresh-meadows-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 390,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.739435, 'longitude': -73.790506},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '18312 Horace Harding Expy',
#     'address2': '',
#     'address3': '',
#     'city': 'Fresh Meadows',
#     'zip_code': '11365',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18312 Horace Harding Expy',
#      'Fresh Meadows, NY 11365']},
#    'phone': '+17183599245',
#    'display_phone': '(718) 359-9245',
#    'distance': 17585.932577142015},
#   {'id': 'A8jRnZGiMJiMpfHt8qKV3w',
#    'alias': 'fiction-bar-cafe-brooklyn',
#    'name': 'Fiction Bar/Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GdhN-_6OZFkK2cjiN449rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fiction-bar-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 95,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.707248, 'longitude': -73.95375},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '308 Hooper St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['308 Hooper St', 'Brooklyn, NY 11211']},
#    'phone': '+17185995151',
#    'display_phone': '(718) 599-5151',
#    'distance': 3425.4795376581733},
#   {'id': 'qn8kAN7VOCx1nJmSJ2FBuQ',
#    'alias': 'sunny-delicatessen-brooklyn',
#    'name': 'Sunny Delicatessen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uj9xQe1wbmy09EfMd99N5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sunny-delicatessen-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'delis', 'title': 'Delis'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.693065, 'longitude': -73.993339},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '153 Joralemon St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['153 Joralemon St', 'Brooklyn, NY 11201']},
#    'phone': '+17186241956',
#    'display_phone': '(718) 624-1956',
#    'distance': 1382.1174209419735},
#   {'id': 'k5uLQag3XnKyd_ZwunQuKg',
#    'alias': 'brooklyn-heights-deli-brooklyn-2',
#    'name': 'Brooklyn-Heights Deli',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/j1N8_vbqTUBgLgOhMr5WvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-heights-deli-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6913909912109,
#     'longitude': -73.9962463378906},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '292 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['292 Henry St', 'Brooklyn, NY 11201']},
#    'phone': '+17186431361',
#    'display_phone': '(718) 643-1361',
#    'distance': 1571.9795450317185},
#   {'id': 'ZO9CKtJ9tvPSwEns-semKA',
#    'alias': 'zuckers-bagels-and-smoked-fish-new-york-10',
#    'name': "Zucker's Bagels & Smoked Fish",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4XWi8I5McnKdC4ePa9yTKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zuckers-bagels-and-smoked-fish-new-york-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 145,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.740301, 'longitude': -73.98736},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '40 E 23rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40 E 23rd St', 'New York, NY 10010']},
#    'phone': '+12122285100',
#    'display_phone': '(212) 228-5100',
#    'distance': 3919.6128243315757},
#   {'id': 'GqO2I5acetVHwBszFeHabw',
#    'alias': 'bagel-pub-brooklyn-3',
#    'name': 'Bagel Pub',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JdtF2f1-D3JofpYAWDdmew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagel-pub-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.65546, 'longitude': -74.00603},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '313 36th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11232',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['313 36th St', 'Brooklyn, NY 11232']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5643.093261128823},
#   {'id': 'tgxqF7k3jWnBecVjmZEbsA',
#    'alias': 'bagels-and-more-edgewater-2',
#    'name': 'Bagels & More',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DDb3Gv0CkSiUOnMmRS4rvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagels-and-more-edgewater-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.830253, 'longitude': -73.97229},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1040 River Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Edgewater',
#     'zip_code': '07020',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1040 River Rd', 'Edgewater, NJ 07020']},
#    'phone': '+12018861112',
#    'display_phone': '(201) 886-1112',
#    'distance': 14003.517125918213},
#   {'id': '8Ifb62t36tYFI0NcOsxLMw',
#    'alias': 'sarges-delicatessen-downtown-new-york',
#    'name': "Sarge's Delicatessen Downtown",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZAECWeChKcsos62sx8ZeOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sarges-delicatessen-downtown-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'fooddeliveryservices',
#      'title': 'Food Delivery Services'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72613, 'longitude': -74.004997},
#    'transactions': ['delivery'],
#    'location': {'address1': '30 Vandam St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30 Vandam St', 'New York, NY 10013']},
#    'phone': '+12122037142',
#    'display_phone': '(212) 203-7142',
#    'distance': 2471.2702034517006},
#   {'id': 'l6lg4lqJSkGDFE6Svl5wnw',
#    'alias': 'the-bagel-shop-new-york-2',
#    'name': 'The Bagel Shop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wpivl2rimpirbz5AFS2DKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bagel-shop-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 159,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78307, 'longitude': -73.95065},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1659 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1659 3rd Ave', 'New York, NY 10128']},
#    'phone': '+12128602377',
#    'display_phone': '(212) 860-2377',
#    'distance': 9382.14381790592},
#   {'id': 'V7lXZKBDzScDeGB8JmnzSA',
#    'alias': 'katzs-delicatessen-new-york',
#    'name': "Katz's Delicatessen",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qr7eSU6CFwRGZ7Rc-QEoTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/katzs-delicatessen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12925,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722237, 'longitude': -73.9875259},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '205 E Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['205 E Houston St', 'New York, NY 10002']},
#    'phone': '+12122542246',
#    'display_phone': '(212) 254-2246',
#    'distance': 1952.3706239726876},
#   {'id': 'OtqShhp-cOByPzzdTMZu6w',
#    'alias': 'knickerbocker-bagel-brooklyn',
#    'name': 'Knickerbocker Bagel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QeHLwlP1u9gJldmVgbYLrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/knickerbocker-bagel-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 266,
#    'categories': [{'alias': 'wraps', 'title': 'Wraps'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7006584, 'longitude': -73.9212251},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '367 Knickerbocker Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['367 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17187098888',
#    'display_phone': '(718) 709-8888',
#    'distance': 6182.355319828193},
#   {'id': 'uoT2_Wrt1noD6kZOID7tUg',
#    'alias': 'jane-new-york-2',
#    'name': 'Jane',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fL4CNvQYiUmE9HKbOd1AcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jane-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3208,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7273779, 'longitude': -74.00025},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '100 W Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100 W Houston St', 'New York, NY 10012']},
#    'phone': '+12122547000',
#    'display_phone': '(212) 254-7000',
#    'distance': 2489.9758210239006},
#   {'id': 'vZevXSC1w27dEvXc2EHCEg',
#    'alias': 'good-thanks-cafe-new-york',
#    'name': 'Good Thanks Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bwiCKLNSXLFdUQXgd_iPXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/good-thanks-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 251,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71972, 'longitude': -73.98952},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '131A Orchard St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['131A Orchard St', 'New York, NY 10002']},
#    'phone': '+16463704426',
#    'display_phone': '(646) 370-4426',
#    'distance': 1640.2291870611812},
#   {'id': 'xLEhzxC9RdbOW_CYnlGuBw',
#    'alias': 'liberty-bagel-elmhurst',
#    'name': 'Liberty Bagel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Qki328REBQnjHR_B3DrNOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/liberty-bagel-elmhurst?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.747491, 'longitude': -73.8835},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '82-10 Roosevelt Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['82-10 Roosevelt Ave', 'Elmhurst, NY 11373']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 10445.946543939057},
#   {'id': 'koh-4_SAbshwZ8EBRmXcmg',
#    'alias': 'b-and-h-dairy-new-york-2',
#    'name': 'B&H Dairy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uqw6D9083EcXLm2Bgci_LQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b-and-h-dairy-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 488,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7284622192383,
#     'longitude': -73.988166809082},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '127 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['127 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12125058065',
#    'display_phone': '(212) 505-8065',
#    'distance': 2614.748126892428},
#   {'id': 'T4Dz6vmotl5CkleLMSBK9Q',
#    'alias': 'bergen-bagels-brooklyn-5',
#    'name': 'Bergen Bagels',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XuTyiJsH5hzVdig41zsfbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bergen-bagels-brooklyn-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 172,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.6832101, 'longitude': -73.9649926},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '949 Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['949 Fulton St', 'Brooklyn, NY 11238']},
#    'phone': '+17187896400',
#    'display_phone': '(718) 789-6400',
#    'distance': 3494.98853318031},
#   {'id': 's_bkOOVmBwkNueITXriXmw',
#    'alias': 'mixtape-bushwick-brooklyn',
#    'name': 'Mixtape Bushwick',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KeqhqfvxpL7ztmFNNWC6sw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mixtape-bushwick-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 81,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6994942, 'longitude': -73.9140196},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1533 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1533 Myrtle Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17183815248',
#    'display_phone': '(718) 381-5248',
#    'distance': 6799.136127053621},
#   {'id': 'w3ZyOZ8hYiYE57JmsWjJpw',
#    'alias': 'bagel-boss-east-village-new-york',
#    'name': 'Bagel Boss East Village',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SDpn4f48yYQR-6V1UqsZZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagel-boss-east-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7325, 'longitude': -73.98571},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '238 E 14th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['238 E 14th St', 'New York, NY 10003']},
#    'phone': '+16466096533',
#    'display_phone': '(646) 609-6533',
#    'distance': 3085.539521450322},
#   {'id': '1UOo0w-JNKASCMvSWnle0w',
#    'alias': 'old-country-coffee-new-york',
#    'name': 'Old Country Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ziym5ZHDsElePA1WVueAyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/old-country-coffee-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 233,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7544507270095,
#     'longitude': -73.9984663948417},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '455 W 34th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['455 W 34th St', 'New York, NY 10001']},
#    'phone': '+16468612171',
#    'display_phone': '(646) 861-2171',
#    'distance': 5460.531458009035},
#   {'id': 'TCYy1ULREceEiEu5h5FHPA',
#    'alias': 'olympias-finest-deli-new-york-5',
#    'name': 'Olympias Finest Deli',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4NOC-lMMSj3WaIW9TzdBGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olympias-finest-deli-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7444138481323,
#     'longitude': -73.9918421691789},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '761 6th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['761 6th Ave', 'New York, NY 10001']},
#    'phone': '+12129245074',
#    'display_phone': '(212) 924-5074',
#    'distance': 4338.0683973615905},
#   {'id': 'N1ONVWG0X8mDmk7QFM4DiA',
#    'alias': 'bake-a-bagel-maspeth',
#    'name': 'Bake a Bagel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fI6eBRJlV2nmDYDyU_q2cA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bake-a-bagel-maspeth?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72071, 'longitude': -73.9043},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '60-94 Flushing Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Maspeth',
#     'zip_code': '11378',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60-94 Flushing Ave', 'Maspeth, NY 11378']},
#    'phone': '+17183262197',
#    'display_phone': '(718) 326-2197',
#    'distance': 7773.087031931616},
#   {'id': 'Eed-9O8xP80b4L9zYJ_WOA',
#    'alias': 'pio-bagel-brooklyn',
#    'name': 'Pio Bagel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/d1DgE8K4MvbLjhHVMyFjdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pio-bagel-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 148,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6920693, 'longitude': -73.9865172},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '136 Lawrence St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136 Lawrence St', 'Brooklyn, NY 11201']},
#    'phone': '+17182372777',
#    'display_phone': '(718) 237-2777',
#    'distance': 1625.3513664372138},
#   {'id': 'ChloY7v4KGqx_Tl9D7kuEw',
#    'alias': 'avenue-x-bagels-brooklyn',
#    'name': 'Avenue X Bagels',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/alaZscbW5aEp7pXUSLC57A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/avenue-x-bagels-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.59206, 'longitude': -73.96091},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '2650C Coney Island Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11223',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2650C Coney Island Ave', 'Brooklyn, NY 11223']},
#    'phone': '+13475876820',
#    'display_phone': '(347) 587-6820',
#    'distance': 12912.869372022487},
#   {'id': '9uhWTKavezO5TKWMui-o3w',
#    'alias': 'la-bagel-delight-brooklyn-7',
#    'name': 'La Bagel Delight',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pNaZRMER4f2-BjvX4Xh-Dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-bagel-delight-brooklyn-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 186,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.687362, 'longitude': -73.975395},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '73 Lafayette Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['73 Lafayette Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17182463744',
#    'display_phone': '(718) 246-3744',
#    'distance': 2566.1262468634854},
#   {'id': 'w7zQ47EyJ6R7K_TEWZnInA',
#    'alias': 'spring-streets-finest-deli-new-york',
#    'name': 'Spring Streets Finest Deli',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ki7BxhVN3sCc7g9HJ7BsXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spring-streets-finest-deli-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72589, 'longitude': -74.0092899},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '322 Spring St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['322 Spring St', 'New York, NY 10013']},
#    'phone': '+12123432335',
#    'display_phone': '(212) 343-2335',
#    'distance': 2599.7744470537555},
#   {'id': 'uL709qg0IGe4KsNZk_AjxQ',
#    'alias': 'lions-milk-brooklyn-2',
#    'name': "Lion's Milk",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tz6iRZN6VX7Lxn7CAbze6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lions-milk-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 143,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'turkish', 'title': 'Turkish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7159199, 'longitude': -73.9558},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '104 Roebling St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['104 Roebling St', 'Brooklyn, NY 11211']},
#    'phone': '+17185990099',
#    'display_phone': '(718) 599-0099',
#    'distance': 3447.736050407977},
#   {'id': 'lWOkeS-wV4no8qqA9OwwEg',
#    'alias': 'doughnut-plant-new-york-6',
#    'name': 'Doughnut Plant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hLWKXsLv6hyltNSilBy8-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doughnut-plant-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3273,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.716334, 'longitude': -73.988652},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '379 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['379 Grand St', 'New York, NY 10002']},
#    'phone': '+12125053700',
#    'display_phone': '(212) 505-3700',
#    'distance': 1300.8284914110848},
#   {'id': '59-JJp5t2OCFifY7DUQ2rQ',
#    'alias': 'bricktown-bagel-and-cafe-long-island-city-16',
#    'name': 'Bricktown Bagel & Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dwv8wFYKNAch_eqWbwdLqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bricktown-bagel-and-cafe-long-island-city-16?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 278,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.74182, 'longitude': -73.95466},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '51-06 Vernon Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['51-06 Vernon Blvd', 'Long Island City, NY 11101']},
#    'phone': '+17183612428',
#    'display_phone': '(718) 361-2428',
#    'distance': 5246.461430282726},
#   {'id': 'AZIxbXMnIDkGU2P7pOhHkg',
#    'alias': 'tribeca-bagels-new-york',
#    'name': 'Tribeca Bagels',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KDlXK0qNjr37e7y2Nks7kA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tribeca-bagels-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 161,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.72097, 'longitude': -74.00436},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '374 Canal St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['374 Canal St', 'New York, NY 10013']},
#    'phone': '+12122268518',
#    'display_phone': '(212) 226-8518',
#    'distance': 1918.9835029867102},
#   {'id': 'gfgbbPRqVqSj_rxlSwhJhg',
#    'alias': 'black-star-bakery-and-cafe-long-island-city',
#    'name': 'Black Star Bakery & Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VW3TAoB9FGh57CMRUSBpCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-star-bakery-and-cafe-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 135,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7433494, 'longitude': -73.9580353},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2-10 50th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2-10 50th Ave', 'Long Island City, NY 11101']},
#    'phone': '+17184339189',
#    'display_phone': '(718) 433-9189',
#    'distance': 5212.243615213465},
#   {'id': 'HFOiW4RvijuoblE4DD3JwA',
#    'alias': 'dekalb-market-hall-brooklyn-2',
#    'name': 'Dekalb Market Hall',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p3HJcEcHV7KuX0XVh30KUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dekalb-market-hall-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 687,
#    'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.691025, 'longitude': -73.983311},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '445 Albee Square W',
#     'address2': 'Basement Level',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['445 Albee Square W',
#      'Basement Level',
#      'Brooklyn, NY 11201']},
#    'phone': '+19293596555',
#    'display_phone': '(929) 359-6555',
#    'distance': 1851.5130715768003},
#   {'id': 'VRhEPnjPI64dBC39gDD-Vw',
#    'alias': 'ic-brooklyn-cafe-brooklyn',
#    'name': 'IC Brooklyn Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CJuupHwAW0FAY66kRPGBlg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ic-brooklyn-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 115,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'acaibowls', 'title': 'Acai Bowls'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70124879999999, 'longitude': -73.9262574},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '117 Wilson Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['117 Wilson Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17184503346',
#    'display_phone': '(718) 450-3346',
#    'distance': 5754.119269251738},
#   {'id': 'biapLGctTtB9MDl2UW8bXQ',
#    'alias': 'eagle-trading-brooklyn',
#    'name': 'Eagle Trading',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FnTKNaz_yWEkqzMdL3xLBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eagle-trading-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 147,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.734981, 'longitude': -73.958175},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '258 Franklin St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['258 Franklin St', 'Brooklyn, NY 11222']},
#    'phone': '+17185763217',
#    'display_phone': '(718) 576-3217',
#    'distance': 4478.049032019955},
#   {'id': 'w8eAlTI-8pbVecPsWMrEMw',
#    'alias': 'baked-in-brooklyn-bakery-store-brooklyn',
#    'name': 'Baked In Brooklyn Bakery Store',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6FIArb2bNa931A807Kxl4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baked-in-brooklyn-bakery-store-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 259,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6589279174805,
#     'longitude': -73.9963531494141},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '755 5th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11232',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['755 5th Ave', 'Brooklyn, NY 11232']},
#    'phone': '+17187883164',
#    'display_phone': '(718) 788-3164',
#    'distance': 5176.155801775199},
#   {'id': 'rGfDX_ors68i8LnuG55NQA',
#    'alias': 'bagel-buffet-new-york-116',
#    'name': 'Bagel Buffet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/juaJYOWLzNXdv0D0Zm2d0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagel-buffet-new-york-116?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73691631697569,
#     'longitude': -73.99693574914174},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '510 Ave Of Americas',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['510 Ave Of Americas', 'New York, NY 10011']},
#    'phone': '+12129248911',
#    'display_phone': '(212) 924-8911',
#    'distance': 3506.5407245881674},
#   {'id': 'j1TePe2B6pjvvEg2VOLNcg',
#    'alias': 'gramercy-bagels-new-york',
#    'name': 'Gramercy Bagels',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ANHQ7yshMbdqg_fr55CeqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gramercy-bagels-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 173,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7371889, 'longitude': -73.9845285},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '246 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['246 3rd Ave', 'New York, NY 10010']},
#    'phone': '+12123880080',
#    'display_phone': '(212) 388-0080',
#    'distance': 3624.162599165757},
#   {'id': 'ht3DxDFrvMRSv9WeeX80NA',
#    'alias': 'lox-new-york',
#    'name': 'Lox',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nuRVECrmppv0gCwZ1JDaEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lox-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'kosher', 'title': 'Kosher'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7055377733267,
#     'longitude': -74.0180295074092},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '36 Battery Pl',
#     'address2': '',
#     'address3': 'Museum Of Jewish Heritage',
#     'city': 'New York',
#     'zip_code': '10280',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['36 Battery Pl',
#      'Museum Of Jewish Heritage',
#      'New York, NY 10280']},
#    'phone': '+16464374231',
#    'display_phone': '(646) 437-4231',
#    'distance': 2046.2401638344413},
#   {'id': 'lgndZLoGNjS8gSBx-fS-Uw',
#    'alias': 'la-bagel-delight-at-court-st-brooklyn-2',
#    'name': 'La Bagel Delight at Court St',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ic5GKwPywbfjjoiULT3-4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-bagel-delight-at-court-st-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 169,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.69117, 'longitude': -73.99182},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '90 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90 Court St', 'Brooklyn, NY 11201']},
#    'phone': '+17185220520',
#    'display_phone': '(718) 522-0520',
#    'distance': 1598.476178612692},
#   {'id': 'U5hCNNyJmb7f3dmC1HTzSQ',
#    'alias': 'juniors-restaurant-and-bakery-45th-st-new-york',
#    'name': "Junior's Restaurant & Bakery - 45th St",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RwLK04cnu1y4t8xPRY3mwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/juniors-restaurant-and-bakery-45th-st-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4735,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75754564001459,
#     'longitude': -73.98608001118411},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1515 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1515 Broadway', 'New York, NY 10036']},
#    'phone': '+12123022000',
#    'display_phone': '(212) 302-2000',
#    'distance': 5834.523948198199},
#   {'id': 'cCesIqo-LQt0cRlZAnrAZQ',
#    'alias': 'friedmans-new-york-71',
#    'name': 'Friedmans',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oVctx3sVd5jF_vBVAjybUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/friedmans-new-york-71?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2531,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74839, 'longitude': -73.99062},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '132 W 31st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['132 W 31st St', 'New York, NY 10001']},
#    'phone': '+12129719400',
#    'display_phone': '(212) 971-9400',
#    'distance': 4771.255588008896},
#   {'id': 'qQG3McQHA6600GhZBgmLLg',
#    'alias': 'ar-hot-bagels-brooklyn',
#    'name': 'AR Hot Bagels',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zkA1Ow3SBuIdYdzw2a5sXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ar-hot-bagels-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.678116, 'longitude': -74.012321},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '350 Van Brunt St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['350 Van Brunt St', 'Brooklyn, NY 11231']},
#    'phone': '+17184039342',
#    'display_phone': '(718) 403-9342',
#    'distance': 3397.748310048559},
#   {'id': 'XKWvRI7WI4LotDLUboUUGA',
#    'alias': 'barney-greengrass-new-york',
#    'name': 'Barney Greengrass',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/je84DKJxPdEQq9QFzS3eWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barney-greengrass-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 786,
#    'categories': [{'alias': 'gourmet', 'title': 'Specialty Food'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7879308300971,
#     'longitude': -73.9745054748688},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '541 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['541 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12127244707',
#    'display_phone': '(212) 724-4707',
#    'distance': 9322.258112599642},
#   {'id': 'ga6sRtE0l85iftw_5-W84Q',
#    'alias': 'dominique-ansel-bakery-new-york',
#    'name': 'Dominique Ansel Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ae6sDhEfUXTE5EKfWSOrCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dominique-ansel-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4788,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72522, 'longitude': -74.00291},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '189 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['189 Spring St', 'New York, NY 10012']},
#    'phone': '+12122192773',
#    'display_phone': '(212) 219-2773',
#    'distance': 2316.930739426023},
#   {'id': '7akz4cCMAn0Ze6JKMfU5oQ',
#    'alias': 'mazzola-bakery-brooklyn',
#    'name': 'Mazzola Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T3F4mUreVwKGewOLC0NS6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mazzola-bakery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 214,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68328, 'longitude': -73.999664},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '192 Union St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['192 Union St', 'Brooklyn, NY 11231']},
#    'phone': '+17186431719',
#    'display_phone': '(718) 643-1719',
#    'distance': 2502.8313332577995},
#   {'id': '0dO6JJPmkivbK8-Qu5eUYg',
#    'alias': 'toasties-new-york-6',
#    'name': 'Toasties',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6ZLHoCkcZyxAhDriBfz1sA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/toasties-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 377,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76006, 'longitude': -73.98306},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '148 W 49th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['148 W 49th St', 'New York, NY 10019']},
#    'phone': '+12123984900',
#    'display_phone': '(212) 398-4900',
#    'distance': 6144.705575955638},
#   {'id': 'F8RLZFoTxOO_GBPJNjz3kA',
#    'alias': 'marks-off-madison-new-york',
#    'name': "Mark's Off Madison",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HtTT8JEA5dcOO6JAto4I_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marks-off-madison-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.742325, 'longitude': -73.986271},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '41 Madison Ave',
#     'address2': 'Between Park & Madison',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41 Madison Ave',
#      'Between Park & Madison',
#      'New York, NY 10010']},
#    'phone': '+16468388300',
#    'display_phone': '(646) 838-8300',
#    'distance': 4156.626153088693},
#   {'id': 'O0xFECgTDf1rbZzW9qUULQ',
#    'alias': 'peter-pan-donut-and-pastry-shop-brooklyn-2',
#    'name': 'Peter Pan Donut & Pastry Shop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HDnInssfBVBX6cOke14p9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peter-pan-donut-and-pastry-shop-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1406,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.726086, 'longitude': -73.952308},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '727 Manhattan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['727 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183893676',
#    'display_phone': '(718) 389-3676',
#    'distance': 4217.718983924479},
#   {'id': 'tQIC8V5c9vwaakcOSv62ig',
#    'alias': 'hudson-bagels-new-york',
#    'name': 'Hudson Bagels',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gws8_RMb1CfERoReZGH3-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hudson-bagels-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 133,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.73341, 'longitude': -74.00364},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '82 Christopher St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['82 Christopher St', 'New York, NY 10014']},
#    'phone': '+12126752906',
#    'display_phone': '(212) 675-2906',
#    'distance': 3204.311250739395},
#   {'id': '8tbzYLbnTS7aAeIv1YNeGA',
#    'alias': 'ediths-brooklyn',
#    'name': "Edith's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gnLj7Nwk0SXYlq297BkmAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ediths-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71171, 'longitude': -73.94911},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '495 Lorimer St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['495 Lorimer St', 'Brooklyn, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3866.272888895111},
#   {'id': 'G18cPTEjuxXx957dGYBDAQ',
#    'alias': 'marlow-and-sons-brooklyn-2',
#    'name': 'Marlow & Sons',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3N2dy6_fkiiqQatHUfY3rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marlow-and-sons-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 527,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7106126934043,
#     'longitude': -73.9658814005443},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '81 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81 Broadway', 'Brooklyn, NY 11249']},
#    'phone': '+17183841441',
#    'display_phone': '(718) 384-1441',
#    'distance': 2462.8203943048193}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                       Restaurant          Type Price Rating  \
# 0                    Bagel Oasis        Bagels     $      4
# 1               Fiction Bar/Cafe  Coffee & Tea     $    4.5
# 2             Sunny Delicatessen         Delis     $      5
# 3          Brooklyn-Heights Deli         Delis    $$      4
# 4  Zucker's Bagels & Smoked Fish        Bagels     $      3
#
#                      Address        Lat        Lng  \
# 0  18312 Horace Harding Expy  40.739435 -73.790506
# 1              308 Hooper St  40.707248 -73.953750
# 2           153 Joralemon St  40.693065 -73.993339
# 3               292 Henry St  40.691391 -73.996246
# 4               40 E 23rd St  40.740301 -73.987360
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/bagel-oasis-fresh-mea...  psx14GCq03cuRCWJIs0CuQ
# 1  https://www.yelp.com/biz/fiction-bar-cafe-broo...  A8jRnZGiMJiMpfHt8qKV3w
# 2  https://www.yelp.com/biz/sunny-delicatessen-br...  qn8kAN7VOCx1nJmSJ2FBuQ
# 3  https://www.yelp.com/biz/brooklyn-heights-deli...  k5uLQag3XnKyd_ZwunQuKg
# 4  https://www.yelp.com/biz/zuckers-bagels-and-sm...  ZO9CKtJ9tvPSwEns-semKA

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"bagel","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [{'id': 'rY-EP5WCxQS0Ti-cdLSO7A',
#    'alias': 'empire-bagels-bronx',
#    'name': 'Empire Bagels',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SMKYRsQ9Xpg1AEeFixSfSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/empire-bagels-bronx?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 121,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.8494, 'longitude': -73.83062},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3101 Westchester Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10461',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3101 Westchester Ave', 'Bronx, NY 10461']},
#    'phone': '+17188284530',
#    'display_phone': '(718) 828-4530',
#    'distance': 21114.309925623686},
#   {'id': 'N7ux8gAg5udFTgZ2Y5P-6A',
#    'alias': 'ceci-cela-new-york-2',
#    'name': 'Ceci-Cela',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/v4ZxqpyctSZ0NLl-ExfuQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ceci-cela-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 577,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7202848335508,
#     'longitude': -73.993055798842},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '14 Delancey St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 Delancey St', 'New York, NY 10012']},
#    'phone': '+12122749179',
#    'display_phone': '(212) 274-9179',
#    'distance': 1653.420076703117},
#   {'id': 'tJWQnagxMYkFZXKrdiO3gg',
#    'alias': 'bagel-hole-brooklyn-3',
#    'name': 'Bagel Hole',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RY8hpdaNyQgkoAP1JmgkCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagel-hole-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 274,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.66489, 'longitude': -73.983619},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '400 7th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['400 7th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187884014',
#    'display_phone': '(718) 788-4014',
#    'distance': 4604.997386405979},
#   {'id': 'gC7QKqUe2wrxUTxL11ab1A',
#    'alias': 'gertie-brooklyn',
#    'name': 'Gertie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uTGtDnbejClzI_gxPUOEZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gertie-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 96,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.712389, 'longitude': -73.9555675},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '357 Grand St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['357 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17186360902',
#    'display_phone': '(718) 636-0902',
#    'distance': 3354.2484960353863},
#   {'id': 'tPfXeeC54I8MLSUE6Tnzcw',
#    'alias': 'bagel-belly-new-york',
#    'name': 'Bagel Belly',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zlo5oZO-a4233nO0IaUbQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagel-belly-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 168,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.733074, 'longitude': -73.987693},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '114 Third Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['114 Third Ave', 'New York, NY 10003']},
#    'phone': '+12123532299',
#    'display_phone': '(212) 353-2299',
#    'distance': 3123.4501758967003},
#   {'id': 'MN17Htz75s1aZvO5nltzPA',
#    'alias': 'haven-cafe-new-york',
#    'name': 'Haven Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gnfsKwbuUOQduwFOOKGnhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/haven-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71885, 'longitude': -73.99668},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '147 Mott St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['147 Mott St', 'New York, NY 10013']},
#    'phone': '+16462076574',
#    'display_phone': '(646) 207-6574',
#    'distance': 1503.0474404150254},
#   {'id': 'DxeD4Jw3gsImI-olCOB0bA',
#    'alias': 'little-canal-new-york-2',
#    'name': 'Little Canal',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/35ZbxM9Zh8ex3U4-GPWknA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-canal-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 128,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.714309, 'longitude': -73.990417},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '26 Canal St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 Canal St', 'New York, NY 10002']},
#    'phone': '+19174727479',
#    'display_phone': '(917) 472-7479',
#    'distance': 1035.3030353262682},
#   {'id': 'UtyTBbBL6reUN68CvN5Lnw',
#    'alias': 'everything-bagels-and-deli-bayonne',
#    'name': 'Everything Bagels & Deli',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/e_Wywy7DJY_MOmJ8kXxgSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/everything-bagels-and-deli-bayonne?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6611, 'longitude': -74.11425},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '91 E 22nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'Bayonne',
#     'zip_code': '07002',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['91 E 22nd St', 'Bayonne, NJ 07002']},
#    'phone': '+12016209535',
#    'display_phone': '(201) 620-9535',
#    'distance': 11258.226789425962},
#   {'id': 'ROFCA0HkLDA1KZWzAOnCxw',
#    'alias': 'penny-house-cafe-brooklyn',
#    'name': 'Penny House Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pXEvi5p2CpqRZPj4S5ODnQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/penny-house-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 277,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.676044, 'longitude': -73.963713},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '732 Washington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['732 Washington Ave', 'Brooklyn, NY 11238']},
#    'phone': '+13472407281',
#    'display_phone': '(347) 240-7281',
#    'distance': 4163.5792071370415},
#   {'id': 's_YuHngBngWwzpcKNIM71A',
#    'alias': 'pi-bakerie-new-york-2',
#    'name': 'Pi Bakerie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/z3XmLECFFhL2wstbpGz7Sg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pi-bakerie-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 293,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72361, 'longitude': -74.00329},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '512 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['512 Broome St', 'New York, NY 10013']},
#    'phone': '+12122262701',
#    'display_phone': '(212) 226-2701',
#    'distance': 2162.699623969127},
#   {'id': 'NzHiK8Csmypx4f6jYhSqiQ',
#    'alias': 'lennys-bagels-new-york-2',
#    'name': "Lenny's Bagels",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/M2wWtEdaMiuEZXbhBkPnLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lennys-bagels-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 161,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7961904, 'longitude': -73.9709623},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '2601 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2601 Broadway', 'New York, NY 10025']},
#    'phone': '+12122220410',
#    'display_phone': '(212) 222-0410',
#    'distance': 10278.291437341539},
#   {'id': 'WKDdD8Z17-P1XhkyJtDEFA',
#    'alias': 'johnys-luncheonette-new-york',
#    'name': "Johny's Luncheonette",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/R7iqSJVtx8MQoZd-nP7yMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/johnys-luncheonette-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1029,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7444458007812,
#     'longitude': -73.9930725097656},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '124 W 25th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['124 W 25th St', 'New York, NY 10001']},
#    'phone': '+12122436230',
#    'display_phone': '(212) 243-6230',
#    'distance': 4335.848559426747},
#   {'id': 'yc17eYI-lv59ShQ3zMy_Bg',
#    'alias': 'pick-a-bagel-new-york-4',
#    'name': 'Pick a Bagel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/M1rddLzByipAGgZWFTQ_5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pick-a-bagel-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 343,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7384, 'longitude': -73.98252},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '210 E 23rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['210 E 23rd St', 'New York, NY 10010']},
#    'phone': '+12126861414',
#    'display_phone': '(212) 686-1414',
#    'distance': 3789.0823749972756},
#   {'id': 'PQAIs-ZPN7QrBvJ-F9pE8w',
#    'alias': 'awesome-deli-brooklyn',
#    'name': 'Awesome Deli',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/a-tHHezDs0tG17Io8CAjag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/awesome-deli-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7102999, 'longitude': -73.96629},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '60 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Broadway', 'Brooklyn, NY 11211']},
#    'phone': '+17183842806',
#    'display_phone': '(718) 384-2806',
#    'distance': 2443.9214913129276},
#   {'id': 'Qmv4SPta2zx7MhKit8ywag',
#    'alias': 'absolute-coffee-brooklyn',
#    'name': 'Absolute Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WrEZlU_pGNek1-Bpb5vdtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/absolute-coffee-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 196,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68827, 'longitude': -73.987569},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '327 Atlantic Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['327 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17185220969',
#    'display_phone': '(718) 522-0969',
#    'distance': 1995.2838490428082},
#   {'id': '3dP2gdfDLr-YEVmopobJpA',
#    'alias': 'chip-city-williamsburg-new-york',
#    'name': 'Chip City Williamsburg',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/D821SILNrQrlEajBMcv26Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chip-city-williamsburg-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.720009, 'longitude': -73.961744},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '123 Kent Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['123 Kent Ave', 'New York, NY 11249']},
#    'phone': '+19293970344',
#    'display_phone': '(929) 397-0344',
#    'distance': 3185.059149316024},
#   {'id': 'tzkq2pVSrCL9N5aDRl5B9w',
#    'alias': 'the-bagelnaitor-brooklyn',
#    'name': 'The Bagelnaitor',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TGmpbNt2bXspf_X9hp42CA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bagelnaitor-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.700798, 'longitude': -73.942815},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '749 Flushing Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['749 Flushing Ave', 'Brooklyn, NY 11206']},
#    'phone': '+13477991343',
#    'display_phone': '(347) 799-1343',
#    'distance': 4370.715265944003},
#   {'id': 'x3RfohtUQPWHS1l1VfAMTQ',
#    'alias': 'pick-a-bagel-new-york-15',
#    'name': 'Pick A Bagel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TRvomzC6Cf8Ydxtq9BrocA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pick-a-bagel-new-york-15?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 938,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.76462, 'longitude': -73.98494},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '891 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['891 8th Ave', 'New York, NY 10019']},
#    'phone': '+12125828333',
#    'display_phone': '(212) 582-8333',
#    'distance': 6608.934065106378},
#   {'id': 'I41VRmgmiQ4kITgFZtJlvQ',
#    'alias': 'old-poland-bakery-brooklyn-2',
#    'name': 'Old Poland Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/siXMguqT0CH7vYT1ouoRDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/old-poland-bakery-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.731071, 'longitude': -73.9542397},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '926 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['926 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4416.609623364894},
#   {'id': 'pSQQ-0nm96PFLwheAsrtlg',
#    'alias': 'bagels-plus-and-deli-secaucus-2',
#    'name': 'Bagels Plus & Deli',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ca1SgAYx_uIHGpYYjufwcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagels-plus-and-deli-secaucus-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 92,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.785597, 'longitude': -74.045558},
#    'transactions': ['pickup'],
#    'price': '$',
#    'location': {'address1': '700 Plz Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Secaucus',
#     'zip_code': '07094',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['700 Plz Dr', 'Secaucus, NJ 07094']},
#    'phone': '+12013300744',
#    'display_phone': '(201) 330-0744',
#    'distance': 9903.72715783461},
#   {'id': '7DOgevJnErkLNh4dWVh2zw',
#    'alias': 'hot-bagel-and-deli-bay-ridge',
#    'name': 'Hot Bagel and Deli',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2ySMmPFdEu_WZOdAZOW3PQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hot-bagel-and-deli-bay-ridge?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6342812, 'longitude': -74.0262985},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '7017 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bay Ridge',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7017 3rd Ave', 'Bay Ridge, NY 11209']},
#    'phone': '+17187482660',
#    'display_phone': '(718) 748-2660',
#    'distance': 8359.050041975337},
#   {'id': 'wWhZvkaFrntlSf1CWvD1Zw',
#    'alias': 'cafe-patoro-new-york',
#    'name': 'Cafe Patoro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Nnlsd9Wl7KFVVqZxtDRWpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-patoro-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 182,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7072720974983,
#     'longitude': -74.0023160353303},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '223 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['223 Front St', 'New York, NY 10038']},
#    'phone': '+19172620031',
#    'display_phone': '(917) 262-0031',
#    'distance': 706.1266596183273},
#   {'id': 'HUlbrPvAr6sXuBfp5z1MWA',
#    'alias': 'urban-backyard-new-york',
#    'name': 'Urban Backyard',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bB8vr7pVnZmY5x1Snh2WoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/urban-backyard-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 210,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72077, 'longitude': -73.99646},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '180 Mulberry St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['180 Mulberry St', 'New York, NY 10012']},
#    'phone': '+16466929957',
#    'display_phone': '(646) 692-9957',
#    'distance': 1716.018342303412},
#   {'id': '0EOWrLcnWEO1pP7bZafofw',
#    'alias': 'wonder-bagels-jersey-city',
#    'name': 'Wonder Bagels',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Zg13SU3JS8a8YpXxzBfOkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wonder-bagels-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 521,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7205996367127,
#     'longitude': -74.0469315376866},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '517 Jersey Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['517 Jersey Ave', 'Jersey City, NJ 07302']},
#    'phone': '+12014338082',
#    'display_phone': '(201) 433-8082',
#    'distance': 4745.825903018381},
#   {'id': '1XH47HzrPYmPWHEgS6PH5w',
#    'alias': 'franklin-corner-cafe-brooklyn',
#    'name': 'Franklin Corner Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2A5MLwYecTmyW3_Vdq2MCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/franklin-corner-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.732851, 'longitude': -73.95783},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '210 Franklin St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['210 Franklin St', 'Brooklyn, NY 11222']},
#    'phone': '+17183894575',
#    'display_phone': '(718) 389-4575',
#    'distance': 4326.760060397871},
#   {'id': 'eAWGPqVKNrUuLw7V5S8mYQ',
#    'alias': 'bagel-boss-new-york-8',
#    'name': 'Bagel Boss',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9hvEzEPd3vxq1NAlHbIBYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagel-boss-new-york-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 181,
#    'categories': [{'alias': 'kosher', 'title': 'Kosher'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.73237, 'longitude': -73.98219},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '263 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['263 1st Ave', 'New York, NY 10003']},
#    'phone': '+12123889292',
#    'display_phone': '(212) 388-9292',
#    'distance': 3160.4975018572427},
#   {'id': 'fZYymv8linCo2id7wIokwQ',
#    'alias': 'bagel-boy-brooklyn',
#    'name': 'Bagel Boy',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DwH3aNL0vuanNsvdq8jSig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagel-boy-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 291,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6277725075456,
#     'longitude': -74.0295010981476},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '8002 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8002 3rd Ave', 'Brooklyn, NY 11209']},
#    'phone': '+17187480366',
#    'display_phone': '(718) 748-0366',
#    'distance': 9133.00541987983},
#   {'id': '4GBqDgTYsV7owGzNMyAFKA',
#    'alias': 'sullivan-street-bakery-new-york-3',
#    'name': 'Sullivan Street Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9IqTUcD62P3ziCRpCel3dA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sullivan-street-bakery-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 522,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76366, 'longitude': -73.994716},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '533 W 47th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['533 W 47th St', 'New York, NY 10036']},
#    'phone': '+12122655580',
#    'display_phone': '(212) 265-5580',
#    'distance': 6473.318564773586},
#   {'id': 'ZP2uwlP0s21sh0wlPR-9Sw',
#    'alias': 'catherine-deli-and-bagel-new-york',
#    'name': 'Catherine  Deli and Bagel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OS77WHv4JKTEjkxFao_tZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/catherine-deli-and-bagel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7120098, 'longitude': -73.9966423},
#    'transactions': [],
#    'location': {'address1': '43 Catherine St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43 Catherine St', 'New York, NY 10038']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 756.3636655316732},
#   {'id': 'g3jNtkQZVZrrC823oBxdtg',
#    'alias': 'lafayette-grand-café-and-bakery-new-york',
#    'name': 'Lafayette Grand Café & Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Z0k9Sjk5k57EqC9h_NMvcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lafayette-grand-caf%C3%A9-and-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 956,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.727617, 'longitude': -73.993464},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '380 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['380 Lafayette St', 'New York, NY 10003']},
#    'phone': '+12125333000',
#    'display_phone': '(212) 533-3000',
#    'distance': 2466.4165560809},
#   {'id': 'XpAZBiSrLNi0t332tWxYcQ',
#    'alias': 'acme-smoked-fish-brooklyn',
#    'name': 'Acme Smoked Fish',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MzabtjAsxeDPxDFnlf9kCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/acme-smoked-fish-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 144,
#    'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72542, 'longitude': -73.95662},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '30 Gem St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30 Gem St', 'Brooklyn, NY 11222']},
#    'phone': '+17183838585',
#    'display_phone': '(718) 383-8585',
#    'distance': 3888.530763674833},
#   {'id': '5Iq46XSngo4RoUAedDxK5g',
#    'alias': 'comptons-astoria',
#    'name': "Compton's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LoNQsfiy0KTzTmeU53SgoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/comptons-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 156,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77086, 'longitude': -73.930221},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '30-02 14th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30-02 14th St', 'Astoria, NY 11102']},
#    'phone': '+19177450573',
#    'display_phone': '(917) 745-0573',
#    'distance': 9058.1118419921},
#   {'id': 'Qu9J_yrZnq07RsnwYEYdtQ',
#    'alias': 'dggd-coffee-shop-downtown-brooklyn',
#    'name': 'DGGD Coffee Shop',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dggd-coffee-shop-downtown-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6937508652269,
#     'longitude': -73.9871062338352},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '336 Jay St',
#     'address2': '',
#     'address3': '',
#     'city': 'Downtown Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['336 Jay St', 'Downtown Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1434.5347527298295},
#   {'id': 'QOmvgnyNHrD6J8vuwaTOkg',
#    'alias': 'brooklyn-bagel-and-coffee-company-astoria-5',
#    'name': 'Brooklyn Bagel & Coffee Company',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yA-naFbwqz2Taad0Wc-Uqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-bagel-and-coffee-company-astoria-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 476,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76457, 'longitude': -73.91703},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '36-14 30th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['36-14 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17187771121',
#    'display_phone': '(718) 777-1121',
#    'distance': 9252.00349643318},
#   {'id': 'wXiIxbnFRaFBS9RI4wJrdw',
#    'alias': 'baba-cool-brooklyn',
#    'name': 'Baba Cool',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/n_CzesswTxIUNxHX1XuUkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baba-cool-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 214,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68701, 'longitude': -73.97537},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '64 Lafayette Ave',
#     'address2': 'Ste B',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64 Lafayette Ave', 'Ste B', 'Brooklyn, NY 11217']},
#    'phone': '+13476892344',
#    'display_phone': '(347) 689-2344',
#    'distance': 2600.435369431958},
#   {'id': 'Ha2rlHHhLiSt2JliLs7f-A',
#    'alias': 'zucker-s-bagels-and-smoked-fish-new-york',
#    'name': 'Zucker’s Bagels & Smoked Fish',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W6Sxv5l6xs3qb8yuLEu8wg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zucker-s-bagels-and-smoked-fish-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 40.71010728801129,
#     'longitude': -74.00728481978022},
#    'transactions': [],
#    'location': {'address1': '125 Fulton St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['125 Fulton St', 'New York, NY 10038']},
#    'phone': '+12123619400',
#    'display_phone': '(212) 361-9400',
#    'distance': 1211.5942834910747},
#   {'id': 'gA0VbcoBLCiD2EpSC6vWeg',
#    'alias': 'partners-coffee-long-island-city',
#    'name': 'Partners Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_e06-YI5h2zMRfO4DourEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/partners-coffee-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 174,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74769, 'longitude': -73.9416},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '26-25 Jackson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26-25 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+13475310477',
#    'display_phone': '(347) 531-0477',
#    'distance': 6460.204326416233},
#   {'id': '6XX2Ytf8nYqh8dRhz9Kk_g',
#    'alias': 'mikes-bagels-new-york',
#    'name': "Mike's Bagels",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sxrL2s_MlX3_MJIIOB-ZkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mikes-bagels-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 211,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.84136, 'longitude': -73.93987},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '4003 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10032',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4003 Broadway', 'New York, NY 10032']},
#    'phone': '+12129282300',
#    'display_phone': '(212) 928-2300',
#    'distance': 15793.229592945652},
#   {'id': 'lM44NybalPaw3aiw24WOdA',
#    'alias': 'court-street-grocers-brooklyn',
#    'name': 'Court Street Grocers',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AqgaMRGE9rLqJ8HHaFmzmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/court-street-grocers-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 300,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'cheese', 'title': 'Cheese Shops'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.676244, 'longitude': -73.998717},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '485 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['485 Court St', 'Brooklyn, NY 11231']},
#    'phone': '+17187227229',
#    'display_phone': '(718) 722-7229',
#    'distance': 3268.3361202669307},
#   {'id': '7egiLH0paGKy0eINpHgIwg',
#    'alias': 'nagles-bagels-bedford-stuyvesant-3',
#    'name': "Nagle's Bagels",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/K4qUHJ8YsYR4XiF_pRvULA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nagles-bagels-bedford-stuyvesant-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 138,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.68441, 'longitude': -73.94426},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '378 Tompkins Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bedford-Stuyvesant',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['378 Tompkins Ave', 'Bedford-Stuyvesant, NY 11216']},
#    'phone': '+13473053007',
#    'display_phone': '(347) 305-3007',
#    'distance': 4819.603759527193},
#   {'id': 'o4MpyA_z4Jb-WqJwDk_Szg',
#    'alias': 'we-bagel-long-island-city',
#    'name': 'We Bagel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fYPBX02RwGG_gq4Oj9_Agg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/we-bagel-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74461, 'longitude': -73.9506},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '47-11 11th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47-11 11th St', 'Long Island City, NY 11101']},
#    'phone': '+17182551992',
#    'display_phone': '(718) 255-1992',
#    'distance': 5711.45356233489},
#   {'id': 'GlPJPpKvPR4d8dmcSEYpdA',
#    'alias': 'takahachi-bakery-new-york',
#    'name': 'Takahachi Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oP2xYZjbAa8akp-9CLmiVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/takahachi-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 947,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71393, 'longitude': -74.00822},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '25 Murray St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 Murray St', 'New York, NY 10007']},
#    'phone': '+12127915550',
#    'display_phone': '(212) 791-5550',
#    'distance': 1511.7020935512141},
#   {'id': 'ZMQzXIiqdBIuicFySTWGKg',
#    'alias': 'dough-new-york-2',
#    'name': 'Dough',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Mg3YZ1U-UpkFCCiaL5Remw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dough-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1571,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73931, 'longitude': -73.99243},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '14 W 19th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 W 19th St', 'New York, NY 10011']},
#    'phone': '+12122436844',
#    'display_phone': '(212) 243-6844',
#    'distance': 3771.936848199482},
#   {'id': 'zUv1BNm_a9-3DkxrCG3tng',
#    'alias': 'friedmans-new-york-70',
#    'name': "Friedman's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Na8uc4gUJWcc8WKXWcmjEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/friedmans-new-york-70?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 659,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.755311, 'longitude': -73.998389},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '450 10th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['450 10th Ave', 'New York, NY 10018']},
#    'phone': '+12122681100',
#    'display_phone': '(212) 268-1100',
#    'distance': 5555.5851283960355},
#   {'id': 'bZ6HG9K2T4fcn7CihNTPfQ',
#    'alias': 'bakers-dozen-bagels-ridgewood',
#    'name': 'Bakers Dozen Bagels',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2uDcHlEPEnuGdO5PF1qO5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bakers-dozen-bagels-ridgewood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70876617, 'longitude': -73.8985385},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '6608 Fresh Pond Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6608 Fresh Pond Rd', 'Ridgewood, NY 11385']},
#    'phone': '+17183663330',
#    'display_phone': '(718) 366-3330',
#    'distance': 8078.8173940214665},
#   {'id': 'jNRT5vY1Hvp5WDTaHy4Mhw',
#    'alias': 'sarges-delicatessen-and-diner-new-york-2',
#    'name': "Sarge's Delicatessen & Diner",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xSbz5c8sTq4F8zcbO3w15A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sarges-delicatessen-and-diner-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1216,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7473279523583,
#     'longitude': -73.9772017867971},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '548 3rd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['548 3rd Ave', 'New York, NY 10016']},
#    'phone': '+12126790442',
#    'display_phone': '(212) 679-0442',
#    'distance': 4874.79758041062},
#   {'id': 'T55YbUuuYSmBtoN3b2mfzA',
#    'alias': 'prospect-provisions-brooklyn',
#    'name': 'Prospect Provisions',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Nny7yksWTA4DvrhvS4i7mA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prospect-provisions-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 126,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.6649938946527,
#     'longitude': -73.9930540403283},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '597 4th Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['597 4th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+13477632777',
#    'display_phone': '(347) 763-2777',
#    'distance': 4499.151062407403},
#   {'id': 'QWaSFpv0ujHM09kbilB-PQ',
#    'alias': 'hot-bagels-brooklyn',
#    'name': 'Hot Bagels',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8V7FOsdbzZwjsik4slWbSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hot-bagels-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 85,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.643377, 'longitude': -73.978544},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '127 Church Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11218',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['127 Church Ave', 'Brooklyn, NY 11218']},
#    'phone': '+17184385650',
#    'display_phone': '(718) 438-5650',
#    'distance': 7028.262209663983},
#   {'id': 'MHtbBc2np3sR7jiV9GphNg',
#    'alias': 'tribecas-kitchen-new-york',
#    'name': "Tribeca's Kitchen",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bn5YpHm-vpd85jXThFjJqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tribecas-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 552,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7162705535921,
#     'longitude': -74.0072225927912},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '200 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 Church St', 'New York, NY 10013']},
#    'phone': '+12122275100',
#    'display_phone': '(212) 227-5100',
#    'distance': 1623.7772210156222},
#   {'id': 'qoFxbBRTUHMsBk8JUBeYpA',
#    'alias': 'lic-bagel-and-deli-long-island-city',
#    'name': 'LIC Bagel & Deli',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/J4B-qdy4XWTo7wOWAnA1Mg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lic-bagel-and-deli-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.751623, 'longitude': -73.938682},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '41-04 27th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41-04 27th St', 'Long Island City, NY 11101']},
#    'phone': '+17187073333',
#    'display_phone': '(718) 707-3333',
#    'distance': 6951.611869470013}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#       Restaurant            Type Price Rating               Address  \
# 0  Empire Bagels          Bagels     $    4.5  3101 Westchester Ave
# 1      Ceci-Cela        Bakeries    $$      4        14 Delancey St
# 2     Bagel Hole          Bagels     $    3.5           400 7th Ave
# 3         Gertie  American (New)    $$      4          357 Grand St
# 4    Bagel Belly          Bagels     $      3         114 Third Ave
#
#          Lat        Lng                                                url  \
# 0  40.849400 -73.830620  https://www.yelp.com/biz/empire-bagels-bronx?a...
# 1  40.720285 -73.993056  https://www.yelp.com/biz/ceci-cela-new-york-2?...
# 2  40.664890 -73.983619  https://www.yelp.com/biz/bagel-hole-brooklyn-3...
# 3  40.712389 -73.955568  https://www.yelp.com/biz/gertie-brooklyn?adjus...
# 4  40.733074 -73.987693  https://www.yelp.com/biz/bagel-belly-new-york?...
#
#                        ID
# 0  rY-EP5WCxQS0Ti-cdLSO7A
# 1  N7ux8gAg5udFTgZ2Y5P-6A
# 2  tJWQnagxMYkFZXKrdiO3gg
# 3  gC7QKqUe2wrxUTxL11ab1A
# 4  tPfXeeC54I8MLSUE6Tnzcw

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                                           Restaurant                    Type  \
# 0                                          Friedmans          American (New)
# 1                              High Street On Hudson          American (New)
# 2                                             Gertie          American (New)
# 3                                  Tribeca's Kitchen          American (New)
# 4                                      Marlow & Sons          American (New)
# 5                                   Bagels & Schmear                  Bagels
# 6                                       Pick A Bagel                  Bagels
# 7                                    The Bagelnaitor                  Bagels
# 8                                  Black Seed Bagels                  Bagels
# 9                                   The Bagel Market                  Bagels
# 10                                       Bagel World                  Bagels
# 11                                        H&H Bagels                  Bagels
# 12                                       Ess-a-Bagel                  Bagels
# 13                                     Mike's Bagels                  Bagels
# 14                                      Bagel Buffet                  Bagels
# 15                                   Gramercy Bagels                  Bagels
# 16                          Cafe Panino Mucho Giusto                  Bagels
# 17                             Russ & Daughters Cafe                  Bagels
# 18                      La Bagel Delight at Court St                  Bagels
# 19                                     Wonder Bagels                  Bagels
# 20                                      Myrtle Bagel                  Bagels
# 21                                Greenberg’s Bagels                  Bagels
# 22                                       Bagel Bob's                  Bagels
# 23                                  La Bagel Delight                  Bagels
# 24                                      Pick a Bagel                  Bagels
# 25                                        Bagelworks                  Bagels
# 26                     Zucker's Bagels & Smoked Fish                  Bagels
# 27                                         Bagel Boy                  Bagels
# 28                                    The Bagel Shop                  Bagels
# 29                                       Bagel Oasis                  Bagels
# ..                                               ...                     ...
# 170                              Katz's Delicatessen                   Delis
# 171                       Spring Streets Finest Deli                   Delis
# 172                                   Tribeca Bagels                   Delis
# 173                                            Dough                Desserts
# 174                                   Doughnut Plant                  Donuts
# 175                             The Doughnut Project                  Donuts
# 176                               Dekalb Market Hall              Food Court
# 177                         Time Out Market New York              Food Court
# 178                    Sarge's Delicatessen Downtown  Food Delivery Services
# 179                    Lafayette Grand Café & Bakery                  French
# 180                             Court Street Grocers                 Grocery
# 181                                        Bagel Pub  Juice Bars & Smoothies
# 182                             Olympias Finest Deli  Juice Bars & Smoothies
# 183                    Yonah Schimmel's Knish Bakery                  Kosher
# 184                                     2nd Ave Deli                  Kosher
# 185                                       Bagel Boss                  Kosher
# 186                                        Juliana's                   Pizza
# 187                              Brooklyn Bread Cafe              Sandwiches
# 188                              Prospect Provisions              Sandwiches
# 189                                Sunny and Annie's              Sandwiches
# 190                                         Toasties              Sandwiches
# 191                                        Baba Cool              Sandwiches
# 192                                             Bite              Sandwiches
# 193                                        Compton's              Sandwiches
# 194                                 Acme Smoked Fish         Seafood Markets
# 195  Shelsky's of Brooklyn Appetizing & Delicateseen         Seafood Markets
# 196                                Barney Greengrass          Specialty Food
# 197                                      Mekelburg's          Specialty Food
# 198                                        B&H Dairy              Vegetarian
# 199                              Knickerbocker Bagel                   Wraps
#
#     Rating Price                    Address        Lat        Lng  \
# 0        4    $$              132 W 31st St  40.748390 -73.990620
# 1        4    $$              637 Hudson St  40.738880 -74.005740
# 2        4    $$               357 Grand St  40.712389 -73.955568
# 3        4    $$              200 Church St  40.716271 -74.007223
# 4        4   $$$                81 Broadway  40.710613 -73.965881
# 5        4     $              116 E 28th St  40.742899 -73.983317
# 6      3.5     $                891 8th Ave  40.764620 -73.984940
# 7                          749 Flushing Ave  40.700798 -73.942815
# 8        3    $$              176 First Ave  40.729120 -73.983980
# 9        3    $$                106 7th Ave  40.674180 -73.975810
# 10     4.5     $                339 5th Ave  40.672050 -73.983730
# 11       4     $               1551 2nd Ave  40.774440 -73.954470
# 12     3.5    $$              108 W 32nd St  40.748630 -73.989400
# 13       4     $              4003 Broadway  40.841360 -73.939870
# 14       4     $        510 Ave Of Americas  40.736916 -73.996936
# 15       3     $                246 3rd Ave  40.737189 -73.984528
# 16       4     $              551 Hudson St  40.735256 -74.006309
# 17       4    $$             127 Orchard St  40.719625 -73.989576
# 18     3.5     $                90 Court St  40.691170 -73.991820
# 19       4     $             517 Jersey Ave  40.720600 -74.046932
# 20     3.5     $             410 Myrtle Ave  40.693031 -73.969392
# 21                         1065 Bedford Ave  40.687530 -73.954580
# 22       4     $           51 University Pl  40.732480 -73.993850
# 23     3.5     $           73 Lafayette Ave  40.687362 -73.975395
# 24       3     $              210 E 23rd St  40.738400 -73.982520
# 25       4     $               1229 1st Ave  40.764358 -73.958862
# 26       3     $               40 E 23rd St  40.740301 -73.987360
# 27       4     $               8002 3rd Ave  40.627773 -74.029501
# 28       4    $$               1659 3rd Ave  40.783070 -73.950650
# 29       4     $  18312 Horace Harding Expy  40.739435 -73.790506
# ..     ...   ...                        ...        ...        ...
# 170      4    $$           205 E Houston St  40.722237 -73.987526
# 171      4     $              322 Spring St  40.725890 -74.009290
# 172      3     $               374 Canal St  40.720970 -74.004360
# 173      4     $               14 W 19th St  40.739310 -73.992430
# 174    4.5    $$               379 Grand St  40.716334 -73.988652
# 175    4.5     $               10 Morton St  40.731151 -74.003547
# 176      4    $$         445 Albee Square W  40.691025 -73.983311
# 177    3.5    $$                55 Water St  40.703721 -73.991811
# 178                            30 Vandam St  40.726130 -74.004997
# 179    3.5   $$$           380 Lafayette St  40.727617 -73.993464
# 180    4.5    $$               485 Court St  40.676244 -73.998717
# 181                             313 36th St  40.655460 -74.006030
# 182    4.5     $                761 6th Ave  40.744414 -73.991842
# 183      4     $           137 E Houston St  40.723133 -73.990144
# 184      4    $$              162 E 33rd St  40.745206 -73.979170
# 185      3     $                263 1st Ave  40.732370 -73.982190
# 186    4.5    $$           19 Old Fulton St  40.702747 -73.993435
# 187    3.5    $$               412 Court St  40.680175 -73.997144
# 188                             597 4th Ave  40.664994 -73.993054
# 189    4.5     $                   94 Ave B  40.724653 -73.981702
# 190      4     $              148 W 49th St  40.760060 -73.983060
# 191      4    $$           64 Lafayette Ave  40.687010 -73.975370
# 192      4     $           335 Lafayette St  40.725732 -73.994634
# 193    4.5    $$              30-02 14th St  40.770860 -73.930221
# 194      5    $$                  30 Gem St  40.725420 -73.956620
# 195      4   $$$               141 Court St  40.689386 -73.992294
# 196      4    $$          541 Amsterdam Ave  40.787931 -73.974505
# 197      4    $$              293 Grand Ave  40.687542 -73.962334
# 198    4.5     $                127 2nd Ave  40.728462 -73.988167
# 199      4     $      367 Knickerbocker Ave  40.700658 -73.921225
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/friedmans-new-york-71...  cCesIqo-LQt0cRlZAnrAZQ
# 1    https://www.yelp.com/biz/high-street-on-hudson...  Oq1mej1BYfjcdPKkM_5o8g
# 2    https://www.yelp.com/biz/gertie-brooklyn?adjus...  gC7QKqUe2wrxUTxL11ab1A
# 3    https://www.yelp.com/biz/tribecas-kitchen-new-...  MHtbBc2np3sR7jiV9GphNg
# 4    https://www.yelp.com/biz/marlow-and-sons-brook...  G18cPTEjuxXx957dGYBDAQ
# 5    https://www.yelp.com/biz/bagels-and-schmear-ne...  UgTfFaQ_NAyne5OwLtTpXQ
# 6    https://www.yelp.com/biz/pick-a-bagel-new-york...  x3RfohtUQPWHS1l1VfAMTQ
# 7
# 8    https://www.yelp.com/biz/black-seed-bagels-new...  4v5lbiExMocWoG7iKnYWrQ
# 9    https://www.yelp.com/biz/the-bagel-market-broo...  2bpjwQBGoo9KyMYUuPt0Hw
# 10   https://www.yelp.com/biz/bagel-world-brooklyn-...  2xxX3t7ykIlyoaOXZdRZNw
# 11   https://www.yelp.com/biz/h-and-h-bagels-new-yo...  bb4TLfMexv3XPy864A09ug
# 12   https://www.yelp.com/biz/ess-a-bagel-new-york-...  lLsEzgmXwCoP6OK5ACT1Ig
# 13   https://www.yelp.com/biz/mikes-bagels-new-york...  6XX2Ytf8nYqh8dRhz9Kk_g
# 14   https://www.yelp.com/biz/bagel-buffet-new-york...  rGfDX_ors68i8LnuG55NQA
# 15   https://www.yelp.com/biz/gramercy-bagels-new-y...  j1TePe2B6pjvvEg2VOLNcg
# 16   https://www.yelp.com/biz/cafe-panino-mucho-giu...  jewdjZyGcAXIepOeTBae6g
# 17   https://www.yelp.com/biz/russ-and-daughters-ca...  0rQz8mkleT62eUkiAVs4UA
# 18   https://www.yelp.com/biz/la-bagel-delight-at-c...  lgndZLoGNjS8gSBx-fS-Uw
# 19   https://www.yelp.com/biz/wonder-bagels-jersey-...  0EOWrLcnWEO1pP7bZafofw
# 20   https://www.yelp.com/biz/myrtle-bagel-brooklyn...  oLYnY3SKNqIwERzZXOc63A
# 21
# 22   https://www.yelp.com/biz/bagel-bobs-new-york?a...  XTa5infpecABoyLZ86EH2w
# 23   https://www.yelp.com/biz/la-bagel-delight-broo...  9uhWTKavezO5TKWMui-o3w
# 24   https://www.yelp.com/biz/pick-a-bagel-new-york...  yc17eYI-lv59ShQ3zMy_Bg
# 25   https://www.yelp.com/biz/bagelworks-new-york-5...  m6FV9h1mMJ9_LZetNOjNjg
# 26   https://www.yelp.com/biz/zuckers-bagels-and-sm...  ZO9CKtJ9tvPSwEns-semKA
# 27   https://www.yelp.com/biz/bagel-boy-brooklyn?ad...  fZYymv8linCo2id7wIokwQ
# 28   https://www.yelp.com/biz/the-bagel-shop-new-yo...  l6lg4lqJSkGDFE6Svl5wnw
# 29   https://www.yelp.com/biz/bagel-oasis-fresh-mea...  psx14GCq03cuRCWJIs0CuQ
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/katzs-delicatessen-ne...  V7lXZKBDzScDeGB8JmnzSA
# 171  https://www.yelp.com/biz/spring-streets-finest...  w7zQ47EyJ6R7K_TEWZnInA
# 172  https://www.yelp.com/biz/tribeca-bagels-new-yo...  AZIxbXMnIDkGU2P7pOhHkg
# 173  https://www.yelp.com/biz/dough-new-york-2?adju...  ZMQzXIiqdBIuicFySTWGKg
# 174  https://www.yelp.com/biz/doughnut-plant-new-yo...  lWOkeS-wV4no8qqA9OwwEg
# 175  https://www.yelp.com/biz/the-doughnut-project-...  c6UUcUTbwbk0kOpF6jVOJQ
# 176  https://www.yelp.com/biz/dekalb-market-hall-br...  HFOiW4RvijuoblE4DD3JwA
# 177  https://www.yelp.com/biz/time-out-market-new-y...  MGd6HFEq1ALD58XWNviSXw
# 178
# 179  https://www.yelp.com/biz/lafayette-grand-caf%C...  g3jNtkQZVZrrC823oBxdtg
# 180  https://www.yelp.com/biz/court-street-grocers-...  lM44NybalPaw3aiw24WOdA
# 181
# 182  https://www.yelp.com/biz/olympias-finest-deli-...  TCYy1ULREceEiEu5h5FHPA
# 183  https://www.yelp.com/biz/yonah-schimmels-knish...  amoGEhgkE4xcNXwYqWeoaw
# 184  https://www.yelp.com/biz/2nd-ave-deli-new-york...  xiwnLiNhSlEN4CDcurqsLQ
# 185  https://www.yelp.com/biz/bagel-boss-new-york-8...  eAWGPqVKNrUuLw7V5S8mYQ
# 186  https://www.yelp.com/biz/julianas-brooklyn-3?a...  ysqgdbSrezXgVwER2kQWKA
# 187  https://www.yelp.com/biz/brooklyn-bread-cafe-b...  3AgtLUyDGFIsMrg25e8LPQ
# 188
# 189  https://www.yelp.com/biz/sunny-and-annies-new-...  pWywDImlX0n_XKPNg0Bizg
# 190  https://www.yelp.com/biz/toasties-new-york-6?a...  0dO6JJPmkivbK8-Qu5eUYg
# 191  https://www.yelp.com/biz/baba-cool-brooklyn?ad...  wXiIxbnFRaFBS9RI4wJrdw
# 192  https://www.yelp.com/biz/bite-new-york?adjust_...  a7BC1doUjNDqrqTaAMmfZg
# 193  https://www.yelp.com/biz/comptons-astoria?adju...  5Iq46XSngo4RoUAedDxK5g
# 194  https://www.yelp.com/biz/acme-smoked-fish-broo...  XpAZBiSrLNi0t332tWxYcQ
# 195  https://www.yelp.com/biz/shelskys-of-brooklyn-...  rdgOCFe30sIaAo6tkXkJ-A
# 196  https://www.yelp.com/biz/barney-greengrass-new...  XKWvRI7WI4LotDLUboUUGA
# 197  https://www.yelp.com/biz/mekelburgs-brooklyn?a...  1Jjg8-vQVRQqqtL4sODi5g
# 198  https://www.yelp.com/biz/b-and-h-dairy-new-yor...  koh-4_SAbshwZ8EBRmXcmg
# 199  https://www.yelp.com/biz/knickerbocker-bagel-b...  OtqShhp-cOByPzzdTMZu6w
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_Bagel.csv')
