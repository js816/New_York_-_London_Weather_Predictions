# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"british","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': 'NSlwJrO3nKLyTDh6oVxvfA',
#    'alias': 'kensington-pies-east-meadow-2',
#    'name': 'Kensington Pies',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4txAV_yETtIhKYL4-o-yOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kensington-pies-east-meadow-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7850656, 'longitude': -73.8124984},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '548 E Meadow Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'East Meadow',
#     'zip_code': '11554',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['548 E Meadow Ave', 'East Meadow, NY 11554']},
#    'phone': '+13478869001',
#    'display_phone': '(347) 886-9001',
#    'distance': 17689.877590522832},
#   {'id': '66T7rXIZvcVg7XicY6QObg',
#    'alias': 'oscars-place-new-york-2',
#    'name': "Oscar's Place",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FETfiRPwBgR91DFXMbEwiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oscars-place-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 219,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7318649, 'longitude': -74.0064011},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '466 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['466 Hudson St', 'New York, NY 10014']},
#    'phone': '+12127416479',
#    'display_phone': '(212) 741-6479',
#    'distance': 3102.120244740204},
#   {'id': 'tyM20Xp41uWm5-q_htVQmA',
#    'alias': 'tea-and-sympathy-new-york',
#    'name': 'Tea & Sympathy',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1FaEAfKmftpFXxNXXo5dAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tea-and-sympathy-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 949,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.738175114449, 'longitude': -74.001898149974},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '108 Greenwich Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['108 Greenwich Ave', 'New York, NY 10011']},
#    'phone': '+12129899735',
#    'display_phone': '(212) 989-9735',
#    'distance': 3695.4321418144177},
#   {'id': 'a2DgSBzPml-ewaEz_J4Ezg',
#    'alias': 'a-salt-and-battery-new-york',
#    'name': 'A Salt & Battery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bbwZkAtGZodRKNF5O283pQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/a-salt-and-battery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 812,
#    'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7383669895876,
#     'longitude': -74.002024580178},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '112 Greenwich Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['112 Greenwich Ave', 'New York, NY 10011']},
#    'phone': '+12126912713',
#    'display_phone': '(212) 691-2713',
#    'distance': 3718.2982075719992},
#   {'id': '74FFOreAgPphSwSZlfZzgw',
#    'alias': 'jones-wood-foundry-new-york-2',
#    'name': 'Jones Wood Foundry',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sTZR2UnV7dxjmL5ja-Ti-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jones-wood-foundry-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 702,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7703854340118,
#     'longitude': -73.9535711917713},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '401 E 76th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['401 E 76th St', 'New York, NY 10021']},
#    'phone': '+12122492700',
#    'display_phone': '(212) 249-2700',
#    'distance': 7994.681771202271},
#   {'id': 'OxqUWRZFUOz3r6_4bh4mfg',
#    'alias': 'cock-and-bull-new-york',
#    'name': 'Cock & Bull',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-82MfQUN7FXel19Ra9BsLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cock-and-bull-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 544,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7560908823673,
#     'longitude': -73.9804858350908},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '23 W 45th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23 W 45th St', 'New York, NY 10036']},
#    'phone': '+12128191900',
#    'display_phone': '(212) 819-1900',
#    'distance': 5750.495668005237},
#   {'id': 'vHyyn-ef4IvuHVJK8KqDtg',
#    'alias': 'the-chippery-jersey-city',
#    'name': 'The Chippery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ai569Al3yNd8awVf4UvOXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-chippery-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.723509, 'longitude': -74.08995},
#    'transactions': ['delivery'],
#    'location': {'address1': '983 Communipaw Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07304',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['983 Communipaw Ave', 'Jersey City, NJ 07304']},
#    'phone': '+12018934424',
#    'display_phone': '(201) 893-4424',
#    'distance': 8308.623794515828},
#   {'id': 'FlgTV8DgQpm1D9lwC_-ZQA',
#    'alias': 'bluebird-london-nyc-new-york-4',
#    'name': 'Bluebird London NYC',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LiGNptnAckicXPqQM7Ke-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bluebird-london-nyc-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 334,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.768494, 'longitude': -73.983072},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '10 Columbus Cir',
#     'address2': 'Fl 3rd',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10 Columbus Cir', 'Fl 3rd', 'New York, NY 10019']},
#    'phone': '+13476822100',
#    'display_phone': '(347) 682-2100',
#    'distance': 7079.371546056122},
#   {'id': 'vRqj40pRwz0OHHRVgOdgRg',
#    'alias': 'the-clocktower-new-york',
#    'name': 'The Clocktower',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nsBqPGbl0u0HcBnsfX_bwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-clocktower-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 378,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74133, 'longitude': -73.98747},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '5 Madison Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 Madison Avenue', 'New York, NY 10010']},
#    'phone': '+12124134300',
#    'display_phone': '(212) 413-4300',
#    'distance': 4027.268953084492},
#   {'id': '3d4zgFXojnTZ49j12t9YKg',
#    'alias': 'the-headless-widow-new-york',
#    'name': 'The Headless Widow',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FiLzmXT9yRyxtj6d7PbIPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-headless-widow-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 75,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72658, 'longitude': -73.9863},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'location': {'address1': '99 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['99 1st Ave', 'New York, NY 10003']},
#    'phone': '+19174090446',
#    'display_phone': '(917) 409-0446',
#    'distance': 2445.63828466036},
#   {'id': 'U7H_286KDxKSed5K3kn7Vg',
#    'alias': 'queen-vic-new-york',
#    'name': 'Queen Vic',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tvgZ9kiBDyUm1bsr9c5awA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/queen-vic-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72594, 'longitude': -73.9892179},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '68 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['68 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12122285357',
#    'display_phone': '(212) 228-5357',
#    'distance': 2318.7487582397607},
#   {'id': '3NbhYebjZPjLTWZZyRuhsw',
#    'alias': 'the-winslow-gin-house-and-eatery-new-york',
#    'name': 'The Winslow Gin House and Eatery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KqK_JDisR25T9QQdVvgHNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-winslow-gin-house-and-eatery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 555,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7327766418457,
#     'longitude': -73.9852142333984},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '243 E 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['243 E 14th St', 'New York, NY 10003']},
#    'phone': '+12127777717',
#    'display_phone': '(212) 777-7717',
#    'distance': 3132.7023604652477},
#   {'id': 'RemvTpxalDjSew5HwmNzUQ',
#    'alias': 'the-dead-rabbit-new-york',
#    'name': 'The Dead Rabbit',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_4T5R0HHhASROheby-TXDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dead-rabbit-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1615,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70329, 'longitude': -74.01102},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '30 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30 Water St', 'New York, NY 10004']},
#    'phone': '+16464227906',
#    'display_phone': '(646) 422-7906',
#    'distance': 1431.0399855447463},
#   {'id': 'lhEzTykkqFz92Vq2uILtyw',
#    'alias': 'the-wren-new-york',
#    'name': 'The Wren',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GU7pSWigy_h52g4Qm54_Tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wren-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 573,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7263350655, 'longitude': -73.9920476876},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '344 Bowery',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['344 Bowery', 'New York, NY 10012']},
#    'phone': '+12123880148',
#    'display_phone': '(212) 388-0148',
#    'distance': 2330.5786633327825},
#   {'id': '2RbBg1CIxBZAc2MQPdxkcA',
#    'alias': 'lillies-victorian-establishment-new-york',
#    'name': "Lillie's Victorian Establishment",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sBLOuDpQfuxrjS8eG5RGnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lillies-victorian-establishment-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1076,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.737661, 'longitude': -73.991113},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '13 E 17th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['13 E 17th St', 'New York, NY 10003']},
#    'phone': '+12123371970',
#    'display_phone': '(212) 337-1970',
#    'distance': 3592.2783333741954},
#   {'id': 'vGS5X12NYXCl8NpynlxRuw',
#    'alias': 'oscar-wilde-new-york-2',
#    'name': 'Oscar Wilde',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZSnGxg5BBKVs-Jt4AE8f2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oscar-wilde-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 779,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74514, 'longitude': -73.9900399},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '45 W 27th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 W 27th St', 'New York, NY 10001']},
#    'phone': '+12122133066',
#    'display_phone': '(212) 213-3066',
#    'distance': 4431.997041905199},
#   {'id': 'oLA02lMIfgvbYquvXzkARw',
#    'alias': 'lillies-victorian-establishment-new-york-2',
#    'name': "Lillie's Victorian Establishment",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lv1yDDDoSCoOYzRPXbrleg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lillies-victorian-establishment-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1463,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7614625, 'longitude': -73.9860519},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '249 W 49th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['249 W 49th St', 'New York, NY 10019']},
#    'phone': '+12129574530',
#    'display_phone': '(212) 957-4530',
#    'distance': 6267.456448728524},
#   {'id': 'X2cZaJqblzi4M0irKodWcg',
#    'alias': 'butcher-block-sunnyside',
#    'name': 'Butcher Block',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3rV6CwdIQiv9GSexPCsovA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/butcher-block-sunnyside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 225,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'},
#     {'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'intlgrocery', 'title': 'International Grocery'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7442277477524,
#     'longitude': -73.9233800102348},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '43-46 41st St',
#     'address2': '',
#     'address3': '',
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43-46 41st St', 'Sunnyside, NY 11104']},
#    'phone': '+17187841078',
#    'display_phone': '(718) 784-1078',
#    'distance': 7369.355460512403},
#   {'id': 'EYjn8wQKq38xpesxSIG1kg',
#    'alias': 'left-hand-path-bushwick',
#    'name': 'Left Hand Path',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FMi2yoLTS5Q3LRnhtkI2qQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/left-hand-path-bushwick?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.705176, 'longitude': -73.920148},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '89 Wyckoff Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bushwick',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['89 Wyckoff Ave', 'Bushwick, NY 11237']},
#    'phone': '+17184171262',
#    'display_phone': '(718) 417-1262',
#    'distance': 6250.058809304104},
#   {'id': '4FtqGBB96denVJu8KnuGKg',
#    'alias': 'the-milton-new-york',
#    'name': 'The Milton',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sQTXh0DJubCZPgYPsqMg2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-milton-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 431,
#    'categories': [{'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.781258, 'longitude': -73.948988},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1754 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1754 2nd Ave', 'New York, NY 10128']},
#    'phone': '+16466827019',
#    'display_phone': '(646) 682-7019',
#    'distance': 9253.814096288745},
#   {'id': 'qOomR3AwClOGpV1HdqOTFg',
#    'alias': 'les-enfants-de-boheme-new-york',
#    'name': 'Les Enfants de Boheme',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Sw6SDhbhkdi7MJeDajbp5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/les-enfants-de-boheme-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 271,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7136187, 'longitude': -73.9888503},
#    'transactions': ['restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '177 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['177 Henry St', 'New York, NY 10002']},
#    'phone': '+16464764843',
#    'display_phone': '(646) 476-4843',
#    'distance': 1026.2110364656392},
#   {'id': 'G6Kc58Oc42uXY2alGCoDBA',
#    'alias': 'the-churchill-tavern-new-york',
#    'name': 'The Churchill Tavern',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cmDOvXC3Bp5kUPVlqxfusg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-churchill-tavern-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 245,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7435888, 'longitude': -73.9844841},
#    'transactions': ['restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '45 E 28th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 E 28th St', 'New York, NY 10016']},
#    'phone': '+16469227744',
#    'display_phone': '(646) 922-7744',
#    'distance': 4321.205883326993},
#   {'id': 'VN7CdSCyo-ZWquo_ouGoVA',
#    'alias': 'alphabet-city-beer-company-new-york',
#    'name': 'Alphabet City Beer Company',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BiwhImZ2WtplG3UXkkkm9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alphabet-city-beer-company-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 198,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.723652, 'longitude': -73.978836},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '96 Ave C',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['96 Ave C', 'New York, NY 10009']},
#    'phone': '+16464227103',
#    'display_phone': '(646) 422-7103',
#    'distance': 2407.1609754997653},
#   {'id': '7boggcCID7gVdNFQn4e8hQ',
#    'alias': 'carraghers-pub-and-restaurant-new-york',
#    'name': "Carragher's Pub & Restaurant",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rfqbIcBTGHa2ON1yroL_Ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carraghers-pub-and-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 225,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7561483754108,
#     'longitude': -73.9908477827673},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '228 W 39th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 W 39th St', 'New York, NY 10018']},
#    'phone': '+16463701545',
#    'display_phone': '(646) 370-1545',
#    'distance': 5645.436681619799},
#   {'id': '_cYuN0yD4aStZ0oXPaaRmQ',
#    'alias': 'the-monro-pub-brooklyn',
#    'name': 'The Monro Pub',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Dn8YKoiFPMIAZIrd9uZenw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-monro-pub-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6677448, 'longitude': -73.9873605},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '481 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['481 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17184992005',
#    'display_phone': '(718) 499-2005',
#    'distance': 4232.610506708749},
#   {'id': 'S6QKuyB2LTc6MpiBxria6A',
#    'alias': 'the-pie-store-montclair',
#    'name': 'The Pie Store',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/krYVpF3tTkkWrljDaexRag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pie-store-montclair?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 199,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.831143, 'longitude': -74.20726},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '100 Watchung Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Montclair',
#     'zip_code': '07043',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['100 Watchung Ave', 'Montclair, NJ 07043']},
#    'phone': '+19737444424',
#    'display_phone': '(973) 744-4424',
#    'distance': 22732.985819059086},
#   {'id': 'HYFSOb5o4hppToeYe1va1A',
#    'alias': 'the-rookery-brooklyn',
#    'name': 'The Rookery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/H3ZzCX8S21lvKO-woPVQkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-rookery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 331,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7073514, 'longitude': -73.9221093},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '425 Troutman St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['425 Troutman St', 'Brooklyn, NY 11237']},
#    'phone': '+17184838048',
#    'display_phone': '(718) 483-8048',
#    'distance': 6088.254414272855},
#   {'id': 'qUmdCtNNKvbHYQPMMorwkg',
#    'alias': 'o-henrys-publick-house-staten-island',
#    'name': "O'Henry's Publick House",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5ts_Q8Lbw9Kv_pTN4TnXcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/o-henrys-publick-house-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6375049, 'longitude': -74.0755598},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '10 Minthorne St',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10301',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10 Minthorne St', 'Staten Island, NY 10301']},
#    'phone': '+17184426200',
#    'display_phone': '(718) 442-6200',
#    'distance': 10189.760892211529},
#   {'id': 'ihd2cISx6muy6bKVPhA4cg',
#    'alias': 'queensyard-new-york',
#    'name': 'Queensyard',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oT7NbBX1GBl2PaXoZbPR3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/queensyard-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 279,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7533936, 'longitude': -74.00174205487694},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '20 Hudson Yards',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['20 Hudson Yards', 'New York, NY 10001']},
#    'phone': '+12123770780',
#    'display_phone': '(212) 377-0780',
#    'distance': 5368.468740425915},
#   {'id': 'i34wlziIjT8lHgUN1o0ToQ',
#    'alias': 'the-shakespeare-new-york',
#    'name': 'The Shakespeare',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/01zB53rsuOTzFqu4FbfPog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-shakespeare-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 361,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7506062, 'longitude': -73.9801755},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '24 E 39th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 E 39th St', 'New York, NY 10016']},
#    'phone': '+16468376779',
#    'display_phone': '(646) 837-6779',
#    'distance': 5160.692836404028},
#   {'id': 'xd7ioU33jkwx0hQ3kUNIOg',
#    'alias': 'the-double-windsor-brooklyn',
#    'name': 'The Double Windsor',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eR8BDoxAHu73JZI-r7qLGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-double-windsor-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 427,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.66063, 'longitude': -73.98056},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '210 Prospect Park W',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['210 Prospect Park W', 'Brooklyn, NY 11215']},
#    'phone': '+13477253479',
#    'display_phone': '(347) 725-3479',
#    'distance': 5115.8390326932185},
#   {'id': 'FLRx5tOBMMDJHEUYAAfa8A',
#    'alias': 'caledonia-bar-new-york-3',
#    'name': 'Caledonia Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kWlmDa54NBllXT2yIKri1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caledonia-bar-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 259,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'scottish', 'title': 'Scottish'},
#     {'alias': 'whiskeybars', 'title': 'Whiskey Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.776327, 'longitude': -73.953213},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1609 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1609 2nd Ave', 'New York, NY 10028']},
#    'phone': '+12127344300',
#    'display_phone': '(212) 734-4300',
#    'distance': 8608.12582370487},
#   {'id': 'Xu8H24NxJJxEE-9wGp_AMA',
#    'alias': 'the-brazen-tavern-new-york',
#    'name': 'The Brazen Tavern',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tCU2RPh_ts0ASsJ0cGMV4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-brazen-tavern-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 384,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7593269348145,
#     'longitude': -73.9913101196289},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '356 W 44th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['356 W 44th St', 'New York, NY 10036']},
#    'phone': '+16466785989',
#    'display_phone': '(646) 678-5989',
#    'distance': 5998.398762920218},
#   {'id': 'PxyxNj43WSDjRF588HFJdQ',
#    'alias': 'the-craic-brooklyn',
#    'name': 'The Craic',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Gw35g-fCsIMz_IbNCfHKGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-craic-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 104,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71852, 'longitude': -73.95504},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '488 Driggs Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['488 Driggs Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13473842772',
#    'display_phone': '(347) 384-2772',
#    'distance': 3613.832837477861},
#   {'id': 'Xcnq-GIw48tMPlUIavpGmA',
#    'alias': 'the-east-pole-new-york',
#    'name': 'The East Pole',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DW2u9OYjOmjRZmhoDneyng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-east-pole-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 263,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7662355, 'longitude': -73.9658007},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '133 E 65th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['133 E 65th St', 'New York, NY 10065']},
#    'phone': '+12122492222',
#    'display_phone': '(212) 249-2222',
#    'distance': 7173.236015010647},
#   {'id': 'kExRD3nL8Z2TntRtW5ACiw',
#    'alias': 'the-thistle-fish-and-chips-lyndhurst',
#    'name': 'The Thistle Fish And Chips',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YDeap52NlJO71ijzXWhF4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-thistle-fish-and-chips-lyndhurst?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 82,
#    'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.811, 'longitude': -74.12342},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '442 Valley Brook Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Lyndhurst',
#     'zip_code': '07032',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['442 Valley Brook Ave', 'Lyndhurst, NJ 07032']},
#    'phone': '+12019350004',
#    'display_phone': '(201) 935-0004',
#    'distance': 16003.07386061946},
#   {'id': 'uoT2_Wrt1noD6kZOID7tUg',
#    'alias': 'jane-new-york-2',
#    'name': 'Jane',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fL4CNvQYiUmE9HKbOd1AcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jane-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3209,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7273779, 'longitude': -74.00025},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '100 W Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100 W Houston St', 'New York, NY 10012']},
#    'phone': '+12122547000',
#    'display_phone': '(212) 254-7000',
#    'distance': 2489.9758210239006},
#   {'id': 'J4pAppaiXwCkbLOGc4wHww',
#    'alias': 'raines-law-room-new-york',
#    'name': 'Raines Law Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1MDwROZhGa1Hdsz7qzQrsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raines-law-room-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1485,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73879, 'longitude': -73.99455},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '48 W 17th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['48 W 17th St', 'New York, NY 10011']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3705.657290917968},
#   {'id': 'n69FkL9ZcWqda_LeSN6CRA',
#    'alias': 'shellys-deli-and-cafe-maspeth',
#    'name': "Shelly's Deli & Cafe",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/iLF8Cng0PelREiHjDB7YNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shellys-deli-and-cafe-maspeth?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72485, 'longitude': -73.8987},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '56-34 66th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Maspeth',
#     'zip_code': '11378',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['56-34 66th St', 'Maspeth, NY 11378']},
#    'phone': '+17184240429',
#    'display_phone': '(718) 424-0429',
#    'distance': 8339.139667057014},
#   {'id': 'RsLs863308rBCJqwuGfNeA',
#    'alias': 'custom-house-brooklyn',
#    'name': 'Custom House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lzHBmTUfS85FbdH-Zd6ACg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/custom-house-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 180,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.694862, 'longitude': -73.993713},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '139 Montague St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['139 Montague St', 'Brooklyn, NY 11201']},
#    'phone': '+17186436000',
#    'display_phone': '(718) 643-6000',
#    'distance': 1177.6284266634227},
#   {'id': '3p_qnoOpDu4svcnwoXPljA',
#    'alias': 'black-swan-brooklyn',
#    'name': 'Black Swan',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/W8t1fyliuxqmpFjS6U3UMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-swan-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 825,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6890943, 'longitude': -73.95526006502993},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1048 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1048 Bedford Ave', 'Brooklyn, NY 11205']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3759.50444752359},
#   {'id': 'siMk2bf7QomxjAY0hD3BFQ',
#    'alias': 'morans-hoboken',
#    'name': "Moran's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kD5kgUoNZmpzVnB025LoCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/morans-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 149,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7425922, 'longitude': -74.0309736},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '501 Garden St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['501 Garden St', 'Hoboken, NJ 07030']},
#    'phone': '+12017952025',
#    'display_phone': '(201) 795-2025',
#    'distance': 5166.240805758247},
#   {'id': 's9pCq2kw9k1JKL06N9BsiQ',
#    'alias': 'mary-o-s-new-york',
#    'name': 'Mary O’s',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DA5mSYIZZ711dPLxGoLmHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mary-o-s-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 145,
#    'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72329, 'longitude': -73.98523},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '32 Ave A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 Ave A', 'New York, NY 10009']},
#    'phone': '+12125055610',
#    'display_phone': '(212) 505-5610',
#    'distance': 2125.745130115327},
#   {'id': 'ohLIPmzTysowInbte9XhMw',
#    'alias': 'the-malt-house-new-york-3',
#    'name': 'The Malt House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wxCetW7aHVatpcEf11RLgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-malt-house-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 539,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.709659, 'longitude': -74.009262},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '9 Maiden Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Maiden Ln', 'New York, NY 10038']},
#    'phone': '+16466827577',
#    'display_phone': '(646) 682-7577',
#    'distance': 1350.1089630689858},
#   {'id': 'gt-0HkY2DC-NscmhOsKOWw',
#    'alias': 'the-hutton-jersey-city',
#    'name': 'The Hutton',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hJoIhf-oNOerBf7IVeH5SA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hutton-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 294,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.746707841754,
#     'longitude': -74.0555749833584},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '225 Hutton St',
#     'address2': None,
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07307',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['225 Hutton St', 'Jersey City, NJ 07307']},
#    'phone': '+12013569169',
#    'display_phone': '(201) 356-9169',
#    'distance': 6907.924856420219},
#   {'id': 'NMDrXW5_qnme1hcJrXNP9Q',
#    'alias': 'the-nomad-bar-new-york-2',
#    'name': 'The NoMad Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/INX5gM4HuRM5PjImwRH-7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-nomad-bar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 485,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7449365409844,
#     'longitude': -73.9885197632294},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '10 W 28th St',
#     'address2': '',
#     'address3': 'The NoMad Hotel',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10 W 28th St',
#      'The NoMad Hotel',
#      'New York, NY 10001']},
#    'phone': '+12127961500',
#    'display_phone': '(212) 796-1500',
#    'distance': 4418.138526681626},
#   {'id': 'gOp_igC6eFDJ4ctxnv9myA',
#    'alias': 'the-chippery-elizabeth-elizabeth',
#    'name': 'The Chippery - Elizabeth',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SIOB34EGVM6J-y4KDO-lBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-chippery-elizabeth-elizabeth?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 105,
#    'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6641955, 'longitude': -74.246263},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '929 Westfield Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Elizabeth',
#     'zip_code': '07208',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['929 Westfield Ave', 'Elizabeth, NJ 07208']},
#    'phone': '+19087378700',
#    'display_phone': '(908) 737-8700',
#    'distance': 21747.17375343068},
#   {'id': 'wLvcBF3tbvu5h6XDYfm7DA',
#    'alias': 'burp-castle-new-york',
#    'name': 'Burp Castle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3aqHNbGm3mRGIjclVq0CaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burp-castle-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 554,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7283252192663,
#     'longitude': -73.9886448736218},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '41 E 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41 E 7th St', 'New York, NY 10003']},
#    'phone': '+12129824576',
#    'display_phone': '(212) 982-4576',
#    'distance': 2588.328840089062},
#   {'id': 'DEBtWelTYeMA3dAaq8YhVA',
#    'alias': 'swing-the-teapot-floral-park',
#    'name': 'Swing the Teapot',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/l6nVKrjnj-XFTkw-O9XJ_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/swing-the-teapot-floral-park?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 372,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72458, 'longitude': -73.70493},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '6 Verbena Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Floral Park',
#     'zip_code': '11001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6 Verbena Ave', 'Floral Park, NY 11001']},
#    'phone': '+15164882180',
#    'display_phone': '(516) 488-2180',
#    'distance': 24482.182940852017},
#   {'id': 'YL1LxYufuwX5sq4RwW-2Gw',
#    'alias': 'floyd-ny-brooklyn-2',
#    'name': 'Floyd, NY',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9SDNpk2ueMDDstGKS1DJAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/floyd-ny-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 211,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6907799, 'longitude': -73.9957},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '131 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['131 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17188585810',
#    'display_phone': '(718) 858-5810',
#    'distance': 1630.1308479384288}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#            Restaurant             Type Price Rating            Address  \
# 0     Kensington Pies         Bakeries                548 E Meadow Ave
# 1       Oscar's Place  Modern European    $$    4.5      466 Hudson St
# 2      Tea & Sympathy     Coffee & Tea    $$    3.5  108 Greenwich Ave
# 3    A Salt & Battery     Fish & Chips    $$    3.5  112 Greenwich Ave
# 4  Jones Wood Foundry          British    $$      4      401 E 76th St
#
#          Lat        Lng                                                url  \
# 0  40.785066 -73.812498
# 1  40.731865 -74.006401  https://www.yelp.com/biz/oscars-place-new-york...
# 2  40.738175 -74.001898  https://www.yelp.com/biz/tea-and-sympathy-new-...
# 3  40.738367 -74.002025  https://www.yelp.com/biz/a-salt-and-battery-ne...
# 4  40.770385 -73.953571  https://www.yelp.com/biz/jones-wood-foundry-ne...
#
#                        ID
# 0
# 1  66T7rXIZvcVg7XicY6QObg
# 2  tyM20Xp41uWm5-q_htVQmA
# 3  a2DgSBzPml-ewaEz_J4Ezg
# 4  74FFOreAgPphSwSZlfZzgw

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"british","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': 'GXh9YpX4v8Wemrq-SPDPhA',
#    'alias': 'es-bar-new-york',
#    'name': "e's BAR",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/s_n3rI6L-ga4FhZimQPOPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/es-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 365,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.786692073145,
#     'longitude': -73.9755653589964},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '511 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['511 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12128770961',
#    'display_phone': '(212) 877-0961',
#    'distance': 9170.989609048018},
#   {'id': 'TikAlBfPzWZQ9h5yk8Mmdg',
#    'alias': 'cronin-and-phelans-astoria',
#    'name': "Cronin & Phelan's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/l5BnaiT8QoeldCldNkTQWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cronin-and-phelans-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 211,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'irish', 'title': 'Irish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7589, 'longitude': -73.91941},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '38-14 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38-14 Broadway', 'Astoria, NY 11103']},
#    'phone': '+17185458999',
#    'display_phone': '(718) 545-8999',
#    'distance': 8675.497009363213},
#   {'id': 'zDkwJeNcNU251vmi2EeANg',
#    'alias': 'frankie-jersey-city',
#    'name': 'Frankie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ky8WRe9oYT0PmtMCywlx5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frankie-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 263,
#    'categories': [{'alias': 'australian', 'title': 'Australian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7171775955244,
#     'longitude': -74.0442452984261},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '264 Grove St',
#     'address2': '',
#     'address3': None,
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['264 Grove St', 'Jersey City, NJ 07302']},
#    'phone': '+12013330170',
#    'display_phone': '(201) 333-0170',
#    'distance': 4397.68543833138},
#   {'id': 'GlSWzWVmQsKLGxySYSGRbQ',
#    'alias': 'smithfield-hall-new-york-5',
#    'name': 'Smithfield Hall',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/b_11vLu_Gkc-Ph51zuB18A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/smithfield-hall-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 487,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7447532620452,
#     'longitude': -73.9934939850447},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '138 W 25th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['138 W 25th St', 'New York, NY 10001']},
#    'phone': '+12129299677',
#    'display_phone': '(212) 929-9677',
#    'distance': 4371.408398892504},
#   {'id': 'EY5ot4Z1tgbDC-TZXIcRjQ',
#    'alias': 'putnams-pub-and-cooker-brooklyn',
#    'name': "Putnam's Pub & Cooker",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/W2mNO8Md_PfbQIvtz02Gbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/putnams-pub-and-cooker-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 459,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.693321, 'longitude': -73.969045},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '419 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['419 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+13477992382',
#    'display_phone': '(347) 799-2382',
#    'distance': 2519.4723419181505},
#   {'id': 'Pu0AKdb_fSg0S_crsIp0uw',
#    'alias': 'sonnyboy-new-york',
#    'name': 'Sonnyboy',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cITy5oSUwny0VEXCHmzjgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sonnyboy-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 149,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'australian', 'title': 'Australian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72052, 'longitude': -73.9901},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '65 Rivington St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['65 Rivington St', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1710.1014490226703},
#   {'id': 'DMOwfdP0Va1QI_KNefD8kg',
#    'alias': 'berry-park-brooklyn',
#    'name': 'Berry Park',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IsaOmF8XRx5PRKQm2sA36w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/berry-park-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 690,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7224719, 'longitude': -73.9552526},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4 Berry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4 Berry St', 'Brooklyn, NY 11211']},
#    'phone': '+17187822829',
#    'display_phone': '(718) 782-2829',
#    'distance': 3796.282557902373},
#   {'id': '-2wm7v5JBQ6N1QL1MY1gwA',
#    'alias': 'mulligans-hoboken',
#    'name': "Mulligan's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YCCSPSvk8p1N1x8jsSCrXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mulligans-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 111,
#    'categories': [{'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73752, 'longitude': -74.03227},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '159 1st St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['159 1st St', 'Hoboken, NJ 07030']},
#    'phone': '+12018764101',
#    'display_phone': '(201) 876-4101',
#    'distance': 4799.039072405214},
#   {'id': 'hOuETUkoGbMDyA4w9fmdmg',
#    'alias': 'craft-house-tompkinsville-2',
#    'name': 'Craft House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gUUJrY7fm_SKFVhgCuAD7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/craft-house-tompkinsville-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 335,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.636373, 'longitude': -74.077543},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '60 Vanduzer St',
#     'address2': '',
#     'address3': '',
#     'city': 'Tompkinsville',
#     'zip_code': '10301',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Vanduzer St', 'Tompkinsville, NY 10301']},
#    'phone': '+17184423433',
#    'display_phone': '(718) 442-3433',
#    'distance': 10405.981690374294},
#   {'id': 'tiwrAjwddw-3TSrnWSYD7w',
#    'alias': 'raines-law-room-at-the-william-new-york-3',
#    'name': 'Raines Law Room at the William',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8xSrNaFBePULqqR729rWoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raines-law-room-at-the-william-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 363,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75058, 'longitude': -73.98018},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '24 E 39th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 E 39th St', 'New York, NY 10016']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5145.572903449319},
#   {'id': 'sSams4lvONlOHQtI7lv9tg',
#    'alias': 'the-sackett-brooklyn',
#    'name': 'The Sackett',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TAXAmbkUYEXJAR3zk8IaOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-sackett-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 132,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.677979, 'longitude': -73.9821964},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '661 Sackett St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['661 Sackett St', 'Brooklyn, NY 11217']},
#    'phone': '+17186220437',
#    'display_phone': '(718) 622-0437',
#    'distance': 3219.85677329079},
#   {'id': 'ulLQVyjtnWjsFttiOn2D8w',
#    'alias': 'under-the-volcano-new-york',
#    'name': 'Under the Volcano',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uNDygDwhmUtuUwuyld5v1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/under-the-volcano-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7493203133345,
#     'longitude': -73.9827778190374},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '12 E 36th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['12 E 36th St', 'New York, NY 10016']},
#    'phone': '+16464484442',
#    'display_phone': '(646) 448-4442',
#    'distance': 4965.713809170217},
#   {'id': 'Rbm8W3kgisxD0KVk_HKIBw',
#    'alias': 'swift-new-york',
#    'name': 'Swift',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ny9j19NKMNGVhP-PvJQE7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/swift-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 358,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.727309, 'longitude': -73.992387},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '34 E 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['34 E 4th St', 'New York, NY 10003']},
#    'phone': '+12122603600',
#    'display_phone': '(212) 260-3600',
#    'distance': 2436.4806266527657},
#   {'id': 'eN-OHMPod8iJjzpgYS3LKw',
#    'alias': 'st-dymphnas-new-york-2',
#    'name': "St. Dymphna's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LWsfJCDZLyhEpf9Z6fOl1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-dymphnas-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 194,
#    'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.726442, 'longitude': -73.98357692999745},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '117 Ave A',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['117 Ave A', 'New York, NY 10009']},
#    'phone': '+12122546636',
#    'display_phone': '(212) 254-6636',
#    'distance': 2503.3743319965683},
#   {'id': 'jJfCbhEnI5PMPW_vS-Pp6g',
#    'alias': 'black-rabbit-brooklyn',
#    'name': 'Black Rabbit',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y4buPzv_EkfFxZN4GZwr5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-rabbit-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 178,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7301408235242,
#     'longitude': -73.9563193070954},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '91 Greenpoint Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['91 Greenpoint Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183491595',
#    'display_phone': '(718) 349-1595',
#    'distance': 4217.014499488315},
#   {'id': 'UJSQHmL81lgWqBrc9Bp3Cw',
#    'alias': 'maggie-maes-sunnyside',
#    'name': "Maggie Mae's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uIUnN0jptNkap2r2uAmOAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maggie-maes-sunnyside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 137,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7438348, 'longitude': -73.9230293},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '41-15 Queens Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41-15 Queens Blvd', 'Sunnyside, NY 11104']},
#    'phone': '+17184333067',
#    'display_phone': '(718) 433-3067',
#    'distance': 7367.954858657587},
#   {'id': 'JXcYD52B4190gIh6_RSXCg',
#    'alias': 'lillys-craft-and-kitchen-new-york',
#    'name': "Lilly's Craft and Kitchen",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/M9xP4V9f8ZQe2TOtGVnNNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lillys-craft-and-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1134,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76138, 'longitude': -73.99071},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '675 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['675 9th Ave', 'New York, NY 10036']},
#    'phone': '+12127570373',
#    'display_phone': '(212) 757-0373',
#    'distance': 6235.276259080637},
#   {'id': '-wkcI5M7902hJyhkN1zS3A',
#    'alias': '124-old-rabbit-club-new-york',
#    'name': '124 Old Rabbit Club',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eCjkZJi7EfFRd-UoVNaVGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/124-old-rabbit-club-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 347,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729926, 'longitude': -74.000219},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '124 MacDougal St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['124 MacDougal St', 'New York, NY 10012']},
#    'phone': '+16467819646',
#    'display_phone': '(646) 781-9646',
#    'distance': 2767.607648492549},
#   {'id': 'xEF3Kvd0yw74pjnlFB2Sgg',
#    'alias': 'nobody-told-me-new-york',
#    'name': 'Nobody Told Me',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/023VD9KRItElXaH3QJjKZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nobody-told-me-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 148,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.800806379326424,
#     'longitude': -73.96519384340974},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '951 Amsterdam Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['951 Amsterdam Ave', 'New York, NY 10025']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 10883.318630907874},
#   {'id': 'H3AnaDvXg_tXticwUGL7PA',
#    'alias': 'hudson-hound-new-york',
#    'name': 'Hudson Hound',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HO2K2U7Sqrw9pz9JXFIvfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hudson-hound-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 112,
#    'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73615, 'longitude': -74.00609},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '575 Hudson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['575 Hudson St', 'New York, NY 10014']},
#    'phone': '+12127966213',
#    'display_phone': '(212) 796-6213',
#    'distance': 3555.6152052036864},
#   {'id': 'h6qbszNgXgjj9Lrb62m-9w',
#    'alias': 'the-uncommons-new-york',
#    'name': 'The Uncommons',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/23Mnb_KXYfPD2SAzEvB6YA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-uncommons-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 385,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tabletopgames', 'title': 'Tabletop Games'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72933, 'longitude': -73.99865},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '230 Thompson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['230 Thompson St', 'New York, NY 10012']},
#    'phone': '+16465439215',
#    'display_phone': '(646) 543-9215',
#    'distance': 2683.826935437106},
#   {'id': 'KkiYlELDkbSCE_Bx6djTgQ',
#    'alias': 'dullboy-jersey-city',
#    'name': 'Dullboy',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/L6_99D_tqEVQOSTJyPzzrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dullboy-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 452,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72138, 'longitude': -74.04239},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '364 Grove St',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['364 Grove St', 'Jersey City, NJ 07302']},
#    'phone': '+12017951628',
#    'display_phone': '(201) 795-1628',
#    'distance': 4434.283571451144},
#   {'id': 'ykXZyQBXxoOMoZfaZMnHmg',
#    'alias': 'tryon-public-house-new-york',
#    'name': 'Tryon Public House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fTrQldH6ywmsNWIoj2rVYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tryon-public-house-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 402,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8649821372469,
#     'longitude': -73.927843119049},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '4740 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10040',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4740 Broadway', 'New York, NY 10040']},
#    'phone': '+16469187129',
#    'display_phone': '(646) 918-7129',
#    'distance': 18600.997587573136},
#   {'id': 'AawLwOYZwMf_9wkShExfuw',
#    'alias': 'sanfords-astoria-astoria',
#    'name': 'Sanfords Astoria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dQwdngc4tQsPpZtUMGvQcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sanfords-astoria-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 951,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'whiskeybars', 'title': 'Whiskey Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7623, 'longitude': -73.92555},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '30-13 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30-13 Broadway', 'Astoria, NY 11106']},
#    'phone': '+17189329569',
#    'display_phone': '(718) 932-9569',
#    'distance': 8574.096783834835},
#   {'id': 'qtFJ6T6-bO7IhOpgWb7XLg',
#    'alias': 'spuyten-duyvil-brooklyn',
#    'name': 'Spuyten Duyvil',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oriikyQNwB2Ij8R2FbiO3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spuyten-duyvil-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 374,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.714355, 'longitude': -73.955955},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '359 Metropolitan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['359 Metropolitan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17189634140',
#    'display_phone': '(718) 963-4140',
#    'distance': 3375.5807577253195},
#   {'id': 'UOaYpNM7VBFMCg1D9hmzqg',
#    'alias': 'devins-fish-and-chips-new-york',
#    'name': "Devin's Fish & Chips",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/F1tRSQqNpRGt8yNdr6tjOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/devins-fish-and-chips-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.8256877064888,
#     'longitude': -73.9437282085419},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '747 Saint Nicholas Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10031',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['747 Saint Nicholas Ave', 'New York, NY 10031']},
#    'phone': '+12124915518',
#    'display_phone': '(212) 491-5518',
#    'distance': 14032.159940038822},
#   {'id': 'hQmH1FWXBWaIBD1tEV9_Hg',
#    'alias': 'the-rum-house-new-york',
#    'name': 'The Rum House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jFJHsAbis9QrHtLVWiM4vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-rum-house-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 560,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'pianobars', 'title': 'Piano Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.759673, 'longitude': -73.986345},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '228 W 47th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 W 47th St', 'New York, NY 10036']},
#    'phone': '+16464906924',
#    'display_phone': '(646) 490-6924',
#    'distance': 6075.69408743864},
#   {'id': '2Mia4J1QKd247oh2IkuEdg',
#    'alias': 'the-cauldron-nyc-new-york',
#    'name': 'The Cauldron NYC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ApDXlNA0MdnrdIC_ow7Wvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cauldron-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 232,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7043756, 'longitude': -74.0105259},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '47 Stone St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 Stone St', 'New York, NY 10004']},
#    'phone': '+19176351960',
#    'display_phone': '(917) 635-1960',
#    'distance': 1373.480237917608},
#   {'id': 'DUYxe9yYAx3GQiZXub5pmA',
#    'alias': 'mothers-brooklyn-2',
#    'name': "Mother's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oS-T3i_uUaBlOsO23bXu9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mothers-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 268,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71488, 'longitude': -73.94471},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '347 Graham Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['347 Graham Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17183847778',
#    'display_phone': '(718) 384-7778',
#    'distance': 4311.230885740953},
#   {'id': 'xydPj_xtAqlIEz4q8RFNUw',
#    'alias': 'gaf-west-new-york',
#    'name': 'Gaf West',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oFb2GxkQvfqLkeM-ojMYuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gaf-west-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 93,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76245, 'longitude': -73.99011},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '401 W 48th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['401 W 48th St', 'New York, NY 10036']},
#    'phone': '+12123077536',
#    'display_phone': '(212) 307-7536',
#    'distance': 6356.937757012105},
#   {'id': 'IOHaEgK1zDvUvB3SfKuGCw',
#    'alias': 'parker-and-quinn-new-york',
#    'name': 'Parker & Quinn',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6xuN0yyAi9PaxSAVVAgfrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/parker-and-quinn-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1387,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7525862175813,
#     'longitude': -73.9850713153442},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '64 W 39th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64 W 39th St', 'New York, NY 10018']},
#    'phone': '+12127290277',
#    'display_phone': '(212) 729-0277',
#    'distance': 5299.158389411888},
#   {'id': 'VP_HZr_j0dXKd80lUBfsyg',
#    'alias': 'the-wicked-monk-brooklyn-3',
#    'name': 'The Wicked Monk',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/20iRdBR9AZMUpIddAypQVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wicked-monk-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 257,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.616988, 'longitude': -74.034023},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '9510 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9510 3rd Ave', 'Brooklyn, NY 11209']},
#    'phone': '+13474975152',
#    'display_phone': '(347) 497-5152',
#    'distance': 10391.163639112341},
#   {'id': 'zHh6ioC3tSXBFhXXuXrL8A',
#    'alias': 'gebhards-beer-culture-new-york',
#    'name': "Gebhard's Beer Culture",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4fJSuQuqQcw0gkxaRCtcMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gebhards-beer-culture-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 142,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.778946, 'longitude': -73.983219},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '228 W 72nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 W 72nd St', 'New York, NY 10023']},
#    'phone': '+19176393420',
#    'display_phone': '(917) 639-3420',
#    'distance': 8226.022946513258},
#   {'id': '60_ONUWGij1TbvDHSEcOpQ',
#    'alias': 'pj-clarkes-new-york-9',
#    'name': "PJ Clarke's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uJld_cDK8TJxKP1iVul21A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pj-clarkes-new-york-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 836,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7713765, 'longitude': -73.9824758},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '44 W 63rd St',
#     'address2': '',
#     'address3': 'Lincoln Square',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['44 W 63rd St',
#      'Lincoln Square',
#      'New York, NY 10023']},
#    'phone': '+12129579700',
#    'display_phone': '(212) 957-9700',
#    'distance': 7396.043425265559},
#   {'id': 'txSykTj5nbwmpiVNoK_Dyg',
#    'alias': 'blue-ribbon-brasserie-soho-new-york',
#    'name': 'Blue Ribbon Brasserie - SoHo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZAxYITiJ5k1H_zZ2Ph59sg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-ribbon-brasserie-soho-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 949,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.725456, 'longitude': -74.003027},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '97 Sullivan St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['97 Sullivan St', 'New York, NY 10012']},
#    'phone': '+12122740404',
#    'display_phone': '(212) 274-0404',
#    'distance': 2343.726730880165},
#   {'id': 'mVN2G1c5bRtAsNlr2Tbx6Q',
#    'alias': 'white-oak-tavern-new-york-2',
#    'name': 'White Oak Tavern',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RT22Bi0DMlwxLX7SQDs2sQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/white-oak-tavern-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 370,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'whiskeybars', 'title': 'Whiskey Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73036, 'longitude': -73.99462},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '21 Waverly Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21 Waverly Pl', 'New York, NY 10003']},
#    'phone': '+12122602604',
#    'display_phone': '(212) 260-2604',
#    'distance': 2770.9374114611564},
#   {'id': '-MXQI-AjTJViEekzs_5_8A',
#    'alias': 'corner-delhi-brooklyn',
#    'name': 'Corner Delhi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0PVoyTOtTGcA1FxlrwJBvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/corner-delhi-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 79,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.681277, 'longitude': -73.976069},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '447 Bergen St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['447 Bergen St', 'Brooklyn, NY 11217']},
#    'phone': '+17185763056',
#    'display_phone': '(718) 576-3056',
#    'distance': 3095.5655969642985},
#   {'id': 'hpzm2ZMMccvsm3etCxnJEw',
#    'alias': 'le-chéile-new-york-2',
#    'name': 'Le Chéile',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZUBid6xOThIaoJp31WNxyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-ch%C3%A9ile-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 389,
#    'categories': [{'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8514803804586,
#     'longitude': -73.9399689480721},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '839 W 181st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10033',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['839 W 181st St', 'New York, NY 10033']},
#    'phone': '+12127403111',
#    'display_phone': '(212) 740-3111',
#    'distance': 16870.338306369445},
#   {'id': 'pNYcGGAj4AYaExlmrEmfUw',
#    'alias': 'harrys-new-york-3',
#    'name': "Harry's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/39-Q464fNu8S5y3LCQB_UA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harrys-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 711,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.704512, 'longitude': -74.009834},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '1 Hanover Sq',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Hanover Sq', 'New York, NY 10004']},
#    'phone': '+12127859200',
#    'display_phone': '(212) 785-9200',
#    'distance': 1305.755380059775},
#   {'id': 'XVbFdJaSEECQdU0nDyUOug',
#    'alias': 'harefield-road-brooklyn',
#    'name': 'Harefield Road',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/q9O0ymp56FnNO1DFpRFYyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harefield-road-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 456,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.714756, 'longitude': -73.943436},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '769 Metropolitan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['769 Metropolitan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17183886870',
#    'display_phone': '(718) 388-6870',
#    'distance': 4409.904738270775},
#   {'id': 'J6WUjE6i1vAJFVKEdUtupQ',
#    'alias': 'cork-city-hoboken',
#    'name': 'Cork City',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rzij6DM_GDFLJ_AKvUD5kA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cork-city-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 118,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74, 'longitude': -74.03077},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '239 Bloomfield St',
#     'address2': 'Ste A',
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['239 Bloomfield St', 'Ste A', 'Hoboken, NJ 07030']},
#    'phone': '+12019635512',
#    'display_phone': '(201) 963-5512',
#    'distance': 4921.432539009519},
#   {'id': '-WUCua_aSIpfsHKMFlMEMg',
#    'alias': 'dirty-precious-brooklyn',
#    'name': 'Dirty Precious',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WJh5OJHFs3O4cVSOo98zqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dirty-precious-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 80,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6763896691334,
#     'longitude': -73.9867169468351},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '317 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['317 3rd Ave', 'Brooklyn, NY 11215']},
#    'phone': '+16466854481',
#    'display_phone': '(646) 685-4481',
#    'distance': 3293.328261853655},
#   {'id': 'P3NfoMjBy_o2BTNNZ-5okg',
#    'alias': 'apotheke-new-york-4',
#    'name': 'Apotheke',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ovQE3vhXaNeAL9lMSXUq9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/apotheke-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1460,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71434, 'longitude': -73.99822},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '9 Doyers St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Doyers St', 'New York, NY 10013']},
#    'phone': '+12124060400',
#    'display_phone': '(212) 406-0400',
#    'distance': 1046.0094120816689},
#   {'id': 'q0yhbxB4ErbWKRQ28_q5qA',
#    'alias': 'the-bit-dobbs-ferry-2',
#    'name': 'The Bit',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CBexUyPaT61C5H1Ogz_8Lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bit-dobbs-ferry-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 111,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.01525671626719,
#     'longitude': -73.87156249037085},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '23 Cedar St',
#     'address2': '',
#     'address3': None,
#     'city': 'Dobbs Ferry',
#     'zip_code': '10522',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23 Cedar St', 'Dobbs Ferry, NY 10522']},
#    'phone': '+19146938008',
#    'display_phone': '(914) 693-8008',
#    'distance': 35962.40779791702},
#   {'id': 'ETgJqJHV7BW6pIr9Ox74sA',
#    'alias': 'amélie-new-york',
#    'name': 'Amélie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cSDgVuPMnJgMLTrTNSEXug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/am%C3%A9lie-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2751,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7327, 'longitude': -73.99766},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '22 W 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 W 8th St', 'New York, NY 10011']},
#    'phone': '+12125332962',
#    'display_phone': '(212) 533-2962',
#    'distance': 3038.8699032940094},
#   {'id': 'ph-GkrDhM1pBwbs-pfvV1A',
#    'alias': 'garfunkels-new-york',
#    'name': "Garfunkel's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V4SDoWXp4DlWqgN0hvdukA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/garfunkels-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 240,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'speakeasies', 'title': 'Speakeasies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71941, 'longitude': -73.98501},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '67 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['67 Clinton St', 'New York, NY 10002']},
#    'phone': '+12125296900',
#    'display_phone': '(212) 529-6900',
#    'distance': 1736.5904931956702},
#   {'id': 'Xq9uOJz0U1iugBqRoQt1hA',
#    'alias': 'tír-na-nóg-new-york-12',
#    'name': 'Tír na Nóg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yni4uxDlGj_ozExMfZaUjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/t%C3%ADr-na-n%C3%B3g-new-york-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 377,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'irish_pubs', 'title': 'Irish Pub'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75585, 'longitude': -73.99214},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '315 W 39th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['315 W 39th St', 'New York, NY 10018']},
#    'phone': '+12127600072',
#    'display_phone': '(212) 760-0072',
#    'distance': 5617.993162615603},
#   {'id': 'z5hRX3iJ5Ty_S38iG_WY3Q',
#    'alias': 'tanner-smiths-new-york-2',
#    'name': 'Tanner Smiths',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Cd4oaUWci9sYJbXy3fbqnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tanner-smiths-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1822,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76442, 'longitude': -73.98169},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '204 W 55th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['204 W 55th St', 'New York, NY 10019']},
#    'phone': '+16465902034',
#    'display_phone': '(646) 590-2034',
#    'distance': 6628.69302856469},
#   {'id': 'IPrNgaXjtEJrb8vWA3si1g',
#    'alias': 'bar-great-harry-brooklyn',
#    'name': 'Bar Great Harry',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/m65tgn23I4CkmdAm__9oxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-great-harry-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 207,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.682437, 'longitude': -73.993598},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '280 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['280 Smith St', 'Brooklyn, NY 11231']},
#    'phone': '+13474575650',
#    'display_phone': '(347) 457-5650',
#    'distance': 2558.7546243068955},
#   {'id': '_4Z3SqUupa6s1oOkLWYSww',
#    'alias': 'london-lennies-rego-park',
#    'name': "London Lennie's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/82r8tUaD5UWge0YWy57_tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/london-lennies-rego-park?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 660,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7219348, 'longitude': -73.8672914},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '6388 Woodhaven Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6388 Woodhaven Blvd', 'Rego Park, NY 11374']},
#    'phone': '+17188948084',
#    'display_phone': '(718) 894-8084',
#    'distance': 10833.19946629678}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#               Restaurant        Type Price  Rating            Address  \
# 0                e's BAR        Bars    $$     4.0  511 Amsterdam Ave
# 1      Cronin & Phelan's        Pubs    $$     4.5     38-14 Broadway
# 2                Frankie  Australian    $$     4.0       264 Grove St
# 3        Smithfield Hall        Pubs    $$     4.0      138 W 25th St
# 4  Putnam's Pub & Cooker  Gastropubs    $$     3.5     419 Myrtle Ave
#
#          Lat        Lng                                                url  \
# 0  40.786692 -73.975565  https://www.yelp.com/biz/es-bar-new-york?adjus...
# 1  40.758900 -73.919410  https://www.yelp.com/biz/cronin-and-phelans-as...
# 2  40.717178 -74.044245  https://www.yelp.com/biz/frankie-jersey-city?a...
# 3  40.744753 -73.993494  https://www.yelp.com/biz/smithfield-hall-new-y...
# 4  40.693321 -73.969045  https://www.yelp.com/biz/putnams-pub-and-cooke...
#
#                        ID
# 0  GXh9YpX4v8Wemrq-SPDPhA
# 1  TikAlBfPzWZQ9h5yk8Mmdg
# 2  zDkwJeNcNU251vmi2EeANg
# 3  GlSWzWVmQsKLGxySYSGRbQ
# 4  EY5ot4Z1tgbDC-TZXIcRjQ

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"british","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': '3ESlPTtjsEsyI5jhJFvBbw',
#    'alias': 'the-porterhouse-brewing-company-new-york',
#    'name': 'The Porterhouse Brewing Company',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kNhvT9F8RGbRkd2zZRmE3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-porterhouse-brewing-company-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 122,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7032627, 'longitude': -74.0107867},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '36 Water St',
#     'address2': '',
#     'address3': '58 Pearl St',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['36 Water St', '58 Pearl St', 'New York, NY 10004']},
#    'phone': '+12124257171',
#    'display_phone': '(212) 425-7171',
#    'distance': 1405.968175059443},
#   {'id': 'Rgm8BwcoqfIVSl2QSEOhbQ',
#    'alias': 'craft-new-york',
#    'name': 'Craft',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/glGoseqHJ11Y4HaAZBIT_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/craft-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1027,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73818, 'longitude': -73.98866},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '43 E 19th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43 E 19th St', 'New York, NY 10003']},
#    'phone': '+12127800880',
#    'display_phone': '(212) 780-0880',
#    'distance': 3671.1199253246136},
#   {'id': 'tRZcEKBNNwiZw1_Px_POag',
#    'alias': 'smith-and-mills-new-york-2',
#    'name': 'Smith & Mills',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HbiNnZw9Ak9x4qCxFb5Gtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/smith-and-mills-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 288,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72018, 'longitude': -74.00991},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '71 N Moore St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['71 N Moore St', 'New York, NY 10013']},
#    'phone': '+12122262515',
#    'display_phone': '(212) 226-2515',
#    'distance': 2097.499008813302},
#   {'id': 'qY1o1MhoRyN84RRhUJtvpQ',
#    'alias': 'her-name-is-han-new-york-3',
#    'name': 'Her Name Is Han',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fwSCdGzJPpe7DuO_LwLPDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/her-name-is-han-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1361,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7462615966797,
#     'longitude': -73.984733581543},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '17 E 31st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 E 31st St', 'New York, NY 10016']},
#    'phone': '+12127799990',
#    'display_phone': '(212) 779-9990',
#    'distance': 4610.341632711306},
#   {'id': 'eGfpa9r0aGtN3V8ZwgaOEw',
#    'alias': 'the-supply-house-new-york-2',
#    'name': 'The Supply House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZWfVzgaeUjHNhPELocQOOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-supply-house-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 355,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7775579, 'longitude': -73.9521892},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1647 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1647 2nd Ave', 'New York, NY 10028']},
#    'phone': '+16468613585',
#    'display_phone': '(646) 861-3585',
#    'distance': 8768.14412472643},
#   {'id': 'GCAQmtRdNhqVit5KGJ46Qg',
#    'alias': 'estela-new-york-2',
#    'name': 'Estela',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8wWtHn7OJvlyHsZWpMTDkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/estela-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 546,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.724759, 'longitude': -73.994728},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '47 E Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 E Houston St', 'New York, NY 10012']},
#    'phone': '+12122197693',
#    'display_phone': '(212) 219-7693',
#    'distance': 2147.944109430493},
#   {'id': 'FgsN_18sk15FcTnYY3Ghjg',
#    'alias': 'the-irish-american-new-york-2',
#    'name': 'The Irish American',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fCC0O8bsYa7ztIVa2yY-hg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-irish-american-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 302,
#    'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71015, 'longitude': -74.008781},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '17 John St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 John St', 'New York, NY 10038']},
#    'phone': '+16464146223',
#    'display_phone': '(646) 414-6223',
#    'distance': 1328.5404928833252},
#   {'id': 'C-8mGN7lt5rIraO5n-15ug',
#    'alias': 'the-smith-new-york-2',
#    'name': 'The Smith',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gih2UqttrnFYeoHpMEWYow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-smith-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2777,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.755165, 'longitude': -73.967868},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '956 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['956 2nd Ave', 'New York, NY 10022']},
#    'phone': '+12126442700',
#    'display_phone': '(212) 644-2700',
#    'distance': 5960.16818302934},
#   {'id': 'Kmi3Fm26aRRMLpQz4cf8XQ',
#    'alias': 'houndstooth-pub-new-york',
#    'name': 'Houndstooth Pub',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nQJ7_aFjJHe999lnahJO7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/houndstooth-pub-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 401,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7538807491515,
#     'longitude': -73.9919900171967},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '520 8th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['520 8th Ave', 'New York, NY 10018']},
#    'phone': '+12126430034',
#    'display_phone': '(212) 643-0034',
#    'distance': 5389.314205401417},
#   {'id': 'veku2cg2qaV-7MxwhOMBmg',
#    'alias': 'judge-roy-bean-public-house-new-york',
#    'name': 'Judge Roy Bean Public House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uyOBbYOb-lCGQBu6OmRNcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/judge-roy-bean-public-house-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 769,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7629158108786,
#     'longitude': -73.9761248066812},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '38 W 56th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38 W 56th St', 'New York, NY 10019']},
#    'phone': '+12122628300',
#    'display_phone': '(212) 262-8300',
#    'distance': 6571.265299457194},
#   {'id': 'Oyo1aojLt5Q6FXBNjidVeQ',
#    'alias': 'an-beal-bocht-cafe-bronx',
#    'name': 'An Beal Bocht Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ANA6ftlFERqukhXWI9szXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/an-beal-bocht-cafe-bronx?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 134,
#    'categories': [{'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.88738, 'longitude': -73.90498},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '445 W 238th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10463',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['445 W 238th St', 'Bronx, NY 10463']},
#    'phone': '+17188847127',
#    'display_phone': '(718) 884-7127',
#    'distance': 21591.840966026248},
#   {'id': 'XO3yD87rTPz9o6Dy9qRaJg',
#    'alias': 'the-spaniard-new-york',
#    'name': 'The Spaniard',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C7TTSwl8qtsN3YJbKvAS9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-spaniard-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 288,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'whiskeybars', 'title': 'Whiskey Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7327497, 'longitude': -74.0021829},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '190 W 4th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['190 W 4th St', 'New York, NY 10014']},
#    'phone': '+12129181986',
#    'display_phone': '(212) 918-1986',
#    'distance': 3108.1109361713225},
#   {'id': '7XTAcbukPloRuFbOgH4IoA',
#    'alias': 'haileys-harp-and-pub-metuchen',
#    'name': "Hailey's Harp and Pub",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/D3sBqPBqiwM1WXWuxVdKcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/haileys-harp-and-pub-metuchen?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 317,
#    'categories': [{'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.541342, 'longitude': -74.361062},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '400 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Metuchen',
#     'zip_code': '08840',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['400 Main St', 'Metuchen, NJ 08840']},
#    'phone': '+17323210777',
#    'display_phone': '(732) 321-0777',
#    'distance': 35932.37945619666},
#   {'id': 'PmFFar8XTHHft1BVE0NpCg',
#    'alias': 'keats-bar-new-york-3',
#    'name': 'Keats Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/11hMacQ34FiMWGeVadCvaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/keats-bar-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 141,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'karaoke', 'title': 'Karaoke'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.751495, 'longitude': -73.970637},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '842 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['842 2nd Ave', 'New York, NY 10017']},
#    'phone': '+12126825490',
#    'display_phone': '(212) 682-5490',
#    'distance': 5494.856772359663},
#   {'id': 'HhXM_ZKngz5oY6Hhjo8MqA',
#    'alias': 'freddys-bar-brooklyn-2',
#    'name': "Freddy's Bar",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vCyPRc8hPNT2JXigMyNHmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/freddys-bar-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 221,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6631969, 'longitude': -73.991061},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '627 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['627 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187680131',
#    'display_phone': '(718) 768-0131',
#    'distance': 4705.653246224021},
#   {'id': 'W_o2Hu_L53VQTpb5q29Kuw',
#    'alias': 'ryan-maguires-bar-and-restaurant-new-york-3',
#    'name': "Ryan Maguire's Bar & Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0UTvO_A-KDbflb6uEUaXhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ryan-maguires-bar-and-restaurant-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 160,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70806, 'longitude': -74.0051},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '28 Cliff St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 Cliff St', 'New York, NY 10038']},
#    'phone': '+12125666906',
#    'display_phone': '(212) 566-6906',
#    'distance': 951.677741948122},
#   {'id': 'gnrBeWKUchrJ_jFseV0mug',
#    'alias': 'clinton-hall-staten-island-3',
#    'name': 'Clinton Hall',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/E0EbYBmPix3aFXaGflXuwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clinton-hall-staten-island-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.644045, 'longitude': -74.074642},
#    'transactions': [],
#    'location': {'address1': '55 Richmond Ter',
#     'address2': '',
#     'address3': 'Empire Outlets',
#     'city': 'Staten Island',
#     'zip_code': '10301',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Richmond Ter',
#      'Empire Outlets',
#      'Staten Island, NY 10301']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9646.232584605716},
#   {'id': '_m0UAJile3kJDJ9lb3p9bQ',
#    'alias': 'the-painted-lady-saloon-new-york',
#    'name': 'The Painted Lady Saloon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NnFXHp8xX5yW1bQOZDarAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-painted-lady-saloon-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 94,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78336, 'longitude': -73.94796},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1825 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1825 2nd Ave', 'New York, NY 10128']},
#    'phone': '+16463681682',
#    'display_phone': '(646) 368-1682',
#    'distance': 9501.326463525229},
#   {'id': 'n4m37Dm2Y5MUPF_dFGG_ww',
#    'alias': 'fort-washington-public-house-new-york',
#    'name': 'Fort Washington Public House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/S4i9ULE9HpDsaoI0SpegTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fort-washington-public-house-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 88,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.8390591026124,
#     'longitude': -73.9410637691617},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3938 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10032',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3938 Broadway', 'New York, NY 10032']},
#    'phone': '+16468132210',
#    'display_phone': '(646) 813-2210',
#    'distance': 15518.652192968764},
#   {'id': '2YPmpAaue_v1t0tb1PoHWw',
#    'alias': 'the-brass-rail-hoboken-hoboken',
#    'name': 'The Brass Rail Hoboken',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Cj8LKcSBfcJXib6ZOuz5WA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-brass-rail-hoboken-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 522,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73855, 'longitude': -74.03019},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '135 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['135 Washington St', 'Hoboken, NJ 07030']},
#    'phone': '+12016597074',
#    'display_phone': '(201) 659-7074',
#    'distance': 4774.197980959563},
#   {'id': 'jf3JRaxUYU93x8LFU-8gkA',
#    'alias': 'gupshup-new-york',
#    'name': 'GupShup',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6mlCylhy_vusqveopX5OIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gupshup-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 399,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7368323318866,
#     'longitude': -73.9877132715179},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '115 E18th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['115 E18th St', 'New York, NY 10003']},
#    'phone': '+12125187313',
#    'display_phone': '(212) 518-7313',
#    'distance': 3540.447976577984},
#   {'id': 'gvrsN1fIZhzmagEPT21cCQ',
#    'alias': 'corgi-spirits-jersey-city',
#    'name': 'Corgi Spirits',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Waer3euYp-WGXboGRagb4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/corgi-spirits-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'distilleries', 'title': 'Distilleries'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7180595397949,
#     'longitude': -74.0745620727539},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1 Distillery Dr',
#     'address2': None,
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07304',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1 Distillery Dr', 'Jersey City, NJ 07304']},
#    'phone': '+12014484184',
#    'display_phone': '(201) 448-4184',
#    'distance': 5938.594751671779},
#   {'id': 'Hp1ZDTeJOP1NrY2aFtROgQ',
#    'alias': 'woodbines-long-island-city',
#    'name': 'Woodbines',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qKT9T0L4ojYVi269vYSlVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/woodbines-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 326,
#    'categories': [{'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.745216, 'longitude': -73.95357},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '47-10 Vernon Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47-10 Vernon Blvd', 'Long Island City, NY 11101']},
#    'phone': '+17183618488',
#    'display_phone': '(718) 361-8488',
#    'distance': 5597.641114477878},
#   {'id': 'vnzaqkKceFACrL1Lys1bPg',
#    'alias': 'lucky-jacks-new-york',
#    'name': "Lucky Jack's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lVShRnxoR3dUgIh0-SDu5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lucky-jacks-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 177,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7196945116378,
#     'longitude': -73.989668437417},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '129 Orchard St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['129 Orchard St', 'New York, NY 10002']},
#    'phone': '+12124776555',
#    'display_phone': '(212) 477-6555',
#    'distance': 1631.7292817004218},
#   {'id': '-SM_BQ5jiqvot_kl7RKoaQ',
#    'alias': 'zacks-oak-bar-and-restaurant-hoboken',
#    'name': "Zack's Oak Bar & Restaurant",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6dQrT3zHi2l2BX7KCSy2Ug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zacks-oak-bar-and-restaurant-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 542,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7405885173001,
#     'longitude': -74.033968783915},
#    'transactions': ['restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '232 Willow Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['232 Willow Ave', 'Hoboken, NJ 07030']},
#    'phone': '+12016537770',
#    'display_phone': '(201) 653-7770',
#    'distance': 5142.95139366226},
#   {'id': 'AMXOlur-z5DXBeyri9b-Hg',
#    'alias': 'black-horse-pub-brooklyn-2',
#    'name': 'Black Horse Pub',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ckj46OBiqH7--J6ZBZvUbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-horse-pub-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 201,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.66518, 'longitude': -73.989997},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '568 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['568 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187881975',
#    'display_phone': '(718) 788-1975',
#    'distance': 4492.034231838354},
#   {'id': '6gPa-25RIcjTudX2s9Mrsg',
#    'alias': 'charleston-brooklyn',
#    'name': 'Charleston',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AtaXdu3_OzDwc7l92XCt9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/charleston-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 270,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7181519, 'longitude': -73.9576854},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '174 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['174 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17185999599',
#    'display_phone': '(718) 599-9599',
#    'distance': 3393.6471693591625},
#   {'id': '2T7VnitTQk8MQ0Zj9icIhQ',
#    'alias': 'electric-room-new-york-3',
#    'name': 'Electric Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/stkK8i36VBKVQ9laed_f0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/electric-room-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7421895, 'longitude': -74.0038627},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '355 W 16th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['355 W 16th St', 'New York, NY 10011']},
#    'phone': '+12122292511',
#    'display_phone': '(212) 229-2511',
#    'distance': 4173.967332771831},
#   {'id': 'Cnqy9w1BFXZFEaChfox0ow',
#    'alias': 'rosemarys-new-york',
#    'name': "Rosemary's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yTna7bBPXzSisuREIkV6Wg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rosemarys-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1043,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.734863, 'longitude': -73.99974},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '18 Greenwich Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18 Greenwich Ave', 'New York, NY 10011']},
#    'phone': '+12126471818',
#    'display_phone': '(212) 647-1818',
#    'distance': 3304.8439422821502},
#   {'id': 'mosd9Voq5Ws6k6Uduii_ww',
#    'alias': 'bar-boulud-new-york-2',
#    'name': 'Bar Boulud',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L8ZAztiUuJb-DRtAx2W88A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-boulud-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 892,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7718443592464,
#     'longitude': -73.9818808860381},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '1900 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1900 Broadway', 'New York, NY 10023']},
#    'phone': '+12125950303',
#    'display_phone': '(212) 595-0303',
#    'distance': 7456.971063517986},
#   {'id': 'hwkePen_Ewq3zR8P2P4Bdw',
#    'alias': 'the-hoptimist-new-york',
#    'name': 'The Hoptimist',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UR7pAdG_AVti8Vcq0IpONQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hoptimist-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.784068824638176,
#     'longitude': -73.97788119467435},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '422 Amsterdam Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['422 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+16466091046',
#    'display_phone': '(646) 609-1046',
#    'distance': 8851.228671168172},
#   {'id': '9pMhRYYgV7E9L7pzECtJKA',
#    'alias': 'the-drunken-munkey-ues-new-york',
#    'name': 'The Drunken Munkey - UES',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GgyYVXAY1-AFFZHYeBa6dQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-drunken-munkey-ues-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1123,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78098, 'longitude': -73.94751},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '338 E 92nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['338 E 92nd St', 'New York, NY 10128']},
#    'phone': '+18773686539',
#    'display_phone': '(877) 368-6539',
#    'distance': 9259.57479406468},
#   {'id': 'QvQilClGyuKFz08TBsoJNA',
#    'alias': 'le-district-new-york',
#    'name': 'Le District',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9V2g0-Cmq5-i3RnMiWntCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-district-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 580,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7126473617984,
#     'longitude': -74.0157784596443},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '225 Liberty St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10281',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['225 Liberty St', 'New York, NY 10281']},
#    'phone': '+12129818588',
#    'display_phone': '(212) 981-8588',
#    'distance': 1980.159842860005},
#   {'id': '_MjMpJ6fVQZbbTOZf8T2XA',
#    'alias': 'lovers-of-today-new-york',
#    'name': 'Lovers of Today',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UX9VNWlaJWL-GBHbTFeEEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lovers-of-today-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 279,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7258338928223,
#     'longitude': -73.9833755493164},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '132 1/2 E 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['132 1/2 E 7th St', 'New York, NY 10009']},
#    'phone': '+12124209517',
#    'display_phone': '(212) 420-9517',
#    'distance': 2444.430058178137},
#   {'id': 'noujMiOizbAWyDw8LbiM8Q',
#    'alias': 'union-hall-brooklyn',
#    'name': 'Union Hall',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/miR8UX9F5maFVShJKS-1Fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/union-hall-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 647,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'theater', 'title': 'Performing Arts'},
#     {'alias': 'bocceball', 'title': 'Bocce Ball'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67612, 'longitude': -73.98005},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '702 Union St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['702 Union St', 'Brooklyn, NY 11215']},
#    'phone': '+17186384400',
#    'display_phone': '(718) 638-4400',
#    'distance': 3480.900494743433},
#   {'id': 'dDl8JcDS10GsR4-jiKS80Q',
#    'alias': 'rambling-house-bronx',
#    'name': 'Rambling House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rhAyVHZpU6UVdoNGsT4bcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rambling-house-bronx?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 159,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'irish', 'title': 'Irish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.8983612, 'longitude': -73.8671608},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4292 Katonah Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10470',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4292 Katonah Ave', 'Bronx, NY 10470']},
#    'phone': '+17187984510',
#    'display_phone': '(718) 798-4510',
#    'distance': 23988.76992304577},
#   {'id': 'i6TXF9Oh-0TFb3AsifIuYg',
#    'alias': 'the-crown-inn-brooklyn',
#    'name': 'The Crown Inn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/N47jYYrWxQDUSaJPdRzk3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-crown-inn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 200,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.673874, 'longitude': -73.957101},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '724 Franklin Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['724 Franklin Ave', 'Brooklyn, NY 11238']},
#    'phone': '+13344630756',
#    'display_phone': '(334) 463-0756',
#    'distance': 4707.12671177677},
#   {'id': 'yXkibW4aTbHlmorIkGSg_Q',
#    'alias': 'xiv-brooklyn',
#    'name': 'XIV',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mvqY-T24DxouoCq_OzxChg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/xiv-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 82,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'cabaret', 'title': 'Cabaret'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7060529, 'longitude': -73.9233777},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '383 Troutman St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['383 Troutman St', 'Brooklyn, NY 11237']},
#    'phone': '+18668114111',
#    'display_phone': '(866) 811-4111',
#    'distance': 5978.086378705586},
#   {'id': 'SlaI4mfLp9r3aWEvj-E6FQ',
#    'alias': 'the-old-toll-bar-cafe-gretna',
#    'name': 'The Old Toll Bar Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Pf7wR82tBqtoHN4wOxI6DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-old-toll-bar-cafe-gretna?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 54.9954, 'longitude': -3.06594},
#    'transactions': [],
#    'location': {'address1': 'Sarkbridge',
#     'address2': '',
#     'address3': '',
#     'city': 'Gretna',
#     'zip_code': '',
#     'country': 'GB',
#     'state': 'DGY',
#     'display_address': ['Sarkbridge',
#      'Gretna, Dumfries and Galloway',
#      'United Kingdom']},
#    'phone': '+441461338461',
#    'display_phone': '+44 1461 338461',
#    'distance': 8633.313316521037},
#   {'id': 'w75Qg2i02FPNN6HQ2yKS_w',
#    'alias': 'the-penny-farthing-new-york',
#    'name': 'The Penny Farthing',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HWKodaadvuavLXLtiAqR4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-penny-farthing-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 482,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'irish', 'title': 'Irish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7324498147889,
#     'longitude': -73.9875972841437},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '103 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 3rd Ave', 'New York, NY 10003']},
#    'phone': '+12123877300',
#    'display_phone': '(212) 387-7300',
#    'distance': 3055.3747304378344},
#   {'id': 'wJ9VnRlrJJP5QnVohBDjoA',
#    'alias': 'russian-vodka-room-new-york',
#    'name': 'Russian Vodka Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PKlderfFSqWRqDgPlgoHbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/russian-vodka-room-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 549,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'jazzandblues', 'title': 'Jazz & Blues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76349, 'longitude': -73.9848},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '265 W 52nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['265 W 52nd St', 'New York, NY 10019']},
#    'phone': '+12123075835',
#    'display_phone': '(212) 307-5835',
#    'distance': 6503.7308715178715},
#   {'id': '9AXTJkwXdWaJaQkCjpj6mA',
#    'alias': 'sunday-in-brooklyn-brooklyn-3',
#    'name': 'Sunday in Brooklyn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aQ6Q-J6s4imnnsxnfVASjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sunday-in-brooklyn-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 946,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.714145, 'longitude': -73.965322},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '348 Wythe Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['348 Wythe Ave', 'Brooklyn, NY 11249']},
#    'phone': '+13472226722',
#    'display_phone': '(347) 222-6722',
#    'distance': 2626.5777794971095},
#   {'id': '1DiNPx_BycnIl5vFvOnpNA',
#    'alias': 'the-unusual-times-newark',
#    'name': 'The Unusual Times',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ESIglVgW43Ju2q75P4U74A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-unusual-times-newark?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 119,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.6899443953096,
#     'longitude': -74.1756600135658},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3 Brewster Rd',
#     'address2': 'Gate B53',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07114',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['3 Brewster Rd', 'Gate B53', 'Newark, NJ 07114']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 15386.695502730538},
#   {'id': 'rgAj05ov6HLAECdE39wMVg',
#    'alias': 'light-horse-tavern-jersey-city-3',
#    'name': 'Light Horse Tavern',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/E6cQeKgJJa3hWaHBOCZEZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/light-horse-tavern-jersey-city-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 703,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7139744, 'longitude': -74.03812453680533},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '199 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['199 Washington St', 'Jersey City, NJ 07302']},
#    'phone': '+12019462028',
#    'display_phone': '(201) 946-2028',
#    'distance': 3814.267073132141},
#   {'id': '4MqJOLaeqCgBFQmMFPfe3g',
#    'alias': 'clover-club-brooklyn',
#    'name': 'Clover Club',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rTFP3ikw4UUsST892sav9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clover-club-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 795,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6846046447754, 'longitude': -73.9921875},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '210 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['210 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17188557939',
#    'display_phone': '(718) 855-7939',
#    'distance': 2326.838717287213},
#   {'id': 'bpjDo7svAFD10eszaOPQHw',
#    'alias': 'clinton-hall-new-york-13',
#    'name': 'Clinton Hall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0lX58zsHKhM7R9Ey9DAGdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clinton-hall-new-york-13?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 216,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75009, 'longitude': -73.98471},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '16 W 36th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['16 W 36th St', 'New York, NY 10018']},
#    'phone': '+12126950036',
#    'display_phone': '(212) 695-0036',
#    'distance': 5021.331080017711},
#   {'id': 't_IXO90SSJz4pt5GLD2lTA',
#    'alias': 'playwright-celtic-pub-new-york-4',
#    'name': 'Playwright Celtic Pub',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QjdhOSfCoP3s7F6I0mHMwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/playwright-celtic-pub-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 373,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.75933, 'longitude': -73.98793},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '732 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['732 8th Ave', 'New York, NY 10036']},
#    'phone': '+12123548404',
#    'display_phone': '(212) 354-8404',
#    'distance': 6015.546677865985},
#   {'id': 'LDwxXfapMw6xNbTF0YDFaQ',
#    'alias': 'brooklyn-public-house-brooklyn',
#    'name': 'Brooklyn Public House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0zx7-jZ0bb4mMu5mTP1Tbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-public-house-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 325,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.68958, 'longitude': -73.96939},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '247 Dekalb Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['247 Dekalb Ave', 'Brooklyn, NY 11205']},
#    'phone': '+13472278976',
#    'display_phone': '(347) 227-8976',
#    'distance': 2738.4094534097794},
#   {'id': 'tOn-wEQ06ScrgeU5Ljw7Gw',
#    'alias': 'alfies-new-york',
#    'name': "Alfie's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/elq8pQW9zl3k_fYpkGFYzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alfies-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 561,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.765437, 'longitude': -73.987278},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '800 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['800 9th Ave', 'New York, NY 10019']},
#    'phone': '+12127572390',
#    'display_phone': '(212) 757-2390',
#    'distance': 6696.94866880618},
#   {'id': 'Ujjazj0UBN7-4GyImezpUg',
#    'alias': 'st-elias-bar-brooklyn',
#    'name': 'St. Elias Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/alY6ZxDKKklxK3Ji5dw4Nw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-elias-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'whiskeybars', 'title': 'Whiskey Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69798, 'longitude': -73.93679},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '899 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['899 Broadway', 'Brooklyn, NY 11206']},
#    'phone': '+13475339072',
#    'display_phone': '(347) 533-9072',
#    'distance': 4920.878962425359}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                         Restaurant            Type Price Rating  \
# 0  The Porterhouse Brewing Company       Breweries    $$      4
# 1                            Craft  American (New)  $$$$      4
# 2                    Smith & Mills         Lounges    $$      4
# 3                  Her Name Is Han          Korean    $$    4.5
# 4                 The Supply House            Bars    $$      4
#
#          Address        Lat        Lng  \
# 0    36 Water St  40.703263 -74.010787
# 1   43 E 19th St  40.738180 -73.988660
# 2  71 N Moore St  40.720180 -74.009910
# 3   17 E 31st St  40.746262 -73.984734
# 4   1647 2nd Ave  40.777558 -73.952189
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/the-porterhouse-brewi...  3ESlPTtjsEsyI5jhJFvBbw
# 1  https://www.yelp.com/biz/craft-new-york?adjust...  Rgm8BwcoqfIVSl2QSEOhbQ
# 2  https://www.yelp.com/biz/smith-and-mills-new-y...  tRZcEKBNNwiZw1_Px_POag
# 3  https://www.yelp.com/biz/her-name-is-han-new-y...  qY1o1MhoRyN84RRhUJtvpQ
# 4  https://www.yelp.com/biz/the-supply-house-new-...  eGfpa9r0aGtN3V8ZwgaOEw

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"british","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [{'id': 'j8DFd-bxnvM_UfHnDLIA0g',
#    'alias': 'woodrows-new-york',
#    'name': "Woodrow's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/q4BGHV69-aKRPENBtE52Ww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/woodrows-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 337,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7141113, 'longitude': -74.009201},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '43 Murray St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43 Murray St', 'New York, NY 10007']},
#    'phone': '+12126760300',
#    'display_phone': '(212) 676-0300',
#    'distance': 1581.2688575831396},
#   {'id': '_YmyHYuM5On1zW17aOf3ZA',
#    'alias': 'terrace-fish-and-chips-new-york-2',
#    'name': 'Terrace Fish & Chips',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ez6tExW9CL2sflh0PoNL8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/terrace-fish-and-chips-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 101,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.704044, 'longitude': -74.01049},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '77 Pearl St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['77 Pearl St', 'New York, NY 10004']},
#    'phone': '+12128094604',
#    'display_phone': '(212) 809-4604',
#    'distance': 1373.936855881178},
#   {'id': 'HDfDo-wh4WOEdkoAMlc4Gw',
#    'alias': 'tierney-fine-foods-bronx',
#    'name': 'Tierney Fine Foods',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fzZpErmf79mfoROSg5xSoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tierney-fine-foods-bronx?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'irish', 'title': 'Irish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.90538, 'longitude': -73.89794},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '5780 Mosholu Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10471',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5780 Mosholu Ave', 'Bronx, NY 10471']},
#    'phone': '+17187964996',
#    'display_phone': '(718) 796-4996',
#    'distance': 23658.923915734053},
#   {'id': '6CjMpreth0lfnbpxTMTkvQ',
#    'alias': 'st-anns-warehouse-brooklyn',
#    'name': "St Ann's Warehouse",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RjKNz4zkjga9sA_nmtDq9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-anns-warehouse-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'theater', 'title': 'Performing Arts'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7036590915414,
#     'longitude': -73.9928808671827},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '45 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+17182548779',
#    'display_phone': '(718) 254-8779',
#    'distance': 231.52373501426365},
#   {'id': 'PldbjkxtHmWC2QVyV5dAbQ',
#    'alias': 'wilfie-and-nell-new-york',
#    'name': 'Wilfie & Nell',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VdiH0hF8YkZeV_Q-Q5qKmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wilfie-and-nell-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 356,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7340642, 'longitude': -74.003069},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '228 W 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 W 4th St', 'New York, NY 10014']},
#    'phone': '+12122422990',
#    'display_phone': '(212) 242-2990',
#    'distance': 3267.132512853281},
#   {'id': 'nsAU6F2vmdnphmfIa_RuWg',
#    'alias': 'mables-smokehouse-and-banquet-hall-brooklyn-6',
#    'name': "Mable's Smokehouse & Banquet Hall",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OS2cqRCWCOioXnpLo-yeHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mables-smokehouse-and-banquet-hall-brooklyn-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 909,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7211890204726,
#     'longitude': -73.9570004492998},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '44 Berry St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['44 Berry St', 'Brooklyn, NY 11249']},
#    'phone': '+17182186655',
#    'display_phone': '(718) 218-6655',
#    'distance': 3597.829928403173},
#   {'id': 'IiIzeFqe4tJiHaAWyw7ddg',
#    'alias': 'west-end-bar-and-grill-new-york',
#    'name': 'West End Bar & Grill',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/omM0NS_hFe9quXE9odlIag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/west-end-bar-and-grill-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 388,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7615693, 'longitude': -73.9867747},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '813 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['813 8th Ave', 'New York, NY 10019']},
#    'phone': '+12127078986',
#    'display_phone': '(212) 707-8986',
#    'distance': 6282.898553138117},
#   {'id': 'urAFiOOP-QGzD8sUwFsb6g',
#    'alias': 'coast-and-valley-new-york',
#    'name': 'Coast and Valley',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DnPCE6dWPWYDTe_ErTWCJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coast-and-valley-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72288, 'longitude': -73.95039},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '587 Manhattan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['587 Manhattan Ave', 'New York, NY 11222']},
#    'phone': '+19178387559',
#    'display_phone': '(917) 838-7559',
#    'distance': 4174.873723295263},
#   {'id': 'QKiVXF-Y1IK_NkRfvtY4sQ',
#    'alias': 'one-star-new-york',
#    'name': 'One Star',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EWR4XoEhHqqI5yH-kV6OWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/one-star-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 158,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7445145622588,
#     'longitude': -73.9940418298492},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '147 W 24th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['147 W 24th St', 'New York, NY 10011']},
#    'phone': '+12127770100',
#    'display_phone': '(212) 777-0100',
#    'distance': 4344.399011590157},
#   {'id': 'lZ1yZxsZULTo5jJSljWr9g',
#    'alias': 'the-pub-rye',
#    'name': 'The Pub',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/f3-oiC1G3ferK_3r5B-JeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pub-rye?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.9832899, 'longitude': -73.68513},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3 Elm Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'Rye',
#     'zip_code': '10580',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3 Elm Pl', 'Rye, NY 10580']},
#    'phone': '+19143053966',
#    'display_phone': '(914) 305-3966',
#    'distance': 40380.90116006212},
#   {'id': '66ndKMpJyowBx-GrvM4QvA',
#    'alias': 'trinity-pub-new-york',
#    'name': 'Trinity Pub',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tuE1Stz_u_5NR5uvkUasng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trinity-pub-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 107,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'triviahosts', 'title': 'Trivia Hosts'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7771, 'longitude': -73.9537},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '229 E 84th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['229 E 84th St', 'New York, NY 10028']},
#    'phone': '+12123274450',
#    'display_phone': '(212) 327-4450',
#    'distance': 8680.959303380501},
#   {'id': 'MyQV4i518ZO4CLudtR8gLA',
#    'alias': 'the-bar-room-new-york',
#    'name': 'The Bar Room',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Cqic-DpE3NCrBpEAnIDKPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bar-room-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 538,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.763409, 'longitude': -73.968449},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '117 E 60th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['117 E 60th St', 'New York, NY 10022']},
#    'phone': '+12125615523',
#    'display_phone': '(212) 561-5523',
#    'distance': 6803.218295278219},
#   {'id': 'kMxXLrASxsbmS-ZzAaBe-A',
#    'alias': 'mollys-new-york',
#    'name': "Molly's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5D7aQWP3TN6tRM_0IJlcXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mollys-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 523,
#    'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73825, 'longitude': -73.98321},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '287 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['287 3rd Ave', 'New York, NY 10010']},
#    'phone': '+12128893361',
#    'display_phone': '(212) 889-3361',
#    'distance': 3764.352123073312},
#   {'id': '49ST--X1jcIPzUIM1O3K6w',
#    'alias': 'mominette-brooklyn-2',
#    'name': 'Mominette',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SClcXzYF9awG33Iya6weKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mominette-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 713,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.703252, 'longitude': -73.925889},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '221 Knickerbocker Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['221 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#    'phone': '+19292342941',
#    'display_phone': '(929) 234-2941',
#    'distance': 5781.762228266177},
#   {'id': '13jzN6n45XtcbYA46nWThg',
#    'alias': 'the-bar-downstairs-and-kitchen-new-york-3',
#    'name': 'The Bar Downstairs and Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VnWn7j3_EjsheURgDHyYwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bar-downstairs-and-kitchen-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 372,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7528813879886,
#     'longitude': -73.9810645580292},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '485 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['485 5th Ave', 'New York, NY 10017']},
#    'phone': '+12126011234',
#    'display_phone': '(212) 601-1234',
#    'distance': 5391.192018714771},
#   {'id': 'ok8VAxxZLd05RNEX88GzFg',
#    'alias': 'beauty-bar-new-york',
#    'name': 'Beauty Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MTyw8FvOlIiJL7gS5JJxmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beauty-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 537,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'danceclubs', 'title': 'Dance Clubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7329864501953,
#     'longitude': -73.985710144043},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '231 E 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 E 14th St', 'New York, NY 10003']},
#    'phone': '+12125391389',
#    'display_phone': '(212) 539-1389',
#    'distance': 3139.40631485587},
#   {'id': 'bn3qRcfBg0YG1-zIR1hscA',
#    'alias': 'drift-in-new-york',
#    'name': 'Drift In',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/umj5VRz2_zFESbiTw4m3Sg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/drift-in-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 80,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7329109, 'longitude': -74.0106435},
#    'transactions': ['delivery'],
#    'location': {'address1': '389 W St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['389 W St', 'New York, NY 10014']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3355.4028107537397},
#   {'id': 'MLFKsPTgN2EHEyD4cPZznQ',
#    'alias': 'nearys-new-york',
#    'name': "Neary's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/guxF1cLK_EgXrnN7TkOwnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nearys-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'},
#     {'alias': 'irish', 'title': 'Irish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.758244, 'longitude': -73.963522},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '358 East 57th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['358 East 57th St', 'New York, NY 10022']},
#    'phone': '+12127511434',
#    'display_phone': '(212) 751-1434',
#    'distance': 6420.655031181185},
#   {'id': '8ucQ3A7f6h9_PkKStYBkQA',
#    'alias': 'lalou-brooklyn',
#    'name': 'LaLou',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LZnjnHumh3h5FTN-O0SB4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lalou-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.680311, 'longitude': -73.967596},
#    'transactions': ['delivery'],
#    'location': {'address1': '581 Vanderbilt Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['581 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17188579463',
#    'display_phone': '(718) 857-9463',
#    'distance': 3586.3868798584126},
#   {'id': 'Li52Rr6BM4bGNYdpn7H8_w',
#    'alias': 'coopers-craft-and-kitchen-new-york-2',
#    'name': "Cooper's Craft & Kitchen",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ejB9Y5jDsDjC7t5ATYu9aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coopers-craft-and-kitchen-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 386,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.742702, 'longitude': -74.000778},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '169 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['169 8th Ave', 'New York, NY 10011']},
#    'phone': '+16466617711',
#    'display_phone': '(646) 661-7711',
#    'distance': 4178.814049118333},
#   {'id': 'CZAio2nkMzsEyYlZOK4zrQ',
#    'alias': 'the-globe-new-york',
#    'name': 'The Globe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PqQ4nZMhSBjNLwtk-5FXiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-globe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 220,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7388038635254,
#     'longitude': -73.9838180541992},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '158 E 23rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['158 E 23rd St', 'New York, NY 10010']},
#    'phone': '+12124776161',
#    'display_phone': '(212) 477-6161',
#    'distance': 3819.9780314803784},
#   {'id': 'RKfsthB00W-NGoM_abs-Lg',
#    'alias': 'bell-book-and-candle-new-york',
#    'name': 'Bell Book & Candle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_0lBsdtXfUkwR1PzT82_lQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bell-book-and-candle-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 244,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73465, 'longitude': -74.00086},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '141 W 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['141 W 10th St', 'New York, NY 10014']},
#    'phone': '+12124142355',
#    'display_phone': '(212) 414-2355',
#    'distance': 3298.708279975039},
#   {'id': 'vRPIyINPzX1depGmOp6svA',
#    'alias': 'the-shannon-rose-clifton-3',
#    'name': 'The Shannon Rose',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/s_dwXkN_J0WjpfPNLaHrdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-shannon-rose-clifton-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 435,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.8252898972273,
#     'longitude': -74.1381025314331},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '98 Kingsland Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Clifton',
#     'zip_code': '07014',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['98 Kingsland Rd', 'Clifton, NJ 07014']},
#    'phone': '+19732840200',
#    'display_phone': '(973) 284-0200',
#    'distance': 18007.4898584122},
#   {'id': 'XghOzJn16M-nvaKMOdC5og',
#    'alias': 'verlaine-new-york-2',
#    'name': 'Verlaine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/F2ou7G6rM1TcQW9G0V31Hg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/verlaine-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1452,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720079, 'longitude': -73.987785},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '110 Rivington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['110 Rivington St', 'New York, NY 10002']},
#    'phone': '+12126142493',
#    'display_phone': '(212) 614-2493',
#    'distance': 1717.209013709613},
#   {'id': 'C1m7JYy9RSooGD06kMvoPA',
#    'alias': 'british-airways-concorde-room-queens',
#    'name': 'British Airways Concorde Room',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hl2G1eQzG1KWos216sCpLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/british-airways-concorde-room-queens?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'airportlounges', 'title': 'Airport Lounges'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.6492645901329,
#     'longitude': -73.7838849797845},
#    'transactions': [],
#    'location': {'address1': 'Van Wyck & JFK Expressway',
#     'address2': 'Terminal 7',
#     'address3': None,
#     'city': 'Queens',
#     'zip_code': '11430',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Van Wyck & JFK Expressway',
#      'Terminal 7',
#      'Queens, NY 11430']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 18811.125284946516},
#   {'id': '3lLBRLbXAIgd1yZgWgnfeg',
#    'alias': 'dutch-kills-long-island-city',
#    'name': 'Dutch Kills',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/S11kn7JT_YRT4onWUBE54g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dutch-kills-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 783,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.747615, 'longitude': -73.940159},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '27-24 Jackson Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27-24 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+17183832724',
#    'display_phone': '(718) 383-2724',
#    'distance': 6541.943251600472},
#   {'id': 'XAltgdIxnXF3iaNgWhb5ZA',
#    'alias': 'hawksmoor-new-york',
#    'name': 'Hawksmoor',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yFoZ4ZfohTzBz4Q1Z0JhyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hawksmoor-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.73977538644137,
#     'longitude': -73.986388401965},
#    'transactions': [],
#    'location': {'address1': '109 E 22nd St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['109 E 22nd St', 'New York, NY 10010']},
#    'phone': '+12127771840',
#    'display_phone': '(212) 777-1840',
#    'distance': 3875.063607507648},
#   {'id': '0zoH7DYisCVenAQUQzr5VA',
#    'alias': 'the-wheeltapper-pub-and-patio-new-york',
#    'name': 'The Wheeltapper Pub And Patio',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WN2NAxdOCtVobOJ1CyDAGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wheeltapper-pub-and-patio-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 189,
#    'categories': [{'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7525725446153,
#     'longitude': -73.9744985103607},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '141 E 44th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['141 E 44th St', 'New York, NY 10017']},
#    'phone': '+12123516800',
#    'display_phone': '(212) 351-6800',
#    'distance': 5499.404712167268},
#   {'id': 'FCJaZeBoeeM5F2ZhfzO0sA',
#    'alias': 'crave-astoria-44',
#    'name': 'Crave',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mssIbSqloDGfSnZPbAmXaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crave-astoria-44?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 348,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.765631, 'longitude': -73.9166717},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '28-55 36th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28-55 36th St', 'Astoria, NY 11103']},
#    'phone': '+17187264976',
#    'display_phone': '(718) 726-4976',
#    'distance': 9305.824394501422},
#   {'id': '16ZnHpuaaBt92XWeJHCC5A',
#    'alias': 'olio-e-piú-new-york-city',
#    'name': 'Olio e Piú',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/W_kyLvXj7ustj-XHWYU6tQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olio-e-pi%C3%BA-new-york-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2773,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.733798036104304,
#     'longitude': -73.99977392649927},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3 Greenwich Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York City',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3 Greenwich Ave', 'New York City, NY 10014']},
#    'phone': '+12122436546',
#    'display_phone': '(212) 243-6546',
#    'distance': 3186.3804982206075},
#   {'id': '234C99-QPpEDnUZ3yWnukw',
#    'alias': 'norwood-club-new-york',
#    'name': 'Norwood Club',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/z01UnkzSKJqlC76uTSan4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/norwood-club-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 134,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'social_clubs', 'title': 'Social Clubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73952, 'longitude': -74.00124},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '241 W 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['241 W 14th St', 'New York, NY 10011']},
#    'phone': '+12122559300',
#    'display_phone': '(212) 255-9300',
#    'distance': 3832.474580501234},
#   {'id': 'Yfz28vZWjNIUi_8chtaNcw',
#    'alias': 'bellos-pub-and-grill-newark',
#    'name': "Bello's Pub & Grill",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2yQd0VWTRgSUSfFClCHQyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bellos-pub-and-grill-newark?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 181,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7334, 'longitude': -74.16351},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '376 Market St',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07105',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['376 Market St', 'Newark, NJ 07105']},
#    'phone': '+19734650052',
#    'display_phone': '(973) 465-0052',
#    'distance': 14593.262866620977},
#   {'id': 'objNX6cuj1JyUijFjw21Qw',
#    'alias': 'bombay-bistro-new-york-2',
#    'name': 'Bombay Bistro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/b1C4UNd7ZaddOFKKhjouug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bombay-bistro-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 215,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73136, 'longitude': -74.00253},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '31 Cornelia St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31 Cornelia St', 'New York, NY 10014']},
#    'phone': '+16468503719',
#    'display_phone': '(646) 850-3719',
#    'distance': 2964.061413304234},
#   {'id': 'uiqxxKHuuETtWbiKdiocXw',
#    'alias': 'irish-cottage-forest-hills',
#    'name': 'Irish Cottage',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QyVPBjGXv5BnDoH9yOEp6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/irish-cottage-forest-hills?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 197,
#    'categories': [{'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7197538285905,
#     'longitude': -73.8425123691559},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10807 72nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10807 72nd Ave', 'Forest Hills, NY 11375']},
#    'phone': '+17185208530',
#    'display_phone': '(718) 520-8530',
#    'distance': 12891.358221052527},
#   {'id': 'TtGdKu-qGVvFttp-RcdYwg',
#    'alias': 'the-harold-new-york',
#    'name': 'The Harold',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/G7E9ylv0aiGcf-rhXRdpRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-harold-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 479,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7483140920034,
#     'longitude': -73.9884801920307},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1271 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1271 Broadway', 'New York, NY 10001']},
#    'phone': '+12126861888',
#    'display_phone': '(212) 686-1888',
#    'distance': 4791.937551180646},
#   {'id': 't-KNCZ7WtIWedBzYu_li3Q',
#    'alias': 'summit-house-summit',
#    'name': 'Summit House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Rh3nOuMIi_GQ_GDB2cqsNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/summit-house-summit?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 197,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71826, 'longitude': -74.35853},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '395 Springfield Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Summit',
#     'zip_code': '07901',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['395 Springfield Ave', 'Summit, NJ 07901']},
#    'phone': '+19082736000',
#    'display_phone': '(908) 273-6000',
#    'distance': 30725.265173837906},
#   {'id': '5wDbAclRoX71FCn-Dj5M-Q',
#    'alias': 'the-long-room-new-york',
#    'name': 'The Long Room',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T8bEe4lP6hjWiEfx0LC-1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-long-room-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 294,
#    'categories': [{'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.756387, 'longitude': -73.98436},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '120 W 44th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['120 W 44th St', 'New York, NY 10036']},
#    'phone': '+12129973933',
#    'display_phone': '(212) 997-3933',
#    'distance': 5726.00347632453},
#   {'id': 'iYmTPHpjcb3xtHn8DlkoWQ',
#    'alias': 'doc-watsons-new-york',
#    'name': "Doc Watson's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ePWDkDuvr2lfMGOPk1o3PQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doc-watsons-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 252,
#    'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.77226, 'longitude': -73.95548},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1490 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1490 2nd Ave', 'New York, NY 10075']},
#    'phone': '+12129885300',
#    'display_phone': '(212) 988-5300',
#    'distance': 8117.99717511201},
#   {'id': '1LIptXhtDh58vAA-QPFL4w',
#    'alias': 'cask-new-york-2',
#    'name': 'Cask',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eZRKDZp7cskMvw9-5hP9Jw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cask-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1385,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.745414, 'longitude': -73.979004},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '167 E 33rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['167 E 33rd St', 'New York, NY 10016']},
#    'phone': '+12123004924',
#    'display_phone': '(212) 300-4924',
#    'distance': 4627.343247572076},
#   {'id': 'RYKGs45OjF-vlb2Ds2Jb_g',
#    'alias': 'izakaya-juraku-new-york-2',
#    'name': 'Izakaya Juraku',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xlRw20ojLF480_VF8GNrZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-juraku-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 139,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7196796287355,
#     'longitude': -73.9887088537216},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '121 Ludlow St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['121 Ludlow St', 'New York, NY 10002']},
#    'phone': '+12124770100',
#    'display_phone': '(212) 477-0100',
#    'distance': 1651.3305168112172},
#   {'id': '6F9XOOr60g5fL46YOOhyRQ',
#    'alias': 'british-airways-galleries-lounge-queens',
#    'name': 'British Airways Galleries Lounge',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PGnVg__OkIR8IZ9fB2R-1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/british-airways-galleries-lounge-queens?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'airportlounges', 'title': 'Airport Lounges'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.649188, 'longitude': -73.782907},
#    'transactions': [],
#    'location': {'address1': 'Van Wyck & JFK Expy',
#     'address2': None,
#     'address3': 'Terminal 7',
#     'city': 'Queens',
#     'zip_code': '11430',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Van Wyck & JFK Expy',
#      'Terminal 7',
#      'Queens, NY 11430']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 18891.764854022873},
#   {'id': 'OiSjFh06dsNonI0cPXMSOw',
#    'alias': 'bondurants-new-york',
#    'name': 'Bondurants',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3KJieSHQuFeZqP8zPzo4TA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bondurants-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 472,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'southern', 'title': 'Southern'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.777292, 'longitude': -73.951854},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '303 E 85th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['303 E 85th St', 'New York, NY 10028']},
#    'phone': '+19292791884',
#    'display_phone': '(929) 279-1884',
#    'distance': 8752.61399842724},
#   {'id': 'UWcSgjqokBZ9X80bXAQBQg',
#    'alias': 'blue-bar-at-india-house-new-york',
#    'name': 'Blue Bar At India House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YUxeg2T9SOtrnds3iAYAZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-bar-at-india-house-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.704621, 'longitude': -74.009757},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1 Hanover Square',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Hanover Square', 'New York, NY 10004']},
#    'phone': '+12122692323',
#    'display_phone': '(212) 269-2323',
#    'distance': 1306.7231578291455},
#   {'id': 'uFRbWHqcD3mh5HX_vkQm8A',
#    'alias': 'drop-off-service-new-york',
#    'name': 'Drop Off Service',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hzvfrndtYLz7OicnKFIm2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/drop-off-service-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 303,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72993, 'longitude': -73.9809},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '211 Ave A',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['211 Ave A', 'New York, NY 10009']},
#    'phone': '+12122602914',
#    'display_phone': '(212) 260-2914',
#    'distance': 2944.976210235594},
#   {'id': 'GW42yOQB6G97Pc0KujI3lA',
#    'alias': 'donovans-pub-woodside',
#    'name': "Donovan's Pub",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CAgLKn5_kgrm0JmSfsBPUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/donovans-pub-woodside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 438,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7452467497759,
#     'longitude': -73.9068230114332},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '57-24 Roosevelt Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['57-24 Roosevelt Ave', 'Woodside, NY 11377']},
#    'phone': '+17184299339',
#    'display_phone': '(718) 429-9339',
#    'distance': 8597.602493312226},
#   {'id': 'U_hLyiUqDB16FBREKfJ8Xw',
#    'alias': 'the-barrow-house-clifton',
#    'name': 'The Barrow House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Fo_MTm1sqDBMfheRYqYKYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-barrow-house-clifton?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 970,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8717056, 'longitude': -74.172376},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1296 Van Houten Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Clifton',
#     'zip_code': '07013',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1296 Van Houten Ave', 'Clifton, NJ 07013']},
#    'phone': '+15512236609',
#    'display_phone': '(551) 223-6609',
#    'distance': 23773.94992638993},
#   {'id': '6gzQLjzJk25ePm_JS7ZAug',
#    'alias': 'esme-brooklyn-2',
#    'name': 'Esme',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cUxgl7JaulSa5e1Q4cS_Yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/esme-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 348,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73322607409529,
#     'longitude': -73.95492695812946},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '999 Manhattan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['999 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183830999',
#    'display_phone': '(718) 383-0999',
#    'distance': 4533.145027356241},
#   {'id': 'w4cFJhUpjGXqqWBd3BbY4w',
#    'alias': 'freemans-new-york-3',
#    'name': 'Freemans',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/u8-TgAt7tq_VQXj-fXPMCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/freemans-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2104,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.721988, 'longitude': -73.992466},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': 'Freeman Alley',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Freeman Alley', 'New York, NY 10002']},
#    'phone': '+12124200012',
#    'display_phone': '(212) 420-0012',
#    'distance': 1845.9460130020204},
#   {'id': 'Cz6It2NB_QBXCjnlsWGZSA',
#    'alias': 'boulton-and-watt-new-york',
#    'name': 'Boulton & Watt',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uScYMiEdwntiw58KDS0H7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boulton-and-watt-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 685,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722520164329694,
#     'longitude': -73.98635991078673},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '5 Ave A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 Ave A', 'New York, NY 10009']},
#    'phone': '+16464906004',
#    'display_phone': '(646) 490-6004',
#    'distance': 2012.9791315994748},
#   {'id': 'n8p5g3-Fu1RBKx35QhiaXg',
#    'alias': 'bua-new-york',
#    'name': 'Bua',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0X-HBJC7dDEdaAqz_0MiOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bua-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 531,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7268537, 'longitude': -73.9838067},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '122 St Marks Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['122 St Marks Pl', 'New York, NY 10009']},
#    'phone': '+12129796276',
#    'display_phone': '(212) 979-6276',
#    'distance': 2539.317914220864}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#              Restaurant                    Type Price Rating  \
# 0             Woodrow's  American (Traditional)    $$      4
# 1  Terrace Fish & Chips                 Seafood    $$      4
# 2    Tierney Fine Foods                   Delis    $$    3.5
# 3    St Ann's Warehouse         Performing Arts    $$      4
# 4         Wilfie & Nell                    Bars    $$    3.5
#
#             Address        Lat        Lng  \
# 0      43 Murray St  40.714111 -74.009201
# 1       77 Pearl St  40.704044 -74.010490
# 2  5780 Mosholu Ave  40.905380 -73.897940
# 3       45 Water St  40.703659 -73.992881
# 4      228 W 4th St  40.734064 -74.003069
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/woodrows-new-york?adj...  j8DFd-bxnvM_UfHnDLIA0g
# 1  https://www.yelp.com/biz/terrace-fish-and-chip...  _YmyHYuM5On1zW17aOf3ZA
# 2  https://www.yelp.com/biz/tierney-fine-foods-br...  HDfDo-wh4WOEdkoAMlc4Gw
# 3  https://www.yelp.com/biz/st-anns-warehouse-bro...  6CjMpreth0lfnbpxTMTkvQ
# 4  https://www.yelp.com/biz/wilfie-and-nell-new-y...  PldbjkxtHmWC2QVyV5dAbQ

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                            Restaurant                    Type Rating Price  \
# 0    British Airways Galleries Lounge         Airport Lounges
# 1       British Airways Concorde Room         Airport Lounges
# 2                          Berry Park          American (New)    3.5    $$
# 3                        The Spaniard          American (New)      4    $$
# 4                       The East Pole          American (New)    3.5   $$$
# 5                  Sunday in Brooklyn          American (New)      4    $$
# 6                  Light Horse Tavern          American (New)    3.5    $$
# 7               Playwright Celtic Pub          American (New)      3    $$
# 8                             Alfie's          American (New)      4    $$
# 9                           The Smith          American (New)      4    $$
# 10                             Estela          American (New)      4   $$$
# 11                              Craft          American (New)      4  $$$$
# 12                     Boulton & Watt          American (New)      4    $$
# 13             The Brass Rail Hoboken          American (New)    3.5    $$
# 14                         Tír na Nóg          American (New)      4    $$
# 15                   White Oak Tavern          American (New)      4    $$
# 16                 Bell Book & Candle          American (New)    3.5    $$
# 17                         The Hutton          American (New)    4.5    $$
# 18                       Summit House          American (New)      4   $$$
# 19                    The Wicked Monk          American (New)      4    $$
# 20                     Parker & Quinn          American (New)      4    $$
# 21                   The Barrow House          American (New)      4    $$
# 22                               Esme          American (New)    4.5    $$
# 23                       The Bar Room          American (New)      4    $$
# 24                       Clinton Hall          American (New)
# 25       Blue Ribbon Brasserie - SoHo  American (Traditional)    4.5   $$$
# 26                 Tryon Public House  American (Traditional)      4    $$
# 27                    Houndstooth Pub  American (Traditional)      3    $$
# 28                          Keats Bar  American (Traditional)      3    $$
# 29    Ryan Maguire's Bar & Restaurant  American (Traditional)      4    $$
# ..                                ...                     ...    ...   ...
# 170                    Rambling House                    Pubs    3.5    $$
# 171      Carragher's Pub & Restaurant                    Pubs      4    $$
# 172                        Union Hall                    Pubs      4    $$
# 173                 The Unusual Times                    Pubs      2    $$
# 174              The Churchill Tavern                    Pubs    3.5    $$
# 175                     The Monro Pub                    Pubs    4.5     $
# 176                       The Rookery                    Pubs      4    $$
# 177             Brooklyn Public House                    Pubs    3.5    $$
# 178                   Black Horse Pub                    Pubs      4    $$
# 179           O'Henry's Publick House                    Pubs
# 180                      Maggie Mae's                    Pubs    4.5    $$
# 181                   The Shakespeare                    Pubs      4    $$
# 182                The Double Windsor                    Pubs      4    $$
# 183                     Caledonia Bar                    Pubs    4.5    $$
# 184                       Trinity Pub                    Pubs      4    $$
# 185                         The Craic                    Pubs      4    $$
# 186       Judge Roy Bean Public House                    Pubs    4.5    $$
# 187               124 Old Rabbit Club                    Pubs      4    $$
# 188                   Smithfield Hall                    Pubs      4    $$
# 189                      Custom House                    Pubs      3    $$
# 190      Fort Washington Public House                   Salad    4.5    $$
# 191                   London Lennie's                 Seafood    3.5   $$$
# 192                          Drift In                 Seafood
# 193              Terrace Fish & Chips                 Seafood      4    $$
# 194                      The Chippery                 Seafood
# 195                           Harry's             Steakhouses      4   $$$
# 196                         Hawksmoor             Steakhouses
# 197                          Verlaine      Tapas/Small Plates      4    $$
# 198                  Coast and Valley               Wine Bars
# 199                             LaLou               Wine Bars
#
#                        Address        Lat        Lng  \
# 0          Van Wyck & JFK Expy  40.649188 -73.782907
# 1    Van Wyck & JFK Expressway  40.649265 -73.783885
# 2                   4 Berry St  40.722472 -73.955253
# 3                 190 W 4th St  40.732750 -74.002183
# 4                133 E 65th St  40.766236 -73.965801
# 5                348 Wythe Ave  40.714145 -73.965322
# 6            199 Washington St  40.713974 -74.038125
# 7                  732 8th Ave  40.759330 -73.987930
# 8                  800 9th Ave  40.765437 -73.987278
# 9                  956 2nd Ave  40.755165 -73.967868
# 10             47 E Houston St  40.724759 -73.994728
# 11                43 E 19th St  40.738180 -73.988660
# 12                     5 Ave A  40.722520 -73.986360
# 13           135 Washington St  40.738550 -74.030190
# 14               315 W 39th St  40.755850 -73.992140
# 15               21 Waverly Pl  40.730360 -73.994620
# 16               141 W 10th St  40.734650 -74.000860
# 17               225 Hutton St  40.746708 -74.055575
# 18         395 Springfield Ave  40.718260 -74.358530
# 19                9510 3rd Ave  40.616988 -74.034023
# 20                64 W 39th St  40.752586 -73.985071
# 21         1296 Van Houten Ave  40.871706 -74.172376
# 22           999 Manhattan Ave  40.733226 -73.954927
# 23               117 E 60th St  40.763409 -73.968449
# 24             55 Richmond Ter  40.644045 -74.074642
# 25              97 Sullivan St  40.725456 -74.003027
# 26               4740 Broadway  40.864982 -73.927843
# 27                 520 8th Ave  40.753881 -73.991990
# 28                 842 2nd Ave  40.751495 -73.970637
# 29                 28 Cliff St  40.708060 -74.005100
# ..                         ...        ...        ...
# 170           4292 Katonah Ave  40.898361 -73.867161
# 171              228 W 39th St  40.756148 -73.990848
# 172               702 Union St  40.676120 -73.980050
# 173              3 Brewster Rd  40.689944 -74.175660
# 174               45 E 28th St  40.743589 -73.984484
# 175                481 5th Ave  40.667745 -73.987360
# 176            425 Troutman St  40.707351 -73.922109
# 177             247 Dekalb Ave  40.689580 -73.969390
# 178                568 5th Ave  40.665180 -73.989997
# 179            10 Minthorne St  40.637505 -74.075560
# 180          41-15 Queens Blvd  40.743835 -73.923029
# 181               24 E 39th St  40.750606 -73.980176
# 182        210 Prospect Park W  40.660630 -73.980560
# 183               1609 2nd Ave  40.776327 -73.953213
# 184              229 E 84th St  40.777100 -73.953700
# 185             488 Driggs Ave  40.718520 -73.955040
# 186               38 W 56th St  40.762916 -73.976125
# 187           124 MacDougal St  40.729926 -74.000219
# 188              138 W 25th St  40.744753 -73.993494
# 189            139 Montague St  40.694862 -73.993713
# 190              3938 Broadway  40.839059 -73.941064
# 191        6388 Woodhaven Blvd  40.721935 -73.867291
# 192                   389 W St  40.732911 -74.010644
# 193                77 Pearl St  40.704044 -74.010490
# 194         983 Communipaw Ave  40.723509 -74.089950
# 195               1 Hanover Sq  40.704512 -74.009834
# 196              109 E 22nd St  40.739775 -73.986388
# 197           110 Rivington St  40.720079 -73.987785
# 198          587 Manhattan Ave  40.722880 -73.950390
# 199         581 Vanderbilt Ave  40.680311 -73.967596
#
#                                                    url                      ID
# 0
# 1
# 2    https://www.yelp.com/biz/berry-park-brooklyn?a...  DMOwfdP0Va1QI_KNefD8kg
# 3    https://www.yelp.com/biz/the-spaniard-new-york...  XO3yD87rTPz9o6Dy9qRaJg
# 4    https://www.yelp.com/biz/the-east-pole-new-yor...  Xcnq-GIw48tMPlUIavpGmA
# 5    https://www.yelp.com/biz/sunday-in-brooklyn-br...  9AXTJkwXdWaJaQkCjpj6mA
# 6    https://www.yelp.com/biz/light-horse-tavern-je...  rgAj05ov6HLAECdE39wMVg
# 7    https://www.yelp.com/biz/playwright-celtic-pub...  t_IXO90SSJz4pt5GLD2lTA
# 8    https://www.yelp.com/biz/alfies-new-york?adjus...  tOn-wEQ06ScrgeU5Ljw7Gw
# 9    https://www.yelp.com/biz/the-smith-new-york-2?...  C-8mGN7lt5rIraO5n-15ug
# 10   https://www.yelp.com/biz/estela-new-york-2?adj...  GCAQmtRdNhqVit5KGJ46Qg
# 11   https://www.yelp.com/biz/craft-new-york?adjust...  Rgm8BwcoqfIVSl2QSEOhbQ
# 12   https://www.yelp.com/biz/boulton-and-watt-new-...  Cz6It2NB_QBXCjnlsWGZSA
# 13   https://www.yelp.com/biz/the-brass-rail-hoboke...  2YPmpAaue_v1t0tb1PoHWw
# 14   https://www.yelp.com/biz/t%C3%ADr-na-n%C3%B3g-...  Xq9uOJz0U1iugBqRoQt1hA
# 15   https://www.yelp.com/biz/white-oak-tavern-new-...  mVN2G1c5bRtAsNlr2Tbx6Q
# 16   https://www.yelp.com/biz/bell-book-and-candle-...  RKfsthB00W-NGoM_abs-Lg
# 17   https://www.yelp.com/biz/the-hutton-jersey-cit...  gt-0HkY2DC-NscmhOsKOWw
# 18   https://www.yelp.com/biz/summit-house-summit?a...  t-KNCZ7WtIWedBzYu_li3Q
# 19   https://www.yelp.com/biz/the-wicked-monk-brook...  VP_HZr_j0dXKd80lUBfsyg
# 20   https://www.yelp.com/biz/parker-and-quinn-new-...  IOHaEgK1zDvUvB3SfKuGCw
# 21   https://www.yelp.com/biz/the-barrow-house-clif...  U_hLyiUqDB16FBREKfJ8Xw
# 22   https://www.yelp.com/biz/esme-brooklyn-2?adjus...  6gzQLjzJk25ePm_JS7ZAug
# 23   https://www.yelp.com/biz/the-bar-room-new-york...  MyQV4i518ZO4CLudtR8gLA
# 24
# 25   https://www.yelp.com/biz/blue-ribbon-brasserie...  txSykTj5nbwmpiVNoK_Dyg
# 26   https://www.yelp.com/biz/tryon-public-house-ne...  ykXZyQBXxoOMoZfaZMnHmg
# 27   https://www.yelp.com/biz/houndstooth-pub-new-y...  Kmi3Fm26aRRMLpQz4cf8XQ
# 28   https://www.yelp.com/biz/keats-bar-new-york-3?...  PmFFar8XTHHft1BVE0NpCg
# 29   https://www.yelp.com/biz/ryan-maguires-bar-and...  W_o2Hu_L53VQTpb5q29Kuw
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/rambling-house-bronx?...  dDl8JcDS10GsR4-jiKS80Q
# 171  https://www.yelp.com/biz/carraghers-pub-and-re...  7boggcCID7gVdNFQn4e8hQ
# 172  https://www.yelp.com/biz/union-hall-brooklyn?a...  noujMiOizbAWyDw8LbiM8Q
# 173  https://www.yelp.com/biz/the-unusual-times-new...  1DiNPx_BycnIl5vFvOnpNA
# 174  https://www.yelp.com/biz/the-churchill-tavern-...  G6Kc58Oc42uXY2alGCoDBA
# 175  https://www.yelp.com/biz/the-monro-pub-brookly...  _cYuN0yD4aStZ0oXPaaRmQ
# 176  https://www.yelp.com/biz/the-rookery-brooklyn?...  HYFSOb5o4hppToeYe1va1A
# 177  https://www.yelp.com/biz/brooklyn-public-house...  LDwxXfapMw6xNbTF0YDFaQ
# 178  https://www.yelp.com/biz/black-horse-pub-brook...  AMXOlur-z5DXBeyri9b-Hg
# 179
# 180  https://www.yelp.com/biz/maggie-maes-sunnyside...  UJSQHmL81lgWqBrc9Bp3Cw
# 181  https://www.yelp.com/biz/the-shakespeare-new-y...  i34wlziIjT8lHgUN1o0ToQ
# 182  https://www.yelp.com/biz/the-double-windsor-br...  xd7ioU33jkwx0hQ3kUNIOg
# 183  https://www.yelp.com/biz/caledonia-bar-new-yor...  FLRx5tOBMMDJHEUYAAfa8A
# 184  https://www.yelp.com/biz/trinity-pub-new-york?...  66ndKMpJyowBx-GrvM4QvA
# 185  https://www.yelp.com/biz/the-craic-brooklyn?ad...  PxyxNj43WSDjRF588HFJdQ
# 186  https://www.yelp.com/biz/judge-roy-bean-public...  veku2cg2qaV-7MxwhOMBmg
# 187  https://www.yelp.com/biz/124-old-rabbit-club-n...  -wkcI5M7902hJyhkN1zS3A
# 188  https://www.yelp.com/biz/smithfield-hall-new-y...  GlSWzWVmQsKLGxySYSGRbQ
# 189  https://www.yelp.com/biz/custom-house-brooklyn...  RsLs863308rBCJqwuGfNeA
# 190  https://www.yelp.com/biz/fort-washington-publi...  n4m37Dm2Y5MUPF_dFGG_ww
# 191  https://www.yelp.com/biz/london-lennies-rego-p...  _4Z3SqUupa6s1oOkLWYSww
# 192
# 193  https://www.yelp.com/biz/terrace-fish-and-chip...  _YmyHYuM5On1zW17aOf3ZA
# 194
# 195  https://www.yelp.com/biz/harrys-new-york-3?adj...  pNYcGGAj4AYaExlmrEmfUw
# 196
# 197  https://www.yelp.com/biz/verlaine-new-york-2?a...  XghOzJn16M-nvaKMOdC5og
# 198
# 199
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_British.csv')
