# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"italian","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': 'WG639VkTjmK5dzydd1BBJA',
#    'alias': 'rubirosa-new-york-2',
#    'name': 'Rubirosa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LuSzR8cpVQRofXOT_bMi1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2448,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.722766, 'longitude': -73.996233},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '235 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#    'phone': '+12129650500',
#    'display_phone': '(212) 965-0500',
#    'distance': 1932.9467701334759},
#   {'id': '16ZnHpuaaBt92XWeJHCC5A',
#    'alias': 'olio-e-piú-new-york-city',
#    'name': 'Olio e Piú',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/W_kyLvXj7ustj-XHWYU6tQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olio-e-pi%C3%BA-new-york-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2773,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.733798036104304,
#     'longitude': -73.99977392649927},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3 Greenwich Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York City',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3 Greenwich Ave', 'New York City, NY 10014']},
#    'phone': '+12122436546',
#    'display_phone': '(212) 243-6546',
#    'distance': 3186.3804982206075},
#   {'id': 'Vs8kQ4R381y27AH018gLpg',
#    'alias': 'supper-new-york',
#    'name': 'Supper',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0_7KZ8dR-G-p8x0clySkSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/supper-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1364,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7229, 'longitude': -73.98527},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '156 E 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156 E 2nd St', 'New York, NY 10009']},
#    'phone': '+12124777600',
#    'display_phone': '(212) 477-7600',
#    'distance': 2088.7434147525933},
#   {'id': 'rp8S7scxOkVVeG7dNneMGQ',
#    'alias': 'l-artusi-new-york',
#    'name': "L'Artusi",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/I6GySxIEaWaA2n5v7yCl3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-artusi-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1958,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73372, 'longitude': -74.00513},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '228 W 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 W 10th St', 'New York, NY 10014']},
#    'phone': '+12122555757',
#    'display_phone': '(212) 255-5757',
#    'distance': 3272.999060891836},
#   {'id': 'hdiuRS9sVZSMReZm4oV5SA',
#    'alias': 'da-andrea-new-york',
#    'name': 'Da Andrea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dYaaHrqfyAn8C6x2odES-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-andrea-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 959,
#    'categories': [{'alias': 'tuscan', 'title': 'Tuscan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.736218, 'longitude': -73.99597},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '35 W 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35 W 13th St', 'New York, NY 10011']},
#    'phone': '+12123671979',
#    'display_phone': '(212) 367-1979',
#    'distance': 3424.7293369303584},
#   {'id': 'OCTiJwvjoK81WoDwsTkFvA',
#    'alias': 'paesano-of-mulberry-street-new-york',
#    'name': 'Paesano of Mulberry Street',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yN9ARCE3LF6u9E0yN5WpIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paesano-of-mulberry-street-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1060,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.718554, 'longitude': -73.997447},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '136 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136 Mulberry St', 'New York, NY 10013']},
#    'phone': '+12129651188',
#    'display_phone': '(212) 965-1188',
#    'distance': 1481.7066528289554},
#   {'id': 'k5fd-RSdG4IuXnnGSQ5oOw',
#    'alias': 'san-marzano-pasta-fresca-new-york',
#    'name': 'San Marzano Pasta Fresca',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zdM-ivewN83FqN36dZHChw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/san-marzano-pasta-fresca-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1270,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.727966, 'longitude': -73.988382},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '117 Second Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['117 Second Ave', 'New York, NY 10003']},
#    'phone': '+12127773600',
#    'display_phone': '(212) 777-3600',
#    'distance': 2557.918277420454},
#   {'id': 'DoSU8IPq-Py_YV3kYmXPfQ',
#    'alias': 'trattoria-trecolori-new-york',
#    'name': 'Trattoria Trecolori',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nL_iTlbmA__6yNAAj1Xldg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trattoria-trecolori-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2398,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.759876, 'longitude': -73.986767},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '254 West 47th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['254 West 47th St', 'New York, NY 10036']},
#    'phone': '+12129974540',
#    'display_phone': '(212) 997-4540',
#    'distance': 6084.389331712267},
#   {'id': 'MphfKkYFEe0BDQ6hZ0A5fA',
#    'alias': 'gelso-and-grand-new-york',
#    'name': 'Gelso & Grand',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hkiNG-bPWX459H2KIBrsvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gelso-and-grand-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1085,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7194089547259,
#     'longitude': -73.9973777877722},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '186 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['186 Grand St', 'New York, NY 10013']},
#    'phone': '+12122261600',
#    'display_phone': '(212) 226-1600',
#    'distance': 1574.3490321455226},
#   {'id': 'dh5r9-SbN8xJ76XvnayWLQ',
#    'alias': 'giano-restaurant-new-york',
#    'name': 'Giano Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0PrOZ5stl86k6V1SzHcjNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giano-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 636,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7262256596862,
#     'longitude': -73.9840574049125},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '126 E 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['126 E 7th St', 'New York, NY 10009']},
#    'phone': '+12126737200',
#    'display_phone': '(212) 673-7200',
#    'distance': 2466.5008597028605},
#   {'id': 'zwOAiVT4pAmpNGXzj-t5MA',
#    'alias': 'lilia-brooklyn',
#    'name': 'Lilia',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CVDfrE84IWv9v-Y86jqlRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lilia-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 921,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71757, 'longitude': -73.95236},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '567 Union Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['567 Union Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17185763095',
#    'display_phone': '(718) 576-3095',
#    'distance': 3776.4789584058713},
#   {'id': 'qBGKigOGn_flCx1apxPzlA',
#    'alias': 'piccola-cucina-osteria-new-york-city',
#    'name': 'Piccola Cucina Osteria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4JK5-l9XVlwXoPEMxaoCgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piccola-cucina-osteria-new-york-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 589,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72506, 'longitude': -74.00322},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '196 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York City',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['196 Spring St', 'New York City, NY 10012']},
#    'phone': '+16464787488',
#    'display_phone': '(646) 478-7488',
#    'distance': 2305.731891755423},
#   {'id': 'qgY41g_eg0eNzewCXmKcaA',
#    'alias': 'lillo-cucina-italiana-brooklyn',
#    'name': 'Lillo Cucina Italiana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/b2MP6R0g_sfFpnLRnQSduA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lillo-cucina-italiana-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 160,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.69023, 'longitude': -73.99634},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '331 Henry St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['331 Henry St', 'Brooklyn, NY 11201']},
#    'phone': '+13477630899',
#    'display_phone': '(347) 763-0899',
#    'distance': 1699.2204952670313},
#   {'id': 'CFR-HzVHKWRMpMAR3LAhzg',
#    'alias': 'montesacro-pinseria-brooklyn-brooklyn',
#    'name': 'Montesacro Pinseria Brooklyn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pXeNs5eU9r6Ks1fO2DX6eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/montesacro-pinseria-brooklyn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 155,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71338, 'longitude': -73.95136},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '432 Union Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['432 Union Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13479161062',
#    'display_phone': '(347) 916-1062',
#    'distance': 3734.036336252337},
#   {'id': 'TWH4MjLtN1fKlF-7n6YXHg',
#    'alias': 'lil-frankies-new-york',
#    'name': "Lil Frankie's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/b0nsA2W4oswnmH3fr-BOig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lil-frankies-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1230,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.723625, 'longitude': -73.988555},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '19 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 1st Ave', 'New York, NY 10003']},
#    'phone': '+12124204900',
#    'display_phone': '(212) 420-4900',
#    'distance': 2079.0350425992006},
#   {'id': 'J0OeDwmh5JBhid0A5GvltA',
#    'alias': 'il-corallo-trattoria-new-york',
#    'name': 'Il Corallo Trattoria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GQZVMl-a6lIpu_ZnB5xcgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-corallo-trattoria-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1029,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7262073, 'longitude': -74.0018919},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '176 Prince St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['176 Prince St', 'New York, NY 10012']},
#    'phone': '+12129417119',
#    'display_phone': '(212) 941-7119',
#    'distance': 2395.854722395596},
#   {'id': '6eqrk1wCQMww_ejze5gvsg',
#    'alias': 'forsythia-new-york-3',
#    'name': 'Forsythia',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MmMfYJlhQpcwS_HN91TgQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/forsythia-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 80,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7225353, 'longitude': -73.992492},
#    'transactions': ['delivery'],
#    'location': {'address1': '9 Stanton St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Stanton St', 'New York, NY 10002']},
#    'phone': '+16465900609',
#    'display_phone': '(646) 590-0609',
#    'distance': 1906.421726918875},
#   {'id': 'hpRrYBbKUqv8ewFKDjbjoA',
#    'alias': 'gersi-brooklyn',
#    'name': 'Gersi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aWJFBchETG6OWGVHj5aONg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gersi-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 292,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.683438, 'longitude': -73.995711},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '316 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['316 Court St', 'Brooklyn, NY 11231']},
#    'phone': '+13478895077',
#    'display_phone': '(347) 889-5077',
#    'distance': 2450.871323793601},
#   {'id': 'yZJbealagfujEkgesAl2hA',
#    'alias': 'lupa-new-york',
#    'name': 'Lupa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OdUK7zgusaMmPzToZuq3tA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lupa-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1602,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7276, 'longitude': -74.000045},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '170 Thompson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['170 Thompson St', 'New York, NY 10012']},
#    'phone': '+12129825089',
#    'display_phone': '(212) 982-5089',
#    'distance': 2517.265489271021},
#   {'id': 'IErfGS0DASSJfYU73m0Sqg',
#    'alias': 'malatesta-trattoria-new-york',
#    'name': 'Malatesta Trattoria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_qPgu5mT0We7Zv8sqdxLNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/malatesta-trattoria-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1271,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73285, 'longitude': -74.00847},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '649 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['649 Washington St', 'New York, NY 10014']},
#    'phone': '+12127411207',
#    'display_phone': '(212) 741-1207',
#    'distance': 3272.155011667827},
#   {'id': 'HodL0fXoF08C3Ir-kLeTtw',
#    'alias': 'forma-pasta-factory-brooklyn',
#    'name': 'Forma Pasta Factory',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7CWJUVmPmHFlo0CrXqPKGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/forma-pasta-factory-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 322,
#    'categories': [{'alias': 'pastashops', 'title': 'Pasta Shops'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72371, 'longitude': -73.95157},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '14 Bedford Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 Bedford Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183492009',
#    'display_phone': '(718) 349-2009',
#    'distance': 4141.117801995315},
#   {'id': '15k7iqFbhf4h8L01yggLqg',
#    'alias': 'song-e-napule-new-york',
#    'name': 'Song E Napule',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y9G-nheTrxSrx4Cqg0HzHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/song-e-napule-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 560,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72813, 'longitude': -74.00188},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '146 W Houston St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['146 W Houston St', 'New York, NY 10012']},
#    'phone': '+12125331242',
#    'display_phone': '(212) 533-1242',
#    'distance': 2607.168270554507},
#   {'id': 'fH8DkdRerw5LJ7fZZHRfeA',
#    'alias': 'leuca-brooklyn',
#    'name': 'Leuca',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vwsD0CIQCXcerVESUWsJNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/leuca-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 347,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722121, 'longitude': -73.956678},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '111 N 12th St',
#     'address2': '',
#     'address3': 'The William Vale Hotel',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 N 12th St',
#      'The William Vale Hotel',
#      'Brooklyn, NY 11249']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3672.793357584282},
#   {'id': 's5nPO911cYB2chdwqSqT9g',
#    'alias': 'la-nonna-ristorante-and-bar-brooklyn',
#    'name': 'La Nonna Ristorante & Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mJTwWUijvBuKe8H6h_6d6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-nonna-ristorante-and-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 340,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.718468787527,
#     'longitude': -73.9639185527139},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '184 Kent Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['184 Kent Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17183021100',
#    'display_phone': '(718) 302-1100',
#    'distance': 2941.358597910694},
#   {'id': 'V-FCEicobl5Su-R7EVJQNA',
#    'alias': 'la-lanterna-di-vittorio-new-york',
#    'name': 'La Lanterna Di Vittorio',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fniemSih6k-Gy103nmNVxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-lanterna-di-vittorio-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1501,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73069, 'longitude': -74.00015},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '129 MacDougal St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['129 MacDougal St', 'New York, NY 10012']},
#    'phone': '+19176393236',
#    'display_phone': '(917) 639-3236',
#    'distance': 2852.210394135104},
#   {'id': 'RXCCofQw1EjTcSN0ZeXfRA',
#    'alias': 'risotteria-melotti-nyc-new-york-3',
#    'name': 'Risotteria Melotti NYC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qZ4MldeNv60P9v8jzO_2lQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/risotteria-melotti-nyc-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 342,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.726673363853,
#     'longitude': -73.9880919456482},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '309 E 5th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['309 E 5th St', 'New York, NY 10003']},
#    'phone': '+16467558939',
#    'display_phone': '(646) 755-8939',
#    'distance': 2417.666625550634},
#   {'id': 'Q9F2ocrmYuGt1yn3M7MOBw',
#    'alias': 'lucali-brooklyn-3',
#    'name': 'Lucali',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Yl_eZ_DW_iaumnU-pfSoaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lucali-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1714,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6818, 'longitude': -74.00024},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '575 Henry St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['575 Henry St', 'Brooklyn, NY 11231']},
#    'phone': '+17188584086',
#    'display_phone': '(718) 858-4086',
#    'distance': 2674.849860473569},
#   {'id': 'nHMDOIX32dGbfpuNUwsLNQ',
#    'alias': 'almar-brooklyn-2',
#    'name': 'AlMar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_EoXWmBYT1-X--xHq0oUTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/almar-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 460,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.702662, 'longitude': -73.989177},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '111 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17188555288',
#    'display_phone': '(718) 855-5288',
#    'distance': 530.8013177444826},
#   {'id': 'HiNUBUR1hFwScd_OvVLQAg',
#    'alias': 'la-pecora-bianca-new-york',
#    'name': 'La Pecora Bianca',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pXoM8IbmiWix_LZSNqYGqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-pecora-bianca-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 739,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74358, 'longitude': -73.9892},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1133 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1133 Broadway', 'New York, NY 10010']},
#    'phone': '+12124989696',
#    'display_phone': '(212) 498-9696',
#    'distance': 4283.308393922253},
#   {'id': 'h37t9rA06Sr4EetJjKrfzw',
#    'alias': 'don-angie-new-york',
#    'name': 'Don Angie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SaIEklaR8jXW5itX2jRMgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/don-angie-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 431,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73778, 'longitude': -74.00197},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '103 Greenwich Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 Greenwich Ave', 'New York, NY 10014']},
#    'phone': '+12128898884',
#    'display_phone': '(212) 889-8884',
#    'distance': 3657.076882257761},
#   {'id': 'a4WZUTKn90dOkeY38JHNjQ',
#    'alias': 'aurora-brooklyn',
#    'name': 'Aurora',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gqibbn1SQd04poMNmRh2Dg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aurora-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 717,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.715621, 'longitude': -73.964757},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '70 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70 Grand St', 'Brooklyn, NY 11249']},
#    'phone': '+17183885100',
#    'display_phone': '(718) 388-5100',
#    'distance': 2734.6134515729195},
#   {'id': '4j_n7nPaZrp6_lEInZaA8Q',
#    'alias': 'aita-brooklyn',
#    'name': 'Aita',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4cX6tf-zDOQCNxa_aROOjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aita-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 282,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.686412, 'longitude': -73.966629},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '132 Greene Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['132 Greene Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17185763584',
#    'display_phone': '(718) 576-3584',
#    'distance': 3143.349399264751},
#   {'id': 'rJJiGJx3kfMAxtD7P7okHQ',
#    'alias': 'celeste-restaurant-new-york-4',
#    'name': 'Celeste Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EA5ECJCF3AQBoc5kOuh92g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/celeste-restaurant-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 919,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.78666, 'longitude': -73.97599},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '502 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['502 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12128744559',
#    'display_phone': '(212) 874-4559',
#    'distance': 9164.23028791989},
#   {'id': 'xeC9vn3dxVVzAMR_aFwfXg',
#    'alias': 'il-brigante-new-york',
#    'name': 'IL Brigante',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0G1IhFFYvIhkvG85SiSAgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-brigante-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 427,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.707492, 'longitude': -74.002571},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '214 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['214 Front St', 'New York, NY 10038']},
#    'phone': '+12122850222',
#    'display_phone': '(212) 285-0222',
#    'distance': 738.248263617683},
#   {'id': 'raqwXUBlnc0e8c7CYmxEJQ',
#    'alias': 'scarpetta-new-york',
#    'name': 'Scarpetta',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rinYP3lyShbUzJviQ92yIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scarpetta-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1990,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.744509, 'longitude': -73.9856},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '88 Madison Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['88 Madison Ave', 'New York, NY 10016']},
#    'phone': '+12126910555',
#    'display_phone': '(212) 691-0555',
#    'distance': 4405.069418725455},
#   {'id': '-Gc5sTFxoXM3Tiv_dkSJZg',
#    'alias': 'cecconis-dumbo-brooklyn',
#    'name': "Cecconi's Dumbo",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/39iIx_iSeCTk3PIwaKFBAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cecconis-dumbo-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 864,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7033063330116,
#     'longitude': -73.9916549604523},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '55 Water St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+17186503900',
#    'display_phone': '(718) 650-3900',
#    'distance': 325.5822990331506},
#   {'id': '74zaTegd7fnS6llTesn_Dg',
#    'alias': 'fragole-ristorante-brooklyn',
#    'name': 'Fragole Ristorante',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ss4i4Q0d1KG1D85p6Z4-vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fragole-ristorante-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 376,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68087, 'longitude': -73.99688},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '394 Court St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['394 Court St', 'Brooklyn, NY 11231']},
#    'phone': '+17185227133',
#    'display_phone': '(718) 522-7133',
#    'distance': 2740.565647878918},
#   {'id': 'M4pCWzdBCkp2g_d834a7Hw',
#    'alias': 'sauce-new-york-3',
#    'name': 'Sauce',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EtQuNDHcbVhXUplq7s9MFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sauce-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 844,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7204716, 'longitude': -73.9893263},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '78 Rivington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['78 Rivington St', 'New York, NY 10002']},
#    'phone': '+12124207700',
#    'display_phone': '(212) 420-7700',
#    'distance': 1722.539622700155},
#   {'id': '5k_jwjhdFMPUNWhouGNzuA',
#    'alias': 'misi-brooklyn',
#    'name': 'Misi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5oBIoYe1Xx82Eu7C9quqwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/misi-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 386,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71341, 'longitude': -73.96662},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '329 Kent Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['329 Kent Ave', 'Brooklyn, NY 11249']},
#    'phone': '+13475663262',
#    'display_phone': '(347) 566-3262',
#    'distance': 2494.8001205883406},
#   {'id': 'pk89jzL1RsE9U0thf_z6tw',
#    'alias': 'locanda-verde-new-york',
#    'name': 'Locanda Verde',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IQTzgUKx2v58Buv0OhF_XQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/locanda-verde-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1686,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7198601300801,
#     'longitude': -74.010039072422},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '377 Greenwich St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['377 Greenwich St', 'New York, NY 10013']},
#    'phone': '+12129253797',
#    'display_phone': '(212) 925-3797',
#    'distance': 2081.0044178443195},
#   {'id': 'VmgvCsAP6vZ3DL1mw8ugWQ',
#    'alias': 'osteria-del-porto-new-york',
#    'name': 'Osteria Del Porto',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YoBFIx8Zzk5y1IBFaVmGnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osteria-del-porto-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70737443140159,
#     'longitude': -74.00270427364536},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '212 Front St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['212 Front St', 'New York, NY 10038']},
#    'phone': '+16465906053',
#    'display_phone': '(646) 590-6053',
#    'distance': 740.7433933770113},
#   {'id': 'yc4vsT-Q4Ej1_9hr94DxkQ',
#    'alias': 'sotto-13-new-york-7',
#    'name': 'Sotto 13',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mCE2TARhbLRvR1eqSn9DsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sotto-13-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 938,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7372, 'longitude': -73.99919},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '140 W 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['140 W 13th St', 'New York, NY 10011']},
#    'phone': '+12126471001',
#    'display_phone': '(212) 647-1001',
#    'distance': 3557.7665642618012},
#   {'id': 'I2lgw_7DUnwD92ND4PN-Ow',
#    'alias': 'aunt-jakes-new-york',
#    'name': "Aunt Jake's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sidpFKYNOqx9VmLgslQN7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aunt-jakes-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1562,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7186467, 'longitude': -73.9979241},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '133 Mulberry St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['133 Mulberry St', 'New York, NY 10013']},
#    'phone': '+16468580470',
#    'display_phone': '(646) 858-0470',
#    'distance': 1499.535533956955},
#   {'id': '3D6UAhoKnF3A03rX_v5ngA',
#    'alias': 'bacaro-new-york',
#    'name': 'Bacaro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Gz_dhityi18F1JL5xdtXLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bacaro-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 400,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71456, 'longitude': -73.99154},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '136 Division St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136 Division St', 'New York, NY 10002']},
#    'phone': '+12129415060',
#    'display_phone': '(212) 941-5060',
#    'distance': 1036.2033423676269},
#   {'id': '7_hGsGEkHrjgAiYVjrCFnw',
#    'alias': 'carbone-new-york',
#    'name': 'Carbone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IPaDl6bzctnQOM6__ibOzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carbone-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1250,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.728, 'longitude': -74.0001497},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '181 Thompson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['181 Thompson St', 'New York, NY 10012']},
#    'phone': '+12122543000',
#    'display_phone': '(212) 254-3000',
#    'distance': 2556.1213049291623},
#   {'id': '5Akss-swwfyoSVeIsDBbvw',
#    'alias': 'basta-pasta-new-york',
#    'name': 'Basta Pasta',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vTXQdjnTGKpRs3_gamdVIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/basta-pasta-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1467,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73881, 'longitude': -73.99407},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '37 W 17th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37 W 17th St', 'New York, NY 10011']},
#    'phone': '+12123660888',
#    'display_phone': '(212) 366-0888',
#    'distance': 3719.6205096179538},
#   {'id': '-hUvO0C0A-pGZdiSKvjoFw',
#    'alias': 'babbo-new-york',
#    'name': 'Babbo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iA3DzrvJKPR2fBLccp2-iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/babbo-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2439,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.732283, 'longitude': -73.999284},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '110 Waverly Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['110 Waverly Pl', 'New York, NY 10011']},
#    'phone': '+12127770303',
#    'display_phone': '(212) 777-0303',
#    'distance': 3013.756015058358},
#   {'id': '78TCGIG1eHMYdyvMpFdDbQ',
#    'alias': 'follia-nyc-new-york',
#    'name': 'Follia NYC',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wpf_6eIsOO219K91kn4LhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/follia-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 216,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7349243164062,
#     'longitude': -73.9855880737305},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '179 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['179 3rd Ave', 'New York, NY 10003']},
#    'phone': '+12124774100',
#    'display_phone': '(212) 477-4100',
#    'distance': 3359.1268163984287},
#   {'id': 'OAqsZMbjv66nOMqlimnYuQ',
#    'alias': 'uva-new-york',
#    'name': 'Uva',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Dv_IaSo7QTUrRRtclijk2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uva-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2482,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7722, 'longitude': -73.95566},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1486 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1486 2nd Ave', 'New York, NY 10075']},
#    'phone': '+12124724552',
#    'display_phone': '(212) 472-4552',
#    'distance': 8104.693377840111},
#   {'id': 'rJfGgBleDYCVq2rkBr_w-Q',
#    'alias': 'barano-brooklyn',
#    'name': 'Barano',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zp2q4o3QGrUsLtnQIwplrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barano-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 283,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.710372, 'longitude': -73.96794},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '26 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 Broadway', 'Brooklyn, NY 11249']},
#    'phone': '+13479874500',
#    'display_phone': '(347) 987-4500',
#    'distance': 2294.1417665733024}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#    Restaurant     Type Price Rating          Address        Lat        Lng  \
# 0    Rubirosa  Italian    $$    4.5  235 Mulberry St  40.722766 -73.996233
# 1  Olio e Piú    Pizza    $$    4.5  3 Greenwich Ave  40.733798 -73.999774
# 2      Supper  Italian    $$      4     156 E 2nd St  40.722900 -73.985270
# 3    L'Artusi  Italian   $$$    4.5    228 W 10th St  40.733720 -74.005130
# 4   Da Andrea   Tuscan    $$      4     35 W 13th St  40.736218 -73.995970
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/rubirosa-new-york-2?a...  WG639VkTjmK5dzydd1BBJA
# 1  https://www.yelp.com/biz/olio-e-pi%C3%BA-new-y...  16ZnHpuaaBt92XWeJHCC5A
# 2  https://www.yelp.com/biz/supper-new-york?adjus...  Vs8kQ4R381y27AH018gLpg
# 3  https://www.yelp.com/biz/l-artusi-new-york?adj...  rp8S7scxOkVVeG7dNneMGQ
# 4  https://www.yelp.com/biz/da-andrea-new-york?ad...  hdiuRS9sVZSMReZm4oV5SA

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"italian","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': 'eMSTTuOUlKEnSOr8lPp3Xg',
#    'alias': 'ammazzacaffè-brooklyn',
#    'name': 'Ammazzacaffè',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oKxqtVdEn_VP9bnEK6uYRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ammazzacaff%C3%A8-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 219,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7113172, 'longitude': -73.9446243},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '702 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['702 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+19292502875',
#    'display_phone': '(929) 250-2875',
#    'distance': 4237.207558829539},
#   {'id': 'ry0nAQiUn8bpNAruY_5wfw',
#    'alias': 'scalino-brooklyn-2',
#    'name': 'Scalino',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gmFEW9fmTZaea1CMg2Fl6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scalino-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 268,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7244699, 'longitude': -73.95151},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '659 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['659 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183898600',
#    'display_phone': '(718) 389-8600',
#    'distance': 4180.593504669945},
#   {'id': 'r2nIYBSyXny1-7XvsL2PVg',
#    'alias': 'lenas-italian-kitchen-new-york',
#    'name': "Lena's Italian Kitchen",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hyeBNxepNriR3FbYi1fgvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lenas-italian-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 244,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.742664, 'longitude': -73.977783},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '551 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['551 2nd Ave', 'New York, NY 10016']},
#    'phone': '+16468465362',
#    'display_phone': '(646) 846-5362',
#    'distance': 4364.881454886058},
#   {'id': '9K0run3oObR0YT4jaOEvWg',
#    'alias': 'l-angeletto-new-york',
#    'name': "L'Angeletto",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RFgRpSwdOJjXY7wbv2LhOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-angeletto-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73541417, 'longitude': -73.982956},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'location': {'address1': '327 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['327 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12122539600',
#    'display_phone': '(212) 253-9600',
#    'distance': 3467.2849491910156},
#   {'id': 'f8ipr8Wdy1_wHhw7JgNqPQ',
#    'alias': 'da-claudio-new-york',
#    'name': 'Da Claudio',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XLxqA77QYDZwKS_h6tGdWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-claudio-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 525,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71087, 'longitude': -74.00753},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '21 Ann St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21 Ann St', 'New York, NY 10038']},
#    'phone': '+12122852668',
#    'display_phone': '(212) 285-2668',
#    'distance': 1268.4294254501694},
#   {'id': 'LfRiA6RORToZUSJUHkZBVA',
#    'alias': 'frankies-457-spuntino-brooklyn-3',
#    'name': 'Frankies 457 Spuntino',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/btKAwreoI9Yr6-R4JqgsdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frankies-457-spuntino-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 841,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.677328, 'longitude': -73.997972},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '457 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['457 Court St', 'Brooklyn, NY 11231']},
#    'phone': '+17184030033',
#    'display_phone': '(718) 403-0033',
#    'distance': 3141.796684827657},
#   {'id': 'Sp-vnk-waTvKblG_88M4TA',
#    'alias': 'trapizzino-new-york',
#    'name': 'Trapizzino',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tueJs5B-V_ccXA1Hst4ToQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trapizzino-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 233,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72043, 'longitude': -73.98894},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '144 Orchard St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['144 Orchard St', 'New York, NY 10002']},
#    'phone': '+12124752555',
#    'display_phone': '(212) 475-2555',
#    'distance': 1719.2709455356865},
#   {'id': '22nKUyCIbpnzR6R3_g1ptQ',
#    'alias': 'carmines-italian-restaurant-times-square-new-york-5',
#    'name': "Carmine's Italian Restaurant - Times Square",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ABC0jQ9tmZ58dDgztabrVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carmines-italian-restaurant-times-square-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3779,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'catering', 'title': 'Caterers'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75749, 'longitude': -73.98662},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '200 W 44th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 W 44th St', 'New York, NY 10036']},
#    'phone': '+12122213800',
#    'display_phone': '(212) 221-3800',
#    'distance': 5821.554586323717},
#   {'id': 'mPHPVJ2-8mOR-lFHafrc6w',
#    'alias': 'evelina-brooklyn-2',
#    'name': 'Evelina',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hG3aShzVvdnbAFm02sQgZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/evelina-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 234,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.689722, 'longitude': -73.971003},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '211 Dekalb Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['211 Dekalb Ave', 'Brooklyn, NY 11205']},
#    'phone': '+19292980209',
#    'display_phone': '(929) 298-0209',
#    'distance': 2628.710848301728},
#   {'id': 'H_KyiRhwho8rdlw_R93_0Q',
#    'alias': 'marea-new-york',
#    'name': 'Marea',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-7_hUV0_zqVzsbqNOJ_iMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marea-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2157,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7674213694566,
#     'longitude': -73.9810554368179},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '240 Central Park S',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['240 Central Park S', 'New York, NY 10019']},
#    'phone': '+12125825100',
#    'display_phone': '(212) 582-5100',
#    'distance': 6981.13750343581},
#   {'id': '6Z5OWpaeGGazJHR4LfThsw',
#    'alias': 'palma-new-york',
#    'name': 'Palma',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KRhsHF7JmChZ5xrW5owiKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/palma-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 760,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73115, 'longitude': -74.00233},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '28 Cornelia St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 Cornelia St', 'New York, NY 10014']},
#    'phone': '+12126912223',
#    'display_phone': '(212) 691-2223',
#    'distance': 2941.9863317681697},
#   {'id': 'KCBfW6sWl9Gx-LvMff08jg',
#    'alias': 'osteria-morini-new-york-3',
#    'name': 'Osteria Morini',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4VU9R-TAo0Yga-Ih3H4W6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osteria-morini-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1200,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7219179851303,
#     'longitude': -73.9976472073402},
#    'transactions': ['pickup'],
#    'price': '$$$',
#    'location': {'address1': '218 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['218 Lafayette St', 'New York, NY 10012']},
#    'phone': '+12129658777',
#    'display_phone': '(212) 965-8777',
#    'distance': 1853.4101472927232},
#   {'id': 'clOFor0bFSjse7EUfdRacg',
#    'alias': 'faro-brooklyn',
#    'name': 'Faro',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uE_e7ROScbFLYLN2TVVViQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/faro-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 290,
#    'categories': [{'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.707407, 'longitude': -73.922839},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '436 Jefferson St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['436 Jefferson St', 'Brooklyn, NY 11237']},
#    'phone': '+17183818201',
#    'display_phone': '(718) 381-8201',
#    'distance': 6028.260197370216},
#   {'id': 'vVVmHacu2YAxKfpIjhfd1g',
#    'alias': 'norma-new-york-5',
#    'name': 'Norma',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qJKt5l2xSBUKOFRA6UOqVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/norma-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 477,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.743553, 'longitude': -73.980026},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '438 3rd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['438 3rd Ave', 'New York, NY 10016']},
#    'phone': '+12128890600',
#    'display_phone': '(212) 889-0600',
#    'distance': 4409.483534452521},
#   {'id': 'b42PcC1nCP602fiXF0a9Xg',
#    'alias': 'barbalu-restaurant-new-york',
#    'name': 'Barbalu Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-i2phwCUNAqTKm5WGuGzHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barbalu-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 315,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7074747, 'longitude': -74.0020404},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '225-227 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['225-227 Front St', 'New York, NY 10038']},
#    'phone': '+16469186565',
#    'display_phone': '(646) 918-6565',
#    'distance': 690.9347453308609},
#   {'id': 'ysqgdbSrezXgVwER2kQWKA',
#    'alias': 'julianas-brooklyn-3',
#    'name': "Juliana's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/clscwgOF9_Ecq-Rwsq7jyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/julianas-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2354,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70274718768062,
#     'longitude': -73.99343490196397},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '19 Old Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#    'phone': '+17185966700',
#    'display_phone': '(718) 596-6700',
#    'distance': 308.56984360837544},
#   {'id': 'wCj2FSi9o6iosMIMNIIZsA',
#    'alias': 'loreto-italian-kitchen-and-bar-brooklyn',
#    'name': 'Loreto Italian Kitchen & Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pi8p1uSbM68o5lE5U13htw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/loreto-italian-kitchen-and-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.687037, 'longitude': -73.978577},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '280 Ashland Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['280 Ashland Pl', 'Brooklyn, NY 11217']},
#    'phone': '+17185541121',
#    'display_phone': '(718) 554-1121',
#    'distance': 2441.300877961441},
#   {'id': 'VmdyRRMtUXOWV7F7w0ImwQ',
#    'alias': 'piccola-cucina-uptown-new-york',
#    'name': 'Piccola Cucina Uptown',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KCehyhsH9n169ZDLXH8Yvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piccola-cucina-uptown-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 119,
#    'categories': [{'alias': 'sicilian', 'title': 'Sicilian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.763174, 'longitude': -73.969046},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '106 E 60th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['106 E 60th St', 'New York, NY 10022']},
#    'phone': '+16467073997',
#    'display_phone': '(646) 707-3997',
#    'distance': 6762.477200754241},
#   {'id': 'LRgB2kEKtBxqIxNksTO_PQ',
#    'alias': 'patrizias-williamsburg-brooklyn',
#    'name': "Patrizia's - Williamsburg",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OsItAhnu1KLVGxPfVAqFkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patrizias-williamsburg-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 702,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7109154314181,
#     'longitude': -73.9673637711639},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '35 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35 Broadway', 'Brooklyn, NY 11249']},
#    'phone': '+17182189272',
#    'display_phone': '(718) 218-9272',
#    'distance': 2349.983905012418},
#   {'id': 'rZ9OFoSqy8u4WECfh--ylg',
#    'alias': 'marta-new-york-7',
#    'name': 'Marta',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wVdnsTQRlks4TUXt0QQiFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marta-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 908,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7445882, 'longitude': -73.9847936},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '29 E 29th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['29 E 29th St', 'New York, NY 10016']},
#    'phone': '+12126513800',
#    'display_phone': '(212) 651-3800',
#    'distance': 4444.4428187583135},
#   {'id': 'kr5fRwdHtVwPPwSJxm9Fkg',
#    'alias': 'il-posto-accanto-new-york',
#    'name': 'Il Posto Accanto',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/l57H-S0EhaQEKGuseqeOaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-posto-accanto-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 258,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72238, 'longitude': -73.98403},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '190 E 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['190 E 2nd St', 'New York, NY 10009']},
#    'phone': '+12122283562',
#    'display_phone': '(212) 228-3562',
#    'distance': 2075.0122344745505},
#   {'id': 'uPWyvfh5qSrVbujhjsDiiw',
#    'alias': 'oregano-brooklyn',
#    'name': 'Oregano',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UfCQWozhn4MTnupaktM9vQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oregano-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 438,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7190165, 'longitude': -73.9586248},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '102 Berry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 Berry St', 'Brooklyn, NY 11249']},
#    'phone': '+17185995988',
#    'display_phone': '(718) 599-5988',
#    'distance': 3363.8232350677754},
#   {'id': 'JyXn_GCGM2DsNYIzgzQrDw',
#    'alias': 'da-gennaro-new-york',
#    'name': 'Da Gennaro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RkC0BOn79I16tRHBt9hgbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-gennaro-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1096,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71832, 'longitude': -73.99794},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '129 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['129 Mulberry St', 'New York, NY 10013']},
#    'phone': '+12124313934',
#    'display_phone': '(212) 431-3934',
#    'distance': 1468.7793653309982},
#   {'id': 'ZTsN8TdMXl8SW_AKd_ablw',
#    'alias': 'forno-rosso-brooklyn',
#    'name': 'Forno Rosso',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9aKNymymd9out1HSpkLuiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/forno-rosso-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 727,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.694467, 'longitude': -73.98293},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '327 Gold St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['327 Gold St', 'Brooklyn, NY 11201']},
#    'phone': '+17184513800',
#    'display_phone': '(718) 451-3800',
#    'distance': 1546.804489135146},
#   {'id': '5TX0X8w5ssIACU_pnBEq6g',
#    'alias': 'tonys-di-napoli-new-york-4',
#    'name': "Tony's Di Napoli",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QtT59Kv6ZpXIzQV1r_uImQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tonys-di-napoli-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2169,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75641, 'longitude': -73.98547},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '147 W 43rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['147 W 43rd St', 'New York, NY 10036']},
#    'phone': '+12122210100',
#    'display_phone': '(212) 221-0100',
#    'distance': 5724.255233853066},
#   {'id': 'jj_SCEzBi_CdZWMTjTwf_Q',
#    'alias': 'montes-brooklyn-26',
#    'name': "Monte's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LzwSVOSd-iqeGSiHQmSf1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/montes-brooklyn-26?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 158,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6775499, 'longitude': -73.98724},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '451 Carroll St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['451 Carroll St', 'Brooklyn, NY 11215']},
#    'phone': '+17188527800',
#    'display_phone': '(718) 852-7800',
#    'distance': 3155.0348683726984},
#   {'id': '1mp7uP6Kz_Zz4UClVfnjFQ',
#    'alias': 'testo-brooklyn',
#    'name': 'Testo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jV-UTCDi_-I-RrJ-vRqk8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/testo-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 213,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.708337, 'longitude': -73.946965},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '141 Leonard St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['141 Leonard St', 'Brooklyn, NY 11206']},
#    'phone': '+17183884810',
#    'display_phone': '(718) 388-4810',
#    'distance': 4005.7426041092267},
#   {'id': 'mTWlEiCUEBlxBAkIikkB1A',
#    'alias': 'carmines-italian-restaurant-upper-west-side-new-york',
#    'name': "Carmine's Italian Restaurant - Upper West Side",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_lTCIijz3zVH13nUugBwhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carmines-italian-restaurant-upper-west-side-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1477,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.791077, 'longitude': -73.973763},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '2450 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2450 Broadway', 'New York, NY 10024']},
#    'phone': '+12123622200',
#    'display_phone': '(212) 362-2200',
#    'distance': 9677.634530042784},
#   {'id': 'zo4JHfD2nWPUiqgsgDOaHQ',
#    'alias': 'raos-new-york',
#    'name': "Rao's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/B7RWu3d1c8KM9SF1OoCnZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raos-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 186,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.79392, 'longitude': -73.93427},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '455 E 114th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['455 E 114th St', 'New York, NY 10029']},
#    'phone': '+12127226709',
#    'display_phone': '(212) 722-6709',
#    'distance': 11067.267086274775},
#   {'id': 'a0IET3_yCFcO36OqGSsisg',
#    'alias': 'eataly-flatiron-new-york',
#    'name': 'Eataly Flatiron',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/n9MMv47vKQiiUyeRSJkTDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eataly-flatiron-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5710,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74195877796, 'longitude': -73.989716662832},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '200 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 5th Ave', 'New York, NY 10010']},
#    'phone': '+12122292560',
#    'display_phone': '(212) 229-2560',
#    'distance': 4078.4333537925154},
#   {'id': 'GjEE8vvjqb7eeHA3BGNxAw',
#    'alias': 'barolo-east-new-york',
#    'name': 'Barolo East',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/msKukDHgkfhgy-hsuKrA7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barolo-east-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 185,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75481, 'longitude': -73.97059},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'location': {'address1': '214 E 49th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['214 E 49th St', 'New York, NY 10017']},
#    'phone': '+12127545710',
#    'display_phone': '(212) 754-5710',
#    'distance': 5833.791567148375},
#   {'id': 'twHJyFgUSd7wzioKQjE7Jw',
#    'alias': 'galli-new-york-5',
#    'name': 'Galli',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NriJMGzJm4mZn-Pj2oRm3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/galli-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 974,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72161, 'longitude': -74.00127},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '45 Mercer St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 Mercer St', 'New York, NY 10013']},
#    'phone': '+12129669288',
#    'display_phone': '(212) 966-9288',
#    'distance': 1898.5732904580973},
#   {'id': 'xKIv_b2L2pUHmsoJ-xOepg',
#    'alias': 'gran-morsi-new-york',
#    'name': 'Gran Morsi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SoYx13srHD1UYNShb_OiHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gran-morsi-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 401,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7142052394856,
#     'longitude': -74.0077535494539},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '22 Warren St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 Warren St', 'New York, NY 10007']},
#    'phone': '+12125772725',
#    'display_phone': '(212) 577-2725',
#    'distance': 1495.3540489764287},
#   {'id': 'q3_FgDWWuXcVGiNuo_OPBQ',
#    'alias': 'fiaschetteria-pistoia-new-york',
#    'name': 'Fiaschetteria Pistoia',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-jMY96QXuagJ3ReZGoX1Cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fiaschetteria-pistoia-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 194,
#    'categories': [{'alias': 'tuscan', 'title': 'Tuscan'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72666, 'longitude': -73.9773},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '647 E 11th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['647 E 11th St', 'New York, NY 10009']},
#    'phone': '+12127773355',
#    'display_phone': '(212) 777-3355',
#    'distance': 2762.8361693570178},
#   {'id': 'fU22eRTnKLT2C-OFJ6eUGQ',
#    'alias': 'saraghina-brooklyn',
#    'name': 'Saraghina',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eRPby_hSC_z4Zv9b_GTqkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saraghina-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 908,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6837407, 'longitude': -73.9353473},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '350 Lewis Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['350 Lewis Ave', 'Brooklyn, NY 11233']},
#    'phone': '+17185740010',
#    'display_phone': '(718) 574-0010',
#    'distance': 5524.596550882466},
#   {'id': 'Z67mgMkN3RfdPEX5mXsyYA',
#    'alias': 'piacere-new-york',
#    'name': 'Piacere',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nP5_rJ7tlw_ZamiMN1zxOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piacere-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 677,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7196979, 'longitude': -73.9951175},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '351 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['351 Broome St', 'New York, NY 10013']},
#    'phone': '+12122194080',
#    'display_phone': '(212) 219-4080',
#    'distance': 1586.3855179286054},
#   {'id': 'XHhRAKq6DArQXYhkgvwaow',
#    'alias': 'spaghetti-incident-new-york-2',
#    'name': 'Spaghetti Incident',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/p5gt4VvPJnobk0HpF53Ong/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spaghetti-incident-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 613,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7223153441439,
#     'longitude': -73.9899454318763},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '231 Eldridge St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 Eldridge St', 'New York, NY 10002']},
#    'phone': '+16468961446',
#    'display_phone': '(646) 896-1446',
#    'distance': 1911.3655890506484},
#   {'id': '15d_Y6TVOQFD2KRVkxuAjw',
#    'alias': 'baci-and-abbracci-brooklyn',
#    'name': 'Baci & Abbracci',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sKM13yG4MDhsmhQOoBNOtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baci-and-abbracci-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 325,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7139015197754, 'longitude': -73.96044921875},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '204 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['204 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17185996599',
#    'display_phone': '(718) 599-6599',
#    'distance': 3005.4887951912056},
#   {'id': 'OwDRIugcA4LkUuTRqpJsog',
#    'alias': 'naked-dog-brooklyn-2',
#    'name': 'Naked Dog',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1sC00X-YIu2oxVKk2oFIfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/naked-dog-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 246,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7312720665479,
#     'longitude': -73.9593493647979},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '47 Java St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 Java St', 'Brooklyn, NY 11222']},
#    'phone': '+19293378096',
#    'display_phone': '(929) 337-8096',
#    'distance': 4113.441999440594},
#   {'id': 'St8a2de1vfyCxwIySBUWbA',
#    'alias': 'graziellas-brooklyn-11',
#    'name': "Graziella's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GV0d871fK5Ys0lQRdaHBaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/graziellas-brooklyn-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 449,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6904563903809,
#     'longitude': -73.9696273803711},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '232 Vanderbilt Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['232 Vanderbilt Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17187895663',
#    'display_phone': '(718) 789-5663',
#    'distance': 2668.0909755132543},
#   {'id': 'ZVa3-O6LMxZXSpKG0J1h-w',
#    'alias': 'piccolo-angolo-restaurant-new-york',
#    'name': 'Piccolo Angolo Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/q536opZ7gIL0oLxztUd2Gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piccolo-angolo-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 562,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7378601855952,
#     'longitude': -74.0058052539825},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '621 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['621 Hudson St', 'New York, NY 10014']},
#    'phone': '+12122299177',
#    'display_phone': '(212) 229-9177',
#    'distance': 3732.6951094282817},
#   {'id': 'AAQDZdKhtcX7otmOfOF9nw',
#    'alias': 'ginos-restaurant-brooklyn-2',
#    'name': "Gino's Restaurant",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VoHtU2k9NVNjIyODQqCRzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginos-restaurant-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 705,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.63, 'longitude': -74.02274},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '7414 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7414 5th Ave', 'Brooklyn, NY 11209']},
#    'phone': '+17187481698',
#    'display_phone': '(718) 748-1698',
#    'distance': 8727.715758977029},
#   {'id': 'JBthOvTegHbrLDiVaCAy5Q',
#    'alias': 'bigoi-venezia-new-york',
#    'name': 'Bigoi Venezia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sw2TeTUoHrJza8fJEl_JHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bigoi-venezia-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 280,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.770036, 'longitude': -73.9577755},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1415 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1415 2nd Ave', 'New York, NY 10021']},
#    'phone': '+19172620680',
#    'display_phone': '(917) 262-0680',
#    'distance': 7813.461518611187},
#   {'id': 'LTi4_wcCVmqQeJ_jgTEbOQ',
#    'alias': 'emporio-new-york',
#    'name': 'Emporio',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CbrzzbxrkoucdhNfahv_rQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/emporio-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 801,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722647, 'longitude': -73.995246},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '231 Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 Mott St', 'New York, NY 10012']},
#    'phone': '+12129661234',
#    'display_phone': '(212) 966-1234',
#    'distance': 1908.6732685916875},
#   {'id': 'Q1_UvNyONsaVS_VC1mD9Dw',
#    'alias': 'osteria-cotta-new-york',
#    'name': 'Osteria Cotta',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dyEq3RCwLaLbnPsisJJApQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osteria-cotta-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 946,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78554, 'longitude': -73.97263},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '513 Columbus Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['513 Columbus Ave', 'New York, NY 10024']},
#    'phone': '+12128738500',
#    'display_phone': '(212) 873-8500',
#    'distance': 9089.69680298336},
#   {'id': 'jnHbdsqlTKlPcmJ8BCP9-g',
#    'alias': 'via-carota-new-york',
#    'name': 'Via Carota',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QrjsvDq7vsuk4cxasnQqJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/via-carota-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 668,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.733148231901204,
#     'longitude': -74.00366777251583},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '51 Grove St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['51 Grove St', 'New York, NY 10014']},
#    'phone': '+12122551962',
#    'display_phone': '(212) 255-1962',
#    'distance': 3180.1699029556735},
#   {'id': 'lwfCl81r5a0mjxDNxNGC9w',
#    'alias': 'il-buco-alimentari-and-vineria-new-york-3',
#    'name': 'Il Buco Alimentari & Vineria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Stk9ssPZ24tVQRd-Bs7gsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-buco-alimentari-and-vineria-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 716,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72583, 'longitude': -73.99299},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '47 Bond St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 Bond St', 'New York, NY 10012']},
#    'phone': '+12125331932',
#    'display_phone': '(212) 533-1932',
#    'distance': 2262.8925146941324},
#   {'id': 'RfxOtJ4SQmEeVX_XjFLWUQ',
#    'alias': 'otis-brooklyn-2',
#    'name': 'Otis',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aViDtyaJ5YRmsqC4ot5L2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/otis-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 374,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.706011, 'longitude': -73.932598},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '18 Harrison Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18 Harrison Pl', 'Brooklyn, NY 11206']},
#    'phone': '+16468860601',
#    'display_phone': '(646) 886-0601',
#    'distance': 5200.877004016517},
#   {'id': 'vyoA8dxwScuMV_AsTcjQcg',
#    'alias': 'l-and-b-spumoni-gardens-brooklyn',
#    'name': 'L & B Spumoni Gardens',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BrTci9PjIwi7V1vkbgkdqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-and-b-spumoni-gardens-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4048,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.594715, 'longitude': -73.981316},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '2725 86th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11223',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2725 86th St', 'Brooklyn, NY 11223']},
#    'phone': '+17184491230',
#    'display_phone': '(718) 449-1230',
#    'distance': 12361.163422806636},
#   {'id': '5EQOEAkH2Qh3Rv1TcnE7yA',
#    'alias': 'fiaschetteria-pistoia-new-york-2',
#    'name': 'Fiaschetteria Pistoia',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3QYhjQ8_N6-W5i89tgFbag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fiaschetteria-pistoia-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 71,
#    'categories': [{'alias': 'tuscan', 'title': 'Tuscan'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73316, 'longitude': -74.00537},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '114 Christopher St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['114 Christopher St', 'New York, NY 10014']},
#    'phone': '+16466092911',
#    'display_phone': '(646) 609-2911',
#    'distance': 3220.0623227536303}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                Restaurant           Type Price Rating            Address  \
# 0            Ammazzacaffè  Cocktail Bars    $$    4.5       702 Grand St
# 1                 Scalino        Italian    $$    4.5  659 Manhattan Ave
# 2  Lena's Italian Kitchen        Italian    $$    4.5        551 2nd Ave
# 3             L'Angeletto        Italian                     327 2nd Ave
# 4              Da Claudio        Italian    $$    4.5          21 Ann St
#
#          Lat        Lng                                                url  \
# 0  40.711317 -73.944624  https://www.yelp.com/biz/ammazzacaff%C3%A8-bro...
# 1  40.724470 -73.951510  https://www.yelp.com/biz/scalino-brooklyn-2?ad...
# 2  40.742664 -73.977783  https://www.yelp.com/biz/lenas-italian-kitchen...
# 3  40.735414 -73.982956
# 4  40.710870 -74.007530  https://www.yelp.com/biz/da-claudio-new-york?a...
#
#                        ID
# 0  eMSTTuOUlKEnSOr8lPp3Xg
# 1  ry0nAQiUn8bpNAruY_5wfw
# 2  r2nIYBSyXny1-7XvsL2PVg
# 3
# 4  f8ipr8Wdy1_wHhw7JgNqPQ

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"italian","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': 'muX5xoh3aOleCrSja_T_FA',
#    'alias': 'il-tavolo-di-palmisano-hoboken-2',
#    'name': 'IL Tavolo di’ Palmisano',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZlZZBsrVoFIPR_OCLnQ5HQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-tavolo-di-palmisano-hoboken-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 130,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74571, 'longitude': -74.03346},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '700 Clinton St',
#     'address2': None,
#     'address3': None,
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['700 Clinton St', 'Hoboken, NJ 07030']},
#    'phone': '+12013455980',
#    'display_phone': '(201) 345-5980',
#    'distance': 5564.087208129049},
#   {'id': 'eTneVbjPKdo4gD9HfkDGdA',
#    'alias': 'santa-panza-brooklyn',
#    'name': 'Santa Panza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/i2mhjGgXUCS1YDWt2urv6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/santa-panza-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 183,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6947, 'longitude': -73.93068},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1079 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1079 Broadway', 'Brooklyn, NY 11221']},
#    'phone': '+13474139695',
#    'display_phone': '(347) 413-9695',
#    'distance': 5491.707809648726},
#   {'id': 'gqTikTCIS01E2m20PzHoDQ',
#    'alias': 'tarallucci-e-vino-east-village-new-york-5',
#    'name': 'Tarallucci e Vino - East Village',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hmM2uPtGntvag9ZBbQ6roQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tarallucci-e-vino-east-village-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 291,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72896, 'longitude': -73.98454},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '163 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['163 1st Ave', 'New York, NY 10003']},
#    'phone': '+12123881190',
#    'display_phone': '(212) 388-1190',
#    'distance': 2741.308776369351},
#   {'id': 'FhXjAc6nKLf414KxYujUHw',
#    'alias': 'robertas-brooklyn-2',
#    'name': "Roberta's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8fY9fA5TtCF0ebdTNph9mQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/robertas-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3005,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70493, 'longitude': -73.93399},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '261 Moore St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['261 Moore St', 'Brooklyn, NY 11206']},
#    'phone': '+17184171118',
#    'display_phone': '(718) 417-1118',
#    'distance': 5083.5233118395545},
#   {'id': 'VqnPcfqYltgxAkIuTaGkYg',
#    'alias': 'tre-new-york',
#    'name': 'Tre',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GTOSuF09iVS7qxDtjivAZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tre-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 489,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72184, 'longitude': -73.987714},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '173 Ludlow St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['173 Ludlow St', 'New York, NY 10002']},
#    'phone': '+12123533353',
#    'display_phone': '(212) 353-3353',
#    'distance': 1905.5223970639986},
#   {'id': 'hFmz7HH2og9hn7xNNv20yw',
#    'alias': 'il-porto-ristorante-brooklyn',
#    'name': 'Il Porto Ristorante',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ka4_bkUB_I5JAZyRjAnbLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-porto-ristorante-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 344,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6974427, 'longitude': -73.9675197},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '37 Washington Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37 Washington Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17186240954',
#    'display_phone': '(718) 624-0954',
#    'distance': 2433.138320005117},
#   {'id': 'hDj_0pbi4mFR5p1H1w6igw',
#    'alias': 'misirizzi-new-york',
#    'name': 'Misirizzi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/d7fxVg-QMUrP8vtRYXheug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/misirizzi-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 151,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7272, 'longitude': -73.99228},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '36 E 4th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['36 E 4th St', 'New York, NY 10003']},
#    'phone': '+12123750100',
#    'display_phone': '(212) 375-0100',
#    'distance': 2425.0943478607733},
#   {'id': 'V3USzFEGhuoXez4G2Rk11A',
#    'alias': 'tavola-new-york',
#    'name': 'Tavola',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HhhlKQchXV9dhvgGgNH1Bw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tavola-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1009,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.755403, 'longitude': -73.994516},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '488 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['488 9th Ave', 'New York, NY 10018']},
#    'phone': '+12122731181',
#    'display_phone': '(212) 273-1181',
#    'distance': 5555.116776273299},
#   {'id': 'fuS39acPaRi38DhSSwEI4Q',
#    'alias': 'felice-new-york-6',
#    'name': 'Felice',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RjmwyXZWgYk0IPqigCTjzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/felice-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 395,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tuscan', 'title': 'Tuscan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70789, 'longitude': -74.00712},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '15 Gold St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Gold St', 'New York, NY 10038']},
#    'phone': '+12127855950',
#    'display_phone': '(212) 785-5950',
#    'distance': 1115.3484069613505},
#   {'id': 'FRp1NwIyp6tkDU986cJkXQ',
#    'alias': 'piccola-cucina-estiatorio-new-york',
#    'name': 'Piccola Cucina Estiatorio',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3ToLESKv0zNdwXOIYfqqcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piccola-cucina-estiatorio-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 150,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7246, 'longitude': -74.0029799},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '75 Thompson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 Thompson St', 'New York, NY 10012']},
#    'phone': '+16467819183',
#    'display_phone': '(646) 781-9183',
#    'distance': 2254.742845482553},
#   {'id': 'Ve6GVzzJpR5QIIPdcn6ViQ',
#    'alias': 'mercato-new-york',
#    'name': 'Mercato',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KbeeUPTic0jw8C1o70_1Ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mercato-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 918,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75619, 'longitude': -73.9937},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '352 W 39th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['352 W 39th St', 'New York, NY 10018']},
#    'phone': '+12126432000',
#    'display_phone': '(212) 643-2000',
#    'distance': 5644.746419510025},
#   {'id': 'JLpEKUYAtzBRQwsUL3RPIA',
#    'alias': 'il-corso-new-york',
#    'name': 'Il Corso',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yuX3PJs2MhveFtIBnCe_kw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-corso-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 374,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.762441, 'longitude': -73.977206},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '54 W 55th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['54 W 55th St', 'New York, NY 10019']},
#    'phone': '+12129571500',
#    'display_phone': '(212) 957-1500',
#    'distance': 6498.919757653028},
#   {'id': '77llOAEwInvK-oC2AHZ4nQ',
#    'alias': 'coppolas-east-new-york-4',
#    'name': "Coppola's East",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/D4i8xMaGJKkm0TTIn0PiYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coppolas-east-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 363,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74165, 'longitude': -73.98154},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '378 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['378 3rd Ave', 'New York, NY 10016']},
#    'phone': '+12126790070',
#    'display_phone': '(212) 679-0070',
#    'distance': 4169.382898967834},
#   {'id': 'Be1Y-vAEMgo7lqL5alXgDA',
#    'alias': 'taverna-di-bacco-new-york',
#    'name': 'Taverna Di Bacco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pEIG8wiigCMeWkXFyNvxig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taverna-di-bacco-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 297,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72191, 'longitude': -73.98768},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '175 Ludlow St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['175 Ludlow St', 'New York, NY 10002']},
#    'phone': '+12124770077',
#    'display_phone': '(212) 477-0077',
#    'distance': 1915.0507089547862},
#   {'id': 'fFIQ8Rx4x1Z34kFJcmlVzQ',
#    'alias': 'cacio-e-pepe-new-york-4',
#    'name': 'Cacio E Pepe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MgdIWiazrhxE6CTp96NEew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cacio-e-pepe-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77095763153376,
#     'longitude': -73.95095177321691},
#    'transactions': [],
#    'location': {'address1': '1479 York Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1479 York Ave', 'New York, NY 10075']},
#    'phone': '+16466827676',
#    'display_phone': '(646) 682-7676',
#    'distance': 8148.670159640003},
#   {'id': 'h4VCnZ2aZ33mdenS_ZI7jQ',
#    'alias': 'mama-mia-44-sw-new-york-2',
#    'name': 'Mama Mia 44 SW',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Dpd1wHWGVawq9MTOvoBwbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mama-mia-44-sw-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 660,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.759761, 'longitude': -73.992065},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '621 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['621 9th Ave', 'New York, NY 10036']},
#    'phone': '+12123154582',
#    'display_phone': '(212) 315-4582',
#    'distance': 6040.223213303815},
#   {'id': 'Pu09oBx1ekEZiFt90PsSIw',
#    'alias': 'tableside-italian-cook-shoppe-new-york',
#    'name': 'Tableside Italian Cook Shoppe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qVAs4mY2sNJaICTC1zRfCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tableside-italian-cook-shoppe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 297,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7266287, 'longitude': -73.9863384},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '345 E 6th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['345 E 6th St', 'New York, NY 10003']},
#    'phone': '+16468526498',
#    'display_phone': '(646) 852-6498',
#    'distance': 2450.614719593678},
#   {'id': '_N92SH1Zi-Hbxn_bNHFz0Q',
#    'alias': 'noodle-pudding-brooklyn',
#    'name': 'Noodle Pudding',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/o5ygMLdH6f5XVONTb3msMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noodle-pudding-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 576,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69979, 'longitude': -73.99203},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '38 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38 Henry St', 'Brooklyn, NY 11201']},
#    'phone': '+17186253737',
#    'display_phone': '(718) 625-3737',
#    'distance': 655.5435192103048},
#   {'id': 'FNxOWxts63oDRKwy9Pbfzw',
#    'alias': 'tarallucci-e-vino-nomad-new-york',
#    'name': 'Tarallucci E Vino - Nomad',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SkYHqv-iNy6J4k2Neonm7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tarallucci-e-vino-nomad-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 180,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7436553, 'longitude': -73.9852171},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '44 E 28th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['44 E 28th St', 'New York, NY 10016']},
#    'phone': '+12127791100',
#    'display_phone': '(212) 779-1100',
#    'distance': 4296.15943884492},
#   {'id': '4RhrQpbhjDmOyXT3qz7v2g',
#    'alias': 'osteria-carlina-new-york',
#    'name': 'Osteria Carlina',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tMNGd64NHhdmfHOkaV7XTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osteria-carlina-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.731409, 'longitude': -74.006984},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '455 Hudson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['455 Hudson St', 'New York, NY 10014']},
#    'phone': '+16465595137',
#    'display_phone': '(646) 559-5137',
#    'distance': 3078.951161648123},
#   {'id': 'H_TGP2AgX3IUmzq8Aml79Q',
#    'alias': 'l-angolo-tribeca-new-york',
#    'name': "L' Angolo Tribeca",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DMQ5h6yLE7M8XBgf-0h7lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-angolo-tribeca-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 163,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71734, 'longitude': -74.01044},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '190-A Duane St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['190-A Duane St', 'New York, NY 10013']},
#    'phone': '+12126253333',
#    'display_phone': '(212) 625-3333',
#    'distance': 1903.091157450161},
#   {'id': 'kIm0oeOaVfC9-2flLPVklA',
#    'alias': 'patrizias-pizza-and-pasta-new-york',
#    'name': "Patrizia's Pizza and Pasta",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HG4eRBBgLSG0RrzLZv1mLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patrizias-pizza-and-pasta-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 665,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7398415, 'longitude': -73.9792862},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '462-466 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['462-466 2nd Ave', 'New York, NY 10016']},
#    'phone': '+12125979999',
#    'display_phone': '(212) 597-9999',
#    'distance': 4040.895814674829},
#   {'id': 'TO9IICJjvcg1QhLVnap9fA',
#    'alias': 'centanni-brooklyn',
#    'name': "Cent'Anni",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5ndXtFM2rPaC94TZzzBi9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/centanni-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 465,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6730907423467,
#     'longitude': -73.9573492245369},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '742 Franklin Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['742 Franklin Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17189425201',
#    'display_phone': '(718) 942-5201',
#    'distance': 4758.719705437703},
#   {'id': 'ktMtLr8mp4K7IGxUgCTs6Q',
#    'alias': 'bocca-di-bacco-new-york-12',
#    'name': 'Bocca di Bacco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hzdxczL3I_ap9NW5I36kYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bocca-di-bacco-new-york-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.76021745303923,
#     'longitude': -73.99156281784906},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '635 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['635 9th Ave', 'New York, NY 10036']},
#    'phone': '+12122622525',
#    'display_phone': '(212) 262-2525',
#    'distance': 6094.770830009599},
#   {'id': 'TcSy5I5xHKDK0Uf5_cLOew',
#    'alias': 'cotto-new-york',
#    'name': 'Cotto',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8Wci6JoDRLFA9zduu8a4ug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cotto-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74442, 'longitude': -73.99266},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '112 W 25th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['112 W 25th St', 'New York, NY 10001']},
#    'phone': '+16469071200',
#    'display_phone': '(646) 907-1200',
#    'distance': 4324.842116479579},
#   {'id': 'vhqFa_0SG9M7Ra1OTmfB9A',
#    'alias': 'larina-pastificio-and-vino-brooklyn',
#    'name': 'LaRina Pastificio & Vino',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Pd-lNq2oV9FP5OrtYmvSYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/larina-pastificio-and-vino-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 171,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6933631896973,
#     'longitude': -73.9704132080078},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '387 Myrtle Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['387 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17188520001',
#    'display_phone': '(718) 852-0001',
#    'distance': 2424.07370875462},
#   {'id': 'T-RXDLq_VEv7s1_SooYIYQ',
#    'alias': 'osteria-57-new-york',
#    'name': 'Osteria 57',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KD1qrK51WILJwl4mwp6g1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osteria-57-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 207,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73467, 'longitude': -73.99786},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '57 W 10th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['57 W 10th St', 'New York, NY 10011']},
#    'phone': '+12127770057',
#    'display_phone': '(212) 777-0057',
#    'distance': 3264.8135124375995},
#   {'id': 'MOwB9YYd-Ko6nVgSB-ltQw',
#    'alias': 'briciola-new-york',
#    'name': 'Briciola',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eO9jNBCXTg5yxxnbpLrkeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/briciola-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 867,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7637997047278,
#     'longitude': -73.9880919456482},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '370 W 51st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['370 W 51st St', 'New York, NY 10019']},
#    'phone': '+16466785763',
#    'display_phone': '(646) 678-5763',
#    'distance': 6509.757763438482},
#   {'id': 'WIhm0W9197f_rRtDziq5qQ',
#    'alias': 'lombardis-pizza-new-york-4',
#    'name': "Lombardi's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UZ6V_hobp1KpYDPOHNoCKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6193,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7215934960083,
#     'longitude': -73.9955956044561},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '32 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 Spring St', 'New York, NY 10012']},
#    'phone': '+12129417994',
#    'display_phone': '(212) 941-7994',
#    'distance': 1798.9959778083735},
#   {'id': '7cjT33LfYSk7vrRdEaSr4w',
#    'alias': 'angeletto-restaurant-new-york',
#    'name': 'Angeletto Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6uaxZoW81RMhxJ1-8XBHOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/angeletto-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 247,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.753188, 'longitude': -73.969365},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '890 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['890 2nd Ave', 'New York, NY 10017']},
#    'phone': '+12122351227',
#    'display_phone': '(212) 235-1227',
#    'distance': 5709.246502195981},
#   {'id': 'z7H9ApIGopnDnQaglnPTzg',
#    'alias': 'allora-ristorante-new-york-2',
#    'name': 'Allora Ristorante',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PFMCcufxzzNRQ6JOVX5jFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/allora-ristorante-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 629,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75433, 'longitude': -73.97277},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '145 E 47th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['145 E 47th St', 'New York, NY 10017']},
#    'phone': '+12127549800',
#    'display_phone': '(212) 754-9800',
#    'distance': 5742.77805353143},
#   {'id': 'qoBcWhGwlcUsKIQ2nB22vA',
#    'alias': 'lombardos-of-bay-ridge-brooklyn-2',
#    'name': "Lombardo's of Bay Ridge",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dApR-oBFGa2kQIpmEeasfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lombardos-of-bay-ridge-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 154,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.634741, 'longitude': -74.0284259},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '279 71st St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['279 71st St', 'Brooklyn, NY 11209']},
#    'phone': '+17182387100',
#    'display_phone': '(718) 238-7100',
#    'distance': 8367.095256061873},
#   {'id': 'eWMuXtaBzf0H5u0Vf_zpjw',
#    'alias': 'ciccio-new-york-11',
#    'name': 'Ciccio',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OZ5Cj_D0fAzbSW3qPXbTCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ciccio-new-york-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 290,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7263263267119,
#     'longitude': -74.0034471165676},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '190 6th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['190 6th Ave', 'New York, NY 10013']},
#    'phone': '+16464769498',
#    'display_phone': '(646) 476-9498',
#    'distance': 2446.726741699908},
#   {'id': 'FelC65I3j7s7mM2rnePN3Q',
#    'alias': 'savelli-new-york',
#    'name': 'Savelli',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/s6qW1W14qJZy3rSUUa0wNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/savelli-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.685074, 'longitude': -73.991272},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '195 Smith St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['195 Smith St', 'New York, NY 11201']},
#    'phone': '+13478897617',
#    'display_phone': '(347) 889-7617',
#    'distance': 2276.226882362459},
#   {'id': '0Tvwk0hvgaY0QVIsZGTZKQ',
#    'alias': 'antica-ristorante-new-york',
#    'name': 'Antica Ristorante',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IsT5GUqh2qOm66RLlDjudA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/antica-ristorante-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 503,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7039355145338,
#     'longitude': -74.0121731758117},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '8 Stone St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8 Stone St', 'New York, NY 10004']},
#    'phone': '+12124803880',
#    'display_phone': '(212) 480-3880',
#    'distance': 1516.5010643209548},
#   {'id': 'idxD3X7WfLFPZMoFnCRIQQ',
#    'alias': 'il-cantinori-new-york',
#    'name': 'Il Cantinori',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-LKNk4aQn4Vp83T9z1GU_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-cantinori-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 256,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7322779619352,
#     'longitude': -73.9929321762328},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '32 E 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 E 10th St', 'New York, NY 10003']},
#    'phone': '+12126736044',
#    'display_phone': '(212) 673-6044',
#    'distance': 2985.9049858041385},
#   {'id': 'gAMETn5mltwjn2QLt6bWjw',
#    'alias': 'isabella-new-york-2',
#    'name': 'Isabella',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/za4M7QEntLzamwmrroyffw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/isabella-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.726966, 'longitude': -73.984334},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '110 St Marks Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['110 St Marks Pl', 'New York, NY 10009']},
#    'phone': '+16466783206',
#    'display_phone': '(646) 678-3206',
#    'distance': 2529.063356525261},
#   {'id': 'aSprnLY-6GkMk1cuv0TMeA',
#    'alias': 'al-di-la-trattoria-brooklyn',
#    'name': 'Al Di La Trattoria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1II2utFYuMWjG8t6liHt0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/al-di-la-trattoria-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 905,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.675332643247, 'longitude': -73.981340475038},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '248 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['248 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187834565',
#    'display_phone': '(718) 783-4565',
#    'distance': 3521.9177536215343},
#   {'id': 'XvEz60Y0NbLxooK9AmRU8g',
#    'alias': 'piccoli-trattoria-brooklyn',
#    'name': 'Piccoli Trattoria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7FoKTPDjJjp0K02SgYZFrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piccoli-trattoria-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 507,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.66518, 'longitude': -73.9865},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '522 6th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['522 6th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187880066',
#    'display_phone': '(718) 788-0066',
#    'distance': 4521.799444124006},
#   {'id': 'jku9Fg8JsUbv_LQzg6PK4g',
#    'alias': 'lavagna-new-york',
#    'name': 'Lavagna',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HtbVRtgaxzrLfImGh85eHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lavagna-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 394,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72406, 'longitude': -73.98226},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '545 E 5th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['545 E 5th St', 'New York, NY 10009']},
#    'phone': '+12129791005',
#    'display_phone': '(212) 979-1005',
#    'distance': 2309.070502236486},
#   {'id': 'Z-QmxQZAJEy5GXqA82Bemw',
#    'alias': 'da-toscano-new-york',
#    'name': 'Da Toscano',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1M535X726GseP1uuxjBVUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-toscano-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.730508, 'longitude': -74.001238},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '24 Minetta Ln',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 Minetta Ln', 'New York, NY 10012']},
#    'phone': '+12126064054',
#    'display_phone': '(212) 606-4054',
#    'distance': 2866.8215964153596},
#   {'id': 'yi6jIxzHo-nbAOG4KWuqcw',
#    'alias': 'maialino-new-york',
#    'name': 'Maialino',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rPx9Q-3FDlY6ljUrpgIYkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maialino-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1382,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.738437, 'longitude': -73.985686},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '2 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2 Lexington Ave', 'New York, NY 10010']},
#    'phone': '+12127772410',
#    'display_phone': '(212) 777-2410',
#    'distance': 3739.575807220527},
#   {'id': 'bdKc4CSJPv-XLgxVwrtPrg',
#    'alias': 'forlinis-restaurant-new-york',
#    'name': "Forlini's Restaurant",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EeLoB-xwkNi-5xBfFdE7dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/forlinis-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 475,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71695, 'longitude': -73.99957},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '93 Baxter St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['93 Baxter St', 'New York, NY 10013']},
#    'phone': '+12123496779',
#    'display_phone': '(212) 349-6779',
#    'distance': 1345.7828431706812},
#   {'id': 'QQpQujXQGbZBK6BeAokzDA',
#    'alias': 'pomp-and-circumstance-dining-williamsburg',
#    'name': 'Pomp & Circumstance Dining',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/J8ppNLf0cuYb55mK9HpJ5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pomp-and-circumstance-dining-williamsburg?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 92,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.714166, 'longitude': -73.949612},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '577 Lorimer St',
#     'address2': '',
#     'address3': None,
#     'city': 'Williamsburg',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['577 Lorimer St', 'Williamsburg, NY 11211']},
#    'phone': '+17183874861',
#    'display_phone': '(718) 387-4861',
#    'distance': 3889.525543827368},
#   {'id': '4zw8vEJNc4mcHh2ARzj2gw',
#    'alias': 'osteria-brooklyn-brooklyn',
#    'name': 'Osteria Brooklyn',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_PwFHgwgFPtbjC2aQarxrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osteria-brooklyn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.693154, 'longitude': -73.967177},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '458 Myrtle Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['458 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+16467509156',
#    'display_phone': '(646) 750-9156',
#    'distance': 2663.32927828955},
#   {'id': '32VbG_XgkZIuye0PV-BxaA',
#    'alias': 'zero-otto-nove-new-york-3',
#    'name': 'Zero Otto Nove',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/B1rfkFnHFfmbci_miI1slw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zero-otto-nove-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 483,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7407551035259,
#     'longitude': -73.9914887388588},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '15 W 21st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 W 21st St', 'New York, NY 10010']},
#    'phone': '+12122420899',
#    'display_phone': '(212) 242-0899',
#    'distance': 3933.421573673737},
#   {'id': 'X9f5HH4x3Mi7lo4ph9efvQ',
#    'alias': 'terre-brooklyn',
#    'name': 'Terre',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8OZY_VRODKnhQ8Y5R169Lw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/terre-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 107,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.671949831792,
#     'longitude': -73.9837719490146},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '341 5th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['341 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187882285',
#    'display_phone': '(718) 788-2285',
#    'distance': 3828.661448606197},
#   {'id': 'dc3hkLkAqCSxDWQzrx-g9A',
#    'alias': 'quality-italian-new-york',
#    'name': 'Quality Italian',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7JK95Qmi9lKwvI7ags6fVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/quality-italian-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1140,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7644044527436,
#     'longitude': -73.9767805051616},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '57 W 57th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['57 W 57th St', 'New York, NY 10019']},
#    'phone': '+12123901111',
#    'display_phone': '(212) 390-1111',
#    'distance': 6720.000208872442},
#   {'id': 'V1kPnrBjxs17oTBExksIqw',
#    'alias': 'sestina-new-york',
#    'name': 'SESTINA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GAQDPG-CTBJEjQXWrXAmNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sestina-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 72,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.726191, 'longitude': -73.989755},
#    'transactions': ['delivery'],
#    'location': {'address1': '67 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['67 2nd Ave', 'New York, NY 10003']},
#    'phone': '+16464904114',
#    'display_phone': '(646) 490-4114',
#    'distance': 2338.7400426553654},
#   {'id': 'l7OsDvMOO3ji3fg0nT0QzA',
#    'alias': 'tonys-di-napoli-new-york-7',
#    'name': "Tony's Di Napoli",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tigQFsaajPtCMTBZwFLX-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tonys-di-napoli-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 735,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76441, 'longitude': -73.96427},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1081 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1081 3rd Ave', 'New York, NY 10065']},
#    'phone': '+12128886333',
#    'display_phone': '(212) 888-6333',
#    'distance': 7027.0556373030495}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                          Restaurant     Type Price Rating         Address  \
# 0           IL Tavolo di’ Palmisano  Italian    $$    4.5  700 Clinton St
# 1                       Santa Panza     Bars    $$    4.5   1079 Broadway
# 2  Tarallucci e Vino - East Village     Bars    $$      4     163 1st Ave
# 3                         Roberta's    Pizza    $$      4    261 Moore St
# 4                               Tre  Italian    $$      4   173 Ludlow St
#
#         Lat        Lng                                                url  \
# 0  40.74571 -74.033460  https://www.yelp.com/biz/il-tavolo-di-palmisan...
# 1  40.69470 -73.930680  https://www.yelp.com/biz/santa-panza-brooklyn?...
# 2  40.72896 -73.984540  https://www.yelp.com/biz/tarallucci-e-vino-eas...
# 3  40.70493 -73.933990  https://www.yelp.com/biz/robertas-brooklyn-2?a...
# 4  40.72184 -73.987714  https://www.yelp.com/biz/tre-new-york?adjust_c...
#
#                        ID
# 0  muX5xoh3aOleCrSja_T_FA
# 1  eTneVbjPKdo4gD9HfkDGdA
# 2  gqTikTCIS01E2m20PzHoDQ
# 3  FhXjAc6nKLf414KxYujUHw
# 4  VqnPcfqYltgxAkIuTaGkYg

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"italian","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [{'id': 'JU5d81TYm7IJHWqOqJWMqw',
#    'alias': 'have-and-meyer-brooklyn',
#    'name': 'Have & Meyer',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hzduhbuVvYRa6jZ7Lt7Arg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/have-and-meyer-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 140,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7132687751084,
#     'longitude': -73.9564743950496},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '103 Havemeyer St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 Havemeyer St', 'Brooklyn, NY 11211']},
#    'phone': '+17184190722',
#    'display_phone': '(718) 419-0722',
#    'distance': 3304.285127566444},
#   {'id': 't-Pm38_XhMnGfOYgkhaNRA',
#    'alias': 'le-fanfare-brooklyn-4',
#    'name': 'Le Fanfare',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MSs2OKz8_BYKpcU7UxCmMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-fanfare-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 198,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.736202, 'longitude': -73.955558},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1103 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1103 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+13479874244',
#    'display_phone': '(347) 987-4244',
#    'distance': 4734.875684140819},
#   {'id': 'QObHX0yR6zd0WfksRDbJTA',
#    'alias': 'becco-new-york-4',
#    'name': 'Becco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-2p7x5nakbTB0nz96x4bLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/becco-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2871,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.76083, 'longitude': -73.98981},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '355 W 46th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['355 W 46th St', 'New York, NY 10036']},
#    'phone': '+12123977597',
#    'display_phone': '(212) 397-7597',
#    'distance': 6167.279010897303},
#   {'id': 'bW3mY-voyav37nU0uaLmNQ',
#    'alias': 'dante-new-york',
#    'name': 'Dante',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/828zxxk4lED3Cmh34oZdyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dante-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 434,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72879, 'longitude': -74.00165},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '79-81 Macdougal St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79-81 Macdougal St', 'New York, NY 10012']},
#    'phone': '+12129825275',
#    'display_phone': '(212) 982-5275',
#    'distance': 2678.723212827433},
#   {'id': 'aJJlY5xvqS180wtRIHEWqA',
#    'alias': 'cotenna-new-york',
#    'name': 'Cotenna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/A9FtedBK3bJGB7t-EeclJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cotenna-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 422,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72903, 'longitude': -74.00357},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '21 Bedford St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21 Bedford St', 'New York, NY 10014']},
#    'phone': '+16468610175',
#    'display_phone': '(646) 861-0175',
#    'distance': 2736.0683317521443},
#   {'id': 'FXYsBqMu2q1dhJYQg_FfAA',
#    'alias': 'rosemary-s-new-york',
#    'name': 'Rosemary’s',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t6JhLAL6hx4KbG04keW1RA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rosemary-s-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 65,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73512, 'longitude': -73.97965},
#    'transactions': [],
#    'location': {'address1': '350 1st Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['350 1st Ave', 'New York, NY 10010']},
#    'phone': '+16468685335',
#    'display_phone': '(646) 868-5335',
#    'distance': 3520.4220508659423},
#   {'id': 'kQuTJxm0KAX1AsS46vhC_g',
#    'alias': 'barbuto-new-york-2',
#    'name': 'Barbuto',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-NSVxG5KQwP_grhWGP3Y6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barbuto-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73885, 'longitude': -74.00932},
#    'transactions': [],
#    'location': {'address1': '113 Horatio St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['113 Horatio St', 'New York, NY 10014']},
#    'phone': '+12129249700',
#    'display_phone': '(212) 924-9700',
#    'distance': 3929.2350727496696},
#   {'id': 'Ei5qjq0qmfNLkdVoO-S5Tw',
#    'alias': 'raffettos-new-york-2',
#    'name': "Raffetto's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/38njXkebZvBqAKe0ae3hlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raffettos-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 238,
#    'categories': [{'alias': 'gourmet', 'title': 'Specialty Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72816, 'longitude': -74.00172},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '144 W Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['144 W Houston St', 'New York, NY 10012']},
#    'phone': '+12127771261',
#    'display_phone': '(212) 777-1261',
#    'distance': 2601.6287697618077},
#   {'id': '1ZKbUeFAs0ltSnAYq4ELKw',
#    'alias': 'trattoria-l-incontro-astoria-6',
#    'name': "Trattoria L'incontro",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cK_dW15pU7H4vTEjY9qsxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trattoria-l-incontro-astoria-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 984,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77648209257472,
#     'longitude': -73.91059675544598},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '21-76 31st St',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21-76 31st St', 'Astoria, NY 11105']},
#    'phone': '+17187213532',
#    'display_phone': '(718) 721-3532',
#    'distance': 10588.429379395355},
#   {'id': 'tJxAlyeT5PRbUIyJ2wsv-A',
#    'alias': 'bamontes-brooklyn',
#    'name': "Bamonte's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y5w9ak4F0uv6TG-kFYWaNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bamontes-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 361,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.716579, 'longitude': -73.951174},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '32 Withers St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 Withers St', 'Brooklyn, NY 11211']},
#    'phone': '+17183848831',
#    'display_phone': '(718) 384-8831',
#    'distance': 3839.4615572236266},
#   {'id': 'DynFEEWtMX76qeqviUbOdA',
#    'alias': 'mille-nonne-new-york-2',
#    'name': 'Mille Nonne',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xgiTNhCWg-tGcmN7waiKSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mille-nonne-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71821, 'longitude': -73.98815},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '88 Essex St',
#     'address2': 'Store 47 ( Inside Essex Market )',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['88 Essex St',
#      'Store 47 ( Inside Essex Market )',
#      'New York, NY 10002']},
#    'phone': '+16466698957',
#    'display_phone': '(646) 669-8957',
#    'distance': 1515.3696218243854},
#   {'id': 'iEUXrUUqGfUhpgYYSr5Zig',
#    'alias': 'da-nico-ristorante-new-york',
#    'name': 'Da Nico Ristorante',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HzlwrWVPQ_KCVS3n7kKMSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-nico-ristorante-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 848,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71963, 'longitude': -73.99691},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '164 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['164 Mulberry St', 'New York, NY 10013']},
#    'phone': '+12123431212',
#    'display_phone': '(212) 343-1212',
#    'distance': 1594.738345180833},
#   {'id': 'e6ic-qLMcaQLrAnHn2jgTw',
#    'alias': 'la-pecora-bianca-new-york-7',
#    'name': 'La Pecora Bianca',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KjA-OCSs2YUBn_xkzzRkxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-pecora-bianca-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 67,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72346, 'longitude': -73.9963118},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '54 Prince St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['54 Prince St', 'New York, NY 10012']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2010.4011061077633},
#   {'id': 'vegSCksJy6SI8WUGttLH-w',
#    'alias': 'fradei-bistro-brooklyn-4',
#    'name': 'Fradei Bistro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ukys9pga2bQNptMn0ySLOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fradei-bistro-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.686579, 'longitude': -73.974191},
#    'transactions': [],
#    'location': {'address1': '99 South Portland Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['99 South Portland Ave', 'Brooklyn, NY 11217']},
#    'phone': '+13477253275',
#    'display_phone': '(347) 725-3275',
#    'distance': 2694.3213368567067},
#   {'id': 'acXWoQ2wZnpzRV-0V58YTQ',
#    'alias': 'bevacco-brooklyn',
#    'name': 'Bevacco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PgBq5rhmuQhzwbUOtcE6Bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bevacco-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 249,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6992683, 'longitude': -73.9923096},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '60 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Henry St', 'Brooklyn, NY 11201']},
#    'phone': '+17186241444',
#    'display_phone': '(718) 624-1444',
#    'distance': 715.0007787095552},
#   {'id': 'xbrQ2dHuQoFJmNxAuOky4A',
#    'alias': 'vics-new-york',
#    'name': "Vic's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-AKKhSlRxqudkdani2Ut0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vics-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 509,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72693, 'longitude': -73.99319},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '31 Great Jones St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31 Great Jones St', 'New York, NY 10012']},
#    'phone': '+12122535700',
#    'display_phone': '(212) 253-5700',
#    'distance': 2387.4482277722477},
#   {'id': 'dIyKvfhjtm3NuKrMVVt0TA',
#    'alias': 'lucciola-italian-restaurant-new-york',
#    'name': 'Lucciola Italian Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oMkHt1W8euxW9x4ah9oYMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lucciola-italian-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.790362, 'longitude': -73.972629},
#    'transactions': [],
#    'location': {'address1': '621 Amsterdam Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['621 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+13475361335',
#    'display_phone': '(347) 536-1335',
#    'distance': 9611.92572213535},
#   {'id': 'rtivWWzG0XjUuhSrwusTgQ',
#    'alias': 'fausto-brooklyn',
#    'name': 'Fausto',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dyC9YwvTgoE8tFMAZJhjAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fausto-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 179,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67597, 'longitude': -73.97181},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '348 Flatbush Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['348 Flatbush Ave', 'Brooklyn, NY 11238']},
#    'phone': '+19179091427',
#    'display_phone': '(917) 909-1427',
#    'distance': 3779.2636040245116},
#   {'id': 'YFvF4r2D-wJOgJAOvanaZQ',
#    'alias': 'gnoccheria-by-luzzos-new-york',
#    'name': "Gnoccheria By Luzzo's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/czqK6BtyIrUIl60H6p11hQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gnoccheria-by-luzzos-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 452,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.723315, 'longitude': -73.983139},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '234 E 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['234 E 4th St', 'New York, NY 10009']},
#    'phone': '+12122543638',
#    'display_phone': '(212) 254-3638',
#    'distance': 2198.2327567712673},
#   {'id': 'PajKY49h4SpvSr-TW3lwCQ',
#    'alias': 'rafele-ristorante-new-york',
#    'name': 'Rafele Ristorante',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sSRFRyAT1LAVU2j8cFjPpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rafele-ristorante-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 487,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7309471231405,
#     'longitude': -74.0041171779098},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '29 7th Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['29 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12122421999',
#    'display_phone': '(212) 242-1999',
#    'distance': 2954.113163998282},
#   {'id': '25npnVAlhRjguunYS8zy8w',
#    'alias': 'piccola-strada-new-york',
#    'name': 'Piccola Strada',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Otzhs2DxuJfYpFeUoWRUOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piccola-strada-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 204,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72662, 'longitude': -73.99019},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '77 E 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['77 E 4th St', 'New York, NY 10003']},
#    'phone': '+12126741557',
#    'display_phone': '(212) 674-1557',
#    'distance': 2389.6841060385354},
#   {'id': '9mawr6QwVHm5q8JRXPFjPA',
#    'alias': 'san-marino-ristorante-new-york-2',
#    'name': 'San Marino Ristorante',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mEgZ9Ri_RpfbZoEG7LDRIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/san-marino-ristorante-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 164,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72697, 'longitude': -74.00611},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '66 Charlton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['66 Charlton St', 'New York, NY 10014']},
#    'phone': '+12122063766',
#    'display_phone': '(212) 206-3766',
#    'distance': 2588.8002704043392},
#   {'id': 'tLZfepIfSf0a80zHQTbTGQ',
#    'alias': 'trattoria-zero-otto-nove-bronx',
#    'name': 'Trattoria Zero Otto Nove',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lvghehU8tD0cYZgOmxbLWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trattoria-zero-otto-nove-bronx?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 802,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.854779, 'longitude': -73.888474},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2357 Arthur Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10458',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2357 Arthur Ave', 'Bronx, NY 10458']},
#    'phone': '+17182201027',
#    'display_phone': '(718) 220-1027',
#    'distance': 18844.5723615574},
#   {'id': '0SakkRuHhECsDsZ8mRkisQ',
#    'alias': 'il-triangolo-restaurant-corona-3',
#    'name': 'IL Triangolo Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ge_Ezddkhf0dzfTZPd2rLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-triangolo-restaurant-corona-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 490,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.742278, 'longitude': -73.8672901},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '96-01 Corona Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Corona',
#     'zip_code': '11368',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['96-01 Corona Ave', 'Corona, NY 11368']},
#    'phone': '+17182711250',
#    'display_phone': '(718) 271-1250',
#    'distance': 11459.495586730902},
#   {'id': 'XfOa_KyrV7JSFJMOKckGMg',
#    'alias': 'montes-trattoria-new-york-2',
#    'name': "Monte's Trattoria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gjCsoro5Iyw7FhIOyMDR-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/montes-trattoria-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 372,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72959, 'longitude': -74.0011},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '97 Macdougal St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['97 Macdougal St', 'New York, NY 10012']},
#    'phone': '+12122289194',
#    'display_phone': '(212) 228-9194',
#    'distance': 2749.837728349273},
#   {'id': 'f_1BjTChf6bobreSRpqhsw',
#    'alias': 'arco-cafe-new-york',
#    'name': 'Arco Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oNW76vEP9B2sGldRq7lnAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arco-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 295,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7988462, 'longitude': -73.967065},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '886 Amsterdam Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['886 Amsterdam Ave', 'New York, NY 10025']},
#    'phone': '+18444102583',
#    'display_phone': '(844) 410-2583',
#    'distance': 10619.497189367872},
#   {'id': 'd5ya04K-2A_hI3Xzqe1HeA',
#    'alias': 'caffe-buon-gusto-new-york-4',
#    'name': 'Caffe Buon Gusto',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/K-xONaTV6OqrgS9738DR9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-buon-gusto-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 566,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77249, 'longitude': -73.95713},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '236 E 77th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['236 E 77th St', 'New York, NY 10075']},
#    'phone': '+12125356884',
#    'display_phone': '(212) 535-6884',
#    'distance': 8085.884880511559},
#   {'id': 'o5mMVFk4Hcpk2FuKfgTgdg',
#    'alias': 'malaparte-new-york',
#    'name': 'Malaparte',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FmYYMRGH-EtYxt0ywMlA3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/malaparte-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 348,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73687, 'longitude': -74.00812},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '753 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['753 Washington St', 'New York, NY 10014']},
#    'phone': '+12122552122',
#    'display_phone': '(212) 255-2122',
#    'distance': 3683.8690941142286},
#   {'id': 'X8Hl9OezX-Yr9Jir3fsF7g',
#    'alias': 'posto-new-york-4',
#    'name': 'Posto',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GNK1zpfkMKebOq7U5ljZqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/posto-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 621,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73483, 'longitude': -73.98282},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '310 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['310 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12127161200',
#    'display_phone': '(212) 716-1200',
#    'distance': 3407.292340600204},
#   {'id': 'JSexQM-wn8HvWmfxu_m5ZA',
#    'alias': 'gnocco-new-york',
#    'name': 'Gnocco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zTyoQD58mdTT452gEcvfyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gnocco-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 506,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72713, 'longitude': -73.9802799},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '337 E 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['337 E 10th St', 'New York, NY 10009']},
#    'phone': '+12126771913',
#    'display_phone': '(212) 677-1913',
#    'distance': 2688.6638426063128},
#   {'id': 'cGqMEMQFtkB3hIGfLy2R3A',
#    'alias': 'bar-pitti-new-york',
#    'name': 'Bar Pitti',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eUTdsZpTQhROG2acKpyj7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-pitti-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1097,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.729047, 'longitude': -74.002153},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '268 Ave Of The Americas',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['268 Ave Of The Americas', 'New York, NY 10014']},
#    'phone': '+12129823300',
#    'display_phone': '(212) 982-3300',
#    'distance': 2706.7414605883773},
#   {'id': 'dhKZRnt3DwfSu48OdPDdvA',
#    'alias': 'pasta-louise-brooklyn',
#    'name': 'Pasta Louise',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/s296vfHEvHPBDGW5Yf_OyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pasta-louise-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 141,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.666091, 'longitude': -73.9787254},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '803 8th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['803 8th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+13477253883',
#    'display_phone': '(347) 725-3883',
#    'distance': 4560.468991092741},
#   {'id': '9iC39Z1YjZKbrrCANgzBXg',
#    'alias': 'sergimmo-salumeria-new-york',
#    'name': 'Sergimmo Salumeria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sgtrM4QD1sozFbAwXagpJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sergimmo-salumeria-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 687,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.754296, 'longitude': -73.995498},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '456 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['456 9th Ave', 'New York, NY 10018']},
#    'phone': '+12129674212',
#    'display_phone': '(212) 967-4212',
#    'distance': 5432.940970395526},
#   {'id': 'WYhRkUATHRyXZrE55MArbA',
#    'alias': 'scalini-fedeli-new-york',
#    'name': 'Scalini Fedeli',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jyyvm1ZMPC7SjtMUqYj8Uw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scalini-fedeli-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 323,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7173964385114,
#     'longitude': -74.0093277537459},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '165 Duane St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['165 Duane St', 'New York, NY 10013']},
#    'phone': '+12125280400',
#    'display_phone': '(212) 528-0400',
#    'distance': 1836.2789790427398},
#   {'id': 's3jou_L_LVYGkNHiuhjlew',
#    'alias': 'boucherie-west-village-new-york-3',
#    'name': 'Boucherie West Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gGTUB2AHF7sK5u-wdjO8DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boucherie-west-village-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1767,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.733063, 'longitude': -74.0028772},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '99 7th Ave S',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['99 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12128371616',
#    'display_phone': '(212) 837-1616',
#    'distance': 3155.0505772747442},
#   {'id': '5MpWHGQ6Qc-M4q1KL_nioA',
#    'alias': 'bar-b-new-york',
#    'name': 'Bar B',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rP6Gfe33cpkYe549tj_2BQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-b-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 187,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7395804, 'longitude': -73.999118},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '84 7th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['84 7th Ave', 'New York, NY 10011']},
#    'phone': '+12122291888',
#    'display_phone': '(212) 229-1888',
#    'distance': 3817.3548091487633},
#   {'id': 'NAlOPUbFQVE0bUu8_wmBLQ',
#    'alias': 'rezdôra-new-york-4',
#    'name': 'Rezdôra',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/flUY4VYU1QtwmO5mlpYkQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rezd%C3%B4ra-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 328,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73901, 'longitude': -73.9891},
#    'transactions': [],
#    'location': {'address1': '27 E 20th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27 E 20th St', 'New York, NY 10003']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3773.837742494728},
#   {'id': '53ZNJNrT91VgvrI0LFjLNQ',
#    'alias': 'locanda-vini-e-olii-brooklyn-4',
#    'name': 'Locanda Vini e Olii',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4YwmIuacjpAJe9YvHk8lCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/locanda-vini-e-olii-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 314,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.685007, 'longitude': -73.962943},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '129 Gates Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['129 Gates Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17186229202',
#    'display_phone': '(718) 622-9202',
#    'distance': 3485.7212460286987},
#   {'id': 'BgGz5IdV53bGb4o7opR5zg',
#    'alias': 'arturos-new-york',
#    'name': "Arturo's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hUTu5vlfU4JYSNp-Qt0t4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arturos-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 705,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7273563342024,
#     'longitude': -74.0004944801331},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '106 W Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['106 W Houston St', 'New York, NY 10012']},
#    'phone': '+12126773820',
#    'display_phone': '(212) 677-3820',
#    'distance': 2491.867165709998},
#   {'id': 'zzJA5P32V9MIHIMBIyasJw',
#    'alias': 'dante-west-village-new-york',
#    'name': 'Dante West Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AuCIUtbjFSrJ3Tcb5Dt7Yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dante-west-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.735202, 'longitude': -74.006251},
#    'transactions': ['delivery'],
#    'location': {'address1': '551 Hudson St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['551 Hudson St', 'New York, NY 10014']},
#    'phone': '+12129825275',
#    'display_phone': '(212) 982-5275',
#    'distance': 3458.895237809097},
#   {'id': '5CuYWr0-cE01HxlBu5Ka6g',
#    'alias': 'carne-mare-new-york-5',
#    'name': 'Carne Mare',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tFR0OcGHVFVpHIKr9fee6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carne-mare-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70634, 'longitude': -74.00383},
#    'transactions': ['delivery'],
#    'location': {'address1': '89 South St',
#     'address2': '',
#     'address3': 'Pier 17',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['89 South St', 'Pier 17', 'New York, NY 10038']},
#    'phone': '+12122804600',
#    'display_phone': '(212) 280-4600',
#    'distance': 633.1849803021449},
#   {'id': 'EL5Y6BSinmUte5VW4Eh54Q',
#    'alias': 'frank-new-york',
#    'name': 'Frank',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/luN-_iIU56S_09mBWo7R4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frank-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 711,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7268483205383,
#     'longitude': -73.9887172038649},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '88 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['88 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12124200202',
#    'display_phone': '(212) 420-0202',
#    'distance': 2425.907423878083},
#   {'id': 'x6_1vzeCH9YvbvIBmSr2iA',
#    'alias': 'doc-wine-bar-brooklyn-2',
#    'name': 'DOC Wine Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4aT0GeTWrnkNAFdONnnUXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doc-wine-bar-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 236,
#    'categories': [{'alias': 'sardinian', 'title': 'Sardinian'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71966, 'longitude': -73.96046},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '83 N 7th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['83 N 7th St', 'Brooklyn, NY 11249']},
#    'phone': '+17189631925',
#    'display_phone': '(718) 963-1925',
#    'distance': 3275.645288514589},
#   {'id': 'QhRQE6nOMLd00kV2k-IsbQ',
#    'alias': 'augustinos-hoboken',
#    'name': "Augustino's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3O4LpMCjXLX0D85wUqFIbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/augustinos-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 318,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75024, 'longitude': -74.02732},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '1104 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1104 Washington St', 'Hoboken, NJ 07030']},
#    'phone': '+12014200104',
#    'display_phone': '(201) 420-0104',
#    'distance': 5706.588293322334},
#   {'id': 'Ry9w-jFALWYhazi6jjyIKw',
#    'alias': 'rucola-brooklyn',
#    'name': 'Rucola',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fnyiy87Gj34GbKKlHz_hFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rucola-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 504,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68562, 'longitude': -73.98587},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '190 Dean St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['190 Dean St', 'Brooklyn, NY 11217']},
#    'phone': '+17185763209',
#    'display_phone': '(718) 576-3209',
#    'distance': 2317.3629905521802},
#   {'id': 'Tgi-rDD3mxFi9uGybZxdaQ',
#    'alias': 'faun-brooklyn',
#    'name': 'Faun',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/h7KH6w1xahz45DnA5Xg70A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/faun-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 181,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.678271, 'longitude': -73.968883},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '606 Vanderbilt Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['606 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17185766120',
#    'display_phone': '(718) 576-6120',
#    'distance': 3704.0138539585605},
#   {'id': 'KogxM0x2p9auUyU4h4CAqQ',
#    'alias': 'creminis-brooklyn',
#    'name': "Cremini's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/c1KgCZ-yAqHaE5UPEinuHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/creminis-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.674968, 'longitude': -73.999242},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '521 Court St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['521 Court St', 'Brooklyn, NY 11231']},
#    'phone': '+19293052967',
#    'display_phone': '(929) 305-2967',
#    'distance': 3413.5026614410585},
#   {'id': '2ggi1luerd3Mf_C82JvCYg',
#    'alias': 'grimaldis-pizzeria-brooklyn-4',
#    'name': "Grimaldi's Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KnocNRTl04953MdDXH9y7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grimaldis-pizzeria-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4689,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.702583, 'longitude': -73.9932413},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17188584300',
#    'display_phone': '(718) 858-4300',
#    'distance': 330.34746206527655},
#   {'id': 'l7Z0p-PkSwIDPLPY1TRl8A',
#    'alias': 'emilios-ballato-new-york',
#    'name': "Emilio's Ballato",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MsoYj6sZi8ZI_7xv4UGQxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/emilios-ballato-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 387,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7244923, 'longitude': -73.9944022},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '55 E Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 E Houston St', 'New York, NY 10012']},
#    'phone': '+12122748881',
#    'display_phone': '(212) 274-8881',
#    'distance': 2117.9957689325374},
#   {'id': '2Nwmd7-1d1rI6lb9QSSYYA',
#    'alias': 'a-pasta-bar-new-york',
#    'name': 'A Pasta Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4VDTeJrDb4PTdSiVLEeCag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/a-pasta-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 336,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72229, 'longitude': -74.00403},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '330 W Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['330 W Broadway', 'New York, NY 10013']},
#    'phone': '+16466924131',
#    'display_phone': '(646) 692-4131',
#    'distance': 2048.470504817877}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#      Restaurant           Type Price Rating             Address        Lat  \
# 0  Have & Meyer      Wine Bars    $$      4    103 Havemeyer St  40.713269
# 1    Le Fanfare        Italian    $$      4  1103 Manhattan Ave  40.736202
# 2         Becco        Italian   $$$    3.5       355 W 46th St  40.760830
# 3         Dante  Cocktail Bars    $$      4  79-81 Macdougal St  40.728790
# 4       Cotenna        Italian    $$      4       21 Bedford St  40.729030
#
#          Lng                                                url  \
# 0 -73.956474  https://www.yelp.com/biz/have-and-meyer-brookl...
# 1 -73.955558  https://www.yelp.com/biz/le-fanfare-brooklyn-4...
# 2 -73.989810  https://www.yelp.com/biz/becco-new-york-4?adju...
# 3 -74.001650  https://www.yelp.com/biz/dante-new-york?adjust...
# 4 -74.003570  https://www.yelp.com/biz/cotenna-new-york?adju...
#
#                        ID
# 0  JU5d81TYm7IJHWqOqJWMqw
# 1  t-Pm38_XhMnGfOYgkhaNRA
# 2  QObHX0yR6zd0WfksRDbJTA
# 3  bW3mY-voyav37nU0uaLmNQ
# 4  aJJlY5xvqS180wtRIHEWqA

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                            Restaurant            Type Rating Price  \
# 0                                Otis  American (New)      5    $$
# 1            LaRina Pastificio & Vino            Bars      4    $$
# 2                         Santa Panza            Bars    4.5    $$
# 3    Tarallucci e Vino - East Village            Bars      4    $$
# 4                             Savelli            Bars
# 5               Lillo Cucina Italiana           Cafes      5    $$
# 6                        Ammazzacaffè   Cocktail Bars    4.5    $$
# 7                  Dante West Village   Cocktail Bars
# 8                               Dante   Cocktail Bars      4    $$
# 9              Boucherie West Village          French    4.5   $$$
# 10                         Osteria 57         Italian    4.5   $$$
# 11                           Briciola         Italian      4    $$
# 12               Angeletto Restaurant         Italian    4.5    $$
# 13                  Allora Ristorante         Italian    4.5   $$$
# 14                             Ciccio         Italian    4.5    $$
# 15                  Antica Ristorante         Italian    4.5   $$$
# 16                           Rubirosa         Italian    4.5    $$
# 17                           Isabella         Italian
# 18                              Cotto         Italian
# 19                 Al Di La Trattoria         Italian      4   $$$
# 20                  Piccoli Trattoria         Italian    4.5    $$
# 21                            Lavagna         Italian      4   $$$
# 22                         Da Toscano         Italian
# 23                           Maialino         Italian      4   $$$
# 24                       Il Cantinori         Italian      4   $$$
# 25                     Bocca di Bacco         Italian
# 26                    Osteria Carlina         Italian
# 27         Patrizia's Pizza and Pasta         Italian      4    $$
# 28                         Via Carota         Italian      4   $$$
# 29       Il Buco Alimentari & Vineria         Italian      4   $$$
# ..                                ...             ...    ...   ...
# 170                     Lil Frankie's           Pizza      4    $$
# 171                        Olio e Piú           Pizza    4.5    $$
# 172               Grimaldi's Pizzeria           Pizza    3.5    $$
# 173                     Song E Napule           Pizza    4.5    $$
# 174                 Gino's Restaurant           Pizza      4    $$
# 175                             Marta           Pizza      4   $$$
# 176                         Roberta's           Pizza      4    $$
# 177               Il Porto Ristorante           Pizza      4    $$
# 178                            Lucali           Pizza      4    $$
# 179                    Mama Mia 44 SW           Pizza      4    $$
# 180                         Saraghina           Pizza      4    $$
# 181         Patrizia's - Williamsburg           Pizza      4    $$
# 182                           Piacere           Pizza      4    $$
# 183                  Lombardi's Pizza           Pizza      4    $$
# 184           Lombardo's of Bay Ridge           Pizza      5    $$
# 185                            Barano           Pizza    4.5   $$$
# 186                   Baci & Abbracci           Pizza      4    $$
# 187             L & B Spumoni Gardens           Pizza      4     $
# 188                         Juliana's           Pizza    4.5    $$
# 189                      DOC Wine Bar       Sardinian      4    $$
# 190             Piccola Cucina Uptown        Sicilian
# 191                        Raffetto's  Specialty Food    4.5     $
# 192                        Carne Mare     Steakhouses
# 193             Fiaschetteria Pistoia          Tuscan      4    $$
# 194                         Da Andrea          Tuscan      4    $$
# 195             Fiaschetteria Pistoia          Tuscan
# 196                     Fradei Bistro       Wine Bars
# 197                      Have & Meyer       Wine Bars      4    $$
# 198                        Follia NYC       Wine Bars      4    $$
# 199                            Felice       Wine Bars      4    $$
#
#                    Address        Lat        Lng  \
# 0           18 Harrison Pl  40.706011 -73.932598
# 1           387 Myrtle Ave  40.693363 -73.970413
# 2            1079 Broadway  40.694700 -73.930680
# 3              163 1st Ave  40.728960 -73.984540
# 4             195 Smith St  40.685074 -73.991272
# 5             331 Henry St  40.690230 -73.996340
# 6             702 Grand St  40.711317 -73.944624
# 7            551 Hudson St  40.735202 -74.006251
# 8       79-81 Macdougal St  40.728790 -74.001650
# 9             99 7th Ave S  40.733063 -74.002877
# 10            57 W 10th St  40.734670 -73.997860
# 11           370 W 51st St  40.763800 -73.988092
# 12             890 2nd Ave  40.753188 -73.969365
# 13           145 E 47th St  40.754330 -73.972770
# 14             190 6th Ave  40.726326 -74.003447
# 15              8 Stone St  40.703936 -74.012173
# 16         235 Mulberry St  40.722766 -73.996233
# 17         110 St Marks Pl  40.726966 -73.984334
# 18           112 W 25th St  40.744420 -73.992660
# 19             248 5th Ave  40.675333 -73.981340
# 20             522 6th Ave  40.665180 -73.986500
# 21            545 E 5th St  40.724060 -73.982260
# 22           24 Minetta Ln  40.730508 -74.001238
# 23         2 Lexington Ave  40.738437 -73.985686
# 24            32 E 10th St  40.732278 -73.992932
# 25             635 9th Ave  40.760217 -73.991563
# 26           455 Hudson St  40.731409 -74.006984
# 27         462-466 2nd Ave  40.739841 -73.979286
# 28             51 Grove St  40.733148 -74.003668
# 29              47 Bond St  40.725830 -73.992990
# ..                     ...        ...        ...
# 170             19 1st Ave  40.723625 -73.988555
# 171        3 Greenwich Ave  40.733798 -73.999774
# 172             1 Front St  40.702583 -73.993241
# 173       146 W Houston St  40.728130 -74.001880
# 174           7414 5th Ave  40.630000 -74.022740
# 175           29 E 29th St  40.744588 -73.984794
# 176           261 Moore St  40.704930 -73.933990
# 177      37 Washington Ave  40.697443 -73.967520
# 178           575 Henry St  40.681800 -74.000240
# 179            621 9th Ave  40.759761 -73.992065
# 180          350 Lewis Ave  40.683741 -73.935347
# 181            35 Broadway  40.710915 -73.967364
# 182          351 Broome St  40.719698 -73.995118
# 183           32 Spring St  40.721593 -73.995596
# 184            279 71st St  40.634741 -74.028426
# 185            26 Broadway  40.710372 -73.967940
# 186           204 Grand St  40.713902 -73.960449
# 187           2725 86th St  40.594715 -73.981316
# 188       19 Old Fulton St  40.702747 -73.993435
# 189            83 N 7th St  40.719660 -73.960460
# 190          106 E 60th St  40.763174 -73.969046
# 191       144 W Houston St  40.728160 -74.001720
# 192            89 South St  40.706340 -74.003830
# 193          647 E 11th St  40.726660 -73.977300
# 194           35 W 13th St  40.736218 -73.995970
# 195     114 Christopher St  40.733160 -74.005370
# 196  99 South Portland Ave  40.686579 -73.974191
# 197       103 Havemeyer St  40.713269 -73.956474
# 198            179 3rd Ave  40.734924 -73.985588
# 199             15 Gold St  40.707890 -74.007120
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/otis-brooklyn-2?adjus...  RfxOtJ4SQmEeVX_XjFLWUQ
# 1    https://www.yelp.com/biz/larina-pastificio-and...  vhqFa_0SG9M7Ra1OTmfB9A
# 2    https://www.yelp.com/biz/santa-panza-brooklyn?...  eTneVbjPKdo4gD9HfkDGdA
# 3    https://www.yelp.com/biz/tarallucci-e-vino-eas...  gqTikTCIS01E2m20PzHoDQ
# 4
# 5    https://www.yelp.com/biz/lillo-cucina-italiana...  qgY41g_eg0eNzewCXmKcaA
# 6    https://www.yelp.com/biz/ammazzacaff%C3%A8-bro...  eMSTTuOUlKEnSOr8lPp3Xg
# 7
# 8    https://www.yelp.com/biz/dante-new-york?adjust...  bW3mY-voyav37nU0uaLmNQ
# 9    https://www.yelp.com/biz/boucherie-west-villag...  s3jou_L_LVYGkNHiuhjlew
# 10   https://www.yelp.com/biz/osteria-57-new-york?a...  T-RXDLq_VEv7s1_SooYIYQ
# 11   https://www.yelp.com/biz/briciola-new-york?adj...  MOwB9YYd-Ko6nVgSB-ltQw
# 12   https://www.yelp.com/biz/angeletto-restaurant-...  7cjT33LfYSk7vrRdEaSr4w
# 13   https://www.yelp.com/biz/allora-ristorante-new...  z7H9ApIGopnDnQaglnPTzg
# 14   https://www.yelp.com/biz/ciccio-new-york-11?ad...  eWMuXtaBzf0H5u0Vf_zpjw
# 15   https://www.yelp.com/biz/antica-ristorante-new...  0Tvwk0hvgaY0QVIsZGTZKQ
# 16   https://www.yelp.com/biz/rubirosa-new-york-2?a...  WG639VkTjmK5dzydd1BBJA
# 17
# 18
# 19   https://www.yelp.com/biz/al-di-la-trattoria-br...  aSprnLY-6GkMk1cuv0TMeA
# 20   https://www.yelp.com/biz/piccoli-trattoria-bro...  XvEz60Y0NbLxooK9AmRU8g
# 21   https://www.yelp.com/biz/lavagna-new-york?adju...  jku9Fg8JsUbv_LQzg6PK4g
# 22
# 23   https://www.yelp.com/biz/maialino-new-york?adj...  yi6jIxzHo-nbAOG4KWuqcw
# 24   https://www.yelp.com/biz/il-cantinori-new-york...  idxD3X7WfLFPZMoFnCRIQQ
# 25
# 26
# 27   https://www.yelp.com/biz/patrizias-pizza-and-p...  kIm0oeOaVfC9-2flLPVklA
# 28   https://www.yelp.com/biz/via-carota-new-york?a...  jnHbdsqlTKlPcmJ8BCP9-g
# 29   https://www.yelp.com/biz/il-buco-alimentari-an...  lwfCl81r5a0mjxDNxNGC9w
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/lil-frankies-new-york...  TWH4MjLtN1fKlF-7n6YXHg
# 171  https://www.yelp.com/biz/olio-e-pi%C3%BA-new-y...  16ZnHpuaaBt92XWeJHCC5A
# 172  https://www.yelp.com/biz/grimaldis-pizzeria-br...  2ggi1luerd3Mf_C82JvCYg
# 173  https://www.yelp.com/biz/song-e-napule-new-yor...  15k7iqFbhf4h8L01yggLqg
# 174  https://www.yelp.com/biz/ginos-restaurant-broo...  AAQDZdKhtcX7otmOfOF9nw
# 175  https://www.yelp.com/biz/marta-new-york-7?adju...  rZ9OFoSqy8u4WECfh--ylg
# 176  https://www.yelp.com/biz/robertas-brooklyn-2?a...  FhXjAc6nKLf414KxYujUHw
# 177  https://www.yelp.com/biz/il-porto-ristorante-b...  hFmz7HH2og9hn7xNNv20yw
# 178  https://www.yelp.com/biz/lucali-brooklyn-3?adj...  Q9F2ocrmYuGt1yn3M7MOBw
# 179  https://www.yelp.com/biz/mama-mia-44-sw-new-yo...  h4VCnZ2aZ33mdenS_ZI7jQ
# 180  https://www.yelp.com/biz/saraghina-brooklyn?ad...  fU22eRTnKLT2C-OFJ6eUGQ
# 181  https://www.yelp.com/biz/patrizias-williamsbur...  LRgB2kEKtBxqIxNksTO_PQ
# 182  https://www.yelp.com/biz/piacere-new-york?adju...  Z67mgMkN3RfdPEX5mXsyYA
# 183  https://www.yelp.com/biz/lombardis-pizza-new-y...  WIhm0W9197f_rRtDziq5qQ
# 184  https://www.yelp.com/biz/lombardos-of-bay-ridg...  qoBcWhGwlcUsKIQ2nB22vA
# 185  https://www.yelp.com/biz/barano-brooklyn?adjus...  rJfGgBleDYCVq2rkBr_w-Q
# 186  https://www.yelp.com/biz/baci-and-abbracci-bro...  15d_Y6TVOQFD2KRVkxuAjw
# 187  https://www.yelp.com/biz/l-and-b-spumoni-garde...  vyoA8dxwScuMV_AsTcjQcg
# 188  https://www.yelp.com/biz/julianas-brooklyn-3?a...  ysqgdbSrezXgVwER2kQWKA
# 189  https://www.yelp.com/biz/doc-wine-bar-brooklyn...  x6_1vzeCH9YvbvIBmSr2iA
# 190
# 191  https://www.yelp.com/biz/raffettos-new-york-2?...  Ei5qjq0qmfNLkdVoO-S5Tw
# 192
# 193  https://www.yelp.com/biz/fiaschetteria-pistoia...  q3_FgDWWuXcVGiNuo_OPBQ
# 194  https://www.yelp.com/biz/da-andrea-new-york?ad...  hdiuRS9sVZSMReZm4oV5SA
# 195
# 196
# 197  https://www.yelp.com/biz/have-and-meyer-brookl...  JU5d81TYm7IJHWqOqJWMqw
# 198  https://www.yelp.com/biz/follia-nyc-new-york?a...  78TCGIG1eHMYdyvMpFdDbQ
# 199  https://www.yelp.com/biz/felice-new-york-6?adj...  fuS39acPaRi38DhSSwEI4Q
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_Italian.csv')
