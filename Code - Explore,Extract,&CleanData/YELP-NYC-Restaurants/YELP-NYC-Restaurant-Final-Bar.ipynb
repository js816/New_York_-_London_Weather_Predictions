# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"bar","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': 'zWrZBXj5F2V_0UknnTfqbw',
#    'alias': 'the-up-and-up-new-york-2',
#    'name': 'The Up & Up',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PjivAhOykU5fiHN2f_bFig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-up-and-up-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 460,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7295104447158,
#     'longitude': -74.0006693438721},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '116 MacDougal St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['116 MacDougal St', 'New York, NY 10012']},
#    'phone': '+12122603000',
#    'display_phone': '(212) 260-3000',
#    'distance': 2729.3898625454526},
#   {'id': 'PTWQs2DE0CJJiN8q9pxmLw',
#    'alias': 'panorama-room-new-york',
#    'name': 'Panorama Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GXtWgCW-ybm9P_p2TjLcJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/panorama-room-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7562653, 'longitude': -73.9554546},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '22 N Loop Rd',
#     'address2': '',
#     'address3': 'Graduate Hotels',
#     'city': 'New York',
#     'zip_code': '10044',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 N Loop Rd',
#      'Graduate Hotels',
#      'New York, NY 10044']},
#    'phone': '+19294474717',
#    'display_phone': '(929) 447-4717',
#    'distance': 6524.03631672482},
#   {'id': 'ZD22cMZvSmfNsXS9vKizGA',
#    'alias': 'angels-share-new-york',
#    'name': "Angel's Share",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YUk-iz4i2AeWHiZizWD9hA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/angels-share-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2163,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'speakeasies', 'title': 'Speakeasies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7297097529882,
#     'longitude': -73.9891492245369},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '8 Stuyvesant St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8 Stuyvesant St', 'New York, NY 10003']},
#    'phone': '+12127775415',
#    'display_phone': '(212) 777-5415',
#    'distance': 2732.736424747175},
#   {'id': 'zvxUXRQOqzsyFiCKS09_JQ',
#    'alias': 'botanica-bar-new-york',
#    'name': 'Botanica Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lOFj1GtSNQLgrh1H9J_mwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/botanica-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 390,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72459, 'longitude': -73.99478},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '47 E Houston St',
#     'address2': 'Ste B',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 E Houston St', 'Ste B', 'New York, NY 10012']},
#    'phone': '+12123437251',
#    'display_phone': '(212) 343-7251',
#    'distance': 2132.280745842899},
#   {'id': 'J3NT61-AH5d5Gu5tFJhYSw',
#    'alias': 'the-cabin-nyc-new-york-2',
#    'name': 'The Cabin NYC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XEdD6R1D3DtTVKkc5U48Cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cabin-nyc-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 333,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72393, 'longitude': -73.98383},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '205 E 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['205 E 4th St', 'New York, NY 10009']},
#    'phone': '+12127770454',
#    'display_phone': '(212) 777-0454',
#    'distance': 2240.673403602855},
#   {'id': 'RemvTpxalDjSew5HwmNzUQ',
#    'alias': 'the-dead-rabbit-new-york',
#    'name': 'The Dead Rabbit',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_4T5R0HHhASROheby-TXDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dead-rabbit-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1615,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70329, 'longitude': -74.01102},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '30 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30 Water St', 'New York, NY 10004']},
#    'phone': '+16464227906',
#    'display_phone': '(646) 422-7906',
#    'distance': 1431.0399855447463},
#   {'id': 'wTQYOTh9_JPI2I8s6Xc-Cw',
#    'alias': 'pineapple-club-new-york',
#    'name': 'Pineapple Club',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9zSCg2vxqRdZmaNoSsrDig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pineapple-club-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 127,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72529189450972,
#     'longitude': -73.98324323292351},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '509 E 6th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['509 E 6th St', 'New York, NY 10009']},
#    'phone': '+12126978600',
#    'display_phone': '(212) 697-8600',
#    'distance': 2395.3449467702417},
#   {'id': 'zFhfTMtWW6ZHU5rhpyZjrw',
#    'alias': 'queen-bees-tavern-brooklyn',
#    'name': "Queen Bee's Tavern",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WvycgdnUyX8Ow4wwEksm0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/queen-bees-tavern-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.65098, 'longitude': -73.94874},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '3023 Church Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11226',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3023 Church Ave', 'Brooklyn, NY 11226']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 7168.121069070502},
#   {'id': '-dQexkmhlgbiKvZ94jBmjQ',
#    'alias': 'dear-irving-new-york',
#    'name': 'Dear Irving',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OElWI1r3u6qkAiu0_MxXmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dear-irving-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 668,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7360568971331,
#     'longitude': -73.9872401005554},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '55 Irving Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Irving Pl', 'New York, NY 10003']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3455.406641336099},
#   {'id': 'QhE50zhSMnQaudpHW1jp7g',
#    'alias': 'the-tyger-new-york-2',
#    'name': 'The Tyger',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xdyC5Z_denJ-lBlR1dlqhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-tyger-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 215,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'panasian', 'title': 'Pan Asian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71888, 'longitude': -73.99951},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1 Howard St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Howard St', 'New York, NY 10013']},
#    'phone': '+16464767566',
#    'display_phone': '(646) 476-7566',
#    'distance': 1558.0214279215886},
#   {'id': 'H7S7-vF2z_HfaLo6BGPetw',
#    'alias': 'attaboy-new-york',
#    'name': 'Attaboy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RFfMf7jImPkVX1MUa1_2SA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/attaboy-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 597,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'empanadas', 'title': 'Empanadas'},
#     {'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71887, 'longitude': -73.99134},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '134 Eldridge St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['134 Eldridge St', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1514.7473683794203},
#   {'id': 'aiRctIzCj9J3UqBHd-Z3HQ',
#    'alias': 'please-dont-tell-new-york-2',
#    'name': "Please Don't Tell",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zk1RQhSYBQ7Dy9-QyDaVSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/please-dont-tell-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1814,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'speakeasies', 'title': 'Speakeasies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.727157, 'longitude': -73.983721},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '113 St Marks Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['113 St Marks Pl', 'New York, NY 10009']},
#    'phone': '+12126140386',
#    'display_phone': '(212) 614-0386',
#    'distance': 2567.4716321105648},
#   {'id': 'iJUoxnxbCtVDMek4keHJFQ',
#    'alias': 'pokito-brooklyn-2',
#    'name': 'Pokito',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9k0ylqTnqgGLQuazsQ4NMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pokito-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 124,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71162, 'longitude': -73.96184},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '155 S 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['155 S 4th St', 'Brooklyn, NY 11211']},
#    'phone': '+19179091542',
#    'display_phone': '(917) 909-1542',
#    'distance': 2813.8971237218802},
#   {'id': 'uUPs_2S54rROkRTjlDOJVg',
#    'alias': 'moon-bar-rooftop-flushing',
#    'name': 'MOON BAR Rooftop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hb3y4o7EJ4b_QvoIhhAZkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moon-bar-rooftop-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7635, 'longitude': -73.82844},
#    'transactions': ['delivery'],
#    'location': {'address1': '137-72 Northern Blvd',
#     'address2': 'Fl 9',
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['137-72 Northern Blvd', 'Fl 9', 'Flushing, NY 11354']},
#    'phone': '+17188863555',
#    'display_phone': '(718) 886-3555',
#    'distance': 15392.481513220806},
#   {'id': '036OHcA8Au0yTOrrcj5SEQ',
#    'alias': 'someday-bar-brooklyn',
#    'name': 'Someday Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/s-OCLXP-WzE_xmwEMH84_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/someday-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68736, 'longitude': -73.98633},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '364 Atlantic Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['364 Atlantic Ave', 'Brooklyn, NY 11217']},
#    'phone': '+19294808454',
#    'display_phone': '(929) 480-8454',
#    'distance': 2120.044511746092},
#   {'id': 'kLEx49YQZZYhtf57YEvQIg',
#    'alias': 'basement-new-york-3',
#    'name': 'Basement',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/36AYyuLu707I3VZCPBaIIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/basement-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 89,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71526, 'longitude': -73.99883},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '45 Mott St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 Mott St', 'New York, NY 10013']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1164.0064222322944},
#   {'id': 'd6mslo1LlpkNPgb2HWOlEg',
#    'alias': 'fresh-kills-bar-brooklyn',
#    'name': 'Fresh Kills Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lXJNME_AOTnsMXdV2FNccQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fresh-kills-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 142,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7147999, 'longitude': -73.96151},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '161 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['161 Grand St', 'Brooklyn, NY 11249']},
#    'phone': '+17185997888',
#    'display_phone': '(718) 599-7888',
#    'distance': 2950.6174458442506},
#   {'id': 'J4pAppaiXwCkbLOGc4wHww',
#    'alias': 'raines-law-room-new-york',
#    'name': 'Raines Law Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1MDwROZhGa1Hdsz7qzQrsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raines-law-room-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1484,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73879, 'longitude': -73.99455},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '48 W 17th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['48 W 17th St', 'New York, NY 10011']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3705.657290917968},
#   {'id': '9sU8ceKHiqNrLBMRM-aUkg',
#    'alias': 'harriets-rooftop-brooklyn-2',
#    'name': "Harriet's Rooftop",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CXyPJd5XZSEuo3UGlWkdkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harriets-rooftop-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 147,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.70184, 'longitude': -73.9958147},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '60 Furman St',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Furman St', 'Brooklyn, NY 11201']},
#    'phone': '+13476962505',
#    'display_phone': '(347) 696-2505',
#    'distance': 420.8608742302901},
#   {'id': 'P3NfoMjBy_o2BTNNZ-5okg',
#    'alias': 'apotheke-new-york-4',
#    'name': 'Apotheke',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ovQE3vhXaNeAL9lMSXUq9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/apotheke-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1460,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71434, 'longitude': -73.99822},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '9 Doyers St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Doyers St', 'New York, NY 10013']},
#    'phone': '+12124060400',
#    'display_phone': '(212) 406-0400',
#    'distance': 1046.0094120816689},
#   {'id': 'pCxIVhhF96sYKVFR3ct_vg',
#    'alias': 'we-got-company-brooklyn',
#    'name': 'We Got Company',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/THfiB-LMDzlZz6NQcTqsJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/we-got-company-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7142, 'longitude': -73.95389},
#    'transactions': ['pickup'],
#    'location': {'address1': '441 Metropolitan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['441 Metropolitan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17184907814',
#    'display_phone': '(718) 490-7814',
#    'distance': 3540.0269380445957},
#   {'id': 'hmdm-dO72hLsMQwQRcGEUQ',
#    'alias': 'atrium-dumbo-brooklyn',
#    'name': 'Atrium Dumbo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VUzaLCgAu6qYRSsVGZTDVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/atrium-dumbo-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 669,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7033899, 'longitude': -73.9904923},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '15 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Main St', 'Brooklyn, NY 11201']},
#    'phone': '+17188581095',
#    'display_phone': '(718) 858-1095',
#    'distance': 391.3077959872246},
#   {'id': 'Q_bI2gY7LtMCXkzkakPUkg',
#    'alias': 'henrys-rooftop-bar-new-york',
#    'name': "Henry's Rooftop Bar",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_icYfdoRPXIwzQGdaqFJ-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/henrys-rooftop-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 76,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.754799, 'longitude': -73.97314},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '501 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['501 Lexington Ave', 'New York, NY 10017']},
#    'phone': '+12127551400',
#    'display_phone': '(212) 755-1400',
#    'distance': 5770.123944907824},
#   {'id': 'iPc-zPgcpgeSo76xl5Jbpw',
#    'alias': 'the-maze-new-york-3',
#    'name': 'The Maze',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hPYHRfgxCwzPF5HVpXqyQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-maze-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 513,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.747846, 'longitude': -73.9872499},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '32 W 32nd St',
#     'address2': 'Fl 3',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 W 32nd St', 'Fl 3', 'New York, NY 10001']},
#    'phone': '+16469187519',
#    'display_phone': '(646) 918-7519',
#    'distance': 4751.996403737684},
#   {'id': '6-609WDIIp8x5j5C24szqA',
#    'alias': 'peachys-new-york',
#    'name': "Peachy's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QSMF7qL9m2WJMccz1YEF8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peachys-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 65,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71433, 'longitude': -73.99804},
#    'transactions': [],
#    'location': {'address1': '5 Doyers St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 Doyers St', 'New York, NY 10013']},
#    'phone': '+16468959301',
#    'display_phone': '(646) 895-9301',
#    'distance': 1037.1388795725875},
#   {'id': 'xxiV3-0t_gO1Ojo3xo73TQ',
#    'alias': 'vineapple-cafe-brooklyn',
#    'name': 'Vineapple Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3CTXWh2vzVj7lz0s6MFhKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vineapple-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.698296727787, 'longitude': -73.99307556416},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '71 Pineapple St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['71 Pineapple St', 'Brooklyn, NY 11201']},
#    'phone': '+13477991035',
#    'display_phone': '(347) 799-1035',
#    'distance': 801.4361087691583},
#   {'id': '9itMlJoBaBDGjqgnyDem-w',
#    'alias': '142-sullivan-bar-new-york-2',
#    'name': '142 Sullivan Bar ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vZsjOtl6HgxzzE9pT9LthQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/142-sullivan-bar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 65,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72712, 'longitude': -74.0022},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '142 Sullivan St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['142 Sullivan St', 'New York, NY 10012']},
#    'phone': '+12124772404',
#    'display_phone': '(212) 477-2404',
#    'distance': 2499.831162552287},
#   {'id': 'PcF_ebeELn7mg6vqVnHjIg',
#    'alias': 'elsa-brooklyn',
#    'name': 'Elsa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9Rl3uYIb7eVT-prW2xMdtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elsa-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 114,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69035, 'longitude': -73.99531},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '136 Atlantic Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+19178827395',
#    'display_phone': '(917) 882-7395',
#    'distance': 1680.657852889869},
#   {'id': '3d4zgFXojnTZ49j12t9YKg',
#    'alias': 'the-headless-widow-new-york',
#    'name': 'The Headless Widow',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FiLzmXT9yRyxtj6d7PbIPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-headless-widow-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 75,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72658, 'longitude': -73.9863},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'location': {'address1': '99 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['99 1st Ave', 'New York, NY 10003']},
#    'phone': '+19174090446',
#    'display_phone': '(917) 409-0446',
#    'distance': 2445.63828466036},
#   {'id': 'nCH7SR7qXu0asO1GU3iqHw',
#    'alias': 'the-press-lounge-new-york-3',
#    'name': 'The Press Lounge',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AMbo8r7UAA-YhJVmK_nMEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-press-lounge-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1108,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76452, 'longitude': -73.99586},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '653 11th Ave',
#     'address2': 'Fl 16',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['653 11th Ave', 'Fl 16', 'New York, NY 10036']},
#    'phone': '+12127572224',
#    'display_phone': '(212) 757-2224',
#    'distance': 6576.534446741705},
#   {'id': 'NMDrXW5_qnme1hcJrXNP9Q',
#    'alias': 'the-nomad-bar-new-york-2',
#    'name': 'The NoMad Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/INX5gM4HuRM5PjImwRH-7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-nomad-bar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 485,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7449365409844,
#     'longitude': -73.9885197632294},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '10 W 28th St',
#     'address2': '',
#     'address3': 'The NoMad Hotel',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10 W 28th St',
#      'The NoMad Hotel',
#      'New York, NY 10001']},
#    'phone': '+12127961500',
#    'display_phone': '(212) 796-1500',
#    'distance': 4418.138526681626},
#   {'id': 'PcwfZzwdQx-hO5pEQyjSXA',
#    'alias': 'straylight-new-york',
#    'name': 'Straylight',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ntJqgLuemTanqXTk3rdWpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/straylight-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71461, 'longitude': -73.99939},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '32 Mulberry St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 Mulberry St', 'New York, NY 10013']},
#    'phone': '+16465902111',
#    'display_phone': '(646) 590-2111',
#    'distance': 1105.2756929233985},
#   {'id': 'GpWXEpVyehmKP2WQsD_Y8g',
#    'alias': 'otb-brooklyn',
#    'name': 'OTB',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AU9Lkx_vancc7qp4mJmOCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/otb-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 145,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.710484, 'longitude': -73.963408},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '141 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['141 Broadway', 'Brooklyn, NY 11211']},
#    'phone': '+13477631481',
#    'display_phone': '(347) 763-1481',
#    'distance': 2668.3585156444715},
#   {'id': 'WaUuOzaY7WnmBer2nTLPUQ',
#    'alias': 'mace-new-york-5',
#    'name': 'Mace',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mUkeFHylZA6YpscFZ3F_Zg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mace-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 215,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.733138, 'longitude': -73.998044},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '35 W 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35 W 8th St', 'New York, NY 10011']},
#    'phone': '+13478667739',
#    'display_phone': '(347) 866-7739',
#    'distance': 3095.5146142852263},
#   {'id': 'nHMDOIX32dGbfpuNUwsLNQ',
#    'alias': 'almar-brooklyn-2',
#    'name': 'AlMar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_EoXWmBYT1-X--xHq0oUTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/almar-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 460,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.702662, 'longitude': -73.989177},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '111 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17188555288',
#    'display_phone': '(718) 855-5288',
#    'distance': 530.8013177444826},
#   {'id': '2DJjJu3sqaBCN7w4CwR5Dw',
#    'alias': 'livingston-manor-brooklyn',
#    'name': 'Livingston Manor',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6z_ZQa3aL0p9TSzdhT7uFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/livingston-manor-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 121,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68937, 'longitude': -73.98603},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '42 Hoyt St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 Hoyt St', 'Brooklyn, NY 11201']},
#    'phone': '+13479873292',
#    'display_phone': '(347) 987-3292',
#    'distance': 1916.9230475163283},
#   {'id': 'ePqKbqXFBCbwBaWiN2Jo9w',
#    'alias': 'ampersand-new-york-2',
#    'name': 'Ampersand',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VonOfbx-KisgqaxG0zhltw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ampersand-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 229,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7386178790617,
#     'longitude': -73.9834206895483},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '294 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['294 3rd Ave', 'New York, NY 10010']},
#    'phone': '+12124778100',
#    'display_phone': '(212) 477-8100',
#    'distance': 3800.7617476958712},
#   {'id': '511OTzlr0FkL4esfBxMzIw',
#    'alias': 'rooftop-93-new-york-5',
#    'name': 'Rooftop 93',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/P_QP4qcPZvmwkssGW0kg-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rooftop-93-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 365,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71705, 'longitude': -73.99522},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '93 Bowery',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['93 Bowery', 'New York, NY 10002']},
#    'phone': '+12129669033',
#    'display_phone': '(212) 966-9033',
#    'distance': 1292.7929431290174},
#   {'id': 'EDOUZDqwvD4UzOy0doER0g',
#    'alias': 'jungle-bird-new-york-3',
#    'name': 'Jungle Bird',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kJME5ukjHstU_-Uo8eC9tQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jungle-bird-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 105,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74262, 'longitude': -74.00021},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '174 8th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['174 8th Ave', 'New York, NY 10011']},
#    'phone': '+16468688422',
#    'display_phone': '(646) 868-8422',
#    'distance': 4161.519000456325},
#   {'id': '_l40VhhS3pNm55yZTLgLuw',
#    'alias': 'velvet-brooklyn-brooklyn-2',
#    'name': 'Velvet Brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Kxs0OpGO0SIRpMxHrlpt9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/velvet-brooklyn-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7100847891067,
#     'longitude': -73.9625787734985},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '174 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['174 Broadway', 'Brooklyn, NY 11211']},
#    'phone': '+17183024427',
#    'display_phone': '(718) 302-4427',
#    'distance': 2722.5672262380717},
#   {'id': 'mWS4umRg2AyykyAClMrIRw',
#    'alias': 'the-penrose-new-york',
#    'name': 'The Penrose',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qNLV1pybDp4Elzp3Ci_gzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-penrose-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1262,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.775427, 'longitude': -73.953115},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1590 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1590 2nd Ave', 'New York, NY 10028']},
#    'phone': '+12122032751',
#    'display_phone': '(212) 203-2751',
#    'distance': 8520.81817524141},
#   {'id': 'IBgjj5VBu5JJvKgo9EzKrg',
#    'alias': 'the-three-monkeys-new-york-3',
#    'name': 'The Three Monkeys',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9PvL7hV_rZUQI0AiAaGSwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-three-monkeys-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1227,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.764164, 'longitude': -73.98306},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '236 W 54th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['236 W 54th St', 'New York, NY 10019']},
#    'phone': '+12125862080',
#    'display_phone': '(212) 586-2080',
#    'distance': 6597.505592442847},
#   {'id': 'KenUip4W38fN4Ua9WxsohA',
#    'alias': 'bohemien-bar-brooklyn',
#    'name': 'Bohemien Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gj4IpZ784nNOfvkysOT4jA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bohemien-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.691171, 'longitude': -73.99704},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '97 Atlantic Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['97 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+13478449895',
#    'display_phone': '(347) 844-9895',
#    'distance': 1597.4986248795544},
#   {'id': 'jEEb_EKKD2lx2mvTly_U6Q',
#    'alias': 'watermark-new-york',
#    'name': 'Watermark',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V4_mha4A3Fo6AYfcEiCppQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/watermark-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 353,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7043789539783,
#     'longitude': -74.0029934983643},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': 'Pier 15, 78 S St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Pier 15, 78 S St', 'New York, NY 10038']},
#    'phone': '+12127428200',
#    'display_phone': '(212) 742-8200',
#    'distance': 742.9008679000856},
#   {'id': '9QK3vhI04Q8ylqk49C3JcQ',
#    'alias': 'rule-of-thirds-brooklyn',
#    'name': 'Rule of Thirds',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/z3wcWXhTpcFm-yTiQgwekQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rule-of-thirds-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 110,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7246328, 'longitude': -73.9551096},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '171 Banker St',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 Banker St', 'Brooklyn, NY 11222']},
#    'phone': '+13473346684',
#    'display_phone': '(347) 334-6684',
#    'distance': 3944.454297372159},
#   {'id': 'uVfOB37NyYEGRs5FITM-nQ',
#    'alias': 'leyenda-brooklyn',
#    'name': 'Leyenda',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xmzICvK5W37OzD61Bpv1uQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/leyenda-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 261,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68431, 'longitude': -73.99197},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '221 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['221 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+13479873260',
#    'display_phone': '(347) 987-3260',
#    'distance': 2361.4337938854646},
#   {'id': 'BPLhZ4FildfaCiKLNd0dsA',
#    'alias': 'jupiter-disco-brooklyn',
#    'name': 'Jupiter Disco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6Hh9hppCGMj_busRA7RNpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jupiter-disco-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70814, 'longitude': -73.92352},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1237 Flushing Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1237 Flushing Ave', 'Brooklyn, NY 11237']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5972.866358827232},
#   {'id': 'mD2i8YXq5tVB62hlQGTeQA',
#    'alias': 'all-night-skate-brooklyn',
#    'name': 'All Night Skate',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UC4PiCDTv6ibTkq8Pe6NeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/all-night-skate-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.68192, 'longitude': -73.9116856},
#    'transactions': ['delivery'],
#    'location': {'address1': '54 Rockaway Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['54 Rockaway Ave', 'Brooklyn, NY 11233']},
#    'phone': '+13472406263',
#    'display_phone': '(347) 240-6263',
#    'distance': 7439.578465658087},
#   {'id': 'JnT3w2BDpaQpbBP76pyYew',
#    'alias': 'anotheroom-new-york',
#    'name': 'Anotheroom',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LKPexc1rgv4DFvzW_ksDuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anotheroom-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 155,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.719807787837276,
#     'longitude': -74.00539277019567},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '249 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['249 W Broadway', 'New York, NY 10013']},
#    'phone': '+12122261418',
#    'display_phone': '(212) 226-1418',
#    'distance': 1850.9115613859544},
#   {'id': '-egltOQhAdo1kWlPSJfmvA',
#    'alias': 'the-tippler-new-york',
#    'name': 'The Tippler',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/C79CIA4RHymr1Kqciz78Ww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-tippler-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 678,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7423540864346,
#     'longitude': -74.0063398693085},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '425 W 15th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['425 W 15th St', 'New York, NY 10011']},
#    'phone': '+12122060000',
#    'display_phone': '(212) 206-0000',
#    'distance': 4227.804522556444}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#       Restaurant                   Type Price Rating           Address  \
# 0    The Up & Up          Cocktail Bars    $$      4  116 MacDougal St
# 1  Panorama Room  Venues & Event Spaces   $$$    3.5      22 N Loop Rd
# 2  Angel's Share          Cocktail Bars    $$    4.5   8 Stuyvesant St
# 3   Botanica Bar                   Bars     $      4   47 E Houston St
# 4  The Cabin NYC         American (New)    $$      4      205 E 4th St
#
#          Lat        Lng                                                url  \
# 0  40.729510 -74.000669  https://www.yelp.com/biz/the-up-and-up-new-yor...
# 1  40.756265 -73.955455  https://www.yelp.com/biz/panorama-room-new-yor...
# 2  40.729710 -73.989149  https://www.yelp.com/biz/angels-share-new-york...
# 3  40.724590 -73.994780  https://www.yelp.com/biz/botanica-bar-new-york...
# 4  40.723930 -73.983830  https://www.yelp.com/biz/the-cabin-nyc-new-yor...
#
#                        ID
# 0  zWrZBXj5F2V_0UknnTfqbw
# 1  PTWQs2DE0CJJiN8q9pxmLw
# 2  ZD22cMZvSmfNsXS9vKizGA
# 3  zvxUXRQOqzsyFiCKS09_JQ
# 4  J3NT61-AH5d5Gu5tFJhYSw

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"bar","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': 'HuU2IGPfQ23FTOGDQg0Ieg',
#    'alias': 'four-five-six-brooklyn',
#    'name': 'Four Five Six',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NK9cktavJQgXkpVvbpAH7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/four-five-six-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 67,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.719181, 'longitude': -73.943149},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '199 Richardson St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['199 Richardson St', 'Brooklyn, NY 11222']},
#    'phone': '+13479160286',
#    'display_phone': '(347) 916-0286',
#    'distance': 4573.288117051587},
#   {'id': 'dq8RjU9dj24zSvx53bI6Vw',
#    'alias': 'v-new-york-7',
#    'name': 'V',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Isg-Ubue1MzmhUuA0MRxUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/v-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.739248, 'longitude': -73.9867219},
#    'transactions': [],
#    'location': {'address1': '281 Park Ave S',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['281 Park Ave S', 'New York, NY 10010']},
#    'phone': '+16469936993',
#    'display_phone': '(646) 993-6993',
#    'distance': 3812.5036661049967},
#   {'id': '92-4c0RnpGlUdMpk83MSOw',
#    'alias': 'vault-manhattan-new-york',
#    'name': 'VAULT Manhattan',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_8aDWJgGnZDPCa4awmkVhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vault-manhattan-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'speakeasies', 'title': 'Speakeasies'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7423311, 'longitude': -74.0049025},
#    'transactions': [],
#    'location': {'address1': '410 W 16th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['410 W 16th St', 'New York, NY 10011']},
#    'phone': '+19294460222',
#    'display_phone': '(929) 446-0222',
#    'distance': 4161.153373432203},
#   {'id': 'Y7bbr09ssPvFojIIFBa6rA',
#    'alias': 'thyme-bar-new-york',
#    'name': 'Thyme Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/akLGUXi7C_I7u505fVuLgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thyme-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 98,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'speakeasies', 'title': 'Speakeasies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.741672, 'longitude': -73.990594},
#    'transactions': ['delivery'],
#    'location': {'address1': '20 W 23rd St Cellar',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['20 W 23rd St Cellar', 'New York, NY 10010']},
#    'phone': '+16468288707',
#    'display_phone': '(646) 828-8707',
#    'distance': 4045.2541988512426},
#   {'id': 'cfKT8pNcaPQuZlaIwlEAOg',
#    'alias': 'hidden-lane-bar-new-york-2',
#    'name': 'Hidden Lane Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SJ_zE_DJ5s3koCXusQRAQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hidden-lane-bar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.734579, 'longitude': -73.987684},
#    'transactions': [],
#    'location': {'address1': '129 E 15th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['129 E 15th St', 'New York, NY 10003']},
#    'phone': '+19143142032',
#    'display_phone': '(914) 314-2032',
#    'distance': 3287.183028962069},
#   {'id': 'q4oqvj0o8DQIDiOICjBraQ',
#    'alias': 'subject-new-york-4',
#    'name': 'Subject',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-9vkqMR4rXg5Zuosr5vnqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/subject-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 196,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72147, 'longitude': -73.9847},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '188 Suffolk St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['188 Suffolk St', 'New York, NY 10002']},
#    'phone': '+16464227898',
#    'display_phone': '(646) 422-7898',
#    'distance': 1961.33585889308},
#   {'id': '2hHlAxt4gsfMUkG48pXXKw',
#    'alias': 'loopy-doopy-rooftop-bar-new-york',
#    'name': 'Loopy Doopy Rooftop Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MyBnHGL0Qt9de2uhywUETw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/loopy-doopy-rooftop-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 663,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.715, 'longitude': -74.0158},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '102 N End Ave',
#     'address2': '',
#     'address3': 'Conrad New York Hotel',
#     'city': 'New York',
#     'zip_code': '10282',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 N End Ave',
#      'Conrad New York Hotel',
#      'New York, NY 10282']},
#    'phone': '+16467694250',
#    'display_phone': '(646) 769-4250',
#    'distance': 2087.045438950315},
#   {'id': 'X0f9UYHoE4OxnuUq801vMg',
#    'alias': 'the-upstairs-at-66-new-york',
#    'name': 'The Upstairs at 66',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rAFkogN1Jpl-stxKwtep4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-upstairs-at-66-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'arcades', 'title': 'Arcades'},
#     {'alias': 'speakeasies', 'title': 'Speakeasies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.70418, 'longitude': -74.01048},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '46 Stone St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['46 Stone St', 'New York, NY 10004']},
#    'phone': '+12129431602',
#    'display_phone': '(212) 943-1602',
#    'distance': 1372.1057452096138},
#   {'id': 'nm5rcWNmfevNXLNQAITi5w',
#    'alias': 'clinton-hall-new-york',
#    'name': 'Clinton Hall',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jkOeBmGbclLyY3zbOa7COw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clinton-hall-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 700,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70803, 'longitude': -74.014869},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '90 Washington St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10006',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90 Washington St', 'New York, NY 10006']},
#    'phone': '+12123636000',
#    'display_phone': '(212) 363-6000',
#    'distance': 1758.0354661858244},
#   {'id': 'kLxfxcs8DPVjeOt9jvPwrw',
#    'alias': 'doris-brooklyn',
#    'name': 'Doris',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Vp9XeoT94CLEyURto22Nag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doris-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 98,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68121, 'longitude': -73.957436},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1088 Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1088 Fulton St', 'Brooklyn, NY 11238']},
#    'phone': '+13472403350',
#    'display_phone': '(347) 240-3350',
#    'distance': 4113.190208978372},
#   {'id': 'H1QphdrrsaB472y9HXi2Ow',
#    'alias': 'death-and-co-new-york-3',
#    'name': 'Death & Co',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7xJdaitJgW5TWYr8TpEfyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/death-and-co-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1544,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72589, 'longitude': -73.9847},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '433 E 6th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['433 E 6th St', 'New York, NY 10009']},
#    'phone': '+12123880882',
#    'display_phone': '(212) 388-0882',
#    'distance': 2417.5799718139488},
#   {'id': '1tKMSbOT2zDIRsDvLbtkhg',
#    'alias': 'happy-be-new-york',
#    'name': 'Happy Be',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4UaW2MQRk9pCp24QPeDSAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/happy-be-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7182107, 'longitude': -74.0021064},
#    'transactions': [],
#    'location': {'address1': '26 Cortlandt Aly',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 Cortlandt Aly', 'New York, NY 10013']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1551.3820300067223},
#   {'id': 'jp1qR5SfYEhiPTDjstCnOA',
#    'alias': 'seven-bridges-brooklyn',
#    'name': 'Seven Bridges',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ibIUY6Htb-35ZSx0bc8zuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seven-bridges-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67626, 'longitude': -73.98356},
#    'transactions': [],
#    'location': {'address1': '249 4th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['249 4th Ave', 'Brooklyn, NY 11215']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3380.962060656512},
#   {'id': 'VYHY4LbrRWZCoZzW25zynQ',
#    'alias': 'brass-monkey-new-york',
#    'name': 'Brass Monkey',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8gDtValfW4bAX1i0g3VPxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brass-monkey-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 864,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7406584244867,
#     'longitude': -74.0085168948392},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '55 Little W 12th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Little W 12th St', 'New York, NY 10014']},
#    'phone': '+12126756686',
#    'display_phone': '(212) 675-6686',
#    'distance': 4094.9248696291465},
#   {'id': 'sul_ihulQ5VUPNbk9liWqA',
#    'alias': 'cantina-rooftop-new-york-6',
#    'name': 'Cantina Rooftop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_IeeOJChwW3fEuRRMRkCMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cantina-rooftop-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1135,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.765101, 'longitude': -73.996046},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '605 W 48th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['605 W 48th St', 'New York, NY 10036']},
#    'phone': '+12129571700',
#    'display_phone': '(212) 957-1700',
#    'distance': 6635.096010126041},
#   {'id': 'bW3mY-voyav37nU0uaLmNQ',
#    'alias': 'dante-new-york',
#    'name': 'Dante',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/828zxxk4lED3Cmh34oZdyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dante-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 434,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72879, 'longitude': -74.00165},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '79-81 Macdougal St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79-81 Macdougal St', 'New York, NY 10012']},
#    'phone': '+12129825275',
#    'display_phone': '(212) 982-5275',
#    'distance': 2678.723212827433},
#   {'id': '5usxLwlQ2rF0UwuOEd3aOQ',
#    'alias': 'dick-and-janes-brooklyn',
#    'name': "Dick and Jane's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hRQaYxLVbBCW7JAGPSI7Qg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dick-and-janes-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 129,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68987, 'longitude': -73.97136},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '266 Adelphi St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['266 Adelphi St', 'Brooklyn, NY 11205']},
#    'phone': '+13477391027',
#    'display_phone': '(347) 739-1027',
#    'distance': 2597.082217167577},
#   {'id': 'j8cKSxr6aQ8qTx23FLyyiA',
#    'alias': 'the-wayland-new-york',
#    'name': 'The Wayland',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/t-SSxxNoTysDN3wVSVREVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wayland-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 503,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7251, 'longitude': -73.9778},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '700 E 9th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['700 E 9th St', 'New York, NY 10009']},
#    'phone': '+12127777022',
#    'display_phone': '(212) 777-7022',
#    'distance': 2587.4936869668145},
#   {'id': 'GiP7os-JQVWuSRoX1BHcpA',
#    'alias': 'mr-fongs-new-york',
#    'name': "Mr Fong's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/D55ksuowTsJb0q4RBVZhqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-fongs-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 82,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7122732860015,
#     'longitude': -73.9942900257959},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '40 Market St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40 Market St', 'New York, NY 10002']},
#    'phone': '+16469644540',
#    'display_phone': '(646) 964-4540',
#    'distance': 759.2850393436906},
#   {'id': '4LoroCI3VtQ17dyQa75-Rg',
#    'alias': 'the-warren-new-york',
#    'name': 'The Warren',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qJGtQFPKUJ3ZgBcBGBqcgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-warren-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 246,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7331, 'longitude': -74.0067},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '131 Christopher St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['131 Christopher St', 'New York, NY 10014']},
#    'phone': '+12122431311',
#    'display_phone': '(212) 243-1311',
#    'distance': 3252.281013226276},
#   {'id': 'huOYFLpe3EQKFeDVoxk6Hw',
#    'alias': 'the-happiest-hour-new-york',
#    'name': 'The Happiest Hour',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/URma6Y5n8vYLhA3iiwR6RA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-happiest-hour-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 420,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.734883, 'longitude': -73.999742},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '121 W 10th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['121 W 10th St', 'New York, NY 10011']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3305.4194696004856},
#   {'id': '6qnWAPjJ7UER4QLCtotyBw',
#    'alias': 'amor-y-amargo-new-york',
#    'name': 'Amor y Amargo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/H1J43_EOPxUg7N_B-Qgc_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amor-y-amargo-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 474,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'vermouthbars', 'title': 'Vermouth Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72572, 'longitude': -73.98428},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '443 E 6th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['443 E 6th St', 'New York, NY 10009']},
#    'phone': '+18333284588',
#    'display_phone': '(833) 328-4588',
#    'distance': 2408.323481784112},
#   {'id': 'PszZvrDqzgPpl6SQuk3K9Q',
#    'alias': 'endswell-bar-and-bistro-brooklyn',
#    'name': 'Endswell Bar & Bistro',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rk6NmeZR7DZLcRm1JPv8vA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/endswell-bar-and-bistro-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 76,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68618, 'longitude': -73.97377},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '773 Fulton St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['773 Fulton St', 'Brooklyn, NY 11217']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2754.1920511788758},
#   {'id': 'fmG6BTunLXI2cN61NuLHiw',
#    'alias': 'ophelia-new-york',
#    'name': 'Ophelia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yfADtmiKu7PrWZE_6a2V6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ophelia-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 191,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75319, 'longitude': -73.96598},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '3 Mitchell Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3 Mitchell Pl', 'New York, NY 10017']},
#    'phone': '+12129804796',
#    'display_phone': '(212) 980-4796',
#    'distance': 5832.52913343281},
#   {'id': 'RBwPxrKQESBdXuWELAD-YA',
#    'alias': 'grand-republic-cocktail-club-brooklyn-2',
#    'name': 'grand republic cocktail club',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/v8TvPH1m7sMocDjqtyaQKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grand-republic-cocktail-club-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7297031651375,
#     'longitude': -73.9598640528719},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '19 Greenpoint Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Greenpoint Ave', 'Brooklyn, NY 11222']},
#    'phone': '+13476893860',
#    'display_phone': '(347) 689-3860',
#    'distance': 3961.745018462879},
#   {'id': 'bfwpOyOo9G6MKYHZaMyxfQ',
#    'alias': 'cloudm-rooftop-bar-new-york',
#    'name': 'CloudM Rooftop Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4r-y7DZdAL0OxmtWjaAbQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cloudm-rooftop-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76168, 'longitude': -73.98488},
#    'transactions': [],
#    'location': {'address1': '218 W 50th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['218 W 50th St', 'New York, NY 10019']},
#    'phone': '+12124613638',
#    'display_phone': '(212) 461-3638',
#    'distance': 6292.310755822187},
#   {'id': 'zyxI5ko5Dpkqi9q5oSGa9w',
#    'alias': 'pilot-brooklyn',
#    'name': 'Pilot',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hNSXtVezk05tsj_Y8GxHmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pilot-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 258,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.696432423661,
#     'longitude': -73.9890010861378},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Pier 6 Brooklyn Bridge Park',
#     'address2': '',
#     'address3': 'Brooklyn Bridge Park',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Pier 6 Brooklyn Bridge Park',
#      'Brooklyn Bridge Park',
#      'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1495.270613516155},
#   {'id': 'K3Pol2TudEUXgjWeABHeGA',
#    'alias': 'maiden-korea-new-york',
#    'name': 'Maiden Korea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/S1kNy12pZm0tEbTKRGKgog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maiden-korea-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74712996071734,
#     'longitude': -73.98573998361826},
#    'transactions': [],
#    'location': {'address1': '316 5th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['316 5th Ave', 'New York, NY 10001']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4690.869452686711},
#   {'id': '89XYJZSPKt-dqjE1zyTIzQ',
#    'alias': 'bathtub-gin-new-york',
#    'name': 'Bathtub Gin',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UW01ezUUO__3vtqjsBDPXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bathtub-gin-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1009,
#    'categories': [{'alias': 'speakeasies', 'title': 'Speakeasies'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74364, 'longitude': -74.00319},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '132 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['132 9th Ave', 'New York, NY 10011']},
#    'phone': '+16465591671',
#    'display_phone': '(646) 559-1671',
#    'distance': 4312.766572685916},
#   {'id': 'wfGFM8zvdw9Zs-jxsTdjww',
#    'alias': 'soju-haus-new-york',
#    'name': 'Soju Haus',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vugjGOJ4hHXOL1E5wybyEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soju-haus-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 577,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7468603, 'longitude': -73.9851724},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '315 5th Ave',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['315 5th Ave', 'Fl 2', 'New York, NY 10016']},
#    'phone': '+12122132177',
#    'display_phone': '(212) 213-2177',
#    'distance': 4668.8779662572515},
#   {'id': 'a8CdwY4uFIP4nXkl4V5EEg',
#    'alias': 'little-branch-new-york',
#    'name': 'Little Branch',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zNCwpssakKdLp6Q1XbqqZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-branch-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1042,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'speakeasies', 'title': 'Speakeasies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73013, 'longitude': -74.005046},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '22 7th Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12129294360',
#    'display_phone': '(212) 929-4360',
#    'distance': 2890.58682925155},
#   {'id': '4aF0F8w7yXX9o5_QFky_ig',
#    'alias': 'celestine-brooklyn',
#    'name': 'Celestine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/p98BTWB9IIb4RQyDQw13ZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/celestine-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 235,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.704676, 'longitude': -73.987975},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '1 John St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 John St', 'Brooklyn, NY 11201']},
#    'phone': '+17185225356',
#    'display_phone': '(718) 522-5356',
#    'distance': 539.4069533813018},
#   {'id': 'qLYloGaI-4OmLbNnr_wrGA',
#    'alias': 'castell-rooftop-lounge-new-york',
#    'name': 'Castell Rooftop Lounge',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZElTdN9KeFib0zOtHxcfhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/castell-rooftop-lounge-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 148,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75558, 'longitude': -73.99012},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '260 W 40th St',
#     'address2': 'Fl 21',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['260 W 40th St', 'Fl 21', 'New York, NY 10018']},
#    'phone': '+19292843761',
#    'display_phone': '(929) 284-3761',
#    'distance': 5573.02130762801},
#   {'id': 'vyRQGK3qABg1HSWNpMbmtg',
#    'alias': 'the-cabinet-new-york-2',
#    'name': 'The Cabinet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CFsdsoH6wsgOwlJlifndkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cabinet-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72546, 'longitude': -73.97816},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '649 East 9th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['649 East 9th St', 'New York, NY 10009']},
#    'phone': '+19177407492',
#    'display_phone': '(917) 740-7492',
#    'distance': 2613.6484829687765},
#   {'id': '3Uzy1yp1SXq3FG-i2hEcyA',
#    'alias': 'luckydog-brooklyn',
#    'name': 'Luckydog',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tPXRhp8RMZ6hKopg9XeTRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luckydog-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 305,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71348, 'longitude': -73.96166},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '303 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['303 Bedford Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13472944971',
#    'display_phone': '(347) 294-4971',
#    'distance': 2891.1067556439434},
#   {'id': 'VLGmFHE4s0Sfu0piMVQa1Q',
#    'alias': 'hold-fast-kitchen-and-spirits-new-york',
#    'name': 'Hold Fast Kitchen & Spirits',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2a8BP3w4_pgEn8Y0E6TBow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hold-fast-kitchen-and-spirits-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 420,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.76064, 'longitude': -73.99023},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '364 W 46th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['364 W 46th St', 'New York, NY 10036']},
#    'phone': '+19172616691',
#    'display_phone': '(917) 261-6691',
#    'distance': 6140.252693485879},
#   {'id': 'pf5JBOPUBHbY6F4s15lk6g',
#    'alias': 'strangelove-new-york',
#    'name': 'Strangelove',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Y7CsCkCJSJnNkE1oIcPeIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/strangelove-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7574, 'longitude': -73.96809},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '229 E 53rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['229 E 53rd St', 'New York, NY 10022']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6180.280148388789},
#   {'id': 'SBkebBPuX2mRUQ9VaQ91NQ',
#    'alias': 'boobie-trap-brooklyn',
#    'name': 'Boobie Trap',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yAR-ZoHYP5p6s4xjGHOMOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boobie-trap-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 273,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7001991, 'longitude': -73.9160156},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '308 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['308 Bleecker St', 'Brooklyn, NY 11237']},
#    'phone': '+13472409105',
#    'display_phone': '(347) 240-9105',
#    'distance': 6623.465008412954},
#   {'id': 'TE87BLxClCcIg62i0xVgMg',
#    'alias': 'moot-bar-brooklyn-2',
#    'name': 'Moot Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8mVDG0Fz5ki5arXYNyW2aQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moot-bar-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6941986, 'longitude': -73.9609604},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '579 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['579 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17186383982',
#    'display_phone': '(718) 638-3982',
#    'distance': 3074.2131554439516},
#   {'id': 'dYyd66STjtwdO9_02SgLDg',
#    'alias': 'congress-bar-brooklyn',
#    'name': 'Congress Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/68dOYCxhDdUVGBE7k59WhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/congress-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 71,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68694, 'longitude': -73.99383},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '208 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['208 Court St', 'Brooklyn, NY 11201']},
#    'phone': '+13479160802',
#    'display_phone': '(347) 916-0802',
#    'distance': 2059.6197925566516},
#   {'id': '28q-EaDlKgYNeaF7-LXXqg',
#    'alias': 'lavender-lake-brooklyn',
#    'name': 'Lavender Lake',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xc720iC989jRcGHjWhMaqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lavender-lake-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 279,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6786075, 'longitude': -73.9901923},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '383 Carroll St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['383 Carroll St', 'Brooklyn, NY 11231']},
#    'phone': '+13477992154',
#    'display_phone': '(347) 799-2154',
#    'distance': 3004.138276609909},
#   {'id': 'N5UY113nNpeKdLPv0cbMjQ',
#    'alias': 'the-wild-son-new-york',
#    'name': 'The Wild Son',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bKbzwnDOl26D3aVzh-lj0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wild-son-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 535,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.727424, 'longitude': -73.985201},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '132 First Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['132 First Ave', 'New York, NY 10009']},
#    'phone': '+12127277900',
#    'display_phone': '(212) 727-7900',
#    'distance': 2560.9007972575373},
#   {'id': 'VBjYIelQBlCK889IBVrWzQ',
#    'alias': 'patent-pending-new-york-2',
#    'name': 'Patent Pending',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/88c_USXkj9pbxPPMT_ngjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patent-pending-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 237,
#    'categories': [{'alias': 'speakeasies', 'title': 'Speakeasies'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74526, 'longitude': -73.99032},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '49 W 27th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['49 W 27th St', 'New York, NY 10001']},
#    'phone': '+12126894002',
#    'display_phone': '(212) 689-4002',
#    'distance': 4446.517224145578},
#   {'id': 'XO3yD87rTPz9o6Dy9qRaJg',
#    'alias': 'the-spaniard-new-york',
#    'name': 'The Spaniard',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C7TTSwl8qtsN3YJbKvAS9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-spaniard-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 288,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'whiskeybars', 'title': 'Whiskey Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7327497, 'longitude': -74.0021829},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '190 W 4th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['190 W 4th St', 'New York, NY 10014']},
#    'phone': '+12129181986',
#    'display_phone': '(212) 918-1986',
#    'distance': 3108.1109361713225},
#   {'id': 'LSTcQPMmoSdd68zur-aNdw',
#    'alias': 'itaewon-pocha-new-york',
#    'name': 'Itaewon Pocha',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/j2x3unNX8v8AExvD8wHzIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/itaewon-pocha-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 146,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7475125111924,
#     'longitude': -73.9867554408843},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '28 W 32nd St',
#     'address2': 'Fl 2',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 W 32nd St', 'Fl 2', 'New York, NY 10001']},
#    'phone': '+12129672228',
#    'display_phone': '(212) 967-2228',
#    'distance': 4720.632711850733},
#   {'id': 'kt77PF-PfvsY5aGv0UGeNA',
#    'alias': 'juke-bar-new-york',
#    'name': 'Juke Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/O-SbGJL2M4L3yOHxJ0an4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/juke-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 267,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.731098, 'longitude': -73.985611},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '196 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['196 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12122287464',
#    'display_phone': '(212) 228-7464',
#    'distance': 2944.8491512050305},
#   {'id': 'DGhWO1sUWydVeR5j5ZZaMw',
#    'alias': 'la-grande-boucherie-new-york-2',
#    'name': 'La Grande Boucherie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/b9URGcuuhnLq7J-__pHIng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-grande-boucherie-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 519,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7626274, 'longitude': -73.98084109999999},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '145 W 53rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['145 W 53rd St', 'New York, NY 10019']},
#    'phone': '+12125107714',
#    'display_phone': '(212) 510-7714',
#    'distance': 6458.633757596852},
#   {'id': 'WqfWUXT66Q6SaoT9x2adzw',
#    'alias': 'porchlight-new-york',
#    'name': 'Porchlight',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oUCab_6xY2Agfzb4ki3eyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/porchlight-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 227,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7518044, 'longitude': -74.0050735},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '271 11th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['271 11th Ave', 'New York, NY 10001']},
#    'phone': '+12129816188',
#    'display_phone': '(212) 981-6188',
#    'distance': 5246.010158185858},
#   {'id': '5BcgRq8wUtM3_Ds13RyD-A',
#    'alias': 'bar-donna-new-york',
#    'name': 'Bar Donna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/B5OC4xaCAvO6o47SESk-cg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-donna-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.735967, 'longitude': -73.979625},
#    'transactions': [],
#    'location': {'address1': '365 1st Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['365 1st Ave', 'New York, NY 10010']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3611.320613062785},
#   {'id': '6ZIGSGKlc16hR9JUGTYjNA',
#    'alias': 'the-long-island-bar-new-york',
#    'name': 'The Long Island Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WNdmTxHSkX2kJNcvI8dqjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-long-island-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 154,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6906586, 'longitude': -73.9964447},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '110 Atlantic Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['110 Atlantic Ave', 'New York, NY 11201']},
#    'phone': '+17186258908',
#    'display_phone': '(718) 625-8908',
#    'distance': 1663.8351560371543}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#         Restaurant           Type Price Rating              Address  \
# 0    Four Five Six           Bars    $$    4.5    199 Richardson St
# 1                V  Cocktail Bars                    281 Park Ave S
# 2  VAULT Manhattan        Lounges                     410 W 16th St
# 3        Thyme Bar  Cocktail Bars               20 W 23rd St Cellar
# 4  Hidden Lane Bar           Bars                     129 E 15th St
#
#          Lat        Lng                                                url  \
# 0  40.719181 -73.943149  https://www.yelp.com/biz/four-five-six-brookly...
# 1  40.739248 -73.986722
# 2  40.742331 -74.004903
# 3  40.741672 -73.990594
# 4  40.734579 -73.987684
#
#                        ID
# 0  HuU2IGPfQ23FTOGDQg0Ieg
# 1
# 2
# 3
# 4

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"bar","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': 'TI5dWiHdFn55WQDmvffu0Q',
#    'alias': 'the-lingerie-shoppe-aka-astoria-s-secret-astoria',
#    'name': 'The Lingerie Shoppe aka Astoria’s Secret',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RE9r2LYnrlKE6i94uZjbkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lingerie-shoppe-aka-astoria-s-secret-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'speakeasies', 'title': 'Speakeasies'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76406, 'longitude': -73.9145},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '28-53 Steinway St',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28-53 Steinway St', 'Astoria, NY 11103']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9367.381575917318},
#   {'id': 'MtcgW0RCTm44PuA-HAq49g',
#    'alias': 'santiagos-beer-garden-new-york',
#    'name': "Santiago's Beer Garden",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bNEBjbsoftKl58-3b2aB4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/santiagos-beer-garden-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 521,
#    'categories': [{'alias': 'dominican', 'title': 'Dominican'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.79849, 'longitude': -73.93382},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '2337 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10035',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2337 1st Ave', 'New York, NY 10035']},
#    'phone': '+12129206165',
#    'display_phone': '(212) 920-6165',
#    'distance': 11533.550321066834},
#   {'id': 'P9x0uX9nmPCph1mWM3k4vg',
#    'alias': 'barely-disfigured-brooklyn-3',
#    'name': 'Barely Disfigured',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y_dgfZIDct0Mbk-AQOFz9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barely-disfigured-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 105,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68309, 'longitude': -73.9928},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '257 Smith St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['257 Smith St', 'Brooklyn, NY 11231']},
#    'phone': '+17188585646',
#    'display_phone': '(718) 858-5646',
#    'distance': 2488.952828636363},
#   {'id': 'cs6FZeHRFOO_QRpEQ5vgAQ',
#    'alias': 'oldies-brooklyn-2',
#    'name': 'Oldies',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Oe2VaX3Vzwwt7ffOWyR94A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oldies-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.656173689036,
#     'longitude': -74.0069703165711},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '269 36th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11232',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['269 36th St', 'Brooklyn, NY 11232']},
#    'phone': '+13475844577',
#    'display_phone': '(347) 584-4577',
#    'distance': 5582.014834411873},
#   {'id': 'vkQSMwAf5yqDw9HfEQYgzw',
#    'alias': 'the-flower-shop-new-york-2',
#    'name': 'The Flower Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/raG7FHaFJ2ZGvBK2fG2TJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-flower-shop-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 129,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71807, 'longitude': -73.99213},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '107 Eldridge St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['107 Eldridge St', 'New York, NY 10002']},
#    'phone': '+12122574072',
#    'display_phone': '(212) 257-4072',
#    'distance': 1417.2568929322106},
#   {'id': '1VFAJtFoeTSwGCXVWBQEIg',
#    'alias': 'public-records-brooklyn',
#    'name': 'Public Records',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SDK09K6QabQ1hmIOJKM2EA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/public-records-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6821609392503,
#     'longitude': -73.986539662892},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '233 Butler St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['233 Butler St', 'Brooklyn, NY 11217']},
#    'phone': '+13475294869',
#    'display_phone': '(347) 529-4869',
#    'distance': 2670.2991960610425},
#   {'id': '7szsAtxOkGJ2ady3Qx7v4w',
#    'alias': 'the-hideaway-seaport-new-york',
#    'name': 'The Hideaway Seaport',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lRm2xYEBIcNIiDd5MDOAGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hideaway-seaport-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 109,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7080634, 'longitude': -74.002083},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '22 Peck Slip',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 Peck Slip', 'New York, NY 10038']},
#    'phone': '+12123852222',
#    'display_phone': '(212) 385-2222',
#    'distance': 718.278907947431},
#   {'id': 'YLneWqE-Mixh9BCwnS5QBA',
#    'alias': 'mood-ring-brooklyn-2',
#    'name': 'Mood Ring',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XlRyygM0kPGYHyFw4EifLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mood-ring-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'gaybars', 'title': 'Gay Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69779, 'longitude': -73.92698},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1260 Myrtle Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1260 Myrtle Ave', 'Brooklyn, NY 11221']},
#    'phone': '+19178181738',
#    'display_phone': '(917) 818-1738',
#    'distance': 5742.6324320868},
#   {'id': 'gNA_ZxAd5xvBuqc0AIfheA',
#    'alias': 'the-dancer-new-york',
#    'name': 'The Dancer',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mHHBzlZCWWJcis6t_r-QwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dancer-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.714, 'longitude': -73.98705},
#    'transactions': [],
#    'location': {'address1': '202 Clinton St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['202 Clinton St', 'New York, NY 10002']},
#    'phone': '+16468761174',
#    'display_phone': '(646) 876-1174',
#    'distance': 1141.717543577916},
#   {'id': 'EDFfoyXTsHPBW6mNWLVoig',
#    'alias': 'local-138-new-york',
#    'name': 'Local 138',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4wcOIcvHq6xXm3lvOVhfbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/local-138-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 246,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72191, 'longitude': -73.98841},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '181 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['181 Orchard St', 'New York, NY 10002']},
#    'phone': '+12124770280',
#    'display_phone': '(212) 477-0280',
#    'distance': 1900.054346823651},
#   {'id': '_7-wGQfXNgbr-WDIMzUvZw',
#    'alias': 'the-moonlight-mile-brooklyn',
#    'name': 'The Moonlight Mile',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZSTixp1E1RqHRKuQNYPl0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-moonlight-mile-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'whiskeybars', 'title': 'Whiskey Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7321141, 'longitude': -73.9578424},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '200 Franklin St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 Franklin St', 'Brooklyn, NY 11222']},
#    'phone': '+17183893904',
#    'display_phone': '(718) 389-3904',
#    'distance': 4269.778060254642},
#   {'id': 'SjG7CnTIuUBIo9T4BThkGQ',
#    'alias': 'employees-only-new-york',
#    'name': 'Employees Only',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DYmz8eh42wWGxw4xEYpL8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/employees-only-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1482,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73343, 'longitude': -74.00617},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '510 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['510 Hudson St', 'New York, NY 10014']},
#    'phone': '+12122423021',
#    'display_phone': '(212) 242-3021',
#    'distance': 3268.7723308088894},
#   {'id': '83Lyvofsx-H2Q0ug0z6dKg',
#    'alias': 'the-little-shop-new-york',
#    'name': 'The Little Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m29KXPfmSQgkl6i5Ujzemg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-little-shop-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'convenience', 'title': 'Convenience Stores'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.708333, 'longitude': -74.000908},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '252 Front St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['252 Front St', 'New York, NY 10038']},
#    'phone': '+16463604650',
#    'display_phone': '(646) 360-4650',
#    'distance': 649.2103077986898},
#   {'id': 'lhEzTykkqFz92Vq2uILtyw',
#    'alias': 'the-wren-new-york',
#    'name': 'The Wren',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GU7pSWigy_h52g4Qm54_Tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wren-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 573,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7263350655, 'longitude': -73.9920476876},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '344 Bowery',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['344 Bowery', 'New York, NY 10012']},
#    'phone': '+12123880148',
#    'display_phone': '(212) 388-0148',
#    'distance': 2330.5786633327825},
#   {'id': 'XyulGZ5P9VhtNcK7zN2R9g',
#    'alias': 'cardiff-giant-brooklyn',
#    'name': 'Cardiff Giant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zH6xrPI9T_YpxuFBCH9Oyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cardiff-giant-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#     {'alias': 'cideries', 'title': 'Cideries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69324, 'longitude': -73.96923},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '415 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['415 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+19293377873',
#    'display_phone': '(929) 337-7873',
#    'distance': 2510.0853060372096},
#   {'id': '2VxD5TQH9MZsbJX3JlEZ6g',
#    'alias': 'dollys-swing-and-dive-brooklyn',
#    'name': "Dolly's Swing & Dive",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3tjWWDa68sj55I6SWXQXZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dollys-swing-and-dive-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72073, 'longitude': -73.96111},
#    'transactions': ['delivery'],
#    'location': {'address1': '101 Kent Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['101 Kent Ave', 'Brooklyn, NY 11249']},
#    'phone': '+19044145095',
#    'display_phone': '(904) 414-5095',
#    'distance': 3272.7523867489413},
#   {'id': '_CiiMsYT0W6LpsnLCiYAFA',
#    'alias': 'joyface-new-york',
#    'name': 'Joyface',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_n3QojciRHSBhPN1Not9SA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joyface-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 56,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72394, 'longitude': -73.97878},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '104 Avenue C',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['104 Avenue C', 'New York, NY 10009']},
#    'phone': '+19172612166',
#    'display_phone': '(917) 261-2166',
#    'distance': 2430.5887290972205},
#   {'id': 'TDyu1-6XF7r1jc13j7nDNA',
#    'alias': 'tørst-brooklyn',
#    'name': 'TØRST',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/f0oWXjJQj6XifVzRUQ_Lcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/t%C3%B8rst-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 409,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7233949, 'longitude': -73.950856},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '615 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['615 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183896034',
#    'display_phone': '(718) 389-6034',
#    'distance': 4169.732367493427},
#   {'id': 'MNNpsRXe7Wt5m3Jla9Wk0w',
#    'alias': 'the-alcove-sunnyside',
#    'name': 'The Alcove',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/peNqHPI1kUUKbvTse-xIxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-alcove-sunnyside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 953,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7459065, 'longitude': -73.915103},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '41-11 49th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41-11 49th St', 'Sunnyside, NY 11104']},
#    'phone': '+13478134159',
#    'display_phone': '(347) 813-4159',
#    'distance': 8045.510107980188},
#   {'id': 'ajdv6_mWIkAXzn71CUdpkw',
#    'alias': 'copper-and-oak-new-york-5',
#    'name': 'Copper & Oak',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r0q_bdFul0N2ZRV02Zw_xA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/copper-and-oak-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 103,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.721065, 'longitude': -73.98986},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '157 Allen St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['157 Allen St', 'New York, NY 10002']},
#    'phone': '+12124605546',
#    'display_phone': '(212) 460-5546',
#    'distance': 1776.9624145912003},
#   {'id': 'nnSyjwIkhbJIBMiBtch_BQ',
#    'alias': 'kimoto-rooftop-brooklyn-5',
#    'name': 'Kimoto Rooftop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6_-ZWMIayaZfxnj19mCZQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kimoto-rooftop-brooklyn-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 599,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'danceclubs', 'title': 'Dance Clubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6915156530047, 'longitude': -73.9846554},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '228 Duffield St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 Duffield St', 'Brooklyn, NY 11201']},
#    'phone': '+17188588940',
#    'display_phone': '(718) 858-8940',
#    'distance': 1749.027674612803},
#   {'id': 'uq5rHbGtBFwCwPkokIkKvQ',
#    'alias': 'jojo-new-york-3',
#    'name': 'JoJo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tzYjNDXmSZVorVfwfN25gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jojo-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 173,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76506, 'longitude': -73.96571},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '160 E 64th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['160 E 64th St', 'New York, NY 10065']},
#    'phone': '+12122235656',
#    'display_phone': '(212) 223-5656',
#    'distance': 7054.833766162339},
#   {'id': 'c3Ww3pgeHjBi3ctkeUWrjQ',
#    'alias': 'whiskey-tavern-new-york',
#    'name': 'Whiskey Tavern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IdW7hYA-KPWjEU28pS3Mrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/whiskey-tavern-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 788,
#    'categories': [{'alias': 'whiskeybars', 'title': 'Whiskey Bars'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71646, 'longitude': -73.99969},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '79 Baxter St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79 Baxter St', 'New York, NY 10013']},
#    'phone': '+12123749119',
#    'display_phone': '(212) 374-9119',
#    'distance': 1309.0498086988187},
#   {'id': 'bkIMbvXOcztDVz8bpyhMzQ',
#    'alias': 'the-dead-poet-new-york',
#    'name': 'The Dead Poet',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fW9WcVHznuZMT-_x___jAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dead-poet-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 442,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78499, 'longitude': -73.97735},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '450 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['450 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12125955670',
#    'display_phone': '(212) 595-5670',
#    'distance': 8960.113892240845},
#   {'id': 'dJoWkpVxWcvdqNRo7w622w',
#    'alias': 'the-garret-new-york',
#    'name': 'The Garret',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AVg7ooVMB-pzRp7syKq78Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-garret-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 268,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73238, 'longitude': -74.0038457},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '296 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['296 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12126756157',
#    'display_phone': '(212) 675-6157',
#    'distance': 3101.357015522796},
#   {'id': 'f7g3GhoQs9nQVTJEL2p48Q',
#    'alias': 'gran-electrica-brooklyn-3',
#    'name': 'Gran Electrica',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vltMa2sCZfwlSMNxMtFd4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gran-electrica-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 504,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7027, 'longitude': -73.99314},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '5 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17188522700',
#    'display_phone': '(718) 852-2700',
#    'distance': 321.6955097734123},
#   {'id': 'sMQv00tw4hR654VC5d63CA',
#    'alias': 'carmelos-brooklyn',
#    'name': "Carmelo's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/c4-X6jHwXdP--k0UP7_2CA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carmelos-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70282, 'longitude': -73.92054},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1544 Dekalb Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1544 Dekalb Ave', 'Brooklyn, NY 11237']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6230.1298992896955},
#   {'id': 'C7s1ohdoF8UtToowLsdIsQ',
#    'alias': 'cobble-fish-new-york-2',
#    'name': 'Cobble Fish',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/btDfqqmCTDsd43Udnreuaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cobble-fish-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70530194592761,
#     'longitude': -74.00257774322735},
#    'transactions': [],
#    'location': {'address1': '89 South St',
#     'address2': 'Pier 16',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['89 South St', 'Pier 16', 'New York, NY 10038']},
#    'phone': '+12122102997',
#    'display_phone': '(212) 210-2997',
#    'distance': 698.5153237996998},
#   {'id': 'MyQV4i518ZO4CLudtR8gLA',
#    'alias': 'the-bar-room-new-york',
#    'name': 'The Bar Room',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Cqic-DpE3NCrBpEAnIDKPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bar-room-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 538,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.763409, 'longitude': -73.968449},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '117 E 60th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['117 E 60th St', 'New York, NY 10022']},
#    'phone': '+12125615523',
#    'display_phone': '(212) 561-5523',
#    'distance': 6803.218295278219},
#   {'id': 'NXdEbUpVdtE5VwlqFOXliQ',
#    'alias': 'sandbar-rooftop-new-york',
#    'name': 'Sandbar Rooftop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/btBMVHvY02cNkfnf550H1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sandbar-rooftop-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 72,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.745537, 'longitude': -73.993771},
#    'transactions': ['delivery'],
#    'location': {'address1': '152 W 26th St',
#     'address2': '',
#     'address3': 'Hilton Fashion District Hotel',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['152 W 26th St',
#      'Hilton Fashion District Hotel',
#      'New York, NY 10001']},
#    'phone': '+12124340445',
#    'display_phone': '(212) 434-0445',
#    'distance': 4458.254317426004},
#   {'id': 'xGDGHg7G0Z6xvUo4xVXXVQ',
#    'alias': 'the-emerson-brooklyn',
#    'name': 'The Emerson',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2nwHRb56sWtBh01AvyNEdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-emerson-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 79,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69414, 'longitude': -73.961817},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '561 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['561 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+13477631310',
#    'display_phone': '(347) 763-1310',
#    'distance': 3008.6024880760965},
#   {'id': 'beSULYnLPVj2HAOCWmvpjw',
#    'alias': 'the-crown-new-york-2',
#    'name': 'The Crown',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cO5WFWFKdIBlzWf3iHTzCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-crown-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 179,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.71599, 'longitude': -73.99683},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '50 Bowery',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['50 Bowery', 'New York, NY 10013']},
#    'phone': '+16466308057',
#    'display_phone': '(646) 630-8057',
#    'distance': 1202.705246954195},
#   {'id': 'nGyffNA23K4sO08rKB2E5g',
#    'alias': 'goodnight-sonny-new-york-3',
#    'name': 'Goodnight Sonny',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MFiw5153Ysrlsjf9fNf9dA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/goodnight-sonny-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 282,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72768, 'longitude': -73.98502},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '134 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['134 1st Ave', 'New York, NY 10009']},
#    'phone': '+16466923254',
#    'display_phone': '(646) 692-3254',
#    'distance': 2595.0475117274095},
#   {'id': '-9MLyUR2SyI2zXBBvksj3A',
#    'alias': 'jackdaw-new-york-2',
#    'name': 'Jackdaw',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Lpc--kNUKbLFw2AXvOs5jg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jackdaw-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 121,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73183, 'longitude': -73.98557},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '213 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['213 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12125079333',
#    'display_phone': '(212) 507-9333',
#    'distance': 3027.98287897186},
#   {'id': 'Gxvx-U8i5zja38WKUaiuqA',
#    'alias': 'blue-quarter-new-york',
#    'name': 'Blue Quarter',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KerKzRF0g8cdq-Yc7NlNEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-quarter-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72697, 'longitude': -73.98863},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '92 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['92 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12124322232',
#    'display_phone': '(212) 432-2232',
#    'distance': 2437.0919616320148},
#   {'id': 'aOdbXPdCPrckxo_it5xwSA',
#    'alias': 'the-otheroom-new-york-2',
#    'name': 'The Otheroom',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fhx6CAv3BEtzVzizAGhnLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-otheroom-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 298,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.734966, 'longitude': -74.008028},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '143 Perry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['143 Perry St', 'New York, NY 10014']},
#    'phone': '+12126459758',
#    'display_phone': '(212) 645-9758',
#    'distance': 3480.696357214459},
#   {'id': 'ne1sjzU07jRQZSFO0K9l9Q',
#    'alias': '68-jay-st-bar-brooklyn',
#    'name': '68 Jay St Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-h7JkBDpwiZK7O17b-42iA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/68-jay-st-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 95,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.70300059165199,
#     'longitude': -73.9868171822155},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '68 Jay St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['68 Jay St', 'Brooklyn, NY 11201']},
#    'phone': '+17182608207',
#    'display_phone': '(718) 260-8207',
#    'distance': 686.3048868733733},
#   {'id': 'Zcc5Gbnd8nwtE_-uei4Swg',
#    'alias': 'mika-brooklyn',
#    'name': 'Mika',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lO93lgHl_a8lI9lUljYA0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mika-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'poolhalls', 'title': 'Pool Halls'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.705116, 'longitude': -73.931991},
#    'transactions': ['delivery'],
#    'location': {'address1': '25 Thames St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 Thames St', 'Brooklyn, NY 11206']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5251.824667855465},
#   {'id': '9M5OhArH9neG1VTj6CXqSw',
#    'alias': 'pink-metal-brooklyn',
#    'name': 'Pink Metal',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AwuDO3Sq6HlJl4cQ16qjpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pink-metal-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'popuprestaurants', 'title': 'Pop-Up Restaurants'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.707266, 'longitude': -73.9395446},
#    'transactions': ['delivery'],
#    'location': {'address1': '253 Bushwick Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253 Bushwick Ave', 'Brooklyn, NY 11206']},
#    'phone': '+13477991236',
#    'display_phone': '(347) 799-1236',
#    'distance': 4619.341088402071},
#   {'id': 'bn3qRcfBg0YG1-zIR1hscA',
#    'alias': 'drift-in-new-york',
#    'name': 'Drift In',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/umj5VRz2_zFESbiTw4m3Sg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/drift-in-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 80,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7329109, 'longitude': -74.0106435},
#    'transactions': ['delivery'],
#    'location': {'address1': '389 W St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['389 W St', 'New York, NY 10014']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3355.4028107537397},
#   {'id': 'ZNEFXERBvl7i_QQojRoKNQ',
#    'alias': 'flatbush-zombie-house-brooklyn',
#    'name': 'Flatbush Zombie House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sQ1e6agynR6Rf8aGkEr5Zw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flatbush-zombie-house-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 107,
#    'categories': [{'alias': 'tikibars', 'title': 'Tiki Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6550392260637,
#     'longitude': -73.9600387215614},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '734 Flatbush Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11226',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['734 Flatbush Ave', 'Brooklyn, NY 11226']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6305.38613954536},
#   {'id': 'SaYTVG7wHCMDBofHCgXPaA',
#    'alias': 'dutch-freds-new-york-2',
#    'name': 'Dutch Freds',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/F5fSQkZSmWf_JEkcFUpcyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dutch-freds-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1648,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.760835, 'longitude': -73.987823},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '307 W 47th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['307 W 47th St', 'New York, NY 10036']},
#    'phone': '+16469186923',
#    'display_phone': '(646) 918-6923',
#    'distance': 6182.299430087978},
#   {'id': '-JFi2vYrS-CqL44o3fsf1A',
#    'alias': 'w-xyz-bar-brooklyn-2',
#    'name': 'W XYZ Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vRZN0uMn8eDkFvueCtCOAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/w-xyz-bar-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6913942, 'longitude': -73.9844709},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '216 Duffield St',
#     'address2': 'Aloft New York Brooklyn',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['216 Duffield St',
#      'Aloft New York Brooklyn',
#      'Brooklyn, NY 11201']},
#    'phone': '+17182563833',
#    'display_phone': '(718) 256-3833',
#    'distance': 1768.2286281187942},
#   {'id': '3Ic4C60oSH1cV2jknUXSjQ',
#    'alias': 'the-flatiron-room-new-york-3',
#    'name': 'The Flatiron Room',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/A2FfEvW9w7fQCZO0fKR5ZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-flatiron-room-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 821,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'jazzandblues', 'title': 'Jazz & Blues'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74452, 'longitude': -73.99049},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '37 W 26th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37 W 26th St', 'New York, NY 10010']},
#    'phone': '+12127253860',
#    'display_phone': '(212) 725-3860',
#    'distance': 4365.545169612609},
#   {'id': 'vGS5X12NYXCl8NpynlxRuw',
#    'alias': 'oscar-wilde-new-york-2',
#    'name': 'Oscar Wilde',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZSnGxg5BBKVs-Jt4AE8f2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oscar-wilde-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 779,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74514, 'longitude': -73.9900399},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '45 W 27th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 W 27th St', 'New York, NY 10001']},
#    'phone': '+12122133066',
#    'display_phone': '(212) 213-3066',
#    'distance': 4431.997041905199},
#   {'id': 'z5hRX3iJ5Ty_S38iG_WY3Q',
#    'alias': 'tanner-smiths-new-york-2',
#    'name': 'Tanner Smiths',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Cd4oaUWci9sYJbXy3fbqnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tanner-smiths-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1822,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76442, 'longitude': -73.98169},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '204 W 55th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['204 W 55th St', 'New York, NY 10019']},
#    'phone': '+16465902034',
#    'display_phone': '(646) 590-2034',
#    'distance': 6628.69302856469},
#   {'id': 'H8mnryiCI02N00g9vuFDLg',
#    'alias': 'the-library-new-york',
#    'name': 'The Library',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/a95NgrsukXWY47GTJEFrqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-library-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 402,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7226142883301,
#     'longitude': -73.9863433837891},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '7 Ave A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 Ave A', 'New York, NY 10009']},
#    'phone': '+12123751352',
#    'display_phone': '(212) 375-1352',
#    'distance': 2022.6023880642597},
#   {'id': 'rRPuX18uiYLEUGdJ9xQBEQ',
#    'alias': 'zombie-hut-brooklyn',
#    'name': 'Zombie Hut',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ao9MHh0EJ5SA0exEbPwCSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zombie-hut-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 514,
#    'categories': [{'alias': 'tikibars', 'title': 'Tiki Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6825715, 'longitude': -73.993164},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '273 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['273 Smith St', 'Brooklyn, NY 11231']},
#    'phone': '+17188753433',
#    'display_phone': '(718) 875-3433',
#    'distance': 2545.180386210544},
#   {'id': 'RwwUgOdJ6rTF7MSSwujjlQ',
#    'alias': 'library-of-distilled-spirits-new-york',
#    'name': 'Library of Distilled Spirits',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xEJUBCJIHxej1i39Tg-rcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/library-of-distilled-spirits-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 98,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7335489, 'longitude': -73.9901842},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '80 13th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 13th St', 'New York, NY 10003']},
#    'phone': '+16468780396',
#    'display_phone': '(646) 878-0396',
#    'distance': 3144.1507994870053},
#   {'id': 'bpjDo7svAFD10eszaOPQHw',
#    'alias': 'clinton-hall-new-york-13',
#    'name': 'Clinton Hall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0lX58zsHKhM7R9Ey9DAGdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clinton-hall-new-york-13?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 215,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75009, 'longitude': -73.98471},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '16 W 36th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['16 W 36th St', 'New York, NY 10018']},
#    'phone': '+12126950036',
#    'display_phone': '(212) 695-0036',
#    'distance': 5021.331080017711}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                                  Restaurant            Type Price Rating  \
# 0  The Lingerie Shoppe aka Astoria’s Secret     Speakeasies    $$    4.5
# 1                    Santiago's Beer Garden       Dominican    $$    4.5
# 2                         Barely Disfigured   Cocktail Bars    $$    4.5
# 3                                    Oldies   Cocktail Bars    $$    4.5
# 4                           The Flower Shop  American (New)    $$      4
#
#              Address        Lat       Lng  \
# 0  28-53 Steinway St  40.764060 -73.91450
# 1       2337 1st Ave  40.798490 -73.93382
# 2       257 Smith St  40.683090 -73.99280
# 3        269 36th St  40.656174 -74.00697
# 4    107 Eldridge St  40.718070 -73.99213
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/the-lingerie-shoppe-a...  TI5dWiHdFn55WQDmvffu0Q
# 1  https://www.yelp.com/biz/santiagos-beer-garden...  MtcgW0RCTm44PuA-HAq49g
# 2  https://www.yelp.com/biz/barely-disfigured-bro...  P9x0uX9nmPCph1mWM3k4vg
# 3  https://www.yelp.com/biz/oldies-brooklyn-2?adj...  cs6FZeHRFOO_QRpEQ5vgAQ
# 4  https://www.yelp.com/biz/the-flower-shop-new-y...  vkQSMwAf5yqDw9HfEQYgzw

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"bar","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [{'id': '5MpWHGQ6Qc-M4q1KL_nioA',
#    'alias': 'bar-b-new-york',
#    'name': 'Bar B',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rP6Gfe33cpkYe549tj_2BQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-b-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 187,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7395804, 'longitude': -73.999118},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '84 7th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['84 7th Ave', 'New York, NY 10011']},
#    'phone': '+12122291888',
#    'display_phone': '(212) 229-1888',
#    'distance': 3817.3548091487633},
#   {'id': 'ZJ5kDHCo2BgLkB4uwpTZfw',
#    'alias': 'cookies-brooklyn-2',
#    'name': 'Cookies',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/a8wMUiRiSSWAjtkGF7OxRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cookies-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69485, 'longitude': -73.95285},
#    'transactions': ['delivery'],
#    'location': {'address1': '748 Myrtle Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['748 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3685.665077643447},
#   {'id': 'l8um5IoiMqV5RGgtFGwOkA',
#    'alias': 'cloudm-rooftop-bar-bowery-new-york',
#    'name': 'cloudM Rooftop Bar Bowery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7hyntKU6LWfKaG-qtND-Yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cloudm-rooftop-bar-bowery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 76,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72069, 'longitude': -73.99366},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '189 Bowery',
#     'address2': None,
#     'address3': 'citizenM New York Bowery Hotel',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['189 Bowery',
#      'citizenM New York Bowery Hotel',
#      'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1683.1646494398813},
#   {'id': 'U3d5QB5a8Q37Csj7L1aBXA',
#    'alias': 'mama-tried-brooklyn-2',
#    'name': 'Mama Tried',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6uSqwc2X5ZxHpIqEuCk0ZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mama-tried-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.66046, 'longitude': -74.00082},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '147 27th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11232',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['147 27th St', 'Brooklyn, NY 11232']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5021.820240055637},
#   {'id': 'cRsIsiuoV11zX8oLY8brhQ',
#    'alias': 'dumboluv-brooklyn-3',
#    'name': 'DumboLuv',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/iN17geeIHSh3tdvRrXojig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dumboluv-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7032593, 'longitude': -73.9866501},
#    'transactions': ['delivery'],
#    'location': {'address1': '54 Jay St',
#     'address2': None,
#     'address3': 'Olympia Wine Bar',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['54 Jay St',
#      'Olympia Wine Bar',
#      'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 688.5877509468264},
#   {'id': 'I4LSdJd2Z8M6VNLhbX3aLA',
#    'alias': 'superfine-brooklyn',
#    'name': 'Superfine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/a68hCkJePMYBUnNKGNN9jw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/superfine-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 478,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.702236, 'longitude': -73.987426},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '126 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['126 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17182439005',
#    'display_phone': '(718) 243-9005',
#    'distance': 684.5691418649358},
#   {'id': 'iBv3jR8lxH2e9dV42Sca0g',
#    'alias': 'super-power-brooklyn',
#    'name': 'Super Power',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/I1QIRJIO_dTowwbmcEl3cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/super-power-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 159,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6739268745309,
#     'longitude': -73.9503274715026},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '722 Nostrand Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['722 Nostrand Ave', 'Brooklyn, NY 11216']},
#    'phone': '+17184840020',
#    'display_phone': '(718) 484-0020',
#    'distance': 5101.340457126579},
#   {'id': '1m6pfntylp2UL67hRPCbiw',
#    'alias': 'the-lost-lady-new-york',
#    'name': 'The Lost Lady',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ar_YI7Gnq_KRQP36ScV9xg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lost-lady-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'tikibars', 'title': 'Tiki Bars'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72631, 'longitude': -73.97756},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '171 Avenue C',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 Avenue C', 'New York, NY 10009']},
#    'phone': '+13474550228',
#    'display_phone': '(347) 455-0228',
#    'distance': 2718.37100486118},
#   {'id': 'AA9wpuJRhkSHUePAiv3otA',
#    'alias': 'the-leroy-house-new-york-5',
#    'name': 'The Leroy House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2gFtU7B5tZx4WVtl5jiwjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-leroy-house-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 122,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73063, 'longitude': -74.00661},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '430 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['430 Hudson St', 'New York, NY 10014']},
#    'phone': '+16465900640',
#    'display_phone': '(646) 590-0640',
#    'distance': 2983.4823644949856},
#   {'id': 'TRWTCtNQYxiBU_7OvnhAvw',
#    'alias': 'the-woods-brooklyn',
#    'name': 'The Woods',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WzBe2UVWAxgVTx7BUkBUzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-woods-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 430,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'danceclubs', 'title': 'Dance Clubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.712818, 'longitude': -73.966659},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '48 S 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['48 S 4th St', 'Brooklyn, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2493.7069333497225},
#   {'id': 'Cw8g99c6ybhsbrTCgI5S_Q',
#    'alias': 'proletariat-new-york',
#    'name': 'Proletariat',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yxUUAKazhMOFqNa7ZwV7mQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/proletariat-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 294,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7272506368689,
#     'longitude': -73.9845192432404},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '102 St Marks Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 St Marks Pl', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2560.796259516192},
#   {'id': 'LZvmeRaHF2469Re1Uc9ElQ',
#    'alias': 'roof-at-park-south-new-york',
#    'name': 'Roof At Park South',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1PnXdfTEgsBoKLvmdEffaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roof-at-park-south-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 171,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74234, 'longitude': -73.98343},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '125 E 27th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['125 E 27th St', 'New York, NY 10016']},
#    'phone': '+12122045222',
#    'display_phone': '(212) 204-5222',
#    'distance': 4207.800646194941},
#   {'id': '_MjMpJ6fVQZbbTOZf8T2XA',
#    'alias': 'lovers-of-today-new-york',
#    'name': 'Lovers of Today',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UX9VNWlaJWL-GBHbTFeEEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lovers-of-today-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 279,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7258338928223,
#     'longitude': -73.9833755493164},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '132 1/2 E 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['132 1/2 E 7th St', 'New York, NY 10009']},
#    'phone': '+12124209517',
#    'display_phone': '(212) 420-9517',
#    'distance': 2444.430058178137},
#   {'id': 'JVPWjHJI3eu-oFdS10U1FA',
#    'alias': 'runaway-roof-brooklyn',
#    'name': 'Runaway Roof',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1WCJEdgyrjBAZ7vWK5UzQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/runaway-roof-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.708074, 'longitude': -73.9205073},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '321 Starr St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['321 Starr St', 'Brooklyn, NY 11237']},
#    'phone': '+19294808969',
#    'display_phone': '(929) 480-8969',
#    'distance': 6226.432165907675},
#   {'id': 'DbH-qORJRJeWQVmnnF1tUA',
#    'alias': 'garden-bar-new-york',
#    'name': 'Garden Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9_lJfThRLIOZSRuzSRMyzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/garden-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.70701, 'longitude': -74.00356},
#    'transactions': ['delivery'],
#    'location': {'address1': '19 Fulton St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Fulton St', 'New York, NY 10038']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 800.6417178224538},
#   {'id': 'YKfj-CUjgb9xQ1kN_bhNLg',
#    'alias': 'forgtmenot-new-york-2',
#    'name': 'Forgtmenot',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jrbtdzmbila2bW6t1FV8cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/forgtmenot-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 188,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.714498871349,
#     'longitude': -73.9915559401866},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '138 Division St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['138 Division St', 'New York, NY 10002']},
#    'phone': '+16467073195',
#    'display_phone': '(646) 707-3195',
#    'distance': 1039.1101430838685},
#   {'id': 'IHLGmtOkqm8Qm3Ny8yjfVA',
#    'alias': 'pata-paplean-elmhurst',
#    'name': 'Pata Paplean',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ectHd2wXvXG5Mh23FXgU1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pata-paplean-elmhurst?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7435901462143,
#     'longitude': -73.8880684963577},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '76-21 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['76-21 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17186512076',
#    'display_phone': '(718) 651-2076',
#    'distance': 9905.57046768824},
#   {'id': 'kDJbzzmCEjFbyDQ-lSygvw',
#    'alias': 'fresh-salt-new-york',
#    'name': 'Fresh Salt',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Rmf9kAAubededQTq1rzLIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fresh-salt-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 407,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70707, 'longitude': -74.00244},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '146 Beekman St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['146 Beekman St', 'New York, NY 10038']},
#    'phone': '+12129620053',
#    'display_phone': '(212) 962-0053',
#    'distance': 710.677389267444},
#   {'id': 'Cezyi2kTskAOOX7jJH4mUA',
#    'alias': 'cork-new-york',
#    'name': 'Cork',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rBiUdMnJl6tRqa1Hz23H4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cork-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72464171265232,
#     'longitude': -74.00325882159193},
#    'transactions': [],
#    'location': {'address1': '69 Thompson St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['69 Thompson St', 'New York, NY 10012']},
#    'phone': '+16466698169',
#    'display_phone': '(646) 669-8169',
#    'distance': 2264.3891862641885},
#   {'id': 'rXpFlvax5ma_rwFsAEg3XA',
#    'alias': 'spare-lounge-bar-and-social-new-york',
#    'name': 'Spare Lounge Bar & Social',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4BdDgEeJo2QuBWVj2BqLOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spare-lounge-bar-and-social-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.75727, 'longitude': -73.9932752},
#    'transactions': [],
#    'location': {'address1': '550 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['550 9th Ave', 'New York, NY 10018']},
#    'phone': '+12122686909',
#    'display_phone': '(212) 268-6909',
#    'distance': 5756.16807045792},
#   {'id': 'CzVfYhOJrNSG-5Sn8BKHsQ',
#    'alias': 'crown-alley-new-york',
#    'name': 'Crown Alley',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HzPlD2g7EPR7sFOIEDQDZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crown-alley-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.742835593003456,
#     'longitude': -73.99978804723622},
#    'transactions': ['delivery'],
#    'location': {'address1': '263 West 19th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['263 West 19th St', 'New York, NY 10011']},
#    'phone': '+16468923003',
#    'display_phone': '(646) 892-3003',
#    'distance': 4183.360833974331},
#   {'id': 'X9m0Z_fNmW26MgIMqTa8Ng',
#    'alias': 'mayflower-brooklyn-2',
#    'name': 'Mayflower',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/H8pcvzpZrFBaCyJKJbE-Jw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mayflower-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68643, 'longitude': -73.96662},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '132 Greene Ave',
#     'address2': '',
#     'address3': 'Aita',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['132 Greene Ave', 'Aita', 'Brooklyn, NY 11238']},
#    'phone': '+17185763584',
#    'display_phone': '(718) 576-3584',
#    'distance': 3143.349399264751},
#   {'id': 'igbXdpEil8ZTcridxpBlLg',
#    'alias': 'analogue-new-york',
#    'name': 'Analogue',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/b5t_ZN9lCtNdpMTOxtDqyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/analogue-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 288,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'whiskeybars', 'title': 'Whiskey Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.732688, 'longitude': -73.997467},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '19 W 8th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 W 8th St', 'New York, NY 10011']},
#    'phone': '+12124320200',
#    'display_phone': '(212) 432-0200',
#    'distance': 3041.0807240080157},
#   {'id': '9ZcGTKa8jXxHe-wPWXK6nA',
#    'alias': 'diamond-reef-brooklyn-3',
#    'name': 'Diamond Reef',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nOjlgkeijTP_VhWA9csIUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/diamond-reef-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 61,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6796758019517,
#     'longitude': -73.9566367333384},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1057 Atlantic Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1057 Atlantic Ave', 'Brooklyn, NY 11238']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4276.670009482654},
#   {'id': 'YL1LxYufuwX5sq4RwW-2Gw',
#    'alias': 'floyd-ny-brooklyn-2',
#    'name': 'Floyd, NY',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9SDNpk2ueMDDstGKS1DJAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/floyd-ny-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 211,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6907799, 'longitude': -73.9957},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '131 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['131 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17188585810',
#    'display_phone': '(718) 858-5810',
#    'distance': 1630.1308479384288},
#   {'id': 'vyyJNMgVo5b3Lyex5GawHg',
#    'alias': 'district-local-new-york-2',
#    'name': 'District Local',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9Vs8AzvCwwSxBR63pweD_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/district-local-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73917, 'longitude': -73.99946},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '72 7th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['72 7th Ave', 'New York, NY 10011']},
#    'phone': '+12129306677',
#    'display_phone': '(212) 930-6677',
#    'distance': 3773.6284900511323},
#   {'id': 'JJ0vb8jp3Qj91ESPiuj66g',
#    'alias': 'penthouse-lounge-bar-brooklyn',
#    'name': 'Penthouse Lounge Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bZLBcllLPCkPh7GcYwKwIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/penthouse-lounge-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'comedyclubs', 'title': 'Comedy Clubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.583995, 'longitude': -73.94697},
#    'transactions': [],
#    'location': {'address1': '2027 Emmons Ave',
#     'address2': '3 Fl',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11235',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2027 Emmons Ave', '3 Fl', 'Brooklyn, NY 11235']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 14082.455728558925},
#   {'id': 'S81cNOF-SslUCcBQgWPO-g',
#    'alias': 'skinny-dennis-brooklyn',
#    'name': 'Skinny Dennis',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/K4Kq9vlHBG5BV9ldbagcqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/skinny-dennis-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 232,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.715863, 'longitude': -73.962168},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '152 Metropolitan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['152 Metropolitan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+12125551212',
#    'display_phone': '(212) 555-1212',
#    'distance': 2945.140554457677},
#   {'id': 'iIixO6VbKitogJGBRIalYA',
#    'alias': 'keybar-new-york',
#    'name': 'Keybar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6ENeV8VvH8Ge7Ir3Lvs9hQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/keybar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 602,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7299112, 'longitude': -73.981883},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '432 E 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['432 E 13th St', 'New York, NY 10009']},
#    'phone': '+12124783021',
#    'display_phone': '(212) 478-3021',
#    'distance': 2914.654206890365},
#   {'id': 'MGKoqfOinZbW3NkV2fYhIA',
#    'alias': 'sally-s-brooklyn',
#    'name': 'Sally’s',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rmYpgwErhZFtEQHE83GiLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sally-s-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'caribbean', 'title': 'Caribbean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.694143, 'longitude': -73.945805},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '151 Tompkins Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['151 Tompkins Ave', 'Brooklyn, NY 11206']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4277.6533680480015},
#   {'id': '3GO3jhLmY8E3qsvwOaHrKg',
#    'alias': 'sour-mouse-new-york',
#    'name': 'Sour Mouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hMY-Ive9xrlcWmzayvgorw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sour-mouse-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'poolhalls', 'title': 'Pool Halls'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7188783, 'longitude': -73.988375},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '110 Delancey St',
#     'address2': 'Lower Level',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['110 Delancey St',
#      'Lower Level',
#      'New York, NY 10002']},
#    'phone': '+16464767407',
#    'display_phone': '(646) 476-7407',
#    'distance': 1584.0140234436826},
#   {'id': 'W6m3XQqlyKDsY1BSmypKpw',
#    'alias': 'summerly-at-the-hoxton-williamsburg-brooklyn',
#    'name': 'Summerly at The Hoxton, Williamsburg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/21foKp92XvfFw9xLm46DZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/summerly-at-the-hoxton-williamsburg-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 72,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72077, 'longitude': -73.95873},
#    'transactions': [],
#    'location': {'address1': '97 Wythe Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['97 Wythe Ave', 'Brooklyn, NY 11249']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3468.575814422786},
#   {'id': 'bEloKDe-QVkwakAwmFKbbA',
#    'alias': 'frying-pan-new-york',
#    'name': 'Frying Pan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HgBT-gGv_X8Ae-d4JNvNBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frying-pan-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1573,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7521174043978,
#     'longitude': -74.0090024471283},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '207 12th Avenue',
#     'address2': '',
#     'address3': 'Big Red Boat in Park',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['207 12th Avenue',
#      'Big Red Boat in Park',
#      'New York, NY 10001']},
#    'phone': '+12129896363',
#    'display_phone': '(212) 989-6363',
#    'distance': 5335.701065281043},
#   {'id': 'okF1w-7gZNy2OB73SsjuYw',
#    'alias': 'travel-bar-carroll-gardens',
#    'name': 'Travel Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-t4LtDJOympPWgO9pWEmCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/travel-bar-carroll-gardens?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 52,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.6761536, 'longitude': -73.9991514612044},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '520 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Carroll Gardens',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['520 Court St', 'Carroll Gardens, NY 11231']},
#    'phone': '+17188582509',
#    'display_phone': '(718) 858-2509',
#    'distance': 3282.6919165583677},
#   {'id': '3xTQT7qjZJIxc-eBiFMerQ',
#    'alias': '1803-new-york',
#    'name': '1803',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/f6_ZYxoZGbyGsCn6m_auog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/1803-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 554,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.715498, 'longitude': -74.007178},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '82 Reade St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['82 Reade St', 'New York, NY 10007']},
#    'phone': '+12122673000',
#    'display_phone': '(212) 267-3000',
#    'distance': 1558.541688391669},
#   {'id': 'f8eil3mRKg_GLbq7rpFwuA',
#    'alias': 'butterfly-bar-new-york',
#    'name': 'Butterfly Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/__eXR6d_pFvNMMWJcYj4hQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/butterfly-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.72399, 'longitude': -74.00316},
#    'transactions': [],
#    'location': {'address1': '60 Thompson St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Thompson St', 'New York, NY 10012']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2190.590271810382},
#   {'id': 'kIzVGUWS2b5H_b-G0Q0-0g',
#    'alias': 'katana-kitten-new-york-2',
#    'name': 'Katana Kitten',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T8_WgDni-INC7arpAEKI7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/katana-kitten-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73425, 'longitude': -74.00639},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '531 Hudson St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['531 Hudson St', 'New York, NY 10014']},
#    'phone': '+12122433007',
#    'display_phone': '(212) 243-3007',
#    'distance': 3363.180571362766},
#   {'id': '6hKJePanmG9AxK4dfwgyyg',
#    'alias': 'the-horny-ram-new-york-2',
#    'name': 'The Horny Ram',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/r7ChItmOrNARZf1IqqG1RQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-horny-ram-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 576,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75528, 'longitude': -73.96857},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '951 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['951 2nd Ave', 'New York, NY 10022']},
#    'phone': '+19172614136',
#    'display_phone': '(917) 261-4136',
#    'distance': 5949.853020058706},
#   {'id': '_qXrnp-rcwpvtY4H93E5ug',
#    'alias': 'bandits-new-york',
#    'name': 'Bandits',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_cQyX-bqA2yhYvOkdpFn5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bandits-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.730425, 'longitude': -74.004121},
#    'transactions': [],
#    'location': {'address1': '44 Bedford St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['44 Bedford St', 'New York, NY 10014']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2898.052949138615},
#   {'id': '46gT-bvsj5sXDMLAAcybzQ',
#    'alias': 'barrow-s-intense-tasting-room-brooklyn-2',
#    'name': 'Barrow’s Intense Tasting Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/biHilseCB3v8HNd4Jf1Hng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barrow-s-intense-tasting-room-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'distilleries', 'title': 'Distilleries'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6568712, 'longitude': -74.0060622},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '86 34th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11232',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['86 34th St', 'Brooklyn, NY 11232']},
#    'phone': '+19175971084',
#    'display_phone': '(917) 597-1084',
#    'distance': 5491.555975750816},
#   {'id': '6ZYJ5iiTi6KqRCOigqY7iw',
#    'alias': 'cedar-local-new-york',
#    'name': 'Cedar Local',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Eiqg8sTMewzGhFUsfHlJaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cedar-local-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 144,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7068528, 'longitude': -74.0076058},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '25 Cedar St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 Cedar St', 'New York, NY 10005']},
#    'phone': '+12123443467',
#    'display_phone': '(212) 344-3467',
#    'distance': 1176.4185995505916},
#   {'id': 'wEb_fHmbMuzT1of_E9LT2g',
#    'alias': 'refinery-rooftop-new-york',
#    'name': 'Refinery Rooftop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JfAafmf72QD_95G0cG75rQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/refinery-rooftop-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1051,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7522605288633,
#     'longitude': -73.9853609711639},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '63 W 38th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63 W 38th St', 'New York, NY 10018']},
#    'phone': '+16466640372',
#    'display_phone': '(646) 664-0372',
#    'distance': 5259.789829566064},
#   {'id': '1k6pYbG1A261PRCohFcclQ',
#    'alias': 'llohi-roof-bar-brooklyn',
#    'name': 'LLoHi Roof Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TcICzKgah_gB7bg_1iu-aQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/llohi-roof-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.709106, 'longitude': -73.935238},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '314 Scholes St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['314 Scholes St', 'Brooklyn, NY 11206']},
#    'phone': '+13475663662',
#    'display_phone': '(347) 566-3662',
#    'distance': 4989.280901733187},
#   {'id': 'IYR-jmboN66jRDPRKw0eqw',
#    'alias': 'mister-paradise-new-york',
#    'name': 'Mister Paradise',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/quQJKyqb3ZKsOuVDGiifvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mister-paradise-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72676, 'longitude': -73.98617},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '105 1st Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['105 1st Ave', 'New York, NY 10003']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2467.3715320253964},
#   {'id': 'H-a29tsPI8VKFf2pOpbzqg',
#    'alias': 'paradise-club-new-york-2',
#    'name': 'Paradise Club',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MCWI0yGUtkuY2KR8GcuSmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paradise-club-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 80,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'cabaret', 'title': 'Cabaret'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75923, 'longitude': -73.9841},
#    'transactions': [],
#    'location': {'address1': '701 7th Ave 20 Times Square',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['701 7th Ave 20 Times Square', 'New York, NY 10036']},
#    'phone': '+12122615400',
#    'display_phone': '(212) 261-5400',
#    'distance': 6045.575815726739},
#   {'id': 'AlZYxW1hQ3S2sGbtNjo64w',
#    'alias': 'cibar-new-york',
#    'name': 'Cibar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iLqFm1fvg9bMRfCQCKh84w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cibar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 317,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73596, 'longitude': -73.98696},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '56 Irving Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['56 Irving Pl', 'New York, NY 10003']},
#    'phone': '+12124605656',
#    'display_phone': '(212) 460-5656',
#    'distance': 3444.0768258597886},
#   {'id': 'XsElXaLxUPKquI78poB8yw',
#    'alias': 'maison-pickle-new-york',
#    'name': 'Maison Pickle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zZw_u_oeO9it_GYSinWkMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maison-pickle-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1225,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7870473, 'longitude': -73.9781361},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2315 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2315 Broadway', 'New York, NY 10024']},
#    'phone': '+12124969100',
#    'display_phone': '(212) 496-9100',
#    'distance': 9175.285173753695},
#   {'id': 'k5bGHJbAXDw9g_uP42QqDw',
#    'alias': 'the-highwater-astoria',
#    'name': 'The Highwater',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jNVe-hci7160WIpkIBjG2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-highwater-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 444,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'hawaiian', 'title': 'Hawaiian'},
#     {'alias': 'tikibars', 'title': 'Tiki Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76033, 'longitude': -73.92245},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3420 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3420 Broadway', 'Astoria, NY 11106']},
#    'phone': '+19177450407',
#    'display_phone': '(917) 745-0407',
#    'distance': 8599.837600298042},
#   {'id': 'OmrD9neOHhfmJIoP6erJjA',
#    'alias': 'elsewhere-rooftop-brooklyn',
#    'name': 'Elsewhere Rooftop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7KhifI8Eqkyuok80_tWzEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elsewhere-rooftop-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'outdoormovies', 'title': 'Outdoor Movies'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70950450588652,
#     'longitude': -73.92319045977891},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '599 Johnson Ave',
#     'address2': 'Fl 3',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['599 Johnson Ave', 'Fl 3', 'Brooklyn, NY 11237']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6010.307665350121},
#   {'id': 'NGfltxqJQ4x9w7L0x2VDFw',
#    'alias': 'baba-cool-new-york',
#    'name': 'Baba Cool',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pQpaq-AhFBhbfpBw0uRDlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baba-cool-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.717015, 'longitude': -73.950737},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '47 Withers St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 Withers St', 'New York, NY 11211']},
#    'phone': '+19292958424',
#    'display_phone': '(929) 295-8424',
#    'distance': 3889.418261027659}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#                   Restaurant            Type Price Rating         Address  \
# 0                      Bar B         Italian    $$    4.5      84 7th Ave
# 1                    Cookies            Bars               748 Myrtle Ave
# 2  cloudM Rooftop Bar Bowery   Cocktail Bars    $$      4      189 Bowery
# 3                 Mama Tried   Cocktail Bars    $$    4.5     147 27th St
# 4                   DumboLuv  American (New)                    54 Jay St
#
#          Lat        Lng                                                url  \
# 0  40.739580 -73.999118  https://www.yelp.com/biz/bar-b-new-york?adjust...
# 1  40.694850 -73.952850
# 2  40.720690 -73.993660  https://www.yelp.com/biz/cloudm-rooftop-bar-bo...
# 3  40.660460 -74.000820  https://www.yelp.com/biz/mama-tried-brooklyn-2...
# 4  40.703259 -73.986650
#
#                        ID
# 0  5MpWHGQ6Qc-M4q1KL_nioA
# 1
# 2  l8um5IoiMqV5RGgtFGwOkA
# 3  U3d5QB5a8Q37Csj7L1aBXA
# 4

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                                    Restaurant                   Type Rating  \
# 0                                The Bar Room         American (New)      4
# 1                              Employees Only         American (New)      4
# 2                 Hold Fast Kitchen & Spirits         American (New)      5
# 3                             The Flower Shop         American (New)      4
# 4                               The Horny Ram         American (New)      4
# 5                         Henry's Rooftop Bar         American (New)      4
# 6                                The Wild Son         American (New)    4.5
# 7                                    DumboLuv         American (New)
# 8                                Atrium Dumbo         American (New)      4
# 9                                The Spaniard         American (New)      4
# 10                              The Cabin NYC         American (New)      4
# 11                                        OTB         American (New)    4.5
# 12                            The Leroy House         American (New)    4.5
# 13                              The Highwater         American (New)      4
# 14                                       JoJo         American (New)      4
# 15                             Kimoto Rooftop           Asian Fusion    3.5
# 16                                  Superfine                   Bars    3.5
# 17                                  Local 138                   Bars      4
# 18                                    Cookies                   Bars
# 19                            All Night Skate                   Bars
# 20                                   Juke Bar                   Bars    4.5
# 21                              Four Five Six                   Bars    4.5
# 22                                  Baba Cool                   Bars
# 23                              Cardiff Giant                   Bars      4
# 24                            Hidden Lane Bar                   Bars
# 25                                  The Woods                   Bars      3
# 26                              68 Jay St Bar                   Bars      3
# 27                               Clinton Hall                   Bars    3.5
# 28                                      Doris                   Bars      4
# 29                               Copper & Oak                   Bars    4.5
# ..                                        ...                    ...    ...
# 170                   Loopy Doopy Rooftop Bar                Lounges    3.5
# 171                        The Upstairs at 66                Lounges      5
# 172                                 Watermark                Lounges    3.5
# 173                                Death & Co                Lounges      4
# 174                           Cantina Rooftop                Lounges      3
# 175                                Rooftop 93                Lounges      4
# 176                               The Emerson                Lounges      4
# 177                              The Otheroom                Lounges      4
# 178                           Lovers of Today                Lounges      4
# 179                                 Celestine          Mediterranean      4
# 180                            Gran Electrica                Mexican    3.5
# 181                                Sour Mouse             Pool Halls    4.5
# 182                                  Moot Bar                   Pubs    4.5
# 183                               Cobble Fish                Seafood
# 184                                  Drift In                Seafood
# 185                               Bathtub Gin            Speakeasies    3.5
# 186  The Lingerie Shoppe aka Astoria’s Secret            Speakeasies    4.5
# 187                            Patent Pending            Speakeasies      4
# 188                         The Three Monkeys            Sports Bars      4
# 189                            District Local     Tapas/Small Plates    4.5
# 190                             The Lost Lady              Tiki Bars    4.5
# 191                     Flatbush Zombie House              Tiki Bars      4
# 192                                Zombie Hut              Tiki Bars      4
# 193                             Panorama Room  Venues & Event Spaces    3.5
# 194                                 Mayflower  Venues & Event Spaces      4
# 195                               Dear Irving  Venues & Event Spaces      4
# 196                            Whiskey Tavern           Whiskey Bars    4.5
# 197                               The Tippler              Wine Bars      4
# 198                         142 Sullivan Bar               Wine Bars    4.5
# 199                                      Cork              Wine Bars
#
#     Price            Address        Lat        Lng  \
# 0      $$      117 E 60th St  40.763409 -73.968449
# 1     $$$      510 Hudson St  40.733430 -74.006170
# 2      $$      364 W 46th St  40.760640 -73.990230
# 3      $$    107 Eldridge St  40.718070 -73.992130
# 4      $$        951 2nd Ave  40.755280 -73.968570
# 5      $$  501 Lexington Ave  40.754799 -73.973140
# 6      $$      132 First Ave  40.727424 -73.985201
# 7                  54 Jay St  40.703259 -73.986650
# 8      $$         15 Main St  40.703390 -73.990492
# 9      $$       190 W 4th St  40.732750 -74.002183
# 10     $$       205 E 4th St  40.723930 -73.983830
# 11     $$       141 Broadway  40.710484 -73.963408
# 12    $$$      430 Hudson St  40.730630 -74.006610
# 13     $$      3420 Broadway  40.760330 -73.922450
# 14    $$$      160 E 64th St  40.765060 -73.965710
# 15     $$    228 Duffield St  40.691516 -73.984655
# 16     $$       126 Front St  40.702236 -73.987426
# 17      $     181 Orchard St  40.721910 -73.988410
# 18            748 Myrtle Ave  40.694850 -73.952850
# 19           54 Rockaway Ave  40.681920 -73.911686
# 20     $$        196 2nd Ave  40.731098 -73.985611
# 21     $$  199 Richardson St  40.719181 -73.943149
# 22             47 Withers St  40.717015 -73.950737
# 23     $$     415 Myrtle Ave  40.693240 -73.969230
# 24             129 E 15th St  40.734579 -73.987684
# 25     $$        48 S 4th St  40.712818 -73.966659
# 26      $          68 Jay St  40.703001 -73.986817
# 27     $$   90 Washington St  40.708030 -74.014869
# 28     $$     1088 Fulton St  40.681210 -73.957436
# 29    $$$       157 Allen St  40.721065 -73.989860
# ..    ...                ...        ...        ...
# 170   $$$      102 N End Ave  40.715000 -74.015800
# 171    $$        46 Stone St  40.704180 -74.010480
# 172    $$   Pier 15, 78 S St  40.704379 -74.002993
# 173   $$$       433 E 6th St  40.725890 -73.984700
# 174    $$      605 W 48th St  40.765101 -73.996046
# 175    $$          93 Bowery  40.717050 -73.995220
# 176    $$     561 Myrtle Ave  40.694140 -73.961817
# 177    $$       143 Perry St  40.734966 -74.008028
# 178    $$   132 1/2 E 7th St  40.725834 -73.983376
# 179   $$$          1 John St  40.704676 -73.987975
# 180    $$         5 Front St  40.702700 -73.993140
# 181    $$    110 Delancey St  40.718878 -73.988375
# 182     $     579 Myrtle Ave  40.694199 -73.960960
# 183              89 South St  40.705302 -74.002578
# 184                 389 W St  40.732911 -74.010644
# 185    $$        132 9th Ave  40.743640 -74.003190
# 186    $$  28-53 Steinway St  40.764060 -73.914500
# 187   $$$       49 W 27th St  40.745260 -73.990320
# 188    $$      236 W 54th St  40.764164 -73.983060
# 189    $$         72 7th Ave  40.739170 -73.999460
# 190    $$       171 Avenue C  40.726310 -73.977560
# 191    $$   734 Flatbush Ave  40.655039 -73.960039
# 192     $       273 Smith St  40.682572 -73.993164
# 193   $$$       22 N Loop Rd  40.756265 -73.955455
# 194    $$     132 Greene Ave  40.686430 -73.966620
# 195   $$$       55 Irving Pl  40.736057 -73.987240
# 196    $$       79 Baxter St  40.716460 -73.999690
# 197    $$      425 W 15th St  40.742354 -74.006340
# 198    $$    142 Sullivan St  40.727120 -74.002200
# 199           69 Thompson St  40.724642 -74.003259
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/the-bar-room-new-york...  MyQV4i518ZO4CLudtR8gLA
# 1    https://www.yelp.com/biz/employees-only-new-yo...  SjG7CnTIuUBIo9T4BThkGQ
# 2    https://www.yelp.com/biz/hold-fast-kitchen-and...  VLGmFHE4s0Sfu0piMVQa1Q
# 3    https://www.yelp.com/biz/the-flower-shop-new-y...  vkQSMwAf5yqDw9HfEQYgzw
# 4    https://www.yelp.com/biz/the-horny-ram-new-yor...  6hKJePanmG9AxK4dfwgyyg
# 5    https://www.yelp.com/biz/henrys-rooftop-bar-ne...  Q_bI2gY7LtMCXkzkakPUkg
# 6    https://www.yelp.com/biz/the-wild-son-new-york...  N5UY113nNpeKdLPv0cbMjQ
# 7
# 8    https://www.yelp.com/biz/atrium-dumbo-brooklyn...  hmdm-dO72hLsMQwQRcGEUQ
# 9    https://www.yelp.com/biz/the-spaniard-new-york...  XO3yD87rTPz9o6Dy9qRaJg
# 10   https://www.yelp.com/biz/the-cabin-nyc-new-yor...  J3NT61-AH5d5Gu5tFJhYSw
# 11   https://www.yelp.com/biz/otb-brooklyn?adjust_c...  GpWXEpVyehmKP2WQsD_Y8g
# 12   https://www.yelp.com/biz/the-leroy-house-new-y...  AA9wpuJRhkSHUePAiv3otA
# 13   https://www.yelp.com/biz/the-highwater-astoria...  k5bGHJbAXDw9g_uP42QqDw
# 14   https://www.yelp.com/biz/jojo-new-york-3?adjus...  uq5rHbGtBFwCwPkokIkKvQ
# 15   https://www.yelp.com/biz/kimoto-rooftop-brookl...  nnSyjwIkhbJIBMiBtch_BQ
# 16   https://www.yelp.com/biz/superfine-brooklyn?ad...  I4LSdJd2Z8M6VNLhbX3aLA
# 17   https://www.yelp.com/biz/local-138-new-york?ad...  EDFfoyXTsHPBW6mNWLVoig
# 18
# 19
# 20   https://www.yelp.com/biz/juke-bar-new-york?adj...  kt77PF-PfvsY5aGv0UGeNA
# 21   https://www.yelp.com/biz/four-five-six-brookly...  HuU2IGPfQ23FTOGDQg0Ieg
# 22
# 23   https://www.yelp.com/biz/cardiff-giant-brookly...  XyulGZ5P9VhtNcK7zN2R9g
# 24
# 25   https://www.yelp.com/biz/the-woods-brooklyn?ad...  TRWTCtNQYxiBU_7OvnhAvw
# 26   https://www.yelp.com/biz/68-jay-st-bar-brookly...  ne1sjzU07jRQZSFO0K9l9Q
# 27   https://www.yelp.com/biz/clinton-hall-new-york...  nm5rcWNmfevNXLNQAITi5w
# 28   https://www.yelp.com/biz/doris-brooklyn?adjust...  kLxfxcs8DPVjeOt9jvPwrw
# 29   https://www.yelp.com/biz/copper-and-oak-new-yo...  ajdv6_mWIkAXzn71CUdpkw
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/loopy-doopy-rooftop-b...  2hHlAxt4gsfMUkG48pXXKw
# 171  https://www.yelp.com/biz/the-upstairs-at-66-ne...  X0f9UYHoE4OxnuUq801vMg
# 172  https://www.yelp.com/biz/watermark-new-york?ad...  jEEb_EKKD2lx2mvTly_U6Q
# 173  https://www.yelp.com/biz/death-and-co-new-york...  H1QphdrrsaB472y9HXi2Ow
# 174  https://www.yelp.com/biz/cantina-rooftop-new-y...  sul_ihulQ5VUPNbk9liWqA
# 175  https://www.yelp.com/biz/rooftop-93-new-york-5...  511OTzlr0FkL4esfBxMzIw
# 176  https://www.yelp.com/biz/the-emerson-brooklyn?...  xGDGHg7G0Z6xvUo4xVXXVQ
# 177  https://www.yelp.com/biz/the-otheroom-new-york...  aOdbXPdCPrckxo_it5xwSA
# 178  https://www.yelp.com/biz/lovers-of-today-new-y...  _MjMpJ6fVQZbbTOZf8T2XA
# 179  https://www.yelp.com/biz/celestine-brooklyn?ad...  4aF0F8w7yXX9o5_QFky_ig
# 180  https://www.yelp.com/biz/gran-electrica-brookl...  f7g3GhoQs9nQVTJEL2p48Q
# 181  https://www.yelp.com/biz/sour-mouse-new-york?a...  3GO3jhLmY8E3qsvwOaHrKg
# 182  https://www.yelp.com/biz/moot-bar-brooklyn-2?a...  TE87BLxClCcIg62i0xVgMg
# 183
# 184
# 185  https://www.yelp.com/biz/bathtub-gin-new-york?...  89XYJZSPKt-dqjE1zyTIzQ
# 186  https://www.yelp.com/biz/the-lingerie-shoppe-a...  TI5dWiHdFn55WQDmvffu0Q
# 187  https://www.yelp.com/biz/patent-pending-new-yo...  VBjYIelQBlCK889IBVrWzQ
# 188  https://www.yelp.com/biz/the-three-monkeys-new...  IBgjj5VBu5JJvKgo9EzKrg
# 189  https://www.yelp.com/biz/district-local-new-yo...  vyyJNMgVo5b3Lyex5GawHg
# 190  https://www.yelp.com/biz/the-lost-lady-new-yor...  1m6pfntylp2UL67hRPCbiw
# 191  https://www.yelp.com/biz/flatbush-zombie-house...  ZNEFXERBvl7i_QQojRoKNQ
# 192  https://www.yelp.com/biz/zombie-hut-brooklyn?a...  rRPuX18uiYLEUGdJ9xQBEQ
# 193  https://www.yelp.com/biz/panorama-room-new-yor...  PTWQs2DE0CJJiN8q9pxmLw
# 194  https://www.yelp.com/biz/mayflower-brooklyn-2?...  X9m0Z_fNmW26MgIMqTa8Ng
# 195  https://www.yelp.com/biz/dear-irving-new-york?...  -dQexkmhlgbiKvZ94jBmjQ
# 196  https://www.yelp.com/biz/whiskey-tavern-new-yo...  c3Ww3pgeHjBi3ctkeUWrjQ
# 197  https://www.yelp.com/biz/the-tippler-new-york?...  -egltOQhAdo1kWlPSJfmvA
# 198  https://www.yelp.com/biz/142-sullivan-bar-new-...  9itMlJoBaBDGjqgnyDem-w
# 199
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_Bar.csv')
