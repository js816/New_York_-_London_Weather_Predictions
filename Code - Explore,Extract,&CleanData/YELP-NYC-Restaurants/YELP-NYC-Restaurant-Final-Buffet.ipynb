# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"buffet","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': 'YvWQMlMjtYmVmheH97tTlQ',
#    'alias': 'crab-house-all-you-can-eat-seafood-new-york',
#    'name': 'Crab House All You Can Eat Seafood',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1J0qtJbyF3aYyTobEOzjgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crab-house-all-you-can-eat-seafood-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 204,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.759664, 'longitude': -73.969776},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$$',
#    'location': {'address1': '135 E 55th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['135 E 55th St', 'New York, NY 10022']},
#    'phone': '+12129330264',
#    'display_phone': '(212) 933-0264',
#    'distance': 6382.194727371187},
#   {'id': 'w2oSwwvOf-DBnEUumq_TIA',
#    'alias': 'the-buffet-flushing',
#    'name': 'The Buffet',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wj1U0ZjtVnwPq8zVEfyXgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-buffet-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 800,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.78139892324089, 'longitude': -73.8412969},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '20-07 127th St',
#     'address2': 'Fl 4',
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11356',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['20-07 127th St', 'Fl 4', 'Flushing, NY 11356']},
#    'phone': '+17188863722',
#    'display_phone': '(718) 886-3722',
#    'distance': 15409.832608285877},
#   {'id': 't_UObgQX6M_ZRn3tk2cXYQ',
#    'alias': 'lets-meat-new-york',
#    'name': "Let's Meat",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_uuM4nLAurZUgK9XBO1H2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lets-meat-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1292,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.746774, 'longitude': -73.985524},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '307 5th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['307 5th Ave', 'New York, NY 10016']},
#    'phone': '+12128890089',
#    'display_phone': '(212) 889-0089',
#    'distance': 4654.617524485395},
#   {'id': 'aBcQo4Xy-Lcf3JfVcn94XA',
#    'alias': 'mizumi-douglaston',
#    'name': 'Mizumi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/seD52tpazlvZF77INI5hpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mizumi-douglaston?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1277,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.76357, 'longitude': -73.749},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '231-10 Northern Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Douglaston',
#     'zip_code': '11362',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231-10 Northern Blvd', 'Douglaston, NY 11362']},
#    'phone': '+17182298686',
#    'display_phone': '(718) 229-8686',
#    'distance': 21647.696292458255},
#   {'id': 'HGLH-sa-Fp3X6UXcaG7U0g',
#    'alias': '66s-fusion-brooklyn',
#    'name': '66S Fusion',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/e6U8wbMrWmUYoX7vSRldQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/66s-fusion-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6977600194066,
#     'longitude': -73.9715740687866},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '130 Flushing Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['130 Flushing Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17182220050',
#    'display_phone': '(718) 222-0050',
#    'distance': 2097.177517878902},
#   {'id': 'e96uZ0XXMwO8l7vfxH9jDQ',
#    'alias': 'flaming-grill-and-modern-buffet-brooklyn',
#    'name': 'Flaming Grill & Modern Buffet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/67Mr9o3ED-81B3U4mMhtcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flaming-grill-and-modern-buffet-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 129,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.59064, 'longitude': -73.93957},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3839 Nostrand Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11235',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3839 Nostrand Ave', 'Brooklyn, NY 11235']},
#    'phone': '+17186486888',
#    'display_phone': '(718) 648-6888',
#    'distance': 13605.964758470387},
#   {'id': 'VvsZAnEwU4c8Xkyrzx05Nw',
#    'alias': 'anytime-new-york',
#    'name': 'Anytime',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZCynTTqe0O1JtxKRozmWHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anytime-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1636,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74776270790539,
#     'longitude': -73.9867793576711},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '23 W 32nd St',
#     'address2': 'Fl 3',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23 W 32nd St', 'Fl 3', 'New York, NY 10001']},
#    'phone': '+16466697733',
#    'display_phone': '(646) 669-7733',
#    'distance': 4747.932417457403},
#   {'id': 'ogCC-lJJYnwXDvKGmKZ6Sw',
#    'alias': 'woorijip-new-york-2',
#    'name': 'Woorijip',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/taCQ8Tl5mh4i61WCPFCyMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/woorijip-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2688,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74747, 'longitude': -73.98648},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '12 W 32nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['12 W 32nd St', 'New York, NY 10001']},
#    'phone': '+12122441115',
#    'display_phone': '(212) 244-1115',
#    'distance': 4710.703598173038},
#   {'id': 'Xf6e3HaP0AgMBxY7dEDkOA',
#    'alias': '99-favor-taste-new-york-12',
#    'name': '99 Favor Taste',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9gFktkHItuyectWnoi1Mbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/99-favor-taste-new-york-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1935,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7176199, 'longitude': -73.99249},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '285 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['285 Grand St', 'New York, NY 10002']},
#    'phone': '+16466829162',
#    'display_phone': '(646) 682-9162',
#    'distance': 1348.6324758108813},
#   {'id': '54om5q7V4anmIXw2PdNJbA',
#    'alias': 'chens-buffet-bar-new-york',
#    'name': "Chen's Buffet Bar",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AvG4SNaldEDw8iayYc_wbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chens-buffet-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70712, 'longitude': -74.00845},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '32 Cedar St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 Cedar St', 'New York, NY 10038']},
#    'phone': '+12127979477',
#    'display_phone': '(212) 797-9477',
#    'distance': 1203.02167456842},
#   {'id': '5ccJFGa6crpptt9tW0YKAA',
#    'alias': 'new-grand-buffet-long-island-city',
#    'name': 'New Grand Buffet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6f-ym8RI8WsH2vY7a2H2Aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-grand-buffet-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 174,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.752193532499,
#     'longitude': -73.9149212837219},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '34-45 48th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['34-45 48th St', 'Long Island City, NY 11101']},
#    'phone': '+17182788889',
#    'display_phone': '(718) 278-8889',
#    'distance': 8470.741248326163},
#   {'id': '5u4T6-Z-KhHrRZ9g54pugQ',
#    'alias': 'carols-bun-new-york-3',
#    'name': "Carol's Bun",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/d8qaSRuicMeA-HCl7MzoqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carols-bun-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7138317002555,
#     'longitude': -73.9914554524045},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '139 E Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['139 E Broadway', 'New York, NY 10002']},
#    'phone': '+12125660203',
#    'display_phone': '(212) 566-0203',
#    'distance': 962.7583138449673},
#   {'id': '9gmHbifr93B0wOllYZdAZA',
#    'alias': 'seaport-buffet-brooklyn',
#    'name': 'Seaport Buffet',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/T_Al00s98ACpHRfDXaueew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seaport-buffet-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 192,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.584138, 'longitude': -73.946639},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2027 Emmons Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11235',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2027 Emmons Ave', 'Brooklyn, NY 11235']},
#    'phone': '+17189343388',
#    'display_phone': '(718) 934-3388',
#    'distance': 14082.207743561308},
#   {'id': 'zEIt0xaPM9DIS-pc118O6A',
#    'alias': 'hometown-hotpot-and-bbq-new-york-2',
#    'name': 'Hometown Hotpot & BBQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/B7p-cZUcJasqgM36BVes-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hometown-hotpot-and-bbq-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1311,
#    'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71931, 'longitude': -73.99689},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '194 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['194 Grand St', 'New York, NY 10013']},
#    'phone': '+12122198833',
#    'display_phone': '(212) 219-8833',
#    'distance': 1559.1780943715246},
#   {'id': 'kxykwx5qTWBhlMh18MQ82Q',
#    'alias': 'lukes-lobster-fidi-new-york',
#    'name': "Luke's Lobster FiDi",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C5NV5lfsLo2nJDkx3Or9ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lukes-lobster-fidi-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1177,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7046213003984,
#     'longitude': -74.0107793876969},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '26 S William St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 S William St', 'New York, NY 10004']},
#    'phone': '+12127471700',
#    'display_phone': '(212) 747-1700',
#    'distance': 1392.7033987694713},
#   {'id': '3rZwXDjkyDLAHNSdPUI5WA',
#    'alias': 'korai-kitchen-jersey-city',
#    'name': 'Korai Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/czVFamLw-OlToyBTn_pCcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/korai-kitchen-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 283,
#    'categories': [{'alias': 'bangladeshi', 'title': 'Bangladeshi'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.733896, 'longitude': -74.059151},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '576 Summit Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07306',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['576 Summit Ave', 'Jersey City, NJ 07306']},
#    'phone': '+12017216566',
#    'display_phone': '(201) 721-6566',
#    'distance': 6315.879341411726},
#   {'id': '22CRLIEfJWIO-8RjEiecAg',
#    'alias': 'akino-elmhurst',
#    'name': 'Akino',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7OaFodhkcMGYurUhJs7Ifw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/akino-elmhurst?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 914,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.741236, 'longitude': -73.881306},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '82-80 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['82-80 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+17187798280',
#    'display_phone': '(718) 779-8280',
#    'distance': 10319.817555373415},
#   {'id': 'z9uTP0OgfJ3iSjlu77uZ9A',
#    'alias': 'hibachi-grill-and-supreme-buffet-bronx-4',
#    'name': 'Hibachi Grill & Supreme Buffet',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cNTMHIvQHupuRRYws-J8hA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hibachi-grill-and-supreme-buffet-bronx-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.825096, 'longitude': -73.921577},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '200 E 161st St',
#     'address2': '',
#     'address3': None,
#     'city': 'Bronx',
#     'zip_code': '10451',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 E 161st St', 'Bronx, NY 10451']},
#    'phone': '+17185901627',
#    'display_phone': '(718) 590-1627',
#    'distance': 14646.34486026932},
#   {'id': 'OhNqJhgpqXOuJbh9mjMZ9w',
#    'alias': '37-alley-queens-2',
#    'name': '37 Alley',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JE1DyPwH6QufTkm-5OugmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/37-alley-queens-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.76134, 'longitude': -73.83236},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '135-21 37th Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Queens',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['135-21 37th Ave', 'Queens, NY 11354']},
#    'phone': '+17189890888',
#    'display_phone': '(718) 989-0888',
#    'distance': 14987.49817069004},
#   {'id': 'hAVrIoUHtbM16EigWMJvjA',
#    'alias': 'mon-cher-market-new-york',
#    'name': 'Mon Cher Market',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ffUZZAYTutjbZ2JOv2crLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mon-cher-market-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.716682, 'longitude': -74.004707},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '339 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['339 Broadway', 'New York, NY 10013']},
#    'phone': '+12129650007',
#    'display_phone': '(212) 965-0007',
#    'distance': 1515.2969188038849},
#   {'id': 'QPTxlH9KxraVczH-Ckntxg',
#    'alias': 'delicacy-new-york',
#    'name': 'Delicacy',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/G5iEAoEsrgJvbVH0g6zkWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/delicacy-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.754207, 'longitude': -73.979179},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '12 E 44th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['12 E 44th St', 'New York, NY 10017']},
#    'phone': '+12126974444',
#    'display_phone': '(212) 697-4444',
#    'distance': 5569.91749060809},
#   {'id': '0XC6L2GCtuaNEI8XFEyD2g',
#    'alias': 'jungle-cafe-brooklyn-2',
#    'name': 'Jungle Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/f5uyfDQBe_ICo7v9qniDyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jungle-cafe-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 267,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.730358, 'longitude': -73.954885},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '131 Greenpoint Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['131 Greenpoint Ave', 'Brooklyn, NY 11222']},
#    'phone': '+13479874981',
#    'display_phone': '(347) 987-4981',
#    'distance': 4324.895871335414},
#   {'id': 'oLcO1966IMx-Juv69hn6Cw',
#    'alias': 'copacabana-astoria',
#    'name': 'Copacabana',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Jre3puot4GIfvnY0HOETuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/copacabana-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 242,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7565371, 'longitude': -73.9293383},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '31-13 36th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31-13 36th Ave', 'Astoria, NY 11106']},
#    'phone': '+17185453685',
#    'display_phone': '(718) 545-3685',
#    'distance': 7895.225805254095},
#   {'id': 'rGfDX_ors68i8LnuG55NQA',
#    'alias': 'bagel-buffet-new-york-116',
#    'name': 'Bagel Buffet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/juaJYOWLzNXdv0D0Zm2d0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagel-buffet-new-york-116?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73691631697569,
#     'longitude': -73.99693574914174},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '510 Ave Of Americas',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['510 Ave Of Americas', 'New York, NY 10011']},
#    'phone': '+12129248911',
#    'display_phone': '(212) 924-8911',
#    'distance': 3506.5407245881674},
#   {'id': 'EKY8DwZVWpkgv6IWrepbWg',
#    'alias': 'namaste-brooklyn-2',
#    'name': 'Namaste',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/b5pMz-kvph2QPKDjiYID4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/namaste-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 248,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'halal', 'title': 'Halal'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.676687, 'longitude': -73.979965},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '195 5th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['195 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17188571951',
#    'display_phone': '(718) 857-1951',
#    'distance': 3418.304198146482},
#   {'id': '7OMGEtFWT6sdd9TVuoGqJQ',
#    'alias': 'okonomi-brooklyn',
#    'name': 'Okonomi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RMSBnhoB5aHc-3CUSwULgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/okonomi-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 466,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.712622, 'longitude': -73.9487843},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '150 Ainslie St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 Ainslie St', 'Brooklyn, NY 11211']},
#    'phone': '+19292950480',
#    'display_phone': '(929) 295-0480',
#    'distance': 3918.0469578683437},
#   {'id': 'VnjcxOUuZAeJMiDIU-7hUQ',
#    'alias': 'churrascaria-plataforma-new-york-3',
#    'name': 'Churrascaria Plataforma',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/K4tRCt5Gzwvfnp-0nwb8vA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/churrascaria-plataforma-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1386,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76202, 'longitude': -73.98765},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$$',
#    'location': {'address1': '316 W 49th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['316 W 49th St', 'New York, NY 10019']},
#    'phone': '+12122450505',
#    'display_phone': '(212) 245-0505',
#    'distance': 6304.956424027397},
#   {'id': 'gEs8gD2QSZCgApM2yG19PQ',
#    'alias': 'the-mighty-crab-long-island-city',
#    'name': 'The Mighty Crab',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8dH3SQNftuJ0G1n0FXB7JA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mighty-crab-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.752303, 'longitude': -73.9145444},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '34-45 48th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['34-45 48th St', 'Long Island City, NY 11101']},
#    'phone': '+17182788889',
#    'display_phone': '(718) 278-8889',
#    'distance': 8503.28713166641},
#   {'id': '7YJxZAvMxB-oVZfHAuvBmw',
#    'alias': 'lakruwana-restaurant-staten-island-2',
#    'name': 'Lakruwana Restaurant ',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kuerfRTidkJmKHmdoE0pyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lakruwana-restaurant-staten-island-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 348,
#    'categories': [{'alias': 'srilankan', 'title': 'Sri Lankan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.62571, 'longitude': -74.075373},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '668 Bay St',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['668 Bay St', 'Staten Island, NY 10304']},
#    'phone': '+13478576619',
#    'display_phone': '(347) 857-6619',
#    'distance': 11197.065298631001},
#   {'id': 'MFYh1htbCY8naZfkdF9rEQ',
#    'alias': 'lan-ting-hotpot-brooklyn',
#    'name': 'Lan Ting Hotpot',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cyni0WODa244JQ5cBOTONQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lan-ting-hotpot-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 258,
#    'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.637494, 'longitude': -74.010961},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '705 59th St',
#     'address2': 'Ste BC',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11220',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['705 59th St', 'Ste BC', 'Brooklyn, NY 11220']},
#    'phone': '+13472277698',
#    'display_phone': '(347) 227-7698',
#    'distance': 7685.432040920216},
#   {'id': 'ONQRhDuWv0e9R5xOiI7YAA',
#    'alias': 'gyu-kaku-japanese-bbq-new-york-3',
#    'name': 'Gyu-Kaku Japanese BBQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ONxhOlpk4f0ZuWxCyDtCuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gyu-kaku-japanese-bbq-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1261,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75908, 'longitude': -73.98989},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '321 W 44th St',
#     'address2': 'Unit 103',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['321 W 44th St', 'Unit 103', 'New York, NY 10036']},
#    'phone': '+16466929115',
#    'display_phone': '(646) 692-9115',
#    'distance': 5987.473305453897},
#   {'id': 'n5gyy4Oh4puCFfJVkoF-2A',
#    'alias': 'metro-buffet-brooklyn',
#    'name': 'Metro Buffet',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FPQefTB69DeOIdAuY2Hf7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/metro-buffet-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6884, 'longitude': -73.98902},
#    'transactions': [],
#    'location': {'address1': '296 Atlantic Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['296 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1945.7680888413047},
#   {'id': '_vQugjzPLr-4udYpiISieA',
#    'alias': 'gopchang-story-bbq-new-york',
#    'name': 'Gopchang Story BBQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9iWQClZDB5Zm_0c1JgxtEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gopchang-story-bbq-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 438,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74701, 'longitude': -73.98583},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '312 5th Ave',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['312 5th Ave', 'Fl 2', 'New York, NY 10001']},
#    'phone': '+16463719469',
#    'display_phone': '(646) 371-9469',
#    'distance': 4678.771765245314},
#   {'id': 'wRHUJ69-f4CiV5BRY72mUg',
#    'alias': 'aqua-boil-new-york-2',
#    'name': 'Aqua Boil',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wREsz4nOI5oGdYrRiOG1uA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aqua-boil-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 415,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.763702, 'longitude': -73.988386},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '750 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['750 9th Ave', 'New York, NY 10019']},
#    'phone': '+12124647428',
#    'display_phone': '(212) 464-7428',
#    'distance': 6497.896610888184},
#   {'id': 'CHlSivNP8U8R5ARvXvz8QQ',
#    'alias': 'spring-shabu-shabu-flushing-6',
#    'name': 'Spring Shabu-Shabu',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Fn0zzqoTMvGyR6zwX3fgkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spring-shabu-shabu-flushing-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1210,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.760924701904784,
#     'longitude': -73.83002707689919},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '136 20 38th Ave',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136 20 38th Ave', 'Fl 2', 'Flushing, NY 11354']},
#    'phone': '+17183958076',
#    'display_phone': '(718) 395-8076',
#    'distance': 15153.414250350035},
#   {'id': 'clNwADxHkEgI8Vx0F5xhBQ',
#    'alias': 'golden-corral-bronx',
#    'name': 'Golden Corral',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gXi0W9ntMsProbjNQ4lKLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/golden-corral-bronx?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.84258, 'longitude': -73.85529},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '2375 E Tremont Ave',
#     'address2': 'Ste 2674',
#     'address3': None,
#     'city': 'Bronx',
#     'zip_code': '10462',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2375 E Tremont Ave', 'Ste 2674', 'Bronx, NY 10462']},
#    'phone': '+17188925200',
#    'display_phone': '(718) 892-5200',
#    'distance': 19226.101972974222},
#   {'id': '1GtTDS6YRwbBS-seP_iPXg',
#    'alias': 'mr-fulton-brooklyn-3',
#    'name': 'Mr. Fulton',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bdWU97wFZMcFV2-5iSaaNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-fulton-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'soulfood', 'title': 'Soul Food'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6914707448577,
#     'longitude': -73.9864613407883},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '156 Lawrence St',
#     'address2': 'Ste A',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156 Lawrence St', 'Ste A', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1688.3050733082969},
#   {'id': 'fEiqFzk4Z-kbdzHIeu_tjA',
#    'alias': 'k-and-k-super-buffet-ridgewood',
#    'name': 'K&K Super Buffet',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/N4YII79x6kcoupCwVVSmHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/k-and-k-super-buffet-ridgewood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 82,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.700904, 'longitude': -73.909247},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '341 St Nicholas Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['341 St Nicholas Ave', 'Ridgewood, NY 11385']},
#    'phone': '+17183817111',
#    'display_phone': '(718) 381-7111',
#    'distance': 7186.863478229478},
#   {'id': 'Ea2ud4oD4IsExoyfmDMjAA',
#    'alias': 'djs-buffet-garden-city',
#    'name': "DJ's Buffet",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Hf-6k3VvmKRAeakRotOMew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/djs-buffet-garden-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 373,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.735192, 'longitude': -73.592292},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1100 Stewart Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Garden City',
#     'zip_code': '11530',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1100 Stewart Ave', 'Garden City, NY 11530']},
#    'phone': '+15162272472',
#    'display_phone': '(516) 227-2472',
#    'distance': 34039.66451541296},
#   {'id': 'yl_IA_EAnWjObw72xrTWpg',
#    'alias': 'hibachi-grill-and-supreme-buffet-jersey-city',
#    'name': 'Hibachi Grill & Supreme Buffet',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Sw058tGIJPllTk4I3ekCzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hibachi-grill-and-supreme-buffet-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 109,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'teppanyaki', 'title': 'Teppanyaki'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7214652189858,
#     'longitude': -74.0955440349182},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Hudson Mall',
#     'address2': '',
#     'address3': '701 Rte 440',
#     'city': 'Jersey City',
#     'zip_code': '07304',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['Hudson Mall',
#      '701 Rte 440',
#      'Jersey City, NJ 07304']},
#    'phone': '+12018600007',
#    'display_phone': '(201) 860-0007',
#    'distance': 8717.724271127103},
#   {'id': 'lMtmOKihaiUBq8T2xHvfOg',
#    'alias': 'o2-bbq-bayside',
#    'name': 'O2 BBQ',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/l30b5ssi5pdqjekdFgn6YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/o2-bbq-bayside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 439,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7589126, 'longitude': -73.7683094},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '45-53 Bell Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45-53 Bell Blvd', 'Bayside, NY 11361']},
#    'phone': '+17182241253',
#    'display_phone': '(718) 224-1253',
#    'distance': 19947.93948804385},
#   {'id': 'cMuHouN7_VzSsm6NsSkyAQ',
#    'alias': 'icook-buffet-elmhurst',
#    'name': 'iCook Buffet',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/R8pjR9k_5numAhpIk06eCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/icook-buffet-elmhurst?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 277,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7432600908448,
#     'longitude': -73.883305080235},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '81-17 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81-17 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+19295220889',
#    'display_phone': '(929) 522-0889',
#    'distance': 10254.675548557047},
#   {'id': 'ug5ZILy-nRz9nWAFHuw4Uw',
#    'alias': 'kimpanadas-brooklyn-2',
#    'name': 'Kimpanadas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yeKhQGulNVA4cY4faLdK6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kimpanadas-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'empanadas', 'title': 'Empanadas'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.684003810446335,
#     'longitude': -73.99253871291877},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '228 Smith St',
#     'address2': '',
#     'address3': 'Finns Corner Bar',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 Smith St',
#      'Finns Corner Bar',
#      'Brooklyn, NY 11231']},
#    'phone': '+19174556477',
#    'display_phone': '(917) 455-6477',
#    'distance': 2388.717933007183},
#   {'id': 'NgD-6ogFGc_c4z5_Ur4k2g',
#    'alias': 'dhaba-indian-cuisine-new-york',
#    'name': 'Dhaba Indian Cuisine',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CYFN3-f1tqhtW2kK4Wb8AA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dhaba-indian-cuisine-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1501,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.742364, 'longitude': -73.982813},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '108 Lexington Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['108 Lexington Ave', 'New York, NY 10016']},
#    'phone': '+12126791284',
#    'display_phone': '(212) 679-1284',
#    'distance': 4217.670134583849},
#   {'id': 'H1jops1lmuhrq9lP7lEGJQ',
#    'alias': 'flor-de-mayo-new-york-2',
#    'name': 'Flor De Mayo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/upMdi6U9mtbpAxkbl5ikdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flor-de-mayo-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1229,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78609, 'longitude': -73.97658},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '484 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['484 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12127873388',
#    'display_phone': '(212) 787-3388',
#    'distance': 9088.843494696126},
#   {'id': 'm9Q9x-Hcxp24gZCaTTJY-A',
#    'alias': 'sahib-new-york',
#    'name': 'Sahib',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ipDmOefiP1PQMWPUuvTNew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sahib-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 258,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74232, 'longitude': -73.9830099},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '104 Lexington Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['104 Lexington Ave', 'New York, NY 10016']},
#    'phone': '+16465900994',
#    'display_phone': '(646) 590-0994',
#    'distance': 4207.609609253024},
#   {'id': 'j9TdOBSQ1LRw8v3hW5fObQ',
#    'alias': 'pies-n-thighs-brooklyn',
#    'name': 'Pies-n-Thighs',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZEox6v_ipIvcrzeRv9mFIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pies-n-thighs-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3007,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.711191, 'longitude': -73.961424},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '166 S 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['166 S 4th St', 'Brooklyn, NY 11211']},
#    'phone': '+13475296090',
#    'display_phone': '(347) 529-6090',
#    'distance': 2843.269690474491},
#   {'id': '1yqrirjDVm40roP-NcU-Ig',
#    'alias': 'komorebi-full-house-brooklyn',
#    'name': 'Komorebi Full House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gow9AoBwtJllLgYfAM8VjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/komorebi-full-house-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.630169, 'longitude': -74.004041},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '6201 11th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11219',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6201 11th Ave', 'Brooklyn, NY 11219']},
#    'phone': '+17188772828',
#    'display_phone': '(718) 877-2828',
#    'distance': 8410.563952753604},
#   {'id': 'Ot8hO6DqtS1QWIqyxPnxFw',
#    'alias': 'm2n-cafeteria-new-york',
#    'name': 'M2n Cafeteria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fToSidzUuSrO7MUJKJ9FVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/m2n-cafeteria-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7471809, 'longitude': -73.8841095},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '40-12 82nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40-12 82nd St', 'New York, NY 11373']},
#    'phone': '+17188032488',
#    'display_phone': '(718) 803-2488',
#    'distance': 10388.07485970504},
#   {'id': 'iHiEMvbpLzNYTMsd5-VnQw',
#    'alias': 'jacob-soul-food-restaurant-new-york-2',
#    'name': 'Jacob Soul Food Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RtJtywyJaXdMs82m1Tlckw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jacob-soul-food-restaurant-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 364,
#    'categories': [{'alias': 'soulfood', 'title': 'Soul Food'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.810025, 'longitude': -73.9439219},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '373 Lenox Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['373 Lenox Ave', 'New York, NY 10027']},
#    'phone': '+12128663663',
#    'display_phone': '(212) 866-3663',
#    'distance': 12378.541594040064}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                            Restaurant        Type Price Rating  \
# 0  Crab House All You Can Eat Seafood     Buffets  $$$$    4.5
# 1                          The Buffet     Buffets   $$$    3.5
# 2                          Let's Meat      Korean   $$$      4
# 3                              Mizumi  Sushi Bars   $$$    3.5
# 4                          66S Fusion  Sushi Bars    $$      4
#
#                 Address        Lat        Lng  \
# 0         135 E 55th St  40.759664 -73.969776
# 1        20-07 127th St  40.781399 -73.841297
# 2           307 5th Ave  40.746774 -73.985524
# 3  231-10 Northern Blvd  40.763570 -73.749000
# 4      130 Flushing Ave  40.697760 -73.971574
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/crab-house-all-you-ca...  YvWQMlMjtYmVmheH97tTlQ
# 1  https://www.yelp.com/biz/the-buffet-flushing?a...  w2oSwwvOf-DBnEUumq_TIA
# 2  https://www.yelp.com/biz/lets-meat-new-york?ad...  t_UObgQX6M_ZRn3tk2cXYQ
# 3  https://www.yelp.com/biz/mizumi-douglaston?adj...  aBcQo4Xy-Lcf3JfVcn94XA
# 4  https://www.yelp.com/biz/66s-fusion-brooklyn?a...  HGLH-sa-Fp3X6UXcaG7U0g

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"buffet","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': '7B2XMvV5uGuKyl19-HTSvg',
#    'alias': 'fogo-de-chao-brazilian-steakhouse-new-york-6',
#    'name': 'Fogo de Chao Brazilian Steakhouse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vTXZ-X3j0pB089Mc14Q7-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fogo-de-chao-brazilian-steakhouse-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1344,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7610765, 'longitude': -73.9777711},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$$',
#    'location': {'address1': '40 W 53rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40 W 53rd St', 'New York, NY 10019']},
#    'phone': '+12129699980',
#    'display_phone': '(212) 969-9980',
#    'distance': 6340.661082588139},
#   {'id': 'MM5i395oQHBP-9XtJrsO3A',
#    'alias': 'tokyo-hibachi-asian-cuisine-and-buffet-secaucus',
#    'name': 'Tokyo Hibachi Asian Cuisine & Buffet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/I_igRPlzFWsU2XZEsr8hVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tokyo-hibachi-asian-cuisine-and-buffet-secaucus?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 283,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.7862203603794,
#     'longitude': -74.0456456185952},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '700 Plaza Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Secaucus',
#     'zip_code': '07094',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['700 Plaza Dr', 'Secaucus, NJ 07094']},
#    'phone': '+12018632828',
#    'display_phone': '(201) 863-2828',
#    'distance': 9969.341988738293},
#   {'id': '91tQ4ToReVVCA5MTJi9gfw',
#    'alias': 'iron-chef-house-brooklyn',
#    'name': 'Iron Chef House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bOvogEht3LihX4PHkWsfzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/iron-chef-house-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 424,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69722956441029,
#     'longitude': -73.99262170000003},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '92 Clark St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['92 Clark St', 'Brooklyn, NY 11201']},
#    'phone': '+17188588517',
#    'display_phone': '(718) 858-8517',
#    'distance': 924.3021819050917},
#   {'id': 'QQfwlKFD6X8-ZXf7gfQZqg',
#    'alias': 'hardee-new-york-4',
#    'name': 'Hardee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/w2rSwrMnLYsmVnlRcrZvrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hardee-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6933441162109,
#     'longitude': -73.9722290039062},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '351 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['351 Myrtle Ave', 'New York, NY 11205']},
#    'phone': '+13478897210',
#    'display_phone': '(347) 889-7210',
#    'distance': 2295.6999778208606},
#   {'id': 'tjstlcFtOiXnUU1MAG1uqg',
#    'alias': 'villa-brazil-cafe-grill-astoria',
#    'name': 'Villa Brazil Cafe Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pB17U8Dav84IY31IHBCsOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/villa-brazil-cafe-grill-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 337,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7552896059395,
#     'longitude': -73.9180071651936},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '43-16 34th Ave',
#     'address2': '',
#     'address3': 'Ste A 2',
#     'city': 'Astoria',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43-16 34th Ave', 'Ste A 2', 'Astoria, NY 11101']},
#    'phone': '+13476704202',
#    'display_phone': '(347) 670-4202',
#    'distance': 8487.553276773537},
#   {'id': 'hfMtSdxRsC3JQP3yrm6nag',
#    'alias': 'claw-daddys-new-york',
#    'name': "Claw Daddy's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RCru71cTtO-TtqRw50rc2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/claw-daddys-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1769,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722071, 'longitude': -73.98847},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '185 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['185 Orchard St', 'New York, NY 10002']},
#    'phone': '+16465906816',
#    'display_phone': '(646) 590-6816',
#    'distance': 1912.7787900899964},
#   {'id': '2LcsDUTlvovnFz-SEcSJTQ',
#    'alias': 'astoria-seafood-long-island-city',
#    'name': 'Astoria Seafood',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1JpV37tvXerudsIowCpMMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/astoria-seafood-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 776,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.754, 'longitude': -73.9298699},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '37-10 33rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37-10 33rd St', 'Long Island City, NY 11101']},
#    'phone': '+17183922680',
#    'display_phone': '(718) 392-2680',
#    'distance': 7657.624763799523},
#   {'id': 'LpVbI-E9C-CSp7WhU5h2Iw',
#    'alias': 'fishmarket-restaurant-new-york',
#    'name': 'Fishmarket Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zIPbObERXHKehqV-yU7Wgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fishmarket-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 579,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'divebars', 'title': 'Dive Bars'},
#     {'alias': 'malaysian', 'title': 'Malaysian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70717, 'longitude': -74.00192},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '111 South St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 South St', 'New York, NY 10038']},
#    'phone': '+19173638101',
#    'display_phone': '(917) 363-8101',
#    'distance': 667.9406968270184},
#   {'id': 'SU0_Hd_ET94_maeuIB0_vg',
#    'alias': 'flaming-grill-and-supreme-buffet-staten-island',
#    'name': 'Flaming Grill & Supreme Buffet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/J9TMGxc4M8dmn0xqN5AS2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flaming-grill-and-supreme-buffet-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 132,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.6244187, 'longitude': -74.1386512},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1501 Forest Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10302',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1501 Forest Ave', 'Staten Island, NY 10302']},
#    'phone': '+17184476888',
#    'display_phone': '(718) 447-6888',
#    'distance': 14957.334922887116},
#   {'id': 'iIWMaISFp4K50oHFfq2Oxw',
#    'alias': 'the-cast-iron-pot-fairview-2',
#    'name': 'The Cast Iron Pot',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WQ78cgoBPraUuwNvY6FMLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cast-iron-pot-fairview-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 805,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.82128, 'longitude': -73.99911},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '356 Bergen Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Fairview',
#     'zip_code': '07022',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['356 Bergen Blvd', 'Fairview, NJ 07022']},
#    'phone': '+12018401870',
#    'display_phone': '(201) 840-1870',
#    'distance': 12893.974159528187},
#   {'id': 'AAPJkyU0Y7Aci0RZBdJONg',
#    'alias': 'shokunin-bbq-brooklyn-2',
#    'name': 'Shokunin BBQ',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KQpow_8fsy6UncAD9uT9TA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shokunin-bbq-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 294,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6332876204455,
#     'longitude': -74.0062164404754},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '952 60th St',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11219',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['952 60th St', 'Brooklyn, NY 11219']},
#    'phone': '+17188517888',
#    'display_phone': '(718) 851-7888',
#    'distance': 8086.281417047183},
#   {'id': 'mlGfXoxc8cEss8Yms6VrXg',
#    'alias': 'fette-sau-brooklyn',
#    'name': 'Fette Sau',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LhLuFryDtHTGDBytD09Kcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fette-sau-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2270,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.714066, 'longitude': -73.956327},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '354 Metropolitan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['354 Metropolitan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17189633404',
#    'display_phone': '(718) 963-3404',
#    'distance': 3340.604589727266},
#   {'id': '_kaQarBVxm8rHnyeFlCwTQ',
#    'alias': 'cafe-22-new-york-2',
#    'name': 'Cafe 22',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4ktYUHuMjvlMyppwEYRyFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-22-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7557116976974,
#     'longitude': -73.9872019943609},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '5 Times Sq',
#     'address2': 'Fl 22',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 Times Sq', 'Fl 22', 'New York, NY 10036']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5619.539146623216},
#   {'id': 'VQjDV6U3LcuiS19vPbbhlQ',
#    'alias': 'brazilian-buffet-newark',
#    'name': 'Brazilian Buffet',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/D2sWbdKDxT6F9KzXC7UWOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brazilian-buffet-newark?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7239952087402,
#     'longitude': -74.1521453857422},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '124 Wilson Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07105',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['124 Wilson Ave', 'Newark, NJ 07105']},
#    'phone': '+19735220080',
#    'display_phone': '(973) 522-0080',
#    'distance': 13466.100380044203},
#   {'id': '_X8K1SI2ikAYgxbpB8lBiQ',
#    'alias': 'east-buffet-and-restaurant-flushing',
#    'name': 'East Buffet & Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WOQpqSRxqmh6eo8sam5Hfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/east-buffet-and-restaurant-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 373,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.7550707, 'longitude': -73.8280097},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4207 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11355',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4207 Main St', 'Flushing, NY 11355']},
#    'phone': '+17183536333',
#    'display_phone': '(718) 353-6333',
#    'distance': 15064.75442917307},
#   {'id': 'NlgC8TjNuf8sy6qg2xpqsQ',
#    'alias': 'yuka-japanese-restaurant-new-york-2',
#    'name': 'Yuka Japanese Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oFLclOqJiR_DYUpND8CWYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yuka-japanese-restaurant-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 577,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.77463, 'longitude': -73.95447},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1557 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1557 2nd Ave', 'New York, NY 10028']},
#    'phone': '+12127729675',
#    'display_phone': '(212) 772-9675',
#    'distance': 8393.377134147824},
#   {'id': 'nsAU6F2vmdnphmfIa_RuWg',
#    'alias': 'mables-smokehouse-and-banquet-hall-brooklyn-6',
#    'name': "Mable's Smokehouse & Banquet Hall",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OS2cqRCWCOioXnpLo-yeHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mables-smokehouse-and-banquet-hall-brooklyn-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 909,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7211890204726,
#     'longitude': -73.9570004492998},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '44 Berry St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['44 Berry St', 'Brooklyn, NY 11249']},
#    'phone': '+17182186655',
#    'display_phone': '(718) 218-6655',
#    'distance': 3597.829928403173},
#   {'id': 'lynQoI3w_pzYfHGeuUU-Qg',
#    'alias': 'shu-jiao-fu-zhou-cuisine-restaurant-new-york',
#    'name': 'Shu Jiao Fu Zhou Cuisine Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EV10p_mweh7C1qjrLUJePw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shu-jiao-fu-zhou-cuisine-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 912,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7174109, 'longitude': -73.9920876},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '295 Grand St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['295 Grand St', 'New York, NY 10002']},
#    'phone': '+12126252532',
#    'display_phone': '(212) 625-2532',
#    'distance': 1343.4851190479994},
#   {'id': 'vWQLcEnV7qwHPJvKOcxR5w',
#    'alias': 'ninja-86-sushi-brooklyn',
#    'name': 'Ninja 86 Sushi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_0-ZVKeoPr1cJUMNvlXUjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ninja-86-sushi-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 106,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6006799, 'longitude': -73.99208},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2274 86th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2274 86th St', 'Brooklyn, NY 11214']},
#    'phone': '+17187577997',
#    'display_phone': '(718) 757-7997',
#    'distance': 11657.099973110611},
#   {'id': 'LeaMwZ8W2wmw6ZmVPnCLAg',
#    'alias': 'the-cast-iron-pot-3-flushing',
#    'name': 'The Cast Iron Pot 3',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dZF-CurfXWYJhC7lUD23Yw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cast-iron-pot-3-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 349,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.763328, 'longitude': -73.8076273},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '157-26 Northern Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['157-26 Northern Blvd', 'Flushing, NY 11354']},
#    'phone': '+13473686255',
#    'display_phone': '(347) 368-6255',
#    'distance': 16993.921880917722},
#   {'id': 'eZRCx_bsjOsrwsfrAPYEew',
#    'alias': 'brazeiro-churrascaria-north-bergen-2',
#    'name': 'Brazeiro Churrascaria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6-8AJav-4WqVKA-CcmLhGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brazeiro-churrascaria-north-bergen-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 354,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.796315, 'longitude': -74.002996},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '7420 Broadway Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'North Bergen',
#     'zip_code': '07047',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['7420 Broadway Ave', 'North Bergen, NJ 07047']},
#    'phone': '+12016621212',
#    'display_phone': '(201) 662-1212',
#    'distance': 10130.845601413685},
#   {'id': '-J8VuX3wGrYSOBu2G0hMsw',
#    'alias': 'katsu-hama-new-york',
#    'name': 'Katsu-Hama',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pOcVelVViCscikDfwsRcUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/katsu-hama-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1377,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75638, 'longitude': -73.97759},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '11 E 47th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 E 47th St', 'New York, NY 10017']},
#    'phone': '+12127585909',
#    'display_phone': '(212) 758-5909',
#    'distance': 5841.3064284782295},
#   {'id': 'Zjdtcex73QIz2_MvEvDrFQ',
#    'alias': 'makimaki-new-york-2',
#    'name': 'MakiMaki',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qN2QqervoYAaevmgxutfLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/makimaki-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 197,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7633913312621,
#     'longitude': -73.9780393019703},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1369 6th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1369 6th Ave', 'New York, NY 10019']},
#    'phone': '+12122454550',
#    'display_phone': '(212) 245-4550',
#    'distance': 6587.279720344749},
#   {'id': 'AhQW6ScNWmr2ivtd3lJS2Q',
#    'alias': 'royal-hibachi-buffet-saddle-brook',
#    'name': 'Royal Hibachi Buffet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/R8Eb-FaDcWVT2GlvMF1agg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/royal-hibachi-buffet-saddle-brook?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 149,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.8918830801602,
#     'longitude': -74.0945870429277},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '189 Rte 46 W',
#     'address2': None,
#     'address3': '',
#     'city': 'Saddle Brook',
#     'zip_code': '07663',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['189 Rte 46 W', 'Saddle Brook, NJ 07663']},
#    'phone': '+12019685886',
#    'display_phone': '(201) 968-5886',
#    'distance': 22384.03126748802},
#   {'id': 'eo3ML5g-Nt9vsvUfWqg-1w',
#    'alias': 'gorilla-grill-cliffside-park',
#    'name': 'Gorilla Grill',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ezf9Jmh3z5Y0ocSansr-xw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gorilla-grill-cliffside-park?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 154,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8247299665005,
#     'longitude': -73.9880000799894},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '606 Anderson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Cliffside Park',
#     'zip_code': '07010',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['606 Anderson Ave', 'Cliffside Park, NJ 07010']},
#    'phone': '+12019175023',
#    'display_phone': '(201) 917-5023',
#    'distance': 13274.467977524184},
#   {'id': 'GjAHO7PA-3Sxg1lkGza4sQ',
#    'alias': 'b-and-b-restaurant-corporation-new-york',
#    'name': 'B&B Restaurant Corporation',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1K16MSCu2unC9HVUqnhDBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b-and-b-restaurant-corporation-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 159,
#    'categories': [{'alias': 'african', 'title': 'African'},
#     {'alias': 'caribbean', 'title': 'Caribbean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7459112, 'longitude': -73.9936086},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '165 West 26th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['165 West 26th St', 'New York, NY 10001']},
#    'phone': '+16464298174',
#    'display_phone': '(646) 429-8174',
#    'distance': 4500.01604276325},
#   {'id': '_saXnBy0Wq2Gb3YusWZhqw',
#    'alias': 'five-senses-new-york',
#    'name': 'Five Senses',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Wxh01qA7K-xUVM-0pqBCdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/five-senses-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1514,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.747573158626,
#     'longitude': -73.9863122632311},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '9 W 32nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 W 32nd St', 'New York, NY 10001']},
#    'phone': '+12124410005',
#    'display_phone': '(212) 441-0005',
#    'distance': 4732.477702641706},
#   {'id': 'tiSw-6DIm3-mMORyEIOVyg',
#    'alias': 'the-boil-new-york-3',
#    'name': 'The Boil',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oWCJBXN8cM-nGi83pNqc5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-boil-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1972,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71974, 'longitude': -73.99339},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '139 Chrystie St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['139 Chrystie St', 'New York, NY 10002']},
#    'phone': '+12129258815',
#    'display_phone': '(212) 925-8815',
#    'distance': 1594.3621278980172},
#   {'id': 'TeBthQZ2xpxyvXheS08ovw',
#    'alias': 'blue-ribbon-sushi-izakaya-new-york',
#    'name': 'Blue Ribbon Sushi Izakaya',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nNZlFOGfiiznMr5N2UT5eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-ribbon-sushi-izakaya-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 532,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7220839812692,
#     'longitude': -73.9882245327093},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '187 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['187 Orchard St', 'New York, NY 10002']},
#    'phone': '+12124660404',
#    'display_phone': '(212) 466-0404',
#    'distance': 1919.5827489838694},
#   {'id': 'D3LtTiVtIPOcUT_bjxztRA',
#    'alias': 'teppan-bar-and-grill-jersey-city',
#    'name': 'Teppan Bar & Grill',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/N552diJ4cgJND6P1wiUYPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/teppan-bar-and-grill-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 559,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'teppanyaki', 'title': 'Teppanyaki'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.718919, 'longitude': -74.038909},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '319 Warren St',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['319 Warren St', 'Jersey City, NJ 07302']},
#    'phone': '+12014519989',
#    'display_phone': '(201) 451-9989',
#    'distance': 4047.9310244351686},
#   {'id': '_7jEITBmNIMD73_ni89MaQ',
#    'alias': 'kpot-korean-bbq-and-hot-pot-jersey-city-3',
#    'name': 'KPOT Korean BBQ & Hot Pot',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xlEckVboaTWbmluLIwkbWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kpot-korean-bbq-and-hot-pot-jersey-city-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 184,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71834, 'longitude': -74.0529},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '414 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['414 Grand St', 'Jersey City, NJ 07302']},
#    'phone': '+12013569528',
#    'display_phone': '(201) 356-9528',
#    'distance': 5082.697352894614},
#   {'id': 'bvADKEK_ZebdskpQ59E58Q',
#    'alias': 'flaming-grill-and-supreme-buffet-newark',
#    'name': 'Flaming Grill & Supreme Buffet',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wxZWC6WibL0wxeQqRn8FCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flaming-grill-and-supreme-buffet-newark?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.727234, 'longitude': -74.148996},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '293 Ferry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07105',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['293 Ferry St', 'Newark, NJ 07105']},
#    'phone': '+19735891108',
#    'display_phone': '(973) 589-1108',
#    'distance': 13261.53667843652},
#   {'id': '6qYic55Ho8xEL_iWxlrGSg',
#    'alias': 'zous-restaurant-crown-heights',
#    'name': "Zou's Restaurant",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4Lwl0yfaOJAKWGmDlAuEwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zous-restaurant-crown-heights?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'diyfood', 'title': 'Do-It-Yourself Food'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.670791, 'longitude': -73.930656},
#    'transactions': [],
#    'location': {'address1': '233 Utica Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Crown Heights',
#     'zip_code': '11213',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['233 Utica Ave', 'Crown Heights, NY 11213']},
#    'phone': '+17188778599',
#    'display_phone': '(718) 877-8599',
#    'distance': 6599.889616656614},
#   {'id': 'RQRQOO_CGhj16AIz4KqlQA',
#    'alias': 'fu-zhou-wei-zhong-wei-jia-xiang-feng-wei-new-york',
#    'name': 'Fu Zhou Wei Zhong Wei Jia Xiang Feng Wei',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GOyfeeZPCmfOdQSyuvYCRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fu-zhou-wei-zhong-wei-jia-xiang-feng-wei-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.713837, 'longitude': -73.99414},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '88 E Broadway',
#     'address2': '',
#     'address3': 'Stall B45',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['88 E Broadway', 'Stall B45', 'New York, NY 10002']},
#    'phone': '+12124313555',
#    'display_phone': '(212) 431-3555',
#    'distance': 933.2512172402797},
#   {'id': '_dhsOIr9dfCBuaAM6lX7vA',
#    'alias': 'new-china-buffet-staten-island',
#    'name': 'New China Buffet',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SczTGSaVs2YIXOe_tLJdCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-china-buffet-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 80,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.567711, 'longitude': -74.111769},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2626 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2626 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17189873388',
#    'display_phone': '(718) 987-3388',
#    'distance': 18243.344048348397},
#   {'id': 'SRMiVG2wNPwqXgEPXCxEOw',
#    'alias': 'la-fiesta-buffet-west-new-york',
#    'name': 'La Fiesta Buffet',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6hIUy2naYCWywkm7PtubkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-fiesta-buffet-west-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.79022, 'longitude': -74.01492},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '6100 Bergenline Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'West New York',
#     'zip_code': '07093',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['6100 Bergenline Ave', 'West New York, NJ 07093']},
#    'phone': '+12018696832',
#    'display_phone': '(201) 869-6832',
#    'distance': 9588.001721017332},
#   {'id': 'hWmzrNyhPO3phBstCynSvw',
#    'alias': 'rainhas-churrascaria-corona',
#    'name': 'Rainhas Churrascaria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xH96BCGSlSGlNgQbMp88YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rainhas-churrascaria-corona?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 896,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75824, 'longitude': -73.86068},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '108-01 Northern Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Corona',
#     'zip_code': '11368',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['108-01 Northern Blvd', 'Corona, NY 11368']},
#    'phone': '+17187798808',
#    'display_phone': '(718) 779-8808',
#    'distance': 12691.02061328291},
#   {'id': 'n5XiGT_J_5HtZ7VO_M4CxA',
#    'alias': 'century-super-buffet-queens-village',
#    'name': 'Century Super Buffet',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6hjtYvBr-ONMsUzzIRzBQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/century-super-buffet-queens-village?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 238,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7303973, 'longitude': -73.7431664},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '220-18 Hillside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Queens Village',
#     'zip_code': '11427',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['220-18 Hillside Ave', 'Queens Village, NY 11427']},
#    'phone': '+17184682100',
#    'display_phone': '(718) 468-2100',
#    'distance': 21346.263982199904},
#   {'id': 'a5-ChYM1t2Fl019KLPVBNw',
#    'alias': 'rakuzen-ayce-sushi-elmhurst-elmhurst',
#    'name': 'Rakuzen AYCE Sushi - Elmhurst',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HtjV-KetWwaVC44eLzY9ug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rakuzen-ayce-sushi-elmhurst-elmhurst?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 157,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.734813, 'longitude': -73.87346412883555},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '89-23 Queens Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['89-23 Queens Blvd', 'Elmhurst, NY 11373']},
#    'phone': '+17185058883',
#    'display_phone': '(718) 505-8883',
#    'distance': 10693.69777435318},
#   {'id': 'F72nO0bZqd87pIayCPWq7g',
#    'alias': 'originals-soldier-new-york',
#    'name': "Original's Soldier",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yFEvh-BUbzldoomn02NM9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/originals-soldier-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#     {'alias': 'macarons', 'title': 'Macarons'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6799545756352,
#     'longitude': -73.9425426721573},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1444 Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1444 Fulton St', 'New York, NY 11216']},
#    'phone': '+15168502774',
#    'display_phone': '(516) 850-2774',
#    'distance': 5202.904538143564},
#   {'id': 'E38Ozd_hRo7sy88iN3GRVQ',
#    'alias': 'china-buffet-king-valley-stream',
#    'name': 'China Buffet King',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Is3uzeycEoOgmRoKXKkaSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/china-buffet-king-valley-stream?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.665807, 'longitude': -73.703238},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '160 W Merrick Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Valley Stream',
#     'zip_code': '11580',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['160 W Merrick Rd', 'Valley Stream, NY 11580']},
#    'phone': '+15165681888',
#    'display_phone': '(516) 568-1888',
#    'distance': 24934.0541936515},
#   {'id': 'HZWHBfeuP4Fb6y8b8uqnbA',
#    'alias': 'sushi-yasaka-new-york',
#    'name': 'Sushi Yasaka',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kBzfFxtiN2eLH_XOPXIdsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-yasaka-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1831,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.779583, 'longitude': -73.983482},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '251 W 72nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['251 W 72nd St', 'New York, NY 10023']},
#    'phone': '+12124968460',
#    'display_phone': '(212) 496-8460',
#    'distance': 8293.93796491287},
#   {'id': 'OLSSJIp8pu5UlugTF7tuHA',
#    'alias': 'ootoya-chelsea-new-york',
#    'name': 'Ootoya Chelsea',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bBYOWD2DUwWaML3ADlcZ9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ootoya-chelsea-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1427,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'japacurry', 'title': 'Japanese Curry'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.738721, 'longitude': -73.99279},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '8 W 18th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8 W 18th St', 'New York, NY 10011']},
#    'phone': '+12122550018',
#    'display_phone': '(212) 255-0018',
#    'distance': 3705.421593464517},
#   {'id': 'eIPiRkf6KCo9A9Ok-Nr_ow',
#    'alias': 'miss-korea-bbq-new-york',
#    'name': 'Miss KOREA BBQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RuKe-K-VxPA1vtUWsj1suQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/miss-korea-bbq-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1929,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.747452, 'longitude': -73.986336},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '10 W 32nd St',
#     'address2': '1st, 2nd & Fl 3',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10 W 32nd St',
#      '1st, 2nd & Fl 3',
#      'New York, NY 10001']},
#    'phone': '+12125944963',
#    'display_phone': '(212) 594-4963',
#    'distance': 4718.858059205753},
#   {'id': 'P2bxlKAmRWZIpHdJ_JT3fg',
#    'alias': 'east-harbor-seafood-palace-brooklyn',
#    'name': 'East Harbor Seafood Palace',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8vLNECyXNwu_JOKg0tl4bQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/east-harbor-seafood-palace-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 709,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.633425, 'longitude': -74.014425},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '714 65th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11220',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['714 65th St', 'Brooklyn, NY 11220']},
#    'phone': '+17187650098',
#    'display_phone': '(718) 765-0098',
#    'distance': 8191.334745352622},
#   {'id': 'AtUxlW7ltZb73ZXMwpkY_g',
#    'alias': 'sashimi-ramen-express-new-york',
#    'name': 'Sashimi Ramen Express',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yuJYnJQuaJ4iXYWl9-FrMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sashimi-ramen-express-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 331,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.772239, 'longitude': -73.954052},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '341 E 78th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['341 E 78th St', 'New York, NY 10075']},
#    'phone': '+19292319376',
#    'display_phone': '(929) 231-9376',
#    'distance': 8164.397435277453},
#   {'id': 'Tl3-184IK6tovU5IvO-lNQ',
#    'alias': 'dynasty-buffet-saddle-brook',
#    'name': 'Dynasty Buffet',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5dIcDZCarfRjA1ayJ1aAwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dynasty-buffet-saddle-brook?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 234,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.89726, 'longitude': -74.09555},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '383 Market St',
#     'address2': '',
#     'address3': '',
#     'city': 'Saddle Brook',
#     'zip_code': '07663',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['383 Market St', 'Saddle Brook, NJ 07663']},
#    'phone': '+12012261388',
#    'display_phone': '(201) 226-1388',
#    'distance': 22974.94773512645},
#   {'id': 'gEfsayvqWqI2KfCF43TJ_A',
#    'alias': 'poc-american-fusion-and-sushi-hackensack',
#    'name': 'POC American Fusion and Sushi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lnxlvdmKZ75nZA3fV-N8DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/poc-american-fusion-and-sushi-hackensack?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 919,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.9096827672378,
#     'longitude': -74.0316456805744},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '450 Hackensack Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Hackensack',
#     'zip_code': '07601',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['450 Hackensack Ave', 'Hackensack, NJ 07601']},
#    'phone': '+12014880888',
#    'display_phone': '(201) 488-0888',
#    'distance': 22926.752614915717},
#   {'id': 'bxKK5doRz3SZceEws8Ya8g',
#    'alias': 'lian-jiang-restaurant-new-york-2',
#    'name': 'Lian Jiang Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-V7Mh7FtlUl1GUGlI1VG0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lian-jiang-restaurant-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7143117126122,
#     'longitude': -73.9938462769547},
#    'transactions': ['delivery'],
#    'location': {'address1': '88 Division St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['88 Division St', 'New York, NY 10002']},
#    'phone': '+16467157113',
#    'display_phone': '(646) 715-7113',
#    'distance': 986.6668551443622},
#   {'id': 'wpT1QU7PSQgQQ1DkzI00JA',
#    'alias': 'izakaya-toribar-new-york',
#    'name': 'Izakaya Toribar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lZig3aa5S2etRjst2WP4qw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-toribar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 87,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.759641, 'longitude': -73.9685558},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '164 E 56th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['164 E 56th St', 'New York, NY 10022']},
#    'phone': '+16467670029',
#    'display_phone': '(646) 767-0029',
#    'distance': 6404.650179251868}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                              Restaurant        Type Price Rating  \
# 0     Fogo de Chao Brazilian Steakhouse   Brazilian  $$$$      4
# 1  Tokyo Hibachi Asian Cuisine & Buffet    Japanese    $$    2.5
# 2                       Iron Chef House  Sushi Bars    $$      4
# 3                                Hardee     Chinese     $    4.5
# 4               Villa Brazil Cafe Grill   Brazilian    $$    4.5
#
#           Address        Lat        Lng  \
# 0    40 W 53rd St  40.761077 -73.977771
# 1    700 Plaza Dr  40.786220 -74.045646
# 2     92 Clark St  40.697230 -73.992622
# 3  351 Myrtle Ave  40.693344 -73.972229
# 4  43-16 34th Ave  40.755290 -73.918007
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/fogo-de-chao-brazilia...  7B2XMvV5uGuKyl19-HTSvg
# 1  https://www.yelp.com/biz/tokyo-hibachi-asian-c...  MM5i395oQHBP-9XtJrsO3A
# 2  https://www.yelp.com/biz/iron-chef-house-brook...  91tQ4ToReVVCA5MTJi9gfw
# 3  https://www.yelp.com/biz/hardee-new-york-4?adj...  QQfwlKFD6X8-ZXf7gfQZqg
# 4  https://www.yelp.com/biz/villa-brazil-cafe-gri...  tjstlcFtOiXnUU1MAG1uqg

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"buffet","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': '6Jjz97KPJ0jtmmIBCjReEw',
#    'alias': 'hou-yi-hot-pot-new-york',
#    'name': 'Hou Yi Hot Pot',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4WgLptcazALB91bnRKLtTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hou-yi-hot-pot-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 449,
#    'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7161793, 'longitude': -73.9925896},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '92 Hester St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['92 Hester St', 'New York, NY 10002']},
#    'phone': '+12129663420',
#    'display_phone': '(212) 966-3420',
#    'distance': 1202.2195344421025},
#   {'id': '2FuFCA8uaRXUjpC_X941jA',
#    'alias': '99-favor-taste-staten-island',
#    'name': '99 Favor Taste',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DQ9aUlib9x5rSrjYRFJrWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/99-favor-taste-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 159,
#    'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.57292, 'longitude': -74.11409},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '201 New Dorp Ln',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['201 New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+17188080066',
#    'display_phone': '(718) 808-0066',
#    'distance': 17857.924986897233},
#   {'id': 'NN3mOWF5e_pnR1ArqM2bHQ',
#    'alias': 'obao-new-york-3',
#    'name': 'OBAO',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CpVI2XJLrvg09Fm83bfPog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/obao-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2752,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7606544, 'longitude': -73.991332},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '647 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['647 9th Ave', 'New York, NY 10036']},
#    'phone': '+12122458880',
#    'display_phone': '(212) 245-8880',
#    'distance': 6144.081737145313},
#   {'id': '9MIkAs75TQzdwljVkUoZEg',
#    'alias': 'rakuzen-brooklyn',
#    'name': 'Rakuzen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Dd-bvGN4q2uM3lCYWoaNHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rakuzen-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 257,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.63112, 'longitude': -74.00903},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '6408 Fort Hamilton Pkwy',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11219',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6408 Fort Hamilton Pkwy', 'Brooklyn, NY 11219']},
#    'phone': '+17182380008',
#    'display_phone': '(718) 238-0008',
#    'distance': 8356.939976909101},
#   {'id': 'k_rLFIMOAbvchgWKEuKdtw',
#    'alias': 'kikoo-sushi-new-york-4',
#    'name': 'Kikoo Sushi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GvNbPRqcKLHfsKJbZ9bUpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kikoo-sushi-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 146,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8016099, 'longitude': -73.96164},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '998 Columbus Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['998 Columbus Ave', 'New York, NY 10025']},
#    'phone': '+12125332211',
#    'display_phone': '(212) 533-2211',
#    'distance': 11021.873387252632},
#   {'id': 'Hkg4b2x8LlYbq2molIFdhw',
#    'alias': 'kikoo-sushi-new-york-6',
#    'name': 'Kikoo Sushi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8XBhvyzAHRXs_STQ5FYWCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kikoo-sushi-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 706,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72808601890026,
#     'longitude': -73.98535905341164},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '141 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['141 1st Ave', 'New York, NY 10009']},
#    'phone': '+12125333888',
#    'display_phone': '(212) 533-3888',
#    'distance': 2627.7670105564384},
#   {'id': 'UuiW2A-O11Q0baqSEUMvZA',
#    'alias': 'miyabi-asian-fusion-staten-island',
#    'name': 'Miyabi Asian Fusion',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fTNQEULhPpZ6cRsCFp2Dkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/miyabi-asian-fusion-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 365,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6258092020868,
#     'longitude': -74.1345641477488},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1348 Forest Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10302',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1348 Forest Ave', 'Staten Island, NY 10302']},
#    'phone': '+17188768018',
#    'display_phone': '(718) 876-8018',
#    'distance': 14769.851027919054},
#   {'id': '-48FPDLFS26aSx4IYk05JA',
#    'alias': 'hibachi-grill-and-supreme-buffet-north-bergen',
#    'name': 'Hibachi Grill & Supreme Buffet',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DLO0HxZ21sv2GyUlwjkcXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hibachi-grill-and-supreme-buffet-north-bergen?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.8082974761147,
#     'longitude': -74.0182073260072},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '8101 Tonnelle Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'North Bergen',
#     'zip_code': '07047',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['8101 Tonnelle Ave', 'North Bergen, NJ 07047']},
#    'phone': '+12016621888',
#    'display_phone': '(201) 662-1888',
#    'distance': 11612.698366990124},
#   {'id': 'vSPKmk499CglpfJFuFvbvg',
#    'alias': 'food-station-new-york',
#    'name': 'Food Station',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SAKzAbOut-dTKwF9bzQe9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/food-station-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71802, 'longitude': -74.00038},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '244 Canal St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['244 Canal St', 'New York, NY 10013']},
#    'phone': '+16466092115',
#    'display_phone': '(646) 609-2115',
#    'distance': 1489.9228749998808},
#   {'id': 'm5Whyz8O8jM4DrE808h71g',
#    'alias': 'darbar-grill-new-york',
#    'name': 'Darbar Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9rN41wJJx8ic1fxNMnaslA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/darbar-grill-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 536,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.759357, 'longitude': -73.968826},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '157 E 55th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['157 E 55th St', 'New York, NY 10022']},
#    'phone': '+12127514600',
#    'display_phone': '(212) 751-4600',
#    'distance': 6367.237941554213},
#   {'id': 'mnj9O1tbCKiAN5zWMe5v8w',
#    'alias': 'picnic-garden-flushing',
#    'name': 'Picnic Garden',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0WT-6eG5S8x4sNwtysl4fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/picnic-garden-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1352,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.76489, 'longitude': -73.81062},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '154-05 Northern Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['154-05 Northern Blvd', 'Flushing, NY 11354']},
#    'phone': '+17183585959',
#    'display_phone': '(718) 358-5959',
#    'distance': 16833.803386292588},
#   {'id': 'x0k5kFArHLijdY8-NEQ7Xg',
#    'alias': 'bengal-tiger-indian-food-new-york',
#    'name': 'Bengal Tiger Indian Food',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UIX06NFq1Ux1mX4BGwMtGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bengal-tiger-indian-food-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2025,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.763167, 'longitude': -73.977131},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '58 W 56th St',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['58 W 56th St', 'Fl 2', 'New York, NY 10019']},
#    'phone': '+12122652703',
#    'display_phone': '(212) 265-2703',
#    'distance': 6579.278643154158},
#   {'id': 'rEWsz2KHmJX6jmAEQBa6Zw',
#    'alias': 'churrasqueria-jc-jersey-city-2',
#    'name': 'Churrasqueria JC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/x3V6wPvctFwbJOPRkb94nw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/churrasqueria-jc-jersey-city-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 129,
#    'categories': [{'alias': 'portuguese', 'title': 'Portuguese'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73103, 'longitude': -74.05597},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '542 Newak Av',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07304',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['542 Newak Av', 'Jersey City, NJ 07304']},
#    'phone': '+12019422620',
#    'display_phone': '(201) 942-2620',
#    'distance': 5922.845629767329},
#   {'id': 'wUu9WcGjP8KS6KlpARChyQ',
#    'alias': 'gyu-kaku-japanese-bbq-flushing',
#    'name': 'Gyu-Kaku Japanese BBQ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oXctMrpONbPO3MtGHviDIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gyu-kaku-japanese-bbq-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 629,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.758159, 'longitude': -73.829822},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '4052 Main St',
#     'address2': '',
#     'address3': None,
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4052 Main St', 'Flushing, NY 11354']},
#    'phone': '+13475423653',
#    'display_phone': '(347) 542-3653',
#    'distance': 15044.921077958006},
#   {'id': 'hR7_M9S7nSfv_z0R1BWOCw',
#    'alias': 'delmonico-nyc-new-york',
#    'name': 'Delmonico NYC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-w9RWIrYtzEUC2nRBBpOYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/delmonico-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 216,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7510732, 'longitude': -73.9760569},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '375 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['375 Lexington Ave', 'New York, NY 10017']},
#    'phone': '+12126610150',
#    'display_phone': '(212) 661-0150',
#    'distance': 5301.239860869375},
#   {'id': 'BWDtEFmrLyUyT2-oUrY2bw',
#    'alias': 'o2-bbq-guttenberg',
#    'name': 'O2 BBQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SzSB3GtlMr361B6JI090RQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/o2-bbq-guttenberg?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 181,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.790165, 'longitude': -74.000752},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '7000 Kennedy Blvd E',
#     'address2': None,
#     'address3': '',
#     'city': 'Guttenberg',
#     'zip_code': '07093',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['7000 Kennedy Blvd E', 'Guttenberg, NJ 07093']},
#    'phone': '+12012104051',
#    'display_phone': '(201) 210-4051',
#    'distance': 9473.727627325003},
#   {'id': '_VWpp7qBwJTAEwc4U2QX8Q',
#    'alias': 'funny-bbq-new-york-2',
#    'name': 'Funny BBQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4MmlSKq1JAPqedzMNb4vPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/funny-bbq-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 215,
#    'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.71773, 'longitude': -73.99554},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '98 Bowery',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['98 Bowery', 'New York, NY 10013']},
#    'phone': '+12129650076',
#    'display_phone': '(212) 965-0076',
#    'distance': 1372.5806673880359},
#   {'id': 'R655ubRGyN4wj9_ozY-QWA',
#    'alias': 'queens-buffet-and-cajun-seafood-ozone-park',
#    'name': 'Queens Buffet & Cajun Seafood',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NQ8rGhO6s5vRB1iqlKyOjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/queens-buffet-and-cajun-seafood-ozone-park?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 87,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.687268, 'longitude': -73.851328},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '9010 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Ozone Park',
#     'zip_code': '11416',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9010 Atlantic Ave', 'Ozone Park, NY 11416']},
#    'phone': '+17183237799',
#    'display_phone': '(718) 323-7799',
#    'distance': 12221.00548508916},
#   {'id': '6gE9N5wD4K-bbmSEBm7Lhw',
#    'alias': 'kong-kee-new-york',
#    'name': 'Kong Kee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xjQ3kbzW1Zc0Sv1K23qDvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kong-kee-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 62,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.719047, 'longitude': -73.996139},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '212 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['212 Grand St', 'New York, NY 10002']},
#    'phone': '+12129661350',
#    'display_phone': '(212) 966-1350',
#    'distance': 1520.4667171903654},
#   {'id': 'HEQ04JVgYl1QkLDym_Ji9A',
#    'alias': 'holy-crab-boiling-brooklyn-2',
#    'name': 'Holy Crab Boiling',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pHN1NeISNt_Mgchd4D3V2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holy-crab-boiling-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 208,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.63698, 'longitude': -74.01139},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '5915 7th Ave',
#     'address2': 'Fl 1',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11220',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5915 7th Ave', 'Fl 1', 'Brooklyn, NY 11220']},
#    'phone': '+13478896663',
#    'display_phone': '(347) 889-6663',
#    'distance': 7748.289673639649},
#   {'id': 'MYPes7EWP5aLiVG1Z_9eFQ',
#    'alias': 'jing-fong-new-york-6',
#    'name': 'Jing Fong',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UluObpM4s-pTjarY4QwKmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jing-fong-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 233,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7827096147799,
#     'longitude': -73.9789128775797},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '380 Amsterdam Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['380 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+16466785511',
#    'display_phone': '(646) 678-5511',
#    'distance': 8688.595454201595},
#   {'id': 'aSFBv64GBpMOFPqIleeQFQ',
#    'alias': 'lure-fishbar-new-york-2',
#    'name': 'Lure Fishbar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zh47yiTYJdmzLGJ70oT92w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lure-fishbar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1733,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.724612166991, 'longitude': -73.998574708004},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '142 Mercer St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['142 Mercer St', 'New York, NY 10012']},
#    'phone': '+12124317676',
#    'display_phone': '(212) 431-7676',
#    'distance': 2161.6364530898604},
#   {'id': '1-4W4i1fj9rp0Blrg0Q1zg',
#    'alias': 'aroma-brazil-restaurant-jackson-heights',
#    'name': 'Aroma Brazil Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4R0kwz9-MzapLMre_QrmiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aroma-brazil-restaurant-jackson-heights?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 133,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7472120454333, 'longitude': -73.8900118},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '75-13 Roosevelt Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75-13 Roosevelt Ave', 'Jackson Heights, NY 11372']},
#    'phone': '+17186727662',
#    'display_phone': '(718) 672-7662',
#    'distance': 9939.304457696158},
#   {'id': 'hQq78Foj5L062Nwyd_m9BQ',
#    'alias': 'shabu-garden-new-york-2',
#    'name': 'Shabu Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lg3ZUKapD6YoW4IlLS5gcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shabu-garden-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 156,
#    'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7482056, 'longitude': -73.9864598},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '24 West 33rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 West 33rd St', 'New York, NY 10001']},
#    'phone': '+16463977412',
#    'display_phone': '(646) 397-7412',
#    'distance': 4805.433069035822},
#   {'id': 'SXH-A8k7t7C_lmzzVdWQTg',
#    'alias': 'golden-palace-brooklyn',
#    'name': 'Golden Palace',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ie9ZJSY1_c8bxb3ORjArOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/golden-palace-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 110,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.610031, 'longitude': -74.006664},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1619 86th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1619 86th St', 'Brooklyn, NY 11214']},
#    'phone': '+17185003188',
#    'display_phone': '(718) 500-3188',
#    'distance': 10665.75493104588},
#   {'id': 'wknuaLcG01V_DV_zPcXwew',
#    'alias': 'crab-du-jour-north-bergen-5',
#    'name': 'Crab Du Jour',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-nMyt2U3NJLrPeP2i8w-eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crab-du-jour-north-bergen-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.80828, 'longitude': -74.01806},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '8101 Tonnelle Ave',
#     'address2': 'Ste 2',
#     'address3': '',
#     'city': 'North Bergen',
#     'zip_code': '07047',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['8101 Tonnelle Ave',
#      'Ste 2',
#      'North Bergen, NJ 07047']},
#    'phone': '+12016621888',
#    'display_phone': '(201) 662-1888',
#    'distance': 11607.887758588147},
#   {'id': 'ko4MB9i4qg0L7yasjXFFUA',
#    'alias': 'cafe-pilipino-jersey-city',
#    'name': 'Cafe Pilipino',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/P3dKZz2fqOt0mBl0wyCPPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-pilipino-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'filipino', 'title': 'Filipino'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.731, 'longitude': -74.05565},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '530 Newark Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07306',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['530 Newark Ave', 'Jersey City, NJ 07306']},
#    'phone': '+12016593880',
#    'display_phone': '(201) 659-3880',
#    'distance': 5899.553187828141},
#   {'id': 'hDQG3p22LYlRw5OA5YrUqw',
#    'alias': 'nom-new-york',
#    'name': 'Nom!',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kXypE1iNul0ckd05wxpMeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nom-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'delis', 'title': 'Delis'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7332741455808,
#     'longitude': -73.9935822336434},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '74 University Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['74 University Pl', 'New York, NY 10003']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3095.051492261644},
#   {'id': 'BPZfuPvSxCfoppU4lPFm0Q',
#    'alias': 'domodomo-new-york-new-york-4',
#    'name': 'DOMODOMO - New York',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YX89PDM_-aBCL2USyNyhuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/domodomo-new-york-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1252,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7280299, 'longitude': -74.00167},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '140 W Houston St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['140 W Houston St', 'New York, NY 10012']},
#    'phone': '+16467070301',
#    'display_phone': '(646) 707-0301',
#    'distance': 2584.2825548983697},
#   {'id': 'yyIw_wlW41BjrV2mJeN9bA',
#    'alias': 'golden-dragon-brooklyn-2',
#    'name': 'Golden Dragon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1YdmkpX8J2pOGkt9mrhsfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/golden-dragon-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.64028, 'longitude': -73.9941599},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '4413 New Utrecht Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11219',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4413 New Utrecht Ave', 'Brooklyn, NY 11219']},
#    'phone': '+17188714753',
#    'display_phone': '(718) 871-4753',
#    'distance': 7251.429803921969},
#   {'id': 'tHY4jNvSgdIYoWnE9b7IZg',
#    'alias': 'banana-boat-restaurant-brooklyn-2',
#    'name': 'Banana Boat Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_UQWj5GtY-MaV5f4bL57mA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/banana-boat-restaurant-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6426217691169,
#     'longitude': -73.9581528236144},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1138 Flatbush Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11226',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1138 Flatbush Ave', 'Brooklyn, NY 11226']},
#    'phone': '+17184841131',
#    'display_phone': '(718) 484-1131',
#    'distance': 7621.547088851051},
#   {'id': 'D4QotfnCpx1zgafuKoN5QQ',
#    'alias': 'obaltan-fort-lee-3',
#    'name': 'Obaltan',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9aBt9cu-4li0mLioSq3-7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/obaltan-fort-lee-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 371,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.8314694, 'longitude': -73.9829498},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '799 Abbot Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Fort Lee',
#     'zip_code': '07024',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['799 Abbot Blvd', 'Fort Lee, NJ 07024']},
#    'phone': '+12019175536',
#    'display_phone': '(201) 917-5536',
#    'distance': 14045.795743904167},
#   {'id': 'rN347NNwQ0hDSlbedzI9BQ',
#    'alias': 'kai-sushi-asian-fusion-bronx',
#    'name': 'Kai Sushi Asian Fusion',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oxO3r9z24A02zlHJHnTZYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kai-sushi-asian-fusion-bronx?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 261,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.84362, 'longitude': -73.84565},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1475 Williamsbridge Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10461',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1475 Williamsbridge Rd', 'Bronx, NY 10461']},
#    'phone': '+17188637900',
#    'display_phone': '(718) 863-7900',
#    'distance': 19797.529893592415},
#   {'id': 'EFihj7vsRRXiF5la-UURyw',
#    'alias': 'hop-kee-new-york',
#    'name': 'Hop Kee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Rs6J2QJVyPaW8bHPXLyhRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hop-kee-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 815,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.714458, 'longitude': -73.998889},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '21 Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21 Mott St', 'New York, NY 10013']},
#    'phone': '+12129648365',
#    'display_phone': '(212) 964-8365',
#    'distance': 1074.4709718581325},
#   {'id': 'azGPyK3p6HDmvQGX0AyDtg',
#    'alias': 'shaburo-palisades-park',
#    'name': 'ShabuRo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mBnIOYsPqYiCFKQYkbveUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shaburo-palisades-park?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 493,
#    'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.8480599, 'longitude': -73.98447},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '520 Bergen Blvd',
#     'address2': 'Ste 2',
#     'address3': '',
#     'city': 'Palisades Park',
#     'zip_code': '07650',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['520 Bergen Blvd',
#      'Ste 2',
#      'Palisades Park, NJ 07650']},
#    'phone': '+12019442872',
#    'display_phone': '(201) 944-2872',
#    'distance': 15835.940500738234},
#   {'id': 'G2lMrqIfCVZKjw3R6wzPzQ',
#    'alias': 'happy-land-buffet-bronx',
#    'name': 'Happy Land Buffet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5OYbCNvS6FO7D4EmiqGNew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/happy-land-buffet-bronx?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8531112670898,
#     'longitude': -73.9075698852539},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2028 Jerome Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Bronx',
#     'zip_code': '10453',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2028 Jerome Ave', 'Bronx, NY 10453']},
#    'phone': '+17182995050',
#    'display_phone': '(718) 299-5050',
#    'distance': 17970.214644782605},
#   {'id': 'q1oqr0FIXm0uF5_fT25LtQ',
#    'alias': '65-kuho-sushi-shabu-shabu-brooklyn',
#    'name': '65 Kuho Sushi Shabu Shabu',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/k0gcqybCJY0dqSkOgkJMww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/65-kuho-sushi-shabu-shabu-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 204,
#    'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.62061, 'longitude': -73.99212},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1701 65th St',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11204',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1701 65th St', 'Brooklyn, NY 11204']},
#    'phone': '+17182325688',
#    'display_phone': '(718) 232-5688',
#    'distance': 9440.144398987377},
#   {'id': 'XVqXXolr-RS_ZarEAJjQ7A',
#    'alias': 'dig-new-york-19',
#    'name': 'Dig',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iHuZtO7cbLKyWnEDHyW49A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dig-new-york-19?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 302,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7406997680664,
#     'longitude': -73.9883117675781},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '16 E 23rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['16 E 23rd St', 'New York, NY 10010']},
#    'phone': '+12122536174',
#    'display_phone': '(212) 253-6174',
#    'distance': 3956.738726697708},
#   {'id': 'hA5QUlrSjpxMZ90Kof0bgA',
#    'alias': 'khao-kang-elmhurst',
#    'name': 'Khao Kang',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vfRK27R36XLI4wHpZr6bHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khao-kang-elmhurst?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 255,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.743269, 'longitude': -73.888039},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '7620 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7620 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17188061807',
#    'display_phone': '(718) 806-1807',
#    'distance': 9892.601528091449},
#   {'id': '6EArjn_iacj-yGVLTKWuEQ',
#    'alias': 'fushimi-williamsburg-brooklyn',
#    'name': 'Fushimi Williamsburg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HNs4pxcWYswvhKrKVhdhcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fushimi-williamsburg-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 705,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.718827, 'longitude': -73.954131},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '475 Driggs Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['475 Driggs Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17189632555',
#    'display_phone': '(718) 963-2555',
#    'distance': 3697.701013831024},
#   {'id': '0CjK3esfpFcxIopebzjFxA',
#    'alias': 'joes-shanghai-new-york-2',
#    'name': "Joe's Shanghai",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KRvabBPGaQikcpSD6vO2bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-shanghai-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6439,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7156608, 'longitude': -73.9967012},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '46 Bowery St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['46 Bowery St', 'New York, NY 10013']},
#    'phone': '+12122338888',
#    'display_phone': '(212) 233-8888',
#    'distance': 1153.9482385806896},
#   {'id': '5VGupWYa2DHMKPcOYLlQbQ',
#    'alias': 'fix-u-plate-brooklyn',
#    'name': 'Fix u Plate',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Si0loJchJAPqUbHgkKGy6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fix-u-plate-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6609539, 'longitude': -73.920824},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1139 Clarkson Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11212',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1139 Clarkson Ave', 'Brooklyn, NY 11212']},
#    'phone': '+19292343888',
#    'display_phone': '(929) 234-3888',
#    'distance': 7928.000843819741},
#   {'id': 'EKkHfSYTm266-ZBve3SdgA',
#    'alias': 'yoon-haeundae-galbi-new-york-2',
#    'name': 'Yoon Haeundae Galbi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/M9i5rqze0t9rfRosu_-gKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yoon-haeundae-galbi-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 527,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74996750318778,
#     'longitude': -73.98443095513923},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '8 W 36th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8 W 36th St', 'New York, NY 10018']},
#    'phone': '+12126918078',
#    'display_phone': '(212) 691-8078',
#    'distance': 5019.953551619518},
#   {'id': 'X0QdRUQC1vhVBRv7kOU35g',
#    'alias': 'baraka-buffet-restaurant-manhattan',
#    'name': 'Baraka Buffet Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xbX4h4ylLaldPCkTed0izA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baraka-buffet-restaurant-manhattan?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'african', 'title': 'African'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.81688, 'longitude': -73.94605},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2546 Frederick Douglass Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Manhattan',
#     'zip_code': '10039',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2546 Frederick Douglass Blvd',
#      'Manhattan, NY 10039']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 13039.650278200605},
#   {'id': '_WsfOuvObbp1tH4cBE-jNw',
#    'alias': 'chart-house-weehawken',
#    'name': 'Chart House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NPJgTi58ozoENm9a6tPwzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chart-house-weehawken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1605,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7607, 'longitude': -74.018038},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '1700 Harbor Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Weehawken',
#     'zip_code': '07086',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1700 Harbor Blvd', 'Weehawken, NJ 07086']},
#    'phone': '+12013486628',
#    'display_phone': '(201) 348-6628',
#    'distance': 6461.624349559966},
#   {'id': '8WnHtvMdPWE66eSkUdbLhQ',
#    'alias': 'flip-sigi-new-york-2',
#    'name': 'Flip Sigi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Or5e12QrL0SkMfKNFiSp4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flip-sigi-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 832,
#    'categories': [{'alias': 'filipino', 'title': 'Filipino'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7344965, 'longitude': -74.0020674},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '131 7th Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['131 7th Ave S', 'New York, NY 10014']},
#    'phone': '+18333547744',
#    'display_phone': '(833) 354-7744',
#    'distance': 3296.160771524839},
#   {'id': 'Ug2_5DOrlfaU1Pce5Lvikw',
#    'alias': 'garden-shabu-and-grill-little-ferry-2',
#    'name': 'Garden Shabu & Grill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/asoiiIe7ahAmnkv7xSr4QA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/garden-shabu-and-grill-little-ferry-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 180,
#    'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.854026, 'longitude': -74.033212},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1 Valley Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Little Ferry',
#     'zip_code': '07643',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1 Valley Rd', 'Little Ferry, NJ 07643']},
#    'phone': '+12018706177',
#    'display_phone': '(201) 870-6177',
#    'distance': 16843.29761533477},
#   {'id': 'O5PfyAXUkIQB8jsIJh5VDQ',
#    'alias': 'soul-food-kitchen-crown-heights',
#    'name': 'Soul Food Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/be99LAEWfz2-DeVZpoxE7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soul-food-kitchen-crown-heights?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 85,
#    'categories': [{'alias': 'soulfood', 'title': 'Soul Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.676666, 'longitude': -73.941665},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '88 Kingston Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Crown Heights',
#     'zip_code': '11213',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['88 Kingston Ave', 'Crown Heights, NY 11213']},
#    'phone': '+17184937570',
#    'display_phone': '(718) 493-7570',
#    'distance': 5470.867051363905},
#   {'id': 'ojbH3wnRu050hRhkmoxRiA',
#    'alias': 'han-dynasty-new-york-4',
#    'name': 'Han Dynasty',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-aIQqghSAjISvaYL-9w5oA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/han-dynasty-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 629,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78752, 'longitude': -73.97647},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '215 W 85th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['215 W 85th St', 'New York, NY 10024']},
#    'phone': '+12128589060',
#    'display_phone': '(212) 858-9060',
#    'distance': 9254.42805459871},
#   {'id': 'o4-DfLRRkWRMK-_LOM_AVg',
#    'alias': 'flaming-grill-and-supreme-buffet-riverdale-4',
#    'name': 'Flaming Grill & Supreme Buffet',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4AcDBlHUprUKC0sdzeAJFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flaming-grill-and-supreme-buffet-riverdale-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 140,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.98877404457217,
#     'longitude': -74.32335414762474},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '92 NJ-23',
#     'address2': '',
#     'address3': '',
#     'city': 'Riverdale',
#     'zip_code': '07457',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['92 NJ-23', 'Riverdale, NJ 07457']},
#    'phone': '+18623770598',
#    'display_phone': '(862) 377-0598',
#    'distance': 41936.27956588011}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#        Restaurant        Type Price Rating                  Address  \
# 0  Hou Yi Hot Pot     Hot Pot    $$      4             92 Hester St
# 1  99 Favor Taste     Hot Pot    $$    4.5          201 New Dorp Ln
# 2            OBAO  Vietnamese    $$      4              647 9th Ave
# 3         Rakuzen  Sushi Bars    $$    3.5  6408 Fort Hamilton Pkwy
# 4     Kikoo Sushi  Sushi Bars    $$      4         998 Columbus Ave
#
#          Lat        Lng                                                url  \
# 0  40.716179 -73.992590  https://www.yelp.com/biz/hou-yi-hot-pot-new-yo...
# 1  40.572920 -74.114090  https://www.yelp.com/biz/99-favor-taste-staten...
# 2  40.760654 -73.991332  https://www.yelp.com/biz/obao-new-york-3?adjus...
# 3  40.631120 -74.009030  https://www.yelp.com/biz/rakuzen-brooklyn?adju...
# 4  40.801610 -73.961640  https://www.yelp.com/biz/kikoo-sushi-new-york-...
#
#                        ID
# 0  6Jjz97KPJ0jtmmIBCjReEw
# 1  2FuFCA8uaRXUjpC_X941jA
# 2  NN3mOWF5e_pnR1ArqM2bHQ
# 3  9MIkAs75TQzdwljVkUoZEg
# 4  k_rLFIMOAbvchgWKEuKdtw

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"buffet","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [{'id': 'o7fIFh6OgHy8jryyYM3VNA',
#    'alias': 'flaming-grill-and-supreme-buffet-east-rutherford',
#    'name': 'Flaming Grill & Supreme Buffet',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hg_rJVUe9efQ7MXFPCeYHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flaming-grill-and-supreme-buffet-east-rutherford?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 346,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.8297868, 'longitude': -74.0920766},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '53 Rt 17 S',
#     'address2': '',
#     'address3': '',
#     'city': 'East Rutherford',
#     'zip_code': '07073',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['53 Rt 17 S', 'East Rutherford, NJ 07073']},
#    'phone': '+12014381115',
#    'display_phone': '(201) 438-1115',
#    'distance': 16257.687396994492},
#   {'id': 'KvLrI20Abz6F9WzAIHmyWQ',
#    'alias': 'cafe-r-new-york',
#    'name': 'Cafe R',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2xI-ZDEwj9bV1HSVSh4ykA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-r-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 274,
#    'categories': [{'alias': 'food_court', 'title': 'Food Court'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.74883, 'longitude': -73.98972},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '116 W 32nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['116 W 32nd St', 'New York, NY 10001']},
#    'phone': '+12126959550',
#    'display_phone': '(212) 695-9550',
#    'distance': 4823.126741198138},
#   {'id': '5wPuuBi8fxhgpfAjYG2O8w',
#    'alias': 'b-and-b-47-new-york-2',
#    'name': 'B & B 47',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VsyY6r-OyS07tcyEoxpgjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b-and-b-47-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.75408, 'longitude': -73.9718},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '757 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['757 3rd Ave', 'New York, NY 10017']},
#    'phone': '+12125880444',
#    'display_phone': '(212) 588-0444',
#    'distance': 5716.680632017994},
#   {'id': '_z2_1TE_1brlvljiGtJ4mA',
#    'alias': 'aahar-indian-cuisine-new-york',
#    'name': 'Aahar Indian Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V5QIjldzSDuXfIERTyDSUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aahar-indian-cuisine-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 360,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71334, 'longitude': -74.0081},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '10 Murray St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10 Murray St', 'New York, NY 10007']},
#    'phone': '+16466493374',
#    'display_phone': '(646) 649-3374',
#    'distance': 1463.316767052917},
#   {'id': '6sTAomlazQ5UwbKyyAK0OQ',
#    'alias': 'copacabana-brazilian-grill-jackson-heights',
#    'name': 'Copacabana Brazilian Grill',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/d3gWnwP447BAJD_eUEM_Xw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/copacabana-brazilian-grill-jackson-heights?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'brazilian', 'title': 'Brazilian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7473064935523,
#     'longitude': -73.8850180059672},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '80-26 Roosevelt Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80-26 Roosevelt Ave', 'Jackson Heights, NY 11372']},
#    'phone': '+17182556093',
#    'display_phone': '(718) 255-6093',
#    'distance': 10317.955112722664},
#   {'id': 'AFt1Qcec4_JNr6PWpkRYyw',
#    'alias': 'sushi-lin-brooklyn-2',
#    'name': 'Sushi Lin',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2zPxmKj8fumQqJ1S94UcEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-lin-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 286,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.677786, 'longitude': -73.972591},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '335 Flatbush Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['335 Flatbush Ave', 'Brooklyn, NY 11217']},
#    'phone': '+13476276027',
#    'display_phone': '(347) 627-6027',
#    'distance': 3577.679843014624},
#   {'id': 'sfsjk1h50ooC2ioY7m48gw',
#    'alias': 'pig-heaven-new-york-3',
#    'name': 'Pig Heaven',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YzHJPPxM5m6qp_vwfrC6SA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pig-heaven-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 429,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77544, 'longitude': -73.95686},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1420 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1420 3rd Ave', 'New York, NY 10028']},
#    'phone': '+12127444333',
#    'display_phone': '(212) 744-4333',
#    'distance': 8399.490329439157},
#   {'id': 'L3PwWn54PvHm5Rd4oUg7xw',
#    'alias': 'b-and-d-halal-food-new-york',
#    'name': 'B&D Halal Food',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SrNWfU1vRr_JkFBVUfl81g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b-and-d-halal-food-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'african', 'title': 'African'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7477911583293,
#     'longitude': -73.9923941393954},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '163B W 29th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['163B W 29th St', 'New York, NY 10001']},
#    'phone': '+12122687602',
#    'display_phone': '(212) 268-7602',
#    'distance': 4711.406400751023},
#   {'id': 'mwznN_YtWSGQdaCAV4bZ4g',
#    'alias': 'open-market-new-york',
#    'name': 'Open Market',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yP0nVmq8wM3r-rLJtDOuig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/open-market-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.70537, 'longitude': -74.01036},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '15 William St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 William St', 'New York, NY 10005']},
#    'phone': '+12127855555',
#    'display_phone': '(212) 785-5555',
#    'distance': 1352.82880679944},
#   {'id': 'AFisWoWm0pfxEi1dMYitKw',
#    'alias': 'kyoto-brooklyn',
#    'name': 'Kyoto',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tsaPXswocSvunGg5je1-mA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kyoto-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 233,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6877593994141,
#     'longitude': -73.989501953125},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '115 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['115 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17185225888',
#    'display_phone': '(718) 522-5888',
#    'distance': 2005.5017231162078},
#   {'id': 'j_ZW3vvpjLDG34nBq5f-UA',
#    'alias': 'grill-21-new-york',
#    'name': 'Grill 21',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5hFrsIvZNMqQ_u-hKCACdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grill-21-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 540,
#    'categories': [{'alias': 'filipino', 'title': 'Filipino'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73570710809612,
#     'longitude': -73.9799634876969},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '346 E 21st St',
#     'address2': 'Apt 1',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['346 E 21st St', 'Apt 1', 'New York, NY 10010']},
#    'phone': '+12124735950',
#    'display_phone': '(212) 473-5950',
#    'distance': 3575.140060092247},
#   {'id': '4EEDkitbROK_6DmujlWbYA',
#    'alias': 'philippine-famous-jamaica',
#    'name': 'Philippine Famous',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Py2nR2nYNeppvOMSpTxQdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/philippine-famous-jamaica?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'filipino', 'title': 'Filipino'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.714871210477924,
#     'longitude': -73.80775123672113},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '83-30 Parsons Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Jamaica',
#     'zip_code': '11432',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['83-30 Parsons Blvd', 'Jamaica, NY 11432']},
#    'phone': '+13472563560',
#    'display_phone': '(347) 256-3560',
#    'distance': 15758.097101115196},
#   {'id': '7RFUG5LmFaQnqrpwRjwS4A',
#    'alias': 'cafe-metro-brooklyn',
#    'name': 'Cafe Metro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/P7d8mSKVOPLBQoqBO-wDwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-metro-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 71,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.6939092938425,
#     'longitude': -73.9849905253267},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '15 Metrotech Ctr',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Metrotech Ctr', 'Brooklyn, NY 11201']},
#    'phone': '+17182374800',
#    'display_phone': '(718) 237-4800',
#    'distance': 1503.4354190534355},
#   {'id': 'XhCzENVgRBYcKwWLMX7FRg',
#    'alias': 'kimchi-grill-brooklyn',
#    'name': 'Kimchi Grill',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kRcu2eiND2tFtMrjf6UktQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kimchi-grill-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 613,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6750885, 'longitude': -73.9634982},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '766 Washington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['766 Washington Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17183601839',
#    'display_phone': '(718) 360-1839',
#    'distance': 4258.541980227749},
#   {'id': 'tT6teP3ZfCAfvdPdDoqG4A',
#    'alias': 'ki-sushi-brooklyn',
#    'name': 'Ki Sushi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Mbkxqjg7HBvrez77WmwHrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ki-sushi-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 722,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68764, 'longitude': -73.9901},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '122 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['122 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17189350575',
#    'display_phone': '(718) 935-0575',
#    'distance': 2009.758329718251},
#   {'id': '0087AC_NnFRtC0c9FsB9pw',
#    'alias': 'the-boil-new-york-5',
#    'name': 'The Boil',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lzFeR6PJ2JH9LzdHVYUILQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-boil-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 840,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.730316162745154,
#     'longitude': -73.99429517055144},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '17 Waverly Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 Waverly Pl', 'New York, NY 10003']},
#    'phone': '+16468337110',
#    'display_phone': '(646) 833-7110',
#    'distance': 2765.559127548041},
#   {'id': '1xZ_5lc8EQjItqza0duJXA',
#    'alias': 'k1-buffet-brooklyn-2',
#    'name': 'K1 Buffet ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gTfkpg7Z1Y5ntJivMfNZRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/k1-buffet-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.629956, 'longitude': -73.92148},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '5614 Flatlands Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11234',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5614 Flatlands Ave', 'Brooklyn, NY 11234']},
#    'phone': '+17189688808',
#    'display_phone': '(718) 968-8808',
#    'distance': 10405.592132645206},
#   {'id': 'BKMCAYb9EAivUm3p-vrC9w',
#    'alias': 'khe-yo-new-york',
#    'name': 'Khe-Yo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ai79Wa0Z8ecgZwnpvjDIkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khe-yo-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 844,
#    'categories': [{'alias': 'laotian', 'title': 'Laotian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.716906, 'longitude': -74.008587},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '157 Duane St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['157 Duane St', 'New York, NY 10013']},
#    'phone': '+12125871089',
#    'display_phone': '(212) 587-1089',
#    'distance': 1753.7446005214726},
#   {'id': 'IZaIOOUNnZV2kgabfpwfFA',
#    'alias': 'flaming-grill-and-modern-buffet-mount-vernon-2',
#    'name': 'Flaming Grill & Modern Buffet',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/M0oF6kkxl44Y-YLZ1CAgWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flaming-grill-and-modern-buffet-mount-vernon-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.90075, 'longitude': -73.81964},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '440 E Sandford Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Mount Vernon',
#     'zip_code': '10550',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['440 E Sandford Blvd', 'Mount Vernon, NY 10550']},
#    'phone': '+19146687888',
#    'display_phone': '(914) 668-7888',
#    'distance': 26223.970893613012},
#   {'id': 'xZ3VuupSlqg9gd97opdlTQ',
#    'alias': 'la-grande-international-buffet-and-grill-fairview',
#    'name': 'La Grande International Buffet & Grill',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/W2lFlZmk8pNrr0SkQ0eGxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-grande-international-buffet-and-grill-fairview?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 95,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.8156731307131,
#     'longitude': -74.0027182826811},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '127 Bergen Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Fairview',
#     'zip_code': '07022',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['127 Bergen Blvd', 'Fairview, NJ 07022']},
#    'phone': '+12019458880',
#    'display_phone': '(201) 945-8880',
#    'distance': 12277.333654228758},
#   {'id': 'r5tdEA1S-Almn_2cv-c6Sg',
#    'alias': 'sushi-x-long-island-city',
#    'name': 'Sushi X',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/15R49IlXpQtNG0l1KW3_tQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-x-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 257,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7539316554037,
#     'longitude': -73.9145785103119},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '47-15 Northern Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47-15 Northern Blvd', 'Long Island City, NY 11101']},
#    'phone': '+17187289600',
#    'display_phone': '(718) 728-9600',
#    'distance': 8613.137719179049},
#   {'id': 'IO6QAXCXu_31YZBeXGclcQ',
#    'alias': 'mannas-soul-food-restaurant-new-york-3',
#    'name': "Manna's Soul Food Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/F7edl3nJhVFC8QA0gupGnQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mannas-soul-food-restaurant-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'soulfood', 'title': 'Soul Food'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.813327, 'longitude': -73.941052},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '486 Malcolm X Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10037',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['486 Malcolm X Blvd', 'New York, NY 10037']},
#    'phone': '+12122344488',
#    'display_phone': '(212) 234-4488',
#    'distance': 12806.677703510126},
#   {'id': 'x1vyHnuyuRoJRRLzRb7Nog',
#    'alias': 'northern-sushi-and-sashimi-flushing',
#    'name': 'Northern Sushi & Sashimi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SzmPrNGMg-5nlebh6bV_JQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/northern-sushi-and-sashimi-flushing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 128,
#    'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'},
#     {'alias': 'importedfood', 'title': 'Imported Food'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7645739630046,
#     'longitude': -73.8113314625656},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '15314 Northern Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15314 Northern Blvd', 'Flushing, NY 11354']},
#    'phone': '+17188864123',
#    'display_phone': '(718) 886-4123',
#    'distance': 16759.222601605477},
#   {'id': '5UqEDoMZCrvhSKgCWg5GGw',
#    'alias': 'isohama-new-york',
#    'name': 'Isohama',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y9psSJkJmgExnWDQTQjuyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/isohama-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 184,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78361, 'longitude': -73.95088},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1666 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1666 3rd Ave', 'New York, NY 10128']},
#    'phone': '+12128280099',
#    'display_phone': '(212) 828-0099',
#    'distance': 9429.84036123343},
#   {'id': 'y3K6ZZplmLWif4EviLWveg',
#    'alias': 'tsq-food-court-new-york',
#    'name': 'TSQ Food Court',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/G8KjDcg1vK48IoueCJLYQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tsq-food-court-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'delis', 'title': 'Delis'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.759635, 'longitude': -73.9836677},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '163 W 48th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['163 W 48th St', 'New York, NY 10036']},
#    'phone': '+12129330966',
#    'display_phone': '(212) 933-0966',
#    'distance': 6091.810640948989},
#   {'id': 'NzU2hb0z0jGEOOv0-zTLEQ',
#    'alias': 'sigiri-new-york',
#    'name': 'Sigiri',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZX9iOuEI6F45ek7K3hjWWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sigiri-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 612,
#    'categories': [{'alias': 'srilankan', 'title': 'Sri Lankan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.726261, 'longitude': -73.986686},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '91 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['91 1st Ave', 'New York, NY 10003']},
#    'phone': '+12126149333',
#    'display_phone': '(212) 614-9333',
#    'distance': 2398.7650810886194},
#   {'id': 'UA2M9QFZghe-9th2KwLoWQ',
#    'alias': 'burger-and-lobster-flatiron-nyc-new-york',
#    'name': 'Burger & Lobster - Flatiron NYC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y1NYFEnpLG2KuyYDg8IcSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burger-and-lobster-flatiron-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5519,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74007, 'longitude': -73.99344},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '39 W 19th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39 W 19th St', 'New York, NY 10011']},
#    'phone': '+16468337532',
#    'display_phone': '(646) 833-7532',
#    'distance': 3849.54386751767},
#   {'id': 'x9ADy3a--S_6Oqn_1KLipA',
#    'alias': 'kang-ho-dong-baekjeong-new-york',
#    'name': 'Kang Ho Dong Baekjeong',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CF9LFMeGsKeQra6Z9ZftfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kang-ho-dong-baekjeong-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1350,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.747173576622,
#     'longitude': -73.9852144232788},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '1 E 32nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 E 32nd St', 'New York, NY 10016']},
#    'phone': '+12129669839',
#    'display_phone': '(212) 966-9839',
#    'distance': 4702.663263992757},
#   {'id': 'KxUDnvmd4YpThY_5A9Seng',
#    'alias': 'brasilia-grill-newark',
#    'name': 'Brasilia Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uBTJAzGeumqJTEf2HD2tAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brasilia-grill-newark?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 330,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.729067, 'longitude': -74.159647},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '99 Monroe St',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07105',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['99 Monroe St', 'Newark, NJ 07105']},
#    'phone': '+19735898682',
#    'display_phone': '(973) 589-8682',
#    'distance': 14181.188732554037},
#   {'id': 'gmJEBBWAKD8zSfBIdJfrsA',
#    'alias': 'sweet-mamas-soul-food-restaurant-and-salad-bar-new-york',
#    'name': "Sweet Mama's Soul Food Restaurant & Salad Bar",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zXZAScH6KLwLx74rIkZx1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweet-mamas-soul-food-restaurant-and-salad-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 110,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'soulfood', 'title': 'Soul Food'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8200624492871,
#     'longitude': -73.9364389139661},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '689 Lenox Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10037',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['689 Lenox Ave', 'New York, NY 10037']},
#    'phone': '+12129399383',
#    'display_phone': '(212) 939-9383',
#    'distance': 13644.549163497788},
#   {'id': 't9WWw6ZDk7lLksrbrc8kgg',
#    'alias': 'flaming-grill-and-buffet-linden-2',
#    'name': 'Flaming Grill & Buffet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vf2BRBG4srCcdGZxdAV3LQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flaming-grill-and-buffet-linden-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 130,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6121340674324,
#     'longitude': -74.2536832748653},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1701 W Edgar Rd',
#     'address2': 'Unit B',
#     'address3': '',
#     'city': 'Linden',
#     'zip_code': '07036',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1701 W Edgar Rd', 'Unit B', 'Linden, NJ 07036']},
#    'phone': '+19088628866',
#    'display_phone': '(908) 862-8866',
#    'distance': 24215.691853790486},
#   {'id': 'nkfUKb7oWQt54Uz9VQLhUg',
#    'alias': 'butcher-bar-astoria-2',
#    'name': 'Butcher Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_d3uhCZO0h_5WedVHJhv1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/butcher-bar-astoria-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2135,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76431, 'longitude': -73.9164},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '37-10 30th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37-10 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17186068140',
#    'display_phone': '(718) 606-8140',
#    'distance': 9270.719872124859},
#   {'id': '7g1pN6JgTf03ts4Jupgdmw',
#    'alias': '6b-new-york',
#    'name': '6b',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/v1yAmGmvvW36YuA6PosROQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/6b-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7521961, 'longitude': -73.9787133},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '60 E 42nd St',
#     'address2': '',
#     'address3': 'Lobby Level',
#     'city': 'New York',
#     'zip_code': '10165',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 E 42nd St', 'Lobby Level', 'New York, NY 10165']},
#    'phone': '+12129222110',
#    'display_phone': '(212) 922-2110',
#    'distance': 5361.703121140007},
#   {'id': '91rrB0aH3caC70oCkxAynA',
#    'alias': 'deluxe-green-bo-new-york-2',
#    'name': 'Deluxe Green Bo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eoXKFseMZnWEvjNC8PifKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/deluxe-green-bo-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 692,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.715540215765,
#     'longitude': -73.9981645926656},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '66 Bayard St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['66 Bayard St', 'New York, NY 10013']},
#    'phone': '+12126252359',
#    'display_phone': '(212) 625-2359',
#    'distance': 1169.0153601888098},
#   {'id': 'MhceeLrM2_3mcKw5EGLY6A',
#    'alias': 'pure-thai-cookhouse-new-york',
#    'name': 'Pure Thai Cookhouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QFYS-7MPGlOjUUy_2TkwLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pure-thai-cookhouse-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2618,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.764291, 'longitude': -73.988159},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '766 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['766 9th Ave', 'New York, NY 10019']},
#    'phone': '+12125810999',
#    'display_phone': '(212) 581-0999',
#    'distance': 6563.765009094688},
#   {'id': 'QqrEF8_ZQCGi63cL10J5oA',
#    'alias': 'chola-new-york-3',
#    'name': 'Chola',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sES9shU8nbErVX_saLRRgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chola-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 629,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76016, 'longitude': -73.96582},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '232 E 58th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['232 E 58th St', 'New York, NY 10022']},
#    'phone': '+12126884619',
#    'display_phone': '(212) 688-4619',
#    'distance': 6540.086788607515},
#   {'id': 'e1d40LtcHu8WU4iaJxLdVw',
#    'alias': 'hooked-jc-jersey-city',
#    'name': 'Hooked JC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/948GofYVYRj9PJj5l_kU8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hooked-jc-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 562,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7146930849064,
#     'longitude': -74.0670708676607},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '467 Communipaw Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Jersey City',
#     'zip_code': '07304',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['467 Communipaw Ave', 'Jersey City, NJ 07304']},
#    'phone': '+12019464177',
#    'display_phone': '(201) 946-4177',
#    'distance': 6219.871958057928},
#   {'id': 'nMdTCGSG3DLvTFx9S45AVg',
#    'alias': 'china-buffet-hazlet',
#    'name': 'China Buffet',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YSKa8Z6lg8ZV2MiZHYtGRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/china-buffet-hazlet?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.419075096172,
#     'longitude': -74.1784858703613},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': 'Hazlet Plz',
#     'address2': '',
#     'address3': '',
#     'city': 'Hazlet',
#     'zip_code': '07730',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['Hazlet Plz', 'Hazlet, NJ 07730']},
#    'phone': '+17328889696',
#    'display_phone': '(732) 888-9696',
#    'distance': 35441.01735975674},
#   {'id': 'kYURnv37Z5P_sir_QJGHzg',
#    'alias': 'sake-sushi-brooklyn-5',
#    'name': 'Sake Sushi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/W6D89Ei1dPheSrwvSCuRbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sake-sushi-brooklyn-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 753,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.600102, 'longitude': -73.990238},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2347 86th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2347 86th St', 'Brooklyn, NY 11214']},
#    'phone': '+17189966288',
#    'display_phone': '(718) 996-6288',
#    'distance': 11719.587762553087},
#   {'id': 'OwV-MtDBC2H08rVcBqP2mA',
#    'alias': 'pio-pio-8-new-york-5',
#    'name': 'Pio Pio 8',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HezN3FXL21Ru-UGkqyEMaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pio-pio-8-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2381,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.760506289326, 'longitude': -73.994564488901},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '604 10th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['604 10th Ave', 'New York, NY 10036']},
#    'phone': '+12124592929',
#    'display_phone': '(212) 459-2929',
#    'distance': 6122.5869767591485},
#   {'id': '8cyRl5HIQzbkYD7orq223g',
#    'alias': 'shi-long-island-city',
#    'name': 'SHI',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/q93ZdEACDKkpeEaK9ZW5hg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shi-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 855,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74599336793073, 'longitude': -73.957094},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '4720 Center Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11109',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4720 Center Blvd', 'Long Island City, NY 11109']},
#    'phone': '+13472422450',
#    'display_phone': '(347) 242-2450',
#    'distance': 5491.401984684194},
#   {'id': 'V2oWqXcoJkgGeIPOaS9eDA',
#    'alias': 'masala-times-greenwich-village-new-york-9',
#    'name': 'Masala Times Greenwich Village',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eLgcigFzYIl4dDbDGpPcgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/masala-times-greenwich-village-new-york-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 560,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7292728223798,
#     'longitude': -74.0015978515206},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '194 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['194 Bleecker St', 'New York, NY 10012']},
#    'phone': '+12129955100',
#    'display_phone': '(212) 995-5100',
#    'distance': 2720.125590142341},
#   {'id': 'bJgl6cDIBIMlgrntQbxt1g',
#    'alias': 'tomiz-new-york',
#    'name': 'Tomiz',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_Rskf90ezf37G4zBTohZGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tomiz-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1205,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7523, 'longitude': -73.98043},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '18 E 41st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18 E 41st St', 'New York, NY 10017']},
#    'phone': '+12127790740',
#    'display_phone': '(212) 779-0740',
#    'distance': 5328.954263284404},
#   {'id': 'GaxVczLK1qUuJHOP9VcFsQ',
#    'alias': 'ananda-new-york-4',
#    'name': 'Ananda',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BcEKtAx2k7Lp306o1i_tCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ananda-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 343,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'kosher', 'title': 'Kosher'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.728724, 'longitude': -73.999147},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '210 Thompson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['210 Thompson St', 'New York, NY 10012']},
#    'phone': '+12125337290',
#    'display_phone': '(212) 533-7290',
#    'distance': 2621.50680422371},
#   {'id': 'w_o8gsWgic_jr4bYn46hWg',
#    'alias': 'moonstone-great-neck-4',
#    'name': 'Moonstone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WT12QJGRJBdrnmuB-eWiPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moonstone-great-neck-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 285,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7729366, 'longitude': -73.7332079},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '14 Northern Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Great Neck',
#     'zip_code': '11021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 Northern Blvd', 'Great Neck, NY 11021']},
#    'phone': '+15165001000',
#    'display_phone': '(516) 500-1000',
#    'distance': 23241.664710347246},
#   {'id': 'Q_rT0lwuW8rJ6kGBYxPWkw',
#    'alias': 'asea-fusion-brooklyn',
#    'name': 'Asea Fusion',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nIIiG7gpy3bQxnUxTZJqMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/asea-fusion-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 283,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.64588, 'longitude': -73.99915},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '4120 8th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11232',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4120 8th Ave', 'Brooklyn, NY 11232']},
#    'phone': '+13478895252',
#    'display_phone': '(347) 889-5252',
#    'distance': 6631.95091537028},
#   {'id': 'znB_ZvfFDJWjqYFzuGV8qg',
#    'alias': 'da-yu-hot-pot-大渝火锅-new-york',
#    'name': 'Da Yu Hot Pot 大渝火锅',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fGBZRKItDXcfsMjuTsgfcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-yu-hot-pot-%E5%A4%A7%E6%B8%9D%E7%81%AB%E9%94%85-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 213,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.716775284480875, 'longitude': -73.9953824},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '81 Bowery',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81 Bowery', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1263.2241279812995},
#   {'id': 'xM7ICL6d6E3NjHWjyDIxDg',
#    'alias': 'flaming-grill-and-supreme-buffet-baldwin-5',
#    'name': 'Flaming Grill & Supreme Buffet',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FyUDoiFQ96AKhUfVwXfgWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flaming-grill-and-supreme-buffet-baldwin-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 263,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6671692, 'longitude': -73.6081461},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1773 Grand Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Baldwin',
#     'zip_code': '11510',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1773 Grand Ave', 'Baldwin, NY 11510']},
#    'phone': '+15165442222',
#    'display_phone': '(516) 544-2222',
#    'distance': 32885.94894455481},
#   {'id': '2h12doe_dr-_pj52ZrJ5hg',
#    'alias': 'sushi-factory-brooklyn-2',
#    'name': 'Sushi Factory',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Hd_tjC43dRLpsgeqTpsMPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-factory-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 98,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6418518141296,
#     'longitude': -74.0038870071483},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '772 49th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11220',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['772 49th St', 'Brooklyn, NY 11220']},
#    'phone': '+17186868688',
#    'display_phone': '(718) 686-8688',
#    'distance': 7117.353450306033},
#   {'id': 'Po5xPWsDdnHf41RnxQWhwg',
#    'alias': 'latin-bbq-north-bergen',
#    'name': 'Latin BBQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6ITdsZvUtttU237n4ReQbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/latin-bbq-north-bergen?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7588682, 'longitude': -74.0448246},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '707 Kennedy Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'North Bergen',
#     'zip_code': '07047',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['707 Kennedy Blvd', 'North Bergen, NJ 07047']},
#    'phone': '+12016241000',
#    'display_phone': '(201) 624-1000',
#    'distance': 7308.687503487219}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#                        Restaurant        Type Price Rating  \
# 0  Flaming Grill & Supreme Buffet     Buffets    $$      3
# 1                          Cafe R  Food Court     $      3
# 2                        B & B 47       Delis
# 3            Aahar Indian Cuisine      Indian    $$    4.5
# 4      Copacabana Brazilian Grill     Buffets    $$    4.5
#
#                Address        Lat        Lng  \
# 0           53 Rt 17 S  40.829787 -74.092077
# 1        116 W 32nd St  40.748830 -73.989720
# 2          757 3rd Ave  40.754080 -73.971800
# 3         10 Murray St  40.713340 -74.008100
# 4  80-26 Roosevelt Ave  40.747306 -73.885018
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/flaming-grill-and-sup...  o7fIFh6OgHy8jryyYM3VNA
# 1  https://www.yelp.com/biz/cafe-r-new-york?adjus...  KvLrI20Abz6F9WzAIHmyWQ
# 2
# 3  https://www.yelp.com/biz/aahar-indian-cuisine-...  _z2_1TE_1brlvljiGtJ4mA
# 4  https://www.yelp.com/biz/copacabana-brazilian-...  6sTAomlazQ5UwbKyyAK0OQ

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                             Restaurant                    Type Rating Price  \
# 0           B&B Restaurant Corporation                 African    4.5     $
# 1                       B&D Halal Food                 African    4.5     $
# 2             Baraka Buffet Restaurant                 African    4.5     $
# 3               Flaming Grill & Buffet          American (New)    3.5    $$
# 4                                  Dig          American (New)      4    $$
# 5                        Golden Corral  American (Traditional)
# 6                                  SHI            Asian Fusion    3.5    $$
# 7               Kai Sushi Asian Fusion            Asian Fusion      4    $$
# 8                          Asea Fusion            Asian Fusion      4    $$
# 9                         Bagel Buffet                  Bagels      4     $
# 10                               Tomiz                Bakeries      4     $
# 11                       Korai Kitchen             Bangladeshi      5    $$
# 12                        iCook Buffet                Barbeque    3.5    $$
# 13   Mable's Smokehouse & Banquet Hall                Barbeque      4    $$
# 14                  Gopchang Story BBQ                Barbeque      4    $$
# 15                       Picnic Garden                Barbeque    3.5   $$$
# 16                           Fette Sau                Barbeque      4    $$
# 17               Gyu-Kaku Japanese BBQ                Barbeque    4.5    $$
# 18                           Latin BBQ                Barbeque    3.5    $$
# 19                          Pig Heaven                Barbeque      4    $$
# 20                         Butcher Bar                Barbeque      4    $$
# 21             Villa Brazil Cafe Grill               Brazilian    4.5    $$
# 22               Brazeiro Churrascaria               Brazilian      4    $$
# 23                          Copacabana               Brazilian      4     $
# 24   Fogo de Chao Brazilian Steakhouse               Brazilian      4  $$$$
# 25             Aroma Brazil Restaurant               Brazilian    4.5    $$
# 26             Churrascaria Plataforma               Brazilian      4  $$$$
# 27                      Brasilia Grill               Brazilian    3.5    $$
# 28                    Brazilian Buffet               Brazilian      4     $
# 29                Rainhas Churrascaria               Brazilian      4   $$$
# ..                                 ...                     ...    ...   ...
# 170                             Sigiri              Sri Lankan      4    $$
# 171                              Kyoto              Sushi Bars      4    $$
# 172                     Ootoya Chelsea              Sushi Bars      4    $$
# 173                         Sake Sushi              Sushi Bars    3.5    $$
# 174                 Teppan Bar & Grill              Sushi Bars      4    $$
# 175                         66S Fusion              Sushi Bars      4    $$
# 176          Blue Ribbon Sushi Izakaya              Sushi Bars      4   $$$
# 177                             Mizumi              Sushi Bars    3.5   $$$
# 178                     Ninja 86 Sushi              Sushi Bars      4    $$
# 179           Yuka Japanese Restaurant              Sushi Bars    3.5    $$
# 180                    Iron Chef House              Sushi Bars      4    $$
# 181              Sashimi Ramen Express              Sushi Bars    4.5     $
# 182      POC American Fusion and Sushi              Sushi Bars      4    $$
# 183      Flaming Grill & Modern Buffet              Sushi Bars      4    $$
# 184                           Ki Sushi              Sushi Bars      4    $$
# 185                            Rakuzen              Sushi Bars    3.5    $$
# 186                        Kikoo Sushi              Sushi Bars      4    $$
# 187                        Kikoo Sushi              Sushi Bars    3.5   $$$
# 188                Miyabi Asian Fusion              Sushi Bars    4.5    $$
# 189                Komorebi Full House              Sushi Bars    4.5    $$
# 190                            Sushi X              Sushi Bars    3.5    $$
# 191                              Akino              Sushi Bars    4.5   $$$
# 192                          Sushi Lin              Sushi Bars    4.5   $$$
# 193                      Sushi Factory              Sushi Bars    3.5    $$
# 194                        Han Dynasty                Szechuan      4    $$
# 195                    Izakaya Toribar      Tapas/Small Plates    4.5    $$
# 196                Pure Thai Cookhouse                    Thai      4    $$
# 197                          Khao Kang                    Thai      4     $
# 198                        Jungle Cafe                   Vegan      4    $$
# 199                               OBAO              Vietnamese      4    $$
#
#                           Address        Lat        Lng  \
# 0                165 West 26th St  40.745911 -73.993609
# 1                  163B W 29th St  40.747791 -73.992394
# 2    2546 Frederick Douglass Blvd  40.816880 -73.946050
# 3                 1701 W Edgar Rd  40.612134 -74.253683
# 4                    16 E 23rd St  40.740700 -73.988312
# 5              2375 E Tremont Ave  40.842580 -73.855290
# 6                4720 Center Blvd  40.745993 -73.957094
# 7          1475 Williamsbridge Rd  40.843620 -73.845650
# 8                    4120 8th Ave  40.645880 -73.999150
# 9             510 Ave Of Americas  40.736916 -73.996936
# 10                   18 E 41st St  40.752300 -73.980430
# 11                 576 Summit Ave  40.733896 -74.059151
# 12                 81-17 Broadway  40.743260 -73.883305
# 13                    44 Berry St  40.721189 -73.957000
# 14                    312 5th Ave  40.747010 -73.985830
# 15           154-05 Northern Blvd  40.764890 -73.810620
# 16           354 Metropolitan Ave  40.714066 -73.956327
# 17                   4052 Main St  40.758159 -73.829822
# 18               707 Kennedy Blvd  40.758868 -74.044825
# 19                   1420 3rd Ave  40.775440 -73.956860
# 20                 37-10 30th Ave  40.764310 -73.916400
# 21                 43-16 34th Ave  40.755290 -73.918007
# 22              7420 Broadway Ave  40.796315 -74.002996
# 23                 31-13 36th Ave  40.756537 -73.929338
# 24                   40 W 53rd St  40.761077 -73.977771
# 25            75-13 Roosevelt Ave  40.747212 -73.890012
# 26                  316 W 49th St  40.762020 -73.987650
# 27                   99 Monroe St  40.729067 -74.159647
# 28                 124 Wilson Ave  40.723995 -74.152145
# 29           108-01 Northern Blvd  40.758240 -73.860680
# ..                            ...        ...        ...
# 170                    91 1st Ave  40.726261 -73.986686
# 171                  115 Smith St  40.687759 -73.989502
# 172                   8 W 18th St  40.738721 -73.992790
# 173                  2347 86th St  40.600102 -73.990238
# 174                 319 Warren St  40.718919 -74.038909
# 175              130 Flushing Ave  40.697760 -73.971574
# 176                187 Orchard St  40.722084 -73.988225
# 177          231-10 Northern Blvd  40.763570 -73.749000
# 178                  2274 86th St  40.600680 -73.992080
# 179                  1557 2nd Ave  40.774630 -73.954470
# 180                   92 Clark St  40.697230 -73.992622
# 181                 341 E 78th St  40.772239 -73.954052
# 182            450 Hackensack Ave  40.909683 -74.031646
# 183             3839 Nostrand Ave  40.590640 -73.939570
# 184                  122 Smith St  40.687640 -73.990100
# 185       6408 Fort Hamilton Pkwy  40.631120 -74.009030
# 186              998 Columbus Ave  40.801610 -73.961640
# 187                   141 1st Ave  40.728086 -73.985359
# 188               1348 Forest Ave  40.625809 -74.134564
# 189                 6201 11th Ave  40.630169 -74.004041
# 190           47-15 Northern Blvd  40.753932 -73.914579
# 191                82-80 Broadway  40.741236 -73.881306
# 192              335 Flatbush Ave  40.677786 -73.972591
# 193                   772 49th St  40.641852 -74.003887
# 194                 215 W 85th St  40.787520 -73.976470
# 195                 164 E 56th St  40.759641 -73.968556
# 196                   766 9th Ave  40.764291 -73.988159
# 197             7620 Woodside Ave  40.743269 -73.888039
# 198            131 Greenpoint Ave  40.730358 -73.954885
# 199                   647 9th Ave  40.760654 -73.991332
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/b-and-b-restaurant-co...  GjAHO7PA-3Sxg1lkGza4sQ
# 1    https://www.yelp.com/biz/b-and-d-halal-food-ne...  L3PwWn54PvHm5Rd4oUg7xw
# 2    https://www.yelp.com/biz/baraka-buffet-restaur...  X0QdRUQC1vhVBRv7kOU35g
# 3    https://www.yelp.com/biz/flaming-grill-and-buf...  t9WWw6ZDk7lLksrbrc8kgg
# 4    https://www.yelp.com/biz/dig-new-york-19?adjus...  XVqXXolr-RS_ZarEAJjQ7A
# 5
# 6    https://www.yelp.com/biz/shi-long-island-city?...  8cyRl5HIQzbkYD7orq223g
# 7    https://www.yelp.com/biz/kai-sushi-asian-fusio...  rN347NNwQ0hDSlbedzI9BQ
# 8    https://www.yelp.com/biz/asea-fusion-brooklyn?...  Q_rT0lwuW8rJ6kGBYxPWkw
# 9    https://www.yelp.com/biz/bagel-buffet-new-york...  rGfDX_ors68i8LnuG55NQA
# 10   https://www.yelp.com/biz/tomiz-new-york?adjust...  bJgl6cDIBIMlgrntQbxt1g
# 11   https://www.yelp.com/biz/korai-kitchen-jersey-...  3rZwXDjkyDLAHNSdPUI5WA
# 12   https://www.yelp.com/biz/icook-buffet-elmhurst...  cMuHouN7_VzSsm6NsSkyAQ
# 13   https://www.yelp.com/biz/mables-smokehouse-and...  nsAU6F2vmdnphmfIa_RuWg
# 14   https://www.yelp.com/biz/gopchang-story-bbq-ne...  _vQugjzPLr-4udYpiISieA
# 15   https://www.yelp.com/biz/picnic-garden-flushin...  mnj9O1tbCKiAN5zWMe5v8w
# 16   https://www.yelp.com/biz/fette-sau-brooklyn?ad...  mlGfXoxc8cEss8Yms6VrXg
# 17   https://www.yelp.com/biz/gyu-kaku-japanese-bbq...  wUu9WcGjP8KS6KlpARChyQ
# 18   https://www.yelp.com/biz/latin-bbq-north-berge...  Po5xPWsDdnHf41RnxQWhwg
# 19   https://www.yelp.com/biz/pig-heaven-new-york-3...  sfsjk1h50ooC2ioY7m48gw
# 20   https://www.yelp.com/biz/butcher-bar-astoria-2...  nkfUKb7oWQt54Uz9VQLhUg
# 21   https://www.yelp.com/biz/villa-brazil-cafe-gri...  tjstlcFtOiXnUU1MAG1uqg
# 22   https://www.yelp.com/biz/brazeiro-churrascaria...  eZRCx_bsjOsrwsfrAPYEew
# 23   https://www.yelp.com/biz/copacabana-astoria?ad...  oLcO1966IMx-Juv69hn6Cw
# 24   https://www.yelp.com/biz/fogo-de-chao-brazilia...  7B2XMvV5uGuKyl19-HTSvg
# 25   https://www.yelp.com/biz/aroma-brazil-restaura...  1-4W4i1fj9rp0Blrg0Q1zg
# 26   https://www.yelp.com/biz/churrascaria-platafor...  VnjcxOUuZAeJMiDIU-7hUQ
# 27   https://www.yelp.com/biz/brasilia-grill-newark...  KxUDnvmd4YpThY_5A9Seng
# 28   https://www.yelp.com/biz/brazilian-buffet-newa...  VQjDV6U3LcuiS19vPbbhlQ
# 29   https://www.yelp.com/biz/rainhas-churrascaria-...  hWmzrNyhPO3phBstCynSvw
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/sigiri-new-york?adjus...  NzU2hb0z0jGEOOv0-zTLEQ
# 171  https://www.yelp.com/biz/kyoto-brooklyn?adjust...  AFisWoWm0pfxEi1dMYitKw
# 172  https://www.yelp.com/biz/ootoya-chelsea-new-yo...  OLSSJIp8pu5UlugTF7tuHA
# 173  https://www.yelp.com/biz/sake-sushi-brooklyn-5...  kYURnv37Z5P_sir_QJGHzg
# 174  https://www.yelp.com/biz/teppan-bar-and-grill-...  D3LtTiVtIPOcUT_bjxztRA
# 175  https://www.yelp.com/biz/66s-fusion-brooklyn?a...  HGLH-sa-Fp3X6UXcaG7U0g
# 176  https://www.yelp.com/biz/blue-ribbon-sushi-iza...  TeBthQZ2xpxyvXheS08ovw
# 177  https://www.yelp.com/biz/mizumi-douglaston?adj...  aBcQo4Xy-Lcf3JfVcn94XA
# 178  https://www.yelp.com/biz/ninja-86-sushi-brookl...  vWQLcEnV7qwHPJvKOcxR5w
# 179  https://www.yelp.com/biz/yuka-japanese-restaur...  NlgC8TjNuf8sy6qg2xpqsQ
# 180  https://www.yelp.com/biz/iron-chef-house-brook...  91tQ4ToReVVCA5MTJi9gfw
# 181  https://www.yelp.com/biz/sashimi-ramen-express...  AtUxlW7ltZb73ZXMwpkY_g
# 182  https://www.yelp.com/biz/poc-american-fusion-a...  gEfsayvqWqI2KfCF43TJ_A
# 183  https://www.yelp.com/biz/flaming-grill-and-mod...  e96uZ0XXMwO8l7vfxH9jDQ
# 184  https://www.yelp.com/biz/ki-sushi-brooklyn?adj...  tT6teP3ZfCAfvdPdDoqG4A
# 185  https://www.yelp.com/biz/rakuzen-brooklyn?adju...  9MIkAs75TQzdwljVkUoZEg
# 186  https://www.yelp.com/biz/kikoo-sushi-new-york-...  k_rLFIMOAbvchgWKEuKdtw
# 187  https://www.yelp.com/biz/kikoo-sushi-new-york-...  Hkg4b2x8LlYbq2molIFdhw
# 188  https://www.yelp.com/biz/miyabi-asian-fusion-s...  UuiW2A-O11Q0baqSEUMvZA
# 189  https://www.yelp.com/biz/komorebi-full-house-b...  1yqrirjDVm40roP-NcU-Ig
# 190  https://www.yelp.com/biz/sushi-x-long-island-c...  r5tdEA1S-Almn_2cv-c6Sg
# 191  https://www.yelp.com/biz/akino-elmhurst?adjust...  22CRLIEfJWIO-8RjEiecAg
# 192  https://www.yelp.com/biz/sushi-lin-brooklyn-2?...  AFt1Qcec4_JNr6PWpkRYyw
# 193  https://www.yelp.com/biz/sushi-factory-brookly...  2h12doe_dr-_pj52ZrJ5hg
# 194  https://www.yelp.com/biz/han-dynasty-new-york-...  ojbH3wnRu050hRhkmoxRiA
# 195  https://www.yelp.com/biz/izakaya-toribar-new-y...  wpT1QU7PSQgQQ1DkzI00JA
# 196  https://www.yelp.com/biz/pure-thai-cookhouse-n...  MhceeLrM2_3mcKw5EGLY6A
# 197  https://www.yelp.com/biz/khao-kang-elmhurst?ad...  hA5QUlrSjpxMZ90Kof0bgA
# 198  https://www.yelp.com/biz/jungle-cafe-brooklyn-...  0XC6L2GCtuaNEI8XFEyD2g
# 199  https://www.yelp.com/biz/obao-new-york-3?adjus...  NN3mOWF5e_pnR1ArqM2bHQ
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_Buffet.csv')
