# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"thai","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': 'jjJc_CrkB2HodEinB6cWww',
#    'alias': 'lovemama-new-york',
#    'name': 'LoveMama',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bLlFKTlVuLfmF-lIDGIjZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lovemama-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5566,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.730408722512074,
#     'longitude': -73.98612673033213},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '174 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['174 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12122545370',
#    'display_phone': '(212) 254-5370',
#    'distance': 2859.902795118878},
#   {'id': 'B3_K2kUVbYOU0VaLcj_LTw',
#    'alias': 'thai-villa-new-york-2',
#    'name': 'Thai Villa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XKvKGgVuj4_jhqHPVQj4_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-villa-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3822,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73902, 'longitude': -73.99065},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '5 E 19th St',
#     'address2': 'G Floor',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 E 19th St', 'G Floor', 'New York, NY 10003']},
#    'phone': '+12128029999',
#    'display_phone': '(212) 802-9999',
#    'distance': 3744.570399827637},
#   {'id': 'O1fUmxt3kbV-rnyjBtzAfw',
#    'alias': 'thep-thai-restaurant-new-york-5',
#    'name': 'THEP Thai Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WymEpZCm4CPRTeVHXVyzXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thep-thai-restaurant-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1519,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77078, 'longitude': -73.95727},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1439 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1439 2nd Ave', 'New York, NY 10021']},
#    'phone': '+12128999995',
#    'display_phone': '(212) 899-9995',
#    'distance': 7904.787644740089},
#   {'id': 'wGFSTTB6b4MHJJUzBnVJeg',
#    'alias': 'top-thai-greenwich-new-york',
#    'name': 'Top Thai Greenwich',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4xK8iIj2rZrRvP9MMG7yOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/top-thai-greenwich-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1594,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.729771, 'longitude': -73.999392},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '235 Sullivan St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['235 Sullivan St', 'New York, NY 10012']},
#    'phone': '+16467264418',
#    'display_phone': '(646) 726-4418',
#    'distance': 2739.489773141031},
#   {'id': '9WgsvzaiXNAmmQGD0uQxFQ',
#    'alias': 'thai-holic-brooklyn',
#    'name': 'Thai Holic',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/iUqXan4GX7zWw8U7agjZBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-holic-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 480,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.693005, 'longitude': -73.971286},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '372 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['372 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17182229992',
#    'display_phone': '(718) 222-9992',
#    'distance': 2383.5456137420542},
#   {'id': '-OixbLnFLCzQclxCSbUQ8w',
#    'alias': 'up-thai-new-york',
#    'name': 'Up Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/78u5SWauEV0nu9Tus3bf6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/up-thai-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2509,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7698275926665,
#     'longitude': -73.9576330868512},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1411 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1411 2nd Ave', 'New York, NY 10021']},
#    'phone': '+12122561188',
#    'display_phone': '(212) 256-1188',
#    'distance': 7796.9126757590075},
#   {'id': 'qrydcGQpeDP_1oFvx3qOeg',
#    'alias': 'somtum-der-new-york',
#    'name': 'Somtum Der',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/85AftnoxLOq0T0HKHPSdgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/somtum-der-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 779,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7252151982238,
#     'longitude': -73.9842741682317},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '85 Ave A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 Ave A', 'New York, NY 10009']},
#    'phone': '+12122608570',
#    'display_phone': '(212) 260-8570',
#    'distance': 2354.956408341586},
#   {'id': 'MhceeLrM2_3mcKw5EGLY6A',
#    'alias': 'pure-thai-cookhouse-new-york',
#    'name': 'Pure Thai Cookhouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QFYS-7MPGlOjUUy_2TkwLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pure-thai-cookhouse-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2617,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.764291, 'longitude': -73.988159},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '766 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['766 9th Ave', 'New York, NY 10019']},
#    'phone': '+12125810999',
#    'display_phone': '(212) 581-0999',
#    'distance': 6563.765009094688},
#   {'id': 'I4FWrwXDC91lsfQLXYSeXA',
#    'alias': 'malii-new-york',
#    'name': 'Malii',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xckY06JuBqvDfWJhMP-6Hw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/malii-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 310,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.789432, 'longitude': -73.942962},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2028 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2028 2nd Ave', 'New York, NY 10029']},
#    'phone': '+12122892729',
#    'display_phone': '(212) 289-2729',
#    'distance': 10291.839523057411},
#   {'id': 'liZmIO0FqZwslLJfLDkfgw',
#    'alias': 'wayla-new-york',
#    'name': 'Wayla',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Se9IRHfGW8z9-292HJyKsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wayla-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 403,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7183, 'longitude': -73.9926038},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '100 Forsyth St',
#     'address2': 'Basement',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100 Forsyth St', 'Basement', 'New York, NY 10002']},
#    'phone': '+12122062500',
#    'display_phone': '(212) 206-2500',
#    'distance': 1436.4990587768912},
#   {'id': 'WJS06XxRdc6DD1s4LWE9HA',
#    'alias': 'fish-cheeks-new-york',
#    'name': 'Fish Cheeks',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pqupe3fe52869QQ23KkiBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fish-cheeks-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 864,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7258, 'longitude': -73.9927},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '55 Bond St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Bond St', 'New York, NY 10012']},
#    'phone': '+12126772223',
#    'display_phone': '(212) 677-2223',
#    'distance': 2258.7720584764224},
#   {'id': 'nxTEuWKzkK1tCF4LrhFSUQ',
#    'alias': 'pig-and-khao-new-york',
#    'name': 'Pig and Khao',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HxBiasXFwEpLeH7PLNP9Ug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pig-and-khao-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1690,
#    'categories': [{'alias': 'filipino', 'title': 'Filipino'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71926, 'longitude': -73.98475},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '68 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['68 Clinton St', 'New York, NY 10002']},
#    'phone': '+12129204485',
#    'display_phone': '(212) 920-4485',
#    'distance': 1733.9421500064454},
#   {'id': 'VoAuIReq_cPUrFwxbWqG_Q',
#    'alias': 'sala-thai-restaurant-new-york-2',
#    'name': 'Sala Thai Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rY-GxvSeet0K4kPzB44gXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sala-thai-restaurant-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 495,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7801199, 'longitude': -73.98032},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '307 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['307 Amsterdam Ave', 'New York, NY 10023']},
#    'phone': '+12124333999',
#    'display_phone': '(212) 433-3999',
#    'distance': 8383.821131514791},
#   {'id': 'AEHojbCPCrIhTko7olaqTg',
#    'alias': 'lil-chef-mama-new-york',
#    'name': 'Lil Chef Mama',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/D502Qh3UCQfAhF70H7unbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lil-chef-mama-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.708453, 'longitude': -74.005321},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '27 Cliff St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27 Cliff St', 'New York, NY 10038']},
#    'phone': '+16469645555',
#    'display_phone': '(646) 964-5555',
#    'distance': 984.8706027327107},
#   {'id': 'feY7PgoRjCp2qReaIitRkQ',
#    'alias': 'boran-brooklyn-2',
#    'name': 'Boran',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lOd6awn3sfathHtte1Ed2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boran-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 207,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6782327, 'longitude': -73.998062},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '462 Court St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['462 Court St', 'Brooklyn, NY 11231']},
#    'phone': '+17184900207',
#    'display_phone': '(718) 490-0207',
#    'distance': 3042.489267250247},
#   {'id': 'e64Y17DJgjotSz8B9gEI7Q',
#    'alias': 'ugly-baby-brooklyn-3',
#    'name': 'Ugly Baby',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/l8yQEU47KsIWXQpqU352Pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ugly-baby-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 359,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67795, 'longitude': -73.9961},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '407 Smith St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['407 Smith St', 'Brooklyn, NY 11231']},
#    'phone': '+13476893075',
#    'display_phone': '(347) 689-3075',
#    'distance': 3067.1882609950244},
#   {'id': 'eGIY_25KFspf8KefDQMj-Q',
#    'alias': 'lan-larb-new-york-2',
#    'name': 'Lan Larb',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KqhPzrcDeZUGj67IMTmK0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lan-larb-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 320,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.745373, 'longitude': -73.975807},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '637 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['637 2nd Ave', 'New York, NY 10016']},
#    'phone': '+12128891769',
#    'display_phone': '(212) 889-1769',
#    'distance': 4705.484604086747},
#   {'id': 'kZ5q8Uwxt3MpLcvxEdPeFg',
#    'alias': 'marwin-thai-restaurant-new-york',
#    'name': 'Marwin Thai Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6Wj2xRkyYaflgI-H0YYkdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marwin-thai-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.76158, 'longitude': -73.96032},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'location': {'address1': '1132 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1132 1st Ave', 'New York, NY 10065']},
#    'phone': '+19176757698',
#    'display_phone': '(917) 675-7698',
#    'distance': 6866.481586012883},
#   {'id': '-XYp6w50XbZfS90YddS5ew',
#    'alias': 'soothr-new-york-2',
#    'name': 'Soothr',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7Kg74WVsVfMB-2eG0I_QAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soothr-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 284,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.732259, 'longitude': -73.987363},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '204 E 13th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['204 E 13th St', 'New York, NY 10003']},
#    'phone': '+12128449789',
#    'display_phone': '(212) 844-9789',
#    'distance': 3043.263183253491},
#   {'id': '0IFDnYf3bhqxJR6hVrG7Gw',
#    'alias': 'top-thai-55-carmine-new-york-2',
#    'name': 'Top Thai 55 - Carmine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-ZoEVVSfXiLLw8NLKSF9BA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/top-thai-55-carmine-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 497,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'halal', 'title': 'Halal'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.729967, 'longitude': -74.004229},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '55 Carmine St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Carmine St', 'New York, NY 10014']},
#    'phone': '+16466092272',
#    'display_phone': '(646) 609-2272',
#    'distance': 2850.6467662416635},
#   {'id': 'dqjko5ndMGayALuhwq3ghQ',
#    'alias': 'thailicious-new-york-3',
#    'name': 'Thailicious',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Zu4TCkvWV-DdvvCR6Vxo6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thailicious-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 176,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71931, 'longitude': -73.9851608},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '71 Clinton St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['71 Clinton St', 'New York, NY 10002']},
#    'phone': '+16468820343',
#    'display_phone': '(646) 882-0343',
#    'distance': 1723.1978419575535},
#   {'id': 'BKMCAYb9EAivUm3p-vrC9w',
#    'alias': 'khe-yo-new-york',
#    'name': 'Khe-Yo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ai79Wa0Z8ecgZwnpvjDIkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khe-yo-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 843,
#    'categories': [{'alias': 'laotian', 'title': 'Laotian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.716906, 'longitude': -74.008587},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '157 Duane St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['157 Duane St', 'New York, NY 10013']},
#    'phone': '+12125871089',
#    'display_phone': '(212) 587-1089',
#    'distance': 1753.7446005214726},
#   {'id': 'nFszVPUX4tj-oarjfBO0nw',
#    'alias': 'klong-new-york',
#    'name': 'Klong',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QcX3gIQslp9gpXk9QUMpBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/klong-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1133,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729507, 'longitude': -73.989181},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '7 St Marks Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 St Marks Pl', 'New York, NY 10003']},
#    'phone': '+12125059955',
#    'display_phone': '(212) 505-9955',
#    'distance': 2719.0288253184776},
#   {'id': 'NN3mOWF5e_pnR1ArqM2bHQ',
#    'alias': 'obao-new-york-3',
#    'name': 'OBAO',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CpVI2XJLrvg09Fm83bfPog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/obao-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2751,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7606544, 'longitude': -73.991332},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '647 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['647 9th Ave', 'New York, NY 10036']},
#    'phone': '+12122458880',
#    'display_phone': '(212) 245-8880',
#    'distance': 6144.081737145313},
#   {'id': 'IGjdEM0s4WfOYrMSzO6q9Q',
#    'alias': 'krok-brooklyn-brooklyn-2',
#    'name': 'KROK Brooklyn',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Xo1YcH67_21bNyXODTylAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/krok-brooklyn-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 81,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68758900312233,
#     'longitude': -74.00120192883554},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '117 Columbia St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['117 Columbia St', 'Brooklyn, NY 11231']},
#    'phone': '+17188588898',
#    'display_phone': '(718) 858-8898',
#    'distance': 2069.1453279350276},
#   {'id': 'XgiG7K7ubHsj2JJ-c2sXnw',
#    'alias': 'thai-diner-new-york',
#    'name': 'Thai Diner',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qgJHYdMOogBT5zpPrQiggg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-diner-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 247,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72071042964739, 'longitude': -73.9956057},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '186 Mott St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['186 Mott St', 'New York, NY 10012']},
#    'phone': '+16465594140',
#    'display_phone': '(646) 559-4140',
#    'distance': 1701.0522709842332},
#   {'id': 'O8i5XlvcfzH1q-wpfURrpg',
#    'alias': 'ayada-thai-chelsea-market-new-york-2',
#    'name': 'Ayada Thai - Chelsea Market',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XnVyAZQN7Q8cO_iBpjs_sA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ayada-thai-chelsea-market-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 138,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74222, 'longitude': -74.00466},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '75 9th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 9th Ave', 'New York, NY 10011']},
#    'phone': '+12126459445',
#    'display_phone': '(212) 645-9445',
#    'distance': 4160.424215067582},
#   {'id': 'l_gQf_4NgPMJcx2OkjsMfg',
#    'alias': 'noods-n-chill-brooklyn',
#    'name': 'Noods n’ Chill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hP1kidGsvB9iEgLr8uUUOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noods-n-chill-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 105,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71194, 'longitude': -73.96121},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '170 S 3rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['170 S 3rd St', 'Brooklyn, NY 11211']},
#    'phone': '+17183887695',
#    'display_phone': '(718) 388-7695',
#    'distance': 2874.5347935406644},
#   {'id': 'f7jZvRH-h76F4emzvKytaQ',
#    'alias': 'tuk-tuk-long-island-city',
#    'name': 'Tuk Tuk',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8Q8ojT6I_SyUYLTGSoFdyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tuk-tuk-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 717,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.743232, 'longitude': -73.954254},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '4906 Vernon Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4906 Vernon Blvd', 'Long Island City, NY 11101']},
#    'phone': '+17184725598',
#    'display_phone': '(718) 472-5598',
#    'distance': 5389.827078491865},
#   {'id': '0GftSP2dRwEzujkv2VKIgA',
#    'alias': 'wok-wok-southeast-asian-kitchen-new-york',
#    'name': 'Wok Wok Southeast Asian Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XOc7n_rq6kYGXySwasouRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wok-wok-southeast-asian-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1069,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7140555, 'longitude': -73.9988387116394},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '11 Mott St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 Mott St', 'New York, NY 10013']},
#    'phone': '+19173883627',
#    'display_phone': '(917) 388-3627',
#    'distance': 1031.2690925773445},
#   {'id': '0L03onqNwxWLrbb_FCK79A',
#    'alias': 'sripraphai-thai-restaurant-woodside',
#    'name': 'SriPraPhai Thai Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ror9gVp9hFCCwcbJ5_noaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sripraphai-thai-restaurant-woodside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2408,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7464987, 'longitude': -73.8992328},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '64-13 39th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64-13 39th Ave', 'Woodside, NY 11377']},
#    'phone': '+17188999599',
#    'display_phone': '(718) 899-9599',
#    'distance': 9219.94935152076},
#   {'id': 'ihBRikaKYVdJ7M0gVEGjZg',
#    'alias': 'maomao-brooklyn-5',
#    'name': 'Maomao',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Y9U30z_aX2CdSCSTn879fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maomao-brooklyn-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69583, 'longitude': -73.933508},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1000 Bdwy',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1000 Bdwy', 'Brooklyn, NY 11221']},
#    'phone': '+19178330895',
#    'display_phone': '(917) 833-0895',
#    'distance': 5234.524943145931},
#   {'id': 'g7qtHQ_121mYWUdu3VWlrA',
#    'alias': 'tong-brooklyn',
#    'name': 'Tong',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yLdDN-6mdb07KblZKp1qhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tong-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 66,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.708053, 'longitude': -73.920502},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '321 Starr St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['321 Starr St', 'Brooklyn, NY 11237']},
#    'phone': '+17183660586',
#    'display_phone': '(718) 366-0586',
#    'distance': 6226.370732963361},
#   {'id': 'sy24z1YfzTpLuj59_kovDA',
#    'alias': 'yoongkao-thai-dining-new-york',
#    'name': 'Yoongkao Thai Dining',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/U3abTAWYddFEciT7Gcpo7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yoongkao-thai-dining-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74505, 'longitude': -73.97591},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '625 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['625 2nd Ave', 'New York, NY 10016']},
#    'phone': '+16466698424',
#    'display_phone': '(646) 669-8424',
#    'distance': 4669.354782395737},
#   {'id': 'mpD_kUFo8POQDLoLgRSfCg',
#    'alias': 'sage-brooklyn',
#    'name': 'SAGE',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yqyWPbMSiqzwn48EPFPP5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sage-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 635,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7129736, 'longitude': -73.9442765},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '299-301 Graham Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['299-301 Graham Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17182186644',
#    'display_phone': '(718) 218-6644',
#    'distance': 4298.170607587344},
#   {'id': '9v4l7pz4J709z0mkqUpQbw',
#    'alias': 'savory-thai-brooklyn-4',
#    'name': 'Savory Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BD5EYmjCQT9GeI0VGOlvHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/savory-thai-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71395, 'longitude': -73.95554},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '378 Metropolitan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['378 Metropolitan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13477213878',
#    'display_phone': '(347) 721-3878',
#    'distance': 3391.5267651556655},
#   {'id': 'McU7XI3HoWFELTDaGc1SEw',
#    'alias': 'ginger-and-lemongrass-new-york-2',
#    'name': 'Ginger and Lemongrass',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hsU_1M52BlXu1X5t9a4-ZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginger-and-lemongrass-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 451,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71912, 'longitude': -73.98567},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '153 Rivington St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['153 Rivington St', 'New York, NY 10002']},
#    'phone': '+16468761237',
#    'display_phone': '(646) 876-1237',
#    'distance': 1686.4399758635075},
#   {'id': 'qusZ-K5tzM1EyOa1IEWCHA',
#    'alias': 'nourish-brooklyn-4',
#    'name': 'Nourish',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vu0P_ORyUMI-Sz5xwOacuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nourish-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 288,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.677941, 'longitude': -73.968455},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '637A Vanderbilt Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['637A Vanderbilt Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17187893981',
#    'display_phone': '(718) 789-3981',
#    'distance': 3752.4722090267096},
#   {'id': 'xRvMOTMzDrMfyAWbYhkA8A',
#    'alias': 'terra-thai-new-york',
#    'name': 'Terra Thai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WJvFxBYsZjSWXxqlUN2uzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/terra-thai-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.724896, 'longitude': -73.983031},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '518 E 6th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['518 E 6th St', 'New York, NY 10009']},
#    'phone': '+16464787415',
#    'display_phone': '(646) 478-7415',
#    'distance': 2361.9100123091093},
#   {'id': 'p2zm0HnXZkI2yCAuYLb45g',
#    'alias': 'thai-market-new-york',
#    'name': 'Thai Market',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jPGJaYsRiU_se_UJzphxkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-market-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1031,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.80132, 'longitude': -73.96529},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '960 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['960 Amsterdam Ave', 'New York, NY 10025']},
#    'phone': '+12122804575',
#    'display_phone': '(212) 280-4575',
#    'distance': 10940.010065176182},
#   {'id': 'a-Bq_yXFVk2PptoWpmry3w',
#    'alias': 'pye-boat-noodle-astoria',
#    'name': 'Pye Boat Noodle',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jxPnZAwHuRciVqUAd14P4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pye-boat-noodle-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 877,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76043, 'longitude': -73.92152},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '35-13 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35-13 Broadway', 'Astoria, NY 11106']},
#    'phone': '+17186852329',
#    'display_phone': '(718) 685-2329',
#    'distance': 8656.427099874069},
#   {'id': 'n20BmzZ-KGd0RCKcPGRv1A',
#    'alias': 'klom-klorm-brooklyn',
#    'name': 'Klom Klorm',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/97vZYw_-bF6zMSP2BqOAcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/klom-klorm-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 345,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70318, 'longitude': -73.91701},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '181 Wyckoff Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['181 Wyckoff Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17184899188',
#    'display_phone': '(718) 489-9188',
#    'distance': 6517.2874846716195},
#   {'id': 'QVWmn5jmy_TPmg0G71Dk5g',
#    'alias': 'sea-brooklyn-2',
#    'name': 'Sea',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UbY8oEZIcLzPHPqkHdXYaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sea-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3205,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71807, 'longitude': -73.960044},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '114 N 6th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['114 N 6th St', 'Brooklyn, NY 11211']},
#    'phone': '+17183848850',
#    'display_phone': '(718) 384-8850',
#    'distance': 3210.611387108361},
#   {'id': 'AkoNWXRhZWyJInoWI1AaZw',
#    'alias': 'pad-thai-kitchen-brooklyn',
#    'name': 'Pad Thai Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iIi2r4HbYHZr6qrQmcY-3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pad-thai-kitchen-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 110,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.620614, 'longitude': -73.989027},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '6218 18th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11204',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6218 18th Ave', 'Brooklyn, NY 11204']},
#    'phone': '+17184840156',
#    'display_phone': '(718) 484-0156',
#    'distance': 9442.140183514946},
#   {'id': '5ZjNZd3Yg0jOkJ9WRx1r6g',
#    'alias': 'kor-tor-mor-brooklyn',
#    'name': 'Kor Tor Mor',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/g8vp1MFooFU7-mUZbnjOAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kor-tor-mor-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 271,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6846634, 'longitude': -73.9918633},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '204 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['204 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17187975100',
#    'display_phone': '(718) 797-5100',
#    'distance': 2319.8537216888553},
#   {'id': 'liGIz8CzhyS1udx1aefjng',
#    'alias': 'williamsburg-thai-cuisine-brooklyn',
#    'name': 'Williamsburg Thai Cuisine',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Rb4WdnfScKrktF0O_ZWqqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/williamsburg-thai-cuisine-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 254,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71699, 'longitude': -73.9588799},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '212 Bedford Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['212 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+19293377651',
#    'display_phone': '(929) 337-7651',
#    'distance': 3250.468442566167},
#   {'id': 'UC3n_0vZ5zI1fvi7UzNZAg',
#    'alias': 'sabai-thai-new-york-2',
#    'name': 'Sabai Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/S6__V4_5-eGub10wtnaRaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sabai-thai-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 339,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74422, 'longitude': -73.98365},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '432 Park Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['432 Park Ave S', 'New York, NY 10016']},
#    'phone': '+16464764521',
#    'display_phone': '(646) 476-4521',
#    'distance': 4412.21786588836},
#   {'id': 'jiQMBtFQ0nY1hv3vRPM66w',
#    'alias': 'the-nuaa-table-brooklyn',
#    'name': 'The Nuaa Table',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vLMUNKUueybtbfXFf3Anww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-nuaa-table-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.679366, 'longitude': -73.968485},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '638 Bergen St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['638 Bergen St', 'Brooklyn, NY 11238']},
#    'phone': '+17186236395',
#    'display_phone': '(718) 623-6395',
#    'distance': 3628.310888943038},
#   {'id': '83BXSwE0166sObnXLUE4bQ',
#    'alias': 'land-new-york',
#    'name': 'Land',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ptDV_QtdeLeSvBZs-tTqWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/land-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1069,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78497, 'longitude': -73.9772182},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '450 Amsterdam Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['450 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12125018121',
#    'display_phone': '(212) 501-8121',
#    'distance': 8959.014790043642},
#   {'id': 'pSSajdYNKTyAGV8-fk7fWQ',
#    'alias': 'joya-brooklyn',
#    'name': 'Joya',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/X4HbR16EFVcywHtrW7BPqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joya-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1332,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.686672, 'longitude': -73.993544},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '215 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['215 Court St', 'Brooklyn, NY 11201']},
#    'phone': '+17182223484',
#    'display_phone': '(718) 222-3484',
#    'distance': 2087.041238313192}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#              Restaurant  Type Price Rating          Address        Lat  \
# 0              LoveMama  Thai    $$    4.5      174 2nd Ave  40.730409
# 1            Thai Villa  Thai    $$    4.5      5 E 19th St  40.739020
# 2  THEP Thai Restaurant  Thai    $$    4.5     1439 2nd Ave  40.770780
# 3    Top Thai Greenwich  Thai    $$    4.5  235 Sullivan St  40.729771
# 4            Thai Holic  Thai    $$    4.5   372 Myrtle Ave  40.693005
#
#          Lng                                                url  \
# 0 -73.986127  https://www.yelp.com/biz/lovemama-new-york?adj...
# 1 -73.990650  https://www.yelp.com/biz/thai-villa-new-york-2...
# 2 -73.957270  https://www.yelp.com/biz/thep-thai-restaurant-...
# 3 -73.999392  https://www.yelp.com/biz/top-thai-greenwich-ne...
# 4 -73.971286  https://www.yelp.com/biz/thai-holic-brooklyn?a...
#
#                        ID
# 0  jjJc_CrkB2HodEinB6cWww
# 1  B3_K2kUVbYOU0VaLcj_LTw
# 2  O1fUmxt3kbV-rnyjBtzAfw
# 3  wGFSTTB6b4MHJJUzBnVJeg
# 4  9WgsvzaiXNAmmQGD0uQxFQ

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"thai","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': 'RrPIJvmje1qb9iaYd6jH0g',
#    'alias': 'pinto-brooklyn-3',
#    'name': 'Pinto',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QzRfSeXdqIx4y7Vbov9vHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pinto-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 231,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69467724943562,
#     'longitude': -73.99423425339312},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '128 Montague St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['128 Montague St', 'Brooklyn, NY 11201']},
#    'phone': '+19293377732',
#    'display_phone': '(929) 337-7732',
#    'distance': 1197.3131497975153},
#   {'id': 'EbX_9tqAJs4gW51gZpOB7g',
#    'alias': 'rasa-new-york',
#    'name': 'Rasa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nDMosrGaz6OOVsoTjkrLTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rasa-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 765,
#    'categories': [{'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7327654, 'longitude': -73.9975674},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '25 W 8th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 W 8th St', 'New York, NY 10011']},
#    'phone': '+12122541888',
#    'display_phone': '(212) 254-1888',
#    'distance': 3050.407691012176},
#   {'id': 'HnTcWZbZJzNAYO8YseQlSQ',
#    'alias': 'zabb-putawn-new-york-2',
#    'name': 'Zabb PuTawn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ff_QsBXJ9db9TWNIWUKHSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zabb-putawn-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 248,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77446, 'longitude': -73.95077},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1584 First Av',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1584 First Av', 'New York, NY 10028']},
#    'phone': '+12129888800',
#    'display_phone': '(212) 988-8800',
#    'distance': 8504.539456073351},
#   {'id': '1sEr-BDi2LD6HH6K960pfQ',
#    'alias': 'ace-thai-kitchen-brooklyn-3',
#    'name': 'ACE Thai Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DDDufVScz4Ae3wjz_i0e1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ace-thai-kitchen-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 107,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69315, 'longitude': -73.97328},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '330 Myrtle Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['330 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+13479874100',
#    'display_phone': '(347) 987-4100',
#    'distance': 2240.064612841999},
#   {'id': 'rCtsqHtOAOjZ7EUQDFRSbA',
#    'alias': 'pinto-garden-new-york-3',
#    'name': 'Pinto Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Q4b5LKC2PGWMesBgDy85Cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pinto-garden-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 326,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.734882, 'longitude': -73.9994844},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '117 W 10th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['117 W 10th St', 'New York, NY 10011']},
#    'phone': '+12123665455',
#    'display_phone': '(212) 366-5455',
#    'distance': 3302.3633301992627},
#   {'id': 'StFf9fVnAlhwrUWan0C4Ww',
#    'alias': 'wanisa-home-kitchen-brooklyn',
#    'name': 'Wanisa Home Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/azd794dZJoROs5zyEizhrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wanisa-home-kitchen-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 169,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.687, 'longitude': -73.99042},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '142 Smith St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['142 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17185223027',
#    'display_phone': '(718) 522-3027',
#    'distance': 2074.755884968529},
#   {'id': 'yt6reb5HlIhJRubUVX80WA',
#    'alias': 'talay-restaurant-staten-island',
#    'name': 'Talay Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/t7fKsUqxia6WKIxWaQkC2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/talay-restaurant-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.64249, 'longitude': -74.07665},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '154 Stuyvesant Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10301',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['154 Stuyvesant Pl', 'Staten Island, NY 10301']},
#    'phone': '+17165991365',
#    'display_phone': '(716) 599-1365',
#    'distance': 9867.857788184738},
#   {'id': '_zRVdCfUcx1cwseFycSQdQ',
#    'alias': 'thai-farm-kitchen-brooklyn',
#    'name': 'Thai Farm Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LPDdTtx-3TbMwaocArwC8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-farm-kitchen-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 275,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.644041754256,
#     'longitude': -73.9760518446565},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '416 Church Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11218',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['416 Church Ave', 'Brooklyn, NY 11218']},
#    'phone': '+13475339368',
#    'display_phone': '(347) 533-9368',
#    'distance': 6998.862222232292},
#   {'id': 'rKeLuHDI3PQZsPSVCEMHtw',
#    'alias': 'wondee-siam-new-york-3',
#    'name': 'Wondee Siam',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dbQSuZI7iTsdq7BacBk2MA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wondee-siam-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1057,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76495, 'longitude': -73.98747},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '792 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['792 9th Ave', 'New York, NY 10019']},
#    'phone': '+12124599057',
#    'display_phone': '(212) 459-9057',
#    'distance': 6639.674884696999},
#   {'id': 'M-odQWSEfsR2mVEw7nKG-g',
#    'alias': 'nyonya-new-york',
#    'name': 'Nyonya',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YuWC1Gwo7ku4PvD-7mDQnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nyonya-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2151,
#    'categories': [{'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7190148, 'longitude': -73.9968228},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '199 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['199 Grand St', 'New York, NY 10013']},
#    'phone': '+12123343669',
#    'display_phone': '(212) 334-3669',
#    'distance': 1524.9858332338151},
#   {'id': 'cegA4jf16vEt7NCQ7cpu2w',
#    'alias': 'kind-fresh-meadows',
#    'name': "Kin'd",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/75GptlVgTc9HqZoyHdu8NQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kind-fresh-meadows?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 863,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73031, 'longitude': -73.77814},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '192-03 Union Tpke',
#     'address2': '',
#     'address3': None,
#     'city': 'Fresh Meadows',
#     'zip_code': '11366',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['192-03 Union Tpke', 'Fresh Meadows, NY 11366']},
#    'phone': '+17184680888',
#    'display_phone': '(718) 468-0888',
#    'distance': 18401.011784437622},
#   {'id': 'sinDhwX8Egru_3FCI7bhkw',
#    'alias': 'laut-new-york',
#    'name': 'Laut',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9GbaF4tmf1OuhcSbeN0vKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laut-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1278,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'singaporean', 'title': 'Singaporean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73756, 'longitude': -73.9911},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '15 E 17th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 E 17th St', 'New York, NY 10003']},
#    'phone': '+12122068989',
#    'display_phone': '(212) 206-8989',
#    'distance': 3586.6195275391437},
#   {'id': 'UO4kyXfdQIlAhM-TRgM9cw',
#    'alias': 'look-by-plant-love-house-brooklyn-2',
#    'name': 'Look By Plant Love House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8ZwIueHuO16VtZGbMWzciw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/look-by-plant-love-house-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 339,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.679893, 'longitude': -73.964447},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '622 Washington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['622 Washington Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17186220026',
#    'display_phone': '(718) 622-0026',
#    'distance': 3798.9064789978547},
#   {'id': '-Q8MYIWoE4EsGQtudIOY0w',
#    'alias': 'bua-thai-ramen-and-robata-grill-new-york',
#    'name': 'Bua Thai Ramen & Robata Grill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/STPkeCnzxNZTax2QYGhe-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bua-thai-ramen-and-robata-grill-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1129,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77635, 'longitude': -73.95308},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1611 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1611 2nd Ave', 'New York, NY 10028']},
#    'phone': '+12128797999',
#    'display_phone': '(212) 879-7999',
#    'distance': 8614.977282214206},
#   {'id': 'ZfuZ2byArGq-5j8zX8Afeg',
#    'alias': 'zest-sushi-new-york-3',
#    'name': 'Zest Sushi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W0-g2DqPNGEih80-h92b8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zest-sushi-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 867,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7178344726563,
#     'longitude': -73.9899597167969},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '249 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['249 Broome St', 'New York, NY 10002']},
#    'phone': '+12126773158',
#    'display_phone': '(212) 677-3158',
#    'distance': 1425.2566698018184},
#   {'id': 'YS8pw7sYOBqaW23FCOqecg',
#    'alias': 'glur-thai-new-york',
#    'name': 'Glur Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qVRmUeQWlYt71Rmnc4I7DQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/glur-thai-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 169,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74121, 'longitude': -73.99665},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '144 W 19th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['144 W 19th St', 'New York, NY 10011']},
#    'phone': '+12127389898',
#    'display_phone': '(212) 738-9898',
#    'distance': 3970.4266835826643},
#   {'id': 'vA2VEhW6S1ioX6tXtQdO9A',
#    'alias': 'lemongrass-grill-brooklyn-2',
#    'name': 'Lemongrass Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ttKyVZY6xDaeIboOVpVnkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lemongrass-grill-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 497,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.688684, 'longitude': -73.993137},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '156 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156 Court St', 'Brooklyn, NY 11201']},
#    'phone': '+17185229728',
#    'display_phone': '(718) 522-9728',
#    'distance': 1868.3529526910174},
#   {'id': '1KoKR9fug8VXZr5tqqtimQ',
#    'alias': 'rim-nam-thai-brooklyn',
#    'name': 'Rim Nam Thai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/C45gqQ7OAHtanVuhSmSjxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rim-nam-thai-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7033674860089, 'longitude': -73.9868891},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '52 Jay St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['52 Jay St', 'Brooklyn, NY 11201']},
#    'phone': '+19292980337',
#    'display_phone': '(929) 298-0337',
#    'distance': 665.5044429640708},
#   {'id': 'z1OgXX3L9Ipl2mu-Hf4ADw',
#    'alias': 'viv-new-york-32',
#    'name': 'VIV',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-HcRhoHIXVjzUKMXj7vZYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/viv-new-york-32?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1030,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76277, 'longitude': -73.98969},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '717 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['717 9th Ave', 'New York, NY 10019']},
#    'phone': '+12125815999',
#    'display_phone': '(212) 581-5999',
#    'distance': 6387.667223867158},
#   {'id': 'L2ZW-MdvRJ3gM2RIq8STbA',
#    'alias': 'thai72-new-york',
#    'name': 'Thai72',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wB3j5dPiZmPtGdxzfPCR8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai72-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 284,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77763, 'longitude': -73.98003},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '128 W 72nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['128 W 72nd St', 'New York, NY 10023']},
#    'phone': '+12124966153',
#    'display_phone': '(212) 496-6153',
#    'distance': 8115.4012965108495},
#   {'id': '9b_FvTUgkkUUMyL0nGhFtg',
#    'alias': 'three-roosters-new-york',
#    'name': 'Three Roosters',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RZJDNAXD9ATfNk5ErLSLVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/three-roosters-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 79,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.764957, 'longitude': -73.987485},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '792 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['792 9th Ave', 'New York, NY 10019']},
#    'phone': '+19172614055',
#    'display_phone': '(917) 261-4055',
#    'distance': 6640.475059154251},
#   {'id': 'Wq9cARVEwOmoqfg41mNRNg',
#    'alias': 'noree-thai-bazaar-new-york',
#    'name': 'Noree Thai Bazaar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/o2rQ3DMNnTaRaoiUIFBtMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noree-thai-bazaar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 190,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7178949956625,
#     'longitude': -73.9928582310677},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '274 Grand St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['274 Grand St', 'New York, NY 10002']},
#    'phone': '+16468640338',
#    'display_phone': '(646) 864-0338',
#    'distance': 1389.6632483859646},
#   {'id': 'SoEQRDUNYDZPVSSIhTOG6A',
#    'alias': 'muse-brooklyn',
#    'name': 'Muse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uSBvWNseDN7KCPjgfrJwuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/muse-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 106,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6766485, 'longitude': -73.96339957259552},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '689 Washington Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['689 Washington Ave', 'Brooklyn, NY 11238']},
#    'phone': '+13474420443',
#    'display_phone': '(347) 442-0443',
#    'distance': 4127.628484052107},
#   {'id': 'GSOwJ5Gr8X4eGbkIjCzMWA',
#    'alias': 'thaism-brooklyn',
#    'name': 'Thaism',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1T2byRRWjTKJ2beEC0S49g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thaism-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 169,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6824841, 'longitude': -73.9935637},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '278 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['278 Smith St', 'Brooklyn, NY 11231']},
#    'phone': '+17188340505',
#    'display_phone': '(718) 834-0505',
#    'distance': 2553.8583862164905},
#   {'id': '6wJOojpF2c4lLeBNbTBB0A',
#    'alias': 'baoburg-brooklyn-2',
#    'name': 'Baoburg',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dKj992_3gxwfLizCVFBCUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baoburg-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 270,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7234929271998,
#     'longitude': -73.9503321851175},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '614 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['614 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183490011',
#    'display_phone': '(718) 349-0011',
#    'distance': 4213.725334102182},
#   {'id': 'pcVlzw0Id0MvP8MJYMRgJg',
#    'alias': 'river-thai-new-york-2',
#    'name': 'River Thai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dkVxNF6X2SHMeuWCr6Djkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/river-thai-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.82685, 'longitude': -73.94666},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1766 Amsterdam Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10031',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1766 Amsterdam Ave', 'New York, NY 10031']},
#    'phone': '+16464908290',
#    'display_phone': '(646) 490-8290',
#    'distance': 14085.821718304529},
#   {'id': '5pzc2GdvdmqiLRSdjHnnKw',
#    'alias': 'bangkok-avenue-little-neck-2',
#    'name': 'Bangkok Avenue',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-6MNVU7V930qB3PvdLHKAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bangkok-avenue-little-neck-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 143,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77135, 'longitude': -73.73529},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '253-21 Northern Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Little Neck',
#     'zip_code': '11362',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253-21 Northern Blvd', 'Little Neck, NY 11362']},
#    'phone': '+19143033388',
#    'display_phone': '(914) 303-3388',
#    'distance': 23019.786025414527},
#   {'id': 'rehmlZmUNL2AthW-VTXJJQ',
#    'alias': 'tasty-thai-ridgewood',
#    'name': 'Tasty Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NX0ocs11fl3Dj1kTmpBrRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tasty-thai-ridgewood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 107,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69984, 'longitude': -73.89958},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '72-04 Forest Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['72-04 Forest Ave', 'Ridgewood, NY 11385']},
#    'phone': '+19179090937',
#    'display_phone': '(917) 909-0937',
#    'distance': 8005.09091781871},
#   {'id': 'hA5QUlrSjpxMZ90Kof0bgA',
#    'alias': 'khao-kang-elmhurst',
#    'name': 'Khao Kang',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vfRK27R36XLI4wHpZr6bHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khao-kang-elmhurst?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 255,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.743269, 'longitude': -73.888039},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '7620 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7620 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17188061807',
#    'display_phone': '(718) 806-1807',
#    'distance': 9892.601528091449},
#   {'id': '_c0MxccsmIBZcGLJpb4nSA',
#    'alias': 'nana-thai-street-new-york',
#    'name': 'NaNa Thai Street',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/scVeDpNKRBwnA_5iQWggAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nana-thai-street-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 137,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73954, 'longitude': -73.98854},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '31 E 21st St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31 E 21st St', 'New York, NY 10010']},
#    'phone': '+12124207500',
#    'display_phone': '(212) 420-7500',
#    'distance': 3830.8073292537733},
#   {'id': 'F_16U6tXkSSZYsjotzr-cA',
#    'alias': 'appethaize-new-york',
#    'name': 'AppeThaize',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2QU_t_0_qSF-LD5mkA99zA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/appethaize-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.716353, 'longitude': -73.999926},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '75 Baxter St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 Baxter St', 'New York, NY 10013']},
#    'phone': '+16466699353',
#    'display_phone': '(646) 669-9353',
#    'distance': 1294.1263527323606},
#   {'id': 'KHdYPT0jUnUGdHGaY73mxg',
#    'alias': 'sukhumvit-51-new-york',
#    'name': 'Sukhumvit 51',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qCdrI6n9UN9J6Kgu3HFCjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sukhumvit-51-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 774,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7559139831703,
#     'longitude': -73.9693867939228},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '224 E 51st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['224 E 51st St', 'New York, NY 10022']},
#    'phone': '+12128888894',
#    'display_phone': '(212) 888-8894',
#    'distance': 5991.479858543423},
#   {'id': 'uVoFnGvcwk2wSNwATtuf8g',
#    'alias': 'thai-hot-box-new-york',
#    'name': 'Thai Hot Box',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VqS9PM75T04ow9lxlKkSrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-hot-box-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78123, 'longitude': -73.95246},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1598 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1598 3rd Ave', 'New York, NY 10128']},
#    'phone': '+19174091641',
#    'display_phone': '(917) 409-1641',
#    'distance': 9135.559420050742},
#   {'id': 'SBy46BviyBKowPjbTjDsHQ',
#    'alias': 'lantern-brooklyn',
#    'name': 'Lantern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iHCexP4alMF6GHCDuNKyLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lantern-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 480,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.69533, 'longitude': -73.99544},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '101 Montague St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['101 Montague St', 'Brooklyn, NY 11201']},
#    'phone': '+17182372594',
#    'display_phone': '(718) 237-2594',
#    'distance': 1132.8854453675879},
#   {'id': 'RdGWCbcxA79G1ZMPVL3SGQ',
#    'alias': 'nora-thai-brooklyn-4',
#    'name': 'Nora Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pKgSo4nNsd0-FiRAvahoXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nora-thai-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 94,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71864, 'longitude': -73.95625},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '176 N 9th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['176 N 9th St', 'Brooklyn, NY 11211']},
#    'phone': '+17183021499',
#    'display_phone': '(718) 302-1499',
#    'distance': 3511.550118914059},
#   {'id': '9UkHgv9R3LakP0vNj6DMIg',
#    'alias': 'charm-kao-brooklyn',
#    'name': 'Charm Kao',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DAHQe_wP_Skuxrhbt492Mg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/charm-kao-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6892229764259,
#     'longitude': -73.9863216751898},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '193 Schermerhorn St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['193 Schermerhorn St', 'Brooklyn, NY 11201']},
#    'phone': '+13475991748',
#    'display_phone': '(347) 599-1748',
#    'distance': 1924.911553192453},
#   {'id': '_ucIHYqW0ZwAdzaEIYnnsA',
#    'alias': 'one-two-thai-new-york-2',
#    'name': 'One Two Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dnbNdOhUD8vzX5J3PmBTVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/one-two-thai-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 114,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.745573, 'longitude': -73.979451},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '153 E 33 St 10016',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['153 E 33 St 10016', 'New York, NY 10016']},
#    'phone': '+16469186144',
#    'display_phone': '(646) 918-6144',
#    'distance': 4636.646797251755},
#   {'id': 'dVR5KHPMZoU9rQvxhY5Otw',
#    'alias': 'thai-terminal-new-york-2',
#    'name': 'Thai Terminal',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SsEH6bvxVTJzF9rAGxvT3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-terminal-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 582,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73039, 'longitude': -73.98381},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '349 E 12th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['349 E 12th St', 'New York, NY 10003']},
#    'phone': '+12126140155',
#    'display_phone': '(212) 614-0155',
#    'distance': 2909.1995849569603},
#   {'id': 'cPXF0NTHTHEdWLDwknWHXA',
#    'alias': 'huge-thai-brooklyn',
#    'name': 'Huge Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bOMI0tpm7evod5yV7zxR-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/huge-thai-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68887, 'longitude': -73.99261},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '157 Court St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['157 Court St', 'Brooklyn, NY 11201']},
#    'phone': '+13479874198',
#    'display_phone': '(347) 987-4198',
#    'distance': 1850.0768895950473},
#   {'id': 'V58g7E1AHkuTchTVyLQuYQ',
#    'alias': 'saigon-grill-and-bar-brooklyn-3',
#    'name': 'Saigon Grill & Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/n0P0wybogAiDPrhsXoF0Fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saigon-grill-and-bar-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 248,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.61883, 'longitude': -73.93099},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '4521 Ave N',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11234',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4521 Ave N', 'Brooklyn, NY 11234']},
#    'phone': '+17183388886',
#    'display_phone': '(718) 338-8886',
#    'distance': 11007.438427911506},
#   {'id': '3GMHPnrkFAcqffw3T7JSdQ',
#    'alias': 'kitchen-79-jackson-heights',
#    'name': 'Kitchen 79',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ip9F8-pOstZmt7_8T_46Jg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kitchen-79-jackson-heights?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 652,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.747551, 'longitude': -73.8868866},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '37-70 79th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37-70 79th St', 'Jackson Heights, NY 11372']},
#    'phone': '+17188036227',
#    'display_phone': '(718) 803-6227',
#    'distance': 10188.414233766554},
#   {'id': 'fRO4Fwe5uRAajMcTwLbVkA',
#    'alias': 'ayada-thai-elmhurst-2',
#    'name': 'Ayada Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qybFSiSVmsTTXx5fmX3BNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ayada-thai-elmhurst-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1267,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7433662414551,
#     'longitude': -73.8876037597656},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '7708 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7708 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17184240844',
#    'display_phone': '(718) 424-0844',
#    'distance': 9933.20870507791},
#   {'id': 'OBiBi8nimTl9GF64sPQfuQ',
#    'alias': 'mother-duck-new-york-2',
#    'name': 'Mother Duck',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6ItTncxeuIUTTsk3VxEv-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mother-duck-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72139, 'longitude': -73.98867},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '167 Orchard St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['167 Orchard St', 'New York, NY 10002']},
#    'phone': '+16467191700',
#    'display_phone': '(646) 719-1700',
#    'distance': 1828.6176285518454},
#   {'id': 'IdHZfmpp8MmQ4_KZL2qXbg',
#    'alias': 'makiinny-new-york-3',
#    'name': 'MAKIINNY',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DZJT80Vr7kUgiafyL_VbHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/makiinny-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72831, 'longitude': -73.98914},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '32 E7th St',
#     'address2': 'Front 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 E7th St', 'Front 2', 'New York, NY 10003']},
#    'phone': '+12126734610',
#    'display_phone': '(212) 673-4610',
#    'distance': 2566.784676576643},
#   {'id': 'a23bfZBVjIhV32Em4hKHAA',
#    'alias': 'the-buffs-long-island-city-4',
#    'name': 'The Buffs',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lQID-gz3kJ6Gw-Yr8rLVKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-buffs-long-island-city-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 138,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7556342, 'longitude': -73.9417121},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1313 40th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1313 40th Ave', 'Long Island City, NY 11101']},
#    'phone': '+17183612362',
#    'display_phone': '(718) 361-2362',
#    'distance': 7133.241313659094},
#   {'id': '33ry5dmopDOElU7zf1Sn2w',
#    'alias': 'lan-larb-chiang-mai-new-york-3',
#    'name': 'Lan Larb Chiang Mai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xw_0ZAe1KLelKj-gJZE6rA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lan-larb-chiang-mai-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 217,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7199936, 'longitude': -73.9985428},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '227 Centre St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['227 Centre St', 'New York, NY 10013']},
#    'phone': '+16468959264',
#    'display_phone': '(646) 895-9264',
#    'distance': 1658.7903143864842},
#   {'id': 'TUoya6mwmxr0Zpr8oZSXlg',
#    'alias': 'thip-osha-brooklyn-2',
#    'name': 'Thip Osha',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AexQnAuV99JTkUsoe7edng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thip-osha-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 88,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.712123, 'longitude': -73.941437},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '795 Grand St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['795 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17183887787',
#    'display_phone': '(718) 388-7787',
#    'distance': 4514.165073687724},
#   {'id': 'AAXX-WkDd1CW3_GgIVivvw',
#    'alias': 'chang-noi-thai-staten-island',
#    'name': 'Chang Noi Thai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cBw0Mvxhe7Ws8MzS5gAkQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chang-noi-thai-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 182,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6437040412059,
#     'longitude': -74.0776029179201},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '100 Stuyvesant Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10301',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100 Stuyvesant Pl', 'Staten Island, NY 10301']},
#    'phone': '+17184428424',
#    'display_phone': '(718) 442-8424',
#    'distance': 9823.072414687464},
#   {'id': 'fcCF0Kh_RCbv6KSVlb-Seg',
#    'alias': 'sticky-rice-new-york',
#    'name': 'Sticky Rice',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/08Od2-qdYcXQoKjirHIpkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sticky-rice-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 385,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71798, 'longitude': -73.99042},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '85 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 Orchard St', 'New York, NY 10002']},
#    'phone': '+12122748208',
#    'display_phone': '(212) 274-8208',
#    'distance': 1427.0140817149313},
#   {'id': 'QhE50zhSMnQaudpHW1jp7g',
#    'alias': 'the-tyger-new-york-2',
#    'name': 'The Tyger',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xdyC5Z_denJ-lBlR1dlqhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-tyger-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 215,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'panasian', 'title': 'Pan Asian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71888, 'longitude': -73.99951},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1 Howard St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Howard St', 'New York, NY 10013']},
#    'phone': '+16464767566',
#    'display_phone': '(646) 476-7566',
#    'distance': 1558.0214279215886}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#          Restaurant       Type Price Rating          Address        Lat  \
# 0             Pinto       Thai    $$      4  128 Montague St  40.694677
# 1              Rasa  Malaysian    $$      4      25 W 8th St  40.732765
# 2       Zabb PuTawn       Thai    $$    4.5    1584 First Av  40.774460
# 3  ACE Thai Kitchen       Thai    $$    4.5   330 Myrtle Ave  40.693150
# 4      Pinto Garden       Thai    $$      4    117 W 10th St  40.734882
#
#          Lng                                                url  \
# 0 -73.994234  https://www.yelp.com/biz/pinto-brooklyn-3?adju...
# 1 -73.997567  https://www.yelp.com/biz/rasa-new-york?adjust_...
# 2 -73.950770  https://www.yelp.com/biz/zabb-putawn-new-york-...
# 3 -73.973280  https://www.yelp.com/biz/ace-thai-kitchen-broo...
# 4 -73.999484  https://www.yelp.com/biz/pinto-garden-new-york...
#
#                        ID
# 0  RrPIJvmje1qb9iaYd6jH0g
# 1  EbX_9tqAJs4gW51gZpOB7g
# 2  HnTcWZbZJzNAYO8YseQlSQ
# 3  1sEr-BDi2LD6HH6K960pfQ
# 4  rCtsqHtOAOjZ7EUQDFRSbA

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"thai","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': 'i6H4hcjBSarJRVaieOZ2fw',
#    'alias': 'come-on-thai-cuisine-brooklyn',
#    'name': 'Come On Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cmzuDIUxDUjkrvoNPSHwJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/come-on-thai-cuisine-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.629117, 'longitude': -74.028483},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '7803 3th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7803 3th Ave', 'Brooklyn, NY 11209']},
#    'phone': '+13475606666',
#    'display_phone': '(347) 560-6666',
#    'distance': 8963.758108196802},
#   {'id': 'dyFvVNDumWZgXtV3GlK8vw',
#    'alias': 'blink-thai-brooklyn-2',
#    'name': 'Blink Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gjqo_HdU2dpdPsy4OMAYug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blink-thai-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71163, 'longitude': -73.94281},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '756 Grand St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['756 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+13472940254',
#    'display_phone': '(347) 294-0254',
#    'distance': 4392.647734184381},
#   {'id': 'R7mKCkD9ZZfeec92GW7esQ',
#    'alias': 'bangkok-2-thai-new-york',
#    'name': 'Bangkok 2 Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gW6f39kPdz5tMOpOLVZBKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bangkok-2-thai-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 205,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7352413982153,
#     'longitude': -73.9798079431057},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '349 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['349 1st Ave', 'New York, NY 10010']},
#    'phone': '+12124734480',
#    'display_phone': '(212) 473-4480',
#    'distance': 3530.954608055556},
#   {'id': 'No1PU4NbOdoaG1lSikfeNg',
#    'alias': '7-elephants-new-york',
#    'name': '7 Elephants',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RylEgFXmusdxb6sLLrxvBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/7-elephants-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.714099, 'longitude': -73.986987},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '221 East Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['221 East Broadway', 'New York, NY 10002']},
#    'phone': '+16467527940',
#    'display_phone': '(646) 752-7940',
#    'distance': 1142.856596202019},
#   {'id': 'uazg6WhYVOw3jhWCG_MDBg',
#    'alias': 'sup-thai-kitchen-fresh-meadows',
#    'name': 'Sup Thai Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hiXI9wATxdZK2SvMyi8mKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sup-thai-kitchen-fresh-meadows?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 432,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7266838, 'longitude': -73.7894371},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '178-19 Union Tpke',
#     'address2': None,
#     'address3': '',
#     'city': 'Fresh Meadows',
#     'zip_code': '11366',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['178-19 Union Tpke', 'Fresh Meadows, NY 11366']},
#    'phone': '+17184874449',
#    'display_phone': '(718) 487-4449',
#    'distance': 17436.9986852112},
#   {'id': 'TMmiudSEF1PIXb8usY5c0Q',
#    'alias': 'valla-table-new-york',
#    'name': 'Valla Table',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6f1vxFPAwoguT95ljxkabw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/valla-table-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 110,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7619, 'longitude': -73.994186},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '641 10th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['641 10th Ave', 'New York, NY 10036']},
#    'phone': '+12122454601',
#    'display_phone': '(212) 245-4601',
#    'distance': 6284.017723782243},
#   {'id': 'yA29ur97O7B6kYr1g5IoAw',
#    'alias': 'aroy-dee-thai-kitchen-new-york',
#    'name': 'Aroy Dee Thai Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Fq0bdsQNv_14TzwgNo6E9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aroy-dee-thai-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 424,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7096786, 'longitude': -74.0089569},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '20 John St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['20 John St', 'New York, NY 10038']},
#    'phone': '+12125289922',
#    'display_phone': '(212) 528-9922',
#    'distance': 1315.8610270227744},
#   {'id': 'yCJHIM-PWl54K53ACOpoNg',
#    'alias': 'hug-esan-elmhurst',
#    'name': 'Hug Esan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2OCFHxcmexNCVO2vcud7Rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hug-esan-elmhurst?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 204,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7436465, 'longitude': -73.8873753},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '77-16 Woodside Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['77-16 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+19293280392',
#    'display_phone': '(929) 328-0392',
#    'distance': 9961.058044336613},
#   {'id': 'rvI-gvqsWy_HmunwUsjmGg',
#    'alias': 'bangkok-bar-brooklyn-2',
#    'name': 'Bangkok BAR',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DDic7vT2iGRqZcmE6JITJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bangkok-bar-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.657456, 'longitude': -74.007112},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '238 36th St',
#     'address2': 'Bldg 2',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11232',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['238 36th St', 'Bldg 2', 'Brooklyn, NY 11232']},
#    'phone': '+19177894447',
#    'display_phone': '(917) 789-4447',
#    'distance': 5444.4934877680025},
#   {'id': 'kI7XN2V8zi4aMypgitFg4w',
#    'alias': 'prim-thai-restaurant-new-york',
#    'name': 'Prim Thai restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/O-_jWMKNXKXFB7ZfvgtACA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prim-thai-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.723251, 'longitude': -73.987895},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '78 E 1st St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['78 E 1st St', 'New York, NY 10009']},
#    'phone': '+16467999642',
#    'display_phone': '(646) 799-9642',
#    'distance': 2050.516425499501},
#   {'id': 'jKDXlyPG-2rmcp9Ej6jPLA',
#    'alias': 'living-thai-new-york-2',
#    'name': 'Living Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HmgdoHv-mrBFJUG5M1H1oQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/living-thai-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 120,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8001, 'longitude': -73.96574},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '931 Amsterdam Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['931 Amsterdam Ave', 'New York, NY 10025']},
#    'phone': '+12122222600',
#    'display_phone': '(212) 222-2600',
#    'distance': 10803.0785874646},
#   {'id': 'B0e6kXT0doU-n6EvMVGzQQ',
#    'alias': 'thai-me-brooklyn',
#    'name': 'Thai Me',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RWjHOwM54hBnQXV7G_ot-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-me-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 133,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.697306, 'longitude': -73.936091},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '918 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['918 Broadway', 'Brooklyn, NY 11206']},
#    'phone': '+17189755190',
#    'display_phone': '(718) 975-5190',
#    'distance': 4989.147049892824},
#   {'id': '9FjGW7u1iTyFUDpJt-Ql9Q',
#    'alias': 'tue-thai-restaurant-new-york',
#    'name': 'Tue Thai Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rcApTiFHZ74b-7kd8bzwJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tue-thai-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 360,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73387, 'longitude': -73.9997999},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3 Greenwich Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3 Greenwich Ave', 'New York, NY 10014']},
#    'phone': '+12129299888',
#    'display_phone': '(212) 929-9888',
#    'distance': 3197.39557930376},
#   {'id': 'B9UfgHgm5-hOErK8-54EsA',
#    'alias': 'very-thai-new-york-2',
#    'name': 'Very Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nxMsygHo8lpC4GdsJZrreQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/very-thai-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 98,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72784, 'longitude': -73.97933},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '186 Ave B',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['186 Ave B', 'New York, NY 10009']},
#    'phone': '+12122287950',
#    'display_phone': '(212) 228-7950',
#    'distance': 2790.689645520863},
#   {'id': 'CDa0GJZDMPcjvhbx7RbG5Q',
#    'alias': 'senn-thai-comfort-food-new-york',
#    'name': 'Senn Thai Comfort Food',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4Nhm9Buj0hcYnsV8cWXDNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/senn-thai-comfort-food-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 298,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7849945637664,
#     'longitude': -73.9770103128512},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '452 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['452 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12125017755',
#    'display_phone': '(212) 501-7755',
#    'distance': 8964.53840211706},
#   {'id': 'coQAQmIKG9dBPA6-RHqJag',
#    'alias': 'charms-new-york',
#    'name': "CHARM'S",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JKtYOBHMD-Vg_eqMMmIwFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/charms-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 143,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74346, 'longitude': -73.99947},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '200 8th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 8th Ave', 'New York, NY 10011']},
#    'phone': '+16465908994',
#    'display_phone': '(646) 590-8994',
#    'distance': 4251.392414455583},
#   {'id': 'BF6pY829iPBERt15CG1g3w',
#    'alias': 'at-nine-restaurant-and-bar-new-york',
#    'name': 'At Nine Restaurant & Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KuN4OJKZ2tlz-kQpw-G1uA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/at-nine-restaurant-and-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 517,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.758697, 'longitude': -73.992064},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '592 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['592 9th Ave', 'New York, NY 10036']},
#    'phone': '+12122654499',
#    'display_phone': '(212) 265-4499',
#    'distance': 5924.339153813895},
#   {'id': 'pREotiEdCIV1GKSp_pLgNA',
#    'alias': 'somtum-der-redhook-new-york',
#    'name': 'Somtum Der Redhook',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7mfP_Ys2VkbVf-7wrIyhWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/somtum-der-redhook-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67707, 'longitude': -74.01343},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'location': {'address1': '380 Van Brunt St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['380 Van Brunt St', 'New York, NY 11231']},
#    'phone': '+13472277889',
#    'display_phone': '(347) 227-7889',
#    'distance': 3544.596057643579},
#   {'id': 'RnQjRZ9MJrBN9SKiIv3i-A',
#    'alias': 'amarin-cafe-brooklyn',
#    'name': 'Amarin Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iKb1LwZdLRxn2UX6X1Sp_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amarin-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 293,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72345, 'longitude': -73.95087},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '617 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['617 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183492788',
#    'display_phone': '(718) 349-2788',
#    'distance': 4170.821017931773},
#   {'id': 'Tgz0bhjz-api1CGS_ANFoQ',
#    'alias': 'skyice-9th-st-brooklyn',
#    'name': 'SkyIce 9th St.',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3XDQ9XrHyMxbAfXs2YAGUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/skyice-9th-st-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.669364, 'longitude': -73.985873},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '437 5th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['437 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+13478895532',
#    'display_phone': '(347) 889-5532',
#    'distance': 4074.3378345645665},
#   {'id': 'hSiTqxKKgvQSI5x5VdMjoQ',
#    'alias': 'top-thai-brooklyn-brooklyn',
#    'name': 'Top Thai - Brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XDqz5GxZC5X-msp2l4Cx3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/top-thai-brooklyn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 320,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'halal', 'title': 'Halal'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.62325, 'longitude': -74.02838},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '8510 4th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8510 4th Ave', 'Brooklyn, NY 11209']},
#    'phone': '+17183335811',
#    'display_phone': '(718) 333-5811',
#    'distance': 9580.898372074198},
#   {'id': '-5npn9NRmOun7VUVLZpjyw',
#    'alias': 'eat-gai-new-york-3',
#    'name': 'Eat Gai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uaydDANPkgjsA8VWHqGz4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eat-gai-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'chickenshop', 'title': 'Chicken Shop'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7180351, 'longitude': -73.9882738},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '88 Essex St',
#     'address2': 'Booth 46',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['88 Essex St', 'Booth 46', 'New York, NY 10002']},
#    'phone': '+19172658631',
#    'display_phone': '(917) 265-8631',
#    'distance': 1515.3696218243854},
#   {'id': 'B9_TgZa8rgW5oZOtXZUMCw',
#    'alias': 'laut-singapura-new-york',
#    'name': 'Laut Singapura',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Rv8wEkVyZGGS-WFtTjt7hQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laut-singapura-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 219,
#    'categories': [{'alias': 'singaporean', 'title': 'Singaporean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73895, 'longitude': -73.98896},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '31 E 20th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31 E 20th St', 'New York, NY 10003']},
#    'phone': '+16464299986',
#    'display_phone': '(646) 429-9986',
#    'distance': 3756.5340970208595},
#   {'id': '0fjab0vzFgIQ-FKzjFR7JQ',
#    'alias': 'dannee-thai-brooklyn',
#    'name': 'Dannee Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/s3ZBXr6jvtzo0--HV9saaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dannee-thai-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 163,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.690601348877,
#     'longitude': -73.9600830078125},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '433 Dekalb Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['433 Dekalb Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17186224422',
#    'display_phone': '(718) 622-4422',
#    'distance': 3325.5230801681637},
#   {'id': '7Qvh0oFRsoqrO9qNlcMKXQ',
#    'alias': 'saigon-shack-new-york',
#    'name': 'Saigon Shack',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TlIH3rCYMec53AszcOtMXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saigon-shack-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2473,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72969, 'longitude': -74.000629},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '114 Macdougal St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['114 Macdougal St', 'New York, NY 10012']},
#    'phone': '+12122280588',
#    'display_phone': '(212) 228-0588',
#    'distance': 2748.304724711492},
#   {'id': 'CpY77cDN1KS5EdiXMmWovw',
#    'alias': 'house-of-thai-long-island-city-4',
#    'name': 'House of Thai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uZJDECEq7QBfrSIfyrPsRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/house-of-thai-long-island-city-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 318,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7535257695712,
#     'longitude': -73.9377629319284},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2501 40th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2501 40th Ave', 'Long Island City, NY 11101']},
#    'phone': '+19295220247',
#    'display_phone': '(929) 522-0247',
#    'distance': 7160.562172041353},
#   {'id': 'UkA3V8itzKuBGZ9c7y989w',
#    'alias': 'jaiya-new-york-3',
#    'name': 'Jaiya',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Lz4s7NX48RsJhhkLP38LOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jaiya-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 835,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.742179, 'longitude': -73.980915},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '396 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['396 3rd Ave', 'New York, NY 10016']},
#    'phone': '+12128891330',
#    'display_phone': '(212) 889-1330',
#    'distance': 4237.372816972815},
#   {'id': 'T4xmuPYBmMhF48bfi9rkfA',
#    'alias': 'pro-thai-new-york',
#    'name': 'Pro Thai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rNTbd8Xi0keJjjCjc7Ld3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pro-thai-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 212,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78888, 'longitude': -73.94857},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1575 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1575 Lexington Ave', 'New York, NY 10029']},
#    'phone': '+19174751494',
#    'display_phone': '(917) 475-1494',
#    'distance': 10043.518116157922},
#   {'id': 'p2sAfaFyfFj9nYPyqcmQdw',
#    'alias': 'thai-sidewalk-brooklyn-5',
#    'name': 'Thai Sidewalk',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8VY5opp0KuYAekshjrEl1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-sidewalk-brooklyn-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'streetvendors', 'title': 'Street Vendors'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7024794, 'longitude': -73.9885649},
#    'transactions': [],
#    'location': {'address1': 'Adams St And Front St',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Adams St And Front St', 'Brooklyn, NY 11201']},
#    'phone': '+16466418333',
#    'display_phone': '(646) 641-8333',
#    'distance': 583.9836845783237},
#   {'id': 'e1jwvzY8hU642HSBZZATcw',
#    'alias': 'hub-thai-new-york',
#    'name': 'Hub Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ltFVkuNe3M6mjXQojeXGDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hub-thai-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 130,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7238123, 'longitude': -73.9847935},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '50 Avenue A',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['50 Avenue A', 'New York, NY 10009']},
#    'phone': '+12122288221',
#    'display_phone': '(212) 228-8221',
#    'distance': 2193.6949519588675},
#   {'id': 'er4E7VCjDo0xE_IPu5o6Ig',
#    'alias': 'pongsri-thai-restaurant-new-york-2',
#    'name': 'Pongsri Thai Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/INs_uhaBr0uw035V7fhKvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pongsri-thai-restaurant-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 519,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.76071, 'longitude': -73.98652},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '244 W 48th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['244 W 48th St', 'New York, NY 10036']},
#    'phone': '+12125823392',
#    'display_phone': '(212) 582-3392',
#    'distance': 6181.9097752923735},
#   {'id': '1Fe4lCiMPNVhoEyjg92frA',
#    'alias': 'kati-thai-cuisine-new-york',
#    'name': 'Kati Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oV6pDm2DmIeAdURA4qyOjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kati-thai-cuisine-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 247,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7318077087402, 'longitude': -73.98291015625},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '347 E 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['347 E 14th St', 'New York, NY 10003']},
#    'phone': '+12125332046',
#    'display_phone': '(212) 533-2046',
#    'distance': 3077.276864107023},
#   {'id': 'T8WfkzuVi96qCpj1tWjlxw',
#    'alias': 'spice-new-york',
#    'name': 'Spice',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ju9yJ3NV43yh4sjJsKeAGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spice-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1556,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7345, 'longitude': -73.9919},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '39 E 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39 E 13th St', 'New York, NY 10003']},
#    'phone': '+12129823758',
#    'display_phone': '(212) 982-3758',
#    'distance': 3241.3350724879742},
#   {'id': 'l3aVYfTWVINXaNGxlMz0bQ',
#    'alias': 'soho-thai-new-york-8',
#    'name': 'Soho Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qkENi3KYQGSZHAuXc-x-xQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soho-thai-new-york-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 179,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.720078, 'longitude': -73.999641},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '141 Grand St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['141 Grand St', 'New York, NY 10013']},
#    'phone': '+12129668916',
#    'display_phone': '(212) 966-8916',
#    'distance': 1690.3559440893941},
#   {'id': '0nvJPFqv5VD-Bf2WtzD0rA',
#    'alias': 'one-more-charm-brooklyn',
#    'name': 'One More Charm',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cFb2nCnZYj2fNzigOFsi1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/one-more-charm-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.669892, 'longitude': -73.979454},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '236 7th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['236 7th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+19292502052',
#    'display_phone': '(929) 250-2052',
#    'distance': 4147.763847425557},
#   {'id': 'A_GbgtUSyGWpihHZOqMdwQ',
#    'alias': 'little-basil-new-york-5',
#    'name': 'Little Basil',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ojn2dqxqJlXoXtV3p2MsEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-basil-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 521,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.741014, 'longitude': -73.982259},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '153 E 26th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['153 E 26th St', 'New York, NY 10010']},
#    'phone': '+12126891444',
#    'display_phone': '(212) 689-1444',
#    'distance': 4083.052133823934},
#   {'id': 'Kyx9QFPJUzlC7dmM8SE1bw',
#    'alias': 'jaiya-new-york-4',
#    'name': 'Jaiya',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YSbur2MOXim9Q9FpvH30XQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jaiya-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 325,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.774553, 'longitude': -73.954563},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1553 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1553 2nd Ave', 'New York, NY 10075']},
#    'phone': '+12127178877',
#    'display_phone': '(212) 717-8877',
#    'distance': 8381.838354302066},
#   {'id': 'jfnDwWBGK4JoWE5jbeKxSw',
#    'alias': 'chu-ros-thai-new-york',
#    'name': 'Chu-Ros Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CPuUhG3gTTDGgjCVjcD1iQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chu-ros-thai-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 99,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78922, 'longitude': -73.94873},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1590 Lexington Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1590 Lexington Ave', 'New York, NY 10029']},
#    'phone': '+19172658432',
#    'display_phone': '(917) 265-8432',
#    'distance': 10082.249947035149},
#   {'id': 'SSDOkx5enfRH3nsniS_2jA',
#    'alias': '5ive-spice-brooklyn-3',
#    'name': '5ive Spice',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VFQdUvDvYj36stc4PvfyKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/5ive-spice-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 753,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.681442, 'longitude': -73.977241},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '52 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['52 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17188573483',
#    'display_phone': '(718) 857-3483',
#    'distance': 3031.5630577712896},
#   {'id': 'dl4QvM8WAzATC7ChNIQh3g',
#    'alias': 'thank-you-come-again-new-york',
#    'name': 'Thank You Come Again',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0C_OuCUTSOs3juBTuaEE_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thank-you-come-again-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75878, 'longitude': -73.97048},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '601 Lexington Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['601 Lexington Ave', 'New York, NY 10022']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6245.802876253213},
#   {'id': '9VyMJICKGbC7Y5Ssq-Xk7w',
#    'alias': 'the-sabieng-thai-new-york',
#    'name': 'The Sabieng Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BXnO0iQq97hN6FZO8u3Ahw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-sabieng-thai-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 107,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72554, 'longitude': -73.98722},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '71 1st Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['71 1st Ave', 'New York, NY 10003']},
#    'phone': '+12122532742',
#    'display_phone': '(212) 253-2742',
#    'distance': 2312.4428829965273},
#   {'id': 'ZGKdgFAGOL6NOPXPrBkhzA',
#    'alias': 'myrtle-thai-brooklyn',
#    'name': 'Myrtle Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TiD-m_A1hy50w9xCx8XZxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/myrtle-thai-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 181,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.69308, 'longitude': -73.96814},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '438 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['438 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17184221142',
#    'display_phone': '(718) 422-1142',
#    'distance': 2606.4956831499812},
#   {'id': 'iPaule2uCieebZk0rVFG1w',
#    'alias': 'lum-dee-thai-cuisine-brooklyn',
#    'name': 'Lum Dee Thai Cuisine',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zKu0pzsh3v71VbB0WnVfMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lum-dee-thai-cuisine-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68471, 'longitude': -74.00301},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '218 Columbia St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['218 Columbia St', 'Brooklyn, NY 11231']},
#    'phone': '+17186432737',
#    'display_phone': '(718) 643-2737',
#    'distance': 2421.938418550715},
#   {'id': '1E7lCNaRAM1Da0vkt5rcvw',
#    'alias': 'thai-mission-maspeth',
#    'name': 'Thai Mission',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aHW0GXkqdtA3jOMX6NenRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-mission-maspeth?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72779, 'longitude': -73.89279},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '70-11 Grand Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Maspeth',
#     'zip_code': '11378',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70-11 Grand Ave', 'Maspeth, NY 11378']},
#    'phone': '+19293280328',
#    'display_phone': '(929) 328-0328',
#    'distance': 8908.357132786918},
#   {'id': 'ZQHZAvw1jvNznbo1wFb_4w',
#    'alias': 'bay-thai-brooklyn-4',
#    'name': 'Bay Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KNIE3kWO8r2ON-lHQEBXYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bay-thai-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 151,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.63688, 'longitude': -74.02526},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '6735 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11220',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6735 3rd Ave', 'Brooklyn, NY 11220']},
#    'phone': '+16462605964',
#    'display_phone': '(646) 260-5964',
#    'distance': 8057.177592598429},
#   {'id': '414qtc1lNAI-HaJ-Gw9puA',
#    'alias': 'galanga-new-york',
#    'name': 'Galanga',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zFQP3-S9JUwC8fKVynz6eQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/galanga-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 508,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7316, 'longitude': -74.00049},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '149 W 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['149 W 4th St', 'New York, NY 10012']},
#    'phone': '+12122284267',
#    'display_phone': '(212) 228-4267',
#    'distance': 2959.073100214115},
#   {'id': 'v5YA6gFdj1jwTpz0Kjpjqw',
#    'alias': 'krua-and-koo-cha-new-york-3',
#    'name': 'Krua & Koo Cha',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0DgDx0B1qmShNhy4ChChuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/krua-and-koo-cha-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 80,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7780368755686,
#     'longitude': -73.9455220142999},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1764 1AVE',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1764 1AVE', 'New York, NY 10128']},
#    'phone': '+16467915999',
#    'display_phone': '(646) 791-5999',
#    'distance': 9244.293366292753},
#   {'id': 'OuHB-EdeXmQ26QDzAsDxyw',
#    'alias': 'thai-on-clinton-brooklyn-4',
#    'name': 'Thai on Clinton',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Lei0cCX25s4gZ6I3JID2gg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-on-clinton-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.693925372884756,
#     'longitude': -73.99241130799055},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '168 Montague St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['168 Montague St', 'Brooklyn, NY 11201']},
#    'phone': '+19177026055',
#    'display_phone': '(917) 702-6055',
#    'distance': 1290.6947643054452},
#   {'id': 'QfcobhW--x1cEbQjOWrURg',
#    'alias': 'pattanian-thai-ridgewood',
#    'name': 'Pattanian Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rnjtLY6e8i3gLGqEUVinJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pattanian-thai-ridgewood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71012, 'longitude': -73.89958},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '6402 Fresh Pond Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6402 Fresh Pond Rd', 'Ridgewood, NY 11385']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8002.394350417572},
#   {'id': 'B_uLqJNcrKc6PwA6A3s_Wg',
#    'alias': 'eim-a-roy-thai-kitchen-new-york',
#    'name': 'Eim A-Roy Thai Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mmYltPI5Ifgchn-_nUFewg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eim-a-roy-thai-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.76631, 'longitude': -73.78936},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '33-47 Francis Lewis Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11358',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-47 Francis Lewis Blvd', 'New York, NY 11358']},
#    'phone': '+17182696821',
#    'display_phone': '(718) 269-6821',
#    'distance': 18543.152205845345}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#              Restaurant  Type Price Rating            Address        Lat  \
# 0  Come On Thai Cuisine  Thai    $$      4       7803 3th Ave  40.629117
# 1            Blink Thai  Thai    $$    4.5       756 Grand St  40.711630
# 2        Bangkok 2 Thai  Thai    $$      4        349 1st Ave  40.735241
# 3           7 Elephants  Thai               221 East Broadway  40.714099
# 4      Sup Thai Kitchen  Thai    $$    4.5  178-19 Union Tpke  40.726684
#
#          Lng                                                url  \
# 0 -74.028483  https://www.yelp.com/biz/come-on-thai-cuisine-...
# 1 -73.942810  https://www.yelp.com/biz/blink-thai-brooklyn-2...
# 2 -73.979808  https://www.yelp.com/biz/bangkok-2-thai-new-yo...
# 3 -73.986987
# 4 -73.789437  https://www.yelp.com/biz/sup-thai-kitchen-fres...
#
#                        ID
# 0  i6H4hcjBSarJRVaieOZ2fw
# 1  dyFvVNDumWZgXtV3GlK8vw
# 2  R7mKCkD9ZZfeec92GW7esQ
# 3
# 4  uazg6WhYVOw3jhWCG_MDBg

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"thai","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [{'id': 'yQiII2hHgV5aEMtIA2VG0Q',
#    'alias': 'chai-thai-kitchen-new-york-10',
#    'name': 'Chai Thai Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bZV16Y0e-ehVkCf2NZUxOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chai-thai-kitchen-new-york-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 583,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.76541, 'longitude': -73.98352},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '930 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['930 8th Ave', 'New York, NY 10019']},
#    'phone': '+12127078778',
#    'display_phone': '(212) 707-8778',
#    'distance': 6730.6797647178955},
#   {'id': '_Ge2eC89Z-jlaDDWglfT8g',
#    'alias': 'pa-pa-thai-cuisine-new-york',
#    'name': 'Pa Pa Thai Cuisine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3ADgOBYgXwM7w8PKQ6S4nw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pa-pa-thai-cuisine-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 240,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7593778206059,
#     'longitude': -73.9624154842934},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1069 1st Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1069 1st Ave', 'New York, NY 10022']},
#    'phone': '+12127529277',
#    'display_phone': '(212) 752-9277',
#    'distance': 6571.103078001443},
#   {'id': 'EjuI8hyZO4jREWj3BTh8gw',
#    'alias': 'mr-khao-man-gai-long-island-city',
#    'name': 'Mr Khao Man Gai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BzQk0kc-ZcAk-uNCpYdonQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-khao-man-gai-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'hainan', 'title': 'Hainan'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74606, 'longitude': -73.94842},
#    'transactions': [],
#    'location': {'address1': None,
#     'address2': None,
#     'address3': None,
#     'city': 'Long Island City ',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Long Island City , NY 11101']},
#    'phone': '+13472606438',
#    'display_phone': '(347) 260-6438',
#    'distance': 6180.476321499615},
#   {'id': 'toykv8K0yg8qtvZSXRQ5bg',
#    'alias': 'pochana-thai-kitchen-astoria-2',
#    'name': 'Pochana Thai Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5hfYhHZOsD9SRICjUaFpYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pochana-thai-kitchen-astoria-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 215,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.765733, 'longitude': -73.91932},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '33-16 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-16 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17189569559',
#    'display_phone': '(718) 956-9559',
#    'distance': 9211.041350181566},
#   {'id': 'wT-NWAbuXP4zqACpAtE-AA',
#    'alias': 'imm-thai-clark',
#    'name': 'Imm Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/emQH59GmFEitZG1Iu29jjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/imm-thai-clark?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 56,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.63171963708329,
#     'longitude': -74.3136770983697},
#    'transactions': ['delivery'],
#    'location': {'address1': '301 Central Ave',
#     'address2': 'Ste 6',
#     'address3': '',
#     'city': 'Clark',
#     'zip_code': '07066',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['301 Central Ave', 'Ste 6', 'Clark, NJ 07066']},
#    'phone': '+18486667097',
#    'display_phone': '(848) 666-7097',
#    'distance': 28156.756932183984},
#   {'id': 'n61FbfvTddHBXF5WKWjF4g',
#    'alias': 'pad-thai-noodle-lounge-new-york-2',
#    'name': 'Pad Thai Noodle Lounge',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i0badHl_FlFpztJ3zmV6mQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pad-thai-noodle-lounge-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 332,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7408371121571,
#     'longitude': -74.0014776911789},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '114 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['114 8th Ave', 'New York, NY 10011']},
#    'phone': '+12126916226',
#    'display_phone': '(212) 691-6226',
#    'distance': 3981.7339194093383},
#   {'id': 'ET4xGd-SQ6gs9lce4xVpQg',
#    'alias': 'tum-thai-cuisine-rockville-centre',
#    'name': 'Tum Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0keHJi1yLq97gnDyCeM7UQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tum-thai-cuisine-rockville-centre?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 687,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.65591, 'longitude': -73.64574},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '274 Merrick Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Rockville Centre',
#     'zip_code': '11570',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['274 Merrick Rd', 'Rockville Centre, NY 11570']},
#    'phone': '+15165435078',
#    'display_phone': '(516) 543-5078',
#    'distance': 29913.662003704143},
#   {'id': '23NSOmpzzrJTfWmYk8Lp4A',
#    'alias': 'lovely-day-new-york',
#    'name': 'Lovely Day',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PhkxvOZQSmGklqdudZyFrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lovely-day-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 364,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'irish', 'title': 'Irish'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.721774, 'longitude': -73.994275},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '196 Elizabeth St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['196 Elizabeth St', 'New York, NY 10012']},
#    'phone': '+12129253310',
#    'display_phone': '(212) 925-3310',
#    'distance': 1815.715665146426},
#   {'id': 'g4EXxoV0z_TnyWF8h9xMKQ',
#    'alias': 'may-kaidee-east-broadway-new-york',
#    'name': 'May Kaidee East Broadway',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4quv6Vy4uosA4IUFkI4JNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/may-kaidee-east-broadway-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7140637, 'longitude': -73.987464979291},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '215 E Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['215 E Broadway', 'New York, NY 10002']},
#    'phone': '+19174437885',
#    'display_phone': '(917) 443-7885',
#    'distance': 1117.9081711870808},
#   {'id': '7CdpBlw4NLaOLzfFL9IEUg',
#    'alias': 'uncle-boons-sister-new-york-3',
#    'name': 'Uncle Boons Sister',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SJFiM2W_-p3eodJx315B1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uncle-boons-sister-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 158,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72147, 'longitude': -73.99565},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '203 Mott St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['203 Mott St', 'New York, NY 10012']},
#    'phone': '+16468509480',
#    'display_phone': '(646) 850-9480',
#    'distance': 1781.565867673711},
#   {'id': 'pvxX-nvg3o-eZDlvrtYhQQ',
#    'alias': 'spice-thai-new-york-4',
#    'name': 'Spice Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mAb2mhEG8lgy8wh3IMZxIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spice-thai-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.771212, 'longitude': -73.953786},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1479 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1479 1st Ave', 'New York, NY 10075']},
#    'phone': '+12127446374',
#    'display_phone': '(212) 744-6374',
#    'distance': 8072.448984972199},
#   {'id': 'LQ8ITaZIbaiQ8pHPOx5i6w',
#    'alias': 'skyice-brooklyn-2',
#    'name': 'SkyIce',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/L_crEBQnh8LVwMo19Ktisw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/skyice-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 768,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6806411743164,
#     'longitude': -73.9772872924805},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '63 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17182300910',
#    'display_phone': '(718) 230-0910',
#    'distance': 3108.4493439489506},
#   {'id': 'ri2YWZ2jMuxauAUA__4uvw',
#    'alias': 'sita-thai-new-york',
#    'name': 'SITA THAI',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/olgmyNx9JgXikO3rTcSEGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sita-thai-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.82889, 'longitude': -73.94899},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '3609 Broadway Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10031',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3609 Broadway Ave', 'New York, NY 10031']},
#    'phone': '+16469015623',
#    'display_phone': '(646) 901-5623',
#    'distance': 14245.970032456455},
#   {'id': 'gJMMX5Ip4AsulbzxMZgdYg',
#    'alias': 'thai-bird-new-york',
#    'name': 'Thai Bird',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/c8nc9GOU8k8ToLbJgXiFig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-bird-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7395853, 'longitude': -73.9469816},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2330 Borden Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New york',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2330 Borden Ave', 'New york, NY 11101']},
#    'phone': '+18567456041',
#    'display_phone': '(856) 745-6041',
#    'distance': 5505.269076794453},
#   {'id': 'AekKkXTaCXlYp95KrxlesA',
#    'alias': 'little-tiffin-brooklyn',
#    'name': 'Little Tiffin',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/f5Ls4Hck2m3GQclNtlwWPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-tiffin-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.732257609566,
#     'longitude': -73.9543802663684},
#    'transactions': ['delivery'],
#    'location': {'address1': '970 Manhattan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['970 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+19177450336',
#    'display_phone': '(917) 745-0336',
#    'distance': 4494.849294950583},
#   {'id': 'RmQOUUkwHDhuuh9Y6XzLsQ',
#    'alias': 'hungry-brooklyn',
#    'name': 'Hungry?',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KHy5jk8JiyvKq2Ep2Syc3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hungry-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 128,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7253533, 'longitude': -73.952406},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '77 Norman Ave',
#     'address2': '',
#     'address3': 'Store 1',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['77 Norman Ave', 'Store 1', 'Brooklyn, NY 11222']},
#    'phone': '+13479873893',
#    'display_phone': '(347) 987-3893',
#    'distance': 4170.64067942364},
#   {'id': '1ctLdRJjP9m5QdL7ruYAzA',
#    'alias': 'herbs-thai-bistro-new-york-2',
#    'name': 'Herbs Thai Bistro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ykHUSxlVppGxy5AZu2rJLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/herbs-thai-bistro-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 198,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.75193, 'longitude': -73.97099},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '251 E 45th St',
#     'address2': 'Ste 1',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['251 E 45th St', 'Ste 1', 'New York, NY 10017']},
#    'phone': '+12128089388',
#    'display_phone': '(212) 808-9388',
#    'distance': 5531.0397667096395},
#   {'id': '4mzogOLOVDPBDVTO4cz9fA',
#    'alias': 'roi-siam-union-city',
#    'name': 'Roi Siam',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/we_G3xswz0N-MMFT1gLSUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roi-siam-union-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 138,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76397, 'longitude': -74.03454},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1814 Bergenline Ave',
#     'address2': 'Ste 1',
#     'address3': None,
#     'city': 'Union City',
#     'zip_code': '07087',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1814 Bergenline Ave',
#      'Ste 1',
#      'Union City, NJ 07087']},
#    'phone': '+12012230222',
#    'display_phone': '(201) 223-0222',
#    'distance': 7344.948608157555},
#   {'id': 'ybPMdh4XiTTwLWOMUXdwlw',
#    'alias': 'thai-101-bistro-brooklyn-2',
#    'name': 'Thai 101 Bistro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/l54hBrGSHNlffEZ2lRC9Vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-101-bistro-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 199,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.6930313110352,
#     'longitude': -73.9674987792969},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '448 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['448 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17188558518',
#    'display_phone': '(718) 855-8518',
#    'distance': 2644.159795336851},
#   {'id': 'kXuubLd6s3GidpqU3psPdw',
#    'alias': 'chao-thai-elmhurst-3',
#    'name': 'Chao Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Sq1y11AFR9zp81X0aH9vKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chao-thai-elmhurst-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 384,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7414656, 'longitude': -73.8801273},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '8503 Whitney Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8503 Whitney Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17184244999',
#    'display_phone': '(718) 424-4999',
#    'distance': 10420.63016928679},
#   {'id': 'Ri0hq80RV6yrPDHmW4Gu3g',
#    'alias': 'spice-thai-brooklyn-3',
#    'name': 'Spice Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8-jyD2DfuSLkGxWW3u6ABA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spice-thai-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.710786, 'longitude': -73.963886},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '394 Bedford Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['394 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17185763571',
#    'display_phone': '(718) 576-3571',
#    'distance': 2632.1915385812804},
#   {'id': '1ubEg-rrSE8IWXl6lJzIGw',
#    'alias': 'nur-thai-rego-park',
#    'name': 'Nur Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wKL4Mnmig42Youp-9eYUIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nur-thai-rego-park?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 591,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7235516378586,
#     'longitude': -73.868817789544},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '63-32 Woodhaven Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63-32 Woodhaven Blvd', 'Rego Park, NY 11374']},
#    'phone': '+17182556141',
#    'display_phone': '(718) 255-6141',
#    'distance': 10765.301476095121},
#   {'id': 'eQzQo6XWLHstH5A2IpwXPQ',
#    'alias': 'national-brooklyn-2',
#    'name': 'National',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/opK9lbw9eF0Q-EjpLYgLPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/national-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 426,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6871800754375,
#     'longitude': -73.9763717601786},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '723 Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['723 Fulton St', 'Brooklyn, NY 11217']},
#    'phone': '+17185223510',
#    'display_phone': '(718) 522-3510',
#    'distance': 2531.3026230988335},
#   {'id': 'XNkC1vJmLOI8NRR3Jl_vyQ',
#    'alias': 'amy-thai-bistro-brooklyn',
#    'name': 'Amy Thai Bistro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iImj0hp6AoEW5cL4Vm68aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amy-thai-bistro-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 182,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.66055, 'longitude': -73.9604851},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '545 Flatbush Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11225',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['545 Flatbush Ave', 'Brooklyn, NY 11225']},
#    'phone': '+17184621555',
#    'display_phone': '(718) 462-1555',
#    'distance': 5737.696421812777},
#   {'id': 'wyjtGsW5NeVDknGQWnIPAQ',
#    'alias': 'wagamama-midtown-new-york',
#    'name': 'wagamama - midtown',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xCufQewC6rJ5iFqGZXiS8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wagamama-midtown-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 105,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7629, 'longitude': -73.9781574},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '100 W 55th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100 W 55th St', 'New York, NY 10019']},
#    'phone': '+13329006111',
#    'display_phone': '(332) 900-6111',
#    'distance': 6530.759592323944},
#   {'id': '2-z6dRAkKupCyz1LF251pQ',
#    'alias': 'jintana-thai-farmhouse-brooklyn',
#    'name': 'Jintana Thai Farmhouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_iuRtbTXp7vsOI2f_S_sbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jintana-thai-farmhouse-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 163,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6665799, 'longitude': -73.98211},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '344 7th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['344 7th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187881922',
#    'display_phone': '(718) 788-1922',
#    'distance': 4441.998491284249},
#   {'id': 'tVB11pOiDhPWlt_o6ylMNg',
#    'alias': 'enthaice-thai-kitchen-astoria',
#    'name': 'Enthaice Thai Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/poiYY93PvnCGFXQAEvO-Ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/enthaice-thai-kitchen-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 714,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7630889337809,
#     'longitude': -73.9213237166405},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '33-20 31st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-20 31st Ave', 'Astoria, NY 11106']},
#    'phone': '+17189321111',
#    'display_phone': '(718) 932-1111',
#    'distance': 8881.720321020517},
#   {'id': 'Q99VEcN9r1Qqmvnm5I03tw',
#    'alias': 'wau-new-york',
#    'name': 'WAU',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_U-UylAnJO6NxyrQjeJ_Eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wau-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'indonesian', 'title': 'Indonesian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78448, 'longitude': -73.97776},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '434 Amsterdam Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['434 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+19172615926',
#    'display_phone': '(917) 261-5926',
#    'distance': 8899.318662452877},
#   {'id': '_n7CjKNQTUhEIabK-VVZfw',
#    'alias': 'thai-tai-eatery-brooklyn',
#    'name': 'Thai Tai Eatery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ah4_CLwLT5UXt1RXk89nbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-tai-eatery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69234040687198,
#     'longitude': -73.98673029999999},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '55 Willoughby St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Willoughby St', 'Brooklyn, NY 11201']},
#    'phone': '+17185966626',
#    'display_phone': '(718) 596-6626',
#    'distance': 1590.525980404514},
#   {'id': 'JzD9nfJWHwnG-2Wk87muHg',
#    'alias': 'qi-new-york-3',
#    'name': 'Qi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-u57xPWy0QnHp-PQQs2-ug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/qi-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1229,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.762, 'longitude': -73.98961},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '698 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['698 9th Ave', 'New York, NY 10036']},
#    'phone': '+12122478991',
#    'display_phone': '(212) 247-8991',
#    'distance': 6301.733024775894},
#   {'id': 'f4ZveYR7fuBp_9klL8OgYQ',
#    'alias': 'little-thai-kitchen-new-york',
#    'name': 'Little Thai Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0VBhYbyasD4KDUwdTKq2tA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-thai-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 375,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.757359, 'longitude': -73.968025},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '231 E 53rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 E 53rd St', 'New York, NY 10022']},
#    'phone': '+12126445353',
#    'display_phone': '(212) 644-5353',
#    'distance': 6182.3751101712705},
#   {'id': 'sljnE3uoRUmM7aW5f1I3Ug',
#    'alias': 'one-more-thai-new-york',
#    'name': 'One More Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FREc0HWSClfy83ojuu5PHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/one-more-thai-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 262,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72103, 'longitude': -73.98381},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '6 Clinton St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6 Clinton St', 'New York, NY 10002']},
#    'phone': '+12122288858',
#    'display_phone': '(212) 228-8858',
#    'distance': 1943.218946337562},
#   {'id': 'Nvhx093-K2xwHIZVnFstJw',
#    'alias': 'copper-throat-thai-cuisine-new-york',
#    'name': 'Copper Throat Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kU4KGhCSqEKP43D20XoZuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/copper-throat-thai-cuisine-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 126,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71978, 'longitude': -73.98877},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '123 Ludlow St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['123 Ludlow St', 'New York, NY 10002']},
#    'phone': '+19172617891',
#    'display_phone': '(917) 261-7891',
#    'distance': 1664.2227246686566},
#   {'id': 'r2JVKalbucGf2nryywuL2w',
#    'alias': 'kopitiam-new-york',
#    'name': 'Kopitiam',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/swqtcraojeled7bQRnAweg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kopitiam-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 760,
#    'categories': [{'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71387, 'longitude': -73.99091},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '151 E Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['151 E Broadway', 'New York, NY 10002']},
#    'phone': '+16466093785',
#    'display_phone': '(646) 609-3785',
#    'distance': 974.5409367264409},
#   {'id': 'cugwo9ncnGnH_Chu-P-iAw',
#    'alias': 'am-thai-bistro-brooklyn',
#    'name': 'Am Thai Bistro',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IoRoSUSNqi0Se2uoRL2FCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/am-thai-bistro-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 561,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.646825, 'longitude': -73.970082},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1003 Church Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11218',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1003 Church Ave', 'Brooklyn, NY 11218']},
#    'phone': '+17182878888',
#    'display_phone': '(718) 287-8888',
#    'distance': 6830.519239328913},
#   {'id': 'QCpJlezYJnkZYNat-XYXYw',
#    'alias': 'topaz-thai-authentic-new-york',
#    'name': 'Topaz Thai Authentic',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1E-ZXHD-cRQj_BMt4eoMww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/topaz-thai-authentic-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 833,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7644157409668,
#     'longitude': -73.9789047241211},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '127 W 56th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['127 W 56th St', 'New York, NY 10019']},
#    'phone': '+12129578020',
#    'display_phone': '(212) 957-8020',
#    'distance': 6684.68447465173},
#   {'id': 'WlhkVLite9TQrtnzYLiO4Q',
#    'alias': 'lucys-vietnamese-williamsburg-brooklyn',
#    'name': "Lucy's Vietnamese Williamsburg",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eV7rx5S2xhkX2EgdXATOmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lucys-vietnamese-williamsburg-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.718903, 'longitude': -73.958957},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '112 Berry St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['112 Berry St', 'Brooklyn, NY 11249']},
#    'phone': '+13479161127',
#    'display_phone': '(347) 916-1127',
#    'distance': 3331.7613661130067},
#   {'id': 'HLDKZXsi7TQ0P3rS2wd-UQ',
#    'alias': 'seak-edgewater-3',
#    'name': 'SEAK',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Q_hzlEFdpXG6b8KD_oXOew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seak-edgewater-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 561,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.818223, 'longitude': -73.977102},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '725 River Rd',
#     'address2': 'Ste 30',
#     'address3': None,
#     'city': 'Edgewater',
#     'zip_code': '07020',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['725 River Rd', 'Ste 30', 'Edgewater, NJ 07020']},
#    'phone': '+12014023400',
#    'display_phone': '(201) 402-3400',
#    'distance': 12623.650691423412},
#   {'id': 'CODADSsXEq7PsdV7BncjFw',
#    'alias': 'uni-thai-bistro-brooklyn',
#    'name': 'Uni Thai Bistro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YhvYkdoB7EbpK-DHG7exDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uni-thai-bistro-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.64571, 'longitude': -73.97302},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '265 E 7th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11218',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['265 E 7th St', 'Brooklyn, NY 11218']},
#    'phone': '+19294195642',
#    'display_phone': '(929) 419-5642',
#    'distance': 6883.155577146474},
#   {'id': 'tp4OFMVSQ4kxChtjd_j-KQ',
#    'alias': 'cathailina-new-york-2',
#    'name': 'Cathailina',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AMz2Qy2sdhb7N7zG0Wx4TA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cathailina-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72985, 'longitude': -73.98058},
#    'transactions': [],
#    'location': {'address1': '212 Ave A',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['212 Ave A', 'New York, NY 10009']},
#    'phone': '+19177018959',
#    'display_phone': '(917) 701-8959',
#    'distance': 2944.3452319051826},
#   {'id': 'HyENSD29rcF_5iSFakhMSw',
#    'alias': 'song-brooklyn',
#    'name': 'Song',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Lr9RybP999yik031pmVqew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/song-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1075,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6735, 'longitude': -73.9825199},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '295 5th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['295 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17189651108',
#    'display_phone': '(718) 965-1108',
#    'distance': 3699.108057930545},
#   {'id': 'oWBDdSamOzxMJzsD_-seXg',
#    'alias': 'noodies-new-york',
#    'name': 'Noodies',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NW8TJ0Y5mirETPtpBHGHDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noodies-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 514,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7662850538302,
#     'longitude': -73.9866788007826},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '830 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['830 9th Ave', 'New York, NY 10019']},
#    'phone': '+16466697828',
#    'display_phone': '(646) 669-7828',
#    'distance': 6795.464925631454},
#   {'id': 'Swjm9no7DRqhThLlf0EHng',
#    'alias': 'sama-street-brooklyn-2',
#    'name': 'Sama Street',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4-AGIzhwZZs3ev8TmZ4X6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sama-street-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 120,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'panasian', 'title': 'Pan Asian'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7328843, 'longitude': -73.9545232327229},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '988 Manhattan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['988 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+19292763140',
#    'display_phone': '(929) 276-3140',
#    'distance': 4532.441879818043},
#   {'id': 'U74_3F7r3tMhd6dmTmDBxQ',
#    'alias': 'macao-trading-company-new-york',
#    'name': 'Macao Trading Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EY5hMnXAFZpZcISNvOEymQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/macao-trading-company-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 766,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'portuguese', 'title': 'Portuguese'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.719623, 'longitude': -74.003904},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '311 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['311 Church St', 'New York, NY 10013']},
#    'phone': '+12124318750',
#    'display_phone': '(212) 431-8750',
#    'distance': 1774.0795207044496},
#   {'id': 'TuGFxspYWd0smugwUeN9sA',
#    'alias': 'a-gusto-thai-bistro-brooklyn',
#    'name': 'A Gusto Thai Bistro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sFBiGJ0e2oPanbECLRHUFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/a-gusto-thai-bistro-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 144,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6798609, 'longitude': -73.942852},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1450 Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1450 Fulton St', 'Brooklyn, NY 11216']},
#    'phone': '+13475339961',
#    'display_phone': '(347) 533-9961',
#    'distance': 5186.762501946158},
#   {'id': 'jg5nc64wLYKwKAvz_lfMuA',
#    'alias': 'thai-at-lex-new-york-3',
#    'name': 'Thai At Lex',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/73P4XOx56I8pvHvpvhgnDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-at-lex-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 198,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.778142, 'longitude': -73.956807},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1244 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1244 Lexington Ave', 'New York, NY 10028']},
#    'phone': '+12122886060',
#    'display_phone': '(212) 288-6060',
#    'distance': 8677.865684084838},
#   {'id': 'RBjVu2fFv9NPkV8XD9R9yw',
#    'alias': 'bkk-eatery-new-york',
#    'name': 'BKK Eatery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7tCyDOHuwGbQ9KSP1lcf7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bkk-eatery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 108,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.746043, 'longitude': -73.9795058593154},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '138 E 34th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['138 E 34th St', 'New York, NY 10016']},
#    'phone': '+12122133317',
#    'display_phone': '(212) 213-3317',
#    'distance': 4683.127903178602},
#   {'id': '3KlWyCJ2BikxwcEb0-O4Ww',
#    'alias': 'thai-cafe-brooklyn',
#    'name': 'Thai Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/33lSU4T_0El2vXIZ-lyCMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 133,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73104, 'longitude': -73.95456},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '925 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['925 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183833562',
#    'display_phone': '(718) 383-3562',
#    'distance': 4389.719067798367},
#   {'id': '2wxwpJs4ZrgniJH6Cst-bA',
#    'alias': 'mr-thai-ridgewood',
#    'name': 'Mr. Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zqD6HIv4r9WxIKCdUDU_og/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-thai-ridgewood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70028, 'longitude': -73.90205},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '57-42 Myrtle Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['57-42 Myrtle Ave', 'Ridgewood, NY 11385']},
#    'phone': '+19294478169',
#    'display_phone': '(929) 447-8169',
#    'distance': 7798.845619774471},
#   {'id': 'oNN202L_XcNM-tuDHlgkfg',
#    'alias': 'boon-chu-thai-place-elmhurst',
#    'name': 'Boon Chu Thai Place',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0ffVw7NKAcTDUIPfd5tUwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boon-chu-thai-place-elmhurst?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 337,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.740638, 'longitude': -73.879645},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '83-18 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['83-18 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+17188986836',
#    'display_phone': '(718) 898-6836',
#    'distance': 10423.999333194679}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#              Restaurant         Type Price Rating          Address        Lat  \
# 0     Chai Thai Kitchen         Thai    $$    3.5      930 8th Ave  40.765410
# 1    Pa Pa Thai Cuisine         Thai    $$    4.5     1069 1st Ave  40.759378
# 2       Mr Khao Man Gai  Food Trucks                          None  40.746060
# 3  Pochana Thai Kitchen         Thai    $$      4   33-16 30th Ave  40.765733
# 4              Imm Thai         Thai               301 Central Ave  40.631720
#
#          Lng                                                url  \
# 0 -73.983520  https://www.yelp.com/biz/chai-thai-kitchen-new...
# 1 -73.962415  https://www.yelp.com/biz/pa-pa-thai-cuisine-ne...
# 2 -73.948420
# 3 -73.919320  https://www.yelp.com/biz/pochana-thai-kitchen-...
# 4 -74.313677
#
#                        ID
# 0  yQiII2hHgV5aEMtIA2VG0Q
# 1  _Ge2eC89Z-jlaDDWglfT8g
# 2
# 3  toykv8K0yg8qtvZSXRQ5bg
# 4

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                           Restaurant                       Type Rating Price  \
# 0                            Baoburg               Asian Fusion      4    $$
# 1              Macao Trading Company               Asian Fusion      4   $$$
# 2                 wagamama - midtown               Asian Fusion      4    $$
# 3                A Gusto Thai Bistro                      Cafes    3.5    $$
# 4    Wok Wok Southeast Asian Kitchen                    Chinese      4    $$
# 5                          The Tyger              Cocktail Bars
# 6                        Sama Street              Cocktail Bars      5    $$
# 7                       Pig and Khao                   Filipino      4   $$$
# 8                    Thai on Clinton                Food Trucks    4.5     $
# 9                    Mr Khao Man Gai                Food Trucks
# 10                            SkyIce  Ice Cream & Frozen Yogurt      4    $$
# 11                            Khe-Yo                    Laotian      4    $$
# 12                               WAU                  Malaysian
# 13                            Nyonya                  Malaysian      4    $$
# 14                              Rasa                  Malaysian      4    $$
# 15                          Kopitiam                  Malaysian      4    $$
# 16                       Mother Duck                    Noodles
# 17                       Fish Cheeks                    Seafood    4.5    $$
# 18                    Laut Singapura                Singaporean
# 19                     Thai Sidewalk             Street Vendors
# 20                        Zest Sushi                 Sushi Bars      4    $$
# 21                         Soho Thai                       Thai    3.5    $$
# 22                      Little Basil                       Thai      4    $$
# 23                             Jaiya                       Thai    3.5    $$
# 24                             Spice                       Thai    3.5    $$
# 25                 Kati Thai Cuisine                       Thai      4    $$
# 26              Thank You Come Again                       Thai
# 27           Pongsri Thai Restaurant                       Thai    3.5    $$
# 28                  The Sabieng Thai                       Thai      4    $$
# 29                       Myrtle Thai                       Thai    3.5    $$
# ..                               ...                        ...    ...   ...
# 170                 ACE Thai Kitchen                       Thai    4.5    $$
# 171                        Khao Kang                       Thai      4     $
# 172              Boon Chu Thai Place                       Thai      4     $
# 173                   Bangkok Avenue                       Thai    4.5    $$
# 174    Bua Thai Ramen & Robata Grill                       Thai    4.5    $$
# 175                            Kin'd                       Thai    4.5    $$
# 176                      Wondee Siam                       Thai      4    $$
# 177                Thai Farm Kitchen                       Thai    4.5    $$
# 178                       Tasty Thai                       Thai    4.5     $
# 179                        Glur Thai                       Thai    4.5    $$
# 180                 Lemongrass Grill                       Thai      4    $$
# 181                     Rim Nam Thai                       Thai
# 182                              VIV                       Thai      4    $$
# 183                 Talay Restaurant                       Thai
# 184                           Thai72                       Thai      4    $$
# 185                   Three Roosters                       Thai      5    $$
# 186                Noree Thai Bazaar                       Thai      4    $$
# 187                             Muse                       Thai    4.5    $$
# 188              Wanisa Home Kitchen                       Thai    4.5    $$
# 189                           Thaism                       Thai    3.5    $$
# 190                       River Thai                       Thai
# 191         Look By Plant Love House                       Thai      4    $$
# 192                             Laut                       Thai    3.5    $$
# 193   Lucy's Vietnamese Williamsburg                 Vietnamese
# 194               Saigon Grill & Bar                 Vietnamese    4.5    $$
# 195                             SEAK                 Vietnamese      4    $$
# 196            Ginger and Lemongrass                 Vietnamese    4.5    $$
# 197                             OBAO                 Vietnamese      4    $$
# 198                       5ive Spice                 Vietnamese    4.5    $$
# 199                     Saigon Shack                 Vietnamese      4    $$
#
#                    Address        Lat        Lng  \
# 0        614 Manhattan Ave  40.723493 -73.950332
# 1            311 Church St  40.719623 -74.003904
# 2            100 W 55th St  40.762900 -73.978157
# 3           1450 Fulton St  40.679861 -73.942852
# 4               11 Mott St  40.714056 -73.998839
# 5              1 Howard St  40.718880 -73.999510
# 6        988 Manhattan Ave  40.732884 -73.954523
# 7            68 Clinton St  40.719260 -73.984750
# 8          168 Montague St  40.693925 -73.992411
# 9                     None  40.746060 -73.948420
# 10              63 5th Ave  40.680641 -73.977287
# 11            157 Duane St  40.716906 -74.008587
# 12       434 Amsterdam Ave  40.784480 -73.977760
# 13            199 Grand St  40.719015 -73.996823
# 14             25 W 8th St  40.732765 -73.997567
# 15          151 E Broadway  40.713870 -73.990910
# 16          167 Orchard St  40.721390 -73.988670
# 17              55 Bond St  40.725800 -73.992700
# 18            31 E 20th St  40.738950 -73.988960
# 19   Adams St And Front St  40.702479 -73.988565
# 20           249 Broome St  40.717834 -73.989960
# 21            141 Grand St  40.720078 -73.999641
# 22           153 E 26th St  40.741014 -73.982259
# 23            1553 2nd Ave  40.774553 -73.954563
# 24            39 E 13th St  40.734500 -73.991900
# 25           347 E 14th St  40.731808 -73.982910
# 26       601 Lexington Ave  40.758780 -73.970480
# 27           244 W 48th St  40.760710 -73.986520
# 28              71 1st Ave  40.725540 -73.987220
# 29          438 Myrtle Ave  40.693080 -73.968140
# ..                     ...        ...        ...
# 170         330 Myrtle Ave  40.693150 -73.973280
# 171      7620 Woodside Ave  40.743269 -73.888039
# 172         83-18 Broadway  40.740638 -73.879645
# 173   253-21 Northern Blvd  40.771350 -73.735290
# 174           1611 2nd Ave  40.776350 -73.953080
# 175      192-03 Union Tpke  40.730310 -73.778140
# 176            792 9th Ave  40.764950 -73.987470
# 177         416 Church Ave  40.644042 -73.976052
# 178       72-04 Forest Ave  40.699840 -73.899580
# 179          144 W 19th St  40.741210 -73.996650
# 180           156 Court St  40.688684 -73.993137
# 181              52 Jay St  40.703367 -73.986889
# 182            717 9th Ave  40.762770 -73.989690
# 183      154 Stuyvesant Pl  40.642490 -74.076650
# 184          128 W 72nd St  40.777630 -73.980030
# 185            792 9th Ave  40.764957 -73.987485
# 186           274 Grand St  40.717895 -73.992858
# 187     689 Washington Ave  40.676648 -73.963400
# 188           142 Smith St  40.687000 -73.990420
# 189           278 Smith St  40.682484 -73.993564
# 190     1766 Amsterdam Ave  40.826850 -73.946660
# 191     622 Washington Ave  40.679893 -73.964447
# 192           15 E 17th St  40.737560 -73.991100
# 193           112 Berry St  40.718903 -73.958957
# 194             4521 Ave N  40.618830 -73.930990
# 195           725 River Rd  40.818223 -73.977102
# 196       153 Rivington St  40.719120 -73.985670
# 197            647 9th Ave  40.760654 -73.991332
# 198             52 5th Ave  40.681442 -73.977241
# 199       114 Macdougal St  40.729690 -74.000629
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/baoburg-brooklyn-2?ad...  6wJOojpF2c4lLeBNbTBB0A
# 1    https://www.yelp.com/biz/macao-trading-company...  U74_3F7r3tMhd6dmTmDBxQ
# 2    https://www.yelp.com/biz/wagamama-midtown-new-...  wyjtGsW5NeVDknGQWnIPAQ
# 3    https://www.yelp.com/biz/a-gusto-thai-bistro-b...  TuGFxspYWd0smugwUeN9sA
# 4    https://www.yelp.com/biz/wok-wok-southeast-asi...  0GftSP2dRwEzujkv2VKIgA
# 5
# 6    https://www.yelp.com/biz/sama-street-brooklyn-...  Swjm9no7DRqhThLlf0EHng
# 7    https://www.yelp.com/biz/pig-and-khao-new-york...  nxTEuWKzkK1tCF4LrhFSUQ
# 8    https://www.yelp.com/biz/thai-on-clinton-brook...  OuHB-EdeXmQ26QDzAsDxyw
# 9
# 10   https://www.yelp.com/biz/skyice-brooklyn-2?adj...  LQ8ITaZIbaiQ8pHPOx5i6w
# 11   https://www.yelp.com/biz/khe-yo-new-york?adjus...  BKMCAYb9EAivUm3p-vrC9w
# 12
# 13   https://www.yelp.com/biz/nyonya-new-york?adjus...  M-odQWSEfsR2mVEw7nKG-g
# 14   https://www.yelp.com/biz/rasa-new-york?adjust_...  EbX_9tqAJs4gW51gZpOB7g
# 15   https://www.yelp.com/biz/kopitiam-new-york?adj...  r2JVKalbucGf2nryywuL2w
# 16
# 17   https://www.yelp.com/biz/fish-cheeks-new-york?...  WJS06XxRdc6DD1s4LWE9HA
# 18
# 19
# 20   https://www.yelp.com/biz/zest-sushi-new-york-3...  ZfuZ2byArGq-5j8zX8Afeg
# 21   https://www.yelp.com/biz/soho-thai-new-york-8?...  l3aVYfTWVINXaNGxlMz0bQ
# 22   https://www.yelp.com/biz/little-basil-new-york...  A_GbgtUSyGWpihHZOqMdwQ
# 23   https://www.yelp.com/biz/jaiya-new-york-4?adju...  Kyx9QFPJUzlC7dmM8SE1bw
# 24   https://www.yelp.com/biz/spice-new-york?adjust...  T8WfkzuVi96qCpj1tWjlxw
# 25   https://www.yelp.com/biz/kati-thai-cuisine-new...  1Fe4lCiMPNVhoEyjg92frA
# 26
# 27   https://www.yelp.com/biz/pongsri-thai-restaura...  er4E7VCjDo0xE_IPu5o6Ig
# 28   https://www.yelp.com/biz/the-sabieng-thai-new-...  9VyMJICKGbC7Y5Ssq-Xk7w
# 29   https://www.yelp.com/biz/myrtle-thai-brooklyn?...  ZGKdgFAGOL6NOPXPrBkhzA
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/ace-thai-kitchen-broo...  1sEr-BDi2LD6HH6K960pfQ
# 171  https://www.yelp.com/biz/khao-kang-elmhurst?ad...  hA5QUlrSjpxMZ90Kof0bgA
# 172  https://www.yelp.com/biz/boon-chu-thai-place-e...  oNN202L_XcNM-tuDHlgkfg
# 173  https://www.yelp.com/biz/bangkok-avenue-little...  5pzc2GdvdmqiLRSdjHnnKw
# 174  https://www.yelp.com/biz/bua-thai-ramen-and-ro...  -Q8MYIWoE4EsGQtudIOY0w
# 175  https://www.yelp.com/biz/kind-fresh-meadows?ad...  cegA4jf16vEt7NCQ7cpu2w
# 176  https://www.yelp.com/biz/wondee-siam-new-york-...  rKeLuHDI3PQZsPSVCEMHtw
# 177  https://www.yelp.com/biz/thai-farm-kitchen-bro...  _zRVdCfUcx1cwseFycSQdQ
# 178  https://www.yelp.com/biz/tasty-thai-ridgewood?...  rehmlZmUNL2AthW-VTXJJQ
# 179  https://www.yelp.com/biz/glur-thai-new-york?ad...  YS8pw7sYOBqaW23FCOqecg
# 180  https://www.yelp.com/biz/lemongrass-grill-broo...  vA2VEhW6S1ioX6tXtQdO9A
# 181
# 182  https://www.yelp.com/biz/viv-new-york-32?adjus...  z1OgXX3L9Ipl2mu-Hf4ADw
# 183
# 184  https://www.yelp.com/biz/thai72-new-york?adjus...  L2ZW-MdvRJ3gM2RIq8STbA
# 185  https://www.yelp.com/biz/three-roosters-new-yo...  9b_FvTUgkkUUMyL0nGhFtg
# 186  https://www.yelp.com/biz/noree-thai-bazaar-new...  Wq9cARVEwOmoqfg41mNRNg
# 187  https://www.yelp.com/biz/muse-brooklyn?adjust_...  SoEQRDUNYDZPVSSIhTOG6A
# 188  https://www.yelp.com/biz/wanisa-home-kitchen-b...  StFf9fVnAlhwrUWan0C4Ww
# 189  https://www.yelp.com/biz/thaism-brooklyn?adjus...  GSOwJ5Gr8X4eGbkIjCzMWA
# 190
# 191  https://www.yelp.com/biz/look-by-plant-love-ho...  UO4kyXfdQIlAhM-TRgM9cw
# 192  https://www.yelp.com/biz/laut-new-york?adjust_...  sinDhwX8Egru_3FCI7bhkw
# 193
# 194  https://www.yelp.com/biz/saigon-grill-and-bar-...  V58g7E1AHkuTchTVyLQuYQ
# 195  https://www.yelp.com/biz/seak-edgewater-3?adju...  HLDKZXsi7TQ0P3rS2wd-UQ
# 196  https://www.yelp.com/biz/ginger-and-lemongrass...  McU7XI3HoWFELTDaGc1SEw
# 197  https://www.yelp.com/biz/obao-new-york-3?adjus...  NN3mOWF5e_pnR1ArqM2bHQ
# 198  https://www.yelp.com/biz/5ive-spice-brooklyn-3...  SSDOkx5enfRH3nsniS_2jA
# 199  https://www.yelp.com/biz/saigon-shack-new-york...  7Qvh0oFRsoqrO9qNlcMKXQ
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_Thai.csv')
