# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"bakery","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': 'MauzeeZM7S-wUk_G98Ybrg',
#    'alias': 'mei-lai-wah-bakery-new-york',
#    'name': 'Mei Lai Wah Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rDd0B0a8-5CV3KItant2GA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mei-lai-wah-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1189,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7155758, 'longitude': -73.9979585},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '64 Bayard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64 Bayard St', 'New York, NY 10013']},
#    'phone': '+12129667866',
#    'display_phone': '(212) 966-7866',
#    'distance': 1167.8722852194924},
#   {'id': 'ga6sRtE0l85iftw_5-W84Q',
#    'alias': 'dominique-ansel-bakery-new-york',
#    'name': 'Dominique Ansel Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ae6sDhEfUXTE5EKfWSOrCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dominique-ansel-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4788,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72522, 'longitude': -74.00291},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '189 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['189 Spring St', 'New York, NY 10012']},
#    'phone': '+12122192773',
#    'display_phone': '(212) 219-2773',
#    'distance': 2316.930739426023},
#   {'id': 'GlPJPpKvPR4d8dmcSEYpdA',
#    'alias': 'takahachi-bakery-new-york',
#    'name': 'Takahachi Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oP2xYZjbAa8akp-9CLmiVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/takahachi-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 947,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71393, 'longitude': -74.00822},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '25 Murray St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 Murray St', 'New York, NY 10007']},
#    'phone': '+12127915550',
#    'display_phone': '(212) 791-5550',
#    'distance': 1511.7020935512141},
#   {'id': 'nyxmTe-It-tzfagvjkge1g',
#    'alias': 'burrow-brooklyn',
#    'name': 'Burrow',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oAg_RiYyeMnUO5bY_eIOQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burrow-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 81,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7027217, 'longitude': -73.9868878},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '68 Jay St',
#     'address2': 'Ste 119',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['68 Jay St', 'Ste 119', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 693.8065652395189},
#   {'id': 'WHRHK3S1mQc3PmhwsGRvbw',
#    'alias': 'bibble-and-sip-new-york-2',
#    'name': 'Bibble & Sip',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gX847-f2s1X65RkzsFAWBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bibble-and-sip-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5020,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7628355, 'longitude': -73.98518009478293},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '253 W 51st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253 W 51st St', 'New York, NY 10019']},
#    'phone': '+16466495116',
#    'display_phone': '(646) 649-5116',
#    'distance': 6427.569355387715},
#   {'id': '0kW0112jMERVjpRzWT4F7Q',
#    'alias': 'la-bicyclette-bakery-new-york',
#    'name': 'La Bicyclette Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1rM5TGW_oyS3OxjGnaHs_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-bicyclette-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.714372, 'longitude': -73.959061},
#    'transactions': ['delivery'],
#    'location': {'address1': '667 Driggs Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['667 Driggs Ave', 'New York, NY 11211']},
#    'phone': '+13479161417',
#    'display_phone': '(347) 916-1417',
#    'distance': 3134.5375723686243},
#   {'id': 'H4jJ7XB3CetIr1pg56CczQ',
#    'alias': 'levain-bakery-new-york',
#    'name': 'Levain Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ElQFlcl5wBXfn1qbfweYsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/levain-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8481,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.779961, 'longitude': -73.980299},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '167 W 74th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['167 W 74th St', 'New York, NY 10023']},
#    'phone': '+19174643769',
#    'display_phone': '(917) 464-3769',
#    'distance': 8369.262424680568},
#   {'id': '_kwVdjdWvq2HaTlrykitNw',
#    'alias': 'sullivan-street-bakery-new-york-5',
#    'name': 'Sullivan Street Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vrzbT0sLityw4yJtfmFonA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sullivan-street-bakery-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72759724358166,
#     'longitude': -73.98319280396632},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '437 E 9th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['437 E 9th St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2634.906533756502},
#   {'id': 'jWC4mD-yy-IzuZxU5ctAKw',
#    'alias': 'mias-bakery-brooklyn',
#    'name': "Mia's Bakery",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-_RVN3QbCDs6ScFwP_0hqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mias-bakery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 852,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6870199, 'longitude': -73.9901299},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '139 Smith St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['139 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+13479873194',
#    'display_phone': '(347) 987-3194',
#    'distance': 2081.025885948994},
#   {'id': 'iTcxncdrcQRK1tdcbFIqGQ',
#    'alias': 'aux-merveilleux-de-fred-new-york',
#    'name': 'Aux Merveilleux De Fred',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0vNnSW83c92J0_CqaCmPRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aux-merveilleux-de-fred-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 395,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73835064346807,
#     'longitude': -74.00412204723874},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '37 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37 8th Ave', 'New York, NY 10014']},
#    'phone': '+19174751992',
#    'display_phone': '(917) 475-1992',
#    'distance': 3751.534985878222},
#   {'id': 'nOCjslrdcKBQQYgD5qUs9Q',
#    'alias': 'kam-hing-coffee-shop-new-york-2',
#    'name': 'Kam Hing Coffee Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dJMMeLLjl_h03ovSk9aB7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kam-hing-coffee-shop-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 743,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71798, 'longitude': -73.99921},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '118 Baxter St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['118 Baxter St', 'New York, NY 10013']},
#    'phone': '+16465527867',
#    'display_phone': '(646) 552-7867',
#    'distance': 1454.1441795259896},
#   {'id': 'XSwagBljEsxG2i1rq4GEAQ',
#    'alias': 'almondine-bakery-brooklyn',
#    'name': 'Almondine Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/E3wP_njOCmZ2IW6hrWCK6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/almondine-bakery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 372,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7033174, 'longitude': -73.9912506},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '85 Water St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+17187975026',
#    'display_phone': '(718) 797-5026',
#    'distance': 348.91633855519586},
#   {'id': 'oDRZt37ROqadlK3-VI0PfQ',
#    'alias': 'alimama-new-york-3',
#    'name': 'Alimama',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5XwgumtgBN2Wzm20dprDqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alimama-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1386,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7158626896215,
#     'longitude': -73.9992850858479},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '89A Bayard St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['89A Bayard St', 'New York, NY 10013']},
#    'phone': '+12122357288',
#    'display_phone': '(212) 235-7288',
#    'distance': 1227.5817807830615},
#   {'id': 'VtJd1l64kqUUyWacwK0J2Q',
#    'alias': 'venieros-new-york-2',
#    'name': "Veniero's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/pMtdkncb9gTkja1DX0Tp6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/venieros-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2141,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729431, 'longitude': -73.984541},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '342 E 11th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['342 E 11th St', 'New York, NY 10003']},
#    'phone': '+12126747070',
#    'display_phone': '(212) 674-7070',
#    'distance': 2790.900365889197},
#   {'id': '-k_5NsYnKCHGTdBaqegkrw',
#    'alias': 'le-fournil-new-york',
#    'name': 'Le fournil',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yNmD0Jf29RgVF-0KNla1rQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-fournil-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 67,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.727947, 'longitude': -73.988489},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '115 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['115 2nd Ave', 'New York, NY 10003']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2548.470476989717},
#   {'id': 'mU23NlQfn1R9OhA6WMe_xg',
#    'alias': 'breads-bakery-new-york',
#    'name': 'Breads Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mDaSWYX8hEV0eNGXJSDhVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/breads-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1080,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73661, 'longitude': -73.99181},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '18 E 16th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18 E 16th St', 'New York, NY 10003']},
#    'phone': '+12126332253',
#    'display_phone': '(212) 633-2253',
#    'distance': 3470.824425100059},
#   {'id': 'k17DEW9TqRZf6EFSc49OsA',
#    'alias': 'bakeri-brooklyn',
#    'name': 'Bakeri',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gfXzPEGq7pudg-fVhYalrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bakeri-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 382,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72004, 'longitude': -73.96013},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '150 Wythe Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 Wythe Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17183888037',
#    'display_phone': '(718) 388-8037',
#    'distance': 3306.011559281162},
#   {'id': 'M2CSxMwbkwJr_G_Bzp7Y5Q',
#    'alias': 'mah-ze-dahr-bakery-new-york',
#    'name': 'Mah-Ze-Dahr Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FUdkQklLHJeembS3oqXuZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mah-ze-dahr-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 367,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73503, 'longitude': -74.00002},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '28 Greenwich Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 Greenwich Ave', 'New York, NY 10011']},
#    'phone': '+12124989810',
#    'display_phone': '(212) 498-9810',
#    'distance': 3329.046042624273},
#   {'id': 'PWsU_ORsfcjeeUqocm9vQg',
#    'alias': 'petees-pie-company-new-york',
#    'name': "Petee's Pie Company",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jck-uj4Li_9L-X6bIEbyLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/petees-pie-company-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 823,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7192158508607,
#     'longitude': -73.9912822511308},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '61 Delancey St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['61 Delancey St', 'New York, NY 10002']},
#    'phone': '+12129662526',
#    'display_phone': '(212) 966-2526',
#    'distance': 1552.149290787714},
#   {'id': 'o4pAOfbT9Bd9RskLjD0g_w',
#    'alias': 'sweet-rehab-new-york',
#    'name': 'Sweet Rehab',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kmXLOZ6jLODgx2HSz50Yww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweet-rehab-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 160,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.726699, 'longitude': -74.001808},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '135 Sullivan St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['135 Sullivan St', 'New York, NY 10012']},
#    'phone': '+19292184745',
#    'display_phone': '(929) 218-4745',
#    'distance': 2444.2624207825033},
#   {'id': '3t4VJC1vyUGk0aaem3b5ng',
#    'alias': 'ceremonia-bakeshop-brooklyn',
#    'name': 'Ceremonia Bakeshop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4QcEFcXoB6EHY8-zsj_hLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ceremonia-bakeshop-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 98,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7125, 'longitude': -73.96056},
#    'transactions': ['delivery'],
#    'location': {'address1': '743 Driggs Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['743 Driggs Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13473842212',
#    'display_phone': '(347) 384-2212',
#    'distance': 2952.0083122815354},
#   {'id': 'ZMQzXIiqdBIuicFySTWGKg',
#    'alias': 'dough-new-york-2',
#    'name': 'Dough',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Mg3YZ1U-UpkFCCiaL5Remw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dough-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1571,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73931, 'longitude': -73.99243},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '14 W 19th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 W 19th St', 'New York, NY 10011']},
#    'phone': '+12122436844',
#    'display_phone': '(212) 243-6844',
#    'distance': 3771.936848199482},
#   {'id': 'Q-0NA-MheoaGvG7wtMhPGw',
#    'alias': 'minnies-bake-shop-manhattan',
#    'name': "Minnie's Bake Shop",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/F509pZDK2s53jFBlKFijQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/minnies-bake-shop-manhattan?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7349582686699,
#     'longitude': -73.9937028335709},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '10 E 13th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Manhattan',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10 E 13th St', 'Manhattan, NY 10003']},
#    'phone': '+16462295102',
#    'display_phone': '(646) 229-5102',
#    'distance': 3282.114316783861},
#   {'id': '-2UtjTxrt1Xzd-HPsLJ7mA',
#    'alias': 'butler-brooklyn-2',
#    'name': 'Butler',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CU_zfWiYItMJkR6iJsnk0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/butler-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 131,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7032670673495,
#     'longitude': -73.9922419276899},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '40 Water St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40 Water St', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 299.48141504845114},
#   {'id': 'rVJ57CwEcucZg1k_y8u3Rg',
#    'alias': 'patisserie-fouet-new-york',
#    'name': 'Patisserie Fouet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8zhW4vcphXIomWgtz0aokw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-fouet-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 262,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.735034, 'longitude': -73.993047},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '15 E 13th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 E 13th St', 'New York, NY 10003']},
#    'phone': '+12126200622',
#    'display_phone': '(212) 620-0622',
#    'distance': 3291.833916830272},
#   {'id': 'drE9p2p_a9TptqyOFnnJVg',
#    'alias': 'fabrique-new-york',
#    'name': 'Fabrique',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/efMAA30lwKD48lKGbNtavQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fabrique-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 164,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7405, 'longitude': -74.00471},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '348 W 14th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['348 W 14th St', 'New York, NY 10014']},
#    'phone': '+19172612476',
#    'display_phone': '(917) 261-2476',
#    'distance': 3991.028597552693},
#   {'id': '0tJEDmeNMLueSGLNTF0JFg',
#    'alias': 'angelina-bakery-new-york',
#    'name': 'Angelina Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8040_-AxajTbQjzk4cySRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/angelina-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 257,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75498, 'longitude': -73.99166},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '575 8th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['575 8th Ave', 'New York, NY 10018']},
#    'phone': '+12126877100',
#    'display_phone': '(212) 687-7100',
#    'distance': 5517.513781375333},
#   {'id': 'Sgh7Uar8wv6WKA-UZ7hcXA',
#    'alias': 'balthazar-boulangerie-new-york',
#    'name': 'Balthazar Boulangerie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XorcA_Z0wQneLiV5SrzUEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/balthazar-boulangerie-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 377,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72276, 'longitude': -73.99842},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '80 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Spring St', 'New York, NY 10012']},
#    'phone': '+12129651785',
#    'display_phone': '(212) 965-1785',
#    'distance': 1943.5604048732139},
#   {'id': 's1pJHjoce-IbHQiCe4mA3w',
#    'alias': 'marthas-country-bakery-brooklyn-2',
#    'name': "Martha's Country Bakery",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/So6BeZ1ZbMgbh7Wi5QvXLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marthas-country-bakery-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 777,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7148806028737,
#     'longitude': -73.9607515186071},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '263 Bedford Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['263 Bedford Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17185990900',
#    'display_phone': '(718) 599-0900',
#    'distance': 3015.564267934753},
#   {'id': 'S-M4rqJM7fwLJ2rSMYS35g',
#    'alias': 'madman-bakery-new-york',
#    'name': 'Madman Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mJe3nsD6Kiye3Fc3Des_PQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/madman-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.73242, 'longitude': -73.99426},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '42 University Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 University Pl', 'New York, NY 10003']},
#    'phone': '+13477811121',
#    'display_phone': '(347) 781-1121',
#    'distance': 2999.863061685295},
#   {'id': 'AI680OnsLsoCro-0hYF1aQ',
#    'alias': 'michaeli-bakery-new-york-2',
#    'name': 'Michaeli Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-e5YrXebJLxor7-nWdUJtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/michaeli-bakery-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 114,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.714349, 'longitude': -73.992054},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '115A Division St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['115A Division St', 'New York, NY 10002']},
#    'phone': '+16463602284',
#    'display_phone': '(646) 360-2284',
#    'distance': 1007.9224803527684},
#   {'id': 'pHfsXEPHkGXkmGo-PbwB6w',
#    'alias': 'keki-modern-cakes-new-york',
#    'name': 'Keki Modern Cakes',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uecbXo0a7qGf6pupc50Y-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/keki-modern-cakes-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 662,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71656, 'longitude': -73.99822},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '79 Mott St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79 Mott St', 'New York, NY 10013']},
#    'phone': '+16468632094',
#    'display_phone': '(646) 863-2094',
#    'distance': 1276.2958662297299},
#   {'id': 'Tp3-DL6wF8mETTiUDXzO3A',
#    'alias': 'kam-boat-bakery-and-cafe-new-york',
#    'name': 'Kam Boat Bakery & Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Tg2Uq_tcD5OmsgeKJyklVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kam-boat-bakery-and-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 142,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7178308, 'longitude': -73.995106},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '111 Bowery St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 Bowery St', 'New York, NY 10002']},
#    'phone': '+12122741822',
#    'display_phone': '(212) 274-1822',
#    'distance': 1378.9544200391526},
#   {'id': 'qXuUBEaib4caLC6WCPhBjA',
#    'alias': 'patisserie-tomoko-brooklyn-2',
#    'name': 'Patisserie Tomoko',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lfFS5x973jlpmFuq5vRf9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-tomoko-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 347,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'macarons', 'title': 'Macarons'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7176114, 'longitude': -73.9519192},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '568 Union Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['568 Union Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17183887121',
#    'display_phone': '(718) 388-7121',
#    'distance': 3819.1739527873074},
#   {'id': 'b5x-Fw7I7Y88TdFIzvbsnw',
#    'alias': 'supermoon-bakehouse-new-york',
#    'name': 'Supermoon Bakehouse',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SrQiuKi4go9Bjl8XPn-7IA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/supermoon-bakehouse-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 807,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71991, 'longitude': -73.9872},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '120 Rivington St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['120 Rivington St', 'New York, NY 10002']},
#    'phone': '+13476541211',
#    'display_phone': '(347) 654-1211',
#    'distance': 1714.9424016310745},
#   {'id': 'nyqK-hAA8ZKYar9PuQiBiA',
#    'alias': 'bakeri-brooklyn-2',
#    'name': 'Bakeri',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZaM9GSlDXVIna8UlGOi0Dg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bakeri-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 103,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73431, 'longitude': -73.95753},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '105 Freeman St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['105 Freeman St', 'Brooklyn, NY 11222']},
#    'phone': '+17183491542',
#    'display_phone': '(718) 349-1542',
#    'distance': 4464.080896473425},
#   {'id': '_DcfYjnGffQI3iP1Be0kdA',
#    'alias': 'ladurée-madison-new-york-2',
#    'name': 'Ladurée Madison',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8sYGlnNpM1oAKNvf8DOrWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ladur%C3%A9e-madison-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1930,
#    'categories': [{'alias': 'macarons', 'title': 'Macarons'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7707702252517,
#     'longitude': -73.9663760711639},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '864 Madison Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['864 Madison Ave', 'New York, NY 10021']},
#    'phone': '+16465583157',
#    'display_phone': '(646) 558-3157',
#    'distance': 7635.1609196521695},
#   {'id': 'wWhZvkaFrntlSf1CWvD1Zw',
#    'alias': 'cafe-patoro-new-york',
#    'name': 'Cafe Patoro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Nnlsd9Wl7KFVVqZxtDRWpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-patoro-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 182,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7072720974983,
#     'longitude': -74.0023160353303},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '223 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['223 Front St', 'New York, NY 10038']},
#    'phone': '+19172620031',
#    'display_phone': '(917) 262-0031',
#    'distance': 706.1266596183273},
#   {'id': 'JWLRT0dkdaC7AHtYapWbGw',
#    'alias': 'pasticceria-rocco-new-york',
#    'name': 'Pasticceria Rocco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_OAdfVr9GOg2ihEzcKXeiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pasticceria-rocco-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1052,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73083, 'longitude': -74.00265},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '243 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['243 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12122426031',
#    'display_phone': '(212) 242-6031',
#    'distance': 2909.8673181164463},
#   {'id': 'lqnI_jISnH7RZWlPtKkViQ',
#    'alias': 'tres-leches-cafe-new-york',
#    'name': 'Tres Leches Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NCmBmnJP5gWDLF3fgBrikQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tres-leches-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 155,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.79356, 'longitude': -73.93778},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '356 E 112th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['356 E 112th St', 'New York, NY 10029']},
#    'phone': '+16465590176',
#    'display_phone': '(646) 559-0176',
#    'distance': 10888.873527787518},
#   {'id': 'Tns-1BJip9a6K-O6V2pyUQ',
#    'alias': 'red-gate-bakery-new-york',
#    'name': 'Red Gate Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AKCAnopUuox0kXCQZESkHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/red-gate-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.723717, 'longitude': -73.988806},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '68 E 1st St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['68 E 1st St', 'New York, NY 10003']},
#    'phone': '+16468705553',
#    'display_phone': '(646) 870-5553',
#    'distance': 2081.3552305882727},
#   {'id': '7-yC49tlWreX6TQtMNFSFg',
#    'alias': 'kitsby-brooklyn',
#    'name': 'Kitsby',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2Yss10njvmZ7qcshlj35gA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kitsby-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 220,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71411, 'longitude': -73.960977},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '186 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['186 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+19175305006',
#    'display_phone': '(917) 530-5006',
#    'distance': 2969.509868206952},
#   {'id': 'Xn_UheApVz6K9heX4vY8PA',
#    'alias': 'terms-of-endearment-brooklyn-2',
#    'name': 'Terms of Endearment',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TBK0GCkD-YY4QxfbA98zOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/terms-of-endearment-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.716367, 'longitude': -73.962207},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '135 Metropolitan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['135 Metropolitan Ave', 'Brooklyn, NY 11249']},
#    'phone': '+13477631420',
#    'display_phone': '(347) 763-1420',
#    'distance': 2964.3329491322866},
#   {'id': 'bNUCP7QwgcGthpO1e2atzQ',
#    'alias': 'colomba-bakery-new-york',
#    'name': 'Colomba Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/iZJlWR_s7QuQVYXnWpN5gg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/colomba-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.73062100936686, 'longitude': -73.995053},
#    'transactions': [],
#    'location': {'address1': '29 Waverly Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['29 Waverly Pl', 'New York, NY 10003']},
#    'phone': '+16467200572',
#    'display_phone': '(646) 720-0572',
#    'distance': 2800.1887159585826},
#   {'id': 'oHEKc3Og4v13ReftMolKZg',
#    'alias': 'pinklady-cheese-tart-new-york-2',
#    'name': 'Pinklady Cheese Tart',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/f5rATsGxrMnBf_Xe_eqaHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pinklady-cheese-tart-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 212,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7141357508495,
#     'longitude': -73.9988519623876},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '11 Mott St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 Mott St', 'New York, NY 10013']},
#    'phone': '+16467642539',
#    'display_phone': '(646) 764-2539',
#    'distance': 1039.9712375042332},
#   {'id': '9pddyMWw4Vxo3E6lKZXiqQ',
#    'alias': 'marvelous-by-fred-new-york',
#    'name': 'Marvelous By Fred',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sQhdEozO9vvMxf5-SXIHhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marvelous-by-fred-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75202, 'longitude': -73.98657},
#    'transactions': [],
#    'location': {'address1': '1001 6th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1001 6th Ave', 'New York, NY 10018']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5225.740767264816},
#   {'id': 'Nbam9IMWMgSiQWL8dHql4g',
#    'alias': 'nick-sons-bakery-brooklyn',
#    'name': 'Nick + Sons Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FLQhbmtCHbZ1I_pkgLgdiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nick-sons-bakery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 99,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.710838, 'longitude': -73.947412},
#    'transactions': ['delivery'],
#    'location': {'address1': '205 Leonard St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['205 Leonard St', 'Brooklyn, NY 11206']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4001.59592412898},
#   {'id': 'SWRz34fmNEDPcrngJMMo7Q',
#    'alias': 'butler-brooklyn',
#    'name': 'Butler',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_N74apVU_48PvLh6YlukTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/butler-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 123,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7117670177852,
#     'longitude': -73.9646924963509},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '95 S 5th St',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['95 S 5th St', 'Brooklyn, NY 11249']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2592.1803299896737},
#   {'id': 'cgWxj5zytsVQtbygN9M-OQ',
#    'alias': 'charlotte-patisserie-brooklyn-2',
#    'name': 'Charlotte Patisserie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2h8aP59CSEwPk9KV8H6bKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/charlotte-patisserie-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6872171402548,
#     'longitude': -73.9933373406529},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '201 Court St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['201 Court St', 'Brooklyn, NY 11201']},
#    'phone': '+19292950372',
#    'display_phone': '(929) 295-0372',
#    'distance': 2028.4295715424657},
#   {'id': 'xTnivXEdEtXrnhp-z4JGvg',
#    'alias': 'la-parisienne-new-york-5',
#    'name': 'La Parisienne',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ywbWsBIM-z7OHvhMoHUg5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-parisienne-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 606,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70961, 'longitude': -74.0093799},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '9 Maiden Ln',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Maiden Ln', 'New York, NY 10038']},
#    'phone': '+16467564911',
#    'display_phone': '(646) 756-4911',
#    'distance': 1350.1089630689858}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                Restaurant          Type Price Rating        Address  \
# 0      Mei Lai Wah Bakery      Bakeries     $      4   64 Bayard St
# 1  Dominique Ansel Bakery      Bakeries    $$      4  189 Spring St
# 2        Takahachi Bakery      Bakeries    $$      4   25 Murray St
# 3                  Burrow      Desserts     $    4.5      68 Jay St
# 4            Bibble & Sip  Coffee & Tea    $$    4.5  253 W 51st St
#
#          Lat        Lng                                                url  \
# 0  40.715576 -73.997958  https://www.yelp.com/biz/mei-lai-wah-bakery-ne...
# 1  40.725220 -74.002910  https://www.yelp.com/biz/dominique-ansel-baker...
# 2  40.713930 -74.008220  https://www.yelp.com/biz/takahachi-bakery-new-...
# 3  40.702722 -73.986888  https://www.yelp.com/biz/burrow-brooklyn?adjus...
# 4  40.762836 -73.985180  https://www.yelp.com/biz/bibble-and-sip-new-yo...
#
#                        ID
# 0  MauzeeZM7S-wUk_G98Ybrg
# 1  ga6sRtE0l85iftw_5-W84Q
# 2  GlPJPpKvPR4d8dmcSEYpdA
# 3  nyxmTe-It-tzfagvjkge1g
# 4  WHRHK3S1mQc3PmhwsGRvbw

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"bakery","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': 'SjNNOP3KKHayd_BpatGmwQ',
#    'alias': 'brooklyn-sweet-spot-brooklyn-2',
#    'name': 'Brooklyn Sweet Spot',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mQKmKpCCa1-ww056D0sU-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-sweet-spot-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6930261, 'longitude': -73.9715469},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '366 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['366 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+13479160494',
#    'display_phone': '(347) 916-0494',
#    'distance': 2363.0251117544976},
#   {'id': 'qMr-lz0G0vyz2r4mJJQxmA',
#    'alias': 'butter-lane-new-york',
#    'name': 'Butter Lane',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qwdSGuda8Q89zZljsllVWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/butter-lane-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1233,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'},
#     {'alias': 'cookingclasses', 'title': 'Cooking Classes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7264944895101,
#     'longitude': -73.9841490983963},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '123 E 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['123 E 7th St', 'New York, NY 10009']},
#    'phone': '+12126772880',
#    'display_phone': '(212) 677-2880',
#    'distance': 2491.864637411364},
#   {'id': 'pjpRglb5st10jXf9tKqk-A',
#    'alias': 'ella-crown-bakehouse-brooklyn',
#    'name': 'Ella Crown Bakehouse',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DxxIl2ic-Fq5FD5jUX8whA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ella-crown-bakehouse-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 56,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.690691, 'longitude': -73.995072},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '149 Atlantic Ave',
#     'address2': 'Ste 1C',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['149 Atlantic Ave', 'Ste 1C', 'Brooklyn, NY 11201']},
#    'phone': '+13473874980',
#    'display_phone': '(347) 387-4980',
#    'distance': 1644.8715668787179},
#   {'id': 'fPQ2eE9lm8tc87O5-GLjyA',
#    'alias': 'mille-feuille-bakery-new-york-3',
#    'name': 'Mille-Feuille Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8u453wcp-jdwfV9kpimDQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mille-feuille-bakery-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 355,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.782425, 'longitude': -73.9811603},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2175 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2175 Broadway', 'New York, NY 10024']},
#    'phone': '+12123626261',
#    'display_phone': '(212) 362-6261',
#    'distance': 8630.99662794525},
#   {'id': 'qVSOes5JoWc5_umv4nd4Hg',
#    'alias': 'sugar-sweet-sunshine-bakery-new-york',
#    'name': 'Sugar Sweet Sunshine Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mK4J_NrzxZmmbP-ND6w0gg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sugar-sweet-sunshine-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2086,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.719851, 'longitude': -73.987011},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '126 Rivington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['126 Rivington St', 'New York, NY 10002']},
#    'phone': '+12129951960',
#    'display_phone': '(212) 995-1960',
#    'distance': 1715.4495332037206},
#   {'id': '6G_NSMacAfdf-WYOpcQ4uw',
#    'alias': 'eileens-special-cheesecake-new-york',
#    'name': "Eileen's Special Cheesecake",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5wemqIS_o0sTwr3JnO7MTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eileens-special-cheesecake-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1742,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7215431969029,
#     'longitude': -73.9972332037048},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '17 Cleveland Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 Cleveland Pl', 'New York, NY 10012']},
#    'phone': '+12129665585',
#    'display_phone': '(212) 966-5585',
#    'distance': 1807.1202287470203},
#   {'id': 'ReYr4cHNlnZ4jiC4R7IRZg',
#    'alias': 'melt-bakery-brooklyn-2',
#    'name': 'Melt Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SF-v6J_5LMvZyko89tMQgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/melt-bakery-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 444,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.702676, 'longitude': -73.989176},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '111 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+16465356358',
#    'display_phone': '(646) 535-6358',
#    'distance': 529.9638776061175},
#   {'id': 'nkssBtuLaKgxeLfNJjnSeQ',
#    'alias': 'bread-story-new-york-new-york',
#    'name': 'Bread Story New York',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eL93DgVkVUCHYlW7dD4RoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bread-story-new-york-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.731988819247285,
#     'longitude': -73.98156216802064},
#    'transactions': [],
#    'location': {'address1': '264 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['264 1st Ave', 'New York, NY 10009']},
#    'phone': '+13476333780',
#    'display_phone': '(347) 633-3780',
#    'distance': 3140.514568609332},
#   {'id': 'cO9E0n9ulzJ6eZ4TKrFx1A',
#    'alias': 'mille-feuille-bakery-new-york-2',
#    'name': 'Mille-Feuille Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tF46aDSEYYoEcbXAl3WHIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mille-feuille-bakery-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 527,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72933, 'longitude': -73.99808},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '552 Laguardia Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['552 Laguardia Pl', 'New York, NY 10012']},
#    'phone': '+12125334698',
#    'display_phone': '(212) 533-4698',
#    'distance': 2657.8473641828227},
#   {'id': '85x3dZCMBj4rJ2LAdW-wFg',
#    'alias': 'magnolia-bakery-west-village-new-york',
#    'name': 'Magnolia Bakery West Village',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fqN9-uf9O3qyY8q5qj8ENA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/magnolia-bakery-west-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2456,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.73589, 'longitude': -74.00498},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '401 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['401 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12124622572',
#    'display_phone': '(212) 462-2572',
#    'distance': 3501.4198143415374},
#   {'id': 'H7QoApSloy7Zu0LFpQVv-A',
#    'alias': 'keki-modern-cakes-new-york-2',
#    'name': 'Keki Modern Cakes',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y9LYeX5c2QnPxFBpx9MoPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/keki-modern-cakes-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 382,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7468603, 'longitude': -73.984986},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '315 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['315 5th Ave', 'New York, NY 10016']},
#    'phone': '+12128890251',
#    'display_phone': '(212) 889-0251',
#    'distance': 4671.489411005774},
#   {'id': 'KakiWGOfm_h5rEqOyKD7zQ',
#    'alias': 'dominique-ansel-workshop-new-york',
#    'name': 'Dominique Ansel Workshop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LWH8FfCgBGTQFQ0GEKY5yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dominique-ansel-workshop-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74368, 'longitude': -73.98658},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '17 E 27th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 E 27th St', 'New York, NY 10016']},
#    'phone': '+12129011015',
#    'display_phone': '(212) 901-1015',
#    'distance': 4311.226067535746},
#   {'id': 'iks1xNyp-uZnaeunOM2UPg',
#    'alias': 'magnolia-bakery-rockefeller-center-new-york',
#    'name': 'Magnolia Bakery Rockefeller Center',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fSq3zjaIlaxP6nRZ85liKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/magnolia-bakery-rockefeller-center-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2590,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7592651914885,
#     'longitude': -73.980564548757},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1240 Ave of the Americas',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10020',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1240 Ave of the Americas', 'New York, NY 10020']},
#    'phone': '+12127671123',
#    'display_phone': '(212) 767-1123',
#    'distance': 6095.313685956134},
#   {'id': 'DA1hijID0q6D6Ouch17v7w',
#    'alias': 'pecks-new-york',
#    'name': "Peck's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/H_hr9SJgmj0fOZZIdYCDQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pecks-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 150,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.693489, 'longitude': -73.967376},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '455A Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['455A Myrtle Ave', 'New York, NY 11205']},
#    'phone': '+13476894969',
#    'display_phone': '(347) 689-4969',
#    'distance': 2638.841789597834},
#   {'id': 'qpj8kc8y3SgLA6GWkVgX3g',
#    'alias': 'partybus-bakeshop-new-york',
#    'name': 'Partybus Bakeshop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Aq7jHpehVIB9vDKSedQMdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/partybus-bakeshop-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.715981, 'longitude': -73.989862},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '31 Essex St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31 Essex St', 'New York, NY 10002']},
#    'phone': '+19172620732',
#    'display_phone': '(917) 262-0732',
#    'distance': 1227.979181826809},
#   {'id': 'PKa6XxkvMTVD5gaDbMznNg',
#    'alias': 'buttermilk-bakeshop-brooklyn',
#    'name': 'Buttermilk Bakeshop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uIIeptqnF0XqPvcXGF8xcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/buttermilk-bakeshop-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 312,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67491, 'longitude': -73.98171},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '260 5th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['260 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+13479873941',
#    'display_phone': '(347) 987-3941',
#    'distance': 3550.3196531083413},
#   {'id': '26TL7d7o1lVvTwRLKj8Bsg',
#    'alias': 'twister-cake-bakery-new-york-3',
#    'name': 'Twister Cake Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ScEEaJCQQK_MvHmnae9W-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/twister-cake-bakery-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'chimneycakes', 'title': 'Chimney Cakes'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7581423, 'longitude': -73.9792983},
#    'transactions': ['delivery'],
#    'location': {'address1': '10 Rockefeller Plz',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10020',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10 Rockefeller Plz', 'New York, NY 10020']},
#    'phone': '+13479462141',
#    'display_phone': '(347) 946-2141',
#    'distance': 5994.350170027817},
#   {'id': 'uYMimeHJ5XBGkyTrg8GXhw',
#    'alias': 'joey-bats-café-new-york',
#    'name': 'Joey Bats Café',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Z1P5LXx2wxymTkN8Ym9QgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joey-bats-caf%C3%A9-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 318,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'portuguese', 'title': 'Portuguese'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72006, 'longitude': -73.99037},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '129 Allen St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['129 Allen St', 'New York, NY 10002']},
#    'phone': '+12129511189',
#    'display_phone': '(212) 951-1189',
#    'distance': 1658.9638318560021},
#   {'id': 'yicBRA8X7urJyKn6aF2wzw',
#    'alias': 'sullivan-street-bakery-new-york-4',
#    'name': 'Sullivan Street Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/C5EOOhqnVAhEA9ay3zwXUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sullivan-street-bakery-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 282,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7474103457198,
#     'longitude': -74.0005904621599},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '236 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['236 9th Ave', 'New York, NY 10001']},
#    'phone': '+12129295900',
#    'display_phone': '(212) 929-5900',
#    'distance': 4684.439691978602},
#   {'id': 'meVzfRH_wLAJjcrCAhkh1g',
#    'alias': 'patisserie-chanson-new-york-3',
#    'name': 'Patisserie Chanson',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IlMGWhx6FH4s1FL5Xiq0XQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-chanson-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 444,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7417, 'longitude': -73.990571},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '20 W 23rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['20 W 23rd St', 'New York, NY 10010']},
#    'phone': '+19294238880',
#    'display_phone': '(929) 423-8880',
#    'distance': 4045.2541988512426},
#   {'id': 'leI3BslJ5I2-IxXyRaRjPw',
#    'alias': 'cafe-d-avignon-essex-market-new-york',
#    'name': 'Cafe d’Avignon - Essex Market',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/W-8K5W6J3gUu6YdfAMcJmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-d-avignon-essex-market-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 96,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71792, 'longitude': -73.988317},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '88 Essex St',
#     'address2': '',
#     'address3': 'Essex Street Market',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['88 Essex St',
#      'Essex Street Market',
#      'New York, NY 10002']},
#    'phone': '+19172612092',
#    'display_phone': '(917) 261-2092',
#    'distance': 1475.7930084537218},
#   {'id': '6q6WWGaO75PQkpWOQ2zzHQ',
#    'alias': 'parisi-bakery-new-york-4',
#    'name': 'Parisi Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9P2czBcU6yl8-wgPygmCgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/parisi-bakery-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 427,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7211836, 'longitude': -73.9954365},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '198 Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['198 Mott St', 'New York, NY 10012']},
#    'phone': '+12122266378',
#    'display_phone': '(212) 226-6378',
#    'distance': 1742.4460459404133},
#   {'id': 's_YuHngBngWwzpcKNIM71A',
#    'alias': 'pi-bakerie-new-york-2',
#    'name': 'Pi Bakerie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/z3XmLECFFhL2wstbpGz7Sg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pi-bakerie-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 293,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72361, 'longitude': -74.00329},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '512 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['512 Broome St', 'New York, NY 10013']},
#    'phone': '+12122262701',
#    'display_phone': '(212) 226-2701',
#    'distance': 2162.699623969127},
#   {'id': 'bvc5P9vmRiNhyVWjd5bVcg',
#    'alias': 'eclair-bakery-new-york',
#    'name': 'Eclair Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qjM8dIvuUOCIGnnet6R_5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eclair-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 649,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'macarons', 'title': 'Macarons'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.756689, 'longitude': -73.966617},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '305 E 53rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['305 E 53rd St', 'New York, NY 10022']},
#    'phone': '+16464298555',
#    'display_phone': '(646) 429-8555',
#    'distance': 6156.82625750047},
#   {'id': 'MKYhiSeXjahxh9O4Gqnimw',
#    'alias': 'grace-street-new-york',
#    'name': 'Grace Street',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sGpzBlU62QQfT9H1Z-yzvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grace-street-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2742,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'shavedice', 'title': 'Shaved Ice'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7478576793883,
#     'longitude': -73.9865590631962},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '17 W 32nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 W 32nd St', 'New York, NY 10001']},
#    'phone': '+19177452125',
#    'display_phone': '(917) 745-2125',
#    'distance': 4760.904253854418},
#   {'id': 'J-jHnvA_D99YqaJAW6IM9w',
#    'alias': 'le-french-tart-deli-brooklyn-2',
#    'name': 'Le French Tart Deli',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iquUiJaQTbJZ4s22GPU0bA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-french-tart-deli-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69967, 'longitude': -73.99207},
#    'transactions': [],
#    'location': {'address1': '44 Henry St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['44 Henry St', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 664.8406354338085},
#   {'id': 'Wv6jzavopKvQT7RqeXttKA',
#    'alias': 'le-petit-monstre-brooklyn',
#    'name': 'Le Petit Monstre',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NtqFfVROVxVmJN8k-hVcYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-petit-monstre-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'gardening', 'title': 'Nurseries & Gardening'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.696311154904876,
#     'longitude': -73.96770130204715},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '82 Washington Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['82 Washington Ave', 'Brooklyn, NY 11205']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2461.0231986129706},
#   {'id': 'h7M1s9arHO5dcMf-XxzOLA',
#    'alias': 'ebb-and-flow-bakery-brooklyn',
#    'name': 'Ebb & Flow Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cp6O1BykYWqCjtlR_Kg2mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ebb-and-flow-bakery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69385416250277,
#     'longitude': -74.00085359915278},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '159 Bridge Dr',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['159 Bridge Dr', 'Brooklyn, NY 11201']},
#    'phone': '+17186189775',
#    'display_phone': '(718) 618-9775',
#    'distance': 1402.4740362013142},
#   {'id': 'MejD0KdN4LLbzwpHjBAL0Q',
#    'alias': 'crispy-heaven-bakery-new-york',
#    'name': 'Crispy Heaven Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HJIplB9wZJhH2ixEsuMs9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crispy-heaven-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7227, 'longitude': -74.0042},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '38 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38 Grand St', 'New York, NY 10013']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2095.100507505705},
#   {'id': 'YnPNXJvUsn2jymwBeLpQ4g',
#    'alias': 'mille-feuille-bakery-brooklyn',
#    'name': 'Mille-Feuille Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/43_dAxxNou8ziZgrwSiV0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mille-feuille-bakery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 79,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cookingclasses', 'title': 'Cooking Classes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.677621, 'longitude': -73.96912},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '622 Vanderbilt Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['622 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#    'phone': '+13473508838',
#    'display_phone': '(347) 350-8838',
#    'distance': 3751.8729863207573},
#   {'id': 'vijwGDNrPBJHEG7_DsjZNw',
#    'alias': 'usagi-ny-dumbo-7',
#    'name': 'Usagi NY',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6yNqnkPDJAZXpMemwCYN3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/usagi-ny-dumbo-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'bookstores', 'title': 'Bookstores'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'homedecor', 'title': 'Home Decor'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70383, 'longitude': -73.98691},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '163 Plymouth St',
#     'address2': '',
#     'address3': '',
#     'city': 'Dumbo',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['163 Plymouth St', 'Dumbo, NY 11201']},
#    'phone': '+17188018037',
#    'display_phone': '(718) 801-8037',
#    'distance': 635.7818631527628},
#   {'id': 'DE0ROwygh-86i4s-WLp8wQ',
#    'alias': 'maman-soho-new-york',
#    'name': 'Maman Soho',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nUj5B96Xh73Y2aGmuvDr6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maman-soho-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 577,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72028, 'longitude': -73.9984},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '239 Centre St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['239 Centre St', 'New York, NY 10013']},
#    'phone': '+12122260700',
#    'display_phone': '(212) 226-0700',
#    'distance': 1685.4911071554986},
#   {'id': 'fvDZVAvv_g4L-WWkbDpCXg',
#    'alias': 'patisserie-claude-new-york',
#    'name': 'Patisserie Claude',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pbL_trMOpVtW_rzGn0qPeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-claude-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 257,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7327402, 'longitude': -74.0018208},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '187 W 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['187 W 4th St', 'New York, NY 10014']},
#    'phone': '+12122555911',
#    'display_phone': '(212) 255-5911',
#    'distance': 3094.0515887033007},
#   {'id': '0uyNyorc1m-W0R4zd-wvhQ',
#    'alias': 'beard-papas-new-york-2',
#    'name': "Beard Papa's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gvSbjdOYwgW92312czEESw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beard-papas-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 135,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75714, 'longitude': -73.96782},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '239 E 53rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['239 E 53rd St', 'New York, NY 10022']},
#    'phone': '+12129356308',
#    'display_phone': '(212) 935-6308',
#    'distance': 6173.258261096518},
#   {'id': 'Yx6xDJBEmC8oTAmIEzDRag',
#    'alias': 'tous-les-jours-new-york-4',
#    'name': 'Tous Les Jours',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/b4CCJkf-9RZtvH-BpbMb7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tous-les-jours-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 794,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7479385, 'longitude': -73.9870117},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '31 West 32nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31 West 32nd St', 'New York, NY 10001']},
#    'phone': '+12129679661',
#    'display_phone': '(212) 967-9661',
#    'distance': 4764.181385913695},
#   {'id': 'nU4XBdvxDABXqZ6CnB8Dig',
#    'alias': 'clinton-street-baking-company-new-york-5',
#    'name': 'Clinton Street Baking Company',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DWHdizJ9bKbXN4yq6nbwAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clinton-street-baking-company-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5276,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.721128, 'longitude': -73.983933},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4 Clinton St', 'New York, NY 10002']},
#    'phone': '+16466026263',
#    'display_phone': '(646) 602-6263',
#    'distance': 1950.282829638887},
#   {'id': 'I41VRmgmiQ4kITgFZtJlvQ',
#    'alias': 'old-poland-bakery-brooklyn-2',
#    'name': 'Old Poland Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/siXMguqT0CH7vYT1ouoRDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/old-poland-bakery-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.731071, 'longitude': -73.9542397},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '926 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['926 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4416.609623364894},
#   {'id': 'N7ux8gAg5udFTgZ2Y5P-6A',
#    'alias': 'ceci-cela-new-york-2',
#    'name': 'Ceci-Cela',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/v4ZxqpyctSZ0NLl-ExfuQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ceci-cela-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 577,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7202848335508,
#     'longitude': -73.993055798842},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '14 Delancey St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 Delancey St', 'New York, NY 10012']},
#    'phone': '+12122749179',
#    'display_phone': '(212) 274-9179',
#    'distance': 1653.420076703117},
#   {'id': 'wQLNq8dQE4DxvUSQwzAagw',
#    'alias': 'city-cakes-new-york',
#    'name': 'City Cakes',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/siQIY8Oo7d7-jPzNTE2IVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/city-cakes-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 791,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74078, 'longitude': -73.99695},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '155 W 18th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['155 W 18th St', 'New York, NY 10011']},
#    'phone': '+16466882286',
#    'display_phone': '(646) 688-2286',
#    'distance': 3945.007250227327},
#   {'id': 'lDW4DlTZYcSP9T1yQY5HKg',
#    'alias': 'ferrara-bakery-and-cafe-new-york',
#    'name': 'Ferrara Bakery & Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bmJabXEt4mcL99W8PFXi5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ferrara-bakery-and-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1616,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'gelato', 'title': 'Gelato'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.719079, 'longitude': -73.997086},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '195 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['195 Grand St', 'New York, NY 10013']},
#    'phone': '+12122266150',
#    'display_phone': '(212) 226-6150',
#    'distance': 1534.210249658016},
#   {'id': 'pNbrxyrG5d5QwRsKbu0cXg',
#    'alias': '46-new-york',
#    'name': '46',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PDgpYA8dbkA2x4Cc3kGklg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/46-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7152930293439,
#     'longitude': -73.9986442157158},
#    'transactions': ['delivery'],
#    'location': {'address1': '46 Mott St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['46 Mott St', 'New York, NY 10013']},
#    'phone': '+16467156699',
#    'display_phone': '(646) 715-6699',
#    'distance': 1154.8425931908018},
#   {'id': 'Pa9ot06iF3b_DGWLyotZkQ',
#    'alias': 'luckybird-cakes-brooklyn',
#    'name': 'Luckybird Cakes',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/J9HzXoqnVZ-pCi4y6Sk1aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luckybird-cakes-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 94,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7076263427734,
#     'longitude': -73.9427032470703},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '163 Montrose Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['163 Montrose Ave', 'Brooklyn, NY 11206']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4354.249793997423},
#   {'id': 'p-mqsZI4eENIVxq1ziSEag',
#    'alias': 'the-love-bakery-new-york-5',
#    'name': 'The Love Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zKF2BfG2NwA1HOHql6S5iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-love-bakery-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72072150000102,
#     'longitude': -73.98789715276054},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '150 Ludlow St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 Ludlow St', 'New York, NY 10002']},
#    'phone': '+19142025409',
#    'display_phone': '(914) 202-5409',
#    'distance': 1782.1716139558314},
#   {'id': 'PDLYcA21uXCAlqRAkQLNNw',
#    'alias': 'ovenly-brooklyn',
#    'name': 'Ovenly',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/92S_XV7GShkVWM72gvx-Bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ovenly-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 211,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729904, 'longitude': -73.959579},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '31 Greenpoint Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31 Greenpoint Ave', 'Brooklyn, NY 11222']},
#    'phone': '+18888992213',
#    'display_phone': '(888) 899-2213',
#    'distance': 3991.6091247453433},
#   {'id': '-JQavt5ZBdpUH_y7tMWFvw',
#    'alias': 'harbs-chelsea-new-york-2',
#    'name': 'HARBS Chelsea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-3OMKpAbkGssnQPhUzx78Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harbs-chelsea-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 551,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.745849, 'longitude': -74.0015476},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '198 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['198 9th Ave', 'New York, NY 10011']},
#    'phone': '+16463366888',
#    'display_phone': '(646) 336-6888',
#    'distance': 4534.129061457494},
#   {'id': 'M-1k30Dgcc1OxZ8buddE4Q',
#    'alias': 'harbs-soho-new-york-3',
#    'name': 'HARBS SoHo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DE8GF-q9Skq_iRkh_oiRVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harbs-soho-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 147,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.726366, 'longitude': -74.000015},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '465 W Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['465 W Broadway', 'New York, NY 10012']},
#    'phone': '+12124731981',
#    'display_phone': '(212) 473-1981',
#    'distance': 2375.550309555605},
#   {'id': 'DOSNJk1qfKITbox4defOBw',
#    'alias': 'carlos-bakery-hoboken-9',
#    'name': "Carlo's Bakery",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LPOXChQ4qoub9fGR0kHvUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carlos-bakery-hoboken-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1408,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7372037883636,
#     'longitude': -74.031268176657},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '95 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['95 Washington St', 'Hoboken, NJ 07030']},
#    'phone': '+12016593671',
#    'display_phone': '(201) 659-3671',
#    'distance': 4709.619739464844},
#   {'id': 'yaBrQbt7kMrbXAo6qrzpYw',
#    'alias': 'by-the-way-bakery-new-york',
#    'name': 'By the Way Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iioE0AdgUvuhNdogk04M6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/by-the-way-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 244,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7910023, 'longitude': -73.9742942},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '2442 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2442 Broadway', 'New York, NY 10024']},
#    'phone': '+12128770806',
#    'display_phone': '(212) 877-0806',
#    'distance': 9661.559070639432},
#   {'id': 'tJY11BoV6Epe2MmV6o7L9w',
#    'alias': 'the-dough-club-new-york',
#    'name': 'The Dough Club',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0Pz682B5ENshaANmNKmKbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dough-club-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 352,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.717937, 'longitude': -73.99891233660313},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '119 Baxter St',
#     'address2': 'Ste A',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['119 Baxter St', 'Ste A', 'New York, NY 10013']},
#    'phone': '+16469186090',
#    'display_phone': '(646) 918-6090',
#    'distance': 1442.5894716160906},
#   {'id': 'aiELyvL3nWrI8WJb2lUniw',
#    'alias': 'padoca-bakery-new-york',
#    'name': 'Padoca Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LYb3nd7-9bDy3Ww0ihfmgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/padoca-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 296,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7662, 'longitude': -73.96228},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '210 E. 67th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['210 E. 67th St', 'New York, NY 10065']},
#    'phone': '+17184408671',
#    'display_phone': '(718) 440-8671',
#    'distance': 7262.8482051472065}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                     Restaurant          Type Price Rating           Address  \
# 0          Brooklyn Sweet Spot      Bakeries    $$      4    366 Myrtle Ave
# 1                  Butter Lane      Bakeries     $      4      123 E 7th St
# 2         Ella Crown Bakehouse      Bakeries               149 Atlantic Ave
# 3         Mille-Feuille Bakery  Coffee & Tea    $$    4.5     2175 Broadway
# 4  Sugar Sweet Sunshine Bakery      Bakeries     $      4  126 Rivington St
#
#          Lat        Lng                                                url  \
# 0  40.693026 -73.971547  https://www.yelp.com/biz/brooklyn-sweet-spot-b...
# 1  40.726494 -73.984149  https://www.yelp.com/biz/butter-lane-new-york?...
# 2  40.690691 -73.995072
# 3  40.782425 -73.981160  https://www.yelp.com/biz/mille-feuille-bakery-...
# 4  40.719851 -73.987011  https://www.yelp.com/biz/sugar-sweet-sunshine-...
#
#                        ID
# 0  SjNNOP3KKHayd_BpatGmwQ
# 1  qMr-lz0G0vyz2r4mJJQxmA
# 2
# 3  fPQ2eE9lm8tc87O5-GLjyA
# 4  qVSOes5JoWc5_umv4nd4Hg

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"bakery","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': 'PJfXA2NFkwyDY9a14qYthw',
#    'alias': 'taste-crème-long-island-city-2',
#    'name': 'Taste Crème',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Z8MgPtOkHvNw9cZsHgZ0rQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taste-cr%C3%A8me-long-island-city-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 147,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.744347, 'longitude': -73.9495349},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '13-11 Jackson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['13-11 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+19292600856',
#    'display_phone': '(929) 260-0856',
#    'distance': 5739.150522547548},
#   {'id': 'Hk6yiiuk9lMFV1QilkYKYA',
#    'alias': 'sullivan-street-bakery-new-york-6',
#    'name': 'Sullivan Street Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FYsBKTxNSRvmv1iwsOoVGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sullivan-street-bakery-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72562430385372,
#     'longitude': -74.00281930212823},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '103 Sullivan St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 Sullivan St', 'New York, NY 10012']},
#    'phone': '+19173882900',
#    'display_phone': '(917) 388-2900',
#    'distance': 2356.103639581212},
#   {'id': '2coj9-JUozEYyPyUDTkCoA',
#    'alias': 'damascus-bread-and-pastry-shop-brooklyn',
#    'name': 'Damascus Bread & Pastry Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MMjtF6Ncz84rzqmUECVaGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/damascus-bread-and-pastry-shop-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 268,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69005, 'longitude': -73.99307},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '195 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['195 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17186257070',
#    'display_phone': '(718) 625-7070',
#    'distance': 1712.1146932751706},
#   {'id': 'FjI6SFjwhdTWQvZ6jWgkeA',
#    'alias': 'the-dough-club-williamsburg-new-york-4',
#    'name': 'The Dough Club - Williamsburg',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/u2edFxMddEh8h3ROMfni3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dough-club-williamsburg-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71438418201451,
#     'longitude': -73.96152183446654},
#    'transactions': ['delivery'],
#    'location': {'address1': '294 Bedford Ave',
#     'address2': '',
#     'address3': 'Taiyaki NYC',
#     'city': 'New York',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['294 Bedford Ave',
#      'Taiyaki NYC',
#      'New York, NY 11249']},
#    'phone': '+19179091856',
#    'display_phone': '(917) 909-1856',
#    'distance': 2935.6417556500833},
#   {'id': 'UsDeDLDJzYp91t6akkueqw',
#    'alias': 'lassen-and-hennigs-brooklyn',
#    'name': 'Lassen & Hennigs',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IO8Wqp1VbYcWebDJB8wrrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lassen-and-hennigs-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 193,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69484, 'longitude': -73.9949},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '114 Montague St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['114 Montague St', 'Brooklyn, NY 11201']},
#    'phone': '+17188756272',
#    'display_phone': '(718) 875-6272',
#    'distance': 1185.6209412126627},
#   {'id': 'cJBLw_FfD9w_X2XZS3TqIg',
#    'alias': 'brigadeiro-bakery-new-york-3',
#    'name': 'Brigadeiro Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2Zx6HT0Bs0OgOvjnetA22g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brigadeiro-bakery-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 127,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7274461088028,
#     'longitude': -74.0016795987419},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '156 Sullivan St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156 Sullivan St', 'New York, NY 10012']},
#    'phone': '+19177405772',
#    'display_phone': '(917) 740-5772',
#    'distance': 2524.386151183599},
#   {'id': 'KEyhIMAUpj7cceOvG9C1sA',
#    'alias': 'kabisera-new-york-4',
#    'name': 'Kabisera',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eZtLR5F-zklfBWEJyycuTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kabisera-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 101,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'filipino', 'title': 'Filipino'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.720907, 'longitude': -73.989913},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '151 Allen St',
#     'address2': '',
#     'address3': 'Store South',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['151 Allen St', 'Store South', 'New York, NY 10002']},
#    'phone': '+19292073729',
#    'display_phone': '(929) 207-3729',
#    'distance': 1759.6506732063558},
#   {'id': 'm8UUM6DjMgXtH_qKzo9LBA',
#    'alias': 'golden-steamer-new-york',
#    'name': 'Golden Steamer',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/shG2onzLfryYzgsFEcwy5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/golden-steamer-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 367,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71877, 'longitude': -73.99679},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '143-A Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['143-A Mott St', 'New York, NY 10013']},
#    'phone': '+12122261886',
#    'display_phone': '(212) 226-1886',
#    'distance': 1496.7338078628518},
#   {'id': 'XEdGYktN7VVuyjkN5ukr4A',
#    'alias': 'bright-side-brooklyn-3',
#    'name': 'Bright Side',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cSx5LjCIO0G3XipfmnXqUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bright-side-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7187096995697,
#     'longitude': -73.9640169072708},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '184 Kent Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['184 Kent Ave', 'Brooklyn, NY 11249']},
#    'phone': '+19292763577',
#    'display_phone': '(929) 276-3577',
#    'distance': 2947.45577986316},
#   {'id': '_4UvguU5z2hMsHXlYedFXw',
#    'alias': 'tao-hong-bakery-new-york',
#    'name': 'Tao Hong Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KB5N-p_TzBh6yOLeAfMddg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tao-hong-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71735, 'longitude': -73.9945679},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '79 Chrystie St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79 Chrystie St', 'New York, NY 10002']},
#    'phone': '+12122190981',
#    'display_phone': '(212) 219-0981',
#    'distance': 1317.382315428026},
#   {'id': 'wMYocgxx-pPbFFYPFYND5g',
#    'alias': 'one-girl-cookies-brooklyn-3',
#    'name': 'One Girl Cookies',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nI2d91ghceukOS2C_0ooBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/one-girl-cookies-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 261,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.703327, 'longitude': -73.990368},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '33 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33 Main St', 'Brooklyn, NY 11201']},
#    'phone': '+12126754996',
#    'display_phone': '(212) 675-4996',
#    'distance': 406.1244543626289},
#   {'id': '4GBqDgTYsV7owGzNMyAFKA',
#    'alias': 'sullivan-street-bakery-new-york-3',
#    'name': 'Sullivan Street Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9IqTUcD62P3ziCRpCel3dA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sullivan-street-bakery-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 522,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76366, 'longitude': -73.994716},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '533 W 47th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['533 W 47th St', 'New York, NY 10036']},
#    'phone': '+12122655580',
#    'display_phone': '(212) 265-5580',
#    'distance': 6473.318564773586},
#   {'id': 'yr-X-bhRgh5XMolmM2WAiw',
#    'alias': 'funny-face-bakery-new-york-2',
#    'name': 'Funny Face Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/N53TRKB9sdj-0koqbojheA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/funny-face-bakery-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 312,
#    'categories': [{'alias': 'cupcakes', 'title': 'Cupcakes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70649, 'longitude': -74.00354},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '6 Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6 Fulton St', 'New York, NY 10038']},
#    'phone': '+16468611274',
#    'display_phone': '(646) 861-1274',
#    'distance': 788.2051777496248},
#   {'id': 'wIj-js49hM9rW_I7A4i-vQ',
#    'alias': 'laperi-bakery-new-york-2',
#    'name': 'Laperi Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4wOFc4ZM4scO8AUBnrsQkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laperi-bakery-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'turkish', 'title': 'Turkish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.737343, 'longitude': -73.997496},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '104 West 14th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['104 West 14th St', 'New York, NY 10011']},
#    'phone': '+16465854515',
#    'display_phone': '(646) 585-4515',
#    'distance': 3555.9003992529006},
#   {'id': 'lWOkeS-wV4no8qqA9OwwEg',
#    'alias': 'doughnut-plant-new-york-6',
#    'name': 'Doughnut Plant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hLWKXsLv6hyltNSilBy8-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doughnut-plant-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3273,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.716334, 'longitude': -73.988652},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '379 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['379 Grand St', 'New York, NY 10002']},
#    'phone': '+12125053700',
#    'display_phone': '(212) 505-3700',
#    'distance': 1300.8284914110848},
#   {'id': 'LXxYiSqSereUtkY6EDEnHQ',
#    'alias': 'silver-moon-bakery-new-york',
#    'name': 'Silver Moon Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Wd9O6qyj73JR1bOiZs_W1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/silver-moon-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 439,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.80053, 'longitude': -73.9676999},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2740 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2740 Broadway', 'New York, NY 10025']},
#    'phone': '+12128664717',
#    'display_phone': '(212) 866-4717',
#    'distance': 10806.845906248729},
#   {'id': 'RHz7OAoy5yMNWBcLArgLrQ',
#    'alias': 'sweets-bakery-new-york',
#    'name': 'Sweets Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/V3-BCTHX5M452uLqN9rX_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweets-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 82,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.717286, 'longitude': -73.9996625},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '135 Walker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['135 Walker St', 'New York, NY 10013']},
#    'phone': '+12122192012',
#    'display_phone': '(212) 219-2012',
#    'distance': 1392.2768502710003},
#   {'id': 't4M1VX4n34eEgUWMJ7cgKw',
#    'alias': 'daily-provisions-new-york',
#    'name': 'Daily Provisions',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KOSmplXpEbiCLdRnRBkcTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daily-provisions-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 471,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73768, 'longitude': -73.9876685},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '103 E 19th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 E 19th St', 'New York, NY 10003']},
#    'phone': '+12124881505',
#    'display_phone': '(212) 488-1505',
#    'distance': 3624.11900652027},
#   {'id': 'XBWO26QblInZGftnSDD94A',
#    'alias': 'maman-tribeca-new-york-2',
#    'name': 'Maman Tribeca',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OSqmQbY7pfGTYYSOOz7kxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maman-tribeca-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 279,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7188969, 'longitude': -74.0062207},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '211 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['211 W Broadway', 'New York, NY 10013']},
#    'phone': '+16468828682',
#    'display_phone': '(646) 882-8682',
#    'distance': 1802.2364781853016},
#   {'id': 'U5hCNNyJmb7f3dmC1HTzSQ',
#    'alias': 'juniors-restaurant-and-bakery-45th-st-new-york',
#    'name': "Junior's Restaurant & Bakery - 45th St",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RwLK04cnu1y4t8xPRY3mwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/juniors-restaurant-and-bakery-45th-st-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4735,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75754564001459,
#     'longitude': -73.98608001118411},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1515 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1515 Broadway', 'New York, NY 10036']},
#    'phone': '+12123022000',
#    'display_phone': '(212) 302-2000',
#    'distance': 5834.523948198199},
#   {'id': 'c6UUcUTbwbk0kOpF6jVOJQ',
#    'alias': 'the-doughnut-project-new-york',
#    'name': 'The Doughnut Project',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TsRkIkazmTpT_HZ6zaia0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-doughnut-project-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 520,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.731151, 'longitude': -74.003547},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '10 Morton St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10 Morton St', 'New York, NY 10014']},
#    'phone': '+12126915000',
#    'display_phone': '(212) 691-5000',
#    'distance': 2964.428663792995},
#   {'id': 'xKgh4ZcjY5fTmXTvYVrsbw',
#    'alias': 'cafe-belle-new-york',
#    'name': 'Cafe Belle',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1Ua1nwj1YCZmprX8q8QGDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-belle-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72437, 'longitude': -73.99509},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '280 Mulberry St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['280 Mulberry St', 'New York, NY 10012']},
#    'phone': '+12128371605',
#    'display_phone': '(212) 837-1605',
#    'distance': 2103.4737670809786},
#   {'id': 'ury76z-6Cgjn7965pJhlLQ',
#    'alias': 'ovenly-brooklyn-9',
#    'name': 'Ovenly',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pURYXkVtX-WI4bEzpT_8Eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ovenly-brooklyn-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71909, 'longitude': -73.96247},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '43 N 5th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43 N 5th St', 'Brooklyn, NY 11249']},
#    'phone': '+18888992213',
#    'display_phone': '(888) 899-2213',
#    'distance': 3082.161925796781},
#   {'id': 'GVGhfMMEw2TrDh-GGVTUmA',
#    'alias': 'le-french-tart-deli-new-york',
#    'name': 'Le French Tart Deli',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ncPhQvoYvsyiMga5TTrLPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-french-tart-deli-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'macarons', 'title': 'Macarons'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.683691, 'longitude': -73.995502},
#    'transactions': ['delivery'],
#    'location': {'address1': '306 Court St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['306 Court St', 'New York, NY 11231']},
#    'phone': '+13479160014',
#    'display_phone': '(347) 916-0014',
#    'distance': 2418.167362234124},
#   {'id': 'OsVrO0NH1XTewdbkfWzTbw',
#    'alias': 'vesuvio-bakery-new-york-7',
#    'name': 'Vesuvio Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DJqXYjlIwEQlj11FsMBw-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vesuvio-bakery-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 256,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72596, 'longitude': -74.00143},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '160 Prince St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['160 Prince St', 'New York, NY 10012']},
#    'phone': '+16468690090',
#    'display_phone': '(646) 869-0090',
#    'distance': 2356.1239629126962},
#   {'id': 'gXz2MvC4637r2rg5YVO2tw',
#    'alias': 'big-booty-bread-new-york',
#    'name': 'Big Booty Bread',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Av4z17ymFhVgE8YCGRynkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/big-booty-bread-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 327,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.745115, 'longitude': -73.9977148},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '261 W 23rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['261 W 23rd St', 'New York, NY 10011']},
#    'phone': '+12124143056',
#    'display_phone': '(212) 414-3056',
#    'distance': 4419.038186328543},
#   {'id': 'zi_TJRxi0WzADbbI6Jcz3A',
#    'alias': 'koneko-new-york-3',
#    'name': 'Koneko',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WZcJF6gmjNHO6TYv9KOfNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/koneko-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 300,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'themedcafes', 'title': 'Themed Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72044, 'longitude': -73.98412},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '26 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 Clinton St', 'New York, NY 10002']},
#    'phone': '+16463705699',
#    'display_phone': '(646) 370-5699',
#    'distance': 1874.6275271483207},
#   {'id': 'KWC_KYP336tSFhAihd8plg',
#    'alias': 'bluestone-lane-dumbo-café-brooklyn',
#    'name': 'Bluestone Lane DUMBO Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AjXvAC5Y5Blhi2a5XxpmIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bluestone-lane-dumbo-caf%C3%A9-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 196,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70077577888819,
#     'longitude': -73.98836356287899},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '55 Prospect St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Prospect St', 'Brooklyn, NY 11201']},
#    'phone': '+17183746858',
#    'display_phone': '(718) 374-6858',
#    'distance': 720.6910385584724},
#   {'id': 'nqJXUlVn1cZmWQfjYvYRpA',
#    'alias': 'soma-cakes-nyc-new-york-4',
#    'name': 'Soma cakes NYC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/52YHKmZdft-T52EyrR5few/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soma-cakes-nyc-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'customcakes', 'title': 'Custom Cakes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72599803571189,
#     'longitude': -73.97853506804728},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '380 E 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['380 E 10th St', 'New York, NY 10009']},
#    'phone': '+12123881801',
#    'display_phone': '(212) 388-1801',
#    'distance': 2643.283792797021},
#   {'id': 'oxcVXXxS6cS0xoE5XtqHeQ',
#    'alias': 'tadaima-brooklyn',
#    'name': 'Tadaima',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/R0P5cymwQaMOxDFZps2cSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tadaima-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.656024, 'longitude': -74.006553},
#    'transactions': [],
#    'location': {'address1': '934 3rd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11232',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['934 3rd Ave', 'Brooklyn, NY 11232']},
#    'phone': '+13475844579',
#    'display_phone': '(347) 584-4579',
#    'distance': 5590.552705441527},
#   {'id': 'ky3c5RRlyO0tQQS33sO9RQ',
#    'alias': 'new-golden-fung-wong-bakery-new-york',
#    'name': 'New Golden Fung Wong Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7zP1jYJ5IBAMUbLgVZydTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-golden-fung-wong-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 94,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71517, 'longitude': -73.99903},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '41 Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41 Mott St', 'New York, NY 10013']},
#    'phone': '+19178165820',
#    'display_phone': '(917) 816-5820',
#    'distance': 1149.8599984264372},
#   {'id': 'mIhqKMgru4002wfrVW-Gfw',
#    'alias': 'chikalicious-dessert-bar-new-york-3',
#    'name': 'ChikaLicious Dessert Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Pd-rhbnq6CvQ6TH9zi6o1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chikalicious-dessert-bar-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1346,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72964636531206,
#     'longitude': -73.98620154365136},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '203 E 10th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['203 E 10th St', 'New York, NY 10003']},
#    'phone': '+12129959511',
#    'display_phone': '(212) 995-9511',
#    'distance': 2776.1443252783456},
#   {'id': 'z5IMh69DbE7TJ5LFhw_qvQ',
#    'alias': 'cafe-ubani-new-york',
#    'name': 'Cafe Ubani',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bTVIdN6s0dRFmcOFMkiNUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-ubani-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.73005, 'longitude': -74.00417},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '37A Bedford St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37A Bedford St', 'New York, NY 10014']},
#    'phone': '+16466785595',
#    'display_phone': '(646) 678-5595',
#    'distance': 2811.9960172923793},
#   {'id': 'aSDGr4NIfm1C6IspWSNaQw',
#    'alias': 'orwashers-new-york',
#    'name': 'Orwashers',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/F6VeUHed2qVjpTUIaT3WgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/orwashers-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 462,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.772191, 'longitude': -73.95505},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '308 E 78th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['308 E 78th St', 'New York, NY 10075']},
#    'phone': '+12122886569',
#    'display_phone': '(212) 288-6569',
#    'distance': 8124.619987999245},
#   {'id': 'hw9FyXzf67gZG33fUp5ySw',
#    'alias': 'confectionery-new-york',
#    'name': 'Confectionery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qrtqmo4guGw965yBBbzXgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/confectionery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 142,
#    'categories': [{'alias': 'chocolate', 'title': 'Chocolatiers & Shops'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72732, 'longitude': -73.98305},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '440 E 9th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['440 E 9th St', 'New York, NY 10009']},
#    'phone': '+16468690133',
#    'display_phone': '(646) 869-0133',
#    'distance': 2607.2802684367125},
#   {'id': 'G8uQtDQ53aBIwNff1k0wgA',
#    'alias': 'kam-hing-bakery-new-york',
#    'name': 'Kam Hing Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-ZTt0em21qxSJKR-TY1CBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kam-hing-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71558, 'longitude': -73.99887},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '81 Bayard St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81 Bayard St', 'New York, NY 10013']},
#    'phone': '+17189616177',
#    'display_phone': '(718) 961-6177',
#    'distance': 1194.7853337169952},
#   {'id': 'NkOpM1SBI50qviqE6LCKRg',
#    'alias': 'the-little-one-new-york',
#    'name': 'The Little One',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zMTtT-TkGnyt-VSvFja4Rg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-little-one-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 247,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'shavedice', 'title': 'Shaved Ice'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.714158, 'longitude': -73.990942},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '150 E Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 E Broadway', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1010.3434362978925},
#   {'id': 'LyWjwCnRzv2CZzPHuUpAsg',
#    'alias': 'the-evercake-new-york',
#    'name': 'The Evercake',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BMDJPhZ5jeA_M_RGq3sIDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-evercake-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 56,
#    'categories': [{'alias': 'customcakes', 'title': 'Custom Cakes'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.768775939941406,
#     'longitude': -73.95834350585938},
#    'transactions': [],
#    'location': {'address1': None,
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['New York, NY 10021']},
#    'phone': '+12015891164',
#    'display_phone': '(201) 589-1164',
#    'distance': 7808.730506514465},
#   {'id': 'vk6L5A4OaBmdvgpB_bWDhw',
#    'alias': 'oxa-house-coffee-and-tea-new-york-3',
#    'name': 'OXA House Coffee & Tea ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tm3AbhsX-toc1FL160QZzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oxa-house-coffee-and-tea-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7103, 'longitude': -73.96513},
#    'transactions': [],
#    'location': {'address1': '102 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 Broadway', 'New York, NY 11249']},
#    'phone': '+13478013646',
#    'display_phone': '(347) 801-3646',
#    'distance': 2514.56603882948},
#   {'id': 'PoyJmQHzlfuxFmhLdzo9Rg',
#    'alias': 'chip-city-west-village-new-york',
#    'name': 'Chip City - West Village',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-h1OwRL9ehJsvuC_AT2o4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chip-city-west-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 164,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7324, 'longitude': -74.0038},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '298 Bleecker St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['298 Bleecker St', 'New York, NY 10014']},
#    'phone': '+16468580229',
#    'display_phone': '(646) 858-0229',
#    'distance': 3101.2532266516378},
#   {'id': 'sM1mrw5y2ttH6GHNTRNieg',
#    'alias': 'mia-s-bakery-new-york',
#    'name': 'Mia’s Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Q9QxOcO2NBap09aV72WEyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mia-s-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 208,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7596408145034,
#     'longitude': -73.984548577331},
#    'transactions': ['delivery'],
#    'location': {'address1': '716 7th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['716 7th Ave', 'New York, NY 10036']},
#    'phone': '+19172614437',
#    'display_phone': '(917) 261-4437',
#    'distance': 6081.986166081543},
#   {'id': 'jgaDo7PElSG6BKXrqVz-kg',
#    'alias': 'doughnut-plant-brooklyn-2',
#    'name': 'Doughnut Plant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tbMvcHx-K6T6R6jPMRPsBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doughnut-plant-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7174797, 'longitude': -73.9583136},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '198 Bedford Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['198 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+13159045100',
#    'display_phone': '(315) 904-5100',
#    'distance': 3311.332190135505},
#   {'id': 'FbNzAk4zFdD4j6gQLunFHw',
#    'alias': 'cannelle-lic-long-island-city-3',
#    'name': 'Cannelle LIC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kljSYUxCKNU7dYfHhCBjgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cannelle-lic-long-island-city-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 264,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.746326, 'longitude': -73.955408},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '5-11 47th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5-11 47th Ave', 'Long Island City, NY 11101']},
#    'phone': '+17189378500',
#    'display_phone': '(718) 937-8500',
#    'distance': 5603.682714573715},
#   {'id': 'fb7u7SAvscRrCU7hLMjlEw',
#    'alias': 'frenchette-bakery-new-york',
#    'name': 'Frenchette Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/t9XVQbYWOPlU_upX7mzeKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frenchette-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.716923, 'longitude': -74.0067617982603},
#    'transactions': ['delivery'],
#    'location': {'address1': '220 Church St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['220 Church St', 'New York, NY 10013']},
#    'phone': '+12122271787',
#    'display_phone': '(212) 227-1787',
#    'distance': 1653.3070732529673},
#   {'id': 'Hs1TH_4FpyzbX6_J5r1XXg',
#    'alias': 'mollys-cupcakes-new-york',
#    'name': "Molly's Cupcakes",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UPAzgAsBqOlHdi00SfCwnQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mollys-cupcakes-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1717,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73014, 'longitude': -74.00248},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '228 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12124142253',
#    'display_phone': '(212) 414-2253',
#    'distance': 2828.812386861157},
#   {'id': 'iyKEtW9KM7rIyycAR0o3ew',
#    'alias': 'black-star-bakery-and-cafe-new-york-3',
#    'name': 'Black Star Bakery & Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6pfbDH57Vyv0DVL0b8IuQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-star-bakery-and-cafe-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.738951, 'longitude': -73.980784},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '241 E 24th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['241 E 24th St', 'New York, NY 10010']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3890.344620331399},
#   {'id': 'S8KO9WmFfiuxmE_vJ7WhRQ',
#    'alias': 'sweet-generation-brooklyn',
#    'name': 'Sweet Generation',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JNqcaIHXNyhXnXdp8TDYJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweet-generation-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 106,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7064711, 'longitude': -73.9209643},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1329 Willoughby Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1329 Willoughby Ave', 'Brooklyn, NY 11237']},
#    'phone': '+16469645777',
#    'display_phone': '(646) 964-5777',
#    'distance': 6182.171364271687},
#   {'id': '1uPB-IOaoWd4s2jNFpZgVw',
#    'alias': 'poseidon-bakery-new-york',
#    'name': 'Poseidon Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HRehumnpbd6jMnjEfqop3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/poseidon-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 200,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'chocolate', 'title': 'Chocolatiers & Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7600399, 'longitude': -73.99168},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '629 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['629 9th Ave', 'New York, NY 10036']},
#    'phone': '+12127576173',
#    'display_phone': '(212) 757-6173',
#    'distance': 6076.449878827711},
#   {'id': 'HcqYKQs46fYmk3aFNIQ2aA',
#    'alias': 'go-believe-bakery-new-york',
#    'name': 'Go Believe Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0_bKNvp-SVJ-E0I_SzHPvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/go-believe-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 67,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7182597, 'longitude': -73.9945592},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '239 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['239 Grand St', 'New York, NY 10002']},
#    'phone': '+12127750102',
#    'display_phone': '(212) 775-0102',
#    'distance': 1425.1194681725876},
#   {'id': 'nVIAmfM55P6zoKzaUKdGgw',
#    'alias': 'jacques-torres-chocolate-brooklyn',
#    'name': 'Jacques Torres Chocolate',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-RuZ7qk_3H9u8QETOY-0tQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jacques-torres-chocolate-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 566,
#    'categories': [{'alias': 'chocolate', 'title': 'Chocolatiers & Shops'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7032212028374,
#     'longitude': -73.9914379239426},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '66 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['66 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+17188751269',
#    'display_phone': '(718) 875-1269',
#    'distance': 345.06159656995317}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                       Restaurant      Type Price Rating            Address  \
# 0                    Taste Crème  Desserts               13-11 Jackson Ave
# 1         Sullivan Street Bakery  Bakeries                 103 Sullivan St
# 2   Damascus Bread & Pastry Shop  Bakeries     $    4.5   195 Atlantic Ave
# 3  The Dough Club - Williamsburg    Donuts                 294 Bedford Ave
# 4               Lassen & Hennigs     Delis    $$      4    114 Montague St
#
#          Lat        Lng                                                url  \
# 0  40.744347 -73.949535
# 1  40.725624 -74.002819
# 2  40.690050 -73.993070  https://www.yelp.com/biz/damascus-bread-and-pa...
# 3  40.714384 -73.961522
# 4  40.694840 -73.994900  https://www.yelp.com/biz/lassen-and-hennigs-br...
#
#                        ID
# 0
# 1
# 2  2coj9-JUozEYyPyUDTkCoA
# 3
# 4  UsDeDLDJzYp91t6akkueqw

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"bakery","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [{'id': 'BJL3JbPPX97a58GTURvTxA',
#    'alias': 'the-donut-pub-new-york',
#    'name': 'The Donut Pub',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/l3O-18zhlv9in84VzLuDSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-donut-pub-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 995,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.738867, 'longitude': -73.999811},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '203 W 14th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['203 W 14th St', 'New York, NY 10011']},
#    'phone': '+16463987007',
#    'display_phone': '(646) 398-7007',
#    'distance': 3745.34546764287},
#   {'id': 'CHBDkg9U4xx6uDanE6tGvA',
#    'alias': 'coffee-project-new-york-fort-greene-brooklyn',
#    'name': 'Coffee Project New York | Fort Greene',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vdbv81x3BFTR0pskJAj1HA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffee-project-new-york-fort-greene-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 78,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6875927899466,
#     'longitude': -73.9792491098683},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '78 Rockwell Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['78 Rockwell Pl', 'Brooklyn, NY 11217']},
#    'phone': '+15858883153',
#    'display_phone': '(585) 888-3153',
#    'distance': 2357.913680206829},
#   {'id': 'Bm_OeNNmJ6Q8FXUDzGzfHw',
#    'alias': 'k-minamoto-new-york',
#    'name': 'K Minamoto',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LLWBMRFLREkto7GSHMQamQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/k-minamoto-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 154,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.759536, 'longitude': -73.9742545},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '509 Madison Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['509 Madison Ave', 'New York, NY 10022']},
#    'phone': '+12124893747',
#    'display_phone': '(212) 489-3747',
#    'distance': 6247.152939767607},
#   {'id': 'eyVi4b5NtBzxSZHr1MsQxA',
#    'alias': 'maman-greenpoint-brooklyn-2',
#    'name': 'Maman - Greenpoint',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5hiu4gxntVBqDdPJziVgfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maman-greenpoint-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 111,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7304699, 'longitude': -73.95796},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '80 Kent St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Kent St', 'Brooklyn, NY 11222']},
#    'phone': '+13476899195',
#    'display_phone': '(347) 689-9195',
#    'distance': 4137.496244400561},
#   {'id': 'vPrJbdUxqCWVDDP5nQGWYA',
#    'alias': 'gooey-on-the-inside-new-york-4',
#    'name': 'Gooey on The Inside',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/v0I3JhcytGkWZOABPIU25Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gooey-on-the-inside-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 217,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72063, 'longitude': -73.99275},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '163 Chrystie St',
#     'address2': 'Basement',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['163 Chrystie St', 'Basement', 'New York, NY 10002']},
#    'phone': '+16469720409',
#    'display_phone': '(646) 972-0409',
#    'distance': 1694.6349092807527},
#   {'id': '0O59ACZQxmBNw9LbdV6Ezw',
#    'alias': 'mel-new-york-3',
#    'name': 'Mel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/D2L0mkPDvOHffJsfRm01sw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mel-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7147330779558,
#     'longitude': -73.9910982165329},
#    'transactions': ['delivery'],
#    'location': {'address1': '1 Ludlow St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Ludlow St', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1067.3332073477957},
#   {'id': 'F7UeBLZHOtyxz2rTNnmt3Q',
#    'alias': 'billys-bakery-new-york',
#    'name': "Billy's Bakery",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cEM4yZyoIN-a9gRQT3SBjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/billys-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1247,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.745323, 'longitude': -74.001861},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '184 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['184 9th Ave', 'New York, NY 10011']},
#    'phone': '+12126479956',
#    'display_phone': '(212) 647-9956',
#    'distance': 4481.047834667675},
#   {'id': 'xGkjOhRnsIQz_maA6tfhbA',
#    'alias': 'winner-brooklyn',
#    'name': 'Winner',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Zeyq20eFxenkESJ3FP9Wwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/winner-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 87,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.665709, 'longitude': -73.982375},
#    'transactions': ['delivery'],
#    'location': {'address1': '376 7th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['376 7th Ave', 'Brooklyn, NY 11215']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4531.261840506078},
#   {'id': 'CjIBoGl2gdvojZvVlyPIgg',
#    'alias': 'huascar-and-co-bakeshop-new-york',
#    'name': 'Huascar & Co Bakeshop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gdYQDDmT8lMlyDMphFwFHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/huascar-and-co-bakeshop-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 254,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7671574, 'longitude': -73.9895795},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '453 W 54th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['453 W 54th St', 'New York, NY 10019']},
#    'phone': '+12129331041',
#    'display_phone': '(212) 933-1041',
#    'distance': 6873.596446573447},
#   {'id': 'Hoee2W7IQ1Aic1i830rfrg',
#    'alias': 'the-brooklyn-biscuit-company-brooklyn',
#    'name': 'The Brooklyn Biscuit Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wZEUa-uQUEwiunA8CIEszA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-brooklyn-biscuit-company-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.679729, 'longitude': -74.006313},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '24 Commerce St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 Commerce St', 'Brooklyn, NY 11231']},
#    'phone': '+17184402288',
#    'display_phone': '(718) 440-2288',
#    'distance': 3033.7314750989062},
#   {'id': 'l6cNsWLIIYygtvt-kp2k9w',
#    'alias': 'tai-pan-bakery-new-york',
#    'name': 'Tai Pan Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eBnnfcQ6_XmEQXFAdXLGTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tai-pan-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 631,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7168192, 'longitude': -73.9982137},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '194 Canal St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['194 Canal St', 'New York, NY 10013']},
#    'phone': '+12127322222',
#    'display_phone': '(212) 732-2222',
#    'distance': 1295.285003723171},
#   {'id': '0hkTO8W3g3r5p27XRKxJRw',
#    'alias': 'la-bella-ferrara-cafe-new-york',
#    'name': 'La Bella Ferrara Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MH1Ezwt7MMPYDIEkMnLe6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-bella-ferrara-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 473,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7173118, 'longitude': -73.9982466},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '108 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['108 Mulberry St', 'New York, NY 10013']},
#    'phone': '+12129667867',
#    'display_phone': '(212) 966-7867',
#    'distance': 1367.1993932552612},
#   {'id': 'ovNuIGcC0LF4lyJP2Sawyw',
#    'alias': 'bake-culture-new-york',
#    'name': 'Bake Culture',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/luHMwPTz6x6ufA1ychLAPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bake-culture-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 165,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7157, 'longitude': -73.99663},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '48 Bowery',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['48 Bowery', 'New York, NY 10013']},
#    'phone': '+16468582898',
#    'display_phone': '(646) 858-2898',
#    'distance': 1165.9015274200265},
#   {'id': 'aQ5CQf_8GMrLHvMxf5l-Tw',
#    'alias': 'steinbergs-bakery-brooklyn',
#    'name': "Steinberg's Bakery",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ptJeCVi---Zv_roCTql30w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/steinbergs-bakery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7068459, 'longitude': -73.9634131},
#    'transactions': [],
#    'location': {'address1': '153 Clymer St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['153 Clymer St', 'Brooklyn, NY 11211']},
#    'phone': '+17184869100',
#    'display_phone': '(718) 486-9100',
#    'distance': 2598.398314253857},
#   {'id': '7Oab05KVxJDrA8VfpgxEcQ',
#    'alias': 'magnolia-bakery-upper-west-side-new-york',
#    'name': 'Magnolia Bakery Upper West Side',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V9FScPMSz7h2zfX0s8kypQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/magnolia-bakery-upper-west-side-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1222,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7756888898897,
#     'longitude': -73.9802770593954},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '200 Columbus Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 Columbus Ave', 'New York, NY 10023']},
#    'phone': '+12127248101',
#    'display_phone': '(212) 724-8101',
#    'distance': 7899.528088867079},
#   {'id': '6ykDNYoOMEiQ2aJ7fzJbXA',
#    'alias': 'mr-banana-man-brooklyn',
#    'name': 'Mr Banana Man',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SSh9_-neQRcSgFNqTZwmFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-banana-man-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.6626845840016,
#     'longitude': -73.9850924328808},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Brooklyn, NY 11201']},
#    'phone': '+19545517605',
#    'display_phone': '(954) 551-7605',
#    'distance': 4817.599311355858},
#   {'id': 'RTbltj7zrc3mL2CIQvNUpg',
#    'alias': 'grandaisy-bakery-new-york-4',
#    'name': 'Grandaisy Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Zb6ReyEt1CfsC5rOLAupQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grandaisy-bakery-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 128,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720041, 'longitude': -74.005867765337},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '250 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['250 W Broadway', 'New York, NY 10013']},
#    'phone': '+12123349435',
#    'display_phone': '(212) 334-9435',
#    'distance': 1893.6428868035466},
#   {'id': 'g3jNtkQZVZrrC823oBxdtg',
#    'alias': 'lafayette-grand-café-and-bakery-new-york',
#    'name': 'Lafayette Grand Café & Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Z0k9Sjk5k57EqC9h_NMvcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lafayette-grand-caf%C3%A9-and-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 956,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.727617, 'longitude': -73.993464},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '380 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['380 Lafayette St', 'New York, NY 10003']},
#    'phone': '+12125333000',
#    'display_phone': '(212) 533-3000',
#    'distance': 2466.4165560809},
#   {'id': '7akz4cCMAn0Ze6JKMfU5oQ',
#    'alias': 'mazzola-bakery-brooklyn',
#    'name': 'Mazzola Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T3F4mUreVwKGewOLC0NS6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mazzola-bakery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 214,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68328, 'longitude': -73.999664},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '192 Union St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['192 Union St', 'Brooklyn, NY 11231']},
#    'phone': '+17186431719',
#    'display_phone': '(718) 643-1719',
#    'distance': 2502.8313332577995},
#   {'id': 'V5naohe9wFKhKW7ZQJpWkg',
#    'alias': 'betty-bakery-brooklyn',
#    'name': 'Betty Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/z8DUQEF6_aim6nktTTS4Kw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/betty-bakery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 291,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6862159, 'longitude': -73.9834234},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '448 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['448 Atlantic Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17182462402',
#    'display_phone': '(718) 246-2402',
#    'distance': 2326.2633234145105},
#   {'id': '8xYvp9j7j8RCRQGsiRRujQ',
#    'alias': 'la-bergamote-nyc-new-york',
#    'name': 'La Bergamote NYC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/f1XkG1aI8OxqSjYZEGpg3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-bergamote-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 359,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.745044, 'longitude': -74.002863},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '177 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['177 9th Ave', 'New York, NY 10011']},
#    'phone': '+12126279010',
#    'display_phone': '(212) 627-9010',
#    'distance': 4461.894981676772},
#   {'id': 'TmEPtynTP1qoTqwUbGKyGw',
#    'alias': 'ladurée-soho-new-york-2',
#    'name': 'Ladurée SoHo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kOU2qgsrtRcxA5W75S2UEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ladur%C3%A9e-soho-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1655,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'macarons', 'title': 'Macarons'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.724329, 'longitude': -74.002508},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '398 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['398 W Broadway', 'New York, NY 10012']},
#    'phone': '+16463927868',
#    'display_phone': '(646) 392-7868',
#    'distance': 2211.0161222976785},
#   {'id': 'Q_7J5E-cYCQfHNCkCyMdLA',
#    'alias': 'baked-brooklyn',
#    'name': 'Baked',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IVtF0KBB15w5ya_lMD_oAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baked-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 509,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.676789, 'longitude': -74.013211},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '359 Van Brunt St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['359 Van Brunt St', 'Brooklyn, NY 11231']},
#    'phone': '+17182220345',
#    'display_phone': '(718) 222-0345',
#    'distance': 3563.290868654911},
#   {'id': 'x35Qxemj9L30BcYUZ9mEeA',
#    'alias': 'lady-m-cake-boutique-new-york-8',
#    'name': 'Lady M Cake Boutique',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mgj83kAVAJTs6zuLCPtcVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lady-m-cake-boutique-new-york-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 186,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.710233, 'longitude': -74.011849},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '101 Liberty St',
#     'address2': 'Ste 1415',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10281',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['101 Liberty St', 'Ste 1415', 'New York, NY 10281']},
#    'phone': '+12124522222',
#    'display_phone': '(212) 452-2222',
#    'distance': 1572.6546316716299},
#   {'id': 'qS1d3RQW68HJmdHLIANx7Q',
#    'alias': 'oneg-bakery-brooklyn',
#    'name': 'Oneg Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SVp8PDUpUEYGVabO7X6ApQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oneg-bakery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7021085, 'longitude': -73.956163},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '188 Lee Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['188 Lee Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17187970971',
#    'display_phone': '(718) 797-0971',
#    'distance': 3231.528035425583},
#   {'id': 'BV5Uvivsv_8_wCLK-S3eLw',
#    'alias': 'xin-fa-bakery-brooklyn',
#    'name': 'Xin Fa Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Soec93bpozfGKBVjTFRPhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/xin-fa-bakery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 220,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.637296, 'longitude': -74.007533},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '5617 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11220',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5617 8th Ave', 'Brooklyn, NY 11220']},
#    'phone': '+17188712889',
#    'display_phone': '(718) 871-2889',
#    'distance': 7659.624336126698},
#   {'id': '4jtWfrGODTtbg5sar4cjPA',
#    'alias': 'cannelle-patisserie-east-elmhurst',
#    'name': 'Cannelle Patisserie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/j2T9oZbOXnPePKzLnc623Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cannelle-patisserie-east-elmhurst?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 835,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76017183023, 'longitude': -73.8920721786869},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '75-59 31st Ave',
#     'address2': 'FLR GRD',
#     'address3': '',
#     'city': 'EAST ELMHURST',
#     'zip_code': '11370',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75-59 31st Ave',
#      'FLR GRD',
#      'EAST ELMHURST, NY 11370']},
#    'phone': '+17185656200',
#    'display_phone': '(718) 565-6200',
#    'distance': 10545.905228825326},
#   {'id': 'lpE8xvDjugLvLxlTIl-fJw',
#    'alias': 'las-delicias-patisserie-new-york-2',
#    'name': 'Las Delicias Patisserie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sF22_2CeQrdLPmndFTx0_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/las-delicias-patisserie-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'kosher', 'title': 'Kosher'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7346439, 'longitude': -73.9910605},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Union Square Greenmarket',
#     'address2': '20 Union Square W',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Union Square Greenmarket',
#      '20 Union Square W',
#      'New York, NY 10003']},
#    'phone': '+12124170044',
#    'display_phone': '(212) 417-0044',
#    'distance': 3258.191094610409},
#   {'id': 'tjr3-6HsFtQvd0GC1xe7Pw',
#    'alias': 'magnolia-bakery-new-york-12',
#    'name': 'Magnolia Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hAc6HWFmqyeJoWZuMxHQHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/magnolia-bakery-new-york-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75116241676398,
#     'longitude': -73.9951505181098},
#    'transactions': [],
#    'location': {'address1': '421 8th Ave',
#     'address2': '',
#     'address3': 'Moynihan Train Hall',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['421 8th Ave',
#      'Moynihan Train Hall',
#      'New York, NY 10007']},
#    'phone': '+16469083500',
#    'display_phone': '(646) 908-3500',
#    'distance': 5084.067505413213},
#   {'id': 'Q1ErIlQqHXqtb-13UXXjVQ',
#    'alias': 'four-and-twenty-blackbirds-brooklyn',
#    'name': 'Four & Twenty Blackbirds',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mieHuyQEc3E8RVJ5qU2LgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/four-and-twenty-blackbirds-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 728,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67206, 'longitude': -73.99015},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '439 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['439 3rd Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17184992917',
#    'display_phone': '(718) 499-2917',
#    'distance': 3727.5234855350877},
#   {'id': 'EJHYYM09cnEfQmFBVZi3rg',
#    'alias': 'cafe-d-avignon-dekalb-market-hall-brooklyn-3',
#    'name': 'Cafe d’Avignon - Dekalb Market Hall',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hJWYDVuORpVWZ39aUw3WPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-d-avignon-dekalb-market-hall-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 66,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.690934, 'longitude': -73.982881},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '445 Albee Square W',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['445 Albee Square W', 'Brooklyn, NY 11201']},
#    'phone': '+19293784848',
#    'display_phone': '(929) 378-4848',
#    'distance': 1878.5873945929363},
#   {'id': 'vk7W3_sQwr7eZbRFsXv6rw',
#    'alias': 'taiyaki-nyc-new-york',
#    'name': 'Taiyaki NYC',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/F3Vyd-otu36oE8B8M1XXug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taiyaki-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3037,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71789, 'longitude': -73.9988},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '119 Baxter St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['119 Baxter St', 'New York, NY 10013']},
#    'phone': '+12129662882',
#    'display_phone': '(212) 966-2882',
#    'distance': 1439.7258094631309},
#   {'id': 'yE61VPU9Z_rKdQcCc8ImCg',
#    'alias': 'mamas-bakery-new-york',
#    'name': "Mama's Bakery",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hiW6Ev907eVIOtEV74r9Lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mamas-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.712635, 'longitude': -73.996841},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '27 Catherine St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27 Catherine St', 'New York, NY 10038']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 828.4796893582417},
#   {'id': 'RcqZmRj3mWiimohFnNA4Nw',
#    'alias': 'milk-bar-east-village-new-york-2',
#    'name': 'Milk Bar East Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2xYDsaWyFxdCNyY1z5pVRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/milk-bar-east-village-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3364,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7318893900159,
#     'longitude': -73.9857388595245},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '251 E 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['251 E 13th St', 'New York, NY 10003']},
#    'phone': '+16466924154',
#    'display_phone': '(646) 692-4154',
#    'distance': 3027.581728184138},
#   {'id': '-CR-a1EGcaw7c9Qp2HsygA',
#    'alias': 'erotic-bakery-new-york-6',
#    'name': 'Erotic Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6AyTGCHttcR0Z6NKEDIY8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/erotic-bakery-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72506, 'longitude': -73.84549},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['New York, NY 11375']},
#    'phone': '+17188867623',
#    'display_phone': '(718) 886-7623',
#    'distance': 12697.438994820077},
#   {'id': 'FUO--908-zGodIpUw69VJQ',
#    'alias': 'ka-wah-bakery-corporation-new-york',
#    'name': 'Ka Wah Bakery Corporation',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Y9F5s-TVXSIOwQyrHlB4jQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ka-wah-bakery-corporation-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71468, 'longitude': -73.99385},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '9 Eldridge St',
#     'address2': 'Ste 101',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Eldridge St', 'Ste 101', 'New York, NY 10002']},
#    'phone': '+12122260133',
#    'display_phone': '(212) 226-0133',
#    'distance': 1027.9304276886644},
#   {'id': 'j_x5CbFjKfPcvakcWCE_hA',
#    'alias': 'kings-kolache-brooklyn',
#    'name': 'Kings Kolache',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/z9IN0-Z6N_NKsD9KcOKxdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kings-kolache-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'tex-mex', 'title': 'Tex-Mex'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.708076, 'longitude': -73.9205073},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '321 Starr St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['321 Starr St', 'Brooklyn, NY 11237']},
#    'phone': '+18456143226',
#    'display_phone': '(845) 614-3226',
#    'distance': 6226.44251831494},
#   {'id': 'lWy_mbdjaRokfdl-lnOraQ',
#    'alias': 'zeppola-bakery-new-york',
#    'name': 'Zeppola Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ue7Fb170HP2XVL0wjGXvZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zeppola-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.752603, 'longitude': -73.989115},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '499 7th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['499 7th Ave', 'New York, NY 10018']},
#    'phone': '+16467340303',
#    'display_phone': '(646) 734-0303',
#    'distance': 5264.205562957953},
#   {'id': '8QaVI3EgwfnflOaZRcwxAg',
#    'alias': 'clementine-bakery-and-provision-brooklyn',
#    'name': 'Clementine Bakery and Provision',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0So1EGK2GFxDHBY6xvUVHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clementine-bakery-and-provision-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 488,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68756, 'longitude': -73.9596},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '395 Classon Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['395 Classon Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17184838788',
#    'display_phone': '(718) 483-8788',
#    'distance': 3534.3986081246176},
#   {'id': 'LJtq4TugycFgNN5AoJvc5Q',
#    'alias': 'posh-pop-bakeshop-new-york-2',
#    'name': 'Posh Pop Bakeshop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/pfvfrXB9sWtH5Yq--6ob9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/posh-pop-bakeshop-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 363,
#    'categories': [{'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7291965397419,
#     'longitude': -74.0015334018494},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '192 Bleecker St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['192 Bleecker St', 'New York, NY 10012']},
#    'phone': '+12126747674',
#    'display_phone': '(212) 674-7674',
#    'distance': 2710.6363038329896},
#   {'id': 'ikazsJps1k-Br2FbunwCtg',
#    'alias': 'spot-dessert-bar-new-york-2',
#    'name': 'Spot Dessert Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5dnRWVMLgjNYXDeeG5kPjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spot-dessert-bar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3101,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72939, 'longitude': -73.98892},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '13 St Marks Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['13 St Marks Pl', 'New York, NY 10003']},
#    'phone': '+12126775670',
#    'display_phone': '(212) 677-5670',
#    'distance': 2697.5233343657724},
#   {'id': '26RnTqk2gDyRAdHXC5sshQ',
#    'alias': 'miss-madeleine-new-york',
#    'name': 'Miss Madeleine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gDms1ASoCDTb5yWLllO0Vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/miss-madeleine-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 74,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.77407, 'longitude': -73.9509999},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '400 E 82nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['400 E 82nd St', 'New York, NY 10028']},
#    'phone': '+16468961227',
#    'display_phone': '(646) 896-1227',
#    'distance': 8454.529998951546},
#   {'id': 'WkmqGh7NF6VUz43UTTFvMg',
#    'alias': 'f-monteleone-bakery-and-cafe-brooklyn',
#    'name': 'F Monteleone Bakery & Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jdeAyd2F8RlKqhwlQQIh2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/f-monteleone-bakery-and-cafe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 167,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6819599, 'longitude': -73.99594},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '355 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['355 Court St', 'Brooklyn, NY 11231']},
#    'phone': '+17188525600',
#    'display_phone': '(718) 852-5600',
#    'distance': 2613.3549630734433},
#   {'id': 'C_GM5FUpruYtIvIESpxrog',
#    'alias': 'guadalupana-bakery-brooklyn',
#    'name': 'Guadalupana Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cG9XvLU6S4qywxLuhC1p_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/guadalupana-bakery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.699218, 'longitude': -73.939908},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '308 Ellery St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['308 Ellery St', 'Brooklyn, NY 11206']},
#    'phone': '+17183842011',
#    'display_phone': '(718) 384-2011',
#    'distance': 4631.795565535603},
#   {'id': 'a5FVkeyRpiAttprSRmzgkQ',
#    'alias': 'court-pastry-shop-brooklyn',
#    'name': 'Court Pastry Shop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RWi5Bm1syFFNdl_XAtOWXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/court-pastry-shop-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 183,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68407, 'longitude': -73.99537},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '298 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['298 Court St', 'Brooklyn, NY 11231']},
#    'phone': '+17188754820',
#    'display_phone': '(718) 875-4820',
#    'distance': 2380.579301673822},
#   {'id': 'o9Ipm--aunOX5BbcKY4ENw',
#    'alias': 'feed-shop-and-cafe-brooklyn-2',
#    'name': 'FEED Shop & Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/j0hg_LPCsnAywwrwtP1AAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/feed-shop-and-cafe-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'accessories', 'title': 'Accessories'},
#     {'alias': 'jewelry', 'title': 'Jewelry'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.703402, 'longitude': -73.99141},
#    'transactions': ['delivery'],
#    'location': {'address1': '55 Water St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+19293972716',
#    'display_phone': '(929) 397-2716',
#    'distance': 332.66869202732244},
#   {'id': '4VEgZ7aVUt6oKw8KmXj-jQ',
#    'alias': 'brooklyn-kolache-brooklyn',
#    'name': 'Brooklyn Kolache',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QqQV6MtAiG4i2vqCwFQhCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-kolache-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 337,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6907913077698,
#     'longitude': -73.9556479454041},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '520 Dekalb Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['520 Dekalb Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17183981111',
#    'display_phone': '(718) 398-1111',
#    'distance': 3642.653889043858},
#   {'id': '1zRIzYEbyI8QdE8tGjnjGg',
#    'alias': 'nitas-european-bakery-sunnyside',
#    'name': "Nita's European Bakery",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZiJTKbFq6mQ1wF1f1hFKlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nitas-european-bakery-sunnyside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 124,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.739476, 'longitude': -73.924659},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4010 Greenpoint Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4010 Greenpoint Ave', 'Sunnyside, NY 11104']},
#    'phone': '+17187844047',
#    'display_phone': '(718) 784-4047',
#    'distance': 6982.594041932722},
#   {'id': '4krqWXQqWfTmSh0q0CShGg',
#    'alias': 'doc-ds-southern-desserts-brooklyn',
#    'name': "DOC D's Southern Desserts",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3KbQfwbB_KR76YIIAuhH0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doc-ds-southern-desserts-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 210,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68115, 'longitude': -73.928399},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '214 Bainbridge St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['214 Bainbridge St', 'Brooklyn, NY 11233']},
#    'phone': '+13474138438',
#    'display_phone': '(347) 413-8438',
#    'distance': 6179.426400279547},
#   {'id': 'oBcuOhubYwHV_bY35lu5hA',
#    'alias': 'petees-cafe-brooklyn-4',
#    'name': "Petee's Cafe",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xExFxShGqOg7KuKQqQlBDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/petees-cafe-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 111,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.693794, 'longitude': -73.964702},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '505 Myrtle Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['505 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+16464943630',
#    'display_phone': '(646) 494-3630',
#    'distance': 2811.0519873458315}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#                               Restaurant      Type Price Rating  \
# 0                          The Donut Pub  Bakeries    $$      4
# 1  Coffee Project New York | Fort Greene     Cafes    $$    4.5
# 2                             K Minamoto  Desserts   $$$    4.5
# 3                     Maman - Greenpoint     Cafes    $$    3.5
# 4                    Gooey on The Inside  Desserts     $      4
#
#            Address        Lat        Lng  \
# 0    203 W 14th St  40.738867 -73.999811
# 1   78 Rockwell Pl  40.687593 -73.979249
# 2  509 Madison Ave  40.759536 -73.974255
# 3       80 Kent St  40.730470 -73.957960
# 4  163 Chrystie St  40.720630 -73.992750
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/the-donut-pub-new-yor...  BJL3JbPPX97a58GTURvTxA
# 1  https://www.yelp.com/biz/coffee-project-new-yo...  CHBDkg9U4xx6uDanE6tGvA
# 2  https://www.yelp.com/biz/k-minamoto-new-york?a...  Bm_OeNNmJ6Q8FXUDzGzfHw
# 3  https://www.yelp.com/biz/maman-greenpoint-broo...  eyVi4b5NtBzxSZHr1MsQxA
# 4  https://www.yelp.com/biz/gooey-on-the-inside-n...  vPrJbdUxqCWVDDP5nQGWYA

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                           Restaurant                       Type Rating Price  \
# 0                 Mei Lai Wah Bakery                   Bakeries      4     $
# 1                    Luckybird Cakes                   Bakeries    4.5    $$
# 2              Huascar & Co Bakeshop                   Bakeries    4.5    $$
# 3              Ferrara Bakery & Cafe                   Bakeries    3.5    $$
# 4       The Brooklyn Biscuit Company                   Bakeries    4.5   $$$
# 5                          Ceci-Cela                   Bakeries      4    $$
# 6                  Old Poland Bakery                   Bakeries      4     $
# 7      Clinton Street Baking Company                   Bakeries      4    $$
# 8                     Tai Pan Bakery                   Bakeries    3.5     $
# 9              La Bella Ferrara Cafe                   Bakeries      4     $
# 10                 Patisserie Claude                   Bakeries      4     $
# 11                      Bake Culture                   Bakeries    3.5    $$
# 12              Mille-Feuille Bakery                   Bakeries
# 13              Crispy Heaven Bakery                   Bakeries
# 14                 Ebb & Flow Bakery                   Bakeries
# 15                Steinberg's Bakery                   Bakeries
# 16                  Grandaisy Bakery                   Bakeries      4     $
# 17                    Mazzola Bakery                   Bakeries    4.5     $
# 18                     Eclair Bakery                   Bakeries    4.5    $$
# 19                        Pi Bakerie                   Bakeries    4.5    $$
# 20                     Parisi Bakery                   Bakeries    4.5    $$
# 21     Cafe d’Avignon - Essex Market                   Bakeries    4.5    $$
# 22                      Betty Bakery                   Bakeries      4    $$
# 23            Sullivan Street Bakery                   Bakeries    3.5    $$
# 24                             Baked                   Bakeries      4    $$
# 25               Buttermilk Bakeshop                   Bakeries    4.5     $
# 26       New Golden Fung Wong Bakery                   Bakeries      4     $
# 27                            Peck's                   Bakeries      4    $$
# 28                   The Love Bakery                   Bakeries
# 29                       Oneg Bakery                   Bakeries    4.5     $
# ..                               ...                        ...    ...   ...
# 170                           Kitsby                   Desserts    4.5    $$
# 171         ChikaLicious Dessert Bar                   Desserts      4    $$
# 172                   Joey Bats Café                   Desserts      5     $
# 173                   The Little One                   Desserts      4     $
# 174                 Sweet Generation                   Desserts      4    $$
# 175                Brigadeiro Bakery                   Desserts      4    $$
# 176                       K Minamoto                   Desserts    4.5   $$$
# 177                      Taste Crème                   Desserts
# 178              Gooey on The Inside                   Desserts      4     $
# 179                    HARBS Chelsea                   Desserts      4    $$
# 180                               46                   Desserts
# 181                    Mr Banana Man                   Desserts      5    $$
# 182                   Tous Les Jours                   Desserts    3.5     $
# 183               Patisserie Chanson                   Desserts      4    $$
# 184                       City Cakes                   Desserts    4.5    $$
# 185  Magnolia Bakery Upper West Side                   Desserts    3.5    $$
# 186                     Beard Papa's                   Desserts
# 187    The Dough Club - Williamsburg                     Donuts
# 188                   Doughnut Plant                     Donuts    4.5    $$
# 189                   Doughnut Plant                     Donuts
# 190             The Doughnut Project                     Donuts    4.5     $
# 191                   The Dough Club                     Donuts
# 192    Lafayette Grand Café & Bakery                     French    3.5   $$$
# 193                Posh Pop Bakeshop                Gluten-Free
# 194                      Melt Bakery  Ice Cream & Frozen Yogurt      4     $
# 195                  Ladurée Madison                   Macarons    4.5   $$$
# 196             Charlotte Patisserie       Patisserie/Cake Shop      4     $
# 197                 Le Petit Monstre       Patisserie/Cake Shop
# 198                    Madman Bakery                 Sandwiches
# 199                     Ladurée SoHo                  Tea Rooms    3.5   $$$
#
#                  Address        Lat        Lng  \
# 0           64 Bayard St  40.715576 -73.997958
# 1       163 Montrose Ave  40.707626 -73.942703
# 2          453 W 54th St  40.767157 -73.989580
# 3           195 Grand St  40.719079 -73.997086
# 4         24 Commerce St  40.679729 -74.006313
# 5         14 Delancey St  40.720285 -73.993056
# 6      926 Manhattan Ave  40.731071 -73.954240
# 7           4 Clinton St  40.721128 -73.983933
# 8           194 Canal St  40.716819 -73.998214
# 9        108 Mulberry St  40.717312 -73.998247
# 10          187 W 4th St  40.732740 -74.001821
# 11             48 Bowery  40.715700 -73.996630
# 12    622 Vanderbilt Ave  40.677621 -73.969120
# 13           38 Grand St  40.722700 -74.004200
# 14         159 Bridge Dr  40.693854 -74.000854
# 15         153 Clymer St  40.706846 -73.963413
# 16        250 W Broadway  40.720041 -74.005868
# 17          192 Union St  40.683280 -73.999664
# 18         305 E 53rd St  40.756689 -73.966617
# 19         512 Broome St  40.723610 -74.003290
# 20           198 Mott St  40.721184 -73.995436
# 21           88 Essex St  40.717920 -73.988317
# 22      448 Atlantic Ave  40.686216 -73.983423
# 23           236 9th Ave  40.747410 -74.000590
# 24      359 Van Brunt St  40.676789 -74.013211
# 25           260 5th Ave  40.674910 -73.981710
# 26            41 Mott St  40.715170 -73.999030
# 27       455A Myrtle Ave  40.693489 -73.967376
# 28         150 Ludlow St  40.720722 -73.987897
# 29           188 Lee Ave  40.702109 -73.956163
# ..                   ...        ...        ...
# 170         186 Grand St  40.714110 -73.960977
# 171        203 E 10th St  40.729646 -73.986202
# 172         129 Allen St  40.720060 -73.990370
# 173       150 E Broadway  40.714158 -73.990942
# 174  1329 Willoughby Ave  40.706471 -73.920964
# 175      156 Sullivan St  40.727446 -74.001680
# 176      509 Madison Ave  40.759536 -73.974255
# 177    13-11 Jackson Ave  40.744347 -73.949535
# 178      163 Chrystie St  40.720630 -73.992750
# 179          198 9th Ave  40.745849 -74.001548
# 180           46 Mott St  40.715293 -73.998644
# 181                       40.662685 -73.985092
# 182      31 West 32nd St  40.747938 -73.987012
# 183         20 W 23rd St  40.741700 -73.990571
# 184        155 W 18th St  40.740780 -73.996950
# 185     200 Columbus Ave  40.775689 -73.980277
# 186        239 E 53rd St  40.757140 -73.967820
# 187      294 Bedford Ave  40.714384 -73.961522
# 188         379 Grand St  40.716334 -73.988652
# 189      198 Bedford Ave  40.717480 -73.958314
# 190         10 Morton St  40.731151 -74.003547
# 191        119 Baxter St  40.717937 -73.998912
# 192     380 Lafayette St  40.727617 -73.993464
# 193      192 Bleecker St  40.729197 -74.001533
# 194         111 Front St  40.702676 -73.989176
# 195      864 Madison Ave  40.770770 -73.966376
# 196         201 Court St  40.687217 -73.993337
# 197    82 Washington Ave  40.696311 -73.967701
# 198     42 University Pl  40.732420 -73.994260
# 199       398 W Broadway  40.724329 -74.002508
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/mei-lai-wah-bakery-ne...  MauzeeZM7S-wUk_G98Ybrg
# 1    https://www.yelp.com/biz/luckybird-cakes-brook...  Pa9ot06iF3b_DGWLyotZkQ
# 2    https://www.yelp.com/biz/huascar-and-co-bakesh...  CjIBoGl2gdvojZvVlyPIgg
# 3    https://www.yelp.com/biz/ferrara-bakery-and-ca...  lDW4DlTZYcSP9T1yQY5HKg
# 4    https://www.yelp.com/biz/the-brooklyn-biscuit-...  Hoee2W7IQ1Aic1i830rfrg
# 5    https://www.yelp.com/biz/ceci-cela-new-york-2?...  N7ux8gAg5udFTgZ2Y5P-6A
# 6    https://www.yelp.com/biz/old-poland-bakery-bro...  I41VRmgmiQ4kITgFZtJlvQ
# 7    https://www.yelp.com/biz/clinton-street-baking...  nU4XBdvxDABXqZ6CnB8Dig
# 8    https://www.yelp.com/biz/tai-pan-bakery-new-yo...  l6cNsWLIIYygtvt-kp2k9w
# 9    https://www.yelp.com/biz/la-bella-ferrara-cafe...  0hkTO8W3g3r5p27XRKxJRw
# 10   https://www.yelp.com/biz/patisserie-claude-new...  fvDZVAvv_g4L-WWkbDpCXg
# 11   https://www.yelp.com/biz/bake-culture-new-york...  ovNuIGcC0LF4lyJP2Sawyw
# 12
# 13
# 14
# 15
# 16   https://www.yelp.com/biz/grandaisy-bakery-new-...  RTbltj7zrc3mL2CIQvNUpg
# 17   https://www.yelp.com/biz/mazzola-bakery-brookl...  7akz4cCMAn0Ze6JKMfU5oQ
# 18   https://www.yelp.com/biz/eclair-bakery-new-yor...  bvc5P9vmRiNhyVWjd5bVcg
# 19   https://www.yelp.com/biz/pi-bakerie-new-york-2...  s_YuHngBngWwzpcKNIM71A
# 20   https://www.yelp.com/biz/parisi-bakery-new-yor...  6q6WWGaO75PQkpWOQ2zzHQ
# 21   https://www.yelp.com/biz/cafe-d-avignon-essex-...  leI3BslJ5I2-IxXyRaRjPw
# 22   https://www.yelp.com/biz/betty-bakery-brooklyn...  V5naohe9wFKhKW7ZQJpWkg
# 23   https://www.yelp.com/biz/sullivan-street-baker...  yicBRA8X7urJyKn6aF2wzw
# 24   https://www.yelp.com/biz/baked-brooklyn?adjust...  Q_7J5E-cYCQfHNCkCyMdLA
# 25   https://www.yelp.com/biz/buttermilk-bakeshop-b...  PKa6XxkvMTVD5gaDbMznNg
# 26   https://www.yelp.com/biz/new-golden-fung-wong-...  ky3c5RRlyO0tQQS33sO9RQ
# 27   https://www.yelp.com/biz/pecks-new-york?adjust...  DA1hijID0q6D6Ouch17v7w
# 28
# 29   https://www.yelp.com/biz/oneg-bakery-brooklyn?...  qS1d3RQW68HJmdHLIANx7Q
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/kitsby-brooklyn?adjus...  7-yC49tlWreX6TQtMNFSFg
# 171  https://www.yelp.com/biz/chikalicious-dessert-...  mIhqKMgru4002wfrVW-Gfw
# 172  https://www.yelp.com/biz/joey-bats-caf%C3%A9-n...  uYMimeHJ5XBGkyTrg8GXhw
# 173  https://www.yelp.com/biz/the-little-one-new-yo...  NkOpM1SBI50qviqE6LCKRg
# 174  https://www.yelp.com/biz/sweet-generation-broo...  S8KO9WmFfiuxmE_vJ7WhRQ
# 175  https://www.yelp.com/biz/brigadeiro-bakery-new...  cJBLw_FfD9w_X2XZS3TqIg
# 176  https://www.yelp.com/biz/k-minamoto-new-york?a...  Bm_OeNNmJ6Q8FXUDzGzfHw
# 177
# 178  https://www.yelp.com/biz/gooey-on-the-inside-n...  vPrJbdUxqCWVDDP5nQGWYA
# 179  https://www.yelp.com/biz/harbs-chelsea-new-yor...  -JQavt5ZBdpUH_y7tMWFvw
# 180
# 181  https://www.yelp.com/biz/mr-banana-man-brookly...  6ykDNYoOMEiQ2aJ7fzJbXA
# 182  https://www.yelp.com/biz/tous-les-jours-new-yo...  Yx6xDJBEmC8oTAmIEzDRag
# 183  https://www.yelp.com/biz/patisserie-chanson-ne...  meVzfRH_wLAJjcrCAhkh1g
# 184  https://www.yelp.com/biz/city-cakes-new-york?a...  wQLNq8dQE4DxvUSQwzAagw
# 185  https://www.yelp.com/biz/magnolia-bakery-upper...  7Oab05KVxJDrA8VfpgxEcQ
# 186
# 187
# 188  https://www.yelp.com/biz/doughnut-plant-new-yo...  lWOkeS-wV4no8qqA9OwwEg
# 189
# 190  https://www.yelp.com/biz/the-doughnut-project-...  c6UUcUTbwbk0kOpF6jVOJQ
# 191
# 192  https://www.yelp.com/biz/lafayette-grand-caf%C...  g3jNtkQZVZrrC823oBxdtg
# 193
# 194  https://www.yelp.com/biz/melt-bakery-brooklyn-...  ReYr4cHNlnZ4jiC4R7IRZg
# 195  https://www.yelp.com/biz/ladur%C3%A9e-madison-...  _DcfYjnGffQI3iP1Be0kdA
# 196  https://www.yelp.com/biz/charlotte-patisserie-...  cgWxj5zytsVQtbygN9M-OQ
# 197
# 198
# 199  https://www.yelp.com/biz/ladur%C3%A9e-soho-new...  TmEPtynTP1qoTqwUbGKyGw
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_Bakery.csv')
