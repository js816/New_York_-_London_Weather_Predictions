# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"french","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': 'ETgJqJHV7BW6pIr9Ox74sA',
#    'alias': 'amélie-new-york',
#    'name': 'Amélie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cSDgVuPMnJgMLTrTNSEXug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/am%C3%A9lie-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2751,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7327, 'longitude': -73.99766},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '22 W 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 W 8th St', 'New York, NY 10011']},
#    'phone': '+12125332962',
#    'display_phone': '(212) 533-2962',
#    'distance': 3038.8699032940094},
#   {'id': 'FiRB9Ek3Xo9JHwXgBYITYg',
#    'alias': 'la-sirène-soho-new-york',
#    'name': 'La Sirène-Soho',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L7cSgPVmrKJosZatGJKvBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-sir%C3%A8ne-soho-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1636,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7243642217227,
#     'longitude': -74.005708694458},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '558 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['558 Broome St', 'New York, NY 10013']},
#    'phone': '+12129253061',
#    'display_phone': '(212) 925-3061',
#    'distance': 2313.301948098778},
#   {'id': 'DGhWO1sUWydVeR5j5ZZaMw',
#    'alias': 'la-grande-boucherie-new-york-2',
#    'name': 'La Grande Boucherie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/b9URGcuuhnLq7J-__pHIng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-grande-boucherie-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 519,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7626274, 'longitude': -73.98084109999999},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '145 W 53rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['145 W 53rd St', 'New York, NY 10019']},
#    'phone': '+12125107714',
#    'display_phone': '(212) 510-7714',
#    'distance': 6458.633757596852},
#   {'id': 'qOomR3AwClOGpV1HdqOTFg',
#    'alias': 'les-enfants-de-boheme-new-york',
#    'name': 'Les Enfants de Boheme',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Sw6SDhbhkdi7MJeDajbp5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/les-enfants-de-boheme-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 271,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7136187, 'longitude': -73.9888503},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '177 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['177 Henry St', 'New York, NY 10002']},
#    'phone': '+16464764843',
#    'display_phone': '(646) 476-4843',
#    'distance': 1026.2110364656392},
#   {'id': 'FbGw2sPwZZlZuEndVpP2pQ',
#    'alias': 'la-petite-joie-brooklyn',
#    'name': 'La Petite Joie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qa8nWcGvAZoHkh33ZIOTTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-petite-joie-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7177, 'longitude': -73.95238},
#    'transactions': [],
#    'location': {'address1': '577 Union Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['577 Union Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13474576917',
#    'display_phone': '(347) 457-6917',
#    'distance': 3782.458990844829},
#   {'id': 'flcy6dNr4s12PTv6VtBK9Q',
#    'alias': 'lēna-new-york-8',
#    'name': 'LĒNA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kNWzdvKWch5VRL4LOdujnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l%C4%93na-new-york-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 184,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.719135, 'longitude': -73.991758},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '137 Eldridge St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['137 Eldridge St', 'New York, NY 10002']},
#    'phone': '+13479351897',
#    'display_phone': '(347) 935-1897',
#    'distance': 1537.1958876609465},
#   {'id': 's3jou_L_LVYGkNHiuhjlew',
#    'alias': 'boucherie-west-village-new-york-3',
#    'name': 'Boucherie West Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gGTUB2AHF7sK5u-wdjO8DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boucherie-west-village-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1767,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.733063, 'longitude': -74.0028772},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '99 7th Ave S',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['99 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12128371616',
#    'display_phone': '(212) 837-1616',
#    'distance': 3155.0505772747442},
#   {'id': 'iexl39DYyy_76Xq3ExaJkQ',
#    'alias': 'excuse-my-french-new-york',
#    'name': 'Excuse My French',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZIhKH5H06vFbrLn7OJFM_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/excuse-my-french-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 312,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71844, 'longitude': -73.98981},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '96 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['96 Orchard St', 'New York, NY 10002']},
#    'phone': '+12127809600',
#    'display_phone': '(212) 780-9600',
#    'distance': 1494.339354725842},
#   {'id': 'KgpOYAG-r_eDsQXFXt0nnQ',
#    'alias': 'balthazar-new-york-2',
#    'name': 'Balthazar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/059pBnbIE72oJcKRoaj6bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/balthazar-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3181,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7226892950401,
#     'longitude': -73.9982149184027},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '80 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Spring St', 'New York, NY 10012']},
#    'phone': '+12129651414',
#    'display_phone': '(212) 965-1414',
#    'distance': 1945.7706937139035},
#   {'id': 'xQ445GaWVN5Aa3sFX9OoIg',
#    'alias': 'buvette-new-york',
#    'name': 'Buvette',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ds96JzlOyCSUL--F7kookw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/buvette-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1875,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.732704, 'longitude': -74.004317},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '42 Grove St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 Grove St', 'New York, NY 10014']},
#    'phone': '+12122553590',
#    'display_phone': '(212) 255-3590',
#    'distance': 3146.5927484937347},
#   {'id': 'TGP5gbAgml0IDRLGCpFnCw',
#    'alias': 'pmf-pardon-my-french-new-york',
#    'name': 'PMF Pardon My French',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/X8eWP2AqEiktrGTr3th8JA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pmf-pardon-my-french-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1034,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72473, 'longitude': -73.98115},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '103 Ave B',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 Ave B', 'New York, NY 10009']},
#    'phone': '+12123589683',
#    'display_phone': '(212) 358-9683',
#    'distance': 2414.8553623569283},
#   {'id': '5m-TrbqMNnwJvOd7pAt6OA',
#    'alias': 'raclette-new-york',
#    'name': 'Raclette',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/r_PG8MC_RG-1b3QTQ9-Y7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raclette-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1420,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7289298, 'longitude': -73.980601},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '511 E 12th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['511 E 12th St', 'New York, NY 10009']},
#    'phone': '+19179977306',
#    'display_phone': '(917) 997-7306',
#    'distance': 2855.005616815332},
#   {'id': 'p6-X_mg5ETcUuV-X4RkPCg',
#    'alias': 'citroën-brooklyn',
#    'name': 'Citroën',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JxB9EP6Lc-9vKx_WZGwsmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/citro%C3%ABn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 76,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7312, 'longitude': -73.95459},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '931 Manhattan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['931 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17187342220',
#    'display_phone': '(718) 734-2220',
#    'distance': 4395.936778171056},
#   {'id': '8XHbZIKDQbXhyKIGiukVeQ',
#    'alias': 'boucherie-union-square-new-york-city',
#    'name': 'Boucherie Union Square',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1IVgirEX8ILPSKVfylIR2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boucherie-union-square-new-york-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 977,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73725824850519,
#     'longitude': -73.9882252705524},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '225 Park Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'New York City',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['225 Park Ave S', 'New York City, NY 10003']},
#    'phone': '+12123530200',
#    'display_phone': '(212) 353-0200',
#    'distance': 3574.2526799067864},
#   {'id': 'VpEy7E9fij06n7BRrzvEaw',
#    'alias': 'le-crocodile-brooklyn',
#    'name': 'Le Crocodile',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/36S2BKbamLSZoCiv0ZYggQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-crocodile-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 111,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72191, 'longitude': -73.957873},
#    'transactions': ['delivery'],
#    'location': {'address1': '80 Wythe Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Wythe Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17184608004',
#    'display_phone': '(718) 460-8004',
#    'distance': 3574.1437285922625},
#   {'id': '-qxQDGZc8Ejz7MUFlFWyuQ',
#    'alias': 'francie-brooklyn',
#    'name': 'Francie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TtEcF4qpMntgzngjecaR9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/francie-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71002578663716,
#     'longitude': -73.96405744314846},
#    'transactions': ['delivery'],
#    'location': {'address1': '134 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['134 Broadway', 'Brooklyn, NY 11249']},
#    'phone': '+17182187572',
#    'display_phone': '(718) 218-7572',
#    'distance': 2599.00204327148},
#   {'id': '0Q13lJ3OHXOuBVpN6jeTjw',
#    'alias': 'tartine-new-york',
#    'name': 'Tartine',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gcfu7rVH_F9puznQwnSgGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tartine-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1007,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7362899, 'longitude': -74.00344},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '253 W 11th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253 W 11th St', 'New York, NY 10014']},
#    'phone': '+12122292611',
#    'display_phone': '(212) 229-2611',
#    'distance': 3516.069880880911},
#   {'id': 'gtXP0CmOnBbgfnff7VXa7A',
#    'alias': 'pastis-new-york-3',
#    'name': 'Pastis',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3r_UeuwKiISls-w5h1xatA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pastis-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 295,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73928, 'longitude': -74.00695},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '52 Gansevoort St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['52 Gansevoort St', 'New York, NY 10014']},
#    'phone': '+12129294844',
#    'display_phone': '(212) 929-4844',
#    'distance': 3907.953101477796},
#   {'id': 'emTmnLlesIwxRofQ34ntdA',
#    'alias': 'juliette-brooklyn',
#    'name': 'Juliette',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EjtIS4UiTlJoK_Imdv_H_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/juliette-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 938,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71702, 'longitude': -73.959077},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '135C N 5th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['135C N 5th St', 'Brooklyn, NY 11249']},
#    'phone': '+17183889222',
#    'display_phone': '(718) 388-9222',
#    'distance': 3235.2904566609345},
#   {'id': 'kHeakps7Gj8EaImiOYaX8g',
#    'alias': 'le-french-diner-new-york',
#    'name': 'Le French Diner',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/obBvvGHF-vo-K6fY5LVEOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-french-diner-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 125,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7218274586187,
#     'longitude': -73.9879689992204},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '188 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['188 Orchard St', 'New York, NY 10002']},
#    'phone': '+12127771577',
#    'display_phone': '(212) 777-1577',
#    'distance': 1898.040906805897},
#   {'id': '3zbz9kLrLKHCBeGrNhMMGA',
#    'alias': 'l-accolade-new-york',
#    'name': "L'Accolade",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9tAqyS1eXxm2d31PkpyiYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-accolade-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 98,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.732484, 'longitude': -74.003915},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '302 Bleecker St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['302 Bleecker St', 'New York, NY 10014']},
#    'phone': '+19174091407',
#    'display_phone': '(917) 409-1407',
#    'distance': 3114.7853924865485},
#   {'id': 'CcxreLJbZsO6Z775-hMWpw',
#    'alias': 'st-tropez-west-village-new-york-3',
#    'name': 'St Tropez West Village',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/T4TolJBuIlUIoEWaWm091g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-tropez-west-village-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 202,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73704, 'longitude': -74.00386},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '304 W 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['304 W 4th St', 'New York, NY 10014']},
#    'phone': '+19173883893',
#    'display_phone': '(917) 388-3893',
#    'distance': 3606.8808422406223},
#   {'id': 'mJeKLz8GC4x6HGWNun1CNA',
#    'alias': 'bar-bête-brooklyn-2',
#    'name': 'Bar Bête',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sqTOo_n5UZE7804hqvUc7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-b%C3%AAte-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6830415993956,
#     'longitude': -73.9928337145761},
#    'transactions': ['delivery'],
#    'location': {'address1': '263 Smith St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['263 Smith St', 'Brooklyn, NY 11231']},
#    'phone': '+13478449950',
#    'display_phone': '(347) 844-9950',
#    'distance': 2494.1637090232457},
#   {'id': 'C6f_MQaRwIbJ8diailVaCA',
#    'alias': 'l-appart-new-york',
#    'name': "L'Appart",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/U7vx4eJJjfVWeOsqMMmNHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-appart-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 112,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.712708, 'longitude': -74.015919},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '225 Liberty St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10281',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['225 Liberty St', 'New York, NY 10281']},
#    'phone': '+12129818577',
#    'display_phone': '(212) 981-8577',
#    'distance': 1993.7205315842018},
#   {'id': '9pI_G9xGiTY4YCcfe9eoPA',
#    'alias': 'french-louie-brooklyn',
#    'name': 'French Louie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8mxpq3mYJnEzxi9wL0oCZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/french-louie-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 411,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6879459, 'longitude': -73.988257},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '320 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['320 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17189351200',
#    'display_phone': '(718) 935-1200',
#    'distance': 2011.2370367503813},
#   {'id': 'PszZvrDqzgPpl6SQuk3K9Q',
#    'alias': 'endswell-bar-and-bistro-brooklyn',
#    'name': 'Endswell Bar & Bistro',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rk6NmeZR7DZLcRm1JPv8vA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/endswell-bar-and-bistro-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 76,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68618, 'longitude': -73.97377},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '773 Fulton St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['773 Fulton St', 'Brooklyn, NY 11217']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2754.1920511788758},
#   {'id': 'xTnivXEdEtXrnhp-z4JGvg',
#    'alias': 'la-parisienne-new-york-5',
#    'name': 'La Parisienne',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ywbWsBIM-z7OHvhMoHUg5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-parisienne-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 606,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70961, 'longitude': -74.0093799},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '9 Maiden Ln',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Maiden Ln', 'New York, NY 10038']},
#    'phone': '+16467564911',
#    'display_phone': '(646) 756-4911',
#    'distance': 1350.1089630689858},
#   {'id': 'mv8dMMzzrzalso3sYCP_QA',
#    'alias': 'café-luluc-brooklyn-2',
#    'name': 'CAFÉ LULUc',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-DzDbYF-Qf3jxYy7pr8Q4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-luluc-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1479,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68451, 'longitude': -73.99225},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '214 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['214 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17186253815',
#    'display_phone': '(718) 625-3815',
#    'distance': 2334.479697543251},
#   {'id': 'csVEpHy5KJoFvM1qp5XwLQ',
#    'alias': 'le-parisien-new-york',
#    'name': 'Le Parisien',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qsfi62ltjD37wYVHDIJ72g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-parisien-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 989,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7454079308793,
#     'longitude': -73.9791478306885},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '163 East 33rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['163 East 33rd St', 'New York, NY 10016']},
#    'phone': '+12128895489',
#    'display_phone': '(212) 889-5489',
#    'distance': 4623.334586884622},
#   {'id': '9vYSRXdp5JtFmqhi0FigMA',
#    'alias': 'le-relais-de-venise-l-entrecôte-new-york-4',
#    'name': "Le Relais De Venise L'Entrecôte",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/e11i5l2yba8nf8II6zz-YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-relais-de-venise-l-entrec%C3%B4te-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 855,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7577089110773,
#     'longitude': -73.9717626571655},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '590 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['590 Lexington Ave', 'New York, NY 10022']},
#    'phone': '+12127583989',
#    'display_phone': '(212) 758-3989',
#    'distance': 6113.713201130883},
#   {'id': 'aTFkjo0scqmOgsFF5kuGXg',
#    'alias': 'claudette-new-york',
#    'name': 'Claudette',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/pwJMLXt_NosBimUAsY1Ubg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/claudette-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 444,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7331, 'longitude': -73.99596},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '24 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 5th Ave', 'New York, NY 10011']},
#    'phone': '+12128682424',
#    'display_phone': '(212) 868-2424',
#    'distance': 3095.2010285913057},
#   {'id': 'vRrVSB-LegwUwIxpkeRVtQ',
#    'alias': 'le-bernardin-new-york',
#    'name': 'Le Bernardin',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/c54rsVNmAhn_Ccz4tIXI_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-bernardin-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2592,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.761557, 'longitude': -73.981763},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '155 W 51st St',
#     'address2': '',
#     'address3': 'The Equitable Bldg',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['155 W 51st St',
#      'The Equitable Bldg',
#      'New York, NY 10019']},
#    'phone': '+12125541515',
#    'display_phone': '(212) 554-1515',
#    'distance': 6328.07179784047},
#   {'id': 'a8D87UlkkR3HixryrAay9w',
#    'alias': 'coco-bistro-peck-slip',
#    'name': 'Coco Bistro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1C-FOwG5-Ucsq2kloqVvEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coco-bistro-peck-slip?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 124,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70757, 'longitude': -74.00184},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '233-235 Front St',
#     'address2': None,
#     'address3': '',
#     'city': 'Peck Slip',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['233-235 Front St', 'Peck Slip, NY 10038']},
#    'phone': '+12123469090',
#    'display_phone': '(212) 346-9090',
#    'distance': 675.1486628106738},
#   {'id': 'nBkSqOhZMa1A7Yk3q8VPaA',
#    'alias': 'dirty-french-new-york',
#    'name': 'Dirty French',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CTbqztJCbUwZeFNdXxSW7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dirty-french-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 656,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72183, 'longitude': -73.98719},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '180 Ludlow St',
#     'address2': '',
#     'address3': 'Ludlow Hotel',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['180 Ludlow St',
#      'Ludlow Hotel',
#      'New York, NY 10002']},
#    'phone': '+12122543000',
#    'display_phone': '(212) 254-3000',
#    'distance': 1920.239232129666},
#   {'id': 'UJe9_p6NEl0kA6xHVo5PKw',
#    'alias': 'amelie-new-york-2',
#    'name': 'Amelie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Dn-MbEQvRT8HzHp_qTf-MQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amelie-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 243,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78875, 'longitude': -73.97464},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '566 Amsterdam Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['566 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+16464227167',
#    'display_phone': '(646) 422-7167',
#    'distance': 9411.937172965341},
#   {'id': 'Du4yrt8aWlBhOeEjhEH3ww',
#    'alias': 'st-tropez-soho-new-york-2',
#    'name': 'St Tropez - Soho',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zAlqB-hcZgrKvs5I-3Iblw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-tropez-soho-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 115,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72498, 'longitude': -74.00328},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '194 Spring St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['194 Spring St', 'New York, NY 10012']},
#    'phone': '+19172614441',
#    'display_phone': '(917) 261-4441',
#    'distance': 2298.546347742118},
#   {'id': 'mxDfu4bHwSXoCr3FRpyMsw',
#    'alias': 'l-antagoniste-brooklyn',
#    'name': "L'Antagoniste",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GngY4FPVFDXqjgIgEECOaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-antagoniste-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 292,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68501, 'longitude': -73.92961},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '238 Malcolm X Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['238 Malcolm X Blvd', 'Brooklyn, NY 11221']},
#    'phone': '+19179665300',
#    'display_phone': '(917) 966-5300',
#    'distance': 5902.707243878774},
#   {'id': 'aUakHsv3bAk6tDtLe96rIA',
#    'alias': 'lucien-new-york',
#    'name': 'Lucien',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oTvcMoBkFlzuDr_qxQS8wA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lucien-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 380,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72339, 'longitude': -73.98817},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '14 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 1st Ave', 'New York, NY 10009']},
#    'phone': '+12122606481',
#    'display_phone': '(212) 260-6481',
#    'distance': 2057.441375652483},
#   {'id': 'ZOfk6Ao0db5icjc0WEq7zg',
#    'alias': 'bacchus-bistro-and-wine-bar-brooklyn-2',
#    'name': 'Bacchus Bistro & Wine Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_m46oBmSGKhdddta9WoejA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bacchus-bistro-and-wine-bar-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 504,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68692, 'longitude': -73.98437},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '409-411 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['409-411 Atlantic Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17188521572',
#    'display_phone': '(718) 852-1572',
#    'distance': 2219.7594386413657},
#   {'id': 'eL1ojVz0QYCZ7xJOii46LQ',
#    'alias': 'papilles-new-york',
#    'name': 'Papilles',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tIIF1_MjIK1r0xMCu3rAIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/papilles-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 74,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.726467, 'longitude': -73.9839901},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '127 E 7th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['127 E 7th St', 'New York, NY 10009']},
#    'phone': '+16468505345',
#    'display_phone': '(646) 850-5345',
#    'distance': 2493.6284770281973},
#   {'id': 'LF2_slTY37P0Ua8vI4Hr5g',
#    'alias': 'bistro-les-amis-new-york',
#    'name': 'Bistro Les Amis',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fKtlMVwS9M8rGUw5fBgWHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistro-les-amis-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 402,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.724678, 'longitude': -74.002624},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '180 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['180 Spring St', 'New York, NY 10012']},
#    'phone': '+12122268645',
#    'display_phone': '(212) 226-8645',
#    'distance': 2250.934111586926},
#   {'id': 'g6R8iwi__IDy8plQy0v9WQ',
#    'alias': 'café-gitane-new-york-3',
#    'name': 'Café Gitane',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IZYz7cLHVGrGMMNKwaEsug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-gitane-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 715,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'moroccan', 'title': 'Moroccan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7231802723335,
#     'longitude': -73.9946175625656},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '242 Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['242 Mott St', 'New York, NY 10012']},
#    'phone': '+12123349552',
#    'display_phone': '(212) 334-9552',
#    'distance': 1972.2746550749027},
#   {'id': 'kmcgUxWhwlbmC-FAMTEF2g',
#    'alias': 'café-d-alsace-new-york-4',
#    'name': "Café D'Alsace",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FXKHmPuDc0MQZEn-ycGn7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-d-alsace-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1255,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77916, 'longitude': -73.95104},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1695 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1695 2nd Ave', 'New York, NY 10128']},
#    'phone': '+12127225133',
#    'display_phone': '(212) 722-5133',
#    'distance': 8969.946647972984},
#   {'id': 'EF4M55USa1ZNy1rP5Kuk2w',
#    'alias': 'chez-moi-brooklyn',
#    'name': 'Chez Moi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/R3yul6k8j3eZAdy7gySUSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chez-moi-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 412,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6907305802403, 'longitude': -73.99551244328},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '135 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['135 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+13472278337',
#    'display_phone': '(347) 227-8337',
#    'distance': 1639.3772843148975},
#   {'id': 'WoZnkXZInggzgQM_LbDpGg',
#    'alias': 'le-baratin-new-york',
#    'name': 'Le Baratin',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4oHEGTTARIHR4G4wLX9sQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-baratin-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 228,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.735025, 'longitude': -73.999857},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '26 Greenwich Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 Greenwich Ave', 'New York, NY 10011']},
#    'phone': '+12129331080',
#    'display_phone': '(212) 933-1080',
#    'distance': 3322.4105883919337},
#   {'id': 'NMVRHrkdp68twl4CWo1I5A',
#    'alias': 'marseille-new-york',
#    'name': 'Marseille',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/p0wr9T29_mYpX-tWKcEaZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marseille-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 962,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75980969121533,
#     'longitude': -73.99140518895494},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '630 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['630 9th Ave', 'New York, NY 10036']},
#    'phone': '+12123332323',
#    'display_phone': '(212) 333-2323',
#    'distance': 6049.982077600834},
#   {'id': 'npiIhpcWePbVT3JYEcy3zg',
#    'alias': 'wayan-new-york-4',
#    'name': 'Wayan',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tdkfOvfHX4OXUHj0CLv4aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wayan-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 350,
#    'categories': [{'alias': 'indonesian', 'title': 'Indonesian'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7213813139202,
#     'longitude': -73.9950757664721},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '20 Spring St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['20 Spring St', 'New York, NY 10012']},
#    'phone': '+19172614388',
#    'display_phone': '(917) 261-4388',
#    'distance': 1773.2774032172667},
#   {'id': 'zBButa4blgIhHru9B2qMrw',
#    'alias': 'café-paulette-brooklyn-4',
#    'name': 'Café Paulette',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ODp801QsEhCLrXfFeVvc6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-paulette-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 208,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6896094060701,
#     'longitude': -73.975917359407},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1 S Elliott Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 S Elliott Pl', 'Brooklyn, NY 11217']},
#    'phone': '+17188528582',
#    'display_phone': '(718) 852-8582',
#    'distance': 2345.285541733604},
#   {'id': 'CsZLG1VpdFAZiT_qRRmJ2A',
#    'alias': 'vin-sur-vingt-new-york-7',
#    'name': 'Vin Sur Vingt',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nxrRYgX8Fjn-WvuJlDC8CQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vin-sur-vingt-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 149,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.743927, 'longitude': -73.9887},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1140 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1140 Broadway', 'New York, NY 10001']},
#    'phone': '+16469227700',
#    'display_phone': '(646) 922-7700',
#    'distance': 4302.441155499942},
#   {'id': 'DU_DMCalguwdsnmLOJX3mg',
#    'alias': 'la-cigogne-brooklyn',
#    'name': 'La Cigogne ',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AUHodCQKBLgf4Efo7l1rDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-cigogne-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 377,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.683501, 'longitude': -73.999304},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '215 Union St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['215 Union St', 'Brooklyn, NY 11231']},
#    'phone': '+17188585641',
#    'display_phone': '(718) 858-5641',
#    'distance': 2473.626129266588}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#               Restaurant    Type Price Rating        Address        Lat  \
# 0                 Amélie  French   $$$    4.5    22 W 8th St  40.732700
# 1         La Sirène-Soho  French   $$$    4.5  558 Broome St  40.724364
# 2    La Grande Boucherie  French   $$$    4.5  145 W 53rd St  40.762627
# 3  Les Enfants de Boheme  French    $$    4.5   177 Henry St  40.713619
# 4         La Petite Joie  French               577 Union Ave  40.717700
#
#          Lng                                                url  \
# 0 -73.997660  https://www.yelp.com/biz/am%C3%A9lie-new-york?...
# 1 -74.005709  https://www.yelp.com/biz/la-sir%C3%A8ne-soho-n...
# 2 -73.980841  https://www.yelp.com/biz/la-grande-boucherie-n...
# 3 -73.988850  https://www.yelp.com/biz/les-enfants-de-boheme...
# 4 -73.952380
#
#                        ID
# 0  ETgJqJHV7BW6pIr9Ox74sA
# 1  FiRB9Ek3Xo9JHwXgBYITYg
# 2  DGhWO1sUWydVeR5j5ZZaMw
# 3  qOomR3AwClOGpV1HdqOTFg
# 4

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"french","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': 'Orbsfc3nI21mQ8cwSPahhg',
#    'alias': 'the-four-horsemen-brooklyn',
#    'name': 'The Four Horsemen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_HpgmmeSN9qK2hdPa8S-7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-four-horsemen-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 212,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71305, 'longitude': -73.95732},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '295 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['295 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17185994900',
#    'display_phone': '(718) 599-4900',
#    'distance': 3234.4709420444497},
#   {'id': 'BA6wd1pZTVu1DmrtiyTs8g',
#    'alias': 'raouls-restaurant-new-york',
#    'name': "Raoul's Restaurant",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FZ1-90qvE18T7hvDnVYmbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raouls-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 537,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72615, 'longitude': -74.00216},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '180 Prince St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['180 Prince St', 'New York, NY 10012']},
#    'phone': '+12129663518',
#    'display_phone': '(212) 966-3518',
#    'distance': 2397.616235487115},
#   {'id': 'g5f6p9jfzB30Mhcu6d5OWA',
#    'alias': 'petite-boucherie-new-york',
#    'name': 'Petite Boucherie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0j89ZVH23hB-RNWgkOZfNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/petite-boucherie-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 167,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73382, 'longitude': -74.00042},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '14 Christopher St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 Christopher St', 'New York, NY 10014']},
#    'phone': '+16467564145',
#    'display_phone': '(646) 756-4145',
#    'distance': 3198.5619536252693},
#   {'id': 'IVjpsmmsgc42k9K2RZR3Qg',
#    'alias': 'le-fond-brooklyn',
#    'name': 'Le Fond',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uljNBGtir-KG4rLDgoWdhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-fond-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 156,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7258415222168,
#     'longitude': -73.9511032104492},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '105 Norman Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['105 Norman Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183896859',
#    'display_phone': '(718) 389-6859',
#    'distance': 4288.698320926473},
#   {'id': '49ST--X1jcIPzUIM1O3K6w',
#    'alias': 'mominette-brooklyn-2',
#    'name': 'Mominette',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SClcXzYF9awG33Iya6weKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mominette-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 712,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.703252, 'longitude': -73.925889},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '221 Knickerbocker Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['221 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#    'phone': '+19292342941',
#    'display_phone': '(929) 234-2941',
#    'distance': 5781.762228266177},
#   {'id': 'TQzGf4k3HXyMbnNkYKKQSw',
#    'alias': 'oxalis-brooklyn',
#    'name': 'Oxalis',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6Yw9Awhdciq9NLilWt4vBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oxalis-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 160,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.673109, 'longitude': -73.9626279},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '791 Washington Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['791 Washington Ave', 'Brooklyn, NY 11238']},
#    'phone': '+13476278298',
#    'display_phone': '(347) 627-8298',
#    'distance': 4478.416202887657},
#   {'id': 'A8zppFZvBDGUKRSUrzJWMg',
#    'alias': 'chez-josephine-new-york',
#    'name': 'Chez Josephine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/P2LNtGgz0k6Zx8Xgaxd9fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chez-josephine-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 514,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.758502, 'longitude': -73.993413},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '414 W 42nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['414 W 42nd St', 'New York, NY 10036']},
#    'phone': '+12125941925',
#    'display_phone': '(212) 594-1925',
#    'distance': 5896.5432859375605},
#   {'id': 'mjGdtrh0tX7I91GM9dlMNg',
#    'alias': 'mimi-new-york-3',
#    'name': 'MIMI',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9fZgOHTpDmxs-CSmUPa3Lw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mimi-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 150,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7283483, 'longitude': -74.0006612},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '185 Sullivan St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['185 Sullivan St', 'New York, NY 10012']},
#    'phone': '+12124181260',
#    'display_phone': '(212) 418-1260',
#    'distance': 2602.678421417576},
#   {'id': '6S62Z7e0UP82shutXERUzA',
#    'alias': 'cafe-du-soleil-new-york',
#    'name': 'Cafe Du Soleil',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Egv0TndluCUltUmbdD98Ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-du-soleil-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 479,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.8000739, 'longitude': -73.9682123},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2723 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2723 Broadway', 'New York, NY 10025']},
#    'phone': '+12123165000',
#    'display_phone': '(212) 316-5000',
#    'distance': 10749.150338962874},
#   {'id': 'JUGgD5WXc8eU5MoBKrfSGA',
#    'alias': 'l-atelier-de-joël-robuchon-new-york-5',
#    'name': "L'Atelier de Joël Robuchon",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eOgBCPrYwagu4hOcqriEgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-atelier-de-jo%C3%ABl-robuchon-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 142,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.743052, 'longitude': -74.007872},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '85 10th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 10th Ave', 'New York, NY 10011']},
#    'phone': '+12124888885',
#    'display_phone': '(212) 488-8885',
#    'distance': 4335.452616506238},
#   {'id': 'HUEj_yVB1E2mNNxW5PqUtQ',
#    'alias': 'bistro-vendome-new-york',
#    'name': 'Bistro Vendome',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-bzTmjpGN3X1FTCjjCd0pA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistro-vendome-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 152,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7588875, 'longitude': -73.961963},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '405 East 58th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['405 East 58th St', 'New York, NY 10022']},
#    'phone': '+12129359100',
#    'display_phone': '(212) 935-9100',
#    'distance': 6537.182664330528},
#   {'id': '3y_-DwmoM198umnZHSOmKQ',
#    'alias': 'yves-new-york-2',
#    'name': 'Yves',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NKAjMbPLx2OjaJN_vbUW3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yves-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72021, 'longitude': -74.00996},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '385 Greenwich St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['385 Greenwich St', 'New York, NY 10013']},
#    'phone': '+12124313385',
#    'display_phone': '(212) 431-3385',
#    'distance': 2102.5846400489295},
#   {'id': '8xYvp9j7j8RCRQGsiRRujQ',
#    'alias': 'la-bergamote-nyc-new-york',
#    'name': 'La Bergamote NYC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/f1XkG1aI8OxqSjYZEGpg3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-bergamote-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 359,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.745044, 'longitude': -74.002863},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '177 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['177 9th Ave', 'New York, NY 10011']},
#    'phone': '+12126279010',
#    'display_phone': '(212) 627-9010',
#    'distance': 4461.894981676772},
#   {'id': 'fAPkN79fe7Gjq7A6fj6s9Q',
#    'alias': 'bistro-eloise-east-elmhurst',
#    'name': 'Bistro Eloise',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LoByrmXEi4koh9i14Ngf2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistro-eloise-east-elmhurst?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 201,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7587335, 'longitude': -73.8920429},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '75-57 31st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'East Elmhurst',
#     'zip_code': '11370',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75-57 31st Ave', 'East Elmhurst, NY 11370']},
#    'phone': '+17184409493',
#    'display_phone': '(718) 440-9493',
#    'distance': 10534.639737504942},
#   {'id': 'tmzWZtu9Nimn7Hfas9XmcA',
#    'alias': 'quality-bistro-new-york-3',
#    'name': 'Quality Bistro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/x8jIDTRfgNYfkEUIRKHYDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/quality-bistro-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 105,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76306, 'longitude': -73.9786},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '120 W 55th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['120 W 55th St', 'New York, NY 10019']},
#    'phone': '+12124333330',
#    'display_phone': '(212) 433-3330',
#    'distance': 6530.075284620907},
#   {'id': '7-n32xMWRYbJpy-pVm132Q',
#    'alias': 'la-baraka-restaurant-little-neck',
#    'name': 'La Baraka Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UewUaPan2qTZ18wWa70Cgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-baraka-restaurant-little-neck?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 157,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'african', 'title': 'African'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77235, 'longitude': -73.73442},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '25509 Northern Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Little Neck',
#     'zip_code': '11362',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25509 Northern Blvd', 'Little Neck, NY 11362']},
#    'phone': '+17184281461',
#    'display_phone': '(718) 428-1461',
#    'distance': 23125.184668346632},
#   {'id': '8ucQ3A7f6h9_PkKStYBkQA',
#    'alias': 'lalou-brooklyn',
#    'name': 'LaLou',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LZnjnHumh3h5FTN-O0SB4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lalou-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.680311, 'longitude': -73.967596},
#    'transactions': ['delivery'],
#    'location': {'address1': '581 Vanderbilt Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['581 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17188579463',
#    'display_phone': '(718) 857-9463',
#    'distance': 3586.3868798584126},
#   {'id': 'ATQDTQu3SsCetuG-byzOFg',
#    'alias': 'cafe-gitane-brooklyn',
#    'name': 'Cafe Gitane',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OveEa94egfLWCN5HgIFrRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-gitane-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'moroccan', 'title': 'Moroccan'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7028272982236,
#     'longitude': -73.9812811999999},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '70 Hudson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70 Hudson Ave', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1134.8131488276106},
#   {'id': '7uGPAk8ELYABSzZhXhj7tA',
#    'alias': 'le-gigot-new-york',
#    'name': 'Le Gigot',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GJZNVXkzvnf7tiaOBc2ocw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-gigot-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 210,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7314099, 'longitude': -74.00197},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '18 Cornelia St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18 Cornelia St', 'New York, NY 10014']},
#    'phone': '+12126273737',
#    'display_phone': '(212) 627-3737',
#    'distance': 2949.5670912279784},
#   {'id': 'l2b6HJGarUxoeLnM9syTmg',
#    'alias': 'compagnie-des-vins-surnaturels-new-york-2',
#    'name': 'Compagnie des Vins Surnaturels',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3-XFmswZUjzpJb6y6OmOHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/compagnie-des-vins-surnaturels-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 125,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7205157, 'longitude': -73.9981652},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '249 Ctr St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['249 Ctr St', 'New York, NY 10013']},
#    'phone': '+12123433660',
#    'display_phone': '(212) 343-3660',
#    'distance': 1707.2795423406862},
#   {'id': 'DhBhEWMVLDxYF14a1znUvA',
#    'alias': 'lighthouse-brooklyn-2',
#    'name': 'Lighthouse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y3zbJj3MQK-MUXnymqwBpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lighthouse-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 270,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7104080536563,
#     'longitude': -73.9539040490168},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '145 Borinquen Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['145 Borinquen Pl', 'Brooklyn, NY 11211']},
#    'phone': '+13477897742',
#    'display_phone': '(347) 789-7742',
#    'distance': 3448.867236343932},
#   {'id': '0Q3xCYWK2N-wJfXjLa9dFg',
#    'alias': 'bâtard-new-york',
#    'name': 'Bâtard',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pg_CyIMJxC47x_ZOi7uxXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b%C3%A2tard-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 423,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71958, 'longitude': -74.00581},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '239 West Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['239 West Broadway', 'New York, NY 10013']},
#    'phone': '+12122192777',
#    'display_phone': '(212) 219-2777',
#    'distance': 1835.005105739778},
#   {'id': 't2h_VDI6kw7c1uHvyV-Grw',
#    'alias': 'brasserie-saint-marc-new-york',
#    'name': 'Brasserie Saint Marc',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/A6TFDahpJLhikdpOZsreqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brasserie-saint-marc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7286485, 'longitude': -73.98720783},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '136 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12125483959',
#    'display_phone': '(212) 548-3959',
#    'distance': 2652.881199056852},
#   {'id': 'OsA5iRphHwPlYNhdddvBng',
#    'alias': 'june-brooklyn-3',
#    'name': 'June',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1dZlWIzH26L-BAd0yF7tJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/june-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 189,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68606512542637,
#     'longitude': -73.99388911165558},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '231 Court St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 Court St', 'Brooklyn, NY 11201']},
#    'phone': '+19179090434',
#    'display_phone': '(917) 909-0434',
#    'distance': 2155.1955507472085},
#   {'id': 'GVGhfMMEw2TrDh-GGVTUmA',
#    'alias': 'le-french-tart-deli-new-york',
#    'name': 'Le French Tart Deli',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ncPhQvoYvsyiMga5TTrLPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-french-tart-deli-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'macarons', 'title': 'Macarons'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.683691, 'longitude': -73.995502},
#    'transactions': ['delivery'],
#    'location': {'address1': '306 Court St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['306 Court St', 'New York, NY 11231']},
#    'phone': '+13479160014',
#    'display_phone': '(347) 916-0014',
#    'distance': 2418.167362234124},
#   {'id': '1A3m0-dOhF2PKRU_8S2YYQ',
#    'alias': 'le-prive-new-york-2',
#    'name': 'Le Prive',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QZffuCy7_IeajXLzAnuWjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-prive-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 186,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76108, 'longitude': -73.99419},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '626 10th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['626 10th Ave', 'New York, NY 10036']},
#    'phone': '+12128372795',
#    'display_phone': '(212) 837-2795',
#    'distance': 6191.744528375467},
#   {'id': 'fFkqEyupjc5x2iJQIPcpLw',
#    'alias': 'ruffian-new-york-4',
#    'name': 'Ruffian',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0UFfPVtjZ2PAEJd0gx7rtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ruffian-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 230,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7264, 'longitude': -73.98411},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '125 E 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['125 E 7th St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2487.011426980985},
#   {'id': 'kMljfja7weqfl_lzspjzHA',
#    'alias': 'cafe-cluny-new-york-3',
#    'name': 'Cafe Cluny',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/C4mRJFgdeiKj59c2UuwDMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-cluny-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 762,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.737385, 'longitude': -74.003966},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '284 W 12th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['284 W 12th St', 'New York, NY 10014']},
#    'phone': '+12122556900',
#    'display_phone': '(212) 255-6900',
#    'distance': 3643.9243748335875},
#   {'id': 'uby3glEc0Brt9LAoCI0WTg',
#    'alias': 'l-express-new-york-44',
#    'name': 'L’Express',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2l4QsY9mcV8S0XApfhyBzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-express-new-york-44?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 838,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.738162056865, 'longitude': -73.987657},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '249 Park Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['249 Park Ave S', 'New York, NY 10003']},
#    'phone': '+12122545858',
#    'display_phone': '(212) 254-5858',
#    'distance': 3680.716767754624},
#   {'id': 'hmdm-dO72hLsMQwQRcGEUQ',
#    'alias': 'atrium-dumbo-brooklyn',
#    'name': 'Atrium Dumbo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VUzaLCgAu6qYRSsVGZTDVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/atrium-dumbo-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 669,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7033899, 'longitude': -73.9904923},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '15 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Main St', 'Brooklyn, NY 11201']},
#    'phone': '+17188581095',
#    'display_phone': '(718) 858-1095',
#    'distance': 391.3077959872246},
#   {'id': 'dAHoDxBmzWqfobnTbCHaQA',
#    'alias': 'frenchette-new-york-2',
#    'name': 'Frenchette',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CnW76JbibPSSLu2-AjqOUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frenchette-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 267,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71964, 'longitude': -74.00578},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '241 W Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['241 W Broadway', 'New York, NY 10013']},
#    'phone': '+12123343883',
#    'display_phone': '(212) 334-3883',
#    'distance': 1843.3790726734544},
#   {'id': 'P2CTp4xyaNCe2AXSiLeOSQ',
#    'alias': 'the-odeon-new-york',
#    'name': 'The Odeon',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZCaQpdFP6sIzzaW2eO4yfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-odeon-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 676,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71692, 'longitude': -74.00792},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '145 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['145 W Broadway', 'New York, NY 10013']},
#    'phone': '+12122330507',
#    'display_phone': '(212) 233-0507',
#    'distance': 1709.5396927212962},
#   {'id': 'DZaN3bNWfwcm__sNw5bvDg',
#    'alias': 'daniel-new-york-4',
#    'name': 'Daniel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8NEPw6Mn1Oa7NdcAlweHAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daniel-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1671,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7667736797858, 'longitude': -73.967607},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '60 E 65th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 E 65th St', 'New York, NY 10065']},
#    'phone': '+12122880033',
#    'display_phone': '(212) 288-0033',
#    'distance': 7180.552592897932},
#   {'id': '4XX-zF8h5Lvrr22_tqU6-Q',
#    'alias': 'the-river-café-brooklyn-3',
#    'name': 'The River Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/X5pxv0ydhNP7kPBDArEHsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-river-caf%C3%A9-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1166,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70318, 'longitude': -73.9946499},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '1 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+17185225200',
#    'display_phone': '(718) 522-5200',
#    'distance': 252.24127844020637},
#   {'id': 'ArfL-sU2FaB73WV1qQ4c6Q',
#    'alias': 'simple-cafe-and-restaurant-brooklyn',
#    'name': 'Simple Cafe & Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/efMJDc2PMl7AVJ6_MMiuJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/simple-cafe-and-restaurant-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 190,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71244, 'longitude': -73.96275},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '346 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['346 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17182187067',
#    'display_phone': '(718) 218-7067',
#    'distance': 2764.7945828233073},
#   {'id': '1DfbZ0VsSCg9g1KILmnvzQ',
#    'alias': 'per-se-new-york',
#    'name': 'Per Se',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/531LmZ0PjJD523UNhldWjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/per-se-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1690,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7681528889558,
#     'longitude': -73.9827629623657},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '10 Columbus Cir',
#     'address2': 'Fl 4',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10 Columbus Cir', 'Fl 4', 'New York, NY 10019']},
#    'phone': '+12128239335',
#    'display_phone': '(212) 823-9335',
#    'distance': 7040.1550537017865},
#   {'id': 'OppTOs3uBwOG29yF45lb8A',
#    'alias': 'mister-french-new-york',
#    'name': 'Mister French',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DIQ__mwlO1289IfCLh5p4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mister-french-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7219571708362,
#     'longitude': -73.9937923103571},
#    'transactions': ['delivery'],
#    'location': {'address1': '218 Bowery',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['218 Bowery', 'New York, NY 10012']},
#    'phone': '+16466494805',
#    'display_phone': '(646) 649-4805',
#    'distance': 1836.567960430796},
#   {'id': 'iQB37FNqD_G5_QMrp9ovnw',
#    'alias': 'jadis-new-york',
#    'name': 'Jadis',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Wrbv-pxZM-jwvAzATjLxPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jadis-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 499,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7210234741789,
#     'longitude': -73.9910054106201},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '42 Rivington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 Rivington St', 'New York, NY 10002']},
#    'phone': '+12122541675',
#    'display_phone': '(212) 254-1675',
#    'distance': 1754.284879719958},
#   {'id': 'M85t-iOAbMpO9mVIKAgwMw',
#    'alias': 'le-garage-brooklyn',
#    'name': 'Le Garage',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/I48IZ2yKiGxZKqi3oe1A_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-garage-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 164,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6993863968861,
#     'longitude': -73.9265948743181},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '157 Suydam St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['157 Suydam St', 'Brooklyn, NY 11221']},
#    'phone': '+13472951700',
#    'display_phone': '(347) 295-1700',
#    'distance': 5746.428087621073},
#   {'id': '7flJeg5Tnc06cQQ7jnBtxg',
#    'alias': 'barnea-bistro-new-york',
#    'name': 'Barnea Bistro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Yuv-h7ALDiCrnpmtR9YkCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barnea-bistro-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75314, 'longitude': -73.97179},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '211 E 46th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['211 E 46th St', 'New York, NY 10017']},
#    'phone': '+12124611001',
#    'display_phone': '(212) 461-1001',
#    'distance': 5639.3849273001215},
#   {'id': 'TCJrcryBkI6eg2HYThoiKg',
#    'alias': 'petite-crevette-brooklyn',
#    'name': 'Petite Crevette',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HhnCUa1fzQ2o4c4c9rnGHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/petite-crevette-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 326,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68396, 'longitude': -74.0018},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '144 Union St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['144 Union St', 'Brooklyn, NY 11231']},
#    'phone': '+17188552632',
#    'display_phone': '(718) 855-2632',
#    'distance': 2477.863579971962},
#   {'id': '50fWXrNECQQYght4ZWeBXQ',
#    'alias': 'taureau-new-york',
#    'name': 'Taureau',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mwRVqEkCw64zN0QIotayKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taureau-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 576,
#    'categories': [{'alias': 'fondue', 'title': 'Fondue'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.724511, 'longitude': -74.005701},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '558 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['558 Broome St', 'New York, NY 10013']},
#    'phone': '+12122282222',
#    'display_phone': '(212) 228-2222',
#    'distance': 2331.955595765452},
#   {'id': 'EaNRl3vlDOsNF-gkCR5mBA',
#    'alias': 'la-sirène-uws-new-york',
#    'name': 'La Sirène-UWS',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VX7A3oUMnKc9OMtTbzbAMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-sir%C3%A8ne-uws-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 93,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7838, 'longitude': -73.97806},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '416 Amsterdam Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['416 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+19172615279',
#    'display_phone': '(917) 261-5279',
#    'distance': 8822.359183379458},
#   {'id': 'uBGjcW-GuYy_qSvMykuISA',
#    'alias': 'pommes-frites-new-york-2',
#    'name': 'Pommes Frites',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vVHlbwaAf7v1yrdf3Eibvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pommes-frites-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 991,
#    'categories': [{'alias': 'belgian', 'title': 'Belgian'},
#     {'alias': 'gourmet', 'title': 'Specialty Food'},
#     {'alias': 'poutineries', 'title': 'Poutineries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.730022, 'longitude': -74.000152},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '128 Macdougal St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['128 Macdougal St', 'New York, NY 10012']},
#    'phone': '+12126741234',
#    'display_phone': '(212) 674-1234',
#    'distance': 2784.525199027455},
#   {'id': 'hD55NUiGDK7STQ8oy9QDPA',
#    'alias': 'le-monde-new-york-5',
#    'name': 'Le Monde',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p9cHsf5MPyoNHZlMjJ2EqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-monde-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 504,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.8058021, 'longitude': -73.9658246},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2885 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2885 Broadway', 'New York, NY 10025']},
#    'phone': '+12125313939',
#    'display_phone': '(212) 531-3939',
#    'distance': 11421.89714735843},
#   {'id': 'KIIYvTOc0Uv90aUHEGvoSg',
#    'alias': 'la-grenouille-new-york',
#    'name': 'La Grenouille',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B0wtJS_2H9ves6JHtEIGKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-grenouille-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 446,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75972, 'longitude': -73.97555},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '3 E 52nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3 E 52nd St', 'New York, NY 10022']},
#    'phone': '+12127521495',
#    'display_phone': '(212) 752-1495',
#    'distance': 6233.541641585679},
#   {'id': '9vQca1DMqfbDGssiqEd6Hw',
#    'alias': 'le-gamin-brooklyn',
#    'name': 'Le Gamin',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RH9X-2HbL2E0IKx_OOXZbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-gamin-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 224,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.728299, 'longitude': -73.957153},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '108 Franklin St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['108 Franklin St', 'Brooklyn, NY 11222']},
#    'phone': '+17187707918',
#    'display_phone': '(718) 770-7918',
#    'distance': 4031.8532108675718},
#   {'id': 'Ps0cOZevNA1M9M5_z7W3oQ',
#    'alias': 'joseph-leonard-new-york',
#    'name': 'Joseph Leonard',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JeyJlPox7ecO16MXImNZiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joseph-leonard-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 679,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7336021670705,
#     'longitude': -74.001675412843},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '170 Waverly Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['170 Waverly Pl', 'New York, NY 10014']},
#    'phone': '+16464298383',
#    'display_phone': '(646) 429-8383',
#    'distance': 3192.1593151240463},
#   {'id': 'Gc7OVEIs4HodL4hw9U3C3w',
#    'alias': 'copinette-new-york-3',
#    'name': 'Copinette',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_S8coii-sUY_mD7_7hXK-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/copinette-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 167,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75407, 'longitude': -73.96623},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '891 1st Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['891 1st Ave', 'New York, NY 10022']},
#    'phone': '+12129034001',
#    'display_phone': '(212) 903-4001',
#    'distance': 5908.593694327018},
#   {'id': 'nw5_0jb_u2a6nUt4Je09Xg',
#    'alias': 'casa-del-chef-bistro-woodside-2',
#    'name': 'Casa Del Chef Bistro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2PXm5h90gVDijuU_XBFd7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-del-chef-bistro-woodside-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 218,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.746291, 'longitude': -73.900092},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '39-06 1/2 64th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39-06 1/2 64th St', 'Woodside, NY 11377']},
#    'phone': '+17184579000',
#    'display_phone': '(718) 457-9000',
#    'distance': 9146.03783383254}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#            Restaurant       Type Price Rating                Address  \
# 0   The Four Horsemen  Wine Bars    $$    4.5           295 Grand St
# 1  Raoul's Restaurant     French   $$$      4          180 Prince St
# 2    Petite Boucherie     French   $$$    4.5      14 Christopher St
# 3             Le Fond     French    $$    4.5         105 Norman Ave
# 4           Mominette     French    $$      4  221 Knickerbocker Ave
#
#          Lat        Lng                                                url  \
# 0  40.713050 -73.957320  https://www.yelp.com/biz/the-four-horsemen-bro...
# 1  40.726150 -74.002160  https://www.yelp.com/biz/raouls-restaurant-new...
# 2  40.733820 -74.000420  https://www.yelp.com/biz/petite-boucherie-new-...
# 3  40.725842 -73.951103  https://www.yelp.com/biz/le-fond-brooklyn?adju...
# 4  40.703252 -73.925889  https://www.yelp.com/biz/mominette-brooklyn-2?...
#
#                        ID
# 0  Orbsfc3nI21mQ8cwSPahhg
# 1  BA6wd1pZTVu1DmrtiyTs8g
# 2  g5f6p9jfzB30Mhcu6d5OWA
# 3  IVjpsmmsgc42k9K2RZR3Qg
# 4  49ST--X1jcIPzUIM1O3K6w

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"french","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': '3qf3FLXxVdX3Wz5F_rTeog',
#    'alias': 'bar-tabac-brooklyn',
#    'name': 'Bar Tabac',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LAUXkb8EzsZqAmQmedk9sA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-tabac-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 600,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.68736766240864,
#     'longitude': -73.99028494341295},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '128 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['128 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17189230918',
#    'display_phone': '(718) 923-0918',
#    'distance': 2038.2968199377308},
#   {'id': 'sHSCUGKAUR9gYThXlginkA',
#    'alias': 'bar-blondeau-brooklyn',
#    'name': 'Bar Blondeau',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/X1blkXJ2oOau-IM1F_XJEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-blondeau-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72208, 'longitude': -73.95785},
#    'transactions': [],
#    'location': {'address1': '80 Wythe Ave',
#     'address2': 'Ste 6',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Wythe Ave', 'Ste 6', 'Brooklyn, NY 11249']},
#    'phone': '+17184608006',
#    'display_phone': '(718) 460-8006',
#    'distance': 3558.1145634571285},
#   {'id': 'PMJOGt8QQmo-2A4DnUcmZQ',
#    'alias': 'liberty-bistro-new-york-3',
#    'name': 'Liberty Bistro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9rrC16-LUwm1y3uw6fKVmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/liberty-bistro-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.712344, 'longitude': -74.015511},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '225 Liberty St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10080',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['225 Liberty St', 'New York, NY 10080']},
#    'phone': '+12129818588',
#    'display_phone': '(212) 981-8588',
#    'distance': 1906.7703404306988},
#   {'id': 'pDwhlX9jNBGnjvyGR9jYWQ',
#    'alias': 'gabriel-kreuther-new-york',
#    'name': 'Gabriel Kreuther',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1tj5zYaAbSk1K_RM_KsKWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gabriel-kreuther-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 507,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.754546, 'longitude': -73.982556},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '41 W 42nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41 W 42nd St', 'New York, NY 10036']},
#    'phone': '+12122575826',
#    'display_phone': '(212) 257-5826',
#    'distance': 5548.644552027803},
#   {'id': 'qLL_x4uzDHCgXd9lwaGxjw',
#    'alias': 'frevo-new-york',
#    'name': 'Frevo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HV2GNtOkyilTm_DQauuHlg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frevo-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73313, 'longitude': -73.99867},
#    'transactions': ['delivery'],
#    'location': {'address1': '48 W 8th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['48 W 8th St', 'New York, NY 10011']},
#    'phone': '+16464550804',
#    'display_phone': '(646) 455-0804',
#    'distance': 3088.456542750878},
#   {'id': 'hpRrYBbKUqv8ewFKDjbjoA',
#    'alias': 'gersi-brooklyn',
#    'name': 'Gersi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aWJFBchETG6OWGVHj5aONg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gersi-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 292,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.683438, 'longitude': -73.995711},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '316 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['316 Court St', 'Brooklyn, NY 11231']},
#    'phone': '+13478895077',
#    'display_phone': '(347) 889-5077',
#    'distance': 2450.871323793601},
#   {'id': '5XQgZQF-5N94bkQ2d_PJIQ',
#    'alias': 'pascalou-new-york',
#    'name': 'Pascalou',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gc-qEsUZHElhtBwTURv6Qg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pascalou-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 247,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78521, 'longitude': -73.95595},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1308 Madison Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1308 Madison Ave', 'New York, NY 10128']},
#    'phone': '+12125347522',
#    'display_phone': '(212) 534-7522',
#    'distance': 9435.687144807547},
#   {'id': 'wDLHOgux_G8Y82Y6D9rSog',
#    'alias': 'maison-sun-new-york',
#    'name': 'Maison Sun',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JOWc353zZ9xglvZcWrwFiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maison-sun-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72612, 'longitude': -74.002068},
#    'transactions': ['restaurant_reservation'],
#    'location': {'address1': '178 Prince St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['178 Prince St', 'New York, NY 10012']},
#    'phone': '+19177909689',
#    'display_phone': '(917) 790-9689',
#    'distance': 2395.0555795457144},
#   {'id': 'ILwCoB-PD8n9ObGk_sac0A',
#    'alias': 'recette-brooklyn',
#    'name': 'Recette',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/agIFpo0qG-x4llgSGejMDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/recette-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71326399774355,
#     'longitude': -73.95637202012806},
#    'transactions': [],
#    'location': {'address1': '103 Havemeyer St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 Havemeyer St', 'Brooklyn, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3312.4711434948194},
#   {'id': '7N6Jle8ovxzAiiwwtE77Yw',
#    'alias': 'le-pavillon-new-york',
#    'name': 'Le Pavillon',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YZJGsg8PD_r515XygWAf8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-pavillon-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7524571, 'longitude': -73.978131},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': 'One Vanderbilt Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['One Vanderbilt Ave', 'New York, NY 10017']},
#    'phone': '+12126621000',
#    'display_phone': '(212) 662-1000',
#    'distance': 5452.753981309788},
#   {'id': 'O64wSq9NvecPNPRkz38o8Q',
#    'alias': 'madame-claude-bis-jersey-city',
#    'name': 'Madame Claude Bis',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UD-ZyIoUlQE2URrAe476hA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/madame-claude-bis-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 213,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72473095928894,
#     'longitude': -74.05183738424924},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '390 4th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['390 4th St', 'Jersey City, NJ 07302']},
#    'phone': '+12018768800',
#    'display_phone': '(201) 876-8800',
#    'distance': 5302.881802370037},
#   {'id': 'GBJOu9Rk4JqqWjB8ddYudw',
#    'alias': 'la-mercerie-new-york',
#    'name': 'La Mercerie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/69iYfOxtWqdGyWtUh99vDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-mercerie-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 238,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7202236743825,
#     'longitude': -74.0021909441629},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '53 Howard St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['53 Howard St', 'New York, NY 10013']},
#    'phone': '+12128529097',
#    'display_phone': '(212) 852-9097',
#    'distance': 1773.0256600230534},
#   {'id': 'PYcL2z9gHj6-ZTlViT9Nqw',
#    'alias': 'minetta-tavern-new-york',
#    'name': 'Minetta Tavern',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uMGD3p2lKLGfa3F5-FZxyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/minetta-tavern-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2259,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7300047976758,
#     'longitude': -74.0006073834151},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '113 Macdougal St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['113 Macdougal St', 'New York, NY 10012']},
#    'phone': '+12124753850',
#    'display_phone': '(212) 475-3850',
#    'distance': 2782.3006101825745},
#   {'id': 'lAwfazjM5ot64O4A6EAjjQ',
#    'alias': 'le-succulent-brooklyn-2',
#    'name': 'Le Succulent',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4StjLv6AF0ASwJnPJFh_iQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-succulent-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 108,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'african', 'title': 'African'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67356, 'longitude': -73.98247},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '291 5th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['291 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+13472278282',
#    'display_phone': '(347) 227-8282',
#    'distance': 3692.583911633529},
#   {'id': 'RdjykuwofIdvPTwohJeulw',
#    'alias': 'maman-rockefeller-new-york',
#    'name': 'Maman Rockefeller',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BnzT8OPw8ptxxJB7BEDLSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maman-rockefeller-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75754502006123, 'longitude': -73.9791089},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '12 W 48th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['12 W 48th St', 'New York, NY 10036']},
#    'phone': '+12128849337',
#    'display_phone': '(212) 884-9337',
#    'distance': 5932.866671859275},
#   {'id': 'hiTfA7vnxDSLv77nl6UQXQ',
#    'alias': 'st-anselm-brooklyn',
#    'name': 'St. Anselm',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8gro6PlGJ3qAQnKjskgTjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-anselm-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 869,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7143299, 'longitude': -73.95604},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '355 Metropolitan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['355 Metropolitan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17183845054',
#    'display_phone': '(718) 384-5054',
#    'distance': 3369.1594687967336},
#   {'id': 'bQPU31GkNo3TkPnq7iSngg',
#    'alias': 'jubilee-new-york-2',
#    'name': 'Jubilee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uAyg-D_NoUazhuSFfCWLbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jubilee-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 218,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75523, 'longitude': -73.965164},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '948 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['948 1st Ave', 'New York, NY 10022']},
#    'phone': '+12128883569',
#    'display_phone': '(212) 888-3569',
#    'distance': 6055.5878025846505},
#   {'id': 'fSQ3CCtFSJ2S8VXDi02-3Q',
#    'alias': 'cafe-luxembourg-new-york',
#    'name': 'Cafe Luxembourg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Wh-4j7J-Wh8cUh2CHq5L-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-luxembourg-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 533,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77741, 'longitude': -73.98312},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '200 W 70th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 W 70th St', 'New York, NY 10023']},
#    'phone': '+12128737411',
#    'display_phone': '(212) 873-7411',
#    'distance': 8053.065658829433},
#   {'id': '8vDBwBThldNxqvQ7ur1Uzw',
#    'alias': 'risbo-brooklyn-3',
#    'name': 'Risbo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RcimXd-Uei30QTuYTC2kPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/risbo-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 197,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6560593, 'longitude': -73.9597273},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '701 Flatbush Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11225',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['701 Flatbush Ave', 'Brooklyn, NY 11225']},
#    'phone': '+13474259116',
#    'display_phone': '(347) 425-9116',
#    'distance': 6217.037023595736},
#   {'id': 'nlmFAz_93gjSUfmvmv8Tog',
#    'alias': 'le-grainne-cafe-new-york',
#    'name': 'Le Grainne Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JkuMD9fKS7yvSGj0qbTNhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-grainne-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 621,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7454064780449,
#     'longitude': -74.0024026704959},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '183 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['183 9th Ave', 'New York, NY 10011']},
#    'phone': '+16464863000',
#    'display_phone': '(646) 486-3000',
#    'distance': 4495.764615088749},
#   {'id': 'xN7JOFf3nBBDxvZ1M4Slbg',
#    'alias': 'barbès-restaurant-hoboken',
#    'name': 'Barbès Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aqiG4zZZ-cGXDSHNzij8Ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barb%C3%A8s-restaurant-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 236,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'moroccan', 'title': 'Moroccan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7529899, 'longitude': -74.02924},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '1300 Park Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1300 Park Ave', 'Hoboken, NJ 07030']},
#    'phone': '+12016101000',
#    'display_phone': '(201) 610-1000',
#    'distance': 6052.022792440891},
#   {'id': 'TdUhTJ7hCt0uANqHIcltOA',
#    'alias': 'olivier-bistro-brooklyn',
#    'name': 'Olivier Bistro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1adlGBswMikwpePuIShP4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olivier-bistro-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 341,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6688499963761,
#     'longitude': -73.9896939343586},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '469 4th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['469 4th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187686600',
#    'display_phone': '(718) 768-6600',
#    'distance': 4087.5961808696557},
#   {'id': '6ujYWjs1FTksvuVxuzjUYA',
#    'alias': 'almond-new-york',
#    'name': 'Almond',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vvfpKa_InIeZ6CFdKZClpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/almond-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1025,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7400817871094,
#     'longitude': -73.9887542724609},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '12 E 22nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['12 E 22nd St', 'New York, NY 10010']},
#    'phone': '+12122287557',
#    'display_phone': '(212) 228-7557',
#    'distance': 3879.62819763039},
#   {'id': 'TOlIQbDBIHq_or6JcXx4ZQ',
#    'alias': 'sauced-brooklyn',
#    'name': 'Sauced',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9fTKY6-18pBciiTp_xoKlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sauced-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7126701394003,
#     'longitude': -73.9623194526208},
#    'transactions': ['delivery'],
#    'location': {'address1': '331 Bedford Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['331 Bedford Ave', 'Brooklyn, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2812.2439705902975},
#   {'id': '43y93456fzLVTF7LdlZikw',
#    'alias': 'la-boulangerie-forest-hills-3',
#    'name': 'La Boulangerie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YP67iYf_1IvmoHQZHFicRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-boulangerie-forest-hills-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 574,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'creperies', 'title': 'Creperies'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7191996169974,
#     'longitude': -73.8415304306788},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '109-01 72nd Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['109-01 72nd Rd', 'Forest Hills, NY 11375']},
#    'phone': '+13476445606',
#    'display_phone': '(347) 644-5606',
#    'distance': 12966.131427159185},
#   {'id': 'bTyyPU8A4pz9dieLSZPMdA',
#    'alias': 'le-rivage-new-york-2',
#    'name': 'Le Rivage',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1NmZrj3Q2SqP_8TFAuXs-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-rivage-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 475,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76023, 'longitude': -73.98957},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '340 W 46th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['340 W 46th St', 'New York, NY 10036']},
#    'phone': '+12127657374',
#    'display_phone': '(212) 765-7374',
#    'distance': 6107.38465037784},
#   {'id': 'QvQilClGyuKFz08TBsoJNA',
#    'alias': 'le-district-new-york',
#    'name': 'Le District',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9V2g0-Cmq5-i3RnMiWntCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-district-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 580,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7126473617984,
#     'longitude': -74.0157784596443},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '225 Liberty St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10281',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['225 Liberty St', 'New York, NY 10281']},
#    'phone': '+12129818588',
#    'display_phone': '(212) 981-8588',
#    'distance': 1980.159842860005},
#   {'id': '6BHKPn6QtTJ0lTZonI-WgQ',
#    'alias': 'the-lavaux-new-york',
#    'name': 'The Lavaux',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XUbuBxy5FYNsEQkPUM63bA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lavaux-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'fondue', 'title': 'Fondue'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7383532750564,
#     'longitude': -74.0055276453495},
#    'transactions': ['delivery'],
#    'location': {'address1': '630 Hudson St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['630 Hudson St', 'New York, NY 10014']},
#    'phone': '+16466923328',
#    'display_phone': '(646) 692-3328',
#    'distance': 3779.737953455809},
#   {'id': 'U1H_LiA_-9NtaSbehPdODw',
#    'alias': 'ratatouille-new-york',
#    'name': 'Ratatouille',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DOpT57-dYwbzA1Y1HJfpSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ratatouille-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 280,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'chickenshop', 'title': 'Chicken Shop'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7489198, 'longitude': -73.9763381},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '154 E 39th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['154 E 39th St', 'New York, NY 10016']},
#    'phone': '+12129220505',
#    'display_phone': '(212) 922-0505',
#    'distance': 5065.427792802066},
#   {'id': 'K6ik5ceZaea55wXnmHWz0Q',
#    'alias': 'bliss-46-bistro-sunnyside',
#    'name': 'Bliss 46 Bistro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0Ci2HdT1SDdUeFbdgEiGmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bliss-46-bistro-sunnyside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 215,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.743560749198224,
#     'longitude': -73.91874828398852},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '43-46 46th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43-46 46th St', 'Sunnyside, NY 11104']},
#    'phone': '+17183610690',
#    'display_phone': '(718) 361-0690',
#    'distance': 7647.928681991345},
#   {'id': '3gtheZvv3Or0YzWXIl3SJg',
#    'alias': 'benoit-new-york',
#    'name': 'Benoit',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Nf63y60UvqQ_HekhR61IXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/benoit-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 504,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7625640535871,
#     'longitude': -73.9772810679851},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '60 W 55th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 W 55th St', 'New York, NY 10019']},
#    'phone': '+16469437373',
#    'display_phone': '(646) 943-7373',
#    'distance': 6511.096335276607},
#   {'id': 'ykTc4pZYEAY0Esd0yVFSOQ',
#    'alias': 'vin-sur-vingt-new-york-5',
#    'name': 'Vin Sur Vingt',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tRCKAlx3o_md_-by2KIGkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vin-sur-vingt-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 61,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78492, 'longitude': -73.97291},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '66 W 84th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['66 W 84th St', 'New York, NY 10024']},
#    'phone': '+16468959944',
#    'display_phone': '(646) 895-9944',
#    'distance': 9020.63427691596},
#   {'id': 'Nt36orNgZKCsGcdHw8TwEg',
#    'alias': 'francis-and-staub-la-rotisserie-new-york-2',
#    'name': 'Francis & Staub - La Rotisserie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8YMrHXvQ6bZeq7ZwA6mj9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/francis-and-staub-la-rotisserie-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.738572, 'longitude': -73.988906},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '30 E 20th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30 E 20th St', 'New York, NY 10003']},
#    'phone': '+12122677426',
#    'display_phone': '(212) 267-7426',
#    'distance': 3713.551266824723},
#   {'id': 'RQojRzAYA9Cq87PqwQq5yg',
#    'alias': 'deux-amis-new-york',
#    'name': 'Deux Amis',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DHOkQkVRLjlyVwqI49rRog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/deux-amis-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 175,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7544765, 'longitude': -73.9660238},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '356 E 51st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['356 E 51st St', 'New York, NY 10022']},
#    'phone': '+12122301117',
#    'display_phone': '(212) 230-1117',
#    'distance': 5949.9571151341715},
#   {'id': 'q-QEwZi32JCnjb7zbY-PQw',
#    'alias': 'soogil-new-york',
#    'name': 'Soogil',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gnzD004YQCRclWFM52lzpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soogil-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 127,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72551, 'longitude': -73.98838},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '108 E 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['108 E 4th St', 'New York, NY 10003']},
#    'phone': '+16468385524',
#    'display_phone': '(646) 838-5524',
#    'distance': 2289.2038585586733},
#   {'id': 'C2o3Iw-DXjoUJFgQIbiqkQ',
#    'alias': 'bocaphê-new-york-3',
#    'name': 'BoCaphe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ffH2uivBehucfzNsFaOqQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bocaph%C3%AA-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1610,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722062, 'longitude': -73.997587},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '222 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['222 Lafayette St', 'New York, NY 10012']},
#    'phone': '+16468821939',
#    'display_phone': '(646) 882-1939',
#    'distance': 1868.477363167493},
#   {'id': 'VuR3lhMA80aH42jrBM_C8A',
#    'alias': 'duane-park-new-york-3',
#    'name': 'Duane Park',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W3hIWq57AnpeiP0i39uRUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duane-park-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 497,
#    'categories': [{'alias': 'supperclubs', 'title': 'Supper Clubs'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7249172, 'longitude': -73.9925423},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$$$',
#    'location': {'address1': '308 Bowery',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['308 Bowery', 'New York, NY 10012']},
#    'phone': '+12127325555',
#    'display_phone': '(212) 732-5555',
#    'distance': 2170.245443603778},
#   {'id': 't-Pm38_XhMnGfOYgkhaNRA',
#    'alias': 'le-fanfare-brooklyn-4',
#    'name': 'Le Fanfare',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MSs2OKz8_BYKpcU7UxCmMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-fanfare-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 198,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.736202, 'longitude': -73.955558},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1103 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1103 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+13479874244',
#    'display_phone': '(347) 987-4244',
#    'distance': 4734.875684140819},
#   {'id': 'XBWO26QblInZGftnSDD94A',
#    'alias': 'maman-tribeca-new-york-2',
#    'name': 'Maman Tribeca',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OSqmQbY7pfGTYYSOOz7kxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maman-tribeca-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 279,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7188969, 'longitude': -74.0062207},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '211 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['211 W Broadway', 'New York, NY 10013']},
#    'phone': '+16468828682',
#    'display_phone': '(646) 882-8682',
#    'distance': 1802.2364781853016},
#   {'id': 'JU5d81TYm7IJHWqOqJWMqw',
#    'alias': 'have-and-meyer-brooklyn',
#    'name': 'Have & Meyer',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hzduhbuVvYRa6jZ7Lt7Arg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/have-and-meyer-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 140,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7132687751084,
#     'longitude': -73.9564743950496},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '103 Havemeyer St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 Havemeyer St', 'Brooklyn, NY 11211']},
#    'phone': '+17184190722',
#    'display_phone': '(718) 419-0722',
#    'distance': 3304.285127566444},
#   {'id': '-vBfKWJ1v9YdJQT5XUbcBQ',
#    'alias': 'le-botaniste-new-york',
#    'name': 'Le Botaniste',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4uHTrPOgmrA6LB9-lc508Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-botaniste-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 416,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'organic_stores', 'title': 'Organic Stores'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7649986274526,
#     'longitude': -73.9659830279587},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '833 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['833 Lexington Ave', 'New York, NY 10065']},
#    'phone': '+19172620766',
#    'display_phone': '(917) 262-0766',
#    'distance': 7038.56994541135},
#   {'id': '3V20VbC45XL4TBYTL9DrOg',
#    'alias': 'davids-cafe-new-york',
#    'name': "David's Cafe",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MI8yA82mgupSopKWJz2Xuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/davids-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 217,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7269310030458,
#     'longitude': -73.9843428879976},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '110 St Marks Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['110 St Marks Pl', 'New York, NY 10009']},
#    'phone': '+16466783206',
#    'display_phone': '(646) 678-3206',
#    'distance': 2532.053981515675},
#   {'id': 'StF9WWWbrRzEOmNAcEINcA',
#    'alias': 'balzem-new-york',
#    'name': 'Balzem',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FHbj0Hqn0btPLBS7pwPfew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/balzem-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 456,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.721408, 'longitude': -73.995415},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '202 Mott St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['202 Mott St', 'New York, NY 10012']},
#    'phone': '+16468377033',
#    'display_phone': '(646) 837-7033',
#    'distance': 1777.534042874945},
#   {'id': 'RyVOeKAWLT2srJqpGNFHXw',
#    'alias': 'café-le-mistral-brooklyn',
#    'name': 'Café Le Mistral',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/83JCZCXyOMJjLJQtw1oofw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-le-mistral-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 82,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.671555, 'longitude': -73.984566},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '330 5th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['330 5th St', 'Brooklyn, NY 11215']},
#    'phone': '+18448419019',
#    'display_phone': '(844) 841-9019',
#    'distance': 3849.387376925011},
#   {'id': 'gISZs8okQgFIpd-yz9aC4w',
#    'alias': 'café-henri-long-island-city-2',
#    'name': 'Café Henri',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MkgDkRYzlJQfrkASGhbGwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-henri-long-island-city-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 715,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.742559, 'longitude': -73.953697},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1010 50th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1010 50th Ave', 'Long Island City, NY 11101']},
#    'phone': '+17187295794',
#    'display_phone': '(718) 729-5794',
#    'distance': 5360.493261866259},
#   {'id': 'r_QEUVdoo8dsKR9fK31w3w',
#    'alias': 'paradis-des-gouts-brooklyn',
#    'name': 'Paradis Des Gouts',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AD-VB6dzNNXuh4sUYCq4mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paradis-des-gouts-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'african', 'title': 'African'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69333, 'longitude': -73.92931},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1136 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1136 Broadway', 'Brooklyn, NY 11221']},
#    'phone': '+17184434584',
#    'display_phone': '(718) 443-4584',
#    'distance': 5641.105531375134},
#   {'id': '-7PnG_cD9VY-IfHGWzynmQ',
#    'alias': 'ainslie-brooklyn-2',
#    'name': 'Ainslie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x4PdlWcrz3lzNg1WTWEhHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ainslie-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 322,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.712343, 'longitude': -73.952121},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '76 Ainslie St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['76 Ainslie St', 'Brooklyn, NY 11211']},
#    'phone': '+13477253400',
#    'display_phone': '(347) 725-3400',
#    'distance': 3636.4832270704437},
#   {'id': '7KO4zcBtc2-2M5kJLfl0kw',
#    'alias': 'jolie-bistro-brooklyn',
#    'name': 'Jolie Bistro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mwzCodjMIM6saZpp4h_ZxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jolie-bistro-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 416,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6836, 'longitude': -73.99247},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '241 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['241 Smith St', 'Brooklyn, NY 11231']},
#    'phone': '+17184880777',
#    'display_phone': '(718) 488-0777',
#    'distance': 2433.893987381038},
#   {'id': '2VpurA2lb-q90nmALklNcA',
#    'alias': 'perry-st-new-york',
#    'name': 'Perry St',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2TrXKYmlNB8BWPTwSmaSZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/perry-st-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 954,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73442, 'longitude': -74.00971},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '176 Perry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['176 Perry St', 'New York, NY 10014']},
#    'phone': '+12123521900',
#    'display_phone': '(212) 352-1900',
#    'distance': 3474.641743010235},
#   {'id': 'NIX9YFX1taOkm1J9IGuLqA',
#    'alias': 'bistrot-leo-new-york',
#    'name': 'Bistrot Leo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PhhgsXqZTZfZNm0mW0LJUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistrot-leo-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72399, 'longitude': -74.00316},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '60 Thompson St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Thompson St', 'New York, NY 10012']},
#    'phone': '+12122198119',
#    'display_phone': '(212) 219-8119',
#    'distance': 2189.6663853275204}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#          Restaurant       Type Price Rating         Address        Lat  \
# 0         Bar Tabac     French    $$    3.5    128 Smith St  40.687368
# 1      Bar Blondeau  Wine Bars                 80 Wythe Ave  40.722080
# 2    Liberty Bistro     French               225 Liberty St  40.712344
# 3  Gabriel Kreuther    Lounges  $$$$    4.5    41 W 42nd St  40.754546
# 4             Frevo     French                  48 W 8th St  40.733130
#
#          Lng                                                url  \
# 0 -73.990285  https://www.yelp.com/biz/bar-tabac-brooklyn?ad...
# 1 -73.957850
# 2 -74.015511
# 3 -73.982556  https://www.yelp.com/biz/gabriel-kreuther-new-...
# 4 -73.998670
#
#                        ID
# 0  3qf3FLXxVdX3Wz5F_rTeog
# 1
# 2
# 3  pDwhlX9jNBGnjvyGR9jYWQ
# 4

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"french","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [{'id': '8cT6XDwI9KiCaoVohlx42Q',
#    'alias': 'bxl-zoute-new-york',
#    'name': 'BXL Zoute',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eGoCERv0Kp3-NgnF0m7PUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bxl-zoute-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 414,
#    'categories': [{'alias': 'belgian', 'title': 'Belgian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74174, 'longitude': -73.992627},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '50 W 22nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['50 W 22nd St', 'New York, NY 10010']},
#    'phone': '+16466929282',
#    'display_phone': '(646) 692-9282',
#    'distance': 4038.272316249407},
#   {'id': 'OwDRIugcA4LkUuTRqpJsog',
#    'alias': 'naked-dog-brooklyn-2',
#    'name': 'Naked Dog',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1sC00X-YIu2oxVKk2oFIfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/naked-dog-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 246,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7312720665479,
#     'longitude': -73.9593493647979},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '47 Java St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 Java St', 'Brooklyn, NY 11222']},
#    'phone': '+19293378096',
#    'display_phone': '(929) 337-8096',
#    'distance': 4113.441999440594},
#   {'id': 'eT39RKlQ8i5Z4ml0ZwUK-Q',
#    'alias': 'tambour-brooklyn-3',
#    'name': 'Tambour',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wtTb5D1C_oh_SmWmrDqwww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tambour-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 120,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.662504, 'longitude': -73.992533},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '652 5th Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['652 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+13479161747',
#    'display_phone': '(347) 916-1747',
#    'distance': 4778.894156848371},
#   {'id': '5M5tLSpe4qyvqRAUUAf8gQ',
#    'alias': 'nubleu-restaurant-brooklyn-2',
#    'name': 'Nubleu Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iIwuOlCOkOU_29Yshut7Rg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nubleu-restaurant-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67287362863534,
#     'longitude': -73.9830296822084},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '315 5th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['315 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+19293970555',
#    'display_phone': '(929) 397-0555',
#    'distance': 3744.1921451603116},
#   {'id': 'Okbtt-ISFB3kuoxkl2wVgg',
#    'alias': 'the-simone-new-york',
#    'name': 'The Simone',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0XcpuijFh_1XYm3EkeFRSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-simone-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 95,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.77682, 'longitude': -73.95698},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '151 E 82nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['151 E 82nd St', 'New York, NY 10028']},
#    'phone': '+12127728861',
#    'display_phone': '(212) 772-8861',
#    'distance': 8542.554765469777},
#   {'id': '7m4GnzK5pv7qGn-Ar1zabQ',
#    'alias': 'lena-new-york-12',
#    'name': 'Lena',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YDGiHCiuRcIBvMZEdCaM7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lena-new-york-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.732552, 'longitude': -73.996704},
#    'transactions': [],
#    'location': {'address1': '1B West 8th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1B West 8th St', 'New York, NY 10011']},
#    'phone': '+12129792315',
#    'display_phone': '(212) 979-2315',
#    'distance': 3021.012362493374},
#   {'id': 'jeJfYLekXo3yxUpDfNukyQ',
#    'alias': 'cafe-matisse-rutherford-5',
#    'name': 'Cafe Matisse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QPokqDH9sKWeYv6WDn7pXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-matisse-rutherford-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 387,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.82503, 'longitude': -74.10933},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '167 Park Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Rutherford',
#     'zip_code': '07070',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['167 Park Ave', 'Rutherford, NJ 07070']},
#    'phone': '+12019352995',
#    'display_phone': '(201) 935-2995',
#    'distance': 16452.52656203066},
#   {'id': 'PBUIaPtgnhmdHE3KHglK-g',
#    'alias': 'jean-georges-new-york-2',
#    'name': 'Jean-Georges',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KfRxsT7S7fessl5BAvImZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jean-georges-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1913,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7691122743293,
#     'longitude': -73.9814290717583},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$$',
#    'location': {'address1': '1 Central Park W',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Central Park W', 'New York, NY 10023']},
#    'phone': '+12122993900',
#    'display_phone': '(212) 299-3900',
#    'distance': 7161.971442127786},
#   {'id': 'ZWPgzW0qqtksyI3GxCPM-Q',
#    'alias': 'little-frog-bistro-and-bar-new-york',
#    'name': 'Little Frog Bistro & Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/k0XrMaD5nA1uOjZZnvrwJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-frog-bistro-and-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 226,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77722, 'longitude': -73.95092},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '322 E 86th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['322 E 86th St', 'New York, NY 10028']},
#    'phone': '+13475375786',
#    'display_phone': '(347) 537-5786',
#    'distance': 8781.04762964201},
#   {'id': '3D6UAhoKnF3A03rX_v5ngA',
#    'alias': 'bacaro-new-york',
#    'name': 'Bacaro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Gz_dhityi18F1JL5xdtXLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bacaro-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 400,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71456, 'longitude': -73.99154},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '136 Division St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136 Division St', 'New York, NY 10002']},
#    'phone': '+12129415060',
#    'display_phone': '(212) 941-5060',
#    'distance': 1036.2033423676269},
#   {'id': '1_JZHKkWQBozYQ00fephWQ',
#    'alias': 'pistache-new-york',
#    'name': 'Pistache',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PdaWADa76LLokqwLYZiiqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pistache-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'catering', 'title': 'Caterers'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.6996109, 'longitude': -73.9479221},
#    'transactions': [],
#    'location': {'address1': '630 Flushing Ave',
#     'address2': 'Unit 806',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['630 Flushing Ave', 'Unit 806', 'New York, NY 11206']},
#    'phone': '+19175978387',
#    'display_phone': '(917) 597-8387',
#    'distance': 3962.426149733325},
#   {'id': 'CZg05roVBkzu1QzxTHfkPw',
#    'alias': 'fino-french-bistro-bayside',
#    'name': 'FINO French Bistro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0LT8x1_O0mYlh9sczmrqVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fino-french-bistro-bayside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 420,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76492513125973,
#     'longitude': -73.77149154087756},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '39 13 Bell Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39 13 Bell Blvd', 'Bayside, NY 11361']},
#    'phone': '+17182291330',
#    'display_phone': '(718) 229-1330',
#    'distance': 19903.415708425804},
#   {'id': 'eCb2VMBFGDgfKCMB4DUPvQ',
#    'alias': 'la-cantine-brooklyn',
#    'name': 'La Cantine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Q0Ksx3jA6dyDh_PcGZpVJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-cantine-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70664, 'longitude': -73.9206},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '60 St Nicholas Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 St Nicholas Ave', 'Brooklyn, NY 11237']},
#    'phone': '+19176524556',
#    'display_phone': '(917) 652-4556',
#    'distance': 6215.627835405373},
#   {'id': '5Vzj1puJsudW6RGI6B76SA',
#    'alias': 'l-atelier-gourmand-manhattan',
#    'name': "L'atelier Gourmand",
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-atelier-gourmand-manhattan?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7147400000155,
#     'longitude': -73.9461399997206},
#    'transactions': [],
#    'location': {'address1': 'Avenue Deloffre',
#     'address2': '',
#     'address3': '',
#     'city': 'Manhattan',
#     'zip_code': '10069',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Avenue Deloffre', 'Manhattan, NY 10069']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4188.263830748771},
#   {'id': 'ZxfXy-odIz_Xi1i9Uu00pg',
#    'alias': 'la-bonne-soupe-new-york-8',
#    'name': 'La Bonne Soupe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/G0gps1Q9Jx6eXIn-dRISrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-bonne-soupe-new-york-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 758,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7624, 'longitude': -73.97694},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '48 W 55th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['48 W 55th St', 'New York, NY 10019']},
#    'phone': '+12125867650',
#    'display_phone': '(212) 586-7650',
#    'distance': 6499.699710916821},
#   {'id': 'qEbQbYZxurnuVxDrNHQUJg',
#    'alias': 'la-boite-en-bois-new-york-2',
#    'name': 'La Boite en Bois',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/P7CFAivydKdTbmCIhgfakA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-boite-en-bois-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 228,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7749214172363,
#     'longitude': -73.9802398681641},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '75 W 68th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 W 68th St', 'New York, NY 10023']},
#    'phone': '+12128742705',
#    'display_phone': '(212) 874-2705',
#    'distance': 7812.873887329484},
#   {'id': '_F-GTYP0Cfc6LGamqRhXgQ',
#    'alias': 'boutique-bistro-bar-astoria',
#    'name': 'Boutique Bistro Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TrlRZ8ILJhqcrsIgm5U6uw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boutique-bistro-bar-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 121,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.775414, 'longitude': -73.9093017},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '33-01 Ditmars Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-01 Ditmars Blvd', 'Astoria, NY 11105']},
#    'phone': '+19296667761',
#    'display_phone': '(929) 666-7761',
#    'distance': 10573.745772422713},
#   {'id': 'nRO136GRieGtxz18uD61DA',
#    'alias': 'eleven-madison-park-new-york',
#    'name': 'Eleven Madison Park',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/s_H7gm_Hwmz--O6bo1iU-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eleven-madison-park-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2211,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7416907417333,
#     'longitude': -73.9872074872255},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '11 Madison Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 Madison Ave', 'New York, NY 10010']},
#    'phone': '+12128890905',
#    'display_phone': '(212) 889-0905',
#    'distance': 4074.3463982775174},
#   {'id': 'oyxtaqfFZkP_vC0M6GfkbA',
#    'alias': 'chez-napoleon-new-york',
#    'name': 'Chez Napoleon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IV9Z-Kz6EtqOAE7LCtMgoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chez-napoleon-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 289,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76346, 'longitude': -73.9883},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '365 W 50th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['365 W 50th St', 'New York, NY 10019']},
#    'phone': '+12122656980',
#    'display_phone': '(212) 265-6980',
#    'distance': 6473.387132354896},
#   {'id': 'cpfBJVV-5Jo5w2KcbOBtVQ',
#    'alias': 'chez-oskar-brooklyn',
#    'name': 'Chez Oskar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lwUDb4g_VzxTJMyI8u-XRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chez-oskar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 527,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6822491, 'longitude': -73.9290779},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '310 Malcolm X Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['310 Malcolm X Blvd', 'Brooklyn, NY 11233']},
#    'phone': '+17188526250',
#    'display_phone': '(718) 852-6250',
#    'distance': 6073.112694968124},
#   {'id': 'OkiPb6gNNRmcbB4zIIMx0g',
#    'alias': 'big-tiny-brooklyn-4',
#    'name': 'Big Tiny',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HVKFUDb7zcv4Hytu7qWcTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/big-tiny-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6834507, 'longitude': -73.992855},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '244 Smith St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['244 Smith St', 'Brooklyn, NY 11231']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2448.640731099753},
#   {'id': 'xtfKAP7X36CCZrJm_Ta6Cg',
#    'alias': 'the-consulate-new-york-2',
#    'name': 'The Consulate',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GkmLTPhs7Xu0oa_1TwkC5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-consulate-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 141,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78586, 'longitude': -73.97242},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '519 Columbus Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['519 Columbus Ave', 'New York, NY 10024']},
#    'phone': '+16467819288',
#    'display_phone': '(646) 781-9288',
#    'distance': 9130.026299629822},
#   {'id': '0j4yPmK9rOS52-mgKoq0Eg',
#    'alias': 'maison-yaki-brooklyn',
#    'name': 'Maison Yaki',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tZ62rypitLKK1uC_Y5--jg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maison-yaki-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 105,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.67749, 'longitude': -73.96913},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '626 Vanderbilt Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['626 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3757.0358255177002},
#   {'id': 'hcGcjMrRcVSLzmBIsMIcwQ',
#    'alias': 'chez-les-frenchies-new-york-2',
#    'name': 'Chez Les Frenchies',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rpEgkpfwBllk80V74IoGug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chez-les-frenchies-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'creperies', 'title': 'Creperies'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7687, 'longitude': -73.95182},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '501 E 75th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['501 E 75th St', 'New York, NY 10021']},
#    'phone': '+13474625346',
#    'display_phone': '(347) 462-5346',
#    'distance': 7894.600368564261},
#   {'id': 'JNv9J5mn1JtzYqn_R2bFYA',
#    'alias': 'petit-paulette-brooklyn-3',
#    'name': 'Petit Paulette',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZPAuu56mzNqlxkeT4WvlfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/petit-paulette-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68961, 'longitude': -73.97579},
#    'transactions': ['delivery'],
#    'location': {'address1': '136 Dekalb Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136 Dekalb Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17186942044',
#    'display_phone': '(718) 694-2044',
#    'distance': 2347.5860238079645},
#   {'id': '5jPaUdIjz_5u3N1gpUbwmA',
#    'alias': 'pinkerton-wine-bar-brooklyn',
#    'name': 'Pinkerton Wine Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/d1M1l-aRnj2_FwiU0xvBbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pinkerton-wine-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 120,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.714912, 'longitude': -73.954229},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '263 N 6th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['263 N 6th St', 'Brooklyn, NY 11211']},
#    'phone': '+17187827171',
#    'display_phone': '(718) 782-7171',
#    'distance': 3536.094038383863},
#   {'id': 'HbCyzokiA19bEWUp6mga_g',
#    'alias': 'bibi-new-york',
#    'name': 'bibi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V2qvFO0ohemmEdb0Nm4ROg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bibi-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 196,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.723937, 'longitude': -73.983519},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '211 E 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['211 E 4th St', 'New York, NY 10009']},
#    'phone': '+12126732424',
#    'display_phone': '(212) 673-2424',
#    'distance': 2247.8154805576246},
#   {'id': 'vegSCksJy6SI8WUGttLH-w',
#    'alias': 'fradei-bistro-brooklyn-4',
#    'name': 'Fradei Bistro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ukys9pga2bQNptMn0ySLOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fradei-bistro-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.686579, 'longitude': -73.974191},
#    'transactions': [],
#    'location': {'address1': '99 South Portland Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['99 South Portland Ave', 'Brooklyn, NY 11217']},
#    'phone': '+13477253275',
#    'display_phone': '(347) 725-3275',
#    'distance': 2694.3213368567067},
#   {'id': 'mosd9Voq5Ws6k6Uduii_ww',
#    'alias': 'bar-boulud-new-york-2',
#    'name': 'Bar Boulud',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L8ZAztiUuJb-DRtAx2W88A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-boulud-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 892,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7718443592464,
#     'longitude': -73.9818808860381},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '1900 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1900 Broadway', 'New York, NY 10023']},
#    'phone': '+12125950303',
#    'display_phone': '(212) 595-0303',
#    'distance': 7456.971063517986},
#   {'id': '2BRJP7YeiNuWSwyn2TdAoA',
#    'alias': 'kafana-new-york',
#    'name': 'Kafana',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B-nIvpYSddOHsatr70-fkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kafana-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 415,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72432, 'longitude': -73.97851},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '116 Ave C',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['116 Ave C', 'New York, NY 10009']},
#    'phone': '+12123538000',
#    'display_phone': '(212) 353-8000',
#    'distance': 2491.373576619052},
#   {'id': 'WBPbYPBrha8jxeUuqreYpQ',
#    'alias': 'bistro-so-brooklyn',
#    'name': 'Bistro So',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AkW3uEnghgFmLFKjwCHTSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistro-so-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71755, 'longitude': -73.95603},
#    'transactions': [],
#    'location': {'address1': '530 Driggs Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['530 Driggs Ave', 'Brooklyn, NY 11211']},
#    'phone': '+19293376644',
#    'display_phone': '(929) 337-6644',
#    'distance': 3490.1421410009666},
#   {'id': 'cJREPXNhyznkLrKhjg9hoA',
#    'alias': 'tournesol-long-island-city',
#    'name': 'Tournesol',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/deRbFS50LcgJ7O5RgWpGcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tournesol-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 433,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74239, 'longitude': -73.95451},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '5012 Vernon Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5012 Vernon Blvd', 'Long Island City, NY 11101']},
#    'phone': '+17184724355',
#    'display_phone': '(718) 472-4355',
#    'distance': 5304.801809142766},
#   {'id': 'JbpjgLAk4DaP0zvY7dP9Hw',
#    'alias': 'elysian-cafe-hoboken',
#    'name': 'Elysian Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bAS7VrYyd6cktLLAciknZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elysian-cafe-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 589,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7486464, 'longitude': -74.027349},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1001 Washington St',
#     'address2': None,
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1001 Washington St', 'Hoboken, NJ 07030']},
#    'phone': '+12017985898',
#    'display_phone': '(201) 798-5898',
#    'distance': 5552.956031161564},
#   {'id': '71HLFDV5yIX8l7WqP7Km5g',
#    'alias': 'westlight-brooklyn',
#    'name': 'Westlight',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TjVEapZucfdPEvCnN46cOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/westlight-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 615,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.722299, 'longitude': -73.956691},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '111 N 12th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 N 12th St', 'Brooklyn, NY 11249']},
#    'phone': '+17183077100',
#    'display_phone': '(718) 307-7100',
#    'distance': 3681.878990715751},
#   {'id': 'TQEajJ-kahYPOToGZIyyaA',
#    'alias': 'cafe-boulud-new-york-4',
#    'name': 'Cafe Boulud',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FcW3o3A_eTdUjf60PyROJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-boulud-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 728,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77444, 'longitude': -73.96396},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '20 E 76th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['20 E 76th St', 'New York, NY 10021']},
#    'phone': '+12127722600',
#    'display_phone': '(212) 772-2600',
#    'distance': 8088.406404759938},
#   {'id': 'H_KyiRhwho8rdlw_R93_0Q',
#    'alias': 'marea-new-york',
#    'name': 'Marea',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-7_hUV0_zqVzsbqNOJ_iMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marea-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2157,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7674213694566,
#     'longitude': -73.9810554368179},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '240 Central Park S',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['240 Central Park S', 'New York, NY 10019']},
#    'phone': '+12125825100',
#    'display_phone': '(212) 582-5100',
#    'distance': 6981.13750343581},
#   {'id': 'gvMYV5E3HyzhN_MYFIMGzg',
#    'alias': 'el-born-brooklyn',
#    'name': 'El Born',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cRJdg0UISKlStMI7vkp6Tw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-born-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 344,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7243479163883,
#     'longitude': -73.9512226101037},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '651 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['651 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+13478449295',
#    'display_phone': '(347) 844-9295',
#    'distance': 4194.692764168617},
#   {'id': 'jvuwuo6UWC5HtPRsFhm-iA',
#    'alias': 'les-trois-chevaux-new-york',
#    'name': 'Les Trois Chevaux',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Jt4YifZ3AIBf2S3Kdnouhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/les-trois-chevaux-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.73764434900123, 'longitude': -74.0040136},
#    'transactions': [],
#    'location': {'address1': '283 W 12th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['283 W 12th St', 'New York, NY 10014']},
#    'phone': '+19172612829',
#    'display_phone': '(917) 261-2829',
#    'distance': 3672.9296858636158},
#   {'id': '56Uc2Wrqll0Ah5JYDel19Q',
#    'alias': 'runner-up-brooklyn-2',
#    'name': 'Runner Up',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wv4uoXU_5t7oNTk-o0vs-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/runner-up-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.66556972929384,
#     'longitude': -73.98229889177945},
#    'transactions': [],
#    'location': {'address1': '367 7th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['367 7th Ave', 'Brooklyn, NY 11215']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4547.786706836967},
#   {'id': 'I6Wg1NFYAAVzM2OpsdqcXA',
#    'alias': 'grand-vin-hoboken',
#    'name': 'Grand Vin',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_nTrI3aiUn50VWvMYmDpMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grand-vin-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 457,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74331, 'longitude': -74.0351699},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '500 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['500 Grand St', 'Hoboken, NJ 07030']},
#    'phone': '+12016560012',
#    'display_phone': '(201) 656-0012',
#    'distance': 5444.684801808162},
#   {'id': '3R-S958SenPaaveuPzSN9g',
#    'alias': 'le-paddock-brooklyn',
#    'name': 'Le Paddock',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Zw5rmPBX_yVaA5mD1VnJfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-paddock-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 310,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.65295, 'longitude': -73.97588},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1235 Prospect Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11218',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1235 Prospect Ave', 'Brooklyn, NY 11218']},
#    'phone': '+17184350921',
#    'display_phone': '(718) 435-0921',
#    'distance': 6039.562070198042},
#   {'id': 'obFs12x7mgYPGxgalBd22w',
#    'alias': 'le-coucou-new-york',
#    'name': 'Le Coucou',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gqUrYGo_gvK1YN-JinT2Bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-coucou-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 569,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71909, 'longitude': -74.00013},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '138 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['138 Lafayette St', 'New York, NY 10013']},
#    'phone': '+12122714252',
#    'display_phone': '(212) 271-4252',
#    'distance': 1598.3391395087986},
#   {'id': 'g3jNtkQZVZrrC823oBxdtg',
#    'alias': 'lafayette-grand-café-and-bakery-new-york',
#    'name': 'Lafayette Grand Café & Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Z0k9Sjk5k57EqC9h_NMvcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lafayette-grand-caf%C3%A9-and-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 956,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.727617, 'longitude': -73.993464},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '380 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['380 Lafayette St', 'New York, NY 10003']},
#    'phone': '+12125333000',
#    'display_phone': '(212) 533-3000',
#    'distance': 2466.4165560809},
#   {'id': 'h_qGWauoScc3tMBDBb-few',
#    'alias': 'gaudir-new-york-2',
#    'name': 'GAUDir',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LS8WTvGz_qpJTzMuFvGIZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gaudir-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.79349, 'longitude': -73.941},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '251 E 110th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['251 E 110th St', 'New York, NY 10029']},
#    'phone': '+12127444422',
#    'display_phone': '(212) 744-4422',
#    'distance': 10769.60213643748},
#   {'id': 'Knbn0h4MA1KX5Fv3eZfK4w',
#    'alias': 'nice-matin-new-york',
#    'name': 'Nice Matin',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Tb8dgg1HBJIRcdwPCZZ3kQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nice-matin-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 771,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.78337, 'longitude': -73.97847},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '201 W 79th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['201 W 79th St', 'New York, NY 10024']},
#    'phone': '+12128736423',
#    'display_phone': '(212) 873-6423',
#    'distance': 8777.057504623037},
#   {'id': 'y_tRUBOu3qg7lkaO2Xk1hQ',
#    'alias': 'frost-restaurant-brooklyn',
#    'name': 'Frost Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/n-tTg4edrVF67pJ0D9EObg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frost-restaurant-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 165,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.718316564452245,
#     'longitude': -73.94345573128281},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '193 Frost St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['193 Frost St', 'Brooklyn, NY 11211']},
#    'phone': '+17183893347',
#    'display_phone': '(718) 389-3347',
#    'distance': 4517.587384471612},
#   {'id': 'pV-f6jq8mqNWymbPyPNmzg',
#    'alias': 'bobo-new-york',
#    'name': 'BOBO',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2DYFutiMLwgJ267fTjqzUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bobo-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 545,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.734489440918,
#     'longitude': -74.0026245117188},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '181 W 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['181 W 10th St', 'New York, NY 10014']},
#    'phone': '+12124882626',
#    'display_phone': '(212) 488-2626',
#    'distance': 3301.8594285638296},
#   {'id': 'RP02PZPNdhfoL-TjOMiKVg',
#    'alias': 'table-d-hôte-new-york-2',
#    'name': "Table d'Hôte",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wOi0Md5l7YgF63CnA8-zkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/table-d-h%C3%B4te-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 160,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78447, 'longitude': -73.95581},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '44 E 92nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['44 E 92nd St', 'New York, NY 10128']},
#    'phone': '+12123488125',
#    'display_phone': '(212) 348-8125',
#    'distance': 9362.688417846051},
#   {'id': 'a0AvIH1UnFmqAXhZDEQtrw',
#    'alias': 'tocqueville-restaurant-new-york-2',
#    'name': 'Tocqueville Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KlZPmuca6JytZz8Zxtqu1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tocqueville-restaurant-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 370,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73662, 'longitude': -73.99272},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$$',
#    'location': {'address1': '1 E 15th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 E 15th St', 'New York, NY 10003']},
#    'phone': '+12126471515',
#    'display_phone': '(212) 647-1515',
#    'distance': 3475.4254303958433},
#   {'id': '9V0u-hctFSqJf6lHZra_QA',
#    'alias': 'la-bouche-hoboken-3',
#    'name': 'La Bouche',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tIbLjhItX7PbNi9Ud2qcJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-bouche-hoboken-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 218,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7389977, 'longitude': -74.030226},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '207 Washington St',
#     'address2': '',
#     'address3': None,
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['207 Washington St', 'Hoboken, NJ 07030']},
#    'phone': '+12016569100',
#    'display_phone': '(201) 656-9100',
#    'distance': 4805.13074102588}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#           Restaurant           Type Price Rating        Address        Lat  \
# 0          BXL Zoute        Belgian    $$      4   50 W 22nd St  40.741740
# 1          Naked Dog        Italian    $$    4.5     47 Java St  40.731272
# 2            Tambour      Wine Bars   $$$    4.5    652 5th Ave  40.662504
# 3  Nubleu Restaurant  Mediterranean                 315 5th Ave  40.672874
# 4         The Simone         French  $$$$      5  151 E 82nd St  40.776820
#
#          Lng                                                url  \
# 0 -73.992627  https://www.yelp.com/biz/bxl-zoute-new-york?ad...
# 1 -73.959349  https://www.yelp.com/biz/naked-dog-brooklyn-2?...
# 2 -73.992533  https://www.yelp.com/biz/tambour-brooklyn-3?ad...
# 3 -73.983030
# 4 -73.956980  https://www.yelp.com/biz/the-simone-new-york?a...
#
#                        ID
# 0  8cT6XDwI9KiCaoVohlx42Q
# 1  OwDRIugcA4LkUuTRqpJsog
# 2  eT39RKlQ8i5Z4ml0ZwUK-Q
# 3
# 4  Okbtt-ISFB3kuoxkl2wVgg

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                           Restaurant                Type Rating Price  \
# 0                  Paradis Des Gouts             African    4.5    $$
# 1               Casa Del Chef Bistro      American (New)    4.5    $$
# 2                           Perry St      American (New)      4   $$$
# 3                       David's Cafe      American (New)      4    $$
# 4                            Francie      American (New)
# 5                             Almond      American (New)      4    $$
# 6                Eleven Madison Park      American (New)    4.5  $$$$
# 7                    Cafe Luxembourg      American (New)      4   $$$
# 8                         St. Anselm      American (New)      4   $$$
# 9                       Elysian Cafe      American (New)    3.5    $$
# 10                         The Odeon      American (New)      4   $$$
# 11            Tocqueville Restaurant      American (New)      4  $$$$
# 12                    The River Café      American (New)      4  $$$$
# 13          Simple Cafe & Restaurant      American (New)      4    $$
# 14                    Joseph Leonard      American (New)      4    $$
# 15                         Le Garage      American (New)      4    $$
# 16                      Atrium Dumbo      American (New)      4    $$
# 17                      Cafe Matisse      American (New)    4.5  $$$$
# 18                    La Boulangerie            Bakeries      4    $$
# 19                     Maman Tribeca            Bakeries      4    $$
# 20                  Excuse My French                Bars    4.5    $$
# 21                          Juliette                Bars    3.5    $$
# 22                           Ainslie        Beer Gardens      4    $$
# 23                         BXL Zoute             Belgian      4    $$
# 24                     Pommes Frites             Belgian    4.5     $
# 25                         Bistro So          Brasseries
# 26              Brasserie Saint Marc          Brasseries
# 27                        Frenchette          Brasseries    3.5  $$$$
# 28                  La Bergamote NYC  Breakfast & Brunch      4    $$
# 29                        La Cantine  Breakfast & Brunch
# ..                               ...                 ...    ...   ...
# 170                      Cafe Gitane            Moroccan
# 171                         Raclette          Sandwiches      4    $$
# 172                  Petite Crevette             Seafood      4    $$
# 173                          El Born             Spanish    4.5    $$
# 174           Boucherie Union Square         Steakhouses    4.5   $$$
# 175  Le Relais De Venise L'Entrecôte         Steakhouses      4   $$$
# 176                       Duane Park        Supper Clubs    4.5  $$$$
# 177                           GAUDir  Tapas/Small Plates
# 178                        Westlight  Tapas/Small Plates    3.5   $$$
# 179                          BoCaphe          Vietnamese      4    $$
# 180                     Have & Meyer           Wine Bars      4    $$
# 181                     Le Botaniste           Wine Bars    4.5    $$
# 182                The Four Horsemen           Wine Bars    4.5    $$
# 183                           Sauced           Wine Bars
# 184                          Tambour           Wine Bars    4.5   $$$
# 185                        Grand Vin           Wine Bars      4    $$
# 186                     Bar Blondeau           Wine Bars
# 187                       Lighthouse           Wine Bars      4    $$
# 188                         Big Tiny           Wine Bars    4.5    $$
# 189                            LaLou           Wine Bars
# 190                    Vin Sur Vingt           Wine Bars    4.5    $$
# 191   Compagnie des Vins Surnaturels           Wine Bars    4.5   $$$
# 192                    Fradei Bistro           Wine Bars
# 193                             bibi           Wine Bars    4.5    $$
# 194               Pinkerton Wine Bar           Wine Bars      4    $$
# 195                   Petit Paulette           Wine Bars
# 196                             June           Wine Bars      4    $$
# 197           St Tropez West Village           Wine Bars    4.5    $$
# 198                          Ruffian           Wine Bars    4.5    $$
# 199                             Lena           Wine Bars
#
#                    Address        Lat        Lng  \
# 0            1136 Broadway  40.693330 -73.929310
# 1        39-06 1/2 64th St  40.746291 -73.900092
# 2             176 Perry St  40.734420 -74.009710
# 3          110 St Marks Pl  40.726931 -73.984343
# 4             134 Broadway  40.710026 -73.964057
# 5             12 E 22nd St  40.740082 -73.988754
# 6           11 Madison Ave  40.741691 -73.987207
# 7            200 W 70th St  40.777410 -73.983120
# 8     355 Metropolitan Ave  40.714330 -73.956040
# 9       1001 Washington St  40.748646 -74.027349
# 10          145 W Broadway  40.716920 -74.007920
# 11             1 E 15th St  40.736620 -73.992720
# 12              1 Water St  40.703180 -73.994650
# 13         346 Bedford Ave  40.712440 -73.962750
# 14          170 Waverly Pl  40.733602 -74.001675
# 15           157 Suydam St  40.699386 -73.926595
# 16              15 Main St  40.703390 -73.990492
# 17            167 Park Ave  40.825030 -74.109330
# 18          109-01 72nd Rd  40.719200 -73.841530
# 19          211 W Broadway  40.718897 -74.006221
# 20           96 Orchard St  40.718440 -73.989810
# 21           135C N 5th St  40.717020 -73.959077
# 22           76 Ainslie St  40.712343 -73.952121
# 23            50 W 22nd St  40.741740 -73.992627
# 24        128 Macdougal St  40.730022 -74.000152
# 25          530 Driggs Ave  40.717550 -73.956030
# 26             136 2nd Ave  40.728648 -73.987208
# 27          241 W Broadway  40.719640 -74.005780
# 28             177 9th Ave  40.745044 -74.002863
# 29      60 St Nicholas Ave  40.706640 -73.920600
# ..                     ...        ...        ...
# 170          70 Hudson Ave  40.702827 -73.981281
# 171          511 E 12th St  40.728930 -73.980601
# 172           144 Union St  40.683960 -74.001800
# 173      651 Manhattan Ave  40.724348 -73.951223
# 174         225 Park Ave S  40.737258 -73.988225
# 175      590 Lexington Ave  40.757709 -73.971763
# 176             308 Bowery  40.724917 -73.992542
# 177         251 E 110th St  40.793490 -73.941000
# 178          111 N 12th St  40.722299 -73.956691
# 179       222 Lafayette St  40.722062 -73.997587
# 180       103 Havemeyer St  40.713269 -73.956474
# 181      833 Lexington Ave  40.764999 -73.965983
# 182           295 Grand St  40.713050 -73.957320
# 183        331 Bedford Ave  40.712670 -73.962319
# 184            652 5th Ave  40.662504 -73.992533
# 185           500 Grand St  40.743310 -74.035170
# 186           80 Wythe Ave  40.722080 -73.957850
# 187       145 Borinquen Pl  40.710408 -73.953904
# 188           244 Smith St  40.683451 -73.992855
# 189     581 Vanderbilt Ave  40.680311 -73.967596
# 190           66 W 84th St  40.784920 -73.972910
# 191             249 Ctr St  40.720516 -73.998165
# 192  99 South Portland Ave  40.686579 -73.974191
# 193           211 E 4th St  40.723937 -73.983519
# 194           263 N 6th St  40.714912 -73.954229
# 195         136 Dekalb Ave  40.689610 -73.975790
# 196           231 Court St  40.686065 -73.993889
# 197           304 W 4th St  40.737040 -74.003860
# 198           125 E 7th St  40.726400 -73.984110
# 199         1B West 8th St  40.732552 -73.996704
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/paradis-des-gouts-bro...  r_QEUVdoo8dsKR9fK31w3w
# 1    https://www.yelp.com/biz/casa-del-chef-bistro-...  nw5_0jb_u2a6nUt4Je09Xg
# 2    https://www.yelp.com/biz/perry-st-new-york?adj...  2VpurA2lb-q90nmALklNcA
# 3    https://www.yelp.com/biz/davids-cafe-new-york?...  3V20VbC45XL4TBYTL9DrOg
# 4
# 5    https://www.yelp.com/biz/almond-new-york?adjus...  6ujYWjs1FTksvuVxuzjUYA
# 6    https://www.yelp.com/biz/eleven-madison-park-n...  nRO136GRieGtxz18uD61DA
# 7    https://www.yelp.com/biz/cafe-luxembourg-new-y...  fSQ3CCtFSJ2S8VXDi02-3Q
# 8    https://www.yelp.com/biz/st-anselm-brooklyn?ad...  hiTfA7vnxDSLv77nl6UQXQ
# 9    https://www.yelp.com/biz/elysian-cafe-hoboken?...  JbpjgLAk4DaP0zvY7dP9Hw
# 10   https://www.yelp.com/biz/the-odeon-new-york?ad...  P2CTp4xyaNCe2AXSiLeOSQ
# 11   https://www.yelp.com/biz/tocqueville-restauran...  a0AvIH1UnFmqAXhZDEQtrw
# 12   https://www.yelp.com/biz/the-river-caf%C3%A9-b...  4XX-zF8h5Lvrr22_tqU6-Q
# 13   https://www.yelp.com/biz/simple-cafe-and-resta...  ArfL-sU2FaB73WV1qQ4c6Q
# 14   https://www.yelp.com/biz/joseph-leonard-new-yo...  Ps0cOZevNA1M9M5_z7W3oQ
# 15   https://www.yelp.com/biz/le-garage-brooklyn?ad...  M85t-iOAbMpO9mVIKAgwMw
# 16   https://www.yelp.com/biz/atrium-dumbo-brooklyn...  hmdm-dO72hLsMQwQRcGEUQ
# 17   https://www.yelp.com/biz/cafe-matisse-rutherfo...  jeJfYLekXo3yxUpDfNukyQ
# 18   https://www.yelp.com/biz/la-boulangerie-forest...  43y93456fzLVTF7LdlZikw
# 19   https://www.yelp.com/biz/maman-tribeca-new-yor...  XBWO26QblInZGftnSDD94A
# 20   https://www.yelp.com/biz/excuse-my-french-new-...  iexl39DYyy_76Xq3ExaJkQ
# 21   https://www.yelp.com/biz/juliette-brooklyn?adj...  emTmnLlesIwxRofQ34ntdA
# 22   https://www.yelp.com/biz/ainslie-brooklyn-2?ad...  -7PnG_cD9VY-IfHGWzynmQ
# 23   https://www.yelp.com/biz/bxl-zoute-new-york?ad...  8cT6XDwI9KiCaoVohlx42Q
# 24   https://www.yelp.com/biz/pommes-frites-new-yor...  uBGjcW-GuYy_qSvMykuISA
# 25
# 26
# 27   https://www.yelp.com/biz/frenchette-new-york-2...  dAHoDxBmzWqfobnTbCHaQA
# 28   https://www.yelp.com/biz/la-bergamote-nyc-new-...  8xYvp9j7j8RCRQGsiRRujQ
# 29
# ..                                                 ...                     ...
# 170
# 171  https://www.yelp.com/biz/raclette-new-york?adj...  5m-TrbqMNnwJvOd7pAt6OA
# 172  https://www.yelp.com/biz/petite-crevette-brook...  TCJrcryBkI6eg2HYThoiKg
# 173  https://www.yelp.com/biz/el-born-brooklyn?adju...  gvMYV5E3HyzhN_MYFIMGzg
# 174  https://www.yelp.com/biz/boucherie-union-squar...  8XHbZIKDQbXhyKIGiukVeQ
# 175  https://www.yelp.com/biz/le-relais-de-venise-l...  9vYSRXdp5JtFmqhi0FigMA
# 176  https://www.yelp.com/biz/duane-park-new-york-3...  VuR3lhMA80aH42jrBM_C8A
# 177
# 178  https://www.yelp.com/biz/westlight-brooklyn?ad...  71HLFDV5yIX8l7WqP7Km5g
# 179  https://www.yelp.com/biz/bocaph%C3%AA-new-york...  C2o3Iw-DXjoUJFgQIbiqkQ
# 180  https://www.yelp.com/biz/have-and-meyer-brookl...  JU5d81TYm7IJHWqOqJWMqw
# 181  https://www.yelp.com/biz/le-botaniste-new-york...  -vBfKWJ1v9YdJQT5XUbcBQ
# 182  https://www.yelp.com/biz/the-four-horsemen-bro...  Orbsfc3nI21mQ8cwSPahhg
# 183
# 184  https://www.yelp.com/biz/tambour-brooklyn-3?ad...  eT39RKlQ8i5Z4ml0ZwUK-Q
# 185  https://www.yelp.com/biz/grand-vin-hoboken?adj...  I6Wg1NFYAAVzM2OpsdqcXA
# 186
# 187  https://www.yelp.com/biz/lighthouse-brooklyn-2...  DhBhEWMVLDxYF14a1znUvA
# 188  https://www.yelp.com/biz/big-tiny-brooklyn-4?a...  OkiPb6gNNRmcbB4zIIMx0g
# 189
# 190  https://www.yelp.com/biz/vin-sur-vingt-new-yor...  ykTc4pZYEAY0Esd0yVFSOQ
# 191  https://www.yelp.com/biz/compagnie-des-vins-su...  l2b6HJGarUxoeLnM9syTmg
# 192
# 193  https://www.yelp.com/biz/bibi-new-york?adjust_...  HbCyzokiA19bEWUp6mga_g
# 194  https://www.yelp.com/biz/pinkerton-wine-bar-br...  5jPaUdIjz_5u3N1gpUbwmA
# 195
# 196  https://www.yelp.com/biz/june-brooklyn-3?adjus...  OsA5iRphHwPlYNhdddvBng
# 197  https://www.yelp.com/biz/st-tropez-west-villag...  CcxreLJbZsO6Z775-hMWpw
# 198  https://www.yelp.com/biz/ruffian-new-york-4?ad...  fFkqEyupjc5x2iJQIPcpLw
# 199
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_French.csv')
