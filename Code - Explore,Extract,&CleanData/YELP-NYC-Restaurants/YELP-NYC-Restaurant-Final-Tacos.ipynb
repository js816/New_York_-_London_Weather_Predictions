# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"tacos","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': 'jnEv25Y2DosTq2sNnvmC9g',
#    'alias': 'los-tacos-no-1-new-york',
#    'name': 'Los Tacos No.1',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FU44TYl3PzXsE06G4W5aog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-tacos-no-1-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3208,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7425547, 'longitude': -74.0060838},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '75 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 9th Ave', 'New York, NY 10011']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4244.358699250552},
#   {'id': '6403iqg-_a-sdg-DrKEfhw',
#    'alias': 'birria-landia-jackson-heights',
#    'name': 'Birria-Landia',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9RXUeoOuM2-Z7L-mKmlUaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/birria-landia-jackson-heights?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 367,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.747258, 'longitude': -73.887784},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': 'Roosevelt Ave & 78th St',
#     'address2': None,
#     'address3': None,
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Roosevelt Ave & 78th St',
#      'Jackson Heights, NY 11372']},
#    'phone': '+13472832162',
#    'display_phone': '(347) 283-2162',
#    'distance': 10108.007635605787},
#   {'id': '6Ct7OeTRn4caY9g0swFBsw',
#    'alias': 'la-contenta-new-york',
#    'name': 'La Contenta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FwZAyPgdKdPGQ8aAGKh3-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-contenta-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 804,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71873, 'longitude': -73.98691},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '102 Norfolk St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 Norfolk St', 'New York, NY 10002']},
#    'phone': '+12124324180',
#    'display_phone': '(212) 432-4180',
#    'distance': 1605.0692537545654},
#   {'id': 'MfbVI5reXLIIs8Cc2HwgQw',
#    'alias': 'breakroom-new-york',
#    'name': 'Breakroom',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6vv_E_iEX19gRg8M-zXFXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/breakroom-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1611,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7166907225542,
#     'longitude': -73.9999440120647},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '83 Baxter St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['83 Baxter St', 'New York, NY 10013']},
#    'phone': '+12122272802',
#    'display_phone': '(212) 227-2802',
#    'distance': 1338.114942586202},
#   {'id': '9aJ1MVTthZw3QjqoG7mPjg',
#    'alias': 'rosies-new-york-2',
#    'name': "Rosie's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/C5Mf9gLWxbTiTzmOp2B2YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rosies-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 789,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72492, 'longitude': -73.99079},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '29 E 2nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['29 E 2nd St', 'New York, NY 10003']},
#    'phone': '+12123350114',
#    'display_phone': '(212) 335-0114',
#    'distance': 2184.8979126551453},
#   {'id': '7YYp_2WYWdRSt_NohV7Psw',
#    'alias': 'casa-birria-nyc-new-york',
#    'name': 'Casa Birria NYC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/koyMTX0E-LNBnuV8-_q7uw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-birria-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.778824, 'longitude': -73.953986},
#    'transactions': ['delivery'],
#    'location': {'address1': '86th & 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['86th & 3rd Ave', 'New York, NY 10028']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8837.33983212048},
#   {'id': 'LWHHNai3yu6ovrf4Bcepjg',
#    'alias': 'birria-landia-williamsburg-brooklyn',
#    'name': 'Birria Landia Williamsburg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5OTMaxk9XpdQFQaCnjGVPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/birria-landia-williamsburg-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 114,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71390489837251,
#     'longitude': -73.95196261271435},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '495 Metropolian Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['495 Metropolian Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13478398706',
#    'display_phone': '(347) 839-8706',
#    'distance': 3689.9045076815796},
#   {'id': 'buZ1-T3rdV_1d5gHreJD6w',
#    'alias': 'sullivan-taqueria-new-york',
#    'name': 'Sullivan Taqueria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1jTWGGfhDaepaT1JD5WECg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sullivan-taqueria-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72447, 'longitude': -74.0039},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '71 Sullivan St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['71 Sullivan St', 'New York, NY 10012']},
#    'phone': '+16467070077',
#    'display_phone': '(646) 707-0077',
#    'distance': 2263.219481785737},
#   {'id': '8CTaeOtqr461Ah5yWcnCPw',
#    'alias': 'fatty-daddy-taco-brooklyn-2',
#    'name': 'Fatty Daddy Taco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Aciaw9F7SRJjDYBB-IziUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fatty-daddy-taco-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 182,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.686578, 'longitude': -73.990821},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '152 Smith St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['152 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+19292959361',
#    'display_phone': '(929) 295-9361',
#    'distance': 2115.8390976966602},
#   {'id': 'L3REPLCvQpMapYPd_fkS-A',
#    'alias': 'los-mariscos-new-york',
#    'name': 'Los Mariscos',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/miAqlvuZ-SEdViMIAbHkeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-mariscos-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 659,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74207, 'longitude': -74.00565},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '409 W 15th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['409 W 15th St', 'New York, NY 10011']},
#    'phone': '+12129204986',
#    'display_phone': '(212) 920-4986',
#    'distance': 4183.62631647822},
#   {'id': 'SCQvI5pAJmD-OMm37kkS6Q',
#    'alias': 'dorado-tacos-and-quesadillas-new-york-3',
#    'name': 'DORADO Tacos & Quesadillas',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hnzUM5cHSTuCyh2WtsMZDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dorado-tacos-and-quesadillas-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 672,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73396, 'longitude': -73.99312},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '28 E 12th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 E 12th St', 'New York, NY 10003']},
#    'phone': '+12126270900',
#    'display_phone': '(212) 627-0900',
#    'distance': 3169.948723705394},
#   {'id': 'ykTNq1F-Vpfw4i4xGhPS0Q',
#    'alias': 'the-little-taco-house-new-york',
#    'name': 'The Little Taco House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JB2ZLgqi9DjwOp5SHwxvYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-little-taco-house-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 62,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73475, 'longitude': -74.00321},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '246 West 4th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['246 West 4th St', 'New York, NY 10014']},
#    'phone': '+16467191600',
#    'display_phone': '(646) 719-1600',
#    'distance': 3338.201322009663},
#   {'id': 'BK99GBVm_V6n_CTsc65mTw',
#    'alias': 'esqueleto-taqueria-brooklyn-new-york',
#    'name': 'Esqueleto Taqueria - Brooklyn',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pfrKAR480EcKgha5R9DxLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/esqueleto-taqueria-brooklyn-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.690561, 'longitude': -73.994917},
#    'transactions': ['delivery'],
#    'location': {'address1': '155 Atlantic Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['155 Atlantic Ave', 'New York, NY 11201']},
#    'phone': '+19292981531',
#    'display_phone': '(929) 298-1531',
#    'distance': 1644.1127558652634},
#   {'id': 'SULHf6nGQ8sK0UpG1XU30w',
#    'alias': 'los-tacos-no-1-new-york-3',
#    'name': 'Los Tacos No.1',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5wEe4FCwda16knmBHSsX0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-tacos-no-1-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2011,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7575067, 'longitude': -73.9877717},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '229 W 43rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['229 W 43rd St', 'New York, NY 10036']},
#    'phone': '+12125744696',
#    'display_phone': '(212) 574-4696',
#    'distance': 5815.027424033859},
#   {'id': '4UxmxAqehEIh7fYrzUEA7A',
#    'alias': 'tacovision-new-york',
#    'name': 'Tacovision',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RrlJH2x3tsoh-JhnfO5gzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacovision-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 238,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7568200311153,
#     'longitude': -73.9678929001093},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '244 E 53rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['244 E 53rd St', 'New York, NY 10004']},
#    'phone': '+16469211990',
#    'display_phone': '(646) 921-1990',
#    'distance': 6130.488021640037},
#   {'id': '4pj4ol7lXiytDD-BTKe3kg',
#    'alias': 'las-santas-brooklyn-2',
#    'name': 'Las Santas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/m6bIlG5fhb3C-wbJr3-yzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/las-santas-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 197,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6882, 'longitude': -73.97953},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '572 Fulton St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['572 Fulton St', 'Brooklyn, NY 11217']},
#    'phone': '+17182225919',
#    'display_phone': '(718) 222-5919',
#    'distance': 2284.03042107995},
#   {'id': 'WSjhU85kBSvidxDJaBTV1g',
#    'alias': 'chinelos-tacos-nyc-queens',
#    'name': 'Chinelos Tacos NYC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0rgWLznjBVV4G4vXPSVr-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chinelos-tacos-nyc-queens?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7423518016186,
#     'longitude': -73.9599615129021},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '4-09 Center Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Queens',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4-09 Center Blvd', 'Queens, NY 11101']},
#    'phone': '+19178199066',
#    'display_phone': '(917) 819-9066',
#    'distance': 5316.862222316733},
#   {'id': 'BbMUXd69i0tlWS2aoppwaQ',
#    'alias': 'el-camion-new-york',
#    'name': 'El Camion',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AKQiOduSegbWFk8zbG0YlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-camion-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 717,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7291, 'longitude': -73.98105},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '194 Ave A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['194 Ave A', 'New York, NY 10009']},
#    'phone': '+12125335436',
#    'display_phone': '(212) 533-5436',
#    'distance': 2859.0916051095014},
#   {'id': 'RzKR9QcYP03EQ_8DxTxowg',
#    'alias': 'barrio-chino-new-york',
#    'name': 'Barrio Chino',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Gd6huFUDxp3I27bfo8c1gg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barrio-chino-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1135,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.718022, 'longitude': -73.990026},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '253 Broome St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253 Broome St', 'New York, NY 10002']},
#    'phone': '+12122286710',
#    'display_phone': '(212) 228-6710',
#    'distance': 1444.0205013853188},
#   {'id': 'zash7ih8QWBk3Kl3AAeyCQ',
#    'alias': 'los-tacos-nyc-new-york-3',
#    'name': 'Los Tacos NYC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AKUse56XW2gG62mdRwLwfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-tacos-nyc-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.726629, 'longitude': -73.984279},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '117 E 7th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['117 E 7th St', 'New York, NY 10009']},
#    'phone': '+16463705211',
#    'display_phone': '(646) 370-5211',
#    'distance': 2497.185753459356},
#   {'id': 'FavssEgZjXFi2unEXePkVQ',
#    'alias': 'tacombi-bleecker-street-new-york',
#    'name': 'Tacombi - Bleecker Street',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zSzX3khnr-eDMFngm76D2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacombi-bleecker-street-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 410,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73112, 'longitude': -74.00272},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '255 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['255 Bleecker St', 'New York, NY 10014']},
#    'phone': '+16469645984',
#    'display_phone': '(646) 964-5984',
#    'distance': 2940.5050096886853},
#   {'id': '8uuMkezIN1c8zGEWkaMRqg',
#    'alias': 'los-tacos-no-1-new-york-5',
#    'name': 'Los Tacos No. 1',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Kc8b_SfidM01BhZtOmH34A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-tacos-no-1-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 246,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.714282, 'longitude': -74.008675},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '136 Church St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136 Church St', 'New York, NY 10007']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1560.4648143099334},
#   {'id': 'xN4yKQMzo3PIoQlFamUOLQ',
#    'alias': 'la-esquina-midtown-new-york-2',
#    'name': 'La Esquina - Midtown',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1qOuQs_ldEtU9kAs4XZJlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-esquina-midtown-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 222,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7642986928764,
#     'longitude': -73.9814604957066},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '200 W 55th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 W 55th St', 'New York, NY 10019']},
#    'phone': '+16466137100',
#    'display_phone': '(646) 613-7100',
#    'distance': 6632.95963056546},
#   {'id': '8_NilECM6qg_L7WYb25uNw',
#    'alias': 'luchadores-new-york',
#    'name': 'Luchadores',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/msMvfv7V-0dPzBWwsTqNdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luchadores-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 102,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70582, 'longitude': -74.00411},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '87 South St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['87 South St', 'New York, NY 10038']},
#    'phone': '+19174093033',
#    'display_phone': '(917) 409-3033',
#    'distance': 832.4915733862251},
#   {'id': 'NUdrJYB7GHRuwVVETSDIFQ',
#    'alias': 'top-quality-long-island-city-2',
#    'name': 'Top Quality',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/93b7W8nBnMewfeW5xVp9Og/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/top-quality-long-island-city-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 94,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74961, 'longitude': -73.94994},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '10-29 44th Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10-29 44th Rd', 'Long Island City, NY 11101']},
#    'phone': '+17187868271',
#    'display_phone': '(718) 786-8271',
#    'distance': 6161.211772393139},
#   {'id': 'XipQLDbyTl5tsLlyzAWzug',
#    'alias': 'jajaja-plantas-mexicana-new-york-2',
#    'name': 'Jajaja Plantas Mexicana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OkWKXxOZBLJO7hRjOlIMig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jajaja-plantas-mexicana-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1050,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7141530317142,
#     'longitude': -73.9904247969389},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '162 E Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 E Broadway', 'New York, NY 10002']},
#    'phone': '+16468835453',
#    'display_phone': '(646) 883-5453',
#    'distance': 1021.7274074140097},
#   {'id': 'hKkPlYmHoS9Nb_UbGGqx8A',
#    'alias': 'street-taco-new-york',
#    'name': 'Street Taco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9zKNZP_LgeTRca1iMosWZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/street-taco-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 421,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74097, 'longitude': -73.98202},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '358 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['358 3rd Ave', 'New York, NY 10016']},
#    'phone': '+16467915413',
#    'display_phone': '(646) 791-5413',
#    'distance': 4083.368080929157},
#   {'id': '7ERwg_4Kiaq1ezKTSSv7pg',
#    'alias': 'taqueria-86-new-york',
#    'name': 'Taqueria 86',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Go99acAiyA8VmOYwLesLgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-86-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.793, 'longitude': -73.97214},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '210 W 94th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['210 W 94th St', 'New York, NY 10025']},
#    'phone': '+19176757727',
#    'display_phone': '(917) 675-7727',
#    'distance': 9910.460688933712},
#   {'id': 'pG-IkylRFOb-HlaD8NwvvQ',
#    'alias': 'la-loteria-new-york',
#    'name': 'La Loteria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EyExqWPVoPrct0D_shxCHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-loteria-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 341,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7307865530978,
#     'longitude': -74.0041882564488},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '29 7th Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['29 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12128589096',
#    'display_phone': '(212) 858-9096',
#    'distance': 2938.6730350789044},
#   {'id': 'M6XZ8IIOGmBfh79vk79Eqw',
#    'alias': 'tacombi-williamsburg-new-york-2',
#    'name': 'Tacombi - Williamsburg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/g3JXGXiyRr6zrMgP-ZxWcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacombi-williamsburg-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71489, 'longitude': -73.95949},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '242 Metropolitan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['242 Metropolitan Ave', 'New York, NY 11211']},
#    'phone': '+17185993496',
#    'display_phone': '(718) 599-3496',
#    'distance': 3115.9797628458473},
#   {'id': '_M5FVY4hkcuU-ASdVZPfRQ',
#    'alias': 'tacos-el-bronco-brooklyn-2',
#    'name': 'Tacos El Bronco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Lh8G4EkEtpmd1Fru7DMMdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-el-bronco-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 616,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.65006, 'longitude': -74.00915},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '4324 4th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11220',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4324 4th Ave', 'Brooklyn, NY 11220']},
#    'phone': '+17187882229',
#    'display_phone': '(718) 788-2229',
#    'distance': 6282.52410458184},
#   {'id': 'r5NT8-nV4py2c-mppTKucQ',
#    'alias': 'essex-taqueria-new-york',
#    'name': 'Essex Taqueria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/npICG7pJaFGryptc6Su53w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/essex-taqueria-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 299,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7197418, 'longitude': -73.9877989},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '123 Essex St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['123 Essex St', 'New York, NY 10002']},
#    'phone': '+12122608226',
#    'display_phone': '(212) 260-8226',
#    'distance': 1681.3399161905245},
#   {'id': 'eCD1l-Xx3QqnhrSsoccgMg',
#    'alias': 'tacocina-brooklyn',
#    'name': 'Tacocina',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/B7Nc3cXHIPvh-qZBrWclfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacocina-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 116,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.715238, 'longitude': -73.967644},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '25 River St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 River St', 'Brooklyn, NY 11249']},
#    'phone': '+16467836825',
#    'display_phone': '(646) 783-6825',
#    'distance': 2496.2368372547307},
#   {'id': 'B9GWlhwXaUezB_GpGq1pfA',
#    'alias': 'los-tacos-al-pastor-brooklyn-4',
#    'name': 'Los Tacos Al Pastor',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kWs8jxlV8dG1hFx_4ZxSPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-tacos-al-pastor-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 75,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.70254, 'longitude': -73.98736},
#    'transactions': ['delivery'],
#    'location': {'address1': '141 Front St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['141 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+13479160190',
#    'display_phone': '(347) 916-0190',
#    'distance': 659.2895421506058},
#   {'id': 'WZynqsGjqQLc_T8R80_-7g',
#    'alias': 'yellow-rose-new-york',
#    'name': 'Yellow Rose',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dRTusdsM9wHzfxbFSyGtsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yellow-rose-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'tex-mex', 'title': 'Tex-Mex'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.732575, 'longitude': -73.98806909999999},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '102 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 3rd Ave', 'New York, NY 10003']},
#    'phone': '+12125298880',
#    'display_phone': '(212) 529-8880',
#    'distance': 3061.9943849968618},
#   {'id': 'IfIyjm4SfORGYPbaAWST3g',
#    'alias': 'mexicue-new-york-6',
#    'name': 'Mexicue',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pGHHhm-MWI7EDzkQSy_ocg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mexicue-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 562,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.743617, 'longitude': -73.987867},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '225 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['225 5th Ave', 'New York, NY 10010']},
#    'phone': '+16469227289',
#    'display_phone': '(646) 922-7289',
#    'distance': 4278.949083000282},
#   {'id': 'znlol6dCKwjoXpZZwV_ZOg',
#    'alias': 'nacho-macho-taco-brooklyn',
#    'name': 'Nacho Macho Taco',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tbSPgGRLO1uDjLLS-r-QRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nacho-macho-taco-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 208,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.680574, 'longitude': -73.977879},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '82 5th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['82 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17186228282',
#    'display_phone': '(718) 622-8282',
#    'distance': 3093.8183653681804},
#   {'id': 'uLWp1QR_W2WJImMnB706hg',
#    'alias': 'mexicue-new-york-10',
#    'name': 'Mexicue',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qrJYY_rxp9vwfTjAdw4NVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mexicue-new-york-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 456,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74202, 'longitude': -74.00046},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '160 8th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['160 8th Ave', 'New York, NY 10011']},
#    'phone': '+16466493133',
#    'display_phone': '(646) 649-3133',
#    'distance': 4103.57785075036},
#   {'id': 'ub2VfE7SRLJABAClzGZp3A',
#    'alias': 'tacombi-flatiron-new-york-3',
#    'name': 'Tacombi - Flatiron',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KpC1h8QFhBFXJfENxuZ6ZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacombi-flatiron-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 687,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.742807, 'longitude': -73.991138},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '30 W 24th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30 W 24th St', 'New York, NY 10010']},
#    'phone': '+12122423491',
#    'display_phone': '(212) 242-3491',
#    'distance': 4162.975211237086},
#   {'id': '6ZfVmImuKJg9lB1PF4pfPg',
#    'alias': 'taqueria-fort-greene-brooklyn',
#    'name': 'Taqueria Fort Greene',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Xma0q6hT2gBu3W43MJH64A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-fort-greene-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6930219027123,
#     'longitude': -73.9729583744799},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '154 Carlton Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['154 Carlton Ave', 'Brooklyn, NY 11205']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2267.818109249734},
#   {'id': 'Zk8UgB9MDoIHWFYgAxNlIQ',
#    'alias': 'de-mole-brooklyn',
#    'name': 'De Mole',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pkungMeCPUImTcI3Sy4Q9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/de-mole-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 167,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71377, 'longitude': -73.95786},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2 Hope St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2 Hope St', 'Brooklyn, NY 11211']},
#    'phone': '+13477213399',
#    'display_phone': '(347) 721-3399',
#    'distance': 3209.8393092317224},
#   {'id': 'jQjQHNAM8xXB73kFkfg9kA',
#    'alias': 'tacos-cholula-new-york',
#    'name': 'Tacos Cholula',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_JlaiQQIga5YxUIE1NQafg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-cholula-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 153,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72301, 'longitude': -73.98605},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '25 Ave A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 Ave A', 'New York, NY 10009']},
#    'phone': '+19294054961',
#    'display_phone': '(929) 405-4961',
#    'distance': 2072.9195616899315},
#   {'id': 'uVfOB37NyYEGRs5FITM-nQ',
#    'alias': 'leyenda-brooklyn',
#    'name': 'Leyenda',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xmzICvK5W37OzD61Bpv1uQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/leyenda-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 261,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68431, 'longitude': -73.99197},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '221 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['221 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+13479873260',
#    'display_phone': '(347) 987-3260',
#    'distance': 2361.4337938854646},
#   {'id': 'SP4bvMvxel_UPdof_er3HA',
#    'alias': 'taco-mahal-new-york',
#    'name': 'Taco Mahal',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wo7f5lvsgtQ5fOeWw6z83A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-mahal-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 658,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73235768476899,
#     'longitude': -74.00332645767203},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '73 7th Ave S',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['73 7th Ave S', 'New York, NY 10014']},
#    'phone': '+16467191553',
#    'display_phone': '(646) 719-1553',
#    'distance': 3087.8819675850696},
#   {'id': 'NUi84uNaFW2LUNZ3oEai1Q',
#    'alias': 'the-99-cent-taco-truck-new-york',
#    'name': 'The 99 Cent Taco Truck',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rV8WoiH2Rf14BsZFlcrgyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-99-cent-taco-truck-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.790896, 'longitude': -73.9451536},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['New York, NY 10029']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 10364.274623819032},
#   {'id': 'xGNzAsakHgbbl9fwgSoiUg',
#    'alias': 'kahlo-new-york',
#    'name': 'Kahlo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EhIU0Y_tiR3ScJpOaBmJOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kahlo-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 157,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.752092, 'longitude': -74.0026757},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '525 West 29th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['525 West 29th St', 'New York, NY 10001']},
#    'phone': '+12122560083',
#    'display_phone': '(212) 256-0083',
#    'distance': 5234.792286716743},
#   {'id': 'Wx6lMnEh7dCmX-9PQF1Ifw',
#    'alias': 'toloache-50-new-york',
#    'name': 'Toloache 50',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/m5yGUnpSxMB0KaxgwwXMQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/toloache-50-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2021,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.762227, 'longitude': -73.9856178382696},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '251 West 50th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['251 West 50th St', 'New York, NY 10012']},
#    'phone': '+12125811818',
#    'display_phone': '(212) 581-1818',
#    'distance': 6356.050185697199},
#   {'id': 'r0Krxbk7O1KRjgvOYMHMug',
#    'alias': 'el-gallo-taqueria-new-york',
#    'name': 'EL Gallo Taqueria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XA6rFVejFdIl_VN7o4_HjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-gallo-taqueria-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.719886, 'longitude': -73.995982},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '369 Broome St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['369 Broome St', 'New York, NY 10013']},
#    'phone': '+19176680033',
#    'display_phone': '(917) 668-0033',
#    'distance': 1613.5181728785944},
#   {'id': 'd7YbQzGlmawMGAzUHzZvuw',
#    'alias': 'tacombi-nolita-new-york-3',
#    'name': 'Tacombi - Nolita',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rzykPC6abTNxa-W5fsRQ6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacombi-nolita-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1139,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7240304, 'longitude': -73.9939028},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '267 Elizabeth St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['267 Elizabeth St', 'New York, NY 10012']},
#    'phone': '+19177270179',
#    'display_phone': '(917) 727-0179',
#    'distance': 2066.876909549628},
#   {'id': '7bD22UAtH56ikWYslOSIQg',
#    'alias': 'calexico-upper-east-side-new-york-2',
#    'name': 'Calexico - Upper East Side',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/If17MxTRNkk2CbzlFkW_8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/calexico-upper-east-side-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 736,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77259, 'longitude': -73.95588},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1491 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1491 2nd Ave', 'New York, NY 10075']},
#    'phone': '+13479675955',
#    'display_phone': '(347) 967-5955',
#    'distance': 8138.257554066013}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#        Restaurant         Type Price Rating                  Address  \
# 0  Los Tacos No.1        Tacos     $    4.5               75 9th Ave
# 1   Birria-Landia  Food Trucks     $    4.5  Roosevelt Ave & 78th St
# 2     La Contenta      Mexican    $$    4.5           102 Norfolk St
# 3       Breakroom      Burgers    $$    4.5             83 Baxter St
# 4         Rosie's      Mexican    $$      4              29 E 2nd St
#
#          Lat        Lng                                                url  \
# 0  40.742555 -74.006084  https://www.yelp.com/biz/los-tacos-no-1-new-yo...
# 1  40.747258 -73.887784  https://www.yelp.com/biz/birria-landia-jackson...
# 2  40.718730 -73.986910  https://www.yelp.com/biz/la-contenta-new-york?...
# 3  40.716691 -73.999944  https://www.yelp.com/biz/breakroom-new-york?ad...
# 4  40.724920 -73.990790  https://www.yelp.com/biz/rosies-new-york-2?adj...
#
#                        ID
# 0  jnEv25Y2DosTq2sNnvmC9g
# 1  6403iqg-_a-sdg-DrKEfhw
# 2  6Ct7OeTRn4caY9g0swFBsw
# 3  MfbVI5reXLIIs8Cc2HwgQw
# 4  9aJ1MVTthZw3QjqoG7mPjg

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"tacos","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': 'ry7XCoXXxS0DxRmzZLFybw',
#    'alias': 'taqueria-gramercy-new-york',
#    'name': 'Taqueria Gramercy',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XayLwDU6hCJKRXwgfGXx1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-gramercy-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 110,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7363, 'longitude': -73.98531},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '218 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['218 3rd Ave', 'New York, NY 10003']},
#    'phone': '+16463706435',
#    'display_phone': '(646) 370-6435',
#    'distance': 3512.2874354237915},
#   {'id': 'NOh24SMS6k4pzNv8Ds7KDg',
#    'alias': 'cafe-habana-new-york-4',
#    'name': 'Cafe Habana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cUHxmLdN0XyZi6AgvaMb3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-habana-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3187,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722998, 'longitude': -73.994171},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '17 Prince St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 Prince St', 'New York, NY 10012']},
#    'phone': '+12126252001',
#    'display_phone': '(212) 625-2001',
#    'distance': 1951.844634788307},
#   {'id': 'P5gcdU1DX9M1V4W-V9o-wg',
#    'alias': 'the-bear-brooklyn',
#    'name': 'The Bear',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lzsPmaKuFnF4frbM8wM7BA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bear-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7128339, 'longitude': -73.9663587},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '48 S 4th St',
#     'address2': '',
#     'address3': 'The Woods bar',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['48 S 4th St', 'The Woods bar', 'Brooklyn, NY 11211']},
#    'phone': '+17183888789',
#    'display_phone': '(718) 388-8789',
#    'distance': 2493.8078026862245},
#   {'id': 'hMWo5pJqSYTcc9dNmR1QMg',
#    'alias': 'tacoway-beach-rockaway-beach',
#    'name': 'Tacoway Beach',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dzL6waP8iu0_aY3ghPn4fQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacoway-beach-rockaway-beach?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 283,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.58886, 'longitude': -73.812093},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '302 Beach 87th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Rockaway Beach',
#     'zip_code': '11693',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['302 Beach 87th St', 'Rockaway Beach, NY 11693']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 20096.050270891003},
#   {'id': '5f08TByddjzk6ThRGRSHkw',
#    'alias': 'palomas-bk-brooklyn',
#    'name': 'Palomas BK',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bSKxIhqyESoq4xgX44QXhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/palomas-bk-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.707726225279785,
#     'longitude': -73.93172809990169},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1 Knickerbocker Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17185763022',
#    'display_phone': '(718) 576-3022',
#    'distance': 5279.852442184058},
#   {'id': 'ONUgIihg-ROELPgKiWfs7A',
#    'alias': 'bushwick-taco-company-brooklyn-3',
#    'name': 'Bushwick Taco Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YkcLF8KeyHMe3LYGs0dOaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bushwick-taco-company-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 206,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.692052, 'longitude': -73.906106},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '839 Knickerbocker Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11207',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['839 Knickerbocker Ave', 'Brooklyn, NY 11207']},
#    'phone': '+17186765305',
#    'display_phone': '(718) 676-5305',
#    'distance': 7582.063423910134},
#   {'id': 'SXWnyFNLCehVlJPRxk7gAg',
#    'alias': 'anejo-tribeca-new-york-3',
#    'name': 'Anejo Tribeca',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_fuWOS5dG8GL2oyWkn1L5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anejo-tribeca-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 536,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7193829, 'longitude': -74.004417},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '301 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['301 Church St', 'New York, NY 10013']},
#    'phone': '+12129206270',
#    'display_phone': '(212) 920-6270',
#    'distance': 1769.2048160174595},
#   {'id': 'Q10FeFs1mtNchv1NbNcsLg',
#    'alias': 'oaxaca-taqueria-new-york-6',
#    'name': 'Oaxaca Taqueria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wTCcUKGxHzYWR7C1c5cv_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oaxaca-taqueria-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 135,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7453117370605,
#     'longitude': -73.9795227050781},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '152 E 33rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['152 E 33rd St', 'New York, NY 10016']},
#    'phone': '+12126844404',
#    'display_phone': '(212) 684-4404',
#    'distance': 4604.721466059278},
#   {'id': 'LdbANxQjzdvzBqUESYTUnw',
#    'alias': 'los-tacos-no-1-new-york-7',
#    'name': 'Los Tacos No. 1',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_vAw6VvHf2cifT3_T6quRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-tacos-no-1-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.751566, 'longitude': -73.977476},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '125 Park Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['125 Park Ave', 'New York, NY 10017']},
#    'phone': '+16469701955',
#    'display_phone': '(646) 970-1955',
#    'distance': 5338.439900512934},
#   {'id': 'jfNc9_Of6ojLl4DVG9QKCw',
#    'alias': 'san-pedro-inn-brooklyn-2',
#    'name': 'San Pedro Inn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NxxTpmdc_vH2YwRZGcQiJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/san-pedro-inn-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67908, 'longitude': -74.01106},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '320 Van Brunt St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['320 Van Brunt St', 'Brooklyn, NY 11231']},
#    'phone': '+17185763916',
#    'display_phone': '(718) 576-3916',
#    'distance': 3253.506032554299},
#   {'id': 'l0ZOGV9tohkpfHiZ-3XSRg',
#    'alias': 'friducha-brooklyn',
#    'name': 'Friducha',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/t9WRQF4ujpZKYxr-l7cTww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/friducha-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 103,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73152, 'longitude': -73.95432},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '946 Manhattan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['946 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183830026',
#    'display_phone': '(718) 383-0026',
#    'distance': 4453.762047935486},
#   {'id': 'DY2wlHlgC5eHITs-d5rT4w',
#    'alias': 'panchos-new-york-2',
#    'name': 'Panchos',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vwfG2x08lpXbqe3sybnT-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/panchos-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 65,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.8015, 'longitude': -73.96534},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '964 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['964 Amsterdam Ave', 'New York, NY 10025']},
#    'phone': '+12123165400',
#    'display_phone': '(212) 316-5400',
#    'distance': 10954.185858259876},
#   {'id': '-SYHh9DWvYuBZxkA4gfzHg',
#    'alias': 'calabrijes-margaritas-and-tacos-brooklyn',
#    'name': "Calabrije's Margaritas & Tacos",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wQF-rw-lfJ1rKVhJxXhbSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/calabrijes-margaritas-and-tacos-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 136,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7055429619569,
#     'longitude': -73.9225539192783},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '234 Starr St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['234 Starr St', 'Brooklyn, NY 11237']},
#    'phone': '+17184842110',
#    'display_phone': '(718) 484-2110',
#    'distance': 6047.176236994416},
#   {'id': 'U6l20gH8YuOJMO8vF6_Ufw',
#    'alias': 'jajaja-plantas-mexicana-new-york-4',
#    'name': 'Jajaja Plantas Mexicana',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gBVO_Q1qld25zcCQU91vig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jajaja-plantas-mexicana-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75264793272132,
#     'longitude': -73.99981519174997},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '450 W 33rd St',
#     'address2': None,
#     'address3': 'Whole Foods',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['450 W 33rd St', 'Whole Foods', 'New York, NY 10001']},
#    'phone': '+16465401104',
#    'display_phone': '(646) 540-1104',
#    'distance': 5269.320201720425},
#   {'id': '9MWmRzKbw6-OR8O1fYa2fw',
#    'alias': 'tacos-el-bronco-brooklyn-7',
#    'name': 'Tacos El Bronco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3l_xN5soFjrSzJjlY9XqWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-el-bronco-brooklyn-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 176,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.65237, 'longitude': -74.00274},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '37th St & 5th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11232',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37th St & 5th Ave', 'Brooklyn, NY 11232']},
#    'phone': '+19174055759',
#    'display_phone': '(917) 405-5759',
#    'distance': 5941.752746606829},
#   {'id': 'iK2jJQA72XRjf4nUD3cAnA',
#    'alias': 'tortilleria-mexicana-los-hermanos-brooklyn-2',
#    'name': 'Tortilleria Mexicana Los Hermanos',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LpI9QEXiNbD3wAxPuHoVJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tortilleria-mexicana-los-hermanos-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 721,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7066299, 'longitude': -73.92198},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '271 Starr St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['271 Starr St', 'Brooklyn, NY 11237']},
#    'phone': '+17184563422',
#    'display_phone': '(718) 456-3422',
#    'distance': 6103.0701535331},
#   {'id': 'PqqnNrUtU7XTKQvUM4cyqQ',
#    'alias': 'bar-verde-new-york',
#    'name': 'Bar Verde',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XDbt28GMM-L2wQmxY9cG6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-verde-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 332,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7260849061034,
#     'longitude': -73.9897361397743},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '65 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['65 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12127776965',
#    'display_phone': '(212) 777-6965',
#    'distance': 2326.9802691069017},
#   {'id': 'ifGXrRqs-zp6ek7LsoozrQ',
#    'alias': 'taqueria-diana-new-york',
#    'name': 'Taqueria Diana',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/z9h_3wBGKWbLsT4E4PaMVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-diana-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 744,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7284337609976,
#     'longitude': -73.9879844318771},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '129 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['129 2nd Ave', 'New York, NY 10003']},
#    'phone': '+16464227871',
#    'display_phone': '(646) 422-7871',
#    'distance': 2610.9569686957734},
#   {'id': 'zwWksgd8M4-g7RBmVudYTg',
#    'alias': 'aldama-brooklyn',
#    'name': 'Aldama',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TBbK3Xu_M8JqVbfjvQOJEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aldama-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.710999707909046,
#     'longitude': -73.96489653736353},
#    'transactions': [],
#    'location': {'address1': '91 S 6th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['91 S 6th St', 'Brooklyn, NY 11249']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2553.6764650144546},
#   {'id': 'IBY_PUKMfcbHAtO8BTqigg',
#    'alias': 'moho-mexican-grill-bayside',
#    'name': 'Moho Mexican Grill',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-kfh6nmQa2x_yw4rGo_-ww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moho-mexican-grill-bayside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 142,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.766353, 'longitude': -73.772158},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '38-05 Bell Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38-05 Bell Blvd', 'Bayside, NY 11361']},
#    'phone': '+17187099695',
#    'display_phone': '(718) 709-9695',
#    'distance': 19901.50424338688},
#   {'id': '9A2cDPA78es4Ecjd6VFZcA',
#    'alias': 'nenes-deli-taqueria-brooklyn',
#    'name': "Nene's Deli Taqueria",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/R8EDpkpyT9INGgFIl12V4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nenes-deli-taqueria-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 75,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70018, 'longitude': -73.92781},
#    'transactions': ['delivery'],
#    'location': {'address1': '14 Starr St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 Starr St', 'Brooklyn, NY 11237']},
#    'phone': '+13474136684',
#    'display_phone': '(347) 413-6684',
#    'distance': 5634.83148599527},
#   {'id': 'nrwOQSXoRXfAYhkdjiUk8g',
#    'alias': 'toro-loco-new-york',
#    'name': 'Toro Loco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uBhe_gNq53jqkdtPmBM_Lw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/toro-loco-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 333,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70421, 'longitude': -74.01208},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '15 Stone St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Stone St', 'New York, NY 10004']},
#    'phone': '+19172620444',
#    'display_phone': '(917) 262-0444',
#    'distance': 1509.416353803401},
#   {'id': 'f7g3GhoQs9nQVTJEL2p48Q',
#    'alias': 'gran-electrica-brooklyn-3',
#    'name': 'Gran Electrica',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vltMa2sCZfwlSMNxMtFd4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gran-electrica-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 504,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7027, 'longitude': -73.99314},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '5 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17188522700',
#    'display_phone': '(718) 852-2700',
#    'distance': 321.6955097734123},
#   {'id': '2u8T56A4qu-MjeuT-v7s_g',
#    'alias': 'casa-bocado-new-york',
#    'name': 'Casa Bocado',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uJUNdYuKR3A2DVUGnn21dg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-bocado-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 87,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71958, 'longitude': -73.99484},
#    'transactions': ['delivery'],
#    'location': {'address1': '341 Broome St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['341 Broome St', 'New York, NY 10013']},
#    'phone': '+12122047502',
#    'display_phone': '(212) 204-7502',
#    'distance': 1543.1791629526126},
#   {'id': 'FeSZi6LBCcAIipoSua6dXg',
#    'alias': 'la-esquina-ues-new-york-3',
#    'name': 'La Esquina - UES',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2xO53hmHQzYr1oTY58ZDEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-esquina-ues-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 178,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7693131667402,
#     'longitude': -73.9577519273524},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1402 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1402 2nd Ave', 'New York, NY 10021']},
#    'phone': '+16466137100',
#    'display_phone': '(646) 613-7100',
#    'distance': 7740.440972013736},
#   {'id': 'DQuwci5xgJxXx7dxxp9FBA',
#    'alias': 'taqueria-st-marks-place-new-york',
#    'name': 'Taqueria St. Marks Place',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Z52Y0_XukoBmq1aoFvG4_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-st-marks-place-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 434,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72788723475379,
#     'longitude': -73.98557625767012},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '79 St Marks Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79 St Marks Pl', 'New York, NY 10003']},
#    'phone': '+16469645614',
#    'display_phone': '(646) 964-5614',
#    'distance': 2601.369157838829},
#   {'id': 'Xak3sB5LkJgjgYYf6_hQLA',
#    'alias': 'casa-taqueria-new-york-3',
#    'name': 'Casa Taqueria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FGJ_ifyuSJMc8wl3Phywvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-taqueria-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 74,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70875, 'longitude': -74.00583},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '40 Gold St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40 Gold St', 'New York, NY 10038']},
#    'phone': '+12124063333',
#    'display_phone': '(212) 406-3333',
#    'distance': 1032.5883192937333},
#   {'id': 'G92jSUckfs4MhD6bGPyHow',
#    'alias': 'taqueria-diana-brooklyn',
#    'name': 'Taqueria Diana',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Bb3-WL4dFV8r0wT2KftSIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-diana-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 82,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7142179690191, 'longitude': -73.9556609},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '367 Metropolitan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['367 Metropolitan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+19292502460',
#    'display_phone': '(929) 250-2460',
#    'distance': 3399.2332416334175},
#   {'id': 'mhrLDFTxUzW2koRAzjlt5g',
#    'alias': 'chavelas-brooklyn-2',
#    'name': "Chavela's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/55OytxTOhtMW-mGEcA6wjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chavelas-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1156,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.673484, 'longitude': -73.957267},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '736 Franklin Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['736 Franklin Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17186223100',
#    'display_phone': '(718) 622-3100',
#    'distance': 4730.422567366242},
#   {'id': 'boRM4i0UQswxQIp6CA9y_A',
#    'alias': 'la-esquina-soho-new-york',
#    'name': 'La Esquina - SoHo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OKbbMhOq8jd2kF0mtPKuwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-esquina-soho-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2062,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.721372, 'longitude': -73.997529},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '114 Kenmare St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['114 Kenmare St', 'New York, NY 10012']},
#    'phone': '+16466137100',
#    'display_phone': '(646) 613-7100',
#    'distance': 1791.8904533131627},
#   {'id': 'ci0-GO_iMb0NdTCUYWjocQ',
#    'alias': 'noche-de-margaritas-new-york',
#    'name': 'Noche De Margaritas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/102pyt27Z8aE8EjpnOqsqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noche-de-margaritas-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 375,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7801018, 'longitude': -73.9497833},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1726 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1726 2nd Ave', 'New York, NY 10128']},
#    'phone': '+12122895195',
#    'display_phone': '(212) 289-5195',
#    'distance': 9112.579310933183},
#   {'id': 'h_ITJux-MF0YcmZx8KRHtA',
#    'alias': 'taco-edition-brooklyn-4',
#    'name': 'Taco Edition',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/infk1FAM4fL3O0IXNZrMAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-edition-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 95,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.711641, 'longitude': -73.941319},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '800 Grand St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['800 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17184866222',
#    'display_phone': '(718) 486-6222',
#    'distance': 4518.101127800442},
#   {'id': '_ay580EYYsobmsQn185hhg',
#    'alias': 'brujos-brooklyn-taco-brooklyn',
#    'name': 'Brujos - Brooklyn Taco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gd4CvmUhYFLcgX-lNTKrBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brujos-brooklyn-taco-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7143008, 'longitude': -73.944522},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '333 Graham Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['333 Graham Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17183888445',
#    'display_phone': '(718) 388-8445',
#    'distance': 4309.1462692869145},
#   {'id': '4c4Uwb5yUqXJ-inkcDinIg',
#    'alias': 'mcondo-tacos-brooklyn',
#    'name': 'Mcondo Tacos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BsQmP064YcX4fm9zQnCKyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mcondo-tacos-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 335,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7108323440285,
#     'longitude': -73.9509542539666},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '502 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['502 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+19176991090',
#    'display_phone': '(917) 699-1090',
#    'distance': 3701.847377267165},
#   {'id': 'FXgSgiLg6xgOO8zrG51mzg',
#    'alias': 'claro-brooklyn',
#    'name': 'Claro',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2_n3ndzp6cJ367V_VI-qmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/claro-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 241,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'newmexican', 'title': 'New Mexican Cuisine'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6773587963142,
#     'longitude': -73.9861984489446},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '284 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['284 3rd Ave', 'Brooklyn, NY 11215']},
#    'phone': '+13477213126',
#    'display_phone': '(347) 721-3126',
#    'distance': 3196.727237508255},
#   {'id': '5AsVCBQoJeTomvaw-_IaUQ',
#    'alias': 'la-taqueria-new-york',
#    'name': 'La Taqueria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ta36MTXiUaXY3JCAU9gSgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-taqueria-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7112690867, 'longitude': -73.9489733333},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '572 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['572 Grand St', 'New York, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3874.521852081565},
#   {'id': 'v4_89HfTm05NFTuukjsl_g',
#    'alias': 'the-burrito-box-new-york',
#    'name': 'The Burrito Box',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rtaSt7G_ER5nzlutfwfNVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-burrito-box-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 903,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76831, 'longitude': -73.98565},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '885 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['885 9th Ave', 'New York, NY 10019']},
#    'phone': '+12124896889',
#    'display_phone': '(212) 489-6889',
#    'distance': 7020.568185863763},
#   {'id': 'Jd2_ZC4ugEMSY9ElivNZgg',
#    'alias': 'summer-salt-new-york-3',
#    'name': 'Summer Salt',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ms1qsfHRq0vp65aYung_Gg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/summer-salt-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 132,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'newmexican', 'title': 'New Mexican Cuisine'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74057, 'longitude': -73.98768},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '30 East 23rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30 East 23rd St', 'New York, NY 10010']},
#    'phone': '+12122090648',
#    'display_phone': '(212) 209-0648',
#    'distance': 3942.246985121424},
#   {'id': 'jf95dOTlZB7oPWz9JLgaQA',
#    'alias': 'borrachito-new-york',
#    'name': 'Borrachito',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FD-QrZtEOfYf74LGqBfTxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/borrachito-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7294609, 'longitude': -73.980749},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '206 Avenue A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['206 Avenue A', 'New York, NY 10009']},
#    'phone': '+16469924743',
#    'display_phone': '(646) 992-4743',
#    'distance': 2904.193196523671},
#   {'id': '_5G0SOM1ogWTsSmPBGRfzA',
#    'alias': 'el-gallo-taqueria-brooklyn-2',
#    'name': 'El Gallo Taqueria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fUHOE0eFxYuOT86fJn7vMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-gallo-taqueria-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 308,
#    'categories': [{'alias': 'tex-mex', 'title': 'Tex-Mex'},
#     {'alias': 'newmexican', 'title': 'New Mexican Cuisine'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6035151454871,
#     'longitude': -73.9779098353486},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '214 Highlawn Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11223',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['214 Highlawn Ave', 'Brooklyn, NY 11223']},
#    'phone': '+19176682332',
#    'display_phone': '(917) 668-2332',
#    'distance': 11418.008802871578},
#   {'id': 'PHMkwS5nmo4IUXbcg0OcAg',
#    'alias': 'jajaja-plantas-mexicana-new-york',
#    'name': 'Jajaja Plantas Mexicana',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uWbBN6yZcR5TMFY0W0RmYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jajaja-plantas-mexicana-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 394,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72979, 'longitude': -74.00455},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '63 Carmine St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63 Carmine St', 'New York, NY 10014']},
#    'phone': '+19172620184',
#    'display_phone': '(917) 262-0184',
#    'distance': 2853.141959001067},
#   {'id': 'aTBxCoZDOnqAXPDdQmrxMg',
#    'alias': 'taqueria-mexico-2000-brooklyn',
#    'name': 'Taqueria Mexico 2000',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rO86DNWxkRtkMCfF_hy9BA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-mexico-2000-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71509, 'longitude': -73.96246},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '131 Grand St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['131 Grand St', 'Brooklyn, NY 11249']},
#    'phone': '+17183959985',
#    'display_phone': '(718) 395-9985',
#    'distance': 2890.968286076366},
#   {'id': 'iUsk8CPoDyoBmwVdU1_9QQ',
#    'alias': 'sidewalk-tacos-new-york-3',
#    'name': 'Sidewalk Tacos',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XhWA1uYb4zRPw9NqtOo2DQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sidewalk-tacos-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7284088, 'longitude': -73.9996719},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': 'Bleecker & Thompson',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Bleecker & Thompson', 'New York, NY 10012']},
#    'phone': '+16464549255',
#    'display_phone': '(646) 454-9255',
#    'distance': 2593.345076061584},
#   {'id': 'hOLv0a65RSb5QvFd0FrYjw',
#    'alias': 'taqueria-santa-fe-brooklyn',
#    'name': 'Taqueria Santa Fe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZTBsdz8HzdMAH-tdOzw9CQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-santa-fe-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 123,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.700351, 'longitude': -73.920546},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '214 Stanhope St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['214 Stanhope St', 'Brooklyn, NY 11237']},
#    'phone': '+17184555012',
#    'display_phone': '(718) 455-5012',
#    'distance': 6243.395344425543},
#   {'id': '-kVueEw_fyO1Q2Gkmj6Few',
#    'alias': 'taqueria-santa-fe-woodside-2',
#    'name': 'Taqueria Santa Fe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HSeOqcDKWMekhMeLYxrqLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-santa-fe-woodside-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 390,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.740766, 'longitude': -73.917876},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '4708 47th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4708 47th Ave', 'Woodside, NY 11377']},
#    'phone': '+17182699946',
#    'display_phone': '(718) 269-9946',
#    'distance': 7551.2519937263405},
#   {'id': 'zjnnccSIpMdx5fN-MxAr_w',
#    'alias': 'la-superior-brooklyn',
#    'name': 'La Superior',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Mobng3v0athIkAynLfym0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-superior-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 607,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71357, 'longitude': -73.96363},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '295 Berry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['295 Berry St', 'Brooklyn, NY 11211']},
#    'phone': '+17183885988',
#    'display_phone': '(718) 388-5988',
#    'distance': 2740.5807593049267},
#   {'id': 'mmAlHhnTDXIohPC3wfl0hQ',
#    'alias': 'mesa-coyoacan-brooklyn',
#    'name': 'Mesa Coyoacan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fcuNrnpyyRSAUcvSmXgj1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mesa-coyoacan-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 791,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.715528, 'longitude': -73.944273},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '372 Graham Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['372 Graham Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17187828171',
#    'display_phone': '(718) 782-8171',
#    'distance': 4359.095637089325},
#   {'id': 'B6bEkY9sJ_GU2pD2Rwb4gg',
#    'alias': 'el-mitote-new-york',
#    'name': 'El Mitote',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/H9pTuL8VUFz4CZXJ1HXNfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-mitote-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 541,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.77578, 'longitude': -73.98021},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '208 Columbus Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['208 Columbus Ave', 'New York, NY 10023']},
#    'phone': '+12128742929',
#    'display_phone': '(212) 874-2929',
#    'distance': 7917.892101138702},
#   {'id': 'zxdsVR_hHUzhBFfus4yd7A',
#    'alias': 'dos-caminos-new-york-3',
#    'name': 'Dos Caminos',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OjqowmWExanMFsEQPVws9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dos-caminos-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1078,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7404330511257,
#     'longitude': -74.0054753422738},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '675 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['675 Hudson St', 'New York, NY 10014']},
#    'phone': '+12126992400',
#    'display_phone': '(212) 699-2400',
#    'distance': 4003.00158127486},
#   {'id': 'J9pgjC191T-odCmTAG-grQ',
#    'alias': 'el-diablito-taqueria-new-york',
#    'name': 'El Diablito Taqueria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7_gDrHrX5xNYaoLrZjq-GQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-diablito-taqueria-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 399,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72504, 'longitude': -73.98917},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '60 E 3rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 E 3rd St', 'New York, NY 10003']},
#    'phone': '+16466929268',
#    'display_phone': '(646) 692-9268',
#    'distance': 2223.517805265928}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#           Restaurant       Type Price Rating              Address        Lat  \
# 0  Taqueria Gramercy       Bars                       218 3rd Ave  40.736300
# 1        Cafe Habana      Cuban    $$      4         17 Prince St  40.722998
# 2           The Bear  Fast Food    $$    4.5          48 S 4th St  40.712834
# 3      Tacoway Beach    Mexican    $$      4    302 Beach 87th St  40.588860
# 4         Palomas BK    Mexican               1 Knickerbocker Ave  40.707726
#
#          Lng                                                url  \
# 0 -73.985310
# 1 -73.994171  https://www.yelp.com/biz/cafe-habana-new-york-...
# 2 -73.966359  https://www.yelp.com/biz/the-bear-brooklyn?adj...
# 3 -73.812093  https://www.yelp.com/biz/tacoway-beach-rockawa...
# 4 -73.931728
#
#                        ID
# 0
# 1  NOh24SMS6k4pzNv8Ds7KDg
# 2  P5gcdU1DX9M1V4W-V9o-wg
# 3  hMWo5pJqSYTcc9dNmR1QMg
# 4

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"tacos","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': 'hSkeb_lmfxnoqg7EVo19Vw',
#    'alias': 'taco-mix-new-york',
#    'name': 'Taco Mix',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/E3q1Qln8vVY1syfM13QKxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-mix-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 418,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.797098, 'longitude': -73.938785},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '234 E 116th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['234 E 116th St', 'New York, NY 10029']},
#    'phone': '+12122892963',
#    'display_phone': '(212) 289-2963',
#    'distance': 11212.78249479794},
#   {'id': 'pcQ9ld7xuX9EXTCAoakkbQ',
#    'alias': 'tacombi-financial-district-new-york-4',
#    'name': 'Tacombi - Financial District',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/64cuWeHIgsr5C8Fwf1Vntw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacombi-financial-district-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.704647, 'longitude': -74.011824},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '74 Broad St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['74 Broad St', 'New York, NY 10004']},
#    'phone': '+19172617136',
#    'display_phone': '(917) 261-7136',
#    'distance': 1484.0899667778401},
#   {'id': 'ND2PgVHYAF4IdaV6Zse5hQ',
#    'alias': 'taqueria-al-pastor-brooklyn-2',
#    'name': 'Taqueria al Pastor',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sGDs19U-EYlFxSVQvJE7vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-al-pastor-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 115,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.703326, 'longitude': -73.918029},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '128 Wyckoff Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['128 Wyckoff Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17182697538',
#    'display_phone': '(718) 269-7538',
#    'distance': 6433.011253825096},
#   {'id': '6VRIJ7fHe35-baWzkgZCUg',
#    'alias': 'tarachi-brooklyn',
#    'name': 'Tarachi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZKfbMy8a2L21Peovns7WFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tarachi-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68697, 'longitude': -73.962191},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '222 Greene Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['222 Greene Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17185763612',
#    'display_phone': '(718) 576-3612',
#    'distance': 3397.9681690477305},
#   {'id': '_URXTaYBbd2XX5qJbDkKAg',
#    'alias': 'taco-morelos-brooklyn',
#    'name': 'Taco Morelos',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XyX-FWMW_at2mRkIuRc6tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-morelos-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 100,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.717799, 'longitude': -73.957446},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '183 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['183 Bedford Ave', 'Brooklyn, NY 11211']},
#    'phone': '+16464049080',
#    'display_phone': '(646) 404-9080',
#    'distance': 3393.6786682136535},
#   {'id': 'DjtjAuN5jWd_ukx0YWUFWw',
#    'alias': 'oaxaca-taqueria-brooklyn-3',
#    'name': 'Oaxaca Taqueria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L8m2aDwp58IkKksc4beOGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oaxaca-taqueria-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 92,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.688233, 'longitude': -73.986593},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '75 Hoyt St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 Hoyt St', 'Brooklyn, NY 11201']},
#    'phone': '+19292029337',
#    'display_phone': '(929) 202-9337',
#    'distance': 2020.9678323151713},
#   {'id': 'FhPAf4w6t0KsujSQBHH_-w',
#    'alias': 'taqueria-casa-imelda-brooklyn',
#    'name': 'Taqueria Casa Imelda',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ItfZM16UDaSfJv6U2q__SQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-casa-imelda-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.712405, 'longitude': -73.964871},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '82 S 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['82 S 4th St', 'Brooklyn, NY 11249']},
#    'phone': '+13474575992',
#    'display_phone': '(347) 457-5992',
#    'distance': 2601.0839586156276},
#   {'id': '1ux5rxwWjKxoXHUyGynwSg',
#    'alias': 'purepecha-brooklyn',
#    'name': 'Purepecha',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KEYXMBXLF0rlYncOt2MPPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/purepecha-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 65,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68453, 'longitude': -73.99182},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '213 Smith St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['213 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+13479161227',
#    'display_phone': '(347) 916-1227',
#    'distance': 2334.7135685384546},
#   {'id': 'a3xDhQkSIH451c_sEmtidQ',
#    'alias': 'oro-verde-taqueria-new-york',
#    'name': 'Oro Verde Taqueria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/THaVp5PgjRSaxbd5anfziA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oro-verde-taqueria-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74182, 'longitude': -74.00078},
#    'transactions': ['delivery'],
#    'location': {'address1': '150 8th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 8th Ave', 'New York, NY 10011']},
#    'phone': '+12126752888',
#    'display_phone': '(212) 675-2888',
#    'distance': 4079.8995176720473},
#   {'id': '8WnHtvMdPWE66eSkUdbLhQ',
#    'alias': 'flip-sigi-new-york-2',
#    'name': 'Flip Sigi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Or5e12QrL0SkMfKNFiSp4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flip-sigi-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 831,
#    'categories': [{'alias': 'filipino', 'title': 'Filipino'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7344965, 'longitude': -74.0020674},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '131 7th Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['131 7th Ave S', 'New York, NY 10014']},
#    'phone': '+18333547744',
#    'display_phone': '(833) 354-7744',
#    'distance': 3296.160771524839},
#   {'id': 'fJXCMGOhaS6rKGjoGldSSQ',
#    'alias': 'taqueria-tepango-brooklyn',
#    'name': 'Taqueria Tepango',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/83UDiPvmsZRg3aOewc3M4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-tepango-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 224,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6937857, 'longitude': -73.9616331},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '568 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['568 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17186368878',
#    'display_phone': '(718) 636-8878',
#    'distance': 3031.8962029314607},
#   {'id': '0Y8dv9UHGquFkWlVK7PdjA',
#    'alias': 'buddys-burrito-and-taco-bar-brooklyn',
#    'name': "Buddy's Burrito & Taco Bar",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Z7LvvD7YD2qG49rtJV904A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/buddys-burrito-and-taco-bar-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 185,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.685223, 'longitude': -73.994696},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '260 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['260 Court St', 'Brooklyn, NY 11231']},
#    'phone': '+17184888695',
#    'display_phone': '(718) 488-8695',
#    'distance': 2248.8226367488714},
#   {'id': 'AnAZaBsEuBjYvzaPMTN0oQ',
#    'alias': 'flats-fix-taqueria-new-york-3',
#    'name': 'Flats Fix Taqueria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KIkJVnFCBagU2oAxXQPt1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flats-fix-taqueria-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 213,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7365039, 'longitude': -73.9910582},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '28 E 16th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 E 16th St', 'New York, NY 10003']},
#    'phone': '+19174350515',
#    'display_phone': '(917) 435-0515',
#    'distance': 3475.372519946562},
#   {'id': '2zLgKnIQDmrJDb99jl9qRA',
#    'alias': 'tacos-güey-new-york-2',
#    'name': 'Tacos Güey',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9rK__1R-6kQopaISW3xVBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-g%C3%BCey-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73997, 'longitude': -73.99323},
#    'transactions': ['delivery'],
#    'location': {'address1': '37 W 19th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37 W 19th St', 'New York, NY 10011']},
#    'phone': '+12129918222',
#    'display_phone': '(212) 991-8222',
#    'distance': 3848.666405928496},
#   {'id': 'vyKBwzRdNX4yiJDIFv37iw',
#    'alias': 'oxomoco-brooklyn-2',
#    'name': 'Oxomoco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rZCgQsW2cOTMJDdAKIsryQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oxomoco-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 389,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7299099, 'longitude': -73.95548},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '128 Greenpoint Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['128 Greenpoint Ave', 'Brooklyn, NY 11222']},
#    'phone': '+16466884180',
#    'display_phone': '(646) 688-4180',
#    'distance': 4247.863857495379},
#   {'id': '_csLDQow8YzjZJNEeZUMUw',
#    'alias': 'planet-taco-new-york',
#    'name': 'Planet Taco',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3SuwYan26HUIVLEwWG8WOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/planet-taco-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72914, 'longitude': -73.98749},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '141 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['141 2nd Ave', 'New York, NY 10003']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2690.5866064306283},
#   {'id': 'LSMfKvER1s42GV_BV4nELA',
#    'alias': 'pico-taco-hoboken-2',
#    'name': 'Pico Taco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5DKZe7f78qcuNltk8Iby9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pico-taco-hoboken-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 91,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73618, 'longitude': -74.03045},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '70 Hudson St',
#     'address2': None,
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['70 Hudson St', 'Hoboken, NJ 07030']},
#    'phone': '+12016835847',
#    'display_phone': '(201) 683-5847',
#    'distance': 4575.0866462993135},
#   {'id': 'XDl93co2VJznxglYcoQvmA',
#    'alias': 'chilos-brooklyn',
#    'name': "Chilo's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/obZ4SarBrm_O-0DLLV8Tlg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chilos-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 226,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68835, 'longitude': -73.95696},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '323 Franklin Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['323 Franklin Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17186765245',
#    'display_phone': '(718) 676-5245',
#    'distance': 3676.35108314971},
#   {'id': 'TPN2at7fMDHxeGYuQdQZVA',
#    'alias': 'homemade-taqueria-maspeth',
#    'name': 'Homemade Taqueria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YUpeNPwLGgrbGT35QgcAIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/homemade-taqueria-maspeth?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 304,
#    'categories': [{'alias': 'newmexican', 'title': 'New Mexican Cuisine'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7279733, 'longitude': -73.89216},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '7103 Grand Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Maspeth',
#     'zip_code': '11378',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7103 Grand Ave', 'Maspeth, NY 11378']},
#    'phone': '+17187790771',
#    'display_phone': '(718) 779-0771',
#    'distance': 8963.13346946856},
#   {'id': 'tvqtAjAyc7dplVVwhw3VZQ',
#    'alias': 'la-contenta-oeste-new-york',
#    'name': 'La Contenta Oeste',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/REnuRJEbMXWlGRRFv6KPfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-contenta-oeste-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 263,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7352, 'longitude': -73.99808},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '78 W 11th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['78 W 11th St', 'New York, NY 10011']},
#    'phone': '+12125332233',
#    'display_phone': '(212) 533-2233',
#    'distance': 3317.9994194379715},
#   {'id': 'AhRzrLCNagCX87EK-VBVog',
#    'alias': 'summer-salt-new-york-5',
#    'name': 'Summer Salt',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Q9oQKVFwp68eRbLAIJXc1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/summer-salt-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7511757, 'longitude': -73.9799914622357},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '275 Madison Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['275 Madison Ave', 'New York, NY 10016']},
#    'phone': '+12127633362',
#    'display_phone': '(212) 763-3362',
#    'distance': 5225.886497902381},
#   {'id': 'xWLSJOiN1mMRHmBmHyjAfw',
#    'alias': 'mad-dog-and-beans-mexican-cantina-new-york',
#    'name': 'Mad Dog & Beans Mexican Cantina',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AMzBKS4NQ8YawAA8tzaUaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mad-dog-and-beans-mexican-cantina-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 531,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75098, 'longitude': -73.98181},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '5 E 38th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 E 38th St', 'New York, NY 10016']},
#    'phone': '+16469985722',
#    'display_phone': '(646) 998-5722',
#    'distance': 5161.86838424718},
#   {'id': 'vj-kTW34lV2ePesZRUUy0Q',
#    'alias': 'taqueria-mariposa-rosa-new-york',
#    'name': 'Taqueria Mariposa Rosa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FihxHvlDbg5SFF4hQKtJMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-mariposa-rosa-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.733207, 'longitude': -74.0035415},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '55 Grove St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Grove St', 'New York, NY 10014']},
#    'phone': '+19173593254',
#    'display_phone': '(917) 359-3254',
#    'distance': 3183.8782760154136},
#   {'id': 'dgaNriM1VdI2nGochhHE_g',
#    'alias': 'casa-enrique-long-island-city',
#    'name': 'Casa Enrique',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/20ejWnqtIIXa0Sys3X-BYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-enrique-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1302,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.743404338358, 'longitude': -73.954350367693},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '5-48 49th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5-48 49th Ave', 'Long Island City, NY 11101']},
#    'phone': '+13474486040',
#    'display_phone': '(347) 448-6040',
#    'distance': 5398.677888836931},
#   {'id': '7CfaiHE11MO2zAiu3w6bsw',
#    'alias': 'taco-dumbo-new-york-3',
#    'name': 'Taco Dumbo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/39TeoKJVhwOt95d_RTWJjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-dumbo-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 315,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.760941, 'longitude': -73.978049},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '31 W 52nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31 W 52nd St', 'New York, NY 10019']},
#    'phone': '+16463604001',
#    'display_phone': '(646) 360-4001',
#    'distance': 6318.052274391553},
#   {'id': 'V9jFJfuK3FzWCJGoY15EgQ',
#    'alias': 'blue-maiz-new-york',
#    'name': 'Blue Maiz',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JFKR1Q_wJw1qG6R6TN-g2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-maiz-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 259,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75543, 'longitude': -73.99071},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '606 8th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['606 8th Ave', 'New York, NY 10018']},
#    'phone': '+12127042106',
#    'display_phone': '(212) 704-2106',
#    'distance': 5568.107607025401},
#   {'id': 'Drh9-6n7lWNOSnlP5vmOXA',
#    'alias': 'xilonen-brooklyn',
#    'name': 'Xilonen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iQwqSDVd2K4FLZUja4xeNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/xilonen-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.723513, 'longitude': -73.951928},
#    'transactions': ['delivery'],
#    'location': {'address1': '905 Lorimer St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['905 Lorimer St', 'Brooklyn, NY 11222']},
#    'phone': '+19292720370',
#    'display_phone': '(929) 272-0370',
#    'distance': 4096.191082241702},
#   {'id': 'G2PCaDt_VC4O4w6uRMpE9A',
#    'alias': 'birria-les-new-york',
#    'name': 'Birria LES',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LVSaauoMHOjyopCMyWbhqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/birria-les-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'halal', 'title': 'Halal'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.719628849397935,
#     'longitude': -73.98711402147562},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '127 Rivington St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['127 Rivington St', 'New York, NY 10002']},
#    'phone': '+16467897777',
#    'display_phone': '(646) 789-7777',
#    'distance': 1689.276549665948},
#   {'id': 'PAJdNrD4HFBN16OAFeDx4A',
#    'alias': 'ponche-taqueria-and-cantina-new-york',
#    'name': 'Ponche Taqueria & Cantina',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Oz9i1TgKPQjjROUDPgQFgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ponche-taqueria-and-cantina-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 525,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76319, 'longitude': -73.99045},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '420 W 49th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['420 W 49th St', 'New York, NY 10019']},
#    'phone': '+12125811235',
#    'display_phone': '(212) 581-1235',
#    'distance': 6423.643781162055},
#   {'id': 'ipmOYDh9snm3ZUv546MACQ',
#    'alias': 'taqueria-milear-crown-heights',
#    'name': 'Taqueria Milear',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RRHNeADWVFrgR1WibhLt2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-milear-crown-heights?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 225,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6729835327648,
#     'longitude': -73.9503121359905},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '752A Nostrand Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Crown Heights',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['752A Nostrand Ave', 'Crown Heights, NY 11216']},
#    'phone': '+17184848005',
#    'display_phone': '(718) 484-8005',
#    'distance': 5174.910172129429},
#   {'id': 'Pikhqmsy370W2BXHnNfP0g',
#    'alias': 'taqueria-el-gallo-azteca-staten-island-2',
#    'name': 'Taqueria El Gallo Azteca',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1lN05B3JR9J6-ADDt6hy8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-el-gallo-azteca-staten-island-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 126,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.63842, 'longitude': -74.07867},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '75 Victory Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10301',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 Victory Blvd', 'Staten Island, NY 10301']},
#    'phone': '+17182736404',
#    'display_phone': '(718) 273-6404',
#    'distance': 10306.37613199125},
#   {'id': '1NL-Uk5v0PYtLNulhO1YRw',
#    'alias': 'el-rinconcito-mix-brooklyn-2',
#    'name': 'El Rinconcito Mix',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YMZzXNzOgP7dB3m9E0nkgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-rinconcito-mix-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'dominican', 'title': 'Dominican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67152, 'longitude': -73.95251},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '774 St Johns Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['774 St Johns Pl', 'Brooklyn, NY 11216']},
#    'phone': '+13474421383',
#    'display_phone': '(347) 442-1383',
#    'distance': 5157.098179854094},
#   {'id': 'sshS0FJ6tKkmLCcEKXyVkA',
#    'alias': 'el-tepeyac-food-market-carniceria-grocery-and-taqueria-new-york-2',
#    'name': 'El Tepeyac Food Market: Carniceria, Grocery & Taqueria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/z_5v_kYu43pCBFQBSSrDZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-tepeyac-food-market-carniceria-grocery-and-taqueria-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'importedfood', 'title': 'Imported Food'},
#     {'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.789743, 'longitude': -73.947903},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1621A Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1621A Lexington Ave', 'New York, NY 10029']},
#    'phone': '+12129878364',
#    'display_phone': '(212) 987-8364',
#    'distance': 10156.235066463374},
#   {'id': 'hE2GaFRKhafpUPAYyNRTCQ',
#    'alias': 'tributo-long-island-city-6',
#    'name': 'Tributo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8FjgeaGAe5mE6OesZYudfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tributo-long-island-city-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7533751, 'longitude': -73.9497771},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '42-25 Vernon Blvd',
#     'address2': 'Unit C',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42-25 Vernon Blvd',
#      'Unit C',
#      'Long Island City, NY 11101']},
#    'phone': '+13479353035',
#    'display_phone': '(347) 935-3035',
#    'distance': 6517.295678670304},
#   {'id': 'AUm7If5Cbvy20AnmyxE-xA',
#    'alias': 'dos-toros-taqueria-new-york-21',
#    'name': 'Dos Toros Taqueria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/haryVZ-pbnXsqqnBrB4kiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dos-toros-taqueria-new-york-21?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7607084122727,
#     'longitude': -73.9784675091505},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '52 W 52nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['52 W 52nd St', 'New York, NY 10019']},
#    'phone': '+13473057765',
#    'display_phone': '(347) 305-7765',
#    'distance': 6288.033132188951},
#   {'id': 'xlv_CcDXH1hkG4Wq5mECkQ',
#    'alias': 'vamos-al-tequila-brooklyn',
#    'name': 'Vamos Al Tequila',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pSxRTco6G-GYovI3d3KC0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vamos-al-tequila-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 305,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73079, 'longitude': -73.95753},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '162 Franklin St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 Franklin St', 'Brooklyn, NY 11222']},
#    'phone': '+17183830808',
#    'display_phone': '(718) 383-0808',
#    'distance': 4191.2842657350875},
#   {'id': 'kJCjKpwcOFA1fal0fuNVRg',
#    'alias': 'tacoria-jersey-city-3',
#    'name': 'Tacoria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/j3cGqF4rBmcNuPHdfvwL7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacoria-jersey-city-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 231,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.721858, 'longitude': -74.044181},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '24-26 Erie st',
#     'address2': '',
#     'address3': None,
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['24-26 Erie st', 'Jersey City, NJ 07302']},
#    'phone': '+12017929041',
#    'display_phone': '(201) 792-9041',
#    'distance': 4583.710092256171},
#   {'id': 'MT8a8H25oeQ6eATdffxWmA',
#    'alias': 'reyes-deli-and-grocery-brooklyn',
#    'name': 'Reyes Deli & Grocery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CmGktd54jfL5DtP94QbILw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/reyes-deli-and-grocery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 221,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.66731, 'longitude': -73.99162},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '532 4th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['532 4th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17183693211',
#    'display_phone': '(718) 369-3211',
#    'distance': 4250.866863265668},
#   {'id': '9_CEU7Wmvmwlyvqr-PJD6w',
#    'alias': 'ofrenda-new-york',
#    'name': 'Ofrenda',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C2PxC5KF6dL5twB2BM42Aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ofrenda-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1011,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73391, 'longitude': -74.00242},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '113 7th Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['113 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12129242305',
#    'display_phone': '(212) 924-2305',
#    'distance': 3239.692567061365},
#   {'id': 'skN-mgnOezFQr9YNh5G5TQ',
#    'alias': 'lolitas-kitchen-new-york',
#    'name': "Lolita's Kitchen",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/D9LOW5MsId59pGuEBqvk3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lolitas-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 109,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7824207446896,
#     'longitude': -73.9534502033954},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1364 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1364 Lexington Ave', 'New York, NY 10128']},
#    'phone': '+12127225055',
#    'display_phone': '(212) 722-5055',
#    'distance': 9225.028293198693},
#   {'id': 'mBFnE5EDUwpZiEsSf_1piA',
#    'alias': 'los-tacos-city-habanero-long-island-city',
#    'name': 'Los Tacos City Habanero',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ABa1WShvWyOImyHtX_SBCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-tacos-city-habanero-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 66,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7440144504923,
#     'longitude': -73.9537688118532},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '48th Ave Vernon Blvd',
#     'address2': None,
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['48th Ave Vernon Blvd', 'Long Island City, NY 11101']},
#    'phone': '+19178033873',
#    'display_phone': '(917) 803-3873',
#    'distance': 5482.265780244753},
#   {'id': '4zBGXDXg9DzK0IROwCUeFg',
#    'alias': 'cowgirl-seahorse-new-york-2',
#    'name': 'Cowgirl Seahorse',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xpMlQYybUIHmJNXvxRQSbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cowgirl-seahorse-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 610,
#    'categories': [{'alias': 'tex-mex', 'title': 'Tex-Mex'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'southern', 'title': 'Southern'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7081358, 'longitude': -74.0004532},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '259 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['259 Front St', 'New York, NY 10038']},
#    'phone': '+12126087873',
#    'display_phone': '(212) 608-7873',
#    'distance': 599.2822281843487},
#   {'id': 'zJmMDGwr6yZ8pjrdC2VciA',
#    'alias': 'tacombi-fort-greene-brooklyn-2',
#    'name': 'Tacombi - Fort Greene',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2H_dDVFxC0uCNEpuB9hOpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacombi-fort-greene-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 199,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.68709, 'longitude': -73.97797},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '25 Lafayette Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 Lafayette Ave', 'Brooklyn, NY 11217']},
#    'phone': '+13472940647',
#    'display_phone': '(347) 294-0647',
#    'distance': 2465.2027671992537},
#   {'id': '9fG8-RRh1rzuCKN2TmF-QQ',
#    'alias': '5ive-spice-new-york-2',
#    'name': '5ive Spice',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GNDdH26bue1yTqVJEawx6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/5ive-spice-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 403,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.722598, 'longitude': -73.996272},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '227 Mulberry St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['227 Mulberry St', 'New York, NY 10012']},
#    'phone': '+19174092605',
#    'display_phone': '(917) 409-2605',
#    'distance': 1912.9622722449587},
#   {'id': 'l-ELX4tgoaNucr33ZvdzbQ',
#    'alias': 'el-santo-taqueria-brooklyn',
#    'name': 'El Santo Taqueria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Vx6ixaZZffD9Ronw99W9UA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-santo-taqueria-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 61,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70427, 'longitude': -73.9302},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1053 Flushing Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1053 Flushing Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17183663138',
#    'display_phone': '(718) 366-3138',
#    'distance': 5398.2539374976295},
#   {'id': 'Xjswj531-FkRZPpcccU6kQ',
#    'alias': 'vida-verde-new-york',
#    'name': 'Vida Verde',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4VtXhki9jwY7yDXXA1p2eA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vida-verde-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1253,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7649503286729,
#     'longitude': -73.9828372257363},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '248 W 55th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['248 W 55th St', 'New York, NY 10019']},
#    'phone': '+16466570565',
#    'display_phone': '(646) 657-0565',
#    'distance': 6686.786631887716},
#   {'id': 'JAL8di-znskAHDTrLIdhfg',
#    'alias': 'for-all-things-good-brooklyn',
#    'name': 'For All Things Good',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tETAp07NCwgN6yvJnezimQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/for-all-things-good-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.687630013555,
#     'longitude': -73.9568200707436},
#    'transactions': ['delivery'],
#    'location': {'address1': '343 Franklin Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['343 Franklin Ave', 'Brooklyn, NY 11238']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3728.861754394365},
#   {'id': 'Ahx8GsuAGUl8TgqCWP7uXw',
#    'alias': 'temerario-new-york-2',
#    'name': 'Temerario',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QLSD_WYbE0chCzpE1vcBSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/temerario-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 316,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7434133400872,
#     'longitude': -73.9996277220286},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '198 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['198 8th Ave', 'New York, NY 10011']},
#    'phone': '+12126452100',
#    'display_phone': '(212) 645-2100',
#    'distance': 4245.762548000244},
#   {'id': 'Ai2mbsb0cYZoMWC3DAAP3Q',
#    'alias': 'bklyn-burro-brooklyn-5',
#    'name': "B'klyn Burro",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-2YchsT4WP7iZe9-DCNzcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bklyn-burro-brooklyn-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 127,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6827188, 'longitude': -73.9640973},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '922 Fulton St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['922 Fulton St', 'Brooklyn, NY 11238']},
#    'phone': '+17186228776',
#    'display_phone': '(718) 622-8776',
#    'distance': 3587.021519922538},
#   {'id': 'Av0BsdlotLFoEar5u1rDzg',
#    'alias': 'gueros-brooklyn',
#    'name': 'Gueros',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kUsjJa30PXbzjm8Cvm_3-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gueros-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 606,
#    'categories': [{'alias': 'tex-mex', 'title': 'Tex-Mex'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67521, 'longitude': -73.95657},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '605 Prospect Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['605 Prospect Pl', 'Brooklyn, NY 11238']},
#    'phone': '+17182304941',
#    'display_phone': '(718) 230-4941',
#    'distance': 4622.798412840416}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                      Restaurant     Type Price Rating          Address  \
# 0                      Taco Mix  Mexican     $      4   234 E 116th St
# 1  Tacombi - Financial District  Mexican    $$      4      74 Broad St
# 2            Taqueria al Pastor    Tacos     $    4.5  128 Wyckoff Ave
# 3                       Tarachi  Mexican                222 Greene Ave
# 4                  Taco Morelos  Mexican     $      4  183 Bedford Ave
#
#          Lat        Lng                                                url  \
# 0  40.797098 -73.938785  https://www.yelp.com/biz/taco-mix-new-york?adj...
# 1  40.704647 -74.011824  https://www.yelp.com/biz/tacombi-financial-dis...
# 2  40.703326 -73.918029  https://www.yelp.com/biz/taqueria-al-pastor-br...
# 3  40.686970 -73.962191
# 4  40.717799 -73.957446  https://www.yelp.com/biz/taco-morelos-brooklyn...
#
#                        ID
# 0  hSkeb_lmfxnoqg7EVo19Vw
# 1  pcQ9ld7xuX9EXTCAoakkbQ
# 2  ND2PgVHYAF4IdaV6Zse5hQ
# 3
# 4  _URXTaYBbd2XX5qJbDkKAg

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"tacos","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [{'id': 'ED91L2kUw_pwF_Pd1ZdViQ',
#    'alias': 'rancho-tequileria-new-york-10',
#    'name': 'Rancho Tequileria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rkntr3oaLqmb24PmXpd3fA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rancho-tequileria-new-york-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 71,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.793432, 'longitude': -73.971356},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '718 Amsterdam Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['718 Amsterdam Ave', 'New York, NY 10025']},
#    'phone': '+12122474505',
#    'display_phone': '(212) 247-4505',
#    'distance': 9972.680751591097},
#   {'id': 'U9BX6bMvXHk8umBYnS3Dog',
#    'alias': 'dos-toros-taqueria-new-york',
#    'name': 'Dos Toros Taqueria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0CldinGekqrfSBLh7D7S1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dos-toros-taqueria-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1331,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7336815475083,
#     'longitude': -73.9897049423153},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '137 4th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['137 4th Ave', 'New York, NY 10003']},
#    'phone': '+12126777300',
#    'display_phone': '(212) 677-7300',
#    'distance': 3163.4937203475915},
#   {'id': 'xGoSAOhQBNdJMJmPn7CMDQ',
#    'alias': 'mexicue-new-york-4',
#    'name': 'Mexicue',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qefsGMnFlD4LBNDA1O9SOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mexicue-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 585,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.754109, 'longitude': -73.986015},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1440 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1440 Broadway', 'New York, NY 10018']},
#    'phone': '+12123020385',
#    'display_phone': '(212) 302-0385',
#    'distance': 5455.9733408704715},
#   {'id': 'PPsevWepXv8XJjUc2QBOFQ',
#    'alias': 'don-taqueria-at-bens-deli-new-york',
#    'name': "Don Taqueria at Ben's Deli",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1LJyCwxsbf8_8z0vQ8mk0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/don-taqueria-at-bens-deli-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.722605, 'longitude': -73.983294},
#    'transactions': [],
#    'location': {'address1': '32 Avenue B',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 Avenue B', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2122.2051072134695},
#   {'id': 'WjI6oSe5IPHzr6b6fVoo6g',
#    'alias': 'hermana-nyc-new-york',
#    'name': 'Hermana NYC',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ipDLC4JjW9RE-H7bWMxyXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hermana-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'jazzandblues', 'title': 'Jazz & Blues'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.73092, 'longitude': -73.98335},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '349 E 13th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['349 E 13th St', 'New York, NY 10003']},
#    'phone': '+19172658234',
#    'display_phone': '(917) 265-8234',
#    'distance': 2983.632015228534},
#   {'id': 'cy0vBvZu2Eb4XtRFCp8Seg',
#    'alias': 'conmigo-new-york',
#    'name': 'Conmigo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fGkTlQIhw45NyOqy1FU4YA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/conmigo-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 271,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77793, 'longitude': -73.94902},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1685 1st Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1685 1st Ave', 'New York, NY 10128']},
#    'phone': '+12122560056',
#    'display_phone': '(212) 256-0056',
#    'distance': 8919.089273547434},
#   {'id': 'r2eXF4w9e8_V3RQTTPTfKw',
#    'alias': 'eastpoint-new-york-2',
#    'name': 'Eastpoint',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tUnxnDADquDf7NZuXTHPsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eastpoint-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72228, 'longitude': -73.98311},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '25 Ave B',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 Ave B', 'New York, NY 10009']},
#    'phone': '+16468820593',
#    'display_phone': '(646) 882-0593',
#    'distance': 2094.0426171506974},
#   {'id': 'gAAG2KJ_pdfAK-_UVN-bjQ',
#    'alias': 'oaxaca-taqueria-brooklyn-5',
#    'name': 'Oaxaca Taqueria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-iHvNsPUDl4xb6qgdvy-3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oaxaca-taqueria-brooklyn-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7148433, 'longitude': -73.9626569},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '130 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['130 Grand St', 'Brooklyn, NY 11249']},
#    'phone': '+17183888804',
#    'display_phone': '(718) 388-8804',
#    'distance': 2864.027629035049},
#   {'id': '7RAsF8y17iVonLJZDfortQ',
#    'alias': 'izkina-brooklyn',
#    'name': 'Izkina',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KOdgyjLBGOiYfIzIasCSWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izkina-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'empanadas', 'title': 'Empanadas'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69793526007247, 'longitude': -73.9256661},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1282 Myrtle Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1282 Myrtle Ave', 'Brooklyn, NY 11221']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5845.113052444889},
#   {'id': '98Bm2w9RzNJQZo4U3jSgQQ',
#    'alias': 'tacos-times-square-new-york-2',
#    'name': 'Tacos Times Square',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Gx0fzmbyZjQQ9D1v0l0maw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-times-square-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 129,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7417320336149,
#     'longitude': -73.9823354903991},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '134 E 27th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['134 E 27th St', 'New York, NY 10016']},
#    'phone': '+12128899090',
#    'display_phone': '(212) 889-9090',
#    'distance': 4158.871172514062},
#   {'id': 'cFB3Mfsqrg69Vi9WO7bTmA',
#    'alias': 'carniceria-brooklyn-2',
#    'name': 'Carniceria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Dm6r3AolGfYzUP31ErxQ5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carniceria-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7100952311239,
#     'longitude': -73.9520365428969},
#    'transactions': [],
#    'location': {'address1': '396 Hooper St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['396 Hooper St', 'Brooklyn, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3599.1864044328386},
#   {'id': 'UH_aksIxzGPPyhWZJbTP7A',
#    'alias': 'cantina-taqueria-and-tequila-bar-new-york',
#    'name': 'Cantina Taqueria & Tequila Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vCSe8HcrSNQS_br7Gua1Fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cantina-taqueria-and-tequila-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 555,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.800338992692026,
#     'longitude': -73.95497594715312},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1838 7th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10026',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1838 7th Ave', 'New York, NY 10026']},
#    'phone': '+19292632110',
#    'display_phone': '(929) 263-2110',
#    'distance': 11059.264770545851},
#   {'id': 'Z3wa8EmAr0yfihPZZMLE_A',
#    'alias': 'les-crêpes-and-taqueria-new-york',
#    'name': 'LES Crêpes & Taqueria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/u7vvyzIf79rzgjFc5pTwqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/les-cr%C3%AApes-and-taqueria-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7154425095498,
#     'longitude': -73.9899829811096},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '25A Essex St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25A Essex St', 'New York, NY 10002']},
#    'phone': '+16469645000',
#    'display_phone': '(646) 964-5000',
#    'distance': 1169.5433748426997},
#   {'id': '60sLpAHHl-IvANGTRzfCow',
#    'alias': 'tacos-grand-central-new-york-7',
#    'name': 'Tacos Grand Central',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x9IzmgcqnMvGUfYWOLIAAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-grand-central-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7476230390695,
#     'longitude': -73.9740906903076},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '711 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['711 2nd Ave', 'New York, NY 10016']},
#    'phone': '+16467819901',
#    'display_phone': '(646) 781-9901',
#    'distance': 4989.411634443161},
#   {'id': 'fbqL5ZbHa--q3seP4ZgdxA',
#    'alias': 'fat-taco-hoboken-hoboken',
#    'name': 'Fat Taco Hoboken',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Dr367gKUBtnPU_DIxSv4sA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fat-taco-hoboken-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.73679992626722,
#     'longitude': -74.02930302216558},
#    'transactions': ['restaurant_reservation'],
#    'location': {'address1': '32 Newark St',
#     'address2': None,
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['32 Newark St', 'Hoboken, NJ 07030']},
#    'phone': '+19735575016',
#    'display_phone': '(973) 557-5016',
#    'distance': 4567.357038428108},
#   {'id': 'LKA8QkPAULAJy1UwLP7ixw',
#    'alias': 'dirty-taco-tequila-rockville-centre',
#    'name': 'Dirty Taco + Tequila',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ee8w6rCMah5L-rxsVV_7rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dirty-taco-tequila-rockville-centre?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 484,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.657764, 'longitude': -73.647551},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '201 Sunrise Hwy',
#     'address2': None,
#     'address3': '',
#     'city': 'Rockville Centre',
#     'zip_code': '11570',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['201 Sunrise Hwy', 'Rockville Centre, NY 11570']},
#    'phone': '+15166009874',
#    'display_phone': '(516) 600-9874',
#    'distance': 29714.751006128176},
#   {'id': 'ApzxIf8AYh3MEgvF63Zuvw',
#    'alias': 'cantina-48-new-york-2',
#    'name': 'Cantina 48',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YkBC9MVRA7Lde85kDiiSSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cantina-48-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76497, 'longitude': -73.99607},
#    'transactions': ['delivery'],
#    'location': {'address1': '605 W 48th St',
#     'address2': 'Fl 3',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['605 W 48th St', 'Fl 3', 'New York, NY 10036']},
#    'phone': '+12129571700',
#    'display_phone': '(212) 957-1700',
#    'distance': 6633.113527865096},
#   {'id': 'Ck09FempamAKGSPsV_bX-A',
#    'alias': 'xixa-brooklyn',
#    'name': 'Xixa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gP0Mr0TzIptA5-C2ryCNrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/xixa-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 614,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.710505, 'longitude': -73.958466},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '241 S 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['241 S 4th St', 'Brooklyn, NY 11211']},
#    'phone': '+17183888860',
#    'display_phone': '(718) 388-8860',
#    'distance': 3068.0963514710497},
#   {'id': 'bx6z2FgYUxElWDvGyeFKiw',
#    'alias': 'tacos-lupita-brooklyn',
#    'name': 'Tacos Lupita',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PM8ztlLEiYBR5jvMk1mmJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-lupita-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 71,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6188823, 'longitude': -73.99003},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1802 65th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11204',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1802 65th St', 'Brooklyn, NY 11204']},
#    'phone': '+19293505682',
#    'display_phone': '(929) 350-5682',
#    'distance': 9627.021565559175},
#   {'id': 'KzJYO3-2k9XJhOHVpXayZQ',
#    'alias': 'empellón-al-pastor-east-village-new-york',
#    'name': 'Empellón Al Pastor East Village',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5A6J1opK6WjDyjBaPHmGYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/empell%C3%B3n-al-pastor-east-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 265,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72668, 'longitude': -73.98336},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '132 St Marks Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['132 St Marks Pl', 'New York, NY 10009']},
#    'phone': '+16468337039',
#    'display_phone': '(646) 833-7039',
#    'distance': 2535.9097614349607},
#   {'id': 'HKBJGt04_ZSdiIWA_6J8kQ',
#    'alias': 'tortaria-new-york',
#    'name': 'Tortaria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kwZrZkEQS-5S1jpjalnjmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tortaria-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 737,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73387, 'longitude': -73.9930481239834},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '94 University Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['94 University Pl', 'New York, NY 10003']},
#    'phone': '+12127761830',
#    'display_phone': '(212) 776-1830',
#    'distance': 3162.4686385993477},
#   {'id': '2I0GExiJv27i_oi8b-te9Q',
#    'alias': 'hot-peppers-oakland-gardens',
#    'name': 'Hot Peppers',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/x4N5ndevIsrVdQ9JwfFWlg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hot-peppers-oakland-gardens?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 374,
#    'categories': [{'alias': 'halal', 'title': 'Halal'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7371977717683,
#     'longitude': -73.7475878655444},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '78-33 Springfield Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Oakland Gardens',
#     'zip_code': '11364',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['78-33 Springfield Blvd',
#      'Oakland Gardens, NY 11364']},
#    'phone': '+13476767566',
#    'display_phone': '(347) 676-7566',
#    'distance': 21131.4647347134},
#   {'id': 'UCcqDRcLO2MTyde0w0Wr3Q',
#    'alias': 'calexico-east-village-new-york',
#    'name': 'Calexico - East Village',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m7eVxTk7dvmPpcMZuxMVTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/calexico-east-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72732, 'longitude': -73.98883},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '99 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['99 2nd Ave', 'New York, NY 10003']},
#    'phone': '+16465901466',
#    'display_phone': '(646) 590-1466',
#    'distance': 2477.671703397263},
#   {'id': '0Nu2kmbWnfP7GD-NZ5h3fw',
#    'alias': 'tacos-los-poblanos-brooklyn',
#    'name': 'Tacos Los Poblanos',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-Ua8WXPgYaJZJAIO6trLaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-los-poblanos-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.643196, 'longitude': -74.012781},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '5320 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11220',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5320 5th Ave', 'Brooklyn, NY 11220']},
#    'phone': '+13476412092',
#    'display_phone': '(347) 641-2092',
#    'distance': 7095.175738482115},
#   {'id': 'R5jpETY0OshPn-AeJjs0fA',
#    'alias': 'dos-caminos-new-york-4',
#    'name': 'Dos Caminos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0Q_W1gcSGPL93_Nl2I9MSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dos-caminos-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1133,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7266452, 'longitude': -73.9999024},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '475 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['475 W Broadway', 'New York, NY 10012']},
#    'phone': '+12122774300',
#    'display_phone': '(212) 277-4300',
#    'distance': 2404.301695404806},
#   {'id': 'oNgT6-rh-2TOeAF16AxXVw',
#    'alias': 'tacos-and-tequila-new-york',
#    'name': 'Tacos & Tequila',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dcC5SxL2hm9Ks2ovDPpOiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-and-tequila-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.780745, 'longitude': -73.9493227},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1742 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1742 2nd Ave', 'New York, NY 10128']},
#    'phone': '+16464540029',
#    'display_phone': '(646) 454-0029',
#    'distance': 9190.22551784629},
#   {'id': '9ijkw9x8oSSSnsUo5uR4Xw',
#    'alias': 'taco-santana-brooklyn',
#    'name': 'Taco Santana',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RwyHQK9ME-NdaKDhxy5zvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-santana-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 157,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7079186820012,
#     'longitude': -73.9554587596491},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '301 Keap St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['301 Keap St', 'Brooklyn, NY 11211']},
#    'phone': '+17183888761',
#    'display_phone': '(718) 388-8761',
#    'distance': 3284.9765432080976},
#   {'id': 'hcI6TVxFyVNEPXg3rF1bQw',
#    'alias': 'oaxaca-taqueria-new-york-5',
#    'name': 'Oaxaca Taqueria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BQJhe1mTu7d2869JJA_r6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oaxaca-taqueria-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 129,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7601356506348,
#     'longitude': -73.992057800293},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '405 W 44th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['405 W 44th St', 'New York, NY 10036']},
#    'phone': '+12127572957',
#    'display_phone': '(212) 757-2957',
#    'distance': 6080.4852268635805},
#   {'id': 'zASGm-RyRNTY2xQir2nV_w',
#    'alias': 'jajaja-plantas-mexicana-brooklyn',
#    'name': 'Jajaja Plantas Mexicana',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/01E7Hf18Oq7BMa1I6cy6Nw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jajaja-plantas-mexicana-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7201266, 'longitude': -73.9615772},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '119 Kent Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['119 Kent Ave', 'Brooklyn, NY 11249']},
#    'phone': '+18604792872',
#    'display_phone': '(860) 479-2872',
#    'distance': 3204.48021011505},
#   {'id': 'SSDOkx5enfRH3nsniS_2jA',
#    'alias': '5ive-spice-brooklyn-3',
#    'name': '5ive Spice',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VFQdUvDvYj36stc4PvfyKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/5ive-spice-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 753,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.681442, 'longitude': -73.977241},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '52 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['52 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17188573483',
#    'display_phone': '(718) 857-3483',
#    'distance': 3031.5630577712896},
#   {'id': 'q1ha1qnViHKmh3-tEGw8DA',
#    'alias': 'taco-dumbo-new-york-4',
#    'name': 'Taco Dumbo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XMxqPiUL53s4uj89jOEZMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-dumbo-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 108,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75275, 'longitude': -73.98756},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1385 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1385 Broadway', 'New York, NY 10018']},
#    'phone': '+16469984491',
#    'display_phone': '(646) 998-4491',
#    'distance': 5288.057000263931},
#   {'id': 'iPc-zPgcpgeSo76xl5Jbpw',
#    'alias': 'the-maze-new-york-3',
#    'name': 'The Maze',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hPYHRfgxCwzPF5HVpXqyQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-maze-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 514,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.747846, 'longitude': -73.9872499},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '32 W 32nd St',
#     'address2': 'Fl 3',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 W 32nd St', 'Fl 3', 'New York, NY 10001']},
#    'phone': '+16469187519',
#    'display_phone': '(646) 918-7519',
#    'distance': 4751.996403737684},
#   {'id': 'qjCl34rJ0zVUHaZ1irb8FA',
#    'alias': 'taqueria-ramirez-brooklyn',
#    'name': 'Taqueria Ramirez',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/r4RTy-eKKOE5ao9kkNI1CA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-ramirez-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.727876136419724,
#     'longitude': -73.95699203025863},
#    'transactions': [],
#    'location': {'address1': '94 Franklin St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['94 Franklin St', 'Brooklyn, NY 11222']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4013.00964714223},
#   {'id': 'BsDu_kup3lJ2QHb-Botpeg',
#    'alias': 'covacha-new-york',
#    'name': 'Covacha',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8JLKNy0d0RU_ReMYCIhCXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/covacha-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78110489839311,
#     'longitude': -73.97644500326436},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '368 Columbus Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['368 Columbus Ave', 'New York, NY 10023']},
#    'phone': '+12127122929',
#    'display_phone': '(212) 712-2929',
#    'distance': 8546.31706328435},
#   {'id': 'UmY9dyGOclJ0tGbn1IozlA',
#    'alias': 'zaragoza-mexican-deli-and-grocery-new-york',
#    'name': 'Zaragoza Mexican Deli & Grocery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JfCVpZaKKXdC329R-pShPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zaragoza-mexican-deli-and-grocery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 311,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.730102, 'longitude': -73.980949},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '215 Ave A',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['215 Ave A', 'New York, NY 10009']},
#    'phone': '+12127809204',
#    'display_phone': '(212) 780-9204',
#    'distance': 2959.9776315229014},
#   {'id': 'KhGbD1U51KKcl6frzNDa0A',
#    'alias': 'taqueria-el-patron-mexican-grill-brooklyn',
#    'name': 'Taqueria El Patron Mexican Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_phyi9RSMZg0LYneADrEFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-el-patron-mexican-grill-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 217,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6609280639479,
#     'longitude': -73.9614267185271},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '51 Lincoln Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11225',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['51 Lincoln Rd', 'Brooklyn, NY 11225']},
#    'phone': '+19178938733',
#    'display_phone': '(917) 893-8733',
#    'distance': 5673.034828263466},
#   {'id': 'ELFvdT_91a3lVef-Cnsg0w',
#    'alias': 'tacostio1-brooklyn-3',
#    'name': 'Tacostio1',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3WdDuPFhTOtPzuJQoaMK7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacostio1-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7035, 'longitude': -73.93154},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '994 Flushing Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['994 Flushing Ave', 'Brooklyn, NY 11206']},
#    'phone': '+13475289766',
#    'display_phone': '(347) 528-9766',
#    'distance': 5297.071167697858},
#   {'id': 'VREXC353INWXdSyTYvt8Lg',
#    'alias': 'oaxaca-taqueria-brooklyn',
#    'name': 'Oaxaca Taqueria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hY7ApZXIbDTKsAB3jMNy6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oaxaca-taqueria-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 175,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.68634, 'longitude': -73.954767},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1116 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1116 Bedford Ave', 'New York, NY 11216']},
#    'phone': '+17182308111',
#    'display_phone': '(718) 230-8111',
#    'distance': 3951.8427243994465},
#   {'id': '2h9uosx5vBHWJR23T0PhqA',
#    'alias': 'maya-taqueria-brooklyn-8',
#    'name': 'Maya Taqueria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6xO9ICAI5cmdCk5jQMpkVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maya-taqueria-brooklyn-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 89,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67763, 'longitude': -73.9798},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '168 5th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['168 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17183986292',
#    'display_phone': '(718) 398-6292',
#    'distance': 3322.067794206807},
#   {'id': 'yl214H_cUd1intjVAeE1Mw',
#    'alias': 'casa-publica-brooklyn-2',
#    'name': 'Casa Publica',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IFmZEha1GKMYKGayjpaBTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-publica-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 132,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.718194, 'longitude': -73.9520543},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '594 Union Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['594 Union Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17183883555',
#    'display_phone': '(718) 388-3555',
#    'distance': 3832.003174234117},
#   {'id': 'jF9hIgD5MvZBXyKvztUtSA',
#    'alias': 'gmc-temaxcal-deli-and-grocery-brooklyn',
#    'name': 'GMC Temaxcal Deli & Grocery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_gpwZp0W_keHkXcyRjki_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gmc-temaxcal-deli-and-grocery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.696418, 'longitude': -73.972984},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '163 Park Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['163 Park Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17183078100',
#    'display_phone': '(718) 307-8100',
#    'distance': 2061.3164156003413},
#   {'id': 'trOfIBnEr_CxZuLRyGj9FQ',
#    'alias': 'miti-miti-brooklyn-2',
#    'name': 'Miti Miti',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bD1NjFE32z2ShYIX2FDSHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/miti-miti-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1231,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6786672454389,
#     'longitude': -73.9791200818081},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '138 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['138 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17182303760',
#    'display_phone': '(718) 230-3760',
#    'distance': 3240.7089537904526},
#   {'id': 'L5eqJRy8Yx_4El6rUxWmBw',
#    'alias': 'el-vez-burrito-bar-new-york',
#    'name': 'El Vez Burrito Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/p-1_uKZapdvXP2OJA97Mdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-vez-burrito-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 144,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7147356376792, 'longitude': -74.015635},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '259 Vesey St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10282',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['259 Vesey St', 'New York, NY 10282']},
#    'phone': '+12122332500',
#    'display_phone': '(212) 233-2500',
#    'distance': 2074.4005590427},
#   {'id': 'v8tuFxvNkKdZytWTn9BhMA',
#    'alias': 'fonda-chelsea-new-york-2',
#    'name': 'Fonda Chelsea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mNyXXg9XcA-y_XpwBRKX3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fonda-chelsea-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 374,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7455185879981,
#     'longitude': -74.0021848849335},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '189 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['189 9th Ave', 'New York, NY 10011']},
#    'phone': '+19175255252',
#    'display_phone': '(917) 525-5252',
#    'distance': 4505.340632387758},
#   {'id': '1vkYZbdwMpqteI8x_sS68g',
#    'alias': 'fast-and-fresh-burrito-deli-brooklyn',
#    'name': 'Fast and Fresh Burrito Deli',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7RjOQwrp5rTTDXpg3aYnJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fast-and-fresh-burrito-deli-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 182,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68806, 'longitude': -73.98694},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '84 Hoyt St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['84 Hoyt St', 'Brooklyn, NY 11201']},
#    'phone': '+17188021661',
#    'display_phone': '(718) 802-1661',
#    'distance': 2027.3645591556144},
#   {'id': '1m6pfntylp2UL67hRPCbiw',
#    'alias': 'the-lost-lady-new-york',
#    'name': 'The Lost Lady',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ar_YI7Gnq_KRQP36ScV9xg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lost-lady-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'tikibars', 'title': 'Tiki Bars'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72631, 'longitude': -73.97756},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '171 Avenue C',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 Avenue C', 'New York, NY 10009']},
#    'phone': '+13474550228',
#    'display_phone': '(347) 455-0228',
#    'distance': 2718.37100486118},
#   {'id': '3kDlekYKGTPXqiLIUcC6Ng',
#    'alias': 'mama-lupitas-bistro-brooklyn',
#    'name': "Mama Lupita's Bistro",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/51-exB13WW0wcptFNwSOrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mama-lupitas-bistro-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.655989, 'longitude': -74.003119},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '904 4th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11232',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['904 4th Ave', 'Brooklyn, NY 11232']},
#    'phone': '+19179090522',
#    'display_phone': '(917) 909-0522',
#    'distance': 5549.366787638498},
#   {'id': 't9JRIzyQoJU29WeVBLU7Lw',
#    'alias': 'maya-taqueria-brooklyn-7',
#    'name': 'Maya Taqueria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZvoN3pbbkm8f5SEznkeeVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maya-taqueria-brooklyn-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 406,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.678009898445076,
#     'longitude': -73.96853092252653},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '637 Vanderbilt Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['637 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17186386292',
#    'display_phone': '(718) 638-6292',
#    'distance': 3744.8766537466154},
#   {'id': 'Nnuz_Ic0IdWOUbl64r4Hkg',
#    'alias': 'fonda-park-slope-brooklyn',
#    'name': 'Fonda Park Slope',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qVcynT6bkKccqVhvLEUXaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fonda-park-slope-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 846,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.663631439209,
#     'longitude': -73.9846343994141},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '434 7th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['434 7th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17183693144',
#    'display_phone': '(718) 369-3144',
#    'distance': 4721.62152084486},
#   {'id': 'zgBCa3-Ht4xBHQGyP4Bufg',
#    'alias': 'taco-mix-new-york-3',
#    'name': 'Taco Mix',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2SfLoox9gtdlOV2QEx2a4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-mix-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7181, 'longitude': -73.98592},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '158 Delancey St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['158 Delancey St', 'New York, NY 10002']},
#    'phone': '+19173883977',
#    'display_phone': '(917) 388-3977',
#    'distance': 1575.3294513046344}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#                    Restaurant     Type Price Rating            Address  \
# 0           Rancho Tequileria  Mexican               718 Amsterdam Ave
# 1          Dos Toros Taqueria  Mexican     $      4        137 4th Ave
# 2                     Mexicue  Mexican    $$      4      1440 Broadway
# 3  Don Taqueria at Ben's Deli  Mexican                     32 Avenue B
# 4                 Hermana NYC  Mexican                   349 E 13th St
#
#          Lat        Lng                                                url  \
# 0  40.793432 -73.971356
# 1  40.733682 -73.989705  https://www.yelp.com/biz/dos-toros-taqueria-ne...
# 2  40.754109 -73.986015  https://www.yelp.com/biz/mexicue-new-york-4?ad...
# 3  40.722605 -73.983294
# 4  40.730920 -73.983350
#
#                        ID
# 0
# 1  U9BX6bMvXHk8umBYnS3Dog
# 2  xGoSAOhQBNdJMJmPn7CMDQ
# 3
# 4

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                          Restaurant                Type Rating Price  \
# 0                Flats Fix Taqueria                Bars    3.5    $$
# 1                           Chilo's                Bars      4     $
# 2                 Taqueria Gramercy                Bars
# 3           Calexico - East Village  Breakfast & Brunch      4    $$
# 4                         Breakroom             Burgers    4.5    $$
# 5               For All Things Good               Cafes
# 6                        Vida Verde       Cocktail Bars    4.5    $$
# 7                  Fat Taco Hoboken       Cocktail Bars
# 8                       Street Taco       Cocktail Bars      4    $$
# 9                         Toro Loco       Cocktail Bars      4    $$
# 10                          Conmigo       Cocktail Bars      4    $$
# 11                      Cafe Habana               Cuban      4    $$
# 12                           Izkina           Empanadas
# 13                         The Bear           Fast Food    4.5    $$
# 14                        Flip Sigi            Filipino      4    $$
# 15                    Tacos Cholula         Food Trucks    4.5     $
# 16          Los Tacos City Habanero         Food Trucks    4.5     $
# 17           The 99 Cent Taco Truck         Food Trucks      5     $
# 18               Chinelos Tacos NYC         Food Trucks
# 19                        Tacostio1         Food Trucks
# 20                  Tacos El Bronco         Food Trucks    4.5     $
# 21       Birria Landia Williamsburg         Food Trucks    4.5    $$
# 22                  Casa Birria NYC         Food Trucks
# 23                    Birria-Landia         Food Trucks    4.5     $
# 24                     Tacos Lupita         Food Trucks    4.5     $
# 25             Reyes Deli & Grocery             Grocery    4.5     $
# 26                      Hot Peppers               Halal    4.5    $$
# 27                       Birria LES               Halal      4    $$
# 28                       Taco Mahal              Indian    4.5    $$
# 29                         The Maze              Korean      4    $$
# ..                              ...                 ...    ...   ...
# 170             Los Tacos Al Pastor               Tacos
# 171              Taqueria al Pastor               Tacos    4.5     $
# 172              Oro Verde Taqueria               Tacos
# 173                      Borrachito               Tacos
# 174                     Summer Salt               Tacos
# 175                     La Taqueria               Tacos
# 176                     Planet Taco               Tacos
# 177                       Pico Taco               Tacos      4    $$
# 178          Brujos - Brooklyn Taco               Tacos
# 179                    Taco Edition               Tacos      4     $
# 180          Taqueria Mariposa Rosa               Tacos
# 181            Nene's Deli Taqueria               Tacos
# 182                        Tacocina               Tacos    3.5    $$
# 183              Moho Mexican Grill               Tacos
# 184                         Tacoria               Tacos    4.5     $
# 185  Calabrije's Margaritas & Tacos               Tacos      4    $$
# 186                   San Pedro Inn               Tacos      4    $$
# 187                 Los Tacos No. 1               Tacos    4.5     $
# 188                       Eastpoint               Tacos    4.5    $$
# 189            Taqueria Fort Greene               Tacos
# 190                      Carniceria               Tacos
# 191            Dirty Taco + Tequila               Tacos    4.5    $$
# 192                         Tributo               Tacos
# 193                Cowgirl Seahorse             Tex-Mex      4    $$
# 194               El Gallo Taqueria             Tex-Mex      4    $$
# 195                     Yellow Rose             Tex-Mex
# 196                          Gueros             Tex-Mex      4    $$
# 197                   The Lost Lady           Tiki Bars    4.5    $$
# 198                      5ive Spice          Vietnamese    4.5    $$
# 199                      5ive Spice          Vietnamese    4.5    $$
#
#                      Address        Lat        Lng  \
# 0               28 E 16th St  40.736504 -73.991058
# 1           323 Franklin Ave  40.688350 -73.956960
# 2                218 3rd Ave  40.736300 -73.985310
# 3                 99 2nd Ave  40.727320 -73.988830
# 4               83 Baxter St  40.716691 -73.999944
# 5           343 Franklin Ave  40.687630 -73.956820
# 6              248 W 55th St  40.764950 -73.982837
# 7               32 Newark St  40.736800 -74.029303
# 8                358 3rd Ave  40.740970 -73.982020
# 9                15 Stone St  40.704210 -74.012080
# 10              1685 1st Ave  40.777930 -73.949020
# 11              17 Prince St  40.722998 -73.994171
# 12           1282 Myrtle Ave  40.697935 -73.925666
# 13               48 S 4th St  40.712834 -73.966359
# 14             131 7th Ave S  40.734496 -74.002067
# 15                  25 Ave A  40.723010 -73.986050
# 16      48th Ave Vernon Blvd  40.744014 -73.953769
# 17                            40.790896 -73.945154
# 18          4-09 Center Blvd  40.742352 -73.959962
# 19          994 Flushing Ave  40.703500 -73.931540
# 20         37th St & 5th Ave  40.652370 -74.002740
# 21       495 Metropolian Ave  40.713905 -73.951963
# 22            86th & 3rd Ave  40.778824 -73.953986
# 23   Roosevelt Ave & 78th St  40.747258 -73.887784
# 24              1802 65th St  40.618882 -73.990030
# 25               532 4th Ave  40.667310 -73.991620
# 26    78-33 Springfield Blvd  40.737198 -73.747588
# 27          127 Rivington St  40.719629 -73.987114
# 28              73 7th Ave S  40.732358 -74.003326
# 29              32 W 32nd St  40.747846 -73.987250
# ..                       ...        ...        ...
# 170             141 Front St  40.702540 -73.987360
# 171          128 Wyckoff Ave  40.703326 -73.918029
# 172              150 8th Ave  40.741820 -74.000780
# 173             206 Avenue A  40.729461 -73.980749
# 174          30 East 23rd St  40.740570 -73.987680
# 175             572 Grand St  40.711269 -73.948973
# 176              141 2nd Ave  40.729140 -73.987490
# 177             70 Hudson St  40.736180 -74.030450
# 178           333 Graham Ave  40.714301 -73.944522
# 179             800 Grand St  40.711641 -73.941319
# 180              55 Grove St  40.733207 -74.003541
# 181              14 Starr St  40.700180 -73.927810
# 182              25 River St  40.715238 -73.967644
# 183          38-05 Bell Blvd  40.766353 -73.772158
# 184            24-26 Erie st  40.721858 -74.044181
# 185             234 Starr St  40.705543 -73.922554
# 186         320 Van Brunt St  40.679080 -74.011060
# 187             125 Park Ave  40.751566 -73.977476
# 188                 25 Ave B  40.722280 -73.983110
# 189          154 Carlton Ave  40.693022 -73.972958
# 190            396 Hooper St  40.710095 -73.952037
# 191          201 Sunrise Hwy  40.657764 -73.647551
# 192        42-25 Vernon Blvd  40.753375 -73.949777
# 193             259 Front St  40.708136 -74.000453
# 194         214 Highlawn Ave  40.603515 -73.977910
# 195              102 3rd Ave  40.732575 -73.988069
# 196          605 Prospect Pl  40.675210 -73.956570
# 197             171 Avenue C  40.726310 -73.977560
# 198               52 5th Ave  40.681442 -73.977241
# 199          227 Mulberry St  40.722598 -73.996272
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/flats-fix-taqueria-ne...  AnAZaBsEuBjYvzaPMTN0oQ
# 1    https://www.yelp.com/biz/chilos-brooklyn?adjus...  XDl93co2VJznxglYcoQvmA
# 2
# 3    https://www.yelp.com/biz/calexico-east-village...  UCcqDRcLO2MTyde0w0Wr3Q
# 4    https://www.yelp.com/biz/breakroom-new-york?ad...  MfbVI5reXLIIs8Cc2HwgQw
# 5
# 6    https://www.yelp.com/biz/vida-verde-new-york?a...  Xjswj531-FkRZPpcccU6kQ
# 7
# 8    https://www.yelp.com/biz/street-taco-new-york?...  hKkPlYmHoS9Nb_UbGGqx8A
# 9    https://www.yelp.com/biz/toro-loco-new-york?ad...  nrwOQSXoRXfAYhkdjiUk8g
# 10   https://www.yelp.com/biz/conmigo-new-york?adju...  cy0vBvZu2Eb4XtRFCp8Seg
# 11   https://www.yelp.com/biz/cafe-habana-new-york-...  NOh24SMS6k4pzNv8Ds7KDg
# 12
# 13   https://www.yelp.com/biz/the-bear-brooklyn?adj...  P5gcdU1DX9M1V4W-V9o-wg
# 14   https://www.yelp.com/biz/flip-sigi-new-york-2?...  8WnHtvMdPWE66eSkUdbLhQ
# 15   https://www.yelp.com/biz/tacos-cholula-new-yor...  jQjQHNAM8xXB73kFkfg9kA
# 16   https://www.yelp.com/biz/los-tacos-city-habane...  mBFnE5EDUwpZiEsSf_1piA
# 17   https://www.yelp.com/biz/the-99-cent-taco-truc...  NUi84uNaFW2LUNZ3oEai1Q
# 18
# 19
# 20   https://www.yelp.com/biz/tacos-el-bronco-brook...  9MWmRzKbw6-OR8O1fYa2fw
# 21   https://www.yelp.com/biz/birria-landia-william...  LWHHNai3yu6ovrf4Bcepjg
# 22
# 23   https://www.yelp.com/biz/birria-landia-jackson...  6403iqg-_a-sdg-DrKEfhw
# 24   https://www.yelp.com/biz/tacos-lupita-brooklyn...  bx6z2FgYUxElWDvGyeFKiw
# 25   https://www.yelp.com/biz/reyes-deli-and-grocer...  MT8a8H25oeQ6eATdffxWmA
# 26   https://www.yelp.com/biz/hot-peppers-oakland-g...  2I0GExiJv27i_oi8b-te9Q
# 27   https://www.yelp.com/biz/birria-les-new-york?a...  G2PCaDt_VC4O4w6uRMpE9A
# 28   https://www.yelp.com/biz/taco-mahal-new-york?a...  SP4bvMvxel_UPdof_er3HA
# 29   https://www.yelp.com/biz/the-maze-new-york-3?a...  iPc-zPgcpgeSo76xl5Jbpw
# ..                                                 ...                     ...
# 170
# 171  https://www.yelp.com/biz/taqueria-al-pastor-br...  ND2PgVHYAF4IdaV6Zse5hQ
# 172
# 173
# 174
# 175
# 176
# 177  https://www.yelp.com/biz/pico-taco-hoboken-2?a...  LSMfKvER1s42GV_BV4nELA
# 178
# 179  https://www.yelp.com/biz/taco-edition-brooklyn...  h_ITJux-MF0YcmZx8KRHtA
# 180
# 181
# 182  https://www.yelp.com/biz/tacocina-brooklyn?adj...  eCD1l-Xx3QqnhrSsoccgMg
# 183
# 184  https://www.yelp.com/biz/tacoria-jersey-city-3...  kJCjKpwcOFA1fal0fuNVRg
# 185  https://www.yelp.com/biz/calabrijes-margaritas...  -SYHh9DWvYuBZxkA4gfzHg
# 186  https://www.yelp.com/biz/san-pedro-inn-brookly...  jfNc9_Of6ojLl4DVG9QKCw
# 187  https://www.yelp.com/biz/los-tacos-no-1-new-yo...  LdbANxQjzdvzBqUESYTUnw
# 188  https://www.yelp.com/biz/eastpoint-new-york-2?...  r2eXF4w9e8_V3RQTTPTfKw
# 189
# 190
# 191  https://www.yelp.com/biz/dirty-taco-tequila-ro...  LKA8QkPAULAJy1UwLP7ixw
# 192
# 193  https://www.yelp.com/biz/cowgirl-seahorse-new-...  4zBGXDXg9DzK0IROwCUeFg
# 194  https://www.yelp.com/biz/el-gallo-taqueria-bro...  _5G0SOM1ogWTsSmPBGRfzA
# 195
# 196  https://www.yelp.com/biz/gueros-brooklyn?adjus...  Av0BsdlotLFoEar5u1rDzg
# 197  https://www.yelp.com/biz/the-lost-lady-new-yor...  1m6pfntylp2UL67hRPCbiw
# 198  https://www.yelp.com/biz/5ive-spice-brooklyn-3...  SSDOkx5enfRH3nsniS_2jA
# 199  https://www.yelp.com/biz/5ive-spice-new-york-2...  9fG8-RRh1rzuCKN2TmF-QQ
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_Tacos.csv')
