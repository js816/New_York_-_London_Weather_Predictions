# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"soup and salad","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': 'HuSaFUqMDLbovpU-XbR9UA',
#    'alias': 'the-original-soupman-new-york-7',
#    'name': 'The Original Soupman',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_xT6tSRilqKloOryNZgMhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-original-soupman-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 531,
#    'categories': [{'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7653611721499,
#     'longitude': -73.9834392665359},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '259A W 55th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['259A W 55th St', 'New York, NY 10019']},
#    'phone': '+12129560900',
#    'display_phone': '(212) 956-0900',
#    'distance': 6724.853803229754},
#   {'id': 'lR58h9jeoDfy_9jVOqTDJg',
#    'alias': 'the-soup-bowl-of-park-slope-brooklyn',
#    'name': 'The Soup Bowl of Park Slope',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uxvH16TeaNWj2XD1RLNb6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-soup-bowl-of-park-slope-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 104,
#    'categories': [{'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6670558, 'longitude': -73.981222},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '319 7th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['319 7th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17189654237',
#    'display_phone': '(718) 965-4237',
#    'distance': 4403.612489934311},
#   {'id': 'VCqNjupCWZ5INzOcyBMJSg',
#    'alias': 'the-grey-dog-union-square-new-york',
#    'name': 'The Grey Dog - Union Square',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FW9ZtnLzYXITP6frUZJuaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grey-dog-union-square-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1098,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.733828, 'longitude': -73.993052},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '90 University Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90 University Pl', 'New York, NY 10003']},
#    'phone': '+12129661060',
#    'display_phone': '(212) 966-1060',
#    'distance': 3157.790195665447},
#   {'id': 'IiLLntICUim7YREkIBU7lA',
#    'alias': 'outro-new-york',
#    'name': 'Outro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QuGJCO9M5O2eEVmLtLI52g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/outro-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 340,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'waffles', 'title': 'Waffles'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7327799573693,
#     'longitude': -73.9910601451993},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '816 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['816 Broadway', 'New York, NY 10003']},
#    'phone': '+12129946771',
#    'display_phone': '(212) 994-6771',
#    'distance': 3051.7084001127732},
#   {'id': 'PpxJsItHTF6sDAK6XnDJ9w',
#    'alias': 'bite-new-york-3',
#    'name': 'Bite',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wqNBS7CvzhN-98qvnu0YgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bite-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 628,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.733163, 'longitude': -73.986158},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '211 E 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['211 E 14th St', 'New York, NY 10003']},
#    'phone': '+12126773123',
#    'display_phone': '(212) 677-3123',
#    'distance': 3157.4470413202994},
#   {'id': '7vl4N31vGFEJwK-qq26uGQ',
#    'alias': 'just-salad-new-york-58',
#    'name': 'Just Salad',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hvYQ0yvp37omUEzCLPrHhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/just-salad-new-york-58?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'wraps', 'title': 'Wraps'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75362767830822, 'longitude': -73.9865612},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1412 Broadway',
#     'address2': 'Ste 106',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1412 Broadway', 'Ste 106', 'New York, NY 10018']},
#    'phone': '+18666733757',
#    'display_phone': '(866) 673-3757',
#    'distance': 5397.147648478635},
#   {'id': '_4Grm99JEHnDWskCHAJfUg',
#    'alias': 'kikis-new-york',
#    'name': "Kiki's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GgeWTqIFt1KuRqfcFHDKUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kikis-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 668,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7144971858255,
#     'longitude': -73.9918553931336},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '130 Division St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['130 Division St', 'New York, NY 10002']},
#    'phone': '+16468827052',
#    'display_phone': '(646) 882-7052',
#    'distance': 1027.330009136556},
#   {'id': 'DW5SL9RM-kJnmRyYo4oEqg',
#    'alias': 'rubys-murray-hill-new-york-2',
#    'name': "Ruby's - Murray Hill",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MOcyUVptR_27yLxOx2-wZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rubys-murray-hill-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 568,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'australian', 'title': 'Australian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74364, 'longitude': -73.97985},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '442 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['442 3rd Ave', 'New York, NY 10016']},
#    'phone': '+12123004245',
#    'display_phone': '(212) 300-4245',
#    'distance': 4415.271099706975},
#   {'id': 'T7-BtR3aYps17K7CHiHlOQ',
#    'alias': 'sanpanino-brooklyn',
#    'name': 'Sanpanino',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kXF6Ms5iiKkmsvaBVbjnvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sanpanino-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69034, 'longitude': -73.991676},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '187 State St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['187 State St', 'Brooklyn, NY 11201']},
#    'phone': '+17185763803',
#    'display_phone': '(718) 576-3803',
#    'distance': 1695.8888202150679},
#   {'id': 'I6optu9x0JAf8oT5lqJ8qw',
#    'alias': 'the-blue-dog-cookhouse-and-bar-new-york',
#    'name': 'The Blue Dog Cookhouse & Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ti4clcUwTHygJ7FlOg6dmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-blue-dog-cookhouse-and-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1302,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76244, 'longitude': -73.98674},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '308 W 50th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['308 W 50th St', 'New York, NY 10019']},
#    'phone': '+12124590700',
#    'display_phone': '(212) 459-0700',
#    'distance': 6367.978690875311},
#   {'id': 'FOf_vQQ2HshtN3HUBPlNiw',
#    'alias': 'the-sandwich-shop-brooklyn',
#    'name': 'The Sandwich Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/edF-8_pf07cxTKqSbaxA7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-sandwich-shop-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 147,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71132, 'longitude': -73.94618},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '658A Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['658A Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+19179325662',
#    'display_phone': '(917) 932-5662',
#    'distance': 4106.418753355149},
#   {'id': '5WdsgeCz2WwN57B-eYZi7w',
#    'alias': 'the-grey-dog-new-york-6',
#    'name': 'The Grey Dog',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Lfa2YFrMMSEk48mnCyHqGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grey-dog-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 363,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729998660113,
#     'longitude': -74.0038951001712},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '49 Carmine St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['49 Carmine St', 'New York, NY 10014']},
#    'phone': '+12129661060',
#    'display_phone': '(212) 966-1060',
#    'distance': 2847.655493154376},
#   {'id': 'U5hCNNyJmb7f3dmC1HTzSQ',
#    'alias': 'juniors-restaurant-and-bakery-45th-st-new-york',
#    'name': "Junior's Restaurant & Bakery - 45th St",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RwLK04cnu1y4t8xPRY3mwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/juniors-restaurant-and-bakery-45th-st-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4735,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75754564001459,
#     'longitude': -73.98608001118411},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1515 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1515 Broadway', 'New York, NY 10036']},
#    'phone': '+12123022000',
#    'display_phone': '(212) 302-2000',
#    'distance': 5834.523948198199},
#   {'id': 'MctQwL9Mp5X7DJk13VoERg',
#    'alias': 'westville-chelsea-new-york-2',
#    'name': 'Westville Chelsea',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ePvwxoDmrJzWIWT16MWUwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/westville-chelsea-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1159,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74175, 'longitude': -74.00007},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '246 W 18th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['246 W 18th St', 'New York, NY 10011']},
#    'phone': '+12129242223',
#    'display_phone': '(212) 924-2223',
#    'distance': 4067.8903874945936},
#   {'id': 'koh-4_SAbshwZ8EBRmXcmg',
#    'alias': 'b-and-h-dairy-new-york-2',
#    'name': 'B&H Dairy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uqw6D9083EcXLm2Bgci_LQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b-and-h-dairy-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 488,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7284622192383,
#     'longitude': -73.988166809082},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '127 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['127 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12125058065',
#    'display_phone': '(212) 505-8065',
#    'distance': 2614.748126892428},
#   {'id': 'nHMDOIX32dGbfpuNUwsLNQ',
#    'alias': 'almar-brooklyn-2',
#    'name': 'AlMar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_EoXWmBYT1-X--xHq0oUTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/almar-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 460,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.702662, 'longitude': -73.989177},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '111 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17188555288',
#    'display_phone': '(718) 855-5288',
#    'distance': 530.8013177444826},
#   {'id': 'QpkKEFHK5dz8XT-osEXgJw',
#    'alias': 'the-grey-dog-new-york-5',
#    'name': 'The Grey Dog',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/otXCu2LRthBRARlQF4-FgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grey-dog-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1156,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.740624, 'longitude': -74.000648},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '242 W 16th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['242 W 16th St', 'New York, NY 10011']},
#    'phone': '+12122292345',
#    'display_phone': '(212) 229-2345',
#    'distance': 3948.224414243807},
#   {'id': 'a7BC1doUjNDqrqTaAMmfZg',
#    'alias': 'bite-new-york',
#    'name': 'Bite',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TwZI7h0HzbdECV7Tv7WQWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bite-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 276,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7257318645125,
#     'longitude': -73.9946338116395},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '335 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['335 Lafayette St', 'New York, NY 10012']},
#    'phone': '+12124310301',
#    'display_phone': '(212) 431-0301',
#    'distance': 2255.9916215713783},
#   {'id': 'sR60I9PI_63noBQcGoIrbw',
#    'alias': 'pause-cafe-new-york',
#    'name': 'Pause Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/T8poA0a4leJLMEeF4DxeSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pause-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 437,
#    'categories': [{'alias': 'moroccan', 'title': 'Moroccan'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72123, 'longitude': -73.98408},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '3 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3 Clinton St', 'New York, NY 10002']},
#    'phone': '+12126775415',
#    'display_phone': '(212) 677-5415',
#    'distance': 1950.7097014911349},
#   {'id': 'Me4TxTbPPQZQopW1wOGx5g',
#    'alias': 'jacks-wife-freda-new-york',
#    'name': "Jack's Wife Freda",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Mo4sHJ9wi76R2Eg3Q7bSqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jacks-wife-freda-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2024,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72213, 'longitude': -73.99756},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '224 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['224 Lafayette St', 'New York, NY 10012']},
#    'phone': '+12125108550',
#    'display_phone': '(212) 510-8550',
#    'distance': 1874.7368920314377},
#   {'id': '8JDwcklaawqYprHg0c9aIA',
#    'alias': 'the-brooklyn-tree-brooklyn-2',
#    'name': 'The Brooklyn Tree',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SEkkfiJ8v_8-rDtvSmFTNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-brooklyn-tree-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 183,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70734, 'longitude': -73.94186},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '188 Montrose Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['188 Montrose Ave', 'Brooklyn, NY 11206']},
#    'phone': '+19179090307',
#    'display_phone': '(917) 909-0307',
#    'distance': 4424.9357538503},
#   {'id': 'zV1_EFMN4VY7Rxpv7P-ajg',
#    'alias': 'sunflower-gramercy-new-york-3',
#    'name': 'Sunflower - Gramercy',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MBjaUlDYeC2t4M6834Gqsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sunflower-gramercy-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 179,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7399, 'longitude': -73.98219},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '335 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['335 3rd Ave', 'New York, NY 10010']},
#    'phone': '+19172620804',
#    'display_phone': '(917) 262-0804',
#    'distance': 3966.0144034235027},
#   {'id': 'ArfL-sU2FaB73WV1qQ4c6Q',
#    'alias': 'simple-cafe-and-restaurant-brooklyn',
#    'name': 'Simple Cafe & Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/efMJDc2PMl7AVJ6_MMiuJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/simple-cafe-and-restaurant-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 190,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71244, 'longitude': -73.96275},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '346 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['346 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17182187067',
#    'display_phone': '(718) 218-7067',
#    'distance': 2764.7945828233073},
#   {'id': '5m-TrbqMNnwJvOd7pAt6OA',
#    'alias': 'raclette-new-york',
#    'name': 'Raclette',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/r_PG8MC_RG-1b3QTQ9-Y7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raclette-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1421,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7289298, 'longitude': -73.980601},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '511 E 12th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['511 E 12th St', 'New York, NY 10009']},
#    'phone': '+19179977306',
#    'display_phone': '(917) 997-7306',
#    'distance': 2855.005616815332},
#   {'id': 'U2rFQLQ9zO9TMSkM5eNMcg',
#    'alias': 'hale-and-hearty-soups-new-york-17',
#    'name': 'Hale and Hearty Soups',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3WoLP4f7UrGpDFnHESakXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hale-and-hearty-soups-new-york-17?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 145,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7655177451256,
#     'longitude': -73.9655730995432},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '849 Lexington Ave',
#     'address2': 'Between 64th & 65th',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['849 Lexington Ave',
#      'Between 64th & 65th',
#      'New York, NY 10065']},
#    'phone': '+12125177600',
#    'display_phone': '(212) 517-7600',
#    'distance': 7104.590875925366},
#   {'id': 'ypGzLFySw_JBin1noTz2Nw',
#    'alias': 'hale-and-hearty-soups-new-york-14',
#    'name': 'Hale and Hearty Soups',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KUf3Bz9G2ukjSULcQZiF0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hale-and-hearty-soups-new-york-14?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 152,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.75191, 'longitude': -73.99019},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '462 7th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['462 7th Ave', 'New York, NY 10018']},
#    'phone': '+12129710605',
#    'display_phone': '(212) 971-0605',
#    'distance': 5188.98788280465},
#   {'id': 'q7U2GCMWIZxIqWeMDml0LQ',
#    'alias': 'pure-ktchn-new-york',
#    'name': 'Pure Ktchn',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kDc7Yka1kf0SJdoQYrYKIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pure-ktchn-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 338,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76053, 'longitude': -73.98992},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '352 West 46th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['352 West 46th St', 'New York, NY 10036']},
#    'phone': '+16467558502',
#    'display_phone': '(646) 755-8502',
#    'distance': 6124.467319676779},
#   {'id': 'uqBZzJXrsw0c7SJ2hcJ8HQ',
#    'alias': 'peasant-stock-new-york-2',
#    'name': 'Peasant Stock',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4k7okd48ll3Wb8_mf6d7yw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peasant-stock-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.718045, 'longitude': -73.988052},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '88 Essex St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['88 Essex St', 'New York, NY 10002']},
#    'phone': '+12122547687',
#    'display_phone': '(212) 254-7687',
#    'distance': 1496.5692637636969},
#   {'id': '1aD88qNRb08LGBkl84GQTA',
#    'alias': 'little-collins-new-york-3',
#    'name': 'Little Collins',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JIaDv0kxB4z8bIjItcGMHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-collins-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 869,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75233, 'longitude': -73.97353},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '708 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['708 3rd Ave', 'New York, NY 10017']},
#    'phone': '+12123081969',
#    'display_phone': '(212) 308-1969',
#    'distance': 5507.334764233976},
#   {'id': 'oXnJEg_AScyrR1lO4dnAfw',
#    'alias': 'the-wheelhouse-brooklyn-2',
#    'name': 'The Wheelhouse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3n8wWZt6isA7Y13-2MO_2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wheelhouse-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 292,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.700122, 'longitude': -73.924188},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '165 Wilson Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['165 Wilson Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17184839970',
#    'display_phone': '(718) 483-9970',
#    'distance': 5939.229558280646},
#   {'id': 'CEEUDBFxvUPKGlA65qJ8JQ',
#    'alias': 'beatnic-flatiron-new-york',
#    'name': 'Beatnic - Flatiron',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LCZBeVEd_3UsMRTEqfEx9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beatnic-flatiron-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 796,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7418636, 'longitude': -73.9929947},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '60 W 22nd St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 W 22nd St', 'New York, NY 10010']},
#    'phone': '+12122908000',
#    'display_phone': '(212) 290-8000',
#    'distance': 4051.052314640705},
#   {'id': 'mv8dMMzzrzalso3sYCP_QA',
#    'alias': 'café-luluc-brooklyn-2',
#    'name': 'CAFÉ LULUc',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-DzDbYF-Qf3jxYy7pr8Q4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-luluc-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1480,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68451, 'longitude': -73.99225},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '214 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['214 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17186253815',
#    'display_phone': '(718) 625-3815',
#    'distance': 2334.479697543251},
#   {'id': 'hgQxxv1WlmI7lMjLjp-2zA',
#    'alias': 'bus-stop-cafe-new-york',
#    'name': 'Bus Stop Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8jSTXWeYaQi4dQ0cSzy63A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bus-stop-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 228,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73702, 'longitude': -74.00595},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '597 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['597 Hudson St', 'New York, NY 10014']},
#    'phone': '+12122061100',
#    'display_phone': '(212) 206-1100',
#    'distance': 3646.8922985790914},
#   {'id': '9fG8-RRh1rzuCKN2TmF-QQ',
#    'alias': '5ive-spice-new-york-2',
#    'name': '5ive Spice',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GNDdH26bue1yTqVJEawx6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/5ive-spice-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 404,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.722598, 'longitude': -73.996272},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '227 Mulberry St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['227 Mulberry St', 'New York, NY 10012']},
#    'phone': '+19174092605',
#    'display_phone': '(917) 409-2605',
#    'distance': 1912.9622722449587},
#   {'id': 'xkvv0n7jbl4Ra3Vm_jfxaA',
#    'alias': 'upland-new-york',
#    'name': 'Upland',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aaHIBePLehwF_llzTIdg1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/upland-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1078,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7418912, 'longitude': -73.9846396},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '345 Park Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['345 Park Ave S', 'New York, NY 10010']},
#    'phone': '+12126861006',
#    'display_phone': '(212) 686-1006',
#    'distance': 4133.488189568971},
#   {'id': 'Lw044EfH1h3XhUhri3ExfA',
#    'alias': 'blackbarn-new-york',
#    'name': 'BLACKBARN',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Mu_4g5FWi-MoCBx1LMLKGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blackbarn-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 610,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7431036278527,
#     'longitude': -73.9870538457459},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '19 E 26th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 E 26th St', 'New York, NY 10010']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4231.664558058691},
#   {'id': 'xxE4sKeYJAuHdNm7WZlVOg',
#    'alias': 'banc-cafe-new-york-2',
#    'name': 'Banc Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BtQF2Xa2eAN6rnmkU0aY6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/banc-cafe-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 631,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7432632446289,
#     'longitude': -73.9795150756836},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '431 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['431 3rd Ave', 'New York, NY 10016']},
#    'phone': '+12122520146',
#    'display_phone': '(212) 252-0146',
#    'distance': 4377.172401428187},
#   {'id': 'CaYvCcWDITsD0J_4NL2TFg',
#    'alias': 'porcelain-ridgewood',
#    'name': 'Porcelain',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6fUB0L_4I6Dq4RcavrfdNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/porcelain-ridgewood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'panasian', 'title': 'Pan Asian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.702315, 'longitude': -73.901679},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '880 Woodward Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['880 Woodward Ave', 'Ridgewood, NY 11385']},
#    'phone': '+13474645267',
#    'display_phone': '(347) 464-5267',
#    'distance': 7820.925057565874},
#   {'id': 'S3qnPndTrNlgJnf_5oOrag',
#    'alias': 'secret-garden-brooklyn-4',
#    'name': 'Secret Garden',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/b2kGwU9zDc7ST-oj5MIaxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/secret-garden-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.683746, 'longitude': -73.935023},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '347 Lewis Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['347 Lewis Ave', 'Brooklyn, NY 11233']},
#    'phone': '+13472210719',
#    'display_phone': '(347) 221-0719',
#    'distance': 5547.65490461958},
#   {'id': 'CviK6c6BkxN_TTZahdvwyA',
#    'alias': 'zatar-brooklyn-2',
#    'name': 'Zatar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/q0F9ojqzJdqGCChfBGHGzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zatar-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 168,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'falafel', 'title': 'Falafel'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6980763644669,
#     'longitude': -73.9245712108767},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1294 Myrtle Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1294 Myrtle Ave', 'Brooklyn, NY 11221']},
#    'phone': '+13476277641',
#    'display_phone': '(347) 627-7641',
#    'distance': 5934.285649913043},
#   {'id': 'gtT9TZBNFn9xlnjup5Q8sg',
#    'alias': 'hale-and-hearty-soups-new-york-16',
#    'name': 'Hale and Hearty Soups',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/e7xzt5Kk-TZcmhICGRfFKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hale-and-hearty-soups-new-york-16?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74254, 'longitude': -74.005613},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '75 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 9th Ave', 'New York, NY 10011']},
#    'phone': '+12122552433',
#    'display_phone': '(212) 255-2433',
#    'distance': 4233.654128325823},
#   {'id': 'L7_MTRZyYp_i-cnH2CU4zQ',
#    'alias': 'dudleys-new-york',
#    'name': "Dudley's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_HlT0wpcR2XrW8l8SOvDeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dudleys-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 820,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71798, 'longitude': -73.99042},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '85 Orchard St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 Orchard St', 'New York, NY 10002']},
#    'phone': '+12129257355',
#    'display_phone': '(212) 925-7355',
#    'distance': 1427.0140817149313},
#   {'id': 'Ci8ZAbhfNc0sj3kwj6XRmw',
#    'alias': 'beatnic-rock-center-new-york',
#    'name': 'Beatnic - Rock Center',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nwt8an_TIa2dw0wj9Nhrxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beatnic-rock-center-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 473,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.757733, 'longitude': -73.97889},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1 Rockefeller Plz',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10020',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Rockefeller Plz', 'New York, NY 10020']},
#    'phone': '+12122908000',
#    'display_phone': '(212) 290-8000',
#    'distance': 5957.269785908656},
#   {'id': '8zTyhMq0ki83WoWrq4D0qw',
#    'alias': 'nón-lá-new-york-10',
#    'name': 'Nón Lá',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aD3W2mfsf6nvTOd6Uao9Yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/n%C3%B3n-l%C3%A1-new-york-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 95,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.725287, 'longitude': -73.987563},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '128 E 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['128 E 4th St', 'New York, NY 10003']},
#    'phone': '+19173883321',
#    'display_phone': '(917) 388-3321',
#    'distance': 2275.9046412673556},
#   {'id': 'PYmjoid5P-Mw8dkkKxZy6w',
#    'alias': 'harvest-kitchen-new-york',
#    'name': 'Harvest Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5ZT02qLPGXu55CluUJ4gJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harvest-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 197,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.777697, 'longitude': -73.978357},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '269 Columbus Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['269 Columbus Ave', 'New York, NY 10023']},
#    'phone': '+16468700810',
#    'display_phone': '(646) 870-0810',
#    'distance': 8159.531234626589},
#   {'id': 'ZxfXy-odIz_Xi1i9Uu00pg',
#    'alias': 'la-bonne-soupe-new-york-8',
#    'name': 'La Bonne Soupe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/G0gps1Q9Jx6eXIn-dRISrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-bonne-soupe-new-york-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 758,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7624, 'longitude': -73.97694},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '48 W 55th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['48 W 55th St', 'New York, NY 10019']},
#    'phone': '+12125867650',
#    'display_phone': '(212) 586-7650',
#    'distance': 6499.699710916821},
#   {'id': 'FwMyv3CVIxbI6ngodw7s3w',
#    'alias': 'panino-rustico-brooklyn-6',
#    'name': 'Panino Rustico',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HV7dtMKcsCNuCWor57lSrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/panino-rustico-brooklyn-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 492,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'wraps', 'title': 'Wraps'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.610494, 'longitude': -74.003153},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '8222 17th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8222 17th Ave', 'Brooklyn, NY 11214']},
#    'phone': '+17182366343',
#    'display_phone': '(718) 236-6343',
#    'distance': 10582.205773513151},
#   {'id': 'n1g_W6D4TQRPf0Rm2rMBTA',
#    'alias': 'hale-and-hearty-soups-brooklyn-2',
#    'name': 'Hale and Hearty Soups',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5ifR_e6GsJWRkz62mbqEXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hale-and-hearty-soups-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.6934653526478,
#     'longitude': -73.9857016759698},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2 MetroTech Center',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2 MetroTech Center', 'Brooklyn, NY 11201']},
#    'phone': '+13478895258',
#    'display_phone': '(347) 889-5258',
#    'distance': 1516.2323293006846},
#   {'id': 'emTmnLlesIwxRofQ34ntdA',
#    'alias': 'juliette-brooklyn',
#    'name': 'Juliette',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EjtIS4UiTlJoK_Imdv_H_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/juliette-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 938,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71702, 'longitude': -73.959077},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '135C N 5th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['135C N 5th St', 'Brooklyn, NY 11249']},
#    'phone': '+17183889222',
#    'display_phone': '(718) 388-9222',
#    'distance': 3235.2904566609345},
#   {'id': 'MHtbBc2np3sR7jiV9GphNg',
#    'alias': 'tribecas-kitchen-new-york',
#    'name': "Tribeca's Kitchen",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bn5YpHm-vpd85jXThFjJqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tribecas-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 552,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7162705535921,
#     'longitude': -74.0072225927912},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '200 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 Church St', 'New York, NY 10013']},
#    'phone': '+12122275100',
#    'display_phone': '(212) 227-5100',
#    'distance': 1623.7772210156222}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                     Restaurant          Type Price Rating           Address  \
# 0         The Original Soupman          Soup     $      4    259A W 55th St
# 1  The Soup Bowl of Park Slope          Soup     $      4       319 7th Ave
# 2  The Grey Dog - Union Square  Coffee & Tea    $$      4  90 University Pl
# 3                        Outro         Cafes    $$      4      816 Broadway
# 4                         Bite    Sandwiches    $$      4     211 E 14th St
#
#          Lat        Lng                                                url  \
# 0  40.765361 -73.983439  https://www.yelp.com/biz/the-original-soupman-...
# 1  40.667056 -73.981222  https://www.yelp.com/biz/the-soup-bowl-of-park...
# 2  40.733828 -73.993052  https://www.yelp.com/biz/the-grey-dog-union-sq...
# 3  40.732780 -73.991060  https://www.yelp.com/biz/outro-new-york?adjust...
# 4  40.733163 -73.986158  https://www.yelp.com/biz/bite-new-york-3?adjus...
#
#                        ID
# 0  HuSaFUqMDLbovpU-XbR9UA
# 1  lR58h9jeoDfy_9jVOqTDJg
# 2  VCqNjupCWZ5INzOcyBMJSg
# 3  IiLLntICUim7YREkIBU7lA
# 4  PpxJsItHTF6sDAK6XnDJ9w

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"soup and salad","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': 'MHtbBc2np3sR7jiV9GphNg',
#    'alias': 'tribecas-kitchen-new-york',
#    'name': "Tribeca's Kitchen",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bn5YpHm-vpd85jXThFjJqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tribecas-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 552,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7162705535921,
#     'longitude': -74.0072225927912},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '200 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 Church St', 'New York, NY 10013']},
#    'phone': '+12122275100',
#    'display_phone': '(212) 227-5100',
#    'distance': 1623.7772210156222},
#   {'id': 'nKpHJSu7xbGyerOjfLRzfA',
#    'alias': 'gotan-tribeca-new-york-2',
#    'name': 'Gotan - Tribeca',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1BcKjEDffC-wjX51u-sT3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gotan-tribeca-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 393,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.719255, 'longitude': -74.006607},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '130 Franklin St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['130 Franklin St', 'New York, NY 10013']},
#    'phone': '+12124315200',
#    'display_phone': '(212) 431-5200',
#    'distance': 1853.4515251009466},
#   {'id': 'scjoZtbTQHi35xhAlUm2iQ',
#    'alias': 'l-adresse-new-york',
#    'name': "L'ADRESSE",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sITsMiTFxdfg3ltczk1bxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-adresse-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 682,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75403, 'longitude': -73.98539},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '1065 Ave Of The Americas',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1065 Ave Of The Americas', 'New York, NY 10018']},
#    'phone': '+12122212510',
#    'display_phone': '(212) 221-2510',
#    'distance': 5442.406496486924},
#   {'id': 'uoT2_Wrt1noD6kZOID7tUg',
#    'alias': 'jane-new-york-2',
#    'name': 'Jane',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fL4CNvQYiUmE9HKbOd1AcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jane-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3210,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7273779, 'longitude': -74.00025},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '100 W Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100 W Houston St', 'New York, NY 10012']},
#    'phone': '+12122547000',
#    'display_phone': '(212) 254-7000',
#    'distance': 2489.9758210239006},
#   {'id': 'o7kcieG51OlB6CNTkxGeaQ',
#    'alias': 'molto-stretto-brooklyn',
#    'name': 'Molto Stretto',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7nsGFXd1X0Atw_k_KH9RMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/molto-stretto-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.68938789694508,
#     'longitude': -73.98601831586906},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '42 Hoyt St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 Hoyt St', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1916.896026600202},
#   {'id': 'ml5hBBDsEILy9WsTQyyV-Q',
#    'alias': 'b-cup-café-new-york-5',
#    'name': 'B Cup Café',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-Ow6irDxjC5gOazKhJ2rAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b-cup-caf%C3%A9-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 384,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.728708, 'longitude': -73.978827},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '212 Ave B',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['212 Ave B', 'New York, NY 10009']},
#    'phone': '+12122284808',
#    'display_phone': '(212) 228-4808',
#    'distance': 2896.9287307264567},
#   {'id': 'G18cPTEjuxXx957dGYBDAQ',
#    'alias': 'marlow-and-sons-brooklyn-2',
#    'name': 'Marlow & Sons',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3N2dy6_fkiiqQatHUfY3rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marlow-and-sons-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 527,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7106126934043,
#     'longitude': -73.9658814005443},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '81 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81 Broadway', 'Brooklyn, NY 11249']},
#    'phone': '+17183841441',
#    'display_phone': '(718) 384-1441',
#    'distance': 2462.8203943048193},
#   {'id': 'ehyZHDeH7d1KOJLrOHfnEw',
#    'alias': 'melt-shop-new-york-7',
#    'name': 'Melt Shop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ef_iuV03-J_h1PrqgfybqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/melt-shop-new-york-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 378,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7097319537713,
#     'longitude': -74.0065573416641},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '111 Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 Fulton St', 'New York, NY 10038']},
#    'phone': '+16467417910',
#    'display_phone': '(646) 741-7910',
#    'distance': 1138.3740607099403},
#   {'id': 'c8_1XxMgFLnYBLkBEL-PdA',
#    'alias': 'brookside-market-sunnyside',
#    'name': 'Brookside Market',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-LEfoOOfFMeLLEInj_IdqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brookside-market-sunnyside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 107,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7437641, 'longitude': -73.9208344},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '43-15 Queens Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43-15 Queens Blvd', 'Sunnyside, NY 11104']},
#    'phone': '+17188061902',
#    'display_phone': '(718) 806-1902',
#    'distance': 7515.017986231929},
#   {'id': 'HodL0fXoF08C3Ir-kLeTtw',
#    'alias': 'forma-pasta-factory-brooklyn',
#    'name': 'Forma Pasta Factory',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7CWJUVmPmHFlo0CrXqPKGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/forma-pasta-factory-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 323,
#    'categories': [{'alias': 'pastashops', 'title': 'Pasta Shops'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72371, 'longitude': -73.95157},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '14 Bedford Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 Bedford Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183492009',
#    'display_phone': '(718) 349-2009',
#    'distance': 4141.117801995315},
#   {'id': 'BqKuDTR5UfzaXA39_wH3Yg',
#    'alias': 'fresh-from-hell-new-york',
#    'name': 'Fresh From Hell',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1FWPhfOSUkhZ2B4T6Iexfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fresh-from-hell-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 289,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'acaibowls', 'title': 'Acai Bowls'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7608265, 'longitude': -73.9889803},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '326 W 47th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['326 W 47th St', 'New York, NY 10036']},
#    'phone': '+12129564355',
#    'display_phone': '(212) 956-4355',
#    'distance': 6174.399625112292},
#   {'id': '4b43TOXpskBPZqQzbKkwDQ',
#    'alias': 'le-botaniste-new-york-4',
#    'name': 'Le Botaniste',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dBmJJzmLbn6kkVhFpgduPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-botaniste-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 174,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7204278, 'longitude': -74.0002028},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '127 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['127 Grand St', 'New York, NY 10013']},
#    'phone': '+16468707770',
#    'display_phone': '(646) 870-7770',
#    'distance': 1746.4854595430756},
#   {'id': 'V67wFDfxZyZ_8p74qBlv8Q',
#    'alias': 'sweetgreen-brooklyn-2',
#    'name': 'sweetgreen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6y9WUlvvhYTvLlw__kUyrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweetgreen-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 258,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7158037924556, 'longitude': -73.9591804},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '162 N 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 N 4th St', 'Brooklyn, NY 11211']},
#    'phone': '+13479873863',
#    'display_phone': '(347) 987-3863',
#    'distance': 3175.8098532304707},
#   {'id': 'jzQNE09rRKz8Ou-bEdEY1Q',
#    'alias': 'the-grey-dog-nolita-new-york-3',
#    'name': 'The Grey Dog - Nolita',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pDVxVWnSFuFC1JmdLTYzPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grey-dog-nolita-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 632,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7229699, 'longitude': -73.99576},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '244 Mulberry St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['244 Mulberry St', 'New York, NY 10012']},
#    'phone': '+12129661060',
#    'display_phone': '(212) 966-1060',
#    'distance': 1949.6090161894615},
#   {'id': '6XlC2KRc6ISCzV8zuavQMQ',
#    'alias': 'freshmix-salads-wraps-and-bowls-fresh-meadows-2',
#    'name': 'Freshmix Salads, Wraps and Bowls',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dfhE4qaBhAXwlqxXxLWG7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/freshmix-salads-wraps-and-bowls-fresh-meadows-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'wraps', 'title': 'Wraps'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71985102585194,
#     'longitude': -73.81006479999999},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '15315 Union Tpke',
#     'address2': None,
#     'address3': '',
#     'city': 'Fresh Meadows',
#     'zip_code': '11367',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15315 Union Tpke', 'Fresh Meadows, NY 11367']},
#    'phone': '+17183802267',
#    'display_phone': '(718) 380-2267',
#    'distance': 15610.02324633626},
#   {'id': '0Bm2vjJW5Fw7_Maer6kDUw',
#    'alias': 'melt-shop-new-york-3',
#    'name': 'Melt Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ojpaJSMXH3gIreqtYdMNJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/melt-shop-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 613,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76091344676272,
#     'longitude': -73.9825650029376},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '135 W 50th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['135 W 50th St', 'New York, NY 10019']},
#    'phone': '+12129743423',
#    'display_phone': '(212) 974-3423',
#    'distance': 6246.480932630761},
#   {'id': 'nZC3WQp6XrmIYIoZSa6r3Q',
#    'alias': 'olives-new-york-3',
#    'name': "Olive's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rZKfGqTWQKZJYRXJ66yNlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olives-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 216,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72662, 'longitude': -74.00241},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '191 Prince St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['191 Prince St', 'New York, NY 10012']},
#    'phone': '+12129410111',
#    'display_phone': '(212) 941-0111',
#    'distance': 2455.955928100161},
#   {'id': 'xTnivXEdEtXrnhp-z4JGvg',
#    'alias': 'la-parisienne-new-york-5',
#    'name': 'La Parisienne',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ywbWsBIM-z7OHvhMoHUg5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-parisienne-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 608,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70961, 'longitude': -74.0093799},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '9 Maiden Ln',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Maiden Ln', 'New York, NY 10038']},
#    'phone': '+16467564911',
#    'display_phone': '(646) 756-4911',
#    'distance': 1350.1089630689858},
#   {'id': 'rO4-ytxRRN98GMk2gSXxjQ',
#    'alias': 'honeygrow-hoboken',
#    'name': 'honeygrow',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qc2OBKrA7aFgscNBZO4X8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/honeygrow-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 342,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73827000147528,
#     'longitude': -74.03094254869448},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '120 Washington St',
#     'address2': None,
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['120 Washington St', 'Hoboken, NJ 07030']},
#    'phone': '+12015338089',
#    'display_phone': '(201) 533-8089',
#    'distance': 4781.371061237488},
#   {'id': 'xxgtwN5sxqiGWMJ03dZQcg',
#    'alias': 'soup-n-burger-brooklyn-2',
#    'name': 'Soup N Burger',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/quYCfOk_ahzjtmftzw7PTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soup-n-burger-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 351,
#    'categories': [{'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.583572, 'longitude': -73.950016},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1825 Emmons Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11235',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1825 Emmons Ave', 'Brooklyn, NY 11235']},
#    'phone': '+17185136939',
#    'display_phone': '(718) 513-6939',
#    'distance': 14057.101948904141},
#   {'id': 'UXVDyIzmO5kmJnlv-HDXLg',
#    'alias': 'cafeteria-new-york',
#    'name': 'Cafeteria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/b75csM4Dx4KSccjwETPC4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafeteria-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3402,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.740567590122, 'longitude': -73.9980747946},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '119 7th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['119 7th Ave', 'New York, NY 10011']},
#    'phone': '+12124141717',
#    'display_phone': '(212) 414-1717',
#    'distance': 3918.4448613860486},
#   {'id': '56qlj1cYlqNzmG0xllGg-w',
#    'alias': 'westville-dumbo-brooklyn',
#    'name': 'Westville Dumbo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/y9agcxhbRPYMNzsk4b9Peg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/westville-dumbo-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 345,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70208865020039,
#     'longitude': -73.9894541379247},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '81 Washington St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81 Washington St', 'Brooklyn, NY 11201']},
#    'phone': '+17186185699',
#    'display_phone': '(718) 618-5699',
#    'distance': 552.8717360375787},
#   {'id': 'gxCnsgWQS_79sMDHpmeHzw',
#    'alias': 'good-stock-new-york-3',
#    'name': 'Good Stock',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pS0DdAamp4tyuFiJAo9avA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/good-stock-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73033, 'longitude': -74.00327},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '31 Carmine St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31 Carmine St', 'New York, NY 10014']},
#    'phone': '+16466495163',
#    'display_phone': '(646) 649-5163',
#    'distance': 2870.914638515903},
#   {'id': 'S9DvhHSe9V7cJaLQ5m5SjA',
#    'alias': 'good-health-cafe-new-york-4',
#    'name': 'Good Health Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JuHi6LTlO6L7LaVmCWb_lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/good-health-cafe-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 297,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'wraps', 'title': 'Wraps'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76948, 'longitude': -73.95499},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1435 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1435 1st Ave', 'New York, NY 10021']},
#    'phone': '+12125179898',
#    'display_phone': '(212) 517-9898',
#    'distance': 7850.9810528023545},
#   {'id': 'C-8mGN7lt5rIraO5n-15ug',
#    'alias': 'the-smith-new-york-2',
#    'name': 'The Smith',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gih2UqttrnFYeoHpMEWYow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-smith-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2777,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.755165, 'longitude': -73.967868},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '956 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['956 2nd Ave', 'New York, NY 10022']},
#    'phone': '+12126442700',
#    'display_phone': '(212) 644-2700',
#    'distance': 5960.16818302934},
#   {'id': 'd-Q0sBnYh1z99QlYD8QiCQ',
#    'alias': 'sweetgreen-new-york-4',
#    'name': 'sweetgreen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uuGujxt0c6sMGMUMJOX8ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweetgreen-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 267,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7210635428336,
#     'longitude': -73.9972511652099},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '100 Kenmare St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100 Kenmare St', 'New York, NY 10012']},
#    'phone': '+16469645012',
#    'display_phone': '(646) 964-5012',
#    'distance': 1754.5188115948315},
#   {'id': 'UB1mGugr1pvgUUP1eTNXrg',
#    'alias': 'stone-bridge-pizza-and-salad-new-york',
#    'name': 'Stone Bridge Pizza & Salad',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yfY3OA1Zd1GWBnbeZoWB8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stone-bridge-pizza-and-salad-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 289,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75225, 'longitude': -73.98061},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '16 E 41st St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['16 E 41st St', 'New York, NY 10017']},
#    'phone': '+16467915690',
#    'display_phone': '(646) 791-5690',
#    'distance': 5333.518247518763},
#   {'id': 'j0n_poMVZnODYOFviLbh0Q',
#    'alias': 'taim-west-village-new-york',
#    'name': 'Taim West Village',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IbBGoqAgy6RpB1FSvxH8yQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taim-west-village-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1539,
#    'categories': [{'alias': 'falafel', 'title': 'Falafel'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.736002376347,
#     'longitude': -74.0019588366439},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '222 Waverly Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['222 Waverly Pl', 'New York, NY 10014']},
#    'phone': '+12126911287',
#    'display_phone': '(212) 691-1287',
#    'distance': 3458.7033927339817},
#   {'id': 'oqVG2LsTwvRzgJxId5pqiw',
#    'alias': 'dar-525-brooklyn',
#    'name': 'Dar 525',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bqhE4obRVHOuvof38nMj7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dar-525-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 523,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'kebab', 'title': 'Kebab'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.711266, 'longitude': -73.950317},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '525 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['525 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+13474220401',
#    'display_phone': '(347) 422-0401',
#    'distance': 3762.66929981729},
#   {'id': 'mv4A3Yl90ZLONO03ksqRrg',
#    'alias': 'ix-restaurant-brooklyn-3',
#    'name': 'Ix Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gbpNfFJfJhWVXtbb6iWotA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ix-restaurant-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 167,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6609148441096,
#     'longitude': -73.9613892462263},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '43 Lincoln Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11225',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43 Lincoln Rd', 'Brooklyn, NY 11225']},
#    'phone': '+13475336920',
#    'display_phone': '(347) 533-6920',
#    'distance': 5675.861543925705},
#   {'id': 'DE0ROwygh-86i4s-WLp8wQ',
#    'alias': 'maman-soho-new-york',
#    'name': 'Maman Soho',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nUj5B96Xh73Y2aGmuvDr6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maman-soho-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 577,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72028, 'longitude': -73.9984},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '239 Centre St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['239 Centre St', 'New York, NY 10013']},
#    'phone': '+12122260700',
#    'display_phone': '(212) 226-0700',
#    'distance': 1685.4911071554986},
#   {'id': 'gjJiJ5yHqiEe3sFn_v-5JA',
#    'alias': 'c-and-b-new-york',
#    'name': 'C&B',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/V0D6pOIdIxSOkuGCmWY8GQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/c-and-b-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 231,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7252271901335,
#     'longitude': -73.9816302970189},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '178 E 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['178 E 7th St', 'New York, NY 10009']},
#    'phone': '+12126742985',
#    'display_phone': '(212) 674-2985',
#    'distance': 2444.9247777919436},
#   {'id': 'JQI9jo2g_OIxkMIumpMtXQ',
#    'alias': 'le-pain-quotidien-new-york-158',
#    'name': 'Le Pain Quotidien',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6tV4sV2r8F1iYY3X1ReiqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-pain-quotidien-new-york-158?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 239,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7215006, 'longitude': -74.001552},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '100 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100 Grand St', 'New York, NY 10013']},
#    'phone': '+12126259009',
#    'display_phone': '(212) 625-9009',
#    'distance': 1887.231325932069},
#   {'id': 'lXGCo-K7eftxRT_6E59-Iw',
#    'alias': 'union-square-cafe-new-york-8',
#    'name': 'Union Square Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3mi2XuWW6Moh6VGe4fHr-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/union-square-cafe-new-york-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1251,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.737772, 'longitude': -73.987876},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '101 E 19th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['101 E 19th St', 'New York, NY 10003']},
#    'phone': '+12122434020',
#    'display_phone': '(212) 243-4020',
#    'distance': 3635.0627554502266},
#   {'id': 'XSoFi1TZ5fUznmDstJNuaw',
#    'alias': 'bonsignour-new-york',
#    'name': 'Bonsignour',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/z7J-oiCVl77VX4ygGnbppQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bonsignour-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 91,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73832, 'longitude': -74.00436},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '35 Jane St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35 Jane St', 'New York, NY 10014']},
#    'phone': '+12122299700',
#    'display_phone': '(212) 229-9700',
#    'distance': 3754.2597497594315},
#   {'id': 'WJS06XxRdc6DD1s4LWE9HA',
#    'alias': 'fish-cheeks-new-york',
#    'name': 'Fish Cheeks',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pqupe3fe52869QQ23KkiBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fish-cheeks-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 866,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7258, 'longitude': -73.9927},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '55 Bond St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Bond St', 'New York, NY 10012']},
#    'phone': '+12126772223',
#    'display_phone': '(212) 677-2223',
#    'distance': 2258.7720584764224},
#   {'id': 'flcy6dNr4s12PTv6VtBK9Q',
#    'alias': 'lēna-new-york-8',
#    'name': 'LĒNA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kNWzdvKWch5VRL4LOdujnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l%C4%93na-new-york-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 184,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.719135, 'longitude': -73.991758},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '137 Eldridge St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['137 Eldridge St', 'New York, NY 10002']},
#    'phone': '+13479351897',
#    'display_phone': '(347) 935-1897',
#    'distance': 1537.1958876609465},
#   {'id': 'mU23NlQfn1R9OhA6WMe_xg',
#    'alias': 'breads-bakery-new-york',
#    'name': 'Breads Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mDaSWYX8hEV0eNGXJSDhVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/breads-bakery-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1080,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73661, 'longitude': -73.99181},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '18 E 16th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18 E 16th St', 'New York, NY 10003']},
#    'phone': '+12126332253',
#    'display_phone': '(212) 633-2253',
#    'distance': 3470.824425100059},
#   {'id': 'rvoyaPumkhL5FA2zTqk13w',
#    'alias': 'sandwich-house-new-york',
#    'name': 'Sandwich House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_mpM9K_yh8Z5dDMD6r3sVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sandwich-house-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 270,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71096, 'longitude': -74.0077699},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '17 Ann St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 Ann St', 'New York, NY 10038']},
#    'phone': '+12125666886',
#    'display_phone': '(212) 566-6886',
#    'distance': 1288.0225679047148},
#   {'id': 'RKAK9AuzKR7K36ABcXPjTA',
#    'alias': 'ccs-cafe-new-york-2',
#    'name': "CC's Cafe",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ReA5ahTHehAxnSaQNWK9XA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ccs-cafe-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 151,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71166, 'longitude': -73.99452},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '41 Monroe St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41 Monroe St', 'New York, NY 10002']},
#    'phone': '+12125711060',
#    'display_phone': '(212) 571-1060',
#    'distance': 695.0211568685693},
#   {'id': 'KXD44wWmrGf7mzyyr0bikw',
#    'alias': 'p-s-kitchen-new-york-3',
#    'name': 'P.S. Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QcLe9hoAxhAQsh7fR0oqpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/p-s-kitchen-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 502,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.760706, 'longitude': -73.986627},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '246 W 48th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['246 W 48th St', 'New York, NY 10036']},
#    'phone': '+12126517247',
#    'display_phone': '(212) 651-7247',
#    'distance': 6178.609175008067},
#   {'id': 'IVjpsmmsgc42k9K2RZR3Qg',
#    'alias': 'le-fond-brooklyn',
#    'name': 'Le Fond',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uljNBGtir-KG4rLDgoWdhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-fond-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 156,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7258415222168,
#     'longitude': -73.9511032104492},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '105 Norman Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['105 Norman Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183896859',
#    'display_phone': '(718) 389-6859',
#    'distance': 4288.698320926473},
#   {'id': 'dp2gh3PsxKBiqVVxKwyTHw',
#    'alias': 'au-jus-new-york',
#    'name': 'Au Jus',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uipj68eGAdiZrz960PLcbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/au-jus-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 238,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7803856796944,
#     'longitude': -73.9467066627937},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1762 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1762 1st Ave', 'New York, NY 10128']},
#    'phone': '+16464763580',
#    'display_phone': '(646) 476-3580',
#    'distance': 9247.235333745002},
#   {'id': 'qYqe-kArMUebiEvxUPUlVg',
#    'alias': 'the-picnic-basket-new-york',
#    'name': 'The Picnic Basket',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5EzyWwNAy5eopXi4hmc-9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-picnic-basket-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 450,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7516246, 'longitude': -73.9858858},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '65 W 37th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['65 W 37th St', 'New York, NY 10018']},
#    'phone': '+12123822627',
#    'display_phone': '(212) 382-2627',
#    'distance': 5183.586856771757},
#   {'id': 'QEY6X80_WXLmCvpOxphzxA',
#    'alias': 'smør-new-york',
#    'name': 'Smør',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UlrthhGONEYPmjqUkXouVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sm%C3%B8r-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'scandinavian', 'title': 'Scandinavian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72935222162667,
#     'longitude': -73.98166426266144},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '441 E 12th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['441 E 12th St', 'New York, NY 10009']},
#    'phone': '+16464788391',
#    'display_phone': '(646) 478-8391',
#    'distance': 2863.527968633293},
#   {'id': 'qcMpRNrnS6gggYv28dgm_A',
#    'alias': 'belle-reve-new-york',
#    'name': 'Belle Reve',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/amr5FItJwRG-4tk_K4y8ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/belle-reve-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 179,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7194897, 'longitude': -74.0041143883606},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '305 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['305 Church St', 'New York, NY 10013']},
#    'phone': '+12126800101',
#    'display_phone': '(212) 680-0101',
#    'distance': 1767.5292711655588},
#   {'id': '3idAtiEXe_XfTcPoZC_DcQ',
#    'alias': 'westville-east-new-york-3',
#    'name': 'Westville East',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lNktPIQQ_HEhQMEC1IIj4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/westville-east-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1071,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72847, 'longitude': -73.98213},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '173 Ave A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['173 Ave A', 'New York, NY 10009']},
#    'phone': '+12126772033',
#    'display_phone': '(212) 677-2033',
#    'distance': 2757.8062456985617},
#   {'id': 'zBf-m72ATTPTey-_9vu3Yw',
#    'alias': 'peacefood-cafe-new-york-5',
#    'name': 'Peacefood Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dAjhNU7JB3s4KIZmMtwSOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peacefood-cafe-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1345,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.785326, 'longitude': -73.97713},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '460 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['460 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12123622266',
#    'display_phone': '(212) 362-2266',
#    'distance': 8999.278996359702},
#   {'id': 'uuHujhrkVQdS8XVSGWW2mA',
#    'alias': 'cebu-bar-and-bistro-brooklyn-2',
#    'name': 'Cebu Bar & Bistro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DzJIyK2yJq1X_Zi2yVFT0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cebu-bar-and-bistro-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 766,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.62186, 'longitude': -74.031383},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '8801 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8801 3rd Ave', 'Brooklyn, NY 11209']},
#    'phone': '+17184925095',
#    'display_phone': '(718) 492-5095',
#    'distance': 9806.582563940117},
#   {'id': '_2eGAao4W3ww4vNB3RQiBA',
#    'alias': 'salad-box-new-york-4',
#    'name': 'Salad Box',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/szVhmueuTYt1BFkmiiYUMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salad-box-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 74,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71328, 'longitude': -74.00958},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '44 Park Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['44 Park Pl', 'New York, NY 10007']},
#    'phone': '+16095294969',
#    'display_phone': '(609) 529-4969',
#    'distance': 1549.273874230449}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#           Restaurant                Type Price Rating  \
# 0  Tribeca's Kitchen      American (New)    $$      4
# 1    Gotan - Tribeca               Cafes    $$      4
# 2          L'ADRESSE      American (New)   $$$      4
# 3               Jane  Breakfast & Brunch    $$      4
# 4      Molto Stretto          Sandwiches
#
#                     Address        Lat        Lng  \
# 0             200 Church St  40.716271 -74.007223
# 1           130 Franklin St  40.719255 -74.006607
# 2  1065 Ave Of The Americas  40.754030 -73.985390
# 3          100 W Houston St  40.727378 -74.000250
# 4                42 Hoyt St  40.689388 -73.986018
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/tribecas-kitchen-new-...  MHtbBc2np3sR7jiV9GphNg
# 1  https://www.yelp.com/biz/gotan-tribeca-new-yor...  nKpHJSu7xbGyerOjfLRzfA
# 2  https://www.yelp.com/biz/l-adresse-new-york?ad...  scjoZtbTQHi35xhAlUm2iQ
# 3  https://www.yelp.com/biz/jane-new-york-2?adjus...  uoT2_Wrt1noD6kZOID7tUg
# 4

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"soup and salad","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': 'zBf-m72ATTPTey-_9vu3Yw',
#    'alias': 'peacefood-cafe-new-york-5',
#    'name': 'Peacefood Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dAjhNU7JB3s4KIZmMtwSOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peacefood-cafe-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1345,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.785326, 'longitude': -73.97713},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '460 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['460 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12123622266',
#    'display_phone': '(212) 362-2266',
#    'distance': 8999.278996359702},
#   {'id': 'uuHujhrkVQdS8XVSGWW2mA',
#    'alias': 'cebu-bar-and-bistro-brooklyn-2',
#    'name': 'Cebu Bar & Bistro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DzJIyK2yJq1X_Zi2yVFT0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cebu-bar-and-bistro-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 766,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.62186, 'longitude': -74.031383},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '8801 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8801 3rd Ave', 'Brooklyn, NY 11209']},
#    'phone': '+17184925095',
#    'display_phone': '(718) 492-5095',
#    'distance': 9806.582563940117},
#   {'id': '_2eGAao4W3ww4vNB3RQiBA',
#    'alias': 'salad-box-new-york-4',
#    'name': 'Salad Box',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/szVhmueuTYt1BFkmiiYUMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salad-box-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 74,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71328, 'longitude': -74.00958},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '44 Park Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['44 Park Pl', 'New York, NY 10007']},
#    'phone': '+16095294969',
#    'display_phone': '(609) 529-4969',
#    'distance': 1549.273874230449},
#   {'id': 'g5f6p9jfzB30Mhcu6d5OWA',
#    'alias': 'petite-boucherie-new-york',
#    'name': 'Petite Boucherie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0j89ZVH23hB-RNWgkOZfNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/petite-boucherie-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 168,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73382, 'longitude': -74.00042},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '14 Christopher St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 Christopher St', 'New York, NY 10014']},
#    'phone': '+16467564145',
#    'display_phone': '(646) 756-4145',
#    'distance': 3198.5619536252693},
#   {'id': 'De_10VF2CrC2moWaPA81mg',
#    'alias': 'just-salad-brooklyn',
#    'name': 'Just Salad',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p6aQE5rjq2E8N684uBYG0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/just-salad-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 261,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'wraps', 'title': 'Wraps'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6694291366086,
#     'longitude': -73.9794939539662},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '252 7th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['252 7th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+18666733757',
#    'display_phone': '(866) 673-3757',
#    'distance': 4194.660361913647},
#   {'id': 'gjIctg7P18f6UocGVW2IMQ',
#    'alias': 'bite-new-york-6',
#    'name': 'Bite',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wG24AhAoy1giNDdq_kLqbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bite-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 332,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74189, 'longitude': -73.99305},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '62 W 22nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['62 W 22nd St', 'New York, NY 10010']},
#    'phone': '+16466492768',
#    'display_phone': '(646) 649-2768',
#    'distance': 4057.224004495941},
#   {'id': 'LF2_slTY37P0Ua8vI4Hr5g',
#    'alias': 'bistro-les-amis-new-york',
#    'name': 'Bistro Les Amis',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fKtlMVwS9M8rGUw5fBgWHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistro-les-amis-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 402,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.724678, 'longitude': -74.002624},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '180 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['180 Spring St', 'New York, NY 10012']},
#    'phone': '+12122268645',
#    'display_phone': '(212) 226-8645',
#    'distance': 2250.934111586926},
#   {'id': 'gls8Eii-vgwKScOCNQWz9w',
#    'alias': 'cafetal-social-club-new-york',
#    'name': 'Cafetal Social Club',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uBmAxFuvo25LMDraBOdtOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafetal-social-club-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 136,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.724308, 'longitude': -73.994457},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '285 Mott St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['285 Mott St', 'New York, NY 10012']},
#    'phone': '+12129661259',
#    'display_phone': '(212) 966-1259',
#    'distance': 2097.528072739415},
#   {'id': 'WlhkVLite9TQrtnzYLiO4Q',
#    'alias': 'lucys-vietnamese-williamsburg-brooklyn',
#    'name': "Lucy's Vietnamese Williamsburg",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eV7rx5S2xhkX2EgdXATOmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lucys-vietnamese-williamsburg-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.718903, 'longitude': -73.958957},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '112 Berry St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['112 Berry St', 'Brooklyn, NY 11249']},
#    'phone': '+13479161127',
#    'display_phone': '(347) 916-1127',
#    'distance': 3331.7613661130067},
#   {'id': 'szM1B9tHQixNsmTZTfKoWA',
#    'alias': 'lincoln-station-brooklyn',
#    'name': 'Lincoln Station',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ReC-t1q7zX_Limv9eznVqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lincoln-station-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 285,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6726102, 'longitude': -73.9627163},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '409 Lincoln Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['409 Lincoln Pl', 'Brooklyn, NY 11238']},
#    'phone': '+17183992211',
#    'display_phone': '(718) 399-2211',
#    'distance': 4518.677712488417},
#   {'id': 'd8zSYpArh4oXpxeJWNA4Pg',
#    'alias': 'nish-nush-new-york',
#    'name': 'Nish Nush',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OMGpw5j96GX414mh61Lxxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nish-nush-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 737,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'moroccan', 'title': 'Moroccan'},
#     {'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.715688, 'longitude': -74.007695},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '88 Reade St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['88 Reade St', 'New York, NY 10013']},
#    'phone': '+12129641318',
#    'display_phone': '(212) 964-1318',
#    'distance': 1604.1440616130528},
#   {'id': '8M_0cxAChoXl7Ls9YkWJlg',
#    'alias': 'xe-may-sandwich-shop-new-york',
#    'name': 'Xe May Sandwich Shop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/u07WeKmygCmLFBrXff4k_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/xe-may-sandwich-shop-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 640,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7272, 'longitude': -73.98493},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '96 Saint Marks Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['96 Saint Marks Pl', 'New York, NY 10009']},
#    'phone': '+12123881688',
#    'display_phone': '(212) 388-1688',
#    'distance': 2543.4269139485905},
#   {'id': 'qusZ-K5tzM1EyOa1IEWCHA',
#    'alias': 'nourish-brooklyn-4',
#    'name': 'Nourish',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vu0P_ORyUMI-Sz5xwOacuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nourish-brooklyn-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 288,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.677941, 'longitude': -73.968455},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '637A Vanderbilt Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['637A Vanderbilt Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17187893981',
#    'display_phone': '(718) 789-3981',
#    'distance': 3752.4722090267096},
#   {'id': 'j5Me3YSKfaYHoLu_74SMjA',
#    'alias': 'pret-a-manger-new-york-64',
#    'name': 'Pret A Manger',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/udvK5rVz-u9yjxN_KVTQ_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pret-a-manger-new-york-64?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.715924, 'longitude': -74.005122},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '319 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['319 Broadway', 'New York, NY 10007']},
#    'phone': '+12129641614',
#    'display_phone': '(212) 964-1614',
#    'distance': 1480.142042735936},
#   {'id': 'wwYJlPAg4_DV_DihANcuOw',
#    'alias': 'estuary-new-york-2',
#    'name': 'Estuary',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vwQ2qdgycjJqtW84R0W_9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/estuary-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6932355, 'longitude': -74.0007940774},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '159 Bridge Park Dr',
#     'address2': '',
#     'address3': 'Brooklyn Bridge Park',
#     'city': 'New York',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['159 Bridge Park Dr',
#      'Brooklyn Bridge Park',
#      'New York, NY 11201']},
#    'phone': '+17185216744',
#    'display_phone': '(718) 521-6744',
#    'distance': 1464.057918260259},
#   {'id': 'c3eMI4_o4dPDDhPV_ibBYQ',
#    'alias': 'ess-a-bagel-new-york',
#    'name': 'Ess-a-Bagel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KJliJ0mJDcTGVi36f30L7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ess-a-bagel-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3788,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.756300559255,
#     'longitude': -73.9703701025162},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '831 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['831 3rd Ave', 'New York, NY 10022']},
#    'phone': '+12129801010',
#    'display_phone': '(212) 980-1010',
#    'distance': 6003.433036669106},
#   {'id': 'LvKQJRmHRp9rPaZbB8UnmQ',
#    'alias': 'fresh-eats-café-brooklyn',
#    'name': 'Fresh Eats Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CJTtRPuCaSyIK61GeiJt4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fresh-eats-caf%C3%A9-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.63173, 'longitude': -74.02213},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '478 72nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['478 72nd St', 'Brooklyn, NY 11209']},
#    'phone': '+17183335758',
#    'display_phone': '(718) 333-5758',
#    'distance': 8528.99859206547},
#   {'id': '6uPzZapAHWEalyJdkjBqKw',
#    'alias': 'blank-slate-coffee-kitchen-midtown-new-york-2',
#    'name': 'Blank Slate Coffee + Kitchen Midtown',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/j-HTfV6_ztGOmo0DmMp23A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blank-slate-coffee-kitchen-midtown-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 125,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75485, 'longitude': -73.96878},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '941 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['941 2nd Ave', 'New York, NY 10022']},
#    'phone': '+19179701188',
#    'display_phone': '(917) 970-1188',
#    'distance': 5902.40203781674},
#   {'id': 'sy24z1YfzTpLuj59_kovDA',
#    'alias': 'yoongkao-thai-dining-new-york',
#    'name': 'Yoongkao Thai Dining',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eYBU2ieFcuvPVqUc0ZVQ5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yoongkao-thai-dining-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74505, 'longitude': -73.97591},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '625 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['625 2nd Ave', 'New York, NY 10016']},
#    'phone': '+16466698424',
#    'display_phone': '(646) 669-8424',
#    'distance': 4669.354782395737},
#   {'id': 'P91q647NhgyIf7nLc4wYsQ',
#    'alias': 'frankels-delicatessen-brooklyn',
#    'name': "Frankel's Delicatessen",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/P2ctJ8B6CHUr0S4aBJ4LbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frankels-delicatessen-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 268,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.723826, 'longitude': -73.9509979},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '631 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['631 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183892302',
#    'display_phone': '(718) 389-2302',
#    'distance': 4185.370971697787},
#   {'id': 'mMuAsPSy2T56j0ENSTPL9w',
#    'alias': 'cava-new-york-4',
#    'name': 'CAVA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yPTYHRBOEK-6azbb6ZzBQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cava-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 298,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7337897786475,
#     'longitude': -73.9896078601189},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '143 4th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['143 4th Ave', 'New York, NY 10003']},
#    'phone': '+16464166440',
#    'display_phone': '(646) 416-6440',
#    'distance': 3176.445202197731},
#   {'id': 'Jh6wMPv4IK9jUpWMGj4J9g',
#    'alias': 'mama-pho-brooklyn',
#    'name': 'Mama Pho',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DN2sB0oULs0J0W-eGPqHdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mama-pho-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 273,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.710914, 'longitude': -73.948592},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '580 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['580 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17185995015',
#    'display_phone': '(718) 599-5015',
#    'distance': 3899.8743374142623},
#   {'id': 'wouDDTacUIBaRp8YGCFTsA',
#    'alias': 'colonie-brooklyn',
#    'name': 'Colonie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Slaynnu1ndJqrfGzp9UhhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/colonie-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 606,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6909, 'longitude': -73.9958},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '127 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['127 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17188557500',
#    'display_phone': '(718) 855-7500',
#    'distance': 1625.24899251244},
#   {'id': 'upaVTWhLsxcu1HXqN8iHVQ',
#    'alias': 'ladybird-new-york',
#    'name': 'Ladybird',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i-DTQD4m9DkmN8kFtst07A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ladybird-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 343,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.726769311104,
#     'longitude': -73.9847712789363},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '111 East 7th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 East 7th St', 'New York, NY 10009']},
#    'phone': '+18333284588',
#    'display_phone': '(833) 328-4588',
#    'distance': 2503.289690803383},
#   {'id': 'o__rNMK8xCSPKPVe6yIlxQ',
#    'alias': 'greenstreets-salads-brooklyn',
#    'name': 'GreenStreets Salads',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BhK90Cq0NZHtZDyRioO6QA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greenstreets-salads-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 217,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70455, 'longitude': -73.9238699},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '67 Irving Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['67 Irving Ave', 'Brooklyn, NY 11237']},
#    'phone': '+13474057956',
#    'display_phone': '(347) 405-7956',
#    'distance': 5940.021961265408},
#   {'id': 'DoSU8IPq-Py_YV3kYmXPfQ',
#    'alias': 'trattoria-trecolori-new-york',
#    'name': 'Trattoria Trecolori',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nL_iTlbmA__6yNAAj1Xldg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trattoria-trecolori-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2398,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.759876, 'longitude': -73.986767},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '254 West 47th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['254 West 47th St', 'New York, NY 10036']},
#    'phone': '+12129974540',
#    'display_phone': '(212) 997-4540',
#    'distance': 6084.389331712267},
#   {'id': 'mfK5xIUfIm8nnIL_KGb9Dg',
#    'alias': 'sanpanino-new-york',
#    'name': 'Sanpanino',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7WPYeZG8RtEzQWJsdqNNIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sanpanino-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 163,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73281, 'longitude': -74.00613},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '494 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['494 Hudson St', 'New York, NY 10014']},
#    'phone': '+12126457228',
#    'display_phone': '(212) 645-7228',
#    'distance': 3207.080854501388},
#   {'id': 'N6_qSesaVVrnZ5VDGFpCrg',
#    'alias': 'telegraphe-cafe-new-york-3',
#    'name': 'Telegraphe Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FTLaT3i7biXal-Zr8tRNXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/telegraphe-cafe-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 349,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7401399, 'longitude': -73.99543},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '107 W 18th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['107 W 18th St', 'New York, NY 10011']},
#    'phone': '+19178547398',
#    'display_phone': '(917) 854-7398',
#    'distance': 3867.7647834734676},
#   {'id': 'xefmiLAsKURFc6FDGSRgfQ',
#    'alias': 'westville-wall-st-new-york-5',
#    'name': 'Westville - Wall St',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_O4D1UjnQ9GNf4ocli5vCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/westville-wall-st-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 212,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70478, 'longitude': -74.00652},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '110 Wall St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['110 Wall St', 'New York, NY 10005']},
#    'phone': '+12127414780',
#    'display_phone': '(212) 741-4780',
#    'distance': 1023.6948113039041},
#   {'id': 'Y39SdfmS0Z_GepcFnFqlMA',
#    'alias': 'natureworks-new-york-2',
#    'name': 'Natureworks',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vqzWlBzNahJ4aDpIOoHAZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/natureworks-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 255,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.745068, 'longitude': -73.981859},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '113 E 31st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['113 E 31st St', 'New York, NY 10016']},
#    'phone': '+12127251411',
#    'display_phone': '(212) 725-1411',
#    'distance': 4528.769405373036},
#   {'id': '7Rn4Qo8w64fl-iB4V43-pQ',
#    'alias': 'a-novel-kitchen-new-york',
#    'name': 'A Novel Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fex9wcr7t-7qB6QfIAZ4rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/a-novel-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6905865531983,
#     'longitude': -73.99502954823993},
#    'transactions': ['delivery'],
#    'location': {'address1': '151 Atlantic Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['151 Atlantic Ave', 'New York, NY 11201']},
#    'phone': '+13478976766',
#    'display_phone': '(347) 897-6766',
#    'distance': 1653.3327359209438},
#   {'id': 'qOomR3AwClOGpV1HdqOTFg',
#    'alias': 'les-enfants-de-boheme-new-york',
#    'name': 'Les Enfants de Boheme',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Sw6SDhbhkdi7MJeDajbp5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/les-enfants-de-boheme-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 271,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7136187, 'longitude': -73.9888503},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '177 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['177 Henry St', 'New York, NY 10002']},
#    'phone': '+16464764843',
#    'display_phone': '(646) 476-4843',
#    'distance': 1026.2110364656392},
#   {'id': 'TMoFGaSlAlpEGjb9dOKPQg',
#    'alias': 'sweetgreen-new-york-2',
#    'name': 'sweetgreen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lbIgY8VfB6WGW7SuoHFdIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweetgreen-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 648,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7448032395629,
#     'longitude': -73.9886377751827},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1164 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1164 Broadway', 'New York, NY 10001']},
#    'phone': '+16464498884',
#    'display_phone': '(646) 449-8884',
#    'distance': 4402.318928742303},
#   {'id': 'HUEj_yVB1E2mNNxW5PqUtQ',
#    'alias': 'bistro-vendome-new-york',
#    'name': 'Bistro Vendome',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-bzTmjpGN3X1FTCjjCd0pA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistro-vendome-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 154,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7588875, 'longitude': -73.961963},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '405 East 58th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['405 East 58th St', 'New York, NY 10022']},
#    'phone': '+12129359100',
#    'display_phone': '(212) 935-9100',
#    'distance': 6537.182664330528},
#   {'id': '63nYipWuA42RZmESBMUNkQ',
#    'alias': 'the-bluebell-cafe-new-york',
#    'name': 'The Bluebell Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HUKTIk8N2qfZUa26NT6zpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bluebell-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 626,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73845, 'longitude': -73.98321},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '293 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['293 3rd Ave', 'New York, NY 10010']},
#    'phone': '+16466492389',
#    'display_phone': '(646) 649-2389',
#    'distance': 3782.5557737768595},
#   {'id': '7Oq1UdUHUGZGH_QI6N-0LQ',
#    'alias': 'hearth-new-york',
#    'name': 'Hearth',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Gp9_iXx6OSheBWBOuNrzjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hearth-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 740,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.730006, 'longitude': -73.983225},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '403 East 12th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['403 East 12th St', 'New York, NY 10009']},
#    'phone': '+16466021300',
#    'display_phone': '(646) 602-1300',
#    'distance': 2885.9796849241384},
#   {'id': 'VvsZAnEwU4c8Xkyrzx05Nw',
#    'alias': 'anytime-new-york',
#    'name': 'Anytime',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZCynTTqe0O1JtxKRozmWHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anytime-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1636,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74776270790539,
#     'longitude': -73.9867793576711},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '23 W 32nd St',
#     'address2': 'Fl 3',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23 W 32nd St', 'Fl 3', 'New York, NY 10001']},
#    'phone': '+16466697733',
#    'display_phone': '(646) 669-7733',
#    'distance': 4747.932417457403},
#   {'id': 'F2TE6sQpywj3bkVi8L_nLw',
#    'alias': 'toasties-new-york-9',
#    'name': 'Toasties',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kDt0CWilhg_AZ2nyrmHAIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/toasties-new-york-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 180,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.758511, 'longitude': -73.9748188},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '23 E 51st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23 E 51st St', 'New York, NY 10022']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6134.114598902275},
#   {'id': '_F-GTYP0Cfc6LGamqRhXgQ',
#    'alias': 'boutique-bistro-bar-astoria',
#    'name': 'Boutique Bistro Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TrlRZ8ILJhqcrsIgm5U6uw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boutique-bistro-bar-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 121,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.775414, 'longitude': -73.9093017},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '33-01 Ditmars Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-01 Ditmars Blvd', 'Astoria, NY 11105']},
#    'phone': '+19296667761',
#    'display_phone': '(929) 666-7761',
#    'distance': 10573.745772422713},
#   {'id': 'MAwtBgCmrY-i_jbmXlDMkw',
#    'alias': 'peacefood-cafe-downtown-new-york',
#    'name': 'Peacefood Cafe Downtown',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mNYkq6eXIryOv7SIAVj0Xw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peacefood-cafe-downtown-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 758,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7332670924819,
#     'longitude': -73.9929751334153},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '41 E 11th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41 E 11th St', 'New York, NY 10003']},
#    'phone': '+12129792288',
#    'display_phone': '(212) 979-2288',
#    'distance': 3095.6808095461624},
#   {'id': 'YOOZjCcC4s1MOBtFsaMB8w',
#    'alias': 'the-richmond-staten-island',
#    'name': 'The Richmond',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LRCrYGAfEJHxAIzS3GZ1Yw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-richmond-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 150,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.62508, 'longitude': -74.07463},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '695 Bay St',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['695 Bay St', 'Staten Island, NY 10304']},
#    'phone': '+17184898805',
#    'display_phone': '(718) 489-8805',
#    'distance': 11211.350335739966},
#   {'id': 'nrxSzq-VxLqD7aFkE4SH3Q',
#    'alias': 'cocoron-new-york-2',
#    'name': 'Cocoron',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1bYemlNsVqys2QiOezAT4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cocoron-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 675,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7207236, 'longitude': -73.9953191},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '37 Kenmare St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37 Kenmare St', 'New York, NY 10012']},
#    'phone': '+12129660800',
#    'display_phone': '(212) 966-0800',
#    'distance': 1701.114902248387},
#   {'id': 'or0Op4EDk95L0vhLwSATcQ',
#    'alias': 'montagus-gusto-new-york',
#    'name': "Montagu's Gusto",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CA1U2yfaZ4R7-KtdOVH8Mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/montagus-gusto-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 136,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74571, 'longitude': -73.97553},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '645 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['645 2nd Ave', 'New York, NY 10016']},
#    'phone': '+19172614129',
#    'display_phone': '(917) 261-4129',
#    'distance': 4748.338826569053},
#   {'id': 'cPXF0NTHTHEdWLDwknWHXA',
#    'alias': 'huge-thai-brooklyn',
#    'name': 'Huge Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bOMI0tpm7evod5yV7zxR-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/huge-thai-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68887, 'longitude': -73.99261},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '157 Court St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['157 Court St', 'Brooklyn, NY 11201']},
#    'phone': '+13479874198',
#    'display_phone': '(347) 987-4198',
#    'distance': 1850.0768895950473},
#   {'id': 'lQKKBtdp7No9HJ_tW6PuAQ',
#    'alias': 'fort-defiance-brooklyn',
#    'name': 'Fort Defiance',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aOqgnxhkoURIrx-7hZZWJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fort-defiance-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 355,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67719, 'longitude': -74.01291},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '347 Van Brunt St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['347 Van Brunt St', 'Brooklyn, NY 11231']},
#    'phone': '+13474536672',
#    'display_phone': '(347) 453-6672',
#    'distance': 3515.9658701613666},
#   {'id': 'nsIHA99ryl_1xDjRtyVJDA',
#    'alias': 'lenwich-new-york-26',
#    'name': 'Lenwich',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/e9jl5J0eDdMfqeaUSNMddg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lenwich-new-york-26?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 150,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.734715, 'longitude': -73.99235},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '120 University Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['120 University Pl', 'New York, NY 10003']},
#    'phone': '+12123530300',
#    'display_phone': '(212) 353-0300',
#    'distance': 3258.804396578918},
#   {'id': 'dbCTJp9ENDVIquxBWONzWQ',
#    'alias': 'pomodoro-new-york-2',
#    'name': 'Pomodoro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lkQTD4ZL1aEFZMeGSh64wA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pomodoro-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 122,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75624, 'longitude': -73.9939},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '518 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['518 9th Ave', 'New York, NY 10018']},
#    'phone': '+12122397019',
#    'display_phone': '(212) 239-7019',
#    'distance': 5649.745129315644},
#   {'id': 'ggxuLGEkOM_yGhMvPjCteA',
#    'alias': 'citizens-of-bleecker-new-york',
#    'name': 'Citizens of Bleecker',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EAQkHArAiFXohs3Mx9xWBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/citizens-of-bleecker-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 103,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'australian', 'title': 'Australian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.728603, 'longitude': -73.999672},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '155 Bleecker St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['155 Bleecker St', 'New York, NY 10012']},
#    'phone': '+16468337000',
#    'display_phone': '(646) 833-7000',
#    'distance': 2618.4839747051196},
#   {'id': 'gtXP0CmOnBbgfnff7VXa7A',
#    'alias': 'pastis-new-york-3',
#    'name': 'Pastis',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3r_UeuwKiISls-w5h1xatA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pastis-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 295,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73928, 'longitude': -74.00695},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '52 Gansevoort St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['52 Gansevoort St', 'New York, NY 10014']},
#    'phone': '+12129294844',
#    'display_phone': '(212) 929-4844',
#    'distance': 3907.953101477796},
#   {'id': '6ur9R2Fmr-7qXlNnyoclEg',
#    'alias': 'blume-hütte-new-york',
#    'name': 'Blume/Hütte',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r9EcfF5UULBOJorDUs1bdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blume-h%C3%BCtte-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77754, 'longitude': -73.9517855},
#    'transactions': ['delivery'],
#    'location': {'address1': '1652 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1652 2nd Ave', 'New York, NY 10028']},
#    'phone': '+16469810764',
#    'display_phone': '(646) 981-0764',
#    'distance': 8780.141294779694}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#           Restaurant                Type Price Rating            Address  \
# 0     Peacefood Cafe               Vegan    $$      4  460 Amsterdam Ave
# 1  Cebu Bar & Bistro  Breakfast & Brunch    $$      4       8801 3rd Ave
# 2          Salad Box               Salad                      44 Park Pl
# 3   Petite Boucherie              French   $$$    4.5  14 Christopher St
# 4         Just Salad               Salad    $$    3.5        252 7th Ave
#
#          Lat        Lng                                                url  \
# 0  40.785326 -73.977130  https://www.yelp.com/biz/peacefood-cafe-new-yo...
# 1  40.621860 -74.031383  https://www.yelp.com/biz/cebu-bar-and-bistro-b...
# 2  40.713280 -74.009580
# 3  40.733820 -74.000420  https://www.yelp.com/biz/petite-boucherie-new-...
# 4  40.669429 -73.979494  https://www.yelp.com/biz/just-salad-brooklyn?a...
#
#                        ID
# 0  zBf-m72ATTPTey-_9vu3Yw
# 1  uuHujhrkVQdS8XVSGWW2mA
# 2
# 3  g5f6p9jfzB30Mhcu6d5OWA
# 4  De_10VF2CrC2moWaPA81mg

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"soup and salad","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [{'id': 'nDhhVuhDyP-QRi0lwk0j3w',
#    'alias': 'evas-kitchen-kew-gardens',
#    'name': "Eva's Kitchen",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/g8O_4R4swkJCur1zsFj24w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/evas-kitchen-kew-gardens?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 123,
#    'categories': [{'alias': 'gourmet', 'title': 'Specialty Food'},
#     {'alias': 'falafel', 'title': 'Falafel'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7132359, 'longitude': -73.8293642},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '12036 Queens Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Kew Gardens',
#     'zip_code': '11415',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['12036 Queens Blvd', 'Kew Gardens, NY 11415']},
#    'phone': '+19293860170',
#    'display_phone': '(929) 386-0170',
#    'distance': 13928.630214469089},
#   {'id': 'enT7NJ7tLMvUMCWQcsUonw',
#    'alias': 'mémé-mediterranean-new-york-4',
#    'name': 'Mémé Mediterranean',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TCo41uZ7WhL5MwMMjZ-RKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/m%C3%A9m%C3%A9-mediterranean-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 635,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.736412, 'longitude': -74.00616},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '581 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['581 Hudson St', 'New York, NY 10014']},
#    'phone': '+16466928450',
#    'display_phone': '(646) 692-8450',
#    'distance': 3585.669092216312},
#   {'id': 'cQxtisUT6TgEGSN7gpnTDg',
#    'alias': 'good-enough-to-eat-new-york',
#    'name': 'Good Enough to Eat',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LhCautcV-8XJlyQtQ7US5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/good-enough-to-eat-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1470,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7859436042416,
#     'longitude': -73.9727859590175},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '520 Columbus Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['520 Columbus Ave', 'New York, NY 10024']},
#    'phone': '+12124960163',
#    'display_phone': '(212) 496-0163',
#    'distance': 9132.571987481726},
#   {'id': '0c2L2SZVIesxaYodGMkGgA',
#    'alias': 'waverly-diner-new-york-2',
#    'name': 'Waverly Diner',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iX_3ILROK1rqJ24VA_eprw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/waverly-diner-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 479,
#    'categories': [{'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.733152, 'longitude': -74.000269},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '385 6th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['385 6th Ave', 'New York, NY 10014']},
#    'phone': '+12126753181',
#    'display_phone': '(212) 675-3181',
#    'distance': 3123.069418732255},
#   {'id': 'TxHx1fb8O_MsfQB_ODdTQg',
#    'alias': 'hummus-place-new-york-4',
#    'name': 'Hummus Place',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HHlsj08PVrgK9FhTXE6jYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hummus-place-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 631,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.780044, 'longitude': -73.98027},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '305 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['305 Amsterdam Ave', 'New York, NY 10023']},
#    'phone': '+12127993335',
#    'display_phone': '(212) 799-3335',
#    'distance': 8379.866623361238},
#   {'id': 'LTfR_0NiS7OIRCfkaAJg9w',
#    'alias': 'silver-rice-brooklyn',
#    'name': 'Silver Rice',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NA3n6gNM-obdHqXS8LcULQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/silver-rice-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 297,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6742123562615,
#     'longitude': -73.9568891376257},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '638 Park Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['638 Park Pl', 'Brooklyn, NY 11238']},
#    'phone': '+17183988100',
#    'display_phone': '(718) 398-8100',
#    'distance': 4691.119256308481},
#   {'id': 'jAaVnUKLITkuhzwXIe0vLQ',
#    'alias': 'cafe-mogador-brooklyn',
#    'name': 'Cafe Mogador',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/79mu5Jkhl1UelPQvNjtk7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-mogador-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1228,
#    'categories': [{'alias': 'moroccan', 'title': 'Moroccan'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.719747, 'longitude': -73.959993},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '133 Wythe Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['133 Wythe Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17184869222',
#    'display_phone': '(718) 486-9222',
#    'distance': 3299.5306167935732},
#   {'id': '7xV4gzrgaOgQYtPC3FBZig',
#    'alias': 'pylos-new-york',
#    'name': 'Pylos',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lS0AxUffw5pWv5HluFKyvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pylos-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1147,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72608, 'longitude': -73.98415},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '128 E 7th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['128 E 7th St', 'New York, NY 10009']},
#    'phone': '+12124730220',
#    'display_phone': '(212) 473-0220',
#    'distance': 2451.8568607366624},
#   {'id': 'kaSd6qzlsxn__ILDtGf3iA',
#    'alias': 'alices-tea-cup-chapter-i-new-york',
#    'name': "Alice's Tea Cup Chapter I",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MaO4QznxaB383kO6vqvLwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alices-tea-cup-chapter-i-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1164,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77802, 'longitude': -73.9787},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '102 W 73rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 W 73rd St', 'New York, NY 10023']},
#    'phone': '+12127993006',
#    'display_phone': '(212) 799-3006',
#    'distance': 8179.7513501789335},
#   {'id': 'hmndKMvCwTzXSAPp4KmGYg',
#    'alias': 'bayou-staten-island',
#    'name': 'Bayou',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/z_1stFihRiGJ26JfEVr3CA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bayou-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 392,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.616771, 'longitude': -74.068443},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1072 Bay St',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1072 Bay St', 'Staten Island, NY 10305']},
#    'phone': '+17182734383',
#    'display_phone': '(718) 273-4383',
#    'distance': 11672.271529555299},
#   {'id': 'Bx9ufqCtxxdl2l6pT3J45g',
#    'alias': 'petrossian-boutique-and-cafe-new-york',
#    'name': 'Petrossian Boutique & Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1rdKEPcETJDNFWdU8KK5XQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/petrossian-boutique-and-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 364,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7658521957585,
#     'longitude': -73.979433064085},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '911 7th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['911 7th Ave', 'New York, NY 10019']},
#    'phone': '+12122452217',
#    'display_phone': '(212) 245-2217',
#    'distance': 6832.676181347042},
#   {'id': '66T7rXIZvcVg7XicY6QObg',
#    'alias': 'oscars-place-new-york-2',
#    'name': "Oscar's Place",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FETfiRPwBgR91DFXMbEwiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oscars-place-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 219,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7318649, 'longitude': -74.0064011},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '466 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['466 Hudson St', 'New York, NY 10014']},
#    'phone': '+12127416479',
#    'display_phone': '(212) 741-6479',
#    'distance': 3102.120244740204},
#   {'id': 'lzUkaMCuxYWR1cL_q3ElsQ',
#    'alias': 'dar-525-brooklyn-2',
#    'name': 'Dar 525',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/69QxLc4qSfNwZMRl3niZBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dar-525-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 153,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'kebab', 'title': 'Kebab'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72308, 'longitude': -73.9452699},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '168 Driggs Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['168 Driggs Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183890003',
#    'display_phone': '(718) 389-0003',
#    'distance': 4574.793830441655},
#   {'id': 'JdNzj7EGQLC9eqqw3SYBPg',
#    'alias': 'the-organic-grill-new-york-130',
#    'name': 'The Organic Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qdCiuKXGv9LyngPGZiQQGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-organic-grill-new-york-130?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 452,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'kosher', 'title': 'Kosher'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72737, 'longitude': -73.98578},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '123 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['123 1st Ave', 'New York, NY 10003']},
#    'phone': '+12124777177',
#    'display_phone': '(212) 477-7177',
#    'distance': 2542.413382236769},
#   {'id': 'h8XLhVVPoYPYodZqQOjRMw',
#    'alias': 'robert-new-york-25',
#    'name': 'Robert',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LSZpShahH4Gq34Qh_vHe-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/robert-new-york-25?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 941,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.767394, 'longitude': -73.982036},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '2 Columbus Cir',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2 Columbus Cir', 'New York, NY 10019']},
#    'phone': '+12122997730',
#    'display_phone': '(212) 299-7730',
#    'distance': 6965.405799353917},
#   {'id': 'VgIiCZoUnujSMZATByk77Q',
#    'alias': 'the-meatball-shop-hells-kitchen-new-york',
#    'name': "The Meatball Shop - Hell's Kitchen",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hD59qPZaeYfgfiKndEaamg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-meatball-shop-hells-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 410,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7651804928198,
#     'longitude': -73.9874866666706},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '798 9th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['798 9th Ave', 'New York, NY 10019']},
#    'phone': '+12122305860',
#    'display_phone': '(212) 230-5860',
#    'distance': 6667.002942400346},
#   {'id': 'X3ToKHjzofO8EzfiHYewWg',
#    'alias': 'brooklyn-blend-brooklyn',
#    'name': 'Brooklyn Blend',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CoKqf_70jcdPE64psMVhqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-blend-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 354,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6923575699329,
#     'longitude': -73.9457686990499},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '194 Tompkins Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['194 Tompkins Ave', 'Brooklyn, NY 11206']},
#    'phone': '+17184842247',
#    'display_phone': '(718) 484-2247',
#    'distance': 4333.625517097762},
#   {'id': 'DU_DMCalguwdsnmLOJX3mg',
#    'alias': 'la-cigogne-brooklyn',
#    'name': 'La Cigogne ',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AUHodCQKBLgf4Efo7l1rDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-cigogne-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 377,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.683501, 'longitude': -73.999304},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '215 Union St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['215 Union St', 'Brooklyn, NY 11231']},
#    'phone': '+17188585641',
#    'display_phone': '(718) 858-5641',
#    'distance': 2473.626129266588},
#   {'id': '8UwRTdW4OtSEI2rJ_p1zGg',
#    'alias': 'dimes-new-york-3',
#    'name': 'Dimes',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i-I4wOT4O6uGQ6C1ostY1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dimes-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 262,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.714973, 'longitude': -73.991539},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '49 Canal St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['49 Canal St', 'New York, NY 10002']},
#    'phone': '+12129251300',
#    'display_phone': '(212) 925-1300',
#    'distance': 1086.6618834305216},
#   {'id': 'R9XDds0a1_jip3glIdlQsg',
#    'alias': 'the-district-new-york',
#    'name': 'The District',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/i1Jkb4pv1tlmp0nfd3A3OA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-district-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 368,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.783851, 'longitude': -73.949892},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1679 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1679 3rd Ave', 'New York, NY 10128']},
#    'phone': '+12122892005',
#    'display_phone': '(212) 289-2005',
#    'distance': 9486.90330662253},
#   {'id': 'Oq1mej1BYfjcdPKkM_5o8g',
#    'alias': 'high-street-on-hudson-new-york',
#    'name': 'High Street On Hudson',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FvKsbK7g79UVFYyyzqNeYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/high-street-on-hudson-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 427,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73888, 'longitude': -74.00574},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '637 Hudson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['637 Hudson St', 'New York, NY 10014']},
#    'phone': '+19173883944',
#    'display_phone': '(917) 388-3944',
#    'distance': 3843.1955727088894},
#   {'id': 'owYYuyLvlsdjLz68c3SSfg',
#    'alias': 'taboonette-new-york',
#    'name': 'Taboonette',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7ASnp9q29aNE9vSin5V9Ug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taboonette-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 898,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7346038818359,
#     'longitude': -73.9928283691406},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '30 E 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30 E 13th St', 'New York, NY 10003']},
#    'phone': '+12125107881',
#    'display_phone': '(212) 510-7881',
#    'distance': 3246.679954451783},
#   {'id': 'vYHT1mRQMOGgSYyPGmMo2w',
#    'alias': 'kitchen-at-cobble-hill-brooklyn',
#    'name': 'Kitchen at Cobble Hill',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MEyZjVU9nF7ISCRotCLnXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kitchen-at-cobble-hill-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 350,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.68528, 'longitude': -73.99466},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '254 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['254 Court St', 'Brooklyn, NY 11231']},
#    'phone': '+13475991887',
#    'display_phone': '(347) 599-1887',
#    'distance': 2231.6745023811013},
#   {'id': 'HD0e3eHwv573qHZOJJitWg',
#    'alias': 'aurora-soho-new-york',
#    'name': 'Aurora Soho',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/M4sGEk7xHI9pYu3oDroZTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aurora-soho-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 483,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.723543, 'longitude': -74.003199},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '510 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['510 Broome St', 'New York, NY 10013']},
#    'phone': '+12123349020',
#    'display_phone': '(212) 334-9020',
#    'distance': 2147.8428165108357},
#   {'id': 'jewdjZyGcAXIepOeTBae6g',
#    'alias': 'cafe-panino-mucho-giusto-new-york',
#    'name': 'Cafe Panino Mucho Giusto',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_1MBpcFh7BJClhvNVjlLag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-panino-mucho-giusto-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 109,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.735256, 'longitude': -74.006309},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '551 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['551 Hudson St', 'New York, NY 10014']},
#    'phone': '+12122292799',
#    'display_phone': '(212) 229-2799',
#    'distance': 3466.3911255716803},
#   {'id': 'l4AfiXGgRjRYRidnqRQU7Q',
#    'alias': 'capriottis-sandwich-shop-brooklyn-3',
#    'name': "Capriotti's Sandwich Shop",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Xl7oIQ8zi5aeMotycJTmNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/capriottis-sandwich-shop-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69121, 'longitude': -73.99071},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '88 Livingston St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['88 Livingston St', 'Brooklyn, NY 11201']},
#    'phone': '+13477630250',
#    'display_phone': '(347) 763-0250',
#    'distance': 1611.4095877038549},
#   {'id': 'BSv3awhABROYjjwlQaQ-Qw',
#    'alias': 'tinys-and-the-bar-upstairs-new-york-2',
#    'name': "Tiny's & The Bar Upstairs",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vG17NIk_HU-knfvIIy5AxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tinys-and-the-bar-upstairs-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 595,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.716698, 'longitude': -74.00816},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '135 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['135 W Broadway', 'New York, NY 10013']},
#    'phone': '+12123741135',
#    'display_phone': '(212) 374-1135',
#    'distance': 1712.2451618660841},
#   {'id': '38YuedP0ItlKbC-ncJ1XCQ',
#    'alias': 'tavern-on-jane-new-york',
#    'name': 'Tavern on Jane',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pvxu87G34YkiP1LIzELiXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tavern-on-jane-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 420,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73822, 'longitude': -74.00426},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '31 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31 8th Ave', 'New York, NY 10014']},
#    'phone': '+12126752526',
#    'display_phone': '(212) 675-2526',
#    'distance': 3744.321101108146},
#   {'id': 'EPr3PIfano_q04qz-lO-GQ',
#    'alias': 'don-andrés-brooklyn-3',
#    'name': 'Don Andrés',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tr5zrYDvhbfKc9MB7ZMEmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/don-andr%C3%A9s-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6974158940626,
#     'longitude': -73.9240515271922},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '238 Central Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['238 Central Ave', 'Brooklyn, NY 11221']},
#    'phone': '+17184847358',
#    'display_phone': '(718) 484-7358',
#    'distance': 5988.21483576414},
#   {'id': 'ElngKkPciE61tzzPgoYFhQ',
#    'alias': 'honeybrains-new-york-2',
#    'name': 'Honeybrains',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ASMjz5e5OjTbZxrQz0o1dA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/honeybrains-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 191,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'honey', 'title': 'Honey'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.727156, 'longitude': -73.993962},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '372 Lafayette St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['372 Lafayette St', 'New York, NY 10012']},
#    'phone': '+16466784092',
#    'display_phone': '(646) 678-4092',
#    'distance': 2414.326828430954},
#   {'id': 'CqmsVXJ4gbrt4bHc0LUQQQ',
#    'alias': 'heights-deli-and-grill-jersey-city-3',
#    'name': 'Heights Deli & Grill',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YaxvEZDBxO6RIZNrXpbuFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heights-deli-and-grill-jersey-city-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74768, 'longitude': -74.04227},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '557 Palisade Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Jersey City',
#     'zip_code': '07307',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['557 Palisade Ave', 'Jersey City, NJ 07307']},
#    'phone': '+12019636500',
#    'display_phone': '(201) 963-6500',
#    'distance': 6195.882119284754},
#   {'id': 'shTLI1GCcZ9rosFdt8d2Xg',
#    'alias': 'purbird-brooklyn',
#    'name': 'Purbird',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/b1oDmaoa0kW5ZvKbSJnCzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/purbird-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 466,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67985, 'longitude': -73.97518},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '82 Sixth Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['82 Sixth Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17188572473',
#    'display_phone': '(718) 857-2473',
#    'distance': 3264.830348409594},
#   {'id': 'kMljfja7weqfl_lzspjzHA',
#    'alias': 'cafe-cluny-new-york-3',
#    'name': 'Cafe Cluny',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/C4mRJFgdeiKj59c2UuwDMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-cluny-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 762,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.737385, 'longitude': -74.003966},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '284 W 12th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['284 W 12th St', 'New York, NY 10014']},
#    'phone': '+12122556900',
#    'display_phone': '(212) 255-6900',
#    'distance': 3643.9243748335875},
#   {'id': '14BLy22t6EKuPO5aAQ6R8g',
#    'alias': 'just-salad-new-york-34',
#    'name': 'Just Salad',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QBHxvy6CU60Tr5rh6193fA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/just-salad-new-york-34?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 119,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71234276137147,
#     'longitude': -74.00806126094226},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '233 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10279',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['233 Broadway', 'New York, NY 10279']},
#    'phone': '+12122441111',
#    'display_phone': '(212) 244-1111',
#    'distance': 1391.0659066997805},
#   {'id': 'qCf1QN11Qdncpqb7PhuyVw',
#    'alias': 'the-rag-trader-and-bo-peep-cocktail-and-highball-store-new-york',
#    'name': 'The Rag Trader & Bo Peep Cocktail and Highball Store',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/i8TwHAYZBxv950tCkhtjjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-rag-trader-and-bo-peep-cocktail-and-highball-store-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 527,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'pianobars', 'title': 'Piano Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75059, 'longitude': -73.98628},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '70 W 36th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70 W 36th St', 'New York, NY 10018']},
#    'phone': '+19172615495',
#    'display_phone': '(917) 261-5495',
#    'distance': 5067.325983022351},
#   {'id': 'cOtB9fWWLrbaBebZDjJquQ',
#    'alias': 'dunhuang-miss-noodles-brooklyn',
#    'name': 'DunHuang Miss Noodles',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RrlOuwLfm1pi5oqXk6CN4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dunhuang-miss-noodles-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.693868137768895,
#     'longitude': -73.9634565145772},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '531 Myrtle Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['531 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17187893530',
#    'display_phone': '(718) 789-3530',
#    'distance': 2900.8291200464364},
#   {'id': 'zupIzmhdcH0U6vJQQxDBiQ',
#    'alias': 'bar-bruno-brooklyn-2',
#    'name': 'Bar Bruno',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/u2ky7ICWnun6WOYOaY018g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-bruno-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 282,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6833674, 'longitude': -73.9997959},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '520 Henry St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['520 Henry St', 'Brooklyn, NY 11231']},
#    'phone': '+13477630850',
#    'display_phone': '(347) 763-0850',
#    'distance': 2498.349709571379},
#   {'id': '0moBSyrTezcT3uePV74nug',
#    'alias': 'westville-hells-kitchen-new-york',
#    'name': "Westville Hell's Kitchen",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oEica-EOQV47DPwr3HFgNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/westville-hells-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 170,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76577, 'longitude': -73.9875},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '809 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['809 9th Ave', 'New York, NY 10019']},
#    'phone': '+12129242202',
#    'display_phone': '(212) 924-2202',
#    'distance': 6735.506367983286},
#   {'id': 'DI0PHE6PVTpJF6dvG_d1Wg',
#    'alias': 'red-hook-tavern-brooklyn',
#    'name': 'Red Hook Tavern',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xcPYKGxDdVG54LOaDT9jtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/red-hook-tavern-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 92,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67788, 'longitude': -74.01209},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '329 Van Brunt St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['329 Van Brunt St', 'Brooklyn, NY 11231']},
#    'phone': '+19179666094',
#    'display_phone': '(917) 966-6094',
#    'distance': 3413.639980146156},
#   {'id': 'YqWXNq0Ku7cGb6Zj1j43Pw',
#    'alias': 'kal-astoria',
#    'name': 'KAL',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gZJT52Ivjhjz73lY0-MxGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kal-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 196,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76584, 'longitude': -73.91859},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '34-05 30th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['34-05 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+19293491230',
#    'display_phone': '(929) 349-1230',
#    'distance': 9261.880442747193},
#   {'id': 'apykLG7DTZ-7xnOcZGDZZA',
#    'alias': 'taverna-kyclades-east-village-new-york-2',
#    'name': 'Taverna Kyclades - East Village',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bs7AH0uB2FzHtQu4kSfuCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taverna-kyclades-east-village-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 870,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.731019969685164,
#     'longitude': -73.98260448877211},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '228 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 1st Ave', 'New York, NY 10009']},
#    'phone': '+12124320011',
#    'display_phone': '(212) 432-0011',
#    'distance': 3009.6047537923587},
#   {'id': '8wMJdpw2R_4VfS55itB_gQ',
#    'alias': 'sweetwater-restaurant-brooklyn-2',
#    'name': 'Sweetwater Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kMmAhqVDm_aIs0ch-G2EIQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweetwater-restaurant-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 402,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7184736, 'longitude': -73.9600178},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '105 N 6th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['105 N 6th St', 'Brooklyn, NY 11249']},
#    'phone': '+17189630608',
#    'display_phone': '(718) 963-0608',
#    'distance': 3231.820645331585},
#   {'id': 'rYUtdvkEC36CbR_B2JHMWA',
#    'alias': 'tidal-poke-co-harborside-jersey-city-6',
#    'name': 'Tidal Poke Co - Harborside',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tmWLLR0ao5Cmwwp5uB8irA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tidal-poke-co-harborside-jersey-city-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'hawaiian', 'title': 'Hawaiian'},
#     {'alias': 'poke', 'title': 'Poke'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7190635, 'longitude': -74.033369},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '210 Hudson St',
#     'address2': 'District Kitchen',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['210 Hudson St',
#      'District Kitchen',
#      'Jersey City, NJ 07302']},
#    'phone': '+12018395470',
#    'display_phone': '(201) 839-5470',
#    'distance': 3624.962365520728},
#   {'id': 'n-hBKsnFFUpe-y00EZrOqg',
#    'alias': 'amys-bread-new-york',
#    'name': "Amy's Bread",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8f7KsEz2kzgB97eFsNFOFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amys-bread-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1143,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76121, 'longitude': -73.99024},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '672 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['672 9th Ave', 'New York, NY 10036']},
#    'phone': '+12129772670',
#    'display_phone': '(212) 977-2670',
#    'distance': 6208.963689714628},
#   {'id': '3xTQT7qjZJIxc-eBiFMerQ',
#    'alias': '1803-new-york',
#    'name': '1803',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/f6_ZYxoZGbyGsCn6m_auog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/1803-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 554,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.715498, 'longitude': -74.007178},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '82 Reade St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['82 Reade St', 'New York, NY 10007']},
#    'phone': '+12122673000',
#    'display_phone': '(212) 267-3000',
#    'distance': 1558.541688391669},
#   {'id': 'ziPLg64qxWsYiBBmCMbXPw',
#    'alias': 'flavors-cafe-new-york',
#    'name': 'Flavors Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-lONAKyVWpHTLlWL_w5EbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flavors-cafe-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.706363, 'longitude': -74.005126},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '175 Water St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['175 Water St', 'New York, NY 10038']},
#    'phone': '+12124803800',
#    'display_phone': '(212) 480-3800',
#    'distance': 921.7423753074205},
#   {'id': 'WG639VkTjmK5dzydd1BBJA',
#    'alias': 'rubirosa-new-york-2',
#    'name': 'Rubirosa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LuSzR8cpVQRofXOT_bMi1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2451,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.722766, 'longitude': -73.996233},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '235 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#    'phone': '+12129650500',
#    'display_phone': '(212) 965-0500',
#    'distance': 1932.9467701334759},
#   {'id': 'YnDs59_dEQ61TdCD4fdyEw',
#    'alias': 'orchard-grocer-new-york',
#    'name': 'Orchard Grocer',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZNowZRl_p1AjvUfHRuGehw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/orchard-grocer-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 258,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.717744, 'longitude': -73.990187},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '78 Orchard St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['78 Orchard St', 'New York, NY 10002']},
#    'phone': '+16467579910',
#    'display_phone': '(646) 757-9910',
#    'distance': 1410.7133123264375},
#   {'id': 'j9TdOBSQ1LRw8v3hW5fObQ',
#    'alias': 'pies-n-thighs-brooklyn',
#    'name': 'Pies-n-Thighs',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZEox6v_ipIvcrzeRv9mFIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pies-n-thighs-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3007,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.711191, 'longitude': -73.961424},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '166 S 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['166 S 4th St', 'Brooklyn, NY 11211']},
#    'phone': '+13475296090',
#    'display_phone': '(347) 529-6090',
#    'distance': 2843.269690474491},
#   {'id': '8mZ6fE9n_mK59mJ_MYtrSQ',
#    'alias': 'mimis-hummus-brooklyn',
#    'name': "Mimi's Hummus",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ujAIrrFazhA-zdModvIDpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mimis-hummus-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 360,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'moroccan', 'title': 'Moroccan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.64035, 'longitude': -73.9667},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1209 Cortelyou Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11218',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1209 Cortelyou Rd', 'Brooklyn, NY 11218']},
#    'phone': '+17182844444',
#    'display_phone': '(718) 284-4444',
#    'distance': 7603.504375304448}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#            Restaurant                Type Price Rating            Address  \
# 0       Eva's Kitchen      Specialty Food    $$    4.5  12036 Queens Blvd
# 1  Mémé Mediterranean       Mediterranean    $$      4      581 Hudson St
# 2  Good Enough to Eat  Breakfast & Brunch    $$    3.5   520 Columbus Ave
# 3       Waverly Diner              Diners    $$    3.5        385 6th Ave
# 4        Hummus Place          Vegetarian    $$      4  305 Amsterdam Ave
#
#          Lat        Lng                                                url  \
# 0  40.713236 -73.829364  https://www.yelp.com/biz/evas-kitchen-kew-gard...
# 1  40.736412 -74.006160  https://www.yelp.com/biz/m%C3%A9m%C3%A9-medite...
# 2  40.785944 -73.972786  https://www.yelp.com/biz/good-enough-to-eat-ne...
# 3  40.733152 -74.000269  https://www.yelp.com/biz/waverly-diner-new-yor...
# 4  40.780044 -73.980270  https://www.yelp.com/biz/hummus-place-new-york...
#
#                        ID
# 0  nDhhVuhDyP-QRi0lwk0j3w
# 1  enT7NJ7tLMvUMCWQcsUonw
# 2  cQxtisUT6TgEGSN7gpnTDg
# 3  0c2L2SZVIesxaYodGMkGgA
# 4  TxHx1fb8O_MsfQB_ODdTQg

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                          Restaurant            Type Rating Price  \
# 0                            Hearth  American (New)      4   $$$
# 1                    The Wheelhouse  American (New)      4    $$
# 2                 The Bluebell Cafe  American (New)      4    $$
# 3                            Upland  American (New)      4   $$$
# 4                         BLACKBARN  American (New)      4   $$$
# 5                            Robert  American (New)      4   $$$
# 6                           Purbird  American (New)      4    $$
# 7                   Harvest Kitchen  American (New)      4    $$
# 8                 Union Square Cafe  American (New)      4   $$$
# 9                 Tribeca's Kitchen  American (New)      4    $$
# 10                Tribeca's Kitchen  American (New)      4    $$
# 11                        L'ADRESSE  American (New)      4   $$$
# 12                   Tavern on Jane  American (New)      4    $$
# 13                   Brooklyn Blend  American (New)    4.5    $$
# 14                    Marlow & Sons  American (New)      4   $$$
# 15                        The Smith  American (New)      4    $$
# 16                            Dimes  American (New)    3.5    $$
# 17                  Westville Dumbo  American (New)      4    $$
# 18                        Cafeteria  American (New)    3.5    $$
# 19            High Street On Hudson  American (New)      4    $$
# 20                        Bar Bruno  American (New)      4    $$
# 21         Westville Hell's Kitchen  American (New)    4.5    $$
# 22                    Bus Stop Cafe  American (New)      4    $$
# 23                Westville Chelsea  American (New)      4    $$
# 24                      Natureworks  American (New)      4    $$
# 25                     The Richmond  American (New)
# 26                  Montagu's Gusto  American (New)    4.5     $
# 27         Simple Cafe & Restaurant  American (New)      4    $$
# 28            Sweetwater Restaurant  American (New)      4    $$
# 29                    Fort Defiance  American (New)      4    $$
# ..                              ...             ...    ...   ...
# 170                     Fish Cheeks         Seafood    4.5    $$
# 171                         Estuary         Seafood
# 172           Hale and Hearty Soups            Soup    3.5    $$
# 173           Hale and Hearty Soups            Soup      3     $
# 174     The Soup Bowl of Park Slope            Soup      4     $
# 175                   Peasant Stock            Soup    4.5     $
# 176                      Good Stock            Soup    3.5     $
# 177                   Soup N Burger            Soup    3.5    $$
# 178            The Original Soupman            Soup      4     $
# 179                   Pies-n-Thighs        Southern      4    $$
# 180                   Eva's Kitchen  Specialty Food    4.5    $$
# 181                      Don Andrés           Tacos
# 182            Yoongkao Thai Dining            Thai
# 183                       Huge Thai            Thai
# 184                         Nourish            Thai      4    $$
# 185         Peacefood Cafe Downtown           Vegan      4    $$
# 186               The Organic Grill           Vegan      4    $$
# 187                        Ladybird           Vegan      4    $$
# 188                  Peacefood Cafe           Vegan      4    $$
# 189                  Peacefood Cafe           Vegan      4    $$
# 190                       B&H Dairy      Vegetarian    4.5     $
# 191                Good Health Cafe      Vegetarian      4    $$
# 192                    Le Botaniste      Vegetarian    4.5    $$
# 193                    Hummus Place      Vegetarian      4    $$
# 194                    P.S. Kitchen      Vegetarian      4    $$
# 195                       Nish Nush      Vegetarian    4.5    $$
# 196                      5ive Spice      Vietnamese    4.5    $$
# 197                        Mama Pho      Vietnamese    3.5    $$
# 198                          Nón Lá      Vietnamese    4.5    $$
# 199  Lucy's Vietnamese Williamsburg      Vietnamese
#
#                       Address        Lat        Lng  \
# 0            403 East 12th St  40.730006 -73.983225
# 1              165 Wilson Ave  40.700122 -73.924188
# 2                 293 3rd Ave  40.738450 -73.983210
# 3              345 Park Ave S  40.741891 -73.984640
# 4                19 E 26th St  40.743104 -73.987054
# 5              2 Columbus Cir  40.767394 -73.982036
# 6                82 Sixth Ave  40.679850 -73.975180
# 7            269 Columbus Ave  40.777697 -73.978357
# 8               101 E 19th St  40.737772 -73.987876
# 9               200 Church St  40.716271 -74.007223
# 10              200 Church St  40.716271 -74.007223
# 11   1065 Ave Of The Americas  40.754030 -73.985390
# 12                 31 8th Ave  40.738220 -74.004260
# 13           194 Tompkins Ave  40.692358 -73.945769
# 14                81 Broadway  40.710613 -73.965881
# 15                956 2nd Ave  40.755165 -73.967868
# 16                49 Canal St  40.714973 -73.991539
# 17           81 Washington St  40.702089 -73.989454
# 18                119 7th Ave  40.740568 -73.998075
# 19              637 Hudson St  40.738880 -74.005740
# 20               520 Henry St  40.683367 -73.999796
# 21                809 9th Ave  40.765770 -73.987500
# 22              597 Hudson St  40.737020 -74.005950
# 23              246 W 18th St  40.741750 -74.000070
# 24              113 E 31st St  40.745068 -73.981859
# 25                 695 Bay St  40.625080 -74.074630
# 26                645 2nd Ave  40.745710 -73.975530
# 27            346 Bedford Ave  40.712440 -73.962750
# 28               105 N 6th St  40.718474 -73.960018
# 29           347 Van Brunt St  40.677190 -74.012910
# ..                        ...        ...        ...
# 170                55 Bond St  40.725800 -73.992700
# 171        159 Bridge Park Dr  40.693236 -74.000794
# 172                75 9th Ave  40.742540 -74.005613
# 173        2 MetroTech Center  40.693465 -73.985702
# 174               319 7th Ave  40.667056 -73.981222
# 175               88 Essex St  40.718045 -73.988052
# 176             31 Carmine St  40.730330 -74.003270
# 177           1825 Emmons Ave  40.583572 -73.950016
# 178            259A W 55th St  40.765361 -73.983439
# 179              166 S 4th St  40.711191 -73.961424
# 180         12036 Queens Blvd  40.713236 -73.829364
# 181           238 Central Ave  40.697416 -73.924052
# 182               625 2nd Ave  40.745050 -73.975910
# 183              157 Court St  40.688870 -73.992610
# 184       637A Vanderbilt Ave  40.677941 -73.968455
# 185              41 E 11th St  40.733267 -73.992975
# 186               123 1st Ave  40.727370 -73.985780
# 187           111 East 7th St  40.726769 -73.984771
# 188         460 Amsterdam Ave  40.785326 -73.977130
# 189         460 Amsterdam Ave  40.785326 -73.977130
# 190               127 2nd Ave  40.728462 -73.988167
# 191              1435 1st Ave  40.769480 -73.954990
# 192              127 Grand St  40.720428 -74.000203
# 193         305 Amsterdam Ave  40.780044 -73.980270
# 194             246 W 48th St  40.760706 -73.986627
# 195               88 Reade St  40.715688 -74.007695
# 196           227 Mulberry St  40.722598 -73.996272
# 197              580 Grand St  40.710914 -73.948592
# 198              128 E 4th St  40.725287 -73.987563
# 199              112 Berry St  40.718903 -73.958957
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/hearth-new-york?adjus...  7Oq1UdUHUGZGH_QI6N-0LQ
# 1    https://www.yelp.com/biz/the-wheelhouse-brookl...  oXnJEg_AScyrR1lO4dnAfw
# 2    https://www.yelp.com/biz/the-bluebell-cafe-new...  63nYipWuA42RZmESBMUNkQ
# 3    https://www.yelp.com/biz/upland-new-york?adjus...  xkvv0n7jbl4Ra3Vm_jfxaA
# 4    https://www.yelp.com/biz/blackbarn-new-york?ad...  Lw044EfH1h3XhUhri3ExfA
# 5    https://www.yelp.com/biz/robert-new-york-25?ad...  h8XLhVVPoYPYodZqQOjRMw
# 6    https://www.yelp.com/biz/purbird-brooklyn?adju...  shTLI1GCcZ9rosFdt8d2Xg
# 7    https://www.yelp.com/biz/harvest-kitchen-new-y...  PYmjoid5P-Mw8dkkKxZy6w
# 8    https://www.yelp.com/biz/union-square-cafe-new...  lXGCo-K7eftxRT_6E59-Iw
# 9    https://www.yelp.com/biz/tribecas-kitchen-new-...  MHtbBc2np3sR7jiV9GphNg
# 10   https://www.yelp.com/biz/tribecas-kitchen-new-...  MHtbBc2np3sR7jiV9GphNg
# 11   https://www.yelp.com/biz/l-adresse-new-york?ad...  scjoZtbTQHi35xhAlUm2iQ
# 12   https://www.yelp.com/biz/tavern-on-jane-new-yo...  38YuedP0ItlKbC-ncJ1XCQ
# 13   https://www.yelp.com/biz/brooklyn-blend-brookl...  X3ToKHjzofO8EzfiHYewWg
# 14   https://www.yelp.com/biz/marlow-and-sons-brook...  G18cPTEjuxXx957dGYBDAQ
# 15   https://www.yelp.com/biz/the-smith-new-york-2?...  C-8mGN7lt5rIraO5n-15ug
# 16   https://www.yelp.com/biz/dimes-new-york-3?adju...  8UwRTdW4OtSEI2rJ_p1zGg
# 17   https://www.yelp.com/biz/westville-dumbo-brook...  56qlj1cYlqNzmG0xllGg-w
# 18   https://www.yelp.com/biz/cafeteria-new-york?ad...  UXVDyIzmO5kmJnlv-HDXLg
# 19   https://www.yelp.com/biz/high-street-on-hudson...  Oq1mej1BYfjcdPKkM_5o8g
# 20   https://www.yelp.com/biz/bar-bruno-brooklyn-2?...  zupIzmhdcH0U6vJQQxDBiQ
# 21   https://www.yelp.com/biz/westville-hells-kitch...  0moBSyrTezcT3uePV74nug
# 22   https://www.yelp.com/biz/bus-stop-cafe-new-yor...  hgQxxv1WlmI7lMjLjp-2zA
# 23   https://www.yelp.com/biz/westville-chelsea-new...  MctQwL9Mp5X7DJk13VoERg
# 24   https://www.yelp.com/biz/natureworks-new-york-...  Y39SdfmS0Z_GepcFnFqlMA
# 25
# 26   https://www.yelp.com/biz/montagus-gusto-new-yo...  or0Op4EDk95L0vhLwSATcQ
# 27   https://www.yelp.com/biz/simple-cafe-and-resta...  ArfL-sU2FaB73WV1qQ4c6Q
# 28   https://www.yelp.com/biz/sweetwater-restaurant...  8wMJdpw2R_4VfS55itB_gQ
# 29   https://www.yelp.com/biz/fort-defiance-brookly...  lQKKBtdp7No9HJ_tW6PuAQ
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/fish-cheeks-new-york?...  WJS06XxRdc6DD1s4LWE9HA
# 171
# 172  https://www.yelp.com/biz/hale-and-hearty-soups...  gtT9TZBNFn9xlnjup5Q8sg
# 173  https://www.yelp.com/biz/hale-and-hearty-soups...  n1g_W6D4TQRPf0Rm2rMBTA
# 174  https://www.yelp.com/biz/the-soup-bowl-of-park...  lR58h9jeoDfy_9jVOqTDJg
# 175  https://www.yelp.com/biz/peasant-stock-new-yor...  uqBZzJXrsw0c7SJ2hcJ8HQ
# 176  https://www.yelp.com/biz/good-stock-new-york-3...  gxCnsgWQS_79sMDHpmeHzw
# 177  https://www.yelp.com/biz/soup-n-burger-brookly...  xxgtwN5sxqiGWMJ03dZQcg
# 178  https://www.yelp.com/biz/the-original-soupman-...  HuSaFUqMDLbovpU-XbR9UA
# 179  https://www.yelp.com/biz/pies-n-thighs-brookly...  j9TdOBSQ1LRw8v3hW5fObQ
# 180  https://www.yelp.com/biz/evas-kitchen-kew-gard...  nDhhVuhDyP-QRi0lwk0j3w
# 181
# 182
# 183
# 184  https://www.yelp.com/biz/nourish-brooklyn-4?ad...  qusZ-K5tzM1EyOa1IEWCHA
# 185  https://www.yelp.com/biz/peacefood-cafe-downto...  MAwtBgCmrY-i_jbmXlDMkw
# 186  https://www.yelp.com/biz/the-organic-grill-new...  JdNzj7EGQLC9eqqw3SYBPg
# 187  https://www.yelp.com/biz/ladybird-new-york?adj...  upaVTWhLsxcu1HXqN8iHVQ
# 188  https://www.yelp.com/biz/peacefood-cafe-new-yo...  zBf-m72ATTPTey-_9vu3Yw
# 189  https://www.yelp.com/biz/peacefood-cafe-new-yo...  zBf-m72ATTPTey-_9vu3Yw
# 190  https://www.yelp.com/biz/b-and-h-dairy-new-yor...  koh-4_SAbshwZ8EBRmXcmg
# 191  https://www.yelp.com/biz/good-health-cafe-new-...  S9DvhHSe9V7cJaLQ5m5SjA
# 192  https://www.yelp.com/biz/le-botaniste-new-york...  4b43TOXpskBPZqQzbKkwDQ
# 193  https://www.yelp.com/biz/hummus-place-new-york...  TxHx1fb8O_MsfQB_ODdTQg
# 194  https://www.yelp.com/biz/p-s-kitchen-new-york-...  KXD44wWmrGf7mzyyr0bikw
# 195  https://www.yelp.com/biz/nish-nush-new-york?ad...  d8zSYpArh4oXpxeJWNA4Pg
# 196  https://www.yelp.com/biz/5ive-spice-new-york-2...  9fG8-RRh1rzuCKN2TmF-QQ
# 197  https://www.yelp.com/biz/mama-pho-brooklyn?adj...  Jh6wMPv4IK9jUpWMGj4J9g
# 198  https://www.yelp.com/biz/n%C3%B3n-l%C3%A1-new-...  8zTyhMq0ki83WoWrq4D0qw
# 199
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_SoupAndSalad.csv')
