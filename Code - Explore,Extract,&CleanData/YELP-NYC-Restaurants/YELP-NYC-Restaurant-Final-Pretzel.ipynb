# %% [markdown]
# NYC RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
nycr_params1 = {"term":"pretzel","location":"New York","limit":50}
nycr_response1 = requests.get(search_api_url, headers=headers, params=nycr_params1)
nycr1 = nycr_response1.json()
display(nycr1)
#print(nycr_response1.url)
#print(nycr_response1.status_code)
# Out:
# {'businesses': [{'id': 'BxNs9d8rEW3Tls-nVdmIgA',
#    'alias': 'reichenbach-hall-new-york',
#    'name': 'Reichenbach Hall',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/luuVq3iQZWeQW1gMZYHXhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/reichenbach-hall-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 772,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'german', 'title': 'German'},
#     {'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7508, 'longitude': -73.98401},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '5 W 37th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 W 37th St', 'New York, NY 10018']},
#    'phone': '+12123027744',
#    'display_phone': '(212) 302-7744',
#    'distance': 5125.789193272705},
#   {'id': 'KK2dco2CHBXQTspWBpgB9Q',
#    'alias': 'philly-pretzel-factory-forest-hills',
#    'name': 'Philly Pretzel Factory',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Slfxzv5vZAn7YnLcDyndlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/philly-pretzel-factory-forest-hills?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71448, 'longitude': -73.83215},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '118-14 Queens Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['118-14 Queens Blvd', 'Forest Hills, NY 11375']},
#    'phone': '+17184806393',
#    'display_phone': '(718) 480-6393',
#    'distance': 13701.321051688707},
#   {'id': 'TOaQzGPAIQWQUIXi4CPnbA',
#    'alias': 'radegast-hall-and-biergarten-brooklyn',
#    'name': 'Radegast Hall and Biergarten',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UZRCvkeV1EEsH45807P93Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/radegast-hall-and-biergarten-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1352,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'german', 'title': 'German'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.716641, 'longitude': -73.961498},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '113 N 3rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['113 N 3rd St', 'Brooklyn, NY 11249']},
#    'phone': '+17189633973',
#    'display_phone': '(718) 963-3973',
#    'distance': 3031.61581674316},
#   {'id': 'Q6quwwLiwx_47SRd3tItvA',
#    'alias': 'schallers-stube-sausage-bar-new-york',
#    'name': "Schaller's Stube Sausage Bar",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pKZ6bv7V1Oz8K8q0Yp5AXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/schallers-stube-sausage-bar-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 226,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.777544, 'longitude': -73.951607},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1652 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1652 2nd Ave', 'New York, NY 10028']},
#    'phone': '+16467264355',
#    'display_phone': '(646) 726-4355',
#    'distance': 8786.691519919546},
#   {'id': '5Ik9DS-wyA4aC_qBkPVL5A',
#    'alias': 'philly-pretzel-factory-hasbrouck-heights',
#    'name': 'Philly Pretzel Factory',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/i6RpQK1WIqon3SYj06vjmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/philly-pretzel-factory-hasbrouck-heights?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.85477, 'longitude': -74.07191},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '155 Route 17 S',
#     'address2': None,
#     'address3': '',
#     'city': 'Hasbrouck Heights',
#     'zip_code': '07604',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['155 Route 17 S', 'Hasbrouck Heights, NJ 07604']},
#    'phone': '+12012881800',
#    'display_phone': '(201) 288-1800',
#    'distance': 17852.07705904233},
#   {'id': 'zo4mcEfVKaktdj_gnSFhGQ',
#    'alias': 'cafe-katja-new-york',
#    'name': 'Cafe Katja',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aOQeKl7wYPmmSthza1Jj7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-katja-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 799,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'austrian', 'title': 'Austrian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7177673, 'longitude': -73.990589},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '79 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79 Orchard St', 'New York, NY 10002']},
#    'phone': '+12122199545',
#    'display_phone': '(212) 219-9545',
#    'distance': 1400.4825475532655},
#   {'id': 'exkTMrGqV-4j_z0QRVVY7Q',
#    'alias': 'billys-hot-dog-cart-new-york',
#    'name': "Billy's Hot Dog Cart",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8CHy7SNchS9EXzytPxaf9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/billys-hot-dog-cart-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'foodstands', 'title': 'Food Stands'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'},
#     {'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.78973, 'longitude': -73.9661},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '93rd St & Central Park W',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['93rd St & Central Park W', 'New York, NY 10025']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9669.48859004321},
#   {'id': 'BO8TysRpIPgJH0l6tG_Meg',
#    'alias': 'auntie-annes-pretzels-new-york-11',
#    'name': "Auntie Anne's Pretzels",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QoLd5-jSC-PVlSkg_LGYFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auntie-annes-pretzels-new-york-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.7104, 'longitude': -74.00897},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '200 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 Broadway', 'New York, NY 10038']},
#    'phone': '+19172620380',
#    'display_phone': '(917) 262-0380',
#    'distance': 1361.9078555476328},
#   {'id': 'nm5rcWNmfevNXLNQAITi5w',
#    'alias': 'clinton-hall-new-york',
#    'name': 'Clinton Hall',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jkOeBmGbclLyY3zbOa7COw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clinton-hall-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 700,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70803, 'longitude': -74.014869},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '90 Washington St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10006',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90 Washington St', 'New York, NY 10006']},
#    'phone': '+12123636000',
#    'display_phone': '(212) 363-6000',
#    'distance': 1758.0354661858244},
#   {'id': '3d4zgFXojnTZ49j12t9YKg',
#    'alias': 'the-headless-widow-new-york',
#    'name': 'The Headless Widow',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FiLzmXT9yRyxtj6d7PbIPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-headless-widow-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 75,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72658, 'longitude': -73.9863},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'location': {'address1': '99 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['99 1st Ave', 'New York, NY 10003']},
#    'phone': '+19174090446',
#    'display_phone': '(917) 409-0446',
#    'distance': 2445.63828466036},
#   {'id': '9N098o3vpvAsrb6b7eMZTw',
#    'alias': 'auntie-annes-pretzels-new-york-12',
#    'name': "Auntie Anne's Pretzels",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1tE14vJxFcuqm695YLr6Cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auntie-annes-pretzels-new-york-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.7574130555888,
#     'longitude': -73.989587659681},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '664 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['664 8th Ave', 'New York, NY 10036']},
#    'phone': '+12127641562',
#    'display_phone': '(212) 764-1562',
#    'distance': 5798.032181561367},
#   {'id': 'Utao0K7U6eny2tZTNDqziA',
#    'alias': 'wiener-bar-queens',
#    'name': 'Wiener Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EP-px64cRdviq3CQ_bw-3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wiener-bar-queens?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.695, 'longitude': -73.90433},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1539 Covert St',
#     'address2': None,
#     'address3': '',
#     'city': 'Queens',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1539 Covert St', 'Queens, NY 11385']},
#    'phone': '+13617398400',
#    'display_phone': '(361) 739-8400',
#    'distance': 7704.193501996933},
#   {'id': 'oirrpVPn9UGIKWYE-IaiJA',
#    'alias': 'martins-pretzels-new-york',
#    'name': "Martin's Pretzels",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-doyGoIZe6GfqGg-Gw7BTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/martins-pretzels-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7361877822195,
#     'longitude': -73.990522378453},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '17th Street & Broadway',
#     'address2': '',
#     'address3': 'Union Square Greenmarket',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17th Street & Broadway',
#      'Union Square Greenmarket',
#      'New York, NY 10003']},
#    'phone': '+13156284927',
#    'display_phone': '(315) 628-4927',
#    'distance': 3433.191757702274},
#   {'id': 'BqPCyiV0N8dwZ69KOUqO2w',
#    'alias': 'spritzenhaus-33-brooklyn',
#    'name': 'Spritzenhaus 33',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ni9xmpc8qegyd2ErrxooiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spritzenhaus-33-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 549,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7232908725574,
#     'longitude': -73.9527179893456},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '33 Nassau Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33 Nassau Ave', 'Brooklyn, NY 11222']},
#    'phone': '+13479874632',
#    'display_phone': '(347) 987-4632',
#    'distance': 4026.936093172967},
#   {'id': 'XLS5Gl03NJnEhINbmy_-Yg',
#    'alias': 'philly-pretzel-factory-brooklyn-2',
#    'name': 'Philly Pretzel Factory',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pgt8sTIEIDThgYHpd8P1sQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/philly-pretzel-factory-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.691791, 'longitude': -73.987572},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '408 Jay St',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['408 Jay St', 'Brooklyn, NY 11201']},
#    'phone': '+19293082228',
#    'display_phone': '(929) 308-2228',
#    'distance': 1610.278580057886},
#   {'id': 'PJeuLlvja4ZKv_tHq_pE1A',
#    'alias': 'heidelberg-restaurant-new-york',
#    'name': 'Heidelberg Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BnKnxH81g71-iKadtkOD-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heidelberg-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 707,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77742, 'longitude': -73.95172},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1648 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1648 2nd Ave', 'New York, NY 10028']},
#    'phone': '+12126282332',
#    'display_phone': '(212) 628-2332',
#    'distance': 8772.369147841455},
#   {'id': '7Bb_IDWV_zJqpBjAvxuBIA',
#    'alias': 'coopers-craft-and-kitchen-new-york-4',
#    'name': "Cooper's Craft & Kitchen",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Br01tBjG5copD4S8m1aATA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coopers-craft-and-kitchen-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 448,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72704, 'longitude': -73.9892},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '87 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['87 2nd Ave', 'New York, NY 10003']},
#    'phone': '+16466062384',
#    'display_phone': '(646) 606-2384',
#    'distance': 2440.070713751667},
#   {'id': 'ZCfqAtpASbibf_YaU1rIpw',
#    'alias': 'the-grafton-new-york',
#    'name': 'The Grafton',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/E2i9HyBA21EMILMbOm4OiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grafton-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7271881103516,
#     'longitude': -73.9851989746094},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '126 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['126 1st Ave', 'New York, NY 10009']},
#    'phone': '+12122288580',
#    'display_phone': '(212) 228-8580',
#    'distance': 2541.4632767714697},
#   {'id': 'vEIJc2FNdO7f0_KEgDkw2g',
#    'alias': 'wetzels-pretzels-brooklyn',
#    'name': "Wetzel's Pretzels",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/A5pULzcKKR28lNLQut0OGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wetzels-pretzels-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.6828485564073,
#     'longitude': -73.9776855155694},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '139 Flatbush Ave',
#     'address2': 'Ste 160',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['139 Flatbush Ave', 'Ste 160', 'Brooklyn, NY 11217']},
#    'phone': '+17183983200',
#    'display_phone': '(718) 398-3200',
#    'distance': 2876.381717194882},
#   {'id': 'osY94UfXtrynDL2nMs_bdw',
#    'alias': 'max-bratwurst-und-bier-astoria',
#    'name': 'Max Bratwurst und Bier',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WeahMxEWu0rH3UKD2FTDKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/max-bratwurst-und-bier-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 404,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7612453874006,
#     'longitude': -73.9094611979998},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '4702 30th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4702 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17187771635',
#    'display_phone': '(718) 777-1635',
#    'distance': 9465.188938384523},
#   {'id': 'ERhV0s9MsgzSV-1fPhfs0g',
#    'alias': 'the-pretzel-twister-ridgewood-2',
#    'name': 'The Pretzel Twister',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pf0Kx2uTKjJH7XmBDLv32w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pretzel-twister-ridgewood-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6996894, 'longitude': -73.9086939},
#    'transactions': [],
#    'location': {'address1': '5458 Myrtle Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5458 Myrtle Ave', 'Ridgewood, NY 11385']},
#    'phone': '+17183812218',
#    'display_phone': '(718) 381-2218',
#    'distance': 7244.119516553699},
#   {'id': 'QArou0r7CmLNPWYRA9ecog',
#    'alias': 'mcsorleys-old-ale-house-new-york',
#    'name': 'McSorleys Old Ale House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jXJs73auLg_M2_rr9z_anQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mcsorleys-old-ale-house-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1803,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'},
#     {'alias': 'breweries', 'title': 'Breweries'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72884, 'longitude': -73.98965},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '15 E 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 E 7th St', 'New York, NY 10003']},
#    'phone': '+12124739148',
#    'display_phone': '(212) 473-9148',
#    'distance': 2627.521769759495},
#   {'id': 'pYEyLT06ngEHlOtXlP64bg',
#    'alias': 'megans-new-york',
#    'name': "Megan's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Jb1dLYpTkAg-rViCM4Cw4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/megans-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 85,
#    'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7558, 'longitude': -73.98014},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '7 W 45th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 W 45th St', 'New York, NY 10036']},
#    'phone': '+12128692225',
#    'display_phone': '(212) 869-2225',
#    'distance': 5742.98867442967},
#   {'id': 'Q8rbyxLDg6rrBvi4aZuOjA',
#    'alias': 'auntie-anne-s-new-york',
#    'name': 'Auntie Anne’s',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9bKBsBl_Qg0DIUWVMYjTxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auntie-anne-s-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.7108139100342,
#     'longitude': -74.0090751601625},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '200 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 Broadway', 'New York, NY 10007']},
#    'phone': '+12125663500',
#    'display_phone': '(212) 566-3500',
#    'distance': 1381.6201984918118},
#   {'id': 'IBgjj5VBu5JJvKgo9EzKrg',
#    'alias': 'the-three-monkeys-new-york-3',
#    'name': 'The Three Monkeys',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9PvL7hV_rZUQI0AiAaGSwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-three-monkeys-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1227,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.764164, 'longitude': -73.98306},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '236 W 54th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['236 W 54th St', 'New York, NY 10019']},
#    'phone': '+12125862080',
#    'display_phone': '(212) 586-2080',
#    'distance': 6597.505592442847},
#   {'id': '7qtIemPU3LlNix8CVWdhwA',
#    'alias': 'clancey-new-york',
#    'name': 'Clancey',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/V5uFH1LIPkHyxZ3l2FV9iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clancey-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 178,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7190299, 'longitude': -73.98521},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '79 Clinton St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79 Clinton St', 'New York, NY 10002']},
#    'phone': '+19173883575',
#    'display_phone': '(917) 388-3575',
#    'distance': 1679.963011100139},
#   {'id': 'qloOSMYGRj3jqOL-7_tJlQ',
#    'alias': 'philly-pretzel-factory-new-hyde-park',
#    'name': 'Philly Pretzel Factory',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_rPIoPxygOGUc7jjgysapg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/philly-pretzel-factory-new-hyde-park?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.751812, 'longitude': -73.67277399999999},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2105 Hillside Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New Hyde Park',
#     'zip_code': '11040',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2105 Hillside Ave', 'New Hyde Park, NY 11040']},
#    'phone': '+15163231300',
#    'display_phone': '(516) 323-1300',
#    'distance': 27578.808466236707},
#   {'id': '7sQYI_Ym9RzlxHIhJpj6hg',
#    'alias': 'arts-and-crafts-beer-parlor-new-york',
#    'name': 'Arts and Crafts Beer Parlor',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2eEnARbsZqc_5CzMDadSxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arts-and-crafts-beer-parlor-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 252,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7327283010334,
#     'longitude': -73.9977158235951},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '26 W 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 W 8th St', 'New York, NY 10011']},
#    'phone': '+16466785263',
#    'display_phone': '(646) 678-5263',
#    'distance': 3047.4579245318782},
#   {'id': 'DVlV9DmZsB1iUSc60LHttg',
#    'alias': 'get-stuffed-jersey-union',
#    'name': 'Get Stuffed Jersey',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FV_s6eYNlKPdW7j_4L8D7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/get-stuffed-jersey-union?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 136,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7050887, 'longitude': -74.2953438},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2705 Morris Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Union',
#     'zip_code': '07083',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['2705 Morris Ave', 'Union, NJ 07083']},
#    'phone': '+18624000505',
#    'display_phone': '(862) 400-0505',
#    'distance': 25376.75642718807},
#   {'id': 'K_e7_aNgghFLZ2zvjFSNkQ',
#    'alias': 'loreley-beer-garden-new-york-2',
#    'name': 'Loreley Beer Garden',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OnN4ZY1nvIwRuST8Y96UZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/loreley-beer-garden-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 768,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7212291, 'longitude': -73.992872},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '7 Rivington St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 Rivington St', 'New York, NY 10002']},
#    'phone': '+12122537077',
#    'display_phone': '(212) 253-7077',
#    'distance': 1759.2078116057417},
#   {'id': '5NdHeWLgrXhIySx9ogCNQg',
#    'alias': 'leitao-new-york-2',
#    'name': 'Leitao',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AjhlmJvhH-JJpwGmfw3Tfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/leitao-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 252,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'portuguese', 'title': 'Portuguese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73493, 'longitude': -74.00641},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '547 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['547 Hudson St', 'New York, NY 10014']},
#    'phone': '+12128109944',
#    'display_phone': '(212) 810-9944',
#    'distance': 3434.2098209393425},
#   {'id': '61Tl42ENbjLAAIkZjN7qfw',
#    'alias': 'berlin-currywurst-new-york-3',
#    'name': 'Berlin Currywurst',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eJz2pS0DtYxs52iHxJkfsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/berlin-currywurst-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74222, 'longitude': -74.00466},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '75 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 9th Ave', 'New York, NY 10011']},
#    'phone': '+16468273689',
#    'display_phone': '(646) 827-3689',
#    'distance': 4160.424215067582},
#   {'id': 'rrsjcQVLg2PkIkO_vPjOLw',
#    'alias': 'the-bonnie-astoria',
#    'name': 'The Bonnie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/q8q8I6EzAWGdnd1ewxbxmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bonnie-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 687,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7746737, 'longitude': -73.9136003},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '29-12 23rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['29-12 23rd Ave', 'Astoria, NY 11105']},
#    'phone': '+17182742105',
#    'display_phone': '(718) 274-2105',
#    'distance': 10270.114461034447},
#   {'id': '-6tSx9IXwt1btreBtcyZ0g',
#    'alias': 'würstbar-jersey-city',
#    'name': 'Würstbar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MEiXmMiFIhEzy3BLRohWMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/w%C3%BCrstbar-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 390,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72038, 'longitude': -74.04648},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '516 Jersey Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['516 Jersey Ave', 'Jersey City, NJ 07302']},
#    'phone': '+12014798396',
#    'display_phone': '(201) 479-8396',
#    'distance': 4715.423325111628},
#   {'id': 'F622poZMX_mk1eoSoUOyaw',
#    'alias': 'the-biergarten-at-the-standard-high-line-new-york',
#    'name': 'The Biergarten at The Standard, High Line',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oE3_rXk3WFK3OyP33sDvjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-biergarten-at-the-standard-high-line-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 886,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'german', 'title': 'German'},
#     {'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.740799, 'longitude': -74.007907},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '848 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['848 Washington St', 'New York, NY 10014']},
#    'phone': '+12126454100',
#    'display_phone': '(212) 645-4100',
#    'distance': 4099.042539416837},
#   {'id': 'FSVUSpd-gsbxNiupEvmT6g',
#    'alias': 'auntie-annes-pretzels-new-york-8',
#    'name': "Auntie Anne's Pretzels",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/96gS8Vk9-LHsK3mLR_qdHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auntie-annes-pretzels-new-york-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7504037325136,
#     'longitude': -73.9891191041158},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '151 W 34th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['151 W 34th St', 'New York, NY 10001']},
#    'phone': '+12125940018',
#    'display_phone': '(212) 594-0018',
#    'distance': 5051.9675866675525},
#   {'id': 'h5WkewI6U7NjLB_n6WgdvQ',
#    'alias': 'handcraft-kitchen-and-cocktails-new-york',
#    'name': 'HandCraft Kitchen & Cocktails',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tCQy7V4OL5T393GytLBeRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/handcraft-kitchen-and-cocktails-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 432,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.740967, 'longitude': -73.981292},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '367 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['367 3rd Ave', 'New York, NY 10016']},
#    'phone': '+12126893000',
#    'display_phone': '(212) 689-3000',
#    'distance': 4100.3818380199},
#   {'id': 'mPzHZd0GRFQBhn4YU7kQog',
#    'alias': 'pretzel-stop-rockville-centre',
#    'name': 'Pretzel Stop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NpGEiKZkr7S_7WSbFAJDCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pretzel-stop-rockville-centre?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.651114, 'longitude': -73.636446},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '106 S Long Beach Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Rockville Centre',
#     'zip_code': '11570',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['106 S Long Beach Rd', 'Rockville Centre, NY 11570']},
#    'phone': '+15165435050',
#    'display_phone': '(516) 543-5050',
#    'distance': 30775.33490648571},
#   {'id': '-0bdnX762vdTb9lI00etvA',
#    'alias': 'brooklyn-burgers-and-beer-brooklyn',
#    'name': 'Brooklyn Burgers & Beer',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Xt6uxV5pTXQ_c1gdJytrYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-burgers-and-beer-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 382,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6743507, 'longitude': -73.9815826},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '259 5th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['259 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187881458',
#    'display_phone': '(718) 788-1458',
#    'distance': 3610.69044291405},
#   {'id': '5WD82Wg_s4bh5K0f3ZwnxQ',
#    'alias': 'black-forest-brooklyn-brooklyn-2',
#    'name': 'Black Forest Brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/s0_CJfWE_S66sziuhlnWsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-forest-brooklyn-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 94,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'german', 'title': 'German'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68563, 'longitude': -73.990823},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '181 Smith St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['181 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17185221806',
#    'display_phone': '(718) 522-1806',
#    'distance': 2221.076565579013},
#   {'id': 'lMy1BYJ5HX8TccXTBwdRNg',
#    'alias': 'covenhoven-brooklyn',
#    'name': 'Covenhoven',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QL24a3HEKWq_5MHt_m-i-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/covenhoven-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 139,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.675246, 'longitude': -73.960244},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '730 Classon Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['730 Classon Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17184839950',
#    'display_phone': '(718) 483-9950',
#    'distance': 4417.8365326838175},
#   {'id': 'oFDKXoHhSBQgDGjADLfQEg',
#    'alias': 'the-brooklyn-brewery-brooklyn',
#    'name': 'The Brooklyn Brewery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/syfYpBWVaFCk4UpLfW2VGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-brooklyn-brewery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1002,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.721636270191,
#     'longitude': -73.9576329544152},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '79 N 11th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79 N 11th St', 'Brooklyn, NY 11211']},
#    'phone': '+17184867422',
#    'display_phone': '(718) 486-7422',
#    'distance': 3576.120056136586},
#   {'id': 'bfswNnIxzJrSr06MjsXJ3g',
#    'alias': 'schallers-stube-brooklyn',
#    'name': "Schaller's Stube",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gKbky2wqsXMfuOVAqykyQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/schallers-stube-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.691005, 'longitude': -73.982934},
#    'transactions': [],
#    'location': {'address1': '445 Albee Square W',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['445 Albee Square W', 'Brooklyn, NY 11201']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1868.4980548111632},
#   {'id': '5f3M0k7mTjrKoQFJW-PFzg',
#    'alias': 'lock-yard-brooklyn',
#    'name': 'Lock Yard',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/F018zat3Yzuu86WtVn7Ifg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lock-yard-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 298,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.617264, 'longitude': -74.029419},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '9221 5th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9221 5th Ave', 'Brooklyn, NY 11209']},
#    'phone': '+17183335282',
#    'display_phone': '(718) 333-5282',
#    'distance': 10238.34981935419},
#   {'id': '3ESlPTtjsEsyI5jhJFvBbw',
#    'alias': 'the-porterhouse-brewing-company-new-york',
#    'name': 'The Porterhouse Brewing Company',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kNhvT9F8RGbRkd2zZRmE3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-porterhouse-brewing-company-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 122,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7032627, 'longitude': -74.0107867},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '36 Water St',
#     'address2': '',
#     'address3': '58 Pearl St',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['36 Water St', '58 Pearl St', 'New York, NY 10004']},
#    'phone': '+12124257171',
#    'display_phone': '(212) 425-7171',
#    'distance': 1405.968175059443},
#   {'id': 'NA_p2AH5RSBV314bklZn_g',
#    'alias': 'stone-street-tavern-new-york',
#    'name': 'Stone Street Tavern',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rNoIlPTFMYjlNLGazrv6fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stone-street-tavern-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 442,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7043685019016,
#     'longitude': -74.0102007240057},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '52 Stone St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['52 Stone St', 'New York, NY 10004']},
#    'phone': '+12127855658',
#    'display_phone': '(212) 785-5658',
#    'distance': 1346.2447255271536},
#   {'id': '-2aMphgYYnoxncuZ7xI3Gw',
#    'alias': 'bierhaus-nyc-new-york-4',
#    'name': 'Bierhaus NYC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/150yhnGbxKhRi5iDur4hqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bierhaus-nyc-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 889,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'karaoke', 'title': 'Karaoke'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.75261, 'longitude': -73.97342},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '712 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['712 3rd Ave', 'New York, NY 10017']},
#    'phone': '+12128672337',
#    'display_phone': '(212) 867-2337',
#    'distance': 5531.595364231468},
#   {'id': 'va93RJg_tlMcgwBQoIoPaw',
#    'alias': 'philly-pretzel-factory-bayonne-3',
#    'name': 'Philly Pretzel Factory',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sFuKQvtEPG2uOZJ_acm1Yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/philly-pretzel-factory-bayonne-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.671602, 'longitude': -74.111973},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '713 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Bayonne',
#     'zip_code': '07002',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['713 Broadway', 'Bayonne, NJ 07002']},
#    'phone': '+12014552811',
#    'display_phone': '(201) 455-2811',
#    'distance': 10611.83505384504},
#   {'id': 'PxyxNj43WSDjRF588HFJdQ',
#    'alias': 'the-craic-brooklyn',
#    'name': 'The Craic',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Gw35g-fCsIMz_IbNCfHKGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-craic-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 104,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71852, 'longitude': -73.95504},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '488 Driggs Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['488 Driggs Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13473842772',
#    'display_phone': '(347) 384-2772',
#    'distance': 3613.832837477861},
#   {'id': '6Q2DGEIUOdiMIl0MR6g0IA',
#    'alias': 'beer-street-brooklyn',
#    'name': 'Beer Street',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KGbzO87Z6eCHifnxanV81w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beer-street-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71724, 'longitude': -73.945},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '413 Graham Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['413 Graham Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13472940495',
#    'display_phone': '(347) 294-0495',
#    'distance': 4348.478504318845}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                      Restaurant      Type Price Rating             Address  \
# 0              Reichenbach Hall      Bars    $$      4         5 W 37th St
# 1        Philly Pretzel Factory  Pretzels               118-14 Queens Blvd
# 2  Radegast Hall and Biergarten      Pubs    $$      4        113 N 3rd St
# 3  Schaller's Stube Sausage Bar    German    $$      4        1652 2nd Ave
# 4        Philly Pretzel Factory  Pretzels                   155 Route 17 S
#
#          Lat        Lng                                                url  \
# 0  40.750800 -73.984010  https://www.yelp.com/biz/reichenbach-hall-new-...
# 1  40.714480 -73.832150
# 2  40.716641 -73.961498  https://www.yelp.com/biz/radegast-hall-and-bie...
# 3  40.777544 -73.951607  https://www.yelp.com/biz/schallers-stube-sausa...
# 4  40.854770 -74.071910
#
#                        ID
# 0  BxNs9d8rEW3Tls-nVdmIgA
# 1
# 2  TOaQzGPAIQWQUIXi4CPnbA
# 3  Q6quwwLiwx_47SRd3tItvA
# 4

# %%
#2nd set of 50 records 51-100 
nycr_params2 = {"term":"pretzel","location":"New York","limit":50,"offset":51}
nycr_response2 = requests.get(search_api_url, headers=headers, params=nycr_params2)
nycr2 = nycr_response2.json()
display(nycr2)
#print(nycr_response2.url)
#print(nycr_response2.status_code)
# Out:
# {'businesses': [{'id': 'eCtDCj1Mbl5VFihJQroGvw',
#    'alias': 'pretzelmaker-elmhurst-2',
#    'name': 'Pretzelmaker',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pyP-hkSDxNnqo3sUYMSkPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pretzelmaker-elmhurst-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7345846283472,
#     'longitude': -73.869032499128},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '90 15 Queens Blvd',
#     'address2': 'Space K10',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90 15 Queens Blvd',
#      'Space K10',
#      'Elmhurst, NY 11373']},
#    'phone': '+17182715178',
#    'display_phone': '(718) 271-5178',
#    'distance': 11042.461639924073},
#   {'id': '3K8Z8S7bsVI1w9QjUelbag',
#    'alias': 'hasenstüble-brooklyn-2',
#    'name': 'HasenStüble',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kVLn4TrBdxqetmf8SedaFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hasenst%C3%BCble-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.658609, 'longitude': -73.950605},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1184 Nostrand Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11225',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1184 Nostrand Ave', 'Brooklyn, NY 11225']},
#    'phone': '+13472405191',
#    'display_phone': '(347) 240-5191',
#    'distance': 6379.15775332685},
#   {'id': '5fMNw2pZmXB2jF81cqjy1g',
#    'alias': 'philly-pretzel-factory-lynbrook',
#    'name': 'Philly Pretzel Factory',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sXCpTFN4hqzfWI1AcnI6Yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/philly-pretzel-factory-lynbrook?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.654072, 'longitude': -73.6756531},
#    'transactions': [],
#    'location': {'address1': '118 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Lynbrook',
#     'zip_code': '11563',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['118 Broadway', 'Lynbrook, NY 11563']},
#    'phone': '+15165178111',
#    'display_phone': '(516) 517-8111',
#    'distance': 27469.549538977597},
#   {'id': 'QzZlCAp7Qp7nBP7kRuGuNg',
#    'alias': 'harlem-hops-new-york-2',
#    'name': 'Harlem Hops',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6AmF33DK3pNEc-Wl4K6roA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harlem-hops-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 125,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.81444, 'longitude': -73.9448},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2268 Adam Clayton Powell Jr Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10030',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2268 Adam Clayton Powell Jr Blvd',
#      'New York, NY 10030']},
#    'phone': '+16469983444',
#    'display_phone': '(646) 998-3444',
#    'distance': 12821.080616066774},
#   {'id': 'z5z9ji_ABjylFPjiQgoSWw',
#    'alias': 'gretels-pretzels-brooklyn',
#    'name': "Gretel's Pretzels",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2KN11Qxf8QgXeI0QVV4YQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gretels-pretzels-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.61896, 'longitude': -73.922655},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '5371 Kings Plz Mall',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11234',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5371 Kings Plz Mall', 'Brooklyn, NY 11234']},
#    'phone': '+17182583828',
#    'display_phone': '(718) 258-3828',
#    'distance': 11357.504895525313},
#   {'id': 'Ad3JpyadCNBDKZiKD57Tbw',
#    'alias': 'the-brooklyneer-new-york',
#    'name': 'The Brooklyneer',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jaXkxLdPWGiuDNAo9dxqsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-brooklyneer-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 253,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7286219, 'longitude': -74.0045657},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '220 W Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['220 W Houston St', 'New York, NY 10014']},
#    'phone': '+16466924911',
#    'display_phone': '(646) 692-4911',
#    'distance': 2718.697554451463},
#   {'id': '5grFfuYswh8K9GoEnOy81A',
#    'alias': 'bierocracy-long-island-city-2',
#    'name': 'Bierocracy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mybTXtdDICBftt497mJiBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bierocracy-long-island-city-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 316,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74402, 'longitude': -73.95028},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '12-23 Jackson Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['12-23 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+17183619333',
#    'display_phone': '(718) 361-9333',
#    'distance': 5665.738793712728},
#   {'id': 'I3boMDez9rUejzf7EyT2Dg',
#    'alias': 'jagerhaus-german-restaurant-and-biergarten-whitestone-3',
#    'name': 'Jagerhaus German Restaurant & Biergarten',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PiJ4cN9RhWJ0_QZs-M2O6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jagerhaus-german-restaurant-and-biergarten-whitestone-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 282,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78663, 'longitude': -73.81654},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1516 149th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Whitestone',
#     'zip_code': '11357',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1516 149th St', 'Whitestone, NY 11357']},
#    'phone': '+17187673486',
#    'display_phone': '(718) 767-3486',
#    'distance': 17491.46255774265},
#   {'id': 'rEw0U5tN2gTwoFrd-Yfsog',
#    'alias': 'schnitzel-haus-brooklyn',
#    'name': 'Schnitzel Haus',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VhIwOq4phguge0ZAbhbkYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/schnitzel-haus-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 313,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.630358, 'longitude': -74.021959},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '7319 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7319 5th Ave', 'Brooklyn, NY 11209']},
#    'phone': '+17188365600',
#    'display_phone': '(718) 836-5600',
#    'distance': 8669.191928039076},
#   {'id': '1L0pkxU2QqOkOg2drzqtPA',
#    'alias': 'randolph-beer-brooklyn-5',
#    'name': 'Randolph Beer',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kaxWETuXI2DpYF2qL3j4Dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/randolph-beer-brooklyn-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 392,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7120096, 'longitude': -73.9634612},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '104 S 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['104 S 4th St', 'Brooklyn, NY 11249']},
#    'phone': '+16463833623',
#    'display_phone': '(646) 383-3623',
#    'distance': 2699.3880145899193},
#   {'id': 'n8p5g3-Fu1RBKx35QhiaXg',
#    'alias': 'bua-new-york',
#    'name': 'Bua',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0X-HBJC7dDEdaAqz_0MiOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bua-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 531,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7268537, 'longitude': -73.9838067},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '122 St Marks Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['122 St Marks Pl', 'New York, NY 10009']},
#    'phone': '+12129796276',
#    'display_phone': '(212) 979-6276',
#    'distance': 2539.317914220864},
#   {'id': 'iBEWDOTIl2wVxEAVZslR_w',
#    'alias': 'philly-pretzel-factory-clifton',
#    'name': 'Philly Pretzel Factory',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AM5u0ebFB6dsS1iN57QWUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/philly-pretzel-factory-clifton?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.86563, 'longitude': -74.159},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '859 Clifton Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Clifton',
#     'zip_code': '07013',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['859 Clifton Ave', 'Clifton, NJ 07013']},
#    'phone': '+19738260159',
#    'display_phone': '(973) 826-0159',
#    'distance': 22552.28812860336},
#   {'id': 'GlSWzWVmQsKLGxySYSGRbQ',
#    'alias': 'smithfield-hall-new-york-5',
#    'name': 'Smithfield Hall',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/b_11vLu_Gkc-Ph51zuB18A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/smithfield-hall-new-york-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 487,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7447532620452,
#     'longitude': -73.9934939850447},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '138 W 25th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['138 W 25th St', 'New York, NY 10001']},
#    'phone': '+12129299677',
#    'display_phone': '(212) 929-9677',
#    'distance': 4371.408398892504},
#   {'id': '8vwANffgp9s9RDCSn3mD5w',
#    'alias': 'keg-and-lantern-brewing-company-brooklyn',
#    'name': 'Keg & Lantern Brewing Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MjkTGWY5zxD5d9gtCk0G_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/keg-and-lantern-brewing-company-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 273,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'brewpubs', 'title': 'Brewpubs'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.724054, 'longitude': -73.950341},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '97 Nassau Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['97 Nassau Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183895050',
#    'display_phone': '(718) 389-5050',
#    'distance': 4243.131078510608},
#   {'id': 'D2qV8sDdHEFlHbVz7VSHRQ',
#    'alias': 'black-tap-soho-new-york-3',
#    'name': 'Black Tap - Soho',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CNTqbEKz1aBB9tzQ1hJwSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-tap-soho-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1249,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.723794, 'longitude': -74.004193},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '529 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['529 Broome St', 'New York, NY 10013']},
#    'phone': '+19176393089',
#    'display_phone': '(917) 639-3089',
#    'distance': 2204.3415650587467},
#   {'id': 'j3HLOkrjzBjcvYPiIHua1A',
#    'alias': 'jaspers-taphouse-kitchen-new-york',
#    'name': "Jasper's Taphouse + Kitchen",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lR6IRt49Vzr2YxABYh76aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jaspers-taphouse-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 388,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.764266, 'longitude': -73.9886122},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '761 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['761 9th Ave', 'New York, NY 10019']},
#    'phone': '+12129571000',
#    'display_phone': '(212) 957-1000',
#    'distance': 6558.096207195189},
#   {'id': 'FE18d2zjFRPzr4gHV2kYXw',
#    'alias': 'island-soft-pretzel-stop-staten-island',
#    'name': 'Island Soft Pretzel Stop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Syu1tUrKqNGiI8BZwQmoXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/island-soft-pretzel-stop-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.64251, 'longitude': -74.0737},
#    'transactions': [],
#    'location': {'address1': 'St George Ferry Terminal',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10301',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['St George Ferry Terminal',
#      'Staten Island, NY 10301']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9491.326757846056},
#   {'id': 'NVp1S29NLR573Lc4ZvICKw',
#    'alias': 'forest-hills-station-house-forest-hills',
#    'name': 'Forest Hills Station House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tG5GRRJA-aL_tQHl5OGrWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/forest-hills-station-house-forest-hills?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1166,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720035691092825,
#     'longitude': -73.84509507330708},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '106-11 71st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['106-11 71st Ave', 'Forest Hills, NY 11375']},
#    'phone': '+17185445000',
#    'display_phone': '(718) 544-5000',
#    'distance': 12679.314707030817},
#   {'id': '28q-EaDlKgYNeaF7-LXXqg',
#    'alias': 'lavender-lake-brooklyn',
#    'name': 'Lavender Lake',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xc720iC989jRcGHjWhMaqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lavender-lake-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 279,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6786075, 'longitude': -73.9901923},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '383 Carroll St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['383 Carroll St', 'Brooklyn, NY 11231']},
#    'phone': '+13477992154',
#    'display_phone': '(347) 799-2154',
#    'distance': 3004.138276609909},
#   {'id': 'VBa_hZ0COXmmN7cKJvfLWg',
#    'alias': 'philly-pretzel-factory-staten-island',
#    'name': 'Philly Pretzel Factory',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_Dnkk630x68Pww7iFDYAsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/philly-pretzel-factory-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.629833, 'longitude': -74.109413},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '604 Forest Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10310',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['604 Forest Ave', 'Staten Island, NY 10310']},
#    'phone': '+17189812951',
#    'display_phone': '(718) 981-2951',
#    'distance': 12841.298645824421},
#   {'id': 'XDDZM7EbanRJiZlOlCjHJg',
#    'alias': 'interboro-spirits-and-ales-brooklyn',
#    'name': 'Interboro Spirits and Ales',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/l6mhB6y9QGiuW8ttm3O0Gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/interboro-spirits-and-ales-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#     {'alias': 'distilleries', 'title': 'Distilleries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.712598, 'longitude': -73.936906},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '942 Grand St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['942 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+18778436545',
#    'display_phone': '(877) 843-6545',
#    'distance': 4900.699354564312},
#   {'id': 'yOPbrFZ2ZUsyQWsedP6gUg',
#    'alias': 'amity-hall-uptown-new-york',
#    'name': 'Amity Hall Uptown',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YMq7T_kIoHKo2AQJ_37Olg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amity-hall-uptown-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 238,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.80231, 'longitude': -73.96475},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '982 Amsterdam Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['982 Amsterdam Ave', 'New York, NY 10025']},
#    'phone': '+16469302501',
#    'display_phone': '(646) 930-2501',
#    'distance': 11043.985508056334},
#   {'id': '2Mia4J1QKd247oh2IkuEdg',
#    'alias': 'the-cauldron-nyc-new-york',
#    'name': 'The Cauldron NYC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ApDXlNA0MdnrdIC_ow7Wvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cauldron-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 232,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7043756, 'longitude': -74.0105259},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '47 Stone St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 Stone St', 'New York, NY 10004']},
#    'phone': '+19176351960',
#    'display_phone': '(917) 635-1960',
#    'distance': 1373.480237917608},
#   {'id': 'Esgyg0dRzBQJFMuVSaCYww',
#    'alias': 'as-is-nyc-new-york',
#    'name': 'As Is NYC',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/C-Xg9OXOpZOFZZnwjYpWJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/as-is-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 220,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7645799, 'longitude': -73.9914759},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '734 10th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['734 10th Ave', 'New York, NY 10019']},
#    'phone': '+16468581153',
#    'display_phone': '(646) 858-1153',
#    'distance': 6579.791900915277},
#   {'id': 'Y0V1YQ5vsKaQcEB_m80rvQ',
#    'alias': 'philly-pretzel-factory-long-beach',
#    'name': 'Philly Pretzel Factory',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/goqx_L9GssAXeJaD7DgR6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/philly-pretzel-factory-long-beach?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.588195, 'longitude': -73.659947},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '134 East Park Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Beach',
#     'zip_code': '11561',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['134 East Park Ave', 'Long Beach, NY 11561']},
#    'phone': '+15166080339',
#    'display_phone': '(516) 608-0339',
#    'distance': 31075.264425418707},
#   {'id': '9hOtQc38qBmFWZP281Mkmw',
#    'alias': 'coney-island-brewery-brooklyn',
#    'name': 'Coney Island Brewery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jUfr6iI9KkAkQzlM-Ooh-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coney-island-brewery-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 162,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.574764, 'longitude': -73.984426},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1904 Surf Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11224',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1904 Surf Ave', 'Brooklyn, NY 11224']},
#    'phone': '+17189960019',
#    'display_phone': '(718) 996-0019',
#    'distance': 14554.86430228145},
#   {'id': 'CjSLDlOGzyHcJPwYXZQsWw',
#    'alias': 'clinton-hall-new-york-4',
#    'name': 'Clinton Hall',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bF-w_PFm7P0tJZx0U3SF1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clinton-hall-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 183,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7558, 'longitude': -73.96905},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '230 E 51st St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['230 E 51st St', 'New York, NY 10022']},
#    'phone': '+12127588519',
#    'display_phone': '(212) 758-8519',
#    'distance': 5980.894291773265},
#   {'id': 'InN3vm86FcWhmgsrl-tCUA',
#    'alias': 'philly-pretzel-factory-franklin-square',
#    'name': 'Philly Pretzel Factory',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yoeJ_1ltm2YmZ36sL7sl3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/philly-pretzel-factory-franklin-square?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.702619, 'longitude': -73.678643},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '197 Franklin Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Franklin Square',
#     'zip_code': '11010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['197 Franklin Ave', 'Franklin Square, NY 11010']},
#    'phone': '+15164073300',
#    'display_phone': '(516) 407-3300',
#    'distance': 26609.732131697692},
#   {'id': 'Fm1mE5Hf2k-yuzmFz98ufw',
#    'alias': 'manor-oktoberfest-forest-hills-46',
#    'name': 'Manor Oktoberfest',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HA4UyTO0j9w2WHuTTdXVrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/manor-oktoberfest-forest-hills-46?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 284,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7174275, 'longitude': -73.8569518},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '73-11 Yellowstone Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['73-11 Yellowstone Blvd', 'Forest Hills, NY 11375']},
#    'phone': '+17185442400',
#    'display_phone': '(718) 544-2400',
#    'distance': 11658.718614399377},
#   {'id': '4ccWWNAXWq-BESeZwZVV6A',
#    'alias': 'arts-and-crafts-beer-parlor-morningside-heights-new-york-2',
#    'name': 'Arts and Crafts Beer Parlor - Morningside Heights',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wDELcXIkY5B5gk277B1djA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arts-and-crafts-beer-parlor-morningside-heights-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 67,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'publicart', 'title': 'Public Art'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.8065912, 'longitude': -73.9610353},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1135 Amsterdam Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1135 Amsterdam Ave', 'New York, NY 10025']},
#    'phone': '+19176756835',
#    'display_phone': '(917) 675-6835',
#    'distance': 11588.684276364913},
#   {'id': 'jhpeHVxJSmGdD61MTrKi7A',
#    'alias': 'salud-bar-and-grill-brooklyn',
#    'name': 'Salud Bar & Grill',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LKlgWGpWe8DN_n49mCQXWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salud-bar-and-grill-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 322,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6846559, 'longitude': -73.9090595},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1413 Bushwick Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11207',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1413 Bushwick Ave', 'Brooklyn, NY 11207']},
#    'phone': '+13473657257',
#    'display_phone': '(347) 365-7257',
#    'distance': 7548.452581017486},
#   {'id': '6UTTxRRihdrtahlR0tO4ug',
#    'alias': 'auntie-annes-pretzels-brooklyn-9',
#    'name': "Auntie Anne's Pretzels",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Juq0pf7mm71-N1co_ui9qQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auntie-annes-pretzels-brooklyn-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.6323, 'longitude': -73.94735},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1570 Flatbush Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11210',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1570 Flatbush Ave', 'Brooklyn, NY 11210']},
#    'phone': '+18453104083',
#    'display_phone': '(845) 310-4083',
#    'distance': 9045.658731431335},
#   {'id': 'eC6L0M5BfLwpmmkPQE0WSw',
#    'alias': 'the-ferryman-on-1st-hoboken',
#    'name': 'The Ferryman on 1st',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lPsyQqh2_Wlxrdu8ZQ17MA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ferryman-on-1st-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wraps', 'title': 'Wraps'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7373766, 'longitude': -74.0319336},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '94-98 Bloomfield St',
#     'address2': None,
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['94-98 Bloomfield St', 'Hoboken, NJ 07030']},
#    'phone': '+12014209222',
#    'display_phone': '(201) 420-9222',
#    'distance': 4771.572570228141},
#   {'id': 'u5pK1oszIUvrnDRLKwifqA',
#    'alias': 'pilsener-haus-and-biergarten-hoboken',
#    'name': 'Pilsener Haus & Biergarten',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5T0SiDIQ5yhS1K6HB9qBnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pilsener-haus-and-biergarten-hoboken?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 810,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7552077, 'longitude': -74.0314563558197},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1422 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1422 Grand St', 'Hoboken, NJ 07030']},
#    'phone': '+12016835465',
#    'display_phone': '(201) 683-5465',
#    'distance': 6357.997848641078},
#   {'id': 'XaAj9qfWoQ048-5D9ciX-g',
#    'alias': 'nostrand-avenue-pub-brooklyn',
#    'name': 'Nostrand Avenue Pub',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eXiz_yK1IsyK0vCGR5DryQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nostrand-avenue-pub-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 96,
#    'categories': [{'alias': 'whiskeybars', 'title': 'Whiskey Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.675862, 'longitude': -73.950236},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '658 Nostrand Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['658 Nostrand Ave', 'Brooklyn, NY 11216']},
#    'phone': '+17184839699',
#    'display_phone': '(718) 483-9699',
#    'distance': 4961.711897608545},
#   {'id': '7lypfdhsYBgdsL2dr4MoWw',
#    'alias': 'the-shepherd-and-the-knucklehead-of-hoboken-hoboken-2',
#    'name': 'The Shepherd & the Knucklehead of Hoboken',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5-pplZzrD0z7f3GlYYr4ag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-shepherd-and-the-knucklehead-of-hoboken-hoboken-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 123,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.753251, 'longitude': -74.029507},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1313 Willow Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1313 Willow Ave', 'Hoboken, NJ 07030']},
#    'phone': '+12017144222',
#    'display_phone': '(201) 714-4222',
#    'distance': 6087.868782487722},
#   {'id': 'hKChLzaG8tyrSrg3U_wRNw',
#    'alias': 'threes-brewing-brooklyn',
#    'name': 'Threes Brewing',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8dKcvHxK-z5Okc2mRyMWgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/threes-brewing-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 402,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6797218322754,
#     'longitude': -73.9821624755859},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '333 Douglass St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['333 Douglass St', 'Brooklyn, NY 11217']},
#    'phone': '+17185689673',
#    'display_phone': '(718) 568-9673',
#    'distance': 3039.305665185108},
#   {'id': 'h1bYtCaLRAlJjydNAyGlmQ',
#    'alias': 'auntie-annes-pretzels-jersey-city-4',
#    'name': "Auntie Anne's Pretzels",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yTGSSBGydb9Hmorx1vbHxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auntie-annes-pretzels-jersey-city-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.72681, 'longitude': -74.036997},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '30 Mall Dr W',
#     'address2': '2nd. Lvl',
#     'address3': 'Newport Center Mall',
#     'city': 'Jersey City',
#     'zip_code': '07310',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['30 Mall Dr W',
#      '2nd. Lvl',
#      'Newport Center Mall',
#      'Jersey City, NJ 07310']},
#    'phone': '+12012229149',
#    'display_phone': '(201) 222-9149',
#    'distance': 4312.459972908592},
#   {'id': '_NS1hEZ0LPwaTG4R6jxgnw',
#    'alias': 'cafe-sabarsky-new-york-4',
#    'name': 'Cafe Sabarsky',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8dk88iFlkJH7R720j_igQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-sabarsky-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 505,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'austrian', 'title': 'Austrian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78122494966741,
#     'longitude': -73.9602662713214},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1048 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1048 5th Ave', 'New York, NY 10028']},
#    'phone': '+12122880665',
#    'display_phone': '(212) 288-0665',
#    'distance': 8900.614315463365},
#   {'id': 'R7AngT3-6uRGs-rSUivOfQ',
#    'alias': 'philly-pretzel-factory-edison',
#    'name': 'Philly Pretzel Factory',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iSIkmACcos2GK2XK64frNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/philly-pretzel-factory-edison?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.534, 'longitude': -74.33407},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '960 Amboy Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Edison',
#     'zip_code': '08837',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['960 Amboy Ave', 'Edison, NJ 08837']},
#    'phone': '+17322254567',
#    'display_phone': '(732) 225-4567',
#    'distance': 34439.4718478595},
#   {'id': 'l_hBcWIFx_ausYBxLkSglQ',
#    'alias': 'olivers-astoria-astoria',
#    'name': "Oliver's Astoria",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uCxKb58kkXmYW75DMspSjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olivers-astoria-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 522,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7595239, 'longitude': -73.9198044},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3719 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3719 Broadway', 'Astoria, NY 11103']},
#    'phone': '+17188061476',
#    'display_phone': '(718) 806-1476',
#    'distance': 8692.117539958672},
#   {'id': 'GRTwWIa4uF9m7cxUYYRilA',
#    'alias': 'talea-beer-brooklyn',
#    'name': 'TALEA Beer',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SYmrJ4BNRwBVDKsziTQIeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/talea-beer-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 66,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breweries', 'title': 'Breweries'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71873729578213,
#     'longitude': -73.94819947258614},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '87 Richardson St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['87 Richardson St', 'Brooklyn, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4156.68671241729},
#   {'id': 'VP_HZr_j0dXKd80lUBfsyg',
#    'alias': 'the-wicked-monk-brooklyn-3',
#    'name': 'The Wicked Monk',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/20iRdBR9AZMUpIddAypQVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wicked-monk-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 257,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.616988, 'longitude': -74.034023},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '9510 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9510 3rd Ave', 'Brooklyn, NY 11209']},
#    'phone': '+13474975152',
#    'display_phone': '(347) 497-5152',
#    'distance': 10391.163639112341},
#   {'id': 'VRXwdcYLqYhuF-tzIdvINw',
#    'alias': 'dsk-brooklyn-brooklyn',
#    'name': 'DSK Brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JhOgZuF6_3cy_Kivugq53g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dsk-brooklyn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 246,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6857666, 'longitude': -73.9735353},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '710 Fulton St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['710 Fulton St', 'Brooklyn, NY 11217']},
#    'phone': '+13478414495',
#    'display_phone': '(347) 841-4495',
#    'distance': 2801.864016748146},
#   {'id': 'XA7phnS0fBfLR8xdsngiUQ',
#    'alias': 'gottscheer-hall-ridgewood',
#    'name': 'Gottscheer Hall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gOLNWBRYfJfwA_m5_WhgZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gottscheer-hall-ridgewood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'catering', 'title': 'Caterers'},
#     {'alias': 'german', 'title': 'German'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.706891, 'longitude': -73.905479},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '657 Fairview Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['657 Fairview Ave', 'Ridgewood, NY 11385']},
#    'phone': '+17183663030',
#    'display_phone': '(718) 366-3030',
#    'distance': 7493.100665139834},
#   {'id': 'zHh6ioC3tSXBFhXXuXrL8A',
#    'alias': 'gebhards-beer-culture-new-york',
#    'name': "Gebhard's Beer Culture",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4fJSuQuqQcw0gkxaRCtcMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gebhards-beer-culture-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 142,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.778946, 'longitude': -73.983219},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '228 W 72nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 W 72nd St', 'New York, NY 10023']},
#    'phone': '+19176393420',
#    'display_phone': '(917) 639-3420',
#    'distance': 8226.022946513258},
#   {'id': 'PMp7WlHIXQUnej-Ds1jRfw',
#    'alias': 'blind-tiger-ale-house-new-york',
#    'name': 'Blind Tiger Ale House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/em6l-CtzWbuca3-Y9lRMsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blind-tiger-ale-house-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 902,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.731926, 'longitude': -74.003223},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '281 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['281 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12124624682',
#    'display_phone': '(212) 462-4682',
#    'distance': 3039.2154288142483},
#   {'id': 'f5csvsEkOEdBWLeBOdZcLg',
#    'alias': 'beer-culture-new-york',
#    'name': 'Beer Culture',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WOm4hjl6eSldS5KqBNyadA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beer-culture-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 368,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7596004712907,
#     'longitude': -73.9897146794391},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '328 W 45th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['328 W 45th St', 'New York, NY 10036']},
#    'phone': '+16465902139',
#    'display_phone': '(646) 590-2139',
#    'distance': 6034.166930463986},
#   {'id': '9pQg2-DV6NdjK-qRnrEtLw',
#    'alias': 'sinfully-sweet-new-york-city',
#    'name': 'Sinfully Sweet',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jAaeKnW1eT7DxUd5NqiwNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sinfully-sweet-new-york-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'},
#     {'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.62860327468553,
#     'longitude': -74.09589125431535},
#    'transactions': [],
#    'location': {'address1': None,
#     'address2': None,
#     'address3': None,
#     'city': 'New York City',
#     'zip_code': '10301',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['New York City, NY 10301']},
#    'phone': '+13473362552',
#    'display_phone': '(347) 336-2552',
#    'distance': 12101.011671902415},
#   {'id': 'VL46XNUCYSfiY_5lLfh2gA',
#    'alias': 'auntie-annes-pretzels-flushing-2',
#    'name': "Auntie Anne's Pretzels",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GY24wGfr6O4mysvxC3TxNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auntie-annes-pretzels-flushing-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7572536051717,
#     'longitude': -73.8348317506598},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '40-24 College Point Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40-24 College Point Blvd', 'Flushing, NY 11354']},
#    'phone': '+17188865751',
#    'display_phone': '(718) 886-5751',
#    'distance': 14619.283232224563}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                Restaurant          Type Price Rating  \
# 0            Pretzelmaker      Pretzels     $      4
# 1             HasenStüble  Beer Gardens
# 2  Philly Pretzel Factory      Pretzels
# 3             Harlem Hops      Beer Bar    $$    4.5
# 4       Gretel's Pretzels      Pretzels     $      4
#
#                             Address        Lat        Lng  \
# 0                 90 15 Queens Blvd  40.734585 -73.869032
# 1                 1184 Nostrand Ave  40.658609 -73.950605
# 2                      118 Broadway  40.654072 -73.675653
# 3  2268 Adam Clayton Powell Jr Blvd  40.814440 -73.944800
# 4               5371 Kings Plz Mall  40.618960 -73.922655
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/pretzelmaker-elmhurst...  eCtDCj1Mbl5VFihJQroGvw
# 1
# 2
# 3  https://www.yelp.com/biz/harlem-hops-new-york-...  QzZlCAp7Qp7nBP7kRuGuNg
# 4  https://www.yelp.com/biz/gretels-pretzels-broo...  z5z9ji_ABjylFPjiQgoSWw

# %%
#3rd set of 50 records 101-150
nycr_params3 = {"term":"pretzel","location":"New York","limit":50,"offset":101}
nycr_response3 = requests.get(search_api_url, headers=headers, params=nycr_params3)
nycr3 = nycr_response3.json()
display(nycr3)
#print(nycr_response3.url)
#print(nycr_response3.status_code)
# Out:
# {'businesses': [{'id': 'cuVyM_ZxtREqpO1SXgZmRA',
#    'alias': 'bohemian-hall-and-beer-garden-astoria',
#    'name': 'Bohemian Hall & Beer Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/L5ZB9pLN3_Hl7lGBO138QQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bohemian-hall-and-beer-garden-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1160,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77273, 'longitude': -73.915772},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2919 24th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2919 24th Ave', 'Astoria, NY 11102']},
#    'phone': '+17182744925',
#    'display_phone': '(718) 274-4925',
#    'distance': 9987.067072302658},
#   {'id': 'ZMZn8YTq7M9tB4qoAB6flQ',
#    'alias': 'folksbier-brauerei-brooklyn',
#    'name': 'Folksbier Brauerei',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ykJcoaP2f0DhHuhrTzx86Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/folksbier-brauerei-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 61,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67802, 'longitude': -74.00126},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '101 Luquer St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['101 Luquer St', 'Brooklyn, NY 11231']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3094.673730731831},
#   {'id': 'DUYxe9yYAx3GQiZXub5pmA',
#    'alias': 'mothers-brooklyn-2',
#    'name': "Mother's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oS-T3i_uUaBlOsO23bXu9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mothers-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 268,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71488, 'longitude': -73.94471},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '347 Graham Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['347 Graham Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17183847778',
#    'display_phone': '(718) 384-7778',
#    'distance': 4311.230885740953},
#   {'id': 'wA5WLYvThEsZc1Te_4Lcbw',
#    'alias': 'essex-market-new-york-2',
#    'name': 'Essex Market',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Xqo_Elh5iuEHW3h_1dbfHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/essex-market-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 270,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'publicmarkets', 'title': 'Public Markets'},
#     {'alias': 'food_court', 'title': 'Food Court'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71821, 'longitude': -73.98815},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '88 Essex St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['88 Essex St', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1515.3696218243854},
#   {'id': '0iCISI2oP9bkS54hy68Xsw',
#    'alias': 'rolfs-bar-and-restaurant-new-york',
#    'name': "Rolf's Bar & Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6hzjg8gf2B7Ob4A1_1nahw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rolfs-bar-and-restaurant-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 985,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.73803, 'longitude': -73.98353},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '281 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['281 3rd Ave', 'New York, NY 10010']},
#    'phone': '+12124774750',
#    'display_phone': '(212) 477-4750',
#    'distance': 3735.107034518671},
#   {'id': 'qUmdCtNNKvbHYQPMMorwkg',
#    'alias': 'o-henrys-publick-house-staten-island',
#    'name': "O'Henry's Publick House",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5ts_Q8Lbw9Kv_pTN4TnXcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/o-henrys-publick-house-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6375049, 'longitude': -74.0755598},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '10 Minthorne St',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10301',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10 Minthorne St', 'Staten Island, NY 10301']},
#    'phone': '+17184426200',
#    'display_phone': '(718) 442-6200',
#    'distance': 10189.760892211529},
#   {'id': 'vf0sRM_qLdP-5krALqgjhw',
#    'alias': 'sweetwaters-coffee-and-tea-park-slope-brooklyn',
#    'name': 'Sweetwaters Coffee & Tea - Park Slope',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L1YztV49pc-nSwmDiMcy-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweetwaters-coffee-and-tea-park-slope-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cideries', 'title': 'Cideries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.68105, 'longitude': -73.977036},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '55 5th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+18452366103',
#    'display_phone': '(845) 236-6103',
#    'distance': 3076.9383173025},
#   {'id': 'wmUHxR--bSyaY1uIK2hRvA',
#    'alias': 'oculus-beer-garden-new-york',
#    'name': 'Oculus Beer Garden',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7c0sYJ8mGUoX61oeV4x-eA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oculus-beer-garden-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7121812, 'longitude': -74.010087},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '33 Vesey St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10282',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33 Vesey St', 'New York, NY 10282']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1586.87392457587},
#   {'id': 'U_hLyiUqDB16FBREKfJ8Xw',
#    'alias': 'the-barrow-house-clifton',
#    'name': 'The Barrow House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Fo_MTm1sqDBMfheRYqYKYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-barrow-house-clifton?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 970,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8717056, 'longitude': -74.172376},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1296 Van Houten Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Clifton',
#     'zip_code': '07013',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1296 Van Houten Ave', 'Clifton, NJ 07013']},
#    'phone': '+15512236609',
#    'display_phone': '(551) 223-6609',
#    'distance': 23773.94992638993},
#   {'id': 'tXtEDmMmEd60A9DQOqvY4A',
#    'alias': 'gold-star-beer-counter-prospect-heights',
#    'name': 'Gold Star Beer Counter',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7waHLNWelGH_llfcqmpOSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gold-star-beer-counter-prospect-heights?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 80,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6752104084685,
#     'longitude': -73.9667623490095},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '176 Underhill Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Prospect Heights',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['176 Underhill Ave', 'Prospect Heights, NY 11238']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4085.3961585788948},
#   {'id': 'eaV_aUOFJPsG7wRbzr6M9Q',
#    'alias': 'hudson-hall-jersey-city',
#    'name': 'Hudson Hall',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/q57QbZW0JIbCmjjVrug1YA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hudson-hall-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 241,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'smokehouse', 'title': 'Smokehouse'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72127, 'longitude': -74.04082},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '364 Marin Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['364 Marin Blvd', 'Jersey City, NJ 07302']},
#    'phone': '+12016596565',
#    'display_phone': '(201) 659-6565',
#    'distance': 4298.163920408219},
#   {'id': '7gH6Gcf8tnLlctw9kzKNHw',
#    'alias': 'bridge-and-tunnel-brewery-ridgewood',
#    'name': 'Bridge and Tunnel Brewery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0-pAGNN8qGmxsM3QqFv43Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bridge-and-tunnel-brewery-ridgewood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6935067, 'longitude': -73.9030978},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '15-35 Decatur St',
#     'address2': '',
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15-35 Decatur St', 'Ridgewood, NY 11385']},
#    'phone': '+13473928593',
#    'display_phone': '(347) 392-8593',
#    'distance': 7812.505757009472},
#   {'id': 'jW22gmsZjh5hFJsC1qUDOA',
#    'alias': 'the-baroness-bar-burgers-beer-long-island-city',
#    'name': 'The Baroness Bar Burgers + Beer',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/K29B1Q_brq_lm5UMgp2CcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-baroness-bar-burgers-beer-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 447,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74496, 'longitude': -73.95362},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '47-18 Vernon Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47-18 Vernon Blvd', 'Long Island City, NY 11101']},
#    'phone': '+17182551336',
#    'display_phone': '(718) 255-1336',
#    'distance': 5571.414552203242},
#   {'id': '8lHTKVJyiK9V8WiJq9-khQ',
#    'alias': 'midwood-flats-prospect-lefferts-gardens',
#    'name': 'Midwood Flats',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EJAbvyuGRqILT1e4A5-_0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/midwood-flats-prospect-lefferts-gardens?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 272,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'bartenders', 'title': 'Bartenders'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6596512, 'longitude': -73.9603844},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '577 Flatbush Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Prospect Lefferts Gardens',
#     'zip_code': '11225',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['577 Flatbush Ave',
#      'Prospect Lefferts Gardens, NY 11225']},
#    'phone': '+17184844466',
#    'display_phone': '(718) 484-4466',
#    'distance': 5840.516199955178},
#   {'id': '-BmS1FH3DSK6fSifIt8GgQ',
#    'alias': 'nurnberger-bierhaus-staten-island',
#    'name': 'Nurnberger Bierhaus',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UmPYeEbm4w6GQTLXiRAE2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nurnberger-bierhaus-staten-island?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 224,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.63482, 'longitude': -74.10961},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '817 Castleton Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10310',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['817 Castleton Ave', 'Staten Island, NY 10310']},
#    'phone': '+17188167461',
#    'display_phone': '(718) 816-7461',
#    'distance': 12494.497421319058},
#   {'id': '2O5w-15_AVnnVJEtlWWE_A',
#    'alias': 'clinton-hall-bronx-4',
#    'name': 'Clinton Hall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lneg4MLQMpq4UJ-jCVWSPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clinton-hall-bronx-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 183,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.85735, 'longitude': -73.88574},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '601 E 189th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10458',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['601 E 189th St', 'Bronx, NY 10458']},
#    'phone': '+17182206400',
#    'display_phone': '(718) 220-6400',
#    'distance': 19211.098766323194},
#   {'id': '_IHpfiDskjESk88OqscjbQ',
#    'alias': 'philly-pretzel-factory-westfield',
#    'name': 'Philly Pretzel Factory',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7EBY5i1uC8YPNSSenXMUmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/philly-pretzel-factory-westfield?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.650044, 'longitude': -74.338978},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '295 South Ave E',
#     'address2': None,
#     'address3': None,
#     'city': 'Westfield',
#     'zip_code': '07090',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['295 South Ave E', 'Westfield, NJ 07090']},
#    'phone': '+19082326232',
#    'display_phone': '(908) 232-6232',
#    'distance': 29714.544230589614},
#   {'id': '6q-7JBqybIo_MFmFFtlDXQ',
#    'alias': 'east-harlem-bottling-new-york-3',
#    'name': 'East Harlem Bottling',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UW8nUyYNpzDptiLuRY_V_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/east-harlem-bottling-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 204,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.79293791199, 'longitude': -73.9455429167249},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1711 Lexington Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1711 Lexington Ave', 'New York, NY 10029']},
#    'phone': '+16469227705',
#    'display_phone': '(646) 922-7705',
#    'distance': 10559.995852932965},
#   {'id': 'LJTGRkX5yWoqx1jJ7E4zqw',
#    'alias': 'haymaker-bar-and-kitchen-new-york',
#    'name': 'Haymaker Bar and Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-0u1fc73yGbX2KSXEzS_dA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/haymaker-bar-and-kitchen-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 341,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7487508496393,
#     'longitude': -73.995229748466},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '252 W 29th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['252 W 29th St', 'New York, NY 10001']},
#    'phone': '+16464298237',
#    'display_phone': '(646) 429-8237',
#    'distance': 4816.047149274326},
#   {'id': 'CW80-xqH6Gm9Npl-QaJ6zg',
#    'alias': 'philly-pretzel-factory-livingston',
#    'name': 'Philly Pretzel Factory',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2RLuVk3Xb6Q9Ra1pUcMgRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/philly-pretzel-factory-livingston?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7956801, 'longitude': -74.3163602},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '21 W Mt Pleasant Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Livingston',
#     'zip_code': '07039',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['21 W Mt Pleasant Ave', 'Livingston, NJ 07039']},
#    'phone': '+19739941004',
#    'display_phone': '(973) 994-1004',
#    'distance': 28925.780280956482},
#   {'id': 'NTwOc9yQ1xl5deeVzZqxfw',
#    'alias': 'tavern29-new-york',
#    'name': 'Tavern29',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/i4-L6ynQSj3awI_DDngaDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tavern29-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 948,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74431, 'longitude': -73.98394},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '47 E 29th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 E 29th St', 'New York, NY 10016']},
#    'phone': '+12126854422',
#    'display_phone': '(212) 685-4422',
#    'distance': 4405.322562505105},
#   {'id': 'U59wtA8rlOXWkUYjKhDb3w',
#    'alias': 'randolph-beer-brooklyn-7',
#    'name': 'Randolph Beer',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/03jB_PtdxKEgMP1FBQYu2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/randolph-beer-brooklyn-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 121,
#    'categories': [{'alias': 'brewpubs', 'title': 'Brewpubs'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.700536, 'longitude': -73.987459},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '82 Prospect St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '07307',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['82 Prospect St', 'Brooklyn, NY 07307']},
#    'phone': '+16463833623',
#    'display_phone': '(646) 383-3623',
#    'distance': 793.6217509447091},
#   {'id': 'tUru4njlrCzu32gbrnAAVg',
#    'alias': 'auntie-annes-elmhurst-2',
#    'name': "Auntie Anne's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FzVypyuEv3HpU6qxqky_1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auntie-annes-elmhurst-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73462, 'longitude': -73.87094},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '90-15 Queens Blvd',
#     'address2': 'Space 1033',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90-15 Queens Blvd',
#      'Space 1033',
#      'Elmhurst, NY 11373']},
#    'phone': '+17182711756',
#    'display_phone': '(718) 271-1756',
#    'distance': 10962.959472667964},
#   {'id': 'CkKTdw-lxGX8H3L0ppr6Zg',
#    'alias': 'black-forest-brooklyn-brooklyn',
#    'name': 'Black Forest Brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OyqXY8ydqNNx-AzZWhordA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-forest-brooklyn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 411,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6867553, 'longitude': -73.9750998},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '733 Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['733 Fulton St', 'Brooklyn, NY 11217']},
#    'phone': '+17189350300',
#    'display_phone': '(718) 935-0300',
#    'distance': 2633.8422732759072},
#   {'id': 'mn6JM5lHuSSsG9KSXck3ww',
#    'alias': 'ulysses-folk-house-new-york-2',
#    'name': 'Ulysses Folk House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KPep2sUZf0iEz-SEpYq0Pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ulysses-folk-house-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 779,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7042799890041,
#     'longitude': -74.0099190920591},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '95 Pearl St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['95 Pearl St', 'New York, NY 10004']},
#    'phone': '+12124820400',
#    'display_phone': '(212) 482-0400',
#    'distance': 1323.528234913188},
#   {'id': '5mqqqlQQB7BmVP3CH8ohag',
#    'alias': 'd-b-a-new-york-2',
#    'name': 'D B A',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-GW5rC48yCCpYUTmQw5GMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/d-b-a-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 444,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72431, 'longitude': -73.98793},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '41 1st Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41 1st Ave', 'New York, NY 10003']},
#    'phone': '+12124755097',
#    'display_phone': '(212) 475-5097',
#    'distance': 2165.1983735081594},
#   {'id': 'U3TwPnfQ1aJuilUB-JnUNw',
#    'alias': 'houston-hall-new-york',
#    'name': 'Houston Hall',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qo5D3yG5gOhehjbAU08ZNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/houston-hall-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 548,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'brewpubs', 'title': 'Brewpubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72866, 'longitude': -74.00472},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '222 W Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['222 W Houston St', 'New York, NY 10014']},
#    'phone': '+12126759323',
#    'display_phone': '(212) 675-9323',
#    'distance': 2741.6431434361994},
#   {'id': 'zsgDZati0aRKaPf0Um16XQ',
#    'alias': 'stammtisch-pork-store-glendale',
#    'name': 'Stammtisch Pork Store',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/my23ZMIdcTMdnFCsmcHgDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stammtisch-pork-store-glendale?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7017618, 'longitude': -73.8813408},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '69-46 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Glendale',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['69-46 Myrtle Ave', 'Glendale, NY 11385']},
#    'phone': '+17183867200',
#    'display_phone': '(718) 386-7200',
#    'distance': 9550.09692986248},
#   {'id': 'E4wNBoe1PD0pCyF6qr-xbA',
#    'alias': 'greenpoint-beer-and-ale-co-brooklyn',
#    'name': 'Greenpoint Beer & Ale Co.',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FnvGGeO_4TQJMR7b3vNuNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greenpoint-beer-and-ale-co-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 149,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73768, 'longitude': -73.9552235},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1150 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1150 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+13477253061',
#    'display_phone': '(347) 725-3061',
#    'distance': 4867.088922347014},
#   {'id': 'Li52Rr6BM4bGNYdpn7H8_w',
#    'alias': 'coopers-craft-and-kitchen-new-york-2',
#    'name': "Cooper's Craft & Kitchen",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ejB9Y5jDsDjC7t5ATYu9aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coopers-craft-and-kitchen-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 386,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.742702, 'longitude': -74.000778},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '169 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['169 8th Ave', 'New York, NY 10011']},
#    'phone': '+16466617711',
#    'display_phone': '(646) 661-7711',
#    'distance': 4178.814049118333},
#   {'id': 'rsIFmGM9_-q_UXf6Dvcl2A',
#    'alias': 'auntie-annes-pretzels-ridgewood',
#    'name': "Auntie Anne's Pretzels",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/N4bgoxKOjq3eT25a0vHWPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auntie-annes-pretzels-ridgewood?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.7087477088711,
#     'longitude': -73.8683697459748},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '8000 Cooper Ave',
#     'address2': '',
#     'address3': 'The Shops At Atlas Park',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8000 Cooper Ave',
#      'The Shops At Atlas Park',
#      'Ridgewood, NY 11385']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 10620.643511598048},
#   {'id': 'uiqxxKHuuETtWbiKdiocXw',
#    'alias': 'irish-cottage-forest-hills',
#    'name': 'Irish Cottage',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QyVPBjGXv5BnDoH9yOEp6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/irish-cottage-forest-hills?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 197,
#    'categories': [{'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7197538285905,
#     'longitude': -73.8425123691559},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10807 72nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10807 72nd Ave', 'Forest Hills, NY 11375']},
#    'phone': '+17185208530',
#    'display_phone': '(718) 520-8530',
#    'distance': 12891.358221052527},
#   {'id': 'Xy5zmV2va1RTgnqyakfMnQ',
#    'alias': 'gruit-brooklyn',
#    'name': 'Gruit',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zmHRicaJtSvTrx885IXQ9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gruit-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'kosher', 'title': 'Kosher'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.663465879123,
#     'longitude': -73.9536466271922},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '252 Empire Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11225',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['252 Empire Blvd', 'Brooklyn, NY 11225']},
#    'phone': '+13478460622',
#    'display_phone': '(347) 846-0622',
#    'distance': 5790.973395592829},
#   {'id': '35ezIH9BDHLY4XVQrxw6NA',
#    'alias': 'stout-grand-central-new-york',
#    'name': 'Stout',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-ZD6BMEyR-xN0c8g9XGQIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stout-grand-central-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 224,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7516115, 'longitude': -73.9788202},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '60 E 41st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 E 41st St', 'New York, NY 10017']},
#    'phone': '+12129229009',
#    'display_phone': '(212) 922-9009',
#    'distance': 5296.478045549563},
#   {'id': 'I9sBawh9WnuPZSxXn1nkBw',
#    'alias': 'auntie-annes-and-cinnabon-new-york',
#    'name': "Auntie Anne's and Cinnabon",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kI1wmSDqxHdOzXBZDUqRKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auntie-annes-and-cinnabon-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.742021, 'longitude': -73.9931495},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '688 6th Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['688 6th Ave', 'New York, NY 10011']},
#    'phone': '+16464905019',
#    'display_phone': '(646) 490-5019',
#    'distance': 4068.2180579464116},
#   {'id': 'lNP1km2kaEtlsBw2VNHHhQ',
#    'alias': 'tap-haus-33-new-york',
#    'name': 'Tap Haus 33',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Tjo1khTYFSNeKDXIH_J9hg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tap-haus-33-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 229,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.747247, 'longitude': -73.9843},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '14 E 33rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 E 33rd St', 'New York, NY 10016']},
#    'phone': '+12128899889',
#    'display_phone': '(212) 889-9889',
#    'distance': 4722.188897897444},
#   {'id': 'w0WyVm-BoTeUSrjhmHvP7g',
#    'alias': 'auntie-annes-new-york-4',
#    'name': "Auntie Anne's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3XsHkigaTsieGOjMMTT1ug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auntie-annes-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.753401, 'longitude': -73.996076},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '34th Str  7 & 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['34th Str  7 & 8th Ave', 'New York, NY 10001']},
#    'phone': '+12122396882',
#    'display_phone': '(212) 239-6882',
#    'distance': 5334.588650971862},
#   {'id': '0jL_7Lw8i7K0ailwbNBEug',
#    'alias': 'nyc-hot-dogs-new-york',
#    'name': 'Nyc Hot Dogs',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kz5sljzx109jm8W_6xj8Ww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nyc-hot-dogs-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.75759, 'longitude': -73.98562},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Times Sq',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Times Sq', 'New York, NY 10036']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5844.142147311589},
#   {'id': 'hPJ7x8rfSsJ4ObgHeAK5kg',
#    'alias': 'greenwood-park-brooklyn',
#    'name': 'Greenwood Park',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lIoaKrYcy3_76AAiyiM2CA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greenwood-park-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 452,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.659353, 'longitude': -73.987894},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '555 7th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['555 7th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17184997999',
#    'display_phone': '(718) 499-7999',
#    'distance': 5153.5031869986915},
#   {'id': 'jF5CrF1BmvhoPlMTp5AoJQ',
#    'alias': 'chelsea-market-new-york',
#    'name': 'Chelsea Market',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-g1gEmow0OleqGk0fNo_fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chelsea-market-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2259,
#    'categories': [{'alias': 'publicmarkets', 'title': 'Public Markets'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7419711362098,
#     'longitude': -74.0048450364568},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '75 9th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 9th Ave', 'New York, NY 10011']},
#    'phone': '+12126522111',
#    'display_phone': '(212) 652-2111',
#    'distance': 4157.731403316093},
#   {'id': 'xTq-F5nRIOV494iKQJxWeA',
#    'alias': 'the-perfect-pint-new-york-2',
#    'name': 'The Perfect Pint',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mnoDYRPyQZDKjUmoS6xxZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-perfect-pint-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 367,
#    'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.75271, 'longitude': -73.9726},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '203 E 45th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['203 E 45th St', 'New York, NY 10017']},
#    'phone': '+12128678159',
#    'display_phone': '(212) 867-8159',
#    'distance': 5558.21004008781},
#   {'id': 'w5B0FmQoEOoeURoFuguh0w',
#    'alias': 'the-brew-inn-brooklyn',
#    'name': 'The Brew Inn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YOArFThZktjXt6eNbY9Ziw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-brew-inn-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 166,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.731044, 'longitude': -73.954101},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '924 Manhattan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['924 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17185647155',
#    'display_phone': '(718) 564-7155',
#    'distance': 4425.656516549139},
#   {'id': 'Ayx5XNT7i79TUjbHTTC5YQ',
#    'alias': 'waterfront-ale-house-new-york',
#    'name': 'Waterfront Ale House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7ahyxROwE3d_oaptrKseBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/waterfront-ale-house-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 281,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74204, 'longitude': -73.9775},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '540 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['540 2nd Ave', 'New York, NY 10016']},
#    'phone': '+12126964104',
#    'display_phone': '(212) 696-4104',
#    'distance': 4308.868304635837},
#   {'id': 'XjhAs-09KfSfIfbaSa_whA',
#    'alias': 'iconyc-brewing-long-island-city',
#    'name': 'ICONYC Brewing',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/d761wWpExiMILepeKcvOQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/iconyc-brewing-long-island-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 99,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7501896, 'longitude': -73.94879242467091},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '43-63 11th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43-63 11th St', 'Long Island City, NY 11101']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6281.326648207917},
#   {'id': 'qz6buZ7Hs-clKoT6MmExNg',
#    'alias': 'alewife-brewing-and-taproom-sunnyside',
#    'name': 'Alewife Brewing & Taproom',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/imcJSXAmXA7gHFh7iPEfEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alewife-brewing-and-taproom-sunnyside?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74694, 'longitude': -73.92524},
#    'transactions': [],
#    'location': {'address1': '41-11 39th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41-11 39th St', 'Sunnyside, NY 11104']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 7428.086187171424},
#   {'id': 'mf2c_I0L_yHKLqNDQdj3Gw',
#    'alias': 'new-jersey-beer-co-north-bergen-2',
#    'name': 'New Jersey Beer Co',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lRSUW0mi_TvrWP8IJVPd-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-jersey-beer-co-north-bergen-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 124,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.783521, 'longitude': -74.036031},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4201 Tonnelle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'North Bergen',
#     'zip_code': '07047',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['4201 Tonnelle Ave', 'North Bergen, NJ 07047']},
#    'phone': '+12017588342',
#    'display_phone': '(201) 758-8342',
#    'distance': 9366.678865385593},
#   {'id': 'do_ndggWB4Gb56rP6ikbVw',
#    'alias': 'irish-rover-astoria',
#    'name': 'Irish Rover',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9MfgVyWLtpnQgLfA0-LZCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/irish-rover-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 162,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.765754699707,
#     'longitude': -73.9147491455078},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3718 28th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3718 28th Ave', 'Astoria, NY 11103']},
#    'phone': '+17182789372',
#    'display_phone': '(718) 278-9372',
#    'distance': 9476.507858931103},
#   {'id': '6FIzpXy82HBT3KZaiA38-Q',
#    'alias': 'amity-hall-new-york',
#    'name': 'Amity Hall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GRGU8_bfh089bia4zcic2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amity-hall-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 422,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72963, 'longitude': -73.99892},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '80 W 3rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 W 3rd St', 'New York, NY 10012']},
#    'phone': '+12126772290',
#    'display_phone': '(212) 677-2290',
#    'distance': 2713.026943996369},
#   {'id': 'j_cpaoMtVJ26i6YPUB04EA',
#    'alias': 'clinton-hall-and-rooftop-beer-garden-brooklyn',
#    'name': 'Clinton Hall & Rooftop Beer Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hj3LLggDVjP_XoFqL3ht2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clinton-hall-and-rooftop-beer-garden-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 152,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71502, 'longitude': -73.95903},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '247 Metropolitan Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['247 Metropolitan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+19294196988',
#    'display_phone': '(929) 419-6988',
#    'distance': 3159.860915550328},
#   {'id': '_JY4-9KcxtitbE_lIXMryA',
#    'alias': 'one-station-plaza-beer-garden-and-eatery-bayside-4',
#    'name': 'One Station Plaza Beer Garden & Eatery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/btdEXt-6VfdIJo-_trqJkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/one-station-plaza-beer-garden-and-eatery-bayside-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 150,
#    'categories': [{'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.76331, 'longitude': -73.771394},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '213-10 41st Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['213-10 41st Ave', 'Bayside, NY 11361']},
#    'phone': '+17182240060',
#    'display_phone': '(718) 224-0060',
#    'distance': 19852.449965511492}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                     Restaurant                   Type Price Rating  \
# 0  Bohemian Hall & Beer Garden  Venues & Event Spaces    $$      4
# 1           Folksbier Brauerei              Breweries     $    4.5
# 2                     Mother's                Burgers    $$    3.5
# 3                 Essex Market                Grocery    $$      4
# 4      Rolf's Bar & Restaurant                 German   $$$    2.5
#
#           Address       Lat        Lng  \
# 0   2919 24th Ave  40.77273 -73.915772
# 1   101 Luquer St  40.67802 -74.001260
# 2  347 Graham Ave  40.71488 -73.944710
# 3     88 Essex St  40.71821 -73.988150
# 4     281 3rd Ave  40.73803 -73.983530
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/bohemian-hall-and-bee...  cuVyM_ZxtREqpO1SXgZmRA
# 1  https://www.yelp.com/biz/folksbier-brauerei-br...  ZMZn8YTq7M9tB4qoAB6flQ
# 2  https://www.yelp.com/biz/mothers-brooklyn-2?ad...  DUYxe9yYAx3GQiZXub5pmA
# 3  https://www.yelp.com/biz/essex-market-new-york...  wA5WLYvThEsZc1Te_4Lcbw
# 4  https://www.yelp.com/biz/rolfs-bar-and-restaur...  0iCISI2oP9bkS54hy68Xsw

# %%
#4th set of 50 records 151-200
nycr_params4 = {"term":"pretzel","location":"New York","limit":50,"offset":151}
nycr_response4 = requests.get(search_api_url, headers=headers, params=nycr_params4)
nycr4 = nycr_response4.json()
display(nycr4)
#print(nycr_response4.url)
#print(nycr_response4.status_code)
# Out:
# {'businesses': [{'id': '2270Iy6WQskMawb4iETO8w',
#    'alias': 'loki-bar-park-slope-6',
#    'name': 'Loki Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1H61whUfaVfiePnKVqW5jA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/loki-bar-park-slope-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 172,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.673937, 'longitude': -73.983064},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '341 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Park Slope',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['341 2nd St', 'Park Slope, NY 11215']},
#    'phone': '+17189659600',
#    'display_phone': '(718) 965-9600',
#    'distance': 3666.295055224476},
#   {'id': 'tOn-wEQ06ScrgeU5Ljw7Gw',
#    'alias': 'alfies-new-york',
#    'name': "Alfie's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/elq8pQW9zl3k_fYpkGFYzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alfies-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 561,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.765437, 'longitude': -73.987278},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '800 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['800 9th Ave', 'New York, NY 10019']},
#    'phone': '+12127572390',
#    'display_phone': '(212) 757-2390',
#    'distance': 6696.94866880618},
#   {'id': 'CJpBLfB3csuC0ZVQYaqbtQ',
#    'alias': 'that-bar-brooklyn-2',
#    'name': 'That Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zMENkal4vh2ZLU_Ro7ppvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/that-bar-brooklyn-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6813421554003,
#     'longitude': -73.9769475638237},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '47 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+13475992220',
#    'display_phone': '(347) 599-2220',
#    'distance': 3053.1147185680284},
#   {'id': '19o6iblcJvz2hdPouYhXgg',
#    'alias': 'zum-stammtisch-glendale',
#    'name': 'Zum Stammtisch',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OAI9b7m-P32jNr_hsCE9yQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zum-stammtisch-glendale?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 484,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7017618, 'longitude': -73.8813408},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '6946 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Glendale',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6946 Myrtle Ave', 'Glendale, NY 11385']},
#    'phone': '+17183863014',
#    'display_phone': '(718) 386-3014',
#    'distance': 9550.09692986248},
#   {'id': '_edG68ufw52-v_xRL4jsyw',
#    'alias': 'prost-garden-city',
#    'name': 'Prost',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XEYE6gIBAcujaaio_LDbfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prost-garden-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 159,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72456, 'longitude': -73.63403},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '652 Franklin Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Garden City',
#     'zip_code': '11530',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['652 Franklin Ave', 'Garden City, NY 11530']},
#    'phone': '+15164275215',
#    'display_phone': '(516) 427-5215',
#    'distance': 30427.097404977365},
#   {'id': 'AxpsI4_tOI0sM6-KfOY9ig',
#    'alias': 'auntie-annes-pretzels-rego-park-2',
#    'name': "Auntie Anne's Pretzels",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/x28Pq_9QKeByj6sbTZvosw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auntie-annes-pretzels-rego-park-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.733178, 'longitude': -73.862651},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '61-35 Junction Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['61-35 Junction Blvd', 'Rego Park, NY 11374']},
#    'phone': '+17186991643',
#    'display_phone': '(718) 699-1643',
#    'distance': 11514.90997946917},
#   {'id': 'qpvD-NIGBCGWn3TdrJ8C6g',
#    'alias': 'auntie-annes-new-york-8',
#    'name': "Auntie Anne's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/enJobZzg1Xz3OfaRTt7jvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auntie-annes-new-york-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 40.700990061242,
#     'longitude': -74.0130770603446},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '4 S St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4 S St', 'New York, NY 10004']},
#    'phone': '+16315747700',
#    'display_phone': '(631) 574-7700',
#    'distance': 1659.0869752386398},
#   {'id': 'ZH7-ixqxu9Xu5PiX2MP11A',
#    'alias': 'philly-pretzel-factory-old-bridge-township',
#    'name': 'Philly Pretzel Factory',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sfo5rVcqYCeD0D8fhPiinQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/philly-pretzel-factory-old-bridge-township?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.4494915, 'longitude': -74.2990733},
#    'transactions': ['delivery'],
#    'location': {'address1': '1126 US 9',
#     'address2': None,
#     'address3': '',
#     'city': 'Old Bridge Township',
#     'zip_code': '08857',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1126 US 9', 'Old Bridge Township, NJ 08857']},
#    'phone': '+17327211900',
#    'display_phone': '(732) 721-1900',
#    'distance': 38603.27231100145},
#   {'id': 'ru_48Holy5Yw2Ejax8PE8A',
#    'alias': 'blackjack-mulligans-hawthorne-hawthorne',
#    'name': 'Blackjack Mulligans Hawthorne',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aDi99WNphCmt09t-0HTdgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blackjack-mulligans-hawthorne-hawthorne?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.949209, 'longitude': -74.153178},
#    'transactions': ['delivery'],
#    'location': {'address1': '237 Diamond Bridge Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Hawthorne',
#     'zip_code': '07506',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['237 Diamond Bridge Ave', 'Hawthorne, NJ 07506']},
#    'phone': '+19734234000',
#    'display_phone': '(973) 423-4000',
#    'distance': 30220.501889192},
#   {'id': 'tphnYCcwIBADJ1-8Znqnmw',
#    'alias': 'the-plank-pizza-co-beer-parlor-saddle-brook',
#    'name': 'The Plank Pizza Co Beer Parlor',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/b15mTcL353HAJwZI4-bCUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-plank-pizza-co-beer-parlor-saddle-brook?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 495,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.897536, 'longitude': -74.096637},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '383 Market St',
#     'address2': 'Bldg D',
#     'address3': '',
#     'city': 'Saddle Brook',
#     'zip_code': '07663',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['383 Market St', 'Bldg D', 'Saddle Brook, NJ 07663']},
#    'phone': '+12018432426',
#    'display_phone': '(201) 843-2426',
#    'distance': 23031.258756541032},
#   {'id': 'JmQXn0KORkrFwaywu_6gIg',
#    'alias': 'keg-and-lantern-brewing-brooklyn',
#    'name': 'Keg & Lantern Brewing',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dJ4xy-rGSC3XHrY0pzlxrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/keg-and-lantern-brewing-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'brewpubs', 'title': 'Brewpubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.675735, 'longitude': -74.01579},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '158 Beard St',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['158 Beard St', 'Brooklyn, NY 11231']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3769.557160200134},
#   {'id': 'X97pE0LRWOng1q66kjAz1g',
#    'alias': 'the-independent-new-york-3',
#    'name': 'The Independent',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GiRm0zdizbAcuxADW-R0_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-independent-new-york-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 100,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.754782, 'longitude': -73.987377},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '147 W 40th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['147 W 40th St', 'New York, NY 10018']},
#    'phone': '+19173883727',
#    'display_phone': '(917) 388-3727',
#    'distance': 5518.621143429752},
#   {'id': 'jL8f3gumMouGcQKr2M15Ng',
#    'alias': 'vol-de-nuit-new-york',
#    'name': 'Vol de Nuit',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/J-89eROapPGpEoIy0255Cg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vol-de-nuit-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 480,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.731319, 'longitude': -74.000663},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '148 W 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['148 W 4th St', 'New York, NY 10012']},
#    'phone': '+12129823388',
#    'display_phone': '(212) 982-3388',
#    'distance': 2930.4648405144103},
#   {'id': '_xRGTDjG-nYMgCCNcmCoNQ',
#    'alias': 'trionas-new-york-2',
#    'name': "Triona's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2HdpKNUPkGSVvGCWCZKdsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trionas-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 114,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72989, 'longitude': -73.99938},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '237 Sullivan St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['237 Sullivan St', 'New York, NY 10012']},
#    'phone': '+12129825322',
#    'display_phone': '(212) 982-5322',
#    'distance': 2745.074825152439},
#   {'id': 'P1uB518HQkAG19XZA_tv7g',
#    'alias': 'grace-o-malley-s-jersey-city',
#    'name': 'Grace O Malley’s',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DAye-fQDo0CRuYNEVFAJeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grace-o-malley-s-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7204036166368,
#     'longitude': -74.0435801407155},
#    'transactions': [],
#    'location': {'address1': '140 Newark Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['140 Newark Ave', 'Jersey City, NJ 07302']},
#    'phone': '+12015201144',
#    'display_phone': '(201) 520-1144',
#    'distance': 4474.742965903041},
#   {'id': 'me1IBLFIImlQsafNPvMKdQ',
#    'alias': 'snowdonia-astoria',
#    'name': 'Snowdonia',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4XkfvwjGJDqhROB-bAFsyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/snowdonia-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 284,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'fishnchips', 'title': 'Fish & Chips'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7578, 'longitude': -73.9275},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '32-01 35th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32-01 35th Ave', 'Astoria, NY 11106']},
#    'phone': '+13477305783',
#    'display_phone': '(347) 730-5783',
#    'distance': 8097.283812449867},
#   {'id': '6OR2yWbTiaBrqLwNnGNaMA',
#    'alias': 'milk-and-hops-new-york-6',
#    'name': 'Milk & Hops',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DS2lDIlj4qoKbNYC2A0fXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/milk-and-hops-new-york-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 108,
#    'categories': [{'alias': 'cheese', 'title': 'Cheese Shops'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7446831, 'longitude': -74.0023905374366},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '166 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['166 9th Ave', 'New York, NY 10011']},
#    'phone': '+12129891999',
#    'display_phone': '(212) 989-1999',
#    'distance': 4416.122804755498},
#   {'id': 'P5X8K61nDAlo8QrgCn-agQ',
#    'alias': 'zeppelin-hall-jersey-city',
#    'name': 'Zeppelin Hall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VHbV8hfLEumrAjPkDlF-Ww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zeppelin-hall-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 874,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.715132087537, 'longitude': -74.04667189924},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '88 Liberty View Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['88 Liberty View Dr', 'Jersey City, NJ 07302']},
#    'phone': '+12017218888',
#    'display_phone': '(201) 721-8888',
#    'distance': 4544.380217519045},
#   {'id': 'ACduxcM6wdaJPVHKy9GHbQ',
#    'alias': 'circa-brewing-brooklyn-3',
#    'name': 'Circa Brewing',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aJ93g6qT-iCKgAmi5l0RKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/circa-brewing-brooklyn-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 352,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'brewpubs', 'title': 'Brewpubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69165, 'longitude': -73.98603},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '141 Lawrence St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['141 Lawrence St', 'Brooklyn, NY 11201']},
#    'phone': '+17188580055',
#    'display_phone': '(718) 858-0055',
#    'distance': 1683.4641658447156},
#   {'id': 'qjzkDnjT2sIa_8-uYaMYoA',
#    'alias': 'mason-jar-nyc-new-york',
#    'name': 'Mason Jar NYC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fz11s6DKfrJedG9kaVwoUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mason-jar-nyc-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 453,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74489, 'longitude': -73.98368},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '43 E 30th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43 E 30th St', 'New York, NY 10016']},
#    'phone': '+12122133587',
#    'display_phone': '(212) 213-3587',
#    'distance': 4477.415451730729},
#   {'id': 'uNv0QzHplmxTnZbpkeznXg',
#    'alias': 'auntie-annes-pretzels-union',
#    'name': "Auntie Anne's Pretzels",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dRWz6omp1Z9sohYGu36SkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auntie-annes-pretzels-union?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.677966, 'longitude': -74.234958},
#    'transactions': [],
#    'location': {'address1': '1000 Morris Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Union',
#     'zip_code': '07083',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1000 Morris Ave', 'Union, NJ 07083']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 20519.474127843867},
#   {'id': 'mw0EQ-dO4lUD2q44ASizhA',
#    'alias': 'rochelles-new-york',
#    'name': 'Rochelles',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zmxgViWEkN1N2gaYxwZ1NA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rochelles-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 160,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722386, 'longitude': -73.991958},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '205 Chrystie St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['205 Chrystie St', 'New York, NY 10002']},
#    'phone': '+12126732400',
#    'display_phone': '(212) 673-2400',
#    'distance': 1894.0202841517944},
#   {'id': 'z5hRX3iJ5Ty_S38iG_WY3Q',
#    'alias': 'tanner-smiths-new-york-2',
#    'name': 'Tanner Smiths',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Cd4oaUWci9sYJbXy3fbqnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tanner-smiths-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1822,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76442, 'longitude': -73.98169},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '204 W 55th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['204 W 55th St', 'New York, NY 10019']},
#    'phone': '+16465902034',
#    'display_phone': '(646) 590-2034',
#    'distance': 6628.69302856469},
#   {'id': '7D8Gu3eKCwCTxNI9G-qEqQ',
#    'alias': 'auntie-annes-newark-3',
#    'name': "Auntie Anne's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vgE1ADVctz6frzgrXs8rAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auntie-annes-newark-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.695938, 'longitude': -74.177547},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': "Newark Liberty Int'l Airport",
#     'address2': '',
#     'address3': 'Term C',
#     'city': 'Newark',
#     'zip_code': '07114',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ["Newark Liberty Int'l Airport",
#      'Term C',
#      'Newark, NJ 07114']},
#    'phone': '+19736241111',
#    'display_phone': '(973) 624-1111',
#    'distance': 15484.367297783843},
#   {'id': 'epDvy_G3YITZRbhqcExkBg',
#    'alias': 'hops-hill-brooklyn',
#    'name': 'Hops Hill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AaoRaSQZzrhSIAsZUkUBRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hops-hill-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'whiskeybars', 'title': 'Whiskey Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68309, 'longitude': -73.96557},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '886 Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['886 Fulton St', 'Brooklyn, NY 11238']},
#    'phone': '+13479874334',
#    'display_phone': '(347) 987-4334',
#    'distance': 3471.1558721193123},
#   {'id': 'qpD22cY8CSXLT2qujiJtqw',
#    'alias': 'the-full-shilling-new-york',
#    'name': 'The Full Shilling',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QIY7ZybjSKBYancNX0Qc5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-full-shilling-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 90,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'irish', 'title': 'Irish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.705722, 'longitude': -74.007469},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '160 Pearl St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['160 Pearl St', 'New York, NY 10005']},
#    'phone': '+12124223855',
#    'display_phone': '(212) 422-3855',
#    'distance': 1111.3680890121782},
#   {'id': 'Uejp87ErPr6_Y6tPqfhAVA',
#    'alias': 'auntie-annes-kingsbridge',
#    'name': "Auntie Anne's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dt_GsFwUDUl2gvS9T0Imkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auntie-annes-kingsbridge?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.8773994, 'longitude': -73.9049072},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '171 W 230th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Kingsbridge',
#     'zip_code': '10463',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 W 230th St', 'Kingsbridge, NY 10463']},
#    'phone': '+17185482200',
#    'display_phone': '(718) 548-2200',
#    'distance': 20533.977373244317},
#   {'id': 'lHGQM__w1x5Dxiq3aRPCTQ',
#    'alias': 'white-horse-tavern-financial-district-new-york',
#    'name': 'White Horse Tavern - Financial District',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YV-yxNcjo9RzuTdNZnY4Ow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/white-horse-tavern-financial-district-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 374,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70372, 'longitude': -74.01237},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '25 Bridge St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 Bridge St', 'New York, NY 10004']},
#    'phone': '+12126689046',
#    'display_phone': '(212) 668-9046',
#    'distance': 1537.340275509881},
#   {'id': 'y6XohzcYjUAQOD8U3NT_yw',
#    'alias': 'the-stags-head-new-york-2',
#    'name': "The Stag's Head",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DHFcsWUfr1GbJBpt2nBm5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-stags-head-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 436,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.755592, 'longitude': -73.968588},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '252 E 51st St',
#     'address2': 'Ste 1',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['252 E 51st St', 'Ste 1', 'New York, NY 10022']},
#    'phone': '+12128882453',
#    'display_phone': '(212) 888-2453',
#    'distance': 5982.00079394467},
#   {'id': 'noujMiOizbAWyDw8LbiM8Q',
#    'alias': 'union-hall-brooklyn',
#    'name': 'Union Hall',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/miR8UX9F5maFVShJKS-1Fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/union-hall-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 647,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'theater', 'title': 'Performing Arts'},
#     {'alias': 'bocceball', 'title': 'Bocce Ball'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67612, 'longitude': -73.98005},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '702 Union St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['702 Union St', 'Brooklyn, NY 11215']},
#    'phone': '+17186384400',
#    'display_phone': '(718) 638-4400',
#    'distance': 3480.900494743433},
#   {'id': 'Rpw8mQPKJb8esVjosT4Sog',
#    'alias': 'valhalla-new-york',
#    'name': 'Valhalla',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FSH0c0iAImX1M2wyqu8vJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/valhalla-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 504,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76596, 'longitude': -73.98737},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '815 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['815 9th Ave', 'New York, NY 10019']},
#    'phone': '+12127572747',
#    'display_phone': '(212) 757-2747',
#    'distance': 6755.312521837086},
#   {'id': 'r4SazXX-ISikdRYWbH-HAg',
#    'alias': 'hudson-and-co-jersey-city',
#    'name': 'Hudson & Co',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Fl5gb6TuB5J_98jzQV8f1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hudson-and-co-jersey-city?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 500,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720988, 'longitude': -74.031573},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '3 2nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'Jersey City',
#     'zip_code': '07302',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['3 2nd St', 'Jersey City, NJ 07302']},
#    'phone': '+12016857330',
#    'display_phone': '(201) 685-7330',
#    'distance': 3586.052429327624},
#   {'id': 'JT13SN5PPEJLa0HXXWRWkw',
#    'alias': '18th-ward-brewing-brooklyn',
#    'name': '18th Ward Brewing',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2zmIJpkVFakiZB0db9KLsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/18th-ward-brewing-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.719652, 'longitude': -73.939498},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '300 Richardson St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['300 Richardson St', 'Brooklyn, NY 11222']},
#    'phone': '+17183874025',
#    'display_phone': '(718) 387-4025',
#    'distance': 4881.111384184543},
#   {'id': 'Hc2KkfFWYnWYtL11_F40Ew',
#    'alias': 'brooklyn-ice-house-brooklyn',
#    'name': 'Brooklyn Ice House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZPgZWmntl0aSpqjyENwIIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-ice-house-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 230,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67919, 'longitude': -74.011099},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '318 Van Brunt St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['318 Van Brunt St', 'Brooklyn, NY 11231']},
#    'phone': '+17182221865',
#    'display_phone': '(718) 222-1865',
#    'distance': 3245.078076133803},
#   {'id': 'apFNQyii29KahceFL1znOw',
#    'alias': 'das-biergarten-long-beach',
#    'name': 'Das Biergarten',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DWdTnJ6a2wB80w11S6QpFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/das-biergarten-long-beach?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 71,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.5858084002527,
#     'longitude': -73.7034325955231},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1148 West Beech St',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Beach',
#     'zip_code': '11561',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1148 West Beech St', 'Long Beach, NY 11561']},
#    'phone': '+15168972437',
#    'display_phone': '(516) 897-2437',
#    'distance': 27913.536887019764},
#   {'id': 'KLol7xXsBQm7R9RWaxHT2A',
#    'alias': 'hellcat-annies-tap-room-new-york-2',
#    'name': "Hellcat Annie's Tap Room",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9xNsdx_FOUxw9AyWRs7W4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hellcat-annies-tap-room-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 87,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76178, 'longitude': -73.99431},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '637 10th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['637 10th Ave', 'New York, NY 10036']},
#    'phone': '+12125862707',
#    'display_phone': '(212) 586-2707',
#    'distance': 6262.5067589506825},
#   {'id': 'UvU7OiSPwLYPw_6cwQiNww',
#    'alias': 'wetzels-pretzels-woodbridge',
#    'name': "Wetzel's Pretzels",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fQXVN_zd0iXD2ZCOScKing/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wetzels-pretzels-woodbridge?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.55648824903435,
#     'longitude': -74.29815190226205},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '308 Woodbridge Center Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodbridge',
#     'zip_code': '07095',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['308 Woodbridge Center Dr', 'Woodbridge, NJ 07095']},
#    'phone': '+17327261000',
#    'display_phone': '(732) 726-1000',
#    'distance': 30526.21534411082},
#   {'id': 'fhaXI9CpdMV1jBlbJm_aew',
#    'alias': 'auntie-annes-jf-kennedy-ap',
#    'name': "Auntie Anne's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IKKbS2_hsIz74niXS2MPPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auntie-annes-jf-kennedy-ap?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6478571026808,
#     'longitude': -73.7907242774963},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': 'Jfk International Airport',
#     'address2': '',
#     'address3': 'Terminal 8 - Depatures Level',
#     'city': 'JF KENNEDY AP',
#     'zip_code': '11430',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Jfk International Airport',
#      'Terminal 8 - Depatures Level',
#      'JF KENNEDY AP, NY 11430']},
#    'phone': '+17185531345',
#    'display_phone': '(718) 553-1345',
#    'distance': 18322.38711322721},
#   {'id': 'JNkK9xp-hTWxsLrboPWC3Q',
#    'alias': 'the-perfect-pint-new-york',
#    'name': 'The Perfect Pint',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KfjG_1K6TVGPhJ4q61T5kQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-perfect-pint-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 390,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'irish_pubs', 'title': 'Irish Pub'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7574091835053,
#     'longitude': -73.9837408764447},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '123 W 45th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['123 W 45th St', 'New York, NY 10036']},
#    'phone': '+12123541099',
#    'display_phone': '(212) 354-1099',
#    'distance': 5846.1734185813875},
#   {'id': 'xwdyPDcF1PifAiXyNnyA5Q',
#    'alias': 'third-avenue-ale-house-new-york',
#    'name': 'Third Avenue Ale House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_qDL5IbxBarKIdzIUCaQHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/third-avenue-ale-house-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 321,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7828, 'longitude': -73.95129},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1644 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1644 3rd Ave', 'New York, NY 10128']},
#    'phone': '+16465599131',
#    'display_phone': '(646) 559-9131',
#    'distance': 9334.991853498585},
#   {'id': 'aT6VpKPvHIoIbLNdT4bj8g',
#    'alias': 'dive-106-new-york-4',
#    'name': 'Dive 106',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ne6HUdJmFTXPCpR29oUMog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dive-106-new-york-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.80078, 'longitude': -73.96587},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '938 Amsterdam Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['938 Amsterdam Ave', 'New York, NY 10025']},
#    'phone': '+19179652840',
#    'display_phone': '(917) 965-2840',
#    'distance': 10868.7703493107},
#   {'id': '_2SfbMa2Qe4mtu2p08Zntw',
#    'alias': 'the-alementary-brewing-hackensack-2',
#    'name': 'The Alementary Brewing',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sKbMCaLr42RmrzsLQdPKAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-alementary-brewing-hackensack-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 122,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'breweries', 'title': 'Breweries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.90459, 'longitude': -74.04002},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '58 Voorhis Ln',
#     'address2': None,
#     'address3': '',
#     'city': 'Hackensack',
#     'zip_code': '07601',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['58 Voorhis Ln', 'Hackensack, NJ 07601']},
#    'phone': '+12019681290',
#    'display_phone': '(201) 968-1290',
#    'distance': 22476.624664556737},
#   {'id': 'RxVfu1yHCuINQ2bI7z7MtQ',
#    'alias': 'evil-twin-brewing-ridgewood-2',
#    'name': 'Evil Twin Brewing',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MidZKrvsxQ1N3cLzH4KBbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/evil-twin-brewing-ridgewood-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 76,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6962131, 'longitude': -73.9041592},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1616 George St',
#     'address2': '',
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1616 George St', 'Ridgewood, NY 11385']},
#    'phone': '+17183661850',
#    'display_phone': '(718) 366-1850',
#    'distance': 7666.691612860853},
#   {'id': 'iYmTPHpjcb3xtHn8DlkoWQ',
#    'alias': 'doc-watsons-new-york',
#    'name': "Doc Watson's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ePWDkDuvr2lfMGOPk1o3PQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doc-watsons-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 252,
#    'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.77226, 'longitude': -73.95548},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1490 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1490 2nd Ave', 'New York, NY 10075']},
#    'phone': '+12129885300',
#    'display_phone': '(212) 988-5300',
#    'distance': 8117.99717511201},
#   {'id': 'WRPrwGH50FBm7yiuYKiLjw',
#    'alias': 'mosaic-craft-cocktail-beer-and-wine-bar-astoria',
#    'name': 'Mosaic Craft Cocktail, Beer & Wine Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4zUywERGpv_JyMeWrNnQEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mosaic-craft-cocktail-beer-and-wine-bar-astoria?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 292,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7746577, 'longitude': -73.9183673},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '25-19 24th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25-19 24th Ave', 'Astoria, NY 11102']},
#    'phone': '+17187280708',
#    'display_phone': '(718) 728-0708',
#    'distance': 10007.420429132915},
#   {'id': 'oLA02lMIfgvbYquvXzkARw',
#    'alias': 'lillies-victorian-establishment-new-york-2',
#    'name': "Lillie's Victorian Establishment",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lv1yDDDoSCoOYzRPXbrleg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lillies-victorian-establishment-new-york-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1463,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7614625, 'longitude': -73.9860519},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '249 W 49th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['249 W 49th St', 'New York, NY 10019']},
#    'phone': '+12129574530',
#    'display_phone': '(212) 957-4530',
#    'distance': 6267.456448728524},
#   {'id': 'SBLoGGk936tFHg0gYSZ-ow',
#    'alias': 'kent-ale-house-brooklyn',
#    'name': 'Kent Ale House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/if-xMQCIGEVmXBSbUJIvXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kent-ale-house-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 179,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7223281860352,
#     'longitude': -73.9592514038086},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '51 Kent Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['51 Kent Ave', 'Brooklyn, NY 11249']},
#    'phone': '+13472278624',
#    'display_phone': '(347) 227-8624',
#    'distance': 3497.2903432486546},
#   {'id': 'DMOwfdP0Va1QI_KNefD8kg',
#    'alias': 'berry-park-brooklyn',
#    'name': 'Berry Park',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IsaOmF8XRx5PRKQm2sA36w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/berry-park-brooklyn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 690,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7224719, 'longitude': -73.9552526},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4 Berry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4 Berry St', 'Brooklyn, NY 11211']},
#    'phone': '+17187822829',
#    'display_phone': '(718) 782-2829',
#    'distance': 3796.282557902373},
#   {'id': 'IZV317V2lwA-Eb5EFrKzLg',
#    'alias': 'auntie-annes-elizabeth',
#    'name': "Auntie Anne's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0EIlkJrwUOPvgbS-lrB66w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/auntie-annes-elizabeth?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'pretzels', 'title': 'Pretzels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.659224, 'longitude': -74.170309},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '651 Kapkowski Rd',
#     'address2': 'Space 2258',
#     'address3': '',
#     'city': 'Elizabeth',
#     'zip_code': '07201',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['651 Kapkowski Rd',
#      'Space 2258',
#      'Elizabeth, NJ 07201']},
#    'phone': '+19088204315',
#    'display_phone': '(908) 820-4315',
#    'distance': 15706.832273637532},
#   {'id': 'lGe2NRqJbEhf1dA0zo-qBw',
#    'alias': 'hudson-station-new-york',
#    'name': 'Hudson Station',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rDGR7fqDObP2XcZhw0V0Uw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hudson-station-new-york?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 261,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.753676, 'longitude': -73.995493},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '440 9th Ave SE 35th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['440 9th Ave SE 35th St', 'New York, NY 10001']},
#    'phone': '+12122444406',
#    'display_phone': '(212) 244-4406',
#    'distance': 5364.004435374695}],
#  'total': 240,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (nycr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#        Restaurant            Type Price Rating           Address        Lat  \
# 0        Loki Bar  American (New)    $$      4        341 2nd St  40.673937
# 1         Alfie's  American (New)    $$      4       800 9th Ave  40.765437
# 2        That Bar      Gastropubs    $$      4        47 5th Ave  40.681342
# 3  Zum Stammtisch          German    $$      4   6946 Myrtle Ave  40.701762
# 4           Prost          German    $$    3.5  652 Franklin Ave  40.724560
#
#          Lng                                                url  \
# 0 -73.983064  https://www.yelp.com/biz/loki-bar-park-slope-6...
# 1 -73.987278  https://www.yelp.com/biz/alfies-new-york?adjus...
# 2 -73.976948  https://www.yelp.com/biz/that-bar-brooklyn-2?a...
# 3 -73.881341  https://www.yelp.com/biz/zum-stammtisch-glenda...
# 4 -73.634030  https://www.yelp.com/biz/prost-garden-city?adj...
#
#                        ID
# 0  2270Iy6WQskMawb4iETO8w
# 1  tOn-wEQ06ScrgeU5Ljw7Gw
# 2  CJpBLfB3csuC0ZVQYaqbtQ
# 3  19o6iblcJvz2hdPouYhXgg
# 4  _edG68ufw52-v_xRL4jsyw

# %%
nyc_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
nyc_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
nyc_restaurants_df = nyc_restaurants_df[column_order]
nyc_restaurants_df = nyc_restaurants_df.sort_values(["Type"], ascending=True)
nyc_restaurants_df = nyc_restaurants_df.reset_index(drop=True)
nyc_restaurants_df
# Out:
#                                     Restaurant                    Type Rating  \
# 0                                   Berry Park          American (New)    3.5
# 1                                    Lock Yard          American (New)      4
# 2                             The Barrow House          American (New)      4
# 3                  Jasper's Taphouse + Kitchen          American (New)      4
# 4                              The Stag's Head          American (New)      4
# 5                                      Clancey          American (New)    4.5
# 6                              The Wicked Monk          American (New)      4
# 7                                      Alfie's          American (New)      4
# 8                                     Loki Bar          American (New)      4
# 9                              The Brooklyneer          American (New)    3.5
# 10                              Hudson Station  American (Traditional)      3
# 11                       Blind Tiger Ale House  American (Traditional)      4
# 12                            Black Tap - Soho  American (Traditional)    3.5
# 13                               Zeppelin Hall  American (Traditional)    3.5
# 14                            The Perfect Pint  American (Traditional)      4
# 15                      Third Avenue Ale House  American (Traditional)    3.5
# 16                              Kent Ale House  American (Traditional)      4
# 17                           Amity Hall Uptown  American (Traditional)      4
# 18                      Philly Pretzel Factory                Bakeries      5
# 19                      Philly Pretzel Factory                Bakeries
# 20                      Philly Pretzel Factory                Bakeries    3.5
# 21                      Philly Pretzel Factory                Bakeries      4
# 22                               Mason Jar NYC                Barbeque    3.5
# 23                          Brooklyn Ice House                Barbeque    4.5
# 24   The Biergarten at The Standard, High Line                    Bars    3.5
# 25                                         Bua                    Bars      4
# 26                                       Gruit                    Bars
# 27            Lillie's Victorian Establishment                    Bars      4
# 28                                Clinton Hall                    Bars    3.5
# 29                                  The Bonnie                    Bars      4
# ..                                         ...                     ...    ...
# 170                     Philly Pretzel Factory                Pretzels    3.5
# 171                   Island Soft Pretzel Stop                Pretzels
# 172                     Auntie Anne's Pretzels                Pretzels      3
# 173                     Philly Pretzel Factory                Pretzels
# 174                             Chelsea Market          Public Markets    4.5
# 175                                   Valhalla                    Pubs      4
# 176                                  The Craic                    Pubs      4
# 177                Arts and Crafts Beer Parlor                    Pubs    4.5
# 178                        Stone Street Tavern                    Pubs    3.5
# 179                         Ulysses Folk House                    Pubs      3
# 180    White Horse Tavern - Financial District                    Pubs      4
# 181                          The Full Shilling                    Pubs      4
# 182                                   Tavern29                    Pubs      4
# 183                       Waterfront Ale House                    Pubs    3.5
# 184                                Irish Rover                    Pubs    4.5
# 185               Radegast Hall and Biergarten                    Pubs      4
# 186                    O'Henry's Publick House                    Pubs
# 187                            Smithfield Hall                    Pubs      4
# 188              Keg & Lantern Brewing Company                    Pubs      4
# 189                                 Union Hall                    Pubs      4
# 190                                  Hops Hill              Sandwiches    4.5
# 191                                Tap Haus 33             Sports Bars    4.5
# 192                          The Three Monkeys             Sports Bars      4
# 193                                 Amity Hall             Sports Bars    3.5
# 194                                   Triona's             Sports Bars      4
# 195                                      Stout             Sports Bars    3.5
# 196                             Threes Brewing   Venues & Event Spaces      4
# 197                Bohemian Hall & Beer Garden   Venues & Event Spaces      4
# 198                        Nostrand Avenue Pub            Whiskey Bars      4
# 199            The Baroness Bar Burgers + Beer               Wine Bars      4
#
#     Price                   Address        Lat        Lng  \
# 0      $$                4 Berry St  40.722472 -73.955253
# 1      $$              9221 5th Ave  40.617264 -74.029419
# 2      $$       1296 Van Houten Ave  40.871706 -74.172376
# 3      $$               761 9th Ave  40.764266 -73.988612
# 4      $$             252 E 51st St  40.755592 -73.968588
# 5      $$             79 Clinton St  40.719030 -73.985210
# 6      $$              9510 3rd Ave  40.616988 -74.034023
# 7      $$               800 9th Ave  40.765437 -73.987278
# 8      $$                341 2nd St  40.673937 -73.983064
# 9      $$          220 W Houston St  40.728622 -74.004566
# 10     $$    440 9th Ave SE 35th St  40.753676 -73.995493
# 11     $$           281 Bleecker St  40.731926 -74.003223
# 12     $$             529 Broome St  40.723794 -74.004193
# 13     $$        88 Liberty View Dr  40.715132 -74.046672
# 14     $$             123 W 45th St  40.757409 -73.983741
# 15     $$              1644 3rd Ave  40.782800 -73.951290
# 16     $$               51 Kent Ave  40.722328 -73.959251
# 17     $$         982 Amsterdam Ave  40.802310 -73.964750
# 18      $              713 Broadway  40.671602 -74.111973
# 19                       408 Jay St  40.691791 -73.987572
# 20      $             960 Amboy Ave  40.534000 -74.334070
# 21      $           295 South Ave E  40.650044 -74.338978
# 22     $$              43 E 30th St  40.744890 -73.983680
# 23      $          318 Van Brunt St  40.679190 -74.011099
# 24     $$         848 Washington St  40.740799 -74.007907
# 25     $$           122 St Marks Pl  40.726854 -73.983807
# 26                  252 Empire Blvd  40.663466 -73.953647
# 27     $$             249 W 49th St  40.761463 -73.986052
# 28     $$             230 E 51st St  40.755800 -73.969050
# 29     $$            29-12 23rd Ave  40.774674 -73.913600
# ..    ...                       ...        ...        ...
# 170     $            604 Forest Ave  40.629833 -74.109413
# 171        St George Ferry Terminal  40.642510 -74.073700
# 172     $              30 Mall Dr W  40.726810 -74.036997
# 173                       1126 US 9  40.449492 -74.299073
# 174    $$                75 9th Ave  40.741971 -74.004845
# 175    $$               815 9th Ave  40.765960 -73.987370
# 176    $$            488 Driggs Ave  40.718520 -73.955040
# 177    $$               26 W 8th St  40.732728 -73.997716
# 178    $$               52 Stone St  40.704369 -74.010201
# 179    $$               95 Pearl St  40.704280 -74.009919
# 180     $              25 Bridge St  40.703720 -74.012370
# 181    $$              160 Pearl St  40.705722 -74.007469
# 182    $$              47 E 29th St  40.744310 -73.983940
# 183    $$               540 2nd Ave  40.742040 -73.977500
# 184     $             3718 28th Ave  40.765755 -73.914749
# 185    $$              113 N 3rd St  40.716641 -73.961498
# 186                 10 Minthorne St  40.637505 -74.075560
# 187    $$             138 W 25th St  40.744753 -73.993494
# 188    $$             97 Nassau Ave  40.724054 -73.950341
# 189    $$              702 Union St  40.676120 -73.980050
# 190    $$             886 Fulton St  40.683090 -73.965570
# 191    $$              14 E 33rd St  40.747247 -73.984300
# 192    $$             236 W 54th St  40.764164 -73.983060
# 193    $$               80 W 3rd St  40.729630 -73.998920
# 194     $           237 Sullivan St  40.729890 -73.999380
# 195    $$              60 E 41st St  40.751612 -73.978820
# 196    $$           333 Douglass St  40.679722 -73.982162
# 197    $$             2919 24th Ave  40.772730 -73.915772
# 198     $          658 Nostrand Ave  40.675862 -73.950236
# 199    $$         47-18 Vernon Blvd  40.744960 -73.953620
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/berry-park-brooklyn?a...  DMOwfdP0Va1QI_KNefD8kg
# 1    https://www.yelp.com/biz/lock-yard-brooklyn?ad...  5f3M0k7mTjrKoQFJW-PFzg
# 2    https://www.yelp.com/biz/the-barrow-house-clif...  U_hLyiUqDB16FBREKfJ8Xw
# 3    https://www.yelp.com/biz/jaspers-taphouse-kitc...  j3HLOkrjzBjcvYPiIHua1A
# 4    https://www.yelp.com/biz/the-stags-head-new-yo...  y6XohzcYjUAQOD8U3NT_yw
# 5    https://www.yelp.com/biz/clancey-new-york?adju...  7qtIemPU3LlNix8CVWdhwA
# 6    https://www.yelp.com/biz/the-wicked-monk-brook...  VP_HZr_j0dXKd80lUBfsyg
# 7    https://www.yelp.com/biz/alfies-new-york?adjus...  tOn-wEQ06ScrgeU5Ljw7Gw
# 8    https://www.yelp.com/biz/loki-bar-park-slope-6...  2270Iy6WQskMawb4iETO8w
# 9    https://www.yelp.com/biz/the-brooklyneer-new-y...  Ad3JpyadCNBDKZiKD57Tbw
# 10   https://www.yelp.com/biz/hudson-station-new-yo...  lGe2NRqJbEhf1dA0zo-qBw
# 11   https://www.yelp.com/biz/blind-tiger-ale-house...  PMp7WlHIXQUnej-Ds1jRfw
# 12   https://www.yelp.com/biz/black-tap-soho-new-yo...  D2qV8sDdHEFlHbVz7VSHRQ
# 13   https://www.yelp.com/biz/zeppelin-hall-jersey-...  P5X8K61nDAlo8QrgCn-agQ
# 14   https://www.yelp.com/biz/the-perfect-pint-new-...  JNkK9xp-hTWxsLrboPWC3Q
# 15   https://www.yelp.com/biz/third-avenue-ale-hous...  xwdyPDcF1PifAiXyNnyA5Q
# 16   https://www.yelp.com/biz/kent-ale-house-brookl...  SBLoGGk936tFHg0gYSZ-ow
# 17   https://www.yelp.com/biz/amity-hall-uptown-new...  yOPbrFZ2ZUsyQWsedP6gUg
# 18   https://www.yelp.com/biz/philly-pretzel-factor...  va93RJg_tlMcgwBQoIoPaw
# 19
# 20   https://www.yelp.com/biz/philly-pretzel-factor...  R7AngT3-6uRGs-rSUivOfQ
# 21   https://www.yelp.com/biz/philly-pretzel-factor...  _IHpfiDskjESk88OqscjbQ
# 22   https://www.yelp.com/biz/mason-jar-nyc-new-yor...  qjzkDnjT2sIa_8-uYaMYoA
# 23   https://www.yelp.com/biz/brooklyn-ice-house-br...  Hc2KkfFWYnWYtL11_F40Ew
# 24   https://www.yelp.com/biz/the-biergarten-at-the...  F622poZMX_mk1eoSoUOyaw
# 25   https://www.yelp.com/biz/bua-new-york?adjust_c...  n8p5g3-Fu1RBKx35QhiaXg
# 26
# 27   https://www.yelp.com/biz/lillies-victorian-est...  oLA02lMIfgvbYquvXzkARw
# 28   https://www.yelp.com/biz/clinton-hall-new-york...  CjSLDlOGzyHcJPwYXZQsWw
# 29   https://www.yelp.com/biz/the-bonnie-astoria?ad...  rrsjcQVLg2PkIkO_vPjOLw
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/philly-pretzel-factor...  VBa_hZ0COXmmN7cKJvfLWg
# 171
# 172  https://www.yelp.com/biz/auntie-annes-pretzels...  h1bYtCaLRAlJjydNAyGlmQ
# 173
# 174  https://www.yelp.com/biz/chelsea-market-new-yo...  jF5CrF1BmvhoPlMTp5AoJQ
# 175  https://www.yelp.com/biz/valhalla-new-york?adj...  Rpw8mQPKJb8esVjosT4Sog
# 176  https://www.yelp.com/biz/the-craic-brooklyn?ad...  PxyxNj43WSDjRF588HFJdQ
# 177  https://www.yelp.com/biz/arts-and-crafts-beer-...  7sQYI_Ym9RzlxHIhJpj6hg
# 178  https://www.yelp.com/biz/stone-street-tavern-n...  NA_p2AH5RSBV314bklZn_g
# 179  https://www.yelp.com/biz/ulysses-folk-house-ne...  mn6JM5lHuSSsG9KSXck3ww
# 180  https://www.yelp.com/biz/white-horse-tavern-fi...  lHGQM__w1x5Dxiq3aRPCTQ
# 181  https://www.yelp.com/biz/the-full-shilling-new...  qpD22cY8CSXLT2qujiJtqw
# 182  https://www.yelp.com/biz/tavern29-new-york?adj...  NTwOc9yQ1xl5deeVzZqxfw
# 183  https://www.yelp.com/biz/waterfront-ale-house-...  Ayx5XNT7i79TUjbHTTC5YQ
# 184  https://www.yelp.com/biz/irish-rover-astoria?a...  do_ndggWB4Gb56rP6ikbVw
# 185  https://www.yelp.com/biz/radegast-hall-and-bie...  TOaQzGPAIQWQUIXi4CPnbA
# 186
# 187  https://www.yelp.com/biz/smithfield-hall-new-y...  GlSWzWVmQsKLGxySYSGRbQ
# 188  https://www.yelp.com/biz/keg-and-lantern-brewi...  8vwANffgp9s9RDCSn3mD5w
# 189  https://www.yelp.com/biz/union-hall-brooklyn?a...  noujMiOizbAWyDw8LbiM8Q
# 190  https://www.yelp.com/biz/hops-hill-brooklyn?ad...  epDvy_G3YITZRbhqcExkBg
# 191  https://www.yelp.com/biz/tap-haus-33-new-york?...  lNP1km2kaEtlsBw2VNHHhQ
# 192  https://www.yelp.com/biz/the-three-monkeys-new...  IBgjj5VBu5JJvKgo9EzKrg
# 193  https://www.yelp.com/biz/amity-hall-new-york?a...  6FIzpXy82HBT3KZaiA38-Q
# 194  https://www.yelp.com/biz/trionas-new-york-2?ad...  _xRGTDjG-nYMgCCNcmCoNQ
# 195  https://www.yelp.com/biz/stout-grand-central-n...  35ezIH9BDHLY4XVQrxw6NA
# 196  https://www.yelp.com/biz/threes-brewing-brookl...  hKChLzaG8tyrSrg3U_wRNw
# 197  https://www.yelp.com/biz/bohemian-hall-and-bee...  cuVyM_ZxtREqpO1SXgZmRA
# 198  https://www.yelp.com/biz/nostrand-avenue-pub-b...  XaAj9qfWoQ048-5D9ciX-g
# 199  https://www.yelp.com/biz/the-baroness-bar-burg...  jW22gmsZjh5hFJsC1qUDOA
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
nyc_restaurants_df.to_csv('Resources/NYC_Restaurants_Pretzel.csv')
