# %% [markdown]
# LONDON RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
lndr_params1 = {"term":"brunch","location":"London","limit":50,"offset":0}
lndr_response1 = requests.get(search_api_url, headers=headers, params=lndr_params1)
lndr1 = lndr_response1.json()
display(lndr1)
#print(lndr_response1.url)
#print(lndr_response1.status_code)
# Out:
# {'businesses': [{'id': 'tYynO1nOy1GKxMV3jkxbmw',
#    'alias': 'the-breakfast-club-london-2',
#    'name': 'The Breakfast Club',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TElKM303HWt3LAkvgBuTWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-breakfast-club-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 497,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514733, 'longitude': -0.135406},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "33 D'Arblay Street",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["33 D'Arblay Street",
#      'London W1F 8EU',
#      'United Kingdom']},
#    'phone': '+442074342571',
#    'display_phone': '+44 20 7434 2571',
#    'distance': 215.73161782407266},
#   {'id': '70Q-Ll18zb4aglXXbUG7lw',
#    'alias': 'ffionas-restaurant-london',
#    'name': "Ffiona's Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/seykrl3tugRsE8UL6-phKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ffionas-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 265,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.50405773515,
#     'longitude': -0.192783395566043},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '51 Kensington Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Kensington Church Street',
#      'London W8 4BA',
#      'United Kingdom']},
#    'phone': '+442079374152',
#    'display_phone': '+44 20 7937 4152',
#    'distance': 4052.2035032181666},
#   {'id': 'mK87F1KiR7Ph-iOwI45Thw',
#    'alias': 'milk-london-2',
#    'name': 'Milk',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mkSDunrDVhCd2ba-ISglrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/milk-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.444649, 'longitude': -0.1510286},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18-20 Bedford Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW12 9RG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18-20 Bedford Hill',
#      'London SW12 9RG',
#      'United Kingdom']},
#    'phone': '+44442087729085',
#    'display_phone': '+44 442087729085',
#    'distance': 7653.50288388963},
#   {'id': 'a4FkZ2b7Wn3-AP7q3ptHtQ',
#    'alias': 'duck-and-waffle-local-london',
#    'name': 'Duck & Waffle Local',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zd2VBLt5bwlnlLFVP1VIWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duck-and-waffle-local-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 141,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'waffles', 'title': 'Waffles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5094175706263,
#     'longitude': -0.132749820495633},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '52 Haymarket',
#     'address2': "St James's Market",
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 4RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['52 Haymarket',
#      "St James's Market",
#      'London SW1Y 4RP',
#      'United Kingdom']},
#    'phone': '+442039004444',
#    'display_phone': '+44 20 3900 4444',
#    'distance': 440.07809948825326},
#   {'id': '7_mJPWb6tREPW58f2xRpgA',
#    'alias': 'where-the-pancakes-are-london-2',
#    'name': 'Where the Pancakes are',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/u3gKgKG_1-RmLHhB0VQXMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/where-the-pancakes-are-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 75,
#    'categories': [{'alias': 'pancakes', 'title': 'Pancakes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.504367, 'longitude': -0.0955551},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Arch 35a',
#     'address2': '85 Southwark Bridge Road',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 0NQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Arch 35a',
#      '85 Southwark Bridge Road',
#      'London SE1 0NQ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2951.471145585305},
#   {'id': '0r2-fwgLvuOLef0epiFkFQ',
#    'alias': 'granger-and-co-london',
#    'name': 'Granger & Co',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4pSTSM2JgsADC_cPoLBQJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/granger-and-co-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 183,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514646148453,
#     'longitude': -0.19779915622354},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '175 Westbourne Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['175 Westbourne Grove',
#      'London W11 2SB',
#      'United Kingdom']},
#    'phone': '+442072299111',
#    'display_phone': '+44 20 7229 9111',
#    'distance': 4284.263019990538},
#   {'id': 'tNqlff6UM01PCRaSg3kdfA',
#    'alias': 'soho-joe-london-2',
#    'name': 'Soho Joe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i5TOWJJ9ixhIO1r2pq0IIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soho-joe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5149162419674,
#     'longitude': -0.135393677274406},
#    'transactions': [],
#    'location': {'address1': "34 D'Arblay St",
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1F 8EY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["34 D'Arblay St", 'London W1F 8EY', 'United Kingdom']},
#    'phone': '+447534134398',
#    'display_phone': '+44 7534 134398',
#    'distance': 234.61259657975114},
#   {'id': 'BZElA7zGQvVCBXCHcQO37A',
#    'alias': 'farm-girl-london',
#    'name': 'Farm Girl',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FpD2ozhuT8Mx1vrX2bMLzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/farm-girl-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5124174815933,
#     'longitude': -0.137917511165142},
#    'transactions': [],
#    'location': {'address1': '1 Carnaby St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1F 9QG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Carnaby St', 'London W1F 9QG', 'United Kingdom']},
#    'phone': '+442072294678',
#    'display_phone': '+44 20 7229 4678',
#    'distance': 143.48996186400115},
#   {'id': 'rKwkCvsSfp8z7w1CmNnMMQ',
#    'alias': 'the-table-london-8',
#    'name': 'The Table',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/T-rwpQYiLxDyUXGNAwEYSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-table-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 268,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.505604, 'longitude': -0.099671},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '83 Southwark Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Southwark Street',
#      'London SE1 0HX',
#      'United Kingdom']},
#    'phone': '+442074012760',
#    'display_phone': '+44 20 7401 2760',
#    'distance': 2636.7435245046486},
#   {'id': 'T-_ewkgY9DiMJ36qHL4UvQ',
#    'alias': 'greenberry-café-london',
#    'name': 'Greenberry Café',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZD7JdkRDA6OEHybFT934Hw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greenberry-caf%C3%A9-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.542194, 'longitude': -0.156334},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '101 Regents Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8UR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['101 Regents Park Road',
#      'London NW1 8UR',
#      'United Kingdom']},
#    'phone': '+442074833765',
#    'display_phone': '+44 20 7483 3765',
#    'distance': 3554.568759488491},
#   {'id': 'Z0r83lDOA1mI8RpNccXtHw',
#    'alias': 'the-fat-bear-london',
#    'name': 'The Fat Bear',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-U3vVDIo1UItF64Gf1yAZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-fat-bear-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 123,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'soulfood', 'title': 'Soul Food'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5131833881734,
#     'longitude': -0.10138103121642},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61 Carter Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4V 5DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Carter Lane',
#      'London EC4V 5DY',
#      'United Kingdom']},
#    'phone': '+442072362498',
#    'display_phone': '+44 20 7236 2498',
#    'distance': 2392.909207748214},
#   {'id': 'KcTG8dVnattBQaWXdIzMrg',
#    'alias': 'feya-london',
#    'name': 'Feya',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/29bCWknB8eqsYuHmY2ii3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/feya-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51509, 'longitude': -0.1508},
#    'transactions': [],
#    'location': {'address1': '23 James St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1U 1DT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23 James St', 'London W1U 1DT', 'United Kingdom']},
#    'phone': '+442078580858',
#    'display_phone': '+44 20 7858 0858',
#    'distance': 1056.5656492391608},
#   {'id': 'RdVuh5xQAkzULoKtjXsE1Q',
#    'alias': 'mill-and-brew-london-3',
#    'name': 'Mill & Brew',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AYy71B2VX1cGjehIm5Jarg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mill-and-brew-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.6144307, 'longitude': -0.2483771},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '23 The Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW7 3DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23 The Broadway',
#      'London NW7 3DA',
#      'United Kingdom']},
#    'phone': '+442089596964',
#    'display_phone': '+44 20 8959 6964',
#    'distance': 13711.561379122157},
#   {'id': 'PHTcl--LbBwA1N6EHZV_sg',
#    'alias': 'new-london-cafe-london',
#    'name': 'New London Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JCkupf-AWh-_sjg8myef1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-london-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.546910711, 'longitude': -0.0983781045074466},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "216 St Paul's Road",
#     'address2': 'Islington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 2LL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["216 St Paul's Road",
#      'Islington',
#      'London N1 2LL',
#      'United Kingdom']},
#    'phone': '+442073547321',
#    'display_phone': '+44 20 7354 7321',
#    'distance': 4594.940461650296},
#   {'id': 'e5jPAqpCcIAsTtasUN5h2g',
#    'alias': 'the-wolseley-london',
#    'name': 'The Wolseley',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T9xpXsz-az88-l0Ko_KLpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wolseley-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 553,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.507617, 'longitude': -0.141012},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '160 Picadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 9EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['160 Picadilly', 'London W1J 9EB', 'United Kingdom']},
#    'phone': '+442074996996',
#    'display_phone': '+44 20 7499 6996',
#    'distance': 677.6098617325135},
#   {'id': 'Rb3xF0gkAwnDHML6okB1FA',
#    'alias': 'honey-and-co-london',
#    'name': 'Honey & Co',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GjRuBFxsvAvRsNXS44S23Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/honey-and-co-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 112,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5238287, 'longitude': -0.1407882},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '25a Warren Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 5LZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['25a Warren Street',
#      'London W1T 5LZ',
#      'United Kingdom']},
#    'phone': '+442073886175',
#    'display_phone': '+44 20 7388 6175',
#    'distance': 1267.2898980857588},
#   {'id': '-ylzTrYtRJUJa2BuAInoyQ',
#    'alias': 'friends-of-ours-london',
#    'name': 'Friends of Ours',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/q5Fg1_UQtNmvOoIzrLzhAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/friends-of-ours-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 96,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5291189, 'longitude': -0.0836995},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61 Pitfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 6BU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Pitfield Street',
#      'London N1 6BU',
#      'United Kingdom']},
#    'phone': '+442076865525',
#    'display_phone': '+44 20 7686 5525',
#    'distance': 4041.3053965414406},
#   {'id': 'PBFvhVyBi0lEJyTbyuxf5w',
#    'alias': 'the-orangery-london-7',
#    'name': 'The Orangery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L_0d22xNmfCC_d-tArBo3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-orangery-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 238,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5066360577041,
#     'longitude': -0.187725349125042},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Kensington Palace',
#     'address2': 'Palace Green',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Kensington Palace',
#      'Palace Green',
#      'London W8 4PX',
#      'United Kingdom']},
#    'phone': '+442031666113',
#    'display_phone': '+44 20 3166 6113',
#    'distance': 3648.4574890404074},
#   {'id': 'sTjZJB20joSHE8oVPHs1Cw',
#    'alias': 'covent-garden-grind-london',
#    'name': 'Covent Garden Grind',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c7YW3mmPah5JplPL-fFPbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/covent-garden-grind-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5110479046224,
#     'longitude': -0.122459969000028},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '42 Maiden Lane',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 7LJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 Maiden Lane',
#      'Covent Garden',
#      'London WC2E 7LJ',
#      'United Kingdom']},
#    'phone': '+442030191801',
#    'display_phone': '+44 20 3019 1801',
#    'distance': 954.8611659358846},
#   {'id': 'YNduANMPzIVE8CzBH7YjEQ',
#    'alias': 'regency-café-london-2',
#    'name': 'Regency Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pz5q5e8LBG7C1ozSuhvuKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/regency-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 393,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4940143171, 'longitude': -0.13222007974201},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '17-19 Regency Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 4BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17-19 Regency Street',
#      'London SW1P 4BY',
#      'United Kingdom']},
#    'phone': '+442078216596',
#    'display_phone': '+44 20 7821 6596',
#    'distance': 2108.732795587357},
#   {'id': '6NIJqOFjLUPXnGaJbxW3lA',
#    'alias': 'l-eto-london-2',
#    'name': "L'ETO",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wPsMI8cgIW_5JjqdEcUhgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-eto-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.496624, 'longitude': -0.1688603},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '243 Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['243 Brompton Road', 'London SW3', 'United Kingdom']},
#    'phone': '+442078542860',
#    'display_phone': '+44 20 7854 2860',
#    'distance': 2898.9080858295915},
#   {'id': 'UMJxTGTSShg2u1FFwZBWAQ',
#    'alias': 'the-book-club-london',
#    'name': 'The Book Club',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8HCdjBRKyg074ero0uqGAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-book-club-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.524537, 'longitude': -0.081494},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '100 Leonard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 4RH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['100 Leonard Street',
#      'London EC2A 4RH',
#      'United Kingdom']},
#    'phone': '+442076848618',
#    'display_phone': '+44 20 7684 8618',
#    'distance': 3994.972382925784},
#   {'id': '68gc1BAE1IT_zZghFafw0Q',
#    'alias': 'ozone-coffee-london-2',
#    'name': 'Ozone Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FMKfpA6gKHlDAKDuPVVdTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ozone-coffee-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 188,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.524683689256,
#     'longitude': -0.086674106560876},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Leonard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 4AQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Leonard Street',
#      'London EC2A 4AQ',
#      'United Kingdom']},
#    'phone': '+442074901039',
#    'display_phone': '+44 20 7490 1039',
#    'distance': 3655.552919913525},
#   {'id': 'hOLFwKg4-0FsCleJ4yoCXw',
#    'alias': 'duck-and-waffle-london',
#    'name': 'Duck & Waffle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WrS5I1dN-nGXePaADwE0cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duck-and-waffle-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 707,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516178, 'longitude': -0.08094},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '110 Bishopsgate',
#     'address2': '40th Floor',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2N 4AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['110 Bishopsgate',
#      '40th Floor',
#      'London EC2N 4AY',
#      'United Kingdom']},
#    'phone': '+442036407310',
#    'display_phone': '+44 20 3640 7310',
#    'distance': 3825.102922188434},
#   {'id': 'se61yyYAHdJZ_Fq9ygXjVg',
#    'alias': 'bills-london-4',
#    'name': "Bill's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BMTYyZHF72uuASONanBykA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bills-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 207,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511881, 'longitude': -0.135307},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '36-44 Brewer Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9TB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['36-44 Brewer Street',
#      'London W1F 9TB',
#      'United Kingdom']},
#    'phone': '+442072878712',
#    'display_phone': '+44 20 7287 8712',
#    'distance': 121.31404288224127},
#   {'id': 'EanCLBAeSJNU9MA0pVlHVg',
#    'alias': 'cafe-twelve-london',
#    'name': 'Cafe Twelve',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uAIN5SbTugPIgyu7ljHtjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-twelve-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.528322, 'longitude': -0.075946},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '57 Hackney Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7NX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57 Hackney Rd', 'London E2 7NX', 'United Kingdom']},
#    'phone': '+442077299319',
#    'display_phone': '+44 20 7729 9319',
#    'distance': 4494.95978931185},
#   {'id': 'jrRKp4dsl9uTQjBb0uBbfw',
#    'alias': 'pimlico-fresh-london',
#    'name': 'Pimlico Fresh',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pxjxkpfArqkdyAaBJwaWZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pimlico-fresh-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 154,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.492391374275,
#     'longitude': -0.14021524722041},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '85 Wilton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1DE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['85 Wilton Road',
#      'London SW1V 1DE',
#      'United Kingdom']},
#    'phone': '+442079320030',
#    'display_phone': '+44 20 7932 0030',
#    'distance': 2292.321028443847},
#   {'id': 'BjPq77aiaKZAVUHIu2S3gA',
#    'alias': 'the-english-rose-cafe-and-tea-shop-london',
#    'name': 'The English Rose Cafe and Tea Shop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B_v1cOkgPEcbr8e2rtfaog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-english-rose-cafe-and-tea-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 213,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4980558, 'longitude': -0.1444512},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 Lower Grosvenor Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 0EJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Lower Grosvenor Place',
#      'London SW1W 0EJ',
#      'United Kingdom']},
#    'phone': '+442079766280',
#    'display_phone': '+44 20 7976 6280',
#    'distance': 1745.2072668809335},
#   {'id': 'JaveZcrYNz-Pq0UIjgWJCA',
#    'alias': 'egg-break-london',
#    'name': 'Egg Break',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FcjERvhFTXfYHIPi6uvQbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/egg-break-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 80,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.50832, 'longitude': -0.198022},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '30 Uxbridge Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 7TA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Uxbridge Street',
#      'London W8 7TA',
#      'United Kingdom']},
#    'phone': '+442035358300',
#    'display_phone': '+44 20 3535 8300',
#    'distance': 4312.433159863853},
#   {'id': 'cgkDnzaQvP9q-JHXd-ECcA',
#    'alias': 'cambridge-street-london-2',
#    'name': 'Cambridge Street',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FPLn24WdcutHUe8geTYRYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cambridge-street-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4905412, 'longitude': -0.1449144},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Artist Residence',
#     'address2': '52 Cambridge Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 4QQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Artist Residence',
#      '52 Cambridge Street',
#      'London SW1V 4QQ',
#      'United Kingdom']},
#    'phone': '+442032620501',
#    'display_phone': '+44 20 3262 0501',
#    'distance': 2558.1902736900183},
#   {'id': 'r9WDG-yHwzimEe10gR88Fg',
#    'alias': '39-steps-coffee-london',
#    'name': '39 Steps Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_9YteXr-jIFUECyJ53yuuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/39-steps-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5137938420751,
#     'longitude': -0.135145469921005},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "8 D'Arblay St",
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1F 8DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["8 D'Arblay St", 'London W1F 8DP', 'United Kingdom']},
#    'phone': '+442072876682',
#    'display_phone': '+44 20 7287 6682',
#    'distance': 120.41421495607376},
#   {'id': 'PYwzVOvFIjwCMNYV5upPwg',
#    'alias': 'the-attendant-london-2',
#    'name': 'The Attendant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W4pc8bJ_lVWg801nKejVOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-attendant-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 74,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5192470995905,
#     'longitude': -0.140738025145255},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Downstairs 27A',
#     'address2': 'Foley Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 6DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Downstairs 27A',
#      'Foley Street',
#      'London W1W 6DY',
#      'United Kingdom']},
#    'phone': '+442076373794',
#    'display_phone': '+44 20 7637 3794',
#    'distance': 785.9877629261662},
#   {'id': 'p77CnjTGOIZA1hEpLfCC6Q',
#    'alias': 'kennington-lane-cafe-london',
#    'name': 'Kennington Lane Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4pjtT4PSUYl_0_BqOTx6Cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kennington-lane-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4860611, 'longitude': -0.1208514},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '383 Kennington Lane',
#     'address2': 'Vauxhall',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE11 5QY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['383 Kennington Lane',
#      'Vauxhall',
#      'London SE11 5QY',
#      'United Kingdom']},
#    'phone': '+442077355853',
#    'display_phone': '+44 20 7735 5853',
#    'distance': 3147.932368103276},
#   {'id': 'bJiVADMSTEKj0MjqiLrOPA',
#    'alias': 'the-grazing-goat-marylebone-london',
#    'name': 'The Grazing Goat Marylebone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/h73f5PAFit9wdm8w_zm3lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grazing-goat-marylebone-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 240,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515378341447,
#     'longitude': -0.15823586449841},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 New Quebec Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7RQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 New Quebec Street',
#      'London W1H 7RQ',
#      'United Kingdom']},
#    'phone': '+442077247243',
#    'display_phone': '+44 20 7724 7243',
#    'distance': 1567.469377589238},
#   {'id': 'ZTSM33QFv3pwxtSJp8Y02g',
#    'alias': 'farmacy-london',
#    'name': 'Farmacy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/38AZr06tSZ3IU2zDxBb7zQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/farmacy-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 67,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.515446, 'longitude': -0.1926381},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '74 Westbourne Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 5SH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['74 Westbourne Grove',
#      'London W2 5SH',
#      'United Kingdom']},
#    'phone': '+442072210705',
#    'display_phone': '+44 20 7221 0705',
#    'distance': 3938.117967873019},
#   {'id': 'YfKn2fkIyXC2jmE1qmgxQw',
#    'alias': 'outsider-tart-london',
#    'name': 'Outsider Tart',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CCbq7o_xmLzRkBXvNOh9TQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/outsider-tart-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4927, 'longitude': -0.252125},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '83 Chiswick High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W4 2EF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Chiswick High Road',
#      'London W4 2EF',
#      'United Kingdom']},
#    'phone': '+442070961609',
#    'display_phone': '+44 20 7096 1609',
#    'distance': 8339.382278059751},
#   {'id': 'o95C9QEq-bKJx1wTn7RBnQ',
#    'alias': 'bonjour-brioche-london-3',
#    'name': 'Bonjour Brioche',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UWqIpJ1pZ3SE1v9OFGgMMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bonjour-brioche-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4900052, 'longitude': -0.20631690489347},
#    'transactions': [],
#    'location': {'address1': '187 North End Road',
#     'address2': 'West Kensington',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W14 9NL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['187 North End Road',
#      'West Kensington',
#      'London W14 9NL',
#      'United Kingdom']},
#    'phone': '+442030927735',
#    'display_phone': '+44 20 3092 7735',
#    'distance': 5492.184466817846},
#   {'id': '3dAMMcrbElIf7v_roJ9-kA',
#    'alias': 'the-gallery-london',
#    'name': 'The Gallery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nzmMJYVtCtAn8QJzNBzkNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-gallery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5465294, 'longitude': -0.1902599},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '190 Broadhurst Gardens',
#     'address2': 'West Hampstead',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 3AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['190 Broadhurst Gardens',
#      'West Hampstead',
#      'London NW6 3AY',
#      'United Kingdom']},
#    'phone': '+442076259184',
#    'display_phone': '+44 20 7625 9184',
#    'distance': 5305.487316039617},
#   {'id': 'MF6Xwxep-fx_WfjpR-hmRQ',
#    'alias': 'the-quince-tree-london',
#    'name': 'The Quince Tree',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RvTdclXJQCaKu3xrr_QntQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-quince-tree-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.522522, 'longitude': -0.1849087},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Clifton Nurseries',
#     'address2': '5a Clifton Villas',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W9 2PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Clifton Nurseries',
#      '5a Clifton Villas',
#      'London W9 2PH',
#      'United Kingdom']},
#    'phone': '+442074321867',
#    'display_phone': '+44 20 7432 1867',
#    'distance': 3554.3491487276037},
#   {'id': 'zP3xfKUWhU-WZWuKKY5WIQ',
#    'alias': 'proud-marys-london',
#    'name': "Proud Mary's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JY-fiOvcilmHizB0F24CUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/proud-marys-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.506566, 'longitude': -0.2368532},
#    'transactions': [],
#    'location': {'address1': '1C Oaklands Grove',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W12 0JD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1C Oaklands Grove',
#      'London W12 0JD',
#      'United Kingdom']},
#    'phone': '+442088344884',
#    'display_phone': '+44 20 8834 4884',
#    'distance': 7013.0154239499325},
#   {'id': 'K_dDxWgagylIvuB2oQy1KQ',
#    'alias': 'the-black-penny-london',
#    'name': 'The Black Penny',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/e8S7oObCnKdDhx5w9AJTag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-black-penny-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51524, 'longitude': -0.12171},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '34 Great Queen Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['34 Great Queen Street',
#      'London WC2B 5AA',
#      'United Kingdom']},
#    'phone': '+442072422580',
#    'display_phone': '+44 20 7242 2580',
#    'distance': 1027.612848006736},
#   {'id': 'aGqt0g9_WU2UGituR7yn-w',
#    'alias': 'farm-girl-cafe-london',
#    'name': 'Farm Girl Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Qxj7RtZyROODLKeUzWbarw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/farm-girl-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 78,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5120686916922,
#     'longitude': -0.200769876546774},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '59A Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 3DB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['59A Portobello Road',
#      'London W11 3DB',
#      'United Kingdom']},
#    'phone': '+442072294678',
#    'display_phone': '+44 20 7229 4678',
#    'distance': 4486.039469290095},
#   {'id': 'bv5I4riA1pJvbNFefeHXWw',
#    'alias': 'esters-london-2',
#    'name': 'Esters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Y1mIi5vQ5SYh7sUZalxHsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/esters-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5600418, 'longitude': -0.0783293},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '55 Kynaston Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 0EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55 Kynaston Road',
#      'London N16 0EB',
#      'United Kingdom']},
#    'phone': '+442072540253',
#    'display_phone': '+44 20 7254 0253',
#    'distance': 6590.8338161308875},
#   {'id': 'ZDDEKWdrpjJHqX2d0InVMg',
#    'alias': 'urban-baristas-london-2',
#    'name': 'Urban Baristas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/f5NsZ4qiBlgvwVMbwh54Qg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/urban-baristas-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5108318662288,
#     'longitude': -0.187354646623135},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Queensway',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 4QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Queensway', 'London W2 4QJ', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3563.8944950081736},
#   {'id': 'M8wSfQWdxh7AHYKPbDFUPA',
#    'alias': 'the-good-egg-stoke-newington',
#    'name': 'The Good Egg',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GrsF5bOYEfthxNlWtQ6FDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-good-egg-stoke-newington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5620555, 'longitude': -0.0788542},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '93 Stoke Newington Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Stoke Newington',
#     'zip_code': 'N16 0AS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['93 Stoke Newington Church Street',
#      'Stoke Newington N16 0AS',
#      'United Kingdom']},
#    'phone': '+442076822120',
#    'display_phone': '+44 20 7682 2120',
#    'distance': 6752.857729185346},
#   {'id': 'Lr5_1a2rIyzA7W-6UPKS-A',
#    'alias': '26-grains-london',
#    'name': '26 Grains',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ci9nQvD05RdQ7k56unmJwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/26-grains-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5143765, 'longitude': -0.126556},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "1 Neal's Yard",
#     'address2': 'Covent Garden',
#     'address3': 'Seven Dials',
#     'city': 'London',
#     'zip_code': 'WC2H 9DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["1 Neal's Yard",
#      'Covent Garden',
#      'Seven Dials',
#      'London WC2H 9DP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 672.6546229251097},
#   {'id': 'n7vXgfapPy4uGLgqsUTDyg',
#    'alias': 'the-barge-house-london',
#    'name': 'The Barge House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qyRLwAeCfi9ydDeemsMTwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-barge-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5372997, 'longitude': -0.0808728},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '46 De Beauvoir Crescent',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 5RY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['46 De Beauvoir Crescent',
#      'London N1 5RY',
#      'United Kingdom']},
#    'phone': '+442072490765',
#    'display_phone': '+44 20 7249 0765',
#    'distance': 4682.087331063891},
#   {'id': 'ZXsDUkkD46vTf0n5q4aDxw',
#    'alias': 'fego-london',
#    'name': 'Fego',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hut0OPEQLpsoWgsPWeyh8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fego-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5325, 'longitude': -0.16923},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "64 St John's Wood High Street",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 7SH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["64 St John's Wood High Street",
#      'London NW8 7SH',
#      'United Kingdom']},
#    'phone': '+442074831826',
#    'display_phone': '+44 20 7483 1826',
#    'distance': 3178.889626383039},
#   {'id': '6ugop_2_fnetqRX6DbRNmA',
#    'alias': 'the-ivy-cafe-marylebone-london',
#    'name': 'The Ivy Cafe - Marylebone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/b-QqY82b4G-8fYxsCXn6Xg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ivy-cafe-marylebone-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5174429568542,
#     'longitude': -0.150753520220344},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '96 Marylebone Lane',
#     'address2': 'Marylebone',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['96 Marylebone Lane',
#      'Marylebone',
#      'London W1U',
#      'United Kingdom']},
#    'phone': '+442033010400',
#    'display_phone': '+44 20 3301 0400',
#    'distance': 1144.9781390024443},
#   {'id': 'pa2j9BlCHH8mRIk-TtD6UQ',
#    'alias': 'camden-bakery-london',
#    'name': 'Camden Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/V1BIQXnDxmTz0NyfTs6BiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camden-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5370833, 'longitude': -0.1407642},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '94 Camden High Street',
#     'address2': 'Camden Town',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 0LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['94 Camden High Street',
#      'Camden Town',
#      'London NW1 0LT',
#      'United Kingdom']},
#    'phone': '+442073874947',
#    'display_phone': '+44 20 7387 4947',
#    'distance': 2712.007403533704}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                Restaurant          Type Price Rating  \
# 0      The Breakfast Club  Coffee & Tea    ££      4
# 1     Ffiona's Restaurant       British    ££    4.5
# 2                    Milk  Coffee & Tea    ££    4.5
# 3     Duck & Waffle Local          Bars    ££    4.5
# 4  Where the Pancakes are      Pancakes    ££    4.5
#
#                        Address        Lat       Lng  \
# 0           33 D'Arblay Street  51.514733 -0.135406
# 1  51 Kensington Church Street  51.504058 -0.192783
# 2           18-20 Bedford Hill  51.444649 -0.151029
# 3                 52 Haymarket  51.509418 -0.132750
# 4                     Arch 35a  51.504367 -0.095555
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/the-breakfast-club-lo...  tYynO1nOy1GKxMV3jkxbmw
# 1  https://www.yelp.com/biz/ffionas-restaurant-lo...  70Q-Ll18zb4aglXXbUG7lw
# 2  https://www.yelp.com/biz/milk-london-2?adjust_...  mK87F1KiR7Ph-iOwI45Thw
# 3  https://www.yelp.com/biz/duck-and-waffle-local...  a4FkZ2b7Wn3-AP7q3ptHtQ
# 4  https://www.yelp.com/biz/where-the-pancakes-ar...  7_mJPWb6tREPW58f2xRpgA

# %%
#2nd set of 50 records 51-100 
lndr_params2 = {"term":"brunch","location":"London","limit":50,"offset":51}
lndr_response2 = requests.get(search_api_url, headers=headers, params=lndr_params2)
lndr2 = lndr_response2.json()
display(lndr2)
#print(lndr_response2.url)
#print(lndr_response2.status_code)
# Out:
# {'businesses': [{'id': 'LpIY4AvlAQZqJEZgcFoFPA',
#    'alias': 'the-alchemist-london-3',
#    'name': 'The Alchemist',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NXHurBRaL0gJuLtVnXZAKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-alchemist-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 85,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5150476, 'longitude': -0.0793474},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 Bevis Marks',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3A 7BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Bevis Marks', 'London EC3A 7BA', 'United Kingdom']},
#    'phone': '+442072838800',
#    'display_phone': '+44 20 7283 8800',
#    'distance': 3924.9724248663238},
#   {'id': 'za-KLljMB6yelgi2idCQPg',
#    'alias': 'beany-green-london',
#    'name': 'Beany Green',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UMPucP-qTkGpe2o5ix3woA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beany-green-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.519873314712,
#     'longitude': -0.180045690126235},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 6C',
#     'address2': '4 Sheldon Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 6EZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 6C',
#      '4 Sheldon Square',
#      'London W2 6EZ',
#      'United Kingdom']},
#    'phone': '+442072893344',
#    'display_phone': '+44 20 7289 3344',
#    'distance': 3149.5925485320417},
#   {'id': '91TQLypsN7trt-EyX8TgBQ',
#    'alias': 'daisy-green-london-2',
#    'name': 'Daisy Green',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ythY0ZkbjY3cYODreg4hLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daisy-green-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5148104, 'longitude': -0.1579352},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Seymour Street',
#     'address2': 'Marble Arch',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Seymour Street',
#      'Marble Arch',
#      'London W1H 7HX',
#      'United Kingdom']},
#    'phone': '+442077233301',
#    'display_phone': '+44 20 7723 3301',
#    'distance': 1536.7313570216975},
#   {'id': 'pda-judhXA46ukcyknEimg',
#    'alias': 'blighty-coffee-london',
#    'name': 'Blighty Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yU3WsVG82ePp0O03oTniXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blighty-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5639223, 'longitude': -0.102986},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '35-37 Blackstock Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N4 2JF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35-37 Blackstock Road',
#      'London N4 2JF',
#      'United Kingdom']},
#    'phone': '+442075027759',
#    'display_phone': '+44 20 7502 7759',
#    'distance': 6121.162135172724},
#   {'id': '3R0Klq1B1ESNTwqPfcsY-w',
#    'alias': 'the-pig-and-butcher-london',
#    'name': 'The Pig and Butcher',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zpEzs1qPf3ijMGJdGEcM8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pig-and-butcher-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 109,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.537442542029,
#     'longitude': -0.10682789450616},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '80 Liverpool Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 0QD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['80 Liverpool Road',
#      'London N1 0QD',
#      'United Kingdom']},
#    'phone': '+442072268304',
#    'display_phone': '+44 20 7226 8304',
#    'distance': 3398.14716948262},
#   {'id': '4xPHAFb8u_wzfjcWYHVKnw',
#    'alias': 'abuelo-london',
#    'name': 'Abuelo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/T2JtRvcsRVB6iEpIr9KQPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/abuelo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5112, 'longitude': -0.12261},
#    'transactions': [],
#    'location': {'address1': '26 Southampton Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2E 7RS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Southampton Street',
#      'London WC2E 7RS',
#      'United Kingdom']},
#    'phone': '+442078368476',
#    'display_phone': '+44 20 7836 8476',
#    'distance': 945.0913708751297},
#   {'id': 'B6ayHXLwfYBuIADficAeMg',
#    'alias': 'caravan-kings-cross-london',
#    'name': 'Caravan Kings Cross',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/N3qh0kXJvNLcjPEP9EEZGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caravan-kings-cross-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 170,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5357788239146,
#     'longitude': -0.125370576153865},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Granary Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Granary Square',
#      'London N1C 4AA',
#      'United Kingdom']},
#    'phone': '+442071017661',
#    'display_phone': '+44 20 7101 7661',
#    'distance': 2654.2035388419845},
#   {'id': 'lMxu8jhSIb_liUki8cy2Wg',
#    'alias': 'chamomile-london',
#    'name': 'Chamomile',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/L1XvSQmXkGbyxSqLdzqEWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chamomile-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5456005, 'longitude': -0.1623197},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "45 England's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 4YD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["45 England's Lane",
#      'London NW3 4YD',
#      'United Kingdom']},
#    'phone': '+442075864580',
#    'display_phone': '+44 20 7586 4580',
#    'distance': 4074.0720076605753},
#   {'id': 'fM99pmX2-ipWvG33tILdZQ',
#    'alias': 'franze-and-evans-cafe-shoreditch-london-2',
#    'name': 'Franze & Evans Cafe Shoreditch',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GXigHW3dfzZ42TB_8cvOvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/franze-and-evans-cafe-shoreditch-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5248675, 'longitude': -0.0726335},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '101 Redchurch St',
#     'address2': 'Shoreditch',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['101 Redchurch St',
#      'Shoreditch',
#      'London E2 7DL',
#      'United Kingdom']},
#    'phone': '+442070331910',
#    'display_phone': '+44 20 7033 1910',
#    'distance': 4581.098657661117},
#   {'id': 'PymJ3yWM5SaZC8QH89ZEBw',
#    'alias': 'dirty-bones-soho-london',
#    'name': 'Dirty Bones Soho',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/o3YH-aF3ffVn0EgZol8PrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dirty-bones-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.510811, 'longitude': -0.135314},
#    'transactions': [],
#    'location': {'address1': '14 Denman Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1D 7HJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Denman Street',
#      'London W1D 7HJ',
#      'United Kingdom']},
#    'phone': '+442030199064',
#    'display_phone': '+44 20 3019 9064',
#    'distance': 229.45587427086852},
#   {'id': 'Qk9CwHdpFgYo1Za77yfPtQ',
#    'alias': 'l-eto-caffe-london-6',
#    'name': "L'eto Caffe",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1FQ30FQP3kvrI5A8NXId9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-eto-caffe-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.48794, 'longitude': -0.167225},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "149 King's Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 5TX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["149 King's Road",
#      'London SW3 5TX',
#      'United Kingdom']},
#    'phone': '+442073517656',
#    'display_phone': '+44 20 7351 7656',
#    'distance': 3513.9797015942327},
#   {'id': 'qb0Wm0Ag3AE8ue_lHYLU_A',
#    'alias': 'the-chelsea-corner-london-2',
#    'name': 'The Chelsea Corner',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4kTBYlDwZv-K4s5T4YrQow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-chelsea-corner-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.48316, 'longitude': -0.18549},
#    'transactions': [],
#    'location': {'address1': '451 Fulham Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW10 9UZ',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ['451 Fulham Rd', 'London SW10 9UZ', 'United Kingdom']},
#    'phone': '+442030550088',
#    'display_phone': '+44 20 3055 0088',
#    'distance': 4757.374762175273},
#   {'id': 'pOnkBNgFreS7QzKZXXV3jA',
#    'alias': 'the-portman-london',
#    'name': 'The Portman',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zEMYATE1Ul51acGAA3QLnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-portman-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5152469791282,
#     'longitude': -0.161370500226781},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '51 Upper Berkeley Street',
#     'address2': 'Marylebone',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7QW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Upper Berkeley Street',
#      'Marylebone',
#      'London W1H 7QW',
#      'United Kingdom']},
#    'phone': '+442077238996',
#    'display_phone': '+44 20 7723 8996',
#    'distance': 1778.9968273370253},
#   {'id': 'rQKDeNCx8LkUR12YH9LpVg',
#    'alias': 'bäkehaus-london-2',
#    'name': 'Bäkehaus',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t8nwOKGUsvFhyuNdJFTrvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b%C3%A4kehaus-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4926600176647,
#     'longitude': -0.227837562561035},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '71 King Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W6 9HW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['71 King Street', 'London W6 9HW', 'United Kingdom']},
#    'phone': '+442034903231',
#    'display_phone': '+44 20 3490 3231',
#    'distance': 6743.794563736779},
#   {'id': '6xXfpMnpujSY_XuxeVvESQ',
#    'alias': 'pickle-and-rye-london',
#    'name': 'Pickle & Rye',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dWPINkZ7mmq7yezm_BF2GA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pickle-and-rye-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4683030502269,
#     'longitude': -0.266688129485996},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '31 Sheen Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW14 8AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['31 Sheen Lane', 'London SW14 8AB', 'United Kingdom']},
#    'phone': '+442088788982',
#    'display_phone': '+44 20 8878 8982',
#    'distance': 10317.197483082797},
#   {'id': 'OLXUZqx6doQtdeHfyEoyOw',
#    'alias': 'balans-soho-society-london',
#    'name': 'Balans Soho Society',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/x5-9gQeXo60P7Y5uC0nWUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/balans-soho-society-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 92,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4999833, 'longitude': -0.1956639},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '187 Kensington High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 6SH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['187 Kensington High Street',
#      'London W8 6SH',
#      'United Kingdom']},
#    'phone': '+442073760115',
#    'display_phone': '+44 20 7376 0115',
#    'distance': 4362.76195718541},
#   {'id': 'bEmaFY0A9JwpuxHKJXWx7Q',
#    'alias': 'the-ledbury-london',
#    'name': 'The Ledbury',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/j28_qI46pGjAGK3I6QLB5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ledbury-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 166,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.516819, 'longitude': -0.200107},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '127 Ledbury Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2AQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['127 Ledbury Road',
#      'London W11 2AQ',
#      'United Kingdom']},
#    'phone': '+442077929090',
#    'display_phone': '+44 20 7792 9090',
#    'distance': 4461.169501484266},
#   {'id': '_y_PWbW_PneBQ-Wh2yF-kQ',
#    'alias': 'vq-euston-london',
#    'name': 'VQ Euston',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0vKlpkC7CkVfo5ZtmhM3kA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vq-euston-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5259308, 'longitude': -0.1360934},
#    'transactions': [],
#    'location': {'address1': '152-156 North Gower street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 2LU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['152-156 North Gower street',
#      'London NW1 2LU',
#      'United Kingdom']},
#    'phone': '+442033011224',
#    'display_phone': '+44 20 3301 1224',
#    'distance': 1451.6580589688217},
#   {'id': 'wm6Hwzan5qYhTzCDmO3oDQ',
#    'alias': 'muriels-kitchen-london',
#    'name': "Muriel's Kitchen",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9un8EzHME-wGnd7zVoev2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/muriels-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 134,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.494117, 'longitude': -0.174468},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 1',
#     'address2': '3 Pelham Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 2ND',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 1',
#      '3 Pelham Street',
#      'London SW7 2ND',
#      'United Kingdom']},
#    'phone': '+442075893511',
#    'display_phone': '+44 20 7589 3511',
#    'distance': 3381.980840047671},
#   {'id': 'vCF8ut7OZcfA4hEmhngfSQ',
#    'alias': 'andina-london',
#    'name': 'Andina',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sgBZI-KCVdW5u838gGQW6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/andina-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 142,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5243208695971,
#     'longitude': -0.077134990126122},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Redchurch Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7DJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Redchurch Street',
#      'London E2 7DJ',
#      'United Kingdom']},
#    'phone': '+442079206499',
#    'display_phone': '+44 20 7920 6499',
#    'distance': 4265.6096504626785},
#   {'id': 'ltNrgT5KBga_-G09KPKUGA',
#    'alias': 'ginger-and-white-london',
#    'name': 'Ginger & White',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7QXlwpFegZ2gwdzLskNX8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginger-and-white-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5554778031252, 'longitude': -0.178065},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "4 Perrin's Court",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 1QS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["4 Perrin's Court",
#      'London NW3 1QS',
#      'United Kingdom']},
#    'phone': '+442074319098',
#    'display_phone': '+44 20 7431 9098',
#    'distance': 5564.726459557364},
#   {'id': 'hf_Jnbwab8jJ96XyPWwbMw',
#    'alias': 'the-ivy-chelsea-garden-london',
#    'name': 'The Ivy Chelsea Garden',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/P_jrMo87FJNimNla8tTcbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ivy-chelsea-garden-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 72,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4871107, 'longitude': -0.1693342},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '195-197 Kings Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 5EQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['195-197 Kings Road',
#      'London SW3 5EQ',
#      'United Kingdom']},
#    'phone': '+442033010300',
#    'display_phone': '+44 20 3301 0300',
#    'distance': 3677.026440039353},
#   {'id': 'VtLgCcLSEwFBiKPFV6_Mug',
#    'alias': 'balthazar-london',
#    'name': 'Balthazar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jjUdrn07VkCmksfsd6RuPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/balthazar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 176,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512493, 'longitude': -0.1212219},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '4-6 Russell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5HZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4-6 Russell Street',
#      'London WC2B 5HZ',
#      'United Kingdom']},
#    'phone': '+442033011155',
#    'display_phone': '+44 20 3301 1155',
#    'distance': 1017.1328446810884},
#   {'id': 'J38s3iokvd30sRGi5uB9lA',
#    'alias': 'l-eto-caffe-london',
#    'name': "L'Eto Caffe",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/glLwggFfv-PFoCGgzDIynA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-eto-caffe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 124,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514301, 'longitude': -0.134786},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '155 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8WG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['155 Wardour Street',
#      'London W1F 8WG',
#      'United Kingdom']},
#    'phone': '+442074944991',
#    'display_phone': '+44 20 7494 4991',
#    'distance': 181.95299001691527},
#   {'id': 'y8xX3BDj1bf7-wc4Q9Atvg',
#    'alias': 'the-monocle-cafe-london',
#    'name': 'The Monocle Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WVPzYgrKif_v7M9hkSshJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-monocle-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 69,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5188109085709,
#     'longitude': -0.154666668198166},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '18 Chiltern Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 7QA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Chiltern Street',
#      'London W1U 7QA',
#      'United Kingdom']},
#    'phone': '+442071352040',
#    'display_phone': '+44 20 7135 2040',
#    'distance': 1455.2587544542089},
#   {'id': 'dXEPhJmyV9BiA77wdAfEmg',
#    'alias': 'the-blackbird-london',
#    'name': 'The Blackbird',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/l-vFQ5dw4QEJDAkWvI5Neg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-blackbird-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 157,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.49178, 'longitude': -0.19211},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '209 Earls Ct Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 9AN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['209 Earls Ct Road',
#      'London SW5 9AN',
#      'United Kingdom']},
#    'phone': '+442078351855',
#    'display_phone': '+44 20 7835 1855',
#    'distance': 4538.901972736327},
#   {'id': 'h7I2R6d3x1yVYDj0PVhZaw',
#    'alias': 'the-good-life-eatery-london',
#    'name': 'The Good Life Eatery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bcMuQ58Jmb82smec88_YEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-good-life-eatery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4919548, 'longitude': -0.1653394},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '59 Sloane Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 3DH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['59 Sloane Avenue',
#      'London SW3 3DH',
#      'United Kingdom']},
#    'phone': '+442070529388',
#    'display_phone': '+44 20 7052 9388',
#    'distance': 3086.6446536335807},
#   {'id': 'LgKc7xGArsmxAw6xUQ2mYA',
#    'alias': 'gails-bakery-seymour-place-london-4',
#    'name': "GAIL's Bakery Seymour Place",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FWiORe3Zw8vEUmD0tANYvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-seymour-place-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.514595, 'longitude': -0.160964},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4-6 Seymour Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4-6 Seymour Place',
#      'London W1H 7NA',
#      'United Kingdom']},
#    'phone': '+442077243590',
#    'display_phone': '+44 20 7724 3590',
#    'distance': 1741.5797182376227},
#   {'id': 'HWkwznRK0BOcK3uvrxassA',
#    'alias': 'timmy-green-london',
#    'name': 'Timmy Green',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IwoyW9aGT7nx3tbkXTbVNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/timmy-green-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'australian', 'title': 'Australian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4980343768138,
#     'longitude': -0.143855731693976},
#    'transactions': [],
#    'location': {'address1': 'Sir Simon Milton Square',
#     'address2': '11 Bressenden Place',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1E 5DD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Sir Simon Milton Square',
#      '11 Bressenden Place',
#      'London SW1E 5DD',
#      'United Kingdom']},
#    'phone': '+442077233301',
#    'display_phone': '+44 20 7723 3301',
#    'distance': 1734.25763887698},
#   {'id': 'AMfqUC9oYC0xc55MaXbvAA',
#    'alias': 'nopi-london',
#    'name': 'NOPI',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Gu5NZ13wiFuOMxMrMJh5Dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nopi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 271,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511617, 'longitude': -0.1385226},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '21-22 Warwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21-22 Warwick Street',
#      'London W1B 5NE',
#      'United Kingdom']},
#    'phone': '+442074949584',
#    'display_phone': '+44 20 7494 9584',
#    'distance': 223.40454126752283},
#   {'id': 'MWz-nfYczrpnKaS9uGWQig',
#    'alias': 'tried-and-true-london',
#    'name': 'Tried & True',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OilO4ZKmOJ3cgECdzAKDOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tried-and-true-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.462736, 'longitude': -0.226235},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '279 Upper Richmond Road',
#     'address2': 'Putney',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW15 6SP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['279 Upper Richmond Road',
#      'Putney',
#      'London SW15 6SP',
#      'United Kingdom']},
#    'phone': '+442087890410',
#    'display_phone': '+44 20 8789 0410',
#    'distance': 8373.100427631674},
#   {'id': 'ya18ZfPH4beNzooV3r42rg',
#    'alias': 'drunch-mayfair',
#    'name': 'Drunch',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-4u3QM2yRbsbLdDoIAHZyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/drunch-mayfair?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.513893, 'longitude': -0.1465944},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '16 Blenheim Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Mayfair',
#     'zip_code': 'W1C 2AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Blenheim Street',
#      'Mayfair W1C 2AA',
#      'United Kingdom']},
#    'phone': '+442074952020',
#    'display_phone': '+44 20 7495 2020',
#    'distance': 751.5252126640925},
#   {'id': 'Snr_3I7dSsx3QMUH-xfcnA',
#    'alias': 'the-breakfast-club-london-12',
#    'name': 'The Breakfast Club',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zwu_aWTV0FdyvKouknk-Pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-breakfast-club-london-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 61,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5058390348173,
#     'longitude': -0.0181783917421963},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit CR30',
#     'address2': 'Level Zero',
#     'address3': '1 Crossrail Place',
#     'city': 'London',
#     'zip_code': 'E14 5AR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit CR30',
#      'Level Zero',
#      '1 Crossrail Place',
#      'London E14 5AR',
#      'United Kingdom']},
#    'phone': '+442078719986',
#    'display_phone': '+44 20 7871 9986',
#    'distance': 8187.970876270602},
#   {'id': 'riWepzZEIHj82UiDk_WVLQ',
#    'alias': 'montparnasse-cafe-london-2',
#    'name': 'Montparnasse Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/90P9GQECkOj3aZIrJfpO8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/montparnasse-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5005205, 'longitude': -0.1885342},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '22 Thackeray Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 5ET',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Thackeray Street',
#      'London W8 5ET',
#      'United Kingdom']},
#    'phone': '+442073762212',
#    'display_phone': '+44 20 7376 2212',
#    'distance': 3888.086719460034},
#   {'id': 'XeAaUJWcS9RZsE80a1UxjA',
#    'alias': 'mestizo-london',
#    'name': 'Mestizo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m15vQhfhss5ycfcdVatg7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mestizo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 153,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.52752, 'longitude': -0.1387649},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '103 Hampstead Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 3EL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['103 Hampstead Road',
#      'London NW1 3EL',
#      'United Kingdom']},
#    'phone': '+442073874064',
#    'display_phone': '+44 20 7387 4064',
#    'distance': 1656.1089625620355},
#   {'id': 'ghg0SAC1cuKkk46ji-M9Kw',
#    'alias': 'the-black-lab-coffee-house-london',
#    'name': "'The Black Lab' Coffee House",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/e_hPHnpzTNA0ezHfxHGFiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-black-lab-coffee-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4610903556983,
#     'longitude': -0.138673064112254},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18 Clapham Common South Side',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW4 7AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Clapham Common South Side',
#      'London SW4 7AB',
#      'United Kingdom']},
#    'phone': '+442077388441',
#    'display_phone': '+44 20 7738 8441',
#    'distance': 5756.8687201302955},
#   {'id': 'SQqalQPyvPPeMVRZpM4Euw',
#    'alias': 'chez-antoinette-london',
#    'name': 'Chez Antoinette',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zlMs2nYV9CufeYXN9wJHBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chez-antoinette-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512071, 'longitude': -0.122977},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '30 The Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 8RF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 The Market', 'London WC2E 8RF', 'United Kingdom']},
#    'phone': '+442072409072',
#    'display_phone': '+44 20 7240 9072',
#    'distance': 904.8765108749993},
#   {'id': 'Gyxs4y3aofIAjAWGaPNmrQ',
#    'alias': 'milk-bar-london',
#    'name': 'Milk Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5onhkWkXKrnHmKGOHDxEtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/milk-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 82,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514162886575,
#     'longitude': -0.13126851745979},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3 Bateman Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 4AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Bateman Street',
#      'London W1D 4AG',
#      'United Kingdom']},
#    'phone': '+442072874796',
#    'display_phone': '+44 20 7287 4796',
#    'distance': 356.36235664390273},
#   {'id': 'xl05GXufB5wPlGQL75wiJA',
#    'alias': 'lantana-cafe-london-2',
#    'name': 'Lantana Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kRvWu-oAIbU1rGj-T_fcOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lantana-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 124,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5189676, 'longitude': -0.1359559},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '13 Charlotte Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 1SN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Charlotte Place',
#      'London W1T 1SN',
#      'United Kingdom']},
#    'phone': '+442076373347',
#    'display_phone': '+44 20 7637 3347',
#    'distance': 681.8552979623188},
#   {'id': '1TBmcRK1gywVVRHYYr7R0Q',
#    'alias': 'el-and-n-london-2',
#    'name': 'EL&N',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eV5QcWA8peOvw15Ns6A5Aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-and-n-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4998051, 'longitude': -0.1620998},
#    'transactions': [],
#    'location': {'address1': '42 Hans Cres',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1X 0LZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 Hans Cres', 'London SW1X 0LZ', 'United Kingdom']},
#    'phone': '+442070520130',
#    'display_phone': '+44 20 7052 0130',
#    'distance': 2322.608342949373},
#   {'id': 'DAE3fIusVTUGt9PDwPlelg',
#    'alias': 'exmouth-coffee-company-london',
#    'name': 'Exmouth Coffee Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0yrsGXNRm5roKhOo_8VUiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/exmouth-coffee-company-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 81,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.515994, 'longitude': -0.070496},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '83 Whitechapel High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 7QX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Whitechapel High Street',
#      'London E1 7QX',
#      'United Kingdom']},
#    'phone': '+442073771010',
#    'display_phone': '+44 20 7377 1010',
#    'distance': 4553.663911477298},
#   {'id': '9UncLmEiGmHmQkerlXBpcQ',
#    'alias': 'blue-plate-london',
#    'name': 'Blue Plate',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kf3vDNuufWuRNuPUX9vpwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-plate-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4927, 'longitude': -0.252125},
#    'transactions': [],
#    'location': {'address1': '85 Chiswick High Road',
#     'address2': 'Chiswick',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W4 2EF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['85 Chiswick High Road',
#      'Chiswick',
#      'London W4 2EF',
#      'United Kingdom']},
#    'phone': '+442070961609',
#    'display_phone': '+44 20 7096 1609',
#    'distance': 8344.695074936832},
#   {'id': 'XL7cx1Sb3dFPak2gkPOzKw',
#    'alias': 'soho-grind-london-2',
#    'name': 'Soho Grind',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Vl36Az1so-DbXZ25ImcqjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soho-grind-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512154, 'longitude': -0.138379},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '19 Beak Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Beak Street',
#      'Soho',
#      'London W1F 9RP',
#      'United Kingdom']},
#    'phone': '+442072877073',
#    'display_phone': '+44 20 7287 7073',
#    'distance': 181.13696795054122},
#   {'id': 'ypsFAFBmx2cUq1DZ5esZRA',
#    'alias': 'silverberry-deli-and-kitchen-london',
#    'name': 'Silverberry Deli & Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uAEsyPmbhweFlgcQqlkEMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/silverberry-deli-and-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5540823038372,
#     'longitude': -0.165075874311875},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 Pond Street',
#     'address2': 'Hampstead',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 2PS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Pond Street',
#      'Hampstead',
#      'London NW3 2PS',
#      'United Kingdom']},
#    'phone': '+442077945461',
#    'display_phone': '+44 20 7794 5461',
#    'distance': 5009.2325017215735},
#   {'id': 'IPWn4OJe7om08i2-VIh3MA',
#    'alias': 'trade-commercial-street-london',
#    'name': 'TRADE - Commercial Street',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Bn4mV-VdKlcXjHhZG_3BGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trade-commercial-street-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5174201859475,
#     'longitude': -0.073803998529911},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '47 Commercial Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6BD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Commercial Street',
#      'London E1 6BD',
#      'United Kingdom']},
#    'phone': '+442034901880',
#    'display_phone': '+44 20 3490 1880',
#    'distance': 4330.853277885616},
#   {'id': 'SeDzq2X1sP3g7BteNJkxxg',
#    'alias': 'urban-pantry-london',
#    'name': 'Urban Pantry',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6Gl6fC0Xd5nhOQZh41dTlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/urban-pantry-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4916802381695,
#     'longitude': -0.255905280028632},
#    'transactions': [],
#    'location': {'address1': '15 Devonshire Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W4 2HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Devonshire Road',
#      'London W4 2HA',
#      'United Kingdom']},
#    'phone': '+442089941444',
#    'display_phone': '+44 20 8994 1444',
#    'distance': 8629.35128354945},
#   {'id': 'S3h8uhI3wK2Fn4e9gw9bfA',
#    'alias': 'shoreditch-grind-london',
#    'name': 'Shoreditch Grind',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wcWCxMuAey7jvjK6_m5TIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shoreditch-grind-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 116,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5258391235513,
#     'longitude': -0.0879659656067133},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '213 Old Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 9NR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['213 Old Street',
#      'London EC1V 9NR',
#      'United Kingdom']},
#    'phone': '+442074907490',
#    'display_phone': '+44 20 7490 7490',
#    'distance': 3621.631922482148},
#   {'id': 'g0EAOJ_KXkJDcE19lc3LRg',
#    'alias': 'the-tin-shed-london-2',
#    'name': 'The Tin Shed',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OjrVG3cY6uIawrKk8ylkbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-tin-shed-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5185254426503,
#     'longitude': -0.204378206745901},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '33 All Saints Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 1HE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['33 All Saints Road',
#      'London W11 1HE',
#      'United Kingdom']},
#    'phone': '+447785300906',
#    'display_phone': '+44 7785 300906',
#    'distance': 4776.681718853927},
#   {'id': 'UjMwZ6-PgXs3BXN7LLOSAw',
#    'alias': 'gails-bakery-pimlico-london',
#    'name': "GAIL's Bakery - Pimlico",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zobkG9NdbclJN7D9O6w5yw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-pimlico-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4917627846861,
#     'longitude': -0.139058523838447},
#    'transactions': [],
#    'location': {'address1': '26 Churton Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1V 2LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Churton Street',
#      'London SW1V 2LP',
#      'United Kingdom']},
#    'phone': '+442079320734',
#    'display_phone': '+44 20 7932 0734',
#    'distance': 2352.9999537192894},
#   {'id': 'zJNI06Y2zZQFh9OBSFCdgQ',
#    'alias': 'sketch-london-2',
#    'name': 'Sketch',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pAEJmqSJX1lh_pLuvjbFww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sketch-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 831,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5127614699071,
#     'longitude': -0.14159163911048},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '9 Conduit Street',
#     'address2': 'Mayfair',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 2XG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Conduit Street',
#      'Mayfair',
#      'London W1S 2XG',
#      'United Kingdom']},
#    'phone': '+442076594500',
#    'display_phone': '+44 20 7659 4500',
#    'distance': 390.09161644125044}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#             Restaurant           Type Price Rating                Address  \
# 0        The Alchemist  Cocktail Bars    ££      4          6 Bevis Marks
# 1          Beany Green   Coffee & Tea    ££    4.5                Unit 6C
# 2          Daisy Green          Cafes    ££      4      20 Seymour Street
# 3       Blighty Coffee   Coffee & Tea    ££    4.5  35-37 Blackstock Road
# 4  The Pig and Butcher        British    ££    4.5      80 Liverpool Road
#
#          Lat       Lng                                                url  \
# 0  51.515048 -0.079347  https://www.yelp.com/biz/the-alchemist-london-...
# 1  51.519873 -0.180046  https://www.yelp.com/biz/beany-green-london?ad...
# 2  51.514810 -0.157935  https://www.yelp.com/biz/daisy-green-london-2?...
# 3  51.563922 -0.102986  https://www.yelp.com/biz/blighty-coffee-london...
# 4  51.537443 -0.106828  https://www.yelp.com/biz/the-pig-and-butcher-l...
#
#                        ID
# 0  LpIY4AvlAQZqJEZgcFoFPA
# 1  za-KLljMB6yelgi2idCQPg
# 2  91TQLypsN7trt-EyX8TgBQ
# 3  pda-judhXA46ukcyknEimg
# 4  3R0Klq1B1ESNTwqPfcsY-w

# %%
#3rd set of 50 records 101-150
lndr_params3 = {"term":"brunch","location":"London","limit":50,"offset":101}
lndr_response3 = requests.get(search_api_url, headers=headers, params=lndr_params3)
lndr3 = lndr_response3.json()
display(lndr3)
#print(lndr_response3.url)
#print(lndr_response3.status_code)
# Out:
# {'businesses': [{'id': 'k41zE5iiFxKva8yjGbleEg',
#    'alias': 'darcie-and-may-green-london',
#    'name': 'Darcie and May Green',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2U1j7IP_45nVhFk6CX-bJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/darcie-and-may-green-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'australian', 'title': 'Australian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.518888, 'longitude': -0.17827},
#    'transactions': [],
#    'location': {'address1': 'Sheldon Square',
#     'address2': 'Paddington Central',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 6DS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Sheldon Square',
#      'Paddington Central',
#      'London W2 6DS',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3004.3355755049047},
#   {'id': '1fH92NtBqTqo8TW-00NQvw',
#    'alias': 'granger-and-co-london-4',
#    'name': 'Granger & Co',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/pglet8Wf-SZp4IGhgSRfFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/granger-and-co-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'australian', 'title': 'Australian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5325845472022,
#     'longitude': -0.125704638943534},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Stanley Building',
#     'address2': '7 Pancras Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Stanley Building',
#      '7 Pancras Square',
#      'London N1C 4AG',
#      'United Kingdom']},
#    'phone': '+442030582567',
#    'display_phone': '+44 20 3058 2567',
#    'distance': 2307.679423681929},
#   {'id': 'k-qIxL_IHDlXxlgDpNkN7Q',
#    'alias': 'ez-and-moss-london',
#    'name': 'EZ & Moss',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ItZEzaXsRlQSbo3-dg0ztg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ez-and-moss-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5501848, 'longitude': -0.1092206},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '183 Holloway Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N7 8LX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['183 Holloway Road',
#      'London N7 8LX',
#      'United Kingdom']},
#    'phone': '+442076199523',
#    'display_phone': '+44 20 7619 9523',
#    'distance': 4546.191125147666},
#   {'id': 'f8s8dT9Rm4359xUVHtiqRA',
#    'alias': 'black-cat-london',
#    'name': 'Black Cat',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RZHJY2Tw6cAtF7ZrT7vQTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-cat-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5513968, 'longitude': -0.055691},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '76 Clarence Road',
#     'address2': 'Hackney',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E5 8HB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['76 Clarence Road',
#      'Hackney',
#      'London E5 8HB',
#      'United Kingdom']},
#    'phone': '+442089857091',
#    'display_phone': '+44 20 8985 7091',
#    'distance': 7015.023023552639},
#   {'id': 'WHrXrCaBE3Uf3d-B5Wyh0g',
#    'alias': 'heddon-street-kitchen-london',
#    'name': 'Heddon Street Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T5ZDviNFEe04BXyeJvfpig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heddon-street-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 91,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5107288, 'longitude': -0.1393024},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '3-9 Heddon St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 4BE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3-9 Heddon St', 'London W1B 4BE', 'United Kingdom']},
#    'phone': '+442075921212',
#    'display_phone': '+44 20 7592 1212',
#    'distance': 329.41022584098886},
#   {'id': 'Y51qImK_hOk-AaT5c5yC2w',
#    'alias': 'plum-and-spilt-milk-london',
#    'name': 'Plum & Spilt Milk',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GdWFQ0A3uGHuTwSTmCDzzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/plum-and-spilt-milk-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.532379, 'longitude': -0.1254596},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "King's Cross Street",
#     'address2': 'Pancras Station',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4TB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["King's Cross Street",
#      'Pancras Station',
#      'London N1C 4TB',
#      'United Kingdom']},
#    'phone': '+442033880818',
#    'display_phone': '+44 20 3388 0818',
#    'distance': 2291.2577599195056},
#   {'id': 'WsLdK-MPXbYV1-e8tJOQ5Q',
#    'alias': 'ella-canta-london',
#    'name': 'Ella Canta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6czGsUhwiwOcOITXnXU6jA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ella-canta-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.503868, 'longitude': -0.150415},
#    'transactions': [],
#    'location': {'address1': 'One Hamilton Place',
#     'address2': 'Park Lane',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 7QY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['One Hamilton Place',
#      'Park Lane',
#      'London W1J 7QY',
#      'United Kingdom']},
#    'phone': '+442073188715',
#    'display_phone': '+44 20 7318 8715',
#    'distance': 1412.6807249454405},
#   {'id': 'KTmzCl1J5u8WcQaxWI8lcg',
#    'alias': 'flotsam-and-jetsam-london',
#    'name': 'Flotsam & Jetsam',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5kLju_wMpyIpBwZ483dBTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flotsam-and-jetsam-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.444001, 'longitude': -0.167601},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 Bellevue Parade',
#     'address2': 'Wandsworth Common',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW17 7EF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Bellevue Parade',
#      'Wandsworth Common',
#      'London SW17 7EF',
#      'United Kingdom']},
#    'phone': '+442086727639',
#    'display_phone': '+44 20 8672 7639',
#    'distance': 7913.392077862781},
#   {'id': 'zZQdJRJ1hqFuNWmCuOictg',
#    'alias': 'dalloway-terrace-london',
#    'name': 'Dalloway Terrace',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9ANzc_AlRXqIjZVrsq51JQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dalloway-terrace-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5172302719223,
#     'longitude': -0.12909671319926},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '16-22 Great Russell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3NN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16-22 Great Russell Street',
#      'London WC1B 3NN',
#      'United Kingdom']},
#    'phone': '+442073471221',
#    'display_phone': '+44 20 7347 1221',
#    'distance': 681.2327177861348},
#   {'id': '7Q6JpFSFv997rhv7w1izNA',
#    'alias': 'the-colonel-fawcett-london',
#    'name': 'The Colonel Fawcett',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5sI0DzmCXQB1JkmxqaLbtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-colonel-fawcett-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5418041646628,
#     'longitude': -0.136007736926076},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Randolph Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 0SS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Randolph Street',
#      'London NW1 0SS',
#      'United Kingdom']},
#    'phone': '+442072679829',
#    'display_phone': '+44 20 7267 9829',
#    'distance': 3221.1646170751255},
#   {'id': 'fp5po-wno5RLU4Rz0q0h-w',
#    'alias': 'my-place-soho-london',
#    'name': 'My Place Soho',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gnMfIijyZhFXOyvJPP88ZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-place-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5138405, 'longitude': -0.1346902},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '21 Berwick Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1F 0PZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21 Berwick Street',
#      'London W1F 0PZ',
#      'United Kingdom']},
#    'phone': '+442034172829',
#    'display_phone': '+44 20 3417 2829',
#    'distance': 141.97901027026617},
#   {'id': 'xViBKVW8zxlrxLfDam2eqg',
#    'alias': 'byward-kitchen-and-bar-london',
#    'name': 'Byward Kitchen & Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RTf7hDLtp2wy5sMWe7spQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/byward-kitchen-and-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5092887647333,
#     'longitude': -0.0789638981223106},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Byward Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3R 5BJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Byward Street', 'London EC3R 5BJ', 'United Kingdom']},
#    'phone': '+442074813533',
#    'display_phone': '+44 20 7481 3533',
#    'distance': 3963.7136520192603},
#   {'id': '3ViNQObKHR6l02hkvBFClw',
#    'alias': 'mimos-cafe-london',
#    'name': 'Mimos Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/k6WfcS61Er3U5TxjAdvcNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mimos-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 85,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5150959, 'longitude': -0.174005},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '19 London Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 London Street',
#      'London W2 1HL',
#      'United Kingdom']},
#    'phone': '+442077067175',
#    'display_phone': '+44 20 7706 7175',
#    'distance': 2647.9526940777378},
#   {'id': 'Gdqq0f4R8pBXIcHvAI3SuQ',
#    'alias': 'the-abingdon-london',
#    'name': 'The Abingdon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zwPShdHLzpDv-834u5I5zQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-abingdon-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.497629045444,
#     'longitude': -0.19607751802576},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '54 Abingdon Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 6AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54 Abingdon Road',
#      'London W8 6AP',
#      'United Kingdom']},
#    'phone': '+442079373339',
#    'display_phone': '+44 20 7937 3339',
#    'distance': 4491.5939634918195},
#   {'id': '5rXUEcOAORmQtFLY_J5Wsg',
#    'alias': 'magus-and-the-fool-art-café-london',
#    'name': 'Magus & the Fool - Art Café',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JsWg3XnQdMXfO_ZRujIPpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/magus-and-the-fool-art-caf%C3%A9-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5312506, 'longitude': -0.0390237},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '357 Roman Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E3 5QR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['357 Roman Road', 'London E3 5QR', 'United Kingdom']},
#    'phone': '+442089806344',
#    'display_phone': '+44 20 8980 6344',
#    'distance': 7009.832564327023},
#   {'id': 'xqpUr61KFa1Xx721-E6l_A',
#    'alias': 'kipferl-london-6',
#    'name': 'Kipferl',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CUoYGTlW1CYS-nJ5vAUGPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kipferl-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'austrian', 'title': 'Austrian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.535247538411,
#     'longitude': -0.10339315152949},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Camden Passage',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Camden Passage',
#      'London N1 8ED',
#      'United Kingdom']},
#    'phone': '+442077041555',
#    'display_phone': '+44 20 7704 1555',
#    'distance': 3359.4222431551457},
#   {'id': '-pFugy4jvUurL5Xy_TKfDw',
#    'alias': 'tiosk-london',
#    'name': 'Tiosk',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rqZolTMZK5aH3o5CTb4_iQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tiosk-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'homedecor', 'title': 'Home Decor'},
#     {'alias': 'coffeeteasupplies', 'title': 'Coffee & Tea Supplies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5365326, 'longitude': -0.0620065},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '33 Broadway Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 4PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['33 Broadway Market',
#      'London E8 4PH',
#      'United Kingdom']},
#    'phone': '+442072544211',
#    'display_phone': '+44 20 7254 4211',
#    'distance': 5755.925697186309},
#   {'id': 'mWIaThf7jXEFk-IzPfxRrQ',
#    'alias': 'garden-breakfast-cafe-london',
#    'name': 'Garden Breakfast Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QlmAbh_5E8hFLOM7DjwC9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/garden-breakfast-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.545783996582,
#     'longitude': -0.179408997297287},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3 Goldhurst Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 3HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Goldhurst Terrace',
#      'London NW6 3HX',
#      'United Kingdom']},
#    'phone': '+442073282295',
#    'display_phone': '+44 20 7328 2295',
#    'distance': 4739.603460462908},
#   {'id': 'RoSm8-2L0MaJ1rJ8xj5haQ',
#    'alias': 'sunday-london',
#    'name': 'Sunday',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iOkMyEWqAufFWqDoHf09GA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sunday-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 52,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5426444, 'longitude': -0.1134125},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '169 Hemingford Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 1DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['169 Hemingford Road',
#      'London N1 1DA',
#      'United Kingdom']},
#    'phone': '+442076073868',
#    'display_phone': '+44 20 7607 3868',
#    'distance': 3663.138559414116},
#   {'id': 'UESyhTRQY4CYtGNoYBc52Q',
#    'alias': 'terrys-cafe-london-3',
#    'name': "Terry's Cafe",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YBkG1Yc2dbbemDZCQeKbOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/terrys-cafe-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.50069, 'longitude': -0.0984105},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '158 Great Suffolk Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1PE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['158 Great Suffolk Street',
#      'London SE1 1PE',
#      'United Kingdom']},
#    'phone': '+442074079358',
#    'display_phone': '+44 20 7407 9358',
#    'distance': 2928.512166850289},
#   {'id': 'X2CHzdmpEGukjTjo63txCA',
#    'alias': 'bread-and-butter-london',
#    'name': 'Bread & Butter',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ddSFzsZtbXUwqPPglwoRQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bread-and-butter-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5396907022005,
#     'longitude': -0.07725894294631},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '5 Enfield Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 5EN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Enfield Road', 'London N1 5EN', 'United Kingdom']},
#    'phone': '+442079230047',
#    'display_phone': '+44 20 7923 0047',
#    'distance': 5040.460079585767},
#   {'id': 'PudMFuWJGxQW6XHtMhZlyQ',
#    'alias': 'cereal-killer-cafe-london-2',
#    'name': 'Cereal Killer Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kiQounOvJOlW5Tt23LlBvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cereal-killer-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.542371733327,
#     'longitude': -0.148038655927107},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '48 Chalk Farm Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['48 Chalk Farm Road',
#      'London NW1 8AJ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3388.972421626742},
#   {'id': 'kAgxFPCeNiZeiKc9POkiOg',
#    'alias': 'ottolenghi-london-2',
#    'name': 'Ottolenghi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/h7J52IR5gmXdlef7pJxfSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ottolenghi-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4995017, 'longitude': -0.1566887},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '13 Motcomb Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 8LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Motcomb Street',
#      'London SW1X 8LB',
#      'United Kingdom']},
#    'phone': '+442078232707',
#    'display_phone': '+44 20 7823 2707',
#    'distance': 2068.4293878068443},
#   {'id': 'nyLKZw4j3Qi066s-Z7mG9w',
#    'alias': '34-mayfair-london',
#    'name': '34 Mayfair',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uF_S0xkBDG4186xIghHyAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/34-mayfair-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5105548, 'longitude': -0.1525879},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '34 Grovesnor Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 2HD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['34 Grovesnor Square',
#      'London W1K 2HD',
#      'United Kingdom']},
#    'phone': '+442033503434',
#    'display_phone': '+44 20 3350 3434',
#    'distance': 1169.6895596498505},
#   {'id': 'cRPLtawbzjJUpzELkYvKoA',
#    'alias': 'les-filles-london',
#    'name': 'Les Filles',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cimg4esLzkPU7Ha3ymSS7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/les-filles-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5589763, 'longitude': -0.1786497},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '95-97 Heath Street',
#     'address2': 'Hampstead',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 6SS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['95-97 Heath Street',
#      'Hampstead',
#      'London NW3 6SS',
#      'United Kingdom']},
#    'phone': '+442077948600',
#    'display_phone': '+44 20 7794 8600',
#    'distance': 5928.7767908252135},
#   {'id': 'FwQZrdVz0SrbkUtFzw--HA',
#    'alias': 'the-ivy-city-garden-london',
#    'name': 'The Ivy City Garden',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/I1lqjfdvb-XEdYyJR8-OXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ivy-city-garden-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5168006186057,
#     'longitude': -0.0821242480483012},
#    'transactions': [],
#    'location': {'address1': '69 Old Broad Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EC2M 1QS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['69 Old Broad Street',
#      'London EC2M 1QS',
#      'United Kingdom']},
#    'phone': '+442031467744',
#    'display_phone': '+44 20 3146 7744',
#    'distance': 3751.0319683068},
#   {'id': '_Nq4qS4X_GP-0hEaPLflWw',
#    'alias': 'black-and-blue-london-5',
#    'name': 'Black & Blue',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BZc3fqxTQ2RJH5nY7AgQng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-and-blue-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'tradamerican',
#      'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.508423, 'longitude': -0.19538},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '215-217 Kensington Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 7LX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['215-217 Kensington Church Street',
#      'London W8 7LX',
#      'United Kingdom']},
#    'phone': '+442077270004',
#    'display_phone': '+44 20 7727 0004',
#    'distance': 4137.623224528128},
#   {'id': 'GxgR6fSRJe6maz0ScUfgFA',
#    'alias': 'lizzys-on-the-green-london-2',
#    'name': "Lizzy's On The Green",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/flgnL0r_XyskWEyhem76HA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lizzys-on-the-green-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5510260200928,
#     'longitude': -0.0858629749540199},
#    'transactions': [],
#    'location': {'address1': 'Newington Green',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N16 9PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Newington Green',
#      'London N16 9PX',
#      'United Kingdom']},
#    'phone': '+447779046233',
#    'display_phone': '+44 7779 046233',
#    'distance': 5480.859066523686},
#   {'id': 'QyYFRNphu0fICXNfZjD_AA',
#    'alias': 'the-hummingbird-bakery-london-2',
#    'name': 'The Hummingbird Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iNrM97UAuo0a-o3XgX-WqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hummingbird-bakery-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 131,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5140019, 'longitude': -0.2038738},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '133 Portobello Road',
#     'address2': 'Notting Hill',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['133 Portobello Road',
#      'Notting Hill',
#      'London W11 2DY',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4701.254789485355},
#   {'id': 'ivojzgnsc6AH6Tp_Kl0jZA',
#    'alias': 'louie-louie-london',
#    'name': 'Louie Louie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WzHuGxu7Uw3lLrsCbpvEfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/louie-louie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4860094504896,
#     'longitude': -0.0941036269068718},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '347 Walworth Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE17 2AL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['347 Walworth Road',
#      'London SE17 2AL',
#      'United Kingdom']},
#    'phone': '+442074503223',
#    'display_phone': '+44 20 7450 3223',
#    'distance': 4158.21748917824},
#   {'id': 'CvYiWzRJ_xBXBcXm6QLYyw',
#    'alias': 'snaps-and-rye-london',
#    'name': 'Snaps & Rye',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fzGYVIp4ObasQP8Ypo87oA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/snaps-and-rye-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'scandinavian', 'title': 'Scandinavian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5215609, 'longitude': -0.2089577},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '93 Golborne Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W10 5NL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['93 Golborne Road',
#      'London W10 5NL',
#      'United Kingdom']},
#    'phone': '+442089643004',
#    'display_phone': '+44 20 8964 3004',
#    'distance': 5143.644092189328},
#   {'id': 'VSrnYJMirUi6ZQna_qtwMw',
#    'alias': 'the-breakfast-club-london-9',
#    'name': 'The Breakfast Club',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RFa6fZXhbxhU3k5Y7KfcCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-breakfast-club-london-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 85,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.504551, 'longitude': -0.091138},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Southwark Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1RQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Southwark Street',
#      'London SE1 1RQ',
#      'United Kingdom']},
#    'phone': '+442070789634',
#    'display_phone': '+44 20 7078 9634',
#    'distance': 3220.038994170034},
#   {'id': '4piTf0lU0v2hm3golRXpDg',
#    'alias': 'the-locals-cafe-london',
#    'name': 'The Locals Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ordWJ5xSneOazk-OcRt0Zw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-locals-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4878443014327,
#     'longitude': -0.149484480397052},
#    'transactions': [],
#    'location': {'address1': '8 Gatliff Road',
#     'address2': '',
#     'address3': 'Grosvenor Waterside',
#     'city': 'London',
#     'zip_code': 'SW1W 8DE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Gatliff Road',
#      'Grosvenor Waterside',
#      'London SW1W 8DE',
#      'United Kingdom']},
#    'phone': '+442077303305',
#    'display_phone': '+44 20 7730 3305',
#    'distance': 2932.4383065079855},
#   {'id': '5sEiM_Xw5jXbMhloNqSgYQ',
#    'alias': 'grumbles-london',
#    'name': 'Grumbles',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/D6YLzHz7ilRcYpLsaG92Gg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grumbles-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4911292, 'longitude': -0.1388531},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '35 Churton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 2LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35 Churton Street',
#      'London SW1V 2LT',
#      'United Kingdom']},
#    'phone': '+442078340149',
#    'display_phone': '+44 20 7834 0149',
#    'distance': 2417.0516096383467},
#   {'id': 'MY5vPpDxJFPzj-wR4_pUsg',
#    'alias': 'crumpets-london',
#    'name': 'Crumpets',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2GXRSS7bftG4X6Z-0Q4VxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crumpets-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4991936, 'longitude': -0.1382647},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '82 Buckingham Gate',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1E 6PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['82 Buckingham Gate',
#      'London SW1E 6PD',
#      'United Kingdom']},
#    'phone': '+442072331479',
#    'display_phone': '+44 20 7233 1479',
#    'distance': 1525.3047584226708},
#   {'id': 'yQy0O4maalqIZX3txcxCXg',
#    'alias': 'grounded-coffee-london-2',
#    'name': 'Grounded Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/InuECK964Pm_rRX4-V7Rfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grounded-coffee-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5164248587188,
#     'longitude': -0.0693253754631087},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9 Whitechapel Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 1DU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Whitechapel Road',
#      'London E1 1DU',
#      'United Kingdom']},
#    'phone': '+442073771703',
#    'display_phone': '+44 20 7377 1703',
#    'distance': 4627.946047616965},
#   {'id': '335bAiGx1OzbnmgV-6dE4g',
#    'alias': 'le-peche-mignon-london',
#    'name': 'Le Peche Mignon',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/W68FEGHxYOJkqtZnIhgpZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-peche-mignon-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5500471393663,
#     'longitude': -0.107909992126366},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '6 Ronalds Road',
#     'address2': 'Highbury',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N5 1XH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Ronalds Road',
#      'Highbury',
#      'London N5 1XH',
#      'United Kingdom']},
#    'phone': '+442076071826',
#    'display_phone': '+44 20 7607 1826',
#    'distance': 4569.955270762261},
#   {'id': 'jIuiv7VJkAAM5bRCuKNozg',
#    'alias': 'baker-and-spice-london',
#    'name': 'Baker & Spice',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qhKK__pVmzQmzhkDlOTx8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baker-and-spice-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4936, 'longitude': -0.150758},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '54-56 Elizabeth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 9PB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54-56 Elizabeth Street',
#      'London SW1W 9PB',
#      'United Kingdom']},
#    'phone': '+442077305524',
#    'display_phone': '+44 20 7730 5524',
#    'distance': 2371.6101398591395},
#   {'id': 'BNAddFkvoUGR1l6AL32p8w',
#    'alias': 'over-under-coffee-london-3',
#    'name': 'Over Under Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nlSAXEZwQAl5HFBHSWTpvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/over-under-coffee-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4923794, 'longitude': -0.1930041},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "181A Earl's Court Road",
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW5 9RD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["181A Earl's Court Road",
#      'London SW5 9RD',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4556.96556200919},
#   {'id': 'L5bYiNsHg-hKJraeFXBSYA',
#    'alias': 'baker-and-spice-london-2',
#    'name': 'Baker & Spice',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nnqOqLOXyhgiq2lOvBhPqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baker-and-spice-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4939913, 'longitude': -0.164682},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '47 Denyer Street',
#     'address2': '',
#     'address3': 'Chelsea',
#     'city': 'London',
#     'zip_code': 'SW3 2LX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Denyer Street',
#      'Chelsea',
#      'London SW3 2LX',
#      'United Kingdom']},
#    'phone': '+442075894734',
#    'display_phone': '+44 20 7589 4734',
#    'distance': 2883.911010904249},
#   {'id': '5qHpg2z69QMbQGh0KIor6Q',
#    'alias': 'aix-london-2',
#    'name': 'Aix',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zLtgofgI88N-G8xSsXP5gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aix-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5816532516394,
#     'longitude': -0.121383368968964},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '54 Topsfield Parade',
#     'address2': 'Tottenham Lane',
#     'address3': 'Crouch End',
#     'city': 'London',
#     'zip_code': 'N8 8PT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54 Topsfield Parade',
#      'Tottenham Lane',
#      'Crouch End',
#      'London N8 8PT',
#      'United Kingdom']},
#    'phone': '+442083406346',
#    'display_phone': '+44 20 8340 6346',
#    'distance': 7718.2351129770295},
#   {'id': 'wnUHPVeubkSIEAF0nqNxBg',
#    'alias': 'i-will-kill-again-london',
#    'name': 'I Will Kill Again',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/p9E9cW9_P8hEKLI6DTDpWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/i-will-kill-again-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5472640626661,
#     'longitude': -0.0468713453717017},
#    'transactions': [],
#    'location': {'address1': 'Arch 216 Dark Arts Coffee',
#     'address2': '217A Ponsford Street',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E9 6JU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Arch 216 Dark Arts Coffee',
#      '217A Ponsford Street',
#      'London E9 6JU',
#      'United Kingdom']},
#    'phone': '+442037740131',
#    'display_phone': '+44 20 3774 0131',
#    'distance': 7254.708071911209},
#   {'id': 'apqNvjbaB20wozywrLNPiQ',
#    'alias': 'fischers-london',
#    'name': "Fischer's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/A68yx91bh-81NvBKkMXVCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fischers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'austrian', 'title': 'Austrian'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5216155579831,
#     'longitude': -0.151699820819173},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '50 Marylebone High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 5HN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50 Marylebone High Street',
#      'London W1U 5HN',
#      'United Kingdom']},
#    'phone': '+442074665501',
#    'display_phone': '+44 20 7466 5501',
#    'distance': 1462.850471845834},
#   {'id': 'MaNE6xr9_bqpIWCLm5VhkA',
#    'alias': 'goddards-at-greenwich-london',
#    'name': 'Goddards at Greenwich',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hGrxtzUFxlDAbt8TyhlZ5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/goddards-at-greenwich-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 84,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4812088, 'longitude': -0.0083317},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '22 King William Walk',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE10 9HU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 King William Walk',
#      'London SE10 9HU',
#      'United Kingdom']},
#    'phone': '+442083059612',
#    'display_phone': '+44 20 8305 9612',
#    'distance': 9498.252492833206},
#   {'id': '8P4qwhVKdxoV1bW-_I3s-A',
#    'alias': 'the-dairy-london-2',
#    'name': 'The Dairy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9gI0ORT8RPrbeM1xa1KNhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dairy-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4618724, 'longitude': -0.1395915},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '15 The Pavement',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW4 0HY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 The Pavement',
#      'London SW4 0HY',
#      'United Kingdom']},
#    'phone': '+442076224165',
#    'display_phone': '+44 20 7622 4165',
#    'distance': 5672.422770158091},
#   {'id': 'mvds37L7mCurGn3rGPM8ag',
#    'alias': 'kaffeine-london',
#    'name': 'Kaffeine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QWk5UJ1ELO0n7VrE3aLUWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaffeine-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 173,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51848, 'longitude': -0.14037},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '66 Great Titchfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 7QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Great Titchfield Street',
#      'London W1W 7QJ',
#      'United Kingdom']},
#    'phone': '+442075806755',
#    'display_phone': '+44 20 7580 6755',
#    'distance': 697.5687539772275},
#   {'id': 'XurEgYTPm4PARiqrqcotkw',
#    'alias': 'my-old-dutch-london-2',
#    'name': 'My Old Dutch',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wZc-OBa5JvHvdiZqZuYIlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-old-dutch-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5025085986798,
#     'longitude': -0.190974987903188},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '16 Kensington Church Street',
#     'address2': 'Kensington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Kensington Church Street',
#      'Kensington',
#      'London W8 4EP',
#      'United Kingdom']},
#    'phone': '+442079376090',
#    'display_phone': '+44 20 7937 6090',
#    'distance': 3977.184097835303},
#   {'id': 'mnLM9jFngaaL8EdH0qHnWw',
#    'alias': 'orsini-london',
#    'name': 'Orsini',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FpcnzKFZx3Zaw4u5rTpoFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/orsini-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 66,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.496176, 'longitude': -0.169932},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8A Thurloe Place',
#     'address2': 'South Kensington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 2RX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8A Thurloe Place',
#      'South Kensington',
#      'London SW7 2RX',
#      'United Kingdom']},
#    'phone': '+442075815553',
#    'display_phone': '+44 20 7581 5553',
#    'distance': 2996.4733331679718},
#   {'id': '9kYUIi9guLcWh3iFOJ_vWg',
#    'alias': 'knockbox-coffee-london',
#    'name': 'Knockbox Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IrDnvf2dRXzDwYW9xz__yA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/knockbox-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5211323, 'longitude': -0.1180363},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '29 Lambs Conduit Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 3NG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['29 Lambs Conduit Street',
#      'London WC1N 3NG',
#      'United Kingdom']},
#    'phone': '+442034897325',
#    'display_phone': '+44 20 3489 7325',
#    'distance': 1545.4931234557102},
#   {'id': 'G0T2DsJeB14fryOJnwd-Ew',
#    'alias': 'zer-cafe-and-juice-bar-london',
#    'name': 'Zer Cafe and Juice Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ly1GmNW1ikxKXXLRPNNnpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zer-cafe-and-juice-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5707343, 'longitude': -0.0907975},
#    'transactions': [],
#    'location': {'address1': 'Unit A Residence Tower',
#     'address2': 'Goodchild Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N4 2LY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit A Residence Tower',
#      'Goodchild Road',
#      'London N4 2LY',
#      'United Kingdom']},
#    'phone': '+442088095270',
#    'display_phone': '+44 20 8809 5270',
#    'distance': 7155.52817341348}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#               Restaurant             Type Price Rating            Address  \
# 0   Darcie and May Green       Australian                  Sheldon Square
# 1           Granger & Co       Australian    ££    3.5   Stanley Building
# 2              EZ & Moss            Cafes     £    4.5  183 Holloway Road
# 3              Black Cat            Vegan     £    4.5   76 Clarence Road
# 4  Heddon Street Kitchen  Modern European   £££      4      3-9 Heddon St
#
#          Lat       Lng                                                url  \
# 0  51.518888 -0.178270
# 1  51.532585 -0.125705  https://www.yelp.com/biz/granger-and-co-london...
# 2  51.550185 -0.109221  https://www.yelp.com/biz/ez-and-moss-london?ad...
# 3  51.551397 -0.055691  https://www.yelp.com/biz/black-cat-london?adju...
# 4  51.510729 -0.139302  https://www.yelp.com/biz/heddon-street-kitchen...
#
#                        ID
# 0
# 1  1fH92NtBqTqo8TW-00NQvw
# 2  k-qIxL_IHDlXxlgDpNkN7Q
# 3  f8s8dT9Rm4359xUVHtiqRA
# 4  WHrXrCaBE3Uf3d-B5Wyh0g

# %%
#4th set of 50 records 151-200
lndr_params4 = {"term":"brunch","location":"London","limit":50,"offset":151}
lndr_response4 = requests.get(search_api_url, headers=headers, params=lndr_params4)
lndr4 = lndr_response4.json()
display(lndr4)
#print(lndr_response4.url)
#print(lndr_response4.status_code)
# Out:
# {'businesses': [{'id': 'IhpwcD7I4NzdloijSkM5KQ',
#    'alias': 'the-breakfast-club-london',
#    'name': 'The Breakfast Club',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/r0Uraee3mQyhPKBkCqJEDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-breakfast-club-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 137,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5351048605, 'longitude': -0.103710715876},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '31 Camden Passage',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['31 Camden Passage',
#      'London N1 8EA',
#      'United Kingdom']},
#    'phone': '+442072265454',
#    'display_phone': '+44 20 7226 5454',
#    'distance': 3332.9271329293742},
#   {'id': 'EKM6VmUANUVy5wqXT7gEXQ',
#    'alias': 'bon-gusto-london',
#    'name': 'Bon Gusto',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9vVpPXCeNEEK2r6ri3rfBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bon-gusto-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 88,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4992042, 'longitude': -0.1378462},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '75-77 Buckingham Gate',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1E 6PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['75-77 Buckingham Gate',
#      'London SW1E 6PD',
#      'United Kingdom']},
#    'phone': '+442072227185',
#    'display_phone': '+44 20 7222 7185',
#    'distance': 1521.3684126347684},
#   {'id': 'E_3NekwxctQ3BzN7tLKk2A',
#    'alias': 'casa-tua-london-2',
#    'name': 'Casa Tua',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m7FJ2XmVjJQ-Sx0umK6pmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-tua-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5276449011142,
#     'longitude': -0.123588235886524},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '106 Cromer Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 8BZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['106 Cromer Street',
#      'London WC1H 8BZ',
#      'United Kingdom']},
#    'phone': '+442078331483',
#    'display_phone': '+44 20 7833 1483',
#    'distance': 1855.7864052166005},
#   {'id': 'NCj4ufnnu9iJuJVy_15nxw',
#    'alias': 'niche-london-5',
#    'name': 'Niche',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QiV8fpqNY26Tbd4y-IE8lw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/niche-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5299391920297,
#     'longitude': -0.105478788954883},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '197-199 Rosebery Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 4TJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['197-199 Rosebery Avenue',
#      'London EC1R 4TJ',
#      'United Kingdom']},
#    'phone': '+442078375048',
#    'display_phone': '+44 20 7837 5048',
#    'distance': 2839.605686346751},
#   {'id': 'U4FjnVDflNIqFS_rsS8EuQ',
#    'alias': 'scarlett-green-soho',
#    'name': 'Scarlett Green',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XKj_oVNORjiB_brh9syhZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scarlett-green-soho?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'australian', 'title': 'Australian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5152820364531,
#     'longitude': -0.135854987703738},
#    'transactions': [],
#    'location': {'address1': '4 Noel Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Soho',
#     'zip_code': 'W1F 8GB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Noel Street', 'Soho W1F 8GB', 'United Kingdom']},
#    'phone': '+442036532010',
#    'display_phone': '+44 20 3653 2010',
#    'distance': 272.1292350090104},
#   {'id': '66uNLSVxF-S9CeGE_olN6Q',
#    'alias': 'daylesford-farmhouse-and-cafe-london',
#    'name': 'Daylesford Farmhouse & Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ikJ2IJK4TRV7X6cpp6-_DQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daylesford-farmhouse-and-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'organic_stores', 'title': 'Organic Stores'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5185188799413,
#     'longitude': -0.151910542410043},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6-8 Blandford Street',
#     'address2': 'Marylebone',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 4AU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6-8 Blandford Street',
#      'Marylebone',
#      'London W1U 4AU',
#      'United Kingdom']},
#    'phone': '+442036966500',
#    'display_phone': '+44 20 3696 6500',
#    'distance': 1272.0918945942365},
#   {'id': 'dQe5yW6U9_DXdDwjDEdXSg',
#    'alias': 'beam-london',
#    'name': 'Beam',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9QXpKDDyEsVwDoiuHjddwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beam-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.581051, 'longitude': -0.122344},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '17 Tottenham Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N8 8PT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17 Tottenham Lane',
#      'London N8 8PT',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 7596.386744165015},
#   {'id': 'WT5EjZGp4gn9BNnzTlC2Ww',
#    'alias': 'ottolenghi-islington',
#    'name': 'Ottolenghi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y0eBCsgaeswDaLcF0m-iLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ottolenghi-islington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 212,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5397542479056,
#     'longitude': -0.102216303348541},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '287 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 2TZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['287 Upper Street',
#      'London N1 2TZ',
#      'United Kingdom']},
#    'phone': '+442072881454',
#    'display_phone': '+44 20 7288 1454',
#    'distance': 3795.717274260169},
#   {'id': 'AM2d672O6FjDpL82iVWTlg',
#    'alias': 'momo-london',
#    'name': 'Momo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1wtcMgYTFwevbAopsEL6sQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/momo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 116,
#    'categories': [{'alias': 'moroccan', 'title': 'Moroccan'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5111056, 'longitude': -0.1403264},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '25-27 Heddon Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 4BH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['25-27 Heddon Street',
#      'London W1B 4BH',
#      'United Kingdom']},
#    'phone': '+442074344040',
#    'display_phone': '+44 20 7434 4040',
#    'distance': 358.44161076116546},
#   {'id': 'R1UKQHTz65dQKkdLjzVEBg',
#    'alias': 'dishoom-london-3',
#    'name': 'Dishoom',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Gy-vIVmqUc_fHHnFcdje6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dishoom-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 385,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5363182978271,
#     'longitude': -0.125145272091882},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5 Stable Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Stable Street',
#      'London N1C 4AB',
#      'United Kingdom']},
#    'phone': '+442074209321',
#    'display_phone': '+44 20 7420 9321',
#    'distance': 2716.1616871636725},
#   {'id': 'zE_UPVsKaoNX0dhuN5jqlg',
#    'alias': 'burnt-toast-cafe-london',
#    'name': 'Burnt Toast Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y2YlDdxQ1sOzuXLOkfho9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burnt-toast-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4626312255859,
#     'longitude': -0.111818999052048},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 88 Brixton Village Market',
#     'address2': 'Coldharbour Lane',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 8PS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 88 Brixton Village Market',
#      'Coldharbour Lane',
#      'London SW9 8PS',
#      'United Kingdom']},
#    'phone': '+447717642812',
#    'display_phone': '+44 7717 642812',
#    'distance': 5827.243159344378},
#   {'id': '1Z-uv6_JuONT0QYcf48PlQ',
#    'alias': 'natural-kitchen-london-2',
#    'name': 'Natural Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oTYQK-3cPQ90QcvAjWiF1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/natural-kitchen-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5109071, 'longitude': -0.0782531},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '7 Pepys Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3N 4AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Pepys Street',
#      'London EC3N 4AF',
#      'United Kingdom']},
#    'phone': '+442077024038',
#    'display_phone': '+44 20 7702 4038',
#    'distance': 4013.293436140861},
#   {'id': 'uNPd8mSNqunIKqBPJc8rKQ',
#    'alias': 'container-cafe-london-2',
#    'name': 'Container Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xWQoDBGHzpPAft1aeuJbqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/container-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.53537, 'longitude': -0.013197},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'View Tube The Greenway',
#     'address2': 'Marshgate Lane',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E15 2PJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['View Tube The Greenway',
#      'Marshgate Lane',
#      'London E15 2PJ',
#      'United Kingdom']},
#    'phone': '+447530274160',
#    'display_phone': '+44 7530 274160',
#    'distance': 8861.371642965705},
#   {'id': 'NVK4capCup4iZB5ZErR2xg',
#    'alias': 'long-white-cloud-london',
#    'name': 'Long White Cloud',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CwuMldUDRnRAzPpC_SZIGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/long-white-cloud-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5305939, 'longitude': -0.0735575},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '151 Hackney Road',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E2 8JL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['151 Hackney Road',
#      'London E2 8JL',
#      'United Kingdom']},
#    'phone': '+442070334642',
#    'display_phone': '+44 20 7033 4642',
#    'distance': 4747.338072539963},
#   {'id': 'N-U604mIyucKujlDgzTCig',
#    'alias': 'franks-cafe-london',
#    'name': "Frank's Cafe",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HTjUX8mrhlf4JUSNb3vkcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/franks-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.506313, 'longitude': -0.101584},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '132 Southwark Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0SW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['132 Southwark Street',
#      'London SE1 0SW',
#      'United Kingdom']},
#    'phone': '+442079283850',
#    'display_phone': '+44 20 7928 3850',
#    'distance': 2465.749710783424},
#   {'id': 'PRenwS7JtbCWYMlg38no0Q',
#    'alias': 'moka-london-2',
#    'name': 'Moka',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YEwqnPYcVeRilTRqLBHm3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moka-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5778679489636,
#     'longitude': -0.104370558860751},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5 Wightman Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N4 1RQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Wightman Road', 'London N4 1RQ', 'United Kingdom']},
#    'phone': '+442083408664',
#    'display_phone': '+44 20 8340 8664',
#    'distance': 7553.927488477886},
#   {'id': 'Q_rR0j8TS-2gJIMHAYh_jw',
#    'alias': 'bills-london-25',
#    'name': "Bill's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kYsBw6VXyuPObpVUm9F9RQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bills-london-25?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.521638, 'longitude': -0.157553},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '119-121 Baker Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 6RY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['119-121 Baker Street',
#      'London W1U 6RY',
#      'United Kingdom']},
#    'phone': '+442074867701',
#    'display_phone': '+44 20 7486 7701',
#    'distance': 1785.0969149750756},
#   {'id': '4rpkLLSPzVRqdHlM9_-9Cw',
#    'alias': 'four-corners-cafe-london-2',
#    'name': 'Four Corners Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rq5jjv5YtDdYt9HJQ8OyEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/four-corners-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5003689, 'longitude': -0.1135442},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '12 Lower Marsh',
#     'address2': 'Waterloo',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Lower Marsh',
#      'Waterloo',
#      'London SE1 7RJ',
#      'United Kingdom']},
#    'phone': '+442086179591',
#    'display_phone': '+44 20 8617 9591',
#    'distance': 2080.282557645936},
#   {'id': '1HYMkWwwcFT7E3rNtJO8gg',
#    'alias': 'blend-london',
#    'name': 'Blend',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vFrValDUnwvSW0CVqRajug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blend-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5841063, 'longitude': -0.1001619},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '587 Green Lanes',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N8 0RG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['587 Green Lanes', 'London N8 0RG', 'United Kingdom']},
#    'phone': '+442083412939',
#    'display_phone': '+44 20 8341 2939',
#    'distance': 8302.436942422453},
#   {'id': '_TpRjqSg_MSm8Kh2-DcKng',
#    'alias': 'near-and-far-camden-london-2',
#    'name': 'Near & Far Camden',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UK2Y43ox_qZp0Je_dr34GA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/near-and-far-camden-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'djs', 'title': 'DJs'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5430231, 'longitude': -0.148893},
#    'transactions': [],
#    'location': {'address1': '48 Chalk Farm Road',
#     'address2': None,
#     'address3': 'Camden',
#     'city': 'London',
#     'zip_code': 'NW1 8AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['48 Chalk Farm Road',
#      'Camden',
#      'London NW1 8AJ',
#      'United Kingdom']},
#    'phone': '+442072672700',
#    'display_phone': '+44 20 7267 2700',
#    'distance': 3473.907343579959},
#   {'id': 'vBEQW6eX3DFYlDgrzr8VCQ',
#    'alias': 'el-vergel-london',
#    'name': 'El Vergel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HMpP7JOOK9BZy5cSKuOAwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-vergel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.500707, 'longitude': -0.099151},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '132 Webber Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['132 Webber Street',
#      'London SE1 0QL',
#      'United Kingdom']},
#    'phone': '+442074012308',
#    'display_phone': '+44 20 7401 2308',
#    'distance': 2881.1132049899998},
#   {'id': 'F_LaVYcB8-Fha_iS72kUxg',
#    'alias': 'to-a-tea-london',
#    'name': 'To A Tea',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZsxVJ_XfBEdzJ5E_BzdY4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/to-a-tea-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515112, 'longitude': -0.104413},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 Farringdon Street',
#     'address2': 'Five Feet Place',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4A 4AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Farringdon Street',
#      'Five Feet Place',
#      'London EC4A 4AB',
#      'United Kingdom']},
#    'phone': '+442072483498',
#    'display_phone': '+44 20 7248 3498',
#    'distance': 2197.3651067721244},
#   {'id': 'q7z_7wz_kCUZOyW58QRTrg',
#    'alias': 'annies-london-3',
#    'name': "Annie's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/m5zm8Cd15BXZRKUhgVkqGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/annies-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4847798, 'longitude': -0.2778904},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '162 Thames Road',
#     'address2': 'Chiswick',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W4 3QS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['162 Thames Road',
#      'Chiswick',
#      'London W4 3QS',
#      'United Kingdom']},
#    'phone': '+442089949080',
#    'display_phone': '+44 20 8994 9080',
#    'distance': 10310.713477347996},
#   {'id': '7sKAUqEagSjsNjHVyMHq-Q',
#    'alias': 'the-london-particular-london-3',
#    'name': 'The London Particular',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XXSiR_OXzNtqxrWyohd4Bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-london-particular-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4759049028314,
#     'longitude': -0.033576499062248},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '399 New Cross Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE14 6LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['399 New Cross Road',
#      'London SE14 6LA',
#      'United Kingdom']},
#    'phone': '+442086926149',
#    'display_phone': '+44 20 8692 6149',
#    'distance': 8191.30650062815},
#   {'id': 'xFjP08phJ-IeeP4EGgt67g',
#    'alias': 'flour-to-the-people-london',
#    'name': 'Flour To The People',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CeeNyGT0oMKW1fz7iLmYTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flour-to-the-people-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.471184, 'longitude': -0.168629},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '573 Battersea Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW11 3BJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['573 Battersea Park Road',
#      'London SW11 3BJ',
#      'United Kingdom']},
#    'phone': '+442072285672',
#    'display_phone': '+44 20 7228 5672',
#    'distance': 5162.824084700251},
#   {'id': '--tghoL5fzAThS66gt7yKg',
#    'alias': 'hallys-london',
#    'name': "Hally's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sI-1ZcNzZHWjdupkC5BRwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hallys-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4727116, 'longitude': -0.2011121},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "60 New King's Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 4LS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["60 New King's Road",
#      'London SW6 4LS',
#      'United Kingdom']},
#    'phone': '+442033027408',
#    'display_phone': '+44 20 3302 7408',
#    'distance': 6344.561731388316},
#   {'id': '6hw3LjFoZ3aLcnfxuDSJAg',
#    'alias': 'harrods-tea-room-london',
#    'name': "Harrods' Tea Room",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tRQR6OEsZ-aLJWt0yYL5MQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harrods-tea-room-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 98,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4992262754487,
#     'longitude': -0.16359383122593},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '87-135 Brompton Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7XL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['87-135 Brompton Rd',
#      'London SW1X 7XL',
#      'United Kingdom']},
#    'phone': '+442077301234',
#    'display_phone': '+44 20 7730 1234',
#    'distance': 2439.0669041104725},
#   {'id': '8fOwzD6Ksk7fFinUzozVvg',
#    'alias': 'artisan-london-3',
#    'name': 'Artisan',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NVdCCZcVwtt7CUihU2T53w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/artisan-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.513316, 'longitude': -0.306361},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '32 New Broadway Ealing',
#     'address2': 'Ealing London',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W5 2XA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['32 New Broadway Ealing',
#      'Ealing London',
#      'London W5 2XA',
#      'United Kingdom']},
#    'phone': '+442079983450',
#    'display_phone': '+44 20 7998 3450',
#    'distance': 11815.45890187267},
#   {'id': 'p9TrMj3CyIQd-nywbZklZw',
#    'alias': 'red-rooster-shoreditch-london',
#    'name': 'Red Rooster Shoreditch',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wtexbI6JcJDq9otJexz4JA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/red-rooster-shoreditch-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'scandinavian', 'title': 'Scandinavian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.524165, 'longitude': -0.08029},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '45 Curtain Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EC2A',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Curtain Road', 'London EC2A', 'United Kingdom']},
#    'phone': '+442031464545',
#    'display_phone': '+44 20 3146 4545',
#    'distance': 4031.9623647685676},
#   {'id': 'SsA4xyF60DUXdOaCspIe1w',
#    'alias': 'bistrò-by-shot-london',
#    'name': 'Bistrò by Shot',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WHINRY_CDwPiuEDOG8CXGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistr%C3%B2-by-shot-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4761126249543,
#     'longitude': -0.201063260185887},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '28 Parsons Green Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 4HS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28 Parsons Green Lane',
#      'London SW6 4HS',
#      'United Kingdom']},
#    'phone': '+442073717533',
#    'display_phone': '+44 20 7371 7533',
#    'distance': 6081.936487270801},
#   {'id': 'shVl3BQRfZLmTu1u852azA',
#    'alias': 'drury-london-2',
#    'name': 'Drury',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RQPdd4rfz5hxAQzr4lx2pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/drury-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51609, 'longitude': -0.12404},
#    'transactions': [],
#    'location': {'address1': '188-189 Drury Ln',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2B 5QD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['188-189 Drury Ln',
#      'London WC2B 5QD',
#      'United Kingdom']},
#    'phone': '+442074047664',
#    'display_phone': '+44 20 7404 7664',
#    'distance': 900.3253465614542},
#   {'id': 'vAiqG2dTHlG0kKOCMYEBsg',
#    'alias': 'cafe-van-gogh-camberwell',
#    'name': 'Cafe Van Gogh',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gcV6XzjrlV6R2pcp7beldQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-van-gogh-camberwell?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4777129, 'longitude': -0.112505},
#    'transactions': [],
#    'location': {'address1': '88-96 Brixton Road',
#     'address2': '',
#     'address3': None,
#     'city': 'Camberwell',
#     'zip_code': 'SW9 6BH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['88-96 Brixton Road',
#      'Camberwell SW9 6BH',
#      'United Kingdom']},
#    'phone': '+447546966554',
#    'display_phone': '+44 7546 966554',
#    'distance': 4229.435925758568},
#   {'id': 'x7Z52Z5asB91V2l2sBLWWg',
#    'alias': 'megans-kings-road-restaurant-chelsea-london',
#    'name': "Megan's Kings Road Restaurant, Chelsea",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PTI0UgpFFo77c9Q1REJ2Pw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/megans-kings-road-restaurant-chelsea-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.47881, 'longitude': -0.18801},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '571 Kings Road',
#     'address2': 'Chelsea',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 2EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['571 Kings Road',
#      'Chelsea',
#      'London SW6 2EB',
#      'United Kingdom']},
#    'phone': '+442034680220',
#    'display_phone': '+44 20 3468 0220',
#    'distance': 5224.329399253999},
#   {'id': '6tXkeZlisxTtdUsjDaTqaw',
#    'alias': 'chiltern-firehouse-london',
#    'name': 'Chiltern Firehouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/58u7lwgpHV2IpKEsxFTxBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chiltern-firehouse-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 146,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5187121017659,
#     'longitude': -0.154846859653053},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '1 Chiltern Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 7PA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Chiltern Street',
#      'London W1U 7PA',
#      'United Kingdom']},
#    'phone': '+442070737676',
#    'display_phone': '+44 20 7073 7676',
#    'distance': 1461.4187311898597},
#   {'id': 'b8b32YEI1wQXT7oZeagNCA',
#    'alias': 'the-orange-public-house-and-hotel-victoria-london',
#    'name': 'The Orange Public House & Hotel Victoria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lMQZ4mnDpv6C_we6ktJJeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-orange-public-house-and-hotel-victoria-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 65,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4905695688428,
#     'longitude': -0.152324890517983},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '37 Pimlico Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 8NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['37 Pimlico Road',
#      'London SW1W 8NE',
#      'United Kingdom']},
#    'phone': '+442078819844',
#    'display_phone': '+44 20 7881 9844',
#    'distance': 2722.7990698208014},
#   {'id': 'nVMVXywZjvDBkPPR_uqhUA',
#    'alias': 'the-garrison-london',
#    'name': 'The Garrison',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/z8a68zJmqJXkFn7wjll03g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-garrison-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 104,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.500646, 'longitude': -0.08159},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '99 Bermondsey Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 3XB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['99 Bermondsey Street',
#      'London SE1 3XB',
#      'United Kingdom']},
#    'phone': '+442070899355',
#    'display_phone': '+44 20 7089 9355',
#    'distance': 3989.2901215567895},
#   {'id': '35B3UJMEaI1sQj4vaKK0RQ',
#    'alias': 'percy-and-founders-london',
#    'name': 'Percy & Founders',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/H_OABaaEO2qHgs_Zx-yG_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/percy-and-founders-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5187944346049,
#     'longitude': -0.137987967211919},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1 Pearson Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 3BF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Pearson Square',
#      'London W1T 3BF',
#      'United Kingdom']},
#    'phone': '+442037610200',
#    'display_phone': '+44 20 3761 0200',
#    'distance': 677.3569343118869},
#   {'id': 'ZmtcyezJv8HMIT-OuoU-4g',
#    'alias': 'malibu-kitchen-london-3',
#    'name': 'Malibu Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wANC5crrA-4eIphrEEDrMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/malibu-kitchen-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.513583, 'longitude': -0.089917},
#    'transactions': [],
#    'location': {'address1': '27 Poultry',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2R 8AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['27 Poultry', 'London EC2R 8AJ', 'United Kingdom']},
#    'phone': '+442038282000',
#    'display_phone': '+44 20 3828 2000',
#    'distance': 3186.9847532414465},
#   {'id': 'gJAFSUO7U70GQJFo3ynRUw',
#    'alias': 'rapsa-london-2',
#    'name': 'Rapsa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fouHC09o9SvAWW-yBPmfbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rapsa-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5310648658011,
#     'longitude': -0.0800106030410461},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '100-104 Hoxton Street',
#     'address2': 'Shoreditch',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 6SG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['100-104 Hoxton Street',
#      'Shoreditch',
#      'London N1 6SG',
#      'United Kingdom']},
#    'phone': '+442077291444',
#    'display_phone': '+44 20 7729 1444',
#    'distance': 4369.319716613212},
#   {'id': 'yihpb_5t5mGJvfbOEED_VQ',
#    'alias': 'the-corner-cafe-london',
#    'name': 'The Corner Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fs3yEyFv4HCGFSyC_bTvWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-corner-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4957548701444,
#     'longitude': -0.115179994392665},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '182 Hercules Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7LD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['182 Hercules Road',
#      'London SE1 7LD',
#      'United Kingdom']},
#    'phone': '+442032671062',
#    'display_phone': '+44 20 3267 1062',
#    'distance': 2382.232987907946},
#   {'id': 'xhsk3wZvMdXETGxSPrXBTg',
#    'alias': 'morty-and-bobs-london-2',
#    'name': "Morty & Bob's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-1KVZIh-5AqtJiGB5MH2Vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/morty-and-bobs-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5377767414878,
#     'longitude': -0.0579549922315281},
#    'transactions': [],
#    'location': {'address1': 'Unit 207 Netil House',
#     'address2': 'Westgate Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 4RU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 207 Netil House',
#      'Westgate Street',
#      'London E8 4RU',
#      'United Kingdom']},
#    'phone': '+44447944635556',
#    'display_phone': '+44 447944635556',
#    'distance': 6067.196802783649},
#   {'id': '9jY-_VLBs4XVXgiGApNe7Q',
#    'alias': 'colbert-chelsea',
#    'name': 'Colbert',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4_6HwpF9QVUOxw4ktCqWUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/colbert-chelsea?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4928527, 'longitude': -0.1566231},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '50-52 Sloane Square',
#     'address2': '',
#     'address3': '',
#     'city': 'Chelsea',
#     'zip_code': 'SW1W 8AX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50-52 Sloane Square',
#      'Chelsea SW1W 8AX',
#      'United Kingdom']},
#    'phone': '+442077302804',
#    'display_phone': '+44 20 7730 2804',
#    'distance': 2642.645637785076},
#   {'id': 'U_XeFWW1Lttdq22txTABMw',
#    'alias': 'gails-bakery-neo-bankside-london',
#    'name': "GAIL's Bakery Neo Bankside",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CEfkaYA0zFoAlNcdiNt_aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-neo-bankside-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5066352772979,
#     'longitude': -0.100412668500134},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit C Neo Bankside',
#     'address2': '70 Holland Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9NX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit C Neo Bankside',
#      '70 Holland Road',
#      'London SE1 9NX',
#      'United Kingdom']},
#    'phone': '+442079280621',
#    'display_phone': '+44 20 7928 0621',
#    'distance': 2554.576460738087},
#   {'id': 'ySM7A1ljKIthN6ckAYdN5g',
#    'alias': 'the-marquis-of-westminster-london',
#    'name': 'The Marquis of Westminster',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JQVTZHnF8TRJ-UJQVWfpzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-marquis-of-westminster-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 121,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.491901, 'longitude': -0.140515},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '50 Warwick Way',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1RY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50 Warwick Way',
#      'London SW1V 1RY',
#      'United Kingdom']},
#    'phone': '+442078281700',
#    'display_phone': '+44 20 7828 1700',
#    'distance': 2360.251869923125},
#   {'id': '1OcBgrUzPgp82BfZBUKRow',
#    'alias': 'gails-bakery-hampstead-london',
#    'name': "GAIL's Bakery Hampstead",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UOf253iDTU_yHsHrbwwV2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-hampstead-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5561216, 'longitude': -0.1779628},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '64 Hampstead High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 1QH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['64 Hampstead High Street',
#      'London NW3 1QH',
#      'United Kingdom']},
#    'phone': '+442077940926',
#    'display_phone': '+44 20 7794 0926',
#    'distance': 5621.242336165493},
#   {'id': 'EDUYMl-qz7djEABhs_Ysdg',
#    'alias': 'caravan-city-london',
#    'name': 'Caravan City',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/F2RErmSC08I-9dAnaNbeRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caravan-city-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5121026881328,
#     'longitude': -0.0914937108755112},
#    'transactions': [],
#    'location': {'address1': '22 Bloomberg Arcade',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4N 8AR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Bloomberg Arcade',
#      'London EC4N 8AR',
#      'United Kingdom']},
#    'phone': '+442039575555',
#    'display_phone': '+44 20 3957 5555',
#    'distance': 3077.920703151008},
#   {'id': 'U_71ZadYKpRQH3a3brJldg',
#    'alias': 'the-footman-london',
#    'name': 'The Footman',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wHVZ3ZnSg1UYK8X6WiQtBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-footman-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.508493408063,
#     'longitude': -0.14612577314659},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5 Charles Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 5DF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Charles Street',
#      'London W1J 5DF',
#      'United Kingdom']},
#    'phone': '+442074992988',
#    'display_phone': '+44 20 7499 2988',
#    'distance': 853.4961697235703},
#   {'id': 'Rw0EzoWhElWgfbb84hMuhQ',
#    'alias': 'the-cakehouse-london',
#    'name': 'The Cakehouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yQl2G5YIdYgq5m5I0Z-0bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cakehouse-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5460129, 'longitude': -0.147699},
#    'transactions': [],
#    'location': {'address1': '73 Prince of Wales Road',
#     'address2': 'Kentish Town',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW5 3LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['73 Prince of Wales Road',
#      'Kentish Town',
#      'London NW5 3LT',
#      'United Kingdom']},
#    'phone': '+447913233777',
#    'display_phone': '+44 7913 233777',
#    'distance': 3779.91205310475},
#   {'id': 'BZ96WsFu82jq65zs4Y2MsQ',
#    'alias': 'aux-merveilleux-de-fred-london',
#    'name': 'Aux Merveilleux de Fred',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DXEeU-Kc1KA0V6mm3yRPXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aux-merveilleux-de-fred-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4924431, 'longitude': -0.1778994},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '88 Old Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3LQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['88 Old Brompton Road',
#      'London SW7 3LQ',
#      'United Kingdom']},
#    'phone': '+442075844249',
#    'display_phone': '+44 20 7584 4249',
#    'distance': 3661.0849280759267},
#   {'id': 'lHDmU30IffReJzeN-nfbcg',
#    'alias': 'céleste-london-2',
#    'name': 'Céleste',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/q4WPntQvfi9ygoA2kMHITg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/c%C3%A9leste-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5024378995539,
#     'longitude': -0.152714507934547},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'Hyde Park Corner',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7TA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Hyde Park Corner',
#      'London SW1X 7TA',
#      'United Kingdom']},
#    'phone': '+442072595599',
#    'display_phone': '+44 20 7259 5599',
#    'distance': 1637.668948636185}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#            Restaurant                    Type Price Rating  \
# 0  The Breakfast Club  American (Traditional)    ££    3.5
# 1           Bon Gusto                 Italian    ££    4.5
# 2            Casa Tua            Coffee & Tea     £    4.5
# 3               Niche                 British    ££      4
# 4      Scarlett Green      Breakfast & Brunch
#
#                    Address        Lat       Lng  \
# 0        31 Camden Passage  51.535105 -0.103711
# 1    75-77 Buckingham Gate  51.499204 -0.137846
# 2        106 Cromer Street  51.527645 -0.123588
# 3  197-199 Rosebery Avenue  51.529939 -0.105479
# 4            4 Noel Street  51.515282 -0.135855
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/the-breakfast-club-lo...  IhpwcD7I4NzdloijSkM5KQ
# 1  https://www.yelp.com/biz/bon-gusto-london?adju...  EKM6VmUANUVy5wqXT7gEXQ
# 2  https://www.yelp.com/biz/casa-tua-london-2?adj...  E_3NekwxctQ3BzN7tLKk2A
# 3  https://www.yelp.com/biz/niche-london-5?adjust...  NCj4ufnnu9iJuJVy_15nxw
# 4

# %%
london_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
london_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_restaurants_df = london_restaurants_df[column_order]
london_restaurants_df = london_restaurants_df.sort_values(["Type"], ascending=True)
london_restaurants_df = london_restaurants_df.reset_index(drop=True)
london_restaurants_df
# Out:
#                          Restaurant                    Type Rating Price  \
# 0            Red Rooster Shoreditch          American (New)      4   £££
# 1                        Blue Plate          American (New)
# 2                      The Abingdon          American (New)    4.5   £££
# 3                The Breakfast Club  American (Traditional)    3.5    ££
# 4                      The Fat Bear  American (Traditional)    4.5    ££
# 5                      Black & Blue  American (Traditional)      4    ££
# 6                             Rapsa            Asian Fusion    4.5    ££
# 7                       Timmy Green              Australian
# 8              Darcie and May Green              Australian
# 9                      Granger & Co              Australian    3.5    ££
# 10                        Fischer's                Austrian      4   £££
# 11      GAIL's Bakery Seymour Place                Bakeries    4.5    ££
# 12                    Camden Bakery                Bakeries    4.5     £
# 13          GAIL's Bakery - Pimlico                Bakeries
# 14          GAIL's Bakery Hampstead                Bakeries    4.5    ££
# 15             Byward Kitchen & Bar                Bakeries      4    ££
# 16          Aux Merveilleux de Fred                Bakeries    4.5     £
# 17                       Ottolenghi                Bakeries      4    ££
# 18           The Hummingbird Bakery                Bakeries      4    ££
# 19                    Baker & Spice                Bakeries      4    ££
# 20                    Baker & Spice                Bakeries      4    ££
# 21                        The Dairy                    Bars    4.5  ££££
# 22              Duck & Waffle Local                    Bars    4.5    ££
# 23                             Fego              Brasseries      4    ££
# 24                  Greenberry Café              Brasseries      4    ££
# 25                     The Tin Shed      Breakfast & Brunch      4    ££
# 26                 Burnt Toast Cafe      Breakfast & Brunch      4     £
# 27              Caravan Kings Cross      Breakfast & Brunch      4    ££
# 28                   Malibu Kitchen      Breakfast & Brunch
# 29                 Percy & Founders      Breakfast & Brunch      4   £££
# ..                              ...                     ...    ...   ...
# 170                 The Barge House                 Lounges      4    ££
# 171                      Ottolenghi           Mediterranean      4    ££
# 172                            NOPI           Mediterranean      4   £££
# 173                      Ella Canta                 Mexican
# 174                         Mestizo                 Mexican      4    ££
# 175                      Honey & Co          Middle Eastern    4.5    ££
# 176                          Bill's         Modern European      4    ££
# 177                   Duck & Waffle         Modern European      4   £££
# 178                          Bill's         Modern European      4    ££
# 179              Chiltern Firehouse         Modern European      4  ££££
# 180                     The Ledbury         Modern European    4.5  ££££
# 181                          Drunch         Modern European    3.5   £££
# 182                         Annie's         Modern European    4.5    ££
# 183           Heddon Street Kitchen         Modern European      4   £££
# 184                            Momo                Moroccan      4   £££
# 185     Daylesford Farmhouse & Cafe          Organic Stores    3.5    ££
# 186          Where the Pancakes are                Pancakes    4.5    ££
# 187  Franze & Evans Cafe Shoreditch    Patisserie/Cake Shop      4    ££
# 188                    The Garrison                    Pubs      4    ££
# 189                   The Blackbird                    Pubs      4    ££
# 190                     The Footman                    Pubs      4    ££
# 191                    Pickle & Rye              Sandwiches      5     £
# 192               Harrods' Tea Room              Sandwiches      4    ££
# 193                     Snaps & Rye            Scandinavian      4    ££
# 194                      34 Mayfair             Steakhouses      4  ££££
# 195                       Black Cat                   Vegan    4.5     £
# 196                         Farmacy                   Vegan    4.5    ££
# 197                   The Book Club   Venues & Event Spaces      4    ££
# 198                     Louie Louie               Wine Bars    4.5    ££
# 199             The Ivy City Garden               Wine Bars
#
#                               Address        Lat       Lng  \
# 0                     45 Curtain Road  51.524165 -0.080290
# 1               85 Chiswick High Road  51.492700 -0.252125
# 2                    54 Abingdon Road  51.497629 -0.196078
# 3                   31 Camden Passage  51.535105 -0.103711
# 4                      61 Carter Lane  51.513183 -0.101381
# 5    215-217 Kensington Church Street  51.508423 -0.195380
# 6               100-104 Hoxton Street  51.531065 -0.080011
# 7             Sir Simon Milton Square  51.498034 -0.143856
# 8                      Sheldon Square  51.518888 -0.178270
# 9                    Stanley Building  51.532585 -0.125705
# 10          50 Marylebone High Street  51.521616 -0.151700
# 11                  4-6 Seymour Place  51.514595 -0.160964
# 12              94 Camden High Street  51.537083 -0.140764
# 13                  26 Churton Street  51.491763 -0.139059
# 14           64 Hampstead High Street  51.556122 -0.177963
# 15                      Byward Street  51.509289 -0.078964
# 16               88 Old Brompton Road  51.492443 -0.177899
# 17                  13 Motcomb Street  51.499502 -0.156689
# 18                133 Portobello Road  51.514002 -0.203874
# 19                   47 Denyer Street  51.493991 -0.164682
# 20             54-56 Elizabeth Street  51.493600 -0.150758
# 21                    15 The Pavement  51.461872 -0.139592
# 22                       52 Haymarket  51.509418 -0.132750
# 23      64 St John's Wood High Street  51.532500 -0.169230
# 24              101 Regents Park Road  51.542194 -0.156334
# 25                 33 All Saints Road  51.518525 -0.204378
# 26     Unit 88 Brixton Village Market  51.462631 -0.111819
# 27                   1 Granary Square  51.535779 -0.125371
# 28                         27 Poultry  51.513583 -0.089917
# 29                   1 Pearson Square  51.518794 -0.137988
# ..                                ...        ...       ...
# 170           46 De Beauvoir Crescent  51.537300 -0.080873
# 171                  287 Upper Street  51.539754 -0.102216
# 172              21-22 Warwick Street  51.511617 -0.138523
# 173                One Hamilton Place  51.503868 -0.150415
# 174                103 Hampstead Road  51.527520 -0.138765
# 175                 25a Warren Street  51.523829 -0.140788
# 176              119-121 Baker Street  51.521638 -0.157553
# 177                   110 Bishopsgate  51.516178 -0.080940
# 178               36-44 Brewer Street  51.511881 -0.135307
# 179                 1 Chiltern Street  51.518712 -0.154847
# 180                  127 Ledbury Road  51.516819 -0.200107
# 181                16 Blenheim Street  51.513893 -0.146594
# 182                   162 Thames Road  51.484780 -0.277890
# 183                     3-9 Heddon St  51.510729 -0.139302
# 184               25-27 Heddon Street  51.511106 -0.140326
# 185              6-8 Blandford Street  51.518519 -0.151911
# 186                          Arch 35a  51.504367 -0.095555
# 187                  101 Redchurch St  51.524867 -0.072634
# 188              99 Bermondsey Street  51.500646 -0.081590
# 189                 209 Earls Ct Road  51.491780 -0.192110
# 190                  5 Charles Street  51.508493 -0.146126
# 191                     31 Sheen Lane  51.468303 -0.266688
# 192                87-135 Brompton Rd  51.499226 -0.163594
# 193                  93 Golborne Road  51.521561 -0.208958
# 194               34 Grovesnor Square  51.510555 -0.152588
# 195                  76 Clarence Road  51.551397 -0.055691
# 196               74 Westbourne Grove  51.515446 -0.192638
# 197                100 Leonard Street  51.524537 -0.081494
# 198                 347 Walworth Road  51.486009 -0.094104
# 199               69 Old Broad Street  51.516801 -0.082124
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/red-rooster-shoreditc...  p9TrMj3CyIQd-nywbZklZw
# 1
# 2    https://www.yelp.com/biz/the-abingdon-london?a...  Gdqq0f4R8pBXIcHvAI3SuQ
# 3    https://www.yelp.com/biz/the-breakfast-club-lo...  IhpwcD7I4NzdloijSkM5KQ
# 4    https://www.yelp.com/biz/the-fat-bear-london?a...  Z0r83lDOA1mI8RpNccXtHw
# 5    https://www.yelp.com/biz/black-and-blue-london...  _Nq4qS4X_GP-0hEaPLflWw
# 6    https://www.yelp.com/biz/rapsa-london-2?adjust...  gJAFSUO7U70GQJFo3ynRUw
# 7
# 8
# 9    https://www.yelp.com/biz/granger-and-co-london...  1fH92NtBqTqo8TW-00NQvw
# 10   https://www.yelp.com/biz/fischers-london?adjus...  apqNvjbaB20wozywrLNPiQ
# 11   https://www.yelp.com/biz/gails-bakery-seymour-...  LgKc7xGArsmxAw6xUQ2mYA
# 12   https://www.yelp.com/biz/camden-bakery-london?...  pa2j9BlCHH8mRIk-TtD6UQ
# 13
# 14   https://www.yelp.com/biz/gails-bakery-hampstea...  1OcBgrUzPgp82BfZBUKRow
# 15   https://www.yelp.com/biz/byward-kitchen-and-ba...  xViBKVW8zxlrxLfDam2eqg
# 16   https://www.yelp.com/biz/aux-merveilleux-de-fr...  BZ96WsFu82jq65zs4Y2MsQ
# 17   https://www.yelp.com/biz/ottolenghi-london-2?a...  kAgxFPCeNiZeiKc9POkiOg
# 18   https://www.yelp.com/biz/the-hummingbird-baker...  QyYFRNphu0fICXNfZjD_AA
# 19   https://www.yelp.com/biz/baker-and-spice-londo...  L5bYiNsHg-hKJraeFXBSYA
# 20   https://www.yelp.com/biz/baker-and-spice-londo...  jIuiv7VJkAAM5bRCuKNozg
# 21   https://www.yelp.com/biz/the-dairy-london-2?ad...  8P4qwhVKdxoV1bW-_I3s-A
# 22   https://www.yelp.com/biz/duck-and-waffle-local...  a4FkZ2b7Wn3-AP7q3ptHtQ
# 23   https://www.yelp.com/biz/fego-london?adjust_cr...  ZXsDUkkD46vTf0n5q4aDxw
# 24   https://www.yelp.com/biz/greenberry-caf%C3%A9-...  T-_ewkgY9DiMJ36qHL4UvQ
# 25   https://www.yelp.com/biz/the-tin-shed-london-2...  g0EAOJ_KXkJDcE19lc3LRg
# 26   https://www.yelp.com/biz/burnt-toast-cafe-lond...  zE_UPVsKaoNX0dhuN5jqlg
# 27   https://www.yelp.com/biz/caravan-kings-cross-l...  B6ayHXLwfYBuIADficAeMg
# 28
# 29   https://www.yelp.com/biz/percy-and-founders-lo...  35B3UJMEaI1sQj4vaKK0RQ
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/the-barge-house-londo...  n7vXgfapPy4uGLgqsUTDyg
# 171  https://www.yelp.com/biz/ottolenghi-islington?...  WT5EjZGp4gn9BNnzTlC2Ww
# 172  https://www.yelp.com/biz/nopi-london?adjust_cr...  AMfqUC9oYC0xc55MaXbvAA
# 173
# 174  https://www.yelp.com/biz/mestizo-london?adjust...  XeAaUJWcS9RZsE80a1UxjA
# 175  https://www.yelp.com/biz/honey-and-co-london?a...  Rb3xF0gkAwnDHML6okB1FA
# 176  https://www.yelp.com/biz/bills-london-25?adjus...  Q_rR0j8TS-2gJIMHAYh_jw
# 177  https://www.yelp.com/biz/duck-and-waffle-londo...  hOLFwKg4-0FsCleJ4yoCXw
# 178  https://www.yelp.com/biz/bills-london-4?adjust...  se61yyYAHdJZ_Fq9ygXjVg
# 179  https://www.yelp.com/biz/chiltern-firehouse-lo...  6tXkeZlisxTtdUsjDaTqaw
# 180  https://www.yelp.com/biz/the-ledbury-london?ad...  bEmaFY0A9JwpuxHKJXWx7Q
# 181  https://www.yelp.com/biz/drunch-mayfair?adjust...  ya18ZfPH4beNzooV3r42rg
# 182  https://www.yelp.com/biz/annies-london-3?adjus...  q7z_7wz_kCUZOyW58QRTrg
# 183  https://www.yelp.com/biz/heddon-street-kitchen...  WHrXrCaBE3Uf3d-B5Wyh0g
# 184  https://www.yelp.com/biz/momo-london?adjust_cr...  AM2d672O6FjDpL82iVWTlg
# 185  https://www.yelp.com/biz/daylesford-farmhouse-...  66uNLSVxF-S9CeGE_olN6Q
# 186  https://www.yelp.com/biz/where-the-pancakes-ar...  7_mJPWb6tREPW58f2xRpgA
# 187  https://www.yelp.com/biz/franze-and-evans-cafe...  fM99pmX2-ipWvG33tILdZQ
# 188  https://www.yelp.com/biz/the-garrison-london?a...  nVMVXywZjvDBkPPR_uqhUA
# 189  https://www.yelp.com/biz/the-blackbird-london?...  dXEPhJmyV9BiA77wdAfEmg
# 190  https://www.yelp.com/biz/the-footman-london?ad...  U_71ZadYKpRQH3a3brJldg
# 191  https://www.yelp.com/biz/pickle-and-rye-london...  6xXfpMnpujSY_XuxeVvESQ
# 192  https://www.yelp.com/biz/harrods-tea-room-lond...  6hw3LjFoZ3aLcnfxuDSJAg
# 193  https://www.yelp.com/biz/snaps-and-rye-london?...  CvYiWzRJ_xBXBcXm6QLYyw
# 194  https://www.yelp.com/biz/34-mayfair-london?adj...  nyLKZw4j3Qi066s-Z7mG9w
# 195  https://www.yelp.com/biz/black-cat-london?adju...  f8s8dT9Rm4359xUVHtiqRA
# 196  https://www.yelp.com/biz/farmacy-london?adjust...  ZTSM33QFv3pwxtSJp8Y02g
# 197  https://www.yelp.com/biz/the-book-club-london?...  UMJxTGTSShg2u1FFwZBWAQ
# 198  https://www.yelp.com/biz/louie-louie-london?ad...  ivojzgnsc6AH6Tp_Kl0jZA
# 199
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
london_restaurants_df.to_csv('Resources/London_Restaurants_Brunch.csv')
