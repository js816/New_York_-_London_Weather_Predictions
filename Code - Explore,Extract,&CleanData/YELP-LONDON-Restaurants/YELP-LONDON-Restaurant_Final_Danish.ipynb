# %% [markdown]
# LONDON RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
lndr_params1 = {"term":"danish","location":"London","limit":50,"offset":0}
lndr_response1 = requests.get(search_api_url, headers=headers, params=lndr_params1)
lndr1 = lndr_response1.json()
display(lndr1)
#print(lndr_response1.url)
#print(lndr_response1.status_code)
# Out:
# {'businesses': [{'id': '5or4AzNouZq8RClNeTdqiA',
#    'alias': 'ole-and-steen-london-2',
#    'name': 'Ole and Steen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HhmDFvGw42MnOJErQE9vkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ole-and-steen-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.509238, 'longitude': -0.1326965},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '56 Haymarket',
#     'address2': '',
#     'address3': "No 2 St James's Market",
#     'city': 'London',
#     'zip_code': 'SW1Y 4RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['56 Haymarket',
#      "No 2 St James's Market",
#      'London SW1Y 4RP',
#      'United Kingdom']},
#    'phone': '+442038288242',
#    'display_phone': '+44 20 3828 8242',
#    'distance': 459.23424350084883},
#   {'id': '0tJs57Xoq75-RDWKVco0nw',
#    'alias': 'bageriet-london',
#    'name': 'Bageriet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2yfTj7nJkUd_snGs1WP2aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bageriet-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'scandinavian', 'title': 'Scandinavian'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5119236, 'longitude': -0.1261821},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '24 Rose Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 9EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Rose Street',
#      'London WC2E 9EA',
#      'United Kingdom']},
#    'phone': '+442072400000',
#    'display_phone': '+44 20 7240 0000',
#    'distance': 683.9151857905819},
#   {'id': 'CvYiWzRJ_xBXBcXm6QLYyw',
#    'alias': 'snaps-and-rye-london',
#    'name': 'Snaps & Rye',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fzGYVIp4ObasQP8Ypo87oA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/snaps-and-rye-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'scandinavian', 'title': 'Scandinavian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5215609, 'longitude': -0.2089577},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '93 Golborne Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W10 5NL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['93 Golborne Road',
#      'London W10 5NL',
#      'United Kingdom']},
#    'phone': '+442089643004',
#    'display_phone': '+44 20 8964 3004',
#    'distance': 5143.644092189328},
#   {'id': 'kAgxFPCeNiZeiKc9POkiOg',
#    'alias': 'ottolenghi-london-2',
#    'name': 'Ottolenghi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/h7J52IR5gmXdlef7pJxfSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ottolenghi-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4995017, 'longitude': -0.1566887},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '13 Motcomb Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 8LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Motcomb Street',
#      'London SW1X 8LB',
#      'United Kingdom']},
#    'phone': '+442078232707',
#    'display_phone': '+44 20 7823 2707',
#    'distance': 2068.4293878068443},
#   {'id': 'N-U604mIyucKujlDgzTCig',
#    'alias': 'franks-cafe-london',
#    'name': "Frank's Cafe",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HTjUX8mrhlf4JUSNb3vkcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/franks-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.506313, 'longitude': -0.101584},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '132 Southwark Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0SW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['132 Southwark Street',
#      'London SE1 0SW',
#      'United Kingdom']},
#    'phone': '+442079283850',
#    'display_phone': '+44 20 7928 3850',
#    'distance': 2465.749710783424},
#   {'id': 'geQ7nECbljb9R2T-vzF-4w',
#    'alias': 'ekte-london',
#    'name': 'Ekte',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mzb-p9APm4qGrfQUQh6JTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ekte-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'scandinavian', 'title': 'Scandinavian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5125028, 'longitude': -0.0921989},
#    'transactions': [],
#    'location': {'address1': '2-8 Bloomberg Arcade',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EC4N 8AR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2-8 Bloomberg Arcade',
#      'London EC4N 8AR',
#      'United Kingdom']},
#    'phone': '+442038148330',
#    'display_phone': '+44 20 3814 8330',
#    'distance': 3028.2544371570098},
#   {'id': 'Sh_PrXavTAk2d5jTs_onuQ',
#    'alias': 'nordic-bakery-london',
#    'name': 'Nordic Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y1r_R3BokRhDYZIaF0XB6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nordic-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 118,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'scandinavian', 'title': 'Scandinavian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5114297969411,
#     'longitude': -0.13674108684063},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 Golden Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9JG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Golden Square',
#      'London W1F 9JG',
#      'United Kingdom']},
#    'phone': '+442032301077',
#    'display_phone': '+44 20 3230 1077',
#    'distance': 165.48625457765309},
#   {'id': 'X_1Z-RAonaFLaTjkdKBljA',
#    'alias': 'lisas-london-2',
#    'name': "Lisa's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/o7f1ipNVpmcVj689xXBKZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lisas-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'scandinavian', 'title': 'Scandinavian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5193556, 'longitude': -0.2078333},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '305 Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W10 5TD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['305 Portobello Road',
#      'London W10 5TD',
#      'United Kingdom']},
#    'phone': '+447445261778',
#    'display_phone': '+44 7445 261778',
#    'distance': 5026.193752550122},
#   {'id': 'qmvTW4c9KGAcykHa9szLUg',
#    'alias': 'the-bread-station-london',
#    'name': 'The Bread Station',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XdOTTrqwKaTbfx9dl_MwmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bread-station-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.539462, 'longitude': -0.058356},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Arch 373 Hemsley Place',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E8 3SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Arch 373 Hemsley Place',
#      'London E8 3SB',
#      'United Kingdom']},
#    'phone': '+442072547388',
#    'display_phone': '+44 20 7254 7388',
#    'distance': 6123.571899706672},
#   {'id': 'CrQcYS4nWWdXmSD1pxf_KA',
#    'alias': 'beigel-bake-london',
#    'name': 'Beigel Bake',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1Q9nDZsnX30-yv55INHp7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beigel-bake-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 477,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.524391, 'longitude': -0.071726},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '159 Brick Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['159 Brick Lane', 'London E1 6SB', 'United Kingdom']},
#    'phone': '+442077290616',
#    'display_phone': '+44 20 7729 0616',
#    'distance': 4626.215959115099},
#   {'id': 'FM2fOny0zttmwnSeHCHzyA',
#    'alias': 'fabrique-bakery-london-5',
#    'name': 'Fabrique Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1-A9bxyUwournvQ4hL3sMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fabrique-bakery-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516469, 'longitude': -0.205223},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '212 Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 1LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['212 Portobello Road',
#      'London W11 1LA',
#      'United Kingdom']},
#    'phone': '+442072213721',
#    'display_phone': '+44 20 7221 3721',
#    'distance': 4813.9954429630825},
#   {'id': 'xHpdYU6opeGiTgF-UN9jHA',
#    'alias': 'melissa-riva-flowers-london',
#    'name': 'Melissa Riva Flowers',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/me8JaDkhYUwurN3QphVFkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/melissa-riva-flowers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'florists', 'title': 'Florists'},
#     {'alias': 'homedecor', 'title': 'Home Decor'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5338189195529,
#     'longitude': -0.16914395195778},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '85 Allitsen Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 7AS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['85 Allitsen Rd', 'London NW8 7AS', 'United Kingdom']},
#    'phone': '+442075866996',
#    'display_phone': '+44 20 7586 6996',
#    'distance': 3273.5605698108234},
#   {'id': '91TQLypsN7trt-EyX8TgBQ',
#    'alias': 'daisy-green-london-2',
#    'name': 'Daisy Green',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ythY0ZkbjY3cYODreg4hLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daisy-green-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5148104, 'longitude': -0.1579352},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Seymour Street',
#     'address2': 'Marble Arch',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Seymour Street',
#      'Marble Arch',
#      'London W1H 7HX',
#      'United Kingdom']},
#    'phone': '+442077233301',
#    'display_phone': '+44 20 7723 3301',
#    'distance': 1536.7313570216975},
#   {'id': 'yzCe9pe62SNNsG2YnVvsSw',
#    'alias': 'bread-and-butler-london',
#    'name': 'Bread and Butler',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lUEpKgCKy8Ea8v4AT-60Pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bread-and-butler-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4765242895393,
#     'longitude': -0.0217996537685394},
#    'transactions': [],
#    'location': {'address1': '3 Creekside',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE8 4SA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Creekside', 'London SE8 4SA', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8874.541760663467},
#   {'id': '4svfWCht7u4QZBOsKDsU8g',
#    'alias': 'canada-water-cafe-london-2',
#    'name': 'Canada Water Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uwvTuIjHjzdReStWQYO9mQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/canada-water-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4988032772992,
#     'longitude': -0.049119766697061},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '40 Surrey Quays Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE16 7DX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 Surrey Quays Road',
#      'London SE16 7DX',
#      'United Kingdom']},
#    'phone': '+442036687518',
#    'display_phone': '+44 20 3668 7518',
#    'distance': 6209.296363971311},
#   {'id': 'QFbRZBFoCY8_CE9bCdoULg',
#    'alias': 'ole-and-steen-london-6',
#    'name': 'Ole & Steen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wqrY1J0EA-PXu2-6p_6fPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ole-and-steen-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5017972502378,
#     'longitude': -0.191780626773834},
#    'transactions': [],
#    'location': {'address1': 'Kensington High Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W8 4SH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Kensington High Street',
#      'London W8 4SH',
#      'United Kingdom']},
#    'phone': '+442039557448',
#    'display_phone': '+44 20 3955 7448',
#    'distance': 4053.8715548536993},
#   {'id': 'DY2qHkTlkWB8UVxnaCWj-w',
#    'alias': 'euphorium-bakery-london-6',
#    'name': 'Euphorium Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cz8zy9HMtV9RRobzyZk4HA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/euphorium-bakery-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5365826, 'longitude': -0.1035965},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '79 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 0NU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['79 Upper Street', 'London N1 0NU', 'United Kingdom']},
#    'phone': '+442072888788',
#    'display_phone': '+44 20 7288 8788',
#    'distance': 3460.115806670105},
#   {'id': 'QP9XgJDpJqgxeW1yZ1cV0Q',
#    'alias': 'gordons-cafe-london',
#    'name': "Gordon's Cafe",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hn3wb-zjGcUbLzxDy2OZxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gordons-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.525731809348,
#     'longitude': -0.13331898483959},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '25 Gordon Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 0AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['25 Gordon Street',
#      'London WC1H 0AY',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1445.5596765928715},
#   {'id': 'e_ltf3fKYx4HB3v8bptHiw',
#    'alias': 'l-express-coffee-company-ltd-london-9',
#    'name': "L'Express Coffee Company Ltd",
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-express-coffee-company-ltd-london-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5255535, 'longitude': -0.137105},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '250 Euston Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 2PG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['250 Euston Rd', 'London NW1 2PG', 'United Kingdom']},
#    'phone': '+442073884703',
#    'display_phone': '+44 20 7388 4703',
#    'distance': 1416.406776778061},
#   {'id': 'oYi2mMLV2qjmBT72W_ArJw',
#    'alias': 'jolt-coffee-london',
#    'name': 'Jolt Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FBjsLDM88tir2FgrwKopdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jolt-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5161534827318,
#     'longitude': -0.140492980095612},
#    'transactions': [],
#    'location': {'address1': '40-41 Great Castle Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1W 8LU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40-41 Great Castle Street',
#      'London W1W 8LU',
#      'United Kingdom']},
#    'phone': '+442074221144',
#    'display_phone': '+44 20 7422 1144',
#    'distance': 484.4488172876588},
#   {'id': 'OLXnVhh19HtAnbywQzD3zw',
#    'alias': 'rinkoff-bakeries-london-2',
#    'name': 'Rinkoff Bakeries',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U0sRZgXWXgBxJhqCMQAESA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rinkoff-bakeries-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5198880062398,
#     'longitude': -0.0530246183202313},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '224 Jubilee Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 3BS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['224 Jubilee Street',
#      'London E1 3BS',
#      'United Kingdom']},
#    'phone': '+442077914909',
#    'display_phone': '+44 20 7791 4909',
#    'distance': 5791.8034174832765},
#   {'id': 'jIuiv7VJkAAM5bRCuKNozg',
#    'alias': 'baker-and-spice-london',
#    'name': 'Baker & Spice',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qhKK__pVmzQmzhkDlOTx8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baker-and-spice-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4936, 'longitude': -0.150758},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '54-56 Elizabeth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 9PB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54-56 Elizabeth Street',
#      'London SW1W 9PB',
#      'United Kingdom']},
#    'phone': '+442077305524',
#    'display_phone': '+44 20 7730 5524',
#    'distance': 2371.6101398591395},
#   {'id': 'TB31gU2v3mFZphYYN-xecg',
#    'alias': 'boxcar-baker-and-deli-london',
#    'name': 'Boxcar Baker & Deli',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uZ_uXO8zbbKVRM61J0D9lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boxcar-baker-and-deli-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5195266, 'longitude': -0.161565},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '7A Wyndham Place',
#     'address2': 'Marylebone',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 1PN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7A Wyndham Place',
#      'Marylebone',
#      'London W1H 1PN',
#      'United Kingdom']},
#    'phone': '+442030067000',
#    'display_phone': '+44 20 3006 7000',
#    'distance': 1920.25121063196},
#   {'id': 'HAi7bThXmEtooc5ZQq9hdw',
#    'alias': 'laurents-london',
#    'name': 'Laurents',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IjF-yyo_-fqEs5nTO5MMpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laurents-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.513468, 'longitude': -0.179164},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '39 Craven Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 3BX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39 Craven Road', 'London W2 3BX', 'United Kingdom']},
#    'phone': '+442035819232',
#    'display_phone': '+44 20 3581 9232',
#    'distance': 2990.8516064262462},
#   {'id': '7XmKJcAcVdUx74sH7NFA_g',
#    'alias': 'hide-london',
#    'name': 'Hide',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eKTpFUfYIlbJaw9f5CCStQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hide-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5061568370745,
#     'longitude': -0.144324263574846},
#    'transactions': [],
#    'location': {'address1': '85 Piccadilly',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1J 7NB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['85 Piccadilly', 'London W1J 7NB', 'United Kingdom']},
#    'phone': '+442031468666',
#    'display_phone': '+44 20 3146 8666',
#    'distance': 941.7631440041313},
#   {'id': 'L5bYiNsHg-hKJraeFXBSYA',
#    'alias': 'baker-and-spice-london-2',
#    'name': 'Baker & Spice',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nnqOqLOXyhgiq2lOvBhPqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baker-and-spice-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4939913, 'longitude': -0.164682},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '47 Denyer Street',
#     'address2': '',
#     'address3': 'Chelsea',
#     'city': 'London',
#     'zip_code': 'SW3 2LX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Denyer Street',
#      'Chelsea',
#      'London SW3 2LX',
#      'United Kingdom']},
#    'phone': '+442075894734',
#    'display_phone': '+44 20 7589 4734',
#    'distance': 2883.911010904249},
#   {'id': 'L-ZNTln24SoU_jYia4M19Q',
#    'alias': 'ottolenghi-london-3',
#    'name': 'Ottolenghi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/M0v7lVN-ZkBDz0BuJQhzwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ottolenghi-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 96,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514890823172,
#     'longitude': -0.19941762827537},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '63 Ledbury Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2AD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63 Ledbury Road',
#      'London W11 2AD',
#      'United Kingdom']},
#    'phone': '+442077271121',
#    'display_phone': '+44 20 7727 1121',
#    'distance': 4397.458116121883},
#   {'id': '3AXQMV-Yirhfq4oQHry6tA',
#    'alias': 'poilane-london-2',
#    'name': 'Poilane',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Q6ebWSVX6ww2ytOCd96_Aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/poilane-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.493827, 'longitude': -0.150838},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '46 Elizabeth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 9PA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['46 Elizabeth Street',
#      'London SW1W 9PA',
#      'United Kingdom']},
#    'phone': '+442078084910',
#    'display_phone': '+44 20 7808 4910',
#    'distance': 2353.221354752839},
#   {'id': 'sTjZJB20joSHE8oVPHs1Cw',
#    'alias': 'covent-garden-grind-london',
#    'name': 'Covent Garden Grind',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c7YW3mmPah5JplPL-fFPbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/covent-garden-grind-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5110479046224,
#     'longitude': -0.122459969000028},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '42 Maiden Lane',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 7LJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 Maiden Lane',
#      'Covent Garden',
#      'London WC2E 7LJ',
#      'United Kingdom']},
#    'phone': '+442030191801',
#    'display_phone': '+44 20 3019 1801',
#    'distance': 954.8611659358846},
#   {'id': 'j51ptsqH2-KGXELJpA4w9A',
#    'alias': 'the-last-crumb-cafe-london-2',
#    'name': 'The Last Crumb Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Te-LLgbc5VlKRqeUfuF2rA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-last-crumb-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5624351501465,
#     'longitude': -0.078355997800827},
#    'transactions': [],
#    'location': {'address1': '71-73 Stoke Newington Church Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 0AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['71-73 Stoke Newington Church Street',
#      'London N16 0AP',
#      'United Kingdom']},
#    'phone': '+442072491551',
#    'display_phone': '+44 20 7249 1551',
#    'distance': 6780.335006205463},
#   {'id': 'dSEoONOM7wGmNYGm6pq4kw',
#    'alias': 'patisserie-valerie-london-23',
#    'name': 'Patisserie Valerie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/k2863Opic_UBFt6K1QF3aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-valerie-london-23?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5192643639646,
#     'longitude': -0.16873803092403},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '256 Edgware Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1DS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['256 Edgware Road',
#      'London W2 1DS',
#      'United Kingdom']},
#    'phone': '+442077236289',
#    'display_phone': '+44 20 7723 6289',
#    'distance': 2378.3712416396834},
#   {'id': '8tsGkeT6Z9EhT8UvBzVtWw',
#    'alias': 'rinkoff-bakeries-london',
#    'name': 'Rinkoff Bakeries',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2xa-EAj9vCWoIrLWUFOXeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rinkoff-bakeries-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5220242, 'longitude': -0.0644858},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '79 Vallance Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 5BS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['79 Vallance Road',
#      'London E1 5BS',
#      'United Kingdom']},
#    'phone': '+442072476228',
#    'display_phone': '+44 20 7247 6228',
#    'distance': 5049.735578986961},
#   {'id': 'PBFvhVyBi0lEJyTbyuxf5w',
#    'alias': 'the-orangery-london-7',
#    'name': 'The Orangery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L_0d22xNmfCC_d-tArBo3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-orangery-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 238,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5066360577041,
#     'longitude': -0.187725349125042},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Kensington Palace',
#     'address2': 'Palace Green',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Kensington Palace',
#      'Palace Green',
#      'London W8 4PX',
#      'United Kingdom']},
#    'phone': '+442031666113',
#    'display_phone': '+44 20 3166 6113',
#    'distance': 3648.4574890404074},
#   {'id': 'iM6MsRXEP7GN5FMagtoieQ',
#    'alias': 'kupp-london',
#    'name': 'KuPP',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c0piftjHufv-1UtFbfJktg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kupp-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'scandinavian', 'title': 'Scandinavian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.518769386792,
#     'longitude': -0.173566584655759},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 53',
#     'address2': '5 Merchant Square',
#     'address3': 'Paddington Basin',
#     'city': 'London',
#     'zip_code': 'W2 1AS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 53',
#      '5 Merchant Square',
#      'Paddington Basin',
#      'London W2 1AS',
#      'United Kingdom']},
#    'phone': '+442072628618',
#    'display_phone': '+44 20 7262 8618',
#    'distance': 2684.868112367749},
#   {'id': 'zYUCY6y7RqC7GB0xPAZZNg',
#    'alias': 'the-sandwich-centre-london',
#    'name': 'The Sandwich Centre',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AFsOo7vJvSqGsVvA1cV1Bw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-sandwich-centre-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5071972354505,
#     'longitude': -0.131873477246131},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '15-16 Royal Opera Arcade',
#     'address2': 'Pall Mall',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 4UY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15-16 Royal Opera Arcade',
#      'Pall Mall',
#      'London SW1Y 4UY',
#      'United Kingdom']},
#    'phone': '+442078397838',
#    'display_phone': '+44 20 7839 7838',
#    'distance': 687.6631791429497},
#   {'id': 'Lr5_1a2rIyzA7W-6UPKS-A',
#    'alias': '26-grains-london',
#    'name': '26 Grains',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ci9nQvD05RdQ7k56unmJwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/26-grains-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5143765, 'longitude': -0.126556},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "1 Neal's Yard",
#     'address2': 'Covent Garden',
#     'address3': 'Seven Dials',
#     'city': 'London',
#     'zip_code': 'WC2H 9DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["1 Neal's Yard",
#      'Covent Garden',
#      'Seven Dials',
#      'London WC2H 9DP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 672.6546229251097},
#   {'id': '1TgYqfxkXv6-IB4cvuuy3w',
#    'alias': 'tea-and-tattle-london',
#    'name': 'Tea and Tattle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zm3bEijY0rcDGz-5Nw9sKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tea-and-tattle-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5178680419922,
#     'longitude': -0.126817002892494},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '41 Great Russell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3PE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41 Great Russell Street',
#      'London WC1B 3PE',
#      'United Kingdom']},
#    'phone': '+447722192703',
#    'display_phone': '+44 7722 192703',
#    'distance': 841.826045500197},
#   {'id': 'klqP4NUFEl9kA6DIyRHpjA',
#    'alias': 'little-bread-pedlar-london',
#    'name': 'Little Bread Pedlar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/c8tHh4TWUFb98oD65Gfing/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-bread-pedlar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4955192, 'longitude': -0.0692471},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 5',
#     'address2': 'Dockley Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE16 3SF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 5',
#      'Dockley Road',
#      'London SE16 3SF',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5002.583314102826},
#   {'id': '7TETeEdYvewlhdjmMSwLdg',
#    'alias': 'pâtisserie-deux-amis-london-2',
#    'name': 'Pâtisserie Deux Amis',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QOrh6QeP-vvD3r_lviR-CA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/p%C3%A2tisserie-deux-amis-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.526409002227,
#     'longitude': -0.12406009445317},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '63 Judd Street',
#     'address2': 'Bloomsbury',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 9QT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63 Judd Street',
#      'Bloomsbury',
#      'London WC1H 9QT',
#      'United Kingdom']},
#    'phone': '+442073837029',
#    'display_phone': '+44 20 7383 7029',
#    'distance': 1719.1378500956116},
#   {'id': '1iZkMMh1PZnCjQhJLivG3Q',
#    'alias': 'carmelli-london',
#    'name': 'Carmelli',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/M7o8leBNP8ttnhOP8rHOcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carmelli-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5739863, 'longitude': -0.2007461},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '126-128 Golders Green Road',
#     'address2': '',
#     'address3': 'London',
#     'city': 'London',
#     'zip_code': 'NW11 8HB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['126-128 Golders Green Road',
#      'London',
#      'London NW11 8HB',
#      'United Kingdom']},
#    'phone': '+442084552074',
#    'display_phone': '+44 20 8455 2074',
#    'distance': 8150.379306826664},
#   {'id': 'klR6m5YGum9IP9NGziry8A',
#    'alias': 'greggs-hounslow',
#    'name': 'Greggs',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greggs-hounslow?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.4687041, 'longitude': -0.3614446},
#    'transactions': [],
#    'location': {'address1': '181 High Street',
#     'address2': 'Middlesex',
#     'address3': '',
#     'city': 'Hounslow',
#     'zip_code': 'TW3 1BL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['181 High Street',
#      'Middlesex',
#      'Hounslow TW3 1BL',
#      'United Kingdom']},
#    'phone': '+442085772890',
#    'display_phone': '+44 20 8577 2890',
#    'distance': 16364.649027768373},
#   {'id': 'wh4R2zTxcjZw4JcQFNBtog',
#    'alias': 'aux-pains-de-papy-london',
#    'name': 'Aux Pains de Papy',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Kqbb4D3ddlwupyZ2hxiYVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aux-pains-de-papy-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5273865, 'longitude': -0.1184675},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '279 Grays Inn Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1X 8EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['279 Grays Inn Rd',
#      'London WC1X 8EB',
#      'United Kingdom']},
#    'phone': '+447771613779',
#    'display_phone': '+44 7771 613779',
#    'distance': 2020.4045688598862},
#   {'id': 'cBH0H0sCT4eygYvo-Rca2Q',
#    'alias': 'zilly-london',
#    'name': 'Zilly',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IBuvPeg2FJhI0y0WYLD_ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zilly-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.523216250785,
#     'longitude': -0.14176486517352},
#    'transactions': [],
#    'location': {'address1': '126 Cleveland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 6PQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['126 Cleveland Street',
#      'London W1T 6PQ',
#      'United Kingdom']},
#    'phone': '+442073837694',
#    'display_phone': '+44 20 7383 7694',
#    'distance': 1222.2643917884307},
#   {'id': 'FeRP9CIb0TLDkDv9fbLe7g',
#    'alias': 'quartiers-london',
#    'name': 'Quartiers',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XJFOVCtrSQSKsa9IUFJFRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/quartiers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4920492171925,
#     'longitude': -0.140656046569347},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '47 Warwick Way',
#     'address2': 'Pimlico',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1QS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Warwick Way',
#      'Pimlico',
#      'London SW1V 1QS',
#      'United Kingdom']},
#    'phone': '+442036026165',
#    'display_phone': '+44 20 3602 6165',
#    'distance': 2334.1131855610943},
#   {'id': 'S--3Zg6kT54JETDh_qym7A',
#    'alias': 'laveli-bakery-london',
#    'name': 'Laveli Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/buGRiamui8KxzOnqXJSP-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laveli-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5088348, 'longitude': -0.263378},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5 Churchfield Road',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W3 6BH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Churchfield Road',
#      'London W3 6BH',
#      'United Kingdom']},
#    'phone': '+442089936490',
#    'display_phone': '+44 20 8993 6490',
#    'distance': 8829.32983472595},
#   {'id': 'e5jPAqpCcIAsTtasUN5h2g',
#    'alias': 'the-wolseley-london',
#    'name': 'The Wolseley',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T9xpXsz-az88-l0Ko_KLpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wolseley-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 553,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.507617, 'longitude': -0.141012},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '160 Picadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 9EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['160 Picadilly', 'London W1J 9EB', 'United Kingdom']},
#    'phone': '+442074996996',
#    'display_phone': '+44 20 7499 6996',
#    'distance': 677.6098617325135},
#   {'id': 'LsAb0HuEayFLS0fnT_qPCw',
#    'alias': 'andalucia-london-3',
#    'name': 'Andalucia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_h_c5xbdq79l97nUfFC_Yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/andalucia-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4747696, 'longitude': -0.1322888},
#    'transactions': [],
#    'location': {'address1': '248 Wandsworth Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW8 2JS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['248 Wandsworth Road',
#      'London SW8 2JS',
#      'United Kingdom']},
#    'phone': '+442077388800',
#    'display_phone': '+44 20 7738 8800',
#    'distance': 4245.309147824933},
#   {'id': '2P2qP8XcFFYnyX6BvguYxA',
#    'alias': 'house-of-twenty-london',
#    'name': 'House of Twenty',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1-2ODR1jleQlaGBGQPHnNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/house-of-twenty-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'antiques', 'title': 'Antiques'},
#     {'alias': 'homedecor', 'title': 'Home Decor'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5615708, 'longitude': -0.045895},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 5',
#     'address2': '142 Lea Bridge Road',
#     'address3': 'Hackney',
#     'city': 'London',
#     'zip_code': 'E5 9RB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 5',
#      '142 Lea Bridge Road',
#      'Hackney',
#      'London E5 9RB',
#      'United Kingdom']},
#    'phone': '+442089853223',
#    'display_phone': '+44 20 8985 3223',
#    'distance': 8256.307035197064},
#   {'id': 'K-kn0Ab7ks9d_NVVaVO7Dg',
#    'alias': 'bens-cookies-london-7',
#    'name': "Ben's Cookies",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PM0PTGQPf-Fqj4KDwn-h_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bens-cookies-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5140380859375,
#     'longitude': -0.13926799595356},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '35-36 Great Marlborough Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7JF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35-36 Great Marlborough Street',
#      'London W1F 7JF',
#      'United Kingdom']},
#    'phone': '+442077348846',
#    'display_phone': '+44 20 7734 8846',
#    'distance': 264.1498025655537},
#   {'id': 'SGFChjEHGxDAMBQ60qqrJw',
#    'alias': 'j-f-ayre-london-2',
#    'name': 'J F Ayre',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Ro52gNkTlHWlbZURd_aCuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/j-f-ayre-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4660904, 'longitude': -0.0566952},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '131-133 Evelina Road',
#     'address2': 'Nunhead',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE15 3HB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['131-133 Evelina Road',
#      'Nunhead',
#      'London SE15 3HB',
#      'United Kingdom']},
#    'phone': '+442076390648',
#    'display_phone': '+44 20 7639 0648',
#    'distance': 7558.5926624145595}],
#  'total': 125,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#       Restaurant                  Type Price Rating               Address  \
# 0  Ole and Steen  Patisserie/Cake Shop    ££    4.5          56 Haymarket
# 1       Bageriet          Scandinavian     £    4.5        24 Rose Street
# 2    Snaps & Rye          Scandinavian    ££      4      93 Golborne Road
# 3     Ottolenghi              Bakeries    ££      4     13 Motcomb Street
# 4   Frank's Cafe          Coffee & Tea     £    4.5  132 Southwark Street
#
#          Lat       Lng                                                url  \
# 0  51.509238 -0.132696  https://www.yelp.com/biz/ole-and-steen-london-...
# 1  51.511924 -0.126182  https://www.yelp.com/biz/bageriet-london?adjus...
# 2  51.521561 -0.208958  https://www.yelp.com/biz/snaps-and-rye-london?...
# 3  51.499502 -0.156689  https://www.yelp.com/biz/ottolenghi-london-2?a...
# 4  51.506313 -0.101584  https://www.yelp.com/biz/franks-cafe-london?ad...
#
#                        ID
# 0  5or4AzNouZq8RClNeTdqiA
# 1  0tJs57Xoq75-RDWKVco0nw
# 2  CvYiWzRJ_xBXBcXm6QLYyw
# 3  kAgxFPCeNiZeiKc9POkiOg
# 4  N-U604mIyucKujlDgzTCig

# %%
#2nd set of 50 records 51-100 
lndr_params2 = {"term":"danish","location":"London","limit":50,"offset":51}
lndr_response2 = requests.get(search_api_url, headers=headers, params=lndr_params2)
lndr2 = lndr_response2.json()
display(lndr2)
#print(lndr_response2.url)
#print(lndr_response2.status_code)
# Out:
# {'businesses': [{'id': 'HqH0Z0mZPhCyMRTY3Gq4KA',
#    'alias': 'roomscape-london',
#    'name': 'Roomscape',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XvsR_anjz0_TtYNlmTJ_Zw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roomscape-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'antiques', 'title': 'Antiques'},
#     {'alias': 'furniture', 'title': 'Furniture Stores'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5441433, 'longitude': -0.1511037},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'in the CityStore',
#     'address2': 'Belmont St',
#     'address3': 'Camden',
#     'city': 'London',
#     'zip_code': 'NW1 8HF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['in the CityStore',
#      'Belmont St',
#      'Camden',
#      'London NW1 8HF',
#      'United Kingdom']},
#    'phone': '+447956645492',
#    'display_phone': '+44 7956 645492',
#    'distance': 3635.5542671247},
#   {'id': 'V--A9CPTH6q3NVQI7lWtpg',
#    'alias': 'minamoto-kitchoan-london-2',
#    'name': 'Minamoto Kitchoan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/s1JkbmmDSkyoxiTR8W4qyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/minamoto-kitchoan-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'candy', 'title': 'Candy Stores'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5088682, 'longitude': -0.1253374},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '448 Strand',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2N',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['448 Strand', 'London WC2N', 'United Kingdom']},
#    'phone': '+442034904747',
#    'display_phone': '+44 20 3490 4747',
#    'distance': 851.9241553503688},
#   {'id': 'Opa8XUwUghxbGFafvubV6A',
#    'alias': 'monmouth-coffee-london-3',
#    'name': 'Monmouth Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bwLj-cK2l4ws5hpEefgdqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/monmouth-coffee-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 306,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5143539, 'longitude': -0.1269168},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '27 Monmouth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['27 Monmouth Street',
#      'London WC2H 9EU',
#      'United Kingdom']},
#    'phone': '+442072323010',
#    'display_phone': '+44 20 7232 3010',
#    'distance': 647.8829298163467},
#   {'id': 'OFDcUBPqx7LB6IIgwEyyGg',
#    'alias': 'apostrophe-london-14',
#    'name': 'Apostrophe',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/apostrophe-london-14?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5199362, 'longitude': -0.1333911},
#    'transactions': [],
#    'location': {'address1': '216-217 Tottenham Court Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 7PT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['216-217 Tottenham Court Rd',
#      'London W1T 7PT',
#      'United Kingdom']},
#    'phone': '+442074366688',
#    'display_phone': '+44 20 7436 6688',
#    'distance': 807.8755017578588},
#   {'id': 'Z3dr4as9zDncGnaCtqnntQ',
#    'alias': 'patisserie-valerie-london-7',
#    'name': 'Patisserie Valerie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GeZus7r-mVclADzIcGbopg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-valerie-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5191096196678,
#     'longitude': -0.15177361600921},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '105 Marylebone High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 4RS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['105 Marylebone High Road',
#      'London W1U 4RS',
#      'United Kingdom']},
#    'phone': '+442079356240',
#    'display_phone': '+44 20 7935 6240',
#    'distance': 1297.9635922946884},
#   {'id': 'szf0xNjM-D8u--eVAYkXUw',
#    'alias': 'everything-but-the-dog-london',
#    'name': 'Everything But The Dog',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qCEf-Pdb-Pad_283-nInkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/everything-but-the-dog-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'furniture', 'title': 'Furniture Stores'},
#     {'alias': 'homedecor', 'title': 'Home Decor'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5891127, 'longitude': -0.0196925},
#    'transactions': [],
#    'location': {'address1': '70 Hoe Street',
#     'address2': 'Walthamstow',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E17 4PG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['70 Hoe Street',
#      'Walthamstow',
#      'London E17 4PG',
#      'United Kingdom']},
#    'phone': '+442085210357',
#    'display_phone': '+44 20 8521 0357',
#    'distance': 11685.889620280046},
#   {'id': 'S41G_f79UqY-YpHJ5XjAgg',
#    'alias': 'haminados-london',
#    'name': 'Haminados',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PWHQDQQ21zytZEJxo5572g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/haminados-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5173006, 'longitude': -0.1955482},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '78 Chepstow Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 5BE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['78 Chepstow Road',
#      'London W2 5BE',
#      'United Kingdom']},
#    'phone': '+442072295204',
#    'display_phone': '+44 20 7229 5204',
#    'distance': 4155.463008533445},
#   {'id': 'qnMS_VFY-JC9w90mU8EQow',
#    'alias': 'danish-patisserie-london',
#    'name': 'Danish Patisserie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7TkfgDroeckrSqAbpX_Qww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/danish-patisserie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.476402, 'longitude': -0.208971},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '156 Munster Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 5RA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['156 Munster Road',
#      'London SW6 5RA',
#      'United Kingdom']},
#    'phone': '+442077313877',
#    'display_phone': '+44 20 7731 3877',
#    'distance': 6482.830146927403},
#   {'id': 'nHMn6sJQEj1c2cnGThyvvg',
#    'alias': 'harrods-food-hall-london',
#    'name': 'Harrods Food Hall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lTez1h3O4WyMt5kA4i8FBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harrods-food-hall-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 325,
#    'categories': [{'alias': 'cheese', 'title': 'Cheese Shops'},
#     {'alias': 'wineries', 'title': 'Wineries'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4990917420527,
#     'longitude': -0.162348972665107},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '87-135 Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7XL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['87-135 Brompton Road',
#      'London SW1X 7XL',
#      'United Kingdom']},
#    'phone': '+442077301234',
#    'display_phone': '+44 20 7730 1234',
#    'distance': 2381.6721756016004},
#   {'id': 'ztuEuIDjVTJMklB2OP3rpg',
#    'alias': 'ty-seven-dials-timberyard-london-2',
#    'name': 'TY Seven Dials - Timberyard',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Gr5lHKB84DjJGw8ESo5I6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ty-seven-dials-timberyard-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 138,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5128577362728,
#     'longitude': -0.127308054907987},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "7 Upper St Martin's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["7 Upper St Martin's Lane",
#      'London WC2H 9DL',
#      'United Kingdom']},
#    'phone': '+442032172009',
#    'display_phone': '+44 20 3217 2009',
#    'distance': 598.4373905869091},
#   {'id': 'hLg5fxKmxMP5y7LJTtPSmg',
#    'alias': 'amouls-london',
#    'name': "Amoul's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RemZJEwrlG8I7uglcIrvkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amouls-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'lebanese', 'title': 'Lebanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5246696472168,
#     'longitude': -0.184762999415398},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 Formosa Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W9 1EE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Formosa Street',
#      'London W9 1EE',
#      'United Kingdom']},
#    'phone': '+442072866386',
#    'display_phone': '+44 20 7286 6386',
#    'distance': 3624.3793316505044},
#   {'id': '4tqZnelLvUK2Ko35QZTIHw',
#    'alias': 'mono-london-london',
#    'name': 'Mono London',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rJCeRzFDXZQLY0MLrXU7eA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mono-london-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5329971, 'longitude': -0.0303377},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '535 Roman Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E3 5EL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['535 Roman Road', 'London E3 5EL', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 7617.290486927655},
#   {'id': 'pTzAvHQQ-eJqp8fcZ8F_wQ',
#    'alias': 'planet-organic-london-2',
#    'name': 'Planet Organic',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NWj6-btnC-bVbCYfo5gIKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/planet-organic-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'healthmarkets', 'title': 'Health Markets'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.521367, 'longitude': -0.134126},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Torrington Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1E 7HJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Torrington Place',
#      'London WC1E 7HJ',
#      'United Kingdom']},
#    'phone': '+442074361929',
#    'display_phone': '+44 20 7436 1929',
#    'distance': 993.9618175190195},
#   {'id': 'zjX_19K5wWXcdD3ZruZizg',
#    'alias': 'euphorium-bakery-london',
#    'name': 'Euphorium Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HNqlgSFb631DJmLHPjJypA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/euphorium-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5510701, 'longitude': -0.1659348},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '211 Haverstock Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 4QN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['211 Haverstock Hill',
#      'London NW3 4QN',
#      'United Kingdom']},
#    'phone': '+442074318944',
#    'display_phone': '+44 20 7431 8944',
#    'distance': 4725.5872019167455},
#   {'id': 'yf5UMDuX_srDzWTbgQ30pQ',
#    'alias': 'carpo-knightsbridge-london',
#    'name': 'Carpo Knightsbridge',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hYeYJjkCAdd4nVJVXggprQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carpo-knightsbridge-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'chocolate', 'title': 'Chocolatiers & Shops'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4989501, 'longitude': -0.1658158},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '5 Montpelier Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 1EX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Montpelier Street',
#      'London SW7 1EX',
#      'United Kingdom']},
#    'phone': '+442075842777',
#    'display_phone': '+44 20 7584 2777',
#    'distance': 2579.7187867776215},
#   {'id': '2SWn7n-K0bMFLNh4X7rjHg',
#    'alias': 'lombok-london-2',
#    'name': 'Lombok',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wrDQivZwe3Q4-fh6petDsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lombok-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'furniture', 'title': 'Furniture Stores'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5206445, 'longitude': -0.1341155},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '204-208 Tottenham Court Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 7PL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['204-208 Tottenham Court Road',
#      'London W1T 7PL',
#      'United Kingdom']},
#    'phone': '+442075800800',
#    'display_phone': '+44 20 7580 0800',
#    'distance': 871.343539809781},
#   {'id': 's_oVaCneOdnzBgCKD9_R1w',
#    'alias': 'le-signore-snack-bar-london-2',
#    'name': 'Le Signore Snack Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5N4qAqySMCBzoku0AEsbqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-signore-snack-bar-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4990164, 'longitude': -0.1428489},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '4 Palace Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1E 5HY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Palace Street',
#      'London SW1E 5HY',
#      'United Kingdom']},
#    'phone': '+442078347119',
#    'display_phone': '+44 20 7834 7119',
#    'distance': 1608.9716047481213},
#   {'id': 'B6ayHXLwfYBuIADficAeMg',
#    'alias': 'caravan-kings-cross-london',
#    'name': 'Caravan Kings Cross',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/N3qh0kXJvNLcjPEP9EEZGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caravan-kings-cross-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 170,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5357788239146,
#     'longitude': -0.125370576153865},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Granary Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Granary Square',
#      'London N1C 4AA',
#      'United Kingdom']},
#    'phone': '+442071017661',
#    'display_phone': '+44 20 7101 7661',
#    'distance': 2654.2035388419845},
#   {'id': 'iv4_ETrCnsu12oKBw6yQRA',
#    'alias': 'shalom-bakery-ilford',
#    'name': 'Shalom Bakery',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shalom-bakery-ilford?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5777738, 'longitude': 0.0645983},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Sir Charles House',
#     'address2': '35 Woodford Avenue',
#     'address3': '',
#     'city': 'Ilford',
#     'zip_code': 'IG2 6UF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Sir Charles House',
#      '35 Woodford Avenue',
#      'Ilford IG2 6UF',
#      'United Kingdom']},
#    'phone': '+442085515503',
#    'display_phone': '+44 20 8551 5503',
#    'distance': 15634.073478897255},
#   {'id': '7sLPMTB42uDVzxw1isKUCQ',
#    'alias': 'james-rotisserie-and-cafe-london',
#    'name': 'James Rotisserie and Cafe',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/james-rotisserie-and-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5150604, 'longitude': -0.1508341},
#    'transactions': [],
#    'location': {'address1': '21 James Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 1DS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21 James Street',
#      'London W1U 1DS',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1051.2792689436003},
#   {'id': 'b4f-kC6naDWRJo54Aeex0g',
#    'alias': 'chumleys-london',
#    'name': "Chumley's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nII4EveG_z-hQs__mhuBEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chumleys-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5598948, 'longitude': -0.0742493},
#    'transactions': [],
#    'location': {'address1': '101 Stoke Newington High Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N16 0PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['101 Stoke Newington High Street',
#      'London N16 0PH',
#      'United Kingdom']},
#    'phone': '+442072547684',
#    'display_phone': '+44 20 7254 7684',
#    'distance': 6752.55117280944},
#   {'id': 'hdHgeTZbUCUQ_PZ1nG96PA',
#    'alias': 'pret-a-manger-london-41',
#    'name': 'Pret A Manger',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/H0YPUPDdqcvLkhvJkZoKVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pret-a-manger-london-41?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.500753, 'longitude': -0.192514},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 14',
#     'address2': 'Kensington Arcade',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 5SF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 14',
#      'Kensington Arcade',
#      'London W8 5SF',
#      'United Kingdom']},
#    'phone': '+442079325254',
#    'display_phone': '+44 20 7932 5254',
#    'distance': 4153.677089415716},
#   {'id': 'xZfLg7Kkf7ZD_A84uio5cw',
#    'alias': 'konnigans-london',
#    'name': 'Konnigans',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cvN2vFu5LyMhvAozC0xdWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/konnigans-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.460212, 'longitude': -0.1888494},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '344 - 346 Old York Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW18 1SS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['344 - 346 Old York Road',
#      'London SW18 1SS',
#      'United Kingdom']},
#    'phone': '+442088711496',
#    'display_phone': '+44 20 8871 1496',
#    'distance': 6903.0977388999145},
#   {'id': 'AKhm8Oc4qVGobeQ555DuxQ',
#    'alias': 'richoux-london-2',
#    'name': 'Richoux',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mRmYWUBhUgMGgdnadY7Iqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/richoux-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.50799, 'longitude': -0.139541},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '172 Piccadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 9EJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['172 Piccadilly', 'London W1J 9EJ', 'United Kingdom']},
#    'phone': '+442074932204',
#    'display_phone': '+44 20 7493 2204',
#    'distance': 593.1789691622027},
#   {'id': 'SaU08qQw8zHV-Hcl5uJc2A',
#    'alias': 'boulangerie-bon-matin-london',
#    'name': 'Boulangerie Bon Matin',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3ProwjEE1DXE6-SzqAJhMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boulangerie-bon-matin-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.568414044592,
#     'longitude': -0.11076807793941},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '178 Tollington Park',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N4 3AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['178 Tollington Park',
#      'London N4 3AJ',
#      'United Kingdom']},
#    'phone': '+442072638633',
#    'display_phone': '+44 20 7263 8633',
#    'distance': 6420.85042933909},
#   {'id': 'GGG-14QFlozKOOSDAlDZ3g',
#    'alias': 'saint-espresso-london',
#    'name': 'Saint Espresso',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TRBUoKWFRJHTc6XHBR2-ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saint-espresso-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5320215750491,
#     'longitude': -0.107608515753707},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Angel House',
#     'address2': '26 Pentonville Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9HJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Angel House',
#      '26 Pentonville Road',
#      'London N1 9HJ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2897.9014287817117},
#   {'id': 'x58LDkXGU7vC8-KRDlS9Mw',
#    'alias': 'raison-d-etre-london',
#    'name': "Raison D'Etre",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GNL9SAtkBRabO34z0GOmqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raison-d-etre-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.493706018346,
#     'longitude': -0.17628170716244},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '18 Bute Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3EX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Bute Street', 'London SW7 3EX', 'United Kingdom']},
#    'phone': '+442075845008',
#    'display_phone': '+44 20 7584 5008',
#    'distance': 3509.3036349562817},
#   {'id': 'HaUEkzqd8ahjouFlhvq1tQ',
#    'alias': 'pickles-london-2',
#    'name': 'Pickles',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rt8BFFy1puq4RDeSw_sVEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pickles-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.501011, 'longitude': -0.130923},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '6 Old Queen Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1H 9HP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Old Queen Street',
#      'London SW1H 9HP',
#      'United Kingdom']},
#    'phone': '+442072228749',
#    'display_phone': '+44 20 7222 8749',
#    'distance': 1380.8110470930878},
#   {'id': 'mB2SodmTlTb_anJk3wvxVw',
#    'alias': 'amici-coffee-deli-london-2',
#    'name': 'Amici Coffee Deli',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WSo5q9l6aR2j9FB8_CWCBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amici-coffee-deli-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5467071533203,
#     'longitude': -0.10385499894619},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '6 Highbury Corner',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N5 1RD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Highbury Corner',
#      'London N5 1RD',
#      'United Kingdom']},
#    'phone': '+442077003132',
#    'display_phone': '+44 20 7700 3132',
#    'distance': 4372.225796029592},
#   {'id': 'I0sKyehdq3iKZ6GI5K5Gag',
#    'alias': 'caffé-concerto-london-8',
#    'name': 'Caffé Concerto',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/p8x4ybyEIPwQUQT8ep8X5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caff%C3%A9-concerto-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.509699, 'longitude': -0.136678},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '79-81 Regent Street',
#     'address2': 'Piccadilly',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 4EG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['79-81 Regent Street',
#      'Piccadilly',
#      'London W1B 4EG',
#      'United Kingdom']},
#    'phone': '+442074390090',
#    'display_phone': '+44 20 7439 0090',
#    'distance': 345.7304354390102},
#   {'id': 'WugHcUkDK5gaenFJi4ZWtA',
#    'alias': 'greggs-london-19',
#    'name': 'Greggs',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greggs-london-19?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.6037696, 'longitude': -0.1903887},
#    'transactions': [],
#    'location': {'address1': 'Ballards Lane',
#     'address2': 'Finchley',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N3 1LZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Ballards Lane',
#      'Finchley',
#      'London N3 1LZ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 10788.921695949863},
#   {'id': 'Kfz7NwTNSztX4pgXLSmUaw',
#    'alias': 'patisserie-valerie-london',
#    'name': 'Patisserie Valerie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Wlti6EDjRS60M_Dsgw5Kzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-valerie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.497184, 'longitude': -0.16763},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '215 Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 2EJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['215 Brompton Road',
#      'London SW3 2EJ',
#      'United Kingdom']},
#    'phone': '+442078239971',
#    'display_phone': '+44 20 7823 9971',
#    'distance': 2788.450907744187},
#   {'id': 'V_tBdpt8FqD8L9Uu62Qqgg',
#    'alias': 'loft-coffee-company-london',
#    'name': 'Loft Coffee Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/92vxPPBnPewSMIwdWnVBZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/loft-coffee-company-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5466931, 'longitude': -0.1805074},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '4 Canfield Gardens',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 3BS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Canfield Gardens',
#      'London NW6 3BS',
#      'United Kingdom']},
#    'phone': '+442073722008',
#    'display_phone': '+44 20 7372 2008',
#    'distance': 4865.336991257988},
#   {'id': 'oZFmFK_7utppr5Dqtn7oEw',
#    'alias': 'paul-rhodes-bakery-london',
#    'name': 'Paul Rhodes Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OBSgblMYY_7WlKajiiOsBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-rhodes-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5096498950531,
#     'longitude': -0.194281597508819},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '26 Notting Hill Gate',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 3HY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Notting Hill Gate',
#      'London W11 3HY',
#      'United Kingdom']},
#    'phone': '+442072211440',
#    'display_phone': '+44 20 7221 1440',
#    'distance': 4051.8511445572512},
#   {'id': 'HEUr7gS5wKskUPO3-J8D6w',
#    'alias': 'nells-kings-road-london',
#    'name': 'Nells Kings Road',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lOVn3WnoUW0f7aCLaD44_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nells-kings-road-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.48703, 'longitude': -0.1694247},
#    'transactions': [],
#    'location': {'address1': "191 King's Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 5ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["191 King's Road",
#      'London SW3 5ED',
#      'United Kingdom']},
#    'phone': '+442073519346',
#    'display_phone': '+44 20 7351 9346',
#    'distance': 3668.9533265656332},
#   {'id': 'YZrJSNqEI-m9mWwlm3ES7g',
#    'alias': 'the-upholstery-house-london',
#    'name': 'The Upholstery House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ms0IhEc3QH3djdRi5zd-Aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-upholstery-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'reupholstery', 'title': 'Furniture Reupholstery'},
#     {'alias': 'furniture', 'title': 'Furniture Stores'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.433206454324,
#     'longitude': -0.188697752450594},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Studio 1',
#     'address2': 'Delta House Studios',
#     'address3': 'Riverside Road',
#     'city': 'London',
#     'zip_code': 'SW17 0BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Studio 1',
#      'Delta House Studios',
#      'Riverside Road',
#      'London SW17 0BA',
#      'United Kingdom']},
#    'phone': '+447840675657',
#    'display_phone': '+44 7840 675657',
#    'distance': 9578.285305390118},
#   {'id': 'zWCUKosTsfZEwExrle-SYQ',
#    'alias': 'lanes-of-london-london',
#    'name': 'Lanes of London',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ATNkMPy7LuIzETaT0BQ-5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lanes-of-london-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5131069, 'longitude': -0.1578938},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '140 Park Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 7AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['140 Park Lane', 'London W1K 7AA', 'United Kingdom']},
#    'phone': '+442076475664',
#    'display_phone': '+44 20 7647 5664',
#    'distance': 1518.4238743633418},
#   {'id': 'eDLN85yEcgnecfY5kxgUzw',
#    'alias': 'lido-cafe-london',
#    'name': 'Lido Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uJd1-mAc3soxHq1EgXrIfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lido-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.504720440665,
#     'longitude': -0.169637034239847},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Hyde Park',
#     'address2': 'Princess of Wales Memorial Fountain',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 2UH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Hyde Park',
#      'Princess of Wales Memorial Fountain',
#      'London W2 2UH',
#      'United Kingdom']},
#    'phone': '+442077067098',
#    'display_phone': '+44 20 7706 7098',
#    'distance': 2499.5408708564023},
#   {'id': 'YDiSy92WGRJjWwPUMJNq4Q',
#    'alias': 'greggs-london-112',
#    'name': 'Greggs',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greggs-london-112?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 51.5529945, 'longitude': -0.2956079},
#    'transactions': [],
#    'location': {'address1': '504 High Road',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'HA9 7BH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['504 High Road', 'London HA9 7BH', 'United Kingdom']},
#    'phone': '+442089035923',
#    'display_phone': '+44 20 8903 5923',
#    'distance': 11911.865789925067},
#   {'id': 'JpZjcxIChQrNkFw4PND6Cw',
#    'alias': 'the-royal-quarter-café-london-2',
#    'name': 'The Royal Quarter Café',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aCP5U6sXU3Rln-oOjzu4tA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-royal-quarter-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.4989274, 'longitude': -0.1373499},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '72 Buckingham Gate',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1E 6AL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['72 Buckingham Gate',
#      'London SW1E 6AL',
#      'United Kingdom']},
#    'phone': '+442077994999',
#    'display_phone': '+44 20 7799 4999',
#    'distance': 1549.5177918611348},
#   {'id': 'GcKhWyZQaaIC12g_g-lyBw',
#    'alias': 'morbleu-london-4',
#    'name': 'MorBleu',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QsJiUDaBBZ9DaUeCA4sp6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/morbleu-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'furniture', 'title': 'Furniture Stores'},
#     {'alias': 'antiques', 'title': 'Antiques'},
#     {'alias': 'homedecor', 'title': 'Home Decor'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4526226133909,
#     'longitude': -0.102825552924543},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '135 Dulwich Road',
#     'address2': '',
#     'address3': 'Herne Hill',
#     'city': 'London',
#     'zip_code': 'SE24 0JN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['135 Dulwich Road',
#      'Herne Hill',
#      'London SE24 0JN',
#      'United Kingdom']},
#    'phone': '+442077334999',
#    'display_phone': '+44 20 7733 4999',
#    'distance': 7077.502245708546},
#   {'id': 'AXV8DnRPc6iX_lj59KJsmg',
#    'alias': 'the-delicious-deli-london',
#    'name': 'The Delicious Deli',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-delicious-deli-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4449198, 'longitude': -0.2041438},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '38 Replingham Road',
#     'address2': 'Southfields',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW18 5LR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38 Replingham Road',
#      'Southfields',
#      'London SW18 5LR',
#      'United Kingdom']},
#    'phone': '+442088742138',
#    'display_phone': '+44 20 8874 2138',
#    'distance': 8906.730590688065},
#   {'id': 'y1b2F9LD9uTM7xCCnarVLQ',
#    'alias': 'pret-a-manger-london-65',
#    'name': 'Pret A Manger',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-vzK28NyPa7rYnfLr_so5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pret-a-manger-london-65?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.522549, 'longitude': -0.158266},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '211-213 Baker Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 6UY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['211-213 Baker Street',
#      'London NW1 6UY',
#      'United Kingdom']},
#    'phone': '+442079325443',
#    'display_phone': '+44 20 7932 5443',
#    'distance': 1882.7552572870638},
#   {'id': '3BrqzKn6uzAeOQ4I8ZJZ2g',
#    'alias': 'boconcept-uk-london',
#    'name': 'Boconcept UK',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SKyr--VSnnKYsZW0_U2x_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boconcept-uk-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'furniture', 'title': 'Furniture Stores'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.523457, 'longitude': -0.136664},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '158 Tottenham Court Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 7NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['158 Tottenham Court Road',
#      'London W1T 7NH',
#      'United Kingdom']},
#    'phone': '+442073882447',
#    'display_phone': '+44 20 7388 2447',
#    'distance': 1161.564836327816},
#   {'id': 'wE0QAquH4HfeOBCT9Y0Oqw',
#    'alias': 'hej-coffee-london-2',
#    'name': 'Hej Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DvF4XxbirUvP_2q9n18AgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hej-coffee-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.497604, 'longitude': -0.080335},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '1 Bermondsey Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 3UN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Bermondsey Square',
#      'London SE1 3UN',
#      'United Kingdom']},
#    'phone': '+442034414544',
#    'display_phone': '+44 20 3441 4544',
#    'distance': 4175.73487297855},
#   {'id': 'ltmk1I-apNHLEvBj21uzZQ',
#    'alias': 'morris-of-bond-street-mayfair',
#    'name': 'Morris Of Bond Street',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/morris-of-bond-street-mayfair?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 51.5106733, 'longitude': -0.1422443},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '15B Clifford Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Mayfair',
#     'zip_code': 'W1S 4JZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15B Clifford Street',
#      'Mayfair W1S 4JZ',
#      'United Kingdom']},
#    'phone': '+442077346930',
#    'display_phone': '+44 20 7734 6930',
#    'distance': 497.17868556247413},
#   {'id': 'BDExDQzpmMyeeroGvGmOOQ',
#    'alias': 'the-patisserie-london',
#    'name': 'The Patisserie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x8ac7vDLwXWe_cgFw0Ekvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-patisserie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 51.4948074, 'longitude': -0.1824949},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '77A Gloucester Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 4SS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['77A Gloucester Road',
#      'London SW7 4SS',
#      'United Kingdom']},
#    'phone': '+442078351990',
#    'display_phone': '+44 20 7835 1990',
#    'distance': 3801.0175476672175},
#   {'id': 't5EthzFtA6mB2SzdFcfzPQ',
#    'alias': 'after-noah-london',
#    'name': 'After Noah',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Xv3hQsjY30yWPLqsn3ak0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/after-noah-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'antiques', 'title': 'Antiques'},
#     {'alias': 'toys', 'title': 'Toy Stores'},
#     {'alias': 'furniture', 'title': 'Furniture Stores'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.539117, 'longitude': -0.1026872},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '121 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 1QP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['121 Upper Street',
#      'London N1 1QP',
#      'United Kingdom']},
#    'phone': '+442073594281',
#    'display_phone': '+44 20 7359 4281',
#    'distance': 3719.860000535066},
#   {'id': 'LcrHcZj1tEQrwhJMPsBEjQ',
#    'alias': 'ginger-pig-london',
#    'name': 'Ginger Pig',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BKQD4E6uZadYt7cIyd-T6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginger-pig-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'},
#     {'alias': 'butcher', 'title': 'Butcher'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5374186, 'longitude': -0.0444647},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '99 Lauriston Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E9 7HJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['99 Lauriston Road',
#      'London E9 7HJ',
#      'United Kingdom']},
#    'phone': '+442089866911',
#    'display_phone': '+44 20 8986 6911',
#    'distance': 6902.595501465732},
#   {'id': 'nKaf4AKaZ2fwuHIpHbSeww',
#    'alias': 'the-castle-london-7',
#    'name': 'The Castle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7fVwbltBo66K6q2T9DLGhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-castle-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5319649, 'longitude': -0.1091644},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '54 Pentonville Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9HF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54 Pentonville Road',
#      'London N1 9HF',
#      'United Kingdom']},
#    'phone': '+442077131858',
#    'display_phone': '+44 20 7713 1858',
#    'distance': 2828.215009804018}],
#  'total': 125,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#            Restaurant                  Type Price Rating  \
# 0           Roomscape              Antiques    ££      4
# 1   Minamoto Kitchoan          Candy Stores   £££      4
# 2     Monmouth Coffee          Coffee & Tea    ££    4.5
# 3          Apostrophe          Coffee & Tea
# 4  Patisserie Valerie  Patisserie/Cake Shop    ££      4
#
#                       Address        Lat       Lng  \
# 0            in the CityStore  51.544143 -0.151104
# 1                  448 Strand  51.508868 -0.125337
# 2          27 Monmouth Street  51.514354 -0.126917
# 3  216-217 Tottenham Court Rd  51.519936 -0.133391
# 4    105 Marylebone High Road  51.519110 -0.151774
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/roomscape-london?adju...  HqH0Z0mZPhCyMRTY3Gq4KA
# 1  https://www.yelp.com/biz/minamoto-kitchoan-lon...  V--A9CPTH6q3NVQI7lWtpg
# 2  https://www.yelp.com/biz/monmouth-coffee-londo...  Opa8XUwUghxbGFafvubV6A
# 3
# 4  https://www.yelp.com/biz/patisserie-valerie-lo...  Z3dr4as9zDncGnaCtqnntQ

# %%
#3rd set of 50 records 101-150
lndr_params3 = {"term":"danish","location":"London","limit":50,"offset":101}
lndr_response3 = requests.get(search_api_url, headers=headers, params=lndr_params3)
lndr3 = lndr_response3.json()
display(lndr3)
#print(lndr_response3.url)
#print(lndr_response3.status_code)
# Out:
# {'businesses': [{'id': 'JIKFw7ufE__d3rupaxyq6A',
#    'alias': 'baker-and-spice-london-3',
#    'name': 'Baker & Spice',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WNJwqQx4dEG9_m_Uwoz2yA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baker-and-spice-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.525646318334,
#     'longitude': -0.17958285670861},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Clifton Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W9 1ST',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Clifton Rd', 'London W9 1ST', 'United Kingdom']},
#    'phone': '+442072663535',
#    'display_phone': '+44 20 7266 3535',
#    'distance': 3337.8385224906333},
#   {'id': 'eynphHGkpxUG2AVnEVEcFQ',
#    'alias': 'the-rosie-tate-cafe-london',
#    'name': 'The Rosie Tate Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xoUCKGiu5mNQkNDRJ4XYKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-rosie-tate-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.504684, 'longitude': -0.09766},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '11-17 Great Guildford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0HS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11-17 Great Guildford Street',
#      'London SE1 0HS',
#      'United Kingdom']},
#    'phone': '+442079289100',
#    'display_phone': '+44 20 7928 9100',
#    'distance': 2800.3458622465237},
#   {'id': 'qH-kupTBzRj5lvgaS9xzTA',
#    'alias': 'le-pain-quotidien-london-11',
#    'name': 'Le Pain Quotidien',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ohcKu92aOmwa64kZGRd43Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-pain-quotidien-london-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.508836, 'longitude': -0.196546},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '81-85 Notting Hill Gate',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 3JS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['81-85 Notting Hill Gate',
#      'London W11 3JS',
#      'United Kingdom']},
#    'phone': '+442036576938',
#    'display_phone': '+44 20 3657 6938',
#    'distance': 4244.965963335675},
#   {'id': 'djtPa63TXwDKqNVh0wwJXQ',
#    'alias': 'tiger-london',
#    'name': 'Tiger',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xhyVVWpLHfG13s6KLwiO_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tiger-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'homedecor', 'title': 'Home Decor'},
#     {'alias': 'cosmetics', 'title': 'Cosmetics & Beauty Supply'},
#     {'alias': 'toys', 'title': 'Toy Stores'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4927558, 'longitude': -0.2286226},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '41-42 King Street',
#     'address2': 'Hammersmith',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W6 0QB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41-42 King Street',
#      'Hammersmith',
#      'London W6 0QB',
#      'United Kingdom']},
#    'phone': '+442088347527',
#    'display_phone': '+44 20 8834 7527',
#    'distance': 6791.545957808055},
#   {'id': 'oloDcFsN_jkRRj3JL7890w',
#    'alias': 'toast-london-3',
#    'name': 'Toast',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/R9RbnDBhb9a-cdsBnXOwUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/toast-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.5134162902832,
#     'longitude': -0.147595003247261},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '11 S Molton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 5QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 S Molton Street',
#      'London W1K 5QL',
#      'United Kingdom']},
#    'phone': '+442076290549',
#    'display_phone': '+44 20 7629 0549',
#    'distance': 808.0221745656305},
#   {'id': 'IWmqRJQAu5VBUlkp8QACaQ',
#    'alias': 'gana-cafe-and-restaurant-wembley',
#    'name': 'Gana Cafe & Restaurant',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gana-cafe-and-restaurant-wembley?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'diyfood', 'title': 'Do-It-Yourself Food'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.551364, 'longitude': -0.299091},
#    'transactions': [],
#    'location': {'address1': '24 Ealing Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Wembley',
#     'zip_code': 'HA0 4TL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Ealing Road',
#      'Wembley HA0 4TL',
#      'United Kingdom']},
#    'phone': '+442089037004',
#    'display_phone': '+44 20 8903 7004',
#    'distance': 12054.008916904224},
#   {'id': 'LBo6Dem8FpgURFZvK-UhEA',
#    'alias': 'prestige-london-3',
#    'name': 'Prestige',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Bc6vZx6eaP860crlT927dQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prestige-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.445639, 'longitude': -0.165952},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 Bellevue Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW17 7EG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Bellevue Rd',
#      'London SW17 7EG',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 7783.5630763634545},
#   {'id': 'gmUj1CNsf7H3YSoVEtLL0A',
#    'alias': 'aqua-shard-london',
#    'name': 'Aqua Shard',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/93WbwwjntclIkotc1t7IIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aqua-shard-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 197,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5044480395328,
#     'longitude': -0.0865149965538268},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Level 31 The Shard',
#     'address2': '31 St Thomas Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9RY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Level 31 The Shard',
#      '31 St Thomas Street',
#      'London SE1 9RY',
#      'United Kingdom']},
#    'phone': '+442030111256',
#    'display_phone': '+44 20 3011 1256',
#    'distance': 3546.4921655112666},
#   {'id': 'Fm4j-XbPqYQxA3kXyl1WAg',
#    'alias': 'couch-potato-company-london',
#    'name': 'Couch Potato Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/usQmmAHAT5arFflnBaQsNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/couch-potato-company-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'furniture', 'title': 'Furniture Stores'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.441739, 'longitude': -0.3443802},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '23 Hampton Road',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'TW2 5QE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23 Hampton Road',
#      'London TW2 5QE',
#      'United Kingdom']},
#    'phone': '+442088941333',
#    'display_phone': '+44 20 8894 1333',
#    'distance': 16457.51331456609},
#   {'id': '5Pst7pV5uyEUrW31RkcQFw',
#    'alias': 'the-conran-shop-london-2',
#    'name': 'The Conran Shop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RKg-YAv3yywinom4-nDMTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-conran-shop-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'deptstores', 'title': 'Department Stores'},
#     {'alias': 'furniture', 'title': 'Furniture Stores'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.493123, 'longitude': -0.168455},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Michelin House',
#     'address2': '81 Fulham Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 6RD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Michelin House',
#      '81 Fulham Road',
#      'London SW3 6RD',
#      'United Kingdom']},
#    'phone': '+442075897401',
#    'display_phone': '+44 20 7589 7401',
#    'distance': 3137.747474126815},
#   {'id': 'J92VgnLR5Ye5qYYfEzqcgg',
#    'alias': 'kensington-coffee-london',
#    'name': 'Kensington Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2W_BLBrTMO3iYVberTOtog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kensington-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5041291999959,
#     'longitude': -0.192936784819755},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '45 Kensington Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Kensington Church Street',
#      'London W8 4BA',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4060.602576041901},
#   {'id': 'B__B6RPZjC0bv2bFKcIJ3g',
#    'alias': 'caffe-concerto-kensington',
#    'name': 'Caffe Concerto',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2b9nrmahZNEZ8A6Zl27cdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-concerto-kensington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.4983999, 'longitude': -0.1664499},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '152 Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Kensington',
#     'zip_code': 'SW3 1HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['152 Brompton Road',
#      'Kensington SW3 1HX',
#      'United Kingdom']},
#    'phone': '+442080751120',
#    'display_phone': '+44 20 8075 1120',
#    'distance': 2645.6469328050607},
#   {'id': 'Tn6IKz98WzZOlDNgWoUr2Q',
#    'alias': 'the-chelsea-quarter-cafe-london',
#    'name': 'The Chelsea Quarter Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Bj5goNs74Thhw9E16FplEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-chelsea-quarter-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.4863577, 'longitude': -0.1711776},
#    'transactions': [],
#    'location': {'address1': '219 Kings Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 5EJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['219 Kings Road', 'London SW3 5EJ', 'United Kingdom']},
#    'phone': '+442073523660',
#    'display_phone': '+44 20 7352 3660',
#    'distance': 3822.6380373707602},
#   {'id': '4Ccpf8fEyvwCM9L4DXOjMQ',
#    'alias': 'le-pain-quotidien-canary-wharf',
#    'name': 'Le Pain Quotidien',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4HWXSVpZ8WmPeP6YjhjJ2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-pain-quotidien-canary-wharf?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5031005, 'longitude': -0.0185947},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Jubilee Place Unit 84 Level B4',
#     'address2': 'Jubilee Place',
#     'address3': '',
#     'city': 'Canary Wharf',
#     'zip_code': 'E14 5NY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Jubilee Place Unit 84 Level B4',
#      'Jubilee Place',
#      'Canary Wharf E14 5NY',
#      'United Kingdom']},
#    'phone': '+442036176631',
#    'display_phone': '+44 20 3617 6631',
#    'distance': 8185.669161270771},
#   {'id': '7DFOTwLQapai38a8OOBTZQ',
#    'alias': 'fat-boys-diner-london-2',
#    'name': "Fat Boy's Diner",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/K6MjWNn1TBRvDEOmRELGVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fat-boys-diner-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.507817, 'longitude': 0.0083991817534752},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '64 Trinity Buoy Wharf',
#     'address2': 'Orchard Place',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E14 0JY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['64 Trinity Buoy Wharf',
#      'Orchard Place',
#      'London E14 0JY',
#      'United Kingdom']},
#    'phone': '+442079874334',
#    'display_phone': '+44 20 7987 4334',
#    'distance': 10005.616861801911},
#   {'id': 'uT-oV_4eRMEPTrErzdp-4A',
#    'alias': 'greggs-hayes',
#    'name': 'Greggs',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2XTGr_MPsMWr75L9f7WAFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greggs-hayes?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.506307, 'longitude': -0.4188497},
#    'transactions': [],
#    'location': {'address1': '25 Station Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Hayes',
#     'zip_code': 'UB3 4BD',
#     'country': 'GB',
#     'state': 'DOR',
#     'display_address': ['25 Station Road', 'Hayes UB3 4BD', 'United Kingdom']},
#    'phone': '+442085730374',
#    'display_phone': '+44 20 8573 0374',
#    'distance': 19588.172953336463},
#   {'id': 'CrzA2NzgOHAcdA1wbQdAeg',
#    'alias': 'pret-a-manger-london-44',
#    'name': 'Pret A Manger',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/biUvY9ebZuuHtWsmIXiMdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pret-a-manger-london-44?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5201196278702,
#     'longitude': -0.102052688598633},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '3-5 St John Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1M 4AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3-5 St John Street',
#      'London EC1M 4AA',
#      'United Kingdom']},
#    'phone': '+442079325444',
#    'display_phone': '+44 20 7932 5444',
#    'distance': 2481.8250721842646},
#   {'id': 'R4hVXyqA---r5TjKgvVHOg',
#    'alias': 'caffe-concerto-london-10',
#    'name': 'Caffe Concerto',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/81CTeXDgJvy4X_-drNTCDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-concerto-london-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.499889, 'longitude': -0.164078},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 78 Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 1ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 78 Brompton Road',
#      'London SW3 1ER',
#      'United Kingdom']},
#    'phone': '+442074946855',
#    'display_phone': '+44 20 7494 6855',
#    'distance': 2395.198147777067},
#   {'id': 'P0lP5DQFx_klZfgwYxf6xQ',
#    'alias': 'caffe-concerto-london-19',
#    'name': 'Caffe Concerto',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hR1Re6TKiu6Knxfcv0Sf4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-concerto-london-19?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.5436177682967,
#     'longitude': -0.00868029892444611},
#    'transactions': [],
#    'location': {'address1': '31-34 Westfield Stratford City',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E15 2DU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['31-34 Westfield Stratford City',
#      'London E15 2DU',
#      'United Kingdom']},
#    'phone': '+442074946852',
#    'display_phone': '+44 20 7494 6852',
#    'distance': 9446.520380343298},
#   {'id': 'sIgnSnPwjr8hxtpLzHZh4w',
#    'alias': 'cafe-zee-london',
#    'name': 'Cafe Zee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y7XNXAnyla830wB5ElgPyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-zee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5130421976393,
#     'longitude': -0.305126085877419},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5 New Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W5 5AW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 New Broadway', 'London W5 5AW', 'United Kingdom']},
#    'phone': '+442085674485',
#    'display_phone': '+44 20 8567 4485',
#    'distance': 11706.728025566408},
#   {'id': 'RuXSheCwh8or-YhnxjDvzg',
#    'alias': 'cafe-luna-london',
#    'name': 'Cafe Luna',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/19zfHA_psUOxS-vuKCvSdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-luna-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.492910986855,
#     'longitude': -0.267533169952187},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '442 Chiswick High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W4 5TT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['442 Chiswick High Road',
#      'London W4 5TT',
#      'United Kingdom']},
#    'phone': '+442087421514',
#    'display_phone': '+44 20 8742 1514',
#    'distance': 9372.868279657558},
#   {'id': 'QdJBB4oxg2U25g2PzpaGFA',
#    'alias': 'pret-a-manger-london-16',
#    'name': 'Pret A Manger',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_5TN6G6r0yl543wWeKLXvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pret-a-manger-london-16?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.508856986928,
#     'longitude': -0.19667208881652},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '65 Notting Hill Gate',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 3JS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['65 Notting Hill Gate',
#      'London W11 3JS',
#      'United Kingdom']},
#    'phone': '+442079325320',
#    'display_phone': '+44 20 7932 5320',
#    'distance': 4225.028943785254},
#   {'id': '4QK1kQOde5RZ6PNTfo7wug',
#    'alias': 'albion-london-5',
#    'name': 'Albion',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5Cs76CZPdDPELbONN2AJHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/albion-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 101,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.524137, 'longitude': -0.076235},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2-4 Boundary Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7DD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2-4 Boundary Street',
#      'London E2 7DD',
#      'United Kingdom']},
#    'phone': '+442077291051',
#    'display_phone': '+44 20 7729 1051',
#    'distance': 4327.903016108891},
#   {'id': 'tbzentkM8HGfavVML6l8gA',
#    'alias': 'lite-bite-london',
#    'name': 'Lite Bite',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cW0wQLo8GzM2SlBXBPPTUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lite-bite-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.5155045, 'longitude': -0.1745693},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '7 London Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 London Street', 'London W2 1HL', 'United Kingdom']},
#    'phone': '+442077064127',
#    'display_phone': '+44 20 7706 4127',
#    'distance': 2699.877867320931}],
#  'total': 125,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#             Restaurant          Type Price Rating  \
# 0        Baker & Spice  Coffee & Tea    ££      3
# 1  The Rosie Tate Cafe  Coffee & Tea   £££      3
# 2    Le Pain Quotidien      Bakeries    ££      4
# 3                Tiger    Home Decor     £      4
# 4                Toast         Cafes     £    2.5
#
#                         Address        Lat       Lng  \
# 0                 20 Clifton Rd  51.525646 -0.179583
# 1  11-17 Great Guildford Street  51.504684 -0.097660
# 2       81-85 Notting Hill Gate  51.508836 -0.196546
# 3             41-42 King Street  51.492756 -0.228623
# 4            11 S Molton Street  51.513416 -0.147595
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/baker-and-spice-londo...  JIKFw7ufE__d3rupaxyq6A
# 1  https://www.yelp.com/biz/the-rosie-tate-cafe-l...  eynphHGkpxUG2AVnEVEcFQ
# 2  https://www.yelp.com/biz/le-pain-quotidien-lon...  qH-kupTBzRj5lvgaS9xzTA
# 3  https://www.yelp.com/biz/tiger-london?adjust_c...  djtPa63TXwDKqNVh0wwJXQ
# 4  https://www.yelp.com/biz/toast-london-3?adjust...  oloDcFsN_jkRRj3JL7890w

# %%
#4th set of 50 records 151-200
lndr_params4 = {"term":"danish","location":"London","limit":50,"offset":151}
lndr_response4 = requests.get(search_api_url, headers=headers, params=lndr_params4)
lndr4 = lndr_response4.json()
display(lndr4)
#print(lndr_response4.url)
#print(lndr_response4.status_code)
# Out:
# {'businesses': [],
#  'total': 125,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
# Empty DataFrame
# Columns: [Restaurant, Type, Price, Rating, Address, Lat, Lng, url, ID]
# Index: []

# %%
london_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
london_restaurants_df.shape
# Out:
# (124, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_restaurants_df = london_restaurants_df[column_order]
london_restaurants_df = london_restaurants_df.sort_values(["Type"], ascending=True)
london_restaurants_df = london_restaurants_df.reset_index(drop=True)
london_restaurants_df
# Out:
#                  Restaurant                    Type Rating Price  \
# 0                 Roomscape                Antiques      4    ££
# 1                After Noah                Antiques      4   £££
# 2           House of Twenty                Antiques      5    ££
# 3                  Carmelli                  Bagels      4     £
# 4                  J F Ayre                Bakeries      4     £
# 5             Baker & Spice                Bakeries      4    ££
# 6       Boxcar Baker & Deli                Bakeries      4    ££
# 7                  Laurents                Bakeries    4.5     £
# 8             Baker & Spice                Bakeries      4    ££
# 9                Ottolenghi                Bakeries      4    ££
# 10            Shalom Bakery                Bakeries      4     £
# 11         Rinkoff Bakeries                Bakeries    4.5     £
# 12         Euphorium Bakery                Bakeries    3.5     £
# 13         Rinkoff Bakeries                Bakeries      4     £
# 14                   Greggs                Bakeries
# 15                   Greggs                Bakeries
# 16                  Poilane                Bakeries      4    ££
# 17        Aux Pains de Papy                Bakeries      5     £
# 18      Little Bread Pedlar                Bakeries      4     £
# 19                   Greggs                Bakeries
# 20        Le Pain Quotidien                Bakeries      4    ££
# 21               Ottolenghi                Bakeries      4    ££
# 22            Nordic Bakery                Bakeries    3.5    ££
# 23            Laveli Bakery                Bakeries    4.5    ££
# 24     Pâtisserie Deux Amis                Bakeries      4    ££
# 25              Beigel Bake                Bakeries      4     £
# 26        The Bread Station                Bakeries    4.5    ££
# 27                   Greggs                Bakeries
# 28                  Amoul's                Bakeries      4    ££
# 29         Bread and Butler                Bakeries
# ..                      ...                     ...    ...   ...
# 94                  Richoux                  French    3.5    ££
# 95                     Hide                  French
# 96     The Upholstery House  Furniture Reupholstery      5     £
# 97   Everything But The Dog        Furniture Stores
# 98     Couch Potato Company        Furniture Stores      5  ££££
# 99                  MorBleu        Furniture Stores    4.5   £££
# 100                  Lombok        Furniture Stores      4   £££
# 101            Boconcept UK        Furniture Stores      3   £££
# 102          Planet Organic          Health Markets      4    ££
# 103                   Tiger              Home Decor      4     £
# 104          Caffe Concerto                 Italian    2.5    ££
# 105          Caffe Concerto                 Italian    2.5    ££
# 106     Covent Garden Grind  Juice Bars & Smoothies    4.5     £
# 107              Ginger Pig              Meat Shops    4.5   £££
# 108           Ole and Steen    Patisserie/Cake Shop    4.5    ££
# 109          The Patisserie    Patisserie/Cake Shop      2    ££
# 110      Patisserie Valerie    Patisserie/Cake Shop      4    ££
# 111                  Albion    Patisserie/Cake Shop    3.5    ££
# 112       Danish Patisserie    Patisserie/Cake Shop    3.5     £
# 113      Patisserie Valerie    Patisserie/Cake Shop      4    ££
# 114      Patisserie Valerie    Patisserie/Cake Shop    3.5    ££
# 115              The Castle                    Pubs    3.5    ££
# 116                 Pickles              Sandwiches    3.5     £
# 117     The Sandwich Centre              Sandwiches    4.5     £
# 118           Pret A Manger              Sandwiches      3     £
# 119               Lite Bite              Sandwiches    2.5     £
# 120                  Lisa's            Scandinavian      4    ££
# 121                    Ekte            Scandinavian
# 122             Snaps & Rye            Scandinavian      4    ££
# 123                Bageriet            Scandinavian    4.5     £
#
#                           Address        Lat       Lng  \
# 0                in the CityStore  51.544143 -0.151104
# 1                121 Upper Street  51.539117 -0.102687
# 2                          Unit 5  51.561571 -0.045895
# 3      126-128 Golders Green Road  51.573986 -0.200746
# 4            131-133 Evelina Road  51.466090 -0.056695
# 5          54-56 Elizabeth Street  51.493600 -0.150758
# 6                7A Wyndham Place  51.519527 -0.161565
# 7                  39 Craven Road  51.513468 -0.179164
# 8                47 Denyer Street  51.493991 -0.164682
# 9                 63 Ledbury Road  51.514891 -0.199418
# 10              Sir Charles House  51.577774  0.064598
# 11             224 Jubilee Street  51.519888 -0.053025
# 12            211 Haverstock Hill  51.551070 -0.165935
# 13               79 Vallance Road  51.522024 -0.064486
# 14                181 High Street  51.468704 -0.361445
# 15                25 Station Road  51.506307 -0.418850
# 16            46 Elizabeth Street  51.493827 -0.150838
# 17               279 Grays Inn Rd  51.527386 -0.118468
# 18                         Unit 5  51.495519 -0.069247
# 19                  Ballards Lane  51.603770 -0.190389
# 20        81-85 Notting Hill Gate  51.508836 -0.196546
# 21              13 Motcomb Street  51.499502 -0.156689
# 22               14 Golden Square  51.511430 -0.136741
# 23             5 Churchfield Road  51.508835 -0.263378
# 24                 63 Judd Street  51.526409 -0.124060
# 25                 159 Brick Lane  51.524391 -0.071726
# 26         Arch 373 Hemsley Place  51.539462 -0.058356
# 27                  504 High Road  51.552994 -0.295608
# 28              14 Formosa Street  51.524670 -0.184763
# 29                    3 Creekside  51.476524 -0.021800
# ..                            ...        ...       ...
# 94                 172 Piccadilly  51.507990 -0.139541
# 95                  85 Piccadilly  51.506157 -0.144324
# 96                       Studio 1  51.433206 -0.188698
# 97                  70 Hoe Street  51.589113 -0.019693
# 98                23 Hampton Road  51.441739 -0.344380
# 99               135 Dulwich Road  51.452623 -0.102826
# 100  204-208 Tottenham Court Road  51.520645 -0.134115
# 101      158 Tottenham Court Road  51.523457 -0.136664
# 102           22 Torrington Place  51.521367 -0.134126
# 103             41-42 King Street  51.492756 -0.228623
# 104         Unit 78 Brompton Road  51.499889 -0.164078
# 105             152 Brompton Road  51.498400 -0.166450
# 106                42 Maiden Lane  51.511048 -0.122460
# 107             99 Lauriston Road  51.537419 -0.044465
# 108                  56 Haymarket  51.509238 -0.132696
# 109           77A Gloucester Road  51.494807 -0.182495
# 110             215 Brompton Road  51.497184 -0.167630
# 111           2-4 Boundary Street  51.524137 -0.076235
# 112              156 Munster Road  51.476402 -0.208971
# 113      105 Marylebone High Road  51.519110 -0.151774
# 114              256 Edgware Road  51.519264 -0.168738
# 115           54 Pentonville Road  51.531965 -0.109164
# 116            6 Old Queen Street  51.501011 -0.130923
# 117      15-16 Royal Opera Arcade  51.507197 -0.131873
# 118          65 Notting Hill Gate  51.508857 -0.196672
# 119               7 London Street  51.515504 -0.174569
# 120           305 Portobello Road  51.519356 -0.207833
# 121          2-8 Bloomberg Arcade  51.512503 -0.092199
# 122              93 Golborne Road  51.521561 -0.208958
# 123                24 Rose Street  51.511924 -0.126182
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/roomscape-london?adju...  HqH0Z0mZPhCyMRTY3Gq4KA
# 1    https://www.yelp.com/biz/after-noah-london?adj...  t5EthzFtA6mB2SzdFcfzPQ
# 2    https://www.yelp.com/biz/house-of-twenty-londo...  2P2qP8XcFFYnyX6BvguYxA
# 3    https://www.yelp.com/biz/carmelli-london?adjus...  1iZkMMh1PZnCjQhJLivG3Q
# 4    https://www.yelp.com/biz/j-f-ayre-london-2?adj...  SGFChjEHGxDAMBQ60qqrJw
# 5    https://www.yelp.com/biz/baker-and-spice-londo...  jIuiv7VJkAAM5bRCuKNozg
# 6    https://www.yelp.com/biz/boxcar-baker-and-deli...  TB31gU2v3mFZphYYN-xecg
# 7    https://www.yelp.com/biz/laurents-london?adjus...  HAi7bThXmEtooc5ZQq9hdw
# 8    https://www.yelp.com/biz/baker-and-spice-londo...  L5bYiNsHg-hKJraeFXBSYA
# 9    https://www.yelp.com/biz/ottolenghi-london-3?a...  L-ZNTln24SoU_jYia4M19Q
# 10   https://www.yelp.com/biz/shalom-bakery-ilford?...  iv4_ETrCnsu12oKBw6yQRA
# 11   https://www.yelp.com/biz/rinkoff-bakeries-lond...  OLXnVhh19HtAnbywQzD3zw
# 12   https://www.yelp.com/biz/euphorium-bakery-lond...  zjX_19K5wWXcdD3ZruZizg
# 13   https://www.yelp.com/biz/rinkoff-bakeries-lond...  8tsGkeT6Z9EhT8UvBzVtWw
# 14
# 15
# 16   https://www.yelp.com/biz/poilane-london-2?adju...  3AXQMV-Yirhfq4oQHry6tA
# 17   https://www.yelp.com/biz/aux-pains-de-papy-lon...  wh4R2zTxcjZw4JcQFNBtog
# 18   https://www.yelp.com/biz/little-bread-pedlar-l...  klqP4NUFEl9kA6DIyRHpjA
# 19
# 20   https://www.yelp.com/biz/le-pain-quotidien-lon...  qH-kupTBzRj5lvgaS9xzTA
# 21   https://www.yelp.com/biz/ottolenghi-london-2?a...  kAgxFPCeNiZeiKc9POkiOg
# 22   https://www.yelp.com/biz/nordic-bakery-london?...  Sh_PrXavTAk2d5jTs_onuQ
# 23   https://www.yelp.com/biz/laveli-bakery-london?...  S--3Zg6kT54JETDh_qym7A
# 24   https://www.yelp.com/biz/p%C3%A2tisserie-deux-...  7TETeEdYvewlhdjmMSwLdg
# 25   https://www.yelp.com/biz/beigel-bake-london?ad...  CrQcYS4nWWdXmSD1pxf_KA
# 26   https://www.yelp.com/biz/the-bread-station-lon...  qmvTW4c9KGAcykHa9szLUg
# 27
# 28   https://www.yelp.com/biz/amouls-london?adjust_...  hLg5fxKmxMP5y7LJTtPSmg
# 29
# ..                                                 ...                     ...
# 94   https://www.yelp.com/biz/richoux-london-2?adju...  AKhm8Oc4qVGobeQ555DuxQ
# 95
# 96   https://www.yelp.com/biz/the-upholstery-house-...  YZrJSNqEI-m9mWwlm3ES7g
# 97
# 98   https://www.yelp.com/biz/couch-potato-company-...  Fm4j-XbPqYQxA3kXyl1WAg
# 99   https://www.yelp.com/biz/morbleu-london-4?adju...  GcKhWyZQaaIC12g_g-lyBw
# 100  https://www.yelp.com/biz/lombok-london-2?adjus...  2SWn7n-K0bMFLNh4X7rjHg
# 101  https://www.yelp.com/biz/boconcept-uk-london?a...  3BrqzKn6uzAeOQ4I8ZJZ2g
# 102  https://www.yelp.com/biz/planet-organic-london...  pTzAvHQQ-eJqp8fcZ8F_wQ
# 103  https://www.yelp.com/biz/tiger-london?adjust_c...  djtPa63TXwDKqNVh0wwJXQ
# 104  https://www.yelp.com/biz/caffe-concerto-london...  R4hVXyqA---r5TjKgvVHOg
# 105  https://www.yelp.com/biz/caffe-concerto-kensin...  B__B6RPZjC0bv2bFKcIJ3g
# 106  https://www.yelp.com/biz/covent-garden-grind-l...  sTjZJB20joSHE8oVPHs1Cw
# 107  https://www.yelp.com/biz/ginger-pig-london?adj...  LcrHcZj1tEQrwhJMPsBEjQ
# 108  https://www.yelp.com/biz/ole-and-steen-london-...  5or4AzNouZq8RClNeTdqiA
# 109  https://www.yelp.com/biz/the-patisserie-london...  BDExDQzpmMyeeroGvGmOOQ
# 110  https://www.yelp.com/biz/patisserie-valerie-lo...  Kfz7NwTNSztX4pgXLSmUaw
# 111  https://www.yelp.com/biz/albion-london-5?adjus...  4QK1kQOde5RZ6PNTfo7wug
# 112  https://www.yelp.com/biz/danish-patisserie-lon...  qnMS_VFY-JC9w90mU8EQow
# 113  https://www.yelp.com/biz/patisserie-valerie-lo...  Z3dr4as9zDncGnaCtqnntQ
# 114  https://www.yelp.com/biz/patisserie-valerie-lo...  dSEoONOM7wGmNYGm6pq4kw
# 115  https://www.yelp.com/biz/the-castle-london-7?a...  nKaf4AKaZ2fwuHIpHbSeww
# 116  https://www.yelp.com/biz/pickles-london-2?adju...  HaUEkzqd8ahjouFlhvq1tQ
# 117  https://www.yelp.com/biz/the-sandwich-centre-l...  zYUCY6y7RqC7GB0xPAZZNg
# 118  https://www.yelp.com/biz/pret-a-manger-london-...  QdJBB4oxg2U25g2PzpaGFA
# 119  https://www.yelp.com/biz/lite-bite-london?adju...  tbzentkM8HGfavVML6l8gA
# 120  https://www.yelp.com/biz/lisas-london-2?adjust...  X_1Z-RAonaFLaTjkdKBljA
# 121
# 122  https://www.yelp.com/biz/snaps-and-rye-london?...  CvYiWzRJ_xBXBcXm6QLYyw
# 123  https://www.yelp.com/biz/bageriet-london?adjus...  0tJs57Xoq75-RDWKVco0nw
#
# [124 rows x 9 columns]

# %%
# Save the dataframe to a csv file
london_restaurants_df.to_csv('Resources/London_Restaurants_Danish.csv')
