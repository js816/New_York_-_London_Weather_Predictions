# %% [markdown]
# LONDON RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
lndr_params1 = {"term":"German","location":"London","limit":50,"offset":0}
lndr_response1 = requests.get(search_api_url, headers=headers, params=lndr_params1)
lndr1 = lndr_response1.json()
display(lndr1)
#print(lndr_response1.url)
#print(lndr_response1.status_code)
# Out:
# {'businesses': [{'id': 'EFwQyq_qSoL_3A2oQWL6Ig',
#    'alias': 'bierschenke-london',
#    'name': 'Bierschenke',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sGzMdgGIaKXrhgy2AxZMcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bierschenke-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5172964975816,
#     'longitude': -0.0852677978367637},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 London Wall Buildings',
#     'address2': 'Blomfield Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2M 5NT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 London Wall Buildings',
#      'Blomfield Street',
#      'London EC2M 5NT',
#      'United Kingdom']},
#    'phone': '+442071002500',
#    'display_phone': '+44 20 7100 2500',
#    'distance': 3542.385863708519},
#   {'id': 'UdFNcwNbwVJ7qNdDXYd_PA',
#    'alias': 'herman-ze-german-london',
#    'name': 'Herman Ze German',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ihuIc-ESzJtO7NVYqkMg8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/herman-ze-german-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 100,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.508297609923,
#     'longitude': -0.12397418784664},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '19 Villiers Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 6NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Villiers Street',
#      'London WC2N 6NE',
#      'United Kingdom']},
#    'phone': '+442079304827',
#    'display_phone': '+44 20 7930 4827',
#    'distance': 970.6457866246815},
#   {'id': '4IpNjfnu3VnM8p7_i4or4Q',
#    'alias': 'german-gymnasium-london-2',
#    'name': 'German Gymnasium',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TmJEnHXlhw3juq9561WDQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/german-gymnasium-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 52,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5323975443626,
#     'longitude': -0.125419827905187},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1 Kings Boulevard',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Kings Boulevard',
#      'London N1C 4AG',
#      'United Kingdom']},
#    'phone': '+442072878000',
#    'display_phone': '+44 20 7287 8000',
#    'distance': 2294.086392187214},
#   {'id': 'apqNvjbaB20wozywrLNPiQ',
#    'alias': 'fischers-london',
#    'name': "Fischer's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/A68yx91bh-81NvBKkMXVCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fischers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'austrian', 'title': 'Austrian'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5216155579831,
#     'longitude': -0.151699820819173},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '50 Marylebone High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 5HN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50 Marylebone High Street',
#      'London W1U 5HN',
#      'United Kingdom']},
#    'phone': '+442074665501',
#    'display_phone': '+44 20 7466 5501',
#    'distance': 1462.850471845834},
#   {'id': 'sen5D3KKE0penBC7d5GlUQ',
#    'alias': 'zeitgeist-london-3',
#    'name': 'Zeitgeist',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zuld2QQENVx6CJmJ36AWSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zeitgeist-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.491333, 'longitude': -0.1182021},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '49 - 51 Black Prince Road',
#     'address2': 'Lambeth',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE11 6AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 - 51 Black Prince Road',
#      'Lambeth',
#      'London SE11 6AB',
#      'United Kingdom']},
#    'phone': '+442078400426',
#    'display_phone': '+44 20 7840 0426',
#    'distance': 2684.618353612666},
#   {'id': 'GXGXX8Eapy5yBpLTx-N1kw',
#    'alias': 'munich-cricket-club-london-3',
#    'name': 'Munich Cricket Club',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_3TswQ46hIQxri5qJvMl0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/munich-cricket-club-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4980721, 'longitude': -0.1325256},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Abbey Orchard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 2LU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Abbey Orchard Street',
#      'London SW1P 2LU',
#      'United Kingdom']},
#    'phone': '+442072228972',
#    'display_phone': '+44 20 7222 8972',
#    'distance': 1658.6942639754977},
#   {'id': 'jcBeMcH_nAaDDJotomqs-g',
#    'alias': 'katzenjammers-london',
#    'name': 'Katzenjammers',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Wam1D3XSLBf1uOjRuXOh_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/katzenjammers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.504827352652,
#     'longitude': -0.0910319201774978},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '24 Southwark Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1TY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Southwark Street',
#      'London SE1 1TY',
#      'United Kingdom']},
#    'phone': '+447771363542',
#    'display_phone': '+44 7771 363542',
#    'distance': 3234.0535001935},
#   {'id': 'o7PM_2GI50-9mlhQ_0WqyA',
#    'alias': 'the-wurst-club-london',
#    'name': 'The Wurst Club',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YXOcrYMlAk77PQL91S25TQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wurst-club-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.513202, 'longitude': -0.084998},
#    'transactions': [],
#    'location': {'address1': '56-57 Cornhill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3V 3PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['56-57 Cornhill',
#      'London EC3V 3PD',
#      'United Kingdom']},
#    'phone': '+442072838008',
#    'display_phone': '+44 20 7283 8008',
#    'distance': 3527.392606845823},
#   {'id': 'Zf6FbXwsCKxSpBLql9l_9Q',
#    'alias': 'herman-ze-german-london-4',
#    'name': 'Herman Ze German',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GI-9oMbK1c1i8XTftugpOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/herman-ze-german-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5191705290611,
#     'longitude': -0.135596556276787},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '43 Charlotte Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 2NW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['43 Charlotte Street',
#      'London W1T 2NW',
#      'United Kingdom']},
#    'phone': '+442073239207',
#    'display_phone': '+44 20 7323 9207',
#    'distance': 704.858455490402},
#   {'id': 'CoOXb3OMOuMnOEatF62LiQ',
#    'alias': 'steins-kingston-upon-thames',
#    'name': "Stein's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VkQ5OpRyhL2auQbsUE6szw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/steins-kingston-upon-thames?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.407239, 'longitude': -0.308125},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '56 High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Kingston Upon Thames',
#     'zip_code': 'KT1 1HN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['56 High Street',
#      'Kingston Upon Thames KT1 1HN',
#      'United Kingdom']},
#    'phone': '+442085462411',
#    'display_phone': '+44 20 8546 2411',
#    'distance': 16740.459370749977},
#   {'id': 'QTRkMjYHXAVROidXkkt7Ow',
#    'alias': 'the-delaunay-london-3',
#    'name': 'The Delaunay',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zz7VMc8u_hhSOuIphETZLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-delaunay-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 118,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5131115, 'longitude': -0.1182553},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '55 Aldwych',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 4BB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55 Aldwych', 'London WC2B 4BB', 'United Kingdom']},
#    'phone': '+442074998558',
#    'display_phone': '+44 20 7499 8558',
#    'distance': 1233.9810795843225},
#   {'id': '2vgpyvU72DEHiLRYmSE1FQ',
#    'alias': 'herman-ze-german-london-3',
#    'name': 'Herman Ze German',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/y1gCQFgTD2X8RAB5Tc1c_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/herman-ze-german-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.513273, 'longitude': -0.131731},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '33 Old Compton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 5JU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['33 Old Compton Street',
#      'London W1D 5JU',
#      'United Kingdom']},
#    'phone': '+442077340431',
#    'display_phone': '+44 20 7734 0431',
#    'distance': 296.37866942693194},
#   {'id': 'xqpUr61KFa1Xx721-E6l_A',
#    'alias': 'kipferl-london-6',
#    'name': 'Kipferl',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CUoYGTlW1CYS-nJ5vAUGPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kipferl-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'austrian', 'title': 'Austrian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.535247538411,
#     'longitude': -0.10339315152949},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Camden Passage',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Camden Passage',
#      'London N1 8ED',
#      'United Kingdom']},
#    'phone': '+442077041555',
#    'display_phone': '+44 20 7704 1555',
#    'distance': 3359.4222431551457},
#   {'id': '5puz_aDYRkQ-Ur45ceZy9A',
#    'alias': 'world-of-wurst-london',
#    'name': 'World of Wurst',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FXc3SEDHdr3bo23dMN3r-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/world-of-wurst-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4634005, 'longitude': -0.1110494},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '49 Brixton Station Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 8PQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Brixton Station Road',
#      'London SW9 8PQ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5739.665567173421},
#   {'id': 'ZQ83yqyl8qsySQtzssuh0g',
#    'alias': 'german-doner-kebab-london',
#    'name': 'German Doner Kebab',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MDZkA6C7WULfk1lcIQcOyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/german-doner-kebab-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'german', 'title': 'German'},
#     {'alias': 'kebab', 'title': 'Kebab'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5108062940712,
#     'longitude': -0.320996134946345},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '24 Broadway',
#     'address2': 'West Ealing',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W13 0SU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Broadway',
#      'West Ealing',
#      'London W13 0SU',
#      'United Kingdom']},
#    'phone': '+442085795246',
#    'display_phone': '+44 20 8579 5246',
#    'distance': 12807.225859281436},
#   {'id': 'wba5ChSu7cstA-sJEoOSYg',
#    'alias': 'german-food-london',
#    'name': 'German Food',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dxIcQQ19q00MME-JVRKB8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/german-food-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5154729584454,
#     'longitude': -0.204620361328125},
#    'transactions': [],
#    'location': {'address1': 'Portobello Road Market',
#     'address2': 'Stall 59 Portobello Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 1AN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Portobello Road Market',
#      'Stall 59 Portobello Road',
#      'London W11 1AN',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4760.5525830091065},
#   {'id': 'Ztez_cQAGM1-37QvYaqY_Q',
#    'alias': 'tiger-tiger-london',
#    'name': 'Tiger Tiger',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Tgzy4peKXH_eqKtzK8EVjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tiger-tiger-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 122,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.5096445, 'longitude': -0.1325555},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Haymarket House',
#     'address2': '28-29 Haymarket',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 4SP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Haymarket House',
#      '28-29 Haymarket',
#      'London SW1Y 4SP',
#      'United Kingdom']},
#    'phone': '+442079301885',
#    'display_phone': '+44 20 7930 1885',
#    'distance': 421.29548917698594},
#   {'id': 'JiXzJ68Q7wM8E9mf7UItKQ',
#    'alias': 'german-doner-kebab-london-2',
#    'name': 'German Doner Kebab',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wCOwhXfP2gNWY1NKRJ5rOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/german-doner-kebab-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5323937, 'longitude': -0.1064983},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '11A Islington High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9LQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11A Islington High Street',
#      'London N1 9LQ',
#      'United Kingdom']},
#    'phone': '+442078377876',
#    'display_phone': '+44 20 7837 7876',
#    'distance': 2980.479250227467},
#   {'id': 'RQxZlkXAAiDA6KNmvThi5w',
#    'alias': 'hansel-and-pretzel-london',
#    'name': 'Hansel & Pretzel',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hansel-and-pretzel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'german', 'title': 'German'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4384193, 'longitude': -0.3134942},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '71 Ham Street',
#     'address2': 'Ham',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'TW10 7UD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['71 Ham Street',
#      'Ham',
#      'London TW10 7UD',
#      'United Kingdom']},
#    'phone': '+442083321916',
#    'display_phone': '+44 20 8332 1916',
#    'distance': 14825.29350775577},
#   {'id': 'KuwUTzRwJDT2XBfowo6hTQ',
#    'alias': 'camden-town-brewery-london-2',
#    'name': 'Camden Town Brewery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8-LODjpI5S7ggUF6SAKA1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camden-town-brewery-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'breweries', 'title': 'Breweries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5468318969433,
#     'longitude': -0.146872169040243},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '55-59 Wilkin Street Mews',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW5',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55-59 Wilkin Street Mews',
#      'London NW5',
#      'United Kingdom']},
#    'phone': '+442074851671',
#    'display_phone': '+44 20 7485 1671',
#    'distance': 3854.9061951335702},
#   {'id': 'fdwAAs9cm_uLkgxXedYh3w',
#    'alias': 'baltic-bar-and-restaurant-london',
#    'name': 'Baltic Bar and Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Th3235Hk9AlSXVsMlC9XSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baltic-bar-and-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 68,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'polish', 'title': 'Polish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.503466, 'longitude': -0.104866},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '74 Blackfriars Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['74 Blackfriars Road',
#      'London SE1 8HA',
#      'United Kingdom']},
#    'phone': '+442079281111',
#    'display_phone': '+44 20 7928 1111',
#    'distance': 2390.6260048944155},
#   {'id': 'CWYCCZkND7MEsOZH6C3jAg',
#    'alias': 'social-eating-house-london-2',
#    'name': 'Social Eating House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hIyL1b22NC8KsGz-82kDdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/social-eating-house-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 93,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5136727, 'longitude': -0.1363879},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '58 Poland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7NS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['58 Poland Street',
#      'London W1F 7NS',
#      'United Kingdom']},
#    'phone': '+442079933251',
#    'display_phone': '+44 20 7993 3251',
#    'distance': 97.77416732581322},
#   {'id': 'Nv63I1hKZpqtKUwJgV2FYw',
#    'alias': 'the-monkey-puzzle-london',
#    'name': 'The Monkey Puzzle',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-Wz6mShH7W9n3rOOl_NxeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-monkey-puzzle-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5164243625465,
#     'longitude': -0.169808305799961},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '30 Southwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1JQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Southwick Street',
#      'London W2 1JQ',
#      'United Kingdom']},
#    'phone': '+442077230143',
#    'display_phone': '+44 20 7723 0143',
#    'distance': 2376.2784719424735},
#   {'id': 'VgZY9s-K6352TxW-mVKUfw',
#    'alias': 'octoberfest-pub-london',
#    'name': 'Octoberfest Pub',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fXPv_z0RdRURLE7D1wClSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/octoberfest-pub-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.4746953, 'longitude': -0.2068198},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '678-680 Fulham Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 5SA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['678-680 Fulham Road',
#      'London SW6 5SA',
#      'United Kingdom']},
#    'phone': '+442077365293',
#    'display_phone': '+44 20 7736 5293',
#    'distance': 6484.8995491315045},
#   {'id': 'NsW-FrgdMkt41DfhtZlYtA',
#    'alias': 'the-carpenters-arms-london-2',
#    'name': 'The Carpenters Arms',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fhSgS4MXs_wvoFwquPGDcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-carpenters-arms-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.523959386643,
#     'longitude': -0.067309584978472},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '73 Cheshire Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 6EG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['73 Cheshire Street',
#      'London E2 6EG',
#      'United Kingdom']},
#    'phone': '+442077396342',
#    'display_phone': '+44 20 7739 6342',
#    'distance': 4908.213735114037},
#   {'id': 'NQ9I7dhtMzS69wNTGZmyUQ',
#    'alias': 'work-kitchen-hemel-hempstead',
#    'name': 'Work Kitchen',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/work-kitchen-hemel-hempstead?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.76606, 'longitude': -0.434941},
#    'transactions': [],
#    'location': {'address1': 'Maxted Road',
#     'address2': 'Maylands Industrial Estate',
#     'address3': '',
#     'city': 'Hemel Hempstead',
#     'zip_code': 'HP2 7DX',
#     'country': 'GB',
#     'state': 'HRT',
#     'display_address': ['Maxted Road',
#      'Maylands Industrial Estate',
#      'Hemel Hempstead HP2 7DX',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 35127.702694035535},
#   {'id': 'pOnkBNgFreS7QzKZXXV3jA',
#    'alias': 'the-portman-london',
#    'name': 'The Portman',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zEMYATE1Ul51acGAA3QLnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-portman-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5152469791282,
#     'longitude': -0.161370500226781},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '51 Upper Berkeley Street',
#     'address2': 'Marylebone',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7QW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Upper Berkeley Street',
#      'Marylebone',
#      'London W1H 7QW',
#      'United Kingdom']},
#    'phone': '+442077238996',
#    'display_phone': '+44 20 7723 8996',
#    'distance': 1778.9968273370253},
#   {'id': 'rvgaw--mJ2NZoGfrb_t9Qg',
#    'alias': 'zetland-arms-london',
#    'name': 'Zetland Arms',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SiOIkbqZ4UoCnWme4PFiXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zetland-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.4933447535418,
#     'longitude': -0.175905324689021},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Bute Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3EX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Bute Street', 'London SW7 3EX', 'United Kingdom']},
#    'phone': '+442075893813',
#    'display_phone': '+44 20 7589 3813',
#    'distance': 3513.2650321105552},
#   {'id': 'O6PWDbK6H9MQmrDfAAoJng',
#    'alias': 'wild-honey-london',
#    'name': 'Wild Honey',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/W2eG0NcywyULbPKbRoOQOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wild-honey-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 71,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5074559, 'longitude': -0.1321665},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '8 Pall Mall',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 5NG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Pall Mall', 'London SW1Y 5NG', 'United Kingdom']},
#    'phone': '+442077589160',
#    'display_phone': '+44 20 7758 9160',
#    'distance': 653.1429975219093},
#   {'id': 'X-fad8Xp37BNRczsxjHTeA',
#    'alias': 'the-old-brewery-london',
#    'name': 'The Old Brewery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hOGZ1rrhZDobP_eQSK5vyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-old-brewery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4829321623981,
#     'longitude': -0.00824511051177979},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'The Pepys Building',
#     'address2': 'The Old Royal Naval College',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE10 9LW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Pepys Building',
#      'The Old Royal Naval College',
#      'London SE10 9LW',
#      'United Kingdom']},
#    'phone': '+442034372222',
#    'display_phone': '+44 20 3437 2222',
#    'distance': 9445.230112330042},
#   {'id': 'FJs1PrhFMFVL_iMcH69VuQ',
#    'alias': 'the-grenadier-london',
#    'name': 'The Grenadier',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yvn70RKEt4QFqJp6MfeluA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grenadier-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 188,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.501462, 'longitude': -0.155004},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18 Wilton Row',
#     'address2': '',
#     'address3': 'Belgravia',
#     'city': 'London',
#     'zip_code': 'SW1X 7NR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Wilton Row',
#      'Belgravia',
#      'London SW1X 7NR',
#      'United Kingdom']},
#    'phone': '+442072353074',
#    'display_phone': '+44 20 7235 3074',
#    'distance': 1826.8454804863936},
#   {'id': 'zs86cdpXWDzS33aogi89pw',
#    'alias': 'the-rose-and-crown-london-3',
#    'name': 'The Rose and Crown',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7xdK3V_KnUGMziAsHcOebg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-rose-and-crown-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.463751442705,
#     'longitude': -0.14128651701909},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 The Polygon',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW4 0JG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 The Polygon', 'London SW4 0JG', 'United Kingdom']},
#    'phone': '+442077208265',
#    'display_phone': '+44 20 7720 8265',
#    'distance': 5470.359954289019},
#   {'id': 'QFOUxTcxG3tB9HyxvfU1FA',
#    'alias': 'vinoteca-london',
#    'name': 'Vinoteca',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Js05toclN6pen1N2jlfWYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vinoteca-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.520121, 'longitude': -0.101915},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '7 St John Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1M 4AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 St John Street',
#      'London EC1M 4AA',
#      'United Kingdom']},
#    'phone': '+442072538786',
#    'display_phone': '+44 20 7253 8786',
#    'distance': 2490.8823586808176},
#   {'id': '5o8lm4tCTGgZfH0N4QAgMg',
#    'alias': 'cask-pub-and-kitchen-london-2',
#    'name': 'CASK Pub and Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ntmuMfLZr0WOVoqNXUqW6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cask-pub-and-kitchen-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 139,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.49135039773, 'longitude': -0.13753688795203},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 Charlwood Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 2EE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Charlwood Street',
#      'London SW1V 2EE',
#      'United Kingdom']},
#    'phone': '+442076307225',
#    'display_phone': '+44 20 7630 7225',
#    'distance': 2391.5393462801244},
#   {'id': 'bRlAMHrc5d_HYzlesl7Epw',
#    'alias': 'the-fitzroy-tavern-london',
#    'name': 'The Fitzroy Tavern',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gIvABOUNSvukhYXW1umeHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-fitzroy-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5185617814394,
#     'longitude': -0.134738874084618},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '16 Charlotte Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 2NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Charlotte Street',
#      'London W1T 2NA',
#      'United Kingdom']},
#    'phone': '+442075803714',
#    'display_phone': '+44 20 7580 3714',
#    'distance': 642.2745006289289},
#   {'id': 'EFpGMzFyjVNgEyqa_j-m_A',
#    'alias': 'the-peahen-st-albans-2',
#    'name': 'The Peahen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zs10s2cTkkrRdeRZuTJ3bw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-peahen-st-albans-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.7507088, 'longitude': -0.339535},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 London Road',
#     'address2': '',
#     'address3': '',
#     'city': 'St Albans',
#     'zip_code': 'AL1 1NG',
#     'country': 'GB',
#     'state': 'HRT',
#     'display_address': ['14 London Road',
#      'St Albans AL1 1NG',
#      'United Kingdom']},
#    'phone': '+441727853669',
#    'display_phone': '+44 1727 853669',
#    'distance': 29937.649709845984},
#   {'id': '4BxxZPDBbrIg9egm-r8FXg',
#    'alias': 'czechoslovak-national-house-club-and-restaurant-london',
#    'name': 'Czechoslovak National House Club & Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/s9c6X0nCwRaziIUcAHB-Iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/czechoslovak-national-house-club-and-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'czech', 'title': 'Czech'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5445546, 'longitude': -0.1921988},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '74 W End Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 2LX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['74 W End Lane', 'London NW6 2LX', 'United Kingdom']},
#    'phone': '+442073721193',
#    'display_phone': '+44 20 7372 1193',
#    'distance': 5241.810882230616},
#   {'id': 'yFaZL5ndSiQO1qRcumM6Cg',
#    'alias': 'the-white-hart-london-5',
#    'name': 'The White Hart',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/v-4AMgTcHy0p0kOwkOz7gA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-white-hart-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 69,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.504794060355,
#     'longitude': -0.11069307491512},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '29 Cornwall Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8TJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['29 Cornwall Road',
#      'London SE1 8TJ',
#      'United Kingdom']},
#    'phone': '+442079289190',
#    'display_phone': '+44 20 7928 9190',
#    'distance': 1963.744905321},
#   {'id': 'GyK15muNSx4rJ155l4-2Ag',
#    'alias': 'earl-of-essex-london',
#    'name': 'Earl of Essex',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yAOEnZqDDmTJvy2H-8NCsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/earl-of-essex-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5339046, 'longitude': -0.0996945},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '25 Danbury Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8LE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['25 Danbury Street',
#      'London N1 8LE',
#      'United Kingdom']},
#    'phone': '+442074245828',
#    'display_phone': '+44 20 7424 5828',
#    'distance': 3429.9449916991935},
#   {'id': 'lVn3qBXylytx6BxrTzCpLQ',
#    'alias': 'the-chandos-london',
#    'name': 'The Chandos',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Clk3rjykKlojgJzv5motqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-chandos-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 151,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.509588, 'longitude': -0.126792},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "29 Saint Martin's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["29 Saint Martin's Lane",
#      'London WC2N 4ER',
#      'United Kingdom']},
#    'phone': '+442078361401',
#    'display_phone': '+44 20 7836 1401',
#    'distance': 729.771036358222},
#   {'id': '4-XTDzMijxlATEnCQMvOJQ',
#    'alias': 'jerusalem-tavern-london',
#    'name': 'Jerusalem Tavern',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/b7xMT1wQFRHCbwPbs8GgOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jerusalem-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.521759651743,
#     'longitude': -0.10411592018887},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '55 Britton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1M 5UQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55 Britton Street',
#      'London EC1M 5UQ',
#      'United Kingdom']},
#    'phone': '+442074904281',
#    'display_phone': '+44 20 7490 4281',
#    'distance': 2416.2964023140485},
#   {'id': 'DpWAtyCrLeit4RHbHoI2Tw',
#    'alias': 'round-table-london',
#    'name': 'Round Table',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5puZIykhTyC0WKtYqpnVsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/round-table-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.510887, 'longitude': -0.127927},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '26-27 St Martins Court',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26-27 St Martins Court',
#      'London WC2N 4AJ',
#      'United Kingdom']},
#    'phone': '+442078366436',
#    'display_phone': '+44 20 7836 6436',
#    'distance': 596.3635249596229},
#   {'id': 'aA79oNXSvGKc0xfTTp0yrA',
#    'alias': 'the-horseshoe-london-3',
#    'name': 'The Horseshoe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vPyBgdLOdWBOUB4eCxvN8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-horseshoe-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'breweries', 'title': 'Breweries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5560201, 'longitude': -0.1785851},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '28 Heath Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 6TE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28 Heath Street',
#      'London NW3 6TE',
#      'United Kingdom']},
#    'phone': '+442074317206',
#    'display_phone': '+44 20 7431 7206',
#    'distance': 5624.956716108426},
#   {'id': 'zOLPCLptUE2UKRXYWCEHvg',
#    'alias': 'the-modern-pantry-london',
#    'name': 'The Modern Pantry',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xCCsKLYTjFB2it91U1ntmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-modern-pantry-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 145,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5230301121618,
#     'longitude': -0.103575187145258},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "47-48 St John's Square",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 4JJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["47-48 St John's Square",
#      'London EC1V 4JJ',
#      'United Kingdom']},
#    'phone': '+442075539210',
#    'display_phone': '+44 20 7553 9210',
#    'distance': 2510.962821457009},
#   {'id': 'b6djyRDnsN_iX-X8i5wQWg',
#    'alias': 'the-forest-hill-hotel-london',
#    'name': 'The Forest Hill Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wCXmbIqlPTUBgP6mMH2Bcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-forest-hill-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 51.441477, 'longitude': -0.0514108},
#    'transactions': [],
#    'location': {'address1': '41 Stanstead Road',
#     'address2': 'Forest Hill',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE23 1HG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41 Stanstead Road',
#      'Forest Hill',
#      'London SE23 1HG',
#      'United Kingdom']},
#    'phone': '+442086990677',
#    'display_phone': '+44 20 8699 0677',
#    'distance': 9861.157054798336},
#   {'id': '_faDmrUFilwMxk0atkXjNA',
#    'alias': 'the-dove-london-3',
#    'name': 'The Dove',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/e4-NZ4Ue4Fg45Xp3GAABcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dove-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'belgian', 'title': 'Belgian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5363390811417,
#     'longitude': -0.0618530896556768},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '24-26 Broadway Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 4QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24-26 Broadway Market',
#      'London E8 4QJ',
#      'United Kingdom']},
#    'phone': '+442072757617',
#    'display_phone': '+44 20 7275 7617',
#    'distance': 5754.37208734647},
#   {'id': 'ivaTPZkgXISZME4LS6KWZQ',
#    'alias': 'the-wheatsheaf-london-6',
#    'name': 'The Wheatsheaf',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/f8sQ4Hy5Rw7G1rvXidecwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wheatsheaf-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.504901, 'longitude': -0.091051},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '24 Southwark Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1TY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Southwark Street',
#      'London SE1 1TY',
#      'United Kingdom']},
#    'phone': '+442074079934',
#    'display_phone': '+44 20 7407 9934',
#    'distance': 3208.7070333597976},
#   {'id': 'P-lfeLq93Bo6KQb5CnWIZw',
#    'alias': 'the-gun-london-2',
#    'name': 'The Gun',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/X60ebgCzVCkqMVZ8G1WGig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-gun-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5017821676253,
#     'longitude': -0.00774186701236745},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '27 Coldharbour',
#     'address2': 'Docklands',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E14 9NS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['27 Coldharbour',
#      'Docklands',
#      'London E14 9NS',
#      'United Kingdom']},
#    'phone': '+442075155222',
#    'display_phone': '+44 20 7515 5222',
#    'distance': 8958.309757042443},
#   {'id': '4bzGqKQMrTUAhB84SKy83w',
#    'alias': 'the-ordnance-london',
#    'name': 'The Ordnance',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wOglfHDVn5_GPDqe9lrlHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ordnance-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5357005, 'longitude': -0.1713083},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '29 Ordnance Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 6PS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['29 Ordnance Hill',
#      'London NW8 6PS',
#      'United Kingdom']},
#    'phone': '+442077220278',
#    'display_phone': '+44 20 7722 0278',
#    'distance': 3545.873700919653},
#   {'id': '2CGxJgOhR0Z-fK4E69artA',
#    'alias': 'the-coach-and-horses-london-2',
#    'name': 'The Coach and Horses',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aqLMi8V0J5SrHe46khcLcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-coach-and-horses-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.45974, 'longitude': -0.131395},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '173-175 Clapham Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW4 7EX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['173-175 Clapham Park Road',
#      'London SW4 7EX',
#      'United Kingdom']},
#    'phone': '+442074986308',
#    'display_phone': '+44 20 7498 6308',
#    'distance': 5912.385804712793}],
#  'total': 115,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#          Restaurant      Type Price Rating                    Address  \
# 0       Bierschenke    German    ££      4    4 London Wall Buildings
# 1  Herman Ze German    German     £      4         19 Villiers Street
# 2  German Gymnasium    German   £££      4          1 Kings Boulevard
# 3         Fischer's  Austrian   £££      4  50 Marylebone High Street
# 4         Zeitgeist    German    ££      4  49 - 51 Black Prince Road
#
#          Lat       Lng                                                url  \
# 0  51.517296 -0.085268  https://www.yelp.com/biz/bierschenke-london?ad...
# 1  51.508298 -0.123974  https://www.yelp.com/biz/herman-ze-german-lond...
# 2  51.532398 -0.125420  https://www.yelp.com/biz/german-gymnasium-lond...
# 3  51.521616 -0.151700  https://www.yelp.com/biz/fischers-london?adjus...
# 4  51.491333 -0.118202  https://www.yelp.com/biz/zeitgeist-london-3?ad...
#
#                        ID
# 0  EFwQyq_qSoL_3A2oQWL6Ig
# 1  UdFNcwNbwVJ7qNdDXYd_PA
# 2  4IpNjfnu3VnM8p7_i4or4Q
# 3  apqNvjbaB20wozywrLNPiQ
# 4  sen5D3KKE0penBC7d5GlUQ

# %%
#2nd set of 50 records 51-100 
lndr_params2 = {"term":"German","location":"London","limit":50,"offset":51}
lndr_response2 = requests.get(search_api_url, headers=headers, params=lndr_params2)
lndr2 = lndr_response2.json()
display(lndr2)
#print(lndr_response2.url)
#print(lndr_response2.status_code)
# Out:
# {'businesses': [{'id': 'ys0CRv-iRRySKs2l-vIOxg',
#    'alias': 'ye-old-white-horse-holborn',
#    'name': 'Ye Old White Horse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nUDUxgBCGIAFg7biRaTmUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ye-old-white-horse-holborn?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51473, 'longitude': -0.117203},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '2 St Clements Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'Holborn',
#     'zip_code': 'WC2A 2HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 St Clements Lane',
#      'Holborn WC2A 2HA',
#      'United Kingdom']},
#    'phone': '+442072425518',
#    'display_phone': '+44 20 7242 5518',
#    'distance': 1312.561104570272},
#   {'id': 'jFn8bNvKKck9IbkWWWgKFA',
#    'alias': 'millers-london',
#    'name': 'Millers',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LQFK1kIRUQQk8aAPegiudA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/millers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5316571115579,
#     'longitude': -0.121054802122433},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '19 Caledonian Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9DX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Caledonian Road',
#      'London N1 9DX',
#      'United Kingdom']},
#    'phone': '+442078374863',
#    'display_phone': '+44 20 7837 4863',
#    'distance': 2333.009590449386},
#   {'id': 'siT3_BKKzurJ2S0Y_BWbLQ',
#    'alias': 'draft-house-london',
#    'name': 'Draft House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jgMfPB4PwFzXt579NSE-eA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/draft-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.457455384358,
#     'longitude': -0.16599480425884},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '94 Northcote Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW11 6QW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['94 Northcote Road',
#      'London SW11 6QW',
#      'United Kingdom']},
#    'phone': '+442079241814',
#    'display_phone': '+44 20 7924 1814',
#    'distance': 6499.777716424107},
#   {'id': 'xQFwpDaButTd9Yf18L9Dyg',
#    'alias': 'crown-and-two-chairmen-london',
#    'name': 'Crown & Two Chairmen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/e2e04GmvlC36qqx1Nh3rtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crown-and-two-chairmen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5138322646467,
#     'longitude': -0.132497728333694},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '31-32 Dean Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 3SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['31-32 Dean Street',
#      'London W1D 3SB',
#      'United Kingdom']},
#    'phone': '+442074378192',
#    'display_phone': '+44 20 7437 8192',
#    'distance': 263.72005160549895},
#   {'id': 'I00ahdNmf_KUH-0FbDkrOQ',
#    'alias': 'the-salisbury-hotel-london',
#    'name': 'The Salisbury Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DEyjus8E5Iy2-HBNGXijqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-salisbury-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5821099309491,
#     'longitude': -0.0997781753540039},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Grand Parade',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N4 1JX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Grand Parade', 'London N4 1JX', 'United Kingdom']},
#    'phone': '+442088009617',
#    'display_phone': '+44 20 8800 9617',
#    'distance': 8098.988077805639},
#   {'id': '4m2-sWOvdCqjQ05lH6uy4Q',
#    'alias': 'museum-tavern-bloomsbury',
#    'name': 'Museum Tavern',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dkr0SyJ3rld7imJWCIexLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/museum-tavern-bloomsbury?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5182144172415,
#     'longitude': -0.125971101400664},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '49 Great Russell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Bloomsbury',
#     'zip_code': 'WC1B 3BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Great Russell Street',
#      'Bloomsbury WC1B 3BA',
#      'United Kingdom']},
#    'phone': '+442072428987',
#    'display_phone': '+44 20 7242 8987',
#    'distance': 913.8307272380717},
#   {'id': 'LtdSl2rpVynXuQxHWdTh5A',
#    'alias': 'earl-of-lonsdale-london',
#    'name': 'Earl Of Lonsdale',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aS2J2RnYLW--hcd4Py-O5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/earl-of-lonsdale-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5134898614532,
#     'longitude': -0.202847849241705},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '277-281 Westbourne Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2QA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['277-281 Westbourne Grove',
#      'London W11 2QA',
#      'United Kingdom']},
#    'phone': '+442077276335',
#    'display_phone': '+44 20 7727 6335',
#    'distance': 4629.527396375901},
#   {'id': 'SWQA_2a5HOiY9eaZmMSDaA',
#    'alias': 'the-roebuck-london-3',
#    'name': 'The Roebuck',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Nn087JmbxA5mAw5EgVrtzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-roebuck-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.498087870273,
#     'longitude': -0.090559191956849},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '50 Great Dover Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 4YG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50 Great Dover Street',
#      'London SE1 4YG',
#      'United Kingdom']},
#    'phone': '+442073577324',
#    'display_phone': '+44 20 7357 7324',
#    'distance': 3544.189730112101},
#   {'id': 'uq52voow6qazaRAFJ0ceMw',
#    'alias': 'the-greenwich-union-london',
#    'name': 'The Greenwich Union',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/N0-v397Ntye4xRU4u0CuSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-greenwich-union-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.47653480684,
#     'longitude': -0.0095805481062472},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '56 Royal Hill',
#     'address2': 'Greenwich',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE10 8RT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['56 Royal Hill',
#      'Greenwich',
#      'London SE10 8RT',
#      'United Kingdom']},
#    'phone': '+442086926258',
#    'display_phone': '+44 20 8692 6258',
#    'distance': 9635.029679658126},
#   {'id': '7L3gPAnKDPzoXo2kKJTvZA',
#    'alias': 'stormbird-london',
#    'name': 'Stormbird',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6AkW45s-dExl9dMTDOy9jQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stormbird-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4740524, 'longitude': -0.0902971},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '25 Camberwell Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE5 8TR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['25 Camberwell Church Street',
#      'London SE5 8TR',
#      'United Kingdom']},
#    'phone': '+442077084460',
#    'display_phone': '+44 20 7708 4460',
#    'distance': 5346.41397848266},
#   {'id': 'ZkkkITYlRvrmk8lBdV3g3w',
#    'alias': 'sir-richard-steele-london',
#    'name': 'Sir Richard Steele',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dQGdZHglTmLf-N8slC5bXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sir-richard-steele-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.546681, 'longitude': -0.158604},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '97 Haverstock Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 4RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['97 Haverstock Hill',
#      'London NW3 4RL',
#      'United Kingdom']},
#    'phone': '+442074831261',
#    'display_phone': '+44 20 7483 1261',
#    'distance': 4094.8871369827093},
#   {'id': 'Ymv6S0DpQyQFtBJvom-ANw',
#    'alias': 'camden-head-london',
#    'name': 'Camden Head',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xALaEeAznXqztnLEmsyEng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camden-head-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5356157, 'longitude': -0.1027805},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Camden Passage',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Camden Passage',
#      'London N1 8DY',
#      'United Kingdom']},
#    'phone': '+448712233759',
#    'display_phone': '+44 871 223 3759',
#    'distance': 3418.2104327674533},
#   {'id': '53pYlbjaaq1l8R1H53O0mQ',
#    'alias': 'the-draft-house-london-3',
#    'name': 'The Draft House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KEHxIUBzzmlMeP__tRiylA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-draft-house-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 77,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5028699547583,
#     'longitude': -0.0769468034392541},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '206-208 Tower Bridge Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 2UP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['206-208 Tower Bridge Road',
#      'London SE1 2UP',
#      'United Kingdom']},
#    'phone': '+442073789995',
#    'display_phone': '+44 20 7378 9995',
#    'distance': 4231.5898306272065},
#   {'id': 'eXNSn0FwCeSmDHDlDWzv5w',
#    'alias': 'steins-london',
#    'name': "Stein's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BVMPsMmPHU5B8ypSGTGH3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/steins-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.455546, 'longitude': -0.304016},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Richmond Towpath',
#     'address2': '55 Petersham Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'TW10 6UX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Richmond Towpath',
#      '55 Petersham Road',
#      'London TW10 6UX',
#      'United Kingdom']},
#    'phone': '+442089488189',
#    'display_phone': '+44 20 8948 8189',
#    'distance': 13266.710868756603},
#   {'id': '9qTCHY5yzNo7Vqbv4W0a6Q',
#    'alias': 'star-tavern-london',
#    'name': 'Star Tavern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Mkk2SGn8CPAtg3Tlevr7ww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/star-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4983045, 'longitude': -0.1557526},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 Belgrave Mews West',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 8HT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Belgrave Mews West',
#      'London SW1X 8HT',
#      'United Kingdom']},
#    'phone': '+442072353019',
#    'display_phone': '+44 20 7235 3019',
#    'distance': 2113.363716472156},
#   {'id': 'n_oGHFO88muDRn6vgQLjqw',
#    'alias': 'princess-louise-london-2',
#    'name': 'Princess Louise',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QE9E6yLWz7vbB9IZ2Q_Flw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/princess-louise-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 131,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.517294236118,
#     'longitude': -0.12157103373648},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '208 High Holborn',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1V 7BW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['208 High Holborn',
#      'London WC1V 7BW',
#      'United Kingdom']},
#    'phone': '+442074058816',
#    'display_phone': '+44 20 7405 8816',
#    'distance': 1112.028049897214},
#   {'id': 'i4sDNMJATBgWqjesmJTYgg',
#    'alias': 'mother-kellys-london',
#    'name': "Mother Kelly's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cvMlgjuWdbHQMzA92WBOGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mother-kellys-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5283869050483,
#     'longitude': -0.0561702696149043},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '251 Paradise Row',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 9QT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['251 Paradise Row',
#      'London E2 9QT',
#      'United Kingdom']},
#    'phone': '+442085259851',
#    'display_phone': '+44 20 8525 9851',
#    'distance': 5784.792773371582},
#   {'id': 'hqznZa5xhj32u27icNxLeA',
#    'alias': 'the-antelope-london',
#    'name': 'The Antelope',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/juaHjQfMr3aihfbrNofFpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-antelope-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4260812, 'longitude': -0.1658628},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '76 Mitcham Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW17 9NG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['76 Mitcham Road',
#      'London SW17 9NG',
#      'United Kingdom']},
#    'phone': '+442086723888',
#    'display_phone': '+44 20 8672 3888',
#    'distance': 9862.138345408246},
#   {'id': 'aAGDecm8DlOTVADNjxyXMg',
#    'alias': 'the-horse-and-groom-london-2',
#    'name': 'The Horse & Groom',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gg2vIaqHiAv1hM-Ai_T4NQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-horse-and-groom-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.519887, 'longitude': -0.1424087},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '128 Great Portland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 6PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['128 Great Portland Street',
#      'London W1W 6PX',
#      'United Kingdom']},
#    'phone': '+442075804726',
#    'display_phone': '+44 20 7580 4726',
#    'distance': 900.877125116509},
#   {'id': 'j-62V03K9x9rK4BuJa-g6A',
#    'alias': 'five-bells-streatham',
#    'name': 'Five Bells',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yhRIezouEFNpb7lUfgbpAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/five-bells-streatham?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4362876, 'longitude': -0.1280947},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '68-70 Streatham High Road',
#     'address2': '',
#     'address3': None,
#     'city': 'Streatham',
#     'zip_code': 'SW16 1DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['68-70 Streatham High Road',
#      'Streatham SW16 1DA',
#      'United Kingdom']},
#    'phone': '+442087699805',
#    'display_phone': '+44 20 8769 9805',
#    'distance': 8529.126211693476},
#   {'id': 'y__iD3k2p4Xm0Xl_tSSNZg',
#    'alias': 'holly-bush-london',
#    'name': 'Holly Bush',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/A1ESayCy7xj7xcE0p_1Pew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holly-bush-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 117,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5579124, 'longitude': -0.1793261},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Holly Mount',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 6SG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Holly Mount', 'London NW3 6SG', 'United Kingdom']},
#    'phone': '+442074352892',
#    'display_phone': '+44 20 7435 2892',
#    'distance': 5836.476390811221},
#   {'id': 'g39uJIugM2A4DBIabAcgyg',
#    'alias': 'the-jolly-gardeners-london',
#    'name': 'The Jolly Gardeners',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Bl4Xg7t4r1EBnLnclIa_MA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-jolly-gardeners-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.447003572129,
#     'longitude': -0.18955116391547},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '214 Garratt Lane',
#     'address2': 'Wandsworth',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW18 4EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['214 Garratt Lane',
#      'Wandsworth',
#      'London SW18 4EA',
#      'United Kingdom']},
#    'phone': '+442088708417',
#    'display_phone': '+44 20 8870 8417',
#    'distance': 8207.332827397508},
#   {'id': 'FeLJAQRuOgdMLuR2BnBywg',
#    'alias': 'the-bull-london-8',
#    'name': 'The Bull',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/C8_OjwJny0IMHJLNww_Rbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bull-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5754950115533,
#     'longitude': -0.15090279626407},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '13 North Hill',
#     'address2': 'Highgate',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N6 4AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 North Hill',
#      'Highgate',
#      'London N6 4AB',
#      'United Kingdom']},
#    'phone': '+442083410510',
#    'display_phone': '+44 20 8341 0510',
#    'distance': 7043.663477181744},
#   {'id': 'CexMDiWtQh7BNpq3nSN30g',
#    'alias': 'prospect-of-whitby-london',
#    'name': 'Prospect Of Whitby',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BKeENWGbj3-GSGe0IKUgbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prospect-of-whitby-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 56,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5071151879516,
#     'longitude': -0.0511241777638486},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '57 Wapping Wall',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1W 3SH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57 Wapping Wall',
#      'London E1W 3SH',
#      'United Kingdom']},
#    'phone': '+442074811095',
#    'display_phone': '+44 20 7481 1095',
#    'distance': 5905.15028374947},
#   {'id': '8ZUHGbZjVqK61KturAB0eg',
#    'alias': 'the-flask-london-3',
#    'name': 'The Flask',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HPgAi-PO5qUA3CvAGRABtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-flask-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.569881303877,
#     'longitude': -0.15093969430275},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '77 Highgate West Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N6 6BU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['77 Highgate West Hill',
#      'London N6 6BU',
#      'United Kingdom']},
#    'phone': '+442083487346',
#    'display_phone': '+44 20 8348 7346',
#    'distance': 6427.280036303667},
#   {'id': 'd7QSjtv73g9EHnbAxbq3Gg',
#    'alias': 'the-weir-brentford',
#    'name': 'The Weir',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HFM8HfdxvXMEj2uqbaq1kA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-weir-brentford?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4836023, 'longitude': -0.3093794},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '24 Market Place',
#     'address2': '',
#     'address3': '',
#     'city': 'Brentford',
#     'zip_code': 'TW8 8EQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Market Place',
#      'Brentford TW8 8EQ',
#      'United Kingdom']},
#    'phone': '+442085683600',
#    'display_phone': '+44 20 8568 3600',
#    'distance': 12431.023637340657},
#   {'id': 'xdw_P7cZBp8PTG6eM2B2tg',
#    'alias': 'bradleys-spanish-bar-london-2',
#    'name': "Bradley's Spanish Bar",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cP4ymz-wvnMV7MewGGi4fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bradleys-spanish-bar-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516396827163,
#     'longitude': -0.132729090213047},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '42-44 Hanway Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 1UT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42-44 Hanway Street',
#      'London W1T 1UT',
#      'United Kingdom']},
#    'phone': '+442076360359',
#    'display_phone': '+44 20 7636 0359',
#    'distance': 454.61013667159625},
#   {'id': '1OCM7fEC1Fzk8t-764Baqg',
#    'alias': 'the-camel-london-2',
#    'name': 'The Camel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fd8qSWJnMis8-hMQQ5B6AQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-camel-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5287234, 'longitude': -0.05184},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '277 Globe Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 0JD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['277 Globe Road', 'London E2 0JD', 'United Kingdom']},
#    'phone': '+442036202333',
#    'display_phone': '+44 20 3620 2333',
#    'distance': 6108.850105230813},
#   {'id': 'gbbaKUE7jvoR9r0_yVZhCA',
#    'alias': 'the-george-london-3',
#    'name': 'The George ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Hw4zphUI23yuzPOx9AfozQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-george-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.514921, 'longitude': -0.135355},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "1 D'Arblay Street",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8DG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["1 D'Arblay Street",
#      'London W1F 8DG',
#      'United Kingdom']},
#    'phone': '+442074391911',
#    'display_phone': '+44 20 7439 1911',
#    'distance': 239.58193158520962},
#   {'id': '5eYm4Tb9sMqAyT0atPqTjw',
#    'alias': 'devonshire-arms-london-2',
#    'name': 'Devonshire Arms',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/li5ssPOHc6dPUpgHeAs9rQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/devonshire-arms-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.496805173579,
#     'longitude': -0.19253351618059},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '37 Marloes Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 6LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['37 Marloes Road', 'London W8 6LA', 'United Kingdom']},
#    'phone': '+442079370710',
#    'display_phone': '+44 20 7937 0710',
#    'distance': 4302.519978330082},
#   {'id': 'rFMgqotkxTL1dJKMJVuw8Q',
#    'alias': 'king-and-queen-london',
#    'name': 'King & Queen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XwNXYBbZVPsel3J9iVWnkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/king-and-queen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5200329, 'longitude': -0.1390298},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Foley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 6DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Foley Street', 'London W1W 6DL', 'United Kingdom']},
#    'phone': '+442076365619',
#    'display_phone': '+44 20 7636 5619',
#    'distance': 847.6938895852345},
#   {'id': 'LWE3HRlQIGKw1FXxfDlp8A',
#    'alias': 'the-florist-arms-london-2',
#    'name': 'The Florist Arms',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ny7dll8Go19yHsQHlLsZUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-florist-arms-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5284599, 'longitude': -0.051429},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '255 Globe Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 0JD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['255 Globe Road', 'London E2 0JD', 'United Kingdom']},
#    'phone': '+442089811100',
#    'display_phone': '+44 20 8981 1100',
#    'distance': 6103.560962206912},
#   {'id': '-wAmPgs5fdZQ2U1knXcymg',
#    'alias': 'the-mason-arms-london',
#    'name': 'The Mason Arms',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/i02sEMjzJxKWECfbr56Abw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mason-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.512873315148,
#     'longitude': -0.14259335731627},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '38 Maddox Street',
#     'address2': 'London',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 1PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38 Maddox Street',
#      'London',
#      'London W1S 1PD',
#      'United Kingdom']},
#    'phone': '+442074917809',
#    'display_phone': '+44 20 7491 7809',
#    'distance': 459.34321754213397},
#   {'id': 'e68elNdquCtZ2UWzMw4uAg',
#    'alias': 'the-magazine-restaurant-london',
#    'name': 'The Magazine Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YuVCLiJMLcEuS6uEu-qThQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-magazine-restaurant-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5070518464263,
#     'longitude': -0.171575510589605},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Serpentine Sackler Gallery',
#     'address2': 'West Carriage Drive',
#     'address3': 'Kensington Gardens',
#     'city': 'London',
#     'zip_code': 'W2 2AR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Serpentine Sackler Gallery',
#      'West Carriage Drive',
#      'Kensington Gardens',
#      'London W2 2AR',
#      'United Kingdom']},
#    'phone': '+442072987552',
#    'display_phone': '+44 20 7298 7552',
#    'distance': 2547.582060839701},
#   {'id': 'rlU4x1HMMK7oeHoPPGYcXA',
#    'alias': 'salut-london',
#    'name': 'Salut!',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fQgNLbfWtxCEWZpWkOSDYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salut-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5458255, 'longitude': -0.0872909},
#    'transactions': [],
#    'location': {'address1': '412 Essex Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 3PJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['412 Essex Road', 'London N1 3PJ', 'United Kingdom']},
#    'phone': '+442034418808',
#    'display_phone': '+44 20 3441 8808',
#    'distance': 4979.661136459817},
#   {'id': 'K3_4DUUm42UDaS7F_18IUQ',
#    'alias': 'the-crown-and-anchor-london-3',
#    'name': 'The Crown & Anchor',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Uonq4xhzagF_X31e4MKK3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-crown-and-anchor-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.47134957157,
#     'longitude': -0.112795614647525},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '246 Brixton Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 6AQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['246 Brixton Rd', 'London SW9 6AQ', 'United Kingdom']},
#    'phone': '+442077370060',
#    'display_phone': '+44 20 7737 0060',
#    'distance': 4883.746344285559},
#   {'id': 'z6s18W6UWk73QyintC4hsQ',
#    'alias': 'hereford-arms-london',
#    'name': 'Hereford Arms',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/stGKFOLxnF2PaxYrbaQaTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hereford-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 103,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4928650556698,
#     'longitude': -0.181306525714939},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '127 Gloucester Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 4TE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['127 Gloucester Road',
#      'London SW7 4TE',
#      'United Kingdom']},
#    'phone': '+442073704988',
#    'display_phone': '+44 20 7370 4988',
#    'distance': 3845.052015495539},
#   {'id': 'WHSJsMnrsAQEN4TKo0n7XA',
#    'alias': 'lord-nelson-london-2',
#    'name': 'Lord Nelson',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4heSWuWOQKVc3uJr4YpRvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lord-nelson-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.503489520908,
#     'longitude': -0.10225512172207},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '243 Union Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0LR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['243 Union Street',
#      'London SE1 0LR',
#      'United Kingdom']},
#    'phone': '+442072072701',
#    'display_phone': '+44 20 7207 2701',
#    'distance': 2553.4058565853998},
#   {'id': 'gXRriaB1DNMbq8PFXnljxQ',
#    'alias': 'the-pembury-tavern-london',
#    'name': 'The Pembury Tavern',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZY-gEgZnZlf6MWRFbyeeTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pembury-tavern-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.54937814426,
#     'longitude': -0.059258798955593},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '90 Amhurst Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 1JH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['90 Amhurst Road', 'London E8 1JH', 'United Kingdom']},
#    'phone': '+442089868597',
#    'display_phone': '+44 20 8986 8597',
#    'distance': 6682.648029649987},
#   {'id': 'j8yPZj1-eDfsIwfsGBFaJw',
#    'alias': 'compton-arms-london',
#    'name': 'Compton Arms',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m-q9TBhgWswF49daJC6iww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/compton-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5436107, 'longitude': -0.1020662},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '4 Compton Avenue',
#     'address2': 'Islington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 2XD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Compton Avenue',
#      'Islington',
#      'London N1 2XD',
#      'United Kingdom']},
#    'phone': '+442073596883',
#    'display_phone': '+44 20 7359 6883',
#    'distance': 4148.079556001775},
#   {'id': 'Ibua6QtXv8u8HkiQhEyGqg',
#    'alias': 'the-shaston-arms-london',
#    'name': 'The Shaston Arms',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/V4A_rlg1ptJzJI3J01ZniQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-shaston-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5134683, 'longitude': -0.1382233},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 Ganton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7QH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Ganton Street',
#      'London W1F 7QH',
#      'United Kingdom']},
#    'phone': '+4420772872631',
#    'display_phone': '+44 20772872631',
#    'distance': 171.8681451031243},
#   {'id': 'DWPtpdsU6mIMzRUouGklBQ',
#    'alias': 'the-worlds-end-london-2',
#    'name': "The World's End",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r0tYqO0UL3b7gP3cT4KNrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-worlds-end-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 115,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.539470248288,
#     'longitude': -0.14222360058202},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '174 Camden High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 0NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['174 Camden High Street',
#      'London NW1 0NE',
#      'United Kingdom']},
#    'phone': '+442074821932',
#    'display_phone': '+44 20 7482 1932',
#    'distance': 2993.2170312903895},
#   {'id': 'Lfhb267w4FGa3kiaT8SoEA',
#    'alias': 'the-lamb-london',
#    'name': 'The Lamb',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XZS5Naon39Pd7UaKMgm1Nw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lamb-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 63,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5233037072011,
#     'longitude': -0.119153724223369},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '92-94 Lambs Conduit Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 3LZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['92-94 Lambs Conduit Street',
#      'London WC1N 3LZ',
#      'United Kingdom']},
#    'phone': '+442074050713',
#    'display_phone': '+44 20 7405 0713',
#    'distance': 1645.1504914517332},
#   {'id': 'de1tlephOC5z-B7INiBnNg',
#    'alias': 'the-one-tun-london',
#    'name': 'The One Tun',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3urES7bZrFlxmZA3yxkxTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-one-tun-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.519098791332,
#     'longitude': -0.13672213912772},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '58-60 Goodge St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 4ND',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['58-60 Goodge St',
#      'London W1T 4ND',
#      'United Kingdom']},
#    'phone': '+442072094105',
#    'display_phone': '+44 20 7209 4105',
#    'distance': 698.458904489205},
#   {'id': 'EworxQ9xPMBe9Ap1Z2YvTg',
#    'alias': 'flat-top-burgers-london',
#    'name': 'Flat Top Burgers',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flat-top-burgers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5243442600574,
#     'longitude': -0.0774195901119663},
#    'transactions': [],
#    'location': {'address1': '186 - 187 Shoreditch High Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EC2A 3ET',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['186 - 187 Shoreditch High Street',
#      'London EC2A 3ET',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4247.606835105727},
#   {'id': 'CgxkMXS6ibHV4QOz9DSOPg',
#    'alias': 'the-griffin-london-3',
#    'name': 'The Griffin',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sUJoCRqnzATq96vYU_-LbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-griffin-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.524764803371,
#     'longitude': -0.081974499743276},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '93 Leonard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 4RD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['93 Leonard Street',
#      'London EC2A 4RD',
#      'United Kingdom']},
#    'phone': '+442037457496',
#    'display_phone': '+44 20 3745 7496',
#    'distance': 3963.6158261789633},
#   {'id': '55D4920dDElptODIsKQAfg',
#    'alias': 'hanswurst-wimbledon',
#    'name': 'Hanswurst',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hanswurst-wimbledon?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4221561024405,
#     'longitude': -0.208048196433992},
#    'transactions': [],
#    'location': {'address1': 'St Marks Place',
#     'address2': '',
#     'address3': None,
#     'city': 'Wimbledon',
#     'zip_code': 'SW19 7ND',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['St Marks Place',
#      'Wimbledon SW19 7ND',
#      'United Kingdom']},
#    'phone': '+447845553076',
#    'display_phone': '+44 7845 553076',
#    'distance': 11251.965444076715},
#   {'id': 'TYCrKfYC7Zo14xmi8CIGtw',
#    'alias': 'the-craft-beer-co-london-5',
#    'name': 'The Craft Beer Co',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0YGfQ_V89OJPca-dZ3weQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-craft-beer-co-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51575, 'longitude': -0.125786},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '168 High Holborn',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1V 7AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['168 High Holborn',
#      'London WC1V 7AA',
#      'United Kingdom']},
#    'phone': '+442078349988',
#    'display_phone': '+44 20 7834 9988',
#    'distance': 774.7715742064693},
#   {'id': 'ruDjQfBIz2I71ne4aUf5VA',
#    'alias': 'the-abbey-london-3',
#    'name': 'The Abbey',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kmMfGB-l6FAveAhYQfcB-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-abbey-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.498076, 'longitude': -0.132527},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Abbey Orchard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 2LU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Abbey Orchard Street',
#      'London SW1P 2LU',
#      'United Kingdom']},
#    'phone': '+442072225084',
#    'display_phone': '+44 20 7222 5084',
#    'distance': 1658.251199214348},
#   {'id': 'ZqAIcrSGN8JpQLjxYTkXDw',
#    'alias': 'german-doner-kebab-croydon',
#    'name': 'German Doner Kebab',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/german-doner-kebab-croydon?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'kebab', 'title': 'Kebab'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.37418, 'longitude': -0.09799},
#    'transactions': [],
#    'location': {'address1': '27 George St',
#     'address2': '',
#     'address3': None,
#     'city': 'Croydon',
#     'zip_code': 'CR0 1LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['27 George St', 'Croydon CR0 1LB', 'United Kingdom']},
#    'phone': '+442086884800',
#    'display_phone': '+44 20 8688 4800',
#    'distance': 15642.379202907734}],
#  'total': 115,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#              Restaurant        Type Price Rating             Address  \
# 0    Ye Old White Horse        Pubs     £      4  2 St Clements Lane
# 1               Millers        Pubs    ££    3.5  19 Caledonian Road
# 2           Draft House  Gastropubs    ££      4   94 Northcote Road
# 3  Crown & Two Chairmen        Pubs    ££      3   31-32 Dean Street
# 4   The Salisbury Hotel        Pubs    ££      4      1 Grand Parade
#
#          Lat       Lng                                                url  \
# 0  51.514730 -0.117203  https://www.yelp.com/biz/ye-old-white-horse-ho...
# 1  51.531657 -0.121055  https://www.yelp.com/biz/millers-london?adjust...
# 2  51.457455 -0.165995  https://www.yelp.com/biz/draft-house-london?ad...
# 3  51.513832 -0.132498  https://www.yelp.com/biz/crown-and-two-chairme...
# 4  51.582110 -0.099778  https://www.yelp.com/biz/the-salisbury-hotel-l...
#
#                        ID
# 0  ys0CRv-iRRySKs2l-vIOxg
# 1  jFn8bNvKKck9IbkWWWgKFA
# 2  siT3_BKKzurJ2S0Y_BWbLQ
# 3  xQFwpDaButTd9Yf18L9Dyg
# 4  I00ahdNmf_KUH-0FbDkrOQ

# %%
#3rd set of 50 records 101-150
lndr_params3 = {"term":"German","location":"London","limit":50,"offset":101}
lndr_response3 = requests.get(search_api_url, headers=headers, params=lndr_params3)
lndr3 = lndr_response3.json()
display(lndr3)
#print(lndr_response3.url)
#print(lndr_response3.status_code)
# Out:
# {'businesses': [{'id': 'kcjovWxxglD9kJ-qOwViFg',
#    'alias': 'the-grafton-arms-london',
#    'name': 'The Grafton Arms',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/b46GbLm9AKpI6bJAqm2baQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grafton-arms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5233116149902,
#     'longitude': -0.138775005936623},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '72 Grafton Way',
#     'address2': 'London',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 5DU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['72 Grafton Way',
#      'London',
#      'London W1T 5DU',
#      'United Kingdom']},
#    'phone': '+442073877923',
#    'display_phone': '+44 20 7387 7923',
#    'distance': 1181.1070449783797},
#   {'id': 'JcO8N2mrooxEoFZTRiLRqw',
#    'alias': 'the-queens-arms-london-3',
#    'name': "The Queen's Arms",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V56aN41Oywr5Br_j-EWYjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-queens-arms-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 128,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4992491095565,
#     'longitude': -0.180797918037262},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "30 Queen's Gate Mews",
#     'address2': 'Kensington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 5QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["30 Queen's Gate Mews",
#      'Kensington',
#      'London SW7 5QL',
#      'United Kingdom']},
#    'phone': '+442078239293',
#    'display_phone': '+44 20 7823 9293',
#    'distance': 3451.741366066539},
#   {'id': 'VFt0kawsBqqNIh9UJYS4tg',
#    'alias': 'the-george-inn-london',
#    'name': 'The George Inn',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/unfXINjGsdgKMfYdVdYDvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-george-inn-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 142,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5040031333562,
#     'longitude': -0.0902946426058238},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '75-77 Borough High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['75-77 Borough High Street',
#      'London SE1 1NH',
#      'United Kingdom']},
#    'phone': '+442074072056',
#    'display_phone': '+44 20 7407 2056',
#    'distance': 3309.196726671051},
#   {'id': '8bolBfqMoKH_dgaUPz0WTw',
#    'alias': 'hops-and-glory-london',
#    'name': 'Hops and Glory',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2Kfff3Z4z7D9qYUCokXZNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hops-and-glory-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5453147700321,
#     'longitude': -0.0905422804831942},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '382 Essex Road',
#     'address2': 'Islington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 3PF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['382 Essex Road',
#      'Islington',
#      'London N1 3PF',
#      'United Kingdom']},
#    'phone': '+442072262277',
#    'display_phone': '+44 20 7226 2277',
#    'distance': 4786.684990925835},
#   {'id': '1i6naOXJ5ndPLihFkoWygw',
#    'alias': 'the-ram-london',
#    'name': 'The Ram',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jwgi0DTZxlkTyP5fsRBwAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ram-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.4081773032059,
#     'longitude': -0.30770282731822},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '34 High Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'KT1 1HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['34 High Street', 'London KT1 1HL', 'United Kingdom']},
#    'phone': '+442085464518',
#    'display_phone': '+44 20 8546 4518',
#    'distance': 16643.584249857417},
#   {'id': 'pKOfB1rCHVc42nEh1oMkNw',
#    'alias': 'birds-nest-bar-and-hostel-london',
#    'name': "Bird's Nest Bar and Hostel",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8JTvw-uWvfTIKhcSMH0XmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/birds-nest-bar-and-hostel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'hostels', 'title': 'Hostels'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.476061, 'longitude': -0.022673},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '32 Deptford Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE8 4RZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['32 Deptford Church St',
#      'London SE8 4RZ',
#      'United Kingdom']},
#    'phone': '+442086921928',
#    'display_phone': '+44 20 8692 1928',
#    'distance': 8839.002299582662},
#   {'id': 'k2yAbVvjC1tmvxV87PageA',
#    'alias': 'bridge-house-london',
#    'name': 'Bridge House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2G_pfjJpK4zHq6ISNDixtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bridge-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5209689, 'longitude': -0.1842099},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '13 Westbourne Terrace Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 6NG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Westbourne Terrace Road',
#      'London W2 6NG',
#      'United Kingdom']},
#    'phone': '+442072664326',
#    'display_phone': '+44 20 7266 4326',
#    'distance': 3467.167050183025},
#   {'id': 'MVSqxbzJZkzBfRHEBGNi0Q',
#    'alias': 'indo-london',
#    'name': 'Indo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/B_CeeaGrzVI-qSg8NnAqig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/indo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5178888, 'longitude': -0.0654968},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '133 Whitechapel Road',
#     'address2': 'London',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 1DT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['133 Whitechapel Road',
#      'London',
#      'London E1 1DT',
#      'United Kingdom']},
#    'phone': '+442072474926',
#    'display_phone': '+44 20 7247 4926',
#    'distance': 4894.5283414109435},
#   {'id': 'zJNnaIvF4f5Sr26YMkfPiA',
#    'alias': 'hole-in-the-wall-london-3',
#    'name': 'Hole in the Wall',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8BhYrLvWcuxpUy1kZeSlLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hole-in-the-wall-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.50399, 'longitude': -0.113346},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '5 Mepham Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8SQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Mepham Street',
#      'London SE1 8SQ',
#      'United Kingdom']},
#    'phone': '+442079286196',
#    'display_phone': '+44 20 7928 6196',
#    'distance': 1848.2235021923163},
#   {'id': 'KbqO1qi3Se82T4ebw2FZmA',
#    'alias': 'the-old-star-london',
#    'name': 'The Old Star',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HMYhv18QZy1GBAZZuf3XNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-old-star-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.49999, 'longitude': -0.133486},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '66 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1H 0DB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Broadway', 'London SW1H 0DB', 'United Kingdom']},
#    'phone': '+442072228755',
#    'display_phone': '+44 20 7222 8755',
#    'distance': 1441.3927222738396},
#   {'id': 'hM4RCPwAZHWy9woF0UWATA',
#    'alias': 'the-winchester-london',
#    'name': 'The Winchester',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bqDEtqwHTsWGGhaE--Vkog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-winchester-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.536355271762,
#     'longitude': -0.10161073774793},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Essex Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8LN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Essex Road', 'London N1 8LN', 'United Kingdom']},
#    'phone': '+442077048789',
#    'display_phone': '+44 20 7704 8789',
#    'distance': 3533.4814194333685},
#   {'id': 'wkVfJw2WDVSHTFe0cMV2Uw',
#    'alias': 'rose-and-crown-london-6',
#    'name': 'Rose & Crown',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DjqEBpuYgVggVBgm0les_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rose-and-crown-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.503851, 'longitude': -0.095043},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '65 Union Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1SG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['65 Union Street',
#      'London SE1 1SG',
#      'United Kingdom']},
#    'phone': '+442074071191',
#    'display_phone': '+44 20 7407 1191',
#    'distance': 3019.9332236874598},
#   {'id': '_Wt6wt60tHcs7x5OVmNzNQ',
#    'alias': 'the-regent-london-3',
#    'name': 'The Regent',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/u138daKU1YhejBD5ChZ1iQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-regent-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.444047, 'longitude': -0.153683},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '21 Chestnut Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW12 8JB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21 Chestnut Grove',
#      'London SW12 8JB',
#      'United Kingdom']},
#    'phone': '+442087720546',
#    'display_phone': '+44 20 8772 0546',
#    'distance': 7746.820416622371},
#   {'id': 'cMZsEgHHE5R2f0Wuo4WT_A',
#    'alias': 'the-lambourne-london',
#    'name': 'The Lambourne',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9iKwH6llu9DnL2UvlUyKZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lambourne-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.419318152559,
#     'longitude': -0.19502002764269},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '263 The Broadway',
#     'address2': 'Wimbledon',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW19 1SD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['263 The Broadway',
#      'Wimbledon',
#      'London SW19 1SD',
#      'United Kingdom']},
#    'phone': '+442085458661',
#    'display_phone': '+44 20 8545 8661',
#    'distance': 11174.618596261706}],
#  'total': 115,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#          Restaurant  Type Price  Rating                    Address        Lat  \
# 0  The Grafton Arms  Pubs    ££     4.5             72 Grafton Way  51.523312
# 1  The Queen's Arms  Pubs    ££     4.0       30 Queen's Gate Mews  51.499249
# 2    The George Inn  Pubs    ££     4.0  75-77 Borough High Street  51.504003
# 3    Hops and Glory  Pubs    ££     3.5             382 Essex Road  51.545315
# 4           The Ram  Pubs    ££     3.0             34 High Street  51.408177
#
#         Lng                                                url  \
# 0 -0.138775  https://www.yelp.com/biz/the-grafton-arms-lond...
# 1 -0.180798  https://www.yelp.com/biz/the-queens-arms-londo...
# 2 -0.090295  https://www.yelp.com/biz/the-george-inn-london...
# 3 -0.090542  https://www.yelp.com/biz/hops-and-glory-london...
# 4 -0.307703  https://www.yelp.com/biz/the-ram-london?adjust...
#
#                        ID
# 0  kcjovWxxglD9kJ-qOwViFg
# 1  JcO8N2mrooxEoFZTRiLRqw
# 2  VFt0kawsBqqNIh9UJYS4tg
# 3  8bolBfqMoKH_dgaUPz0WTw
# 4  1i6naOXJ5ndPLihFkoWygw

# %%
#4th set of 50 records 151-200
lndr_params4 = {"term":"German","location":"London","limit":50,"offset":151}
lndr_response4 = requests.get(search_api_url, headers=headers, params=lndr_params4)
lndr4 = lndr_response4.json()
display(lndr4)
#print(lndr_response4.url)
#print(lndr_response4.status_code)
# Out:
# {'businesses': [],
#  'total': 115,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
# Empty DataFrame
# Columns: [Restaurant, Type, Price, Rating, Address, Lat, Lng, url, ID]
# Index: []

# %%
london_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
london_restaurants_df.shape
# Out:
# (114, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_restaurants_df = london_restaurants_df[column_order]
london_restaurants_df = london_restaurants_df.sort_values(["Type"], ascending=True)
london_restaurants_df = london_restaurants_df.reset_index(drop=True)
london_restaurants_df
# Out:
#                                         Restaurant                Type Rating  \
# 0                                        Fischer's            Austrian      4
# 1                                 Hansel & Pretzel            Bakeries      5
# 2                        Baltic Bar and Restaurant                Bars      4
# 3                                      Tiger Tiger                Bars    2.5
# 4                                       The Peahen  Breakfast & Brunch      4
# 5                                The Modern Pantry  Breakfast & Brunch      4
# 6                              Social Eating House             British      4
# 7                                          The Gun             British      4
# 8                              The Greenwich Union             British    4.5
# 9                                     The Antelope             British    3.5
# 10                                       The Flask             British      4
# 11                                     The Portman             British      4
# 12                                Flat Top Burgers             Burgers
# 13                                         Kipferl        Coffee & Tea      4
# 14   Czechoslovak National House Club & Restaurant               Czech      4
# 15                              German Doner Kebab           Fast Food      4
# 16                                     Draft House          Gastropubs      4
# 17                                 The Draft House          Gastropubs    3.5
# 18                                Herman Ze German              German      4
# 19                                    Work Kitchen              German
# 20                                 Octoberfest Pub              German      3
# 21                                   Katzenjammers              German    3.5
# 22                                German Gymnasium              German      4
# 23                                       Hanswurst              German
# 24                              German Doner Kebab              German      4
# 25                                       Zeitgeist              German      4
# 26                                     German Food              German
# 27                                  World of Wurst              German    4.5
# 28                                Herman Ze German              German    3.5
# 29                              German Doner Kebab              German
# ..                                             ...                 ...    ...
# 84                                    The Ordnance                Pubs      4
# 85                              The Fitzroy Tavern                Pubs      4
# 86                                  The Wheatsheaf                Pubs      3
# 87                                        The Dove                Pubs      4
# 88                           The Forest Hill Hotel                Pubs
# 89                                  The White Hart                Pubs      4
# 90                                   The Horseshoe                Pubs    3.5
# 91                                     Round Table                Pubs      3
# 92                                Jerusalem Tavern                Pubs      4
# 93                                   Museum Tavern                Pubs      4
# 94                                   Earl of Essex                Pubs    4.5
# 95                                      The Regent                Pubs      3
# 96                                   The Grenadier                Pubs      4
# 97                              Prospect Of Whitby                Pubs      4
# 98                                        The Bull                Pubs    4.5
# 99                             The Jolly Gardeners                Pubs      4
# 100                                     Holly Bush                Pubs      4
# 101                                     Five Bells                Pubs    3.5
# 102                              The Horse & Groom                Pubs    3.5
# 103                                The Old Brewery                Pubs      4
# 104                               Earl Of Lonsdale                Pubs      3
# 105                                Princess Louise                Pubs    4.5
# 106                                    Star Tavern                Pubs      4
# 107                                        Stein's                Pubs    3.5
# 108                             The Rose and Crown                Pubs      4
# 109                                    Camden Head                Pubs    3.5
# 110                             Sir Richard Steele                Pubs    4.5
# 111                                      Stormbird                Pubs      4
# 112                                    The Roebuck                Pubs      4
# 113                                       Vinoteca           Wine Bars      4
#
#     Price                           Address        Lat       Lng  \
# 0     £££         50 Marylebone High Street  51.521616 -0.151700
# 1      ££                     71 Ham Street  51.438419 -0.313494
# 2     £££               74 Blackfriars Road  51.503466 -0.104866
# 3      ££                   Haymarket House  51.509645 -0.132555
# 4      ££                    14 London Road  51.750709 -0.339535
# 5      ££            47-48 St John's Square  51.523030 -0.103575
# 6     £££                  58 Poland Street  51.513673 -0.136388
# 7      ££                    27 Coldharbour  51.501782 -0.007742
# 8      ££                     56 Royal Hill  51.476535 -0.009581
# 9      ££                   76 Mitcham Road  51.426081 -0.165863
# 10     ££             77 Highgate West Hill  51.569881 -0.150940
# 11     ££          51 Upper Berkeley Street  51.515247 -0.161371
# 12         186 - 187 Shoreditch High Street  51.524344 -0.077420
# 13     ££                 20 Camden Passage  51.535248 -0.103393
# 14     ££                     74 W End Lane  51.544555 -0.192199
# 15      £                       24 Broadway  51.510806 -0.320996
# 16     ££                 94 Northcote Road  51.457455 -0.165995
# 17     ££         206-208 Tower Bridge Road  51.502870 -0.076947
# 18      £                19 Villiers Street  51.508298 -0.123974
# 19                              Maxted Road  51.766060 -0.434941
# 20      £               678-680 Fulham Road  51.474695 -0.206820
# 21     ££               24 Southwark Street  51.504827 -0.091032
# 22    £££                 1 Kings Boulevard  51.532398 -0.125420
# 23                           St Marks Place  51.422156 -0.208048
# 24      £         11A Islington High Street  51.532394 -0.106498
# 25     ££         49 - 51 Black Prince Road  51.491333 -0.118202
# 26                   Portobello Road Market  51.515473 -0.204620
# 27      £           49 Brixton Station Road  51.463400 -0.111049
# 28      £             33 Old Compton Street  51.513273 -0.131731
# 29                             27 George St  51.374180 -0.097990
# ..    ...                               ...        ...       ...
# 84      £                  29 Ordnance Hill  51.535700 -0.171308
# 85      £               16 Charlotte Street  51.518562 -0.134739
# 86     ££               24 Southwark Street  51.504901 -0.091051
# 87     ££             24-26 Broadway Market  51.536339 -0.061853
# 88                        41 Stanstead Road  51.441477 -0.051411
# 89     ££                  29 Cornwall Road  51.504794 -0.110693
# 90     ££                   28 Heath Street  51.556020 -0.178585
# 91      £            26-27 St Martins Court  51.510887 -0.127927
# 92     ££                 55 Britton Street  51.521760 -0.104116
# 93     ££           49 Great Russell Street  51.518214 -0.125971
# 94     ££                 25 Danbury Street  51.533905 -0.099695
# 95     ££                 21 Chestnut Grove  51.444047 -0.153683
# 96     ££                     18 Wilton Row  51.501462 -0.155004
# 97     ££                   57 Wapping Wall  51.507115 -0.051124
# 98     ££                     13 North Hill  51.575495 -0.150903
# 99     ££                  214 Garratt Lane  51.447004 -0.189551
# 100    ££                    22 Holly Mount  51.557912 -0.179326
# 101     £         68-70 Streatham High Road  51.436288 -0.128095
# 102     £         128 Great Portland Street  51.519887 -0.142409
# 103    ££                The Pepys Building  51.482932 -0.008245
# 104    ££          277-281 Westbourne Grove  51.513490 -0.202848
# 105    ££                  208 High Holborn  51.517294 -0.121571
# 106    ££              6 Belgrave Mews West  51.498305 -0.155753
# 107    ££                  Richmond Towpath  51.455546 -0.304016
# 108    ££                     2 The Polygon  51.463751 -0.141287
# 109    ££                  2 Camden Passage  51.535616 -0.102780
# 110    ££                97 Haverstock Hill  51.546681 -0.158604
# 111     £       25 Camberwell Church Street  51.474052 -0.090297
# 112    ££             50 Great Dover Street  51.498088 -0.090559
# 113    ££                  7 St John Street  51.520121 -0.101915
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/fischers-london?adjus...  apqNvjbaB20wozywrLNPiQ
# 1    https://www.yelp.com/biz/hansel-and-pretzel-lo...  RQxZlkXAAiDA6KNmvThi5w
# 2    https://www.yelp.com/biz/baltic-bar-and-restau...  fdwAAs9cm_uLkgxXedYh3w
# 3    https://www.yelp.com/biz/tiger-tiger-london?ad...  Ztez_cQAGM1-37QvYaqY_Q
# 4    https://www.yelp.com/biz/the-peahen-st-albans-...  EFpGMzFyjVNgEyqa_j-m_A
# 5    https://www.yelp.com/biz/the-modern-pantry-lon...  zOLPCLptUE2UKRXYWCEHvg
# 6    https://www.yelp.com/biz/social-eating-house-l...  CWYCCZkND7MEsOZH6C3jAg
# 7    https://www.yelp.com/biz/the-gun-london-2?adju...  P-lfeLq93Bo6KQb5CnWIZw
# 8    https://www.yelp.com/biz/the-greenwich-union-l...  uq52voow6qazaRAFJ0ceMw
# 9    https://www.yelp.com/biz/the-antelope-london?a...  hqznZa5xhj32u27icNxLeA
# 10   https://www.yelp.com/biz/the-flask-london-3?ad...  8ZUHGbZjVqK61KturAB0eg
# 11   https://www.yelp.com/biz/the-portman-london?ad...  pOnkBNgFreS7QzKZXXV3jA
# 12
# 13   https://www.yelp.com/biz/kipferl-london-6?adju...  xqpUr61KFa1Xx721-E6l_A
# 14   https://www.yelp.com/biz/czechoslovak-national...  4BxxZPDBbrIg9egm-r8FXg
# 15   https://www.yelp.com/biz/german-doner-kebab-lo...  ZQ83yqyl8qsySQtzssuh0g
# 16   https://www.yelp.com/biz/draft-house-london?ad...  siT3_BKKzurJ2S0Y_BWbLQ
# 17   https://www.yelp.com/biz/the-draft-house-londo...  53pYlbjaaq1l8R1H53O0mQ
# 18   https://www.yelp.com/biz/herman-ze-german-lond...  UdFNcwNbwVJ7qNdDXYd_PA
# 19
# 20   https://www.yelp.com/biz/octoberfest-pub-londo...  VgZY9s-K6352TxW-mVKUfw
# 21   https://www.yelp.com/biz/katzenjammers-london?...  jcBeMcH_nAaDDJotomqs-g
# 22   https://www.yelp.com/biz/german-gymnasium-lond...  4IpNjfnu3VnM8p7_i4or4Q
# 23
# 24   https://www.yelp.com/biz/german-doner-kebab-lo...  JiXzJ68Q7wM8E9mf7UItKQ
# 25   https://www.yelp.com/biz/zeitgeist-london-3?ad...  sen5D3KKE0penBC7d5GlUQ
# 26
# 27   https://www.yelp.com/biz/world-of-wurst-london...  5puz_aDYRkQ-Ur45ceZy9A
# 28   https://www.yelp.com/biz/herman-ze-german-lond...  2vgpyvU72DEHiLRYmSE1FQ
# 29
# ..                                                 ...                     ...
# 84   https://www.yelp.com/biz/the-ordnance-london?a...  4bzGqKQMrTUAhB84SKy83w
# 85   https://www.yelp.com/biz/the-fitzroy-tavern-lo...  bRlAMHrc5d_HYzlesl7Epw
# 86   https://www.yelp.com/biz/the-wheatsheaf-london...  ivaTPZkgXISZME4LS6KWZQ
# 87   https://www.yelp.com/biz/the-dove-london-3?adj...  _faDmrUFilwMxk0atkXjNA
# 88
# 89   https://www.yelp.com/biz/the-white-hart-london...  yFaZL5ndSiQO1qRcumM6Cg
# 90   https://www.yelp.com/biz/the-horseshoe-london-...  aA79oNXSvGKc0xfTTp0yrA
# 91   https://www.yelp.com/biz/round-table-london?ad...  DpWAtyCrLeit4RHbHoI2Tw
# 92   https://www.yelp.com/biz/jerusalem-tavern-lond...  4-XTDzMijxlATEnCQMvOJQ
# 93   https://www.yelp.com/biz/museum-tavern-bloomsb...  4m2-sWOvdCqjQ05lH6uy4Q
# 94   https://www.yelp.com/biz/earl-of-essex-london?...  GyK15muNSx4rJ155l4-2Ag
# 95   https://www.yelp.com/biz/the-regent-london-3?a...  _Wt6wt60tHcs7x5OVmNzNQ
# 96   https://www.yelp.com/biz/the-grenadier-london?...  FJs1PrhFMFVL_iMcH69VuQ
# 97   https://www.yelp.com/biz/prospect-of-whitby-lo...  CexMDiWtQh7BNpq3nSN30g
# 98   https://www.yelp.com/biz/the-bull-london-8?adj...  FeLJAQRuOgdMLuR2BnBywg
# 99   https://www.yelp.com/biz/the-jolly-gardeners-l...  g39uJIugM2A4DBIabAcgyg
# 100  https://www.yelp.com/biz/holly-bush-london?adj...  y__iD3k2p4Xm0Xl_tSSNZg
# 101  https://www.yelp.com/biz/five-bells-streatham?...  j-62V03K9x9rK4BuJa-g6A
# 102  https://www.yelp.com/biz/the-horse-and-groom-l...  aAGDecm8DlOTVADNjxyXMg
# 103  https://www.yelp.com/biz/the-old-brewery-londo...  X-fad8Xp37BNRczsxjHTeA
# 104  https://www.yelp.com/biz/earl-of-lonsdale-lond...  LtdSl2rpVynXuQxHWdTh5A
# 105  https://www.yelp.com/biz/princess-louise-londo...  n_oGHFO88muDRn6vgQLjqw
# 106  https://www.yelp.com/biz/star-tavern-london?ad...  9qTCHY5yzNo7Vqbv4W0a6Q
# 107  https://www.yelp.com/biz/steins-london?adjust_...  eXNSn0FwCeSmDHDlDWzv5w
# 108  https://www.yelp.com/biz/the-rose-and-crown-lo...  zs86cdpXWDzS33aogi89pw
# 109  https://www.yelp.com/biz/camden-head-london?ad...  Ymv6S0DpQyQFtBJvom-ANw
# 110  https://www.yelp.com/biz/sir-richard-steele-lo...  ZkkkITYlRvrmk8lBdV3g3w
# 111  https://www.yelp.com/biz/stormbird-london?adju...  7L3gPAnKDPzoXo2kKJTvZA
# 112  https://www.yelp.com/biz/the-roebuck-london-3?...  SWQA_2a5HOiY9eaZmMSDaA
# 113  https://www.yelp.com/biz/vinoteca-london?adjus...  QFOUxTcxG3tB9HyxvfU1FA
#
# [114 rows x 9 columns]

# %%
# Save the dataframe to a csv file
london_restaurants_df.to_csv('Resources/London_Restaurants_German.csv')
