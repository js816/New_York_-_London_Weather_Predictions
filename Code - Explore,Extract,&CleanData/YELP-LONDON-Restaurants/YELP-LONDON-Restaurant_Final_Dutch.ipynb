# %% [markdown]
# LONDON RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
lndr_params1 = {"term":"Dutch","location":"London","limit":50,"offset":0}
lndr_response1 = requests.get(search_api_url, headers=headers, params=lndr_params1)
lndr1 = lndr_response1.json()
display(lndr1)
#print(lndr_response1.url)
#print(lndr_response1.status_code)
# Out:
# {'businesses': [{'id': 'cb3Jpyal_xLH_L_MI0zxEw',
#    'alias': 'my-old-dutch-london-5',
#    'name': 'My Old Dutch',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iBb0SAK9NE8vSWO9G-zytQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-old-dutch-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 133,
#    'categories': [{'alias': 'creperies', 'title': 'Creperies'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5175498062912,
#     'longitude': -0.121954230547052},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '131-132 High Holborn',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1V 6PS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['131-132 High Holborn',
#      'London WC1V 6PS',
#      'United Kingdom']},
#    'phone': '+442072425200',
#    'display_phone': '+44 20 7242 5200',
#    'distance': 1101.5908004258345},
#   {'id': 'XurEgYTPm4PARiqrqcotkw',
#    'alias': 'my-old-dutch-london-2',
#    'name': 'My Old Dutch',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wZc-OBa5JvHvdiZqZuYIlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-old-dutch-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5025085986798,
#     'longitude': -0.190974987903188},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '16 Kensington Church Street',
#     'address2': 'Kensington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Kensington Church Street',
#      'Kensington',
#      'London W8 4EP',
#      'United Kingdom']},
#    'phone': '+442079376090',
#    'display_phone': '+44 20 7937 6090',
#    'distance': 3977.184097835303},
#   {'id': 'uW7R_zECQ756i0b2iS3l5w',
#    'alias': 'de-hems-dutch-cafe-bar-london',
#    'name': 'De Hems Dutch Cafe Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nYApaL4bJ0nu4vUVkGR6xg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/de-hems-dutch-cafe-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5120611, 'longitude': -0.1312182},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Macclesfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 5BW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Macclesfield Street',
#      'London W1D 5BW',
#      'United Kingdom']},
#    'phone': '+442074372494',
#    'display_phone': '+44 20 7437 2494',
#    'distance': 338.9699443366357},
#   {'id': 'ci6r0vrtoyU-c3RAb-nIiA',
#    'alias': 'my-old-dutch-london-4',
#    'name': 'My Old Dutch',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Pn1PLHC6c031CMJoIUU8sw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-old-dutch-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'creperies', 'title': 'Creperies'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4864497, 'longitude': -0.1709963},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '221 Kings Road',
#     'address2': 'Chelsea',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 5EJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['221 Kings Road',
#      'Chelsea',
#      'London SW3 5EJ',
#      'United Kingdom']},
#    'phone': '+442073765650',
#    'display_phone': '+44 20 7376 5650',
#    'distance': 3797.837237314494},
#   {'id': '0dsKY-uPUemxf0ZUvIpHIA',
#    'alias': 'dutch-bike-hire-london',
#    'name': 'Dutch Bike Hire',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2rp1niwc6s32tlUQ7NoOWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dutch-bike-hire-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'active', 'title': 'Active Life'},
#     {'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.512001, 'longitude': -0.18747},
#    'transactions': [],
#    'location': {'address1': 'Queensway',
#     'address2': 'Bayswater',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Queensway',
#      'Bayswater',
#      'London W2',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3585.8296095911915},
#   {'id': 'H-l4CDhIZ0uTfyv_lR1p7Q',
#    'alias': 'belgo-centraal-london',
#    'name': 'Belgo Centraal',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8GohGojpcA36MuSYPRICww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/belgo-centraal-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 317,
#    'categories': [{'alias': 'belgian', 'title': 'Belgian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5137833644188,
#     'longitude': -0.125649969207333},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '50 Earlham Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9LJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50 Earlham Street',
#      'London WC2H 9LJ',
#      'United Kingdom']},
#    'phone': '+442078132233',
#    'display_phone': '+44 20 7813 2233',
#    'distance': 720.9118878292174},
#   {'id': '65JkA2ikIjsbBHtrUJcH2w',
#    'alias': 'lowlander-london',
#    'name': 'Lowlander',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tp9v_dWpnXTNkdf-7vxljQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lowlander-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'belgian', 'title': 'Belgian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514624, 'longitude': -0.12241},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '36 Drury Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5RR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['36 Drury Lane', 'London WC2B 5RR', 'United Kingdom']},
#    'phone': '+442073797446',
#    'display_phone': '+44 20 7379 7446',
#    'distance': 963.9661830841728},
#   {'id': '7_mJPWb6tREPW58f2xRpgA',
#    'alias': 'where-the-pancakes-are-london-2',
#    'name': 'Where the Pancakes are',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/u3gKgKG_1-RmLHhB0VQXMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/where-the-pancakes-are-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 75,
#    'categories': [{'alias': 'pancakes', 'title': 'Pancakes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.504367, 'longitude': -0.0955551},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Arch 35a',
#     'address2': '85 Southwark Bridge Road',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 0NQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Arch 35a',
#      '85 Southwark Bridge Road',
#      'London SE1 0NQ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2951.471145585305},
#   {'id': 'kZmUq5ZCVX5veOUYdqZGqg',
#    'alias': 'mrs-kibbles-olde-sweet-shoppe-london-2',
#    'name': "Mrs Kibble's Olde Sweet Shoppe",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/edCY_Yv6-Zfrfqz3wMvPqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mrs-kibbles-olde-sweet-shoppe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'candy', 'title': 'Candy Stores'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.515488, 'longitude': -0.150191},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "4 St Christopher's Place",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 1LZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["4 St Christopher's Place",
#      'London W1U 1LZ',
#      'United Kingdom']},
#    'phone': '+442079354333',
#    'display_phone': '+44 20 7935 4333',
#    'distance': 1027.3846335756277},
#   {'id': '7Q6JpFSFv997rhv7w1izNA',
#    'alias': 'the-colonel-fawcett-london',
#    'name': 'The Colonel Fawcett',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5sI0DzmCXQB1JkmxqaLbtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-colonel-fawcett-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5418041646628,
#     'longitude': -0.136007736926076},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Randolph Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 0SS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Randolph Street',
#      'London NW1 0SS',
#      'United Kingdom']},
#    'phone': '+442072679829',
#    'display_phone': '+44 20 7267 9829',
#    'distance': 3221.1646170751255},
#   {'id': 'U-Sz3hVjbZ8eaNeKGpZU_A',
#    'alias': 'borough-market-london-3',
#    'name': 'Borough Market',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EjVltsQ_qhUKdgdTMndkIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/borough-market-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1657,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5051427191678,
#     'longitude': -0.0909365332063361},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8 Southwark Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 1TL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Southwark Street',
#      'London SE1 1TL',
#      'United Kingdom']},
#    'phone': '+442030262283',
#    'display_phone': '+44 20 3026 2283',
#    'distance': 3230.9293288880117},
#   {'id': 'LtKwDYJMa1Ud_6MrsIOKvQ',
#    'alias': 'joe-and-the-juice-london',
#    'name': 'JOE & THE JUICE',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ng5sqzvKV7WOEwXfojFX0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joe-and-the-juice-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 89,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5161285, 'longitude': -0.1424872},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '281 Regent Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 2HE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['281 Regent Street',
#      'London W1B 2HE',
#      'United Kingdom']},
#    'phone': '+442073551000',
#    'display_phone': '+44 20 7355 1000',
#    'distance': 585.6274532203665},
#   {'id': 'nI1XOUOdIAh5SmQJ4b31yw',
#    'alias': 'the-v-and-a-café-london-3',
#    'name': 'The V&A Café',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OMsbe3EBlRK4FVkww4TwGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-v-and-a-caf%C3%A9-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.497374632002,
#     'longitude': -0.172478386364495},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Victoria & Albert Museum',
#     'address2': 'Cromwell Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 2RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Victoria & Albert Museum',
#      'Cromwell Road',
#      'London SW7 2RL',
#      'United Kingdom']},
#    'phone': '+442079422211',
#    'display_phone': '+44 20 7942 2211',
#    'distance': 3057.0312944343955},
#   {'id': 'Lh4GPX7fKLSbLLvFIFB0YQ',
#    'alias': 'pedler-london',
#    'name': 'Pedler',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oiniTtEM3zXOyRgSph9Phg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pedler-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.465394, 'longitude': -0.066771},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '58 Peckham Rye',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE15 4JR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['58 Peckham Rye',
#      'London SE15 4JR',
#      'United Kingdom']},
#    'phone': '+442030305015',
#    'display_phone': '+44 20 3030 5015',
#    'distance': 7154.6344277586195},
#   {'id': 'WT5EjZGp4gn9BNnzTlC2Ww',
#    'alias': 'ottolenghi-islington',
#    'name': 'Ottolenghi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y0eBCsgaeswDaLcF0m-iLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ottolenghi-islington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 212,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5397542479056,
#     'longitude': -0.102216303348541},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '287 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 2TZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['287 Upper Street',
#      'London N1 2TZ',
#      'United Kingdom']},
#    'phone': '+442072881454',
#    'display_phone': '+44 20 7288 1454',
#    'distance': 3795.717274260169},
#   {'id': 'DoHbyQU-P5MfsmBiRfTBFA',
#    'alias': 'chip-nation-london',
#    'name': 'Chip Nation',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0XyQKByPIwpNZ0J3p0q9Nw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chip-nation-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5111739, 'longitude': -0.1343177},
#    'transactions': [],
#    'location': {'address1': '40 Great Windmill Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1D 7LY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 Great Windmill Street',
#      'London W1D 7LY',
#      'United Kingdom']},
#    'phone': '+442030267150',
#    'display_phone': '+44 20 3026 7150',
#    'distance': 218.00824055872923},
#   {'id': 'HHg5hAmrb8wEwaj88yBmHA',
#    'alias': 'la-crêperie-de-hampstead-london-2',
#    'name': 'La Crêperie de Hampstead',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dCxd-sJrepsfeBpekagQWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-cr%C3%AAperie-de-hampstead-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'creperies', 'title': 'Creperies'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.55568223459, 'longitude': -0.17692025446205},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '77 Hampstead High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 1RE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['77 Hampstead High Street',
#      'London NW3 1RE',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5543.216967342599},
#   {'id': 'VtLgCcLSEwFBiKPFV6_Mug',
#    'alias': 'balthazar-london',
#    'name': 'Balthazar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jjUdrn07VkCmksfsd6RuPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/balthazar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 176,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512493, 'longitude': -0.1212219},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '4-6 Russell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5HZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4-6 Russell Street',
#      'London WC2B 5HZ',
#      'United Kingdom']},
#    'phone': '+442033011155',
#    'display_phone': '+44 20 3301 1155',
#    'distance': 1017.1328446810884},
#   {'id': 'Ee7TTtcIn7ia8D3phX_k-w',
#    'alias': 'barts-london',
#    'name': 'Barts',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TRnGRBIbGjnqrlxRKyY1vw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barts-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4926281, 'longitude': -0.1669994},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '87 Sloane Avenue',
#     'address2': 'Chelsea Cloisters',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 3DW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['87 Sloane Avenue',
#      'Chelsea Cloisters',
#      'London SW3 3DW',
#      'United Kingdom']},
#    'phone': '+442075813355',
#    'display_phone': '+44 20 7581 3355',
#    'distance': 3115.3285606117524},
#   {'id': '8vaMxxZPF1KMmD-YecIL_w',
#    'alias': 'hamiltons-chertsey',
#    'name': "Hamilton's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Z-9cH4NLG3BHIXcsu1pifA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hamiltons-chertsey?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.39234, 'longitude': -0.504544},
#    'transactions': [],
#    'location': {'address1': 'Unit 23 Windsor House',
#     'address2': 'Windsor Street',
#     'address3': '',
#     'city': 'Chertsey',
#     'zip_code': 'KT16 8AY',
#     'country': 'GB',
#     'state': 'SRY',
#     'display_address': ['Unit 23 Windsor House',
#      'Windsor Street',
#      'Chertsey KT16 8AY',
#      'United Kingdom']},
#    'phone': '+441932560745',
#    'display_phone': '+44 1932 560745',
#    'distance': 28841.174062654114},
#   {'id': 'ElxBJGffVB-jV1kMCG9PbQ',
#    'alias': 'the-national-gallery-london-2',
#    'name': 'The National Gallery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Y2mDtEARDc8m4RLXstgorA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-national-gallery-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 463,
#    'categories': [{'alias': 'artmuseums', 'title': 'Art Museums'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.508929, 'longitude': -0.128302},
#    'transactions': [],
#    'location': {'address1': 'Trafalgar Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 5DN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Trafalgar Square',
#      'London WC2N 5DN',
#      'United Kingdom']},
#    'phone': '+4420077472885',
#    'display_phone': '+44 20077472885',
#    'distance': 685.0138399344412},
#   {'id': 'zOLPCLptUE2UKRXYWCEHvg',
#    'alias': 'the-modern-pantry-london',
#    'name': 'The Modern Pantry',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xCCsKLYTjFB2it91U1ntmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-modern-pantry-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 145,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5230301121618,
#     'longitude': -0.103575187145258},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "47-48 St John's Square",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 4JJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["47-48 St John's Square",
#      'London EC1V 4JJ',
#      'United Kingdom']},
#    'phone': '+442075539210',
#    'display_phone': '+44 20 7553 9210',
#    'distance': 2510.962821457009},
#   {'id': '_uqo_Rqvo3vzZXvshge8FA',
#    'alias': 'royal-academy-of-arts-london',
#    'name': 'Royal Academy of Arts',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3uC81MQGLdnil3SVdUNu4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/royal-academy-of-arts-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 61,
#    'categories': [{'alias': 'museums', 'title': 'Museums'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.508980693997,
#     'longitude': -0.13944657577184},
#    'transactions': [],
#    'location': {'address1': '1 Piccadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 0BD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Piccadilly', 'London W1J 0BD', 'United Kingdom']},
#    'phone': '+442073008000',
#    'display_phone': '+44 20 7300 8000',
#    'distance': 492.02399060408834},
#   {'id': 'Fs5ErFF70aJ_fDrLqgD3CA',
#    'alias': 'hot-chip-london',
#    'name': 'Hot Chip',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sJbT6zEEHavUYWMEWvvBpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hot-chip-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4626349253772,
#     'longitude': -0.11377656508178},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '15-16 Brixton Food Court',
#     'address2': '20a Atlantic Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 8JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15-16 Brixton Food Court',
#      '20a Atlantic Road',
#      'London SW9 8JA',
#      'United Kingdom']},
#    'phone': '+447776210730',
#    'display_phone': '+44 7776 210730',
#    'distance': 5789.430852323424},
#   {'id': 'A4zQ6o088HDPQXsYDDtUIA',
#    'alias': 'bali-bali-london',
#    'name': 'Bali Bali',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wusYz4ZE8_-5H6riUQVcKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bali-bali-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'indonesian', 'title': 'Indonesian'},
#     {'alias': 'malaysian', 'title': 'Malaysian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.513782, 'longitude': -0.12821},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '150 Shaftesbury Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 8HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['150 Shaftesbury Avenue',
#      'London WC2H 8HL',
#      'United Kingdom']},
#    'phone': '+442078362644',
#    'display_phone': '+44 20 7836 2644',
#    'distance': 540.2805757750795},
#   {'id': 'cle1dgxqx1rXK5J2EY3rQQ',
#    'alias': 'costa-coffee-london-121',
#    'name': 'Costa Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mQfc3f29QLlJ4i6HBXjubA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/costa-coffee-london-121?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4926218, 'longitude': -0.1939531},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '198 Earls Court Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 9RQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['198 Earls Court Road',
#      'London SW5 9RQ',
#      'United Kingdom']},
#    'phone': '+442078352302',
#    'display_phone': '+44 20 7835 2302',
#    'distance': 4600.900710756483},
#   {'id': 'Yrd6_HUC4pxj6TpiCtMkrw',
#    'alias': 'mirror-room-london',
#    'name': 'Mirror Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GoQowCMQQ864qRlXPAAxUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mirror-room-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'champagne_bars', 'title': 'Champagne Bars'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5175931, 'longitude': -0.1178827},
#    'transactions': [],
#    'location': {'address1': '252 High Holborn',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC1V 7EN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['252 High Holborn',
#      'London WC1V 7EN',
#      'United Kingdom']},
#    'phone': '+442037478620',
#    'display_phone': '+44 20 3747 8620',
#    'distance': 1357.8975587955601},
#   {'id': 'KNr7pTfNYPm5xNGpdHdHwQ',
#    'alias': 'le-quecumbar-and-brasserie-london-2',
#    'name': 'Le QuecumBar & Brasserie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-XscZ63LrwlydzT3KxZxgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-quecumbar-and-brasserie-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'jazzandblues', 'title': 'Jazz & Blues'},
#     {'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.473577, 'longitude': -0.173875},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '42-44 Battersea High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW11 3HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42-44 Battersea High Street',
#      'London SW11 3HX',
#      'United Kingdom']},
#    'phone': '+442077872227',
#    'display_phone': '+44 20 7787 2227',
#    'distance': 5048.751491290247},
#   {'id': '6-SiYv2AwKatWmF_ohi20Q',
#    'alias': 'brick-lane-and-market-london',
#    'name': 'Brick Lane and Market',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5kGnXMd3ilkWAg5T6YghdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brick-lane-and-market-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 114,
#    'categories': [{'alias': 'fashion', 'title': 'Fashion'},
#     {'alias': 'farmersmarket', 'title': 'Farmers Market'},
#     {'alias': 'artsandcrafts', 'title': 'Arts & Crafts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5206479128337,
#     'longitude': -0.0725192870915743},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Brick Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6PU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Brick Lane', 'London E1 6PU', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4474.621448860984},
#   {'id': 'cy28kr98GOWJzUqf7Dg_dg',
#    'alias': 'absolutely-starving-london',
#    'name': 'Absolutely Starving',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kwgsDjzjZ9sNiJ7gkPIw7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/absolutely-starving-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5050986007288,
#     'longitude': -0.0849500457449048},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '51 Tooley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 2QN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Tooley Street',
#      'London SE1 2QN',
#      'United Kingdom']},
#    'phone': '+442074077417',
#    'display_phone': '+44 20 7407 7417',
#    'distance': 3633.267376510319},
#   {'id': '7-luWfckJm0vLx9k6QTLEw',
#    'alias': 'victoria-and-albert-museum-london-3',
#    'name': 'Victoria and Albert Museum',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cxsnwlUC_xoYIHSEC2SXVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/victoria-and-albert-museum-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 417,
#    'categories': [{'alias': 'artmuseums', 'title': 'Art Museums'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4963940559606,
#     'longitude': -0.171935630295101},
#    'transactions': [],
#    'location': {'address1': 'Cromwell Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 2RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Cromwell Road', 'London SW7 2RL', 'United Kingdom']},
#    'phone': '+442079422000',
#    'display_phone': '+44 20 7942 2000',
#    'distance': 3089.312967676907},
#   {'id': 'KEdzoG7JgKvORS5iCf0WpQ',
#    'alias': 'husk-coffee-and-creative-space-london',
#    'name': 'Husk Coffee & Creative Space',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rzgz_C0PiM76alChW3ttKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/husk-coffee-and-creative-space-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5128641363092,
#     'longitude': -0.0380804927226164},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '649 - 651 Commerical Road',
#     'address2': 'Limehouse',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E14 7LW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['649 - 651 Commerical Road',
#      'Limehouse',
#      'London E14 7LW',
#      'United Kingdom']},
#    'phone': '+442077028802',
#    'display_phone': '+44 20 7702 8802',
#    'distance': 6773.057805675593},
#   {'id': 'hCsr4V2ZcrwmpwChcASLkQ',
#    'alias': 'sunday-upmarket-london',
#    'name': 'Sunday UpMarket',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XAweafBaf-7cu4xRfNEvnQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sunday-upmarket-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 79,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5204534220778,
#     'longitude': -0.0721085071563721},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'The Old Truman Brewery',
#     'address2': '91 Brick Lane',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Old Truman Brewery',
#      '91 Brick Lane',
#      'London E1 6QL',
#      'United Kingdom']},
#    'phone': '+442077706028',
#    'display_phone': '+44 20 7770 6028',
#    'distance': 4498.394742957158},
#   {'id': '8P4qwhVKdxoV1bW-_I3s-A',
#    'alias': 'the-dairy-london-2',
#    'name': 'The Dairy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9gI0ORT8RPrbeM1xa1KNhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dairy-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4618724, 'longitude': -0.1395915},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '15 The Pavement',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW4 0HY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 The Pavement',
#      'London SW4 0HY',
#      'United Kingdom']},
#    'phone': '+442076224165',
#    'display_phone': '+44 20 7622 4165',
#    'distance': 5672.422770158091},
#   {'id': 'S9Ey-tHVx5hO4CPbthEM7Q',
#    'alias': 'way-2-save-london-3',
#    'name': 'Way 2 Save',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/way-2-save-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5462576, 'longitude': -0.2026694},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '352-354 Kilburn High Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 2QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['352-354 Kilburn High Rd',
#      'London NW6 2QJ',
#      'United Kingdom']},
#    'phone': '+442076257475',
#    'display_phone': '+44 20 7625 7475',
#    'distance': 5925.2905447189605},
#   {'id': 'O_bxw5fk2TLaKcnQGNVpsg',
#    'alias': 'snog-london-12',
#    'name': 'Snog',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Z1ZHHMvm1C8q98fE5nVXhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/snog-london-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5115736631529,
#     'longitude': -0.125741958618164},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '5 Garrick Street',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 9AR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Garrick Street',
#      'Covent Garden',
#      'London WC2E 9AR',
#      'United Kingdom']},
#    'phone': '+442030340555',
#    'display_phone': '+44 20 3034 0555',
#    'distance': 720.6097712503674},
#   {'id': 'aoMC0Tr_pBbYuUeafqVVYQ',
#    'alias': 'artesian-london-2',
#    'name': 'Artesian',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EXw35swG078qdFDj1vWvTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/artesian-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 75,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5178898198077,
#     'longitude': -0.143916606903076},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1C Portland Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 1JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1C Portland Place',
#      'London W1B 1JA',
#      'United Kingdom']},
#    'phone': '+442076361000',
#    'display_phone': '+44 20 7636 1000',
#    'distance': 786.961237222705},
#   {'id': 'w8BHTtoDhGm0osvKfbeZsg',
#    'alias': 'jerk-garden-london',
#    'name': 'Jerk Garden',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jerk-garden-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'gourmet', 'title': 'Specialty Food'},
#     {'alias': 'caribbean', 'title': 'Caribbean'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.453979, 'longitude': -0.0379514},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '394 Brockley Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE4 2BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['394 Brockley Road',
#      'London SE4 2BY',
#      'United Kingdom']},
#    'phone': '+442083202322',
#    'display_phone': '+44 20 8320 2322',
#    'distance': 9427.928062226048},
#   {'id': '1GaY9M0nxvt6NgHcmOXknQ',
#    'alias': 'coin-street-festival-london',
#    'name': 'Coin Street Festival',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coin-street-festival-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'arts', 'title': 'Arts & Entertainment'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.492195, 'longitude': -0.125095},
#    'transactions': [],
#    'location': {'address1': None,
#     'address2': 'South Bank',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1P 3JX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['South Bank', 'London SW1P 3JX', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2415.0972969789314},
#   {'id': 'emdb4ELhKKQXpJ0lIOdg0w',
#    'alias': 'nightjar-london',
#    'name': 'Nightjar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/v1lGFQT5ecwh8BFBsYJjyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nightjar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 181,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5265350341797,
#     'longitude': -0.0877109989523888},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '129 City Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 1JB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['129 City Road', 'London EC1V 1JB', 'United Kingdom']},
#    'phone': '+442072534101',
#    'display_phone': '+44 20 7253 4101',
#    'distance': 3669.2341609224163},
#   {'id': 'FJs1PrhFMFVL_iMcH69VuQ',
#    'alias': 'the-grenadier-london',
#    'name': 'The Grenadier',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yvn70RKEt4QFqJp6MfeluA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grenadier-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 188,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.501462, 'longitude': -0.155004},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18 Wilton Row',
#     'address2': '',
#     'address3': 'Belgravia',
#     'city': 'London',
#     'zip_code': 'SW1X 7NR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Wilton Row',
#      'Belgravia',
#      'London SW1X 7NR',
#      'United Kingdom']},
#    'phone': '+442072353074',
#    'display_phone': '+44 20 7235 3074',
#    'distance': 1826.8454804863936},
#   {'id': 'hF7L2L1pcPqNrE0js9xMDw',
#    'alias': 'the-wallace-collection-london',
#    'name': 'The Wallace Collection',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qfxUFD04vurEtpYmv2T5Kw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wallace-collection-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 111,
#    'categories': [{'alias': 'museums', 'title': 'Museums'},
#     {'alias': 'galleries', 'title': 'Art Galleries'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5174316756205,
#     'longitude': -0.153022552114862},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Hertford House',
#     'address2': 'Manchester Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 3BN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Hertford House',
#      'Manchester Square',
#      'London W1U 3BN',
#      'United Kingdom']},
#    'phone': '+442075639500',
#    'display_phone': '+44 20 7563 9500',
#    'distance': 1286.8143284293117},
#   {'id': '5MZcmd120PuO8Qk36gud3Q',
#    'alias': 'liverpool-street-station-london',
#    'name': 'Liverpool Street Station',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kvTYxTqp80GWoT4phCcyyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/liverpool-street-station-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'trainstations', 'title': 'Train Stations'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.518755, 'longitude': -0.081445},
#    'transactions': [],
#    'location': {'address1': 'Liverpool Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2M 7PP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Liverpool Street',
#      'London EC2M 7PP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3828.951202573996},
#   {'id': 'K16v8TAJaa_1yrCF8E7lqA',
#    'alias': 'midhurst-butchers-london',
#    'name': 'Midhurst Butchers',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BWMtbUt5ejj7wZHr7zbR8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/midhurst-butchers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'meats', 'title': 'Meat Shops'},
#     {'alias': 'butcher', 'title': 'Butcher'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5908826889912,
#     'longitude': -0.152090484925167},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Fortis Green',
#     'address2': 'Muswell Hill',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N10 3EJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Fortis Green',
#      'Muswell Hill',
#      'London N10 3EJ',
#      'United Kingdom']},
#    'phone': '+442088835303',
#    'display_phone': '+44 20 8883 5303',
#    'distance': 8749.847031163526},
#   {'id': 'HmRmh9bYb39O2W48pUTbkQ',
#    'alias': 'arts-club-london',
#    'name': 'Arts Club',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lH8SbNlAa2aQjkxImVYY0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arts-club-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'social_clubs', 'title': 'Social Clubs'},
#     {'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.508169, 'longitude': -0.142274},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '40 Dover St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 4NP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 Dover St', 'London W1S 4NP', 'United Kingdom']},
#    'phone': '+442074998581',
#    'display_phone': '+44 20 7499 8581',
#    'distance': 675.0006818911323},
#   {'id': 'M1gUkd17zi9ZYjBcSkSpIA',
#    'alias': 'le-gavroche-london',
#    'name': 'Le Gavroche',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dAz5UoYBrv5cZZzwO1db_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-gavroche-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.511300562631,
#     'longitude': -0.15507069144529},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '43 Upper Brook Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 7QR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['43 Upper Brook Street',
#      'London W1K 7QR',
#      'United Kingdom']},
#    'phone': '+442074080881',
#    'display_phone': '+44 20 7408 0881',
#    'distance': 1333.7550905711703},
#   {'id': 'IYSKMlGpn--rfzyg9MpEyQ',
#    'alias': 'camden-market-london-4',
#    'name': 'Camden Market',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-pxYKNZCaXOtYHtPO60QWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camden-market-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 503,
#    'categories': [{'alias': 'fleamarkets', 'title': 'Flea Markets'},
#     {'alias': 'localflavor', 'title': 'Local Flavor'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.541502, 'longitude': -0.14573},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Camden Lock Place',
#     'address2': 'Camden Town',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW1 8AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Camden Lock Place',
#      'Camden Town',
#      'London NW1 8AF',
#      'United Kingdom']},
#    'phone': '+442037639999',
#    'display_phone': '+44 20 3763 9999',
#    'distance': 3258.491442551086},
#   {'id': 'TGsc5V3AhitJhLBr1SIbXQ',
#    'alias': 'vegas-gallery-london',
#    'name': 'Vegas Gallery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/u_6is2LpkotARzB8dTmkow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vegas-gallery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.529886, 'longitude': -0.056789},
#    'transactions': [],
#    'location': {'address1': '274 Poyser St Railway Arches',
#     'address2': '',
#     'address3': 'London',
#     'city': 'London',
#     'zip_code': 'E2 9RF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['274 Poyser St Railway Arches',
#      'London',
#      'London E2 9RF',
#      'United Kingdom']},
#    'phone': '+442025815404',
#    'display_phone': '+44 20 2581 5404',
#    'distance': 5753.95132181259},
#   {'id': 'ZON82Y8CLkwB4ybgoGi0Mg',
#    'alias': 'temple-church-london',
#    'name': 'Temple Church',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/q_SvsI-5pRaCmNAy5_X90w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/temple-church-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'churches', 'title': 'Churches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5136903, 'longitude': -0.1108634},
#    'transactions': [],
#    'location': {'address1': '1 Inner Temple Lane',
#     'address2': '',
#     'address3': 'Temple',
#     'city': 'London',
#     'zip_code': 'EC4Y 7BB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Inner Temple Lane',
#      'Temple',
#      'London EC4Y 7BB',
#      'United Kingdom']},
#    'phone': '+442073533470',
#    'display_phone': '+44 20 7353 3470',
#    'distance': 1739.0003834528045},
#   {'id': 'tBkUQ3qQtNlX0loC-72rkg',
#    'alias': 'waitrose-and-partners-london-174',
#    'name': 'Waitrose & Partners',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_fXWjuEc1o7y54xGxcNojQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/waitrose-and-partners-london-174?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4947493970999,
#     'longitude': -0.183059296473743},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '128 Gloucester Road',
#     'address2': '128 Gloucester Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 4SF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['128 Gloucester Road',
#      '128 Gloucester Road',
#      'London SW7 4SF',
#      'United Kingdom']},
#    'phone': '+442073702424',
#    'display_phone': '+44 20 7370 2424',
#    'distance': 3830.6248934323376}],
#  'total': 104,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                Restaurant                Type Price Rating  \
# 0            My Old Dutch           Creperies    ££    3.5
# 1            My Old Dutch  Breakfast & Brunch    ££      4
# 2  De Hems Dutch Cafe Bar                Pubs    ££      4
# 3            My Old Dutch           Creperies    ££    3.5
# 4         Dutch Bike Hire         Active Life
#
#                        Address        Lat       Lng  \
# 0         131-132 High Holborn  51.517550 -0.121954
# 1  16 Kensington Church Street  51.502509 -0.190975
# 2       11 Macclesfield Street  51.512061 -0.131218
# 3               221 Kings Road  51.486450 -0.170996
# 4                    Queensway  51.512001 -0.187470
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/my-old-dutch-london-5...  cb3Jpyal_xLH_L_MI0zxEw
# 1  https://www.yelp.com/biz/my-old-dutch-london-2...  XurEgYTPm4PARiqrqcotkw
# 2  https://www.yelp.com/biz/de-hems-dutch-cafe-ba...  uW7R_zECQ756i0b2iS3l5w
# 3  https://www.yelp.com/biz/my-old-dutch-london-4...  ci6r0vrtoyU-c3RAb-nIiA
# 4

# %%
#2nd set of 50 records 51-100 
lndr_params2 = {"term":"Dutch","location":"London","limit":50,"offset":51}
lndr_response2 = requests.get(search_api_url, headers=headers, params=lndr_params2)
lndr2 = lndr_response2.json()
display(lndr2)
#print(lndr_response2.url)
#print(lndr_response2.status_code)
# Out:
# {'businesses': [{'id': '4m2-sWOvdCqjQ05lH6uy4Q',
#    'alias': 'museum-tavern-bloomsbury',
#    'name': 'Museum Tavern',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dkr0SyJ3rld7imJWCIexLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/museum-tavern-bloomsbury?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5182144172415,
#     'longitude': -0.125971101400664},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '49 Great Russell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Bloomsbury',
#     'zip_code': 'WC1B 3BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Great Russell Street',
#      'Bloomsbury WC1B 3BA',
#      'United Kingdom']},
#    'phone': '+442072428987',
#    'display_phone': '+44 20 7242 8987',
#    'distance': 913.8307272380717},
#   {'id': 'Pqi3giyMOxwjSLu0Z1F1SA',
#    'alias': 'st-georges-church-c-of-e-london',
#    'name': "St George's Church C Of E",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pKFpWmXSssO3HykYs_bTDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-georges-church-c-of-e-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'musicvideo', 'title': 'Music & DVDs'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5177614, 'longitude': -0.1255078},
#    'transactions': [],
#    'location': {'address1': '7 Little Russell Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC1A 2HR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Little Russell Street',
#      'London WC1A 2HR',
#      'United Kingdom']},
#    'phone': '+442074053044',
#    'display_phone': '+44 20 7405 3044',
#    'distance': 907.0280369912713},
#   {'id': '_abTj0y321OwKVLx5X1LUw',
#    'alias': 'elephants-head-london',
#    'name': 'Elephants Head',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/95x3kCsvpu82zlZNck4IFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elephants-head-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 59,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5407487, 'longitude': -0.1439448},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '224 Camden High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8QR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['224 Camden High Street',
#      'London NW1 8QR',
#      'United Kingdom']},
#    'phone': '+442074853130',
#    'display_phone': '+44 20 7485 3130',
#    'distance': 3152.6223438930274},
#   {'id': 'ZsvAq-7mwVE4VBB4Q82jaQ',
#    'alias': 'project-orange-london',
#    'name': 'Project Orange',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AZd6hE0cTgTeplF2wlIAMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/project-orange-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.462851913426,
#     'longitude': -0.17040910213262},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "43 St John's Hill",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW11 1TT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["43 St John's Hill",
#      'London SW11 1TT',
#      'United Kingdom']},
#    'phone': '+442075851549',
#    'display_phone': '+44 20 7585 1549',
#    'distance': 6048.229903870399},
#   {'id': 'U3Pha6qoX5MraAp5oa7oXA',
#    'alias': 'les-deux-salons-london',
#    'name': 'Les Deux Salons',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TBoImaahar84wFkOSl__hw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/les-deux-salons-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5096092224121,
#     'longitude': -0.126536995172501},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '40 - 42 William IV Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4DD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 - 42 William IV Street',
#      'London WC2N 4DD',
#      'United Kingdom']},
#    'phone': '+442074202050',
#    'display_phone': '+44 20 7420 2050',
#    'distance': 744.0166506668805},
#   {'id': '9rmZLJftZRM8dBpraKfXmg',
#    'alias': 'nags-head-london-10',
#    'name': 'Nags Head',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/x2IcoKcgFSPDgx2dOr_A0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nags-head-london-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.514061, 'longitude': -0.12088},
#    'transactions': [],
#    'location': {'address1': None,
#     'address2': 'Drury Lane',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3AS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Drury Lane', 'London WC1B 3AS', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1078.4499110250574},
#   {'id': 'nwZeSFKD0dRqDM1H4pDy3w',
#    'alias': 'look-mum-no-hands-london',
#    'name': 'Look Mum No Hands!',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/c2zdboPS3D-wrvCcrcTtpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/look-mum-no-hands-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 145,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.524013227609,
#     'longitude': -0.096938452042226},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '49 Old Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 9HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Old Street', 'London EC1V 9HX', 'United Kingdom']},
#    'phone': '+442072531025',
#    'display_phone': '+44 20 7253 1025',
#    'distance': 2972.0723030819227},
#   {'id': '7KlQYVwDJK-re5gCJp2kdw',
#    'alias': 'le-mercury-london-2',
#    'name': 'Le Mercury',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kyl7e6rH1SjOit7MuOXgVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-mercury-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 149,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.539763831626,
#     'longitude': -0.10271961840901},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '140a Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 1QY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['140a Upper Street',
#      'London N1 1QY',
#      'United Kingdom']},
#    'phone': '+442073544088',
#    'display_phone': '+44 20 7354 4088',
#    'distance': 3775.250444701267},
#   {'id': 'uNBw-V4ZYn-cXt4fc9Jw9Q',
#    'alias': 'national-portrait-gallery-london',
#    'name': 'National Portrait Gallery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JgungspLPQbo3k1K9VuNGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/national-portrait-gallery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 191,
#    'categories': [{'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.509425, 'longitude': -0.128123},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "St Martin's Place",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 0HE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["St Martin's Place",
#      'London WC2H 0HE',
#      'United Kingdom']},
#    'phone': '+442073060055',
#    'display_phone': '+44 20 7306 0055',
#    'distance': 661.5464774788601},
#   {'id': 'eVXY5kedgkTe5L279X-kfg',
#    'alias': 'portside-parlour-london-2',
#    'name': 'PortSide Parlour',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6XPK1Z2Nf-fGisSfKdMAMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/portside-parlour-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5260588, 'longitude': -0.0825125},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '14 Rivington Street',
#     'address2': 'Shoreditch',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 3DU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Rivington Street',
#      'Shoreditch',
#      'London EC2A 3DU',
#      'United Kingdom']},
#    'phone': '+442036626381',
#    'display_phone': '+44 20 3662 6381',
#    'distance': 3979.3962720365166},
#   {'id': 'BWbLNYoD08lsr8022XtdwQ',
#    'alias': 'the-chocolate-room-harrow',
#    'name': 'The Chocolate Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/S53aA5dBWv-WVJx7P7xU3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-chocolate-room-harrow?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'chocolate', 'title': 'Chocolatiers & Shops'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5809039, 'longitude': -0.3337373},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '324 Station Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Harrow',
#     'zip_code': 'HA1 2DX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['324 Station Road',
#      'Harrow HA1 2DX',
#      'United Kingdom']},
#    'phone': '+442084279391',
#    'display_phone': '+44 20 8427 9391',
#    'distance': 15631.120962640221},
#   {'id': 'OvAtlIbaaeZG3Jlhj-XOHA',
#    'alias': 'the-gilbert-scott-london',
#    'name': 'The Gilbert Scott',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/V_Rm2ylTT7J6_IwRWzI6vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-gilbert-scott-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5294649409269,
#     'longitude': -0.126171112060547},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'Euston Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 2AR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Euston Road', 'London NW1 2AR', 'United Kingdom']},
#    'phone': '+442072783888',
#    'display_phone': '+44 20 7278 3888',
#    'distance': 1969.1368552242407},
#   {'id': 'mM1b_zgmQ_Pyj8Gmc58Tpg',
#    'alias': 'tamesis-dock-london',
#    'name': 'Tamesis Dock',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5V7_cj-7dnlsJGZBwMSbQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tamesis-dock-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4885783958466,
#     'longitude': -0.12484073638916},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Albert Dock',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7TP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Albert Dock', 'London SE1 7TP', 'United Kingdom']},
#    'phone': '+442075821066',
#    'display_phone': '+44 20 7582 1066',
#    'distance': 2804.8507326998265},
#   {'id': 'bOEPov-chRVQhggY5k805w',
#    'alias': 'the-blue-legume-london',
#    'name': 'The Blue Legume',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZGvcO144Vdi31dN1q3oatA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-blue-legume-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.541374206543,
#     'longitude': -0.103168003261089},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '177 Upper St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 1RG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['177 Upper St', 'London N1 1RG', 'United Kingdom']},
#    'phone': '+442072265858',
#    'display_phone': '+44 20 7226 5858',
#    'distance': 3900.6488057505812},
#   {'id': 'm1HQUczUwC4-WfGnIfgQkg',
#    'alias': 'meatmarket-london',
#    'name': 'MEATmarket',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iSqGXOMHa2q-57URSll6GQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meatmarket-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 93,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5115639700479,
#     'longitude': -0.121881224701809},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'The Deck Jubilee Market Hall',
#     'address2': 'Tavistock Street',
#     'address3': 'Covent Garden',
#     'city': 'London',
#     'zip_code': 'WC2E 8BE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Deck Jubilee Market Hall',
#      'Tavistock Street',
#      'Covent Garden',
#      'London WC2E 8BE',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 984.1965410983465},
#   {'id': 'Si3cZkuv3ZN06lW8kcb9Mg',
#    'alias': 'the-crown-london-4',
#    'name': 'The Crown',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sPYJXe-tKkeKTNE5ay1cPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-crown-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5372627, 'longitude': -0.1096032},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '116 Cloudesley Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 0EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['116 Cloudesley Road',
#      'London N1 0EB',
#      'United Kingdom']},
#    'phone': '+442078377107',
#    'display_phone': '+44 20 7837 7107',
#    'distance': 3278.3771674687305},
#   {'id': 'hLqp-riW-FS7FJdIrX-WPQ',
#    'alias': 'rising-sun-london-2',
#    'name': 'Rising Sun',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lVf4towuOotySPeRaerJ_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rising-sun-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.519244815631,
#     'longitude': -0.13305669352495},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '46 Tottenham Court Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 2ED',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['46 Tottenham Court Road',
#      'London W1T 2ED',
#      'United Kingdom']},
#    'phone': '+442076366530',
#    'display_phone': '+44 20 7636 6530',
#    'distance': 740.3758771691805},
#   {'id': 'Ds183PwKYB6PXSygM2N-EA',
#    'alias': 'rules-london',
#    'name': 'Rules',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Bl8HeiYvldLYUV_IFMqRSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rules-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51088, 'longitude': -0.12309},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Upstairs',
#     'address2': '35 Maiden Lane',
#     'address3': 'Covent Garden',
#     'city': 'London',
#     'zip_code': 'WC2E 7LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Upstairs',
#      '35 Maiden Lane',
#      'Covent Garden',
#      'London WC2E 7LB',
#      'United Kingdom']},
#    'phone': '+442078365314',
#    'display_phone': '+44 20 7836 5314',
#    'distance': 913.8201956539808},
#   {'id': 'v8B5sOt0TFd0-OhfUw1dxQ',
#    'alias': 'kew-palace-richmond',
#    'name': 'Kew Palace',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/S5LLQ50EUgo8feimVltmuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kew-palace-richmond?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'landmarks',
#      'title': 'Landmarks & Historical Buildings'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.48366, 'longitude': -0.289758},
#    'transactions': [],
#    'location': {'address1': 'Kew Green',
#     'address2': '',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': 'TW9 3AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Kew Green', 'Richmond TW9 3AB', 'United Kingdom']},
#    'phone': '+448707515179',
#    'display_phone': '+44 870 751 5179',
#    'distance': 11681.952623322515},
#   {'id': 'Are85mULfn44Tcm9hQuH0A',
#    'alias': 'greenwich-market-london-3',
#    'name': 'Greenwich Market',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rczLAXYxfBdgYOGE8slRgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greenwich-market-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 145,
#    'categories': [{'alias': 'publicmarkets', 'title': 'Public Markets'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4810577348372,
#     'longitude': -0.0086488115868497},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5b Greenwich Market',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE10 9HZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5b Greenwich Market',
#      'London SE10 9HZ',
#      'United Kingdom']},
#    'phone': '+442082695096',
#    'display_phone': '+44 20 8269 5096',
#    'distance': 9494.82769425876},
#   {'id': 'kyDsukC9YP5aM97WajnO_g',
#    'alias': 'the-new-angel-london',
#    'name': 'The New Angel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/29L3RxrLsKn6BwlGaATWGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-new-angel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5128446, 'longitude': -0.1940695},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '39 Chepstow Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 4TS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39 Chepstow Place',
#      'London W2 4TS',
#      'United Kingdom']},
#    'phone': '+442072217620',
#    'display_phone': '+44 20 7221 7620',
#    'distance': 4021.5190006134453},
#   {'id': '-5iFMr_Ew9Tkz9iK5tNBMA',
#    'alias': 'alexandra-palace-london-3',
#    'name': 'Alexandra Palace',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4WzYpLW6YMmGrLsRp_WG_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alexandra-palace-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5939065176711,
#     'longitude': -0.130093499999995},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Alexandra Palace Way',
#     'address2': 'Wood Green',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N22 7AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Alexandra Palace Way',
#      'Wood Green',
#      'London N22 7AY',
#      'United Kingdom']},
#    'phone': '+442083652121',
#    'display_phone': '+44 20 8365 2121',
#    'distance': 9023.780772300152},
#   {'id': 'sXXkRK0cltx1CFVAQiOI6w',
#    'alias': 'boulevard-brasserie-london',
#    'name': 'Boulevard Brasserie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Me2gfKo38RulvYnmJ-uTxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boulevard-brasserie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.512475, 'longitude': -0.12074},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '40 Wellington Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 7BD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 Wellington Street',
#      'London WC2E 7BD',
#      'United Kingdom']},
#    'phone': '+442072402992',
#    'display_phone': '+44 20 7240 2992',
#    'distance': 1047.0259150795523},
#   {'id': 'SR8YJe1KLU24LOwCcVlo9w',
#    'alias': 'south-london-gallery-london',
#    'name': 'South London Gallery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WMjmMHM4eWZWwKt07CZ8Qw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/south-london-gallery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.474248, 'longitude': -0.079688},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '65 Peckham Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE5 8UH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['65 Peckham Road',
#      'London SE5 8UH',
#      'United Kingdom']},
#    'phone': '+442077036120',
#    'display_phone': '+44 20 7703 6120',
#    'distance': 5804.296809775172},
#   {'id': 'cA7GccAlTm6EdudmEUFtSA',
#    'alias': 'the-riding-house-café-london-2',
#    'name': 'The Riding House Café',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9bAQeq2H8mrMrhxgcs0-1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-riding-house-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 137,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5183614862654,
#     'longitude': -0.140664577282208},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '43-51 Great Tichfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 7PQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['43-51 Great Tichfield Street',
#      'London W1W 7PQ',
#      'United Kingdom']},
#    'phone': '+442079270840',
#    'display_phone': '+44 20 7927 0840',
#    'distance': 695.5036199468383},
#   {'id': 'I00ahdNmf_KUH-0FbDkrOQ',
#    'alias': 'the-salisbury-hotel-london',
#    'name': 'The Salisbury Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DEyjus8E5Iy2-HBNGXijqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-salisbury-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5821099309491,
#     'longitude': -0.0997781753540039},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Grand Parade',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N4 1JX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Grand Parade', 'London N4 1JX', 'United Kingdom']},
#    'phone': '+442088009617',
#    'display_phone': '+44 20 8800 9617',
#    'distance': 8098.988077805639},
#   {'id': '6kif2rPUcxOy8w2oXX5cVQ',
#    'alias': 'new-spitalfields-market-london',
#    'name': 'New Spitalfields Market',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pozlDiriRnRVaEplh6ewbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-spitalfields-market-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 51.555569, 'longitude': -0.017553},
#    'transactions': [],
#    'location': {'address1': 'Superintendant Office',
#     'address2': '23 Sherrin Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E10 5SQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Superintendant Office',
#      '23 Sherrin Road',
#      'London E10 5SQ',
#      'United Kingdom']},
#    'phone': '+442085187670',
#    'display_phone': '+44 20 8518 7670',
#    'distance': 9392.460778123439},
#   {'id': 'krhpAYE7a2A62efBLg-IRQ',
#    'alias': 'the-clapton-hart-london',
#    'name': 'The Clapton Hart',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SR-Z_QGl3tQfecIo4bvfOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-clapton-hart-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.556726, 'longitude': -0.056064},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '231 Lower Clapton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E5 8EG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['231 Lower Clapton Road',
#      'London E5 8EG',
#      'United Kingdom']},
#    'phone': '+442089858124',
#    'display_phone': '+44 20 8985 8124',
#    'distance': 7372.440647875486},
#   {'id': 'lOe25ACx2bqhC5qiQhGcTQ',
#    'alias': 'lord-wolseley-london',
#    'name': 'Lord Wolseley',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/djKVsJrU6HIziG04cCDx4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lord-wolseley-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5327808, 'longitude': -0.111223},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '55 White Lion Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9PP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55 White Lion Street',
#      'London N1 9PP',
#      'United Kingdom']},
#    'phone': '+442072784560',
#    'display_phone': '+44 20 7278 4560',
#    'distance': 2808.736723311774},
#   {'id': 'KDr8BNXyAZBXjVFN0GLXng',
#    'alias': 'st-christophers-village-london-bridge-southwark',
#    'name': "St Christopher's Village London Bridge",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IyXy2Se0b-RHC4a-7k1VbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-christophers-village-london-bridge-southwark?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'hostels', 'title': 'Hostels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.5020393421732,
#     'longitude': -0.0927776098251143},
#    'transactions': [],
#    'location': {'address1': '161 Borough High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Southwark',
#     'zip_code': 'SE1 1HR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['161 Borough High Street',
#      'Southwark SE1 1HR',
#      'United Kingdom']},
#    'phone': '+442079399710',
#    'display_phone': '+44 20 7939 9710',
#    'distance': 3220.4395893958113},
#   {'id': 'zPTsSBY1Lago2PvtOHTUYA',
#    'alias': 'lowlander-grand-cafe-london-2',
#    'name': 'Lowlander Grand Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LQyDE7sgI3th49ofcdjVtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lowlander-grand-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5136041, 'longitude': -0.0788719},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '4 Creechurch Lane',
#     'address2': 'Southwark',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EC3A 5AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Creechurch Lane',
#      'Southwark',
#      'London EC3A 5AY',
#      'United Kingdom']},
#    'phone': '+442076233999',
#    'display_phone': '+44 20 7623 3999',
#    'distance': 3951.1486974628842},
#   {'id': 'byVfWREQ9M1fDhTOI96Mcg',
#    'alias': 'goodmans-field-greater-london',
#    'name': "Goodman's Field",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kVUsFwJIxfhT3NCw_OIaEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/goodmans-field-greater-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5116913, 'longitude': -0.0728216},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '87-91 Mansell Street',
#     'address2': 'Tower Hamlets',
#     'address3': '',
#     'city': 'Greater London',
#     'zip_code': 'E1 8AN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['87-91 Mansell Street',
#      'Tower Hamlets',
#      'Greater London E1 8AN',
#      'United Kingdom']},
#    'phone': '+442076802850',
#    'display_phone': '+44 20 7680 2850',
#    'distance': 4375.6310554790825},
#   {'id': 'XSjMfPAc1EYi6NOLwJCzIA',
#    'alias': 'the-queens-gallery-london',
#    'name': "The Queen's Gallery",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W1x2ZdmfFRczFHDGGdDg_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-queens-gallery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.499837, 'longitude': -0.14234},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Buckingham Palace',
#     'address2': '5 Buckingham Gate',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1E 6JP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Buckingham Palace',
#      '5 Buckingham Gate',
#      'London SW1E 6JP',
#      'United Kingdom']},
#    'phone': '+444402077667300',
#    'display_phone': '+44 4402077667300',
#    'distance': 1511.3980972123404},
#   {'id': 'iZflMKO4RLBHO0LZfhG_3A',
#    'alias': 'hampton-court-palace-east-molesey-4',
#    'name': 'Hampton Court Palace',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WIa_QsZXYE6n6lduAhNlhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hampton-court-palace-east-molesey-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 146,
#    'categories': [{'alias': 'museums', 'title': 'Museums'},
#     {'alias': 'landmarks', 'title': 'Landmarks & Historical Buildings'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.40362, 'longitude': -0.337817},
#    'transactions': [],
#    'location': {'address1': 'Hampton Court Palace',
#     'address2': '',
#     'address3': '',
#     'city': 'East Molesey',
#     'zip_code': 'KT8 9AU',
#     'country': 'GB',
#     'state': 'SRY',
#     'display_address': ['Hampton Court Palace',
#      'East Molesey KT8 9AU',
#      'United Kingdom']},
#    'phone': '+448444827777',
#    'display_phone': '+44 844 482 7777',
#    'distance': 18522.453649536154},
#   {'id': '01pXl7HGpN-U_p31akd7Cw',
#    'alias': 'the-pommelers-rest-tower-bridge',
#    'name': 'The Pommelers Rest',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fm9TspXl-DSvoRcpYkxXsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pommelers-rest-tower-bridge?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5023852554298,
#     'longitude': -0.0772468166118542},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '196-198 Tower Bridge Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Tower Bridge',
#     'zip_code': 'SE1 2UN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['196-198 Tower Bridge Road',
#      'Tower Bridge SE1 2UN',
#      'United Kingdom']},
#    'phone': '+442073781399',
#    'display_phone': '+44 20 7378 1399',
#    'distance': 4226.075939798819},
#   {'id': 'MRMfRhnutkbUDGVLLYQ_9Q',
#    'alias': 'windmill-taverns-london',
#    'name': 'Windmill Taverns',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/S0pVqBZHGolJWXE3zDjkqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/windmill-taverns-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.502951026977,
#     'longitude': -0.10814272596907},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '86 The Cut',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8LW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['86 The Cut', 'London SE1 8LW', 'United Kingdom']},
#    'phone': '+442077879487',
#    'display_phone': '+44 20 7787 9487',
#    'distance': 2216.5890937891895},
#   {'id': 'SaifWta4q3nlvj1MrgO0Xg',
#    'alias': 'voc-grill-and-punch-house-london',
#    'name': 'VOC Grill and Punch House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-M9FNqJixs_104bMeu5ecQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/voc-grill-and-punch-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5328287841143,
#     'longitude': -0.124282836914062},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Varnishers Yard',
#     'address2': 'Regents Quarter',
#     'address3': 'Kings Cross',
#     'city': 'London',
#     'zip_code': 'N1 9AW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Varnishers Yard',
#      'Regents Quarter',
#      'Kings Cross',
#      'London N1 9AW',
#      'United Kingdom']},
#    'phone': '+442077138229',
#    'display_phone': '+44 20 7713 8229',
#    'distance': 2365.2916973050214},
#   {'id': 'OyLrjCVSSp5UUAYe9Vm0Hg',
#    'alias': 'camino-london',
#    'name': 'Camino',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TDU4TPZeSeQkrj7WyEY_Dg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camino-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 107,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'basque', 'title': 'Basque'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5312937277784,
#     'longitude': -0.121793746948242},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3 Varnishers Yard',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Varnishers Yard',
#      'London N1 9AF',
#      'United Kingdom']},
#    'phone': '+442078417331',
#    'display_phone': '+44 20 7841 7331',
#    'distance': 2274.344517625361},
#   {'id': 'X2k5CH6cJhd7Iy2-wTNuuQ',
#    'alias': 'national-maritime-museum-london',
#    'name': 'National Maritime Museum',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xtNRcJRPY-LoQSf4_bRdFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/national-maritime-museum-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'museums', 'title': 'Museums'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4809466299078,
#     'longitude': -0.00527477947460664},
#    'transactions': [],
#    'location': {'address1': 'Romney Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE10 9NF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Romney Road', 'London SE10 9NF', 'United Kingdom']},
#    'phone': '+442088584422',
#    'display_phone': '+44 20 8858 4422',
#    'distance': 9716.51921320149},
#   {'id': 'M17L9rnCeltj7Eq38DyL1A',
#    'alias': 'open-kitchen-london',
#    'name': 'Open Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r8xJR2pAYh8sqfXoz09ihg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/open-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5303725185205,
#     'longitude': -0.0801017251312715},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '40 Hoxton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 6LR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 Hoxton Street',
#      'London N1 6LR',
#      'United Kingdom']},
#    'phone': '+442076139590',
#    'display_phone': '+44 20 7613 9590',
#    'distance': 4328.538205214764},
#   {'id': '2Wk2tLxfg0iV8ZT9GMErjA',
#    'alias': 'the-swan-london-4',
#    'name': 'The Swan',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tKPS982Zim61EcMGOkfX7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-swan-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.498052518888,
#     'longitude': -0.26523814735848},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '119 Acton Lane',
#     'address2': '1 Evershed Walk',
#     'address3': 'Chiswick',
#     'city': 'London',
#     'zip_code': 'W4 5HH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['119 Acton Lane',
#      '1 Evershed Walk',
#      'Chiswick',
#      'London W4 5HH',
#      'United Kingdom']},
#    'phone': '+442089948262',
#    'display_phone': '+44 20 8994 8262',
#    'distance': 9097.63913502285},
#   {'id': 'lUkOOlQ-_8WG8al5X7GmJQ',
#    'alias': 'the-cornershop-london',
#    'name': 'The Cornershop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vtbiuLMjg9cbN2QdQxhamg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cornershop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5264282226563,
#     'longitude': -0.0782869979739189},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '123 Shoreditch High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6JE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['123 Shoreditch High Street',
#      'London E1 6JE',
#      'United Kingdom']},
#    'phone': '+442076133554',
#    'display_phone': '+44 20 7613 3554',
#    'distance': 4266.807331922487},
#   {'id': 'af_utoi1Jb5LCWGLI6IoFg',
#    'alias': 'the-slaughtered-lamb-london',
#    'name': 'The Slaughtered Lamb',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SL0i8G_9DBysk1iA_zX5kA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-slaughtered-lamb-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.523305722599,
#     'longitude': -0.10117923460476},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '34-35 Great Sutton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 0DX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['34-35 Great Sutton Street',
#      'London EC1V 0DX',
#      'United Kingdom']},
#    'phone': '+442072531516',
#    'display_phone': '+44 20 7253 1516',
#    'distance': 2673.1414115295966},
#   {'id': 'tGQs1pWWBMoerK-_tLPLNw',
#    'alias': 'fox-excel-london',
#    'name': 'Fox Excel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VpGcovWwrxdyZNVi-h8Ozg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fox-excel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.508889, 'longitude': 0.025021},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Warehouse K Excel Centre',
#     'address2': '2 Western Gateway',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E16 1DR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Warehouse K Excel Centre',
#      '2 Western Gateway',
#      'London E16 1DR',
#      'United Kingdom']},
#    'phone': '+442074732288',
#    'display_phone': '+44 20 7473 2288',
#    'distance': 11177.125939543526},
#   {'id': 'MxHY2DvmZ8GysD-HheavUQ',
#    'alias': 'the-kings-head-london-2',
#    'name': "The King's Head",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5RFikCJ2JGurSfetg8jUVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-kings-head-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.434168, 'longitude': -0.162714},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '84 Upper Tooting Road',
#     'address2': 'Tooting',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW17 7PB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['84 Upper Tooting Road',
#      'Tooting',
#      'London SW17 7PB',
#      'United Kingdom']},
#    'phone': '+442087676708',
#    'display_phone': '+44 20 8767 6708',
#    'distance': 8980.472610548606},
#   {'id': 'HjVoLxNG-tMAaGG6R9UD9w',
#    'alias': 'gordon-bennett-surbiton',
#    'name': 'Gordon Bennett',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r_K2dVqaYXePM5CF6t5Q2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gordon-bennett-surbiton?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.3947258, 'longitude': -0.3081413},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '75 Maple Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Surbiton',
#     'zip_code': 'KT6 4AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['75 Maple Road',
#      'Surbiton KT6 4AG',
#      'United Kingdom']},
#    'phone': '+442083907222',
#    'display_phone': '+44 20 8390 7222',
#    'distance': 17738.261745447286}],
#  'total': 104,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                   Restaurant          Type Price Rating  \
# 0              Museum Tavern          Pubs    ££      4
# 1  St George's Church C Of E  Music & DVDs
# 2             Elephants Head          Pubs    ££    3.5
# 3             Project Orange          Bars    ££    4.5
# 4            Les Deux Salons        French   £££      4
#
#                      Address        Lat       Lng  \
# 0    49 Great Russell Street  51.518214 -0.125971
# 1    7 Little Russell Street  51.517761 -0.125508
# 2     224 Camden High Street  51.540749 -0.143945
# 3          43 St John's Hill  51.462852 -0.170409
# 4  40 - 42 William IV Street  51.509609 -0.126537
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz