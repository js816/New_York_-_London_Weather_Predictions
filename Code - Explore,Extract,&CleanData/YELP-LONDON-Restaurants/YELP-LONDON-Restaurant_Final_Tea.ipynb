# %% [markdown]
# LONDON RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
term = "tea"

# %%
#First set of 50 records 0-50
lndr_params1 = {"term":term,"location":"London","limit":50,"offset":0}
lndr_response1 = requests.get(search_api_url, headers=headers, params=lndr_params1)
lndr1 = lndr_response1.json()
display(lndr1)
#print(lndr_response1.url)
#print(lndr_response1.status_code)
# Out:
# {'businesses': [{'id': 'PBFvhVyBi0lEJyTbyuxf5w',
#    'alias': 'the-orangery-london-7',
#    'name': 'The Orangery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L_0d22xNmfCC_d-tArBo3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-orangery-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 238,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5066360577041,
#     'longitude': -0.187725349125042},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Kensington Palace',
#     'address2': 'Palace Green',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4PX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Kensington Palace',
#      'Palace Green',
#      'London W8 4PX',
#      'United Kingdom']},
#    'phone': '+442031666113',
#    'display_phone': '+44 20 3166 6113',
#    'distance': 3648.4574890404074},
#   {'id': 'tcVWoHSko9PIy_Ec95_j1A',
#    'alias': 'candella-tea-room-london',
#    'name': 'Candella Tea Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VU1iZ4XuPbqFlUuaTFe6cg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/candella-tea-room-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5040735504425,
#     'longitude': -0.192011632025242},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '34 Kensington Church Street',
#     'address2': 'High Street',
#     'address3': 'Kensington',
#     'city': 'London',
#     'zip_code': 'W8 4HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['34 Kensington Church Street',
#      'High Street',
#      'Kensington',
#      'London W8 4HA',
#      'United Kingdom']},
#    'phone': '+442079374161',
#    'display_phone': '+44 20 7937 4161',
#    'distance': 3999.955512224944},
#   {'id': 'BjPq77aiaKZAVUHIu2S3gA',
#    'alias': 'the-english-rose-cafe-and-tea-shop-london',
#    'name': 'The English Rose Cafe and Tea Shop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B_v1cOkgPEcbr8e2rtfaog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-english-rose-cafe-and-tea-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 213,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4980558, 'longitude': -0.1444512},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 Lower Grosvenor Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 0EJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Lower Grosvenor Place',
#      'London SW1W 0EJ',
#      'United Kingdom']},
#    'phone': '+442079766280',
#    'display_phone': '+44 20 7976 6280',
#    'distance': 1745.2072668809335},
#   {'id': '6hw3LjFoZ3aLcnfxuDSJAg',
#    'alias': 'harrods-tea-room-london',
#    'name': "Harrods' Tea Room",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tRQR6OEsZ-aLJWt0yYL5MQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harrods-tea-room-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 98,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4992262754487,
#     'longitude': -0.16359383122593},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '87-135 Brompton Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7XL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['87-135 Brompton Rd',
#      'London SW1X 7XL',
#      'United Kingdom']},
#    'phone': '+442077301234',
#    'display_phone': '+44 20 7730 1234',
#    'distance': 2439.0669041104725},
#   {'id': 'wdPCcml663tzNsnBWArE0g',
#    'alias': 'the-st-ermins-tea-lounge-westminster',
#    'name': "The St. Ermin's Tea Lounge",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/--zcMqj2NmkMePwZ1fHIvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-st-ermins-tea-lounge-westminster?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4991015229692,
#     'longitude': -0.134610682725906},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Caxton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Westminster',
#     'zip_code': 'SW1H 0QW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Caxton Street',
#      'Westminster SW1H 0QW',
#      'United Kingdom']},
#    'phone': '+442072277777',
#    'display_phone': '+44 20 7227 7777',
#    'distance': 1529.9843214535217},
#   {'id': 'mBTDYaxdZ6S4QnV9raERkw',
#    'alias': 'savoy-tea-strand',
#    'name': 'Savoy Tea',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RYu1wOzuAm4_Z2sDFv746g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/savoy-tea-strand?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5105502385103,
#     'longitude': -0.121950658568569},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'The Savoy',
#     'address2': 'Covent Garden',
#     'address3': None,
#     'city': 'Strand',
#     'zip_code': 'WC2R 0EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Savoy',
#      'Covent Garden',
#      'Strand WC2R 0EU',
#      'United Kingdom']},
#    'phone': '+442078364343',
#    'display_phone': '+44 20 7836 4343',
#    'distance': 1001.9523334461319},
#   {'id': 'GSbQscE52ZfK43ykA6vLbg',
#    'alias': 'fortnum-and-mason-diamond-jubilee-tea-salon-london',
#    'name': 'Fortnum and Mason: Diamond Jubilee Tea Salon',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BnvHO-ZpEwnHqhsLLXzr0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fortnum-and-mason-diamond-jubilee-tea-salon-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 262,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5087069889729,
#     'longitude': -0.138279327972609},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '4th Floor',
#     'address2': '181 Piccadilly',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1A 1ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4th Floor',
#      '181 Piccadilly',
#      'London W1A 1ER',
#      'United Kingdom']},
#    'phone': '+448453001707',
#    'display_phone': '+44 845 300 1707',
#    'distance': 486.41760431695195},
#   {'id': '1TgYqfxkXv6-IB4cvuuy3w',
#    'alias': 'tea-and-tattle-london',
#    'name': 'Tea and Tattle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zm3bEijY0rcDGz-5Nw9sKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tea-and-tattle-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5178680419922,
#     'longitude': -0.126817002892494},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '41 Great Russell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3PE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41 Great Russell Street',
#      'London WC1B 3PE',
#      'United Kingdom']},
#    'phone': '+447722192703',
#    'display_phone': '+44 7722 192703',
#    'distance': 841.826045500197},
#   {'id': 'e5jPAqpCcIAsTtasUN5h2g',
#    'alias': 'the-wolseley-london',
#    'name': 'The Wolseley',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T9xpXsz-az88-l0Ko_KLpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wolseley-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 553,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.507617, 'longitude': -0.141012},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '160 Picadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 9EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['160 Picadilly', 'London W1J 9EB', 'United Kingdom']},
#    'phone': '+442074996996',
#    'display_phone': '+44 20 7499 6996',
#    'distance': 677.6098617325135},
#   {'id': 'lkethHYEgAT3gE-09fLWag',
#    'alias': 'yumchaa-soho-london',
#    'name': 'Yumchaa Soho',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Si6ohuBWReqcfiWiaPMNYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yumchaa-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 161,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515164726519,
#     'longitude': -0.13609727051977},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '45 Berwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8SF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Berwick Street',
#      'London W1F 8SF',
#      'United Kingdom']},
#    'phone': '+442072099641',
#    'display_phone': '+44 20 7209 9641',
#    'distance': 259.1804522380711},
#   {'id': 'QhUxOg8WBi9iQV3_rC4Mfg',
#    'alias': 'the-basement-tea-rooms-london',
#    'name': 'The Basement Tea Rooms',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WpfR5_yKTbsdIoU34hu4GA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-basement-tea-rooms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5422884690367,
#     'longitude': -0.14835063368082},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Stables Market',
#     'address2': '449-451 Chalk Farm Road',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW1 8AH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Stables Market',
#      '449-451 Chalk Farm Road',
#      'London NW1 8AH',
#      'United Kingdom']},
#    'phone': '+447405333105',
#    'display_phone': '+44 7405 333105',
#    'distance': 3385.402709640982},
#   {'id': 'eyFzHGBlLjMWmsXFdMrA3w',
#    'alias': 'fortnum-and-mason-london',
#    'name': 'Fortnum & Mason',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/l-x6jtK3UZkhp6TOKJ93UA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fortnum-and-mason-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 439,
#    'categories': [{'alias': 'accessories', 'title': 'Accessories'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#     {'alias': 'homedecor', 'title': 'Home Decor'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5083667842501,
#     'longitude': -0.138357858761537},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '181 Piccadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1A 1ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['181 Piccadilly', 'London W1A 1ER', 'United Kingdom']},
#    'phone': '+442077348040',
#    'display_phone': '+44 20 7734 8040',
#    'distance': 523.9685333656001},
#   {'id': 'm-49WP-2bBX6INAP8o9VoA',
#    'alias': 'scoff-and-banter-tea-rooms-london-3',
#    'name': 'Scoff & Banter Tea Rooms',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2VenHtdTNeHWypgOp4Nw8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scoff-and-banter-tea-rooms-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5146197, 'longitude': -0.1484107},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '350 Oxford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1C 1BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['350 Oxford Street',
#      'London W1C 1BY',
#      'United Kingdom']},
#    'phone': '+442075143456',
#    'display_phone': '+44 20 7514 3456',
#    'distance': 871.743090665736},
#   {'id': '71JEoZ_N-kNYGpub1-oz1Q',
#    'alias': 'twg-london',
#    'name': 'TWG',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YJIQ5GswEtr61YN8bllZ-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/twg-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5103312768937,
#     'longitude': -0.131230093538761},
#    'transactions': [],
#    'location': {'address1': '48 Leicester Square',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2H 7LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['48 Leicester Square',
#      'London WC2H 7LT',
#      'United Kingdom']},
#    'phone': '+442039720202',
#    'display_phone': '+44 20 3972 0202',
#    'distance': 429.522834965031},
#   {'id': 'YNduANMPzIVE8CzBH7YjEQ',
#    'alias': 'regency-café-london-2',
#    'name': 'Regency Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pz5q5e8LBG7C1ozSuhvuKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/regency-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 393,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4940143171, 'longitude': -0.13222007974201},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '17-19 Regency Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 4BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17-19 Regency Street',
#      'London SW1P 4BY',
#      'United Kingdom']},
#    'phone': '+442078216596',
#    'display_phone': '+44 20 7821 6596',
#    'distance': 2108.732795587357},
#   {'id': 'tYynO1nOy1GKxMV3jkxbmw',
#    'alias': 'the-breakfast-club-london-2',
#    'name': 'The Breakfast Club',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TElKM303HWt3LAkvgBuTWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-breakfast-club-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 497,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514733, 'longitude': -0.135406},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "33 D'Arblay Street",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["33 D'Arblay Street",
#      'London W1F 8EU',
#      'United Kingdom']},
#    'phone': '+442074342571',
#    'display_phone': '+44 20 7434 2571',
#    'distance': 215.73161782407266},
#   {'id': 'hq695SY9qohYxX5a324thw',
#    'alias': 'katsute-100-london',
#    'name': 'Katsute 100',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XaQ6_4KnqWBiJUu8Hdus1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/katsute-100-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5344633, 'longitude': -0.104346},
#    'transactions': [],
#    'location': {'address1': 'Camden Passage',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N1 8EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Camden Passage', 'London N1 8EA', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3250.5528023046013},
#   {'id': 'T_Vi4oboGjQdd0-IBBV5rg',
#    'alias': 'the-foyer-and-reading-room-london',
#    'name': 'The Foyer and Reading Room',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aI4DPBk9K3BEp1YGmSXCCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-foyer-and-reading-room-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5128199, 'longitude': -0.1475618},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': "Claridge's",
#     'address2': 'Brook Street',
#     'address3': 'Mayfair',
#     'city': 'London',
#     'zip_code': 'W1K 4HR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["Claridge's",
#      'Brook Street',
#      'Mayfair',
#      'London W1K 4HR',
#      'United Kingdom']},
#    'phone': '+442071078886',
#    'display_phone': '+44 20 7107 8886',
#    'distance': 803.1468843661861},
#   {'id': 'QqKWAOWglGHzqaFTqJhxAA',
#    'alias': 'the-tea-house-london',
#    'name': 'The Tea House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pTIZHaFXwx4lh2EMGyKEIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-tea-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5135923, 'longitude': -0.1247242},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '15 Neal Street',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9PU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Neal Street',
#      'Covent Garden',
#      'London WC2H 9PU',
#      'United Kingdom']},
#    'phone': '+442072407539',
#    'display_phone': '+44 20 7240 7539',
#    'distance': 781.7731871968144},
#   {'id': '6NIJqOFjLUPXnGaJbxW3lA',
#    'alias': 'l-eto-london-2',
#    'name': "L'ETO",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wPsMI8cgIW_5JjqdEcUhgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-eto-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.496624, 'longitude': -0.1688603},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '243 Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['243 Brompton Road', 'London SW3', 'United Kingdom']},
#    'phone': '+442078542860',
#    'display_phone': '+44 20 7854 2860',
#    'distance': 2898.9080858295915},
#   {'id': 'r-USboJFp1ifbtFWtbTGhQ',
#    'alias': 'paper-and-cup-london-2',
#    'name': 'Paper and Cup',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XkBLH87FtSkzIaMMSnmN3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paper-and-cup-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5262201, 'longitude': -0.076815},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '18 Calvert Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7JP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Calvert Avenue',
#      'London E2 7JP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4354.245310616501},
#   {'id': '-22PaX8rQyh0ZQrdCiDz4A',
#    'alias': 'fuckoffee-london-3',
#    'name': 'Fuckoffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MQ7RV7bMOSjdLX1DfhzQ_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fuckoffee-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 87,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4993814, 'longitude': -0.0812485},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '163-167 Bermondsey Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 3UW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['163-167 Bermondsey Street',
#      'London SE1 3UW',
#      'United Kingdom']},
#    'phone': '+442074037655',
#    'display_phone': '+44 20 7403 7655',
#    'distance': 4071.1885164771065},
#   {'id': 'n2bhQ85Vk9pT77jb4th38A',
#    'alias': 'crumbs-and-doilies-london',
#    'name': 'Crumbs and Doilies',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vZzB_zJMf0NKTG4TaSZwTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crumbs-and-doilies-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512258, 'longitude': -0.138374},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '1 Kingly Court',
#     'address2': 'Carnaby Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5PW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Kingly Court',
#      'Carnaby Street',
#      'London W1B 5PW',
#      'United Kingdom']},
#    'phone': '+442088748885',
#    'display_phone': '+44 20 8874 8885',
#    'distance': 179.24059999393177},
#   {'id': 'ttV7LFe4atjb9c7MZHn7Bw',
#    'alias': 'beas-of-bloomsbury-marylebone-city-of-westminster',
#    'name': "Bea's of Bloomsbury - Marylebone",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RqrfxQ47yXv2ZQTeQCnevA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beas-of-bloomsbury-marylebone-city-of-westminster?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5223, 'longitude': -0.14439},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '27A Devonshire Street',
#     'address2': None,
#     'address3': '',
#     'city': 'City of Westminster',
#     'zip_code': 'W1W 5',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['27A Devonshire Street',
#      'City of Westminster W1W 5',
#      'United Kingdom']},
#    'phone': '+442074869669',
#    'display_phone': '+44 20 7486 9669',
#    'distance': 1203.3819687531186},
#   {'id': 'iOWE6hNrBkraWR4kf0w3MA',
#    'alias': 'camellias-tea-house-london-2',
#    'name': "Camellia's Tea House",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jAH7TOr4qgnlJaigEVQFMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camellias-tea-house-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.518644, 'longitude': -0.124841},
#    'transactions': [],
#    'location': {'address1': '64 Great Russell St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC1B 3BL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['64 Great Russell St',
#      'London WC1B 3BL',
#      'United Kingdom']},
#    'phone': '+442072422308',
#    'display_phone': '+44 20 7242 2308',
#    'distance': 1004.3282518763993},
#   {'id': 'bPbHHWSUbEQ82X2-ZUcVYQ',
#    'alias': 'peggy-porschen-cakes-london',
#    'name': 'Peggy Porschen Cakes',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c_IC2X6VwcQEK8REEtmceQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peggy-porschen-cakes-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 102,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.493261207677,
#     'longitude': -0.150525569915771},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '116 Ebury Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 9QQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['116 Ebury Street',
#      'London SW1W 9QQ',
#      'United Kingdom']},
#    'phone': '+442077301316',
#    'display_phone': '+44 20 7730 1316',
#    'distance': 2398.834581982357},
#   {'id': 'riWepzZEIHj82UiDk_WVLQ',
#    'alias': 'montparnasse-cafe-london-2',
#    'name': 'Montparnasse Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/90P9GQECkOj3aZIrJfpO8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/montparnasse-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5005205, 'longitude': -0.1885342},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '22 Thackeray Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 5ET',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Thackeray Street',
#      'London W8 5ET',
#      'United Kingdom']},
#    'phone': '+442073762212',
#    'display_phone': '+44 20 7376 2212',
#    'distance': 3888.086719460034},
#   {'id': 'Jwph04sxmidfud2Mpx4Ltg',
#    'alias': 'twinings-london',
#    'name': 'Twinings',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1ehcnUKJipTedAEwwkxqsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/twinings-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'coffeeteasupplies',
#      'title': 'Coffee & Tea Supplies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5132251, 'longitude': -0.1129045},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '216 Strand',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2R 1AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['216 Strand', 'London WC2R 1AP', 'United Kingdom']},
#    'phone': '+442073533511',
#    'display_phone': '+44 20 7353 3511',
#    'distance': 1599.823137914137},
#   {'id': '5or4AzNouZq8RClNeTdqiA',
#    'alias': 'ole-and-steen-london-2',
#    'name': 'Ole and Steen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HhmDFvGw42MnOJErQE9vkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ole-and-steen-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.509238, 'longitude': -0.1326965},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '56 Haymarket',
#     'address2': '',
#     'address3': "No 2 St James's Market",
#     'city': 'London',
#     'zip_code': 'SW1Y 4RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['56 Haymarket',
#      "No 2 St James's Market",
#      'London SW1Y 4RP',
#      'United Kingdom']},
#    'phone': '+442038288242',
#    'display_phone': '+44 20 3828 8242',
#    'distance': 459.23424350084883},
#   {'id': 'KcTG8dVnattBQaWXdIzMrg',
#    'alias': 'feya-london',
#    'name': 'Feya',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/29bCWknB8eqsYuHmY2ii3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/feya-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51509, 'longitude': -0.1508},
#    'transactions': [],
#    'location': {'address1': '23 James St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1U 1DT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23 James St', 'London W1U 1DT', 'United Kingdom']},
#    'phone': '+442078580858',
#    'display_phone': '+44 20 7858 0858',
#    'distance': 1056.5656492391608},
#   {'id': 'OGDGdRZgbcRFE7oYFWU9jw',
#    'alias': 'the-rose-lounge-london',
#    'name': 'The Rose Lounge',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gF-Z8EMOdRzpNFIAYVDF6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-rose-lounge-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.507811, 'longitude': -0.1328967},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Sofitel St James',
#     'address2': '6 Waterloo Place',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 4AN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Sofitel St James',
#      '6 Waterloo Place',
#      'London SW1Y 4AN',
#      'United Kingdom']},
#    'phone': '+442077472200',
#    'display_phone': '+44 20 7747 2200',
#    'distance': 629.3016985320504},
#   {'id': '0r2-fwgLvuOLef0epiFkFQ',
#    'alias': 'granger-and-co-london',
#    'name': 'Granger & Co',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4pSTSM2JgsADC_cPoLBQJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/granger-and-co-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 183,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514646148453,
#     'longitude': -0.19779915622354},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '175 Westbourne Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['175 Westbourne Grove',
#      'London W11 2SB',
#      'United Kingdom']},
#    'phone': '+442072299111',
#    'display_phone': '+44 20 7229 9111',
#    'distance': 4284.263019990538},
#   {'id': '-d_5w-b7cjo9f-M-f_57pA',
#    'alias': 'biju-bubble-tea-room-london',
#    'name': 'Biju Bubble Tea Room',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fuL7ZSHk7SUf0ZwhgcHEQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/biju-bubble-tea-room-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 144,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5127048, 'longitude': -0.1321942},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '45 Old Compton Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6HQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Old Compton Street',
#      'Soho',
#      'London W1D 6HQ',
#      'United Kingdom']},
#    'phone': '+442072874040',
#    'display_phone': '+44 20 7287 4040',
#    'distance': 258.85569262069225},
#   {'id': 'ZD20gmNMmnU_IGfCIyHh5g',
#    'alias': 'my-cup-of-tea-london',
#    'name': 'My Cup Of Tea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ev5q55QIZ70P9x523tSLdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-cup-of-tea-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5108947753906,
#     'longitude': -0.13432365655899},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '5 Denman Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 7AH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Denman Place', 'London W1D 7AH', 'United Kingdom']},
#    'phone': '+442072872255',
#    'display_phone': '+44 20 7287 2255',
#    'distance': 198.56211464972722},
#   {'id': 'ZUIJ8U6GU6TLx29lcwIyvg',
#    'alias': 'urban-tea-rooms-london',
#    'name': 'Urban Tea Rooms',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XMrZyD4PVAmkdBbkb6Evlg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/urban-tea-rooms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512947, 'longitude': -0.139558},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '19 Kingly Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5PY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Kingly Street',
#      'London W1B 5PY',
#      'United Kingdom']},
#    'phone': '+442074343767',
#    'display_phone': '+44 20 7434 3767',
#    'distance': 248.67741461823445},
#   {'id': '-EPJuMu8Qbr5azjHu_QOtg',
#    'alias': 'the-watch-house-london-5',
#    'name': 'The Watch House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/v6IlbI-P0BgzdTxXQcQn2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-watch-house-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4980461313304,
#     'longitude': -0.0810502413027092},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '199 Bermondsey Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 3UW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['199 Bermondsey Street',
#      'London SE1 3UW',
#      'United Kingdom']},
#    'phone': '+442074075431',
#    'display_phone': '+44 20 7407 5431',
#    'distance': 4140.698976372922},
#   {'id': 'IWl1Y0eQOZSnYeIDw94svg',
#    'alias': 'monmouth-coffee-london',
#    'name': 'Monmouth Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-eZOw_Lts2a7dWXNYekA_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/monmouth-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 306,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5055383383613,
#     'longitude': -0.0914615294783139},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Park Street',
#     'address2': 'The Borough',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Park Street',
#      'The Borough',
#      'London SE1 9AB',
#      'United Kingdom']},
#    'phone': '+442072323010',
#    'display_phone': '+44 20 7232 3010',
#    'distance': 3184.4018654070014},
#   {'id': 'pOQwGM-8Qrwb8PGzLDGyeg',
#    'alias': 'queen-elizabeth-roof-garden-bar-and-café-southbank-centre-2',
#    'name': 'Queen Elizabeth Roof Garden Bar & Café',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8KH-8QITcveXy9JjR8GTGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/queen-elizabeth-roof-garden-bar-and-caf%C3%A9-southbank-centre-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.50571, 'longitude': -0.116686820983887},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Queen Elizabeth Hall',
#     'address2': 'Southbank Centre',
#     'address3': '',
#     'city': 'Southbank Centre',
#     'zip_code': 'SE1 8XX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Queen Elizabeth Hall',
#      'Southbank Centre',
#      'Southbank Centre SE1 8XX',
#      'United Kingdom']},
#    'phone': '+442079210758',
#    'display_phone': '+44 20 7921 0758',
#    'distance': 1551.1575341559812},
#   {'id': 'cse6Zq5WyXkOxfVjFd5Ftw',
#    'alias': 'original-maids-of-honour-richmond-2',
#    'name': 'Original Maids Of Honour',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VL6482QwkhFwy9t3zegrSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/original-maids-of-honour-richmond-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.480649607176,
#     'longitude': -0.288493910450711},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '288 Kew Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': 'TW9 3DU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['288 Kew Road', 'Richmond TW9 3DU', 'United Kingdom']},
#    'phone': '+442089402752',
#    'display_phone': '+44 20 8940 2752',
#    'distance': 11149.510856546958},
#   {'id': 'O_SZ2sBo0f2cryOyePojfw',
#    'alias': 'golden-tea-london',
#    'name': 'Golden Tea',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zCNAqpnBTUdtXRuYonDkSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/golden-tea-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.52532, 'longitude': -0.07047},
#    'transactions': [],
#    'location': {'address1': '156 Bethnal Green Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 6DG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['156 Bethnal Green Road',
#      'London E2 6DG',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4740.024245434636},
#   {'id': 'MIKUeHBDQs46i6YOVeNKyw',
#    'alias': 'h-r-higgins-london',
#    'name': 'H R Higgins',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eAfRQlbtrCwZ8MP0k8Uisw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/h-r-higgins-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5129642, 'longitude': -0.1508551},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '79 Duke Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1K 5AS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['79 Duke Street', 'London W1K 5AS', 'United Kingdom']},
#    'phone': '+442074918819',
#    'display_phone': '+44 20 7491 8819',
#    'distance': 1031.1420005559974},
#   {'id': 'MY5vPpDxJFPzj-wR4_pUsg',
#    'alias': 'crumpets-london',
#    'name': 'Crumpets',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2GXRSS7bftG4X6Z-0Q4VxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crumpets-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4991936, 'longitude': -0.1382647},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '82 Buckingham Gate',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1E 6PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['82 Buckingham Gate',
#      'London SW1E 6PD',
#      'United Kingdom']},
#    'phone': '+442072331479',
#    'display_phone': '+44 20 7233 1479',
#    'distance': 1525.3047584226708},
#   {'id': 'FM2fOny0zttmwnSeHCHzyA',
#    'alias': 'fabrique-bakery-london-5',
#    'name': 'Fabrique Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1-A9bxyUwournvQ4hL3sMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fabrique-bakery-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516469, 'longitude': -0.205223},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '212 Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 1LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['212 Portobello Road',
#      'London W11 1LA',
#      'United Kingdom']},
#    'phone': '+442072213721',
#    'display_phone': '+44 20 7221 3721',
#    'distance': 4813.9954429630825},
#   {'id': 'zf9tnxwaDRLh7sRSeK6_uw',
#    'alias': 'gonuts-boba-tea-london',
#    'name': 'Gonuts Boba Tea',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OTlr4KWHggDmHOsLt75axw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gonuts-boba-tea-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.55261, 'longitude': -0.11197},
#    'transactions': [],
#    'location': {'address1': '228 Holloway Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N7 8DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['228 Holloway Road',
#      'London N7 8DA',
#      'United Kingdom']},
#    'phone': '+442080010812',
#    'display_phone': '+44 20 8001 0812',
#    'distance': 4722.114913333944},
#   {'id': 'RYus9YxVxD-R8jm6xkDX8g',
#    'alias': 'red-door-london',
#    'name': 'Red Door',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Wpge_vSiPdmdj5nk00vX0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/red-door-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'galleries', 'title': 'Art Galleries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.481164, 'longitude': -0.009072},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10 Turnpin Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE10 9JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Turnpin Lane',
#      'London SE10 9JA',
#      'United Kingdom']},
#    'phone': '+442088582131',
#    'display_phone': '+44 20 8858 2131',
#    'distance': 9456.14762342682},
#   {'id': 'D_HGFJqfB8AS33iXXrHIIQ',
#    'alias': 'kova-patisserie-london',
#    'name': 'Kova Patisserie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-5-9ySe3MKeTKJd_nxcNlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kova-patisserie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514325, 'longitude': -0.134068},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "9-12 Saint Anne's Court",
#     'address2': 'Unit 5',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1F 0BB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["9-12 Saint Anne's Court",
#      'Unit 5',
#      'London W1F 0BB',
#      'United Kingdom']},
#    'phone': '+442074949866',
#    'display_phone': '+44 20 7494 9866',
#    'distance': 211.4462471110243},
#   {'id': 'OGW03dLcEui-6CWZIucVMw',
#    'alias': 'laduree-london-14',
#    'name': 'Laduree',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gnAH2qu0IqhJq3NQA1h8Jg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laduree-london-14?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'macarons', 'title': 'Macarons'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5083572494815,
#     'longitude': -0.139577354757421},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '71-72 Burlington Arcade',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 0QX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['71-72 Burlington Arcade',
#      'London W1J 0QX',
#      'United Kingdom']},
#    'phone': '+442074919155',
#    'display_phone': '+44 20 7491 9155',
#    'distance': 557.4749357668763},
#   {'id': 'x5vg6DMQQjiuZ2SQVKhIAg',
#    'alias': 'ladurée-london-8',
#    'name': 'Ladurée',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/h8Pp-zN6jYrCJ5nbwRx96Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ladur%C3%A9e-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 127,
#    'categories': [{'alias': 'delicatessen', 'title': 'Delicatessen'},
#     {'alias': 'macarons', 'title': 'Macarons'},
#     {'alias': 'chocolate', 'title': 'Chocolatiers & Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4984851733343,
#     'longitude': -0.162618309259415},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '87 Brompton Road',
#     'address2': 'Harrods',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7XL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['87 Brompton Road',
#      'Harrods',
#      'London SW1X 7XL',
#      'United Kingdom']},
#    'phone': '+442031550111',
#    'display_phone': '+44 20 3155 0111',
#    'distance': 2439.5817151439915},
#   {'id': 'Wv1Zlca4NTkgFVjKgEJyog',
#    'alias': 'poilane-london',
#    'name': 'Poilane',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MxEA4XTmPnw2OAaRPCqi7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/poilane-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.492054852899, 'longitude': -0.1597783672174},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '39 Cadogan Gardens',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 2TB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39 Cadogan Gardens',
#      'London SW3 2TB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2838.7103460697786},
#   {'id': 'mOD60RafvMIEv0PR0QqV-g',
#    'alias': 'the-rosebery-lounge-london',
#    'name': 'The Rosebery Lounge',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/s_HF9blFPjxAvkRh1lVC2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-rosebery-lounge-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.502405, 'longitude': -0.159971},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '66 Knightsbridge',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Knightsbridge',
#      'London SW1X 7LA',
#      'United Kingdom']},
#    'phone': '+442072013828',
#    'display_phone': '+44 20 7201 3828',
#    'distance': 2037.494114265099}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                            Restaurant          Type Price Rating  \
# 0                        The Orangery       British   £££      4
# 1                   Candella Tea Room     Tea Rooms    ££    4.5
# 2  The English Rose Cafe and Tea Shop  Coffee & Tea    ££    4.5
# 3                   Harrods' Tea Room    Sandwiches    ££      4
# 4          The St. Ermin's Tea Lounge     Tea Rooms    ££    4.5
#
#                        Address        Lat       Lng  \
# 0            Kensington Palace  51.506636 -0.187725
# 1  34 Kensington Church Street  51.504074 -0.192012
# 2      4 Lower Grosvenor Place  51.498056 -0.144451
# 3           87-135 Brompton Rd  51.499226 -0.163594
# 4              2 Caxton Street  51.499102 -0.134611
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/the-orangery-london-7...  PBFvhVyBi0lEJyTbyuxf5w
# 1  https://www.yelp.com/biz/candella-tea-room-lon...  tcVWoHSko9PIy_Ec95_j1A
# 2  https://www.yelp.com/biz/the-english-rose-cafe...  BjPq77aiaKZAVUHIu2S3gA
# 3  https://www.yelp.com/biz/harrods-tea-room-lond...  6hw3LjFoZ3aLcnfxuDSJAg
# 4  https://www.yelp.com/biz/the-st-ermins-tea-lou...  wdPCcml663tzNsnBWArE0g

# %%
#2nd set of 50 records 51-100 
lndr_params2 = {"term":term,"location":"London","limit":50,"offset":51}
lndr_response2 = requests.get(search_api_url, headers=headers, params=lndr_params2)
lndr2 = lndr_response2.json()
display(lndr2)
#print(lndr_response2.url)
#print(lndr_response2.status_code)
# Out:
# {'businesses': [{'id': '8hz9UOfK0mIsAzs90vrN8Q',
#    'alias': 'the-muffin-man-tea-shop-london',
#    'name': 'The Muffin Man Tea Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kPTPhO63d2YD2pl6ZsmyIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-muffin-man-tea-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 106,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.49944, 'longitude': -0.1928114},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '12 Wrights Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 6TA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Wrights Lane', 'London W8 6TA', 'United Kingdom']},
#    'phone': '+442079376652',
#    'display_phone': '+44 20 7937 6652',
#    'distance': 4202.319177271801},
#   {'id': 'RJd6_J2dekhZT3g7S2sFKQ',
#    'alias': 'ripe-kitchen-london',
#    'name': 'Ripe Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eWdcUDw5jrPd2z1GjchEdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ripe-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'healthmarkets', 'title': 'Health Markets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5406973, 'longitude': -0.1572616},
#    'transactions': [],
#    'location': {'address1': '136 Regents Park Road',
#     'address2': 'Primrose Hill',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8XL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['136 Regents Park Road',
#      'Primrose Hill',
#      'London NW1 8XL',
#      'United Kingdom']},
#    'phone': '+447572480102',
#    'display_phone': '+44 7572 480102',
#    'distance': 3430.830308059021},
#   {'id': '1OKrknY5Vize2MyC5l31Eg',
#    'alias': 'tea-and-glory-camden',
#    'name': 'Tea & Glory',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0lCqSN2S9n7LBlVsmJ8kEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tea-and-glory-camden?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5426727708367,
#     'longitude': -0.147332400083542},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '29 Chalk Farm Road',
#     'address2': '',
#     'address3': None,
#     'city': 'Camden',
#     'zip_code': 'NW1 8AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['29 Chalk Farm Road',
#      'Camden NW1 8AG',
#      'United Kingdom']},
#    'phone': '+447714752348',
#    'display_phone': '+44 7714 752348',
#    'distance': 3409.8143941874987},
#   {'id': 'XqYhhs7WWgOnP_e5x3Wg8g',
#    'alias': 'garden-shack-hideaway-london',
#    'name': 'Garden Shack Hideaway',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iGtACYivM-UcH1iQyS19Zg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/garden-shack-hideaway-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5027676843354,
#     'longitude': -0.115942216752501},
#    'transactions': [],
#    'location': {'address1': '55 York Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 7NJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55 York Rd', 'London SE1 7NJ', 'United Kingdom']},
#    'phone': '+447912106692',
#    'display_phone': '+44 7912 106692',
#    'distance': 1780.9533069366198},
#   {'id': 'KLofVP70jrDEnxBLkoSmmw',
#    'alias': 'the-english-tea-room-london-2',
#    'name': 'The English Tea Room',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pxHdMyPzZA2f42HASXlsxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-english-tea-room-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5091362709689,
#     'longitude': -0.1421633976617},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '30 Albemarle Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 4BP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Albemarle Street',
#      'London W1S 4BP',
#      'United Kingdom']},
#    'phone': '+442074936020',
#    'display_phone': '+44 20 7493 6020',
#    'distance': 594.7640988997952},
#   {'id': 'UjsIWFM9xcD9PCO0nJoMCQ',
#    'alias': 'caffe-in-london',
#    'name': 'Caffe In',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O4NH7q62sJXw765I_8fEvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-in-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.506194, 'longitude': -0.146446},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3 Shepherd Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 7HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Shepherd Street',
#      'London W1J 7HL',
#      'United Kingdom']},
#    'phone': '+442074936400',
#    'display_phone': '+44 20 7493 6400',
#    'distance': 1032.7212314091926},
#   {'id': '840LCp_kSXT7TMfCi1Utpg',
#    'alias': 'whittard-of-chelsea-london-17',
#    'name': 'Whittard of Chelsea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/P0GQNUlNLPtvAnPP2Cqsrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/whittard-of-chelsea-london-17?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeteasupplies', 'title': 'Coffee & Tea Supplies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5086702280449,
#     'longitude': -0.134049813491856},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '13 Regent Street',
#     'address2': 'St James',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 4LR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Regent Street',
#      'St James',
#      'London SW1Y 4LR',
#      'United Kingdom']},
#    'phone': '+442079308013',
#    'display_phone': '+44 20 7930 8013',
#    'distance': 481.5750672091083},
#   {'id': 'mdy8N4wPOlOSiatLWKjLGg',
#    'alias': 'the-borough-barista-london',
#    'name': 'The Borough Barista',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5BOQF57dPe1EaVvhzb0wtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-borough-barista-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.514461025878,
#     'longitude': -0.16090849657059},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '60A Seymour Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7JN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['60A Seymour Street',
#      'London W1H 7JN',
#      'United Kingdom']},
#    'phone': '+442075637222',
#    'display_phone': '+44 20 7563 7222',
#    'distance': 1736.1517070034572},
#   {'id': 'k7qmLDOGfESN8fDBQZZL7w',
#    'alias': '106-baker-st-london',
#    'name': '106 Baker St',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9CXBPhU2Ib_gv7QmtYAMCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/106-baker-st-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5207977, 'longitude': -0.1566825},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '106 Baker Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 6TW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['106 Baker Street',
#      'London W1U 6TW',
#      'United Kingdom']},
#    'phone': '+442074873372',
#    'display_phone': '+44 20 7487 3372',
#    'distance': 1689.8849777286025},
#   {'id': 'UxuxEoIWnQQNPMdNzBJPJQ',
#    'alias': 'mariage-freres-london',
#    'name': 'Mariage Freres',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Efdu-Oz-hL1XJC_SygBoNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mariage-freres-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5118571, 'longitude': -0.1243388},
#    'transactions': [],
#    'location': {'address1': '38 King Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2E 8JS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38 King Street',
#      'London WC2E 8JS',
#      'United Kingdom']},
#    'phone': '+442078361854',
#    'display_phone': '+44 20 7836 1854',
#    'distance': 815.2586931885163},
#   {'id': 'Yrd6_HUC4pxj6TpiCtMkrw',
#    'alias': 'mirror-room-london',
#    'name': 'Mirror Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GoQowCMQQ864qRlXPAAxUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mirror-room-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'champagne_bars', 'title': 'Champagne Bars'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5175931, 'longitude': -0.1178827},
#    'transactions': [],
#    'location': {'address1': '252 High Holborn',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC1V 7EN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['252 High Holborn',
#      'London WC1V 7EN',
#      'United Kingdom']},
#    'phone': '+442037478620',
#    'display_phone': '+44 20 3747 8620',
#    'distance': 1357.8975587955601},
#   {'id': 'XN7K4g1Wq-93WYvg85EgMg',
#    'alias': 'the-gentlemen-baristas-london',
#    'name': 'The Gentlemen Baristas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/weXGI3HolMjieVD466xwyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-gentlemen-baristas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.503841999477,
#     'longitude': -0.0947035655992168},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '63 Union Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1SG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63 Union Street',
#      'London SE1 1SG',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3025.052485481412},
#   {'id': 'y8xX3BDj1bf7-wc4Q9Atvg',
#    'alias': 'the-monocle-cafe-london',
#    'name': 'The Monocle Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WVPzYgrKif_v7M9hkSshJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-monocle-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 69,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5188109085709,
#     'longitude': -0.154666668198166},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '18 Chiltern Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 7QA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Chiltern Street',
#      'London W1U 7QA',
#      'United Kingdom']},
#    'phone': '+442071352040',
#    'display_phone': '+44 20 7135 2040',
#    'distance': 1455.2587544542089},
#   {'id': 'rKwkCvsSfp8z7w1CmNnMMQ',
#    'alias': 'the-table-london-8',
#    'name': 'The Table',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/T-rwpQYiLxDyUXGNAwEYSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-table-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 268,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.505604, 'longitude': -0.099671},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '83 Southwark Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Southwark Street',
#      'London SE1 0HX',
#      'United Kingdom']},
#    'phone': '+442074012760',
#    'display_phone': '+44 20 7401 2760',
#    'distance': 2636.7435245046486},
#   {'id': '5H4EEA8Sdqy1L_xFY9xSUw',
#    'alias': 'white-mulberries-london',
#    'name': 'White Mulberries',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IMvRHPQJRmhhvlkLW5uJVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/white-mulberries-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.507252, 'longitude': -0.071157},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit D3',
#     'address2': 'Ivory House',
#     'address3': 'St Katharine Docks',
#     'city': 'London',
#     'zip_code': 'E1W 1AT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit D3',
#      'Ivory House',
#      'St Katharine Docks',
#      'London E1W 1AT',
#      'United Kingdom']},
#    'phone': '+447507572600',
#    'display_phone': '+44 7507 572600',
#    'distance': 4527.184767844278},
#   {'id': '60FKzb3X3kkuv29_P-PPMw',
#    'alias': 'fait-maison-london-3',
#    'name': 'Fait Maison',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mxkd73WcbWEQqqJ3_a7mNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fait-maison-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.498051, 'longitude': -0.184063},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '50 Gloucester Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 4QT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50 Gloucester Road',
#      'London SW7 4QT',
#      'United Kingdom']},
#    'phone': '+442079980071',
#    'display_phone': '+44 20 7998 0071',
#    'distance': 3710.7500937380755},
#   {'id': 'F_LaVYcB8-Fha_iS72kUxg',
#    'alias': 'to-a-tea-london',
#    'name': 'To A Tea',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZsxVJ_XfBEdzJ5E_BzdY4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/to-a-tea-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515112, 'longitude': -0.104413},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 Farringdon Street',
#     'address2': 'Five Feet Place',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4A 4AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Farringdon Street',
#      'Five Feet Place',
#      'London EC4A 4AB',
#      'United Kingdom']},
#    'phone': '+442072483498',
#    'display_phone': '+44 20 7248 3498',
#    'distance': 2197.3651067721244},
#   {'id': '0MWn2dt-a5boV59-ZgcKuQ',
#    'alias': 'victorian-afternoon-tea-victoria-and-albert-musuem-london',
#    'name': 'Victorian Afternoon Tea - Victoria and Albert Musuem',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bax0A6xFaVGIXdjSGHfOiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/victorian-afternoon-tea-victoria-and-albert-musuem-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.49555, 'longitude': -0.17624},
#    'transactions': [],
#    'location': {'address1': 'Cromwell Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW7 2RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Cromwell Road', 'London SW7 2RL', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3910.967921732078},
#   {'id': 'Opa8XUwUghxbGFafvubV6A',
#    'alias': 'monmouth-coffee-london-3',
#    'name': 'Monmouth Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bwLj-cK2l4ws5hpEefgdqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/monmouth-coffee-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 306,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5143539, 'longitude': -0.1269168},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '27 Monmouth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['27 Monmouth Street',
#      'London WC2H 9EU',
#      'United Kingdom']},
#    'phone': '+442072323010',
#    'display_phone': '+44 20 7232 3010',
#    'distance': 647.8829298163467},
#   {'id': '5_0GHVzaA2tgzHSvFt5idw',
#    'alias': 'ladurée-london-12',
#    'name': 'Ladurée',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GkoHmWAPtVH8e9cQqztaJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ladur%C3%A9e-london-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 92,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51184286271,
#     'longitude': -0.123133037598674},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1 The Market',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 8RA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 The Market',
#      'Covent Garden',
#      'London WC2E 8RA',
#      'United Kingdom']},
#    'phone': '+442072400706',
#    'display_phone': '+44 20 7240 0706',
#    'distance': 894.1956882105256},
#   {'id': 'HG-nUBOpiMIo3cYdaNbM8Q',
#    'alias': 'tea-house-theatre-london',
#    'name': 'Tea House Theatre',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZM_OMOVZeFqMBWmqhLrIbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tea-house-theatre-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4881460278669,
#     'longitude': -0.120783489248339},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Tea House Theatre',
#     'address2': '139 Vauxhall Walk',
#     'address3': 'Vauxhall Pleasure Gardens',
#     'city': 'London',
#     'zip_code': 'SE11 5HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Tea House Theatre',
#      '139 Vauxhall Walk',
#      'Vauxhall Pleasure Gardens',
#      'London SE11 5HL',
#      'United Kingdom']},
#    'phone': '+442072074585',
#    'display_phone': '+44 20 7207 4585',
#    'distance': 2939.3669050875624},
#   {'id': 'XL7cx1Sb3dFPak2gkPOzKw',
#    'alias': 'soho-grind-london-2',
#    'name': 'Soho Grind',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Vl36Az1so-DbXZ25ImcqjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soho-grind-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512154, 'longitude': -0.138379},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '19 Beak Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Beak Street',
#      'Soho',
#      'London W1F 9RP',
#      'United Kingdom']},
#    'phone': '+442072877073',
#    'display_phone': '+44 20 7287 7073',
#    'distance': 181.13696795054122},
#   {'id': '6zT5qW1I_jcwSnIHo3OsBA',
#    'alias': 'nineteen-london-3',
#    'name': 'Nineteen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jV2bxZIx17VtnQbRBzqy7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nineteen-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'giftshops', 'title': 'Gift Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5371819, 'longitude': -0.2031378},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '19 Lonsdale Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 6RA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Lonsdale Road',
#      'London NW6 6RA',
#      'United Kingdom']},
#    'phone': '+442076254119',
#    'display_phone': '+44 20 7625 4119',
#    'distance': 5379.799052035305},
#   {'id': 'ztuEuIDjVTJMklB2OP3rpg',
#    'alias': 'ty-seven-dials-timberyard-london-2',
#    'name': 'TY Seven Dials - Timberyard',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Gr5lHKB84DjJGw8ESo5I6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ty-seven-dials-timberyard-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 138,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5128577362728,
#     'longitude': -0.127308054907987},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "7 Upper St Martin's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["7 Upper St Martin's Lane",
#      'London WC2H 9DL',
#      'United Kingdom']},
#    'phone': '+442032172009',
#    'display_phone': '+44 20 3217 2009',
#    'distance': 598.4373905869091},
#   {'id': 'mvds37L7mCurGn3rGPM8ag',
#    'alias': 'kaffeine-london',
#    'name': 'Kaffeine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QWk5UJ1ELO0n7VrE3aLUWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaffeine-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 173,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51848, 'longitude': -0.14037},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '66 Great Titchfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 7QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Great Titchfield Street',
#      'London W1W 7QJ',
#      'United Kingdom']},
#    'phone': '+442075806755',
#    'display_phone': '+44 20 7580 6755',
#    'distance': 697.5687539772275},
#   {'id': 'W7DpFG8AbfLi516fIvgdDg',
#    'alias': 'abbey-cafe-london',
#    'name': 'Abbey Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UedDW_RDdKobWFYeQBagGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/abbey-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.531848626266,
#     'longitude': -0.18065861355395},
#    'transactions': [],
#    'location': {'address1': '3 Nugent Terrace',
#     'address2': "St. John's Wood",
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 9QB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Nugent Terrace',
#      "St. John's Wood",
#      'London NW8 9QB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3746.3652871577324},
#   {'id': 'ltNrgT5KBga_-G09KPKUGA',
#    'alias': 'ginger-and-white-london',
#    'name': 'Ginger & White',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7QXlwpFegZ2gwdzLskNX8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginger-and-white-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5554778031252, 'longitude': -0.178065},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "4 Perrin's Court",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 1QS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["4 Perrin's Court",
#      'London NW3 1QS',
#      'United Kingdom']},
#    'phone': '+442074319098',
#    'display_phone': '+44 20 7431 9098',
#    'distance': 5564.726459557364},
#   {'id': '1pUEGW91riUIux0TZWw_4g',
#    'alias': 'palm-court-london',
#    'name': 'Palm Court',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lm0uTmtWFWNdHZ9t_bDGDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/palm-court-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 66,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.517861058645,
#     'longitude': -0.14380458653274},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1C Portland Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 1JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1C Portland Place',
#      'London W1B 1JA',
#      'United Kingdom']},
#    'phone': '+442079650195',
#    'display_phone': '+44 20 7965 0195',
#    'distance': 779.2584555813771},
#   {'id': 'FP-CMUyDNQk8jx6cPTVjJQ',
#    'alias': 'highness-cafe-and-tea-room-london',
#    'name': 'Highness Cafe & Tea Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jbZepmrX00u3O8Yb3IrCNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/highness-cafe-and-tea-room-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.553784799755,
#     'longitude': -0.098400140698002},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '21a Highbury Park',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N5 1QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21a Highbury Park',
#      'London N5 1QJ',
#      'United Kingdom']},
#    'phone': '+442079988595',
#    'display_phone': '+44 20 7998 8595',
#    'distance': 5242.242306493428},
#   {'id': 'c3m_OXrRNdJpWmTqhEgdeQ',
#    'alias': 'lanka-london-2',
#    'name': 'Lanka',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1pANCLbvBZdO9tptjqOjmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lanka-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5457719, 'longitude': -0.1793938},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9 Goldhurst Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 3HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Goldhurst Terrace',
#      'London NW6 3HX',
#      'United Kingdom']},
#    'phone': '+442076253366',
#    'display_phone': '+44 20 7625 3366',
#    'distance': 4737.301543897287},
#   {'id': 'TBgSUa6Xub-wBs_w13hg7g',
#    'alias': 'xing-fu-tang-london',
#    'name': 'Xing Fu Tang',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/g5zEdD4GWyI4sRnDLvxQRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/xing-fu-tang-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5127897397816,
#     'longitude': -0.130833046586645},
#    'transactions': [],
#    'location': {'address1': '29 Frith Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1D 5LG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['29 Frith Street',
#      'London W1D 5LG',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 354.5365833789741},
#   {'id': '4LrPlD9U-E0oxyAFBCjChw',
#    'alias': 'tap-coffee-no-114-london',
#    'name': 'Tap Coffee No.114',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/M97PW0Ttz9OwyUKZHgqIkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tap-coffee-no-114-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.523831, 'longitude': -0.137085},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '114 Tottenham Court Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 5AQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['114 Tottenham Court Road',
#      'London W1T 5AQ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1225.1340149771556},
#   {'id': '-77hMp9gvLLmDKrF5dUz1g',
#    'alias': 'serendipity-tea-rooms-london',
#    'name': 'Serendipity Tea Rooms',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/paPVM5ICQ9GELTrEDlt9fA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/serendipity-tea-rooms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4266678, 'longitude': -0.1308678},
#    'transactions': [],
#    'location': {'address1': '241-243 Streatham High Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW16 6EN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['241-243 Streatham High Road',
#      'London SW16 6EN',
#      'United Kingdom']},
#    'phone': '+442081270323',
#    'display_phone': '+44 20 8127 0323',
#    'distance': 9587.882196239752},
#   {'id': 'wzDJaIeVV89GVycKwMMeyw',
#    'alias': 'kioskafé-london-2',
#    'name': 'Kioskafé',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4jNvSE6Jqv2aCu7YTZcQng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kioskaf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'mags', 'title': 'Newspapers & Magazines'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.516821580645,
#     'longitude': -0.172688003330827},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '31 Norfolk Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1QH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['31 Norfolk Place',
#      'London W2 1QH',
#      'United Kingdom']},
#    'phone': '+442031114242',
#    'display_phone': '+44 20 3111 4242',
#    'distance': 2580.144462242365},
#   {'id': 'Tb1cVvzhIzGGxTpLlgCOCQ',
#    'alias': 'teanamu-chaya-teahouse-london-2',
#    'name': 'Teanamu Chaya Teahouse',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tDJRIqo7RGiCZw5wViTb3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/teanamu-chaya-teahouse-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5148575835338,
#     'longitude': -0.207801936523424},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 Melina Road',
#     'address2': "Shepherd's Bush",
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W12 9HZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Melina Road',
#      "Shepherd's Bush",
#      'London W12 9HZ',
#      'United Kingdom']},
#    'phone': '+442072430374',
#    'display_phone': '+44 20 7243 0374',
#    'distance': 4976.787348837685},
#   {'id': 't9-_U2-WmaIee3XDB0Tz0w',
#    'alias': 'hotel-café-royal-london',
#    'name': 'Hotel Café Royal',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Jnx6mmFqDAEbaSkqyvdMKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-caf%C3%A9-royal-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 65,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.510171, 'longitude': -0.135962},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '68 Regent Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 4DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['68 Regent Street',
#      'London W1B 4DY',
#      'United Kingdom']},
#    'phone': '+442074063333',
#    'display_phone': '+44 20 7406 3333',
#    'distance': 296.2812185491074},
#   {'id': 'dyAE0ROgElNHbRa-y3CfFw',
#    'alias': 'sacred-london',
#    'name': 'Sacred',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gbnky4zCMMrFXmkPjO3zlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sacred-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 69,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512954, 'longitude': -0.138923},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '13 Ganton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9BL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Ganton Street',
#      'London W1F 9BL',
#      'United Kingdom']},
#    'phone': '+447595733057',
#    'display_phone': '+44 7595 733057',
#    'distance': 201.35274674274652},
#   {'id': 'UxznD85815S17Rcg5g9-3w',
#    'alias': 'jova-marylebone-london',
#    'name': 'JOVA Marylebone',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Esws3_Pb02JhvS3xg0NMlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jova-marylebone-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'creperies', 'title': 'Creperies'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.52219, 'longitude': -0.1585},
#    'transactions': [],
#    'location': {'address1': '144 Marylebone Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 5PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['144 Marylebone Road',
#      'London NW1 5PH',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1869.9241659210334},
#   {'id': 'xJvPDma1C7F7hvEp0OfjWg',
#    'alias': 'patisserie-valerie-london-11',
#    'name': 'Patisserie Valerie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lcoP_bGFWqLxUVWqFEuszA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-valerie-london-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5142705778633,
#     'longitude': -0.159455789441691},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'York House',
#     'address2': '15 Great Cumberland Place',
#     'address3': 'London',
#     'city': 'London',
#     'zip_code': 'W1H 7AS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['York House',
#      '15 Great Cumberland Place',
#      'London',
#      'London W1H 7AS',
#      'United Kingdom']},
#    'phone': '+442077248542',
#    'display_phone': '+44 20 7724 8542',
#    'distance': 1634.0041903497304},
#   {'id': 'kOmkk63gMmsKk0Wve5aJRA',
#    'alias': 'the-garden-café-london-4',
#    'name': 'The Garden Café',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LG14Vavn8I5mnEQd6g6ANA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-garden-caf%C3%A9-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5268751462841,
#     'longitude': -0.154452323913574},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Inner Circle',
#     'address2': "Regent's Park",
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 4NU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Inner Circle',
#      "Regent's Park",
#      'London NW1 4NU',
#      'United Kingdom']},
#    'phone': '+442079355729',
#    'display_phone': '+44 20 7935 5729',
#    'distance': 2018.6552787350033},
#   {'id': '7C0Mh99YulJU5Mtrn4wDyA',
#    'alias': 'whittards-london-3',
#    'name': 'Whittards',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oAr3tzeuhAn2nSvp_v1Qlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/whittards-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeteasupplies', 'title': 'Coffee & Tea Supplies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.511614, 'longitude': -0.122707},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '17 The Marketplace',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 8RB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17 The Marketplace',
#      'Covent Garden',
#      'London WC2E 8RB',
#      'United Kingdom']},
#    'phone': '+442072403532',
#    'display_phone': '+44 20 7240 3532',
#    'distance': 926.8483709316955},
#   {'id': 'cW7lpaW9hnyLFVhoJ4DfhA',
#    'alias': 'tsujiri-london',
#    'name': 'Tsujiri',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yU_PV2mS2CH75qATlbEZVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tsujiri-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5119331851363,
#     'longitude': -0.133540146052837},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '47 Rupert Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 7PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Rupert Street',
#      'London W1D 7PD',
#      'United Kingdom']},
#    'phone': '+447446245225',
#    'display_phone': '+44 7446 245225',
#    'distance': 194.9671831466374},
#   {'id': 'FYGPmMn5B2iHGnYODyWK-Q',
#    'alias': 'teatulia-tea-bar-london',
#    'name': 'Teatulia Tea Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2sGCWezBGW4m_nIsxFp0hA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/teatulia-tea-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5143311324282,
#     'longitude': -0.125458491222724},
#    'transactions': [],
#    'location': {'address1': '36 Neal Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2H 9PS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['36 Neal Street',
#      'London WC2H 9PS',
#      'United Kingdom']},
#    'phone': '+44442073799444',
#    'display_phone': '+44 442073799444',
#    'distance': 745.2056407951179},
#   {'id': '4rpkLLSPzVRqdHlM9_-9Cw',
#    'alias': 'four-corners-cafe-london-2',
#    'name': 'Four Corners Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rq5jjv5YtDdYt9HJQ8OyEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/four-corners-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5003689, 'longitude': -0.1135442},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '12 Lower Marsh',
#     'address2': 'Waterloo',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Lower Marsh',
#      'Waterloo',
#      'London SE1 7RJ',
#      'United Kingdom']},
#    'phone': '+442086179591',
#    'display_phone': '+44 20 8617 9591',
#    'distance': 2080.282557645936},
#   {'id': 'wMA4JrWh6XGFXFWGWukoaQ',
#    'alias': 'the-garden-cafe-buckingham-palace-london',
#    'name': 'The Garden Cafe - Buckingham Palace',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WXhiVwnZbcPzsVigrH_rzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-garden-cafe-buckingham-palace-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.501356, 'longitude': -0.141896},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Buckingham Palace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1A 1AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Buckingham Palace',
#      'London SW1A 1AA',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1341.0355092835214},
#   {'id': 'X0Bw6wgjhmAZraXvPdLELQ',
#    'alias': 'notes-london-4',
#    'name': 'Notes',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2n4_s5u-BgN4-zKSUhwamw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/notes-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 101,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5095536, 'longitude': -0.1267229},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "31 St Martin's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["31 St Martin's Lane",
#      'London WC2N 4ER',
#      'United Kingdom']},
#    'phone': '+442072400424',
#    'display_phone': '+44 20 7240 0424',
#    'distance': 730.1254826123966},
#   {'id': 'pb1lTQ-SdGHT2wDkKzQRqA',
#    'alias': 'tiffins-london',
#    'name': 'Tiffins',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ACSLt7tXDXL-ZKvjVJO1Fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tiffins-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5196881, 'longitude': -0.1090228},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '24-26 Leather Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1N 7SU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24-26 Leather Lane',
#      'London EC1N 7SU',
#      'United Kingdom']},
#    'phone': '+442074045894',
#    'display_phone': '+44 20 7404 5894',
#    'distance': 2005.6322105383317},
#   {'id': 'rQKDeNCx8LkUR12YH9LpVg',
#    'alias': 'bäkehaus-london-2',
#    'name': 'Bäkehaus',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t8nwOKGUsvFhyuNdJFTrvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b%C3%A4kehaus-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4926600176647,
#     'longitude': -0.227837562561035},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '71 King Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W6 9HW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['71 King Street', 'London W6 9HW', 'United Kingdom']},
#    'phone': '+442034903231',
#    'display_phone': '+44 20 3490 3231',
#    'distance': 6743.794563736779},
#   {'id': 'eDqcRJKUdRt46nld92YyTA',
#    'alias': 'biscuiteers-london-2',
#    'name': 'Biscuiteers',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_kSvmhQwojvsCUR1OLCivg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/biscuiteers-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5155496, 'longitude': -0.2058177},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '194 Kensington Park Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2ES',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['194 Kensington Park Rd',
#      'London W11 2ES',
#      'United Kingdom']},
#    'phone': '+442077278096',
#    'display_phone': '+44 20 7727 8096',
#    'distance': 4843.771849571174},
#   {'id': 'dbrYUOzVoXANmL39SsFywA',
#    'alias': 'postcard-teas-london',
#    'name': 'Postcard Teas',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/e2_dPUTyt_7EI2tcTUTA-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/postcard-teas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5142, 'longitude': -0.146021},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9 Dering Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 1AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Dering Street',
#      'London W1S 1AG',
#      'United Kingdom']},
#    'phone': '+442076293654',
#    'display_phone': '+44 20 7629 3654',
#    'distance': 706.6451039604588}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                 Restaurant          Type Price Rating                Address  \
# 0  The Muffin Man Tea Shop  Coffee & Tea     £    3.5        12 Wrights Lane
# 1             Ripe Kitchen         Cafes               136 Regents Park Road
# 2              Tea & Glory  Coffee & Tea   £££      4     29 Chalk Farm Road
# 3    Garden Shack Hideaway  Coffee & Tea                          55 York Rd
# 4     The English Tea Room     Tea Rooms   £££      4    30 Albemarle Street
#
#          Lat       Lng                                                url  \
# 0  51.499440 -0.192811  https://www.yelp.com/biz/the-muffin-man-tea-sh...
# 1  51.540697 -0.157262
# 2  51.542673 -0.147332  https://www.yelp.com/biz/tea-and-glory-camden?...
# 3  51.502768 -0.115942
# 4  51.509136 -0.142163  https://www.yelp.com/biz/the-english-tea-room-...
#
#                        ID
# 0  8hz9UOfK0mIsAzs90vrN8Q
# 1
# 2  1OKrknY5Vize2MyC5l31Eg
# 3
# 4  KLofVP70jrDEnxBLkoSmmw

# %%
#3rd set of 50 records 101-150
lndr_params3 = {"term":term,"location":"London","limit":50,"offset":101}
lndr_response3 = requests.get(search_api_url, headers=headers, params=lndr_params3)
lndr3 = lndr_response3.json()
display(lndr3)
#print(lndr_response3.url)
#print(lndr_response3.status_code)
# Out:
# {'businesses': [{'id': '7fnq7-pePPEM2WaZ4CLg0g',
#    'alias': 'department-of-coffee-and-social-affairs-london',
#    'name': 'Department of Coffee and Social Affairs',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/W_xUKBTvCBaAlWlj7UjbUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/department-of-coffee-and-social-affairs-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5194646, 'longitude': -0.1089855},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14-16 Leather Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1N 7SU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14-16 Leather Lane',
#      'London EC1N 7SU',
#      'United Kingdom']},
#    'phone': '+442074196906',
#    'display_phone': '+44 20 7419 6906',
#    'distance': 2005.7501145358774},
#   {'id': 'eRVFJXY-aLDD-0qmYvEBag',
#    'alias': 'hampstead-tea-rooms-london',
#    'name': 'Hampstead Tea Rooms',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bB-1V0jtx3kjyX20blW1HQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hampstead-tea-rooms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.554198, 'longitude': -0.1657509},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '9 S End Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 2PT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 S End Road', 'London NW3 2PT', 'United Kingdom']},
#    'phone': '+442074359563',
#    'display_phone': '+44 20 7435 9563',
#    'distance': 5055.903191492869},
#   {'id': 'iXVq9PcCT-a34FzaXbUagA',
#    'alias': 'scooter-caffè-london-2',
#    'name': 'Scooter Caffè',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/x9HNw_Kud2pJil8Zv5_8oA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scooter-caff%C3%A8-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.500341224864,
#     'longitude': -0.11381534473676},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '132 Lower Marsh',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7AE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['132 Lower Marsh',
#      'London SE1 7AE',
#      'United Kingdom']},
#    'phone': '+442076201421',
#    'display_phone': '+44 20 7620 1421',
#    'distance': 2068.3940056684514},
#   {'id': 'G9fziI6-xivwIobgudOtaQ',
#    'alias': 'momento-london-2',
#    'name': 'Momento',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/x5fAer3cjkyJ6c0PCteY2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/momento-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5164189, 'longitude': -0.1738711},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '159 Praed Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['159 Praed Street',
#      'London W2 1RL',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2653.752571351006},
#   {'id': '-mwUNBsseNvc47-IMGE1cA',
#    'alias': 'kissaten-london',
#    'name': 'Kissaten',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jy-PVAFYkT2LyJOO4xlNWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kissaten-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5121392916709,
#     'longitude': -0.134605075321141},
#    'transactions': [],
#    'location': {'address1': '30 Brewer Street',
#     'address2': 'Soho',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1F 0SS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Brewer Street',
#      'Soho',
#      'London W1F 0SS',
#      'United Kingdom']},
#    'phone': '+442039762045',
#    'display_phone': '+44 20 3976 2045',
#    'distance': 121.36957070776417},
#   {'id': 'aivGgBZ83bZjE95nrB1jvA',
#    'alias': 'peyton-and-byrne-london-11',
#    'name': 'Peyton and Byrne',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/G61GtUBwTiGpiZmjnU5Z9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peyton-and-byrne-london-11?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5228863, 'longitude': -0.143831277057965},
#    'transactions': [],
#    'location': {'address1': '226 Great Portland Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1W 5QP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['226 Great Portland Street',
#      'London W1W 5QP',
#      'United Kingdom']},
#    'phone': '+442034221453',
#    'display_phone': '+44 20 3422 1453',
#    'distance': 1243.3684205844672},
#   {'id': '1-ELFsotKBvc5WbfqEsrdg',
#    'alias': 'yumchaa-camden-market-london',
#    'name': 'Yumchaa Camden Market',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_7ueI4mgmsfNuf1lIZBBfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yumchaa-camden-market-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5412866087782,
#     'longitude': -0.146655096405732},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '91-92 Camden Lock Place',
#     'address2': 'Upper Walkway West',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW1 8AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['91-92 Camden Lock Place',
#      'Upper Walkway West',
#      'London NW1 8AF',
#      'United Kingdom']},
#    'phone': '+442072099641',
#    'display_phone': '+44 20 7209 9641',
#    'distance': 3249.0456699032684},
#   {'id': 'kEI6mZ6EBzYFJ9veQ-vD3A',
#    'alias': 'chatime-london-3',
#    'name': 'Chatime',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qVtesbo9iNyufTQSjaO6gA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chatime-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.524453914796,
#     'longitude': -0.124379430363801},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 34',
#     'address2': 'The Brunswick',
#     'address3': 'Russell Square',
#     'city': 'London',
#     'zip_code': 'WC1N 1AE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 34',
#      'The Brunswick',
#      'Russell Square',
#      'London WC1N 1AE',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1520.0688911604277},
#   {'id': 't-SEsNsUW0DS2dcvtFmx3Q',
#    'alias': 'mei-leaf-london',
#    'name': 'Mei Leaf',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/G6DjtWaOo1Sy2Kd77vUH0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mei-leaf-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.536856, 'longitude': -0.1410199},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '99-105 Camden High Street',
#     'address2': 'Camden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 7JN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['99-105 Camden High Street',
#      'Camden',
#      'London NW1 7JN',
#      'United Kingdom']},
#    'phone': '+442073886704',
#    'display_phone': '+44 20 7388 6704',
#    'distance': 2693.831827796193},
#   {'id': 'PYwzVOvFIjwCMNYV5upPwg',
#    'alias': 'the-attendant-london-2',
#    'name': 'The Attendant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W4pc8bJ_lVWg801nKejVOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-attendant-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 74,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5192470995905,
#     'longitude': -0.140738025145255},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Downstairs 27A',
#     'address2': 'Foley Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 6DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Downstairs 27A',
#      'Foley Street',
#      'London W1W 6DY',
#      'United Kingdom']},
#    'phone': '+442076373794',
#    'display_phone': '+44 20 7637 3794',
#    'distance': 785.9877629261662},
#   {'id': '1tXmuTujxH2biANLDGo3cg',
#    'alias': 'my-tea-shop-london',
#    'name': 'My Tea Shop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OrUJbfkUhlEqT_EA4XFc1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-tea-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5058708, 'longitude': -0.087459},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '23 Duke Street Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 2SW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23 Duke Street Hill',
#      'London SE1 2SW',
#      'United Kingdom']},
#    'phone': '+442074071110',
#    'display_phone': '+44 20 7407 1110',
#    'distance': 3455.5540240368746},
#   {'id': 'U4SvoA9FmOmN487C0hs7Mw',
#    'alias': 'whittard-of-chelsea-london-24',
#    'name': 'Whittard Of Chelsea',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tGCCtPET9AUYuqKBvH_p1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/whittard-of-chelsea-london-24?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'coffeeteasupplies',
#      'title': 'Coffee & Tea Supplies'},
#     {'alias': 'chocolate', 'title': 'Chocolatiers & Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.516211, 'longitude': -0.132463},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '53 Oxford Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1D 2DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['53 Oxford Street',
#      'London W1D 2DY',
#      'United Kingdom']},
#    'phone': '+442072872599',
#    'display_phone': '+44 20 7287 2599',
#    'distance': 446.4237532582346},
#   {'id': 'uN9nxbQlUmXUMv1kt8Ye1w',
#    'alias': 'saint-espresso-london-2',
#    'name': 'Saint Espresso',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6wpKqcs2qZXaLHdioBj9pQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saint-espresso-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5233293750657,
#     'longitude': -0.158073306083679},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '214 Baker Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW1',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['214 Baker Street', 'London NW1', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1924.4771101888414},
#   {'id': 'Qk9CwHdpFgYo1Za77yfPtQ',
#    'alias': 'l-eto-caffe-london-6',
#    'name': "L'eto Caffe",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1FQ30FQP3kvrI5A8NXId9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-eto-caffe-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.48794, 'longitude': -0.167225},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "149 King's Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 5TX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["149 King's Road",
#      'London SW3 5TX',
#      'United Kingdom']},
#    'phone': '+442073517656',
#    'display_phone': '+44 20 7351 7656',
#    'distance': 3513.9797015942327},
#   {'id': 'XC-5i2XYrDfY0vrPThCNBA',
#    'alias': 'beas-of-bloomsbury-bloomsbury',
#    'name': "Bea's of Bloomsbury",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XAX_VKZ1ltpH8pQCM78GQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beas-of-bloomsbury-bloomsbury?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'},
#     {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5221514, 'longitude': -0.1247099},
#    'transactions': [],
#    'location': {'address1': '72 Russell Square',
#     'address2': '',
#     'address3': None,
#     'city': 'Bloomsbury',
#     'zip_code': 'WC1B 5BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['72 Russell Square',
#      'Bloomsbury WC1B 5BA',
#      'United Kingdom']},
#    'phone': '+442072787949',
#    'display_phone': '+44 20 7278 7949',
#    'distance': 1291.6575617131123},
#   {'id': 'f8s8dT9Rm4359xUVHtiqRA',
#    'alias': 'black-cat-london',
#    'name': 'Black Cat',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RZHJY2Tw6cAtF7ZrT7vQTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-cat-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5513968, 'longitude': -0.055691},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '76 Clarence Road',
#     'address2': 'Hackney',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E5 8HB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['76 Clarence Road',
#      'Hackney',
#      'London E5 8HB',
#      'United Kingdom']},
#    'phone': '+442089857091',
#    'display_phone': '+44 20 8985 7091',
#    'distance': 7015.023023552639},
#   {'id': 'tH_2560cbjme-hFBFVj8cQ',
#    'alias': 'brigits-bakery-london',
#    'name': "Brigit's Bakery",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mdh8u6FH2qeo4BRzNVNBHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brigits-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 55,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5100888407083,
#     'longitude': -0.124539992630842},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6-7 Chandos Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4HU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6-7 Chandos Place',
#      'London WC2N 4HU',
#      'United Kingdom']},
#    'phone': '+442030261188',
#    'display_phone': '+44 20 3026 1188',
#    'distance': 846.9905268424552},
#   {'id': 'Q6tw8tw0iZUUq9gumhA0nA',
#    'alias': 'park-room-london',
#    'name': 'Park Room',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6VtyTatZ9j7FjoZxckotnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/park-room-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5097307293668,
#     'longitude': -0.155653953552246},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'J W Marriott Hotel - Grosvenor House',
#     'address2': '86-90 Park Lane',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 7TN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['J W Marriott Hotel - Grosvenor House',
#      '86-90 Park Lane',
#      'London W1K 7TN',
#      'United Kingdom']},
#    'phone': '+442073998452',
#    'display_phone': '+44 20 7399 8452',
#    'distance': 1406.2133857848767},
#   {'id': '0T5fEkTQAry6pRmI056nTA',
#    'alias': 'maitre-choux-london',
#    'name': 'Maitre Choux',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Fl6oLvKyCIxXAp71W_X52w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maitre-choux-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 49,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4939411, 'longitude': -0.1755375},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '15 Harrington Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3ES',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Harrington Road',
#      'London SW7 3ES',
#      'United Kingdom']},
#    'phone': '+442035834561',
#    'display_phone': '+44 20 3583 4561',
#    'distance': 3452.4998941819867},
#   {'id': 'x58LDkXGU7vC8-KRDlS9Mw',
#    'alias': 'raison-d-etre-london',
#    'name': "Raison D'Etre",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GNL9SAtkBRabO34z0GOmqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raison-d-etre-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.493706018346,
#     'longitude': -0.17628170716244},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '18 Bute Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3EX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 Bute Street', 'London SW7 3EX', 'United Kingdom']},
#    'phone': '+442075845008',
#    'display_phone': '+44 20 7584 5008',
#    'distance': 3509.3036349562817},
#   {'id': 'yCxqRO2uvi0laTBGuJMBqA',
#    'alias': 'bond-and-brook-london',
#    'name': 'Bond & Brook',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sBjxC6Y0p9vNb2_mY-4AiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bond-and-brook-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'food', 'title': 'Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5134773, 'longitude': -0.1454519},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '63 New Bond St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1A 3BS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63 New Bond St', 'London W1A 3BS', 'United Kingdom']},
#    'phone': '+442076290273',
#    'display_phone': '+44 20 7629 0273',
#    'distance': 638.204771073436},
#   {'id': 'AJ7i8Xqyx70wpcTTcK4GFA',
#    'alias': 'somerset-house-strand',
#    'name': 'Somerset House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/85dQ4lnXBBi6Xi4C4w3DpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/somerset-house-strand?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 67,
#    'categories': [{'alias': 'museums', 'title': 'Museums'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5110614108427,
#     'longitude': -0.117102253177384},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'South Building',
#     'address2': 'Somerset House',
#     'address3': '',
#     'city': 'Strand',
#     'zip_code': 'WC2R 1LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['South Building',
#      'Somerset House',
#      'Strand WC2R 1LA',
#      'United Kingdom']},
#    'phone': '+442078454600',
#    'display_phone': '+44 20 7845 4600',
#    'distance': 1319.5379341546704},
#   {'id': 'Kfz7NwTNSztX4pgXLSmUaw',
#    'alias': 'patisserie-valerie-london',
#    'name': 'Patisserie Valerie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Wlti6EDjRS60M_Dsgw5Kzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patisserie-valerie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.497184, 'longitude': -0.16763},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '215 Brompton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 2EJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['215 Brompton Road',
#      'London SW3 2EJ',
#      'United Kingdom']},
#    'phone': '+442078239971',
#    'display_phone': '+44 20 7823 9971',
#    'distance': 2788.450907744187},
#   {'id': 'XfXZ3GtzcZtCcPeLv5wHJA',
#    'alias': 'the-east-india-company-fine-foods-london',
#    'name': 'The East India Company Fine Foods',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/g08Wy7oKdxHCt6m0xSyDcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-east-india-company-fine-foods-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'gourmet', 'title': 'Specialty Food'},
#     {'alias': 'coffeeteasupplies', 'title': 'Coffee & Tea Supplies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.51287, 'longitude': -0.141549},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '7-8 Conduit Street',
#     'address2': 'Mayfair',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 2XF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7-8 Conduit Street',
#      'Mayfair',
#      'London W1S 2XF',
#      'United Kingdom']},
#    'phone': '+442032053395',
#    'display_phone': '+44 20 3205 3395',
#    'distance': 383.85918927931044},
#   {'id': 'rRSStigtOHSi7K8J0kEvsA',
#    'alias': 'the-buttery-café-london-2',
#    'name': 'The Buttery Café',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SVKu-DFYa9UjGQe_qt-l2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-buttery-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.558188, 'longitude': -0.175104},
#    'transactions': [],
#    'location': {'address1': 'Burgh House',
#     'address2': 'New End Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 1LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Burgh House',
#      'New End Square',
#      'London NW3 1LT',
#      'United Kingdom']},
#    'phone': '+442077942905',
#    'display_phone': '+44 20 7794 2905',
#    'distance': 5722.964667148881},
#   {'id': 'BWOhQKfARucMBBwf3C90Aw',
#    'alias': 't4-tea-for-u-london',
#    'name': 'T4 Tea for U',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Id8SlXvVQ1i8XpaFi--jYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/t4-tea-for-u-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5435621742426,
#     'longitude': -0.00596807036129121},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Montfichet Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E20 1EJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Montfichet Road',
#      'London E20 1EJ',
#      'United Kingdom']},
#    'phone': '+442078872649',
#    'display_phone': '+44 20 7887 2649',
#    'distance': 9619.443772329932},
#   {'id': 'WI6ZlfN6EFuExc21VnmVrQ',
#    'alias': 'a-wanted-man-london',
#    'name': 'A Wanted Man',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/r4MenIFqF40hvRwn67Fv1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/a-wanted-man-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4854399, 'longitude': -0.1742},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "330 King's Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 5UR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["330 King's Road",
#      'London SW3 5UR',
#      'United Kingdom']},
#    'phone': '+442073515166',
#    'display_phone': '+44 20 7351 5166',
#    'distance': 4039.144607784619},
#   {'id': '_zQGr1XLpDPyUxkMAdiJUw',
#    'alias': 'orrery-epicerie-london',
#    'name': 'Orrery Epicerie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BMwN-OMCWhOqzuKJUdJnCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/orrery-epicerie-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.522249, 'longitude': -0.1512119},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '55-57 Marylebone High Street',
#     'address2': 'Marylebone',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 5HS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['55-57 Marylebone High Street',
#      'Marylebone',
#      'London W1U 5HS',
#      'United Kingdom']},
#    'phone': '+442076168036',
#    'display_phone': '+44 20 7616 8036',
#    'distance': 1489.7859807332125},
#   {'id': '-ylzTrYtRJUJa2BuAInoyQ',
#    'alias': 'friends-of-ours-london',
#    'name': 'Friends of Ours',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/q5Fg1_UQtNmvOoIzrLzhAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/friends-of-ours-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 96,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5291189, 'longitude': -0.0836995},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61 Pitfield Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 6BU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Pitfield Street',
#      'London N1 6BU',
#      'United Kingdom']},
#    'phone': '+442076865525',
#    'display_phone': '+44 20 7686 5525',
#    'distance': 4041.3053965414406},
#   {'id': '0tJs57Xoq75-RDWKVco0nw',
#    'alias': 'bageriet-london',
#    'name': 'Bageriet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2yfTj7nJkUd_snGs1WP2aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bageriet-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'scandinavian', 'title': 'Scandinavian'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5119236, 'longitude': -0.1261821},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '24 Rose Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 9EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Rose Street',
#      'London WC2E 9EA',
#      'United Kingdom']},
#    'phone': '+442072400000',
#    'display_phone': '+44 20 7240 0000',
#    'distance': 683.9151857905819},
#   {'id': 'tHKiDGayBq4RD0oL-DutCg',
#    'alias': 'bloomsbury-coffee-house-london',
#    'name': 'Bloomsbury Coffee House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CAUiQ6-F7FTloOIkmSnTyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bloomsbury-coffee-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 58,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.525250540481,
#     'longitude': -0.126389201213277},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '20 Tavistock Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 9RE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Tavistock Place',
#      'London WC1H 9RE',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1530.9764438322995},
#   {'id': 'dIWOqYszVKk-oswXDzUH6A',
#    'alias': 'primrose-bakery-london',
#    'name': 'Primrose Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ng53dTpGBxCLSpY5sotd_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/primrose-bakery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5402263, 'longitude': -0.1511222},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '69 Gloucester Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8LD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['69 Gloucester Avenue',
#      'London NW1 8LD',
#      'United Kingdom']},
#    'phone': '+442074834222',
#    'display_phone': '+44 20 7483 4222',
#    'distance': 3221.367607689674},
#   {'id': '-fLxQOd0pjTkQl4ttwR4XA',
#    'alias': 'books-for-cooks-london',
#    'name': 'Books for Cooks',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/REu7-q4WSa6QKKI6sYCNtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/books-for-cooks-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'bookstores', 'title': 'Bookstores'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cookingschools', 'title': 'Cooking Schools'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5159431, 'longitude': -0.2053744},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 Blenheim Cresent',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 1NN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Blenheim Cresent',
#      'London W11 1NN',
#      'United Kingdom']},
#    'phone': '+442072211992',
#    'display_phone': '+44 20 7221 1992',
#    'distance': 4820.047305934839},
#   {'id': 'B6oZuZIUt3IVvViQB20zXA',
#    'alias': 'hubbub-london-4',
#    'name': 'Hubbub',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XWc2iU0WG9n2rjiKPx445w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hubbub-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4921565081536,
#     'longitude': -0.0244143954638809},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '269 Westferry Road',
#     'address2': '',
#     'address3': 'Isle of Dogs',
#     'city': 'London',
#     'zip_code': 'E14 3RS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['269 Westferry Road',
#      'Isle of Dogs',
#      'London E14 3RS',
#      'United Kingdom']},
#    'phone': '+442075155577',
#    'display_phone': '+44 20 7515 5577',
#    'distance': 8055.657192058607},
#   {'id': 'SpMzwgQjKcnSnKQvwjxckQ',
#    'alias': 'alchemy-london-5',
#    'name': 'Alchemy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8V8icqdpvsMUoUZtH0LjVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alchemy-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5134264160446,
#     'longitude': -0.102642286734127},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '8 Ludgate Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4V 6DU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Ludgate Broadway',
#      'London EC4V 6DU',
#      'United Kingdom']},
#    'phone': '+442073299904',
#    'display_phone': '+44 20 7329 9904',
#    'distance': 2306.246867512033},
#   {'id': 'WviWKTmXpSZWv7Pdt_7RyQ',
#    'alias': 'pompidou-cafe-london',
#    'name': 'Pompidou Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZvIwYIvwIJxnuX9XCIW8CQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pompidou-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5310148, 'longitude': -0.1213579},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '284 Pentonville Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 9NR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['284 Pentonville Road',
#      'London N1 9NR',
#      'United Kingdom']},
#    'phone': '+442072787677',
#    'display_phone': '+44 20 7278 7677',
#    'distance': 2252.1800220171363},
#   {'id': 'WnLk57JkCmdqbSkdmnp9_Q',
#    'alias': 'beas-of-bloomsbury-london-17',
#    'name': "Bea's of Bloomsbury",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x4VNAQaKgX3fBHz8BebP8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beas-of-bloomsbury-london-17?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5200841, 'longitude': -0.1050001},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '43 Cowcross Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1M 6BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['43 Cowcross Street',
#      'London EC1M 6BY',
#      'United Kingdom']},
#    'phone': '+442072428330',
#    'display_phone': '+44 20 7242 8330',
#    'distance': 2288.6184849036517},
#   {'id': 'UESyhTRQY4CYtGNoYBc52Q',
#    'alias': 'terrys-cafe-london-3',
#    'name': "Terry's Cafe",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YBkG1Yc2dbbemDZCQeKbOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/terrys-cafe-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.50069, 'longitude': -0.0984105},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '158 Great Suffolk Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1PE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['158 Great Suffolk Street',
#      'London SE1 1PE',
#      'United Kingdom']},
#    'phone': '+442074079358',
#    'display_phone': '+44 20 7407 9358',
#    'distance': 2928.512166850289},
#   {'id': 'Da8ClETsPknyD-XIam-jbg',
#    'alias': 'maroush-bakehouse-london-6',
#    'name': 'Maroush Bakehouse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hYjyJ-w7yL5JNQ_7sUFl9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maroush-bakehouse-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'lebanese', 'title': 'Lebanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.49332, 'longitude': -0.194478},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '131 Earls Court Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 9RH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['131 Earls Court Road',
#      'London SW5 9RH',
#      'United Kingdom']},
#    'phone': '+442073704324',
#    'display_phone': '+44 20 7370 4324',
#    'distance': 4595.303422118365},
#   {'id': 'bM4i_JbpURfbJ6l_pIxMSQ',
#    'alias': 'chatime-london-4',
#    'name': 'Chatime',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DvbcgY_manzFUTTtIfTYug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chatime-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5261358500562,
#     'longitude': -0.0800114841471178},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '68 Rivington Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['68 Rivington Street',
#      'London EC2A',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4143.738432112867},
#   {'id': 'UA5L6AQ7BBJzRpk30OOzLw',
#    'alias': 'notes-kings-cross-london',
#    'name': 'Notes Kings Cross',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JdSTo1kGOD1pPMwvL1ADzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/notes-kings-cross-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5328633212823,
#     'longitude': -0.124956891176129},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'One Pancras Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['One Pancras Square',
#      'London N1C 4AG',
#      'United Kingdom']},
#    'phone': '+442034791576',
#    'display_phone': '+44 20 3479 1576',
#    'distance': 2353.4112010836106},
#   {'id': 'NEvo7jfIiQ79fZ-EdLtV8g',
#    'alias': 'beany-green-london-3',
#    'name': 'Beany Green',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Fxfiiot87jlkvL2BwU2tqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beany-green-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.518924, 'longitude': -0.08359},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '41 Broadgate Circle',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2M 2QS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41 Broadgate Circle',
#      'London EC2M 2QS',
#      'United Kingdom']},
#    'phone': '+442072569524',
#    'display_phone': '+44 20 7256 9524',
#    'distance': 3669.246894751587},
#   {'id': '4olVEJN71cEVd8QCMHb38w',
#    'alias': 'woo-tea-london',
#    'name': 'Woo Tea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SqmqqpPIM6MZtJRtMnj2qQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/woo-tea-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5112485677036,
#     'longitude': -0.131984800100327},
#    'transactions': [],
#    'location': {'address1': 'G/F-24 Wardour Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1D 6QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['G/F-24 Wardour Street',
#      'London W1D 6QL',
#      'United Kingdom']},
#    'phone': '+442074342028',
#    'display_phone': '+44 20 7434 2028',
#    'distance': 326.58040912350907},
#   {'id': 'EanCLBAeSJNU9MA0pVlHVg',
#    'alias': 'cafe-twelve-london',
#    'name': 'Cafe Twelve',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uAIN5SbTugPIgyu7ljHtjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-twelve-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.528322, 'longitude': -0.075946},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '57 Hackney Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7NX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57 Hackney Rd', 'London E2 7NX', 'United Kingdom']},
#    'phone': '+442077299319',
#    'display_phone': '+44 20 7729 9319',
#    'distance': 4494.95978931185},
#   {'id': 'uu0ld-hLz2DDjpf5Ch0kGg',
#    'alias': 'treves-and-hyde-london',
#    'name': 'Treves & Hyde',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/c0ONf-gl6I6iLwDtFf5poQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/treves-and-hyde-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.514397, 'longitude': -0.071017},
#    'transactions': [],
#    'location': {'address1': '15/17 leman st',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E1 8EN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15/17 leman st', 'London E1 8EN', 'United Kingdom']},
#    'phone': '+442036218900',
#    'display_phone': '+44 20 3621 8900',
#    'distance': 4497.099762735951},
#   {'id': 'PymJ3yWM5SaZC8QH89ZEBw',
#    'alias': 'dirty-bones-soho-london',
#    'name': 'Dirty Bones Soho',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/o3YH-aF3ffVn0EgZol8PrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dirty-bones-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.510811, 'longitude': -0.135314},
#    'transactions': [],
#    'location': {'address1': '14 Denman Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1D 7HJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Denman Street',
#      'London W1D 7HJ',
#      'United Kingdom']},
#    'phone': '+442030199064',
#    'display_phone': '+44 20 3019 9064',
#    'distance': 229.45587427086852},
#   {'id': '5zFiOz2Y1FMCE6nCDFQaYg',
#    'alias': 'tapped-and-packed-london-2',
#    'name': 'Tapped & Packed',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uGsyBXLkXqwgkkUADNxKSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tapped-and-packed-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.523323059082,
#     'longitude': -0.137232005596161},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '114 Tottenham Court Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 5AH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['114 Tottenham Court Road',
#      'London W1T 5AH',
#      'United Kingdom']},
#    'phone': '+442075802163',
#    'display_phone': '+44 20 7580 2163',
#    'distance': 1167.6137484032245},
#   {'id': 'QFZbVqRDwhaIfSqRVGsHrg',
#    'alias': 'blossom-haven-teas-london',
#    'name': 'Blossom Haven Teas',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OCVEKgABx0ae3D6mlgE8XQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blossom-haven-teas-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4816271, 'longitude': -0.0088386},
#    'transactions': [],
#    'location': {'address1': 'Greenwich Market',
#     'address2': 'College Approach',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE10 9HZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Greenwich Market',
#      'College Approach',
#      'London SE10 9HZ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9459.174442337338},
#   {'id': 'IFx29LvkxdZx8pTp-JrvnA',
#    'alias': 'l-eto-caffe-london-3',
#    'name': "L'eto Caffe",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/102DdjCIFtBYllWCYwlo2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-eto-caffe-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4987685, 'longitude': -0.1570349},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10 W Halkin Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 8JL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 W Halkin Street',
#      'London SW1X 8JL',
#      'United Kingdom']},
#    'phone': '+442072356415',
#    'display_phone': '+44 20 7235 6415',
#    'distance': 2138.947633367185},
#   {'id': 'TqSnt86jxwyllhb-WVV8wQ',
#    'alias': 'yi-fang-london',
#    'name': 'Yi Fang',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eBCXQRxlSd-6iUgc7YPScg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yi-fang-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5196988441591,
#     'longitude': -0.0753336575999231},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Brushfield St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E1 6AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Brushfield St', 'London E1 6AA', 'United Kingdom']},
#    'phone': '+447446127070',
#    'display_phone': '+44 7446 127070',
#    'distance': 4263.6480611275465}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                                 Restaurant          Type Price Rating  \
# 0  Department of Coffee and Social Affairs  Coffee & Tea    ££    4.5
# 1                      Hampstead Tea Rooms     Tea Rooms    ££      4
# 2                            Scooter Caffè         Cafes     £    4.5
# 3                                  Momento  Coffee & Tea     £    4.5
# 4                                 Kissaten    Bubble Tea
#
#               Address        Lat       Lng  \
# 0  14-16 Leather Lane  51.519465 -0.108985
# 1        9 S End Road  51.554198 -0.165751
# 2     132 Lower Marsh  51.500341 -0.113815
# 3    159 Praed Street  51.516419 -0.173871
# 4    30 Brewer Street  51.512139 -0.134605
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/department-of-coffee-...  7fnq7-pePPEM2WaZ4CLg0g
# 1  https://www.yelp.com/biz/hampstead-tea-rooms-l...  eRVFJXY-aLDD-0qmYvEBag
# 2  https://www.yelp.com/biz/scooter-caff%C3%A8-lo...  iXVq9PcCT-a34FzaXbUagA
# 3  https://www.yelp.com/biz/momento-london-2?adju...  G9fziI6-xivwIobgudOtaQ
# 4

# %%
#4th set of 50 records 151-200
lndr_params4 = {"term":term,"location":"London","limit":50,"offset":151}
lndr_response4 = requests.get(search_api_url, headers=headers, params=lndr_params4)
lndr4 = lndr_response4.json()
display(lndr4)
#print(lndr_response4.url)
#print(lndr_response4.status_code)
# Out:
# {'businesses': [{'id': 'ttROKeMmaM1k39JogTAFSA',
#    'alias': 'paul-london-32',
#    'name': 'Paul',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JVQ8KzP7TMypYooagV1lfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-london-32?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51468, 'longitude': -0.09843},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Paternoster Lodge',
#     'address2': 'Paternoster Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4M 7DX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Paternoster Lodge',
#      'Paternoster Square',
#      'London EC4M 7DX',
#      'United Kingdom']},
#    'phone': '+442073294705',
#    'display_phone': '+44 20 7329 4705',
#    'distance': 2578.3611394881545},
#   {'id': 'p77CnjTGOIZA1hEpLfCC6Q',
#    'alias': 'kennington-lane-cafe-london',
#    'name': 'Kennington Lane Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4pjtT4PSUYl_0_BqOTx6Cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kennington-lane-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 97,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4860611, 'longitude': -0.1208514},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '383 Kennington Lane',
#     'address2': 'Vauxhall',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE11 5QY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['383 Kennington Lane',
#      'Vauxhall',
#      'London SE11 5QY',
#      'United Kingdom']},
#    'phone': '+442077355853',
#    'display_phone': '+44 20 7735 5853',
#    'distance': 3147.932368103276},
#   {'id': 'LUfGFtvxJw_Acs-KWCNNMw',
#    'alias': 'the-watch-house-london-9',
#    'name': 'The Watch House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_yucrh0lyKoc16DW8UDLDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-watch-house-london-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.52089, 'longitude': -0.07528},
#    'transactions': [],
#    'location': {'address1': '139 Commercial Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E1 6BJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['139 Commercial Street',
#      'London E1 6BJ',
#      'United Kingdom']},
#    'phone': '+442032460087',
#    'display_phone': '+44 20 3246 0087',
#    'distance': 4294.082311254525},
#   {'id': 'RUlcbocOFeAaNnLHpApyvg',
#    'alias': 'up-t-london',
#    'name': 'Up...T',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cVN87UCZH88jRjCRHn1TEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/up-t-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'taiwanese', 'title': 'Taiwanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5117163658139,
#     'longitude': -0.128739782807152},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '10 Little Newport Street',
#     'address2': 'Chinatown',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 7JJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Little Newport Street',
#      'Chinatown',
#      'London WC2H 7JJ',
#      'United Kingdom']},
#    'phone': '+442077346391',
#    'display_phone': '+44 20 7734 6391',
#    'distance': 514.6343366259584},
#   {'id': 'QkVCOVfQQkLnVpDl8Z02GA',
#    'alias': 'madd-hatters-cafe-by-massis-tea-and-madd-london',
#    'name': 'Madd Hatters Cafe by Massis Tea & Madd',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RpCF8SvwVFlRD0-Wln6HPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/madd-hatters-cafe-by-massis-tea-and-madd-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5125308687381,
#     'longitude': -0.126842831382492},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6/7 Great Newport Street',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6/7 Great Newport Street',
#      'Covent Garden',
#      'London WC2H',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 631.5376367531346},
#   {'id': 'W2mLUxdAjkYJrgBvRhSwLw',
#    'alias': 'beas-of-bloomsbury-london-2',
#    'name': "Bea's of Bloomsbury",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IZXzZD6kjlovTJPUKyZJiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beas-of-bloomsbury-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 82,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.513394, 'longitude': -0.095509},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '83 Watling Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4M 9BX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Watling Street',
#      'London EC4M 9BX',
#      'United Kingdom']},
#    'phone': '+442079894099',
#    'display_phone': '+44 20 7989 4099',
#    'distance': 2799.627157327845},
#   {'id': 'oNAAsT496i9QM1zAh9XOvQ',
#    'alias': 'verde-and-company-london',
#    'name': 'Verde & Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9A9uLuwiy5nis3aeFyaohQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/verde-and-company-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'delicatessen', 'title': 'Delicatessen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5190381178332,
#     'longitude': -0.0765180587768555},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '40 Brushfield Street',
#     'address2': 'Spitalfields',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 Brushfield Street',
#      'Spitalfields',
#      'London E1 6AG',
#      'United Kingdom']},
#    'phone': '+442072471924',
#    'display_phone': '+44 20 7247 1924',
#    'distance': 4170.293051362143},
#   {'id': '3SL1apsNAVSW3AlyGquAcA',
#    'alias': 'harris-hoole-london-6',
#    'name': 'Harris+Hoole',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0MB7D_ApwV1FV-3Dt07iUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harris-hoole-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4743213346655,
#     'longitude': -0.182825330601449},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '215 Townmead Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 2TW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['215 Townmead Road',
#      'London SW6 2TW',
#      'United Kingdom']},
#    'phone': '+442077313520',
#    'display_phone': '+44 20 7731 3520',
#    'distance': 5372.996154725009},
#   {'id': 'ZjymdmWGHaD9sGoDo-VNbw',
#    'alias': 'le-petit-venice-london-2',
#    'name': 'Le Petit Venice',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bf6S2FcDpBR_8POOHvlPhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-petit-venice-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5266025167736,
#     'longitude': -0.193608552217484},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '131 Shirland Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W9 2BT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['131 Shirland Road',
#      'London W9 2BT',
#      'United Kingdom']},
#    'phone': '+442072864461',
#    'display_phone': '+44 20 7286 4461',
#    'distance': 4272.665699508015},
#   {'id': 'ZDDEKWdrpjJHqX2d0InVMg',
#    'alias': 'urban-baristas-london-2',
#    'name': 'Urban Baristas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/f5NsZ4qiBlgvwVMbwh54Qg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/urban-baristas-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5108318662288,
#     'longitude': -0.187354646623135},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Queensway',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 4QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Queensway', 'London W2 4QJ', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3563.8944950081736},
#   {'id': '4T1gT3znvOLfvaeRsmfTvA',
#    'alias': 'thomass-cafe-at-burberry-regent-street-london',
#    'name': "Thomas's Cafe at Burberry Regent Street",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/g2dqw7OpKCjqU0d7wG_jdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thomass-cafe-at-burberry-regent-street-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5104256, 'longitude': -0.1387973},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '5 Vigo Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 3HB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Vigo Street', 'London W1S 3HB', 'United Kingdom']},
#    'phone': '+442031591410',
#    'display_phone': '+44 20 3159 1410',
#    'distance': 343.7804706152944},
#   {'id': 'eBkr2OPdOGkyONlb5FAmcA',
#    'alias': 't4-liverpool-street-london-2',
#    'name': 'T4 Liverpool Street',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-2qjGY4hPbjxjVs2fCqThA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/t4-liverpool-street-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5188661141396, 'longitude': -0.0785778},
#    'transactions': [],
#    'location': {'address1': '8 Brushfield Street',
#     'address2': '',
#     'address3': 'Spitalfields',
#     'city': 'London',
#     'zip_code': 'E1 6AN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Brushfield Street',
#      'Spitalfields',
#      'London E1 6AN',
#      'United Kingdom']},
#    'phone': '+442081271449',
#    'display_phone': '+44 20 8127 1449',
#    'distance': 4026.5765434018313},
#   {'id': 'j0PAetkQTQxUt-9CFhsySA',
#    'alias': 'black-sheep-coffee-london-42',
#    'name': 'Black Sheep Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6z3JfgTbHbR3FVspGb9Iwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-sheep-coffee-london-42?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.514694, 'longitude': -0.086011},
#    'transactions': [],
#    'location': {'address1': '125 Old Broad Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2N 1AR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['125 Old Broad Street',
#      'London EC2N 1AR',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3462.3277442739386},
#   {'id': '-HkQk8DoHwNvzuLKmsWwOA',
#    'alias': 'host-cafe-london-2',
#    'name': 'Host Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/so4TLurpNtPvYfZy-Z_c0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/host-cafe-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5126908219997,
#     'longitude': -0.0935071706771851},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Saint Mary Aldermary',
#     'address2': 'Watling Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4M 9BW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Saint Mary Aldermary',
#      'Watling Street',
#      'London EC4M 9BW',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2937.5326021021433},
#   {'id': 'Jd261zc0ZrBG8x1gs_Cwxg',
#    'alias': 'scotts-pie-and-mash-shop-london',
#    'name': 'Scotts Pie & Mash Shop',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scotts-pie-and-mash-shop-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5000036, 'longitude': -0.1270045},
#    'transactions': [],
#    'location': {'address1': '51 The Walnuts',
#     'address2': 'Town Centre',
#     'address3': 'Orpington',
#     'city': 'London',
#     'zip_code': 'BR6 0TW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 The Walnuts',
#      'Town Centre',
#      'Orpington',
#      'London BR6 0TW',
#      'United Kingdom']},
#    'phone': '+441689876744',
#    'display_phone': '+44 1689 876744',
#    'distance': 1555.536307131157},
#   {'id': 'GWeEuO9SvFKldRJBVJFBcw',
#    'alias': 'le-cordon-bleu-london-3',
#    'name': 'Le Cordon Bleu',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4F6VrTrPduCVRwiTQUWVmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-cordon-bleu-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5189056, 'longitude': -0.1237716},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '15 Bloomsbury Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1A 2LS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Bloomsbury Square',
#      'London WC1A 2LS',
#      'United Kingdom']},
#    'phone': '+442074003900',
#    'display_phone': '+44 20 7400 3900',
#    'distance': 1096.4929426913645},
#   {'id': 'E_3NekwxctQ3BzN7tLKk2A',
#    'alias': 'casa-tua-london-2',
#    'name': 'Casa Tua',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m7FJ2XmVjJQ-Sx0umK6pmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-tua-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 48,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5276449011142,
#     'longitude': -0.123588235886524},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '106 Cromer Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 8BZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['106 Cromer Street',
#      'London WC1H 8BZ',
#      'United Kingdom']},
#    'phone': '+442078331483',
#    'display_phone': '+44 20 7833 1483',
#    'distance': 1855.7864052166005},
#   {'id': '84ujVhySvmiKmxsOXlKLgQ',
#    'alias': 'cuppacha-london-2',
#    'name': 'Cuppacha',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UvZmYNsH9zwHoz30wfGnIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cuppacha-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5340050665719,
#     'longitude': -0.105202701682547},
#    'transactions': [],
#    'location': {'address1': '43 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 0PQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['43 Upper Street', 'London N1 0PQ', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3173.0011115345133},
#   {'id': 'Xc_CqK-PSfeSjcvQVvR4Yg',
#    'alias': 'whittard-london',
#    'name': 'Whittard',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1h4E7cCx0c3mjCmFAHak0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/whittard-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffeeteasupplies',
#      'title': 'Coffee & Tea Supplies'},
#     {'alias': 'chocolate', 'title': 'Chocolatiers & Shops'},
#     {'alias': 'giftshops', 'title': 'Gift Shops'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5096846, 'longitude': -0.1362376},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '65-67 Regent Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 4DZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['65-67 Regent Street',
#      'London W1B 4DZ',
#      'United Kingdom']},
#    'phone': '+442074374175',
#    'display_phone': '+44 20 7437 4175',
#    'distance': 345.5037803208439},
#   {'id': 'UzE5yz6dMpK4pumxfxH-HA',
#    'alias': 'fortnum-and-mason-heathrow-london',
#    'name': 'Fortnum & Mason Heathrow',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3u4t_7WSgNwDuF8YTNwcag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fortnum-and-mason-heathrow-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.481459, 'longitude': -0.44486},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '234 Bath Road',
#     'address2': 'Heathrow Terminal 2',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'UB3 5AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['234 Bath Road',
#      'Heathrow Terminal 2',
#      'London UB3 5AP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 21658.20425034626},
#   {'id': 'n_HexdowAUaDBNZ8qWFykg',
#    'alias': 'curled-leaf-london',
#    'name': 'Curled Leaf',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/curled-leaf-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5515376226734,
#     'longitude': -0.19876798784018},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '98 Mill Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 1NF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['98 Mill Lane', 'London NW6 1NF', 'United Kingdom']},
#    'phone': '+442077946296',
#    'display_phone': '+44 20 7794 6296',
#    'distance': 6115.33028657133},
#   {'id': 'Fz845NV8xsrrTo7lIBc4vQ',
#    'alias': '2-love-tea-and-coffee-house-london',
#    'name': '2 Love Tea and Coffee House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-wNxSeVDd-PdD0sksfexRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/2-love-tea-and-coffee-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4610438, 'longitude': -0.1669939},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "89 St John's Rd",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW11 1QY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["89 St John's Rd",
#      'London SW11 1QY',
#      'United Kingdom']},
#    'phone': '+442079987130',
#    'display_phone': '+44 20 7998 7130',
#    'distance': 6146.893529917467},
#   {'id': 'U_XeFWW1Lttdq22txTABMw',
#    'alias': 'gails-bakery-neo-bankside-london',
#    'name': "GAIL's Bakery Neo Bankside",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CEfkaYA0zFoAlNcdiNt_aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gails-bakery-neo-bankside-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5066352772979,
#     'longitude': -0.100412668500134},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit C Neo Bankside',
#     'address2': '70 Holland Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9NX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit C Neo Bankside',
#      '70 Holland Road',
#      'London SE1 9NX',
#      'United Kingdom']},
#    'phone': '+442079280621',
#    'display_phone': '+44 20 7928 0621',
#    'distance': 2554.576460738087},
#   {'id': '_sh6rhL66Ovek6HpJPmHOA',
#    'alias': 'the-library-at-county-hall-london',
#    'name': 'The Library at County Hall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mWFbYV2ex06e_IB9MVBG1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-library-at-county-hall-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5015929265416,
#     'longitude': -0.119514539837837},
#    'transactions': [],
#    'location': {'address1': 'Westminster Bridge Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 7PB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Westminster Bridge Road',
#      'London SE1 7PB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1690.4411519899013},
#   {'id': '-MMUfvKPJXeo5ONoHSw7Zw',
#    'alias': 'double-six-cafe-london',
#    'name': 'Double Six Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Eevd-YQNFeUZFgBz6cpc2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/double-six-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5295715, 'longitude': -0.1330154},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '66 Eversholt Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 1DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Eversholt Street',
#      'London NW1 1DA',
#      'United Kingdom']},
#    'phone': '+442073870262',
#    'display_phone': '+44 20 7387 0262',
#    'distance': 1868.62168679472},
#   {'id': 'uOJdfrpcGudig1CSKy54Dg',
#    'alias': 'lab-cafe-london',
#    'name': 'Lab Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yhfofjS6GM-lt_QfiPpj9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lab-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514595, 'longitude': -0.15285},
#    'transactions': [],
#    'location': {'address1': 'Selfridges 2nd Floor',
#     'address2': '400 Oxford Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1A 1AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Selfridges 2nd Floor',
#      '400 Oxford Street',
#      'London W1A 1AB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1176.758684857418},
#   {'id': 'FFJ0zFhCNkodqGA7CCf5mQ',
#    'alias': 'the-penny-drop-london-2',
#    'name': 'The Penny Drop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WaMCkr61mJR5X0k6-hSI7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-penny-drop-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5204977, 'longitude': -0.1351846},
#    'transactions': [],
#    'location': {'address1': '13 Tottenham Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1T 2AH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13 Tottenham Street',
#      'London W1T 2AH',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 853.664034889092},
#   {'id': '68gc1BAE1IT_zZghFafw0Q',
#    'alias': 'ozone-coffee-london-2',
#    'name': 'Ozone Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FMKfpA6gKHlDAKDuPVVdTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ozone-coffee-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 188,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.524683689256,
#     'longitude': -0.086674106560876},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Leonard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 4AQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Leonard Street',
#      'London EC2A 4AQ',
#      'United Kingdom']},
#    'phone': '+442074901039',
#    'display_phone': '+44 20 7490 1039',
#    'distance': 3655.552919913525},
#   {'id': '8YjRy2Zd-0lwVQpfs1jVsA',
#    'alias': 'boat-house-cafe-london',
#    'name': 'Boat House Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FzXoYTPZoh-HcbIG54T3Ww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boat-house-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5072572124003,
#     'longitude': -0.070714684354336},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "St Katharine's Docks",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1W',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["St Katharine's Docks",
#      'London E1W',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4557.4288183307535},
#   {'id': '4Z4ITxO2JTyzjJRQG0tirA',
#    'alias': 'whittard-of-chelsea-london',
#    'name': 'Whittard of Chelsea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/j8Xyj1P5rjZA98dUoxjiOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/whittard-of-chelsea-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'coffeeteasupplies',
#      'title': 'Coffee & Tea Supplies'},
#     {'alias': 'chocolate', 'title': 'Chocolatiers & Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4985246180407,
#     'longitude': -0.143380162778612},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 1',
#     'address2': '29 Buckingham Palace Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 0PP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 1',
#      '29 Buckingham Palace Road',
#      'London SW1W 0PP',
#      'United Kingdom']},
#    'phone': '+442078219698',
#    'display_phone': '+44 20 7821 9698',
#    'distance': 1672.2063044537028},
#   {'id': '-C_XNwbfJu3RMvdu0oDwZA',
#    'alias': 'paul-canary-wharf-london',
#    'name': 'PAUL Canary Wharf',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6KlCtAW60G3-hO_t95sFdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-canary-wharf-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.505188, 'longitude': -0.020382},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Unit RP 390',
#     'address2': 'Cabot Place',
#     'address3': 'Canary Wharf',
#     'city': 'London',
#     'zip_code': 'E14 5AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit RP 390',
#      'Cabot Place',
#      'Canary Wharf',
#      'London E14 5AB',
#      'United Kingdom']},
#    'phone': '+442075191703',
#    'display_phone': '+44 20 7519 1703',
#    'distance': 8043.558248238632},
#   {'id': 'nI1XOUOdIAh5SmQJ4b31yw',
#    'alias': 'the-v-and-a-café-london-3',
#    'name': 'The V&A Café',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OMsbe3EBlRK4FVkww4TwGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-v-and-a-caf%C3%A9-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.497374632002,
#     'longitude': -0.172478386364495},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Victoria & Albert Museum',
#     'address2': 'Cromwell Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 2RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Victoria & Albert Museum',
#      'Cromwell Road',
#      'London SW7 2RL',
#      'United Kingdom']},
#    'phone': '+442079422211',
#    'display_phone': '+44 20 7942 2211',
#    'distance': 3057.0312944343955},
#   {'id': 'ChWDaYEVATiRTqv3lBaSkQ',
#    'alias': 'high-tea-of-highgate-london',
#    'name': 'High Tea Of Highgate',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3QYpMhgMInZ0PgenVxhWNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/high-tea-of-highgate-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5709556, 'longitude': -0.1480439},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '50 Highgate High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N6 5HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50 Highgate High Street',
#      'London N6 5HX',
#      'United Kingdom']},
#    'phone': '+442083483162',
#    'display_phone': '+44 20 8348 3162',
#    'distance': 6516.4948258962995},
#   {'id': 'a-hDyvimTMu-FwphEL8mug',
#    'alias': 'portrait-café-london-2',
#    'name': 'Portrait Café',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bIrdxL_wL2cCLrGsTdukLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/portrait-caf%C3%A9-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5092935261756,
#     'longitude': -0.1275874376297},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'National Portrait Gallery',
#     'address2': '2 St Martins Place',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 0HE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['National Portrait Gallery',
#      '2 St Martins Place',
#      'London WC2H 0HE',
#      'United Kingdom']},
#    'phone': '+448721481007',
#    'display_phone': '+44 872 148 1007',
#    'distance': 700.3574589149606},
#   {'id': 'sP8YA4G77wcc4uZHBx8GtQ',
#    'alias': 'tea-studio-trinity-buoy-wharf',
#    'name': 'Tea Studio',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oovFTQFqRBKbZz7Q4Q1dcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tea-studio-trinity-buoy-wharf?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'coffeeteasupplies', 'title': 'Coffee & Tea Supplies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.508398, 'longitude': 0.0082},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Studio 15',
#     'address2': 'Riverside Building',
#     'address3': '',
#     'city': 'Trinity Buoy Wharf',
#     'zip_code': 'E14 0FP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Studio 15',
#      'Riverside Building',
#      'Trinity Buoy Wharf E14 0FP',
#      'United Kingdom']},
#    'phone': '+442038281708',
#    'display_phone': '+44 20 3828 1708',
#    'distance': 9988.390714394243},
#   {'id': '2DPvfVF6vSEaZ5JqDFnXTw',
#    'alias': 'sweetheart-london-2',
#    'name': 'Sweetheart',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_Th_C_WBYuE-upP5DJ8oNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweetheart-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'cupcakes', 'title': 'Cupcakes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5118923302027,
#     'longitude': -0.122435174762825},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 34',
#     'address2': 'The Market',
#     'address3': 'Covent Garden',
#     'city': 'London',
#     'zip_code': 'WC2E 8RE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 34',
#      'The Market',
#      'Covent Garden',
#      'London WC2E 8RE',
#      'United Kingdom']},
#    'phone': '+442072405039',
#    'display_phone': '+44 20 7240 5039',
#    'distance': 941.5093845598345},
#   {'id': 'YZIsogwDym4uAgoAH3bQUw',
#    'alias': 'beehive-london-4',
#    'name': 'Beehive',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XonTWExprcY09ipinpTZTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beehive-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.491655, 'longitude': -0.2556941},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '28 Devonshire Road',
#     'address2': 'Chiswick',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W4 2HD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28 Devonshire Road',
#      'Chiswick',
#      'London W4 2HD',
#      'United Kingdom']},
#    'phone': '+442089948628',
#    'display_phone': '+44 20 8994 8628',
#    'distance': 8616.05744964085},
#   {'id': 'RouMqlhHGlFj4jUr6CIwUA',
#    'alias': 'the-den-at-st-martins-lane-london-2',
#    'name': 'The Den at St Martins Lane',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8R8XKLYch9ZQlGoSgzcaHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-den-at-st-martins-lane-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.510378, 'longitude': -0.1268051},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'St Martins Lane',
#     'address2': '45 St Martins Lane',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4EA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['St Martins Lane',
#      '45 St Martins Lane',
#      'London WC2N 4EA',
#      'United Kingdom']},
#    'phone': '+442073005500',
#    'display_phone': '+44 20 7300 5500',
#    'distance': 699.9833691313636},
#   {'id': 'mY7jfpFRET1_34ZMTpEhIw',
#    'alias': 'sacred-london-4',
#    'name': 'Sacred',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LrnTUQWHEL14bfJK-5Hkzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sacred-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5072023, 'longitude': -0.221239},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Westfield London Shopping Centre',
#     'address2': 'The Atrium',
#     'address3': 'Ariel Way',
#     'city': 'London',
#     'zip_code': 'W12 7GQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Westfield London Shopping Centre',
#      'The Atrium',
#      'Ariel Way',
#      'London W12 7GQ',
#      'United Kingdom']},
#    'phone': '+442076073838',
#    'display_phone': '+44 20 7607 3838',
#    'distance': 5935.183798654211},
#   {'id': 'GTImh5FbaxKTo8TXyxRT4w',
#    'alias': 'rabot-1745-london-3',
#    'name': 'Rabot 1745',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MZQVMlveAsL3Gh11ocSHZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rabot-1745-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 80,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5053829371106,
#     'longitude': -0.0899640662595528},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2-4 Bedale Street',
#     'address2': 'Borough Market',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9AL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2-4 Bedale Street',
#      'Borough Market',
#      'London SE1 9AL',
#      'United Kingdom']},
#    'phone': '+442073788226',
#    'display_phone': '+44 20 7378 8226',
#    'distance': 3289.037757085594},
#   {'id': 'Q-f511k1hYDIKfKIpC_HIw',
#    'alias': 'fabrique-bakery-london-4',
#    'name': 'Fabrique Bakery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5Qq5T9LiFK91ag7ftRlFWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fabrique-bakery-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5134638236347,
#     'longitude': -0.12840236007971},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8 Earlham Street',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9RY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Earlham Street',
#      'Covent Garden',
#      'London WC2H 9RY',
#      'United Kingdom']},
#    'phone': '+442072401392',
#    'display_phone': '+44 20 7240 1392',
#    'distance': 527.3502509023187},
#   {'id': 'wm6Hwzan5qYhTzCDmO3oDQ',
#    'alias': 'muriels-kitchen-london',
#    'name': "Muriel's Kitchen",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9un8EzHME-wGnd7zVoev2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/muriels-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 134,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.494117, 'longitude': -0.174468},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 1',
#     'address2': '3 Pelham Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 2ND',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 1',
#      '3 Pelham Street',
#      'London SW7 2ND',
#      'United Kingdom']},
#    'phone': '+442075893511',
#    'display_phone': '+44 20 7589 3511',
#    'distance': 3381.980840047671},
#   {'id': 'kr2GXDBoeT1zYLbOZEPMHw',
#    'alias': 'dulce-cafe-london',
#    'name': 'Dulce Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/w1E52CDDLVg35epHLlLItg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dulce-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5157828853472,
#     'longitude': -0.0701125458498586},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '86 Whitechapel High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 7QX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['86 Whitechapel High Street',
#      'London E1 7QX',
#      'United Kingdom']},
#    'phone': '+442073751636',
#    'display_phone': '+44 20 7375 1636',
#    'distance': 4568.036992788059},
#   {'id': 'DAE3fIusVTUGt9PDwPlelg',
#    'alias': 'exmouth-coffee-company-london',
#    'name': 'Exmouth Coffee Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0yrsGXNRm5roKhOo_8VUiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/exmouth-coffee-company-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 81,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.515994, 'longitude': -0.070496},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '83 Whitechapel High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 7QX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Whitechapel High Street',
#      'London E1 7QX',
#      'United Kingdom']},
#    'phone': '+442073771010',
#    'display_phone': '+44 20 7377 1010',
#    'distance': 4553.663911477298},
#   {'id': 'fXXpHxB-Ijf0FM3sQacsPQ',
#    'alias': 'cafe-de-fred-london',
#    'name': 'Cafe de Fred',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QKhpj0Z8dO5WxPUlf_NlEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-de-fred-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.498455, 'longitude': -0.198598},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '10a Earls Court Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 6DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10a Earls Court Road',
#      'London W8 6DA',
#      'United Kingdom']},
#    'phone': '+442079381556',
#    'display_phone': '+44 20 7938 1556',
#    'distance': 4612.851200878143},
#   {'id': 'lMxu8jhSIb_liUki8cy2Wg',
#    'alias': 'chamomile-london',
#    'name': 'Chamomile',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/L1XvSQmXkGbyxSqLdzqEWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chamomile-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5456005, 'longitude': -0.1623197},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "45 England's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 4YD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["45 England's Lane",
#      'London NW3 4YD',
#      'United Kingdom']},
#    'phone': '+442075864580',
#    'display_phone': '+44 20 7586 4580',
#    'distance': 4074.0720076605753},
#   {'id': 'PCXrad73m0VqqFmqKW5ZRA',
#    'alias': 'yunique-london',
#    'name': 'Yunique',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IXzEb7UMOY3a_YLulTM_QA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yunique-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5118263512738,
#     'longitude': -0.129062868654728},
#    'transactions': [],
#    'location': {'address1': '10 Little Newport Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2H 7JJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Little Newport Street',
#      'London WC2H 7JJ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 490.0244700737028},
#   {'id': 'OiMSRYdiUZDxHRdT88FKQA',
#    'alias': 'cafe-vintage-london',
#    'name': 'Cafe Vintage',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vjqCUoXHsei8XSWKuI3oBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-vintage-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'fashion', 'title': 'Fashion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.561075689401,
#     'longitude': -0.097312043609048},
#    'transactions': [],
#    'location': {'address1': '88 Mountgrove Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N5 2LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['88 Mountgrove Road',
#      'London N5 2LT',
#      'United Kingdom']},
#    'phone': '+447903875750',
#    'display_phone': '+44 7903 875750',
#    'distance': 5993.060861496003},
#   {'id': 'aGqt0g9_WU2UGituR7yn-w',
#    'alias': 'farm-girl-cafe-london',
#    'name': 'Farm Girl Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Qxj7RtZyROODLKeUzWbarw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/farm-girl-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 78,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5120686916922,
#     'longitude': -0.200769876546774},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '59A Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 3DB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['59A Portobello Road',
#      'London W11 3DB',
#      'United Kingdom']},
#    'phone': '+442072294678',
#    'display_phone': '+44 20 7229 4678',
#    'distance': 4486.039469290095},
#   {'id': 'cmEEbxS7FXHhRONnb-Um4Q',
#    'alias': 'elliots-london',
#    'name': "Elliot's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IRuXRNS9zw_lgSSyswl9RQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elliots-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5056571960449,
#     'longitude': -0.091669000685215},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '12 Stoney Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9AD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Stoney Street',
#      'London SE1 9AD',
#      'United Kingdom']},
#    'phone': '+442074037436',
#    'display_phone': '+44 20 7403 7436',
#    'distance': 3170.4112351766125}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#                                Restaurant          Type Price Rating  \
# 0                                    Paul  Coffee & Tea    ££      4
# 1                    Kennington Lane Cafe         Cafes     £      5
# 2                         The Watch House  Coffee & Tea
# 3                                  Up...T  Coffee & Tea     £      4
# 4  Madd Hatters Cafe by Massis Tea & Madd  Coffee & Tea    ££      4
#
#                     Address        Lat       Lng  \
# 0         Paternoster Lodge  51.514680 -0.098430
# 1       383 Kennington Lane  51.486061 -0.120851
# 2     139 Commercial Street  51.520890 -0.075280
# 3  10 Little Newport Street  51.511716 -0.128740
# 4  6/7 Great Newport Street  51.512531 -0.126843
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/paul-london-32?adjust...  ttROKeMmaM1k39JogTAFSA
# 1  https://www.yelp.com/biz/kennington-lane-cafe-...  p77CnjTGOIZA1hEpLfCC6Q
# 2
# 3  https://www.yelp.com/biz/up-t-london?adjust_cr...  RUlcbocOFeAaNnLHpApyvg
# 4  https://www.yelp.com/biz/madd-hatters-cafe-by-...  QkVCOVfQQkLnVpDl8Z02GA

# %%
london_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
london_restaurants_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_restaurants_df = london_restaurants_df[column_order]
london_restaurants_df = london_restaurants_df.sort_values(["Type"], ascending=True)
london_restaurants_df = london_restaurants_df.reset_index(drop=True)
london_restaurants_df
# Out:
#                                             Restaurant                Type  \
# 0                                      Fortnum & Mason         Accessories
# 1                                             Red Door       Art Galleries
# 2                                              Poilane            Bakeries
# 3                                      Primrose Bakery            Bakeries
# 4                                      Brigit's Bakery            Bakeries
# 5                                    Maroush Bakehouse            Bakeries
# 6                                    PAUL Canary Wharf            Bakeries
# 7                                              Ladurée            Bakeries
# 8               Queen Elizabeth Roof Garden Bar & Café                Bars
# 9                                      Books for Cooks          Bookstores
# 10                                         Mirror Room  Breakfast & Brunch
# 11                          GAIL's Bakery Neo Bankside  Breakfast & Brunch
# 12                            Original Maids Of Honour             British
# 13                                     The Garden Café             British
# 14                                     Urban Tea Rooms             British
# 15                                        Granger & Co             British
# 16                                           The Table             British
# 17                                        The Orangery             British
# 18                                      Tea and Tattle             British
# 19                                       Treves & Hyde             British
# 20                          The Library at County Hall             British
# 21                                    Muriel's Kitchen             British
# 22                                             Woo Tea          Bubble Tea
# 23                                          Golden Tea          Bubble Tea
# 24                                            Kissaten          Bubble Tea
# 25                                        Xing Fu Tang          Bubble Tea
# 26                                            Cuppacha          Bubble Tea
# 27                                     Gonuts Boba Tea          Bubble Tea
# 28                                             Yunique          Bubble Tea
# 29                                             Chatime          Bubble Tea
# ..                                                 ...                 ...
# 170                                  Harrods' Tea Room          Sandwiches
# 171                                           Bageriet        Scandinavian
# 172                  The East India Company Fine Foods      Specialty Food
# 173                             Teanamu Chaya Teahouse           Tea Rooms
# 174                                            Yi Fang           Tea Rooms
# 175                                Bea's of Bloomsbury           Tea Rooms
# 176                                        Katsute 100           Tea Rooms
# 177                               The English Tea Room           Tea Rooms
# 178                         The Foyer and Reading Room           Tea Rooms
# 179                                            Tsujiri           Tea Rooms
# 180                                  Candella Tea Room           Tea Rooms
# 181                                   Teatulia Tea Bar           Tea Rooms
# 182                              Serendipity Tea Rooms           Tea Rooms
# 183                                         Tea Studio           Tea Rooms
# 184                             The Basement Tea Rooms           Tea Rooms
# 185                                           Mei Leaf           Tea Rooms
# 186                         The St. Ermin's Tea Lounge           Tea Rooms
# 187                                Hampstead Tea Rooms           Tea Rooms
# 188                                         Palm Court           Tea Rooms
# 189                   Bea's of Bloomsbury - Marylebone           Tea Rooms
# 190                                                TWG           Tea Rooms
# 191                                          Savoy Tea           Tea Rooms
# 192                                    The Rose Lounge           Tea Rooms
# 193  Victorian Afternoon Tea - Victoria and Albert ...           Tea Rooms
# 194                               Camellia's Tea House           Tea Rooms
# 195                                       T4 Tea for U           Tea Rooms
# 196                           Scoff & Banter Tea Rooms           Tea Rooms
# 197                                The Rosebery Lounge           Tea Rooms
# 198                                  Tea House Theatre           Tea Rooms
# 199                                          Black Cat               Vegan
#
#     Rating Price                      Address        Lat       Lng  \
# 0      4.5   £££               181 Piccadilly  51.508367 -0.138358
# 1      4.5    ££              10 Turnpin Lane  51.481164 -0.009072
# 2      4.5   £££           39 Cadogan Gardens  51.492055 -0.159778
# 3        4    ££         69 Gloucester Avenue  51.540226 -0.151122
# 4        4    ££            6-7 Chandos Place  51.510089 -0.124540
# 5      4.5    ££         131 Earls Court Road  51.493320 -0.194478
# 6      3.5   £££                  Unit RP 390  51.505188 -0.020382
# 7        4   £££                 1 The Market  51.511843 -0.123133
# 8      3.5    ££         Queen Elizabeth Hall  51.505710 -0.116687
# 9        5    ££           4 Blenheim Cresent  51.515943 -0.205374
# 10                           252 High Holborn  51.517593 -0.117883
# 11     4.5    ££          Unit C Neo Bankside  51.506635 -0.100413
# 12       4    ££                 288 Kew Road  51.480650 -0.288494
# 13     3.5    ££                 Inner Circle  51.526875 -0.154452
# 14       4    ££             19 Kingly Street  51.512947 -0.139558
# 15       4    ££         175 Westbourne Grove  51.514646 -0.197799
# 16       4    ££          83 Southwark Street  51.505604 -0.099671
# 17       4   £££            Kensington Palace  51.506636 -0.187725
# 18     4.5    ££      41 Great Russell Street  51.517868 -0.126817
# 19                             15/17 leman st  51.514397 -0.071017
# 20                    Westminster Bridge Road  51.501593 -0.119515
# 21       4    ££                       Unit 1  51.494117 -0.174468
# 22                      G/F-24 Wardour Street  51.511249 -0.131985
# 23                     156 Bethnal Green Road  51.525320 -0.070470
# 24                           30 Brewer Street  51.512139 -0.134605
# 25                            29 Frith Street  51.512790 -0.130833
# 26                            43 Upper Street  51.534005 -0.105203
# 27                          228 Holloway Road  51.552610 -0.111970
# 28                   10 Little Newport Street  51.511826 -0.129063
# 29       5     £          68 Rivington Street  51.526136 -0.080011
# ..     ...   ...                          ...        ...       ...
# 170      4    ££           87-135 Brompton Rd  51.499226 -0.163594
# 171    4.5     £               24 Rose Street  51.511924 -0.126182
# 172      5   £££           7-8 Conduit Street  51.512870 -0.141549
# 173    4.5    ££                4 Melina Road  51.514858 -0.207802
# 174    4.5    ££                Brushfield St  51.519699 -0.075334
# 175                         72 Russell Square  51.522151 -0.124710
# 176                            Camden Passage  51.534463 -0.104346
# 177      4   £££          30 Albemarle Street  51.509136 -0.142163
# 178    4.5  ££££                   Claridge's  51.512820 -0.147562
# 179      4     £             47 Rupert Street  51.511933 -0.133540
# 180    4.5    ££  34 Kensington Church Street  51.504074 -0.192012
# 181                            36 Neal Street  51.514331 -0.125458
# 182               241-243 Streatham High Road  51.426668 -0.130868
# 183      5    ££                    Studio 15  51.508398  0.008200
# 184      4     £               Stables Market  51.542288 -0.148351
# 185      5    ££    99-105 Camden High Street  51.536856 -0.141020
# 186    4.5    ££              2 Caxton Street  51.499102 -0.134611
# 187      4    ££                 9 S End Road  51.554198 -0.165751
# 188      4   £££            1C Portland Place  51.517861 -0.143805
# 189    4.5    ££        27A Devonshire Street  51.522300 -0.144390
# 190                       48 Leicester Square  51.510331 -0.131230
# 191    4.5  ££££                    The Savoy  51.510550 -0.121951
# 192    4.5   £££             Sofitel St James  51.507811 -0.132897
# 193                             Cromwell Road  51.495550 -0.176240
# 194                       64 Great Russell St  51.518644 -0.124841
# 195    3.5     £              Montfichet Road  51.543562 -0.005968
# 196    4.5    ££            350 Oxford Street  51.514620 -0.148411
# 197    4.5   £££             66 Knightsbridge  51.502405 -0.159971
# 198    3.5    ££            Tea House Theatre  51.488146 -0.120783
# 199    4.5     £             76 Clarence Road  51.551397 -0.055691
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/fortnum-and-mason-lon...  eyFzHGBlLjMWmsXFdMrA3w
# 1    https://www.yelp.com/biz/red-door-london?adjus...  RYus9YxVxD-R8jm6xkDX8g
# 2    https://www.yelp.com/biz/poilane-london?adjust...  Wv1Zlca4NTkgFVjKgEJyog
# 3    https://www.yelp.com/biz/primrose-bakery-londo...  dIWOqYszVKk-oswXDzUH6A
# 4    https://www.yelp.com/biz/brigits-bakery-london...  tH_2560cbjme-hFBFVj8cQ
# 5    https://www.yelp.com/biz/maroush-bakehouse-lon...  Da8ClETsPknyD-XIam-jbg
# 6    https://www.yelp.com/biz/paul-canary-wharf-lon...  -C_XNwbfJu3RMvdu0oDwZA
# 7    https://www.yelp.com/biz/ladur%C3%A9e-london-1...  5_0GHVzaA2tgzHSvFt5idw
# 8    https://www.yelp.com/biz/queen-elizabeth-roof-...  pOQwGM-8Qrwb8PGzLDGyeg
# 9    https://www.yelp.com/biz/books-for-cooks-londo...  -fLxQOd0pjTkQl4ttwR4XA
# 10
# 11   https://www.yelp.com/biz/gails-bakery-neo-bank...  U_XeFWW1Lttdq22txTABMw
# 12   https://www.yelp.com/biz/original-maids-of-hon...  cse6Zq5WyXkOxfVjFd5Ftw
# 13   https://www.yelp.com/biz/the-garden-caf%C3%A9-...  kOmkk63gMmsKk0Wve5aJRA
# 14   https://www.yelp.com/biz/urban-tea-rooms-londo...  ZUIJ8U6GU6TLx29lcwIyvg
# 15   https://www.yelp.com/biz/granger-and-co-london...  0r2-fwgLvuOLef0epiFkFQ
# 16   https://www.yelp.com/biz/the-table-london-8?ad...  rKwkCvsSfp8z7w1CmNnMMQ
# 17   https://www.yelp.com/biz/the-orangery-london-7...  PBFvhVyBi0lEJyTbyuxf5w
# 18   https://www.yelp.com/biz/tea-and-tattle-london...  1TgYqfxkXv6-IB4cvuuy3w
# 19
# 20
# 21   https://www.yelp.com/biz/muriels-kitchen-londo...  wm6Hwzan5qYhTzCDmO3oDQ
# 22
# 23
# 24
# 25
# 26
# 27
# 28
# 29   https://www.yelp.com/biz/chatime-london-4?adju...  bM4i_JbpURfbJ6l_pIxMSQ
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/harrods-tea-room-lond...  6hw3LjFoZ3aLcnfxuDSJAg
# 171  https://www.yelp.com/biz/bageriet-london?adjus...  0tJs57Xoq75-RDWKVco0nw
# 172  https://www.yelp.com/biz/the-east-india-compan...  XfXZ3GtzcZtCcPeLv5wHJA
# 173  https://www.yelp.com/biz/teanamu-chaya-teahous...  Tb1cVvzhIzGGxTpLlgCOCQ
# 174  https://www.yelp.com/biz/yi-fang-london?adjust...  TqSnt86jxwyllhb-WVV8wQ
# 175
# 176
# 177  https://www.yelp.com/biz/the-english-tea-room-...  KLofVP70jrDEnxBLkoSmmw
# 178  https://www.yelp.com/biz/the-foyer-and-reading...  T_Vi4oboGjQdd0-IBBV5rg
# 179  https://www.yelp.com/biz/tsujiri-london?adjust...  cW7lpaW9hnyLFVhoJ4DfhA
# 180  https://www.yelp.com/biz/candella-tea-room-lon...  tcVWoHSko9PIy_Ec95_j1A
# 181
# 182
# 183  https://www.yelp.com/biz/tea-studio-trinity-bu...  sP8YA4G77wcc4uZHBx8GtQ
# 184  https://www.yelp.com/biz/the-basement-tea-room...  QhUxOg8WBi9iQV3_rC4Mfg
# 185  https://www.yelp.com/biz/mei-leaf-london?adjus...  t-SEsNsUW0DS2dcvtFmx3Q
# 186  https://www.yelp.com/biz/the-st-ermins-tea-lou...  wdPCcml663tzNsnBWArE0g
# 187  https://www.yelp.com/biz/hampstead-tea-rooms-l...  eRVFJXY-aLDD-0qmYvEBag
# 188  https://www.yelp.com/biz/palm-court-london?adj...  1pUEGW91riUIux0TZWw_4g
# 189  https://www.yelp.com/biz/beas-of-bloomsbury-ma...  ttV7LFe4atjb9c7MZHn7Bw
# 190
# 191  https://www.yelp.com/biz/savoy-tea-strand?adju...  mBTDYaxdZ6S4QnV9raERkw
# 192  https://www.yelp.com/biz/the-rose-lounge-londo...  OGDGdRZgbcRFE7oYFWU9jw
# 193
# 194
# 195  https://www.yelp.com/biz/t4-tea-for-u-london?a...  BWOhQKfARucMBBwf3C90Aw
# 196  https://www.yelp.com/biz/scoff-and-banter-tea-...  m-49WP-2bBX6INAP8o9VoA
# 197  https://www.yelp.com/biz/the-rosebery-lounge-l...  mOD60RafvMIEv0PR0QqV-g
# 198  https://www.yelp.com/biz/tea-house-theatre-lon...  HG-nUBOpiMIo3cYdaNbM8Q
# 199  https://www.yelp.com/biz/black-cat-london?adju...  f8s8dT9Rm4359xUVHtiqRA
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
london_restaurants_df.to_csv('Resources/London_Restaurants_Tea.csv')
