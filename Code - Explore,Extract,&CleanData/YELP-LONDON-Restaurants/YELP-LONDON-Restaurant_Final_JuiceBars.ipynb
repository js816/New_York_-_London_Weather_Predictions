# %% [markdown]
# LONDON RESTAURANTS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
term = "juice bar"

# %%
#First set of 50 records 0-50
lndr_params1 = {"term":term,"location":"London","limit":50,"offset":0}
lndr_response1 = requests.get(search_api_url, headers=headers, params=lndr_params1)
lndr1 = lndr_response1.json()
display(lndr1)
#print(lndr_response1.url)
#print(lndr_response1.status_code)
# Out:
# {'businesses': [{'id': 'LtKwDYJMa1Ud_6MrsIOKvQ',
#    'alias': 'joe-and-the-juice-london',
#    'name': 'JOE & THE JUICE',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ng5sqzvKV7WOEwXfojFX0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joe-and-the-juice-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 89,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5161285, 'longitude': -0.1424872},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '281 Regent Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 2HE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['281 Regent Street',
#      'London W1B 2HE',
#      'United Kingdom']},
#    'phone': '+442073551000',
#    'display_phone': '+44 20 7355 1000',
#    'distance': 585.6274532203665},
#   {'id': 'a9nibAT0lq28RDTRKy15Cw',
#    'alias': 'press-london-2',
#    'name': 'PRESS',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BT2vDucuuO-sLAcoeGIqWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/press-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.510902, 'longitude': -0.1346108},
#    'transactions': [],
#    'location': {'address1': '6 Denman Street',
#     'address2': 'Ham Yard Hotel',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 7HD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Denman Street',
#      'Ham Yard Hotel',
#      'London W1D 7HD',
#      'United Kingdom']},
#    'phone': '+442072872462',
#    'display_phone': '+44 20 7287 2462',
#    'distance': 234.28065582081962},
#   {'id': 'onnTNyrh_MeFIz34ywRSag',
#    'alias': 'pure-made-for-you-london-30',
#    'name': 'Pure - Made for You',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LWpj2aHmUhJDZg1FQSDB7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pure-made-for-you-london-30?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5191707, 'longitude': -0.1360068},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '47 Goodge Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 1TD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Goodge Street',
#      'London W1T 1TD',
#      'United Kingdom']},
#    'phone': '+442074363601',
#    'display_phone': '+44 20 7436 3601',
#    'distance': 704.4477983234599},
#   {'id': 'mf3jzlhoDSAsm4xs2lxggg',
#    'alias': 'viva-acai-london',
#    'name': 'Viva Acai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cP1Lb2iixyMSxF_qa6XWXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/viva-acai-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.494509, 'longitude': -0.183555},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 15 Gloucester Arcade',
#     'address2': '128 Gloucester Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 4SF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 15 Gloucester Arcade',
#      '128 Gloucester Road',
#      'London SW7 4SF',
#      'United Kingdom']},
#    'phone': '+442078350669',
#    'display_phone': '+44 20 7835 0669',
#    'distance': 3833.3542345945298},
#   {'id': '6G6lvHO8c12MGFcdDbRhkA',
#    'alias': 'cyclelab-and-juicebar-london',
#    'name': 'CycleLab & JuiceBar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tk1mrEG8YstHcv2e8XDW6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cyclelab-and-juicebar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.527144, 'longitude': -0.083562},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '16B-18A Pitfield Street',
#     'address2': 'Shoreditch',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 6EY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16B-18A Pitfield Street',
#      'Shoreditch',
#      'London N1 6EY',
#      'United Kingdom']},
#    'phone': '+442032220016',
#    'display_phone': '+44 20 3222 0016',
#    'distance': 3967.092912543902},
#   {'id': 'a7r33JtBW35c2IalZLyOHA',
#    'alias': 'crussh-london-10',
#    'name': 'Crussh',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/I5VsLdMnhxOpYyLLwav2_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crussh-london-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5141925019073,
#     'longitude': -0.160121063131597},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 4',
#     'address2': 'Bryanston Street',
#     'address3': 'London',
#     'city': 'London',
#     'zip_code': 'W1H 7EF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 4',
#      'Bryanston Street',
#      'London',
#      'London W1H 7EF',
#      'United Kingdom']},
#    'phone': '+442077235272',
#    'display_phone': '+44 20 7723 5272',
#    'distance': 1679.0259489257446},
#   {'id': 'sTjZJB20joSHE8oVPHs1Cw',
#    'alias': 'covent-garden-grind-london',
#    'name': 'Covent Garden Grind',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c7YW3mmPah5JplPL-fFPbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/covent-garden-grind-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5110479046224,
#     'longitude': -0.122459969000028},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '42 Maiden Lane',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2E 7LJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 Maiden Lane',
#      'Covent Garden',
#      'London WC2E 7LJ',
#      'United Kingdom']},
#    'phone': '+442030191801',
#    'display_phone': '+44 20 3019 1801',
#    'distance': 954.8611659358846},
#   {'id': 'jYjLF_8a95J_Iq-yO2Pm7Q',
#    'alias': 'crussh-juice-bar-london',
#    'name': 'Crussh Juice Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LU0x0QMTs02B8tFwy6Olow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crussh-juice-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514044, 'longitude': -0.135088},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 Broadwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8HP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 Broadwick Street',
#      'London W1F 8HP',
#      'United Kingdom']},
#    'phone': '+442072874480',
#    'display_phone': '+44 20 7287 4480',
#    'distance': 148.4166689985696},
#   {'id': 'UGVu0hwCHfOw7Fc4BdYGRw',
#    'alias': 'total-organics-london',
#    'name': 'Total Organics',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YYNjrragqUNnGsoTXu73dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/total-organics-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5050392, 'longitude': -0.09079},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Stoney Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1TL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Stoney Street', 'London SE1 1TL', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3174.621286596372},
#   {'id': 'pTzAvHQQ-eJqp8fcZ8F_wQ',
#    'alias': 'planet-organic-london-2',
#    'name': 'Planet Organic',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NWj6-btnC-bVbCYfo5gIKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/planet-organic-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'healthmarkets', 'title': 'Health Markets'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.521367, 'longitude': -0.134126},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Torrington Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1E 7HJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Torrington Place',
#      'London WC1E 7HJ',
#      'United Kingdom']},
#    'phone': '+442074361929',
#    'display_phone': '+44 20 7436 1929',
#    'distance': 993.9618175190195},
#   {'id': 'IQpsCaCYOAZkKAJRcA-24Q',
#    'alias': 'jusu-brothers-london',
#    'name': 'Jusu Brothers',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qkifmhPA8so5lXo5-rRXtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jusu-brothers-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5147605, 'longitude': -0.1960694},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '147-149 Westbourne Grove',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2RS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['147-149 Westbourne Grove',
#      'London W11 2RS',
#      'United Kingdom']},
#    'phone': '+442038028805',
#    'display_phone': '+44 20 3802 8805',
#    'distance': 4173.611679665257},
#   {'id': '8qP9Dj8FTOqPPbIzy5dNwg',
#    'alias': 'juicebaby-chelsea',
#    'name': 'Juicebaby',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RQHuWuLl845v01iFyyOQqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/juicebaby-chelsea?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'organic_stores', 'title': 'Organic Stores'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4835167, 'longitude': -0.1771433},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "398 King's Road",
#     'address2': '',
#     'address3': '',
#     'city': 'Chelsea',
#     'zip_code': 'SW10 0LJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["398 King's Road",
#      'Chelsea SW10 0LJ',
#      'United Kingdom']},
#    'phone': '+442073512230',
#    'display_phone': '+44 20 7351 2230',
#    'distance': 4317.671779993667},
#   {'id': 'kgBdeOR-wnA8XOjI0PeEOg',
#    'alias': 'portobello-juice-cafe-london',
#    'name': 'Portobello Juice Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T_fWSI6QmbjGaljlDUYNDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/portobello-juice-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5191147, 'longitude': -0.2077025},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '297 Portobello Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W10 5TD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['297 Portobello Road',
#      'London W10 5TD',
#      'United Kingdom']},
#    'phone': '+442089606291',
#    'display_phone': '+44 20 8960 6291',
#    'distance': 5009.004229847621},
#   {'id': 'M5kXvoIDt3JoZAi9SyTeMw',
#    'alias': 'the-covent-garden-kafeneo-covent-garden',
#    'name': 'The Covent Garden Kafeneo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RjlqoNe9rVvBLN9_FqZ5PA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-covent-garden-kafeneo-covent-garden?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5114772785777,
#     'longitude': -0.121451282246565},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '12-14 Tavistock Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Covent Garden',
#     'zip_code': 'WC2E 7PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12-14 Tavistock Street',
#      'Covent Garden WC2E 7PH',
#      'United Kingdom']},
#    'phone': '+442072408577',
#    'display_phone': '+44 20 7240 8577',
#    'distance': 1015.0401694395738},
#   {'id': '6kz1DOu387HO_4wKORt3Wg',
#    'alias': 'hawraman-cafe-bar-london',
#    'name': 'Hawraman Cafe Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2zdZUtRHTt5wyF9EMGWZ7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hawraman-cafe-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.542848, 'longitude': -0.1483066},
#    'transactions': [],
#    'location': {'address1': '38 Chalk Farm Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['38 Chalk Farm Road',
#      'London NW1 8AJ',
#      'United Kingdom']},
#    'phone': '+447737892812',
#    'display_phone': '+44 7737 892812',
#    'distance': 3444.868877567905},
#   {'id': 'A_djHANzLlq71YE-h1qOrA',
#    'alias': 'fresh-and-organic-london-3',
#    'name': 'Fresh And Organic',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/b2yAYjqSh91WJrda_n0Teg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fresh-and-organic-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.513168, 'longitude': -0.136565},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '51 Lexington Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9AR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Lexington Street',
#      'London W1F 9AR',
#      'United Kingdom']},
#    'phone': '+442074949539',
#    'display_phone': '+44 20 7494 9539',
#    'distance': 61.370676582394765},
#   {'id': '4Ojk03MO2H1sn6SQ3E9h3w',
#    'alias': 'boost-juice-bar-london',
#    'name': 'Boost Juice Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7rf_uDnTwEtYyGKNPenDfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boost-juice-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.516496257216,
#     'longitude': -0.130897749656666},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '12 Oxford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 1AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Oxford Street',
#      'London W1D 1AP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 536.8420865652386},
#   {'id': 'rf9i6QF9mGBHYSvP5ET53w',
#    'alias': 'first-aid-box-london',
#    'name': 'First Aid Box',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EPnfqHGbvtu1VJWj2IDFdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/first-aid-box-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4528725666396,
#     'longitude': -0.103489844881437},
#    'transactions': [],
#    'location': {'address1': '119 Dulwich Road',
#     'address2': 'Herne Hill',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE24 0NG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['119 Dulwich Road',
#      'Herne Hill',
#      'London SE24 0NG',
#      'United Kingdom']},
#    'phone': '+442072746409',
#    'display_phone': '+44 20 7274 6409',
#    'distance': 7036.3812687423515},
#   {'id': '6TSkD_hMhNKPSxVijLhJtA',
#    'alias': 'ginger-and-mint-london',
#    'name': 'Ginger And Mint',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3URvDyDSeBH0X5v8c4CYyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginger-and-mint-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.580689, 'longitude': -0.125},
#    'transactions': [],
#    'location': {'address1': '11 Park Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N8 8TE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Park Road', 'London N8 8TE', 'United Kingdom']},
#    'phone': '+442083419181',
#    'display_phone': '+44 20 8341 9181',
#    'distance': 7573.697734319213},
#   {'id': 'Ymkqc69L0BxS49yrnTn1WQ',
#    'alias': 'pulp-london-2',
#    'name': 'Pulp',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/w8KFmMud7V6luPepNy7tEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pulp-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4297979672891,
#     'longitude': -0.166632256243608},
#    'transactions': [],
#    'location': {'address1': '2 Gatton Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW17 0SQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Gatton Road', 'London SW17 0SQ', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9474.666252240599},
#   {'id': 'WXMROUBNvri-oZr1Z8lKzg',
#    'alias': 'roots-juicery-london',
#    'name': 'Roots Juicery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jambD8cm6LJfo5QMC4uaxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roots-juicery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.519009, 'longitude': -0.136283},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Charlotte Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 1SA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Charlotte Place',
#      'London W1T 1SA',
#      'United Kingdom']},
#    'phone': '+442073247701',
#    'display_phone': '+44 20 7324 7701',
#    'distance': 694.7851093903619},
#   {'id': 'grfcexcNWkru_-WsFs87xA',
#    'alias': 'joe-and-the-juice-london-2',
#    'name': 'Joe and the Juice',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MuH5xD0G8AVRK8mkT3_OQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joe-and-the-juice-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.512982513308,
#     'longitude': -0.13193694019836},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '46 Dean Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 4QD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['46 Dean Street', 'London W1D 4QD', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 278.5888657520913},
#   {'id': 'Jvf6CJMRvhAkZgf0w4UBHA',
#    'alias': 'fresco-london-3',
#    'name': 'Fresco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PrEfIghjMn1fnPOwvNqrHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fresco-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'lebanese', 'title': 'Lebanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515524, 'longitude': -0.189489},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '25 Westbourne Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 4UA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['25 Westbourne Grove',
#      'London W2 4UA',
#      'United Kingdom']},
#    'phone': '+442072212355',
#    'display_phone': '+44 20 7221 2355',
#    'distance': 3716.478002291112},
#   {'id': 'xgLuPE9Y1Y9WFp_PYSgZFg',
#    'alias': 'whole-foods-market-london-8',
#    'name': 'Whole Foods Market',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/olwsTvXW3OKtWhgoRYk9Zg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/whole-foods-market-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 81,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'organic_stores', 'title': 'Organic Stores'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5105532925813,
#     'longitude': -0.136078061208309},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '20 Glasshouse Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5AR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Glasshouse Street',
#      'London W1B 5AR',
#      'United Kingdom']},
#    'phone': '+442074063100',
#    'display_phone': '+44 20 7406 3100',
#    'distance': 253.91293920898744},
#   {'id': '7NeXiFYsArbjI4UBfgAqiw',
#    'alias': 'get-juiced-london',
#    'name': 'Get Juiced',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HwupjXfhGDkSaAra7TOSLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/get-juiced-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'raw_food', 'title': 'Live/Raw Food'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.429158, 'longitude': -0.166095},
#    'transactions': [],
#    'location': {'address1': 'Tooting Market',
#     'address2': '21-23 Tooting High street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW17 0SN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Tooting Market',
#      '21-23 Tooting High street',
#      'London SW17 0SN',
#      'United Kingdom']},
#    'phone': '+447840035299',
#    'display_phone': '+44 7840 035299',
#    'distance': 9567.496691959452},
#   {'id': 'yHiG4O9qLPHAIUmHoez0zg',
#    'alias': 'grounds-of-arabica-london',
#    'name': 'Grounds of Arabica',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Ir8c-78f8NIeBdTd-kdwyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grounds-of-arabica-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51199, 'longitude': -0.217984},
#    'transactions': [],
#    'location': {'address1': 'Ground Floor',
#     'address2': '11 Bramley Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W10 6SZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Ground Floor',
#      '11 Bramley Road',
#      'London W10 6SZ',
#      'United Kingdom']},
#    'phone': '+442072433737',
#    'display_phone': '+44 20 7243 3737',
#    'distance': 5677.255126875702},
#   {'id': 'obteyiK5NvBgHTHDrk2zLg',
#    'alias': 'fruzi-london',
#    'name': 'Fruzi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wOxaP2SbIIdC5qMKr9Z8HQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fruzi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5143654, 'longitude': -0.1482658},
#    'transactions': [],
#    'location': {'address1': '355-361 Oxford Street',
#     'address2': 'Units 1 & 2 Sedley Place',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1C 2HE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['355-361 Oxford Street',
#      'Units 1 & 2 Sedley Place',
#      'London W1C 2HE',
#      'United Kingdom']},
#    'phone': '+442074918088',
#    'display_phone': '+44 20 7491 8088',
#    'distance': 855.8135049035685},
#   {'id': '0Vc-LIGv5Y2thnwHdoVxYw',
#    'alias': 'the-oxford-street-roof-garden-john-lewis-london',
#    'name': 'The Oxford Street Roof Garden - John Lewis',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/g4pGxVEt5pYBI-JYuwXvjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-oxford-street-roof-garden-john-lewis-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5154006, 'longitude': -0.1452248},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'John Lewis',
#     'address2': '300 Oxford Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1C 1DX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['John Lewis',
#      '300 Oxford Street',
#      'London W1C 1DX',
#      'United Kingdom']},
#    'phone': '+442076297711',
#    'display_phone': '+44 20 7629 7711',
#    'distance': 701.9628933639672},
#   {'id': 'iEowEE8-LunOIppntKHl3w',
#    'alias': 'total-chi-yoga-bar-london',
#    'name': 'Total Chi Yoga Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/P9i9kljWEDbKeFYXnqXZzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/total-chi-yoga-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'pilates', 'title': 'Pilates'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5238878, 'longitude': -0.1585462},
#    'transactions': [],
#    'location': {'address1': '243 Baker Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 6XE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['243 Baker Street',
#      'London NW1 6XE',
#      'United Kingdom']},
#    'phone': '+442074864676',
#    'display_phone': '+44 20 7486 4676',
#    'distance': 1989.138661193682},
#   {'id': 'HcMn8wprOcu9eLfsRy3r2w',
#    'alias': 'joe-and-the-juice-london-8',
#    'name': 'Joe & The Juice',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4ofI4dwQukV6brijsEe-MQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joe-and-the-juice-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5561957990553,
#     'longitude': -0.17785975377957},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '42 Hampstead High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 1QE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 Hampstead High Street',
#      'London NW3 1QE',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5625.570109283806},
#   {'id': 'izDKJQTY1TuSrnt4l7reqA',
#    'alias': 'granger-and-co-london-5',
#    'name': 'Granger & Co',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sngypUSJ_Z7F4DL1VuRftA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/granger-and-co-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4937584582247,
#     'longitude': -0.158635840925337},
#    'transactions': [],
#    'location': {'address1': '237 Pavilion Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1X 0BP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['237 Pavilion Road',
#      'London SW1X 0BP',
#      'United Kingdom']},
#    'phone': '+442038481060',
#    'display_phone': '+44 20 3848 1060',
#    'distance': 2638.954622882282},
#   {'id': 'g9N2jOCNG7uJQ66M8i-YZw',
#    'alias': 'crussh-london',
#    'name': 'Crussh',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BTgGDxPh2P2XRTq53jv1KA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crussh-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5132966, 'longitude': -0.0850851},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '48 Cornhill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3V 3PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['48 Cornhill', 'London EC3V 3PD', 'United Kingdom']},
#    'phone': '+442076262175',
#    'display_phone': '+44 20 7626 2175',
#    'distance': 3508.2629461851147},
#   {'id': 'q98qW2-8whT72cYOb_CMPg',
#    'alias': 'crussh-juice-bar-london-4',
#    'name': 'Crussh Juice Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HbLlKXfpdD2O0DMDymkFrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crussh-juice-bar-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516420219142,
#     'longitude': -0.139360146782568},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '47 Eastcastle Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 8DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Eastcastle Street',
#      'London W1W 8DY',
#      'United Kingdom']},
#    'phone': '+442076369834',
#    'display_phone': '+44 20 7636 9834',
#    'distance': 463.0084515226374},
#   {'id': 'Yoxx_-Stq41BqxAHLc1VNA',
#    'alias': 'crussh-london-23',
#    'name': 'Crussh',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/v5uyfoN0D2WJdQLrtqsWHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crussh-london-23?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.504964, 'longitude': -0.019462},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Canada Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E14 5AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Canada Square',
#      'London E14 5AB',
#      'United Kingdom']},
#    'phone': '+442075196427',
#    'display_phone': '+44 20 7519 6427',
#    'distance': 8107.0715841582805},
#   {'id': '_eLGYgZ5aqLeyADvCRUT0w',
#    'alias': 'the-detox-kitchen-london-3',
#    'name': 'The Detox Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YgwPSjd7-HVtPsz6NBtiNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-detox-kitchen-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'healthmarkets', 'title': 'Health Markets'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5186046, 'longitude': -0.1380871},
#    'transactions': [],
#    'location': {'address1': '10 Mortimer Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1T 3JJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Mortimer Street',
#      'London W1T 3JJ',
#      'United Kingdom']},
#    'phone': '+442074986417',
#    'display_phone': '+44 20 7498 6417',
#    'distance': 658.445753130219},
#   {'id': 'FzMLjXcYXBs_msvKdREYRw',
#    'alias': 'ddk-cafe-london',
#    'name': 'DDK Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vH6VuBS1iyRgPOtDXh74Ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ddk-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4922261, 'longitude': -0.1403977},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '39 Warcick Way',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1QS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39 Warcick Way',
#      'London SW1V 1QS',
#      'United Kingdom']},
#    'phone': '+442072336178',
#    'display_phone': '+44 20 7233 6178',
#    'distance': 2317.4799884749436},
#   {'id': '2Ffr8Fs_OlGQqxT7TN_nJg',
#    'alias': 'lundenwic-london-2',
#    'name': 'Lundenwic',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UxlKEsPg6r_m9lpmyS95nQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lundenwic-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5129, 'longitude': -0.118617},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '45 Aldwych',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 4DW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Aldwych', 'London WC2B 4DW', 'United Kingdom']},
#    'phone': '+447921911068',
#    'display_phone': '+44 7921 911068',
#    'distance': 1199.8817944620134},
#   {'id': 'cv6bIom98ReOtrkJeW5R7g',
#    'alias': 'joe-and-the-juice-london-5',
#    'name': 'Joe & The Juice',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yAx3YCOLOdq36MMTce4hNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joe-and-the-juice-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5129388, 'longitude': -0.1378315},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '65 - 67 Broadwick Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1F 9QY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['65 - 67 Broadwick Street',
#      'London W1F 9QY',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 130.30628327176672},
#   {'id': 'h2GatYGNX-K2MAofMETM0A',
#    'alias': 'as-nature-intended-london-6',
#    'name': 'As Nature Intended',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Reb3ST_fL5W1LTEmoXM6eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/as-nature-intended-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'organic_stores', 'title': 'Organic Stores'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5211397787296,
#     'longitude': -0.0752202048897743},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'The Exchange Building',
#     'address2': '132 Commercial Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6AZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Exchange Building',
#      '132 Commercial Street',
#      'London E1 6AZ',
#      'United Kingdom']},
#    'phone': '+442072479596',
#    'display_phone': '+44 20 7247 9596',
#    'distance': 4302.823144286677},
#   {'id': 'DnBY9gukSdy42EoJtBhdaQ',
#    'alias': 'tibits-london-3',
#    'name': 'Tibits',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zP-qObQgPFOzh6GlckF9Yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tibits-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 159,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.511302947998,
#     'longitude': -0.139624997973442},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '12-14 Heddon Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 4DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12-14 Heddon Street',
#      'London W1B 4DA',
#      'United Kingdom']},
#    'phone': '+442077456146',
#    'display_phone': '+44 20 7745 6146',
#    'distance': 276.51513726465686},
#   {'id': 'pD0FFxeSxvd997eVE81I0g',
#    'alias': 'sourced-market-london-2',
#    'name': 'Sourced Market',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zPTwY9NsUZw6ERkLbS4Jhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sourced-market-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.532036, 'longitude': -0.126343},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'St Pancras International',
#     'address2': 'Pancras Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C 4QL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['St Pancras International',
#      'Pancras Road',
#      'London N1C 4QL',
#      'United Kingdom']},
#    'phone': '+442078339352',
#    'display_phone': '+44 20 7833 9352',
#    'distance': 2236.1846304921187},
#   {'id': 'jAdR92T0NTurS1hUSmeV6Q',
#    'alias': 'joe-and-the-juice-london-22',
#    'name': 'Joe & The Juice',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tekfZd2hLoWLKsHgl9E4-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joe-and-the-juice-london-22?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5056786003468,
#     'longitude': -0.0991015881299973},
#    'transactions': [],
#    'location': {'address1': '100 Southwark Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 0SU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['100 Southwark Street',
#      'London SE1 0SU',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2671.815822183177},
#   {'id': '7HL9K-MXYZiYXWFcHO5gsw',
#    'alias': 'the-parlour-london-12',
#    'name': 'The Parlour',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Y0EZ1TEgaRAj6TJM0jawgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-parlour-london-12?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4521117, 'longitude': -0.101192},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '19 Norwood Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE24 9AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 Norwood Road',
#      'London SE24 9AA',
#      'United Kingdom']},
#    'phone': '+442086710759',
#    'display_phone': '+44 20 8671 0759',
#    'distance': 7168.46471743197},
#   {'id': 'PC5MyWEwUApF1sP-Uy76kQ',
#    'alias': 'crussh-juice-bars-london',
#    'name': 'Crussh Juice Bars',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SJOETGM-foc-HiBPWFaFRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crussh-juice-bars-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'catering', 'title': 'Caterers'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.52416, 'longitude': -0.123186},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Brunswick Centre',
#     'address2': 'Brunswick Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 1AW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Brunswick Centre',
#      'Brunswick Square',
#      'London WC1N 1AW',
#      'United Kingdom']},
#    'phone': '+442078376848',
#    'display_phone': '+44 20 7837 6848',
#    'distance': 1536.975588840387},
#   {'id': '1W0Py6So69KJtTR7_ScZ9A',
#    'alias': 'crussh-millbank-london',
#    'name': 'Crussh Millbank',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VVUjjmTY7ehn7UHDRWIiHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crussh-millbank-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.496826, 'longitude': -0.126196},
#    'transactions': [],
#    'location': {'address1': '4 Millbank',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1P 3JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Millbank', 'London SW1P 3JA', 'United Kingdom']},
#    'phone': '+442072332099',
#    'display_phone': '+44 20 7233 2099',
#    'distance': 1926.712550273194},
#   {'id': '6o2qrggYvfu91PhS4J-6Gg',
#    'alias': 'pure-london-16',
#    'name': 'Pure',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oTuYfIjNbh8jtkKyXKhkVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pure-london-16?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5124016305796,
#     'longitude': -0.137629508972148},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '39 Beak Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9SA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39 Beak Street', 'London W1F 9SA', 'United Kingdom']},
#    'phone': '+442072873708',
#    'display_phone': '+44 20 7287 3708',
#    'distance': 125.46889969120163},
#   {'id': '401tx6knTNiFxEbYOBIuSQ',
#    'alias': 'whole-foods-market-london-2',
#    'name': 'Whole Foods Market',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/alSC0CeCzHvgZu9LDj2U6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/whole-foods-market-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 215,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5016271, 'longitude': -0.1907953},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'The Barkers Building',
#     'address2': '63-97 Kensington High Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 5SE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Barkers Building',
#      '63-97 Kensington High Street',
#      'London W8 5SE',
#      'United Kingdom']},
#    'phone': '+442073684500',
#    'display_phone': '+44 20 7368 4500',
#    'distance': 3994.8009885547244},
#   {'id': 'hjdAcxsdt4naowzld3ZkZg',
#    'alias': 'prezzemolo-and-vitale-london',
#    'name': 'Prezzemolo & Vitale',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prezzemolo-and-vitale-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'markets', 'title': 'Fruits & Veggies'},
#     {'alias': 'meats', 'title': 'Meat Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4980681, 'longitude': -0.0984512},
#    'transactions': [],
#    'location': {'address1': '44 Newington Causeway',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 6DR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['44 Newington Causeway',
#      'London SE1 6DR',
#      'United Kingdom']},
#    'phone': '+447778067221',
#    'display_phone': '+44 7778 067221',
#    'distance': 3067.324904941056},
#   {'id': 'oLzNsjq9ohcNqEpUHP-6pQ',
#    'alias': 'the-hive-london-8',
#    'name': 'The Hive',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Rg5AOZV-_XlZGLlcnJAvlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hive-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5342284755869,
#     'longitude': -0.0571906441803094},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '286-290 Cambridge Heath Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 9DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['286-290 Cambridge Heath Road',
#      'London E2 9DA',
#      'United Kingdom']},
#    'phone': '+442089819245',
#    'display_phone': '+44 20 8981 9245',
#    'distance': 5945.916491211892},
#   {'id': 'ZWOPXRS0tzo5Hdy0AjAZxg',
#    'alias': 'boost-juice-london',
#    'name': 'Boost Juice',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rUlC7CcNlj8moBvL7Xar2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boost-juice-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'milkshakebars', 'title': 'Milkshake Bars'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5430876184499,
#     'longitude': -0.00719894538541155},
#    'transactions': [],
#    'location': {'address1': '232a The Arcade',
#     'address2': 'Westfield Stratford City',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E20',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['232a The Arcade',
#      'Westfield Stratford City',
#      'London E20',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9521.167131556585}],
#  'total': 162,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Restaurant": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#             Restaurant                    Type Price Rating  \
# 0      JOE & THE JUICE  Juice Bars & Smoothies    ££      4
# 1                PRESS  Juice Bars & Smoothies
# 2  Pure - Made for You  Juice Bars & Smoothies    ££      4
# 3            Viva Acai  Juice Bars & Smoothies    ££      4
# 4  CycleLab & JuiceBar                   Cafes     £      5
#
#                      Address        Lat       Lng  \
# 0          281 Regent Street  51.516129 -0.142487
# 1            6 Denman Street  51.510902 -0.134611
# 2           47 Goodge Street  51.519171 -0.136007
# 3  Unit 15 Gloucester Arcade  51.494509 -0.183555
# 4    16B-18A Pitfield Street  51.527144 -0.083562
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/joe-and-the-juice-lon...  LtKwDYJMa1Ud_6MrsIOKvQ
# 1
# 2  https://www.yelp.com/biz/pure-made-for-you-lon...  onnTNyrh_MeFIz34ywRSag
# 3  https://www.yelp.com/biz/viva-acai-london?adju...  mf3jzlhoDSAsm4xs2lxggg
# 4  https://www.yelp.com/biz/cyclelab-and-juicebar...  6G6lvHO8c12MGFcdDbRhkA

# %%
#2nd set of 50 records 51-100 
lndr_params2 = {"term":term,"location":"London","limit":50,"offset":51}
lndr_response2 = requests.get(search_api_url, headers=headers, params=lndr_params2)
lndr2 = lndr_response2.json()
display(lndr2)
#print(lndr_response2.url)
#print(lndr_response2.status_code)
# Out:
# {'businesses': [{'id': 'U-Sz3hVjbZ8eaNeKGpZU_A',
#    'alias': 'borough-market-london-3',
#    'name': 'Borough Market',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EjVltsQ_qhUKdgdTMndkIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/borough-market-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1657,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5051427191678,
#     'longitude': -0.0909365332063361},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8 Southwark Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 1TL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Southwark Street',
#      'London SE1 1TL',
#      'United Kingdom']},
#    'phone': '+442030262283',
#    'display_phone': '+44 20 3026 2283',
#    'distance': 3230.9293288880117},
#   {'id': '6AmObM5tVu3Bhb-Y5HCMgA',
#    'alias': 'lumiere-london',
#    'name': 'Lumiere',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8P-1toe3DnnAcGvQMN2LEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lumiere-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.554275, 'longitude': -0.044888},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '88 Chatsworth Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E5 0LS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['88 Chatsworth Road',
#      'London E5 0LS',
#      'United Kingdom']},
#    'phone': '+442071830110',
#    'display_phone': '+44 20 7183 0110',
#    'distance': 7803.683976310543},
#   {'id': 'p9EYdshkkqAWpK90XkQkiQ',
#    'alias': 'chegworth-valley-london',
#    'name': 'Chegworth Valley',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZoVX1TVd5UOuwjI51GmYYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chegworth-valley-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'organic_stores', 'title': 'Organic Stores'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.50571, 'longitude': -0.09152},
#    'transactions': [],
#    'location': {'address1': 'Borough Market',
#     'address2': 'Stoney Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1TL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Borough Market',
#      'Stoney Street',
#      'London SE1 1TL',
#      'United Kingdom']},
#    'phone': '+441622859272',
#    'display_phone': '+44 1622 859272',
#    'distance': 3209.2148534642415},
#   {'id': 'UAq6LPa04ActoBFOj22xlw',
#    'alias': 'the-hive-of-vyner-st-london-2',
#    'name': 'The Hive of Vyner St',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ERi2JeUxSVO0svpEM4rCaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hive-of-vyner-st-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5341704314523,
#     'longitude': -0.0572431679470379},
#    'transactions': [],
#    'location': {'address1': '286-290 Cambridge Heath Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E2 9DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['286-290 Cambridge Heath Road',
#      'London E2 9DA',
#      'United Kingdom']},
#    'phone': '+442089819245',
#    'display_phone': '+44 20 8981 9245',
#    'distance': 5940.008857010381},
#   {'id': 'NEsstws8No4eisAV40_naA',
#    'alias': '5-senses-juice-and-coffee-bar-london',
#    'name': '5 Senses Juice & Coffee Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/feaGpBmQhpCi1hz7dxtYlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/5-senses-juice-and-coffee-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5311400107262,
#     'longitude': -0.230429917573929},
#    'transactions': [],
#    'location': {'address1': '1028 Harrow Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW10 5NN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1028 Harrow Road',
#      'London NW10 5NN',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6845.944294611863},
#   {'id': 'Vh8hSFaPIQAZvv41EFxj1Q',
#    'alias': 'yogo-kingston-upon-thames',
#    'name': 'Yogo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_8jgbiXv3YpgjVRs4VfX6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yogo-kingston-upon-thames?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.409319, 'longitude': -0.30582},
#    'transactions': [],
#    'location': {'address1': '8 Apple Market',
#     'address2': '',
#     'address3': '',
#     'city': 'Kingston Upon Thames',
#     'zip_code': 'KT1 1JE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Apple Market',
#      'Kingston Upon Thames KT1 1JE',
#      'United Kingdom']},
#    'phone': '+442085490388',
#    'display_phone': '+44 20 8549 0388',
#    'distance': 16458.36492156267},
#   {'id': '0Po5pG8_WumGCbsujcZ_BA',
#    'alias': 'the-power-yoga-company-london',
#    'name': 'The Power Yoga Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IzuCHSCf_UvcmQMgLic5cA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-power-yoga-company-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4742152, 'longitude': -0.2044122},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'The Glass House',
#     'address2': '11-12 Lettice Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 4EH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Glass House',
#      '11-12 Lettice Street',
#      'London SW6 4EH',
#      'United Kingdom']},
#    'phone': '+442077364429',
#    'display_phone': '+44 20 7736 4429',
#    'distance': 6395.481812215517},
#   {'id': 'ZC-AWV99EUKpWuAE18sOaw',
#    'alias': 'wild-bunch-juicery-chiswick',
#    'name': 'Wild Bunch Juicery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8orDRWzSJ9VPCKOocOauOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wild-bunch-juicery-chiswick?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.492836, 'longitude': -0.265502},
#    'transactions': [],
#    'location': {'address1': '402 Chiswick High Road',
#     'address2': '',
#     'address3': None,
#     'city': 'Chiswick',
#     'zip_code': 'W4 5TF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['402 Chiswick High Road',
#      'Chiswick W4 5TF',
#      'United Kingdom']},
#    'phone': '+442080619109',
#    'display_phone': '+44 20 8061 9109',
#    'distance': 9244.038425197272},
#   {'id': 'CLMx6Q707WazaIE2wXmxiQ',
#    'alias': 'columbia-juice-company-london',
#    'name': 'Columbia Juice Company',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/s7kNB-CnOuqPixefspmeOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/columbia-juice-company-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5295128, 'longitude': -0.0688858},
#    'transactions': [],
#    'location': {'address1': '156 Columbia Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7RG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['156 Columbia Road',
#      'London E2 7RG',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5005.042540617458},
#   {'id': 'ZTSM33QFv3pwxtSJp8Y02g',
#    'alias': 'farmacy-london',
#    'name': 'Farmacy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/38AZr06tSZ3IU2zDxBb7zQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/farmacy-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 67,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.515446, 'longitude': -0.1926381},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '74 Westbourne Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 5SH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['74 Westbourne Grove',
#      'London W2 5SH',
#      'United Kingdom']},
#    'phone': '+442072210705',
#    'display_phone': '+44 20 7221 0705',
#    'distance': 3938.117967873019},
#   {'id': 'VYOFivYzIl3brZvd4VvV_Q',
#    'alias': 'maple-and-fitz-london',
#    'name': 'Maple & Fitz',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/D8Xp6bCNmh5KZLp_aeMKRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maple-and-fitz-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.518613, 'longitude': -0.137395},
#    'transactions': [],
#    'location': {'address1': '36A Berners Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 3LY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['36A Berners Street',
#      'London W1T 3LY',
#      'United Kingdom']},
#    'phone': '+442076313056',
#    'display_phone': '+44 20 7631 3056',
#    'distance': 648.9420298004893},
#   {'id': 'G0T2DsJeB14fryOJnwd-Ew',
#    'alias': 'zer-cafe-and-juice-bar-london',
#    'name': 'Zer Cafe and Juice Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ly1GmNW1ikxKXXLRPNNnpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zer-cafe-and-juice-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5707343, 'longitude': -0.0907975},
#    'transactions': [],
#    'location': {'address1': 'Unit A Residence Tower',
#     'address2': 'Goodchild Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N4 2LY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit A Residence Tower',
#      'Goodchild Road',
#      'London N4 2LY',
#      'United Kingdom']},
#    'phone': '+442088095270',
#    'display_phone': '+44 20 8809 5270',
#    'distance': 7155.52817341348},
#   {'id': 'n01ZFkgcdoXIdJ8p9OOBSw',
#    'alias': 'boost-juice-bar-london-2',
#    'name': 'Boost juice Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4S4aFKRmox9bSAIMAQh9Yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boost-juice-bar-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5005750773121,
#     'longitude': -0.192100749861213},
#    'transactions': [],
#    'location': {'address1': 'Unit 6 Kensington Arcade',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W8 5SF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 6 Kensington Arcade',
#      'London W8 5SF',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4118.014543419928},
#   {'id': 'LHiRDTP2peablIMH8WgZYw',
#    'alias': 'joe-and-the-juice-london-17',
#    'name': 'Joe & the Juice',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/z3MhpdWi1GM2GT0-CU8bNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joe-and-the-juice-london-17?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.425360805835,
#     'longitude': -0.217007137835026},
#    'transactions': [],
#    'location': {'address1': '78 High Street',
#     'address2': 'Wimbledon',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW19 5EG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['78 High Street',
#      'Wimbledon',
#      'London SW19 5EG',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 11230.700895144979},
#   {'id': 'vGRmk3sjnCYwRKdqirjj7g',
#    'alias': 'tossed-london',
#    'name': 'Tossed',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_ZcHaJWd6zN_qzHMS7_ldw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tossed-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'healthmarkets', 'title': 'Health Markets'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.51039, 'longitude': -0.1270749},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '100 St Martins Lane',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4AZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['100 St Martins Lane',
#      'Covent Garden',
#      'London WC2N 4AZ',
#      'United Kingdom']},
#    'phone': '+442078363842',
#    'display_phone': '+44 20 7836 3842',
#    'distance': 672.1265284089293},
#   {'id': 'm2x7O6w0HdRGBYc-Y12rXg',
#    'alias': 'kunduz-cafe-and-sandwich-bar-london',
#    'name': 'Kunduz Cafe & Sandwich Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2K1ZKXn7Ge56zrMh8v86OQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kunduz-cafe-and-sandwich-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5108106, 'longitude': -0.1872917},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '23-25 Queensway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 4QP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23-25 Queensway', 'London W2 4QP', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3567.8692096773493},
#   {'id': 'P5h48SHgNAiqCq64QMwzMA',
#    'alias': 'yogland-fit-frozen-dessert-london',
#    'name': 'Yogland Fit Frozen Dessert',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xfVEqXNxqmw20B7ztOIX3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yogland-fit-frozen-dessert-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5153934, 'longitude': -0.1919184},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '58 Westbourne Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 5SH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['58 Westbourne Grove',
#      'London W2 5SH',
#      'United Kingdom']},
#    'phone': '+442072433119',
#    'display_phone': '+44 20 7243 3119',
#    'distance': 3882.983297919659},
#   {'id': 'upCvvPPcD-pqG_KjyXKz8Q',
#    'alias': 'veggie-pret-london-2',
#    'name': 'Veggie Pret',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V5rY5TPi7Zkd632t426jvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/veggie-pret-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5133272140713,
#     'longitude': -0.13637449086557},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '35 Broadwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0DH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35 Broadwick Street',
#      'London W1F 0DH',
#      'United Kingdom']},
#    'phone': '+442079325274',
#    'display_phone': '+44 20 7932 5274',
#    'distance': 61.87601765848984},
#   {'id': 'qHSAKNjfi_0OqlGkgw56HA',
#    'alias': 'ripe-juice-bar-london',
#    'name': 'Ripe Juice Bar',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ripe-juice-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5103874, 'longitude': -0.1385003},
#    'transactions': [],
#    'location': {'address1': '117 Regent Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 8QR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['117 Regent Street',
#      'London W1W 8QR',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 314.9134178583349},
#   {'id': 'eJ6G7gSWv7JUtMs4KDWdQQ',
#    'alias': 'bubbleology-london',
#    'name': 'Bubbleology',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mqnagEqh2J85FwQDBo2gag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bubbleology-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 87,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.511962890625,
#     'longitude': -0.133645996451378},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '49 Rupert Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 7PF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49 Rupert Street',
#      'London W1D 7PF',
#      'United Kingdom']},
#    'phone': '+442074944231',
#    'display_phone': '+44 20 7494 4231',
#    'distance': 190.4654722601182},
#   {'id': 'JnFwWjHzQAD72XBtudW9gw',
#    'alias': 'la-piazzetta-london',
#    'name': 'La Piazzetta',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/f7EWVuF8krAAkrqrSp2nKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-piazzetta-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5124246984168, 'longitude': -0.1263641},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "13 Neal's Yard",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["13 Neal's Yard",
#      'London WC2H 9DP',
#      'United Kingdom']},
#    'phone': '+442072401168',
#    'display_phone': '+44 20 7240 1168',
#    'distance': 665.3280478367622},
#   {'id': 'x7Z52Z5asB91V2l2sBLWWg',
#    'alias': 'megans-kings-road-restaurant-chelsea-london',
#    'name': "Megan's Kings Road Restaurant, Chelsea",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PTI0UgpFFo77c9Q1REJ2Pw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/megans-kings-road-restaurant-chelsea-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.47881, 'longitude': -0.18801},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '571 Kings Road',
#     'address2': 'Chelsea',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 2EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['571 Kings Road',
#      'Chelsea',
#      'London SW6 2EB',
#      'United Kingdom']},
#    'phone': '+442034680220',
#    'display_phone': '+44 20 3468 0220',
#    'distance': 5224.329399253999},
#   {'id': 'f2ubaZPfDqxtqw64k21X8A',
#    'alias': 'alara-health-store-london',
#    'name': 'Alara Health Store',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XTlkSKBZGd7fD4FqiOcHQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alara-health-store-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.525397, 'longitude': -0.125182},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '58 Marchmont Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 1AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['58 Marchmont Street',
#      'London WC1N 1AB',
#      'United Kingdom']},
#    'phone': '+442078371172',
#    'display_phone': '+44 20 7837 1172',
#    'distance': 1569.5260766000993},
#   {'id': 'ZsqXSnhoX5GvsL-hNqXhIg',
#    'alias': 'joe-and-the-juice-london-21',
#    'name': 'Joe & The Juice',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joe-and-the-juice-london-21?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.5079158600865,
#     'longitude': -0.142699899140098},
#    'transactions': [],
#    'location': {'address1': '8 Berkeley Street',
#     'address2': '',
#     'address3': 'Mayfair',
#     'city': 'London',
#     'zip_code': 'W1J 8DN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Berkeley Street',
#      'Mayfair',
#      'London W1J 8DN',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 719.0849508069891},
#   {'id': 'HWkwznRK0BOcK3uvrxassA',
#    'alias': 'timmy-green-london',
#    'name': 'Timmy Green',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IwoyW9aGT7nx3tbkXTbVNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/timmy-green-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'australian', 'title': 'Australian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4980343768138,
#     'longitude': -0.143855731693976},
#    'transactions': [],
#    'location': {'address1': 'Sir Simon Milton Square',
#     'address2': '11 Bressenden Place',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1E 5DD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Sir Simon Milton Square',
#      '11 Bressenden Place',
#      'London SW1E 5DD',
#      'United Kingdom']},
#    'phone': '+442077233301',
#    'display_phone': '+44 20 7723 3301',
#    'distance': 1734.25763887698},
#   {'id': 'NapOvyJkbqORBUNesnlgBQ',
#    'alias': 'boysnberry-london',
#    'name': "Boys'N'Berry",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YqgNbOVQn-cjq8NP--V93Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boysnberry-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4748900209557,
#     'longitude': -0.206247456371784},
#    'transactions': [],
#    'location': {'address1': '839 Fulham Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW6 5HQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['839 Fulham Road',
#      'London SW6 5HQ',
#      'United Kingdom']},
#    'phone': '+442077312068',
#    'display_phone': '+44 20 7731 2068',
#    'distance': 6440.763340870984},
#   {'id': 'xcUgSY2x12cCdw_1jIiFKQ',
#    'alias': 'espresso-bar-mozzino-london',
#    'name': 'Espresso Bar Mozzino',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NKMlrBZAMGfX1QnksV_MUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/espresso-bar-mozzino-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5129012, 'longitude': -0.1381433},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '74 Broadwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9QZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['74 Broadwick Street',
#      'London W1F 9QZ',
#      'United Kingdom']},
#    'phone': '+447572327979',
#    'display_phone': '+44 7572 327979',
#    'distance': 151.55218875178886},
#   {'id': 'jfV08NFblhc6fYCRSp__kA',
#    'alias': 'planet-organic-london-5',
#    'name': 'Planet Organic',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JO55v7lizgeid48l86SK-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/planet-organic-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'healthmarkets', 'title': 'Health Markets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515559506012,
#     'longitude': -0.19132778535574},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '42 Westbourne Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 5SH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['42 Westbourne Grove',
#      'London W2 5SH',
#      'United Kingdom']},
#    'phone': '+442072217171',
#    'display_phone': '+44 20 7221 7171',
#    'distance': 3843.6287720222863},
#   {'id': 'b4H15rt8Y6tzHoSY7etpng',
#    'alias': 'daylesford-organic-london-2',
#    'name': 'Daylesford Organic',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5Wb6gOLlh5CIFf4F4jEE6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daylesford-organic-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'organic_stores', 'title': 'Organic Stores'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5145345, 'longitude': -0.2004594},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '208-212 Westbourne Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2RH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['208-212 Westbourne Grove',
#      'London W11 2RH',
#      'United Kingdom']},
#    'phone': '+442073138050',
#    'display_phone': '+44 20 7313 8050',
#    'distance': 4467.618870876895},
#   {'id': 'fi6WP9Z5MycLIgIQjsimdw',
#    'alias': 'boost-juice-bars-uk-london',
#    'name': 'Boost Juice Bars UK',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boost-juice-bars-uk-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.507578, 'longitude': -0.22128},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Level 2 Retail Westfield Shopping Centre',
#     'address2': 'Unit 4006 Ariel Way',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W12 7GF',
#     'country': 'GB',
#     'state': 'THR',
#     'display_address': ['Level 2 Retail Westfield Shopping Centre',
#      'Unit 4006 Ariel Way',
#      'London W12 7GF',
#      'United Kingdom']},
#    'phone': '+442088111787',
#    'display_phone': '+44 20 8811 1787',
#    'distance': 5928.642885918171},
#   {'id': 'YyIX0_soRNuTTulJ6r6pPQ',
#    'alias': 'yogu-sensi-london',
#    'name': 'Yogu Sensi',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yogu-sensi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4173698, 'longitude': -0.08075},
#    'transactions': [],
#    'location': {'address1': 'Alma Place',
#     'address2': 'Crystal Palace',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE19',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Alma Place',
#      'Crystal Palace',
#      'London SE19',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 11281.393790995036},
#   {'id': 'AWLFDyjPlViuFcuspx8DKw',
#    'alias': 'bubbleology-london-2',
#    'name': 'Bubbleology',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kAnB38U9SxUq2e7KYLfOmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bubbleology-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.501788, 'longitude': -0.1597774},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Harvey Nichols',
#     'address2': 'Floor 5',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Harvey Nichols',
#      'Floor 5',
#      'London SW1X 7RJ',
#      'United Kingdom']},
#    'phone': '+442072355000',
#    'display_phone': '+44 20 7235 5000',
#    'distance': 2056.0064821496285},
#   {'id': '811USW7rcrzrwRgzI41ppg',
#    'alias': 'chatime-london-2',
#    'name': 'Chatime',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8hplTTw4XPBIubHyUdUnZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chatime-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 39,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5120613, 'longitude': -0.1303394},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '5 Gerrard Street',
#     'address2': 'Chinatown',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 5PD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Gerrard Street',
#      'Chinatown',
#      'London W1D 5PD',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 398.0842147177175},
#   {'id': 'aXUt42VCqy-5bJQclu-vUQ',
#    'alias': 'chatime-london',
#    'name': 'Chatime',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RyA8AkmNE1FBu3wJoARBkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chatime-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5136222839355,
#     'longitude': -0.129988998174667},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '11 Old Compton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 5JF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Old Compton Street',
#      'London W1D 5JF',
#      'United Kingdom']},
#    'phone': '+447866258257',
#    'display_phone': '+44 7866 258257',
#    'distance': 422.07124911615676},
#   {'id': '-dmIlCd_GoRdBPn_4MAxWA',
#    'alias': 'number-one-church-steet-shisha-london',
#    'name': 'Number One Church Steet - Shisha',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9jY0CmuP5AfL539X40WgJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/number-one-church-steet-shisha-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'hookah_bars', 'title': 'Hookah Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5245041, 'longitude': -0.1684123},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW8 8EE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Church Street',
#      'London NW8 8EE',
#      'United Kingdom']},
#    'phone': '+442072583346',
#    'display_phone': '+44 20 7258 3346',
#    'distance': 2596.9739270200103},
#   {'id': 'kfIeFuTel1nIyY6Y2a-fNw',
#    'alias': 'crussh-london-9',
#    'name': 'Crussh',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tXtPXITUe06zEFZQ3aY-uA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crussh-london-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.506321, 'longitude': -0.099883},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit R5',
#     'address2': '14 Sumner St',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9JZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit R5',
#      '14 Sumner St',
#      'London SE1 9JZ',
#      'United Kingdom']},
#    'phone': '+442079283007',
#    'display_phone': '+44 20 7928 3007',
#    'distance': 2601.204580420548},
#   {'id': 'bPKjRqkbdhXmvkSX-C6qbA',
#    'alias': 'juice-bars-and-smoothies-london',
#    'name': 'Juice Bars & Smoothies',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/o8zJfge5wMERxnlfLN0x8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/juice-bars-and-smoothies-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.50022, 'longitude': -0.19487},
#    'transactions': [],
#    'location': {'address1': '165 Kensington High Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W8 6SH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['165 Kensington High Street',
#      'London W8 6SH',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4306.303873963686},
#   {'id': '66uNLSVxF-S9CeGE_olN6Q',
#    'alias': 'daylesford-farmhouse-and-cafe-london',
#    'name': 'Daylesford Farmhouse & Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ikJ2IJK4TRV7X6cpp6-_DQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daylesford-farmhouse-and-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 21,
#    'categories': [{'alias': 'organic_stores', 'title': 'Organic Stores'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5185188799413,
#     'longitude': -0.151910542410043},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6-8 Blandford Street',
#     'address2': 'Marylebone',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 4AU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6-8 Blandford Street',
#      'Marylebone',
#      'London W1U 4AU',
#      'United Kingdom']},
#    'phone': '+442036966500',
#    'display_phone': '+44 20 3696 6500',
#    'distance': 1272.0918945942365},
#   {'id': 'Gnl7Ir2cijVA1iPabV_OMw',
#    'alias': 'bubbleology-london-5',
#    'name': 'Bubbleology',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/s96utMzJl7MEi0XGfwq9aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bubbleology-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.543831, 'longitude': -0.008398},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Westfield Stratford',
#     'address2': 'Kiosk 32',
#     'address3': '1st Floor',
#     'city': 'London',
#     'zip_code': 'E20 1EJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Westfield Stratford',
#      'Kiosk 32',
#      '1st Floor',
#      'London E20 1EJ',
#      'United Kingdom']},
#    'phone': '+442085555072',
#    'display_phone': '+44 20 8555 5072',
#    'distance': 9473.305840053086},
#   {'id': 'Zkuxlo1mzDp3MrkZTBiEJg',
#    'alias': 'blanche-eatery-london-2',
#    'name': 'Blanche Eatery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/trthTvFTjdvHmDz27dIj_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blanche-eatery-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5040545, 'longitude': -0.191941},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '32B Kensington Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W8 4HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['32B Kensington Church Street',
#      'London W8 4HA',
#      'United Kingdom']},
#    'phone': '+442087412888',
#    'display_phone': '+44 20 8741 2888',
#    'distance': 3997.538763030073},
#   {'id': '5ePr6dGjTU_LpaVDBbv4bw',
#    'alias': 'vital-ingredients-london-4',
#    'name': 'Vital Ingredients',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WTdQNMLU_EB1Etgb-D8Myw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vital-ingredients-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5141699615936,
#     'longitude': -0.109391212463379},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '176 Fleet Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4A 2EN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['176 Fleet Street',
#      'London EC4A 2EN',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1844.2459782599954},
#   {'id': 'rIJy-BctBkxqVJNrwbtaVg',
#    'alias': 'beaufort-house-chelsea',
#    'name': 'Beaufort House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1M4KzA-uPd-HsAONzocpkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beaufort-house-chelsea?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4845340805816,
#     'longitude': -0.175986981001262},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "354 King's Road",
#     'address2': '',
#     'address3': '',
#     'city': 'Chelsea',
#     'zip_code': 'SW3 5UZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["354 King's Road",
#      'Chelsea SW3 5UZ',
#      'United Kingdom']},
#    'phone': '+442073522828',
#    'display_phone': '+44 20 7352 2828',
#    'distance': 4193.110434883543},
#   {'id': '6uY8Sp8KpyqUjnXn1gWFTA',
#    'alias': 'planet-organic-london-3',
#    'name': 'Planet Organic',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L0i-081AsNro0i34NzPU6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/planet-organic-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 25,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'healthmarkets', 'title': 'Health Markets'},
#     {'alias': 'markets', 'title': 'Fruits & Veggies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.537773, 'longitude': -0.099612},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '64 Essex Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8LR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['64 Essex Road', 'London N1 8LR', 'United Kingdom']},
#    'phone': '+442072889460',
#    'display_phone': '+44 20 7288 9460',
#    'distance': 3769.3501186087283},
#   {'id': '4TU99yHlV6jNjZNwsiz1rA',
#    'alias': 'daylesford-organic-london-3',
#    'name': 'Daylesford Organic',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Sqexo7taEv-7g0YnP4qT3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daylesford-organic-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'organic_stores', 'title': 'Organic Stores'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.490645, 'longitude': -0.1533991},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '44b Pimlico Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 8LP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['44b Pimlico Road',
#      'London SW1W 8LP',
#      'United Kingdom']},
#    'phone': '+442078818060',
#    'display_phone': '+44 20 7881 8060',
#    'distance': 2746.656110253187},
#   {'id': '-Yyjc4mAqmTK-5CxgCbH9A',
#    'alias': 'happy-dumplings-london',
#    'name': 'Happy Dumplings',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rsSIOj-VBL1b2lvf_4Gc_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/happy-dumplings-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.4619978293128,
#     'longitude': -0.112842207890182},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '29 Market Row',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW9 8LB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['29 Market Row', 'London SW9 8LB', 'United Kingdom']},
#    'phone': '+442075115160',
#    'display_phone': '+44 20 7511 5160',
#    'distance': 5875.0600170127045},
#   {'id': 'buzXH4MZL1sE2xkyLltLPw',
#    'alias': 'vital-ingredient-london',
#    'name': 'Vital Ingredient',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aoIzl_90LSiWYD_YPnFgQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vital-ingredient-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'healthmarkets', 'title': 'Health Markets'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.51461, 'longitude': -0.135584},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '36 Berwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8RR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['36 Berwick Street',
#      'London W1F 8RR',
#      'United Kingdom']},
#    'phone': '+442074943441',
#    'display_phone': '+44 20 7494 3441',
#    'distance': 197.59127945276856},
#   {'id': 'E_2AMpY_lSXcgRQTcTPj0Q',
#    'alias': 'tinseltown-london-10',
#    'name': 'Tinseltown',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kl-3wA7pHEsM97Q0zMnrOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tinseltown-london-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 75,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5213012631375,
#     'longitude': -0.101313133681606},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '44-46 St John Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1M 4DF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['44-46 St John Street',
#      'London EC1M 4DF',
#      'United Kingdom']},
#    'phone': '+442076892424',
#    'display_phone': '+44 20 7689 2424',
#    'distance': 2575.2927760922953},
#   {'id': 'sDrobUAk7rUf4pnRY5HS5A',
#    'alias': 'little-h-london',
#    'name': 'Little H',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-h-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4723948709436,
#     'longitude': -0.201495058157606},
#    'transactions': [],
#    'location': {'address1': "267 New King's Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW6 4RD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["267 New King's Road",
#      'London SW6 4RD',
#      'United Kingdom']},
#    'phone': '+442034178228',
#    'display_phone': '+44 20 3417 8228',
#    'distance': 6388.192295345858},
#   {'id': '0KZ107VXX8qsbGjRNNuWzQ',
#    'alias': 'tuttis-london',
#    'name': "Tutti's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KUmlz8ZkyKPKH8tgjj1rGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tuttis-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5222952, 'longitude': -0.1184993},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': "68 Lamb's Conduit Street",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1N 3LW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["68 Lamb's Conduit Street",
#      'London WC1N 3LW',
#      'United Kingdom']},
#    'phone': '+442074049254',
#    'display_phone': '+44 20 7404 9254',
#    'distance': 1599.057394869384},
#   {'id': 'CwQhljS__yTGSl3RYX17Uw',
#    'alias': 'ngon-london',
#    'name': 'Ngon',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DGqaEdDTira9BOL_YCrnJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ngon-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4923867370861,
#     'longitude': -0.257217525077126},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '195 Chiswick High Road',
#     'address2': 'Chiswick',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W4 2DR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['195 Chiswick High Road',
#      'Chiswick',
#      'London W4 2DR',
#      'United Kingdom']},
#    'phone': '+442089949630',
#    'display_phone': '+44 20 8994 9630',
#    'distance': 8695.841960937398}],
#  'total': 162,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Restaurant": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                     Restaurant                    Type Price Rating  \
# 0               Borough Market          Farmers Market    ££    4.5
# 1                      Lumiere  Juice Bars & Smoothies    ££      4
# 2             Chegworth Valley  Juice Bars & Smoothies
# 3         The Hive of Vyner St               Wine Bars
# 4  5 Senses Juice & Coffee Bar            Coffee & Tea
#
#                         Address        Lat       Lng  \
# 0            8 Southwark Street  51.505143 -0.090937
# 1            88 Chatsworth Road  51.554275 -0.044888
# 2                Borough Market  51.505710 -0.091520
# 3  286-290 Cambridge Heath Road  51.534170 -0.057243
# 4              1028 Harrow Road  51.531140 -0.230430
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/borough-market-london...  U-Sz3hVjbZ8eaNeKGpZU_A
# 1  https://www.yelp.com/biz/lumiere-london?adjust...  6AmObM5tVu3Bhb-Y5HCMgA
# 2
# 3
# 4

# %%
#3rd set of 50 records 101-150
lndr_params3 = {"term":term,"location":"London","limit":50,"offset":101}
lndr_response3 = requests.get(search_api_url, headers=headers, params=lndr_params3)
lndr3 = lndr_response3.json()
display(lndr3)
#print(lndr_response3.url)
#print(lndr_response3.status_code)
# Out:
# {'businesses': [{'id': '9oagZEy-R5xTqG32R5OD1g',
#    'alias': 'the-detox-kitchen-london-2',
#    'name': 'The Detox Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9xnqIjWzOzbu9xZe0XI8xA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-detox-kitchen-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'healthmarkets', 'title': 'Health Markets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512532, 'longitude': -0.138969},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10 Kingly Street',
#     'address2': 'Kingly Court',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5PJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Kingly Street',
#      'Kingly Court',
#      'London W1B 5PJ',
#      'United Kingdom']},
#    'phone': '+442074399386',
#    'display_phone': '+44 20 7439 9386',
#    'distance': 215.86548271766327},
#   {'id': 'XBq3wcm8fXNjUG2Ju_329w',
#    'alias': 'the-blue-legume-london-2',
#    'name': 'The Blue Legume',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/22pusaESf_K5Zogj0HoDpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-blue-legume-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.562061701206,
#     'longitude': -0.079256478358629},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '101 Stoke Newington Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 0UD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['101 Stoke Newington Church Street',
#      'London N16 0UD',
#      'United Kingdom']},
#    'phone': '+442079231303',
#    'display_phone': '+44 20 7923 1303',
#    'distance': 6733.475162792293},
#   {'id': 'IWl1Y0eQOZSnYeIDw94svg',
#    'alias': 'monmouth-coffee-london',
#    'name': 'Monmouth Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-eZOw_Lts2a7dWXNYekA_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/monmouth-coffee-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 306,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5055383383613,
#     'longitude': -0.0914615294783139},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Park Street',
#     'address2': 'The Borough',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Park Street',
#      'The Borough',
#      'London SE1 9AB',
#      'United Kingdom']},
#    'phone': '+442072323010',
#    'display_phone': '+44 20 7232 3010',
#    'distance': 3184.4018654070014},
#   {'id': 'PtxhCXU1KzE9-nUGIzOtsQ',
#    'alias': 'tossed-london-15',
#    'name': 'Tossed',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8d4of0LGU4BE9AOW3NhF2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tossed-london-15?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5133194472607,
#     'longitude': -0.0834441809944777},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit B Leadenhall Court',
#     'address2': '1 Leadenhall Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3V 1AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit B Leadenhall Court',
#      '1 Leadenhall Street',
#      'London EC3V 1AB',
#      'United Kingdom']},
#    'phone': '+442072838218',
#    'display_phone': '+44 20 7283 8218',
#    'distance': 3634.2308261875246},
#   {'id': '8NsK6JufpwaNlJPov5aOHg',
#    'alias': 'planet-organic-wandsworth',
#    'name': 'Planet Organic',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/v7FmTtxyeU0nRKMiAp5qdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/planet-organic-wandsworth?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'organic_stores', 'title': 'Organic Stores'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4550327, 'longitude': -0.1930173},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '52 Garratt Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'Wandsworth',
#     'zip_code': 'SW18 4FT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['52 Garratt Lane',
#      'Wandsworth SW18 4FT',
#      'United Kingdom']},
#    'phone': '+442088778330',
#    'display_phone': '+44 20 8877 8330',
#    'distance': 7544.745672476313},
#   {'id': 'za-KLljMB6yelgi2idCQPg',
#    'alias': 'beany-green-london',
#    'name': 'Beany Green',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UMPucP-qTkGpe2o5ix3woA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beany-green-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.519873314712,
#     'longitude': -0.180045690126235},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 6C',
#     'address2': '4 Sheldon Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 6EZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 6C',
#      '4 Sheldon Square',
#      'London W2 6EZ',
#      'United Kingdom']},
#    'phone': '+442072893344',
#    'display_phone': '+44 20 7289 3344',
#    'distance': 3149.5925485320417},
#   {'id': 'XslwM43lTahRAG5n_BvAVA',
#    'alias': 'limeyard-ealing',
#    'name': 'Limeyard',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/etv9QqYItBUSwoBBeAsWRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/limeyard-ealing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5112435, 'longitude': -0.3050154},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '8 Ealing High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Ealing',
#     'zip_code': 'W5 5DB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Ealing High Street',
#      'Ealing W5 5DB',
#      'United Kingdom']},
#    'phone': '+442085679056',
#    'display_phone': '+44 20 8567 9056',
#    'distance': 11700.616116253932},
#   {'id': '0r2-fwgLvuOLef0epiFkFQ',
#    'alias': 'granger-and-co-london',
#    'name': 'Granger & Co',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4pSTSM2JgsADC_cPoLBQJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/granger-and-co-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 183,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514646148453,
#     'longitude': -0.19779915622354},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '175 Westbourne Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 2SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['175 Westbourne Grove',
#      'London W11 2SB',
#      'United Kingdom']},
#    'phone': '+442072299111',
#    'display_phone': '+44 20 7229 9111',
#    'distance': 4284.263019990538},
#   {'id': '9AcZTopsS2xtwjZ_LfycCA',
#    'alias': 'waitrose-london-75',
#    'name': 'Waitrose',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JWj4pWKNzM6fPKhGjMM4kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/waitrose-london-75?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5351600519193,
#     'longitude': -0.125071071088314},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Granary Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1C',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Granary Square', 'London N1C', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2594.0803270168176},
#   {'id': '-ATEXu2q4Oe4wPQeyrsILw',
#    'alias': 'princi-london',
#    'name': 'Princi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QLFgoDIBiLx2F0tpUIw7gQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/princi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 304,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5138629586873,
#     'longitude': -0.134387051472991},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '135 Wardour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0UT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['135 Wardour Street',
#      'London W1F 0UT',
#      'United Kingdom']},
#    'phone': '+442074788888',
#    'display_phone': '+44 20 7478 8888',
#    'distance': 157.59755401297926},
#   {'id': 'LRHSeC3QJh_ahSNCsviy8Q',
#    'alias': 'urban-social-london',
#    'name': 'Urban Social',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wW2NbpCQXs8oha97-hS4Uw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/urban-social-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 51.5146918370783,
#     'longitude': -0.18873153158508},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '148-151 Queensway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 4SB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['148-151 Queensway',
#      'London W2 4SB',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3657.88122468471},
#   {'id': 'nSZsig9ZEHk88siWIsRBww',
#    'alias': 'ginger-and-mint-london-2',
#    'name': 'Ginger & Mint',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eWi35Ds3vRQVPpV37CTQxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginger-and-mint-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'milkshakebars', 'title': 'Milkshake Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5471958, 'longitude': -0.0112651},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '13-14 Victory Parade',
#     'address2': '',
#     'address3': 'East Village',
#     'city': 'London',
#     'zip_code': 'E20 1FS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13-14 Victory Parade',
#      'East Village',
#      'London E20 1FS',
#      'United Kingdom']},
#    'phone': '+442080019533',
#    'display_phone': '+44 20 8001 9533',
#    'distance': 9433.772350430225},
#   {'id': 'Vq7gk0itKLHOSYtC45cykQ',
#    'alias': 'kaspas-desserts-london-2',
#    'name': "Kaspa's Desserts",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3Na3x0k0AnMHZMRtXy8Yxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaspas-desserts-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'creperies', 'title': 'Creperies'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4858525323484,
#     'longitude': -0.0941111703598141},
#    'transactions': [],
#    'location': {'address1': '321-323 Walworth Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE17 2TG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['321-323 Walworth Road',
#      'London SE17 2TG',
#      'United Kingdom']},
#    'phone': '+442034906883',
#    'display_phone': '+44 20 3490 6883',
#    'distance': 4170.392742078706},
#   {'id': 'wm6Hwzan5qYhTzCDmO3oDQ',
#    'alias': 'muriels-kitchen-london',
#    'name': "Muriel's Kitchen",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9un8EzHME-wGnd7zVoev2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/muriels-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 134,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.494117, 'longitude': -0.174468},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Unit 1',
#     'address2': '3 Pelham Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 2ND',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 1',
#      '3 Pelham Street',
#      'London SW7 2ND',
#      'United Kingdom']},
#    'phone': '+442075893511',
#    'display_phone': '+44 20 7589 3511',
#    'distance': 3381.980840047671},
#   {'id': 'nBQDwxhxfr94-rPIvAjTQw',
#    'alias': 'sblended-milkshakes-london',
#    'name': 'Sblended Milkshakes',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sblended-milkshakes-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.506227, 'longitude': -0.220569},
#    'transactions': [],
#    'location': {'address1': None,
#     'address2': 'Westfield',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W12 8AG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Westfield', 'London W12 8AG', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5928.6428859180305},
#   {'id': '3-sUDl7xsZisqlsagnOBCA',
#    'alias': 'sakonis-wembley',
#    'name': 'Sakonis',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ccYpPz_nVxkEp9nDlpInXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sakonis-wembley?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.545849, 'longitude': -0.297033},
#    'transactions': [],
#    'location': {'address1': '127-129 Ealing Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Wembley',
#     'zip_code': 'HA0 4BP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['127-129 Ealing Road',
#      'Wembley HA0 4BP',
#      'United Kingdom']},
#    'phone': '+442089039601',
#    'display_phone': '+44 20 8903 9601',
#    'distance': 11705.954019714745},
#   {'id': 'BGXvR4Z4d2Z8jFk54bay7w',
#    'alias': 'shakeaway-croydon-2',
#    'name': 'ShakeAway',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wV5ZOepYyDnobL3KgtCzPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shakeaway-croydon-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.3780355357699,
#     'longitude': -0.124776363372803},
#    'transactions': [],
#    'location': {'address1': 'Valley Park Leisure Centre',
#     'address2': 'Hesterman Way',
#     'address3': '',
#     'city': 'Croydon',
#     'zip_code': 'CR0 4YA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Valley Park Leisure Centre',
#      'Hesterman Way',
#      'Croydon CR0 4YA',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 15009.06810992617},
#   {'id': '5YW4JzNbqvGJ6SUzOa8poQ',
#    'alias': 'cable-co-london',
#    'name': 'Cable co',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/l5iXgXjTQDRcOgMdERvHiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cable-co-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5347724096131,
#     'longitude': -0.219354601232224},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '4 Bridge House',
#     'address2': 'Chamberlayne Rd',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW10 3NR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Bridge House',
#      'Chamberlayne Rd',
#      'London NW10 3NR',
#      'United Kingdom']},
#    'phone': '+447444421087',
#    'display_phone': '+44 7444 421087',
#    'distance': 6264.307869501614},
#   {'id': 'QzH386Ttt_GNjQBPYLADQw',
#    'alias': 'bubbleology-london-3',
#    'name': 'Bubbleology',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WU3faf0zMXIGBvt7qKcEiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bubbleology-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.510399, 'longitude': -0.197596},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '45 Pembridge Road',
#     'address2': 'Notting Hill',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W11 3HG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Pembridge Road',
#      'Notting Hill',
#      'London W11 3HG',
#      'United Kingdom']},
#    'phone': '+442077279771',
#    'display_phone': '+44 20 7727 9771',
#    'distance': 4274.265461222591},
#   {'id': 'SiYcTcmjZkogL6hhm4NY1g',
#    'alias': 'bubbleology-london-7',
#    'name': 'Bubbleology',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mhOd4uHsLLqaE4sS3Vep-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bubbleology-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.5359244, 'longitude': -0.1039501},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '64 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 0NY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['64 Upper Street', 'London N1 0NY', 'United Kingdom']},
#    'phone': '+442073545330',
#    'display_phone': '+44 20 7354 5330',
#    'distance': 3378.7473050110893},
#   {'id': '2hMKa2Sbs7flUknMkW5h3g',
#    'alias': 'revital-health-shop-london-4',
#    'name': 'Revital Health Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8YCBpTgfp-CFn3cuIQPyYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/revital-health-shop-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'healthmarkets', 'title': 'Health Markets'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.516777, 'longitude': -0.1472242},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Wigmore Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 2RG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Wigmore Street',
#      'London W1U 2RG',
#      'United Kingdom']},
#    'phone': '+442076313731',
#    'display_phone': '+44 20 7631 3731',
#    'distance': 898.8128801359629},
#   {'id': 'C1MMQ48SksaByhPs6Hc4IQ',
#    'alias': 'bubbleology-west-end',
#    'name': 'Bubbleology',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vNO3bS7WUiV-V2LapIM5eA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bubbleology-west-end?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 51.5152868737707,
#     'longitude': -0.141826695770305},
#    'transactions': [],
#    'location': {'address1': 'Oxford Circus',
#     'address2': 'Topshop',
#     'address3': '',
#     'city': 'West End',
#     'zip_code': 'W1W 8LG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Oxford Circus',
#      'Topshop',
#      'West End W1W 8LG',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 489.22943188380157},
#   {'id': 'DZ4tVjm66Z_EJ7KeaCZF1Q',
#    'alias': 'shaketastic-pinner',
#    'name': 'ShakeTastic',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IuydpVkpXA0XEyn--COX8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shaketastic-pinner?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5942460849837,
#     'longitude': -0.380074046552181},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '48 High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Pinner',
#     'zip_code': 'HA5 5PW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['48 High Street', 'Pinner HA5 5PW', 'United Kingdom']},
#    'phone': '+442088688988',
#    'display_phone': '+44 20 8868 8988',
#    'distance': 19152.44849076318},
#   {'id': 'rYWI2S9aPiU9O4VZJ0Dwkg',
#    'alias': 'fressh-juice-bar-london',
#    'name': 'Fressh Juice Bar',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fressh-juice-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5133776, 'longitude': -0.3038972},
#    'transactions': [],
#    'location': {'address1': 'The Broadway',
#     'address2': 'Ealing Broadway Centre',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W5 5JY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Broadway',
#      'Ealing Broadway Centre',
#      'London W5 5JY',
#      'United Kingdom']},
#    'phone': '+442085795004',
#    'display_phone': '+44 20 8579 5004',
#    'distance': 11621.77924252517},
#   {'id': 'EIT9mzwf9IHM59TT8WOQkw',
#    'alias': 'the-parlour-london-2',
#    'name': 'The Parlour',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bfbWjmr9QkkOFJO6JLxv2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-parlour-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5612073, 'longitude': -0.0823609},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '167 Stoke Newington Church Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N16 0UL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['167 Stoke Newington Church Street',
#      'London N16 0UL',
#      'United Kingdom']},
#    'phone': '+442079230654',
#    'display_phone': '+44 20 7923 0654',
#    'distance': 6547.2361229707585},
#   {'id': 'vCF8ut7OZcfA4hEmhngfSQ',
#    'alias': 'andina-london',
#    'name': 'Andina',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sgBZI-KCVdW5u838gGQW6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/andina-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 142,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5243208695971,
#     'longitude': -0.077134990126122},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Redchurch Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 7DJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Redchurch Street',
#      'London E2 7DJ',
#      'United Kingdom']},
#    'phone': '+442079206499',
#    'display_phone': '+44 20 7920 6499',
#    'distance': 4265.6096504626785},
#   {'id': 'LpIY4AvlAQZqJEZgcFoFPA',
#    'alias': 'the-alchemist-london-3',
#    'name': 'The Alchemist',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NXHurBRaL0gJuLtVnXZAKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-alchemist-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 85,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5150476, 'longitude': -0.0793474},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 Bevis Marks',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3A 7BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Bevis Marks', 'London EC3A 7BA', 'United Kingdom']},
#    'phone': '+442072838800',
#    'display_phone': '+44 20 7283 8800',
#    'distance': 3924.9724248663238},
#   {'id': '0ho6hvyjTUFmuKWpNuwzLA',
#    'alias': 'riverford-at-the-duke-of-cambridge-london',
#    'name': 'Riverford at The Duke of Cambridge',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/12OkEXki_RKX8vlVbMmxbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/riverford-at-the-duke-of-cambridge-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 73,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'organic_stores', 'title': 'Organic Stores'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5345940382283,
#     'longitude': -0.0987110343933182},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '30 St Peters Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 8JT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 St Peters Street',
#      'London N1 8JT',
#      'United Kingdom']},
#    'phone': '+442073593066',
#    'display_phone': '+44 20 7359 3066',
#    'distance': 3534.5909880110257},
#   {'id': '8qy3zqgeRy6r2vB7OaE7Sw',
#    'alias': 'food-london',
#    'name': 'Food',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WhXCYVG-33sNwkJe-Z0lxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/food-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'gourmet', 'title': 'Specialty Food'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.5146183469422,
#     'longitude': -0.188827514648438},
#    'transactions': [],
#    'location': {'address1': 'Whiteleys',
#     'address2': '151 Queensway',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 4YN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Whiteleys',
#      '151 Queensway',
#      'London W2 4YN',
#      'United Kingdom']},
#    'phone': '+442077926020',
#    'display_phone': '+44 20 7792 6020',
#    'distance': 3664.0643769093144},
#   {'id': 'IYkFPzxOKbeaGgNrcNaw5Q',
#    'alias': 'crussh-greenhithe',
#    'name': 'Crussh',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crussh-greenhithe?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.439173, 'longitude': 0.270165},
#    'transactions': [],
#    'location': {'address1': 'Unit 90B Upper Thames Walk',
#     'address2': 'Bluewater',
#     'address3': '',
#     'city': 'Greenhithe',
#     'zip_code': 'DA9 9ST',
#     'country': 'GB',
#     'state': 'KEN',
#     'display_address': ['Unit 90B Upper Thames Walk',
#      'Bluewater',
#      'Greenhithe DA9 9ST',
#      'United Kingdom']},
#    'phone': '+441322423700',
#    'display_phone': '+44 1322 423700',
#    'distance': 29467.738370199637},
#   {'id': '2yHOKoIbTjd9HFo53KaJww',
#    'alias': 'espresso-bar-london',
#    'name': 'Espresso Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/N2WRyRvQKTGSlJlarNLPUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/espresso-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5074469905976,
#     'longitude': -0.100250244140625},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Bankside',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9TG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Bankside', 'London SE1 9TG', 'United Kingdom']},
#    'phone': '+442078878888',
#    'display_phone': '+44 20 7887 8888',
#    'distance': 2542.610836500104},
#   {'id': 'jS0-NHOVJ8E4FeWFkHdqZA',
#    'alias': 'brooks-counter-and-table-london',
#    'name': "Brook's Counter & Table",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AXwZqr5d-eNeJc6sULdi0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooks-counter-and-table-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4978256225586,
#     'longitude': -0.222856000065804},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '140 Shepherds Bush Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W6 7PB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['140 Shepherds Bush Road',
#      'London W6 7PB',
#      'United Kingdom']},
#    'phone': '+442076020664',
#    'display_phone': '+44 20 7602 0664',
#    'distance': 6241.841334706852},
#   {'id': 'cy28kr98GOWJzUqf7Dg_dg',
#    'alias': 'absolutely-starving-london',
#    'name': 'Absolutely Starving',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kwgsDjzjZ9sNiJ7gkPIw7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/absolutely-starving-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5050986007288,
#     'longitude': -0.0849500457449048},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '51 Tooley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 2QN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Tooley Street',
#      'London SE1 2QN',
#      'United Kingdom']},
#    'phone': '+442074077417',
#    'display_phone': '+44 20 7407 7417',
#    'distance': 3633.267376510319},
#   {'id': 'sIOQNGD-TNg8s5dnEspskg',
#    'alias': 'fresh-and-organic-london-2',
#    'name': 'Fresh and Organic',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rwYqzgb6rp7lcGXP6LTeOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fresh-and-organic-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5156194, 'longitude': -0.1232397},
#    'transactions': [],
#    'location': {'address1': '174 drury lane',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5QF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['174 drury lane',
#      'London WC2B 5QF',
#      'United Kingdom']},
#    'phone': '+442074045153',
#    'display_phone': '+44 20 7404 5153',
#    'distance': 927.9868619074809},
#   {'id': 'GFa_df3J5gxWd7815y9mUw',
#    'alias': 'organico-epsom',
#    'name': 'Organico',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/F-wKtx6zQJAQmyX7H0k4pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/organico-epsom?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'organic_stores', 'title': 'Organic Stores'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.3329824705593,
#     'longitude': -0.268400825253083},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Kings Shade Walk',
#     'address2': 'High Street',
#     'address3': '',
#     'city': 'Epsom',
#     'zip_code': 'KT19 8EB',
#     'country': 'GB',
#     'state': 'SRY',
#     'display_address': ['1 Kings Shade Walk',
#      'High Street',
#      'Epsom KT19 8EB',
#      'United Kingdom']},
#    'phone': '+441372740531',
#    'display_phone': '+44 1372 740531',
#    'distance': 22006.438029010635},
#   {'id': 'fiPtJqjk4-hVhrdvLoCXiQ',
#    'alias': 'broadway-market-london',
#    'name': 'Broadway Market',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OzrOxq2T-hss5FBJ2vLoSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/broadway-market-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 114,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.53676, 'longitude': -0.061918},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '25 Broadway Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 4PH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['25 Broadway Market',
#      'London E8 4PH',
#      'United Kingdom']},
#    'phone': '+447872463409',
#    'display_phone': '+44 7872 463409',
#    'distance': 5771.773024230724},
#   {'id': 'rD7hhPYGKLfAK-E23zzhqQ',
#    'alias': 'kruger-london-2',
#    'name': 'Kruger',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YND4uu2aNbOcgqVjMs-6RA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kruger-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5077445175947,
#     'longitude': -0.026466218554674},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Cabot Place W',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E14 4QT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Cabot Place W', 'London E14 4QT', 'United Kingdom']},
#    'phone': '+442077191629',
#    'display_phone': '+44 20 7719 1629',
#    'distance': 7598.317522462164},
#   {'id': 'Vy0aF64b64EqUInvhOWaew',
#    'alias': 'creams-brent',
#    'name': 'Creams',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ox5sfKQQrlmZPu5x7ASmnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/creams-brent?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5522581199132,
#     'longitude': -0.296613522350764},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 6',
#     'address2': '455 High Road',
#     'address3': '',
#     'city': 'Brent',
#     'zip_code': 'HA9 7AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 6',
#      '455 High Road',
#      'Brent HA9 7AF',
#      'United Kingdom']},
#    'phone': '+442087952355',
#    'display_phone': '+44 20 8795 2355',
#    'distance': 11946.175990281237},
#   {'id': 'oLMGv8U3jhM7xvA9caUlHA',
#    'alias': 'shakeabout-london',
#    'name': 'shakeabout',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shakeabout-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.439173, 'longitude': 0.270165},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Bluewater',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'DA9 9ST',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Bluewater', 'London DA9 9ST', 'United Kingdom']},
#    'phone': '+448707770252',
#    'display_phone': '+44 870 777 0252',
#    'distance': 29364.894699917655},
#   {'id': 'bXo_3uLhacyeGJ0iF743PQ',
#    'alias': 'mildreds-london',
#    'name': 'Mildreds',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3tO7I9umlO0hbSp29-q7wA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mildreds-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 280,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5130233764648,
#     'longitude': -0.136484995484352},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '45 Lexington Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9AN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Lexington Street',
#      'London W1F 9AN',
#      'United Kingdom']},
#    'phone': '+442074941634',
#    'display_phone': '+44 20 7494 1634',
#    'distance': 37.57987441984523},
#   {'id': '2w6zCee4z9Q55jUPw-Pu9w',
#    'alias': 'carluccios-marriot-regents-park-london',
#    'name': "Carluccio's Marriot Regents Park",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lEjLMBxyE2JdjjIS6UKYkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carluccios-marriot-regents-park-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.5421475089086,
#     'longitude': -0.170307196676731},
#    'transactions': [],
#    'location': {'address1': "128 King Henry's Road",
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW3 3ST',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["128 King Henry's Road",
#      'London NW3 3ST',
#      'United Kingdom']},
#    'phone': '+442077227711',
#    'display_phone': '+44 20 7722 7711',
#    'distance': 4033.669750038744},
#   {'id': 'WHrXrCaBE3Uf3d-B5Wyh0g',
#    'alias': 'heddon-street-kitchen-london',
#    'name': 'Heddon Street Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T5ZDviNFEe04BXyeJvfpig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heddon-street-kitchen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 91,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5107288, 'longitude': -0.1393024},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '3-9 Heddon St',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 4BE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3-9 Heddon St', 'London W1B 4BE', 'United Kingdom']},
#    'phone': '+442075921212',
#    'display_phone': '+44 20 7592 1212',
#    'distance': 329.41022584098886},
#   {'id': 'nOYtSW76HBkmqmI_mbfCVg',
#    'alias': 'bubbleology-london-4',
#    'name': 'Bubbleology',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/C0eOZRbA_cgaIRgDk35U5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bubbleology-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.494573, 'longitude': -0.17439},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '23 Cromwell Place',
#     'address2': 'South Kensington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 2LD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23 Cromwell Place',
#      'South Kensington',
#      'London SW7 2LD',
#      'United Kingdom']},
#    'phone': '+442075841171',
#    'display_phone': '+44 20 7584 1171',
#    'distance': 3353.2837689551716},
#   {'id': 'xsZqlueXWeDZYkjIbM8Nkw',
#    'alias': 'blue-mountain-london',
#    'name': 'Blue Mountain',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fwZsFj72nk9W2B3GAbkaMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-mountain-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.45759277398,
#     'longitude': -0.072380143086589},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '18 North Cross Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE22 9EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['18 North Cross Road',
#      'London SE22 9EU',
#      'United Kingdom']},
#    'phone': '+442082996953',
#    'display_phone': '+44 20 8299 6953',
#    'distance': 7557.238050308057},
#   {'id': 'Hhfd6Q-O5STPLZVmfMkpew',
#    'alias': 'enfield-market-enfield-3',
#    'name': 'Enfield Market',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/s-g3lMQN0GHYWUGu1b0Usg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/enfield-market-enfield-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.6523289249765,
#     'longitude': -0.0822896536348293},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Church Street',
#     'address2': 'Enfield',
#     'address3': '',
#     'city': 'Enfield',
#     'zip_code': 'EN2 6LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Church Street',
#      'Enfield',
#      'Enfield EN2 6LT',
#      'United Kingdom']},
#    'phone': '+442083678941',
#    'display_phone': '+44 20 8367 8941',
#    'distance': 15948.007995561446},
#   {'id': 'iS23oWH7t98_W1I93KqcvA',
#    'alias': 'planet-organic-london-10',
#    'name': 'Planet Organic',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WJY8-VWSdTwOIoPAQ3iNOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/planet-organic-london-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'organic_stores', 'title': 'Organic Stores'},
#     {'alias': 'healthmarkets', 'title': 'Health Markets'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5177705, 'longitude': -0.1316695},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '23-24 Tottenham Court Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 1BP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23-24 Tottenham Court Road',
#      'London W1T 1BP',
#      'United Kingdom']},
#    'phone': '+442030731038',
#    'display_phone': '+44 20 3073 1038',
#    'distance': 631.2066350735855},
#   {'id': 'zI4Z-LjiIWBubhcLCX8vpw',
#    'alias': 'the-pavilion-cafe-london',
#    'name': 'The Pavilion Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zgj62S140sq4g5Q-Jetmzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pavilion-cafe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.533421, 'longitude': -0.042846},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Victoria Park',
#     'address2': 'Old Ford Rd',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E9 7DE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Victoria Park',
#      'Old Ford Rd',
#      'London E9 7DE',
#      'United Kingdom']},
#    'phone': '+442089800030',
#    'display_phone': '+44 20 8980 0030',
#    'distance': 6836.419536616521},
#   {'id': 'NEhIrdzk6gGALfOplTa-1g',
#    'alias': 'farmw5-london',
#    'name': 'FarmW5',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wTRiKwON7j6ZfIdrayS4wA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/farmw5-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'healthmarkets', 'title': 'Health Markets'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5109960850417,
#     'longitude': -0.305230021476746},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '19 The Green',
#     'address2': 'Ealing',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W5 5DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['19 The Green',
#      'Ealing',
#      'London W5 5DA',
#      'United Kingdom']},
#    'phone': '+442085661965',
#    'display_phone': '+44 20 8566 1965',
#    'distance': 11715.946468650289},
#   {'id': 'zEJmnNqCnaM_x1m5W6sbbA',
#    'alias': 'coffee-house-and-deli-croxley-green',
#    'name': 'Coffee House and Deli',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hlYg2q8SDVcLbBrYuWa-pw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffee-house-and-deli-croxley-green?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.6484124, 'longitude': -0.4483361},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '141 New Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Croxley Green',
#     'zip_code': 'WD3 3EN',
#     'country': 'GB',
#     'state': 'HRT',
#     'display_address': ['141 New Road',
#      'Croxley Green WD3 3EN',
#      'United Kingdom']},
#    'phone': '+441923510995',
#    'display_phone': '+44 1923 510995',
#    'distance': 26318.525826017085},
#   {'id': '7kBtTjr1SdEDESFiyan-Ag',
#    'alias': 'apero-restaurant-and-bar-london',
#    'name': 'Apero Restaurant and Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4itRKhjda2FZNmDd1uWylQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/apero-restaurant-and-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 38,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4942818627381,
#     'longitude': -0.175694857095886},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Harrington Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Harrington Road',
#      'London SW7 3ER',
#      'United Kingdom']},
#    'phone': '+442075914410',
#    'display_phone': '+44 20 7591 4410',
#    'distance': 3438.2722475474984}],
#  'total': 162,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Restaurant": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#           Restaurant            Type Price Rating  \
# 0  The Detox Kitchen  Health Markets    ££      4
# 1    The Blue Legume    Coffee & Tea    ££    3.5
# 2    Monmouth Coffee    Coffee & Tea    ££    4.5
# 3             Tossed           Salad     £      3
# 4     Planet Organic  Organic Stores     £    4.5
#
#                              Address        Lat       Lng  \
# 0                   10 Kingly Street  51.512532 -0.138969
# 1  101 Stoke Newington Church Street  51.562062 -0.079256
# 2                      2 Park Street  51.505538 -0.091462
# 3            Unit B Leadenhall Court  51.513319 -0.083444
# 4                    52 Garratt Lane  51.455033 -0.193017
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/the-detox-kitchen-lon...  9oagZEy-R5xTqG32R5OD1g
# 1  https://www.yelp.com/biz/the-blue-legume-londo...  XBq3wcm8fXNjUG2Ju_329w
# 2  https://www.yelp.com/biz/monmouth-coffee-londo...  IWl1Y0eQOZSnYeIDw94svg
# 3  https://www.yelp.com/biz/tossed-london-15?adju...  PtxhCXU1KzE9-nUGIzOtsQ
# 4  https://www.yelp.com/biz/planet-organic-wandsw...  8NsK6JufpwaNlJPov5aOHg

# %%
#4th set of 50 records 151-200
lndr_params4 = {"term":term,"location":"London","limit":50,"offset":151}
lndr_response4 = requests.get(search_api_url, headers=headers, params=lndr_params4)
lndr4 = lndr_response4.json()
display(lndr4)
#print(lndr_response4.url)
#print(lndr_response4.status_code)
# Out:
# {'businesses': [{'id': 'Zu95anP0mIezAc6fvYTzmg',
#    'alias': 'the-blue-legume-london-3',
#    'name': 'The Blue Legume',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1j-JNM2Ju5y2NZHx-Ljvxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-blue-legume-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5775696012625,
#     'longitude': -0.123145580291748},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '130 Crouch Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N8 9DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['130 Crouch Hill', 'London N8 9DY', 'United Kingdom']},
#    'phone': '+442084429282',
#    'display_phone': '+44 20 8442 9282',
#    'distance': 7252.397940409153},
#   {'id': '46LI_quaSEdZgNiT_U_gyA',
#    'alias': 'the-sanctuary-house-london',
#    'name': 'The Sanctuary House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MQgX5hIsXiiDa3CCMnycWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-sanctuary-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'fishnchips', 'title': 'Fish & Chips'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.499569, 'longitude': -0.131861},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '33 Tothill Street',
#     'address2': "St James's Park",
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1H 9LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['33 Tothill Street',
#      "St James's Park",
#      'London SW1H 9LA',
#      'United Kingdom']},
#    'phone': '+442077994044',
#    'display_phone': '+44 20 7799 4044',
#    'distance': 1504.1528815732227},
#   {'id': 'D3S8aol0T8Sr9hqM7fgrvg',
#    'alias': 'pret-a-manger-london-33',
#    'name': 'Pret A Manger',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/asd27FKqQq0HCnKnC6_w8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pret-a-manger-london-33?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5142107, 'longitude': -0.1494624},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit G15 West One Shopping Centre',
#     'address2': '381 Oxford Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1C 2JS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit G15 West One Shopping Centre',
#      '381 Oxford Street',
#      'London W1C 2JS',
#      'United Kingdom']},
#    'phone': '+442079325280',
#    'display_phone': '+44 20 7932 5280',
#    'distance': 953.1379394258827},
#   {'id': '9uC3zvA6gag6j_wzwJAJag',
#    'alias': 'cafe-marrone-london',
#    'name': 'Cafe Marrone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HwJPl7fSa-86n5XxOCYKoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-marrone-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51204, 'longitude': -0.05665},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Shadwell Station',
#     'address2': 'Watney Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 2QD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Shadwell Station',
#      'Watney Street',
#      'London E1 2QD',
#      'United Kingdom']},
#    'phone': '+442077915356',
#    'display_phone': '+44 20 7791 5356',
#    'distance': 5489.583071494003},
#   {'id': 'bjlhWqJE8oLHl_P0G5kQ4A',
#    'alias': 'alternatives-health-food-london',
#    'name': 'Alternatives Health Food',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Yb8tZx12MfKDMSVg_fpptg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alternatives-health-food-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'healthmarkets', 'title': 'Health Markets'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.633056, 'longitude': -0.176118},
#    'transactions': [],
#    'location': {'address1': '1369 High Road',
#     'address2': 'Whetstone',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N20 9LN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1369 High Road',
#      'Whetstone',
#      'London N20 9LN',
#      'United Kingdom']},
#    'phone': '+442084452675',
#    'display_phone': '+44 20 8445 2675',
#    'distance': 13645.684900681752},
#   {'id': 'Bc4GZfIUJu9363QQVACZVA',
#    'alias': 'caravan-london-3',
#    'name': 'Caravan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/v264jW33G2GVAP44U9OJ1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caravan-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 149,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5254718215956,
#     'longitude': -0.110122750616417},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11-13 Exmouth Market',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1R 4QD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11-13 Exmouth Market',
#      'London EC1R 4QD',
#      'United Kingdom']},
#    'phone': '+442078338115',
#    'display_phone': '+44 20 7833 8115',
#    'distance': 2273.5789430194204},
#   {'id': 'wBBUOLmss7SQFP2YH1nCRQ',
#    'alias': 'mada-deli-surrey',
#    'name': 'Mada Deli',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_5GH8pGrK3qgearhWJTDKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mada-deli-surrey?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'gourmet', 'title': 'Specialty Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.402838, 'longitude': -0.344403},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '11 Bridge Road',
#     'address2': 'East Molesey',
#     'address3': 'KT8 9EU',
#     'city': 'Surrey',
#     'zip_code': 'KT8 9EU',
#     'country': 'GB',
#     'state': 'SRY',
#     'display_address': ['11 Bridge Road',
#      'East Molesey',
#      'KT8 9EU',
#      'Surrey KT8 9EU',
#      'United Kingdom']},
#    'phone': '+442089797553',
#    'display_phone': '+44 20 8979 7553',
#    'distance': 18913.837116790688},
#   {'id': 'XqzfqKCa5TPfPM0wsRY4Tg',
#    'alias': 'graveney-and-meadow-london',
#    'name': 'Graveney & Meadow',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WcUOCLcY57V1dxkK8i9Q5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/graveney-and-meadow-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.42684, 'longitude': -0.166792},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '40 Mitcham Road',
#     'address2': 'Tooting',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW17 9NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 Mitcham Road',
#      'Tooting',
#      'London SW17 9NA',
#      'United Kingdom']},
#    'phone': '+442086729016',
#    'display_phone': '+44 20 8672 9016',
#    'distance': 9798.771267712225},
#   {'id': 'SPVzsOuOv2fL6oeYvGwVpQ',
#    'alias': 'pret-a-manger-wandsworth',
#    'name': 'Pret A Manger',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MX5pqhOSSpBWp6IjvgowCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pret-a-manger-wandsworth?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4566662371074,
#     'longitude': -0.193010084331036},
#    'transactions': [],
#    'location': {'address1': 'Unit 8 Gate Level',
#     'address2': 'Southside',
#     'address3': '',
#     'city': 'Wandsworth',
#     'zip_code': 'SW18 4TF',
#     'country': 'GB',
#     'state': 'ABE',
#     'display_address': ['Unit 8 Gate Level',
#      'Southside',
#      'Wandsworth SW18 4TF',
#      'United Kingdom']},
#    'phone': '+442088705746',
#    'display_phone': '+44 20 8870 5746',
#    'distance': 7390.313040960612},
#   {'id': 'bkwdrWGbls9MBhzrc-GvCQ',
#    'alias': 'nincomsoup-london',
#    'name': 'Nincomsoup',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JUnajU3Jp5bN-XSGZnuxgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nincomsoup-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 26,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5257003455078,
#     'longitude': -0.0876331329345703},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Old Street Station',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1Y 1BE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Old Street Station',
#      'London EC1Y 1BE',
#      'United Kingdom']},
#    'phone': '+442072534552',
#    'display_phone': '+44 20 7253 4552',
#    'distance': 3636.6645450446713},
#   {'id': 'Dnw968z5KT5vga8zLc3WXg',
#    'alias': 'giraffe-juice-bar-london',
#    'name': 'Giraffe Juice Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5NcYhgVHynLAa_17RQL6Iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giraffe-juice-bar-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.481459, 'longitude': -0.44486},
#    'transactions': [],
#    'location': {'address1': 'T5',
#     'address2': 'Heathrow International Airport',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'UB3 5AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['T5',
#      'Heathrow International Airport',
#      'London UB3 5AP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 21658.151589521876}],
#  'total': 162,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndr4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Restaurant": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#                  Restaurant                Type Price Rating  \
# 0           The Blue Legume  Breakfast & Brunch    ££    3.5
# 1       The Sanctuary House          Sandwiches    ££    3.5
# 2             Pret A Manger        Coffee & Tea     £      4
# 3              Cafe Marrone        Coffee & Tea     £    4.5
# 4  Alternatives Health Food      Health Markets
#
#                              Address        Lat       Lng  \
# 0                    130 Crouch Hill  51.577570 -0.123146
# 1                  33 Tothill Street  51.499569 -0.131861
# 2  Unit G15 West One Shopping Centre  51.514211 -0.149462
# 3                   Shadwell Station  51.512040 -0.056650
# 4                     1369 High Road  51.633056 -0.176118
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/the-blue-legume-londo...  Zu95anP0mIezAc6fvYTzmg
# 1  https://www.yelp.com/biz/the-sanctuary-house-l...  46LI_quaSEdZgNiT_U_gyA
# 2  https://www.yelp.com/biz/pret-a-manger-london-...  D3S8aol0T8Sr9hqM7fgrvg
# 3  https://www.yelp.com/biz/cafe-marrone-london?a...  9uC3zvA6gag6j_wzwJAJag
# 4

# %%
london_restaurants_df = pd.concat([df1,df2,df3,df4], sort=True)
london_restaurants_df.shape
# Out:
# (161, 9)

# %%
column_order = ["Restaurant","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_restaurants_df = london_restaurants_df[column_order]
london_restaurants_df = london_restaurants_df.sort_values(["Type"], ascending=True)
london_restaurants_df = london_restaurants_df.reset_index(drop=True)
london_restaurants_df
# Out:
#                                  Restaurant                    Type Rating  \
# 0                                Tinseltown  American (Traditional)      3
# 1                               Timmy Green              Australian
# 2                              Boys'N'Berry      Breakfast & Brunch
# 3                                   Caravan      Breakfast & Brunch      4
# 4    Megan's Kings Road Restaurant, Chelsea      Breakfast & Brunch      4
# 5                           The Blue Legume      Breakfast & Brunch    3.5
# 6                                    Andina      Breakfast & Brunch      4
# 7                                  DDK Cafe                 British    4.5
# 8                          Muriel's Kitchen                 British      4
# 9                        Daylesford Organic                 British    3.5
# 10                             Granger & Co                 British      4
# 11                       Daylesford Organic                 British      4
# 12                              Bubbleology              Bubble Tea    2.5
# 13                              Bubbleology              Bubble Tea    3.5
# 14                        Giraffe Juice Bar                   Cafes
# 15                           Blanche Eatery                   Cafes      4
# 16                         Fressh Juice Bar                   Cafes
# 17                      CycleLab & JuiceBar                   Cafes      5
# 18                        Hawraman Cafe Bar                   Cafes
# 19                            Blue Mountain                   Cafes      4
# 20                        Crussh Juice Bars                Caterers      4
# 21                            The Alchemist           Cocktail Bars      4
# 22                        Graveney & Meadow           Cocktail Bars    3.5
# 23                            First Aid Box           Cocktail Bars
# 24                              Beany Green            Coffee & Tea    4.5
# 25                          Monmouth Coffee            Coffee & Tea    4.5
# 26                              Veggie Pret            Coffee & Tea      4
# 27                                     Food            Coffee & Tea
# 28                             La Piazzetta            Coffee & Tea      5
# 29               Kunduz Cafe & Sandwich Bar            Coffee & Tea      4
# ..                                      ...                     ...    ...
# 131                Apero Restaurant and Bar           Mediterranean      4
# 132                             Boost Juice          Milkshake Bars
# 133                   Heddon Street Kitchen         Modern European      4
# 134                          Planet Organic          Organic Stores    4.5
# 135                          Planet Organic          Organic Stores      3
# 136                                Organico          Organic Stores      5
# 137                      As Nature Intended          Organic Stores    4.5
# 138             Daylesford Farmhouse & Cafe          Organic Stores    3.5
# 139                            Urban Social    Patisserie/Cake Shop      2
# 140      Riverford at The Duke of Cambridge                    Pubs      4
# 141                                  Tossed                   Salad      3
# 142                                  Tossed                   Salad      3
# 143                       Vital Ingredients                   Salad      4
# 144                             The Parlour                   Salad      3
# 145                                    Pure                   Salad      4
# 146                        Vital Ingredient                   Salad      3
# 147                     The Sanctuary House              Sandwiches    3.5
# 148                                 Tutti's              Sandwiches      4
# 149                                Mildreds                   Vegan      4
# 150                       The Detox Kitchen                   Vegan
# 151                                 Farmacy                   Vegan    4.5
# 152                           Jusu Brothers                   Vegan      5
# 153                                  Tibits              Vegetarian      4
# 154                         Ginger And Mint              Vegetarian
# 155                                 Sakonis              Vegetarian
# 156                                    Ngon              Vietnamese      4
# 157                                The Hive               Wine Bars      5
# 158                    The Hive of Vyner St               Wine Bars
# 159                      Total Chi Yoga Bar                    Yoga
# 160                  The Power Yoga Company                    Yoga      4
#
#     Price                            Address        Lat       Lng  \
# 0      ££               44-46 St John Street  51.521301 -0.101313
# 1                    Sir Simon Milton Square  51.498034 -0.143856
# 2                            839 Fulham Road  51.474890 -0.206247
# 3      ££               11-13 Exmouth Market  51.525472 -0.110123
# 4      ££                     571 Kings Road  51.478810 -0.188010
# 5      ££                    130 Crouch Hill  51.577570 -0.123146
# 6      ££                 1 Redchurch Street  51.524321 -0.077135
# 7       £                     39 Warcick Way  51.492226 -0.140398
# 8      ££                             Unit 1  51.494117 -0.174468
# 9      ££                   44b Pimlico Road  51.490645 -0.153399
# 10     ££               175 Westbourne Grove  51.514646 -0.197799
# 11     ££           208-212 Westbourne Grove  51.514535 -0.200459
# 12      £                    64 Upper Street  51.535924 -0.103950
# 13      £                  23 Cromwell Place  51.494573 -0.174390
# 14                                        T5  51.481459 -0.444860
# 15     ££       32B Kensington Church Street  51.504055 -0.191941
# 16                              The Broadway  51.513378 -0.303897
# 17      £            16B-18A Pitfield Street  51.527144 -0.083562
# 18                        38 Chalk Farm Road  51.542848 -0.148307
# 19     ££                18 North Cross Road  51.457593 -0.072380
# 20     ££                   Brunswick Centre  51.524160 -0.123186
# 21     ££                      6 Bevis Marks  51.515048 -0.079347
# 22      £                    40 Mitcham Road  51.426840 -0.166792
# 23                          119 Dulwich Road  51.452873 -0.103490
# 24     ££                            Unit 6C  51.519873 -0.180046
# 25     ££                      2 Park Street  51.505538 -0.091462
# 26      £                35 Broadwick Street  51.513327 -0.136374
# 27                                 Whiteleys  51.514618 -0.188828
# 28     ££                     13 Neal's Yard  51.512425 -0.126364
# 29      £                    23-25 Queensway  51.510811 -0.187292
# ..    ...                                ...        ...       ...
# 131    ££                  2 Harrington Road  51.494282 -0.175695
# 132                          232a The Arcade  51.543088 -0.007199
# 133   £££                      3-9 Heddon St  51.510729 -0.139302
# 134     £                    52 Garratt Lane  51.455033 -0.193017
# 135    ££         23-24 Tottenham Court Road  51.517770 -0.131669
# 136    ££                 1 Kings Shade Walk  51.332982 -0.268401
# 137    ££              The Exchange Building  51.521140 -0.075220
# 138    ££               6-8 Blandford Street  51.518519 -0.151911
# 139    ££                  148-151 Queensway  51.514692 -0.188732
# 140   £££                30 St Peters Street  51.534594 -0.098711
# 141     £                100 St Martins Lane  51.510390 -0.127075
# 142     £            Unit B Leadenhall Court  51.513319 -0.083444
# 143     £                   176 Fleet Street  51.514170 -0.109391
# 144     £  167 Stoke Newington Church Street  51.561207 -0.082361
# 145     £                     39 Beak Street  51.512402 -0.137630
# 146     £                  36 Berwick Street  51.514610 -0.135584
# 147    ££                  33 Tothill Street  51.499569 -0.131861
# 148     £           68 Lamb's Conduit Street  51.522295 -0.118499
# 149    ££                45 Lexington Street  51.513023 -0.136485
# 150                       10 Mortimer Street  51.518605 -0.138087
# 151    ££                74 Westbourne Grove  51.515446 -0.192638
# 152    ££           147-149 Westbourne Grove  51.514761 -0.196069
# 153    ££                12-14 Heddon Street  51.511303 -0.139625
# 154                             11 Park Road  51.580689 -0.125000
# 155                      127-129 Ealing Road  51.545849 -0.297033
# 156     £             195 Chiswick High Road  51.492387 -0.257218
# 157    ££       286-290 Cambridge Heath Road  51.534228 -0.057191
# 158             286-290 Cambridge Heath Road  51.534170 -0.057243
# 159                         243 Baker Street  51.523888 -0.158546
# 160   £££                    The Glass House  51.474215 -0.204412
#
#                                                    url                      ID
# 0    https://www.yelp.com/biz/tinseltown-london-10?...  E_2AMpY_lSXcgRQTcTPj0Q
# 1
# 2
# 3    https://www.yelp.com/biz/caravan-london-3?adju...  Bc4GZfIUJu9363QQVACZVA
# 4    https://www.yelp.com/biz/megans-kings-road-res...  x7Z52Z5asB91V2l2sBLWWg
# 5    https://www.yelp.com/biz/the-blue-legume-londo...  Zu95anP0mIezAc6fvYTzmg
# 6    https://www.yelp.com/biz/andina-london?adjust_...  vCF8ut7OZcfA4hEmhngfSQ
# 7    https://www.yelp.com/biz/ddk-cafe-london?adjus...  FzMLjXcYXBs_msvKdREYRw
# 8    https://www.yelp.com/biz/muriels-kitchen-londo...  wm6Hwzan5qYhTzCDmO3oDQ
# 9    https://www.yelp.com/biz/daylesford-organic-lo...  4TU99yHlV6jNjZNwsiz1rA
# 10   https://www.yelp.com/biz/granger-and-co-london...  0r2-fwgLvuOLef0epiFkFQ
# 11   https://www.yelp.com/biz/daylesford-organic-lo...  b4H15rt8Y6tzHoSY7etpng
# 12   https://www.yelp.com/biz/bubbleology-london-7?...  SiYcTcmjZkogL6hhm4NY1g
# 13   https://www.yelp.com/biz/bubbleology-london-4?...  nOYtSW76HBkmqmI_mbfCVg
# 14
# 15   https://www.yelp.com/biz/blanche-eatery-london...  Zkuxlo1mzDp3MrkZTBiEJg
# 16
# 17   https://www.yelp.com/biz/cyclelab-and-juicebar...  6G6lvHO8c12MGFcdDbRhkA
# 18
# 19   https://www.yelp.com/biz/blue-mountain-london?...  xsZqlueXWeDZYkjIbM8Nkw
# 20   https://www.yelp.com/biz/crussh-juice-bars-lon...  PC5MyWEwUApF1sP-Uy76kQ
# 21   https://www.yelp.com/biz/the-alchemist-london-...  LpIY4AvlAQZqJEZgcFoFPA
# 22   https://www.yelp.com/biz/graveney-and-meadow-l...  XqzfqKCa5TPfPM0wsRY4Tg
# 23
# 24   https://www.yelp.com/biz/beany-green-london?ad...  za-KLljMB6yelgi2idCQPg
# 25   https://www.yelp.com/biz/monmouth-coffee-londo...  IWl1Y0eQOZSnYeIDw94svg
# 26   https://www.yelp.com/biz/veggie-pret-london-2?...  upCvvPPcD-pqG_KjyXKz8Q
# 27
# 28   https://www.yelp.com/biz/la-piazzetta-london?a...  JnFwWjHzQAD72XBtudW9gw
# 29   https://www.yelp.com/biz/kunduz-cafe-and-sandw...  m2x7O6w0HdRGBYc-Y12rXg
# ..                                                 ...                     ...
# 131  https://www.yelp.com/biz/apero-restaurant-and-...  7kBtTjr1SdEDESFiyan-Ag
# 132
# 133  https://www.yelp.com/biz/heddon-street-kitchen...  WHrXrCaBE3Uf3d-B5Wyh0g
# 134  https://www.yelp.com/biz/planet-organic-wandsw...  8NsK6JufpwaNlJPov5aOHg
# 135  https://www.yelp.com/biz/planet-organic-london...  iS23oWH7t98_W1I93KqcvA
# 136  https://www.yelp.com/biz/organico-epsom?adjust...  GFa_df3J5gxWd7815y9mUw
# 137  https://www.yelp.com/biz/as-nature-intended-lo...  h2GatYGNX-K2MAofMETM0A
# 138  https://www.yelp.com/biz/daylesford-farmhouse-...  66uNLSVxF-S9CeGE_olN6Q
# 139  https://www.yelp.com/biz/urban-social-london?a...  LRHSeC3QJh_ahSNCsviy8Q
# 140  https://www.yelp.com/biz/riverford-at-the-duke...  0ho6hvyjTUFmuKWpNuwzLA
# 141  https://www.yelp.com/biz/tossed-london?adjust_...  vGRmk3sjnCYwRKdqirjj7g
# 142  https://www.yelp.com/biz/tossed-london-15?adju...  PtxhCXU1KzE9-nUGIzOtsQ
# 143  https://www.yelp.com/biz/vital-ingredients-lon...  5ePr6dGjTU_LpaVDBbv4bw
# 144  https://www.yelp.com/biz/the-parlour-london-2?...  EIT9mzwf9IHM59TT8WOQkw
# 145  https://www.yelp.com/biz/pure-london-16?adjust...  6o2qrggYvfu91PhS4J-6Gg
# 146  https://www.yelp.com/biz/vital-ingredient-lond...  buzXH4MZL1sE2xkyLltLPw
# 147  https://www.yelp.com/biz/the-sanctuary-house-l...  46LI_quaSEdZgNiT_U_gyA
# 148  https://www.yelp.com/biz/tuttis-london?adjust_...  0KZ107VXX8qsbGjRNNuWzQ
# 149  https://www.yelp.com/biz/mildreds-london?adjus...  bXo_3uLhacyeGJ0iF743PQ
# 150
# 151  https://www.yelp.com/biz/farmacy-london?adjust...  ZTSM33QFv3pwxtSJp8Y02g
# 152  https://www.yelp.com/biz/jusu-brothers-london?...  IQpsCaCYOAZkKAJRcA-24Q
# 153  https://www.yelp.com/biz/tibits-london-3?adjus...  DnBY9gukSdy42EoJtBhdaQ
# 154
# 155
# 156  https://www.yelp.com/biz/ngon-london?adjust_cr...  CwQhljS__yTGSl3RYX17Uw
# 157  https://www.yelp.com/biz/the-hive-london-8?adj...  oLzNsjq9ohcNqEpUHP-6pQ
# 158
# 159
# 160  https://www.yelp.com/biz/the-power-yoga-compan...  0Po5pG8_WumGCbsujcZ_BA
#
# [161 rows x 9 columns]

# %%
# Save the dataframe to a csv file
london_restaurants_df.to_csv('Resources/London_Restaurants_JuiceBar.csv')
