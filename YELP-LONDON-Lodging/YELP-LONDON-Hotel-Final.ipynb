# %% [markdown]
# LONDON HOTELS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
lndh_params1 = {"term":"hotel","location":"London","limit":50,"offset":0}
lndh_response1 = requests.get(search_api_url, headers=headers, params=lndh_params1)
lndh1 = lndh_response1.json()
display(lndh1)
#print(lndh_response1.url)
#print(lndh_response1.status_code)
# Out:
# {'businesses': [{'id': 'eCS9km_3I4yQZ4x6dpFdCA',
#    'alias': 'the-hoxton-shoreditch-london',
#    'name': 'The Hoxton - Shoreditch',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/31zzg5cGjJSSAYA6YIQZCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hoxton-shoreditch-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 187,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5255813407725,
#     'longitude': -0.0828488618135452},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '81-83 Great Eastern Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 3HU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['81-83 Great Eastern Street',
#      'London EC2A 3HU',
#      'United Kingdom']},
#    'phone': '+442075501000',
#    'display_phone': '+44 20 7550 1000',
#    'distance': 3938.3819561853247},
#   {'id': 'ordoxmuOAuK0dRySXjvZ8Q',
#    'alias': 'london-marriott-hotel-park-lane-london',
#    'name': 'London Marriott Hotel Park Lane',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SGD3KFGrgDRe1b_nyLarDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/london-marriott-hotel-park-lane-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5130472305961,
#     'longitude': -0.157890279762221},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '140 Park Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 7AA',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ['140 Park Lane', 'London W1K 7AA', 'United Kingdom']},
#    'phone': '+442074937000',
#    'display_phone': '+44 20 7493 7000',
#    'distance': 1518.0639291398934},
#   {'id': '4bvjoUHcp5GEc61ZSDulEQ',
#    'alias': 'hotel-41-london',
#    'name': 'Hotel 41',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/srAS0oUOw8wtPZrEHQ0AlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-41-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.49822327, 'longitude': -0.14352472},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '41 Buckingham Palace Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 0PS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['41 Buckingham Palace Road',
#      'London SW1W 0PS',
#      'United Kingdom']},
#    'phone': '+442073000041',
#    'display_phone': '+44 20 7300 0041',
#    'distance': 1707.1685330948885},
#   {'id': 'iYn-qYHwQfjUABOr0E-K4g',
#    'alias': 'savoy-hotel-london',
#    'name': 'Savoy Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/h1H5X19mpy-Qk6bxv3DcDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/savoy-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 95,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.509711, 'longitude': -0.120045},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'Strand',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2R 0EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Strand', 'London WC2R 0EU', 'United Kingdom']},
#    'phone': '+442078364343',
#    'display_phone': '+44 20 7836 4343',
#    'distance': 1154.5931565177525},
#   {'id': 'ppPfg4JyTThWDpk0dIOaoQ',
#    'alias': 'the-ritz-london-london-2',
#    'name': 'The Ritz London',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FG5bio0jkfP8LuaLFXNq2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ritz-london-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 202,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5069729900444,
#     'longitude': -0.141605891449217},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '150 Piccadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 9BR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['150 Piccadilly', 'London W1J 9BR', 'United Kingdom']},
#    'phone': '+442074938181',
#    'display_phone': '+44 20 7493 8181',
#    'distance': 760.1610434141414},
#   {'id': 'w6xEsZey7lgaxR3uoKtyjw',
#    'alias': 'the-z-hotel-piccadilly-london',
#    'name': 'The Z Hotel Piccadilly',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1lRcqgJSWroWx2SuPaOoeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-z-hotel-piccadilly-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5089718, 'longitude': -0.1314339},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '2 Orange Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 7DF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Orange Street',
#      'London WC2H 7DF',
#      'United Kingdom']},
#    'phone': '+442035513720',
#    'display_phone': '+44 20 3551 3720',
#    'distance': 531.5126073285456},
#   {'id': '_VoSkSIb26RiAOW-bOxDHg',
#    'alias': 'kimpton-fitzroy-london-london',
#    'name': 'Kimpton Fitzroy London',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bUANHr2HFk1pU5HOwiaBbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kimpton-fitzroy-london-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5226349, 'longitude': -0.1249981},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1-8 Russell Square',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC1B 5BE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1-8 Russell Square',
#      'London WC1B 5BE',
#      'United Kingdom']},
#    'phone': '+442071235000',
#    'display_phone': '+44 20 7123 5000',
#    'distance': 1323.273264984322},
#   {'id': 'hGJkHYD10mPIh-R_xrUQNg',
#    'alias': 'the-kensington-hotel-london',
#    'name': 'The Kensington Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oir5rOUGDB_jrvp4_u1z6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-kensington-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.492559, 'longitude': -0.1780645},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "109 - 113 Queen's Gate",
#     'address2': '',
#     'address3': 'South Kensington',
#     'city': 'London',
#     'zip_code': 'SW7 5LR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["109 - 113 Queen's Gate",
#      'South Kensington',
#      'London SW7 5LR',
#      'United Kingdom']},
#    'phone': '+442075896300',
#    'display_phone': '+44 20 7589 6300',
#    'distance': 3684.881921445302},
#   {'id': '1tyiyRStaEuq_0hBc6ypCg',
#    'alias': 'citizenm-hotel-london-4',
#    'name': 'CitizenM Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/L3g_0J75dMDFPb9DUF-mgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/citizenm-hotel-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 79,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5051155599748,
#     'longitude': -0.098283347856649},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Lavington Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0NZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Lavington Street',
#      'London SE1 0NZ',
#      'United Kingdom']},
#    'phone': '+442035191680',
#    'display_phone': '+44 20 3519 1680',
#    'distance': 2744.8713574254475},
#   {'id': 'W_ZiOfiMZMMRONZD_LqpYA',
#    'alias': 'the-dorchester-london',
#    'name': 'The Dorchester',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r3YCmswQw5qgAmsupMfJUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dorchester-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 118,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.507302, 'longitude': -0.152594},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '53 Park Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 1QA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['53 Park Lane', 'London W1K 1QA', 'United Kingdom']},
#    'phone': '+442076298888',
#    'display_phone': '+44 20 7629 8888',
#    'distance': 1305.5359256580698},
#   {'id': 'tRMfDgUMJBC5vAjF1AvsWQ',
#    'alias': 'the-langham-london-london',
#    'name': 'The Langham London',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U9mpNhs9EjmAQhrXLoj0pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-langham-london-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 76,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5177971001259,
#     'longitude': -0.143983186883702},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '1C Portland Place',
#     'address2': 'Regent Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 1JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1C Portland Place',
#      'Regent Street',
#      'London W1B 1JA',
#      'United Kingdom']},
#    'phone': '+442076361000',
#    'display_phone': '+44 20 7636 1000',
#    'distance': 782.8941985806931},
#   {'id': 'SDKz9bB7hBmNbo2ibepQXw',
#    'alias': 'doubletree-by-hilton-hotel-london-hyde-park-london-3',
#    'name': 'DoubleTree by Hilton Hotel London - Hyde Park',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/n2jWRuujs5dkAWWwoE1KDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doubletree-by-hilton-hotel-london-hyde-park-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51009, 'longitude': -0.1903424},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '150 Bayswater Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 4RT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['150 Bayswater Road',
#      'London W2 4RT',
#      'United Kingdom']},
#    'phone': '+442072291212',
#    'display_phone': '+44 20 7229 1212',
#    'distance': 3776.0752100965406},
#   {'id': 'ZN2ugzPdTH-6CJ2eVozYSw',
#    'alias': 'claridges-london-2',
#    'name': "Claridge's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/H-NEABbzT-ekHIxN5DVaKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/claridges-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 107,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512611807224,
#     'longitude': -0.14789937950015},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'Brook Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 4HR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Brook Street', 'London W1K 4HR', 'United Kingdom']},
#    'phone': '+442076298860',
#    'display_phone': '+44 20 7629 8860',
#    'distance': 826.8819672104015},
#   {'id': 'gdKuHxKLv4mUjVYECsGypA',
#    'alias': 'the-landmark-london-london-2',
#    'name': 'The Landmark London',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cDo6xiPl-wx3tu5ctOCRzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-landmark-london-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 60,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.521462340704,
#     'longitude': -0.16263050427116},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '222 Marylebone Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 6JQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['222 Marylebone Road',
#      'London NW1 6JQ',
#      'United Kingdom']},
#    'phone': '+442076318000',
#    'display_phone': '+44 20 7631 8000',
#    'distance': 2080.1257971403284},
#   {'id': '0-uw5Y2_2UXyQR2Z2Lk1pA',
#    'alias': 'hotel-indigo-london-3',
#    'name': 'Hotel Indigo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/A_SLhZWtOS6BdTv131UADA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-indigo-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 33,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5151159, 'longitude': -0.17403},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '16 London Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 London Street',
#      'London W2 1HL',
#      'United Kingdom']},
#    'phone': '+442077064444',
#    'display_phone': '+44 20 7706 4444',
#    'distance': 2649.136068486688},
#   {'id': 'JgPmZ5n2bU71Xsg1Vq2Yzg',
#    'alias': 'the-london-edition-london',
#    'name': 'The London EDITION',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4BGGLpkmtQWyexbeHIHorw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-london-edition-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 44,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5165663165253,
#     'longitude': -0.136568941983944},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '10 Berners Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 3NP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Berners Street',
#      'London W1T 3NP',
#      'United Kingdom']},
#    'phone': '+442077810000',
#    'display_phone': '+44 20 7781 0000',
#    'distance': 417.0090075945117},
#   {'id': '79wQG7mK0fDppG6s59eIcQ',
#    'alias': 'the-fielding-london',
#    'name': 'The Fielding',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9jz49ymVlFVRpB3DkhKFFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-fielding-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5139067879982,
#     'longitude': -0.121998639525867},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 Broad Court',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5QZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Broad Court', 'London WC2B 5QZ', 'United Kingdom']},
#    'phone': '+442078368305',
#    'display_phone': '+44 20 7836 8305',
#    'distance': 973.1553098209641},
#   {'id': 'TKh-jjknmqz8DeoFXtZZBw',
#    'alias': 'conrad-london-st-james-london-2',
#    'name': 'Conrad London St. James',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/F9ZWaAPamtqRBRP8tyUbgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/conrad-london-st-james-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 67,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.499352, 'longitude': -0.132922},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '22 - 28 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1H 0BH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 - 28 Broadway',
#      'London SW1H 0BH',
#      'United Kingdom']},
#    'phone': '+442033018080',
#    'display_phone': '+44 20 3301 8080',
#    'distance': 1503.6586498247116},
#   {'id': 'DBkxwMryWb2zvhRSu7wmBg',
#    'alias': 'the-soho-hotel-london',
#    'name': 'The Soho Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FRDurJkTSiBsPgBSp_-72w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-soho-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 51,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.513944, 'longitude': -0.133896},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '4 Richmond Mews',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 3DH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Richmond Mews',
#      'London W1D 3DH',
#      'United Kingdom']},
#    'phone': '+442075593000',
#    'display_phone': '+44 20 7559 3000',
#    'distance': 199.49124012666655},
#   {'id': '4IUl4e0IdHm7C-tZzzPLhw',
#    'alias': 'crescent-hotel-london',
#    'name': 'Crescent Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hYu69FEjHVGE7Za9eq0DRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crescent-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5262838, 'longitude': -0.1270723},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '49-50 Cartwright Gardens',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 9EL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['49-50 Cartwright Gardens',
#      'London WC1H 9EL',
#      'United Kingdom']},
#    'phone': '+442073871515',
#    'display_phone': '+44 20 7387 1515',
#    'distance': 1622.1596355223194},
#   {'id': '5auFvoTZbS8TDxGdL7DPEg',
#    'alias': 'london-marriott-hotel-county-hall-london',
#    'name': 'London Marriott Hotel County Hall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/F9JnBrZop7Yv2M0J-2ccIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/london-marriott-hotel-county-hall-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 105,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5009824925665,
#     'longitude': -0.119301246332043},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'London County Hall Westminster Bridge Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7PB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['London County Hall Westminster Bridge Road',
#      'London SE1 7PB',
#      'United Kingdom']},
#    'phone': '+442079285200',
#    'display_phone': '+44 20 7928 5200',
#    'distance': 1750.9248885230056},
#   {'id': 'tGEMzAQwVsKkBOBavvaskA',
#    'alias': 'afternoon-tea-at-the-montague-on-the-gardens-london-9',
#    'name': 'Afternoon Tea at The Montague on The Gardens',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DRgDgQWnNM_s178IUU3bLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/afternoon-tea-at-the-montague-on-the-gardens-london-9?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 56,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.52014261, 'longitude': -0.12558305},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '15 Montague st',
#     'address2': 'Bloomsbury',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 5BJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Montague st',
#      'Bloomsbury',
#      'London WC1B 5BJ',
#      'United Kingdom']},
#    'phone': '+442076371001',
#    'display_phone': '+44 20 7637 1001',
#    'distance': 1084.1279399704836},
#   {'id': '9gfxX1sAq2j83cSiGQAVlA',
#    'alias': 'ham-yard-hotel-london',
#    'name': 'Ham Yard Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XNmQ3TBD9sa1KjQS78_qdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ham-yard-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5111504, 'longitude': -0.1344988},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'One Ham Yard',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 7DT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['One Ham Yard', 'London W1D 7DT', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 192.12803891707816},
#   {'id': 'MXXkkGldpE0afT_moqaUnQ',
#    'alias': 'st-pancras-renaissance-hotel-london-london-2',
#    'name': 'St. Pancras Renaissance Hotel London',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QmSY8nswPEdf1l-8U7N7YA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-pancras-renaissance-hotel-london-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 80,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.529852, 'longitude': -0.12581},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Euston Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 2AR',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ['Euston Road', 'London NW1 2AR', 'United Kingdom']},
#    'phone': '+442078413540',
#    'display_phone': '+44 20 7841 3540',
#    'distance': 2018.1595779936297},
#   {'id': '62JNxqo1Rs9Q8UMT29v0vQ',
#    'alias': 'corinthia-hotel-london-london-2',
#    'name': 'Corinthia Hotel London',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uxWwGjUvYWf-zye_IHtGsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/corinthia-hotel-london-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5065361584961,
#     'longitude': -0.124341458197023},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'Whitehall Place',
#     'address2': 'London',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1A 2BD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Whitehall Place',
#      'London',
#      'London SW1A 2BD',
#      'United Kingdom']},
#    'phone': '+442079308181',
#    'display_phone': '+44 20 7930 8181',
#    'distance': 1066.1613817565785},
#   {'id': 'mcKkDc_xxFVGizFRgPPpxg',
#    'alias': 'jw-marriott-grosvenor-house-london-london',
#    'name': 'JW Marriott Grosvenor House London',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/h0rtaB33kjUizgDMPK1u8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jw-marriott-grosvenor-house-london-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 109,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.509738, 'longitude': -0.154891},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '86-90 Park Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 7TN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['86-90 Park Lane',
#      'London W1K 7TN',
#      'United Kingdom']},
#    'phone': '+442074996363',
#    'display_phone': '+44 20 7499 6363',
#    'distance': 1354.8866048022835},
#   {'id': 'IAMW4pZ_djhszqIGsSZhIw',
#    'alias': 'the-lanesborough-london-2',
#    'name': 'The Lanesborough',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6ycS6JsndWsCbjZDIv_SyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lanesborough-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.502441, 'longitude': -0.152723},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'The Lanesborough',
#     'address2': 'Lanesborough Place',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7TA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Lanesborough',
#      'Lanesborough Place',
#      'London SW1X 7TA',
#      'United Kingdom']},
#    'phone': '+442072595599',
#    'display_phone': '+44 20 7259 5599',
#    'distance': 1637.841910161753},
#   {'id': 'cPPCVTT_v0p5AcT4B3A82w',
#    'alias': 'shangri-la-hotel-london',
#    'name': 'Shangri La Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qsloBgtl1F0t5c7FWLCLeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shangri-la-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5052532, 'longitude': -0.0869875},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'At The Shard',
#     'address2': '31 St Thomas Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9QU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['At The Shard',
#      '31 St Thomas Street',
#      'London SE1 9QU',
#      'United Kingdom']},
#    'phone': '+442072348000',
#    'display_phone': '+44 20 7234 8000',
#    'distance': 3492.235471085661},
#   {'id': '9LyJ5oa_dOFwbc0iG-i76A',
#    'alias': 'four-seasons-hotel-london-4',
#    'name': 'Four Seasons Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GZ30RdS9mn7quvLHMf5fJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/four-seasons-hotel-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5044391859339,
#     'longitude': -0.149880248341834},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'Hamilton Place',
#     'address2': 'Park Lane',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 7DR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Hamilton Place',
#      'Park Lane',
#      'London W1J 7DR',
#      'United Kingdom']},
#    'phone': '+442074990888',
#    'display_phone': '+44 20 7499 0888',
#    'distance': 1341.7627395675609},
#   {'id': 'zRWecrLR6rjSkEkxoCvyCA',
#    'alias': 'the-ampersand-hotel-london',
#    'name': 'The Ampersand Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/X55BRuZvbFG5y31Rx8fqHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ampersand-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4943093699229, 'longitude': -0.1755579},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '10 Harrington Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Harrington Road',
#      'London SW7 3ER',
#      'United Kingdom']},
#    'phone': '+442075895895',
#    'display_phone': '+44 20 7589 5895',
#    'distance': 3428.8544642715888},
#   {'id': 'KFTpdt_xnhv6dojj6bk2yg',
#    'alias': 'andaz-london-liverpool-street-london-2',
#    'name': 'Andaz London Liverpool Street',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RgVwKCy6LYa97fU4dKPLMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/andaz-london-liverpool-street-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 88,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5172135, 'longitude': -0.0813499},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '40 Liverpool Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2M 7QN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 Liverpool Street',
#      'London EC2M 7QN',
#      'United Kingdom']},
#    'phone': '+442079611234',
#    'display_phone': '+44 20 7961 1234',
#    'distance': 3839.15035454053},
#   {'id': '_pEVqH_WQ6zRu2iry9vPvw',
#    'alias': 'mercure-london-hyde-park-hotel-london',
#    'name': 'Mercure London Hyde Park Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Orx46ys6h5KUgb3UbGx_Ug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mercure-london-hyde-park-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5150334, 'longitude': -0.1742911},
#    'transactions': [],
#    'location': {'address1': '8 - 14 Talbot Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1TS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 - 14 Talbot Square',
#      'London W2 1TS',
#      'United Kingdom']},
#    'phone': '+442078352000',
#    'display_phone': '+44 20 7835 2000',
#    'distance': 2664.0061818208806},
#   {'id': 'wDe0JaxHJSKoQPwj1pyjxg',
#    'alias': 'haymarket-hotel-london',
#    'name': 'Haymarket Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0PhfHVNqMg2ML1UhI8V6pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/haymarket-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5080197, 'longitude': -0.1311541},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '1 Suffolk Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 4HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Suffolk Place',
#      'London SW1Y 4HX',
#      'United Kingdom']},
#    'phone': '+442074704000',
#    'display_phone': '+44 20 7470 4000',
#    'distance': 610.6760244392212},
#   {'id': 'vRTIg2OnEFhWcSc0TXNMVg',
#    'alias': 'mandarin-oriental-london-2',
#    'name': 'Mandarin Oriental',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1nzaqCNxvDMOcYL6KYEbDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mandarin-oriental-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.502252452438,
#     'longitude': -0.160007139695516},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '66 Knightsbridge',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['66 Knightsbridge',
#      'London SW1X 7LA',
#      'United Kingdom']},
#    'phone': '+442072352000',
#    'display_phone': '+44 20 7235 2000',
#    'distance': 2038.5286836569614},
#   {'id': 'ngHlIGlEEK89MrE-TgWIMg',
#    'alias': '69thegrove-london',
#    'name': '69TheGrove',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hpr-AZA4oMNVeVI65o7UBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/69thegrove-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4848899841309,
#     'longitude': -0.120852999389172},
#    'transactions': [],
#    'location': {'address1': '69 Vauxhall Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW8 1TA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['69 Vauxhall Grove',
#      'London SW8 1TA',
#      'United Kingdom']},
#    'phone': '+447796874677',
#    'display_phone': '+44 7796 874677',
#    'distance': 3278.549689922597},
#   {'id': 'PG68a_fQyWH5JlyfLLs09g',
#    'alias': 'w-london-leicester-square-london',
#    'name': 'W London- Leicester Square',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1p3MzocsEDdkNI0vy2khBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/w-london-leicester-square-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 110,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.510782643006,
#     'longitude': -0.13138019123122},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '10 Wardour Street',
#     'address2': 'Leicester Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6QF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Wardour Street',
#      'Leicester Square',
#      'London W1D 6QF',
#      'United Kingdom']},
#    'phone': '+442077581000',
#    'display_phone': '+44 20 7758 1000',
#    'distance': 390.3465030328613},
#   {'id': 'RshDXZKYqY6-ru8dzqpm_g',
#    'alias': 'the-bloomsbury-hotel-london',
#    'name': 'The Bloomsbury Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Cdo8Uq_vv-KwnsPgYy98MA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bloomsbury-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5171420898507,
#     'longitude': -0.1290839910507},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '16-22 Great Russell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3NN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16-22 Great Russell Street',
#      'London WC1B 3NN',
#      'United Kingdom']},
#    'phone': '+442073471000',
#    'display_phone': '+44 20 7347 1000',
#    'distance': 674.8539001940776},
#   {'id': 'HBlUZe6f1y6BGTbA07wb2A',
#    'alias': 'hub-premier-inn-london',
#    'name': 'Hub Premier Inn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0La7vI7s7QahfiN3pphOtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hub-premier-inn-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4989475320884,
#     'longitude': -0.132892395235955},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '15 Dacre Street',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1H 0DJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Dacre Street',
#      'London SW1H 0DJ',
#      'United Kingdom']},
#    'phone': '+448715279608',
#    'display_phone': '+44 871 527 9608',
#    'distance': 1558.7593132415643},
#   {'id': 'mdw5yHXAGhvFtdxAj2EfcQ',
#    'alias': 'lse-high-holborn-residence-london',
#    'name': 'LSE High Holborn Residence',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/opIrMpx-MOXzgZkpgz-9mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lse-high-holborn-residence-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515647, 'longitude': -0.124927},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '178 High Holborn',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1V 7AA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['178 High Holborn',
#      'London WC1V 7AA',
#      'United Kingdom']},
#    'phone': '+442071075737',
#    'display_phone': '+44 20 7107 5737',
#    'distance': 824.7279262587622},
#   {'id': 'bq4MyM1GISMEE2JJA8LP1g',
#    'alias': 'limetree-hotel-london',
#    'name': 'Limetree Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ICLz-j-Z1wnP27gt1g1yWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/limetree-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4932719, 'longitude': -0.1500756},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '135-137 Ebury Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 9QU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['135-137 Ebury Street',
#      'London SW1W 9QU',
#      'United Kingdom']},
#    'phone': '+442077308191',
#    'display_phone': '+44 20 7730 8191',
#    'distance': 2372.5306356741517},
#   {'id': 'Fzl_brSsiw5IBnFU2o75lQ',
#    'alias': 'sofitel-london-3',
#    'name': 'Sofitel ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Z3fqJy0rH5bmZY-jz2MTUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sofitel-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 50,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.507572834636,
#     'longitude': -0.13251408519246},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '6 Waterloo Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 4AN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Waterloo Place',
#      'London SW1Y 4AN',
#      'United Kingdom']},
#    'phone': '+442077472202',
#    'display_phone': '+44 20 7747 2202',
#    'distance': 631.800076177935},
#   {'id': 'ol-qloaIQ1D8L75sx88G2A',
#    'alias': 'the-connaught-london-2',
#    'name': 'The Connaught',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UmsyBIZjxs3mL9ehKJWaOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-connaught-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5101556, 'longitude': -0.1496314},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'Carlos Place',
#     'address2': 'Mayfair',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 2AL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Carlos Place',
#      'Mayfair',
#      'London W1K 2AL',
#      'United Kingdom']},
#    'phone': '+442074997070',
#    'display_phone': '+44 20 7499 7070',
#    'distance': 992.1974132195033},
#   {'id': 'KN0BfGqqX0gJ0wWovgtKNw',
#    'alias': 'bulgari-hotel-london-london-2',
#    'name': 'Bulgari Hotel - London',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HG5eF54QSna6jvQUyOoIWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bulgari-hotel-london-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.501536, 'longitude': -0.162789},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '171 Knightsbridge',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 1DW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['171 Knightsbridge',
#      'London SW7 1DW',
#      'United Kingdom']},
#    'phone': '+442071511010',
#    'display_phone': '+44 20 7151 1010',
#    'distance': 2242.2138560980898},
#   {'id': 'LNDsn8gxFFiLMHTLo82pQA',
#    'alias': 'st-ermins-hotel-autograph-collection-london',
#    'name': "St. Ermin's Hotel, Autograph Collection",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WjVwtQdpF__QCBatOh2e5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-ermins-hotel-autograph-collection-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 123,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4989304968664,
#     'longitude': -0.133800663215879},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '2 Caxton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1H 0QW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Caxton Street',
#      'London SW1H 0QW',
#      'United Kingdom']},
#    'phone': '+442072227888',
#    'display_phone': '+44 20 7222 7888',
#    'distance': 1553.3446630750361},
#   {'id': 'eTCvZLGW3iMICir0fkfShQ',
#    'alias': 'mile-end-hotel-london',
#    'name': 'Mile End Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/63YkCLuX1nsbePtrcJ23dg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mile-end-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5266128, 'longitude': -0.036171},
#    'transactions': [],
#    'location': {'address1': '51 Grove Road',
#     'address2': 'Mile End',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'E3 4PE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Grove Road',
#      'Mile End',
#      'London E3 4PE',
#      'United Kingdom']},
#    'phone': '+442089816614',
#    'display_phone': '+44 20 8981 6614',
#    'distance': 7072.07476371859},
#   {'id': '_EaXEfvYjQWpt5BtqXbV9g',
#    'alias': 'the-kensington-gardens-hotel-london',
#    'name': 'The Kensington Gardens Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HS-aP9NwTkDw1tVQAPS7nA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-kensington-gardens-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5133583, 'longitude': -0.1900571},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '9 Kensington Gardens Square',
#     'address2': 'Bayswater',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 4BH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Kensington Gardens Square',
#      'Bayswater',
#      'London W2 4BH',
#      'United Kingdom']},
#    'phone': '+442072217790',
#    'display_phone': '+44 20 7221 7790',
#    'distance': 3744.2874028855595},
#   {'id': 'PtXvUxXU-On_hNJ_u6QMZw',
#    'alias': 'henrietta-london',
#    'name': 'Henrietta',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tS0hTc180_VoVjjl-X0_2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/henrietta-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5110531, 'longitude': -0.1234376},
#    'transactions': [],
#    'location': {'address1': '14-15 Henrietta St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2E 8QH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14-15 Henrietta St',
#      'London WC2E 8QH',
#      'United Kingdom']},
#    'phone': '+442037945314',
#    'display_phone': '+44 20 3794 5314',
#    'distance': 869.3605835049359},
#   {'id': 'kY5bMnQ16IxEp7oWQJDg3Q',
#    'alias': 'hazlitts-hotels-london',
#    'name': 'Hazlitts Hotels',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AkMcsmnTQr_YiBngDp2mmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hazlitts-hotels-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5143751616248,
#     'longitude': -0.131922345785483},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '6 Frith Street',
#     'address2': 'Soho Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 3JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Frith Street',
#      'Soho Square',
#      'London W1D 3JA',
#      'United Kingdom']},
#    'phone': '+442074341771',
#    'display_phone': '+44 20 7434 1771',
#    'distance': 327.4361588283478},
#   {'id': 'dds7MeCuHTxa5ikuuqoYQg',
#    'alias': 'the-ned-london',
#    'name': 'The Ned',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QCqpgaRKxRkUy4yqAwn3YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ned-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 31,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5138261953983,
#     'longitude': -0.0899183012754747},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '27 Poultry',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2R 8AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['27 Poultry', 'London EC2R 8AJ', 'United Kingdom']},
#    'phone': '+442038282000',
#    'display_phone': '+44 20 3828 2000',
#    'distance': 3187.706132165589},
#   {'id': 'SjGYpd_bzEYDW9PkMzvE_g',
#    'alias': 'st-martins-lane-hotel-london-2',
#    'name': 'St Martins Lane Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0a79nLS0XBwxxBx_rIDU3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-martins-lane-hotel-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 75,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.510378, 'longitude': -0.1268051},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "45 St Martin's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["45 St Martin's Lane",
#      'London WC2N 4HX',
#      'United Kingdom']},
#    'phone': '+442073005500',
#    'display_phone': '+44 20 7300 5500',
#    'distance': 693.2787271841788}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndh1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Lodging": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                            Lodging    Type Price Rating  \
# 0          The Hoxton - Shoreditch  Hotels    ££    4.5
# 1  London Marriott Hotel Park Lane  Hotels   £££    4.5
# 2                         Hotel 41  Hotels  ££££      5
# 3                      Savoy Hotel  Hotels  ££££    4.5
# 4                  The Ritz London  Hotels  ££££      4
#
#                       Address        Lat       Lng  \
# 0  81-83 Great Eastern Street  51.525581 -0.082849
# 1               140 Park Lane  51.513047 -0.157890
# 2   41 Buckingham Palace Road  51.498223 -0.143525
# 3                      Strand  51.509711 -0.120045
# 4              150 Piccadilly  51.506973 -0.141606
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/the-hoxton-shoreditch...  eCS9km_3I4yQZ4x6dpFdCA
# 1  https://www.yelp.com/biz/london-marriott-hotel...  ordoxmuOAuK0dRySXjvZ8Q
# 2  https://www.yelp.com/biz/hotel-41-london?adjus...  4bvjoUHcp5GEc61ZSDulEQ
# 3  https://www.yelp.com/biz/savoy-hotel-london?ad...  iYn-qYHwQfjUABOr0E-K4g
# 4  https://www.yelp.com/biz/the-ritz-london-londo...  ppPfg4JyTThWDpk0dIOaoQ

# %%
#2nd set of 50 records 51-100 
lndh_params2 = {"term":"hotel","location":"London","limit":50,"offset":51}
lndh_response2 = requests.get(search_api_url, headers=headers, params=lndh_params2)
lndh2 = lndh_response2.json()
display(lndh2)
#print(lndh_response2.url)
#print(lndh_response2.status_code)
# Out:
# {'businesses': [{'id': 'xqGynJcWIF6-jl9i69phOw',
#    'alias': 'harlingford-hotel-london',
#    'name': 'Harlingford Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1b8WrsP1RLA4k4VgbpDUgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harlingford-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5260951, 'longitude': -0.1261868},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61-63 Cartwright Gardens',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 9EL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61-63 Cartwright Gardens',
#      'London WC1H 9EL',
#      'United Kingdom']},
#    'phone': '+442073871551',
#    'display_phone': '+44 20 7387 1551',
#    'distance': 1628.788296777725},
#   {'id': 'UDSI_z1-edmeNtg3YOy-SQ',
#    'alias': 'rosewood-london-london',
#    'name': 'Rosewood London',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eTF_N_n5yl28rUGY4LJlEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rosewood-london-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5174224898076,
#     'longitude': -0.117810666561127},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '252 High Holborn',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1V 7EN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['252 High Holborn',
#      'London WC1V 7EN',
#      'United Kingdom']},
#    'phone': '+442077818888',
#    'display_phone': '+44 20 7781 8888',
#    'distance': 1355.2386649179412},
#   {'id': '_jFVWny91oy62o5uNIvSSw',
#    'alias': 'st-davids-hotels-london',
#    'name': "St David's Hotels",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zoncWdBN6-UQEjSSaIw38g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-davids-hotels-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.516004, 'longitude': -0.173908},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14-20 Norfolk Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1RS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14-20 Norfolk Square',
#      'London W2 1RS',
#      'United Kingdom']},
#    'phone': '+442077234963',
#    'display_phone': '+44 20 7723 4963',
#    'distance': 2645.1935860717804},
#   {'id': 'bqqtUZG_6913SWAMd597Ug',
#    'alias': 'radisson-blu-edwardian-hampshire-london-2',
#    'name': 'Radisson Blu Edwardian Hampshire',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/COlRhfr6qJRFs0eqlPdP0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/radisson-blu-edwardian-hampshire-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5098477563198,
#     'longitude': -0.129852334579805},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '31-36 Liecester Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 7LH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['31-36 Liecester Square',
#      'London WC2H 7LH',
#      'United Kingdom']},
#    'phone': '+442078399399',
#    'display_phone': '+44 20 7839 9399',
#    'distance': 537.3802006127233},
#   {'id': 'jRduIw5aVQ8fO00Ta3wU8g',
#    'alias': 'plaza-on-the-river-hotel-london',
#    'name': 'Plaza On the River Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8c-4WJpI4DLDk6TFV6V_vw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/plaza-on-the-river-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5002, 'longitude': -0.126236},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': None,
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1P 3JX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['London SW1P 3JX', 'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1557.7482685360876},
#   {'id': 'jRaxuGSxXeqO4KSpPyvLBA',
#    'alias': 'holiday-inn-london-camden-lock-london',
#    'name': 'Holiday Inn London Camden Lock',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-78NyHvZC-BMHuvI0wWGlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holiday-inn-london-camden-lock-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.540294818363,
#     'longitude': -0.14585854209414},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '30 Jamestown Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 7BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Jamestown Road',
#      'London NW1 7BY',
#      'United Kingdom']},
#    'phone': '+442074854343',
#    'display_phone': '+44 20 7485 4343',
#    'distance': 3129.2417282296037},
#   {'id': 'wuYwGXyR6RFqpFsE-28Fmg',
#    'alias': 'the-nadler-kensington-london-2',
#    'name': 'The Nadler Kensington',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Qy3gwcchwWv2NN5AeJoHtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-nadler-kensington-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4930313, 'longitude': -0.1901229},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '25 Courtfield Gardens',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 0PG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['25 Courtfield Gardens',
#      'London SW5 0PG',
#      'United Kingdom']},
#    'phone': '+442072442255',
#    'display_phone': '+44 20 7244 2255',
#    'distance': 4350.722704690604},
#   {'id': 'z3nQWuGTiVqy4tbU13ab7A',
#    'alias': 'the-california-london',
#    'name': 'The California',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DF5knTUz3UOXUg7wHzhPWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-california-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5295197473846,
#     'longitude': -0.123414203302367},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '4-8 Belgrove Street',
#     'address2': 'St Pancras',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 8AB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4-8 Belgrove Street',
#      'St Pancras',
#      'London WC1H 8AB',
#      'United Kingdom']},
#    'phone': '+442078377629',
#    'display_phone': '+44 20 7837 7629',
#    'distance': 2048.1021004106024},
#   {'id': 'SXUptNI-yemUbrImbl66Ow',
#    'alias': 'the-stafford-london-london',
#    'name': 'The Stafford London',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iO4PxGZbWSFpRw7Sdxfprw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-stafford-london-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.505918, 'longitude': -0.140391},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': "16-18 St James's Place",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1A 1NJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["16-18 St James's Place",
#      'London SW1A 1NJ',
#      'United Kingdom']},
#    'phone': '+442074930111',
#    'display_phone': '+44 20 7493 0111',
#    'distance': 843.9198077728366},
#   {'id': 'jtbgfUOhppBTZCLIpgK0bA',
#    'alias': 'the-hoxton-holborn-london',
#    'name': 'The Hoxton, Holborn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/u9d9apux5Ct-1MhqCiOv-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hoxton-holborn-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5172396196256,
#     'longitude': -0.122062552720325},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '199 - 206 High Holborn',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1V 7BD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['199 - 206 High Holborn',
#      'London WC1V 7BD',
#      'United Kingdom']},
#    'phone': '+442076613000',
#    'display_phone': '+44 20 7661 3000',
#    'distance': 1078.9203210299913},
#   {'id': 'h2XKxrNNxLk00AAe7GSUWA',
#    'alias': 'premier-inn-london-24',
#    'name': 'Premier Inn',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EBZMLxw-a1L6H3scvEWvrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/premier-inn-london-24?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5194945, 'longitude': -0.116961},
#    'transactions': [],
#    'location': {'address1': '27-29 Red Lion Street',
#     'address2': 'Holborn',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1R 4PS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['27-29 Red Lion Street',
#      'Holborn',
#      'London WC1R 4PS',
#      'United Kingdom']},
#    'phone': '+448715279496',
#    'display_phone': '+44 871 527 9496',
#    'distance': 1526.0475331812497},
#   {'id': 'dZc5d459tdpI9wk9cx4cIQ',
#    'alias': 'great-scotland-yard-hotel-london',
#    'name': 'Great Scotland Yard Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y_RuBmh1j6pId5D0YsZwZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/great-scotland-yard-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5062952700701,
#     'longitude': -0.12628510594368},
#    'transactions': [],
#    'location': {'address1': '3-5 Great Scotland Yard',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1A 2HN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3-5 Great Scotland Yard',
#      'London SW1A 2HN',
#      'United Kingdom']},
#    'phone': '+442079254700',
#    'display_phone': '+44 20 7925 4700',
#    'distance': 988.3331645522871},
#   {'id': 'ANEIyj70aOKVsEd6DU40Sg',
#    'alias': 'london-marriott-hotel-regents-park-london',
#    'name': 'London Marriott Hotel Regents Park',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NYCJoPZ4x740p-HqNF-Eug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/london-marriott-hotel-regents-park-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5420479728882,
#     'longitude': -0.17014765889553},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "128 King Henry's Road",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 3ST',
#     'country': 'GB',
#     'state': 'ABE',
#     'display_address': ["128 King Henry's Road",
#      'London NW3 3ST',
#      'United Kingdom']},
#    'phone': '+442077227711',
#    'display_phone': '+44 20 7722 7711',
#    'distance': 4018.2266970137734},
#   {'id': 'uZ7itHFaLK1tYm8WP0hLqA',
#    'alias': 'park-plaza-westminster-bridge-london-london-4',
#    'name': 'Park Plaza Westminster Bridge London',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U3joHSng2syiUxGx12g8mg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/park-plaza-westminster-bridge-london-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 136,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.500945128618,
#     'longitude': -0.116817394584042},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '200 Westminster Bridge Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7UT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['200 Westminster Bridge Road',
#      'London SE1 7UT',
#      'United Kingdom']},
#    'phone': '+448444156790',
#    'display_phone': '+44 844 415 6790',
#    'distance': 1871.513179372403},
#   {'id': 'vVlTW6ylANoAEmTttU2Y4A',
#    'alias': 'amba-hotel-charing-cross-london',
#    'name': 'Amba Hotel Charing Cross',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yYRNDZFZ6ScILkaM0XEQWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amba-hotel-charing-cross-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 36,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.508459, 'longitude': -0.124932},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'The Strand',
#     'address2': 'Charing Cross',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 5HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['The Strand',
#      'Charing Cross',
#      'London WC2N 5HX',
#      'United Kingdom']},
#    'phone': '+442077478410',
#    'display_phone': '+44 20 7747 8410',
#    'distance': 904.8935329348292},
#   {'id': 'AIssXkThJSw4Y2gSGUwbSQ',
#    'alias': 'the-shaftesbury-london-3',
#    'name': 'The Shaftesbury',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vvjMAfAY0TdqiFvUDaKIhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-shaftesbury-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'},
#     {'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5118239, 'longitude': -0.132904},
#    'transactions': [],
#    'location': {'address1': '39-45 Shaftesbury Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 6LA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39-45 Shaftesbury Avenue',
#      'London W1D 6LA',
#      'United Kingdom']},
#    'phone': '+442072878064',
#    'display_phone': '+44 20 7287 8064',
#    'distance': 239.27954648471407},
#   {'id': 'UC6Rwig5kN_0wpFG0T9mTg',
#    'alias': 'the-nadler-soho-london',
#    'name': 'The Nadler Soho',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Cnq7aQqdmZpF4PFL3Ml3zA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-nadler-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5147387, 'longitude': -0.1341108},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '10 Carlisle Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 3BR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Carlisle Street',
#      'London W1D 3BR',
#      'United Kingdom']},
#    'phone': '+442036973697',
#    'display_phone': '+44 20 3697 3697',
#    'distance': 247.15404778863302},
#   {'id': 'n5qSC3ssty-SFuI7CcFbBw',
#    'alias': 'hotel-chocolat-london-19',
#    'name': 'Hotel Chocolat',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YM7MtPXMhGRv8G7kaBfMyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-chocolat-london-19?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 56,
#    'categories': [{'alias': 'chocolate', 'title': 'Chocolatiers & Shops'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5147637621008,
#     'longitude': -0.126961926387449},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '4 Monmouth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9HB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Monmouth Street',
#      'London WC2H 9HB',
#      'United Kingdom']},
#    'phone': '+442072090659',
#    'display_phone': '+44 20 7209 0659',
#    'distance': 658.2691709867701},
#   {'id': '0mAnAZuRvYQEXffLRcLCzg',
#    'alias': 'st-jamess-st-jamess',
#    'name': "St. James's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_iqbn8fPCAv3CSugM4PZvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-jamess-st-jamess?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.506115, 'longitude': -0.140311},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '7-8 Park Place',
#     'address2': '',
#     'address3': '',
#     'city': "St James's",
#     'zip_code': 'SW1A 1LS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7-8 Park Place',
#      "St James's SW1A 1LS",
#      'United Kingdom']},
#    'phone': '+442073161600',
#    'display_phone': '+44 20 7316 1600',
#    'distance': 800.4797734578315},
#   {'id': 'h65olqVVtg_E3BlkVdh2jg',
#    'alias': 'strand-palace-london-2',
#    'name': 'Strand Palace',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/z1wJB-WEmTNPrAonMw4lWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/strand-palace-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 99,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.511099, 'longitude': -0.12071},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '372 Strand',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2R 0JJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['372 Strand', 'London WC2R 0JJ', 'United Kingdom']},
#    'phone': '+442073794737',
#    'display_phone': '+44 20 7379 4737',
#    'distance': 1067.858299923233},
#   {'id': 'qT3_PDPveYLjDJUuc94iUw',
#    'alias': 'doubletree-by-hilton-hotel-london-tower-of-london-london-3',
#    'name': 'DoubleTree by Hilton Hotel London - Tower of London',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/N3g_5Td3OWfkQM_d3lxJZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doubletree-by-hilton-hotel-london-tower-of-london-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 72,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5109056055575,
#     'longitude': -0.0782793035577134},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '7 Pepys Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3N 4AF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Pepys Street',
#      'London EC3N 4AF',
#      'United Kingdom']},
#    'phone': '+442077091000',
#    'display_phone': '+44 20 7709 1000',
#    'distance': 3997.115176347679},
#   {'id': '_H9UZT4HOO2vVQ-Fq_767A',
#    'alias': 'de-vere-grand-connaught-rooms-london',
#    'name': 'De Vere Grand Connaught Rooms',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zXbELN7qxRUmnizO5HqkRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/de-vere-grand-connaught-rooms-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5155551848791,
#     'longitude': -0.120639991795868},
#    'transactions': [],
#    'location': {'address1': '61-65 Great Queen Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61-65 Great Queen Street',
#      'London WC2B 5DA',
#      'United Kingdom']},
#    'phone': '+442074057811',
#    'display_phone': '+44 20 7405 7811',
#    'distance': 1102.1375671300616},
#   {'id': '5VQzRhyilXNDPL4FuVouxw',
#    'alias': 'hyatt-regency-london-the-churchill-london',
#    'name': 'Hyatt Regency London - The Churchill',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rYDYOl4iFztV4yXUnUYPGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hyatt-regency-london-the-churchill-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 70,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5154357, 'longitude': -0.1569583},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '30 Portman Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7BH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Portman Square',
#      'London W1H 7BH',
#      'United Kingdom']},
#    'phone': '+442074865800',
#    'display_phone': '+44 20 7486 5800',
#    'distance': 1497.0881132274078},
#   {'id': 'ACZzwkEWIKXg0MMjDr8LiQ',
#    'alias': 'the-berkeley-london',
#    'name': 'The Berkeley',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iwkHEuQN8QbipBgOVoUTpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-berkeley-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5019068266959,
#     'longitude': -0.156179445368934},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'Wilton Place',
#     'address2': 'Knightsbridge',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Wilton Place',
#      'Knightsbridge',
#      'London SW1X 7RL',
#      'United Kingdom']},
#    'phone': '+442072356000',
#    'display_phone': '+44 20 7235 6000',
#    'distance': 1853.5904250569788},
#   {'id': 'zfBM08Y_1DqFccBfwsdmMw',
#    'alias': 'hilton-london-bankside-london',
#    'name': 'Hilton London Bankside',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m9U1SPangIs9eNDPI2HGAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hilton-london-bankside-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.505734121605,
#     'longitude': -0.101752281188965},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '2-8 Great Suffolk Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0UG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2-8 Great Suffolk Street',
#      'London SE1 0UG',
#      'United Kingdom']},
#    'phone': '+442036675600',
#    'display_phone': '+44 20 3667 5600',
#    'distance': 2495.3333580679882},
#   {'id': 'vJRRJ0oPJI45P4vHidKMBQ',
#    'alias': 'haverstock-hotel-london',
#    'name': 'Haverstock Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ftUdLzGVo6GpYlah2sbrlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/haverstock-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5490438, 'longitude': -0.1619664},
#    'transactions': [],
#    'location': {'address1': '154 Haverstock Hill',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 2AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['154 Haverstock Hill',
#      'London NW3 2AY',
#      'United Kingdom']},
#    'phone': '+442077225097',
#    'display_phone': '+44 20 7722 5097',
#    'distance': 4413.373007510521},
#   {'id': '3KYZAtAgFqjIESnPGBt2Jw',
#    'alias': 'royal-park-hotel-london',
#    'name': 'Royal Park Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4scPAD0PCmfkYPr83irKfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/royal-park-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5140501, 'longitude': -0.1765312},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '3 Westbourne Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3UL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Westbourne Terrace',
#      'London W2 3UL',
#      'United Kingdom']},
#    'phone': '+442074796600',
#    'display_phone': '+44 20 7479 6600',
#    'distance': 2805.2181799883747},
#   {'id': 'wze_extjAhiGo23wkU078w',
#    'alias': 'hotel-indigo-london',
#    'name': 'Hotel Indigo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hmKcOi_aHO1UZhLfd_onsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-indigo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5130615234375,
#     'longitude': -0.075995996594429},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '142 Minories',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3N 1LS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['142 Minories', 'London EC3N 1LS', 'United Kingdom']},
#    'phone': '+448432087007',
#    'display_phone': '+44 843 208 7007',
#    'distance': 4149.338541955364},
#   {'id': 'JNUURMv-X6KPyadWrAQCsw',
#    'alias': 'hub-by-premier-inn-london',
#    'name': 'Hub By Premier Inn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_GKIpy6faaMZcZhPA2j5GQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hub-by-premier-inn-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5100618095395,
#     'longitude': -0.127215376054204},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "110 St. Martin's Lane",
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 4BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["110 St. Martin's Lane",
#      'Covent Garden',
#      'London WC2N 4BA',
#      'United Kingdom']},
#    'phone': '+443333213104',
#    'display_phone': '+44 333 321 3104',
#    'distance': 678.9588818252062},
#   {'id': 'u1SPXOMOPkyCOdcu6F85zQ',
#    'alias': 'hilton-london-paddington-london-2',
#    'name': 'Hilton London Paddington',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/f9WWc10kzOhq-mdT-7OcFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hilton-london-paddington-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 96,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5157526580863,
#     'longitude': -0.175882600189798},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '146 Praed Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1EE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['146 Praed Street',
#      'London W2 1EE',
#      'United Kingdom']},
#    'phone': '+442078500500',
#    'display_phone': '+44 20 7850 0500',
#    'distance': 2781.8569796804013},
#   {'id': '8ehiJFYEG49xxDAxuXglwQ',
#    'alias': 'the-sumner-hotel-london',
#    'name': 'The Sumner Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/k4loYTCN2xjDfTMmM6YywQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-sumner-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5152138, 'longitude': -0.1608312},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '54 Upper Berkeley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7QR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['54 Upper Berkeley Street',
#      'London W1H 7QR',
#      'United Kingdom']},
#    'phone': '+442077232244',
#    'display_phone': '+44 20 7723 2244',
#    'distance': 1743.1578646686228},
#   {'id': 'G7uJE057HeMLOZGg6c6lAA',
#    'alias': 'hotel-indigo-london-4',
#    'name': 'Hotel Indigo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KpBo-nmUF8BHOjT-ghZX9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-indigo-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4919293664835,
#     'longitude': -0.191815613709144},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '34 - 44 Barkston Gardens',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 0EW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['34 - 44 Barkston Gardens',
#      'London SW5 0EW',
#      'United Kingdom']},
#    'phone': '+442073737851',
#    'display_phone': '+44 20 7373 7851',
#    'distance': 4511.468188223717},
#   {'id': 'OnF85zr4lM6yimMK6HUlAA',
#    'alias': 'dawson-house-hotel-london',
#    'name': 'Dawson House Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oUS-JKOE88SrZgRGozO_tA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dawson-house-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.544256, 'longitude': -0.186507},
#    'transactions': [],
#    'location': {'address1': '72 Canfield Gardens',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW6 3EG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['72 Canfield Gardens',
#      'London NW6 3EG',
#      'United Kingdom']},
#    'phone': '+442076240079',
#    'display_phone': '+44 20 7624 0079',
#    'distance': 4938.231787594024},
#   {'id': 'vtDa4XLc5ovFSM5ak0EPJg',
#    'alias': 'the-chesterfield-mayfair-london',
#    'name': 'THE CHESTERFIELD MAYFAIR',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lDF21N3uWbFtvAlf5rP2zg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-chesterfield-mayfair-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 57,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5077092067692,
#     'longitude': -0.147149585319539},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '35 Charles st',
#     'address2': 'Mayfair',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 5EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35 Charles st',
#      'Mayfair',
#      'London W1J 5EB',
#      'United Kingdom']},
#    'phone': '+442074912622',
#    'display_phone': '+44 20 7491 2622',
#    'distance': 961.782070046326},
#   {'id': '1ug-7RR10IdBKzBM4UfrVg',
#    'alias': 'the-athenaeum-hotel-london',
#    'name': 'The Athenaeum Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XSpyZOQOv4ZA8jMLd5LQjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-athenaeum-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.504635, 'longitude': -0.147403},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Mayfair',
#     'address2': '116 Piccadilly',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 7BJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Mayfair',
#      '116 Piccadilly',
#      'London W1J 7BJ',
#      'United Kingdom']},
#    'phone': '+442074993464',
#    'display_phone': '+44 20 7499 3464',
#    'distance': 1210.074662334814},
#   {'id': 'kOBdPzn7tYeaKkhzb0y_vw',
#    'alias': 'h10-hotel-london',
#    'name': 'H10 Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NOu7t7fKCrU7Yi3dmkfcgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/h10-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.498886, 'longitude': -0.106292},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '284-302 Waterloo Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8RG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['284-302 Waterloo Road',
#      'London SE1 8RG',
#      'United Kingdom']},
#    'phone': '+442079284062',
#    'display_phone': '+44 20 7928 4062',
#    'distance': 2573.1456634004257},
#   {'id': 'uOnP6DwjgxLmv40wQ7eBWA',
#    'alias': 'the-dixon-london',
#    'name': 'The Dixon',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RjEMVgGEZBFQAD_8ZlHD_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dixon-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.501578, 'longitude': -0.075917},
#    'transactions': [],
#    'location': {'address1': '211 Tooley Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 2JX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['211 Tooley Street',
#      'London SE1 2JX',
#      'United Kingdom']},
#    'phone': '+442039592900',
#    'display_phone': '+44 20 3959 2900',
#    'distance': 4339.708816243784},
#   {'id': 'bb2tev-VDDEgWUOAd17oZA',
#    'alias': 'jurys-clifton-ford-hotel-london-2',
#    'name': 'Jurys Clifton Ford Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ztif_SKn8EyDGQ6NvBWBNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jurys-clifton-ford-hotel-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5179939, 'longitude': -0.1497692},
#    'transactions': [],
#    'location': {'address1': '47 Welbeck Street',
#     'address2': 'Marylebone',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1G 8DN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Welbeck Street',
#      'Marylebone',
#      'London W1G 8DN',
#      'United Kingdom']},
#    'phone': '+442074866600',
#    'display_phone': '+44 20 7486 6600',
#    'distance': 1123.6988507970257},
#   {'id': 'I0u3rVZNykXLsrjwk_h_gw',
#    'alias': 'number-sixteen-london',
#    'name': 'Number Sixteen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Cv9PGjSiyrenqnf1QHGMUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/number-sixteen-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.493083293133,
#     'longitude': -0.175445396683422},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '16 Sumner Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3EG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16 Sumner Place',
#      'London SW7 3EG',
#      'United Kingdom']},
#    'phone': '+442075895232',
#    'display_phone': '+44 20 7589 5232',
#    'distance': 3506.408311417197},
#   {'id': 'cvcqMWT-1bQZWmnavCrTiQ',
#    'alias': 'citizenm-tower-of-london-london-2',
#    'name': 'citizenM Tower of London',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BPO3Rc28-5jCT4WWtJJW-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/citizenm-tower-of-london-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5102499752476,
#     'longitude': -0.0766607053971314},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '40 Trinity Square',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EC3N 4DJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40 Trinity Square',
#      'London EC3N 4DJ',
#      'United Kingdom']},
#    'phone': '+44442035194830',
#    'display_phone': '+44 442035194830',
#    'distance': 4113.450055866643},
#   {'id': '5KiFZa-m4bS8KQoYbnBgsQ',
#    'alias': 'the-westbourne-hyde-park-london',
#    'name': 'The Westbourne Hyde Park',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JVlfSFnd4aMimlZwEypL9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-westbourne-hyde-park-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5127872, 'longitude': -0.17727},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '51 Gloucester Terrace',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3DQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Gloucester Terrace',
#      'London W2 3DQ',
#      'United Kingdom']},
#    'phone': '+442074025077',
#    'display_phone': '+44 20 7402 5077',
#    'distance': 2904.823855454361},
#   {'id': 'WkLEiLIM67bBIhf6G3fGbw',
#    'alias': 'gower-house-hotel-london',
#    'name': 'Gower House Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qUlaDo_UcCS4TMmGEh82yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gower-house-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5215474, 'longitude': -0.1318161},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '57 Gower Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1E 6HJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57 Gower Street',
#      'London WC1E 6HJ',
#      'United Kingdom']},
#    'phone': '+442076364685',
#    'display_phone': '+44 20 7636 4685',
#    'distance': 1012.0189991190663},
#   {'id': 'vO9_Nb_vj0SXoZ9obl0XFg',
#    'alias': 'the-cavendish-london-3',
#    'name': 'The Cavendish',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sxxXPp80VSK0aSVJjZZhkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cavendish-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.507877, 'longitude': -0.137955},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '81 Jermyn Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 6JF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['81 Jermyn Street',
#      'London SW1Y 6JF',
#      'United Kingdom']},
#    'phone': '+442079302111',
#    'display_phone': '+44 20 7930 2111',
#    'distance': 568.4553081486129},
#   {'id': '87L4PxozU_bncE7SHHkelQ',
#    'alias': 'radisson-london',
#    'name': 'Radisson',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NcTDSodV4LXOAIKaCWYpNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/radisson-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.513951, 'longitude': -0.127117},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '20 Mercer Street',
#     'address2': 'Covent Garden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9HD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Mercer Street',
#      'Covent Garden',
#      'London WC2H 9HD',
#      'United Kingdom']},
#    'phone': '+442078364300',
#    'display_phone': '+44 20 7836 4300',
#    'distance': 624.0959611229148},
#   {'id': 'Z8ZDXGXlAaPbD8OLPFJHkw',
#    'alias': 'doubletree-by-hilton-hotel-london-docklands-riverside-london',
#    'name': 'DoubleTree by Hilton Hotel London - Docklands Riverside',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SJrojSis5IIuysDalq_xSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doubletree-by-hilton-hotel-london-docklands-riverside-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5042384890007,
#     'longitude': -0.0340705423278678},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '265A Rotherhithe Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE16 5HW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['265A Rotherhithe Street',
#      'London SE16 5HW',
#      'United Kingdom']},
#    'phone': '+442072311001',
#    'display_phone': '+44 20 7231 1001',
#    'distance': 7115.721031323441},
#   {'id': 'Uyat8azSbi1oCNDWrbGvdw',
#    'alias': 'charlies-hotel-london',
#    'name': 'Charlies Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GrGDLYuz4T_hJVgVgU7Rtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/charlies-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5553807, 'longitude': -0.1298956},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '63 Anson Road',
#     'address2': 'Tufnell Park',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N7 0AR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63 Anson Road',
#      'Tufnell Park',
#      'London N7 0AR',
#      'United Kingdom']},
#    'phone': '+442076078375',
#    'display_phone': '+44 20 7607 8375',
#    'distance': 4749.33717794328},
#   {'id': 'abr3a1-iKYcFR1XinizgBw',
#    'alias': 'm-by-montcalm-shoreditch-london',
#    'name': '\u200bM by Montcalm Shoreditch',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ow3Dri4XbHucz2zL4Evb3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/m-by-montcalm-shoreditch-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.5276621, 'longitude': -0.088896},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '151-157 City Road',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 1JH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['151-157 City Road',
#      'London EC1V 1JH',
#      'United Kingdom']},
#    'phone': '+442038373000',
#    'display_phone': '+44 20 3837 3000',
#    'distance': 3648.8208907417047},
#   {'id': 'O_oje-iRyBY-SpYlrO3VKg',
#    'alias': 'travelodge-london-23',
#    'name': 'Travelodge',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1WPu1H0JQvsOKKcvHjCQhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/travelodge-london-23?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5225814036872,
#     'longitude': -0.0869478787353308},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Unit 1',
#     'address2': '23 City Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1Y 1AE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Unit 1',
#      '23 City Road',
#      'London EC1Y 1AE',
#      'United Kingdom']},
#    'phone': '+448719846333',
#    'display_phone': '+44 871 984 6333',
#    'distance': 3559.981900033017},
#   {'id': 'B2g7OKPDNR8eiky0REueNQ',
#    'alias': 'the-penn-club-london',
#    'name': 'The Penn Club',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/X4El8YdTRQjvIPqJX9zKGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-penn-club-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5206450127812,
#     'longitude': -0.12505496414401},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '21-23 Bedford Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 5JJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['21-23 Bedford Place',
#      'London WC1B 5JJ',
#      'United Kingdom']},
#    'phone': '+442076364718',
#    'display_phone': '+44 20 7636 4718',
#    'distance': 1150.2255406836173},
#   {'id': 'Q1ov9y1qyfBQ4QR26HMuGw',
#    'alias': 'the-w14-kensington-west-kensington',
#    'name': 'The W14 Kensington',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mM_QVRWKzPEvT2uVl5ykvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-w14-kensington-west-kensington?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.49159793, 'longitude': -0.21048263},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '16-22 Gunterstone Road',
#     'address2': '',
#     'address3': '',
#     'city': 'West Kensington',
#     'zip_code': 'W14 9BX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16-22 Gunterstone Road',
#      'West Kensington W14 9BX',
#      'United Kingdom']},
#    'phone': '+442076026600',
#    'display_phone': '+44 20 7602 6600',
#    'distance': 5678.397436795609}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndh2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Lodging": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                             Lodging    Type Price Rating  \
# 0                 Harlingford Hotel  Hotels    ££      4
# 1                   Rosewood London  Hotels  ££££    4.5
# 2                 St David's Hotels  Hotels    ££    3.5
# 3  Radisson Blu Edwardian Hampshire  Hotels   £££      4
# 4          Plaza On the River Hotel  Hotels   £££    3.5
#
#                     Address        Lat       Lng  \
# 0  61-63 Cartwright Gardens  51.526095 -0.126187
# 1          252 High Holborn  51.517422 -0.117811
# 2      14-20 Norfolk Square  51.516004 -0.173908
# 3    31-36 Liecester Square  51.509848 -0.129852
# 4                      None  51.500200 -0.126236
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/harlingford-hotel-lon...  xqGynJcWIF6-jl9i69phOw
# 1  https://www.yelp.com/biz/rosewood-london-londo...  UDSI_z1-edmeNtg3YOy-SQ
# 2  https://www.yelp.com/biz/st-davids-hotels-lond...  _jFVWny91oy62o5uNIvSSw
# 3  https://www.yelp.com/biz/radisson-blu-edwardia...  bqqtUZG_6913SWAMd597Ug
# 4  https://www.yelp.com/biz/plaza-on-the-river-ho...  jRduIw5aVQ8fO00Ta3wU8g

# %%
#3rd set of 50 records 101-150
lndh_params3 = {"term":"hotel","location":"London","limit":50,"offset":101}
lndh_response3 = requests.get(search_api_url, headers=headers, params=lndh_params3)
lndh3 = lndh_response3.json()
display(lndh3)
#print(lndh_response3.url)
#print(lndh_response3.status_code)
# Out:
# {'businesses': [{'id': '0wGix_lvipMqeu9p64r3Dg',
#    'alias': 'hampstead-village-guest-house-london',
#    'name': 'Hampstead Village Guest House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/q7Yf2RaPxUS1WqVdmk_5Gg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hampstead-village-guest-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'guesthouses', 'title': 'Guest Houses'},
#     {'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5558066, 'longitude': -0.172092},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '2 Kemplay Road',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'NW3 1SY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Kemplay Road', 'London NW3 1SY', 'United Kingdom']},
#    'phone': '+442074358679',
#    'display_phone': '+44 20 7435 8679',
#    'distance': 5392.420898028759},
#   {'id': 'OBqwCUsR2nLyThpB4U-log',
#    'alias': 'lancaster-hall-hotel-london',
#    'name': 'Lancaster Hall Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6fWW7nHGvvkeD_iyXlcmxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lancaster-hall-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5132116234142,
#     'longitude': -0.179161089618674},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '35 Craven Terrace',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3EL',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ['35 Craven Terrace',
#      'London W2 3EL',
#      'United Kingdom']},
#    'phone': '+442077239276',
#    'display_phone': '+44 20 7723 9276',
#    'distance': 2990.124109133956},
#   {'id': 'LhOP8kZzvSnYTAaaopp7Bg',
#    'alias': 'holiday-inn-london-29',
#    'name': 'Holiday Inn',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AxuNkpvMw-yzSu-FDXfy7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holiday-inn-london-29?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5169316, 'longitude': -0.1492864},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '57-59 Welbeck Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1G 9BL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57-59 Welbeck Street',
#      'London W1G 9BL',
#      'United Kingdom']},
#    'phone': '+442079354442',
#    'display_phone': '+44 20 7935 4442',
#    'distance': 1020.7110909040068},
#   {'id': 'AaByHFUY2eLbN9T-0JpDrQ',
#    'alias': 'blair-victoria-london',
#    'name': 'Blair Victoria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RCTiaI0Cyr2SP9YQqk-Ixw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blair-victoria-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 51.4914437, 'longitude': -0.14212},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '78-84 Warwick Way',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1RZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['78-84 Warwick Way',
#      'London SW1V 1RZ',
#      'United Kingdom']},
#    'phone': '+442079317689',
#    'display_phone': '+44 20 7931 7689',
#    'distance': 2416.7789584254815},
#   {'id': 'NDkrcHjLSobKPzbwFLF3Vw',
#    'alias': 'the-marylebone-hotel-london',
#    'name': 'The Marylebone Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_eolRXaFtOaNOH70D-ZUbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-marylebone-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5180684097082,
#     'longitude': -0.149774551391602},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '47 Welbeck Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1G 8DN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Welbeck Street',
#      'London W1G 8DN',
#      'United Kingdom']},
#    'phone': '+442074866600',
#    'display_phone': '+44 20 7486 6600',
#    'distance': 1119.3384358105152},
#   {'id': 'ufKzcskvO65818nmiU7dHg',
#    'alias': '11-cadogan-gardens-london',
#    'name': '11 Cadogan Gardens',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Z82cusWZ0qymXtuE5YR1rg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/11-cadogan-gardens-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.493533704065,
#     'longitude': -0.159166531174037},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Cadogan Gardens',
#     'address2': 'Knightsbridge',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 2RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Cadogan Gardens',
#      'Knightsbridge',
#      'London SW3 2RJ',
#      'United Kingdom']},
#    'phone': '+442077307000',
#    'display_phone': '+44 20 7730 7000',
#    'distance': 2680.936318070177},
#   {'id': '1H9Uqnpqti9rPZ4B2Pw7fQ',
#    'alias': 'k-k-hotel-george-london-2',
#    'name': 'K+K Hotel George',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/taDsGEPz6sgnmRBwsVg5tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/k-k-hotel-george-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 53,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4921, 'longitude': -0.19529},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1-15 Templeton Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 9NB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1-15 Templeton Place',
#      'London SW5 9NB',
#      'United Kingdom']},
#    'phone': '+442075988700',
#    'display_phone': '+44 20 7598 8700',
#    'distance': 4710.077285206833},
#   {'id': 'bK6cNmVJvHkH2KNNpv5YaQ',
#    'alias': 'park-avenue-baker-street-london',
#    'name': 'Park Avenue Baker Street',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/D-Rv46OJoyzPcBU-gMtPMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/park-avenue-baker-street-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5240975, 'longitude': -0.1609137},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '173 Gloucester Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 6DX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['173 Gloucester Place',
#      'London NW1 6DX',
#      'United Kingdom']},
#    'phone': '+442077243461',
#    'display_phone': '+44 20 7724 3461',
#    'distance': 2137.5768412314483},
#   {'id': 'dXSFdmrYx_vgsSV4Z0ZXZQ',
#    'alias': 'camden-lock-hotel-london',
#    'name': 'Camden Lock Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2c5VsjBarzY2ZORyaFaSEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/camden-lock-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.5437777, 'longitude': -0.152007},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '89 Chalk Farm Road',
#     'address2': 'Camden',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 8AR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['89 Chalk Farm Road',
#      'Camden',
#      'London NW1 8AR',
#      'United Kingdom']},
#    'phone': '+442072673912',
#    'display_phone': '+44 20 7267 3912',
#    'distance': 3649.78245052214},
#   {'id': 'dG-JrtF8aNFU5fFHvQzdMw',
#    'alias': 'pullman-hotel-london-2',
#    'name': 'Pullman Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EcAohzL64EX39mtTBlK0IA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pullman-hotel-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5287433066088,
#     'longitude': -0.127791479939421},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '100 - 110 Euston Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 2AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['100 - 110 Euston Road',
#      'London NW1 2AJ',
#      'United Kingdom']},
#    'phone': '+442076669000',
#    'display_phone': '+44 20 7666 9000',
#    'distance': 1856.8700421491626},
#   {'id': 'glL93CF9WxJdM9WEeRogeQ',
#    'alias': 'charlotte-street-hotel-london',
#    'name': 'Charlotte Street Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qLOm_cUe5ktPE-yhdjFtYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/charlotte-street-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51840064125,
#     'longitude': -0.134992897529986},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '15-17 Charlotte Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 1RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15-17 Charlotte Street',
#      'London W1T 1RJ',
#      'United Kingdom']},
#    'phone': '+442078062000',
#    'display_phone': '+44 20 7806 2000',
#    'distance': 622.3892927066557},
#   {'id': 'K6OT5WL5icTezcNhy_qimw',
#    'alias': '40-winks-london',
#    'name': '40 Winks',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_5I9ZkgsKw3GbRzUr9aGng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/40-winks-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5214767456055,
#     'longitude': -0.0512520000338554},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '109 Mile End Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 4UJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['109 Mile End Rd', 'London E1 4UJ', 'United Kingdom']},
#    'phone': '+442077900259',
#    'display_phone': '+44 20 7790 0259',
#    'distance': 5939.262931865729},
#   {'id': 'Sk2v68NoRpXgS67eRaoENw',
#    'alias': 'the-westbury-mayfair-a-luxury-collection-hotel-london-london',
#    'name': 'The Westbury Mayfair, a Luxury Collection Hotel, London',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vSgBaTnZgMQEhElxjSXCBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-westbury-mayfair-a-luxury-collection-hotel-london-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.511301, 'longitude': -0.142627},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '37 Conduit Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 2YF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['37 Conduit Street',
#      'London W1S 2YF',
#      'United Kingdom']},
#    'phone': '+442076297755',
#    'display_phone': '+44 20 7629 7755',
#    'distance': 492.18378385110327},
#   {'id': 'cDrLSCzqconeKxJHnnBt0A',
#    'alias': 'citadines-st-marks-london-london',
#    'name': "Citadines St Mark's London",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mo8Vl5hRDGk5y8ins-NKMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/citadines-st-marks-london-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5298483055582,
#     'longitude': -0.098963603561546},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '300 City Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 2PW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['300 City Road', 'London EC1V 2PW', 'United Kingdom']},
#    'phone': '+442072532039',
#    'display_phone': '+44 20 7253 2039',
#    'distance': 3182.65039091423},
#   {'id': 'HYsinVX6dqvjVXaxYuRwXg',
#    'alias': 'grange-blooms-hotel-london-3',
#    'name': 'Grange Blooms Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RNvnnnHkw38FAD1F_BXFqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grange-blooms-hotel-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5198687, 'longitude': -0.1259157},
#    'transactions': [],
#    'location': {'address1': '7 Montague Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 5BP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Montague Street',
#      'London WC1B 5BP',
#      'United Kingdom']},
#    'phone': '+442073231717',
#    'display_phone': '+44 20 7323 1717',
#    'distance': 1046.0678589749862},
#   {'id': 'kf0EKf0nuOGVjwnUdy7_nQ',
#    'alias': 'the-standard-london-london-3',
#    'name': 'The Standard, London',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1-gim662kVfXhnjPrvWq7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-standard-london-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5294399, 'longitude': -0.1241796},
#    'transactions': [],
#    'location': {'address1': '10 Argyle Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC1H 8EG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Argyle Street',
#      'London WC1H 8EG',
#      'United Kingdom']},
#    'phone': '+444402039818888',
#    'display_phone': '+44 4402039818888',
#    'distance': 2031.6102692133584},
#   {'id': 'eicqrtoLRue0kvyiBVo9vQ',
#    'alias': 'the-waldorf-hilton-london-london-4',
#    'name': 'The Waldorf Hilton, London',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eSV6fgBwpcMojMCMtrcHOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-waldorf-hilton-london-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 101,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.512569, 'longitude': -0.118935},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Aldwych',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 4DD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Aldwych', 'London WC2B 4DD', 'United Kingdom']},
#    'phone': '+442078362400',
#    'display_phone': '+44 20 7836 2400',
#    'distance': 1178.231553121846},
#   {'id': 'Jy9zg1ZTwd3eqMd6DLWH0Q',
#    'alias': 'the-grand-at-trafalgar-square-london',
#    'name': 'The Grand at Trafalgar Square',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lVF9HB1i5q_EJYyZpOu7YA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grand-at-trafalgar-square-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 96,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5071479913617,
#     'longitude': -0.126278438630075},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8 Northumberland Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 5BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Northumberland Ave',
#      'London WC2N 5BY',
#      'United Kingdom']},
#    'phone': '+442078398877',
#    'display_phone': '+44 20 7839 8877',
#    'distance': 921.135639188193},
#   {'id': '6r3jpZ377oysG0CLsCXcZw',
#    'alias': 'millers-hotel-london',
#    'name': "Miller's Hotel",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c2xXE6EM7Juae5DRpe9cxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/millers-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5150554, 'longitude': -0.1936962},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '111a Westbourne Grove',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 4UW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['111a Westbourne Grove',
#      'London W2 4UW',
#      'United Kingdom']},
#    'phone': '+442072431024',
#    'display_phone': '+44 20 7243 1024',
#    'distance': 4005.59864869309},
#   {'id': 'M2zf3hZItPnI75hmNyCY0w',
#    'alias': 'me-london-3',
#    'name': 'Me',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Mo4yqbOiBmrbS0nkmcy5jQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/me-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5118462758476,
#     'longitude': -0.118709250331904},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Strand',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2R 1HA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Strand', 'London WC2R 1HA', 'United Kingdom']},
#    'phone': '+442034998651',
#    'display_phone': '+44 20 3499 8651',
#    'distance': 1198.5487239392496},
#   {'id': 'iE6JM0o8ALjlB76QvjH20A',
#    'alias': 'oakley-hotel-london',
#    'name': 'Oakley Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/w2UgVS7F_a6v70omIuvJsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oakley-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.484772, 'longitude': -0.168646},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '73 Oakley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 5HF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['73 Oakley Street',
#      'London SW3 5HF',
#      'United Kingdom']},
#    'phone': '+442073525599',
#    'display_phone': '+44 20 7352 5599',
#    'distance': 3849.114542354527},
#   {'id': '7IVdX6ZQ5VKosk7aMm9x3w',
#    'alias': 'four-seasons-hotel-london-7',
#    'name': 'Four Seasons Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RN8S9ozCH-Ba1-6lpTX9MA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/four-seasons-hotel-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.510102, 'longitude': -0.07798},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '10 Trinity Square',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EC3N 4AJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Trinity Square',
#      'London EC3N 4AJ',
#      'United Kingdom']},
#    'phone': '+442032979200',
#    'display_phone': '+44 20 3297 9200',
#    'distance': 4023.59545729884},
#   {'id': 'hLzmh0Lq2cHJDDntlnNeuw',
#    'alias': 'holiday-inn-london-27',
#    'name': 'Holiday Inn ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_LoaWX23-fp7cQhPuk92_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holiday-inn-london-27?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5225489331923,
#     'longitude': -0.142724030932378},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Carburton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 5EE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Carburton Street',
#      'London W1W 5EE',
#      'United Kingdom']},
#    'phone': '+448719429111',
#    'display_phone': '+44 871 942 9111',
#    'distance': 1177.2406813961143},
#   {'id': '7lcPj3CpX9bnXpHzvan79Q',
#    'alias': 'london-city-hotel-london',
#    'name': 'London City Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ORJJFtSMKzj9Mi_452lp0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/london-city-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5011849, 'longitude': -0.0935363},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '200 Borough High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1JX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['200 Borough High Street',
#      'London SE1 1JX',
#      'United Kingdom']},
#    'phone': '+442074070737',
#    'display_phone': '+44 20 7407 0737',
#    'distance': 3206.152649384404},
#   {'id': 'mHtH47UEuSZGg2RJ1nYBIQ',
#    'alias': 'london-marriott-hotel-grosvenor-square-london',
#    'name': 'London Marriott Hotel Grosvenor Square',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ak18cB5jjiK6x3HDp2UuuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/london-marriott-hotel-grosvenor-square-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 54,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5125949421553,
#     'longitude': -0.150771225131166},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Grosvenor Square',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 6JP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Grosvenor Square',
#      'London W1K 6JP',
#      'United Kingdom']},
#    'phone': '+442074931232',
#    'display_phone': '+44 20 7493 1232',
#    'distance': 1025.5916119412261},
#   {'id': '-Uyd8UlBLO6lqPC8VK9INg',
#    'alias': 'the-goring-london',
#    'name': 'The Goring',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fgXkrk2aVAwCridzZSRYbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-goring-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.49762, 'longitude': -0.145632},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '15 Beeston Place',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1W 0JW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Beeston Place',
#      'London SW1W 0JW',
#      'United Kingdom']},
#    'phone': '+442073969000',
#    'display_phone': '+44 20 7396 9000',
#    'distance': 1819.6143691803463},
#   {'id': 'Vp8V6u9VooYcnEJBv4WvAA',
#    'alias': 'club-quarters-london-4',
#    'name': 'Club Quarters',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QBTeZg0iHdjSroMw0WcDrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/club-quarters-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5069599284465,
#     'longitude': -0.126023153127242},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8 Northumberland Avenue',
#     'address2': 'Trafalgar Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2N 5BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Northumberland Avenue',
#      'Trafalgar Square',
#      'London WC2N 5BY',
#      'United Kingdom']},
#    'phone': '+442078399333',
#    'display_phone': '+44 20 7839 9333',
#    'distance': 948.3440381832661},
#   {'id': 'jEa-BJscV6RIxatz335sAw',
#    'alias': 'the-draycott-london',
#    'name': 'The Draycott',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FE5RD1w3Y6fQ2PqaLQ24Ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-draycott-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4930610656738,
#     'longitude': -0.159959003329277},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '26 Cadogan Gardens',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 2RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Cadogan Gardens',
#      'London SW3 2RP',
#      'United Kingdom']},
#    'phone': '+442077306466',
#    'display_phone': '+44 20 7730 6466',
#    'distance': 2757.8979319210976},
#   {'id': 'R6v-A-TETGftAgOHTWOUhg',
#    'alias': 'sanctum-soho-london',
#    'name': 'Sanctum Soho',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/M2A9s2EdDA1Z9cmw0cnu0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sanctum-soho-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5116683, 'longitude': -0.1383868},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '20 Warwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5NF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Warwick Street',
#      'London W1B 5NF',
#      'United Kingdom']},
#    'phone': '+442072926100',
#    'display_phone': '+44 20 7292 6100',
#    'distance': 212.47610845061342},
#   {'id': 'ZAxCJK2r9Okx5nTjGGf-rw',
#    'alias': 'holiday-inn-london-5',
#    'name': 'Holiday Inn ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/co2jIm9mWZBVvEl__79cTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holiday-inn-london-5?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5077090319947,
#     'longitude': -0.142347367024516},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3 Berkeley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 8NE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Berkeley Street',
#      'London W1J 8NE',
#      'United Kingdom']},
#    'phone': '+448719429110',
#    'display_phone': '+44 871 942 9110',
#    'distance': 721.5240723131545},
#   {'id': 'loeMRdWerolE9W1j5f2rwA',
#    'alias': 'hilton-london-tower-bridge-london',
#    'name': 'Hilton London Tower Bridge',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/P-voM9RpITRFITJVPHi38A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hilton-london-tower-bridge-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5046388785402,
#     'longitude': -0.0824432680348952},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '5 More London Place',
#     'address2': 'Tooley Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 2BY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 More London Place',
#      'Tooley Street',
#      'London SE1 2BY',
#      'United Kingdom']},
#    'phone': '+442030024300',
#    'display_phone': '+44 20 3002 4300',
#    'distance': 3813.951734219474},
#   {'id': '6nApL63kBo4oEFA-H3PMzw',
#    'alias': 'aster-house-london',
#    'name': 'Aster House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yQxWkRtPLFJP5LJrUNkdwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aster-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4925736, 'longitude': -0.1754493},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '3 Sumner Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3EE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3 Sumner Place', 'London SW7 3EE', 'United Kingdom']},
#    'phone': '+442075815888',
#    'display_phone': '+44 20 7581 5888',
#    'distance': 3545.3166941471964},
#   {'id': 'ugLZ4kaMSHiUjkt36XxqRA',
#    'alias': 'sheraton-grand-london-park-lane-london-2',
#    'name': 'Sheraton Grand London Park Lane',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/S9kNyzBk8xbhk8Vf88PVew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sheraton-grand-london-park-lane-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 106,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5045999, 'longitude': -0.1469917},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Piccadilly',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 7BX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Piccadilly', 'London W1J 7BX', 'United Kingdom']},
#    'phone': '+442074996321',
#    'display_phone': '+44 20 7499 6321',
#    'distance': 1192.4539094169859},
#   {'id': 'AW3ZBSBgVBYU3k6nWi7ygg',
#    'alias': 'dorsett-london-2',
#    'name': 'DORSETT',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZdxOK7sspfTPKSJzn7BtoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dorsett-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 24,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5040567, 'longitude': -0.2246746},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '58 Shepherds Bush Green',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W12 8QE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['58 Shepherds Bush Green',
#      'London W12 8QE',
#      'United Kingdom']},
#    'phone': '+442032621026',
#    'display_phone': '+44 20 3262 1026',
#    'distance': 6217.123158663369},
#   {'id': 'OQtI-q8Im3ix-eBoEOeeJQ',
#    'alias': 'the-baileys-hotel-london-london-3',
#    'name': 'The Bailey’s Hotel London',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xPvUlBuRasB_5m0c0ZcD0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-baileys-hotel-london-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4940067839874,
#     'longitude': -0.182480116717755},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '140 Gloucester Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW7 4QH',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ['140 Gloucester Road',
#      'London SW7 4QH',
#      'United Kingdom']},
#    'phone': '+442073736000',
#    'display_phone': '+44 20 7373 6000',
#    'distance': 3840.9658825671536},
#   {'id': 'G2L9RZ7RF4mwOqH9d7f2lA',
#    'alias': 'seven-dials-hotel-london',
#    'name': 'Seven Dials Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/J_brVCGA5QYabNdBOEDyPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seven-dials-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5149, 'longitude': -0.126723},
#    'transactions': [],
#    'location': {'address1': '7 Monmouth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7 Monmouth Street',
#      'London WC2H 9DA',
#      'United Kingdom']},
#    'phone': '+442072400823',
#    'display_phone': '+44 20 7240 0823',
#    'distance': 680.4820227603985},
#   {'id': 'oQFU_E6Ru1_s5jIJ9VdNNA',
#    'alias': 'wyndham-grand-london-chelsea-harbour-london-2',
#    'name': 'Wyndham Grand London Chelsea Harbour',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wYNRrBGEqm3EJnbky53Tog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wyndham-grand-london-chelsea-harbour-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'spas', 'title': 'Day Spas'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4773654686125,
#     'longitude': -0.18584659580074},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': 'Chelsea Harbour',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW10 0XG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Chelsea Harbour',
#      'London SW10 0XG',
#      'United Kingdom']},
#    'phone': '+442078233000',
#    'display_phone': '+44 20 7823 3000',
#    'distance': 5242.590622898676},
#   {'id': 'vCnwGIj73ixitVM5lA_cFQ',
#    'alias': 'lincoln-house-hotel-london',
#    'name': 'Lincoln House Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gd615JCjr03A0u02eMLJFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lincoln-house-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51759, 'longitude': -0.158048},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '33 Gloucester Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 8HY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['33 Gloucester Place',
#      'London W1U 8HY',
#      'United Kingdom']},
#    'phone': '+442074867630',
#    'display_phone': '+44 20 7486 7630',
#    'distance': 1612.5455182127182},
#   {'id': '-BcaEVNIiQgi6rXb57Rjrg',
#    'alias': 'no-ten-manchester-street-hotel-london',
#    'name': 'No Ten Manchester Street Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XWxssoR3TY44PxJwWjESWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/no-ten-manchester-street-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5187995, 'longitude': -0.1538386},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '10 Manchester Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 4DG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Manchester Street',
#      'London W1U 4DG',
#      'United Kingdom']},
#    'phone': '+442073175900',
#    'display_phone': '+44 20 7317 5900',
#    'distance': 1403.92450392211},
#   {'id': 'O_d-P1JDlElAdcIvMsqwcQ',
#    'alias': 'the-beaumont-london-2',
#    'name': 'The Beaumont',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PH5Q1Tj9VnFsQrPcD2ad6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-beaumont-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51306, 'longitude': -0.152256},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '8 Balderton Street',
#     'address2': 'Brown Hart Gardens',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 6TF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Balderton Street',
#      'Brown Hart Gardens',
#      'London W1K 6TF',
#      'United Kingdom']},
#    'phone': '+442074991001',
#    'display_phone': '+44 20 7499 1001',
#    'distance': 1128.2610761483688},
#   {'id': '1ZVWnxQW5GFxtQnXNzN3ZQ',
#    'alias': 'the-may-fair-hotel-london-3',
#    'name': 'The May Fair Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/V6n4bKUtEc-u8igPueCT5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-may-fair-hotel-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 72,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'gyms', 'title': 'Gyms'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.50814, 'longitude': -0.143972},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'May Fair Hotel',
#     'address2': 'Stratton Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1J 8LT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['May Fair Hotel',
#      'Stratton Street',
#      'London W1J 8LT',
#      'United Kingdom']},
#    'phone': '+442079152826',
#    'display_phone': '+44 20 7915 2826',
#    'distance': 761.8143143332397},
#   {'id': 'OKMKLgs8iVNQ9lU51UPDSQ',
#    'alias': 'como-the-halkin-london',
#    'name': 'COMO The Halkin',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JpN93ETG6NSZSYkqm00Wiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/como-the-halkin-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.500831, 'longitude': -0.151952},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Halkin Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1X 7DJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Halkin Street', 'London SW1X 7DJ', 'United Kingdom']},
#    'phone': '+442073331000',
#    'display_phone': '+44 20 7333 1000',
#    'distance': 1742.7080502753886},
#   {'id': 'BCnri2b-wmuIzmivwAMhKg',
#    'alias': 'hotel-montana-london',
#    'name': 'Hotel Montana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AIiVZUc2Ed54QfW0UM6i_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-montana-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5291364, 'longitude': -0.1217579},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '16-17 Argyle Square',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC1H 8AS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['16-17 Argyle Square',
#      'London WC1H 8AS',
#      'United Kingdom']},
#    'phone': '+442032861733',
#    'display_phone': '+44 20 3286 1733',
#    'distance': 2061.6492678168747},
#   {'id': 'Ttvhy6KPXVtGQh8yopHstQ',
#    'alias': 'regency-house-hotel-london-2',
#    'name': 'Regency House Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YBC12Z-OfvGq2AjJ3fSlCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/regency-house-hotel-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5216848, 'longitude': -0.1321776},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '71 Gower Street Bloomsbury',
#     'address2': 'London',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1E 6HJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['71 Gower Street Bloomsbury',
#      'London',
#      'London WC1E 6HJ',
#      'United Kingdom']},
#    'phone': '+442076371804',
#    'display_phone': '+44 20 7637 1804',
#    'distance': 1018.1304240324273},
#   {'id': 'PpTb-RwM8yqtq6mtOn6Yuw',
#    'alias': 'browns-hotel-london',
#    'name': "Brown's Hotel",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5yP72cH1Stfq-X-VLbkuPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/browns-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5091761, 'longitude': -0.1422935},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '30 Albemarle Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 4BP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['30 Albemarle Street',
#      'London W1S 4BP',
#      'United Kingdom']},
#    'phone': '+442074936020',
#    'display_phone': '+44 20 7493 6020',
#    'distance': 580.2585637794593},
#   {'id': 'OPtqyoClLHUMo5Tr3Os4kQ',
#    'alias': 'nobu-hotel-shoreditch-london',
#    'name': 'Nobu Hotel Shoreditch',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AiHPPNA3maQND4BrTpFjiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nobu-hotel-shoreditch-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5250722, 'longitude': -0.0826811},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '10-50 Willow Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 4BH',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ['10-50 Willow Street',
#      'London EC2A 4BH',
#      'United Kingdom']},
#    'phone': '+442076831200',
#    'display_phone': '+44 20 7683 1200',
#    'distance': 3929.2716370081243},
#   {'id': 'EoUO9kzjHt_HBmBTxHZRfQ',
#    'alias': 'piccadilly-hotel-london',
#    'name': 'Piccadilly Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wnFIzBEwSuIdvipZUP682g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piccadilly-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.511192, 'longitude': -0.135579},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '12 Sherwood Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7BZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Sherwood Street',
#      'London W1F 7BZ',
#      'United Kingdom']},
#    'phone': '+442074349009',
#    'display_phone': '+44 20 7434 9009',
#    'distance': 189.12578522644472},
#   {'id': 'OVKglwMXLS6R11voWK8zZw',
#    'alias': 'the-belgrave-london',
#    'name': 'The Belgrave',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HKqa4jcel_8XikT5_mQlpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-belgrave-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 16,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4901569, 'longitude': -0.1380582},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '80-86 Belgrave Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 2BJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['80-86 Belgrave Road',
#      'London SW1V 2BJ',
#      'United Kingdom']},
#    'phone': '+442078288661',
#    'display_phone': '+44 20 7828 8661',
#    'distance': 2532.0037644837016},
#   {'id': 'Rgg191-6wVMZImQWmZX5Xg',
#    'alias': 'hilton-london-metropole-london-2',
#    'name': 'Hilton London Metropole',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ykeZONgMhknP_CHjI48U-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hilton-london-metropole-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 141,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5193983134154,
#     'longitude': -0.169682935447581},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '225 Edgware Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1JU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['225 Edgware Road',
#      'London W2 1JU',
#      'United Kingdom']},
#    'phone': '+442074024141',
#    'display_phone': '+44 20 7402 4141',
#    'distance': 2445.211166672671},
#   {'id': 'SJZbFo89ONAvHujafLbGdQ',
#    'alias': 'alhambra-hotel-london',
#    'name': 'Alhambra Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pcNj3uXewbNzbJRrVONHZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alhambra-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5293381, 'longitude': -0.1236626},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '17-19 Argyle Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 8EJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17-19 Argyle Street',
#      'London WC1H 8EJ',
#      'United Kingdom']},
#    'phone': '+442078379575',
#    'display_phone': '+44 20 7837 9575',
#    'distance': 2018.1337842859748}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndh3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Lodging": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
#                          Lodging          Type Price Rating  \
# 0  Hampstead Village Guest House  Guest Houses   £££    3.5
# 1           Lancaster Hall Hotel        Hotels     £    4.5
# 2                    Holiday Inn        Hotels    ££      3
# 3                 Blair Victoria        Hotels     £      1
# 4           The Marylebone Hotel        Hotels   £££      4
#
#                 Address        Lat       Lng  \
# 0        2 Kemplay Road  51.555807 -0.172092
# 1     35 Craven Terrace  51.513212 -0.179161
# 2  57-59 Welbeck Street  51.516932 -0.149286
# 3     78-84 Warwick Way  51.491444 -0.142120
# 4     47 Welbeck Street  51.518068 -0.149775
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/hampstead-village-gue...  0wGix_lvipMqeu9p64r3Dg
# 1  https://www.yelp.com/biz/lancaster-hall-hotel-...  OBqwCUsR2nLyThpB4U-log
# 2  https://www.yelp.com/biz/holiday-inn-london-29...  LhOP8kZzvSnYTAaaopp7Bg
# 3  https://www.yelp.com/biz/blair-victoria-london...  AaByHFUY2eLbN9T-0JpDrQ
# 4  https://www.yelp.com/biz/the-marylebone-hotel-...  NDkrcHjLSobKPzbwFLF3Vw

# %%
#4th set of 50 records 151-200
lndh_params4 = {"term":"hotel","location":"London","limit":50,"offset":151}
lndh_response4 = requests.get(search_api_url, headers=headers, params=lndh_params4)
lndh4 = lndh_response4.json()
display(lndh4)
#print(lndh_response4.url)
#print(lndh_response4.status_code)
# Out:
# {'businesses': [{'id': 'Kfd_kXdY_dyyx2FJBXVXTw',
#    'alias': 'the-rubens-at-the-palace-london',
#    'name': 'The Rubens at the Palace',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GaKvvTVKqFy1IVASzaX_CQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-rubens-at-the-palace-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 83,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.49826525, 'longitude': -0.14349978},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '39 Buckingham Palace Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 0PS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['39 Buckingham Palace Road',
#      'London SW1W 0PS',
#      'United Kingdom']},
#    'phone': '+442078346600',
#    'display_phone': '+44 20 7834 6600',
#    'distance': 1702.196036508304},
#   {'id': 'tjx9QUBMw3kCGzepS10u2Q',
#    'alias': 'grand-residences-by-marriott-mayfair-london-london',
#    'name': 'Grand Residences by Marriott - Mayfair-London',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ujC3mT5NxaMX-SH2Zzv2Og/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grand-residences-by-marriott-mayfair-london-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5111287, 'longitude': -0.1549705},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '47 Park Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 7EB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['47 Park Street', 'London W1K 7EB', 'United Kingdom']},
#    'phone': '+442074917282',
#    'display_phone': '+44 20 7491 7282',
#    'distance': 1333.5566308220962},
#   {'id': 'VO3LfCg4ueYzKKx-PwG-Wg',
#    'alias': 'the-curtain-london',
#    'name': 'The Curtain',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2ZtassQuc2oPokkeqtcxkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-curtain-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5236988173443,
#     'longitude': -0.0806030631065369},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '45 Curtain Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EC2A 3PT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['45 Curtain Rd', 'London EC2A 3PT', 'United Kingdom']},
#    'phone': '+442031464545',
#    'display_phone': '+44 20 3146 4545',
#    'distance': 4015.9738449577158},
#   {'id': 'R7jHFXhXNMaDBGBcmMPmUA',
#    'alias': 'country-inns-and-suites-london',
#    'name': 'Country Inns & Suites',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ruynqU77i0Yr1B61jbezhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/country-inns-and-suites-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 51.5175138, 'longitude': -0.1294779},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '110 Great Russell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3NA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['110 Great Russell Street',
#      'London WC1B 3NA',
#      'United Kingdom']},
#    'phone': '+442076377777',
#    'display_phone': '+44 20 7637 7777',
#    'distance': 681.2739756642476},
#   {'id': 'eRsagtXFoJIBiszGWG8mQQ',
#    'alias': 'the-holmes-hotel-london',
#    'name': 'The Holmes Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/j5Bu-x95L0o-nY81_EB2lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-holmes-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 20,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5210546187993,
#     'longitude': -0.156072708598344},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '83 Chiltern Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 6NF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['83 Chiltern Street',
#      'London W1U 6NF',
#      'United Kingdom']},
#    'phone': '+443334006136',
#    'display_phone': '+44 333 400 6136',
#    'distance': 1665.1921022631086},
#   {'id': '9h8s3Zq1sKzpRwPd4bXFow',
#    'alias': 'the-rookery-london',
#    'name': 'The Rookery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2Yezcs_QiH_0BmSJUkdiuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-rookery-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.52033, 'longitude': -0.1022499},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "12 Peter's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1M 6DS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["12 Peter's Lane",
#      'London EC1M 6DS',
#      'United Kingdom']},
#    'phone': '+442073360931',
#    'display_phone': '+44 20 7336 0931',
#    'distance': 2456.8947173803995},
#   {'id': 'FNEhNoxoDPDt6APP00N4hw',
#    'alias': 'sea-containers-london-london-2',
#    'name': 'Sea Containers London',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EZgz-m2YBeU610TTycEo6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sea-containers-london-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.508145, 'longitude': -0.106668},
#    'transactions': [],
#    'location': {'address1': '20 Upper Ground',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 9PD',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ['20 Upper Ground',
#      'London SE1 9PD',
#      'United Kingdom']},
#    'phone': '+442037471000',
#    'display_phone': '+44 20 3747 1000',
#    'distance': 2092.877318544294},
#   {'id': 't9-_U2-WmaIee3XDB0Tz0w',
#    'alias': 'hotel-café-royal-london',
#    'name': 'Hotel Café Royal',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Jnx6mmFqDAEbaSkqyvdMKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-caf%C3%A9-royal-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 65,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.510171, 'longitude': -0.135962},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '68 Regent Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 4DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['68 Regent Street',
#      'London W1B 4DY',
#      'United Kingdom']},
#    'phone': '+442074063333',
#    'display_phone': '+44 20 7406 3333',
#    'distance': 296.2812185491074},
#   {'id': 'igsHBUp7ZQPOQ7EbgFkKRA',
#    'alias': 'myhotel-london-2',
#    'name': 'myhotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iI1lPx6KcrRVNV5W6HKvmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/myhotel-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.491938, 'longitude': -0.168589},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '35 Ixworth Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 3QX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35 Ixworth Place',
#      'London SW3 3QX',
#      'United Kingdom']},
#    'phone': '+442072257500',
#    'display_phone': '+44 20 7225 7500',
#    'distance': 3234.3503394281797},
#   {'id': '0rTsnYGt_8u7yxs8Xg6Ufw',
#    'alias': 'the-z-hotel-london-2',
#    'name': 'The Z Hotel ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3CJLCrY45PyM0kM2EqG6DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-z-hotel-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5268102, 'longitude': -0.0883364},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '136-144 City Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 2RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['136-144 City Road',
#      'London EC1V 2RL',
#      'United Kingdom']},
#    'phone': '+442035513700',
#    'display_phone': '+44 20 3551 3700',
#    'distance': 3644.427263709549},
#   {'id': 'tP2AiQXgLtheNxBYV73SlA',
#    'alias': 'thistle-london-3',
#    'name': 'Thistle',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XIyav6dhhr0kkUa8Ato9RQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thistle-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.520901, 'longitude': -0.122974},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '126 Southampton Row',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 5AD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['126 Southampton Row',
#      'London WC1B 5AD',
#      'United Kingdom']},
#    'phone': '+448003308551',
#    'display_phone': '+44 800 330 8551',
#    'distance': 1268.1804582814639},
#   {'id': 'Ut5NZhcbl1bElj1JEIPmTg',
#    'alias': 'holiday-inn-london-kensington-london-2',
#    'name': 'Holiday Inn London - Kensington',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NgPy3GQRNNxXDpJW1p09GA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holiday-inn-london-kensington-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 74,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.4988245259061,
#     'longitude': -0.191950977925019},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Wrights Lane',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W8 5SP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Wrights Lane', 'London W8 5SP', 'United Kingdom']},
#    'phone': '+442079378289',
#    'display_phone': '+44 20 7937 8289',
#    'distance': 4176.936314313553},
#   {'id': 'EujiHYtcngGm7UFif9tNEg',
#    'alias': 'travelodge-london-15',
#    'name': 'Travelodge',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WQHHHsQp32o--ZkZ2BN0FA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/travelodge-london-15?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5301395893589,
#     'longitude': -0.120352728472182},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': 'Willings House 356-364',
#     'address2': 'Grays Inn Road',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1X 8BH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Willings House 356-364',
#      'Grays Inn Road',
#      'London WC1X 8BH',
#      'United Kingdom']},
#    'phone': '+448719846256',
#    'display_phone': '+44 871 984 6256',
#    'distance': 2206.2770630038845},
#   {'id': '7nWuz48vCnuMrSwe_bD2Yw',
#    'alias': 'hotel-la-gaffe-london',
#    'name': 'Hotel La Gaffe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FpqGD8fpa7xGlhMz1QAaoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-la-gaffe-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5593645, 'longitude': -0.1785256},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '107-111 Heath Street',
#     'address2': 'Hampstead',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 6SS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['107-111 Heath Street',
#      'Hampstead',
#      'London NW3 6SS',
#      'United Kingdom']},
#    'phone': '+442074358965',
#    'display_phone': '+44 20 7435 8965',
#    'distance': 5952.921632326477},
#   {'id': 'VWTYSnuV3IDJJjSk7kzMkw',
#    'alias': 'residence-inn-by-marriott-london-2',
#    'name': 'Residence Inn by Marriott',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/E-Gq4iYqQodbSS155uNDzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/residence-inn-by-marriott-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4987162467047,
#     'longitude': -0.0841357962951861},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '201 - 211 Long Lane',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 4PN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['201 - 211 Long Lane',
#      'London SE1 4PN',
#      'United Kingdom']},
#    'phone': '+442031467344',
#    'display_phone': '+44 20 3146 7344',
#    'distance': 3915.122957001724},
#   {'id': '2QQbF5bre2duA2a_s7ekzQ',
#    'alias': 'cherry-court-hotel-london',
#    'name': 'Cherry Court Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KZ3YR3L4YORPGpL1JOjGWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cherry-court-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4925203, 'longitude': -0.1450402},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '23 Hugh Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['23 Hugh Street',
#      'London SW1V 1QJ',
#      'United Kingdom']},
#    'phone': '+442078282840',
#    'display_phone': '+44 20 7828 2840',
#    'distance': 2344.6205295263717},
#   {'id': 'N8oLZIUrKK8Ksgsn2xa3aw',
#    'alias': 'morgan-hotel-london',
#    'name': 'Morgan Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QSh9meVYWjicGu8jLvQ1tQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/morgan-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5180446, 'longitude': -0.1275755},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '24 Bloomsbury Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 3QJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['24 Bloomsbury Street',
#      'London WC1B 3QJ',
#      'United Kingdom']},
#    'phone': '+442076363735',
#    'display_phone': '+44 20 7636 3735',
#    'distance': 819.2870021292113},
#   {'id': 'HOucp57m1eh-4JnwYC0lPQ',
#    'alias': 'hampton-by-hilton-london-waterloo-london',
#    'name': 'Hampton By Hilton London Waterloo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QO_j4wlRo8vIyH5EKcw0UA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hampton-by-hilton-london-waterloo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5008745782199,
#     'longitude': -0.10801792094101},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '157 Waterloo Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8XA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['157 Waterloo Road',
#      'London SE1 8XA',
#      'United Kingdom']},
#    'phone': '+442074018080',
#    'display_phone': '+44 20 7401 8080',
#    'distance': 2346.8320072142824},
#   {'id': 's8DYhX_JL_7gtgCEZy6QcA',
#    'alias': 'princess-hotel-london',
#    'name': 'Princess Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HcRri5-wyQBEOiEUCfqRuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/princess-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5289363, 'longitude': -0.1232505},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '35-37 Argyle Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1H 8EP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['35-37 Argyle Street',
#      'London WC1H 8EP',
#      'United Kingdom']},
#    'phone': '+442072786895',
#    'display_phone': '+44 20 7278 6895',
#    'distance': 1989.9397076001508},
#   {'id': '8FL5yNgR-dY83HY__6pwGg',
#    'alias': 'hotel-xenia-autograph-collection-london-6',
#    'name': 'Hotel Xenia, Autograph Collection',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9XTxiU5ox4r7HXNCkvWS8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-xenia-autograph-collection-london-6?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4950079536724,
#     'longitude': -0.189841389656067},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '160 Cromwell Road',
#     'address2': 'Kensington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW5 0TL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['160 Cromwell Road',
#      'Kensington',
#      'London SW5 0TL',
#      'United Kingdom']},
#    'phone': '+442074424242',
#    'display_phone': '+44 20 7442 4242',
#    'distance': 4223.743100304449},
#   {'id': 'CPArXY7C2-J9bPMdxImD8Q',
#    'alias': 'residence-inn-by-marriott-london-kensington-london',
#    'name': 'Residence Inn by Marriott London Kensington',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Np6BSOuExqC7TFTL96r7cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/residence-inn-by-marriott-london-kensington-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.4936447143555,
#     'longitude': -0.20218800008297},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '181-183 Warwick Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W14 8PU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['181-183 Warwick Rd',
#      'London W14 8PU',
#      'United Kingdom']},
#    'phone': '+442031467980',
#    'display_phone': '+44 20 3146 7980',
#    'distance': 5059.214250492587},
#   {'id': 'tT7r2HyAGtyekPwZ0bP5aA',
#    'alias': 'the-biltmore-mayfair-lxr-hotels-and-resorts-london',
#    'name': 'The Biltmore Mayfair, LXR Hotels & Resorts',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/I9ab5tV4y95Zq9_Cybwz1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-biltmore-mayfair-lxr-hotels-and-resorts-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.51084523852935,
#     'longitude': -0.1508711552267935},
#    'transactions': [],
#    'location': {'address1': '44 Grosvenor Square',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1K 2HP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['44 Grosvenor Square',
#      'London W1K 2HP',
#      'United Kingdom']},
#    'phone': '+442076299400',
#    'display_phone': '+44 20 7629 9400',
#    'distance': 1055.636605971994},
#   {'id': 'xxOLQvRBVjUCVKb2wjl-VA',
#    'alias': 'easyhotel-victoria-london',
#    'name': 'easyHotel - Victoria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/A-PdAWRIGNC-WqEsWqZmYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/easyhotel-victoria-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 34,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4920332, 'longitude': -0.1421055},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '34-40 Belgrave Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1RG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['34-40 Belgrave Road',
#      'London SW1V 1RG',
#      'United Kingdom']},
#    'phone': '+442078341379',
#    'display_phone': '+44 20 7834 1379',
#    'distance': 2351.9492679559935},
#   {'id': '50xBkYgaecoki59YnBH7Yg',
#    'alias': 'the-capital-hotel-apartments-and-townhouse-london',
#    'name': 'The Capital Hotel, Apartments and Townhouse',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uWxtchTvCf575C2UtU6pxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-capital-hotel-apartments-and-townhouse-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 17,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.49996, 'longitude': -0.16146},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '22-24 Basil Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 1AT',
#     'country': 'GB',
#     'state': 'ABE',
#     'display_address': ['22-24 Basil Street',
#      'London SW3 1AT',
#      'United Kingdom']},
#    'phone': '+442075895171',
#    'display_phone': '+44 20 7589 5171',
#    'distance': 2286.0263107082756},
#   {'id': 'JW_eJ4yzxjL46uUQbaZ7-w',
#    'alias': 'kip-london',
#    'name': '.Kip',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FbUVjOz0HmSwswRl0VlyDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kip-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5472762163796,
#     'longitude': -0.0562167540192604},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '7-19 Amhurst Road',
#     'address2': 'Hackney Central',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E8 1JW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['7-19 Amhurst Road',
#      'Hackney Central',
#      'London E8 1JW',
#      'United Kingdom']},
#    'phone': '+442086297884',
#    'display_phone': '+44 20 8629 7884',
#    'distance': 6715.019819159247},
#   {'id': 'rsKWux6LkLSIrXMYoNmgdg',
#    'alias': 'thanet-hotel-london',
#    'name': 'Thanet Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/a1YJTws2l7YYLuYX2-JRZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thanet-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5201551, 'longitude': -0.12396},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '8 Bedford Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 5JA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Bedford Place',
#      'London WC1B 5JA',
#      'United Kingdom']},
#    'phone': '+442075803377',
#    'display_phone': '+44 20 7580 3377',
#    'distance': 1155.4731030239177},
#   {'id': 'JipTk5aigtfNIoJ8vmIK-Q',
#    'alias': 'hilton-london-hyde-park-london-2',
#    'name': 'Hilton London Hyde Park',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oBrkE2WsG3dQm4Sefdra3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hilton-london-hyde-park-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 37,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5104863798633,
#     'longitude': -0.187543331119741},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '129 Bayswater Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 4RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['129 Bayswater Road',
#      'London W2 4RJ',
#      'United Kingdom']},
#    'phone': '+442072212217',
#    'display_phone': '+44 20 7221 2217',
#    'distance': 3579.5381591558207},
#   {'id': 'sJ7eEgT45PExqhTSk8Ujqg',
#    'alias': 'dolphin-square-hotel-london',
#    'name': 'Dolphin Square Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fgXygMnYSL9gRP3s8WLwWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dolphin-square-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 7,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4863, 'longitude': -0.136429},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Dolphin Square',
#     'address2': 'Chichester Street',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW1V 3LX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Dolphin Square',
#      'Chichester Street',
#      'London SW1V 3LX',
#      'United Kingdom']},
#    'phone': '+442077988591',
#    'display_phone': '+44 20 7798 8591',
#    'distance': 2950.793857711551},
#   {'id': 'wvO3KoWHOZW4sMebZohsjw',
#    'alias': 'doubletree-by-hilton-hotel-london-victoria-london-4',
#    'name': 'DoubleTree By Hilton Hotel London - Victoria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TIOEA4S15LjJ4AjagD4-8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doubletree-by-hilton-hotel-london-victoria-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4939289134206,
#     'longitude': -0.143322030594069},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '2 Bridge Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1QA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Bridge Place',
#      'London SW1V 1QA',
#      'United Kingdom']},
#    'phone': '+442078348123',
#    'display_phone': '+44 20 7834 8123',
#    'distance': 2163.2583537263167},
#   {'id': '-vGtr71C6VkwGPrjUsMEeQ',
#    'alias': 'pasha-hotel-london',
#    'name': 'Pasha Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wdNwppwnf0jp71tv4Bny5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pasha-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4795931, 'longitude': -0.0944206},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '158 Camberwell Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE5 0EE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['158 Camberwell Road',
#      'London SE5 0EE',
#      'United Kingdom']},
#    'phone': '+442077035054',
#    'display_phone': '+44 20 7703 5054',
#    'distance': 4690.986974076935},
#   {'id': 'IIh4xw679d5LesxgElr-0Q',
#    'alias': 'apex-city-of-london-hotel-london-2',
#    'name': 'Apex City of London Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iMCGP0hZB7BsOLouNIBygA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/apex-city-of-london-hotel-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5105825, 'longitude': -0.0793204},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '1 Seething Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC3N 4AX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['1 Seething Lane',
#      'London EC3N 4AX',
#      'United Kingdom']},
#    'phone': '+442077022020',
#    'display_phone': '+44 20 7702 2020',
#    'distance': 3927.3166131305647},
#   {'id': 'b6nFTqY896qVuKjGmRt2iw',
#    'alias': 'knightsbridge-hotel-london',
#    'name': 'Knightsbridge Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/79_lFKFsDK2gMWvH_C5bmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/knightsbridge-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 8,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4981661, 'longitude': -0.1642037},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '10 Beaufort Gardens',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 1PT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Beaufort Gardens',
#      'London SW3 1PT',
#      'United Kingdom']},
#    'phone': '+442075846300',
#    'display_phone': '+44 20 7584 6300',
#    'distance': 2550.4820018317314},
#   {'id': 'hyL2TF3aKk7MoPpJ2HUWTg',
#    'alias': 'batty-langleys-spitalfields',
#    'name': "Batty Langley's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eUBokkMXYC7JyEPXiH49qA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/batty-langleys-spitalfields?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5210115062075,
#     'longitude': -0.0783524139418201},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '12 Folgate Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Spitalfields',
#     'zip_code': 'E1 6BX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12 Folgate Street',
#      'Spitalfields E1 6BX',
#      'United Kingdom']},
#    'phone': '+442073774390',
#    'display_phone': '+44 20 7377 4390',
#    'distance': 4088.2150991350563},
#   {'id': 'XgafaGoHLw2yxJXlaJJTSA',
#    'alias': 'yotel-hounslow',
#    'name': 'Yotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DpFEU4vTbMH6tGvEMbWACQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yotel-hounslow?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.459606, 'longitude': -0.446491},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Heathrow Airport',
#     'address2': 'Terminal 4',
#     'address3': '',
#     'city': 'Hounslow',
#     'zip_code': 'TW6 3XA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Heathrow Airport',
#      'Terminal 4',
#      'Hounslow TW6 3XA',
#      'United Kingdom']},
#    'phone': '+442071001100',
#    'display_phone': '+44 20 7100 1100',
#    'distance': 22301.616514159985},
#   {'id': 'E4xZ9OAk4HlHmh6iDFLOLA',
#    'alias': 'cote-marylebone-london',
#    'name': 'Cote Marylebone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GaUDFS91l5ZqN-ce7d7VAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cote-marylebone-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5212173, 'longitude': -0.1515591},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '26-27 Devonshire Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1G 6PL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26-27 Devonshire Street',
#      'London W1G 6PL',
#      'United Kingdom']},
#    'phone': '+442072244480',
#    'display_phone': '+44 20 7224 4480',
#    'distance': 1418.1630901901838},
#   {'id': 'BlC3OB8CkXHeb4LJW0548w',
#    'alias': 'hub-by-premier-inn-london-3',
#    'name': 'Hub by Premier Inn',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hvIwt6Rp00F2W5K4O2SgPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hub-by-premier-inn-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5336638077301,
#     'longitude': -0.122056831444198},
#    'transactions': [],
#    'location': {'address1': '50 Wharfdale Rd',
#     'address2': "King's Cross",
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N1 9FA',
#     'country': 'GB',
#     'state': 'ABE',
#     'display_address': ['50 Wharfdale Rd',
#      "King's Cross",
#      'London N1 9FA',
#      'United Kingdom']},
#    'phone': '+443333213104',
#    'display_phone': '+44 333 321 3104',
#    'distance': 2507.6924296352504},
#   {'id': 'rCAmc_cKX5KAUHrZ9MUepg',
#    'alias': 'doubletree-by-hilton-hotel-london-west-end-london-3',
#    'name': 'DoubleTree by Hilton Hotel London - West End',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/px9AuLBF4PqNTSUMsHyRtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doubletree-by-hilton-hotel-london-west-end-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5202715055578,
#     'longitude': -0.121863203559605},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '92 Southampton Row',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 4BH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['92 Southampton Row',
#      'London WC1B 4BH',
#      'United Kingdom']},
#    'phone': '+442072422828',
#    'display_phone': '+44 20 7242 2828',
#    'distance': 1278.5029739966878},
#   {'id': '4aR691JVCwVCsDfLgnQvsw',
#    'alias': 'apex-temple-court-hotel-london',
#    'name': 'Apex Temple Court Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eNBgEay0yAW4XZw0HsknQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/apex-temple-court-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5137832, 'longitude': -0.1088746},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "1-2 Serjeants' Inn",
#     'address2': 'Fleet Street',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4Y 1LL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["1-2 Serjeants' Inn",
#      'Fleet Street',
#      'London EC4Y 1LL',
#      'United Kingdom']},
#    'phone': '+442030044141',
#    'display_phone': '+44 20 3004 4141',
#    'distance': 1876.9848814314382},
#   {'id': 'ICCD8Ur7Eo_FtqIbPcHlSw',
#    'alias': 'mad-hatter-hotel-london',
#    'name': 'Mad Hatter Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/I034DXD1bUrJnUwtx5YSVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mad-hatter-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 29,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.507024, 'longitude': -0.104918},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '3-7 Stamford Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 9NY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['3-7 Stamford Street',
#      'London SE1 9NY',
#      'United Kingdom']},
#    'phone': '+442074019222',
#    'display_phone': '+44 20 7401 9222',
#    'distance': 2243.080956633813},
#   {'id': 'QH-S2t3_En66aEbB4IRmzQ',
#    'alias': '130-queens-gate-apartments-london',
#    'name': "130 Queen's Gate Apartments",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tNwaEXwTZNedkBIsBRlnrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/130-queens-gate-apartments-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'vacation_rentals', 'title': 'Vacation Rentals'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4945286, 'longitude': -0.1785535},
#    'transactions': [],
#    'location': {'address1': "130 Queen's Gate",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 5LE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["130 Queen's Gate",
#      'London SW7 5LE',
#      'United Kingdom']},
#    'phone': '+442079385930',
#    'display_phone': '+44 20 7938 5930',
#    'distance': 3582.849987541958},
#   {'id': '-tF5AziiEuDVKS75tkd9mg',
#    'alias': 'premier-travel-inn-london-7',
#    'name': 'Premier Travel Inn',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lXox4gxJXNbbIs_flKuqDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/premier-travel-inn-london-7?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 51.551546, 'longitude': -0.167221},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '215 Haverstock Hill',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW3 4RB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['215 Haverstock Hill',
#      'London NW3 4RB',
#      'United Kingdom']},
#    'phone': '+448708506328',
#    'display_phone': '+44 870 850 6328',
#    'distance': 4813.4538268564365},
#   {'id': 'Len6R7Nkzu8AGii_hLBIMw',
#    'alias': 'holiday-inn-london-oxford-circus-london',
#    'name': 'Holiday Inn London - Oxford Circus',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lNF-2jHr6r34uyTgA6z4vQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holiday-inn-london-oxford-circus-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 51.5148920933946,
#     'longitude': -0.147197170135479},
#    'transactions': [],
#    'location': {'address1': '57-59 Welbeck St',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1G 9BL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57-59 Welbeck St',
#      'London W1G 9BL',
#      'United Kingdom']},
#    'phone': '+44442079354442',
#    'display_phone': '+44 442079354442',
#    'distance': 810.8110806886389},
#   {'id': 'O39jKovoeE6jZBvX4yt1vA',
#    'alias': 'the-zetter-townhouse-marylebone-london',
#    'name': 'The Zetter Townhouse Marylebone',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3rM_qpydgQGNMqNmvW8RDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-zetter-townhouse-marylebone-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5148506164551,
#     'longitude': -0.158677995204926},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '28-30 Seymour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7JB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28-30 Seymour Street',
#      'London W1H 7JB',
#      'United Kingdom']},
#    'phone': '+442073244544',
#    'display_phone': '+44 20 7324 4544',
#    'distance': 1580.0507290603184},
#   {'id': '85nwHxYWNfqGcvxRyI4HyQ',
#    'alias': 'no-5-london',
#    'name': 'No 5',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DyH1aKwP5sw5pYHeWwJTRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/no-5-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.51664, 'longitude': -0.14399},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '5 Cavendish Sq',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1G 0PG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['5 Cavendish Sq', 'London W1G 0PG', 'United Kingdom']},
#    'phone': '+442070795000',
#    'display_phone': '+44 20 7079 5000',
#    'distance': 708.1588477849116},
#   {'id': 'fJ1G0mb0EMQ3qBlx9dRv9g',
#    'alias': 'the-dining-room-at-the-goring-hotel-london',
#    'name': 'The Dining Room at The Goring Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/i7pFuNEZzinIKirZt_CtGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dining-room-at-the-goring-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.497484, 'longitude': -0.145575},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '15 Beeston Place',
#     'address2': 'Grosvenor Gardens',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1W 0JW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Beeston Place',
#      'Grosvenor Gardens',
#      'London SW1W 0JW',
#      'United Kingdom']},
#    'phone': '+442073969000',
#    'display_phone': '+44 20 7396 9000',
#    'distance': 1823.5531621164491},
#   {'id': 'PV0o6dOcmEnaSJMkuZuo7Q',
#    'alias': 'holiday-inn-hotel-london-kensington-forum-london',
#    'name': 'Holiday Inn Hotel London Kensington Forum',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y1h2_1YiSmLxRVqWQi9j2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holiday-inn-hotel-london-kensington-forum-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 64,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.4942881090697,
#     'longitude': -0.185131809694077},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '97 Cromwell Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 4DN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['97 Cromwell Road',
#      'London SW7 4DN',
#      'United Kingdom']},
#    'phone': '+448719429100',
#    'display_phone': '+44 871 942 9100',
#    'distance': 3979.783314357948},
#   {'id': 'HRRX5k8fDPT85sgtqmzR9Q',
#    'alias': 'the-caesar-hotel-4-london',
#    'name': 'The Caesar Hotel 4',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nulOwllgFs0g8Hxl-zy_CA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-caesar-hotel-4-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5135917, 'longitude': -0.1827586},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '26-33 Queens Gardens',
#     'address2': 'Hyde Park',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3BE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26-33 Queens Gardens',
#      'Hyde Park',
#      'London W2 3BE',
#      'United Kingdom']},
#    'phone': '+442072620022',
#    'display_phone': '+44 20 7262 0022',
#    'distance': 3239.8593059831496},
#   {'id': '-A-AKE17XHntNugiK7KPzg',
#    'alias': 'london-marriott-hotel-marble-arch-london-2',
#    'name': 'London Marriott Hotel Marble Arch',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QYaA_9MWF1832ZE9ZiZn6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/london-marriott-hotel-marble-arch-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 46,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5164128020252,
#     'longitude': -0.163492229341955},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '134 George Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 5DN',
#     'country': 'GB',
#     'state': 'LND',
#     'display_address': ['134 George Street',
#      'London W1H 5DN',
#      'United Kingdom']},
#    'phone': '+442077231277',
#    'display_phone': '+44 20 7723 1277',
#    'distance': 1946.5459099161774},
#   {'id': 'xT0EWDmBEe52C8rxXBsoBQ',
#    'alias': 'tune-hotel-london-2',
#    'name': 'Tune Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Cgqyvr5nKBQlgeyfdvPPfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tune-hotel-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5209666, 'longitude': -0.0776169},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '13/15 Folgate Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 6BX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['13/15 Folgate Street',
#      'London E1 6BX',
#      'United Kingdom']},
#    'phone': '+442074560400',
#    'display_phone': '+44 20 7456 0400',
#    'distance': 4136.757608253972},
#   {'id': 'cFPi4GEibfqa8bYkLcMOKw',
#    'alias': 'the-zetter-hotel-london',
#    'name': 'The Zetter Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0jfpRStWhVkpgjweC-Wu7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-zetter-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 43,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.522758, 'longitude': -0.103696},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '86-88 Clerkenwell Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1M 5RJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['86-88 Clerkenwell Road',
#      'London EC1M 5RJ',
#      'United Kingdom']},
#    'phone': '+442073244444',
#    'display_phone': '+44 20 7324 4444',
#    'distance': 2484.6779114928086}],
#  'total': 240,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndh4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Lodging": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
#                                          Lodging    Type Price Rating  \
# 0                       The Rubens at the Palace  Hotels   £££    4.5
# 1  Grand Residences by Marriott - Mayfair-London  Hotels  ££££    4.5
# 2                                    The Curtain  Hotels    ££    4.5
# 3                          Country Inns & Suites  Hotels   £££    1.5
# 4                               The Holmes Hotel  Hotels    ££    3.5
#
#                      Address        Lat       Lng  \
# 0  39 Buckingham Palace Road  51.498265 -0.143500
# 1             47 Park Street  51.511129 -0.154971
# 2              45 Curtain Rd  51.523699 -0.080603
# 3   110 Great Russell Street  51.517514 -0.129478
# 4         83 Chiltern Street  51.521055 -0.156073
#
#                                                  url                      ID
# 0  https://www.yelp.com/biz/the-rubens-at-the-pal...  Kfd_kXdY_dyyx2FJBXVXTw
# 1  https://www.yelp.com/biz/grand-residences-by-m...  tjx9QUBMw3kCGzepS10u2Q
# 2  https://www.yelp.com/biz/the-curtain-london?ad...  VO3LfCg4ueYzKKx-PwG-Wg
# 3  https://www.yelp.com/biz/country-inns-and-suit...  R7jHFXhXNMaDBGBcmMPmUA
# 4  https://www.yelp.com/biz/the-holmes-hotel-lond...  eRsagtXFoJIBiszGWG8mQQ

# %%
london_hotels_df = pd.concat([df1,df2,df3,df4], sort=True)
london_hotels_df.shape
# Out:
# (200, 9)

# %%
column_order = ["Lodging","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_hotels_df = london_hotels_df[column_order]
london_hotels_df = london_hotels_df.sort_values(["Type"], ascending=True)
london_hotels_df = london_hotels_df.reset_index(drop=True)
london_hotels_df
# Out:
#                                                Lodging                   Type  \
# 0                                    Seven Dials Hotel        Bed & Breakfast
# 1                                           69TheGrove        Bed & Breakfast
# 2                  The Dining Room at The Goring Hotel                British
# 3                                       Hotel Chocolat   Chocolatiers & Shops
# 4                        Hampstead Village Guest House           Guest Houses
# 5                                        Hotel Montana                 Hotels
# 6                                         The Draycott                 Hotels
# 7                                         Sanctum Soho                 Hotels
# 8                                         Holiday Inn                  Hotels
# 9                           Hilton London Tower Bridge                 Hotels
# 10                                         Aster House                 Hotels
# 11                               Nobu Hotel Shoreditch                 Hotels
# 12                     Sheraton Grand London Park Lane                 Hotels
# 13                                       Brown's Hotel                 Hotels
# 14                                             DORSETT                 Hotels
# 15                           The Bailey’s Hotel London                 Hotels
# 16                                       Club Quarters                 Hotels
# 17                Wyndham Grand London Chelsea Harbour                 Hotels
# 18                                 Lincoln House Hotel                 Hotels
# 19                      No Ten Manchester Street Hotel                 Hotels
# 20                                        The Beaumont                 Hotels
# 21                                  The May Fair Hotel                 Hotels
# 22                                     COMO The Halkin                 Hotels
# 23                                 Regency House Hotel                 Hotels
# 24                                          The Goring                 Hotels
# 25              London Marriott Hotel Grosvenor Square                 Hotels
# 26                                   London City Hotel                 Hotels
# 27                                         Holiday Inn                 Hotels
# 28                                      Blair Victoria                 Hotels
# 29                                The Marylebone Hotel                 Hotels
# ..                                                 ...                    ...
# 170                          ​M by Montcalm Shoreditch                 Hotels
# 171                                         Travelodge                 Hotels
# 172                                   Royal Park Hotel                 Hotels
# 173                              St Martins Lane Hotel                 Hotels
# 174                                   Haverstock Hotel                 Hotels
# 175                                       The Berkeley                 Hotels
# 176                                    Rosewood London                 Hotels
# 177                                  St David's Hotels                 Hotels
# 178                   Radisson Blu Edwardian Hampshire                 Hotels
# 179                           Plaza On the River Hotel                 Hotels
# 180                     Holiday Inn London Camden Lock                 Hotels
# 181                              The Nadler Kensington                 Hotels
# 182                                     The California                 Hotels
# 183                                The Stafford London                 Hotels
# 184                                The Hoxton, Holborn                 Hotels
# 185                             Hilton London Bankside                 Hotels
# 186                                        Premier Inn                 Hotels
# 187                 London Marriott Hotel Regents Park                 Hotels
# 188               Park Plaza Westminster Bridge London                 Hotels
# 189                           Amba Hotel Charing Cross                 Hotels
# 190                                    The Nadler Soho                 Hotels
# 191                                        St. James's                 Hotels
# 192                                      Strand Palace                 Hotels
# 193  DoubleTree by Hilton Hotel London - Tower of L...                 Hotels
# 194               Hyatt Regency London - The Churchill                 Hotels
# 195                          Great Scotland Yard Hotel                 Hotels
# 196                                   The Zetter Hotel                 Hotels
# 197                                    The Shaftesbury                   Pubs
# 198                        130 Queen's Gate Apartments       Vacation Rentals
# 199                      De Vere Grand Connaught Rooms  Venues & Event Spaces
#
#     Rating Price                      Address        Lat       Lng  \
# 0                           7 Monmouth Street  51.514900 -0.126723
# 1                           69 Vauxhall Grove  51.484890 -0.120853
# 2        4  ££££             15 Beeston Place  51.497484 -0.145575
# 3      4.5    ££            4 Monmouth Street  51.514764 -0.126962
# 4      3.5   £££               2 Kemplay Road  51.555807 -0.172092
# 5        4     £          16-17 Argyle Square  51.529136 -0.121758
# 6        5   £££           26 Cadogan Gardens  51.493061 -0.159959
# 7      3.5   £££            20 Warwick Street  51.511668 -0.138387
# 8      3.5    ££            3 Berkeley Street  51.507709 -0.142347
# 9        4   £££          5 More London Place  51.504639 -0.082443
# 10     4.5   £££               3 Sumner Place  51.492574 -0.175449
# 11       4  ££££          10-50 Willow Street  51.525072 -0.082681
# 12     3.5   £££                   Piccadilly  51.504600 -0.146992
# 13       4   £££          30 Albemarle Street  51.509176 -0.142293
# 14       4    ££      58 Shepherds Bush Green  51.504057 -0.224675
# 15     3.5    ££          140 Gloucester Road  51.494007 -0.182480
# 16       4    ££      8 Northumberland Avenue  51.506960 -0.126023
# 17     4.5  ££££              Chelsea Harbour  51.477365 -0.185847
# 18       4    ££          33 Gloucester Place  51.517590 -0.158048
# 19       4   £££         10 Manchester Street  51.518800 -0.153839
# 20     4.5   £££           8 Balderton Street  51.513060 -0.152256
# 21     3.5   £££               May Fair Hotel  51.508140 -0.143972
# 22       5   £££                Halkin Street  51.500831 -0.151952
# 23     3.5    ££   71 Gower Street Bloomsbury  51.521685 -0.132178
# 24     4.5  ££££             15 Beeston Place  51.497620 -0.145632
# 25       4   £££             Grosvenor Square  51.512595 -0.150771
# 26       4    ££      200 Borough High Street  51.501185 -0.093536
# 27       3    ££         57-59 Welbeck Street  51.516932 -0.149286
# 28       1     £            78-84 Warwick Way  51.491444 -0.142120
# 29       4   £££            47 Welbeck Street  51.518068 -0.149775
# ..     ...   ...                          ...        ...       ...
# 170    2.5   £££            151-157 City Road  51.527662 -0.088896
# 171    3.5     £                       Unit 1  51.522581 -0.086948
# 172    4.5   £££         3 Westbourne Terrace  51.514050 -0.176531
# 173      4   £££          45 St Martin's Lane  51.510378 -0.126805
# 174                       154 Haverstock Hill  51.549044 -0.161966
# 175    4.5  ££££                 Wilton Place  51.501907 -0.156179
# 176    4.5  ££££             252 High Holborn  51.517422 -0.117811
# 177    3.5    ££         14-20 Norfolk Square  51.516004 -0.173908
# 178      4   £££       31-36 Liecester Square  51.509848 -0.129852
# 179    3.5   £££                         None  51.500200 -0.126236
# 180    3.5   £££            30 Jamestown Road  51.540295 -0.145859
# 181    4.5    ££        25 Courtfield Gardens  51.493031 -0.190123
# 182    3.5     £          4-8 Belgrove Street  51.529520 -0.123414
# 183      5  ££££       16-18 St James's Place  51.505918 -0.140391
# 184      4    ££       199 - 206 High Holborn  51.517240 -0.122063
# 185    4.5   £££     2-8 Great Suffolk Street  51.505734 -0.101752
# 186                     27-29 Red Lion Street  51.519495 -0.116961
# 187    3.5    ££        128 King Henry's Road  51.542048 -0.170148
# 188    3.5   £££  200 Westminster Bridge Road  51.500945 -0.116817
# 189    4.5   £££                   The Strand  51.508459 -0.124932
# 190    4.5   £££           10 Carlisle Street  51.514739 -0.134111
# 191    4.5  ££££               7-8 Park Place  51.506115 -0.140311
# 192      3    ££                   372 Strand  51.511099 -0.120710
# 193      4   £££               7 Pepys Street  51.510906 -0.078279
# 194    4.5   £££            30 Portman Square  51.515436 -0.156958
# 195                   3-5 Great Scotland Yard  51.506295 -0.126285
# 196      4   £££       86-88 Clerkenwell Road  51.522758 -0.103696
# 197                  39-45 Shaftesbury Avenue  51.511824 -0.132904
# 198                          130 Queen's Gate  51.494529 -0.178554
# 199                  61-65 Great Queen Street  51.515555 -0.120640
#
#                                                    url                      ID
# 0
# 1
# 2    https://www.yelp.com/biz/the-dining-room-at-th...  fJ1G0mb0EMQ3qBlx9dRv9g
# 3    https://www.yelp.com/biz/hotel-chocolat-london...  n5qSC3ssty-SFuI7CcFbBw
# 4    https://www.yelp.com/biz/hampstead-village-gue...  0wGix_lvipMqeu9p64r3Dg
# 5    https://www.yelp.com/biz/hotel-montana-london?...  BCnri2b-wmuIzmivwAMhKg
# 6    https://www.yelp.com/biz/the-draycott-london?a...  jEa-BJscV6RIxatz335sAw
# 7    https://www.yelp.com/biz/sanctum-soho-london?a...  R6v-A-TETGftAgOHTWOUhg
# 8    https://www.yelp.com/biz/holiday-inn-london-5?...  ZAxCJK2r9Okx5nTjGGf-rw
# 9    https://www.yelp.com/biz/hilton-london-tower-b...  loeMRdWerolE9W1j5f2rwA
# 10   https://www.yelp.com/biz/aster-house-london?ad...  6nApL63kBo4oEFA-H3PMzw
# 11   https://www.yelp.com/biz/nobu-hotel-shoreditch...  OPtqyoClLHUMo5Tr3Os4kQ
# 12   https://www.yelp.com/biz/sheraton-grand-london...  ugLZ4kaMSHiUjkt36XxqRA
# 13   https://www.yelp.com/biz/browns-hotel-london?a...  PpTb-RwM8yqtq6mtOn6Yuw
# 14   https://www.yelp.com/biz/dorsett-london-2?adju...  AW3ZBSBgVBYU3k6nWi7ygg
# 15   https://www.yelp.com/biz/the-baileys-hotel-lon...  OQtI-q8Im3ix-eBoEOeeJQ
# 16   https://www.yelp.com/biz/club-quarters-london-...  Vp8V6u9VooYcnEJBv4WvAA
# 17   https://www.yelp.com/biz/wyndham-grand-london-...  oQFU_E6Ru1_s5jIJ9VdNNA
# 18   https://www.yelp.com/biz/lincoln-house-hotel-l...  vCnwGIj73ixitVM5lA_cFQ
# 19   https://www.yelp.com/biz/no-ten-manchester-str...  -BcaEVNIiQgi6rXb57Rjrg
# 20   https://www.yelp.com/biz/the-beaumont-london-2...  O_d-P1JDlElAdcIvMsqwcQ
# 21   https://www.yelp.com/biz/the-may-fair-hotel-lo...  1ZVWnxQW5GFxtQnXNzN3ZQ
# 22   https://www.yelp.com/biz/como-the-halkin-londo...  OKMKLgs8iVNQ9lU51UPDSQ
# 23   https://www.yelp.com/biz/regency-house-hotel-l...  Ttvhy6KPXVtGQh8yopHstQ
# 24   https://www.yelp.com/biz/the-goring-london?adj...  -Uyd8UlBLO6lqPC8VK9INg
# 25   https://www.yelp.com/biz/london-marriott-hotel...  mHtH47UEuSZGg2RJ1nYBIQ
# 26   https://www.yelp.com/biz/london-city-hotel-lon...  7lcPj3CpX9bnXpHzvan79Q
# 27   https://www.yelp.com/biz/holiday-inn-london-29...  LhOP8kZzvSnYTAaaopp7Bg
# 28   https://www.yelp.com/biz/blair-victoria-london...  AaByHFUY2eLbN9T-0JpDrQ
# 29   https://www.yelp.com/biz/the-marylebone-hotel-...  NDkrcHjLSobKPzbwFLF3Vw
# ..                                                 ...                     ...
# 170  https://www.yelp.com/biz/m-by-montcalm-shoredi...  abr3a1-iKYcFR1XinizgBw
# 171  https://www.yelp.com/biz/travelodge-london-23?...  O_oje-iRyBY-SpYlrO3VKg
# 172  https://www.yelp.com/biz/royal-park-hotel-lond...  3KYZAtAgFqjIESnPGBt2Jw
# 173  https://www.yelp.com/biz/st-martins-lane-hotel...  SjGYpd_bzEYDW9PkMzvE_g
# 174
# 175  https://www.yelp.com/biz/the-berkeley-london?a...  ACZzwkEWIKXg0MMjDr8LiQ
# 176  https://www.yelp.com/biz/rosewood-london-londo...  UDSI_z1-edmeNtg3YOy-SQ
# 177  https://www.yelp.com/biz/st-davids-hotels-lond...  _jFVWny91oy62o5uNIvSSw
# 178  https://www.yelp.com/biz/radisson-blu-edwardia...  bqqtUZG_6913SWAMd597Ug
# 179  https://www.yelp.com/biz/plaza-on-the-river-ho...  jRduIw5aVQ8fO00Ta3wU8g
# 180  https://www.yelp.com/biz/holiday-inn-london-ca...  jRaxuGSxXeqO4KSpPyvLBA
# 181  https://www.yelp.com/biz/the-nadler-kensington...  wuYwGXyR6RFqpFsE-28Fmg
# 182  https://www.yelp.com/biz/the-california-london...  z3nQWuGTiVqy4tbU13ab7A
# 183  https://www.yelp.com/biz/the-stafford-london-l...  SXUptNI-yemUbrImbl66Ow
# 184  https://www.yelp.com/biz/the-hoxton-holborn-lo...  jtbgfUOhppBTZCLIpgK0bA
# 185  https://www.yelp.com/biz/hilton-london-banksid...  zfBM08Y_1DqFccBfwsdmMw
# 186
# 187  https://www.yelp.com/biz/london-marriott-hotel...  ANEIyj70aOKVsEd6DU40Sg
# 188  https://www.yelp.com/biz/park-plaza-westminste...  uZ7itHFaLK1tYm8WP0hLqA
# 189  https://www.yelp.com/biz/amba-hotel-charing-cr...  vVlTW6ylANoAEmTttU2Y4A
# 190  https://www.yelp.com/biz/the-nadler-soho-londo...  UC6Rwig5kN_0wpFG0T9mTg
# 191  https://www.yelp.com/biz/st-jamess-st-jamess?a...  0mAnAZuRvYQEXffLRcLCzg
# 192  https://www.yelp.com/biz/strand-palace-london-...  h65olqVVtg_E3BlkVdh2jg
# 193  https://www.yelp.com/biz/doubletree-by-hilton-...  qT3_PDPveYLjDJUuc94iUw
# 194  https://www.yelp.com/biz/hyatt-regency-london-...  5VQzRhyilXNDPL4FuVouxw
# 195
# 196  https://www.yelp.com/biz/the-zetter-hotel-lond...  cFPi4GEibfqa8bYkLcMOKw
# 197
# 198
# 199
#
# [200 rows x 9 columns]

# %%
# Save the dataframe to a csv file
london_hotels_df.to_csv('Resources/London_Hotels.csv')
