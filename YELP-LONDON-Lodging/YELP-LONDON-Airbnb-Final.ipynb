# %% [markdown]
# LONDON HOTELS, TYPE, LOCATION, RATINGS, and LOCATION

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# Import API key
from config import api_key

# %% [markdown]
# Yelp Business Search API Documentation: https://www.yelp.com/developers/documentation/v3/business_search

# %%
# headers contain the api key.
# reference this site for set up: https://www.justintodata.com/python-api-call-to-request-data/
headers = {"Authorization": "Bearer {}".format(api_key)}
search_api_url = "https://api.yelp.com/v3/businesses/search"

# %% [markdown]
# Yelp Business Search API default returns twenty records at a time. However, the API allows fifty records per call by adding a limit to the parameters, with four calls maximum before returning an error. So, the maximum dataset size is 200 records.

# %%
#First set of 50 records 0-50
lndh_params1 = {"term":"airbnb","location":"London","limit":50,"offset":0}
lndh_response1 = requests.get(search_api_url, headers=headers, params=lndh_params1)
lndh1 = lndh_response1.json()
display(lndh1)
#print(lndh_response1.url)
#print(lndh_response1.status_code)
# Out:
# {'businesses': [{'id': 'ruGbkfDHp_xDID_My1k43g',
#    'alias': 'sohostel-london',
#    'name': 'Sohostel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IIn7_D3EItLXRJNxkrLjGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sohostel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'hostels', 'title': 'Hostels'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5150779089329,
#     'longitude': -0.133680928287407},
#    'transactions': [],
#    'location': {'address1': '91 Dean Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1D 3SY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['91 Dean Street', 'London W1D 3SY', 'United Kingdom']},
#    'phone': '+442088215154',
#    'display_phone': '+44 20 8821 5154',
#    'distance': 294.8769691886493},
#   {'id': 'tV1LcufPT7nToywRIlx96Q',
#    'alias': 'juliettes-guest-house-notting-hill',
#    'name': "Juliette's Guest House",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WHw6Bya-MlJYoYyrLMs9iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/juliettes-guest-house-notting-hill?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'guesthouses', 'title': 'Guest Houses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512094, 'longitude': -0.197425},
#    'transactions': [],
#    'location': {'address1': '29 Dawson Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'Notting Hill',
#     'zip_code': 'W2 4TH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['29 Dawson Pl',
#      'Notting Hill W2 4TH',
#      'United Kingdom']},
#    'phone': '+44442077922401',
#    'display_phone': '+44 442077922401',
#    'distance': 4254.556529658386},
#   {'id': 'hGJkHYD10mPIh-R_xrUQNg',
#    'alias': 'the-kensington-hotel-london',
#    'name': 'The Kensington Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oir5rOUGDB_jrvp4_u1z6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-kensington-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 45,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.492559, 'longitude': -0.1780645},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "109 - 113 Queen's Gate",
#     'address2': '',
#     'address3': 'South Kensington',
#     'city': 'London',
#     'zip_code': 'SW7 5LR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["109 - 113 Queen's Gate",
#      'South Kensington',
#      'London SW7 5LR',
#      'United Kingdom']},
#    'phone': '+442075896300',
#    'display_phone': '+44 20 7589 6300',
#    'distance': 3684.881921445302},
#   {'id': 'VWTYSnuV3IDJJjSk7kzMkw',
#    'alias': 'residence-inn-by-marriott-london-2',
#    'name': 'Residence Inn by Marriott',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/E-Gq4iYqQodbSS155uNDzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/residence-inn-by-marriott-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4987162467047,
#     'longitude': -0.0841357962951861},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '201 - 211 Long Lane',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 4PN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['201 - 211 Long Lane',
#      'London SE1 4PN',
#      'United Kingdom']},
#    'phone': '+442031467344',
#    'display_phone': '+44 20 3146 7344',
#    'distance': 3915.122957001724},
#   {'id': '1tyiyRStaEuq_0hBc6ypCg',
#    'alias': 'citizenm-hotel-london-4',
#    'name': 'CitizenM Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/L3g_0J75dMDFPb9DUF-mgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/citizenm-hotel-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 79,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5051155599748,
#     'longitude': -0.098283347856649},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Lavington Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 0NZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Lavington Street',
#      'London SE1 0NZ',
#      'United Kingdom']},
#    'phone': '+442035191680',
#    'display_phone': '+44 20 3519 1680',
#    'distance': 2744.8713574254475},
#   {'id': 'hfpBEYTt58gr5Nxk4W0W7g',
#    'alias': 'the-z-hotel-london-3',
#    'name': 'The Z Hotel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/57gYrJyMgXpol0aERFimGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-z-hotel-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.518144, 'longitude': -0.158343},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '51 Gloucester Place',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1U 8JF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['51 Gloucester Place',
#      'London W1U 8JF',
#      'United Kingdom']},
#    'phone': '+442035513700',
#    'display_phone': '+44 20 3551 3700',
#    'distance': 1654.7765832399514},
#   {'id': 'NOyRSiG5k4BmBlhyOXxZAg',
#    'alias': 'travelodge-hotel-london-10',
#    'name': 'Travelodge Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1t7FTPWzweu-JnT3S2i4Iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/travelodge-hotel-london-10?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 4,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5006142, 'longitude': -0.1078255},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '195 -203 Waterloo Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 8UX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['195 -203 Waterloo Road',
#      'London SE1 8UX',
#      'United Kingdom']},
#    'phone': '+448719846291',
#    'display_phone': '+44 871 984 6291',
#    'distance': 2386.25425808031},
#   {'id': 'wB3gKeVj6hoSkfXN7kMK7w',
#    'alias': 'london-short-letting-london',
#    'name': 'London Short Letting',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/london-short-letting-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'realestate', 'title': 'Real Estate'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.51769, 'longitude': -0.154474},
#    'transactions': [],
#    'location': {'address1': '102 George Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1U 8NT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['102 George Street',
#      'London W1U 8NT',
#      'United Kingdom']},
#    'phone': '+442074865335',
#    'display_phone': '+44 20 7486 5335',
#    'distance': 1390.4604363525045},
#   {'id': 'WSmvqMrRs3P-CgTQwdws3g',
#    'alias': 'sanderson-hotel-london-3',
#    'name': 'Sanderson Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qNFWWDtJrITpQuMhpII0Wg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sanderson-hotel-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 107,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.517469, 'longitude': -0.13724},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '50 Berners Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 3NG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['50 Berners Street',
#      'London W1T 3NG',
#      'United Kingdom']},
#    'phone': '+442073001400',
#    'display_phone': '+44 20 7300 1400',
#    'distance': 513.9339331622115},
#   {'id': 'I-9u_WC-WBqlsNSJ324f3A',
#    'alias': 'olympic-house-london',
#    'name': 'Olympic House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VevXsw0rrETYqTaGoNSJdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olympic-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5154356, 'longitude': -0.1729402},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '138-140 Sussex Gardens',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1UB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['138-140 Sussex Gardens',
#      'London W2 1UB',
#      'United Kingdom']},
#    'phone': '+442077235935',
#    'display_phone': '+44 20 7723 5935',
#    'distance': 2557.4640570876386},
#   {'id': 'qp90wS_xYlywsxTwzzqxRA',
#    'alias': 'emirates-air-line-greenwich-peninsula-london',
#    'name': 'Emirates Air Line - Greenwich Peninsula',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TzV0c1ryd3_bckpsB242mQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/emirates-air-line-greenwich-peninsula-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 30,
#    'categories': [{'alias': 'publictransport',
#      'title': 'Public Transportation'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.499783261712,
#     'longitude': 0.00820117802565079},
#    'transactions': [],
#    'location': {'address1': 'Greenwich Peninsula',
#     'address2': 'Unit 1 Emirates Cable Car Terminal',
#     'address3': 'Edmund Halley Way',
#     'city': 'London',
#     'zip_code': 'SE10 0FR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Greenwich Peninsula',
#      'Unit 1 Emirates Cable Car Terminal',
#      'Edmund Halley Way',
#      'London SE10 0FR',
#      'United Kingdom']},
#    'phone': '+44443432221234',
#    'display_phone': '+44 443432221234',
#    'distance': 10082.2278763228},
#   {'id': 'gYa5BUZGmWHa0J91SnprlA',
#    'alias': 'keynest-smart-key-exchange-london',
#    'name': 'Keynest - Smart Key Exchange',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KZm5erWotyqgKpr5Z1MXqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/keynest-smart-key-exchange-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'realestatesvcs',
#      'title': 'Real Estate Services'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 51.5142645, 'longitude': -0.0912244},
#    'transactions': [],
#    'location': {'address1': "1 Frederick's Pl",
#     'address2': '',
#     'address3': 'London',
#     'city': 'London',
#     'zip_code': 'EC2R 8AE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["1 Frederick's Pl",
#      'London',
#      'London EC2R 8AE',
#      'United Kingdom']},
#    'phone': '+442036334599',
#    'display_phone': '+44 20 3633 4599',
#    'distance': 3099.4806499310785},
#   {'id': 'LA7vhjFnh9vwKLVYxqn5Aw',
#    'alias': 'point-a-hotel-london-westminster-london',
#    'name': 'Point A Hotel London - Westminster',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/point-a-hotel-london-westminster-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.4991150896639,
#     'longitude': -0.112530402839184},
#    'transactions': [],
#    'location': {'address1': '118-120 Westminster Bridge Rd',
#     'address2': '',
#     'address3': 'Lambeth',
#     'city': 'London',
#     'zip_code': 'SE1 7RW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['118-120 Westminster Bridge Rd',
#      'Lambeth',
#      'London SE1 7RW',
#      'United Kingdom']},
#    'phone': '+442076339317',
#    'display_phone': '+44 20 7633 9317',
#    'distance': 2226.253318611241},
#   {'id': 'Ba9zwE0V_gj_JaIgdxe8sA',
#    'alias': 'leman-locke-london',
#    'name': 'Leman Locke',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mg6_46y7ocI96qsMSne2rA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/leman-locke-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5145665, 'longitude': -0.0710777},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '15 Leman Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E1 8EN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15 Leman Street', 'London E1 8EN', 'United Kingdom']},
#    'phone': '+441179745936',
#    'display_phone': '+44 117 974 5936',
#    'distance': 4507.885337771772},
#   {'id': '1wuvVd56vMs4NTFva-nMmw',
#    'alias': 'the-dictionary-hostel-london',
#    'name': 'The Dictionary Hostel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/l6xpYTwYmM2u2l5A5Ed9yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dictionary-hostel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'hostels', 'title': 'Hostels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5277074573188,
#     'longitude': -0.0778712770395991},
#    'transactions': [],
#    'location': {'address1': '12-20 Kingsland Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'E2 8DA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['12-20 Kingsland Road',
#      'London E2 8DA',
#      'United Kingdom']},
#    'phone': '+442076132784',
#    'display_phone': '+44 20 7613 2784',
#    'distance': 4345.77759217616},
#   {'id': 'GFgFEF4ghF1aqohh54klXw',
#    'alias': 'premier-inn-london-33',
#    'name': 'Premier Inn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RXbeDRz7d59HRaKz0I6Pwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/premier-inn-london-33?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5026057302504,
#     'longitude': -0.1181543888855},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'County Hall',
#     'address2': 'Belvedere Road',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 7PB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['County Hall',
#      'Belvedere Road',
#      'London SE1 7PB',
#      'United Kingdom']},
#    'phone': '+448715278648',
#    'display_phone': '+44 871 527 8648',
#    'distance': 1676.830473273192},
#   {'id': 'CPArXY7C2-J9bPMdxImD8Q',
#    'alias': 'residence-inn-by-marriott-london-kensington-london',
#    'name': 'Residence Inn by Marriott London Kensington',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Np6BSOuExqC7TFTL96r7cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/residence-inn-by-marriott-london-kensington-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.4936447143555,
#     'longitude': -0.20218800008297},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '181-183 Warwick Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W14 8PU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['181-183 Warwick Rd',
#      'London W14 8PU',
#      'United Kingdom']},
#    'phone': '+442031467980',
#    'display_phone': '+44 20 3146 7980',
#    'distance': 5059.214250492587},
#   {'id': 'mhy7rOYXBZe9Mkh4ItRAsg',
#    'alias': 'belle-cour-hotel-and-spa-london',
#    'name': 'Belle Cour Hotel & SPA',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZkPWktVhjNwtXS7I_TJcZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/belle-cour-hotel-and-spa-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 51.4932327, 'longitude': -0.1397839},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '4 Upper Tachbrook Street',
#     'address2': 'Westminster',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1SH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['4 Upper Tachbrook Street',
#      'Westminster',
#      'London SW1V 1SH',
#      'United Kingdom']},
#    'phone': '+442078280206',
#    'display_phone': '+44 20 7828 0206',
#    'distance': 1130.796998857605},
#   {'id': 'zdxxuEB043cyX6kZI7bzWg',
#    'alias': 'landmark-apartments-london',
#    'name': 'Landmark Apartments',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Vwpp3awT11XEyjFiba1pZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/landmark-apartments-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'apartments', 'title': 'Apartments'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.5259472171549,
#     'longitude': -0.0822431630711833},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '28-30 Rivington Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2A 3DZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['28-30 Rivington Street',
#      'London EC2A 3DZ',
#      'United Kingdom']},
#    'phone': '+442077390093',
#    'display_phone': '+44 20 7739 0093',
#    'distance': 3992.175391091959},
#   {'id': 'smkEiZlVrK3nyMK_WlFWnw',
#    'alias': 'twelve-transfers-london-2',
#    'name': 'Twelve Transfers',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VmDVIov1Xw6nRhn9zO8rRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/twelve-transfers-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'airport_shuttles', 'title': 'Airport Shuttles'},
#     {'alias': 'taxis', 'title': 'Taxis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5371932983398,
#     'longitude': 0.0706439986824989},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'IG11 8BB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['London IG11 8BB', 'United Kingdom']},
#    'phone': '+442034795700',
#    'display_phone': '+44 20 3479 5700',
#    'distance': 14501.891893034968},
#   {'id': '0wB6Ps7T6cMY8JAA4s8BRg',
#    'alias': 'astor-court-hotel-london',
#    'name': 'Astor Court Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Nb3dc-MpF54ogfb1U56Kgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/astor-court-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 9,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.519802, 'longitude': -0.14317},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '20 Hallam Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 6JQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['20 Hallam Street',
#      'London W1W 6JQ',
#      'United Kingdom']},
#    'phone': '+442076364133',
#    'display_phone': '+44 20 7636 4133',
#    'distance': 912.0684890711954},
#   {'id': 'KDfl9NmXb4Er_bdXQyqRLg',
#    'alias': 'the-windmill-guest-house-london',
#    'name': 'The Windmill Guest House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-XjjyurIQOukGpsXHb-vMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-windmill-guest-house-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'guesthouses', 'title': 'Guest Houses'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5535221, 'longitude': -0.2119243},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '57 Cricklewood Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW2 3JX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['57 Cricklewood Broadway',
#      'London NW2 3JX',
#      'United Kingdom']},
#    'phone': '+442084504422',
#    'display_phone': '+44 20 8450 4422',
#    'distance': 6941.712121027308},
#   {'id': 'UIF5fUJ11b62WT0tW17Akg',
#    'alias': 'hilton-london-angel-islington-london-2',
#    'name': 'Hilton London Angel Islington',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8OUZuUiy6QNNwJlAXPAQWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hilton-london-angel-islington-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5362022, 'longitude': -0.1048415},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '53 Upper Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'N1 0UY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['53 Upper Street', 'London N1 0UY', 'United Kingdom']},
#    'phone': '+442073547700',
#    'display_phone': '+44 20 7354 7700',
#    'distance': 3374.0992307652855},
#   {'id': 'n7ksN4R9HVB-xigKLPOI7w',
#    'alias': 'comfort-inn-edgware-road-london-2',
#    'name': 'Comfort Inn Edgware Road',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/comfort-inn-edgware-road-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.5233231, 'longitude': -0.1745747},
#    'transactions': [],
#    'location': {'address1': '450 Edgware Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 1EG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['450 Edgware Road',
#      'London W2 1EG',
#      'United Kingdom']},
#    'phone': '+444402077243569',
#    'display_phone': '+44 4402077243569',
#    'distance': 2908.4166767638785},
#   {'id': 'z0x09usiTuKzJkpAcUPGyA',
#    'alias': 'restup-london',
#    'name': 'Restup',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/raOy1IBIqbHD_Qcwu8rcUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/restup-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 12,
#    'categories': [{'alias': 'hostels', 'title': 'Hostels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.4938653720948,
#     'longitude': -0.0906588734718525},
#    'transactions': [],
#    'location': {'address1': '172 New Kent Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 4YT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['172 New Kent Road',
#      'London SE1 4YT',
#      'United Kingdom']},
#    'phone': '+442036424549',
#    'display_phone': '+44 20 3642 4549',
#    'distance': 3778.786753216089},
#   {'id': 'ziGKBTeWiyCgpaahXyaSfQ',
#    'alias': '3pleclean-london',
#    'name': '3pleclean',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/R__HpXYrbYiJpN4ciR89Ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/3pleclean-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'homecleaning', 'title': 'Home Cleaning'},
#     {'alias': 'laundryservices', 'title': 'Laundry Services'},
#     {'alias': 'officecleaning', 'title': 'Office Cleaning'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.506420135498,
#     'longitude': -0.127210006117821},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'RH6 0NP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['London RH6 0NP', 'United Kingdom']},
#    'phone': '+447712279934',
#    'display_phone': '+44 7712 279934',
#    'distance': 832.9289576996765},
#   {'id': 'j2Kyw3VuGf7A-8MftbMmgQ',
#    'alias': 'homeclean-london-4',
#    'name': 'Homeclean',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/homeclean-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'homecleaning', 'title': 'Home Cleaning'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 51.534176, 'longitude': -0.1383},
#    'transactions': [],
#    'location': {'address1': '271 Eversholt Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 1BA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['271 Eversholt Street',
#      'London NW1 1BA',
#      'United Kingdom']},
#    'phone': '+442073834958',
#    'display_phone': '+44 20 7383 4958',
#    'distance': 2378.48614486776},
#   {'id': 'uP0PiLy43VLqea6XTpfpXA',
#    'alias': 'parislondonapartments-london-2',
#    'name': 'Parislondonapartments',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/parislondonapartments-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 10,
#    'categories': [{'alias': 'vacationrentalagents',
#      'title': 'Vacation Rental Agents'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 51.49838, 'longitude': -0.16397},
#    'transactions': [],
#    'location': {'address1': '9 Brompton Place',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW3 1QE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Brompton Place',
#      'London SW3 1QE',
#      'United Kingdom']},
#    'phone': '+442070992095',
#    'display_phone': '+44 20 7099 2095',
#    'distance': 2537.553043397645},
#   {'id': 'dASdaKgRlRk5hQH7Pacdnw',
#    'alias': 'holiday-inn-express-ealing-london-ealing',
#    'name': 'Holiday Inn Express - Ealing, London',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/F23pWVacOmi8hoh0lkFGuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holiday-inn-express-ealing-london-ealing?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5098193, 'longitude': -0.3248211},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '75 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Ealing',
#     'zip_code': 'W13 9BP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['75 Broadway', 'Ealing W13 9BP', 'United Kingdom']},
#    'phone': '+442085678832',
#    'display_phone': '+44 20 8567 8832',
#    'distance': 13074.378747062452},
#   {'id': '0rTsnYGt_8u7yxs8Xg6Ufw',
#    'alias': 'the-z-hotel-london-2',
#    'name': 'The Z Hotel ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3CJLCrY45PyM0kM2EqG6DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-z-hotel-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 28,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5268102, 'longitude': -0.0883364},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '136-144 City Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC1V 2RL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['136-144 City Road',
#      'London EC1V 2RL',
#      'United Kingdom']},
#    'phone': '+442035513700',
#    'display_phone': '+44 20 3551 3700',
#    'distance': 3644.427263709549},
#   {'id': 'FVO-zsFAMKMfWUcRQQq_Ag',
#    'alias': 'premier-inn-london-35',
#    'name': 'Premier Inn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/b9tM-j54JcJyWvlxU2q9kA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/premier-inn-london-35?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 11,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5284598, 'longitude': -0.1270915},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '88 Euston Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'NW1 2RA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['88 Euston Road', 'London NW1 2RA', 'United Kingdom']},
#    'phone': '+448715279492',
#    'display_phone': '+44 871 527 9492',
#    'distance': 1842.416431106924},
#   {'id': 'c1v7Niifty12aF8J6GH9lQ',
#    'alias': 'victory-services-club-london',
#    'name': 'Victory Services Club',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gUUcFguSbD7A2OsMkbcAoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/victory-services-club-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'social_clubs', 'title': 'Social Clubs'},
#     {'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.513906, 'longitude': -0.162217},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '63-79 Seymour Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 2HF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['63-79 Seymour Street',
#      'London W2 2HF',
#      'United Kingdom']},
#    'phone': '+442077234474',
#    'display_phone': '+44 20 7723 4474',
#    'distance': 1834.6690388518823},
#   {'id': 'CxRX95o8GeR4RSudMuiUaA',
#    'alias': 'skylark-b-and-b-hounslow',
#    'name': 'skylark B & B',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Mx1E_rqYU3O8vwenuhpHww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/skylark-b-and-b-hounslow?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.4719334, 'longitude': -0.3822922},
#    'transactions': [],
#    'location': {'address1': '297 Bath Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Hounslow',
#     'zip_code': 'TW3 3DB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['297 Bath Rd', 'Hounslow TW3 3DB', 'United Kingdom']},
#    'phone': '+442085778455',
#    'display_phone': '+44 20 8577 8455',
#    'distance': 17655.174948684496},
#   {'id': 'WobtLbKXCg2HOh-GuG5hkQ',
#    'alias': 'the-harpy-houseboat-tower-bridge-london',
#    'name': 'The Harpy Houseboat, Tower Bridge',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CrQy_B_4AGvOFQeOV2Ab6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-harpy-houseboat-tower-bridge-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'vacation_rentals', 'title': 'Vacation Rentals'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5023764262581,
#     'longitude': -0.0703685570431389},
#    'transactions': [],
#    'location': {'address1': 'River Thames',
#     'address2': 'China Wharf Mill Street',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 2BQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['River Thames',
#      'China Wharf Mill Street',
#      'London SE1 2BQ',
#      'United Kingdom']},
#    'phone': '+447836262222',
#    'display_phone': '+44 7836 262222',
#    'distance': 4685.835878476369},
#   {'id': 'zRWecrLR6rjSkEkxoCvyCA',
#    'alias': 'the-ampersand-hotel-london',
#    'name': 'The Ampersand Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/X55BRuZvbFG5y31Rx8fqHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ampersand-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4943093699229, 'longitude': -0.1755579},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '10 Harrington Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW7 3ER',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10 Harrington Road',
#      'London SW7 3ER',
#      'United Kingdom']},
#    'phone': '+442075895895',
#    'display_phone': '+44 20 7589 5895',
#    'distance': 3428.8544642715888},
#   {'id': 'JO-K5sPXnOBpyfSxm02uWA',
#    'alias': 'marlin-waterloo-london',
#    'name': 'Marlin Waterloo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W4w1Qd6fKOMwS8a6g9F6Ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marlin-waterloo-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 19,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4992169, 'longitude': -0.1130701},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '111 Westminster Bridge Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE1 7HR',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['111 Westminster Bridge Road',
#      'London SE1 7HR',
#      'United Kingdom']},
#    'phone': '+442039085000',
#    'display_phone': '+44 20 3908 5000',
#    'distance': 2191.359668221774},
#   {'id': 'jbHZtMH4L8bl0D3wT_6hgQ',
#    'alias': 'onefinestay-london-2',
#    'name': 'onefinestay',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YODkFD5-h_Dl5z83SDG6Tw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/onefinestay-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 41,
#    'categories': [{'alias': 'vacation_rentals', 'title': 'Vacation Rentals'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 51.5247, 'longitude': -0.107248},
#    'transactions': [],
#    'location': {'address1': '300 St John Street',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EC1V 4PA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['300 St John Street',
#      'London EC1V 4PA',
#      'United Kingdom']},
#    'phone': '+442070978948',
#    'display_phone': '+44 20 7097 8948',
#    'distance': 2384.543002753776},
#   {'id': 'wvO3KoWHOZW4sMebZohsjw',
#    'alias': 'doubletree-by-hilton-hotel-london-victoria-london-4',
#    'name': 'DoubleTree By Hilton Hotel London - Victoria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TIOEA4S15LjJ4AjagD4-8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doubletree-by-hilton-hotel-london-victoria-london-4?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 42,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4939289134206,
#     'longitude': -0.143322030594069},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '2 Bridge Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1QA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2 Bridge Place',
#      'London SW1V 1QA',
#      'United Kingdom']},
#    'phone': '+442078348123',
#    'display_phone': '+44 20 7834 8123',
#    'distance': 2163.2583537263167},
#   {'id': 'rCAmc_cKX5KAUHrZ9MUepg',
#    'alias': 'doubletree-by-hilton-hotel-london-west-end-london-3',
#    'name': 'DoubleTree by Hilton Hotel London - West End',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/px9AuLBF4PqNTSUMsHyRtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doubletree-by-hilton-hotel-london-west-end-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 40,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5202715055578,
#     'longitude': -0.121863203559605},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '92 Southampton Row',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC1B 4BH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['92 Southampton Row',
#      'London WC1B 4BH',
#      'United Kingdom']},
#    'phone': '+442072422828',
#    'display_phone': '+44 20 7242 2828',
#    'distance': 1278.5029739966878},
#   {'id': 'Kgop6RGkXKoBP7dHSDXCCg',
#    'alias': 'columbia-hotel-london',
#    'name': 'Columbia Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/I2AAlSIkLc0pej7VR6eLAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/columbia-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 13,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5114958, 'longitude': -0.1795872},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '95-99 Lancaster Gate',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W2 3NS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['95-99 Lancaster Gate',
#      'London W2 3NS',
#      'United Kingdom']},
#    'phone': '+442074020021',
#    'display_phone': '+44 20 7402 0021',
#    'distance': 3023.04830716498},
#   {'id': 'SIQrmYaOkv3WrY06DTbYQw',
#    'alias': 'the-original-london-sightseeing-tour-london-2',
#    'name': 'The Original London Sightseeing Tour',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6dMMwsad81Hd9qIbUkyqBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-original-london-sightseeing-tour-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 150,
#    'categories': [{'alias': 'tours', 'title': 'Tours'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.507524, 'longitude': -0.130541},
#    'transactions': [],
#    'location': {'address1': '17-19 Cockspur Street',
#     'address2': 'Trafalgar Square',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 5BL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17-19 Cockspur Street',
#      'Trafalgar Square',
#      'London SW1Y 5BL',
#      'United Kingdom']},
#    'phone': '+442088771722',
#    'display_phone': '+44 20 8877 1722',
#    'distance': 735.2697378683794},
#   {'id': 'Hl46n5tO4SvTRNOQ85kukA',
#    'alias': '88-studios-london',
#    'name': '88 Studios',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XJHlJuVvmx4dk6u-ZebuZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/88-studios-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4992798, 'longitude': -0.2091135},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '88 Holland Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W14 8BN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['88 Holland Road',
#      'London W14 8BN',
#      'United Kingdom']},
#    'phone': '+442076033116',
#    'display_phone': '+44 20 7603 3116',
#    'distance': 5280.268791330815},
#   {'id': 'sr8BnwvsWY-InK6N7Hpg6A',
#    'alias': 'fantastic-cleaners-london-8',
#    'name': 'Fantastic Cleaners',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yx08DfImeeG15xtbWzguvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fantastic-cleaners-london-8?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 23,
#    'categories': [{'alias': 'homecleaning', 'title': 'Home Cleaning'},
#     {'alias': 'officecleaning', 'title': 'Office Cleaning'},
#     {'alias': 'carpet_cleaning', 'title': 'Carpet Cleaning'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5044038, 'longitude': -0.0824881},
#    'transactions': [],
#    'location': {'address1': 'Tooley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 2TH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Tooley Street', 'London SE1 2TH', 'United Kingdom']},
#    'phone': '+442034040145',
#    'display_phone': '+44 20 3404 0145',
#    'distance': 3817.2841678411596},
#   {'id': 'nIPi8iSdlG3SlpRL0_ePtw',
#    'alias': 'thistle-kensington-gardens-london-3',
#    'name': 'Thistle Kensington Gardens',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/voKlKjrir0tzLoK3OM8_8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thistle-kensington-gardens-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 32,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5109254, 'longitude': -0.1838732},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '104 Bayswater Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W2 3HL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['104 Bayswater Road',
#      'London W2 3HL',
#      'United Kingdom']},
#    'phone': '+448003308391',
#    'display_phone': '+44 800 330 8391',
#    'distance': 3322.790941353353},
#   {'id': 'hLzmh0Lq2cHJDDntlnNeuw',
#    'alias': 'holiday-inn-london-27',
#    'name': 'Holiday Inn ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_LoaWX23-fp7cQhPuk92_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holiday-inn-london-27?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 18,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.5225489331923,
#     'longitude': -0.142724030932378},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Carburton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1W 5EE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Carburton Street',
#      'London W1W 5EE',
#      'United Kingdom']},
#    'phone': '+448719429111',
#    'display_phone': '+44 871 942 9111',
#    'distance': 1177.2406813961143},
#   {'id': 'iNVune316w9k2X5W98CLUA',
#    'alias': 'william-hemming-associates-london',
#    'name': 'William Hemming Associates',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vWNWpDAqStgLz0J6iPXWQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/william-hemming-associates-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'apartmentagents', 'title': 'Apartment Agents'},
#     {'alias': 'propertymgmt', 'title': 'Property Management'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 51.4924392700195,
#     'longitude': -0.165040001273155},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SW3 3AX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['London SW3 3AX', 'United Kingdom']},
#    'phone': '+442076664350',
#    'display_phone': '+44 20 7666 4350',
#    'distance': 3040.058788945707},
#   {'id': '0ZmzmYq-pHHLYDlelbWJLg',
#    'alias': 'lse-grosvenor-house-london-2',
#    'name': 'LSE Grosvenor House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xotbZGWxhjwnyKEiBeS5WQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lse-grosvenor-house-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 2,
#    'categories': [{'alias': 'vacation_rentals', 'title': 'Vacation Rentals'},
#     {'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 51.5143465191805,
#     'longitude': -0.121290050331936},
#    'transactions': [],
#    'location': {'address1': '141-143 Drury Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2B 5TB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['141-143 Drury Lane',
#      'London WC2B 5TB',
#      'United Kingdom']},
#    'phone': '+442071075950',
#    'display_phone': '+44 20 7107 5950',
#    'distance': 1028.6806771058673},
#   {'id': 'xawtwMNiOkskcvgQohFUNQ',
#    'alias': 'thistle-city-barbican-hotel-london',
#    'name': 'Thistle City Barbican Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ansR8O-sdDDBx99sieiLeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thistle-city-barbican-hotel-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 27,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5274751, 'longitude': -0.0969153},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '120 Central Street',
#     'address2': 'Finsbury',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'EC1V 8DS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['120 Central Street',
#      'Finsbury',
#      'London EC1V 8DS',
#      'United Kingdom']},
#    'phone': '+448713769004',
#    'display_phone': '+44 871 376 9004',
#    'distance': 3153.7887136998957},
#   {'id': 'Ut5NZhcbl1bElj1JEIPmTg',
#    'alias': 'holiday-inn-london-kensington-london-2',
#    'name': 'Holiday Inn London - Kensington',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NgPy3GQRNNxXDpJW1p09GA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holiday-inn-london-kensington-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 74,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 51.4988245259061,
#     'longitude': -0.191950977925019},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Wrights Lane',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W8 5SP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Wrights Lane', 'London W8 5SP', 'United Kingdom']},
#    'phone': '+442079378289',
#    'display_phone': '+44 20 7937 8289',
#    'distance': 4176.936314313553},
#   {'id': 'pbOdb4qRv8Q2AZ7qGbFzdQ',
#    'alias': 'viator-london',
#    'name': 'Viator',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/viator-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 22,
#    'categories': [{'alias': 'tours', 'title': 'Tours'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 51.492228, 'longitude': -0.119888},
#    'transactions': [],
#    'location': {'address1': 'Southbank House Black Prince Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 7SJ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Southbank House Black Prince Rd',
#      'London SE1 7SJ',
#      'United Kingdom']},
#    'phone': '+442031760067',
#    'display_phone': '+44 20 3176 0067',
#    'distance': 2547.0838004509583}],
#  'total': 62,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the first 50 records 0-50

#Create Empty Lists
lat1=[]
lng1=[]
address1=[]
name1=[]
title1=[]
price1=[]
rating1=[]
ids1=[]
url1=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndh1["businesses"]):
    try:
        lat1.append (i["coordinates"]["latitude"])
        lng1.append (i["coordinates"]["longitude"])
        address1.append (i["location"]["address1"])
        name1.append (i["name"])    
        title1.append(i["categories"][0]["title"])
        price1.append (i["price"])
        rating1.append (i["rating"])
        ids1.append (i["id"])
        url1.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price1.append("")
        rating1.append("")
        ids1.append("")
        url1.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the first 50 records collected 
df1 = pd.DataFrame({"Lodging": name1,"Type": title1, "Price":price1, "Rating":rating1, "Address":address1, "Lat":lat1, "Lng":lng1, "url":url1, "ID":ids1 })
df1.head()
# Out:
#                      Lodging          Type Price Rating  \
# 0                   Sohostel       Hostels
# 1     Juliette's Guest House  Guest Houses
# 2       The Kensington Hotel        Hotels   £££    4.5
# 3  Residence Inn by Marriott        Hotels    ££      4
# 4             CitizenM Hotel        Hotels    ££    4.5
#
#                   Address        Lat       Lng  \
# 0          91 Dean Street  51.515078 -0.133681
# 1            29 Dawson Pl  51.512094 -0.197425
# 2  109 - 113 Queen's Gate  51.492559 -0.178064
# 3     201 - 211 Long Lane  51.498716 -0.084136
# 4     20 Lavington Street  51.505116 -0.098283
#
#                                                  url                      ID
# 0
# 1
# 2  https://www.yelp.com/biz/the-kensington-hotel-...  hGJkHYD10mPIh-R_xrUQNg
# 3  https://www.yelp.com/biz/residence-inn-by-marr...  VWTYSnuV3IDJJjSk7kzMkw
# 4  https://www.yelp.com/biz/citizenm-hotel-london...  1tyiyRStaEuq_0hBc6ypCg

# %%
#2nd set of 50 records 51-100 
lndh_params2 = {"term":"airbnb","location":"London","limit":50,"offset":51}
lndh_response2 = requests.get(search_api_url, headers=headers, params=lndh_params2)
lndh2 = lndh_response2.json()
display(lndh2)
#print(lndh_response2.url)
#print(lndh_response2.status_code)
# Out:
# {'businesses': [{'id': '_r4DR4URkkXstTGL12FaFQ',
#    'alias': 'minicabit-london',
#    'name': 'Minicabit',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YIdi50JakXkDfCZNpSVlRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/minicabit-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 6,
#    'categories': [{'alias': 'airport_shuttles', 'title': 'Airport Shuttles'},
#     {'alias': 'taxis', 'title': 'Taxis'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 51.5195401, 'longitude': -0.0986683},
#    'transactions': [],
#    'location': {'address1': '80-83 Long Lane',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 4AU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['80-83 Long Lane',
#      'London SE1 4AU',
#      'United Kingdom']},
#    'phone': '+441234868568',
#    'display_phone': '+44 1234 868568',
#    'distance': 2685.686127077677},
#   {'id': 'xXdyZA1hE2FkPNOBt9SAjw',
#    'alias': 'pembury-hotel-london-2',
#    'name': 'Pembury Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CQJKMKsvMfIGNXNGoFn_6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pembury-hotel-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 51.56598, 'longitude': -0.10204},
#    'transactions': [],
#    'location': {'address1': '326 - 328 Seven Sisters Road',
#     'address2': 'Finsbury Park',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'N4 2AP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['326 - 328 Seven Sisters Road',
#      'Finsbury Park',
#      'London N4 2AP',
#      'United Kingdom']},
#    'phone': '+448444721800',
#    'display_phone': '+44 844 472 1800',
#    'distance': 6365.695874737517},
#   {'id': 'ayRI5U1w3BcTP7q0fTTPtw',
#    'alias': 'travelwifi-london',
#    'name': 'Travelwifi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VrKT263Lp-7VZsdOfd-KLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/travelwifi-london?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 71,
#    'categories': [{'alias': 'isps', 'title': 'Internet Service Providers'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.526257, 'longitude': -0.208762},
#    'transactions': [],
#    'location': {'address1': '222 Kensal Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W10 5BN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['222 Kensal Road',
#      'London W10 5BN',
#      'United Kingdom']},
#    'phone': '+44442033182523',
#    'display_phone': '+44 442033182523',
#    'distance': 5253.929128759237},
#   {'id': 'Lt_ivWH9BMZ7JJF20HCKUQ',
#    'alias': 'premium-tours-london-2',
#    'name': 'Premium Tours',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tr7xewsQ06Nibqx2aGPyCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/premium-tours-london-2?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 86,
#    'categories': [{'alias': 'travelservices', 'title': 'Travel Services'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 51.4924656, 'longitude': -0.2545921},
#    'transactions': [],
#    'location': {'address1': '2A Brackley Road',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W4 2HN',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['2A Brackley Road',
#      'London W4 2HN',
#      'United Kingdom']},
#    'phone': '+442077131311',
#    'display_phone': '+44 20 7713 1311',
#    'distance': 8523.294254975579},
#   {'id': 'XtsuXYJnSbS3hw0qnsuTBQ',
#    'alias': 'hilton-garden-inn-london-heathrow-airport-london-3',
#    'name': 'Hilton Garden Inn London Heathrow Airport',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8q85L8Aqul8RM3E9Fhziyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hilton-garden-inn-london-heathrow-airport-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 47,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4681555455725,
#     'longitude': -0.419068933362628},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': 'Eastern Perimeter Road',
#     'address2': 'Hatton Cross',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'TW6 2SQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Eastern Perimeter Road',
#      'Hatton Cross',
#      'London TW6 2SQ',
#      'United Kingdom']},
#    'phone': '+442082664664',
#    'display_phone': '+44 20 8266 4664',
#    'distance': 20221.096154209506},
#   {'id': 'siDpmUF4bhnLHYo3z4wBSg',
#    'alias': 'hilton-london-wembley-wembley',
#    'name': 'Hilton London Wembley',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Rr7hGjIN9KjAef64GWozMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hilton-london-wembley-wembley?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 14,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.5573196411133,
#     'longitude': -0.283809006214142},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'Lakeside Way',
#     'address2': '',
#     'address3': '',
#     'city': 'Wembley',
#     'zip_code': 'HA9 0BU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Lakeside Way', 'Wembley HA9 0BU', 'United Kingdom']},
#    'phone': '+44442081508090',
#    'display_phone': '+44 442081508090',
#    'distance': 11273.747127379576},
#   {'id': 'i0FcKRH5CB_w1lwRY8LjpQ',
#    'alias': 'data-cars-london-3',
#    'name': 'Data Cars',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gZl9SLHpORqe7hfLlW27dA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/data-cars-london-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 3,
#    'categories': [{'alias': 'taxis', 'title': 'Taxis'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 51.4611575, 'longitude': -0.006084},
#    'transactions': [],
#    'location': {'address1': '94 Lee High Road Lewisham',
#     'address2': None,
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE13 5PT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['94 Lee High Road Lewisham',
#      'London SE13 5PT',
#      'United Kingdom']},
#    'phone': '+442088500000',
#    'display_phone': '+44 20 8850 0000',
#    'distance': 10671.57198177124},
#   {'id': 'hShwCJPf-A0RjFam_I_V-A',
#    'alias': 'moxy-london-heathrow-airport-hounslow-3',
#    'name': 'Moxy London Heathrow Airport',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mZiW-oQUH2q9rqAZzLrQzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moxy-london-heathrow-airport-hounslow-3?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 15,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.480226, 'longitude': -0.414795},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '804 Bath Road',
#     'address2': None,
#     'address3': 'Heathrow Airport',
#     'city': 'Hounslow',
#     'zip_code': 'TW5 9UH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['804 Bath Road',
#      'Heathrow Airport',
#      'Hounslow TW5 9UH',
#      'United Kingdom']},
#    'phone': '+442033188100',
#    'display_phone': '+44 20 3318 8100',
#    'distance': 19640.432272068592},
#   {'id': 'p4ew7JO_a6Gj3NDHo2G0sg',
#    'alias': 'hotel-ibis-heathrow-hayes',
#    'name': 'Hotel Ibis Heathrow',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0U7VGrsJ9n-d0L3v2DB5tQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-ibis-heathrow-hayes?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 35,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 51.4808865597196,
#     'longitude': -0.430631377662583},
#    'transactions': [],
#    'price': '£',
#    'location': {'address1': '112 Bath Road',
#     'address2': '',
#     'address3': None,
#     'city': 'Hayes',
#     'zip_code': 'UB3 5AL',
#     'country': 'GB',
#     'state': 'DOR',
#     'display_address': ['112 Bath Road', 'Hayes UB3 5AL', 'United Kingdom']},
#    'phone': '+442087594888',
#    'display_phone': '+44 20 8759 4888',
#    'distance': 20705.98346036474},
#   {'id': 'qm0aLs1uUH4rXWQXNS6c0A',
#    'alias': 'royal-oak-hotel-sevenoaks',
#    'name': 'Royal Oak Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rD01sRWU16xRiJ8IJa5n5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/royal-oak-hotel-sevenoaks?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 5,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 51.26871, 'longitude': 0.1937599},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': 'High Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Sevenoaks',
#     'zip_code': 'TN13 1HY',
#     'country': 'GB',
#     'state': 'KEN',
#     'display_address': ['High Street',
#      'Sevenoaks TN13 1HY',
#      'United Kingdom']},
#    'phone': '+441732451109',
#    'display_phone': '+44 1732 451109',
#    'distance': 35348.67561183494},
#   {'id': 'Y_NKoKKdaaIUQb9Qm-NPfg',
#    'alias': 'budget-car-rental-longford',
#    'name': 'Budget Car Rental',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Q_7HKV1kyr2Rdkn6N9iiQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/budget-car-rental-longford?adjust_creative=-uBzzloii2ivvF3N0jkhKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uBzzloii2ivvF3N0jkhKQ',
#    'review_count': 1,
#    'categories': [{'alias': 'carrental', 'title': 'Car Rental'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 51.479901, 'longitude': -0.431261},
#    'transactions': [],
#    'location': {'address1': 'Northrop Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Longford',
#     'zip_code': 'TW6 2QA',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['Northrop Road',
#      'Longford TW6 2QA',
#      'United Kingdom']},
#    'phone': '+448445444600',
#    'display_phone': '+44 844 544 4600',
#    'distance': 20728.962615041135}],
#  'total': 62,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the second set of 50 records 51-100

#Create Empty Lists
lat2=[]
lng2=[]
address2=[]
name2=[]
title2=[]
price2=[]
rating2=[]
ids2=[]
url2=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndh2["businesses"]):
    try:
        lat2.append (i["coordinates"]["latitude"])
        lng2.append (i["coordinates"]["longitude"])
        address2.append (i["location"]["address1"])
        name2.append (i["name"])    
        title2.append(i["categories"][0]["title"])
        price2.append (i["price"])
        rating2.append (i["rating"])
        ids2.append (i["id"])
        url2.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price2.append("")
        rating2.append("")
        ids2.append("")
        url2.append("")
# Out:
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found
# Skipping, Not Found

# %%
#Create DataFrame of the next 50 records collected 51-100
df2 = pd.DataFrame({"Lodging": name2,"Type": title2, "Price":price2, "Rating":rating2, "Address":address2, "Lat":lat2, "Lng":lng2, "url":url2, "ID":ids2 })
df2.head()
# Out:
#                                      Lodging                        Type  \
# 0                                  Minicabit            Airport Shuttles
# 1                              Pembury Hotel                      Hotels
# 2                                 Travelwifi  Internet Service Providers
# 3                              Premium Tours             Travel Services
# 4  Hilton Garden Inn London Heathrow Airport                      Hotels
#
#   Price Rating                       Address        Lat       Lng  \
# 0                            80-83 Long Lane  51.519540 -0.098668
# 1               326 - 328 Seven Sisters Road  51.565980 -0.102040
# 2                            222 Kensal Road  51.526257 -0.208762
# 3                           2A Brackley Road  51.492466 -0.254592
# 4    ££      4        Eastern Perimeter Road  51.468156 -0.419069
#
#                                                  url                      ID
# 0
# 1
# 2
# 3
# 4  https://www.yelp.com/biz/hilton-garden-inn-lon...  XtsuXYJnSbS3hw0qnsuTBQ

# %%
#3rd set of 50 records 101-150
lndh_params3 = {"term":"airbnb","location":"London","limit":50,"offset":101}
lndh_response3 = requests.get(search_api_url, headers=headers, params=lndh_params3)
lndh3 = lndh_response3.json()
display(lndh3)
#print(lndh_response3.url)
#print(lndh_response3.status_code)
# Out:
# {'businesses': [],
#  'total': 62,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the third iteration of 50 records 101-150

#Create Empty Lists
lat3=[]
lng3=[]
address3=[]
name3=[]
title3=[]
price3=[]
rating3=[]
ids3=[]
url3=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndh3["businesses"]):
    try:
        lat3.append (i["coordinates"]["latitude"])
        lng3.append (i["coordinates"]["longitude"])
        address3.append (i["location"]["address1"])
        name3.append (i["name"])    
        title3.append(i["categories"][0]["title"])
        price3.append (i["price"])
        rating3.append (i["rating"])
        ids3.append (i["id"])
        url3.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price3.append("")
        rating3.append("")
        ids3.append("")
        url3.append("")

# %%
#Create DataFrame of the third set of 50 records collected 101-150 
df3 = pd.DataFrame({"Lodging": name3,"Type": title3, "Price":price3, "Rating":rating3, "Address":address3, "Lat":lat3, "Lng":lng3, "url":url3, "ID":ids3 })
df3.head()
# Out:
# Empty DataFrame
# Columns: [Lodging, Type, Price, Rating, Address, Lat, Lng, url, ID]
# Index: []

# %%
#4th set of 50 records 151-200
lndh_params4 = {"term":"airbnb","location":"London","limit":50,"offset":151}
lndh_response4 = requests.get(search_api_url, headers=headers, params=lndh_params4)
lndh4 = lndh_response4.json()
display(lndh4)
#print(lndh_response4.url)
#print(lndh_response4.status_code)
# Out:
# {'businesses': [],
#  'total': 62,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %%
#Create a for loop to capture the data of the fourth set of 50 records 151-200

#Create Empty Lists
lat4=[]
lng4=[]
address4=[]
name4=[]
title4=[]
price4=[]
rating4=[]
ids4=[]
url4=[]

#Set Counter to 0
i = 0

#For Loop with Try/Except Error
for i in (lndh4["businesses"]):
    try:
        lat4.append (i["coordinates"]["latitude"])
        lng4.append (i["coordinates"]["longitude"])
        address4.append (i["location"]["address1"])
        name4.append (i["name"])    
        title4.append(i["categories"][0]["title"])
        price4.append (i["price"])
        rating4.append (i["rating"])
        ids4.append (i["id"])
        url4.append (i["url"])
    except(KeyError,IndexError):
        print("Skipping, Not Found")
        price4.append("")
        rating4.append("")
        ids4.append("")
        url4.append("")

# %%
#Create DataFrame of the last 50 records collected 151-200
df4 = pd.DataFrame({"Lodging": name4,"Type": title4, "Price":price4, "Rating":rating4, "Address":address4, "Lat":lat4, "Lng":lng4, "url":url4, "ID":ids4 })
df4.head()
# Out:
# Empty DataFrame
# Columns: [Lodging, Type, Price, Rating, Address, Lat, Lng, url, ID]
# Index: []

# %%
london_hotels_df = pd.concat([df1,df2,df3,df4], sort=True)
london_hotels_df.shape
# Out:
# (61, 9)

# %%
column_order = ["Lodging","Type","Rating","Price","Address","Lat","Lng","url","ID"]
london_hotels_df = london_hotels_df[column_order]
london_hotels_df = london_hotels_df.sort_values(["Type"], ascending=True)
london_hotels_df = london_hotels_df.reset_index(drop=True)
london_hotels_df
# Out:
#                                          Lodging                        Type  \
# 0                                      Minicabit            Airport Shuttles
# 1                               Twelve Transfers            Airport Shuttles
# 2                     William Hemming Associates            Apartment Agents
# 3                                  skylark B & B             Bed & Breakfast
# 4                              Budget Car Rental                  Car Rental
# 5                         Juliette's Guest House                Guest Houses
# 6                       The Windmill Guest House                Guest Houses
# 7                             Fantastic Cleaners               Home Cleaning
# 8                                      Homeclean               Home Cleaning
# 9                                      3pleclean               Home Cleaning
# 10                                        Restup                     Hostels
# 11                         The Dictionary Hostel                     Hostels
# 12                                      Sohostel                     Hostels
# 13                                   Leman Locke                      Hotels
# 14            Point A Hotel London - Westminster                      Hotels
# 15  DoubleTree By Hilton Hotel London - Victoria                      Hotels
# 16  DoubleTree by Hilton Hotel London - West End                      Hotels
# 17                                Columbia Hotel                      Hotels
# 18                                    88 Studios                      Hotels
# 19                                CitizenM Hotel                      Hotels
# 20                    Thistle Kensington Gardens                      Hotels
# 21                                  Holiday Inn                       Hotels
